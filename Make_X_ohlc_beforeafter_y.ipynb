# %%
import numpy as np
import pandas as pd
import pybithumb
import os
import matplotlib.pyplot as plt
import warnings
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime
from Funcs_CNN4 import obv
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 500)

Scaler = MinMaxScaler()

dir = 'ohlcv/'
ohlcv_list = os.listdir(dir)


def min_max_scaler(price):
    Scaler = MinMaxScaler()
    Scaler.fit(price)

    return Scaler.transform(price)


def low_high(Coin, input_data_length, ip_limit=None, trade_limit=None, crop_size=300, sudden_death=0):

    #   거래 제한은 고점과 저점을 분리한다.

    #   User-Agent Configuration
    #   IP - Change
    if ip_limit is None:
        ohlcv_excel = pybithumb.get_ohlcv(Coin, 'KRW', 'minute1')
    else:
        ohlcv_excel = pybithumb.get_ohlcv(Coin, 'KRW', 'minute1', 'proxyon')

    price_gap = ohlcv_excel.close.max() / ohlcv_excel.close.min()
    if (price_gap < 1.07) and (trade_limit is not None):
        return None, None, None

    obv = [0] * len(ohlcv_excel)
    for m in range(1, len(ohlcv_excel)):
        if ohlcv_excel['close'].iloc[m] > ohlcv_excel['close'].iloc[m - 1]:
            obv[m] = obv[m - 1] + ohlcv_excel['volume'].iloc[m]
        elif ohlcv_excel['close'].iloc[m] == ohlcv_excel['close'].iloc[m - 1]:
            obv[m] = obv[m - 1]
        else:
            obv[m] = obv[m - 1] - ohlcv_excel['volume'].iloc[m]
    ohlcv_excel['OBV'] = obv

    closeprice = ohlcv_excel['close'].iloc[-1]
    datetime_list = ohlcv_excel.index.values

    # ----------- dataX, dataY 추출하기 -----------#
    #   OBV :
    ohlcv_data = ohlcv_excel.values[1:].astype(np.float)

    # 결측 데이터 제외
    if len(ohlcv_data) != 0:

        #          데이터 전처리         #
        #   Fixed X_data    #
        # price = ohlcv_data[:, :4]
        # volume = ohlcv_data[:, [4]]
        # OBV = ohlcv_data[:, [-1]]
        #
        # scaled_price = min_max_scaler(price)
        # scaled_volume = min_max_scaler(volume)
        # scaled_OBV = min_max_scaler(OBV)
        # print(scaled_MA60.shape)

        # x = np.concatenate((scaled_price, scaled_volume, scaled_OBV), axis=1)  # axis=1, 세로로 합친다
        # print(x.shape)
        # print(ohlcv_data.shape)
        # quit()

        # if (x[-1][1] > 0.3) and (trade_limit is not None):
        #     return None, None

        # print(x.shape)  # (258, 6)
        # quit()

        dataX = []  # input_data length 만큼 담을 dataX 그릇
        for i in range(crop_size, len(ohlcv_data) + 1):  # 마지막 데이터까지 다 긇어모은다.
            group_x = ohlcv_data[i - crop_size: i]
            scaled_price = min_max_scaler(group_x[:, :4])
            # scaled_volume = min_max_scaler(group_x[:, [4]])
            # scaled_OBV = min_max_scaler(group_x[:, [-1]])
            # x = np.concatenate((scaled_price, scaled_volume, scaled_OBV), axis=1) + sudden_death  # axis=1, 세로로 합친다
            x = scaled_price + sudden_death  # axis=1, 세로로 합친다
            group_x = x[-input_data_length:]
            # print(group_x[-1:, 1:2])
            # print(group_x.shape)
            # print(group_x.max())
            dataX.append(group_x)  # dataX 리스트에 추가

        if len(dataX) < 100:
            return None, None, None, None

        # quit()
        X_test = np.array(dataX)
        row = X_test.shape[1]
        col = X_test.shape[2]

        X_test = X_test.astype('float32').reshape(-1, row, col, 1)
        # closeprice = np.roll(np.array(list(map(lambda x: x[-1][[1]][0], X_test))), -1)
        # plt.plot(closeprice)
        # plt.show()

        return X_test, closeprice, min_max_scaler(ohlcv_data[crop_size:, [1]]), datetime_list


def low_high_origin(Coin, input_data_length, ip_limit=None, trade_limit=None, crop_size=300, sudden_death=0):

    #   거래 제한은 고점과 저점을 분리한다.

    #   User-Agent Configuration
    #   IP - Change
    if ip_limit is None:
        ohlcv_excel = pybithumb.get_ohlcv(Coin, 'KRW', 'minute1')
    else:
        ohlcv_excel = pybithumb.get_ohlcv(Coin, 'KRW', 'minute1', 'proxyon')

    price_gap = ohlcv_excel.close.max() / ohlcv_excel.close.min()
    if (price_gap < 1.07) and (trade_limit is not None):
        return None, None, None

    obv = [0] * len(ohlcv_excel)
    for m in range(1, len(ohlcv_excel)):
        if ohlcv_excel['close'].iloc[m] > ohlcv_excel['close'].iloc[m - 1]:
            obv[m] = obv[m - 1] + ohlcv_excel['volume'].iloc[m]
        elif ohlcv_excel['close'].iloc[m] == ohlcv_excel['close'].iloc[m - 1]:
            obv[m] = obv[m - 1]
        else:
            obv[m] = obv[m - 1] - ohlcv_excel['volume'].iloc[m]
    ohlcv_excel['OBV'] = obv

    closeprice = ohlcv_excel['close'].iloc[-1]
    datetime_list = ohlcv_excel.index.values

    # ----------- dataX, dataY 추출하기 -----------#
    #   OBV :
    ohlcv_data = ohlcv_excel.values[1:].astype(np.float)

    # 결측 데이터 제외
    if len(ohlcv_data) != 0:

        #          데이터 전처리         #
        #   Fixed X_data    #
        price = ohlcv_data[:, :4]
        volume = ohlcv_data[:, [4]]
        OBV = ohlcv_data[:, [-1]]

        scaled_price = min_max_scaler(price)
        scaled_volume = min_max_scaler(volume)
        scaled_OBV = min_max_scaler(OBV)
        # print(scaled_MA60.shape)

        # x = np.concatenate((scaled_price, scaled_volume, scaled_OBV), axis=1)  # axis=1, 세로로 합친다
        x = scaled_price
        # print(x.shape)
        # print(ohlcv_data.shape)
        # quit()

        # if (x[-1][1] > 0.3) and (trade_limit is not None):
        #     return None, None

        # print(x.shape)  # (258, 6)
        # quit()

        dataX = []  # input_data length 만큼 담을 dataX 그릇
        for i in range(input_data_length, len(x) + 1):  # 마지막 데이터까지 다 긇어모은다.
            group_x = x[i - input_data_length:i]
            dataX.append(group_x)  # dataX 리스트에 추가

        if len(dataX) < 100:
            return None, None, None

        # quit()
        X_test = np.array(dataX)
        row = X_test.shape[1]
        col = X_test.shape[2]

        X_test = X_test.astype('float32').reshape(-1, row, col, 1)

        return X_test, closeprice, min_max_scaler(ohlcv_data[input_data_length:, [1]]), datetime_list


def made_x(file, input_data_length, model_num, check_span, get_fig, crop_size=500, sudden_death=0):

    try:
        ohlcv_excel = pd.read_excel(dir + file, index_col=0)
    except Exception as e:
        return None, None, None

    # ohlcv_excel['CMO'] = cmo(ohlcv_excel)
    # ohlcv_excel['OBV'] = obv(ohlcv_excel)
    # ohlcv_excel['RSI'] = rsi(ohlcv_excel)

#     print(ohlcv_excel.info())
#     quit()

    #   이후 check_span 데이터와 현재 포인트를 비교해서 현재 포인트가 저가인지 고가인지 예측한다.
    #   진입, 저점, 고점, 거래 안함의 y_label 인 trade_state  >> [1, 2, 0]
    #   저점과 고점은 최대 3개의 중복 값을 허용한다.
    trade_state = [np.NaN] * len(ohlcv_excel)
    for i in range(len(ohlcv_excel) - check_span):
        #   저점
        if ohlcv_excel['close'][i - check_span:i].min() >= ohlcv_excel['close'][i]:
            if ohlcv_excel['close'][i + 1:i + 1 + check_span].min() >= ohlcv_excel['close'][i]:
                # if ohlcv_excel['close'][i - check_span:i + 1 + check_span].value_counts().sort_index().iloc[0] <= 3:
                if 1 not in trade_state[i - check_span:i]:
                    trade_state[i] = 1
                else:
                    trade_state[i] = 0
                # else:
                #     trade_state[i] = 0
            else:
                trade_state[i] = 0
        #   고점
        elif ohlcv_excel['close'][i - check_span:i].max() <= ohlcv_excel['close'][i]:
            if ohlcv_excel['close'][i + 1:i + 1 + check_span].max() <= ohlcv_excel['close'][i]:
                # if ohlcv_excel['close'][i - check_span:i + 1 + check_span].value_counts().sort_index().iloc[-1] <= 3:
                if 2 not in trade_state[i - check_span:i]:
                    trade_state[i] = 2
                else:
                    trade_state[i] = 0
            # else:
            #     trade_state[i] = 0
            else:
                trade_state[i] = 0

        #   거래 안함
        else:
            trade_state[i] = 0

    ohlcv_excel['trade_state'] = trade_state

    # ----------- dataX, dataY 추출하기 -----------#
    # print(ohlcv_excel.info())
    # ohlcv_excel.to_excel('test.xlsx')
    # quit()

    # NaN 제외하고 데이터 자르기 (데이터가 PIXEL 로 들어간다고 생각하면 된다)
    #   OBV : -CHECK_SPAN
    ohlcv_data = ohlcv_excel.values[: -check_span].astype(np.float)
    # ohlcv_data = ohlcv_excel.values[1: -check_span].astype(np.float)
    # ohlcv_data = ohlcv_excel.values[sum(ohlcv_excel.CMO.isna()): -check_span].astype(np.float)
    # ohlcv_data = ohlcv_excel.values[sum(ohlcv_excel.RSI.isna()): -check_span].astype(np.float)

    # print(pd.DataFrame(ohlcv_data).info())
    # print(pd.DataFrame(ohlcv_data).to_excel('test.xlsx'))
    # print(list(map(float, ohlcv_data[0])))
    # quit()

    #       출력되는 Y 데이터 길이를 동일화 시킨다.     #
    # ohlcv_data = ohlcv_data[-300:]

    # 결측 데이터 제외
    if len(ohlcv_data) != 0:

        #          데이터 전처리         #
        #   Fixed X_data    #
        price = ohlcv_data[:, :4]
        # volume = ohlcv_data[:, [4]]
        # CMO = ohlcv_data[:, [-2]]
        # OBV = ohlcv_data[:, [-2]]
        # RSI = ohlcv_data[:, [-2]]

        #   Flexible Y_data    #
        trade_state = ohlcv_data[:, [-1]]

        # scaled_price = min_max_scaler(price)
        # scaled_volume = min_max_scaler(volume)
        # scaled_CMO = min_max_scaler(CMO)
        # scaled_OBV = min_max_scaler(OBV)
        # scaled_RSI = min_max_scaler(RSI)

        # x = np.concatenate((scaled_price, scaled_volume, scaled_OBV), axis=1)  # axis=1, 세로로 합친다
        # x = scaled_price
        y = trade_state
        # print(x.shape, y_low.shape)  # (258, 6) (258, 1)
        # quit()

        dataX = []  # input_data length 만큼 담을 dataX 그릇
        dataY = []  # Target 을 담을 그릇
        for i in range(crop_size, len(ohlcv_data)):  # 마지막 데이터까지 다 긇어모은다.
            group_x = ohlcv_data[i - crop_size: i]
            group_y = y[i]
            scaled_price = min_max_scaler(group_x[:, :4])
            x = scaled_price + sudden_death  # axis=1, 세로로 합친다
            group_x = x[-input_data_length:]

            dataX.append(group_x)  # dataX 리스트에 추가
            dataY.append(group_y)

        if len(dataX) < 100:
            print('len(dataX) < 100')
            return None, None, None

        X_test = np.array(dataX)
        row = X_test.shape[1]
        col = X_test.shape[2]

        X_test = X_test.astype('float32').reshape(-1, row, col, 1)
        # print(X_test.shape)

        #       Exstracting fiexd X_data       #
        sliced_ohlcv = ohlcv_data[crop_size:, :x.shape[1]]

        #                      Get Figure                     #
        if get_fig == 1:
            spanlist_low = []
            spanlist_high = []

            for m in range(len(trade_state)):
                if (trade_state[m] > 0.5) and (trade_state[m] < 1.5):
                    if m + 1 < len(trade_state):
                        spanlist_low.append((m, m + 1))
                    else:
                        spanlist_low.append((m - 1, m))

            for m in range(len(trade_state)):
                if (trade_state[m] > 1.5) and (trade_state[m] < 2.5):
                    if m + 1 < len(trade_state):
                        spanlist_high.append((m, m + 1))
                    else:
                        spanlist_high.append((m - 1, m))

            # ----------- 인덱스 초기화 됨 -----------#

            # ----------- 공통된 Chart 그리기 -----------#

            plt.subplot(211)
            plt.plot(min_max_scaler(ohlcv_data[:, 1:2]), 'r', label='close')
            # plt.plot(scaled_OBV, 'b', label='OBV')
            plt.legend(loc='upper right')
            for i in range(len(spanlist_low)):
                plt.axvspan(spanlist_low[i][0], spanlist_low[i][1], facecolor='m', alpha=0.5)

            plt.subplot(212)
            plt.plot(min_max_scaler(ohlcv_data[:, 1:2]), 'r', label='close')
            # plt.plot(scaled_OBV, 'b', label='OBV')
            plt.legend(loc='upper right')
            for i in range(len(spanlist_high)):
                plt.axvspan(spanlist_high[i][0], spanlist_high[i][1], facecolor='c', alpha=0.5)

            Date = file.split()[0]
            Coin = file.split()[1].split('.')[0]
            plt.savefig('./Figure_data/%s_%s/%s %s.png' % (input_data_length, model_num, Date, Coin), dpi=500)
            plt.close()
            # plt.show()
            # ----------- Chart 그리기 -----------#

        return dataX, dataY, sliced_ohlcv


def made_x_origin(file, input_data_length, model_num, check_span, get_fig, crop_size=0, sudden_death=0):

    if type(file) is str:
        ohlcv_excel = pd.read_excel(dir + file, index_col=0)

        # ohlcv_excel['MA60'] = ohlcv_excel['close'].rolling(60).mean()
        # ohlcv_excel['CMO'] = cmo(ohlcv_excel)
        # ohlcv_excel['OBV'] = obv(ohlcv_excel)
        # ohlcv_excel['RSI'] = rsi(ohlcv_excel)

        # print(ohlcv_excel)
        # quit()

        #   이후 check_span 데이터와 현재 포인트를 비교해서 현재 포인트가 저가인지 고가인지 예측한다.
        #   진입, 저점, 고점, 거래 안함의 y_label 인 trade_state  >> [1, 2, 0]
        #   저점과 고점은 최대 3개의 중복 값을 허용한다.
        trade_state = [np.NaN] * len(ohlcv_excel)
        for i in range(len(ohlcv_excel) - check_span):
            #   저점
            if ohlcv_excel['close'][i + 1:i + 1 + check_span].min() >= ohlcv_excel['close'][i]:
                if ohlcv_excel['close'][i:i + 1 + check_span].value_counts().sort_index().iloc[0] <= 3:
                    trade_state[i] = 1
                else:
                    trade_state[i] = 0
            #   고점
            elif ohlcv_excel['close'][i + 1:i + 1 + check_span].max() <= ohlcv_excel['close'][i]:
                if ohlcv_excel['close'][i:i + 1 + check_span].value_counts().sort_index().iloc[-1] <= 3:
                    trade_state[i] = 2
                else:
                    trade_state[i] = 0
            #   거래 안함
            else:
                trade_state[i] = 0

        ohlcv_excel['trade_state'] = trade_state

        # ----------- dataX, dataY 추출하기 -----------#
        # print(ohlcv_excel.info())
        # ohlcv_excel.to_excel('test.xlsx')
        # quit()

        # NaN 제외하고 데이터 자르기 (데이터가 PIXEL 로 들어간다고 생각하면 된다)
        #   OBV : -CHECK_SPAN
        ohlcv_data = ohlcv_excel.values[: -check_span].astype(np.float)
        # ohlcv_data = ohlcv_excel.values[ohlcv_excel['MA60'].isnull().sum():-check_span - 150].astype(np.float)
        # ohlcv_data = ohlcv_excel.values[1: -check_span].astype(np.float)
        # ohlcv_data = ohlcv_excel.values[sum(ohlcv_excel.CMO.isna()): -check_span].astype(np.float)
        # ohlcv_data = ohlcv_excel.values[sum(ohlcv_excel.RSI.isna()): -check_span].astype(np.float)

        # print(pd.DataFrame(ohlcv_data).info())
        # print(pd.DataFrame(ohlcv_data).to_excel('test.xlsx'))
        # print(list(map(float, ohlcv_data[0])))
        # quit()
    else:
        ohlcv_data = file

    #           ohlcv_data slicing      #
    # ohlcv_data = ohlcv_data[-crop_size:]

    # 결측 데이터 제외
    if len(ohlcv_data) != 0:

        #          데이터 전처리         #
        #   Fixed X_data    #
        price = ohlcv_data[:, :4]
        # volume = ohlcv_data[:, [4]]
        # MA60 = ohlcv_data[:, [-3]]
        # CMO = ohlcv_data[:, [-2]]
        # OBV = ohlcv_data[:, [-2]]
        # RSI = ohlcv_data[:, [-2]]

        #   Flexible Y_data    #
        trade_state = ohlcv_data[:, [-1]]

        scaled_price = min_max_scaler(price)
        # scaled_volume = min_max_scaler(volume)
        # scaled_MA60 = min_max_scaler(MA60)
        # scaled_CMO = min_max_scaler(CMO)
        # scaled_OBV = min_max_scaler(OBV)
        # scaled_RSI = min_max_scaler(RSI)

        # x = np.concatenate((scaled_price, scaled_MA60), axis=1)  # axis=1, 세로로 합친다
        x = scaled_price
        y = trade_state
        # print(x.shape, y_low.shape)  # (258, 6) (258, 1)
        # quit()

        dataX = []  # input_data length 만큼 담을 dataX 그릇
        dataY = []  # Target 을 담을 그릇
        for i in range(input_data_length, len(x)):
            group_x = x[i - input_data_length:i]
            group_y = y[i]

            dataX.append(group_x)  # dataX 리스트에 추가
            dataY.append(group_y)

        if len(dataX) < 100:
            return None, None, None

        X_test = np.array(dataX)
        row = X_test.shape[1]
        col = X_test.shape[2]

        X_test = X_test.astype('float32').reshape(-1, row, col, 1)
        # print(X_test.shape)

        #       Exstracting fiexd X_data       #
        sliced_ohlcv = ohlcv_data[input_data_length:, :x.shape[1]]

        #                      Get Figure                     #
        if get_fig == 1:
            spanlist_low = []
            spanlist_high = []

            for m in range(len(trade_state)):
                if (trade_state[m] > 0.5) and (trade_state[m] < 1.5):
                    if m + 1 < len(trade_state):
                        spanlist_low.append((m, m + 1))
                    else:
                        spanlist_low.append((m - 1, m))

            for m in range(len(trade_state)):
                if (trade_state[m] > 1.5) and (trade_state[m] < 2.5):
                    if m + 1 < len(trade_state):
                        spanlist_high.append((m, m + 1))
                    else:
                        spanlist_high.append((m - 1, m))

            # ----------- 인덱스 초기화 됨 -----------#

            # ----------- 공통된 Chart 그리기 -----------#

            plt.subplot(211)
            plt.plot(min_max_scaler(ohlcv_data[:, 1:2]), 'r', label='close')
            # plt.plot(scaled_OBV, 'b', label='OBV')
            plt.legend(loc='upper right')
            for i in range(len(spanlist_low)):
                plt.axvspan(spanlist_low[i][0], spanlist_low[i][1], facecolor='m', alpha=0.5)

            plt.subplot(212)
            plt.plot(min_max_scaler(ohlcv_data[:, 1:2]), 'r', label='close')
            # plt.plot(scaled_OBV, 'b', label='OBV')
            plt.legend(loc='upper right')
            for i in range(len(spanlist_high)):
                plt.axvspan(spanlist_high[i][0], spanlist_high[i][1], facecolor='c', alpha=0.5)

            Date = file.split()[0]
            Coin = file.split()[1].split('.')[0]
            plt.savefig('./Figure_data/%s_%s/%s %s.png' % (input_data_length, model_num, Date, Coin), dpi=500)
            plt.close()
            # plt.show()
        
        return X_test, dataY, sliced_ohlcv


if __name__ == '__main__':

    # ----------- Params -----------#
    input_data_length = 50
    model_num = 50

    #       Make folder      #
    try:
        os.mkdir('./Figure_data/%s_%s/' % (input_data_length, model_num))

    except Exception as e:
        pass
    check_span = 30
    get_fig = 0

    Made_X = []
    Made_Y = []

#     ohlcv_list = ['2020-01-10 ETH ohlcv.xlsx']

    for file in ohlcv_list:
        try:
            if int(file.split()[0].split('-')[1]) != 1:
                continue


            result = made_x(file, input_data_length, model_num, check_span, get_fig, crop_size=input_data_length)
            # result = low_high('dvp'.upper(), input_data_length)
            # print(result)
            # quit()

            # ------------ 데이터가 있으면 dataX, dataY 병합하기 ------------#
            if result is not None:
                if result[0] is not None:

                    Made_X += result[0]
                    Made_Y += result[1]

                # 누적 데이터량 표시
                print(file, len(Made_X))
                
        except Exception as e:
            pass

    # SAVING X, Y
    X = np.array(Made_X)
    Y = np.array(Made_Y)
    np.save('./Made_X/Made_X %s_%s' % (input_data_length, model_num), X)
    np.save('./Made_X/Made_Y %s_%s' % (input_data_length, model_num), Y)
    # np.save('./Made_X_high/Made_Y %s_%s' % (input_data_length, model_num), Y_high)
# Out:
# 2020-01-16 XLM ohlcv.xlsx 1010
# 2020-01-23 TRX ohlcv.xlsx 1740
# 2020-01-31 AMO ohlcv.xlsx 2397
# 2020-01-16 SNT ohlcv.xlsx 2619
# len(dataX) < 100
# 2020-01-19 LBA ohlcv.xlsx 2619
# 2020-01-11 FX ohlcv.xlsx 2942
# 2020-01-22 LUNA ohlcv.xlsx 4271
# 2020-01-16 LINK ohlcv.xlsx 5272
# len(dataX) < 100
# 2020-01-28 PLY ohlcv.xlsx 5272
# 2020-01-13 FCT ohlcv.xlsx 5484
# 2020-01-20 IPX ohlcv.xlsx 6843
# len(dataX) < 100
# 2020-01-27 ITC ohlcv.xlsx 6843
# len(dataX) < 100
# 2020-01-14 FZZ ohlcv.xlsx 6843
# len(dataX) < 100
# 2020-01-24 BZNT ohlcv.xlsx 6843
# 2020-01-20 SNT ohlcv.xlsx 7100
# 2020-01-29 TMTG ohlcv.xlsx 8019
# len(dataX) < 100
# 2020-01-25 VET ohlcv.xlsx 8019
# 2020-01-21 EOS ohlcv.xlsx 9186
# 2020-01-24 FAB ohlcv.xlsx 9358
# 2020-01-22 TRV ohlcv.xlsx 9554
# len(dataX) < 100
# 2020-01-13 MBL ohlcv.xlsx 9554
# len(dataX) < 100
# 2020-01-26 DVP ohlcv.xlsx 9554
# 2020-01-22 MTL ohlcv.xlsx 9936
# len(dataX) < 100
# 2020-01-12 POWR ohlcv.xlsx 9936
# 2020-01-28 TRX ohlcv.xlsx 10617
# 2020-01-31 LAMB ohlcv.xlsx 10733
# len(dataX) < 100
# 2020-01-12 MCO ohlcv.xlsx 10733
# len(dataX) < 100
# 2020-01-20 CMT ohlcv.xlsx 10733
# 2020-01-22 BTG ohlcv.xlsx 11747
# 2020-01-13 DAC ohlcv.xlsx 13024
# len(dataX) < 100
# 2020-01-13 INS ohlcv.xlsx 13024
# 2020-01-25 REP ohlcv.xlsx 13343
# 2020-01-11 APIS ohlcv.xlsx 13578
# len(dataX) < 100
# 2020-01-26 LRC ohlcv.xlsx 13578
# 2020-01-26 XRP ohlcv.xlsx 14651
# 2020-01-28 LINK ohlcv.xlsx 15052
# len(dataX) < 100
# 2020-01-13 ELF ohlcv.xlsx 15052
# 2020-01-13 APIS ohlcv.xlsx 15218
# len(dataX) < 100
# 2020-01-31 CMT ohlcv.xlsx 15218
# 2020-01-16 ETH ohlcv.xlsx 16550
# 2020-01-22 STRAT ohlcv.xlsx 16700
# 2020-01-12 BCH ohlcv.xlsx 17843
# 2020-01-22 ZRX ohlcv.xlsx 17969
# len(dataX) < 100
# 2020-01-29 ZRX ohlcv.xlsx 17969
# len(dataX) < 100
# 2020-01-24 PAY ohlcv.xlsx 17969
# 2020-01-11 ETH ohlcv.xlsx 19042
# 2020-01-26 TMTG ohlcv.xlsx 20227
# len(dataX) < 100
# 2020-01-28 WTC ohlcv.xlsx 20227
# len(dataX) < 100
# 2020-01-19 RDN ohlcv.xlsx 20227
# len(dataX) < 100
# 2020-01-31 KNC ohlcv.xlsx 20227
# 2020-01-21 MXC ohlcv.xlsx 20445
# len(dataX) < 100
# 2020-01-19 ICX ohlcv.xlsx 20445
# len(dataX) < 100
# 2020-01-15 SNT ohlcv.xlsx 20445
# 2020-01-16 POWR ohlcv.xlsx 20619
# 2020-01-16 BCD ohlcv.xlsx 21804
# 2020-01-12 BCD ohlcv.xlsx 22515
# 2020-01-23 APIS ohlcv.xlsx 22659
# len(dataX) < 100
# 2020-01-15 OMG ohlcv.xlsx 22659
# len(dataX) < 100
# 2020-01-25 PAY ohlcv.xlsx 22659
# 2020-01-20 BSV ohlcv.xlsx 23974
# 2020-01-16 XMR ohlcv.xlsx 24336
# 2020-01-22 AE ohlcv.xlsx 24675
# len(dataX) < 100
# 2020-01-23 BAT ohlcv.xlsx 24675
# 2020-01-24 FX ohlcv.xlsx 24889
# len(dataX) < 100
# 2020-01-20 CHR ohlcv.xlsx 24889
# 2020-01-28 ETC ohlcv.xlsx 25997
# 2020-01-27 AMO ohlcv.xlsx 26676
# len(dataX) < 100
# 2020-01-29 PCM ohlcv.xlsx 26676
# 2020-01-14 ETH ohlcv.xlsx 27682
# len(dataX) < 100
# 2020-01-27 MIX ohlcv.xlsx 27682
# len(dataX) < 100
# 2020-01-11 ABT ohlcv.xlsx 27682
# len(dataX) < 100
# 2020-01-27 ORBS ohlcv.xlsx 27682
# 2020-01-23 ETH ohlcv.xlsx 28756
# 2020-01-16 CHR ohlcv.xlsx 28862
# 2020-01-25 CON ohlcv.xlsx 29666
# 2020-01-28 ENJ ohlcv.xlsx 29848
# 2020-01-28 IPX ohlcv.xlsx 31143
# 2020-01-30 FNB ohlcv.xlsx 31483
# 2020-01-16 APIS ohlcv.xlsx 31723
# len(dataX) < 100
# 2020-01-19 CRO ohlcv.xlsx 31723
# 2020-01-22 BZNT ohlcv.xlsx 31843
# 2020-01-29 BAT ohlcv.xlsx 32001
# len(dataX) < 100
# 2020-01-26 FAB ohlcv.xlsx 32001
# 2020-01-23 INS ohlcv.xlsx 32193
# 2020-01-14 ETZ ohlcv.xlsx 32452
# 2020-01-23 MCO ohlcv.xlsx 32614
# 2020-01-19 FNB ohlcv.xlsx 33162
# len(dataX) < 100
# 2020-01-29 WAXP ohlcv.xlsx 33162
# len(dataX) < 100
# 2020-01-19 PAY ohlcv.xlsx 33162
# len(dataX) < 100
# 2020-01-28 INS ohlcv.xlsx 33162
# len(dataX) < 100
# 2020-01-12 XVG ohlcv.xlsx 33162
# 2020-01-20 MIX ohlcv.xlsx 33616
# len(dataX) < 100
# 2020-01-30 OGO ohlcv.xlsx 33616
# 2020-01-24 STEEM ohlcv.xlsx 33874
# 2020-01-13 AMO ohlcv.xlsx 34582
# 2020-01-21 BTG ohlcv.xlsx 35402
# 2020-01-24 REP ohlcv.xlsx 35578
# len(dataX) < 100
# 2020-01-14 PPT ohlcv.xlsx 35578
# len(dataX) < 100
# 2020-01-29 MXC ohlcv.xlsx 35578
# 2020-01-26 ETH ohlcv.xlsx 36382
# 2020-01-11 XSR ohlcv.xlsx 37587
# 2020-01-16 OGO ohlcv.xlsx 37725
# len(dataX) < 100
# 2020-01-24 BHP ohlcv.xlsx 37725
# 2020-01-12 LTC ohlcv.xlsx 38440
# len(dataX) < 100
# 2020-01-12 INS ohlcv.xlsx 38440
# 2020-01-30 OMG ohlcv.xlsx 38609
# len(dataX) < 100
# 2020-01-14 SNT ohlcv.xlsx 38609
# len(dataX) < 100
# 2020-01-23 CHR ohlcv.xlsx 38609
# 2020-01-23 ETC ohlcv.xlsx 39383
# len(dataX) < 100
# 2020-01-14 ORBS ohlcv.xlsx 39383
# 2020-01-19 STRAT ohlcv.xlsx 39787
# 2020-01-24 VALOR ohlcv.xlsx 40056
# 2020-01-26 APIS ohlcv.xlsx 40214
# 2020-01-14 OGO ohlcv.xlsx 40757
# len(dataX) < 100
# 2020-01-29 CRO ohlcv.xlsx 40757
# 2020-01-16 PCM ohlcv.xlsx 40919
# len(dataX) < 100
# 2020-01-22 WOM ohlcv.xlsx 40919
# len(dataX) < 100
# 2020-01-14 CHR ohlcv.xlsx 40919
# 2020-01-26 MBL ohlcv.xlsx 42156
# len(dataX) < 100
# 2020-01-30 QKC ohlcv.xlsx 42156
# len(dataX) < 100
# 2020-01-23 WAXP ohlcv.xlsx 42156
# 2020-01-26 FCT ohlcv.xlsx 42503
# 2020-01-15 ICX ohlcv.xlsx 42719
# len(dataX) < 100
# 2020-01-25 MXC ohlcv.xlsx 42719
# 2020-01-21 RDN ohlcv.xlsx 42860
# 2020-01-31 IPX ohlcv.xlsx 44219
# 2020-01-23 BTT ohlcv.xlsx 44503
# len(dataX) < 100
# 2020-01-13 WAXP ohlcv.xlsx 44503
# len(dataX) < 100
# 2020-01-22 TRUE ohlcv.xlsx 44503
# 2020-01-13 XLM ohlcv.xlsx 44883
# 2020-01-20 ADA ohlcv.xlsx 45464
# 2020-01-16 ADA ohlcv.xlsx 46434
# len(dataX) < 100
# 2020-01-22 OGO ohlcv.xlsx 46434
# 2020-01-12 CON ohlcv.xlsx 47393
# 2020-01-13 LAMB ohlcv.xlsx 47563
# 2020-01-28 CON ohlcv.xlsx 48477
# 2020-01-24 WAVES ohlcv.xlsx 48807
# len(dataX) < 100
# 2020-01-23 LRC ohlcv.xlsx 48807
# len(dataX) < 100
# 2020-01-14 PCM ohlcv.xlsx 48807
# len(dataX) < 100
# 2020-01-27 WET ohlcv.xlsx 48807
# 2020-01-15 QTUM ohlcv.xlsx 49736
# 2020-01-27 AOA ohlcv.xlsx 49859
# len(dataX) < 100
# 2020-01-28 CHR ohlcv.xlsx 49859
# 2020-01-22 WPX ohlcv.xlsx 50926
# len(dataX) < 100
# 2020-01-31 BZNT ohlcv.xlsx 50926
# 2020-01-20 TRV ohlcv.xlsx 51263
# 2020-01-15 BAT ohlcv.xlsx 51435
# len(dataX) < 100
# 2020-01-23 PAY ohlcv.xlsx 51435
# 2020-01-31 SOC ohlcv.xlsx 52766
# len(dataX) < 100
# 2020-01-21 LOOM ohlcv.xlsx 52766
# 2020-01-23 MXC ohlcv.xlsx 52949
# 2020-01-31 BSV ohlcv.xlsx 54195
# 2020-01-27 MTL ohlcv.xlsx 54706
# 2020-01-11 ORBS ohlcv.xlsx 54811
# len(dataX) < 100
# 2020-01-24 LBA ohlcv.xlsx 54811
# len(dataX) < 100
# 2020-01-30 PLY ohlcv.xlsx 54811
# 2020-01-20 MXC ohlcv.xlsx 55471
# 2020-01-19 VALOR ohlcv.xlsx 55680
# 2020-01-24 PPT ohlcv.xlsx 55786
# 2020-01-21 FAB ohlcv.xlsx 56707
# len(dataX) < 100
# 2020-01-28 STRAT ohlcv.xlsx 56707
# 2020-01-24 MBL ohlcv.xlsx 57998
# len(dataX) < 100
# 2020-01-22 PCM ohlcv.xlsx 57998
# len(dataX) < 100
# 2020-01-13 TRV ohlcv.xlsx 57998
# 2020-01-15 BHP ohlcv.xlsx 58936
# len(dataX) < 100
# 2020-01-11 MXC ohlcv.xlsx 58936
# 2020-01-28 BCH ohlcv.xlsx 60207
# 2020-01-21 DASH ohlcv.xlsx 60555
# 2020-01-12 TRX ohlcv.xlsx 61360
# len(dataX) < 100
# 2020-01-26 ZEC ohlcv.xlsx 61360
# len(dataX) < 100
# 2020-01-26 MXC ohlcv.xlsx 61360
# 2020-01-24 LTC ohlcv.xlsx 61832
# 2020-01-16 MIX ohlcv.xlsx 62331
# len(dataX) < 100
# 2020-01-22 BAT ohlcv.xlsx 62331
# len(dataX) < 100
# 2020-01-28 GXC ohlcv.xlsx 62331
# 2020-01-30 MIX ohlcv.xlsx 62538
# len(dataX) < 100
# 2020-01-30 GNT ohlcv.xlsx 62538
# len(dataX) < 100
# 2020-01-14 RDN ohlcv.xlsx 62538
# len(dataX) < 100
# 2020-01-19 PCM ohlcv.xlsx 62538
# 2020-01-29 MCO ohlcv.xlsx 62692
# 2020-01-27 REP ohlcv.xlsx 63127
# len(dataX) < 100
# 2020-01-21 WICC ohlcv.xlsx 63127
# len(dataX) < 100
# 2020-01-23 CRO ohlcv.xlsx 63127
# 2020-01-19 LUNA ohlcv.xlsx 64406
# 2020-01-12 IPX ohlcv.xlsx 65200
# len(dataX) < 100
# 2020-01-14 REP ohlcv.xlsx 65200
# 2020-01-25 LINK ohlcv.xlsx 65680
# 2020-01-20 FX ohlcv.xlsx 66054
# len(dataX) < 100
# 2020-01-27 PLY ohlcv.xlsx 66054
# len(dataX) < 100
# 2020-01-15 CRO ohlcv.xlsx 66054
# 2020-01-22 DAC ohlcv.xlsx 67383
# len(dataX) < 100
# 2020-01-27 STRAT ohlcv.xlsx 67383
# 2020-01-25 MBL ohlcv.xlsx 68727
# 2020-01-31 WAVES ohlcv.xlsx 68961
# 2020-01-15 ETH ohlcv.xlsx 70023
# len(dataX) < 100
# 2020-01-26 OMG ohlcv.xlsx 70023
# len(dataX) < 100
# 2020-01-26 BAT ohlcv.xlsx 70023
# len(dataX) < 100
# 2020-01-12 KNC ohlcv.xlsx 70023
# len(dataX) < 100
# 2020-01-15 MCO ohlcv.xlsx 70023
# len(dataX) < 100
# 2020-01-28 LBA ohlcv.xlsx 70023
# 2020-01-11 XRP ohlcv.xlsx 71194
# len(dataX) < 100
# 2020-01-14 BZNT ohlcv.xlsx 71194
# len(dataX) < 100
# 2020-01-26 STEEM ohlcv.xlsx 71194
# 2020-01-19 TRV ohlcv.xlsx 72211
# len(dataX) < 100
# 2020-01-28 OGO ohlcv.xlsx 72211
# 2020-01-12 WAXP ohlcv.xlsx 72312
# len(dataX) < 100
# 2020-01-12 VALOR ohlcv.xlsx 72312
# len(dataX) < 100
# 2020-01-23 WET ohlcv.xlsx 72312
# 2020-01-28 AOA ohlcv.xlsx 72527
# len(dataX) < 100
# 2020-01-14 XEM ohlcv.xlsx 72527
# 2020-01-20 WAVES ohlcv.xlsx 72679
# len(dataX) < 100
# 2020-01-11 CHR ohlcv.xlsx 72679
# 2020-01-28 BCD ohlcv.xlsx 73506
# len(dataX) < 100
# 2020-01-30 PIVX ohlcv.xlsx 73506
# 2020-01-22 CON ohlcv.xlsx 74554
# len(dataX) < 100
# 2020-01-29 XMR ohlcv.xlsx 74554
# len(dataX) < 100
# 2020-01-28 POWR ohlcv.xlsx 74554
# 2020-01-25 MTL ohlcv.xlsx 74832
# 2020-01-24 ABT ohlcv.xlsx 74950
# 2020-01-24 ETC ohlcv.xlsx 75746
# 2020-01-28 REP ohlcv.xlsx 76178
# len(dataX) < 100
# 2020-01-14 WAVES ohlcv.xlsx 76178
# len(dataX) < 100
# 2020-01-22 ANKR ohlcv.xlsx 76178
# 2020-01-20 AE ohlcv.xlsx 76559
# len(dataX) < 100
# 2020-01-19 TRUE ohlcv.xlsx 76559
# len(dataX) < 100
# 2020-01-28 VET ohlcv.xlsx 76559
# len(dataX) < 100
# 2020-01-22 ABT ohlcv.xlsx 76559
# 2020-01-30 BTC ohlcv.xlsx 77904
# 2020-01-31 XMR ohlcv.xlsx 78004
# 2020-01-13 DAD ohlcv.xlsx 78457
# len(dataX) < 100
# 2020-01-25 OMG ohlcv.xlsx 78457
# 2020-01-20 MTL ohlcv.xlsx 79237
# len(dataX) < 100
# 2020-01-15 FZZ ohlcv.xlsx 79237
# len(dataX) < 100
# 2020-01-19 FX ohlcv.xlsx 79237
# len(dataX) < 100
# 2020-01-12 ELF ohlcv.xlsx 79237
# 2020-01-20 BTT ohlcv.xlsx 79563
# 2020-01-27 XSR ohlcv.xlsx 80350
# len(dataX) < 100
# 2020-01-20 OGO ohlcv.xlsx 80350
# len(dataX) < 100
# 2020-01-20 LRC ohlcv.xlsx 80350
# len(dataX) < 100
# 2020-01-31 GNT ohlcv.xlsx 80350
# len(dataX) < 100
# 2020-01-19 LOOM ohlcv.xlsx 80350
# len(dataX) < 100
# 2020-01-12 CTXC ohlcv.xlsx 80350
# 2020-01-19 LTC ohlcv.xlsx 81273
# 2020-01-15 ZEC ohlcv.xlsx 81826
# 2020-01-30 REP ohlcv.xlsx 82275
# len(dataX) < 100
# 2020-01-12 ITC ohlcv.xlsx 82275
# len(dataX) < 100
# 2020-01-29 WET ohlcv.xlsx 82275
# 2020-01-19 INS ohlcv.xlsx 82704
# 2020-01-24 TMTG ohlcv.xlsx 83796
# len(dataX) < 100
# 2020-01-14 MBL ohlcv.xlsx 83796
# len(dataX) < 100
# 2020-01-20 WICC ohlcv.xlsx 83796
# 2020-01-23 LUNA ohlcv.xlsx 85109
# len(dataX) < 100
# 2020-01-12 NPXS ohlcv.xlsx 85109
# 2020-01-20 OCN ohlcv.xlsx 85231
# len(dataX) < 100
# 2020-01-11 AE ohlcv.xlsx 85231
# 2020-01-12 DVP ohlcv.xlsx 85570
# 2020-01-29 AOA ohlcv.xlsx 85907
# len(dataX) < 100
# 2020-01-30 ELF ohlcv.xlsx 85907
# 2020-01-20 REP ohlcv.xlsx 86503
# 2020-01-31 MBL ohlcv.xlsx 87784
# 2020-01-23 BCH ohlcv.xlsx 88842
# len(dataX) < 100
# 2020-01-27 KNC ohlcv.xlsx 88842
# len(dataX) < 100
# 2020-01-28 NPXS ohlcv.xlsx 88842
# 2020-01-19 ZEC ohlcv.xlsx 89589
# len(dataX) < 100
# 2020-01-20 GNT ohlcv.xlsx 89589
# 2020-01-26 BTC ohlcv.xlsx 90872
# len(dataX) < 100
# 2020-01-29 WOM ohlcv.xlsx 90872
# len(dataX) < 100
# 2020-01-21 CMT ohlcv.xlsx 90872
# 2020-01-23 IPX ohlcv.xlsx 92231
# len(dataX) < 100
# 2020-01-21 CHR ohlcv.xlsx 92231
# len(dataX) < 100
# 2020-01-26 WOM ohlcv.xlsx 92231
# len(dataX) < 100
# 2020-01-23 XMR ohlcv.xlsx 92231
# 2020-01-25 VALOR ohlcv.xlsx 92375
# 2020-01-14 BCH ohlcv.xlsx 93159
# 2020-01-19 QTUM ohlcv.xlsx 94367
# len(dataX) < 100
# 2020-01-26 XVG ohlcv.xlsx 94367
# len(dataX) < 100
# 2020-01-12 BAT ohlcv.xlsx 94367
# 2020-01-19 BSV ohlcv.xlsx 95704
# 2020-01-30 NPXS ohlcv.xlsx 95886
# 2020-01-12 ENJ ohlcv.xlsx 96080
# 2020-01-24 BTG ohlcv.xlsx 96874
# len(dataX) < 100
# 2020-01-30 LRC ohlcv.xlsx 96874
# len(dataX) < 100
# 2020-01-20 ZRX ohlcv.xlsx 96874
# 2020-01-25 PIVX ohlcv.xlsx 97038
# 2020-01-23 BSV ohlcv.xlsx 98295
# len(dataX) < 100
# 2020-01-25 NPXS ohlcv.xlsx 98295
# 2020-01-24 CON ohlcv.xlsx 99252
# len(dataX) < 100
# 2020-01-30 STRAT ohlcv.xlsx 99252
# 2020-01-31 ADA ohlcv.xlsx 100148
# len(dataX) < 100
# 2020-01-27 ZRX ohlcv.xlsx 100148
# 2020-01-13 LUNA ohlcv.xlsx 101015
# 2020-01-12 ADA ohlcv.xlsx 101363
# 2020-01-12 AOA ohlcv.xlsx 101561
# 2020-01-21 WTC ohlcv.xlsx 101962
# len(dataX) < 100
# 2020-01-11 HDAC ohlcv.xlsx 101962
# 2020-01-28 XRP ohlcv.xlsx 103153
# 2020-01-23 FCT ohlcv.xlsx 103409
# 2020-01-19 BCH ohlcv.xlsx 104753
# len(dataX) < 100
# 2020-01-30 FX ohlcv.xlsx 104753
# 2020-01-27 WPX ohlcv.xlsx 105052
# 2020-01-25 ETC ohlcv.xlsx 105964
# 2020-01-22 STEEM ohlcv.xlsx 106765
# len(dataX) < 100
# 2020-01-13 BAT ohlcv.xlsx 106765
# len(dataX) < 100
# 2020-01-16 CRO ohlcv.xlsx 106765
# 2020-01-23 STRAT ohlcv.xlsx 106878
# 2020-01-20 CON ohlcv.xlsx 107871
# 2020-01-27 SOC ohlcv.xlsx 109190
# len(dataX) < 100
# 2020-01-26 POWR ohlcv.xlsx 109190
# len(dataX) < 100
# 2020-01-24 GXC ohlcv.xlsx 109190
# len(dataX) < 100
# 2020-01-30 RNT ohlcv.xlsx 109190
# len(dataX) < 100
# 2020-01-15 KNC ohlcv.xlsx 109190
# len(dataX) < 100
# 2020-01-20 PAY ohlcv.xlsx 109190
# 2020-01-30 BAT ohlcv.xlsx 109356
# 2020-01-25 ENJ ohlcv.xlsx 110266
# 2020-01-30 BCH ohlcv.xlsx 111441
# 2020-01-30 DAC ohlcv.xlsx 112676
# len(dataX) < 100
# 2020-01-20 POWR ohlcv.xlsx 112676
# 2020-01-12 LINK ohlcv.xlsx 113200
# len(dataX) < 100
# 2020-01-30 THETA ohlcv.xlsx 113200
# 2020-01-28 AMO ohlcv.xlsx 113866
# 2020-01-15 MXC ohlcv.xlsx 114009
# 2020-01-26 EOS ohlcv.xlsx 114962
# len(dataX) < 100
# 2020-01-29 PIVX ohlcv.xlsx 114962
# len(dataX) < 100
# 2020-01-27 LBA ohlcv.xlsx 114962
# 2020-01-13 OCN ohlcv.xlsx 115292
# 2020-01-31 FX ohlcv.xlsx 115769
# len(dataX) < 100
# 2020-01-21 HC ohlcv.xlsx 115769
# len(dataX) < 100
# 2020-01-13 PIVX ohlcv.xlsx 115769
# 2020-01-22 XLM ohlcv.xlsx 116447
# 2020-01-24 BTT ohlcv.xlsx 116637
# len(dataX) < 100
# 2020-01-23 HDAC ohlcv.xlsx 116637
# 2020-01-24 BTC ohlcv.xlsx 117969
# len(dataX) < 100
# 2020-01-12 PPT ohlcv.xlsx 117969
# 2020-01-29 LTC ohlcv.xlsx 118699
# len(dataX) < 100
# 2020-01-26 ABT ohlcv.xlsx 118699
# len(dataX) < 100
# 2020-01-22 PAY ohlcv.xlsx 118699
# 2020-01-23 ADA ohlcv.xlsx 119197
# 2020-01-23 STEEM ohlcv.xlsx 119614
# 2020-01-11 BCH ohlcv.xlsx 120547
# 2020-01-27 LUNA ohlcv.xlsx 121787
# len(dataX) < 100
# 2020-01-28 WAVES ohlcv.xlsx 121787
# 2020-01-23 GNT ohlcv.xlsx 122574
# 2020-01-19 FAB ohlcv.xlsx 122849
# 2020-01-29 AMO ohlcv.xlsx 123533
# 2020-01-12 XRP ohlcv.xlsx 124740
# len(dataX) < 100
# 2020-01-26 HC ohlcv.xlsx 124740
# 2020-01-28 MBL ohlcv.xlsx 126020
# len(dataX) < 100
# 2020-01-24 HDAC ohlcv.xlsx 126020
# 2020-01-16 XVG ohlcv.xlsx 126331
# len(dataX) < 100
# 2020-01-28 VALOR ohlcv.xlsx 126331
# len(dataX) < 100
# 2020-01-31 VALOR ohlcv.xlsx 126331
# 2020-01-11 LTC ohlcv.xlsx 126760
# 2020-01-22 BCD ohlcv.xlsx 127462
# 2020-01-23 BTC ohlcv.xlsx 128784
# len(dataX) < 100
# 2020-01-22 XVG ohlcv.xlsx 128784
# len(dataX) < 100
# 2020-01-19 NPXS ohlcv.xlsx 128784
# 2020-01-15 DAD ohlcv.xlsx 129394
# 2020-01-13 HC ohlcv.xlsx 129512
# 2020-01-19 VET ohlcv.xlsx 129707
# len(dataX) < 100
# 2020-01-19 FZZ ohlcv.xlsx 129707
# 2020-01-22 VALOR ohlcv.xlsx 129877
# len(dataX) < 100
# 2020-01-16 FZZ ohlcv.xlsx 129877
# len(dataX) < 100
# 2020-01-28 RNT ohlcv.xlsx 129877
# len(dataX) < 100
# 2020-01-23 NPXS ohlcv.xlsx 129877
# 2020-01-19 TRX ohlcv.xlsx 130828
# len(dataX) < 100
# 2020-01-11 WAXP ohlcv.xlsx 130828
# 2020-01-14 MXC ohlcv.xlsx 131086
# 2020-01-16 KNC ohlcv.xlsx 131257
# len(dataX) < 100
# 2020-01-27 ZIL ohlcv.xlsx 131257
# 2020-01-27 EOS ohlcv.xlsx 132146
# 2020-01-19 AE ohlcv.xlsx 132403
# 2020-01-14 WAXP ohlcv.xlsx 132723
# 2020-01-20 AOA ohlcv.xlsx 133081
# 2020-01-14 ADA ohlcv.xlsx 133347
# 2020-01-19 WOM ohlcv.xlsx 133619
# 2020-01-19 TMTG ohlcv.xlsx 134231
# len(dataX) < 100
# 2020-01-13 KNC ohlcv.xlsx 134231
# len(dataX) < 100
# 2020-01-11 STEEM ohlcv.xlsx 134231
# len(dataX) < 100
# 2020-01-13 WAVES ohlcv.xlsx 134231
# 2020-01-12 AMO ohlcv.xlsx 134945
# 2020-01-13 BTG ohlcv.xlsx 135514
# 2020-01-13 FNB ohlcv.xlsx 135995
# 2020-01-27 ZEC ohlcv.xlsx 136199
# 2020-01-14 DAC ohlcv.xlsx 137481
# 2020-01-14 LBA ohlcv.xlsx 137717
# 2020-01-15 STRAT ohlcv.xlsx 137846
# 2020-01-30 MTL ohlcv.xlsx 138182
# len(dataX) < 100
# 2020-01-22 VET ohlcv.xlsx 138182
# 2020-01-11 DASH ohlcv.xlsx 138330
# 2020-01-16 BSV ohlcv.xlsx 139687
# len(dataX) < 100
# 2020-01-13 FZZ ohlcv.xlsx 139687
# len(dataX) < 100
# 2020-01-23 OCN ohlcv.xlsx 139687
# len(dataX) < 100
# 2020-01-13 CTXC ohlcv.xlsx 139687
# len(dataX) < 100
# 2020-01-29 LOOM ohlcv.xlsx 139687
# 2020-01-31 NPXS ohlcv.xlsx 139926
# 2020-01-13 REP ohlcv.xlsx 140066
# 2020-01-31 INS ohlcv.xlsx 140184
# len(dataX) < 100
# 2020-01-30 WICC ohlcv.xlsx 140184
# 2020-01-23 AOA ohlcv.xlsx 140411
# 2020-01-11 AOA ohlcv.xlsx 140656
# 2020-01-15 REP ohlcv.xlsx 141064
# 2020-01-22 EOS ohlcv.xlsx 142117
# len(dataX) < 100
# 2020-01-27 HC ohlcv.xlsx 142117
# len(dataX) < 100
# 2020-01-12 BZNT ohlcv.xlsx 142117
# 2020-01-30 DASH ohlcv.xlsx 142325
# len(dataX) < 100
# 2020-01-28 FAB ohlcv.xlsx 142325
# 2020-01-19 PPT ohlcv.xlsx 142662
# 2020-01-26 LUNA ohlcv.xlsx 143935
# len(dataX) < 100
# 2020-01-23 ANKR ohlcv.xlsx 143935
# 2020-01-11 AMO ohlcv.xlsx 144636
# 2020-01-23 VET ohlcv.xlsx 144760
# 2020-01-29 MIX ohlcv.xlsx 144879
# 2020-01-25 XRP ohlcv.xlsx 146119
# len(dataX) < 100
# 2020-01-25 TRUE ohlcv.xlsx 146119
# 2020-01-28 MIX ohlcv.xlsx 146221
# 2020-01-19 AMO ohlcv.xlsx 146915
# 2020-01-29 ENJ ohlcv.xlsx 147137
# len(dataX) < 100
# 2020-01-22 LRC ohlcv.xlsx 147137
# 2020-01-21 DAC ohlcv.xlsx 148333
# len(dataX) < 100
# 2020-01-24 WICC ohlcv.xlsx 148333
# len(dataX) < 100
# 2020-01-25 ELF ohlcv.xlsx 148333
# len(dataX) < 100
# 2020-01-15 POWR ohlcv.xlsx 148333
# 2020-01-15 BTT ohlcv.xlsx 148759
# len(dataX) < 100
# 2020-01-28 CMT ohlcv.xlsx 148759
# len(dataX) < 100
# 2020-01-29 OGO ohlcv.xlsx 148759
# 2020-01-30 ZIL ohlcv.xlsx 148917
# 2020-01-16 ARN ohlcv.xlsx 149135
# 2020-01-19 DAD ohlcv.xlsx 149261
# len(dataX) < 100
# 2020-01-15 VALOR ohlcv.xlsx 149261
# len(dataX) < 100
# 2020-01-23 WICC ohlcv.xlsx 149261
# len(dataX) < 100
# 2020-01-25 ORBS ohlcv.xlsx 149261
# 2020-01-24 XSR ohlcv.xlsx 150260
# 2020-01-15 LAMB ohlcv.xlsx 150421
# 2020-01-29 LINK ohlcv.xlsx 150879
# len(dataX) < 100
# 2020-01-30 GXC ohlcv.xlsx 150879
# len(dataX) < 100
# 2020-01-15 MBL ohlcv.xlsx 150879
# 2020-01-16 REP ohlcv.xlsx 151645
# len(dataX) < 100
# 2020-01-14 THETA ohlcv.xlsx 151645
# 2020-01-22 TRX ohlcv.xlsx 152418
# 2020-01-20 ETC ohlcv.xlsx 153703
# 2020-01-16 HDAC ohlcv.xlsx 153931
# 2020-01-23 MIX ohlcv.xlsx 154059
# len(dataX) < 100
# 2020-01-26 ANKR ohlcv.xlsx 154059
# 2020-01-15 INS ohlcv.xlsx 154407
# len(dataX) < 100
# 2020-01-21 TRUE ohlcv.xlsx 154407
# 2020-01-31 DVP ohlcv.xlsx 155068
# 2020-01-15 XRP ohlcv.xlsx 156260
# len(dataX) < 100
# 2020-01-27 WTC ohlcv.xlsx 156260
# 2020-01-29 STEEM ohlcv.xlsx 156589
# 2020-01-30 ADA ohlcv.xlsx 157618
# len(dataX) < 100
# 2020-01-30 CRO ohlcv.xlsx 157618
# len(dataX) < 100
# 2020-01-25 LBA ohlcv.xlsx 157618
# 2020-01-23 VALOR ohlcv.xlsx 157879
# len(dataX) < 100
# 2020-01-11 REP ohlcv.xlsx 157879
# 2020-01-19 ZIL ohlcv.xlsx 158011
# 2020-01-26 CON ohlcv.xlsx 158918
# 2020-01-20 XRP ohlcv.xlsx 160247
# len(dataX) < 100
# 2020-01-30 CMT ohlcv.xlsx 160247
# 2020-01-25 BTG ohlcv.xlsx 161017
# 2020-01-24 XEM ohlcv.xlsx 161327
# 2020-01-21 WPX ohlcv.xlsx 162160
# len(dataX) < 100
# 2020-01-28 LOOM ohlcv.xlsx 162160
# len(dataX) < 100
# 2020-01-14 PAY ohlcv.xlsx 162160
# len(dataX) < 100
# 2020-01-23 ITC ohlcv.xlsx 162160
# len(dataX) < 100
# 2020-01-19 CMT ohlcv.xlsx 162160
# len(dataX) < 100
# 2020-01-29 WTC ohlcv.xlsx 162160
# len(dataX) < 100
# 2020-01-11 CRO ohlcv.xlsx 162160
# 2020-01-27 DASH ohlcv.xlsx 162417
# len(dataX) < 100
# 2020-01-14 LOOM ohlcv.xlsx 162417
# 2020-01-27 XRP ohlcv.xlsx 163459
# 2020-01-25 BCD ohlcv.xlsx 163941
# 2020-01-15 APIS ohlcv.xlsx 164116
# 2020-01-31 OGO ohlcv.xlsx 164998
# len(dataX) < 100
# 2020-01-27 GNT ohlcv.xlsx 164998
# 2020-01-31 FCT ohlcv.xlsx 165440
# len(dataX) < 100
# 2020-01-29 ABT ohlcv.xlsx 165440
# len(dataX) < 100
# 2020-01-14 WICC ohlcv.xlsx 165440
# 2020-01-16 LUNA ohlcv.xlsx 166683
# len(dataX) < 100
# 2020-01-22 CTXC ohlcv.xlsx 166683
# len(dataX) < 100
# 2020-01-14 OMG ohlcv.xlsx 166683
# 2020-01-31 ICX ohlcv.xlsx 167142
# 2020-01-19 HC ohlcv.xlsx 167388
# 2020-01-28 TRV ohlcv.xlsx 167594
# 2020-01-13 ETH ohlcv.xlsx 168640
# len(dataX) < 100
# 2020-01-27 NPXS ohlcv.xlsx 168640
# len(dataX) < 100
# 2020-01-14 ZIL ohlcv.xlsx 168640
# len(dataX) < 100
# 2020-01-14 WET ohlcv.xlsx 168640
# 2020-01-24 MCO ohlcv.xlsx 168757
# len(dataX) < 100
# 2020-01-11 STRAT ohlcv.xlsx 168757
# len(dataX) < 100
# 2020-01-23 LBA ohlcv.xlsx 168757
# 2020-01-19 CTXC ohlcv.xlsx 168959
# 2020-01-20 AMO ohlcv.xlsx 169707
# len(dataX) < 100
# 2020-01-13 STRAT ohlcv.xlsx 169707
# len(dataX) < 100
# 2020-01-24 CTXC ohlcv.xlsx 169707
# len(dataX) < 100
# 2020-01-28 MCO ohlcv.xlsx 169707
# len(dataX) < 100
# 2020-01-21 WAXP ohlcv.xlsx 169707
# len(dataX) < 100
# 2020-01-12 LBA ohlcv.xlsx 169707
# len(dataX) < 100
# 2020-01-12 WET ohlcv.xlsx 169707
# len(dataX) < 100
# 2020-01-19 GNT ohlcv.xlsx 169707
# 2020-01-16 PIVX ohlcv.xlsx 169850
# 2020-01-15 FX ohlcv.xlsx 169973
# len(dataX) < 100
# 2020-01-24 CHR ohlcv.xlsx 169973
# 2020-01-21 BSV ohlcv.xlsx 171265
# len(dataX) < 100
# 2020-01-12 FAB ohlcv.xlsx 171265
# 2020-01-15 WTC ohlcv.xlsx 171427
# len(dataX) < 100
# 2020-01-31 LOOM ohlcv.xlsx 171427
# 2020-01-29 BTG ohlcv.xlsx 172622
# 2020-01-20 HC ohlcv.xlsx 172777
# 2020-01-29 BSV ohlcv.xlsx 174099
# 2020-01-15 IOST ohlcv.xlsx 174274
# 2020-01-16 QTUM ohlcv.xlsx 175439
# len(dataX) < 100
# 2020-01-29 CMT ohlcv.xlsx 175439
# len(dataX) < 100
# 2020-01-25 FZZ ohlcv.xlsx 175439
# 2020-01-21 STEEM ohlcv.xlsx 175818
# 2020-01-15 ENJ ohlcv.xlsx 176129
# 2020-01-24 IPX ohlcv.xlsx 177488
# len(dataX) < 100
# 2020-01-14 HC ohlcv.xlsx 177488
# 2020-01-22 PIVX ohlcv.xlsx 178233
# len(dataX) < 100
# 2020-01-14 ICX ohlcv.xlsx 178233
# 2020-01-26 DAC ohlcv.xlsx 179561
# len(dataX) < 100
# 2020-01-11 ITC ohlcv.xlsx 179561
# 2020-01-14 TMTG ohlcv.xlsx 180667
# 2020-01-16 EOS ohlcv.xlsx 182001
# 2020-01-11 ENJ ohlcv.xlsx 182169
# len(dataX) < 100
# 2020-01-19 MCO ohlcv.xlsx 182169
# 2020-01-30 AOA ohlcv.xlsx 182497
# len(dataX) < 100
# 2020-01-11 XEM ohlcv.xlsx 182497
# len(dataX) < 100
# 2020-01-29 PAY ohlcv.xlsx 182497
# 2020-01-28 ADA ohlcv.xlsx 182909
# 2020-01-11 ADA ohlcv.xlsx 183201
# 2020-01-25 BTC ohlcv.xlsx 184549
# 2020-01-14 XRP ohlcv.xlsx 185705
# 2020-01-22 INS ohlcv.xlsx 185874
# 2020-01-19 IPX ohlcv.xlsx 187233
# 2020-01-19 FCT ohlcv.xlsx 187689
# 2020-01-22 IPX ohlcv.xlsx 189048
# len(dataX) < 100
# 2020-01-26 GNT ohlcv.xlsx 189048
# len(dataX) < 100
# 2020-01-21 ANKR ohlcv.xlsx 189048
# 2020-01-23 TMTG ohlcv.xlsx 190087
# len(dataX) < 100
# 2020-01-15 PAY ohlcv.xlsx 190087
# 2020-01-20 STEEM ohlcv.xlsx 191192
# len(dataX) < 100
# 2020-01-21 BHP ohlcv.xlsx 191192
# 2020-01-22 WICC ohlcv.xlsx 191346
# len(dataX) < 100
# 2020-01-14 TRUE ohlcv.xlsx 191346
# len(dataX) < 100
# 2020-01-27 XEM ohlcv.xlsx 191346
# 2020-01-23 LAMB ohlcv.xlsx 191472
# len(dataX) < 100
# 2020-01-15 ELF ohlcv.xlsx 191472
# 2020-01-20 XLM ohlcv.xlsx 192235
# 2020-01-21 XSR ohlcv.xlsx 192969
# 2020-01-27 BCD ohlcv.xlsx 193267
# len(dataX) < 100
# 2020-01-11 BAT ohlcv.xlsx 193267
# len(dataX) < 100
# 2020-01-13 ANKR ohlcv.xlsx 193267
# 2020-01-28 HC ohlcv.xlsx 193367
# len(dataX) < 100
# 2020-01-25 ETZ ohlcv.xlsx 193367
# len(dataX) < 100
# 2020-01-27 VET ohlcv.xlsx 193367
# 2020-01-15 DAC ohlcv.xlsx 194524
# len(dataX) < 100
# 2020-01-13 BZNT ohlcv.xlsx 194524
# len(dataX) < 100
# 2020-01-22 CHR ohlcv.xlsx 194524
# len(dataX) < 100
# 2020-01-13 PPT ohlcv.xlsx 194524
# len(dataX) < 100
# 2020-01-11 ZIL ohlcv.xlsx 194524
# 2020-01-30 STEEM ohlcv.xlsx 194844
# len(dataX) < 100
# 2020-01-23 WOM ohlcv.xlsx 194844
# len(dataX) < 100
# 2020-01-27 ETZ ohlcv.xlsx 194844
# 2020-01-11 XLM ohlcv.xlsx 195223
# 2020-01-23 SOC ohlcv.xlsx 196519
# len(dataX) < 100
# 2020-01-15 HC ohlcv.xlsx 196519
# 2020-01-13 HYC ohlcv.xlsx 196788
# len(dataX) < 100
# 2020-01-24 PCM ohlcv.xlsx 196788
# len(dataX) < 100
# 2020-01-24 KNC ohlcv.xlsx 196788
# 2020-01-19 SNT ohlcv.xlsx 196900
# 2020-01-28 LUNA ohlcv.xlsx 198141
# len(dataX) < 100
# 2020-01-25 PCM ohlcv.xlsx 198141
# len(dataX) < 100
# 2020-01-29 FX ohlcv.xlsx 198141
# 2020-01-20 RDN ohlcv.xlsx 198423
# len(dataX) < 100
# 2020-01-27 CHR ohlcv.xlsx 198423
# len(dataX) < 100
# 2020-01-13 CRO ohlcv.xlsx 198423
# len(dataX) < 100
# 2020-01-19 LRC ohlcv.xlsx 198423
# 2020-01-16 WAXP ohlcv.xlsx 198594
# 2020-01-25 WPX ohlcv.xlsx 199419
# len(dataX) < 100
# 2020-01-31 POWR ohlcv.xlsx 199419
# 2020-01-30 MBL ohlcv.xlsx 200704
# 2020-01-31 TRX ohlcv.xlsx 201537
# 2020-01-27 DAC ohlcv.xlsx 202848
# 2020-01-24 FCT ohlcv.xlsx 203492
# len(dataX) < 100
# 2020-01-13 ICX ohlcv.xlsx 203492
# len(dataX) < 100
# 2020-01-23 LOOM ohlcv.xlsx 203492
# 2020-01-24 WTC ohlcv.xlsx 203671
# 2020-01-21 DAD ohlcv.xlsx 203882
# len(dataX) < 100
# 2020-01-11 ZRX ohlcv.xlsx 203882
# len(dataX) < 100
# 2020-01-25 RNT ohlcv.xlsx 203882
# 2020-01-21 WAVES ohlcv.xlsx 204153
# len(dataX) < 100
# 2020-01-15 LOOM ohlcv.xlsx 204153
# 2020-01-12 XLM ohlcv.xlsx 204593
# len(dataX) < 100
# 2020-01-25 WOM ohlcv.xlsx 204593
# len(dataX) < 100
# 2020-01-28 XVG ohlcv.xlsx 204593
# 2020-01-13 FX ohlcv.xlsx 204749
# 2020-01-25 FCT ohlcv.xlsx 205460
# 2020-01-15 ADA ohlcv.xlsx 205900
# 2020-01-15 XMR ohlcv.xlsx 206086
# 2020-01-31 VET ohlcv.xlsx 206188
# len(dataX) < 100
# 2020-01-23 ZRX ohlcv.xlsx 206188
# len(dataX) < 100
# 2020-01-12 GXC ohlcv.xlsx 206188
# len(dataX) < 100
# 2020-01-24 WAXP ohlcv.xlsx 206188
# 2020-01-27 DAD ohlcv.xlsx 206354
# len(dataX) < 100
# 2020-01-13 GXC ohlcv.xlsx 206354
# 2020-01-11 SOC ohlcv.xlsx 207395
# len(dataX) < 100
# 2020-01-11 KNC ohlcv.xlsx 207395
# len(dataX) < 100
# 2020-01-30 HDAC ohlcv.xlsx 207395
# len(dataX) < 100
# 2020-01-30 XMR ohlcv.xlsx 207395
# len(dataX) < 100
# 2020-01-13 WICC ohlcv.xlsx 207395
# 2020-01-19 XVG ohlcv.xlsx 207534
# len(dataX) < 100
# 2020-01-27 POWR ohlcv.xlsx 207534
# 2020-01-12 STEEM ohlcv.xlsx 207734
# 2020-01-31 RDN ohlcv.xlsx 207916
# 2020-01-22 FAB ohlcv.xlsx 208394
# len(dataX) < 100
# 2020-01-15 RDN ohlcv.xlsx 208394
# 2020-01-20 OMG ohlcv.xlsx 208575
# 2020-01-30 VET ohlcv.xlsx 208726
# len(dataX) < 100
# 2020-01-24 RNT ohlcv.xlsx 208726
# 2020-01-30 XLM ohlcv.xlsx 209546
# len(dataX) < 100
# 2020-01-29 CHR ohlcv.xlsx 209546
# 2020-01-12 REP ohlcv.xlsx 209860
# len(dataX) < 100
# 2020-01-28 ANKR ohlcv.xlsx 209860
# 2020-01-15 OGO ohlcv.xlsx 210199
# 2020-01-14 LAMB ohlcv.xlsx 210317
# 2020-01-13 MIX ohlcv.xlsx 210485
# 2020-01-28 BSV ohlcv.xlsx 211743
# 2020-01-15 WAVES ohlcv.xlsx 211883
# len(dataX) < 100
# 2020-01-13 ORBS ohlcv.xlsx 211883
# 2020-01-25 DAC ohlcv.xlsx 213239
# 2020-01-12 HC ohlcv.xlsx 213351
# 2020-01-13 ADA ohlcv.xlsx 213623
# 2020-01-16 LAMB ohlcv.xlsx 214082
# len(dataX) < 100
# 2020-01-26 XMR ohlcv.xlsx 214082
# 2020-01-12 FCT ohlcv.xlsx 214507
# len(dataX) < 100
# 2020-01-31 MXC ohlcv.xlsx 214507
# len(dataX) < 100
# 2020-01-14 BAT ohlcv.xlsx 214507
# 2020-01-29 ICX ohlcv.xlsx 214771
# len(dataX) < 100
# 2020-01-23 KNC ohlcv.xlsx 214771
# 2020-01-15 ARN ohlcv.xlsx 215307
# len(dataX) < 100
# 2020-01-30 CTXC ohlcv.xlsx 215307
# len(dataX) < 100
# 2020-01-25 GXC ohlcv.xlsx 215307
# 2020-01-24 BCH ohlcv.xlsx 216232
# 2020-01-13 ETC ohlcv.xlsx 216757
# len(dataX) < 100
# 2020-01-12 OCN ohlcv.xlsx 216757
# len(dataX) < 100
# 2020-01-27 STEEM ohlcv.xlsx 216757
# len(dataX) < 100
# 2020-01-25 ICX ohlcv.xlsx 216757
# len(dataX) < 100
# 2020-01-13 HDAC ohlcv.xlsx 216757
# 2020-01-28 SOC ohlcv.xlsx 217939
# 2020-01-25 LUNA ohlcv.xlsx 219224
# len(dataX) < 100
# 2020-01-26 PCM ohlcv.xlsx 219224
# len(dataX) < 100
# 2020-01-13 CHR ohlcv.xlsx 219224
# 2020-01-15 LINK ohlcv.xlsx 219892
# len(dataX) < 100
# 2020-01-19 WAXP ohlcv.xlsx 219892
# len(dataX) < 100
# 2020-01-25 KNC ohlcv.xlsx 219892
# 2020-01-12 BTC ohlcv.xlsx 221244
# 2020-01-16 DAD ohlcv.xlsx 221792
# len(dataX) < 100
# 2020-01-12 ZIL ohlcv.xlsx 221792
# 2020-01-28 XLM ohlcv.xlsx 222286
# len(dataX) < 100
# 2020-01-21 BAT ohlcv.xlsx 222286
# 2020-01-24 INS ohlcv.xlsx 222439
# 2020-01-16 RNT ohlcv.xlsx 222578
# len(dataX) < 100
# 2020-01-26 BZNT ohlcv.xlsx 222578
# 2020-01-25 LTC ohlcv.xlsx 223164
# 2020-01-25 APIS ohlcv.xlsx 223345
# 2020-01-11 DAD ohlcv.xlsx 224222
# len(dataX) < 100
# 2020-01-28 ETZ ohlcv.xlsx 224222
# len(dataX) < 100
# 2020-01-26 BHP ohlcv.xlsx 224222
# 2020-01-22 OCN ohlcv.xlsx 224441
# 2020-01-31 TMTG ohlcv.xlsx 225464
# 2020-01-11 CON ohlcv.xlsx 226432
# len(dataX) < 100
# 2020-01-22 XMR ohlcv.xlsx 226432
# 2020-01-28 LTC ohlcv.xlsx 226995
# 2020-01-13 LBA ohlcv.xlsx 227101
# 2020-01-16 LTC ohlcv.xlsx 228203
# 2020-01-15 AMO ohlcv.xlsx 228917
# len(dataX) < 100
# 2020-01-26 FX ohlcv.xlsx 228917
# 2020-01-24 LUNA ohlcv.xlsx 230213
# len(dataX) < 100
# 2020-01-30 MXC ohlcv.xlsx 230213
# 2020-01-14 ABT ohlcv.xlsx 230927
# len(dataX) < 100
# 2020-01-27 IOST ohlcv.xlsx 230927
# 2020-01-19 IOST ohlcv.xlsx 231152
# 2020-01-20 WOM ohlcv.xlsx 231340
# len(dataX) < 100
# 2020-01-28 THETA ohlcv.xlsx 231340
# 2020-01-11 GNT ohlcv.xlsx 231477
# 2020-01-29 MTL ohlcv.xlsx 231890
# 2020-01-20 ELF ohlcv.xlsx 232108
# 2020-01-14 ZEC ohlcv.xlsx 232375
# 2020-01-30 BTG ohlcv.xlsx 233413
# 2020-01-21 LTC ohlcv.xlsx 234052
# len(dataX) < 100
# 2020-01-12 ANKR ohlcv.xlsx 234052
# len(dataX) < 100
# 2020-01-12 QKC ohlcv.xlsx 234052
# len(dataX) < 100
# 2020-01-31 ABT ohlcv.xlsx 234052
# len(dataX) < 100
# 2020-01-31 WICC ohlcv.xlsx 234052
# 2020-01-29 BTT ohlcv.xlsx 234334
# 2020-01-28 XSR ohlcv.xlsx 235233
# len(dataX) < 100
# 2020-01-14 HDAC ohlcv.xlsx 235233
# len(dataX) < 100
# 2020-01-11 INS ohlcv.xlsx 235233
# len(dataX) < 100
# 2020-01-25 QKC ohlcv.xlsx 235233
# 2020-01-14 MIX ohlcv.xlsx 235481
# len(dataX) < 100
# 2020-01-26 PPT ohlcv.xlsx 235481
# 2020-01-24 AOA ohlcv.xlsx 235878
# 2020-01-13 BCD ohlcv.xlsx 236338
# 2020-01-19 WTC ohlcv.xlsx 236631
# len(dataX) < 100
# 2020-01-25 FAB ohlcv.xlsx 236631
# 2020-01-15 ORBS ohlcv.xlsx 236860
# len(dataX) < 100
# 2020-01-24 THETA ohlcv.xlsx 236860
# 2020-01-15 BSV ohlcv.xlsx 238107
# 2020-01-20 ZIL ohlcv.xlsx 238228
# 2020-01-29 BCH ohlcv.xlsx 239486
# 2020-01-21 MBL ohlcv.xlsx 240802
# len(dataX) < 100
# 2020-01-25 GNT ohlcv.xlsx 240802
# len(dataX) < 100
# 2020-01-20 LBA ohlcv.xlsx 240802
# len(dataX) < 100
# 2020-01-12 CHR ohlcv.xlsx 240802
# len(dataX) < 100
# 2020-01-15 TRUE ohlcv.xlsx 240802
# len(dataX) < 100
# 2020-01-30 HYC ohlcv.xlsx 240802
# 2020-01-25 BSV ohlcv.xlsx 242107
# 2020-01-12 DAD ohlcv.xlsx 242764
# len(dataX) < 100
# 2020-01-24 HYC ohlcv.xlsx 242764
# 2020-01-31 ZEC ohlcv.xlsx 243259
# len(dataX) < 100
# 2020-01-24 HC ohlcv.xlsx 243259
# 2020-01-19 MBL ohlcv.xlsx 244609
# len(dataX) < 100
# 2020-01-30 SNT ohlcv.xlsx 244609
# len(dataX) < 100
# 2020-01-26 ZIL ohlcv.xlsx 244609
# len(dataX) < 100
# 2020-01-11 XVG ohlcv.xlsx 244609
# 2020-01-15 FNB ohlcv.xlsx 245383
# len(dataX) < 100
# 2020-01-12 CRO ohlcv.xlsx 245383
# len(dataX) < 100
# 2020-01-11 OMG ohlcv.xlsx 245383
# len(dataX) < 100
# 2020-01-26 STRAT ohlcv.xlsx 245383
# 2020-01-16 DVP ohlcv.xlsx 245503
# 2020-01-11 LAMB ohlcv.xlsx 245654
# 2020-01-22 SOC ohlcv.xlsx 246957
# len(dataX) < 100
# 2020-01-21 HDAC ohlcv.xlsx 246957
# 2020-01-12 FZZ ohlcv.xlsx 247066
# 2020-01-20 LINK ohlcv.xlsx 247730
# 2020-01-23 WTC ohlcv.xlsx 248043
# len(dataX) < 100
# 2020-01-31 LRC ohlcv.xlsx 248043
# len(dataX) < 100
# 2020-01-27 FX ohlcv.xlsx 248043
# len(dataX) < 100
# 2020-01-21 NPXS ohlcv.xlsx 248043
# 2020-01-12 XSR ohlcv.xlsx 249208
# len(dataX) < 100
# 2020-01-11 POWR ohlcv.xlsx 249208
# 2020-01-12 ZEC ohlcv.xlsx 249403
# 2020-01-30 POWR ohlcv.xlsx 249585
# 2020-01-13 EOS ohlcv.xlsx 250708
# 2020-01-13 PAY ohlcv.xlsx 250883
# 2020-01-13 TMTG ohlcv.xlsx 252176
# len(dataX) < 100
# 2020-01-21 OMG ohlcv.xlsx 252176
# 2020-01-31 HDAC ohlcv.xlsx 252285
# len(dataX) < 100
# 2020-01-24 FZZ ohlcv.xlsx 252285
# 2020-01-11 ETC ohlcv.xlsx 252732
# 2020-01-10 BTC ohlcv.xlsx 254084
# len(dataX) < 100
# 2020-01-21 POWR ohlcv.xlsx 254084
# 2020-01-16 LBA ohlcv.xlsx 254525
# 2020-01-14 XLM ohlcv.xlsx 254861
# 2020-01-14 LTC ohlcv.xlsx 255373
# 2020-01-15 MTL ohlcv.xlsx 255791
# 2020-01-20 WTC ohlcv.xlsx 256204
# 2020-01-12 VET ohlcv.xlsx 256321
# len(dataX) < 100
# 2020-01-22 HYC ohlcv.xlsx 256321
# len(dataX) < 100
# 2020-01-15 CMT ohlcv.xlsx 256321
# len(dataX) < 100
# 2020-01-30 RDN ohlcv.xlsx 256321
# len(dataX) < 100
# 2020-01-12 ORBS ohlcv.xlsx 256321
# len(dataX) < 100
# 2020-01-25 POWR ohlcv.xlsx 256321
# 2020-01-15 ETC ohlcv.xlsx 256878
# len(dataX) < 100
# 2020-01-13 LOOM ohlcv.xlsx 256878
# 2020-01-24 BCD ohlcv.xlsx 257346
# 2020-01-20 VALOR ohlcv.xlsx 258436
# len(dataX) < 100
# 2020-01-26 CHR ohlcv.xlsx 258436
# 2020-01-21 HYC ohlcv.xlsx 258620
# len(dataX) < 100
# 2020-01-26 LOOM ohlcv.xlsx 258620
# len(dataX) < 100
# 2020-01-24 WET ohlcv.xlsx 258620
# 2020-01-27 ETH ohlcv.xlsx 259393
# 2020-01-23 WAVES ohlcv.xlsx 259507
# 2020-01-13 XRP ohlcv.xlsx 260732
# len(dataX) < 100
# 2020-01-26 NPXS ohlcv.xlsx 260732
# 2020-01-21 BTT ohlcv.xlsx 261000
# len(dataX) < 100
# 2020-01-14 AE ohlcv.xlsx 261000
# 2020-01-22 QTUM ohlcv.xlsx 261685
# 2020-01-31 ORBS ohlcv.xlsx 261800
# 2020-01-16 WET ohlcv.xlsx 261946
# len(dataX) < 100
# 2020-01-24 CMT ohlcv.xlsx 261946
# len(dataX) < 100
# 2020-01-19 GXC ohlcv.xlsx 261946
# 2020-01-13 XSR ohlcv.xlsx 263004
# 2020-01-20 DAD ohlcv.xlsx 263149
# 2020-01-20 XSR ohlcv.xlsx 263944
# 2020-01-13 GNT ohlcv.xlsx 264078
# 2020-01-19 XEM ohlcv.xlsx 264233
# 2020-01-29 INS ohlcv.xlsx 264503
# 2020-01-16 FX ohlcv.xlsx 264774
# len(dataX) < 100
# 2020-01-31 ZIL ohlcv.xlsx 264774
# 2020-01-31 BTC ohlcv.xlsx 266126
# len(dataX) < 100
# 2020-01-28 XMR ohlcv.xlsx 266126
# 2020-01-25 TRV ohlcv.xlsx 266274
# len(dataX) < 100
# 2020-01-28 FX ohlcv.xlsx 266274
# 2020-01-16 WTC ohlcv.xlsx 267014
# 2020-01-14 DASH ohlcv.xlsx 267192
# 2020-01-20 SOC ohlcv.xlsx 267934
# len(dataX) < 100
# 2020-01-19 BAT ohlcv.xlsx 267934
# 2020-01-16 TMTG ohlcv.xlsx 268846
# 2020-01-14 EOS ohlcv.xlsx 269983
# 2020-01-16 PPT ohlcv.xlsx 270313
# len(dataX) < 100
# 2020-01-27 FZZ ohlcv.xlsx 270313
# len(dataX) < 100
# 2020-01-13 NPXS ohlcv.xlsx 270313
# 2020-01-24 APIS ohlcv.xlsx 270464
# 2020-01-26 AMO ohlcv.xlsx 271011
# len(dataX) < 100
# 2020-01-19 THETA ohlcv.xlsx 271011
# 2020-01-29 ADA ohlcv.xlsx 271911
# len(dataX) < 100
# 2020-01-12 PIVX ohlcv.xlsx 271911
# len(dataX) < 100
# 2020-01-13 DVP ohlcv.xlsx 271911
# len(dataX) < 100
# 2020-01-11 QKC ohlcv.xlsx 271911
# len(dataX) < 100
# 2020-01-26 XEM ohlcv.xlsx 271911
# len(dataX) < 100
# 2020-01-29 XEM ohlcv.xlsx 271911
# len(dataX) < 100
# 2020-01-29 LBA ohlcv.xlsx 271911
# len(dataX) < 100
# 2020-01-14 CTXC ohlcv.xlsx 271911
# len(dataX) < 100
# 2020-01-25 XMR ohlcv.xlsx 271911
# len(dataX) < 100
# 2020-01-21 LRC ohlcv.xlsx 271911
# 2020-01-30 ETH ohlcv.xlsx 273099
# len(dataX) < 100
# 2020-01-19 WET ohlcv.xlsx 273099
# 2020-01-19 REP ohlcv.xlsx 273856
# len(dataX) < 100
# 2020-01-23 CTXC ohlcv.xlsx 273856
# len(dataX) < 100
# 2020-01-20 BAT ohlcv.xlsx 273856
# 2020-01-19 BTG ohlcv.xlsx 274950
# 2020-01-20 ZEC ohlcv.xlsx 275424
# len(dataX) < 100
# 2020-01-19 BHP ohlcv.xlsx 275424
# len(dataX) < 100
# 2020-01-28 OMG ohlcv.xlsx 275424
# 2020-01-30 IOST ohlcv.xlsx 275555
# 2020-01-22 IOST ohlcv.xlsx 275675
# 2020-01-23 PIVX ohlcv.xlsx 275809
# 2020-01-30 BTT ohlcv.xlsx 276173
# len(dataX) < 100
# 2020-01-21 XVG ohlcv.xlsx 276173
# 2020-01-12 BHP ohlcv.xlsx 277151
# 2020-01-23 WPX ohlcv.xlsx 278079
# 2020-01-26 BCD ohlcv.xlsx 278333
# len(dataX) < 100
# 2020-01-29 KNC ohlcv.xlsx 278333
# 2020-01-15 SOC ohlcv.xlsx 279650
# len(dataX) < 100
# 2020-01-12 THETA ohlcv.xlsx 279650
# 2020-01-21 BTC ohlcv.xlsx 280999
# len(dataX) < 100
# 2020-01-23 BHP ohlcv.xlsx 280999
# len(dataX) < 100
# 2020-01-29 STRAT ohlcv.xlsx 280999
# len(dataX) < 100
# 2020-01-22 PLY ohlcv.xlsx 280999
# len(dataX) < 100
# 2020-01-12 ZRX ohlcv.xlsx 280999
# len(dataX) < 100
# 2020-01-29 NPXS ohlcv.xlsx 280999
# 2020-01-26 ENJ ohlcv.xlsx 281234
# len(dataX) < 100
# 2020-01-25 AE ohlcv.xlsx 281234
# len(dataX) < 100
# 2020-01-27 BAT ohlcv.xlsx 281234
# len(dataX) < 100
# 2020-01-13 ZRX ohlcv.xlsx 281234
# 2020-01-16 VET ohlcv.xlsx 281584
# 2020-01-16 ETZ ohlcv.xlsx 281823
# len(dataX) < 100
# 2020-01-21 RNT ohlcv.xlsx 281823
# len(dataX) < 100
# 2020-01-24 XVG ohlcv.xlsx 281823
# len(dataX) < 100
# 2020-01-25 LOOM ohlcv.xlsx 281823
# len(dataX) < 100
# 2020-01-11 VET ohlcv.xlsx 281823
# 2020-01-21 LUNA ohlcv.xlsx 283132
# len(dataX) < 100
# 2020-01-13 ITC ohlcv.xlsx 283132
# 2020-01-24 LINK ohlcv.xlsx 283635
# len(dataX) < 100
# 2020-01-19 ANKR ohlcv.xlsx 283635
# 2020-01-16 BHP ohlcv.xlsx 284690
# 2020-01-14 APIS ohlcv.xlsx 284856
# len(dataX) < 100
# 2020-01-25 LAMB ohlcv.xlsx 284856
# len(dataX) < 100
# 2020-01-30 DVP ohlcv.xlsx 284856
# 2020-01-19 ETC ohlcv.xlsx 286188
# 2020-01-14 XSR ohlcv.xlsx 287056
# len(dataX) < 100
# 2020-01-29 IOST ohlcv.xlsx 287056
# 2020-01-23 XVG ohlcv.xlsx 287181
# 2020-01-31 ETZ ohlcv.xlsx 287325
# 2020-01-30 TMTG ohlcv.xlsx 288518
# len(dataX) < 100
# 2020-01-24 POWR ohlcv.xlsx 288518
# len(dataX) < 100
# 2020-01-28 WOM ohlcv.xlsx 288518
# 2020-01-26 DAD ohlcv.xlsx 288620
# len(dataX) < 100
# 2020-01-26 WICC ohlcv.xlsx 288620
# len(dataX) < 100
# 2020-01-27 HDAC ohlcv.xlsx 288620
# 2020-01-31 CON ohlcv.xlsx 289203
# 2020-01-25 TRX ohlcv.xlsx 289818
# 2020-01-21 AMO ohlcv.xlsx 290504
# len(dataX) < 100
# 2020-01-26 TRV ohlcv.xlsx 290504
# 2020-01-27 BSV ohlcv.xlsx 291640
# len(dataX) < 100
# 2020-01-11 BZNT ohlcv.xlsx 291640
# 2020-01-27 TRX ohlcv.xlsx 292066
# len(dataX) < 100
# 2020-01-26 ETZ ohlcv.xlsx 292066
# 2020-01-21 PLY ohlcv.xlsx 292302
# len(dataX) < 100
# 2020-01-24 DVP ohlcv.xlsx 292302
# len(dataX) < 100
# 2020-01-15 DVP ohlcv.xlsx 292302
# len(dataX) < 100
# 2020-01-24 VET ohlcv.xlsx 292302
# 2020-01-16 ELF ohlcv.xlsx 292676
# 2020-01-14 RNT ohlcv.xlsx 292879
# 2020-01-28 ETH ohlcv.xlsx 293964
# len(dataX) < 100
# 2020-01-24 SNT ohlcv.xlsx 293964
# len(dataX) < 100
# 2020-01-29 GXC ohlcv.xlsx 293964
# len(dataX) < 100
# 2020-01-26 ICX ohlcv.xlsx 293964
# len(dataX) < 100
# 2020-01-24 IOST ohlcv.xlsx 293964
# len(dataX) < 100
# 2020-01-22 ETZ ohlcv.xlsx 293964
# 2020-01-19 ENJ ohlcv.xlsx 294189
# len(dataX) < 100
# 2020-01-27 LAMB ohlcv.xlsx 294189
# 2020-01-25 TMTG ohlcv.xlsx 294966
# len(dataX) < 100
# 2020-01-28 DVP ohlcv.xlsx 294966
# 2020-01-16 WOM ohlcv.xlsx 295978
# len(dataX) < 100
# 2020-01-29 PLY ohlcv.xlsx 295978
# len(dataX) < 100
# 2020-01-28 HDAC ohlcv.xlsx 295978
# 2020-01-16 FNB ohlcv.xlsx 297037
# len(dataX) < 100
# 2020-01-24 LAMB ohlcv.xlsx 297037
# 2020-01-15 BCH ohlcv.xlsx 298094
# 2020-01-20 MBL ohlcv.xlsx 299260
# 2020-01-22 FCT ohlcv.xlsx 299475
# len(dataX) < 100
# 2020-01-16 MBL ohlcv.xlsx 299475
# len(dataX) < 100
# 2020-01-25 ZRX ohlcv.xlsx 299475
# 2020-01-15 BTC ohlcv.xlsx 300802
# 2020-01-12 LAMB ohlcv.xlsx 300958
# len(dataX) < 100
# 2020-01-25 WICC ohlcv.xlsx 300958
# 2020-01-14 HYC ohlcv.xlsx 301287
# len(dataX) < 100
# 2020-01-29 FZZ ohlcv.xlsx 301287
# 2020-01-31 LTC ohlcv.xlsx 302047
# len(dataX) < 100
# 2020-01-28 CRO ohlcv.xlsx 302047
# len(dataX) < 100
# 2020-01-31 TRUE ohlcv.xlsx 302047
# 2020-01-21 IPX ohlcv.xlsx 303406
# 2020-01-20 RNT ohlcv.xlsx 303539
# 2020-01-20 LUNA ohlcv.xlsx 304791
# 2020-01-31 LUNA ohlcv.xlsx 305843
# len(dataX) < 100
# 2020-01-30 ANKR ohlcv.xlsx 305843
# len(dataX) < 100
# 2020-01-11 ARN ohlcv.xlsx 305843
# 2020-01-16 IOST ohlcv.xlsx 306208
# 2020-01-23 SNT ohlcv.xlsx 306315
# len(dataX) < 100
# 2020-01-19 ABT ohlcv.xlsx 306315
# 2020-01-23 BCD ohlcv.xlsx 306887
# 2020-01-16 ORBS ohlcv.xlsx 307058
# 2020-01-25 XLM ohlcv.xlsx 307453
# 2020-01-20 TMTG ohlcv.xlsx 308279
# 2020-01-30 AMO ohlcv.xlsx 308808
# len(dataX) < 100
# 2020-01-29 HDAC ohlcv.xlsx 308808
# 2020-01-23 ZEC ohlcv.xlsx 308931
# 2020-01-27 ENJ ohlcv.xlsx 309377
# 2020-01-28 BTC ohlcv.xlsx 310729
# 2020-01-23 CMT ohlcv.xlsx 310908
# len(dataX) < 100
# 2020-01-14 VALOR ohlcv.xlsx 310908
# len(dataX) < 100
# 2020-01-19 BZNT ohlcv.xlsx 310908
# 2020-01-16 GNT ohlcv.xlsx 311102
# len(dataX) < 100
# 2020-01-27 BHP ohlcv.xlsx 311102
# 2020-01-13 OGO ohlcv.xlsx 311473
# len(dataX) < 100
# 2020-01-27 DVP ohlcv.xlsx 311473
# 2020-01-31 ETH ohlcv.xlsx 312648
# len(dataX) < 100
# 2020-01-22 GNT ohlcv.xlsx 312648
# len(dataX) < 100
# 2020-01-14 FAB ohlcv.xlsx 312648
# 2020-01-30 WPX ohlcv.xlsx 313563
# 2020-01-21 BCD ohlcv.xlsx 314253
# len(dataX) < 100
# 2020-01-16 LRC ohlcv.xlsx 314253
# 2020-01-31 MIX ohlcv.xlsx 314474
# len(dataX) < 100
# 2020-01-21 GXC ohlcv.xlsx 314474
# 2020-01-29 DAC ohlcv.xlsx 315768
# 2020-01-13 QTUM ohlcv.xlsx 316389
# 2020-01-14 ENJ ohlcv.xlsx 316492
# 2020-01-16 CMT ohlcv.xlsx 316763
# len(dataX) < 100
# 2020-01-28 WICC ohlcv.xlsx 316763
# 2020-01-24 DAC ohlcv.xlsx 318039
# 2020-01-31 ENJ ohlcv.xlsx 318321
# 2020-01-15 BTG ohlcv.xlsx 319146
# len(dataX) < 100
# 2020-01-29 QKC ohlcv.xlsx 319146
# len(dataX) < 100
# 2020-01-26 RDN ohlcv.xlsx 319146
# 2020-01-22 WTC ohlcv.xlsx 319677
# 2020-01-21 TRV ohlcv.xlsx 319905
# len(dataX) < 100
# 2020-01-21 WET ohlcv.xlsx 319905
# 2020-01-30 QTUM ohlcv.xlsx 320709
# len(dataX) < 100
# 2020-01-28 WET ohlcv.xlsx 320709
# 2020-01-14 ARN ohlcv.xlsx 321291
# 2020-01-11 PAY ohlcv.xlsx 321670
# 2020-01-21 ENJ ohlcv.xlsx 321810
# 2020-01-25 WTC ohlcv.xlsx 321968
# len(dataX) < 100
# 2020-01-23 PPT ohlcv.xlsx 321968
# 2020-01-14 DVP ohlcv.xlsx 322121
# 2020-01-16 PLY ohlcv.xlsx 322604
# 2020-01-11 MIX ohlcv.xlsx 323205
# 2020-01-24 SOC ohlcv.xlsx 324195
# len(dataX) < 100
# 2020-01-22 OMG ohlcv.xlsx 324195
# 2020-01-13 AOA ohlcv.xlsx 324412
# 2020-01-26 SOC ohlcv.xlsx 325663
# len(dataX) < 100
# 2020-01-26 LBA ohlcv.xlsx 325663
# 2020-01-22 BSV ohlcv.xlsx 326981
# len(dataX) < 100
# 2020-01-20 LOOM ohlcv.xlsx 326981
# len(dataX) < 100
# 2020-01-26 CMT ohlcv.xlsx 326981
# 2020-01-23 XEM ohlcv.xlsx 327115
# 2020-01-23 DAC ohlcv.xlsx 328278
# 2020-01-30 BSV ohlcv.xlsx 329585
# len(dataX) < 100
# 2020-01-11 PPT ohlcv.xlsx 329585
# 2020-01-16 BTC ohlcv.xlsx 330944
# 2020-01-21 FX ohlcv.xlsx 331179
# len(dataX) < 100
# 2020-01-22 RNT ohlcv.xlsx 331179
# len(dataX) < 100
# 2020-01-14 STEEM ohlcv.xlsx 331179
# len(dataX) < 100
# 2020-01-26 HYC ohlcv.xlsx 331179
# len(dataX) < 100
# 2020-01-25 HYC ohlcv.xlsx 331179
# 2020-01-28 FNB ohlcv.xlsx 331512
# 2020-01-13 LRC ohlcv.xlsx 331680
# 2020-01-13 LINK ohlcv.xlsx 332172
# len(dataX) < 100
# 2020-01-28 ELF ohlcv.xlsx 332172
# 2020-01-12 WOM ohlcv.xlsx 332293
# 2020-01-29 XLM ohlcv.xlsx 332963
# 2020-01-30 TRX ohlcv.xlsx 333977
# len(dataX) < 100
# 2020-01-23 TRUE ohlcv.xlsx 333977
# len(dataX) < 100
# 2020-01-26 HDAC ohlcv.xlsx 333977
# 2020-01-28 WPX ohlcv.xlsx 334793
# 2020-01-13 DASH ohlcv.xlsx 335249
# len(dataX) < 100
# 2020-01-12 OMG ohlcv.xlsx 335249
# 2020-01-29 FNB ohlcv.xlsx 335438
# len(dataX) < 100
# 2020-01-25 ZIL ohlcv.xlsx 335438
# len(dataX) < 100
# 2020-01-30 ZRX ohlcv.xlsx 335438
# 2020-01-16 BTG ohlcv.xlsx 336667
# len(dataX) < 100
# 2020-01-31 STRAT ohlcv.xlsx 336667
# len(dataX) < 100
# 2020-01-28 HYC ohlcv.xlsx 336667
# 2020-01-16 CTXC ohlcv.xlsx 336946
# len(dataX) < 100
# 2020-01-26 WTC ohlcv.xlsx 336946
# len(dataX) < 100
# 2020-01-29 ETZ ohlcv.xlsx 336946
# 2020-01-27 ICX ohlcv.xlsx 337333
# len(dataX) < 100
# 2020-01-25 WAXP ohlcv.xlsx 337333
# 2020-01-16 BTT ohlcv.xlsx 338116
# len(dataX) < 100
# 2020-01-21 ELF ohlcv.xlsx 338116
# len(dataX) < 100
# 2020-01-28 PPT ohlcv.xlsx 338116
# 2020-01-16 SOC ohlcv.xlsx 339006
# 2020-01-20 HDAC ohlcv.xlsx 339123
# len(dataX) < 100
# 2020-01-29 WICC ohlcv.xlsx 339123
# len(dataX) < 100
# 2020-01-24 BAT ohlcv.xlsx 339123
# 2020-01-30 APIS ohlcv.xlsx 339283
# 2020-01-12 LUNA ohlcv.xlsx 340489
# len(dataX) < 100
# 2020-01-22 ORBS ohlcv.xlsx 340489
# 2020-01-11 OGO ohlcv.xlsx 341322
# len(dataX) < 100
# 2020-01-11 ANKR ohlcv.xlsx 341322
# len(dataX) < 100
# 2020-01-15 GXC ohlcv.xlsx 341322
# 2020-01-20 WPX ohlcv.xlsx 342040
# 2020-01-30 MCO ohlcv.xlsx 342215
# 2020-01-29 REP ohlcv.xlsx 342592
# 2020-01-15 ZIL ohlcv.xlsx 342692
# len(dataX) < 100
# 2020-01-21 QKC ohlcv.xlsx 342692
# len(dataX) < 100
# 2020-01-25 ZEC ohlcv.xlsx 342692
# 2020-01-20 FCT ohlcv.xlsx 342978
# len(dataX) < 100
# 2020-01-24 ZIL ohlcv.xlsx 342978
# 2020-01-25 ETH ohlcv.xlsx 344075
# len(dataX) < 100
# 2020-01-21 ICX ohlcv.xlsx 344075
# len(dataX) < 100
# 2020-01-27 WAXP ohlcv.xlsx 344075
# len(dataX) < 100
# 2020-01-20 THETA ohlcv.xlsx 344075
# 2020-01-15 MIX ohlcv.xlsx 344218
# 2020-01-14 FNB ohlcv.xlsx 344758
# len(dataX) < 100
# 2020-01-15 WET ohlcv.xlsx 344758
# 2020-01-27 ETC ohlcv.xlsx 345338
# 2020-01-21 APIS ohlcv.xlsx 345505
# 2020-01-27 LINK ohlcv.xlsx 345739
# len(dataX) < 100
# 2020-01-22 ELF ohlcv.xlsx 345739
# 2020-01-14 BTG ohlcv.xlsx 346042
# 2020-01-11 WOM ohlcv.xlsx 346351
# 2020-01-19 DASH ohlcv.xlsx 346925
# 2020-01-31 FNB ohlcv.xlsx 347901
# len(dataX) < 100
# 2020-01-15 BZNT ohlcv.xlsx 347901
# len(dataX) < 100
# 2020-01-27 BTT ohlcv.xlsx 347901
# 2020-01-20 HYC ohlcv.xlsx 348026
# len(dataX) < 100
# 2020-01-24 ZRX ohlcv.xlsx 348026
# len(dataX) < 100
# 2020-01-13 OMG ohlcv.xlsx 348026
# len(dataX) < 100
# 2020-01-27 PCM ohlcv.xlsx 348026
# 2020-01-16 CON ohlcv.xlsx 348947
# len(dataX) < 100
# 2020-01-11 SNT ohlcv.xlsx 348947
# 2020-01-24 FNB ohlcv.xlsx 349444
# len(dataX) < 100
# 2020-01-29 PPT ohlcv.xlsx 349444
# 2020-01-20 TRX ohlcv.xlsx 350373
# 2020-01-15 XLM ohlcv.xlsx 351046
# len(dataX) < 100
# 2020-01-19 CHR ohlcv.xlsx 351046
# len(dataX) < 100
# 2020-01-27 ELF ohlcv.xlsx 351046
# len(dataX) < 100
# 2020-01-25 BAT ohlcv.xlsx 351046
# 2020-01-25 FX ohlcv.xlsx 351165
# len(dataX) < 100
# 2020-01-13 QKC ohlcv.xlsx 351165
# len(dataX) < 100
# 2020-01-25 HDAC ohlcv.xlsx 351165
# 2020-01-20 VET ohlcv.xlsx 351384
# 2020-01-26 BSV ohlcv.xlsx 352546
# 2020-01-26 FNB ohlcv.xlsx 353136
# len(dataX) < 100
# 2020-01-20 CRO ohlcv.xlsx 353136
# len(dataX) < 100
# 2020-01-29 OMG ohlcv.xlsx 353136
# 2020-01-30 ICX ohlcv.xlsx 353365
# 2020-01-13 ENJ ohlcv.xlsx 353537
# len(dataX) < 100
# 2020-01-31 RNT ohlcv.xlsx 353537
# 2020-01-22 XSR ohlcv.xlsx 354296
# len(dataX) < 100
# 2020-01-19 OGO ohlcv.xlsx 354296
# 2020-01-16 STRAT ohlcv.xlsx 354596
# len(dataX) < 100
# 2020-01-24 OGO ohlcv.xlsx 354596
# len(dataX) < 100
# 2020-01-11 CTXC ohlcv.xlsx 354596
# 2020-01-13 MTL ohlcv.xlsx 354988
# 2020-01-28 STEEM ohlcv.xlsx 355148
# 2020-01-23 AMO ohlcv.xlsx 355806
# 2020-01-31 DAD ohlcv.xlsx 356123
# len(dataX) < 100
# 2020-01-24 ITC ohlcv.xlsx 356123
# len(dataX) < 100
# 2020-01-15 ZRX ohlcv.xlsx 356123
# len(dataX) < 100
# 2020-01-12 ABT ohlcv.xlsx 356123
# len(dataX) < 100
# 2020-01-31 ZRX ohlcv.xlsx 356123
# len(dataX) < 100
# 2020-01-30 TRV ohlcv.xlsx 356123
# len(dataX) < 100
# 2020-01-14 KNC ohlcv.xlsx 356123
# 2020-01-19 XRP ohlcv.xlsx 357442
# 2020-01-15 TRX ohlcv.xlsx 358294
# 2020-01-21 IOST ohlcv.xlsx 358403
# 2020-01-16 STEEM ohlcv.xlsx 358774
# 2020-01-28 EOS ohlcv.xlsx 359869
# 2020-01-20 ITC ohlcv.xlsx 359975
# len(dataX) < 100
# 2020-01-28 BZNT ohlcv.xlsx 359975
# 2020-01-14 OCN ohlcv.xlsx 360436
# len(dataX) < 100
# 2020-01-22 ENJ ohlcv.xlsx 360436
# len(dataX) < 100
# 2020-01-23 RNT ohlcv.xlsx 360436
# len(dataX) < 100
# 2020-01-29 ELF ohlcv.xlsx 360436
# 2020-01-16 WAVES ohlcv.xlsx 360774
# 2020-01-19 XLM ohlcv.xlsx 361804
# len(dataX) < 100
# 2020-01-21 XMR ohlcv.xlsx 361804
# len(dataX) < 100
# 2020-01-25 CHR ohlcv.xlsx 361804
# 2020-01-21 FCT ohlcv.xlsx 362098
# 2020-01-24 ETH ohlcv.xlsx 363121
# len(dataX) < 100
# 2020-01-26 PLY ohlcv.xlsx 363121
# len(dataX) < 100
# 2020-01-22 LOOM ohlcv.xlsx 363121
# 2020-01-23 XLM ohlcv.xlsx 363594
# len(dataX) < 100
# 2020-01-28 ABT ohlcv.xlsx 363594
# 2020-01-23 OMG ohlcv.xlsx 363772
# 2020-01-27 VALOR ohlcv.xlsx 363944
# 2020-01-16 FCT ohlcv.xlsx 364612
# len(dataX) < 100
# 2020-01-24 LOOM ohlcv.xlsx 364612
# 2020-01-12 ETH ohlcv.xlsx 365798
# len(dataX) < 100
# 2020-01-15 ANKR ohlcv.xlsx 365798
# 2020-01-16 MCO ohlcv.xlsx 365954
# len(dataX) < 100
# 2020-01-29 FAB ohlcv.xlsx 365954
# 2020-01-21 XRP ohlcv.xlsx 367225
# len(dataX) < 100
# 2020-01-21 LAMB ohlcv.xlsx 367225
# len(dataX) < 100
# 2020-01-30 CHR ohlcv.xlsx 367225
# len(dataX) < 100
# 2020-01-15 PIVX ohlcv.xlsx 367225
# len(dataX) < 100
# 2020-01-11 WET ohlcv.xlsx 367225
# 2020-01-16 XRP ohlcv.xlsx 368579
# len(dataX) < 100
# 2020-01-21 LBA ohlcv.xlsx 368579
# len(dataX) < 100
# 2020-01-23 PLY ohlcv.xlsx 368579
# len(dataX) < 100
# 2020-01-23 ELF ohlcv.xlsx 368579
# len(dataX) < 100
# 2020-01-29 BZNT ohlcv.xlsx 368579
# len(dataX) < 100
# 2020-01-25 HC ohlcv.xlsx 368579
# len(dataX) < 100
# 2020-01-11 HC ohlcv.xlsx 368579
# len(dataX) < 100
# 2020-01-26 WAVES ohlcv.xlsx 368579
# len(dataX) < 100
# 2020-01-29 SNT ohlcv.xlsx 368579
# len(dataX) < 100
# 2020-01-31 QKC ohlcv.xlsx 368579
# 2020-01-29 ETC ohlcv.xlsx 369742
# 2020-01-27 APIS ohlcv.xlsx 369894
# 2020-01-30 XRP ohlcv.xlsx 371170
# 2020-01-15 PLY ohlcv.xlsx 371445
# len(dataX) < 100
# 2020-01-15 STEEM ohlcv.xlsx 371445
# 2020-01-11 ELF ohlcv.xlsx 371556
# len(dataX) < 100
# 2020-01-20 ABT ohlcv.xlsx 371556
# 2020-01-13 STEEM ohlcv.xlsx 371750
# 2020-01-22 MXC ohlcv.xlsx 371955
# len(dataX) < 100
# 2020-01-20 CTXC ohlcv.xlsx 371955
# 2020-01-13 RNT ohlcv.xlsx 372070
# 2020-01-14 MTL ohlcv.xlsx 372403
# len(dataX) < 100
# 2020-01-28 DAD ohlcv.xlsx 372403
# 2020-01-27 BTC ohlcv.xlsx 373664
# len(dataX) < 100
# 2020-01-30 ORBS ohlcv.xlsx 373664
# len(dataX) < 100
# 2020-01-22 THETA ohlcv.xlsx 373664
# 2020-01-14 TRV ohlcv.xlsx 373766
# 2020-01-27 LTC ohlcv.xlsx 374098
# 2020-01-30 ZEC ohlcv.xlsx 374472
# 2020-01-12 EOS ohlcv.xlsx 375681
# 2020-01-12 BSV ohlcv.xlsx 376910
# len(dataX) < 100
# 2020-01-11 XMR ohlcv.xlsx 376910
# len(dataX) < 100
# 2020-01-15 ITC ohlcv.xlsx 376910
# len(dataX) < 100
# 2020-01-29 ITC ohlcv.xlsx 376910
# 2020-01-11 LINK ohlcv.xlsx 377401
# 2020-01-25 QTUM ohlcv.xlsx 377917
# len(dataX) < 100
# 2020-01-22 HDAC ohlcv.xlsx 377917
# len(dataX) < 100
# 2020-01-15 NPXS ohlcv.xlsx 377917
# len(dataX) < 100
# 2020-01-30 PCM ohlcv.xlsx 377917
# 2020-01-24 WPX ohlcv.xlsx 378912
# 2020-01-11 BHP ohlcv.xlsx 379575
# len(dataX) < 100
# 2020-01-22 DAD ohlcv.xlsx 379575
# 2020-01-19 BTC ohlcv.xlsx 380933
# 2020-01-24 ELF ohlcv.xlsx 381257
# 2020-01-19 ETH ohlcv.xlsx 382538
# 2020-01-15 AOA ohlcv.xlsx 382842
# 2020-01-14 BSV ohlcv.xlsx 383824
# len(dataX) < 100
# 2020-01-13 WET ohlcv.xlsx 383824
# len(dataX) < 100
# 2020-01-11 WICC ohlcv.xlsx 383824
# 2020-01-25 STEEM ohlcv.xlsx 384008
# 2020-01-31 WPX ohlcv.xlsx 384699
# len(dataX) < 100
# 2020-01-14 ITC ohlcv.xlsx 384699
# 2020-01-15 HYC ohlcv.xlsx 384860
# len(dataX) < 100
# 2020-01-23 FZZ ohlcv.xlsx 384860
# 2020-01-21 CON ohlcv.xlsx 386114
# len(dataX) < 100
# 2020-01-22 SNT ohlcv.xlsx 386114
# 2020-01-29 DASH ohlcv.xlsx 386453
# len(dataX) < 100
# 2020-01-21 XEM ohlcv.xlsx 386453
# ...
# 2020-01-28 ICX ohlcv.xlsx 497236
# len(dataX) < 100
# 2020-01-23 DVP ohlcv.xlsx 497236
# len(dataX) < 100
# 2020-01-24 QKC ohlcv.xlsx 497236
# 2020-01-20 DAC ohlcv.xlsx 498524
# len(dataX) < 100
# 2020-01-27 BZNT ohlcv.xlsx 498524
# 2020-01-26 BTG ohlcv.xlsx 499276
# 2020-01-28 BTG ohlcv.xlsx 500485
# 2020-01-21 STRAT ohlcv.xlsx 500595
# len(dataX) < 100
# 2020-01-31 WET ohlcv.xlsx 500595
# 2020-01-21 ETH ohlcv.xlsx 501779
# len(dataX) < 100
# 2020-01-22 WAXP ohlcv.xlsx 501779
# 2020-01-19 XSR ohlcv.xlsx 502701
# 2020-01-21 FNB ohlcv.xlsx 503085
# 2020-01-15 LTC ohlcv.xlsx 503895
# len(dataX) < 100
# 2020-01-30 FZZ ohlcv.xlsx 503895
# 2020-01-14 DAD ohlcv.xlsx 504186
# len(dataX) < 100
# 2020-01-30 WAXP ohlcv.xlsx 504186
# 2020-01-21 VALOR ohlcv.xlsx 504560
# len(dataX) < 100
# 2020-01-30 WET ohlcv.xlsx 504560
# 2020-01-11 TRX ohlcv.xlsx 505206
# 2020-01-30 LTC ohlcv.xlsx 505929
# 2020-01-12 RNT ohlcv.xlsx 506240
# 2020-01-25 BCH ohlcv.xlsx 507356
# 2020-01-24 PLY ohlcv.xlsx 507809
# len(dataX) < 100
# 2020-01-26 OGO ohlcv.xlsx 507809
# len(dataX) < 100
# 2020-01-11 GXC ohlcv.xlsx 507809
# 2020-01-20 PLY ohlcv.xlsx 508032
# len(dataX) < 100
# 2020-01-26 KNC ohlcv.xlsx 508032
# 2020-01-12 BTT ohlcv.xlsx 508173
# 2020-01-19 MIX ohlcv.xlsx 508461
# 2020-01-12 MIX ohlcv.xlsx 508737
# len(dataX) < 100
# 2020-01-29 LAMB ohlcv.xlsx 508737
# 2020-01-11 RDN ohlcv.xlsx 508941
# 2020-01-26 IPX ohlcv.xlsx 510267
# len(dataX) < 100
# 2020-01-31 BAT ohlcv.xlsx 510267
# 2020-01-14 WTC ohlcv.xlsx 510417
# 2020-01-26 LINK ohlcv.xlsx 510712
# 2020-01-23 AE ohlcv.xlsx 511064
# len(dataX) < 100
# 2020-01-23 RDN ohlcv.xlsx 511064
# 2020-01-16 INS ohlcv.xlsx 511332
# len(dataX) < 100
# 2020-01-21 SNT ohlcv.xlsx 511332
# 2020-01-31 OMG ohlcv.xlsx 511465
# len(dataX) < 100
# 2020-01-21 ORBS ohlcv.xlsx 511465
# len(dataX) < 100
# 2020-01-25 PPT ohlcv.xlsx 511465
# 2020-01-23 TRV ohlcv.xlsx 511860
# 2020-01-28 APIS ohlcv.xlsx 512002
# len(dataX) < 100
# 2020-01-13 FAB ohlcv.xlsx 512002
# 2020-01-31 XVG ohlcv.xlsx 512138
# 2020-01-16 VALOR ohlcv.xlsx 512352
# len(dataX) < 100
# 2020-01-30 TRUE ohlcv.xlsx 512352
# len(dataX) < 100
# 2020-01-28 LAMB ohlcv.xlsx 512352
# len(dataX) < 100
# 2020-01-14 GXC ohlcv.xlsx 512352
# 2020-01-20 DASH ohlcv.xlsx 512742
# len(dataX) < 100
# 2020-01-20 XEM ohlcv.xlsx 512742
# 2020-01-23 XRP ohlcv.xlsx 513991
# 2020-01-21 LINK ohlcv.xlsx 514562
# len(dataX) < 100
# 2020-01-29 RNT ohlcv.xlsx 514562
# len(dataX) < 100
# 2020-01-27 CTXC ohlcv.xlsx 514562
# len(dataX) < 100
# 2020-01-28 BHP ohlcv.xlsx 514562
# 2020-01-14 BTT ohlcv.xlsx 514795
# len(dataX) < 100
# 2020-01-11 OCN ohlcv.xlsx 514795
# 2020-01-14 LUNA ohlcv.xlsx 515887
# 2020-01-15 TMTG ohlcv.xlsx 516879
# len(dataX) < 100
# 2020-01-20 PIVX ohlcv.xlsx 516879
# 2020-01-29 XSR ohlcv.xlsx 517754
# len(dataX) < 100
# 2020-01-26 ELF ohlcv.xlsx 517754
# len(dataX) < 100
# 2020-01-31 SNT ohlcv.xlsx 517754
# len(dataX) < 100
# 2020-01-21 OCN ohlcv.xlsx 517754
# 2020-01-29 BTC ohlcv.xlsx 519112
# 2020-01-20 NPXS ohlcv.xlsx 519304
# len(dataX) < 100
# 2020-01-13 SNT ohlcv.xlsx 519304
# 2020-01-29 MBL ohlcv.xlsx 520649
# len(dataX) < 100
# 2020-01-24 RDN ohlcv.xlsx 520649
# 2020-01-24 DASH ohlcv.xlsx 520801
# len(dataX) < 100
# 2020-01-27 PIVX ohlcv.xlsx 520801
# 2020-01-25 XEM ohlcv.xlsx 520958
# len(dataX) < 100
# 2020-01-31 GXC ohlcv.xlsx 520958
# 2020-01-16 ZEC ohlcv.xlsx 521635
# 2020-01-20 LTC ohlcv.xlsx 522501
# 2020-01-24 MIX ohlcv.xlsx 522634
# len(dataX) < 100
# 2020-01-27 PPT ohlcv.xlsx 522634
# 2020-01-31 PAY ohlcv.xlsx 522808
# 2020-01-14 IOST ohlcv.xlsx 522932
# 2020-01-29 XRP ohlcv.xlsx 524236
# 2020-01-29 IPX ohlcv.xlsx 525550
# len(dataX) < 100
# 2020-01-27 CMT ohlcv.xlsx 525550
# 2020-01-14 IPX ohlcv.xlsx 526312
# 2020-01-25 WAVES ohlcv.xlsx 526543
# len(dataX) < 100
# 2020-01-23 POWR ohlcv.xlsx 526543
# 2020-01-22 ETC ohlcv.xlsx 527485
# 2020-01-13 TRX ohlcv.xlsx 528186
# 2020-01-13 LTC ohlcv.xlsx 528920
# 2020-01-31 TRV ohlcv.xlsx 529150
# len(dataX) < 100
# 2020-01-15 AE ohlcv.xlsx 529150
# len(dataX) < 100
# 2020-01-22 CRO ohlcv.xlsx 529150
# 2020-01-12 QTUM ohlcv.xlsx 529785
# 2020-01-19 AOA ohlcv.xlsx 530140
# 2020-01-13 SOC ohlcv.xlsx 530643
# len(dataX) < 100
# 2020-01-12 IOST ohlcv.xlsx 530643
# len(dataX) < 100
# 2020-01-15 THETA ohlcv.xlsx 530643
# 2020-01-15 FCT ohlcv.xlsx 531148
# len(dataX) < 100
# 2020-01-26 MCO ohlcv.xlsx 531148
# 2020-01-25 SOC ohlcv.xlsx 531356
# 2020-01-16 TRX ohlcv.xlsx 532600
# 2020-01-26 AOA ohlcv.xlsx 532907
# 2020-01-31 HYC ohlcv.xlsx 533019
# len(dataX) < 100
# 2020-01-13 XVG ohlcv.xlsx 533019
# len(dataX) < 100
# 2020-01-24 WOM ohlcv.xlsx 533019
# len(dataX) < 100
# 2020-01-20 WET ohlcv.xlsx 533019
# 2020-01-25 DASH ohlcv.xlsx 533168
# len(dataX) < 100
# 2020-01-22 FX ohlcv.xlsx 533168
# len(dataX) < 100
# 2020-01-31 PIVX ohlcv.xlsx 533168
# len(dataX) < 100
# 2020-01-14 INS ohlcv.xlsx 533168
# 2020-01-19 HDAC ohlcv.xlsx 533327
# 2020-01-20 ENJ ohlcv.xlsx 533534
# 2020-01-29 QTUM ohlcv.xlsx 534284
# len(dataX) < 100
# 2020-01-30 ITC ohlcv.xlsx 534284
# 2020-01-25 PLY ohlcv.xlsx 534511
# 2020-01-21 ADA ohlcv.xlsx 535060
# 2020-01-15 ETZ ohlcv.xlsx 535270
# len(dataX) < 100
# 2020-01-15 FAB ohlcv.xlsx 535270
# 2020-01-30 SOC ohlcv.xlsx 536209
# 2020-01-13 BHP ohlcv.xlsx 537146
# 2020-01-22 ZIL ohlcv.xlsx 537272
# len(dataX) < 100
# 2020-01-28 PAY ohlcv.xlsx 537272
# len(dataX) < 100
# 2020-01-25 XVG ohlcv.xlsx 537272
# 2020-01-11 BTC ohlcv.xlsx 538625
# len(dataX) < 100
# 2020-01-15 CHR ohlcv.xlsx 538625
# 2020-01-31 REP ohlcv.xlsx 538966
# 2020-01-29 FCT ohlcv.xlsx 539339
# 2020-01-28 FCT ohlcv.xlsx 539588
# 2020-01-29 WPX ohlcv.xlsx 540596
# 2020-01-31 XEM ohlcv.xlsx 540699
# len(dataX) < 100
# 2020-01-12 STRAT ohlcv.xlsx 540699
# 2020-01-14 BCD ohlcv.xlsx 541127
# len(dataX) < 100
# 2020-01-19 QKC ohlcv.xlsx 541127
# 2020-01-26 MTL ohlcv.xlsx 541356
# 2020-01-13 ABT ohlcv.xlsx 541702
# len(dataX) < 100
# 2020-01-23 BZNT ohlcv.xlsx 541702
# len(dataX) < 100
# 2020-01-21 CTXC ohlcv.xlsx 541702
# len(dataX) < 100
# 2020-01-15 CTXC ohlcv.xlsx 541702
# 2020-01-26 QTUM ohlcv.xlsx 542131
# 2020-01-14 ETC ohlcv.xlsx 542461
# 2020-01-30 ENJ ohlcv.xlsx 542587
# 2020-01-25 INS ohlcv.xlsx 542928
# 2020-01-26 ADA ohlcv.xlsx 543214
# 2020-01-19 OMG ohlcv.xlsx 543654
# len(dataX) < 100
# 2020-01-11 CMT ohlcv.xlsx 543654
# 2020-01-21 AOA ohlcv.xlsx 544005
# 2020-01-22 GXC ohlcv.xlsx 544118
# 2020-01-22 AOA ohlcv.xlsx 544430
# 2020-01-14 PLY ohlcv.xlsx 544744
# 2020-01-16 HYC ohlcv.xlsx 545073
# len(dataX) < 100
# 2020-01-15 WOM ohlcv.xlsx 545073
# 2020-01-19 KNC ohlcv.xlsx 545186
# 2020-01-22 FNB ohlcv.xlsx 545513
# len(dataX) < 100
# 2020-01-27 XVG ohlcv.xlsx 545513
# len(dataX) < 100
# 2020-01-31 WTC ohlcv.xlsx 545513
# len(dataX) < 100
# 2020-01-11 ZEC ohlcv.xlsx 545513
# len(dataX) < 100
# 2020-01-31 FZZ ohlcv.xlsx 545513
# len(dataX) < 100
# 2020-01-24 TRUE ohlcv.xlsx 545513
# 2020-01-19 BCD ohlcv.xlsx 546285
# len(dataX) < 100
# 2020-01-30 FAB ohlcv.xlsx 546285
# 2020-01-25 FNB ohlcv.xlsx 546785
# 2020-01-23 REP ohlcv.xlsx 547028
# len(dataX) < 100
# 2020-01-14 MCO ohlcv.xlsx 547028
# 2020-01-11 IPX ohlcv.xlsx 548212
# len(dataX) < 100
# 2020-01-20 BZNT ohlcv.xlsx 548212
# 2020-01-20 BCD ohlcv.xlsx 549063
# 2020-01-21 REP ohlcv.xlsx 549508
# 2020-01-13 BCH ohlcv.xlsx 550467
# len(dataX) < 100
# 2020-01-25 ANKR ohlcv.xlsx 550467
# 2020-01-13 ZEC ohlcv.xlsx 550609
# 2020-01-19 OCN ohlcv.xlsx 550809
# len(dataX) < 100
# 2020-01-27 PAY ohlcv.xlsx 550809
# len(dataX) < 100
# 2020-01-12 XEM ohlcv.xlsx 550809
# 2020-01-16 HC ohlcv.xlsx 551409
# 2020-01-14 SOC ohlcv.xlsx 552069
# 2020-01-21 PCM ohlcv.xlsx 552208
# len(dataX) < 100
# 2020-01-23 QKC ohlcv.xlsx 552208
# len(dataX) < 100
# 2020-01-27 AE ohlcv.xlsx 552208
# len(dataX) < 100
# 2020-01-20 FZZ ohlcv.xlsx 552208
# 2020-01-11 VALOR ohlcv.xlsx 552327
# 2020-01-16 NPXS ohlcv.xlsx 552583
# len(dataX) < 100
# 2020-01-14 NPXS ohlcv.xlsx 552583
# 2020-01-25 XSR ohlcv.xlsx 553345
# 2020-01-16 OMG ohlcv.xlsx 553744
# len(dataX) < 100
# 2020-01-19 WICC ohlcv.xlsx 553744
# len(dataX) < 100
# 2020-01-19 MXC ohlcv.xlsx 553744
# len(dataX) < 100
# 2020-01-19 PLY ohlcv.xlsx 553744
# len(dataX) < 100
# 2020-01-11 LRC ohlcv.xlsx 553744
# 2020-01-22 BCH ohlcv.xlsx 554873
# 2020-01-21 QTUM ohlcv.xlsx 555553
# 2020-01-15 XSR ohlcv.xlsx 556554
# 2020-01-22 LTC ohlcv.xlsx 557107
# len(dataX) < 100
# 2020-01-22 XEM ohlcv.xlsx 557107
# 2020-01-29 WAVES ohlcv.xlsx 557233
# 2020-01-31 BCH ohlcv.xlsx 558343
# len(dataX) < 100
# 2020-01-14 XMR ohlcv.xlsx 558343
# 2020-01-16 TRV ohlcv.xlsx 558572
# len(dataX) < 100
# 2020-01-13 POWR ohlcv.xlsx 558572
# 2020-01-16 XSR ohlcv.xlsx 559477
# 2020-01-11 TMTG ohlcv.xlsx 560721
# 2020-01-22 LINK ohlcv.xlsx 561216
# len(dataX) < 100
# 2020-01-16 QKC ohlcv.xlsx 561216
# 2020-01-30 BCD ohlcv.xlsx 561853
# len(dataX) < 100
# 2020-01-13 WOM ohlcv.xlsx 561853
# len(dataX) < 100
# 2020-01-30 ETZ ohlcv.xlsx 561853
# 2020-01-15 BCD ohlcv.xlsx 562742
# len(dataX) < 100
# 2020-01-24 AE ohlcv.xlsx 562742
# 2020-01-31 LINK ohlcv.xlsx 563341
# 2020-01-12 ETC ohlcv.xlsx 564032
# 2020-01-31 MTL ohlcv.xlsx 564416
# 2020-01-24 ADA ohlcv.xlsx 564839
# 2020-01-31 APIS ohlcv.xlsx 564984
# 2020-01-21 INS ohlcv.xlsx 565285
# 2020-01-30 AE ohlcv.xlsx 565448
# len(dataX) < 100
# 2020-01-29 TRV ohlcv.xlsx 565448
# len(dataX) < 100
# 2020-01-25 BHP ohlcv.xlsx 565448
# 2020-01-20 WAXP ohlcv.xlsx 565548
# 2020-01-30 DAD ohlcv.xlsx 565661
# 2020-01-25 IPX ohlcv.xlsx 567020
# len(dataX) < 100
# 2020-01-13 MCO ohlcv.xlsx 567020
# len(dataX) < 100
# 2020-01-25 CMT ohlcv.xlsx 567020
# len(dataX) < 100
# 2020-01-25 ITC ohlcv.xlsx 567020
# len(dataX) < 100
# 2020-01-25 ABT ohlcv.xlsx 567020
# 2020-01-24 GNT ohlcv.xlsx 567397
# 2020-01-25 DAD ohlcv.xlsx 567515
# 2020-01-23 ETZ ohlcv.xlsx 567825
# 2020-01-24 TRV ohlcv.xlsx 567990
# 2020-01-12 WAVES ohlcv.xlsx 568142
# len(dataX) < 100
# 2020-01-21 ZRX ohlcv.xlsx 568142
# 2020-01-26 INS ohlcv.xlsx 568243
# 2020-01-22 HC ohlcv.xlsx 568358
# 2020-01-16 IPX ohlcv.xlsx 569375
# 2020-01-22 MBL ohlcv.xlsx 570722
# len(dataX) < 100
# 2020-01-19 ZRX ohlcv.xlsx 570722
# 2020-01-20 ETZ ohlcv.xlsx 570835
# len(dataX) < 100
# 2020-01-28 QKC ohlcv.xlsx 570835
# 2020-01-15 WAXP ohlcv.xlsx 571072
# len(dataX) < 100
# 2020-01-27 XMR ohlcv.xlsx 571072
# len(dataX) < 100
# 2020-01-22 KNC ohlcv.xlsx 571072
# 2020-01-21 BCH ohlcv.xlsx 572183
# len(dataX) < 100
# 2020-01-22 POWR ohlcv.xlsx 572183
# 2020-01-16 AE ohlcv.xlsx 572712
# 2020-01-16 WICC ohlcv.xlsx 572813
# 2020-01-25 AMO ohlcv.xlsx 573436
# 2020-01-26 WPX ohlcv.xlsx 573779
# len(dataX) < 100
# 2020-01-11 MBL ohlcv.xlsx 573779
# len(dataX) < 100
# 2020-01-30 BHP ohlcv.xlsx 573779
# len(dataX) < 100
# 2020-01-11 LBA ohlcv.xlsx 573779
# 2020-01-11 QTUM ohlcv.xlsx 574225
# len(dataX) < 100
# 2020-01-25 CRO ohlcv.xlsx 574225
# 2020-01-19 PIVX ohlcv.xlsx 574334
# len(dataX) < 100
# 2020-01-21 PPT ohlcv.xlsx 574334
# 2020-01-16 THETA ohlcv.xlsx 574472
# 2020-01-23 BTG ohlcv.xlsx 575393
# 2020-01-16 ETC ohlcv.xlsx 576585
# len(dataX) < 100
# 2020-01-20 DVP ohlcv.xlsx 576585
# 2020-01-12 PAY ohlcv.xlsx 576724
# 2020-01-30 XVG ohlcv.xlsx 576849
# len(dataX) < 100
# 2020-01-20 PCM ohlcv.xlsx 576849
# 2020-01-28 DAC ohlcv.xlsx 578177
# 2020-01-16 ZIL ohlcv.xlsx 578564
# len(dataX) < 100
# 2020-01-12 WICC ohlcv.xlsx 578564
# len(dataX) < 100
# 2020-01-28 CTXC ohlcv.xlsx 578564
# len(dataX) < 100
# 2020-01-27 SNT ohlcv.xlsx 578564
# len(dataX) < 100
# 2020-01-22 DVP ohlcv.xlsx 578564
# len(dataX) < 100
# 2020-01-12 WTC ohlcv.xlsx 578564
# 2020-01-30 LINK ohlcv.xlsx 579072
# 2020-01-21 TRX ohlcv.xlsx 579896
# 2020-01-14 QTUM ohlcv.xlsx 580617
# 2020-01-24 MTL ohlcv.xlsx 580997
# len(dataX) < 100
# 2020-01-14 STRAT ohlcv.xlsx 580997
# 2020-01-12 RDN ohlcv.xlsx 581208
# 2020-01-14 BHP ohlcv.xlsx 582149
# len(dataX) < 100
# 2020-01-25 IOST ohlcv.xlsx 582149
# 2020-01-31 AE ohlcv.xlsx 582270
# len(dataX) < 100
# 2020-01-29 HC ohlcv.xlsx 582270
# 2020-01-31 EOS ohlcv.xlsx 583379
# 2020-01-20 FAB ohlcv.xlsx 583943
# len(dataX) < 100
# 2020-01-22 CMT ohlcv.xlsx 583943
# 2020-01-13 CON ohlcv.xlsx 584920
# 2020-01-11 FNB ohlcv.xlsx 585490
# len(dataX) < 100
# 2020-01-26 FZZ ohlcv.xlsx 585490
# 2020-01-19 ELF ohlcv.xlsx 585694
# 2020-01-22 BTT ohlcv.xlsx 585885
# 2020-01-13 RDN ohlcv.xlsx 586063
# len(dataX) < 100
# 2020-01-28 ORBS ohlcv.xlsx 586063
# len(dataX) < 100
# 2020-01-28 WAXP ohlcv.xlsx 586063
# len(dataX) < 100
# 2020-01-23 THETA ohlcv.xlsx 586063
# len(dataX) < 100
# 2020-01-16 BZNT ohlcv.xlsx 586063
# len(dataX) < 100
# 2020-01-20 GXC ohlcv.xlsx 586063
# 2020-01-23 DASH ohlcv.xlsx 586248
# len(dataX) < 100
# 2020-01-30 PAY ohlcv.xlsx 586248
# len(dataX) < 100
# 2020-01-26 AE ohlcv.xlsx 586248
# len(dataX) < 100
# 2020-01-13 VALOR ohlcv.xlsx 586248
# len(dataX) < 100
# 2020-01-27 HYC ohlcv.xlsx 586248
# len(dataX) < 100
# 2020-01-14 CRO ohlcv.xlsx 586248
# len(dataX) < 100
# 2020-01-21 FZZ ohlcv.xlsx 586248
# 2020-01-14 FCT ohlcv.xlsx 586443
# len(dataX) < 100
# 2020-01-11 IOST ohlcv.xlsx 586443
# len(dataX) < 100
# 2020-01-15 PCM ohlcv.xlsx 586443
# 2020-01-31 DAC ohlcv.xlsx 587736
# len(dataX) < 100
# 2020-01-26 THETA ohlcv.xlsx 587736
# 2020-01-12 TRV ohlcv.xlsx 587925
# 2020-01-15 IPX ohlcv.xlsx 588494
# 2020-01-19 ADA ohlcv.xlsx 589270
# len(dataX) < 100
# 2020-01-26 MIX ohlcv.xlsx 589270
# 2020-01-22 AMO ohlcv.xlsx 589861
# 2020-01-11 HYC ohlcv.xlsx 590115
# 2020-01-28 BTT ohlcv.xlsx 590313
# len(dataX) < 100
# 2020-01-30 HC ohlcv.xlsx 590313
# len(dataX) < 100
# 2020-01-27 ANKR ohlcv.xlsx 590313
# len(dataX) < 100
# 2020-01-11 WTC ohlcv.xlsx 590313
# 2020-01-14 AMO ohlcv.xlsx 591043
# len(dataX) < 100
# 2020-01-24 PIVX ohlcv.xlsx 591043
# len(dataX) < 100
# 2020-01-12 TRUE ohlcv.xlsx 591043
# 2020-01-31 DASH ohlcv.xlsx 591433
# len(dataX) < 100
# 2020-01-27 RDN ohlcv.xlsx 591433
# len(dataX) < 100
# 2020-01-21 DVP ohlcv.xlsx 591433
# len(dataX) < 100
# 2020-01-26 DASH ohlcv.xlsx 591433
# len(dataX) < 100
# 2020-01-13 XMR ohlcv.xlsx 591433
# len(dataX) < 100
# 2020-01-13 IOST ohlcv.xlsx 591433
# 2020-01-26 ETC ohlcv.xlsx 592070
# len(dataX) < 100
# 2020-01-30 KNC ohlcv.xlsx 592070
# len(dataX) < 100
# 2020-01-22 LAMB ohlcv.xlsx 592070
# len(dataX) < 100
# 2020-01-15 HDAC ohlcv.xlsx 592070
# len(dataX) < 100
# 2020-01-13 CMT ohlcv.xlsx 592070
# len(dataX) < 100
# 2020-01-19 ITC ohlcv.xlsx 592070
# 2020-01-23 LTC ohlcv.xlsx 592535
# len(dataX) < 100
# 2020-01-13 MXC ohlcv.xlsx 592535
# 2020-01-29 BCD ohlcv.xlsx 593395
# len(dataX) < 100
# 2020-01-15 QKC ohlcv.xlsx 593395
# 2020-01-31 BCD ohlcv.xlsx 593933
# 2020-01-29 ETH ohlcv.xlsx 595161
# 2020-01-21 THETA ohlcv.xlsx 595285
# 2020-01-19 WPX ohlcv.xlsx 596229
# 2020-01-27 GXC ohlcv.xlsx 596332
# len(dataX) < 100
# 2020-01-25 CTXC ohlcv.xlsx 596332
# len(dataX) < 100
# 2020-01-29 GNT ohlcv.xlsx 596332
# 2020-01-23 MBL ohlcv.xlsx 597612
# 2020-01-12 MTL ohlcv.xlsx 598091
# len(dataX) < 100
# 2020-01-26 SNT ohlcv.xlsx 598091
# 2020-01-24 STRAT ohlcv.xlsx 598292
# 2020-01-23 EOS ohlcv.xlsx 599283
# 2020-01-27 MBL ohlcv.xlsx 600471
# 2020-01-15 VET ohlcv.xlsx 600633
# 2020-01-16 FAB ohlcv.xlsx 600869
# 2020-01-31 FAB ohlcv.xlsx 601193
# 2020-01-16 ABT ohlcv.xlsx 601379
# 2020-01-19 MTL ohlcv.xlsx 602068
# len(dataX) < 100
# 2020-01-29 XVG ohlcv.xlsx 602068
# 2020-01-21 MIX ohlcv.xlsx 602350
# len(dataX) < 100
# 2020-01-28 ZRX ohlcv.xlsx 602350
# len(dataX) < 100
# 2020-01-31 PLY ohlcv.xlsx 602350
# len(dataX) < 100
# 2020-01-22 PPT ohlcv.xlsx 602350
# len(dataX) < 100
# 2020-01-28 AE ohlcv.xlsx 602350
# len(dataX) < 100
# 2020-01-21 KNC ohlcv.xlsx 602350
# len(dataX) < 100
# 2020-01-21 PIVX ohlcv.xlsx 602350
# 2020-01-20 PPT ohlcv.xlsx 602462
# 2020-01-21 TMTG ohlcv.xlsx 603425
# 2020-01-22 APIS ohlcv.xlsx 603591
# len(dataX) < 100
# 2020-01-28 PCM ohlcv.xlsx 603591
# len(dataX) < 100
# 2020-01-11 ICX ohlcv.xlsx 603591
# len(dataX) < 100
# 2020-01-27 TRV ohlcv.xlsx 603591
# 2020-01-16 ITC ohlcv.xlsx 603879
# len(dataX) < 100
# 2020-01-23 PCM ohlcv.xlsx 603879
# 2020-01-13 ARN ohlcv.xlsx 604300
# 2020-01-15 XVG ohlcv.xlsx 604409
# len(dataX) < 100
# 2020-01-12 MXC ohlcv.xlsx 604409
# 2020-01-11 EOS ohlcv.xlsx 605435
# 2020-01-22 WAVES ohlcv.xlsx 605597
# 2020-01-31 XSR ohlcv.xlsx 606543
# len(dataX) < 100
# 2020-01-15 GNT ohlcv.xlsx 606543
# len(dataX) < 100
# 2020-01-23 HYC ohlcv.xlsx 606543
# 2020-01-19 LINK ohlcv.xlsx 607347
# len(dataX) < 100
# 2020-01-14 CMT ohlcv.xlsx 607347
# len(dataX) < 100
# 2020-01-23 ZIL ohlcv.xlsx 607347
# len(dataX) < 100
# 2020-01-21 ITC ohlcv.xlsx 607347
# 2020-01-11 DAC ohlcv.xlsx 607842
# len(dataX) < 100
# 2020-01-26 CTXC ohlcv.xlsx 607842
# 2020-01-24 QTUM ohlcv.xlsx 608408
# len(dataX) < 100
# 2020-01-11 DVP ohlcv.xlsx 608408
# 2020-01-20 EOS ohlcv.xlsx 609571
# 2020-01-19 SOC ohlcv.xlsx 610066
# 2020-01-27 TMTG ohlcv.xlsx 611353
# len(dataX) < 100
# 2020-01-28 GNT ohlcv.xlsx 611353
# len(dataX) < 100
# 2020-01-13 PCM ohlcv.xlsx 611353
# 2020-01-23 GXC ohlcv.xlsx 611519
# 2020-01-25 BTT ohlcv.xlsx 611716
# 2020-01-12 PLY ohlcv.xlsx 611977
# len(dataX) < 100
# 2020-01-23 HC ohlcv.xlsx 611977
