# %%
import numpy as np
import pandas as pd
import pybithumb
import os
import matplotlib.pyplot as plt
import warnings
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime
from Funcs_CNN4 import obv, macd, cmo, rsi
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 500)

Scaler = MinMaxScaler()

dir = 'ohlcv/'
ohlcv_list = os.listdir(dir)


def min_max_scaler(price):
    Scaler = MinMaxScaler()
    Scaler.fit(price)

    return Scaler.transform(price)


def low_high(Coin, input_data_length, ip_limit=None, trade_limit=None, crop_size=300, lowhigh_point=None):

    #   거래 제한은 고점과 저점을 분리한다.

    #   User-Agent Configuration
    #   IP - Change
    if ip_limit is None:
        ohlcv_excel = pybithumb.get_ohlcv(Coin, 'KRW', 'minute1')
    else:
        ohlcv_excel = pybithumb.get_ohlcv(Coin, 'KRW', 'minute1', 'proxyon')

    price_gap = ohlcv_excel.close.max() / ohlcv_excel.close.min()
    if (price_gap < 1.07) and (trade_limit is not None):
        return None, None, None, None

    ohlcv_excel['OBV'] = obv(ohlcv_excel)

    if lowhigh_point is not None:
        check_span = 20
        trade_state = [np.NaN] * len(ohlcv_excel)
        for i in range(check_span, len(ohlcv_excel) - check_span):
            #   저점
            if ohlcv_excel['close'][i - check_span:i].min() >= ohlcv_excel['close'][i]:
                if ohlcv_excel['close'][i + 1:i + 1 + check_span].min() >= ohlcv_excel['close'][i]:
                    # if ohlcv_excel['close'][i - check_span:i + 1 + check_span].value_counts().sort_index().iloc[0] <= 3:
                    if 1 not in trade_state[i - check_span:i]:
                        trade_state[i] = 1
                    else:
                        trade_state[i] = 0
                    # else:
                    #     trade_state[i] = 0
                else:
                    trade_state[i] = 0
            #   고점
            elif ohlcv_excel['close'][i - check_span:i].max() <= ohlcv_excel['close'][i]:
                if ohlcv_excel['close'][i + 1:i + 1 + check_span].max() <= ohlcv_excel['close'][i]:
                    # if ohlcv_excel['close'][i - check_span:i + 1 + check_span].value_counts().sort_index().iloc[-1] <= 3:
                    if 2 not in trade_state[i - check_span:i]:
                        trade_state[i] = 2
                    else:
                        trade_state[i] = 0
                # else:
                #     trade_state[i] = 0
                else:
                    trade_state[i] = 0

            #   거래 안함
            else:
                trade_state[i] = 0

        ohlcv_excel['trade_state'] = trade_state

        #   현재가가 이전 저점보다 0.1 이상 크지 않으면 거래하지 않는다.
        low_index = None
        for i in range(len(trade_state)):
            if trade_state[-i] == 1:
                low_index = i

    closeprice = ohlcv_excel['close'].iloc[-1]
    datetime_list = ohlcv_excel.index.values

    # ----------- dataX, dataY 추출하기 -----------#
    #   OBV :
    ohlcv_data = ohlcv_excel.values[1:].astype(np.float)

    scaled_close = min_max_scaler(ohlcv_data[:, [1]])
    prev_low = scaled_close[-low_index]
    pres_low = scaled_close[-1]
    if pres_low - prev_low < 0.1:
        return None, None, None, None

    # 결측 데이터 제외
    if len(ohlcv_data) != 0:

        #          데이터 전처리         #
        #   Fixed X_data    #
        # price = ohlcv_data[:, :4]
        # volume = ohlcv_data[:, [4]]
        # OBV = ohlcv_data[:, [-1]]
        #
        # scaled_price = min_max_scaler(price)
        # scaled_volume = min_max_scaler(volume)
        # scaled_OBV = min_max_scaler(OBV)
        # print(scaled_MA60.shape)

        # x = np.concatenate((scaled_price, scaled_volume, scaled_OBV), axis=1)  # axis=1, 세로로 합친다
        # print(x.shape)
        # print(ohlcv_data.shape)
        # quit()

        # if (x[-1][1] > 0.3) and (trade_limit is not None):
        #     return None, None

        # print(x.shape)  # (258, 6)
        # quit()

        dataX = []  # input_data length 만큼 담을 dataX 그릇
        for i in range(crop_size, len(ohlcv_data) + 1):  # 마지막 데이터까지 다 긇어모은다.
            group_x = ohlcv_data[i - crop_size: i]
            scaled_price = min_max_scaler(group_x[:, :4])
            # scaled_volume = min_max_scaler(group_x[:, [4]])
            # scaled_OBV = min_max_scaler(group_x[:, [-1]])
            # x = np.concatenate((scaled_price, scaled_volume, scaled_OBV), axis=1) + sudden_death  # axis=1, 세로로 합친다
            x = scaled_price  # axis=1, 세로로 합친다
            group_x = x[-input_data_length:]
            # print(group_x[-1:, 1:2])
            # print(group_x.shape)
            # print(group_x.max())
            dataX.append(group_x)  # dataX 리스트에 추가

        if len(dataX) < 100:
            return None, None, None, None

        # quit()
        X_test = np.array(dataX)
        row = X_test.shape[1]
        col = X_test.shape[2]

        X_test = X_test.astype('float32').reshape(-1, row, col, 1)
        # closeprice = np.roll(np.array(list(map(lambda x: x[-1][[1]][0], X_test))), -1)
        # plt.plot(closeprice)
        # plt.show()

        return X_test, closeprice, min_max_scaler(ohlcv_data[crop_size:, [1]]), datetime_list


def made_x(file, input_data_length, model_num, check_span, get_fig, crop_size=None, sudden_death=0):

    ohlcv_excel = pd.read_excel(dir + file, index_col=0)

    ohlcv_excel['MA20'] = ohlcv_excel['close'].rolling(20).mean()
    ohlcv_excel['CMO'] = cmo(ohlcv_excel)
    ohlcv_excel['OBV'] = obv(ohlcv_excel)
    ohlcv_excel['RSI'] = rsi(ohlcv_excel)
    macd(ohlcv_excel, short=15, long=60)

    # print(ohlcv_excel)
    # quit()

    #   이후 check_span 데이터와 현재 포인트를 비교해서 현재 포인트가 저가인지 고가인지 예측한다.
    #   진입, 저점, 고점, 거래 안함의 y_label 인 trade_state  >> [1, 2, 0]
    #   저점과 고점은 최대 3개의 중복 값을 허용한다.
    trade_state = [np.NaN] * len(ohlcv_excel)
    for i in range(len(ohlcv_excel) - check_span):
        #   저점
        if ohlcv_excel['close'][i + 1:i + 1 + check_span].min() >= ohlcv_excel['close'][i]:
            if ohlcv_excel['close'][i:i + 1 + check_span].value_counts().sort_index().iloc[0] <= 3:
                trade_state[i] = 1
            else:
                trade_state[i] = 0
        #   고점
        elif ohlcv_excel['close'][i + 1:i + 1 + check_span].max() <= ohlcv_excel['close'][i]:
            if ohlcv_excel['close'][i:i + 1 + check_span].value_counts().sort_index().iloc[-1] <= 3:
                trade_state[i] = 2
            else:
                trade_state[i] = 0
        #   거래 안함
        else:
            trade_state[i] = 0

    ohlcv_excel['trade_state'] = trade_state

    # ----------- dataX, dataY 추출하기 -----------#
    # print(ohlcv_excel.info())
    # quit()
    # ohlcv_excel.to_excel('test.xlsx')

    # NaN 제외하고 데이터 자르기 (데이터가 PIXEL 로 들어간다고 생각하면 된다)
    #   OBV : -CHECK_SPAN
    ohlcv_data = ohlcv_excel.values[sum(ohlcv_excel.MACD_Signal.isna()): -check_span].astype(np.float)
    # ohlcv_data = ohlcv_excel.values[1: -check_span].astype(np.float)
    # ohlcv_data = ohlcv_excel.values[sum(ohlcv_excel.CMO.isna()): -check_span].astype(np.float)
    # ohlcv_data = ohlcv_excel.values[sum(ohlcv_excel.RSI.isna()): -check_span].astype(np.float)

    # print(pd.DataFrame(ohlcv_data).info())
    # print(pd.DataFrame(ohlcv_data).to_excel('test.xlsx'))
    # print(list(map(float, ohlcv_data[0])))
    # quit()

    #       출력되는 Y 데이터 길이를 동일화 시킨다.     #
    # ohlcv_data = ohlcv_data[-300:]

    # 결측 데이터 제외
    if len(ohlcv_data) != 0:

        #          데이터 전처리         #
        #   Fixed X_data    #
        price = ohlcv_data[:, :4]
        volume = ohlcv_data[:, [4]]
        MA20 = ohlcv_data[:, [-8]]
        CMO = ohlcv_data[:, [-7]]
        OBV = ohlcv_data[:, [-6]]
        RSI = ohlcv_data[:, [-5]]
        MACD = ohlcv_data[:, [-4]]
        MACD_Signal = ohlcv_data[:, [-3]]
        MACD_OSC = ohlcv_data[:, [-2]]

        #   Flexible Y_data    #
        trade_state = ohlcv_data[:, [-1]]

        # scaled_price = min_max_scaler(price)
        # scaled_volume = min_max_scaler(volume)
        # scaled_CMO = min_max_scaler(CMO)
        # scaled_OBV = min_max_scaler(OBV)
        # scaled_RSI = min_max_scaler(RSI)

        # x = np.concatenate((scaled_price, scaled_volume, scaled_OBV), axis=1)  # axis=1, 세로로 합친다
        # x = scaled_price
        y = trade_state
        # print(x.shape, y_low.shape)  # (258, 6) (258, 1)
        # quit()

        dataX = []  # input_data length 만큼 담을 dataX 그릇
        dataY = []  # Target 을 담을 그릇
        for i in range(crop_size, len(ohlcv_data)):  # 마지막 데이터까지 다 긇어모은다.
            group_x = ohlcv_data[i - crop_size: i]
            group_y = y[i]
            price = group_x[:, :4]
            volume = group_x[:, [4]]
            MA20 = group_x[:, [-8]]
            
            pricema = np.concatenate((price, MA20), axis=1)
            scaled_pricema = (pricema - pricema.min()) / (pricema.max() - pricema.min())
            
            CMO = group_x[:, [-7]]
            OBV = group_x[:, [-6]]
            RSI = group_x[:, [-5]]
            MACD = group_x[:, -4:-1]

            scaled_volume = min_max_scaler(volume)
            scaled_CMO = min_max_scaler(CMO)
            scaled_OBV = min_max_scaler(OBV)
            scaled_RSI = min_max_scaler(RSI)
            scaled_MACD = (MACD - MACD.min()) / (MACD.max() - MACD.min())
            x = np.concatenate((scaled_pricema[:, :4], scaled_volume, 
                                scaled_pricema[:, 4:], scaled_CMO, scaled_OBV, scaled_RSI,
                 scaled_MACD), axis=1)
            # x = scaled_x + sudden_death  # axis=1, 세로로 합친다
            group_x = x[-input_data_length:]
            # print(group_x[0])
            # quit()

            #   데이터 값에 결측치가 존재하는 경우 #
            if sum(sum(np.isnan(group_x))) > 0:
                continue

            dataX.append(group_x)  # dataX 리스트에 추가
            dataY.append(group_y)

        if len(dataX) < 100:
            print('len(dataX) < 100')
            return None, None, None

        # X_test = np.array(dataX)
        # row = X_test.shape[1]
        # col = X_test.shape[2]
        #
        # X_test = X_test.astype('float32').reshape(-1, row, col, 1)
        # print(X_test.shape)

        #       Exstracting fiexd X_data       #
        sliced_ohlcv = ohlcv_data[crop_size:, :x.shape[1]]

        #                      Get Figure                     #
        if get_fig == 1:
            spanlist_low = []
            spanlist_high = []

            for m in range(len(trade_state)):
                if (trade_state[m] > 0.5) and (trade_state[m] < 1.5):
                    if m + 1 < len(trade_state):
                        spanlist_low.append((m, m + 1))
                    else:
                        spanlist_low.append((m - 1, m))

            for m in range(len(trade_state)):
                if (trade_state[m] > 1.5) and (trade_state[m] < 2.5):
                    if m + 1 < len(trade_state):
                        spanlist_high.append((m, m + 1))
                    else:
                        spanlist_high.append((m - 1, m))

            # ----------- 인덱스 초기화 됨 -----------#

            # ----------- 공통된 Chart 그리기 -----------#

            plt.subplot(211)
            plt.plot(min_max_scaler(ohlcv_data[:, 1:2]), 'r', label='close')
            # plt.plot(scaled_OBV, 'b', label='OBV')
            plt.legend(loc='upper right')
            for i in range(len(spanlist_low)):
                plt.axvspan(spanlist_low[i][0], spanlist_low[i][1], facecolor='m', alpha=0.5)

            plt.subplot(212)
            plt.plot(min_max_scaler(ohlcv_data[:, 1:2]), 'r', label='close')
            # plt.plot(scaled_OBV, 'b', label='OBV')
            plt.legend(loc='upper right')
            for i in range(len(spanlist_high)):
                plt.axvspan(spanlist_high[i][0], spanlist_high[i][1], facecolor='c', alpha=0.5)

            Date = file.split()[0]
            Coin = file.split()[1].split('.')[0]
            plt.savefig('./Figure_data/%s_%s/%s %s.png' % (input_data_length, model_num, Date, Coin), dpi=500)
            plt.close()
            # plt.show()
            # ----------- Chart 그리기 -----------#

        return dataX, dataY, sliced_ohlcv


if __name__ == '__main__':

    # ----------- Params -----------#
    input_data_length = 30
    model_num = 78

    #       Make folder      #
    try:
        os.mkdir('./Figure_data/%s_%s/' % (input_data_length, model_num))

    except Exception as e:
        pass
    check_span = 30
    get_fig = 0

    Made_X = []
    Made_Y = []

#     ohlcv_list = ['2020-01-10 ETH ohlcv.xlsx']

    for file in ohlcv_list:
        try:
            if int(file.split()[0].split('-')[1]) != 1:
                continue


            result = made_x(file, input_data_length, model_num, check_span, get_fig, crop_size=input_data_length)
            # result = low_high('dvp'.upper(), input_data_length)
            # print(result)
            # quit()

            # ------------ 데이터가 있으면 dataX, dataY 병합하기 ------------#
            if result is not None:
                if result[0] is not None:

                    Made_X += result[0]
                    Made_Y += result[1]

                # 누적 데이터량 표시
                print(file, len(Made_X))
                
        except Exception as e:
            pass

    # SAVING X, Y
    X = np.array(Made_X)
    Y = np.array(Made_Y)
    np.save('./Made_X/Made_X %s_%s' % (input_data_length, model_num), X)
    np.save('./Made_X/Made_Y %s_%s' % (input_data_length, model_num), Y)
    # np.save('./Made_X_high/Made_Y %s_%s' % (input_data_length, model_num), Y_high)
# Out:
# 2020-01-16 XLM ohlcv.xlsx 965
# 2020-01-23 TRX ohlcv.xlsx 1620
# 2020-01-31 AMO ohlcv.xlsx 2232
# 2020-01-16 SNT ohlcv.xlsx 2409
# len(dataX) < 100
# 2020-01-19 LBA ohlcv.xlsx 2409
# 2020-01-11 FX ohlcv.xlsx 2687
# 2020-01-22 LUNA ohlcv.xlsx 3748
# 2020-01-16 LINK ohlcv.xlsx 4704
# len(dataX) < 100
# 2020-01-28 PLY ohlcv.xlsx 4704
# 2020-01-13 FCT ohlcv.xlsx 4871
# 2020-01-20 IPX ohlcv.xlsx 6123
# len(dataX) < 100
# 2020-01-27 ITC ohlcv.xlsx 6123
# 2020-01-20 SNT ohlcv.xlsx 6335
# 2020-01-29 TMTG ohlcv.xlsx 7209
# len(dataX) < 100
# 2020-01-25 VET ohlcv.xlsx 7209
# 2020-01-21 EOS ohlcv.xlsx 8331
# 2020-01-24 FAB ohlcv.xlsx 8458
# 2020-01-22 TRV ohlcv.xlsx 8609
# 2020-01-22 MTL ohlcv.xlsx 8946
# 2020-01-28 TRX ohlcv.xlsx 9549
# len(dataX) < 100
# 2020-01-31 LAMB ohlcv.xlsx 9549
# len(dataX) < 100
# 2020-01-20 CMT ohlcv.xlsx 9549
# 2020-01-22 BTG ohlcv.xlsx 10518
# 2020-01-13 DAC ohlcv.xlsx 11637
# 2020-01-25 REP ohlcv.xlsx 11911
# 2020-01-11 APIS ohlcv.xlsx 12101
# 2020-01-26 XRP ohlcv.xlsx 13129
# 2020-01-28 LINK ohlcv.xlsx 13485
# 2020-01-13 APIS ohlcv.xlsx 13606
# len(dataX) < 100
# 2020-01-31 CMT ohlcv.xlsx 13606
# 2020-01-16 ETH ohlcv.xlsx 14893
# 2020-01-22 STRAT ohlcv.xlsx 14998
# 2020-01-12 BCH ohlcv.xlsx 16096
# len(dataX) < 100
# 2020-01-22 ZRX ohlcv.xlsx 16096
# len(dataX) < 100
# 2020-01-29 ZRX ohlcv.xlsx 16096
# 2020-01-11 ETH ohlcv.xlsx 17124
# 2020-01-26 TMTG ohlcv.xlsx 18264
# len(dataX) < 100
# 2020-01-28 WTC ohlcv.xlsx 18264
# len(dataX) < 100
# 2020-01-19 RDN ohlcv.xlsx 18264
# len(dataX) < 100
# 2020-01-31 KNC ohlcv.xlsx 18264
# 2020-01-21 MXC ohlcv.xlsx 18437
# len(dataX) < 100
# 2020-01-19 ICX ohlcv.xlsx 18437
# len(dataX) < 100
# 2020-01-15 SNT ohlcv.xlsx 18437
# 2020-01-16 POWR ohlcv.xlsx 18566
# 2020-01-16 BCD ohlcv.xlsx 19706
# 2020-01-12 BCD ohlcv.xlsx 20372
# len(dataX) < 100
# 2020-01-23 APIS ohlcv.xlsx 20372
# len(dataX) < 100
# 2020-01-15 OMG ohlcv.xlsx 20372
# 2020-01-20 BSV ohlcv.xlsx 21642
# 2020-01-16 XMR ohlcv.xlsx 21959
# 2020-01-22 AE ohlcv.xlsx 22253
# len(dataX) < 100
# 2020-01-23 BAT ohlcv.xlsx 22253
# 2020-01-24 FX ohlcv.xlsx 22422
# 2020-01-28 ETC ohlcv.xlsx 23485
# 2020-01-27 AMO ohlcv.xlsx 24119
# 2020-01-14 ETH ohlcv.xlsx 25080
# len(dataX) < 100
# 2020-01-27 MIX ohlcv.xlsx 25080
# len(dataX) < 100
# 2020-01-11 ABT ohlcv.xlsx 25080
# 2020-01-23 ETH ohlcv.xlsx 26078
# len(dataX) < 100
# 2020-01-16 CHR ohlcv.xlsx 26078
# 2020-01-25 CON ohlcv.xlsx 26703
# 2020-01-28 ENJ ohlcv.xlsx 26840
# 2020-01-28 IPX ohlcv.xlsx 27873
# 2020-01-30 FNB ohlcv.xlsx 28168
# 2020-01-16 APIS ohlcv.xlsx 28363
# len(dataX) < 100
# 2020-01-22 BZNT ohlcv.xlsx 28363
# 2020-01-29 BAT ohlcv.xlsx 28476
# 2020-01-23 INS ohlcv.xlsx 28623
# 2020-01-14 ETZ ohlcv.xlsx 28837
# 2020-01-23 MCO ohlcv.xlsx 28954
# 2020-01-19 FNB ohlcv.xlsx 29457
# len(dataX) < 100
# 2020-01-29 WAXP ohlcv.xlsx 29457
# len(dataX) < 100
# 2020-01-19 PAY ohlcv.xlsx 29457
# len(dataX) < 100
# 2020-01-28 INS ohlcv.xlsx 29457
# len(dataX) < 100
# 2020-01-12 XVG ohlcv.xlsx 29457
# 2020-01-20 MIX ohlcv.xlsx 29866
# len(dataX) < 100
# 2020-01-30 OGO ohlcv.xlsx 29866
# 2020-01-24 STEEM ohlcv.xlsx 30048
# 2020-01-13 AMO ohlcv.xlsx 30711
# 2020-01-21 BTG ohlcv.xlsx 31486
# 2020-01-24 REP ohlcv.xlsx 31617
# len(dataX) < 100
# 2020-01-14 PPT ohlcv.xlsx 31617
# len(dataX) < 100
# 2020-01-29 MXC ohlcv.xlsx 31617
# 2020-01-26 ETH ohlcv.xlsx 32376
# 2020-01-11 XSR ohlcv.xlsx 33536
# len(dataX) < 100
# 2020-01-16 OGO ohlcv.xlsx 33536
# len(dataX) < 100
# 2020-01-24 BHP ohlcv.xlsx 33536
# 2020-01-12 LTC ohlcv.xlsx 34206
# len(dataX) < 100
# 2020-01-12 INS ohlcv.xlsx 34206
# len(dataX) < 100
# 2020-01-30 OMG ohlcv.xlsx 34206
# 2020-01-23 ETC ohlcv.xlsx 34935
# len(dataX) < 100
# 2020-01-14 ORBS ohlcv.xlsx 34935
# 2020-01-19 STRAT ohlcv.xlsx 35263
# 2020-01-24 VALOR ohlcv.xlsx 35487
# len(dataX) < 100
# 2020-01-26 APIS ohlcv.xlsx 35487
# 2020-01-14 OGO ohlcv.xlsx 35985
# 2020-01-16 PCM ohlcv.xlsx 36102
# len(dataX) < 100
# 2020-01-22 WOM ohlcv.xlsx 36102
# 2020-01-26 MBL ohlcv.xlsx 37240
# len(dataX) < 100
# 2020-01-23 WAXP ohlcv.xlsx 37240
# 2020-01-26 FCT ohlcv.xlsx 37542
# 2020-01-15 ICX ohlcv.xlsx 37682
# len(dataX) < 100
# 2020-01-25 MXC ohlcv.xlsx 37682
# len(dataX) < 100
# 2020-01-21 RDN ohlcv.xlsx 37682
# 2020-01-31 IPX ohlcv.xlsx 38996
# 2020-01-23 BTT ohlcv.xlsx 39204
# len(dataX) < 100
# 2020-01-13 WAXP ohlcv.xlsx 39204
# 2020-01-13 XLM ohlcv.xlsx 39500
# 2020-01-20 ADA ohlcv.xlsx 40036
# 2020-01-16 ADA ohlcv.xlsx 40961
# 2020-01-12 CON ohlcv.xlsx 41844
# 2020-01-13 LAMB ohlcv.xlsx 41969
# 2020-01-28 CON ohlcv.xlsx 42799
# 2020-01-24 WAVES ohlcv.xlsx 42968
# len(dataX) < 100
# 2020-01-14 PCM ohlcv.xlsx 42968
# 2020-01-15 QTUM ohlcv.xlsx 43820
# len(dataX) < 100
# 2020-01-27 AOA ohlcv.xlsx 43820
# 2020-01-22 WPX ohlcv.xlsx 44842
# 2020-01-20 TRV ohlcv.xlsx 45134
# 2020-01-15 BAT ohlcv.xlsx 45246
# len(dataX) < 100
# 2020-01-23 PAY ohlcv.xlsx 45246
# 2020-01-31 SOC ohlcv.xlsx 46532
# 2020-01-23 MXC ohlcv.xlsx 46670
# 2020-01-31 BSV ohlcv.xlsx 47871
# 2020-01-27 MTL ohlcv.xlsx 48337
# len(dataX) < 100
# 2020-01-11 ORBS ohlcv.xlsx 48337
# len(dataX) < 100
# 2020-01-30 PLY ohlcv.xlsx 48337
# 2020-01-20 MXC ohlcv.xlsx 48922
# 2020-01-19 VALOR ohlcv.xlsx 49086
# len(dataX) < 100
# 2020-01-24 PPT ohlcv.xlsx 49086
# 2020-01-21 FAB ohlcv.xlsx 49962
# len(dataX) < 100
# 2020-01-28 STRAT ohlcv.xlsx 49962
# 2020-01-24 MBL ohlcv.xlsx 51177
# len(dataX) < 100
# 2020-01-22 PCM ohlcv.xlsx 51177
# len(dataX) < 100
# 2020-01-13 TRV ohlcv.xlsx 51177
# 2020-01-15 BHP ohlcv.xlsx 51963
# 2020-01-28 BCH ohlcv.xlsx 53189
# 2020-01-21 DASH ohlcv.xlsx 53492
# 2020-01-12 TRX ohlcv.xlsx 54252
# len(dataX) < 100
# 2020-01-26 ZEC ohlcv.xlsx 54252
# 2020-01-24 LTC ohlcv.xlsx 54679
# 2020-01-16 MIX ohlcv.xlsx 55133
# len(dataX) < 100
# 2020-01-22 BAT ohlcv.xlsx 55133
# 2020-01-30 MIX ohlcv.xlsx 55254
# len(dataX) < 100
# 2020-01-14 RDN ohlcv.xlsx 55254
# len(dataX) < 100
# 2020-01-19 PCM ohlcv.xlsx 55254
# 2020-01-29 MCO ohlcv.xlsx 55363
# 2020-01-27 REP ohlcv.xlsx 55753
# 2020-01-19 LUNA ohlcv.xlsx 56320
# 2020-01-12 IPX ohlcv.xlsx 56775
# len(dataX) < 100
# 2020-01-14 REP ohlcv.xlsx 56775
# 2020-01-25 LINK ohlcv.xlsx 57210
# 2020-01-20 FX ohlcv.xlsx 57539
# len(dataX) < 100
# 2020-01-27 PLY ohlcv.xlsx 57539
# 2020-01-22 DAC ohlcv.xlsx 58778
# 2020-01-25 MBL ohlcv.xlsx 60077
# 2020-01-31 WAVES ohlcv.xlsx 60195
# 2020-01-15 ETH ohlcv.xlsx 61182
# len(dataX) < 100
# 2020-01-15 MCO ohlcv.xlsx 61182
# 2020-01-11 XRP ohlcv.xlsx 62278
# len(dataX) < 100
# 2020-01-26 STEEM ohlcv.xlsx 62278
# 2020-01-19 TRV ohlcv.xlsx 63250
# len(dataX) < 100
# 2020-01-28 OGO ohlcv.xlsx 63250
# len(dataX) < 100
# 2020-01-12 WAXP ohlcv.xlsx 63250
# len(dataX) < 100
# 2020-01-12 VALOR ohlcv.xlsx 63250
# 2020-01-28 AOA ohlcv.xlsx 63420
# 2020-01-20 WAVES ohlcv.xlsx 63522
# 2020-01-28 BCD ohlcv.xlsx 64304
# len(dataX) < 100
# 2020-01-30 PIVX ohlcv.xlsx 64304
# 2020-01-22 CON ohlcv.xlsx 65221
# len(dataX) < 100
# 2020-01-29 XMR ohlcv.xlsx 65221
# 2020-01-25 MTL ohlcv.xlsx 65454
# len(dataX) < 100
# 2020-01-24 ABT ohlcv.xlsx 65454
# 2020-01-24 ETC ohlcv.xlsx 66205
# 2020-01-28 REP ohlcv.xlsx 66592
# len(dataX) < 100
# 2020-01-14 WAVES ohlcv.xlsx 66592
# 2020-01-20 AE ohlcv.xlsx 66928
# len(dataX) < 100
# 2020-01-19 TRUE ohlcv.xlsx 66928
# len(dataX) < 100
# 2020-01-28 VET ohlcv.xlsx 66928
# 2020-01-30 BTC ohlcv.xlsx 68228
# len(dataX) < 100
# 2020-01-31 XMR ohlcv.xlsx 68228
# 2020-01-13 DAD ohlcv.xlsx 68636
# len(dataX) < 100
# 2020-01-25 OMG ohlcv.xlsx 68636
# 2020-01-20 MTL ohlcv.xlsx 69371
# len(dataX) < 100
# 2020-01-19 FX ohlcv.xlsx 69371
# len(dataX) < 100
# 2020-01-12 ELF ohlcv.xlsx 69371
# 2020-01-20 BTT ohlcv.xlsx 69652
# 2020-01-27 XSR ohlcv.xlsx 70394
# len(dataX) < 100
# 2020-01-20 OGO ohlcv.xlsx 70394
# len(dataX) < 100
# 2020-01-19 LOOM ohlcv.xlsx 70394
# 2020-01-19 LTC ohlcv.xlsx 71272
# 2020-01-15 ZEC ohlcv.xlsx 71780
# 2020-01-30 REP ohlcv.xlsx 72184
# len(dataX) < 100
# 2020-01-12 ITC ohlcv.xlsx 72184
# 2020-01-19 INS ohlcv.xlsx 72568
# 2020-01-24 TMTG ohlcv.xlsx 73615
# len(dataX) < 100
# 2020-01-20 WICC ohlcv.xlsx 73615
# 2020-01-23 LUNA ohlcv.xlsx 74255
# len(dataX) < 100
# 2020-01-20 OCN ohlcv.xlsx 74255
# 2020-01-12 DVP ohlcv.xlsx 74549
# 2020-01-29 AOA ohlcv.xlsx 74841
# len(dataX) < 100
# 2020-01-30 ELF ohlcv.xlsx 74841
# 2020-01-20 REP ohlcv.xlsx 75392
# 2020-01-31 MBL ohlcv.xlsx 76589
# 2020-01-23 BCH ohlcv.xlsx 77602
# len(dataX) < 100
# 2020-01-28 NPXS ohlcv.xlsx 77602
# 2020-01-19 ZEC ohlcv.xlsx 78304
# len(dataX) < 100
# 2020-01-20 GNT ohlcv.xlsx 78304
# 2020-01-26 BTC ohlcv.xlsx 79542
# len(dataX) < 100
# 2020-01-29 WOM ohlcv.xlsx 79542
# 2020-01-23 IPX ohlcv.xlsx 80823
# len(dataX) < 100
# 2020-01-21 CHR ohlcv.xlsx 80823
# len(dataX) < 100
# 2020-01-23 XMR ohlcv.xlsx 80823
# len(dataX) < 100
# 2020-01-25 VALOR ohlcv.xlsx 80823
# 2020-01-14 BCH ohlcv.xlsx 81562
# 2020-01-19 QTUM ohlcv.xlsx 82725
# len(dataX) < 100
# 2020-01-12 BAT ohlcv.xlsx 82725
# 2020-01-19 BSV ohlcv.xlsx 84017
# 2020-01-30 NPXS ohlcv.xlsx 84152
# 2020-01-12 ENJ ohlcv.xlsx 84291
# 2020-01-24 BTG ohlcv.xlsx 85040
# len(dataX) < 100
# 2020-01-20 ZRX ohlcv.xlsx 85040
# 2020-01-25 PIVX ohlcv.xlsx 85159
# 2020-01-23 BSV ohlcv.xlsx 86371
# len(dataX) < 100
# 2020-01-25 NPXS ohlcv.xlsx 86371
# 2020-01-24 CON ohlcv.xlsx 87283
# len(dataX) < 100
# 2020-01-30 STRAT ohlcv.xlsx 87283
# 2020-01-31 ADA ohlcv.xlsx 88134
# 2020-01-13 LUNA ohlcv.xlsx 88832
# 2020-01-12 ADA ohlcv.xlsx 89135
# 2020-01-12 AOA ohlcv.xlsx 89288
# 2020-01-21 WTC ohlcv.xlsx 89644
# len(dataX) < 100
# 2020-01-11 HDAC ohlcv.xlsx 89644
# 2020-01-28 XRP ohlcv.xlsx 90790
# 2020-01-23 FCT ohlcv.xlsx 91001
# 2020-01-19 BCH ohlcv.xlsx 92300
# 2020-01-27 WPX ohlcv.xlsx 92554
# 2020-01-25 ETC ohlcv.xlsx 93421
# 2020-01-22 STEEM ohlcv.xlsx 94177
# len(dataX) < 100
# 2020-01-16 CRO ohlcv.xlsx 94177
# len(dataX) < 100
# 2020-01-23 STRAT ohlcv.xlsx 94177
# 2020-01-20 CON ohlcv.xlsx 95071
# 2020-01-27 SOC ohlcv.xlsx 96167
# len(dataX) < 100
# 2020-01-30 RNT ohlcv.xlsx 96167
# len(dataX) < 100
# 2020-01-30 BAT ohlcv.xlsx 96167
# 2020-01-25 ENJ ohlcv.xlsx 97032
# 2020-01-30 BCH ohlcv.xlsx 98162
# 2020-01-30 DAC ohlcv.xlsx 99352
# len(dataX) < 100
# 2020-01-20 POWR ohlcv.xlsx 99352
# 2020-01-12 LINK ohlcv.xlsx 99801
# len(dataX) < 100
# 2020-01-30 THETA ohlcv.xlsx 99801
# 2020-01-28 AMO ohlcv.xlsx 100422
# len(dataX) < 100
# 2020-01-15 MXC ohlcv.xlsx 100422
# 2020-01-26 EOS ohlcv.xlsx 101330
# len(dataX) < 100
# 2020-01-29 PIVX ohlcv.xlsx 101330
# 2020-01-13 OCN ohlcv.xlsx 101615
# 2020-01-31 FX ohlcv.xlsx 102047
# len(dataX) < 100
# 2020-01-21 HC ohlcv.xlsx 102047
# len(dataX) < 100
# 2020-01-13 PIVX ohlcv.xlsx 102047
# 2020-01-22 XLM ohlcv.xlsx 102680
# 2020-01-24 BTT ohlcv.xlsx 102825
# len(dataX) < 100
# 2020-01-23 HDAC ohlcv.xlsx 102825
# 2020-01-24 BTC ohlcv.xlsx 104112
# len(dataX) < 100
# 2020-01-12 PPT ohlcv.xlsx 104112
# 2020-01-29 LTC ohlcv.xlsx 104797
# 2020-01-23 ADA ohlcv.xlsx 105250
# 2020-01-23 STEEM ohlcv.xlsx 105622
# 2020-01-11 BCH ohlcv.xlsx 106510
# 2020-01-27 LUNA ohlcv.xlsx 106650
# len(dataX) < 100
# 2020-01-28 WAVES ohlcv.xlsx 106650
# 2020-01-23 GNT ohlcv.xlsx 107392
# 2020-01-19 FAB ohlcv.xlsx 107622
# 2020-01-29 AMO ohlcv.xlsx 108261
# 2020-01-12 XRP ohlcv.xlsx 109423
# 2020-01-28 MBL ohlcv.xlsx 110597
# len(dataX) < 100
# 2020-01-24 HDAC ohlcv.xlsx 110597
# 2020-01-16 XVG ohlcv.xlsx 110846
# len(dataX) < 100
# 2020-01-28 VALOR ohlcv.xlsx 110846
# len(dataX) < 100
# 2020-01-31 VALOR ohlcv.xlsx 110846
# 2020-01-11 LTC ohlcv.xlsx 111230
# 2020-01-22 BCD ohlcv.xlsx 111857
# 2020-01-23 BTC ohlcv.xlsx 113134
# len(dataX) < 100
# 2020-01-22 XVG ohlcv.xlsx 113134
# len(dataX) < 100
# 2020-01-19 NPXS ohlcv.xlsx 113134
# 2020-01-15 DAD ohlcv.xlsx 113699
# len(dataX) < 100
# 2020-01-13 HC ohlcv.xlsx 113699
# 2020-01-19 VET ohlcv.xlsx 113849
# 2020-01-22 VALOR ohlcv.xlsx 113974
# len(dataX) < 100
# 2020-01-16 FZZ ohlcv.xlsx 113974
# len(dataX) < 100
# 2020-01-28 RNT ohlcv.xlsx 113974
# len(dataX) < 100
# 2020-01-23 NPXS ohlcv.xlsx 113974
# 2020-01-19 TRX ohlcv.xlsx 114880
# len(dataX) < 100
# 2020-01-11 WAXP ohlcv.xlsx 114880
# 2020-01-14 MXC ohlcv.xlsx 115093
# 2020-01-16 KNC ohlcv.xlsx 115219
# 2020-01-27 EOS ohlcv.xlsx 116063
# 2020-01-19 AE ohlcv.xlsx 116275
# 2020-01-14 WAXP ohlcv.xlsx 116550
# 2020-01-20 AOA ohlcv.xlsx 116863
# 2020-01-14 ADA ohlcv.xlsx 117084
# 2020-01-19 WOM ohlcv.xlsx 117311
# 2020-01-19 TMTG ohlcv.xlsx 117878
# len(dataX) < 100
# 2020-01-13 WAVES ohlcv.xlsx 117878
# 2020-01-12 AMO ohlcv.xlsx 118547
# 2020-01-13 BTG ohlcv.xlsx 119071
# 2020-01-13 FNB ohlcv.xlsx 119507
# 2020-01-27 ZEC ohlcv.xlsx 119666
# 2020-01-14 DAC ohlcv.xlsx 120903
# 2020-01-14 LBA ohlcv.xlsx 121094
# len(dataX) < 100
# 2020-01-15 STRAT ohlcv.xlsx 121094
# 2020-01-30 MTL ohlcv.xlsx 121385
# len(dataX) < 100
# 2020-01-22 VET ohlcv.xlsx 121385
# 2020-01-11 DASH ohlcv.xlsx 121488
# 2020-01-16 BSV ohlcv.xlsx 122800
# len(dataX) < 100
# 2020-01-13 FZZ ohlcv.xlsx 122800
# len(dataX) < 100
# 2020-01-23 OCN ohlcv.xlsx 122800
# 2020-01-31 NPXS ohlcv.xlsx 122979
# len(dataX) < 100
# 2020-01-13 REP ohlcv.xlsx 122979
# len(dataX) < 100
# 2020-01-31 INS ohlcv.xlsx 122979
# 2020-01-23 AOA ohlcv.xlsx 123161
# 2020-01-11 AOA ohlcv.xlsx 123361
# 2020-01-15 REP ohlcv.xlsx 123724
# 2020-01-22 EOS ohlcv.xlsx 124732
# 2020-01-30 DASH ohlcv.xlsx 124895
# len(dataX) < 100
# 2020-01-28 FAB ohlcv.xlsx 124895
# 2020-01-19 PPT ohlcv.xlsx 125187
# 2020-01-26 LUNA ohlcv.xlsx 125499
# 2020-01-11 AMO ohlcv.xlsx 126155
# len(dataX) < 100
# 2020-01-23 VET ohlcv.xlsx 126155
# len(dataX) < 100
# 2020-01-29 MIX ohlcv.xlsx 126155
# 2020-01-25 XRP ohlcv.xlsx 127350
# len(dataX) < 100
# 2020-01-28 MIX ohlcv.xlsx 127350
# 2020-01-19 AMO ohlcv.xlsx 127999
# 2020-01-29 ENJ ohlcv.xlsx 128176
# 2020-01-21 DAC ohlcv.xlsx 129221
# len(dataX) < 100
# 2020-01-25 ELF ohlcv.xlsx 129221
# len(dataX) < 100
# 2020-01-15 POWR ohlcv.xlsx 129221
# 2020-01-15 BTT ohlcv.xlsx 129602
# 2020-01-30 ZIL ohlcv.xlsx 129715
# 2020-01-16 ARN ohlcv.xlsx 129888
# len(dataX) < 100
# 2020-01-19 DAD ohlcv.xlsx 129888
# len(dataX) < 100
# 2020-01-15 VALOR ohlcv.xlsx 129888
# 2020-01-24 XSR ohlcv.xlsx 130842
# 2020-01-15 LAMB ohlcv.xlsx 130958
# 2020-01-29 LINK ohlcv.xlsx 131341
# len(dataX) < 100
# 2020-01-30 GXC ohlcv.xlsx 131341
# 2020-01-16 REP ohlcv.xlsx 132062
# len(dataX) < 100
# 2020-01-14 THETA ohlcv.xlsx 132062
# 2020-01-22 TRX ohlcv.xlsx 132790
# 2020-01-20 ETC ohlcv.xlsx 134030
# 2020-01-16 HDAC ohlcv.xlsx 134213
# len(dataX) < 100
# 2020-01-23 MIX ohlcv.xlsx 134213
# 2020-01-15 INS ohlcv.xlsx 134516
# 2020-01-31 DVP ohlcv.xlsx 135132
# 2020-01-15 XRP ohlcv.xlsx 136279
# len(dataX) < 100
# 2020-01-27 WTC ohlcv.xlsx 136279
# 2020-01-29 STEEM ohlcv.xlsx 136563
# 2020-01-30 ADA ohlcv.xlsx 137547
# 2020-01-23 VALOR ohlcv.xlsx 137763
# len(dataX) < 100
# 2020-01-11 REP ohlcv.xlsx 137763
# len(dataX) < 100
# 2020-01-19 ZIL ohlcv.xlsx 137763
# 2020-01-26 CON ohlcv.xlsx 138481
# 2020-01-20 XRP ohlcv.xlsx 139765
# 2020-01-25 BTG ohlcv.xlsx 140490
# 2020-01-24 XEM ohlcv.xlsx 140755
# 2020-01-21 WPX ohlcv.xlsx 141543
# len(dataX) < 100
# 2020-01-14 PAY ohlcv.xlsx 141543
# len(dataX) < 100
# 2020-01-19 CMT ohlcv.xlsx 141543
# len(dataX) < 100
# 2020-01-29 WTC ohlcv.xlsx 141543
# 2020-01-27 DASH ohlcv.xlsx 141755
# 2020-01-27 XRP ohlcv.xlsx 142690
# 2020-01-25 BCD ohlcv.xlsx 143127
# 2020-01-15 APIS ohlcv.xlsx 143257
# 2020-01-31 OGO ohlcv.xlsx 144094
# 2020-01-31 FCT ohlcv.xlsx 144491
# len(dataX) < 100
# 2020-01-29 ABT ohlcv.xlsx 144491
# 2020-01-16 LUNA ohlcv.xlsx 145298
# len(dataX) < 100
# 2020-01-14 OMG ohlcv.xlsx 145298
# 2020-01-31 ICX ohlcv.xlsx 145712
# 2020-01-19 HC ohlcv.xlsx 145913
# 2020-01-28 TRV ohlcv.xlsx 146074
# 2020-01-13 ETH ohlcv.xlsx 147075
# len(dataX) < 100
# 2020-01-14 ZIL ohlcv.xlsx 147075
# len(dataX) < 100
# 2020-01-14 WET ohlcv.xlsx 147075
# len(dataX) < 100
# 2020-01-24 MCO ohlcv.xlsx 147075
# len(dataX) < 100
# 2020-01-11 STRAT ohlcv.xlsx 147075
# len(dataX) < 100
# 2020-01-23 LBA ohlcv.xlsx 147075
# 2020-01-19 CTXC ohlcv.xlsx 147232
# 2020-01-20 AMO ohlcv.xlsx 147935
# len(dataX) < 100
# 2020-01-24 CTXC ohlcv.xlsx 147935
# len(dataX) < 100
# 2020-01-28 MCO ohlcv.xlsx 147935
# len(dataX) < 100
# 2020-01-21 WAXP ohlcv.xlsx 147935
# len(dataX) < 100
# 2020-01-12 WET ohlcv.xlsx 147935
# len(dataX) < 100
# 2020-01-19 GNT ohlcv.xlsx 147935
# len(dataX) < 100
# 2020-01-16 PIVX ohlcv.xlsx 147935
# len(dataX) < 100
# 2020-01-15 FX ohlcv.xlsx 147935
# 2020-01-21 BSV ohlcv.xlsx 149182
# len(dataX) < 100
# 2020-01-15 WTC ohlcv.xlsx 149182
# 2020-01-29 BTG ohlcv.xlsx 150332
# 2020-01-20 HC ohlcv.xlsx 150442
# 2020-01-29 BSV ohlcv.xlsx 151719
# 2020-01-15 IOST ohlcv.xlsx 151849
# 2020-01-16 QTUM ohlcv.xlsx 152969
# 2020-01-21 STEEM ohlcv.xlsx 153303
# 2020-01-15 ENJ ohlcv.xlsx 153569
# 2020-01-24 IPX ohlcv.xlsx 154883
# len(dataX) < 100
# 2020-01-14 HC ohlcv.xlsx 154883
# 2020-01-22 PIVX ohlcv.xlsx 155583
# 2020-01-26 DAC ohlcv.xlsx 156821
# 2020-01-14 TMTG ohlcv.xlsx 157820
# 2020-01-16 EOS ohlcv.xlsx 159109
# 2020-01-11 ENJ ohlcv.xlsx 159232
# len(dataX) < 100
# 2020-01-19 MCO ohlcv.xlsx 159232
# 2020-01-30 AOA ohlcv.xlsx 159515
# len(dataX) < 100
# 2020-01-29 PAY ohlcv.xlsx 159515
# 2020-01-28 ADA ohlcv.xlsx 159851
# 2020-01-11 ADA ohlcv.xlsx 160098
# 2020-01-25 BTC ohlcv.xlsx 161401
# 2020-01-14 XRP ohlcv.xlsx 162512
# 2020-01-22 INS ohlcv.xlsx 162636
# 2020-01-19 IPX ohlcv.xlsx 163920
# 2020-01-19 FCT ohlcv.xlsx 164331
# 2020-01-22 IPX ohlcv.xlsx 165613
# len(dataX) < 100
# 2020-01-21 ANKR ohlcv.xlsx 165613
# 2020-01-23 TMTG ohlcv.xlsx 166513
# len(dataX) < 100
# 2020-01-15 PAY ohlcv.xlsx 166513
# 2020-01-20 STEEM ohlcv.xlsx 167573
# len(dataX) < 100
# 2020-01-21 BHP ohlcv.xlsx 167573
# 2020-01-22 WICC ohlcv.xlsx 167682
# len(dataX) < 100
# 2020-01-23 LAMB ohlcv.xlsx 167682
# len(dataX) < 100
# 2020-01-15 ELF ohlcv.xlsx 167682
# 2020-01-20 XLM ohlcv.xlsx 168361
# 2020-01-21 XSR ohlcv.xlsx 169050
# 2020-01-27 BCD ohlcv.xlsx 169303
# len(dataX) < 100
# 2020-01-11 BAT ohlcv.xlsx 169303
# len(dataX) < 100
# 2020-01-28 HC ohlcv.xlsx 169303
# 2020-01-15 DAC ohlcv.xlsx 170385
# len(dataX) < 100
# 2020-01-13 BZNT ohlcv.xlsx 170385
# len(dataX) < 100
# 2020-01-13 PPT ohlcv.xlsx 170385
# len(dataX) < 100
# 2020-01-11 ZIL ohlcv.xlsx 170385
# 2020-01-30 STEEM ohlcv.xlsx 170630
# len(dataX) < 100
# 2020-01-23 WOM ohlcv.xlsx 170630
# 2020-01-11 XLM ohlcv.xlsx 170964
# 2020-01-23 SOC ohlcv.xlsx 172053
# len(dataX) < 100
# 2020-01-15 HC ohlcv.xlsx 172053
# 2020-01-13 HYC ohlcv.xlsx 172246
# len(dataX) < 100
# 2020-01-24 KNC ohlcv.xlsx 172246
# len(dataX) < 100
# 2020-01-19 SNT ohlcv.xlsx 172246
# 2020-01-28 LUNA ohlcv.xlsx 172513
# len(dataX) < 100
# 2020-01-29 FX ohlcv.xlsx 172513
# 2020-01-20 RDN ohlcv.xlsx 172750
# 2020-01-16 WAXP ohlcv.xlsx 172875
# 2020-01-25 WPX ohlcv.xlsx 173655
# len(dataX) < 100
# 2020-01-31 POWR ohlcv.xlsx 173655
# 2020-01-30 MBL ohlcv.xlsx 174895
# 2020-01-31 TRX ohlcv.xlsx 175653
# 2020-01-27 DAC ohlcv.xlsx 176919
# 2020-01-24 FCT ohlcv.xlsx 177434
# len(dataX) < 100
# 2020-01-23 LOOM ohlcv.xlsx 177434
# 2020-01-24 WTC ohlcv.xlsx 177568
# 2020-01-21 DAD ohlcv.xlsx 177734
# len(dataX) < 100
# 2020-01-11 ZRX ohlcv.xlsx 177734
# 2020-01-21 WAVES ohlcv.xlsx 177915
# len(dataX) < 100
# 2020-01-15 LOOM ohlcv.xlsx 177915
# 2020-01-12 XLM ohlcv.xlsx 178310
# len(dataX) < 100
# 2020-01-25 WOM ohlcv.xlsx 178310
# len(dataX) < 100
# 2020-01-28 XVG ohlcv.xlsx 178310
# 2020-01-13 FX ohlcv.xlsx 178421
# 2020-01-25 FCT ohlcv.xlsx 178822
# 2020-01-15 ADA ohlcv.xlsx 179217
# 2020-01-15 XMR ohlcv.xlsx 179337
# len(dataX) < 100
# 2020-01-31 VET ohlcv.xlsx 179337
# len(dataX) < 100
# 2020-01-23 ZRX ohlcv.xlsx 179337
# len(dataX) < 100
# 2020-01-24 WAXP ohlcv.xlsx 179337
# 2020-01-27 DAD ohlcv.xlsx 179458
# 2020-01-11 SOC ohlcv.xlsx 180454
# len(dataX) < 100
# 2020-01-30 HDAC ohlcv.xlsx 180454
# len(dataX) < 100
# 2020-01-30 XMR ohlcv.xlsx 180454
# len(dataX) < 100
# 2020-01-19 XVG ohlcv.xlsx 180454
# 2020-01-12 STEEM ohlcv.xlsx 180609
# 2020-01-31 RDN ohlcv.xlsx 180746
# 2020-01-22 FAB ohlcv.xlsx 181179
# len(dataX) < 100
# 2020-01-15 RDN ohlcv.xlsx 181179
# 2020-01-20 OMG ohlcv.xlsx 181285
# len(dataX) < 100
# 2020-01-30 VET ohlcv.xlsx 181285
# len(dataX) < 100
# 2020-01-24 RNT ohlcv.xlsx 181285
# 2020-01-30 XLM ohlcv.xlsx 182060
# len(dataX) < 100
# 2020-01-29 CHR ohlcv.xlsx 182060
# 2020-01-12 REP ohlcv.xlsx 182329
# 2020-01-15 OGO ohlcv.xlsx 182623
# len(dataX) < 100
# 2020-01-14 LAMB ohlcv.xlsx 182623
# len(dataX) < 100
# 2020-01-13 MIX ohlcv.xlsx 182623
# 2020-01-28 BSV ohlcv.xlsx 183836
# len(dataX) < 100
# 2020-01-15 WAVES ohlcv.xlsx 183836
# len(dataX) < 100
# 2020-01-13 ORBS ohlcv.xlsx 183836
# 2020-01-25 DAC ohlcv.xlsx 184983
# len(dataX) < 100
# 2020-01-12 HC ohlcv.xlsx 184983
# 2020-01-13 ADA ohlcv.xlsx 185210
# 2020-01-16 LAMB ohlcv.xlsx 185624
# 2020-01-12 FCT ohlcv.xlsx 186004
# len(dataX) < 100
# 2020-01-31 MXC ohlcv.xlsx 186004
# len(dataX) < 100
# 2020-01-14 BAT ohlcv.xlsx 186004
# 2020-01-29 ICX ohlcv.xlsx 186223
# 2020-01-15 ARN ohlcv.xlsx 186714
# 2020-01-24 BCH ohlcv.xlsx 187594
# 2020-01-13 ETC ohlcv.xlsx 188074
# len(dataX) < 100
# 2020-01-27 STEEM ohlcv.xlsx 188074
# len(dataX) < 100
# 2020-01-25 ICX ohlcv.xlsx 188074
# 2020-01-28 SOC ohlcv.xlsx 189077
# 2020-01-25 LUNA ohlcv.xlsx 189418
# 2020-01-15 LINK ohlcv.xlsx 190041
# len(dataX) < 100
# 2020-01-19 WAXP ohlcv.xlsx 190041
# 2020-01-12 BTC ohlcv.xlsx 191348
# 2020-01-16 DAD ohlcv.xlsx 191851
# len(dataX) < 100
# 2020-01-12 ZIL ohlcv.xlsx 191851
# 2020-01-28 XLM ohlcv.xlsx 192270
# len(dataX) < 100
# 2020-01-21 BAT ohlcv.xlsx 192270
# 2020-01-24 INS ohlcv.xlsx 192378
# len(dataX) < 100
# 2020-01-16 RNT ohlcv.xlsx 192378
# 2020-01-25 LTC ohlcv.xlsx 192919
# 2020-01-25 APIS ohlcv.xlsx 193055
# 2020-01-11 DAD ohlcv.xlsx 193887
# len(dataX) < 100
# 2020-01-22 OCN ohlcv.xlsx 193887
# 2020-01-31 TMTG ohlcv.xlsx 194865
# 2020-01-11 CON ohlcv.xlsx 195788
# len(dataX) < 100
# 2020-01-22 XMR ohlcv.xlsx 195788
# 2020-01-28 LTC ohlcv.xlsx 196276
# len(dataX) < 100
# 2020-01-13 LBA ohlcv.xlsx 196276
# 2020-01-16 LTC ohlcv.xlsx 197333
# 2020-01-15 AMO ohlcv.xlsx 197958
# len(dataX) < 100
# 2020-01-26 FX ohlcv.xlsx 197958
# 2020-01-24 LUNA ohlcv.xlsx 198560
# 2020-01-14 ABT ohlcv.xlsx 199229
# 2020-01-19 IOST ohlcv.xlsx 199377
# 2020-01-20 WOM ohlcv.xlsx 199520
# len(dataX) < 100
# 2020-01-11 GNT ohlcv.xlsx 199520
# 2020-01-29 MTL ohlcv.xlsx 199888
# 2020-01-20 ELF ohlcv.xlsx 200061
# 2020-01-14 ZEC ohlcv.xlsx 200283
# 2020-01-30 BTG ohlcv.xlsx 201276
# 2020-01-21 LTC ohlcv.xlsx 201839
# len(dataX) < 100
# 2020-01-12 ANKR ohlcv.xlsx 201839
# len(dataX) < 100
# 2020-01-31 ABT ohlcv.xlsx 201839
# 2020-01-29 BTT ohlcv.xlsx 202076
# 2020-01-28 XSR ohlcv.xlsx 202930
# len(dataX) < 100
# 2020-01-11 INS ohlcv.xlsx 202930
# 2020-01-14 MIX ohlcv.xlsx 203079
# 2020-01-24 AOA ohlcv.xlsx 203431
# 2020-01-13 BCD ohlcv.xlsx 203816
# 2020-01-19 WTC ohlcv.xlsx 204064
# len(dataX) < 100
# 2020-01-25 FAB ohlcv.xlsx 204064
# 2020-01-15 ORBS ohlcv.xlsx 204248
# len(dataX) < 100
# 2020-01-24 THETA ohlcv.xlsx 204248
# 2020-01-15 BSV ohlcv.xlsx 205450
# len(dataX) < 100
# 2020-01-20 ZIL ohlcv.xlsx 205450
# 2020-01-29 BCH ohlcv.xlsx 206663
# 2020-01-21 MBL ohlcv.xlsx 207904
# len(dataX) < 100
# 2020-01-25 GNT ohlcv.xlsx 207904
# len(dataX) < 100
# 2020-01-20 LBA ohlcv.xlsx 207904
# len(dataX) < 100
# 2020-01-12 CHR ohlcv.xlsx 207904
# len(dataX) < 100
# 2020-01-15 TRUE ohlcv.xlsx 207904
# len(dataX) < 100
# 2020-01-30 HYC ohlcv.xlsx 207904
# 2020-01-25 BSV ohlcv.xlsx 209164
# 2020-01-12 DAD ohlcv.xlsx 209776
# len(dataX) < 100
# 2020-01-24 HYC ohlcv.xlsx 209776
# 2020-01-31 ZEC ohlcv.xlsx 210226
# len(dataX) < 100
# 2020-01-24 HC ohlcv.xlsx 210226
# 2020-01-19 MBL ohlcv.xlsx 211501
# len(dataX) < 100
# 2020-01-30 SNT ohlcv.xlsx 211501
# len(dataX) < 100
# 2020-01-11 XVG ohlcv.xlsx 211501
# 2020-01-15 FNB ohlcv.xlsx 212230
# len(dataX) < 100
# 2020-01-16 DVP ohlcv.xlsx 212230
# 2020-01-11 LAMB ohlcv.xlsx 212336
# 2020-01-22 SOC ohlcv.xlsx 213529
# len(dataX) < 100
# 2020-01-21 HDAC ohlcv.xlsx 213529
# len(dataX) < 100
# 2020-01-12 FZZ ohlcv.xlsx 213529
# 2020-01-20 LINK ohlcv.xlsx 214148
# 2020-01-23 WTC ohlcv.xlsx 214416
# len(dataX) < 100
# 2020-01-21 NPXS ohlcv.xlsx 214416
# 2020-01-12 XSR ohlcv.xlsx 215536
# 2020-01-12 ZEC ohlcv.xlsx 215686
# 2020-01-30 POWR ohlcv.xlsx 215823
# 2020-01-13 EOS ohlcv.xlsx 216871
# 2020-01-13 PAY ohlcv.xlsx 217001
# 2020-01-13 TMTG ohlcv.xlsx 218218
# len(dataX) < 100
# 2020-01-21 OMG ohlcv.xlsx 218218
# len(dataX) < 100
# 2020-01-31 HDAC ohlcv.xlsx 218218
# len(dataX) < 100
# 2020-01-24 FZZ ohlcv.xlsx 218218
# 2020-01-11 ETC ohlcv.xlsx 218620
# 2020-01-10 BTC ohlcv.xlsx 219927
# len(dataX) < 100
# 2020-01-21 POWR ohlcv.xlsx 219927
# 2020-01-16 LBA ohlcv.xlsx 220323
# 2020-01-14 XLM ohlcv.xlsx 220578
# 2020-01-14 LTC ohlcv.xlsx 221045
# 2020-01-15 MTL ohlcv.xlsx 221418
# 2020-01-20 WTC ohlcv.xlsx 221786
# len(dataX) < 100
# 2020-01-12 VET ohlcv.xlsx 221786
# len(dataX) < 100
# 2020-01-22 HYC ohlcv.xlsx 221786
# 2020-01-15 ETC ohlcv.xlsx 222298
# 2020-01-24 BCD ohlcv.xlsx 222690
# 2020-01-20 VALOR ohlcv.xlsx 223735
# len(dataX) < 100
# 2020-01-26 CHR ohlcv.xlsx 223735
# 2020-01-21 HYC ohlcv.xlsx 223874
# len(dataX) < 100
# 2020-01-24 WET ohlcv.xlsx 223874
# 2020-01-27 ETH ohlcv.xlsx 224602
# len(dataX) < 100
# 2020-01-23 WAVES ohlcv.xlsx 224602
# 2020-01-13 XRP ohlcv.xlsx 225782
# 2020-01-21 BTT ohlcv.xlsx 226005
# len(dataX) < 100
# 2020-01-14 AE ohlcv.xlsx 226005
# 2020-01-22 QTUM ohlcv.xlsx 226645
# len(dataX) < 100
# 2020-01-31 ORBS ohlcv.xlsx 226645
# 2020-01-16 WET ohlcv.xlsx 226746
# len(dataX) < 100
# 2020-01-24 CMT ohlcv.xlsx 226746
# len(dataX) < 100
# 2020-01-19 GXC ohlcv.xlsx 226746
# 2020-01-13 XSR ohlcv.xlsx 227759
# 2020-01-20 DAD ohlcv.xlsx 227859
# 2020-01-20 XSR ohlcv.xlsx 228609
# len(dataX) < 100
# 2020-01-13 GNT ohlcv.xlsx 228609
# 2020-01-19 XEM ohlcv.xlsx 228719
# 2020-01-29 INS ohlcv.xlsx 228944
# 2020-01-16 FX ohlcv.xlsx 229170
# len(dataX) < 100
# 2020-01-31 ZIL ohlcv.xlsx 229170
# 2020-01-31 BTC ohlcv.xlsx 230477
# len(dataX) < 100
# 2020-01-28 XMR ohlcv.xlsx 230477
# 2020-01-25 TRV ohlcv.xlsx 230580
# len(dataX) < 100
# 2020-01-28 FX ohlcv.xlsx 230580
# 2020-01-16 WTC ohlcv.xlsx 231275
# 2020-01-14 DASH ohlcv.xlsx 231378
# 2020-01-20 SOC ohlcv.xlsx 232044
# len(dataX) < 100
# 2020-01-19 BAT ohlcv.xlsx 232044
# 2020-01-16 TMTG ohlcv.xlsx 232911
# 2020-01-14 EOS ohlcv.xlsx 234003
# 2020-01-16 PPT ohlcv.xlsx 234288
# 2020-01-24 APIS ohlcv.xlsx 234394
# 2020-01-26 AMO ohlcv.xlsx 234896
# len(dataX) < 100
# 2020-01-19 THETA ohlcv.xlsx 234896
# 2020-01-29 ADA ohlcv.xlsx 235721
# len(dataX) < 100
# 2020-01-12 PIVX ohlcv.xlsx 235721
# len(dataX) < 100
# 2020-01-26 XEM ohlcv.xlsx 235721
# len(dataX) < 100
# 2020-01-29 XEM ohlcv.xlsx 235721
# len(dataX) < 100
# 2020-01-14 CTXC ohlcv.xlsx 235721
# 2020-01-30 ETH ohlcv.xlsx 236864
# 2020-01-19 REP ohlcv.xlsx 237576
# len(dataX) < 100
# 2020-01-23 CTXC ohlcv.xlsx 237576
# len(dataX) < 100
# 2020-01-20 BAT ohlcv.xlsx 237576
# 2020-01-19 BTG ohlcv.xlsx 238625
# 2020-01-20 ZEC ohlcv.xlsx 239054
# len(dataX) < 100
# 2020-01-19 BHP ohlcv.xlsx 239054
# len(dataX) < 100
# 2020-01-28 OMG ohlcv.xlsx 239054
# len(dataX) < 100
# 2020-01-30 IOST ohlcv.xlsx 239054
# len(dataX) < 100
# 2020-01-22 IOST ohlcv.xlsx 239054
# len(dataX) < 100
# 2020-01-23 PIVX ohlcv.xlsx 239054
# 2020-01-30 BTT ohlcv.xlsx 239335
# len(dataX) < 100
# 2020-01-21 XVG ohlcv.xlsx 239335
# 2020-01-12 BHP ohlcv.xlsx 240150
# 2020-01-23 WPX ohlcv.xlsx 241033
# 2020-01-26 BCD ohlcv.xlsx 241242
# len(dataX) < 100
# 2020-01-29 KNC ohlcv.xlsx 241242
# 2020-01-15 SOC ohlcv.xlsx 242514
# 2020-01-21 BTC ohlcv.xlsx 243818
# len(dataX) < 100
# 2020-01-23 BHP ohlcv.xlsx 243818
# len(dataX) < 100
# 2020-01-29 STRAT ohlcv.xlsx 243818
# len(dataX) < 100
# 2020-01-22 PLY ohlcv.xlsx 243818
# len(dataX) < 100
# 2020-01-12 ZRX ohlcv.xlsx 243818
# len(dataX) < 100
# 2020-01-29 NPXS ohlcv.xlsx 243818
# 2020-01-26 ENJ ohlcv.xlsx 244008
# len(dataX) < 100
# 2020-01-13 ZRX ohlcv.xlsx 244008
# 2020-01-16 VET ohlcv.xlsx 244313
# 2020-01-16 ETZ ohlcv.xlsx 244507
# len(dataX) < 100
# 2020-01-21 RNT ohlcv.xlsx 244507
# len(dataX) < 100
# 2020-01-24 XVG ohlcv.xlsx 244507
# len(dataX) < 100
# 2020-01-25 LOOM ohlcv.xlsx 244507
# len(dataX) < 100
# 2020-01-11 VET ohlcv.xlsx 244507
# 2020-01-21 LUNA ohlcv.xlsx 245643
# len(dataX) < 100
# 2020-01-13 ITC ohlcv.xlsx 245643
# 2020-01-24 LINK ohlcv.xlsx 246101
# 2020-01-16 BHP ohlcv.xlsx 246989
# 2020-01-14 APIS ohlcv.xlsx 247110
# len(dataX) < 100
# 2020-01-25 LAMB ohlcv.xlsx 247110
# 2020-01-19 ETC ohlcv.xlsx 248397
# 2020-01-14 XSR ohlcv.xlsx 249220
# len(dataX) < 100
# 2020-01-29 IOST ohlcv.xlsx 249220
# len(dataX) < 100
# 2020-01-23 XVG ohlcv.xlsx 249220
# len(dataX) < 100
# 2020-01-31 ETZ ohlcv.xlsx 249220
# 2020-01-30 TMTG ohlcv.xlsx 250289
# len(dataX) < 100
# 2020-01-24 POWR ohlcv.xlsx 250289
# len(dataX) < 100
# 2020-01-28 WOM ohlcv.xlsx 250289
# len(dataX) < 100
# 2020-01-26 DAD ohlcv.xlsx 250289
# len(dataX) < 100
# 2020-01-27 HDAC ohlcv.xlsx 250289
# 2020-01-31 CON ohlcv.xlsx 250767
# 2020-01-25 TRX ohlcv.xlsx 251337
# 2020-01-21 AMO ohlcv.xlsx 251978
# 2020-01-27 BSV ohlcv.xlsx 253069
# 2020-01-27 TRX ohlcv.xlsx 253450
# 2020-01-21 PLY ohlcv.xlsx 253641
# len(dataX) < 100
# 2020-01-24 DVP ohlcv.xlsx 253641
# len(dataX) < 100
# 2020-01-15 DVP ohlcv.xlsx 253641
# len(dataX) < 100
# 2020-01-24 VET ohlcv.xlsx 253641
# 2020-01-16 ELF ohlcv.xlsx 253970
# 2020-01-14 RNT ohlcv.xlsx 254128
# 2020-01-28 ETH ohlcv.xlsx 255168
# len(dataX) < 100
# 2020-01-24 SNT ohlcv.xlsx 255168
# len(dataX) < 100
# 2020-01-29 GXC ohlcv.xlsx 255168
# len(dataX) < 100
# 2020-01-24 IOST ohlcv.xlsx 255168
# len(dataX) < 100
# 2020-01-22 ETZ ohlcv.xlsx 255168
# 2020-01-19 ENJ ohlcv.xlsx 255325
# 2020-01-25 TMTG ohlcv.xlsx 256057
# 2020-01-16 WOM ohlcv.xlsx 257024
# len(dataX) < 100
# 2020-01-29 PLY ohlcv.xlsx 257024
# len(dataX) < 100
# 2020-01-28 HDAC ohlcv.xlsx 257024
# 2020-01-16 FNB ohlcv.xlsx 258038
# len(dataX) < 100
# 2020-01-24 LAMB ohlcv.xlsx 258038
# 2020-01-15 BCH ohlcv.xlsx 259050
# 2020-01-20 MBL ohlcv.xlsx 260130
# 2020-01-22 FCT ohlcv.xlsx 260297
# len(dataX) < 100
# 2020-01-16 MBL ohlcv.xlsx 260297
# 2020-01-15 BTC ohlcv.xlsx 261579
# 2020-01-12 LAMB ohlcv.xlsx 261690
# 2020-01-14 HYC ohlcv.xlsx 261936
# 2020-01-31 LTC ohlcv.xlsx 262651
# len(dataX) < 100
# 2020-01-31 TRUE ohlcv.xlsx 262651
# 2020-01-21 IPX ohlcv.xlsx 263896
# len(dataX) < 100
# 2020-01-20 RNT ohlcv.xlsx 263896
# 2020-01-20 LUNA ohlcv.xlsx 265032
# 2020-01-31 LUNA ohlcv.xlsx 265985
# len(dataX) < 100
# 2020-01-11 ARN ohlcv.xlsx 265985
# 2020-01-16 IOST ohlcv.xlsx 266305
# len(dataX) < 100
# 2020-01-23 SNT ohlcv.xlsx 266305
# 2020-01-23 BCD ohlcv.xlsx 266832
# 2020-01-16 ORBS ohlcv.xlsx 266958
# 2020-01-25 XLM ohlcv.xlsx 267308
# 2020-01-20 TMTG ohlcv.xlsx 268027
# 2020-01-30 AMO ohlcv.xlsx 268511
# len(dataX) < 100
# 2020-01-29 HDAC ohlcv.xlsx 268511
# len(dataX) < 100
# 2020-01-23 ZEC ohlcv.xlsx 268511
# 2020-01-27 ENJ ohlcv.xlsx 268912
# 2020-01-28 BTC ohlcv.xlsx 270219
# 2020-01-23 CMT ohlcv.xlsx 270353
# len(dataX) < 100
# 2020-01-19 BZNT ohlcv.xlsx 270353
# 2020-01-16 GNT ohlcv.xlsx 270502
# 2020-01-13 OGO ohlcv.xlsx 270828
# 2020-01-31 ETH ohlcv.xlsx 271928
# 2020-01-30 WPX ohlcv.xlsx 272798
# 2020-01-21 BCD ohlcv.xlsx 273409
# len(dataX) < 100
# 2020-01-16 LRC ohlcv.xlsx 273409
# 2020-01-31 MIX ohlcv.xlsx 273585
# 2020-01-29 DAC ohlcv.xlsx 274772
# 2020-01-13 QTUM ohlcv.xlsx 275348
# len(dataX) < 100
# 2020-01-14 ENJ ohlcv.xlsx 275348
# 2020-01-16 CMT ohlcv.xlsx 275574
# 2020-01-24 DAC ohlcv.xlsx 276771
# 2020-01-31 ENJ ohlcv.xlsx 277008
# 2020-01-15 BTG ohlcv.xlsx 277788
# 2020-01-22 WTC ohlcv.xlsx 278274
# 2020-01-21 TRV ohlcv.xlsx 278457
# len(dataX) < 100
# 2020-01-21 WET ohlcv.xlsx 278457
# 2020-01-30 QTUM ohlcv.xlsx 279216
# 2020-01-14 ARN ohlcv.xlsx 279753
# 2020-01-11 PAY ohlcv.xlsx 280055
# len(dataX) < 100
# 2020-01-21 ENJ ohlcv.xlsx 280055
# 2020-01-25 WTC ohlcv.xlsx 280168
# len(dataX) < 100
# 2020-01-23 PPT ohlcv.xlsx 280168
# 2020-01-14 DVP ohlcv.xlsx 280276
# 2020-01-16 PLY ohlcv.xlsx 280714
# 2020-01-11 MIX ohlcv.xlsx 281245
# 2020-01-24 SOC ohlcv.xlsx 282102
# len(dataX) < 100
# 2020-01-22 OMG ohlcv.xlsx 282102
# 2020-01-13 AOA ohlcv.xlsx 282240
# 2020-01-26 SOC ohlcv.xlsx 283381
# 2020-01-22 BSV ohlcv.xlsx 284654
# len(dataX) < 100
# 2020-01-20 LOOM ohlcv.xlsx 284654
# len(dataX) < 100
# 2020-01-23 XEM ohlcv.xlsx 284654
# 2020-01-23 DAC ohlcv.xlsx 285660
# 2020-01-30 BSV ohlcv.xlsx 286922
# len(dataX) < 100
# 2020-01-11 PPT ohlcv.xlsx 286922
# 2020-01-16 BTC ohlcv.xlsx 288236
# 2020-01-21 FX ohlcv.xlsx 288426
# len(dataX) < 100
# 2020-01-22 RNT ohlcv.xlsx 288426
# len(dataX) < 100
# 2020-01-14 STEEM ohlcv.xlsx 288426
# len(dataX) < 100
# 2020-01-25 HYC ohlcv.xlsx 288426
# 2020-01-28 FNB ohlcv.xlsx 288714
# 2020-01-13 LRC ohlcv.xlsx 288837
# 2020-01-13 LINK ohlcv.xlsx 289284
# len(dataX) < 100
# 2020-01-12 WOM ohlcv.xlsx 289284
# 2020-01-29 XLM ohlcv.xlsx 289909
# 2020-01-30 TRX ohlcv.xlsx 290878
# len(dataX) < 100
# 2020-01-26 HDAC ohlcv.xlsx 290878
# 2020-01-28 WPX ohlcv.xlsx 291619
# 2020-01-13 DASH ohlcv.xlsx 292030
# len(dataX) < 100
# 2020-01-12 OMG ohlcv.xlsx 292030
# 2020-01-29 FNB ohlcv.xlsx 292174
# len(dataX) < 100
# 2020-01-25 ZIL ohlcv.xlsx 292174
# len(dataX) < 100
# 2020-01-30 ZRX ohlcv.xlsx 292174
# 2020-01-16 BTG ohlcv.xlsx 293358
# len(dataX) < 100
# 2020-01-31 STRAT ohlcv.xlsx 293358
# 2020-01-16 CTXC ohlcv.xlsx 293592
# len(dataX) < 100
# 2020-01-26 WTC ohlcv.xlsx 293592
# 2020-01-27 ICX ohlcv.xlsx 293934
# 2020-01-16 BTT ohlcv.xlsx 294672
# len(dataX) < 100
# 2020-01-21 ELF ohlcv.xlsx 294672
# 2020-01-16 SOC ohlcv.xlsx 295517
# len(dataX) < 100
# 2020-01-20 HDAC ohlcv.xlsx 295517
# len(dataX) < 100
# 2020-01-24 BAT ohlcv.xlsx 295517
# 2020-01-30 APIS ohlcv.xlsx 295632
# 2020-01-12 LUNA ohlcv.xlsx 296401
# len(dataX) < 100
# 2020-01-22 ORBS ohlcv.xlsx 296401
# 2020-01-11 OGO ohlcv.xlsx 297189
# len(dataX) < 100
# 2020-01-11 ANKR ohlcv.xlsx 297189
# len(dataX) < 100
# 2020-01-15 GXC ohlcv.xlsx 297189
# 2020-01-20 WPX ohlcv.xlsx 297862
# 2020-01-30 MCO ohlcv.xlsx 297992
# 2020-01-29 REP ohlcv.xlsx 298290
# len(dataX) < 100
# 2020-01-15 ZIL ohlcv.xlsx 298290
# len(dataX) < 100
# 2020-01-25 ZEC ohlcv.xlsx 298290
# 2020-01-20 FCT ohlcv.xlsx 298531
# len(dataX) < 100
# 2020-01-24 ZIL ohlcv.xlsx 298531
# 2020-01-25 ETH ohlcv.xlsx 299583
# len(dataX) < 100
# 2020-01-21 ICX ohlcv.xlsx 299583
# len(dataX) < 100
# 2020-01-20 THETA ohlcv.xlsx 299583
# len(dataX) < 100
# 2020-01-15 MIX ohlcv.xlsx 299583
# 2020-01-14 FNB ohlcv.xlsx 300078
# len(dataX) < 100
# 2020-01-15 WET ohlcv.xlsx 300078
# 2020-01-27 ETC ohlcv.xlsx 300613
# 2020-01-21 APIS ohlcv.xlsx 300735
# 2020-01-27 LINK ohlcv.xlsx 300924
# 2020-01-14 BTG ohlcv.xlsx 301182
# 2020-01-11 WOM ohlcv.xlsx 301446
# 2020-01-19 DASH ohlcv.xlsx 301943
# 2020-01-31 FNB ohlcv.xlsx 302874
# len(dataX) < 100
# 2020-01-27 BTT ohlcv.xlsx 302874
# len(dataX) < 100
# 2020-01-20 HYC ohlcv.xlsx 302874
# len(dataX) < 100
# 2020-01-13 OMG ohlcv.xlsx 302874
# 2020-01-16 CON ohlcv.xlsx 303750
# 2020-01-24 FNB ohlcv.xlsx 304202
# 2020-01-20 TRX ohlcv.xlsx 305086
# 2020-01-15 XLM ohlcv.xlsx 305714
# len(dataX) < 100
# 2020-01-19 CHR ohlcv.xlsx 305714
# len(dataX) < 100
# 2020-01-25 FX ohlcv.xlsx 305714
# len(dataX) < 100
# 2020-01-25 HDAC ohlcv.xlsx 305714
# 2020-01-20 VET ohlcv.xlsx 305888
# 2020-01-26 BSV ohlcv.xlsx 307005
# 2020-01-26 FNB ohlcv.xlsx 307550
# len(dataX) < 100
# 2020-01-20 CRO ohlcv.xlsx 307550
# len(dataX) < 100
# 2020-01-29 OMG ohlcv.xlsx 307550
# 2020-01-30 ICX ohlcv.xlsx 307734
# 2020-01-13 ENJ ohlcv.xlsx 307861
# 2020-01-22 XSR ohlcv.xlsx 308575
# 2020-01-16 STRAT ohlcv.xlsx 308830
# len(dataX) < 100
# 2020-01-24 OGO ohlcv.xlsx 308830
# 2020-01-13 MTL ohlcv.xlsx 309147
# 2020-01-28 STEEM ohlcv.xlsx 309262
# 2020-01-23 AMO ohlcv.xlsx 309875
# 2020-01-31 DAD ohlcv.xlsx 310147
# len(dataX) < 100
# 2020-01-24 ITC ohlcv.xlsx 310147
# len(dataX) < 100
# 2020-01-15 ZRX ohlcv.xlsx 310147
# len(dataX) < 100
# 2020-01-30 TRV ohlcv.xlsx 310147
# len(dataX) < 100
# 2020-01-14 KNC ohlcv.xlsx 310147
# 2020-01-19 XRP ohlcv.xlsx 311421
# 2020-01-15 TRX ohlcv.xlsx 312228
# len(dataX) < 100
# 2020-01-21 IOST ohlcv.xlsx 312228
# 2020-01-16 STEEM ohlcv.xlsx 312554
# 2020-01-28 EOS ohlcv.xlsx 313604
# len(dataX) < 100
# 2020-01-20 ITC ohlcv.xlsx 313604
# 2020-01-14 OCN ohlcv.xlsx 314020
# len(dataX) < 100
# 2020-01-22 ENJ ohlcv.xlsx 314020
# len(dataX) < 100
# 2020-01-23 RNT ohlcv.xlsx 314020
# 2020-01-16 WAVES ohlcv.xlsx 314283
# 2020-01-19 XLM ohlcv.xlsx 315268
# len(dataX) < 100
# 2020-01-21 XMR ohlcv.xlsx 315268
# 2020-01-21 FCT ohlcv.xlsx 315517
# 2020-01-24 ETH ohlcv.xlsx 316465
# len(dataX) < 100
# 2020-01-26 PLY ohlcv.xlsx 316465
# 2020-01-23 XLM ohlcv.xlsx 316893
# 2020-01-23 OMG ohlcv.xlsx 317026
# 2020-01-27 VALOR ohlcv.xlsx 317153
# 2020-01-16 FCT ohlcv.xlsx 317776
# len(dataX) < 100
# 2020-01-24 LOOM ohlcv.xlsx 317776
# 2020-01-12 ETH ohlcv.xlsx 318917
# len(dataX) < 100
# 2020-01-15 ANKR ohlcv.xlsx 318917
# 2020-01-16 MCO ohlcv.xlsx 319028
# len(dataX) < 100
# 2020-01-29 FAB ohlcv.xlsx 319028
# 2020-01-21 XRP ohlcv.xlsx 320254
# len(dataX) < 100
# 2020-01-21 LAMB ohlcv.xlsx 320254
# len(dataX) < 100
# 2020-01-30 CHR ohlcv.xlsx 320254
# 2020-01-16 XRP ohlcv.xlsx 321563
# len(dataX) < 100
# 2020-01-23 PLY ohlcv.xlsx 321563
# len(dataX) < 100
# 2020-01-25 HC ohlcv.xlsx 321563
# len(dataX) < 100
# 2020-01-11 HC ohlcv.xlsx 321563
# len(dataX) < 100
# 2020-01-29 SNT ohlcv.xlsx 321563
# len(dataX) < 100
# 2020-01-31 QKC ohlcv.xlsx 321563
# 2020-01-29 ETC ohlcv.xlsx 322681
# 2020-01-27 APIS ohlcv.xlsx 322788
# 2020-01-30 XRP ohlcv.xlsx 323955
# 2020-01-15 PLY ohlcv.xlsx 324185
# len(dataX) < 100
# 2020-01-15 STEEM ohlcv.xlsx 324185
# len(dataX) < 100
# 2020-01-11 ELF ohlcv.xlsx 324185
# 2020-01-13 STEEM ohlcv.xlsx 324334
# 2020-01-22 MXC ohlcv.xlsx 324494
# len(dataX) < 100
# 2020-01-20 CTXC ohlcv.xlsx 324494
# len(dataX) < 100
# 2020-01-13 RNT ohlcv.xlsx 324494
# 2020-01-14 MTL ohlcv.xlsx 324782
# len(dataX) < 100
# 2020-01-28 DAD ohlcv.xlsx 324782
# 2020-01-27 BTC ohlcv.xlsx 325967
# len(dataX) < 100
# 2020-01-30 ORBS ohlcv.xlsx 325967
# len(dataX) < 100
# 2020-01-22 THETA ohlcv.xlsx 325967
# len(dataX) < 100
# 2020-01-14 TRV ohlcv.xlsx 325967
# 2020-01-27 LTC ohlcv.xlsx 326254
# 2020-01-30 ZEC ohlcv.xlsx 326583
# 2020-01-12 EOS ohlcv.xlsx 327747
# 2020-01-12 BSV ohlcv.xlsx 328931
# len(dataX) < 100
# 2020-01-15 ITC ohlcv.xlsx 328931
# len(dataX) < 100
# 2020-01-29 ITC ohlcv.xlsx 328931
# 2020-01-11 LINK ohlcv.xlsx 329377
# 2020-01-25 QTUM ohlcv.xlsx 329848
# len(dataX) < 100
# 2020-01-22 HDAC ohlcv.xlsx 329848
# len(dataX) < 100
# 2020-01-15 NPXS ohlcv.xlsx 329848
# 2020-01-24 WPX ohlcv.xlsx 330798
# 2020-01-11 BHP ohlcv.xlsx 331258
# len(dataX) < 100
# 2020-01-22 DAD ohlcv.xlsx 331258
# 2020-01-19 BTC ohlcv.xlsx 332571
# 2020-01-24 ELF ohlcv.xlsx 332850
# 2020-01-19 ETH ohlcv.xlsx 334086
# 2020-01-15 AOA ohlcv.xlsx 334314
# 2020-01-14 BSV ohlcv.xlsx 335221
# len(dataX) < 100
# 2020-01-13 WET ohlcv.xlsx 335221
# 2020-01-25 STEEM ohlcv.xlsx 335328
# 2020-01-31 WPX ohlcv.xlsx 335974
# 2020-01-15 HYC ohlcv.xlsx 336090
# len(dataX) < 100
# 2020-01-23 FZZ ohlcv.xlsx 336090
# 2020-01-21 CON ohlcv.xlsx 337299
# len(dataX) < 100
# 2020-01-22 SNT ohlcv.xlsx 337299
# 2020-01-29 DASH ohlcv.xlsx 337593
# len(dataX) < 100
# 2020-01-21 XEM ohlcv.xlsx 337593
# 2020-01-22 ETH ohlcv.xlsx 338628
# 2020-01-16 MXC ohlcv.xlsx 338730
# len(dataX) < 100
# 2020-01-27 WAVES ohlcv.xlsx 338730
# 2020-01-31 LBA ohlcv.xlsx 338852
# 2020-01-16 BCH ohlcv.xlsx 340153
# 2020-01-20 STRAT ohlcv.xlsx 340616
# len(dataX) < 100
# 2020-01-21 WOM ohlcv.xlsx 340616
# 2020-01-11 BSV ohlcv.xlsx 341305
# 2020-01-14 AOA ohlcv.xlsx 341523
# 2020-01-22 XRP ohlcv.xlsx 342697
# len(dataX) < 100
# 2020-01-20 IOST ohlcv.xlsx 342697
# 2020-01-27 QTUM ohlcv.xlsx 342982
# 2020-01-25 STRAT ohlcv.xlsx 343106
# 2020-01-25 ADA ohlcv.xlsx 343427
# 2020-01-26 XSR ohlcv.xlsx 344076
# 2020-01-31 WOM ohlcv.xlsx 344585
# 2020-01-22 ADA ohlcv.xlsx 345229
# len(dataX) < 100
# 2020-01-29 VET ohlcv.xlsx 345229
# 2020-01-19 BTT ohlcv.xlsx 345634
# 2020-01-16 OCN ohlcv.xlsx 345870
# 2020-01-30 CON ohlcv.xlsx 346203
# 2020-01-20 BTG ohlcv.xlsx 347241
# len(dataX) < 100
# 2020-01-11 BTT ohlcv.xlsx 347241
# 2020-01-28 MTL ohlcv.xlsx 347484
# 2020-01-31 ETC ohlcv.xlsx 348608
# 2020-01-27 CON ohlcv.xlsx 349270
# 2020-01-28 KNC ohlcv.xlsx 349382
# 2020-01-13 PLY ohlcv.xlsx 350244
# len(dataX) < 100
# 2020-01-27 FAB ohlcv.xlsx 350244
# 2020-01-24 BSV ohlcv.xlsx 351457
# 2020-01-30 INS ohlcv.xlsx 351620
# len(dataX) < 100
# 2020-01-30 LOOM ohlcv.xlsx 351620
# 2020-01-20 INS ohlcv.xlsx 352118
# len(dataX) < 100
# 2020-01-20 XMR ohlcv.xlsx 352118
# len(dataX) < 100
# 2020-01-28 SNT ohlcv.xlsx 352118
# 2020-01-19 WAVES ohlcv.xlsx 352264
# 2020-01-27 BCH ohlcv.xlsx 353115
# 2020-01-29 LUNA ohlcv.xlsx 353483
# 2020-01-27 IPX ohlcv.xlsx 354499
# len(dataX) < 100
# 2020-01-30 LBA ohlcv.xlsx 354499
# 2020-01-29 SOC ohlcv.xlsx 354961
# len(dataX) < 100
# 2020-01-19 ORBS ohlcv.xlsx 354961
# 2020-01-26 XLM ohlcv.xlsx 355177
# 2020-01-11 PLY ohlcv.xlsx 355554
# len(dataX) < 100
# 2020-01-15 LRC ohlcv.xlsx 355554
# 2020-01-14 CON ohlcv.xlsx 356387
# len(dataX) < 100
# 2020-01-24 NPXS ohlcv.xlsx 356387
# 2020-01-23 QTUM ohlcv.xlsx 356976
# 2020-01-16 DAC ohlcv.xlsx 358111
# len(dataX) < 100
# 2020-01-11 WAVES ohlcv.xlsx 358111
# 2020-01-23 XSR ohlcv.xlsx 359016
# len(dataX) < 100
# 2020-01-24 ORBS ohlcv.xlsx 359016
# 2020-01-15 EOS ohlcv.xlsx 360079
# 2020-01-29 TRX ohlcv.xlsx 360906
# 2020-01-24 DAD ohlcv.xlsx 361351
# len(dataX) < 100
# 2020-01-20 KNC ohlcv.xlsx 361351
# 2020-01-28 ZEC ohlcv.xlsx 361543
# 2020-01-20 APIS ohlcv.xlsx 361665
# 2020-01-16 XEM ohlcv.xlsx 361831
# len(dataX) < 100
# 2020-01-28 IOST ohlcv.xlsx 361831
# 2020-01-12 OGO ohlcv.xlsx 361987
# 2020-01-26 TRX ohlcv.xlsx 362335
# len(dataX) < 100
# 2020-01-20 LAMB ohlcv.xlsx 362335
# 2020-01-19 APIS ohlcv.xlsx 362452
# len(dataX) < 100
# 2020-01-12 FX ohlcv.xlsx 362452
# 2020-01-21 SOC ohlcv.xlsx 363713
# 2020-01-30 LUNA ohlcv.xlsx 364214
# 2020-01-11 PCM ohlcv.xlsx 365186
# len(dataX) < 100
# 2020-01-22 ITC ohlcv.xlsx 365186
# 2020-01-12 SOC ohlcv.xlsx 365988
# 2020-01-31 BTG ohlcv.xlsx 366727
# len(dataX) < 100
# 2020-01-23 ICX ohlcv.xlsx 366727
# 2020-01-30 FCT ohlcv.xlsx 367075
# 2020-01-20 BHP ohlcv.xlsx 367395
# 2020-01-24 MXC ohlcv.xlsx 367531
# 2020-01-27 FNB ohlcv.xlsx 367783
# 2020-01-20 BCH ohlcv.xlsx 369008
# len(dataX) < 100
# 2020-01-11 PIVX ohlcv.xlsx 369008
# len(dataX) < 100
# 2020-01-31 ANKR ohlcv.xlsx 369008
# 2020-01-16 AMO ohlcv.xlsx 369719
# 2020-01-24 XLM ohlcv.xlsx 370103
# len(dataX) < 100
# 2020-01-16 RDN ohlcv.xlsx 370103
# len(dataX) < 100
# 2020-01-20 ORBS ohlcv.xlsx 370103
# 2020-01-12 DAC ohlcv.xlsx 371200
# 2020-01-23 LINK ohlcv.xlsx 371524
# 2020-01-27 XLM ohlcv.xlsx 371680
# 2020-01-11 MTL ohlcv.xlsx 371963
# len(dataX) < 100
# 2020-01-19 DVP ohlcv.xlsx 371963
# 2020-01-19 EOS ohlcv.xlsx 373205
# len(dataX) < 100
# 2020-01-26 GXC ohlcv.xlsx 373205
# 2020-01-31 XRP ohlcv.xlsx 374373
# 2020-01-25 DVP ohlcv.xlsx 374590
# len(dataX) < 100
# 2020-01-31 PCM ohlcv.xlsx 374590
# len(dataX) < 100
# 2020-01-14 POWR ohlcv.xlsx 374590
# 2020-01-11 LUNA ohlcv.xlsx 375648
# 2020-01-28 DASH ohlcv.xlsx 375869
# len(dataX) < 100
# 2020-01-30 VALOR ohlcv.xlsx 375869
# 2020-01-24 XRP ohlcv.xlsx 377018
# 2020-01-15 DASH ohlcv.xlsx 377618
# len(dataX) < 100
# 2020-01-29 VALOR ohlcv.xlsx 377618
# 2020-01-24 ENJ ohlcv.xlsx 378107
# 2020-01-15 OCN ohlcv.xlsx 378220
# 2020-01-26 REP ohlcv.xlsx 378910
# 2020-01-16 ICX ohlcv.xlsx 379175
# 2020-01-22 DASH ohlcv.xlsx 379437
# 2020-01-12 ETZ ohlcv.xlsx 380133
# 2020-01-31 BTT ohlcv.xlsx 380398
# len(dataX) < 100
# 2020-01-14 LRC ohlcv.xlsx 380398
# len(dataX) < 100
# 2020-01-14 FX ohlcv.xlsx 380398
# 2020-01-16 PAY ohlcv.xlsx 380549
# 2020-01-19 DAC ohlcv.xlsx 381769
# len(dataX) < 100
# 2020-01-25 MCO ohlcv.xlsx 381769
# len(dataX) < 100
# 2020-01-20 TRUE ohlcv.xlsx 381769
# len(dataX) < 100
# 2020-01-13 WTC ohlcv.xlsx 381769
# 2020-01-22 TMTG ohlcv.xlsx 382771
# len(dataX) < 100
# 2020-01-19 HYC ohlcv.xlsx 382771
# 2020-01-11 TRV ohlcv.xlsx 383063
# len(dataX) < 100
# 2020-01-24 OMG ohlcv.xlsx 383063
# 2020-01-22 REP ohlcv.xlsx 383504
# 2020-01-11 BCD ohlcv.xlsx 384002
# len(dataX) < 100
# 2020-01-22 MCO ohlcv.xlsx 384002
# 2020-01-15 TRV ohlcv.xlsx 384294
# 2020-01-13 IPX ohlcv.xlsx 384866
# 2020-01-28 TMTG ohlcv.xlsx 385753
# 2020-01-20 BTC ohlcv.xlsx 387059
# 2020-01-15 CON ohlcv.xlsx 387955
# len(dataX) < 100
# 2020-01-22 MIX ohlcv.xlsx 387955
# 2020-01-20 QTUM ohlcv.xlsx 388786
# 2020-01-11 BTG ohlcv.xlsx 389163
# len(dataX) < 100
# 2020-01-23 ORBS ohlcv.xlsx 389163
# 2020-01-16 ZRX ohlcv.xlsx 389329
# 2020-01-12 BTG ohlcv.xlsx 390195
# 2020-01-24 ETZ ohlcv.xlsx 390299
# len(dataX) < 100
# 2020-01-14 VET ohlcv.xlsx 390299
# 2020-01-23 DAD ohlcv.xlsx 391074
# 2020-01-16 GXC ohlcv.xlsx 391350
# len(dataX) < 100
# 2020-01-26 BTT ohlcv.xlsx 391350
# 2020-01-30 IPX ohlcv.xlsx 392318
# 2020-01-30 WOM ohlcv.xlsx 392966
# len(dataX) < 100
# 2020-01-26 VALOR ohlcv.xlsx 392966
# 2020-01-12 PCM ohlcv.xlsx 393861
# 2020-01-29 EOS ohlcv.xlsx 395077
# 2020-01-22 BTC ohlcv.xlsx 396378
# 2020-01-29 HYC ohlcv.xlsx 396533
# 2020-01-13 BSV ohlcv.xlsx 397643
# 2020-01-19 STEEM ohlcv.xlsx 398216
# len(dataX) < 100
# 2020-01-21 AE ohlcv.xlsx 398216
# len(dataX) < 100
# 2020-01-21 ZIL ohlcv.xlsx 398216
# len(dataX) < 100
# 2020-01-14 ZRX ohlcv.xlsx 398216
# len(dataX) < 100
# 2020-01-12 GNT ohlcv.xlsx 398216
# len(dataX) < 100
# 2020-01-16 LOOM ohlcv.xlsx 398216
# len(dataX) < 100
# 2020-01-21 VET ohlcv.xlsx 398216
# len(dataX) < 100
# 2020-01-29 ORBS ohlcv.xlsx 398216
# 2020-01-30 XSR ohlcv.xlsx 398972
# 2020-01-29 APIS ohlcv.xlsx 399216
# 2020-01-13 BTC ohlcv.xlsx 400507
# len(dataX) < 100
# 2020-01-31 HC ohlcv.xlsx 400507
# 2020-01-12 APIS ohlcv.xlsx 400643
# len(dataX) < 100
# 2020-01-15 XEM ohlcv.xlsx 400643
# 2020-01-21 MTL ohlcv.xlsx 401004
# 2020-01-27 BTG ohlcv.xlsx 401596
# len(dataX) < 100
# 2020-01-26 PIVX ohlcv.xlsx 401596
# len(dataX) < 100
# 2020-01-25 MIX ohlcv.xlsx 401596
# 2020-01-30 XEM ohlcv.xlsx 401710
# len(dataX) < 100
# 2020-01-20 XVG ohlcv.xlsx 401710
# len(dataX) < 100
# 2020-01-19 POWR ohlcv.xlsx 401710
# len(dataX) < 100
# 2020-01-13 ZIL ohlcv.xlsx 401710
# 2020-01-24 AMO ohlcv.xlsx 402306
# 2020-01-16 MTL ohlcv.xlsx 403080
# 2020-01-14 LINK ohlcv.xlsx 403430
# len(dataX) < 100
# 2020-01-27 OGO ohlcv.xlsx 403430
# 2020-01-31 AOA ohlcv.xlsx 403742
# 2020-01-13 BTT ohlcv.xlsx 403917
# len(dataX) < 100
# 2020-01-13 VET ohlcv.xlsx 403917
# len(dataX) < 100
# 2020-01-20 ICX ohlcv.xlsx 403917
# len(dataX) < 100
# 2020-01-22 WET ohlcv.xlsx 403917
# len(dataX) < 100
# 2020-01-29 POWR ohlcv.xlsx 403917
# 2020-01-10 ETH ohlcv.xlsx 404893
# len(dataX) < 100
# 2020-01-29 ZIL ohlcv.xlsx 404893
# 2020-01-21 ZEC ohlcv.xlsx 405056
# 2020-01-29 AE ohlcv.xlsx 405189
# len(dataX) < 100
# 2020-01-11 MCO ohlcv.xlsx 405189
# len(dataX) < 100
# 2020-01-14 GNT ohlcv.xlsx 405189
# len(dataX) < 100
# 2020-01-16 TRUE ohlcv.xlsx 405189
# len(dataX) < 100
# 2020-01-14 QKC ohlcv.xlsx 405189
# 2020-01-24 TRX ohlcv.xlsx 405731
# len(dataX) < 100
# 2020-01-27 MXC ohlcv.xlsx 405731
# 2020-01-25 AOA ohlcv.xlsx 405994
# 2020-01-28 QTUM ohlcv.xlsx 406498
# 2020-01-25 EOS ohlcv.xlsx 407496
# 2020-01-31 QTUM ohlcv.xlsx 408128
# len(dataX) < 100
# 2020-01-11 LOOM ohlcv.xlsx 408128
# len(dataX) < 100
# 2020-01-21 ETZ ohlcv.xlsx 408128
# len(dataX) < 100
# 2020-01-15 RNT ohlcv.xlsx 408128
# 2020-01-14 TRX ohlcv.xlsx 408711
# 2020-01-20 ETH ohlcv.xlsx 409901
# len(dataX) < 100
# 2020-01-25 BZNT ohlcv.xlsx 409901
# len(dataX) < 100
# 2020-01-29 DAD ohlcv.xlsx 409901
# len(dataX) < 100
# 2020-01-20 MCO ohlcv.xlsx 409901
# 2020-01-23 FAB ohlcv.xlsx 410169
# len(dataX) < 100
# 2020-01-31 WAXP ohlcv.xlsx 410169
# 2020-01-11 ETZ ohlcv.xlsx 410740
# 2020-01-29 CON ohlcv.xlsx 411579
# 2020-01-30 EOS ohlcv.xlsx 412724
# len(dataX) < 100
# 2020-01-27 INS ohlcv.xlsx 412724
# 2020-01-31 XLM ohlcv.xlsx 413301
# len(dataX) < 100
# 2020-01-30 LAMB ohlcv.xlsx 413301
# 2020-01-23 ABT ohlcv.xlsx 413495
# len(dataX) < 100
# 2020-01-22 BHP ohlcv.xlsx 413495
# len(dataX) < 100
# 2020-01-19 RNT ohlcv.xlsx 413495
# 2020-01-24 EOS ohlcv.xlsx 414388
# 2020-01-21 ETC ohlcv.xlsx 415435
# len(dataX) < 100
# 2020-01-29 CTXC ohlcv.xlsx 415435
# 2020-01-16 DASH ohlcv.xlsx 416246
# 2020-01-12 TMTG ohlcv.xlsx 417456
# 2020-01-26 BCH ohlcv.xlsx 418306
# 2020-01-31 CHR ohlcv.xlsx 419385
# 2020-01-21 BZNT ohlcv.xlsx 419588
# 2020-01-19 ETZ ohlcv.xlsx 419765
# 2020-01-23 CON ohlcv.xlsx 420677
# len(dataX) < 100
# 2020-01-31 ELF ohlcv.xlsx 420677
# 2020-01-29 ZEC ohlcv.xlsx 420879
# 2020-01-26 LTC ohlcv.xlsx 421205
# 2020-01-12 DASH ohlcv.xlsx 421398
# len(dataX) < 100
# 2020-01-12 ICX ohlcv.xlsx 421398
# len(dataX) < 100
# 2020-01-21 MCO ohlcv.xlsx 421398
# len(dataX) < 100
# 2020-01-22 FZZ ohlcv.xlsx 421398
# 2020-01-16 ENJ ohlcv.xlsx 421949
# 2020-01-27 ADA ohlcv.xlsx 422181
# len(dataX) < 100
# 2020-01-14 ANKR ohlcv.xlsx 422181
# len(dataX) < 100
# 2020-01-31 IOST ohlcv.xlsx 422181
# len(dataX) < 100
# 2020-01-19 LAMB ohlcv.xlsx 422181
# 2020-01-25 OGO ohlcv.xlsx 422366
# len(dataX) < 100
# 2020-01-16 ANKR ohlcv.xlsx 422366
# 2020-01-11 FCT ohlcv.xlsx 422615
# 2020-01-23 ENJ ohlcv.xlsx 422718
# 2020-01-15 LBA ohlcv.xlsx 422872
# len(dataX) < 100
# 2020-01-15 PPT ohlcv.xlsx 422872
# 2020-01-30 ETC ohlcv.xlsx 424072
# 2020-01-14 BTC ohlcv.xlsx 425350
# len(dataX) < 100
# 2020-01-31 MCO ohlcv.xlsx 425350
# len(dataX) < 100
# 2020-01-22 ICX ohlcv.xlsx 425350
# 2020-01-23 MTL ohlcv.xlsx 425707
# 2020-01-16 BAT ohlcv.xlsx 426103
# 2020-01-11 RNT ohlcv.xlsx 426534
# 2020-01-15 LUNA ohlcv.xlsx 427781
# len(dataX) < 100
# 2020-01-25 THETA ohlcv.xlsx 427781
# 2020-01-15 ABT ohlcv.xlsx 428037
# 2020-01-27 FCT ohlcv.xlsx 428306
# len(dataX) < 100
# 2020-01-28 XEM ohlcv.xlsx 428306
# len(dataX) < 100
# 2020-01-24 XMR ohlcv.xlsx 428306
# 2020-01-12 FNB ohlcv.xlsx 428852
# len(dataX) < 100
# 2020-01-22 NPXS ohlcv.xlsx 428852
# 2020-01-21 XLM ohlcv.xlsx 429534
# len(dataX) < 100
# 2020-01-23 IOST ohlcv.xlsx 429534
# len(dataX) < 100
# 2020-01-24 ZEC ohlcv.xlsx 429534
# 2020-01-16 AOA ohlcv.xlsx 430005
# 2020-01-19 CON ohlcv.xlsx 430848
# 2020-01-23 FNB ohlcv.xlsx 431162
# len(dataX) < 100
# 2020-01-28 ZIL ohlcv.xlsx 431162
# 2020-01-22 ZEC ohlcv.xlsx 431393
# len(dataX) < 100
# 2020-01-14 XVG ohlcv.xlsx 431393
# len(dataX) < 100
# 2020-01-14 ELF ohlcv.xlsx 431393
# len(dataX) < 100
# 2020-01-12 XMR ohlcv.xlsx 431393
# len(dataX) < 100
# 2020-01-30 WTC ohlcv.xlsx 431393
# 2020-01-19 XMR ohlcv.xlsx 431620
# 2020-01-31 STEEM ohlcv.xlsx 431727
# 2020-01-13 ETZ ohlcv.xlsx 432208
# 2020-01-24 ICX ohlcv.xlsx 432327
# 2020-01-30 WAVES ohlcv.xlsx 432563
# len(dataX) < 100
# 2020-01-11 FZZ ohlcv.xlsx 432563
# len(dataX) < 100
# 2020-01-31 ITC ohlcv.xlsx 432563
# 2020-01-12 HYC ohlcv.xlsx 432793
# 2020-01-23 FX ohlcv.xlsx 432957
# 2020-01-20 FNB ohlcv.xlsx 433396
# 2020-01-28 ICX ohlcv.xlsx 434004
# 2020-01-20 DAC ohlcv.xlsx 435247
# 2020-01-26 BTG ohlcv.xlsx 435954
# 2020-01-28 BTG ohlcv.xlsx 437118
# len(dataX) < 100
# 2020-01-21 STRAT ohlcv.xlsx 437118
# len(dataX) < 100
# 2020-01-31 WET ohlcv.xlsx 437118
# 2020-01-21 ETH ohlcv.xlsx 438257
# len(dataX) < 100
# 2020-01-22 WAXP ohlcv.xlsx 438257
# 2020-01-19 XSR ohlcv.xlsx 439103
# 2020-01-21 FNB ohlcv.xlsx 439442
# 2020-01-15 LTC ohlcv.xlsx 440207
# 2020-01-14 DAD ohlcv.xlsx 440453
# 2020-01-21 VALOR ohlcv.xlsx 440782
# 2020-01-11 TRX ohlcv.xlsx 441383
# 2020-01-30 LTC ohlcv.xlsx 442061
# 2020-01-12 RNT ohlcv.xlsx 442327
# 2020-01-25 BCH ohlcv.xlsx 443398
# 2020-01-24 PLY ohlcv.xlsx 443806
# len(dataX) < 100
# 2020-01-26 OGO ohlcv.xlsx 443806
# 2020-01-20 PLY ohlcv.xlsx 443984
# len(dataX) < 100
# 2020-01-26 KNC ohlcv.xlsx 443984
# len(dataX) < 100
# 2020-01-12 BTT ohlcv.xlsx 443984
# 2020-01-19 MIX ohlcv.xlsx 444227
# 2020-01-12 MIX ohlcv.xlsx 444453
# len(dataX) < 100
# 2020-01-29 LAMB ohlcv.xlsx 444453
# 2020-01-11 RDN ohlcv.xlsx 444612
# 2020-01-26 IPX ohlcv.xlsx 445762
# len(dataX) < 100
# 2020-01-31 BAT ohlcv.xlsx 445762
# 2020-01-14 WTC ohlcv.xlsx 445867
# 2020-01-26 LINK ohlcv.xlsx 446117
# 2020-01-23 AE ohlcv.xlsx 446424
# 2020-01-16 INS ohlcv.xlsx 446647
# len(dataX) < 100
# 2020-01-21 SNT ohlcv.xlsx 446647
# len(dataX) < 100
# 2020-01-31 OMG ohlcv.xlsx 446647
# len(dataX) < 100
# 2020-01-21 ORBS ohlcv.xlsx 446647
# len(dataX) < 100
# 2020-01-25 PPT ohlcv.xlsx 446647
# 2020-01-23 TRV ohlcv.xlsx 446997
# len(dataX) < 100
# 2020-01-28 APIS ohlcv.xlsx 446997
# len(dataX) < 100
# 2020-01-31 XVG ohlcv.xlsx 446997
# 2020-01-16 VALOR ohlcv.xlsx 447166
# 2020-01-20 DASH ohlcv.xlsx 447511
# len(dataX) < 100
# 2020-01-20 XEM ohlcv.xlsx 447511
# 2020-01-23 XRP ohlcv.xlsx 448685
# 2020-01-21 LINK ohlcv.xlsx 449174
# len(dataX) < 100
# 2020-01-29 RNT ohlcv.xlsx 449174
# 2020-01-14 BTT ohlcv.xlsx 449362
# 2020-01-14 LUNA ohlcv.xlsx 450229
# 2020-01-15 TMTG ohlcv.xlsx 451176
# len(dataX) < 100
# 2020-01-20 PIVX ohlcv.xlsx 451176
# 2020-01-29 XSR ohlcv.xlsx 452006
# len(dataX) < 100
# 2020-01-31 SNT ohlcv.xlsx 452006
# len(dataX) < 100
# 2020-01-21 OCN ohlcv.xlsx 452006
# 2020-01-29 BTC ohlcv.xlsx 453319
# 2020-01-20 NPXS ohlcv.xlsx 453466
# 2020-01-29 MBL ohlcv.xlsx 454627
# 2020-01-24 DASH ohlcv.xlsx 454734
# 2020-01-25 XEM ohlcv.xlsx 454846
# len(dataX) < 100
# 2020-01-31 GXC ohlcv.xlsx 454846
# 2020-01-16 ZEC ohlcv.xlsx 455478
# 2020-01-20 LTC ohlcv.xlsx 456299
# len(dataX) < 100
# 2020-01-24 MIX ohlcv.xlsx 456299
# 2020-01-31 PAY ohlcv.xlsx 456428
# len(dataX) < 100
# 2020-01-14 IOST ohlcv.xlsx 456428
# 2020-01-29 XRP ohlcv.xlsx 457687
# 2020-01-29 IPX ohlcv.xlsx 458750
# 2020-01-14 IPX ohlcv.xlsx 458947
# 2020-01-25 WAVES ohlcv.xlsx 459133
# len(dataX) < 100
# 2020-01-23 POWR ohlcv.xlsx 459133
# 2020-01-22 ETC ohlcv.xlsx 460030
# 2020-01-13 TRX ohlcv.xlsx 460655
# 2020-01-13 LTC ohlcv.xlsx 461344
# 2020-01-31 TRV ohlcv.xlsx 461529
# len(dataX) < 100
# 2020-01-15 AE ohlcv.xlsx 461529
# 2020-01-12 QTUM ohlcv.xlsx 462119
# 2020-01-19 AOA ohlcv.xlsx 462429
# 2020-01-13 SOC ohlcv.xlsx 462887
# len(dataX) < 100
# 2020-01-12 IOST ohlcv.xlsx 462887
# 2020-01-15 FCT ohlcv.xlsx 463347
# len(dataX) < 100
# 2020-01-26 MCO ohlcv.xlsx 463347
# 2020-01-25 SOC ohlcv.xlsx 463472
# 2020-01-16 TRX ohlcv.xlsx 464671
# 2020-01-26 AOA ohlcv.xlsx 464933
# len(dataX) < 100
# 2020-01-31 HYC ohlcv.xlsx 464933
# len(dataX) < 100
# 2020-01-13 XVG ohlcv.xlsx 464933
# len(dataX) < 100
# 2020-01-24 WOM ohlcv.xlsx 464933
# len(dataX) < 100
# 2020-01-20 WET ohlcv.xlsx 464933
# 2020-01-25 DASH ohlcv.xlsx 465037
# len(dataX) < 100
# 2020-01-22 FX ohlcv.xlsx 465037
# len(dataX) < 100
# 2020-01-31 PIVX ohlcv.xlsx 465037
# 2020-01-19 HDAC ohlcv.xlsx 465144
# 2020-01-20 ENJ ohlcv.xlsx 465306
# 2020-01-29 QTUM ohlcv.xlsx 466011
# 2020-01-25 PLY ohlcv.xlsx 466193
# 2020-01-21 ADA ohlcv.xlsx 466697
# 2020-01-15 ETZ ohlcv.xlsx 466862
# 2020-01-30 SOC ohlcv.xlsx 467576
# 2020-01-13 BHP ohlcv.xlsx 468213
# len(dataX) < 100
# 2020-01-22 ZIL ohlcv.xlsx 468213
# 2020-01-11 BTC ohlcv.xlsx 469521
# len(dataX) < 100
# 2020-01-15 CHR ohlcv.xlsx 469521
# 2020-01-31 REP ohlcv.xlsx 469781
# 2020-01-29 FCT ohlcv.xlsx 470109
# 2020-01-28 FCT ohlcv.xlsx 470313
# 2020-01-29 WPX ohlcv.xlsx 471276
# len(dataX) < 100
# 2020-01-31 XEM ohlcv.xlsx 471276
# 2020-01-14 BCD ohlcv.xlsx 471659
# 2020-01-26 MTL ohlcv.xlsx 471843
# 2020-01-13 ABT ohlcv.xlsx 472144
# len(dataX) < 100
# 2020-01-23 BZNT ohlcv.xlsx 472144
# len(dataX) < 100
# 2020-01-21 CTXC ohlcv.xlsx 472144
# len(dataX) < 100
# 2020-01-15 CTXC ohlcv.xlsx 472144
# 2020-01-26 QTUM ohlcv.xlsx 472528
# 2020-01-14 ETC ohlcv.xlsx 472813
# len(dataX) < 100
# 2020-01-30 ENJ ohlcv.xlsx 472813
# 2020-01-25 INS ohlcv.xlsx 473109
# 2020-01-26 ADA ohlcv.xlsx 473317
# 2020-01-19 OMG ohlcv.xlsx 473712
# len(dataX) < 100
# 2020-01-11 CMT ohlcv.xlsx 473712
# 2020-01-21 AOA ohlcv.xlsx 474018
# len(dataX) < 100
# 2020-01-22 GXC ohlcv.xlsx 474018
# 2020-01-22 AOA ohlcv.xlsx 474285
# 2020-01-14 PLY ohlcv.xlsx 474554
# 2020-01-16 HYC ohlcv.xlsx 474838
# len(dataX) < 100
# 2020-01-15 WOM ohlcv.xlsx 474838
# len(dataX) < 100
# 2020-01-19 KNC ohlcv.xlsx 474838
# 2020-01-22 FNB ohlcv.xlsx 475120
# len(dataX) < 100
# 2020-01-31 WTC ohlcv.xlsx 475120
# 2020-01-19 BCD ohlcv.xlsx 475847
# len(dataX) < 100
# 2020-01-30 FAB ohlcv.xlsx 475847
# 2020-01-25 FNB ohlcv.xlsx 476302
# 2020-01-23 REP ohlcv.xlsx 476500
# 2020-01-11 IPX ohlcv.xlsx 477639
# 2020-01-20 BCD ohlcv.xlsx 478445
# 2020-01-21 REP ohlcv.xlsx 478845
# 2020-01-13 BCH ohlcv.xlsx 479759
# len(dataX) < 100
# 2020-01-13 ZEC ohlcv.xlsx 479759
# 2020-01-19 OCN ohlcv.xlsx 479914
# len(dataX) < 100
# 2020-01-12 XEM ohlcv.xlsx 479914
# 2020-01-16 HC ohlcv.xlsx 480469
# 2020-01-14 SOC ohlcv.xlsx 481084
# len(dataX) < 100
# 2020-01-21 PCM ohlcv.xlsx 481084
# len(dataX) < 100
# 2020-01-11 VALOR ohlcv.xlsx 481084
# 2020-01-16 NPXS ohlcv.xlsx 481295
# 2020-01-25 XSR ohlcv.xlsx 482012
# 2020-01-16 OMG ohlcv.xlsx 482366
# len(dataX) < 100
# 2020-01-19 WICC ohlcv.xlsx 482366
# len(dataX) < 100
# 2020-01-19 PLY ohlcv.xlsx 482366
# len(dataX) < 100
# 2020-01-11 LRC ohlcv.xlsx 482366
# 2020-01-22 BCH ohlcv.xlsx 483450
# 2020-01-21 QTUM ohlcv.xlsx 484085
# 2020-01-15 XSR ohlcv.xlsx 485041
# 2020-01-22 LTC ohlcv.xlsx 485549
# len(dataX) < 100
# 2020-01-22 XEM ohlcv.xlsx 485549
# len(dataX) < 100
# 2020-01-29 WAVES ohlcv.xlsx 485549
# 2020-01-31 BCH ohlcv.xlsx 486614
# len(dataX) < 100
# 2020-01-14 XMR ohlcv.xlsx 486614
# 2020-01-16 TRV ohlcv.xlsx 486798
# len(dataX) < 100
# 2020-01-13 POWR ohlcv.xlsx 486798
# 2020-01-16 XSR ohlcv.xlsx 487658
# 2020-01-11 TMTG ohlcv.xlsx 488857
# 2020-01-22 LINK ohlcv.xlsx 489307
# len(dataX) < 100
# 2020-01-16 QKC ohlcv.xlsx 489307
# 2020-01-30 BCD ohlcv.xlsx 489869
# len(dataX) < 100
# 2020-01-13 WOM ohlcv.xlsx 489869
# 2020-01-15 BCD ohlcv.xlsx 490713
# len(dataX) < 100
# 2020-01-24 AE ohlcv.xlsx 490713
# 2020-01-31 LINK ohlcv.xlsx 491267
# 2020-01-12 ETC ohlcv.xlsx 491913
# 2020-01-31 MTL ohlcv.xlsx 492252
# 2020-01-24 ADA ohlcv.xlsx 492630
# 2020-01-31 APIS ohlcv.xlsx 492730
# 2020-01-21 INS ohlcv.xlsx 492986
# 2020-01-30 AE ohlcv.xlsx 493104
# len(dataX) < 100
# 2020-01-29 TRV ohlcv.xlsx 493104
# len(dataX) < 100
# 2020-01-20 WAXP ohlcv.xlsx 493104
# len(dataX) < 100
# 2020-01-30 DAD ohlcv.xlsx 493104
# 2020-01-25 IPX ohlcv.xlsx 494386
# len(dataX) < 100
# 2020-01-13 MCO ohlcv.xlsx 494386
# len(dataX) < 100
# 2020-01-25 CMT ohlcv.xlsx 494386
# len(dataX) < 100
# 2020-01-25 ITC ohlcv.xlsx 494386
# 2020-01-24 GNT ohlcv.xlsx 494718
# len(dataX) < 100
# 2020-01-25 DAD ohlcv.xlsx 494718
# 2020-01-23 ETZ ohlcv.xlsx 494983
# 2020-01-24 TRV ohlcv.xlsx 495103
# 2020-01-12 WAVES ohlcv.xlsx 495210
# len(dataX) < 100
# 2020-01-21 ZRX ohlcv.xlsx 495210
# len(dataX) < 100
# 2020-01-26 INS ohlcv.xlsx 495210
# len(dataX) < 100
# 2020-01-22 HC ohlcv.xlsx 495210
# 2020-01-16 IPX ohlcv.xlsx 495357
# 2020-01-22 MBL ohlcv.xlsx 496487
# len(dataX) < 100
# 2020-01-20 ETZ ohlcv.xlsx 496487
# 2020-01-15 WAXP ohlcv.xlsx 496673
# 2020-01-21 BCH ohlcv.xlsx 497739
# len(dataX) < 100
# 2020-01-22 POWR ohlcv.xlsx 497739
# 2020-01-16 AE ohlcv.xlsx 498223
# len(dataX) < 100
# 2020-01-16 WICC ohlcv.xlsx 498223
# 2020-01-25 AMO ohlcv.xlsx 498801
# 2020-01-26 WPX ohlcv.xlsx 499099
# 2020-01-11 QTUM ohlcv.xlsx 499500
# len(dataX) < 100
# 2020-01-19 PIVX ohlcv.xlsx 499500
# len(dataX) < 100
# 2020-01-16 THETA ohlcv.xlsx 499500
# 2020-01-23 BTG ohlcv.xlsx 500376
# 2020-01-16 ETC ohlcv.xlsx 501523
# len(dataX) < 100
# 2020-01-20 DVP ohlcv.xlsx 501523
# len(dataX) < 100
# 2020-01-12 PAY ohlcv.xlsx 501523
# len(dataX) < 100
# 2020-01-30 XVG ohlcv.xlsx 501523
# len(dataX) < 100
# 2020-01-20 PCM ohlcv.xlsx 501523
# 2020-01-28 DAC ohlcv.xlsx 502739
# 2020-01-16 ZIL ohlcv.xlsx 503081
# len(dataX) < 100
# 2020-01-28 CTXC ohlcv.xlsx 503081
# len(dataX) < 100
# 2020-01-12 WTC ohlcv.xlsx 503081
# 2020-01-30 LINK ohlcv.xlsx 503544
# 2020-01-21 TRX ohlcv.xlsx 504323
# 2020-01-14 QTUM ohlcv.xlsx 504999
# 2020-01-24 MTL ohlcv.xlsx 505334
# len(dataX) < 100
# 2020-01-14 STRAT ohlcv.xlsx 505334
# 2020-01-12 RDN ohlcv.xlsx 505500
# 2020-01-14 BHP ohlcv.xlsx 506132
# len(dataX) < 100
# 2020-01-25 IOST ohlcv.xlsx 506132
# len(dataX) < 100
# 2020-01-31 AE ohlcv.xlsx 506132
# len(dataX) < 100
# 2020-01-29 HC ohlcv.xlsx 506132
# 2020-01-31 EOS ohlcv.xlsx 507196
# 2020-01-20 FAB ohlcv.xlsx 507715
# 2020-01-13 CON ohlcv.xlsx 508647
# 2020-01-11 FNB ohlcv.xlsx 509103
# 2020-01-19 ELF ohlcv.xlsx 509262
# 2020-01-22 BTT ohlcv.xlsx 509408
# 2020-01-13 RDN ohlcv.xlsx 509541
# len(dataX) < 100
# 2020-01-28 ORBS ohlcv.xlsx 509541
# len(dataX) < 100
# 2020-01-28 WAXP ohlcv.xlsx 509541
# len(dataX) < 100
# 2020-01-23 THETA ohlcv.xlsx 509541
# len(dataX) < 100
# 2020-01-16 BZNT ohlcv.xlsx 509541
# len(dataX) < 100
# 2020-01-20 GXC ohlcv.xlsx 509541
# 2020-01-23 DASH ohlcv.xlsx 509681
# 2020-01-14 FCT ohlcv.xlsx 509831
# len(dataX) < 100
# 2020-01-11 IOST ohlcv.xlsx 509831
# len(dataX) < 100
# 2020-01-15 PCM ohlcv.xlsx 509831
# 2020-01-31 DAC ohlcv.xlsx 511006
# len(dataX) < 100
# 2020-01-26 THETA ohlcv.xlsx 511006
# 2020-01-12 TRV ohlcv.xlsx 511150
# 2020-01-15 IPX ohlcv.xlsx 511379
# 2020-01-19 ADA ohlcv.xlsx 512080
# len(dataX) < 100
# 2020-01-26 MIX ohlcv.xlsx 512080
# 2020-01-22 AMO ohlcv.xlsx 512626
# 2020-01-11 HYC ohlcv.xlsx 512835
# 2020-01-28 BTT ohlcv.xlsx 512988
# len(dataX) < 100
# 2020-01-30 HC ohlcv.xlsx 512988
# len(dataX) < 100
# 2020-01-27 ANKR ohlcv.xlsx 512988
# len(dataX) < 100
# 2020-01-11 WTC ohlcv.xlsx 512988
# 2020-01-14 AMO ohlcv.xlsx 513639
# 2020-01-31 DASH ohlcv.xlsx 513984
# len(dataX) < 100
# 2020-01-21 DVP ohlcv.xlsx 513984
# len(dataX) < 100
# 2020-01-26 DASH ohlcv.xlsx 513984
# len(dataX) < 100
# 2020-01-13 XMR ohlcv.xlsx 513984
# len(dataX) < 100
# 2020-01-13 IOST ohlcv.xlsx 513984
# 2020-01-26 ETC ohlcv.xlsx 514576
# len(dataX) < 100
# 2020-01-30 KNC ohlcv.xlsx 514576
# len(dataX) < 100
# 2020-01-22 LAMB ohlcv.xlsx 514576
# len(dataX) < 100
# 2020-01-15 HDAC ohlcv.xlsx 514576
# len(dataX) < 100
# 2020-01-13 CMT ohlcv.xlsx 514576
# len(dataX) < 100
# 2020-01-19 ITC ohlcv.xlsx 514576
# 2020-01-23 LTC ohlcv.xlsx 514996
# 2020-01-29 BCD ohlcv.xlsx 515811
# len(dataX) < 100
# 2020-01-15 QKC ohlcv.xlsx 515811
# 2020-01-31 BCD ohlcv.xlsx 516304
# 2020-01-29 ETH ohlcv.xlsx 517487
# len(dataX) < 100
# 2020-01-21 THETA ohlcv.xlsx 517487
# 2020-01-19 WPX ohlcv.xlsx 518386
# len(dataX) < 100
# 2020-01-27 GXC ohlcv.xlsx 518386
# len(dataX) < 100
# 2020-01-29 GNT ohlcv.xlsx 518386
# 2020-01-23 MBL ohlcv.xlsx 519459
# 2020-01-12 MTL ohlcv.xlsx 519829
# 2020-01-24 STRAT ohlcv.xlsx 519951
# 2020-01-23 EOS ohlcv.xlsx 520867
# 2020-01-27 MBL ohlcv.xlsx 521979
# 2020-01-15 VET ohlcv.xlsx 522096
# 2020-01-16 FAB ohlcv.xlsx 522287
# 2020-01-31 FAB ohlcv.xlsx 522566
# 2020-01-16 ABT ohlcv.xlsx 522707
# 2020-01-19 MTL ohlcv.xlsx 523351
# len(dataX) < 100
# 2020-01-29 XVG ohlcv.xlsx 523351
# 2020-01-21 MIX ohlcv.xlsx 523588
# len(dataX) < 100
# 2020-01-31 PLY ohlcv.xlsx 523588
# len(dataX) < 100
# 2020-01-21 KNC ohlcv.xlsx 523588
# len(dataX) < 100
# 2020-01-20 PPT ohlcv.xlsx 523588
# 2020-01-21 TMTG ohlcv.xlsx 524476
# 2020-01-22 APIS ohlcv.xlsx 524597
# len(dataX) < 100
# 2020-01-11 ICX ohlcv.xlsx 524597
# len(dataX) < 100
# 2020-01-27 TRV ohlcv.xlsx 524597
# 2020-01-16 ITC ohlcv.xlsx 524785
# 2020-01-13 ARN ohlcv.xlsx 525161
# len(dataX) < 100
# 2020-01-15 XVG ohlcv.xlsx 525161
# len(dataX) < 100
# 2020-01-12 MXC ohlcv.xlsx 525161
# 2020-01-11 EOS ohlcv.xlsx 526142
# len(dataX) < 100
# 2020-01-22 WAVES ohlcv.xlsx 526142
# 2020-01-31 XSR ohlcv.xlsx 527043
# len(dataX) < 100
# 2020-01-15 GNT ohlcv.xlsx 527043
# len(dataX) < 100
# 2020-01-23 HYC ohlcv.xlsx 527043
# 2020-01-19 LINK ohlcv.xlsx 527770
# len(dataX) < 100
# 2020-01-23 ZIL ohlcv.xlsx 527770
# 2020-01-11 DAC ohlcv.xlsx 528185
# 2020-01-24 QTUM ohlcv.xlsx 528706
# len(dataX) < 100
# 2020-01-11 DVP ohlcv.xlsx 528706
# 2020-01-20 EOS ohlcv.xlsx 529824
# 2020-01-19 SOC ohlcv.xlsx 530247
# 2020-01-27 TMTG ohlcv.xlsx 531489
# len(dataX) < 100
# 2020-01-13 PCM ohlcv.xlsx 531489
# 2020-01-23 GXC ohlcv.xlsx 531610
# 2020-01-25 BTT ohlcv.xlsx 531762
# 2020-01-12 PLY ohlcv.xlsx 531978
# len(dataX) < 100
# 2020-01-23 HC ohlcv.xlsx 531978
