# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %matplotlib inline

input_data_length = 30
model_num = 79
num_classes = 3

Made_X = np.load('Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
Made_Y = np.load('Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)


#       dataset 분리      #
# dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
# dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
Made_X = Made_X[:, :,[0,1,2,3,7]]
print(Made_X.shape)
print(Made_Y.shape)

row = Made_X.shape[1]
col = Made_X.shape[2]

from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                   shuffle=False)

X_train = X_train.astype('float32').reshape(-1, input_data_length, col, 1)
X_val = X_val.astype('float32').reshape(-1, input_data_length, col, 1)
print(X_train.shape)
print(X_val.shape)

from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 

# Data Class Weight
from sklearn.utils import class_weight

print(Y_train[:, 0])
class_weights = class_weight.compute_class_weight('balanced', 
                                                  np.unique(Y_train[:, 0]),
                                                  Y_train[:, 0])
class_weights = dict(enumerate(class_weights))
# class_weights[1] *= 0.97
# class_weights[2] *= 0.97
print(class_weights)
# quit()

Y_train = Y_train.astype('float32')
Y_val = Y_val.astype('float32')
Y_train = np_utils.to_categorical(Y_train, num_classes)
Y_val = np_utils.to_categorical(Y_val, num_classes)
print(Y_train.shape)
print(Y_val.shape)

datagen = ImageDataGenerator( 
#     rotation_range = 60,
#     zoom_range = 0.6,
#     shear_range = 0.6,
#     horizontal_flip = True,
#     width_shift_range=0.6,
#     height_shift_range=0.6,
    fill_mode = 'nearest'
    )

testgen = ImageDataGenerator( 
    )
datagen.fit(X_train)
batch_size = 128

for X_batch, _ in datagen.flow(X_train, Y_train, batch_size=9):
    for i in range(0, 9): 
        pyplot.axis('off') 
        pyplot.subplot(330 + 1 + i) 
        pyplot.imshow(X_batch[i].reshape(input_data_length, col), cmap=pyplot.get_cmap('gray'))
    pyplot.axis('off') 
    pyplot.show() 
    break
    
    
train_flow = datagen.flow(X_train, Y_train, batch_size=batch_size) 
val_flow = testgen.flow(X_val, Y_val, batch_size=batch_size) 


from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix

def FER_Model(input_shape=(row, col, 1)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(64, kernel_size=3, padding='same')(visible)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_1 = net

    net = layers.Conv2D(128, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
    
    return model

model = FER_Model()
opt = Adam(lr=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath="model/rapid_ascending %s_%s_obv.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_accuracy', patience=20)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 100
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(X_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(X_val) / batch_size,
                    shuffle=False)
# Out:
# (397691, 30, 5)
# (397691, 1)
# (278383, 30, 5, 1)
# (119308, 30, 5, 1)
# Using TensorFlow backend.
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# [0. 0. 0. ... 0. 0. 0.]
# {0: 0.42926753296417774, 1: 3.023404578826187, 2: 2.9437958674364992}
# (278383, 3)
# (119308, 3)
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 30, 5, 1)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 5, 64)         640
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 30, 5, 64)         0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 2, 64)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 2, 128)        73856
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 15, 2, 128)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 896)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                57408
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 132,099
# Trainable params: 132,099
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/100
#  - 61s - loss: 1.0625 - accuracy: 0.2130 - val_loss: 1.0772 - val_accuracy: 0.1587
#
# Epoch 00001: val_accuracy improved from -inf to 0.15872, saving model to model/rapid_ascending 30_79_obv.hdf5
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/100
#  - 59s - loss: 1.0546 - accuracy: 0.2159 - val_loss: 1.0792 - val_accuracy: 0.2012
#
# Epoch 00002: val_accuracy improved from 0.15872 to 0.20115, saving model to model/rapid_ascending 30_79_obv.hdf5
# Epoch 3/100
#  - 59s - loss: 1.0517 - accuracy: 0.2318 - val_loss: 1.0500 - val_accuracy: 0.2015
#
# Epoch 00003: val_accuracy improved from 0.20115 to 0.20149, saving model to model/rapid_ascending 30_79_obv.hdf5
# Epoch 4/100
#  - 59s - loss: 1.0500 - accuracy: 0.2442 - val_loss: 1.0696 - val_accuracy: 0.2447
#
# Epoch 00004: val_accuracy improved from 0.20149 to 0.24472, saving model to model/rapid_ascending 30_79_obv.hdf5
# Epoch 5/100
#  - 60s - loss: 1.0480 - accuracy: 0.2472 - val_loss: 1.0934 - val_accuracy: 0.1985
#
# Epoch 00005: val_accuracy did not improve from 0.24472
# Epoch 6/100
#  - 60s - loss: 1.0462 - accuracy: 0.2507 - val_loss: 1.1411 - val_accuracy: 0.2692
#
# Epoch 00006: val_accuracy improved from 0.24472 to 0.26919, saving model to model/rapid_ascending 30_79_obv.hdf5
# Epoch 7/100
#  - 59s - loss: 1.0445 - accuracy: 0.2595 - val_loss: 0.9179 - val_accuracy: 0.2017
#
# Epoch 00007: val_accuracy did not improve from 0.26919
# Epoch 8/100
#  - 60s - loss: 1.0429 - accuracy: 0.2647 - val_loss: 1.0544 - val_accuracy: 0.2397
#
# Epoch 00008: val_accuracy did not improve from 0.26919
# Epoch 9/100
#  - 60s - loss: 1.0412 - accuracy: 0.2696 - val_loss: 1.1226 - val_accuracy: 0.2066
#
# Epoch 00009: val_accuracy did not improve from 0.26919
# Epoch 10/100
#  - 59s - loss: 1.0393 - accuracy: 0.2715 - val_loss: 1.1259 - val_accuracy: 0.2573
#
# Epoch 00010: val_accuracy did not improve from 0.26919
# Epoch 11/100
#  - 60s - loss: 1.0373 - accuracy: 0.2734 - val_loss: 1.0447 - val_accuracy: 0.2732
#
# Epoch 00011: val_accuracy improved from 0.26919 to 0.27319, saving model to model/rapid_ascending 30_79_obv.hdf5
# Epoch 12/100
#  - 60s - loss: 1.0354 - accuracy: 0.2801 - val_loss: 1.1494 - val_accuracy: 0.2621
#
# Epoch 00012: val_accuracy did not improve from 0.27319
# Epoch 13/100
#  - 60s - loss: 1.0329 - accuracy: 0.2852 - val_loss: 1.0822 - val_accuracy: 0.2738
#
# Epoch 00013: val_accuracy improved from 0.27319 to 0.27379, saving model to model/rapid_ascending 30_79_obv.hdf5
# Epoch 14/100
#  - 59s - loss: 1.0312 - accuracy: 0.2864 - val_loss: 1.2043 - val_accuracy: 0.2826
#
# Epoch 00014: val_accuracy improved from 0.27379 to 0.28258, saving model to model/rapid_ascending 30_79_obv.hdf5
# Epoch 15/100
#  - 60s - loss: 1.0287 - accuracy: 0.2929 - val_loss: 1.1252 - val_accuracy: 0.3284
#
# Epoch 00015: val_accuracy improved from 0.28258 to 0.32841, saving model to model/rapid_ascending 30_79_obv.hdf5
# Epoch 16/100
#  - 60s - loss: 1.0262 - accuracy: 0.2967 - val_loss: 1.0709 - val_accuracy: 0.3153
#
# Epoch 00016: val_accuracy did not improve from 0.32841
# Epoch 17/100
#  - 59s - loss: 1.0234 - accuracy: 0.3013 - val_loss: 1.0536 - val_accuracy: 0.2553
#
# Epoch 00017: val_accuracy did not improve from 0.32841
# Epoch 18/100
#  - 60s - loss: 1.0208 - accuracy: 0.3037 - val_loss: 1.0293 - val_accuracy: 0.3303
#
# Epoch 00018: val_accuracy improved from 0.32841 to 0.33032, saving model to model/rapid_ascending 30_79_obv.hdf5
# Epoch 19/100
#  - 60s - loss: 1.0178 - accuracy: 0.3082 - val_loss: 1.0622 - val_accuracy: 0.3056
#
# Epoch 00019: val_accuracy did not improve from 0.33032
# Epoch 20/100
#  - 59s - loss: 1.0147 - accuracy: 0.3095 - val_loss: 1.0935 - val_accuracy: 0.3736
#
# Epoch 00020: val_accuracy improved from 0.33032 to 0.37358, saving model to model/rapid_ascending 30_79_obv.hdf5
# Epoch 21/100
#  - 59s - loss: 1.0124 - accuracy: 0.3129 - val_loss: 1.1874 - val_accuracy: 0.3259
#
# Epoch 00021: val_accuracy did not improve from 0.37358
# Epoch 22/100
#  - 59s - loss: 1.0093 - accuracy: 0.3174 - val_loss: 1.0794 - val_accuracy: 0.2832
#
# Epoch 00022: val_accuracy did not improve from 0.37358
# Epoch 23/100
#  - 59s - loss: 1.0062 - accuracy: 0.3203 - val_loss: 1.0161 - val_accuracy: 0.3050
#
# Epoch 00023: val_accuracy did not improve from 0.37358
# Epoch 24/100
#  - 60s - loss: 1.0030 - accuracy: 0.3258 - val_loss: 1.1555 - val_accuracy: 0.3030
#
# Epoch 00024: val_accuracy did not improve from 0.37358
# Epoch 25/100
#  - 59s - loss: 0.9997 - accuracy: 0.3275 - val_loss: 1.1838 - val_accuracy: 0.2929
#
# Epoch 00025: val_accuracy did not improve from 0.37358
# Epoch 26/100
#  - 60s - loss: 0.9968 - accuracy: 0.3293 - val_loss: 1.0174 - val_accuracy: 0.2574
#
# Epoch 00026: val_accuracy did not improve from 0.37358
# Epoch 27/100
#  - 59s - loss: 0.9941 - accuracy: 0.3332 - val_loss: 1.0249 - val_accuracy: 0.2810
#
# Epoch 00027: val_accuracy did not improve from 0.37358
# Epoch 28/100
#  - 59s - loss: 0.9908 - accuracy: 0.3376 - val_loss: 1.0691 - val_accuracy: 0.2713
#
# Epoch 00028: val_accuracy did not improve from 0.37358
# Epoch 29/100
#  - 60s - loss: 0.9875 - accuracy: 0.3389 - val_loss: 1.0129 - val_accuracy: 0.2607
#
# Epoch 00029: val_accuracy did not improve from 0.37358
# Epoch 30/100
#  - 60s - loss: 0.9844 - accuracy: 0.3421 - val_loss: 1.0712 - val_accuracy: 0.2802
#
# Epoch 00030: val_accuracy did not improve from 0.37358
# Epoch 31/100
#  - 59s - loss: 0.9818 - accuracy: 0.3444 - val_loss: 1.0624 - val_accuracy: 0.2931
# Epoch 00031: val_accuracy did not improve from 0.37358
# Epoch 32/100
#  - 60s - loss: 0.9790 - accuracy: 0.3470 - val_loss: 1.2098 - val_accuracy: 0.3668
#
# Epoch 00032: val_accuracy did not improve from 0.37358
# Epoch 33/100
#  - 59s - loss: 0.9755 - accuracy: 0.3517 - val_loss: 1.1511 - val_accuracy: 0.2948
#
# Epoch 00033: val_accuracy did not improve from 0.37358
# Epoch 34/100
#  - 59s - loss: 0.9728 - accuracy: 0.3533 - val_loss: 1.0047 - val_accuracy: 0.3163
#
# Epoch 00034: val_accuracy did not improve from 0.37358
# Epoch 35/100
#  - 60s - loss: 0.9700 - accuracy: 0.3538 - val_loss: 1.1892 - val_accuracy: 0.3254
#
# Epoch 00035: val_accuracy did not improve from 0.37358
# Epoch 36/100
#  - 60s - loss: 0.9665 - accuracy: 0.3578 - val_loss: 1.0012 - val_accuracy: 0.2947
#
# Epoch 00036: val_accuracy did not improve from 0.37358
# Epoch 37/100
#  - 60s - loss: 0.9642 - accuracy: 0.3599 - val_loss: 1.2008 - val_accuracy: 0.3304
#
# Epoch 00037: val_accuracy did not improve from 0.37358
# Epoch 38/100
#  - 59s - loss: 0.9610 - accuracy: 0.3619 - val_loss: 1.3190 - val_accuracy: 0.3267
#
# Epoch 00038: val_accuracy did not improve from 0.37358
# Epoch 39/100
#  - 59s - loss: 0.9582 - accuracy: 0.3639 - val_loss: 1.0810 - val_accuracy: 0.2969
#
# Epoch 00039: val_accuracy did not improve from 0.37358
# Epoch 40/100
#  - 60s - loss: 0.9554 - accuracy: 0.3660 - val_loss: 1.2576 - val_accuracy: 0.2821
#
# Epoch 00040: val_accuracy did not improve from 0.37358

# %%
from keras.models import load_model

model = load_model('model/rapid_ascending %s_%s.hdf5' % (input_data_length, model_num))
# model = load_model('/content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending %s.hdf5' % input_data_length)
# loss = model.evaluate_generator(test_flow, steps=len(X_test) / batch_size) 
# print("Test Loss " + str(loss[0]))
# print("Test Acc: " + str(loss[1]))

# loss = model.evaluate(X_val, Y_val) 
# print(X_val.shape)
# print(Y_val.shape)

# print("Val Loss " + str(loss[0]))
# print("Val Acc: " + str(loss[1]))

#     Prediction    #
Y_pred_ = model.predict(X_test, verbose=1)

# Y_pred = Y_pred_[:,[-1]]
# print(Y_pred.shape)
# print(Y_test.shape)
Y_pred = np.argmax(Y_pred_, axis=1)
t_te = np.argmax(Y_test, axis=1)

#     Manual processing     #
Y_pred_one = Y_pred_[:, [-1]]
print(Y_pred_)
max_value = np.max(Y_pred_one)
print(max_value)

limit_line = 0.9
Y_pred_one = np.where(Y_pred_one > max_value * limit_line, 1, 0)

# print(Y_pred_one)
Y_pred_one = Y_pred_one.reshape(-1,)
# print(Y_pred_1)
# print(Y_pred.shape)
# print(t_te.shape)

# fail = 0
# fail2 = 0
# for i in range(len(Y_pred)):
#   if Y_pred_1[i] != t_te[i]:
#     fail += 1

#   if Y_pred[i] != t_te[i]:
#     fail2 += 1

# print(1 - fail / len(Y_pred))
# print(1 - fail2 / len(Y_pred))

# print(np.sum(Y_pred), np.sum(t_te))
# print('Y_pred / Y_test :', np.sum(Y_pred) / np.sum(t_te))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(100,10))
plt.subplot(211)
plt.plot(Y_test, 'purple', label='test')

plt.subplot(212)
plt.plot(Y_pred_one, 'y', label='pred')
plt.show()
# plt.savefig('/content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending %s.png' % input_data_length)
# plt.close()
