# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np
import pandas as pd
from keras.models import load_model
from matplotlib import pyplot as plt
import os
from Make_X2 import made_x
from keras.utils import np_utils
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'


dir = 'ohlcv/'
ohlcv_list = os.listdir(dir)

if __name__ == '__main__':

    #           PARAMS           #
    input_data_length = 54
    # model_num = input('Press model num : ')
    model_num = 23
    crop_size = 500
    crop_size2 = 100
    limit_line = 0.9
    limit_line2 = 0.8
    check_span = 30
    get_fig = 1

    #       Make folder      #
    try:
        os.mkdir('./pred_ohlcv/%s_%s/' % (input_data_length, model_num))
    except Exception as e:
        pass

    try:
        os.mkdir('./Figure_pred/%s_%s/' % (input_data_length, model_num))
    except Exception as e:
        pass

    except_list = os.listdir('./pred_ohlcv/%s_%s' % (input_data_length, model_num))

    #       LOAD MODEL      #
    model = load_model('./model/rapid_ascending %s_%s - 4.39.hdf5' % (input_data_length, model_num))

    for file in ohlcv_list:

        #         if file in except_list:
        #             continue

        print('loading %s' % file)

        try:
            X_test, _, sliced_ohlc = made_x(file, input_data_length, model_num, check_span, 0, crop_size=crop_size, sudden_death=0.)
            X_test2, _, sliced_ohlc2 = made_x(file, input_data_length, model_num, check_span, 0, crop_size=crop_size2, sudden_death=0.)
            # X_test, _ = low_high(Coin, input_data_length, sudden_death=1.)
            # closeprice = np.roll(np.array(list(map(lambda x: x[-1][[1]][0], X_test))), -1)

            if X_test is None:
                continue

        except Exception as e:
            print('Error in getting data from made_x :', e)

        # OBV = np.roll(np.array(list(map(lambda x: x[-1][[5]][0], X_test))), -1)

        # dataX 에 담겨있는 value 에 [-1] : 바로 이전의 행 x[-1][:].shape = (1, 6)
        # sliced_ohlcv = np.array(list(map(lambda x: x[-1][:], X_test)))
        # print(sliced_ohlcv)
        # quit()

        if len(X_test) != 0:

            Y_pred_ = model.predict(X_test, verbose=1)
            Y_pred2_ = model.predict(X_test2, verbose=1)

            max_value = np.max(Y_pred_, axis=0)
            max_value2 = np.max(Y_pred2_, axis=0)
            Y_pred = np.zeros(len(Y_pred_))
            Y_pred2 = np.zeros(len(Y_pred2_))
            for i in range(len(Y_pred_)):
                if Y_pred_[i][1] > max_value[1] * limit_line:
                    Y_pred[i] = 1
                elif Y_pred_[i][2] > max_value[2] * limit_line:
                    Y_pred[i] = 2
            for i in range(len(Y_pred2_)):
                if Y_pred2_[i][1] > max_value2[1] * limit_line2:
                    Y_pred2[i] = 1
                elif Y_pred2_[i][2] > max_value2[2] * limit_line2:
                    Y_pred2[i] = 2

            #       Save Pred_ohlcv      #
            #   기존에 pybithumb 을 통해서 제공되던 ohlcv 와는 조금 다르다 >> 이전 데이터와 현재 y 데이터 행이 같다.
            sliced_Y = Y_pred.reshape(-1, 1)
            sliced_Y2 = Y_pred2.reshape(-1, 1)[-len(sliced_Y):]
            pred_ohlcv = np.concatenate((sliced_ohlc, sliced_Y, sliced_Y2), axis=1)  # axis=1 가로로 합친다

            #   col 이 7이 아닌 데이터 걸러주기
            try:
                pred_ohlcv_df = pd.DataFrame(pred_ohlcv,
                                             columns=['open', 'close', 'high', 'low', 'low_state', 'high_state'])

            except Exception as e:
                print(e)
                continue
            # print(pred_ohlcv_df.tail(20))
            # quit()
            pred_ohlcv_df.to_excel('./pred_ohlcv/%s_%s/%s' % (input_data_length, model_num, file))

            # Y_pred 에 1 이 존재하면, Plot Comparing
            if get_fig == 1:

                spanlist_low = []
                spanlist_high = []

                for m in range(len(Y_pred)):
                    if (Y_pred[m] > 0.5) and (Y_pred[m] < 1.5):
                        if m + 1 < len(Y_pred):
                            spanlist_low.append((m, m + 1))
                        else:
                            spanlist_low.append((m - 1, m))

                for m in range(len(Y_pred)):
                    if (Y_pred[m] > 1.5) and (Y_pred[m] < 2.5):
                        if m + 1 < len(Y_pred):
                            spanlist_high.append((m, m + 1))
                        else:
                            spanlist_high.append((m - 1, m))

                plt.subplot(211)
                # plt.subplot(313)
                plt.plot(sliced_ohlc[:, [1]], 'r', label='close')
                # plt.plot(OBV, 'b', label='OBV')
                plt.legend(loc='upper right')
                for i in range(len(spanlist_low)):
                    plt.axvspan(spanlist_low[i][0], spanlist_low[i][1], facecolor='c', alpha=0.5)

                plt.subplot(212)
                # plt.subplot(313)
                plt.plot(sliced_ohlc2[:, [1]], 'r', label='close')
                # plt.plot(OBV, 'b', label='OBV')
                plt.legend(loc='upper right')
                for i in range(len(spanlist_high)):
                    plt.axvspan(spanlist_high[i][0], spanlist_high[i][1], facecolor='m', alpha=0.5)

                Date = file.split()[0]
                Coin = file.split()[1].split('.')[0]
                plt.savefig('./Figure_pred/%s_%s/%s %s.png' % (input_data_length, model_num, Date, Coin), dpi=500)
                plt.close()
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# loading 2020-01-16 XLM ohlcv.xlsx
# 560/560 [==============================] - 2s 4ms/step
# 960/960 [==============================] - 0s 68us/step
# loading 2020-01-23 TRX ohlcv.xlsx
# 280/280 [==============================] - 0s 128us/step
# 680/680 [==============================] - 0s 78us/step
# loading 2020-01-16 SNT ohlcv.xlsx
# loading 2020-01-19 LBA ohlcv.xlsx
# loading 2019-10-20 CHR ohlcv.xlsx
# loading 2020-01-11 FX ohlcv.xlsx
# loading 2020-01-22 LUNA ohlcv.xlsx
# 879/879 [==============================] - 0s 76us/step
# 1279/1279 [==============================] - 0s 88us/step
# loading 2020-01-16 LINK ohlcv.xlsx
# 551/551 [==============================] - 0s 90us/step
# 951/951 [==============================] - 0s 92us/step
# loading 2019-10-25 FAB ohlcv.xlsx
# loading 2020-01-13 FCT ohlcv.xlsx
# loading 2020-01-20 IPX ohlcv.xlsx
# 909/909 [==============================] - 0s 79us/step
# 1309/1309 [==============================] - 0s 83us/step
# loading 2020-01-14 FZZ ohlcv.xlsx
# loading 2020-01-24 BZNT ohlcv.xlsx
# loading 2020-01-20 SNT ohlcv.xlsx
# loading 2019-11-02 PAY ohlcv.xlsx
# loading 2019-10-26 CRO ohlcv.xlsx
# loading 2019-11-13 DVP ohlcv.xlsx
# loading 2020-01-25 VET ohlcv.xlsx
# loading 2019-11-02 IOST ohlcv.xlsx
# loading 2019-10-28 FNB ohlcv.xlsx
# 583/583 [==============================] - 0s 68us/step
# 983/983 [==============================] - 0s 65us/step
# loading 2020-01-21 EOS ohlcv.xlsx
# 717/717 [==============================] - 0s 65us/step
# 1117/1117 [==============================] - 0s 63us/step
# loading 2020-01-24 FAB ohlcv.xlsx
# loading 2020-01-22 TRV ohlcv.xlsx
# loading 2019-11-14 QTUM ohlcv.xlsx
# 171/171 [==============================] - 0s 167us/step
# 571/571 [==============================] - 0s 95us/step
# loading 2019-10-22 XMR ohlcv.xlsx
# loading 2020-01-13 MBL ohlcv.xlsx
# loading 2020-01-26 DVP ohlcv.xlsx
# loading 2020-01-22 MTL ohlcv.xlsx
# loading 2020-01-12 POWR ohlcv.xlsx
# loading 2019-11-20 LBA ohlcv.xlsx
# 164/164 [==============================] - 0s 150us/step
# 564/564 [==============================] - 0s 91us/step
# loading 2019-10-30 LTC ohlcv.xlsx
# 327/327 [==============================] - 0s 86us/step
# 727/727 [==============================] - 0s 55us/step
# loading 2019-10-31 FX ohlcv.xlsx
# loading 2019-10-16 STRAT ohlcv.xlsx
# loading 2020-01-12 MCO ohlcv.xlsx
# loading 2020-01-20 CMT ohlcv.xlsx
# loading 2020-01-22 BTG ohlcv.xlsx
# 564/564 [==============================] - 0s 61us/step
# 964/964 [==============================] - 0s 53us/step
# loading 2020-01-13 DAC ohlcv.xlsx
# 827/827 [==============================] - 0s 61us/step
# 1227/1227 [==============================] - 0s 65us/step
# loading 2020-01-13 INS ohlcv.xlsx
# loading 2020-01-25 REP ohlcv.xlsx
# loading 2020-01-11 APIS ohlcv.xlsx
# loading 2020-01-26 LRC ohlcv.xlsx
# loading 2020-01-26 XRP ohlcv.xlsx
# 623/623 [==============================] - 0s 55us/step
# 1023/1023 [==============================] - 0s 62us/step
# loading 2020-01-13 ELF ohlcv.xlsx
# loading 2020-01-13 APIS ohlcv.xlsx
# loading 2019-11-24 TRUE ohlcv.xlsx
# loading 2019-10-26 WTC ohlcv.xlsx
# loading 2019-10-31 ICX ohlcv.xlsx
# loading 2019-10-10 CHR ohlcv.xlsx
# loading 2020-01-16 ETH ohlcv.xlsx
# 882/882 [==============================] - 0s 85us/step
# 1282/1282 [==============================] - 0s 76us/step
# loading 2020-01-22 STRAT ohlcv.xlsx
# loading 2020-01-12 BCH ohlcv.xlsx
# 693/693 [==============================] - 0s 87us/step
# 1093/1093 [==============================] - 0s 72us/step
# loading 2019-10-21 TRUE ohlcv.xlsx
# loading 2020-01-22 ZRX ohlcv.xlsx
# loading 2020-01-24 PAY ohlcv.xlsx
# loading 2020-01-11 ETH ohlcv.xlsx
# 623/623 [==============================] - 0s 59us/step
# 1023/1023 [==============================] - 0s 55us/step
# loading 2019-11-15 CTXC ohlcv.xlsx
# 664/664 [==============================] - 0s 55us/step
# 1064/1064 [==============================] - 0s 54us/step
# loading 2019-11-01 FX ohlcv.xlsx
# loading 2019-10-25 CHR ohlcv.xlsx
# loading 2020-01-26 TMTG ohlcv.xlsx
# 735/735 [==============================] - 0s 53us/step
# 1135/1135 [==============================] - 0s 64us/step
# loading 2020-01-19 RDN ohlcv.xlsx
# loading 2020-01-21 MXC ohlcv.xlsx
# loading 2020-01-19 ICX ohlcv.xlsx
# loading 2019-11-02 CMT ohlcv.xlsx
# loading 2019-10-27 LBA ohlcv.xlsx
# loading 2020-01-15 SNT ohlcv.xlsx
# loading 2020-01-16 POWR ohlcv.xlsx
# loading 2020-01-16 BCD ohlcv.xlsx
# 735/735 [==============================] - 0s 58us/step
# 1135/1135 [==============================] - 0s 66us/step
# loading 2020-01-12 BCD ohlcv.xlsx
# 261/261 [==============================] - 0s 71us/step
# 661/661 [==============================] - 0s 61us/step
# loading 2020-01-23 APIS ohlcv.xlsx
# loading 2019-10-26 PLY ohlcv.xlsx
# 546/546 [==============================] - 0s 57us/step
# 946/946 [==============================] - 0s 60us/step
# loading 2020-01-15 OMG ohlcv.xlsx
# loading 2019-10-26 BCH ohlcv.xlsx
# 851/851 [==============================] - 0s 78us/step
# 1251/1251 [==============================] - 0s 76us/step
# loading 2019-10-22 BSV ohlcv.xlsx
# 598/598 [==============================] - 0s 91us/step
# 998/998 [==============================] - 0s 73us/step
# loading 2020-01-25 PAY ohlcv.xlsx
# loading 2019-10-27 POLY ohlcv.xlsx
# loading 2020-01-20 BSV ohlcv.xlsx
# 865/865 [==============================] - 0s 76us/step
# 1265/1265 [==============================] - 0s 80us/step
# loading 2020-01-16 XMR ohlcv.xlsx
# loading 2019-10-31 MCO ohlcv.xlsx
# loading 2019-10-25 GXC ohlcv.xlsx
# loading 2020-01-22 AE ohlcv.xlsx
# loading 2019-11-02 LOOM ohlcv.xlsx
# loading 2020-01-23 BAT ohlcv.xlsx
# loading 2019-11-20 CTXC ohlcv.xlsx
# 283/283 [==============================] - 0s 61us/step
# 683/683 [==============================] - 0s 61us/step
# loading 2020-01-24 FX ohlcv.xlsx
# loading 2019-11-12 LRC ohlcv.xlsx
# loading 2020-01-20 CHR ohlcv.xlsx
# loading 2019-10-29 GTO ohlcv.xlsx
# loading 2019-10-31 BHP ohlcv.xlsx
# 285/285 [==============================] - 0s 62us/step
# 685/685 [==============================] - 0s 56us/step
# loading 2019-10-30 RNT ohlcv.xlsx
# loading 2019-10-26 LTC ohlcv.xlsx
# 454/454 [==============================] - 0s 63us/step
# 854/854 [==============================] - 0s 56us/step
# loading 2019-10-18 WET ohlcv.xlsx
# loading 2020-01-14 ETH ohlcv.xlsx
# 556/556 [==============================] - 0s 95us/step
# 956/956 [==============================] - 0s 76us/step
# loading 2019-11-24 VET ohlcv.xlsx
# loading 2020-01-11 ABT ohlcv.xlsx
# loading 2020-01-23 ETH ohlcv.xlsx
# 624/624 [==============================] - 0s 57us/step
# 1024/1024 [==============================] - 0s 59us/step
# loading 2020-01-16 CHR ohlcv.xlsx
# loading 2020-01-25 CON ohlcv.xlsx
# 354/354 [==============================] - 0s 65us/step
# 754/754 [==============================] - 0s 69us/step
# loading 2020-01-16 APIS ohlcv.xlsx
# loading 2020-01-19 CRO ohlcv.xlsx
# loading 2019-10-14 XVG ohlcv.xlsx
# loading 2020-01-22 BZNT ohlcv.xlsx
# loading 2020-01-26 FAB ohlcv.xlsx
# loading 2020-01-23 INS ohlcv.xlsx
# loading 2020-01-14 ETZ ohlcv.xlsx
# loading 2020-01-23 MCO ohlcv.xlsx
# loading 2019-10-29 KNC ohlcv.xlsx
# loading 2020-01-19 FNB ohlcv.xlsx
# loading 2019-10-20 ZRX ohlcv.xlsx
# loading 2019-10-27 XVG ohlcv.xlsx
# loading 2020-01-19 PAY ohlcv.xlsx
# loading 2019-10-27 CRO ohlcv.xlsx
# loading 2020-01-12 XVG ohlcv.xlsx
# loading 2019-10-27 POWR ohlcv.xlsx
# loading 2020-01-20 MIX ohlcv.xlsx
# loading 2019-11-15 ITC ohlcv.xlsx
# 335/335 [==============================] - 0s 62us/step
# 735/735 [==============================] - 0s 62us/step
# loading 2020-01-26 WET ohlcv.xlsx
# Error in getting data from made_x : 'NoneType' object is not iterable
# 335/335 [==============================] - 0s 59us/step
# 735/735 [==============================] - 0s 68us/step
# loading 2019-11-01 GXC ohlcv.xlsx
# loading 2019-10-29 LBA ohlcv.xlsx
# loading 2020-01-24 STEEM ohlcv.xlsx
# loading 2020-01-13 AMO ohlcv.xlsx
# 258/258 [==============================] - 0s 69us/step
# 658/658 [==============================] - 0s 64us/step
# loading 2020-01-21 BTG ohlcv.xlsx
# 370/370 [==============================] - 0s 76us/step
# 770/770 [==============================] - 0s 63us/step
# loading 2019-10-25 MCO ohlcv.xlsx
# loading 2020-01-24 REP ohlcv.xlsx
# loading 2019-10-21 BTC ohlcv.xlsx
# 906/906 [==============================] - 0s 76us/step
# 1306/1306 [==============================] - 0s 83us/step
# loading 2020-01-14 PPT ohlcv.xlsx
# loading 2019-10-31 BTC ohlcv.xlsx
# 909/909 [==============================] - 0s 60us/step
# 1309/1309 [==============================] - 0s 62us/step
# loading 2020-01-26 ETH ohlcv.xlsx
# 354/354 [==============================] - 0s 61us/step
# 754/754 [==============================] - 0s 77us/step
# loading 2020-01-11 XSR ohlcv.xlsx
# 755/755 [==============================] - 0s 55us/step
# 1155/1155 [==============================] - 0s 62us/step
# loading 2020-01-16 OGO ohlcv.xlsx
# loading 2019-11-13 PST ohlcv.xlsx
# loading 2020-01-24 BHP ohlcv.xlsx
# loading 2020-01-12 LTC ohlcv.xlsx
# 265/265 [==============================] - 0s 118us/step
# 665/665 [==============================] - 0s 93us/step
# loading 2020-01-12 INS ohlcv.xlsx
# loading 2019-10-31 GXC ohlcv.xlsx
# loading 2020-01-14 SNT ohlcv.xlsx
# loading 2020-01-23 CHR ohlcv.xlsx
# loading 2019-10-26 QTUM ohlcv.xlsx
# 371/371 [==============================] - 0s 65us/step
# 771/771 [==============================] - 0s 67us/step
# loading 2020-01-23 ETC ohlcv.xlsx
# 324/324 [==============================] - 0s 64us/step
# 724/724 [==============================] - 0s 62us/step
# loading 2020-01-14 ORBS ohlcv.xlsx
# loading 2020-01-19 STRAT ohlcv.xlsx
# loading 2020-01-24 VALOR ohlcv.xlsx
# loading 2020-01-26 APIS ohlcv.xlsx
# loading 2019-11-20 WOM ohlcv.xlsx
# loading 2019-10-29 VET ohlcv.xlsx
# loading 2020-01-14 OGO ohlcv.xlsx
# loading 2019-10-30 CMT ohlcv.xlsx
# 440/440 [==============================] - 0s 68us/step
# 840/840 [==============================] - 0s 59us/step
# loading 2020-01-16 PCM ohlcv.xlsx
# loading 2019-10-16 LOOM ohlcv.xlsx
# loading 2020-01-22 WOM ohlcv.xlsx
# loading 2020-01-14 CHR ohlcv.xlsx
# loading 2020-01-26 MBL ohlcv.xlsx
# 787/787 [==============================] - 0s 65us/step
# 1187/1187 [==============================] - 0s 80us/step
# loading 2020-01-23 WAXP ohlcv.xlsx
# loading 2020-01-26 FCT ohlcv.xlsx
# loading 2020-01-15 ICX ohlcv.xlsx
# loading 2020-01-25 MXC ohlcv.xlsx
# loading 2019-10-30 VET ohlcv.xlsx
# loading 2020-01-21 RDN ohlcv.xlsx
# loading 2020-01-23 BTT ohlcv.xlsx
# loading 2020-01-13 WAXP ohlcv.xlsx
# loading 2020-01-22 TRUE ohlcv.xlsx
# loading 2020-01-13 XLM ohlcv.xlsx
# loading 2020-01-20 ADA ohlcv.xlsx
# 131/131 [==============================] - 0s 80us/step
# 531/531 [==============================] - 0s 59us/step
# loading 2019-10-29 BTG ohlcv.xlsx
# loading 2019-10-31 CRO ohlcv.xlsx
# loading 2020-01-16 ADA ohlcv.xlsx
# 520/520 [==============================] - 0s 62us/step
# 920/920 [==============================] - 0s 58us/step
# loading 2020-01-22 OGO ohlcv.xlsx
# loading 2019-11-15 QKC ohlcv.xlsx
# loading 2020-01-12 CON ohlcv.xlsx
# 509/509 [==============================] - 0s 56us/step
# 909/909 [==============================] - 0s 65us/step
# loading 2020-01-13 LAMB ohlcv.xlsx
# loading 2019-10-30 HYC ohlcv.xlsx
# loading 2019-11-02 ABT ohlcv.xlsx
# loading 2020-01-24 WAVES ohlcv.xlsx
# loading 2020-01-23 LRC ohlcv.xlsx
# loading 2020-01-14 PCM ohlcv.xlsx
# loading 2019-10-17 AE ohlcv.xlsx
# loading 2020-01-15 QTUM ohlcv.xlsx
# 479/479 [==============================] - 0s 77us/step
# 879/879 [==============================] - 0s 64us/step
# loading 2020-01-22 WPX ohlcv.xlsx
# 617/617 [==============================] - 0s 88us/step
# 1017/1017 [==============================] - 0s 59us/step
# loading 2019-11-24 WET ohlcv.xlsx
# loading 2020-01-20 TRV ohlcv.xlsx
# loading 2020-01-15 BAT ohlcv.xlsx
# loading 2019-10-19 QKC ohlcv.xlsx
# loading 2020-01-23 PAY ohlcv.xlsx
# loading 2020-01-21 LOOM ohlcv.xlsx
# loading 2019-10-16 GXC ohlcv.xlsx
# 257/257 [==============================] - 0s 88us/step
# 657/657 [==============================] - 0s 56us/step
# loading 2020-01-23 MXC ohlcv.xlsx
# loading 2019-10-29 OMG ohlcv.xlsx
# loading 2019-10-24 ORBS ohlcv.xlsx
# loading 2020-01-11 ORBS ohlcv.xlsx
# loading 2019-10-28 MITH ohlcv.xlsx
# loading 2020-01-20 MXC ohlcv.xlsx
# 210/210 [==============================] - 0s 59us/step
# 610/610 [==============================] - 0s 58us/step
# loading 2020-01-19 VALOR ohlcv.xlsx
# loading 2020-01-24 PPT ohlcv.xlsx
# loading 2019-10-17 LOOM ohlcv.xlsx
# loading 2020-01-21 FAB ohlcv.xlsx
# 471/471 [==============================] - 0s 66us/step
# 871/871 [==============================] - 0s 55us/step
# loading 2019-10-27 STEEM ohlcv.xlsx
# loading 2020-01-22 PCM ohlcv.xlsx
# loading 2020-01-13 TRV ohlcv.xlsx
# loading 2019-10-24 ETC ohlcv.xlsx
# loading 2020-01-15 BHP ohlcv.xlsx
# 488/488 [==============================] - 0s 80us/step
# 888/888 [==============================] - 0s 57us/step
# loading 2019-10-31 LBA ohlcv.xlsx
# loading 2020-01-11 MXC ohlcv.xlsx
# loading 2020-01-21 DASH ohlcv.xlsx
# loading 2019-11-01 ELF ohlcv.xlsx
# loading 2020-01-12 TRX ohlcv.xlsx
# 355/355 [==============================] - 0s 64us/step
# 755/755 [==============================] - 0s 56us/step
# loading 2019-10-21 INS ohlcv.xlsx
# loading 2020-01-26 ZEC ohlcv.xlsx
# loading 2020-01-26 MXC ohlcv.xlsx
# loading 2019-11-01 ENJ ohlcv.xlsx
# loading 2019-11-12 LOOM ohlcv.xlsx
# loading 2020-01-16 MIX ohlcv.xlsx
# loading 2019-10-26 LOOM ohlcv.xlsx
# loading 2020-01-22 BAT ohlcv.xlsx
# loading 2019-10-26 ZIL ohlcv.xlsx
# loading 2019-10-25 FNB ohlcv.xlsx
# 591/591 [==============================] - 0s 59us/step
# 991/991 [==============================] - 0s 59us/step
# loading 2020-01-14 RDN ohlcv.xlsx
# loading 2020-01-19 PCM ohlcv.xlsx
# loading 2019-10-19 SALT ohlcv.xlsx
# loading 2019-10-08 PPT ohlcv.xlsx
# loading 2019-10-19 FNB ohlcv.xlsx
# 164/164 [==============================] - 0s 77us/step
# 564/564 [==============================] - 0s 59us/step
# loading 2020-01-21 WICC ohlcv.xlsx
# loading 2019-10-19 WAVES ohlcv.xlsx
# loading 2019-10-27 CTXC ohlcv.xlsx
# loading 2019-10-28 ZIL ohlcv.xlsx
# loading 2020-01-23 CRO ohlcv.xlsx
# loading 2020-01-19 LUNA ohlcv.xlsx
# 829/829 [==============================] - 0s 63us/step
# 1229/1229 [==============================] - 0s 70us/step
# loading 2020-01-12 IPX ohlcv.xlsx
# 344/344 [==============================] - 0s 69us/step
# 744/744 [==============================] - 0s 59us/step
# loading 2019-10-25 LAMB ohlcv.xlsx
# loading 2020-01-14 REP ohlcv.xlsx
# loading 2020-01-25 LINK ohlcv.xlsx
# loading 2019-10-25 ETHOS ohlcv.xlsx
# loading 2019-11-01 SALT ohlcv.xlsx
# Error in getting data from made_x : 'NoneType' object is not iterable
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-594fd7704d8a> in <module>()
#      71         # quit()
#      72
# ---> 73         if len(X_test) != 0:
#      74
#      75             Y_pred_ = model.predict(X_test, verbose=1)
#
# TypeError: object of type 'NoneType' has no len()
