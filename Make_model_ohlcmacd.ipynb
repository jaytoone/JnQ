# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %matplotlib inline

input_data_length = 30
model_num = 84
num_classes = 2

Made_X = np.load('Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
Made_Y = np.load('Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)


#       dataset 분리      #
# dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
# dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
Made_X = Made_X[:, :,[0,1,2,3,9,10,11,12]]
print(Made_X.shape)
print(Made_Y.shape)

row = Made_X.shape[1]
col = Made_X.shape[2]

from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                   shuffle=False)

X_train = X_train.astype('float32').reshape(-1, input_data_length, col, 1)
X_val = X_val.astype('float32').reshape(-1, input_data_length, col, 1)
print(X_train.shape)
print(X_val.shape)

from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 

# Data Class Weight
from sklearn.utils import class_weight

print(Y_train[:, 0])
class_weights = class_weight.compute_class_weight('balanced', 
                                                  np.unique(Y_train[:, 0]),
                                                  Y_train[:, 0])
class_weights = dict(enumerate(class_weights))
# class_weights[1] *= 0.97
# class_weights[2] *= 0.97
print(class_weights)
# quit()

Y_train = Y_train.astype('float32')
Y_val = Y_val.astype('float32')
Y_train = np_utils.to_categorical(Y_train, num_classes)
Y_val = np_utils.to_categorical(Y_val, num_classes)
print(Y_train.shape)
print(Y_val.shape)

datagen = ImageDataGenerator( 
#     rotation_range = 60,
#     zoom_range = 0.6,
#     shear_range = 0.6,
#     horizontal_flip = True,
#     width_shift_range=0.6,
#     height_shift_range=0.6,
    fill_mode = 'nearest'
    )

testgen = ImageDataGenerator( 
    )
datagen.fit(X_train)
batch_size = 128

for X_batch, _ in datagen.flow(X_train, Y_train, batch_size=9):
    for i in range(0, 9): 
        pyplot.axis('off') 
        pyplot.subplot(330 + 1 + i) 
        pyplot.imshow(X_batch[i].reshape(input_data_length, col), cmap=pyplot.get_cmap('gray'))
    pyplot.axis('off') 
    pyplot.show() 
    break
    
    
train_flow = datagen.flow(X_train, Y_train, batch_size=batch_size) 
val_flow = testgen.flow(X_val, Y_val, batch_size=batch_size) 


from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix

def FER_Model(input_shape=(row, col, 1)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(64, kernel_size=3, padding='same')(visible)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_1 = net

    net = layers.Conv2D(128, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
    
    return model

# model = FER_Model()
from keras.models import load_model
model = load_model('model/rapid_ascending %s_%s_ohlcmacd.hdf5' % (input_data_length, model_num))
opt = Adam(lr=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath="model/rapid_ascending %s_%s_ohlcmacd.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_accuracy', patience=100)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 500
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(X_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(X_val) / batch_size,
                    shuffle=False)
# Out:
# (238688, 30, 8)
# (238688, 1)
# (167081, 30, 8, 1)
# (71607, 30, 8, 1)
# [0. 0. 0. ... 0. 0. 0.]
# {0: 0.5097414087669628, 1: 26.163639210773567}
# (167081, 2)
# (71607, 2)
# Epoch 1/500
#  - 7s - loss: 0.3384 - accuracy: 0.7951 - val_loss: 0.3508 - val_accuracy: 0.8173
#
# Epoch 00001: val_accuracy improved from -inf to 0.81732, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 2/500
#  - 7s - loss: 0.3362 - accuracy: 0.7945 - val_loss: 0.3405 - val_accuracy: 0.8080
#
# Epoch 00002: val_accuracy did not improve from 0.81732
# Epoch 3/500
#  - 7s - loss: 0.3361 - accuracy: 0.7959 - val_loss: 0.4308 - val_accuracy: 0.8098
#
# Epoch 00003: val_accuracy did not improve from 0.81732
# Epoch 4/500
#  - 7s - loss: 0.3340 - accuracy: 0.7974 - val_loss: 0.4386 - val_accuracy: 0.7915
#
# Epoch 00004: val_accuracy did not improve from 0.81732
# Epoch 5/500
#  - 7s - loss: 0.3320 - accuracy: 0.7980 - val_loss: 0.3840 - val_accuracy: 0.7925
#
# Epoch 00005: val_accuracy did not improve from 0.81732
# Epoch 6/500
#  - 7s - loss: 0.3302 - accuracy: 0.7993 - val_loss: 0.3934 - val_accuracy: 0.8157
#
# Epoch 00006: val_accuracy did not improve from 0.81732
# Epoch 7/500
#  - 7s - loss: 0.3288 - accuracy: 0.7995 - val_loss: 0.4679 - val_accuracy: 0.7900
#
# Epoch 00007: val_accuracy did not improve from 0.81732
# Epoch 8/500
#  - 7s - loss: 0.3273 - accuracy: 0.8000 - val_loss: 0.4858 - val_accuracy: 0.8120
#
# Epoch 00008: val_accuracy did not improve from 0.81732
# Epoch 9/500
#  - 7s - loss: 0.3248 - accuracy: 0.8016 - val_loss: 0.5069 - val_accuracy: 0.8086
#
# Epoch 00009: val_accuracy did not improve from 0.81732
# Epoch 10/500
#  - 7s - loss: 0.3228 - accuracy: 0.8028 - val_loss: 0.4026 - val_accuracy: 0.7973
#
# Epoch 00010: val_accuracy did not improve from 0.81732
# Epoch 11/500
#  - 7s - loss: 0.3230 - accuracy: 0.8032 - val_loss: 0.3778 - val_accuracy: 0.7303
#
# Epoch 00011: val_accuracy did not improve from 0.81732
# Epoch 12/500
#  - 7s - loss: 0.3222 - accuracy: 0.8018 - val_loss: 0.3639 - val_accuracy: 0.8333
#
# Epoch 00012: val_accuracy improved from 0.81732 to 0.83328, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 13/500
#  - 7s - loss: 0.3195 - accuracy: 0.8053 - val_loss: 0.2911 - val_accuracy: 0.8290
#
# Epoch 00013: val_accuracy did not improve from 0.83328
# Epoch 14/500
#  - 7s - loss: 0.3184 - accuracy: 0.8050 - val_loss: 0.4359 - val_accuracy: 0.8282
#
# Epoch 00014: val_accuracy did not improve from 0.83328
# Epoch 15/500
#  - 7s - loss: 0.3163 - accuracy: 0.8068 - val_loss: 0.2481 - val_accuracy: 0.8086
#
# Epoch 00015: val_accuracy did not improve from 0.83328
# Epoch 16/500
#  - 7s - loss: 0.3146 - accuracy: 0.8082 - val_loss: 0.6275 - val_accuracy: 0.7572
#
# Epoch 00016: val_accuracy did not improve from 0.83328
# Epoch 17/500
#  - 7s - loss: 0.3128 - accuracy: 0.8087 - val_loss: 0.3382 - val_accuracy: 0.8078
#
# Epoch 00017: val_accuracy did not improve from 0.83328
# Epoch 18/500
#  - 7s - loss: 0.3133 - accuracy: 0.8078 - val_loss: 0.4157 - val_accuracy: 0.8291
#
# Epoch 00018: val_accuracy did not improve from 0.83328
# Epoch 19/500
#  - 7s - loss: 0.3101 - accuracy: 0.8110 - val_loss: 0.2993 - val_accuracy: 0.8327
#
# Epoch 00019: val_accuracy did not improve from 0.83328
# Epoch 20/500
#  - 7s - loss: 0.3092 - accuracy: 0.8108 - val_loss: 0.3432 - val_accuracy: 0.8149
#
# Epoch 00020: val_accuracy did not improve from 0.83328
# Epoch 21/500
#  - 7s - loss: 0.3083 - accuracy: 0.8111 - val_loss: 0.1921 - val_accuracy: 0.8149
#
# Epoch 00021: val_accuracy did not improve from 0.83328
# Epoch 22/500
#  - 7s - loss: 0.3050 - accuracy: 0.8130 - val_loss: 0.3528 - val_accuracy: 0.8151
#
# Epoch 00022: val_accuracy did not improve from 0.83328
# Epoch 23/500
#  - 7s - loss: 0.3040 - accuracy: 0.8139 - val_loss: 0.3516 - val_accuracy: 0.8328
#
# Epoch 00023: val_accuracy did not improve from 0.83328
# Epoch 24/500
#  - 7s - loss: 0.3026 - accuracy: 0.8143 - val_loss: 0.3237 - val_accuracy: 0.8081
#
# Epoch 00024: val_accuracy did not improve from 0.83328
# Epoch 25/500
#  - 7s - loss: 0.3007 - accuracy: 0.8146 - val_loss: 0.2259 - val_accuracy: 0.8302
#
# Epoch 00025: val_accuracy did not improve from 0.83328
# Epoch 26/500
#  - 7s - loss: 0.2997 - accuracy: 0.8171 - val_loss: 0.4901 - val_accuracy: 0.8179
#
# Epoch 00026: val_accuracy did not improve from 0.83328
# Epoch 27/500
#  - 7s - loss: 0.2985 - accuracy: 0.8173 - val_loss: 0.4137 - val_accuracy: 0.8217
#
# Epoch 00027: val_accuracy did not improve from 0.83328
# Epoch 28/500
#  - 7s - loss: 0.2964 - accuracy: 0.8175 - val_loss: 0.3923 - val_accuracy: 0.8295
#
# Epoch 00028: val_accuracy did not improve from 0.83328
# Epoch 29/500
#  - 7s - loss: 0.2950 - accuracy: 0.8191 - val_loss: 0.1821 - val_accuracy: 0.8189
#
# Epoch 00029: val_accuracy did not improve from 0.83328
# Epoch 30/500
#  - 7s - loss: 0.2941 - accuracy: 0.8196 - val_loss: 0.3827 - val_accuracy: 0.8411
#
# Epoch 00030: val_accuracy improved from 0.83328 to 0.84109, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 31/500
#  - 7s - loss: 0.2911 - accuracy: 0.8212 - val_loss: 0.2989 - val_accuracy: 0.8345
#
# Epoch 00031: val_accuracy did not improve from 0.84109
# Epoch 32/500
#  - 7s - loss: 0.2893 - accuracy: 0.8226 - val_loss: 0.3027 - val_accuracy: 0.8191
#
# Epoch 00032: val_accuracy did not improve from 0.84109
# Epoch 33/500
#  - 7s - loss: 0.2880 - accuracy: 0.8227 - val_loss: 0.2354 - val_accuracy: 0.8467
#
# Epoch 00033: val_accuracy improved from 0.84109 to 0.84669, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 34/500
#  - 7s - loss: 0.2856 - accuracy: 0.8251 - val_loss: 0.4717 - val_accuracy: 0.8239
#
# Epoch 00034: val_accuracy did not improve from 0.84669
# Epoch 35/500
#  - 7s - loss: 0.2860 - accuracy: 0.8249 - val_loss: 0.2950 - val_accuracy: 0.8400
#
# Epoch 00035: val_accuracy did not improve from 0.84669
# Epoch 36/500
#  - 7s - loss: 0.2839 - accuracy: 0.8253 - val_loss: 0.1772 - val_accuracy: 0.8330
#
# Epoch 00036: val_accuracy did not improve from 0.84669
# Epoch 37/500
#  - 7s - loss: 0.2826 - accuracy: 0.8260 - val_loss: 0.3189 - val_accuracy: 0.8422
#
# Epoch 00037: val_accuracy did not improve from 0.84669
# Epoch 38/500
#  - 7s - loss: 0.2790 - accuracy: 0.8286 - val_loss: 0.3141 - val_accuracy: 0.7989
#
# Epoch 00038: val_accuracy did not improve from 0.84669
# Epoch 39/500
#  - 7s - loss: 0.2784 - accuracy: 0.8292 - val_loss: 0.2127 - val_accuracy: 0.8409
#
# Epoch 00039: val_accuracy did not improve from 0.84669
# Epoch 40/500
#  - 7s - loss: 0.2773 - accuracy: 0.8301 - val_loss: 0.4577 - val_accuracy: 0.8128
#
# Epoch 00040: val_accuracy did not improve from 0.84669
# Epoch 41/500
#  - 7s - loss: 0.2753 - accuracy: 0.8311 - val_loss: 0.3212 - val_accuracy: 0.8557
#
# Epoch 00041: val_accuracy improved from 0.84669 to 0.85566, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 42/500
#  - 7s - loss: 0.2749 - accuracy: 0.8318 - val_loss: 0.4442 - val_accuracy: 0.7839
#
# Epoch 00042: val_accuracy did not improve from 0.85566
# Epoch 43/500
#  - 7s - loss: 0.2711 - accuracy: 0.8335 - val_loss: 0.2843 - val_accuracy: 0.8324
#
# Epoch 00043: val_accuracy did not improve from 0.85566
# Epoch 44/500
#  - 7s - loss: 0.2708 - accuracy: 0.8339 - val_loss: 0.3597 - val_accuracy: 0.8301
#
# Epoch 00044: val_accuracy did not improve from 0.85566
# Epoch 45/500
#  - 7s - loss: 0.2709 - accuracy: 0.8351 - val_loss: 0.3816 - val_accuracy: 0.7982
#
# Epoch 00045: val_accuracy did not improve from 0.85566
# Epoch 46/500
#  - 7s - loss: 0.2691 - accuracy: 0.8344 - val_loss: 0.2703 - val_accuracy: 0.8721
#
# Epoch 00046: val_accuracy improved from 0.85566 to 0.87209, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 47/500
#  - 7s - loss: 0.2674 - accuracy: 0.8359 - val_loss: 0.3187 - val_accuracy: 0.8471
#
# Epoch 00047: val_accuracy did not improve from 0.87209
# Epoch 48/500
#  - 7s - loss: 0.2661 - accuracy: 0.8372 - val_loss: 0.4302 - val_accuracy: 0.8019
#
# Epoch 00048: val_accuracy did not improve from 0.87209
# Epoch 49/500
#  - 7s - loss: 0.2636 - accuracy: 0.8387 - val_loss: 0.3192 - val_accuracy: 0.8545
#
# Epoch 00049: val_accuracy did not improve from 0.87209
# Epoch 50/500
#  - 7s - loss: 0.2625 - accuracy: 0.8397 - val_loss: 0.2543 - val_accuracy: 0.8445
#
# Epoch 00050: val_accuracy did not improve from 0.87209
# Epoch 51/500
#  - 7s - loss: 0.2611 - accuracy: 0.8404 - val_loss: 0.1871 - val_accuracy: 0.8389
#
# Epoch 00051: val_accuracy did not improve from 0.87209
# Epoch 52/500
#  - 7s - loss: 0.2596 - accuracy: 0.8411 - val_loss: 0.1612 - val_accuracy: 0.8485
#
# Epoch 00052: val_accuracy did not improve from 0.87209
# Epoch 53/500
#  - 7s - loss: 0.2580 - accuracy: 0.8426 - val_loss: 0.5250 - val_accuracy: 0.8172
#
# Epoch 00053: val_accuracy did not improve from 0.87209
# Epoch 54/500
#  - 7s - loss: 0.2565 - accuracy: 0.8435 - val_loss: 0.2593 - val_accuracy: 0.8480
#
# Epoch 00054: val_accuracy did not improve from 0.87209
# Epoch 55/500
#  - 7s - loss: 0.2577 - accuracy: 0.8426 - val_loss: 0.5666 - val_accuracy: 0.8433
#
# Epoch 00055: val_accuracy did not improve from 0.87209
# Epoch 56/500
#  - 7s - loss: 0.2534 - accuracy: 0.8448 - val_loss: 0.1638 - val_accuracy: 0.8569
#
# Epoch 00056: val_accuracy did not improve from 0.87209
# Epoch 57/500
#  - 7s - loss: 0.2531 - accuracy: 0.8461 - val_loss: 0.2228 - val_accuracy: 0.8285
#
# Epoch 00057: val_accuracy did not improve from 0.87209
# Epoch 58/500
#  - 7s - loss: 0.2515 - accuracy: 0.8461 - val_loss: 0.4109 - val_accuracy: 0.8388
#
# Epoch 00058: val_accuracy did not improve from 0.87209
# Epoch 59/500
#  - 7s - loss: 0.2498 - accuracy: 0.8476 - val_loss: 0.3011 - val_accuracy: 0.8546
#
# Epoch 00059: val_accuracy did not improve from 0.87209
# Epoch 60/500
#  - 7s - loss: 0.2481 - accuracy: 0.8493 - val_loss: 0.3936 - val_accuracy: 0.8054
#
# Epoch 00060: val_accuracy did not improve from 0.87209
# Epoch 61/500
#  - 7s - loss: 0.2474 - accuracy: 0.8489 - val_loss: 0.1514 - val_accuracy: 0.8488
#
# Epoch 00061: val_accuracy did not improve from 0.87209
# Epoch 62/500
#  - 7s - loss: 0.2447 - accuracy: 0.8505 - val_loss: 0.3893 - val_accuracy: 0.8357
#
# Epoch 00062: val_accuracy did not improve from 0.87209
# Epoch 63/500
#  - 7s - loss: 0.2450 - accuracy: 0.8500 - val_loss: 0.2859 - val_accuracy: 0.8566
#
# Epoch 00063: val_accuracy did not improve from 0.87209
# Epoch 64/500
#  - 7s - loss: 0.2417 - accuracy: 0.8523 - val_loss: 0.1787 - val_accuracy: 0.8732
#
# Epoch 00064: val_accuracy improved from 0.87209 to 0.87321, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 65/500
#  - 7s - loss: 0.2431 - accuracy: 0.8525 - val_loss: 0.3838 - val_accuracy: 0.8378
#
# Epoch 00065: val_accuracy did not improve from 0.87321
# Epoch 66/500
#  - 7s - loss: 0.2405 - accuracy: 0.8534 - val_loss: 0.5617 - val_accuracy: 0.8658
#
# Epoch 00066: val_accuracy did not improve from 0.87321
# Epoch 67/500
#  - 7s - loss: 0.2394 - accuracy: 0.8530 - val_loss: 0.3614 - val_accuracy: 0.8766
#
# Epoch 00067: val_accuracy improved from 0.87321 to 0.87660, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 68/500
#  - 7s - loss: 0.2392 - accuracy: 0.8546 - val_loss: 0.4734 - val_accuracy: 0.8320
#
# Epoch 00068: val_accuracy did not improve from 0.87660
# Epoch 69/500
#  - 7s - loss: 0.2368 - accuracy: 0.8555 - val_loss: 0.2756 - val_accuracy: 0.8554
#
# Epoch 00069: val_accuracy did not improve from 0.87660
# Epoch 70/500
#  - 7s - loss: 0.2338 - accuracy: 0.8576 - val_loss: 0.1244 - val_accuracy: 0.8769
#
# Epoch 00070: val_accuracy improved from 0.87660 to 0.87690, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 71/500
#  - 7s - loss: 0.2336 - accuracy: 0.8583 - val_loss: 0.2916 - val_accuracy: 0.8357
#
# Epoch 00071: val_accuracy did not improve from 0.87690
# Epoch 72/500
#  - 7s - loss: 0.2322 - accuracy: 0.8583 - val_loss: 0.1855 - val_accuracy: 0.8467
#
# Epoch 00072: val_accuracy did not improve from 0.87690
# Epoch 73/500
#  - 7s - loss: 0.2314 - accuracy: 0.8582 - val_loss: 0.1872 - val_accuracy: 0.8761
#
# Epoch 00073: val_accuracy did not improve from 0.87690
# Epoch 74/500
#  - 7s - loss: 0.2299 - accuracy: 0.8601 - val_loss: 0.4612 - val_accuracy: 0.8434
#
# Epoch 00074: val_accuracy did not improve from 0.87690
# Epoch 75/500
#  - 7s - loss: 0.2305 - accuracy: 0.8598 - val_loss: 0.3129 - val_accuracy: 0.8731
#
# Epoch 00075: val_accuracy did not improve from 0.87690
# Epoch 76/500
#  - 7s - loss: 0.2260 - accuracy: 0.8617 - val_loss: 0.3207 - val_accuracy: 0.8286
#
# Epoch 00076: val_accuracy did not improve from 0.87690
# Epoch 77/500
#  - 7s - loss: 0.2259 - accuracy: 0.8623 - val_loss: 0.2336 - val_accuracy: 0.8765
#
# Epoch 00077: val_accuracy did not improve from 0.87690
# Epoch 78/500
#  - 7s - loss: 0.2247 - accuracy: 0.8630 - val_loss: 0.3560 - val_accuracy: 0.8738
#
# Epoch 00078: val_accuracy did not improve from 0.87690
# Epoch 79/500
#  - 7s - loss: 0.2235 - accuracy: 0.8644 - val_loss: 0.2916 - val_accuracy: 0.8394
#
# Epoch 00079: val_accuracy did not improve from 0.87690
# Epoch 80/500
#  - 7s - loss: 0.2219 - accuracy: 0.8651 - val_loss: 0.1444 - val_accuracy: 0.8677
#
# Epoch 00080: val_accuracy did not improve from 0.87690
# Epoch 81/500
#  - 7s - loss: 0.2225 - accuracy: 0.8656 - val_loss: 0.3628 - val_accuracy: 0.8300
#
# Epoch 00081: val_accuracy did not improve from 0.87690
# Epoch 82/500
#  - 7s - loss: 0.2179 - accuracy: 0.8675 - val_loss: 0.4929 - val_accuracy: 0.8545
#
# Epoch 00082: val_accuracy did not improve from 0.87690
# Epoch 83/500
#  - 7s - loss: 0.2183 - accuracy: 0.8679 - val_loss: 0.2684 - val_accuracy: 0.8791
#
# Epoch 00083: val_accuracy improved from 0.87690 to 0.87913, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 84/500
#  - 7s - loss: 0.2180 - accuracy: 0.8681 - val_loss: 0.2957 - val_accuracy: 0.8694
#
# Epoch 00084: val_accuracy did not improve from 0.87913
# Epoch 85/500
#  - 7s - loss: 0.2177 - accuracy: 0.8691 - val_loss: 0.4985 - val_accuracy: 0.8250
#
# Epoch 00085: val_accuracy did not improve from 0.87913
# Epoch 86/500
#  - 7s - loss: 0.2148 - accuracy: 0.8699 - val_loss: 0.5530 - val_accuracy: 0.8382
#
# Epoch 00086: val_accuracy did not improve from 0.87913
# Epoch 87/500
#  - 7s - loss: 0.2133 - accuracy: 0.8703 - val_loss: 0.3176 - val_accuracy: 0.8878
#
# Epoch 00087: val_accuracy improved from 0.87913 to 0.88782, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 88/500
#  - 7s - loss: 0.2124 - accuracy: 0.8719 - val_loss: 0.6850 - val_accuracy: 0.8542
#
# Epoch 00088: val_accuracy did not improve from 0.88782
# Epoch 89/500
#  - 7s - loss: 0.2120 - accuracy: 0.8718 - val_loss: 0.2734 - val_accuracy: 0.8757
#
# Epoch 00089: val_accuracy did not improve from 0.88782
# Epoch 90/500
#  - 7s - loss: 0.2104 - accuracy: 0.8723 - val_loss: 0.1848 - val_accuracy: 0.8916
#
# Epoch 00090: val_accuracy improved from 0.88782 to 0.89162, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 91/500
#  - 7s - loss: 0.2084 - accuracy: 0.8741 - val_loss: 0.3192 - val_accuracy: 0.8612
#
# Epoch 00091: val_accuracy did not improve from 0.89162
# Epoch 92/500
#  - 7s - loss: 0.2091 - accuracy: 0.8734 - val_loss: 0.5170 - val_accuracy: 0.8593
#
# Epoch 00092: val_accuracy did not improve from 0.89162
# Epoch 93/500
#  - 7s - loss: 0.2065 - accuracy: 0.8756 - val_loss: 0.2168 - val_accuracy: 0.8539
#
# Epoch 00093: val_accuracy did not improve from 0.89162
# Epoch 94/500
#  - 7s - loss: 0.2060 - accuracy: 0.8760 - val_loss: 0.3986 - val_accuracy: 0.8517
#
# Epoch 00094: val_accuracy did not improve from 0.89162
# Epoch 95/500
#  - 7s - loss: 0.2046 - accuracy: 0.8768 - val_loss: 0.2184 - val_accuracy: 0.9124
#
# Epoch 00095: val_accuracy improved from 0.89162 to 0.91241, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 96/500
#  - 7s - loss: 0.2029 - accuracy: 0.8774 - val_loss: 0.3058 - val_accuracy: 0.8849
#
# Epoch 00096: val_accuracy did not improve from 0.91241
# Epoch 97/500
#  - 7s - loss: 0.2013 - accuracy: 0.8792 - val_loss: 0.2280 - val_accuracy: 0.8580
#
# Epoch 00097: val_accuracy did not improve from 0.91241
# Epoch 98/500
#  - 7s - loss: 0.2016 - accuracy: 0.8787 - val_loss: 0.3175 - val_accuracy: 0.8509
#
# Epoch 00098: val_accuracy did not improve from 0.91241
# Epoch 99/500
#  - 7s - loss: 0.2001 - accuracy: 0.8798 - val_loss: 0.1442 - val_accuracy: 0.8924
#
# Epoch 00099: val_accuracy did not improve from 0.91241
# Epoch 100/500
#  - 7s - loss: 0.2006 - accuracy: 0.8799 - val_loss: 0.3031 - val_accuracy: 0.8491
#
# Epoch 00100: val_accuracy did not improve from 0.91241
# Epoch 101/500
#  - 7s - loss: 0.1969 - accuracy: 0.8810 - val_loss: 0.2151 - val_accuracy: 0.8869
#
# Epoch 00101: val_accuracy did not improve from 0.91241
# Epoch 102/500
#  - 7s - loss: 0.1956 - accuracy: 0.8817 - val_loss: 0.3749 - val_accuracy: 0.8765
#
# Epoch 00102: val_accuracy did not improve from 0.91241
# Epoch 103/500
#  - 7s - loss: 0.1947 - accuracy: 0.8833 - val_loss: 0.2994 - val_accuracy: 0.8838
#
# Epoch 00103: val_accuracy did not improve from 0.91241
# Epoch 104/500
#  - 7s - loss: 0.1942 - accuracy: 0.8839 - val_loss: 0.3905 - val_accuracy: 0.8596
# Epoch 00104: val_accuracy did not improve from 0.91241
# Epoch 105/500
#  - 7s - loss: 0.1931 - accuracy: 0.8838 - val_loss: 0.2641 - val_accuracy: 0.8798
#
# Epoch 00105: val_accuracy did not improve from 0.91241
# Epoch 106/500
#  - 7s - loss: 0.1915 - accuracy: 0.8848 - val_loss: 0.2451 - val_accuracy: 0.8853
#
# Epoch 00106: val_accuracy did not improve from 0.91241
# Epoch 107/500
#  - 7s - loss: 0.1910 - accuracy: 0.8865 - val_loss: 0.1988 - val_accuracy: 0.8951
#
# Epoch 00107: val_accuracy did not improve from 0.91241
# Epoch 108/500
#  - 7s - loss: 0.1929 - accuracy: 0.8852 - val_loss: 0.3142 - val_accuracy: 0.8936
#
# Epoch 00108: val_accuracy did not improve from 0.91241
# Epoch 109/500
#  - 7s - loss: 0.1868 - accuracy: 0.8876 - val_loss: 0.3309 - val_accuracy: 0.8880
#
# Epoch 00109: val_accuracy did not improve from 0.91241
# Epoch 110/500
#  - 7s - loss: 0.1912 - accuracy: 0.8864 - val_loss: 0.1560 - val_accuracy: 0.9058
#
# Epoch 00110: val_accuracy did not improve from 0.91241
# Epoch 111/500
#  - 7s - loss: 0.1882 - accuracy: 0.8874 - val_loss: 0.4494 - val_accuracy: 0.8755
#
# Epoch 00111: val_accuracy did not improve from 0.91241
# Epoch 112/500
#  - 7s - loss: 0.1868 - accuracy: 0.8886 - val_loss: 0.3047 - val_accuracy: 0.8943
#
# Epoch 00112: val_accuracy did not improve from 0.91241
# Epoch 113/500
#  - 7s - loss: 0.1865 - accuracy: 0.8887 - val_loss: 0.0891 - val_accuracy: 0.8813
#
# Epoch 00113: val_accuracy did not improve from 0.91241
# Epoch 114/500
#  - 7s - loss: 0.1830 - accuracy: 0.8911 - val_loss: 0.2013 - val_accuracy: 0.8825
#
# Epoch 00114: val_accuracy did not improve from 0.91241
# Epoch 115/500
#  - 7s - loss: 0.1826 - accuracy: 0.8915 - val_loss: 0.4251 - val_accuracy: 0.8880
#
# Epoch 00115: val_accuracy did not improve from 0.91241
# Epoch 116/500
#  - 7s - loss: 0.1830 - accuracy: 0.8914 - val_loss: 0.1065 - val_accuracy: 0.8848
#
# Epoch 00116: val_accuracy did not improve from 0.91241
# Epoch 117/500
#  - 7s - loss: 0.1825 - accuracy: 0.8916 - val_loss: 0.3184 - val_accuracy: 0.9033
#
# Epoch 00117: val_accuracy did not improve from 0.91241
# Epoch 118/500
#  - 7s - loss: 0.1785 - accuracy: 0.8942 - val_loss: 0.4999 - val_accuracy: 0.8621
#
# Epoch 00118: val_accuracy did not improve from 0.91241
# Epoch 119/500
#  - 7s - loss: 0.1806 - accuracy: 0.8927 - val_loss: 0.3784 - val_accuracy: 0.8752
#
# Epoch 00119: val_accuracy did not improve from 0.91241
# Epoch 120/500
#  - 7s - loss: 0.1778 - accuracy: 0.8946 - val_loss: 0.3312 - val_accuracy: 0.8923
#
# Epoch 00120: val_accuracy did not improve from 0.91241
# Epoch 121/500
#  - 7s - loss: 0.1785 - accuracy: 0.8943 - val_loss: 0.2216 - val_accuracy: 0.8872
#
# Epoch 00121: val_accuracy did not improve from 0.91241
# Epoch 122/500
#  - 7s - loss: 0.1757 - accuracy: 0.8958 - val_loss: 0.3121 - val_accuracy: 0.8993
#
# Epoch 00122: val_accuracy did not improve from 0.91241
# Epoch 123/500
#  - 7s - loss: 0.1755 - accuracy: 0.8959 - val_loss: 0.4219 - val_accuracy: 0.9002
#
# Epoch 00123: val_accuracy did not improve from 0.91241
# Epoch 124/500
#  - 7s - loss: 0.1757 - accuracy: 0.8964 - val_loss: 0.2369 - val_accuracy: 0.8732
#
# Epoch 00124: val_accuracy did not improve from 0.91241
# Epoch 125/500
#  - 7s - loss: 0.1744 - accuracy: 0.8971 - val_loss: 0.1880 - val_accuracy: 0.8771
#
# Epoch 00125: val_accuracy did not improve from 0.91241
# Epoch 126/500
#  - 7s - loss: 0.1748 - accuracy: 0.8974 - val_loss: 0.1755 - val_accuracy: 0.8842
#
# Epoch 00126: val_accuracy did not improve from 0.91241
# Epoch 127/500
#  - 7s - loss: 0.1713 - accuracy: 0.8988 - val_loss: 0.5064 - val_accuracy: 0.9007
#
# Epoch 00127: val_accuracy did not improve from 0.91241
# Epoch 128/500
#  - 7s - loss: 0.1695 - accuracy: 0.8994 - val_loss: 0.1517 - val_accuracy: 0.9122
#
# Epoch 00128: val_accuracy did not improve from 0.91241
# Epoch 129/500
#  - 7s - loss: 0.1683 - accuracy: 0.9000 - val_loss: 0.3264 - val_accuracy: 0.8967
#
# Epoch 00129: val_accuracy did not improve from 0.91241
# Epoch 130/500
#  - 7s - loss: 0.1691 - accuracy: 0.9011 - val_loss: 0.3297 - val_accuracy: 0.8801
#
# Epoch 00130: val_accuracy did not improve from 0.91241
# Epoch 131/500
#  - 7s - loss: 0.1685 - accuracy: 0.9012 - val_loss: 0.3053 - val_accuracy: 0.8655
#
# Epoch 00131: val_accuracy did not improve from 0.91241
# Epoch 132/500
#  - 7s - loss: 0.1681 - accuracy: 0.9011 - val_loss: 0.1855 - val_accuracy: 0.9082
#
# Epoch 00132: val_accuracy did not improve from 0.91241
# Epoch 133/500
#  - 7s - loss: 0.1648 - accuracy: 0.9033 - val_loss: 0.3491 - val_accuracy: 0.8790
#
# Epoch 00133: val_accuracy did not improve from 0.91241
# Epoch 134/500
#  - 7s - loss: 0.1641 - accuracy: 0.9033 - val_loss: 0.2997 - val_accuracy: 0.8921
#
# Epoch 00134: val_accuracy did not improve from 0.91241
# Epoch 135/500
#  - 7s - loss: 0.1660 - accuracy: 0.9027 - val_loss: 0.1240 - val_accuracy: 0.9084
#
# Epoch 00135: val_accuracy did not improve from 0.91241
# Epoch 136/500
#  - 7s - loss: 0.1643 - accuracy: 0.9033 - val_loss: 0.2531 - val_accuracy: 0.9118
#
# Epoch 00136: val_accuracy did not improve from 0.91241
# Epoch 137/500
#  - 7s - loss: 0.1619 - accuracy: 0.9055 - val_loss: 0.2800 - val_accuracy: 0.8776
#
# Epoch 00137: val_accuracy did not improve from 0.91241
# Epoch 138/500
#  - 7s - loss: 0.1622 - accuracy: 0.9049 - val_loss: 0.3953 - val_accuracy: 0.8989
#
# Epoch 00138: val_accuracy did not improve from 0.91241
# Epoch 139/500
#  - 7s - loss: 0.1600 - accuracy: 0.9059 - val_loss: 0.3727 - val_accuracy: 0.8863
#
# Epoch 00139: val_accuracy did not improve from 0.91241
# Epoch 140/500
#  - 7s - loss: 0.1580 - accuracy: 0.9073 - val_loss: 0.1905 - val_accuracy: 0.8867
#
# Epoch 00140: val_accuracy did not improve from 0.91241
# Epoch 141/500
#  - 7s - loss: 0.1587 - accuracy: 0.9072 - val_loss: 0.2958 - val_accuracy: 0.8843
#
# Epoch 00141: val_accuracy did not improve from 0.91241
# Epoch 142/500
#  - 7s - loss: 0.1574 - accuracy: 0.9081 - val_loss: 0.1710 - val_accuracy: 0.8953
#
# Epoch 00142: val_accuracy did not improve from 0.91241
# Epoch 143/500
#  - 7s - loss: 0.1575 - accuracy: 0.9082 - val_loss: 0.1166 - val_accuracy: 0.8955
#
# Epoch 00143: val_accuracy did not improve from 0.91241
# Epoch 144/500
#  - 7s - loss: 0.1573 - accuracy: 0.9091 - val_loss: 0.4185 - val_accuracy: 0.9070
#
# Epoch 00144: val_accuracy did not improve from 0.91241
# Epoch 145/500
#  - 7s - loss: 0.1600 - accuracy: 0.9077 - val_loss: 0.0737 - val_accuracy: 0.9041
#
# Epoch 00145: val_accuracy did not improve from 0.91241
# Epoch 146/500
#  - 7s - loss: 0.1546 - accuracy: 0.9094 - val_loss: 0.3302 - val_accuracy: 0.8890
#
# Epoch 00146: val_accuracy did not improve from 0.91241
# Epoch 147/500
#  - 7s - loss: 0.1545 - accuracy: 0.9098 - val_loss: 0.2254 - val_accuracy: 0.9062
#
# Epoch 00147: val_accuracy did not improve from 0.91241
# Epoch 148/500
#  - 7s - loss: 0.1513 - accuracy: 0.9119 - val_loss: 0.1446 - val_accuracy: 0.8976
#
# Epoch 00148: val_accuracy did not improve from 0.91241
# Epoch 149/500
#  - 7s - loss: 0.1518 - accuracy: 0.9118 - val_loss: 0.2910 - val_accuracy: 0.9062
#
# Epoch 00149: val_accuracy did not improve from 0.91241
# Epoch 150/500
#  - 7s - loss: 0.1487 - accuracy: 0.9139 - val_loss: 0.2236 - val_accuracy: 0.9199
#
# Epoch 00150: val_accuracy improved from 0.91241 to 0.91991, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 151/500
#  - 7s - loss: 0.1532 - accuracy: 0.9116 - val_loss: 0.1629 - val_accuracy: 0.8987
#
# Epoch 00151: val_accuracy did not improve from 0.91991
# Epoch 152/500
#  - 7s - loss: 0.1493 - accuracy: 0.9135 - val_loss: 0.2145 - val_accuracy: 0.9070
#
# Epoch 00152: val_accuracy did not improve from 0.91991
# Epoch 153/500
#  - 7s - loss: 0.1469 - accuracy: 0.9153 - val_loss: 0.5171 - val_accuracy: 0.8769
#
# Epoch 00153: val_accuracy did not improve from 0.91991
# Epoch 154/500
#  - 7s - loss: 0.1496 - accuracy: 0.9138 - val_loss: 0.1213 - val_accuracy: 0.8850
#
# Epoch 00154: val_accuracy did not improve from 0.91991
# Epoch 155/500
#  - 7s - loss: 0.1480 - accuracy: 0.9148 - val_loss: 0.3305 - val_accuracy: 0.8977
#
# Epoch 00155: val_accuracy did not improve from 0.91991
# Epoch 156/500
#  - 7s - loss: 0.1464 - accuracy: 0.9152 - val_loss: 0.1469 - val_accuracy: 0.9084
#
# Epoch 00156: val_accuracy did not improve from 0.91991
# Epoch 157/500
#  - 7s - loss: 0.1472 - accuracy: 0.9151 - val_loss: 0.1873 - val_accuracy: 0.9106
#
# Epoch 00157: val_accuracy did not improve from 0.91991
# Epoch 158/500
#  - 7s - loss: 0.1440 - accuracy: 0.9169 - val_loss: 0.6477 - val_accuracy: 0.8888
# Epoch 00158: val_accuracy did not improve from 0.91991
# Epoch 159/500
#  - 7s - loss: 0.1431 - accuracy: 0.9172 - val_loss: 0.2102 - val_accuracy: 0.9051
#
# Epoch 00159: val_accuracy did not improve from 0.91991
# Epoch 160/500
#  - 7s - loss: 0.1430 - accuracy: 0.9179 - val_loss: 0.1771 - val_accuracy: 0.9152
#
# Epoch 00160: val_accuracy did not improve from 0.91991
# Epoch 161/500
#  - 7s - loss: 0.1446 - accuracy: 0.9164 - val_loss: 0.2860 - val_accuracy: 0.8950
#
# Epoch 00161: val_accuracy did not improve from 0.91991
# Epoch 162/500
#  - 7s - loss: 0.1432 - accuracy: 0.9174 - val_loss: 0.5209 - val_accuracy: 0.9107
#
# Epoch 00162: val_accuracy did not improve from 0.91991
# Epoch 163/500
#  - 7s - loss: 0.1402 - accuracy: 0.9191 - val_loss: 0.4317 - val_accuracy: 0.8992
#
# Epoch 00163: val_accuracy did not improve from 0.91991
# Epoch 164/500
#  - 7s - loss: 0.1414 - accuracy: 0.9188 - val_loss: 0.0860 - val_accuracy: 0.8992
#
# Epoch 00164: val_accuracy did not improve from 0.91991
# Epoch 165/500
#  - 7s - loss: 0.1404 - accuracy: 0.9198 - val_loss: 0.1347 - val_accuracy: 0.8805
#
# Epoch 00165: val_accuracy did not improve from 0.91991
# Epoch 166/500
#  - 7s - loss: 0.1378 - accuracy: 0.9206 - val_loss: 0.2393 - val_accuracy: 0.9074
#
# Epoch 00166: val_accuracy did not improve from 0.91991
# Epoch 167/500
#  - 7s - loss: 0.1382 - accuracy: 0.9202 - val_loss: 0.1609 - val_accuracy: 0.9077
#
# Epoch 00167: val_accuracy did not improve from 0.91991
# Epoch 168/500
#  - 7s - loss: 0.1363 - accuracy: 0.9219 - val_loss: 0.3117 - val_accuracy: 0.8818
#
# Epoch 00168: val_accuracy did not improve from 0.91991
# Epoch 169/500
#  - 7s - loss: 0.1366 - accuracy: 0.9213 - val_loss: 0.4004 - val_accuracy: 0.9119
#
# Epoch 00169: val_accuracy did not improve from 0.91991
# Epoch 170/500
#  - 7s - loss: 0.1371 - accuracy: 0.9222 - val_loss: 0.3897 - val_accuracy: 0.8531
#
# Epoch 00170: val_accuracy did not improve from 0.91991
# Epoch 171/500
#  - 7s - loss: 0.1356 - accuracy: 0.9224 - val_loss: 0.1384 - val_accuracy: 0.9101
#
# Epoch 00171: val_accuracy did not improve from 0.91991
# Epoch 172/500
#  - 7s - loss: 0.1337 - accuracy: 0.9229 - val_loss: 0.1588 - val_accuracy: 0.9270
#
# Epoch 00172: val_accuracy improved from 0.91991 to 0.92698, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 173/500
#  - 7s - loss: 0.1338 - accuracy: 0.9235 - val_loss: 0.1771 - val_accuracy: 0.9113
#
# Epoch 00173: val_accuracy did not improve from 0.92698
# Epoch 174/500
#  - 7s - loss: 0.1333 - accuracy: 0.9238 - val_loss: 0.1323 - val_accuracy: 0.8961
#
# Epoch 00174: val_accuracy did not improve from 0.92698
# Epoch 175/500
#  - 7s - loss: 0.1344 - accuracy: 0.9235 - val_loss: 0.0903 - val_accuracy: 0.9251
#
# Epoch 00175: val_accuracy did not improve from 0.92698
# Epoch 176/500
#  - 7s - loss: 0.1314 - accuracy: 0.9247 - val_loss: 0.0375 - val_accuracy: 0.9057
#
# Epoch 00176: val_accuracy did not improve from 0.92698
# Epoch 177/500
#  - 7s - loss: 0.1329 - accuracy: 0.9242 - val_loss: 0.3362 - val_accuracy: 0.9041
#
# Epoch 00177: val_accuracy did not improve from 0.92698
# Epoch 178/500
#  - 7s - loss: 0.1318 - accuracy: 0.9250 - val_loss: 0.3300 - val_accuracy: 0.9266
#
# Epoch 00178: val_accuracy did not improve from 0.92698
# Epoch 179/500
#  - 7s - loss: 0.1333 - accuracy: 0.9245 - val_loss: 0.2116 - val_accuracy: 0.9122
#
# Epoch 00179: val_accuracy did not improve from 0.92698
# Epoch 180/500
#  - 7s - loss: 0.1297 - accuracy: 0.9264 - val_loss: 0.1179 - val_accuracy: 0.9138
#
# Epoch 00180: val_accuracy did not improve from 0.92698
# Epoch 181/500
#  - 7s - loss: 0.1273 - accuracy: 0.9276 - val_loss: 0.2220 - val_accuracy: 0.9055
#
# Epoch 00181: val_accuracy did not improve from 0.92698
# Epoch 182/500
#  - 7s - loss: 0.1306 - accuracy: 0.9266 - val_loss: 0.2733 - val_accuracy: 0.9243
#
# Epoch 00182: val_accuracy did not improve from 0.92698
# Epoch 183/500
#  - 7s - loss: 0.1289 - accuracy: 0.9267 - val_loss: 0.2235 - val_accuracy: 0.9221
#
# Epoch 00183: val_accuracy did not improve from 0.92698
# Epoch 184/500
#  - 7s - loss: 0.1251 - accuracy: 0.9285 - val_loss: 0.1848 - val_accuracy: 0.8944
#
# Epoch 00184: val_accuracy did not improve from 0.92698
# Epoch 185/500
#  - 7s - loss: 0.1235 - accuracy: 0.9296 - val_loss: 0.1993 - val_accuracy: 0.9050
#
# Epoch 00185: val_accuracy did not improve from 0.92698
# Epoch 186/500
#  - 7s - loss: 0.1258 - accuracy: 0.9290 - val_loss: 0.2932 - val_accuracy: 0.9197
#
# Epoch 00186: val_accuracy did not improve from 0.92698
# Epoch 187/500
#  - 7s - loss: 0.1240 - accuracy: 0.9295 - val_loss: 0.7795 - val_accuracy: 0.8959
#
# Epoch 00187: val_accuracy did not improve from 0.92698
# Epoch 188/500
#  - 7s - loss: 0.1255 - accuracy: 0.9291 - val_loss: 0.0314 - val_accuracy: 0.9294
#
# Epoch 00188: val_accuracy improved from 0.92698 to 0.92939, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 189/500
#  - 7s - loss: 0.1249 - accuracy: 0.9292 - val_loss: 0.2262 - val_accuracy: 0.9119
#
# Epoch 00189: val_accuracy did not improve from 0.92939
# Epoch 190/500
#  - 7s - loss: 0.1226 - accuracy: 0.9307 - val_loss: 0.1218 - val_accuracy: 0.9121
#
# Epoch 00190: val_accuracy did not improve from 0.92939
# Epoch 191/500
#  - 7s - loss: 0.1209 - accuracy: 0.9315 - val_loss: 0.0758 - val_accuracy: 0.9186
#
# Epoch 00191: val_accuracy did not improve from 0.92939
# Epoch 192/500
#  - 7s - loss: 0.1240 - accuracy: 0.9298 - val_loss: 0.3436 - val_accuracy: 0.9102
#
# Epoch 00192: val_accuracy did not improve from 0.92939
# Epoch 193/500
#  - 7s - loss: 0.1220 - accuracy: 0.9317 - val_loss: 0.3230 - val_accuracy: 0.9036
#
# Epoch 00193: val_accuracy did not improve from 0.92939
# Epoch 194/500
#  - 7s - loss: 0.1216 - accuracy: 0.9317 - val_loss: 0.2694 - val_accuracy: 0.8905
#
# Epoch 00194: val_accuracy did not improve from 0.92939
# Epoch 195/500
#  - 7s - loss: 0.1201 - accuracy: 0.9320 - val_loss: 0.1175 - val_accuracy: 0.9063
#
# Epoch 00195: val_accuracy did not improve from 0.92939
# Epoch 196/500
#  - 7s - loss: 0.1195 - accuracy: 0.9326 - val_loss: 0.1800 - val_accuracy: 0.9212
#
# Epoch 00196: val_accuracy did not improve from 0.92939
# Epoch 197/500
#  - 7s - loss: 0.1186 - accuracy: 0.9331 - val_loss: 0.2249 - val_accuracy: 0.9110
#
# Epoch 00197: val_accuracy did not improve from 0.92939
# Epoch 198/500
#  - 7s - loss: 0.1179 - accuracy: 0.9333 - val_loss: 0.0661 - val_accuracy: 0.9314
#
# Epoch 00198: val_accuracy improved from 0.92939 to 0.93138, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 199/500
#  - 7s - loss: 0.1187 - accuracy: 0.9336 - val_loss: 0.1291 - val_accuracy: 0.9059
#
# Epoch 00199: val_accuracy did not improve from 0.93138
# Epoch 200/500
#  - 7s - loss: 0.1165 - accuracy: 0.9345 - val_loss: 0.1627 - val_accuracy: 0.9383
#
# Epoch 00200: val_accuracy improved from 0.93138 to 0.93827, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 201/500
#  - 7s - loss: 0.1163 - accuracy: 0.9347 - val_loss: 0.1469 - val_accuracy: 0.9032
#
# Epoch 00201: val_accuracy did not improve from 0.93827
# Epoch 202/500
#  - 7s - loss: 0.1127 - accuracy: 0.9366 - val_loss: 0.0432 - val_accuracy: 0.9327
#
# Epoch 00202: val_accuracy did not improve from 0.93827
# Epoch 203/500
#  - 7s - loss: 0.1166 - accuracy: 0.9348 - val_loss: 0.4337 - val_accuracy: 0.9335
#
# Epoch 00203: val_accuracy did not improve from 0.93827
# Epoch 204/500
#  - 7s - loss: 0.1145 - accuracy: 0.9363 - val_loss: 0.0694 - val_accuracy: 0.9310
#
# Epoch 00204: val_accuracy did not improve from 0.93827
# Epoch 205/500
#  - 7s - loss: 0.1128 - accuracy: 0.9366 - val_loss: 0.1884 - val_accuracy: 0.9128
#
# Epoch 00205: val_accuracy did not improve from 0.93827
# Epoch 206/500
#  - 7s - loss: 0.1150 - accuracy: 0.9360 - val_loss: 0.2168 - val_accuracy: 0.9266
#
# Epoch 00206: val_accuracy did not improve from 0.93827
# Epoch 207/500
#  - 7s - loss: 0.1107 - accuracy: 0.9379 - val_loss: 0.6028 - val_accuracy: 0.9154
#
# Epoch 00207: val_accuracy did not improve from 0.93827
# Epoch 208/500
#  - 7s - loss: 0.1132 - accuracy: 0.9366 - val_loss: 0.2551 - val_accuracy: 0.9113
#
# Epoch 00208: val_accuracy did not improve from 0.93827
# Epoch 209/500
#  - 7s - loss: 0.1148 - accuracy: 0.9364 - val_loss: 0.1381 - val_accuracy: 0.9109
#
# Epoch 00209: val_accuracy did not improve from 0.93827
# Epoch 210/500
#  - 7s - loss: 0.1073 - accuracy: 0.9394 - val_loss: 0.2950 - val_accuracy: 0.9256
#
# Epoch 00210: val_accuracy did not improve from 0.93827
# Epoch 211/500
#  - 7s - loss: 0.1093 - accuracy: 0.9388 - val_loss: 0.0888 - val_accuracy: 0.9343
#
# Epoch 00211: val_accuracy did not improve from 0.93827
# Epoch 212/500
#  - 7s - loss: 0.1115 - accuracy: 0.9377 - val_loss: 0.3537 - val_accuracy: 0.9293
#
# Epoch 00212: val_accuracy did not improve from 0.93827
# Epoch 213/500
#  - 7s - loss: 0.1082 - accuracy: 0.9396 - val_loss: 0.1366 - val_accuracy: 0.9253
#
# Epoch 00213: val_accuracy did not improve from 0.93827
# Epoch 214/500
#  - 7s - loss: 0.1098 - accuracy: 0.9395 - val_loss: 0.2164 - val_accuracy: 0.8780
#
# Epoch 00214: val_accuracy did not improve from 0.93827
# Epoch 215/500
#  - 7s - loss: 0.1102 - accuracy: 0.9384 - val_loss: 0.1544 - val_accuracy: 0.9064
#
# Epoch 00215: val_accuracy did not improve from 0.93827
# Epoch 216/500
#  - 7s - loss: 0.1106 - accuracy: 0.9387 - val_loss: 0.3477 - val_accuracy: 0.9193
#
# Epoch 00216: val_accuracy did not improve from 0.93827
# Epoch 217/500
#  - 7s - loss: 0.1076 - accuracy: 0.9403 - val_loss: 0.1778 - val_accuracy: 0.9304
#
# Epoch 00217: val_accuracy did not improve from 0.93827
# Epoch 218/500
#  - 7s - loss: 0.1093 - accuracy: 0.9389 - val_loss: 0.2122 - val_accuracy: 0.9228
#
# Epoch 00218: val_accuracy did not improve from 0.93827
# Epoch 219/500
#  - 7s - loss: 0.1077 - accuracy: 0.9401 - val_loss: 0.3128 - val_accuracy: 0.9213
#
# Epoch 00219: val_accuracy did not improve from 0.93827
# Epoch 220/500
#  - 7s - loss: 0.1046 - accuracy: 0.9412 - val_loss: 0.3837 - val_accuracy: 0.9340
#
# Epoch 00220: val_accuracy did not improve from 0.93827
# Epoch 221/500
#  - 7s - loss: 0.1050 - accuracy: 0.9420 - val_loss: 0.3253 - val_accuracy: 0.9406
#
# Epoch 00221: val_accuracy improved from 0.93827 to 0.94055, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 222/500
#  - 7s - loss: 0.1050 - accuracy: 0.9415 - val_loss: 0.1004 - val_accuracy: 0.9327
#
# Epoch 00222: val_accuracy did not improve from 0.94055
# Epoch 223/500
#  - 7s - loss: 0.1029 - accuracy: 0.9419 - val_loss: 0.1540 - val_accuracy: 0.9317
#
# Epoch 00223: val_accuracy did not improve from 0.94055
# Epoch 224/500
#  - 7s - loss: 0.1074 - accuracy: 0.9408 - val_loss: 0.1885 - val_accuracy: 0.9473
#
# Epoch 00224: val_accuracy improved from 0.94055 to 0.94728, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 225/500
#  - 7s - loss: 0.1040 - accuracy: 0.9427 - val_loss: 0.0450 - val_accuracy: 0.9399
#
# Epoch 00225: val_accuracy did not improve from 0.94728
# Epoch 226/500
#  - 7s - loss: 0.1028 - accuracy: 0.9435 - val_loss: 0.2525 - val_accuracy: 0.9038
#
# Epoch 00226: val_accuracy did not improve from 0.94728
# Epoch 227/500
#  - 7s - loss: 0.1000 - accuracy: 0.9438 - val_loss: 0.1479 - val_accuracy: 0.9227
#
# Epoch 00227: val_accuracy did not improve from 0.94728
# Epoch 228/500
#  - 7s - loss: 0.1027 - accuracy: 0.9433 - val_loss: 0.2455 - val_accuracy: 0.9163
#
# Epoch 00228: val_accuracy did not improve from 0.94728
# Epoch 229/500
#  - 7s - loss: 0.1065 - accuracy: 0.9416 - val_loss: 0.2102 - val_accuracy: 0.9306
#
# Epoch 00229: val_accuracy did not improve from 0.94728
# Epoch 230/500
#  - 7s - loss: 0.1009 - accuracy: 0.9440 - val_loss: 0.1107 - val_accuracy: 0.9112
#
# Epoch 00230: val_accuracy did not improve from 0.94728
# Epoch 231/500
#  - 7s - loss: 0.0987 - accuracy: 0.9450 - val_loss: 0.0635 - val_accuracy: 0.9431
#
# Epoch 00231: val_accuracy did not improve from 0.94728
# Epoch 232/500
#  - 7s - loss: 0.1019 - accuracy: 0.9443 - val_loss: 0.3247 - val_accuracy: 0.9204
#
# Epoch 00232: val_accuracy did not improve from 0.94728
# Epoch 233/500
#  - 7s - loss: 0.0973 - accuracy: 0.9458 - val_loss: 0.0266 - val_accuracy: 0.9496
#
# Epoch 00233: val_accuracy improved from 0.94728 to 0.94959, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 234/500
#  - 7s - loss: 0.1010 - accuracy: 0.9457 - val_loss: 0.2057 - val_accuracy: 0.9237
#
# Epoch 00234: val_accuracy did not improve from 0.94959
# Epoch 235/500
#  - 7s - loss: 0.1026 - accuracy: 0.9434 - val_loss: 0.2752 - val_accuracy: 0.9334
#
# Epoch 00235: val_accuracy did not improve from 0.94959
# Epoch 236/500
#  - 7s - loss: 0.0994 - accuracy: 0.9456 - val_loss: 0.1926 - val_accuracy: 0.9190
#
# Epoch 00236: val_accuracy did not improve from 0.94959
# Epoch 237/500
#  - 7s - loss: 0.0968 - accuracy: 0.9466 - val_loss: 0.1584 - val_accuracy: 0.9294
#
# Epoch 00237: val_accuracy did not improve from 0.94959
# Epoch 238/500
#  - 7s - loss: 0.0957 - accuracy: 0.9473 - val_loss: 0.1971 - val_accuracy: 0.9339
#
# Epoch 00238: val_accuracy did not improve from 0.94959
# Epoch 239/500
#  - 7s - loss: 0.0943 - accuracy: 0.9478 - val_loss: 0.1376 - val_accuracy: 0.9190
#
# Epoch 00239: val_accuracy did not improve from 0.94959
# Epoch 240/500
#  - 7s - loss: 0.0952 - accuracy: 0.9474 - val_loss: 0.3138 - val_accuracy: 0.9351
#
# Epoch 00240: val_accuracy did not improve from 0.94959
# Epoch 241/500
#  - 7s - loss: 0.0959 - accuracy: 0.9474 - val_loss: 0.0694 - val_accuracy: 0.9308
#
# Epoch 00241: val_accuracy did not improve from 0.94959
# Epoch 242/500
#  - 7s - loss: 0.0952 - accuracy: 0.9478 - val_loss: 0.1295 - val_accuracy: 0.9199
#
# Epoch 00242: val_accuracy did not improve from 0.94959
# Epoch 243/500
#  - 7s - loss: 0.0924 - accuracy: 0.9487 - val_loss: 0.0689 - val_accuracy: 0.9262
#
# Epoch 00243: val_accuracy did not improve from 0.94959
# Epoch 244/500
#  - 7s - loss: 0.0955 - accuracy: 0.9473 - val_loss: 0.1409 - val_accuracy: 0.9353
#
# Epoch 00244: val_accuracy did not improve from 0.94959
# Epoch 245/500
#  - 7s - loss: 0.0940 - accuracy: 0.9482 - val_loss: 0.1058 - val_accuracy: 0.9271
#
# Epoch 00245: val_accuracy did not improve from 0.94959
# Epoch 246/500
#  - 7s - loss: 0.0890 - accuracy: 0.9507 - val_loss: 0.2342 - val_accuracy: 0.9306
#
# Epoch 00246: val_accuracy did not improve from 0.94959
# Epoch 247/500
#  - 7s - loss: 0.0928 - accuracy: 0.9487 - val_loss: 0.3125 - val_accuracy: 0.9380
#
# Epoch 00247: val_accuracy did not improve from 0.94959
# Epoch 248/500
#  - 7s - loss: 0.0956 - accuracy: 0.9486 - val_loss: 0.1625 - val_accuracy: 0.9353
#
# Epoch 00248: val_accuracy did not improve from 0.94959
# Epoch 249/500
#  - 7s - loss: 0.0901 - accuracy: 0.9504 - val_loss: 0.2872 - val_accuracy: 0.9353
#
# Epoch 00249: val_accuracy did not improve from 0.94959
# Epoch 250/500
#  - 7s - loss: 0.0900 - accuracy: 0.9504 - val_loss: 0.1429 - val_accuracy: 0.9452
#
# Epoch 00250: val_accuracy did not improve from 0.94959
# Epoch 251/500
#  - 7s - loss: 0.0897 - accuracy: 0.9509 - val_loss: 0.0674 - val_accuracy: 0.9238
#
# Epoch 00251: val_accuracy did not improve from 0.94959
# Epoch 252/500
#  - 7s - loss: 0.0894 - accuracy: 0.9508 - val_loss: 0.6699 - val_accuracy: 0.9369
#
# Epoch 00252: val_accuracy did not improve from 0.94959
# Epoch 253/500
#  - 7s - loss: 0.0943 - accuracy: 0.9488 - val_loss: 0.1246 - val_accuracy: 0.9377
#
# Epoch 00253: val_accuracy did not improve from 0.94959
# Epoch 254/500
#  - 7s - loss: 0.0861 - accuracy: 0.9524 - val_loss: 0.3146 - val_accuracy: 0.9291
#
# Epoch 00254: val_accuracy did not improve from 0.94959
# Epoch 255/500
#  - 7s - loss: 0.0901 - accuracy: 0.9507 - val_loss: 0.4103 - val_accuracy: 0.9313
#
# Epoch 00255: val_accuracy did not improve from 0.94959
# Epoch 256/500
#  - 7s - loss: 0.0886 - accuracy: 0.9515 - val_loss: 0.0093 - val_accuracy: 0.9360
#
# Epoch 00256: val_accuracy did not improve from 0.94959
# Epoch 257/500
#  - 7s - loss: 0.0931 - accuracy: 0.9501 - val_loss: 0.4216 - val_accuracy: 0.9148
#
# Epoch 00257: val_accuracy did not improve from 0.94959
# Epoch 258/500
#  - 7s - loss: 0.0845 - accuracy: 0.9533 - val_loss: 0.0958 - val_accuracy: 0.9241
#
# Epoch 00258: val_accuracy did not improve from 0.94959
# Epoch 259/500
#  - 7s - loss: 0.0886 - accuracy: 0.9516 - val_loss: 0.1182 - val_accuracy: 0.9294
#
# Epoch 00259: val_accuracy did not improve from 0.94959
# Epoch 260/500
#  - 7s - loss: 0.0875 - accuracy: 0.9526 - val_loss: 0.4004 - val_accuracy: 0.9228
#
# Epoch 00260: val_accuracy did not improve from 0.94959
# Epoch 261/500
#  - 7s - loss: 0.0867 - accuracy: 0.9526 - val_loss: 0.2268 - val_accuracy: 0.9273
#
# Epoch 00261: val_accuracy did not improve from 0.94959
# Epoch 262/500
#  - 7s - loss: 0.0885 - accuracy: 0.9517 - val_loss: 0.3153 - val_accuracy: 0.9299
#
# Epoch 00262: val_accuracy did not improve from 0.94959
# Epoch 263/500
#  - 7s - loss: 0.0829 - accuracy: 0.9544 - val_loss: 0.3721 - val_accuracy: 0.9316
#
# Epoch 00263: val_accuracy did not improve from 0.94959
# Epoch 264/500
#  - 7s - loss: 0.0850 - accuracy: 0.9533 - val_loss: 0.1496 - val_accuracy: 0.9417
#
# Epoch 00264: val_accuracy did not improve from 0.94959
# Epoch 265/500
#  - 7s - loss: 0.0862 - accuracy: 0.9531 - val_loss: 0.1972 - val_accuracy: 0.9322
#
# Epoch 00265: val_accuracy did not improve from 0.94959
# Epoch 266/500
#  - 7s - loss: 0.0893 - accuracy: 0.9527 - val_loss: 0.0871 - val_accuracy: 0.9308
#
# Epoch 00266: val_accuracy did not improve from 0.94959
# Epoch 267/500
#  - 7s - loss: 0.0831 - accuracy: 0.9548 - val_loss: 0.1725 - val_accuracy: 0.9391
#
# Epoch 00267: val_accuracy did not improve from 0.94959
# Epoch 268/500
#  - 7s - loss: 0.0846 - accuracy: 0.9541 - val_loss: 0.0609 - val_accuracy: 0.9384
#
# Epoch 00268: val_accuracy did not improve from 0.94959
# Epoch 269/500
#  - 7s - loss: 0.0827 - accuracy: 0.9550 - val_loss: 0.3241 - val_accuracy: 0.9331
#
# Epoch 00269: val_accuracy did not improve from 0.94959
# Epoch 270/500
#  - 7s - loss: 0.0795 - accuracy: 0.9568 - val_loss: 0.0506 - val_accuracy: 0.9325
#
# Epoch 00270: val_accuracy did not improve from 0.94959
# Epoch 271/500
#  - 7s - loss: 0.0811 - accuracy: 0.9561 - val_loss: 0.1799 - val_accuracy: 0.9427
#
# Epoch 00271: val_accuracy did not improve from 0.94959
# Epoch 272/500
#  - 7s - loss: 0.0832 - accuracy: 0.9550 - val_loss: 1.7966 - val_accuracy: 0.9322
#
# Epoch 00272: val_accuracy did not improve from 0.94959
# Epoch 273/500
#  - 7s - loss: 0.0816 - accuracy: 0.9555 - val_loss: 0.4423 - val_accuracy: 0.9246
#
# Epoch 00273: val_accuracy did not improve from 0.94959
# Epoch 274/500
#  - 7s - loss: 0.0839 - accuracy: 0.9549 - val_loss: 0.2353 - val_accuracy: 0.9093
#
# Epoch 00274: val_accuracy did not improve from 0.94959
# Epoch 275/500
#  - 7s - loss: 0.0819 - accuracy: 0.9556 - val_loss: 0.0163 - val_accuracy: 0.9360
#
# Epoch 00275: val_accuracy did not improve from 0.94959
# Epoch 276/500
#  - 7s - loss: 0.0786 - accuracy: 0.9574 - val_loss: 0.2531 - val_accuracy: 0.9345
#
# Epoch 00276: val_accuracy did not improve from 0.94959
# Epoch 277/500
#  - 7s - loss: 0.0796 - accuracy: 0.9568 - val_loss: 0.1579 - val_accuracy: 0.9225
#
# Epoch 00277: val_accuracy did not improve from 0.94959
# Epoch 278/500
#  - 7s - loss: 0.0791 - accuracy: 0.9573 - val_loss: 0.1548 - val_accuracy: 0.9308
#
# Epoch 00278: val_accuracy did not improve from 0.94959
# Epoch 279/500
#  - 7s - loss: 0.0873 - accuracy: 0.9548 - val_loss: 0.3653 - val_accuracy: 0.9276
#
# Epoch 00279: val_accuracy did not improve from 0.94959
# Epoch 280/500
#  - 7s - loss: 0.0774 - accuracy: 0.9582 - val_loss: 0.0615 - val_accuracy: 0.9525
#
# Epoch 00280: val_accuracy improved from 0.94959 to 0.95248, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 281/500
#  - 7s - loss: 0.0827 - accuracy: 0.9559 - val_loss: 0.1212 - val_accuracy: 0.9331
#
# Epoch 00281: val_accuracy did not improve from 0.95248
# Epoch 282/500
#  - 7s - loss: 0.0758 - accuracy: 0.9587 - val_loss: 0.0887 - val_accuracy: 0.9444
#
# Epoch 00282: val_accuracy did not improve from 0.95248
# Epoch 283/500
#  - 7s - loss: 0.0770 - accuracy: 0.9580 - val_loss: 0.1688 - val_accuracy: 0.9354
#
# Epoch 00283: val_accuracy did not improve from 0.95248
# Epoch 284/500
#  - 7s - loss: 0.0833 - accuracy: 0.9559 - val_loss: 0.4735 - val_accuracy: 0.9324
#
# Epoch 00284: val_accuracy did not improve from 0.95248
# Epoch 285/500
#  - 7s - loss: 0.0723 - accuracy: 0.9602 - val_loss: 1.7431 - val_accuracy: 0.9445
#
# Epoch 00285: val_accuracy did not improve from 0.95248
# Epoch 286/500
#  - 7s - loss: 0.0842 - accuracy: 0.9562 - val_loss: 0.3156 - val_accuracy: 0.9395
#
# Epoch 00286: val_accuracy did not improve from 0.95248
# Epoch 287/500
#  - 7s - loss: 0.0760 - accuracy: 0.9589 - val_loss: 0.1472 - val_accuracy: 0.9415
#
# Epoch 00287: val_accuracy did not improve from 0.95248
# Epoch 288/500
#  - 7s - loss: 0.0773 - accuracy: 0.9581 - val_loss: 0.3020 - val_accuracy: 0.9358
#
# Epoch 00288: val_accuracy did not improve from 0.95248
# Epoch 289/500
#  - 7s - loss: 0.0733 - accuracy: 0.9603 - val_loss: 0.6003 - val_accuracy: 0.9416
#
# Epoch 00289: val_accuracy did not improve from 0.95248
# Epoch 290/500
#  - 7s - loss: 0.0748 - accuracy: 0.9600 - val_loss: 0.3115 - val_accuracy: 0.9353
#
# Epoch 00290: val_accuracy did not improve from 0.95248
# Epoch 291/500
#  - 7s - loss: 0.0785 - accuracy: 0.9580 - val_loss: 0.1930 - val_accuracy: 0.9497
#
# Epoch 00291: val_accuracy did not improve from 0.95248
# Epoch 292/500
#  - 7s - loss: 0.0745 - accuracy: 0.9599 - val_loss: 0.0607 - val_accuracy: 0.9463
#
# Epoch 00292: val_accuracy did not improve from 0.95248
# Epoch 293/500
#  - 7s - loss: 0.0754 - accuracy: 0.9597 - val_loss: 0.1486 - val_accuracy: 0.9341
#
# Epoch 00293: val_accuracy did not improve from 0.95248
# Epoch 294/500
#  - 7s - loss: 0.0720 - accuracy: 0.9613 - val_loss: 0.5148 - val_accuracy: 0.9392
#
# Epoch 00294: val_accuracy did not improve from 0.95248
# Epoch 295/500
#  - 7s - loss: 0.0759 - accuracy: 0.9595 - val_loss: 0.2902 - val_accuracy: 0.9445
#
# Epoch 00295: val_accuracy did not improve from 0.95248
# Epoch 296/500
#  - 7s - loss: 0.0755 - accuracy: 0.9598 - val_loss: 0.0277 - val_accuracy: 0.9539
#
# Epoch 00296: val_accuracy improved from 0.95248 to 0.95394, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 297/500
#  - 7s - loss: 0.0723 - accuracy: 0.9613 - val_loss: 0.2649 - val_accuracy: 0.9362
#
# Epoch 00297: val_accuracy did not improve from 0.95394
# Epoch 298/500
#  - 7s - loss: 0.0732 - accuracy: 0.9609 - val_loss: 0.2359 - val_accuracy: 0.9444
#
# Epoch 00298: val_accuracy did not improve from 0.95394
# Epoch 299/500
#  - 7s - loss: 0.0727 - accuracy: 0.9612 - val_loss: 0.8074 - val_accuracy: 0.9519
#
# Epoch 00299: val_accuracy did not improve from 0.95394
# Epoch 300/500
#  - 7s - loss: 0.0713 - accuracy: 0.9615 - val_loss: 0.1010 - val_accuracy: 0.9474
#
# Epoch 00300: val_accuracy did not improve from 0.95394
# Epoch 301/500
#  - 7s - loss: 0.0726 - accuracy: 0.9613 - val_loss: 0.2945 - val_accuracy: 0.9267
#
# Epoch 00301: val_accuracy did not improve from 0.95394
# Epoch 302/500
#  - 7s - loss: 0.0733 - accuracy: 0.9608 - val_loss: 0.0501 - val_accuracy: 0.9485
#
# Epoch 00302: val_accuracy did not improve from 0.95394
# Epoch 303/500
#  - 7s - loss: 0.0709 - accuracy: 0.9625 - val_loss: 0.0076 - val_accuracy: 0.9273
#
# Epoch 00303: val_accuracy did not improve from 0.95394
# Epoch 304/500
#  - 7s - loss: 0.0672 - accuracy: 0.9641 - val_loss: 0.0727 - val_accuracy: 0.9417
#
# Epoch 00304: val_accuracy did not improve from 0.95394
# Epoch 305/500
#  - 7s - loss: 0.0733 - accuracy: 0.9610 - val_loss: 0.0710 - val_accuracy: 0.9478
#
# Epoch 00305: val_accuracy did not improve from 0.95394
# Epoch 306/500
#  - 7s - loss: 0.0691 - accuracy: 0.9628 - val_loss: 0.2572 - val_accuracy: 0.9497
#
# ...
#
# Epoch 00396: val_accuracy did not improve from 0.96218
# Epoch 397/500
#  - 7s - loss: 0.0469 - accuracy: 0.9753 - val_loss: 0.2039 - val_accuracy: 0.9431
#
# Epoch 00397: val_accuracy did not improve from 0.96218
# Epoch 398/500
#  - 7s - loss: 0.0475 - accuracy: 0.9754 - val_loss: 0.0914 - val_accuracy: 0.9521
#
# Epoch 00398: val_accuracy did not improve from 0.96218
# Epoch 399/500
#  - 7s - loss: 0.0462 - accuracy: 0.9760 - val_loss: 0.0319 - val_accuracy: 0.9588
#
# Epoch 00399: val_accuracy did not improve from 0.96218
# Epoch 400/500
#  - 7s - loss: 0.0514 - accuracy: 0.9739 - val_loss: 0.2075 - val_accuracy: 0.9421
#
# Epoch 00400: val_accuracy did not improve from 0.96218
# Epoch 401/500
#  - 7s - loss: 0.0446 - accuracy: 0.9769 - val_loss: 0.2909 - val_accuracy: 0.9621
#
# Epoch 00401: val_accuracy did not improve from 0.96218
# Epoch 402/500
#  - 7s - loss: 0.0431 - accuracy: 0.9774 - val_loss: 0.4483 - val_accuracy: 0.9515
#
# Epoch 00402: val_accuracy did not improve from 0.96218
# Epoch 403/500
#  - 7s - loss: 0.0446 - accuracy: 0.9767 - val_loss: 0.1116 - val_accuracy: 0.9641
#
# Epoch 00403: val_accuracy improved from 0.96218 to 0.96411, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 404/500
#  - 7s - loss: 0.0548 - accuracy: 0.9726 - val_loss: 1.2490 - val_accuracy: 0.9560
#
# Epoch 00404: val_accuracy did not improve from 0.96411
# Epoch 405/500
#  - 7s - loss: 0.0461 - accuracy: 0.9762 - val_loss: 0.3214 - val_accuracy: 0.9535
#
# Epoch 00405: val_accuracy did not improve from 0.96411
# Epoch 406/500
#  - 7s - loss: 0.0463 - accuracy: 0.9765 - val_loss: 0.0037 - val_accuracy: 0.9544
#
# Epoch 00406: val_accuracy did not improve from 0.96411
# Epoch 407/500
#  - 7s - loss: 0.0428 - accuracy: 0.9779 - val_loss: 0.6323 - val_accuracy: 0.9496
#
# Epoch 00407: val_accuracy did not improve from 0.96411
# Epoch 408/500
#  - 7s - loss: 0.0505 - accuracy: 0.9741 - val_loss: 0.3998 - val_accuracy: 0.9479
#
# Epoch 00408: val_accuracy did not improve from 0.96411
# Epoch 409/500
#  - 7s - loss: 0.0402 - accuracy: 0.9791 - val_loss: 0.1560 - val_accuracy: 0.9481
#
# Epoch 00409: val_accuracy did not improve from 0.96411
# Epoch 410/500
#  - 7s - loss: 0.0520 - accuracy: 0.9742 - val_loss: 0.5488 - val_accuracy: 0.9485
#
# Epoch 00410: val_accuracy did not improve from 0.96411
# Epoch 411/500
#  - 7s - loss: 0.0438 - accuracy: 0.9775 - val_loss: 0.6541 - val_accuracy: 0.9475
#
# Epoch 00411: val_accuracy did not improve from 0.96411
# Epoch 412/500
#  - 7s - loss: 0.0411 - accuracy: 0.9788 - val_loss: 0.2940 - val_accuracy: 0.9488
#
# Epoch 00412: val_accuracy did not improve from 0.96411
# Epoch 413/500
#  - 7s - loss: 0.0477 - accuracy: 0.9759 - val_loss: 0.4324 - val_accuracy: 0.9466
#
# Epoch 00413: val_accuracy did not improve from 0.96411
# Epoch 414/500
#  - 7s - loss: 0.0467 - accuracy: 0.9762 - val_loss: 0.6074 - val_accuracy: 0.9634
#
# Epoch 00414: val_accuracy did not improve from 0.96411
# Epoch 415/500
#  - 7s - loss: 0.0422 - accuracy: 0.9783 - val_loss: 0.0406 - val_accuracy: 0.9394
#
# Epoch 00415: val_accuracy did not improve from 0.96411
# Epoch 416/500
#  - 7s - loss: 0.0420 - accuracy: 0.9785 - val_loss: 0.0529 - val_accuracy: 0.9467
#
# Epoch 00416: val_accuracy did not improve from 0.96411
# Epoch 417/500
#  - 7s - loss: 0.0485 - accuracy: 0.9753 - val_loss: 0.4585 - val_accuracy: 0.9521
#
# Epoch 00417: val_accuracy did not improve from 0.96411
# Epoch 418/500
#  - 7s - loss: 0.0425 - accuracy: 0.9781 - val_loss: 0.7478 - val_accuracy: 0.9551
#
# Epoch 00418: val_accuracy did not improve from 0.96411
# Epoch 419/500
#  - 7s - loss: 0.0557 - accuracy: 0.9739 - val_loss: 0.1212 - val_accuracy: 0.9469
#
# Epoch 00419: val_accuracy did not improve from 0.96411
# Epoch 420/500
#  - 7s - loss: 0.0414 - accuracy: 0.9783 - val_loss: 0.6225 - val_accuracy: 0.9577
#
# Epoch 00420: val_accuracy did not improve from 0.96411
# Epoch 421/500
#  - 7s - loss: 0.0415 - accuracy: 0.9786 - val_loss: 0.5075 - val_accuracy: 0.9433
#
# Epoch 00421: val_accuracy did not improve from 0.96411
# Epoch 422/500
#  - 7s - loss: 0.0431 - accuracy: 0.9777 - val_loss: 0.2956 - val_accuracy: 0.9341
#
# Epoch 00422: val_accuracy did not improve from 0.96411
# Epoch 423/500
#  - 7s - loss: 0.0447 - accuracy: 0.9779 - val_loss: 0.1262 - val_accuracy: 0.9503
#
# Epoch 00423: val_accuracy did not improve from 0.96411
# Epoch 424/500
#  - 7s - loss: 0.0401 - accuracy: 0.9793 - val_loss: 0.3835 - val_accuracy: 0.9496
# Epoch 00424: val_accuracy did not improve from 0.96411
# Epoch 425/500
#  - 7s - loss: 0.0512 - accuracy: 0.9751 - val_loss: 0.0126 - val_accuracy: 0.9506
#
# Epoch 00425: val_accuracy did not improve from 0.96411
# Epoch 426/500
#  - 7s - loss: 0.0413 - accuracy: 0.9787 - val_loss: 0.1013 - val_accuracy: 0.9536
#
# Epoch 00426: val_accuracy did not improve from 0.96411
# Epoch 427/500
#  - 7s - loss: 0.0390 - accuracy: 0.9803 - val_loss: 0.3232 - val_accuracy: 0.9466
#
# Epoch 00427: val_accuracy did not improve from 0.96411
# Epoch 428/500
#  - 7s - loss: 0.0395 - accuracy: 0.9796 - val_loss: 0.4299 - val_accuracy: 0.9515
#
# Epoch 00428: val_accuracy did not improve from 0.96411
# Epoch 429/500
#  - 7s - loss: 0.0642 - accuracy: 0.9718 - val_loss: 0.3756 - val_accuracy: 0.9463
#
# Epoch 00429: val_accuracy did not improve from 0.96411
# Epoch 430/500
#  - 7s - loss: 0.0359 - accuracy: 0.9817 - val_loss: 0.0019 - val_accuracy: 0.9379
#
# Epoch 00430: val_accuracy did not improve from 0.96411
# Epoch 431/500
#  - 7s - loss: 0.0377 - accuracy: 0.9808 - val_loss: 0.0182 - val_accuracy: 0.9570
#
# Epoch 00431: val_accuracy did not improve from 0.96411
# Epoch 432/500
#  - 7s - loss: 0.0388 - accuracy: 0.9801 - val_loss: 0.3289 - val_accuracy: 0.9238
#
# Epoch 00432: val_accuracy did not improve from 0.96411
# Epoch 433/500
#  - 7s - loss: 0.0483 - accuracy: 0.9763 - val_loss: 0.4224 - val_accuracy: 0.9576
#
# Epoch 00433: val_accuracy did not improve from 0.96411
# Epoch 434/500
#  - 7s - loss: 0.0410 - accuracy: 0.9791 - val_loss: 0.0311 - val_accuracy: 0.9480
#
# Epoch 00434: val_accuracy did not improve from 0.96411
# Epoch 435/500
#  - 7s - loss: 0.0523 - accuracy: 0.9756 - val_loss: 0.0161 - val_accuracy: 0.9508
#
# Epoch 00435: val_accuracy did not improve from 0.96411
# Epoch 436/500
#  - 7s - loss: 0.0369 - accuracy: 0.9812 - val_loss: 0.1068 - val_accuracy: 0.9457
#
# Epoch 00436: val_accuracy did not improve from 0.96411
# Epoch 437/500
#  - 7s - loss: 0.0490 - accuracy: 0.9773 - val_loss: 0.3557 - val_accuracy: 0.9516
#
# Epoch 00437: val_accuracy did not improve from 0.96411
# Epoch 438/500
#  - 7s - loss: 0.0400 - accuracy: 0.9797 - val_loss: 0.1003 - val_accuracy: 0.9579
#
# Epoch 00438: val_accuracy did not improve from 0.96411
# Epoch 439/500
#  - 7s - loss: 0.0350 - accuracy: 0.9819 - val_loss: 0.0745 - val_accuracy: 0.9563
#
# Epoch 00439: val_accuracy did not improve from 0.96411
# Epoch 440/500
#  - 7s - loss: 0.0416 - accuracy: 0.9796 - val_loss: 0.1482 - val_accuracy: 0.9488
#
# Epoch 00440: val_accuracy did not improve from 0.96411
# Epoch 441/500
#  - 7s - loss: 0.0560 - accuracy: 0.9748 - val_loss: 0.0845 - val_accuracy: 0.9543
#
# Epoch 00441: val_accuracy did not improve from 0.96411
# Epoch 442/500
#  - 7s - loss: 0.0352 - accuracy: 0.9823 - val_loss: 0.3588 - val_accuracy: 0.9509
#
# Epoch 00442: val_accuracy did not improve from 0.96411
# Epoch 443/500
#  - 7s - loss: 0.0353 - accuracy: 0.9818 - val_loss: 0.0075 - val_accuracy: 0.9615
#
# Epoch 00443: val_accuracy did not improve from 0.96411
# Epoch 444/500
#  - 7s - loss: 0.0402 - accuracy: 0.9796 - val_loss: 0.3618 - val_accuracy: 0.9588
#
# Epoch 00444: val_accuracy did not improve from 0.96411
# Epoch 445/500
#  - 7s - loss: 0.0389 - accuracy: 0.9799 - val_loss: 0.5599 - val_accuracy: 0.9550
#
# Epoch 00445: val_accuracy did not improve from 0.96411
# Epoch 446/500
#  - 7s - loss: 0.0379 - accuracy: 0.9805 - val_loss: 0.7509 - val_accuracy: 0.9531
#
# Epoch 00446: val_accuracy did not improve from 0.96411
# Epoch 447/500
#  - 7s - loss: 0.0473 - accuracy: 0.9775 - val_loss: 0.6921 - val_accuracy: 0.9541
#
# Epoch 00447: val_accuracy did not improve from 0.96411
# Epoch 448/500
#  - 7s - loss: 0.0327 - accuracy: 0.9830 - val_loss: 0.0209 - val_accuracy: 0.9574
#
# Epoch 00448: val_accuracy did not improve from 0.96411
# Epoch 449/500
#  - 7s - loss: 0.0411 - accuracy: 0.9793 - val_loss: 0.4493 - val_accuracy: 0.9557
#
# Epoch 00449: val_accuracy did not improve from 0.96411
# Epoch 450/500
#  - 7s - loss: 0.0394 - accuracy: 0.9804 - val_loss: 0.7139 - val_accuracy: 0.9480
#
# Epoch 00450: val_accuracy did not improve from 0.96411
# Epoch 451/500
#  - 7s - loss: 0.0397 - accuracy: 0.9801 - val_loss: 0.2902 - val_accuracy: 0.9584
#
# Epoch 00451: val_accuracy did not improve from 0.96411
# Epoch 452/500
#  - 7s - loss: 0.0422 - accuracy: 0.9794 - val_loss: 0.2922 - val_accuracy: 0.9496
#
# Epoch 00452: val_accuracy did not improve from 0.96411
# Epoch 453/500
#  - 7s - loss: 0.0346 - accuracy: 0.9821 - val_loss: 0.2547 - val_accuracy: 0.9611
#
# Epoch 00453: val_accuracy did not improve from 0.96411
# Epoch 454/500
#  - 7s - loss: 0.0464 - accuracy: 0.9776 - val_loss: 0.3965 - val_accuracy: 0.9554
#
# Epoch 00454: val_accuracy did not improve from 0.96411
# Epoch 455/500
#  - 7s - loss: 0.0376 - accuracy: 0.9811 - val_loss: 0.3917 - val_accuracy: 0.9535
#
# Epoch 00455: val_accuracy did not improve from 0.96411
# Epoch 456/500
#  - 7s - loss: 0.0342 - accuracy: 0.9826 - val_loss: 1.6105 - val_accuracy: 0.9545
#
# Epoch 00456: val_accuracy did not improve from 0.96411
# Epoch 457/500
#  - 7s - loss: 0.0379 - accuracy: 0.9805 - val_loss: 0.0218 - val_accuracy: 0.9568
#
# Epoch 00457: val_accuracy did not improve from 0.96411
# Epoch 458/500
#  - 7s - loss: 0.0448 - accuracy: 0.9783 - val_loss: 0.5950 - val_accuracy: 0.9535
#
# Epoch 00458: val_accuracy did not improve from 0.96411
# Epoch 459/500
#  - 7s - loss: 0.0328 - accuracy: 0.9829 - val_loss: 0.0709 - val_accuracy: 0.9546
#
# Epoch 00459: val_accuracy did not improve from 0.96411
# Epoch 460/500
#  - 7s - loss: 0.0431 - accuracy: 0.9789 - val_loss: 0.5275 - val_accuracy: 0.9518
#
# Epoch 00460: val_accuracy did not improve from 0.96411
# Epoch 461/500
#  - 7s - loss: 0.0319 - accuracy: 0.9837 - val_loss: 0.2279 - val_accuracy: 0.9602
#
# Epoch 00461: val_accuracy did not improve from 0.96411
# Epoch 462/500
#  - 7s - loss: 0.0363 - accuracy: 0.9815 - val_loss: 0.2615 - val_accuracy: 0.9558
#
# Epoch 00462: val_accuracy did not improve from 0.96411
# Epoch 463/500
#  - 7s - loss: 0.0558 - accuracy: 0.9752 - val_loss: 0.0308 - val_accuracy: 0.9526
#
# Epoch 00463: val_accuracy did not improve from 0.96411
# Epoch 464/500
#  - 7s - loss: 0.0327 - accuracy: 0.9834 - val_loss: 0.3718 - val_accuracy: 0.9602
#
# Epoch 00464: val_accuracy did not improve from 0.96411
# Epoch 465/500
#  - 7s - loss: 0.0319 - accuracy: 0.9837 - val_loss: 0.1323 - val_accuracy: 0.9597
#
# Epoch 00465: val_accuracy did not improve from 0.96411
# Epoch 466/500
#  - 7s - loss: 0.0401 - accuracy: 0.9799 - val_loss: 3.4799 - val_accuracy: 0.9451
#
# Epoch 00466: val_accuracy did not improve from 0.96411
# Epoch 467/500
#  - 7s - loss: 0.0325 - accuracy: 0.9836 - val_loss: 6.1265e-04 - val_accuracy: 0.9573
#
# Epoch 00467: val_accuracy did not improve from 0.96411
# Epoch 468/500
#  - 7s - loss: 0.0414 - accuracy: 0.9795 - val_loss: 0.3742 - val_accuracy: 0.9554
#
# Epoch 00468: val_accuracy did not improve from 0.96411
# Epoch 469/500
#  - 7s - loss: 0.0320 - accuracy: 0.9839 - val_loss: 7.7980e-04 - val_accuracy: 0.9597
#
# Epoch 00469: val_accuracy did not improve from 0.96411
# Epoch 470/500
#  - 7s - loss: 0.0345 - accuracy: 0.9825 - val_loss: 0.0439 - val_accuracy: 0.9565
#
# Epoch 00470: val_accuracy did not improve from 0.96411
# Epoch 471/500
#  - 7s - loss: 0.0538 - accuracy: 0.9758 - val_loss: 0.0251 - val_accuracy: 0.9533
#
# Epoch 00471: val_accuracy did not improve from 0.96411
# Epoch 472/500
#  - 7s - loss: 0.0305 - accuracy: 0.9847 - val_loss: 0.2588 - val_accuracy: 0.9599
#
# Epoch 00472: val_accuracy did not improve from 0.96411
# Epoch 473/500
#  - 7s - loss: 0.0324 - accuracy: 0.9833 - val_loss: 0.2385 - val_accuracy: 0.9588
#
# Epoch 00473: val_accuracy did not improve from 0.96411
# Epoch 474/500
#  - 7s - loss: 0.0400 - accuracy: 0.9807 - val_loss: 0.0469 - val_accuracy: 0.9566
#
# Epoch 00474: val_accuracy did not improve from 0.96411
# Epoch 475/500
#  - 7s - loss: 0.0400 - accuracy: 0.9812 - val_loss: 0.0373 - val_accuracy: 0.9530
#
# Epoch 00475: val_accuracy did not improve from 0.96411
# Epoch 476/500
#  - 7s - loss: 0.0339 - accuracy: 0.9829 - val_loss: 0.0886 - val_accuracy: 0.9556
#
# Epoch 00476: val_accuracy did not improve from 0.96411
# Epoch 477/500
#  - 7s - loss: 0.0308 - accuracy: 0.9843 - val_loss: 0.2668 - val_accuracy: 0.9521
#
# Epoch 00477: val_accuracy did not improve from 0.96411
# Epoch 478/500
#  - 7s - loss: 0.0511 - accuracy: 0.9782 - val_loss: 0.3755 - val_accuracy: 0.9435
# Epoch 00478: val_accuracy did not improve from 0.96411
# Epoch 479/500
#  - 7s - loss: 0.0365 - accuracy: 0.9816 - val_loss: 0.4225 - val_accuracy: 0.9607
#
# Epoch 00479: val_accuracy did not improve from 0.96411
# Epoch 480/500
#  - 7s - loss: 0.0278 - accuracy: 0.9861 - val_loss: 0.2241 - val_accuracy: 0.9601
#
# Epoch 00480: val_accuracy did not improve from 0.96411
# Epoch 481/500
#  - 7s - loss: 0.0382 - accuracy: 0.9809 - val_loss: 0.0054 - val_accuracy: 0.9571
#
# Epoch 00481: val_accuracy did not improve from 0.96411
# Epoch 482/500
#  - 7s - loss: 0.0369 - accuracy: 0.9816 - val_loss: 0.6573 - val_accuracy: 0.9443
#
# Epoch 00482: val_accuracy did not improve from 0.96411
# Epoch 483/500
#  - 7s - loss: 0.0334 - accuracy: 0.9831 - val_loss: 0.0631 - val_accuracy: 0.9585
#
# Epoch 00483: val_accuracy did not improve from 0.96411
# Epoch 484/500
#  - 7s - loss: 0.0393 - accuracy: 0.9814 - val_loss: 0.6634 - val_accuracy: 0.9616
#
# Epoch 00484: val_accuracy did not improve from 0.96411
# Epoch 485/500
#  - 7s - loss: 0.0300 - accuracy: 0.9850 - val_loss: 0.2605 - val_accuracy: 0.9631
#
# Epoch 00485: val_accuracy did not improve from 0.96411
# Epoch 486/500
#  - 7s - loss: 0.0342 - accuracy: 0.9830 - val_loss: 0.1371 - val_accuracy: 0.9454
#
# Epoch 00486: val_accuracy did not improve from 0.96411
# Epoch 487/500
#  - 7s - loss: 0.0338 - accuracy: 0.9827 - val_loss: 0.0794 - val_accuracy: 0.9578
#
# Epoch 00487: val_accuracy did not improve from 0.96411
# Epoch 488/500
#  - 7s - loss: 0.0341 - accuracy: 0.9829 - val_loss: 0.6021 - val_accuracy: 0.9592
#
# Epoch 00488: val_accuracy did not improve from 0.96411
# Epoch 489/500
#  - 7s - loss: 0.0478 - accuracy: 0.9787 - val_loss: 0.4517 - val_accuracy: 0.9173
#
# Epoch 00489: val_accuracy did not improve from 0.96411
# Epoch 490/500
#  - 7s - loss: 0.0375 - accuracy: 0.9818 - val_loss: 0.5049 - val_accuracy: 0.9658
#
# Epoch 00490: val_accuracy improved from 0.96411 to 0.96583, saving model to model/rapid_ascending 30_84_ohlcmacd.hdf5
# Epoch 491/500
#  - 7s - loss: 0.0289 - accuracy: 0.9855 - val_loss: 0.0530 - val_accuracy: 0.9623
#
# Epoch 00491: val_accuracy did not improve from 0.96583
# Epoch 492/500
#  - 7s - loss: 0.0320 - accuracy: 0.9838 - val_loss: 0.3171 - val_accuracy: 0.9591
#
# Epoch 00492: val_accuracy did not improve from 0.96583
# Epoch 493/500
#  - 7s - loss: 0.0308 - accuracy: 0.9844 - val_loss: 0.0908 - val_accuracy: 0.9557
#
# Epoch 00493: val_accuracy did not improve from 0.96583
# Epoch 494/500
#  - 7s - loss: 0.0474 - accuracy: 0.9793 - val_loss: 0.0506 - val_accuracy: 0.9614
#
# Epoch 00494: val_accuracy did not improve from 0.96583
# Epoch 495/500
#  - 7s - loss: 0.0312 - accuracy: 0.9843 - val_loss: 0.0547 - val_accuracy: 0.9418
#
# Epoch 00495: val_accuracy did not improve from 0.96583
# Epoch 496/500
#  - 7s - loss: 0.0296 - accuracy: 0.9852 - val_loss: 0.1049 - val_accuracy: 0.9533
#
# Epoch 00496: val_accuracy did not improve from 0.96583
# Epoch 497/500
#  - 7s - loss: 0.0292 - accuracy: 0.9852 - val_loss: 0.0709 - val_accuracy: 0.9599
#
# Epoch 00497: val_accuracy did not improve from 0.96583
# Epoch 498/500
#  - 7s - loss: 0.0430 - accuracy: 0.9795 - val_loss: 0.8160 - val_accuracy: 0.9558
#
# Epoch 00498: val_accuracy did not improve from 0.96583
# Epoch 499/500
#  - 7s - loss: 0.0277 - accuracy: 0.9860 - val_loss: 0.1332 - val_accuracy: 0.9601
#
# Epoch 00499: val_accuracy did not improve from 0.96583
# Epoch 500/500
#  - 7s - loss: 0.0332 - accuracy: 0.9835 - val_loss: 0.3535 - val_accuracy: 0.9573
#
# Epoch 00500: val_accuracy did not improve from 0.96583

# %%
from keras.models import load_model

model = load_model('model/rapid_ascending %s_%s.hdf5' % (input_data_length, model_num))
# model = load_model('/content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending %s.hdf5' % input_data_length)
# loss = model.evaluate_generator(test_flow, steps=len(X_test) / batch_size) 
# print("Test Loss " + str(loss[0]))
# print("Test Acc: " + str(loss[1]))

# loss = model.evaluate(X_val, Y_val) 
# print(X_val.shape)
# print(Y_val.shape)

# print("Val Loss " + str(loss[0]))
# print("Val Acc: " + str(loss[1]))

#     Prediction    #
Y_pred_ = model.predict(X_test, verbose=1)

# Y_pred = Y_pred_[:,[-1]]
# print(Y_pred.shape)
# print(Y_test.shape)
Y_pred = np.argmax(Y_pred_, axis=1)
t_te = np.argmax(Y_test, axis=1)

#     Manual processing     #
Y_pred_one = Y_pred_[:, [-1]]
print(Y_pred_)
max_value = np.max(Y_pred_one)
print(max_value)

limit_line = 0.9
Y_pred_one = np.where(Y_pred_one > max_value * limit_line, 1, 0)

# print(Y_pred_one)
Y_pred_one = Y_pred_one.reshape(-1,)
# print(Y_pred_1)
# print(Y_pred.shape)
# print(t_te.shape)

# fail = 0
# fail2 = 0
# for i in range(len(Y_pred)):
#   if Y_pred_1[i] != t_te[i]:
#     fail += 1

#   if Y_pred[i] != t_te[i]:
#     fail2 += 1

# print(1 - fail / len(Y_pred))
# print(1 - fail2 / len(Y_pred))

# print(np.sum(Y_pred), np.sum(t_te))
# print('Y_pred / Y_test :', np.sum(Y_pred) / np.sum(t_te))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(100,10))
plt.subplot(211)
plt.plot(Y_test, 'purple', label='test')

plt.subplot(212)
plt.plot(Y_pred_one, 'y', label='pred')
plt.show()
# plt.savefig('/content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending %s.png' % input_data_length)
# plt.close()
