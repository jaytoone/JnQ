# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     465         """
# --> 466         parts = [self.recv(flags, copy=copy, track=track)]
#     467         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-3aeef50c6911> in <module>()
#       1 from google.colab import drive
#       2
# ----> 3 drive.mount('/content/gdrive')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     236       auth_prompt = d.match.group(1) + '\nEnter your authorization code:\n'
#     237       with open(fifo, 'w') as fifo_file:
# --> 238         fifo_file.write(_getpass.getpass(auth_prompt) + '\n')
#     239       wrote_to_fifo = True
#     240   if not wrote_to_fifo:
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#     686             self._parent_ident,
#     687             self._parent_header,
# --> 688             password=True,
#     689         )
#     690
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import warnings

warnings.filterwarnings(action='ignore')
# %tensorflow_version 1.x
# %matplotlib inline


def min_max_scaler(x):
    scaled_x = (x - x.min()) / (x.max() - x.min())
    return scaled_x


def max_abs_scaler(x):
    scaled_x = x / abs(x).max()
    return scaled_x


# input_data_length = int(input('input_data_length : '))
input_data_length = 10
crop_size = 200
model_num = 105
# num_classes = 3

gdrive_path = '/content/gdrive/My Drive/Colab Notebooks/'

#           read reg ohlcv          #
file_path = gdrive_path + 'ohlcv_reg/'
file_list = os.listdir(file_path)
# print(file_list)
# breakpoint
file = file_list[-3]
print(file)
# breakpoint 
# file = '2020-04-02 BackTest GNT_from_excel.xlsx'
ohlcv_reg = pd.read_excel(file_path + file, index_col=0)
# print(ohlcv_reg.iloc[:, [-7]])
# breakpoint

#     X_data : idl 만큼의 close? (일단),    Y_data : reg
#     실시간으로 reg의 형태가 machine learning으로는 고정되지 않기 때문에,
#     먼저 고정을 시키고, deep learning을 이용해 실시간으로 고정된 regression 결과를 뽑아낼 수 있는지 확인한다.
#     충분히 가능성 있다.     #

#         reg_target = close인 경우 앞의 데이터가 산다.       #  close/ close_reg
ohlcv_reg = ohlcv_reg.values[sum(ohlcv_reg.MACD_Signal.isna()):, :]

reg_target = ohlcv_reg[:, [-7]].astype(np.float32)
reg_result = ohlcv_reg[:, [-5]].astype(np.float32)

# reg_target = max_abs_scaler(reg_target)
# reg_result = max_abs_scaler(reg_result)
# print(reg_target, reg_result)
# breakpoint

dataX, dataY = list(), list()
C, gamma, epsilon = 500, 20, 1
model = SVR(kernel='rbf', C=C, gamma=gamma, epsilon=epsilon)
for i in range(input_data_length, len(reg_target)):

  if i >= crop_size:
    x = np.arange(len(reg_target))[i - crop_size:i].reshape(-1, 1)
    y = reg_target[i - crop_size:i].reshape(-1, 1)
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    x = scaler_x.fit_transform(x)
    y = scaler_y.fit_transform(y)
    model.fit(x, y)
    osc_reg = model.predict(x)

    # group_x = osc_reg[i - input_data_length: i]
    group_x = osc_reg[-input_data_length:]
    group_y = reg_result[i]
    # print(group_x.shape)
    # breakpoint
    # quit()

    #   데이터 값에 결측치가 존재하는 경우 #
    # if sum(sum(np.isnan(group_x))) > 0:
    #     continue

    dataX.append(group_x)  # dataX 리스트에 추가
    dataY.append(group_y)

Made_X = np.array(dataX).reshape(-1, input_data_length, 1)
Made_Y = np.array(dataY)
# print(Made_X.shape, Made_Y.shape)
# breakpoint


from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(Made_X, Made_Y, test_size=0.4,
                                                   shuffle=False)
X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5,
                                                   shuffle=False)
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
print(Y_train.shape)
print(Y_test.shape)
print(Y_val.shape)
# breakpoint

row = X_train.shape[1]
col = X_train.shape[2]

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.layers import Dense, LSTM, Dropout, Input, Flatten
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix

def FER_Model(input_shape=(row, col)):

    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Dense(32)(visible)
    # net = layers.LSTM(10, return_sequences=True)(visible)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    
    net = layers.Dense(64)(net)
    # net = layers.LSTM(64, return_sequences=True)(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.Dropout(0.5)(net)

    # net = layers.Dense(50)(net)
    # # net = layers.LSTM(64, return_sequences=False)(net)
    # net = layers.LeakyReLU()(net)
    # # net = layers.Dropout(0.5)(net)

    # net = layers.Dense(32)(net)
    # # net = layers.LSTM(64, return_sequences=False)(net)
    # net = layers.LeakyReLU()(net)
    # # net = layers.Dropout(0.5)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(1)(net)
    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    model.summary()

    return model

model = FER_Model()
# from keras.models import load_model
# model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_ohlc.hdf5' % (input_data_length, model_num))

opt = Adam(lr=0.0001, decay=1e-6)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse'])
  
    
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath = gdrive_path + "model/rapid_ascending %s_%s_ohlc.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=50)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 300
history = model.fit(X_train, Y_train,
                    epochs=num_epochs,
                    batch_size=32,
                    validation_data=(X_val, Y_val),
                    verbose=2,
                    callbacks=callbacks_list,
                    shuffle=False,
                    )

#         RESULT COMPARING    #
pred_reg = model.predict(X_test)

plt.plot(Y_test, color='r', label='Y_test')
plt.plot(pred_reg, color='b',  label='pred_reg')
plt.show()
# Out:
# 2020-04-04 BackTest CTXC.xlsx
# (534, 10, 1)
# (178, 10, 1)
# (179, 10, 1)
# (534, 1)
# (178, 1)
# (179, 1)
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 10, 1)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10, 32)            64
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 10, 32)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10, 64)            2112
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 10, 64)            0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 641
# =================================================================
# Total params: 2,817
# Trainable params: 2,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 534 samples, validate on 179 samples
# Epoch 1/300
#  - 0s - loss: 1.5995 - mean_squared_error: 1.5995 - val_loss: 0.0420 - val_mean_squared_error: 0.0420
#
# Epoch 00001: val_loss improved from inf to 0.04200, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 2/300
#  - 0s - loss: 1.4916 - mean_squared_error: 1.4916 - val_loss: 0.0337 - val_mean_squared_error: 0.0337
#
# Epoch 00002: val_loss improved from 0.04200 to 0.03372, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 3/300
#  - 0s - loss: 1.4061 - mean_squared_error: 1.4061 - val_loss: 0.0274 - val_mean_squared_error: 0.0274
#
# Epoch 00003: val_loss improved from 0.03372 to 0.02737, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 4/300
#  - 0s - loss: 1.3372 - mean_squared_error: 1.3372 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
#
# Epoch 00004: val_loss improved from 0.02737 to 0.02272, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 5/300
#  - 0s - loss: 1.2828 - mean_squared_error: 1.2828 - val_loss: 0.0195 - val_mean_squared_error: 0.0195
#
# Epoch 00005: val_loss improved from 0.02272 to 0.01947, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 6/300
#  - 0s - loss: 1.2403 - mean_squared_error: 1.2403 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
#
# Epoch 00006: val_loss improved from 0.01947 to 0.01731, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 7/300
#  - 0s - loss: 1.2077 - mean_squared_error: 1.2077 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
#
# Epoch 00007: val_loss improved from 0.01731 to 0.01594, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 8/300
#  - 0s - loss: 1.1829 - mean_squared_error: 1.1829 - val_loss: 0.0152 - val_mean_squared_error: 0.0152
#
# Epoch 00008: val_loss improved from 0.01594 to 0.01517, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 9/300
#  - 0s - loss: 1.1641 - mean_squared_error: 1.1641 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
#
# Epoch 00009: val_loss improved from 0.01517 to 0.01481, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 10/300
#  - 0s - loss: 1.1499 - mean_squared_error: 1.1499 - val_loss: 0.0147 - val_mean_squared_error: 0.0147
#
# Epoch 00010: val_loss improved from 0.01481 to 0.01474, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 11/300
#  - 0s - loss: 1.1393 - mean_squared_error: 1.1393 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
#
# Epoch 00011: val_loss did not improve from 0.01474
# Epoch 12/300
#  - 0s - loss: 1.1312 - mean_squared_error: 1.1312 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
#
# Epoch 00012: val_loss did not improve from 0.01474
# Epoch 13/300
#  - 0s - loss: 1.1249 - mean_squared_error: 1.1249 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
#
# Epoch 00013: val_loss did not improve from 0.01474
# Epoch 14/300
#  - 0s - loss: 1.1200 - mean_squared_error: 1.1200 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
#
# Epoch 00014: val_loss did not improve from 0.01474
# Epoch 15/300
#  - 0s - loss: 1.1160 - mean_squared_error: 1.1160 - val_loss: 0.0160 - val_mean_squared_error: 0.0160
#
# Epoch 00015: val_loss did not improve from 0.01474
# Epoch 16/300
#  - 0s - loss: 1.1126 - mean_squared_error: 1.1126 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
#
# Epoch 00016: val_loss did not improve from 0.01474
# Epoch 17/300
#  - 0s - loss: 1.1097 - mean_squared_error: 1.1097 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
#
# Epoch 00017: val_loss did not improve from 0.01474
# Epoch 18/300
#  - 0s - loss: 1.1071 - mean_squared_error: 1.1071 - val_loss: 0.0170 - val_mean_squared_error: 0.0170
#
# Epoch 00018: val_loss did not improve from 0.01474
# Epoch 19/300
#  - 0s - loss: 1.1047 - mean_squared_error: 1.1047 - val_loss: 0.0173 - val_mean_squared_error: 0.0173
#
# Epoch 00019: val_loss did not improve from 0.01474
# Epoch 20/300
#  - 0s - loss: 1.1024 - mean_squared_error: 1.1024 - val_loss: 0.0176 - val_mean_squared_error: 0.0176
#
# Epoch 00020: val_loss did not improve from 0.01474
# Epoch 21/300
#  - 0s - loss: 1.1002 - mean_squared_error: 1.1002 - val_loss: 0.0179 - val_mean_squared_error: 0.0179
#
# Epoch 00021: val_loss did not improve from 0.01474
# Epoch 22/300
#  - 0s - loss: 1.0981 - mean_squared_error: 1.0981 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
#
# Epoch 00022: val_loss did not improve from 0.01474
# Epoch 23/300
#  - 0s - loss: 1.0960 - mean_squared_error: 1.0960 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
#
# Epoch 00023: val_loss did not improve from 0.01474
# Epoch 24/300
#  - 0s - loss: 1.0940 - mean_squared_error: 1.0940 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
#
# Epoch 00024: val_loss did not improve from 0.01474
# Epoch 25/300
#  - 0s - loss: 1.0919 - mean_squared_error: 1.0919 - val_loss: 0.0190 - val_mean_squared_error: 0.0190
#
# Epoch 00025: val_loss did not improve from 0.01474
# Epoch 26/300
#  - 0s - loss: 1.0898 - mean_squared_error: 1.0898 - val_loss: 0.0193 - val_mean_squared_error: 0.0193
#
# Epoch 00026: val_loss did not improve from 0.01474
# Epoch 27/300
#  - 0s - loss: 1.0878 - mean_squared_error: 1.0878 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
#
# Epoch 00027: val_loss did not improve from 0.01474
# Epoch 28/300
#  - 0s - loss: 1.0857 - mean_squared_error: 1.0857 - val_loss: 0.0199 - val_mean_squared_error: 0.0199
#
# Epoch 00028: val_loss did not improve from 0.01474
# Epoch 29/300
#  - 0s - loss: 1.0837 - mean_squared_error: 1.0837 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
#
# Epoch 00029: val_loss did not improve from 0.01474
# Epoch 30/300
#  - 0s - loss: 1.0816 - mean_squared_error: 1.0816 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
#
# Epoch 00030: val_loss did not improve from 0.01474
# Epoch 31/300
#  - 0s - loss: 1.0795 - mean_squared_error: 1.0795 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
#
# Epoch 00031: val_loss did not improve from 0.01474
# Epoch 32/300
#  - 0s - loss: 1.0774 - mean_squared_error: 1.0774 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
#
# Epoch 00032: val_loss did not improve from 0.01474
# Epoch 33/300
#  - 0s - loss: 1.0752 - mean_squared_error: 1.0752 - val_loss: 0.0217 - val_mean_squared_error: 0.0217
#
# Epoch 00033: val_loss did not improve from 0.01474
# Epoch 34/300
#  - 0s - loss: 1.0731 - mean_squared_error: 1.0731 - val_loss: 0.0220 - val_mean_squared_error: 0.0220
#
# Epoch 00034: val_loss did not improve from 0.01474
# Epoch 35/300
#  - 0s - loss: 1.0709 - mean_squared_error: 1.0709 - val_loss: 0.0224 - val_mean_squared_error: 0.0224
#
# Epoch 00035: val_loss did not improve from 0.01474
# Epoch 36/300
#  - 0s - loss: 1.0687 - mean_squared_error: 1.0687 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
#
# Epoch 00036: val_loss did not improve from 0.01474
# Epoch 37/300
#  - 0s - loss: 1.0666 - mean_squared_error: 1.0666 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
#
# Epoch 00037: val_loss did not improve from 0.01474
# Epoch 38/300
#  - 0s - loss: 1.0644 - mean_squared_error: 1.0644 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
#
# Epoch 00038: val_loss did not improve from 0.01474
# Epoch 39/300
#  - 0s - loss: 1.0623 - mean_squared_error: 1.0623 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
#
# Epoch 00039: val_loss did not improve from 0.01474
# Epoch 40/300
#  - 0s - loss: 1.0602 - mean_squared_error: 1.0602 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
#
# Epoch 00040: val_loss did not improve from 0.01474
# Epoch 41/300
#  - 0s - loss: 1.0580 - mean_squared_error: 1.0580 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
#
# Epoch 00041: val_loss did not improve from 0.01474
# Epoch 42/300
#  - 0s - loss: 1.0559 - mean_squared_error: 1.0559 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
#
# Epoch 00042: val_loss did not improve from 0.01474
# Epoch 43/300
#  - 0s - loss: 1.0539 - mean_squared_error: 1.0539 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
#
# Epoch 00043: val_loss did not improve from 0.01474
# Epoch 44/300
#  - 0s - loss: 1.0518 - mean_squared_error: 1.0518 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
#
# Epoch 00044: val_loss did not improve from 0.01474
# Epoch 45/300
#  - 0s - loss: 1.0498 - mean_squared_error: 1.0498 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
#
# Epoch 00045: val_loss did not improve from 0.01474
# Epoch 46/300
#  - 0s - loss: 1.0478 - mean_squared_error: 1.0478 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
#
# Epoch 00046: val_loss did not improve from 0.01474
# Epoch 47/300
#  - 0s - loss: 1.0458 - mean_squared_error: 1.0458 - val_loss: 0.0283 - val_mean_squared_error: 0.0283
#
# Epoch 00047: val_loss did not improve from 0.01474
# Epoch 48/300
#  - 0s - loss: 1.0438 - mean_squared_error: 1.0438 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
#
# Epoch 00048: val_loss did not improve from 0.01474
# Epoch 49/300
#  - 0s - loss: 1.0418 - mean_squared_error: 1.0418 - val_loss: 0.0294 - val_mean_squared_error: 0.0294
#
# Epoch 00049: val_loss did not improve from 0.01474
# Epoch 50/300
#  - 0s - loss: 1.0399 - mean_squared_error: 1.0399 - val_loss: 0.0300 - val_mean_squared_error: 0.0300
#
# Epoch 00050: val_loss did not improve from 0.01474
# Epoch 51/300
#  - 0s - loss: 1.0379 - mean_squared_error: 1.0379 - val_loss: 0.0306 - val_mean_squared_error: 0.0306
#
# Epoch 00051: val_loss did not improve from 0.01474
# Epoch 52/300
#  - 0s - loss: 1.0359 - mean_squared_error: 1.0359 - val_loss: 0.0313 - val_mean_squared_error: 0.0313
#
# Epoch 00052: val_loss did not improve from 0.01474
# Epoch 53/300
#  - 0s - loss: 1.0340 - mean_squared_error: 1.0340 - val_loss: 0.0319 - val_mean_squared_error: 0.0319
#
# Epoch 00053: val_loss did not improve from 0.01474
# Epoch 54/300
#  - 0s - loss: 1.0320 - mean_squared_error: 1.0320 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
#
# Epoch 00054: val_loss did not improve from 0.01474
# Epoch 55/300
#  - 0s - loss: 1.0300 - mean_squared_error: 1.0300 - val_loss: 0.0332 - val_mean_squared_error: 0.0332
#
# Epoch 00055: val_loss did not improve from 0.01474
# Epoch 56/300
#  - 0s - loss: 1.0281 - mean_squared_error: 1.0281 - val_loss: 0.0339 - val_mean_squared_error: 0.0339
#
# Epoch 00056: val_loss did not improve from 0.01474
# Epoch 57/300
#  - 0s - loss: 1.0261 - mean_squared_error: 1.0261 - val_loss: 0.0346 - val_mean_squared_error: 0.0346
#
# Epoch 00057: val_loss did not improve from 0.01474
# Epoch 58/300
#  - 0s - loss: 1.0241 - mean_squared_error: 1.0241 - val_loss: 0.0354 - val_mean_squared_error: 0.0354
#
# Epoch 00058: val_loss did not improve from 0.01474
# Epoch 59/300
#  - 0s - loss: 1.0221 - mean_squared_error: 1.0221 - val_loss: 0.0361 - val_mean_squared_error: 0.0361
#
# Epoch 00059: val_loss did not improve from 0.01474
# Epoch 60/300
#  - 0s - loss: 1.0201 - mean_squared_error: 1.0201 - val_loss: 0.0369 - val_mean_squared_error: 0.0369
#
# Epoch 00060: val_loss did not improve from 0.01474

# %%
file_list = os.listdir(file_path)
# print(file_list)
# breakpoint
file = file_list[-4]
ohlcv_reg = pd.read_excel(file_path + file, index_col=0)
# print(ohlcv_reg.iloc[:, [1, -5]])
# breakpoint

#     X_data : idl 만큼의 close? (일단),    Y_data : reg
#     실시간으로 reg의 형태가 machine learning으로는 고정되지 않기 때문에,
#     먼저 고정을 시키고, deep learning을 이용해 실시간으로 고정된 regression 결과를 뽑아낼 수 있는지 확인한다.
#     충분히 가능성 있다.     #

#         reg_target = close인 경우 앞의 데이터가 산다.       #  close/ close_reg
ohlcv_reg = ohlcv_reg.values[sum(ohlcv_reg.MACD_Signal.isna()):, :]
reg_target = ohlcv_reg[:, [-7]].astype(np.float32)
reg_result = ohlcv_reg[:, [-5]].astype(np.float32)
# ohlcv_data = ohlcv_reg.values[sum(ohlcv_reg.MACD_Signal.isna()):, :-4].astype(np.float)
# print(np.sum(ohlcv_reg==np.nan, axis=0))
# breakpoint

dataX, dataY = list(), list()
# C, gamma, epsilon = 500, 20, 1
# model = SVR(kernel='rbf', C=C, gamma=gamma, epsilon=epsilon)
for i in range(input_data_length, len(reg_target)):

  if i >= crop_size:
    x = np.arange(len(reg_target))[i - crop_size:i].reshape(-1, 1)
    y = reg_target[i - crop_size:i].reshape(-1, 1)
    scaler_x = StandardScaler()
    scaler_y = StandardScaler()
    x = scaler_x.fit_transform(x)
    y = scaler_y.fit_transform(y)
    model.fit(x, y)
    osc_reg = model.predict(x)

    # group_x = osc_reg[i - input_data_length: i]
    group_x = osc_reg[-input_data_length:]
    group_y = reg_result[i]
    # print(group_x.shape)
    # breakpoint
    # quit()

    #   데이터 값에 결측치가 존재하는 경우 #
    # if sum(sum(np.isnan(group_x))) > 0:
    #     continue

    dataX.append(group_x)  # dataX 리스트에 추가
    dataY.append(group_y)

Made_X = np.array(dataX)
Made_Y = np.array(dataY)
# print(Made_X.shape, Made_Y.shape)
# breakpoint

# from keras.models import load_model
# model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_ohlc.hdf5' % (input_data_length, model_num))

pred_reg = model.predict(Made_X)

# plt.plot(Made_Y, color='r', label='Y_test')
# plt.plot(reg_target[input_data_length:], color='m', label='MACD_OSC')
# plt.plot(pred_reg, color='b',  label='pred_reg')
# plt.legend(loc='upper right')

# span_list = list()
# for i in range(1, len(pred_reg)):
#     if pred_reg[i - 1] < pred_reg[i]:
#         span_list.append((i, i + 1))
# for i in range(len(span_list)):
#     plt.axvspan(span_list[i][0], span_list[i][1], facecolor='b', alpha=0.5)

# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-871c6fd02421> in <module>()
#      57 # model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_ohlc.hdf5' % (input_data_length, model_num))
#      58
# ---> 59 pred_reg = model.predict(Made_X)
#      60
#      61 # plt.plot(Made_Y, color='r', label='Y_test')
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     313         y_pred : array, shape (n_samples,)
#     314         """
# --> 315         X = self._validate_for_predict(X)
#     316         predict = self._sparse_predict if self._sparse else self._dense_predict
#     317         return predict(X)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py in _validate_for_predict(self, X)
#     465             raise ValueError("X.shape[1] = %d should be equal to %d, "
#     466                              "the number of features at training time" %
# --> 467                              (n_features, self.shape_fit_[1]))
#     468         return X
#     469
#
# ValueError: X.shape[1] = 10 should be equal to 1, the number of features at training time
