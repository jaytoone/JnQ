# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-02-11/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-02-11 BTCUSDT.xlsx', '2021-02-11 ETHUSDT.xlsx', '2021-02-11 BCHUSDT.xlsx', '2021-02-11 XRPUSDT.xlsx', '2021-02-11 EOSUSDT.xlsx', '2021-02-11 LTCUSDT.xlsx', '2021-02-11 ETCUSDT.xlsx', '2021-02-11 LINKUSDT.xlsx', '2021-02-11 XLMUSDT.xlsx', '2021-02-11 ADAUSDT.xlsx', '2021-02-11 XMRUSDT.xlsx', '2021-02-11 SXPUSDT.xlsx', '2021-02-11 KAVAUSDT.xlsx', '2021-02-11 BANDUSDT.xlsx', '2021-02-11 DASHUSDT.xlsx', '2021-02-11 ZECUSDT.xlsx', '2021-02-11 XTZUSDT.xlsx', '2021-02-11 BNBUSDT.xlsx', '2021-02-11 ATOMUSDT.xlsx', '2021-02-11 ONTUSDT.xlsx', '2021-02-11 IOTAUSDT.xlsx', '2021-02-11 BATUSDT.xlsx', '2021-02-11 NEOUSDT.xlsx', '2021-02-11 QTUMUSDT.xlsx', '2021-02-11 WAVESUSDT.xlsx', '2021-02-11 MKRUSDT.xlsx', '2021-02-11 SNXUSDT.xlsx', '2021-02-11 DOTUSDT.xlsx', '2021-02-11 THETAUSDT.xlsx', '2021-02-11 ALGOUSDT.xlsx', '2021-02-11 KNCUSDT.xlsx', '2021-02-11 ZRXUSDT.xlsx', '2021-02-11 COMPUSDT.xlsx', '2021-02-11 OMGUSDT.xlsx']

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

with open('./arima_result/prev_close_candi_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
  load_dict = pickle.load(f)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break


candis = list(load_dict.keys())
long_index = 0
leverage = 5
prev_x = None
total_x = None

seed = 1
random_state = 201
np.random.seed(seed)

for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue
  if '2021-03-02 DOTUSDT.xlsx' in candis[i]:
    # print('')
    continue

  if '04-08' not in candis[i]:  # <-- 04-08 includes all timestamp range
    continue

  # if '02-11' not in candis[i]:  # <-- 04-08 includes all timestamp range
  #   continue  

  if 'neo'.upper() not in candis[i]:
    continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      ohlcv = load_dict[key]['ohlcv']
      print('len(ohlcv) :', len(ohlcv))


      #       select timestamp range      #
      # time_index = ohlcv.index
      # total_stamp = list(map(lambda x: datetime.timestamp(x), time_index)) 

      # rm_index_amt = np.sum(np.array(total_stamp) < start_stamp)

      # ohlcv = ohlcv.iloc[rm_index_amt:]
      # print(ohlcv.head())

      # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.3)]  # exclude back_range
      # predictions = load_dict[key]['predictions']
      # err_ranges = load_dict[key]['err_ranges']
      print("ohlcv.index[0] :", ohlcv.index[0])
      print("ohlcv.index[-1] :", ohlcv.index[-1])

      predictions = ohlcv['close'].shift(1).values
      err_ranges = np.zeros_like(predictions)

      # leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]

      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[-len(predictions):]
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = np.array(predictions)
      long_ep = long_ep.reshape(-1, 1)

      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 45
      data_x, data_pr, data_updown = [], [], []
      data_index = []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          min_max = MinMaxScaler()
          temp_data[:, :5] = min_max.fit_transform(temp_data[:, :5])


          #   vol -> min_max
          min_max = MinMaxScaler()
          temp_data[:, [5]] = min_max.fit_transform(temp_data[:, [5]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      # input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      # input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      if prev_x is None:
        prev_x = input_x
        prev_pr = input_pr
        prev_ud = input_ud
        prev_index = input_index

        total_x = input_x
        total_pr = input_pr
        total_ud = input_ud
        total_index = input_index

      else:
        total_x = np.vstack((prev_x, input_x))
        total_pr = np.vstack((prev_pr, input_pr))
        total_ud = np.vstack((prev_ud, input_ud)) 
        total_index = np.vstack((prev_index, input_index)) 

        prev_x = total_x
        prev_pr = total_pr
        prev_ud = total_ud
        prev_index = total_index

        print('total_x.shape :', total_x.shape)
        print('total_pr.shape :', total_pr.shape)
        print('total_ud.shape :', total_ud.shape)
        print('prev_index.shape :', prev_index.shape)

      # if prev_train_x is None:
      #   prev_train_x = x_train
      #   prev_val_x = x_val
      #   prev_test_x = x_test
        
      #   prev_train_pr = pr_train
      #   prev_val_pr = pr_val
      #   prev_test_pr = pr_test

      #   prev_train_ud = ud_train
      #   prev_val_ud = ud_val
      #   prev_test_ud = ud_test

      # else:

      #   total_train_x = np.vstack((prev_train_x, x_train))
      #   total_val_x = np.vstack((prev_val_x, x_val))
      #   total_test_x = np.vstack((prev_test_x, x_test))
      #   total_train_pr = np.vstack((prev_train_pr, pr_train))
      #   total_val_pr = np.vstack((prev_val_pr, pr_val))
      #   total_test_pr = np.vstack((prev_test_pr, pr_test))
      #   total_train_ud = np.vstack((prev_train_ud, ud_train))
      #   total_val_ud = np.vstack((prev_val_ud, ud_val))
      #   total_test_ud = np.vstack((prev_test_ud, ud_test))
        
      #   prev_train_x = total_train_x
      #   prev_val_x = total_val_x
      #   prev_test_x = total_test_x
        
      #   prev_train_pr = total_train_pr
      #   prev_val_pr = total_val_pr
      #   prev_test_pr = total_test_pr

      #   prev_train_ud = total_train_ud
      #   prev_val_ud = total_val_ud
      #   prev_test_ud = total_test_ud
        
      #   print("total_train_x.shape :", total_train_x.shape)
      #   print("total_val_x.shape :", total_val_x.shape)
      #   print("total_test_x.shape :", total_test_x.shape)
      #   print("total_train_pr.shape :", total_train_pr.shape)
      #   print("total_val_pr.shape :", total_val_pr.shape)
      #   print("total_test_pr.shape :", total_test_pr.shape)
      #   print("total_train_ud.shape :", total_train_ud.shape)
      #   print("total_val_ud.shape :", total_val_ud.shape)
      #   print("total_test_ud.shape :", total_test_ud.shape)

  # break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  try:
    if len(total_x) > 300000:
      break
  except:
    pass
# Out:
# start_stamp : 0
# len(ohlcv) : 17129
# ohlcv.index[0] : 2020-04-17 00:29:59.999000
# ohlcv.index[-1] : 2021-04-08 20:29:59.999000
# -------------- 2021-04-08 NEOUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16382, 45, 6)
# input_x.shape : (16382, 45, 6)
# input_x.dtype : float32
# input_pr.shape : (16382, 1)
# input_ud.shape : (16382, 1)
# input_index.shape : (16382, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:226: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
period = 45

# _, row, col, _ = input_x.shape
_, row, col = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


#         get unique timestamp      #
print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=True, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)

index_train = np.array(index_train)
index_val = np.array(index_val)
index_test = np.array(index_test)
  
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

# del total_x
# Out:
# (array([Timestamp('2020-04-17 23:29:59.999000'),
#        Timestamp('2020-04-17 23:59:59.999000'),
#        Timestamp('2020-04-18 00:29:59.999000'), ...,
#        Timestamp('2021-04-08 19:29:59.999000'),
#        Timestamp('2021-04-08 19:59:59.999000'),
#        Timestamp('2021-04-08 20:29:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (9828,)
# stamp_val.shape : (3277,)
# stamp_test.shape : (3277,)
# HBox(children=(FloatProgress(value=0.0, max=16382.0), HTML(value='')))
# x_train.shape : (9828, 45, 6)
# x_val.shape : (3277, 45, 6)
# x_test.shape : (3277, 45, 6)

# %%
x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')
# Out:
# x series saved !
# pr series saved !

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape=(row, col)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    # net = layers.LSTM(10, return_sequences=False)(visible)

    net = layers.Dense(32)(visible)
    # net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)
    # net = layers.ReLU()(net)

    net = layers.Dense(64)(net)
    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    # net = layers.ReLU()(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Dense(128)(net)
    # # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.LeakyReLU()(net)

    # net = layers.Dense(256)(net)
    # # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # # net = layers.Activation('relu')(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.BatchNormalization()(net)


    # net = layers.Dropout(0.3)(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    # net = layers.ReLU()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    # net = layers.ReLU()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    print(model.summary())
    
    return model
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.4.3
# 2.4.1

# %% [markdown]
# ### **Data Split**

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight
# import cv2


_, row, col, = x_train.shape

#         pr label   #
y_train = np.where(pr_train > 1, 1, 0)
y_test = np.where(pr_test > 1, 1, 0)
y_val = np.where(pr_val > 1, 1, 0)


seed = 1
random_state = 20
np.random.seed(seed)
# tf.random.set_seed(seed)

#         up label      #
# y_train = np.where(ud_train > 1, 1, 0)
# y_test = np.where(ud_test > 1, 1, 0)
# y_val = np.where(ud_val > 1, 1, 0)

# print('pr_train[:5] :', pr_train[:5])
# print('ud_train[:5] :', ud_train[:5])
print('y_train[:5] :', y_train[:5])
print('y_train.dtype :', y_train.dtype)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

def class_ratio(in_list):

  return in_list / in_list[1]

print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)
# Out:
# y_train[:5] : [[0]
#  [1]
#  [1]
#  [1]
#  [0]]
# y_train.dtype : int64
# x_train.shape : (9828, 45, 6)
# x_test.shape : (3277, 45, 6)
# x_val.shape : (3277, 45, 6)
# y_train.shape : (9828, 1)
# y_test.shape : (3277, 1)
# y_val.shape : (3277, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([5510, 4318])) [1.27605373 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([1874, 1403])) [1.33570919 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([1805, 1472])) [1.22622283 1.        ]
# class_weights : {0: 0.8918330308529946, 1: 1.1380268642890228}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (9828, 2)
# y_val_ohe.shape : (3277, 2)
# y_test_ohe.shape : (3277, 2)

# %% [markdown]
# ### **Training**

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
# model_name = 'classifier_%s_close_updown_pr_theta_shuffle_without_back_03.h5' % period
# model_name = 'classifier_%s_close_updown_pr_theta_train_prevdata_005.h5' % period

# model_name = 'classifier_%s_close_updown_pr_theta_train_evendata_shuffle2_300k.h5' % period
# model_name = 'classifier_%s_close_updown_pr_all_pair_shuffle_final_0211_062.h5' % period
# model = keras.models.load_model(ckpt_path + model_name)

batch_size = 512
# _, row, col, = x_train.shape
# print("row, col :", row, col)

model = FER_Model(input_shape=(row, col))
# opt = Adam(lr=0.00001, decay=0.000005)
opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# model_name = 'classifier_%s_close_updown_pr_all_pair_shuffle_300k_timesplit.h5' % period
model_name = 'classifier_%s_rnn_close_updown_pr_neo_timesplit.h5' % period


checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=40)
# callbacks_list = [checkpoint, checkpoint2, checkpoint3]
callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000                    

history = model.fit(x_train, y_train_ohe,
                    steps_per_epoch=int(len(x_train) / batch_size), 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=(x_val, y_val_ohe),  
                    validation_steps=int(len(x_val) / batch_size),
                    shuffle=False)
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 45, 6)]           0
# _________________________________________________________________
# dense_18 (Dense)             (None, 45, 32)            224
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 45, 32)            0
# _________________________________________________________________
# dense_19 (Dense)             (None, 45, 64)            2112
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 45, 64)            0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 45, 64)            256
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2880)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               368768
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 379,746
# Trainable params: 379,618
# Non-trainable params: 128
# _________________________________________________________________
# None
# Epoch 1/1000
# 19/19 - 2s - loss: 0.9999 - accuracy: 0.5075 - val_loss: 0.6998 - val_accuracy: 0.4452
#
# Epoch 00001: val_loss improved from inf to 0.69983, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_rnn_close_updown_pr_neo_timesplit.h5
# Epoch 2/1000
# 19/19 - 0s - loss: 0.6966 - accuracy: 0.5460 - val_loss: 0.6968 - val_accuracy: 0.4706
#
# Epoch 00002: val_loss improved from 0.69983 to 0.69680, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_rnn_close_updown_pr_neo_timesplit.h5
# Epoch 3/1000
# 19/19 - 0s - loss: 0.6722 - accuracy: 0.5837 - val_loss: 0.6937 - val_accuracy: 0.4983
#
# Epoch 00003: val_loss improved from 0.69680 to 0.69368, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_rnn_close_updown_pr_neo_timesplit.h5
# Epoch 4/1000
# 19/19 - 0s - loss: 0.6432 - accuracy: 0.6244 - val_loss: 0.6952 - val_accuracy: 0.4843
#
# Epoch 00004: val_loss did not improve from 0.69368
# Epoch 5/1000
# 19/19 - 0s - loss: 0.6244 - accuracy: 0.6549 - val_loss: 0.6937 - val_accuracy: 0.4992
#
# Epoch 00005: val_loss did not improve from 0.69368
# Epoch 6/1000
# 19/19 - 0s - loss: 0.6028 - accuracy: 0.6797 - val_loss: 0.6937 - val_accuracy: 0.5032
#
# Epoch 00006: val_loss did not improve from 0.69368
# Epoch 7/1000
# 19/19 - 0s - loss: 0.5808 - accuracy: 0.7081 - val_loss: 0.6941 - val_accuracy: 0.4968
#
# Epoch 00007: val_loss did not improve from 0.69368
# Epoch 8/1000
# 19/19 - 0s - loss: 0.5582 - accuracy: 0.7289 - val_loss: 0.6946 - val_accuracy: 0.4934
#
# Epoch 00008: val_loss did not improve from 0.69368
# Epoch 9/1000
# 19/19 - 0s - loss: 0.5319 - accuracy: 0.7506 - val_loss: 0.6955 - val_accuracy: 0.5029
#
# Epoch 00009: val_loss did not improve from 0.69368
# Epoch 10/1000
# 19/19 - 0s - loss: 0.5055 - accuracy: 0.7729 - val_loss: 0.6957 - val_accuracy: 0.5017
#
# Epoch 00010: val_loss did not improve from 0.69368
# Epoch 11/1000
# 19/19 - 0s - loss: 0.4781 - accuracy: 0.7935 - val_loss: 0.6969 - val_accuracy: 0.5044
#
# Epoch 00011: val_loss did not improve from 0.69368
# Epoch 12/1000
# 19/19 - 0s - loss: 0.4505 - accuracy: 0.8133 - val_loss: 0.6978 - val_accuracy: 0.5111
#
# Epoch 00012: val_loss did not improve from 0.69368
# Epoch 13/1000
# 19/19 - 0s - loss: 0.4217 - accuracy: 0.8328 - val_loss: 0.7011 - val_accuracy: 0.5121
#
# Epoch 00013: val_loss did not improve from 0.69368
# Epoch 14/1000
# 19/19 - 0s - loss: 0.3913 - accuracy: 0.8488 - val_loss: 0.7056 - val_accuracy: 0.5121
#
# Epoch 00014: val_loss did not improve from 0.69368
# Epoch 15/1000
# 19/19 - 0s - loss: 0.3632 - accuracy: 0.8636 - val_loss: 0.7151 - val_accuracy: 0.5114
#
# Epoch 00015: val_loss did not improve from 0.69368
# Epoch 16/1000
# 19/19 - 0s - loss: 0.3383 - accuracy: 0.8772 - val_loss: 0.7245 - val_accuracy: 0.5145
#
# Epoch 00016: val_loss did not improve from 0.69368
# Epoch 17/1000
# 19/19 - 0s - loss: 0.3161 - accuracy: 0.8909 - val_loss: 0.7356 - val_accuracy: 0.5151
#
# Epoch 00017: val_loss did not improve from 0.69368
# Epoch 18/1000
# 19/19 - 0s - loss: 0.2995 - accuracy: 0.8949 - val_loss: 0.7419 - val_accuracy: 0.5154
#
# Epoch 00018: val_loss did not improve from 0.69368
# Epoch 19/1000
# 19/19 - 0s - loss: 0.2854 - accuracy: 0.8963 - val_loss: 0.7542 - val_accuracy: 0.5020
#
# Epoch 00019: val_loss did not improve from 0.69368
# Epoch 20/1000
# 19/19 - 0s - loss: 0.2910 - accuracy: 0.8841 - val_loss: 0.7588 - val_accuracy: 0.5124
#
# Epoch 00020: val_loss did not improve from 0.69368
# Epoch 21/1000
# 19/19 - 0s - loss: 0.2769 - accuracy: 0.8956 - val_loss: 0.7813 - val_accuracy: 0.5090
#
# Epoch 00021: val_loss did not improve from 0.69368
# Epoch 22/1000
# 19/19 - 0s - loss: 0.2490 - accuracy: 0.9133 - val_loss: 0.8132 - val_accuracy: 0.5035
#
# Epoch 00022: val_loss did not improve from 0.69368
# Epoch 23/1000
# 19/19 - 0s - loss: 0.2142 - accuracy: 0.9375 - val_loss: 0.8430 - val_accuracy: 0.4950
#
# Epoch 00023: val_loss did not improve from 0.69368
# Epoch 24/1000
# 19/19 - 0s - loss: 0.1922 - accuracy: 0.9485 - val_loss: 0.9118 - val_accuracy: 0.4937
#
# Epoch 00024: val_loss did not improve from 0.69368
# Epoch 25/1000
# 19/19 - 0s - loss: 0.1819 - accuracy: 0.9509 - val_loss: 0.9065 - val_accuracy: 0.5075
#
# Epoch 00025: val_loss did not improve from 0.69368
# Epoch 26/1000
# 19/19 - 0s - loss: 0.1770 - accuracy: 0.9487 - val_loss: 0.9465 - val_accuracy: 0.5264
#
# Epoch 00026: val_loss did not improve from 0.69368
# Epoch 27/1000
# 19/19 - 0s - loss: 0.1783 - accuracy: 0.9415 - val_loss: 1.0034 - val_accuracy: 0.5252
#
# Epoch 00027: val_loss did not improve from 0.69368
# Epoch 28/1000
# 19/19 - 0s - loss: 0.2047 - accuracy: 0.9220 - val_loss: 1.0867 - val_accuracy: 0.4937
#
# Epoch 00028: val_loss did not improve from 0.69368
# Epoch 29/1000
# 19/19 - 0s - loss: 0.2119 - accuracy: 0.9205 - val_loss: 1.1785 - val_accuracy: 0.5017
#
# Epoch 00029: val_loss did not improve from 0.69368
# Epoch 30/1000
# 19/19 - 0s - loss: 0.2063 - accuracy: 0.9209 - val_loss: 1.1050 - val_accuracy: 0.5105
#
# Epoch 00030: val_loss did not improve from 0.69368
# Epoch 31/1000
# 19/19 - 0s - loss: 0.1952 - accuracy: 0.9221 - val_loss: 1.1826 - val_accuracy: 0.4849
#
# Epoch 00031: val_loss did not improve from 0.69368
# Epoch 32/1000
# 19/19 - 0s - loss: 0.1581 - accuracy: 0.9512 - val_loss: 1.3399 - val_accuracy: 0.4879
#
# Epoch 00032: val_loss did not improve from 0.69368
# Epoch 33/1000
# 19/19 - 0s - loss: 0.1569 - accuracy: 0.9499 - val_loss: 1.2689 - val_accuracy: 0.4925
#
# Epoch 00033: val_loss did not improve from 0.69368
# Epoch 34/1000
# 19/19 - 0s - loss: 0.1511 - accuracy: 0.9498 - val_loss: 1.3009 - val_accuracy: 0.5182
#
# Epoch 00034: val_loss did not improve from 0.69368
# Epoch 35/1000
# 19/19 - 0s - loss: 0.1446 - accuracy: 0.9509 - val_loss: 1.3441 - val_accuracy: 0.5111
#
# Epoch 00035: val_loss did not improve from 0.69368
# Epoch 36/1000
# 19/19 - 0s - loss: 0.1441 - accuracy: 0.9535 - val_loss: 1.4573 - val_accuracy: 0.4806
#
# Epoch 00036: val_loss did not improve from 0.69368
# Epoch 37/1000
# 19/19 - 0s - loss: 0.1368 - accuracy: 0.9538 - val_loss: 1.5199 - val_accuracy: 0.4974
#
# Epoch 00037: val_loss did not improve from 0.69368
# Epoch 38/1000
# 19/19 - 0s - loss: 0.1213 - accuracy: 0.9639 - val_loss: 1.4831 - val_accuracy: 0.5038
#
# Epoch 00038: val_loss did not improve from 0.69368
# Epoch 39/1000
# 19/19 - 0s - loss: 0.1138 - accuracy: 0.9695 - val_loss: 1.6049 - val_accuracy: 0.4846
#
# Epoch 00039: val_loss did not improve from 0.69368
# Epoch 40/1000
# 19/19 - 0s - loss: 0.1266 - accuracy: 0.9629 - val_loss: 1.7725 - val_accuracy: 0.4663
#
# Epoch 00040: val_loss did not improve from 0.69368
# Epoch 41/1000
# 19/19 - 0s - loss: 0.1384 - accuracy: 0.9555 - val_loss: 1.6421 - val_accuracy: 0.4879
#
# Epoch 00041: val_loss did not improve from 0.69368
# Epoch 42/1000
# 19/19 - 0s - loss: 0.1295 - accuracy: 0.9570 - val_loss: 1.7554 - val_accuracy: 0.4940
#
# Epoch 00042: val_loss did not improve from 0.69368
# Epoch 43/1000
# 19/19 - 0s - loss: 0.1106 - accuracy: 0.9695 - val_loss: 1.6019 - val_accuracy: 0.4873
#
# Epoch 00043: val_loss did not improve from 0.69368
# Epoch 44/1000
# 19/19 - 0s - loss: 0.1145 - accuracy: 0.9645 - val_loss: 1.5697 - val_accuracy: 0.5084
#
# Epoch 00044: val_loss did not improve from 0.69368
# Epoch 45/1000
# 19/19 - 0s - loss: 0.1094 - accuracy: 0.9681 - val_loss: 1.6776 - val_accuracy: 0.4940
#
# Epoch 00045: val_loss did not improve from 0.69368
# Epoch 46/1000
# 19/19 - 0s - loss: 0.1319 - accuracy: 0.9511 - val_loss: 1.7795 - val_accuracy: 0.5169
#
# Epoch 00046: val_loss did not improve from 0.69368
# Epoch 47/1000
# 19/19 - 0s - loss: 0.1522 - accuracy: 0.9418 - val_loss: 1.8447 - val_accuracy: 0.5060
#
# Epoch 00047: val_loss did not improve from 0.69368
# Epoch 48/1000
# 19/19 - 0s - loss: 0.1934 - accuracy: 0.9165 - val_loss: 2.0478 - val_accuracy: 0.5166
#
# Epoch 00048: val_loss did not improve from 0.69368
# Epoch 49/1000
# 19/19 - 0s - loss: 0.1715 - accuracy: 0.9292 - val_loss: 1.8992 - val_accuracy: 0.5087
#
# Epoch 00049: val_loss did not improve from 0.69368
# Epoch 50/1000
# 19/19 - 0s - loss: 0.1868 - accuracy: 0.9217 - val_loss: 1.8468 - val_accuracy: 0.5230
#
# Epoch 00050: val_loss did not improve from 0.69368
# Epoch 51/1000
# 19/19 - 0s - loss: 0.1400 - accuracy: 0.9476 - val_loss: 1.6334 - val_accuracy: 0.5285
#
# Epoch 00051: val_loss did not improve from 0.69368
# Epoch 52/1000
# 19/19 - 0s - loss: 0.1147 - accuracy: 0.9587 - val_loss: 1.6268 - val_accuracy: 0.5383
#
# Epoch 00052: val_loss did not improve from 0.69368
# Epoch 53/1000
# 19/19 - 0s - loss: 0.0916 - accuracy: 0.9728 - val_loss: 1.7344 - val_accuracy: 0.5481
#
# Epoch 00053: val_loss did not improve from 0.69368
# Epoch 54/1000
# 19/19 - 0s - loss: 0.0845 - accuracy: 0.9784 - val_loss: 1.9604 - val_accuracy: 0.5508
#
# Epoch 00054: val_loss did not improve from 0.69368
# Epoch 55/1000
# 19/19 - 0s - loss: 0.0857 - accuracy: 0.9779 - val_loss: 2.1084 - val_accuracy: 0.5581
#
# Epoch 00055: val_loss did not improve from 0.69368
# Epoch 56/1000
# 19/19 - 0s - loss: 0.1108 - accuracy: 0.9617 - val_loss: 2.2878 - val_accuracy: 0.5569
#
# Epoch 00056: val_loss did not improve from 0.69368
# Epoch 57/1000
# 19/19 - 0s - loss: 0.1227 - accuracy: 0.9567 - val_loss: 2.1582 - val_accuracy: 0.5590
#
# Epoch 00057: val_loss did not improve from 0.69368
# Epoch 58/1000
# 19/19 - 0s - loss: 0.1365 - accuracy: 0.9484 - val_loss: 1.8676 - val_accuracy: 0.5349
#
# Epoch 00058: val_loss did not improve from 0.69368
# Epoch 59/1000
# 19/19 - 0s - loss: 0.1335 - accuracy: 0.9485 - val_loss: 1.7074 - val_accuracy: 0.5279
#
# Epoch 00059: val_loss did not improve from 0.69368
# Epoch 60/1000
# 19/19 - 0s - loss: 0.0874 - accuracy: 0.9734 - val_loss: 1.8448 - val_accuracy: 0.4944
#
# Epoch 00060: val_loss did not improve from 0.69368
# Epoch 61/1000
# 19/19 - 0s - loss: 0.0517 - accuracy: 0.9896 - val_loss: 1.8357 - val_accuracy: 0.5023
#
# Epoch 00061: val_loss did not improve from 0.69368
# Epoch 62/1000
# 19/19 - 0s - loss: 0.0328 - accuracy: 0.9972 - val_loss: 1.8001 - val_accuracy: 0.5151
#
# Epoch 00062: val_loss did not improve from 0.69368
# Epoch 63/1000
# 19/19 - 0s - loss: 0.0197 - accuracy: 0.9996 - val_loss: 1.7890 - val_accuracy: 0.5304
#
# Epoch 00063: val_loss did not improve from 0.69368
# Epoch 64/1000
# 19/19 - 0s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 1.8103 - val_accuracy: 0.5273
#
# Epoch 00064: val_loss did not improve from 0.69368
# Epoch 65/1000
# 19/19 - 0s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.8313 - val_accuracy: 0.5298
#
# Epoch 00065: val_loss did not improve from 0.69368
# Epoch 66/1000
# 19/19 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.8495 - val_accuracy: 0.5301
#
# Epoch 00066: val_loss did not improve from 0.69368
# Epoch 67/1000
# 19/19 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.8661 - val_accuracy: 0.5319
#
# Epoch 00067: val_loss did not improve from 0.69368
# Epoch 68/1000
# 19/19 - 0s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.8786 - val_accuracy: 0.5328
#
# Epoch 00068: val_loss did not improve from 0.69368
# Epoch 69/1000
# 19/19 - 0s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.8906 - val_accuracy: 0.5328
#
# Epoch 00069: val_loss did not improve from 0.69368
# Epoch 70/1000
# 19/19 - 0s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.9015 - val_accuracy: 0.5316
#
# Epoch 00070: val_loss did not improve from 0.69368
# Epoch 71/1000
# 19/19 - 0s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.9114 - val_accuracy: 0.5310
#
# Epoch 00071: val_loss did not improve from 0.69368
# Epoch 72/1000
# 19/19 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.9213 - val_accuracy: 0.5304
#
# Epoch 00072: val_loss did not improve from 0.69368
# Epoch 73/1000
# 19/19 - 0s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.9307 - val_accuracy: 0.5291
#
# Epoch 00073: val_loss did not improve from 0.69368
# Epoch 74/1000
# 19/19 - 0s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.9397 - val_accuracy: 0.5304
#
# Epoch 00074: val_loss did not improve from 0.69368
# Epoch 75/1000
# 19/19 - 0s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.9485 - val_accuracy: 0.5304
#
# Epoch 00075: val_loss did not improve from 0.69368
# Epoch 76/1000
# 19/19 - 0s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.9577 - val_accuracy: 0.5310
#
# Epoch 00076: val_loss did not improve from 0.69368
# Epoch 77/1000
# 19/19 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.9663 - val_accuracy: 0.5316
#
# Epoch 00077: val_loss did not improve from 0.69368
# Epoch 78/1000
# 19/19 - 0s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.9752 - val_accuracy: 0.5322
#
# Epoch 00078: val_loss did not improve from 0.69368
# Epoch 79/1000
# 19/19 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.9838 - val_accuracy: 0.5319
#
# Epoch 00079: val_loss did not improve from 0.69368
# Epoch 80/1000
# 19/19 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.9924 - val_accuracy: 0.5313
#
# Epoch 00080: val_loss did not improve from 0.69368
# Epoch 81/1000
# 19/19 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 2.0006 - val_accuracy: 0.5322
#
# Epoch 00081: val_loss did not improve from 0.69368
# Epoch 82/1000
# 19/19 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 2.0089 - val_accuracy: 0.5307
#
# Epoch 00082: val_loss did not improve from 0.69368
# Epoch 83/1000
# 19/19 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 2.0169 - val_accuracy: 0.5307
#
# Epoch 00083: val_loss did not improve from 0.69368
# Epoch 84/1000
# 19/19 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 2.0246 - val_accuracy: 0.5304
#
# Epoch 00084: val_loss did not improve from 0.69368
# Epoch 85/1000
# 19/19 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.0325 - val_accuracy: 0.5298
#
# Epoch 00085: val_loss did not improve from 0.69368
# Epoch 86/1000
# 19/19 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 2.0401 - val_accuracy: 0.5298
#
# Epoch 00086: val_loss did not improve from 0.69368
# Epoch 87/1000
# 19/19 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 2.0476 - val_accuracy: 0.5301
#
# Epoch 00087: val_loss did not improve from 0.69368
# Epoch 88/1000
# 19/19 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 2.0551 - val_accuracy: 0.5294
#
# Epoch 00088: val_loss did not improve from 0.69368
# Epoch 89/1000
# 19/19 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.0622 - val_accuracy: 0.5291
#
# Epoch 00089: val_loss did not improve from 0.69368
# Epoch 90/1000
# 19/19 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 2.0697 - val_accuracy: 0.5294
#
# Epoch 00090: val_loss did not improve from 0.69368
# Epoch 91/1000
# 19/19 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 2.0767 - val_accuracy: 0.5294
#
# Epoch 00091: val_loss did not improve from 0.69368
# Epoch 92/1000
# 19/19 - 0s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.0839 - val_accuracy: 0.5291
#
# Epoch 00092: val_loss did not improve from 0.69368
# Epoch 93/1000
# 19/19 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 2.0908 - val_accuracy: 0.5291
#
# Epoch 00093: val_loss did not improve from 0.69368
# Epoch 94/1000
# 19/19 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 2.0979 - val_accuracy: 0.5291
#
# Epoch 00094: val_loss did not improve from 0.69368
# Epoch 95/1000
# 19/19 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 2.1046 - val_accuracy: 0.5285
#
# Epoch 00095: val_loss did not improve from 0.69368
# Epoch 96/1000
# 19/19 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.1116 - val_accuracy: 0.5294
#
# Epoch 00096: val_loss did not improve from 0.69368
# Epoch 97/1000
# 19/19 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.1183 - val_accuracy: 0.5298
#
# Epoch 00097: val_loss did not improve from 0.69368
# Epoch 98/1000
# 19/19 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.1250 - val_accuracy: 0.5294
#
# Epoch 00098: val_loss did not improve from 0.69368
# Epoch 99/1000
# 19/19 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 2.1317 - val_accuracy: 0.5301
#
# Epoch 00099: val_loss did not improve from 0.69368
# Epoch 100/1000
# 19/19 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.1382 - val_accuracy: 0.5298
#
# Epoch 00100: val_loss did not improve from 0.69368
# Epoch 101/1000
# 19/19 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.1446 - val_accuracy: 0.5294
#
# Epoch 00101: val_loss did not improve from 0.69368
# Epoch 102/1000
# 19/19 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.1510 - val_accuracy: 0.5291
#
# Epoch 00102: val_loss did not improve from 0.69368
# Epoch 103/1000
# 19/19 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 2.1573 - val_accuracy: 0.5294
#
# Epoch 00103: val_loss did not improve from 0.69368
# Epoch 104/1000
# 19/19 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.1636 - val_accuracy: 0.5294
#
# Epoch 00104: val_loss did not improve from 0.69368
# Epoch 105/1000
# 19/19 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.1698 - val_accuracy: 0.5294
#
# Epoch 00105: val_loss did not improve from 0.69368
# Epoch 106/1000
# 19/19 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.1760 - val_accuracy: 0.5294
#
# Epoch 00106: val_loss did not improve from 0.69368
# Epoch 107/1000
# 19/19 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.1820 - val_accuracy: 0.5294
#
# Epoch 00107: val_loss did not improve from 0.69368
# Epoch 108/1000
# 19/19 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.1880 - val_accuracy: 0.5294
#
# Epoch 00108: val_loss did not improve from 0.69368
# Epoch 109/1000
# 19/19 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.1940 - val_accuracy: 0.5298
#
# Epoch 00109: val_loss did not improve from 0.69368
# Epoch 110/1000
# 19/19 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.1998 - val_accuracy: 0.5298
#
# Epoch 00110: val_loss did not improve from 0.69368
# Epoch 111/1000
# 19/19 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.2058 - val_accuracy: 0.5294
#
# Epoch 00111: val_loss did not improve from 0.69368
# Epoch 112/1000
# 19/19 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.2112 - val_accuracy: 0.5294
#
# Epoch 00112: val_loss did not improve from 0.69368
# Epoch 113/1000
# 19/19 - 0s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.2173 - val_accuracy: 0.5294
#
# Epoch 00113: val_loss did not improve from 0.69368
# Epoch 114/1000
# 19/19 - 0s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.2228 - val_accuracy: 0.5298
#
# Epoch 00114: val_loss did not improve from 0.69368
# Epoch 115/1000
# 19/19 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.2286 - val_accuracy: 0.5301
#
# Epoch 00115: val_loss did not improve from 0.69368
# Epoch 116/1000
# 19/19 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.2342 - val_accuracy: 0.5294
#
# Epoch 00116: val_loss did not improve from 0.69368
# Epoch 117/1000
# 19/19 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.2396 - val_accuracy: 0.5304
#
# Epoch 00117: val_loss did not improve from 0.69368
# Epoch 118/1000
# 19/19 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.2451 - val_accuracy: 0.5298
#
# Epoch 00118: val_loss did not improve from 0.69368
# Epoch 119/1000
# 19/19 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.2506 - val_accuracy: 0.5298
#
# Epoch 00119: val_loss did not improve from 0.69368
# Epoch 120/1000
# 19/19 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.2560 - val_accuracy: 0.5298
#
# Epoch 00120: val_loss did not improve from 0.69368
# Epoch 121/1000
# 19/19 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.2613 - val_accuracy: 0.5298
#
# Epoch 00121: val_loss did not improve from 0.69368
# Epoch 122/1000
# 19/19 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.2669 - val_accuracy: 0.5294
#
# Epoch 00122: val_loss did not improve from 0.69368
# Epoch 123/1000
# 19/19 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.2721 - val_accuracy: 0.5294
#
# Epoch 00123: val_loss did not improve from 0.69368
# Epoch 124/1000
# 19/19 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.2774 - val_accuracy: 0.5294
#
# Epoch 00124: val_loss did not improve from 0.69368
# Epoch 125/1000
# 19/19 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.2827 - val_accuracy: 0.5294
#
# Epoch 00125: val_loss did not improve from 0.69368
# Epoch 126/1000
# 19/19 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.2879 - val_accuracy: 0.5291
#
# Epoch 00126: val_loss did not improve from 0.69368
# Epoch 127/1000
# 19/19 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.2933 - val_accuracy: 0.5291
#
# Epoch 00127: val_loss did not improve from 0.69368
# Epoch 128/1000
# 19/19 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.2984 - val_accuracy: 0.5291
#
# Epoch 00128: val_loss did not improve from 0.69368
# Epoch 129/1000
# 19/19 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.3034 - val_accuracy: 0.5288
#
# Epoch 00129: val_loss did not improve from 0.69368
# Epoch 130/1000
# 19/19 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.3084 - val_accuracy: 0.5285
#
# Epoch 00130: val_loss did not improve from 0.69368
# Epoch 131/1000
# 19/19 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.3136 - val_accuracy: 0.5285
#
# Epoch 00131: val_loss did not improve from 0.69368
# Epoch 132/1000
# 19/19 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 2.3184 - val_accuracy: 0.5285
#
# Epoch 00132: val_loss did not improve from 0.69368
# Epoch 133/1000
# 19/19 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.3235 - val_accuracy: 0.5285
#
# Epoch 00133: val_loss did not improve from 0.69368
# Epoch 134/1000
# 19/19 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.3283 - val_accuracy: 0.5291
#
# Epoch 00134: val_loss did not improve from 0.69368
# Epoch 135/1000
# 19/19 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.3333 - val_accuracy: 0.5291
#
# Epoch 00135: val_loss did not improve from 0.69368
# Epoch 136/1000
# 19/19 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.3381 - val_accuracy: 0.5291
#
# Epoch 00136: val_loss did not improve from 0.69368
# Epoch 137/1000
# 19/19 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.3430 - val_accuracy: 0.5285
#
# Epoch 00137: val_loss did not improve from 0.69368
# Epoch 138/1000
# 19/19 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.3477 - val_accuracy: 0.5298
#
# Epoch 00138: val_loss did not improve from 0.69368
# Epoch 139/1000
# 19/19 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.3526 - val_accuracy: 0.5285
#
# Epoch 00139: val_loss did not improve from 0.69368
# Epoch 140/1000
# 19/19 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.3572 - val_accuracy: 0.5285
#
# Epoch 00140: val_loss did not improve from 0.69368
# Epoch 141/1000
# 19/19 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.3620 - val_accuracy: 0.5288
#
# Epoch 00141: val_loss did not improve from 0.69368
# Epoch 142/1000
# 19/19 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.3666 - val_accuracy: 0.5298
#
# Epoch 00142: val_loss did not improve from 0.69368
# Epoch 143/1000
# 19/19 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.3712 - val_accuracy: 0.5294
#
# Epoch 00143: val_loss did not improve from 0.69368
# Epoch 144/1000
# 19/19 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.3759 - val_accuracy: 0.5294
#
# Epoch 00144: val_loss did not improve from 0.69368
# Epoch 145/1000
# 19/19 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.3805 - val_accuracy: 0.5294
#
# Epoch 00145: val_loss did not improve from 0.69368
# Epoch 146/1000
# 19/19 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.3850 - val_accuracy: 0.5294
#
# Epoch 00146: val_loss did not improve from 0.69368
# Epoch 147/1000
# 19/19 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.3896 - val_accuracy: 0.5294
#
# Epoch 00147: val_loss did not improve from 0.69368
# Epoch 148/1000
# 19/19 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.3941 - val_accuracy: 0.5294
#
# Epoch 00148: val_loss did not improve from 0.69368
# Epoch 149/1000
# 19/19 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.3986 - val_accuracy: 0.5294
#
# Epoch 00149: val_loss did not improve from 0.69368
# Epoch 150/1000
# 19/19 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.4031 - val_accuracy: 0.5294
#
# Epoch 00150: val_loss did not improve from 0.69368
# Epoch 151/1000
# 19/19 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.4076 - val_accuracy: 0.5291
#
# Epoch 00151: val_loss did not improve from 0.69368
# Epoch 152/1000
# 19/19 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.4119 - val_accuracy: 0.5288
#
# Epoch 00152: val_loss did not improve from 0.69368
# Epoch 153/1000
# 19/19 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.4164 - val_accuracy: 0.5288
#
# Epoch 00153: val_loss did not improve from 0.69368
# Epoch 154/1000
# 19/19 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.4207 - val_accuracy: 0.5288
#
# Epoch 00154: val_loss did not improve from 0.69368
# Epoch 155/1000
# 19/19 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.4251 - val_accuracy: 0.5291
#
# Epoch 00155: val_loss did not improve from 0.69368
# Epoch 156/1000
# 19/19 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.4293 - val_accuracy: 0.5291
#
# Epoch 00156: val_loss did not improve from 0.69368
# Epoch 157/1000
# 19/19 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.4336 - val_accuracy: 0.5294
#
# Epoch 00157: val_loss did not improve from 0.69368
# Epoch 158/1000
# 19/19 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.4380 - val_accuracy: 0.5294
#
# Epoch 00158: val_loss did not improve from 0.69368
# Epoch 159/1000
# 19/19 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.4421 - val_accuracy: 0.5294
#
# Epoch 00159: val_loss did not improve from 0.69368
# Epoch 160/1000
# 19/19 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.4464 - val_accuracy: 0.5288
#
# Epoch 00160: val_loss did not improve from 0.69368
# Epoch 161/1000
# 19/19 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.4506 - val_accuracy: 0.5288
#
# Epoch 00161: val_loss did not improve from 0.69368
# Epoch 162/1000
# 19/19 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.4548 - val_accuracy: 0.5285
#
# Epoch 00162: val_loss did not improve from 0.69368
# Epoch 163/1000
# 19/19 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.4590 - val_accuracy: 0.5285
#
# Epoch 00163: val_loss did not improve from 0.69368
# Epoch 164/1000
# 19/19 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.4630 - val_accuracy: 0.5282
#
# Epoch 00164: val_loss did not improve from 0.69368
# Epoch 165/1000
# 19/19 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.4672 - val_accuracy: 0.5282
#
# Epoch 00165: val_loss did not improve from 0.69368
# Epoch 166/1000
# 19/19 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.4713 - val_accuracy: 0.5282
#
# Epoch 00166: val_loss did not improve from 0.69368
# Epoch 167/1000
# 19/19 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.4753 - val_accuracy: 0.5282
#
# Epoch 00167: val_loss did not improve from 0.69368
# Epoch 168/1000
# 19/19 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.4794 - val_accuracy: 0.5285
#
# Epoch 00168: val_loss did not improve from 0.69368
# Epoch 169/1000
# 19/19 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.4834 - val_accuracy: 0.5285
#
# Epoch 00169: val_loss did not improve from 0.69368
# Epoch 170/1000
# 19/19 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.4875 - val_accuracy: 0.5285
#
# Epoch 00170: val_loss did not improve from 0.69368
# Epoch 171/1000
# 19/19 - 0s - loss: 9.9611e-04 - accuracy: 1.0000 - val_loss: 2.4914 - val_accuracy: 0.5282
#
# Epoch 00171: val_loss did not improve from 0.69368
# Epoch 172/1000
# 19/19 - 0s - loss: 9.8301e-04 - accuracy: 1.0000 - val_loss: 2.4956 - val_accuracy: 0.5282
#
# Epoch 00172: val_loss did not improve from 0.69368
# Epoch 173/1000
# 19/19 - 0s - loss: 9.7014e-04 - accuracy: 1.0000 - val_loss: 2.4995 - val_accuracy: 0.5279
#
# Epoch 00173: val_loss did not improve from 0.69368
# Epoch 174/1000
# 19/19 - 0s - loss: 9.5750e-04 - accuracy: 1.0000 - val_loss: 2.5035 - val_accuracy: 0.5282
#
# Epoch 00174: val_loss did not improve from 0.69368
# Epoch 175/1000
# 19/19 - 0s - loss: 9.4511e-04 - accuracy: 1.0000 - val_loss: 2.5076 - val_accuracy: 0.5276
#
# Epoch 00175: val_loss did not improve from 0.69368
# Epoch 176/1000
# 19/19 - 0s - loss: 9.3289e-04 - accuracy: 1.0000 - val_loss: 2.5115 - val_accuracy: 0.5276
#
# Epoch 00176: val_loss did not improve from 0.69368
# Epoch 177/1000
# 19/19 - 0s - loss: 9.2087e-04 - accuracy: 1.0000 - val_loss: 2.5154 - val_accuracy: 0.5279
#
# Epoch 00177: val_loss did not improve from 0.69368
# Epoch 178/1000
# 19/19 - 0s - loss: 9.0912e-04 - accuracy: 1.0000 - val_loss: 2.5193 - val_accuracy: 0.5282
#
# Epoch 00178: val_loss did not improve from 0.69368
# Epoch 179/1000
# 19/19 - 0s - loss: 8.9749e-04 - accuracy: 1.0000 - val_loss: 2.5232 - val_accuracy: 0.5285
#
# Epoch 00179: val_loss did not improve from 0.69368
# Epoch 180/1000
# 19/19 - 0s - loss: 8.8611e-04 - accuracy: 1.0000 - val_loss: 2.5271 - val_accuracy: 0.5285
#
# Epoch 00180: val_loss did not improve from 0.69368
# Epoch 181/1000
# 19/19 - 0s - loss: 8.7494e-04 - accuracy: 1.0000 - val_loss: 2.5309 - val_accuracy: 0.5291
#
# Epoch 00181: val_loss did not improve from 0.69368
# Epoch 182/1000
# 19/19 - 0s - loss: 8.6390e-04 - accuracy: 1.0000 - val_loss: 2.5348 - val_accuracy: 0.5285
#
# Epoch 00182: val_loss did not improve from 0.69368
# Epoch 183/1000
# 19/19 - 0s - loss: 8.5313e-04 - accuracy: 1.0000 - val_loss: 2.5386 - val_accuracy: 0.5291
#
# Epoch 00183: val_loss did not improve from 0.69368
# Epoch 184/1000
# 19/19 - 0s - loss: 8.4244e-04 - accuracy: 1.0000 - val_loss: 2.5424 - val_accuracy: 0.5288
#
# Epoch 00184: val_loss did not improve from 0.69368
# Epoch 185/1000
# 19/19 - 0s - loss: 8.3196e-04 - accuracy: 1.0000 - val_loss: 2.5462 - val_accuracy: 0.5285
#
# Epoch 00185: val_loss did not improve from 0.69368
# Epoch 186/1000
# 19/19 - 0s - loss: 8.2168e-04 - accuracy: 1.0000 - val_loss: 2.5500 - val_accuracy: 0.5291
#
# Epoch 00186: val_loss did not improve from 0.69368
# Epoch 187/1000
# 19/19 - 0s - loss: 8.1160e-04 - accuracy: 1.0000 - val_loss: 2.5537 - val_accuracy: 0.5288
#
# Epoch 00187: val_loss did not improve from 0.69368
# Epoch 188/1000
# 19/19 - 0s - loss: 8.0156e-04 - accuracy: 1.0000 - val_loss: 2.5575 - val_accuracy: 0.5298
#
# Epoch 00188: val_loss did not improve from 0.69368
# Epoch 189/1000
# 19/19 - 0s - loss: 7.9171e-04 - accuracy: 1.0000 - val_loss: 2.5614 - val_accuracy: 0.5294
#
# Epoch 00189: val_loss did not improve from 0.69368
# Epoch 190/1000
# 19/19 - 0s - loss: 7.8214e-04 - accuracy: 1.0000 - val_loss: 2.5650 - val_accuracy: 0.5288
#
# Epoch 00190: val_loss did not improve from 0.69368
# Epoch 191/1000
# 19/19 - 0s - loss: 7.7255e-04 - accuracy: 1.0000 - val_loss: 2.5688 - val_accuracy: 0.5285
#
# Epoch 00191: val_loss did not improve from 0.69368
# Epoch 192/1000
# 19/19 - 0s - loss: 7.6321e-04 - accuracy: 1.0000 - val_loss: 2.5725 - val_accuracy: 0.5288
#
# Epoch 00192: val_loss did not improve from 0.69368
# Epoch 193/1000
# 19/19 - 0s - loss: 7.5406e-04 - accuracy: 1.0000 - val_loss: 2.5761 - val_accuracy: 0.5288
#
# Epoch 00193: val_loss did not improve from 0.69368
# Epoch 194/1000
# 19/19 - 0s - loss: 7.4488e-04 - accuracy: 1.0000 - val_loss: 2.5799 - val_accuracy: 0.5291
#
# Epoch 00194: val_loss did not improve from 0.69368
# Epoch 195/1000
# 19/19 - 0s - loss: 7.3604e-04 - accuracy: 1.0000 - val_loss: 2.5836 - val_accuracy: 0.5291
#
# Epoch 00195: val_loss did not improve from 0.69368
# Epoch 196/1000
# 19/19 - 0s - loss: 7.2720e-04 - accuracy: 1.0000 - val_loss: 2.5871 - val_accuracy: 0.5288
#
# Epoch 00196: val_loss did not improve from 0.69368
# Epoch 197/1000
# 19/19 - 0s - loss: 7.1854e-04 - accuracy: 1.0000 - val_loss: 2.5907 - val_accuracy: 0.5291
#
# Epoch 00197: val_loss did not improve from 0.69368
# Epoch 198/1000
# 19/19 - 0s - loss: 7.1002e-04 - accuracy: 1.0000 - val_loss: 2.5945 - val_accuracy: 0.5291
#
# Epoch 00198: val_loss did not improve from 0.69368
# Epoch 199/1000
# 19/19 - 0s - loss: 7.0162e-04 - accuracy: 1.0000 - val_loss: 2.5980 - val_accuracy: 0.5285
#
# Epoch 00199: val_loss did not improve from 0.69368
# Epoch 200/1000
# 19/19 - 0s - loss: 6.9332e-04 - accuracy: 1.0000 - val_loss: 2.6017 - val_accuracy: 0.5288
#
# Epoch 00200: val_loss did not improve from 0.69368
# Epoch 201/1000
# 19/19 - 0s - loss: 6.8519e-04 - accuracy: 1.0000 - val_loss: 2.6052 - val_accuracy: 0.5285
#
# Epoch 00201: val_loss did not improve from 0.69368
# Epoch 202/1000
# 19/19 - 0s - loss: 6.7716e-04 - accuracy: 1.0000 - val_loss: 2.6089 - val_accuracy: 0.5282
#
# Epoch 00202: val_loss did not improve from 0.69368
# Epoch 203/1000
# 19/19 - 0s - loss: 6.6924e-04 - accuracy: 1.0000 - val_loss: 2.6124 - val_accuracy: 0.5276
#
# Epoch 00203: val_loss did not improve from 0.69368
# Epoch 204/1000
# 19/19 - 0s - loss: 6.6143e-04 - accuracy: 1.0000 - val_loss: 2.6160 - val_accuracy: 0.5276
#
# Epoch 00204: val_loss did not improve from 0.69368
# Epoch 205/1000
# 19/19 - 0s - loss: 6.5377e-04 - accuracy: 1.0000 - val_loss: 2.6195 - val_accuracy: 0.5276
#
# Epoch 00205: val_loss did not improve from 0.69368
# Epoch 206/1000
# 19/19 - 0s - loss: 6.4620e-04 - accuracy: 1.0000 - val_loss: 2.6232 - val_accuracy: 0.5279
#
# Epoch 00206: val_loss did not improve from 0.69368
# Epoch 207/1000
# 19/19 - 0s - loss: 6.3874e-04 - accuracy: 1.0000 - val_loss: 2.6268 - val_accuracy: 0.5276
#
# Epoch 00207: val_loss did not improve from 0.69368
# Epoch 208/1000
# 19/19 - 0s - loss: 6.3139e-04 - accuracy: 1.0000 - val_loss: 2.6303 - val_accuracy: 0.5282
#
# Epoch 00208: val_loss did not improve from 0.69368
# Epoch 209/1000
# 19/19 - 0s - loss: 6.2415e-04 - accuracy: 1.0000 - val_loss: 2.6337 - val_accuracy: 0.5282
#
# Epoch 00209: val_loss did not improve from 0.69368
# Epoch 210/1000
# 19/19 - 0s - loss: 6.1700e-04 - accuracy: 1.0000 - val_loss: 2.6375 - val_accuracy: 0.5288
#
# Epoch 00210: val_loss did not improve from 0.69368
# Epoch 211/1000
# 19/19 - 0s - loss: 6.0997e-04 - accuracy: 1.0000 - val_loss: 2.6408 - val_accuracy: 0.5282
#
# Epoch 00211: val_loss did not improve from 0.69368
# Epoch 212/1000
# 19/19 - 0s - loss: 6.0304e-04 - accuracy: 1.0000 - val_loss: 2.6444 - val_accuracy: 0.5288
#
# Epoch 00212: val_loss did not improve from 0.69368
# Epoch 213/1000
# 19/19 - 0s - loss: 5.9618e-04 - accuracy: 1.0000 - val_loss: 2.6479 - val_accuracy: 0.5288
#
# Epoch 00213: val_loss did not improve from 0.69368
# Epoch 214/1000
# 19/19 - 0s - loss: 5.8946e-04 - accuracy: 1.0000 - val_loss: 2.6514 - val_accuracy: 0.5285
#
# Epoch 00214: val_loss did not improve from 0.69368
# Epoch 215/1000
# 19/19 - 0s - loss: 5.8280e-04 - accuracy: 1.0000 - val_loss: 2.6547 - val_accuracy: 0.5294
#
# Epoch 00215: val_loss did not improve from 0.69368
# Epoch 216/1000
# 19/19 - 0s - loss: 5.7625e-04 - accuracy: 1.0000 - val_loss: 2.6583 - val_accuracy: 0.5294
#
# Epoch 00216: val_loss did not improve from 0.69368
# Epoch 217/1000
# 19/19 - 0s - loss: 5.6976e-04 - accuracy: 1.0000 - val_loss: 2.6618 - val_accuracy: 0.5285
#
# Epoch 00217: val_loss did not improve from 0.69368
# Epoch 218/1000
# 19/19 - 0s - loss: 5.6343e-04 - accuracy: 1.0000 - val_loss: 2.6652 - val_accuracy: 0.5285
#
# Epoch 00218: val_loss did not improve from 0.69368
# Epoch 219/1000
# 19/19 - 0s - loss: 5.5710e-04 - accuracy: 1.0000 - val_loss: 2.6688 - val_accuracy: 0.5291
#
# Epoch 00219: val_loss did not improve from 0.69368
# Epoch 220/1000
# 19/19 - 0s - loss: 5.5090e-04 - accuracy: 1.0000 - val_loss: 2.6721 - val_accuracy: 0.5288
#
# Epoch 00220: val_loss did not improve from 0.69368
# Epoch 221/1000
# 19/19 - 0s - loss: 5.4478e-04 - accuracy: 1.0000 - val_loss: 2.6755 - val_accuracy: 0.5288
#
# Epoch 00221: val_loss did not improve from 0.69368
# Epoch 222/1000
# 19/19 - 0s - loss: 5.3877e-04 - accuracy: 1.0000 - val_loss: 2.6790 - val_accuracy: 0.5288
#
# Epoch 00222: val_loss did not improve from 0.69368
# Epoch 223/1000
# 19/19 - 0s - loss: 5.3276e-04 - accuracy: 1.0000 - val_loss: 2.6824 - val_accuracy: 0.5288
#
# Epoch 00223: val_loss did not improve from 0.69368
# Epoch 224/1000
# 19/19 - 0s - loss: 5.2691e-04 - accuracy: 1.0000 - val_loss: 2.6858 - val_accuracy: 0.5288
#
# Epoch 00224: val_loss did not improve from 0.69368
# Epoch 225/1000
# 19/19 - 0s - loss: 5.2113e-04 - accuracy: 1.0000 - val_loss: 2.6892 - val_accuracy: 0.5291
#
# Epoch 00225: val_loss did not improve from 0.69368
# Epoch 226/1000
# 19/19 - 0s - loss: 5.1537e-04 - accuracy: 1.0000 - val_loss: 2.6927 - val_accuracy: 0.5285
#
# Epoch 00226: val_loss did not improve from 0.69368
# Epoch 227/1000
# 19/19 - 0s - loss: 5.0976e-04 - accuracy: 1.0000 - val_loss: 2.6960 - val_accuracy: 0.5291
#
# Epoch 00227: val_loss did not improve from 0.69368
# Epoch 228/1000
# 19/19 - 0s - loss: 5.0419e-04 - accuracy: 1.0000 - val_loss: 2.6994 - val_accuracy: 0.5288
#
# Epoch 00228: val_loss did not improve from 0.69368
# Epoch 229/1000
# 19/19 - 0s - loss: 4.9866e-04 - accuracy: 1.0000 - val_loss: 2.7028 - val_accuracy: 0.5285
#
# Epoch 00229: val_loss did not improve from 0.69368
# Epoch 230/1000
# 19/19 - 0s - loss: 4.9325e-04 - accuracy: 1.0000 - val_loss: 2.7062 - val_accuracy: 0.5288
#
# Epoch 00230: val_loss did not improve from 0.69368
# Epoch 231/1000
# 19/19 - 0s - loss: 4.8793e-04 - accuracy: 1.0000 - val_loss: 2.7095 - val_accuracy: 0.5285
#
# Epoch 00231: val_loss did not improve from 0.69368
# Epoch 232/1000
# 19/19 - 0s - loss: 4.8259e-04 - accuracy: 1.0000 - val_loss: 2.7129 - val_accuracy: 0.5285
#
# Epoch 00232: val_loss did not improve from 0.69368
# Epoch 233/1000
# 19/19 - 0s - loss: 4.7741e-04 - accuracy: 1.0000 - val_loss: 2.7163 - val_accuracy: 0.5291
#
# Epoch 00233: val_loss did not improve from 0.69368
# Epoch 234/1000
# 19/19 - 0s - loss: 4.7226e-04 - accuracy: 1.0000 - val_loss: 2.7194 - val_accuracy: 0.5288
#
# Epoch 00234: val_loss did not improve from 0.69368
# Epoch 235/1000
# 19/19 - 0s - loss: 4.6716e-04 - accuracy: 1.0000 - val_loss: 2.7229 - val_accuracy: 0.5298
#
# Epoch 00235: val_loss did not improve from 0.69368
# Epoch 236/1000
# 19/19 - 0s - loss: 4.6217e-04 - accuracy: 1.0000 - val_loss: 2.7262 - val_accuracy: 0.5294
#
# Epoch 00236: val_loss did not improve from 0.69368
# Epoch 237/1000
# 19/19 - 0s - loss: 4.5720e-04 - accuracy: 1.0000 - val_loss: 2.7295 - val_accuracy: 0.5294
#
# Epoch 00237: val_loss did not improve from 0.69368
# Epoch 238/1000
# 19/19 - 0s - loss: 4.5231e-04 - accuracy: 1.0000 - val_loss: 2.7327 - val_accuracy: 0.5294
#
# Epoch 00238: val_loss did not improve from 0.69368
# Epoch 239/1000
# 19/19 - 0s - loss: 4.4749e-04 - accuracy: 1.0000 - val_loss: 2.7362 - val_accuracy: 0.5294
#
# Epoch 00239: val_loss did not improve from 0.69368
# Epoch 240/1000
# 19/19 - 0s - loss: 4.4272e-04 - accuracy: 1.0000 - val_loss: 2.7395 - val_accuracy: 0.5294
#
# Epoch 00240: val_loss did not improve from 0.69368
# Epoch 241/1000
# 19/19 - 0s - loss: 4.3803e-04 - accuracy: 1.0000 - val_loss: 2.7428 - val_accuracy: 0.5291
#
# Epoch 00241: val_loss did not improve from 0.69368
# Epoch 242/1000
# 19/19 - 0s - loss: 4.3336e-04 - accuracy: 1.0000 - val_loss: 2.7461 - val_accuracy: 0.5298
#
# Epoch 00242: val_loss did not improve from 0.69368
# Epoch 243/1000
# 19/19 - 0s - loss: 4.2881e-04 - accuracy: 1.0000 - val_loss: 2.7493 - val_accuracy: 0.5298
#
# Epoch 00243: val_loss did not improve from 0.69368
# Epoch 244/1000
# 19/19 - 0s - loss: 4.2426e-04 - accuracy: 1.0000 - val_loss: 2.7526 - val_accuracy: 0.5294
#
# Epoch 00244: val_loss did not improve from 0.69368
# Epoch 245/1000
# 19/19 - 0s - loss: 4.1980e-04 - accuracy: 1.0000 - val_loss: 2.7560 - val_accuracy: 0.5291
#
# Epoch 00245: val_loss did not improve from 0.69368
# Epoch 246/1000
# 19/19 - 0s - loss: 4.1538e-04 - accuracy: 1.0000 - val_loss: 2.7592 - val_accuracy: 0.5294
#
# Epoch 00246: val_loss did not improve from 0.69368
# Epoch 247/1000
# 19/19 - 0s - loss: 4.1102e-04 - accuracy: 1.0000 - val_loss: 2.7625 - val_accuracy: 0.5285
#
# Epoch 00247: val_loss did not improve from 0.69368
# Epoch 248/1000
# 19/19 - 0s - loss: 4.0673e-04 - accuracy: 1.0000 - val_loss: 2.7658 - val_accuracy: 0.5294
#
# Epoch 00248: val_loss did not improve from 0.69368
# Epoch 249/1000
# 19/19 - 0s - loss: 4.0247e-04 - accuracy: 1.0000 - val_loss: 2.7690 - val_accuracy: 0.5288
#
# Epoch 00249: val_loss did not improve from 0.69368
# Epoch 250/1000
# 19/19 - 0s - loss: 3.9825e-04 - accuracy: 1.0000 - val_loss: 2.7722 - val_accuracy: 0.5285
#
# Epoch 00250: val_loss did not improve from 0.69368
# Epoch 251/1000
# 19/19 - 0s - loss: 3.9413e-04 - accuracy: 1.0000 - val_loss: 2.7755 - val_accuracy: 0.5291
#
# Epoch 00251: val_loss did not improve from 0.69368
# Epoch 252/1000
# 19/19 - 0s - loss: 3.9003e-04 - accuracy: 1.0000 - val_loss: 2.7787 - val_accuracy: 0.5291
#
# Epoch 00252: val_loss did not improve from 0.69368
# Epoch 253/1000
# 19/19 - 0s - loss: 3.8597e-04 - accuracy: 1.0000 - val_loss: 2.7819 - val_accuracy: 0.5291
#
# Epoch 00253: val_loss did not improve from 0.69368
# Epoch 254/1000
# 19/19 - 0s - loss: 3.8199e-04 - accuracy: 1.0000 - val_loss: 2.7852 - val_accuracy: 0.5291
#
# Epoch 00254: val_loss did not improve from 0.69368
# Epoch 255/1000
# 19/19 - 0s - loss: 3.7803e-04 - accuracy: 1.0000 - val_loss: 2.7883 - val_accuracy: 0.5288
#
# Epoch 00255: val_loss did not improve from 0.69368
# Epoch 256/1000
# 19/19 - 0s - loss: 3.7412e-04 - accuracy: 1.0000 - val_loss: 2.7916 - val_accuracy: 0.5288
#
# Epoch 00256: val_loss did not improve from 0.69368
# Epoch 257/1000
# 19/19 - 0s - loss: 3.7027e-04 - accuracy: 1.0000 - val_loss: 2.7948 - val_accuracy: 0.5288
#
# Epoch 00257: val_loss did not improve from 0.69368
# Epoch 258/1000
# 19/19 - 0s - loss: 3.6646e-04 - accuracy: 1.0000 - val_loss: 2.7980 - val_accuracy: 0.5288
#
# Epoch 00258: val_loss did not improve from 0.69368
# Epoch 259/1000
# 19/19 - 0s - loss: 3.6269e-04 - accuracy: 1.0000 - val_loss: 2.8012 - val_accuracy: 0.5282
#
# Epoch 00259: val_loss did not improve from 0.69368
# Epoch 260/1000
# 19/19 - 0s - loss: 3.5897e-04 - accuracy: 1.0000 - val_loss: 2.8044 - val_accuracy: 0.5288
#
# Epoch 00260: val_loss did not improve from 0.69368
# Epoch 261/1000
# 19/19 - 0s - loss: 3.5532e-04 - accuracy: 1.0000 - val_loss: 2.8076 - val_accuracy: 0.5285
#
# Epoch 00261: val_loss did not improve from 0.69368
# Epoch 262/1000
# 19/19 - 0s - loss: 3.5166e-04 - accuracy: 1.0000 - val_loss: 2.8108 - val_accuracy: 0.5288
#
# Epoch 00262: val_loss did not improve from 0.69368
# Epoch 263/1000
# 19/19 - 0s - loss: 3.4808e-04 - accuracy: 1.0000 - val_loss: 2.8139 - val_accuracy: 0.5282
#
# Epoch 00263: val_loss did not improve from 0.69368
# Epoch 264/1000
# 19/19 - 0s - loss: 3.4454e-04 - accuracy: 1.0000 - val_loss: 2.8172 - val_accuracy: 0.5282
#
# Epoch 00264: val_loss did not improve from 0.69368
# Epoch 265/1000
# 19/19 - 0s - loss: 3.4102e-04 - accuracy: 1.0000 - val_loss: 2.8203 - val_accuracy: 0.5282
#
# Epoch 00265: val_loss did not improve from 0.69368
# Epoch 266/1000
# 19/19 - 0s - loss: 3.3755e-04 - accuracy: 1.0000 - val_loss: 2.8235 - val_accuracy: 0.5279
#
# Epoch 00266: val_loss did not improve from 0.69368
# Epoch 267/1000
# 19/19 - 0s - loss: 3.3415e-04 - accuracy: 1.0000 - val_loss: 2.8266 - val_accuracy: 0.5279
#
# Epoch 00267: val_loss did not improve from 0.69368
# Epoch 268/1000
# 19/19 - 0s - loss: 3.3076e-04 - accuracy: 1.0000 - val_loss: 2.8297 - val_accuracy: 0.5282
#
# Epoch 00268: val_loss did not improve from 0.69368
# Epoch 269/1000
# 19/19 - 0s - loss: 3.2739e-04 - accuracy: 1.0000 - val_loss: 2.8329 - val_accuracy: 0.5282
#
# Epoch 00269: val_loss did not improve from 0.69368
# Epoch 270/1000
# 19/19 - 0s - loss: 3.2412e-04 - accuracy: 1.0000 - val_loss: 2.8361 - val_accuracy: 0.5282
#
# Epoch 00270: val_loss did not improve from 0.69368
# Epoch 271/1000
# 19/19 - 0s - loss: 3.2082e-04 - accuracy: 1.0000 - val_loss: 2.8392 - val_accuracy: 0.5276
#
# Epoch 00271: val_loss did not improve from 0.69368
# Epoch 272/1000
# 19/19 - 0s - loss: 3.1761e-04 - accuracy: 1.0000 - val_loss: 2.8424 - val_accuracy: 0.5279
#
# Epoch 00272: val_loss did not improve from 0.69368
# Epoch 273/1000
# 19/19 - 0s - loss: 3.1440e-04 - accuracy: 1.0000 - val_loss: 2.8455 - val_accuracy: 0.5276
#
# Epoch 00273: val_loss did not improve from 0.69368
# Epoch 274/1000
# 19/19 - 0s - loss: 3.1126e-04 - accuracy: 1.0000 - val_loss: 2.8487 - val_accuracy: 0.5279
#
# Epoch 00274: val_loss did not improve from 0.69368
# Epoch 275/1000
# 19/19 - 0s - loss: 3.0812e-04 - accuracy: 1.0000 - val_loss: 2.8517 - val_accuracy: 0.5279
#
# Epoch 00275: val_loss did not improve from 0.69368
# Epoch 276/1000
# 19/19 - 0s - loss: 3.0504e-04 - accuracy: 1.0000 - val_loss: 2.8550 - val_accuracy: 0.5276
#
# Epoch 00276: val_loss did not improve from 0.69368
# Epoch 277/1000
# 19/19 - 0s - loss: 3.0201e-04 - accuracy: 1.0000 - val_loss: 2.8579 - val_accuracy: 0.5279
#
# Epoch 00277: val_loss did not improve from 0.69368
# Epoch 278/1000
# 19/19 - 0s - loss: 2.9897e-04 - accuracy: 1.0000 - val_loss: 2.8611 - val_accuracy: 0.5276
#
# Epoch 00278: val_loss did not improve from 0.69368
# Epoch 279/1000
# 19/19 - 0s - loss: 2.9600e-04 - accuracy: 1.0000 - val_loss: 2.8643 - val_accuracy: 0.5276
#
# Epoch 00279: val_loss did not improve from 0.69368
# Epoch 280/1000
# 19/19 - 0s - loss: 2.9306e-04 - accuracy: 1.0000 - val_loss: 2.8673 - val_accuracy: 0.5276
#
# Epoch 00280: val_loss did not improve from 0.69368
# Epoch 281/1000
# 19/19 - 0s - loss: 2.9014e-04 - accuracy: 1.0000 - val_loss: 2.8704 - val_accuracy: 0.5273
#
# Epoch 00281: val_loss did not improve from 0.69368
# Epoch 282/1000
# 19/19 - 0s - loss: 2.8725e-04 - accuracy: 1.0000 - val_loss: 2.8735 - val_accuracy: 0.5273
#
# Epoch 00282: val_loss did not improve from 0.69368
# Epoch 283/1000
# 19/19 - 0s - loss: 2.8442e-04 - accuracy: 1.0000 - val_loss: 2.8766 - val_accuracy: 0.5273
#
# Epoch 00283: val_loss did not improve from 0.69368
# Epoch 284/1000
# 19/19 - 0s - loss: 2.8159e-04 - accuracy: 1.0000 - val_loss: 2.8796 - val_accuracy: 0.5273
#
# Epoch 00284: val_loss did not improve from 0.69368
# Epoch 285/1000
# 19/19 - 0s - loss: 2.7881e-04 - accuracy: 1.0000 - val_loss: 2.8828 - val_accuracy: 0.5276
#
# Epoch 00285: val_loss did not improve from 0.69368
# Epoch 286/1000
# 19/19 - 0s - loss: 2.7606e-04 - accuracy: 1.0000 - val_loss: 2.8858 - val_accuracy: 0.5279
#
# Epoch 00286: val_loss did not improve from 0.69368
# Epoch 287/1000
# 19/19 - 0s - loss: 2.7334e-04 - accuracy: 1.0000 - val_loss: 2.8888 - val_accuracy: 0.5276
#
# Epoch 00287: val_loss did not improve from 0.69368
# Epoch 288/1000
# 19/19 - 0s - loss: 2.7063e-04 - accuracy: 1.0000 - val_loss: 2.8920 - val_accuracy: 0.5279
#
# Epoch 00288: val_loss did not improve from 0.69368
# Epoch 289/1000
# 19/19 - 0s - loss: 2.6797e-04 - accuracy: 1.0000 - val_loss: 2.8950 - val_accuracy: 0.5279
#
# Epoch 00289: val_loss did not improve from 0.69368
# Epoch 290/1000
# 19/19 - 0s - loss: 2.6534e-04 - accuracy: 1.0000 - val_loss: 2.8981 - val_accuracy: 0.5279
#
# Epoch 00290: val_loss did not improve from 0.69368
# Epoch 291/1000
# 19/19 - 0s - loss: 2.6274e-04 - accuracy: 1.0000 - val_loss: 2.9011 - val_accuracy: 0.5282
#
# Epoch 00291: val_loss did not improve from 0.69368
# Epoch 292/1000
# 19/19 - 0s - loss: 2.6016e-04 - accuracy: 1.0000 - val_loss: 2.9042 - val_accuracy: 0.5282
#
# Epoch 00292: val_loss did not improve from 0.69368
# Epoch 293/1000
# 19/19 - 0s - loss: 2.5760e-04 - accuracy: 1.0000 - val_loss: 2.9072 - val_accuracy: 0.5282
#
# Epoch 00293: val_loss did not improve from 0.69368
# Epoch 294/1000
# 19/19 - 0s - loss: 2.5509e-04 - accuracy: 1.0000 - val_loss: 2.9102 - val_accuracy: 0.5282
#
# Epoch 00294: val_loss did not improve from 0.69368
# ...
# Epoch 543/1000
# 19/19 - 0s - loss: 2.5128e-05 - accuracy: 1.0000 - val_loss: 3.6348 - val_accuracy: 0.5264
#
# Epoch 00543: val_loss did not improve from 0.69368
# Epoch 544/1000
# 19/19 - 0s - loss: 2.4901e-05 - accuracy: 1.0000 - val_loss: 3.6376 - val_accuracy: 0.5264
#
# Epoch 00544: val_loss did not improve from 0.69368
# Epoch 545/1000
# 19/19 - 0s - loss: 2.4672e-05 - accuracy: 1.0000 - val_loss: 3.6406 - val_accuracy: 0.5267
#
# Epoch 00545: val_loss did not improve from 0.69368
# Epoch 546/1000
# 19/19 - 0s - loss: 2.4445e-05 - accuracy: 1.0000 - val_loss: 3.6435 - val_accuracy: 0.5267
#
# Epoch 00546: val_loss did not improve from 0.69368
# Epoch 547/1000
# 19/19 - 0s - loss: 2.4222e-05 - accuracy: 1.0000 - val_loss: 3.6463 - val_accuracy: 0.5267
#
# Epoch 00547: val_loss did not improve from 0.69368
# Epoch 548/1000
# 19/19 - 0s - loss: 2.4001e-05 - accuracy: 1.0000 - val_loss: 3.6493 - val_accuracy: 0.5270
#
# Epoch 00548: val_loss did not improve from 0.69368
# Epoch 549/1000
# 19/19 - 0s - loss: 2.3782e-05 - accuracy: 1.0000 - val_loss: 3.6523 - val_accuracy: 0.5267
#
# Epoch 00549: val_loss did not improve from 0.69368
# Epoch 550/1000
# 19/19 - 0s - loss: 2.3564e-05 - accuracy: 1.0000 - val_loss: 3.6550 - val_accuracy: 0.5267
#
# Epoch 00550: val_loss did not improve from 0.69368
# Epoch 551/1000
# 19/19 - 0s - loss: 2.3347e-05 - accuracy: 1.0000 - val_loss: 3.6579 - val_accuracy: 0.5264
#
# Epoch 00551: val_loss did not improve from 0.69368
# Epoch 552/1000
# 19/19 - 0s - loss: 2.3134e-05 - accuracy: 1.0000 - val_loss: 3.6609 - val_accuracy: 0.5261
#
# Epoch 00552: val_loss did not improve from 0.69368
# Epoch 553/1000
# 19/19 - 0s - loss: 2.2923e-05 - accuracy: 1.0000 - val_loss: 3.6638 - val_accuracy: 0.5264
#
# Epoch 00553: val_loss did not improve from 0.69368
# Epoch 554/1000
# 19/19 - 0s - loss: 2.2711e-05 - accuracy: 1.0000 - val_loss: 3.6666 - val_accuracy: 0.5264
#
# Epoch 00554: val_loss did not improve from 0.69368
# Epoch 555/1000
# 19/19 - 0s - loss: 2.2503e-05 - accuracy: 1.0000 - val_loss: 3.6696 - val_accuracy: 0.5261
#
# Epoch 00555: val_loss did not improve from 0.69368
# Epoch 556/1000
# 19/19 - 0s - loss: 2.2297e-05 - accuracy: 1.0000 - val_loss: 3.6726 - val_accuracy: 0.5261
#
# Epoch 00556: val_loss did not improve from 0.69368
# Epoch 557/1000
# 19/19 - 0s - loss: 2.2094e-05 - accuracy: 1.0000 - val_loss: 3.6754 - val_accuracy: 0.5261
#
# Epoch 00557: val_loss did not improve from 0.69368
# Epoch 558/1000
# 19/19 - 0s - loss: 2.1891e-05 - accuracy: 1.0000 - val_loss: 3.6783 - val_accuracy: 0.5261
#
# Epoch 00558: val_loss did not improve from 0.69368
# Epoch 559/1000
# 19/19 - 0s - loss: 2.1690e-05 - accuracy: 1.0000 - val_loss: 3.6812 - val_accuracy: 0.5261
#
# Epoch 00559: val_loss did not improve from 0.69368
# Epoch 560/1000
# 19/19 - 0s - loss: 2.1493e-05 - accuracy: 1.0000 - val_loss: 3.6841 - val_accuracy: 0.5264
#
# Epoch 00560: val_loss did not improve from 0.69368
# Epoch 561/1000
# 19/19 - 0s - loss: 2.1296e-05 - accuracy: 1.0000 - val_loss: 3.6870 - val_accuracy: 0.5261
#
# Epoch 00561: val_loss did not improve from 0.69368
# Epoch 562/1000
# 19/19 - 0s - loss: 2.1099e-05 - accuracy: 1.0000 - val_loss: 3.6899 - val_accuracy: 0.5261
#
# Epoch 00562: val_loss did not improve from 0.69368
# Epoch 563/1000
# 19/19 - 0s - loss: 2.0906e-05 - accuracy: 1.0000 - val_loss: 3.6928 - val_accuracy: 0.5261
#
# Epoch 00563: val_loss did not improve from 0.69368
# Epoch 564/1000
# 19/19 - 0s - loss: 2.0716e-05 - accuracy: 1.0000 - val_loss: 3.6957 - val_accuracy: 0.5261
#
# Epoch 00564: val_loss did not improve from 0.69368
# Epoch 565/1000
# 19/19 - 0s - loss: 2.0527e-05 - accuracy: 1.0000 - val_loss: 3.6986 - val_accuracy: 0.5258
#
# Epoch 00565: val_loss did not improve from 0.69368
# Epoch 566/1000
# 19/19 - 0s - loss: 2.0336e-05 - accuracy: 1.0000 - val_loss: 3.7016 - val_accuracy: 0.5258
#
# Epoch 00566: val_loss did not improve from 0.69368
# Epoch 567/1000
# 19/19 - 0s - loss: 2.0151e-05 - accuracy: 1.0000 - val_loss: 3.7045 - val_accuracy: 0.5261
#
# Epoch 00567: val_loss did not improve from 0.69368
# Epoch 568/1000
# 19/19 - 0s - loss: 1.9967e-05 - accuracy: 1.0000 - val_loss: 3.7074 - val_accuracy: 0.5261
#
# Epoch 00568: val_loss did not improve from 0.69368
# Epoch 569/1000
# 19/19 - 0s - loss: 1.9785e-05 - accuracy: 1.0000 - val_loss: 3.7103 - val_accuracy: 0.5258
#
# Epoch 00569: val_loss did not improve from 0.69368
# Epoch 570/1000
# 19/19 - 0s - loss: 1.9601e-05 - accuracy: 1.0000 - val_loss: 3.7132 - val_accuracy: 0.5258
#
# Epoch 00570: val_loss did not improve from 0.69368
# Epoch 571/1000
# 19/19 - 0s - loss: 1.9423e-05 - accuracy: 1.0000 - val_loss: 3.7161 - val_accuracy: 0.5261
#
# Epoch 00571: val_loss did not improve from 0.69368
# Epoch 572/1000
# 19/19 - 0s - loss: 1.9245e-05 - accuracy: 1.0000 - val_loss: 3.7191 - val_accuracy: 0.5264
#
# Epoch 00572: val_loss did not improve from 0.69368
# Epoch 573/1000
# 19/19 - 0s - loss: 1.9069e-05 - accuracy: 1.0000 - val_loss: 3.7220 - val_accuracy: 0.5264
#
# Epoch 00573: val_loss did not improve from 0.69368
# Epoch 574/1000
# 19/19 - 0s - loss: 1.8893e-05 - accuracy: 1.0000 - val_loss: 3.7247 - val_accuracy: 0.5264
#
# Epoch 00574: val_loss did not improve from 0.69368
# Epoch 575/1000
# 19/19 - 0s - loss: 1.8721e-05 - accuracy: 1.0000 - val_loss: 3.7278 - val_accuracy: 0.5264
#
# Epoch 00575: val_loss did not improve from 0.69368
# Epoch 576/1000
# 19/19 - 0s - loss: 1.8549e-05 - accuracy: 1.0000 - val_loss: 3.7307 - val_accuracy: 0.5264
#
# Epoch 00576: val_loss did not improve from 0.69368
# Epoch 577/1000
# 19/19 - 0s - loss: 1.8379e-05 - accuracy: 1.0000 - val_loss: 3.7335 - val_accuracy: 0.5261
#
# Epoch 00577: val_loss did not improve from 0.69368
# Epoch 578/1000
# 19/19 - 0s - loss: 1.8210e-05 - accuracy: 1.0000 - val_loss: 3.7364 - val_accuracy: 0.5261
#
# Epoch 00578: val_loss did not improve from 0.69368
# Epoch 579/1000
# 19/19 - 0s - loss: 1.8043e-05 - accuracy: 1.0000 - val_loss: 3.7395 - val_accuracy: 0.5267
#
# Epoch 00579: val_loss did not improve from 0.69368
# Epoch 580/1000
# 19/19 - 0s - loss: 1.7878e-05 - accuracy: 1.0000 - val_loss: 3.7422 - val_accuracy: 0.5267
#
# Epoch 00580: val_loss did not improve from 0.69368
# Epoch 581/1000
# 19/19 - 0s - loss: 1.7713e-05 - accuracy: 1.0000 - val_loss: 3.7452 - val_accuracy: 0.5267
#
# Epoch 00581: val_loss did not improve from 0.69368
# Epoch 582/1000
# 19/19 - 0s - loss: 1.7549e-05 - accuracy: 1.0000 - val_loss: 3.7481 - val_accuracy: 0.5264
#
# Epoch 00582: val_loss did not improve from 0.69368
# Epoch 583/1000
# 19/19 - 0s - loss: 1.7390e-05 - accuracy: 1.0000 - val_loss: 3.7511 - val_accuracy: 0.5270
#
# Epoch 00583: val_loss did not improve from 0.69368
# Epoch 584/1000
# 19/19 - 0s - loss: 1.7231e-05 - accuracy: 1.0000 - val_loss: 3.7539 - val_accuracy: 0.5270
#
# Epoch 00584: val_loss did not improve from 0.69368
# Epoch 585/1000
# 19/19 - 0s - loss: 1.7072e-05 - accuracy: 1.0000 - val_loss: 3.7568 - val_accuracy: 0.5267
#
# Epoch 00585: val_loss did not improve from 0.69368
# Epoch 586/1000
# 19/19 - 0s - loss: 1.6915e-05 - accuracy: 1.0000 - val_loss: 3.7597 - val_accuracy: 0.5270
#
# Epoch 00586: val_loss did not improve from 0.69368
# Epoch 587/1000
# 19/19 - 0s - loss: 1.6762e-05 - accuracy: 1.0000 - val_loss: 3.7627 - val_accuracy: 0.5270
#
# Epoch 00587: val_loss did not improve from 0.69368
# Epoch 588/1000
# 19/19 - 0s - loss: 1.6607e-05 - accuracy: 1.0000 - val_loss: 3.7654 - val_accuracy: 0.5270
#
# Epoch 00588: val_loss did not improve from 0.69368
# Epoch 589/1000
# 19/19 - 0s - loss: 1.6453e-05 - accuracy: 1.0000 - val_loss: 3.7686 - val_accuracy: 0.5267
#
# Epoch 00589: val_loss did not improve from 0.69368
# Epoch 590/1000
# 19/19 - 0s - loss: 1.6304e-05 - accuracy: 1.0000 - val_loss: 3.7714 - val_accuracy: 0.5267
#
# Epoch 00590: val_loss did not improve from 0.69368
# Epoch 591/1000
# 19/19 - 0s - loss: 1.6155e-05 - accuracy: 1.0000 - val_loss: 3.7744 - val_accuracy: 0.5273
#
# Epoch 00591: val_loss did not improve from 0.69368
# Epoch 592/1000
# 19/19 - 0s - loss: 1.6005e-05 - accuracy: 1.0000 - val_loss: 3.7772 - val_accuracy: 0.5270
#
# Epoch 00592: val_loss did not improve from 0.69368
# Epoch 593/1000
# 19/19 - 0s - loss: 1.5858e-05 - accuracy: 1.0000 - val_loss: 3.7801 - val_accuracy: 0.5270
#
# Epoch 00593: val_loss did not improve from 0.69368
# Epoch 594/1000
# 19/19 - 0s - loss: 1.5713e-05 - accuracy: 1.0000 - val_loss: 3.7831 - val_accuracy: 0.5267
#
# Epoch 00594: val_loss did not improve from 0.69368
# Epoch 595/1000
# 19/19 - 0s - loss: 1.5569e-05 - accuracy: 1.0000 - val_loss: 3.7860 - val_accuracy: 0.5270
#
# Epoch 00595: val_loss did not improve from 0.69368
# Epoch 596/1000
# 19/19 - 0s - loss: 1.5425e-05 - accuracy: 1.0000 - val_loss: 3.7889 - val_accuracy: 0.5264
#
# Epoch 00596: val_loss did not improve from 0.69368
# Epoch 597/1000
# 19/19 - 0s - loss: 1.5283e-05 - accuracy: 1.0000 - val_loss: 3.7918 - val_accuracy: 0.5264
#
# Epoch 00597: val_loss did not improve from 0.69368
# Epoch 598/1000
# 19/19 - 0s - loss: 1.5144e-05 - accuracy: 1.0000 - val_loss: 3.7948 - val_accuracy: 0.5261
#
# Epoch 00598: val_loss did not improve from 0.69368
# Epoch 599/1000
# 19/19 - 0s - loss: 1.5005e-05 - accuracy: 1.0000 - val_loss: 3.7976 - val_accuracy: 0.5264
#
# Epoch 00599: val_loss did not improve from 0.69368
# Epoch 600/1000
# 19/19 - 0s - loss: 1.4866e-05 - accuracy: 1.0000 - val_loss: 3.8006 - val_accuracy: 0.5261
#
# Epoch 00600: val_loss did not improve from 0.69368
# Epoch 601/1000
# 19/19 - 0s - loss: 1.4730e-05 - accuracy: 1.0000 - val_loss: 3.8035 - val_accuracy: 0.5261
#
# Epoch 00601: val_loss did not improve from 0.69368
# Epoch 602/1000
# 19/19 - 0s - loss: 1.4596e-05 - accuracy: 1.0000 - val_loss: 3.8064 - val_accuracy: 0.5255
#
# Epoch 00602: val_loss did not improve from 0.69368
# Epoch 603/1000
# 19/19 - 0s - loss: 1.4461e-05 - accuracy: 1.0000 - val_loss: 3.8093 - val_accuracy: 0.5258
#
# Epoch 00603: val_loss did not improve from 0.69368
# Epoch 604/1000
# 19/19 - 0s - loss: 1.4327e-05 - accuracy: 1.0000 - val_loss: 3.8122 - val_accuracy: 0.5261
#
# Epoch 00604: val_loss did not improve from 0.69368
# Epoch 605/1000
# 19/19 - 0s - loss: 1.4196e-05 - accuracy: 1.0000 - val_loss: 3.8152 - val_accuracy: 0.5258
#
# Epoch 00605: val_loss did not improve from 0.69368
# Epoch 606/1000
# 19/19 - 0s - loss: 1.4067e-05 - accuracy: 1.0000 - val_loss: 3.8181 - val_accuracy: 0.5258
#
# Epoch 00606: val_loss did not improve from 0.69368
# Epoch 607/1000
# 19/19 - 0s - loss: 1.3937e-05 - accuracy: 1.0000 - val_loss: 3.8210 - val_accuracy: 0.5258
#
# Epoch 00607: val_loss did not improve from 0.69368
# Epoch 608/1000
# 19/19 - 0s - loss: 1.3808e-05 - accuracy: 1.0000 - val_loss: 3.8238 - val_accuracy: 0.5261
#
# Epoch 00608: val_loss did not improve from 0.69368
# Epoch 609/1000
# 19/19 - 0s - loss: 1.3682e-05 - accuracy: 1.0000 - val_loss: 3.8268 - val_accuracy: 0.5258
#
# Epoch 00609: val_loss did not improve from 0.69368
# Epoch 610/1000
# 19/19 - 0s - loss: 1.3557e-05 - accuracy: 1.0000 - val_loss: 3.8298 - val_accuracy: 0.5255
#
# Epoch 00610: val_loss did not improve from 0.69368
# Epoch 611/1000
# 19/19 - 0s - loss: 1.3432e-05 - accuracy: 1.0000 - val_loss: 3.8326 - val_accuracy: 0.5258
#
# Epoch 00611: val_loss did not improve from 0.69368
# Epoch 612/1000
# 19/19 - 0s - loss: 1.3307e-05 - accuracy: 1.0000 - val_loss: 3.8356 - val_accuracy: 0.5258
#
# Epoch 00612: val_loss did not improve from 0.69368
# Epoch 613/1000
# 19/19 - 0s - loss: 1.3186e-05 - accuracy: 1.0000 - val_loss: 3.8385 - val_accuracy: 0.5258
#
# Epoch 00613: val_loss did not improve from 0.69368
# Epoch 614/1000
# 19/19 - 0s - loss: 1.3065e-05 - accuracy: 1.0000 - val_loss: 3.8414 - val_accuracy: 0.5258
#
# Epoch 00614: val_loss did not improve from 0.69368
# Epoch 615/1000
# 19/19 - 0s - loss: 1.2945e-05 - accuracy: 1.0000 - val_loss: 3.8443 - val_accuracy: 0.5252
#
# Epoch 00615: val_loss did not improve from 0.69368
# Epoch 616/1000
# 19/19 - 0s - loss: 1.2825e-05 - accuracy: 1.0000 - val_loss: 3.8472 - val_accuracy: 0.5252
#
# Epoch 00616: val_loss did not improve from 0.69368
# Epoch 617/1000
# 19/19 - 0s - loss: 1.2707e-05 - accuracy: 1.0000 - val_loss: 3.8502 - val_accuracy: 0.5252
#
# Epoch 00617: val_loss did not improve from 0.69368
# Epoch 618/1000
# 19/19 - 0s - loss: 1.2591e-05 - accuracy: 1.0000 - val_loss: 3.8530 - val_accuracy: 0.5252
#
# Epoch 00618: val_loss did not improve from 0.69368
# Epoch 619/1000
# 19/19 - 0s - loss: 1.2475e-05 - accuracy: 1.0000 - val_loss: 3.8560 - val_accuracy: 0.5252
#
# Epoch 00619: val_loss did not improve from 0.69368
# Epoch 620/1000
# 19/19 - 0s - loss: 1.2359e-05 - accuracy: 1.0000 - val_loss: 3.8589 - val_accuracy: 0.5249
#
# Epoch 00620: val_loss did not improve from 0.69368
# Epoch 621/1000
# 19/19 - 0s - loss: 1.2246e-05 - accuracy: 1.0000 - val_loss: 3.8619 - val_accuracy: 0.5252
#
# Epoch 00621: val_loss did not improve from 0.69368
# Epoch 622/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-a9d22970fc5d> in <module>()
#      45                     validation_data=(x_val, y_val_ohe),
#      46                     validation_steps=int(len(x_val) / batch_size),
# ---> 47                     shuffle=False)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
# model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_ex_02008.h5'
# model_name = 'classifier_45_close_updown_pr_theta.h5'
# model_name = 'classifier_45_close_updown_pr_theta_train_evendata_shuffle2_300k.h5'
# model_name = 'classifier_45_close_updown_pr_05532.h5'

model = keras.models.load_model(ckpt_path + model_name)

# %%
org_x_test = x_test
org_y_test = y_test
org_pr_test = pr_test

# %%
x_test = org_x_test
y_test = org_y_test
pr_test = org_pr_test

# %%
concat_x = np.vstack((org_x_test, new_input_x))
concat_y = np.vstack((org_y_test, np.where(new_input_pr > 1, 1, 0)))
concat_pr = np.vstack((org_pr_test, new_input_pr))

# %%
x_test = new_input_x
y_test = np.where(new_input_pr > 1, 1, 0)
pr_test = new_input_pr

# %%
# x_test = new_input_x
# y_test = np.where(new_input_pr > 1, 1, 0)
# pr_test = new_input_pr

# x_test = org_x_test
# y_test = org_y_test
# pr_test = org_pr_test

# x_test = x_train
# y_test = y_train
# pr_test = pr_train

# x_test = x_val
# y_test = y_val
# pr_test = pr_val

# x_test = concat_x
# y_test = np.where(concat_pr > 1, 1, 0)
# pr_test = concat_pr

test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


threshold = [0.545]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  if thresh < 0.5:
      continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  print('precision :', precision_score(y_test, y_pred))
  print('recall :', recall_score(y_test, y_pred))
  print()

  print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # plt.show()  
  print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
    print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
    print('thresh :', thresh)
    
  # if len(threshold) == 1:
  plt.figure(figsize=(10, 5))
  plt.subplot(121)
  plt.plot(np.cumprod(test_pr_list))
  plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# plt.show()

  plt.subplot(122)
  plt.plot(np.cumprod(pred_pr_list))
  plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
  # plt.axvline(len(org_pr_test), linestyle='--', color='r')
  plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()
# Out:
# test_result.shape : (3277, 2)
# y_test[:5] : [1 0 0 1 0]
# y_score[:5] : [[0.50291044]
#  [0.50994825]
#  [0.4898329 ]
#  [0.50077724]
#  [0.49599987]]
# y_test.shape : (3277, 1)
# y_score.shape : (3277, 1)
# len(y_test) : 3277
# y_pred.shape : (3277,)
# precision : 0.6363636363636364
# recall : 0.009510869565217392
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 8.82165e-07
# win ratio improvement 0.45 --> 0.64
# accum_pr increased ! : 0.000 --> 1.362
# thresh : 0.545
# acc_pr_bythr : [1.3618054]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-4f0bc8651b1c> in <module>()
#     125 plt.figure(figsize=(10, 5))
#     126 plt.subplot(121)
# --> 127 plt.plot(threshold, precision, label='precision')
#     128 plt.plot(threshold, recall, label='recall')
#     129 plt.legend()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (3274,)

# %%
plt.figure(figsize=(50, 5))
plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test):len(org_pr_test) + 10])
# plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test) - 10:len(org_pr_test) + 10])
plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
# plt.axvline(len(org_pr_test), linestyle='--', color='r')
plt.show()

# %%
# plt.show()
# plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
