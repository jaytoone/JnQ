# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %tensorflow_version 2.x
# import tensorflow as tf
# print(tf.__version__)

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %matplotlib inline
import random

# %tensorflow_version 1.x
import tensorflow as tf

seed = 1203
np.random.seed(seed)
random.seed(seed)
# tf.random.set_seed(seed)
# tf.random.set_random_seed(seed)


# input_data_length = int(input('input_data_length : '))
input_data_length = 30
model_num = 218
num_classes = 2

gdrive_path = '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/'

Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)


#       Data Seperation      #
# Made_X = Made_X_[:, :, [-4]]
Made_X = Made_X_[:, :, :4]
print(Made_X.shape)
print(Made_Y.shape)
# break

row = Made_X.shape[1]
col = Made_X.shape[2]

from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                   shuffle=False)

X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)
print(X_train.shape)
print(X_val.shape)

from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 

# Data Class Weight
from sklearn.utils import class_weight

# print(Y_train[:, 0])
class_weights = class_weight.compute_class_weight('balanced', 
                                                  np.unique(Y_train[:, 0]),
                                                  Y_train[:, 0])
class_weights = dict(enumerate(class_weights))
print(class_weights)
# quit()

Y_train = Y_train.astype('float32')
Y_val = Y_val.astype('float32')
# print(Y_val[:5])
Y_train = np_utils.to_categorical(Y_train, num_classes)
Y_val = np_utils.to_categorical(Y_val, num_classes)
# print(Y_val[:5])
# break
print(Y_train.shape)
print(Y_val.shape)

# datagen = ImageDataGenerator( 
# #     rotation_range = 60,
# #     zoom_range = 0.6,
# #     shear_range = 0.6,
# #     horizontal_flip = True,
# #     width_shift_range=0.6,
# #     height_shift_range=0.6,
#     fill_mode = 'nearest'
#     )

# testgen = ImageDataGenerator( 
#     )
# datagen.fit(X_train)
batch_size = 26

# for X_batch, _ in datagen.flow(X_train, Y_train, batch_size=9):
#     for i in range(0, 9): 
#         pyplot.axis('off') 
#         pyplot.subplot(330 + 1 + i) 
#         pyplot.imshow(X_batch[i].reshape(input_data_length, col))
#     pyplot.axis('off') 
#     pyplot.show() 
#     break
    
    
# train_flow = datagen.flow(X_train, Y_train, batch_size=batch_size) 
# val_flow = testgen.flow(X_val, Y_val, batch_size=batch_size) 


from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix

def FER_Model(input_shape=(row, col)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    #             LSTM Version            #
    # net = layers.LSTM(10, return_sequences=False)(visible)
    net = layers.Dense(64, activation='relu')(visible)
    # net = layers.Dropout(0.2)(net)


    # net = layers.LSTM(5, return_sequences=True)(net)
    net = layers.Dense(32, activation='relu')(net)
    net = layers.Dropout(0.2)(net)

    # net = layers.LSTM(5, return_sequences=True)(visible)
    # net = layers.Dense(16, activation='relu')(net)
    # # net = layers.Dropout(0.2)(net)

    # net = layers.LSTM(1, return_sequences=False)(visible)
    # net = layers.Dense(8, activation='relu')(net)
    # net = layers.Dropout(0.5)(net)

    # net = layers.Conv2D(64, kernel_size=3, padding='same')(visible)
    # net = layers.Activation('relu')(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    # shortcut_1 = net

    # net = layers.Conv2D(32, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    # shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
    
    return model

model = FER_Model()
# from keras.models import load_model
# model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_rnn_macdonly.hdf5' % (input_data_length, model_num))
opt = Adam(lr=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
  
    
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_accuracy', patience=200)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit(X_train, Y_train,
                    steps_per_epoch=int(len(X_train) / batch_size), 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=(X_val, Y_val),  
                    validation_steps=int(len(X_val) / batch_size),
                    shuffle=False)
# Out:
# (2531, 30, 4)
# (2531, 1)
# (1771, 30, 4)
# (760, 30, 4)
# {0: 0.7027777777777777, 1: 1.7328767123287672}
# (1771, 2)
# (760, 2)
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 30, 4)]           0
# _________________________________________________________________
# dense (Dense)                (None, 30, 64)            320
# _________________________________________________________________
# dense_1 (Dense)              (None, 30, 32)            2080
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 960)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                61504
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 64,034
# Trainable params: 64,034
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0067s vs `on_train_batch_end` time: 0.0444s). Check your callbacks.
#
# Epoch 00001: val_accuracy improved from -inf to 0.93684, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_218_futures_rnn.hdf5
# 68/68 - 1s - loss: 0.7151 - accuracy: 0.3995 - val_loss: 0.5496 - val_accuracy: 0.9368
# Epoch 2/1000
#
# Epoch 00002: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.7205 - accuracy: 0.6795 - val_loss: 0.5555 - val_accuracy: 0.9368
# Epoch 3/1000
#
# Epoch 00003: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.7197 - accuracy: 0.6784 - val_loss: 0.5659 - val_accuracy: 0.9368
# Epoch 4/1000
#
# Epoch 00004: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.7066 - accuracy: 0.6970 - val_loss: 0.5855 - val_accuracy: 0.9368
# Epoch 5/1000
#
# Epoch 00005: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.6931 - accuracy: 0.7107 - val_loss: 0.5962 - val_accuracy: 0.9368
# Epoch 6/1000
#
# Epoch 00006: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.6913 - accuracy: 0.7101 - val_loss: 0.6091 - val_accuracy: 0.9368
# Epoch 7/1000
#
# Epoch 00007: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.6953 - accuracy: 0.7079 - val_loss: 0.6142 - val_accuracy: 0.9368
# Epoch 8/1000
#
# Epoch 00008: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.6864 - accuracy: 0.7134 - val_loss: 0.6195 - val_accuracy: 0.9368
# Epoch 9/1000
#
# Epoch 00009: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.6813 - accuracy: 0.7189 - val_loss: 0.6213 - val_accuracy: 0.9368
# Epoch 10/1000
#
# Epoch 00010: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.6813 - accuracy: 0.7205 - val_loss: 0.6161 - val_accuracy: 0.9368
# Epoch 11/1000
#
# Epoch 00011: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.6818 - accuracy: 0.7233 - val_loss: 0.6133 - val_accuracy: 0.9368
# Epoch 12/1000
#
# Epoch 00012: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.6803 - accuracy: 0.7260 - val_loss: 0.6050 - val_accuracy: 0.9368
# Epoch 13/1000
#
# Epoch 00013: val_accuracy did not improve from 0.93684
# 68/68 - 0s - loss: 0.6803 - accuracy: 0.7277 - val_loss: 0.5955 - val_accuracy: 0.9368
# Epoch 14/1000
#
# Epoch 00014: val_accuracy improved from 0.93684 to 0.93816, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_218_futures_rnn.hdf5
# 68/68 - 0s - loss: 0.6742 - accuracy: 0.7299 - val_loss: 0.5851 - val_accuracy: 0.9382
# Epoch 15/1000
#
# Epoch 00015: val_accuracy improved from 0.93816 to 0.93947, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_218_futures_rnn.hdf5
# 68/68 - 0s - loss: 0.6730 - accuracy: 0.7342 - val_loss: 0.5744 - val_accuracy: 0.9395
# Epoch 16/1000
#
# Epoch 00016: val_accuracy improved from 0.93947 to 0.94737, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_218_futures_rnn.hdf5
# 68/68 - 0s - loss: 0.6951 - accuracy: 0.7107 - val_loss: 0.5686 - val_accuracy: 0.9474
# Epoch 17/1000
#
# Epoch 00017: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6825 - accuracy: 0.7260 - val_loss: 0.5697 - val_accuracy: 0.9355
# Epoch 18/1000
#
# Epoch 00018: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6827 - accuracy: 0.7200 - val_loss: 0.5766 - val_accuracy: 0.8118
# Epoch 19/1000
#
# Epoch 00019: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6652 - accuracy: 0.7342 - val_loss: 0.5801 - val_accuracy: 0.7855
# Epoch 20/1000
#
# Epoch 00020: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6621 - accuracy: 0.7090 - val_loss: 0.5786 - val_accuracy: 0.7461
# Epoch 21/1000
#
# Epoch 00021: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6715 - accuracy: 0.6871 - val_loss: 0.5777 - val_accuracy: 0.7355
# Epoch 22/1000
#
# Epoch 00022: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6676 - accuracy: 0.6493 - val_loss: 0.5858 - val_accuracy: 0.7329
# Epoch 23/1000
#
# Epoch 00023: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6729 - accuracy: 0.6192 - val_loss: 0.5950 - val_accuracy: 0.7303
# Epoch 24/1000
#
# Epoch 00024: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6589 - accuracy: 0.6197 - val_loss: 0.6124 - val_accuracy: 0.7263
# Epoch 25/1000
#
# Epoch 00025: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6465 - accuracy: 0.6132 - val_loss: 0.6218 - val_accuracy: 0.7250
# Epoch 26/1000
#
# Epoch 00026: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6462 - accuracy: 0.5978 - val_loss: 0.6202 - val_accuracy: 0.7250
# Epoch 27/1000
#
# Epoch 00027: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6497 - accuracy: 0.5962 - val_loss: 0.6224 - val_accuracy: 0.7237
# Epoch 28/1000
#
# Epoch 00028: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6615 - accuracy: 0.5879 - val_loss: 0.6241 - val_accuracy: 0.7237
# Epoch 29/1000
#
# Epoch 00029: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6571 - accuracy: 0.5934 - val_loss: 0.6437 - val_accuracy: 0.7118
# Epoch 30/1000
#
# Epoch 00030: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6444 - accuracy: 0.5923 - val_loss: 0.6611 - val_accuracy: 0.6908
# Epoch 31/1000
#
# Epoch 00031: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6400 - accuracy: 0.5890 - val_loss: 0.6692 - val_accuracy: 0.6842
# Epoch 32/1000
#
# Epoch 00032: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6389 - accuracy: 0.5934 - val_loss: 0.6659 - val_accuracy: 0.6882
# Epoch 33/1000
#
# Epoch 00033: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6393 - accuracy: 0.5932 - val_loss: 0.6571 - val_accuracy: 0.6974
# Epoch 34/1000
#
# Epoch 00034: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6483 - accuracy: 0.5830 - val_loss: 0.6496 - val_accuracy: 0.7105
# Epoch 35/1000
#
# Epoch 00035: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6473 - accuracy: 0.5918 - val_loss: 0.6511 - val_accuracy: 0.7105
# Epoch 36/1000
#
# Epoch 00036: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6474 - accuracy: 0.5973 - val_loss: 0.6555 - val_accuracy: 0.7053
# Epoch 37/1000
#
# Epoch 00037: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6464 - accuracy: 0.5874 - val_loss: 0.6743 - val_accuracy: 0.6868
# Epoch 38/1000
#
# Epoch 00038: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6411 - accuracy: 0.5770 - val_loss: 0.6884 - val_accuracy: 0.6803
# Epoch 39/1000
#
# Epoch 00039: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6443 - accuracy: 0.5770 - val_loss: 0.6969 - val_accuracy: 0.6737
# Epoch 40/1000
#
# Epoch 00040: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6426 - accuracy: 0.5797 - val_loss: 0.7018 - val_accuracy: 0.6684
# Epoch 41/1000
#
# Epoch 00041: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6415 - accuracy: 0.5748 - val_loss: 0.7030 - val_accuracy: 0.6697
# Epoch 42/1000
#
# Epoch 00042: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6342 - accuracy: 0.5792 - val_loss: 0.6936 - val_accuracy: 0.6803
# Epoch 43/1000
#
# Epoch 00043: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6367 - accuracy: 0.5693 - val_loss: 0.6810 - val_accuracy: 0.6882
# Epoch 44/1000
#
# Epoch 00044: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6398 - accuracy: 0.5699 - val_loss: 0.6626 - val_accuracy: 0.7066
# Epoch 45/1000
#
# Epoch 00045: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6363 - accuracy: 0.5742 - val_loss: 0.6416 - val_accuracy: 0.7224
# Epoch 46/1000
#
# Epoch 00046: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6347 - accuracy: 0.5742 - val_loss: 0.6245 - val_accuracy: 0.7237
# Epoch 47/1000
#
# Epoch 00047: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6318 - accuracy: 0.5748 - val_loss: 0.6033 - val_accuracy: 0.7263
# Epoch 48/1000
#
# Epoch 00048: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6332 - accuracy: 0.5682 - val_loss: 0.5830 - val_accuracy: 0.7276
# Epoch 49/1000
#
# Epoch 00049: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6432 - accuracy: 0.5989 - val_loss: 0.5701 - val_accuracy: 0.7289
# Epoch 50/1000
#
# Epoch 00050: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6411 - accuracy: 0.5868 - val_loss: 0.5700 - val_accuracy: 0.7289
# Epoch 51/1000
#
# Epoch 00051: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6437 - accuracy: 0.5890 - val_loss: 0.5749 - val_accuracy: 0.7276
# Epoch 52/1000
#
# Epoch 00052: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6250 - accuracy: 0.6000 - val_loss: 0.5770 - val_accuracy: 0.7276
# Epoch 53/1000
#
# Epoch 00053: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6251 - accuracy: 0.5995 - val_loss: 0.5782 - val_accuracy: 0.7276
# Epoch 54/1000
#
# Epoch 00054: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6369 - accuracy: 0.5841 - val_loss: 0.5774 - val_accuracy: 0.7276
# Epoch 55/1000
#
# Epoch 00055: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6330 - accuracy: 0.5923 - val_loss: 0.5837 - val_accuracy: 0.7276
# Epoch 56/1000
#
# Epoch 00056: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6437 - accuracy: 0.5830 - val_loss: 0.5985 - val_accuracy: 0.7263
# Epoch 57/1000
#
# Epoch 00057: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6279 - accuracy: 0.5978 - val_loss: 0.6136 - val_accuracy: 0.7237
# Epoch 58/1000
#
# Epoch 00058: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6172 - accuracy: 0.5995 - val_loss: 0.6205 - val_accuracy: 0.7237
# Epoch 59/1000
#
# Epoch 00059: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6199 - accuracy: 0.5995 - val_loss: 0.6296 - val_accuracy: 0.7237
# Epoch 60/1000
#
# Epoch 00060: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6236 - accuracy: 0.5956 - val_loss: 0.6322 - val_accuracy: 0.7237
# Epoch 61/1000
#
# Epoch 00061: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6418 - accuracy: 0.5901 - val_loss: 0.6361 - val_accuracy: 0.7224
# Epoch 62/1000
#
# Epoch 00062: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6358 - accuracy: 0.5918 - val_loss: 0.6535 - val_accuracy: 0.7211
# Epoch 63/1000
#
# Epoch 00063: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6210 - accuracy: 0.6011 - val_loss: 0.6717 - val_accuracy: 0.7039
# Epoch 64/1000
#
# Epoch 00064: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6174 - accuracy: 0.6077 - val_loss: 0.6785 - val_accuracy: 0.6987
# Epoch 65/1000
#
# Epoch 00065: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6168 - accuracy: 0.6044 - val_loss: 0.6769 - val_accuracy: 0.7000
# Epoch 66/1000
#
# Epoch 00066: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6166 - accuracy: 0.6031 - val_loss: 0.6732 - val_accuracy: 0.7053
# Epoch 67/1000
#
# Epoch 00067: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6255 - accuracy: 0.5940 - val_loss: 0.6735 - val_accuracy: 0.7053
# Epoch 68/1000
#
# Epoch 00068: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6199 - accuracy: 0.6044 - val_loss: 0.6725 - val_accuracy: 0.7066
# Epoch 69/1000
#
# Epoch 00069: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6240 - accuracy: 0.6060 - val_loss: 0.6811 - val_accuracy: 0.7000
# Epoch 70/1000
#
# Epoch 00070: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6281 - accuracy: 0.5945 - val_loss: 0.7022 - val_accuracy: 0.6882
# Epoch 71/1000
#
# Epoch 00071: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6267 - accuracy: 0.5814 - val_loss: 0.7159 - val_accuracy: 0.6816
# Epoch 72/1000
#
# Epoch 00072: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6252 - accuracy: 0.5830 - val_loss: 0.7222 - val_accuracy: 0.6789
# Epoch 73/1000
#
# Epoch 00073: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6254 - accuracy: 0.5852 - val_loss: 0.7249 - val_accuracy: 0.6789
# Epoch 74/1000
#
# Epoch 00074: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6243 - accuracy: 0.5836 - val_loss: 0.7248 - val_accuracy: 0.6803
# Epoch 75/1000
#
# Epoch 00075: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6192 - accuracy: 0.5951 - val_loss: 0.7223 - val_accuracy: 0.6829
# Epoch 76/1000
#
# Epoch 00076: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6242 - accuracy: 0.5797 - val_loss: 0.7112 - val_accuracy: 0.6895
# Epoch 77/1000
#
# Epoch 00077: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6227 - accuracy: 0.5792 - val_loss: 0.6943 - val_accuracy: 0.7053
# Epoch 78/1000
#
# Epoch 00078: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6205 - accuracy: 0.5786 - val_loss: 0.6748 - val_accuracy: 0.7211
# Epoch 79/1000
#
# Epoch 00079: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6216 - accuracy: 0.5814 - val_loss: 0.6560 - val_accuracy: 0.7211
# Epoch 80/1000
#
# Epoch 00080: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6176 - accuracy: 0.5792 - val_loss: 0.6371 - val_accuracy: 0.7224
# Epoch 81/1000
#
# Epoch 00081: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6176 - accuracy: 0.5753 - val_loss: 0.6143 - val_accuracy: 0.7237
# Epoch 82/1000
#
# Epoch 00082: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6285 - accuracy: 0.6000 - val_loss: 0.6070 - val_accuracy: 0.7237
# Epoch 83/1000
#
# Epoch 00083: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6259 - accuracy: 0.5934 - val_loss: 0.6018 - val_accuracy: 0.7237
# Epoch 84/1000
#
# Epoch 00084: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6308 - accuracy: 0.5912 - val_loss: 0.6014 - val_accuracy: 0.7237
# Epoch 85/1000
#
# Epoch 00085: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6113 - accuracy: 0.6115 - val_loss: 0.6096 - val_accuracy: 0.7237
# Epoch 86/1000
#
# Epoch 00086: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6090 - accuracy: 0.6060 - val_loss: 0.6088 - val_accuracy: 0.7237
# Epoch 87/1000
#
# Epoch 00087: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6230 - accuracy: 0.5923 - val_loss: 0.6082 - val_accuracy: 0.7237
# Epoch 88/1000
#
# Epoch 00088: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6202 - accuracy: 0.5973 - val_loss: 0.6112 - val_accuracy: 0.7237
# Epoch 89/1000
#
# Epoch 00089: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6328 - accuracy: 0.5929 - val_loss: 0.6233 - val_accuracy: 0.7224
# Epoch 90/1000
#
# Epoch 00090: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6163 - accuracy: 0.6066 - val_loss: 0.6382 - val_accuracy: 0.7224
# Epoch 91/1000
#
# Epoch 00091: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6040 - accuracy: 0.6060 - val_loss: 0.6455 - val_accuracy: 0.7211
# Epoch 92/1000
#
# Epoch 00092: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6082 - accuracy: 0.6071 - val_loss: 0.6494 - val_accuracy: 0.7211
# Epoch 93/1000
#
# Epoch 00093: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6117 - accuracy: 0.6066 - val_loss: 0.6528 - val_accuracy: 0.7211
# Epoch 94/1000
#
# Epoch 00094: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6279 - accuracy: 0.5940 - val_loss: 0.6571 - val_accuracy: 0.7211
# Epoch 95/1000
#
# Epoch 00095: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6221 - accuracy: 0.6016 - val_loss: 0.6753 - val_accuracy: 0.7211
# Epoch 96/1000
#
# Epoch 00096: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6088 - accuracy: 0.6088 - val_loss: 0.6882 - val_accuracy: 0.7197
# Epoch 97/1000
#
# Epoch 00097: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6039 - accuracy: 0.6115 - val_loss: 0.6967 - val_accuracy: 0.7066
# Epoch 98/1000
#
# Epoch 00098: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6031 - accuracy: 0.6104 - val_loss: 0.6947 - val_accuracy: 0.7079
# Epoch 99/1000
#
# Epoch 00099: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6071 - accuracy: 0.6064 - val_loss: 0.6970 - val_accuracy: 0.7079
# Epoch 100/1000
#
# Epoch 00100: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6153 - accuracy: 0.6005 - val_loss: 0.6875 - val_accuracy: 0.7197
# Epoch 101/1000
#
# Epoch 00101: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6047 - accuracy: 0.6148 - val_loss: 0.6908 - val_accuracy: 0.7197
# Epoch 102/1000
#
# Epoch 00102: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6098 - accuracy: 0.6126 - val_loss: 0.6984 - val_accuracy: 0.7171
# Epoch 103/1000
#
# Epoch 00103: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6147 - accuracy: 0.6055 - val_loss: 0.7185 - val_accuracy: 0.6947
# Epoch 104/1000
#
# Epoch 00104: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6146 - accuracy: 0.5879 - val_loss: 0.7277 - val_accuracy: 0.6921
# Epoch 105/1000
#
# Epoch 00105: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6148 - accuracy: 0.5896 - val_loss: 0.7384 - val_accuracy: 0.6895
# Epoch 106/1000
#
# Epoch 00106: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6139 - accuracy: 0.5934 - val_loss: 0.7428 - val_accuracy: 0.6882
# Epoch 107/1000
#
# Epoch 00107: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6132 - accuracy: 0.5885 - val_loss: 0.7418 - val_accuracy: 0.6921
# Epoch 108/1000
#
# Epoch 00108: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6058 - accuracy: 0.6077 - val_loss: 0.7429 - val_accuracy: 0.6934
# Epoch 109/1000
#
# Epoch 00109: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6136 - accuracy: 0.5874 - val_loss: 0.7322 - val_accuracy: 0.7092
# Epoch 110/1000
#
# Epoch 00110: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6109 - accuracy: 0.5879 - val_loss: 0.7178 - val_accuracy: 0.7197
# Epoch 111/1000
#
# Epoch 00111: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6096 - accuracy: 0.5885 - val_loss: 0.6978 - val_accuracy: 0.7211
# Epoch 112/1000
#
# Epoch 00112: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6096 - accuracy: 0.5918 - val_loss: 0.6834 - val_accuracy: 0.7211
# Epoch 113/1000
#
# Epoch 00113: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6069 - accuracy: 0.5923 - val_loss: 0.6642 - val_accuracy: 0.7211
# Epoch 114/1000
#
# Epoch 00114: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6092 - accuracy: 0.5868 - val_loss: 0.6482 - val_accuracy: 0.7224
# Epoch 115/1000
#
# Epoch 00115: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6178 - accuracy: 0.6115 - val_loss: 0.6369 - val_accuracy: 0.7224
# Epoch 116/1000
#
# Epoch 00116: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6155 - accuracy: 0.6022 - val_loss: 0.6358 - val_accuracy: 0.7224
# Epoch 117/1000
#
# Epoch 00117: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6187 - accuracy: 0.5973 - val_loss: 0.6393 - val_accuracy: 0.7224
# Epoch 118/1000
#
# Epoch 00118: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6028 - accuracy: 0.6142 - val_loss: 0.6396 - val_accuracy: 0.7224
# Epoch 119/1000
#
# Epoch 00119: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5989 - accuracy: 0.6164 - val_loss: 0.6405 - val_accuracy: 0.7224
# Epoch 120/1000
#
# Epoch 00120: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6125 - accuracy: 0.6044 - val_loss: 0.6434 - val_accuracy: 0.7224
# Epoch 121/1000
#
# Epoch 00121: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6104 - accuracy: 0.6099 - val_loss: 0.6426 - val_accuracy: 0.7211
# Epoch 122/1000
#
# Epoch 00122: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6207 - accuracy: 0.5989 - val_loss: 0.6529 - val_accuracy: 0.7211
# Epoch 123/1000
#
# Epoch 00123: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6054 - accuracy: 0.6126 - val_loss: 0.6635 - val_accuracy: 0.7211
# Epoch 124/1000
#
# Epoch 00124: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5950 - accuracy: 0.6170 - val_loss: 0.6721 - val_accuracy: 0.7211
# Epoch 125/1000
#
# Epoch 00125: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5945 - accuracy: 0.6170 - val_loss: 0.6730 - val_accuracy: 0.7197
# Epoch 126/1000
#
# Epoch 00126: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6010 - accuracy: 0.6164 - val_loss: 0.6788 - val_accuracy: 0.7197
# Epoch 127/1000
#
# Epoch 00127: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6172 - accuracy: 0.6088 - val_loss: 0.6823 - val_accuracy: 0.7197
# Epoch 128/1000
#
# Epoch 00128: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6142 - accuracy: 0.6066 - val_loss: 0.6993 - val_accuracy: 0.7197
# Epoch 129/1000
#
# Epoch 00129: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5991 - accuracy: 0.6142 - val_loss: 0.7129 - val_accuracy: 0.7132
# Epoch 130/1000
#
# Epoch 00130: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5944 - accuracy: 0.6164 - val_loss: 0.7169 - val_accuracy: 0.7079
# Epoch 131/1000
#
# Epoch 00131: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5937 - accuracy: 0.6197 - val_loss: 0.7232 - val_accuracy: 0.7053
# Epoch 132/1000
#
# Epoch 00132: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5951 - accuracy: 0.6174 - val_loss: 0.7194 - val_accuracy: 0.7079
# Epoch 133/1000
#
# Epoch 00133: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6059 - accuracy: 0.6060 - val_loss: 0.7124 - val_accuracy: 0.7132
# Epoch 134/1000
#
# Epoch 00134: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5917 - accuracy: 0.6181 - val_loss: 0.7141 - val_accuracy: 0.7092
# Epoch 135/1000
#
# Epoch 00135: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6004 - accuracy: 0.6186 - val_loss: 0.7209 - val_accuracy: 0.7079
# Epoch 136/1000
#
# Epoch 00136: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6049 - accuracy: 0.6104 - val_loss: 0.7374 - val_accuracy: 0.7053
# Epoch 137/1000
#
# Epoch 00137: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6037 - accuracy: 0.5973 - val_loss: 0.7536 - val_accuracy: 0.7026
# Epoch 138/1000
#
# Epoch 00138: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6032 - accuracy: 0.5962 - val_loss: 0.7582 - val_accuracy: 0.7026
# Epoch 139/1000
#
# Epoch 00139: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6042 - accuracy: 0.6022 - val_loss: 0.7644 - val_accuracy: 0.7026
# Epoch 140/1000
#
# Epoch 00140: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6022 - accuracy: 0.6071 - val_loss: 0.7692 - val_accuracy: 0.7013
# Epoch 141/1000
#
# Epoch 00141: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5970 - accuracy: 0.6170 - val_loss: 0.7705 - val_accuracy: 0.7026
# Epoch 142/1000
#
# Epoch 00142: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6021 - accuracy: 0.5923 - val_loss: 0.7603 - val_accuracy: 0.7039
# Epoch 143/1000
#
# Epoch 00143: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6012 - accuracy: 0.5962 - val_loss: 0.7464 - val_accuracy: 0.7092
# Epoch 144/1000
#
# Epoch 00144: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5987 - accuracy: 0.5978 - val_loss: 0.7287 - val_accuracy: 0.7197
# Epoch 145/1000
#
# Epoch 00145: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5987 - accuracy: 0.5995 - val_loss: 0.7097 - val_accuracy: 0.7197
# Epoch 146/1000
#
# Epoch 00146: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5965 - accuracy: 0.6066 - val_loss: 0.6939 - val_accuracy: 0.7197
# Epoch 147/1000
#
# Epoch 00147: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5995 - accuracy: 0.5951 - val_loss: 0.6774 - val_accuracy: 0.7197
# Epoch 148/1000
#
# Epoch 00148: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6095 - accuracy: 0.6159 - val_loss: 0.6673 - val_accuracy: 0.7211
# Epoch 149/1000
#
# Epoch 00149: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6067 - accuracy: 0.6093 - val_loss: 0.6642 - val_accuracy: 0.7211
# Epoch 150/1000
#
# Epoch 00150: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6103 - accuracy: 0.6082 - val_loss: 0.6656 - val_accuracy: 0.7211
# Epoch 151/1000
#
# Epoch 00151: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5924 - accuracy: 0.6241 - val_loss: 0.6689 - val_accuracy: 0.7197
# Epoch 152/1000
#
# Epoch 00152: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5928 - accuracy: 0.6279 - val_loss: 0.6724 - val_accuracy: 0.7197
# Epoch 153/1000
#
# Epoch 00153: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6038 - accuracy: 0.6132 - val_loss: 0.6693 - val_accuracy: 0.7197
# Epoch 154/1000
#
# Epoch 00154: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6003 - accuracy: 0.6192 - val_loss: 0.6723 - val_accuracy: 0.7197
# Epoch 155/1000
#
# Epoch 00155: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6131 - accuracy: 0.6104 - val_loss: 0.6805 - val_accuracy: 0.7197
# Epoch 156/1000
#
# Epoch 00156: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5978 - accuracy: 0.6268 - val_loss: 0.6922 - val_accuracy: 0.7197
# Epoch 157/1000
#
# Epoch 00157: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5876 - accuracy: 0.6307 - val_loss: 0.7015 - val_accuracy: 0.7197
# Epoch 158/1000
#
# Epoch 00158: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5888 - accuracy: 0.6296 - val_loss: 0.7033 - val_accuracy: 0.7197
# Epoch 159/1000
#
# Epoch 00159: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5917 - accuracy: 0.6285 - val_loss: 0.7069 - val_accuracy: 0.7197
# Epoch 160/1000
#
# Epoch 00160: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6094 - accuracy: 0.6230 - val_loss: 0.7115 - val_accuracy: 0.7118
# Epoch 161/1000
#
# Epoch 00161: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6048 - accuracy: 0.6241 - val_loss: 0.7186 - val_accuracy: 0.7066
# Epoch 162/1000
#
# Epoch 00162: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5922 - accuracy: 0.6345 - val_loss: 0.7350 - val_accuracy: 0.7053
# Epoch 163/1000
#
# Epoch 00163: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5847 - accuracy: 0.6329 - val_loss: 0.7422 - val_accuracy: 0.7039
# Epoch 164/1000
#
# Epoch 00164: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5864 - accuracy: 0.6384 - val_loss: 0.7356 - val_accuracy: 0.7026
# Epoch 165/1000
#
# Epoch 00165: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5892 - accuracy: 0.6362 - val_loss: 0.7420 - val_accuracy: 0.7026
# Epoch 166/1000
#
# Epoch 00166: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6004 - accuracy: 0.6263 - val_loss: 0.7321 - val_accuracy: 0.7053
# Epoch 167/1000
#
# Epoch 00167: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5836 - accuracy: 0.6395 - val_loss: 0.7321 - val_accuracy: 0.7053
# Epoch 168/1000
#
# Epoch 00168: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5902 - accuracy: 0.6427 - val_loss: 0.7398 - val_accuracy: 0.7026
# Epoch 169/1000
#
# Epoch 00169: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5957 - accuracy: 0.6329 - val_loss: 0.7562 - val_accuracy: 0.7026
# Epoch 170/1000
#
# Epoch 00170: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5933 - accuracy: 0.6241 - val_loss: 0.7684 - val_accuracy: 0.7026
# Epoch 171/1000
#
# Epoch 00171: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5955 - accuracy: 0.6279 - val_loss: 0.7749 - val_accuracy: 0.7026
# Epoch 172/1000
#
# Epoch 00172: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5962 - accuracy: 0.6296 - val_loss: 0.7798 - val_accuracy: 0.7013
# Epoch 173/1000
#
# Epoch 00173: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5934 - accuracy: 0.6411 - val_loss: 0.7849 - val_accuracy: 0.7026
# Epoch 174/1000
#
# Epoch 00174: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5878 - accuracy: 0.6482 - val_loss: 0.7847 - val_accuracy: 0.7026
# Epoch 175/1000
#
# Epoch 00175: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5947 - accuracy: 0.6318 - val_loss: 0.7805 - val_accuracy: 0.7026
# Epoch 176/1000
#
# Epoch 00176: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5918 - accuracy: 0.6296 - val_loss: 0.7675 - val_accuracy: 0.7039
# Epoch 177/1000
#
# Epoch 00177: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5918 - accuracy: 0.6318 - val_loss: 0.7529 - val_accuracy: 0.7066
# Epoch 178/1000
#
# Epoch 00178: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5928 - accuracy: 0.6427 - val_loss: 0.7384 - val_accuracy: 0.7079
# Epoch 179/1000
#
# Epoch 00179: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5890 - accuracy: 0.6438 - val_loss: 0.7226 - val_accuracy: 0.7079
# Epoch 180/1000
#
# Epoch 00180: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5911 - accuracy: 0.6307 - val_loss: 0.7021 - val_accuracy: 0.7145
# Epoch 181/1000
#
# Epoch 00181: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6025 - accuracy: 0.6499 - val_loss: 0.6897 - val_accuracy: 0.7197
# Epoch 182/1000
#
# Epoch 00182: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5997 - accuracy: 0.6542 - val_loss: 0.6928 - val_accuracy: 0.7184
# Epoch 183/1000
#
# Epoch 00183: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6028 - accuracy: 0.6438 - val_loss: 0.6900 - val_accuracy: 0.7184
# Epoch 184/1000
#
# Epoch 00184: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5866 - accuracy: 0.6707 - val_loss: 0.6947 - val_accuracy: 0.7132
# Epoch 185/1000
#
# Epoch 00185: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5838 - accuracy: 0.6668 - val_loss: 0.6993 - val_accuracy: 0.7118
# Epoch 186/1000
#
# Epoch 00186: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5965 - accuracy: 0.6592 - val_loss: 0.6965 - val_accuracy: 0.7118
# Epoch 187/1000
#
# Epoch 00187: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5946 - accuracy: 0.6663 - val_loss: 0.7013 - val_accuracy: 0.7092
# Epoch 188/1000
#
# Epoch 00188: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6022 - accuracy: 0.6526 - val_loss: 0.7084 - val_accuracy: 0.7092
# Epoch 189/1000
#
# Epoch 00189: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5889 - accuracy: 0.6625 - val_loss: 0.7126 - val_accuracy: 0.7079
# Epoch 190/1000
#
# Epoch 00190: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5782 - accuracy: 0.6762 - val_loss: 0.7217 - val_accuracy: 0.7053
# Epoch 191/1000
#
# Epoch 00191: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5791 - accuracy: 0.6723 - val_loss: 0.7235 - val_accuracy: 0.7053
# Epoch 192/1000
#
# Epoch 00192: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5862 - accuracy: 0.6762 - val_loss: 0.7233 - val_accuracy: 0.7053
# Epoch 193/1000
#
# Epoch 00193: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.6025 - accuracy: 0.6696 - val_loss: 0.7298 - val_accuracy: 0.7039
# Epoch 194/1000
#
# Epoch 00194: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5968 - accuracy: 0.6740 - val_loss: 0.7454 - val_accuracy: 0.7039
# Epoch 195/1000
#
# Epoch 00195: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5836 - accuracy: 0.6849 - val_loss: 0.7537 - val_accuracy: 0.7039
# Epoch 196/1000
#
# Epoch 00196: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5783 - accuracy: 0.6838 - val_loss: 0.7581 - val_accuracy: 0.7026
# Epoch 197/1000
#
# Epoch 00197: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5783 - accuracy: 0.6816 - val_loss: 0.7575 - val_accuracy: 0.7026
# Epoch 198/1000
#
# Epoch 00198: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5805 - accuracy: 0.6863 - val_loss: 0.7557 - val_accuracy: 0.7026
# Epoch 199/1000
#
# Epoch 00199: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5933 - accuracy: 0.6718 - val_loss: 0.7500 - val_accuracy: 0.7039
# Epoch 200/1000
#
# Epoch 00200: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5767 - accuracy: 0.6904 - val_loss: 0.7479 - val_accuracy: 0.7039
# Epoch 201/1000
#
# Epoch 00201: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5798 - accuracy: 0.6942 - val_loss: 0.7559 - val_accuracy: 0.7039
# Epoch 202/1000
#
# Epoch 00202: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5888 - accuracy: 0.6844 - val_loss: 0.7675 - val_accuracy: 0.7026
# Epoch 203/1000
#
# Epoch 00203: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5854 - accuracy: 0.6827 - val_loss: 0.7791 - val_accuracy: 0.7026
# Epoch 204/1000
#
# Epoch 00204: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5882 - accuracy: 0.6789 - val_loss: 0.7884 - val_accuracy: 0.7026
# Epoch 205/1000
#
# Epoch 00205: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5878 - accuracy: 0.6816 - val_loss: 0.7934 - val_accuracy: 0.7026
# Epoch 206/1000
#
# Epoch 00206: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5845 - accuracy: 0.6986 - val_loss: 0.7973 - val_accuracy: 0.7026
# Epoch 207/1000
#
# Epoch 00207: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5829 - accuracy: 0.6932 - val_loss: 0.8033 - val_accuracy: 0.7026
# Epoch 208/1000
#
# Epoch 00208: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5863 - accuracy: 0.6718 - val_loss: 0.7947 - val_accuracy: 0.7039
# Epoch 209/1000
#
# Epoch 00209: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5854 - accuracy: 0.6811 - val_loss: 0.7845 - val_accuracy: 0.7039
# Epoch 210/1000
#
# Epoch 00210: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5835 - accuracy: 0.6942 - val_loss: 0.7712 - val_accuracy: 0.7053
# Epoch 211/1000
#
# Epoch 00211: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5858 - accuracy: 0.6882 - val_loss: 0.7547 - val_accuracy: 0.7053
# Epoch 212/1000
#
# Epoch 00212: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5806 - accuracy: 0.6926 - val_loss: 0.7429 - val_accuracy: 0.7066
# Epoch 213/1000
#
# Epoch 00213: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5837 - accuracy: 0.6778 - val_loss: 0.7212 - val_accuracy: 0.7066
# Epoch 214/1000
#
# Epoch 00214: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5997 - accuracy: 0.6899 - val_loss: 0.7131 - val_accuracy: 0.7066
# Epoch 215/1000
#
# Epoch 00215: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5934 - accuracy: 0.6860 - val_loss: 0.7121 - val_accuracy: 0.7066
# Epoch 216/1000
#
# Epoch 00216: val_accuracy did not improve from 0.94737
# 68/68 - 0s - loss: 0.5947 - accuracy: 0.6871 - val_loss: 0.7129 - val_accuracy: 0.7066

# %% [markdown]
# ### Check True True Possibility

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model

model_path = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (input_data_length, model_num)
model = load_model(model_path)
y_pred_ = model.predict(X_val, verbose=1)

target_column = y_pred_[:, [1]]
column_min, column_max = target_column.min(),target_column.max()
# print(column_min, column_max)

x_ticks = np.arange(0.8, 1, 0.005)
confidence_result = list()
for confidence in x_ticks:
  # confidence = 0.9
  scaled_confidence = column_min + (column_max - column_min) * confidence
  # print(scaled_confidence)
  print('confidence :', confidence)

  y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )

  #   inverse version   #
  # confidence = 1 - confidence
  # scaled_confidence = y_pred_[:, [-1]].min() + (y_pred_[:, [-1]].max() - y_pred_[:, [-1]].min()) * confidence
  # y_pred = np.where(y_pred_[:, [-1]] <= scaled_confidence, 1, 0).reshape(-1, )

  #     결국, Categorical 은 index 값으로 value 를 나타내는 것    #
  t_te = np.argmax(Y_val, axis=1)

  # print(y_pred_[:5])
  # print(Y_val[:5])
  # break

  pred_true = 0
  real_true = 0

  #       predict value 존나 높으면 True 일 확률 존나 높은건데, 그게 진짜 True가 맞냐 이걸 알고 싶은거지     #
  #       confidence를 만족하는 label이 1인 데이터 안에서 pred 1 / label 1 -> 이걸 도출해면 된다        #

  for i in range(len(y_pred)):
    if y_pred[i] == 1:  
      pred_true += 1
      if t_te[i] == y_pred[i]:
        real_true += 1

  print('True Pred / Total True : %s / %s' % (real_true, pred_true))
  true_true = real_true / pred_true * 100
  confidence_result.append(true_true)
  print('Accuracy : %2.f %%' % (true_true))
  print()

import matplotlib.pyplot as plt

plt.plot(x_ticks, confidence_result)
plt.axhline(50, linestyle='--', color='red')
plt.ylim(-5, 105)
plt.title('%s %s' % ((column_min, column_max)), color='white', fontsize=10)
plt.show()
# Out:
# 24/24 [==============================] - 0s 2ms/step
# confidence : 0.8
# True Pred / Total True : 0 / 173
# Accuracy :  0 %
#
# confidence : 0.805
# True Pred / Total True : 0 / 164
# Accuracy :  0 %
#
# confidence : 0.81
# True Pred / Total True : 0 / 159
# Accuracy :  0 %
#
# confidence : 0.8150000000000001
# True Pred / Total True : 0 / 150
# Accuracy :  0 %
#
# confidence : 0.8200000000000001
# True Pred / Total True : 0 / 143
# Accuracy :  0 %
#
# confidence : 0.8250000000000001
# True Pred / Total True : 0 / 140
# Accuracy :  0 %
#
# confidence : 0.8300000000000001
# True Pred / Total True : 0 / 136
# Accuracy :  0 %
#
# confidence : 0.8350000000000001
# True Pred / Total True : 0 / 132
# Accuracy :  0 %
#
# confidence : 0.8400000000000001
# True Pred / Total True : 0 / 131
# Accuracy :  0 %
#
# confidence : 0.8450000000000001
# True Pred / Total True : 0 / 128
# Accuracy :  0 %
#
# confidence : 0.8500000000000001
# True Pred / Total True : 0 / 127
# Accuracy :  0 %
#
# confidence : 0.8550000000000001
# True Pred / Total True : 0 / 124
# Accuracy :  0 %
#
# confidence : 0.8600000000000001
# True Pred / Total True : 0 / 122
# Accuracy :  0 %
#
# confidence : 0.8650000000000001
# True Pred / Total True : 0 / 120
# Accuracy :  0 %
#
# confidence : 0.8700000000000001
# True Pred / Total True : 0 / 118
# Accuracy :  0 %
#
# confidence : 0.8750000000000001
# True Pred / Total True : 0 / 114
# Accuracy :  0 %
#
# confidence : 0.8800000000000001
# True Pred / Total True : 0 / 112
# Accuracy :  0 %
#
# confidence : 0.8850000000000001
# True Pred / Total True : 0 / 110
# Accuracy :  0 %
#
# confidence : 0.8900000000000001
# True Pred / Total True : 0 / 109
# Accuracy :  0 %
#
# confidence : 0.8950000000000001
# True Pred / Total True : 0 / 108
# Accuracy :  0 %
#
# confidence : 0.9000000000000001
# True Pred / Total True : 0 / 102
# Accuracy :  0 %
#
# confidence : 0.9050000000000001
# True Pred / Total True : 0 / 95
# Accuracy :  0 %
#
# confidence : 0.9100000000000001
# True Pred / Total True : 0 / 86
# Accuracy :  0 %
#
# confidence : 0.9150000000000001
# True Pred / Total True : 0 / 68
# Accuracy :  0 %
#
# confidence : 0.9200000000000002
# True Pred / Total True : 0 / 56
# Accuracy :  0 %
#
# confidence : 0.9250000000000002
# True Pred / Total True : 0 / 50
# Accuracy :  0 %
#
# confidence : 0.9300000000000002
# True Pred / Total True : 0 / 37
# Accuracy :  0 %
#
# confidence : 0.9350000000000002
# True Pred / Total True : 0 / 28
# Accuracy :  0 %
#
# confidence : 0.9400000000000002
# True Pred / Total True : 0 / 22
# Accuracy :  0 %
#
# confidence : 0.9450000000000002
# True Pred / Total True : 0 / 14
# Accuracy :  0 %
#
# confidence : 0.9500000000000002
# True Pred / Total True : 0 / 14
# Accuracy :  0 %
#
# confidence : 0.9550000000000002
# True Pred / Total True : 0 / 12
# Accuracy :  0 %
#
# confidence : 0.9600000000000002
# True Pred / Total True : 0 / 11
# Accuracy :  0 %
#
# confidence : 0.9650000000000002
# True Pred / Total True : 0 / 9
# Accuracy :  0 %
#
# confidence : 0.9700000000000002
# True Pred / Total True : 0 / 8
# Accuracy :  0 %
#
# confidence : 0.9750000000000002
# True Pred / Total True : 0 / 8
# Accuracy :  0 %
#
# confidence : 0.9800000000000002
# True Pred / Total True : 0 / 8
# Accuracy :  0 %
#
# confidence : 0.9850000000000002
# True Pred / Total True : 0 / 8
# Accuracy :  0 %
#
# confidence : 0.9900000000000002
# True Pred / Total True : 0 / 6
# Accuracy :  0 %
#
# confidence : 0.9950000000000002
# True Pred / Total True : 0 / 4
# Accuracy :  0 %

# %% [markdown]
# ### Check Entry points in Chart

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model


confidence = 0.97
scaled_confidence = column_min + (column_max - column_min) * confidence
# print(scaled_confidence)
print('confidence :', confidence)

y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )
t_te = np.argmax(Y_val, axis=1)

close = Made_X_[-len(X_val):, [-1], [3]]
plt.plot(close)
# plt.show()

long_marker_x = list()
long_marker_y = list()
for i in range(len(y_pred)):
  if y_pred[i] == 1:  
    if t_te[i] == y_pred[i]:
      long_marker_x.append(i)
      long_marker_y.append(close[i])
      

plt.plot(long_marker_x, long_marker_y, 'o', color='blue')
plt.show()
# Out:
# confidence : 0.97

# %% [markdown]
# ### Independent True True Check

# %%
# input_data_length = int(input('input_data_length : '))
input_data_length = 30
model_num = 217
num_classes = 2

gdrive_path = '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/'

Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)


#       Data Seperation      #
# Made_X = Made_X_[:, :, [-4]]
Made_X = Made_X_[:, :, :4]
print(Made_X.shape)
print(Made_Y.shape)
# break

row = Made_X.shape[1]
col = Made_X.shape[2]

from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                   shuffle=False)

X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model

model_path = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (input_data_length, 218)
model = load_model(model_path)
y_pred_ = model.predict(X_val, verbose=1)

target_column = y_pred_[:, [-1]]
column_min, column_max = target_column.min(),target_column.max()
# print(column_min, column_max)

# x_ticks = np.arange(0.8, 1, 0.005)
x_ticks = np.arange(0.5, 0.6, 0.0001)
confidence_result = list()
for confidence in x_ticks:
  # confidence = 0.9
  scaled_confidence = confidence
  # scaled_confidence = column_min + (column_max - column_min) * confidence
  # print(scaled_confidence)
  print('confidence :', confidence)

  y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )

  #   inverse version   #
  # confidence = 1 - confidence
  # scaled_confidence = y_pred_[:, [-1]].min() + (y_pred_[:, [-1]].max() - y_pred_[:, [-1]].min()) * confidence
  # y_pred = np.where(y_pred_[:, [-1]] <= scaled_confidence, 1, 0).reshape(-1, )

  #     결국, Categorical 은 index 값으로 value 를 나타내는 것    #
  # t_te = np.argmax(Y_val, axis=1)
  t_te = Y_val

  # print(y_pred_[:5])
  # print(Y_val[:5])
  # break

  pred_true = 0
  real_true = 0

  #       predict value 존나 높으면 True 일 확률 존나 높은건데, 그게 진짜 True가 맞냐 이걸 알고 싶은거지     #
  #       confidence를 만족하는 label이 1인 데이터 안에서 pred 1 / label 1 -> 이걸 도출해면 된다        #

  for i in range(len(y_pred)):
    if y_pred[i] == 1:  
      pred_true += 1
      if t_te[i] == y_pred[i]:
        real_true += 1

  if pred_true == 0:
    true_true = 0
  else:
    true_true = real_true / pred_true * 100

  confidence_result.append(true_true)
  print('True Pred / Total True : %s / %s' % (real_true, pred_true))
  print('Accuracy : %2.f %%' % (true_true))
  print()

import matplotlib.pyplot as plt

plt.plot(x_ticks, confidence_result)
plt.axhline(50, linestyle='--', color='red')
plt.ylim(-5, 105)
plt.title('%s %s \n Best Acc = %s at %s' % ((column_min, column_max, 
                                             max(confidence_result), x_ticks[np.argmax(confidence_result)])), color='white', fontsize=10)
plt.show()
# Out:
# (1144, 30, 4)
# (1144, 1)
# 11/11 [==============================] - 0s 2ms/step
# confidence : 0.5
# True Pred / Total True : 13 / 135
# Accuracy : 10 %
#
# confidence : 0.5001
# True Pred / Total True : 13 / 134
# Accuracy : 10 %
#
# confidence : 0.5002
# True Pred / Total True : 13 / 134
# Accuracy : 10 %
#
# confidence : 0.5003
# True Pred / Total True : 13 / 134
# Accuracy : 10 %
#
# confidence : 0.5004
# True Pred / Total True : 13 / 133
# Accuracy : 10 %
#
# confidence : 0.5005
# True Pred / Total True : 13 / 133
# Accuracy : 10 %
#
# confidence : 0.5005999999999999
# True Pred / Total True : 13 / 133
# Accuracy : 10 %
#
# confidence : 0.5006999999999999
# True Pred / Total True : 13 / 133
# Accuracy : 10 %
#
# confidence : 0.5007999999999999
# True Pred / Total True : 13 / 132
# Accuracy : 10 %
#
# confidence : 0.5008999999999999
# True Pred / Total True : 13 / 132
# Accuracy : 10 %
#
# confidence : 0.5009999999999999
# True Pred / Total True : 13 / 132
# Accuracy : 10 %
#
# confidence : 0.5010999999999999
# True Pred / Total True : 13 / 130
# Accuracy : 10 %
#
# confidence : 0.5011999999999999
# True Pred / Total True : 13 / 129
# Accuracy : 10 %
#
# confidence : 0.5012999999999999
# True Pred / Total True : 13 / 129
# Accuracy : 10 %
#
# confidence : 0.5013999999999998
# True Pred / Total True : 13 / 128
# Accuracy : 10 %
#
# confidence : 0.5014999999999998
# True Pred / Total True : 13 / 128
# Accuracy : 10 %
#
# confidence : 0.5015999999999998
# True Pred / Total True : 13 / 127
# Accuracy : 10 %
#
# confidence : 0.5016999999999998
# True Pred / Total True : 13 / 126
# Accuracy : 10 %
#
# confidence : 0.5017999999999998
# True Pred / Total True : 13 / 126
# Accuracy : 10 %
#
# confidence : 0.5018999999999998
# True Pred / Total True : 13 / 126
# Accuracy : 10 %
#
# confidence : 0.5019999999999998
# True Pred / Total True : 13 / 126
# Accuracy : 10 %
#
# confidence : 0.5020999999999998
# True Pred / Total True : 13 / 125
# Accuracy : 10 %
#
# confidence : 0.5021999999999998
# True Pred / Total True : 13 / 125
# Accuracy : 10 %
#
# confidence : 0.5022999999999997
# True Pred / Total True : 13 / 124
# Accuracy : 10 %
#
# confidence : 0.5023999999999997
# True Pred / Total True : 13 / 124
# Accuracy : 10 %
#
# confidence : 0.5024999999999997
# True Pred / Total True : 13 / 124
# Accuracy : 10 %
#
# confidence : 0.5025999999999997
# True Pred / Total True : 13 / 123
# Accuracy : 11 %
#
# confidence : 0.5026999999999997
# True Pred / Total True : 13 / 122
# Accuracy : 11 %
#
# confidence : 0.5027999999999997
# True Pred / Total True : 13 / 122
# Accuracy : 11 %
#
# confidence : 0.5028999999999997
# True Pred / Total True : 13 / 120
# Accuracy : 11 %
#
# confidence : 0.5029999999999997
# True Pred / Total True : 13 / 120
# Accuracy : 11 %
#
# confidence : 0.5030999999999997
# True Pred / Total True : 13 / 120
# Accuracy : 11 %
#
# confidence : 0.5031999999999996
# True Pred / Total True : 13 / 120
# Accuracy : 11 %
#
# confidence : 0.5032999999999996
# True Pred / Total True : 13 / 120
# Accuracy : 11 %
#
# confidence : 0.5033999999999996
# True Pred / Total True : 13 / 119
# Accuracy : 11 %
#
# confidence : 0.5034999999999996
# True Pred / Total True : 13 / 117
# Accuracy : 11 %
#
# confidence : 0.5035999999999996
# True Pred / Total True : 13 / 116
# Accuracy : 11 %
#
# confidence : 0.5036999999999996
# True Pred / Total True : 13 / 114
# Accuracy : 11 %
#
# confidence : 0.5037999999999996
# True Pred / Total True : 13 / 114
# Accuracy : 11 %
#
# confidence : 0.5038999999999996
# True Pred / Total True : 13 / 111
# Accuracy : 12 %
#
# confidence : 0.5039999999999996
# True Pred / Total True : 13 / 110
# Accuracy : 12 %
#
# confidence : 0.5040999999999995
# True Pred / Total True : 12 / 108
# Accuracy : 11 %
#
# confidence : 0.5041999999999995
# True Pred / Total True : 12 / 105
# Accuracy : 11 %
#
# confidence : 0.5042999999999995
# True Pred / Total True : 12 / 103
# Accuracy : 12 %
#
# confidence : 0.5043999999999995
# True Pred / Total True : 12 / 99
# Accuracy : 12 %
#
# confidence : 0.5044999999999995
# True Pred / Total True : 12 / 97
# Accuracy : 12 %
#
# confidence : 0.5045999999999995
# True Pred / Total True : 12 / 92
# Accuracy : 13 %
#
# confidence : 0.5046999999999995
# True Pred / Total True : 12 / 90
# Accuracy : 13 %
#
# confidence : 0.5047999999999995
# True Pred / Total True : 12 / 87
# Accuracy : 14 %
#
# confidence : 0.5048999999999995
# True Pred / Total True : 12 / 83
# Accuracy : 14 %
#
# confidence : 0.5049999999999994
# True Pred / Total True : 12 / 81
# Accuracy : 15 %
#
# confidence : 0.5050999999999994
# True Pred / Total True : 12 / 78
# Accuracy : 15 %
#
# confidence : 0.5051999999999994
# True Pred / Total True : 12 / 77
# Accuracy : 16 %
#
# confidence : 0.5052999999999994
# True Pred / Total True : 12 / 76
# Accuracy : 16 %
#
# confidence : 0.5053999999999994
# True Pred / Total True : 12 / 74
# Accuracy : 16 %
#
# confidence : 0.5054999999999994
# True Pred / Total True : 12 / 71
# Accuracy : 17 %
#
# confidence : 0.5055999999999994
# True Pred / Total True : 12 / 71
# Accuracy : 17 %
#
# confidence : 0.5056999999999994
# True Pred / Total True : 11 / 66
# Accuracy : 17 %
#
# confidence : 0.5057999999999994
# True Pred / Total True : 11 / 63
# Accuracy : 17 %
#
# confidence : 0.5058999999999994
# True Pred / Total True : 11 / 62
# Accuracy : 18 %
#
# confidence : 0.5059999999999993
# True Pred / Total True : 10 / 60
# Accuracy : 17 %
#
# confidence : 0.5060999999999993
# True Pred / Total True : 9 / 56
# Accuracy : 16 %
#
# confidence : 0.5061999999999993
# True Pred / Total True : 9 / 53
# Accuracy : 17 %
#
# confidence : 0.5062999999999993
# True Pred / Total True : 9 / 48
# Accuracy : 19 %
#
# confidence : 0.5063999999999993
# True Pred / Total True : 9 / 43
# Accuracy : 21 %
#
# confidence : 0.5064999999999993
# True Pred / Total True : 9 / 41
# Accuracy : 22 %
#
# confidence : 0.5065999999999993
# True Pred / Total True : 9 / 40
# Accuracy : 22 %
#
# confidence : 0.5066999999999993
# True Pred / Total True : 9 / 37
# Accuracy : 24 %
#
# confidence : 0.5067999999999993
# True Pred / Total True : 9 / 37
# Accuracy : 24 %
#
# confidence : 0.5068999999999992
# True Pred / Total True : 9 / 36
# Accuracy : 25 %
#
# confidence : 0.5069999999999992
# True Pred / Total True : 9 / 36
# Accuracy : 25 %
#
# confidence : 0.5070999999999992
# True Pred / Total True : 9 / 35
# Accuracy : 26 %
#
# confidence : 0.5071999999999992
# True Pred / Total True : 9 / 35
# Accuracy : 26 %
#
# confidence : 0.5072999999999992
# True Pred / Total True : 9 / 32
# Accuracy : 28 %
#
# confidence : 0.5073999999999992
# True Pred / Total True : 9 / 32
# Accuracy : 28 %
#
# confidence : 0.5074999999999992
# True Pred / Total True : 9 / 32
# Accuracy : 28 %
#
# confidence : 0.5075999999999992
# True Pred / Total True : 9 / 32
# Accuracy : 28 %
#
# confidence : 0.5076999999999992
# True Pred / Total True : 9 / 32
# Accuracy : 28 %
#
# confidence : 0.5077999999999991
# True Pred / Total True : 8 / 31
# Accuracy : 26 %
#
# confidence : 0.5078999999999991
# True Pred / Total True : 8 / 30
# Accuracy : 27 %
#
# confidence : 0.5079999999999991
# True Pred / Total True : 8 / 30
# Accuracy : 27 %
#
# confidence : 0.5080999999999991
# True Pred / Total True : 8 / 29
# Accuracy : 28 %
#
# confidence : 0.5081999999999991
# True Pred / Total True : 8 / 28
# Accuracy : 29 %
#
# confidence : 0.5082999999999991
# True Pred / Total True : 8 / 28
# Accuracy : 29 %
#
# confidence : 0.5083999999999991
# True Pred / Total True : 8 / 28
# Accuracy : 29 %
#
# confidence : 0.5084999999999991
# True Pred / Total True : 8 / 28
# Accuracy : 29 %
#
# confidence : 0.508599999999999
# True Pred / Total True : 7 / 25
# Accuracy : 28 %
#
# confidence : 0.508699999999999
# True Pred / Total True : 7 / 25
# Accuracy : 28 %
#
# confidence : 0.508799999999999
# True Pred / Total True : 7 / 22
# Accuracy : 32 %
#
# confidence : 0.508899999999999
# True Pred / Total True : 7 / 20
# Accuracy : 35 %
#
# confidence : 0.508999999999999
# True Pred / Total True : 7 / 20
# Accuracy : 35 %
#
# confidence : 0.509099999999999
# True Pred / Total True : 7 / 20
# Accuracy : 35 %
#
# confidence : 0.509199999999999
# True Pred / Total True : 7 / 20
# Accuracy : 35 %
#
# confidence : 0.509299999999999
# True Pred / Total True : 7 / 18
# Accuracy : 39 %
#
# confidence : 0.509399999999999
# True Pred / Total True : 7 / 17
# Accuracy : 41 %
#
# confidence : 0.509499999999999
# True Pred / Total True : 7 / 13
# Accuracy : 54 %
#
# confidence : 0.5095999999999989
# True Pred / Total True : 7 / 13
# Accuracy : 54 %
#
# confidence : 0.5096999999999989
# True Pred / Total True : 7 / 12
# Accuracy : 58 %
#
# confidence : 0.5097999999999989
# True Pred / Total True : 6 / 11
# Accuracy : 55 %
#
# confidence : 0.5098999999999989
# True Pred / Total True : 6 / 11
# Accuracy : 55 %
#
# confidence : 0.5099999999999989
# True Pred / Total True : 6 / 11
# Accuracy : 55 %
#
# confidence : 0.5100999999999989
# True Pred / Total True : 6 / 11
# Accuracy : 55 %
#
# confidence : 0.5101999999999989
# True Pred / Total True : 6 / 10
# Accuracy : 60 %
#
# confidence : 0.5102999999999989
# True Pred / Total True : 5 / 9
# Accuracy : 56 %
#
# confidence : 0.5103999999999989
# True Pred / Total True : 5 / 9
# Accuracy : 56 %
#
# confidence : 0.5104999999999988
# True Pred / Total True : 5 / 9
# Accuracy : 56 %
#
# confidence : 0.5105999999999988
# True Pred / Total True : 4 / 8
# Accuracy : 50 %
#
# confidence : 0.5106999999999988
# True Pred / Total True : 4 / 7
# Accuracy : 57 %
#
# confidence : 0.5107999999999988
# True Pred / Total True : 3 / 5
# Accuracy : 60 %
#
# confidence : 0.5108999999999988
# True Pred / Total True : 1 / 3
# Accuracy : 33 %
#
# confidence : 0.5109999999999988
# True Pred / Total True : 1 / 3
# Accuracy : 33 %
#
# confidence : 0.5110999999999988
# True Pred / Total True : 1 / 3
# Accuracy : 33 %
#
# confidence : 0.5111999999999988
# True Pred / Total True : 1 / 3
# Accuracy : 33 %
#
# confidence : 0.5112999999999988
# True Pred / Total True : 1 / 3
# Accuracy : 33 %
#
# confidence : 0.5113999999999987
# True Pred / Total True : 0 / 2
# Accuracy :  0 %
#
# confidence : 0.5114999999999987
# True Pred / Total True : 0 / 1
# Accuracy :  0 %
#
# confidence : 0.5115999999999987
# True Pred / Total True : 0 / 1
# Accuracy :  0 %
#
# confidence : 0.5116999999999987
# True Pred / Total True : 0 / 1
# Accuracy :  0 %
#
# confidence : 0.5117999999999987
# True Pred / Total True : 0 / 1
# Accuracy :  0 %
#
# confidence : 0.5118999999999987
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5119999999999987
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5120999999999987
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5121999999999987
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5122999999999986
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5123999999999986
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5124999999999986
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5125999999999986
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5126999999999986
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5127999999999986
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5128999999999986
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5129999999999986
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5130999999999986
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5131999999999985
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5132999999999985
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5133999999999985
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5134999999999985
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5135999999999985
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5136999999999985
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5137999999999985
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5138999999999985
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5139999999999985
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5140999999999984
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5141999999999984
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5142999999999984
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5143999999999984
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5144999999999984
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5145999999999984
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5146999999999984
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5147999999999984
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5148999999999984
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5149999999999983
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5150999999999983
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5151999999999983
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5152999999999983
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5153999999999983
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5154999999999983
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5155999999999983
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5156999999999983
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5157999999999983
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5158999999999982
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5159999999999982
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5160999999999982
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5161999999999982
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5162999999999982
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5163999999999982
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5164999999999982
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5165999999999982
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5166999999999982
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5167999999999981
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5168999999999981
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5169999999999981
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5170999999999981
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5171999999999981
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5172999999999981
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5173999999999981
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5174999999999981
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5175999999999981
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.517699999999998
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.517799999999998
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.517899999999998
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.517999999999998
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.518099999999998
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.518199999999998
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.518299999999998
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.518399999999998
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.518499999999998
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.518599999999998
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5186999999999979
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5187999999999979
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5188999999999979
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5189999999999979
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5190999999999979
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5191999999999979
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5192999999999979
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5193999999999979
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5194999999999979
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5195999999999978
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5196999999999978
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5197999999999978
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5198999999999978
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5199999999999978
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5200999999999978
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5201999999999978
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5202999999999978
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5203999999999978
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5204999999999977
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5205999999999977
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5206999999999977
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5207999999999977
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5208999999999977
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5209999999999977
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5210999999999977
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5211999999999977
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5212999999999977
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5213999999999976
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5214999999999976
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5215999999999976
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5216999999999976
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5217999999999976
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5218999999999976
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5219999999999976
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5220999999999976
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5221999999999976
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5222999999999975
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5223999999999975
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5224999999999975
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5225999999999975
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5226999999999975
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5227999999999975
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5228999999999975
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5229999999999975
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5230999999999975
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5231999999999974
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5232999999999974
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5233999999999974
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5234999999999974
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5235999999999974
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5236999999999974
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5237999999999974
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5238999999999974
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5239999999999974
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5240999999999973
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5241999999999973
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5242999999999973
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5243999999999973
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5244999999999973
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5245999999999973
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5246999999999973
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5247999999999973
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5248999999999973
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5249999999999972
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5250999999999972
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5251999999999972
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5252999999999972
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5253999999999972
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5254999999999972
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5255999999999972
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5256999999999972
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5257999999999972
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5258999999999971
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5259999999999971
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5260999999999971
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5261999999999971
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5262999999999971
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5263999999999971
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5264999999999971
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5265999999999971
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5266999999999971
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.526799999999997
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.526899999999997
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.526999999999997
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.527099999999997
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.527199999999997
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.527299999999997
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.527399999999997
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.527499999999997
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.527599999999997
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.527699999999997
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5277999999999969
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5278999999999969
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5279999999999969
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5280999999999969
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5281999999999969
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5282999999999969
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5283999999999969
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5284999999999969
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5285999999999969
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5286999999999968
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5287999999999968
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5288999999999968
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5289999999999968
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5290999999999968
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5291999999999968
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5292999999999968
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5293999999999968
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5294999999999968
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5295999999999967
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5296999999999967
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5297999999999967
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5298999999999967
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5299999999999967
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5300999999999967
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5301999999999967
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5302999999999967
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5303999999999967
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5304999999999966
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5305999999999966
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5306999999999966
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5307999999999966
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5308999999999966
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5309999999999966
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5310999999999966
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5311999999999966
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5312999999999966
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5313999999999965
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5314999999999965
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5315999999999965
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5316999999999965
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5317999999999965
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5318999999999965
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5319999999999965
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5320999999999965
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5321999999999965
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5322999999999964
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5323999999999964
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5324999999999964
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5325999999999964
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5326999999999964
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5327999999999964
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5328999999999964
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5329999999999964
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5330999999999964
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5331999999999963
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5332999999999963
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5333999999999963
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5334999999999963
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5335999999999963
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5336999999999963
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5337999999999963
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5338999999999963
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5339999999999963
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5340999999999962
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5341999999999962
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5342999999999962
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5343999999999962
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5344999999999962
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5345999999999962
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5346999999999962
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5347999999999962
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5348999999999962
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5349999999999961
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5350999999999961
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5351999999999961
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5352999999999961
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5353999999999961
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5354999999999961
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5355999999999961
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5356999999999961
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5357999999999961
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.535899999999996
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.535999999999996
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.536099999999996
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.536199999999996
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.536299999999996
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.536399999999996
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.536499999999996
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.536599999999996
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.536699999999996
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.536799999999996
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5368999999999959
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5369999999999959
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5370999999999959
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5371999999999959
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5372999999999959
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5373999999999959
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5374999999999959
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5375999999999959
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5376999999999958
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5377999999999958
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5378999999999958
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5379999999999958
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5380999999999958
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5381999999999958
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5382999999999958
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5383999999999958
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5384999999999958
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5385999999999957
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5386999999999957
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5387999999999957
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5388999999999957
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5389999999999957
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5390999999999957
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5391999999999957
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5392999999999957
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5393999999999957
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5394999999999956
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5395999999999956
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5396999999999956
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5397999999999956
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5398999999999956
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5399999999999956
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5400999999999956
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5401999999999956
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5402999999999956
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5403999999999956
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5404999999999955
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5405999999999955
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5406999999999955
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5407999999999955
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5408999999999955
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5409999999999955
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5410999999999955
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5411999999999955
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5412999999999955
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5413999999999954
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5414999999999954
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5415999999999954
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5416999999999954
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5417999999999954
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5418999999999954
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5419999999999954
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5420999999999954
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5421999999999954
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5422999999999953
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5423999999999953
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5424999999999953
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5425999999999953
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5426999999999953
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5427999999999953
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5428999999999953
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5429999999999953
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5430999999999953
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5431999999999952
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5432999999999952
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5433999999999952
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5434999999999952
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5435999999999952
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5436999999999952
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5437999999999952
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5438999999999952
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5439999999999952
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5440999999999951
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5441999999999951
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5442999999999951
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5443999999999951
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5444999999999951
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5445999999999951
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5446999999999951
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5447999999999951
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.544899999999995
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.544999999999995
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.545099999999995
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.545199999999995
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.545299999999995
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.545399999999995
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.545499999999995
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.545599999999995
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.545699999999995
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.545799999999995
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.545899999999995
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5459999999999949
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5460999999999949
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5461999999999949
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5462999999999949
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5463999999999949
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5464999999999949
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5465999999999949
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5466999999999949
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5467999999999948
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5468999999999948
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5469999999999948
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5470999999999948
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5471999999999948
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5472999999999948
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5473999999999948
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5474999999999948
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5475999999999948
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5476999999999947
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5477999999999947
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5478999999999947
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5479999999999947
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5480999999999947
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5481999999999947
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5482999999999947
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5483999999999947
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5484999999999947
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5485999999999946
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5486999999999946
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5487999999999946
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5488999999999946
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5489999999999946
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5490999999999946
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5491999999999946
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5492999999999946
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5493999999999946
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5494999999999945
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5495999999999945
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5496999999999945
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5497999999999945
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5498999999999945
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5499999999999945
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5500999999999945
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5501999999999945
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5502999999999945
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5503999999999944
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5504999999999944
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5505999999999944
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5506999999999944
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5507999999999944
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5508999999999944
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5509999999999944
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5510999999999944
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5511999999999944
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5512999999999944
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5513999999999943
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5514999999999943
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5515999999999943
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5516999999999943
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5517999999999943
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5518999999999943
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5519999999999943
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5520999999999943
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5521999999999943
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5522999999999942
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5523999999999942
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5524999999999942
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5525999999999942
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5526999999999942
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5527999999999942
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5528999999999942
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5529999999999942
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5530999999999942
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5531999999999941
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5532999999999941
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5533999999999941
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5534999999999941
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5535999999999941
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5536999999999941
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5537999999999941
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5538999999999941
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.553999999999994
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.554099999999994
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.554199999999994
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.554299999999994
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.554399999999994
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.554499999999994
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.554599999999994
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.554699999999994
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.554799999999994
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.554899999999994
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5549999999999939
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5550999999999939
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5551999999999939
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5552999999999939
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5553999999999939
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5554999999999939
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5555999999999939
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5556999999999939
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5557999999999939
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5558999999999938
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5559999999999938
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5560999999999938
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5561999999999938
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5562999999999938
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5563999999999938
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5564999999999938
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5565999999999938
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5566999999999938
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5567999999999937
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5568999999999937
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5569999999999937
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5570999999999937
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5571999999999937
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5572999999999937
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5573999999999937
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5574999999999937
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5575999999999937
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5576999999999936
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5577999999999936
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5578999999999936
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5579999999999936
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5580999999999936
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5581999999999936
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5582999999999936
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5583999999999936
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5584999999999936
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5585999999999935
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5586999999999935
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5587999999999935
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5588999999999935
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5589999999999935
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5590999999999935
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5591999999999935
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5592999999999935
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5593999999999935
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5594999999999934
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5595999999999934
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5596999999999934
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# ...
# Accuracy :  0 %
#
# confidence : 0.5799999999999912
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5800999999999912
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5801999999999912
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5802999999999912
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5803999999999911
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5804999999999911
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5805999999999911
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5806999999999911
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5807999999999911
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5808999999999911
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5809999999999911
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5810999999999911
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5811999999999911
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.581299999999991
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.581399999999991
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.581499999999991
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.581599999999991
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.581699999999991
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.581799999999991
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.581899999999991
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.581999999999991
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.582099999999991
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.582199999999991
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5822999999999909
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5823999999999909
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5824999999999909
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5825999999999909
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5826999999999909
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5827999999999909
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5828999999999909
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5829999999999909
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5830999999999908
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5831999999999908
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5832999999999908
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5833999999999908
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5834999999999908
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5835999999999908
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5836999999999908
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5837999999999908
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5838999999999908
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5839999999999907
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5840999999999907
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5841999999999907
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5842999999999907
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5843999999999907
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5844999999999907
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5845999999999907
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5846999999999907
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5847999999999907
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5848999999999906
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5849999999999906
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5850999999999906
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5851999999999906
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5852999999999906
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5853999999999906
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5854999999999906
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5855999999999906
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5856999999999906
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5857999999999906
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5858999999999905
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5859999999999905
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5860999999999905
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5861999999999905
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5862999999999905
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5863999999999905
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5864999999999905
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5865999999999905
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5866999999999905
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5867999999999904
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5868999999999904
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5869999999999904
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5870999999999904
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5871999999999904
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5872999999999904
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5873999999999904
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5874999999999904
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5875999999999904
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5876999999999903
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5877999999999903
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5878999999999903
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5879999999999903
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5880999999999903
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5881999999999903
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5882999999999903
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5883999999999903
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5884999999999903
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5885999999999902
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5886999999999902
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5887999999999902
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5888999999999902
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5889999999999902
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5890999999999902
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5891999999999902
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5892999999999902
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5893999999999902
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5894999999999901
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5895999999999901
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5896999999999901
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5897999999999901
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5898999999999901
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5899999999999901
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5900999999999901
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5901999999999901
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.59029999999999
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.59039999999999
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.59049999999999
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.59059999999999
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.59069999999999
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.59079999999999
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.59089999999999
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.59099999999999
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.59109999999999
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.59119999999999
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.59129999999999
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5913999999999899
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5914999999999899
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5915999999999899
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5916999999999899
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5917999999999899
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5918999999999899
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5919999999999899
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5920999999999899
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5921999999999898
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5922999999999898
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5923999999999898
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5924999999999898
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5925999999999898
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5926999999999898
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5927999999999898
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5928999999999898
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5929999999999898
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5930999999999897
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5931999999999897
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5932999999999897
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5933999999999897
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5934999999999897
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5935999999999897
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5936999999999897
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5937999999999897
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5938999999999897
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5939999999999896
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5940999999999896
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5941999999999896
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5942999999999896
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5943999999999896
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5944999999999896
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5945999999999896
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5946999999999896
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5947999999999896
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5948999999999895
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5949999999999895
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5950999999999895
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5951999999999895
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5952999999999895
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5953999999999895
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5954999999999895
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5955999999999895
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5956999999999895
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5957999999999894
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5958999999999894
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5959999999999894
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5960999999999894
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5961999999999894
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5962999999999894
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5963999999999894
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5964999999999894
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5965999999999894
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5966999999999894
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5967999999999893
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5968999999999893
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5969999999999893
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5970999999999893
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5971999999999893
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5972999999999893
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5973999999999893
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5974999999999893
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5975999999999893
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5976999999999892
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5977999999999892
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5978999999999892
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5979999999999892
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5980999999999892
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5981999999999892
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5982999999999892
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5983999999999892
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5984999999999892
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5985999999999891
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5986999999999891
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5987999999999891
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5988999999999891
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5989999999999891
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5990999999999891
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5991999999999891
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.5992999999999891
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.599399999999989
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.599499999999989
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.599599999999989
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.599699999999989
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.599799999999989
# True Pred / Total True : 0 / 0
# Accuracy :  0 %
#
# confidence : 0.599899999999989
# True Pred / Total True : 0 / 0
# Accuracy :  0 %

# %% [markdown]
# ### Check Entry points in Chart

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model


confidence = 0.5102
scaled_confidence = confidence
# scaled_confidence = column_min + (column_max - column_min) * confidence
# print(scaled_confidence)
print('confidence :', confidence)

y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )
# t_te = np.argmax(Y_val, axis=1)
t_te = Y_val


close = Made_X_[-len(X_val):, [-1], [3]]
plt.plot(close)
# plt.show()

long_marker_x = list()
long_marker_y = list()
for i in range(len(y_pred)):
  if y_pred[i] == 1:  
    if t_te[i] == y_pred[i]:
      long_marker_x.append(i)
      long_marker_y.append(close[i])
      

plt.plot(long_marker_x, long_marker_y, 'o', color='blue')
plt.show()
# Out:
# confidence : 0.5102
