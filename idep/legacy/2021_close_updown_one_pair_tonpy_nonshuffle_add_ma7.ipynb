# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_close(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, close = target[:size].values, target[size:]
  close_shift = close.shift(1).values
  close = close.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(close)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = close[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(close) * 100), end='')

  print(len(close), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result_v2(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  ma7 = ohlcv['close'].rolling(7).mean().values[-len(predictions):]
  
  high, low, close = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(close):]

  fee = 0.0006
  org_long_profits = []
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(0, len(close)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    #   결과를 체킹하는 것, 따라서 조건식은 해당 틱 이전 틱의 데이터(진입시기)를 확인해야한다   #
    if low[i] < long_ep and i != 0:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = close[i] / long_ep - fee

        else:
          profit = close[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      #         조건식 적용       #
      # if close[i - 1] > ma7[i - 1]:
      if long_ep > ma7[i - 1]:
        long_profits.append(l_profit)
      else:
        long_profits.append(1.0)
      org_long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(close[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / close[i] - fee
    #         else:
    #           profit = close[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / close[i] - fee
    #       else:
    #         profit = close[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(close[i], predictions[i], short_ep)
    
    else:
      org_long_profits.append(1.0)
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  org_long_win_ratio = sum(np.array(org_long_profits) > 1.0) / sum(np.array(org_long_profits) != 1.0)
  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)

  org_long_frequency = sum(np.array(org_long_profits) != 1.0) / len(close)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(close)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(close)

  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(org_long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (org_long_win_ratio * 100, org_long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(np.cumprod(org_long_profits))
    plt.title('org_accum_profit : %.2f' % np.cumprod(org_long_profits)[-1], color='black')

    plt.subplot(154)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(long_accum_profit)
    plt.title('new accum_profit : %.2f' % long_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-02-11/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-02-11 BTCUSDT.xlsx', '2021-02-11 ETHUSDT.xlsx', '2021-02-11 BCHUSDT.xlsx', '2021-02-11 XRPUSDT.xlsx', '2021-02-11 EOSUSDT.xlsx', '2021-02-11 LTCUSDT.xlsx', '2021-02-11 ETCUSDT.xlsx', '2021-02-11 LINKUSDT.xlsx', '2021-02-11 XLMUSDT.xlsx', '2021-02-11 ADAUSDT.xlsx', '2021-02-11 XMRUSDT.xlsx', '2021-02-11 SXPUSDT.xlsx', '2021-02-11 KAVAUSDT.xlsx', '2021-02-11 BANDUSDT.xlsx', '2021-02-11 DASHUSDT.xlsx', '2021-02-11 ZECUSDT.xlsx', '2021-02-11 XTZUSDT.xlsx', '2021-02-11 BNBUSDT.xlsx', '2021-02-11 ATOMUSDT.xlsx', '2021-02-11 ONTUSDT.xlsx', '2021-02-11 IOTAUSDT.xlsx', '2021-02-11 BATUSDT.xlsx', '2021-02-11 NEOUSDT.xlsx', '2021-02-11 QTUMUSDT.xlsx', '2021-02-11 WAVESUSDT.xlsx', '2021-02-11 MKRUSDT.xlsx', '2021-02-11 SNXUSDT.xlsx', '2021-02-11 DOTUSDT.xlsx', '2021-02-11 THETAUSDT.xlsx', '2021-02-11 ALGOUSDT.xlsx', '2021-02-11 KNCUSDT.xlsx', '2021-02-11 ZRXUSDT.xlsx', '2021-02-11 COMPUSDT.xlsx', '2021-02-11 OMGUSDT.xlsx']

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split

with open('./arima_result/arima_opt_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
  load_dict = pickle.load(f)

candis = list(load_dict.keys())
long_index = 0
leverage = 5
prev_x = None

seed = 1
random_state = 20
np.random.seed(seed)

for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue
  if '2021-03-02 DOTUSDT.xlsx' in candis[i]:
    # print('')
    continue

  if '04-08' not in candis[i]:  # <-- 04-08 includes all timestamp range
    continue

  if 'eth'.upper() not in candis[i]:
    continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      ohlcv = load_dict[key]['ohlcv']
      # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.6)]  # exclude back_range
      # predictions = load_dict[key]['predictions']
      # err_ranges = load_dict[key]['err_ranges']
      print("ohlcv.index[0] :", ohlcv.index[0])
      print("ohlcv.index[-1] :", ohlcv.index[-1])

      predictions = ohlcv['close'].shift(1).values
      err_ranges = np.zeros_like(predictions)

      # leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result_v2(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]
        # pr_list = result[3][1]


      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = np.array(predictions)
      long_ep = long_ep.reshape(-1, 1)

      ma7 = ohlcv['close'].rolling(7).mean()


      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 45
      data_x, org_data_pr, data_pr, data_updown = [], [], [], []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          temp_ma7 = ma7.iloc[i - period : i].values.reshape(-1, 1)

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))
          temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_ma7, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          min_max = MinMaxScaler()
          temp_data[:, :-1] = min_max.fit_transform(temp_data[:, :-1])


          #   vol -> min_max
          min_max = MinMaxScaler()
          temp_data[:, [-1]] = min_max.fit_transform(temp_data[:, [-1]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          # org_data_pr.append(org_pr_list[i])
          data_pr.append(pr_list[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)

      
      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      #     do stacking   #
      if prev_x is None:
        prev_x = input_x
        prev_pr = input_pr
        prev_ud = input_ud
      else:
        total_x = np.vstack((prev_x, input_x))
        total_pr = np.vstack((prev_pr, input_pr))
        total_ud = np.vstack((prev_ud, input_ud))

        prev_x = total_x
        prev_pr = total_pr
        prev_ud = total_ud

        print('total_x.shape :', total_x.shape)
        print('total_pr.shape :', total_pr.shape)
        print('total_ud.shape :', total_ud.shape)
      # if prev_train_x is None:
      #   prev_train_x = x_train
      #   prev_val_x = x_val
      #   prev_test_x = x_test
        
      #   prev_train_pr = pr_train
      #   prev_val_pr = pr_val
      #   prev_test_pr = pr_test

      #   prev_train_ud = ud_train
      #   prev_val_ud = ud_val
      #   prev_test_ud = ud_test

      # else:

      #   total_train_x = np.vstack((prev_train_x, x_train))
      #   total_val_x = np.vstack((prev_val_x, x_val))
      #   total_test_x = np.vstack((prev_test_x, x_test))
      #   total_train_pr = np.vstack((prev_train_pr, pr_train))
      #   total_val_pr = np.vstack((prev_val_pr, pr_val))
      #   total_test_pr = np.vstack((prev_test_pr, pr_test))
      #   total_train_ud = np.vstack((prev_train_ud, ud_train))
      #   total_val_ud = np.vstack((prev_val_ud, ud_val))
      #   total_test_ud = np.vstack((prev_test_ud, ud_test))
        
      #   prev_train_x = total_train_x
      #   prev_val_x = total_val_x
      #   prev_test_x = total_test_x
        
      #   prev_train_pr = total_train_pr
      #   prev_val_pr = total_val_pr
      #   prev_test_pr = total_test_pr

      #   prev_train_ud = total_train_ud
      #   prev_val_ud = total_val_ud
      #   prev_test_ud = total_test_ud
        
      #   print("total_train_x.shape :", total_train_x.shape)
      #   print("total_val_x.shape :", total_val_x.shape)
      #   print("total_test_x.shape :", total_test_x.shape)
      #   print("total_train_pr.shape :", total_train_pr.shape)
      #   print("total_val_pr.shape :", total_val_pr.shape)
      #   print("total_test_pr.shape :", total_test_pr.shape)
      #   print("total_train_ud.shape :", total_train_ud.shape)
      #   print("total_val_ud.shape :", total_val_ud.shape)
      #   print("total_test_ud.shape :", total_test_ud.shape)

  break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  # try:
  #   if len(total_x) > 300000:
  #     break
  # except:
  #   pass
# Out:
# ohlcv.index[0] : 2020-04-17 00:29:59.999000
# ohlcv.index[-1] : 2021-04-08 20:29:59.999000
# -------------- 2021-04-08 ETHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:168: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:169: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:170: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:172: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:173: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:177: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (8819, 45, 7)
# input_x.shape : (8819, 90, 14, 3)
# input_x.dtype : float32
# input_pr.shape : (8819, 1)
# input_ud.shape : (8819, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:208: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
# #         save to npy     #
# x_save_path = current_path + 'npy/' + '%s_close_updown_theta_x_ex' % period
# y_save_path = current_path + 'npy/' + '%s_close_updown_theta_y_ex' % period


# np.save(x_save_path, input_x)
# np.save(y_save_path, input_pr)
# # print('save success !')

# print('input_x.shape :', input_x.shape)
# # print('total_x.shape :', total_x.shape)

# print('npy saved !')
# # np.save(npy_save_path, total_ud)
# Out:
# input_x.shape : (14504, 90, 12, 3)
# npy saved !

# %% [markdown]
# ### Load Data

# %%
period = 45
# x_save_path = current_path + 'npy/' + '%s_close_updown_x.npy' % period
# y_save_path = current_path + 'npy/' + '%s_close_updown_y.npy' % period
#         save to npy     #
x_save_path = current_path + 'npy/' + '%s_close_updown_theta_x_ex.npy' % period
y_save_path = current_path + 'npy/' + '%s_close_updown_theta_y_ex.npy' % period

# total_x = np.load(x_save_path)
# total_pr = np.load(y_save_path)

# _, row, col, _ = total_x.shape

_, row, col, _ = input_x.shape



seed = 1
random_state = 20
np.random.seed(seed)
from sklearn.model_selection import train_test_split
#         train / test split      #
# x_train, x_test_, pr_train, pr_test_, ud_train, ud_test_ = train_test_split(re_input_x, input_pr, input_ud, test_size=0.4, shuffle=True, random_state=random_state)
# x_train_, x_test, pr_train_, pr_test = train_test_split(total_x, total_pr, test_size=0.2, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val = train_test_split(x_train_, pr_train_, test_size=0.25, shuffle=True, random_state=random_state)
# break
x_train_, x_test, pr_train_, pr_test = train_test_split(input_x, input_pr, test_size=0.2, shuffle=False, random_state=random_state)
x_train, x_val, pr_train, pr_val = train_test_split(x_train_, pr_train_, test_size=0.25, shuffle=True, random_state=random_state)
#         pr label   #
y_train = np.where(pr_train > 1, 1, 0)
y_test = np.where(pr_test > 1, 1, 0)
y_val = np.where(pr_val > 1, 1, 0)

# del total_x

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape=(row, col, 3)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight
# import cv2


_, row, col, _ = x_train.shape

#         pr label   #
# y_train = np.where(pr_train > 1, 1, 0)
# y_test = np.where(pr_test > 1, 1, 0)
# y_val = np.where(pr_val > 1, 1, 0)


seed = 1
random_state = 20
np.random.seed(seed)
# tf.random.set_seed(seed)

#         up label      #
# y_train = np.where(ud_train > 1, 1, 0)
# y_test = np.where(ud_test > 1, 1, 0)
# y_val = np.where(ud_val > 1, 1, 0)

print('pr_train[:5] :', pr_train[:5])
# print('ud_train[:5] :', ud_train[:5])
print('y_train[:5] :', y_train[:5])
print('y_train.dtype :', y_train.dtype)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

def class_ratio(in_list):

  return in_list / in_list[1]

print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)

datagen = ImageDataGenerator( 
    rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)

batch_size = 16

for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break
# Out:
# pr_train[:5] : [[1.025003  ]
#  [0.9929604 ]
#  [0.99242634]
#  [1.01238   ]
#  [0.987192  ]]
# y_train[:5] : [[1]
#  [0]
#  [0]
#  [1]
#  [0]]
# y_train.dtype : int64
# x_train.shape : (5291, 90, 14, 3)
# x_test.shape : (1764, 90, 14, 3)
# x_val.shape : (1764, 90, 14, 3)
# y_train.shape : (5291, 1)
# y_test.shape : (1764, 1)
# y_val.shape : (1764, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3264, 2027])) [1.61026147 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([1139,  625])) [1.8224 1.    ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([981, 783])) [1.25287356 1.        ]
# class_weights : {0: 0.8105085784313726, 1: 1.3051307350764676}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (5291, 2)
# y_val_ohe.shape : (1764, 2)
# y_test_ohe.shape : (1764, 2)

# %% [markdown]
# ### **Training**

# %%
(_, row, col, _) = x_train.shape
  
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_%s_close_updown_pr_theta_val_shuffle_ma7_indi.h5' % period

# model = keras.models.load_model(ckpt_path + model_name)

model = FER_Model(input_shape=(row, col, 3))
opt = Adam(lr=0.00001, decay=0.000005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=40)
# callbacks_list = [checkpoint, checkpoint2, checkpoint3]
callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/1000
#  - 11s - loss: 0.7505 - accuracy: 0.4974 - val_loss: 0.7826 - val_accuracy: 0.6406
#
# Epoch 00001: val_loss improved from inf to 0.78262, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/1000
#  - 8s - loss: 0.7171 - accuracy: 0.5035 - val_loss: 0.7644 - val_accuracy: 0.4654
#
# Epoch 00002: val_loss improved from 0.78262 to 0.76437, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 3/1000
#  - 8s - loss: 0.7077 - accuracy: 0.5067 - val_loss: 0.5950 - val_accuracy: 0.5771
#
# Epoch 00003: val_loss improved from 0.76437 to 0.59504, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 4/1000
#  - 8s - loss: 0.7034 - accuracy: 0.5026 - val_loss: 0.7277 - val_accuracy: 0.4654
#
# Epoch 00004: val_loss did not improve from 0.59504
# Epoch 5/1000
#  - 8s - loss: 0.6967 - accuracy: 0.5169 - val_loss: 0.9660 - val_accuracy: 0.5964
#
# Epoch 00005: val_loss did not improve from 0.59504
# Epoch 6/1000
#  - 8s - loss: 0.6982 - accuracy: 0.5137 - val_loss: 0.6708 - val_accuracy: 0.5329
#
# Epoch 00006: val_loss did not improve from 0.59504
# Epoch 7/1000
#  - 8s - loss: 0.6983 - accuracy: 0.5024 - val_loss: 0.6484 - val_accuracy: 0.4989
#
# Epoch 00007: val_loss did not improve from 0.59504
# Epoch 8/1000
#  - 8s - loss: 0.6969 - accuracy: 0.5190 - val_loss: 0.7511 - val_accuracy: 0.4019
#
# Epoch 00008: val_loss did not improve from 0.59504
# Epoch 9/1000
#  - 8s - loss: 0.6957 - accuracy: 0.5201 - val_loss: 0.7278 - val_accuracy: 0.3639
#
# Epoch 00009: val_loss did not improve from 0.59504
# Epoch 10/1000
#  - 8s - loss: 0.6951 - accuracy: 0.5300 - val_loss: 0.6897 - val_accuracy: 0.5573
#
# Epoch 00010: val_loss did not improve from 0.59504
# Epoch 11/1000
#  - 8s - loss: 0.6941 - accuracy: 0.5162 - val_loss: 0.7816 - val_accuracy: 0.3832
#
# Epoch 00011: val_loss did not improve from 0.59504
# Epoch 12/1000
#  - 8s - loss: 0.6928 - accuracy: 0.5245 - val_loss: 0.7986 - val_accuracy: 0.4722
#
# Epoch 00012: val_loss did not improve from 0.59504
# Epoch 13/1000
#  - 8s - loss: 0.6948 - accuracy: 0.5152 - val_loss: 0.5937 - val_accuracy: 0.4518
#
# Epoch 00013: val_loss improved from 0.59504 to 0.59373, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 14/1000
#  - 8s - loss: 0.6928 - accuracy: 0.5169 - val_loss: 0.7059 - val_accuracy: 0.4019
#
# Epoch 00014: val_loss did not improve from 0.59373
# Epoch 15/1000
#  - 8s - loss: 0.6929 - accuracy: 0.5281 - val_loss: 0.6903 - val_accuracy: 0.4529
#
# Epoch 00015: val_loss did not improve from 0.59373
# Epoch 16/1000
#  - 8s - loss: 0.6911 - accuracy: 0.5286 - val_loss: 0.7309 - val_accuracy: 0.3946
#
# Epoch 00016: val_loss did not improve from 0.59373
# Epoch 17/1000
#  - 8s - loss: 0.6904 - accuracy: 0.5252 - val_loss: 0.6397 - val_accuracy: 0.5153
#
# Epoch 00017: val_loss did not improve from 0.59373
# Epoch 18/1000
#  - 8s - loss: 0.6904 - accuracy: 0.5362 - val_loss: 0.7001 - val_accuracy: 0.4813
#
# Epoch 00018: val_loss did not improve from 0.59373
# Epoch 19/1000
#  - 8s - loss: 0.6915 - accuracy: 0.5256 - val_loss: 0.7439 - val_accuracy: 0.6071
#
# Epoch 00019: val_loss did not improve from 0.59373
# Epoch 20/1000
#  - 8s - loss: 0.6875 - accuracy: 0.5381 - val_loss: 0.7129 - val_accuracy: 0.5147
#
# Epoch 00020: val_loss did not improve from 0.59373
# Epoch 21/1000
#  - 8s - loss: 0.6896 - accuracy: 0.5269 - val_loss: 0.7505 - val_accuracy: 0.4926
#
# Epoch 00021: val_loss did not improve from 0.59373
# Epoch 22/1000
#  - 8s - loss: 0.6904 - accuracy: 0.5356 - val_loss: 0.6486 - val_accuracy: 0.5737
#
# Epoch 00022: val_loss did not improve from 0.59373
# Epoch 23/1000
#  - 8s - loss: 0.6903 - accuracy: 0.5237 - val_loss: 0.6458 - val_accuracy: 0.6219
#
# Epoch 00023: val_loss did not improve from 0.59373
# Epoch 24/1000
#  - 8s - loss: 0.6873 - accuracy: 0.5458 - val_loss: 0.6297 - val_accuracy: 0.5363
#
# Epoch 00024: val_loss did not improve from 0.59373
# Epoch 25/1000
#  - 8s - loss: 0.6885 - accuracy: 0.5409 - val_loss: 0.5999 - val_accuracy: 0.5091
#
# Epoch 00025: val_loss did not improve from 0.59373
# Epoch 26/1000
#  - 8s - loss: 0.6856 - accuracy: 0.5366 - val_loss: 0.7055 - val_accuracy: 0.5896
#
# Epoch 00026: val_loss did not improve from 0.59373
# Epoch 27/1000
#  - 8s - loss: 0.6840 - accuracy: 0.5492 - val_loss: 0.8019 - val_accuracy: 0.4705
#
# Epoch 00027: val_loss did not improve from 0.59373
# Epoch 28/1000
#  - 8s - loss: 0.6840 - accuracy: 0.5507 - val_loss: 0.8111 - val_accuracy: 0.5289
#
# Epoch 00028: val_loss did not improve from 0.59373
# Epoch 29/1000
#  - 8s - loss: 0.6824 - accuracy: 0.5553 - val_loss: 0.6162 - val_accuracy: 0.5278
#
# Epoch 00029: val_loss did not improve from 0.59373
# Epoch 30/1000
#  - 8s - loss: 0.6856 - accuracy: 0.5436 - val_loss: 0.5643 - val_accuracy: 0.5391
#
# Epoch 00030: val_loss improved from 0.59373 to 0.56427, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 31/1000
#  - 8s - loss: 0.6834 - accuracy: 0.5473 - val_loss: 0.6761 - val_accuracy: 0.5573
#
# Epoch 00031: val_loss did not improve from 0.56427
# Epoch 32/1000
#  - 8s - loss: 0.6808 - accuracy: 0.5519 - val_loss: 0.6639 - val_accuracy: 0.4563
#
# Epoch 00032: val_loss did not improve from 0.56427
# Epoch 33/1000
#  - 8s - loss: 0.6784 - accuracy: 0.5606 - val_loss: 0.8271 - val_accuracy: 0.4212
#
# Epoch 00033: val_loss did not improve from 0.56427
# Epoch 34/1000
#  - 8s - loss: 0.6814 - accuracy: 0.5604 - val_loss: 0.5871 - val_accuracy: 0.4728
#
# Epoch 00034: val_loss did not improve from 0.56427
# Epoch 35/1000
#  - 8s - loss: 0.6767 - accuracy: 0.5632 - val_loss: 0.6967 - val_accuracy: 0.5017
#
# Epoch 00035: val_loss did not improve from 0.56427
# Epoch 36/1000
#  - 8s - loss: 0.6783 - accuracy: 0.5644 - val_loss: 0.6041 - val_accuracy: 0.4972
#
# Epoch 00036: val_loss did not improve from 0.56427
# Epoch 37/1000
#  - 8s - loss: 0.6765 - accuracy: 0.5649 - val_loss: 0.6011 - val_accuracy: 0.5215
#
# Epoch 00037: val_loss did not improve from 0.56427
# Epoch 38/1000
#  - 8s - loss: 0.6727 - accuracy: 0.5683 - val_loss: 0.7714 - val_accuracy: 0.5527
#
# Epoch 00038: val_loss did not improve from 0.56427
# Epoch 39/1000
#  - 8s - loss: 0.6746 - accuracy: 0.5778 - val_loss: 0.7801 - val_accuracy: 0.4768
#
# Epoch 00039: val_loss did not improve from 0.56427
# Epoch 40/1000
#  - 8s - loss: 0.6713 - accuracy: 0.5679 - val_loss: 0.6911 - val_accuracy: 0.5833
#
# Epoch 00040: val_loss did not improve from 0.56427
# Epoch 41/1000
#  - 8s - loss: 0.6694 - accuracy: 0.5833 - val_loss: 0.7085 - val_accuracy: 0.5556
#
# Epoch 00041: val_loss did not improve from 0.56427
# Epoch 42/1000
#  - 8s - loss: 0.6718 - accuracy: 0.5763 - val_loss: 1.1856 - val_accuracy: 0.5448
#
# Epoch 00042: val_loss did not improve from 0.56427
# Epoch 43/1000
#  - 8s - loss: 0.6687 - accuracy: 0.5844 - val_loss: 0.7390 - val_accuracy: 0.5232
#
# Epoch 00043: val_loss did not improve from 0.56427
# Epoch 44/1000
#  - 8s - loss: 0.6668 - accuracy: 0.5816 - val_loss: 0.6611 - val_accuracy: 0.5210
#
# Epoch 00044: val_loss did not improve from 0.56427
# Epoch 45/1000
#  - 8s - loss: 0.6664 - accuracy: 0.5827 - val_loss: 0.6428 - val_accuracy: 0.5193
#
# Epoch 00045: val_loss did not improve from 0.56427
# Epoch 46/1000
#  - 8s - loss: 0.6596 - accuracy: 0.5971 - val_loss: 0.5498 - val_accuracy: 0.5595
#
# Epoch 00046: val_loss improved from 0.56427 to 0.54983, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 47/1000
#  - 8s - loss: 0.6646 - accuracy: 0.5959 - val_loss: 0.9778 - val_accuracy: 0.5992
#
# Epoch 00047: val_loss did not improve from 0.54983
# Epoch 48/1000
#  - 8s - loss: 0.6604 - accuracy: 0.5946 - val_loss: 0.5985 - val_accuracy: 0.5635
#
# Epoch 00048: val_loss did not improve from 0.54983
# Epoch 49/1000
#  - 8s - loss: 0.6594 - accuracy: 0.5955 - val_loss: 0.8318 - val_accuracy: 0.4892
#
# Epoch 00049: val_loss did not improve from 0.54983
# Epoch 50/1000
#  - 8s - loss: 0.6556 - accuracy: 0.5988 - val_loss: 0.5986 - val_accuracy: 0.5113
#
# Epoch 00050: val_loss did not improve from 0.54983
# Epoch 51/1000
#  - 8s - loss: 0.6592 - accuracy: 0.5986 - val_loss: 0.5916 - val_accuracy: 0.5113
#
# Epoch 00051: val_loss did not improve from 0.54983
# Epoch 52/1000
#  - 8s - loss: 0.6546 - accuracy: 0.6022 - val_loss: 1.1614 - val_accuracy: 0.4813
#
# Epoch 00052: val_loss did not improve from 0.54983
# Epoch 53/1000
#  - 8s - loss: 0.6555 - accuracy: 0.6014 - val_loss: 1.0306 - val_accuracy: 0.5023
#
# Epoch 00053: val_loss did not improve from 0.54983
# Epoch 54/1000
#  - 8s - loss: 0.6502 - accuracy: 0.6082 - val_loss: 0.7294 - val_accuracy: 0.5346
#
# Epoch 00054: val_loss did not improve from 0.54983
# Epoch 55/1000
#  - 8s - loss: 0.6506 - accuracy: 0.6069 - val_loss: 0.6827 - val_accuracy: 0.5317
#
# Epoch 00055: val_loss did not improve from 0.54983
# Epoch 56/1000
#  - 8s - loss: 0.6463 - accuracy: 0.6245 - val_loss: 1.0756 - val_accuracy: 0.4864
#
# Epoch 00056: val_loss did not improve from 0.54983
# Epoch 57/1000
#  - 8s - loss: 0.6476 - accuracy: 0.6116 - val_loss: 0.7767 - val_accuracy: 0.5096
#
# Epoch 00057: val_loss did not improve from 0.54983
# Epoch 58/1000
#  - 8s - loss: 0.6436 - accuracy: 0.6163 - val_loss: 0.7151 - val_accuracy: 0.4966
#
# Epoch 00058: val_loss did not improve from 0.54983
# Epoch 59/1000
#  - 8s - loss: 0.6386 - accuracy: 0.6284 - val_loss: 0.7546 - val_accuracy: 0.5204
#
# Epoch 00059: val_loss did not improve from 0.54983
# Epoch 60/1000
#  - 8s - loss: 0.6390 - accuracy: 0.6231 - val_loss: 0.4741 - val_accuracy: 0.5357
#
# Epoch 00060: val_loss improved from 0.54983 to 0.47407, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 61/1000
#  - 8s - loss: 0.6382 - accuracy: 0.6152 - val_loss: 0.5067 - val_accuracy: 0.5136
#
# Epoch 00061: val_loss did not improve from 0.47407
# Epoch 62/1000
#  - 8s - loss: 0.6389 - accuracy: 0.6279 - val_loss: 0.9325 - val_accuracy: 0.4802
#
# Epoch 00062: val_loss did not improve from 0.47407
# Epoch 63/1000
#  - 8s - loss: 0.6320 - accuracy: 0.6364 - val_loss: 0.4003 - val_accuracy: 0.5130
#
# Epoch 00063: val_loss improved from 0.47407 to 0.40033, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 64/1000
#  - 8s - loss: 0.6334 - accuracy: 0.6347 - val_loss: 0.8324 - val_accuracy: 0.5085
#
# Epoch 00064: val_loss did not improve from 0.40033
# Epoch 65/1000
#  - 8s - loss: 0.6280 - accuracy: 0.6366 - val_loss: 0.7643 - val_accuracy: 0.4858
#
# Epoch 00065: val_loss did not improve from 0.40033
# Epoch 66/1000
#  - 8s - loss: 0.6311 - accuracy: 0.6401 - val_loss: 0.7822 - val_accuracy: 0.5272
#
# Epoch 00066: val_loss did not improve from 0.40033
# Epoch 67/1000
#  - 8s - loss: 0.6303 - accuracy: 0.6379 - val_loss: 0.5654 - val_accuracy: 0.5215
#
# Epoch 00067: val_loss did not improve from 0.40033
# Epoch 68/1000
#  - 8s - loss: 0.6269 - accuracy: 0.6418 - val_loss: 0.6194 - val_accuracy: 0.4836
#
# Epoch 00068: val_loss did not improve from 0.40033
# Epoch 69/1000
#  - 8s - loss: 0.6214 - accuracy: 0.6443 - val_loss: 0.5294 - val_accuracy: 0.5164
#
# Epoch 00069: val_loss did not improve from 0.40033
# Epoch 70/1000
#  - 8s - loss: 0.6180 - accuracy: 0.6566 - val_loss: 1.0019 - val_accuracy: 0.5368
#
# Epoch 00070: val_loss did not improve from 0.40033
# Epoch 71/1000
#  - 8s - loss: 0.6185 - accuracy: 0.6490 - val_loss: 0.7780 - val_accuracy: 0.4960
#
# Epoch 00071: val_loss did not improve from 0.40033
# Epoch 72/1000
#  - 8s - loss: 0.6178 - accuracy: 0.6602 - val_loss: 0.5314 - val_accuracy: 0.5119
#
# Epoch 00072: val_loss did not improve from 0.40033
# Epoch 73/1000
#  - 8s - loss: 0.6151 - accuracy: 0.6486 - val_loss: 0.7027 - val_accuracy: 0.5465
#
# Epoch 00073: val_loss did not improve from 0.40033
# Epoch 74/1000
#  - 8s - loss: 0.6081 - accuracy: 0.6606 - val_loss: 0.6205 - val_accuracy: 0.5533
#
# Epoch 00074: val_loss did not improve from 0.40033
# Epoch 75/1000
#  - 8s - loss: 0.6134 - accuracy: 0.6555 - val_loss: 0.7921 - val_accuracy: 0.5215
#
# Epoch 00075: val_loss did not improve from 0.40033
# Epoch 76/1000
#  - 8s - loss: 0.6046 - accuracy: 0.6555 - val_loss: 0.4821 - val_accuracy: 0.5357
#
# Epoch 00076: val_loss did not improve from 0.40033
# Epoch 77/1000
#  - 8s - loss: 0.6059 - accuracy: 0.6655 - val_loss: 0.6480 - val_accuracy: 0.5108
#
# Epoch 00077: val_loss did not improve from 0.40033
# Epoch 78/1000
#  - 8s - loss: 0.6116 - accuracy: 0.6623 - val_loss: 0.5419 - val_accuracy: 0.5420
#
# Epoch 00078: val_loss did not improve from 0.40033
# Epoch 79/1000
#  - 8s - loss: 0.5983 - accuracy: 0.6672 - val_loss: 0.7934 - val_accuracy: 0.5556
#
# Epoch 00079: val_loss did not improve from 0.40033
# Epoch 80/1000
#  - 8s - loss: 0.5989 - accuracy: 0.6657 - val_loss: 0.5926 - val_accuracy: 0.5799
#
# Epoch 00080: val_loss did not improve from 0.40033
# Epoch 81/1000
#  - 8s - loss: 0.5981 - accuracy: 0.6753 - val_loss: 0.6499 - val_accuracy: 0.5544
#
# Epoch 00081: val_loss did not improve from 0.40033
# Epoch 82/1000
#  - 8s - loss: 0.5981 - accuracy: 0.6674 - val_loss: 0.6782 - val_accuracy: 0.5873
#
# Epoch 00082: val_loss did not improve from 0.40033
# Epoch 83/1000
#  - 8s - loss: 0.5924 - accuracy: 0.6830 - val_loss: 0.6396 - val_accuracy: 0.5476
#
# Epoch 00083: val_loss did not improve from 0.40033
# Epoch 84/1000
#  - 8s - loss: 0.5912 - accuracy: 0.6768 - val_loss: 1.1855 - val_accuracy: 0.5499
#
# Epoch 00084: val_loss did not improve from 0.40033
# Epoch 85/1000
#  - 8s - loss: 0.5911 - accuracy: 0.6823 - val_loss: 0.5226 - val_accuracy: 0.5471
#
# Epoch 00085: val_loss did not improve from 0.40033
# Epoch 86/1000
#  - 8s - loss: 0.5892 - accuracy: 0.6864 - val_loss: 0.6643 - val_accuracy: 0.5510
#
# Epoch 00086: val_loss did not improve from 0.40033
# Epoch 87/1000
#  - 8s - loss: 0.5844 - accuracy: 0.6893 - val_loss: 1.0581 - val_accuracy: 0.5550
#
# Epoch 00087: val_loss did not improve from 0.40033
# Epoch 88/1000
#  - 8s - loss: 0.5840 - accuracy: 0.6874 - val_loss: 0.8253 - val_accuracy: 0.5499
#
# Epoch 00088: val_loss did not improve from 0.40033
# Epoch 89/1000
#  - 8s - loss: 0.5771 - accuracy: 0.6885 - val_loss: 0.8191 - val_accuracy: 0.5385
#
# Epoch 00089: val_loss did not improve from 0.40033
# Epoch 90/1000
#  - 8s - loss: 0.5801 - accuracy: 0.6796 - val_loss: 0.3615 - val_accuracy: 0.5743
#
# Epoch 00090: val_loss improved from 0.40033 to 0.36146, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 91/1000
#  - 8s - loss: 0.5762 - accuracy: 0.6985 - val_loss: 0.8034 - val_accuracy: 0.5391
#
# Epoch 00091: val_loss did not improve from 0.36146
# Epoch 92/1000
#  - 8s - loss: 0.5680 - accuracy: 0.7029 - val_loss: 0.7471 - val_accuracy: 0.5680
#
# Epoch 00092: val_loss did not improve from 0.36146
# Epoch 93/1000
#  - 8s - loss: 0.5746 - accuracy: 0.6900 - val_loss: 1.0677 - val_accuracy: 0.5533
#
# Epoch 00093: val_loss did not improve from 0.36146
# Epoch 94/1000
#  - 8s - loss: 0.5678 - accuracy: 0.7018 - val_loss: 1.3228 - val_accuracy: 0.5300
#
# Epoch 00094: val_loss did not improve from 0.36146
# Epoch 95/1000
#  - 8s - loss: 0.5618 - accuracy: 0.7078 - val_loss: 0.9687 - val_accuracy: 0.5703
#
# Epoch 00095: val_loss did not improve from 0.36146
# Epoch 96/1000
#  - 8s - loss: 0.5640 - accuracy: 0.7063 - val_loss: 0.8943 - val_accuracy: 0.5414
#
# Epoch 00096: val_loss did not improve from 0.36146
# Epoch 97/1000
#  - 8s - loss: 0.5614 - accuracy: 0.7088 - val_loss: 0.6312 - val_accuracy: 0.5442
#
# Epoch 00097: val_loss did not improve from 0.36146
# Epoch 98/1000
#  - 8s - loss: 0.5577 - accuracy: 0.7122 - val_loss: 0.6876 - val_accuracy: 0.5397
#
# Epoch 00098: val_loss did not improve from 0.36146
# Epoch 99/1000
#  - 8s - loss: 0.5574 - accuracy: 0.7025 - val_loss: 0.8674 - val_accuracy: 0.5697
#
# Epoch 00099: val_loss did not improve from 0.36146
# Epoch 100/1000
#  - 8s - loss: 0.5555 - accuracy: 0.7118 - val_loss: 1.5888 - val_accuracy: 0.5289
#
# Epoch 00100: val_loss did not improve from 0.36146
# Epoch 101/1000
#  - 8s - loss: 0.5563 - accuracy: 0.7078 - val_loss: 0.2987 - val_accuracy: 0.5312
#
# Epoch 00101: val_loss improved from 0.36146 to 0.29868, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 102/1000
#  - 8s - loss: 0.5491 - accuracy: 0.7076 - val_loss: 0.6857 - val_accuracy: 0.5266
#
# Epoch 00102: val_loss did not improve from 0.29868
# Epoch 103/1000
#  - 8s - loss: 0.5469 - accuracy: 0.7250 - val_loss: 1.4520 - val_accuracy: 0.5176
#
# Epoch 00103: val_loss did not improve from 0.29868
# Epoch 104/1000
#  - 8s - loss: 0.5410 - accuracy: 0.7259 - val_loss: 0.7696 - val_accuracy: 0.5147
#
# Epoch 00104: val_loss did not improve from 0.29868
# Epoch 105/1000
#  - 8s - loss: 0.5523 - accuracy: 0.7131 - val_loss: 0.7481 - val_accuracy: 0.5295
#
# Epoch 00105: val_loss did not improve from 0.29868
# Epoch 106/1000
#  - 8s - loss: 0.5496 - accuracy: 0.7154 - val_loss: 0.7363 - val_accuracy: 0.5221
#
# Epoch 00106: val_loss did not improve from 0.29868
# Epoch 107/1000
#  - 8s - loss: 0.5346 - accuracy: 0.7305 - val_loss: 0.6068 - val_accuracy: 0.5244
#
# Epoch 00107: val_loss did not improve from 0.29868
# Epoch 108/1000
#  - 8s - loss: 0.5375 - accuracy: 0.7218 - val_loss: 0.8174 - val_accuracy: 0.5368
#
# Epoch 00108: val_loss did not improve from 0.29868
# Epoch 109/1000
#  - 8s - loss: 0.5323 - accuracy: 0.7335 - val_loss: 0.9544 - val_accuracy: 0.5459
#
# Epoch 00109: val_loss did not improve from 0.29868
# Epoch 110/1000
#  - 8s - loss: 0.5277 - accuracy: 0.7348 - val_loss: 0.7380 - val_accuracy: 0.5057
#
# Epoch 00110: val_loss did not improve from 0.29868
# Epoch 111/1000
#  - 8s - loss: 0.5302 - accuracy: 0.7292 - val_loss: 0.8476 - val_accuracy: 0.4989
#
# Epoch 00111: val_loss did not improve from 0.29868
# Epoch 112/1000
#  - 8s - loss: 0.5339 - accuracy: 0.7250 - val_loss: 0.7475 - val_accuracy: 0.5385
#
# Epoch 00112: val_loss did not improve from 0.29868
# Epoch 113/1000
#  - 8s - loss: 0.5198 - accuracy: 0.7339 - val_loss: 0.3522 - val_accuracy: 0.5108
#
# Epoch 00113: val_loss did not improve from 0.29868
# Epoch 114/1000
#  - 8s - loss: 0.5233 - accuracy: 0.7380 - val_loss: 0.6455 - val_accuracy: 0.5431
#
# Epoch 00114: val_loss did not improve from 0.29868
# Epoch 115/1000
#  - 8s - loss: 0.5242 - accuracy: 0.7411 - val_loss: 0.7818 - val_accuracy: 0.5147
#
# Epoch 00115: val_loss did not improve from 0.29868
# Epoch 116/1000
#  - 8s - loss: 0.5198 - accuracy: 0.7407 - val_loss: 1.0103 - val_accuracy: 0.5510
#
# Epoch 00116: val_loss did not improve from 0.29868
# Epoch 117/1000
#  - 8s - loss: 0.5163 - accuracy: 0.7441 - val_loss: 0.5225 - val_accuracy: 0.5085
#
# Epoch 00117: val_loss did not improve from 0.29868
# Epoch 118/1000
#  - 8s - loss: 0.5199 - accuracy: 0.7367 - val_loss: 0.8486 - val_accuracy: 0.5261
#
# Epoch 00118: val_loss did not improve from 0.29868
# Epoch 119/1000
#  - 8s - loss: 0.5092 - accuracy: 0.7473 - val_loss: 0.8286 - val_accuracy: 0.5811
#
# Epoch 00119: val_loss did not improve from 0.29868
# Epoch 120/1000
#  - 8s - loss: 0.5103 - accuracy: 0.7490 - val_loss: 0.4421 - val_accuracy: 0.5181
#
# Epoch 00120: val_loss did not improve from 0.29868
# Epoch 121/1000
#  - 8s - loss: 0.5038 - accuracy: 0.7477 - val_loss: 1.2391 - val_accuracy: 0.5312
#
# Epoch 00121: val_loss did not improve from 0.29868
# Epoch 122/1000
#  - 8s - loss: 0.5103 - accuracy: 0.7477 - val_loss: 0.3721 - val_accuracy: 0.5414
#
# Epoch 00122: val_loss did not improve from 0.29868
# Epoch 123/1000
#  - 8s - loss: 0.5104 - accuracy: 0.7414 - val_loss: 0.7409 - val_accuracy: 0.5300
#
# Epoch 00123: val_loss did not improve from 0.29868
# Epoch 124/1000
#  - 8s - loss: 0.4950 - accuracy: 0.7592 - val_loss: 0.3924 - val_accuracy: 0.5221
#
# Epoch 00124: val_loss did not improve from 0.29868
# Epoch 125/1000
#  - 8s - loss: 0.4974 - accuracy: 0.7477 - val_loss: 0.7002 - val_accuracy: 0.5261
#
# Epoch 00125: val_loss did not improve from 0.29868
# Epoch 126/1000
#  - 8s - loss: 0.4967 - accuracy: 0.7556 - val_loss: 1.3405 - val_accuracy: 0.5215
#
# Epoch 00126: val_loss did not improve from 0.29868
# Epoch 127/1000
#  - 8s - loss: 0.5012 - accuracy: 0.7439 - val_loss: 0.6243 - val_accuracy: 0.5357
#
# Epoch 00127: val_loss did not improve from 0.29868
# Epoch 128/1000
#  - 8s - loss: 0.4950 - accuracy: 0.7545 - val_loss: 0.2830 - val_accuracy: 0.5028
#
# Epoch 00128: val_loss improved from 0.29868 to 0.28305, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 129/1000
#  - 8s - loss: 0.4887 - accuracy: 0.7632 - val_loss: 0.7979 - val_accuracy: 0.5221
#
# Epoch 00129: val_loss did not improve from 0.28305
# Epoch 130/1000
#  - 8s - loss: 0.4929 - accuracy: 0.7549 - val_loss: 1.3330 - val_accuracy: 0.5045
#
# Epoch 00130: val_loss did not improve from 0.28305
# Epoch 131/1000
#  - 8s - loss: 0.4880 - accuracy: 0.7573 - val_loss: 0.4747 - val_accuracy: 0.5380
#
# Epoch 00131: val_loss did not improve from 0.28305
# Epoch 132/1000
#  - 8s - loss: 0.4881 - accuracy: 0.7605 - val_loss: 1.0816 - val_accuracy: 0.5522
#
# Epoch 00132: val_loss did not improve from 0.28305
# Epoch 133/1000
#  - 8s - loss: 0.4742 - accuracy: 0.7721 - val_loss: 0.7991 - val_accuracy: 0.5125
#
# Epoch 00133: val_loss did not improve from 0.28305
# Epoch 134/1000
#  - 8s - loss: 0.4793 - accuracy: 0.7717 - val_loss: 1.2273 - val_accuracy: 0.5431
#
# Epoch 00134: val_loss did not improve from 0.28305
# Epoch 135/1000
#  - 8s - loss: 0.4705 - accuracy: 0.7719 - val_loss: 1.2018 - val_accuracy: 0.5147
#
# Epoch 00135: val_loss did not improve from 0.28305
# Epoch 136/1000
#  - 8s - loss: 0.4788 - accuracy: 0.7724 - val_loss: 0.8949 - val_accuracy: 0.5544
#
# Epoch 00136: val_loss did not improve from 0.28305
# Epoch 137/1000
#  - 8s - loss: 0.4664 - accuracy: 0.7775 - val_loss: 1.4380 - val_accuracy: 0.5045
#
# Epoch 00137: val_loss did not improve from 0.28305
# Epoch 138/1000
#  - 8s - loss: 0.4693 - accuracy: 0.7775 - val_loss: 0.3011 - val_accuracy: 0.5527
#
# Epoch 00138: val_loss did not improve from 0.28305
# Epoch 139/1000
#  - 8s - loss: 0.4545 - accuracy: 0.7857 - val_loss: 0.6731 - val_accuracy: 0.5420
#
# Epoch 00139: val_loss did not improve from 0.28305
# Epoch 140/1000
#  - 8s - loss: 0.4594 - accuracy: 0.7832 - val_loss: 0.4570 - val_accuracy: 0.5499
#
# Epoch 00140: val_loss did not improve from 0.28305
# Epoch 141/1000
#  - 8s - loss: 0.4526 - accuracy: 0.7862 - val_loss: 0.8350 - val_accuracy: 0.5187
#
# Epoch 00141: val_loss did not improve from 0.28305
# Epoch 142/1000
#  - 8s - loss: 0.4542 - accuracy: 0.7874 - val_loss: 1.1832 - val_accuracy: 0.5346
#
# Epoch 00142: val_loss did not improve from 0.28305
# Epoch 143/1000
#  - 8s - loss: 0.4454 - accuracy: 0.7989 - val_loss: 1.0059 - val_accuracy: 0.5624
#
# Epoch 00143: val_loss did not improve from 0.28305
# Epoch 144/1000
#  - 8s - loss: 0.4481 - accuracy: 0.7883 - val_loss: 1.0029 - val_accuracy: 0.5351
#
# Epoch 00144: val_loss did not improve from 0.28305
# Epoch 145/1000
#  - 8s - loss: 0.4584 - accuracy: 0.7755 - val_loss: 1.5935 - val_accuracy: 0.5590
#
# Epoch 00145: val_loss did not improve from 0.28305
# Epoch 146/1000
#  - 8s - loss: 0.4451 - accuracy: 0.7913 - val_loss: 1.1664 - val_accuracy: 0.5420
#
# Epoch 00146: val_loss did not improve from 0.28305
# Epoch 147/1000
#  - 8s - loss: 0.4503 - accuracy: 0.7796 - val_loss: 0.9273 - val_accuracy: 0.5714
#
# Epoch 00147: val_loss did not improve from 0.28305
# Epoch 148/1000
#  - 8s - loss: 0.4445 - accuracy: 0.7895 - val_loss: 1.7597 - val_accuracy: 0.5556
#
# Epoch 00148: val_loss did not improve from 0.28305
# Epoch 149/1000
#  - 8s - loss: 0.4430 - accuracy: 0.7968 - val_loss: 0.6508 - val_accuracy: 0.5414
#
# Epoch 00149: val_loss did not improve from 0.28305
# Epoch 150/1000
#  - 8s - loss: 0.4445 - accuracy: 0.7900 - val_loss: 0.7953 - val_accuracy: 0.5561
#
# Epoch 00150: val_loss did not improve from 0.28305
# Epoch 151/1000
#  - 8s - loss: 0.4410 - accuracy: 0.7904 - val_loss: 0.4646 - val_accuracy: 0.5437
#
# Epoch 00151: val_loss did not improve from 0.28305
# Epoch 152/1000
#  - 8s - loss: 0.4436 - accuracy: 0.7934 - val_loss: 1.9826 - val_accuracy: 0.5522
#
# Epoch 00152: val_loss did not improve from 0.28305
# Epoch 153/1000
#  - 8s - loss: 0.4340 - accuracy: 0.7978 - val_loss: 0.3641 - val_accuracy: 0.5261
#
# Epoch 00153: val_loss did not improve from 0.28305
# Epoch 154/1000
#  - 8s - loss: 0.4331 - accuracy: 0.7983 - val_loss: 1.3054 - val_accuracy: 0.5505
#
# Epoch 00154: val_loss did not improve from 0.28305
# Epoch 155/1000
#  - 8s - loss: 0.4343 - accuracy: 0.7881 - val_loss: 1.6256 - val_accuracy: 0.4966
#
# Epoch 00155: val_loss did not improve from 0.28305
# Epoch 156/1000
#  - 8s - loss: 0.4334 - accuracy: 0.7998 - val_loss: 0.8866 - val_accuracy: 0.5006
#
# Epoch 00156: val_loss did not improve from 0.28305
# Epoch 157/1000
#  - 8s - loss: 0.4352 - accuracy: 0.7989 - val_loss: 0.9040 - val_accuracy: 0.5153
#
# Epoch 00157: val_loss did not improve from 0.28305
# Epoch 158/1000
#  - 8s - loss: 0.4212 - accuracy: 0.8078 - val_loss: 0.2136 - val_accuracy: 0.5136
#
# Epoch 00158: val_loss improved from 0.28305 to 0.21364, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 159/1000
#  - 8s - loss: 0.4200 - accuracy: 0.8015 - val_loss: 0.8123 - val_accuracy: 0.5283
#
# Epoch 00159: val_loss did not improve from 0.21364
# Epoch 160/1000
#  - 8s - loss: 0.4191 - accuracy: 0.8053 - val_loss: 0.5891 - val_accuracy: 0.5618
#
# Epoch 00160: val_loss did not improve from 0.21364
# Epoch 161/1000
#  - 8s - loss: 0.4123 - accuracy: 0.8110 - val_loss: 0.4469 - val_accuracy: 0.5085
#
# Epoch 00161: val_loss did not improve from 0.21364
# Epoch 162/1000
#  - 8s - loss: 0.4137 - accuracy: 0.8101 - val_loss: 1.0831 - val_accuracy: 0.5204
#
# Epoch 00162: val_loss did not improve from 0.21364
# Epoch 163/1000
#  - 8s - loss: 0.4132 - accuracy: 0.8153 - val_loss: 0.8626 - val_accuracy: 0.5062
#
# Epoch 00163: val_loss did not improve from 0.21364
# Epoch 164/1000
#  - 8s - loss: 0.4133 - accuracy: 0.8072 - val_loss: 0.5988 - val_accuracy: 0.5295
#
# Epoch 00164: val_loss did not improve from 0.21364
# Epoch 165/1000
#  - 8s - loss: 0.4071 - accuracy: 0.8114 - val_loss: 0.4060 - val_accuracy: 0.5397
#
# Epoch 00165: val_loss did not improve from 0.21364
# Epoch 166/1000
#  - 8s - loss: 0.4108 - accuracy: 0.8138 - val_loss: 1.1665 - val_accuracy: 0.5130
#
# Epoch 00166: val_loss did not improve from 0.21364
# Epoch 167/1000
#  - 8s - loss: 0.4101 - accuracy: 0.8133 - val_loss: 1.8291 - val_accuracy: 0.5420
#
# Epoch 00167: val_loss did not improve from 0.21364
# Epoch 168/1000
#  - 8s - loss: 0.4047 - accuracy: 0.8142 - val_loss: 1.3784 - val_accuracy: 0.5312
#
# Epoch 00168: val_loss did not improve from 0.21364
# Epoch 169/1000
#  - 8s - loss: 0.4016 - accuracy: 0.8197 - val_loss: 0.7477 - val_accuracy: 0.5278
#
# Epoch 00169: val_loss did not improve from 0.21364
# Epoch 170/1000
#  - 8s - loss: 0.3953 - accuracy: 0.8203 - val_loss: 0.8660 - val_accuracy: 0.5295
#
# Epoch 00170: val_loss did not improve from 0.21364
# Epoch 171/1000
#  - 8s - loss: 0.3952 - accuracy: 0.8222 - val_loss: 0.1233 - val_accuracy: 0.5454
#
# Epoch 00171: val_loss improved from 0.21364 to 0.12332, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 172/1000
#  - 8s - loss: 0.3999 - accuracy: 0.8163 - val_loss: 1.7861 - val_accuracy: 0.5074
#
# Epoch 00172: val_loss did not improve from 0.12332
# Epoch 173/1000
#  - 8s - loss: 0.3874 - accuracy: 0.8257 - val_loss: 0.2895 - val_accuracy: 0.5442
#
# Epoch 00173: val_loss did not improve from 0.12332
# Epoch 174/1000
#  - 8s - loss: 0.3943 - accuracy: 0.8180 - val_loss: 0.6846 - val_accuracy: 0.5051
#
# Epoch 00174: val_loss did not improve from 0.12332
# Epoch 175/1000
#  - 8s - loss: 0.3898 - accuracy: 0.8290 - val_loss: 1.9289 - val_accuracy: 0.5346
#
# Epoch 00175: val_loss did not improve from 0.12332
# Epoch 176/1000
#  - 8s - loss: 0.3861 - accuracy: 0.8252 - val_loss: 1.5649 - val_accuracy: 0.5493
#
# Epoch 00176: val_loss did not improve from 0.12332
# Epoch 177/1000
#  - 8s - loss: 0.3819 - accuracy: 0.8314 - val_loss: 0.6063 - val_accuracy: 0.5193
#
# Epoch 00177: val_loss did not improve from 0.12332
# Epoch 178/1000
#  - 8s - loss: 0.3795 - accuracy: 0.8263 - val_loss: 0.5380 - val_accuracy: 0.5397
#
# Epoch 00178: val_loss did not improve from 0.12332
# Epoch 179/1000
#  - 8s - loss: 0.3819 - accuracy: 0.8307 - val_loss: 1.1757 - val_accuracy: 0.5147
#
# Epoch 00179: val_loss did not improve from 0.12332
# Epoch 180/1000
#  - 8s - loss: 0.3686 - accuracy: 0.8339 - val_loss: 1.5848 - val_accuracy: 0.5130
#
# Epoch 00180: val_loss did not improve from 0.12332
# Epoch 181/1000
#  - 8s - loss: 0.3754 - accuracy: 0.8305 - val_loss: 1.2397 - val_accuracy: 0.5278
#
# Epoch 00181: val_loss did not improve from 0.12332
# Epoch 182/1000
#  - 8s - loss: 0.3723 - accuracy: 0.8354 - val_loss: 1.2646 - val_accuracy: 0.5266
#
# Epoch 00182: val_loss did not improve from 0.12332
# Epoch 183/1000
#  - 8s - loss: 0.3615 - accuracy: 0.8411 - val_loss: 0.9878 - val_accuracy: 0.5215
#
# Epoch 00183: val_loss did not improve from 0.12332
# Epoch 184/1000
#  - 8s - loss: 0.3615 - accuracy: 0.8382 - val_loss: 1.0061 - val_accuracy: 0.5283
#
# Epoch 00184: val_loss did not improve from 0.12332
# Epoch 185/1000
#  - 8s - loss: 0.3710 - accuracy: 0.8346 - val_loss: 1.3044 - val_accuracy: 0.5431
#
# Epoch 00185: val_loss did not improve from 0.12332
# Epoch 186/1000
#  - 8s - loss: 0.3636 - accuracy: 0.8384 - val_loss: 1.8400 - val_accuracy: 0.5244
#
# Epoch 00186: val_loss did not improve from 0.12332
# Epoch 187/1000
#  - 8s - loss: 0.3554 - accuracy: 0.8471 - val_loss: 2.8687 - val_accuracy: 0.5278
#
# Epoch 00187: val_loss did not improve from 0.12332
# Epoch 188/1000
#  - 8s - loss: 0.3587 - accuracy: 0.8428 - val_loss: 1.5793 - val_accuracy: 0.5499
#
# Epoch 00188: val_loss did not improve from 0.12332
# Epoch 189/1000
#  - 8s - loss: 0.3568 - accuracy: 0.8441 - val_loss: 0.4285 - val_accuracy: 0.5402
#
# Epoch 00189: val_loss did not improve from 0.12332
# Epoch 190/1000
#  - 8s - loss: 0.3599 - accuracy: 0.8420 - val_loss: 1.9193 - val_accuracy: 0.5295
#
# Epoch 00190: val_loss did not improve from 0.12332
# Epoch 191/1000
#  - 8s - loss: 0.3581 - accuracy: 0.8420 - val_loss: 0.2901 - val_accuracy: 0.5170
#
# Epoch 00191: val_loss did not improve from 0.12332
# Epoch 192/1000
#  - 8s - loss: 0.3554 - accuracy: 0.8437 - val_loss: 1.6772 - val_accuracy: 0.5306
#
# Epoch 00192: val_loss did not improve from 0.12332
# Epoch 193/1000
#  - 8s - loss: 0.3568 - accuracy: 0.8443 - val_loss: 1.6076 - val_accuracy: 0.5096
#
# Epoch 00193: val_loss did not improve from 0.12332
# Epoch 194/1000
#  - 8s - loss: 0.3507 - accuracy: 0.8411 - val_loss: 0.5394 - val_accuracy: 0.5187
#
# Epoch 00194: val_loss did not improve from 0.12332
# Epoch 195/1000
#  - 8s - loss: 0.3467 - accuracy: 0.8479 - val_loss: 1.6819 - val_accuracy: 0.5499
#
# Epoch 00195: val_loss did not improve from 0.12332
# Epoch 196/1000
#  - 8s - loss: 0.3459 - accuracy: 0.8452 - val_loss: 0.6988 - val_accuracy: 0.5227
#
# Epoch 00196: val_loss did not improve from 0.12332
# Epoch 197/1000
#  - 8s - loss: 0.3359 - accuracy: 0.8547 - val_loss: 0.7702 - val_accuracy: 0.5300
#
# Epoch 00197: val_loss did not improve from 0.12332
# Epoch 198/1000
#  - 8s - loss: 0.3312 - accuracy: 0.8598 - val_loss: 1.0350 - val_accuracy: 0.5590
#
# Epoch 00198: val_loss did not improve from 0.12332
# Epoch 199/1000
#  - 8s - loss: 0.3367 - accuracy: 0.8560 - val_loss: 0.0251 - val_accuracy: 0.5533
#
# Epoch 00199: val_loss improved from 0.12332 to 0.02508, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 200/1000
#  - 8s - loss: 0.3325 - accuracy: 0.8645 - val_loss: 1.8027 - val_accuracy: 0.5437
#
# Epoch 00200: val_loss did not improve from 0.02508
# Epoch 201/1000
#  - 8s - loss: 0.3299 - accuracy: 0.8560 - val_loss: 2.1252 - val_accuracy: 0.5187
#
# Epoch 00201: val_loss did not improve from 0.02508
# Epoch 202/1000
#  - 8s - loss: 0.3374 - accuracy: 0.8516 - val_loss: 0.0988 - val_accuracy: 0.5703
#
# Epoch 00202: val_loss did not improve from 0.02508
# Epoch 203/1000
#  - 8s - loss: 0.3286 - accuracy: 0.8590 - val_loss: 0.1157 - val_accuracy: 0.5505
#
# Epoch 00203: val_loss did not improve from 0.02508
# Epoch 204/1000
#  - 8s - loss: 0.3263 - accuracy: 0.8607 - val_loss: 0.4159 - val_accuracy: 0.5442
#
# Epoch 00204: val_loss did not improve from 0.02508
# Epoch 205/1000
#  - 8s - loss: 0.3282 - accuracy: 0.8577 - val_loss: 1.4396 - val_accuracy: 0.5556
#
# Epoch 00205: val_loss did not improve from 0.02508
# Epoch 206/1000
#  - 8s - loss: 0.3324 - accuracy: 0.8560 - val_loss: 3.8364 - val_accuracy: 0.5448
#
# Epoch 00206: val_loss did not improve from 0.02508
# Epoch 207/1000
#  - 8s - loss: 0.3153 - accuracy: 0.8668 - val_loss: 0.8122 - val_accuracy: 0.5488
#
# Epoch 00207: val_loss did not improve from 0.02508
# Epoch 208/1000
#  - 8s - loss: 0.3204 - accuracy: 0.8601 - val_loss: 2.9096 - val_accuracy: 0.5204
#
# Epoch 00208: val_loss did not improve from 0.02508
# Epoch 209/1000
#  - 8s - loss: 0.3197 - accuracy: 0.8620 - val_loss: 2.3630 - val_accuracy: 0.5295
#
# Epoch 00209: val_loss did not improve from 0.02508
# Epoch 210/1000
#  - 8s - loss: 0.3113 - accuracy: 0.8686 - val_loss: 1.0424 - val_accuracy: 0.5527
#
# Epoch 00210: val_loss did not improve from 0.02508
# Epoch 211/1000
#  - 8s - loss: 0.3189 - accuracy: 0.8617 - val_loss: 0.7709 - val_accuracy: 0.5266
#
# Epoch 00211: val_loss did not improve from 0.02508
# Epoch 212/1000
#  - 8s - loss: 0.3096 - accuracy: 0.8666 - val_loss: 1.1933 - val_accuracy: 0.5414
#
# Epoch 00212: val_loss did not improve from 0.02508
# Epoch 213/1000
#  - 8s - loss: 0.3134 - accuracy: 0.8639 - val_loss: 3.0108 - val_accuracy: 0.5465
#
# Epoch 00213: val_loss did not improve from 0.02508
# Epoch 214/1000
#  - 8s - loss: 0.3061 - accuracy: 0.8696 - val_loss: 1.6620 - val_accuracy: 0.5266
#
# Epoch 00214: val_loss did not improve from 0.02508
# Epoch 215/1000
#  - 8s - loss: 0.2998 - accuracy: 0.8807 - val_loss: 2.4177 - val_accuracy: 0.5215
#
# Epoch 00215: val_loss did not improve from 0.02508
# Epoch 216/1000
#  - 8s - loss: 0.3050 - accuracy: 0.8711 - val_loss: 0.5428 - val_accuracy: 0.5079
#
# Epoch 00216: val_loss did not improve from 0.02508
# Epoch 217/1000
#  - 8s - loss: 0.3094 - accuracy: 0.8675 - val_loss: 1.5792 - val_accuracy: 0.5329
#
# Epoch 00217: val_loss did not improve from 0.02508
# Epoch 218/1000
#  - 8s - loss: 0.2946 - accuracy: 0.8821 - val_loss: 1.6556 - val_accuracy: 0.5323
#
# Epoch 00218: val_loss did not improve from 0.02508
# Epoch 219/1000
#  - 8s - loss: 0.3038 - accuracy: 0.8679 - val_loss: 2.1861 - val_accuracy: 0.5266
#
# Epoch 00219: val_loss did not improve from 0.02508
# Epoch 220/1000
#  - 8s - loss: 0.2976 - accuracy: 0.8745 - val_loss: 0.4405 - val_accuracy: 0.5261
#
# Epoch 00220: val_loss did not improve from 0.02508
# Epoch 221/1000
#  - 8s - loss: 0.3010 - accuracy: 0.8743 - val_loss: 1.0129 - val_accuracy: 0.5448
#
# Epoch 00221: val_loss did not improve from 0.02508
# Epoch 222/1000
#  - 8s - loss: 0.3049 - accuracy: 0.8696 - val_loss: 1.1870 - val_accuracy: 0.5346
#
# Epoch 00222: val_loss did not improve from 0.02508
# Epoch 223/1000
#  - 8s - loss: 0.2947 - accuracy: 0.8734 - val_loss: 1.0947 - val_accuracy: 0.5442
#
# Epoch 00223: val_loss did not improve from 0.02508
# Epoch 224/1000
#  - 8s - loss: 0.2931 - accuracy: 0.8747 - val_loss: 2.1972 - val_accuracy: 0.5215
#
# Epoch 00224: val_loss did not improve from 0.02508
# Epoch 225/1000
#  - 8s - loss: 0.2914 - accuracy: 0.8794 - val_loss: 1.1442 - val_accuracy: 0.5221
#
# Epoch 00225: val_loss did not improve from 0.02508
# Epoch 226/1000
#  - 8s - loss: 0.2875 - accuracy: 0.8777 - val_loss: 1.1285 - val_accuracy: 0.5385
#
# Epoch 00226: val_loss did not improve from 0.02508
# Epoch 227/1000
#  - 8s - loss: 0.2836 - accuracy: 0.8824 - val_loss: 0.2062 - val_accuracy: 0.5488
#
# Epoch 00227: val_loss did not improve from 0.02508
# Epoch 228/1000
#  - 8s - loss: 0.2826 - accuracy: 0.8836 - val_loss: 1.2360 - val_accuracy: 0.5465
#
# Epoch 00228: val_loss did not improve from 0.02508
# Epoch 229/1000
#  - 8s - loss: 0.2854 - accuracy: 0.8753 - val_loss: 1.4770 - val_accuracy: 0.5578
#
# Epoch 00229: val_loss did not improve from 0.02508
# Epoch 230/1000
#  - 8s - loss: 0.2827 - accuracy: 0.8813 - val_loss: 4.7272 - val_accuracy: 0.5476
#
# Epoch 00230: val_loss did not improve from 0.02508
# Epoch 231/1000
#  - 8s - loss: 0.2772 - accuracy: 0.8857 - val_loss: 2.0932 - val_accuracy: 0.5374
#
# Epoch 00231: val_loss did not improve from 0.02508
# Epoch 232/1000
#  - 8s - loss: 0.2778 - accuracy: 0.8860 - val_loss: 2.1894 - val_accuracy: 0.5391
#
# Epoch 00232: val_loss did not improve from 0.02508
# Epoch 233/1000
#  - 8s - loss: 0.2802 - accuracy: 0.8889 - val_loss: 1.3263 - val_accuracy: 0.5505
#
# Epoch 00233: val_loss did not improve from 0.02508
# Epoch 234/1000
#  - 8s - loss: 0.2728 - accuracy: 0.8892 - val_loss: 1.2613 - val_accuracy: 0.5476
#
# Epoch 00234: val_loss did not improve from 0.02508
# Epoch 235/1000
#  - 8s - loss: 0.2768 - accuracy: 0.8862 - val_loss: 3.7363 - val_accuracy: 0.5300
#
# Epoch 00235: val_loss did not improve from 0.02508
# Epoch 236/1000
#  - 8s - loss: 0.2814 - accuracy: 0.8843 - val_loss: 3.2220 - val_accuracy: 0.5431
#
# Epoch 00236: val_loss did not improve from 0.02508
# Epoch 237/1000
#  - 8s - loss: 0.2687 - accuracy: 0.8898 - val_loss: 1.4917 - val_accuracy: 0.5408
#
# Epoch 00237: val_loss did not improve from 0.02508
# Epoch 238/1000
#  - 8s - loss: 0.2664 - accuracy: 0.8934 - val_loss: 1.6782 - val_accuracy: 0.5454
#
# Epoch 00238: val_loss did not improve from 0.02508
# Epoch 239/1000
#  - 8s - loss: 0.2680 - accuracy: 0.8913 - val_loss: 0.1488 - val_accuracy: 0.5351
#
# Epoch 00239: val_loss did not improve from 0.02508
# Epoch 240/1000
#  - 8s - loss: 0.2670 - accuracy: 0.8906 - val_loss: 4.1582 - val_accuracy: 0.5380
#
# Epoch 00240: val_loss did not improve from 0.02508
# Epoch 241/1000
#  - 8s - loss: 0.2600 - accuracy: 0.8940 - val_loss: 1.2113 - val_accuracy: 0.5476
#
# Epoch 00241: val_loss did not improve from 0.02508
# Epoch 242/1000
#  - 8s - loss: 0.2638 - accuracy: 0.8938 - val_loss: 1.5574 - val_accuracy: 0.5544
#
# Epoch 00242: val_loss did not improve from 0.02508
# Epoch 243/1000
#  - 8s - loss: 0.2527 - accuracy: 0.8953 - val_loss: 1.3270 - val_accuracy: 0.5561
#
# Epoch 00243: val_loss did not improve from 0.02508
# Epoch 244/1000
#  - 8s - loss: 0.2568 - accuracy: 0.8964 - val_loss: 0.8118 - val_accuracy: 0.5601
#
# Epoch 00244: val_loss did not improve from 0.02508
# Epoch 245/1000
#  - 8s - loss: 0.2462 - accuracy: 0.9085 - val_loss: 2.1715 - val_accuracy: 0.5635
#
# Epoch 00245: val_loss did not improve from 0.02508
# Epoch 246/1000
#  - 8s - loss: 0.2547 - accuracy: 0.9000 - val_loss: 0.9224 - val_accuracy: 0.5533
#
# Epoch 00246: val_loss did not improve from 0.02508
# Epoch 247/1000
#  - 8s - loss: 0.2530 - accuracy: 0.8945 - val_loss: 3.8406 - val_accuracy: 0.5578
#
# Epoch 00247: val_loss did not improve from 0.02508
# Epoch 248/1000
#  - 8s - loss: 0.2608 - accuracy: 0.8919 - val_loss: 1.2539 - val_accuracy: 0.5164
#
# Epoch 00248: val_loss did not improve from 0.02508
# Epoch 249/1000
#  - 8s - loss: 0.2537 - accuracy: 0.8985 - val_loss: 0.7837 - val_accuracy: 0.5624
#
# Epoch 00249: val_loss did not improve from 0.02508
# Epoch 250/1000
#  - 8s - loss: 0.2495 - accuracy: 0.8974 - val_loss: 4.0227 - val_accuracy: 0.5488
#
# Epoch 00250: val_loss did not improve from 0.02508
# Epoch 251/1000
#  - 8s - loss: 0.2396 - accuracy: 0.9025 - val_loss: 0.4833 - val_accuracy: 0.5414
#
# Epoch 00251: val_loss did not improve from 0.02508
# Epoch 252/1000
#  - 8s - loss: 0.2436 - accuracy: 0.8991 - val_loss: 0.3725 - val_accuracy: 0.5351
#
# Epoch 00252: val_loss did not improve from 0.02508
# Epoch 253/1000
#  - 8s - loss: 0.2363 - accuracy: 0.9070 - val_loss: 1.3386 - val_accuracy: 0.5437
#
# Epoch 00253: val_loss did not improve from 0.02508
# Epoch 254/1000
#  - 8s - loss: 0.2486 - accuracy: 0.8987 - val_loss: 1.8416 - val_accuracy: 0.5454
#
# Epoch 00254: val_loss did not improve from 0.02508
# Epoch 255/1000
#  - 8s - loss: 0.2460 - accuracy: 0.9008 - val_loss: 1.7862 - val_accuracy: 0.5306
#
# Epoch 00255: val_loss did not improve from 0.02508
# Epoch 256/1000
#  - 8s - loss: 0.2373 - accuracy: 0.9066 - val_loss: 0.3841 - val_accuracy: 0.5522
#
# Epoch 00256: val_loss did not improve from 0.02508
# Epoch 257/1000
#  - 8s - loss: 0.2405 - accuracy: 0.9038 - val_loss: 0.7046 - val_accuracy: 0.5499
#
# Epoch 00257: val_loss did not improve from 0.02508
# Epoch 258/1000
#  - 8s - loss: 0.2323 - accuracy: 0.9142 - val_loss: 0.3215 - val_accuracy: 0.5385
#
# Epoch 00258: val_loss did not improve from 0.02508
# Epoch 259/1000
#  - 8s - loss: 0.2316 - accuracy: 0.9110 - val_loss: 0.9835 - val_accuracy: 0.5567
#
# Epoch 00259: val_loss did not improve from 0.02508
# Epoch 260/1000
#  - 8s - loss: 0.2382 - accuracy: 0.9072 - val_loss: 1.2497 - val_accuracy: 0.5493
#
# Epoch 00260: val_loss did not improve from 0.02508
# Epoch 261/1000
#  - 8s - loss: 0.2328 - accuracy: 0.9091 - val_loss: 1.6237 - val_accuracy: 0.5346
#
# Epoch 00261: val_loss did not improve from 0.02508
# Epoch 262/1000
#  - 8s - loss: 0.2329 - accuracy: 0.9063 - val_loss: 2.6222 - val_accuracy: 0.5533
#
# Epoch 00262: val_loss did not improve from 0.02508
# Epoch 263/1000
#  - 8s - loss: 0.2337 - accuracy: 0.9057 - val_loss: 0.9470 - val_accuracy: 0.5595
#
# Epoch 00263: val_loss did not improve from 0.02508
# Epoch 264/1000
#  - 8s - loss: 0.2276 - accuracy: 0.9117 - val_loss: 0.2215 - val_accuracy: 0.5488
#
# Epoch 00264: val_loss did not improve from 0.02508
# Epoch 265/1000
#  - 8s - loss: 0.2259 - accuracy: 0.9125 - val_loss: 1.6383 - val_accuracy: 0.5567
#
# Epoch 00265: val_loss did not improve from 0.02508
# Epoch 266/1000
#  - 8s - loss: 0.2196 - accuracy: 0.9125 - val_loss: 1.1762 - val_accuracy: 0.5493
#
# Epoch 00266: val_loss did not improve from 0.02508
# Epoch 267/1000
#  - 8s - loss: 0.2241 - accuracy: 0.9129 - val_loss: 1.5872 - val_accuracy: 0.5346
#
# Epoch 00267: val_loss did not improve from 0.02508
# Epoch 268/1000
#  - 8s - loss: 0.2317 - accuracy: 0.9036 - val_loss: 1.3374 - val_accuracy: 0.5544
#
# Epoch 00268: val_loss did not improve from 0.02508
# Epoch 269/1000
#  - 8s - loss: 0.2208 - accuracy: 0.9161 - val_loss: 0.5399 - val_accuracy: 0.5425
#
# Epoch 00269: val_loss did not improve from 0.02508
# Epoch 270/1000
#  - 8s - loss: 0.2147 - accuracy: 0.9144 - val_loss: 1.5120 - val_accuracy: 0.5448
#
# Epoch 00270: val_loss did not improve from 0.02508
# Epoch 271/1000
#  - 8s - loss: 0.2295 - accuracy: 0.9074 - val_loss: 1.6295 - val_accuracy: 0.5374
#
# Epoch 00271: val_loss did not improve from 0.02508
# Epoch 272/1000
#  - 8s - loss: 0.2075 - accuracy: 0.9242 - val_loss: 1.2302 - val_accuracy: 0.5505
#
# Epoch 00272: val_loss did not improve from 0.02508
# Epoch 273/1000
#  - 8s - loss: 0.2119 - accuracy: 0.9191 - val_loss: 0.5010 - val_accuracy: 0.5420
#
# Epoch 00273: val_loss did not improve from 0.02508
# Epoch 274/1000
#  - 8s - loss: 0.2137 - accuracy: 0.9208 - val_loss: 0.8194 - val_accuracy: 0.5346
#
# Epoch 00274: val_loss did not improve from 0.02508
# Epoch 275/1000
#  - 8s - loss: 0.2080 - accuracy: 0.9191 - val_loss: 2.5268 - val_accuracy: 0.5516
#
# Epoch 00275: val_loss did not improve from 0.02508
# Epoch 276/1000
#  - 8s - loss: 0.2071 - accuracy: 0.9212 - val_loss: 1.3660 - val_accuracy: 0.5629
#
# Epoch 00276: val_loss did not improve from 0.02508
# Epoch 277/1000
#  - 8s - loss: 0.2147 - accuracy: 0.9149 - val_loss: 4.8504 - val_accuracy: 0.5499
#
# Epoch 00277: val_loss did not improve from 0.02508
# Epoch 278/1000
#  - 8s - loss: 0.2093 - accuracy: 0.9167 - val_loss: 1.1135 - val_accuracy: 0.5658
#
# Epoch 00278: val_loss did not improve from 0.02508
# Epoch 279/1000
#  - 8s - loss: 0.2096 - accuracy: 0.9163 - val_loss: 2.9266 - val_accuracy: 0.5368
#
# Epoch 00279: val_loss did not improve from 0.02508
# Epoch 280/1000
#  - 8s - loss: 0.2073 - accuracy: 0.9174 - val_loss: 1.0035 - val_accuracy: 0.5601
#
# Epoch 00280: val_loss did not improve from 0.02508
# Epoch 281/1000
#  - 8s - loss: 0.1987 - accuracy: 0.9274 - val_loss: 0.5205 - val_accuracy: 0.5578
#
# Epoch 00281: val_loss did not improve from 0.02508
# Epoch 282/1000
#  - 8s - loss: 0.2050 - accuracy: 0.9227 - val_loss: 1.2997 - val_accuracy: 0.5544
#
# Epoch 00282: val_loss did not improve from 0.02508
# Epoch 283/1000
#  - 8s - loss: 0.1978 - accuracy: 0.9253 - val_loss: 5.4765 - val_accuracy: 0.5402
#
# Epoch 00283: val_loss did not improve from 0.02508
# Epoch 284/1000
#  - 8s - loss: 0.1960 - accuracy: 0.9263 - val_loss: 1.6878 - val_accuracy: 0.5385
#
# Epoch 00284: val_loss did not improve from 0.02508
# Epoch 285/1000
#  - 8s - loss: 0.2039 - accuracy: 0.9233 - val_loss: 0.7227 - val_accuracy: 0.5425
#
# Epoch 00285: val_loss did not improve from 0.02508
# Epoch 286/1000
#  - 8s - loss: 0.2000 - accuracy: 0.9248 - val_loss: 0.4083 - val_accuracy: 0.5334
#
# Epoch 00286: val_loss did not improve from 0.02508
# Epoch 287/1000
#  - 8s - loss: 0.1981 - accuracy: 0.9276 - val_loss: 0.7364 - val_accuracy: 0.5471
#
# Epoch 00287: val_loss did not improve from 0.02508
# Epoch 288/1000
#  - 8s - loss: 0.1880 - accuracy: 0.9293 - val_loss: 2.2471 - val_accuracy: 0.5505
#
# Epoch 00288: val_loss did not improve from 0.02508
# Epoch 289/1000
#  - 8s - loss: 0.1891 - accuracy: 0.9301 - val_loss: 1.6263 - val_accuracy: 0.5380
#
# Epoch 00289: val_loss did not improve from 0.02508
# Epoch 290/1000
#  - 8s - loss: 0.1939 - accuracy: 0.9274 - val_loss: 1.4563 - val_accuracy: 0.5573
#
# Epoch 00290: val_loss did not improve from 0.02508
# Epoch 291/1000
#  - 8s - loss: 0.1920 - accuracy: 0.9216 - val_loss: 1.3282 - val_accuracy: 0.5686
#
# Epoch 00291: val_loss did not improve from 0.02508
# Epoch 292/1000
#  - 8s - loss: 0.1895 - accuracy: 0.9291 - val_loss: 2.2494 - val_accuracy: 0.5505
#
# Epoch 00292: val_loss did not improve from 0.02508
# Epoch 293/1000
#  - 8s - loss: 0.1905 - accuracy: 0.9270 - val_loss: 0.8259 - val_accuracy: 0.5420
#
# Epoch 00293: val_loss did not improve from 0.02508
# Epoch 294/1000
#  - 8s - loss: 0.1846 - accuracy: 0.9346 - val_loss: 2.7409 - val_accuracy: 0.5465
#
# Epoch 00294: val_loss did not improve from 0.02508
# Epoch 295/1000
#  - 8s - loss: 0.1845 - accuracy: 0.9306 - val_loss: 0.9333 - val_accuracy: 0.5340
#
# Epoch 00295: val_loss did not improve from 0.02508
# Epoch 296/1000
#  - 8s - loss: 0.1894 - accuracy: 0.9263 - val_loss: 3.0676 - val_accuracy: 0.5442
#
# Epoch 00296: val_loss did not improve from 0.02508
# Epoch 297/1000
#  - 8s - loss: 0.1831 - accuracy: 0.9346 - val_loss: 1.0986 - val_accuracy: 0.5550
#
# Epoch 00297: val_loss did not improve from 0.02508
# Epoch 298/1000
#  - 8s - loss: 0.1753 - accuracy: 0.9335 - val_loss: 0.7400 - val_accuracy: 0.5714
#
# Epoch 00298: val_loss did not improve from 0.02508
# Epoch 299/1000
#  - 8s - loss: 0.1844 - accuracy: 0.9263 - val_loss: 1.3008 - val_accuracy: 0.5420
#
# Epoch 00299: val_loss did not improve from 0.02508
# Epoch 300/1000
#  - 8s - loss: 0.1762 - accuracy: 0.9357 - val_loss: 2.1052 - val_accuracy: 0.5465
#
# Epoch 00300: val_loss did not improve from 0.02508
# Epoch 301/1000
#  - 8s - loss: 0.1833 - accuracy: 0.9301 - val_loss: 2.6420 - val_accuracy: 0.5527
#
# Epoch 00301: val_loss did not improve from 0.02508
# Epoch 302/1000
#  - 8s - loss: 0.1814 - accuracy: 0.9318 - val_loss: 1.0850 - val_accuracy: 0.5402
#
# Epoch 00302: val_loss did not improve from 0.02508
# Epoch 303/1000
# ...
#
# Epoch 00314: val_loss did not improve from 0.02508
# Epoch 315/1000
#  - 8s - loss: 0.1705 - accuracy: 0.9346 - val_loss: 0.0737 - val_accuracy: 0.5380
#
# Epoch 00315: val_loss did not improve from 0.02508
# Epoch 316/1000
#  - 8s - loss: 0.1630 - accuracy: 0.9403 - val_loss: 1.4452 - val_accuracy: 0.5510
#
# Epoch 00316: val_loss did not improve from 0.02508
# Epoch 317/1000
#  - 8s - loss: 0.1677 - accuracy: 0.9352 - val_loss: 3.8418 - val_accuracy: 0.5340
#
# Epoch 00317: val_loss did not improve from 0.02508
# Epoch 318/1000
#  - 8s - loss: 0.1635 - accuracy: 0.9373 - val_loss: 0.6102 - val_accuracy: 0.5431
#
# Epoch 00318: val_loss did not improve from 0.02508
# Epoch 319/1000
#  - 8s - loss: 0.1511 - accuracy: 0.9484 - val_loss: 1.7024 - val_accuracy: 0.5437
#
# Epoch 00319: val_loss did not improve from 0.02508
# Epoch 320/1000
#  - 8s - loss: 0.1544 - accuracy: 0.9452 - val_loss: 0.8313 - val_accuracy: 0.5516
#
# Epoch 00320: val_loss did not improve from 0.02508
# Epoch 321/1000
#  - 8s - loss: 0.1628 - accuracy: 0.9373 - val_loss: 2.6552 - val_accuracy: 0.5306
#
# Epoch 00321: val_loss did not improve from 0.02508
# Epoch 322/1000
#  - 8s - loss: 0.1591 - accuracy: 0.9435 - val_loss: 1.0159 - val_accuracy: 0.5459
#
# Epoch 00322: val_loss did not improve from 0.02508
# Epoch 323/1000
#  - 8s - loss: 0.1557 - accuracy: 0.9418 - val_loss: 0.8941 - val_accuracy: 0.5533
#
# Epoch 00323: val_loss did not improve from 0.02508
# Epoch 324/1000
#  - 8s - loss: 0.1669 - accuracy: 0.9416 - val_loss: 0.8817 - val_accuracy: 0.5397
#
# Epoch 00324: val_loss did not improve from 0.02508
# Epoch 325/1000
#  - 8s - loss: 0.1612 - accuracy: 0.9439 - val_loss: 0.2220 - val_accuracy: 0.5431
#
# Epoch 00325: val_loss did not improve from 0.02508
# Epoch 326/1000
#  - 8s - loss: 0.1528 - accuracy: 0.9424 - val_loss: 2.3162 - val_accuracy: 0.5323
#
# Epoch 00326: val_loss did not improve from 0.02508
# Epoch 327/1000
#  - 8s - loss: 0.1559 - accuracy: 0.9437 - val_loss: 0.4416 - val_accuracy: 0.5300
#
# Epoch 00327: val_loss did not improve from 0.02508
# Epoch 328/1000
#  - 8s - loss: 0.1566 - accuracy: 0.9407 - val_loss: 1.0521 - val_accuracy: 0.5261
#
# Epoch 00328: val_loss did not improve from 0.02508
# Epoch 329/1000
#  - 8s - loss: 0.1461 - accuracy: 0.9442 - val_loss: 1.7701 - val_accuracy: 0.5249
#
# Epoch 00329: val_loss did not improve from 0.02508
# Epoch 330/1000
#  - 8s - loss: 0.1498 - accuracy: 0.9486 - val_loss: 1.5542 - val_accuracy: 0.5374
#
# Epoch 00330: val_loss did not improve from 0.02508
# Epoch 331/1000
#  - 8s - loss: 0.1533 - accuracy: 0.9437 - val_loss: 0.5760 - val_accuracy: 0.5227
#
# Epoch 00331: val_loss did not improve from 0.02508
# Epoch 332/1000
#  - 8s - loss: 0.1431 - accuracy: 0.9497 - val_loss: 4.5756 - val_accuracy: 0.5414
#
# Epoch 00332: val_loss did not improve from 0.02508
# Epoch 333/1000
#  - 8s - loss: 0.1452 - accuracy: 0.9533 - val_loss: 2.6333 - val_accuracy: 0.5391
#
# Epoch 00333: val_loss did not improve from 0.02508
# Epoch 334/1000
#  - 8s - loss: 0.1434 - accuracy: 0.9497 - val_loss: 0.1446 - val_accuracy: 0.5567
#
# Epoch 00334: val_loss did not improve from 0.02508
# Epoch 335/1000
#  - 8s - loss: 0.1513 - accuracy: 0.9456 - val_loss: 0.4887 - val_accuracy: 0.5493
#
# Epoch 00335: val_loss did not improve from 0.02508
# Epoch 336/1000
#  - 8s - loss: 0.1399 - accuracy: 0.9507 - val_loss: 3.4159 - val_accuracy: 0.5329
#
# Epoch 00336: val_loss did not improve from 0.02508
# Epoch 337/1000
#  - 8s - loss: 0.1347 - accuracy: 0.9556 - val_loss: 0.8129 - val_accuracy: 0.5431
#
# Epoch 00337: val_loss did not improve from 0.02508
# Epoch 338/1000
#  - 8s - loss: 0.1422 - accuracy: 0.9505 - val_loss: 4.6017 - val_accuracy: 0.5312
#
# Epoch 00338: val_loss did not improve from 0.02508
# Epoch 339/1000
#  - 8s - loss: 0.1417 - accuracy: 0.9458 - val_loss: 2.9807 - val_accuracy: 0.5215
#
# Epoch 00339: val_loss did not improve from 0.02508
# Epoch 340/1000
#  - 8s - loss: 0.1448 - accuracy: 0.9476 - val_loss: 4.8915 - val_accuracy: 0.5368
#
# Epoch 00340: val_loss did not improve from 0.02508
# Epoch 341/1000
#  - 8s - loss: 0.1388 - accuracy: 0.9527 - val_loss: 0.1443 - val_accuracy: 0.5380
#
# Epoch 00341: val_loss did not improve from 0.02508
# Epoch 342/1000
#  - 8s - loss: 0.1437 - accuracy: 0.9488 - val_loss: 1.6593 - val_accuracy: 0.5374
#
# Epoch 00342: val_loss did not improve from 0.02508
# Epoch 343/1000
#  - 8s - loss: 0.1363 - accuracy: 0.9510 - val_loss: 3.4432 - val_accuracy: 0.5329
#
# Epoch 00343: val_loss did not improve from 0.02508
# Epoch 344/1000
#  - 8s - loss: 0.1389 - accuracy: 0.9527 - val_loss: 1.6425 - val_accuracy: 0.5306
#
# Epoch 00344: val_loss did not improve from 0.02508
# Epoch 345/1000
#  - 8s - loss: 0.1400 - accuracy: 0.9484 - val_loss: 2.6497 - val_accuracy: 0.5340
#
# Epoch 00345: val_loss did not improve from 0.02508
# Epoch 346/1000
#  - 8s - loss: 0.1432 - accuracy: 0.9475 - val_loss: 0.6938 - val_accuracy: 0.5351
#
# Epoch 00346: val_loss did not improve from 0.02508
# Epoch 347/1000
#  - 8s - loss: 0.1294 - accuracy: 0.9548 - val_loss: 4.1900 - val_accuracy: 0.5493
#
# Epoch 00347: val_loss did not improve from 0.02508
# Epoch 348/1000
#  - 8s - loss: 0.1319 - accuracy: 0.9516 - val_loss: 1.7335 - val_accuracy: 0.5431
#
# Epoch 00348: val_loss did not improve from 0.02508
# Epoch 349/1000
#  - 8s - loss: 0.1279 - accuracy: 0.9556 - val_loss: 4.3196 - val_accuracy: 0.5374
#
# Epoch 00349: val_loss did not improve from 0.02508
# Epoch 350/1000
#  - 8s - loss: 0.1225 - accuracy: 0.9563 - val_loss: 1.4692 - val_accuracy: 0.5459
#
# Epoch 00350: val_loss did not improve from 0.02508
# Epoch 351/1000
#  - 8s - loss: 0.1255 - accuracy: 0.9546 - val_loss: 1.9537 - val_accuracy: 0.5584
#
# Epoch 00351: val_loss did not improve from 0.02508
# Epoch 352/1000
#  - 8s - loss: 0.1285 - accuracy: 0.9554 - val_loss: 0.4511 - val_accuracy: 0.5431
#
# Epoch 00352: val_loss did not improve from 0.02508
# Epoch 353/1000
#  - 8s - loss: 0.1261 - accuracy: 0.9558 - val_loss: 0.8755 - val_accuracy: 0.5607
#
# Epoch 00353: val_loss did not improve from 0.02508
# Epoch 354/1000
#  - 8s - loss: 0.1281 - accuracy: 0.9569 - val_loss: 3.7726 - val_accuracy: 0.5522
#
# Epoch 00354: val_loss did not improve from 0.02508
# Epoch 355/1000
#  - 8s - loss: 0.1294 - accuracy: 0.9537 - val_loss: 0.8964 - val_accuracy: 0.5437
#
# Epoch 00355: val_loss did not improve from 0.02508
# Epoch 356/1000
#  - 8s - loss: 0.1255 - accuracy: 0.9590 - val_loss: 1.9615 - val_accuracy: 0.5510
#
# Epoch 00356: val_loss did not improve from 0.02508
# Epoch 357/1000
#  - 8s - loss: 0.1302 - accuracy: 0.9537 - val_loss: 4.3707 - val_accuracy: 0.5323
#
# Epoch 00357: val_loss did not improve from 0.02508
# Epoch 358/1000
#  - 8s - loss: 0.1313 - accuracy: 0.9539 - val_loss: 1.9542 - val_accuracy: 0.5516
#
# Epoch 00358: val_loss did not improve from 0.02508
# Epoch 359/1000
#  - 8s - loss: 0.1285 - accuracy: 0.9560 - val_loss: 0.0110 - val_accuracy: 0.5607
#
# Epoch 00359: val_loss improved from 0.02508 to 0.01098, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_val_shuffle_ma7_indi.h5
# Epoch 360/1000
#  - 8s - loss: 0.1278 - accuracy: 0.9563 - val_loss: 3.8614 - val_accuracy: 0.5340
#
# Epoch 00360: val_loss did not improve from 0.01098
# Epoch 361/1000
#  - 8s - loss: 0.1199 - accuracy: 0.9552 - val_loss: 1.8101 - val_accuracy: 0.5505
#
# Epoch 00361: val_loss did not improve from 0.01098
# Epoch 362/1000
#  - 8s - loss: 0.1246 - accuracy: 0.9550 - val_loss: 0.7054 - val_accuracy: 0.5482
#
# Epoch 00362: val_loss did not improve from 0.01098
# Epoch 363/1000
#  - 8s - loss: 0.1141 - accuracy: 0.9626 - val_loss: 0.8010 - val_accuracy: 0.5505
#
# Epoch 00363: val_loss did not improve from 0.01098
# Epoch 364/1000
#  - 8s - loss: 0.1210 - accuracy: 0.9571 - val_loss: 0.4476 - val_accuracy: 0.5505
#
# Epoch 00364: val_loss did not improve from 0.01098
# Epoch 365/1000
#  - 8s - loss: 0.1226 - accuracy: 0.9577 - val_loss: 2.8813 - val_accuracy: 0.5374
#
# Epoch 00365: val_loss did not improve from 0.01098
# Epoch 366/1000
#  - 8s - loss: 0.1165 - accuracy: 0.9571 - val_loss: 2.1764 - val_accuracy: 0.5238
#
# Epoch 00366: val_loss did not improve from 0.01098
# Epoch 367/1000
#  - 8s - loss: 0.1180 - accuracy: 0.9652 - val_loss: 1.3124 - val_accuracy: 0.5397
#
# Epoch 00367: val_loss did not improve from 0.01098
# Epoch 368/1000
#  - 8s - loss: 0.1066 - accuracy: 0.9641 - val_loss: 2.1198 - val_accuracy: 0.5210
#
# Epoch 00368: val_loss did not improve from 0.01098
# Epoch 369/1000
#  - 8s - loss: 0.1113 - accuracy: 0.9616 - val_loss: 0.7489 - val_accuracy: 0.5522
#
# Epoch 00369: val_loss did not improve from 0.01098
# Epoch 370/1000
#  - 8s - loss: 0.1163 - accuracy: 0.9609 - val_loss: 2.5767 - val_accuracy: 0.5448
#
# Epoch 00370: val_loss did not improve from 0.01098
# Epoch 371/1000
#  - 8s - loss: 0.1134 - accuracy: 0.9630 - val_loss: 1.6858 - val_accuracy: 0.5374
#
# Epoch 00371: val_loss did not improve from 0.01098
# Epoch 372/1000
#  - 8s - loss: 0.1112 - accuracy: 0.9603 - val_loss: 1.7620 - val_accuracy: 0.5289
#
# Epoch 00372: val_loss did not improve from 0.01098
# Epoch 373/1000
#  - 8s - loss: 0.1127 - accuracy: 0.9620 - val_loss: 4.7481 - val_accuracy: 0.5363
#
# Epoch 00373: val_loss did not improve from 0.01098
# Epoch 374/1000
#  - 8s - loss: 0.1149 - accuracy: 0.9618 - val_loss: 3.0486 - val_accuracy: 0.5420
#
# Epoch 00374: val_loss did not improve from 0.01098
# Epoch 375/1000
#  - 8s - loss: 0.1163 - accuracy: 0.9616 - val_loss: 2.3790 - val_accuracy: 0.5459
#
# Epoch 00375: val_loss did not improve from 0.01098
# Epoch 376/1000
#  - 8s - loss: 0.1147 - accuracy: 0.9597 - val_loss: 3.3638 - val_accuracy: 0.5368
#
# Epoch 00376: val_loss did not improve from 0.01098
# Epoch 377/1000
#  - 8s - loss: 0.1172 - accuracy: 0.9567 - val_loss: 3.6188 - val_accuracy: 0.5391
#
# Epoch 00377: val_loss did not improve from 0.01098
# Epoch 378/1000
#  - 8s - loss: 0.1112 - accuracy: 0.9628 - val_loss: 0.7791 - val_accuracy: 0.5278
#
# Epoch 00378: val_loss did not improve from 0.01098
# Epoch 379/1000
#  - 8s - loss: 0.1076 - accuracy: 0.9616 - val_loss: 0.5030 - val_accuracy: 0.5408
#
# Epoch 00379: val_loss did not improve from 0.01098
# Epoch 380/1000
#  - 8s - loss: 0.1042 - accuracy: 0.9652 - val_loss: 3.1015 - val_accuracy: 0.5465
#
# Epoch 00380: val_loss did not improve from 0.01098
# Epoch 381/1000
#  - 8s - loss: 0.1086 - accuracy: 0.9631 - val_loss: 0.6121 - val_accuracy: 0.5397
#
# Epoch 00381: val_loss did not improve from 0.01098
# Epoch 382/1000
#  - 8s - loss: 0.1007 - accuracy: 0.9669 - val_loss: 0.6073 - val_accuracy: 0.5385
#
# Epoch 00382: val_loss did not improve from 0.01098
# Epoch 383/1000
#  - 8s - loss: 0.1120 - accuracy: 0.9592 - val_loss: 0.7554 - val_accuracy: 0.5380
#
# Epoch 00383: val_loss did not improve from 0.01098
# Epoch 384/1000
#  - 8s - loss: 0.1104 - accuracy: 0.9626 - val_loss: 0.0327 - val_accuracy: 0.5215
#
# Epoch 00384: val_loss did not improve from 0.01098
# Epoch 385/1000
#  - 8s - loss: 0.1016 - accuracy: 0.9645 - val_loss: 1.1852 - val_accuracy: 0.5368
#
# Epoch 00385: val_loss did not improve from 0.01098
# Epoch 386/1000
#  - 8s - loss: 0.1158 - accuracy: 0.9582 - val_loss: 0.5284 - val_accuracy: 0.5397
#
# Epoch 00386: val_loss did not improve from 0.01098
# Epoch 387/1000
#  - 8s - loss: 0.1098 - accuracy: 0.9641 - val_loss: 3.2306 - val_accuracy: 0.5312
#
# Epoch 00387: val_loss did not improve from 0.01098
# Epoch 388/1000
#  - 8s - loss: 0.1035 - accuracy: 0.9662 - val_loss: 1.1731 - val_accuracy: 0.5329
#
# Epoch 00388: val_loss did not improve from 0.01098
# Epoch 389/1000
#  - 8s - loss: 0.1012 - accuracy: 0.9684 - val_loss: 2.6870 - val_accuracy: 0.5391
#
# Epoch 00389: val_loss did not improve from 0.01098
# Epoch 390/1000
#  - 8s - loss: 0.1024 - accuracy: 0.9686 - val_loss: 2.9029 - val_accuracy: 0.5312
#
# Epoch 00390: val_loss did not improve from 0.01098
# Epoch 391/1000
#  - 8s - loss: 0.0968 - accuracy: 0.9688 - val_loss: 2.8073 - val_accuracy: 0.5300
#
# Epoch 00391: val_loss did not improve from 0.01098
# Epoch 392/1000
#  - 8s - loss: 0.1000 - accuracy: 0.9673 - val_loss: 6.1364 - val_accuracy: 0.5431
#
# Epoch 00392: val_loss did not improve from 0.01098
# Epoch 393/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-e8b7398c65d1> in <module>()
#      34                     validation_data=val_flow,
#      35                     validation_steps=len(x_val) / batch_size,
# ---> 36                     shuffle=False)
#
# /tensorflow-1.15.2/python3.7/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /tensorflow-1.15.2/python3.7/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /tensorflow-1.15.2/python3.7/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     240                             validation_steps,
#     241                             callbacks=callbacks,
# --> 242                             workers=0)
#     243                     else:
#     244                         # No need for try/except because
#
# /tensorflow-1.15.2/python3.7/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /tensorflow-1.15.2/python3.7/keras/engine/training.py in evaluate_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    1789             workers=workers,
#    1790             use_multiprocessing=use_multiprocessing,
# -> 1791             verbose=verbose)
#    1792
#    1793     @interfaces.legacy_generator_methods_support
#
# /tensorflow-1.15.2/python3.7/keras/engine/training_generator.py in evaluate_generator(model, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#     399             outs = model.test_on_batch(x, y,
#     400                                        sample_weight=sample_weight,
# --> 401                                        reset_metrics=False)
#     402             outs = to_list(outs)
#     403             outs_per_batch.append(outs)
#
# /tensorflow-1.15.2/python3.7/keras/engine/training.py in test_on_batch(self, x, y, sample_weight, reset_metrics)
#    1557             ins = x + y + sample_weights
#    1558         self._make_test_function()
# -> 1559         outputs = self.test_function(ins)
#    1560
#    1561         if reset_metrics:
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
# model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_ex_02008.h5'
# model_name = 'classifier_45_close_updown_pr_theta.h5'

model = keras.models.load_model(ckpt_path + model_name)

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


threshold = [0.9]
# print('threshold :', threshold)
# break

new_thresh = []
acc_pr_bythr = []
for thresh in threshold:

  if thresh < 0.7:
    continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  print('precision :', precision_score(y_test, y_pred))
  print('recall :', recall_score(y_test, y_pred))
  print()

  print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # plt.show()  
  print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
    print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
    print('thresh :', thresh)
    
  # if len(threshold) == 1:
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(test_pr_list))
    plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
  # plt.show()

    plt.subplot(122)
    plt.plot(np.cumprod(pred_pr_list))
    plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)

print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()
# Out:
# test_result.shape : (1764, 2)
# pr_val.shape : (1764, 1)
# y_test[:5] : [1 1 0 1 1]
# y_score[:5] : [[3.7743677e-03]
#  [9.0001059e-01]
#  [5.5624329e-02]
#  [5.2851015e-01]
#  [6.8337707e-05]]
# y_test.shape : (1764, 1)
# y_score.shape : (1764, 1)
# len(y_test) : 1764
# y_pred.shape : (1764,)
# precision : 0.44881889763779526
# recall : 0.14559386973180077
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0018155574
# win ratio improvement 0.44 --> 0.45
# accum_pr increased ! : 0.002 --> 0.288
# thresh : 0.9
# acc_pr_bythr : [0.28820375]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-90f0ebc376dc> in <module>()
#     100 plt.figure(figsize=(10, 5))
#     101 plt.subplot(121)
# --> 102 plt.plot(threshold, precision, label='precision')
#     103 plt.plot(threshold, recall, label='recall')
#     104 plt.legend()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (1759,)

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
