# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2
# !nvidia-smi
# import tensorflow

# %tensorflow_version 1.x

import keras
import tensorflow as tf
# import statsmodels
# statsmodels.__version__
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-02-11/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-02-11 BTCUSDT.xlsx', '2021-02-11 ETHUSDT.xlsx', '2021-02-11 BCHUSDT.xlsx', '2021-02-11 XRPUSDT.xlsx', '2021-02-11 EOSUSDT.xlsx', '2021-02-11 LTCUSDT.xlsx', '2021-02-11 ETCUSDT.xlsx', '2021-02-11 LINKUSDT.xlsx', '2021-02-11 XLMUSDT.xlsx', '2021-02-11 ADAUSDT.xlsx', '2021-02-11 XMRUSDT.xlsx', '2021-02-11 SXPUSDT.xlsx', '2021-02-11 KAVAUSDT.xlsx', '2021-02-11 BANDUSDT.xlsx', '2021-02-11 DASHUSDT.xlsx', '2021-02-11 ZECUSDT.xlsx', '2021-02-11 XTZUSDT.xlsx', '2021-02-11 BNBUSDT.xlsx', '2021-02-11 ATOMUSDT.xlsx', '2021-02-11 ONTUSDT.xlsx', '2021-02-11 IOTAUSDT.xlsx', '2021-02-11 BATUSDT.xlsx', '2021-02-11 NEOUSDT.xlsx', '2021-02-11 QTUMUSDT.xlsx', '2021-02-11 WAVESUSDT.xlsx', '2021-02-11 MKRUSDT.xlsx', '2021-02-11 SNXUSDT.xlsx', '2021-02-11 DOTUSDT.xlsx', '2021-02-11 THETAUSDT.xlsx', '2021-02-11 ALGOUSDT.xlsx', '2021-02-11 KNCUSDT.xlsx', '2021-02-11 ZRXUSDT.xlsx', '2021-02-11 COMPUSDT.xlsx', '2021-02-11 OMGUSDT.xlsx']

# %% [markdown]
# ### **Add coin**

# %%
import pickle

#       read existing last file       #
with open('./arima_result/arima_opt_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
  load_candi_pr_dict = pickle.load(f)

result_dict = dict()

for file in file_list:

  # file = '2021-02-07 ETH.xlsx'
  print(file)
  if not file.endswith('xlsx'):
    continue

  elif '02-11' in file:
    # continue

  #     add new data    #
  # elif file not in list(load_candi_pr_dict.keys()):

    # if 'theta'.upper() not in file:
    #   continue

    ohlcv = pd.read_excel(date_path + file, index_col=0)
    print(len(ohlcv))
    # print(ohlcv.head())

    temp_dict =  dict()
    temp_dict['ohlcv'] = ohlcv
    # print(temp_dict)
    load_candi_pr_dict[file] = temp_dict

    # break

    close = ohlcv.iloc[:, [3]]
    ema7 = close.ewm(span=7, adjust=False).mean()
    predictions, err_ranges = arima_test(ema7, 3000)

    temp_dict['predictions'] = predictions
    temp_dict['err_ranges'] = err_ranges
    # result_dict[file] = temp_dict
    load_candi_pr_dict[file] = temp_dict

  # break

    #         save dict       #
    with open('./arima_result/arima_ma7_profit_ls_only_long_result2_%s.pickle' % interval, 'wb') as f:
      pickle.dump(load_candi_pr_dict, f)
# Out:
# 2021-02-11 BTCUSDT.xlsx
# 14448
#  33.20%
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#  43.13%
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#  67.01%
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
#  67.47%
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
#  67.58%
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
#  67.86%
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
#  67.88%
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
#  67.96%
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
#  68.43%
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
#  68.47%
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:492: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
#  68.94%
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
#  99.98%4913 4913
# 2021-02-11 ETHUSDT.xlsx
# 14448
#  13.80%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2ac89064270e> in <module>()
#      36     close = ohlcv.iloc[:, [3]]
#      37     ema7 = close.ewm(span=7, adjust=False).mean()
# ---> 38     predictions, err_ranges = arima_test(ema7, 3000)
#      39
#      40     temp_dict['predictions'] = predictions
#
# <ipython-input-2-909d6e85f852> in arima_test(target, use_rows)
#      22
#      23       model = ARIMA(history, order=(0, 2, 4))
# ---> 24       model_fit = model.fit()
#      25       output = model_fit.forecast()
#      26       # print(output)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#    1147                                            method, transparams, solver,
#    1148                                            maxiter, full_output, disp,
# -> 1149                                            callback, start_ar_lags, **kwargs)
#    1150         normalized_cov_params = None  # TODO: fix this?
#    1151         arima_fit = ARIMAResults(self, mlefit._results.params,
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     949                                        maxiter=maxiter,
#     950                                        full_output=full_output, disp=disp,
# --> 951                                        callback=callback, **kwargs)
#     952         params = mlefit.params
#     953
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     477             Hinv = np.linalg.inv(-retvals['Hessian']) / nobs
#     478         elif not skip_hessian:
# --> 479             H = -1 * self.hessian(xopt)
#     480             invertible = False
#     481             if np.all(np.isfinite(H)):
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in hessian(self, params)
#     583         This is a numerical approximation.
#     584         """
# --> 585         return approx_hess_cs(params, self.loglike, args=(False,))
#     586
#     587     def _transparams(self, params):
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/numdiff.py in approx_hess_cs(x, f, epsilon, args, kwargs)
#     241             hess[i, j] = (f(*((x + 1j*ee[i, :] + ee[j, :],) + args), **kwargs)
#     242                           - f(*((x + 1j*ee[i, :] - ee[j, :],)+args),
# --> 243                               **kwargs)).imag/2./hess[i, j]
#     244             hess[j, i] = hess[i, j]
#     245
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in loglike(self, params, set_sigma2)
#     770         method = self.method
#     771         if method in ['mle', 'css-mle']:
# --> 772             return self.loglike_kalman(params, set_sigma2)
#     773         elif method == 'css':
#     774             return self.loglike_css(params, set_sigma2)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py in loglike_kalman(self, params, set_sigma2)
#     780         Compute exact loglikelihood for ARMA(p,q) model by the Kalman Filter.
#     781         """
# --> 782         return KalmanFilter.loglike(params, self, set_sigma2)
#     783
#     784     def loglike_css(self, params, set_sigma2=True):
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/kalmanf/kalmanfilter.py in loglike(cls, params, arma_model, set_sigma2)
#     223             loglike, sigma2 = kalman_loglike.kalman_loglike_complex(
#     224                 y, k, k_ar, k_ma, k_lags, int(nobs),
# --> 225                 Z_mat.astype(complex), R_mat, T_mat)
#     226         else:
#     227             raise TypeError("This dtype %s is not supported "
#
# statsmodels/tsa/kalmanf/kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_loglike_complex()
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### **Sum Plot**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
# print(type(result_dict))

with open('./arima_result/arima_candi_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
# with open('./arima_result/arima_profit_ls_only_long_expanded_result_%s.pickle' % interval, 'rb') as f:
  profit_result_dict = pickle.load(f)

keys = profit_result_dict.keys()
print(keys)
# keys = ['2021-02-07 ETH.xlsx']
# break


for i in range(2):

  plt.figure(figsize=(30, 5))

  plt.subplot(151)
  plt.title('win ratio')  
  for key in keys:  
    # print(profit_result_dict[key]['wr_list'].shape)
    plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['wr_list'][:, [i]])


  plt.subplot(152)
  plt.title('frequency')  
  for key in keys:  
    plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['fr_list'][:, [i]])

    
  plt.subplot(153)
  plt.title('acc profit')  
  for key in keys:  
    plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'][:, [i]])

  plt.subplot(155)
  plt.title('max acc profit by leverage')  
  for key in keys:  
    plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'][:, [i]], label=key)
    
  plt.subplot(154)
  plt.title('acc profit by leverage')  
  for key in keys:  
    plt.plot(profit_result_dict[key]['leverage_list'], profit_result_dict[key]['leverage_ap_list'][:, [i]], label=key)
    # print(result_dict[key]['leverage_ap_list'])
  plt.legend()

  plt.show()

  
pd.set_option('display.width', 1000)
pd.set_option('display.max_rows', 2500)
pd.set_option('display.max_columns', 2500)

pairs = list(profit_result_dict.keys())
result_df = pd.DataFrame(index=pairs)
profit = list()
max_lv_profit = list()
pr_fr_std = list()
max_pr_fr_std = list()

long_index = 0

for key in keys:  
  # print(np.max(profit_result_dict[key]['ap_list']))
  profit.append(np.max(profit_result_dict[key]['ap_list'][:, [long_index]]))
  # print(np.max(profit_result_dict[key]['leverage_ap_list']))
  max_lv_profit.append(np.max(profit_result_dict[key]['leverage_ap_list'][:, [long_index]]))

  ohlcv = profit_result_dict[key]['ohlcv']
  predictions = profit_result_dict[key]['predictions']
  err_ranges = profit_result_dict[key]['err_ranges']
  
  #             편의를 위해 long position 분석만을 진행한다.           #
  argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  peak_tp = profit_result_dict[key]['tp_list'][argmax]

  result = get_back_result(ohlcv, predictions, err_ranges, tp=peak_tp, leverage=4)
  profit_list = result[3][long_index]
  pr_list_fr = list(map(lambda x : 0 if x == 1.0 else 1, profit_list))
  profited_index = np.argwhere(np.array(pr_list_fr) == 1)
  # print(profited_index)
  term_list = list()
  for i in range(len(profited_index) - 1):
    term_list.append(profited_index[i + 1] - profited_index[i])

  profit_result_dict[key]['pr_list'] = profit_list
  profit_result_dict[key]['pr_fr_std'] = np.std(term_list)
  pr_fr_std.append(np.std(term_list))

  argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  max_peak_tp = profit_result_dict[key]['tp_list'][argmax]

  result = get_back_result(ohlcv, predictions, err_ranges, tp=max_peak_tp, leverage=4)
  profit_list = result[3][long_index]
  pr_list_fr = list(map(lambda x : 0 if x == 1.0 else 1, profit_list))
  profited_index = np.argwhere(np.array(pr_list_fr) == 1)
  # print(profited_index)
  term_list = list()
  for i in range(len(profited_index) - 1):
    term_list.append(profited_index[i + 1] - profited_index[i])

  profit_result_dict[key]['max_pr_list'] = profit_list
  profit_result_dict[key]['max_pr_fr_std'] = np.std(term_list)
  max_pr_fr_std.append(np.std(term_list))


# result_df['index'] = pairs
result_df['profit']= profit
result_df['max_lv_profit']= max_lv_profit
result_df['pr_fr_std'] = pr_fr_std
result_df['max_pr_fr_std'] = max_pr_fr_std
# print(result_df)

#     sort by values    #
print(result_df.sort_values(by='profit', ascending=False))
print(result_df.sort_values(by=['max_lv_profit'], ascending=False))
print(result_df.sort_values(by=['pr_fr_std'], ascending=True))
print(result_df.sort_values(by=['max_pr_fr_std'], ascending=True))

#     extract candidates    #
candis = result_df.sort_values(by=['max_lv_profit'], ascending=False).index
print(candis)



#         save dict 2       #
# with open('./arima_result/arima_candi_profit_ls_only_long_result_%s.pickle' % interval, 'wb') as f:
#   pickle.dump(profit_result_dict, f)

# %% [markdown]
# ### **Data Stacking**

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler


with open('./arima_result/arima_candi_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
# with open('./arima_result/arima_profit_ls_only_long_expanded_result_%s.pickle' % interval, 'rb') as f:
  profit_result_dict = pickle.load(f)

keys = profit_result_dict.keys()
print(keys)
leverage = 2
prev_x = None
for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue
  if '2021-03-02 DOTUSDT.xlsx' in candis[i]:
    # print('')
    continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  for key in keys:  
    # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
    argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
    max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
    # plt.axvline(max_peak_tp, linestyle='--')
    # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      ohlcv = profit_result_dict[key]['ohlcv']
      predictions = profit_result_dict[key]['predictions']
      err_ranges = profit_result_dict[key]['err_ranges']

      # predictions = ohlcv['close'].shift(1).values
      # err_ranges = np.zeros_like(predictions)

      leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result(ohlcv, predictions, err_ranges, tp=tp, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]

      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = (np.array(predictions) - np.array(err_ranges)) * (1 / (tp + 1))
      long_ep = long_ep.reshape(-1, 1)

      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 45
      data_x, data_pr, data_updown = [], [], []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          min_max = MinMaxScaler()
          temp_data[:, :5] = min_max.fit_transform(temp_data[:, :5])


          #   vol -> min_max
          min_max = MinMaxScaler()
          temp_data[:, [5]] = min_max.fit_transform(temp_data[:, [5]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]

      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)

      #     do stacking   #
      if prev_x is None:
        prev_x = input_x
        prev_pr = input_pr
        prev_ud = input_ud
      else:
        total_x = np.vstack((prev_x, input_x))
        total_pr = np.vstack((prev_pr, input_pr))
        total_ud = np.vstack((prev_ud, input_ud))

        prev_x = total_x
        prev_pr = total_pr
        prev_ud = total_ud

        print('total_x.shape :', total_x.shape)
        print('total_pr.shape :', total_pr.shape)
        print('total_ud.shape :', total_ud.shape)

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Model tester**

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import keras
from sklearn.metrics import confusion_matrix
import pickle
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


with open('./arima_result/arima_ma7_profit_ls_only_long_result2_%s.pickle' % interval, 'rb') as f:
  load_dict = pickle.load(f)

ckpt_path = current_path + 'ckpt/'

model_name = 'classifier_45_ma7_pr3_03766.h5'
model = keras.models.load_model(ckpt_path + model_name)

long_index = 0
leverage = 5
thresh = 0.65

candis = list(load_dict.keys())
prev_x = None
for i in range(len(candis)):

  # if i >= 2:
  #   break

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue
  if '2021-03-02 DOTUSDT.xlsx' in candis[i]:
    # print('')
    continue

  if '02-11' in candis[i]:
  # if '2021-02-11 BTCUSDT.xlsx' not in candis[i]:
    continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      ohlcv = load_dict[key]['ohlcv']
      print('len(ohlcv) :', len(ohlcv))
      # ohlcv = ohlcv.iloc[-int(len(ohlcv) * 0.34):]
      predictions = load_dict[key]['predictions']
      err_ranges = load_dict[key]['err_ranges']

      # predictions = ohlcv['close'].shift(1).values
      # err_ranges = np.zeros_like(predictions)

      # leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]

      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = np.array(predictions)
      # long_ep = ohlc.iloc[:, [-1]].values <-- 이건 이전 종가가 아니라 그냥 종가임
      long_ep = long_ep.reshape(-1, 1)

      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 45
      data_x, data_pr, data_updown = [], [], []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          min_max = MinMaxScaler()
          temp_data[:, :5] = min_max.fit_transform(temp_data[:, :5])


          #   vol -> min_max
          min_max = MinMaxScaler()
          temp_data[:, [5]] = min_max.fit_transform(temp_data[:, [5]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          #     append result data    #
          data_pr.append(pr_list[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]

      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)


      #         reshape data     #
      temp_x = list()
      for d_i, data in enumerate(input_x):
        # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
        resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
        # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
        
        # if d_i == 0:
        #   plt.imshow(data)
        #   plt.show()
        #   plt.imshow(resized_data)
        #   plt.show()
        # print('resized_data.shape :', resized_data.shape)
        # break
        temp_x.append(resized_data)

      re_input_x = np.array(temp_x)
      y_test = np.where(input_pr > 1, 1, 0)
      # y_test = np.where(input_ud > 1, 1, 0)

      #             ai tester phase              #
      test_result = model.predict(re_input_x)
      
      y_score = test_result[:, [1]]
      y_pred = np.where(y_score[:, -1] > thresh, 1, 0)


      
      #         plot result       #
      test_size = len(y_test)
      test_pr_list = input_pr
      print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

      
      cmat = confusion_matrix(y_test, y_pred)

      org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
      ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
      print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

      # print('pr_test.shape :', pr_test.shape)

      # print(y_pred)
      # print(test_pr_list)
      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      # print('pred_pr_list.shape :', pred_pr_list.shape)

      if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
        print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
        print('thresh :', thresh)
        
      precision, recall, threshold = precision_recall_curve(y_test, y_score)
      precision, recall = precision[:-1], recall[:-1]

      plt.plot(threshold, precision, label='precision')
      plt.plot(threshold, recall, label='recall')
      plt.legend()
      plt.title('precision recall')
      plt.show()      

      x_test = re_input_x

      acc_pr_bythr = []
      for thresh in threshold:

        y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
        print('y_pred.shape :', y_pred.shape)
        # print('y_pred :', y_pred)

        #     compare precision     #

        print('precision :', precision_score(y_test, y_pred))
        print('recall :', recall_score(y_test, y_pred))
        print()

        print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
        print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

        # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
        # plt.show()  
        # print()

        #     check win-ratio improvement     #
        cmat = confusion_matrix(y_test, y_pred)
        print(cmat)
        print("cmat.matrix() :", cmat.matrix())
        # print(np.sum(cmat, axis=1))

        test_size = len(y_test)
        test_pr_list = input_pr
        print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

        org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
        ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
        print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

        # print('pr_test.shape :', pr_test.shape)

        # print(y_pred)
        # print(test_pr_list)
        pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
        # print('pred_pr_list.shape :', pred_pr_list.shape)

        if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
          print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
          print('thresh :', thresh)
          
        # if len(threshold) == 1:
        #   plt.figure(figsize=(10, 5))
        #   plt.subplot(121)
        #   plt.plot(np.cumprod(test_pr_list))
        #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
        # # plt.show()

        #   plt.subplot(122)
        #   plt.plot(np.cumprod(pred_pr_list))
        #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
        #   plt.show()


        acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])

      print('acc_pr_bythr :', acc_pr_bythr)

      plt.figure(figsize=(10, 5))
      plt.subplot(121)
      plt.plot(threshold, precision, label='precision')
      plt.plot(threshold, recall, label='recall')
      plt.legend()
      plt.title('precision recall')
      # plt.show()
      plt.subplot(122)
      plt.plot(threshold, acc_pr_bythr)
      plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
      plt.axvline(threshold[np.argmax(acc_pr_bythr)], linestyle='--', color='b')
      plt.title('best thr : %.4f' % threshold[np.argmax(acc_pr_bythr)])
      plt.show()


      #         save dict       #
      # with open('./arima_result/arima_ma7_profit_ls_only_long_result_%s.pickle' % interval, 'wb') as f:
      #   pickle.dump(load_dict, f)


      #     do stacking   #
      # if prev_x is None:
      #   prev_x = input_x
      #   prev_pr = input_pr
      #   prev_ud = input_ud
      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud))

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud

      #   print('total_x.shape :', total_x.shape)
      #   print('total_pr.shape :', total_pr.shape)
      #   print('total_ud.shape :', total_ud.shape)
# Out:
# len(ohlcv) : 17129
# -------------- 2021-04-08 BTCUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5758, 45, 6)
# input_x.shape : (5758, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5758, 1)
# input_ud.shape : (5758, 1)
# origin ac_pr : 9.536046e-10
# win ratio improvement 0.45 --> 0.85
# accum_pr increased ! : 0.000 --> 59945272791277764608.000
# thresh : 0.65
# y_pred.shape : (5758,)
# precision : 0.4570476858345021
# recall : 0.9996165644171779
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
# [[  53 3097]
#  [   1 2607]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-631d19d8ae3e> in <module>()
#     296         cmat = confusion_matrix(y_test, y_pred)
#     297         print(cmat)
# --> 298         print("cmat.matrix() :", cmat.matrix())
#     299         # print(np.sum(cmat, axis=1))
#     300
#
# AttributeError: 'numpy.ndarray' object has no attribute 'matrix'

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape=(row, col, 3)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model
# Out:
# TensorFlow is already loaded. Please restart the runtime to change versions.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-006bcdf57f17> in <module>()
#      36 num_classes = 2
#      37
# ---> 38 def FER_Model(input_shape=(row, col, 3)):
#      39     # first input model
#      40     visible = layers.Input(shape=input_shape, name='input')
#
# NameError: name 'row' is not defined

# %%
print(keras.__version__)
print(tf.__version__)

# %% [markdown]
# ### **Data Split**

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight
# import cv2



seed = 1
random_state = 20
np.random.seed(seed)
# tf.random.set_seed(seed)

#         resize total_x shape  (, 5, 6, 3)      #
# .repeat(2, axis=0).repeat(2, axis=1)
temp_x = list()
for d_i, data in enumerate(total_x):
  # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
  # # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
  resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
  # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
  
  if d_i == 0:
    plt.imshow(data)
    plt.show()
    plt.imshow(resized_data)
    plt.show()
  # print('resized_data.shape :', resized_data.shape)
  # break
  temp_x.append(resized_data)

re_total_x = np.array(temp_x)
print('re_total_x.shape :', re_total_x.shape)
# break

#         train / test split      #
x_train, x_test_, pr_train, pr_test_, ud_train, ud_test_ = train_test_split(re_total_x, total_pr, total_ud, test_size=0.4, shuffle=True, random_state=random_state)
x_test, x_val, pr_test, pr_val, ud_test, ud_val = train_test_split(x_test_, pr_test_, ud_test_, test_size=0.5, shuffle=True, random_state=random_state)


#         pr label   #
y_train = np.where(pr_train > 1, 1, 0)
y_test = np.where(pr_test > 1, 1, 0)
y_val = np.where(pr_val > 1, 1, 0)

#         up label      #
# y_train = np.where(ud_train > 1, 1, 0)
# y_test = np.where(ud_test > 1, 1, 0)
# y_val = np.where(ud_val > 1, 1, 0)

print('pr_train[:5] :', pr_train[:5])
print('ud_train[:5] :', ud_train[:5])
print('y_train[:5] :', y_train[:5])
print('y_train.dtype :', y_train.dtype)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

def class_ratio(in_list):

  return in_list / in_list[1]

print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)

datagen = ImageDataGenerator( 
    rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)

batch_size = 16

for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break
# Out:
# re_total_x.shape : (5009, 45, 6, 3)
# pr_train[:5] : [[1.0224142 ]
#  [0.89844304]
#  [0.9958647 ]
#  [1.0007784 ]
#  [0.998824  ]]
# ud_train[:5] : [[0.97553515]
#  [0.9333513 ]
#  [0.96507597]
#  [0.962473  ]
#  [0.98410076]]
# y_train[:5] : [[1]
#  [0]
#  [0]
#  [1]
#  [0]]
# y_train.dtype : int64
# x_train.shape : (3005, 45, 6, 3)
# x_test.shape : (1002, 45, 6, 3)
# x_val.shape : (1002, 45, 6, 3)
# y_train.shape : (3005, 1)
# y_test.shape : (1002, 1)
# y_val.shape : (1002, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([1161, 1844])) [0.62960954 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([398, 604])) [0.6589404 1.       ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([412, 590])) [0.69830508 1.        ]
# class_weights : {0: 1.294142980189492, 1: 0.8148047722342733}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (3005, 2)
# y_val_ohe.shape : (1002, 2)
# y_test_ohe.shape : (1002, 2)

# %% [markdown]
# ### **Training**

# %%
(_, row, col, _) = x_train.shape

model = FER_Model(input_shape=(row, col, 3))
opt = Adam(lr=0.00001, decay=0.000005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
  
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_%s_min_pr_re2.h5' % period

checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=40)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 300
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)
# Out:
# Epoch 1/300
#  - 2s - loss: 0.7276 - accuracy: 0.4992 - val_loss: 0.8088 - val_accuracy: 0.4022
#
# Epoch 00001: val_loss improved from inf to 0.80884, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 2/300
#  - 2s - loss: 0.7023 - accuracy: 0.5098 - val_loss: 0.6675 - val_accuracy: 0.5429
#
# Epoch 00002: val_loss improved from 0.80884 to 0.66753, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 3/300
#  - 2s - loss: 0.6981 - accuracy: 0.5275 - val_loss: 0.6863 - val_accuracy: 0.5758
#
# Epoch 00003: val_loss did not improve from 0.66753
# Epoch 4/300
#  - 2s - loss: 0.6963 - accuracy: 0.5268 - val_loss: 0.6602 - val_accuracy: 0.5329
#
# Epoch 00004: val_loss improved from 0.66753 to 0.66020, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 5/300
#  - 2s - loss: 0.6948 - accuracy: 0.5351 - val_loss: 0.7234 - val_accuracy: 0.5838
#
# Epoch 00005: val_loss did not improve from 0.66020
# Epoch 6/300
#  - 2s - loss: 0.6950 - accuracy: 0.5268 - val_loss: 0.7945 - val_accuracy: 0.6048
#
# Epoch 00006: val_loss did not improve from 0.66020
# Epoch 7/300
#  - 2s - loss: 0.6939 - accuracy: 0.5295 - val_loss: 0.6650 - val_accuracy: 0.5818
#
# Epoch 00007: val_loss did not improve from 0.66020
# Epoch 8/300
#  - 2s - loss: 0.6974 - accuracy: 0.5208 - val_loss: 0.6825 - val_accuracy: 0.5828
#
# Epoch 00008: val_loss did not improve from 0.66020
# Epoch 9/300
#  - 2s - loss: 0.6912 - accuracy: 0.5201 - val_loss: 0.7218 - val_accuracy: 0.5060
#
# Epoch 00009: val_loss did not improve from 0.66020
# Epoch 10/300
#  - 2s - loss: 0.6917 - accuracy: 0.5344 - val_loss: 0.7048 - val_accuracy: 0.5619
#
# Epoch 00010: val_loss did not improve from 0.66020
# Epoch 11/300
#  - 2s - loss: 0.6917 - accuracy: 0.5201 - val_loss: 0.7650 - val_accuracy: 0.4940
#
# Epoch 00011: val_loss did not improve from 0.66020
# Epoch 12/300
#  - 2s - loss: 0.6920 - accuracy: 0.5408 - val_loss: 0.6492 - val_accuracy: 0.5519
#
# Epoch 00012: val_loss improved from 0.66020 to 0.64916, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 13/300
#  - 2s - loss: 0.6864 - accuracy: 0.5561 - val_loss: 0.7334 - val_accuracy: 0.5000
#
# Epoch 00013: val_loss did not improve from 0.64916
# Epoch 14/300
#  - 2s - loss: 0.6924 - accuracy: 0.5275 - val_loss: 0.7852 - val_accuracy: 0.6018
#
# Epoch 00014: val_loss did not improve from 0.64916
# Epoch 15/300
#  - 2s - loss: 0.6874 - accuracy: 0.5494 - val_loss: 0.5934 - val_accuracy: 0.5948
#
# Epoch 00015: val_loss improved from 0.64916 to 0.59344, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 16/300
#  - 2s - loss: 0.6874 - accuracy: 0.5471 - val_loss: 0.6858 - val_accuracy: 0.5349
#
# Epoch 00016: val_loss did not improve from 0.59344
# Epoch 17/300
#  - 2s - loss: 0.6819 - accuracy: 0.5641 - val_loss: 0.6860 - val_accuracy: 0.5170
#
# Epoch 00017: val_loss did not improve from 0.59344
# Epoch 18/300
#  - 2s - loss: 0.6862 - accuracy: 0.5534 - val_loss: 0.6623 - val_accuracy: 0.5449
#
# Epoch 00018: val_loss did not improve from 0.59344
# Epoch 19/300
#  - 2s - loss: 0.6871 - accuracy: 0.5514 - val_loss: 0.7191 - val_accuracy: 0.5299
#
# Epoch 00019: val_loss did not improve from 0.59344
# Epoch 20/300
#  - 2s - loss: 0.6812 - accuracy: 0.5637 - val_loss: 0.6793 - val_accuracy: 0.4910
#
# Epoch 00020: val_loss did not improve from 0.59344
# Epoch 21/300
#  - 2s - loss: 0.6815 - accuracy: 0.5584 - val_loss: 0.7081 - val_accuracy: 0.4900
#
# Epoch 00021: val_loss did not improve from 0.59344
# Epoch 22/300
#  - 2s - loss: 0.6807 - accuracy: 0.5737 - val_loss: 0.6182 - val_accuracy: 0.4521
#
# Epoch 00022: val_loss did not improve from 0.59344
# Epoch 23/300
#  - 2s - loss: 0.6823 - accuracy: 0.5574 - val_loss: 0.6754 - val_accuracy: 0.5709
#
# Epoch 00023: val_loss did not improve from 0.59344
# Epoch 24/300
#  - 2s - loss: 0.6760 - accuracy: 0.5780 - val_loss: 0.6781 - val_accuracy: 0.5369
#
# Epoch 00024: val_loss did not improve from 0.59344
# Epoch 25/300
#  - 2s - loss: 0.6769 - accuracy: 0.5667 - val_loss: 0.6004 - val_accuracy: 0.5599
#
# Epoch 00025: val_loss did not improve from 0.59344
# Epoch 26/300
#  - 2s - loss: 0.6733 - accuracy: 0.5787 - val_loss: 0.6207 - val_accuracy: 0.5768
#
# Epoch 00026: val_loss did not improve from 0.59344
# Epoch 27/300
#  - 2s - loss: 0.6724 - accuracy: 0.5977 - val_loss: 0.5848 - val_accuracy: 0.5778
#
# Epoch 00027: val_loss improved from 0.59344 to 0.58478, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 28/300
#  - 2s - loss: 0.6700 - accuracy: 0.5890 - val_loss: 0.6496 - val_accuracy: 0.5938
#
# Epoch 00028: val_loss did not improve from 0.58478
# Epoch 29/300
#  - 2s - loss: 0.6693 - accuracy: 0.5953 - val_loss: 0.7688 - val_accuracy: 0.5898
#
# Epoch 00029: val_loss did not improve from 0.58478
# Epoch 30/300
#  - 2s - loss: 0.6671 - accuracy: 0.5923 - val_loss: 0.5869 - val_accuracy: 0.5559
#
# Epoch 00030: val_loss did not improve from 0.58478
# Epoch 31/300
#  - 2s - loss: 0.6613 - accuracy: 0.5980 - val_loss: 0.6515 - val_accuracy: 0.5918
#
# Epoch 00031: val_loss did not improve from 0.58478
# Epoch 32/300
#  - 2s - loss: 0.6689 - accuracy: 0.5870 - val_loss: 0.6388 - val_accuracy: 0.5808
#
# Epoch 00032: val_loss did not improve from 0.58478
# Epoch 33/300
#  - 2s - loss: 0.6595 - accuracy: 0.6037 - val_loss: 0.5826 - val_accuracy: 0.5768
#
# Epoch 00033: val_loss improved from 0.58478 to 0.58262, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 34/300
#  - 2s - loss: 0.6546 - accuracy: 0.6060 - val_loss: 0.7805 - val_accuracy: 0.5329
#
# Epoch 00034: val_loss did not improve from 0.58262
# Epoch 35/300
#  - 2s - loss: 0.6570 - accuracy: 0.6133 - val_loss: 0.7572 - val_accuracy: 0.5250
#
# Epoch 00035: val_loss did not improve from 0.58262
# Epoch 36/300
#  - 2s - loss: 0.6569 - accuracy: 0.6050 - val_loss: 0.8002 - val_accuracy: 0.5389
#
# Epoch 00036: val_loss did not improve from 0.58262
# Epoch 37/300
#  - 2s - loss: 0.6497 - accuracy: 0.6156 - val_loss: 0.8577 - val_accuracy: 0.5210
#
# Epoch 00037: val_loss did not improve from 0.58262
# Epoch 38/300
#  - 2s - loss: 0.6498 - accuracy: 0.6246 - val_loss: 0.6755 - val_accuracy: 0.5389
#
# Epoch 00038: val_loss did not improve from 0.58262
# Epoch 39/300
#  - 2s - loss: 0.6470 - accuracy: 0.6200 - val_loss: 0.8067 - val_accuracy: 0.5399
#
# Epoch 00039: val_loss did not improve from 0.58262
# Epoch 40/300
#  - 2s - loss: 0.6459 - accuracy: 0.6290 - val_loss: 0.6456 - val_accuracy: 0.5449
#
# Epoch 00040: val_loss did not improve from 0.58262
# Epoch 41/300
#  - 2s - loss: 0.6418 - accuracy: 0.6319 - val_loss: 0.6709 - val_accuracy: 0.5050
#
# Epoch 00041: val_loss did not improve from 0.58262
# Epoch 42/300
#  - 2s - loss: 0.6436 - accuracy: 0.6246 - val_loss: 0.6195 - val_accuracy: 0.5200
#
# Epoch 00042: val_loss did not improve from 0.58262
# Epoch 43/300
#  - 2s - loss: 0.6409 - accuracy: 0.6263 - val_loss: 0.5075 - val_accuracy: 0.6018
#
# Epoch 00043: val_loss improved from 0.58262 to 0.50753, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 44/300
#  - 2s - loss: 0.6421 - accuracy: 0.6146 - val_loss: 0.9268 - val_accuracy: 0.5709
#
# Epoch 00044: val_loss did not improve from 0.50753
# Epoch 45/300
#  - 2s - loss: 0.6405 - accuracy: 0.6373 - val_loss: 0.7021 - val_accuracy: 0.5679
#
# Epoch 00045: val_loss did not improve from 0.50753
# Epoch 46/300
#  - 2s - loss: 0.6389 - accuracy: 0.6193 - val_loss: 0.6735 - val_accuracy: 0.5828
#
# Epoch 00046: val_loss did not improve from 0.50753
# Epoch 47/300
#  - 2s - loss: 0.6415 - accuracy: 0.6329 - val_loss: 0.5805 - val_accuracy: 0.5279
#
# Epoch 00047: val_loss did not improve from 0.50753
# Epoch 48/300
#  - 2s - loss: 0.6283 - accuracy: 0.6539 - val_loss: 0.6838 - val_accuracy: 0.5429
#
# Epoch 00048: val_loss did not improve from 0.50753
# Epoch 49/300
#  - 2s - loss: 0.6277 - accuracy: 0.6493 - val_loss: 0.8705 - val_accuracy: 0.5649
#
# Epoch 00049: val_loss did not improve from 0.50753
# Epoch 50/300
#  - 2s - loss: 0.6257 - accuracy: 0.6496 - val_loss: 0.7143 - val_accuracy: 0.5589
#
# Epoch 00050: val_loss did not improve from 0.50753
# Epoch 51/300
#  - 2s - loss: 0.6276 - accuracy: 0.6486 - val_loss: 0.8089 - val_accuracy: 0.5509
#
# Epoch 00051: val_loss did not improve from 0.50753
# Epoch 52/300
#  - 2s - loss: 0.6220 - accuracy: 0.6466 - val_loss: 0.9268 - val_accuracy: 0.5828
#
# Epoch 00052: val_loss did not improve from 0.50753
# Epoch 53/300
#  - 2s - loss: 0.6195 - accuracy: 0.6546 - val_loss: 0.8089 - val_accuracy: 0.5559
#
# Epoch 00053: val_loss did not improve from 0.50753
# Epoch 54/300
#  - 2s - loss: 0.6212 - accuracy: 0.6449 - val_loss: 0.5862 - val_accuracy: 0.5699
#
# Epoch 00054: val_loss did not improve from 0.50753
# Epoch 55/300
#  - 2s - loss: 0.6188 - accuracy: 0.6579 - val_loss: 0.9177 - val_accuracy: 0.4960
#
# Epoch 00055: val_loss did not improve from 0.50753
# Epoch 56/300
#  - 2s - loss: 0.6126 - accuracy: 0.6569 - val_loss: 0.4563 - val_accuracy: 0.5489
#
# Epoch 00056: val_loss improved from 0.50753 to 0.45633, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 57/300
#  - 2s - loss: 0.6146 - accuracy: 0.6572 - val_loss: 0.8113 - val_accuracy: 0.5719
#
# Epoch 00057: val_loss did not improve from 0.45633
# Epoch 58/300
#  - 2s - loss: 0.6093 - accuracy: 0.6686 - val_loss: 0.6632 - val_accuracy: 0.5719
#
# Epoch 00058: val_loss did not improve from 0.45633
# Epoch 59/300
#  - 2s - loss: 0.6136 - accuracy: 0.6546 - val_loss: 0.6347 - val_accuracy: 0.5778
#
# Epoch 00059: val_loss did not improve from 0.45633
# Epoch 60/300
#  - 2s - loss: 0.6059 - accuracy: 0.6626 - val_loss: 0.6862 - val_accuracy: 0.5639
#
# Epoch 00060: val_loss did not improve from 0.45633
# Epoch 61/300
#  - 2s - loss: 0.6012 - accuracy: 0.6755 - val_loss: 0.7319 - val_accuracy: 0.5589
#
# Epoch 00061: val_loss did not improve from 0.45633
# Epoch 62/300
#  - 2s - loss: 0.5929 - accuracy: 0.6779 - val_loss: 0.9735 - val_accuracy: 0.5828
#
# Epoch 00062: val_loss did not improve from 0.45633
# Epoch 63/300
#  - 2s - loss: 0.6051 - accuracy: 0.6626 - val_loss: 0.7130 - val_accuracy: 0.5659
#
# Epoch 00063: val_loss did not improve from 0.45633
# Epoch 64/300
#  - 2s - loss: 0.5992 - accuracy: 0.6835 - val_loss: 0.6872 - val_accuracy: 0.5948
#
# Epoch 00064: val_loss did not improve from 0.45633
# Epoch 65/300
#  - 2s - loss: 0.6011 - accuracy: 0.6712 - val_loss: 0.7146 - val_accuracy: 0.5798
#
# Epoch 00065: val_loss did not improve from 0.45633
# Epoch 66/300
#  - 2s - loss: 0.5936 - accuracy: 0.6928 - val_loss: 0.7144 - val_accuracy: 0.5739
#
# Epoch 00066: val_loss did not improve from 0.45633
# Epoch 67/300
#  - 2s - loss: 0.5989 - accuracy: 0.6849 - val_loss: 0.8800 - val_accuracy: 0.5739
#
# Epoch 00067: val_loss did not improve from 0.45633
# Epoch 68/300
#  - 2s - loss: 0.5831 - accuracy: 0.6902 - val_loss: 1.0165 - val_accuracy: 0.5459
#
# Epoch 00068: val_loss did not improve from 0.45633
# Epoch 69/300
#  - 2s - loss: 0.5951 - accuracy: 0.6765 - val_loss: 0.6837 - val_accuracy: 0.6018
#
# Epoch 00069: val_loss did not improve from 0.45633
# Epoch 70/300
#  - 2s - loss: 0.5920 - accuracy: 0.6819 - val_loss: 0.6627 - val_accuracy: 0.5729
#
# Epoch 00070: val_loss did not improve from 0.45633
# Epoch 71/300
#  - 2s - loss: 0.5732 - accuracy: 0.7075 - val_loss: 0.7418 - val_accuracy: 0.5679
#
# Epoch 00071: val_loss did not improve from 0.45633
# Epoch 72/300
#  - 2s - loss: 0.5890 - accuracy: 0.6696 - val_loss: 0.4851 - val_accuracy: 0.5948
#
# Epoch 00072: val_loss did not improve from 0.45633
# Epoch 73/300
#  - 2s - loss: 0.5880 - accuracy: 0.6802 - val_loss: 0.6812 - val_accuracy: 0.5788
#
# Epoch 00073: val_loss did not improve from 0.45633
# Epoch 74/300
#  - 2s - loss: 0.5755 - accuracy: 0.7151 - val_loss: 0.7062 - val_accuracy: 0.5808
#
# Epoch 00074: val_loss did not improve from 0.45633
# Epoch 75/300
#  - 2s - loss: 0.5744 - accuracy: 0.6978 - val_loss: 0.7548 - val_accuracy: 0.5868
#
# Epoch 00075: val_loss did not improve from 0.45633
# Epoch 76/300
#  - 2s - loss: 0.5706 - accuracy: 0.6995 - val_loss: 0.6909 - val_accuracy: 0.5589
#
# Epoch 00076: val_loss did not improve from 0.45633
# Epoch 77/300
#  - 2s - loss: 0.5710 - accuracy: 0.7018 - val_loss: 0.6055 - val_accuracy: 0.5619
#
# Epoch 00077: val_loss did not improve from 0.45633
# Epoch 78/300
#  - 2s - loss: 0.5715 - accuracy: 0.6968 - val_loss: 0.6697 - val_accuracy: 0.5669
#
# Epoch 00078: val_loss did not improve from 0.45633
# Epoch 79/300
#  - 2s - loss: 0.5729 - accuracy: 0.6975 - val_loss: 0.8546 - val_accuracy: 0.5758
#
# Epoch 00079: val_loss did not improve from 0.45633
# Epoch 80/300
#  - 2s - loss: 0.5716 - accuracy: 0.7048 - val_loss: 0.6010 - val_accuracy: 0.5719
#
# Epoch 00080: val_loss did not improve from 0.45633
# Epoch 81/300
#  - 2s - loss: 0.5668 - accuracy: 0.7072 - val_loss: 0.5771 - val_accuracy: 0.5818
#
# Epoch 00081: val_loss did not improve from 0.45633
# Epoch 82/300
#  - 2s - loss: 0.5567 - accuracy: 0.7072 - val_loss: 0.8952 - val_accuracy: 0.5778
#
# Epoch 00082: val_loss did not improve from 0.45633
# Epoch 83/300
#  - 2s - loss: 0.5650 - accuracy: 0.7048 - val_loss: 0.5774 - val_accuracy: 0.5928
#
# Epoch 00083: val_loss did not improve from 0.45633
# Epoch 84/300
#  - 2s - loss: 0.5579 - accuracy: 0.7231 - val_loss: 0.6828 - val_accuracy: 0.5719
#
# Epoch 00084: val_loss did not improve from 0.45633
# Epoch 85/300
#  - 2s - loss: 0.5605 - accuracy: 0.7095 - val_loss: 0.5093 - val_accuracy: 0.5549
#
# Epoch 00085: val_loss did not improve from 0.45633
# Epoch 86/300
#  - 2s - loss: 0.5633 - accuracy: 0.7065 - val_loss: 1.0841 - val_accuracy: 0.5489
#
# Epoch 00086: val_loss did not improve from 0.45633
# Epoch 87/300
#  - 2s - loss: 0.5582 - accuracy: 0.7045 - val_loss: 0.6449 - val_accuracy: 0.5938
#
# Epoch 00087: val_loss did not improve from 0.45633
# Epoch 88/300
#  - 2s - loss: 0.5504 - accuracy: 0.7191 - val_loss: 0.5018 - val_accuracy: 0.5788
#
# Epoch 00088: val_loss did not improve from 0.45633
# Epoch 89/300
#  - 2s - loss: 0.5529 - accuracy: 0.7111 - val_loss: 0.4060 - val_accuracy: 0.5938
#
# Epoch 00089: val_loss improved from 0.45633 to 0.40599, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 90/300
#  - 2s - loss: 0.5490 - accuracy: 0.7185 - val_loss: 0.8710 - val_accuracy: 0.5978
#
# Epoch 00090: val_loss did not improve from 0.40599
# Epoch 91/300
#  - 2s - loss: 0.5515 - accuracy: 0.7105 - val_loss: 0.6081 - val_accuracy: 0.5878
#
# Epoch 00091: val_loss did not improve from 0.40599
# Epoch 92/300
#  - 2s - loss: 0.5441 - accuracy: 0.7295 - val_loss: 0.5592 - val_accuracy: 0.5948
#
# Epoch 00092: val_loss did not improve from 0.40599
# Epoch 93/300
#  - 2s - loss: 0.5452 - accuracy: 0.7158 - val_loss: 0.7447 - val_accuracy: 0.5709
#
# Epoch 00093: val_loss did not improve from 0.40599
# Epoch 94/300
#  - 2s - loss: 0.5445 - accuracy: 0.7185 - val_loss: 0.8268 - val_accuracy: 0.5808
#
# Epoch 00094: val_loss did not improve from 0.40599
# Epoch 95/300
#  - 2s - loss: 0.5342 - accuracy: 0.7331 - val_loss: 0.5748 - val_accuracy: 0.5828
#
# Epoch 00095: val_loss did not improve from 0.40599
# Epoch 96/300
#  - 2s - loss: 0.5403 - accuracy: 0.7271 - val_loss: 0.6942 - val_accuracy: 0.5918
#
# Epoch 00096: val_loss did not improve from 0.40599
# Epoch 97/300
#  - 2s - loss: 0.5378 - accuracy: 0.7268 - val_loss: 0.8338 - val_accuracy: 0.5868
#
# Epoch 00097: val_loss did not improve from 0.40599
# Epoch 98/300
#  - 2s - loss: 0.5377 - accuracy: 0.7278 - val_loss: 0.7811 - val_accuracy: 0.5768
#
# Epoch 00098: val_loss did not improve from 0.40599
# Epoch 99/300
#  - 2s - loss: 0.5331 - accuracy: 0.7341 - val_loss: 0.9085 - val_accuracy: 0.5848
#
# Epoch 00099: val_loss did not improve from 0.40599
# Epoch 100/300
#  - 2s - loss: 0.5229 - accuracy: 0.7408 - val_loss: 0.4074 - val_accuracy: 0.5948
#
# Epoch 00100: val_loss did not improve from 0.40599
# Epoch 101/300
#  - 2s - loss: 0.5245 - accuracy: 0.7344 - val_loss: 0.3949 - val_accuracy: 0.5639
#
# Epoch 00101: val_loss improved from 0.40599 to 0.39488, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 102/300
#  - 2s - loss: 0.5317 - accuracy: 0.7308 - val_loss: 0.6011 - val_accuracy: 0.5868
#
# Epoch 00102: val_loss did not improve from 0.39488
# Epoch 103/300
#  - 2s - loss: 0.5211 - accuracy: 0.7394 - val_loss: 0.7160 - val_accuracy: 0.5858
#
# Epoch 00103: val_loss did not improve from 0.39488
# Epoch 104/300
#  - 2s - loss: 0.5205 - accuracy: 0.7404 - val_loss: 0.4029 - val_accuracy: 0.5768
#
# Epoch 00104: val_loss did not improve from 0.39488
# Epoch 105/300
#  - 2s - loss: 0.5283 - accuracy: 0.7361 - val_loss: 0.5387 - val_accuracy: 0.5669
#
# Epoch 00105: val_loss did not improve from 0.39488
# Epoch 106/300
#  - 2s - loss: 0.5224 - accuracy: 0.7428 - val_loss: 0.7803 - val_accuracy: 0.5699
#
# Epoch 00106: val_loss did not improve from 0.39488
# Epoch 107/300
#  - 2s - loss: 0.5163 - accuracy: 0.7444 - val_loss: 1.0338 - val_accuracy: 0.5619
#
# Epoch 00107: val_loss did not improve from 0.39488
# Epoch 108/300
#  - 2s - loss: 0.5187 - accuracy: 0.7444 - val_loss: 0.5623 - val_accuracy: 0.5749
#
# Epoch 00108: val_loss did not improve from 0.39488
# Epoch 109/300
#  - 2s - loss: 0.5110 - accuracy: 0.7478 - val_loss: 0.8835 - val_accuracy: 0.5589
#
# Epoch 00109: val_loss did not improve from 0.39488
# Epoch 110/300
#  - 2s - loss: 0.5213 - accuracy: 0.7428 - val_loss: 1.2121 - val_accuracy: 0.5958
#
# Epoch 00110: val_loss did not improve from 0.39488
# Epoch 111/300
#  - 2s - loss: 0.5184 - accuracy: 0.7364 - val_loss: 0.7155 - val_accuracy: 0.5858
#
# Epoch 00111: val_loss did not improve from 0.39488
# Epoch 112/300
#  - 2s - loss: 0.5065 - accuracy: 0.7611 - val_loss: 0.7243 - val_accuracy: 0.5988
#
# Epoch 00112: val_loss did not improve from 0.39488
# Epoch 113/300
#  - 2s - loss: 0.5062 - accuracy: 0.7544 - val_loss: 0.7046 - val_accuracy: 0.5848
#
# Epoch 00113: val_loss did not improve from 0.39488
# Epoch 114/300
#  - 2s - loss: 0.5020 - accuracy: 0.7514 - val_loss: 0.9077 - val_accuracy: 0.5848
#
# Epoch 00114: val_loss did not improve from 0.39488
# Epoch 115/300
#  - 2s - loss: 0.4971 - accuracy: 0.7647 - val_loss: 0.6248 - val_accuracy: 0.5828
#
# Epoch 00115: val_loss did not improve from 0.39488
# Epoch 116/300
#  - 2s - loss: 0.5002 - accuracy: 0.7581 - val_loss: 0.7217 - val_accuracy: 0.5689
#
# Epoch 00116: val_loss did not improve from 0.39488
# Epoch 117/300
#  - 2s - loss: 0.5016 - accuracy: 0.7541 - val_loss: 0.5280 - val_accuracy: 0.5958
#
# Epoch 00117: val_loss did not improve from 0.39488
# Epoch 118/300
#  - 2s - loss: 0.4952 - accuracy: 0.7594 - val_loss: 0.7454 - val_accuracy: 0.5689
#
# Epoch 00118: val_loss did not improve from 0.39488
# Epoch 119/300
#  - 2s - loss: 0.4923 - accuracy: 0.7531 - val_loss: 0.4441 - val_accuracy: 0.5968
#
# Epoch 00119: val_loss did not improve from 0.39488
# Epoch 120/300
#  - 2s - loss: 0.4945 - accuracy: 0.7531 - val_loss: 0.7285 - val_accuracy: 0.5848
#
# Epoch 00120: val_loss did not improve from 0.39488
# Epoch 121/300
#  - 2s - loss: 0.4861 - accuracy: 0.7694 - val_loss: 0.7967 - val_accuracy: 0.5898
#
# Epoch 00121: val_loss did not improve from 0.39488
# Epoch 122/300
#  - 2s - loss: 0.4978 - accuracy: 0.7524 - val_loss: 1.0990 - val_accuracy: 0.5868
#
# Epoch 00122: val_loss did not improve from 0.39488
# Epoch 123/300
#  - 2s - loss: 0.4815 - accuracy: 0.7764 - val_loss: 0.6860 - val_accuracy: 0.5788
#
# Epoch 00123: val_loss did not improve from 0.39488
# Epoch 124/300
#  - 2s - loss: 0.4819 - accuracy: 0.7700 - val_loss: 1.0108 - val_accuracy: 0.5699
#
# Epoch 00124: val_loss did not improve from 0.39488
# Epoch 125/300
#  - 2s - loss: 0.4788 - accuracy: 0.7667 - val_loss: 1.1473 - val_accuracy: 0.5848
#
# Epoch 00125: val_loss did not improve from 0.39488
# Epoch 126/300
#  - 2s - loss: 0.4790 - accuracy: 0.7727 - val_loss: 0.8516 - val_accuracy: 0.5699
#
# Epoch 00126: val_loss did not improve from 0.39488
# Epoch 127/300
#  - 2s - loss: 0.4811 - accuracy: 0.7744 - val_loss: 0.7212 - val_accuracy: 0.5589
#
# Epoch 00127: val_loss did not improve from 0.39488
# Epoch 128/300
#  - 2s - loss: 0.4809 - accuracy: 0.7717 - val_loss: 0.7619 - val_accuracy: 0.5988
#
# Epoch 00128: val_loss did not improve from 0.39488
# Epoch 129/300
#  - 2s - loss: 0.4857 - accuracy: 0.7671 - val_loss: 0.3140 - val_accuracy: 0.5768
#
# Epoch 00129: val_loss improved from 0.39488 to 0.31404, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 130/300
#  - 2s - loss: 0.4665 - accuracy: 0.7804 - val_loss: 1.0095 - val_accuracy: 0.5649
#
# Epoch 00130: val_loss did not improve from 0.31404
# Epoch 131/300
#  - 2s - loss: 0.4789 - accuracy: 0.7691 - val_loss: 0.4980 - val_accuracy: 0.5898
#
# Epoch 00131: val_loss did not improve from 0.31404
# Epoch 132/300
#  - 2s - loss: 0.4763 - accuracy: 0.7750 - val_loss: 0.5550 - val_accuracy: 0.5798
#
# Epoch 00132: val_loss did not improve from 0.31404
# Epoch 133/300
#  - 2s - loss: 0.4757 - accuracy: 0.7747 - val_loss: 0.7265 - val_accuracy: 0.5948
#
# Epoch 00133: val_loss did not improve from 0.31404
# Epoch 134/300
#  - 2s - loss: 0.4706 - accuracy: 0.7844 - val_loss: 0.7734 - val_accuracy: 0.5719
#
# Epoch 00134: val_loss did not improve from 0.31404
# Epoch 135/300
#  - 2s - loss: 0.4651 - accuracy: 0.7857 - val_loss: 0.6476 - val_accuracy: 0.5878
#
# Epoch 00135: val_loss did not improve from 0.31404
# Epoch 136/300
#  - 2s - loss: 0.4600 - accuracy: 0.7814 - val_loss: 0.7125 - val_accuracy: 0.5768
#
# Epoch 00136: val_loss did not improve from 0.31404
# Epoch 137/300
#  - 2s - loss: 0.4595 - accuracy: 0.7844 - val_loss: 1.4181 - val_accuracy: 0.6048
#
# Epoch 00137: val_loss did not improve from 0.31404
# Epoch 138/300
#  - 2s - loss: 0.4699 - accuracy: 0.7664 - val_loss: 0.7074 - val_accuracy: 0.5888
#
# Epoch 00138: val_loss did not improve from 0.31404
# Epoch 139/300
#  - 2s - loss: 0.4598 - accuracy: 0.7824 - val_loss: 0.7964 - val_accuracy: 0.5729
#
# Epoch 00139: val_loss did not improve from 0.31404
# Epoch 140/300
#  - 2s - loss: 0.4483 - accuracy: 0.7983 - val_loss: 0.9718 - val_accuracy: 0.5709
#
# Epoch 00140: val_loss did not improve from 0.31404
# Epoch 141/300
#  - 2s - loss: 0.4595 - accuracy: 0.7754 - val_loss: 0.6284 - val_accuracy: 0.5898
#
# Epoch 00141: val_loss did not improve from 0.31404
# Epoch 142/300
#  - 2s - loss: 0.4633 - accuracy: 0.7804 - val_loss: 0.4833 - val_accuracy: 0.5988
#
# Epoch 00142: val_loss did not improve from 0.31404
# Epoch 143/300
#  - 2s - loss: 0.4558 - accuracy: 0.7877 - val_loss: 0.8791 - val_accuracy: 0.5948
#
# Epoch 00143: val_loss did not improve from 0.31404
# Epoch 144/300
#  - 2s - loss: 0.4510 - accuracy: 0.7820 - val_loss: 0.5312 - val_accuracy: 0.5749
#
# Epoch 00144: val_loss did not improve from 0.31404
# Epoch 145/300
#  - 2s - loss: 0.4524 - accuracy: 0.7874 - val_loss: 0.6180 - val_accuracy: 0.6018
#
# Epoch 00145: val_loss did not improve from 0.31404
# Epoch 146/300
#  - 2s - loss: 0.4522 - accuracy: 0.7897 - val_loss: 0.7785 - val_accuracy: 0.5699
#
# Epoch 00146: val_loss did not improve from 0.31404
# Epoch 147/300
#  - 2s - loss: 0.4527 - accuracy: 0.7884 - val_loss: 1.2187 - val_accuracy: 0.5888
#
# Epoch 00147: val_loss did not improve from 0.31404
# Epoch 148/300
#  - 2s - loss: 0.4511 - accuracy: 0.7844 - val_loss: 0.8204 - val_accuracy: 0.6058
#
# Epoch 00148: val_loss did not improve from 0.31404
# Epoch 149/300
#  - 2s - loss: 0.4541 - accuracy: 0.7894 - val_loss: 0.8478 - val_accuracy: 0.5788
#
# Epoch 00149: val_loss did not improve from 0.31404
# Epoch 150/300
#  - 2s - loss: 0.4476 - accuracy: 0.7910 - val_loss: 0.9435 - val_accuracy: 0.5749
#
# Epoch 00150: val_loss did not improve from 0.31404
# Epoch 151/300
#  - 2s - loss: 0.4407 - accuracy: 0.7980 - val_loss: 1.1497 - val_accuracy: 0.5729
#
# Epoch 00151: val_loss did not improve from 0.31404
# Epoch 152/300
#  - 2s - loss: 0.4360 - accuracy: 0.7967 - val_loss: 0.8809 - val_accuracy: 0.5798
#
# Epoch 00152: val_loss did not improve from 0.31404
# Epoch 153/300
#  - 2s - loss: 0.4363 - accuracy: 0.8010 - val_loss: 0.4229 - val_accuracy: 0.6038
#
# Epoch 00153: val_loss did not improve from 0.31404
# Epoch 154/300
#  - 2s - loss: 0.4352 - accuracy: 0.8037 - val_loss: 1.3109 - val_accuracy: 0.5619
#
# Epoch 00154: val_loss did not improve from 0.31404
# Epoch 155/300
#  - 2s - loss: 0.4323 - accuracy: 0.7997 - val_loss: 1.0368 - val_accuracy: 0.5828
#
# Epoch 00155: val_loss did not improve from 0.31404
# Epoch 156/300
#  - 2s - loss: 0.4251 - accuracy: 0.8013 - val_loss: 0.9369 - val_accuracy: 0.5928
#
# Epoch 00156: val_loss did not improve from 0.31404
# Epoch 157/300
#  - 2s - loss: 0.4352 - accuracy: 0.7950 - val_loss: 0.7125 - val_accuracy: 0.5739
#
# Epoch 00157: val_loss did not improve from 0.31404
# Epoch 158/300
#  - 2s - loss: 0.4388 - accuracy: 0.8003 - val_loss: 0.8555 - val_accuracy: 0.5898
#
# Epoch 00158: val_loss did not improve from 0.31404
# Epoch 159/300
#  - 2s - loss: 0.4382 - accuracy: 0.8050 - val_loss: 0.4930 - val_accuracy: 0.5739
#
# Epoch 00159: val_loss did not improve from 0.31404
# Epoch 160/300
#  - 2s - loss: 0.4218 - accuracy: 0.8087 - val_loss: 1.1631 - val_accuracy: 0.5838
#
# Epoch 00160: val_loss did not improve from 0.31404
# Epoch 161/300
#  - 2s - loss: 0.4216 - accuracy: 0.8043 - val_loss: 0.8327 - val_accuracy: 0.5968
#
# Epoch 00161: val_loss did not improve from 0.31404
# Epoch 162/300
#  - 2s - loss: 0.4204 - accuracy: 0.8130 - val_loss: 0.3836 - val_accuracy: 0.5968
#
# Epoch 00162: val_loss did not improve from 0.31404
# Epoch 163/300
#  - 2s - loss: 0.4150 - accuracy: 0.8146 - val_loss: 0.7802 - val_accuracy: 0.5958
#
# Epoch 00163: val_loss did not improve from 0.31404
# Epoch 164/300
#  - 2s - loss: 0.4189 - accuracy: 0.8090 - val_loss: 1.1122 - val_accuracy: 0.5878
#
# Epoch 00164: val_loss did not improve from 0.31404
# Epoch 165/300
#  - 2s - loss: 0.4158 - accuracy: 0.8183 - val_loss: 0.4383 - val_accuracy: 0.5968
#
# Epoch 00165: val_loss did not improve from 0.31404
# Epoch 166/300
#  - 2s - loss: 0.4206 - accuracy: 0.8073 - val_loss: 0.3091 - val_accuracy: 0.5749
#
# Epoch 00166: val_loss improved from 0.31404 to 0.30913, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_min_pr_re2.h5
# Epoch 167/300
#  - 2s - loss: 0.4116 - accuracy: 0.8146 - val_loss: 1.2979 - val_accuracy: 0.5898
#
# Epoch 00167: val_loss did not improve from 0.30913
# Epoch 168/300
#  - 2s - loss: 0.4149 - accuracy: 0.8093 - val_loss: 1.1524 - val_accuracy: 0.5888
#
# Epoch 00168: val_loss did not improve from 0.30913
# Epoch 169/300
#  - 2s - loss: 0.4106 - accuracy: 0.8180 - val_loss: 0.8063 - val_accuracy: 0.5988
#
# Epoch 00169: val_loss did not improve from 0.30913
# Epoch 170/300
#  - 2s - loss: 0.4173 - accuracy: 0.8083 - val_loss: 0.6156 - val_accuracy: 0.6058
#
# Epoch 00170: val_loss did not improve from 0.30913
# Epoch 171/300
#  - 2s - loss: 0.4108 - accuracy: 0.8097 - val_loss: 0.4259 - val_accuracy: 0.5828
#
# Epoch 00171: val_loss did not improve from 0.30913
# Epoch 172/300
#  - 2s - loss: 0.4122 - accuracy: 0.8153 - val_loss: 0.9914 - val_accuracy: 0.5878
#
# Epoch 00172: val_loss did not improve from 0.30913
# Epoch 173/300
#  - 2s - loss: 0.4034 - accuracy: 0.8200 - val_loss: 0.8983 - val_accuracy: 0.5868
#
# Epoch 00173: val_loss did not improve from 0.30913
# Epoch 174/300
#  - 2s - loss: 0.4136 - accuracy: 0.8146 - val_loss: 0.7149 - val_accuracy: 0.5818
#
# Epoch 00174: val_loss did not improve from 0.30913
# Epoch 175/300
#  - 2s - loss: 0.4123 - accuracy: 0.8070 - val_loss: 0.7885 - val_accuracy: 0.5768
#
# Epoch 00175: val_loss did not improve from 0.30913
# Epoch 176/300
#  - 2s - loss: 0.4141 - accuracy: 0.8090 - val_loss: 0.8056 - val_accuracy: 0.5918
#
# Epoch 00176: val_loss did not improve from 0.30913
# Epoch 177/300
#  - 2s - loss: 0.3947 - accuracy: 0.8163 - val_loss: 0.6511 - val_accuracy: 0.5948
#
# Epoch 00177: val_loss did not improve from 0.30913
# Epoch 178/300
#  - 2s - loss: 0.4026 - accuracy: 0.8176 - val_loss: 0.5099 - val_accuracy: 0.5868
#
# Epoch 00178: val_loss did not improve from 0.30913
# Epoch 179/300
#  - 2s - loss: 0.3919 - accuracy: 0.8329 - val_loss: 0.9328 - val_accuracy: 0.5828
#
# Epoch 00179: val_loss did not improve from 0.30913
# Epoch 180/300
#  - 2s - loss: 0.3921 - accuracy: 0.8243 - val_loss: 0.9026 - val_accuracy: 0.5798
#
# Epoch 00180: val_loss did not improve from 0.30913
# Epoch 181/300
#  - 2s - loss: 0.3992 - accuracy: 0.8260 - val_loss: 1.2142 - val_accuracy: 0.5888
#
# Epoch 00181: val_loss did not improve from 0.30913
# Epoch 182/300
#  - 2s - loss: 0.3972 - accuracy: 0.8236 - val_loss: 0.7962 - val_accuracy: 0.5838
#
# Epoch 00182: val_loss did not improve from 0.30913
# Epoch 183/300
#  - 2s - loss: 0.3907 - accuracy: 0.8290 - val_loss: 1.3052 - val_accuracy: 0.5818
#
# Epoch 00183: val_loss did not improve from 0.30913
# Epoch 184/300
#  - 2s - loss: 0.3947 - accuracy: 0.8186 - val_loss: 1.0116 - val_accuracy: 0.5788
#
# Epoch 00184: val_loss did not improve from 0.30913
# Epoch 185/300
#  - 2s - loss: 0.3934 - accuracy: 0.8213 - val_loss: 1.0649 - val_accuracy: 0.5948
#
# Epoch 00185: val_loss did not improve from 0.30913
# Epoch 186/300
#  - 2s - loss: 0.3929 - accuracy: 0.8326 - val_loss: 0.7367 - val_accuracy: 0.5788
#
# Epoch 00186: val_loss did not improve from 0.30913
# Epoch 187/300
#  - 2s - loss: 0.3940 - accuracy: 0.8240 - val_loss: 1.1797 - val_accuracy: 0.5719
#
# Epoch 00187: val_loss did not improve from 0.30913
# Epoch 188/300
#  - 2s - loss: 0.3868 - accuracy: 0.8313 - val_loss: 0.6773 - val_accuracy: 0.5868
#
# Epoch 00188: val_loss did not improve from 0.30913
# Epoch 189/300
#  - 2s - loss: 0.3757 - accuracy: 0.8353 - val_loss: 1.4638 - val_accuracy: 0.5958
#
# Epoch 00189: val_loss did not improve from 0.30913
# Epoch 190/300
#  - 2s - loss: 0.3838 - accuracy: 0.8240 - val_loss: 0.4905 - val_accuracy: 0.5988
#
# Epoch 00190: val_loss did not improve from 0.30913
# Epoch 191/300
#  - 2s - loss: 0.3746 - accuracy: 0.8396 - val_loss: 0.4254 - val_accuracy: 0.6018
#
# Epoch 00191: val_loss did not improve from 0.30913
# Epoch 192/300
#  - 2s - loss: 0.3695 - accuracy: 0.8406 - val_loss: 0.9052 - val_accuracy: 0.5838
#
# Epoch 00192: val_loss did not improve from 0.30913
# Epoch 193/300
#  - 2s - loss: 0.3769 - accuracy: 0.8309 - val_loss: 0.7022 - val_accuracy: 0.5938
#
# Epoch 00193: val_loss did not improve from 0.30913
# Epoch 194/300
#  - 2s - loss: 0.3776 - accuracy: 0.8403 - val_loss: 0.9334 - val_accuracy: 0.5749
#
# Epoch 00194: val_loss did not improve from 0.30913
# Epoch 195/300
#  - 2s - loss: 0.3800 - accuracy: 0.8296 - val_loss: 0.7541 - val_accuracy: 0.5978
#
# Epoch 00195: val_loss did not improve from 0.30913
# Epoch 196/300
#  - 2s - loss: 0.3548 - accuracy: 0.8489 - val_loss: 0.6995 - val_accuracy: 0.6058
#
# Epoch 00196: val_loss did not improve from 0.30913
# Epoch 197/300
#  - 2s - loss: 0.3790 - accuracy: 0.8323 - val_loss: 0.5152 - val_accuracy: 0.5968
#
# Epoch 00197: val_loss did not improve from 0.30913
# Epoch 198/300
#  - 2s - loss: 0.3717 - accuracy: 0.8389 - val_loss: 1.0086 - val_accuracy: 0.5998
#
# Epoch 00198: val_loss did not improve from 0.30913
# Epoch 199/300
#  - 2s - loss: 0.3661 - accuracy: 0.8409 - val_loss: 0.7384 - val_accuracy: 0.5768
#
# Epoch 00199: val_loss did not improve from 0.30913
# Epoch 200/300
#  - 2s - loss: 0.3618 - accuracy: 0.8496 - val_loss: 1.0579 - val_accuracy: 0.5968
#
# Epoch 00200: val_loss did not improve from 0.30913
# Epoch 201/300
#  - 2s - loss: 0.3669 - accuracy: 0.8466 - val_loss: 0.5918 - val_accuracy: 0.5788
#
# Epoch 00201: val_loss did not improve from 0.30913
# Epoch 202/300
#  - 2s - loss: 0.3668 - accuracy: 0.8373 - val_loss: 0.8216 - val_accuracy: 0.5978
#
# Epoch 00202: val_loss did not improve from 0.30913
# Epoch 203/300
#  - 2s - loss: 0.3540 - accuracy: 0.8446 - val_loss: 1.2976 - val_accuracy: 0.5898
#
# Epoch 00203: val_loss did not improve from 0.30913
# Epoch 204/300
#  - 2s - loss: 0.3485 - accuracy: 0.8562 - val_loss: 1.0498 - val_accuracy: 0.5739
#
# Epoch 00204: val_loss did not improve from 0.30913
# Epoch 205/300
#  - 2s - loss: 0.3603 - accuracy: 0.8479 - val_loss: 0.9825 - val_accuracy: 0.5918
#
# Epoch 00205: val_loss did not improve from 0.30913
# Epoch 206/300
#  - 2s - loss: 0.3552 - accuracy: 0.8456 - val_loss: 0.6034 - val_accuracy: 0.5818
#
# Epoch 00206: val_loss did not improve from 0.30913

# %%
# model_name = "classifier_45_min_pr_re2.h5"  # <-- specifying model name
model = keras.models.load_model(ckpt_path + model_name)

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)

# thresh = 0.19
# threshold = [thresh]
print('threshold :', threshold)

acc_pr_bythr = []
for thresh in threshold:

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  print('precision :', precision_score(y_test, y_pred))
  print('recall :', recall_score(y_test, y_pred))
  print()

  print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # plt.show()  
  print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
    print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
    print('thresh :', thresh)
    
  # if len(threshold) == 1:
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(test_pr_list))
    plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
  # plt.show()

    plt.subplot(122)
    plt.plot(np.cumprod(pred_pr_list))
    plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])

print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(threshold, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
# Out:
# [[0.13271424 0.8672857 ]
#  [0.4993821  0.50061786]
#  [0.16144769 0.8385523 ]
#  [0.6920124  0.30798757]
#  [0.40607196 0.5939281 ]
#  [0.79099524 0.20900474]
#  [0.42303178 0.57696825]
#  [0.877458   0.12254199]
#  [0.2292777  0.7707223 ]
#  [0.83674717 0.16325283]]
# x_train_for_k.shape : (1002, 2)
# pr_train.shape : (1002, 1)
# -43.780922
# 1002 1002
# {0: [], 1: []}
# {0: [1.0015093, 1.0005815, 1.0112358, 1.0108912, 1.0177829, 1.0133405, 0.99886274, 0.9850253, 0.9650012, 1.0359783, 1.0280287, 1.0153972, 1.0142441, 0.9766896, 1.092995, 1.0180852, 1.0056812, 0.9882601, 0.99959344, 1.0860296, 0.99303067, 1.0380174, 1.0296496, 1.0211115, 1.0345049, 1.0031642, 0.97926736, 1.0110428, 0.98009694, 0.9392372, 0.9449992, 1.1119432, 0.98300475, 1.0472324, 1.0159234, 0.948119, 1.0207975, 1.0126865, 1.0199524, 0.99830467, 0.9719168, 0.990376, 0.99910927, 0.9856985, 1.0374557, 0.99626565, 0.9997985, 0.9850428, 1.0107235, 1.0361159, 0.9991396, 1.0630924, 0.99775034, 1.0513692, 1.0896556, 0.9779899, 0.985147, 1.0050505, 0.99909836, 0.9888693, 1.007481, 1.0192297, 1.0210885, 1.0502932, 1.019328, 0.99870586, 0.98987234, 1.046721, 1.0214471, 1.0443726, 1.0296476, 1.0377818, 1.0019435, 1.0441378, 0.99670625, 0.9352834, 1.0365375, 0.99352986, 1.018152, 0.99704814, 1.0188034, 1.0113592, 1.0168475, 0.9242969, 1.0076647, 1.0259365, 1.0306332, 1.0013717, 1.0586827, 0.99184066, 0.9979234, 1.0507333, 1.0162829, 1.0094247, 0.98180854, 1.0062723, 0.9764567, 0.98584163, 0.9972553, 0.99883825, 1.0206846, 0.9952534, 1.071381, 0.99119914, 0.98679423, 1.0199082, 0.9478451, 1.0637711, 1.0272771, 0.99704254, 1.021908, 1.0580806, 1.0409728, 1.0017694, 1.0273541, 0.9868606, 0.9951097, 0.9997188, 1.0100937, 1.0161667, 1.0221747, 0.99330163, 0.96205115, 0.9888942, 1.0090638, 1.0244404, 1.0323864, 1.0088484, 0.9541377, 1.0096807, 1.0169564, 1.0153258, 1.0953089, 1.0059125, 1.0277673, 1.0062833, 0.9714733, 1.0656997, 1.0132445, 0.98907137, 1.0565771, 1.0113647, 1.0119275, 1.0084524, 1.0662725, 1.014603, 0.9881541, 1.0124412, 1.0087646, 0.99593085, 0.9907995, 1.0920048, 1.0122299, 0.99569964, 0.989313, 1.0222744, 0.9935693, 1.0177401, 1.0087016, 0.99872565, 1.0211526, 0.9360124, 0.9969132, 1.0420998, 1.0158881, 0.9892402, 1.023639, 1.042311, 1.0061897, 1.0446713, 1.0397526, 1.09059, 0.9884928, 1.02041, 1.0225967, 1.0005746, 1.0330756, 1.0983063, 1.0087774, 0.9662367, 1.0183517, 1.0130216, 0.96820164, 0.98458165, 1.0505767, 1.0142164, 1.018645, 1.0141938, 1.0069776, 1.0352002, 1.0027127, 1.000693, 1.039766, 1.0408835, 0.9545123, 1.0259432, 0.9710967, 0.9830246, 1.0006127, 1.0337284, 0.95527977, 1.0141429, 0.9802923, 1.0001913, 1.003826, 0.94824487, 1.0153109, 0.9876585, 1.155677, 1.0028129, 1.0037045, 1.0065752, 1.0037993, 1.0569632, 0.9887952, 1.0391892, 0.9902119, 0.95012957, 1.0232881, 1.0667591, 0.9827441, 1.0489633, 1.0353475, 0.95455086, 1.016099, 1.015646, 1.0354635, 1.0052456, 1.0292193, 1.0204567, 1.0095394, 0.9738821, 1.094564, 1.030822, 1.069442, 0.99732435, 1.0232426, 1.0068346, 0.9953281, 1.0063615, 0.99828035, 1.0834212, 0.9864048, 1.1117879, 0.95434755, 0.986316, 1.018237, 0.9837777, 1.0035268, 0.9793935, 0.9889039, 0.9851009, 1.0380063, 1.0153109, 1.0460988, 1.1054811, 1.0065181, 1.0407039, 1.0230623, 1.0480529, 1.0264237, 1.0172447, 0.9978817, 0.99503684, 0.9368502, 1.0277877, 1.0051838, 1.0022933, 1.0095354, 1.0151513, 1.0083847, 1.0116621, 1.0473607, 1.0179533, 1.0085213, 0.9805199, 1.0189849, 1.0020075, 1.015647, 0.9369862, 0.99800074, 1.0128471, 1.0673522, 1.0502064, 1.0425316, 1.0503433, 1.0101213, 1.0013129, 1.017705, 1.034394, 1.0094583, 1.0631335, 1.0192808, 1.0109013, 0.99230915, 1.0009273, 0.99353456, 0.9991043, 1.0156862, 1.0062118, 0.9830636, 1.095938, 1.0004878, 1.0162575, 1.0050287, 1.0086337, 1.0103889, 1.0262053, 1.0268338, 1.0779175, 1.0000325, 0.99212676, 1.0228028, 0.8988932, 1.0408485, 1.0151509, 1.002587, 1.0184166, 1.0041506, 1.0706465, 1.0073614, 1.0026988, 0.99958414, 0.9904874, 0.963918, 0.9781842, 0.9587267, 1.0801309, 1.0101315, 1.045683, 1.0491828, 1.0488138, 0.9846112, 0.9893583, 1.0095216, 0.98402756, 1.0327384, 1.0233173, 1.0251057, 1.0501231, 1.0005542, 0.94625115, 1.0205457, 0.9908348, 0.968612, 0.99955213, 0.9890137, 0.98205113, 0.99435234, 1.0247289, 0.9839246, 1.0886569, 1.0031673, 0.97815466, 1.0126442, 0.9945665, 0.97554994, 0.9847423, 0.9993546, 1.0097054, 1.0028187, 1.025747, 1 ...
# 0 : win_ratio : 0.66 acc_pr : 780.57
# 1 : win_ratio : 0.51 acc_pr : 0.10
