# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
from sklearn.preprocessing import StandardScaler
from scipy.ndimage.filters import gaussian_filter1d
import warnings
# from scipy.ndimage.interpolation import shift

warnings.filterwarnings(action='ignore')
# %tensorflow_version 1.x
# %matplotlib inline


def min_max_scaler(x):
    scaled_x = (x - x.min()) / (x.max() - x.min())
    return scaled_x


def max_abs_scaler(x):
    scaled_x = x / abs(x).max()
    return scaled_x

  
def macd(df, short=12, long=26, signal=9):
    df['MACD'] = df['close'].ewm(span=short, min_periods=short - 1, adjust=False).mean() - \
                 df['close'].ewm(span=long, min_periods=long - 1, adjust=False).mean()
    df['MACD_Signal'] = df['MACD'].ewm(span=signal, min_periods=signal - 1, adjust=False).mean()
    df['MACD_OSC'] = df.MACD - df.MACD_Signal
    df['MACD_Zero'] = 0

    return

    
#           read reg ohlcv          #
file_path = 'ohlcv/'
file_list = os.listdir(file_path)

# %%
print((file_list[1]))
# Out:
# 2020-07-13 WAVES ohlcv.xlsx

# %%
input_data_length = 10
model_num = 108

short, long, signal = 105, 168, 32
sigma= 10
predict_size = 15
inverse = 0

# print(file_list)
# breakpoint

dataX, dataY = list(), list()
for i in range(len(file_list)):

  if i > 50:
    break

  file = file_list[i]
  print(file)

# file = file_list[0]
# print(file)
# breakpoint

  ohlcv_reg = pd.read_excel(file_path + file, index_col=0)

  # ohlcv_reg['osc_reg'] = ohlcv_reg['MACD_OSC'].shift(-predict_size)
  # print(ohlcv_reg.iloc[:, -5:].tail(15))
  # breakpoint

  #     X_data : idl 만큼의 close? (일단),    Y_data : reg
  #     실시간으로 reg의 형태가 machine learning으로는 고정되지 않기 때문에,
  #     먼저 고정을 시키고, deep learning을 이용해 실시간으로 고정된 regression 결과를 뽑아낼 수 있는지 확인한다.
  #     충분히 가능성 있다.     #

  #         reg_target = close인 경우 앞의 데이터가 산다.       #  close/ close_reg
  # if predict_size != 0:
  #   ohlcv_reg = ohlcv_reg.values[sum(ohlcv_reg.osc_reg.isna()):-predict_size, :] # 
  # else:
  #   ohlcv_reg = ohlcv_reg.values[sum(ohlcv_reg.osc_reg.isna()):, :] # 

  reg_target = ohlcv_reg.values[:-predict_size, [1]].astype(np.float32)
  reg_result = ohlcv_reg.shift(-predict_size).values[:-predict_size, [1]].astype(np.float32)
  # print(np.sum(np.isnan(reg_target)))
  # print(np.sum(np.isnan(reg_result)))
  # breakpoint
  # print(reg_target[-5:])
  # print(reg_result[-5:])
  plt.plot(reg_target, color='g')
  plt.plot(reg_result, color='r')
  plt.show()
  # breakpoint

  if len(reg_target) == 0:
    continue

  scaler_x = StandardScaler()
  scaler_y = StandardScaler()
  reg_target = scaler_x.fit_transform(reg_target)
  reg_result = scaler_y.fit_transform(reg_result)
  # reg_target = max_abs_scaler(reg_target)
  # reg_result = max_abs_scaler(reg_result)
  # print(reg_target, reg_result)
  # breakpoint

  # dataX, dataY = list(), list()
  for i in range(input_data_length, len(reg_target)):

    # group_x = reg_target[i - input_data_length: i]
    group_x = reg_target[i + 1 - input_data_length: i + 1]
    group_y = reg_result[i]
    # print(group_x[0])
    # quit()

    #   데이터 값에 결측치가 존재하는 경우 #
    if sum(sum(np.isnan(group_x))) > 0:
        continue

    if inverse == 1:
        dataX.append(group_x[::-1])  # dataX 리스트에 추가 [::-1]
    else:
        dataX.append(group_x)  # dataX 리스트에 추가 [::-1]
    dataY.append(group_y)

Made_X = np.array(dataX)
Made_Y = np.array(dataY)

# Made_X = np.array(reg_target)
# Made_Y = np.array(reg_result)
# print(Made_X.shape, Made_Y.shape)
# breakpoint  

# from sklearn.model_selection import train_test_split
# X_train, X_test, Y_train, Y_test = train_test_split(Made_X, Made_Y, test_size=0.4,
#                                                    shuffle=False)
# X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5,
#                                                    shuffle=False)

#     DATA CONTINOUS SPLIT    #
total_len = len(Made_X)
train_len = int(0.4 * total_len)
val_len = int(0.7 * total_len)

X_train = Made_X[:train_len]
X_val = Made_X[train_len:val_len]
X_test = Made_X[val_len:]
Y_train = Made_Y[:train_len]
Y_val = Made_Y[train_len:val_len]
Y_test = Made_Y[val_len:]
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)

print(Y_train.shape)
print(Y_test.shape)
print(Y_val.shape)
# breakpoint

row = X_train.shape[1]
col = X_train.shape[2]

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.layers import Dense, LSTM, Dropout, Input, Flatten
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
import tensorflow as tf

class Gelu(Activation):
    def __init__(self, activation, **kwargs):
        super(Gelu, self).__init__(activation, **kwargs)
        self.__name__='gelu'
        
def gelu(x):
    return 0.5 * x * (1 + tf.tanh(tf.sqrt(2 / np.pi) * (x + 0.044715 * tf.pow(x, 3))))

get_custom_objects().update({'gelu': Gelu(gelu)})


def FER_Model(input_shape=(row, col)):

    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    # net = layers.Dense(128)(visible)
    # # net = layers.LSTM(50, return_sequences=False)(net)
    # net = layers.Activation('gelu')(net)
    # # net = layers.LeakyReLU()(net)
    # net = layers.Dropout(0.3)(net)

    net = layers.Dense(32)(visible)
    # net = layers.LSTM(50, return_sequences=True)(visible)
    net = layers.Activation('gelu')(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.Dropout(0.3)(net)

    
    net = layers.Dense(64)(net)
    # net = layers.LSTM(50, return_sequences=True)(net)
    net = layers.Activation('gelu')(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.Dropout(0.3)(net)

  

    # net = layers.Dense(32)(net)
    # # net = layers.LSTM(64, return_sequences=False)(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.Dropout(0.2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.Activation('gelu')(net)
    # net = layers.LeakyReLU()(net)

    net = layers.Dense(1)(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    model.summary()

    return model

model = FER_Model()
# from keras.models import load_model
# model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_ohlc.hdf5' % (input_data_length, model_num))

# opt = RMSprop(lr=0.05, rho=0.9,epsilon=1e-10)
opt = Adam(lr=0.0001, decay=1e-6)
# opt = Adadelta(lr=1., rho=0.95, epsilon=1e-13)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse'])
  
    
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath = "model/ohlcv_offset_%s_%s.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=30)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 500
history = model.fit(X_train, Y_train,
                    epochs=num_epochs,
                    batch_size=64,
                    validation_data=(X_val, Y_val),
                    verbose=2,
                    callbacks=callbacks_list,
                    shuffle=False,
                    )
# Out:
# 2020-07-13 LOOM ohlcv.xlsx
# 2020-07-13 WAVES ohlcv.xlsx
# 2020-07-13 ITC ohlcv.xlsx
# 2020-07-13 TRUE ohlcv.xlsx
# 2020-07-13 LINK ohlcv.xlsx
# 2020-07-13 RNT ohlcv.xlsx
# 2020-07-13 ENJ ohlcv.xlsx
# 2020-07-13 PLX ohlcv.xlsx
# 2020-07-13 VET ohlcv.xlsx
# 2020-07-13 MTL ohlcv.xlsx
# 2020-07-13 INS ohlcv.xlsx
# 2020-07-13 IOST ohlcv.xlsx
# 2020-07-13 TMTG ohlcv.xlsx
# 2020-07-13 QKC ohlcv.xlsx
# 2020-07-13 BZNT ohlcv.xlsx
# 2020-07-13 HDAC ohlcv.xlsx
# 2020-07-13 NPXS ohlcv.xlsx
# 2020-07-13 LBA ohlcv.xlsx
# 2020-07-13 WET ohlcv.xlsx
# 2020-07-13 AMO ohlcv.xlsx
# 2020-07-13 BSV ohlcv.xlsx
# 2020-07-13 DAC ohlcv.xlsx
# 2020-07-13 ORBS ohlcv.xlsx
# 2020-07-13 VALOR ohlcv.xlsx
# 2020-07-13 CON ohlcv.xlsx
# 2020-07-13 ANKR ohlcv.xlsx
# 2020-07-13 MIX ohlcv.xlsx
# 2020-07-13 LAMB ohlcv.xlsx
# 2020-07-13 CRO ohlcv.xlsx
# 2020-07-13 FX ohlcv.xlsx
# 2020-07-13 CHR ohlcv.xlsx
# 2020-07-13 MXC ohlcv.xlsx
# 2020-07-13 MBL ohlcv.xlsx
# 2020-07-13 FAB ohlcv.xlsx
# 2020-07-13 OGO ohlcv.xlsx
# 2020-07-13 FCT ohlcv.xlsx
# 2020-07-13 DVP ohlcv.xlsx
# 2020-07-13 TRV ohlcv.xlsx
# 2020-07-13 FNB ohlcv.xlsx
# 2020-07-13 PCM ohlcv.xlsx
# 2020-07-13 DAD ohlcv.xlsx
# 2020-07-13 AOA ohlcv.xlsx
# 2020-07-13 XSR ohlcv.xlsx
# 2020-07-13 WOM ohlcv.xlsx
# 2020-07-13 SOC ohlcv.xlsx
# 2020-07-13 EM ohlcv.xlsx
# 2020-07-13 QBZ ohlcv.xlsx
# 2020-07-13 BOA ohlcv.xlsx
# 2020-07-13 FLETA ohlcv.xlsx
# 2020-07-13 SXP ohlcv.xlsx
# 2020-07-13 COS ohlcv.xlsx
# (13403, 10, 1)
# (10053, 10, 1)
# (10052, 10, 1)
# (13403, 1)
# (10053, 1)
# (10052, 1)
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 10, 1)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10, 32)            64
# _________________________________________________________________
# activation_7 (Activation)    (None, 10, 32)            0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10, 64)            2112
# _________________________________________________________________
# activation_8 (Activation)    (None, 10, 64)            0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                41024
# _________________________________________________________________
# activation_9 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 43,265
# Trainable params: 43,265
# Non-trainable params: 0
# _________________________________________________________________
# Train on 13403 samples, validate on 10052 samples
# Epoch 1/500
#  - 2s - loss: 0.4305 - mse: 0.4305 - val_loss: 0.5259 - val_mse: 0.5259
#
# Epoch 00001: val_loss improved from inf to 0.52592, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 2/500
#  - 1s - loss: 0.3958 - mse: 0.3958 - val_loss: 0.5142 - val_mse: 0.5142
#
# Epoch 00002: val_loss improved from 0.52592 to 0.51420, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 3/500
#  - 1s - loss: 0.3878 - mse: 0.3878 - val_loss: 0.5079 - val_mse: 0.5079
#
# Epoch 00003: val_loss improved from 0.51420 to 0.50791, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 4/500
#  - 1s - loss: 0.3821 - mse: 0.3821 - val_loss: 0.5039 - val_mse: 0.5039
#
# Epoch 00004: val_loss improved from 0.50791 to 0.50393, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 5/500
#  - 1s - loss: 0.3781 - mse: 0.3781 - val_loss: 0.5014 - val_mse: 0.5014
#
# Epoch 00005: val_loss improved from 0.50393 to 0.50139, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 6/500
#  - 1s - loss: 0.3753 - mse: 0.3753 - val_loss: 0.4998 - val_mse: 0.4998
#
# Epoch 00006: val_loss improved from 0.50139 to 0.49976, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 7/500
#  - 1s - loss: 0.3732 - mse: 0.3732 - val_loss: 0.4987 - val_mse: 0.4987
#
# Epoch 00007: val_loss improved from 0.49976 to 0.49866, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 8/500
#  - 1s - loss: 0.3716 - mse: 0.3716 - val_loss: 0.4979 - val_mse: 0.4979
#
# Epoch 00008: val_loss improved from 0.49866 to 0.49789, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 9/500
#  - 1s - loss: 0.3704 - mse: 0.3704 - val_loss: 0.4973 - val_mse: 0.4973
#
# Epoch 00009: val_loss improved from 0.49789 to 0.49729, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 10/500
#  - 1s - loss: 0.3694 - mse: 0.3694 - val_loss: 0.4968 - val_mse: 0.4968
#
# Epoch 00010: val_loss improved from 0.49729 to 0.49680, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 11/500
#  - 1s - loss: 0.3686 - mse: 0.3686 - val_loss: 0.4964 - val_mse: 0.4964
#
# Epoch 00011: val_loss improved from 0.49680 to 0.49639, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 12/500
#  - 1s - loss: 0.3679 - mse: 0.3679 - val_loss: 0.4960 - val_mse: 0.4960
#
# Epoch 00012: val_loss improved from 0.49639 to 0.49603, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 13/500
#  - 1s - loss: 0.3673 - mse: 0.3673 - val_loss: 0.4957 - val_mse: 0.4957
#
# Epoch 00013: val_loss improved from 0.49603 to 0.49571, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 14/500
#  - 1s - loss: 0.3668 - mse: 0.3668 - val_loss: 0.4954 - val_mse: 0.4954
#
# Epoch 00014: val_loss improved from 0.49571 to 0.49543, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 15/500
#  - 1s - loss: 0.3664 - mse: 0.3664 - val_loss: 0.4952 - val_mse: 0.4952
#
# Epoch 00015: val_loss improved from 0.49543 to 0.49517, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 16/500
#  - 1s - loss: 0.3660 - mse: 0.3660 - val_loss: 0.4949 - val_mse: 0.4949
#
# Epoch 00016: val_loss improved from 0.49517 to 0.49494, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 17/500
#  - 1s - loss: 0.3656 - mse: 0.3656 - val_loss: 0.4947 - val_mse: 0.4947
#
# Epoch 00017: val_loss improved from 0.49494 to 0.49473, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 18/500
#  - 1s - loss: 0.3653 - mse: 0.3653 - val_loss: 0.4945 - val_mse: 0.4945
#
# Epoch 00018: val_loss improved from 0.49473 to 0.49453, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 19/500
#  - 1s - loss: 0.3650 - mse: 0.3650 - val_loss: 0.4943 - val_mse: 0.4943
#
# Epoch 00019: val_loss improved from 0.49453 to 0.49434, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 20/500
#  - 1s - loss: 0.3647 - mse: 0.3647 - val_loss: 0.4942 - val_mse: 0.4942
#
# Epoch 00020: val_loss improved from 0.49434 to 0.49417, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 21/500
#  - 1s - loss: 0.3644 - mse: 0.3644 - val_loss: 0.4940 - val_mse: 0.4940
#
# Epoch 00021: val_loss improved from 0.49417 to 0.49401, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 22/500
#  - 1s - loss: 0.3642 - mse: 0.3642 - val_loss: 0.4938 - val_mse: 0.4938
#
# Epoch 00022: val_loss improved from 0.49401 to 0.49385, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 23/500
#  - 1s - loss: 0.3640 - mse: 0.3640 - val_loss: 0.4937 - val_mse: 0.4937
#
# Epoch 00023: val_loss improved from 0.49385 to 0.49369, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 24/500
#  - 1s - loss: 0.3638 - mse: 0.3638 - val_loss: 0.4935 - val_mse: 0.4935
#
# Epoch 00024: val_loss improved from 0.49369 to 0.49354, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 25/500
#  - 1s - loss: 0.3636 - mse: 0.3636 - val_loss: 0.4934 - val_mse: 0.4934
#
# Epoch 00025: val_loss improved from 0.49354 to 0.49339, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 26/500
#  - 1s - loss: 0.3634 - mse: 0.3634 - val_loss: 0.4932 - val_mse: 0.4932
#
# Epoch 00026: val_loss improved from 0.49339 to 0.49324, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 27/500
#  - 1s - loss: 0.3633 - mse: 0.3633 - val_loss: 0.4931 - val_mse: 0.4931
#
# Epoch 00027: val_loss improved from 0.49324 to 0.49310, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 28/500
#  - 1s - loss: 0.3631 - mse: 0.3631 - val_loss: 0.4930 - val_mse: 0.4930
#
# Epoch 00028: val_loss improved from 0.49310 to 0.49295, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 29/500
#  - 1s - loss: 0.3630 - mse: 0.3630 - val_loss: 0.4928 - val_mse: 0.4928
#
# Epoch 00029: val_loss improved from 0.49295 to 0.49281, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 30/500
#  - 1s - loss: 0.3628 - mse: 0.3628 - val_loss: 0.4927 - val_mse: 0.4927
#
# Epoch 00030: val_loss improved from 0.49281 to 0.49266, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 31/500
#  - 1s - loss: 0.3627 - mse: 0.3627 - val_loss: 0.4925 - val_mse: 0.4925
#
# Epoch 00031: val_loss improved from 0.49266 to 0.49252, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 32/500
#  - 1s - loss: 0.3626 - mse: 0.3626 - val_loss: 0.4924 - val_mse: 0.4924
#
# Epoch 00032: val_loss improved from 0.49252 to 0.49237, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 33/500
#  - 1s - loss: 0.3625 - mse: 0.3625 - val_loss: 0.4922 - val_mse: 0.4922
#
# Epoch 00033: val_loss improved from 0.49237 to 0.49223, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 34/500
#  - 1s - loss: 0.3624 - mse: 0.3624 - val_loss: 0.4921 - val_mse: 0.4921
#
# Epoch 00034: val_loss improved from 0.49223 to 0.49208, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 35/500
#  - 1s - loss: 0.3622 - mse: 0.3622 - val_loss: 0.4919 - val_mse: 0.4919
#
# Epoch 00035: val_loss improved from 0.49208 to 0.49194, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 36/500
#  - 1s - loss: 0.3621 - mse: 0.3621 - val_loss: 0.4918 - val_mse: 0.4918
#
# Epoch 00036: val_loss improved from 0.49194 to 0.49180, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 37/500
#  - 1s - loss: 0.3620 - mse: 0.3620 - val_loss: 0.4917 - val_mse: 0.4917
#
# Epoch 00037: val_loss improved from 0.49180 to 0.49166, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 38/500
#  - 1s - loss: 0.3619 - mse: 0.3619 - val_loss: 0.4915 - val_mse: 0.4915
#
# Epoch 00038: val_loss improved from 0.49166 to 0.49153, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 39/500
#  - 1s - loss: 0.3618 - mse: 0.3618 - val_loss: 0.4914 - val_mse: 0.4914
#
# Epoch 00039: val_loss improved from 0.49153 to 0.49139, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 40/500
#  - 1s - loss: 0.3618 - mse: 0.3618 - val_loss: 0.4913 - val_mse: 0.4913
#
# Epoch 00040: val_loss improved from 0.49139 to 0.49126, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 41/500
#  - 1s - loss: 0.3617 - mse: 0.3617 - val_loss: 0.4911 - val_mse: 0.4911
#
# Epoch 00041: val_loss improved from 0.49126 to 0.49113, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 42/500
#  - 1s - loss: 0.3616 - mse: 0.3616 - val_loss: 0.4910 - val_mse: 0.4910
#
# Epoch 00042: val_loss improved from 0.49113 to 0.49100, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 43/500
#  - 1s - loss: 0.3615 - mse: 0.3615 - val_loss: 0.4909 - val_mse: 0.4909
#
# Epoch 00043: val_loss improved from 0.49100 to 0.49087, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 44/500
#  - 1s - loss: 0.3614 - mse: 0.3614 - val_loss: 0.4907 - val_mse: 0.4907
#
# Epoch 00044: val_loss improved from 0.49087 to 0.49074, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 45/500
#  - 1s - loss: 0.3613 - mse: 0.3613 - val_loss: 0.4906 - val_mse: 0.4906
#
# Epoch 00045: val_loss improved from 0.49074 to 0.49062, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 46/500
#  - 1s - loss: 0.3613 - mse: 0.3613 - val_loss: 0.4905 - val_mse: 0.4905
#
# Epoch 00046: val_loss improved from 0.49062 to 0.49050, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 47/500
#  - 1s - loss: 0.3612 - mse: 0.3612 - val_loss: 0.4904 - val_mse: 0.4904
#
# Epoch 00047: val_loss improved from 0.49050 to 0.49037, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 48/500
#  - 1s - loss: 0.3611 - mse: 0.3611 - val_loss: 0.4903 - val_mse: 0.4903
#
# Epoch 00048: val_loss improved from 0.49037 to 0.49025, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 49/500
#  - 1s - loss: 0.3610 - mse: 0.3610 - val_loss: 0.4901 - val_mse: 0.4901
#
# Epoch 00049: val_loss improved from 0.49025 to 0.49014, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 50/500
#  - 1s - loss: 0.3610 - mse: 0.3610 - val_loss: 0.4900 - val_mse: 0.4900
#
# Epoch 00050: val_loss improved from 0.49014 to 0.49002, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 51/500
#  - 1s - loss: 0.3609 - mse: 0.3609 - val_loss: 0.4899 - val_mse: 0.4899
#
# Epoch 00051: val_loss improved from 0.49002 to 0.48991, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 52/500
#  - 1s - loss: 0.3608 - mse: 0.3608 - val_loss: 0.4898 - val_mse: 0.4898
#
# Epoch 00052: val_loss improved from 0.48991 to 0.48979, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 53/500
#  - 1s - loss: 0.3607 - mse: 0.3607 - val_loss: 0.4897 - val_mse: 0.4897
#
# Epoch 00053: val_loss improved from 0.48979 to 0.48968, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 54/500
#  - 1s - loss: 0.3607 - mse: 0.3607 - val_loss: 0.4896 - val_mse: 0.4896
#
# Epoch 00054: val_loss improved from 0.48968 to 0.48957, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 55/500
#  - 1s - loss: 0.3606 - mse: 0.3606 - val_loss: 0.4895 - val_mse: 0.4895
#
# Epoch 00055: val_loss improved from 0.48957 to 0.48946, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 56/500
#  - 1s - loss: 0.3605 - mse: 0.3605 - val_loss: 0.4894 - val_mse: 0.4894
#
# Epoch 00056: val_loss improved from 0.48946 to 0.48935, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 57/500
#  - 1s - loss: 0.3605 - mse: 0.3605 - val_loss: 0.4892 - val_mse: 0.4892
#
# Epoch 00057: val_loss improved from 0.48935 to 0.48924, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 58/500
#  - 1s - loss: 0.3604 - mse: 0.3604 - val_loss: 0.4891 - val_mse: 0.4891
#
# Epoch 00058: val_loss improved from 0.48924 to 0.48914, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 59/500
#  - 1s - loss: 0.3604 - mse: 0.3604 - val_loss: 0.4890 - val_mse: 0.4890
#
# Epoch 00059: val_loss improved from 0.48914 to 0.48903, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 60/500
#  - 1s - loss: 0.3603 - mse: 0.3603 - val_loss: 0.4889 - val_mse: 0.4889
#
# Epoch 00060: val_loss improved from 0.48903 to 0.48892, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 61/500
#  - 1s - loss: 0.3602 - mse: 0.3602 - val_loss: 0.4888 - val_mse: 0.4888
#
# Epoch 00061: val_loss improved from 0.48892 to 0.48882, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 62/500
#  - 1s - loss: 0.3602 - mse: 0.3602 - val_loss: 0.4887 - val_mse: 0.4887
#
# Epoch 00062: val_loss improved from 0.48882 to 0.48872, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 63/500
#  - 1s - loss: 0.3601 - mse: 0.3601 - val_loss: 0.4886 - val_mse: 0.4886
#
# Epoch 00063: val_loss improved from 0.48872 to 0.48861, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 64/500
#  - 1s - loss: 0.3601 - mse: 0.3601 - val_loss: 0.4885 - val_mse: 0.4885
#
# Epoch 00064: val_loss improved from 0.48861 to 0.48851, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 65/500
#  - 1s - loss: 0.3600 - mse: 0.3600 - val_loss: 0.4884 - val_mse: 0.4884
#
# Epoch 00065: val_loss improved from 0.48851 to 0.48841, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 66/500
#  - 1s - loss: 0.3599 - mse: 0.3599 - val_loss: 0.4883 - val_mse: 0.4883
#
# Epoch 00066: val_loss improved from 0.48841 to 0.48831, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 67/500
#  - 1s - loss: 0.3599 - mse: 0.3599 - val_loss: 0.4882 - val_mse: 0.4882
#
# Epoch 00067: val_loss improved from 0.48831 to 0.48821, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 68/500
#  - 1s - loss: 0.3598 - mse: 0.3598 - val_loss: 0.4881 - val_mse: 0.4881
#
# Epoch 00068: val_loss improved from 0.48821 to 0.48811, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 69/500
#  - 1s - loss: 0.3598 - mse: 0.3598 - val_loss: 0.4880 - val_mse: 0.4880
#
# Epoch 00069: val_loss improved from 0.48811 to 0.48802, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 70/500
#  - 1s - loss: 0.3597 - mse: 0.3597 - val_loss: 0.4879 - val_mse: 0.4879
#
# Epoch 00070: val_loss improved from 0.48802 to 0.48792, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 71/500
#  - 1s - loss: 0.3597 - mse: 0.3597 - val_loss: 0.4878 - val_mse: 0.4878
#
# Epoch 00071: val_loss improved from 0.48792 to 0.48783, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 72/500
#  - 1s - loss: 0.3596 - mse: 0.3596 - val_loss: 0.4877 - val_mse: 0.4877
#
# Epoch 00072: val_loss improved from 0.48783 to 0.48774, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 73/500
#  - 1s - loss: 0.3596 - mse: 0.3596 - val_loss: 0.4876 - val_mse: 0.4876
#
# Epoch 00073: val_loss improved from 0.48774 to 0.48765, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 74/500
#  - 1s - loss: 0.3595 - mse: 0.3595 - val_loss: 0.4876 - val_mse: 0.4876
#
# Epoch 00074: val_loss improved from 0.48765 to 0.48756, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 75/500
#  - 1s - loss: 0.3595 - mse: 0.3595 - val_loss: 0.4875 - val_mse: 0.4875
#
# Epoch 00075: val_loss improved from 0.48756 to 0.48747, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 76/500
#  - 1s - loss: 0.3594 - mse: 0.3594 - val_loss: 0.4874 - val_mse: 0.4874
#
# Epoch 00076: val_loss improved from 0.48747 to 0.48738, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 77/500
#  - 1s - loss: 0.3594 - mse: 0.3594 - val_loss: 0.4873 - val_mse: 0.4873
#
# Epoch 00077: val_loss improved from 0.48738 to 0.48730, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 78/500
#  - 1s - loss: 0.3593 - mse: 0.3593 - val_loss: 0.4872 - val_mse: 0.4872
#
# Epoch 00078: val_loss improved from 0.48730 to 0.48721, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 79/500
#  - 1s - loss: 0.3593 - mse: 0.3593 - val_loss: 0.4871 - val_mse: 0.4871
#
# Epoch 00079: val_loss improved from 0.48721 to 0.48713, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 80/500
#  - 1s - loss: 0.3592 - mse: 0.3592 - val_loss: 0.4870 - val_mse: 0.4870
#
# Epoch 00080: val_loss improved from 0.48713 to 0.48705, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 81/500
#  - 1s - loss: 0.3592 - mse: 0.3592 - val_loss: 0.4870 - val_mse: 0.4870
#
# Epoch 00081: val_loss improved from 0.48705 to 0.48697, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 82/500
#  - 1s - loss: 0.3591 - mse: 0.3591 - val_loss: 0.4869 - val_mse: 0.4869
#
# Epoch 00082: val_loss improved from 0.48697 to 0.48689, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 83/500
#  - 1s - loss: 0.3591 - mse: 0.3591 - val_loss: 0.4868 - val_mse: 0.4868
#
# Epoch 00083: val_loss improved from 0.48689 to 0.48681, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 84/500
#  - 1s - loss: 0.3590 - mse: 0.3590 - val_loss: 0.4867 - val_mse: 0.4867
#
# Epoch 00084: val_loss improved from 0.48681 to 0.48674, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 85/500
#  - 1s - loss: 0.3590 - mse: 0.3590 - val_loss: 0.4867 - val_mse: 0.4867
#
# Epoch 00085: val_loss improved from 0.48674 to 0.48666, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 86/500
#  - 1s - loss: 0.3589 - mse: 0.3589 - val_loss: 0.4866 - val_mse: 0.4866
#
# Epoch 00086: val_loss improved from 0.48666 to 0.48659, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 87/500
#  - 1s - loss: 0.3589 - mse: 0.3589 - val_loss: 0.4865 - val_mse: 0.4865
#
# Epoch 00087: val_loss improved from 0.48659 to 0.48651, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 88/500
#  - 1s - loss: 0.3589 - mse: 0.3589 - val_loss: 0.4864 - val_mse: 0.4864
#
# Epoch 00088: val_loss improved from 0.48651 to 0.48644, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 89/500
#  - 1s - loss: 0.3588 - mse: 0.3588 - val_loss: 0.4864 - val_mse: 0.4864
#
# Epoch 00089: val_loss improved from 0.48644 to 0.48637, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 90/500
#  - 1s - loss: 0.3588 - mse: 0.3588 - val_loss: 0.4863 - val_mse: 0.4863
#
# Epoch 00090: val_loss improved from 0.48637 to 0.48629, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 91/500
#  - 1s - loss: 0.3587 - mse: 0.3587 - val_loss: 0.4862 - val_mse: 0.4862
#
# Epoch 00091: val_loss improved from 0.48629 to 0.48622, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 92/500
#  - 1s - loss: 0.3587 - mse: 0.3587 - val_loss: 0.4862 - val_mse: 0.4862
#
# Epoch 00092: val_loss improved from 0.48622 to 0.48615, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 93/500
#  - 1s - loss: 0.3586 - mse: 0.3586 - val_loss: 0.4861 - val_mse: 0.4861
#
# Epoch 00093: val_loss improved from 0.48615 to 0.48608, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 94/500
#  - 1s - loss: 0.3586 - mse: 0.3586 - val_loss: 0.4860 - val_mse: 0.4860
#
# Epoch 00094: val_loss improved from 0.48608 to 0.48601, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 95/500
#  - 1s - loss: 0.3586 - mse: 0.3586 - val_loss: 0.4859 - val_mse: 0.4859
#
# Epoch 00095: val_loss improved from 0.48601 to 0.48594, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 96/500
#  - 1s - loss: 0.3585 - mse: 0.3585 - val_loss: 0.4859 - val_mse: 0.4859
#
# Epoch 00096: val_loss improved from 0.48594 to 0.48588, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 97/500
#  - 1s - loss: 0.3585 - mse: 0.3585 - val_loss: 0.4858 - val_mse: 0.4858
#
# Epoch 00097: val_loss improved from 0.48588 to 0.48581, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 98/500
#  - 1s - loss: 0.3584 - mse: 0.3584 - val_loss: 0.4857 - val_mse: 0.4857
#
# Epoch 00098: val_loss improved from 0.48581 to 0.48574, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 99/500
#  - 1s - loss: 0.3584 - mse: 0.3584 - val_loss: 0.4857 - val_mse: 0.4857
#
# Epoch 00099: val_loss improved from 0.48574 to 0.48567, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 100/500
#  - 1s - loss: 0.3583 - mse: 0.3583 - val_loss: 0.4856 - val_mse: 0.4856
#
# Epoch 00100: val_loss improved from 0.48567 to 0.48561, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 101/500
#  - 1s - loss: 0.3583 - mse: 0.3583 - val_loss: 0.4855 - val_mse: 0.4855
#
# Epoch 00101: val_loss improved from 0.48561 to 0.48554, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 102/500
#  - 1s - loss: 0.3583 - mse: 0.3583 - val_loss: 0.4855 - val_mse: 0.4855
#
# Epoch 00102: val_loss improved from 0.48554 to 0.48548, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 103/500
#  - 1s - loss: 0.3582 - mse: 0.3582 - val_loss: 0.4854 - val_mse: 0.4854
#
# Epoch 00103: val_loss improved from 0.48548 to 0.48541, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 104/500
#  - 1s - loss: 0.3582 - mse: 0.3582 - val_loss: 0.4853 - val_mse: 0.4853
#
# Epoch 00104: val_loss improved from 0.48541 to 0.48535, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 105/500
#  - 1s - loss: 0.3582 - mse: 0.3582 - val_loss: 0.4853 - val_mse: 0.4853
#
# Epoch 00105: val_loss improved from 0.48535 to 0.48528, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 106/500
#  - 1s - loss: 0.3581 - mse: 0.3581 - val_loss: 0.4852 - val_mse: 0.4852
#
# Epoch 00106: val_loss improved from 0.48528 to 0.48522, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 107/500
#  - 1s - loss: 0.3581 - mse: 0.3581 - val_loss: 0.4852 - val_mse: 0.4852
#
# Epoch 00107: val_loss improved from 0.48522 to 0.48515, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 108/500
#  - 1s - loss: 0.3580 - mse: 0.3580 - val_loss: 0.4851 - val_mse: 0.4851
#
# Epoch 00108: val_loss improved from 0.48515 to 0.48509, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 109/500
#  - 1s - loss: 0.3580 - mse: 0.3580 - val_loss: 0.4850 - val_mse: 0.4850
#
# Epoch 00109: val_loss improved from 0.48509 to 0.48502, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 110/500
#  - 1s - loss: 0.3580 - mse: 0.3580 - val_loss: 0.4850 - val_mse: 0.4850
#
# Epoch 00110: val_loss improved from 0.48502 to 0.48496, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 111/500
#  - 1s - loss: 0.3579 - mse: 0.3579 - val_loss: 0.4849 - val_mse: 0.4849
#
# Epoch 00111: val_loss improved from 0.48496 to 0.48489, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 112/500
#  - 1s - loss: 0.3579 - mse: 0.3579 - val_loss: 0.4848 - val_mse: 0.4848
#
# Epoch 00112: val_loss improved from 0.48489 to 0.48483, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 113/500
#  - 1s - loss: 0.3579 - mse: 0.3579 - val_loss: 0.4848 - val_mse: 0.4848
#
# Epoch 00113: val_loss improved from 0.48483 to 0.48477, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 114/500
#  - 1s - loss: 0.3578 - mse: 0.3578 - val_loss: 0.4847 - val_mse: 0.4847
#
# Epoch 00114: val_loss improved from 0.48477 to 0.48470, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 115/500
#  - 1s - loss: 0.3578 - mse: 0.3578 - val_loss: 0.4846 - val_mse: 0.4846
#
# Epoch 00115: val_loss improved from 0.48470 to 0.48464, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 116/500
#  - 1s - loss: 0.3578 - mse: 0.3578 - val_loss: 0.4846 - val_mse: 0.4846
#
# Epoch 00116: val_loss improved from 0.48464 to 0.48458, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 117/500
#  - 1s - loss: 0.3577 - mse: 0.3577 - val_loss: 0.4845 - val_mse: 0.4845
#
# Epoch 00117: val_loss improved from 0.48458 to 0.48452, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 118/500
#  - 1s - loss: 0.3577 - mse: 0.3577 - val_loss: 0.4845 - val_mse: 0.4845
#
# Epoch 00118: val_loss improved from 0.48452 to 0.48446, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 119/500
#  - 1s - loss: 0.3577 - mse: 0.3577 - val_loss: 0.4844 - val_mse: 0.4844
#
# Epoch 00119: val_loss improved from 0.48446 to 0.48440, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 120/500
#  - 1s - loss: 0.3576 - mse: 0.3576 - val_loss: 0.4843 - val_mse: 0.4843
#
# Epoch 00120: val_loss improved from 0.48440 to 0.48434, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 121/500
#  - 1s - loss: 0.3576 - mse: 0.3576 - val_loss: 0.4843 - val_mse: 0.4843
#
# Epoch 00121: val_loss improved from 0.48434 to 0.48428, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 122/500
#  - 1s - loss: 0.3576 - mse: 0.3576 - val_loss: 0.4842 - val_mse: 0.4842
#
# Epoch 00122: val_loss improved from 0.48428 to 0.48423, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 123/500
#  - 1s - loss: 0.3575 - mse: 0.3575 - val_loss: 0.4842 - val_mse: 0.4842
#
# Epoch 00123: val_loss improved from 0.48423 to 0.48417, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 124/500
#  - 1s - loss: 0.3575 - mse: 0.3575 - val_loss: 0.4841 - val_mse: 0.4841
#
# Epoch 00124: val_loss improved from 0.48417 to 0.48412, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 125/500
#  - 1s - loss: 0.3575 - mse: 0.3575 - val_loss: 0.4841 - val_mse: 0.4841
#
# Epoch 00125: val_loss improved from 0.48412 to 0.48406, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 126/500
#  - 1s - loss: 0.3574 - mse: 0.3574 - val_loss: 0.4840 - val_mse: 0.4840
#
# Epoch 00126: val_loss improved from 0.48406 to 0.48401, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 127/500
#  - 1s - loss: 0.3574 - mse: 0.3574 - val_loss: 0.4840 - val_mse: 0.4840
#
# Epoch 00127: val_loss improved from 0.48401 to 0.48395, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 128/500
#  - 1s - loss: 0.3574 - mse: 0.3574 - val_loss: 0.4839 - val_mse: 0.4839
#
# Epoch 00128: val_loss improved from 0.48395 to 0.48390, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 129/500
#  - 1s - loss: 0.3573 - mse: 0.3573 - val_loss: 0.4838 - val_mse: 0.4838
#
# Epoch 00129: val_loss improved from 0.48390 to 0.48385, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 130/500
#  - 1s - loss: 0.3573 - mse: 0.3573 - val_loss: 0.4838 - val_mse: 0.4838
#
# Epoch 00130: val_loss improved from 0.48385 to 0.48379, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 131/500
#  - 1s - loss: 0.3573 - mse: 0.3573 - val_loss: 0.4837 - val_mse: 0.4837
#
# Epoch 00131: val_loss improved from 0.48379 to 0.48374, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 132/500
#  - 1s - loss: 0.3573 - mse: 0.3573 - val_loss: 0.4837 - val_mse: 0.4837
#
# Epoch 00132: val_loss improved from 0.48374 to 0.48369, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 133/500
#  - 1s - loss: 0.3572 - mse: 0.3572 - val_loss: 0.4836 - val_mse: 0.4836
#
# Epoch 00133: val_loss improved from 0.48369 to 0.48364, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 134/500
#  - 1s - loss: 0.3572 - mse: 0.3572 - val_loss: 0.4836 - val_mse: 0.4836
#
# Epoch 00134: val_loss improved from 0.48364 to 0.48359, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 135/500
#  - 1s - loss: 0.3572 - mse: 0.3572 - val_loss: 0.4835 - val_mse: 0.4835
#
# Epoch 00135: val_loss improved from 0.48359 to 0.48354, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 136/500
#  - 1s - loss: 0.3571 - mse: 0.3571 - val_loss: 0.4835 - val_mse: 0.4835
#
# Epoch 00136: val_loss improved from 0.48354 to 0.48348, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 137/500
#  - 1s - loss: 0.3571 - mse: 0.3571 - val_loss: 0.4834 - val_mse: 0.4834
#
# Epoch 00137: val_loss improved from 0.48348 to 0.48343, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 138/500
#  - 1s - loss: 0.3571 - mse: 0.3571 - val_loss: 0.4834 - val_mse: 0.4834
#
# Epoch 00138: val_loss improved from 0.48343 to 0.48338, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 139/500
#  - 1s - loss: 0.3571 - mse: 0.3571 - val_loss: 0.4833 - val_mse: 0.4833
#
# Epoch 00139: val_loss improved from 0.48338 to 0.48333, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 140/500
#  - 1s - loss: 0.3570 - mse: 0.3570 - val_loss: 0.4833 - val_mse: 0.4833
#
# Epoch 00140: val_loss improved from 0.48333 to 0.48328, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 141/500
#  - 1s - loss: 0.3570 - mse: 0.3570 - val_loss: 0.4832 - val_mse: 0.4832
#
# Epoch 00141: val_loss improved from 0.48328 to 0.48323, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 142/500
#  - 1s - loss: 0.3570 - mse: 0.3570 - val_loss: 0.4832 - val_mse: 0.4832
#
# Epoch 00142: val_loss improved from 0.48323 to 0.48318, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 143/500
#  - 1s - loss: 0.3569 - mse: 0.3569 - val_loss: 0.4831 - val_mse: 0.4831
#
# Epoch 00143: val_loss improved from 0.48318 to 0.48313, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 144/500
#  - 1s - loss: 0.3569 - mse: 0.3569 - val_loss: 0.4831 - val_mse: 0.4831
#
# Epoch 00144: val_loss improved from 0.48313 to 0.48307, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 145/500
#  - 1s - loss: 0.3569 - mse: 0.3569 - val_loss: 0.4830 - val_mse: 0.4830
#
# Epoch 00145: val_loss improved from 0.48307 to 0.48302, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 146/500
#  - 1s - loss: 0.3569 - mse: 0.3569 - val_loss: 0.4830 - val_mse: 0.4830
#
# Epoch 00146: val_loss improved from 0.48302 to 0.48297, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 147/500
#  - 1s - loss: 0.3568 - mse: 0.3568 - val_loss: 0.4829 - val_mse: 0.4829
#
# Epoch 00147: val_loss improved from 0.48297 to 0.48292, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 148/500
#  - 1s - loss: 0.3568 - mse: 0.3568 - val_loss: 0.4829 - val_mse: 0.4829
#
# Epoch 00148: val_loss improved from 0.48292 to 0.48287, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 149/500
#  - 1s - loss: 0.3568 - mse: 0.3568 - val_loss: 0.4828 - val_mse: 0.4828
#
# Epoch 00149: val_loss improved from 0.48287 to 0.48282, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 150/500
#  - 1s - loss: 0.3568 - mse: 0.3568 - val_loss: 0.4828 - val_mse: 0.4828
#
# Epoch 00150: val_loss improved from 0.48282 to 0.48277, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 151/500
#  - 1s - loss: 0.3567 - mse: 0.3567 - val_loss: 0.4827 - val_mse: 0.4827
#
# Epoch 00151: val_loss improved from 0.48277 to 0.48271, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 152/500
#  - 1s - loss: 0.3567 - mse: 0.3567 - val_loss: 0.4827 - val_mse: 0.4827
#
# Epoch 00152: val_loss improved from 0.48271 to 0.48266, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 153/500
#  - 1s - loss: 0.3567 - mse: 0.3567 - val_loss: 0.4826 - val_mse: 0.4826
#
# Epoch 00153: val_loss improved from 0.48266 to 0.48261, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 154/500
#  - 1s - loss: 0.3567 - mse: 0.3567 - val_loss: 0.4826 - val_mse: 0.4826
#
# Epoch 00154: val_loss improved from 0.48261 to 0.48256, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 155/500
#  - 1s - loss: 0.3566 - mse: 0.3566 - val_loss: 0.4825 - val_mse: 0.4825
#
# Epoch 00155: val_loss improved from 0.48256 to 0.48251, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 156/500
#  - 1s - loss: 0.3566 - mse: 0.3566 - val_loss: 0.4825 - val_mse: 0.4825
#
# Epoch 00156: val_loss improved from 0.48251 to 0.48246, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 157/500
#  - 1s - loss: 0.3566 - mse: 0.3566 - val_loss: 0.4824 - val_mse: 0.4824
#
# Epoch 00157: val_loss improved from 0.48246 to 0.48240, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 158/500
#  - 1s - loss: 0.3566 - mse: 0.3566 - val_loss: 0.4823 - val_mse: 0.4823
#
# Epoch 00158: val_loss improved from 0.48240 to 0.48235, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 159/500
#  - 1s - loss: 0.3565 - mse: 0.3565 - val_loss: 0.4823 - val_mse: 0.4823
#
# Epoch 00159: val_loss improved from 0.48235 to 0.48230, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 160/500
#  - 1s - loss: 0.3565 - mse: 0.3565 - val_loss: 0.4822 - val_mse: 0.4822
#
# Epoch 00160: val_loss improved from 0.48230 to 0.48225, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 161/500
#  - 1s - loss: 0.3565 - mse: 0.3565 - val_loss: 0.4822 - val_mse: 0.4822
#
# Epoch 00161: val_loss improved from 0.48225 to 0.48219, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 162/500
#  - 1s - loss: 0.3565 - mse: 0.3565 - val_loss: 0.4821 - val_mse: 0.4821
#
# Epoch 00162: val_loss improved from 0.48219 to 0.48214, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 163/500
#  - 1s - loss: 0.3565 - mse: 0.3565 - val_loss: 0.4821 - val_mse: 0.4821
#
# Epoch 00163: val_loss improved from 0.48214 to 0.48209, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 164/500
#  - 1s - loss: 0.3564 - mse: 0.3564 - val_loss: 0.4820 - val_mse: 0.4820
#
# Epoch 00164: val_loss improved from 0.48209 to 0.48204, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 165/500
#  - 1s - loss: 0.3564 - mse: 0.3564 - val_loss: 0.4820 - val_mse: 0.4820
#
# Epoch 00165: val_loss improved from 0.48204 to 0.48199, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 166/500
#  - 1s - loss: 0.3564 - mse: 0.3564 - val_loss: 0.4819 - val_mse: 0.4819
#
# Epoch 00166: val_loss improved from 0.48199 to 0.48194, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 167/500
#  - 1s - loss: 0.3564 - mse: 0.3564 - val_loss: 0.4819 - val_mse: 0.4819
#
# Epoch 00167: val_loss improved from 0.48194 to 0.48188, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 168/500
#  - 1s - loss: 0.3563 - mse: 0.3563 - val_loss: 0.4818 - val_mse: 0.4818
#
# Epoch 00168: val_loss improved from 0.48188 to 0.48183, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 169/500
#  - 1s - loss: 0.3563 - mse: 0.3563 - val_loss: 0.4818 - val_mse: 0.4818
#
# Epoch 00169: val_loss improved from 0.48183 to 0.48178, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 170/500
#  - 1s - loss: 0.3563 - mse: 0.3563 - val_loss: 0.4817 - val_mse: 0.4817
#
# Epoch 00170: val_loss improved from 0.48178 to 0.48173, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 171/500
#  - 1s - loss: 0.3563 - mse: 0.3563 - val_loss: 0.4817 - val_mse: 0.4817
#
# Epoch 00171: val_loss improved from 0.48173 to 0.48168, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 172/500
#  - 1s - loss: 0.3563 - mse: 0.3563 - val_loss: 0.4816 - val_mse: 0.4816
#
# Epoch 00172: val_loss improved from 0.48168 to 0.48163, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 173/500
#  - 1s - loss: 0.3562 - mse: 0.3562 - val_loss: 0.4816 - val_mse: 0.4816
#
# Epoch 00173: val_loss improved from 0.48163 to 0.48158, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 174/500
#  - 1s - loss: 0.3562 - mse: 0.3562 - val_loss: 0.4815 - val_mse: 0.4815
#
# Epoch 00174: val_loss improved from 0.48158 to 0.48153, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 175/500
#  - 1s - loss: 0.3562 - mse: 0.3562 - val_loss: 0.4815 - val_mse: 0.4815
#
# Epoch 00175: val_loss improved from 0.48153 to 0.48148, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 176/500
#  - 1s - loss: 0.3562 - mse: 0.3562 - val_loss: 0.4814 - val_mse: 0.4814
#
# Epoch 00176: val_loss improved from 0.48148 to 0.48143, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 177/500
#  - 1s - loss: 0.3562 - mse: 0.3562 - val_loss: 0.4814 - val_mse: 0.4814
#
# Epoch 00177: val_loss improved from 0.48143 to 0.48138, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 178/500
#  - 1s - loss: 0.3561 - mse: 0.3561 - val_loss: 0.4813 - val_mse: 0.4813
#
# Epoch 00178: val_loss improved from 0.48138 to 0.48133, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 179/500
#  - 1s - loss: 0.3561 - mse: 0.3561 - val_loss: 0.4813 - val_mse: 0.4813
#
# Epoch 00179: val_loss improved from 0.48133 to 0.48128, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 180/500
#  - 1s - loss: 0.3561 - mse: 0.3561 - val_loss: 0.4812 - val_mse: 0.4812
#
# Epoch 00180: val_loss improved from 0.48128 to 0.48123, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 181/500
#  - 1s - loss: 0.3561 - mse: 0.3561 - val_loss: 0.4812 - val_mse: 0.4812
#
# Epoch 00181: val_loss improved from 0.48123 to 0.48118, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 182/500
#  - 1s - loss: 0.3561 - mse: 0.3561 - val_loss: 0.4811 - val_mse: 0.4811
#
# Epoch 00182: val_loss improved from 0.48118 to 0.48114, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 183/500
#  - 1s - loss: 0.3560 - mse: 0.3560 - val_loss: 0.4811 - val_mse: 0.4811
#
# Epoch 00183: val_loss improved from 0.48114 to 0.48109, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 184/500
#  - 1s - loss: 0.3560 - mse: 0.3560 - val_loss: 0.4810 - val_mse: 0.4810
#
# Epoch 00184: val_loss improved from 0.48109 to 0.48104, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 185/500
#  - 1s - loss: 0.3560 - mse: 0.3560 - val_loss: 0.4810 - val_mse: 0.4810
#
# Epoch 00185: val_loss improved from 0.48104 to 0.48099, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 186/500
#  - 1s - loss: 0.3560 - mse: 0.3560 - val_loss: 0.4809 - val_mse: 0.4809
#
# Epoch 00186: val_loss improved from 0.48099 to 0.48094, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 187/500
#  - 1s - loss: 0.3560 - mse: 0.3560 - val_loss: 0.4809 - val_mse: 0.4809
#
# Epoch 00187: val_loss improved from 0.48094 to 0.48090, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 188/500
#  - 1s - loss: 0.3560 - mse: 0.3560 - val_loss: 0.4809 - val_mse: 0.4809
#
# Epoch 00188: val_loss improved from 0.48090 to 0.48085, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 189/500
#  - 1s - loss: 0.3559 - mse: 0.3559 - val_loss: 0.4808 - val_mse: 0.4808
#
# Epoch 00189: val_loss improved from 0.48085 to 0.48080, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 190/500
#  - 1s - loss: 0.3559 - mse: 0.3559 - val_loss: 0.4808 - val_mse: 0.4808
#
# Epoch 00190: val_loss improved from 0.48080 to 0.48076, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 191/500
#  - 1s - loss: 0.3559 - mse: 0.3559 - val_loss: 0.4807 - val_mse: 0.4807
#
# Epoch 00191: val_loss improved from 0.48076 to 0.48072, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 192/500
#  - 1s - loss: 0.3559 - mse: 0.3559 - val_loss: 0.4807 - val_mse: 0.4807
#
# Epoch 00192: val_loss improved from 0.48072 to 0.48067, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 193/500
#  - 1s - loss: 0.3559 - mse: 0.3559 - val_loss: 0.4806 - val_mse: 0.4806
#
# Epoch 00193: val_loss improved from 0.48067 to 0.48062, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 194/500
#  - 1s - loss: 0.3559 - mse: 0.3559 - val_loss: 0.4806 - val_mse: 0.4806
#
# Epoch 00194: val_loss improved from 0.48062 to 0.48058, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 195/500
#  - 1s - loss: 0.3558 - mse: 0.3558 - val_loss: 0.4805 - val_mse: 0.4805
#
# Epoch 00195: val_loss improved from 0.48058 to 0.48054, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 196/500
#  - 1s - loss: 0.3558 - mse: 0.3558 - val_loss: 0.4805 - val_mse: 0.4805
#
# Epoch 00196: val_loss improved from 0.48054 to 0.48049, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 197/500
#  - 1s - loss: 0.3558 - mse: 0.3558 - val_loss: 0.4804 - val_mse: 0.4804
#
# Epoch 00197: val_loss improved from 0.48049 to 0.48045, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 198/500
#  - 1s - loss: 0.3558 - mse: 0.3558 - val_loss: 0.4804 - val_mse: 0.4804
#
# Epoch 00198: val_loss improved from 0.48045 to 0.48040, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 199/500
#  - 1s - loss: 0.3558 - mse: 0.3558 - val_loss: 0.4804 - val_mse: 0.4804
#
# Epoch 00199: val_loss improved from 0.48040 to 0.48036, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 200/500
#  - 1s - loss: 0.3558 - mse: 0.3558 - val_loss: 0.4803 - val_mse: 0.4803
#
# Epoch 00200: val_loss improved from 0.48036 to 0.48032, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 201/500
#  - 1s - loss: 0.3557 - mse: 0.3557 - val_loss: 0.4803 - val_mse: 0.4803
#
# Epoch 00201: val_loss improved from 0.48032 to 0.48028, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 202/500
#  - 1s - loss: 0.3557 - mse: 0.3557 - val_loss: 0.4802 - val_mse: 0.4802
#
# Epoch 00202: val_loss improved from 0.48028 to 0.48023, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 203/500
#  - 1s - loss: 0.3557 - mse: 0.3557 - val_loss: 0.4802 - val_mse: 0.4802
#
# Epoch 00203: val_loss improved from 0.48023 to 0.48019, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 204/500
#  - 1s - loss: 0.3557 - mse: 0.3557 - val_loss: 0.4801 - val_mse: 0.4801
#
# Epoch 00204: val_loss improved from 0.48019 to 0.48015, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 205/500
#  - 1s - loss: 0.3557 - mse: 0.3557 - val_loss: 0.4801 - val_mse: 0.4801
#
# Epoch 00205: val_loss improved from 0.48015 to 0.48010, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 206/500
#  - 1s - loss: 0.3557 - mse: 0.3557 - val_loss: 0.4801 - val_mse: 0.4801
#
# Epoch 00206: val_loss improved from 0.48010 to 0.48006, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 207/500
#  - 1s - loss: 0.3557 - mse: 0.3557 - val_loss: 0.4800 - val_mse: 0.4800
#
# Epoch 00207: val_loss improved from 0.48006 to 0.48002, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 208/500
#  - 1s - loss: 0.3556 - mse: 0.3556 - val_loss: 0.4800 - val_mse: 0.4800
#
# Epoch 00208: val_loss improved from 0.48002 to 0.47998, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 209/500
#  - 1s - loss: 0.3556 - mse: 0.3556 - val_loss: 0.4799 - val_mse: 0.4799
#
# Epoch 00209: val_loss improved from 0.47998 to 0.47994, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 210/500
#  - 1s - loss: 0.3556 - mse: 0.3556 - val_loss: 0.4799 - val_mse: 0.4799
#
# Epoch 00210: val_loss improved from 0.47994 to 0.47990, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 211/500
#  - 1s - loss: 0.3556 - mse: 0.3556 - val_loss: 0.4799 - val_mse: 0.4799
#
# Epoch 00211: val_loss improved from 0.47990 to 0.47986, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 212/500
#  - 1s - loss: 0.3556 - mse: 0.3556 - val_loss: 0.4798 - val_mse: 0.4798
#
# Epoch 00212: val_loss improved from 0.47986 to 0.47982, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 213/500
#  - 1s - loss: 0.3556 - mse: 0.3556 - val_loss: 0.4798 - val_mse: 0.4798
#
# Epoch 00213: val_loss improved from 0.47982 to 0.47978, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 214/500
#  - 1s - loss: 0.3556 - mse: 0.3556 - val_loss: 0.4797 - val_mse: 0.4797
#
# Epoch 00214: val_loss improved from 0.47978 to 0.47974, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 215/500
#  - 1s - loss: 0.3555 - mse: 0.3555 - val_loss: 0.4797 - val_mse: 0.4797
#
# Epoch 00215: val_loss improved from 0.47974 to 0.47970, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 216/500
#  - 1s - loss: 0.3555 - mse: 0.3555 - val_loss: 0.4797 - val_mse: 0.4797
#
# Epoch 00216: val_loss improved from 0.47970 to 0.47966, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 217/500
#  - 1s - loss: 0.3555 - mse: 0.3555 - val_loss: 0.4796 - val_mse: 0.4796
#
# Epoch 00217: val_loss improved from 0.47966 to 0.47962, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 218/500
#  - 1s - loss: 0.3555 - mse: 0.3555 - val_loss: 0.4796 - val_mse: 0.4796
#
# Epoch 00218: val_loss improved from 0.47962 to 0.47958, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 219/500
#  - 1s - loss: 0.3555 - mse: 0.3555 - val_loss: 0.4795 - val_mse: 0.4795
#
# Epoch 00219: val_loss improved from 0.47958 to 0.47954, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 220/500
#  - 1s - loss: 0.3555 - mse: 0.3555 - val_loss: 0.4795 - val_mse: 0.4795
#
# Epoch 00220: val_loss improved from 0.47954 to 0.47950, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 221/500
#  - 1s - loss: 0.3555 - mse: 0.3555 - val_loss: 0.4795 - val_mse: 0.4795
#
# Epoch 00221: val_loss improved from 0.47950 to 0.47946, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 222/500
#  - 1s - loss: 0.3555 - mse: 0.3555 - val_loss: 0.4794 - val_mse: 0.4794
#
# Epoch 00222: val_loss improved from 0.47946 to 0.47943, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 223/500
#  - 1s - loss: 0.3554 - mse: 0.3554 - val_loss: 0.4794 - val_mse: 0.4794
#
# Epoch 00223: val_loss improved from 0.47943 to 0.47939, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 224/500
#  - 1s - loss: 0.3554 - mse: 0.3554 - val_loss: 0.4793 - val_mse: 0.4793
#
# Epoch 00224: val_loss improved from 0.47939 to 0.47934, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 225/500
#  - 1s - loss: 0.3554 - mse: 0.3554 - val_loss: 0.4793 - val_mse: 0.4793
#
# Epoch 00225: val_loss improved from 0.47934 to 0.47931, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 226/500
#  - 1s - loss: 0.3554 - mse: 0.3554 - val_loss: 0.4793 - val_mse: 0.4793
#
# Epoch 00226: val_loss improved from 0.47931 to 0.47927, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 227/500
#  - 1s - loss: 0.3554 - mse: 0.3554 - val_loss: 0.4792 - val_mse: 0.4792
#
# Epoch 00227: val_loss improved from 0.47927 to 0.47923, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 228/500
#  - 1s - loss: 0.3554 - mse: 0.3554 - val_loss: 0.4792 - val_mse: 0.4792
#
# Epoch 00228: val_loss improved from 0.47923 to 0.47919, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 229/500
#  - 1s - loss: 0.3554 - mse: 0.3554 - val_loss: 0.4792 - val_mse: 0.4792
#
# Epoch 00229: val_loss improved from 0.47919 to 0.47916, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 230/500
#  - 1s - loss: 0.3554 - mse: 0.3554 - val_loss: 0.4791 - val_mse: 0.4791
#
# Epoch 00230: val_loss improved from 0.47916 to 0.47912, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 231/500
#  - 1s - loss: 0.3553 - mse: 0.3553 - val_loss: 0.4791 - val_mse: 0.4791
#
# Epoch 00231: val_loss improved from 0.47912 to 0.47908, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 232/500
#  - 1s - loss: 0.3553 - mse: 0.3553 - val_loss: 0.4790 - val_mse: 0.4790
#
# Epoch 00232: val_loss improved from 0.47908 to 0.47905, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 233/500
#  - 1s - loss: 0.3553 - mse: 0.3553 - val_loss: 0.4790 - val_mse: 0.4790
#
# Epoch 00233: val_loss improved from 0.47905 to 0.47901, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 234/500
#  - 1s - loss: 0.3553 - mse: 0.3553 - val_loss: 0.4790 - val_mse: 0.4790
#
# Epoch 00234: val_loss improved from 0.47901 to 0.47897, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 235/500
#  - 1s - loss: 0.3553 - mse: 0.3553 - val_loss: 0.4789 - val_mse: 0.4789
#
# Epoch 00235: val_loss improved from 0.47897 to 0.47894, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 236/500
#  - 1s - loss: 0.3553 - mse: 0.3553 - val_loss: 0.4789 - val_mse: 0.4789
#
# Epoch 00236: val_loss improved from 0.47894 to 0.47890, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 237/500
#  - 1s - loss: 0.3553 - mse: 0.3553 - val_loss: 0.4789 - val_mse: 0.4789
#
# Epoch 00237: val_loss improved from 0.47890 to 0.47887, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 238/500
#  - 1s - loss: 0.3553 - mse: 0.3553 - val_loss: 0.4788 - val_mse: 0.4788
#
# Epoch 00238: val_loss improved from 0.47887 to 0.47883, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 239/500
#  - 1s - loss: 0.3553 - mse: 0.3553 - val_loss: 0.4788 - val_mse: 0.4788
#
# Epoch 00239: val_loss improved from 0.47883 to 0.47880, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 240/500
#  - 1s - loss: 0.3552 - mse: 0.3552 - val_loss: 0.4788 - val_mse: 0.4788
#
# Epoch 00240: val_loss improved from 0.47880 to 0.47876, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 241/500
#  - 1s - loss: 0.3552 - mse: 0.3552 - val_loss: 0.4787 - val_mse: 0.4787
#
# Epoch 00241: val_loss improved from 0.47876 to 0.47873, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 242/500
#  - 1s - loss: 0.3552 - mse: 0.3552 - val_loss: 0.4787 - val_mse: 0.4787
#
# Epoch 00242: val_loss improved from 0.47873 to 0.47869, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 243/500
#  - 1s - loss: 0.3552 - mse: 0.3552 - val_loss: 0.4787 - val_mse: 0.4787
#
# Epoch 00243: val_loss improved from 0.47869 to 0.47866, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 244/500
#  - 1s - loss: 0.3552 - mse: 0.3552 - val_loss: 0.4786 - val_mse: 0.4786
#
# Epoch 00244: val_loss improved from 0.47866 to 0.47862, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 245/500
#  - 1s - loss: 0.3552 - mse: 0.3552 - val_loss: 0.4786 - val_mse: 0.4786
#
# Epoch 00245: val_loss improved from 0.47862 to 0.47859, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 246/500
#  - 1s - loss: 0.3552 - mse: 0.3552 - val_loss: 0.4786 - val_mse: 0.4786
#
# Epoch 00246: val_loss improved from 0.47859 to 0.47855, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 247/500
#  - 1s - loss: 0.3552 - mse: 0.3552 - val_loss: 0.4785 - val_mse: 0.4785
#
# Epoch 00247: val_loss improved from 0.47855 to 0.47852, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 248/500
#  - 1s - loss: 0.3552 - mse: 0.3552 - val_loss: 0.4785 - val_mse: 0.4785
#
# Epoch 00248: val_loss improved from 0.47852 to 0.47848, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 249/500
#  - 1s - loss: 0.3552 - mse: 0.3552 - val_loss: 0.4785 - val_mse: 0.4785
#
# Epoch 00249: val_loss improved from 0.47848 to 0.47845, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 250/500
#  - 1s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.4784 - val_mse: 0.4784
#
# Epoch 00250: val_loss improved from 0.47845 to 0.47841, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 251/500
#  - 1s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.4784 - val_mse: 0.4784
#
# Epoch 00251: val_loss improved from 0.47841 to 0.47838, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 252/500
#  - 1s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.4784 - val_mse: 0.4784
#
# Epoch 00252: val_loss improved from 0.47838 to 0.47835, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 253/500
#  - 1s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.4783 - val_mse: 0.4783
#
# Epoch 00253: val_loss improved from 0.47835 to 0.47832, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 254/500
#  - 1s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.4783 - val_mse: 0.4783
#
# Epoch 00254: val_loss improved from 0.47832 to 0.47828, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 255/500
#  - 1s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.4783 - val_mse: 0.4783
#
# Epoch 00255: val_loss improved from 0.47828 to 0.47825, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 256/500
#  - 1s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.4782 - val_mse: 0.4782
#
# Epoch 00256: val_loss improved from 0.47825 to 0.47822, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 257/500
#  - 1s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.4782 - val_mse: 0.4782
#
# Epoch 00257: val_loss improved from 0.47822 to 0.47819, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 258/500
#  - 1s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.4782 - val_mse: 0.4782
#
# Epoch 00258: val_loss improved from 0.47819 to 0.47815, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 259/500
#  - 1s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.4781 - val_mse: 0.4781
#
# Epoch 00259: val_loss improved from 0.47815 to 0.47813, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 260/500
#  - 1s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.4781 - val_mse: 0.4781
#
# Epoch 00260: val_loss improved from 0.47813 to 0.47809, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 261/500
#  - 1s - loss: 0.3550 - mse: 0.3550 - val_loss: 0.4781 - val_mse: 0.4781
#
# Epoch 00261: val_loss improved from 0.47809 to 0.47806, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 262/500
#  - 1s - loss: 0.3550 - mse: 0.3550 - val_loss: 0.4780 - val_mse: 0.4780
#
# Epoch 00262: val_loss improved from 0.47806 to 0.47803, saving model to model/ohlcv_offset 10_108.hdf5
# Epoch 263/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-46ff804eaaa9> in <module>()
#     218                     verbose=2,
#     219                     callbacks=callbacks_list,
# --> 220                     shuffle=False,
#     221                     )
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     208                                          batch_size=batch_size,
#     209                                          callbacks=callbacks,
# --> 210                                          verbose=0)
#     211                     val_outs = to_list(val_outs)
#     212                     # Same labels assumed.
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in test_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     447             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     448             callbacks._call_batch_hook('test', 'begin', batch_index, batch_logs)
# --> 449             batch_outs = f(ins_batch)
#     450             if isinstance(batch_outs, list):
#     451                 if batch_index == 0:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
#         RESULT COMPARING    #
pred_reg = model.predict(X_test)
Y_pred = Made_Y.copy()
Y_pred[val_len:] = pred_reg

plt.figure(figsize=(10, 7))
# plt.subplot(311)
# if inverse == 1:
#     plt.plot(Made_X[:, [0]].reshape(-1, 1), color='g', label='MACD_OSC') #   if [::-1], [0]
# else:
#     plt.plot(Made_X[:, [-1]].reshape(-1, 1), color='g', label='MACD_OSC')
plt.plot(Made_Y, color='r', label='osc')
plt.plot(Y_pred, color='b', label='osc_pred')
plt.axvline(x=val_len)

plt.show()

# %%
from scipy.ndimage.interpolation import shift

plt.plot(Made_Y, color='orange', label='past')
# print(pd.Series(Made_Y))
# print(pd.Series(Made_Y.reshape(-1, )).shift(-3).values)
# print(shift(Made_Y, 3, cval=np.nan))
# break
plt.plot(pd.Series(Made_Y.reshape(-1, )).shift(predict_size - 1).values, color='r', label='real')
plt.plot(Y_pred, color='b', label='predict')
plt.xlim(len(Y_pred)-100, len(Y_pred))
plt.legend(loc='upper right')
plt.show()
