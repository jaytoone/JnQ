# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-02-11/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-02-11 BTCUSDT.xlsx', '2021-02-11 ETHUSDT.xlsx', '2021-02-11 BCHUSDT.xlsx', '2021-02-11 XRPUSDT.xlsx', '2021-02-11 EOSUSDT.xlsx', '2021-02-11 LTCUSDT.xlsx', '2021-02-11 ETCUSDT.xlsx', '2021-02-11 LINKUSDT.xlsx', '2021-02-11 XLMUSDT.xlsx', '2021-02-11 ADAUSDT.xlsx', '2021-02-11 XMRUSDT.xlsx', '2021-02-11 SXPUSDT.xlsx', '2021-02-11 KAVAUSDT.xlsx', '2021-02-11 BANDUSDT.xlsx', '2021-02-11 DASHUSDT.xlsx', '2021-02-11 ZECUSDT.xlsx', '2021-02-11 XTZUSDT.xlsx', '2021-02-11 BNBUSDT.xlsx', '2021-02-11 ATOMUSDT.xlsx', '2021-02-11 ONTUSDT.xlsx', '2021-02-11 IOTAUSDT.xlsx', '2021-02-11 BATUSDT.xlsx', '2021-02-11 NEOUSDT.xlsx', '2021-02-11 QTUMUSDT.xlsx', '2021-02-11 WAVESUSDT.xlsx', '2021-02-11 MKRUSDT.xlsx', '2021-02-11 SNXUSDT.xlsx', '2021-02-11 DOTUSDT.xlsx', '2021-02-11 THETAUSDT.xlsx', '2021-02-11 ALGOUSDT.xlsx', '2021-02-11 KNCUSDT.xlsx', '2021-02-11 ZRXUSDT.xlsx', '2021-02-11 COMPUSDT.xlsx', '2021-02-11 OMGUSDT.xlsx']

# %% [markdown]
# ### **Data Stacking**

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle

with open('./arima_result/arima_ma7_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
  load_dict = pickle.load(f)

candis = list(load_dict.keys())
long_index = 0
leverage = 5
prev_x = None
for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue
  if '2021-03-02 DOTUSDT.xlsx' in candis[i]:
    # print('')
    continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))

  if '04-08' not in candis[i]:
    continue


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      ohlcv = load_dict[key]['ohlcv']
      # predictions = load_dict[key]['predictions']
      # err_ranges = load_dict[key]['err_ranges']

      predictions = ohlcv['open'].values
      err_ranges = np.zeros_like(predictions)

      # leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]

      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = np.array(predictions)
      long_ep = long_ep.reshape(-1, 1)

      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 45
      data_x, data_pr, data_updown = [], [], []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          min_max = MinMaxScaler()
          temp_data[:, :5] = min_max.fit_transform(temp_data[:, :5])


          #   vol -> min_max
          min_max = MinMaxScaler()
          temp_data[:, [5]] = min_max.fit_transform(temp_data[:, [5]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]

      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)

      #     do stacking   #
      if prev_x is None:
        prev_x = input_x
        prev_pr = input_pr
        prev_ud = input_ud
      else:
        total_x = np.vstack((prev_x, input_x))
        total_pr = np.vstack((prev_pr, input_pr))
        total_ud = np.vstack((prev_ud, input_ud))

        prev_x = total_x
        prev_pr = total_pr
        prev_ud = total_ud

        print('total_x.shape :', total_x.shape)
        print('total_pr.shape :', total_pr.shape)
        print('total_ud.shape :', total_ud.shape)

  try:
    if len(total_x) > 300000:
      break
  except:
    pass
# Out:
# -------------- 2021-04-08 BTCUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16699, 45, 6)
# input_x.shape : (16699, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16699, 1)
# input_ud.shape : (16699, 1)
# -------------- 2021-04-08 ETHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16643, 45, 6)
# input_x.shape : (16643, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16643, 1)
# input_ud.shape : (16643, 1)
# total_x.shape : (33342, 45, 6, 3)
# total_pr.shape : (33342, 1)
# total_ud.shape : (33342, 1)
# -------------- 2021-04-08 BCHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16557, 45, 6)
# input_x.shape : (16557, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16557, 1)
# input_ud.shape : (16557, 1)
# total_x.shape : (49899, 45, 6, 3)
# total_pr.shape : (49899, 1)
# total_ud.shape : (49899, 1)
# -------------- 2021-04-08 XRPUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16211, 45, 6)
# input_x.shape : (16211, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16211, 1)
# input_ud.shape : (16211, 1)
# total_x.shape : (66110, 45, 6, 3)
# total_pr.shape : (66110, 1)
# total_ud.shape : (66110, 1)
# -------------- 2021-04-08 EOSUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16134, 45, 6)
# input_x.shape : (16134, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16134, 1)
# input_ud.shape : (16134, 1)
# total_x.shape : (82244, 45, 6, 3)
# total_pr.shape : (82244, 1)
# total_ud.shape : (82244, 1)
# -------------- 2021-04-08 LTCUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16409, 45, 6)
# input_x.shape : (16409, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16409, 1)
# input_ud.shape : (16409, 1)
# total_x.shape : (98653, 45, 6, 3)
# total_pr.shape : (98653, 1)
# total_ud.shape : (98653, 1)
# -------------- 2021-04-08 ETCUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16331, 45, 6)
# input_x.shape : (16331, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16331, 1)
# input_ud.shape : (16331, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# total_x.shape : (114984, 45, 6, 3)
# total_pr.shape : (114984, 1)
# total_ud.shape : (114984, 1)
# -------------- 2021-04-08 LINKUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16575, 45, 6)
# input_x.shape : (16575, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16575, 1)
# input_ud.shape : (16575, 1)
# total_x.shape : (131559, 45, 6, 3)
# total_pr.shape : (131559, 1)
# total_ud.shape : (131559, 1)
# -------------- 2021-04-08 XLMUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16455, 45, 6)
# input_x.shape : (16455, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16455, 1)
# input_ud.shape : (16455, 1)
# total_x.shape : (148014, 45, 6, 3)
# total_pr.shape : (148014, 1)
# total_ud.shape : (148014, 1)
# -------------- 2021-04-08 ADAUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16497, 45, 6)
# input_x.shape : (16497, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16497, 1)
# input_ud.shape : (16497, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# total_x.shape : (164511, 45, 6, 3)
# total_pr.shape : (164511, 1)
# total_ud.shape : (164511, 1)
# -------------- 2021-04-08 XMRUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16325, 45, 6)
# input_x.shape : (16325, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16325, 1)
# input_ud.shape : (16325, 1)
# total_x.shape : (180836, 45, 6, 3)
# total_pr.shape : (180836, 1)
# total_ud.shape : (180836, 1)
# -------------- 2021-04-08 SXPUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 12533
# long_ep.shape : (12533, 1)
# len(pr_list) : 12533
# np.array(data_x).shape : (12214, 45, 6)
# input_x.shape : (12214, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (12214, 1)
# input_ud.shape : (12214, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# total_x.shape : (193050, 45, 6, 3)
# total_pr.shape : (193050, 1)
# total_ud.shape : (193050, 1)
# -------------- 2021-04-08 KAVAUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 12201
# long_ep.shape : (12201, 1)
# len(pr_list) : 12201
# np.array(data_x).shape : (11858, 45, 6)
# input_x.shape : (11858, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (11858, 1)
# input_ud.shape : (11858, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# total_x.shape : (204908, 45, 6, 3)
# total_pr.shape : (204908, 1)
# total_ud.shape : (204908, 1)
# -------------- 2021-04-08 BANDUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 12153
# long_ep.shape : (12153, 1)
# len(pr_list) : 12153
# np.array(data_x).shape : (11854, 45, 6)
# input_x.shape : (11854, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (11854, 1)
# input_ud.shape : (11854, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# total_x.shape : (216762, 45, 6, 3)
# total_pr.shape : (216762, 1)
# total_ud.shape : (216762, 1)
# -------------- 2021-04-08 DASHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16278, 45, 6)
# input_x.shape : (16278, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16278, 1)
# input_ud.shape : (16278, 1)
# total_x.shape : (233040, 45, 6, 3)
# total_pr.shape : (233040, 1)
# total_ud.shape : (233040, 1)
# -------------- 2021-04-08 ZECUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16310, 45, 6)
# input_x.shape : (16310, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16310, 1)
# input_ud.shape : (16310, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# total_x.shape : (249350, 45, 6, 3)
# total_pr.shape : (249350, 1)
# total_ud.shape : (249350, 1)
# -------------- 2021-04-08 XTZUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16263, 45, 6)
# input_x.shape : (16263, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16263, 1)
# input_ud.shape : (16263, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# total_x.shape : (265613, 45, 6, 3)
# total_pr.shape : (265613, 1)
# total_ud.shape : (265613, 1)
# -------------- 2021-04-08 BNBUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16598, 45, 6)
# input_x.shape : (16598, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16598, 1)
# input_ud.shape : (16598, 1)
# total_x.shape : (282211, 45, 6, 3)
# total_pr.shape : (282211, 1)
# total_ud.shape : (282211, 1)
# -------------- 2021-04-08 ATOMUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16291, 45, 6)
# input_x.shape : (16291, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16291, 1)
# input_ud.shape : (16291, 1)
# total_x.shape : (298502, 45, 6, 3)
# total_pr.shape : (298502, 1)
# total_ud.shape : (298502, 1)
# -------------- 2021-04-08 ONTUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16309, 45, 6)
# input_x.shape : (16309, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16309, 1)
# input_ud.shape : (16309, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:184: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# total_x.shape : (314811, 45, 6, 3)
# total_pr.shape : (314811, 1)
# total_ud.shape : (314811, 1)

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape=(row, col, 3)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight
# import cv2



seed = 1
random_state = 20
np.random.seed(seed)
# tf.random.set_seed(seed)

#         resize total_x shape  (, 5, 6, 3)      #
# .repeat(2, axis=0).repeat(2, axis=1)
temp_x = list()
for d_i, data in enumerate(total_x):
  # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
  resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
  # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
  # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
  
  if d_i == 0:
    plt.imshow(data)
    plt.show()
    plt.imshow(resized_data)
    plt.show()
  # print('resized_data.shape :', resized_data.shape)
  # break
  temp_x.append(resized_data)

re_total_x = np.array(temp_x)
print('re_total_x.shape :', re_total_x.shape)
# break

#         train / test split      #
x_train, x_test_, pr_train, pr_test_, ud_train, ud_test_ = train_test_split(re_total_x, total_pr, total_ud, test_size=0.4, shuffle=True, random_state=random_state)
x_test, x_val, pr_test, pr_val, ud_test, ud_val = train_test_split(x_test_, pr_test_, ud_test_, test_size=0.5, shuffle=True, random_state=random_state)


#         pr label   #
y_train = np.where(pr_train > 1, 1, 0)
y_test = np.where(pr_test > 1, 1, 0)
y_val = np.where(pr_val > 1, 1, 0)

#         up label      #
# y_train = np.where(ud_train > 1, 1, 0)
# y_test = np.where(ud_test > 1, 1, 0)
# y_val = np.where(ud_val > 1, 1, 0)

print('pr_train[:5] :', pr_train[:5])
print('ud_train[:5] :', ud_train[:5])
print('y_train[:5] :', y_train[:5])
print('y_train.dtype :', y_train.dtype)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

def class_ratio(in_list):

  return in_list / in_list[1]

print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)

datagen = ImageDataGenerator( 
    rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)

batch_size = 256

for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break
# Out:
# re_total_x.shape : (314811, 90, 12, 3)
# pr_train[:5] : [[1.1856219 ]
#  [0.98743355]
#  [1.0973072 ]
#  [1.0322257 ]
#  [1.0123228 ]]
# ud_train[:5] : [[1.0377244]
#  [0.9980867]
#  [1.0200614]
#  [1.0070451]
#  [1.0030645]]
# y_train[:5] : [[1]
#  [0]
#  [1]
#  [1]
#  [1]]
# y_train.dtype : int64
# x_train.shape : (188886, 90, 12, 3)
# x_test.shape : (62962, 90, 12, 3)
# x_val.shape : (62963, 90, 12, 3)
# y_train.shape : (188886, 1)
# y_test.shape : (62962, 1)
# y_val.shape : (62963, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([106446,  82440])) [1.2911936 1.       ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([35621, 27342])) [1.30279424 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([35318, 27644])) [1.27760093 1.        ]
# class_weights : {0: 0.8872385998534468, 1: 1.1455967976710335}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (188886, 2)
# y_val_ohe.shape : (62963, 2)
# y_test_ohe.shape : (62962, 2)

# %% [markdown]
# ### **Training**

# %%
(_, row, col, _) = x_train.shape

model = FER_Model(input_shape=(row, col, 3))
opt = Adam(lr=0.00001, decay=0.000005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
  
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_%s_tick_updown_pr.h5' % period

checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=40)
# callbacks_list = [checkpoint, checkpoint2, checkpoint3]
callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/1000
#  - 71s - loss: 0.7194 - accuracy: 0.5041 - val_loss: 0.7490 - val_accuracy: 0.4385
#
# Epoch 00001: val_loss improved from inf to 0.74896, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_tick_updown_pr.h5
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/1000
#  - 65s - loss: 0.7018 - accuracy: 0.5101 - val_loss: 0.6829 - val_accuracy: 0.5494
#
# Epoch 00002: val_loss improved from 0.74896 to 0.68287, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_tick_updown_pr.h5
# Epoch 3/1000
#  - 64s - loss: 0.6980 - accuracy: 0.5142 - val_loss: 0.6870 - val_accuracy: 0.5294
#
# Epoch 00003: val_loss did not improve from 0.68287
# Epoch 4/1000
#  - 64s - loss: 0.6960 - accuracy: 0.5110 - val_loss: 0.6857 - val_accuracy: 0.5470
#
# Epoch 00004: val_loss did not improve from 0.68287
# Epoch 5/1000
#  - 64s - loss: 0.6952 - accuracy: 0.5163 - val_loss: 0.6933 - val_accuracy: 0.5676
#
# Epoch 00005: val_loss did not improve from 0.68287
# Epoch 6/1000
#  - 64s - loss: 0.6961 - accuracy: 0.5132 - val_loss: 0.6858 - val_accuracy: 0.5454
#
# Epoch 00006: val_loss did not improve from 0.68287
# Epoch 7/1000
#  - 64s - loss: 0.6944 - accuracy: 0.5170 - val_loss: 0.6796 - val_accuracy: 0.5652
#
# Epoch 00007: val_loss improved from 0.68287 to 0.67963, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_tick_updown_pr.h5
# Epoch 8/1000
#  - 65s - loss: 0.6936 - accuracy: 0.5175 - val_loss: 0.6657 - val_accuracy: 0.5301
#
# Epoch 00008: val_loss improved from 0.67963 to 0.66575, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_tick_updown_pr.h5
# Epoch 9/1000
#  - 65s - loss: 0.6930 - accuracy: 0.5190 - val_loss: 0.6905 - val_accuracy: 0.5518
#
# Epoch 00009: val_loss did not improve from 0.66575
# Epoch 10/1000
#  - 64s - loss: 0.6927 - accuracy: 0.5203 - val_loss: 0.7072 - val_accuracy: 0.5167
#
# Epoch 00010: val_loss did not improve from 0.66575
# Epoch 11/1000
#  - 64s - loss: 0.6925 - accuracy: 0.5212 - val_loss: 0.6716 - val_accuracy: 0.5589
#
# Epoch 00011: val_loss did not improve from 0.66575
# Epoch 12/1000
#  - 65s - loss: 0.6924 - accuracy: 0.5201 - val_loss: 0.6885 - val_accuracy: 0.5598
#
# Epoch 00012: val_loss did not improve from 0.66575
# Epoch 13/1000
#  - 64s - loss: 0.6919 - accuracy: 0.5229 - val_loss: 0.6995 - val_accuracy: 0.5186
#
# Epoch 00013: val_loss did not improve from 0.66575
# Epoch 14/1000
#  - 65s - loss: 0.6916 - accuracy: 0.5247 - val_loss: 0.6819 - val_accuracy: 0.5536
#
# Epoch 00014: val_loss did not improve from 0.66575
# Epoch 15/1000
#  - 64s - loss: 0.6920 - accuracy: 0.5224 - val_loss: 0.6978 - val_accuracy: 0.5240
#
# Epoch 00015: val_loss did not improve from 0.66575
# Epoch 16/1000
#  - 64s - loss: 0.6914 - accuracy: 0.5254 - val_loss: 0.6803 - val_accuracy: 0.5398
#
# Epoch 00016: val_loss did not improve from 0.66575
# Epoch 17/1000
#  - 64s - loss: 0.6913 - accuracy: 0.5249 - val_loss: 0.6847 - val_accuracy: 0.5518
#
# Epoch 00017: val_loss did not improve from 0.66575
# Epoch 18/1000
#  - 64s - loss: 0.6914 - accuracy: 0.5253 - val_loss: 0.6727 - val_accuracy: 0.5493
#
# Epoch 00018: val_loss did not improve from 0.66575
# Epoch 19/1000
#  - 64s - loss: 0.6906 - accuracy: 0.5296 - val_loss: 0.7008 - val_accuracy: 0.5530
#
# Epoch 00019: val_loss did not improve from 0.66575
# Epoch 20/1000
#  - 64s - loss: 0.6909 - accuracy: 0.5285 - val_loss: 0.7041 - val_accuracy: 0.5288
#
# Epoch 00020: val_loss did not improve from 0.66575
# Epoch 21/1000
#  - 64s - loss: 0.6905 - accuracy: 0.5282 - val_loss: 0.6699 - val_accuracy: 0.5620
#
# Epoch 00021: val_loss did not improve from 0.66575
# Epoch 22/1000
#  - 64s - loss: 0.6910 - accuracy: 0.5254 - val_loss: 0.6920 - val_accuracy: 0.5372
#
# Epoch 00022: val_loss did not improve from 0.66575
# Epoch 23/1000
#  - 64s - loss: 0.6909 - accuracy: 0.5273 - val_loss: 0.6979 - val_accuracy: 0.5652
#
# Epoch 00023: val_loss did not improve from 0.66575
# Epoch 24/1000
#  - 64s - loss: 0.6902 - accuracy: 0.5304 - val_loss: 0.6893 - val_accuracy: 0.5601
#
# Epoch 00024: val_loss did not improve from 0.66575
# Epoch 25/1000
#  - 64s - loss: 0.6898 - accuracy: 0.5334 - val_loss: 0.6971 - val_accuracy: 0.5610
#
# Epoch 00025: val_loss did not improve from 0.66575
# Epoch 26/1000
#  - 65s - loss: 0.6896 - accuracy: 0.5318 - val_loss: 0.6976 - val_accuracy: 0.5207
#
# Epoch 00026: val_loss did not improve from 0.66575
# Epoch 27/1000
#  - 64s - loss: 0.6894 - accuracy: 0.5319 - val_loss: 0.6825 - val_accuracy: 0.5733
#
# Epoch 00027: val_loss did not improve from 0.66575
# Epoch 28/1000
#  - 64s - loss: 0.6895 - accuracy: 0.5342 - val_loss: 0.6871 - val_accuracy: 0.5315
#
# Epoch 00028: val_loss did not improve from 0.66575
# Epoch 29/1000
#  - 65s - loss: 0.6891 - accuracy: 0.5342 - val_loss: 0.6949 - val_accuracy: 0.5368
#
# Epoch 00029: val_loss did not improve from 0.66575
# Epoch 30/1000
#  - 64s - loss: 0.6889 - accuracy: 0.5371 - val_loss: 0.6986 - val_accuracy: 0.5200
#
# Epoch 00030: val_loss did not improve from 0.66575
# Epoch 31/1000
#  - 65s - loss: 0.6885 - accuracy: 0.5378 - val_loss: 0.7049 - val_accuracy: 0.4925
#
# Epoch 00031: val_loss did not improve from 0.66575
# Epoch 32/1000
#  - 65s - loss: 0.6879 - accuracy: 0.5390 - val_loss: 0.6962 - val_accuracy: 0.5476
#
# Epoch 00032: val_loss did not improve from 0.66575
# Epoch 33/1000
#  - 64s - loss: 0.6880 - accuracy: 0.5377 - val_loss: 0.6700 - val_accuracy: 0.5721
#
# Epoch 00033: val_loss did not improve from 0.66575
# Epoch 34/1000
#  - 64s - loss: 0.6878 - accuracy: 0.5403 - val_loss: 0.6786 - val_accuracy: 0.5299
#
# Epoch 00034: val_loss did not improve from 0.66575
# Epoch 35/1000
#  - 64s - loss: 0.6873 - accuracy: 0.5392 - val_loss: 0.6716 - val_accuracy: 0.5724
#
# Epoch 00035: val_loss did not improve from 0.66575
# Epoch 36/1000
#  - 64s - loss: 0.6865 - accuracy: 0.5416 - val_loss: 0.6837 - val_accuracy: 0.5594
#
# Epoch 00036: val_loss did not improve from 0.66575
# Epoch 37/1000
#  - 64s - loss: 0.6871 - accuracy: 0.5414 - val_loss: 0.6879 - val_accuracy: 0.5489
#
# Epoch 00037: val_loss did not improve from 0.66575
# Epoch 38/1000
#  - 64s - loss: 0.6861 - accuracy: 0.5447 - val_loss: 0.6706 - val_accuracy: 0.5638
#
# Epoch 00038: val_loss did not improve from 0.66575
# Epoch 39/1000
#  - 64s - loss: 0.6857 - accuracy: 0.5456 - val_loss: 0.6936 - val_accuracy: 0.5414
#
# Epoch 00039: val_loss did not improve from 0.66575
# Epoch 40/1000
#  - 65s - loss: 0.6856 - accuracy: 0.5460 - val_loss: 0.7077 - val_accuracy: 0.5382
#
# Epoch 00040: val_loss did not improve from 0.66575
# Epoch 41/1000
#  - 64s - loss: 0.6848 - accuracy: 0.5481 - val_loss: 0.6816 - val_accuracy: 0.5173
#
# Epoch 00041: val_loss did not improve from 0.66575
# Epoch 42/1000
#  - 64s - loss: 0.6842 - accuracy: 0.5512 - val_loss: 0.6925 - val_accuracy: 0.5692
#
# Epoch 00042: val_loss did not improve from 0.66575
# Epoch 43/1000
#  - 64s - loss: 0.6848 - accuracy: 0.5485 - val_loss: 0.6664 - val_accuracy: 0.5610
#
# Epoch 00043: val_loss did not improve from 0.66575
# Epoch 44/1000
#  - 65s - loss: 0.6840 - accuracy: 0.5514 - val_loss: 0.6754 - val_accuracy: 0.5640
#
# Epoch 00044: val_loss did not improve from 0.66575
# Epoch 45/1000
#  - 64s - loss: 0.6834 - accuracy: 0.5525 - val_loss: 0.6703 - val_accuracy: 0.5677
#
# Epoch 00045: val_loss did not improve from 0.66575
# Epoch 46/1000
#  - 65s - loss: 0.6832 - accuracy: 0.5531 - val_loss: 0.6908 - val_accuracy: 0.5596
#
# Epoch 00046: val_loss did not improve from 0.66575
# Epoch 47/1000
#  - 64s - loss: 0.6827 - accuracy: 0.5546 - val_loss: 0.6894 - val_accuracy: 0.5497
#
# Epoch 00047: val_loss did not improve from 0.66575
# Epoch 48/1000
#  - 64s - loss: 0.6823 - accuracy: 0.5542 - val_loss: 0.6749 - val_accuracy: 0.5591
#
# Epoch 00048: val_loss did not improve from 0.66575
# Epoch 49/1000
#  - 64s - loss: 0.6821 - accuracy: 0.5546 - val_loss: 0.6933 - val_accuracy: 0.5519
#
# Epoch 00049: val_loss did not improve from 0.66575
# Epoch 50/1000
#  - 65s - loss: 0.6817 - accuracy: 0.5566 - val_loss: 0.6732 - val_accuracy: 0.5506
#
# Epoch 00050: val_loss did not improve from 0.66575
# Epoch 51/1000
#  - 65s - loss: 0.6812 - accuracy: 0.5573 - val_loss: 0.6693 - val_accuracy: 0.5508
#
# Epoch 00051: val_loss did not improve from 0.66575
# Epoch 52/1000
#  - 64s - loss: 0.6806 - accuracy: 0.5582 - val_loss: 0.6803 - val_accuracy: 0.5654
#
# Epoch 00052: val_loss did not improve from 0.66575
# Epoch 53/1000
#  - 64s - loss: 0.6791 - accuracy: 0.5625 - val_loss: 0.7136 - val_accuracy: 0.5404
#
# Epoch 00053: val_loss did not improve from 0.66575
# Epoch 54/1000
#  - 64s - loss: 0.6792 - accuracy: 0.5634 - val_loss: 0.6691 - val_accuracy: 0.5680
#
# Epoch 00054: val_loss did not improve from 0.66575
# Epoch 55/1000
#  - 64s - loss: 0.6789 - accuracy: 0.5617 - val_loss: 0.6885 - val_accuracy: 0.5591
#
# Epoch 00055: val_loss did not improve from 0.66575
# Epoch 56/1000
#  - 65s - loss: 0.6794 - accuracy: 0.5621 - val_loss: 0.6965 - val_accuracy: 0.5667
#
# Epoch 00056: val_loss did not improve from 0.66575
# Epoch 57/1000
#  - 64s - loss: 0.6781 - accuracy: 0.5658 - val_loss: 0.6770 - val_accuracy: 0.5789
#
# Epoch 00057: val_loss did not improve from 0.66575
# Epoch 58/1000
#  - 64s - loss: 0.6781 - accuracy: 0.5661 - val_loss: 0.6933 - val_accuracy: 0.5502
#
# Epoch 00058: val_loss did not improve from 0.66575
# Epoch 59/1000
#  - 64s - loss: 0.6770 - accuracy: 0.5670 - val_loss: 0.6968 - val_accuracy: 0.5727
#
# Epoch 00059: val_loss did not improve from 0.66575
# Epoch 60/1000
#  - 65s - loss: 0.6773 - accuracy: 0.5684 - val_loss: 0.6900 - val_accuracy: 0.5709
#
# Epoch 00060: val_loss did not improve from 0.66575
# Epoch 61/1000
#  - 65s - loss: 0.6758 - accuracy: 0.5701 - val_loss: 0.6516 - val_accuracy: 0.5764
#
# Epoch 00061: val_loss improved from 0.66575 to 0.65157, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_tick_updown_pr.h5
# Epoch 62/1000
#  - 65s - loss: 0.6759 - accuracy: 0.5690 - val_loss: 0.6887 - val_accuracy: 0.5779
#
# Epoch 00062: val_loss did not improve from 0.65157
# Epoch 63/1000
#  - 65s - loss: 0.6746 - accuracy: 0.5740 - val_loss: 0.6796 - val_accuracy: 0.5691
#
# Epoch 00063: val_loss did not improve from 0.65157
# Epoch 64/1000
#  - 64s - loss: 0.6759 - accuracy: 0.5697 - val_loss: 0.6933 - val_accuracy: 0.5642
#
# Epoch 00064: val_loss did not improve from 0.65157
# Epoch 65/1000
#  - 64s - loss: 0.6749 - accuracy: 0.5715 - val_loss: 0.6959 - val_accuracy: 0.5611
#
# Epoch 00065: val_loss did not improve from 0.65157
# Epoch 66/1000
#  - 64s - loss: 0.6736 - accuracy: 0.5760 - val_loss: 0.6951 - val_accuracy: 0.5642
#
# Epoch 00066: val_loss did not improve from 0.65157
# Epoch 67/1000
#  - 64s - loss: 0.6737 - accuracy: 0.5748 - val_loss: 0.6896 - val_accuracy: 0.5599
#
# Epoch 00067: val_loss did not improve from 0.65157
# Epoch 68/1000
#  - 64s - loss: 0.6732 - accuracy: 0.5766 - val_loss: 0.6601 - val_accuracy: 0.5722
#
# Epoch 00068: val_loss did not improve from 0.65157
# Epoch 69/1000
#  - 64s - loss: 0.6732 - accuracy: 0.5745 - val_loss: 0.6791 - val_accuracy: 0.5462
#
# Epoch 00069: val_loss did not improve from 0.65157
# Epoch 70/1000
#  - 64s - loss: 0.6730 - accuracy: 0.5747 - val_loss: 0.6606 - val_accuracy: 0.5721
#
# Epoch 00070: val_loss did not improve from 0.65157
# Epoch 71/1000
#  - 64s - loss: 0.6713 - accuracy: 0.5778 - val_loss: 0.6707 - val_accuracy: 0.5682
#
# Epoch 00071: val_loss did not improve from 0.65157
# Epoch 72/1000
#  - 64s - loss: 0.6725 - accuracy: 0.5775 - val_loss: 0.7011 - val_accuracy: 0.5823
#
# Epoch 00072: val_loss did not improve from 0.65157
# Epoch 73/1000
#  - 64s - loss: 0.6710 - accuracy: 0.5791 - val_loss: 0.6585 - val_accuracy: 0.5728
#
# Epoch 00073: val_loss did not improve from 0.65157
# Epoch 74/1000
#  - 64s - loss: 0.6706 - accuracy: 0.5813 - val_loss: 0.6858 - val_accuracy: 0.5630
#
# Epoch 00074: val_loss did not improve from 0.65157
# Epoch 75/1000
#  - 64s - loss: 0.6700 - accuracy: 0.5832 - val_loss: 0.6922 - val_accuracy: 0.5669
#
# Epoch 00075: val_loss did not improve from 0.65157
# Epoch 76/1000
#  - 65s - loss: 0.6697 - accuracy: 0.5813 - val_loss: 0.6960 - val_accuracy: 0.5721
#
# Epoch 00076: val_loss did not improve from 0.65157
# Epoch 77/1000
#  - 65s - loss: 0.6692 - accuracy: 0.5827 - val_loss: 0.6875 - val_accuracy: 0.5815
#
# Epoch 00077: val_loss did not improve from 0.65157
# Epoch 78/1000
#  - 65s - loss: 0.6686 - accuracy: 0.5820 - val_loss: 0.6497 - val_accuracy: 0.5800
#
# Epoch 00078: val_loss improved from 0.65157 to 0.64969, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_tick_updown_pr.h5
# Epoch 79/1000
#  - 65s - loss: 0.6681 - accuracy: 0.5842 - val_loss: 0.6826 - val_accuracy: 0.5785
#
# Epoch 00079: val_loss did not improve from 0.64969
# Epoch 80/1000
#  - 64s - loss: 0.6672 - accuracy: 0.5851 - val_loss: 0.6385 - val_accuracy: 0.5769
#
# Epoch 00080: val_loss improved from 0.64969 to 0.63845, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_tick_updown_pr.h5
# Epoch 81/1000
#  - 65s - loss: 0.6660 - accuracy: 0.5880 - val_loss: 0.6582 - val_accuracy: 0.5823
#
# Epoch 00081: val_loss did not improve from 0.63845
# Epoch 82/1000
#  - 64s - loss: 0.6662 - accuracy: 0.5888 - val_loss: 0.6560 - val_accuracy: 0.5846
#
# Epoch 00082: val_loss did not improve from 0.63845
# Epoch 83/1000
#  - 65s - loss: 0.6659 - accuracy: 0.5887 - val_loss: 0.6701 - val_accuracy: 0.5632
#
# Epoch 00083: val_loss did not improve from 0.63845
# Epoch 84/1000
#  - 65s - loss: 0.6653 - accuracy: 0.5883 - val_loss: 0.6674 - val_accuracy: 0.5636
#
# Epoch 00084: val_loss did not improve from 0.63845
# Epoch 85/1000
#  - 64s - loss: 0.6647 - accuracy: 0.5913 - val_loss: 0.6561 - val_accuracy: 0.5711
#
# Epoch 00085: val_loss did not improve from 0.63845
# Epoch 86/1000
#  - 64s - loss: 0.6644 - accuracy: 0.5917 - val_loss: 0.7212 - val_accuracy: 0.5619
#
# Epoch 00086: val_loss did not improve from 0.63845
# Epoch 87/1000
#  - 64s - loss: 0.6646 - accuracy: 0.5925 - val_loss: 0.6965 - val_accuracy: 0.5719
#
# Epoch 00087: val_loss did not improve from 0.63845
# Epoch 88/1000
#  - 64s - loss: 0.6635 - accuracy: 0.5907 - val_loss: 0.6852 - val_accuracy: 0.5589
#
# Epoch 00088: val_loss did not improve from 0.63845
# Epoch 89/1000
#  - 64s - loss: 0.6639 - accuracy: 0.5920 - val_loss: 0.7057 - val_accuracy: 0.5711
#
# Epoch 00089: val_loss did not improve from 0.63845
# Epoch 90/1000
#  - 64s - loss: 0.6628 - accuracy: 0.5931 - val_loss: 0.6727 - val_accuracy: 0.5829
#
# Epoch 00090: val_loss did not improve from 0.63845
# Epoch 91/1000
#  - 64s - loss: 0.6625 - accuracy: 0.5936 - val_loss: 0.6793 - val_accuracy: 0.5847
#
# Epoch 00091: val_loss did not improve from 0.63845
# Epoch 92/1000
#  - 64s - loss: 0.6616 - accuracy: 0.5938 - val_loss: 0.6268 - val_accuracy: 0.5864
#
# Epoch 00092: val_loss improved from 0.63845 to 0.62679, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_tick_updown_pr.h5
# Epoch 93/1000
#  - 65s - loss: 0.6604 - accuracy: 0.5969 - val_loss: 0.7350 - val_accuracy: 0.5765
#
# Epoch 00093: val_loss did not improve from 0.62679
# Epoch 94/1000
#  - 64s - loss: 0.6604 - accuracy: 0.5967 - val_loss: 0.6780 - val_accuracy: 0.5659
#
# Epoch 00094: val_loss did not improve from 0.62679
# Epoch 95/1000
#  - 65s - loss: 0.6598 - accuracy: 0.5964 - val_loss: 0.6542 - val_accuracy: 0.5700
#
# Epoch 00095: val_loss did not improve from 0.62679
# Epoch 96/1000
#  - 65s - loss: 0.6594 - accuracy: 0.5980 - val_loss: 0.6976 - val_accuracy: 0.5742
#
# Epoch 00096: val_loss did not improve from 0.62679
# Epoch 97/1000
#  - 64s - loss: 0.6582 - accuracy: 0.5989 - val_loss: 0.7114 - val_accuracy: 0.5692
#
# Epoch 00097: val_loss did not improve from 0.62679
# Epoch 98/1000
#  - 65s - loss: 0.6578 - accuracy: 0.6019 - val_loss: 0.7248 - val_accuracy: 0.5590
#
# Epoch 00098: val_loss did not improve from 0.62679
# Epoch 99/1000
#  - 64s - loss: 0.6576 - accuracy: 0.6007 - val_loss: 0.7015 - val_accuracy: 0.5865
#
# Epoch 00099: val_loss did not improve from 0.62679
# Epoch 100/1000
#  - 65s - loss: 0.6583 - accuracy: 0.5997 - val_loss: 0.6463 - val_accuracy: 0.5754
#
# Epoch 00100: val_loss did not improve from 0.62679
# Epoch 101/1000
#  - 64s - loss: 0.6576 - accuracy: 0.6008 - val_loss: 0.6710 - val_accuracy: 0.5695
#
# Epoch 00101: val_loss did not improve from 0.62679
# Epoch 102/1000
#  - 64s - loss: 0.6570 - accuracy: 0.6024 - val_loss: 0.6525 - val_accuracy: 0.5765
#
# Epoch 00102: val_loss did not improve from 0.62679
# Epoch 103/1000
#  - 65s - loss: 0.6566 - accuracy: 0.6021 - val_loss: 0.7261 - val_accuracy: 0.5772
#
# Epoch 00103: val_loss did not improve from 0.62679
# Epoch 104/1000
#  - 64s - loss: 0.6559 - accuracy: 0.6051 - val_loss: 0.6867 - val_accuracy: 0.5793
#
# Epoch 00104: val_loss did not improve from 0.62679
# Epoch 105/1000
#  - 64s - loss: 0.6550 - accuracy: 0.6048 - val_loss: 0.6803 - val_accuracy: 0.5845
#
# Epoch 00105: val_loss did not improve from 0.62679
# Epoch 106/1000
#  - 65s - loss: 0.6538 - accuracy: 0.6075 - val_loss: 0.6676 - val_accuracy: 0.5688
#
# Epoch 00106: val_loss did not improve from 0.62679
# Epoch 107/1000
#  - 65s - loss: 0.6545 - accuracy: 0.6059 - val_loss: 0.6790 - val_accuracy: 0.5755
#
# Epoch 00107: val_loss did not improve from 0.62679
# Epoch 108/1000
#  - 64s - loss: 0.6530 - accuracy: 0.6076 - val_loss: 0.7018 - val_accuracy: 0.5816
#
# Epoch 00108: val_loss did not improve from 0.62679
# Epoch 109/1000
#  - 64s - loss: 0.6540 - accuracy: 0.6066 - val_loss: 0.6746 - val_accuracy: 0.5881
#
# Epoch 00109: val_loss did not improve from 0.62679
# Epoch 110/1000
#  - 64s - loss: 0.6520 - accuracy: 0.6082 - val_loss: 0.6932 - val_accuracy: 0.5744
#
# Epoch 00110: val_loss did not improve from 0.62679
# Epoch 111/1000
#  - 64s - loss: 0.6520 - accuracy: 0.6074 - val_loss: 0.6488 - val_accuracy: 0.5874
#
# Epoch 00111: val_loss did not improve from 0.62679
# Epoch 112/1000
#  - 65s - loss: 0.6521 - accuracy: 0.6108 - val_loss: 0.6536 - val_accuracy: 0.5820
#
# Epoch 00112: val_loss did not improve from 0.62679
# Epoch 113/1000
#  - 64s - loss: 0.6510 - accuracy: 0.6134 - val_loss: 0.6787 - val_accuracy: 0.5761
#
# Epoch 00113: val_loss did not improve from 0.62679
# Epoch 114/1000
#  - 64s - loss: 0.6503 - accuracy: 0.6129 - val_loss: 0.6568 - val_accuracy: 0.5735
#
# Epoch 00114: val_loss did not improve from 0.62679
# Epoch 115/1000
#  - 65s - loss: 0.6502 - accuracy: 0.6120 - val_loss: 0.6848 - val_accuracy: 0.5668
#
# Epoch 00115: val_loss did not improve from 0.62679
# Epoch 116/1000
#  - 64s - loss: 0.6507 - accuracy: 0.6100 - val_loss: 0.6632 - val_accuracy: 0.5816
#
# Epoch 00116: val_loss did not improve from 0.62679
# Epoch 117/1000
#  - 64s - loss: 0.6491 - accuracy: 0.6127 - val_loss: 0.6616 - val_accuracy: 0.5770
#
# Epoch 00117: val_loss did not improve from 0.62679
# Epoch 118/1000
#  - 64s - loss: 0.6483 - accuracy: 0.6150 - val_loss: 0.6691 - val_accuracy: 0.5649
#
# Epoch 00118: val_loss did not improve from 0.62679
# Epoch 119/1000
#  - 65s - loss: 0.6483 - accuracy: 0.6143 - val_loss: 0.7244 - val_accuracy: 0.5730
#
# Epoch 00119: val_loss did not improve from 0.62679
# Epoch 120/1000
#  - 64s - loss: 0.6465 - accuracy: 0.6169 - val_loss: 0.6765 - val_accuracy: 0.5931
#
# Epoch 00120: val_loss did not improve from 0.62679
# Epoch 121/1000
#  - 64s - loss: 0.6481 - accuracy: 0.6139 - val_loss: 0.6862 - val_accuracy: 0.5685
#
# Epoch 00121: val_loss did not improve from 0.62679
# Epoch 122/1000
#  - 64s - loss: 0.6465 - accuracy: 0.6155 - val_loss: 0.6540 - val_accuracy: 0.5718
#
# Epoch 00122: val_loss did not improve from 0.62679
# Epoch 123/1000
#  - 64s - loss: 0.6456 - accuracy: 0.6180 - val_loss: 0.7019 - val_accuracy: 0.5771
#
# Epoch 00123: val_loss did not improve from 0.62679
# Epoch 124/1000
#  - 64s - loss: 0.6455 - accuracy: 0.6171 - val_loss: 0.6868 - val_accuracy: 0.5726
#
# Epoch 00124: val_loss did not improve from 0.62679
# Epoch 125/1000
#  - 64s - loss: 0.6457 - accuracy: 0.6173 - val_loss: 0.7217 - val_accuracy: 0.5764
#
# Epoch 00125: val_loss did not improve from 0.62679
# Epoch 126/1000
#  - 64s - loss: 0.6449 - accuracy: 0.6178 - val_loss: 0.7138 - val_accuracy: 0.5864
#
# Epoch 00126: val_loss did not improve from 0.62679
# Epoch 127/1000
#  - 64s - loss: 0.6430 - accuracy: 0.6200 - val_loss: 0.6851 - val_accuracy: 0.5924
#
# Epoch 00127: val_loss did not improve from 0.62679
# Epoch 128/1000
#  - 64s - loss: 0.6425 - accuracy: 0.6220 - val_loss: 0.6740 - val_accuracy: 0.5758
#
# Epoch 00128: val_loss did not improve from 0.62679
# Epoch 129/1000
#  - 64s - loss: 0.6426 - accuracy: 0.6225 - val_loss: 0.6168 - val_accuracy: 0.5849
#
# Epoch 00129: val_loss improved from 0.62679 to 0.61683, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_tick_updown_pr.h5
# Epoch 130/1000
#  - 65s - loss: 0.6426 - accuracy: 0.6207 - val_loss: 0.6880 - val_accuracy: 0.5777
#
# Epoch 00130: val_loss did not improve from 0.61683
# Epoch 131/1000
#  - 64s - loss: 0.6424 - accuracy: 0.6209 - val_loss: 0.6642 - val_accuracy: 0.5824
#
# Epoch 00131: val_loss did not improve from 0.61683
# Epoch 132/1000
#  - 64s - loss: 0.6409 - accuracy: 0.6244 - val_loss: 0.6888 - val_accuracy: 0.5870
#
# Epoch 00132: val_loss did not improve from 0.61683
# Epoch 133/1000
#  - 64s - loss: 0.6410 - accuracy: 0.6236 - val_loss: 0.6837 - val_accuracy: 0.5822
#
# Epoch 00133: val_loss did not improve from 0.61683
# Epoch 134/1000
#  - 64s - loss: 0.6403 - accuracy: 0.6266 - val_loss: 0.6995 - val_accuracy: 0.5682
#
# Epoch 00134: val_loss did not improve from 0.61683
# Epoch 135/1000
#  - 64s - loss: 0.6399 - accuracy: 0.6241 - val_loss: 0.6562 - val_accuracy: 0.5840
#
# Epoch 00135: val_loss did not improve from 0.61683
# Epoch 136/1000
#  - 64s - loss: 0.6399 - accuracy: 0.6273 - val_loss: 0.6582 - val_accuracy: 0.5726
#
# Epoch 00136: val_loss did not improve from 0.61683
# Epoch 137/1000
#  - 64s - loss: 0.6387 - accuracy: 0.6260 - val_loss: 0.6724 - val_accuracy: 0.5894
#
# Epoch 00137: val_loss did not improve from 0.61683
# Epoch 138/1000
#  - 64s - loss: 0.6384 - accuracy: 0.6267 - val_loss: 0.6265 - val_accuracy: 0.5906
#
# Epoch 00138: val_loss did not improve from 0.61683
# Epoch 139/1000
#  - 64s - loss: 0.6363 - accuracy: 0.6299 - val_loss: 0.6648 - val_accuracy: 0.5893
#
# Epoch 00139: val_loss did not improve from 0.61683
# Epoch 140/1000
#  - 64s - loss: 0.6377 - accuracy: 0.6273 - val_loss: 0.7895 - val_accuracy: 0.5812
#
# Epoch 00140: val_loss did not improve from 0.61683
# Epoch 141/1000
#  - 65s - loss: 0.6373 - accuracy: 0.6284 - val_loss: 0.6780 - val_accuracy: 0.5789
#
# Epoch 00141: val_loss did not improve from 0.61683
# Epoch 142/1000
#  - 65s - loss: 0.6367 - accuracy: 0.6284 - val_loss: 0.6679 - val_accuracy: 0.5779
#
# Epoch 00142: val_loss did not improve from 0.61683
# Epoch 143/1000
#  - 64s - loss: 0.6357 - accuracy: 0.6296 - val_loss: 0.7220 - val_accuracy: 0.5710
#
# Epoch 00143: val_loss did not improve from 0.61683
# Epoch 144/1000
#  - 64s - loss: 0.6350 - accuracy: 0.6296 - val_loss: 0.6574 - val_accuracy: 0.5800
#
# Epoch 00144: val_loss did not improve from 0.61683
# Epoch 145/1000
#  - 64s - loss: 0.6347 - accuracy: 0.6305 - val_loss: 0.6976 - val_accuracy: 0.5830
#
# Epoch 00145: val_loss did not improve from 0.61683
# Epoch 146/1000
#  - 64s - loss: 0.6353 - accuracy: 0.6295 - val_loss: 0.7063 - val_accuracy: 0.5868
#
# Epoch 00146: val_loss did not improve from 0.61683
# Epoch 147/1000
#  - 64s - loss: 0.6338 - accuracy: 0.6327 - val_loss: 0.6555 - val_accuracy: 0.5954
#
# Epoch 00147: val_loss did not improve from 0.61683
# Epoch 148/1000
#  - 65s - loss: 0.6328 - accuracy: 0.6344 - val_loss: 0.7126 - val_accuracy: 0.5832
#
# Epoch 00148: val_loss did not improve from 0.61683
# Epoch 149/1000
#  - 64s - loss: 0.6323 - accuracy: 0.6340 - val_loss: 0.7079 - val_accuracy: 0.5920
#
# Epoch 00149: val_loss did not improve from 0.61683
# Epoch 150/1000
#  - 64s - loss: 0.6316 - accuracy: 0.6366 - val_loss: 0.6628 - val_accuracy: 0.5867
#
# Epoch 00150: val_loss did not improve from 0.61683
# Epoch 151/1000
#  - 65s - loss: 0.6332 - accuracy: 0.6326 - val_loss: 0.7340 - val_accuracy: 0.5859
#
# Epoch 00151: val_loss did not improve from 0.61683
# Epoch 152/1000
#  - 64s - loss: 0.6306 - accuracy: 0.6349 - val_loss: 0.7482 - val_accuracy: 0.5926
#
# Epoch 00152: val_loss did not improve from 0.61683
# Epoch 153/1000
#  - 64s - loss: 0.6311 - accuracy: 0.6339 - val_loss: 0.7515 - val_accuracy: 0.5968
#
# Epoch 00153: val_loss did not improve from 0.61683
# Epoch 154/1000
#  - 64s - loss: 0.6294 - accuracy: 0.6374 - val_loss: 0.7284 - val_accuracy: 0.5863
#
# Epoch 00154: val_loss did not improve from 0.61683
# Epoch 155/1000
#  - 65s - loss: 0.6284 - accuracy: 0.6388 - val_loss: 0.6493 - val_accuracy: 0.5957
#
# Epoch 00155: val_loss did not improve from 0.61683
# Epoch 156/1000
#  - 65s - loss: 0.6281 - accuracy: 0.6397 - val_loss: 0.6607 - val_accuracy: 0.5973
#
# Epoch 00156: val_loss did not improve from 0.61683
# Epoch 157/1000
#  - 64s - loss: 0.6279 - accuracy: 0.6396 - val_loss: 0.6934 - val_accuracy: 0.5970
#
# Epoch 00157: val_loss did not improve from 0.61683
# Epoch 158/1000
#  - 64s - loss: 0.6281 - accuracy: 0.6379 - val_loss: 0.6756 - val_accuracy: 0.5981
#
# Epoch 00158: val_loss did not improve from 0.61683
# Epoch 159/1000
#  - 65s - loss: 0.6277 - accuracy: 0.6398 - val_loss: 0.6876 - val_accuracy: 0.5903
#
# Epoch 00159: val_loss did not improve from 0.61683
# Epoch 160/1000
#  - 64s - loss: 0.6258 - accuracy: 0.6419 - val_loss: 0.7215 - val_accuracy: 0.5853
#
# Epoch 00160: val_loss did not improve from 0.61683
# Epoch 161/1000
#  - 64s - loss: 0.6251 - accuracy: 0.6419 - val_loss: 0.6646 - val_accuracy: 0.5778
#
# Epoch 00161: val_loss did not improve from 0.61683
# Epoch 162/1000
#  - 64s - loss: 0.6244 - accuracy: 0.6431 - val_loss: 0.7103 - val_accuracy: 0.5785
#
# Epoch 00162: val_loss did not improve from 0.61683
# Epoch 163/1000
#  - 64s - loss: 0.6262 - accuracy: 0.6396 - val_loss: 0.6955 - val_accuracy: 0.5983
#
# Epoch 00163: val_loss did not improve from 0.61683
# Epoch 164/1000
#  - 64s - loss: 0.6253 - accuracy: 0.6423 - val_loss: 0.7417 - val_accuracy: 0.5775
#
# Epoch 00164: val_loss did not improve from 0.61683
# Epoch 165/1000
#  - 64s - loss: 0.6245 - accuracy: 0.6434 - val_loss: 0.6988 - val_accuracy: 0.5772
#
# Epoch 00165: val_loss did not improve from 0.61683
# Epoch 166/1000
#  - 64s - loss: 0.6241 - accuracy: 0.6442 - val_loss: 0.6299 - val_accuracy: 0.6085
#
# Epoch 00166: val_loss did not improve from 0.61683
# Epoch 167/1000
#  - 64s - loss: 0.6225 - accuracy: 0.6466 - val_loss: 0.6623 - val_accuracy: 0.5950
#
# Epoch 00167: val_loss did not improve from 0.61683
# Epoch 168/1000
#  - 64s - loss: 0.6221 - accuracy: 0.6467 - val_loss: 0.7207 - val_accuracy: 0.5971
#
# Epoch 00168: val_loss did not improve from 0.61683
# Epoch 169/1000
#  - 64s - loss: 0.6228 - accuracy: 0.6440 - val_loss: 0.6873 - val_accuracy: 0.6012
#
# Epoch 00169: val_loss did not improve from 0.61683
# Epoch 170/1000
#  - 64s - loss: 0.6225 - accuracy: 0.6445 - val_loss: 0.6626 - val_accuracy: 0.5783
#
# Epoch 00170: val_loss did not improve from 0.61683
# Epoch 171/1000
#  - 64s - loss: 0.6212 - accuracy: 0.6450 - val_loss: 0.6960 - val_accuracy: 0.5940
#
# Epoch 00171: val_loss did not improve from 0.61683
# Epoch 172/1000
#  - 64s - loss: 0.6205 - accuracy: 0.6455 - val_loss: 0.6834 - val_accuracy: 0.6036
#
# Epoch 00172: val_loss did not improve from 0.61683
# Epoch 173/1000
#  - 64s - loss: 0.6202 - accuracy: 0.6480 - val_loss: 0.7229 - val_accuracy: 0.5844
#
# Epoch 00173: val_loss did not improve from 0.61683
# Epoch 174/1000
#  - 64s - loss: 0.6191 - accuracy: 0.6489 - val_loss: 0.7351 - val_accuracy: 0.5833
#
# Epoch 00174: val_loss did not improve from 0.61683
# Epoch 175/1000
#  - 64s - loss: 0.6188 - accuracy: 0.6483 - val_loss: 0.6493 - val_accuracy: 0.5926
#
# Epoch 00175: val_loss did not improve from 0.61683
# Epoch 176/1000
#  - 64s - loss: 0.6193 - accuracy: 0.6473 - val_loss: 0.7213 - val_accuracy: 0.5943
#
# Epoch 00176: val_loss did not improve from 0.61683
# Epoch 177/1000
#  - 64s - loss: 0.6186 - accuracy: 0.6489 - val_loss: 0.6911 - val_accuracy: 0.5862
#
# Epoch 00177: val_loss did not improve from 0.61683
# Epoch 178/1000
#  - 64s - loss: 0.6171 - accuracy: 0.6520 - val_loss: 0.7110 - val_accuracy: 0.5908
#
# Epoch 00178: val_loss did not improve from 0.61683
# Epoch 179/1000
#  - 64s - loss: 0.6171 - accuracy: 0.6504 - val_loss: 0.6690 - val_accuracy: 0.5958
#
# Epoch 00179: val_loss did not improve from 0.61683
# Epoch 180/1000
#  - 64s - loss: 0.6163 - accuracy: 0.6507 - val_loss: 0.7026 - val_accuracy: 0.5874
#
# Epoch 00180: val_loss did not improve from 0.61683
# Epoch 181/1000
#  - 64s - loss: 0.6156 - accuracy: 0.6502 - val_loss: 0.6603 - val_accuracy: 0.5898
#
# Epoch 00181: val_loss did not improve from 0.61683
# Epoch 182/1000
#  - 64s - loss: 0.6157 - accuracy: 0.6523 - val_loss: 0.6761 - val_accuracy: 0.5998
#
# Epoch 00182: val_loss did not improve from 0.61683
# Epoch 183/1000
#  - 64s - loss: 0.6162 - accuracy: 0.6513 - val_loss: 0.6879 - val_accuracy: 0.5891
#
# Epoch 00183: val_loss did not improve from 0.61683
# Epoch 184/1000
#  - 65s - loss: 0.6146 - accuracy: 0.6525 - val_loss: 0.7129 - val_accuracy: 0.5980
#
# Epoch 00184: val_loss did not improve from 0.61683
# Epoch 185/1000
#  - 64s - loss: 0.6131 - accuracy: 0.6532 - val_loss: 0.8071 - val_accuracy: 0.5812
#
# Epoch 00185: val_loss did not improve from 0.61683
# Epoch 186/1000
#  - 64s - loss: 0.6140 - accuracy: 0.6532 - val_loss: 0.7693 - val_accuracy: 0.5876
#
# Epoch 00186: val_loss did not improve from 0.61683
# Epoch 187/1000
#  - 64s - loss: 0.6124 - accuracy: 0.6542 - val_loss: 0.6769 - val_accuracy: 0.6041
#
# Epoch 00187: val_loss did not improve from 0.61683
# Epoch 188/1000
#  - 64s - loss: 0.6129 - accuracy: 0.6529 - val_loss: 0.6962 - val_accuracy: 0.5838
#
# Epoch 00188: val_loss did not improve from 0.61683
# Epoch 189/1000
#  - 64s - loss: 0.6115 - accuracy: 0.6555 - val_loss: 0.7666 - val_accuracy: 0.5988
#
# Epoch 00189: val_loss did not improve from 0.61683
# Epoch 190/1000

# %%
ckpt_path = current_path + 'ckpt/'
model_name = 'classifier_45_tick_updown_pr_05890.h5'

model = keras.models.load_model(ckpt_path + model_name)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)

# thresh = 0.19
# threshold = [thresh]
print('threshold :', threshold)
break

acc_pr_bythr = []
for thresh in threshold:

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  print('precision :', precision_score(y_test, y_pred))
  print('recall :', recall_score(y_test, y_pred))
  print()

  print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # plt.show()  
  print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
    print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
    print('thresh :', thresh)
    
  # if len(threshold) == 1:
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(test_pr_list))
    plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
  # plt.show()

    plt.subplot(122)
    plt.plot(np.cumprod(pred_pr_list))
    plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])

print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(threshold, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()
# Out:
# test_result.shape : (62962, 2)
# pr_val.shape : (62963, 1)
# y_test[:5] : [1 1 1 0 0]
# y_score[:5] : [[0.2948681 ]
#  [0.6902475 ]
#  [0.53798735]
#  [0.48823205]
#  [0.40587106]]
# y_test.shape : (62962, 1)
# y_score.shape : (62962, 1)
# len(y_test) : 62962
# threshold : [0.02105404 0.02282055 0.02516908 ... 0.9749477  0.98232055 0.98568094]
#   File "<ipython-input-12-76fcc560d050>", line 32
#     break
#          ^
# SyntaxError: 'break' outside loop

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
