# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %tensorflow_version 1.x
# %matplotlib inline

# input_data_length = int(input('input_data_length : '))
input_data_length = 20
model_num = 113
num_classes = 2

gdrive_path = '/content/gdrive/My Drive/Colab Notebooks/'

Made_X = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)


#       dataset 분리      #
# dataX 구성 : VOLUME, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
Made_X = Made_X[:, :, [0, 1, 2, 3, -2]]
print(Made_X.shape)
print(Made_Y.shape)

row = Made_X.shape[1]
col = Made_X.shape[2]

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(Made_X, Made_Y, test_size=0.4,
                                                   shuffle=False)
X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5,
                                                   shuffle=False)

X_train = X_train.astype('float32').reshape(-1, input_data_length, col, 1)
X_test = X_test.astype('float32').reshape(-1, input_data_length, col, 1)
X_val = X_val.astype('float32').reshape(-1, input_data_length, col, 1)
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)

from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 

# Data Class Weight
from sklearn.utils import class_weight

print(Y_train[:, 0])
class_weights = class_weight.compute_class_weight('balanced', 
                                                  np.unique(Y_train[:, 0]),
                                                  Y_train[:, 0])
class_weights = dict(enumerate(class_weights))
print(class_weights)
# quit()

Y_train = Y_train.astype('float32')
Y_test = Y_test.astype('float32')
Y_val = Y_val.astype('float32')
Y_train = np_utils.to_categorical(Y_train, num_classes)
Y_test = np_utils.to_categorical(Y_test, num_classes)
Y_val = np_utils.to_categorical(Y_val, num_classes)
print(Y_train.shape)
print(Y_test.shape)
print(Y_val.shape)

datagen = ImageDataGenerator( 
#     rotation_range = 60,
#     zoom_range = 0.6,
#     shear_range = 0.6,
#     horizontal_flip = True,
#     width_shift_range=0.6,
#     height_shift_range=0.6,
    fill_mode = 'nearest'
    )

testgen = ImageDataGenerator( 
    )
datagen.fit(X_train)
batch_size = 128

for X_batch, _ in datagen.flow(X_train, Y_train, batch_size=9):
    for i in range(0, 9): 
        pyplot.axis('off') 
        pyplot.subplot(330 + 1 + i) 
        pyplot.imshow(X_batch[i].reshape(input_data_length, col))
    pyplot.axis('off') 
    pyplot.show() 
    break
    
    
train_flow = datagen.flow(X_train, Y_train, batch_size=batch_size) 
val_flow = testgen.flow(X_val, Y_val, batch_size=batch_size) 


from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix

def FER_Model(input_shape=(row, col, 1)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(64, kernel_size=3, padding='same')(visible)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_1 = net

    net = layers.Conv2D(128, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

    net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
    
    return model

model = FER_Model()
# from keras.models import load_model
# model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_ohlcmacd.hdf5' % (input_data_length, model_num))
opt = Adam(lr=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
  
    
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath = gdrive_path + "model/rapid_ascending %s_%s_ohlcmacd.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=100)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 500
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(X_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(X_val) / batch_size,
                    shuffle=False)
# Out:
# (184418, 20, 5)
# (184418, 1)
# (110650, 20, 5, 1)
# (36884, 20, 5, 1)
# (36884, 20, 5, 1)
# [0. 0. 0. ... 0. 0. 0.]
# {0: 0.5046934437744592, 1: 53.76579203109815}
# (110650, 2)
# (36884, 2)
# (36884, 2)
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 20, 5, 1)          0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 20, 5, 64)         640
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 20, 5, 64)         0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 10, 2, 64)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 10, 2, 128)        73856
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 10, 2, 128)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 5, 1, 128)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 5, 1, 256)         295168
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 5, 1, 256)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                81984
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 451,778
# Trainable params: 451,778
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/500
#  - 7s - loss: 0.6498 - accuracy: 0.7776 - val_loss: 0.7697 - val_accuracy: 0.5755
#
# Epoch 00001: val_loss improved from inf to 0.76973, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 2/500
#  - 7s - loss: 0.6147 - accuracy: 0.7696 - val_loss: 0.7625 - val_accuracy: 0.4948
#
# Epoch 00002: val_loss improved from 0.76973 to 0.76254, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 3/500
#  - 7s - loss: 0.5980 - accuracy: 0.7758 - val_loss: 0.7918 - val_accuracy: 0.6173
#
# Epoch 00003: val_loss did not improve from 0.76254
# Epoch 4/500
#  - 7s - loss: 0.5865 - accuracy: 0.7889 - val_loss: 0.5148 - val_accuracy: 0.6935
#
# Epoch 00004: val_loss improved from 0.76254 to 0.51476, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 5/500
#  - 7s - loss: 0.5768 - accuracy: 0.7770 - val_loss: 1.0371 - val_accuracy: 0.3743
#
# Epoch 00005: val_loss did not improve from 0.51476
# Epoch 6/500
#  - 7s - loss: 0.5708 - accuracy: 0.7769 - val_loss: 0.9660 - val_accuracy: 0.4250
#
# Epoch 00006: val_loss did not improve from 0.51476
# Epoch 7/500
#  - 7s - loss: 0.5641 - accuracy: 0.7777 - val_loss: 0.6565 - val_accuracy: 0.6764
#
# Epoch 00007: val_loss did not improve from 0.51476
# Epoch 8/500
#  - 7s - loss: 0.5580 - accuracy: 0.7920 - val_loss: 0.6161 - val_accuracy: 0.5521
#
# Epoch 00008: val_loss did not improve from 0.51476
# Epoch 9/500
#  - 7s - loss: 0.5440 - accuracy: 0.7834 - val_loss: 0.6500 - val_accuracy: 0.7244
#
# Epoch 00009: val_loss did not improve from 0.51476
# Epoch 10/500
#  - 7s - loss: 0.5357 - accuracy: 0.7932 - val_loss: 0.4509 - val_accuracy: 0.8759
#
# Epoch 00010: val_loss improved from 0.51476 to 0.45095, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 11/500
#  - 7s - loss: 0.5283 - accuracy: 0.8001 - val_loss: 0.6541 - val_accuracy: 0.5070
#
# Epoch 00011: val_loss did not improve from 0.45095
# Epoch 12/500
#  - 7s - loss: 0.5196 - accuracy: 0.8033 - val_loss: 0.4684 - val_accuracy: 0.6803
#
# Epoch 00012: val_loss did not improve from 0.45095
# Epoch 13/500
#  - 7s - loss: 0.5121 - accuracy: 0.8042 - val_loss: 0.6377 - val_accuracy: 0.7730
#
# Epoch 00013: val_loss did not improve from 0.45095
# Epoch 14/500
#  - 7s - loss: 0.5034 - accuracy: 0.8159 - val_loss: 0.4985 - val_accuracy: 0.7595
#
# Epoch 00014: val_loss did not improve from 0.45095
# Epoch 15/500
#  - 7s - loss: 0.4928 - accuracy: 0.8161 - val_loss: 0.6062 - val_accuracy: 0.6809
#
# Epoch 00015: val_loss did not improve from 0.45095
# Epoch 16/500
#  - 7s - loss: 0.4870 - accuracy: 0.8237 - val_loss: 0.5532 - val_accuracy: 0.7508
#
# Epoch 00016: val_loss did not improve from 0.45095
# Epoch 17/500
#  - 7s - loss: 0.4833 - accuracy: 0.8187 - val_loss: 0.3726 - val_accuracy: 0.8243
#
# Epoch 00017: val_loss improved from 0.45095 to 0.37260, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 18/500
#  - 7s - loss: 0.4743 - accuracy: 0.8223 - val_loss: 0.5981 - val_accuracy: 0.7486
#
# Epoch 00018: val_loss did not improve from 0.37260
# Epoch 19/500
#  - 7s - loss: 0.4739 - accuracy: 0.8240 - val_loss: 0.9230 - val_accuracy: 0.6955
#
# Epoch 00019: val_loss did not improve from 0.37260
# Epoch 20/500
#  - 7s - loss: 0.4695 - accuracy: 0.8225 - val_loss: 0.8227 - val_accuracy: 0.6592
#
# Epoch 00020: val_loss did not improve from 0.37260
# Epoch 21/500
#  - 7s - loss: 0.4653 - accuracy: 0.8293 - val_loss: 0.5860 - val_accuracy: 0.8025
#
# Epoch 00021: val_loss did not improve from 0.37260
# Epoch 22/500
#  - 7s - loss: 0.4649 - accuracy: 0.8236 - val_loss: 0.5996 - val_accuracy: 0.7375
#
# Epoch 00022: val_loss did not improve from 0.37260
# Epoch 23/500
#  - 7s - loss: 0.4655 - accuracy: 0.8219 - val_loss: 0.8086 - val_accuracy: 0.6839
#
# Epoch 00023: val_loss did not improve from 0.37260
# Epoch 24/500
#  - 7s - loss: 0.4605 - accuracy: 0.8206 - val_loss: 0.4922 - val_accuracy: 0.8040
#
# Epoch 00024: val_loss did not improve from 0.37260
# Epoch 25/500
#  - 7s - loss: 0.4562 - accuracy: 0.8279 - val_loss: 0.6951 - val_accuracy: 0.7517
#
# Epoch 00025: val_loss did not improve from 0.37260
# Epoch 26/500
#  - 7s - loss: 0.4554 - accuracy: 0.8235 - val_loss: 0.9513 - val_accuracy: 0.6320
#
# Epoch 00026: val_loss did not improve from 0.37260
# Epoch 27/500
#  - 7s - loss: 0.4556 - accuracy: 0.8226 - val_loss: 0.4063 - val_accuracy: 0.8142
#
# Epoch 00027: val_loss did not improve from 0.37260
# Epoch 28/500
#  - 7s - loss: 0.4558 - accuracy: 0.8246 - val_loss: 0.5711 - val_accuracy: 0.8298
#
# Epoch 00028: val_loss did not improve from 0.37260
# Epoch 29/500
#  - 7s - loss: 0.4503 - accuracy: 0.8270 - val_loss: 0.5704 - val_accuracy: 0.7685
#
# Epoch 00029: val_loss did not improve from 0.37260
# Epoch 30/500
#  - 7s - loss: 0.4495 - accuracy: 0.8275 - val_loss: 0.6606 - val_accuracy: 0.6160
#
# Epoch 00030: val_loss did not improve from 0.37260
# Epoch 31/500
#  - 7s - loss: 0.4466 - accuracy: 0.8215 - val_loss: 0.3615 - val_accuracy: 0.8528
#
# Epoch 00031: val_loss improved from 0.37260 to 0.36153, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 32/500
#  - 7s - loss: 0.4441 - accuracy: 0.8226 - val_loss: 0.4585 - val_accuracy: 0.8083
#
# Epoch 00032: val_loss did not improve from 0.36153
# Epoch 33/500
#  - 7s - loss: 0.4414 - accuracy: 0.8276 - val_loss: 0.5187 - val_accuracy: 0.7535
#
# Epoch 00033: val_loss did not improve from 0.36153
# Epoch 34/500
#  - 7s - loss: 0.4448 - accuracy: 0.8232 - val_loss: 0.3910 - val_accuracy: 0.7965
#
# Epoch 00034: val_loss did not improve from 0.36153
# Epoch 35/500
#  - 7s - loss: 0.4386 - accuracy: 0.8276 - val_loss: 0.4238 - val_accuracy: 0.7555
#
# Epoch 00035: val_loss did not improve from 0.36153
# Epoch 36/500
#  - 7s - loss: 0.4362 - accuracy: 0.8194 - val_loss: 0.5986 - val_accuracy: 0.6618
#
# Epoch 00036: val_loss did not improve from 0.36153
# Epoch 37/500
#  - 7s - loss: 0.4353 - accuracy: 0.8254 - val_loss: 0.4105 - val_accuracy: 0.7661
#
# Epoch 00037: val_loss did not improve from 0.36153
# Epoch 38/500
#  - 7s - loss: 0.4368 - accuracy: 0.8253 - val_loss: 0.7235 - val_accuracy: 0.6987
#
# Epoch 00038: val_loss did not improve from 0.36153
# Epoch 39/500
#  - 7s - loss: 0.4374 - accuracy: 0.8195 - val_loss: 0.4839 - val_accuracy: 0.8150
#
# Epoch 00039: val_loss did not improve from 0.36153
# Epoch 40/500
#  - 7s - loss: 0.4318 - accuracy: 0.8291 - val_loss: 0.4911 - val_accuracy: 0.7582
#
# Epoch 00040: val_loss did not improve from 0.36153
# Epoch 41/500
#  - 7s - loss: 0.4340 - accuracy: 0.8238 - val_loss: 0.4183 - val_accuracy: 0.7601
#
# Epoch 00041: val_loss did not improve from 0.36153
# Epoch 42/500
#  - 7s - loss: 0.4300 - accuracy: 0.8222 - val_loss: 0.7595 - val_accuracy: 0.8030
#
# Epoch 00042: val_loss did not improve from 0.36153
# Epoch 43/500
#  - 7s - loss: 0.4289 - accuracy: 0.8270 - val_loss: 0.5091 - val_accuracy: 0.7812
#
# Epoch 00043: val_loss did not improve from 0.36153
# Epoch 44/500
#  - 7s - loss: 0.4263 - accuracy: 0.8247 - val_loss: 0.6756 - val_accuracy: 0.7655
#
# Epoch 00044: val_loss did not improve from 0.36153
# Epoch 45/500
#  - 7s - loss: 0.4242 - accuracy: 0.8261 - val_loss: 0.3493 - val_accuracy: 0.8080
#
# Epoch 00045: val_loss improved from 0.36153 to 0.34933, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 46/500
#  - 7s - loss: 0.4282 - accuracy: 0.8269 - val_loss: 0.8644 - val_accuracy: 0.7230
#
# Epoch 00046: val_loss did not improve from 0.34933
# Epoch 47/500
#  - 7s - loss: 0.4270 - accuracy: 0.8242 - val_loss: 0.5683 - val_accuracy: 0.8370
#
# Epoch 00047: val_loss did not improve from 0.34933
# Epoch 48/500
#  - 7s - loss: 0.4250 - accuracy: 0.8287 - val_loss: 0.5609 - val_accuracy: 0.7623
#
# Epoch 00048: val_loss did not improve from 0.34933
# Epoch 49/500
#  - 7s - loss: 0.4188 - accuracy: 0.8254 - val_loss: 0.5173 - val_accuracy: 0.8737
#
# Epoch 00049: val_loss did not improve from 0.34933
# Epoch 50/500
#  - 7s - loss: 0.4212 - accuracy: 0.8259 - val_loss: 0.4400 - val_accuracy: 0.6838
#
# Epoch 00050: val_loss did not improve from 0.34933
# Epoch 51/500
#  - 7s - loss: 0.4217 - accuracy: 0.8251 - val_loss: 0.6029 - val_accuracy: 0.6304
#
# Epoch 00051: val_loss did not improve from 0.34933
# Epoch 52/500
#  - 7s - loss: 0.4195 - accuracy: 0.8236 - val_loss: 0.6586 - val_accuracy: 0.7624
#
# Epoch 00052: val_loss did not improve from 0.34933
# Epoch 53/500
#  - 7s - loss: 0.4149 - accuracy: 0.8285 - val_loss: 0.5340 - val_accuracy: 0.7087
#
# Epoch 00053: val_loss did not improve from 0.34933
# Epoch 54/500
#  - 7s - loss: 0.4151 - accuracy: 0.8272 - val_loss: 0.6926 - val_accuracy: 0.6880
#
# Epoch 00054: val_loss did not improve from 0.34933
# Epoch 55/500
#  - 7s - loss: 0.4200 - accuracy: 0.8233 - val_loss: 0.3908 - val_accuracy: 0.7752
#
# Epoch 00055: val_loss did not improve from 0.34933
# Epoch 56/500
#  - 7s - loss: 0.4113 - accuracy: 0.8256 - val_loss: 0.3586 - val_accuracy: 0.7487
#
# Epoch 00056: val_loss did not improve from 0.34933
# Epoch 57/500
#  - 7s - loss: 0.4153 - accuracy: 0.8243 - val_loss: 0.5203 - val_accuracy: 0.7331
#
# Epoch 00057: val_loss did not improve from 0.34933
# Epoch 58/500
#  - 7s - loss: 0.4096 - accuracy: 0.8263 - val_loss: 0.6499 - val_accuracy: 0.7344
#
# Epoch 00058: val_loss did not improve from 0.34933
# Epoch 59/500
#  - 7s - loss: 0.4095 - accuracy: 0.8237 - val_loss: 0.2973 - val_accuracy: 0.8200
#
# Epoch 00059: val_loss improved from 0.34933 to 0.29728, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 60/500
#  - 7s - loss: 0.4074 - accuracy: 0.8286 - val_loss: 0.5266 - val_accuracy: 0.7929
#
# Epoch 00060: val_loss did not improve from 0.29728
# Epoch 61/500
#  - 7s - loss: 0.4094 - accuracy: 0.8274 - val_loss: 0.4277 - val_accuracy: 0.7566
#
# Epoch 00061: val_loss did not improve from 0.29728
# Epoch 62/500
#  - 7s - loss: 0.4089 - accuracy: 0.8244 - val_loss: 0.4140 - val_accuracy: 0.7764
#
# Epoch 00062: val_loss did not improve from 0.29728
# Epoch 63/500
#  - 7s - loss: 0.4054 - accuracy: 0.8252 - val_loss: 0.4204 - val_accuracy: 0.7962
#
# Epoch 00063: val_loss did not improve from 0.29728
# Epoch 64/500
#  - 7s - loss: 0.4022 - accuracy: 0.8263 - val_loss: 0.6378 - val_accuracy: 0.7248
#
# Epoch 00064: val_loss did not improve from 0.29728
# Epoch 65/500
#  - 7s - loss: 0.4018 - accuracy: 0.8254 - val_loss: 0.6953 - val_accuracy: 0.6849
#
# Epoch 00065: val_loss did not improve from 0.29728
# Epoch 66/500
#  - 7s - loss: 0.4036 - accuracy: 0.8239 - val_loss: 0.2963 - val_accuracy: 0.7631
#
# Epoch 00066: val_loss improved from 0.29728 to 0.29630, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 67/500
#  - 7s - loss: 0.4004 - accuracy: 0.8251 - val_loss: 0.5605 - val_accuracy: 0.7620
#
# Epoch 00067: val_loss did not improve from 0.29630
# Epoch 68/500
#  - 7s - loss: 0.3991 - accuracy: 0.8284 - val_loss: 0.2422 - val_accuracy: 0.8060
#
# Epoch 00068: val_loss improved from 0.29630 to 0.24220, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 69/500
#  - 7s - loss: 0.3959 - accuracy: 0.8316 - val_loss: 0.3866 - val_accuracy: 0.7730
#
# Epoch 00069: val_loss did not improve from 0.24220
# Epoch 70/500
#  - 7s - loss: 0.3955 - accuracy: 0.8287 - val_loss: 0.5841 - val_accuracy: 0.7227
#
# Epoch 00070: val_loss did not improve from 0.24220
# Epoch 71/500
#  - 7s - loss: 0.3949 - accuracy: 0.8234 - val_loss: 0.6192 - val_accuracy: 0.7216
#
# Epoch 00071: val_loss did not improve from 0.24220
# Epoch 72/500
#  - 7s - loss: 0.3982 - accuracy: 0.8282 - val_loss: 0.4390 - val_accuracy: 0.7382
#
# Epoch 00072: val_loss did not improve from 0.24220
# Epoch 73/500
#  - 7s - loss: 0.3897 - accuracy: 0.8289 - val_loss: 0.3588 - val_accuracy: 0.7806
#
# Epoch 00073: val_loss did not improve from 0.24220
# Epoch 74/500
#  - 7s - loss: 0.3912 - accuracy: 0.8302 - val_loss: 0.5512 - val_accuracy: 0.7763
#
# Epoch 00074: val_loss did not improve from 0.24220
# Epoch 75/500
#  - 7s - loss: 0.3892 - accuracy: 0.8295 - val_loss: 0.2130 - val_accuracy: 0.8183
#
# Epoch 00075: val_loss improved from 0.24220 to 0.21296, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 76/500
#  - 7s - loss: 0.3879 - accuracy: 0.8313 - val_loss: 0.5540 - val_accuracy: 0.7360
#
# Epoch 00076: val_loss did not improve from 0.21296
# Epoch 77/500
#  - 7s - loss: 0.3892 - accuracy: 0.8253 - val_loss: 0.6024 - val_accuracy: 0.7867
#
# Epoch 00077: val_loss did not improve from 0.21296
# Epoch 78/500
#  - 7s - loss: 0.3853 - accuracy: 0.8290 - val_loss: 0.4345 - val_accuracy: 0.7756
#
# Epoch 00078: val_loss did not improve from 0.21296
# Epoch 79/500
#  - 7s - loss: 0.3845 - accuracy: 0.8317 - val_loss: 0.6966 - val_accuracy: 0.6910
#
# Epoch 00079: val_loss did not improve from 0.21296
# Epoch 80/500
#  - 7s - loss: 0.3828 - accuracy: 0.8311 - val_loss: 0.4557 - val_accuracy: 0.7104
#
# Epoch 00080: val_loss did not improve from 0.21296
# Epoch 81/500
#  - 7s - loss: 0.3792 - accuracy: 0.8328 - val_loss: 0.5742 - val_accuracy: 0.7968
#
# Epoch 00081: val_loss did not improve from 0.21296
# Epoch 82/500
#  - 7s - loss: 0.3800 - accuracy: 0.8315 - val_loss: 0.2583 - val_accuracy: 0.7152
#
# Epoch 00082: val_loss did not improve from 0.21296
# Epoch 83/500
#  - 7s - loss: 0.3793 - accuracy: 0.8335 - val_loss: 0.4184 - val_accuracy: 0.7507
#
# Epoch 00083: val_loss did not improve from 0.21296
# Epoch 84/500
#  - 7s - loss: 0.3807 - accuracy: 0.8279 - val_loss: 1.0034 - val_accuracy: 0.7726
#
# Epoch 00084: val_loss did not improve from 0.21296
# Epoch 85/500
#  - 7s - loss: 0.3751 - accuracy: 0.8319 - val_loss: 0.1632 - val_accuracy: 0.8560
#
# Epoch 00085: val_loss improved from 0.21296 to 0.16316, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 86/500
#  - 7s - loss: 0.3764 - accuracy: 0.8336 - val_loss: 0.4238 - val_accuracy: 0.7589
#
# Epoch 00086: val_loss did not improve from 0.16316
# Epoch 87/500
#  - 7s - loss: 0.3720 - accuracy: 0.8360 - val_loss: 0.5496 - val_accuracy: 0.7059
#
# Epoch 00087: val_loss did not improve from 0.16316
# Epoch 88/500
#  - 7s - loss: 0.3681 - accuracy: 0.8341 - val_loss: 0.2409 - val_accuracy: 0.8348
#
# Epoch 00088: val_loss did not improve from 0.16316
# Epoch 89/500
#  - 7s - loss: 0.3687 - accuracy: 0.8379 - val_loss: 0.8756 - val_accuracy: 0.7636
#
# Epoch 00089: val_loss did not improve from 0.16316
# Epoch 90/500
#  - 7s - loss: 0.3703 - accuracy: 0.8319 - val_loss: 0.1888 - val_accuracy: 0.8338
#
# Epoch 00090: val_loss did not improve from 0.16316
# Epoch 91/500
#  - 7s - loss: 0.3710 - accuracy: 0.8347 - val_loss: 0.3987 - val_accuracy: 0.7783
#
# Epoch 00091: val_loss did not improve from 0.16316
# Epoch 92/500
#  - 7s - loss: 0.3715 - accuracy: 0.8313 - val_loss: 0.5664 - val_accuracy: 0.7599
#
# Epoch 00092: val_loss did not improve from 0.16316
# Epoch 93/500
#  - 7s - loss: 0.3667 - accuracy: 0.8335 - val_loss: 0.5698 - val_accuracy: 0.7276
#
# Epoch 00093: val_loss did not improve from 0.16316
# Epoch 94/500
#  - 7s - loss: 0.3639 - accuracy: 0.8336 - val_loss: 0.5146 - val_accuracy: 0.7241
#
# Epoch 00094: val_loss did not improve from 0.16316
# Epoch 95/500
#  - 7s - loss: 0.3643 - accuracy: 0.8370 - val_loss: 0.3569 - val_accuracy: 0.8139
#
# Epoch 00095: val_loss did not improve from 0.16316
# Epoch 96/500
#  - 7s - loss: 0.3602 - accuracy: 0.8369 - val_loss: 0.4072 - val_accuracy: 0.8215
#
# Epoch 00096: val_loss did not improve from 0.16316
# Epoch 97/500
#  - 7s - loss: 0.3626 - accuracy: 0.8339 - val_loss: 0.3305 - val_accuracy: 0.7894
#
# Epoch 00097: val_loss did not improve from 0.16316
# Epoch 98/500
#  - 7s - loss: 0.3562 - accuracy: 0.8367 - val_loss: 0.3741 - val_accuracy: 0.7207
#
# Epoch 00098: val_loss did not improve from 0.16316
# Epoch 99/500
#  - 7s - loss: 0.3539 - accuracy: 0.8380 - val_loss: 0.3416 - val_accuracy: 0.7723
#
# Epoch 00099: val_loss did not improve from 0.16316
# Epoch 100/500
#  - 7s - loss: 0.3564 - accuracy: 0.8336 - val_loss: 0.5453 - val_accuracy: 0.7646
#
# Epoch 00100: val_loss did not improve from 0.16316
# Epoch 101/500
#  - 7s - loss: 0.3567 - accuracy: 0.8375 - val_loss: 0.5601 - val_accuracy: 0.8044
#
# Epoch 00101: val_loss did not improve from 0.16316
# Epoch 102/500
#  - 7s - loss: 0.3552 - accuracy: 0.8380 - val_loss: 0.6313 - val_accuracy: 0.7442
#
# Epoch 00102: val_loss did not improve from 0.16316
# Epoch 103/500
#  - 7s - loss: 0.3502 - accuracy: 0.8379 - val_loss: 0.4280 - val_accuracy: 0.7546
#
# Epoch 00103: val_loss did not improve from 0.16316
# Epoch 104/500
#  - 7s - loss: 0.3509 - accuracy: 0.8349 - val_loss: 0.3115 - val_accuracy: 0.7886
#
# Epoch 00104: val_loss did not improve from 0.16316
# Epoch 105/500
#  - 7s - loss: 0.3518 - accuracy: 0.8396 - val_loss: 0.3728 - val_accuracy: 0.7931
#
# Epoch 00105: val_loss did not improve from 0.16316
# Epoch 106/500
#  - 7s - loss: 0.3492 - accuracy: 0.8416 - val_loss: 0.4136 - val_accuracy: 0.7797
#
# Epoch 00106: val_loss did not improve from 0.16316
# Epoch 107/500
#  - 7s - loss: 0.3478 - accuracy: 0.8409 - val_loss: 0.4451 - val_accuracy: 0.7754
#
# Epoch 00107: val_loss did not improve from 0.16316
# Epoch 108/500
#  - 7s - loss: 0.3389 - accuracy: 0.8438 - val_loss: 0.3086 - val_accuracy: 0.8044
#
# Epoch 00108: val_loss did not improve from 0.16316
# Epoch 109/500
#  - 7s - loss: 0.3424 - accuracy: 0.8417 - val_loss: 0.4949 - val_accuracy: 0.8033
#
# Epoch 00109: val_loss did not improve from 0.16316
# Epoch 110/500
#  - 7s - loss: 0.3368 - accuracy: 0.8478 - val_loss: 0.5258 - val_accuracy: 0.7671
#
# Epoch 00110: val_loss did not improve from 0.16316
# Epoch 111/500
#  - 7s - loss: 0.3404 - accuracy: 0.8456 - val_loss: 0.4716 - val_accuracy: 0.7877
#
# Epoch 00111: val_loss did not improve from 0.16316
# Epoch 112/500
#  - 7s - loss: 0.3352 - accuracy: 0.8456 - val_loss: 0.2900 - val_accuracy: 0.8077
#
# Epoch 00112: val_loss did not improve from 0.16316
# Epoch 113/500
#  - 7s - loss: 0.3340 - accuracy: 0.8465 - val_loss: 0.2277 - val_accuracy: 0.7908
#
# Epoch 00113: val_loss did not improve from 0.16316
# Epoch 114/500
#  - 7s - loss: 0.3338 - accuracy: 0.8468 - val_loss: 0.6302 - val_accuracy: 0.7282
#
# Epoch 00114: val_loss did not improve from 0.16316
# Epoch 115/500
#  - 7s - loss: 0.3339 - accuracy: 0.8444 - val_loss: 0.3375 - val_accuracy: 0.8535
#
# Epoch 00115: val_loss did not improve from 0.16316
# Epoch 116/500
#  - 7s - loss: 0.3306 - accuracy: 0.8487 - val_loss: 0.3267 - val_accuracy: 0.7953
#
# Epoch 00116: val_loss did not improve from 0.16316
# Epoch 117/500
#  - 7s - loss: 0.3320 - accuracy: 0.8464 - val_loss: 0.5025 - val_accuracy: 0.7906
#
# Epoch 00117: val_loss did not improve from 0.16316
# Epoch 118/500
#  - 7s - loss: 0.3268 - accuracy: 0.8504 - val_loss: 0.2373 - val_accuracy: 0.8170
#
# Epoch 00118: val_loss did not improve from 0.16316
# Epoch 119/500
#  - 7s - loss: 0.3250 - accuracy: 0.8538 - val_loss: 0.3025 - val_accuracy: 0.6759
#
# Epoch 00119: val_loss did not improve from 0.16316
# Epoch 120/500
#  - 7s - loss: 0.3223 - accuracy: 0.8504 - val_loss: 0.4109 - val_accuracy: 0.7781
#
# Epoch 00120: val_loss did not improve from 0.16316
# Epoch 121/500
#  - 7s - loss: 0.3232 - accuracy: 0.8502 - val_loss: 0.2674 - val_accuracy: 0.8317
#
# Epoch 00121: val_loss did not improve from 0.16316
# Epoch 122/500
#  - 7s - loss: 0.3203 - accuracy: 0.8531 - val_loss: 0.2678 - val_accuracy: 0.8169
#
# Epoch 00122: val_loss did not improve from 0.16316
# Epoch 123/500
#  - 7s - loss: 0.3190 - accuracy: 0.8568 - val_loss: 0.4520 - val_accuracy: 0.7981
#
# Epoch 00123: val_loss did not improve from 0.16316
# Epoch 124/500
#  - 7s - loss: 0.3146 - accuracy: 0.8565 - val_loss: 0.9609 - val_accuracy: 0.7511
#
# Epoch 00124: val_loss did not improve from 0.16316
# Epoch 125/500
#  - 7s - loss: 0.3137 - accuracy: 0.8572 - val_loss: 0.3090 - val_accuracy: 0.7669
#
# Epoch 00125: val_loss did not improve from 0.16316
# Epoch 126/500
#  - 7s - loss: 0.3100 - accuracy: 0.8580 - val_loss: 0.4837 - val_accuracy: 0.7758
#
# Epoch 00126: val_loss did not improve from 0.16316
# Epoch 127/500
#  - 7s - loss: 0.3114 - accuracy: 0.8583 - val_loss: 0.4368 - val_accuracy: 0.7899
#
# Epoch 00127: val_loss did not improve from 0.16316
# Epoch 128/500
#  - 7s - loss: 0.3062 - accuracy: 0.8574 - val_loss: 0.4812 - val_accuracy: 0.7838
#
# Epoch 00128: val_loss did not improve from 0.16316
# Epoch 129/500
#  - 7s - loss: 0.3067 - accuracy: 0.8601 - val_loss: 0.3345 - val_accuracy: 0.7930
#
# Epoch 00129: val_loss did not improve from 0.16316
# Epoch 130/500
#  - 7s - loss: 0.3032 - accuracy: 0.8614 - val_loss: 0.4312 - val_accuracy: 0.8149
#
# Epoch 00130: val_loss did not improve from 0.16316
# Epoch 131/500
#  - 7s - loss: 0.3050 - accuracy: 0.8618 - val_loss: 0.4159 - val_accuracy: 0.7708
#
# Epoch 00131: val_loss did not improve from 0.16316
# Epoch 132/500
#  - 7s - loss: 0.3004 - accuracy: 0.8635 - val_loss: 0.6006 - val_accuracy: 0.7389
#
# Epoch 00132: val_loss did not improve from 0.16316
# Epoch 133/500
#  - 7s - loss: 0.2981 - accuracy: 0.8610 - val_loss: 0.3815 - val_accuracy: 0.8022
#
# Epoch 00133: val_loss did not improve from 0.16316
# Epoch 134/500
#  - 7s - loss: 0.3020 - accuracy: 0.8615 - val_loss: 0.5820 - val_accuracy: 0.7745
#
# Epoch 00134: val_loss did not improve from 0.16316
# Epoch 135/500
#  - 7s - loss: 0.3012 - accuracy: 0.8629 - val_loss: 0.9160 - val_accuracy: 0.7722
#
# Epoch 00135: val_loss did not improve from 0.16316
# Epoch 136/500
#  - 7s - loss: 0.2999 - accuracy: 0.8624 - val_loss: 0.4222 - val_accuracy: 0.8085
#
# Epoch 00136: val_loss did not improve from 0.16316
# Epoch 137/500
#  - 7s - loss: 0.2966 - accuracy: 0.8657 - val_loss: 0.1752 - val_accuracy: 0.7789
#
# Epoch 00137: val_loss did not improve from 0.16316
# Epoch 138/500
#  - 7s - loss: 0.2939 - accuracy: 0.8640 - val_loss: 0.1159 - val_accuracy: 0.8337
#
# Epoch 00138: val_loss improved from 0.16316 to 0.11590, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 139/500
#  - 7s - loss: 0.2924 - accuracy: 0.8654 - val_loss: 0.4184 - val_accuracy: 0.7763
#
# Epoch 00139: val_loss did not improve from 0.11590
# Epoch 140/500
#  - 7s - loss: 0.2888 - accuracy: 0.8662 - val_loss: 0.2005 - val_accuracy: 0.8564
#
# Epoch 00140: val_loss did not improve from 0.11590
# Epoch 141/500
#  - 7s - loss: 0.2907 - accuracy: 0.8687 - val_loss: 0.5466 - val_accuracy: 0.8100
#
# Epoch 00141: val_loss did not improve from 0.11590
# Epoch 142/500
#  - 7s - loss: 0.2887 - accuracy: 0.8673 - val_loss: 0.4679 - val_accuracy: 0.7921
#
# Epoch 00142: val_loss did not improve from 0.11590
# Epoch 143/500
#  - 7s - loss: 0.2866 - accuracy: 0.8676 - val_loss: 0.6721 - val_accuracy: 0.8141
#
# Epoch 00143: val_loss did not improve from 0.11590
# Epoch 144/500
#  - 7s - loss: 0.2864 - accuracy: 0.8692 - val_loss: 0.3771 - val_accuracy: 0.8155
#
# Epoch 00144: val_loss did not improve from 0.11590
# Epoch 145/500
#  - 7s - loss: 0.2861 - accuracy: 0.8672 - val_loss: 0.3438 - val_accuracy: 0.7877
#
# Epoch 00145: val_loss did not improve from 0.11590
# Epoch 146/500
#  - 7s - loss: 0.2750 - accuracy: 0.8737 - val_loss: 0.3704 - val_accuracy: 0.8276
#
# Epoch 00146: val_loss did not improve from 0.11590
# Epoch 147/500
#  - 7s - loss: 0.2795 - accuracy: 0.8734 - val_loss: 0.4100 - val_accuracy: 0.8043
#
# Epoch 00147: val_loss did not improve from 0.11590
# Epoch 148/500
#  - 7s - loss: 0.2793 - accuracy: 0.8696 - val_loss: 0.7525 - val_accuracy: 0.7727
#
# Epoch 00148: val_loss did not improve from 0.11590
# Epoch 149/500
#  - 7s - loss: 0.2813 - accuracy: 0.8697 - val_loss: 0.2661 - val_accuracy: 0.7793
#
# Epoch 00149: val_loss did not improve from 0.11590
# Epoch 150/500
#  - 7s - loss: 0.2738 - accuracy: 0.8712 - val_loss: 0.9218 - val_accuracy: 0.7964
#
# Epoch 00150: val_loss did not improve from 0.11590
# Epoch 151/500
#  - 7s - loss: 0.2710 - accuracy: 0.8745 - val_loss: 0.2941 - val_accuracy: 0.7620
#
# Epoch 00151: val_loss did not improve from 0.11590
# Epoch 152/500
#  - 7s - loss: 0.2753 - accuracy: 0.8709 - val_loss: 0.3136 - val_accuracy: 0.8647
#
# Epoch 00152: val_loss did not improve from 0.11590
# Epoch 153/500
#  - 7s - loss: 0.2699 - accuracy: 0.8778 - val_loss: 0.7071 - val_accuracy: 0.7963
#
# Epoch 00153: val_loss did not improve from 0.11590
# Epoch 154/500
#  - 7s - loss: 0.2675 - accuracy: 0.8771 - val_loss: 0.3441 - val_accuracy: 0.8339
#
# Epoch 00154: val_loss did not improve from 0.11590
# Epoch 155/500
#  - 7s - loss: 0.2645 - accuracy: 0.8802 - val_loss: 0.1418 - val_accuracy: 0.7615
#
# Epoch 00155: val_loss did not improve from 0.11590
# Epoch 156/500
#  - 7s - loss: 0.2735 - accuracy: 0.8733 - val_loss: 0.2855 - val_accuracy: 0.7614
#
# Epoch 00156: val_loss did not improve from 0.11590
# Epoch 157/500
#  - 7s - loss: 0.2629 - accuracy: 0.8790 - val_loss: 0.3435 - val_accuracy: 0.7834
#
# Epoch 00157: val_loss did not improve from 0.11590
# Epoch 158/500
#  - 7s - loss: 0.2591 - accuracy: 0.8786 - val_loss: 0.6413 - val_accuracy: 0.8354
#
# Epoch 00158: val_loss did not improve from 0.11590
# Epoch 159/500
#  - 7s - loss: 0.2594 - accuracy: 0.8791 - val_loss: 0.4434 - val_accuracy: 0.8190
#
# Epoch 00159: val_loss did not improve from 0.11590
# Epoch 160/500
#  - 7s - loss: 0.2680 - accuracy: 0.8770 - val_loss: 0.7570 - val_accuracy: 0.6878
#
# Epoch 00160: val_loss did not improve from 0.11590
# Epoch 161/500
#  - 7s - loss: 0.2546 - accuracy: 0.8828 - val_loss: 0.3687 - val_accuracy: 0.7601
#
# Epoch 00161: val_loss did not improve from 0.11590
# Epoch 162/500
#  - 7s - loss: 0.2478 - accuracy: 0.8854 - val_loss: 0.2313 - val_accuracy: 0.8102
#
# Epoch 00162: val_loss did not improve from 0.11590
# Epoch 163/500
#  - 7s - loss: 0.2519 - accuracy: 0.8807 - val_loss: 0.1643 - val_accuracy: 0.8230
#
# Epoch 00163: val_loss did not improve from 0.11590
# Epoch 164/500
#  - 7s - loss: 0.2588 - accuracy: 0.8821 - val_loss: 0.5197 - val_accuracy: 0.8169
#
# Epoch 00164: val_loss did not improve from 0.11590
# Epoch 165/500
#  - 7s - loss: 0.2500 - accuracy: 0.8853 - val_loss: 0.2798 - val_accuracy: 0.8293
#
# Epoch 00165: val_loss did not improve from 0.11590
# Epoch 166/500
#  - 7s - loss: 0.2441 - accuracy: 0.8877 - val_loss: 0.0790 - val_accuracy: 0.8312
#
# Epoch 00166: val_loss improved from 0.11590 to 0.07897, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 20_113_ohlcmacd.hdf5
# Epoch 167/500
#  - 7s - loss: 0.2418 - accuracy: 0.8889 - val_loss: 0.4904 - val_accuracy: 0.8173
#
# Epoch 00167: val_loss did not improve from 0.07897
# Epoch 168/500
#  - 7s - loss: 0.2473 - accuracy: 0.8868 - val_loss: 0.4910 - val_accuracy: 0.8170
#
# Epoch 00168: val_loss did not improve from 0.07897
# Epoch 169/500
#  - 7s - loss: 0.2435 - accuracy: 0.8869 - val_loss: 0.4697 - val_accuracy: 0.8299
#
# Epoch 00169: val_loss did not improve from 0.07897
# Epoch 170/500
#  - 7s - loss: 0.2459 - accuracy: 0.8849 - val_loss: 0.6199 - val_accuracy: 0.8523
#
# Epoch 00170: val_loss did not improve from 0.07897
# Epoch 171/500
#  - 7s - loss: 0.2356 - accuracy: 0.8931 - val_loss: 0.5500 - val_accuracy: 0.8394
#
# Epoch 00171: val_loss did not improve from 0.07897
# Epoch 172/500
#  - 7s - loss: 0.2410 - accuracy: 0.8931 - val_loss: 0.2989 - val_accuracy: 0.8320
#
# Epoch 00172: val_loss did not improve from 0.07897
# Epoch 173/500
#  - 7s - loss: 0.2359 - accuracy: 0.8909 - val_loss: 0.2957 - val_accuracy: 0.8438
#
# Epoch 00173: val_loss did not improve from 0.07897
# Epoch 174/500
#  - 7s - loss: 0.2369 - accuracy: 0.8924 - val_loss: 0.5937 - val_accuracy: 0.7930
#
# Epoch 00174: val_loss did not improve from 0.07897
# Epoch 175/500
#  - 7s - loss: 0.2413 - accuracy: 0.8893 - val_loss: 0.6672 - val_accuracy: 0.7718
#
# Epoch 00175: val_loss did not improve from 0.07897
# Epoch 176/500
#  - 7s - loss: 0.2240 - accuracy: 0.8964 - val_loss: 0.3757 - val_accuracy: 0.8609
#
# Epoch 00176: val_loss did not improve from 0.07897
# Epoch 177/500
#  - 7s - loss: 0.2269 - accuracy: 0.8929 - val_loss: 0.1550 - val_accuracy: 0.8852
#
# Epoch 00177: val_loss did not improve from 0.07897
# Epoch 178/500
#  - 7s - loss: 0.2277 - accuracy: 0.8958 - val_loss: 0.1423 - val_accuracy: 0.8548
#
# Epoch 00178: val_loss did not improve from 0.07897
# Epoch 179/500
#  - 7s - loss: 0.2250 - accuracy: 0.8966 - val_loss: 0.2840 - val_accuracy: 0.8204
#
# Epoch 00179: val_loss did not improve from 0.07897
# Epoch 180/500
#  - 7s - loss: 0.2297 - accuracy: 0.8930 - val_loss: 0.3674 - val_accuracy: 0.8591
#
# Epoch 00180: val_loss did not improve from 0.07897
# Epoch 181/500
#  - 7s - loss: 0.2270 - accuracy: 0.8963 - val_loss: 0.2783 - val_accuracy: 0.8566
#
# Epoch 00181: val_loss did not improve from 0.07897
# Epoch 182/500
#  - 7s - loss: 0.2207 - accuracy: 0.8983 - val_loss: 0.5179 - val_accuracy: 0.8431
#
# Epoch 00182: val_loss did not improve from 0.07897
# Epoch 183/500
#  - 7s - loss: 0.2193 - accuracy: 0.8977 - val_loss: 0.3716 - val_accuracy: 0.8738
#
# Epoch 00183: val_loss did not improve from 0.07897
# Epoch 184/500
#  - 7s - loss: 0.2160 - accuracy: 0.9016 - val_loss: 0.3056 - val_accuracy: 0.8161
#
# Epoch 00184: val_loss did not improve from 0.07897
# Epoch 185/500
#  - 7s - loss: 0.2148 - accuracy: 0.9007 - val_loss: 0.1431 - val_accuracy: 0.8468
#
# Epoch 00185: val_loss did not improve from 0.07897
# Epoch 186/500
#  - 7s - loss: 0.2143 - accuracy: 0.9017 - val_loss: 0.4720 - val_accuracy: 0.8485
#
# Epoch 00186: val_loss did not improve from 0.07897
# Epoch 187/500
#  - 7s - loss: 0.2056 - accuracy: 0.9054 - val_loss: 0.3351 - val_accuracy: 0.8475
#
# Epoch 00187: val_loss did not improve from 0.07897
# Epoch 188/500
#  - 7s - loss: 0.2150 - accuracy: 0.9008 - val_loss: 0.1458 - val_accuracy: 0.8114
#
# Epoch 00188: val_loss did not improve from 0.07897
# Epoch 189/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-b523ce5d56b8> in <module>()
#     178                     validation_data=val_flow,
#     179                     validation_steps=len(X_val) / batch_size,
# --> 180                     shuffle=False)
#     181
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ## **Prediction**

# %%
import mpl_finance as mf
import matplotlib.pyplot as plt

X_test = X_test[-100:]
Y_pred_ = model.predict(X_test)

# Y_pred = np.argmax(Y_pred_, axis=1)

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
# ochl = X_test[:, [-1], :4].reshape(-1 ,4)
# # breakpoint
# index = np.arange(len(ochl))
# ochl = np.hstack((np.reshape(index, (-1, 1)), ochl))
# mf.candlestick_ochl(ax, ochl, width=0.5, colorup='r', colordown='b')

span_list = list()
for i in range(len(Y_pred)):
    if Y_pred[i] == 1.:
        span_list.append((i, i + 1))

for i in range(len(span_list)):
    plt.axvspan(span_list[i][0], span_list[i][1], facecolor='c', alpha=0.7)

plt.plot(X_test[:, []])
plt.plot(Y_pred_[:, [-1]])
plt.show()

# plt.plt(X_test[:, [-1], :4])
