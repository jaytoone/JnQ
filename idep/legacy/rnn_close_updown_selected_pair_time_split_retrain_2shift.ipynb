# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %%
import tqdm
tqdm.__version__
# Out:
# '4.41.1'

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    # net = layers.LSTM(32, return_sequences=False)(visible)
    net = layers.LSTM(10, return_sequences=False)(visible)

    # net = layers.Dense(32)(visible)
    # net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    net = layers.Dense(128)(net)
    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(256)(net)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)


    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    # net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dropout(0.3)(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
print(tf.__version__)
print(keras.__version__)
# Out:
# 1.15.2
# 2.3.1

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


def class_ratio(in_list):

  return in_list / in_list[1]

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight

from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

from funcs_indicator import *
from tqdm.notebook import tqdm


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None

seed = 1
random_state = 201
np.random.seed(seed)

for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue


  # if '02-11' not in candis[i]:  # <-- 04-08 includes all timestamp range
  #   continue  

  # if 'eth'.upper() not in candis[i]:
  #   continue

  # if 'neo'.upper() not in candis[i]:
  #   continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  

    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      # ohlcv = load_dict[key]['ohlcv']

    if 'sxp'.upper() not in key:
      continue
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))


    #       select timestamp range      #
    # time_index = ohlcv.index
    # total_stamp = list(map(lambda x: datetime.timestamp(x), time_index)) 

    # rm_index_amt = np.sum(np.array(total_stamp) < start_stamp)

    # ohlcv = ohlcv.iloc[rm_index_amt:]
    # print(ohlcv.head())

    ohlcv = ohlcv.iloc[:-2603]  # exclude back_range
    # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.3)]  # exclude back_range
    # predictions = load_dict[key]['predictions']
    # err_ranges = load_dict[key]['err_ranges']
    print("ohlcv.index[0] :", ohlcv.index[0])
    print("ohlcv.index[-1] :", ohlcv.index[-1])

    predictions = ohlcv['close'].shift(1).values
    err_ranges = np.zeros_like(predictions)

    # leverage_list = profit_result_dict[key]['leverage_list']
    # temp_ap_list = list()
    # temp_pr_list = list()

    try:
      print('-------------- %s --------------' % key)
      result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
      # temp_ap_list.append(result[2])
      # temp_pr_list.append(result[3])

      # if round(leverage) == 1:
      #   temp_pr_list = result[3]
      pr_list = result[3][long_index]

    except Exception as e:
      print(e)
      break    


    
  # break
    #         clustering zone           #

    #       set data features : ohlc, v, ep
    time_index = ohlcv.index[-len(predictions):]

    sliced_ohlcv = ohlcv[-len(predictions):]

    #       scale with price    #
    ohlc = ohlcv.iloc[-len(predictions):, :4]      
    long_ep = np.array(predictions)
    long_ep = long_ep.reshape(-1, 1)
    ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
    sar = lucid_sar(sliced_ohlcv)
    ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
    senkou1, senkou2 = ichimoku(sliced_ohlcv)

    #     min max scale   #
    vol = sliced_ohlcv.iloc[-len(predictions):, [4]]

    #     scale with baseline   #
    #     방법 1. 전체 기간 min_max scaling   #
    cbo, ema_cbo = cct_bbo(sliced_ohlcv, 21, 13) 

    _, _, bbw = bb_width(sliced_ohlcv, 20, 2) 
    
    fish = fisher(sliced_ohlcv, 60)
    trix = trix_hist(sliced_ohlcv, 14, 1, 5) 
    rsi_ = rsi(sliced_ohlcv)
    macd_hist = macd(sliced_ohlcv)




    # ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
    # ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
    # ohlcv['body'] = ohlcv['close'] / ohlcv['open']
    # candle = ohlcv.iloc[-len(predictions):, -3:]


    print('len(ohlc) :', len(ohlc))
    print('long_ep.shape :', long_ep.shape)
    print('len(ha_ohlc) :', len(ha_ohlc))
    print('len(sar) :', len(sar))
    print('len(ema1) :', len(ema1))
    print('len(senkou1) :', len(senkou1))
    print('len(cbo) :', len(cbo))
    print('len(ema_cbo) :', len(ema_cbo))
    print('len(bbw) :', len(bbw))
    print('len(fish) :', len(fish))
    print('len(trix) :', len(trix))
    print('len(rsi_) :', len(rsi_))
    print('len(macd_hist) :', len(macd_hist))


    # break


    #       set params    #
    period = 45
    key_i = i

    # plt.plot(cbo)
    # plt.plot(bbw)
    plt.plot(fish, color='b')
    # plt.plot(trix)
    # plt.plot(rsi_)
    # plt.plot(macd_hist)
    plt.show()

    #      global scaling   #
    min_max = MinMaxScaler()
    cbo = min_max.fit_transform(cbo.values.reshape(-1, 1))
    ema_cbo = min_max.fit_transform(ema_cbo.values.reshape(-1, 1))
    bbw = min_max.fit_transform(bbw.values.reshape(-1, 1))
    fish = min_max.fit_transform(fish.values.reshape(-1, 1))
    trix = min_max.fit_transform(trix.values.reshape(-1, 1))
    rsi_ = min_max.fit_transform(rsi_.values.reshape(-1, 1))
    macd_hist = min_max.fit_transform(macd_hist.values.reshape(-1, 1))

    # plt.plot(cbo)
    # plt.plot(bbw)
    plt.plot(fish, color='r')
    # plt.plot(trix)
    # plt.plot(rsi_)
    # plt.plot(macd_hist)
    plt.show()
    # break

    plotting = True

    for trial_number in range(1):

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)          

          price_data = np.hstack((temp_ohlc, temp_long_ep, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))

          temp_ohlc = temp_price_data[:, :4]
          temp_long_ep = temp_price_data[:, [4]]
          temp_ha_ohlc = temp_price_data[:, 5:9]
          temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2 = np.split(temp_price_data[:, 9:], 6, axis=1)

          if plotting:

            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          # temp_candle = candle.iloc[i - period : i].values

          temp_cbo = cbo[i - period : i]
          temp_ema_cbo = ema_cbo[i - period : i]
          temp_bbw = bbw[i - period : i]
          temp_fish = fish[i - period : i]
          temp_trix = trix[i - period : i]
          temp_rsi_ = rsi_[i - period : i]
          temp_macd_hist = macd_hist[i - period : i]

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          trial_list = [temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2,
                        temp_cbo, temp_ema_cbo, temp_bbw, temp_fish, temp_trix, temp_rsi_, temp_macd_hist]

          # trial_list = [temp_ohlc[:, [0], temp_ohlc[:, [1], temp_ohlc[:, [2], temp_ohlc[:, [3]], temp_vol, temp_ema_cbo]

          #                   feature selection                   #  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          temp_data = temp_ohlc[:, [3]]
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          #     only close    #
          # temp_data = temp_ohlc[:, [-1]]

          # temp_data = temp_ohlc

          #     only volume    #
          # temp_data = temp_vol

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :-1] = max_abs.fit_transform(temp_data[:, :-1])

          
          # min_max = MinMaxScaler()
          # temp_data = min_max.fit_transform(temp_data)

          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      # input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      # input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)

      
      # _, row, col, _ = input_x.shape
      _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      # print(np.unique(total_index, return_counts=True))
      # uniq_stamp = np.unique(total_index)

      # stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      # stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=True, random_state=random_state)

      # print("stamp_train.shape :", stamp_train.shape)
      # print("stamp_val.shape :", stamp_val.shape)
      # print("stamp_test.shape :", stamp_test.shape)
      # # break


      # #         split data by stamp     #
      # x_train, x_val, x_test = [], [], []
      # pr_train, pr_val, pr_test = [], [], []
      # index_train, index_val, index_test = [], [], []



      # np.random.shuffle(total_index)

      # for i in tqdm(range(len(total_index))):

      #   if total_index[i] in stamp_train:
      #     x_train.append(total_x[i])
      #     pr_train.append(total_pr[i])
      #     index_train.append(total_index[i])

      #   elif total_index[i] in stamp_val:
      #     x_val.append(total_x[i])
      #     pr_val.append(total_pr[i])
      #     index_val.append(total_index[i])
        
      #   elif total_index[i] in stamp_test:
      #     x_test.append(total_x[i])
      #     pr_test.append(total_pr[i])
      #     index_test.append(total_index[i])


      # x_train = np.array(x_train)
      # x_val = np.array(x_val)
      # x_test = np.array(x_test)

      # pr_train = np.array(pr_train)
      # pr_val = np.array(pr_val)
      # pr_test = np.array(pr_test)

      # index_train = np.array(index_train)
      # index_val = np.array(index_val)
      # index_test = np.array(index_test)
        
      # print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      # print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      # print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)



      seed = 1
      random_state = 20
      np.random.seed(seed)
  
      symbol_name = key.split(' ')[1].split('.')[0]

      #     test 로 부터 index 한개씩, train / val 로 붙이고 train / val 로부터 -1 data   #
      #     len(test) 만큼 수행   #
      org_test_size = 2092
      x_train, x_test, pr_train, pr_test = train_test_split(total_x, total_pr, test_size=0.2, shuffle=False)

      _, row, col, = x_train.shape
      y_test = np.where(pr_test > 1, 1, 0)

      # org_x_train, org_x_test, org_pr_train, org_pr_test = train_test_split(total_x, total_pr, test_size=0.2, shuffle=False)

      total_result = []
      t_result_path = current_path + 'npy/' + '%s_rnn_close_updown_x_t_result_2shift_transfer_%s.npy' % (period, symbol_name)
      try:
        total_result = np.load(t_result_path)
        total_result = list(total_result)
        print("----------------------- total_result loaded ! -----------------------")
        print("len(total_result) :", len(total_result))
      except:
        pass

      first_iter = True
      for r_i in tqdm(range(1, len(x_test))):

        if r_i < len(total_result):
          continue

        new_x_test = x_test[[r_i]]
        new_pr_test = pr_test[[r_i]]

        ind_x_train = np.vstack((x_train[r_i - 1:], x_test[:r_i - 1]))
        ind_pr_train = np.vstack((pr_train[r_i - 1:], pr_test[:r_i - 1]))

        #     add & remove test set   #
        new_x_train, new_x_val, new_pr_train, new_pr_val = train_test_split(ind_x_train, ind_pr_train, test_size=0.25, shuffle=True, random_state=random_state)

        new_y_train = np.where(new_pr_train > 1, 1, 0)
        new_y_val = np.where(new_pr_val > 1, 1, 0)
        new_y_test = np.where(new_pr_test > 1, 1, 0)

        
        print('new_x_train.shape :', new_x_train.shape)
        print('new_x_test.shape :', new_x_test.shape)
        print('new_x_val.shape :', new_x_val.shape)
        print('new_y_train.shape :', new_y_train.shape)
        print('new_y_test.shape :', new_y_test.shape)
        print('new_y_val.shape :', new_y_val.shape)


        print('np.unique(y_train, return_counts=True :', np.unique(new_y_train, return_counts=True), class_ratio(np.unique(new_y_train, return_counts=True)[1]))
        print('np.unique(new_y_val, return_counts=True :', np.unique(new_y_val, return_counts=True), class_ratio(np.unique(new_y_val, return_counts=True)[1]))
        # print('np.unique(new_y_test, return_counts=True :', np.unique(new_y_test, return_counts=True), class_ratio(np.unique(new_y_test, return_counts=True)[1]))

        label = new_y_train.reshape(-1, )
        class_weights = class_weight.compute_class_weight('balanced', 
                                                            classes=np.unique(label),
                                                            y=label)
        class_weights = dict(enumerate(class_weights))
        print('class_weights :', class_weights)

        # sample_weight = np.ones(shape=(len(new_y_train),))
        # sample_weight[(new_y_train == 1).reshape(-1,)] = 1.5
        # print('sample_weight[:20] :', sample_weight[:20])


        print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(new_x_train)))
        print('np.isnan(np.sum(new_x_val)) :', np.isnan(np.sum(new_x_val)))
        print('np.isnan(np.sum(new_x_test)) :', np.isnan(np.sum(new_x_test)))

        print('np.isnan(np.sum(new_y_train)) :', np.isnan(np.sum(new_y_train)))
        print('np.isnan(np.sum(new_y_val)) :', np.isnan(np.sum(new_y_val)))
        print('np.isnan(np.sum(new_y_test)) :', np.isnan(np.sum(new_y_test)))

        new_y_train_ohe = np_utils.to_categorical(new_y_train, num_classes)
        new_y_val_ohe = np_utils.to_categorical(new_y_val, num_classes)
        new_y_test_ohe = np_utils.to_categorical(new_y_test, num_classes)
        print('new_y_train_ohe.shape :', new_y_train_ohe.shape)
        print('new_y_val_ohe.shape :', new_y_val_ohe.shape)
        print('new_y_test_ohe.shape :', new_y_test_ohe.shape)


        ckpt_path = current_path + 'ckpt/'
        board_path = current_path + 'graph/'

        model_name = 'classifier_%s_lstm_close_updown_pr_retrain_2shift_transfer_%s_timesplit.h5' % (period, symbol_name)

        
        #       retraining    #       
        if r_i != 0:

          K.clear_session() # added for training delation

          try:
            model = keras.models.load_model(ckpt_path + model_name)
            print("----------------------- model loaded ! -----------------------")
            
            #     model 을 load 한 경우에만, freeze 해야한다, initial_model 은 feature_extractor 가 학습되지 않았으니까   #
            for l_i, layer in enumerate(model.layers):

              if l_i != len(model.layers) - 1:
                layer.trainable = False
            
            print("----------------------- layers freezed without last layer ! -----------------------")
            

          except Exception as e:
            print('Error in load_model :', e)

            pretrained_model_name = "classifier_%s_lstm_close_updown_pr_retrain_re_%s_timesplit.h5" % (period, symbol_name)
            model = keras.models.load_model(ckpt_path + pretrained_model_name)
            print("----------------------- pretrained model loaded ! -----------------------")

            # model = FER_Model(input_shape=(row, col))

          # first_iter = False
          

        else:
          model = FER_Model(input_shape=(row, col))

        batch_size = 512
        # _, row, col, = x_train.shape
        # print("row, col :", row, col)

        opt = Adam(lr=0.00001, decay=0.000005)
        # opt = Adam(lr=0.001, decay=0.0005)
        model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

        checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
        checkpoint2 = TensorBoard(log_dir=board_path,
                                  histogram_freq=0,
                                  write_graph=True,
                                  write_images=True)
        checkpoint3 = EarlyStopping(monitor='val_loss', patience=50)
        callbacks_list = [checkpoint, checkpoint2, checkpoint3]
        # callbacks_list = [checkpoint, checkpoint2]

        # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

        # we iterate 200 times over the entire training set
        num_epochs = 1000                    

        history = model.fit(new_x_train, new_y_train_ohe,
                            steps_per_epoch=int(len(new_x_train) / batch_size), 
                            epochs=num_epochs,  
                            verbose=2,  
                            callbacks=callbacks_list,
                            class_weight=class_weights,
                            validation_data=(new_x_val, new_y_val_ohe),  
                            validation_steps=int(len(new_x_val) / batch_size),
                            shuffle=False)
        
        ckpt_path = current_path + 'ckpt/'
        board_path = current_path + 'graph/'
        # model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_ex_02008.h5'
        # model_name = 'classifier_45_close_updown_pr_theta.h5'
        # model_name = 'classifier_45_close_updown_pr_theta_train_evendata_shuffle2_300k.h5'
        # model_name = 'classifier_45_lstm_close_updown_pr_neo_timesplit.h5'

        # model_name = 'classifier_45_lstm_close_updown_pr_eth_timesplit.h5'

        model = keras.models.load_model(ckpt_path + model_name)

        # x_test = new_input_x
        # y_test = np.where(new_input_pr > 1, 1, 0)
        # pr_test = new_input_pr

        # x_test = org_x_test
        # y_test = org_y_test
        # pr_test = org_pr_test

        # x_test = x_train
        # y_test = y_train
        # pr_test = pr_train

        # x_test = x_val
        # y_test = y_val
        # pr_test = pr_val

        # x_test = concat_x
        # y_test = np.where(concat_pr > 1, 1, 0)
        # pr_test = concat_pr

        test_result = model.predict(new_x_test)
        # test_result = model.predict(test_set)

        total_result.append(test_result)

        print('test_result.shape :', test_result.shape)

        
        np.save(t_result_path, np.array(total_result))
        print('total_result.shape :', np.array(total_result).shape)

      # print('pr_val.shape :', pr_val.shape)


      total_result = np.array(total_result).reshape(-1, 2)
      y_score = total_result[:, [1]]
      print('y_test[:5] :', y_test.reshape(-1,)[:5])
      # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
      print('y_score[:5] :', y_score[:5])
      # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

      print('y_test.shape :', y_test.shape)
      print('y_score.shape :', y_score.shape)

      print('len(y_test) :', len(y_test))

      #     precision recall curve   #
      precision, recall, threshold = precision_recall_curve(y_test, y_score)
      precision, recall = precision[:-1], recall[:-1]

      plt.plot(threshold, precision, label='precision')
      plt.plot(threshold, recall, label='recall')
      plt.legend()
      plt.title('precision recall')
      plt.show()
      # print(y_pred)


      # threshold = [0.65]
      # print('threshold :', threshold)
      # break

      acc_pr_bythr = []
      new_thresh = []

      for thresh in threshold:
        
        # if thresh < 0.5:
        #     continue

        y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
        # print('y_pred.shape :', y_pred.shape)
        # print('y_pred :', y_pred)

        #     compare precision     #

        # print('precision :', precision_score(y_test, y_pred))
        # print('recall :', recall_score(y_test, y_pred))
        # print()

        # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
        # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

        # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
        # # plt.show()  
        # print()

        #     check win-ratio improvement     #
        cmat = confusion_matrix(y_test, y_pred)
        # print(cmat)
        # print(np.sum(cmat, axis=1))

        test_size = len(y_test)
        test_pr_list = pr_test
        # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

        org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
        ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
        # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

        # print('pr_test.shape :', pr_test.shape)

        # print(y_pred)
        # print(test_pr_list)
        pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
        pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
        pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
        # print('pred_pr_list.shape :', pred_pr_list.shape)

        # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
        #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
        #   print('thresh :', thresh)
          
        # if len(threshold) == 1:
      #   plt.figure(figsize=(10, 5))
      #   plt.subplot(121)
      #   plt.plot(np.cumprod(test_pr_list))
      #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
      # # plt.show()

      #   plt.subplot(122)
      #   plt.plot(np.cumprod(pred_pr_list))
      #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
      #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
      #   plt.show()


        acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
        new_thresh.append(thresh)


      print('acc_pr_bythr :', acc_pr_bythr)

      plt.figure(figsize=(10, 5))
      plt.subplot(121)
      plt.plot(threshold, precision, label='precision')
      plt.plot(threshold, recall, label='recall')
      plt.legend()
      plt.title('precision recall')
      # plt.show()
      plt.subplot(122)
      plt.plot(new_thresh, acc_pr_bythr)
      plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
      plt.title(symbol_name)
      plt.show()


  # break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  try:
    if len(total_x) > 300000:
      break
  except:
    pass
# Out:
# start_stamp : 0
# len(ohlcv) : 13452
# ohlcv.index[0] : 2020-07-21 18:29:59.999000
# ohlcv.index[-1] : 2021-03-04 18:29:59.999000
# -------------- 2021-04-27 SXPUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# /content/drive/My Drive/Colab Notebooks/300/funcs_indicator.py:273: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlcv_df['up'] = np.where(ohlcv_df['close'].diff(1) > 0, ohlcv_df['close'].diff(1), 0)
# /content/drive/My Drive/Colab Notebooks/300/funcs_indicator.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlcv_df['down'] = np.where(ohlcv_df['close'].diff(1) < 0, ohlcv_df['close'].diff(1) * (-1), 0)
# len(ohlc) : 10849
# long_ep.shape : (10849, 1)
# len(ha_ohlc) : 10849
# len(sar) : 10849
# len(ema1) : 10849
# len(senkou1) : 10849
# len(cbo) : 10849
# len(ema_cbo) : 10849
# len(bbw) : 10849
# len(fish) : 10849
# len(trix) : 10849
# len(rsi_) : 10849
# len(macd_hist) : 10849
# np.array(data_x).shape : (10460, 45, 1)
# input_x.shape : (10460, 45, 1)
# input_x.dtype : float32
# input_pr.shape : (10460, 1)
# input_ud.shape : (10460, 1)
# input_index.shape : (10460, 1)
# total_x.shape : (10460, 45, 1)
# total_pr.shape : (10460, 1)
# total_ud.shape : (10460, 1)
# prev_index.shape : (10460, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:369: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# HBox(children=(FloatProgress(value=0.0, max=2091.0), HTML(value='')))
# Streaming output truncated to the last 5000 lines.
# Epoch 00018: val_loss did not improve from 0.16960
# Epoch 19/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5486 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00019: val_loss did not improve from 0.16960
# Epoch 20/1000
#  - 0s - loss: 0.6841 - accuracy: 0.5490 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00020: val_loss did not improve from 0.16960
# Epoch 21/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5492 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00021: val_loss did not improve from 0.16960
# Epoch 22/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5496 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00022: val_loss did not improve from 0.16960
# Epoch 23/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5497 - val_loss: 0.1696 - val_accuracy: 2.2887
#
# Epoch 00023: val_loss did not improve from 0.16960
# Epoch 24/1000
#  - 0s - loss: 0.6840 - accuracy: 0.5492 - val_loss: 0.1696 - val_accuracy: 2.2887
#
# Epoch 00024: val_loss did not improve from 0.16960
# Epoch 25/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5486 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00025: val_loss did not improve from 0.16960
# Epoch 26/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5483 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00026: val_loss did not improve from 0.16960
# Epoch 27/1000
#  - 0s - loss: 0.6841 - accuracy: 0.5479 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00027: val_loss did not improve from 0.16960
# Epoch 28/1000
#  - 0s - loss: 0.6840 - accuracy: 0.5507 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00028: val_loss did not improve from 0.16960
# Epoch 29/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5478 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00029: val_loss did not improve from 0.16960
# Epoch 30/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5495 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00030: val_loss did not improve from 0.16960
# Epoch 31/1000
#  - 0s - loss: 0.6841 - accuracy: 0.5462 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00031: val_loss did not improve from 0.16960
# Epoch 32/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5485 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00032: val_loss did not improve from 0.16960
# Epoch 33/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5493 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00033: val_loss did not improve from 0.16960
# Epoch 34/1000
#  - 0s - loss: 0.6840 - accuracy: 0.5485 - val_loss: 0.1696 - val_accuracy: 2.2887
#
# Epoch 00034: val_loss did not improve from 0.16960
# Epoch 35/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5489 - val_loss: 0.1696 - val_accuracy: 2.2887
#
# Epoch 00035: val_loss did not improve from 0.16960
# Epoch 36/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5507 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00036: val_loss did not improve from 0.16960
# Epoch 37/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5480 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00037: val_loss did not improve from 0.16960
# Epoch 38/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5486 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00038: val_loss did not improve from 0.16960
# Epoch 39/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5493 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00039: val_loss did not improve from 0.16960
# Epoch 40/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5497 - val_loss: 0.1696 - val_accuracy: 2.2868
#
# Epoch 00040: val_loss did not improve from 0.16960
# Epoch 41/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5493 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00041: val_loss did not improve from 0.16960
# Epoch 42/1000
#  - 0s - loss: 0.6840 - accuracy: 0.5488 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00042: val_loss did not improve from 0.16960
# Epoch 43/1000
#  - 0s - loss: 0.6840 - accuracy: 0.5494 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00043: val_loss did not improve from 0.16960
# Epoch 44/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5485 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00044: val_loss did not improve from 0.16960
# Epoch 45/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5521 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00045: val_loss did not improve from 0.16960
# Epoch 46/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5474 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00046: val_loss did not improve from 0.16960
# Epoch 47/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5485 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00047: val_loss did not improve from 0.16960
# Epoch 48/1000
#  - 0s - loss: 0.6842 - accuracy: 0.5475 - val_loss: 0.1696 - val_accuracy: 2.2830
#
# Epoch 00048: val_loss did not improve from 0.16960
# Epoch 49/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5492 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00049: val_loss did not improve from 0.16960
# Epoch 50/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5499 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00050: val_loss did not improve from 0.16960
# Epoch 51/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5487 - val_loss: 0.1696 - val_accuracy: 2.2849
#
# Epoch 00051: val_loss did not improve from 0.16960
# test_result.shape : (1, 2)
# total_result.shape : (119, 1, 2)
# new_x_train.shape : (6276, 45, 1)
# new_x_test.shape : (1, 45, 1)
# new_x_val.shape : (2092, 45, 1)
# new_y_train.shape : (6276, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (2092, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3402, 2874])) [1.18371608 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1162,  930])) [1.24946237 1.        ]
# class_weights : {0: 0.9223985890652557, 1: 1.091858037578288}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (6276, 2)
# new_y_val_ohe.shape : (2092, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# ----------------------- layers freezed without last layer ! -----------------------
# Train on 6276 samples, validate on 2092 samples
# Epoch 1/1000
#  - 1s - loss: 0.6821 - accuracy: 0.5567 - val_loss: 0.1706 - val_accuracy: 2.2008
#
# Epoch 00001: val_loss improved from inf to 0.17060, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_lstm_close_updown_pr_retrain_2shift_transfer_SXPUSDT_timesplit.h5
# Epoch 2/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5560 - val_loss: 0.1706 - val_accuracy: 2.1969
#
# Epoch 00002: val_loss did not improve from 0.17060
# Epoch 3/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5578 - val_loss: 0.1706 - val_accuracy: 2.1931
#
# Epoch 00003: val_loss did not improve from 0.17060
# Epoch 4/1000
#  - 0s - loss: 0.6820 - accuracy: 0.5573 - val_loss: 0.1706 - val_accuracy: 2.1931
#
# Epoch 00004: val_loss did not improve from 0.17060
# Epoch 5/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5560 - val_loss: 0.1706 - val_accuracy: 2.1950
#
# Epoch 00005: val_loss did not improve from 0.17060
# Epoch 6/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5558 - val_loss: 0.1706 - val_accuracy: 2.1969
#
# Epoch 00006: val_loss did not improve from 0.17060
# Epoch 7/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5553 - val_loss: 0.1706 - val_accuracy: 2.1950
#
# Epoch 00007: val_loss did not improve from 0.17060
# Epoch 8/1000
#  - 0s - loss: 0.6821 - accuracy: 0.5564 - val_loss: 0.1706 - val_accuracy: 2.1989
#
# Epoch 00008: val_loss did not improve from 0.17060
# Epoch 9/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5558 - val_loss: 0.1706 - val_accuracy: 2.1989
#
# Epoch 00009: val_loss did not improve from 0.17060
# Epoch 10/1000
#  - 0s - loss: 0.6825 - accuracy: 0.5554 - val_loss: 0.1706 - val_accuracy: 2.1969
#
# Epoch 00010: val_loss did not improve from 0.17060
# Epoch 11/1000
#  - 0s - loss: 0.6820 - accuracy: 0.5567 - val_loss: 0.1706 - val_accuracy: 2.1931
#
# Epoch 00011: val_loss did not improve from 0.17060
# Epoch 12/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5561 - val_loss: 0.1706 - val_accuracy: 2.1874
#
# Epoch 00012: val_loss did not improve from 0.17060
# Epoch 13/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5571 - val_loss: 0.1707 - val_accuracy: 2.1855
#
# Epoch 00013: val_loss did not improve from 0.17060
# Epoch 14/1000
#  - 0s - loss: 0.6820 - accuracy: 0.5563 - val_loss: 0.1707 - val_accuracy: 2.1836
#
# Epoch 00014: val_loss did not improve from 0.17060
# Epoch 15/1000
#  - 0s - loss: 0.6819 - accuracy: 0.5584 - val_loss: 0.1707 - val_accuracy: 2.1855
#
# Epoch 00015: val_loss did not improve from 0.17060
# Epoch 16/1000
#  - 0s - loss: 0.6818 - accuracy: 0.5584 - val_loss: 0.1707 - val_accuracy: 2.1855
#
# Epoch 00016: val_loss did not improve from 0.17060
# Epoch 17/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5564 - val_loss: 0.1707 - val_accuracy: 2.1855
#
# Epoch 00017: val_loss did not improve from 0.17060
# Epoch 18/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5570 - val_loss: 0.1707 - val_accuracy: 2.1816
#
# Epoch 00018: val_loss did not improve from 0.17060
# Epoch 19/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5581 - val_loss: 0.1707 - val_accuracy: 2.1797
#
# Epoch 00019: val_loss did not improve from 0.17060
# Epoch 20/1000
#  - 0s - loss: 0.6818 - accuracy: 0.5581 - val_loss: 0.1707 - val_accuracy: 2.1816
#
# Epoch 00020: val_loss did not improve from 0.17060
# Epoch 21/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5576 - val_loss: 0.1707 - val_accuracy: 2.1855
#
# Epoch 00021: val_loss did not improve from 0.17060
# Epoch 22/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5565 - val_loss: 0.1707 - val_accuracy: 2.1855
#
# Epoch 00022: val_loss did not improve from 0.17060
# Epoch 23/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5553 - val_loss: 0.1707 - val_accuracy: 2.1836
#
# Epoch 00023: val_loss did not improve from 0.17060
# Epoch 24/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5569 - val_loss: 0.1707 - val_accuracy: 2.1836
#
# Epoch 00024: val_loss did not improve from 0.17060
# Epoch 25/1000
#  - 0s - loss: 0.6817 - accuracy: 0.5579 - val_loss: 0.1707 - val_accuracy: 2.1836
#
# Epoch 00025: val_loss did not improve from 0.17060
# Epoch 26/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5581 - val_loss: 0.1707 - val_accuracy: 2.1797
#
# Epoch 00026: val_loss did not improve from 0.17060
# Epoch 27/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5577 - val_loss: 0.1707 - val_accuracy: 2.1797
#
# Epoch 00027: val_loss did not improve from 0.17060
# Epoch 28/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5564 - val_loss: 0.1707 - val_accuracy: 2.1797
#
# Epoch 00028: val_loss did not improve from 0.17060
# Epoch 29/1000
#  - 0s - loss: 0.6820 - accuracy: 0.5588 - val_loss: 0.1707 - val_accuracy: 2.1797
#
# Epoch 00029: val_loss did not improve from 0.17060
# Epoch 30/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5565 - val_loss: 0.1707 - val_accuracy: 2.1778
#
# Epoch 00030: val_loss did not improve from 0.17060
# Epoch 31/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5569 - val_loss: 0.1707 - val_accuracy: 2.1797
#
# Epoch 00031: val_loss did not improve from 0.17060
# Epoch 32/1000
#  - 0s - loss: 0.6818 - accuracy: 0.5589 - val_loss: 0.1707 - val_accuracy: 2.1836
#
# Epoch 00032: val_loss did not improve from 0.17060
# Epoch 33/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5577 - val_loss: 0.1707 - val_accuracy: 2.1816
#
# Epoch 00033: val_loss did not improve from 0.17060
# Epoch 34/1000
#  - 0s - loss: 0.6821 - accuracy: 0.5581 - val_loss: 0.1707 - val_accuracy: 2.1855
#
# Epoch 00034: val_loss did not improve from 0.17060
# Epoch 35/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5561 - val_loss: 0.1707 - val_accuracy: 2.1836
#
# Epoch 00035: val_loss did not improve from 0.17060
# Epoch 36/1000
#  - 0s - loss: 0.6820 - accuracy: 0.5574 - val_loss: 0.1707 - val_accuracy: 2.1836
#
# Epoch 00036: val_loss did not improve from 0.17060
# Epoch 37/1000
#  - 0s - loss: 0.6820 - accuracy: 0.5567 - val_loss: 0.1707 - val_accuracy: 2.1816
#
# Epoch 00037: val_loss did not improve from 0.17060
# Epoch 38/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5567 - val_loss: 0.1707 - val_accuracy: 2.1816
#
# Epoch 00038: val_loss did not improve from 0.17060
# Epoch 39/1000
#  - 0s - loss: 0.6819 - accuracy: 0.5589 - val_loss: 0.1707 - val_accuracy: 2.1816
#
# Epoch 00039: val_loss did not improve from 0.17060
# Epoch 40/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5584 - val_loss: 0.1707 - val_accuracy: 2.1816
#
# Epoch 00040: val_loss did not improve from 0.17060
# Epoch 41/1000
#  - 0s - loss: 0.6819 - accuracy: 0.5573 - val_loss: 0.1707 - val_accuracy: 2.1816
#
# Epoch 00041: val_loss did not improve from 0.17060
# Epoch 42/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5574 - val_loss: 0.1707 - val_accuracy: 2.1816
#
# Epoch 00042: val_loss did not improve from 0.17060
# Epoch 43/1000
#  - 0s - loss: 0.6818 - accuracy: 0.5578 - val_loss: 0.1707 - val_accuracy: 2.1816
#
# Epoch 00043: val_loss did not improve from 0.17060
# Epoch 44/1000
#  - 0s - loss: 0.6821 - accuracy: 0.5548 - val_loss: 0.1707 - val_accuracy: 2.1836
#
# Epoch 00044: val_loss did not improve from 0.17060
# Epoch 45/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5572 - val_loss: 0.1707 - val_accuracy: 2.1836
#
# Epoch 00045: val_loss did not improve from 0.17060
# Epoch 46/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5594 - val_loss: 0.1708 - val_accuracy: 2.1836
#
# Epoch 00046: val_loss did not improve from 0.17060
# Epoch 47/1000
#  - 0s - loss: 0.6820 - accuracy: 0.5576 - val_loss: 0.1708 - val_accuracy: 2.1836
#
# Epoch 00047: val_loss did not improve from 0.17060
# Epoch 48/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5570 - val_loss: 0.1708 - val_accuracy: 2.1836
#
# Epoch 00048: val_loss did not improve from 0.17060
# Epoch 49/1000
#  - 0s - loss: 0.6819 - accuracy: 0.5590 - val_loss: 0.1708 - val_accuracy: 2.1836
#
# Epoch 00049: val_loss did not improve from 0.17060
# Epoch 50/1000
#  - 0s - loss: 0.6826 - accuracy: 0.5582 - val_loss: 0.1708 - val_accuracy: 2.1836
#
# Epoch 00050: val_loss did not improve from 0.17060
# Epoch 51/1000
#  - 0s - loss: 0.6820 - accuracy: 0.5565 - val_loss: 0.1708 - val_accuracy: 2.1836
#
# Epoch 00051: val_loss did not improve from 0.17060
# test_result.shape : (1, 2)
# total_result.shape : (120, 1, 2)
# new_x_train.shape : (6276, 45, 1)
# new_x_test.shape : (1, 45, 1)
# new_x_val.shape : (2092, 45, 1)
# new_y_train.shape : (6276, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (2092, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3426, 2850])) [1.20210526 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1139,  953])) [1.19517314 1.        ]
# class_weights : {0: 0.9159369527145359, 1: 1.1010526315789473}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (6276, 2)
# new_y_val_ohe.shape : (2092, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# ----------------------- layers freezed without last layer ! -----------------------
# Train on 6276 samples, validate on 2092 samples
# Epoch 1/1000
#  - 1s - loss: 0.6835 - accuracy: 0.5500 - val_loss: 0.1698 - val_accuracy: 2.3021
#
# Epoch 00001: val_loss improved from inf to 0.16983, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_lstm_close_updown_pr_retrain_2shift_transfer_SXPUSDT_timesplit.h5
# Epoch 2/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5484 - val_loss: 0.1698 - val_accuracy: 2.3021
#
# Epoch 00002: val_loss did not improve from 0.16983
# Epoch 3/1000
#  - 0s - loss: 0.6832 - accuracy: 0.5473 - val_loss: 0.1698 - val_accuracy: 2.3021
#
# Epoch 00003: val_loss did not improve from 0.16983
# Epoch 4/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5509 - val_loss: 0.1698 - val_accuracy: 2.2983
#
# Epoch 00004: val_loss did not improve from 0.16983
# Epoch 5/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5512 - val_loss: 0.1698 - val_accuracy: 2.3040
#
# Epoch 00005: val_loss did not improve from 0.16983
# Epoch 6/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5500 - val_loss: 0.1698 - val_accuracy: 2.3040
#
# Epoch 00006: val_loss did not improve from 0.16983
# Epoch 7/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5520 - val_loss: 0.1698 - val_accuracy: 2.3059
#
# Epoch 00007: val_loss did not improve from 0.16983
# Epoch 8/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5499 - val_loss: 0.1698 - val_accuracy: 2.3059
#
# Epoch 00008: val_loss did not improve from 0.16983
# Epoch 9/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5508 - val_loss: 0.1698 - val_accuracy: 2.3040
#
# Epoch 00009: val_loss did not improve from 0.16983
# Epoch 10/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5483 - val_loss: 0.1698 - val_accuracy: 2.3021
#
# Epoch 00010: val_loss did not improve from 0.16983
# Epoch 11/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5485 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00011: val_loss did not improve from 0.16983
# Epoch 12/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5479 - val_loss: 0.1699 - val_accuracy: 2.2983
#
# Epoch 00012: val_loss did not improve from 0.16983
# Epoch 13/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5504 - val_loss: 0.1699 - val_accuracy: 2.2964
#
# Epoch 00013: val_loss did not improve from 0.16983
# Epoch 14/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5511 - val_loss: 0.1699 - val_accuracy: 2.2964
#
# Epoch 00014: val_loss did not improve from 0.16983
# Epoch 15/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5482 - val_loss: 0.1699 - val_accuracy: 2.2983
#
# Epoch 00015: val_loss did not improve from 0.16983
# Epoch 16/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5511 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00016: val_loss did not improve from 0.16983
# Epoch 17/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5491 - val_loss: 0.1699 - val_accuracy: 2.3002
#
# Epoch 00017: val_loss did not improve from 0.16983
# Epoch 18/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5483 - val_loss: 0.1699 - val_accuracy: 2.3002
#
# Epoch 00018: val_loss did not improve from 0.16983
# Epoch 19/1000
#  - 0s - loss: 0.6832 - accuracy: 0.5506 - val_loss: 0.1699 - val_accuracy: 2.3002
#
# Epoch 00019: val_loss did not improve from 0.16983
# Epoch 20/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5487 - val_loss: 0.1699 - val_accuracy: 2.2983
#
# Epoch 00020: val_loss did not improve from 0.16983
# Epoch 21/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5492 - val_loss: 0.1699 - val_accuracy: 2.3002
#
# Epoch 00021: val_loss did not improve from 0.16983
# Epoch 22/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5498 - val_loss: 0.1699 - val_accuracy: 2.3059
#
# Epoch 00022: val_loss did not improve from 0.16983
# Epoch 23/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5488 - val_loss: 0.1699 - val_accuracy: 2.3040
#
# Epoch 00023: val_loss did not improve from 0.16983
# Epoch 24/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5505 - val_loss: 0.1699 - val_accuracy: 2.3040
#
# Epoch 00024: val_loss did not improve from 0.16983
# Epoch 25/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5483 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00025: val_loss did not improve from 0.16983
# Epoch 26/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5499 - val_loss: 0.1699 - val_accuracy: 2.3040
#
# Epoch 00026: val_loss did not improve from 0.16983
# Epoch 27/1000
#  - 0s - loss: 0.6832 - accuracy: 0.5498 - val_loss: 0.1699 - val_accuracy: 2.3040
#
# Epoch 00027: val_loss did not improve from 0.16983
# Epoch 28/1000
#  - 0s - loss: 0.6832 - accuracy: 0.5509 - val_loss: 0.1699 - val_accuracy: 2.3002
#
# Epoch 00028: val_loss did not improve from 0.16983
# Epoch 29/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5504 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00029: val_loss did not improve from 0.16983
# Epoch 30/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5495 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00030: val_loss did not improve from 0.16983
# Epoch 31/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5485 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00031: val_loss did not improve from 0.16983
# Epoch 32/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5490 - val_loss: 0.1699 - val_accuracy: 2.3040
#
# Epoch 00032: val_loss did not improve from 0.16983
# Epoch 33/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5500 - val_loss: 0.1699 - val_accuracy: 2.3040
#
# Epoch 00033: val_loss did not improve from 0.16983
# Epoch 34/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5500 - val_loss: 0.1699 - val_accuracy: 2.3040
#
# Epoch 00034: val_loss did not improve from 0.16983
# Epoch 35/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5507 - val_loss: 0.1699 - val_accuracy: 2.3040
#
# Epoch 00035: val_loss did not improve from 0.16983
# Epoch 36/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5497 - val_loss: 0.1699 - val_accuracy: 2.3040
#
# Epoch 00036: val_loss did not improve from 0.16983
# Epoch 37/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5496 - val_loss: 0.1699 - val_accuracy: 2.3040
#
# Epoch 00037: val_loss did not improve from 0.16983
# Epoch 38/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5476 - val_loss: 0.1699 - val_accuracy: 2.3040
#
# Epoch 00038: val_loss did not improve from 0.16983
# Epoch 39/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5507 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00039: val_loss did not improve from 0.16983
# Epoch 40/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5479 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00040: val_loss did not improve from 0.16983
# Epoch 41/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5487 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00041: val_loss did not improve from 0.16983
# Epoch 42/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5489 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00042: val_loss did not improve from 0.16983
# Epoch 43/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5483 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00043: val_loss did not improve from 0.16983
# Epoch 44/1000
#  - 0s - loss: 0.6832 - accuracy: 0.5497 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00044: val_loss did not improve from 0.16983
# Epoch 45/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5492 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00045: val_loss did not improve from 0.16983
# Epoch 46/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5480 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00046: val_loss did not improve from 0.16983
# Epoch 47/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5481 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00047: val_loss did not improve from 0.16983
# Epoch 48/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5489 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00048: val_loss did not improve from 0.16983
# Epoch 49/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5486 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00049: val_loss did not improve from 0.16983
# Epoch 50/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5497 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00050: val_loss did not improve from 0.16983
# Epoch 51/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5494 - val_loss: 0.1699 - val_accuracy: 2.3021
#
# Epoch 00051: val_loss did not improve from 0.16983
# test_result.shape : (1, 2)
# total_result.shape : (121, 1, 2)
# new_x_train.shape : (6276, 45, 1)
# new_x_test.shape : (1, 45, 1)
# new_x_val.shape : (2092, 45, 1)
# new_y_train.shape : (6276, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (2092, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3440, 2836])) [1.21297602 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1125,  967])) [1.16339193 1.        ]
# class_weights : {0: 0.9122093023255814, 1: 1.1064880112834978}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (6276, 2)
# new_y_val_ohe.shape : (2092, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# ----------------------- layers freezed without last layer ! -----------------------
# Train on 6276 samples, validate on 2092 samples
# Epoch 1/1000
#  - 1s - loss: 0.6821 - accuracy: 0.5591 - val_loss: 0.1708 - val_accuracy: 2.1912
#
# Epoch 00001: val_loss improved from inf to 0.17080, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_lstm_close_updown_pr_retrain_2shift_transfer_SXPUSDT_timesplit.h5
# Epoch 2/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5575 - val_loss: 0.1708 - val_accuracy: 2.1912
#
# Epoch 00002: val_loss did not improve from 0.17080
# Epoch 3/1000
#  - 0s - loss: 0.6820 - accuracy: 0.5591 - val_loss: 0.1708 - val_accuracy: 2.1893
#
# Epoch 00003: val_loss did not improve from 0.17080
# Epoch 4/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5578 - val_loss: 0.1708 - val_accuracy: 2.1893
#
# Epoch 00004: val_loss did not improve from 0.17080
# Epoch 5/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5569 - val_loss: 0.1708 - val_accuracy: 2.1874
#
# Epoch 00005: val_loss did not improve from 0.17080
# Epoch 6/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5584 - val_loss: 0.1708 - val_accuracy: 2.1874
#
# Epoch 00006: val_loss did not improve from 0.17080
# Epoch 7/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5571 - val_loss: 0.1708 - val_accuracy: 2.1874
#
# Epoch 00007: val_loss did not improve from 0.17080
# Epoch 8/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5578 - val_loss: 0.1708 - val_accuracy: 2.1874
#
# Epoch 00008: val_loss did not improve from 0.17080
# Epoch 9/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5561 - val_loss: 0.1708 - val_accuracy: 2.1874
#
# Epoch 00009: val_loss did not improve from 0.17080
# Epoch 10/1000
#  - 0s - loss: 0.6826 - accuracy: 0.5557 - val_loss: 0.1708 - val_accuracy: 2.1893
#
# Epoch 00010: val_loss did not improve from 0.17080
# Epoch 11/1000
#  - 0s - loss: 0.6826 - accuracy: 0.5564 - val_loss: 0.1708 - val_accuracy: 2.1874
#
# Epoch 00011: val_loss did not improve from 0.17080
# Epoch 12/1000
#  - 0s - loss: 0.6825 - accuracy: 0.5582 - val_loss: 0.1708 - val_accuracy: 2.1855
#
# Epoch 00012: val_loss did not improve from 0.17080
# Epoch 13/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5563 - val_loss: 0.1708 - val_accuracy: 2.1836
#
# Epoch 00013: val_loss did not improve from 0.17080
# Epoch 14/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5585 - val_loss: 0.1708 - val_accuracy: 2.1797
#
# Epoch 00014: val_loss did not improve from 0.17080
# Epoch 15/1000
#  - 0s - loss: 0.6825 - accuracy: 0.5585 - val_loss: 0.1708 - val_accuracy: 2.1778
#
# Epoch 00015: val_loss did not improve from 0.17080
# Epoch 16/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5577 - val_loss: 0.1708 - val_accuracy: 2.1797
#
# Epoch 00016: val_loss did not improve from 0.17080
# Epoch 17/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5567 - val_loss: 0.1708 - val_accuracy: 2.1797
#
# Epoch 00017: val_loss did not improve from 0.17080
# Epoch 18/1000
#  - 0s - loss: 0.6825 - accuracy: 0.5569 - val_loss: 0.1708 - val_accuracy: 2.1797
#
# Epoch 00018: val_loss did not improve from 0.17080
# Epoch 19/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5571 - val_loss: 0.1708 - val_accuracy: 2.1797
#
# Epoch 00019: val_loss did not improve from 0.17080
# Epoch 20/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5581 - val_loss: 0.1708 - val_accuracy: 2.1797
#
# Epoch 00020: val_loss did not improve from 0.17080
# Epoch 21/1000
#  - 0s - loss: 0.6825 - accuracy: 0.5572 - val_loss: 0.1708 - val_accuracy: 2.1797
#
# Epoch 00021: val_loss did not improve from 0.17080
# Epoch 22/1000
#  - 0s - loss: 0.6821 - accuracy: 0.5582 - val_loss: 0.1708 - val_accuracy: 2.1797
#
# Epoch 00022: val_loss did not improve from 0.17080
# Epoch 23/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5586 - val_loss: 0.1708 - val_accuracy: 2.1816
#
# Epoch 00023: val_loss did not improve from 0.17080
# Epoch 24/1000
#  - 0s - loss: 0.6820 - accuracy: 0.5567 - val_loss: 0.1708 - val_accuracy: 2.1816
#
# Epoch 00024: val_loss did not improve from 0.17080
# Epoch 25/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5581 - val_loss: 0.1708 - val_accuracy: 2.1816
#
# Epoch 00025: val_loss did not improve from 0.17080
# Epoch 26/1000
#  - 0s - loss: 0.6821 - accuracy: 0.5588 - val_loss: 0.1708 - val_accuracy: 2.1778
#
# Epoch 00026: val_loss did not improve from 0.17080
# Epoch 27/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5573 - val_loss: 0.1708 - val_accuracy: 2.1797
#
# Epoch 00027: val_loss did not improve from 0.17080
# Epoch 28/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5569 - val_loss: 0.1708 - val_accuracy: 2.1816
#
# Epoch 00028: val_loss did not improve from 0.17080
# Epoch 29/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5580 - val_loss: 0.1708 - val_accuracy: 2.1816
#
# Epoch 00029: val_loss did not improve from 0.17080
# Epoch 30/1000
#  - 0s - loss: 0.6819 - accuracy: 0.5598 - val_loss: 0.1708 - val_accuracy: 2.1836
#
# Epoch 00030: val_loss did not improve from 0.17080
# Epoch 31/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5571 - val_loss: 0.1708 - val_accuracy: 2.1836
#
# Epoch 00031: val_loss did not improve from 0.17080
# Epoch 32/1000
#  - 0s - loss: 0.6826 - accuracy: 0.5560 - val_loss: 0.1708 - val_accuracy: 2.1816
#
# Epoch 00032: val_loss did not improve from 0.17080
# Epoch 33/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5562 - val_loss: 0.1708 - val_accuracy: 2.1816
#
# Epoch 00033: val_loss did not improve from 0.17080
# Epoch 34/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5565 - val_loss: 0.1708 - val_accuracy: 2.1836
#
# Epoch 00034: val_loss did not improve from 0.17080
# Epoch 35/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5581 - val_loss: 0.1708 - val_accuracy: 2.1855
#
# Epoch 00035: val_loss did not improve from 0.17080
# Epoch 36/1000
#  - 0s - loss: 0.6821 - accuracy: 0.5551 - val_loss: 0.1708 - val_accuracy: 2.1855
#
# Epoch 00036: val_loss did not improve from 0.17080
# Epoch 37/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5566 - val_loss: 0.1708 - val_accuracy: 2.1874
#
# Epoch 00037: val_loss did not improve from 0.17080
# Epoch 38/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5582 - val_loss: 0.1708 - val_accuracy: 2.1893
#
# Epoch 00038: val_loss did not improve from 0.17080
# Epoch 39/1000
#  - 0s - loss: 0.6827 - accuracy: 0.5555 - val_loss: 0.1708 - val_accuracy: 2.1893
#
# Epoch 00039: val_loss did not improve from 0.17080
# Epoch 40/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5561 - val_loss: 0.1708 - val_accuracy: 2.1912
#
# Epoch 00040: val_loss did not improve from 0.17080
# Epoch 41/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5587 - val_loss: 0.1708 - val_accuracy: 2.1912
#
# Epoch 00041: val_loss did not improve from 0.17080
# Epoch 42/1000
#  - 0s - loss: 0.6826 - accuracy: 0.5572 - val_loss: 0.1708 - val_accuracy: 2.1912
#
# Epoch 00042: val_loss did not improve from 0.17080
# Epoch 43/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5574 - val_loss: 0.1708 - val_accuracy: 2.1893
#
# Epoch 00043: val_loss did not improve from 0.17080
# Epoch 44/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5572 - val_loss: 0.1708 - val_accuracy: 2.1874
#
# Epoch 00044: val_loss did not improve from 0.17080
# Epoch 45/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5594 - val_loss: 0.1708 - val_accuracy: 2.1893
#
# Epoch 00045: val_loss did not improve from 0.17080
# Epoch 46/1000
#  - 0s - loss: 0.6819 - accuracy: 0.5575 - val_loss: 0.1708 - val_accuracy: 2.1855
#
# Epoch 00046: val_loss did not improve from 0.17080
# Epoch 47/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5582 - val_loss: 0.1708 - val_accuracy: 2.1855
#
# Epoch 00047: val_loss did not improve from 0.17080
# Epoch 48/1000
#  - 0s - loss: 0.6824 - accuracy: 0.5571 - val_loss: 0.1708 - val_accuracy: 2.1855
#
# Epoch 00048: val_loss did not improve from 0.17080
# Epoch 49/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5578 - val_loss: 0.1708 - val_accuracy: 2.1912
#
# Epoch 00049: val_loss did not improve from 0.17080
# Epoch 50/1000
#  - 0s - loss: 0.6825 - accuracy: 0.5579 - val_loss: 0.1708 - val_accuracy: 2.1912
#
# Epoch 00050: val_loss did not improve from 0.17080
# Epoch 51/1000
#  - 0s - loss: 0.6823 - accuracy: 0.5568 - val_loss: 0.1708 - val_accuracy: 2.1931
#
# Epoch 00051: val_loss did not improve from 0.17080
# test_result.shape : (1, 2)
# total_result.shape : (122, 1, 2)
# new_x_train.shape : (6276, 45, 1)
# new_x_test.shape : (1, 45, 1)
# new_x_val.shape : (2092, 45, 1)
# new_y_train.shape : (6276, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (2092, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3451, 2825])) [1.22159292 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1113,  979])) [1.13687436 1.        ]
# class_weights : {0: 0.9093016516951609, 1: 1.110796460176991}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (6276, 2)
# new_y_val_ohe.shape : (2092, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# ----------------------- layers freezed without last layer ! -----------------------
# Train on 6276 samples, validate on 2092 samples
# Epoch 1/1000
#  - 1s - loss: 0.6832 - accuracy: 0.5562 - val_loss: 0.1704 - val_accuracy: 2.1969
#
# Epoch 00001: val_loss improved from inf to 0.17037, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_lstm_close_updown_pr_retrain_2shift_transfer_SXPUSDT_timesplit.h5
# Epoch 2/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5557 - val_loss: 0.1704 - val_accuracy: 2.1989
#
# Epoch 00002: val_loss did not improve from 0.17037
# Epoch 3/1000
#  - 0s - loss: 0.6832 - accuracy: 0.5545 - val_loss: 0.1704 - val_accuracy: 2.2008
#
# Epoch 00003: val_loss did not improve from 0.17037
# Epoch 4/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5555 - val_loss: 0.1704 - val_accuracy: 2.2008
#
# Epoch 00004: val_loss did not improve from 0.17037
# Epoch 5/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5572 - val_loss: 0.1704 - val_accuracy: 2.2008
#
# Epoch 00005: val_loss did not improve from 0.17037
# Epoch 6/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5558 - val_loss: 0.1704 - val_accuracy: 2.2027
#
# Epoch 00006: val_loss did not improve from 0.17037
# Epoch 7/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5558 - val_loss: 0.1704 - val_accuracy: 2.2046
#
# Epoch 00007: val_loss did not improve from 0.17037
# Epoch 8/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5553 - val_loss: 0.1704 - val_accuracy: 2.2065
#
# Epoch 00008: val_loss did not improve from 0.17037
# Epoch 9/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5562 - val_loss: 0.1704 - val_accuracy: 2.2103
#
# Epoch 00009: val_loss did not improve from 0.17037
# Epoch 10/1000
#  - 0s - loss: 0.6832 - accuracy: 0.5555 - val_loss: 0.1704 - val_accuracy: 2.2065
#
# Epoch 00010: val_loss did not improve from 0.17037
# Epoch 11/1000
#  - 0s - loss: 0.6829 - accuracy: 0.5555 - val_loss: 0.1704 - val_accuracy: 2.2027
#
# Epoch 00011: val_loss did not improve from 0.17037
# Epoch 12/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5547 - val_loss: 0.1704 - val_accuracy: 2.2027
#
# Epoch 00012: val_loss did not improve from 0.17037
# Epoch 13/1000
#  - 0s - loss: 0.6826 - accuracy: 0.5562 - val_loss: 0.1704 - val_accuracy: 2.2046
#
# Epoch 00013: val_loss did not improve from 0.17037
# Epoch 14/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5567 - val_loss: 0.1704 - val_accuracy: 2.2084
#
# Epoch 00014: val_loss did not improve from 0.17037
# Epoch 15/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5569 - val_loss: 0.1704 - val_accuracy: 2.2084
#
# Epoch 00015: val_loss did not improve from 0.17037
# Epoch 16/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5575 - val_loss: 0.1704 - val_accuracy: 2.2103
#
# Epoch 00016: val_loss did not improve from 0.17037
# Epoch 17/1000
#  - 0s - loss: 0.6827 - accuracy: 0.5570 - val_loss: 0.1704 - val_accuracy: 2.2084
#
# Epoch 00017: val_loss did not improve from 0.17037
# Epoch 18/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5571 - val_loss: 0.1704 - val_accuracy: 2.2065
#
# Epoch 00018: val_loss did not improve from 0.17037
# Epoch 19/1000
#  - 0s - loss: 0.6827 - accuracy: 0.5593 - val_loss: 0.1704 - val_accuracy: 2.2065
#
# Epoch 00019: val_loss did not improve from 0.17037
# Epoch 20/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5563 - val_loss: 0.1704 - val_accuracy: 2.2065
#
# Epoch 00020: val_loss did not improve from 0.17037
# Epoch 21/1000
#  - 0s - loss: 0.6829 - accuracy: 0.5575 - val_loss: 0.1704 - val_accuracy: 2.2065
#
# Epoch 00021: val_loss did not improve from 0.17037
# Epoch 22/1000
#  - 0s - loss: 0.6829 - accuracy: 0.5561 - val_loss: 0.1704 - val_accuracy: 2.2027
#
# Epoch 00022: val_loss did not improve from 0.17037
# Epoch 23/1000
#  - 0s - loss: 0.6832 - accuracy: 0.5551 - val_loss: 0.1704 - val_accuracy: 2.1989
#
# Epoch 00023: val_loss did not improve from 0.17037
# Epoch 24/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5558 - val_loss: 0.1704 - val_accuracy: 2.2008
#
# Epoch 00024: val_loss did not improve from 0.17037
# Epoch 25/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5565 - val_loss: 0.1704 - val_accuracy: 2.2008
#
# Epoch 00025: val_loss did not improve from 0.17037
# Epoch 26/1000
#  - 0s - loss: 0.6832 - accuracy: 0.5550 - val_loss: 0.1704 - val_accuracy: 2.2008
#
# Epoch 00026: val_loss did not improve from 0.17037
# Epoch 27/1000
#  - 0s - loss: 0.6826 - accuracy: 0.5578 - val_loss: 0.1704 - val_accuracy: 2.2027
#
# Epoch 00027: val_loss did not improve from 0.17037
# Epoch 28/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5558 - val_loss: 0.1704 - val_accuracy: 2.1989
#
# Epoch 00028: val_loss did not improve from 0.17037
# Epoch 29/1000
#  - 0s - loss: 0.6827 - accuracy: 0.5579 - val_loss: 0.1704 - val_accuracy: 2.1989
#
# Epoch 00029: val_loss did not improve from 0.17037
# Epoch 30/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5544 - val_loss: 0.1704 - val_accuracy: 2.1989
#
# Epoch 00030: val_loss did not improve from 0.17037
# Epoch 31/1000
#  - 0s - loss: 0.6825 - accuracy: 0.5579 - val_loss: 0.1704 - val_accuracy: 2.1989
#
# Epoch 00031: val_loss did not improve from 0.17037
# Epoch 32/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5568 - val_loss: 0.1704 - val_accuracy: 2.2008
#
# Epoch 00032: val_loss did not improve from 0.17037
# Epoch 33/1000
#  - 0s - loss: 0.6826 - accuracy: 0.5569 - val_loss: 0.1704 - val_accuracy: 2.1989
#
# Epoch 00033: val_loss did not improve from 0.17037
# Epoch 34/1000
#  - 0s - loss: 0.6829 - accuracy: 0.5555 - val_loss: 0.1704 - val_accuracy: 2.1969
#
# Epoch 00034: val_loss did not improve from 0.17037
# Epoch 35/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5582 - val_loss: 0.1704 - val_accuracy: 2.1969
#
# Epoch 00035: val_loss did not improve from 0.17037
# Epoch 36/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5587 - val_loss: 0.1704 - val_accuracy: 2.1969
#
# Epoch 00036: val_loss did not improve from 0.17037
# Epoch 37/1000
#  - 0s - loss: 0.6829 - accuracy: 0.5579 - val_loss: 0.1704 - val_accuracy: 2.1969
#
# Epoch 00037: val_loss did not improve from 0.17037
# Epoch 38/1000
#  - 0s - loss: 0.6827 - accuracy: 0.5579 - val_loss: 0.1704 - val_accuracy: 2.1969
#
# Epoch 00038: val_loss did not improve from 0.17037
# Epoch 39/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5556 - val_loss: 0.1704 - val_accuracy: 2.1989
#
# Epoch 00039: val_loss did not improve from 0.17037
# Epoch 40/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5563 - val_loss: 0.1704 - val_accuracy: 2.2008
#
# Epoch 00040: val_loss did not improve from 0.17037
# Epoch 41/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5579 - val_loss: 0.1704 - val_accuracy: 2.1989
#
# Epoch 00041: val_loss did not improve from 0.17037
# Epoch 42/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5581 - val_loss: 0.1704 - val_accuracy: 2.1989
#
# Epoch 00042: val_loss did not improve from 0.17037
# Epoch 43/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5598 - val_loss: 0.1704 - val_accuracy: 2.1969
#
# Epoch 00043: val_loss did not improve from 0.17037
# Epoch 44/1000
#  - 0s - loss: 0.6829 - accuracy: 0.5573 - val_loss: 0.1704 - val_accuracy: 2.1950
#
# Epoch 00044: val_loss did not improve from 0.17037
# Epoch 45/1000
#  - 0s - loss: 0.6826 - accuracy: 0.5572 - val_loss: 0.1704 - val_accuracy: 2.1950
#
# Epoch 00045: val_loss did not improve from 0.17037
# Epoch 46/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5554 - val_loss: 0.1704 - val_accuracy: 2.1931
#
# Epoch 00046: val_loss did not improve from 0.17037
# Epoch 47/1000
#  - 0s - loss: 0.6825 - accuracy: 0.5583 - val_loss: 0.1704 - val_accuracy: 2.1950
#
# Epoch 00047: val_loss did not improve from 0.17037
# Epoch 48/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5563 - val_loss: 0.1704 - val_accuracy: 2.1931
#
# Epoch 00048: val_loss did not improve from 0.17037
# Epoch 49/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5582 - val_loss: 0.1704 - val_accuracy: 2.1931
#
# Epoch 00049: val_loss did not improve from 0.17037
# Epoch 50/1000
#  - 0s - loss: 0.6829 - accuracy: 0.5569 - val_loss: 0.1704 - val_accuracy: 2.1931
#
# Epoch 00050: val_loss did not improve from 0.17037
# Epoch 51/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5572 - val_loss: 0.1704 - val_accuracy: 2.1931
#
# Epoch 00051: val_loss did not improve from 0.17037
# test_result.shape : (1, 2)
# total_result.shape : (123, 1, 2)
# new_x_train.shape : (6276, 45, 1)
# new_x_test.shape : (1, 45, 1)
# new_x_val.shape : (2092, 45, 1)
# new_y_train.shape : (6276, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (2092, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3435, 2841])) [1.20908131 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1128,  964])) [1.17012448 1.        ]
# class_weights : {0: 0.9135371179039301, 1: 1.1045406546990497}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (6276, 2)
# new_y_val_ohe.shape : (2092, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# ----------------------- layers freezed without last layer ! -----------------------
# Train on 6276 samples, validate on 2092 samples
# Epoch 1/1000
#  - 1s - loss: 0.6832 - accuracy: 0.5542 - val_loss: 0.1702 - val_accuracy: 2.2122
#
# Epoch 00001: val_loss improved from inf to 0.17018, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_lstm_close_updown_pr_retrain_2shift_transfer_SXPUSDT_timesplit.h5
# Epoch 2/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5537 - val_loss: 0.1702 - val_accuracy: 2.2122
#
# Epoch 00002: val_loss did not improve from 0.17018
# Epoch 3/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5537 - val_loss: 0.1702 - val_accuracy: 2.2122
#
# Epoch 00003: val_loss did not improve from 0.17018
# Epoch 4/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5529 - val_loss: 0.1702 - val_accuracy: 2.2103
#
# Epoch 00004: val_loss did not improve from 0.17018
# Epoch 5/1000
#  - 0s - loss: 0.6832 - accuracy: 0.5542 - val_loss: 0.1702 - val_accuracy: 2.2103
#
# Epoch 00005: val_loss did not improve from 0.17018
# Epoch 6/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5545 - val_loss: 0.1702 - val_accuracy: 2.2103
#
# Epoch 00006: val_loss did not improve from 0.17018
# Epoch 7/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5518 - val_loss: 0.1702 - val_accuracy: 2.2122
#
# Epoch 00007: val_loss did not improve from 0.17018
# Epoch 8/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5541 - val_loss: 0.1702 - val_accuracy: 2.2103
#
# Epoch 00008: val_loss did not improve from 0.17018
# Epoch 9/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5535 - val_loss: 0.1702 - val_accuracy: 2.2084
#
# Epoch 00009: val_loss did not improve from 0.17018
# Epoch 10/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5532 - val_loss: 0.1702 - val_accuracy: 2.2103
#
# Epoch 00010: val_loss did not improve from 0.17018
# Epoch 11/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5540 - val_loss: 0.1702 - val_accuracy: 2.2084
#
# Epoch 00011: val_loss did not improve from 0.17018
# Epoch 12/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5534 - val_loss: 0.1702 - val_accuracy: 2.2065
#
# Epoch 00012: val_loss did not improve from 0.17018
# Epoch 13/1000
#  - 0s - loss: 0.6829 - accuracy: 0.5557 - val_loss: 0.1702 - val_accuracy: 2.2084
#
# Epoch 00013: val_loss did not improve from 0.17018
# Epoch 14/1000
#  - 0s - loss: 0.6829 - accuracy: 0.5560 - val_loss: 0.1702 - val_accuracy: 2.2065
#
# Epoch 00014: val_loss did not improve from 0.17018
# Epoch 15/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5549 - val_loss: 0.1702 - val_accuracy: 2.2046
#
# Epoch 00015: val_loss did not improve from 0.17018
# Epoch 16/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5550 - val_loss: 0.1702 - val_accuracy: 2.2046
#
# Epoch 00016: val_loss did not improve from 0.17018
# Epoch 17/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5564 - val_loss: 0.1702 - val_accuracy: 2.2046
#
# Epoch 00017: val_loss did not improve from 0.17018
# Epoch 18/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5550 - val_loss: 0.1702 - val_accuracy: 2.2065
#
# Epoch 00018: val_loss did not improve from 0.17018
# Epoch 19/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5531 - val_loss: 0.1702 - val_accuracy: 2.2065
#
# Epoch 00019: val_loss did not improve from 0.17018
# Epoch 20/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5546 - val_loss: 0.1702 - val_accuracy: 2.2065
#
# Epoch 00020: val_loss did not improve from 0.17018
# Epoch 21/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5531 - val_loss: 0.1702 - val_accuracy: 2.2065
#
# Epoch 00021: val_loss did not improve from 0.17018
# Epoch 22/1000
#  - 0s - loss: 0.6829 - accuracy: 0.5545 - val_loss: 0.1702 - val_accuracy: 2.2065
#
# Epoch 00022: val_loss did not improve from 0.17018
# Epoch 23/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5524 - val_loss: 0.1702 - val_accuracy: 2.2065
#
# Epoch 00023: val_loss did not improve from 0.17018
# Epoch 24/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5554 - val_loss: 0.1702 - val_accuracy: 2.2084
#
# ...
# Epoch 40/1000
#  - 0s - loss: 0.6819 - accuracy: 0.5541 - val_loss: 0.1709 - val_accuracy: 2.2141
#
# Epoch 00040: val_loss did not improve from 0.17084
# Epoch 41/1000
#  - 0s - loss: 0.6819 - accuracy: 0.5535 - val_loss: 0.1709 - val_accuracy: 2.2141
#
# Epoch 00041: val_loss did not improve from 0.17084
# Epoch 42/1000
#  - 0s - loss: 0.6821 - accuracy: 0.5544 - val_loss: 0.1709 - val_accuracy: 2.2141
#
# Epoch 00042: val_loss did not improve from 0.17084
# Epoch 43/1000
#  - 0s - loss: 0.6821 - accuracy: 0.5529 - val_loss: 0.1709 - val_accuracy: 2.2141
#
# Epoch 00043: val_loss did not improve from 0.17084
# Epoch 44/1000
#  - 0s - loss: 0.6818 - accuracy: 0.5541 - val_loss: 0.1709 - val_accuracy: 2.2141
#
# Epoch 00044: val_loss did not improve from 0.17084
# Epoch 45/1000
#  - 0s - loss: 0.6818 - accuracy: 0.5543 - val_loss: 0.1709 - val_accuracy: 2.2141
#
# Epoch 00045: val_loss did not improve from 0.17084
# Epoch 46/1000
#  - 0s - loss: 0.6825 - accuracy: 0.5512 - val_loss: 0.1709 - val_accuracy: 2.2141
#
# Epoch 00046: val_loss did not improve from 0.17084
# Epoch 47/1000
#  - 0s - loss: 0.6817 - accuracy: 0.5545 - val_loss: 0.1709 - val_accuracy: 2.2141
#
# Epoch 00047: val_loss did not improve from 0.17084
# Epoch 48/1000
#  - 0s - loss: 0.6825 - accuracy: 0.5526 - val_loss: 0.1709 - val_accuracy: 2.2141
#
# Epoch 00048: val_loss did not improve from 0.17084
# Epoch 49/1000
#  - 0s - loss: 0.6818 - accuracy: 0.5552 - val_loss: 0.1709 - val_accuracy: 2.2161
#
# Epoch 00049: val_loss did not improve from 0.17084
# Epoch 50/1000
#  - 0s - loss: 0.6818 - accuracy: 0.5555 - val_loss: 0.1709 - val_accuracy: 2.2141
#
# Epoch 00050: val_loss did not improve from 0.17084
# Epoch 51/1000
#  - 0s - loss: 0.6822 - accuracy: 0.5528 - val_loss: 0.1709 - val_accuracy: 2.2141
#
# Epoch 00051: val_loss did not improve from 0.17084
# Epoch 52/1000
#  - 0s - loss: 0.6825 - accuracy: 0.5550 - val_loss: 0.1709 - val_accuracy: 2.2161
#
# Epoch 00052: val_loss did not improve from 0.17084
# test_result.shape : (1, 2)
# total_result.shape : (139, 1, 2)
# new_x_train.shape : (6276, 45, 1)
# new_x_test.shape : (1, 45, 1)
# new_x_val.shape : (2092, 45, 1)
# new_y_train.shape : (6276, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (2092, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3417, 2859])) [1.19517314 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1144,  948])) [1.20675105 1.        ]
# class_weights : {0: 0.9183494293239683, 1: 1.0975865687303252}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (6276, 2)
# new_y_val_ohe.shape : (2092, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# ----------------------- layers freezed without last layer ! -----------------------
# Train on 6276 samples, validate on 2092 samples
# Epoch 1/1000
#  - 1s - loss: 0.6839 - accuracy: 0.5506 - val_loss: 0.1698 - val_accuracy: 2.2925
#
# Epoch 00001: val_loss improved from inf to 0.16981, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_lstm_close_updown_pr_retrain_2shift_transfer_SXPUSDT_timesplit.h5
# Epoch 2/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5515 - val_loss: 0.1698 - val_accuracy: 2.2906
#
# Epoch 00002: val_loss did not improve from 0.16981
# Epoch 3/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5502 - val_loss: 0.1698 - val_accuracy: 2.2906
#
# Epoch 00003: val_loss did not improve from 0.16981
# Epoch 4/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5521 - val_loss: 0.1698 - val_accuracy: 2.2906
#
# Epoch 00004: val_loss did not improve from 0.16981
# Epoch 5/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5512 - val_loss: 0.1698 - val_accuracy: 2.2925
#
# Epoch 00005: val_loss did not improve from 0.16981
# Epoch 6/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5506 - val_loss: 0.1698 - val_accuracy: 2.2906
#
# Epoch 00006: val_loss did not improve from 0.16981
# Epoch 7/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5531 - val_loss: 0.1698 - val_accuracy: 2.2906
#
# Epoch 00007: val_loss did not improve from 0.16981
# Epoch 8/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5528 - val_loss: 0.1698 - val_accuracy: 2.2906
#
# Epoch 00008: val_loss did not improve from 0.16981
# Epoch 9/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5512 - val_loss: 0.1698 - val_accuracy: 2.2868
#
# Epoch 00009: val_loss did not improve from 0.16981
# Epoch 10/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5515 - val_loss: 0.1698 - val_accuracy: 2.2830
#
# Epoch 00010: val_loss did not improve from 0.16981
# Epoch 11/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5517 - val_loss: 0.1698 - val_accuracy: 2.2849
#
# Epoch 00011: val_loss did not improve from 0.16981
# Epoch 12/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5495 - val_loss: 0.1698 - val_accuracy: 2.2792
#
# Epoch 00012: val_loss did not improve from 0.16981
# Epoch 13/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5519 - val_loss: 0.1698 - val_accuracy: 2.2772
#
# Epoch 00013: val_loss did not improve from 0.16981
# Epoch 14/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5518 - val_loss: 0.1698 - val_accuracy: 2.2753
#
# Epoch 00014: val_loss did not improve from 0.16981
# Epoch 15/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5507 - val_loss: 0.1698 - val_accuracy: 2.2753
#
# Epoch 00015: val_loss did not improve from 0.16981
# Epoch 16/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5497 - val_loss: 0.1698 - val_accuracy: 2.2753
#
# Epoch 00016: val_loss did not improve from 0.16981
# Epoch 17/1000
#  - 0s - loss: 0.6839 - accuracy: 0.5511 - val_loss: 0.1699 - val_accuracy: 2.2753
#
# Epoch 00017: val_loss did not improve from 0.16981
# Epoch 18/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5507 - val_loss: 0.1699 - val_accuracy: 2.2753
#
# Epoch 00018: val_loss did not improve from 0.16981
# Epoch 19/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5523 - val_loss: 0.1699 - val_accuracy: 2.2792
#
# Epoch 00019: val_loss did not improve from 0.16981
# Epoch 20/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5517 - val_loss: 0.1699 - val_accuracy: 2.2753
#
# Epoch 00020: val_loss did not improve from 0.16981
# Epoch 21/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5505 - val_loss: 0.1699 - val_accuracy: 2.2792
#
# Epoch 00021: val_loss did not improve from 0.16981
# Epoch 22/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5522 - val_loss: 0.1699 - val_accuracy: 2.2772
#
# Epoch 00022: val_loss did not improve from 0.16981
# Epoch 23/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5519 - val_loss: 0.1699 - val_accuracy: 2.2734
#
# Epoch 00023: val_loss did not improve from 0.16981
# Epoch 24/1000
#  - 0s - loss: 0.6838 - accuracy: 0.5496 - val_loss: 0.1699 - val_accuracy: 2.2734
#
# Epoch 00024: val_loss did not improve from 0.16981
# Epoch 25/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5518 - val_loss: 0.1699 - val_accuracy: 2.2772
#
# Epoch 00025: val_loss did not improve from 0.16981
# Epoch 26/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5523 - val_loss: 0.1699 - val_accuracy: 2.2753
#
# Epoch 00026: val_loss did not improve from 0.16981
# Epoch 27/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5503 - val_loss: 0.1699 - val_accuracy: 2.2715
#
# Epoch 00027: val_loss did not improve from 0.16981
# Epoch 28/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5509 - val_loss: 0.1699 - val_accuracy: 2.2715
#
# Epoch 00028: val_loss did not improve from 0.16981
# Epoch 29/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5522 - val_loss: 0.1699 - val_accuracy: 2.2715
#
# Epoch 00029: val_loss did not improve from 0.16981
# Epoch 30/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5522 - val_loss: 0.1699 - val_accuracy: 2.2715
#
# Epoch 00030: val_loss did not improve from 0.16981
# Epoch 31/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5513 - val_loss: 0.1699 - val_accuracy: 2.2696
#
# Epoch 00031: val_loss did not improve from 0.16981
# Epoch 32/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5542 - val_loss: 0.1699 - val_accuracy: 2.2677
#
# Epoch 00032: val_loss did not improve from 0.16981
# Epoch 33/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5514 - val_loss: 0.1699 - val_accuracy: 2.2677
#
# Epoch 00033: val_loss did not improve from 0.16981
# Epoch 34/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5529 - val_loss: 0.1699 - val_accuracy: 2.2696
#
# Epoch 00034: val_loss did not improve from 0.16981
# Epoch 35/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5528 - val_loss: 0.1699 - val_accuracy: 2.2715
#
# Epoch 00035: val_loss did not improve from 0.16981
# Epoch 36/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5534 - val_loss: 0.1699 - val_accuracy: 2.2715
#
# Epoch 00036: val_loss did not improve from 0.16981
# Epoch 37/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5512 - val_loss: 0.1699 - val_accuracy: 2.2696
#
# Epoch 00037: val_loss did not improve from 0.16981
# Epoch 38/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5527 - val_loss: 0.1699 - val_accuracy: 2.2696
#
# Epoch 00038: val_loss did not improve from 0.16981
# Epoch 39/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5514 - val_loss: 0.1699 - val_accuracy: 2.2696
#
# Epoch 00039: val_loss did not improve from 0.16981
# Epoch 40/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5526 - val_loss: 0.1699 - val_accuracy: 2.2677
#
# Epoch 00040: val_loss did not improve from 0.16981
# Epoch 41/1000
#  - 0s - loss: 0.6837 - accuracy: 0.5500 - val_loss: 0.1699 - val_accuracy: 2.2658
#
# Epoch 00041: val_loss did not improve from 0.16981
# Epoch 42/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5517 - val_loss: 0.1699 - val_accuracy: 2.2658
#
# Epoch 00042: val_loss did not improve from 0.16981
# Epoch 43/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5524 - val_loss: 0.1699 - val_accuracy: 2.2658
#
# Epoch 00043: val_loss did not improve from 0.16981
# Epoch 44/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5537 - val_loss: 0.1699 - val_accuracy: 2.2639
#
# Epoch 00044: val_loss did not improve from 0.16981
# Epoch 45/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5525 - val_loss: 0.1699 - val_accuracy: 2.2639
#
# Epoch 00045: val_loss did not improve from 0.16981
# Epoch 46/1000
#  - 0s - loss: 0.6835 - accuracy: 0.5519 - val_loss: 0.1699 - val_accuracy: 2.2639
#
# Epoch 00046: val_loss did not improve from 0.16981
# Epoch 47/1000
#  - 0s - loss: 0.6834 - accuracy: 0.5519 - val_loss: 0.1699 - val_accuracy: 2.2639
#
# Epoch 00047: val_loss did not improve from 0.16981
# Epoch 48/1000
#  - 0s - loss: 0.6832 - accuracy: 0.5528 - val_loss: 0.1699 - val_accuracy: 2.2620
#
# Epoch 00048: val_loss did not improve from 0.16981
# Epoch 49/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5507 - val_loss: 0.1699 - val_accuracy: 2.2620
#
# Epoch 00049: val_loss did not improve from 0.16981
# Epoch 50/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5504 - val_loss: 0.1699 - val_accuracy: 2.2600
#
# Epoch 00050: val_loss did not improve from 0.16981
# Epoch 51/1000
#  - 0s - loss: 0.6836 - accuracy: 0.5528 - val_loss: 0.1699 - val_accuracy: 2.2620
#
# Epoch 00051: val_loss did not improve from 0.16981
# test_result.shape : (1, 2)
# total_result.shape : (140, 1, 2)
# new_x_train.shape : (6276, 45, 1)
# new_x_test.shape : (1, 45, 1)
# new_x_val.shape : (2092, 45, 1)
# new_y_train.shape : (6276, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (2092, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3379, 2897])) [1.16637901 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1182,  910])) [1.2989011 1.       ]
# class_weights : {0: 0.9286771234092926, 1: 1.0831895063859165}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (6276, 2)
# new_y_val_ohe.shape : (2092, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# ----------------------- layers freezed without last layer ! -----------------------
# Train on 6276 samples, validate on 2092 samples
# Epoch 1/1000
#  - 1s - loss: 0.6828 - accuracy: 0.5547 - val_loss: 0.1701 - val_accuracy: 2.2734
#
# Epoch 00001: val_loss improved from inf to 0.17007, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_lstm_close_updown_pr_retrain_2shift_transfer_SXPUSDT_timesplit.h5
# Epoch 2/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5533 - val_loss: 0.1701 - val_accuracy: 2.2753
#
# Epoch 00002: val_loss did not improve from 0.17007
# Epoch 3/1000
#  - 0s - loss: 0.6833 - accuracy: 0.5525 - val_loss: 0.1701 - val_accuracy: 2.2772
#
# Epoch 00003: val_loss did not improve from 0.17007
# Epoch 4/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5536 - val_loss: 0.1701 - val_accuracy: 2.2792
#
# Epoch 00004: val_loss did not improve from 0.17007
# Epoch 5/1000
#  - 0s - loss: 0.6830 - accuracy: 0.5530 - val_loss: 0.1701 - val_accuracy: 2.2792
#
# Epoch 00005: val_loss did not improve from 0.17007
# Epoch 6/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5534 - val_loss: 0.1701 - val_accuracy: 2.2792
#
# Epoch 00006: val_loss did not improve from 0.17007
# Epoch 7/1000
#  - 0s - loss: 0.6828 - accuracy: 0.5521 - val_loss: 0.1701 - val_accuracy: 2.2811
#
# Epoch 00007: val_loss did not improve from 0.17007
# Epoch 8/1000
#  - 0s - loss: 0.6829 - accuracy: 0.5530 - val_loss: 0.1701 - val_accuracy: 2.2792
#
# Epoch 00008: val_loss did not improve from 0.17007
# Epoch 9/1000
#  - 0s - loss: 0.6826 - accuracy: 0.5552 - val_loss: 0.1701 - val_accuracy: 2.2792
#
# Epoch 00009: val_loss did not improve from 0.17007
# Epoch 10/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5517 - val_loss: 0.1701 - val_accuracy: 2.2792
#
# Epoch 00010: val_loss did not improve from 0.17007
# Epoch 11/1000
#  - 0s - loss: 0.6827 - accuracy: 0.5534 - val_loss: 0.1701 - val_accuracy: 2.2772
#
# Epoch 00011: val_loss did not improve from 0.17007
# Epoch 12/1000
#  - 0s - loss: 0.6831 - accuracy: 0.5538 - val_loss: 0.1701 - val_accuracy: 2.2772
#
# Epoch 00012: val_loss did not improve from 0.17007
# Epoch 13/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-c2a5b98fd18f> in <module>()
#     633                             validation_data=(new_x_val, new_y_val_ohe),
#     634                             validation_steps=int(len(new_x_val) / batch_size),
# --> 635                             shuffle=False)
#     636
#     637         ckpt_path = current_path + 'ckpt/'
#
# /tensorflow-1.15.2/python3.7/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# /tensorflow-1.15.2/python3.7/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     150                 batch_logs = {'batch': step_index, 'size': 1}
#     151                 callbacks._call_batch_hook('train', 'begin', step_index, batch_logs)
# --> 152                 outs = fit_function(fit_inputs)
#     153
#     154                 outs = to_list(outs)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
total_result = np.array(total_result).reshape(-1, 2)
y_score = total_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test[:len(y_score)], y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.6]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test[:len(y_score)], y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test[:len(y_score)])
  test_pr_list = pr_test[:len(y_score)]
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  if len(threshold) == 1:
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(test_pr_list))
    plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
  # plt.show()

    plt.subplot(122)
    plt.plot(np.cumprod(pred_pr_list))
    plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    # plt.axvline(len(org_pr_test), linestyle='--', color='r')
    plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)])
plt.title(symbol_name + '\n' + "%s" % new_thresh[np.argmax(acc_pr_bythr)])
plt.show()
# Out:
# y_test[:5] : [1 0 0 1 0]
# y_score[:5] : [[0.51511145]
#  [0.53504604]
#  [0.57570577]
#  [0.5237232 ]
#  [0.53470224]]
# y_test.shape : (2092, 1)
# y_score.shape : (140, 1)
# len(y_test) : 2092
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [0.11709745, 0.11544919, 0.120533444, 0.12783435, 0.11883819, 0.10965623, 0.09999532, 0.09853271, 0.10273951, 0.0982651, 0.09181646, 0.09042718, 0.093353525, 0.083273396, 0.07291465, 0.07273388, 0.07524687, 0.07219344, 0.071019955, 0.06545226, 0.06495466, 0.060128115, 0.05842976, 0.06116456, 0.060156506, 0.05463029, 0.05269231, 0.05252948, 0.05355678, 0.052679747, 0.05229011, 0.04943318, 0.04904349, 0.049711123, 0.04887722, 0.049622253, 0.04941567, 0.049514238, 0.045663677, 0.04329431, 0.04128122, 0.037891217, 0.03821244, 0.03780241, 0.038198188, 0.035004564, 0.03594103, 0.039241407, 0.037744224, 0.037470207, 0.039193776, 0.037406296, 0.037483547, 0.037463713, 0.03495317, 0.034309693, 0.038938157, 0.03935092, 0.03994543, 0.040009264, 0.045995653, 0.0499625, 0.0525702, 0.05129909, 0.046795078, 0.05418107, 0.051516425, 0.05288319, 0.051120527, 0.058053136, 0.056536235, 0.059925836, 0.057603, 0.056634277, 0.060094573, 0.06097062, 0.06624703, 0.07036952, 0.06541563, 0.056373026, 0.05524127, 0.059494324, 0.056250382, 0.057856042, 0.061981488, 0.06898581, 0.07486843, 0.075752415, 0.0725877, 0.06569815, 0.07189116, 0.07001008, 0.0731239, 0.07586165, 0.08204666, 0.091262996, 0.09219064, 0.09185078, 0.10378579, 0.10878871, 0.105834015, 0.1090238, 0.11422238, 0.12087845, 0.1355595, 0.14100651, 0.13465196, 0.14619817, 0.14604034, 0.14616117, 0.16790318, 0.1689267, 0.14788611, 0.14298157, 0.12953138, 0.14747821, 0.14726163, 0.14733717, 0.16125387, 0.18642513, 0.19603415, 0.19413373, 0.18958941, 0.19517627, 0.20705533, 0.1992309, 0.204177, 0.20268227, 0.21991742, 0.21136367, 0.19573984, 0.21232761, 0.2159752, 0.23069066, 0.28139317, 0.36656815, 0.43269035, 0.53484243, 0.7170499, 1.0]

# %% [markdown]
# ### realtime threshold

# %%
#   lookback n - period, find and use the best thresh for the next infer    #
lb_period = 100

total_result = np.array(total_result).reshape(-1, 2)
y_score = total_result[:, [1]]

# def find_best_thr():
min_thr_list = np.arange(0.53, 0.57, 0.01)

for thr_i in tqdm(range(len(min_thr_list))):

  min_thr = min_thr_list[thr_i]

  best_thr_list = []
  new_pr_list = []
  for i in tqdm(range(lb_period, len(total_result))):

    precision, recall, threshold = precision_recall_curve(y_test[:len(y_score)][i - lb_period:i], y_score[i - lb_period:i])
    precision, recall = precision[:-1], recall[:-1]

    acc_pr_bythr = []
    new_thresh = []
    for thresh in threshold:

      if thresh < 0.5:
          continue

      #   lookback previous range   #
      y_pred = np.where(y_score[i - lb_period:i, -1] > thresh, 1, 0)

      test_size = len(y_test[:len(y_score)][i - lb_period:i])
      test_pr_list = pr_test[:len(y_score)][i - lb_period:i]

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)
    

    #       replace best_thr only max_pr > 1      #
    # if np.max(acc_pr_bythr) > 1.10:
    best_thr = new_thresh[np.argmax(acc_pr_bythr)]

    if best_thr < min_thr:
      best_thr = min_thr

      # if best_thr < 0.52:
      #   plt.subplot(121)
      #   plt.plot(threshold, precision, label='precision')
      #   plt.plot(threshold, recall, label='recall')
      #   plt.legend()
      #   plt.title('precision recall')
      #   # plt.show()
      #   plt.subplot(122)
      #   plt.plot(new_thresh, acc_pr_bythr)
      #   plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
      #   plt.axvline(new_thresh[np.argmax(acc_pr_bythr)])
      #   plt.title(symbol_name + '\n' + "%s" % new_thresh[np.argmax(acc_pr_bythr)])
      #   plt.show()


    best_thr_list.append(best_thr)

    #   use it   #
    new_pr = np.where(y_score[i, -1] > best_thr, pr_test[:len(y_score)][i], 1)

    #   use moving average  #
    # ma_period = 5
    # if len(best_thr_list) > ma_period:
    #   new_pr = np.where(y_score[i, -1] > np.mean(best_thr_list[-ma_period:]), pr_test[:len(y_score)][i], 1)

    new_pr_list.append(new_pr)

  plt.plot(np.cumprod(new_pr_list))
  plt.title(np.cumprod(new_pr_list)[-1])
  plt.show()

  plt.plot(best_thr_list)
  plt.title("best_thr_list")
  plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1982.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1982.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1982.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1982.0), HTML(value='')))

# %%
# model = FER_Model(input_shape=(45, 1))

period = 45
symbol_name = 'SXPUSDT'

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_%s_lstm_close_updown_pr_robust_trial_re_%s_timesplit.h5' % (period, symbol_name)

# model_name = 'classifier_%s_close_updown_pr_theta_shuffle_without_back_03.h5' % period

model = keras.models.load_model(ckpt_path + model_name)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
for l_i, layer in enumerate(model.layers):

  if l_i != len(model.layers) - 1:
    layer.trainable = False

  print(layer, layer.trainable)

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %% [markdown]
# ### **Training**

# %%
org_x_test = x_test
org_y_test = y_test
org_pr_test = pr_test

# %%
x_test = org_x_test
y_test = org_y_test
pr_test = org_pr_test

# %%
concat_x = np.vstack((org_x_test, new_input_x))
concat_y = np.vstack((org_y_test, np.where(new_input_pr > 1, 1, 0)))
concat_pr = np.vstack((org_pr_test, new_input_pr))

# %%
x_test = new_input_x
y_test = np.where(new_input_pr > 1, 1, 0)
pr_test = new_input_pr

# %%
# print(pred_pr_list)
for pr in pred_pr_list:
  if pr != 1:
    print(pr)

# %%
plt.figure(figsize=(50, 5))
plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test):len(org_pr_test) + 10])
# plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test) - 10:len(org_pr_test) + 10])
plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
# plt.axvline(len(org_pr_test), linestyle='--', color='r')
plt.show()

# %%
# plt.show()
# plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
