# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

with open('./arima_result/arima_opt_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
  load_dict = pickle.load(f)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break


# candis = list(load_dict.keys())
np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None

seed = 1
random_state = 201
np.random.seed(seed)

for i in range(len(candis)):

  keys = [candis[i]]


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      if 'sxp'.upper() not in key:
        continue
    
      ohlcv = pd.read_excel(date_path + key, index_col=0)
      print('len(ohlcv) :', len(ohlcv))


      #       select timestamp range      #
      # time_index = ohlcv.index
      # total_stamp = list(map(lambda x: datetime.timestamp(x), time_index)) 

      # rm_index_amt = np.sum(np.array(total_stamp) < start_stamp)

      # ohlcv = ohlcv.iloc[rm_index_amt:]
      # print(ohlcv.head())

      # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.3)]  # exclude back_range
      # predictions = load_dict[key]['predictions']
      # err_ranges = load_dict[key]['err_ranges']
      print("ohlcv.index[0] :", ohlcv.index[0])
      print("ohlcv.index[-1] :", ohlcv.index[-1])

      predictions = ohlcv['close'].shift(1).values
      err_ranges = np.zeros_like(predictions)

      # leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]

      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[-len(predictions):]
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = np.array(predictions)
      long_ep = long_ep.reshape(-1, 1)

      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 45
      data_x, data_pr, data_updown = [], [], []
      data_index = []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          min_max = MinMaxScaler()
          temp_ohlc = min_max.fit_transform(temp_ohlc)

          temp_data = temp_ohlc[:, [3]]


          #   vol -> min_max
          # temp_data[:, [5]] = min_max.fit_transform(temp_data[:, [5]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      if prev_x is None:
        prev_x = input_x
        prev_pr = input_pr
        prev_ud = input_ud
        prev_index = input_index

        total_x = prev_x
        total_pr = prev_pr
        total_ud = prev_ud
        total_index = prev_index

      else:
        total_x = np.vstack((prev_x, input_x))
        total_pr = np.vstack((prev_pr, input_pr))
        total_ud = np.vstack((prev_ud, input_ud)) 
        total_index = np.vstack((prev_index, input_index)) 

        prev_x = total_x
        prev_pr = total_pr
        prev_ud = total_ud
        prev_index = total_index

        print('total_x.shape :', total_x.shape)
        print('total_pr.shape :', total_pr.shape)
        print('total_ud.shape :', total_ud.shape)
        print('prev_index.shape :', prev_index.shape)

      # if prev_train_x is None:
      #   prev_train_x = x_train
      #   prev_val_x = x_val
      #   prev_test_x = x_test
        
      #   prev_train_pr = pr_train
      #   prev_val_pr = pr_val
      #   prev_test_pr = pr_test

      #   prev_train_ud = ud_train
      #   prev_val_ud = ud_val
      #   prev_test_ud = ud_test

      # else:

      #   total_train_x = np.vstack((prev_train_x, x_train))
      #   total_val_x = np.vstack((prev_val_x, x_val))
      #   total_test_x = np.vstack((prev_test_x, x_test))
      #   total_train_pr = np.vstack((prev_train_pr, pr_train))
      #   total_val_pr = np.vstack((prev_val_pr, pr_val))
      #   total_test_pr = np.vstack((prev_test_pr, pr_test))
      #   total_train_ud = np.vstack((prev_train_ud, ud_train))
      #   total_val_ud = np.vstack((prev_val_ud, ud_val))
      #   total_test_ud = np.vstack((prev_test_ud, ud_test))
        
      #   prev_train_x = total_train_x
      #   prev_val_x = total_val_x
      #   prev_test_x = total_test_x
        
      #   prev_train_pr = total_train_pr
      #   prev_val_pr = total_val_pr
      #   prev_test_pr = total_test_pr

      #   prev_train_ud = total_train_ud
      #   prev_val_ud = total_val_ud
      #   prev_test_ud = total_test_ud
        
      #   print("total_train_x.shape :", total_train_x.shape)
      #   print("total_val_x.shape :", total_val_x.shape)
      #   print("total_test_x.shape :", total_test_x.shape)
      #   print("total_train_pr.shape :", total_train_pr.shape)
      #   print("total_val_pr.shape :", total_val_pr.shape)
      #   print("total_test_pr.shape :", total_test_pr.shape)
      #   print("total_train_ud.shape :", total_train_ud.shape)
      #   print("total_val_ud.shape :", total_val_ud.shape)
      #   print("total_test_ud.shape :", total_test_ud.shape)

  # break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  # try:
  #   if len(total_x) > 300000:
  #     break
  # except:
  #   pass
# Out:
# start_stamp : 0
# len(ohlcv) : 13452
# ohlcv.index[0] : 2020-07-21 18:29:59.999000
# ohlcv.index[-1] : 2021-04-27 23:59:59.999000
# -------------- 2021-04-27 SXPUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 13452
# long_ep.shape : (13452, 1)
# len(pr_list) : 13452
# np.array(data_x).shape : (13082, 45, 1)
# input_x.shape : (13082, 90, 2, 3)
# input_x.dtype : float32
# input_pr.shape : (13082, 1)
# input_ud.shape : (13082, 1)
# input_index.shape : (13082, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
period = 45
# x_save_path = current_path + 'npy/' + '%s_close_updown_x.npy' % period
# y_save_path = current_path + 'npy/' + '%s_close_updown_y.npy' % period
#         save to npy     #
# x_save_path = current_path + 'npy/' + '%s_close_updown_theta_x_ex.npy' % period
# y_save_path = current_path + 'npy/' + '%s_close_updown_theta_y_ex.npy' % period

# total_x = np.load(x_save_path)
# total_pr = np.load(y_save_path)

# _, row, col, _ = total_x.shape

_, row, col, _ = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=True, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)


# print("new_input_x.shape :", new_input_x.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

# del total_x
# Out:
# (array([Timestamp('2020-07-22 16:59:59.999000'),
#        Timestamp('2020-07-22 17:29:59.999000'),
#        Timestamp('2020-07-22 17:59:59.999000'), ...,
#        Timestamp('2021-04-27 22:59:59.999000'),
#        Timestamp('2021-04-27 23:29:59.999000'),
#        Timestamp('2021-04-27 23:59:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (7848,)
# stamp_val.shape : (2617,)
# stamp_test.shape : (2617,)
# HBox(children=(FloatProgress(value=0.0, max=13082.0), HTML(value='')))
# x_train.shape : (7848, 90, 2, 3)
# x_val.shape : (2617, 90, 2, 3)
# x_test.shape : (2617, 90, 2, 3)

# %%
x_save_path = current_path + 'npy/' + '%s_close_updown_x_train_neo.npy' % period
np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

pr_save_path = current_path + 'npy/' + '%s_close_updown_pr_train_neo.npy' % period
np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')
# Out:
# x series saved !
# pr series saved !

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_close_updown_x_train2.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

y_save_path = current_path + 'npy/' + '%s_close_updown_y_train2.npy' % period
y_train = np.load(y_save_path)
y_val = np.load(y_save_path.replace('y_train', 'y_val'))
y_test = np.load(y_save_path.replace('y_train', 'y_test'))
print('y series loaded !')

_, row, col, _ = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape=(row, col, 3)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight
# import cv2


_, row, col, _ = x_train.shape

#         pr label   #
y_train = np.where(pr_train > 1, 1, 0)
y_test = np.where(pr_test > 1, 1, 0)
y_val = np.where(pr_val > 1, 1, 0)


seed = 1
random_state = 20
np.random.seed(seed)
# tf.random.set_seed(seed)

#         up label      #
# y_train = np.where(ud_train > 1, 1, 0)
# y_test = np.where(ud_test > 1, 1, 0)
# y_val = np.where(ud_val > 1, 1, 0)

# print('pr_train[:5] :', pr_train[:5])
# print('ud_train[:5] :', ud_train[:5])
print('y_train[:5] :', y_train[:5])
print('y_train.dtype :', y_train.dtype)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

def class_ratio(in_list):

  return in_list / in_list[1]

print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)

datagen = ImageDataGenerator( 
    # rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)

batch_size = 128

for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break
# Out:
# y_train[:5] : [[0]
#  [0]
#  [1]
#  [0]
#  [0]]
# y_train.dtype : int64
# x_train.shape : (7848, 90, 2, 3)
# x_test.shape : (2617, 90, 2, 3)
# x_val.shape : (2617, 90, 2, 3)
# y_train.shape : (7848, 1)
# y_test.shape : (2617, 1)
# y_val.shape : (2617, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([4209, 3639])) [1.15663644 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([1395, 1222])) [1.14157119 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([1392, 1225])) [1.13632653 1.        ]
# class_weights : {0: 0.932287954383464, 1: 1.0783182192910141}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (7848, 2)
# y_val_ohe.shape : (2617, 2)
# y_test_ohe.shape : (2617, 2)

# %% [markdown]
# ### **Training**

# %%
(_, row, col, _) = x_train.shape
  
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
# model_name = 'classifier_%s_close_updown_pr_theta_shuffle_without_back_03.h5' % period
# model_name = 'classifier_%s_close_updown_pr_theta_train_prevdata_005.h5' % period

# model_name = 'classifier_%s_close_updown_pr_theta_train_evendata_shuffle2_300k.h5' % period
# model_name = 'classifier_%s_close_updown_pr_all_pair_shuffle_final_0211_062.h5' % period
# model = keras.models.load_model(ckpt_path + model_name)


model = FER_Model(input_shape=(row, col, 3))
opt = Adam(lr=0.00001, decay=0.000005)
# opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model_name = 'classifier_%s_close_updown_pr_neo_close_tsplit.h5' % period

checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
# checkpoint3 = EarlyStopping(monitor='val_loss', patience=50)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]
# callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)
# Out:
# Epoch 1/1000
#  - 1s - loss: 0.7019 - accuracy: 0.5074 - val_loss: 0.7153 - val_accuracy: 0.4880
#
# Epoch 00001: val_loss improved from inf to 0.71534, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_close_updown_pr_neo_close_tsplit.h5
# Epoch 2/1000
#  - 1s - loss: 0.6975 - accuracy: 0.5213 - val_loss: 0.6889 - val_accuracy: 0.5075
#
# Epoch 00002: val_loss improved from 0.71534 to 0.68889, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_close_updown_pr_neo_close_tsplit.h5
# Epoch 3/1000
#  - 1s - loss: 0.6900 - accuracy: 0.5344 - val_loss: 0.6553 - val_accuracy: 0.5403
#
# Epoch 00003: val_loss improved from 0.68889 to 0.65533, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_close_updown_pr_neo_close_tsplit.h5
# Epoch 4/1000
#  - 1s - loss: 0.6911 - accuracy: 0.5473 - val_loss: 0.6806 - val_accuracy: 0.5052
#
# Epoch 00004: val_loss did not improve from 0.65533
# Epoch 5/1000
#  - 1s - loss: 0.6874 - accuracy: 0.5522 - val_loss: 0.6741 - val_accuracy: 0.5380
#
# Epoch 00005: val_loss did not improve from 0.65533
# Epoch 6/1000
#  - 1s - loss: 0.6897 - accuracy: 0.5394 - val_loss: 0.6740 - val_accuracy: 0.5311
#
# Epoch 00006: val_loss did not improve from 0.65533
# Epoch 7/1000
#  - 1s - loss: 0.6844 - accuracy: 0.5570 - val_loss: 0.6833 - val_accuracy: 0.5174
#
# Epoch 00007: val_loss did not improve from 0.65533
# Epoch 8/1000
#  - 1s - loss: 0.6845 - accuracy: 0.5474 - val_loss: 0.6685 - val_accuracy: 0.5139
#
# Epoch 00008: val_loss did not improve from 0.65533
# Epoch 9/1000
#  - 1s - loss: 0.6869 - accuracy: 0.5511 - val_loss: 0.7064 - val_accuracy: 0.5139
#
# Epoch 00009: val_loss did not improve from 0.65533
# Epoch 10/1000
#  - 1s - loss: 0.6837 - accuracy: 0.5553 - val_loss: 0.6954 - val_accuracy: 0.5346
#
# Epoch 00010: val_loss did not improve from 0.65533
# Epoch 11/1000
#  - 1s - loss: 0.6852 - accuracy: 0.5575 - val_loss: 0.6850 - val_accuracy: 0.5017
#
# Epoch 00011: val_loss did not improve from 0.65533
# Epoch 12/1000
#  - 1s - loss: 0.6813 - accuracy: 0.5645 - val_loss: 0.7119 - val_accuracy: 0.5258
#
# Epoch 00012: val_loss did not improve from 0.65533
# Epoch 13/1000
#  - 1s - loss: 0.6825 - accuracy: 0.5561 - val_loss: 0.7180 - val_accuracy: 0.4883
#
# Epoch 00013: val_loss did not improve from 0.65533
# Epoch 14/1000
#  - 1s - loss: 0.6812 - accuracy: 0.5633 - val_loss: 0.6715 - val_accuracy: 0.5201
#
# Epoch 00014: val_loss did not improve from 0.65533
# Epoch 15/1000
#  - 1s - loss: 0.6839 - accuracy: 0.5605 - val_loss: 0.6838 - val_accuracy: 0.4960
#
# Epoch 00015: val_loss did not improve from 0.65533
# Epoch 16/1000
#  - 1s - loss: 0.6791 - accuracy: 0.5670 - val_loss: 0.6784 - val_accuracy: 0.5182
#
# Epoch 00016: val_loss did not improve from 0.65533
# Epoch 17/1000
#  - 1s - loss: 0.6799 - accuracy: 0.5656 - val_loss: 0.7051 - val_accuracy: 0.5319
#
# Epoch 00017: val_loss did not improve from 0.65533
# Epoch 18/1000
#  - 1s - loss: 0.6778 - accuracy: 0.5715 - val_loss: 0.6690 - val_accuracy: 0.5212
#
# Epoch 00018: val_loss did not improve from 0.65533
# Epoch 19/1000
#  - 1s - loss: 0.6777 - accuracy: 0.5693 - val_loss: 0.7118 - val_accuracy: 0.5201
#
# Epoch 00019: val_loss did not improve from 0.65533
# Epoch 20/1000
#  - 1s - loss: 0.6776 - accuracy: 0.5652 - val_loss: 0.7046 - val_accuracy: 0.5292
#
# Epoch 00020: val_loss did not improve from 0.65533
# Epoch 21/1000
#  - 1s - loss: 0.6781 - accuracy: 0.5736 - val_loss: 0.7143 - val_accuracy: 0.5139
#
# Epoch 00021: val_loss did not improve from 0.65533
# Epoch 22/1000
#  - 1s - loss: 0.6753 - accuracy: 0.5679 - val_loss: 0.7010 - val_accuracy: 0.5250
#
# Epoch 00022: val_loss did not improve from 0.65533
# Epoch 23/1000
#  - 1s - loss: 0.6752 - accuracy: 0.5771 - val_loss: 0.7074 - val_accuracy: 0.5300
#
# Epoch 00023: val_loss did not improve from 0.65533
# Epoch 24/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5823 - val_loss: 0.6932 - val_accuracy: 0.4948
#
# Epoch 00024: val_loss did not improve from 0.65533
# Epoch 25/1000
#  - 1s - loss: 0.6694 - accuracy: 0.5872 - val_loss: 0.7250 - val_accuracy: 0.5075
#
# Epoch 00025: val_loss did not improve from 0.65533
# Epoch 26/1000
#  - 1s - loss: 0.6682 - accuracy: 0.5859 - val_loss: 0.6791 - val_accuracy: 0.5055
#
# Epoch 00026: val_loss did not improve from 0.65533
# Epoch 27/1000
#  - 1s - loss: 0.6681 - accuracy: 0.5919 - val_loss: 0.7462 - val_accuracy: 0.5334
#
# Epoch 00027: val_loss did not improve from 0.65533
# Epoch 28/1000
#  - 1s - loss: 0.6683 - accuracy: 0.5894 - val_loss: 0.6749 - val_accuracy: 0.5231
#
# Epoch 00028: val_loss did not improve from 0.65533
# Epoch 29/1000
#  - 1s - loss: 0.6648 - accuracy: 0.5975 - val_loss: 0.7235 - val_accuracy: 0.4971
#
# Epoch 00029: val_loss did not improve from 0.65533
# Epoch 30/1000
#  - 1s - loss: 0.6629 - accuracy: 0.6002 - val_loss: 0.6860 - val_accuracy: 0.5254
#
# Epoch 00030: val_loss did not improve from 0.65533
# Epoch 31/1000
#  - 1s - loss: 0.6604 - accuracy: 0.6003 - val_loss: 0.7097 - val_accuracy: 0.5059
#
# Epoch 00031: val_loss did not improve from 0.65533
# Epoch 32/1000
#  - 1s - loss: 0.6568 - accuracy: 0.6115 - val_loss: 0.6888 - val_accuracy: 0.5269
#
# Epoch 00032: val_loss did not improve from 0.65533
# Epoch 33/1000
#  - 1s - loss: 0.6599 - accuracy: 0.6046 - val_loss: 0.6728 - val_accuracy: 0.5323
#
# Epoch 00033: val_loss did not improve from 0.65533
# Epoch 34/1000
#  - 1s - loss: 0.6565 - accuracy: 0.6137 - val_loss: 0.7309 - val_accuracy: 0.5113
#
# Epoch 00034: val_loss did not improve from 0.65533
# Epoch 35/1000
#  - 1s - loss: 0.6512 - accuracy: 0.6239 - val_loss: 0.6631 - val_accuracy: 0.5078
#
# Epoch 00035: val_loss did not improve from 0.65533
# Epoch 36/1000
#  - 1s - loss: 0.6507 - accuracy: 0.6144 - val_loss: 0.7156 - val_accuracy: 0.5258
#
# Epoch 00036: val_loss did not improve from 0.65533
# Epoch 37/1000
#  - 1s - loss: 0.6512 - accuracy: 0.6175 - val_loss: 0.6910 - val_accuracy: 0.5315
#
# Epoch 00037: val_loss did not improve from 0.65533
# Epoch 38/1000
#  - 1s - loss: 0.6477 - accuracy: 0.6256 - val_loss: 0.6975 - val_accuracy: 0.5174
#
# Epoch 00038: val_loss did not improve from 0.65533
# Epoch 39/1000
#  - 1s - loss: 0.6433 - accuracy: 0.6293 - val_loss: 0.7121 - val_accuracy: 0.5224
#
# Epoch 00039: val_loss did not improve from 0.65533
# Epoch 40/1000
#  - 1s - loss: 0.6423 - accuracy: 0.6371 - val_loss: 0.7155 - val_accuracy: 0.5246
#
# Epoch 00040: val_loss did not improve from 0.65533
# Epoch 41/1000
#  - 1s - loss: 0.6410 - accuracy: 0.6316 - val_loss: 0.7214 - val_accuracy: 0.5120
#
# Epoch 00041: val_loss did not improve from 0.65533
# Epoch 42/1000
#  - 1s - loss: 0.6375 - accuracy: 0.6334 - val_loss: 0.7226 - val_accuracy: 0.5392
#
# Epoch 00042: val_loss did not improve from 0.65533
# Epoch 43/1000
#  - 1s - loss: 0.6345 - accuracy: 0.6395 - val_loss: 0.7424 - val_accuracy: 0.5082
#
# Epoch 00043: val_loss did not improve from 0.65533
# Epoch 44/1000
#  - 1s - loss: 0.6320 - accuracy: 0.6440 - val_loss: 0.6832 - val_accuracy: 0.5170
#
# Epoch 00044: val_loss did not improve from 0.65533
# Epoch 45/1000
#  - 1s - loss: 0.6278 - accuracy: 0.6441 - val_loss: 0.7333 - val_accuracy: 0.5174
#
# Epoch 00045: val_loss did not improve from 0.65533
# Epoch 46/1000
#  - 1s - loss: 0.6244 - accuracy: 0.6544 - val_loss: 0.7312 - val_accuracy: 0.5151
#
# Epoch 00046: val_loss did not improve from 0.65533
# Epoch 47/1000
#  - 1s - loss: 0.6209 - accuracy: 0.6622 - val_loss: 0.6555 - val_accuracy: 0.5220
#
# Epoch 00047: val_loss did not improve from 0.65533
# Epoch 48/1000
#  - 1s - loss: 0.6170 - accuracy: 0.6618 - val_loss: 0.8014 - val_accuracy: 0.5258
#
# Epoch 00048: val_loss did not improve from 0.65533
# Epoch 49/1000
#  - 1s - loss: 0.6148 - accuracy: 0.6695 - val_loss: 0.6921 - val_accuracy: 0.5327
#
# Epoch 00049: val_loss did not improve from 0.65533
# Epoch 50/1000
#  - 1s - loss: 0.6120 - accuracy: 0.6682 - val_loss: 0.7067 - val_accuracy: 0.5250
#
# Epoch 00050: val_loss did not improve from 0.65533
# Epoch 51/1000
#  - 1s - loss: 0.6129 - accuracy: 0.6683 - val_loss: 0.7415 - val_accuracy: 0.5197
#
# Epoch 00051: val_loss did not improve from 0.65533
# Epoch 52/1000
#  - 1s - loss: 0.6059 - accuracy: 0.6760 - val_loss: 0.6932 - val_accuracy: 0.5239
#
# Epoch 00052: val_loss did not improve from 0.65533
# Epoch 53/1000
#  - 1s - loss: 0.6014 - accuracy: 0.6804 - val_loss: 0.6887 - val_accuracy: 0.5292
#
# Epoch 00053: val_loss did not improve from 0.65533
# Epoch 54/1000
#  - 1s - loss: 0.6000 - accuracy: 0.6839 - val_loss: 0.7901 - val_accuracy: 0.5208
#
# Epoch 00054: val_loss did not improve from 0.65533
# Epoch 55/1000
#  - 1s - loss: 0.5923 - accuracy: 0.6888 - val_loss: 0.7464 - val_accuracy: 0.5243
#
# Epoch 00055: val_loss did not improve from 0.65533
# Epoch 56/1000
#  - 1s - loss: 0.5929 - accuracy: 0.6906 - val_loss: 0.7536 - val_accuracy: 0.5380
#
# Epoch 00056: val_loss did not improve from 0.65533
# Epoch 57/1000
#  - 1s - loss: 0.5881 - accuracy: 0.6923 - val_loss: 0.6821 - val_accuracy: 0.5216
#
# Epoch 00057: val_loss did not improve from 0.65533
# Epoch 58/1000
#  - 1s - loss: 0.5835 - accuracy: 0.7006 - val_loss: 0.8287 - val_accuracy: 0.5277
#
# Epoch 00058: val_loss did not improve from 0.65533
# Epoch 59/1000
#  - 1s - loss: 0.5785 - accuracy: 0.7054 - val_loss: 0.8223 - val_accuracy: 0.5139
#
# Epoch 00059: val_loss did not improve from 0.65533
# Epoch 60/1000
#  - 1s - loss: 0.5762 - accuracy: 0.7007 - val_loss: 0.7300 - val_accuracy: 0.5277
#
# Epoch 00060: val_loss did not improve from 0.65533
# Epoch 61/1000
#  - 1s - loss: 0.5743 - accuracy: 0.7051 - val_loss: 0.6961 - val_accuracy: 0.5334
#
# Epoch 00061: val_loss did not improve from 0.65533
# Epoch 62/1000
#  - 1s - loss: 0.5698 - accuracy: 0.7118 - val_loss: 0.7485 - val_accuracy: 0.5197
#
# Epoch 00062: val_loss did not improve from 0.65533
# Epoch 63/1000
#  - 1s - loss: 0.5652 - accuracy: 0.7139 - val_loss: 0.7026 - val_accuracy: 0.5350
#
# Epoch 00063: val_loss did not improve from 0.65533
# Epoch 64/1000
#  - 1s - loss: 0.5624 - accuracy: 0.7189 - val_loss: 0.7724 - val_accuracy: 0.5250
#
# Epoch 00064: val_loss did not improve from 0.65533
# Epoch 65/1000
#  - 1s - loss: 0.5605 - accuracy: 0.7209 - val_loss: 0.7134 - val_accuracy: 0.5132
#
# Epoch 00065: val_loss did not improve from 0.65533
# Epoch 66/1000
#  - 1s - loss: 0.5555 - accuracy: 0.7189 - val_loss: 0.7904 - val_accuracy: 0.5193
#
# Epoch 00066: val_loss did not improve from 0.65533
# Epoch 67/1000
#  - 1s - loss: 0.5498 - accuracy: 0.7245 - val_loss: 0.7712 - val_accuracy: 0.5346
#
# Epoch 00067: val_loss did not improve from 0.65533
# Epoch 68/1000
#  - 1s - loss: 0.5467 - accuracy: 0.7304 - val_loss: 0.7582 - val_accuracy: 0.5269
#
# Epoch 00068: val_loss did not improve from 0.65533
# Epoch 69/1000
#  - 1s - loss: 0.5405 - accuracy: 0.7425 - val_loss: 0.6433 - val_accuracy: 0.5266
#
# Epoch 00069: val_loss improved from 0.65533 to 0.64327, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_close_updown_pr_neo_close_tsplit.h5
# Epoch 70/1000
#  - 1s - loss: 0.5339 - accuracy: 0.7434 - val_loss: 0.6734 - val_accuracy: 0.5285
#
# Epoch 00070: val_loss did not improve from 0.64327
# Epoch 71/1000
#  - 1s - loss: 0.5372 - accuracy: 0.7375 - val_loss: 0.7610 - val_accuracy: 0.5243
#
# Epoch 00071: val_loss did not improve from 0.64327
# Epoch 72/1000
#  - 1s - loss: 0.5294 - accuracy: 0.7408 - val_loss: 0.7694 - val_accuracy: 0.5311
#
# Epoch 00072: val_loss did not improve from 0.64327
# Epoch 73/1000
#  - 1s - loss: 0.5295 - accuracy: 0.7397 - val_loss: 0.7554 - val_accuracy: 0.5147
#
# Epoch 00073: val_loss did not improve from 0.64327
# Epoch 74/1000
#  - 1s - loss: 0.5202 - accuracy: 0.7528 - val_loss: 0.7102 - val_accuracy: 0.5254
#
# Epoch 00074: val_loss did not improve from 0.64327
# Epoch 75/1000
#  - 1s - loss: 0.5137 - accuracy: 0.7573 - val_loss: 0.8063 - val_accuracy: 0.5262
#
# Epoch 00075: val_loss did not improve from 0.64327
# Epoch 76/1000
#  - 1s - loss: 0.5104 - accuracy: 0.7598 - val_loss: 0.7853 - val_accuracy: 0.5296
#
# Epoch 00076: val_loss did not improve from 0.64327
# Epoch 77/1000
#  - 1s - loss: 0.5054 - accuracy: 0.7607 - val_loss: 0.7082 - val_accuracy: 0.5143
#
# Epoch 00077: val_loss did not improve from 0.64327
# Epoch 78/1000
#  - 1s - loss: 0.5105 - accuracy: 0.7500 - val_loss: 0.8189 - val_accuracy: 0.5212
#
# Epoch 00078: val_loss did not improve from 0.64327
# Epoch 79/1000
#  - 1s - loss: 0.4972 - accuracy: 0.7658 - val_loss: 0.8273 - val_accuracy: 0.5338
#
# Epoch 00079: val_loss did not improve from 0.64327
# Epoch 80/1000
#  - 1s - loss: 0.4938 - accuracy: 0.7733 - val_loss: 0.8422 - val_accuracy: 0.5067
#
# Epoch 00080: val_loss did not improve from 0.64327
# Epoch 81/1000
#  - 1s - loss: 0.4997 - accuracy: 0.7598 - val_loss: 0.6768 - val_accuracy: 0.5258
#
# Epoch 00081: val_loss did not improve from 0.64327
# Epoch 82/1000
#  - 1s - loss: 0.4831 - accuracy: 0.7821 - val_loss: 0.8342 - val_accuracy: 0.5304
#
# Epoch 00082: val_loss did not improve from 0.64327
# Epoch 83/1000
#  - 1s - loss: 0.4808 - accuracy: 0.7789 - val_loss: 0.8044 - val_accuracy: 0.5288
#
# Epoch 00083: val_loss did not improve from 0.64327
# Epoch 84/1000
#  - 1s - loss: 0.4758 - accuracy: 0.7845 - val_loss: 0.8561 - val_accuracy: 0.5365
#
# Epoch 00084: val_loss did not improve from 0.64327
# Epoch 85/1000
#  - 1s - loss: 0.4796 - accuracy: 0.7770 - val_loss: 0.8911 - val_accuracy: 0.5216
#
# Epoch 00085: val_loss did not improve from 0.64327
# Epoch 86/1000
#  - 1s - loss: 0.4675 - accuracy: 0.7882 - val_loss: 0.7148 - val_accuracy: 0.5353
#
# Epoch 00086: val_loss did not improve from 0.64327
# Epoch 87/1000
#  - 1s - loss: 0.4671 - accuracy: 0.7845 - val_loss: 0.8029 - val_accuracy: 0.5235
#
# Epoch 00087: val_loss did not improve from 0.64327
# Epoch 88/1000
#  - 1s - loss: 0.4559 - accuracy: 0.7966 - val_loss: 0.9004 - val_accuracy: 0.5258
#
# Epoch 00088: val_loss did not improve from 0.64327
# Epoch 89/1000
#  - 1s - loss: 0.4521 - accuracy: 0.8012 - val_loss: 0.8045 - val_accuracy: 0.5292
#
# Epoch 00089: val_loss did not improve from 0.64327
# Epoch 90/1000
#  - 1s - loss: 0.4521 - accuracy: 0.7941 - val_loss: 0.8708 - val_accuracy: 0.5243
#
# Epoch 00090: val_loss did not improve from 0.64327
# Epoch 91/1000
#  - 1s - loss: 0.4488 - accuracy: 0.7991 - val_loss: 1.1045 - val_accuracy: 0.5308
#
# Epoch 00091: val_loss did not improve from 0.64327
# Epoch 92/1000
#  - 1s - loss: 0.4448 - accuracy: 0.8021 - val_loss: 0.9391 - val_accuracy: 0.5231
#
# Epoch 00092: val_loss did not improve from 0.64327
# Epoch 93/1000
#  - 1s - loss: 0.4364 - accuracy: 0.8103 - val_loss: 0.8966 - val_accuracy: 0.5292
#
# Epoch 00093: val_loss did not improve from 0.64327
# Epoch 94/1000
#  - 1s - loss: 0.4313 - accuracy: 0.8133 - val_loss: 1.0398 - val_accuracy: 0.5281
#
# Epoch 00094: val_loss did not improve from 0.64327
# Epoch 95/1000
#  - 1s - loss: 0.4265 - accuracy: 0.8157 - val_loss: 0.6572 - val_accuracy: 0.5331
#
# Epoch 00095: val_loss did not improve from 0.64327
# Epoch 96/1000
#  - 1s - loss: 0.4264 - accuracy: 0.8103 - val_loss: 1.0118 - val_accuracy: 0.5224
#
# Epoch 00096: val_loss did not improve from 0.64327
# Epoch 97/1000
#  - 1s - loss: 0.4172 - accuracy: 0.8211 - val_loss: 0.8102 - val_accuracy: 0.5319
#
# Epoch 00097: val_loss did not improve from 0.64327
# Epoch 98/1000
#  - 1s - loss: 0.4147 - accuracy: 0.8189 - val_loss: 0.7297 - val_accuracy: 0.5327
#
# Epoch 00098: val_loss did not improve from 0.64327
# Epoch 99/1000
#  - 1s - loss: 0.4051 - accuracy: 0.8299 - val_loss: 0.8965 - val_accuracy: 0.5220
#
# Epoch 00099: val_loss did not improve from 0.64327
# Epoch 100/1000
#  - 1s - loss: 0.4064 - accuracy: 0.8258 - val_loss: 0.8237 - val_accuracy: 0.5311
#
# Epoch 00100: val_loss did not improve from 0.64327
# Epoch 101/1000
#  - 1s - loss: 0.3948 - accuracy: 0.8347 - val_loss: 0.9041 - val_accuracy: 0.5113
#
# Epoch 00101: val_loss did not improve from 0.64327
# Epoch 102/1000
#  - 1s - loss: 0.3980 - accuracy: 0.8287 - val_loss: 0.9653 - val_accuracy: 0.5204
#
# Epoch 00102: val_loss did not improve from 0.64327
# Epoch 103/1000
#  - 1s - loss: 0.3905 - accuracy: 0.8377 - val_loss: 0.8302 - val_accuracy: 0.5170
#
# Epoch 00103: val_loss did not improve from 0.64327
# Epoch 104/1000
#  - 1s - loss: 0.3907 - accuracy: 0.8319 - val_loss: 1.0265 - val_accuracy: 0.5311
#
# Epoch 00104: val_loss did not improve from 0.64327
# Epoch 105/1000
#  - 1s - loss: 0.3905 - accuracy: 0.8301 - val_loss: 0.6839 - val_accuracy: 0.5346
#
# Epoch 00105: val_loss did not improve from 0.64327
# Epoch 106/1000
#  - 1s - loss: 0.3775 - accuracy: 0.8438 - val_loss: 0.9018 - val_accuracy: 0.5204
#
# Epoch 00106: val_loss did not improve from 0.64327
# Epoch 107/1000
#  - 1s - loss: 0.3758 - accuracy: 0.8428 - val_loss: 0.8838 - val_accuracy: 0.5277
#
# Epoch 00107: val_loss did not improve from 0.64327
# Epoch 108/1000
#  - 1s - loss: 0.3679 - accuracy: 0.8466 - val_loss: 0.8337 - val_accuracy: 0.5189
#
# Epoch 00108: val_loss did not improve from 0.64327
# Epoch 109/1000
#  - 1s - loss: 0.3633 - accuracy: 0.8493 - val_loss: 0.9759 - val_accuracy: 0.5346
#
# Epoch 00109: val_loss did not improve from 0.64327
# Epoch 110/1000
#  - 1s - loss: 0.3696 - accuracy: 0.8429 - val_loss: 0.7889 - val_accuracy: 0.5331
#
# Epoch 00110: val_loss did not improve from 0.64327
# Epoch 111/1000
#  - 1s - loss: 0.3550 - accuracy: 0.8549 - val_loss: 1.0759 - val_accuracy: 0.5204
#
# Epoch 00111: val_loss did not improve from 0.64327
# Epoch 112/1000
#  - 1s - loss: 0.3564 - accuracy: 0.8551 - val_loss: 0.9187 - val_accuracy: 0.5292
#
# Epoch 00112: val_loss did not improve from 0.64327
# Epoch 113/1000
#  - 1s - loss: 0.3489 - accuracy: 0.8574 - val_loss: 0.9714 - val_accuracy: 0.5258
#
# Epoch 00113: val_loss did not improve from 0.64327
# Epoch 114/1000
#  - 1s - loss: 0.3417 - accuracy: 0.8661 - val_loss: 1.0029 - val_accuracy: 0.5277
#
# Epoch 00114: val_loss did not improve from 0.64327
# Epoch 115/1000
#  - 1s - loss: 0.3347 - accuracy: 0.8686 - val_loss: 0.8700 - val_accuracy: 0.5300
#
# Epoch 00115: val_loss did not improve from 0.64327
# Epoch 116/1000
#  - 1s - loss: 0.3347 - accuracy: 0.8707 - val_loss: 1.1816 - val_accuracy: 0.5311
#
# Epoch 00116: val_loss did not improve from 0.64327
# Epoch 117/1000
#  - 1s - loss: 0.3310 - accuracy: 0.8676 - val_loss: 1.3712 - val_accuracy: 0.5254
#
# Epoch 00117: val_loss did not improve from 0.64327
# Epoch 118/1000
#  - 1s - loss: 0.3249 - accuracy: 0.8730 - val_loss: 1.2053 - val_accuracy: 0.5220
#
# Epoch 00118: val_loss did not improve from 0.64327
# Epoch 119/1000
#  - 1s - loss: 0.3187 - accuracy: 0.8784 - val_loss: 1.1444 - val_accuracy: 0.5308
#
# Epoch 00119: val_loss did not improve from 0.64327
# Epoch 120/1000
#  - 1s - loss: 0.3181 - accuracy: 0.8790 - val_loss: 1.0681 - val_accuracy: 0.5197
#
# Epoch 00120: val_loss did not improve from 0.64327
# Epoch 121/1000
#  - 1s - loss: 0.3143 - accuracy: 0.8777 - val_loss: 0.8590 - val_accuracy: 0.5109
#
# Epoch 00121: val_loss did not improve from 0.64327
# Epoch 122/1000
#  - 1s - loss: 0.3106 - accuracy: 0.8761 - val_loss: 0.9705 - val_accuracy: 0.5296
#
# Epoch 00122: val_loss did not improve from 0.64327
# Epoch 123/1000
#  - 1s - loss: 0.3090 - accuracy: 0.8781 - val_loss: 1.1235 - val_accuracy: 0.5346
#
# Epoch 00123: val_loss did not improve from 0.64327
# Epoch 124/1000
#  - 1s - loss: 0.3015 - accuracy: 0.8860 - val_loss: 0.9369 - val_accuracy: 0.5285
#
# Epoch 00124: val_loss did not improve from 0.64327
# Epoch 125/1000
#  - 1s - loss: 0.2952 - accuracy: 0.8844 - val_loss: 1.1760 - val_accuracy: 0.5136
#
# Epoch 00125: val_loss did not improve from 0.64327
# Epoch 126/1000
#  - 1s - loss: 0.2912 - accuracy: 0.8918 - val_loss: 0.9404 - val_accuracy: 0.5204
#
# Epoch 00126: val_loss did not improve from 0.64327
# Epoch 127/1000
#  - 1s - loss: 0.2852 - accuracy: 0.8950 - val_loss: 0.8916 - val_accuracy: 0.5059
#
# Epoch 00127: val_loss did not improve from 0.64327
# Epoch 128/1000
#  - 1s - loss: 0.2881 - accuracy: 0.8883 - val_loss: 1.1645 - val_accuracy: 0.5227
#
# Epoch 00128: val_loss did not improve from 0.64327
# Epoch 129/1000
#  - 1s - loss: 0.2750 - accuracy: 0.9028 - val_loss: 1.3052 - val_accuracy: 0.5288
#
# Epoch 00129: val_loss did not improve from 0.64327
# Epoch 130/1000
#  - 1s - loss: 0.2724 - accuracy: 0.9035 - val_loss: 0.9996 - val_accuracy: 0.5239
#
# Epoch 00130: val_loss did not improve from 0.64327
# Epoch 131/1000
#  - 1s - loss: 0.2692 - accuracy: 0.9025 - val_loss: 1.4200 - val_accuracy: 0.5250
#
# Epoch 00131: val_loss did not improve from 0.64327
# Epoch 132/1000
#  - 1s - loss: 0.2711 - accuracy: 0.9005 - val_loss: 1.0483 - val_accuracy: 0.5220
#
# Epoch 00132: val_loss did not improve from 0.64327
# Epoch 133/1000
#  - 1s - loss: 0.2749 - accuracy: 0.8928 - val_loss: 1.2858 - val_accuracy: 0.5097
#
# Epoch 00133: val_loss did not improve from 0.64327
# Epoch 134/1000
#  - 1s - loss: 0.2635 - accuracy: 0.9032 - val_loss: 0.9848 - val_accuracy: 0.5105
#
# Epoch 00134: val_loss did not improve from 0.64327
# Epoch 135/1000
#  - 1s - loss: 0.2531 - accuracy: 0.9127 - val_loss: 1.6259 - val_accuracy: 0.5304
#
# Epoch 00135: val_loss did not improve from 0.64327
# Epoch 136/1000
#  - 1s - loss: 0.2470 - accuracy: 0.9134 - val_loss: 1.3705 - val_accuracy: 0.5235
#
# Epoch 00136: val_loss did not improve from 0.64327
# Epoch 137/1000
#  - 1s - loss: 0.2429 - accuracy: 0.9163 - val_loss: 1.2285 - val_accuracy: 0.5262
#
# Epoch 00137: val_loss did not improve from 0.64327
# Epoch 138/1000
#  - 1s - loss: 0.2454 - accuracy: 0.9140 - val_loss: 1.0971 - val_accuracy: 0.5239
#
# Epoch 00138: val_loss did not improve from 0.64327
# Epoch 139/1000
#  - 1s - loss: 0.2362 - accuracy: 0.9213 - val_loss: 1.2751 - val_accuracy: 0.5334
#
# Epoch 00139: val_loss did not improve from 0.64327
# Epoch 140/1000
#  - 1s - loss: 0.2392 - accuracy: 0.9173 - val_loss: 1.2357 - val_accuracy: 0.5277
#
# Epoch 00140: val_loss did not improve from 0.64327
# Epoch 141/1000
#  - 1s - loss: 0.2359 - accuracy: 0.9179 - val_loss: 1.2458 - val_accuracy: 0.5193
#
# Epoch 00141: val_loss did not improve from 0.64327
# Epoch 142/1000
#  - 1s - loss: 0.2247 - accuracy: 0.9279 - val_loss: 1.3112 - val_accuracy: 0.5269
#
# Epoch 00142: val_loss did not improve from 0.64327
# Epoch 143/1000
#  - 1s - loss: 0.2216 - accuracy: 0.9284 - val_loss: 1.3857 - val_accuracy: 0.5166
#
# Epoch 00143: val_loss did not improve from 0.64327
# Epoch 144/1000
#  - 1s - loss: 0.2207 - accuracy: 0.9300 - val_loss: 1.6944 - val_accuracy: 0.5170
#
# Epoch 00144: val_loss did not improve from 0.64327
# Epoch 145/1000
#  - 1s - loss: 0.2120 - accuracy: 0.9311 - val_loss: 1.3688 - val_accuracy: 0.5182
#
# Epoch 00145: val_loss did not improve from 0.64327
# Epoch 146/1000
#  - 1s - loss: 0.2158 - accuracy: 0.9269 - val_loss: 1.3464 - val_accuracy: 0.5159
#
# Epoch 00146: val_loss did not improve from 0.64327
# Epoch 147/1000
#  - 1s - loss: 0.2104 - accuracy: 0.9330 - val_loss: 1.5200 - val_accuracy: 0.5292
#
# Epoch 00147: val_loss did not improve from 0.64327
# Epoch 148/1000
#  - 1s - loss: 0.2028 - accuracy: 0.9393 - val_loss: 1.0245 - val_accuracy: 0.5220
#
# Epoch 00148: val_loss did not improve from 0.64327
# Epoch 149/1000
#  - 1s - loss: 0.2028 - accuracy: 0.9344 - val_loss: 1.1369 - val_accuracy: 0.5220
#
# Epoch 00149: val_loss did not improve from 0.64327
# Epoch 150/1000
#  - 1s - loss: 0.1982 - accuracy: 0.9382 - val_loss: 1.2884 - val_accuracy: 0.5101
#
# Epoch 00150: val_loss did not improve from 0.64327
# Epoch 151/1000
#  - 1s - loss: 0.1940 - accuracy: 0.9419 - val_loss: 1.3896 - val_accuracy: 0.5254
#
# Epoch 00151: val_loss did not improve from 0.64327
# Epoch 152/1000
#  - 1s - loss: 0.1916 - accuracy: 0.9399 - val_loss: 1.4452 - val_accuracy: 0.5139
#
# Epoch 00152: val_loss did not improve from 0.64327
# Epoch 153/1000
#  - 1s - loss: 0.1902 - accuracy: 0.9406 - val_loss: 1.1693 - val_accuracy: 0.5212
#
# Epoch 00153: val_loss did not improve from 0.64327
# Epoch 154/1000
#  - 1s - loss: 0.1901 - accuracy: 0.9402 - val_loss: 1.0663 - val_accuracy: 0.5266
#
# Epoch 00154: val_loss did not improve from 0.64327
# Epoch 155/1000
#  - 1s - loss: 0.1777 - accuracy: 0.9483 - val_loss: 1.0894 - val_accuracy: 0.5185
#
# Epoch 00155: val_loss did not improve from 0.64327
# Epoch 156/1000
#  - 1s - loss: 0.1724 - accuracy: 0.9534 - val_loss: 1.4681 - val_accuracy: 0.5117
#
# Epoch 00156: val_loss did not improve from 0.64327
# Epoch 157/1000
#  - 1s - loss: 0.1813 - accuracy: 0.9460 - val_loss: 1.4698 - val_accuracy: 0.5101
#
# Epoch 00157: val_loss did not improve from 0.64327
# Epoch 158/1000
#  - 1s - loss: 0.1690 - accuracy: 0.9522 - val_loss: 0.9304 - val_accuracy: 0.5136
#
# Epoch 00158: val_loss did not improve from 0.64327
# Epoch 159/1000
#  - 1s - loss: 0.1627 - accuracy: 0.9558 - val_loss: 1.6053 - val_accuracy: 0.5288
#
# Epoch 00159: val_loss did not improve from 0.64327
# Epoch 160/1000
#  - 1s - loss: 0.1652 - accuracy: 0.9525 - val_loss: 1.4803 - val_accuracy: 0.5189
#
# Epoch 00160: val_loss did not improve from 0.64327
# Epoch 161/1000
#  - 1s - loss: 0.1573 - accuracy: 0.9585 - val_loss: 1.4675 - val_accuracy: 0.5193
#
# Epoch 00161: val_loss did not improve from 0.64327
# Epoch 162/1000
#  - 1s - loss: 0.1571 - accuracy: 0.9581 - val_loss: 1.5412 - val_accuracy: 0.5147
#
# Epoch 00162: val_loss did not improve from 0.64327
# Epoch 163/1000
#  - 1s - loss: 0.1553 - accuracy: 0.9609 - val_loss: 1.8582 - val_accuracy: 0.5147
#
# Epoch 00163: val_loss did not improve from 0.64327
# Epoch 164/1000
#  - 1s - loss: 0.1528 - accuracy: 0.9588 - val_loss: 1.6078 - val_accuracy: 0.5269
#
# Epoch 00164: val_loss did not improve from 0.64327
# Epoch 165/1000
#  - 1s - loss: 0.1568 - accuracy: 0.9573 - val_loss: 1.1369 - val_accuracy: 0.5220
#
# Epoch 00165: val_loss did not improve from 0.64327
# Epoch 166/1000
#  - 1s - loss: 0.1422 - accuracy: 0.9653 - val_loss: 1.8451 - val_accuracy: 0.5189
#
# Epoch 00166: val_loss did not improve from 0.64327
# Epoch 167/1000
#  - 1s - loss: 0.1479 - accuracy: 0.9611 - val_loss: 1.2362 - val_accuracy: 0.5315
#
# Epoch 00167: val_loss did not improve from 0.64327
# Epoch 168/1000
#  - 1s - loss: 0.1420 - accuracy: 0.9650 - val_loss: 1.1765 - val_accuracy: 0.5120
#
# Epoch 00168: val_loss did not improve from 0.64327
# Epoch 169/1000
#  - 1s - loss: 0.1401 - accuracy: 0.9651 - val_loss: 1.2041 - val_accuracy: 0.5147
#
# Epoch 00169: val_loss did not improve from 0.64327
# Epoch 170/1000
#  - 1s - loss: 0.1356 - accuracy: 0.9653 - val_loss: 1.7310 - val_accuracy: 0.5227
#
# Epoch 00170: val_loss did not improve from 0.64327
# Epoch 171/1000
#  - 1s - loss: 0.1300 - accuracy: 0.9709 - val_loss: 1.3620 - val_accuracy: 0.5243
#
# Epoch 00171: val_loss did not improve from 0.64327
# Epoch 172/1000
#  - 1s - loss: 0.1275 - accuracy: 0.9695 - val_loss: 1.7401 - val_accuracy: 0.5166
#
# Epoch 00172: val_loss did not improve from 0.64327
# Epoch 173/1000
#  - 1s - loss: 0.1235 - accuracy: 0.9755 - val_loss: 1.7483 - val_accuracy: 0.5117
#
# Epoch 00173: val_loss did not improve from 0.64327
# Epoch 174/1000
#  - 1s - loss: 0.1247 - accuracy: 0.9731 - val_loss: 1.9471 - val_accuracy: 0.5254
#
# Epoch 00174: val_loss did not improve from 0.64327
# Epoch 175/1000
#  - 1s - loss: 0.1189 - accuracy: 0.9746 - val_loss: 1.7395 - val_accuracy: 0.5254
#
# Epoch 00175: val_loss did not improve from 0.64327
# Epoch 176/1000
#  - 1s - loss: 0.1175 - accuracy: 0.9718 - val_loss: 1.7059 - val_accuracy: 0.5162
#
# Epoch 00176: val_loss did not improve from 0.64327
# Epoch 177/1000
#  - 1s - loss: 0.1110 - accuracy: 0.9802 - val_loss: 1.8155 - val_accuracy: 0.5254
#
# Epoch 00177: val_loss did not improve from 0.64327
# Epoch 178/1000
#  - 1s - loss: 0.1088 - accuracy: 0.9811 - val_loss: 1.8179 - val_accuracy: 0.5216
#
# Epoch 00178: val_loss did not improve from 0.64327
# Epoch 179/1000
#  - 1s - loss: 0.1094 - accuracy: 0.9771 - val_loss: 1.2549 - val_accuracy: 0.5227
#
# Epoch 00179: val_loss did not improve from 0.64327
# Epoch 180/1000
#  - 1s - loss: 0.1068 - accuracy: 0.9774 - val_loss: 1.8702 - val_accuracy: 0.5155
#
# Epoch 00180: val_loss did not improve from 0.64327
# Epoch 181/1000
#  - 1s - loss: 0.1106 - accuracy: 0.9734 - val_loss: 1.7069 - val_accuracy: 0.5139
#
# Epoch 00181: val_loss did not improve from 0.64327
# Epoch 182/1000
#  - 1s - loss: 0.1016 - accuracy: 0.9809 - val_loss: 2.0494 - val_accuracy: 0.5067
#
# Epoch 00182: val_loss did not improve from 0.64327
# Epoch 183/1000
#  - 1s - loss: 0.0987 - accuracy: 0.9824 - val_loss: 2.3317 - val_accuracy: 0.5246
#
# Epoch 00183: val_loss did not improve from 0.64327
# Epoch 184/1000
#  - 1s - loss: 0.0984 - accuracy: 0.9811 - val_loss: 1.7822 - val_accuracy: 0.5201
#
# Epoch 00184: val_loss did not improve from 0.64327
# Epoch 185/1000
#  - 1s - loss: 0.0945 - accuracy: 0.9834 - val_loss: 1.6406 - val_accuracy: 0.5159
#
# Epoch 00185: val_loss did not improve from 0.64327
# Epoch 186/1000
#  - 1s - loss: 0.0933 - accuracy: 0.9839 - val_loss: 1.5230 - val_accuracy: 0.5201
#
# Epoch 00186: val_loss did not improve from 0.64327
# Epoch 187/1000
#  - 1s - loss: 0.0933 - accuracy: 0.9832 - val_loss: 1.2446 - val_accuracy: 0.5162
#
# Epoch 00187: val_loss did not improve from 0.64327
# Epoch 188/1000
#  - 1s - loss: 0.0967 - accuracy: 0.9797 - val_loss: 2.0690 - val_accuracy: 0.5155
#
# Epoch 00188: val_loss did not improve from 0.64327
# Epoch 189/1000
#  - 1s - loss: 0.0855 - accuracy: 0.9875 - val_loss: 2.2816 - val_accuracy: 0.5185
#
# Epoch 00189: val_loss did not improve from 0.64327
# Epoch 190/1000
#  - 1s - loss: 0.0837 - accuracy: 0.9873 - val_loss: 1.8564 - val_accuracy: 0.5178
#
# Epoch 00190: val_loss did not improve from 0.64327
# Epoch 191/1000
#  - 1s - loss: 0.0871 - accuracy: 0.9843 - val_loss: 1.9689 - val_accuracy: 0.5162
#
# Epoch 00191: val_loss did not improve from 0.64327
# Epoch 192/1000
#  - 1s - loss: 0.0815 - accuracy: 0.9859 - val_loss: 1.6127 - val_accuracy: 0.5235
#
# Epoch 00192: val_loss did not improve from 0.64327
# Epoch 193/1000
#  - 1s - loss: 0.0808 - accuracy: 0.9870 - val_loss: 1.2901 - val_accuracy: 0.5136
#
# Epoch 00193: val_loss did not improve from 0.64327
# Epoch 194/1000
#  - 1s - loss: 0.0724 - accuracy: 0.9906 - val_loss: 1.4971 - val_accuracy: 0.5082
#
# Epoch 00194: val_loss did not improve from 0.64327
# Epoch 195/1000
#  - 1s - loss: 0.0737 - accuracy: 0.9888 - val_loss: 1.9580 - val_accuracy: 0.5216
#
# Epoch 00195: val_loss did not improve from 0.64327
# Epoch 196/1000
#  - 1s - loss: 0.0679 - accuracy: 0.9924 - val_loss: 2.2620 - val_accuracy: 0.5166
#
# Epoch 00196: val_loss did not improve from 0.64327
# Epoch 197/1000
#  - 1s - loss: 0.0700 - accuracy: 0.9898 - val_loss: 2.1889 - val_accuracy: 0.5174
#
# Epoch 00197: val_loss did not improve from 0.64327
# Epoch 198/1000
#  - 1s - loss: 0.0663 - accuracy: 0.9925 - val_loss: 2.3327 - val_accuracy: 0.5155
#
# Epoch 00198: val_loss did not improve from 0.64327
# Epoch 199/1000
#  - 1s - loss: 0.0685 - accuracy: 0.9903 - val_loss: 1.8201 - val_accuracy: 0.5262
#
# Epoch 00199: val_loss did not improve from 0.64327
# Epoch 200/1000
#  - 1s - loss: 0.0735 - accuracy: 0.9879 - val_loss: 2.0865 - val_accuracy: 0.5170
#
# Epoch 00200: val_loss did not improve from 0.64327
# Epoch 201/1000
#  - 1s - loss: 0.0635 - accuracy: 0.9916 - val_loss: 2.3676 - val_accuracy: 0.5166
#
# Epoch 00201: val_loss did not improve from 0.64327
# Epoch 202/1000
#  - 1s - loss: 0.0607 - accuracy: 0.9932 - val_loss: 1.3341 - val_accuracy: 0.5159
#
# Epoch 00202: val_loss did not improve from 0.64327
# Epoch 203/1000
#  - 1s - loss: 0.0573 - accuracy: 0.9954 - val_loss: 1.9713 - val_accuracy: 0.5174
#
# Epoch 00203: val_loss did not improve from 0.64327
# Epoch 204/1000
#  - 1s - loss: 0.0569 - accuracy: 0.9930 - val_loss: 2.0128 - val_accuracy: 0.5201
#
# Epoch 00204: val_loss did not improve from 0.64327
# Epoch 205/1000
#  - 1s - loss: 0.0552 - accuracy: 0.9950 - val_loss: 1.3986 - val_accuracy: 0.5208
#
# Epoch 00205: val_loss did not improve from 0.64327
# Epoch 206/1000
#  - 1s - loss: 0.0506 - accuracy: 0.9966 - val_loss: 1.8258 - val_accuracy: 0.5204
#
# Epoch 00206: val_loss did not improve from 0.64327
# Epoch 207/1000
#  - 1s - loss: 0.0520 - accuracy: 0.9957 - val_loss: 2.7538 - val_accuracy: 0.5185
#
# Epoch 00207: val_loss did not improve from 0.64327
# Epoch 208/1000
#  - 1s - loss: 0.0492 - accuracy: 0.9964 - val_loss: 1.7960 - val_accuracy: 0.5105
#
# Epoch 00208: val_loss did not improve from 0.64327
# Epoch 209/1000
#  - 1s - loss: 0.0488 - accuracy: 0.9966 - val_loss: 1.7479 - val_accuracy: 0.5197
#
# Epoch 00209: val_loss did not improve from 0.64327
# Epoch 210/1000
#  - 1s - loss: 0.0500 - accuracy: 0.9958 - val_loss: 1.8965 - val_accuracy: 0.5113
#
# Epoch 00210: val_loss did not improve from 0.64327
# Epoch 211/1000
#  - 1s - loss: 0.0483 - accuracy: 0.9962 - val_loss: 2.1888 - val_accuracy: 0.5239
#
# Epoch 00211: val_loss did not improve from 0.64327
# Epoch 212/1000
#  - 1s - loss: 0.0447 - accuracy: 0.9966 - val_loss: 1.9218 - val_accuracy: 0.5151
#
# Epoch 00212: val_loss did not improve from 0.64327
# Epoch 213/1000
#  - 1s - loss: 0.0436 - accuracy: 0.9971 - val_loss: 2.4086 - val_accuracy: 0.5224
#
# Epoch 00213: val_loss did not improve from 0.64327
# Epoch 214/1000
#  - 1s - loss: 0.0435 - accuracy: 0.9975 - val_loss: 2.0286 - val_accuracy: 0.5136
#
# Epoch 00214: val_loss did not improve from 0.64327
# Epoch 215/1000
#  - 1s - loss: 0.0441 - accuracy: 0.9967 - val_loss: 1.9642 - val_accuracy: 0.5162
#
# Epoch 00215: val_loss did not improve from 0.64327
# Epoch 216/1000
#  - 1s - loss: 0.0391 - accuracy: 0.9981 - val_loss: 1.4153 - val_accuracy: 0.5258
#
# Epoch 00216: val_loss did not improve from 0.64327
# Epoch 217/1000
#  - 1s - loss: 0.0372 - accuracy: 0.9985 - val_loss: 2.6826 - val_accuracy: 0.5246
#
# Epoch 00217: val_loss did not improve from 0.64327
# Epoch 218/1000
#  - 1s - loss: 0.0368 - accuracy: 0.9980 - val_loss: 2.7870 - val_accuracy: 0.5139
#
# Epoch 00218: val_loss did not improve from 0.64327
# Epoch 219/1000
#  - 1s - loss: 0.0346 - accuracy: 0.9987 - val_loss: 2.8307 - val_accuracy: 0.5136
#
# Epoch 00219: val_loss did not improve from 0.64327
# Epoch 220/1000
#  - 1s - loss: 0.0346 - accuracy: 0.9985 - val_loss: 2.0904 - val_accuracy: 0.5178
#
# Epoch 00220: val_loss did not improve from 0.64327
# Epoch 221/1000
#  - 1s - loss: 0.0374 - accuracy: 0.9973 - val_loss: 1.9623 - val_accuracy: 0.5224
#
# Epoch 00221: val_loss did not improve from 0.64327
# Epoch 222/1000
#  - 1s - loss: 0.0334 - accuracy: 0.9985 - val_loss: 1.9636 - val_accuracy: 0.5113
#
# Epoch 00222: val_loss did not improve from 0.64327
# Epoch 223/1000
#  - 1s - loss: 0.0327 - accuracy: 0.9989 - val_loss: 2.7042 - val_accuracy: 0.5185
#
# Epoch 00223: val_loss did not improve from 0.64327
# Epoch 224/1000
#  - 1s - loss: 0.0380 - accuracy: 0.9971 - val_loss: 2.5692 - val_accuracy: 0.5178
#
# Epoch 00224: val_loss did not improve from 0.64327
# Epoch 225/1000
#  - 1s - loss: 0.0407 - accuracy: 0.9950 - val_loss: 3.1119 - val_accuracy: 0.5231
#
# Epoch 00225: val_loss did not improve from 0.64327
# Epoch 226/1000
#  - 1s - loss: 0.0365 - accuracy: 0.9967 - val_loss: 2.8856 - val_accuracy: 0.5159
#
# Epoch 00226: val_loss did not improve from 0.64327
# Epoch 227/1000
#  - 1s - loss: 0.0305 - accuracy: 0.9986 - val_loss: 2.5700 - val_accuracy: 0.5174
#
# Epoch 00227: val_loss did not improve from 0.64327
# Epoch 228/1000
#  - 1s - loss: 0.0271 - accuracy: 0.9989 - val_loss: 2.2348 - val_accuracy: 0.5143
#
# Epoch 00228: val_loss did not improve from 0.64327
# Epoch 229/1000
#  - 1s - loss: 0.0252 - accuracy: 0.9995 - val_loss: 2.6371 - val_accuracy: 0.5166
#
# Epoch 00229: val_loss did not improve from 0.64327
# Epoch 230/1000
#  - 1s - loss: 0.0265 - accuracy: 0.9996 - val_loss: 3.5172 - val_accuracy: 0.5227
#
# Epoch 00230: val_loss did not improve from 0.64327
# Epoch 231/1000
#  - 1s - loss: 0.0283 - accuracy: 0.9982 - val_loss: 3.3304 - val_accuracy: 0.5147
#
# Epoch 00231: val_loss did not improve from 0.64327
# Epoch 232/1000
#  - 1s - loss: 0.0249 - accuracy: 0.9997 - val_loss: 2.4202 - val_accuracy: 0.5208
#
# Epoch 00232: val_loss did not improve from 0.64327
# Epoch 233/1000
#  - 1s - loss: 0.0220 - accuracy: 0.9997 - val_loss: 2.0221 - val_accuracy: 0.5197
#
# Epoch 00233: val_loss did not improve from 0.64327
# Epoch 234/1000
#  - 1s - loss: 0.0248 - accuracy: 0.9991 - val_loss: 2.1939 - val_accuracy: 0.5193
#
# Epoch 00234: val_loss did not improve from 0.64327
# Epoch 235/1000
#  - 1s - loss: 0.0214 - accuracy: 0.9997 - val_loss: 2.1792 - val_accuracy: 0.5208
#
# Epoch 00235: val_loss did not improve from 0.64327
# Epoch 236/1000
#  - 1s - loss: 0.0251 - accuracy: 0.9990 - val_loss: 3.2165 - val_accuracy: 0.5159
#
# Epoch 00236: val_loss did not improve from 0.64327
# Epoch 237/1000
#  - 1s - loss: 0.0214 - accuracy: 0.9997 - val_loss: 2.2579 - val_accuracy: 0.5204
#
# Epoch 00237: val_loss did not improve from 0.64327
# Epoch 238/1000
#  - 1s - loss: 0.0196 - accuracy: 1.0000 - val_loss: 2.7358 - val_accuracy: 0.5162
#
# Epoch 00238: val_loss did not improve from 0.64327
# Epoch 239/1000
#  - 1s - loss: 0.0189 - accuracy: 0.9999 - val_loss: 2.6157 - val_accuracy: 0.5189
#
# Epoch 00239: val_loss did not improve from 0.64327
# Epoch 240/1000
#  - 1s - loss: 0.0177 - accuracy: 1.0000 - val_loss: 3.1355 - val_accuracy: 0.5182
#
# Epoch 00240: val_loss did not improve from 0.64327
# Epoch 241/1000
#  - 1s - loss: 0.0173 - accuracy: 1.0000 - val_loss: 3.2308 - val_accuracy: 0.5204
#
# Epoch 00241: val_loss did not improve from 0.64327
# Epoch 242/1000
#  - 1s - loss: 0.0167 - accuracy: 1.0000 - val_loss: 3.0880 - val_accuracy: 0.5166
#
# Epoch 00242: val_loss did not improve from 0.64327
# Epoch 243/1000
#  - 1s - loss: 0.0168 - accuracy: 0.9999 - val_loss: 2.2789 - val_accuracy: 0.5197
#
# Epoch 00243: val_loss did not improve from 0.64327
# Epoch 244/1000
#  - 1s - loss: 0.0154 - accuracy: 1.0000 - val_loss: 2.5830 - val_accuracy: 0.5174
#
# Epoch 00244: val_loss did not improve from 0.64327
# Epoch 245/1000
#  - 1s - loss: 0.0161 - accuracy: 0.9999 - val_loss: 2.8904 - val_accuracy: 0.5113
#
# Epoch 00245: val_loss did not improve from 0.64327
# Epoch 246/1000
#  - 1s - loss: 0.0157 - accuracy: 1.0000 - val_loss: 3.1159 - val_accuracy: 0.5162
#
# Epoch 00246: val_loss did not improve from 0.64327
# Epoch 247/1000
#  - 1s - loss: 0.0140 - accuracy: 0.9999 - val_loss: 3.0745 - val_accuracy: 0.5193
#
# Epoch 00247: val_loss did not improve from 0.64327
# Epoch 248/1000
#  - 1s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 2.6544 - val_accuracy: 0.5239
#
# Epoch 00248: val_loss did not improve from 0.64327
# Epoch 249/1000
#  - 1s - loss: 0.0139 - accuracy: 0.9997 - val_loss: 2.5334 - val_accuracy: 0.5250
#
# Epoch 00249: val_loss did not improve from 0.64327
# Epoch 250/1000
#  - 1s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 2.5914 - val_accuracy: 0.5189
#
# Epoch 00250: val_loss did not improve from 0.64327
# Epoch 251/1000
#  - 1s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 3.3948 - val_accuracy: 0.5212
#
# Epoch 00251: val_loss did not improve from 0.64327
# Epoch 252/1000
#  - 1s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 2.3004 - val_accuracy: 0.5201
#
# Epoch 00252: val_loss did not improve from 0.64327
# Epoch 253/1000
#  - 1s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 2.2577 - val_accuracy: 0.5266
#
# Epoch 00253: val_loss did not improve from 0.64327
# Epoch 254/1000
#  - 1s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 2.6942 - val_accuracy: 0.5197
#
# Epoch 00254: val_loss did not improve from 0.64327
# Epoch 255/1000
#  - 1s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 3.0925 - val_accuracy: 0.5182
#
# Epoch 00255: val_loss did not improve from 0.64327
# Epoch 256/1000
#  - 1s - loss: 0.0137 - accuracy: 0.9999 - val_loss: 2.9740 - val_accuracy: 0.5189
#
# Epoch 00256: val_loss did not improve from 0.64327
# Epoch 257/1000
#  - 1s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 3.6093 - val_accuracy: 0.5243
#
# Epoch 00257: val_loss did not improve from 0.64327
# Epoch 258/1000
#  - 1s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 2.8658 - val_accuracy: 0.5227
#
# Epoch 00258: val_loss did not improve from 0.64327
# Epoch 259/1000
#  - 1s - loss: 0.0107 - accuracy: 1.0000 - val_loss: 3.7213 - val_accuracy: 0.5227
#
# Epoch 00259: val_loss did not improve from 0.64327
# Epoch 260/1000
#  - 1s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 2.3459 - val_accuracy: 0.5197
#
# Epoch 00260: val_loss did not improve from 0.64327
# Epoch 261/1000
#  - 1s - loss: 0.0111 - accuracy: 0.9999 - val_loss: 4.0268 - val_accuracy: 0.5197
#
# Epoch 00261: val_loss did not improve from 0.64327
# Epoch 262/1000
#  - 1s - loss: 0.0147 - accuracy: 0.9997 - val_loss: 4.3200 - val_accuracy: 0.5201
#
# Epoch 00262: val_loss did not improve from 0.64327
# Epoch 263/1000
#  - 1s - loss: 0.0132 - accuracy: 0.9997 - val_loss: 3.7939 - val_accuracy: 0.5162
#
# Epoch 00263: val_loss did not improve from 0.64327
# Epoch 264/1000
#  - 1s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 2.7172 - val_accuracy: 0.5174
#
# Epoch 00264: val_loss did not improve from 0.64327
# Epoch 265/1000
#  - 1s - loss: 0.0114 - accuracy: 0.9999 - val_loss: 4.1305 - val_accuracy: 0.5147
#
# Epoch 00265: val_loss did not improve from 0.64327
# Epoch 266/1000
#  - 1s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 2.1004 - val_accuracy: 0.5170
#
# Epoch 00266: val_loss did not improve from 0.64327
# Epoch 267/1000
#  - 1s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 3.7196 - val_accuracy: 0.5189
#
# Epoch 00267: val_loss did not improve from 0.64327
# Epoch 268/1000
#  - 1s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 2.7763 - val_accuracy: 0.5239
#
# Epoch 00268: val_loss did not improve from 0.64327
# Epoch 269/1000
#  - 1s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 2.6047 - val_accuracy: 0.5174
#
# Epoch 00269: val_loss did not improve from 0.64327
# Epoch 270/1000
#  - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 3.1671 - val_accuracy: 0.5201
#
# Epoch 00270: val_loss did not improve from 0.64327
# Epoch 271/1000
#  - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 3.3673 - val_accuracy: 0.5258
#
# Epoch 00271: val_loss did not improve from 0.64327
# Epoch 272/1000
#  - 1s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 2.4862 - val_accuracy: 0.5204
#
# Epoch 00272: val_loss did not improve from 0.64327
# Epoch 273/1000
#  - 1s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 2.8547 - val_accuracy: 0.5239
#
# Epoch 00273: val_loss did not improve from 0.64327
# Epoch 274/1000
#  - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 2.9312 - val_accuracy: 0.5197
#
# Epoch 00274: val_loss did not improve from 0.64327
# Epoch 275/1000
#  - 1s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 3.0611 - val_accuracy: 0.5147
#
# Epoch 00275: val_loss did not improve from 0.64327
# Epoch 276/1000
#  - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 2.4562 - val_accuracy: 0.5224
#
# Epoch 00276: val_loss did not improve from 0.64327
# Epoch 277/1000
#  - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 3.3608 - val_accuracy: 0.5239
#
# Epoch 00277: val_loss did not improve from 0.64327
# Epoch 278/1000
#  - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.9744 - val_accuracy: 0.5224
#
# Epoch 00278: val_loss did not improve from 0.64327
# Epoch 279/1000
#  - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 3.3023 - val_accuracy: 0.5189
#
# Epoch 00279: val_loss did not improve from 0.64327
# Epoch 280/1000
#  - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 4.0527 - val_accuracy: 0.5170
#
# Epoch 00280: val_loss did not improve from 0.64327
# Epoch 281/1000
#  - 1s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 3.6690 - val_accuracy: 0.5166
#
# Epoch 00281: val_loss did not improve from 0.64327
# Epoch 282/1000
#  - 1s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 3.0521 - val_accuracy: 0.5132
#
# Epoch 00282: val_loss did not improve from 0.64327
# Epoch 283/1000
#  - 1s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 4.0687 - val_accuracy: 0.5208
#
# Epoch 00283: val_loss did not improve from 0.64327
# Epoch 284/1000
#  - 1s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 4.1606 - val_accuracy: 0.5220
#
# Epoch 00284: val_loss did not improve from 0.64327
# Epoch 285/1000
#  - 1s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 3.6934 - val_accuracy: 0.5193
#
# Epoch 00285: val_loss did not improve from 0.64327
# Epoch 286/1000
#  - 1s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 2.3635 - val_accuracy: 0.5182
#
# Epoch 00286: val_loss did not improve from 0.64327
# Epoch 287/1000
#  - 1s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 4.4373 - val_accuracy: 0.5185
#
# Epoch 00287: val_loss did not improve from 0.64327
# Epoch 288/1000
#  - 1s - loss: 0.0150 - accuracy: 0.9981 - val_loss: 3.2146 - val_accuracy: 0.5117
#
# Epoch 00288: val_loss did not improve from 0.64327
# Epoch 289/1000
#  - 1s - loss: 0.1322 - accuracy: 0.9515 - val_loss: 4.3512 - val_accuracy: 0.5239
#
# Epoch 00289: val_loss did not improve from 0.64327
# Epoch 290/1000
#  - 1s - loss: 0.0450 - accuracy: 0.9853 - val_loss: 2.2068 - val_accuracy: 0.5243
#
# Epoch 00290: val_loss did not improve from 0.64327
# Epoch 291/1000
#  - 1s - loss: 0.0140 - accuracy: 0.9980 - val_loss: 3.7990 - val_accuracy: 0.5151
#
# Epoch 00291: val_loss did not improve from 0.64327
# Epoch 292/1000
#  - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 2.6036 - val_accuracy: 0.5201
#
# Epoch 00292: val_loss did not improve from 0.64327
# Epoch 293/1000
#  - 1s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 3.1376 - val_accuracy: 0.5189
#
# Epoch 00293: val_loss did not improve from 0.64327
# Epoch 294/1000
#  - 1s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 3.6972 - val_accuracy: 0.5224
#
# Epoch 00294: val_loss did not improve from 0.64327
# Epoch 295/1000
#  - 1s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 4.1809 - val_accuracy: 0.5197
#
# Epoch 00295: val_loss did not improve from 0.64327
# Epoch 296/1000
#  - 1s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.9267 - val_accuracy: 0.5216
#
# Epoch 00296: val_loss did not improve from 0.64327
# Epoch 297/1000
#  - 1s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 3.6831 - val_accuracy: 0.5224
#
# Epoch 00297: val_loss did not improve from 0.64327
# Epoch 298/1000
#  - 1s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 3.7769 - val_accuracy: 0.5193
#
# Epoch 00298: val_loss did not improve from 0.64327
# Epoch 299/1000
#  - 1s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 4.2177 - val_accuracy: 0.5220
#
# Epoch 00299: val_loss did not improve from 0.64327
# Epoch 300/1000
#  - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 3.2425 - val_accuracy: 0.5204
#
# Epoch 00300: val_loss did not improve from 0.64327
# Epoch 301/1000
#  - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 3.1732 - val_accuracy: 0.5220
#
# Epoch 00301: val_loss did not improve from 0.64327
# Epoch 302/1000
#  - 1s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 4.0035 - val_accuracy: 0.5197
#
# Epoch 00302: val_loss did not improve from 0.64327
# Epoch 303/1000
#  - 1s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.8321 - val_accuracy: 0.5231
#
# Epoch 00303: val_loss did not improve from 0.64327
# Epoch 304/1000
#  - 1s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 4.3416 - val_accuracy: 0.5231
#
# Epoch 00304: val_loss did not improve from 0.64327
# Epoch 305/1000
#  - 1s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 3.7330 - val_accuracy: 0.5197
#
# Epoch 00305: val_loss did not improve from 0.64327
# Epoch 306/1000
#  - 1s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 4.6697 - val_accuracy: 0.5220
#
# Epoch 00306: val_loss did not improve from 0.64327
# Epoch 307/1000
#  - 1s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 5.0950 - val_accuracy: 0.5231
#
# Epoch 00307: val_loss did not improve from 0.64327
# Epoch 308/1000
#  - 1s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.5961 - val_accuracy: 0.5189
#
# Epoch 00308: val_loss did not improve from 0.64327
# Epoch 309/1000
#  - 1s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 4.0373 - val_accuracy: 0.5189
#
# Epoch 00309: val_loss did not improve from 0.64327
# Epoch 310/1000
#  - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 4.0108 - val_accuracy: 0.5178
#
# Epoch 00310: val_loss did not improve from 0.64327
# Epoch 311/1000
#  - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 5.0420 - val_accuracy: 0.5227
#
# Epoch 00311: val_loss did not improve from 0.64327
# Epoch 312/1000
#  - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 5.1058 - val_accuracy: 0.5220
#
# Epoch 00312: val_loss did not improve from 0.64327
# Epoch 313/1000
#  - 1s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 5.1492 - val_accuracy: 0.5182
#
# Epoch 00313: val_loss did not improve from 0.64327
# Epoch 314/1000
#  - 1s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 3.9305 - val_accuracy: 0.5197
#
# Epoch 00314: val_loss did not improve from 0.64327
# Epoch 315/1000
#  - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.6591 - val_accuracy: 0.5201
#
# Epoch 00315: val_loss did not improve from 0.64327
# Epoch 316/1000
#  - 1s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.7527 - val_accuracy: 0.5201
#
# Epoch 00316: val_loss did not improve from 0.64327
# Epoch 317/1000
#  - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.6314 - val_accuracy: 0.5201
#
# Epoch 00317: val_loss did not improve from 0.64327
# Epoch 318/1000
#  - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 5.4596 - val_accuracy: 0.5227
#
# Epoch 00318: val_loss did not improve from 0.64327
# Epoch 319/1000
#  - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 4.2349 - val_accuracy: 0.5182
#
# Epoch 00319: val_loss did not improve from 0.64327

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
# model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_ex_02008.h5'
# model_name = 'classifier_45_close_updown_pr_theta.h5'
# model_name = 'classifier_45_close_updown_pr_theta_train_evendata_shuffle2_300k.h5'
# model_name = 'classifier_45_close_updown_pr_05532.h5'

model = keras.models.load_model(ckpt_path + model_name)

# %%
org_x_test = x_test
org_y_test = y_test
org_pr_test = pr_test

# %%
x_test = org_x_test
y_test = org_y_test
pr_test = org_pr_test

# %%
concat_x = np.vstack((org_x_test, new_input_x))
concat_y = np.vstack((org_y_test, np.where(new_input_pr > 1, 1, 0)))
concat_pr = np.vstack((org_pr_test, new_input_pr))

# %%
x_test = new_input_x
y_test = np.where(new_input_pr > 1, 1, 0)
pr_test = new_input_pr

# %%
# x_test = new_input_x
# y_test = np.where(new_input_pr > 1, 1, 0)
# pr_test = new_input_pr

# x_test = org_x_test
# y_test = org_y_test
# pr_test = org_pr_test

# x_test = x_train
# y_test = y_train
# pr_test = pr_train

# x_test = x_val
# y_test = y_val
# pr_test = pr_val

# x_test = concat_x
# y_test = np.where(concat_pr > 1, 1, 0)
# pr_test = concat_pr

test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  if thresh < 0.6:
      continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  print('precision :', precision_score(y_test, y_pred))
  print('recall :', recall_score(y_test, y_pred))
  print()

  print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # plt.show()  
  print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
    print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
    print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()
# Out:
# test_result.shape : (2617, 2)
# y_test[:5] : [0 1 0 1 0]
# y_score[:5] : [[0.6937789 ]
#  [0.6104589 ]
#  [0.34531704]
#  [0.7640255 ]
#  [0.11652698]]
# y_test.shape : (2617, 1)
# y_score.shape : (2617, 1)
# len(y_test) : 2617
# Streaming output truncated to the last 5000 lines.
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.360
# thresh : 0.6782105
# y_pred.shape : (2617,)
# precision : 0.4922737306843267
# recall : 0.1820408163265306
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.406
# thresh : 0.6783552
# y_pred.shape : (2617,)
# precision : 0.4911504424778761
# recall : 0.18122448979591838
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.399
# thresh : 0.67839605
# y_pred.shape : (2617,)
# precision : 0.49002217294900224
# recall : 0.18040816326530612
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.230
# thresh : 0.6789969
# y_pred.shape : (2617,)
# precision : 0.4911111111111111
# recall : 0.18040816326530612
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.573
# thresh : 0.6798932
# y_pred.shape : (2617,)
# precision : 0.4922048997772829
# recall : 0.18040816326530612
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.574
# thresh : 0.68000436
# y_pred.shape : (2617,)
# precision : 0.49330357142857145
# recall : 0.18040816326530612
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.726
# thresh : 0.68050313
# y_pred.shape : (2617,)
# precision : 0.49440715883668906
# recall : 0.18040816326530612
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.808
# thresh : 0.68057984
# y_pred.shape : (2617,)
# precision : 0.49551569506726456
# recall : 0.18040816326530612
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.876
# thresh : 0.68142915
# y_pred.shape : (2617,)
# precision : 0.4943820224719101
# recall : 0.17959183673469387
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.742
# thresh : 0.6818862
# y_pred.shape : (2617,)
# precision : 0.4954954954954955
# recall : 0.17959183673469387
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.779
# thresh : 0.68211156
# y_pred.shape : (2617,)
# precision : 0.4966139954853273
# recall : 0.17959183673469387
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.945
# thresh : 0.6824376
# y_pred.shape : (2617,)
# precision : 0.49547511312217196
# recall : 0.17877551020408164
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.665
# thresh : 0.68301517
# y_pred.shape : (2617,)
# precision : 0.4965986394557823
# recall : 0.17877551020408164
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.712
# thresh : 0.68328685
# y_pred.shape : (2617,)
# precision : 0.4954545454545455
# recall : 0.17795918367346938
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.627
# thresh : 0.6836906
# y_pred.shape : (2617,)
# precision : 0.49430523917995445
# recall : 0.17714285714285713
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.574
# thresh : 0.6840853
# y_pred.shape : (2617,)
# precision : 0.4954337899543379
# recall : 0.17714285714285713
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.640
# thresh : 0.6845166
# y_pred.shape : (2617,)
# precision : 0.494279176201373
# recall : 0.1763265306122449
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.470
# thresh : 0.68458563
# y_pred.shape : (2617,)
# precision : 0.49311926605504586
# recall : 0.17551020408163265
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.454
# thresh : 0.68484956
# y_pred.shape : (2617,)
# precision : 0.4942528735632184
# recall : 0.17551020408163265
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.465
# thresh : 0.6850059
# y_pred.shape : (2617,)
# precision : 0.49539170506912444
# recall : 0.17551020408163265
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.683
# thresh : 0.6852994
# y_pred.shape : (2617,)
# precision : 0.49653579676674364
# recall : 0.17551020408163265
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.940
# thresh : 0.68533903
# y_pred.shape : (2617,)
# precision : 0.49537037037037035
# recall : 0.17469387755102042
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.803
# thresh : 0.68554723
# y_pred.shape : (2617,)
# precision : 0.494199535962877
# recall : 0.17387755102040817
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.615
# thresh : 0.685799
# y_pred.shape : (2617,)
# precision : 0.4930232558139535
# recall : 0.1730612244897959
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.425
# thresh : 0.68596363
# y_pred.shape : (2617,)
# precision : 0.49417249417249415
# recall : 0.1730612244897959
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.457
# thresh : 0.6860507
# y_pred.shape : (2617,)
# precision : 0.4953271028037383
# recall : 0.1730612244897959
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.524
# thresh : 0.68617207
# y_pred.shape : (2617,)
# precision : 0.49414519906323184
# recall : 0.17224489795918368
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.409
# thresh : 0.68642455
# y_pred.shape : (2617,)
# precision : 0.49295774647887325
# recall : 0.17142857142857143
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.384
# thresh : 0.6865733
# y_pred.shape : (2617,)
# precision : 0.49176470588235294
# recall : 0.17061224489795918
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.347
# thresh : 0.68705785
# y_pred.shape : (2617,)
# precision : 0.49292452830188677
# recall : 0.17061224489795918
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.357
# thresh : 0.6872651
# y_pred.shape : (2617,)
# precision : 0.491725768321513
# recall : 0.16979591836734695
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.295
# thresh : 0.687286
# y_pred.shape : (2617,)
# precision : 0.490521327014218
# recall : 0.1689795918367347
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.289
# thresh : 0.6883249
# y_pred.shape : (2617,)
# precision : 0.4916864608076009
# recall : 0.1689795918367347
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.325
# thresh : 0.6887487
# y_pred.shape : (2617,)
# precision : 0.4928571428571429
# recall : 0.1689795918367347
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.351
# thresh : 0.688823
# y_pred.shape : (2617,)
# precision : 0.49403341288782815
# recall : 0.1689795918367347
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.404
# thresh : 0.6892347
# y_pred.shape : (2617,)
# precision : 0.49282296650717705
# recall : 0.16816326530612244
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.378
# thresh : 0.689592
# y_pred.shape : (2617,)
# precision : 0.4940047961630695
# recall : 0.16816326530612244
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.401
# thresh : 0.68996686
# y_pred.shape : (2617,)
# precision : 0.49278846153846156
# recall : 0.1673469387755102
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.377
# thresh : 0.6905556
# y_pred.shape : (2617,)
# precision : 0.491566265060241
# recall : 0.16653061224489796
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.260
# thresh : 0.69078094
# y_pred.shape : (2617,)
# precision : 0.49033816425120774
# recall : 0.1657142857142857
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.228
# thresh : 0.69082844
# y_pred.shape : (2617,)
# precision : 0.4891041162227603
# recall : 0.16489795918367348
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.206
# thresh : 0.6909283
# y_pred.shape : (2617,)
# precision : 0.49029126213592233
# recall : 0.16489795918367348
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.206
# thresh : 0.6918237
# y_pred.shape : (2617,)
# precision : 0.49148418491484186
# recall : 0.16489795918367348
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.375
# thresh : 0.6920251
# y_pred.shape : (2617,)
# precision : 0.4926829268292683
# recall : 0.16489795918367348
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.572
# thresh : 0.6924394
# y_pred.shape : (2617,)
# precision : 0.49144254278728605
# recall : 0.16408163265306122
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.464
# thresh : 0.6929011
# y_pred.shape : (2617,)
# precision : 0.49019607843137253
# recall : 0.16326530612244897
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.386
# thresh : 0.6932731
# y_pred.shape : (2617,)
# precision : 0.4914004914004914
# recall : 0.16326530612244897
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.467
# thresh : 0.69367015
# y_pred.shape : (2617,)
# precision : 0.49261083743842365
# recall : 0.16326530612244897
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.545
# thresh : 0.6937789
# y_pred.shape : (2617,)
# precision : 0.49382716049382713
# recall : 0.16326530612244897
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.621
# thresh : 0.69403285
# y_pred.shape : (2617,)
# precision : 0.49504950495049505
# recall : 0.16326530612244897
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.683
# thresh : 0.69422174
# y_pred.shape : (2617,)
# precision : 0.49627791563275436
# recall : 0.16326530612244897
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.713
# thresh : 0.69442993
# y_pred.shape : (2617,)
# precision : 0.4975124378109453
# recall : 0.16326530612244897
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.720
# thresh : 0.69446856
# y_pred.shape : (2617,)
# precision : 0.49875311720698257
# recall : 0.16326530612244897
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.869
# thresh : 0.69450665
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.16326530612244897
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.925
# thresh : 0.6946199
# y_pred.shape : (2617,)
# precision : 0.49874686716791977
# recall : 0.16244897959183674
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.788
# thresh : 0.6948632
# y_pred.shape : (2617,)
# precision : 0.49748743718592964
# recall : 0.16163265306122448
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.729
# thresh : 0.6950353
# y_pred.shape : (2617,)
# precision : 0.4987405541561713
# recall : 0.16163265306122448
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.753
# thresh : 0.69516367
# y_pred.shape : (2617,)
# precision : 0.49747474747474746
# recall : 0.16081632653061226
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.720
# thresh : 0.6960724
# y_pred.shape : (2617,)
# precision : 0.49873417721518987
# recall : 0.16081632653061226
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.731
# thresh : 0.69613993
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.16081632653061226
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.140
# thresh : 0.69736135
# y_pred.shape : (2617,)
# precision : 0.5012722646310432
# recall : 0.16081632653061226
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.239
# thresh : 0.6976412
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.16
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.019
# thresh : 0.6980264
# y_pred.shape : (2617,)
# precision : 0.49872122762148335
# recall : 0.15918367346938775
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.949
# thresh : 0.6987008
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.15918367346938775
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.736
# thresh : 0.6987044
# y_pred.shape : (2617,)
# precision : 0.4987146529562982
# recall : 0.15836734693877552
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.656
# thresh : 0.699366
# y_pred.shape : (2617,)
# precision : 0.49742268041237114
# recall : 0.15755102040816327
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.533
# thresh : 0.6995576
# y_pred.shape : (2617,)
# precision : 0.49870801033591733
# recall : 0.15755102040816327
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.689
# thresh : 0.6995651
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.15755102040816327
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.800
# thresh : 0.6996803
# y_pred.shape : (2617,)
# precision : 0.5012987012987012
# recall : 0.15755102040816327
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.825
# thresh : 0.69974774
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.156734693877551
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.683
# thresh : 0.699833
# y_pred.shape : (2617,)
# precision : 0.49869451697127937
# recall : 0.15591836734693879
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.598
# thresh : 0.70001954
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.15591836734693879
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.625
# thresh : 0.7004005
# y_pred.shape : (2617,)
# precision : 0.49868766404199477
# recall : 0.15510204081632653
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.422
# thresh : 0.7005188
# y_pred.shape : (2617,)
# precision : 0.49736842105263157
# recall : 0.15428571428571428
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.315
# thresh : 0.7005861
# y_pred.shape : (2617,)
# precision : 0.49868073878627966
# recall : 0.15428571428571428
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.443
# thresh : 0.70076156
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.15428571428571428
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.577
# thresh : 0.7010089
# y_pred.shape : (2617,)
# precision : 0.5013262599469496
# recall : 0.15428571428571428
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.637
# thresh : 0.70163643
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.15346938775510205
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.409
# thresh : 0.70184
# y_pred.shape : (2617,)
# precision : 0.49866666666666665
# recall : 0.1526530612244898
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.038
# thresh : 0.70254475
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.1526530612244898
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.250
# thresh : 0.7031484
# y_pred.shape : (2617,)
# precision : 0.5013404825737265
# recall : 0.1526530612244898
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.381
# thresh : 0.7033096
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.15183673469387754
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 2.364
# thresh : 0.7035632
# y_pred.shape : (2617,)
# precision : 0.49865229110512127
# recall : 0.1510204081632653
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.424
# thresh : 0.70418394
# y_pred.shape : (2617,)
# precision : 0.4972972972972973
# recall : 0.15020408163265306
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.423
# thresh : 0.70442295
# y_pred.shape : (2617,)
# precision : 0.4986449864498645
# recall : 0.15020408163265306
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.503
# thresh : 0.70445555
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.15020408163265306
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.564
# thresh : 0.7045391
# y_pred.shape : (2617,)
# precision : 0.4986376021798365
# recall : 0.1493877551020408
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.476
# thresh : 0.7048181
# y_pred.shape : (2617,)
# precision : 0.4972677595628415
# recall : 0.14857142857142858
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.420
# thresh : 0.704972
# y_pred.shape : (2617,)
# precision : 0.4958904109589041
# recall : 0.14775510204081632
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.297
# thresh : 0.7051215
# y_pred.shape : (2617,)
# precision : 0.49725274725274726
# recall : 0.14775510204081632
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.347
# thresh : 0.7057528
# y_pred.shape : (2617,)
# precision : 0.49586776859504134
# recall : 0.1469387755102041
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.247
# thresh : 0.70580554
# y_pred.shape : (2617,)
# precision : 0.494475138121547
# recall : 0.14612244897959184
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.184
# thresh : 0.7058145
# y_pred.shape : (2617,)
# precision : 0.49584487534626037
# recall : 0.14612244897959184
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.254
# thresh : 0.7061629
# y_pred.shape : (2617,)
# precision : 0.49722222222222223
# recall : 0.14612244897959184
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.372
# thresh : 0.7065649
# y_pred.shape : (2617,)
# precision : 0.4958217270194986
# recall : 0.14530612244897959
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.355
# thresh : 0.70661366
# y_pred.shape : (2617,)
# precision : 0.49441340782122906
# recall : 0.14448979591836736
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.196
# thresh : 0.70669925
# y_pred.shape : (2617,)
# precision : 0.49299719887955185
# recall : 0.1436734693877551
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.186
# thresh : 0.7071526
# y_pred.shape : (2617,)
# precision : 0.49157303370786515
# recall : 0.14285714285714285
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.137
# thresh : 0.7073841
# y_pred.shape : (2617,)
# precision : 0.49014084507042255
# recall : 0.14204081632653062
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.118
# thresh : 0.70740753
# y_pred.shape : (2617,)
# precision : 0.4887005649717514
# recall : 0.14122448979591837
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.112
# thresh : 0.7076944
# y_pred.shape : (2617,)
# precision : 0.49008498583569404
# recall : 0.14122448979591837
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.117
# thresh : 0.70769477
# y_pred.shape : (2617,)
# precision : 0.4914772727272727
# recall : 0.14122448979591837
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.142
# thresh : 0.70788366
# y_pred.shape : (2617,)
# precision : 0.49002849002849
# recall : 0.1404081632653061
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.129
# thresh : 0.7086346
# y_pred.shape : (2617,)
# precision : 0.49142857142857144
# recall : 0.1404081632653061
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.190
# thresh : 0.7088596
# y_pred.shape : (2617,)
# precision : 0.4899713467048711
# recall : 0.13959183673469389
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.184
# thresh : 0.70894235
# y_pred.shape : (2617,)
# precision : 0.4885057471264368
# recall : 0.13877551020408163
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.162
# thresh : 0.708993
# y_pred.shape : (2617,)
# precision : 0.4899135446685879
# recall : 0.13877551020408163
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.166
# thresh : 0.7092663
# y_pred.shape : (2617,)
# precision : 0.4913294797687861
# recall : 0.13877551020408163
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.263
# thresh : 0.7095595
# y_pred.shape : (2617,)
# precision : 0.4927536231884058
# recall : 0.13877551020408163
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.310
# thresh : 0.7101887
# y_pred.shape : (2617,)
# precision : 0.49127906976744184
# recall : 0.13795918367346938
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.160
# thresh : 0.7106098
# y_pred.shape : (2617,)
# precision : 0.4897959183673469
# recall : 0.13714285714285715
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.040
# thresh : 0.71073353
# y_pred.shape : (2617,)
# precision : 0.48830409356725146
# recall : 0.1363265306122449
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 0.999
# thresh : 0.7115453
# y_pred.shape : (2617,)
# precision : 0.4868035190615836
# recall : 0.13551020408163264
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 0.907
# thresh : 0.7119667
# y_pred.shape : (2617,)
# precision : 0.4852941176470588
# recall : 0.1346938775510204
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 0.837
# thresh : 0.71199846
# y_pred.shape : (2617,)
# precision : 0.48672566371681414
# recall : 0.1346938775510204
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 0.838
# thresh : 0.7122437
# y_pred.shape : (2617,)
# precision : 0.48520710059171596
# recall : 0.13387755102040816
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 0.758
# thresh : 0.71275854
# y_pred.shape : (2617,)
# precision : 0.4836795252225519
# recall : 0.13306122448979593
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.752
# thresh : 0.7131249
# y_pred.shape : (2617,)
# precision : 0.48214285714285715
# recall : 0.13224489795918368
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.741
# thresh : 0.71330947
# y_pred.shape : (2617,)
# precision : 0.4835820895522388
# recall : 0.13224489795918368
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.819
# thresh : 0.71426934
# y_pred.shape : (2617,)
# precision : 0.4820359281437126
# recall : 0.13142857142857142
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.787
# thresh : 0.71471244
# y_pred.shape : (2617,)
# precision : 0.4804804804804805
# recall : 0.1306122448979592
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.779
# thresh : 0.71501285
# y_pred.shape : (2617,)
# precision : 0.4819277108433735
# recall : 0.1306122448979592
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.799
# thresh : 0.7150184
# y_pred.shape : (2617,)
# precision : 0.48036253776435045
# recall : 0.12979591836734694
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.794
# thresh : 0.7152088
# y_pred.shape : (2617,)
# precision : 0.4818181818181818
# recall : 0.12979591836734694
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.852
# thresh : 0.715429
# y_pred.shape : (2617,)
# precision : 0.48328267477203646
# recall : 0.12979591836734694
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.867
# thresh : 0.7155961
# y_pred.shape : (2617,)
# precision : 0.4817073170731707
# recall : 0.12897959183673469
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.864
# thresh : 0.71572375
# y_pred.shape : (2617,)
# precision : 0.4801223241590214
# recall : 0.12816326530612246
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.851
# thresh : 0.7161349
# y_pred.shape : (2617,)
# precision : 0.4815950920245399
# recall : 0.12816326530612246
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.891
# thresh : 0.7164454
# y_pred.shape : (2617,)
# precision : 0.48
# recall : 0.1273469387755102
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.873
# thresh : 0.7165512
# y_pred.shape : (2617,)
# precision : 0.48148148148148145
# recall : 0.1273469387755102
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.889
# thresh : 0.7168151
# y_pred.shape : (2617,)
# precision : 0.48297213622291024
# recall : 0.1273469387755102
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.981
# thresh : 0.71756214
# y_pred.shape : (2617,)
# precision : 0.4813664596273292
# recall : 0.12653061224489795
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.974
# thresh : 0.7176524
# y_pred.shape : (2617,)
# precision : 0.4797507788161994
# recall : 0.12571428571428572
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.917
# thresh : 0.71768415
# y_pred.shape : (2617,)
# precision : 0.478125
# recall : 0.12489795918367347
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.843
# thresh : 0.7178478
# y_pred.shape : (2617,)
# precision : 0.47962382445141066
# recall : 0.12489795918367347
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.939
# thresh : 0.7185651
# y_pred.shape : (2617,)
# precision : 0.4779874213836478
# recall : 0.12408163265306123
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.924
# thresh : 0.71916294
# y_pred.shape : (2617,)
# precision : 0.47634069400630913
# recall : 0.12326530612244897
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.902
# thresh : 0.7191946
# y_pred.shape : (2617,)
# precision : 0.47468354430379744
# recall : 0.12244897959183673
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.826
# thresh : 0.7196228
# y_pred.shape : (2617,)
# precision : 0.47619047619047616
# recall : 0.12244897959183673
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.854
# thresh : 0.71992576
# y_pred.shape : (2617,)
# precision : 0.4745222929936306
# recall : 0.12163265306122449
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.796
# thresh : 0.72076905
# y_pred.shape : (2617,)
# precision : 0.476038338658147
# recall : 0.12163265306122449
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.799
# thresh : 0.7208777
# y_pred.shape : (2617,)
# precision : 0.47435897435897434
# recall : 0.12081632653061225
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.775
# thresh : 0.7209605
# y_pred.shape : (2617,)
# precision : 0.4758842443729904
# recall : 0.12081632653061225
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.778
# thresh : 0.72138476
# y_pred.shape : (2617,)
# precision : 0.4774193548387097
# recall : 0.12081632653061225
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.812
# thresh : 0.7215502
# y_pred.shape : (2617,)
# precision : 0.47572815533980584
# recall : 0.12
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.793
# thresh : 0.72166157
# y_pred.shape : (2617,)
# precision : 0.474025974025974
# recall : 0.11918367346938775
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.783
# thresh : 0.7223334
# y_pred.shape : (2617,)
# precision : 0.4723127035830619
# recall : 0.11836734693877551
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.768
# thresh : 0.7225015
# y_pred.shape : (2617,)
# precision : 0.4738562091503268
# recall : 0.11836734693877551
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.836
# thresh : 0.72391236
# y_pred.shape : (2617,)
# precision : 0.4721311475409836
# recall : 0.11755102040816326
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.834
# thresh : 0.724274
# y_pred.shape : (2617,)
# precision : 0.47368421052631576
# recall : 0.11755102040816326
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.861
# thresh : 0.72462374
# y_pred.shape : (2617,)
# precision : 0.4752475247524752
# recall : 0.11755102040816326
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.902
# thresh : 0.72469485
# y_pred.shape : (2617,)
# precision : 0.4768211920529801
# recall : 0.11755102040816326
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.916
# thresh : 0.72510415
# y_pred.shape : (2617,)
# precision : 0.47840531561461797
# recall : 0.11755102040816326
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.984
# thresh : 0.7260613
# y_pred.shape : (2617,)
# precision : 0.4766666666666667
# recall : 0.11673469387755102
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.908
# thresh : 0.7261291
# y_pred.shape : (2617,)
# precision : 0.4782608695652174
# recall : 0.11673469387755102
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.934
# thresh : 0.72678834
# y_pred.shape : (2617,)
# precision : 0.47651006711409394
# recall : 0.11591836734693878
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.869
# thresh : 0.72700137
# y_pred.shape : (2617,)
# precision : 0.47474747474747475
# recall : 0.11510204081632654
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.830
# thresh : 0.7270595
# y_pred.shape : (2617,)
# precision : 0.47297297297297297
# recall : 0.11428571428571428
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.812
# thresh : 0.72722167
# y_pred.shape : (2617,)
# precision : 0.4745762711864407
# recall : 0.11428571428571428
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.817
# thresh : 0.72760814
# y_pred.shape : (2617,)
# precision : 0.47619047619047616
# recall : 0.11428571428571428
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.855
# thresh : 0.7278321
# y_pred.shape : (2617,)
# precision : 0.4778156996587031
# recall : 0.11428571428571428
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.908
# thresh : 0.7278616
# y_pred.shape : (2617,)
# precision : 0.4794520547945205
# recall : 0.11428571428571428
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.950
# thresh : 0.72858894
# y_pred.shape : (2617,)
# precision : 0.48109965635738833
# recall : 0.11428571428571428
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.992
# thresh : 0.7288879
# y_pred.shape : (2617,)
# precision : 0.4793103448275862
# recall : 0.11346938775510204
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.878
# thresh : 0.72894144
# y_pred.shape : (2617,)
# precision : 0.47750865051903113
# recall : 0.1126530612244898
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.710
# thresh : 0.7300491
# y_pred.shape : (2617,)
# precision : 0.4756944444444444
# recall : 0.11183673469387755
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.655
# thresh : 0.730247
# y_pred.shape : (2617,)
# precision : 0.47735191637630664
# recall : 0.11183673469387755
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.665
# thresh : 0.7303316
# y_pred.shape : (2617,)
# precision : 0.4755244755244755
# recall : 0.1110204081632653
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.645
# thresh : 0.7312697
# y_pred.shape : (2617,)
# precision : 0.47719298245614034
# recall : 0.1110204081632653
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.711
# thresh : 0.73187494
# y_pred.shape : (2617,)
# precision : 0.4753521126760563
# recall : 0.11020408163265306
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.644
# thresh : 0.7321425
# y_pred.shape : (2617,)
# precision : 0.4734982332155477
# recall : 0.10938775510204081
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.570
# thresh : 0.7333019
# y_pred.shape : (2617,)
# precision : 0.475177304964539
# recall : 0.10938775510204081
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.48
# accum_pr increased ! : 0.000 --> 0.619
# thresh : 0.73343164
# y_pred.shape : (2617,)
# precision : 0.47330960854092524
# recall : 0.10857142857142857
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.609
# thresh : 0.73425347
# y_pred.shape : (2617,)
# precision : 0.475
# recall : 0.10857142857142857
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.664
# thresh : 0.7360543
# y_pred.shape : (2617,)
# precision : 0.4731182795698925
# recall : 0.10775510204081633
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.611
# thresh : 0.73626167
# y_pred.shape : (2617,)
# precision : 0.4712230215827338
# recall : 0.10693877551020409
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.597
# thresh : 0.73643595
# y_pred.shape : (2617,)
# precision : 0.4693140794223827
# recall : 0.10612244897959183
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.585
# thresh : 0.7383587
# y_pred.shape : (2617,)
# precision : 0.47101449275362317
# recall : 0.10612244897959183
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.621
# thresh : 0.7383971
# y_pred.shape : (2617,)
# precision : 0.4727272727272727
# recall : 0.10612244897959183
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.640
# thresh : 0.7384543
# y_pred.shape : (2617,)
# precision : 0.4708029197080292
# recall : 0.10530612244897959
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.610
# thresh : 0.7386608
# y_pred.shape : (2617,)
# precision : 0.4725274725274725
# recall : 0.10530612244897959
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 0.664
# ...
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.120
# thresh : 0.86721635
# y_pred.shape : (2617,)
# precision : 0.5116279069767442
# recall : 0.017959183673469388
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.51
# accum_pr increased ! : 0.000 --> 1.128
# thresh : 0.867235
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.017142857142857144
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.104
# thresh : 0.86745983
# y_pred.shape : (2617,)
# precision : 0.4878048780487805
# recall : 0.0163265306122449
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.102
# thresh : 0.86790156
# y_pred.shape : (2617,)
# precision : 0.475
# recall : 0.015510204081632653
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.47
# accum_pr increased ! : 0.000 --> 1.008
# thresh : 0.86932147
# y_pred.shape : (2617,)
# precision : 0.48717948717948717
# recall : 0.015510204081632653
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.49
# accum_pr increased ! : 0.000 --> 1.145
# thresh : 0.86953944
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.015510204081632653
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.163
# thresh : 0.8734668
# y_pred.shape : (2617,)
# precision : 0.5135135135135135
# recall : 0.015510204081632653
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.51
# accum_pr increased ! : 0.000 --> 1.175
# thresh : 0.8760036
# y_pred.shape : (2617,)
# precision : 0.5277777777777778
# recall : 0.015510204081632653
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.53
# accum_pr increased ! : 0.000 --> 1.176
# thresh : 0.8790018
# y_pred.shape : (2617,)
# precision : 0.5142857142857142
# recall : 0.014693877551020407
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.51
# accum_pr increased ! : 0.000 --> 1.077
# thresh : 0.87940717
# y_pred.shape : (2617,)
# precision : 0.5294117647058824
# recall : 0.014693877551020407
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.53
# accum_pr increased ! : 0.000 --> 1.137
# thresh : 0.8832793
# y_pred.shape : (2617,)
# precision : 0.5454545454545454
# recall : 0.014693877551020407
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.55
# accum_pr increased ! : 0.000 --> 1.189
# thresh : 0.8863422
# y_pred.shape : (2617,)
# precision : 0.5625
# recall : 0.014693877551020407
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.56
# accum_pr increased ! : 0.000 --> 1.190
# thresh : 0.88641757
# y_pred.shape : (2617,)
# precision : 0.5806451612903226
# recall : 0.014693877551020407
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.58
# accum_pr increased ! : 0.000 --> 1.207
# thresh : 0.8872603
# y_pred.shape : (2617,)
# precision : 0.6
# recall : 0.014693877551020407
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.60
# accum_pr increased ! : 0.000 --> 1.234
# thresh : 0.8884057
# y_pred.shape : (2617,)
# precision : 0.6206896551724138
# recall : 0.014693877551020407
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.62
# accum_pr increased ! : 0.000 --> 1.332
# thresh : 0.88880485
# y_pred.shape : (2617,)
# precision : 0.6071428571428571
# recall : 0.013877551020408163
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.61
# accum_pr increased ! : 0.000 --> 1.305
# thresh : 0.8895375
# y_pred.shape : (2617,)
# precision : 0.5925925925925926
# recall : 0.013061224489795919
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.59
# accum_pr increased ! : 0.000 --> 1.256
# thresh : 0.8896277
# y_pred.shape : (2617,)
# precision : 0.5769230769230769
# recall : 0.012244897959183673
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.58
# accum_pr increased ! : 0.000 --> 1.227
# thresh : 0.8904307
# y_pred.shape : (2617,)
# precision : 0.6
# recall : 0.012244897959183673
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.60
# accum_pr increased ! : 0.000 --> 1.241
# thresh : 0.891014
# y_pred.shape : (2617,)
# precision : 0.5833333333333334
# recall : 0.011428571428571429
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.58
# accum_pr increased ! : 0.000 --> 1.213
# thresh : 0.89348507
# y_pred.shape : (2617,)
# precision : 0.6086956521739131
# recall : 0.011428571428571429
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.61
# accum_pr increased ! : 0.000 --> 1.267
# thresh : 0.8956771
# y_pred.shape : (2617,)
# precision : 0.5909090909090909
# recall : 0.010612244897959184
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.59
# accum_pr increased ! : 0.000 --> 1.224
# thresh : 0.8994794
# y_pred.shape : (2617,)
# precision : 0.5714285714285714
# recall : 0.009795918367346938
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.57
# accum_pr increased ! : 0.000 --> 1.207
# thresh : 0.90103483
# y_pred.shape : (2617,)
# precision : 0.6
# recall : 0.009795918367346938
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.60
# accum_pr increased ! : 0.000 --> 1.275
# thresh : 0.9014014
# y_pred.shape : (2617,)
# precision : 0.5789473684210527
# recall : 0.008979591836734694
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.58
# accum_pr increased ! : 0.000 --> 1.271
# thresh : 0.90211403
# y_pred.shape : (2617,)
# precision : 0.5555555555555556
# recall : 0.00816326530612245
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.56
# accum_pr increased ! : 0.000 --> 1.236
# thresh : 0.9091396
# y_pred.shape : (2617,)
# precision : 0.5882352941176471
# recall : 0.00816326530612245
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.59
# accum_pr increased ! : 0.000 --> 1.339
# thresh : 0.91362643
# y_pred.shape : (2617,)
# precision : 0.625
# recall : 0.00816326530612245
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.62
# accum_pr increased ! : 0.000 --> 1.439
# thresh : 0.9177876
# y_pred.shape : (2617,)
# precision : 0.6666666666666666
# recall : 0.00816326530612245
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.67
# accum_pr increased ! : 0.000 --> 1.497
# thresh : 0.92057896
# y_pred.shape : (2617,)
# precision : 0.6428571428571429
# recall : 0.007346938775510204
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.64
# accum_pr increased ! : 0.000 --> 1.488
# thresh : 0.92464316
# y_pred.shape : (2617,)
# precision : 0.6153846153846154
# recall : 0.006530612244897959
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.62
# accum_pr increased ! : 0.000 --> 1.447
# thresh : 0.9253281
# y_pred.shape : (2617,)
# precision : 0.6666666666666666
# recall : 0.006530612244897959
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.67
# accum_pr increased ! : 0.000 --> 1.455
# thresh : 0.9285836
# y_pred.shape : (2617,)
# precision : 0.6363636363636364
# recall : 0.005714285714285714
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.64
# accum_pr increased ! : 0.000 --> 1.274
# thresh : 0.92928094
# y_pred.shape : (2617,)
# precision : 0.6
# recall : 0.004897959183673469
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.60
# accum_pr increased ! : 0.000 --> 1.224
# thresh : 0.9301474
# y_pred.shape : (2617,)
# precision : 0.5555555555555556
# recall : 0.004081632653061225
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.56
# accum_pr increased ! : 0.000 --> 1.183
# thresh : 0.9462906
# y_pred.shape : (2617,)
# precision : 0.5
# recall : 0.0032653061224489797
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.50
# accum_pr increased ! : 0.000 --> 1.108
# thresh : 0.94757
# y_pred.shape : (2617,)
# precision : 0.5714285714285714
# recall : 0.0032653061224489797
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.57
# accum_pr increased ! : 0.000 --> 1.117
# thresh : 0.9494166
# y_pred.shape : (2617,)
# precision : 0.6666666666666666
# recall : 0.0032653061224489797
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.67
# accum_pr increased ! : 0.000 --> 1.143
# thresh : 0.95548207
# y_pred.shape : (2617,)
# precision : 0.6
# recall : 0.0024489795918367346
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.60
# accum_pr increased ! : 0.000 --> 1.132
# thresh : 0.9580435
# y_pred.shape : (2617,)
# precision : 0.75
# recall : 0.0024489795918367346
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.75
# accum_pr increased ! : 0.000 --> 1.141
# thresh : 0.96287704
# y_pred.shape : (2617,)
# precision : 0.6666666666666666
# recall : 0.0016326530612244899
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 0.67
# accum_pr increased ! : 0.000 --> 1.130
# thresh : 0.97235006
# y_pred.shape : (2617,)
# precision : 1.0
# recall : 0.0016326530612244899
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 1.00
# accum_pr increased ! : 0.000 --> 1.153
# thresh : 0.97762156
# y_pred.shape : (2617,)
# precision : 1.0
# recall : 0.0008163265306122449
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> 1.00
# accum_pr increased ! : 0.000 --> 1.128
# thresh : 0.9778656
# y_pred.shape : (2617,)
# precision : 0.0
# recall : 0.0
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.47 --> nan
# accum_pr increased ! : 0.000 --> 1.000
# thresh : 0.97810215
# acc_pr_bythr : [0.081045695, 0.07517696, 0.07296708, 0.07579125, 0.079332255, 0.080083646, 0.087581635, 0.08622561, 0.09570452, 0.09660338, 0.097870454, 0.092871584, 0.093495876, 0.10245722, 0.10613641, 0.10703979, 0.11088094, 0.115701005, 0.122153334, 0.11959118, 0.11652216, 0.109208, 0.09106198, 0.09411298, 0.10506509, 0.09976038, 0.09790867, 0.12638299, 0.12826529, 0.13241263, 0.13197581, 0.13448782, 0.13146806, 0.13181445, 0.12854542, 0.179488, 0.19162965, 0.18306205, 0.18183255, 0.1869994, 0.20343995, 0.18868908, 0.19485573, 0.19827755, 0.19644037, 0.20268033, 0.202559, 0.21652706, 0.23526396, 0.24114689, 0.27601552, 0.26268196, 0.26281914, 0.26655337, 0.2908633, 0.30935204, 0.3072225, 0.30619705, 0.27676657, 0.29069838, 0.30008483, 0.28118235, 0.27576044, 0.29275247, 0.30459836, 0.3066021, 0.32109687, 0.31409281, 0.32069114, 0.324677, 0.31265092, 0.30041125, 0.3063391, 0.29679006, 0.296921, 0.30339172, 0.34269783, 0.40506086, 0.3720415, 0.37015352, 0.36680308, 0.34493458, 0.3478831, 0.321373, 0.26849124, 0.28458703, 0.29336733, 0.2947395, 0.28197408, 0.2719586, 0.26033422, 0.3109972, 0.35999742, 0.3681683, 0.37587246, 0.4754816, 0.48801774, 0.47579855, 0.514251, 0.52924, 0.5111644, 0.5287032, 0.53186244, 0.50256664, 0.54081076, 0.541776, 0.52276444, 0.53686994, 0.57330066, 0.6029802, 0.583843, 0.59680796, 0.61380094, 0.6738145, 0.67791766, 0.6976624, 0.7455396, 0.783068, 0.7879098, 0.7911282, 0.830345, 0.8528462, 0.8295432, 0.90815765, 0.89555246, 0.9622352, 0.9707342, 0.8979806, 1.0176487, 0.98456335, 0.9554818, 0.93402195, 0.78940904, 0.757622, 0.7628089, 0.7389263, 0.7928306, 0.85950327, 0.76712245, 0.75967956, 0.7791506, 0.74741495, 0.72974735, 0.7834381, 0.7622851, 0.7385431, 0.7222596, 0.68177336, 0.66359544, 0.644497, 0.65663016, 0.63335377, 0.62559205, 0.6031324, 0.6093543, 0.6446045, 0.66060734, 0.6817656, 0.6783147, 0.63696516, 0.6823174, 0.65782255, 0.6585512, 0.65583074, 0.658319, 0.71065795, 0.7377632, 0.70585144, 0.7165082, 0.7949663, 0.88492143, 0.7711011, 0.76610297, 0.75863266, 0.67267364, 0.6499085, 0.663967, 0.76209706, 0.76207405, 0.75715977, 0.80629045, 0.8390013, 0.7840091, 0.8140344, 0.8841092, 0.8885562, 0.70350003, 0.7212826, 0.6837155, 0.68779695, 0.73769623, 0.7218687, 0.6652813, 0.6641579, 0.67566365, 0.74017787, 0.71272594, 0.88741606, 0.97560644, 0.9864226, 0.9893903, 1.0652868, 1.0248924, 1.0629803, 1.056204, 1.103294, 1.1194348, 1.1339703, 1.1365912, 1.1087949, 1.1282634, 1.1402947, 1.135073, 1.1426895, 1.0690448, 1.1591651, 1.1342037, 1.0368401, 1.0695966, 1.1081169, 1.2002866, 1.1820589, 1.1928399, 1.132644, 1.2042738, 1.2801204, 1.1927843, 1.1554617, 1.1170743, 1.3059915, 1.4219702, 1.4055687, 1.4760844, 1.4672614, 1.4289759, 1.586935, 1.7286958, 1.8092887, 1.9194081, 1.9783987, 1.5623214, 1.3656063, 1.4223021, 1.3753637, 1.4171731, 1.4274502, 1.4248912, 1.4117543, 1.2817293, 1.2714498, 1.3994856, 1.5167253, 1.5857705, 1.5482206, 1.7000045, 1.7740009, 1.7363336, 1.8319725, 1.7036252, 1.6287867, 1.4966878, 1.4125177, 1.6478592, 1.7474445, 1.6995578, 1.6911513, 1.595461, 1.5802798, 1.5835553, 1.6454298, 1.5957353, 1.5911759, 1.7144816, 1.3774979, 1.6089777, 1.4709809, 1.5610043, 1.5406134, 1.557284, 1.5599394, 1.5534006, 1.5521773, 1.5246804, 1.3806288, 1.3750907, 1.4946383, 1.4650699, 1.681807, 1.6481559, 1.7050792, 1.7226597, 1.6620079, 1.5478112, 1.4079734, 1.4455017, 1.4244044, 1.396409, 1.3752948, 1.3171893, 1.2445493, 1.5456901, 1.4028594, 1.3307159, 1.2123728, 1.062432, 1.0754627, 1.0804174, 1.1937076, 1.1631538, 1.1820848, 1.1738302, 1.2744843, 1.2090813, 1.2623454, 1.2331125, 1.2102797, 1.2244794, 1.3162882, 1.4095854, 1.3025225, 1.2507695, 1.2571903, 1.4920617, 1.4124231, 1.4684526, 1.4142712, 1.5312265, 1.5221759, 1.5069512, 1.433075, 1.3796793, 1.4362097, 1.3917153, 1.3119367, 1.3912884, 1.3637441, 1.3603457, 1.4062843, 1.3987502, 1.2301137, 1.5727694, 1.5742745, 1.72645, 1.8076781, 1.875995, 1.7423084, 1.7792708, 1.9454584, 1.664506, 1.7123418, 1.6274424, 1.5740937, 1.6404063 ...
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:89: RuntimeWarning: invalid value encountered in long_scalars

# %%
plt.figure(figsize=(50, 5))
plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test):len(org_pr_test) + 10])
# plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test) - 10:len(org_pr_test) + 10])
plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
# plt.axvline(len(org_pr_test), linestyle='--', color='r')
plt.show()

# %%
# plt.show()
# plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
