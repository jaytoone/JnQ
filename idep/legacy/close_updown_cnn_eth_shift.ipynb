# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2
# !pip install vit-keras

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### load file list

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x
# from vit_keras import *
# from vit_keras.vit import *

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

# from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# from vit_keras import vit, utils


gdrive_path = current_path

num_classes = 2

# %% [markdown]
# ### vit model

# %%
image_shape = (45, 5, 3)

# model = build_model(
#         **CONFIG_B,
#         name="vit-b16",
#         patch_size=1,
#         image_shape=image_shape,
#         classes=num_classes,
#         activation="sigmoid",
#         include_top=False,
#     )

# print(CONFIG_B)

# %% [markdown]
# ### custom model

# %%
def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model

# %% [markdown]
# ### all in one loop

# %%
print(ohlcv['close'].pct_change(10).head(20))
print((ohlcv['close'] / ohlcv['close'].shift(10)).head(20) - 1)

# %%
from funcs_indicator import *
import matplotlib.pyplot as plt

# import mpl_finance as mf


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None


shift = 10

#           load saved npy & trained model        #
load_npy = False
load_model = False


seed = 1
random_state = 201
np.random.seed(seed)

fee = 0.0006
lvrg = 5

for i in range(len(candis)):

  keys = [candis[i]]

  if 'eth'.upper() not in candis[i]:
    continue

  # if 'comp'.upper() not in candis[i]:
  #   continue

  for key in keys:  
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))

        
    #       long      #
    pr = (ohlcv['close'].pct_change() - fee) * lvrg + 1    

    #       long liqudation     #
    lq = (ohlcv['low'] / ohlcv['close'].shift(1) - fee - 1) * lvrg + 1

    #       short       # <-- 이거를 단순히 minus 를 붙여도 되는걸까
    s_pr = (-ohlcv['close'].pct_change() - fee) * lvrg + 1

    #       short liqudation     #
    # s_lq = (ohlcv['high'] / ohlcv['close'].shift(1) - fee) * lvrg + 1
    

    #       fill na with 1.0      #
    # pr = np.where(np.isnan(pr), 1, pr)
    # print(len(pr))
    # print("len(pr[np.isnan(pr)]) :", len(pr[np.isnan(pr)]))
    # print("np.sum(np.isnan(pr)) :", np.sum(np.isnan(pr)))
    
    # sliced_ohlcv = ohlcv[np.sum(np.isnan(pr))]
    # print(sliced_ohlcv.head())
    # break
    # s_pr = np.where(np.isnan(s_pr), 1, pr)
    # lq = np.where(np.isnan(lq), 1, lq)


    #       set lq      #
    # pr = np.where((pr != 1) & (lq <= 0), 0, pr)

    # print("len(pr[pr < 0]) :", len(pr[pr < 0]))
    # break

    org_wr = len(pr[pr > 1]) / len(pr[pr != 1])

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(pr))
    plt.title("%s\norg_wr : %.3f\n acc_pr : %.3f" % (key, org_wr, np.cumprod(pr)[-1]))


    #                    strat                   #

    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) < ohlcv['close'].shift(3)), pr, 1)


    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
    #                     (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
    #                     (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)), pr, 1)


    strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
                        (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
                        (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
                        (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)) & 
                        (ohlcv['close'].shift(5) < ohlcv['close'].shift(6)), pr, 1)
    
    # strat_pr = np.where((ohlcv['high'].shift(2) > ohlcv['high'].shift(3))& 
    #                     (ohlcv['close'].shift(1) > ohlcv['close'].shift(2)), pr, 1)


    wr = len(strat_pr[strat_pr > 1]) / len(strat_pr[strat_pr != 1])

    plt.subplot(122)
    plt.plot(np.cumprod(strat_pr))
    plt.title("%s\norg_wr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr, np.cumprod(strat_pr)[-1]))


    # #                  sl cut                #
    # sl_line = ohlcv['low'].rolling(250).min().shift(1)
    # # sl_line = ohlcv['low'].shift(1)

    # strat_pr_sl = np.where((strat_pr != 1) & (sl_line > ohlcv['low']), 
    #                      1 + lvrg * (sl_line / ohlcv['close'].shift(1) - 1 - fee), strat_pr)


    # wr_sl = len(strat_pr_sl[strat_pr_sl > 1]) / len(strat_pr_sl[strat_pr_sl != 1])
    # # wl_pr_ratio = np.mean(strat_pr[strat_pr > 1]) / np.mean(strat_pr[strat_pr < 1])
    # # wl_pr_ratio = np.cumprod(strat_pr[strat_pr > 1])[-1] / np.cumprod(strat_pr[strat_pr < 1])[-1]

    # plt.subplot(122)
    # plt.plot(np.cumprod(strat_pr_sl))
    # plt.title("%s\norg_pr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr_sl, np.cumprod(strat_pr_sl)[-1]))


    plt.show()
    # break

    period = 45
    symbol_name = key.split(' ')[1].split('.')[0]      

    x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_shift_%s_%s_tssplit.npy' % (period, shift, symbol_name)
    pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_shift_%s_%s_tssplit.npy' % (period, shift, symbol_name)
    index_save_path = current_path + 'npy/' + '%s_cnn_updown_index_train_shift_%s_%s_tssplit.npy' % (period, shift, symbol_name)



    if not load_npy:

      from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
      from sklearn.model_selection import train_test_split
      from datetime import datetime

      from funcs_indicator import *

      def min_max_scale(npy_x):

        return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[np.sum(np.isnan(pr)):]

      sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

      #       scale with price    #
      ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

      ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
      sar = lucid_sar(sliced_ohlcv)
      ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
      senkou1, senkou2 = ichimoku(sliced_ohlcv)

      #     min max scale   #
      vol = ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]
      # vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

      pr_list = pr[np.sum(np.isnan(pr)):]
      print("len(ohlc) :", len(ohlc))
      print("len(pr_list) :", len(pr_list))

      # break


      #       set params    #
      period = 45
      key_i = i

      plotting = True

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(ohlc), shift):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          # temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

          temp_close = min_max_scale(temp_ohlc[:, [3]])    

          price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          ind_temp_ohlc = min_max_scale(temp_ohlc)
          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


          if plotting:

            plt.plot(ind_temp_ohlc)
            plt.show()
            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          #                   feature selection                   #        
          temp_data = np.hstack((ind_temp_ohlc, temp_vol))

          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          # temp_data = temp_ohlc[:, [3]]
          # temp_data = ind_temp_ohlc[:, [3]]
          # temp_data = temp_close

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      # input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)


      # _, row, col, _ = input_x.shape
      # _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      #                 don't shuffle timeseries data                 #
      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      # np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)


      np.save(x_save_path, x_train)
      np.save(x_save_path.replace('x_train', 'x_val'), x_val)
      np.save(x_save_path.replace('x_train', 'x_test'), x_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('x series saved !')

      np.save(pr_save_path, pr_train)
      np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
      np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
      # np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
      print('pr series saved !')
      
      np.save(index_save_path, index_train)
      np.save(index_save_path.replace('index_train', 'index_val'), index_val)
      np.save(index_save_path.replace('index_train', 'index_test'), index_test)
      print('index series saved !')

    else:
      
      x_train = np.load(x_save_path)
      x_val = np.load(x_save_path.replace('x_train', 'x_val'))
      x_test = np.load(x_save_path.replace('x_train', 'x_test'))
      print('x series loaded !')


      pr_train = np.load(pr_save_path)
      pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
      pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
      print('y series loaded !')


      index_train = np.load(index_save_path, allow_pickle=True)
      index_val = np.load(index_save_path.replace('index_train', 'index_val'), allow_pickle=True)
      index_test = np.load(index_save_path.replace('index_train', 'index_test'), allow_pickle=True)
      print('index series loaded !')




    #       pr_thresh by percentage 0.285     #
    plt.plot(pr)
    plt.show()
    
    # sorted_pr = sorted(pr, reverse=True)
    # pct = 0.28
    # len_pct = int(len(pr) * pct)
    # pr_thresh = sorted_pr[len_pct]
    # print("pr_thresh :", pr_thresh)

    pr_thresh = 1

    from keras.utils import np_utils

    # from keras.preprocessing.image import ImageDataGenerator 
    from sklearn.utils import class_weight


    def class_ratio(in_list):

      return in_list / in_list[1]
      
    y_train = np.where(pr_train > pr_thresh, 1, 0)
    y_test = np.where(pr_test > pr_thresh, 1, 0)
    y_val = np.where(pr_val > pr_thresh, 1, 0)

    print('x_train.shape :', x_train.shape)
    print('x_test.shape :', x_test.shape)
    print('x_val.shape :', x_val.shape)
    print('y_train.shape :', y_train.shape)
    print('y_test.shape :', y_test.shape)
    print('y_val.shape :', y_val.shape)

    # try:
    print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
    print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
    print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

    # except Exception as e:
      # print(e)

    label = y_train.reshape(-1, )
    class_weights = class_weight.compute_class_weight('balanced', 
                                                        classes=np.unique(label),
                                                        y=label)
    class_weights = dict(enumerate(class_weights))
    print('class_weights :', class_weights)

    # sample_weight = np.ones(shape=(len(y_train),))
    # sample_weight[(y_train == 1).reshape(-1,)] = 1.5
    # print('sample_weight[:20] :', sample_weight[:20])


    print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
    print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
    print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

    print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
    print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
    print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

    y_train_ohe = np_utils.to_categorical(y_train, num_classes)
    y_val_ohe = np_utils.to_categorical(y_val, num_classes)
    y_test_ohe = np_utils.to_categorical(y_test, num_classes)
    print('y_train_ohe.shape :', y_train_ohe.shape)
    print('y_val_ohe.shape :', y_val_ohe.shape)
    print('y_test_ohe.shape :', y_test_ohe.shape)

    from keras.preprocessing.image import ImageDataGenerator 

    datagen = ImageDataGenerator( 
        # rotation_range = 45,
        # zoom_range = 0.5,
        # shear_range = 0.5,
        # horizontal_flip = True,
        # vertical_flip = True,
        # width_shift_range=0.5,
        # height_shift_range=0.5,
        # fill_mode = 'nearest'
        )

    valgen = ImageDataGenerator( 
        )

    datagen.fit(x_train)
    valgen.fit(x_val)


    # batch_size = 512
    batch_size = 128


    for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

        plt.suptitle("train x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break

    for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

        plt.suptitle("val x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break
        
    train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
    val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
    # break

    

    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'

    # batch_size = 512

    K.clear_session()


    # model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)
    model_name = 'classifier_%s_cnn_updown_rascend_modvol_%s_%s_shift.h5' % (period, shift, symbol_name)



    if not load_model:

      from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard      
      
      # model = build_model(
      #         **CONFIG_B,
      #         name="vit-b16",
      #         patch_size=1,
      #         image_shape=x_train.shape[1:],
      #         classes=num_classes,
      #         activation="sigmoid",
      #         include_top=False,
      #     )

      model = FER_Model(input_shape=x_train.shape[1:])

      opt = Adam(learning_rate=1e-5, decay=5e-6)
      # opt = Adam(lr=0.001, decay=0.0005)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir=board_path,
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]
      # callbacks_list = [checkpoint, checkpoint2]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 1000
      history = model.fit(train_flow, 
                          steps_per_epoch=len(x_train) / batch_size, 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=val_flow,  
                          validation_steps=len(x_val) / batch_size,
                          shuffle=False)
      
    
    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'


    model = keras.models.load_model(ckpt_path + model_name)

    test_result = model.predict(x_test)
    # test_result = model.predict(test_set)

    print('test_result.shape :', test_result.shape)
    # print('pr_val.shape :', pr_val.shape)

    y_score = test_result[:, [1]]
    print('y_test[:5] :', y_test.reshape(-1,)[:5])
    # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
    print('y_score[:5] :', y_score[:5])
    # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

    print('y_test.shape :', y_test.shape)
    print('y_score.shape :', y_score.shape)

    print('len(y_test) :', len(y_test))

    #     precision recall curve   #
    precision, recall, threshold = precision_recall_curve(y_test, y_score)
    precision, recall = precision[:-1], recall[:-1]

    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    plt.show()
    # print(y_pred)


    # threshold = [0.65]
    # print('threshold :', threshold)
    # break

    acc_pr_bythr = []
    new_thresh = []

    for thresh in threshold:
      
      # if thresh < 0.5:
      #     continue

      y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
      # print('y_pred.shape :', y_pred.shape)
      # print('y_pred :', y_pred)

      #     compare precision     #

      # print('precision :', precision_score(y_test, y_pred))
      # print('recall :', recall_score(y_test, y_pred))
      # print()

      # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
      # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

      # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
      # # plt.show()  
      # print()

      #     check win-ratio improvement     #
      cmat = confusion_matrix(y_test, y_pred)
      # print(cmat)
      # print(np.sum(cmat, axis=1))

      test_size = len(y_test)
      test_pr_list = pr_test
      # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

      org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
      ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
      # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

      # print('pr_test.shape :', pr_test.shape)

      # print(y_pred)
      # print(test_pr_list)

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
      # print('pred_pr_list.shape :', pred_pr_list.shape)

      # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
      #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
      #   print('thresh :', thresh)
        
      # if len(threshold) == 1:
    #   plt.figure(figsize=(10, 5))
    #   plt.subplot(121)
    #   plt.plot(np.cumprod(test_pr_list))
    #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
    # # plt.show()

    #   plt.subplot(122)
    #   plt.plot(np.cumprod(pred_pr_list))
    #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
    #   plt.show()


      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)


    print('acc_pr_bythr :', acc_pr_bythr)

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    # plt.show()
    plt.subplot(122)
    plt.plot(new_thresh, acc_pr_bythr)
    plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
    plt.title(symbol_name)
    plt.show()
# Out:
# start_stamp : 0
# len(ohlcv) : 18048
# len(ohlc) : 18047
# len(pr_list) : 18047
# np.array(data_x).shape : (1793, 45, 5)
# input_x.shape : (1793, 45, 5, 3)
# input_x.dtype : float32
# input_pr.shape : (1793, 1)
# input_ud.shape : (1793, 1)
# input_index.shape : (1793, 1)
# total_x.shape : (1793, 45, 5, 3)
# total_pr.shape : (1793, 1)
# total_ud.shape : (1793, 1)
# prev_index.shape : (1793, 1)
# (array([Timestamp('2020-04-19 15:29:59.999000'),
#        Timestamp('2020-04-19 20:29:59.999000'),
#        Timestamp('2020-04-20 01:29:59.999000'), ...,
#        Timestamp('2021-04-27 13:29:59.999000'),
#        Timestamp('2021-04-27 18:29:59.999000'),
#        Timestamp('2021-04-27 23:29:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (1075,)
# stamp_val.shape : (359,)
# stamp_test.shape : (359,)
# HBox(children=(FloatProgress(value=0.0, max=1793.0), HTML(value='')))
# x_train.shape : (1075, 45, 5, 3)
# x_val.shape : (359, 45, 5, 3)
# x_test.shape : (359, 45, 5, 3)
# x series saved !
# pr series saved !
# index series saved !
# x_train.shape : (1075, 45, 5, 3)
# x_test.shape : (359, 45, 5, 3)
# x_val.shape : (359, 45, 5, 3)
# y_train.shape : (1075, 1)
# y_test.shape : (359, 1)
# y_val.shape : (359, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([598, 477])) [1.25366876 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([193, 166])) [1.1626506 1.       ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([196, 163])) [1.20245399 1.        ]
# class_weights : {0: 0.8988294314381271, 1: 1.1268343815513626}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (1075, 2)
# y_val_ohe.shape : (359, 2)
# y_test_ohe.shape : (359, 2)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/1000
# 8/8 - 70s - loss: 0.8533 - accuracy: 0.5014 - val_loss: 0.7240 - val_accuracy: 0.5376
#
# Epoch 00001: val_loss improved from inf to 0.72398, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_modvol_10_ETHUSDT_shift.h5
# Epoch 2/1000
# 8/8 - 0s - loss: 0.7056 - accuracy: 0.5079 - val_loss: 0.7103 - val_accuracy: 0.4708
#
# Epoch 00002: val_loss improved from 0.72398 to 0.71028, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_modvol_10_ETHUSDT_shift.h5
# Epoch 3/1000
# 8/8 - 0s - loss: 0.6924 - accuracy: 0.5340 - val_loss: 0.7037 - val_accuracy: 0.4847
#
# Epoch 00003: val_loss improved from 0.71028 to 0.70368, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_modvol_10_ETHUSDT_shift.h5
# Epoch 4/1000
# 8/8 - 0s - loss: 0.6875 - accuracy: 0.5153 - val_loss: 0.6964 - val_accuracy: 0.5070
#
# Epoch 00004: val_loss improved from 0.70368 to 0.69636, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_modvol_10_ETHUSDT_shift.h5
# Epoch 5/1000
# 8/8 - 0s - loss: 0.6817 - accuracy: 0.5479 - val_loss: 0.7040 - val_accuracy: 0.5042
#
# Epoch 00005: val_loss did not improve from 0.69636
# Epoch 6/1000
# 8/8 - 0s - loss: 0.6824 - accuracy: 0.5488 - val_loss: 0.7026 - val_accuracy: 0.4930
#
# Epoch 00006: val_loss did not improve from 0.69636
# Epoch 7/1000
# 8/8 - 0s - loss: 0.6873 - accuracy: 0.5386 - val_loss: 0.7168 - val_accuracy: 0.5376
#
# Epoch 00007: val_loss did not improve from 0.69636
# Epoch 8/1000
# 8/8 - 0s - loss: 0.6810 - accuracy: 0.5712 - val_loss: 0.7253 - val_accuracy: 0.4596
#
# Epoch 00008: val_loss did not improve from 0.69636
# Epoch 9/1000
# 8/8 - 1s - loss: 0.6745 - accuracy: 0.5712 - val_loss: 0.6955 - val_accuracy: 0.5543
#
# Epoch 00009: val_loss improved from 0.69636 to 0.69553, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_modvol_10_ETHUSDT_shift.h5
# Epoch 10/1000
# 8/8 - 0s - loss: 0.6674 - accuracy: 0.5898 - val_loss: 0.6960 - val_accuracy: 0.5460
#
# Epoch 00010: val_loss did not improve from 0.69553
# Epoch 11/1000
# 8/8 - 0s - loss: 0.6628 - accuracy: 0.5963 - val_loss: 0.6977 - val_accuracy: 0.5209
#
# Epoch 00011: val_loss did not improve from 0.69553
# Epoch 12/1000
# 8/8 - 0s - loss: 0.6628 - accuracy: 0.6093 - val_loss: 0.7623 - val_accuracy: 0.4568
#
# Epoch 00012: val_loss did not improve from 0.69553
# Epoch 13/1000
# 8/8 - 0s - loss: 0.6744 - accuracy: 0.5842 - val_loss: 0.6976 - val_accuracy: 0.5404
#
# Epoch 00013: val_loss did not improve from 0.69553
# Epoch 14/1000
# 8/8 - 0s - loss: 0.6613 - accuracy: 0.5721 - val_loss: 0.6976 - val_accuracy: 0.5432
#
# Epoch 00014: val_loss did not improve from 0.69553
# Epoch 15/1000
# 8/8 - 1s - loss: 0.6574 - accuracy: 0.6000 - val_loss: 0.7140 - val_accuracy: 0.5042
#
# Epoch 00015: val_loss did not improve from 0.69553
# Epoch 16/1000
# 8/8 - 0s - loss: 0.6521 - accuracy: 0.6195 - val_loss: 0.7027 - val_accuracy: 0.5209
#
# Epoch 00016: val_loss did not improve from 0.69553
# Epoch 17/1000
# 8/8 - 0s - loss: 0.6528 - accuracy: 0.6074 - val_loss: 0.6999 - val_accuracy: 0.5265
#
# Epoch 00017: val_loss did not improve from 0.69553
# Epoch 18/1000
# 8/8 - 0s - loss: 0.6700 - accuracy: 0.5879 - val_loss: 0.7028 - val_accuracy: 0.5265
#
# Epoch 00018: val_loss did not improve from 0.69553
# Epoch 19/1000
# 8/8 - 0s - loss: 0.6732 - accuracy: 0.5786 - val_loss: 0.7007 - val_accuracy: 0.5237
#
# Epoch 00019: val_loss did not improve from 0.69553
# Epoch 20/1000
# 8/8 - 0s - loss: 0.6548 - accuracy: 0.6260 - val_loss: 0.7028 - val_accuracy: 0.5320
#
# Epoch 00020: val_loss did not improve from 0.69553
# Epoch 21/1000
# 8/8 - 0s - loss: 0.6437 - accuracy: 0.6400 - val_loss: 0.6990 - val_accuracy: 0.5432
#
# Epoch 00021: val_loss did not improve from 0.69553
# Epoch 22/1000
# 8/8 - 0s - loss: 0.6462 - accuracy: 0.6484 - val_loss: 0.7001 - val_accuracy: 0.5432
#
# Epoch 00022: val_loss did not improve from 0.69553
# Epoch 23/1000
# 8/8 - 0s - loss: 0.6393 - accuracy: 0.6419 - val_loss: 0.7407 - val_accuracy: 0.4930
#
# Epoch 00023: val_loss did not improve from 0.69553
# Epoch 24/1000
# 8/8 - 0s - loss: 0.6422 - accuracy: 0.6391 - val_loss: 0.7560 - val_accuracy: 0.4847
#
# Epoch 00024: val_loss did not improve from 0.69553
# Epoch 25/1000
# 8/8 - 0s - loss: 0.6379 - accuracy: 0.6242 - val_loss: 0.7051 - val_accuracy: 0.5181
#
# Epoch 00025: val_loss did not improve from 0.69553
# Epoch 26/1000
# 8/8 - 0s - loss: 0.6308 - accuracy: 0.6567 - val_loss: 0.7112 - val_accuracy: 0.5209
#
# Epoch 00026: val_loss did not improve from 0.69553
# Epoch 27/1000
# 8/8 - 0s - loss: 0.6307 - accuracy: 0.6484 - val_loss: 0.7127 - val_accuracy: 0.5292
#
# Epoch 00027: val_loss did not improve from 0.69553
# Epoch 28/1000
# 8/8 - 0s - loss: 0.6362 - accuracy: 0.6251 - val_loss: 0.7074 - val_accuracy: 0.5181
#
# Epoch 00028: val_loss did not improve from 0.69553
# Epoch 29/1000
# 8/8 - 0s - loss: 0.6272 - accuracy: 0.6530 - val_loss: 0.7145 - val_accuracy: 0.5181
#
# Epoch 00029: val_loss did not improve from 0.69553
# Epoch 30/1000
# 8/8 - 0s - loss: 0.6247 - accuracy: 0.6698 - val_loss: 0.7238 - val_accuracy: 0.5097
#
# Epoch 00030: val_loss did not improve from 0.69553
# Epoch 31/1000
# 8/8 - 0s - loss: 0.6287 - accuracy: 0.6456 - val_loss: 0.7084 - val_accuracy: 0.5237
#
# Epoch 00031: val_loss did not improve from 0.69553
# Epoch 32/1000
# 8/8 - 0s - loss: 0.6255 - accuracy: 0.6558 - val_loss: 0.7120 - val_accuracy: 0.5153
#
# Epoch 00032: val_loss did not improve from 0.69553
# Epoch 33/1000
# 8/8 - 0s - loss: 0.6348 - accuracy: 0.6363 - val_loss: 0.7233 - val_accuracy: 0.5042
#
# Epoch 00033: val_loss did not improve from 0.69553
# Epoch 34/1000
# 8/8 - 0s - loss: 0.6247 - accuracy: 0.6651 - val_loss: 0.7366 - val_accuracy: 0.5097
#
# Epoch 00034: val_loss did not improve from 0.69553
# Epoch 35/1000
# 8/8 - 0s - loss: 0.6168 - accuracy: 0.6679 - val_loss: 0.7276 - val_accuracy: 0.5181
#
# Epoch 00035: val_loss did not improve from 0.69553
# Epoch 36/1000
# 8/8 - 0s - loss: 0.6136 - accuracy: 0.6726 - val_loss: 0.7230 - val_accuracy: 0.5209
#
# Epoch 00036: val_loss did not improve from 0.69553
# Epoch 37/1000
# 8/8 - 0s - loss: 0.6126 - accuracy: 0.6772 - val_loss: 0.7122 - val_accuracy: 0.5237
#
# Epoch 00037: val_loss did not improve from 0.69553
# Epoch 38/1000
# 8/8 - 0s - loss: 0.6093 - accuracy: 0.6688 - val_loss: 0.7326 - val_accuracy: 0.5153
#
# Epoch 00038: val_loss did not improve from 0.69553
# Epoch 39/1000
# 8/8 - 0s - loss: 0.6070 - accuracy: 0.6679 - val_loss: 0.7549 - val_accuracy: 0.4986
#
# Epoch 00039: val_loss did not improve from 0.69553
# Epoch 40/1000
# 8/8 - 0s - loss: 0.6064 - accuracy: 0.6809 - val_loss: 0.7393 - val_accuracy: 0.5070
#
# Epoch 00040: val_loss did not improve from 0.69553
# Epoch 41/1000
# 8/8 - 0s - loss: 0.6075 - accuracy: 0.6688 - val_loss: 0.7569 - val_accuracy: 0.4930
#
# Epoch 00041: val_loss did not improve from 0.69553
# Epoch 42/1000
# 8/8 - 0s - loss: 0.6148 - accuracy: 0.6521 - val_loss: 0.7941 - val_accuracy: 0.4847
#
# Epoch 00042: val_loss did not improve from 0.69553
# Epoch 43/1000
# 8/8 - 0s - loss: 0.6192 - accuracy: 0.6447 - val_loss: 0.7253 - val_accuracy: 0.5153
#
# Epoch 00043: val_loss did not improve from 0.69553
# Epoch 44/1000
# 8/8 - 0s - loss: 0.6148 - accuracy: 0.6447 - val_loss: 0.7199 - val_accuracy: 0.5237
#
# Epoch 00044: val_loss did not improve from 0.69553
# Epoch 45/1000
# 8/8 - 0s - loss: 0.6076 - accuracy: 0.6688 - val_loss: 0.7215 - val_accuracy: 0.5292
#
# Epoch 00045: val_loss did not improve from 0.69553
# Epoch 46/1000
# 8/8 - 0s - loss: 0.6115 - accuracy: 0.6660 - val_loss: 0.7210 - val_accuracy: 0.5181
#
# Epoch 00046: val_loss did not improve from 0.69553
# Epoch 47/1000
# 8/8 - 0s - loss: 0.5917 - accuracy: 0.7014 - val_loss: 0.7217 - val_accuracy: 0.5292
#
# Epoch 00047: val_loss did not improve from 0.69553
# Epoch 48/1000
# 8/8 - 0s - loss: 0.5913 - accuracy: 0.7023 - val_loss: 0.7406 - val_accuracy: 0.5237
#
# Epoch 00048: val_loss did not improve from 0.69553
# Epoch 49/1000
# 8/8 - 0s - loss: 0.5924 - accuracy: 0.6921 - val_loss: 0.7454 - val_accuracy: 0.5014
#
# Epoch 00049: val_loss did not improve from 0.69553
# Epoch 50/1000
# 8/8 - 0s - loss: 0.5943 - accuracy: 0.6837 - val_loss: 0.7746 - val_accuracy: 0.4930
#
# Epoch 00050: val_loss did not improve from 0.69553
# Epoch 51/1000
# 8/8 - 0s - loss: 0.5921 - accuracy: 0.6967 - val_loss: 0.7468 - val_accuracy: 0.4875
#
# Epoch 00051: val_loss did not improve from 0.69553
# Epoch 52/1000
# 8/8 - 0s - loss: 0.5822 - accuracy: 0.7219 - val_loss: 0.7740 - val_accuracy: 0.5125
#
# Epoch 00052: val_loss did not improve from 0.69553
# Epoch 53/1000
# 8/8 - 0s - loss: 0.5892 - accuracy: 0.6884 - val_loss: 0.7488 - val_accuracy: 0.5097
#
# Epoch 00053: val_loss did not improve from 0.69553
# Epoch 54/1000
# 8/8 - 0s - loss: 0.5759 - accuracy: 0.7172 - val_loss: 0.7334 - val_accuracy: 0.5265
#
# Epoch 00054: val_loss did not improve from 0.69553
# Epoch 55/1000
# 8/8 - 0s - loss: 0.5744 - accuracy: 0.7107 - val_loss: 0.7358 - val_accuracy: 0.5181
#
# Epoch 00055: val_loss did not improve from 0.69553
# Epoch 56/1000
# 8/8 - 0s - loss: 0.5744 - accuracy: 0.7181 - val_loss: 0.7386 - val_accuracy: 0.5209
#
# Epoch 00056: val_loss did not improve from 0.69553
# Epoch 57/1000
# 8/8 - 0s - loss: 0.5718 - accuracy: 0.7219 - val_loss: 0.7350 - val_accuracy: 0.5181
#
# Epoch 00057: val_loss did not improve from 0.69553
# Epoch 58/1000
# 8/8 - 0s - loss: 0.5693 - accuracy: 0.7200 - val_loss: 0.7418 - val_accuracy: 0.5265
#
# Epoch 00058: val_loss did not improve from 0.69553
# Epoch 59/1000
# 8/8 - 0s - loss: 0.5674 - accuracy: 0.7228 - val_loss: 0.7334 - val_accuracy: 0.5042
#
# Epoch 00059: val_loss did not improve from 0.69553
# Epoch 60/1000
# 8/8 - 0s - loss: 0.5658 - accuracy: 0.7274 - val_loss: 0.7430 - val_accuracy: 0.5209
#
# Epoch 00060: val_loss did not improve from 0.69553
# Epoch 61/1000
# 8/8 - 0s - loss: 0.5676 - accuracy: 0.7088 - val_loss: 0.7486 - val_accuracy: 0.5153
#
# Epoch 00061: val_loss did not improve from 0.69553
# Epoch 62/1000
# 8/8 - 0s - loss: 0.5566 - accuracy: 0.7367 - val_loss: 0.7411 - val_accuracy: 0.5209
#
# Epoch 00062: val_loss did not improve from 0.69553
# Epoch 63/1000
# 8/8 - 0s - loss: 0.5644 - accuracy: 0.7237 - val_loss: 0.7328 - val_accuracy: 0.5209
#
# Epoch 00063: val_loss did not improve from 0.69553
# Epoch 64/1000
# 8/8 - 0s - loss: 0.5732 - accuracy: 0.7200 - val_loss: 0.7331 - val_accuracy: 0.5487
#
# Epoch 00064: val_loss did not improve from 0.69553
# Epoch 65/1000
# 8/8 - 0s - loss: 0.5699 - accuracy: 0.7107 - val_loss: 0.7403 - val_accuracy: 0.5042
#
# Epoch 00065: val_loss did not improve from 0.69553
# Epoch 66/1000
# 8/8 - 0s - loss: 0.5610 - accuracy: 0.7191 - val_loss: 0.7373 - val_accuracy: 0.5348
#
# Epoch 00066: val_loss did not improve from 0.69553
# Epoch 67/1000
# 8/8 - 0s - loss: 0.5559 - accuracy: 0.7302 - val_loss: 0.7598 - val_accuracy: 0.5097
#
# Epoch 00067: val_loss did not improve from 0.69553
# Epoch 68/1000
# 8/8 - 0s - loss: 0.5485 - accuracy: 0.7367 - val_loss: 0.7385 - val_accuracy: 0.5376
#
# Epoch 00068: val_loss did not improve from 0.69553
# Epoch 69/1000
# 8/8 - 0s - loss: 0.5492 - accuracy: 0.7340 - val_loss: 0.7662 - val_accuracy: 0.5153
#
# Epoch 00069: val_loss did not improve from 0.69553
# Epoch 70/1000
# 8/8 - 0s - loss: 0.5480 - accuracy: 0.7442 - val_loss: 0.7468 - val_accuracy: 0.5265
#
# Epoch 00070: val_loss did not improve from 0.69553
# Epoch 71/1000
# 8/8 - 0s - loss: 0.5411 - accuracy: 0.7516 - val_loss: 0.7428 - val_accuracy: 0.5292
#
# Epoch 00071: val_loss did not improve from 0.69553
# Epoch 72/1000
# 8/8 - 0s - loss: 0.5377 - accuracy: 0.7572 - val_loss: 0.7392 - val_accuracy: 0.5292
#
# Epoch 00072: val_loss did not improve from 0.69553
# Epoch 73/1000
# 8/8 - 0s - loss: 0.5357 - accuracy: 0.7600 - val_loss: 0.7513 - val_accuracy: 0.5292
#
# Epoch 00073: val_loss did not improve from 0.69553
# Epoch 74/1000
# 8/8 - 0s - loss: 0.5411 - accuracy: 0.7414 - val_loss: 0.7457 - val_accuracy: 0.5237
#
# Epoch 00074: val_loss did not improve from 0.69553
# Epoch 75/1000
# 8/8 - 0s - loss: 0.5304 - accuracy: 0.7647 - val_loss: 0.7413 - val_accuracy: 0.5237
#
# Epoch 00075: val_loss did not improve from 0.69553
# Epoch 76/1000
# 8/8 - 0s - loss: 0.5305 - accuracy: 0.7591 - val_loss: 0.7682 - val_accuracy: 0.5153
#
# Epoch 00076: val_loss did not improve from 0.69553
# Epoch 77/1000
# 8/8 - 0s - loss: 0.5379 - accuracy: 0.7386 - val_loss: 0.7469 - val_accuracy: 0.5292
#
# Epoch 00077: val_loss did not improve from 0.69553
# Epoch 78/1000
# 8/8 - 0s - loss: 0.5345 - accuracy: 0.7414 - val_loss: 0.7523 - val_accuracy: 0.5404
#
# Epoch 00078: val_loss did not improve from 0.69553
# Epoch 79/1000
# 8/8 - 0s - loss: 0.5272 - accuracy: 0.7609 - val_loss: 0.7450 - val_accuracy: 0.5292
#
# Epoch 00079: val_loss did not improve from 0.69553
# Epoch 80/1000
# 8/8 - 0s - loss: 0.5217 - accuracy: 0.7712 - val_loss: 0.7625 - val_accuracy: 0.5348
#
# Epoch 00080: val_loss did not improve from 0.69553
# Epoch 81/1000
# 8/8 - 0s - loss: 0.5310 - accuracy: 0.7507 - val_loss: 0.7673 - val_accuracy: 0.5320
#
# Epoch 00081: val_loss did not improve from 0.69553
# Epoch 82/1000
# 8/8 - 0s - loss: 0.5237 - accuracy: 0.7619 - val_loss: 0.7647 - val_accuracy: 0.5460
#
# Epoch 00082: val_loss did not improve from 0.69553
# Epoch 83/1000
# 8/8 - 0s - loss: 0.5213 - accuracy: 0.7526 - val_loss: 0.7639 - val_accuracy: 0.5209
#
# Epoch 00083: val_loss did not improve from 0.69553
# Epoch 84/1000
# 8/8 - 0s - loss: 0.5177 - accuracy: 0.7684 - val_loss: 0.7800 - val_accuracy: 0.5209
#
# Epoch 00084: val_loss did not improve from 0.69553
# Epoch 85/1000
# 8/8 - 0s - loss: 0.5119 - accuracy: 0.7628 - val_loss: 0.8056 - val_accuracy: 0.5042
#
# Epoch 00085: val_loss did not improve from 0.69553
# Epoch 86/1000
# 8/8 - 0s - loss: 0.5276 - accuracy: 0.7470 - val_loss: 0.8187 - val_accuracy: 0.4875
#
# Epoch 00086: val_loss did not improve from 0.69553
# Epoch 87/1000
# 8/8 - 0s - loss: 0.5178 - accuracy: 0.7553 - val_loss: 0.7505 - val_accuracy: 0.5320
#
# Epoch 00087: val_loss did not improve from 0.69553
# Epoch 88/1000
# 8/8 - 0s - loss: 0.5081 - accuracy: 0.7870 - val_loss: 0.7628 - val_accuracy: 0.5348
#
# Epoch 00088: val_loss did not improve from 0.69553
# Epoch 89/1000
# 8/8 - 0s - loss: 0.5100 - accuracy: 0.7637 - val_loss: 0.7706 - val_accuracy: 0.5320
#
# Epoch 00089: val_loss did not improve from 0.69553
# Epoch 90/1000
# 8/8 - 0s - loss: 0.5024 - accuracy: 0.7842 - val_loss: 0.7602 - val_accuracy: 0.5265
#
# Epoch 00090: val_loss did not improve from 0.69553
# Epoch 91/1000
# 8/8 - 0s - loss: 0.5003 - accuracy: 0.7879 - val_loss: 0.7663 - val_accuracy: 0.5320
#
# Epoch 00091: val_loss did not improve from 0.69553
# Epoch 92/1000
# 8/8 - 0s - loss: 0.4991 - accuracy: 0.7712 - val_loss: 0.7706 - val_accuracy: 0.5292
#
# Epoch 00092: val_loss did not improve from 0.69553
# Epoch 93/1000
# 8/8 - 0s - loss: 0.4982 - accuracy: 0.7702 - val_loss: 0.7636 - val_accuracy: 0.5153
#
# Epoch 00093: val_loss did not improve from 0.69553
# Epoch 94/1000
# 8/8 - 0s - loss: 0.5066 - accuracy: 0.7628 - val_loss: 0.7645 - val_accuracy: 0.5348
#
# Epoch 00094: val_loss did not improve from 0.69553
# Epoch 95/1000
# 8/8 - 0s - loss: 0.5032 - accuracy: 0.7870 - val_loss: 0.7702 - val_accuracy: 0.5153
#
# Epoch 00095: val_loss did not improve from 0.69553
# Epoch 96/1000
# 8/8 - 0s - loss: 0.4974 - accuracy: 0.7749 - val_loss: 0.7785 - val_accuracy: 0.5487
#
# Epoch 00096: val_loss did not improve from 0.69553
# Epoch 97/1000
# 8/8 - 0s - loss: 0.4843 - accuracy: 0.7953 - val_loss: 0.7993 - val_accuracy: 0.5125
#
# Epoch 00097: val_loss did not improve from 0.69553
# Epoch 98/1000
# 8/8 - 0s - loss: 0.4870 - accuracy: 0.7823 - val_loss: 0.7690 - val_accuracy: 0.5237
#
# Epoch 00098: val_loss did not improve from 0.69553
# Epoch 99/1000
# 8/8 - 0s - loss: 0.4858 - accuracy: 0.7963 - val_loss: 0.7866 - val_accuracy: 0.5348
#
# Epoch 00099: val_loss did not improve from 0.69553
# Epoch 100/1000
# 8/8 - 0s - loss: 0.4847 - accuracy: 0.7842 - val_loss: 0.8297 - val_accuracy: 0.5070
#
# Epoch 00100: val_loss did not improve from 0.69553
# Epoch 101/1000
# 8/8 - 0s - loss: 0.4942 - accuracy: 0.7888 - val_loss: 0.7686 - val_accuracy: 0.5265
#
# Epoch 00101: val_loss did not improve from 0.69553
# Epoch 102/1000
# 8/8 - 0s - loss: 0.4787 - accuracy: 0.8047 - val_loss: 0.7792 - val_accuracy: 0.5292
#
# Epoch 00102: val_loss did not improve from 0.69553
# Epoch 103/1000
# 8/8 - 0s - loss: 0.4788 - accuracy: 0.7935 - val_loss: 0.7737 - val_accuracy: 0.5320
#
# Epoch 00103: val_loss did not improve from 0.69553
# Epoch 104/1000
# 8/8 - 0s - loss: 0.4955 - accuracy: 0.7665 - val_loss: 0.8123 - val_accuracy: 0.5097
#
# Epoch 00104: val_loss did not improve from 0.69553
# Epoch 105/1000
# 8/8 - 0s - loss: 0.4962 - accuracy: 0.7628 - val_loss: 0.8096 - val_accuracy: 0.5320
#
# Epoch 00105: val_loss did not improve from 0.69553
# Epoch 106/1000
# 8/8 - 0s - loss: 0.4872 - accuracy: 0.7907 - val_loss: 0.7869 - val_accuracy: 0.5209
#
# Epoch 00106: val_loss did not improve from 0.69553
# Epoch 107/1000
# 8/8 - 0s - loss: 0.4943 - accuracy: 0.7926 - val_loss: 0.8044 - val_accuracy: 0.5097
#
# Epoch 00107: val_loss did not improve from 0.69553
# Epoch 108/1000
# 8/8 - 0s - loss: 0.4687 - accuracy: 0.8009 - val_loss: 0.7801 - val_accuracy: 0.5376
#
# Epoch 00108: val_loss did not improve from 0.69553
# Epoch 109/1000
# 8/8 - 0s - loss: 0.4617 - accuracy: 0.8056 - val_loss: 0.7829 - val_accuracy: 0.5125
#
# Epoch 00109: val_loss did not improve from 0.69553
# Epoch 110/1000
# 8/8 - 0s - loss: 0.4538 - accuracy: 0.8177 - val_loss: 0.7953 - val_accuracy: 0.5070
#
# Epoch 00110: val_loss did not improve from 0.69553
# Epoch 111/1000
# 8/8 - 0s - loss: 0.4763 - accuracy: 0.7786 - val_loss: 0.7860 - val_accuracy: 0.5292
#
# Epoch 00111: val_loss did not improve from 0.69553
# Epoch 112/1000
# 8/8 - 0s - loss: 0.4765 - accuracy: 0.7823 - val_loss: 0.7966 - val_accuracy: 0.5209
#
# Epoch 00112: val_loss did not improve from 0.69553
# Epoch 113/1000
# 8/8 - 0s - loss: 0.4647 - accuracy: 0.7851 - val_loss: 0.8357 - val_accuracy: 0.5125
#
# Epoch 00113: val_loss did not improve from 0.69553
# Epoch 114/1000
# 8/8 - 0s - loss: 0.4698 - accuracy: 0.7981 - val_loss: 0.8190 - val_accuracy: 0.5209
#
# Epoch 00114: val_loss did not improve from 0.69553
# Epoch 115/1000
# 8/8 - 0s - loss: 0.4648 - accuracy: 0.8028 - val_loss: 0.8613 - val_accuracy: 0.5042
#
# Epoch 00115: val_loss did not improve from 0.69553
# Epoch 116/1000
# 8/8 - 0s - loss: 0.4702 - accuracy: 0.7963 - val_loss: 0.7881 - val_accuracy: 0.5153
#
# Epoch 00116: val_loss did not improve from 0.69553
# Epoch 117/1000
# 8/8 - 0s - loss: 0.4553 - accuracy: 0.8149 - val_loss: 0.7899 - val_accuracy: 0.5097
#
# Epoch 00117: val_loss did not improve from 0.69553
# Epoch 118/1000
# 8/8 - 0s - loss: 0.4545 - accuracy: 0.8102 - val_loss: 0.7921 - val_accuracy: 0.5209
#
# Epoch 00118: val_loss did not improve from 0.69553
# Epoch 119/1000
# 8/8 - 0s - loss: 0.4460 - accuracy: 0.8288 - val_loss: 0.8220 - val_accuracy: 0.5320
#
# Epoch 00119: val_loss did not improve from 0.69553
# Epoch 120/1000
# 8/8 - 0s - loss: 0.4535 - accuracy: 0.8130 - val_loss: 0.8010 - val_accuracy: 0.5070
#
# Epoch 00120: val_loss did not improve from 0.69553
# Epoch 121/1000
# 8/8 - 0s - loss: 0.4405 - accuracy: 0.8409 - val_loss: 0.7964 - val_accuracy: 0.5153
#
# Epoch 00121: val_loss did not improve from 0.69553
# Epoch 122/1000
# 8/8 - 0s - loss: 0.4421 - accuracy: 0.8298 - val_loss: 0.8019 - val_accuracy: 0.5209
#
# Epoch 00122: val_loss did not improve from 0.69553
# Epoch 123/1000
# 8/8 - 0s - loss: 0.4474 - accuracy: 0.8121 - val_loss: 0.8027 - val_accuracy: 0.5181
#
# Epoch 00123: val_loss did not improve from 0.69553
# Epoch 124/1000
# 8/8 - 0s - loss: 0.4321 - accuracy: 0.8428 - val_loss: 0.8081 - val_accuracy: 0.5153
#
# Epoch 00124: val_loss did not improve from 0.69553
# Epoch 125/1000
# 8/8 - 0s - loss: 0.4297 - accuracy: 0.8474 - val_loss: 0.8036 - val_accuracy: 0.5209
#
# Epoch 00125: val_loss did not improve from 0.69553
# Epoch 126/1000
# 8/8 - 0s - loss: 0.4223 - accuracy: 0.8428 - val_loss: 0.8022 - val_accuracy: 0.5125
#
# Epoch 00126: val_loss did not improve from 0.69553
# Epoch 127/1000
# 8/8 - 0s - loss: 0.4389 - accuracy: 0.8195 - val_loss: 0.8019 - val_accuracy: 0.5209
#
# Epoch 00127: val_loss did not improve from 0.69553
# Epoch 128/1000
# 8/8 - 0s - loss: 0.4261 - accuracy: 0.8344 - val_loss: 0.8292 - val_accuracy: 0.5014
#
# Epoch 00128: val_loss did not improve from 0.69553
# Epoch 129/1000
# 8/8 - 0s - loss: 0.4244 - accuracy: 0.8363 - val_loss: 0.7974 - val_accuracy: 0.5237
#
# Epoch 00129: val_loss did not improve from 0.69553
# Epoch 130/1000
# 8/8 - 0s - loss: 0.4146 - accuracy: 0.8558 - val_loss: 0.8012 - val_accuracy: 0.5209
#
# Epoch 00130: val_loss did not improve from 0.69553
# Epoch 131/1000
# 8/8 - 0s - loss: 0.4131 - accuracy: 0.8660 - val_loss: 0.8103 - val_accuracy: 0.5320
#
# Epoch 00131: val_loss did not improve from 0.69553
# Epoch 132/1000
# 8/8 - 0s - loss: 0.4097 - accuracy: 0.8642 - val_loss: 0.8161 - val_accuracy: 0.5153
#
# Epoch 00132: val_loss did not improve from 0.69553
# Epoch 133/1000
# 8/8 - 0s - loss: 0.4095 - accuracy: 0.8549 - val_loss: 0.8089 - val_accuracy: 0.5181
#
# Epoch 00133: val_loss did not improve from 0.69553
# Epoch 134/1000
# 8/8 - 0s - loss: 0.4124 - accuracy: 0.8493 - val_loss: 0.8155 - val_accuracy: 0.5014
#
# Epoch 00134: val_loss did not improve from 0.69553
# Epoch 135/1000
# 8/8 - 0s - loss: 0.4046 - accuracy: 0.8605 - val_loss: 0.8170 - val_accuracy: 0.5070
#
# Epoch 00135: val_loss did not improve from 0.69553
# Epoch 136/1000
# 8/8 - 0s - loss: 0.4128 - accuracy: 0.8530 - val_loss: 0.8359 - val_accuracy: 0.5097
#
# Epoch 00136: val_loss did not improve from 0.69553
# Epoch 137/1000
# 8/8 - 0s - loss: 0.4072 - accuracy: 0.8474 - val_loss: 0.8614 - val_accuracy: 0.5097
#
# Epoch 00137: val_loss did not improve from 0.69553
# Epoch 138/1000
# 8/8 - 0s - loss: 0.4321 - accuracy: 0.8130 - val_loss: 0.8412 - val_accuracy: 0.4986
#
# Epoch 00138: val_loss did not improve from 0.69553
# Epoch 139/1000
# 8/8 - 0s - loss: 0.4254 - accuracy: 0.8242 - val_loss: 0.8145 - val_accuracy: 0.5181
#
# Epoch 00139: val_loss did not improve from 0.69553
# Epoch 140/1000
# 8/8 - 0s - loss: 0.4075 - accuracy: 0.8567 - val_loss: 0.8190 - val_accuracy: 0.5153
#
# Epoch 00140: val_loss did not improve from 0.69553
# Epoch 141/1000
# 8/8 - 0s - loss: 0.3993 - accuracy: 0.8623 - val_loss: 0.8236 - val_accuracy: 0.5153
#
# Epoch 00141: val_loss did not improve from 0.69553
# Epoch 142/1000
# 8/8 - 0s - loss: 0.3965 - accuracy: 0.8726 - val_loss: 0.8174 - val_accuracy: 0.5209
#
# Epoch 00142: val_loss did not improve from 0.69553
# Epoch 143/1000
# 8/8 - 0s - loss: 0.4051 - accuracy: 0.8521 - val_loss: 0.8639 - val_accuracy: 0.4763
#
# Epoch 00143: val_loss did not improve from 0.69553
# Epoch 144/1000
# 8/8 - 0s - loss: 0.4075 - accuracy: 0.8363 - val_loss: 0.8431 - val_accuracy: 0.5181
#
# Epoch 00144: val_loss did not improve from 0.69553
# Epoch 145/1000
# 8/8 - 0s - loss: 0.3956 - accuracy: 0.8577 - val_loss: 0.8333 - val_accuracy: 0.5265
#
# Epoch 00145: val_loss did not improve from 0.69553
# Epoch 146/1000
# 8/8 - 0s - loss: 0.3881 - accuracy: 0.8772 - val_loss: 0.8264 - val_accuracy: 0.5014
#
# Epoch 00146: val_loss did not improve from 0.69553
# Epoch 147/1000
# 8/8 - 0s - loss: 0.3888 - accuracy: 0.8614 - val_loss: 0.8448 - val_accuracy: 0.5292
#
# Epoch 00147: val_loss did not improve from 0.69553
# Epoch 148/1000
# 8/8 - 0s - loss: 0.3940 - accuracy: 0.8586 - val_loss: 0.8549 - val_accuracy: 0.4958
#
# Epoch 00148: val_loss did not improve from 0.69553
# Epoch 149/1000
# 8/8 - 0s - loss: 0.3849 - accuracy: 0.8642 - val_loss: 0.8364 - val_accuracy: 0.5209
#
# Epoch 00149: val_loss did not improve from 0.69553
# Epoch 150/1000
# 8/8 - 0s - loss: 0.3777 - accuracy: 0.8763 - val_loss: 0.8301 - val_accuracy: 0.5097
#
# Epoch 00150: val_loss did not improve from 0.69553
# Epoch 151/1000
# 8/8 - 0s - loss: 0.3735 - accuracy: 0.8772 - val_loss: 0.8371 - val_accuracy: 0.5181
#
# Epoch 00151: val_loss did not improve from 0.69553
# Epoch 152/1000
# 8/8 - 0s - loss: 0.3871 - accuracy: 0.8493 - val_loss: 0.8319 - val_accuracy: 0.5042
#
# Epoch 00152: val_loss did not improve from 0.69553
# Epoch 153/1000
# 8/8 - 0s - loss: 0.3777 - accuracy: 0.8753 - val_loss: 0.8321 - val_accuracy: 0.5125
#
# Epoch 00153: val_loss did not improve from 0.69553
# Epoch 154/1000
# 8/8 - 0s - loss: 0.3707 - accuracy: 0.8847 - val_loss: 0.8542 - val_accuracy: 0.5209
#
# Epoch 00154: val_loss did not improve from 0.69553
# Epoch 155/1000
# 8/8 - 0s - loss: 0.3665 - accuracy: 0.8837 - val_loss: 0.8373 - val_accuracy: 0.5153
#
# Epoch 00155: val_loss did not improve from 0.69553
# Epoch 156/1000
# 8/8 - 0s - loss: 0.3648 - accuracy: 0.8856 - val_loss: 0.8468 - val_accuracy: 0.5376
#
# Epoch 00156: val_loss did not improve from 0.69553
# Epoch 157/1000
# 8/8 - 0s - loss: 0.3696 - accuracy: 0.8781 - val_loss: 0.8520 - val_accuracy: 0.5070
#
# Epoch 00157: val_loss did not improve from 0.69553
# Epoch 158/1000
# 8/8 - 0s - loss: 0.3682 - accuracy: 0.8800 - val_loss: 0.8543 - val_accuracy: 0.5042
#
# Epoch 00158: val_loss did not improve from 0.69553
# Epoch 159/1000
# 8/8 - 0s - loss: 0.3682 - accuracy: 0.8781 - val_loss: 0.8865 - val_accuracy: 0.4986
#
# Epoch 00159: val_loss did not improve from 0.69553
# Epoch 160/1000
# 8/8 - 0s - loss: 0.3629 - accuracy: 0.8791 - val_loss: 0.8530 - val_accuracy: 0.5153
#
# Epoch 00160: val_loss did not improve from 0.69553
# Epoch 161/1000
# 8/8 - 0s - loss: 0.3572 - accuracy: 0.8940 - val_loss: 0.8526 - val_accuracy: 0.5125
#
# Epoch 00161: val_loss did not improve from 0.69553
# Epoch 162/1000
# 8/8 - 0s - loss: 0.3540 - accuracy: 0.8958 - val_loss: 0.8684 - val_accuracy: 0.5070
#
# Epoch 00162: val_loss did not improve from 0.69553
# Epoch 163/1000
# 8/8 - 0s - loss: 0.3533 - accuracy: 0.8828 - val_loss: 0.8621 - val_accuracy: 0.5153
#
# Epoch 00163: val_loss did not improve from 0.69553
# Epoch 164/1000
# 8/8 - 0s - loss: 0.3482 - accuracy: 0.8930 - val_loss: 0.8559 - val_accuracy: 0.5070
#
# Epoch 00164: val_loss did not improve from 0.69553
# Epoch 165/1000
# 8/8 - 0s - loss: 0.3463 - accuracy: 0.8930 - val_loss: 0.9000 - val_accuracy: 0.5320
#
# Epoch 00165: val_loss did not improve from 0.69553
# Epoch 166/1000
# 8/8 - 0s - loss: 0.3635 - accuracy: 0.8744 - val_loss: 0.8633 - val_accuracy: 0.5125
#
# Epoch 00166: val_loss did not improve from 0.69553
# Epoch 167/1000
# 8/8 - 0s - loss: 0.3537 - accuracy: 0.8809 - val_loss: 0.8596 - val_accuracy: 0.5070
#
# Epoch 00167: val_loss did not improve from 0.69553
# Epoch 168/1000
# 8/8 - 0s - loss: 0.3527 - accuracy: 0.8819 - val_loss: 0.8854 - val_accuracy: 0.5014
#
# Epoch 00168: val_loss did not improve from 0.69553
# Epoch 169/1000
# 8/8 - 0s - loss: 0.3381 - accuracy: 0.9033 - val_loss: 0.8935 - val_accuracy: 0.5097
#
# Epoch 00169: val_loss did not improve from 0.69553
# Epoch 170/1000
# 8/8 - 0s - loss: 0.3402 - accuracy: 0.8977 - val_loss: 0.8705 - val_accuracy: 0.5237
#
# Epoch 00170: val_loss did not improve from 0.69553
# Epoch 171/1000
# 8/8 - 0s - loss: 0.3339 - accuracy: 0.9042 - val_loss: 0.8782 - val_accuracy: 0.5237
#
# Epoch 00171: val_loss did not improve from 0.69553
# Epoch 172/1000
# 8/8 - 0s - loss: 0.3370 - accuracy: 0.9014 - val_loss: 0.8700 - val_accuracy: 0.5209
#
# Epoch 00172: val_loss did not improve from 0.69553
# Epoch 173/1000
# 8/8 - 0s - loss: 0.3324 - accuracy: 0.9042 - val_loss: 0.8817 - val_accuracy: 0.5153
#
# Epoch 00173: val_loss did not improve from 0.69553
# Epoch 174/1000
# 8/8 - 0s - loss: 0.3400 - accuracy: 0.8912 - val_loss: 0.8712 - val_accuracy: 0.5181
#
# Epoch 00174: val_loss did not improve from 0.69553
# Epoch 175/1000
# 8/8 - 0s - loss: 0.3274 - accuracy: 0.9079 - val_loss: 0.8886 - val_accuracy: 0.5237
#
# Epoch 00175: val_loss did not improve from 0.69553
# Epoch 176/1000
# 8/8 - 0s - loss: 0.3277 - accuracy: 0.9070 - val_loss: 0.8730 - val_accuracy: 0.5097
#
# Epoch 00176: val_loss did not improve from 0.69553
# Epoch 177/1000
# 8/8 - 0s - loss: 0.3247 - accuracy: 0.9163 - val_loss: 0.8697 - val_accuracy: 0.5181
#
# Epoch 00177: val_loss did not improve from 0.69553
# Epoch 178/1000
# 8/8 - 0s - loss: 0.3193 - accuracy: 0.9070 - val_loss: 0.8712 - val_accuracy: 0.5097
#
# Epoch 00178: val_loss did not improve from 0.69553
# Epoch 179/1000
# 8/8 - 0s - loss: 0.3188 - accuracy: 0.9126 - val_loss: 0.8934 - val_accuracy: 0.5070
#
# Epoch 00179: val_loss did not improve from 0.69553
# Epoch 180/1000
# 8/8 - 0s - loss: 0.3218 - accuracy: 0.9116 - val_loss: 0.8864 - val_accuracy: 0.5209
#
# Epoch 00180: val_loss did not improve from 0.69553
# Epoch 181/1000
# 8/8 - 0s - loss: 0.3149 - accuracy: 0.9107 - val_loss: 0.8906 - val_accuracy: 0.5237
#
# Epoch 00181: val_loss did not improve from 0.69553
# Epoch 182/1000
# 8/8 - 0s - loss: 0.3131 - accuracy: 0.9209 - val_loss: 0.8890 - val_accuracy: 0.5320
#
# Epoch 00182: val_loss did not improve from 0.69553
# Epoch 183/1000
# 8/8 - 0s - loss: 0.3102 - accuracy: 0.9181 - val_loss: 0.8861 - val_accuracy: 0.5265
#
# Epoch 00183: val_loss did not improve from 0.69553
# Epoch 184/1000
# 8/8 - 0s - loss: 0.3050 - accuracy: 0.9191 - val_loss: 0.8985 - val_accuracy: 0.5153
#
# Epoch 00184: val_loss did not improve from 0.69553
# Epoch 185/1000
# 8/8 - 0s - loss: 0.3093 - accuracy: 0.9135 - val_loss: 0.9262 - val_accuracy: 0.5125
#
# Epoch 00185: val_loss did not improve from 0.69553
# Epoch 186/1000
# 8/8 - 0s - loss: 0.3086 - accuracy: 0.9172 - val_loss: 0.8939 - val_accuracy: 0.5265
#
# Epoch 00186: val_loss did not improve from 0.69553
# Epoch 187/1000
# 8/8 - 0s - loss: 0.3059 - accuracy: 0.9219 - val_loss: 0.9419 - val_accuracy: 0.4958
#
# Epoch 00187: val_loss did not improve from 0.69553
# Epoch 188/1000
# 8/8 - 0s - loss: 0.3150 - accuracy: 0.9079 - val_loss: 0.9198 - val_accuracy: 0.5014
#
# Epoch 00188: val_loss did not improve from 0.69553
# Epoch 189/1000
# 8/8 - 0s - loss: 0.3071 - accuracy: 0.9042 - val_loss: 0.9096 - val_accuracy: 0.5292
#
# Epoch 00189: val_loss did not improve from 0.69553
# Epoch 190/1000
# 8/8 - 0s - loss: 0.3159 - accuracy: 0.9023 - val_loss: 0.9019 - val_accuracy: 0.5125
#
# Epoch 00190: val_loss did not improve from 0.69553
# Epoch 191/1000
# 8/8 - 0s - loss: 0.2961 - accuracy: 0.9200 - val_loss: 0.9044 - val_accuracy: 0.5320
#
# Epoch 00191: val_loss did not improve from 0.69553
# Epoch 192/1000
# 8/8 - 0s - loss: 0.3075 - accuracy: 0.9107 - val_loss: 0.9011 - val_accuracy: 0.5125
#
# Epoch 00192: val_loss did not improve from 0.69553
# Epoch 193/1000
# 8/8 - 0s - loss: 0.2958 - accuracy: 0.9274 - val_loss: 0.9043 - val_accuracy: 0.5209
#
# Epoch 00193: val_loss did not improve from 0.69553
# Epoch 194/1000
# 8/8 - 0s - loss: 0.2879 - accuracy: 0.9293 - val_loss: 0.9108 - val_accuracy: 0.5265
#
# Epoch 00194: val_loss did not improve from 0.69553
# Epoch 195/1000
# 8/8 - 0s - loss: 0.2870 - accuracy: 0.9284 - val_loss: 0.9155 - val_accuracy: 0.5265
#
# Epoch 00195: val_loss did not improve from 0.69553
# Epoch 196/1000
# 8/8 - 0s - loss: 0.3108 - accuracy: 0.9060 - val_loss: 0.9075 - val_accuracy: 0.5265
#
# Epoch 00196: val_loss did not improve from 0.69553
# Epoch 197/1000
# 8/8 - 0s - loss: 0.2835 - accuracy: 0.9274 - val_loss: 0.9144 - val_accuracy: 0.5181
#
# Epoch 00197: val_loss did not improve from 0.69553
# Epoch 198/1000
# 8/8 - 0s - loss: 0.2865 - accuracy: 0.9330 - val_loss: 0.9123 - val_accuracy: 0.5209
#
# Epoch 00198: val_loss did not improve from 0.69553
# Epoch 199/1000
# 8/8 - 0s - loss: 0.2833 - accuracy: 0.9340 - val_loss: 0.9366 - val_accuracy: 0.5265
#
# Epoch 00199: val_loss did not improve from 0.69553
# Epoch 200/1000
# 8/8 - 0s - loss: 0.2766 - accuracy: 0.9414 - val_loss: 0.9130 - val_accuracy: 0.5181
#
# Epoch 00200: val_loss did not improve from 0.69553
# Epoch 201/1000
# 8/8 - 0s - loss: 0.2789 - accuracy: 0.9340 - val_loss: 0.9282 - val_accuracy: 0.5181
#
# Epoch 00201: val_loss did not improve from 0.69553
# Epoch 202/1000
# 8/8 - 0s - loss: 0.2754 - accuracy: 0.9340 - val_loss: 0.9329 - val_accuracy: 0.5181
#
# Epoch 00202: val_loss did not improve from 0.69553
# Epoch 203/1000
# 8/8 - 0s - loss: 0.2756 - accuracy: 0.9293 - val_loss: 0.9200 - val_accuracy: 0.5237
#
# Epoch 00203: val_loss did not improve from 0.69553
# Epoch 204/1000
# 8/8 - 0s - loss: 0.2791 - accuracy: 0.9293 - val_loss: 0.9685 - val_accuracy: 0.4875
#
# Epoch 00204: val_loss did not improve from 0.69553
# Epoch 205/1000
# 8/8 - 0s - loss: 0.2834 - accuracy: 0.9358 - val_loss: 0.9260 - val_accuracy: 0.5181
#
# Epoch 00205: val_loss did not improve from 0.69553
# Epoch 206/1000
# 8/8 - 0s - loss: 0.2664 - accuracy: 0.9414 - val_loss: 0.9344 - val_accuracy: 0.5209
#
# Epoch 00206: val_loss did not improve from 0.69553
# Epoch 207/1000
# 8/8 - 0s - loss: 0.2700 - accuracy: 0.9312 - val_loss: 0.9299 - val_accuracy: 0.5237
#
# Epoch 00207: val_loss did not improve from 0.69553
# Epoch 208/1000
# 8/8 - 0s - loss: 0.2749 - accuracy: 0.9321 - val_loss: 0.9570 - val_accuracy: 0.5292
#
# Epoch 00208: val_loss did not improve from 0.69553
# Epoch 209/1000
# 8/8 - 0s - loss: 0.2763 - accuracy: 0.9256 - val_loss: 0.9522 - val_accuracy: 0.5125
#
# Epoch 00209: val_loss did not improve from 0.69553
# Epoch 210/1000
# 8/8 - 0s - loss: 0.2724 - accuracy: 0.9367 - val_loss: 0.9308 - val_accuracy: 0.5404
#
# Epoch 00210: val_loss did not improve from 0.69553
# Epoch 211/1000
# 8/8 - 0s - loss: 0.2652 - accuracy: 0.9312 - val_loss: 0.9441 - val_accuracy: 0.5320
#
# Epoch 00211: val_loss did not improve from 0.69553
# Epoch 212/1000
# 8/8 - 0s - loss: 0.2561 - accuracy: 0.9470 - val_loss: 0.9554 - val_accuracy: 0.5292
#
# Epoch 00212: val_loss did not improve from 0.69553
# Epoch 213/1000
# 8/8 - 0s - loss: 0.2813 - accuracy: 0.9172 - val_loss: 0.9519 - val_accuracy: 0.5181
#
# Epoch 00213: val_loss did not improve from 0.69553
# Epoch 214/1000
# 8/8 - 0s - loss: 0.2720 - accuracy: 0.9265 - val_loss: 0.9491 - val_accuracy: 0.5209
#
# Epoch 00214: val_loss did not improve from 0.69553
# Epoch 215/1000
# 8/8 - 0s - loss: 0.2649 - accuracy: 0.9330 - val_loss: 0.9457 - val_accuracy: 0.5097
#
# Epoch 00215: val_loss did not improve from 0.69553
# Epoch 216/1000
# 8/8 - 0s - loss: 0.2493 - accuracy: 0.9460 - val_loss: 0.9707 - val_accuracy: 0.5265
#
# Epoch 00216: val_loss did not improve from 0.69553
# Epoch 217/1000
# 8/8 - 0s - loss: 0.2602 - accuracy: 0.9377 - val_loss: 0.9501 - val_accuracy: 0.5209
#
# Epoch 00217: val_loss did not improve from 0.69553
# Epoch 218/1000
# 8/8 - 0s - loss: 0.2455 - accuracy: 0.9516 - val_loss: 0.9551 - val_accuracy: 0.5097
#
# Epoch 00218: val_loss did not improve from 0.69553
# Epoch 219/1000
# 8/8 - 0s - loss: 0.2466 - accuracy: 0.9488 - val_loss: 0.9594 - val_accuracy: 0.5432
#
# Epoch 00219: val_loss did not improve from 0.69553
# Epoch 220/1000
# 8/8 - 0s - loss: 0.2472 - accuracy: 0.9479 - val_loss: 0.9565 - val_accuracy: 0.5320
#
# Epoch 00220: val_loss did not improve from 0.69553
# Epoch 221/1000
# 8/8 - 0s - loss: 0.2461 - accuracy: 0.9442 - val_loss: 0.9603 - val_accuracy: 0.5432
#
# Epoch 00221: val_loss did not improve from 0.69553
# Epoch 222/1000
# 8/8 - 0s - loss: 0.2535 - accuracy: 0.9340 - val_loss: 0.9605 - val_accuracy: 0.5209
#
# Epoch 00222: val_loss did not improve from 0.69553
# Epoch 223/1000
# 8/8 - 0s - loss: 0.2379 - accuracy: 0.9553 - val_loss: 0.9675 - val_accuracy: 0.5292
#
# Epoch 00223: val_loss did not improve from 0.69553
# Epoch 224/1000
# 8/8 - 0s - loss: 0.2379 - accuracy: 0.9544 - val_loss: 0.9595 - val_accuracy: 0.5209
#
# Epoch 00224: val_loss did not improve from 0.69553
# Epoch 225/1000
# 8/8 - 0s - loss: 0.2383 - accuracy: 0.9553 - val_loss: 0.9642 - val_accuracy: 0.5153
#
# Epoch 00225: val_loss did not improve from 0.69553
# Epoch 226/1000
# 8/8 - 0s - loss: 0.2330 - accuracy: 0.9591 - val_loss: 0.9747 - val_accuracy: 0.5181
#
# Epoch 00226: val_loss did not improve from 0.69553
# Epoch 227/1000
# 8/8 - 0s - loss: 0.2364 - accuracy: 0.9498 - val_loss: 0.9650 - val_accuracy: 0.5209
#
# Epoch 00227: val_loss did not improve from 0.69553
# Epoch 228/1000
# 8/8 - 0s - loss: 0.2541 - accuracy: 0.9349 - val_loss: 1.0568 - val_accuracy: 0.5125
#
# Epoch 00228: val_loss did not improve from 0.69553
# Epoch 229/1000
# 8/8 - 0s - loss: 0.2615 - accuracy: 0.9191 - val_loss: 0.9566 - val_accuracy: 0.5320
#
# Epoch 00229: val_loss did not improve from 0.69553
# Epoch 230/1000
# 8/8 - 0s - loss: 0.2347 - accuracy: 0.9479 - val_loss: 0.9911 - val_accuracy: 0.5097
#
# Epoch 00230: val_loss did not improve from 0.69553
# Epoch 231/1000
# 8/8 - 0s - loss: 0.2402 - accuracy: 0.9377 - val_loss: 0.9723 - val_accuracy: 0.5265
#
# Epoch 00231: val_loss did not improve from 0.69553
# Epoch 232/1000
# 8/8 - 0s - loss: 0.2330 - accuracy: 0.9609 - val_loss: 0.9845 - val_accuracy: 0.5181
#
# Epoch 00232: val_loss did not improve from 0.69553
# Epoch 233/1000
# 8/8 - 0s - loss: 0.2205 - accuracy: 0.9600 - val_loss: 0.9895 - val_accuracy: 0.5404
#
# Epoch 00233: val_loss did not improve from 0.69553
# Epoch 234/1000
# 8/8 - 0s - loss: 0.2175 - accuracy: 0.9665 - val_loss: 0.9827 - val_accuracy: 0.5153
#
# Epoch 00234: val_loss did not improve from 0.69553
# Epoch 235/1000
# 8/8 - 0s - loss: 0.2147 - accuracy: 0.9656 - val_loss: 0.9890 - val_accuracy: 0.5237
#
# Epoch 00235: val_loss did not improve from 0.69553
# Epoch 236/1000
# 8/8 - 0s - loss: 0.2124 - accuracy: 0.9693 - val_loss: 0.9910 - val_accuracy: 0.5181
#
# Epoch 00236: val_loss did not improve from 0.69553
# Epoch 237/1000
# 8/8 - 0s - loss: 0.2110 - accuracy: 0.9684 - val_loss: 0.9952 - val_accuracy: 0.5237
#
# Epoch 00237: val_loss did not improve from 0.69553
# Epoch 238/1000
# 8/8 - 0s - loss: 0.2102 - accuracy: 0.9693 - val_loss: 0.9981 - val_accuracy: 0.5125
#
# Epoch 00238: val_loss did not improve from 0.69553
# Epoch 239/1000
# 8/8 - 0s - loss: 0.2158 - accuracy: 0.9591 - val_loss: 0.9948 - val_accuracy: 0.5209
#
# Epoch 00239: val_loss did not improve from 0.69553
# Epoch 240/1000
# 8/8 - 0s - loss: 0.2095 - accuracy: 0.9665 - val_loss: 1.0034 - val_accuracy: 0.5265
#
# Epoch 00240: val_loss did not improve from 0.69553
# Epoch 241/1000
# 8/8 - 0s - loss: 0.2051 - accuracy: 0.9740 - val_loss: 0.9968 - val_accuracy: 0.5237
#
# Epoch 00241: val_loss did not improve from 0.69553
# Epoch 242/1000
# 8/8 - 0s - loss: 0.2032 - accuracy: 0.9712 - val_loss: 0.9983 - val_accuracy: 0.5237
#
# Epoch 00242: val_loss did not improve from 0.69553
# Epoch 243/1000
# 8/8 - 0s - loss: 0.2015 - accuracy: 0.9721 - val_loss: 1.0064 - val_accuracy: 0.5265
#
# Epoch 00243: val_loss did not improve from 0.69553
# Epoch 244/1000
# 8/8 - 0s - loss: 0.2087 - accuracy: 0.9637 - val_loss: 1.0120 - val_accuracy: 0.5292
#
# Epoch 00244: val_loss did not improve from 0.69553
# Epoch 245/1000
# 8/8 - 0s - loss: 0.2074 - accuracy: 0.9665 - val_loss: 1.0041 - val_accuracy: 0.5292
#
# Epoch 00245: val_loss did not improve from 0.69553
# Epoch 246/1000
# 8/8 - 0s - loss: 0.2072 - accuracy: 0.9674 - val_loss: 1.0097 - val_accuracy: 0.5209
#
# Epoch 00246: val_loss did not improve from 0.69553
# Epoch 247/1000
# 8/8 - 0s - loss: 0.2021 - accuracy: 0.9712 - val_loss: 1.0373 - val_accuracy: 0.5265
#
# Epoch 00247: val_loss did not improve from 0.69553
# Epoch 248/1000
# 8/8 - 0s - loss: 0.1970 - accuracy: 0.9721 - val_loss: 1.0120 - val_accuracy: 0.5237
#
# Epoch 00248: val_loss did not improve from 0.69553
# Epoch 249/1000
# 8/8 - 0s - loss: 0.1937 - accuracy: 0.9740 - val_loss: 1.0209 - val_accuracy: 0.5125
#
# Epoch 00249: val_loss did not improve from 0.69553
# Epoch 250/1000
# 8/8 - 0s - loss: 0.1977 - accuracy: 0.9740 - val_loss: 1.0199 - val_accuracy: 0.5265
#
# Epoch 00250: val_loss did not improve from 0.69553
# Epoch 251/1000
# 8/8 - 0s - loss: 0.1989 - accuracy: 0.9749 - val_loss: 1.0212 - val_accuracy: 0.5292
#
# Epoch 00251: val_loss did not improve from 0.69553
# Epoch 252/1000
# 8/8 - 0s - loss: 0.1895 - accuracy: 0.9767 - val_loss: 1.0536 - val_accuracy: 0.5209
#
# Epoch 00252: val_loss did not improve from 0.69553
# Epoch 253/1000
# 8/8 - 0s - loss: 0.1997 - accuracy: 0.9674 - val_loss: 1.0183 - val_accuracy: 0.5209
#
# Epoch 00253: val_loss did not improve from 0.69553
# Epoch 254/1000
# 8/8 - 0s - loss: 0.2064 - accuracy: 0.9470 - val_loss: 1.1084 - val_accuracy: 0.5181
#
# Epoch 00254: val_loss did not improve from 0.69553
# Epoch 255/1000
# 8/8 - 0s - loss: 0.2322 - accuracy: 0.9312 - val_loss: 1.0604 - val_accuracy: 0.5042
#
# Epoch 00255: val_loss did not improve from 0.69553
# Epoch 256/1000
# 8/8 - 0s - loss: 0.1996 - accuracy: 0.9637 - val_loss: 1.0297 - val_accuracy: 0.5237
#
# Epoch 00256: val_loss did not improve from 0.69553
# Epoch 257/1000
# 8/8 - 0s - loss: 0.1811 - accuracy: 0.9814 - val_loss: 1.0269 - val_accuracy: 0.5209
#
# Epoch 00257: val_loss did not improve from 0.69553
# Epoch 258/1000
# 8/8 - 0s - loss: 0.1809 - accuracy: 0.9795 - val_loss: 1.0255 - val_accuracy: 0.5265
#
# Epoch 00258: val_loss did not improve from 0.69553
# Epoch 259/1000
# 8/8 - 0s - loss: 0.1779 - accuracy: 0.9805 - val_loss: 1.0369 - val_accuracy: 0.5265
#
# Epoch 00259: val_loss did not improve from 0.69553
# test_result.shape : (359, 2)
# y_test[:5] : [1 1 1 1 1]
# y_score[:5] : [[0.56920683]
#  [0.5063975 ]
#  [0.44073722]
#  [0.43821406]
#  [0.29136077]]
# y_test.shape : (359, 1)
# y_score.shape : (359, 1)
# len(y_test) : 359
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:697: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [0.35490847, 0.33561292, 0.3245211, 0.32766718, 0.33874375, 0.34186098, 0.33864367, 0.34914124, 0.34981892, 0.34054592, 0.35172793, 0.34949005, 0.34904093, 0.3666827, 0.37687746, 0.38796332, 0.38556135, 0.39207882, 0.39740118, 0.39416745, 0.40493727, 0.41366372, 0.39610055, 0.38666537, 0.3651581, 0.37084243, 0.37458667, 0.37852708, 0.3787924, 0.3870083, 0.39542505, 0.38944155, 0.38437602, 0.38175946, 0.38106707, 0.35928282, 0.36031166, 0.38319987, 0.38330913, 0.3943377, 0.41925156, 0.46945515, 0.4697751, 0.44988558, 0.47589508, 0.47578254, 0.45841005, 0.45681846, 0.4555601, 0.4631582, 0.4763399, 0.48473552, 0.45790768, 0.4620204, 0.47004792, 0.44870472, 0.4557276, 0.46423, 0.46278375, 0.45440897, 0.4795412, 0.4828971, 0.49066666, 0.48346356, 0.4676593, 0.45236713, 0.44053516, 0.45638055, 0.458619, 0.45808604, 0.4685276, 0.44774777, 0.446099, 0.4978227, 0.4918773, 0.50303197, 0.50251836, 0.5338127, 0.5331693, 0.53769004, 0.5347418, 0.53514457, 0.54915667, 0.5568892, 0.5509939, 0.55991846, 0.5654337, 0.53416735, 0.5486007, 0.54922146, 0.5593351, 0.60736394, 0.6009367, 0.58030325, 0.5770443, 0.5681796, 0.55387473, 0.5543906, 0.57653993, 0.61687285, 0.63729155, 0.6479515, 0.64212, 0.6686088, 0.6601595, 0.6505415, 0.6707675, 0.6924266, 0.710483, 0.81833667, 0.8141365, 0.8341846, 0.851295, 0.8516098, 0.8233608, 0.84057045, 0.83628553, 0.84795314, 0.8514848, 0.903569, 0.9062146, 0.8356174, 0.9106558, 0.9345386, 0.9192156, 0.92411333, 0.9363279, 0.92638725, 0.9435498, 0.92129403, 0.90362054, 0.91887766, 0.94849783, 0.95097935, 0.93867975, 0.9444414, 0.9581866, 0.9675181, 1.0103346, 1.0258863, 1.022806, 1.0135239, 1.0278554, 1.0446806, 1.0963113, 1.1017704, 1.1202615, 1.0985999, 1.1312469, 1.1517661, 1.142406, 1.2264223, 1.2153059, 1.2482239, 1.2456818, 1.2314279, 1.2128106, 1.1478878, 1.1134412, 1.1568846, 1.22646, 1.2290841, 1.1849177, 1.1227742, 1.0808058, 1.0033692, 1.0241635, 1.0139861, 0.9999304, 1.0231161, 1.0365261, 1.0153943, 1.006298, 1.0091779, 0.90220445, 0.93843406, 0.8839489, 0.9078648, 0.9411071, 0.88064975, 0.9354599, 0.93386906, 0.97311014, 0.96262723, 0.9651779, 0.99599737, 0.98869544, 0.9967507, 1.0310982, 1.0455183, 1.0230868, 1.0594606, 1.010374, 1.0138078, 1.0442616, 1.0305239, 1.0704879, 1.0646486, 0.96217865, 0.99060625, 0.87784785, 0.86099696, 0.7474205, 0.75056434, 0.76389265, 0.7656646, 0.72266144, 0.7124344, 0.70627266, 0.70937485, 0.71226895, 0.71543694, 0.71340466, 0.7620175, 0.75087523, 0.70230764, 0.65156585, 0.6623792, 0.66330916, 0.6664071, 0.67275006, 0.65841115, 0.66675204, 0.6545112, 0.6591987, 0.6401304, 0.68456966, 0.6684143, 0.66578573, 0.68036205, 0.66057223, 0.66487867, 0.6563735, 0.68790853, 0.71338296, 0.70843565, 0.7060061, 0.7092558, 0.70758206, 0.7200167, 0.6828304, 0.66988903, 0.6578788, 0.6640954, 0.65833527, 0.6745672, 0.67200625, 0.68114656, 0.77336085, 0.7693085, 0.7862172, 0.8342923, 0.809266, 0.7977731, 0.8229443, 0.8241691, 0.81043935, 0.82178074, 0.8103928, 0.85552245, 0.847808, 0.84349406, 0.8167422, 0.82117605, 0.7621231, 0.7854898, 0.7326898, 0.729349, 0.72313046, 0.67035854, 0.6559293, 0.6457546, 0.6609691, 0.6585105, 0.6725744, 0.6609615, 0.64860094, 0.6565482, 0.6587259, 0.68166184, 0.748785, 0.740692, 0.73967534, 0.75399745, 0.75866634, 0.7582144, 0.7569352, 0.74971414, 0.7709286, 0.773624, 0.80266017, 0.81847614, 0.84026235, 0.8539872, 0.8745136, 0.8714988, 0.8606237, 0.8408167, 0.8292692, 0.87075096, 0.87655884, 0.87523603, 0.88512325, 0.9401364, 0.9591143, 0.9296452, 1.053381, 1.0534793, 1.0031049, 0.9913625, 0.9648788, 0.8791806, 0.853808, 0.86476594, 0.88258046, 0.89902866, 0.8287592, 0.8510619, 0.7786524, 0.77591616, 0.7628273, 0.73415476, 0.720885, 0.6848694, 0.65328276, 0.66507167, 0.65867805, 0.7664883, 0.72918063, 0.8038834, 0.8109042, 0.813732, 0.7992504, 0.79454035, 0.7946101, 0.75509924, 0.7759675, 0.83158106, 0.83336115, 0.7905773, 0.7829353, 0.7891321, 0.828268, 0.8287322, 0.83381456, 0.80688643, 0.81777894, 0.8524066, 0.86040896, 0.90609634, 0 ...

# %% [markdown]
# ### save npy

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from funcs_indicator import *

def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


#       set data features : ohlc, v, ep
time_index = ohlcv.index[np.sum(np.isnan(pr)):]

sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

#       scale with price    #
ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
sar = lucid_sar(sliced_ohlcv)
ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
senkou1, senkou2 = ichimoku(sliced_ohlcv)

#     min max scale   #
vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

pr_list = pr[np.sum(np.isnan(pr)):]
print("len(ohlc) :", len(ohlc))
print("len(pr) :", len(pr))

# break


#       set params    #
period = 45
key_i = i

plotting = True

data_x, data_pr, data_updown = [], [], []
data_index = []

for i in range(period, len(ohlc)):

  #   pr_list != 1 인 데이터만 사용한다
  # if 1:
  if pr_list[i] != 1:

    min_max = MinMaxScaler()
    
    #   prediction 을 제외한 이전 데이터를 사용해야한다
    temp_ohlc = ohlc.iloc[i - period : i].values
    # temp_long_ep = long_ep[i - period : i]          
    temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
    temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

    temp_close = min_max_scale(temp_ohlc[:, [3]])    

    price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

    if np.isnan(np.sum(price_data)):
      continue

    # print("price_data[:10] :", price_data[:10])
    # print("temp_ohlc.shape :", temp_ohlc.shape)
    # print("temp_long_ep.shape :", temp_long_ep.shape)
    # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
    # print("price_data.shape :", price_data.shape)

    if plotting:
      plt.plot(price_data)
      plt.show()

    ind_temp_ohlc = min_max_scale(temp_ohlc)
    temp_price_data = min_max_scale(price_data)
    # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


    if plotting:

      plt.plot(ind_temp_ohlc)
      plt.show()
      plt.plot(temp_price_data)
      plt.show()

      plotting = False
    # break

    #   vol -> min_max
    temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
    
    #                   feature selection                   #        
    temp_data = np.hstack((ind_temp_ohlc, temp_vol))

    # temp_data = trial_list[trial_number]
    # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
    # temp_data = temp_ohlc[:, [3]]
    # temp_data = ind_temp_ohlc[:, [3]]
    # temp_data = temp_close

    if np.isnan(np.sum(temp_data)):
      continue

    data_x.append(temp_data)
    data_pr.append(pr_list[i])
    data_index.append(time_index[i])
    data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


print('np.array(data_x).shape :', np.array(data_x).shape)
# print(data_x[0])


#       Reshape data for image deep - learning     #
_, row, col = np.array(data_x).shape

input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
# input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

#     1c to 3c    #
input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
# input_x = np.array(resize_npy(input_x))


input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
input_index = np.array(data_index).reshape(-1, 1)
print('input_x.shape :', input_x.shape)
print('input_x.dtype :', input_x.dtype)
print('input_pr.shape :', input_pr.shape)
print('input_ud.shape :', input_ud.shape)
print('input_index.shape :', input_index.shape)


# x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

#     do stacking   #
# if prev_x is None:
prev_x = input_x
prev_pr = input_pr
prev_ud = input_ud
prev_index = input_index

total_x = input_x
total_pr = input_pr
total_ud = input_ud
total_index = input_index

# else:
#   total_x = np.vstack((prev_x, input_x))
#   total_pr = np.vstack((prev_pr, input_pr))
#   total_ud = np.vstack((prev_ud, input_ud)) 
#   total_index = np.vstack((prev_index, input_index)) 

#   prev_x = total_x
#   prev_pr = total_pr
#   prev_ud = total_ud
#   prev_index = total_index

print('total_x.shape :', total_x.shape)
print('total_pr.shape :', total_pr.shape)
print('total_ud.shape :', total_ud.shape)
print('prev_index.shape :', prev_index.shape)


# _, row, col, _ = input_x.shape
# _, row, col = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


#         get unique timestamp      #
print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

#                 don't shuffle timeseries data                 #
stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)

index_train = np.array(index_train)
index_val = np.array(index_val)
index_test = np.array(index_test)
  
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

symbol_name = key.split(' ')[1].split('.')[0]

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)

np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %% [markdown]
# ### load npy

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


symbol_name = "SXPUSDT"
period = 45

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)


x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')


pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

# total_x = np.vstack((x_train, x_val, x_test))
# total_pr = np.vstack((pr_train, pr_val, pr_test))

# print("total_x.shape :", total_x.shape)
# Out:
# x series loaded !
# y series loaded !

# %% [markdown]
# ### rapid pr selection

# %%
plt.plot(pr)
plt.show()

pr_thresh = 1.005
rapid_pct = len(pr[pr > pr_thresh]) / len(pr)

print(rapid_pct)
# Out:
# 0.36131427304964536

# %% [markdown]
# ### class_weight & categorization

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


def class_ratio(in_list):

  return in_list / in_list[1]
  
y_train = np.where(pr_train > pr_thresh, 1, 0)
y_test = np.where(pr_test > pr_thresh, 1, 0)
y_val = np.where(pr_val > pr_thresh, 1, 0)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

# try:
print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

# except Exception as e:
  # print(e)

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)
# Out:
# x_train.shape : (10755, 45, 5, 3)
# x_test.shape : (3586, 45, 5, 3)
# x_val.shape : (3585, 45, 5, 3)
# y_train.shape : (10755, 1)
# y_test.shape : (3586, 1)
# y_val.shape : (3585, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([6864, 3891])) [1.76407093 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2303, 1282])) [1.79641186 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2291, 1295])) [1.76911197 1.        ]
# class_weights : {0: 0.7834353146853147, 1: 1.382035466461064}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10755, 2)
# y_val_ohe.shape : (3585, 2)
# y_test_ohe.shape : (3586, 2)

# %% [markdown]
# ### augment

# %%
from keras.preprocessing.image import ImageDataGenerator 

datagen = ImageDataGenerator( 
    # rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)


batch_size = 512


for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break

# %% [markdown]
# ### train

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'

# batch_size = 512

model = FER_Model(input_shape=x_train.shape[1:])
opt = Adam(lr=0.00001, decay=0.000005)
# opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model_name = 'classifier_%s_cnn_updown_rascend_1005_%s_tvnon_shuffle.h5' % (period, symbol_name)



checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]
# callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)

# %% [markdown]
# ### load model

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'


model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)


model = keras.models.load_model(ckpt_path + model_name)

# %% [markdown]
# ### test

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)

  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.title(symbol_name)
plt.show()
# Out:
# test_result.shape : (3586, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.04767541]
#  [0.00195843]
#  [0.1600004 ]
#  [0.14308068]
#  [0.00154134]]
# y_test.shape : (3586, 1)
# y_score.shape : (3586, 1)
# len(y_test) : 3586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [5.2342257e-05, 5.224965e-05, 5.119804e-05, 4.92728e-05, 4.9822964e-05, 5.1722614e-05, 5.241118e-05, 5.2653213e-05, 5.4707263e-05, 5.469477e-05, 5.5414595e-05, 5.4917986e-05, 5.5296758e-05, 5.482614e-05, 5.5313794e-05, 5.619928e-05, 5.7341047e-05, 5.8005982e-05, 5.7726982e-05, 5.8714617e-05, 5.924952e-05, 5.9157777e-05, 6.0730683e-05, 6.09751e-05, 6.1022805e-05, 6.194849e-05, 6.286581e-05, 6.367981e-05, 6.4932676e-05, 6.5769455e-05, 6.7948844e-05, 6.841887e-05, 6.806048e-05, 6.849957e-05, 6.9895126e-05, 7.091783e-05, 7.1859926e-05, 7.350335e-05, 7.346305e-05, 7.395025e-05, 7.968566e-05, 7.8947196e-05, 7.8341516e-05, 7.918357e-05, 7.912106e-05, 8.1205275e-05, 8.341604e-05, 8.386569e-05, 8.3938816e-05, 8.564359e-05, 7.970025e-05, 8.0672995e-05, 8.083643e-05, 8.727269e-05, 8.9510206e-05, 8.959228e-05, 8.962243e-05, 8.8885776e-05, 9.023229e-05, 9.169206e-05, 9.0867565e-05, 9.033618e-05, 9.429348e-05, 9.3799725e-05, 9.566918e-05, 9.6586686e-05, 9.398621e-05, 9.4105475e-05, 9.411831e-05, 9.466633e-05, 9.5054995e-05, 9.854746e-05, 9.9124496e-05, 0.00010614127, 0.000108136, 0.00010740872, 0.00010814099, 0.00010723293, 0.00010745465, 0.00010824714, 0.00010731329, 0.000108584194, 0.00010868803, 0.00010257258, 0.000101516416, 0.00010031571, 0.000103715196, 0.00010502134, 0.00010611775, 0.00010916348, 0.00010594193, 0.000104194485, 0.00010433929, 0.000104219216, 0.00010764128, 0.00010433711, 0.00010385209, 0.000106006635, 0.00010645543, 0.00010741285, 0.00010793885, 0.00010773461, 0.000107400294, 0.000107067055, 0.000110430265, 0.00010961514, 0.000110994966, 0.000109511326, 0.00011019072, 0.00011165826, 0.00011095228, 0.00011055433, 0.00011134691, 0.000109883986, 0.0001112986, 0.0001123257, 0.000114077506, 0.00011583454, 0.00011730796, 0.00011702095, 0.00012883096, 0.00012502969, 0.0001211144, 0.00012085415, 0.00012023333, 0.000121178586, 0.0001113643, 0.00011255329, 0.00011366057, 0.00011109531, 0.00011435672, 0.00011691414, 0.00011724194, 0.00011877652, 0.00011876732, 0.00012343662, 0.00012398258, 0.00012742475, 0.00013299534, 0.0001345203, 0.00013497796, 0.00013495858, 0.00013710273, 0.00013803714, 0.00013533776, 0.00014049193, 0.00013862025, 0.00013925365, 0.00013978127, 0.00014475136, 0.00014560782, 0.00014417202, 0.00015133772, 0.0001492487, 0.00015156744, 0.00015025465, 0.00015172384, 0.0001483679, 0.00015025485, 0.00017470514, 0.00017807752, 0.00018197432, 0.00018371776, 0.00018367464, 0.0001920926, 0.00019288564, 0.00020759454, 0.00020698183, 0.00023446795, 0.00023864223, 0.00024568185, 0.0002499611, 0.00025658592, 0.00025730263, 0.00025887572, 0.00026280092, 0.0002670472, 0.00027564648, 0.0002803122, 0.0002723821, 0.00027754836, 0.00027732784, 0.00028359605, 0.0002916876, 0.0002884358, 0.0002919522, 0.00029502896, 0.00028943687, 0.00028854128, 0.00029137387, 0.0002962364, 0.00029461124, 0.00029948735, 0.00030449385, 0.0002996868, 0.00029990985, 0.00029333428, 0.0002965417, 0.00029836778, 0.00029298887, 0.00030178405, 0.00029634495, 0.00029906907, 0.00029697176, 0.0002963374, 0.000295097, 0.000312998, 0.00031196643, 0.00031936396, 0.00032101592, 0.00032832168, 0.0003258465, 0.00033274552, 0.0003290262, 0.00033229083, 0.00034132804, 0.00033895372, 0.00035075872, 0.00034744598, 0.00034445102, 0.00032778905, 0.0003323982, 0.00034709118, 0.0003477889, 0.00035424854, 0.00040091967, 0.00042115894, 0.00041995398, 0.00041660885, 0.00042408038, 0.00044065266, 0.00045346154, 0.00044463656, 0.00047572926, 0.0005098468, 0.00050058664, 0.00049340463, 0.0004999284, 0.0005000292, 0.0004849475, 0.00048356556, 0.0004768842, 0.00047515446, 0.00046261746, 0.00046790738, 0.000461418, 0.00046818578, 0.00046653874, 0.00047877917, 0.00048961974, 0.0005021864, 0.00051662093, 0.00052976055, 0.00053512596, 0.000552535, 0.0005820823, 0.00058700517, 0.00059161586, 0.0005911128, 0.00059325877, 0.00059789245, 0.0006161917, 0.00060233, 0.0006037665, 0.0005968395, 0.0006049573, 0.0006040889, 0.0006045968, 0.000620602, 0.00062113034, 0.0006333279, ...

# %%
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)], linestyle='--', color='r')
plt.title(symbol_name + '\n' + str(new_thresh[np.argmax(acc_pr_bythr)]))
plt.show()

# %%
thresh = 0.5866
y_pred = np.where(y_score[:600, -1] > thresh, 1, 0)
# print('y_pred.shape :', y_pred.shape)
# print('y_pred :', y_pred)

#     compare precision     #

# print('precision :', precision_score(y_test, y_pred))
# print('recall :', recall_score(y_test, y_pred))
# print()

# print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
# print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

# # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
# # plt.show()  
# print()

#     check win-ratio improvement     #
cmat = confusion_matrix(y_test[:len(y_pred)], y_pred)
# print(cmat)
# print(np.sum(cmat, axis=1))

test_size = len(y_test[:len(y_pred)])
test_pr_list = pr_test[:len(y_pred)]
# print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
# print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

# print('pr_test.shape :', pr_test.shape)

# print(y_pred)
# print(test_pr_list)
pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

plt.plot(np.cumprod(pred_pr_list))
plt.show()

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72a922dd9685> in <module>()
#       5 # print(index_train)
#       6 # print(index_val)
# ----> 7 total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index))
#       8 timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train))
#       9 timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val))
#
# NameError: name 'input_index' is not defined

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
