# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2
# !pip install h5py==2.10.0

# import statsmodels
# statsmodels.__version__
# Out:
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.7/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.19.5)

# %% [markdown]
# ### load file list

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-05-17/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-05-17 BTCUSDT.xlsx', '2021-05-17 ETHUSDT.xlsx', '2021-05-17 BCHUSDT.xlsx', '2021-05-17 XRPUSDT.xlsx', '2021-05-17 EOSUSDT.xlsx', '2021-05-17 LTCUSDT.xlsx', '2021-05-17 ETCUSDT.xlsx', '2021-05-17 LINKUSDT.xlsx', '2021-05-17 XLMUSDT.xlsx', '2021-05-17 ADAUSDT.xlsx', '2021-05-17 XMRUSDT.xlsx', '2021-05-17 SXPUSDT.xlsx', '2021-05-17 KAVAUSDT.xlsx', '2021-05-17 BANDUSDT.xlsx', '2021-05-17 DASHUSDT.xlsx', '2021-05-17 ZECUSDT.xlsx', '2021-05-17 XTZUSDT.xlsx', '2021-05-17 BNBUSDT.xlsx', '2021-05-17 ATOMUSDT.xlsx', '2021-05-17 ONTUSDT.xlsx', '2021-05-17 IOTAUSDT.xlsx', '2021-05-17 BATUSDT.xlsx', '2021-05-17 NEOUSDT.xlsx', '2021-05-17 QTUMUSDT.xlsx', '2021-05-17 WAVESUSDT.xlsx', '2021-05-17 MKRUSDT.xlsx', '2021-05-17 SNXUSDT.xlsx', '2021-05-17 DOTUSDT.xlsx', '2021-05-17 THETAUSDT.xlsx', '2021-05-17 ALGOUSDT.xlsx', '2021-05-17 KNCUSDT.xlsx', '2021-05-17 ZRXUSDT.xlsx', '2021-05-17 COMPUSDT.xlsx', '2021-05-17 OMGUSDT.xlsx']

# %% [markdown]
# ### custom model

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

# from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model

# %%
print(tf.__version__)
print(keras.__version__)
# Out:
# 1.15.2
# 2.3.1

# %% [markdown]
# ### all in one loop

# %%
from funcs_indicator import *
import matplotlib.pyplot as plt

# import mpl_finance as mf


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None


#           load saved npy & trained model        #
load_npy = False
load_model = False


seed = 1
random_state = 201
np.random.seed(seed)

fee = 0.0006
lvrg = 5

for i in range(len(candis)):

  keys = [candis[i]]

  #     we already predict eth      #
  if 'kava'.upper() not in candis[i]:
    continue

  # if 'comp'.upper() not in candis[i]:
  #   continue

  for key in keys:  
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))

        
    #       long      #
    # pr = (ohlcv['close'].pct_change() - fee) * lvrg + 1   
    pr = (ohlcv['close'].shift(1) / ohlcv['close'] - fee - 1) * lvrg + 1


    #       long liqudation     #
    lq = (ohlcv['low'] / ohlcv['close'].shift(1) - fee - 1) * lvrg + 1

    #       short       # <-- 이거를 단순히 minus 를 붙여도 되는걸까

    #       short liqudation     #
    # s_lq = (ohlcv['high'] / ohlcv['close'].shift(1) - fee) * lvrg + 1
    

    #       fill na with 1.0      #
    # pr = np.where(np.isnan(pr), 1, pr)
    # # s_pr = np.where(np.isnan(s_pr), 1, pr)
    # lq = np.where(np.isnan(lq), 1, lq)


    # #       set lq      #
    # pr = np.where((pr != 1) & (lq <= 0), 0, pr)

    # print("len(pr[pr < 0]) :", len(pr[pr < 0]))
    # break

    org_wr = len(pr[pr > 1]) / len(pr[pr != 1])

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(pr))
    plt.title("%s\norg_wr : %.3f\n acc_pr : %.3f" % (key, org_wr, np.cumprod(pr)[-1]))


    #                    strat                   #

    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) < ohlcv['close'].shift(3)), pr, 1)


    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
    #                     (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
    #                     (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)), pr, 1)


    strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
                        (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
                        (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
                        (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)) & 
                        (ohlcv['close'].shift(5) < ohlcv['close'].shift(6)), pr, 1)
    
    # strat_pr = np.where((ohlcv['high'].shift(2) > ohlcv['high'].shift(3))& 
    #                     (ohlcv['close'].shift(1) > ohlcv['close'].shift(2)), pr, 1)


    wr = len(strat_pr[strat_pr > 1]) / len(strat_pr[strat_pr != 1])

    plt.subplot(122)
    plt.plot(np.cumprod(strat_pr))
    plt.title("%s\norg_wr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr, np.cumprod(strat_pr)[-1]))


    # #                  sl cut                #
    # sl_line = ohlcv['low'].rolling(250).min().shift(1)
    # # sl_line = ohlcv['low'].shift(1)

    # strat_pr_sl = np.where((strat_pr != 1) & (sl_line > ohlcv['low']), 
    #                      1 + lvrg * (sl_line / ohlcv['close'].shift(1) - 1 - fee), strat_pr)


    # wr_sl = len(strat_pr_sl[strat_pr_sl > 1]) / len(strat_pr_sl[strat_pr_sl != 1])
    # # wl_pr_ratio = np.mean(strat_pr[strat_pr > 1]) / np.mean(strat_pr[strat_pr < 1])
    # # wl_pr_ratio = np.cumprod(strat_pr[strat_pr > 1])[-1] / np.cumprod(strat_pr[strat_pr < 1])[-1]

    # plt.subplot(122)
    # plt.plot(np.cumprod(strat_pr_sl))
    # plt.title("%s\norg_pr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr_sl, np.cumprod(strat_pr_sl)[-1]))


    plt.show()
    # break

    period = 45
    symbol_name = key.split(' ')[1].split('.')[0]      

    x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rdescend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
    pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rdescend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
    index_save_path = current_path + 'npy/' + '%s_cnn_updown_index_train_rdescend_ohlcv_%s_tssplit.npy' % (period, symbol_name)



    if not load_npy:

      from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
      from sklearn.model_selection import train_test_split
      from datetime import datetime

      from funcs_indicator import *

      def min_max_scale(npy_x):

        return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[np.sum(np.isnan(pr)):]

      sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

      #       scale with price    #
      ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

      ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
      sar = lucid_sar(sliced_ohlcv)
      ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
      senkou1, senkou2 = ichimoku(sliced_ohlcv)

      #     min max scale   #
      # vol = ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]
      vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

      pr_list = pr[np.sum(np.isnan(pr)):]
      print("len(ohlc) :", len(ohlc))
      print("len(pr_list) :", len(pr_list))

      # break


      #       set params    #
      period = 45
      key_i = i

      plotting = True

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(ohlc)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          # temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

          temp_close = min_max_scale(temp_ohlc[:, [3]])    

          price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          ind_temp_ohlc = min_max_scale(temp_ohlc)
          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


          if plotting:

            plt.plot(ind_temp_ohlc)
            plt.show()
            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          #                   feature selection                   #        
          temp_data = np.hstack((ind_temp_ohlc, temp_vol))

          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          # temp_data = temp_ohlc[:, [3]]
          # temp_data = ind_temp_ohlc[:, [3]]
          # temp_data = temp_close

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      # input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)


      # _, row, col, _ = input_x.shape
      # _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      #                 don't shuffle timeseries data                 #
      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)


      np.save(x_save_path, x_train)
      np.save(x_save_path.replace('x_train', 'x_val'), x_val)
      np.save(x_save_path.replace('x_train', 'x_test'), x_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('x series saved !')

      np.save(pr_save_path, pr_train)
      np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
      np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('pr series saved !')
      
      np.save(index_save_path, index_train)
      np.save(index_save_path.replace('index_train', 'index_val'), index_val)
      np.save(index_save_path.replace('index_train', 'index_test'), index_test)
      print('index series saved !')

    else:
      
      x_train = np.load(x_save_path)
      x_val = np.load(x_save_path.replace('x_train', 'x_val'))
      x_test = np.load(x_save_path.replace('x_train', 'x_test'))
      print('x series loaded !')


      pr_train = np.load(pr_save_path)
      pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
      pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
      print('y series loaded !')


      index_train = np.load(index_save_path, allow_pickle=True)
      index_val = np.load(index_save_path.replace('index_train', 'index_val'), allow_pickle=True)
      index_test = np.load(index_save_path.replace('index_train', 'index_test'), allow_pickle=True)
      print('index series loaded !')




    #       pr_thresh by percentage 0.285     #
    plt.plot(pr)
    plt.show()
    
    sorted_pr = sorted(pr, reverse=True)
    pct = 0.285
    len_pct = int(len(pr) * pct)
    pr_thresh = sorted_pr[len_pct]
    print("pr_thresh :", pr_thresh)

    from keras.utils import np_utils

    # from keras.preprocessing.image import ImageDataGenerator 
    from sklearn.utils import class_weight


    def class_ratio(in_list):

      return in_list / in_list[1]
      
    y_train = np.where(pr_train > pr_thresh, 1, 0)
    y_test = np.where(pr_test > pr_thresh, 1, 0)
    y_val = np.where(pr_val > pr_thresh, 1, 0)

    print('x_train.shape :', x_train.shape)
    print('x_test.shape :', x_test.shape)
    print('x_val.shape :', x_val.shape)
    print('y_train.shape :', y_train.shape)
    print('y_test.shape :', y_test.shape)
    print('y_val.shape :', y_val.shape)

    # try:
    print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
    print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
    print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

    # except Exception as e:
      # print(e)

    label = y_train.reshape(-1, )
    class_weights = class_weight.compute_class_weight('balanced', 
                                                        classes=np.unique(label),
                                                        y=label)
    class_weights = dict(enumerate(class_weights))
    print('class_weights :', class_weights)

    # sample_weight = np.ones(shape=(len(y_train),))
    # sample_weight[(y_train == 1).reshape(-1,)] = 1.5
    # print('sample_weight[:20] :', sample_weight[:20])

    num_classes = 2

    print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
    print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
    print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

    print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
    print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
    print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

    y_train_ohe = np_utils.to_categorical(y_train, num_classes)
    y_val_ohe = np_utils.to_categorical(y_val, num_classes)
    y_test_ohe = np_utils.to_categorical(y_test, num_classes)
    print('y_train_ohe.shape :', y_train_ohe.shape)
    print('y_val_ohe.shape :', y_val_ohe.shape)
    print('y_test_ohe.shape :', y_test_ohe.shape)

    from keras.preprocessing.image import ImageDataGenerator 

    datagen = ImageDataGenerator( 
        # rotation_range = 45,
        # zoom_range = 0.5,
        # shear_range = 0.5,
        # horizontal_flip = True,
        # vertical_flip = True,
        # width_shift_range=0.5,
        # height_shift_range=0.5,
        # fill_mode = 'nearest'
        )

    valgen = ImageDataGenerator( 
        )

    datagen.fit(x_train)
    valgen.fit(x_val)


    batch_size = 512


    for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

        plt.suptitle("train x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break

    for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

        plt.suptitle("val x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break
        
    train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
    val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
    # break

    

    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'

    # batch_size = 512

    K.clear_session()


    #       we can use trained without lqset    #
    model_name = 'classifier_%s_cnn_updown_rdescend_%s_tf1_%s_tvnon_shuffle.h5' % (period, int(pct * 1000), symbol_name)

    if not load_model:

      from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

      model = FER_Model(input_shape=x_train.shape[1:])
      # opt = Adam(lr=0.00001, decay=0.000005)
      opt = Adam( learning_rate=1e-5, decay=5e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-7)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir=board_path,
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_loss', patience=500)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]
      # callbacks_list = [checkpoint, checkpoint2]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 3000
      history = model.fit_generator(train_flow, 
                          steps_per_epoch=len(x_train) / batch_size, 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=val_flow,  
                          validation_steps=len(x_val) / batch_size,
                          shuffle=False)
      
    
    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'


    model = keras.models.load_model(ckpt_path + model_name)

    test_result = model.predict(x_test)
    # test_result = model.predict(test_set)

    print('test_result.shape :', test_result.shape)
    # print('pr_val.shape :', pr_val.shape)

    y_score = test_result[:, [1]]
    print('y_test[:5] :', y_test.reshape(-1,)[:5])
    # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
    print('y_score[:5] :', y_score[:5])
    # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

    print('y_test.shape :', y_test.shape)
    print('y_score.shape :', y_score.shape)

    print('len(y_test) :', len(y_test))

    #     precision recall curve   #
    precision, recall, threshold = precision_recall_curve(y_test, y_score)
    precision, recall = precision[:-1], recall[:-1]

    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    plt.show()
    # print(y_pred)


    # threshold = [0.65]
    # print('threshold :', threshold)
    # break

    acc_pr_bythr = []
    new_thresh = []
    temp_pr_list = []

    for thresh in threshold:
      
      # if thresh < 0.5:
      #     continue

      y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
      # print('y_pred.shape :', y_pred.shape)
      # print('y_pred :', y_pred)

      #     compare precision     #

      # print('precision :', precision_score(y_test, y_pred))
      # print('recall :', recall_score(y_test, y_pred))
      # print()

      # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
      # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

      # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
      # # plt.show()  
      # print()

      #     check win-ratio improvement     #
      cmat = confusion_matrix(y_test, y_pred)
      # print(cmat)
      # print(np.sum(cmat, axis=1))

      test_size = len(y_test)
      test_pr_list = pr_test
      # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

      org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
      ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
      # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

      # print('pr_test.shape :', pr_test.shape)

      # print(y_pred)
      # print(test_pr_list)

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1)

      # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
      # print('pred_pr_list.shape :', pred_pr_list.shape)

      temp_pr_list.append(pred_pr_list)

      # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
      #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
      #   print('thresh :', thresh)
        
      # if len(threshold) == 1:
    #   plt.figure(figsize=(10, 5))
    #   plt.subplot(121)
    #   plt.plot(np.cumprod(test_pr_list))
    #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
    # # plt.show()

    #   plt.subplot(122)
    #   plt.plot(np.cumprod(pred_pr_list))
    #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
    #   plt.show()


      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)


    print('acc_pr_bythr :', acc_pr_bythr)

    plt.figure(figsize=(13, 5))
    plt.subplot(131)
    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    # plt.show()
    plt.subplot(132)
    plt.plot(new_thresh, acc_pr_bythr)
    plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')

    best_thr = new_thresh[np.argmax(acc_pr_bythr)]
    plt.axvline(best_thr, linestyle='--', color='r')
    plt.title(symbol_name + '\n' + str(best_thr))

    plt.subplot(133)
    plt.plot(np.cumprod(temp_pr_list[np.argmax(acc_pr_bythr)]))

    plt.show()
# Out:
# start_stamp : 0
# len(ohlcv) : 14056
# len(ohlc) : 14055
# len(pr_list) : 14055
# np.array(data_x).shape : (13934, 45, 5)
# input_x.shape : (13934, 45, 5, 3)
# input_x.dtype : float32
# input_pr.shape : (13934, 1)
# input_ud.shape : (13934, 1)
# input_index.shape : (13934, 1)
# total_x.shape : (13934, 45, 5, 3)
# total_pr.shape : (13934, 1)
# total_ud.shape : (13934, 1)
# prev_index.shape : (13934, 1)
# (array([Timestamp('2020-07-31 05:29:59.999000'),
#        Timestamp('2020-07-31 05:59:59.999000'),
#        Timestamp('2020-07-31 06:29:59.999000'), ...,
#        Timestamp('2021-05-17 10:59:59.999000'),
#        Timestamp('2021-05-17 11:29:59.999000'),
#        Timestamp('2021-05-17 11:59:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (8360,)
# stamp_val.shape : (2787,)
# stamp_test.shape : (2787,)
# HBox(children=(FloatProgress(value=0.0, max=13934.0), HTML(value='')))
# x_train.shape : (8360, 45, 5, 3)
# x_val.shape : (2787, 45, 5, 3)
# x_test.shape : (2787, 45, 5, 3)
# x series saved !
# pr series saved !
# index series saved !
# pr_thresh : 1.0247898866608542
# x_train.shape : (8360, 45, 5, 3)
# x_test.shape : (2787, 45, 5, 3)
# x_val.shape : (2787, 45, 5, 3)
# y_train.shape : (8360, 1)
# y_test.shape : (2787, 1)
# y_val.shape : (2787, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([5958, 2402])) [2.48043297 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([1988,  799])) [2.48811014 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2017,  770])) [2.61948052 1.        ]
# class_weights : {0: 0.7015777106411547, 1: 1.7402164862614489}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (8360, 2)
# y_val_ohe.shape : (2787, 2)
# y_test_ohe.shape : (2787, 2)
# Epoch 1/3000
#  - 1s - loss: 0.8180 - accuracy: 0.4998 - val_loss: 0.6354 - val_accuracy: 0.7133
#
# Epoch 00001: val_loss improved from inf to 0.63540, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rdescend_285_tf1_KAVAUSDT_tvnon_shuffle.h5
# Epoch 2/3000
#  - 1s - loss: 0.7082 - accuracy: 0.5398 - val_loss: 0.5914 - val_accuracy: 0.7119
#
# Epoch 00002: val_loss improved from 0.63540 to 0.59137, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rdescend_285_tf1_KAVAUSDT_tvnon_shuffle.h5
# Epoch 3/3000
#  - 1s - loss: 0.6797 - accuracy: 0.5760 - val_loss: 0.6159 - val_accuracy: 0.7126
#
# Epoch 00003: val_loss did not improve from 0.59137
# Epoch 4/3000
#  - 1s - loss: 0.6620 - accuracy: 0.6020 - val_loss: 0.6018 - val_accuracy: 0.7112
#
# Epoch 00004: val_loss did not improve from 0.59137
# Epoch 5/3000
#  - 1s - loss: 0.6487 - accuracy: 0.6197 - val_loss: 0.5981 - val_accuracy: 0.7122
#
# Epoch 00005: val_loss did not improve from 0.59137
# Epoch 6/3000
#  - 1s - loss: 0.6383 - accuracy: 0.6437 - val_loss: 0.6025 - val_accuracy: 0.7133
#
# Epoch 00006: val_loss did not improve from 0.59137
# Epoch 7/3000
#  - 1s - loss: 0.6275 - accuracy: 0.6409 - val_loss: 0.5983 - val_accuracy: 0.7126
#
# Epoch 00007: val_loss did not improve from 0.59137
# Epoch 8/3000
#  - 1s - loss: 0.6149 - accuracy: 0.6804 - val_loss: 0.6054 - val_accuracy: 0.7094
#
# Epoch 00008: val_loss did not improve from 0.59137
# Epoch 9/3000
#  - 1s - loss: 0.6116 - accuracy: 0.6831 - val_loss: 0.6138 - val_accuracy: 0.7018
#
# Epoch 00009: val_loss did not improve from 0.59137
# Epoch 10/3000
#  - 1s - loss: 0.6063 - accuracy: 0.6813 - val_loss: 0.6263 - val_accuracy: 0.6925
#
# Epoch 00010: val_loss did not improve from 0.59137
# Epoch 11/3000
#  - 1s - loss: 0.5933 - accuracy: 0.7029 - val_loss: 0.6242 - val_accuracy: 0.6742
#
# Epoch 00011: val_loss did not improve from 0.59137
# Epoch 12/3000
#  - 1s - loss: 0.5828 - accuracy: 0.7001 - val_loss: 0.6132 - val_accuracy: 0.6764
#
# Epoch 00012: val_loss did not improve from 0.59137
# Epoch 13/3000
#  - 1s - loss: 0.5698 - accuracy: 0.7193 - val_loss: 0.6294 - val_accuracy: 0.6677
#
# Epoch 00013: val_loss did not improve from 0.59137
# Epoch 14/3000
#  - 1s - loss: 0.5592 - accuracy: 0.7432 - val_loss: 0.6175 - val_accuracy: 0.6738
#
# Epoch 00014: val_loss did not improve from 0.59137
# Epoch 15/3000
#  - 1s - loss: 0.5554 - accuracy: 0.7334 - val_loss: 0.6398 - val_accuracy: 0.6197
#
# Epoch 00015: val_loss did not improve from 0.59137
# Epoch 16/3000
#  - 1s - loss: 0.5464 - accuracy: 0.7462 - val_loss: 0.6216 - val_accuracy: 0.6864
#
# Epoch 00016: val_loss did not improve from 0.59137
# Epoch 17/3000
#  - 1s - loss: 0.5322 - accuracy: 0.7623 - val_loss: 0.6191 - val_accuracy: 0.6717
#
# Epoch 00017: val_loss did not improve from 0.59137
# Epoch 18/3000
#  - 1s - loss: 0.5242 - accuracy: 0.7733 - val_loss: 0.6153 - val_accuracy: 0.6555
#
# Epoch 00018: val_loss did not improve from 0.59137
# Epoch 19/3000
#  - 1s - loss: 0.5138 - accuracy: 0.7798 - val_loss: 0.6565 - val_accuracy: 0.6480
#
# Epoch 00019: val_loss did not improve from 0.59137
# Epoch 20/3000
#  - 1s - loss: 0.5133 - accuracy: 0.7750 - val_loss: 0.6713 - val_accuracy: 0.6028
#
# Epoch 00020: val_loss did not improve from 0.59137
# Epoch 21/3000
#  - 1s - loss: 0.5077 - accuracy: 0.7701 - val_loss: 0.6625 - val_accuracy: 0.6060
#
# Epoch 00021: val_loss did not improve from 0.59137
# Epoch 22/3000
#  - 1s - loss: 0.4937 - accuracy: 0.7978 - val_loss: 0.6251 - val_accuracy: 0.6189
#
# Epoch 00022: val_loss did not improve from 0.59137
# Epoch 23/3000
#  - 1s - loss: 0.4793 - accuracy: 0.8111 - val_loss: 0.6392 - val_accuracy: 0.6735
#
# Epoch 00023: val_loss did not improve from 0.59137
# Epoch 24/3000
#  - 1s - loss: 0.4768 - accuracy: 0.8159 - val_loss: 0.6837 - val_accuracy: 0.5938
#
# Epoch 00024: val_loss did not improve from 0.59137
# Epoch 25/3000
#  - 1s - loss: 0.4683 - accuracy: 0.8142 - val_loss: 0.6088 - val_accuracy: 0.6563
#
# Epoch 00025: val_loss did not improve from 0.59137
# Epoch 26/3000
#  - 1s - loss: 0.4619 - accuracy: 0.8233 - val_loss: 0.6381 - val_accuracy: 0.6114
#
# Epoch 00026: val_loss did not improve from 0.59137
# Epoch 27/3000
#  - 1s - loss: 0.4505 - accuracy: 0.8352 - val_loss: 0.6782 - val_accuracy: 0.6333
#
# Epoch 00027: val_loss did not improve from 0.59137
# Epoch 28/3000
#  - 1s - loss: 0.4472 - accuracy: 0.8301 - val_loss: 0.5893 - val_accuracy: 0.6850
#
# Epoch 00028: val_loss improved from 0.59137 to 0.58933, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rdescend_285_tf1_KAVAUSDT_tvnon_shuffle.h5
# Epoch 29/3000
#  - 1s - loss: 0.4417 - accuracy: 0.8403 - val_loss: 0.6738 - val_accuracy: 0.5999
#
# Epoch 00029: val_loss did not improve from 0.58933
# Epoch 30/3000
#  - 1s - loss: 0.4333 - accuracy: 0.8383 - val_loss: 0.7006 - val_accuracy: 0.6164
#
# Epoch 00030: val_loss did not improve from 0.58933
# Epoch 31/3000
#  - 1s - loss: 0.4246 - accuracy: 0.8508 - val_loss: 0.6830 - val_accuracy: 0.6265
#
# Epoch 00031: val_loss did not improve from 0.58933
# Epoch 32/3000
#  - 1s - loss: 0.4124 - accuracy: 0.8632 - val_loss: 0.6578 - val_accuracy: 0.6103
#
# Epoch 00032: val_loss did not improve from 0.58933
# Epoch 33/3000
#  - 1s - loss: 0.4081 - accuracy: 0.8638 - val_loss: 0.6656 - val_accuracy: 0.6290
#
# Epoch 00033: val_loss did not improve from 0.58933
# Epoch 34/3000
#  - 1s - loss: 0.3994 - accuracy: 0.8739 - val_loss: 0.6663 - val_accuracy: 0.6520
#
# Epoch 00034: val_loss did not improve from 0.58933
# Epoch 35/3000
#  - 1s - loss: 0.3955 - accuracy: 0.8730 - val_loss: 0.6299 - val_accuracy: 0.6265
#
# Epoch 00035: val_loss did not improve from 0.58933
# Epoch 36/3000
#  - 1s - loss: 0.3852 - accuracy: 0.8773 - val_loss: 0.6944 - val_accuracy: 0.6121
#
# Epoch 00036: val_loss did not improve from 0.58933
# Epoch 37/3000
#  - 1s - loss: 0.3753 - accuracy: 0.8834 - val_loss: 0.7180 - val_accuracy: 0.6268
#
# Epoch 00037: val_loss did not improve from 0.58933
# Epoch 38/3000
#  - 1s - loss: 0.3730 - accuracy: 0.8836 - val_loss: 0.6057 - val_accuracy: 0.6753
#
# Epoch 00038: val_loss did not improve from 0.58933
# Epoch 39/3000
#  - 1s - loss: 0.3696 - accuracy: 0.8852 - val_loss: 0.6731 - val_accuracy: 0.6319
#
# Epoch 00039: val_loss did not improve from 0.58933
# Epoch 40/3000
#  - 1s - loss: 0.3583 - accuracy: 0.8943 - val_loss: 0.6910 - val_accuracy: 0.6358
#
# Epoch 00040: val_loss did not improve from 0.58933
# Epoch 41/3000
#  - 1s - loss: 0.3517 - accuracy: 0.9016 - val_loss: 0.6962 - val_accuracy: 0.6258
#
# Epoch 00041: val_loss did not improve from 0.58933
# Epoch 42/3000
#  - 1s - loss: 0.3427 - accuracy: 0.9077 - val_loss: 0.6740 - val_accuracy: 0.6111
#
# Epoch 00042: val_loss did not improve from 0.58933
# Epoch 43/3000
#  - 1s - loss: 0.3364 - accuracy: 0.9071 - val_loss: 0.6780 - val_accuracy: 0.6577
#
# Epoch 00043: val_loss did not improve from 0.58933
# Epoch 44/3000
#  - 1s - loss: 0.3383 - accuracy: 0.9062 - val_loss: 0.7555 - val_accuracy: 0.5874
#
# Epoch 00044: val_loss did not improve from 0.58933
# Epoch 45/3000
#  - 1s - loss: 0.3232 - accuracy: 0.9159 - val_loss: 0.6585 - val_accuracy: 0.6537
#
# Epoch 00045: val_loss did not improve from 0.58933
# Epoch 46/3000
#  - 1s - loss: 0.3174 - accuracy: 0.9201 - val_loss: 0.6692 - val_accuracy: 0.6408
#
# Epoch 00046: val_loss did not improve from 0.58933
# Epoch 47/3000
#  - 1s - loss: 0.3119 - accuracy: 0.9273 - val_loss: 0.7379 - val_accuracy: 0.5906
#
# Epoch 00047: val_loss did not improve from 0.58933
# Epoch 48/3000
#  - 1s - loss: 0.3108 - accuracy: 0.9138 - val_loss: 0.5543 - val_accuracy: 0.6598
#
# Epoch 00048: val_loss improved from 0.58933 to 0.55431, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rdescend_285_tf1_KAVAUSDT_tvnon_shuffle.h5
# Epoch 49/3000
#  - 1s - loss: 0.3078 - accuracy: 0.9255 - val_loss: 0.7439 - val_accuracy: 0.6035
#
# Epoch 00049: val_loss did not improve from 0.55431
# Epoch 50/3000
#  - 1s - loss: 0.2959 - accuracy: 0.9291 - val_loss: 0.5988 - val_accuracy: 0.6534
#
# Epoch 00050: val_loss did not improve from 0.55431
# Epoch 51/3000
#  - 1s - loss: 0.2887 - accuracy: 0.9361 - val_loss: 0.6749 - val_accuracy: 0.6254
#
# Epoch 00051: val_loss did not improve from 0.55431
# Epoch 52/3000
#  - 1s - loss: 0.2849 - accuracy: 0.9355 - val_loss: 0.7060 - val_accuracy: 0.6211
#
# Epoch 00052: val_loss did not improve from 0.55431
# Epoch 53/3000
#  - 1s - loss: 0.2813 - accuracy: 0.9360 - val_loss: 0.6949 - val_accuracy: 0.6527
#
# Epoch 00053: val_loss did not improve from 0.55431
# Epoch 54/3000
#  - 1s - loss: 0.2763 - accuracy: 0.9401 - val_loss: 0.7239 - val_accuracy: 0.6355
#
# Epoch 00054: val_loss did not improve from 0.55431
# Epoch 55/3000
#  - 1s - loss: 0.2688 - accuracy: 0.9433 - val_loss: 0.6621 - val_accuracy: 0.6218
#
# Epoch 00055: val_loss did not improve from 0.55431
# Epoch 56/3000
#  - 1s - loss: 0.2623 - accuracy: 0.9432 - val_loss: 0.7052 - val_accuracy: 0.6584
#
# Epoch 00056: val_loss did not improve from 0.55431
# Epoch 57/3000
#  - 1s - loss: 0.2607 - accuracy: 0.9469 - val_loss: 0.6647 - val_accuracy: 0.6444
#
# Epoch 00057: val_loss did not improve from 0.55431
# Epoch 58/3000
#  - 1s - loss: 0.2569 - accuracy: 0.9474 - val_loss: 0.7405 - val_accuracy: 0.6128
#
# Epoch 00058: val_loss did not improve from 0.55431
# Epoch 59/3000
#  - 1s - loss: 0.2480 - accuracy: 0.9528 - val_loss: 0.6409 - val_accuracy: 0.6545
#
# Epoch 00059: val_loss did not improve from 0.55431
# Epoch 60/3000
#  - 1s - loss: 0.2446 - accuracy: 0.9557 - val_loss: 0.7547 - val_accuracy: 0.6304
#
# Epoch 00060: val_loss did not improve from 0.55431
# Epoch 61/3000
#  - 1s - loss: 0.2373 - accuracy: 0.9556 - val_loss: 0.6704 - val_accuracy: 0.6182
#
# Epoch 00061: val_loss did not improve from 0.55431
# Epoch 62/3000
#  - 1s - loss: 0.2322 - accuracy: 0.9584 - val_loss: 0.6927 - val_accuracy: 0.6416
#
# Epoch 00062: val_loss did not improve from 0.55431
# Epoch 63/3000
#  - 1s - loss: 0.2279 - accuracy: 0.9646 - val_loss: 0.6898 - val_accuracy: 0.6276
#
# Epoch 00063: val_loss did not improve from 0.55431
# Epoch 64/3000
#  - 1s - loss: 0.2209 - accuracy: 0.9663 - val_loss: 0.6342 - val_accuracy: 0.6537
#
# Epoch 00064: val_loss did not improve from 0.55431
# Epoch 65/3000
#  - 1s - loss: 0.2168 - accuracy: 0.9685 - val_loss: 0.6467 - val_accuracy: 0.6545
#
# Epoch 00065: val_loss did not improve from 0.55431
# Epoch 66/3000
#  - 1s - loss: 0.2128 - accuracy: 0.9696 - val_loss: 0.7408 - val_accuracy: 0.6311
#
# Epoch 00066: val_loss did not improve from 0.55431
# Epoch 67/3000
#  - 1s - loss: 0.2071 - accuracy: 0.9709 - val_loss: 0.7472 - val_accuracy: 0.6308
#
# Epoch 00067: val_loss did not improve from 0.55431
# Epoch 68/3000
#  - 1s - loss: 0.2077 - accuracy: 0.9707 - val_loss: 0.7658 - val_accuracy: 0.6394
#
# Epoch 00068: val_loss did not improve from 0.55431
# Epoch 69/3000
#  - 1s - loss: 0.2000 - accuracy: 0.9743 - val_loss: 0.6251 - val_accuracy: 0.6430
#
# Epoch 00069: val_loss did not improve from 0.55431
# Epoch 70/3000
#  - 1s - loss: 0.1961 - accuracy: 0.9734 - val_loss: 0.6597 - val_accuracy: 0.6559
#
# Epoch 00070: val_loss did not improve from 0.55431
# Epoch 71/3000
#  - 1s - loss: 0.1948 - accuracy: 0.9726 - val_loss: 0.7187 - val_accuracy: 0.6563
#
# Epoch 00071: val_loss did not improve from 0.55431
# Epoch 72/3000
#  - 1s - loss: 0.1876 - accuracy: 0.9780 - val_loss: 0.8322 - val_accuracy: 0.6355
#
# Epoch 00072: val_loss did not improve from 0.55431
# Epoch 73/3000
#  - 1s - loss: 0.1841 - accuracy: 0.9785 - val_loss: 0.7248 - val_accuracy: 0.6229
#
# Epoch 00073: val_loss did not improve from 0.55431
# Epoch 74/3000
#  - 1s - loss: 0.1832 - accuracy: 0.9761 - val_loss: 0.7733 - val_accuracy: 0.6537
#
# Epoch 00074: val_loss did not improve from 0.55431
# Epoch 75/3000
#  - 1s - loss: 0.1833 - accuracy: 0.9744 - val_loss: 0.6862 - val_accuracy: 0.6814
#
# Epoch 00075: val_loss did not improve from 0.55431
# Epoch 76/3000
#  - 1s - loss: 0.1795 - accuracy: 0.9769 - val_loss: 0.7935 - val_accuracy: 0.6459
#
# Epoch 00076: val_loss did not improve from 0.55431
# Epoch 77/3000
#  - 1s - loss: 0.1700 - accuracy: 0.9825 - val_loss: 0.7445 - val_accuracy: 0.6441
#
# Epoch 00077: val_loss did not improve from 0.55431
# Epoch 78/3000
#  - 1s - loss: 0.1645 - accuracy: 0.9848 - val_loss: 0.7085 - val_accuracy: 0.6498
#
# Epoch 00078: val_loss did not improve from 0.55431
# Epoch 79/3000
#  - 1s - loss: 0.1652 - accuracy: 0.9818 - val_loss: 0.8543 - val_accuracy: 0.6480
#
# Epoch 00079: val_loss did not improve from 0.55431
# Epoch 80/3000
#  - 1s - loss: 0.1606 - accuracy: 0.9849 - val_loss: 0.7332 - val_accuracy: 0.6631
#
# Epoch 00080: val_loss did not improve from 0.55431
# Epoch 81/3000
#  - 1s - loss: 0.1565 - accuracy: 0.9837 - val_loss: 0.7228 - val_accuracy: 0.6706
#
# Epoch 00081: val_loss did not improve from 0.55431
# Epoch 82/3000
#  - 1s - loss: 0.1536 - accuracy: 0.9877 - val_loss: 0.7395 - val_accuracy: 0.6372
#
# Epoch 00082: val_loss did not improve from 0.55431
# Epoch 83/3000
#  - 1s - loss: 0.1524 - accuracy: 0.9858 - val_loss: 0.8329 - val_accuracy: 0.6229
#
# Epoch 00083: val_loss did not improve from 0.55431
# Epoch 84/3000
#  - 1s - loss: 0.1483 - accuracy: 0.9858 - val_loss: 0.7118 - val_accuracy: 0.6390
#
# Epoch 00084: val_loss did not improve from 0.55431
# Epoch 85/3000
#  - 1s - loss: 0.1426 - accuracy: 0.9883 - val_loss: 0.6642 - val_accuracy: 0.6469
#
# Epoch 00085: val_loss did not improve from 0.55431
# Epoch 86/3000
#  - 1s - loss: 0.1408 - accuracy: 0.9902 - val_loss: 0.7457 - val_accuracy: 0.6512
#
# Epoch 00086: val_loss did not improve from 0.55431
# Epoch 87/3000
#  - 1s - loss: 0.1361 - accuracy: 0.9911 - val_loss: 0.6906 - val_accuracy: 0.6491
#
# Epoch 00087: val_loss did not improve from 0.55431
# Epoch 88/3000
#  - 1s - loss: 0.1356 - accuracy: 0.9913 - val_loss: 0.7041 - val_accuracy: 0.6394
#
# Epoch 00088: val_loss did not improve from 0.55431
# Epoch 89/3000
#  - 1s - loss: 0.1316 - accuracy: 0.9911 - val_loss: 0.7057 - val_accuracy: 0.6520
#
# Epoch 00089: val_loss did not improve from 0.55431
# Epoch 90/3000
#  - 1s - loss: 0.1271 - accuracy: 0.9928 - val_loss: 0.8126 - val_accuracy: 0.6430
#
# Epoch 00090: val_loss did not improve from 0.55431
# Epoch 91/3000
#  - 1s - loss: 0.1264 - accuracy: 0.9928 - val_loss: 0.8458 - val_accuracy: 0.6537
#
# Epoch 00091: val_loss did not improve from 0.55431
# Epoch 92/3000
#  - 1s - loss: 0.1244 - accuracy: 0.9933 - val_loss: 0.7431 - val_accuracy: 0.6598
#
# Epoch 00092: val_loss did not improve from 0.55431
# Epoch 93/3000
#  - 1s - loss: 0.1203 - accuracy: 0.9937 - val_loss: 0.7916 - val_accuracy: 0.6512
#
# Epoch 00093: val_loss did not improve from 0.55431
# Epoch 94/3000
#  - 1s - loss: 0.1189 - accuracy: 0.9943 - val_loss: 0.7254 - val_accuracy: 0.6584
#
# Epoch 00094: val_loss did not improve from 0.55431
# Epoch 95/3000
#  - 1s - loss: 0.1164 - accuracy: 0.9944 - val_loss: 0.8594 - val_accuracy: 0.6376
#
# Epoch 00095: val_loss did not improve from 0.55431
# Epoch 96/3000
#  - 1s - loss: 0.1158 - accuracy: 0.9932 - val_loss: 0.7787 - val_accuracy: 0.6595
#
# Epoch 00096: val_loss did not improve from 0.55431
# Epoch 97/3000
#  - 1s - loss: 0.1119 - accuracy: 0.9953 - val_loss: 0.7561 - val_accuracy: 0.6520
#
# Epoch 00097: val_loss did not improve from 0.55431
# Epoch 98/3000
#  - 1s - loss: 0.1074 - accuracy: 0.9969 - val_loss: 0.7665 - val_accuracy: 0.6498
#
# Epoch 00098: val_loss did not improve from 0.55431
# Epoch 99/3000
#  - 1s - loss: 0.1043 - accuracy: 0.9953 - val_loss: 0.8267 - val_accuracy: 0.6649
#
# Epoch 00099: val_loss did not improve from 0.55431
# Epoch 100/3000
#  - 1s - loss: 0.1048 - accuracy: 0.9956 - val_loss: 0.6499 - val_accuracy: 0.6645
#
# Epoch 00100: val_loss did not improve from 0.55431
# Epoch 101/3000
#  - 1s - loss: 0.1017 - accuracy: 0.9963 - val_loss: 0.7955 - val_accuracy: 0.6555
#
# Epoch 00101: val_loss did not improve from 0.55431
# Epoch 102/3000
#  - 1s - loss: 0.1000 - accuracy: 0.9972 - val_loss: 0.8062 - val_accuracy: 0.6390
#
# Epoch 00102: val_loss did not improve from 0.55431
# Epoch 103/3000
#  - 1s - loss: 0.0980 - accuracy: 0.9970 - val_loss: 0.8996 - val_accuracy: 0.6423
#
# Epoch 00103: val_loss did not improve from 0.55431
# Epoch 104/3000
#  - 1s - loss: 0.0952 - accuracy: 0.9975 - val_loss: 0.7988 - val_accuracy: 0.6437
#
# Epoch 00104: val_loss did not improve from 0.55431
# Epoch 105/3000
#  - 1s - loss: 0.0932 - accuracy: 0.9977 - val_loss: 0.6659 - val_accuracy: 0.6444
#
# Epoch 00105: val_loss did not improve from 0.55431
# Epoch 106/3000
#  - 1s - loss: 0.0910 - accuracy: 0.9975 - val_loss: 0.8100 - val_accuracy: 0.6502
#
# Epoch 00106: val_loss did not improve from 0.55431
# Epoch 107/3000
#  - 1s - loss: 0.0901 - accuracy: 0.9980 - val_loss: 0.9631 - val_accuracy: 0.6667
#
# Epoch 00107: val_loss did not improve from 0.55431
# Epoch 108/3000
#  - 1s - loss: 0.0880 - accuracy: 0.9978 - val_loss: 0.7165 - val_accuracy: 0.6537
#
# Epoch 00108: val_loss did not improve from 0.55431
# Epoch 109/3000
#  - 1s - loss: 0.0870 - accuracy: 0.9980 - val_loss: 0.7490 - val_accuracy: 0.6372
#
# Epoch 00109: val_loss did not improve from 0.55431
# Epoch 110/3000
#  - 1s - loss: 0.0845 - accuracy: 0.9982 - val_loss: 0.7577 - val_accuracy: 0.6405
#
# Epoch 00110: val_loss did not improve from 0.55431
# Epoch 111/3000
#  - 1s - loss: 0.0822 - accuracy: 0.9981 - val_loss: 0.7823 - val_accuracy: 0.6448
#
# Epoch 00111: val_loss did not improve from 0.55431
# Epoch 112/3000
#  - 1s - loss: 0.0809 - accuracy: 0.9986 - val_loss: 0.8679 - val_accuracy: 0.6358
#
# Epoch 00112: val_loss did not improve from 0.55431
# Epoch 113/3000
#  - 1s - loss: 0.0819 - accuracy: 0.9981 - val_loss: 0.7915 - val_accuracy: 0.6398
#
# Epoch 00113: val_loss did not improve from 0.55431
# Epoch 114/3000
#  - 1s - loss: 0.0779 - accuracy: 0.9987 - val_loss: 0.7849 - val_accuracy: 0.6437
#
# Epoch 00114: val_loss did not improve from 0.55431
# Epoch 115/3000
#  - 1s - loss: 0.0766 - accuracy: 0.9988 - val_loss: 0.8730 - val_accuracy: 0.6398
#
# Epoch 00115: val_loss did not improve from 0.55431
# Epoch 116/3000
#  - 1s - loss: 0.0746 - accuracy: 0.9990 - val_loss: 0.7465 - val_accuracy: 0.6494
#
# Epoch 00116: val_loss did not improve from 0.55431
# Epoch 117/3000
#  - 1s - loss: 0.0733 - accuracy: 0.9989 - val_loss: 0.7988 - val_accuracy: 0.6448
#
# Epoch 00117: val_loss did not improve from 0.55431
# Epoch 118/3000
#  - 1s - loss: 0.0719 - accuracy: 0.9986 - val_loss: 0.8378 - val_accuracy: 0.6559
#
# Epoch 00118: val_loss did not improve from 0.55431
# Epoch 119/3000
#  - 1s - loss: 0.0701 - accuracy: 0.9990 - val_loss: 0.8991 - val_accuracy: 0.6624
#
# Epoch 00119: val_loss did not improve from 0.55431
# Epoch 120/3000
#  - 1s - loss: 0.0686 - accuracy: 0.9988 - val_loss: 0.6890 - val_accuracy: 0.6534
#
# Epoch 00120: val_loss did not improve from 0.55431
# Epoch 121/3000
#  - 1s - loss: 0.0670 - accuracy: 0.9992 - val_loss: 0.7452 - val_accuracy: 0.6516
#
# Epoch 00121: val_loss did not improve from 0.55431
# Epoch 122/3000
#  - 1s - loss: 0.0666 - accuracy: 0.9994 - val_loss: 0.8647 - val_accuracy: 0.6545
#
# Epoch 00122: val_loss did not improve from 0.55431
# Epoch 123/3000
#  - 1s - loss: 0.0668 - accuracy: 0.9993 - val_loss: 0.8271 - val_accuracy: 0.6541
#
# Epoch 00123: val_loss did not improve from 0.55431
# Epoch 124/3000
#  - 1s - loss: 0.0640 - accuracy: 0.9996 - val_loss: 0.8786 - val_accuracy: 0.6642
#
# Epoch 00124: val_loss did not improve from 0.55431
# Epoch 125/3000
#  - 1s - loss: 0.0619 - accuracy: 0.9995 - val_loss: 0.9901 - val_accuracy: 0.6591
#
# Epoch 00125: val_loss did not improve from 0.55431
# Epoch 126/3000
#  - 1s - loss: 0.0605 - accuracy: 0.9995 - val_loss: 0.8721 - val_accuracy: 0.6588
#
# Epoch 00126: val_loss did not improve from 0.55431
# Epoch 127/3000
#  - 1s - loss: 0.0597 - accuracy: 0.9994 - val_loss: 0.9176 - val_accuracy: 0.6606
#
# Epoch 00127: val_loss did not improve from 0.55431
# Epoch 128/3000
#  - 1s - loss: 0.0593 - accuracy: 0.9993 - val_loss: 0.8738 - val_accuracy: 0.6563
#
# Epoch 00128: val_loss did not improve from 0.55431
# Epoch 129/3000
#  - 1s - loss: 0.0580 - accuracy: 0.9995 - val_loss: 0.7850 - val_accuracy: 0.6326
#
# Epoch 00129: val_loss did not improve from 0.55431
# Epoch 130/3000
#  - 1s - loss: 0.0561 - accuracy: 0.9996 - val_loss: 0.7003 - val_accuracy: 0.6566
#
# Epoch 00130: val_loss did not improve from 0.55431
# Epoch 131/3000
#  - 1s - loss: 0.0554 - accuracy: 0.9998 - val_loss: 0.8268 - val_accuracy: 0.6451
#
# Epoch 00131: val_loss did not improve from 0.55431
# Epoch 132/3000
#  - 1s - loss: 0.0541 - accuracy: 0.9996 - val_loss: 0.9129 - val_accuracy: 0.6494
#
# Epoch 00132: val_loss did not improve from 0.55431
# Epoch 133/3000
#  - 1s - loss: 0.0528 - accuracy: 0.9996 - val_loss: 0.8206 - val_accuracy: 0.6559
#
# Epoch 00133: val_loss did not improve from 0.55431
# Epoch 134/3000
#  - 1s - loss: 0.0516 - accuracy: 0.9998 - val_loss: 1.0240 - val_accuracy: 0.6419
#
# Epoch 00134: val_loss did not improve from 0.55431
# Epoch 135/3000
#  - 1s - loss: 0.0516 - accuracy: 0.9996 - val_loss: 0.7397 - val_accuracy: 0.6459
#
# Epoch 00135: val_loss did not improve from 0.55431
# Epoch 136/3000
#  - 1s - loss: 0.0498 - accuracy: 0.9998 - val_loss: 0.9149 - val_accuracy: 0.6494
#
# Epoch 00136: val_loss did not improve from 0.55431
# Epoch 137/3000
#  - 1s - loss: 0.0496 - accuracy: 0.9999 - val_loss: 0.8297 - val_accuracy: 0.6416
#
# Epoch 00137: val_loss did not improve from 0.55431
# Epoch 138/3000
#  - 1s - loss: 0.0482 - accuracy: 0.9996 - val_loss: 1.0651 - val_accuracy: 0.6527
#
# Epoch 00138: val_loss did not improve from 0.55431
# Epoch 139/3000
#  - 1s - loss: 0.0471 - accuracy: 0.9998 - val_loss: 0.7088 - val_accuracy: 0.6559
#
# Epoch 00139: val_loss did not improve from 0.55431
# Epoch 140/3000
#  - 1s - loss: 0.0462 - accuracy: 0.9998 - val_loss: 0.8590 - val_accuracy: 0.6498
#
# Epoch 00140: val_loss did not improve from 0.55431
# Epoch 141/3000
#  - 1s - loss: 0.0453 - accuracy: 0.9998 - val_loss: 1.0085 - val_accuracy: 0.6570
#
# Epoch 00141: val_loss did not improve from 0.55431
# Epoch 142/3000
#  - 1s - loss: 0.0441 - accuracy: 0.9999 - val_loss: 0.9879 - val_accuracy: 0.6638
#
# Epoch 00142: val_loss did not improve from 0.55431
# Epoch 143/3000
#  - 1s - loss: 0.0440 - accuracy: 0.9996 - val_loss: 0.9236 - val_accuracy: 0.6527
#
# Epoch 00143: val_loss did not improve from 0.55431
# Epoch 144/3000
#  - 1s - loss: 0.0428 - accuracy: 0.9999 - val_loss: 0.8720 - val_accuracy: 0.6502
#
# Epoch 00144: val_loss did not improve from 0.55431
# Epoch 145/3000
#  - 1s - loss: 0.0417 - accuracy: 0.9998 - val_loss: 0.9971 - val_accuracy: 0.6577
#
# Epoch 00145: val_loss did not improve from 0.55431
# Epoch 146/3000
#  - 1s - loss: 0.0412 - accuracy: 0.9999 - val_loss: 0.7500 - val_accuracy: 0.6534
#
# Epoch 00146: val_loss did not improve from 0.55431
# Epoch 147/3000
#  - 1s - loss: 0.0405 - accuracy: 0.9999 - val_loss: 0.9834 - val_accuracy: 0.6537
#
# Epoch 00147: val_loss did not improve from 0.55431
# Epoch 148/3000
#  - 1s - loss: 0.0393 - accuracy: 0.9999 - val_loss: 0.8313 - val_accuracy: 0.6491
#
# Epoch 00148: val_loss did not improve from 0.55431
# Epoch 149/3000
#  - 1s - loss: 0.0388 - accuracy: 0.9999 - val_loss: 0.9534 - val_accuracy: 0.6444
#
# Epoch 00149: val_loss did not improve from 0.55431
# Epoch 150/3000
#  - 1s - loss: 0.0382 - accuracy: 0.9999 - val_loss: 0.9541 - val_accuracy: 0.6577
#
# Epoch 00150: val_loss did not improve from 0.55431
# Epoch 151/3000
#  - 1s - loss: 0.0376 - accuracy: 0.9999 - val_loss: 0.8653 - val_accuracy: 0.6537
#
# Epoch 00151: val_loss did not improve from 0.55431
# Epoch 152/3000
#  - 1s - loss: 0.0369 - accuracy: 0.9999 - val_loss: 0.8806 - val_accuracy: 0.6624
#
# Epoch 00152: val_loss did not improve from 0.55431
# Epoch 153/3000
#  - 1s - loss: 0.0361 - accuracy: 1.0000 - val_loss: 1.0059 - val_accuracy: 0.6534
#
# Epoch 00153: val_loss did not improve from 0.55431
# Epoch 154/3000
#  - 1s - loss: 0.0355 - accuracy: 0.9999 - val_loss: 0.8435 - val_accuracy: 0.6548
#
# Epoch 00154: val_loss did not improve from 0.55431
# Epoch 155/3000
#  - 1s - loss: 0.0347 - accuracy: 1.0000 - val_loss: 1.2294 - val_accuracy: 0.6498
#
# Epoch 00155: val_loss did not improve from 0.55431
# Epoch 156/3000
#  - 1s - loss: 0.0341 - accuracy: 1.0000 - val_loss: 0.9573 - val_accuracy: 0.6509
#
# Epoch 00156: val_loss did not improve from 0.55431
# Epoch 157/3000
#  - 1s - loss: 0.0334 - accuracy: 0.9999 - val_loss: 0.9475 - val_accuracy: 0.6584
#
# Epoch 00157: val_loss did not improve from 0.55431
# Epoch 158/3000
#  - 1s - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.8448 - val_accuracy: 0.6606
#
# Epoch 00158: val_loss did not improve from 0.55431
# Epoch 159/3000
#  - 1s - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.8356 - val_accuracy: 0.6523
#
# Epoch 00159: val_loss did not improve from 0.55431
# Epoch 160/3000
#  - 1s - loss: 0.0317 - accuracy: 1.0000 - val_loss: 0.9049 - val_accuracy: 0.6523
#
# Epoch 00160: val_loss did not improve from 0.55431
# Epoch 161/3000
#  - 1s - loss: 0.0310 - accuracy: 1.0000 - val_loss: 1.0081 - val_accuracy: 0.6523
#
# Epoch 00161: val_loss did not improve from 0.55431
# Epoch 162/3000
#  - 1s - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.8679 - val_accuracy: 0.6498
#
# Epoch 00162: val_loss did not improve from 0.55431
# Epoch 163/3000
#  - 1s - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.8603 - val_accuracy: 0.6491
#
# Epoch 00163: val_loss did not improve from 0.55431
# Epoch 164/3000
#  - 1s - loss: 0.0295 - accuracy: 1.0000 - val_loss: 1.0527 - val_accuracy: 0.6516
#
# Epoch 00164: val_loss did not improve from 0.55431
# Epoch 165/3000
#  - 1s - loss: 0.0289 - accuracy: 1.0000 - val_loss: 1.0793 - val_accuracy: 0.6498
#
# Epoch 00165: val_loss did not improve from 0.55431
# Epoch 166/3000
#  - 1s - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.9192 - val_accuracy: 0.6591
#
# Epoch 00166: val_loss did not improve from 0.55431
# Epoch 167/3000
#  - 1s - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.8398 - val_accuracy: 0.6616
#
# Epoch 00167: val_loss did not improve from 0.55431
# Epoch 168/3000
#  - 1s - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.9476 - val_accuracy: 0.6512
#
# Epoch 00168: val_loss did not improve from 0.55431
# Epoch 169/3000
#  - 1s - loss: 0.0270 - accuracy: 1.0000 - val_loss: 1.0303 - val_accuracy: 0.6530
#
# Epoch 00169: val_loss did not improve from 0.55431
# Epoch 170/3000
#  - 1s - loss: 0.0265 - accuracy: 1.0000 - val_loss: 1.0084 - val_accuracy: 0.6613
#
# Epoch 00170: val_loss did not improve from 0.55431
# Epoch 171/3000
#  - 1s - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.9850 - val_accuracy: 0.6523
#
# Epoch 00171: val_loss did not improve from 0.55431
# Epoch 172/3000
#  - 1s - loss: 0.0259 - accuracy: 1.0000 - val_loss: 1.0107 - val_accuracy: 0.6516
#
# Epoch 00172: val_loss did not improve from 0.55431
# Epoch 173/3000
#  - 1s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.9355 - val_accuracy: 0.6530
#
# Epoch 00173: val_loss did not improve from 0.55431
# Epoch 174/3000
#  - 1s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 1.0119 - val_accuracy: 0.6548
#
# Epoch 00174: val_loss did not improve from 0.55431
# Epoch 175/3000
#  - 1s - loss: 0.0242 - accuracy: 1.0000 - val_loss: 1.0666 - val_accuracy: 0.6559
#
# Epoch 00175: val_loss did not improve from 0.55431
# Epoch 176/3000
#  - 1s - loss: 0.0236 - accuracy: 1.0000 - val_loss: 1.0441 - val_accuracy: 0.6602
#
# Epoch 00176: val_loss did not improve from 0.55431
# Epoch 177/3000
#  - 1s - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.9697 - val_accuracy: 0.6498
#
# Epoch 00177: val_loss did not improve from 0.55431
# Epoch 178/3000
#  - 1s - loss: 0.0230 - accuracy: 1.0000 - val_loss: 1.1209 - val_accuracy: 0.6667
#
# Epoch 00178: val_loss did not improve from 0.55431
# Epoch 179/3000
#  - 1s - loss: 0.0227 - accuracy: 1.0000 - val_loss: 1.1995 - val_accuracy: 0.6502
#
# Epoch 00179: val_loss did not improve from 0.55431
# Epoch 180/3000
#  - 1s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.8993 - val_accuracy: 0.6527
#
# Epoch 00180: val_loss did not improve from 0.55431
# Epoch 181/3000
#  - 1s - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.9826 - val_accuracy: 0.6624
#
# Epoch 00181: val_loss did not improve from 0.55431
# Epoch 182/3000
#  - 1s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.9015 - val_accuracy: 0.6606
#
# Epoch 00182: val_loss did not improve from 0.55431
# Epoch 183/3000
#  - 1s - loss: 0.0212 - accuracy: 1.0000 - val_loss: 1.0246 - val_accuracy: 0.6505
#
# Epoch 00183: val_loss did not improve from 0.55431
# Epoch 184/3000
#  - 1s - loss: 0.0211 - accuracy: 1.0000 - val_loss: 1.1047 - val_accuracy: 0.6573
#
# Epoch 00184: val_loss did not improve from 0.55431
# Epoch 185/3000
#  - 1s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.9777 - val_accuracy: 0.6573
#
# Epoch 00185: val_loss did not improve from 0.55431
# Epoch 186/3000
#  - 1s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 1.1089 - val_accuracy: 0.6570
#
# Epoch 00186: val_loss did not improve from 0.55431
# Epoch 187/3000
#  - 1s - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.8058 - val_accuracy: 0.6616
#
# Epoch 00187: val_loss did not improve from 0.55431
# Epoch 188/3000
#  - 1s - loss: 0.0195 - accuracy: 1.0000 - val_loss: 1.1606 - val_accuracy: 0.6494
#
# Epoch 00188: val_loss did not improve from 0.55431
# Epoch 189/3000
#  - 1s - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.9327 - val_accuracy: 0.6509
#
# Epoch 00189: val_loss did not improve from 0.55431
# Epoch 190/3000
#  - 1s - loss: 0.0187 - accuracy: 1.0000 - val_loss: 1.0127 - val_accuracy: 0.6534
#
# Epoch 00190: val_loss did not improve from 0.55431
# Epoch 191/3000
#  - 1s - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.9370 - val_accuracy: 0.6545
#
# Epoch 00191: val_loss did not improve from 0.55431
# Epoch 192/3000
#  - 1s - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.9787 - val_accuracy: 0.6552
#
# Epoch 00192: val_loss did not improve from 0.55431
# Epoch 193/3000
#  - 1s - loss: 0.0178 - accuracy: 1.0000 - val_loss: 1.0495 - val_accuracy: 0.6584
#
# Epoch 00193: val_loss did not improve from 0.55431
# Epoch 194/3000
#  - 1s - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.8652 - val_accuracy: 0.6552
#
# Epoch 00194: val_loss did not improve from 0.55431
# Epoch 195/3000
#  - 1s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.9872 - val_accuracy: 0.6624
#
# Epoch 00195: val_loss did not improve from 0.55431
# Epoch 196/3000
#  - 1s - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.8835 - val_accuracy: 0.6566
#
# Epoch 00196: val_loss did not improve from 0.55431
# Epoch 197/3000
#  - 1s - loss: 0.0166 - accuracy: 1.0000 - val_loss: 1.0945 - val_accuracy: 0.6523
#
# Epoch 00197: val_loss did not improve from 0.55431
# Epoch 198/3000
#  - 1s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.9086 - val_accuracy: 0.6620
#
# Epoch 00198: val_loss did not improve from 0.55431
# Epoch 199/3000
#  - 1s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.8196 - val_accuracy: 0.6527
#
# Epoch 00199: val_loss did not improve from 0.55431
# Epoch 200/3000
#  - 1s - loss: 0.0159 - accuracy: 1.0000 - val_loss: 1.0646 - val_accuracy: 0.6548
#
# Epoch 00200: val_loss did not improve from 0.55431
# Epoch 201/3000
#  - 1s - loss: 0.0159 - accuracy: 1.0000 - val_loss: 1.1991 - val_accuracy: 0.6598
#
# Epoch 00201: val_loss did not improve from 0.55431
# Epoch 202/3000
#  - 1s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.9602 - val_accuracy: 0.6555
#
# Epoch 00202: val_loss did not improve from 0.55431
# Epoch 203/3000
#  - 1s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.8401 - val_accuracy: 0.6505
#
# Epoch 00203: val_loss did not improve from 0.55431
# Epoch 204/3000
#  - 1s - loss: 0.0150 - accuracy: 1.0000 - val_loss: 1.0980 - val_accuracy: 0.6609
#
# Epoch 00204: val_loss did not improve from 0.55431
# Epoch 205/3000
#  - 1s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.9985 - val_accuracy: 0.6588
#
# Epoch 00205: val_loss did not improve from 0.55431
# Epoch 206/3000
#  - 1s - loss: 0.0143 - accuracy: 1.0000 - val_loss: 1.0207 - val_accuracy: 0.6559
#
# Epoch 00206: val_loss did not improve from 0.55431
# Epoch 207/3000
#  - 1s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 1.0940 - val_accuracy: 0.6570
#
# Epoch 00207: val_loss did not improve from 0.55431
# Epoch 208/3000
#  - 1s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.9896 - val_accuracy: 0.6548
#
# Epoch 00208: val_loss did not improve from 0.55431
# Epoch 209/3000
#  - 1s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 1.0979 - val_accuracy: 0.6537
#
# Epoch 00209: val_loss did not improve from 0.55431
# Epoch 210/3000
#  - 1s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.0599 - val_accuracy: 0.6555
#
# Epoch 00210: val_loss did not improve from 0.55431
# Epoch 211/3000
#  - 1s - loss: 0.0133 - accuracy: 1.0000 - val_loss: 1.0677 - val_accuracy: 0.6548
#
# Epoch 00211: val_loss did not improve from 0.55431
# Epoch 212/3000
#  - 1s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.8177 - val_accuracy: 0.6577
#
# Epoch 00212: val_loss did not improve from 0.55431
# Epoch 213/3000
#  - 1s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 1.0304 - val_accuracy: 0.6588
#
# Epoch 00213: val_loss did not improve from 0.55431
# Epoch 214/3000
#  - 1s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 1.1537 - val_accuracy: 0.6555
#
# Epoch 00214: val_loss did not improve from 0.55431
# Epoch 215/3000
#  - 1s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.8440 - val_accuracy: 0.6563
#
# Epoch 00215: val_loss did not improve from 0.55431
# Epoch 216/3000
#  - 1s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 1.0838 - val_accuracy: 0.6566
#
# Epoch 00216: val_loss did not improve from 0.55431
# Epoch 217/3000
#  - 1s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 1.3192 - val_accuracy: 0.6552
#
# Epoch 00217: val_loss did not improve from 0.55431
# Epoch 218/3000
#  - 1s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 1.1816 - val_accuracy: 0.6595
#
# Epoch 00218: val_loss did not improve from 0.55431
# Epoch 219/3000
#  - 1s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 1.2613 - val_accuracy: 0.6570
#
# Epoch 00219: val_loss did not improve from 0.55431
# Epoch 220/3000
#  - 1s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 1.2575 - val_accuracy: 0.6563
#
# Epoch 00220: val_loss did not improve from 0.55431
# Epoch 221/3000
#  - 1s - loss: 0.0114 - accuracy: 1.0000 - val_loss: 1.0086 - val_accuracy: 0.6577
#
# Epoch 00221: val_loss did not improve from 0.55431
# Epoch 222/3000
#  - 1s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.1288 - val_accuracy: 0.6581
#
# Epoch 00222: val_loss did not improve from 0.55431
# Epoch 223/3000
#  - 1s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 1.1483 - val_accuracy: 0.6584
#
# Epoch 00223: val_loss did not improve from 0.55431
# Epoch 224/3000
#  - 1s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 1.0428 - val_accuracy: 0.6570
#
# Epoch 00224: val_loss did not improve from 0.55431
# Epoch 225/3000
#  - 1s - loss: 0.0107 - accuracy: 1.0000 - val_loss: 1.1353 - val_accuracy: 0.6584
#
# Epoch 00225: val_loss did not improve from 0.55431
# Epoch 226/3000
#  - 1s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.0207 - val_accuracy: 0.6584
#
# Epoch 00226: val_loss did not improve from 0.55431
# Epoch 227/3000
#  - 1s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.2480 - val_accuracy: 0.6606
#
# Epoch 00227: val_loss did not improve from 0.55431
# Epoch 228/3000
#  - 1s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.2311 - val_accuracy: 0.6559
#
# Epoch 00228: val_loss did not improve from 0.55431
# Epoch 229/3000
#  - 1s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.1164 - val_accuracy: 0.6609
#
# Epoch 00229: val_loss did not improve from 0.55431
# Epoch 230/3000
#  - 1s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 1.2448 - val_accuracy: 0.6584
#
# Epoch 00230: val_loss did not improve from 0.55431
# Epoch 231/3000
#  - 1s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.0348 - val_accuracy: 0.6584
#
# Epoch 00231: val_loss did not improve from 0.55431
# Epoch 232/3000
#  - 1s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.0703 - val_accuracy: 0.6577
#
# Epoch 00232: val_loss did not improve from 0.55431
# Epoch 233/3000
#  - 1s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.1281 - val_accuracy: 0.6548
#
# Epoch 00233: val_loss did not improve from 0.55431
# Epoch 234/3000
#  - 1s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.9356 - val_accuracy: 0.6573
#
# Epoch 00234: val_loss did not improve from 0.55431
# Epoch 235/3000
#  - 1s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.0465 - val_accuracy: 0.6548
#
# Epoch 00235: val_loss did not improve from 0.55431
# Epoch 236/3000
#  - 1s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.0336 - val_accuracy: 0.6584
#
# Epoch 00236: val_loss did not improve from 0.55431
# Epoch 237/3000
#  - 1s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 1.1742 - val_accuracy: 0.6620
#
# Epoch 00237: val_loss did not improve from 0.55431
# Epoch 238/3000
#  - 1s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.2182 - val_accuracy: 0.6581
#
# Epoch 00238: val_loss did not improve from 0.55431
# Epoch 239/3000
#  - 1s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.1049 - val_accuracy: 0.6563
#
# Epoch 00239: val_loss did not improve from 0.55431
# Epoch 240/3000
#  - 1s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.9477 - val_accuracy: 0.6563
#
# Epoch 00240: val_loss did not improve from 0.55431
# Epoch 241/3000
#  - 1s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.3053 - val_accuracy: 0.6584
#
# Epoch 00241: val_loss did not improve from 0.55431
# Epoch 242/3000
#  - 1s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.1176 - val_accuracy: 0.6598
#
# Epoch 00242: val_loss did not improve from 0.55431
# Epoch 243/3000
#  - 1s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.2838 - val_accuracy: 0.6570
#
# Epoch 00243: val_loss did not improve from 0.55431
# Epoch 244/3000
#  - 1s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.2493 - val_accuracy: 0.6577
#
# Epoch 00244: val_loss did not improve from 0.55431
# Epoch 245/3000
#  - 1s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.0493 - val_accuracy: 0.6573
#
# Epoch 00245: val_loss did not improve from 0.55431
# Epoch 246/3000
#  - 1s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.0958 - val_accuracy: 0.6581
#
# Epoch 00246: val_loss did not improve from 0.55431
# Epoch 247/3000
#  - 1s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.1563 - val_accuracy: 0.6573
#
# Epoch 00247: val_loss did not improve from 0.55431
# Epoch 248/3000
#  - 1s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.2390 - val_accuracy: 0.6577
#
# Epoch 00248: val_loss did not improve from 0.55431
# Epoch 249/3000
#  - 1s - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.2740 - val_accuracy: 0.6577
#
# Epoch 00249: val_loss did not improve from 0.55431
# Epoch 250/3000
#  - 1s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.4953 - val_accuracy: 0.6591
#
# Epoch 00250: val_loss did not improve from 0.55431
# Epoch 251/3000
#  - 1s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 1.2340 - val_accuracy: 0.6577
#
# Epoch 00251: val_loss did not improve from 0.55431
# Epoch 252/3000
#  - 1s - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.1128 - val_accuracy: 0.6545
#
# Epoch 00252: val_loss did not improve from 0.55431
# Epoch 253/3000
#  - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.3834 - val_accuracy: 0.6595
#
# Epoch 00253: val_loss did not improve from 0.55431
# Epoch 254/3000
#  - 1s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.4485 - val_accuracy: 0.6581
#
# Epoch 00254: val_loss did not improve from 0.55431
# Epoch 255/3000
#  - 1s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.2242 - val_accuracy: 0.6591
#
# Epoch 00255: val_loss did not improve from 0.55431
# Epoch 256/3000
#  - 1s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.3261 - val_accuracy: 0.6566
#
# Epoch 00256: val_loss did not improve from 0.55431
# Epoch 257/3000
#  - 1s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.0947 - val_accuracy: 0.6577
#
# Epoch 00257: val_loss did not improve from 0.55431
# Epoch 258/3000
#  - 1s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.1373 - val_accuracy: 0.6563
#
# Epoch 00258: val_loss did not improve from 0.55431
# Epoch 259/3000
#  - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.0495 - val_accuracy: 0.6520
#
# Epoch 00259: val_loss did not improve from 0.55431
# Epoch 260/3000
#  - 1s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.2861 - val_accuracy: 0.6588
#
# Epoch 00260: val_loss did not improve from 0.55431
# Epoch 261/3000
#  - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.2917 - val_accuracy: 0.6555
#
# Epoch 00261: val_loss did not improve from 0.55431
# Epoch 262/3000
#  - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.3086 - val_accuracy: 0.6602
#
# Epoch 00262: val_loss did not improve from 0.55431
# Epoch 263/3000
#  - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.5007 - val_accuracy: 0.6563
#
# Epoch 00263: val_loss did not improve from 0.55431
# Epoch 264/3000
#  - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.1718 - val_accuracy: 0.6598
#
# Epoch 00264: val_loss did not improve from 0.55431
# Epoch 265/3000
#  - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.3008 - val_accuracy: 0.6523
#
# Epoch 00265: val_loss did not improve from 0.55431
# Epoch 266/3000
#  - 1s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.1957 - val_accuracy: 0.6573
#
# Epoch 00266: val_loss did not improve from 0.55431
# Epoch 267/3000
#  - 1s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.2115 - val_accuracy: 0.6584
#
# Epoch 00267: val_loss did not improve from 0.55431
# Epoch 268/3000
#  - 1s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.2723 - val_accuracy: 0.6566
#
# Epoch 00268: val_loss did not improve from 0.55431
# Epoch 269/3000
#  - 1s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.3085 - val_accuracy: 0.6559
#
# Epoch 00269: val_loss did not improve from 0.55431
# Epoch 270/3000
#  - 1s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.1377 - val_accuracy: 0.6581
#
# Epoch 00270: val_loss did not improve from 0.55431
# Epoch 271/3000
#  - 1s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.1998 - val_accuracy: 0.6552
#
# Epoch 00271: val_loss did not improve from 0.55431
# Epoch 272/3000
#  - 1s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.4065 - val_accuracy: 0.6555
#
# Epoch 00272: val_loss did not improve from 0.55431
# Epoch 273/3000
#  - 1s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.2859 - val_accuracy: 0.6563
#
# Epoch 00273: val_loss did not improve from 0.55431
# Epoch 274/3000
#  - 1s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.0753 - val_accuracy: 0.6591
#
# Epoch 00274: val_loss did not improve from 0.55431
# Epoch 275/3000
#  - 1s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.2186 - val_accuracy: 0.6595
#
# Epoch 00275: val_loss did not improve from 0.55431
# Epoch 276/3000
#  - 1s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.3014 - val_accuracy: 0.6584
#
# Epoch 00276: val_loss did not improve from 0.55431
# Epoch 277/3000
#  - 1s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.1310 - val_accuracy: 0.6545
#
# Epoch 00277: val_loss did not improve from 0.55431
# Epoch 278/3000
#  - 1s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.2881 - val_accuracy: 0.6588
#
# Epoch 00278: val_loss did not improve from 0.55431
# Epoch 279/3000
#  - 1s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.3532 - val_accuracy: 0.6566
#
# Epoch 00279: val_loss did not improve from 0.55431
# Epoch 280/3000
#  - 1s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.2382 - val_accuracy: 0.6570
#
# Epoch 00280: val_loss did not improve from 0.55431
# Epoch 281/3000
#  - 1s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.2332 - val_accuracy: 0.6595
#
# Epoch 00281: val_loss did not improve from 0.55431
# Epoch 282/3000
#  - 1s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.2391 - val_accuracy: 0.6563
#
# Epoch 00282: val_loss did not improve from 0.55431
# Epoch 283/3000
#  - 1s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.3005 - val_accuracy: 0.6577
#
# Epoch 00283: val_loss did not improve from 0.55431
# Epoch 284/3000
#  - 1s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.2120 - val_accuracy: 0.6573
#
# Epoch 00284: val_loss did not improve from 0.55431
# Epoch 285/3000
#  - 1s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.3698 - val_accuracy: 0.6530
#
# Epoch 00285: val_loss did not improve from 0.55431
# Epoch 286/3000
#  - 1s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.2747 - val_accuracy: 0.6573
#
# Epoch 00286: val_loss did not improve from 0.55431
# Epoch 287/3000
#  - 1s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.1506 - val_accuracy: 0.6577
#
# Epoch 00287: val_loss did not improve from 0.55431
# Epoch 288/3000
#  - 1s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.2118 - val_accuracy: 0.6631
#
# Epoch 00288: val_loss did not improve from 0.55431
# Epoch 289/3000
#  - 1s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.1717 - val_accuracy: 0.6548
#
# Epoch 00289: val_loss did not improve from 0.55431
# Epoch 290/3000
#  - 1s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.3131 - val_accuracy: 0.6559
#
# Epoch 00290: val_loss did not improve from 0.55431
# Epoch 291/3000
#  - 1s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.2631 - val_accuracy: 0.6545
#
# Epoch 00291: val_loss did not improve from 0.55431
# Epoch 292/3000
#  - 1s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.3508 - val_accuracy: 0.6555
#
# Epoch 00292: val_loss did not improve from 0.55431
# Epoch 293/3000
#  - 1s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.4015 - val_accuracy: 0.6581
#
# Epoch 00293: val_loss did not improve from 0.55431
# Epoch 294/3000
#  - 1s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.3722 - val_accuracy: 0.6570
#
# Epoch 00294: val_loss did not improve from 0.55431
# Epoch 295/3000
#  - 1s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.5247 - val_accuracy: 0.6545
#
# Epoch 00295: val_loss did not improve from 0.55431
# Epoch 296/3000
#  - 1s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.4337 - val_accuracy: 0.6555
#
# Epoch 00296: val_loss did not improve from 0.55431
# Epoch 297/3000
#  - 1s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.3631 - val_accuracy: 0.6595
#
# Epoch 00297: val_loss did not improve from 0.55431
# Epoch 298/3000
#  - 1s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.3140 - val_accuracy: 0.6559
#
# Epoch 00298: val_loss did not improve from 0.55431
# Epoch 299/3000
#  - 1s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.2622 - val_accuracy: 0.6559
#
# Epoch 00299: val_loss did not improve from 0.55431
# Epoch 300/3000
#  - 1s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.3643 - val_accuracy: 0.6595
#
# Epoch 00300: val_loss did not improve from 0.55431
# Epoch 301/3000
#  - 1s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.4032 - val_accuracy: 0.6559
#
# Epoch 00301: val_loss did not improve from 0.55431
# Epoch 302/3000
#  - 1s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.2959 - val_accuracy: 0.6613
#
# Epoch 00302: val_loss did not improve from 0.55431
# Epoch 303/3000
#  - 1s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.1602 - val_accuracy: 0.6581
#
# Epoch 00303: val_loss did not improve from 0.55431
# Epoch 304/3000
#  - 1s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.2597 - val_accuracy: 0.6563
#
# Epoch 00304: val_loss did not improve from 0.55431
# Epoch 305/3000
#  - 1s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.7054 - val_accuracy: 0.6573
#
# Epoch 00305: val_loss did not improve from 0.55431
# Epoch 306/3000
#  - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.2469 - val_accuracy: 0.6573
#
# Epoch 00306: val_loss did not improve from 0.55431
# Epoch 307/3000
# ...
# Epoch 473/3000
#  - 1s - loss: 4.7535e-04 - accuracy: 1.0000 - val_loss: 1.7831 - val_accuracy: 0.6588
#
# Epoch 00473: val_loss did not improve from 0.55431
# Epoch 474/3000
#  - 1s - loss: 4.6943e-04 - accuracy: 1.0000 - val_loss: 1.5312 - val_accuracy: 0.6595
#
# Epoch 00474: val_loss did not improve from 0.55431
# Epoch 475/3000
#  - 1s - loss: 4.6472e-04 - accuracy: 1.0000 - val_loss: 1.8322 - val_accuracy: 0.6566
#
# Epoch 00475: val_loss did not improve from 0.55431
# Epoch 476/3000
#  - 1s - loss: 4.6111e-04 - accuracy: 1.0000 - val_loss: 1.3655 - val_accuracy: 0.6584
#
# Epoch 00476: val_loss did not improve from 0.55431
# Epoch 477/3000
#  - 1s - loss: 4.6136e-04 - accuracy: 1.0000 - val_loss: 1.5284 - val_accuracy: 0.6566
#
# Epoch 00477: val_loss did not improve from 0.55431
# Epoch 478/3000
#  - 1s - loss: 4.5116e-04 - accuracy: 1.0000 - val_loss: 1.8343 - val_accuracy: 0.6573
#
# Epoch 00478: val_loss did not improve from 0.55431
# Epoch 479/3000
#  - 1s - loss: 4.4743e-04 - accuracy: 1.0000 - val_loss: 1.6233 - val_accuracy: 0.6563
#
# Epoch 00479: val_loss did not improve from 0.55431
# Epoch 480/3000
#  - 1s - loss: 4.3972e-04 - accuracy: 1.0000 - val_loss: 1.4436 - val_accuracy: 0.6581
#
# Epoch 00480: val_loss did not improve from 0.55431
# Epoch 481/3000
#  - 1s - loss: 4.3282e-04 - accuracy: 1.0000 - val_loss: 1.7247 - val_accuracy: 0.6570
#
# Epoch 00481: val_loss did not improve from 0.55431
# Epoch 482/3000
#  - 1s - loss: 4.3488e-04 - accuracy: 1.0000 - val_loss: 1.8667 - val_accuracy: 0.6573
#
# Epoch 00482: val_loss did not improve from 0.55431
# Epoch 483/3000
#  - 1s - loss: 4.2668e-04 - accuracy: 1.0000 - val_loss: 1.7434 - val_accuracy: 0.6573
#
# Epoch 00483: val_loss did not improve from 0.55431
# Epoch 484/3000
#  - 1s - loss: 4.2467e-04 - accuracy: 1.0000 - val_loss: 2.0858 - val_accuracy: 0.6591
#
# Epoch 00484: val_loss did not improve from 0.55431
# Epoch 485/3000
#  - 1s - loss: 4.1637e-04 - accuracy: 1.0000 - val_loss: 1.4926 - val_accuracy: 0.6581
#
# Epoch 00485: val_loss did not improve from 0.55431
# Epoch 486/3000
#  - 1s - loss: 4.1124e-04 - accuracy: 1.0000 - val_loss: 2.0143 - val_accuracy: 0.6566
#
# Epoch 00486: val_loss did not improve from 0.55431
# Epoch 487/3000
#  - 1s - loss: 4.1074e-04 - accuracy: 1.0000 - val_loss: 2.0241 - val_accuracy: 0.6573
#
# Epoch 00487: val_loss did not improve from 0.55431
# Epoch 488/3000
#  - 1s - loss: 4.0627e-04 - accuracy: 1.0000 - val_loss: 2.0305 - val_accuracy: 0.6563
#
# Epoch 00488: val_loss did not improve from 0.55431
# Epoch 489/3000
#  - 1s - loss: 4.0087e-04 - accuracy: 1.0000 - val_loss: 1.8879 - val_accuracy: 0.6577
#
# Epoch 00489: val_loss did not improve from 0.55431
# Epoch 490/3000
#  - 1s - loss: 3.9713e-04 - accuracy: 1.0000 - val_loss: 1.6274 - val_accuracy: 0.6566
#
# Epoch 00490: val_loss did not improve from 0.55431
# Epoch 491/3000
#  - 1s - loss: 3.9331e-04 - accuracy: 1.0000 - val_loss: 1.8469 - val_accuracy: 0.6563
#
# Epoch 00491: val_loss did not improve from 0.55431
# Epoch 492/3000
#  - 1s - loss: 3.8868e-04 - accuracy: 1.0000 - val_loss: 1.1622 - val_accuracy: 0.6573
#
# Epoch 00492: val_loss did not improve from 0.55431
# Epoch 493/3000
#  - 1s - loss: 3.8729e-04 - accuracy: 1.0000 - val_loss: 1.7345 - val_accuracy: 0.6581
#
# Epoch 00493: val_loss did not improve from 0.55431
# Epoch 494/3000
#  - 1s - loss: 3.7759e-04 - accuracy: 1.0000 - val_loss: 1.6575 - val_accuracy: 0.6555
#
# Epoch 00494: val_loss did not improve from 0.55431
# Epoch 495/3000
#  - 1s - loss: 3.7789e-04 - accuracy: 1.0000 - val_loss: 1.6049 - val_accuracy: 0.6566
#
# Epoch 00495: val_loss did not improve from 0.55431
# Epoch 496/3000
#  - 1s - loss: 3.7635e-04 - accuracy: 1.0000 - val_loss: 2.0850 - val_accuracy: 0.6588
#
# Epoch 00496: val_loss did not improve from 0.55431
# Epoch 497/3000
#  - 1s - loss: 3.6542e-04 - accuracy: 1.0000 - val_loss: 1.6837 - val_accuracy: 0.6573
#
# Epoch 00497: val_loss did not improve from 0.55431
# Epoch 498/3000
#  - 1s - loss: 3.6317e-04 - accuracy: 1.0000 - val_loss: 1.8258 - val_accuracy: 0.6559
#
# Epoch 00498: val_loss did not improve from 0.55431
# Epoch 499/3000
#  - 1s - loss: 3.6006e-04 - accuracy: 1.0000 - val_loss: 1.5339 - val_accuracy: 0.6545
#
# Epoch 00499: val_loss did not improve from 0.55431
# Epoch 500/3000
#  - 1s - loss: 3.5811e-04 - accuracy: 1.0000 - val_loss: 1.8540 - val_accuracy: 0.6573
#
# Epoch 00500: val_loss did not improve from 0.55431
# Epoch 501/3000
#  - 1s - loss: 3.5044e-04 - accuracy: 1.0000 - val_loss: 1.4581 - val_accuracy: 0.6570
#
# Epoch 00501: val_loss did not improve from 0.55431
# Epoch 502/3000
#  - 1s - loss: 3.4696e-04 - accuracy: 1.0000 - val_loss: 1.3828 - val_accuracy: 0.6559
#
# Epoch 00502: val_loss did not improve from 0.55431
# Epoch 503/3000
#  - 1s - loss: 3.4403e-04 - accuracy: 1.0000 - val_loss: 1.7013 - val_accuracy: 0.6570
#
# Epoch 00503: val_loss did not improve from 0.55431
# Epoch 504/3000
#  - 1s - loss: 3.4191e-04 - accuracy: 1.0000 - val_loss: 1.7666 - val_accuracy: 0.6577
#
# Epoch 00504: val_loss did not improve from 0.55431
# Epoch 505/3000
#  - 1s - loss: 3.3313e-04 - accuracy: 1.0000 - val_loss: 1.6213 - val_accuracy: 0.6581
#
# Epoch 00505: val_loss did not improve from 0.55431
# Epoch 506/3000
#  - 1s - loss: 3.3321e-04 - accuracy: 1.0000 - val_loss: 2.0895 - val_accuracy: 0.6552
#
# Epoch 00506: val_loss did not improve from 0.55431
# Epoch 507/3000
#  - 1s - loss: 3.2913e-04 - accuracy: 1.0000 - val_loss: 1.5394 - val_accuracy: 0.6584
#
# Epoch 00507: val_loss did not improve from 0.55431
# Epoch 508/3000
#  - 1s - loss: 3.2664e-04 - accuracy: 1.0000 - val_loss: 1.9258 - val_accuracy: 0.6577
#
# Epoch 00508: val_loss did not improve from 0.55431
# Epoch 509/3000
#  - 1s - loss: 3.2570e-04 - accuracy: 1.0000 - val_loss: 1.9089 - val_accuracy: 0.6545
#
# Epoch 00509: val_loss did not improve from 0.55431
# Epoch 510/3000
#  - 1s - loss: 3.2341e-04 - accuracy: 1.0000 - val_loss: 1.8718 - val_accuracy: 0.6552
#
# Epoch 00510: val_loss did not improve from 0.55431
# Epoch 511/3000
#  - 1s - loss: 3.1689e-04 - accuracy: 1.0000 - val_loss: 1.7010 - val_accuracy: 0.6577
#
# Epoch 00511: val_loss did not improve from 0.55431
# Epoch 512/3000
#  - 1s - loss: 3.1162e-04 - accuracy: 1.0000 - val_loss: 1.5490 - val_accuracy: 0.6577
#
# Epoch 00512: val_loss did not improve from 0.55431
# Epoch 513/3000
#  - 1s - loss: 3.0682e-04 - accuracy: 1.0000 - val_loss: 1.5103 - val_accuracy: 0.6563
#
# Epoch 00513: val_loss did not improve from 0.55431
# Epoch 514/3000
#  - 1s - loss: 3.0434e-04 - accuracy: 1.0000 - val_loss: 1.5940 - val_accuracy: 0.6555
#
# Epoch 00514: val_loss did not improve from 0.55431
# Epoch 515/3000
#  - 1s - loss: 3.0268e-04 - accuracy: 1.0000 - val_loss: 1.5199 - val_accuracy: 0.6570
#
# Epoch 00515: val_loss did not improve from 0.55431
# Epoch 516/3000
#  - 1s - loss: 3.0087e-04 - accuracy: 1.0000 - val_loss: 1.6308 - val_accuracy: 0.6563
#
# Epoch 00516: val_loss did not improve from 0.55431
# Epoch 517/3000
#  - 1s - loss: 2.9545e-04 - accuracy: 1.0000 - val_loss: 1.8628 - val_accuracy: 0.6584
#
# Epoch 00517: val_loss did not improve from 0.55431
# Epoch 518/3000
#  - 1s - loss: 2.9340e-04 - accuracy: 1.0000 - val_loss: 1.8666 - val_accuracy: 0.6570
#
# Epoch 00518: val_loss did not improve from 0.55431
# Epoch 519/3000
#  - 1s - loss: 2.9188e-04 - accuracy: 1.0000 - val_loss: 1.7796 - val_accuracy: 0.6584
#
# Epoch 00519: val_loss did not improve from 0.55431
# Epoch 520/3000
#  - 1s - loss: 2.8875e-04 - accuracy: 1.0000 - val_loss: 1.9838 - val_accuracy: 0.6577
#
# Epoch 00520: val_loss did not improve from 0.55431
# Epoch 521/3000
#  - 1s - loss: 2.8461e-04 - accuracy: 1.0000 - val_loss: 1.4370 - val_accuracy: 0.6570
#
# Epoch 00521: val_loss did not improve from 0.55431
# Epoch 522/3000
#  - 1s - loss: 2.8019e-04 - accuracy: 1.0000 - val_loss: 1.9259 - val_accuracy: 0.6573
#
# Epoch 00522: val_loss did not improve from 0.55431
# Epoch 523/3000
#  - 1s - loss: 2.7718e-04 - accuracy: 1.0000 - val_loss: 2.0242 - val_accuracy: 0.6584
#
# Epoch 00523: val_loss did not improve from 0.55431
# Epoch 524/3000
#  - 1s - loss: 2.7448e-04 - accuracy: 1.0000 - val_loss: 1.3942 - val_accuracy: 0.6595
#
# Epoch 00524: val_loss did not improve from 0.55431
# Epoch 525/3000
#  - 1s - loss: 2.7077e-04 - accuracy: 1.0000 - val_loss: 1.7428 - val_accuracy: 0.6581
#
# Epoch 00525: val_loss did not improve from 0.55431
# Epoch 526/3000
#  - 1s - loss: 2.6832e-04 - accuracy: 1.0000 - val_loss: 1.6395 - val_accuracy: 0.6591
#
# Epoch 00526: val_loss did not improve from 0.55431
# Epoch 527/3000
#  - 1s - loss: 2.6518e-04 - accuracy: 1.0000 - val_loss: 1.8221 - val_accuracy: 0.6577
#
# Epoch 00527: val_loss did not improve from 0.55431
# Epoch 528/3000
#  - 1s - loss: 2.6111e-04 - accuracy: 1.0000 - val_loss: 1.6040 - val_accuracy: 0.6584
#
# Epoch 00528: val_loss did not improve from 0.55431
# Epoch 529/3000
#  - 1s - loss: 2.5922e-04 - accuracy: 1.0000 - val_loss: 2.0288 - val_accuracy: 0.6584
#
# Epoch 00529: val_loss did not improve from 0.55431
# Epoch 530/3000
#  - 1s - loss: 2.6006e-04 - accuracy: 1.0000 - val_loss: 1.5468 - val_accuracy: 0.6591
#
# Epoch 00530: val_loss did not improve from 0.55431
# Epoch 531/3000
#  - 1s - loss: 2.5569e-04 - accuracy: 1.0000 - val_loss: 1.9294 - val_accuracy: 0.6588
#
# Epoch 00531: val_loss did not improve from 0.55431
# Epoch 532/3000
#  - 1s - loss: 2.5288e-04 - accuracy: 1.0000 - val_loss: 1.7607 - val_accuracy: 0.6570
#
# Epoch 00532: val_loss did not improve from 0.55431
# Epoch 533/3000
#  - 1s - loss: 2.5206e-04 - accuracy: 1.0000 - val_loss: 1.8402 - val_accuracy: 0.6573
#
# Epoch 00533: val_loss did not improve from 0.55431
# Epoch 534/3000
#  - 1s - loss: 2.4831e-04 - accuracy: 1.0000 - val_loss: 1.7076 - val_accuracy: 0.6573
#
# Epoch 00534: val_loss did not improve from 0.55431
# Epoch 535/3000
#  - 1s - loss: 2.4585e-04 - accuracy: 1.0000 - val_loss: 1.4652 - val_accuracy: 0.6595
#
# Epoch 00535: val_loss did not improve from 0.55431
# Epoch 536/3000
#  - 1s - loss: 2.3880e-04 - accuracy: 1.0000 - val_loss: 1.5904 - val_accuracy: 0.6570
#
# Epoch 00536: val_loss did not improve from 0.55431
# Epoch 537/3000
#  - 1s - loss: 2.3741e-04 - accuracy: 1.0000 - val_loss: 1.8296 - val_accuracy: 0.6577
#
# Epoch 00537: val_loss did not improve from 0.55431
# Epoch 538/3000
#  - 1s - loss: 2.3812e-04 - accuracy: 1.0000 - val_loss: 1.9459 - val_accuracy: 0.6591
#
# Epoch 00538: val_loss did not improve from 0.55431
# Epoch 539/3000
#  - 1s - loss: 2.3447e-04 - accuracy: 1.0000 - val_loss: 1.6677 - val_accuracy: 0.6591
#
# Epoch 00539: val_loss did not improve from 0.55431
# Epoch 540/3000
#  - 1s - loss: 2.3400e-04 - accuracy: 1.0000 - val_loss: 1.7894 - val_accuracy: 0.6591
#
# Epoch 00540: val_loss did not improve from 0.55431
# Epoch 541/3000
#  - 1s - loss: 2.3075e-04 - accuracy: 1.0000 - val_loss: 1.5973 - val_accuracy: 0.6577
#
# Epoch 00541: val_loss did not improve from 0.55431
# Epoch 542/3000
#  - 1s - loss: 2.2626e-04 - accuracy: 1.0000 - val_loss: 2.0159 - val_accuracy: 0.6591
#
# Epoch 00542: val_loss did not improve from 0.55431
# Epoch 543/3000
#  - 1s - loss: 2.2363e-04 - accuracy: 1.0000 - val_loss: 1.9661 - val_accuracy: 0.6581
#
# Epoch 00543: val_loss did not improve from 0.55431
# Epoch 544/3000
#  - 1s - loss: 2.1919e-04 - accuracy: 1.0000 - val_loss: 1.4805 - val_accuracy: 0.6563
#
# Epoch 00544: val_loss did not improve from 0.55431
# Epoch 545/3000
#  - 1s - loss: 2.2013e-04 - accuracy: 1.0000 - val_loss: 1.7093 - val_accuracy: 0.6581
#
# Epoch 00545: val_loss did not improve from 0.55431
# Epoch 546/3000
#  - 1s - loss: 2.1771e-04 - accuracy: 1.0000 - val_loss: 1.7512 - val_accuracy: 0.6570
#
# Epoch 00546: val_loss did not improve from 0.55431
# Epoch 547/3000
#  - 1s - loss: 2.1338e-04 - accuracy: 1.0000 - val_loss: 1.9844 - val_accuracy: 0.6577
#
# Epoch 00547: val_loss did not improve from 0.55431
# Epoch 548/3000
#  - 1s - loss: 2.1143e-04 - accuracy: 1.0000 - val_loss: 1.8057 - val_accuracy: 0.6573
#
# Epoch 00548: val_loss did not improve from 0.55431
# test_result.shape : (2787, 2)
# y_test[:5] : [0 0 0 0 0]
# y_score[:5] : [[0.09287582]
#  [0.42829862]
#  [0.28121924]
#  [0.3018372 ]
#  [0.50714296]]
# y_test.shape : (2787, 1)
# y_score.shape : (2787, 1)
# len(y_test) : 2787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:677: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [2.9609313e-07, 3.0800024e-07, 3.2464106e-07, 3.3022073e-07, 3.1955034e-07, 3.1694046e-07, 3.0475127e-07, 2.7218007e-07, 2.567976e-07, 2.5515254e-07, 2.5203659e-07, 2.5127076e-07, 2.5006375e-07, 2.447636e-07, 2.5467392e-07, 2.593308e-07, 2.6063267e-07, 2.5142003e-07, 2.5808214e-07, 2.4958297e-07, 2.4761616e-07, 2.4132925e-07, 2.5241312e-07, 2.6010377e-07, 2.54933e-07, 2.5663093e-07, 2.6869955e-07, 2.4912384e-07, 2.6517782e-07, 2.5304726e-07, 2.530881e-07, 2.8082655e-07, 2.8368214e-07, 2.825649e-07, 2.8137285e-07, 2.8148955e-07, 2.88564e-07, 2.9071018e-07, 2.8006386e-07, 2.7446717e-07, 2.9376656e-07, 3.0052797e-07, 3.181152e-07, 3.164112e-07, 3.1687927e-07, 3.224583e-07, 3.2526688e-07, 3.189321e-07, 3.3202338e-07, 3.263791e-07, 2.8630078e-07, 2.792027e-07, 2.8154622e-07, 2.8900138e-07, 2.9944022e-07, 3.1961466e-07, 3.2790658e-07, 3.2601224e-07, 3.1502168e-07, 3.196185e-07, 3.3281788e-07, 3.2704241e-07, 3.270598e-07, 3.2561502e-07, 3.2210198e-07, 3.3095048e-07, 3.1321176e-07, 3.051222e-07, 2.8784586e-07, 2.8985062e-07, 2.9432204e-07, 2.9995246e-07, 3.3193615e-07, 3.3130004e-07, 3.37921e-07, 3.376621e-07, 3.2082494e-07, 3.2442168e-07, 3.3742054e-07, 3.39891e-07, 3.6811517e-07, 3.878744e-07, 4.4151423e-07, 4.3737126e-07, 4.1864007e-07, 4.1884493e-07, 4.1890928e-07, 4.3814137e-07, 4.5724198e-07, 4.1725903e-07, 3.8054358e-07, 4.3127343e-07, 4.3541695e-07, 4.2783253e-07, 4.2652698e-07, 4.2186556e-07, 4.2035578e-07, 4.2910793e-07, 4.1260554e-07, 3.8204513e-07, 4.025204e-07, 4.03643e-07, 4.1036205e-07, 4.422118e-07, 4.3210824e-07, 4.3964573e-07, 4.4058064e-07, 4.7168547e-07, 4.5186525e-07, 4.6102602e-07, 4.961278e-07, 5.133194e-07, 4.7366512e-07, 4.822981e-07, 5.089735e-07, 5.1143894e-07, 5.74219e-07, 5.7163885e-07, 5.128344e-07, 5.3420166e-07, 5.4422037e-07, 5.45202e-07, 5.7227277e-07, 5.765145e-07, 6.592885e-07, 6.7155145e-07, 6.9478017e-07, 7.3622147e-07, 7.2238504e-07, 7.8171036e-07, 8.56149e-07, 8.465177e-07, 8.991386e-07, 9.016199e-07, 8.8621925e-07, 9.911396e-07, 9.851811e-07, 9.732445e-07, 9.98317e-07, 1.0449885e-06, 1.0610626e-06, 9.045759e-07, 9.400048e-07, 9.140087e-07, 9.847827e-07, 1.0487555e-06, 1.0467174e-06, 1.0526401e-06, 1.0439605e-06, 1.0188504e-06, 1.0439621e-06, 1.0256589e-06, 9.694269e-07, 1.0420648e-06, 1.0468107e-06, 1.041959e-06, 1.0778946e-06, 1.380575e-06, 1.5508128e-06, 1.5852031e-06, 1.5976483e-06, 1.618893e-06, 1.5937552e-06, 1.606622e-06, 1.6226295e-06, 1.6493302e-06, 1.550906e-06, 1.539766e-06, 1.5693242e-06, 1.4139343e-06, 1.4058381e-06, 1.339529e-06, 1.424929e-06, 1.4364256e-06, 1.4229851e-06, 1.3940447e-06, 1.3214457e-06, 1.263915e-06, 1.2898863e-06, 1.3025092e-06, 1.3064293e-06, 1.258073e-06, 1.2966462e-06, 1.3720935e-06, 1.3908432e-06, 1.3885655e-06, 1.4296517e-06, 1.4510156e-06, 1.5193509e-06, 1.5463922e-06, 1.6428078e-06, 1.6320076e-06, 1.6434425e-06, 1.8381778e-06, 1.9050243e-06, 1.9992103e-06, 2.1337216e-06, 2.491334e-06, 2.5612303e-06, 2.4292067e-06, 2.3635878e-06, 2.4551537e-06, 2.439522e-06, 2.5099887e-06, 2.4595029e-06, 2.5381692e-06, 2.4662831e-06, 2.4372578e-06, 2.4926512e-06, 2.4824412e-06, 2.4436806e-06, 2.6020523e-06, 2.6098826e-06, 2.4413223e-06, 2.4391907e-06, 2.322001e-06, 2.4151789e-06, 2.4846818e-06, 2.5671877e-06, 2.6207495e-06, 2.6609994e-06, 2.4554815e-06, 2.6232167e-06, 2.59423e-06, 2.6119933e-06, 2.9702808e-06, 2.9431149e-06, 2.9814107e-06, 2.9881878e-06, 3.1286934e-06, 3.0288688e-06, 2.8626202e-06, 3.132655e-06, 3.4624638e-06, 3.206237e-06, 3.1911222e-06, 4.3131918e-06, 4.3383343e-06, 4.2689353e-06, 4.1703756e-06, 4.5052593e-06, 4.46629e-06, 4.359576e-06, 4.5406864e-06, 4.4434437e-06, 4.7150315e-06, 4.692358e-06, 4.962756e-06, 4.990317e-06, 5.1585903e-06, 5.496386e-06, 6.288094e-06, 5.687987e-06, 5.4740535e-06, 5.6388517e-06, 5.6111985e-06, 5.4920033e-06, 5.220524e-06, 5.067392e-06, 5.3563945e-06, 5.5099354e-06, 5.051105e-06, 5.0057392e-06, 5.288563e-06, 5.2431246e-06, 5.273563e-06, 5.617765e-06, 5.5740547e-06, 5.7521543e-06, 6.292715e-06, 6.3396446e-06, 6.2584 ...

# %% [markdown]
# ### save npy

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from funcs_indicator import *

def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


#       set data features : ohlc, v, ep
time_index = ohlcv.index[np.sum(np.isnan(pr)):]

sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

#       scale with price    #
ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
sar = lucid_sar(sliced_ohlcv)
ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
senkou1, senkou2 = ichimoku(sliced_ohlcv)

#     min max scale   #
vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

pr_list = pr[np.sum(np.isnan(pr)):]
print("len(ohlc) :", len(ohlc))
print("len(pr) :", len(pr))

# break


#       set params    #
period = 45
key_i = i

plotting = True

data_x, data_pr, data_updown = [], [], []
data_index = []

for i in range(period, len(ohlc)):

  #   pr_list != 1 인 데이터만 사용한다
  # if 1:
  if pr_list[i] != 1:

    min_max = MinMaxScaler()
    
    #   prediction 을 제외한 이전 데이터를 사용해야한다
    temp_ohlc = ohlc.iloc[i - period : i].values
    # temp_long_ep = long_ep[i - period : i]          
    temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
    temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

    temp_close = min_max_scale(temp_ohlc[:, [3]])    

    price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

    if np.isnan(np.sum(price_data)):
      continue

    # print("price_data[:10] :", price_data[:10])
    # print("temp_ohlc.shape :", temp_ohlc.shape)
    # print("temp_long_ep.shape :", temp_long_ep.shape)
    # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
    # print("price_data.shape :", price_data.shape)

    if plotting:
      plt.plot(price_data)
      plt.show()

    ind_temp_ohlc = min_max_scale(temp_ohlc)
    temp_price_data = min_max_scale(price_data)
    # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


    if plotting:

      plt.plot(ind_temp_ohlc)
      plt.show()
      plt.plot(temp_price_data)
      plt.show()

      plotting = False
    # break

    #   vol -> min_max
    temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
    
    #                   feature selection                   #        
    temp_data = np.hstack((ind_temp_ohlc, temp_vol))

    # temp_data = trial_list[trial_number]
    # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
    # temp_data = temp_ohlc[:, [3]]
    # temp_data = ind_temp_ohlc[:, [3]]
    # temp_data = temp_close

    if np.isnan(np.sum(temp_data)):
      continue

    data_x.append(temp_data)
    data_pr.append(pr_list[i])
    data_index.append(time_index[i])
    data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


print('np.array(data_x).shape :', np.array(data_x).shape)
# print(data_x[0])


#       Reshape data for image deep - learning     #
_, row, col = np.array(data_x).shape

input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
# input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

#     1c to 3c    #
input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
# input_x = np.array(resize_npy(input_x))


input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
input_index = np.array(data_index).reshape(-1, 1)
print('input_x.shape :', input_x.shape)
print('input_x.dtype :', input_x.dtype)
print('input_pr.shape :', input_pr.shape)
print('input_ud.shape :', input_ud.shape)
print('input_index.shape :', input_index.shape)


# x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

#     do stacking   #
# if prev_x is None:
prev_x = input_x
prev_pr = input_pr
prev_ud = input_ud
prev_index = input_index

total_x = input_x
total_pr = input_pr
total_ud = input_ud
total_index = input_index

# else:
#   total_x = np.vstack((prev_x, input_x))
#   total_pr = np.vstack((prev_pr, input_pr))
#   total_ud = np.vstack((prev_ud, input_ud)) 
#   total_index = np.vstack((prev_index, input_index)) 

#   prev_x = total_x
#   prev_pr = total_pr
#   prev_ud = total_ud
#   prev_index = total_index

print('total_x.shape :', total_x.shape)
print('total_pr.shape :', total_pr.shape)
print('total_ud.shape :', total_ud.shape)
print('prev_index.shape :', prev_index.shape)


# _, row, col, _ = input_x.shape
# _, row, col = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


#         get unique timestamp      #
print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

#                 don't shuffle timeseries data                 #
stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)

index_train = np.array(index_train)
index_val = np.array(index_val)
index_test = np.array(index_test)
  
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

symbol_name = key.split(' ')[1].split('.')[0]

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)

np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %% [markdown]
# ### load npy

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


symbol_name = "SXPUSDT"
period = 45

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)


x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')


pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

# total_x = np.vstack((x_train, x_val, x_test))
# total_pr = np.vstack((pr_train, pr_val, pr_test))

# print("total_x.shape :", total_x.shape)
# Out:
# x series loaded !
# y series loaded !

# %% [markdown]
# ### rapid pr selection

# %%
plt.plot(pr)
plt.show()

pr_thresh = 1.005
rapid_pct = len(pr[pr > pr_thresh]) / len(pr)

print(rapid_pct)
# Out:
# 0.36131427304964536

# %% [markdown]
# ### class_weight & categorization

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


def class_ratio(in_list):

  return in_list / in_list[1]
  
y_train = np.where(pr_train > pr_thresh, 1, 0)
y_test = np.where(pr_test > pr_thresh, 1, 0)
y_val = np.where(pr_val > pr_thresh, 1, 0)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

# try:
print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

# except Exception as e:
  # print(e)

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)
# Out:
# x_train.shape : (10755, 45, 5, 3)
# x_test.shape : (3586, 45, 5, 3)
# x_val.shape : (3585, 45, 5, 3)
# y_train.shape : (10755, 1)
# y_test.shape : (3586, 1)
# y_val.shape : (3585, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([6864, 3891])) [1.76407093 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2303, 1282])) [1.79641186 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2291, 1295])) [1.76911197 1.        ]
# class_weights : {0: 0.7834353146853147, 1: 1.382035466461064}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10755, 2)
# y_val_ohe.shape : (3585, 2)
# y_test_ohe.shape : (3586, 2)

# %% [markdown]
# ### augment

# %%
from keras.preprocessing.image import ImageDataGenerator 

datagen = ImageDataGenerator( 
    # rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)


batch_size = 512


for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break

# %% [markdown]
# ### train

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'

# batch_size = 512

model = FER_Model(input_shape=x_train.shape[1:])
opt = Adam(lr=0.00001, decay=0.000005)
# opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model_name = 'classifier_%s_cnn_updown_rascend_1005_%s_tvnon_shuffle.h5' % (period, symbol_name)



checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]
# callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)

# %% [markdown]
# ### load model

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'


model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)


model = keras.models.load_model(ckpt_path + model_name)

# %% [markdown]
# ### test

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)

  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.title(symbol_name)
plt.show()
# Out:
# test_result.shape : (3586, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.04767541]
#  [0.00195843]
#  [0.1600004 ]
#  [0.14308068]
#  [0.00154134]]
# y_test.shape : (3586, 1)
# y_score.shape : (3586, 1)
# len(y_test) : 3586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [5.2342257e-05, 5.224965e-05, 5.119804e-05, 4.92728e-05, 4.9822964e-05, 5.1722614e-05, 5.241118e-05, 5.2653213e-05, 5.4707263e-05, 5.469477e-05, 5.5414595e-05, 5.4917986e-05, 5.5296758e-05, 5.482614e-05, 5.5313794e-05, 5.619928e-05, 5.7341047e-05, 5.8005982e-05, 5.7726982e-05, 5.8714617e-05, 5.924952e-05, 5.9157777e-05, 6.0730683e-05, 6.09751e-05, 6.1022805e-05, 6.194849e-05, 6.286581e-05, 6.367981e-05, 6.4932676e-05, 6.5769455e-05, 6.7948844e-05, 6.841887e-05, 6.806048e-05, 6.849957e-05, 6.9895126e-05, 7.091783e-05, 7.1859926e-05, 7.350335e-05, 7.346305e-05, 7.395025e-05, 7.968566e-05, 7.8947196e-05, 7.8341516e-05, 7.918357e-05, 7.912106e-05, 8.1205275e-05, 8.341604e-05, 8.386569e-05, 8.3938816e-05, 8.564359e-05, 7.970025e-05, 8.0672995e-05, 8.083643e-05, 8.727269e-05, 8.9510206e-05, 8.959228e-05, 8.962243e-05, 8.8885776e-05, 9.023229e-05, 9.169206e-05, 9.0867565e-05, 9.033618e-05, 9.429348e-05, 9.3799725e-05, 9.566918e-05, 9.6586686e-05, 9.398621e-05, 9.4105475e-05, 9.411831e-05, 9.466633e-05, 9.5054995e-05, 9.854746e-05, 9.9124496e-05, 0.00010614127, 0.000108136, 0.00010740872, 0.00010814099, 0.00010723293, 0.00010745465, 0.00010824714, 0.00010731329, 0.000108584194, 0.00010868803, 0.00010257258, 0.000101516416, 0.00010031571, 0.000103715196, 0.00010502134, 0.00010611775, 0.00010916348, 0.00010594193, 0.000104194485, 0.00010433929, 0.000104219216, 0.00010764128, 0.00010433711, 0.00010385209, 0.000106006635, 0.00010645543, 0.00010741285, 0.00010793885, 0.00010773461, 0.000107400294, 0.000107067055, 0.000110430265, 0.00010961514, 0.000110994966, 0.000109511326, 0.00011019072, 0.00011165826, 0.00011095228, 0.00011055433, 0.00011134691, 0.000109883986, 0.0001112986, 0.0001123257, 0.000114077506, 0.00011583454, 0.00011730796, 0.00011702095, 0.00012883096, 0.00012502969, 0.0001211144, 0.00012085415, 0.00012023333, 0.000121178586, 0.0001113643, 0.00011255329, 0.00011366057, 0.00011109531, 0.00011435672, 0.00011691414, 0.00011724194, 0.00011877652, 0.00011876732, 0.00012343662, 0.00012398258, 0.00012742475, 0.00013299534, 0.0001345203, 0.00013497796, 0.00013495858, 0.00013710273, 0.00013803714, 0.00013533776, 0.00014049193, 0.00013862025, 0.00013925365, 0.00013978127, 0.00014475136, 0.00014560782, 0.00014417202, 0.00015133772, 0.0001492487, 0.00015156744, 0.00015025465, 0.00015172384, 0.0001483679, 0.00015025485, 0.00017470514, 0.00017807752, 0.00018197432, 0.00018371776, 0.00018367464, 0.0001920926, 0.00019288564, 0.00020759454, 0.00020698183, 0.00023446795, 0.00023864223, 0.00024568185, 0.0002499611, 0.00025658592, 0.00025730263, 0.00025887572, 0.00026280092, 0.0002670472, 0.00027564648, 0.0002803122, 0.0002723821, 0.00027754836, 0.00027732784, 0.00028359605, 0.0002916876, 0.0002884358, 0.0002919522, 0.00029502896, 0.00028943687, 0.00028854128, 0.00029137387, 0.0002962364, 0.00029461124, 0.00029948735, 0.00030449385, 0.0002996868, 0.00029990985, 0.00029333428, 0.0002965417, 0.00029836778, 0.00029298887, 0.00030178405, 0.00029634495, 0.00029906907, 0.00029697176, 0.0002963374, 0.000295097, 0.000312998, 0.00031196643, 0.00031936396, 0.00032101592, 0.00032832168, 0.0003258465, 0.00033274552, 0.0003290262, 0.00033229083, 0.00034132804, 0.00033895372, 0.00035075872, 0.00034744598, 0.00034445102, 0.00032778905, 0.0003323982, 0.00034709118, 0.0003477889, 0.00035424854, 0.00040091967, 0.00042115894, 0.00041995398, 0.00041660885, 0.00042408038, 0.00044065266, 0.00045346154, 0.00044463656, 0.00047572926, 0.0005098468, 0.00050058664, 0.00049340463, 0.0004999284, 0.0005000292, 0.0004849475, 0.00048356556, 0.0004768842, 0.00047515446, 0.00046261746, 0.00046790738, 0.000461418, 0.00046818578, 0.00046653874, 0.00047877917, 0.00048961974, 0.0005021864, 0.00051662093, 0.00052976055, 0.00053512596, 0.000552535, 0.0005820823, 0.00058700517, 0.00059161586, 0.0005911128, 0.00059325877, 0.00059789245, 0.0006161917, 0.00060233, 0.0006037665, 0.0005968395, 0.0006049573, 0.0006040889, 0.0006045968, 0.000620602, 0.00062113034, 0.0006333279, ...

# %%
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)], linestyle='--', color='r')
plt.title(symbol_name + '\n' + str(new_thresh[np.argmax(acc_pr_bythr)]))
plt.show()

# %%
thresh = 0.5866
y_pred = np.where(y_score[:600, -1] > thresh, 1, 0)
# print('y_pred.shape :', y_pred.shape)
# print('y_pred :', y_pred)

#     compare precision     #

# print('precision :', precision_score(y_test, y_pred))
# print('recall :', recall_score(y_test, y_pred))
# print()

# print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
# print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

# # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
# # plt.show()  
# print()

#     check win-ratio improvement     #
cmat = confusion_matrix(y_test[:len(y_pred)], y_pred)
# print(cmat)
# print(np.sum(cmat, axis=1))

test_size = len(y_test[:len(y_pred)])
test_pr_list = pr_test[:len(y_pred)]
# print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
# print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

# print('pr_test.shape :', pr_test.shape)

# print(y_pred)
# print(test_pr_list)
pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

plt.plot(np.cumprod(pred_pr_list))
plt.show()

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72a922dd9685> in <module>()
#       5 # print(index_train)
#       6 # print(index_val)
# ----> 7 total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index))
#       8 timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train))
#       9 timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val))
#
# NameError: name 'input_index' is not defined

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
