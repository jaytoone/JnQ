# %% [markdown]
# # Convert a R script into Python
#
# This notebook introduces the function [r2python](find://code-r2python) which converts *R* into *Python*. It does not work for eveything, it is being improved everytime it is needed.

# %%
rscript = """
nb=function(y=1930){
debut=1816
MatDFemale=matrix(D$Female,nrow=111)
colnames(MatDFemale)=(debut+0):198
cly=(y-debut+1):111
deces=diag(MatDFemale[:,cly[cly%in%1:199]])
return(c(B$Female[B$Year==y],deces))}
"""

# %%
# !pip install pyensae
# !pip install antlr4-python2-runtime
# !pip install builtins
# Out:
# ERROR: Could not find a version that satisfies the requirement builtins (from versions: none)
# ERROR: No matching distribution found for builtins

# %%
from pyensae.languages import r2python
# print(r2python(rscript, pep8=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7ff9a3e37ae2> in <module>()
# ----> 1 from pyensae.languages import r2python
#       2 # print(r2python(rscript, pep8=True))
#
# /usr/local/lib/python3.6/dist-packages/pyensae/languages/__init__.py in <module>()
#       6 from .antlr_grammar_build import build_grammar
#       7 from .antlr_grammar_use import get_parser_lexer, parse_code, get_tree_string, get_tree_graph
# ----> 8 from .rconverter import r2python
#       9 from .tree_string_listener import TreeStringListener
#
# /usr/local/lib/python3.6/dist-packages/pyensae/languages/rconverter.py in <module>()
#       5 from antlr4 import ParseTreeWalker
#       6 from pyquickhelper.pycode import remove_extra_spaces_and_pep8
# ----> 7 from .RParser import RParser
#       8 from .RLexer import RLexer
#       9 from .antlr_grammar_use import parse_code
#
# /usr/local/lib/python3.6/dist-packages/pyensae/languages/RParser.py in <module>()
#     385
#     386
# --> 387 class RParser (Parser):
#     388
#     389     grammarFileName = "R.g4"
#
# /usr/local/lib/python3.6/dist-packages/pyensae/languages/RParser.py in RParser()
#     389     grammarFileName = "R.g4"
#     390
# --> 391     atn = ATNDeserializer().deserialize(serializedATN())
#     392
#     393     decisionsToDFA = [DFA(ds, i) for i, ds in enumerate(atn.decisionToState)]
#
# /usr/local/lib/python3.6/dist-packages/antlr4/atn/ATNDeserializer.py in deserialize(self, data)
#      67         sets = []
#      68         # First, read all sets with 16-bit Unicode code points <= U+FFFF.
# ---> 69         self.readSets(atn, sets, self.readInt)
#      70         # Next, if the ATN was serialized with the Unicode SMP feature,
#      71         # deserialize sets with 32-bit arguments <= U+10FFFF.
#
# /usr/local/lib/python3.6/dist-packages/antlr4/atn/ATNDeserializer.py in readSets(self, atn, sets, readUnicode)
#     194                 i1 = readUnicode()
#     195                 i2 = readUnicode()
# --> 196                 iset.addRange(Interval(i1, i2 + 1)) # range upper limit is exclusive
#     197
#     198     def readEdges(self, atn, sets):
#
# /usr/local/lib/python3.6/dist-packages/antlr4/IntervalSet.py in __init__(self, start, stop)
#      14         self.start = start
#      15         self.stop = stop
# ---> 16         self.range = xrange(start, stop)
#      17
#      18     def __contains__(self, item):
#
# NameError: name 'xrange' is not defined

# %% [markdown]
# It adds some not implemented function such as ``colnames(MatDFemale) .set(range((debut + 0), 198))`` because the original syntax ``colnames(MatDFemale)=debut+0:198`` does not work in *Python*. The conversion does not fix indices (first position is zero in *Python* and 1 in *R*). The bracket ``(debut+0):198`` are needed to tell the converter the beginning of the expression. The operator ``%in%`` is converted into a set intersection.
