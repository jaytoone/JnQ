# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install h5py==2.10.0

# !pip install tensorflow==2.1.0
# !pip install keras==2.4.1

# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__
# Out:
# Collecting h5py==2.10.0
#   Downloading https://files.pythonhosted.org/packages/3f/c0/abde58b837e066bca19a3f7332d9d0493521d7dd6b48248451a9e3fe2214/h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 4.0MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.19.5)
# ERROR: tensorflow 2.5.0 has requirement h5py~=3.1.0, but you'll have h5py 2.10.0 which is incompatible.
# Installing collected packages: h5py
#   Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# Successfully installed h5py-2.10.0

# %%
# %tensorflow_version 1.x

import tensorflow as tf
tf.__version__
# Out:
# '2.1.0'

# %%
import keras
keras.__version__
from tensorflow.keras.utils import np_utils

# %% [markdown]
# ### load file list

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### custom model

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import tensorflow as tf
import keras

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

# from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
print(tf.__version__)
print(keras.__version__)
# Out:
# 1.15.2
# 2.3.1

# %% [markdown]
# ### all in one loop

# %%
print(ohlcv['close'].pct_change().head())
print(ohlcv['close'] / ohlcv['close'].shift(1).head() - 1)

# %%
# from tensorflow.keras.utils import to_categorical

# %%
from funcs_indicator import *
import matplotlib.pyplot as plt

# import mpl_finance as mf


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None


#           load saved npy & trained model        #
load_npy = False
load_model = False


seed = 1
random_state = 201
np.random.seed(seed)

fee = 0.0006
lvrg = 5

for i in range(len(candis)):

  keys = [candis[i]]

  if 'eth'.upper() not in candis[i]:
    continue

  # if 'comp'.upper() not in candis[i]:
  #   continue

  for key in keys:  
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))

        
    #       long      #
    pr = (ohlcv['close'].pct_change() - fee) * lvrg + 1    

    #       long liqudation     #
    lq = (ohlcv['low'] / ohlcv['close'].shift(1) - fee - 1) * lvrg + 1

    #       short       # <-- 이거를 단순히 minus 를 붙여도 되는걸까
    s_pr = (-ohlcv['close'].pct_change() - fee) * lvrg + 1

    #       short liqudation     #
    # s_lq = (ohlcv['high'] / ohlcv['close'].shift(1) - fee) * lvrg + 1
    

    #       fill na with 1.0      #
    # pr = np.where(np.isnan(pr), 1, pr)
    # print(len(pr))
    # print("len(pr[np.isnan(pr)]) :", len(pr[np.isnan(pr)]))
    # print("np.sum(np.isnan(pr)) :", np.sum(np.isnan(pr)))
    
    # sliced_ohlcv = ohlcv[np.sum(np.isnan(pr))]
    # print(sliced_ohlcv.head())
    # break
    # s_pr = np.where(np.isnan(s_pr), 1, pr)
    # lq = np.where(np.isnan(lq), 1, lq)


    #       set lq      #
    # pr = np.where((pr != 1) & (lq <= 0), 0, pr)

    # print("len(pr[pr < 0]) :", len(pr[pr < 0]))
    # break

    org_wr = len(pr[pr > 1]) / len(pr[pr != 1])

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(pr))
    plt.title("%s\norg_wr : %.3f\n acc_pr : %.3f" % (key, org_wr, np.cumprod(pr)[-1]))


    #                    strat                   #

    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) < ohlcv['close'].shift(3)), pr, 1)


    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
    #                     (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
    #                     (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)), pr, 1)


    strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
                        (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
                        (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
                        (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)) & 
                        (ohlcv['close'].shift(5) < ohlcv['close'].shift(6)), pr, 1)
    
    # strat_pr = np.where((ohlcv['high'].shift(2) > ohlcv['high'].shift(3))& 
    #                     (ohlcv['close'].shift(1) > ohlcv['close'].shift(2)), pr, 1)


    wr = len(strat_pr[strat_pr > 1]) / len(strat_pr[strat_pr != 1])

    plt.subplot(122)
    plt.plot(np.cumprod(strat_pr))
    plt.title("%s\norg_wr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr, np.cumprod(strat_pr)[-1]))


    # #                  sl cut                #
    # sl_line = ohlcv['low'].rolling(250).min().shift(1)
    # # sl_line = ohlcv['low'].shift(1)

    # strat_pr_sl = np.where((strat_pr != 1) & (sl_line > ohlcv['low']), 
    #                      1 + lvrg * (sl_line / ohlcv['close'].shift(1) - 1 - fee), strat_pr)


    # wr_sl = len(strat_pr_sl[strat_pr_sl > 1]) / len(strat_pr_sl[strat_pr_sl != 1])
    # # wl_pr_ratio = np.mean(strat_pr[strat_pr > 1]) / np.mean(strat_pr[strat_pr < 1])
    # # wl_pr_ratio = np.cumprod(strat_pr[strat_pr > 1])[-1] / np.cumprod(strat_pr[strat_pr < 1])[-1]

    # plt.subplot(122)
    # plt.plot(np.cumprod(strat_pr_sl))
    # plt.title("%s\norg_pr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr_sl, np.cumprod(strat_pr_sl)[-1]))


    plt.show()
    # break

    # period = 5
    period = 28
    # period = 45
    symbol_name = key.split(' ')[1].split('.')[0]      

    x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_norand.npy' % (period, symbol_name)
    pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_norand.npy' % (period, symbol_name)
    index_save_path = current_path + 'npy/' + '%s_cnn_updown_index_train_rascend_ohlcv_%s_norand.npy' % (period, symbol_name)

    x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_shuffle.npy' % (period, symbol_name)
    pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_shuffle.npy' % (period, symbol_name)
    index_save_path = current_path + 'npy/' + '%s_cnn_updown_index_train_rascend_ohlcv_%s_shuffle.npy' % (period, symbol_name)



    if not load_npy:

      from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
      from sklearn.model_selection import train_test_split
      from datetime import datetime

      from funcs_indicator import *

      def min_max_scale(npy_x):

        return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[np.sum(np.isnan(pr)):]

      sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

      #       scale with price    #
      ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

      ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
      sar = lucid_sar(sliced_ohlcv)
      ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
      senkou1, senkou2 = ichimoku(sliced_ohlcv)

      #     min max scale   #
      vol = ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]
      # vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

      pr_list = pr[np.sum(np.isnan(pr)):]
      print("len(ohlc) :", len(ohlc))
      print("len(pr_list) :", len(pr_list))

      print("ohlc.index[0] :", ohlc.index[0])
      print("vol.index[0] :", vol.index[0])
      # break


      #       set params    #
      # period = 45
      key_i = i

      plotting = True

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(ohlc)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          # temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

          temp_close = min_max_scale(temp_ohlc[:, [3]])    

          price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          ind_temp_ohlc = min_max_scale(temp_ohlc)
          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


          if plotting:

            plt.plot(ind_temp_ohlc)
            plt.show()
            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          #                   feature selection                   #        
          temp_data = np.hstack((ind_temp_ohlc, temp_vol))

          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          # temp_data = temp_ohlc[:, [3]]
          # temp_data = ind_temp_ohlc[:, [3]]
          # temp_data = temp_close

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      # input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)


      # _, row, col, _ = input_x.shape
      # _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      #                 don't shuffle timeseries data                 #
      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=True, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=True, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      # np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)


      np.save(x_save_path, x_train)
      np.save(x_save_path.replace('x_train', 'x_val'), x_val)
      np.save(x_save_path.replace('x_train', 'x_test'), x_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('x series saved !')

      np.save(pr_save_path, pr_train)
      np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
      np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
      # np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
      print('pr series saved !')
      
      np.save(index_save_path, index_train)
      np.save(index_save_path.replace('index_train', 'index_val'), index_val)
      np.save(index_save_path.replace('index_train', 'index_test'), index_test)
      print('index series saved !')

    else:
      
      x_train = np.load(x_save_path)
      x_val = np.load(x_save_path.replace('x_train', 'x_val'))
      x_test = np.load(x_save_path.replace('x_train', 'x_test'))
      print('x series loaded !')


      pr_train = np.load(pr_save_path)
      pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
      pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
      print('y series loaded !')


      index_train = np.load(index_save_path, allow_pickle=True)
      index_val = np.load(index_save_path.replace('index_train', 'index_val'), allow_pickle=True)
      index_test = np.load(index_save_path.replace('index_train', 'index_test'), allow_pickle=True)
      print('index series loaded !')




    #       pr_thresh by percentage 0.285     #
    plt.plot(pr)
    plt.show()
    
    sorted_pr = sorted(pr, reverse=True)
    pct = 0.285
    len_pct = int(len(pr) * pct)
    pr_thresh = sorted_pr[len_pct]
    print("pr_thresh :", pr_thresh)

    # from tensorflow.keras.utils import np_utils
    # from keras.utils import to_categorical
    from keras.utils.np_utils import to_categorical

    from sklearn.utils import class_weight


    def class_ratio(in_list):

      return in_list / in_list[1]
      
    y_train = np.where(pr_train > pr_thresh, 1, 0)
    y_test = np.where(pr_test > pr_thresh, 1, 0)
    y_val = np.where(pr_val > pr_thresh, 1, 0)

    print('x_train.shape :', x_train.shape)
    print('x_test.shape :', x_test.shape)
    print('x_val.shape :', x_val.shape)
    print('y_train.shape :', y_train.shape)
    print('y_test.shape :', y_test.shape)
    print('y_val.shape :', y_val.shape)

    # try:
    print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
    print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
    print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

    # except Exception as e:
      # print(e)

    label = y_train.reshape(-1, )
    class_weights = class_weight.compute_class_weight('balanced', 
                                                        classes=np.unique(label),
                                                        y=label)
    class_weights = dict(enumerate(class_weights))
    print('class_weights :', class_weights)

    # sample_weight = np.ones(shape=(len(y_train),))
    # sample_weight[(y_train == 1).reshape(-1,)] = 1.5
    # print('sample_weight[:20] :', sample_weight[:20])


    print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
    print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
    print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

    print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
    print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
    print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

    num_classes = 2
    
    # y_train_ohe = np_utils.to_categorical(y_train, num_classes)
    # y_val_ohe = np_utils.to_categorical(y_val, num_classes)
    # y_test_ohe = np_utils.to_categorical(y_test, num_classes)
    
    y_train_ohe = to_categorical(y_train, num_classes)
    y_val_ohe = to_categorical(y_val, num_classes)
    y_test_ohe = to_categorical(y_test, num_classes)
    print('y_train_ohe.shape :', y_train_ohe.shape)
    print('y_val_ohe.shape :', y_val_ohe.shape)
    print('y_test_ohe.shape :', y_test_ohe.shape)

    from keras.preprocessing.image import ImageDataGenerator 
    # from tensorflow.keras.preprocessing.image import ImageDataGenerator 

    datagen = ImageDataGenerator( 
        # rotation_range = 45,
        # zoom_range = 0.5,
        # shear_range = 0.5,
        # horizontal_flip = True,
        # vertical_flip = True,
        # width_shift_range=0.5,
        # height_shift_range=0.5,
        # fill_mode = 'nearest'
        )

    valgen = ImageDataGenerator( 
        )

    datagen.fit(x_train)
    valgen.fit(x_val)


    batch_size = 512


    for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

        plt.suptitle("train x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break

    for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

        plt.suptitle("val x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break
        
    train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
    val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
    # break

    

    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'

    # batch_size = 512

    K.clear_session()


    # model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_tf250_%s_tvnon_shuffle.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_tf241_%s_tvnon_shuffle.h5' % (period, symbol_name)

    model_name = 'classifier_%s_cnn_updown_rascend_%s_tf115_%s_norand.h5' % (period, int(pct * 1000), symbol_name)
    model_name = 'classifier_%s_cnn_updown_rascend_%s_tf115_%s_shuffle.h5' % (period, int(pct * 1000), symbol_name)



    if not load_model:

      # from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
      from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

      model = FER_Model(input_shape=x_train.shape[1:])
      # opt = Adam(lr=1e-5, decay=5e-6)
      opt = Adam( learning_rate=1e-5, decay=5e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-7)

      # opt = Adam(lr=0.001, decay=0.0005)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir=board_path,
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_loss', patience=500)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]
      # callbacks_list = [checkpoint, checkpoint2]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 2000
      history = model.fit_generator(train_flow, 
                          steps_per_epoch=len(x_train) / batch_size, 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=val_flow,  
                          validation_steps=len(x_val) / batch_size,
                          shuffle=False)
      
    
    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'


    model = keras.models.load_model(ckpt_path + model_name)

    test_result = model.predict(x_test)
    # test_result = model.predict(test_set)

    print('test_result.shape :', test_result.shape)
    # print('pr_val.shape :', pr_val.shape)

    y_score = test_result[:, [1]]
    print('y_test[:5] :', y_test.reshape(-1,)[:5])
    # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
    print('y_score[:5] :', y_score[:5])
    # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

    print('y_test.shape :', y_test.shape)
    print('y_score.shape :', y_score.shape)

    print('len(y_test) :', len(y_test))

    #     precision recall curve   #
    precision, recall, threshold = precision_recall_curve(y_test, y_score)
    precision, recall = precision[:-1], recall[:-1]

    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    plt.show()
    # print(y_pred)


    # threshold = [0.65]
    # print('threshold :', threshold)
    # break

    acc_pr_bythr = []
    new_thresh = []
    temp_pr_list = []


    for thresh in threshold:
      
      # if thresh < 0.5:
      #     continue

      y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
      # print('y_pred.shape :', y_pred.shape)
      # print('y_pred :', y_pred)

      #     compare precision     #

      # print('precision :', precision_score(y_test, y_pred))
      # print('recall :', recall_score(y_test, y_pred))
      # print()

      # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
      # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

      # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
      # # plt.show()  
      # print()

      #     check win-ratio improvement     #
      cmat = confusion_matrix(y_test, y_pred)
      # print(cmat)
      # print(np.sum(cmat, axis=1))

      test_size = len(y_test)
      test_pr_list = pr_test
      # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

      org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
      ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
      # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

      # print('pr_test.shape :', pr_test.shape)

      # print(y_pred)
      # print(test_pr_list)

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
      # print('pred_pr_list.shape :', pred_pr_list.shape)

      temp_pr_list.append(pred_pr_list)


      # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
      #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
      #   print('thresh :', thresh)
        
      # if len(threshold) == 1:
    #   plt.figure(figsize=(10, 5))
    #   plt.subplot(121)
    #   plt.plot(np.cumprod(test_pr_list))
    #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
    # # plt.show()

    #   plt.subplot(122)
    #   plt.plot(np.cumprod(pred_pr_list))
    #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
    #   plt.show()


      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)


    print('acc_pr_bythr :', acc_pr_bythr)

    plt.figure(figsize=(13, 5))
    plt.subplot(131)
    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    # plt.show()
    plt.subplot(132)
    plt.plot(new_thresh, acc_pr_bythr)
    plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')

    best_thr = new_thresh[np.argmax(acc_pr_bythr)]
    plt.axvline(best_thr, linestyle='--', color='r')
    plt.title(symbol_name + '\n' + str(best_thr))

    plt.subplot(133)
    plt.plot(np.cumprod(temp_pr_list[np.argmax(acc_pr_bythr)]))

    plt.show()
# Out:
# start_stamp : 0
# len(ohlcv) : 18048
# len(ohlc) : 18047
# len(pr_list) : 18047
# ohlc.index[0] : 2020-04-17 00:59:59.999000
# vol.index[0] : 2020-04-17 00:59:59.999000
# np.array(data_x).shape : (17943, 28, 5)
# input_x.shape : (17943, 28, 5, 3)
# input_x.dtype : float32
# input_pr.shape : (17943, 1)
# input_ud.shape : (17943, 1)
# input_index.shape : (17943, 1)
# total_x.shape : (17943, 28, 5, 3)
# total_pr.shape : (17943, 1)
# total_ud.shape : (17943, 1)
# prev_index.shape : (17943, 1)
# (array([Timestamp('2020-04-19 04:59:59.999000'),
#        Timestamp('2020-04-19 05:29:59.999000'),
#        Timestamp('2020-04-19 05:59:59.999000'), ...,
#        Timestamp('2021-04-27 22:59:59.999000'),
#        Timestamp('2021-04-27 23:29:59.999000'),
#        Timestamp('2021-04-27 23:59:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (10765,)
# stamp_val.shape : (3589,)
# stamp_test.shape : (3589,)
# HBox(children=(FloatProgress(value=0.0, max=17943.0), HTML(value='')))
# x_train.shape : (10765, 28, 5, 3)
# x_val.shape : (3589, 28, 5, 3)
# x_test.shape : (3589, 28, 5, 3)
# x series saved !
# pr series saved !
# index series saved !
# pr_thresh : 1.010013727383401
# x_train.shape : (10765, 28, 5, 3)
# x_test.shape : (3589, 28, 5, 3)
# x_val.shape : (3589, 28, 5, 3)
# y_train.shape : (10765, 1)
# y_test.shape : (3589, 1)
# y_val.shape : (3589, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([7682, 3083])) [2.49172884 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2544, 1045])) [2.43444976 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2612,  977])) [2.67349028 1.        ]
# class_weights : {0: 0.7006638896120801, 1: 1.7458644177748945}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10765, 2)
# y_val_ohe.shape : (3589, 2)
# y_test_ohe.shape : (3589, 2)
# Streaming output truncated to the last 5000 lines.
#
# Epoch 00050: val_loss did not improve from 0.33266
# Epoch 51/2000
#  - 1s - loss: 0.5042 - accuracy: 0.7683 - val_loss: 0.6024 - val_accuracy: 0.5561
#
# Epoch 00051: val_loss did not improve from 0.33266
# Epoch 52/2000
#  - 1s - loss: 0.4951 - accuracy: 0.7871 - val_loss: 0.8884 - val_accuracy: 0.5483
#
# Epoch 00052: val_loss did not improve from 0.33266
# Epoch 53/2000
#  - 1s - loss: 0.4992 - accuracy: 0.7647 - val_loss: 0.4607 - val_accuracy: 0.5954
#
# Epoch 00053: val_loss did not improve from 0.33266
# Epoch 54/2000
#  - 1s - loss: 0.4894 - accuracy: 0.7867 - val_loss: 1.0532 - val_accuracy: 0.5171
#
# Epoch 00054: val_loss did not improve from 0.33266
# Epoch 55/2000
#  - 1s - loss: 0.4864 - accuracy: 0.7936 - val_loss: 0.6307 - val_accuracy: 0.5690
#
# Epoch 00055: val_loss did not improve from 0.33266
# Epoch 56/2000
#  - 1s - loss: 0.4775 - accuracy: 0.7908 - val_loss: 0.8262 - val_accuracy: 0.5631
#
# Epoch 00056: val_loss did not improve from 0.33266
# Epoch 57/2000
#  - 1s - loss: 0.4741 - accuracy: 0.7924 - val_loss: 0.6400 - val_accuracy: 0.5748
#
# Epoch 00057: val_loss did not improve from 0.33266
# Epoch 58/2000
#  - 1s - loss: 0.4702 - accuracy: 0.7958 - val_loss: 0.9140 - val_accuracy: 0.6261
#
# Epoch 00058: val_loss did not improve from 0.33266
# Epoch 59/2000
#  - 1s - loss: 0.4787 - accuracy: 0.8077 - val_loss: 0.8653 - val_accuracy: 0.5762
#
# Epoch 00059: val_loss did not improve from 0.33266
# Epoch 60/2000
#  - 1s - loss: 0.4748 - accuracy: 0.8031 - val_loss: 0.8983 - val_accuracy: 0.4778
#
# Epoch 00060: val_loss did not improve from 0.33266
# Epoch 61/2000
#  - 1s - loss: 0.4734 - accuracy: 0.7792 - val_loss: 0.8667 - val_accuracy: 0.5450
#
# Epoch 00061: val_loss did not improve from 0.33266
# Epoch 62/2000
#  - 1s - loss: 0.4584 - accuracy: 0.8113 - val_loss: 0.8229 - val_accuracy: 0.5004
#
# Epoch 00062: val_loss did not improve from 0.33266
# Epoch 63/2000
#  - 1s - loss: 0.4654 - accuracy: 0.7940 - val_loss: 0.5948 - val_accuracy: 0.4907
#
# Epoch 00063: val_loss did not improve from 0.33266
# Epoch 64/2000
#  - 1s - loss: 0.4546 - accuracy: 0.8097 - val_loss: 0.8671 - val_accuracy: 0.5291
#
# Epoch 00064: val_loss did not improve from 0.33266
# Epoch 65/2000
#  - 1s - loss: 0.4514 - accuracy: 0.8010 - val_loss: 1.0044 - val_accuracy: 0.5430
#
# Epoch 00065: val_loss did not improve from 0.33266
# Epoch 66/2000
#  - 1s - loss: 0.4439 - accuracy: 0.8206 - val_loss: 0.8465 - val_accuracy: 0.5548
#
# Epoch 00066: val_loss did not improve from 0.33266
# Epoch 67/2000
#  - 1s - loss: 0.4422 - accuracy: 0.8140 - val_loss: 0.5426 - val_accuracy: 0.5754
#
# Epoch 00067: val_loss did not improve from 0.33266
# Epoch 68/2000
#  - 1s - loss: 0.4372 - accuracy: 0.8268 - val_loss: 1.3868 - val_accuracy: 0.6250
#
# Epoch 00068: val_loss did not improve from 0.33266
# Epoch 69/2000
#  - 1s - loss: 0.4382 - accuracy: 0.8240 - val_loss: 0.7942 - val_accuracy: 0.5954
#
# Epoch 00069: val_loss did not improve from 0.33266
# Epoch 70/2000
#  - 1s - loss: 0.4252 - accuracy: 0.8347 - val_loss: 0.6101 - val_accuracy: 0.5974
#
# Epoch 00070: val_loss did not improve from 0.33266
# Epoch 71/2000
#  - 1s - loss: 0.4381 - accuracy: 0.8341 - val_loss: 0.7351 - val_accuracy: 0.5444
#
# Epoch 00071: val_loss did not improve from 0.33266
# Epoch 72/2000
#  - 1s - loss: 0.4423 - accuracy: 0.8219 - val_loss: 0.7725 - val_accuracy: 0.5085
#
# Epoch 00072: val_loss did not improve from 0.33266
# Epoch 73/2000
#  - 1s - loss: 0.4575 - accuracy: 0.7946 - val_loss: 0.6774 - val_accuracy: 0.5327
#
# Epoch 00073: val_loss did not improve from 0.33266
# Epoch 74/2000
#  - 1s - loss: 0.4287 - accuracy: 0.8320 - val_loss: 0.7926 - val_accuracy: 0.5277
#
# Epoch 00074: val_loss did not improve from 0.33266
# Epoch 75/2000
#  - 1s - loss: 0.4231 - accuracy: 0.8247 - val_loss: 1.0284 - val_accuracy: 0.6007
#
# Epoch 00075: val_loss did not improve from 0.33266
# Epoch 76/2000
#  - 1s - loss: 0.4179 - accuracy: 0.8439 - val_loss: 0.9979 - val_accuracy: 0.5595
#
# Epoch 00076: val_loss did not improve from 0.33266
# Epoch 77/2000
#  - 1s - loss: 0.4129 - accuracy: 0.8416 - val_loss: 0.7237 - val_accuracy: 0.5893
#
# Epoch 00077: val_loss did not improve from 0.33266
# Epoch 78/2000
#  - 1s - loss: 0.4139 - accuracy: 0.8438 - val_loss: 0.6747 - val_accuracy: 0.6046
#
# Epoch 00078: val_loss did not improve from 0.33266
# Epoch 79/2000
#  - 1s - loss: 0.4114 - accuracy: 0.8496 - val_loss: 0.5389 - val_accuracy: 0.5205
#
# Epoch 00079: val_loss did not improve from 0.33266
# Epoch 80/2000
#  - 1s - loss: 0.4328 - accuracy: 0.8085 - val_loss: 1.4496 - val_accuracy: 0.4765
#
# Epoch 00080: val_loss did not improve from 0.33266
# Epoch 81/2000
#  - 1s - loss: 0.4122 - accuracy: 0.8241 - val_loss: 0.4520 - val_accuracy: 0.5634
#
# Epoch 00081: val_loss did not improve from 0.33266
# Epoch 82/2000
#  - 1s - loss: 0.3911 - accuracy: 0.8640 - val_loss: 0.5032 - val_accuracy: 0.6016
#
# Epoch 00082: val_loss did not improve from 0.33266
# Epoch 83/2000
#  - 1s - loss: 0.3931 - accuracy: 0.8635 - val_loss: 1.1250 - val_accuracy: 0.5249
#
# Epoch 00083: val_loss did not improve from 0.33266
# Epoch 84/2000
#  - 1s - loss: 0.4052 - accuracy: 0.8301 - val_loss: 0.6992 - val_accuracy: 0.5046
#
# Epoch 00084: val_loss did not improve from 0.33266
# Epoch 85/2000
#  - 1s - loss: 0.3889 - accuracy: 0.8597 - val_loss: 0.4206 - val_accuracy: 0.5807
#
# Epoch 00085: val_loss did not improve from 0.33266
# Epoch 86/2000
#  - 1s - loss: 0.3828 - accuracy: 0.8636 - val_loss: 0.4299 - val_accuracy: 0.5834
#
# Epoch 00086: val_loss did not improve from 0.33266
# Epoch 87/2000
#  - 1s - loss: 0.3797 - accuracy: 0.8676 - val_loss: 0.5418 - val_accuracy: 0.6124
#
# Epoch 00087: val_loss did not improve from 0.33266
# Epoch 88/2000
#  - 1s - loss: 0.3733 - accuracy: 0.8723 - val_loss: 0.9466 - val_accuracy: 0.6069
#
# Epoch 00088: val_loss did not improve from 0.33266
# Epoch 89/2000
#  - 1s - loss: 0.3712 - accuracy: 0.8758 - val_loss: 0.3562 - val_accuracy: 0.5879
#
# Epoch 00089: val_loss did not improve from 0.33266
# Epoch 90/2000
#  - 1s - loss: 0.3857 - accuracy: 0.8661 - val_loss: 0.8383 - val_accuracy: 0.5525
#
# Epoch 00090: val_loss did not improve from 0.33266
# Epoch 91/2000
#  - 1s - loss: 0.3687 - accuracy: 0.8725 - val_loss: 1.3789 - val_accuracy: 0.5508
#
# Epoch 00091: val_loss did not improve from 0.33266
# Epoch 92/2000
#  - 1s - loss: 0.3711 - accuracy: 0.8629 - val_loss: 0.9630 - val_accuracy: 0.5840
#
# Epoch 00092: val_loss did not improve from 0.33266
# Epoch 93/2000
#  - 1s - loss: 0.3596 - accuracy: 0.8795 - val_loss: 0.9841 - val_accuracy: 0.6297
#
# Epoch 00093: val_loss did not improve from 0.33266
# Epoch 94/2000
#  - 1s - loss: 0.3597 - accuracy: 0.8794 - val_loss: 0.6505 - val_accuracy: 0.6035
#
# Epoch 00094: val_loss did not improve from 0.33266
# Epoch 95/2000
#  - 1s - loss: 0.3611 - accuracy: 0.8883 - val_loss: 0.8881 - val_accuracy: 0.5380
#
# Epoch 00095: val_loss did not improve from 0.33266
# Epoch 96/2000
#  - 1s - loss: 0.3685 - accuracy: 0.8656 - val_loss: 0.6099 - val_accuracy: 0.5149
#
# Epoch 00096: val_loss did not improve from 0.33266
# Epoch 97/2000
#  - 1s - loss: 0.3774 - accuracy: 0.8496 - val_loss: 0.6551 - val_accuracy: 0.5422
#
# Epoch 00097: val_loss did not improve from 0.33266
# Epoch 98/2000
#  - 1s - loss: 0.3562 - accuracy: 0.8741 - val_loss: 1.0497 - val_accuracy: 0.5595
#
# Epoch 00098: val_loss did not improve from 0.33266
# Epoch 99/2000
#  - 1s - loss: 0.3552 - accuracy: 0.8848 - val_loss: 0.5042 - val_accuracy: 0.5545
#
# Epoch 00099: val_loss did not improve from 0.33266
# Epoch 100/2000
#  - 1s - loss: 0.3573 - accuracy: 0.8701 - val_loss: 0.6454 - val_accuracy: 0.5854
#
# Epoch 00100: val_loss did not improve from 0.33266
# Epoch 101/2000
#  - 1s - loss: 0.3446 - accuracy: 0.8935 - val_loss: 0.2613 - val_accuracy: 0.5609
#
# Epoch 00101: val_loss improved from 0.33266 to 0.26131, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT_shuffle.h5
# Epoch 102/2000
#  - 1s - loss: 0.3402 - accuracy: 0.8881 - val_loss: 0.3979 - val_accuracy: 0.5659
#
# Epoch 00102: val_loss did not improve from 0.26131
# Epoch 103/2000
#  - 1s - loss: 0.3356 - accuracy: 0.8925 - val_loss: 0.5617 - val_accuracy: 0.5793
#
# Epoch 00103: val_loss did not improve from 0.26131
# Epoch 104/2000
#  - 1s - loss: 0.3298 - accuracy: 0.9001 - val_loss: 0.5172 - val_accuracy: 0.5862
#
# Epoch 00104: val_loss did not improve from 0.26131
# Epoch 105/2000
#  - 1s - loss: 0.3304 - accuracy: 0.9053 - val_loss: 0.9692 - val_accuracy: 0.5874
#
# Epoch 00105: val_loss did not improve from 0.26131
# Epoch 106/2000
#  - 1s - loss: 0.3292 - accuracy: 0.8908 - val_loss: 0.4003 - val_accuracy: 0.6383
#
# Epoch 00106: val_loss did not improve from 0.26131
# Epoch 107/2000
#  - 1s - loss: 0.3373 - accuracy: 0.9047 - val_loss: 1.1591 - val_accuracy: 0.5545
#
# Epoch 00107: val_loss did not improve from 0.26131
# Epoch 108/2000
#  - 1s - loss: 0.3333 - accuracy: 0.8773 - val_loss: 1.0245 - val_accuracy: 0.5559
#
# Epoch 00108: val_loss did not improve from 0.26131
# Epoch 109/2000
#  - 1s - loss: 0.3295 - accuracy: 0.8909 - val_loss: 0.7147 - val_accuracy: 0.5372
#
# Epoch 00109: val_loss did not improve from 0.26131
# Epoch 110/2000
#  - 1s - loss: 0.3165 - accuracy: 0.9031 - val_loss: 0.8306 - val_accuracy: 0.5678
#
# Epoch 00110: val_loss did not improve from 0.26131
# Epoch 111/2000
#  - 1s - loss: 0.3092 - accuracy: 0.9155 - val_loss: 1.2869 - val_accuracy: 0.5801
#
# Epoch 00111: val_loss did not improve from 0.26131
# Epoch 112/2000
#  - 1s - loss: 0.3177 - accuracy: 0.9143 - val_loss: 0.7865 - val_accuracy: 0.6194
#
# Epoch 00112: val_loss did not improve from 0.26131
# Epoch 113/2000
#  - 1s - loss: 0.3140 - accuracy: 0.9040 - val_loss: 0.3825 - val_accuracy: 0.6342
#
# Epoch 00113: val_loss did not improve from 0.26131
# Epoch 114/2000
#  - 1s - loss: 0.3121 - accuracy: 0.9107 - val_loss: 0.4640 - val_accuracy: 0.6381
#
# Epoch 00114: val_loss did not improve from 0.26131
# Epoch 115/2000
#  - 1s - loss: 0.3112 - accuracy: 0.9052 - val_loss: 1.0591 - val_accuracy: 0.5946
#
# Epoch 00115: val_loss did not improve from 0.26131
# Epoch 116/2000
#  - 1s - loss: 0.3095 - accuracy: 0.9114 - val_loss: 0.9449 - val_accuracy: 0.5748
#
# Epoch 00116: val_loss did not improve from 0.26131
# Epoch 117/2000
#  - 1s - loss: 0.3075 - accuracy: 0.9017 - val_loss: 0.5548 - val_accuracy: 0.5876
#
# Epoch 00117: val_loss did not improve from 0.26131
# Epoch 118/2000
#  - 1s - loss: 0.2923 - accuracy: 0.9241 - val_loss: 0.6724 - val_accuracy: 0.6077
#
# Epoch 00118: val_loss did not improve from 0.26131
# Epoch 119/2000
#  - 1s - loss: 0.2954 - accuracy: 0.9251 - val_loss: 0.5663 - val_accuracy: 0.5885
#
# Epoch 00119: val_loss did not improve from 0.26131
# Epoch 120/2000
#  - 1s - loss: 0.2983 - accuracy: 0.9144 - val_loss: 0.6467 - val_accuracy: 0.5642
#
# Epoch 00120: val_loss did not improve from 0.26131
# Epoch 121/2000
#  - 1s - loss: 0.2929 - accuracy: 0.9184 - val_loss: 0.2643 - val_accuracy: 0.6080
#
# Epoch 00121: val_loss did not improve from 0.26131
# Epoch 122/2000
#  - 1s - loss: 0.2865 - accuracy: 0.9265 - val_loss: 0.2330 - val_accuracy: 0.6539
#
# Epoch 00122: val_loss improved from 0.26131 to 0.23296, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT_shuffle.h5
# Epoch 123/2000
#  - 1s - loss: 0.3045 - accuracy: 0.9047 - val_loss: 0.7858 - val_accuracy: 0.6333
#
# Epoch 00123: val_loss did not improve from 0.23296
# Epoch 124/2000
#  - 1s - loss: 0.2773 - accuracy: 0.9300 - val_loss: 1.2455 - val_accuracy: 0.6004
#
# Epoch 00124: val_loss did not improve from 0.23296
# Epoch 125/2000
#  - 1s - loss: 0.2781 - accuracy: 0.9323 - val_loss: 0.6586 - val_accuracy: 0.5578
#
# Epoch 00125: val_loss did not improve from 0.23296
# Epoch 126/2000
#  - 1s - loss: 0.2784 - accuracy: 0.9228 - val_loss: 0.5352 - val_accuracy: 0.5921
#
# Epoch 00126: val_loss did not improve from 0.23296
# Epoch 127/2000
#  - 1s - loss: 0.2715 - accuracy: 0.9343 - val_loss: 1.3022 - val_accuracy: 0.6032
#
# Epoch 00127: val_loss did not improve from 0.23296
# Epoch 128/2000
#  - 1s - loss: 0.2703 - accuracy: 0.9370 - val_loss: 0.4997 - val_accuracy: 0.5996
#
# Epoch 00128: val_loss did not improve from 0.23296
# Epoch 129/2000
#  - 1s - loss: 0.2656 - accuracy: 0.9392 - val_loss: 1.0897 - val_accuracy: 0.6158
#
# Epoch 00129: val_loss did not improve from 0.23296
# Epoch 130/2000
#  - 1s - loss: 0.2679 - accuracy: 0.9391 - val_loss: 0.4955 - val_accuracy: 0.6055
#
# Epoch 00130: val_loss did not improve from 0.23296
# Epoch 131/2000
#  - 1s - loss: 0.2602 - accuracy: 0.9382 - val_loss: 1.0664 - val_accuracy: 0.6252
#
# Epoch 00131: val_loss did not improve from 0.23296
# Epoch 132/2000
#  - 1s - loss: 0.2636 - accuracy: 0.9366 - val_loss: 0.8368 - val_accuracy: 0.6113
#
# Epoch 00132: val_loss did not improve from 0.23296
# Epoch 133/2000
#  - 1s - loss: 0.2605 - accuracy: 0.9384 - val_loss: 0.8746 - val_accuracy: 0.5876
#
# Epoch 00133: val_loss did not improve from 0.23296
# Epoch 134/2000
#  - 1s - loss: 0.2626 - accuracy: 0.9391 - val_loss: 1.3276 - val_accuracy: 0.5726
#
# Epoch 00134: val_loss did not improve from 0.23296
# Epoch 135/2000
#  - 1s - loss: 0.2560 - accuracy: 0.9424 - val_loss: 0.6325 - val_accuracy: 0.5748
#
# Epoch 00135: val_loss did not improve from 0.23296
# Epoch 136/2000
#  - 1s - loss: 0.2559 - accuracy: 0.9396 - val_loss: 1.4986 - val_accuracy: 0.5913
#
# Epoch 00136: val_loss did not improve from 0.23296
# Epoch 137/2000
#  - 1s - loss: 0.2542 - accuracy: 0.9414 - val_loss: 0.9249 - val_accuracy: 0.6124
#
# Epoch 00137: val_loss did not improve from 0.23296
# Epoch 138/2000
#  - 1s - loss: 0.2530 - accuracy: 0.9440 - val_loss: 0.8768 - val_accuracy: 0.6230
#
# Epoch 00138: val_loss did not improve from 0.23296
# Epoch 139/2000
#  - 1s - loss: 0.2535 - accuracy: 0.9435 - val_loss: 0.4173 - val_accuracy: 0.5748
#
# Epoch 00139: val_loss did not improve from 0.23296
# Epoch 140/2000
#  - 1s - loss: 0.2573 - accuracy: 0.9306 - val_loss: 1.0087 - val_accuracy: 0.5768
#
# Epoch 00140: val_loss did not improve from 0.23296
# Epoch 141/2000
#  - 1s - loss: 0.2462 - accuracy: 0.9421 - val_loss: 0.6644 - val_accuracy: 0.5717
#
# Epoch 00141: val_loss did not improve from 0.23296
# Epoch 142/2000
#  - 1s - loss: 0.2464 - accuracy: 0.9432 - val_loss: 0.4314 - val_accuracy: 0.6158
#
# Epoch 00142: val_loss did not improve from 0.23296
# Epoch 143/2000
#  - 1s - loss: 0.2455 - accuracy: 0.9471 - val_loss: 0.8360 - val_accuracy: 0.6177
#
# Epoch 00143: val_loss did not improve from 0.23296
# Epoch 144/2000
#  - 1s - loss: 0.2475 - accuracy: 0.9423 - val_loss: 0.3706 - val_accuracy: 0.5915
#
# Epoch 00144: val_loss did not improve from 0.23296
# Epoch 145/2000
#  - 1s - loss: 0.2438 - accuracy: 0.9422 - val_loss: 0.8840 - val_accuracy: 0.6007
#
# Epoch 00145: val_loss did not improve from 0.23296
# Epoch 146/2000
#  - 1s - loss: 0.2355 - accuracy: 0.9550 - val_loss: 1.3102 - val_accuracy: 0.6121
#
# Epoch 00146: val_loss did not improve from 0.23296
# Epoch 147/2000
#  - 1s - loss: 0.2281 - accuracy: 0.9558 - val_loss: 0.3589 - val_accuracy: 0.6043
#
# Epoch 00147: val_loss did not improve from 0.23296
# Epoch 148/2000
#  - 1s - loss: 0.2282 - accuracy: 0.9575 - val_loss: 0.7807 - val_accuracy: 0.6124
#
# Epoch 00148: val_loss did not improve from 0.23296
# Epoch 149/2000
#  - 1s - loss: 0.2238 - accuracy: 0.9575 - val_loss: 0.8246 - val_accuracy: 0.6183
#
# Epoch 00149: val_loss did not improve from 0.23296
# Epoch 150/2000
#  - 1s - loss: 0.2265 - accuracy: 0.9582 - val_loss: 1.1253 - val_accuracy: 0.6197
#
# Epoch 00150: val_loss did not improve from 0.23296
# Epoch 151/2000
#  - 1s - loss: 0.2198 - accuracy: 0.9607 - val_loss: 0.5205 - val_accuracy: 0.6199
#
# Epoch 00151: val_loss did not improve from 0.23296
# Epoch 152/2000
#  - 1s - loss: 0.2166 - accuracy: 0.9591 - val_loss: 1.5707 - val_accuracy: 0.5871
#
# Epoch 00152: val_loss did not improve from 0.23296
# Epoch 153/2000
#  - 1s - loss: 0.2147 - accuracy: 0.9605 - val_loss: 0.6018 - val_accuracy: 0.5790
#
# Epoch 00153: val_loss did not improve from 0.23296
# Epoch 154/2000
#  - 1s - loss: 0.2162 - accuracy: 0.9601 - val_loss: 0.8069 - val_accuracy: 0.6158
#
# Epoch 00154: val_loss did not improve from 0.23296
# Epoch 155/2000
#  - 1s - loss: 0.2171 - accuracy: 0.9606 - val_loss: 0.8986 - val_accuracy: 0.6030
#
# Epoch 00155: val_loss did not improve from 0.23296
# Epoch 156/2000
#  - 1s - loss: 0.2138 - accuracy: 0.9570 - val_loss: 0.9285 - val_accuracy: 0.6339
#
# Epoch 00156: val_loss did not improve from 0.23296
# Epoch 157/2000
#  - 1s - loss: 0.2128 - accuracy: 0.9614 - val_loss: 0.3515 - val_accuracy: 0.6244
#
# Epoch 00157: val_loss did not improve from 0.23296
# Epoch 158/2000
#  - 1s - loss: 0.2126 - accuracy: 0.9625 - val_loss: 1.5976 - val_accuracy: 0.5918
#
# Epoch 00158: val_loss did not improve from 0.23296
# Epoch 159/2000
#  - 1s - loss: 0.2195 - accuracy: 0.9475 - val_loss: 1.2459 - val_accuracy: 0.5587
#
# Epoch 00159: val_loss did not improve from 0.23296
# Epoch 160/2000
#  - 1s - loss: 0.2056 - accuracy: 0.9588 - val_loss: 0.4729 - val_accuracy: 0.6166
#
# Epoch 00160: val_loss did not improve from 0.23296
# Epoch 161/2000
#  - 1s - loss: 0.1992 - accuracy: 0.9690 - val_loss: 0.8612 - val_accuracy: 0.5932
#
# Epoch 00161: val_loss did not improve from 0.23296
# Epoch 162/2000
#  - 1s - loss: 0.2032 - accuracy: 0.9669 - val_loss: 0.5124 - val_accuracy: 0.5862
#
# Epoch 00162: val_loss did not improve from 0.23296
# Epoch 163/2000
#  - 1s - loss: 0.2088 - accuracy: 0.9560 - val_loss: 0.5322 - val_accuracy: 0.6208
#
# Epoch 00163: val_loss did not improve from 0.23296
# Epoch 164/2000
#  - 1s - loss: 0.2067 - accuracy: 0.9625 - val_loss: 0.4997 - val_accuracy: 0.5991
#
# Epoch 00164: val_loss did not improve from 0.23296
# Epoch 165/2000
#  - 1s - loss: 0.1994 - accuracy: 0.9600 - val_loss: 0.5359 - val_accuracy: 0.5985
#
# Epoch 00165: val_loss did not improve from 0.23296
# Epoch 166/2000
#  - 1s - loss: 0.1924 - accuracy: 0.9713 - val_loss: 0.8208 - val_accuracy: 0.6144
#
# Epoch 00166: val_loss did not improve from 0.23296
# Epoch 167/2000
#  - 1s - loss: 0.1915 - accuracy: 0.9693 - val_loss: 1.3071 - val_accuracy: 0.6016
#
# Epoch 00167: val_loss did not improve from 0.23296
# Epoch 168/2000
#  - 1s - loss: 0.1856 - accuracy: 0.9708 - val_loss: 1.2281 - val_accuracy: 0.6177
#
# Epoch 00168: val_loss did not improve from 0.23296
# Epoch 169/2000
#  - 1s - loss: 0.1877 - accuracy: 0.9733 - val_loss: 0.5446 - val_accuracy: 0.5952
#
# Epoch 00169: val_loss did not improve from 0.23296
# Epoch 170/2000
#  - 1s - loss: 0.1894 - accuracy: 0.9643 - val_loss: 0.8583 - val_accuracy: 0.5706
#
# Epoch 00170: val_loss did not improve from 0.23296
# Epoch 171/2000
#  - 1s - loss: 0.1822 - accuracy: 0.9723 - val_loss: 0.5008 - val_accuracy: 0.6105
#
# Epoch 00171: val_loss did not improve from 0.23296
# Epoch 172/2000
#  - 1s - loss: 0.1800 - accuracy: 0.9761 - val_loss: 1.2679 - val_accuracy: 0.5971
#
# Epoch 00172: val_loss did not improve from 0.23296
# Epoch 173/2000
#  - 1s - loss: 0.1857 - accuracy: 0.9751 - val_loss: 2.6833 - val_accuracy: 0.5996
#
# Epoch 00173: val_loss did not improve from 0.23296
# Epoch 174/2000
#  - 1s - loss: 0.1878 - accuracy: 0.9691 - val_loss: 0.2177 - val_accuracy: 0.6183
#
# Epoch 00174: val_loss improved from 0.23296 to 0.21765, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT_shuffle.h5
# Epoch 175/2000
#  - 1s - loss: 0.1834 - accuracy: 0.9719 - val_loss: 1.2456 - val_accuracy: 0.6177
#
# Epoch 00175: val_loss did not improve from 0.21765
# Epoch 176/2000
#  - 1s - loss: 0.1829 - accuracy: 0.9658 - val_loss: 0.8543 - val_accuracy: 0.6108
#
# Epoch 00176: val_loss did not improve from 0.21765
# Epoch 177/2000
#  - 1s - loss: 0.1770 - accuracy: 0.9764 - val_loss: 0.9536 - val_accuracy: 0.5929
#
# Epoch 00177: val_loss did not improve from 0.21765
# Epoch 178/2000
#  - 1s - loss: 0.1752 - accuracy: 0.9692 - val_loss: 0.8876 - val_accuracy: 0.6194
#
# Epoch 00178: val_loss did not improve from 0.21765
# Epoch 179/2000
#  - 1s - loss: 0.1722 - accuracy: 0.9784 - val_loss: 0.4309 - val_accuracy: 0.5907
#
# Epoch 00179: val_loss did not improve from 0.21765
# Epoch 180/2000
#  - 1s - loss: 0.1715 - accuracy: 0.9739 - val_loss: 0.2568 - val_accuracy: 0.6032
#
# Epoch 00180: val_loss did not improve from 0.21765
# Epoch 181/2000
#  - 1s - loss: 0.1711 - accuracy: 0.9807 - val_loss: 1.3916 - val_accuracy: 0.5846
#
# Epoch 00181: val_loss did not improve from 0.21765
# Epoch 182/2000
#  - 1s - loss: 0.1862 - accuracy: 0.9604 - val_loss: 1.6859 - val_accuracy: 0.5904
#
# Epoch 00182: val_loss did not improve from 0.21765
# Epoch 183/2000
#  - 1s - loss: 0.1710 - accuracy: 0.9773 - val_loss: 0.5697 - val_accuracy: 0.6091
#
# Epoch 00183: val_loss did not improve from 0.21765
# Epoch 184/2000
#  - 1s - loss: 0.1637 - accuracy: 0.9793 - val_loss: 0.8101 - val_accuracy: 0.6174
#
# Epoch 00184: val_loss did not improve from 0.21765
# Epoch 185/2000
#  - 1s - loss: 0.1620 - accuracy: 0.9820 - val_loss: 0.8553 - val_accuracy: 0.5907
#
# Epoch 00185: val_loss did not improve from 0.21765
# Epoch 186/2000
#  - 1s - loss: 0.1587 - accuracy: 0.9800 - val_loss: 0.8293 - val_accuracy: 0.6002
#
# Epoch 00186: val_loss did not improve from 0.21765
# Epoch 187/2000
#  - 1s - loss: 0.1567 - accuracy: 0.9839 - val_loss: 0.9616 - val_accuracy: 0.6010
#
# Epoch 00187: val_loss did not improve from 0.21765
# Epoch 188/2000
#  - 1s - loss: 0.1592 - accuracy: 0.9816 - val_loss: 0.2283 - val_accuracy: 0.5938
#
# Epoch 00188: val_loss did not improve from 0.21765
# Epoch 189/2000
#  - 1s - loss: 0.1605 - accuracy: 0.9771 - val_loss: 1.3593 - val_accuracy: 0.5573
#
# Epoch 00189: val_loss did not improve from 0.21765
# Epoch 190/2000
#  - 1s - loss: 0.1653 - accuracy: 0.9690 - val_loss: 1.4620 - val_accuracy: 0.5745
#
# Epoch 00190: val_loss did not improve from 0.21765
# Epoch 191/2000
#  - 1s - loss: 0.1556 - accuracy: 0.9787 - val_loss: 0.4313 - val_accuracy: 0.5843
#
# Epoch 00191: val_loss did not improve from 0.21765
# Epoch 192/2000
#  - 1s - loss: 0.1480 - accuracy: 0.9839 - val_loss: 1.2653 - val_accuracy: 0.6071
#
# Epoch 00192: val_loss did not improve from 0.21765
# Epoch 193/2000
#  - 1s - loss: 0.1543 - accuracy: 0.9831 - val_loss: 0.1364 - val_accuracy: 0.5899
#
# Epoch 00193: val_loss improved from 0.21765 to 0.13636, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT_shuffle.h5
# Epoch 194/2000
#  - 1s - loss: 0.1540 - accuracy: 0.9779 - val_loss: 0.3600 - val_accuracy: 0.5776
#
# Epoch 00194: val_loss did not improve from 0.13636
# Epoch 195/2000
#  - 1s - loss: 0.1488 - accuracy: 0.9777 - val_loss: 1.6101 - val_accuracy: 0.5857
#
# Epoch 00195: val_loss did not improve from 0.13636
# Epoch 196/2000
#  - 1s - loss: 0.1446 - accuracy: 0.9835 - val_loss: 0.8600 - val_accuracy: 0.5921
#
# Epoch 00196: val_loss did not improve from 0.13636
# Epoch 197/2000
#  - 1s - loss: 0.1431 - accuracy: 0.9849 - val_loss: 0.6428 - val_accuracy: 0.5993
#
# Epoch 00197: val_loss did not improve from 0.13636
# Epoch 198/2000
#  - 1s - loss: 0.1378 - accuracy: 0.9886 - val_loss: 0.1993 - val_accuracy: 0.6041
#
# Epoch 00198: val_loss did not improve from 0.13636
# Epoch 199/2000
#  - 1s - loss: 0.1350 - accuracy: 0.9886 - val_loss: 1.0258 - val_accuracy: 0.6133
#
# Epoch 00199: val_loss did not improve from 0.13636
# Epoch 200/2000
#  - 1s - loss: 0.1370 - accuracy: 0.9879 - val_loss: 0.3893 - val_accuracy: 0.6163
#
# Epoch 00200: val_loss did not improve from 0.13636
# Epoch 201/2000
#  - 1s - loss: 0.1369 - accuracy: 0.9855 - val_loss: 0.6144 - val_accuracy: 0.6239
#
# Epoch 00201: val_loss did not improve from 0.13636
# Epoch 202/2000
#  - 1s - loss: 0.1327 - accuracy: 0.9897 - val_loss: 0.3656 - val_accuracy: 0.6317
#
# Epoch 00202: val_loss did not improve from 0.13636
# Epoch 203/2000
#  - 1s - loss: 0.1363 - accuracy: 0.9879 - val_loss: 0.9711 - val_accuracy: 0.6269
#
# Epoch 00203: val_loss did not improve from 0.13636
# Epoch 204/2000
#  - 1s - loss: 0.1306 - accuracy: 0.9897 - val_loss: 1.0534 - val_accuracy: 0.6144
#
# Epoch 00204: val_loss did not improve from 0.13636
# Epoch 205/2000
#  - 1s - loss: 0.1285 - accuracy: 0.9905 - val_loss: 0.5875 - val_accuracy: 0.6208
#
# Epoch 00205: val_loss did not improve from 0.13636
# Epoch 206/2000
#  - 1s - loss: 0.1319 - accuracy: 0.9897 - val_loss: 0.9925 - val_accuracy: 0.5843
#
# Epoch 00206: val_loss did not improve from 0.13636
# Epoch 207/2000
#  - 1s - loss: 0.1508 - accuracy: 0.9787 - val_loss: 0.6079 - val_accuracy: 0.5798
#
# Epoch 00207: val_loss did not improve from 0.13636
# Epoch 208/2000
#  - 1s - loss: 0.1351 - accuracy: 0.9854 - val_loss: 0.8123 - val_accuracy: 0.6063
#
# Epoch 00208: val_loss did not improve from 0.13636
# Epoch 209/2000
#  - 1s - loss: 0.1271 - accuracy: 0.9892 - val_loss: 0.5749 - val_accuracy: 0.6158
#
# Epoch 00209: val_loss did not improve from 0.13636
# Epoch 210/2000
#  - 1s - loss: 0.1246 - accuracy: 0.9915 - val_loss: 0.5690 - val_accuracy: 0.5996
#
# Epoch 00210: val_loss did not improve from 0.13636
# Epoch 211/2000
#  - 1s - loss: 0.1266 - accuracy: 0.9899 - val_loss: 0.9751 - val_accuracy: 0.5854
#
# Epoch 00211: val_loss did not improve from 0.13636
# Epoch 212/2000
#  - 1s - loss: 0.1267 - accuracy: 0.9876 - val_loss: 1.2163 - val_accuracy: 0.5974
#
# Epoch 00212: val_loss did not improve from 0.13636
# Epoch 213/2000
#  - 1s - loss: 0.1229 - accuracy: 0.9889 - val_loss: 0.5086 - val_accuracy: 0.6110
#
# Epoch 00213: val_loss did not improve from 0.13636
# Epoch 214/2000
#  - 1s - loss: 0.1175 - accuracy: 0.9927 - val_loss: 1.2720 - val_accuracy: 0.5954
#
# Epoch 00214: val_loss did not improve from 0.13636
# Epoch 215/2000
#  - 1s - loss: 0.1190 - accuracy: 0.9914 - val_loss: 0.1885 - val_accuracy: 0.5982
#
# Epoch 00215: val_loss did not improve from 0.13636
# Epoch 216/2000
#  - 1s - loss: 0.1166 - accuracy: 0.9912 - val_loss: 3.0477 - val_accuracy: 0.6030
#
# Epoch 00216: val_loss did not improve from 0.13636
# Epoch 217/2000
#  - 1s - loss: 0.1138 - accuracy: 0.9934 - val_loss: 1.6048 - val_accuracy: 0.6194
#
# Epoch 00217: val_loss did not improve from 0.13636
# Epoch 218/2000
#  - 1s - loss: 0.1190 - accuracy: 0.9928 - val_loss: 0.6025 - val_accuracy: 0.5949
#
# Epoch 00218: val_loss did not improve from 0.13636
# Epoch 219/2000
#  - 1s - loss: 0.1208 - accuracy: 0.9856 - val_loss: 0.9559 - val_accuracy: 0.5949
#
# Epoch 00219: val_loss did not improve from 0.13636
# Epoch 220/2000
#  - 1s - loss: 0.1117 - accuracy: 0.9936 - val_loss: 1.7035 - val_accuracy: 0.6052
#
# Epoch 00220: val_loss did not improve from 0.13636
# Epoch 221/2000
#  - 1s - loss: 0.1126 - accuracy: 0.9934 - val_loss: 2.0441 - val_accuracy: 0.5963
#
# Epoch 00221: val_loss did not improve from 0.13636
# Epoch 222/2000
#  - 1s - loss: 0.1160 - accuracy: 0.9892 - val_loss: 0.8060 - val_accuracy: 0.6027
#
# Epoch 00222: val_loss did not improve from 0.13636
# Epoch 223/2000
#  - 1s - loss: 0.1112 - accuracy: 0.9925 - val_loss: 0.3625 - val_accuracy: 0.6060
#
# Epoch 00223: val_loss did not improve from 0.13636
# Epoch 224/2000
#  - 1s - loss: 0.1067 - accuracy: 0.9948 - val_loss: 2.7290 - val_accuracy: 0.6213
#
# Epoch 00224: val_loss did not improve from 0.13636
# Epoch 225/2000
#  - 1s - loss: 0.1097 - accuracy: 0.9944 - val_loss: 0.0760 - val_accuracy: 0.6230
#
# Epoch 00225: val_loss improved from 0.13636 to 0.07600, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT_shuffle.h5
# Epoch 226/2000
#  - 1s - loss: 0.1095 - accuracy: 0.9926 - val_loss: 0.2230 - val_accuracy: 0.6071
#
# Epoch 00226: val_loss did not improve from 0.07600
# Epoch 227/2000
#  - 1s - loss: 0.1077 - accuracy: 0.9927 - val_loss: 0.2010 - val_accuracy: 0.6066
#
# Epoch 00227: val_loss did not improve from 0.07600
# Epoch 228/2000
#  - 1s - loss: 0.1029 - accuracy: 0.9929 - val_loss: 1.3188 - val_accuracy: 0.6213
#
# Epoch 00228: val_loss did not improve from 0.07600
# Epoch 229/2000
#  - 1s - loss: 0.1018 - accuracy: 0.9941 - val_loss: 0.7322 - val_accuracy: 0.6264
#
# Epoch 00229: val_loss did not improve from 0.07600
# Epoch 230/2000
#  - 1s - loss: 0.1031 - accuracy: 0.9954 - val_loss: 1.2644 - val_accuracy: 0.6094
#
# Epoch 00230: val_loss did not improve from 0.07600
# Epoch 231/2000
#  - 1s - loss: 0.1017 - accuracy: 0.9933 - val_loss: 0.3109 - val_accuracy: 0.5991
#
# Epoch 00231: val_loss did not improve from 0.07600
# Epoch 232/2000
#  - 1s - loss: 0.1036 - accuracy: 0.9919 - val_loss: 0.6727 - val_accuracy: 0.5862
#
# Epoch 00232: val_loss did not improve from 0.07600
# Epoch 233/2000
#  - 1s - loss: 0.1004 - accuracy: 0.9940 - val_loss: 1.0916 - val_accuracy: 0.6060
#
# Epoch 00233: val_loss did not improve from 0.07600
# Epoch 234/2000
#  - 1s - loss: 0.0996 - accuracy: 0.9932 - val_loss: 0.2205 - val_accuracy: 0.6297
#
# Epoch 00234: val_loss did not improve from 0.07600
# Epoch 235/2000
#  - 1s - loss: 0.0967 - accuracy: 0.9956 - val_loss: 1.4558 - val_accuracy: 0.6350
#
# Epoch 00235: val_loss did not improve from 0.07600
# Epoch 236/2000
#  - 1s - loss: 0.0998 - accuracy: 0.9948 - val_loss: 0.7583 - val_accuracy: 0.6283
#
# Epoch 00236: val_loss did not improve from 0.07600
# Epoch 237/2000
#  - 1s - loss: 0.0929 - accuracy: 0.9957 - val_loss: 1.7825 - val_accuracy: 0.6158
#
# Epoch 00237: val_loss did not improve from 0.07600
# Epoch 238/2000
#  - 1s - loss: 0.0915 - accuracy: 0.9965 - val_loss: 0.9214 - val_accuracy: 0.5924
#
# Epoch 00238: val_loss did not improve from 0.07600
# Epoch 239/2000
#  - 1s - loss: 0.0961 - accuracy: 0.9939 - val_loss: 0.4192 - val_accuracy: 0.5823
#
# Epoch 00239: val_loss did not improve from 0.07600
# Epoch 240/2000
#  - 1s - loss: 0.0939 - accuracy: 0.9953 - val_loss: 2.1877 - val_accuracy: 0.5904
#
# Epoch 00240: val_loss did not improve from 0.07600
# Epoch 241/2000
#  - 1s - loss: 0.0880 - accuracy: 0.9965 - val_loss: 1.2269 - val_accuracy: 0.6130
#
# Epoch 00241: val_loss did not improve from 0.07600
# Epoch 242/2000
#  - 1s - loss: 0.0885 - accuracy: 0.9974 - val_loss: 2.1845 - val_accuracy: 0.6108
#
# Epoch 00242: val_loss did not improve from 0.07600
# Epoch 243/2000
#  - 1s - loss: 0.0880 - accuracy: 0.9967 - val_loss: 1.7043 - val_accuracy: 0.6213
#
# Epoch 00243: val_loss did not improve from 0.07600
# Epoch 244/2000
#  - 1s - loss: 0.0864 - accuracy: 0.9976 - val_loss: 0.5692 - val_accuracy: 0.6191
#
# Epoch 00244: val_loss did not improve from 0.07600
# Epoch 245/2000
#  - 1s - loss: 0.0860 - accuracy: 0.9977 - val_loss: 0.2763 - val_accuracy: 0.6255
#
# Epoch 00245: val_loss did not improve from 0.07600
# Epoch 246/2000
#  - 1s - loss: 0.0891 - accuracy: 0.9957 - val_loss: 1.5125 - val_accuracy: 0.6096
#
# Epoch 00246: val_loss did not improve from 0.07600
# Epoch 247/2000
#  - 1s - loss: 0.0848 - accuracy: 0.9968 - val_loss: 0.7941 - val_accuracy: 0.6186
#
# Epoch 00247: val_loss did not improve from 0.07600
# Epoch 248/2000
#  - 1s - loss: 0.0823 - accuracy: 0.9976 - val_loss: 2.8208 - val_accuracy: 0.6135
#
# Epoch 00248: val_loss did not improve from 0.07600
# Epoch 249/2000
#  - 1s - loss: 0.0810 - accuracy: 0.9980 - val_loss: 0.8250 - val_accuracy: 0.6066
#
# Epoch 00249: val_loss did not improve from 0.07600
# Epoch 250/2000
#  - 1s - loss: 0.0811 - accuracy: 0.9980 - val_loss: 2.7391 - val_accuracy: 0.6030
#
# Epoch 00250: val_loss did not improve from 0.07600
# Epoch 251/2000
#  - 1s - loss: 0.0858 - accuracy: 0.9954 - val_loss: 1.0239 - val_accuracy: 0.5924
#
# Epoch 00251: val_loss did not improve from 0.07600
# Epoch 252/2000
#  - 1s - loss: 0.0813 - accuracy: 0.9958 - val_loss: 1.7254 - val_accuracy: 0.6032
#
# Epoch 00252: val_loss did not improve from 0.07600
# Epoch 253/2000
#  - 1s - loss: 0.0791 - accuracy: 0.9980 - val_loss: 3.6225 - val_accuracy: 0.6127
#
# Epoch 00253: val_loss did not improve from 0.07600
# Epoch 254/2000
#  - 1s - loss: 0.0779 - accuracy: 0.9975 - val_loss: 1.1465 - val_accuracy: 0.6177
#
# Epoch 00254: val_loss did not improve from 0.07600
# Epoch 255/2000
#  - 1s - loss: 0.0764 - accuracy: 0.9977 - val_loss: 1.1424 - val_accuracy: 0.6278
#
# Epoch 00255: val_loss did not improve from 0.07600
# Epoch 256/2000
#  - 1s - loss: 0.0785 - accuracy: 0.9978 - val_loss: 0.8431 - val_accuracy: 0.5993
#
# Epoch 00256: val_loss did not improve from 0.07600
# Epoch 257/2000
#  - 1s - loss: 0.0792 - accuracy: 0.9972 - val_loss: 1.3570 - val_accuracy: 0.5985
#
# Epoch 00257: val_loss did not improve from 0.07600
# Epoch 258/2000
#  - 1s - loss: 0.0777 - accuracy: 0.9968 - val_loss: 0.9181 - val_accuracy: 0.5935
#
# Epoch 00258: val_loss did not improve from 0.07600
# Epoch 259/2000
#  - 1s - loss: 0.0834 - accuracy: 0.9956 - val_loss: 0.3350 - val_accuracy: 0.5940
#
# Epoch 00259: val_loss did not improve from 0.07600
# Epoch 260/2000
#  - 1s - loss: 0.0829 - accuracy: 0.9949 - val_loss: 1.9398 - val_accuracy: 0.6119
#
# Epoch 00260: val_loss did not improve from 0.07600
# Epoch 261/2000
#  - 1s - loss: 0.0731 - accuracy: 0.9988 - val_loss: 0.7901 - val_accuracy: 0.6035
#
# Epoch 00261: val_loss did not improve from 0.07600
# Epoch 262/2000
#  - 1s - loss: 0.0724 - accuracy: 0.9982 - val_loss: 0.4785 - val_accuracy: 0.6049
#
# Epoch 00262: val_loss did not improve from 0.07600
# Epoch 263/2000
#  - 1s - loss: 0.0740 - accuracy: 0.9981 - val_loss: 1.2487 - val_accuracy: 0.6227
#
# Epoch 00263: val_loss did not improve from 0.07600
# Epoch 264/2000
#  - 1s - loss: 0.0749 - accuracy: 0.9978 - val_loss: 0.5302 - val_accuracy: 0.6166
#
# Epoch 00264: val_loss did not improve from 0.07600
# Epoch 265/2000
#  - 1s - loss: 0.0731 - accuracy: 0.9980 - val_loss: 0.5570 - val_accuracy: 0.5996
#
# Epoch 00265: val_loss did not improve from 0.07600
# Epoch 266/2000
#  - 1s - loss: 0.0835 - accuracy: 0.9900 - val_loss: 2.0906 - val_accuracy: 0.5963
#
# Epoch 00266: val_loss did not improve from 0.07600
# Epoch 267/2000
#  - 1s - loss: 0.0679 - accuracy: 0.9981 - val_loss: 0.2984 - val_accuracy: 0.6149
#
# Epoch 00267: val_loss did not improve from 0.07600
# Epoch 268/2000
#  - 1s - loss: 0.0643 - accuracy: 0.9990 - val_loss: 0.5266 - val_accuracy: 0.6174
#
# Epoch 00268: val_loss did not improve from 0.07600
# Epoch 269/2000
#  - 1s - loss: 0.0637 - accuracy: 0.9988 - val_loss: 1.1712 - val_accuracy: 0.6216
#
# Epoch 00269: val_loss did not improve from 0.07600
# Epoch 270/2000
#  - 1s - loss: 0.0645 - accuracy: 0.9990 - val_loss: 0.2923 - val_accuracy: 0.6130
#
# Epoch 00270: val_loss did not improve from 0.07600
# Epoch 271/2000
#  - 1s - loss: 0.0638 - accuracy: 0.9990 - val_loss: 1.7137 - val_accuracy: 0.6188
#
# Epoch 00271: val_loss did not improve from 0.07600
# Epoch 272/2000
#  - 1s - loss: 0.0632 - accuracy: 0.9986 - val_loss: 1.0476 - val_accuracy: 0.6286
#
# Epoch 00272: val_loss did not improve from 0.07600
# Epoch 273/2000
#  - 1s - loss: 0.0614 - accuracy: 0.9991 - val_loss: 0.3760 - val_accuracy: 0.6099
#
# Epoch 00273: val_loss did not improve from 0.07600
# Epoch 274/2000
#  - 1s - loss: 0.0584 - accuracy: 0.9993 - val_loss: 0.3409 - val_accuracy: 0.6180
#
# Epoch 00274: val_loss did not improve from 0.07600
# Epoch 275/2000
#  - 1s - loss: 0.0602 - accuracy: 0.9993 - val_loss: 0.0677 - val_accuracy: 0.6160
#
# Epoch 00275: val_loss improved from 0.07600 to 0.06771, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT_shuffle.h5
# Epoch 276/2000
#  - 1s - loss: 0.0641 - accuracy: 0.9988 - val_loss: 1.1209 - val_accuracy: 0.6241
#
# Epoch 00276: val_loss did not improve from 0.06771
# Epoch 277/2000
#  - 1s - loss: 0.0671 - accuracy: 0.9985 - val_loss: 0.4529 - val_accuracy: 0.6066
#
# Epoch 00277: val_loss did not improve from 0.06771
# Epoch 278/2000
#  - 1s - loss: 0.0653 - accuracy: 0.9974 - val_loss: 0.7496 - val_accuracy: 0.6094
#
# Epoch 00278: val_loss did not improve from 0.06771
# Epoch 279/2000
#  - 1s - loss: 0.0594 - accuracy: 0.9989 - val_loss: 1.3218 - val_accuracy: 0.6158
#
# Epoch 00279: val_loss did not improve from 0.06771
# Epoch 280/2000
#  - 1s - loss: 0.0604 - accuracy: 0.9993 - val_loss: 0.5996 - val_accuracy: 0.6250
#
# Epoch 00280: val_loss did not improve from 0.06771
# Epoch 281/2000
#  - 1s - loss: 0.0698 - accuracy: 0.9954 - val_loss: 0.7242 - val_accuracy: 0.6094
#
# Epoch 00281: val_loss did not improve from 0.06771
# Epoch 282/2000
#  - 1s - loss: 0.0633 - accuracy: 0.9977 - val_loss: 0.6346 - val_accuracy: 0.6283
#
# Epoch 00282: val_loss did not improve from 0.06771
# Epoch 283/2000
#  - 1s - loss: 0.0600 - accuracy: 0.9988 - val_loss: 1.0997 - val_accuracy: 0.6328
#
# Epoch 00283: val_loss did not improve from 0.06771
# Epoch 284/2000
#  - 1s - loss: 0.0568 - accuracy: 0.9995 - val_loss: 2.6349 - val_accuracy: 0.6133
#
# Epoch 00284: val_loss did not improve from 0.06771
# Epoch 285/2000
#  - 1s - loss: 0.0589 - accuracy: 0.9986 - val_loss: 0.5432 - val_accuracy: 0.6130
#
# Epoch 00285: val_loss did not improve from 0.06771
# Epoch 286/2000
#  - 1s - loss: 0.0575 - accuracy: 0.9990 - val_loss: 0.3770 - val_accuracy: 0.6272
#
# Epoch 00286: val_loss did not improve from 0.06771
# Epoch 287/2000
#  - 1s - loss: 0.0563 - accuracy: 0.9990 - val_loss: 0.2999 - val_accuracy: 0.6241
#
# Epoch 00287: val_loss did not improve from 0.06771
# Epoch 288/2000
#  - 1s - loss: 0.0572 - accuracy: 0.9992 - val_loss: 0.6132 - val_accuracy: 0.6222
#
# Epoch 00288: val_loss did not improve from 0.06771
# Epoch 289/2000
#  - 1s - loss: 0.0560 - accuracy: 0.9995 - val_loss: 0.3562 - val_accuracy: 0.6241
#
# Epoch 00289: val_loss did not improve from 0.06771
# Epoch 290/2000
#  - 1s - loss: 0.0582 - accuracy: 0.9984 - val_loss: 2.0550 - val_accuracy: 0.6010
#
# Epoch 00290: val_loss did not improve from 0.06771
# Epoch 291/2000
#  - 1s - loss: 0.0596 - accuracy: 0.9973 - val_loss: 0.7100 - val_accuracy: 0.6049
#
# Epoch 00291: val_loss did not improve from 0.06771
# Epoch 292/2000
#  - 1s - loss: 0.0544 - accuracy: 0.9989 - val_loss: 0.9781 - val_accuracy: 0.6124
#
# Epoch 00292: val_loss did not improve from 0.06771
# Epoch 293/2000
#  - 1s - loss: 0.0510 - accuracy: 0.9995 - val_loss: 2.2705 - val_accuracy: 0.6102
#
# Epoch 00293: val_loss did not improve from 0.06771
# Epoch 294/2000
#  - 1s - loss: 0.0499 - accuracy: 0.9994 - val_loss: 2.5861 - val_accuracy: 0.5979
#
# Epoch 00294: val_loss did not improve from 0.06771
# Epoch 295/2000
#  - 1s - loss: 0.0505 - accuracy: 0.9991 - val_loss: 0.7813 - val_accuracy: 0.6082
#
# Epoch 00295: val_loss did not improve from 0.06771
# Epoch 296/2000
#  - 1s - loss: 0.0506 - accuracy: 0.9995 - val_loss: 1.4178 - val_accuracy: 0.6188
#
# Epoch 00296: val_loss did not improve from 0.06771
# Epoch 297/2000
#  - 1s - loss: 0.0512 - accuracy: 0.9995 - val_loss: 1.4935 - val_accuracy: 0.6091
#
# Epoch 00297: val_loss did not improve from 0.06771
# Epoch 298/2000
#  - 1s - loss: 0.0586 - accuracy: 0.9976 - val_loss: 0.1164 - val_accuracy: 0.5896
#
# Epoch 00298: val_loss did not improve from 0.06771
# Epoch 299/2000
#  - 1s - loss: 0.0512 - accuracy: 0.9989 - val_loss: 0.8710 - val_accuracy: 0.6138
#
# Epoch 00299: val_loss did not improve from 0.06771
# Epoch 300/2000
#  - 1s - loss: 0.0482 - accuracy: 0.9998 - val_loss: 1.3309 - val_accuracy: 0.6063
#
# Epoch 00300: val_loss did not improve from 0.06771
# Epoch 301/2000
#  - 1s - loss: 0.0484 - accuracy: 0.9993 - val_loss: 0.8791 - val_accuracy: 0.6013
#
# Epoch 00301: val_loss did not improve from 0.06771
# Epoch 302/2000
#  - 1s - loss: 0.0468 - accuracy: 0.9993 - val_loss: 0.9663 - val_accuracy: 0.6135
#
# Epoch 00302: val_loss did not improve from 0.06771
# Epoch 303/2000
#  - 1s - loss: 0.0448 - accuracy: 0.9996 - val_loss: 0.2985 - val_accuracy: 0.6158
#
# Epoch 00303: val_loss did not improve from 0.06771
# Epoch 304/2000
#  - 1s - loss: 0.0456 - accuracy: 0.9997 - val_loss: 0.7954 - val_accuracy: 0.6152
#
# Epoch 00304: val_loss did not improve from 0.06771
# Epoch 305/2000
#  - 1s - loss: 0.0451 - accuracy: 0.9991 - val_loss: 0.3874 - val_accuracy: 0.6141
#
# Epoch 00305: val_loss did not improve from 0.06771
# Epoch 306/2000
#  - 1s - loss: 0.0439 - accuracy: 0.9996 - val_loss: 0.1337 - val_accuracy: 0.6002
#
# Epoch 00306: val_loss did not improve from 0.06771
# Epoch 307/2000
#  - 1s - loss: 0.0460 - accuracy: 0.9990 - val_loss: 0.5437 - val_accuracy: 0.6130
#
# Epoch 00307: val_loss did not improve from 0.06771
# Epoch 308/2000
#  - 1s - loss: 0.0451 - accuracy: 0.9996 - val_loss: 2.4687 - val_accuracy: 0.5946
#
# Epoch 00308: val_loss did not improve from 0.06771
# Epoch 309/2000
#  - 1s - loss: 0.0506 - accuracy: 0.9976 - val_loss: 0.3351 - val_accuracy: 0.5957
#
# Epoch 00309: val_loss did not improve from 0.06771
# Epoch 310/2000
#  - 1s - loss: 0.0448 - accuracy: 0.9994 - val_loss: 1.5627 - val_accuracy: 0.6158
#
# Epoch 00310: val_loss did not improve from 0.06771
# Epoch 311/2000
#  - 1s - loss: 0.0434 - accuracy: 0.9998 - val_loss: 0.4704 - val_accuracy: 0.6239
#
# Epoch 00311: val_loss did not improve from 0.06771
# Epoch 312/2000
#  - 1s - loss: 0.0435 - accuracy: 0.9996 - val_loss: 1.5749 - val_accuracy: 0.6197
#
# Epoch 00312: val_loss did not improve from 0.06771
# Epoch 313/2000
#  - 1s - loss: 0.0432 - accuracy: 0.9996 - val_loss: 1.3869 - val_accuracy: 0.5935
#
# Epoch 00313: val_loss did not improve from 0.06771
# Epoch 314/2000
#  - 1s - loss: 0.0427 - accuracy: 0.9992 - val_loss: 0.2945 - val_accuracy: 0.5938
#
# Epoch 00314: val_loss did not improve from 0.06771
# Epoch 315/2000
#  - 1s - loss: 0.0414 - accuracy: 0.9998 - val_loss: 0.1164 - val_accuracy: 0.6119
#
# Epoch 00315: val_loss did not improve from 0.06771
# Epoch 316/2000
#  - 1s - loss: 0.0388 - accuracy: 0.9997 - val_loss: 0.5262 - val_accuracy: 0.6252
#
# Epoch 00316: val_loss did not improve from 0.06771
# Epoch 317/2000
#  - 1s - loss: 0.0381 - accuracy: 0.9998 - val_loss: 1.2306 - val_accuracy: 0.6177
#
# Epoch 00317: val_loss did not improve from 0.06771
# Epoch 318/2000
#  - 1s - loss: 0.0377 - accuracy: 0.9997 - val_loss: 1.9827 - val_accuracy: 0.6135
#
# Epoch 00318: val_loss did not improve from 0.06771
# Epoch 319/2000
#  - 1s - loss: 0.0385 - accuracy: 0.9998 - val_loss: 1.7538 - val_accuracy: 0.5971
#
# Epoch 00319: val_loss did not improve from 0.06771
# Epoch 320/2000
#  - 1s - loss: 0.0371 - accuracy: 0.9998 - val_loss: 1.0705 - val_accuracy: 0.6130
#
# Epoch 00320: val_loss did not improve from 0.06771
# Epoch 321/2000
#  - 1s - loss: 0.0363 - accuracy: 0.9996 - val_loss: 1.4116 - val_accuracy: 0.6197
#
# Epoch 00321: val_loss did not improve from 0.06771
# Epoch 322/2000
#  - 1s - loss: 0.0373 - accuracy: 0.9999 - val_loss: 1.4213 - val_accuracy: 0.6147
#
# Epoch 00322: val_loss did not improve from 0.06771
# Epoch 323/2000
#  - 1s - loss: 0.0370 - accuracy: 0.9999 - val_loss: 0.6834 - val_accuracy: 0.6155
#
# Epoch 00323: val_loss did not improve from 0.06771
# Epoch 324/2000
#  - 1s - loss: 0.0352 - accuracy: 0.9998 - val_loss: 0.0676 - val_accuracy: 0.6169
#
# Epoch 00324: val_loss improved from 0.06771 to 0.06762, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT_shuffle.h5
# Epoch 325/2000
#  - 1s - loss: 0.0349 - accuracy: 0.9998 - val_loss: 0.8414 - val_accuracy: 0.6052
#
# Epoch 00325: val_loss did not improve from 0.06762
# Epoch 326/2000
#  - 1s - loss: 0.0360 - accuracy: 0.9995 - val_loss: 2.7368 - val_accuracy: 0.6043
#
# Epoch 00326: val_loss did not improve from 0.06762
# Epoch 327/2000
#  - 1s - loss: 0.0350 - accuracy: 0.9999 - val_loss: 0.3524 - val_accuracy: 0.6108
#
# Epoch 00327: val_loss did not improve from 0.06762
# Epoch 328/2000
#  - 1s - loss: 0.0340 - accuracy: 0.9997 - val_loss: 1.9586 - val_accuracy: 0.6202
#
# Epoch 00328: val_loss did not improve from 0.06762
# Epoch 329/2000
#  - 1s - loss: 0.0332 - accuracy: 0.9998 - val_loss: 1.3390 - val_accuracy: 0.6160
#
# Epoch 00329: val_loss did not improve from 0.06762
# Epoch 330/2000
#  - 1s - loss: 0.0343 - accuracy: 0.9998 - val_loss: 0.6935 - val_accuracy: 0.6080
#
# Epoch 00330: val_loss did not improve from 0.06762
# Epoch 331/2000
#  - 1s - loss: 0.0365 - accuracy: 0.9993 - val_loss: 1.2210 - val_accuracy: 0.6046
#
# Epoch 00331: val_loss did not improve from 0.06762
# Epoch 332/2000
#  - 1s - loss: 0.0351 - accuracy: 0.9998 - val_loss: 1.1014 - val_accuracy: 0.6186
#
# Epoch 00332: val_loss did not improve from 0.06762
# Epoch 333/2000
#  - 1s - loss: 0.0332 - accuracy: 0.9999 - val_loss: 1.1003 - val_accuracy: 0.6199
#
# Epoch 00333: val_loss did not improve from 0.06762
# Epoch 334/2000
#  - 1s - loss: 0.0318 - accuracy: 0.9999 - val_loss: 1.4668 - val_accuracy: 0.6286
#
# Epoch 00334: val_loss did not improve from 0.06762
# Epoch 335/2000
#  - 1s - loss: 0.0318 - accuracy: 0.9999 - val_loss: 1.9806 - val_accuracy: 0.6166
#
# Epoch 00335: val_loss did not improve from 0.06762
# Epoch 336/2000
#  - 1s - loss: 0.0343 - accuracy: 0.9990 - val_loss: 0.7552 - val_accuracy: 0.6119
#
# Epoch 00336: val_loss did not improve from 0.06762
# Epoch 337/2000
#  - 1s - loss: 0.0315 - accuracy: 0.9998 - val_loss: 1.4820 - val_accuracy: 0.6199
#
# Epoch 00337: val_loss did not improve from 0.06762
# Epoch 338/2000
#  - 1s - loss: 0.0304 - accuracy: 0.9998 - val_loss: 0.5547 - val_accuracy: 0.6239
#
# Epoch 00338: val_loss did not improve from 0.06762
# Epoch 339/2000
#  - 1s - loss: 0.0296 - accuracy: 0.9999 - val_loss: 0.6016 - val_accuracy: 0.6241
#
# Epoch 00339: val_loss did not improve from 0.06762
# Epoch 340/2000
#  - 1s - loss: 0.0301 - accuracy: 0.9999 - val_loss: 0.8654 - val_accuracy: 0.6163
#
# Epoch 00340: val_loss did not improve from 0.06762
# Epoch 341/2000
#  - 1s - loss: 0.0307 - accuracy: 1.0000 - val_loss: 0.5707 - val_accuracy: 0.6069
#
# Epoch 00341: val_loss did not improve from 0.06762
# Epoch 342/2000
#  - 1s - loss: 0.0302 - accuracy: 0.9999 - val_loss: 1.1738 - val_accuracy: 0.6205
#
# Epoch 00342: val_loss did not improve from 0.06762
# Epoch 343/2000
#  - 1s - loss: 0.0292 - accuracy: 0.9999 - val_loss: 1.8471 - val_accuracy: 0.6208
#
# Epoch 00343: val_loss did not improve from 0.06762
# Epoch 344/2000
#  - 1s - loss: 0.0291 - accuracy: 0.9999 - val_loss: 0.7561 - val_accuracy: 0.6063
#
# Epoch 00344: val_loss did not improve from 0.06762
# Epoch 345/2000
#  - 1s - loss: 0.0318 - accuracy: 0.9993 - val_loss: 1.8529 - val_accuracy: 0.5993
#
# Epoch 00345: val_loss did not improve from 0.06762
# Epoch 346/2000
#  - 1s - loss: 0.0285 - accuracy: 0.9999 - val_loss: 0.5918 - val_accuracy: 0.6066
#
# Epoch 00346: val_loss did not improve from 0.06762
# Epoch 347/2000
#  - 1s - loss: 0.0267 - accuracy: 0.9999 - val_loss: 1.3984 - val_accuracy: 0.6160
#
# Epoch 00347: val_loss did not improve from 0.06762
# Epoch 348/2000
#  - 1s - loss: 0.0269 - accuracy: 0.9997 - val_loss: 1.0676 - val_accuracy: 0.6213
#
# Epoch 00348: val_loss did not improve from 0.06762
# Epoch 349/2000
#  - 1s - loss: 0.0275 - accuracy: 0.9999 - val_loss: 3.2236 - val_accuracy: 0.6124
#
# Epoch 00349: val_loss did not improve from 0.06762
# Epoch 350/2000
#  - 1s - loss: 0.0277 - accuracy: 0.9998 - val_loss: 2.3714 - val_accuracy: 0.6180
#
# Epoch 00350: val_loss did not improve from 0.06762
# Epoch 351/2000
#  - 1s - loss: 0.0271 - accuracy: 0.9999 - val_loss: 1.7932 - val_accuracy: 0.6121
#
# Epoch 00351: val_loss did not improve from 0.06762
# Epoch 352/2000
#  - 1s - loss: 0.0262 - accuracy: 0.9999 - val_loss: 0.5233 - val_accuracy: 0.6147
#
# Epoch 00352: val_loss did not improve from 0.06762
# Epoch 353/2000
# ...
#
# Epoch 01222: val_loss did not improve from 0.00022
# Epoch 1223/2000
#  - 1s - loss: 1.1295e-04 - accuracy: 1.0000 - val_loss: 2.7805 - val_accuracy: 0.6166
#
# Epoch 01223: val_loss did not improve from 0.00022
# Epoch 1224/2000
#  - 1s - loss: 1.1237e-04 - accuracy: 1.0000 - val_loss: 1.5250 - val_accuracy: 0.6169
#
# Epoch 01224: val_loss did not improve from 0.00022
# Epoch 1225/2000
#  - 1s - loss: 1.1578e-04 - accuracy: 1.0000 - val_loss: 2.7404 - val_accuracy: 0.6160
#
# Epoch 01225: val_loss did not improve from 0.00022
# Epoch 1226/2000
#  - 1s - loss: 1.2022e-04 - accuracy: 1.0000 - val_loss: 1.9016 - val_accuracy: 0.6155
#
# Epoch 01226: val_loss did not improve from 0.00022
# Epoch 1227/2000
#  - 1s - loss: 1.1322e-04 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 0.6169
#
# Epoch 01227: val_loss did not improve from 0.00022
# Epoch 1228/2000
#  - 1s - loss: 1.0801e-04 - accuracy: 1.0000 - val_loss: 2.3501 - val_accuracy: 0.6160
#
# Epoch 01228: val_loss did not improve from 0.00022
# Epoch 1229/2000
#  - 1s - loss: 1.2145e-04 - accuracy: 1.0000 - val_loss: 4.3166 - val_accuracy: 0.6163
#
# Epoch 01229: val_loss did not improve from 0.00022
# Epoch 1230/2000
#  - 1s - loss: 1.2503e-04 - accuracy: 1.0000 - val_loss: 2.2413 - val_accuracy: 0.6149
#
# Epoch 01230: val_loss did not improve from 0.00022
# Epoch 1231/2000
#  - 1s - loss: 1.1976e-04 - accuracy: 1.0000 - val_loss: 4.0728 - val_accuracy: 0.6152
#
# Epoch 01231: val_loss did not improve from 0.00022
# Epoch 1232/2000
#  - 1s - loss: 1.0850e-04 - accuracy: 1.0000 - val_loss: 4.8747 - val_accuracy: 0.6155
#
# Epoch 01232: val_loss did not improve from 0.00022
# Epoch 1233/2000
#  - 1s - loss: 1.0491e-04 - accuracy: 1.0000 - val_loss: 0.1331 - val_accuracy: 0.6169
#
# Epoch 01233: val_loss did not improve from 0.00022
# Epoch 1234/2000
#  - 1s - loss: 1.0811e-04 - accuracy: 1.0000 - val_loss: 2.0802 - val_accuracy: 0.6172
#
# Epoch 01234: val_loss did not improve from 0.00022
# Epoch 1235/2000
#  - 1s - loss: 1.1651e-04 - accuracy: 1.0000 - val_loss: 0.1927 - val_accuracy: 0.6174
#
# Epoch 01235: val_loss did not improve from 0.00022
# Epoch 1236/2000
#  - 1s - loss: 1.0696e-04 - accuracy: 1.0000 - val_loss: 1.9197 - val_accuracy: 0.6180
#
# Epoch 01236: val_loss did not improve from 0.00022
# Epoch 1237/2000
#  - 1s - loss: 1.0964e-04 - accuracy: 1.0000 - val_loss: 3.9881 - val_accuracy: 0.6191
#
# Epoch 01237: val_loss did not improve from 0.00022
# Epoch 1238/2000
#  - 1s - loss: 1.0755e-04 - accuracy: 1.0000 - val_loss: 2.6474 - val_accuracy: 0.6172
#
# Epoch 01238: val_loss did not improve from 0.00022
# Epoch 1239/2000
#  - 1s - loss: 1.0552e-04 - accuracy: 1.0000 - val_loss: 0.1847 - val_accuracy: 0.6183
#
# Epoch 01239: val_loss did not improve from 0.00022
# Epoch 1240/2000
#  - 1s - loss: 1.0712e-04 - accuracy: 1.0000 - val_loss: 5.1718 - val_accuracy: 0.6166
#
# Epoch 01240: val_loss did not improve from 0.00022
# Epoch 1241/2000
#  - 1s - loss: 1.0420e-04 - accuracy: 1.0000 - val_loss: 2.1659 - val_accuracy: 0.6191
#
# Epoch 01241: val_loss did not improve from 0.00022
# Epoch 1242/2000
#  - 1s - loss: 1.0206e-04 - accuracy: 1.0000 - val_loss: 1.3936 - val_accuracy: 0.6180
#
# Epoch 01242: val_loss did not improve from 0.00022
# Epoch 1243/2000
#  - 1s - loss: 1.0498e-04 - accuracy: 1.0000 - val_loss: 0.4047 - val_accuracy: 0.6169
#
# Epoch 01243: val_loss did not improve from 0.00022
# Epoch 1244/2000
#  - 1s - loss: 1.0582e-04 - accuracy: 1.0000 - val_loss: 1.9818 - val_accuracy: 0.6160
#
# Epoch 01244: val_loss did not improve from 0.00022
# Epoch 1245/2000
#  - 1s - loss: 1.0035e-04 - accuracy: 1.0000 - val_loss: 3.1479 - val_accuracy: 0.6166
#
# Epoch 01245: val_loss did not improve from 0.00022
# Epoch 1246/2000
#  - 1s - loss: 9.8082e-05 - accuracy: 1.0000 - val_loss: 0.8079 - val_accuracy: 0.6166
#
# Epoch 01246: val_loss did not improve from 0.00022
# Epoch 1247/2000
#  - 1s - loss: 9.7499e-05 - accuracy: 1.0000 - val_loss: 0.7532 - val_accuracy: 0.6163
#
# Epoch 01247: val_loss did not improve from 0.00022
# Epoch 1248/2000
#  - 1s - loss: 1.0472e-04 - accuracy: 1.0000 - val_loss: 6.3028e-04 - val_accuracy: 0.6160
#
# Epoch 01248: val_loss did not improve from 0.00022
# Epoch 1249/2000
#  - 1s - loss: 1.0221e-04 - accuracy: 1.0000 - val_loss: 4.5482 - val_accuracy: 0.6147
#
# Epoch 01249: val_loss did not improve from 0.00022
# Epoch 1250/2000
#  - 1s - loss: 1.0108e-04 - accuracy: 1.0000 - val_loss: 5.1983 - val_accuracy: 0.6169
#
# Epoch 01250: val_loss did not improve from 0.00022
# Epoch 1251/2000
#  - 1s - loss: 9.9556e-05 - accuracy: 1.0000 - val_loss: 3.1068 - val_accuracy: 0.6174
#
# Epoch 01251: val_loss did not improve from 0.00022
# Epoch 1252/2000
#  - 1s - loss: 9.7472e-05 - accuracy: 1.0000 - val_loss: 1.9941 - val_accuracy: 0.6172
#
# Epoch 01252: val_loss did not improve from 0.00022
# Epoch 1253/2000
#  - 1s - loss: 9.4642e-05 - accuracy: 1.0000 - val_loss: 3.7293 - val_accuracy: 0.6163
#
# Epoch 01253: val_loss did not improve from 0.00022
# Epoch 1254/2000
#  - 1s - loss: 9.4408e-05 - accuracy: 1.0000 - val_loss: 0.5058 - val_accuracy: 0.6158
#
# Epoch 01254: val_loss did not improve from 0.00022
# Epoch 1255/2000
#  - 1s - loss: 1.4425e-04 - accuracy: 1.0000 - val_loss: 3.7104 - val_accuracy: 0.6194
#
# Epoch 01255: val_loss did not improve from 0.00022
# Epoch 1256/2000
#  - 1s - loss: 1.5499e-04 - accuracy: 1.0000 - val_loss: 1.1368 - val_accuracy: 0.6113
#
# Epoch 01256: val_loss did not improve from 0.00022
# Epoch 1257/2000
#  - 1s - loss: 1.1454e-04 - accuracy: 1.0000 - val_loss: 0.1647 - val_accuracy: 0.6183
#
# Epoch 01257: val_loss did not improve from 0.00022
# Epoch 1258/2000
#  - 1s - loss: 1.0405e-04 - accuracy: 1.0000 - val_loss: 1.7666 - val_accuracy: 0.6174
#
# Epoch 01258: val_loss did not improve from 0.00022
# Epoch 1259/2000
#  - 1s - loss: 9.9683e-05 - accuracy: 1.0000 - val_loss: 6.0095 - val_accuracy: 0.6191
#
# Epoch 01259: val_loss did not improve from 0.00022
# Epoch 1260/2000
#  - 1s - loss: 9.7478e-05 - accuracy: 1.0000 - val_loss: 2.1646 - val_accuracy: 0.6166
#
# Epoch 01260: val_loss did not improve from 0.00022
# Epoch 1261/2000
#  - 1s - loss: 9.6961e-05 - accuracy: 1.0000 - val_loss: 1.8456 - val_accuracy: 0.6166
#
# Epoch 01261: val_loss did not improve from 0.00022
# Epoch 1262/2000
#  - 1s - loss: 9.6088e-05 - accuracy: 1.0000 - val_loss: 2.7287 - val_accuracy: 0.6191
#
# Epoch 01262: val_loss did not improve from 0.00022
# Epoch 1263/2000
#  - 1s - loss: 9.5125e-05 - accuracy: 1.0000 - val_loss: 3.1551 - val_accuracy: 0.6183
#
# Epoch 01263: val_loss did not improve from 0.00022
# Epoch 1264/2000
#  - 1s - loss: 9.2611e-05 - accuracy: 1.0000 - val_loss: 7.1985 - val_accuracy: 0.6183
#
# Epoch 01264: val_loss did not improve from 0.00022
# Epoch 1265/2000
#  - 1s - loss: 9.4991e-05 - accuracy: 1.0000 - val_loss: 3.2007 - val_accuracy: 0.6177
#
# Epoch 01265: val_loss did not improve from 0.00022
# Epoch 1266/2000
#  - 1s - loss: 9.6674e-05 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 0.6180
#
# Epoch 01266: val_loss did not improve from 0.00022
# Epoch 1267/2000
#  - 1s - loss: 9.8276e-05 - accuracy: 1.0000 - val_loss: 0.5291 - val_accuracy: 0.6199
#
# Epoch 01267: val_loss did not improve from 0.00022
# Epoch 1268/2000
#  - 1s - loss: 9.7622e-05 - accuracy: 1.0000 - val_loss: 7.2650 - val_accuracy: 0.6163
#
# Epoch 01268: val_loss did not improve from 0.00022
# Epoch 1269/2000
#  - 1s - loss: 9.2649e-05 - accuracy: 1.0000 - val_loss: 0.1398 - val_accuracy: 0.6211
#
# Epoch 01269: val_loss did not improve from 0.00022
# Epoch 1270/2000
#  - 1s - loss: 9.3448e-05 - accuracy: 1.0000 - val_loss: 0.9905 - val_accuracy: 0.6163
#
# Epoch 01270: val_loss did not improve from 0.00022
# Epoch 1271/2000
#  - 1s - loss: 9.4706e-05 - accuracy: 1.0000 - val_loss: 2.1077 - val_accuracy: 0.6166
#
# Epoch 01271: val_loss did not improve from 0.00022
# Epoch 1272/2000
#  - 1s - loss: 9.7239e-05 - accuracy: 1.0000 - val_loss: 0.0347 - val_accuracy: 0.6177
#
# Epoch 01272: val_loss did not improve from 0.00022
# Epoch 1273/2000
#  - 1s - loss: 9.3277e-05 - accuracy: 1.0000 - val_loss: 3.0068 - val_accuracy: 0.6180
#
# Epoch 01273: val_loss did not improve from 0.00022
# Epoch 1274/2000
#  - 1s - loss: 9.2673e-05 - accuracy: 1.0000 - val_loss: 5.2213 - val_accuracy: 0.6174
#
# Epoch 01274: val_loss did not improve from 0.00022
# Epoch 1275/2000
#  - 1s - loss: 1.0058e-04 - accuracy: 1.0000 - val_loss: 1.8426 - val_accuracy: 0.6180
#
# Epoch 01275: val_loss did not improve from 0.00022
# Epoch 1276/2000
#  - 1s - loss: 9.8218e-05 - accuracy: 1.0000 - val_loss: 3.5132 - val_accuracy: 0.6227
#
# Epoch 01276: val_loss did not improve from 0.00022
# Epoch 1277/2000
#  - 1s - loss: 9.3248e-05 - accuracy: 1.0000 - val_loss: 2.0223 - val_accuracy: 0.6183
#
# Epoch 01277: val_loss did not improve from 0.00022
# Epoch 1278/2000
#  - 1s - loss: 9.4391e-05 - accuracy: 1.0000 - val_loss: 3.5660 - val_accuracy: 0.6172
#
# Epoch 01278: val_loss did not improve from 0.00022
# Epoch 1279/2000
#  - 1s - loss: 8.8903e-05 - accuracy: 1.0000 - val_loss: 0.6640 - val_accuracy: 0.6172
#
# Epoch 01279: val_loss did not improve from 0.00022
# Epoch 1280/2000
#  - 1s - loss: 8.9549e-05 - accuracy: 1.0000 - val_loss: 1.3109 - val_accuracy: 0.6180
#
# Epoch 01280: val_loss did not improve from 0.00022
# Epoch 1281/2000
#  - 1s - loss: 8.9473e-05 - accuracy: 1.0000 - val_loss: 4.8322 - val_accuracy: 0.6163
#
# Epoch 01281: val_loss did not improve from 0.00022
# Epoch 1282/2000
#  - 1s - loss: 8.5880e-05 - accuracy: 1.0000 - val_loss: 2.8799 - val_accuracy: 0.6158
#
# Epoch 01282: val_loss did not improve from 0.00022
# Epoch 1283/2000
#  - 1s - loss: 8.7748e-05 - accuracy: 1.0000 - val_loss: 2.2703 - val_accuracy: 0.6152
#
# Epoch 01283: val_loss did not improve from 0.00022
# Epoch 1284/2000
#  - 1s - loss: 8.9766e-05 - accuracy: 1.0000 - val_loss: 3.7352 - val_accuracy: 0.6172
#
# Epoch 01284: val_loss did not improve from 0.00022
# Epoch 1285/2000
#  - 1s - loss: 8.8721e-05 - accuracy: 1.0000 - val_loss: 1.7619 - val_accuracy: 0.6160
#
# Epoch 01285: val_loss did not improve from 0.00022
# Epoch 1286/2000
#  - 1s - loss: 8.6434e-05 - accuracy: 1.0000 - val_loss: 1.6530 - val_accuracy: 0.6183
#
# Epoch 01286: val_loss did not improve from 0.00022
# Epoch 1287/2000
#  - 1s - loss: 9.2616e-05 - accuracy: 1.0000 - val_loss: 2.3037 - val_accuracy: 0.6174
#
# Epoch 01287: val_loss did not improve from 0.00022
# Epoch 1288/2000
#  - 1s - loss: 1.3718e-04 - accuracy: 1.0000 - val_loss: 4.9071 - val_accuracy: 0.6105
#
# Epoch 01288: val_loss did not improve from 0.00022
# Epoch 1289/2000
#  - 1s - loss: 4.3969e-04 - accuracy: 0.9999 - val_loss: 1.3593 - val_accuracy: 0.5971
#
# Epoch 01289: val_loss did not improve from 0.00022
# Epoch 1290/2000
#  - 1s - loss: 1.7507e-04 - accuracy: 1.0000 - val_loss: 1.5871 - val_accuracy: 0.6133
#
# Epoch 01290: val_loss did not improve from 0.00022
# Epoch 1291/2000
#  - 1s - loss: 1.2837e-04 - accuracy: 1.0000 - val_loss: 4.1455 - val_accuracy: 0.6096
#
# Epoch 01291: val_loss did not improve from 0.00022
# Epoch 1292/2000
#  - 1s - loss: 1.0495e-04 - accuracy: 1.0000 - val_loss: 0.4997 - val_accuracy: 0.6186
#
# Epoch 01292: val_loss did not improve from 0.00022
# Epoch 1293/2000
#  - 1s - loss: 9.4000e-05 - accuracy: 1.0000 - val_loss: 4.2268 - val_accuracy: 0.6188
#
# Epoch 01293: val_loss did not improve from 0.00022
# Epoch 1294/2000
#  - 1s - loss: 9.3080e-05 - accuracy: 1.0000 - val_loss: 0.7928 - val_accuracy: 0.6163
#
# Epoch 01294: val_loss did not improve from 0.00022
# Epoch 1295/2000
#  - 1s - loss: 8.9795e-05 - accuracy: 1.0000 - val_loss: 0.0590 - val_accuracy: 0.6180
#
# Epoch 01295: val_loss did not improve from 0.00022
# Epoch 1296/2000
#  - 1s - loss: 9.3462e-05 - accuracy: 1.0000 - val_loss: 4.6111 - val_accuracy: 0.6172
#
# Epoch 01296: val_loss did not improve from 0.00022
# Epoch 1297/2000
#  - 1s - loss: 8.9012e-05 - accuracy: 1.0000 - val_loss: 1.3171 - val_accuracy: 0.6194
#
# Epoch 01297: val_loss did not improve from 0.00022
# test_result.shape : (3589, 2)
# y_test[:5] : [0 0 1 0 0]
# y_score[:5] : [[9.9052107e-01]
#  [4.6854641e-02]
#  [1.2517594e-01]
#  [2.0187454e-06]
#  [1.3744544e-04]]
# y_test.shape : (3589, 1)
# y_score.shape : (3589, 1)
# len(y_test) : 3589
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:707: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [0.00028543876, 0.00027760334, 0.00026890502, 0.0002845691, 0.00028731526, 0.00029753143, 0.00029561186, 0.0002916344, 0.00029316917, 0.00029146718, 0.0002948143, 0.00028735003, 0.0002932562, 0.00029675223, 0.00029640787, 0.00029878193, 0.00030589913, 0.00031036828, 0.00030800267, 0.0002936818, 0.00029655476, 0.00030424562, 0.00030858343, 0.0003306027, 0.0003041179, 0.00030148332, 0.0003014882, 0.0003034489, 0.00030810043, 0.0003058367, 0.00031233707, 0.0003127635, 0.00031695486, 0.00032053568, 0.00032632137, 0.0003292898, 0.00033659692, 0.00033768264, 0.0003305427, 0.0003313995, 0.00033085243, 0.0003281702, 0.0003278936, 0.00033108031, 0.00033333633, 0.00033391637, 0.00033910436, 0.00033905302, 0.00034816706, 0.00032978883, 0.00033043136, 0.00033054673, 0.00033327966, 0.00033117193, 0.00033200675, 0.00033271735, 0.00033176664, 0.0003347571, 0.000332885, 0.0003264417, 0.00032090928, 0.00031182243, 0.0003133717, 0.00031452175, 0.00031686094, 0.00032197783, 0.00031920202, 0.00032632047, 0.00032427014, 0.0003171221, 0.0003235399, 0.00032477602, 0.0003323699, 0.00032534104, 0.00033120625, 0.00033937613, 0.00034012427, 0.00035041932, 0.00035843754, 0.00037822968, 0.00037513877, 0.0003775321, 0.0003765595, 0.00038466268, 0.0003893221, 0.0003905628, 0.00036970104, 0.00036438266, 0.00034868214, 0.0003515438, 0.0003449253, 0.00036444617, 0.00036012608, 0.0003668661, 0.00035898172, 0.00036411406, 0.00037061019, 0.00037716236, 0.0003915375, 0.00039289883, 0.000394748, 0.00038589808, 0.00045401455, 0.00045655624, 0.00045522113, 0.00045144212, 0.0004573961, 0.00047919573, 0.00048635682, 0.00048688447, 0.00048224643, 0.00047730815, 0.00047863188, 0.00047356676, 0.00048634468, 0.00050054485, 0.0005056792, 0.0005065859, 0.00054718286, 0.0005463351, 0.00054530846, 0.0005459178, 0.00052416796, 0.00053343043, 0.00052788714, 0.0005323132, 0.00053259253, 0.000534339, 0.00054164394, 0.0005373372, 0.00054779556, 0.0005576872, 0.0005508084, 0.00056028436, 0.000550679, 0.0005197593, 0.00050389837, 0.0005067202, 0.0005096041, 0.00051840564, 0.00045156502, 0.00045582157, 0.00047103147, 0.00047810245, 0.00047725328, 0.00047554003, 0.00047437582, 0.00050164043, 0.00050664245, 0.0005050886, 0.00050803175, 0.00052360364, 0.00048996706, 0.00049514865, 0.0004939058, 0.00048476353, 0.00049165095, 0.00047753283, 0.0004747751, 0.0004677447, 0.00047355937, 0.00048374262, 0.000457847, 0.00048111193, 0.00047440332, 0.0004891008, 0.00047577472, 0.00046457894, 0.00049089326, 0.00049697707, 0.00051036896, 0.0004943554, 0.00051016844, 0.0005038105, 0.0005136865, 0.0005214799, 0.00052704685, 0.00052378414, 0.00052189623, 0.0005175148, 0.0005214277, 0.00051754905, 0.00052642217, 0.00052016467, 0.0005358712, 0.0005363391, 0.0005302827, 0.0005376055, 0.000534891, 0.00053532014, 0.0005106788, 0.0005537597, 0.0005489668, 0.00056570803, 0.0005281552, 0.0005390565, 0.00055217405, 0.0005841141, 0.0005825351, 0.00058947265, 0.000593458, 0.0005816818, 0.00058527035, 0.0006123056, 0.00063638296, 0.00063762185, 0.00063548615, 0.00067131687, 0.00068716885, 0.0006933629, 0.00068095705, 0.000686202, 0.00067835464, 0.0007401383, 0.0007479601, 0.0007667011, 0.0007491014, 0.00074892456, 0.0007670867, 0.00077630824, 0.00077019987, 0.0007802811, 0.00080266414, 0.0008015093, 0.0008212715, 0.0008248231, 0.0008130934, 0.0008370934, 0.0008426337, 0.0008598496, 0.00087913004, 0.0008782176, 0.0008993996, 0.00088563544, 0.00090587226, 0.0008987124, 0.0009003466, 0.0009261812, 0.00091896346, 0.0009144129, 0.00093570654, 0.0009293724, 0.0009555224, 0.0009711578, 0.0010610393, 0.0010234676, 0.0010119587, 0.001037964, 0.0010537048, 0.0010543249, 0.0010368892, 0.0010464581, 0.0010270735, 0.0010524433, 0.0010457832, 0.0010384881, 0.0010470023, 0.0010201695, 0.0009865601, 0.0009400305, 0.00091642374, 0.0008996612, 0.0008967135, 0.0008656784, 0.00086817873, 0.00087622297, 0.0008490034, 0.0008589276, 0.00085176417, 0.0008495364, 0.00087454205, 0.00086437975, 0.00088154373, 0.00088023755, 0. ...

# %% [markdown]
# ### save npy

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from funcs_indicator import *

def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


#       set data features : ohlc, v, ep
time_index = ohlcv.index[np.sum(np.isnan(pr)):]

sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

#       scale with price    #
ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
sar = lucid_sar(sliced_ohlcv)
ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
senkou1, senkou2 = ichimoku(sliced_ohlcv)

#     min max scale   #
vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

pr_list = pr[np.sum(np.isnan(pr)):]
print("len(ohlc) :", len(ohlc))
print("len(pr) :", len(pr))

# break


#       set params    #
period = 45
key_i = i

plotting = True

data_x, data_pr, data_updown = [], [], []
data_index = []

for i in range(period, len(ohlc)):

  #   pr_list != 1 인 데이터만 사용한다
  # if 1:
  if pr_list[i] != 1:

    min_max = MinMaxScaler()
    
    #   prediction 을 제외한 이전 데이터를 사용해야한다
    temp_ohlc = ohlc.iloc[i - period : i].values
    # temp_long_ep = long_ep[i - period : i]          
    temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
    temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

    temp_close = min_max_scale(temp_ohlc[:, [3]])    

    price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

    if np.isnan(np.sum(price_data)):
      continue

    # print("price_data[:10] :", price_data[:10])
    # print("temp_ohlc.shape :", temp_ohlc.shape)
    # print("temp_long_ep.shape :", temp_long_ep.shape)
    # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
    # print("price_data.shape :", price_data.shape)

    if plotting:
      plt.plot(price_data)
      plt.show()

    ind_temp_ohlc = min_max_scale(temp_ohlc)
    temp_price_data = min_max_scale(price_data)
    # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


    if plotting:

      plt.plot(ind_temp_ohlc)
      plt.show()
      plt.plot(temp_price_data)
      plt.show()

      plotting = False
    # break

    #   vol -> min_max
    temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
    
    #                   feature selection                   #        
    temp_data = np.hstack((ind_temp_ohlc, temp_vol))

    # temp_data = trial_list[trial_number]
    # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
    # temp_data = temp_ohlc[:, [3]]
    # temp_data = ind_temp_ohlc[:, [3]]
    # temp_data = temp_close

    if np.isnan(np.sum(temp_data)):
      continue

    data_x.append(temp_data)
    data_pr.append(pr_list[i])
    data_index.append(time_index[i])
    data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


print('np.array(data_x).shape :', np.array(data_x).shape)
# print(data_x[0])


#       Reshape data for image deep - learning     #
_, row, col = np.array(data_x).shape

input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
# input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

#     1c to 3c    #
input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
# input_x = np.array(resize_npy(input_x))


input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
input_index = np.array(data_index).reshape(-1, 1)
print('input_x.shape :', input_x.shape)
print('input_x.dtype :', input_x.dtype)
print('input_pr.shape :', input_pr.shape)
print('input_ud.shape :', input_ud.shape)
print('input_index.shape :', input_index.shape)


# x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

#     do stacking   #
# if prev_x is None:
prev_x = input_x
prev_pr = input_pr
prev_ud = input_ud
prev_index = input_index

total_x = input_x
total_pr = input_pr
total_ud = input_ud
total_index = input_index

# else:
#   total_x = np.vstack((prev_x, input_x))
#   total_pr = np.vstack((prev_pr, input_pr))
#   total_ud = np.vstack((prev_ud, input_ud)) 
#   total_index = np.vstack((prev_index, input_index)) 

#   prev_x = total_x
#   prev_pr = total_pr
#   prev_ud = total_ud
#   prev_index = total_index

print('total_x.shape :', total_x.shape)
print('total_pr.shape :', total_pr.shape)
print('total_ud.shape :', total_ud.shape)
print('prev_index.shape :', prev_index.shape)


# _, row, col, _ = input_x.shape
# _, row, col = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


#         get unique timestamp      #
print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

#                 don't shuffle timeseries data                 #
stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)

index_train = np.array(index_train)
index_val = np.array(index_val)
index_test = np.array(index_test)
  
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

symbol_name = key.split(' ')[1].split('.')[0]

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)

np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %% [markdown]
# ### load npy

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


symbol_name = "SXPUSDT"
period = 45

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)


x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')


pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

# total_x = np.vstack((x_train, x_val, x_test))
# total_pr = np.vstack((pr_train, pr_val, pr_test))

# print("total_x.shape :", total_x.shape)
# Out:
# x series loaded !
# y series loaded !

# %% [markdown]
# ### rapid pr selection

# %%
plt.plot(pr)
plt.show()

pr_thresh = 1.005
rapid_pct = len(pr[pr > pr_thresh]) / len(pr)

print(rapid_pct)
# Out:
# 0.36131427304964536

# %% [markdown]
# ### class_weight & categorization

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


def class_ratio(in_list):

  return in_list / in_list[1]
  
y_train = np.where(pr_train > pr_thresh, 1, 0)
y_test = np.where(pr_test > pr_thresh, 1, 0)
y_val = np.where(pr_val > pr_thresh, 1, 0)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

# try:
print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

# except Exception as e:
  # print(e)

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)
# Out:
# x_train.shape : (10755, 45, 5, 3)
# x_test.shape : (3586, 45, 5, 3)
# x_val.shape : (3585, 45, 5, 3)
# y_train.shape : (10755, 1)
# y_test.shape : (3586, 1)
# y_val.shape : (3585, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([6864, 3891])) [1.76407093 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2303, 1282])) [1.79641186 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2291, 1295])) [1.76911197 1.        ]
# class_weights : {0: 0.7834353146853147, 1: 1.382035466461064}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10755, 2)
# y_val_ohe.shape : (3585, 2)
# y_test_ohe.shape : (3586, 2)

# %% [markdown]
# ### augment

# %%
from keras.preprocessing.image import ImageDataGenerator 

datagen = ImageDataGenerator( 
    # rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)


batch_size = 512


for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break

# %% [markdown]
# ### train

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'

# batch_size = 512

model = FER_Model(input_shape=x_train.shape[1:])
opt = Adam(lr=0.00001, decay=0.000005)
# opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model_name = 'classifier_%s_cnn_updown_rascend_1005_%s_tvnon_shuffle.h5' % (period, symbol_name)



checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]
# callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)

# %% [markdown]
# ### load model

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'


model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)


model = keras.models.load_model(ckpt_path + model_name)

# %% [markdown]
# ### test

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)

  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.title(symbol_name)
plt.show()
# Out:
# test_result.shape : (3586, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.04767541]
#  [0.00195843]
#  [0.1600004 ]
#  [0.14308068]
#  [0.00154134]]
# y_test.shape : (3586, 1)
# y_score.shape : (3586, 1)
# len(y_test) : 3586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [5.2342257e-05, 5.224965e-05, 5.119804e-05, 4.92728e-05, 4.9822964e-05, 5.1722614e-05, 5.241118e-05, 5.2653213e-05, 5.4707263e-05, 5.469477e-05, 5.5414595e-05, 5.4917986e-05, 5.5296758e-05, 5.482614e-05, 5.5313794e-05, 5.619928e-05, 5.7341047e-05, 5.8005982e-05, 5.7726982e-05, 5.8714617e-05, 5.924952e-05, 5.9157777e-05, 6.0730683e-05, 6.09751e-05, 6.1022805e-05, 6.194849e-05, 6.286581e-05, 6.367981e-05, 6.4932676e-05, 6.5769455e-05, 6.7948844e-05, 6.841887e-05, 6.806048e-05, 6.849957e-05, 6.9895126e-05, 7.091783e-05, 7.1859926e-05, 7.350335e-05, 7.346305e-05, 7.395025e-05, 7.968566e-05, 7.8947196e-05, 7.8341516e-05, 7.918357e-05, 7.912106e-05, 8.1205275e-05, 8.341604e-05, 8.386569e-05, 8.3938816e-05, 8.564359e-05, 7.970025e-05, 8.0672995e-05, 8.083643e-05, 8.727269e-05, 8.9510206e-05, 8.959228e-05, 8.962243e-05, 8.8885776e-05, 9.023229e-05, 9.169206e-05, 9.0867565e-05, 9.033618e-05, 9.429348e-05, 9.3799725e-05, 9.566918e-05, 9.6586686e-05, 9.398621e-05, 9.4105475e-05, 9.411831e-05, 9.466633e-05, 9.5054995e-05, 9.854746e-05, 9.9124496e-05, 0.00010614127, 0.000108136, 0.00010740872, 0.00010814099, 0.00010723293, 0.00010745465, 0.00010824714, 0.00010731329, 0.000108584194, 0.00010868803, 0.00010257258, 0.000101516416, 0.00010031571, 0.000103715196, 0.00010502134, 0.00010611775, 0.00010916348, 0.00010594193, 0.000104194485, 0.00010433929, 0.000104219216, 0.00010764128, 0.00010433711, 0.00010385209, 0.000106006635, 0.00010645543, 0.00010741285, 0.00010793885, 0.00010773461, 0.000107400294, 0.000107067055, 0.000110430265, 0.00010961514, 0.000110994966, 0.000109511326, 0.00011019072, 0.00011165826, 0.00011095228, 0.00011055433, 0.00011134691, 0.000109883986, 0.0001112986, 0.0001123257, 0.000114077506, 0.00011583454, 0.00011730796, 0.00011702095, 0.00012883096, 0.00012502969, 0.0001211144, 0.00012085415, 0.00012023333, 0.000121178586, 0.0001113643, 0.00011255329, 0.00011366057, 0.00011109531, 0.00011435672, 0.00011691414, 0.00011724194, 0.00011877652, 0.00011876732, 0.00012343662, 0.00012398258, 0.00012742475, 0.00013299534, 0.0001345203, 0.00013497796, 0.00013495858, 0.00013710273, 0.00013803714, 0.00013533776, 0.00014049193, 0.00013862025, 0.00013925365, 0.00013978127, 0.00014475136, 0.00014560782, 0.00014417202, 0.00015133772, 0.0001492487, 0.00015156744, 0.00015025465, 0.00015172384, 0.0001483679, 0.00015025485, 0.00017470514, 0.00017807752, 0.00018197432, 0.00018371776, 0.00018367464, 0.0001920926, 0.00019288564, 0.00020759454, 0.00020698183, 0.00023446795, 0.00023864223, 0.00024568185, 0.0002499611, 0.00025658592, 0.00025730263, 0.00025887572, 0.00026280092, 0.0002670472, 0.00027564648, 0.0002803122, 0.0002723821, 0.00027754836, 0.00027732784, 0.00028359605, 0.0002916876, 0.0002884358, 0.0002919522, 0.00029502896, 0.00028943687, 0.00028854128, 0.00029137387, 0.0002962364, 0.00029461124, 0.00029948735, 0.00030449385, 0.0002996868, 0.00029990985, 0.00029333428, 0.0002965417, 0.00029836778, 0.00029298887, 0.00030178405, 0.00029634495, 0.00029906907, 0.00029697176, 0.0002963374, 0.000295097, 0.000312998, 0.00031196643, 0.00031936396, 0.00032101592, 0.00032832168, 0.0003258465, 0.00033274552, 0.0003290262, 0.00033229083, 0.00034132804, 0.00033895372, 0.00035075872, 0.00034744598, 0.00034445102, 0.00032778905, 0.0003323982, 0.00034709118, 0.0003477889, 0.00035424854, 0.00040091967, 0.00042115894, 0.00041995398, 0.00041660885, 0.00042408038, 0.00044065266, 0.00045346154, 0.00044463656, 0.00047572926, 0.0005098468, 0.00050058664, 0.00049340463, 0.0004999284, 0.0005000292, 0.0004849475, 0.00048356556, 0.0004768842, 0.00047515446, 0.00046261746, 0.00046790738, 0.000461418, 0.00046818578, 0.00046653874, 0.00047877917, 0.00048961974, 0.0005021864, 0.00051662093, 0.00052976055, 0.00053512596, 0.000552535, 0.0005820823, 0.00058700517, 0.00059161586, 0.0005911128, 0.00059325877, 0.00059789245, 0.0006161917, 0.00060233, 0.0006037665, 0.0005968395, 0.0006049573, 0.0006040889, 0.0006045968, 0.000620602, 0.00062113034, 0.0006333279, ...

# %%
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)], linestyle='--', color='r')
plt.title(symbol_name + '\n' + str(new_thresh[np.argmax(acc_pr_bythr)]))
plt.show()

# %%
thresh = 0.5866
y_pred = np.where(y_score[:600, -1] > thresh, 1, 0)
# print('y_pred.shape :', y_pred.shape)
# print('y_pred :', y_pred)

#     compare precision     #

# print('precision :', precision_score(y_test, y_pred))
# print('recall :', recall_score(y_test, y_pred))
# print()

# print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
# print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

# # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
# # plt.show()  
# print()

#     check win-ratio improvement     #
cmat = confusion_matrix(y_test[:len(y_pred)], y_pred)
# print(cmat)
# print(np.sum(cmat, axis=1))

test_size = len(y_test[:len(y_pred)])
test_pr_list = pr_test[:len(y_pred)]
# print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
# print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

# print('pr_test.shape :', pr_test.shape)

# print(y_pred)
# print(test_pr_list)
pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

plt.plot(np.cumprod(pred_pr_list))
plt.show()

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72a922dd9685> in <module>()
#       5 # print(index_train)
#       6 # print(index_val)
# ----> 7 total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index))
#       8 timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train))
#       9 timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val))
#
# NameError: name 'input_index' is not defined

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
