# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-02-11/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-02-11 BTCUSDT.xlsx', '2021-02-11 ETHUSDT.xlsx', '2021-02-11 BCHUSDT.xlsx', '2021-02-11 XRPUSDT.xlsx', '2021-02-11 EOSUSDT.xlsx', '2021-02-11 LTCUSDT.xlsx', '2021-02-11 ETCUSDT.xlsx', '2021-02-11 LINKUSDT.xlsx', '2021-02-11 XLMUSDT.xlsx', '2021-02-11 ADAUSDT.xlsx', '2021-02-11 XMRUSDT.xlsx', '2021-02-11 SXPUSDT.xlsx', '2021-02-11 KAVAUSDT.xlsx', '2021-02-11 BANDUSDT.xlsx', '2021-02-11 DASHUSDT.xlsx', '2021-02-11 ZECUSDT.xlsx', '2021-02-11 XTZUSDT.xlsx', '2021-02-11 BNBUSDT.xlsx', '2021-02-11 ATOMUSDT.xlsx', '2021-02-11 ONTUSDT.xlsx', '2021-02-11 IOTAUSDT.xlsx', '2021-02-11 BATUSDT.xlsx', '2021-02-11 NEOUSDT.xlsx', '2021-02-11 QTUMUSDT.xlsx', '2021-02-11 WAVESUSDT.xlsx', '2021-02-11 MKRUSDT.xlsx', '2021-02-11 SNXUSDT.xlsx', '2021-02-11 DOTUSDT.xlsx', '2021-02-11 THETAUSDT.xlsx', '2021-02-11 ALGOUSDT.xlsx', '2021-02-11 KNCUSDT.xlsx', '2021-02-11 ZRXUSDT.xlsx', '2021-02-11 COMPUSDT.xlsx', '2021-02-11 OMGUSDT.xlsx']

# %% [markdown]
# ### **Data Stacking**

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle

with open('./arima_result/arima_opt_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
  load_dict = pickle.load(f)

candis = list(load_dict.keys())
long_index = 0
leverage = 5
prev_x = None
for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue
  if '2021-03-02 DOTUSDT.xlsx' in candis[i]:
    # print('')
    continue

  if '04-08' not in candis[i]:  # <-- 04-08 includes all timestamp range
    continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      ohlcv = load_dict[key]['ohlcv']
      # ohlcv = ohlcv.iloc[-int(len(ohlcv) * 0.34):]
      # predictions = load_dict[key]['predictions']
      # err_ranges = load_dict[key]['err_ranges']

      predictions = ohlcv['close'].shift(1).values
      err_ranges = np.zeros_like(predictions)

      # leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]

      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = np.array(predictions)
      long_ep = long_ep.reshape(-1, 1)

      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 5
      data_x, data_pr, data_updown = [], [], []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          min_max = MinMaxScaler()
          temp_data[:, :5] = min_max.fit_transform(temp_data[:, :5])


          #   vol -> min_max
          min_max = MinMaxScaler()
          temp_data[:, [5]] = min_max.fit_transform(temp_data[:, [5]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]

      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)

      #     do stacking   #
      if prev_x is None:
        prev_x = input_x
        prev_pr = input_pr
        prev_ud = input_ud
      else:
        total_x = np.vstack((prev_x, input_x))
        total_pr = np.vstack((prev_pr, input_pr))
        total_ud = np.vstack((prev_ud, input_ud))

        prev_x = total_x
        prev_pr = total_pr
        prev_ud = total_ud

        print('total_x.shape :', total_x.shape)
        print('total_pr.shape :', total_pr.shape)
        print('total_ud.shape :', total_ud.shape)

  try:
    if len(total_x) > 300000:
      break
  except:
    pass
# Out:
# -------------- 2021-04-08 BTCUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16711, 5, 6)
# input_x.shape : (16711, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16711, 1)
# input_ud.shape : (16711, 1)
# -------------- 2021-04-08 ETHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16686, 5, 6)
# input_x.shape : (16686, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16686, 1)
# input_ud.shape : (16686, 1)
# total_x.shape : (33397, 5, 6, 3)
# total_pr.shape : (33397, 1)
# total_ud.shape : (33397, 1)
# -------------- 2021-04-08 BCHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16612, 5, 6)
# input_x.shape : (16612, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16612, 1)
# input_ud.shape : (16612, 1)
# total_x.shape : (50009, 5, 6, 3)
# total_pr.shape : (50009, 1)
# total_ud.shape : (50009, 1)
# -------------- 2021-04-08 XRPUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16206, 5, 6)
# input_x.shape : (16206, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16206, 1)
# input_ud.shape : (16206, 1)
# total_x.shape : (66215, 5, 6, 3)
# total_pr.shape : (66215, 1)
# total_ud.shape : (66215, 1)
# -------------- 2021-04-08 EOSUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16184, 5, 6)
# input_x.shape : (16184, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16184, 1)
# input_ud.shape : (16184, 1)
# total_x.shape : (82399, 5, 6, 3)
# total_pr.shape : (82399, 1)
# total_ud.shape : (82399, 1)
# -------------- 2021-04-08 LTCUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16436, 5, 6)
# input_x.shape : (16436, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16436, 1)
# input_ud.shape : (16436, 1)
# total_x.shape : (98835, 5, 6, 3)
# total_pr.shape : (98835, 1)
# total_ud.shape : (98835, 1)
# -------------- 2021-04-08 ETCUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16309, 5, 6)
# input_x.shape : (16309, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16309, 1)
# input_ud.shape : (16309, 1)
# total_x.shape : (115144, 5, 6, 3)
# total_pr.shape : (115144, 1)
# total_ud.shape : (115144, 1)
# -------------- 2021-04-08 LINKUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16581, 5, 6)
# input_x.shape : (16581, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16581, 1)
# input_ud.shape : (16581, 1)
# total_x.shape : (131725, 5, 6, 3)
# total_pr.shape : (131725, 1)
# total_ud.shape : (131725, 1)
# -------------- 2021-04-08 XLMUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16460, 5, 6)
# input_x.shape : (16460, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16460, 1)
# input_ud.shape : (16460, 1)
# total_x.shape : (148185, 5, 6, 3)
# total_pr.shape : (148185, 1)
# total_ud.shape : (148185, 1)
# -------------- 2021-04-08 ADAUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16552, 5, 6)
# input_x.shape : (16552, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16552, 1)
# input_ud.shape : (16552, 1)
# total_x.shape : (164737, 5, 6, 3)
# total_pr.shape : (164737, 1)
# total_ud.shape : (164737, 1)
# -------------- 2021-04-08 XMRUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16294, 5, 6)
# input_x.shape : (16294, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16294, 1)
# input_ud.shape : (16294, 1)
# total_x.shape : (181031, 5, 6, 3)
# total_pr.shape : (181031, 1)
# total_ud.shape : (181031, 1)
# -------------- 2021-04-08 SXPUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 12533
# long_ep.shape : (12533, 1)
# len(pr_list) : 12533
# np.array(data_x).shape : (12217, 5, 6)
# input_x.shape : (12217, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (12217, 1)
# input_ud.shape : (12217, 1)
# total_x.shape : (193248, 5, 6, 3)
# total_pr.shape : (193248, 1)
# total_ud.shape : (193248, 1)
# -------------- 2021-04-08 KAVAUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 12201
# long_ep.shape : (12201, 1)
# len(pr_list) : 12201
# np.array(data_x).shape : (11874, 5, 6)
# input_x.shape : (11874, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (11874, 1)
# input_ud.shape : (11874, 1)
# total_x.shape : (205122, 5, 6, 3)
# total_pr.shape : (205122, 1)
# total_ud.shape : (205122, 1)
# -------------- 2021-04-08 BANDUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 12153
# long_ep.shape : (12153, 1)
# len(pr_list) : 12153
# np.array(data_x).shape : (11848, 5, 6)
# input_x.shape : (11848, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (11848, 1)
# input_ud.shape : (11848, 1)
# total_x.shape : (216970, 5, 6, 3)
# total_pr.shape : (216970, 1)
# total_ud.shape : (216970, 1)
# -------------- 2021-04-08 DASHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16283, 5, 6)
# input_x.shape : (16283, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16283, 1)
# input_ud.shape : (16283, 1)
# total_x.shape : (233253, 5, 6, 3)
# total_pr.shape : (233253, 1)
# total_ud.shape : (233253, 1)
# -------------- 2021-04-08 ZECUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16323, 5, 6)
# input_x.shape : (16323, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16323, 1)
# input_ud.shape : (16323, 1)
# total_x.shape : (249576, 5, 6, 3)
# total_pr.shape : (249576, 1)
# total_ud.shape : (249576, 1)
# -------------- 2021-04-08 XTZUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16240, 5, 6)
# input_x.shape : (16240, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16240, 1)
# input_ud.shape : (16240, 1)
# total_x.shape : (265816, 5, 6, 3)
# total_pr.shape : (265816, 1)
# total_ud.shape : (265816, 1)
# -------------- 2021-04-08 BNBUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16604, 5, 6)
# input_x.shape : (16604, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16604, 1)
# input_ud.shape : (16604, 1)
# total_x.shape : (282420, 5, 6, 3)
# total_pr.shape : (282420, 1)
# total_ud.shape : (282420, 1)
# -------------- 2021-04-08 ATOMUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16281, 5, 6)
# input_x.shape : (16281, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16281, 1)
# input_ud.shape : (16281, 1)
# total_x.shape : (298701, 5, 6, 3)
# total_pr.shape : (298701, 1)
# total_ud.shape : (298701, 1)
# -------------- 2021-04-08 ONTUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16327, 5, 6)
# input_x.shape : (16327, 5, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (16327, 1)
# input_ud.shape : (16327, 1)
# total_x.shape : (315028, 5, 6, 3)
# total_pr.shape : (315028, 1)
# total_ud.shape : (315028, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:185: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape=(row, col, 3)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight
# import cv2



seed = 1
random_state = 20
np.random.seed(seed)
# tf.random.set_seed(seed)

#         resize total_x shape  (, 5, 6, 3)      #
# .repeat(2, axis=0).repeat(2, axis=1)
temp_x = list()
for d_i, data in enumerate(total_x):
  # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
  resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
  # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
  # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
  
  if d_i == 0:
    plt.imshow(data)
    plt.show()
    plt.imshow(resized_data)
    plt.show()
  # print('resized_data.shape :', resized_data.shape)
  # break
  temp_x.append(resized_data)

re_total_x = np.array(temp_x)
print('re_total_x.shape :', re_total_x.shape)
# break

#         train / test split      #
x_train, x_test_, pr_train, pr_test_, ud_train, ud_test_ = train_test_split(re_total_x, total_pr, total_ud, test_size=0.4, shuffle=True, random_state=random_state)
x_test, x_val, pr_test, pr_val, ud_test, ud_val = train_test_split(x_test_, pr_test_, ud_test_, test_size=0.5, shuffle=True, random_state=random_state)


#         pr label   #
y_train = np.where(pr_train > 1, 1, 0)
y_test = np.where(pr_test > 1, 1, 0)
y_val = np.where(pr_val > 1, 1, 0)

#         up label      #
# y_train = np.where(ud_train > 1, 1, 0)
# y_test = np.where(ud_test > 1, 1, 0)
# y_val = np.where(ud_val > 1, 1, 0)

print('pr_train[:5] :', pr_train[:5])
print('ud_train[:5] :', ud_train[:5])
print('y_train[:5] :', y_train[:5])
print('y_train.dtype :', y_train.dtype)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

def class_ratio(in_list):

  return in_list / in_list[1]

print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)

datagen = ImageDataGenerator( 
    rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)

batch_size = 256

for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break
# Out:
# re_total_x.shape : (315028, 10, 12, 3)
# pr_train[:5] : [[0.9787135 ]
#  [1.0115857 ]
#  [0.9595382 ]
#  [1.0135131 ]
#  [0.97834945]]
# ud_train[:5] : [[0.9962862 ]
#  [1.0029172 ]
#  [0.99250764]
#  [1.0036515 ]
#  [0.9962373 ]]
# y_train[:5] : [[0]
#  [1]
#  [0]
#  [1]
#  [0]]
# y_train.dtype : int64
# x_train.shape : (189016, 10, 12, 3)
# x_test.shape : (63006, 10, 12, 3)
# x_val.shape : (63006, 10, 12, 3)
# y_train.shape : (189016, 1)
# y_test.shape : (63006, 1)
# y_val.shape : (63006, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([106404,  82612])) [1.2879969 1.       ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([35616, 27390])) [1.30032859 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([35614, 27392])) [1.30016063 1.        ]
# class_weights : {0: 0.888199691740912, 1: 1.1439984505882923}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (189016, 2)
# y_val_ohe.shape : (63006, 2)
# y_test_ohe.shape : (63006, 2)

# %% [markdown]
# ### **Training**

# %%
(_, row, col, _) = x_train.shape

model = FER_Model(input_shape=(row, col, 3))
opt = Adam(lr=0.00001, decay=0.000005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
  
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_%s_close_updown_pr.h5' % period

checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=40)
# callbacks_list = [checkpoint, checkpoint2, checkpoint3]
callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/1000
#  - 36s - loss: 0.6900 - accuracy: 0.5379 - val_loss: 0.7182 - val_accuracy: 0.5667
#
# Epoch 00001: val_loss improved from inf to 0.71816, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_5_close_updown_pr.h5
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/1000
#  - 32s - loss: 0.6887 - accuracy: 0.5420 - val_loss: 0.6656 - val_accuracy: 0.5445
#
# Epoch 00002: val_loss improved from 0.71816 to 0.66563, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_5_close_updown_pr.h5
# Epoch 3/1000
#  - 32s - loss: 0.6885 - accuracy: 0.5437 - val_loss: 0.6647 - val_accuracy: 0.5395
#
# Epoch 00003: val_loss improved from 0.66563 to 0.66465, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_5_close_updown_pr.h5
# Epoch 4/1000
#  - 32s - loss: 0.6884 - accuracy: 0.5447 - val_loss: 0.6842 - val_accuracy: 0.5595
#
# Epoch 00004: val_loss did not improve from 0.66465
# Epoch 5/1000
#  - 32s - loss: 0.6879 - accuracy: 0.5463 - val_loss: 0.7008 - val_accuracy: 0.5434
#
# Epoch 00005: val_loss did not improve from 0.66465
# Epoch 6/1000
#  - 32s - loss: 0.6878 - accuracy: 0.5464 - val_loss: 0.6198 - val_accuracy: 0.5621
#
# Epoch 00006: val_loss improved from 0.66465 to 0.61983, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_5_close_updown_pr.h5
# Epoch 7/1000
#  - 32s - loss: 0.6877 - accuracy: 0.5472 - val_loss: 0.6898 - val_accuracy: 0.5414
#
# Epoch 00007: val_loss did not improve from 0.61983
# Epoch 8/1000
#  - 32s - loss: 0.6875 - accuracy: 0.5461 - val_loss: 0.6657 - val_accuracy: 0.5589
#
# Epoch 00008: val_loss did not improve from 0.61983
# Epoch 9/1000
#  - 32s - loss: 0.6873 - accuracy: 0.5487 - val_loss: 0.7097 - val_accuracy: 0.5509
#
# Epoch 00009: val_loss did not improve from 0.61983
# Epoch 10/1000
#  - 32s - loss: 0.6872 - accuracy: 0.5495 - val_loss: 0.7049 - val_accuracy: 0.5507
#
# Epoch 00010: val_loss did not improve from 0.61983
# Epoch 11/1000
#  - 32s - loss: 0.6871 - accuracy: 0.5482 - val_loss: 0.6773 - val_accuracy: 0.5605
#
# Epoch 00011: val_loss did not improve from 0.61983
# Epoch 12/1000
#  - 32s - loss: 0.6870 - accuracy: 0.5491 - val_loss: 0.7317 - val_accuracy: 0.5414
#
# Epoch 00012: val_loss did not improve from 0.61983
# Epoch 13/1000
#  - 32s - loss: 0.6869 - accuracy: 0.5478 - val_loss: 0.6730 - val_accuracy: 0.5479
#
# Epoch 00013: val_loss did not improve from 0.61983
# Epoch 14/1000
#  - 32s - loss: 0.6867 - accuracy: 0.5495 - val_loss: 0.6630 - val_accuracy: 0.5471
#
# Epoch 00014: val_loss did not improve from 0.61983
# Epoch 15/1000
#  - 32s - loss: 0.6867 - accuracy: 0.5500 - val_loss: 0.6733 - val_accuracy: 0.5459
#
# Epoch 00015: val_loss did not improve from 0.61983
# Epoch 16/1000
#  - 32s - loss: 0.6867 - accuracy: 0.5492 - val_loss: 0.6700 - val_accuracy: 0.5430
#
# Epoch 00016: val_loss did not improve from 0.61983
# Epoch 17/1000
#  - 32s - loss: 0.6864 - accuracy: 0.5496 - val_loss: 0.7089 - val_accuracy: 0.5551
#
# Epoch 00017: val_loss did not improve from 0.61983
# Epoch 18/1000
#  - 32s - loss: 0.6863 - accuracy: 0.5510 - val_loss: 0.6781 - val_accuracy: 0.5367
#
# Epoch 00018: val_loss did not improve from 0.61983
# Epoch 19/1000
#  - 32s - loss: 0.6863 - accuracy: 0.5500 - val_loss: 0.6647 - val_accuracy: 0.5432
#
# Epoch 00019: val_loss did not improve from 0.61983
# Epoch 20/1000
#  - 32s - loss: 0.6862 - accuracy: 0.5515 - val_loss: 0.6903 - val_accuracy: 0.5462
#
# Epoch 00020: val_loss did not improve from 0.61983
# Epoch 21/1000
#  - 32s - loss: 0.6860 - accuracy: 0.5523 - val_loss: 0.7109 - val_accuracy: 0.5527
#
# Epoch 00021: val_loss did not improve from 0.61983
# Epoch 22/1000
#  - 32s - loss: 0.6859 - accuracy: 0.5512 - val_loss: 0.6785 - val_accuracy: 0.5628
#
# Epoch 00022: val_loss did not improve from 0.61983
# Epoch 23/1000
#  - 32s - loss: 0.6858 - accuracy: 0.5523 - val_loss: 0.6642 - val_accuracy: 0.5550
#
# Epoch 00023: val_loss did not improve from 0.61983
# Epoch 24/1000
#  - 32s - loss: 0.6856 - accuracy: 0.5519 - val_loss: 0.6661 - val_accuracy: 0.5486
#
# Epoch 00024: val_loss did not improve from 0.61983
# Epoch 25/1000
#  - 32s - loss: 0.6857 - accuracy: 0.5530 - val_loss: 0.6930 - val_accuracy: 0.5399
#
# Epoch 00025: val_loss did not improve from 0.61983
# Epoch 26/1000
#  - 32s - loss: 0.6857 - accuracy: 0.5521 - val_loss: 0.6900 - val_accuracy: 0.5495
#
# Epoch 00026: val_loss did not improve from 0.61983
# Epoch 27/1000
#  - 32s - loss: 0.6855 - accuracy: 0.5532 - val_loss: 0.6810 - val_accuracy: 0.5541
#
# Epoch 00027: val_loss did not improve from 0.61983
# Epoch 28/1000
#  - 32s - loss: 0.6854 - accuracy: 0.5537 - val_loss: 0.6927 - val_accuracy: 0.5453
#
# Epoch 00028: val_loss did not improve from 0.61983
# Epoch 29/1000
#  - 32s - loss: 0.6853 - accuracy: 0.5549 - val_loss: 0.6873 - val_accuracy: 0.5393
#
# Epoch 00029: val_loss did not improve from 0.61983
# Epoch 30/1000
#  - 32s - loss: 0.6851 - accuracy: 0.5527 - val_loss: 0.6891 - val_accuracy: 0.5501
#
# Epoch 00030: val_loss did not improve from 0.61983
# Epoch 31/1000
#  - 32s - loss: 0.6849 - accuracy: 0.5546 - val_loss: 0.6659 - val_accuracy: 0.5555
#
# Epoch 00031: val_loss did not improve from 0.61983
# Epoch 32/1000
#  - 32s - loss: 0.6851 - accuracy: 0.5547 - val_loss: 0.6575 - val_accuracy: 0.5393
#
# Epoch 00032: val_loss did not improve from 0.61983
# Epoch 33/1000
#  - 32s - loss: 0.6850 - accuracy: 0.5538 - val_loss: 0.7317 - val_accuracy: 0.5419
#
# Epoch 00033: val_loss did not improve from 0.61983
# Epoch 34/1000
#  - 32s - loss: 0.6847 - accuracy: 0.5563 - val_loss: 0.6884 - val_accuracy: 0.5493
#
# Epoch 00034: val_loss did not improve from 0.61983
# Epoch 35/1000
#  - 32s - loss: 0.6848 - accuracy: 0.5549 - val_loss: 0.6720 - val_accuracy: 0.5361
#
# Epoch 00035: val_loss did not improve from 0.61983
# Epoch 36/1000
#  - 32s - loss: 0.6847 - accuracy: 0.5560 - val_loss: 0.6951 - val_accuracy: 0.5533
#
# Epoch 00036: val_loss did not improve from 0.61983
# Epoch 37/1000
#  - 32s - loss: 0.6846 - accuracy: 0.5556 - val_loss: 0.6794 - val_accuracy: 0.5351
#
# Epoch 00037: val_loss did not improve from 0.61983
# Epoch 38/1000
#  - 32s - loss: 0.6844 - accuracy: 0.5567 - val_loss: 0.6777 - val_accuracy: 0.5439
#
# Epoch 00038: val_loss did not improve from 0.61983
# Epoch 39/1000
#  - 32s - loss: 0.6843 - accuracy: 0.5569 - val_loss: 0.7095 - val_accuracy: 0.5490
#
# Epoch 00039: val_loss did not improve from 0.61983
# Epoch 40/1000
#  - 32s - loss: 0.6842 - accuracy: 0.5585 - val_loss: 0.6921 - val_accuracy: 0.5559
#
# Epoch 00040: val_loss did not improve from 0.61983
# Epoch 41/1000
#  - 32s - loss: 0.6841 - accuracy: 0.5581 - val_loss: 0.6877 - val_accuracy: 0.5582
#
# Epoch 00041: val_loss did not improve from 0.61983
# Epoch 42/1000
#  - 32s - loss: 0.6841 - accuracy: 0.5584 - val_loss: 0.6952 - val_accuracy: 0.5424
#
# Epoch 00042: val_loss did not improve from 0.61983
# Epoch 43/1000
#  - 32s - loss: 0.6838 - accuracy: 0.5575 - val_loss: 0.6851 - val_accuracy: 0.5500
#
# Epoch 00043: val_loss did not improve from 0.61983
# Epoch 44/1000
#  - 32s - loss: 0.6839 - accuracy: 0.5588 - val_loss: 0.7471 - val_accuracy: 0.5508
#
# Epoch 00044: val_loss did not improve from 0.61983
# Epoch 45/1000
#  - 32s - loss: 0.6839 - accuracy: 0.5577 - val_loss: 0.7045 - val_accuracy: 0.5502
#
# Epoch 00045: val_loss did not improve from 0.61983
# Epoch 46/1000
#  - 32s - loss: 0.6838 - accuracy: 0.5565 - val_loss: 0.6621 - val_accuracy: 0.5455
#
# Epoch 00046: val_loss did not improve from 0.61983
# Epoch 47/1000
#  - 32s - loss: 0.6836 - accuracy: 0.5592 - val_loss: 0.7255 - val_accuracy: 0.5458
#
# Epoch 00047: val_loss did not improve from 0.61983
# Epoch 48/1000
#  - 32s - loss: 0.6837 - accuracy: 0.5581 - val_loss: 0.6631 - val_accuracy: 0.5397
#
# Epoch 00048: val_loss did not improve from 0.61983
# Epoch 49/1000
#  - 32s - loss: 0.6835 - accuracy: 0.5585 - val_loss: 0.6942 - val_accuracy: 0.5544
#
# Epoch 00049: val_loss did not improve from 0.61983
# Epoch 50/1000
#  - 32s - loss: 0.6833 - accuracy: 0.5594 - val_loss: 0.6574 - val_accuracy: 0.5483
#
# Epoch 00050: val_loss did not improve from 0.61983
# Epoch 51/1000
#  - 32s - loss: 0.6833 - accuracy: 0.5603 - val_loss: 0.6437 - val_accuracy: 0.5497
#
# Epoch 00051: val_loss did not improve from 0.61983
# Epoch 52/1000
#  - 32s - loss: 0.6831 - accuracy: 0.5600 - val_loss: 0.6618 - val_accuracy: 0.5485
#
# Epoch 00052: val_loss did not improve from 0.61983
# Epoch 53/1000
#  - 32s - loss: 0.6831 - accuracy: 0.5594 - val_loss: 0.7213 - val_accuracy: 0.5438
#
# Epoch 00053: val_loss did not improve from 0.61983
# Epoch 54/1000
#  - 32s - loss: 0.6829 - accuracy: 0.5612 - val_loss: 0.6885 - val_accuracy: 0.5487
#
# Epoch 00054: val_loss did not improve from 0.61983
# Epoch 55/1000
#  - 32s - loss: 0.6829 - accuracy: 0.5602 - val_loss: 0.6760 - val_accuracy: 0.5444
#
# Epoch 00055: val_loss did not improve from 0.61983
# Epoch 56/1000
#  - 32s - loss: 0.6830 - accuracy: 0.5599 - val_loss: 0.7346 - val_accuracy: 0.5562
#
# Epoch 00056: val_loss did not improve from 0.61983
# Epoch 57/1000
#  - 32s - loss: 0.6829 - accuracy: 0.5604 - val_loss: 0.6809 - val_accuracy: 0.5489
#
# Epoch 00057: val_loss did not improve from 0.61983
# Epoch 58/1000
#  - 32s - loss: 0.6826 - accuracy: 0.5616 - val_loss: 0.7272 - val_accuracy: 0.5445
#
# Epoch 00058: val_loss did not improve from 0.61983
# Epoch 59/1000
#  - 32s - loss: 0.6827 - accuracy: 0.5608 - val_loss: 0.6818 - val_accuracy: 0.5560
#
# Epoch 00059: val_loss did not improve from 0.61983
# Epoch 60/1000
#  - 32s - loss: 0.6825 - accuracy: 0.5612 - val_loss: 0.7244 - val_accuracy: 0.5470
#
# Epoch 00060: val_loss did not improve from 0.61983
# Epoch 61/1000
#  - 32s - loss: 0.6825 - accuracy: 0.5612 - val_loss: 0.6905 - val_accuracy: 0.5549
#
# Epoch 00061: val_loss did not improve from 0.61983
# Epoch 62/1000
#  - 32s - loss: 0.6824 - accuracy: 0.5615 - val_loss: 0.6648 - val_accuracy: 0.5571
#
# Epoch 00062: val_loss did not improve from 0.61983
# Epoch 63/1000
#  - 32s - loss: 0.6823 - accuracy: 0.5624 - val_loss: 0.7266 - val_accuracy: 0.5403
#
# Epoch 00063: val_loss did not improve from 0.61983
# Epoch 64/1000
#  - 31s - loss: 0.6822 - accuracy: 0.5636 - val_loss: 0.6551 - val_accuracy: 0.5523
#
# Epoch 00064: val_loss did not improve from 0.61983
# Epoch 65/1000
#  - 32s - loss: 0.6822 - accuracy: 0.5628 - val_loss: 0.7040 - val_accuracy: 0.5416
#
# Epoch 00065: val_loss did not improve from 0.61983
# Epoch 66/1000
#  - 32s - loss: 0.6820 - accuracy: 0.5625 - val_loss: 0.6968 - val_accuracy: 0.5526
#
# Epoch 00066: val_loss did not improve from 0.61983
# Epoch 67/1000
#  - 32s - loss: 0.6820 - accuracy: 0.5629 - val_loss: 0.6904 - val_accuracy: 0.5510
#
# Epoch 00067: val_loss did not improve from 0.61983
# Epoch 68/1000
#  - 32s - loss: 0.6820 - accuracy: 0.5620 - val_loss: 0.7628 - val_accuracy: 0.5534
#
# Epoch 00068: val_loss did not improve from 0.61983
# Epoch 69/1000
#  - 32s - loss: 0.6820 - accuracy: 0.5636 - val_loss: 0.6668 - val_accuracy: 0.5479
#
# Epoch 00069: val_loss did not improve from 0.61983
# Epoch 70/1000
#  - 32s - loss: 0.6819 - accuracy: 0.5622 - val_loss: 0.6702 - val_accuracy: 0.5483
#
# Epoch 00070: val_loss did not improve from 0.61983
# Epoch 71/1000
#  - 32s - loss: 0.6816 - accuracy: 0.5645 - val_loss: 0.6385 - val_accuracy: 0.5521
#
# Epoch 00071: val_loss did not improve from 0.61983
# Epoch 72/1000
#  - 32s - loss: 0.6817 - accuracy: 0.5643 - val_loss: 0.6483 - val_accuracy: 0.5423
#
# Epoch 00072: val_loss did not improve from 0.61983
# Epoch 73/1000
#  - 32s - loss: 0.6814 - accuracy: 0.5637 - val_loss: 0.6579 - val_accuracy: 0.5589
#
# Epoch 00073: val_loss did not improve from 0.61983
# Epoch 74/1000
#  - 32s - loss: 0.6813 - accuracy: 0.5661 - val_loss: 0.6431 - val_accuracy: 0.5458
#
# Epoch 00074: val_loss did not improve from 0.61983
# Epoch 75/1000
#  - 32s - loss: 0.6814 - accuracy: 0.5636 - val_loss: 0.7636 - val_accuracy: 0.5471
#
# Epoch 00075: val_loss did not improve from 0.61983
# Epoch 76/1000
#  - 32s - loss: 0.6812 - accuracy: 0.5645 - val_loss: 0.6476 - val_accuracy: 0.5503
#
# Epoch 00076: val_loss did not improve from 0.61983
# Epoch 77/1000
#  - 32s - loss: 0.6815 - accuracy: 0.5644 - val_loss: 0.6927 - val_accuracy: 0.5536
#
# Epoch 00077: val_loss did not improve from 0.61983
# Epoch 78/1000
#  - 32s - loss: 0.6811 - accuracy: 0.5645 - val_loss: 0.6782 - val_accuracy: 0.5566
#
# Epoch 00078: val_loss did not improve from 0.61983
# Epoch 79/1000
#  - 32s - loss: 0.6812 - accuracy: 0.5651 - val_loss: 0.7129 - val_accuracy: 0.5461
#
# Epoch 00079: val_loss did not improve from 0.61983
# Epoch 80/1000
#  - 32s - loss: 0.6809 - accuracy: 0.5655 - val_loss: 0.6647 - val_accuracy: 0.5441
#
# Epoch 00080: val_loss did not improve from 0.61983
# Epoch 81/1000
#  - 32s - loss: 0.6810 - accuracy: 0.5653 - val_loss: 0.6875 - val_accuracy: 0.5526
#
# Epoch 00081: val_loss did not improve from 0.61983
# Epoch 82/1000
#  - 32s - loss: 0.6809 - accuracy: 0.5658 - val_loss: 0.6495 - val_accuracy: 0.5507
#
# Epoch 00082: val_loss did not improve from 0.61983
# Epoch 83/1000
#  - 32s - loss: 0.6808 - accuracy: 0.5650 - val_loss: 0.7105 - val_accuracy: 0.5483
#
# Epoch 00083: val_loss did not improve from 0.61983
# Epoch 84/1000
#  - 32s - loss: 0.6809 - accuracy: 0.5659 - val_loss: 0.7070 - val_accuracy: 0.5400
#
# Epoch 00084: val_loss did not improve from 0.61983
# Epoch 85/1000
#  - 32s - loss: 0.6808 - accuracy: 0.5656 - val_loss: 0.7073 - val_accuracy: 0.5427
#
# Epoch 00085: val_loss did not improve from 0.61983
# Epoch 86/1000
#  - 32s - loss: 0.6804 - accuracy: 0.5675 - val_loss: 0.7074 - val_accuracy: 0.5442
#
# Epoch 00086: val_loss did not improve from 0.61983
# Epoch 87/1000
#  - 32s - loss: 0.6803 - accuracy: 0.5679 - val_loss: 0.7317 - val_accuracy: 0.5411
#
# Epoch 00087: val_loss did not improve from 0.61983
# Epoch 88/1000
#  - 32s - loss: 0.6805 - accuracy: 0.5673 - val_loss: 0.7259 - val_accuracy: 0.5506
#
# Epoch 00088: val_loss did not improve from 0.61983
# Epoch 89/1000
#  - 32s - loss: 0.6803 - accuracy: 0.5667 - val_loss: 0.6414 - val_accuracy: 0.5475
#
# Epoch 00089: val_loss did not improve from 0.61983
# Epoch 90/1000
#  - 32s - loss: 0.6803 - accuracy: 0.5664 - val_loss: 0.6359 - val_accuracy: 0.5536
#
# Epoch 00090: val_loss did not improve from 0.61983
# Epoch 91/1000
#  - 31s - loss: 0.6800 - accuracy: 0.5689 - val_loss: 0.7096 - val_accuracy: 0.5379
#
# Epoch 00091: val_loss did not improve from 0.61983
# Epoch 92/1000
#  - 32s - loss: 0.6800 - accuracy: 0.5683 - val_loss: 0.6693 - val_accuracy: 0.5452
#
# Epoch 00092: val_loss did not improve from 0.61983
# Epoch 93/1000
#  - 32s - loss: 0.6801 - accuracy: 0.5680 - val_loss: 0.6845 - val_accuracy: 0.5557
#
# Epoch 00093: val_loss did not improve from 0.61983
# Epoch 94/1000
#  - 31s - loss: 0.6799 - accuracy: 0.5683 - val_loss: 0.7320 - val_accuracy: 0.5602
#
# Epoch 00094: val_loss did not improve from 0.61983
# Epoch 95/1000
#  - 32s - loss: 0.6799 - accuracy: 0.5696 - val_loss: 0.7227 - val_accuracy: 0.5502
#
# Epoch 00095: val_loss did not improve from 0.61983
# Epoch 96/1000
#  - 32s - loss: 0.6799 - accuracy: 0.5677 - val_loss: 0.6965 - val_accuracy: 0.5520
#
# Epoch 00096: val_loss did not improve from 0.61983
# Epoch 97/1000
#  - 32s - loss: 0.6796 - accuracy: 0.5679 - val_loss: 0.6890 - val_accuracy: 0.5531
#
# Epoch 00097: val_loss did not improve from 0.61983
# Epoch 98/1000
#  - 32s - loss: 0.6795 - accuracy: 0.5693 - val_loss: 0.6884 - val_accuracy: 0.5356
#
# Epoch 00098: val_loss did not improve from 0.61983
# Epoch 99/1000
#  - 32s - loss: 0.6795 - accuracy: 0.5685 - val_loss: 0.6145 - val_accuracy: 0.5439
#
# Epoch 00099: val_loss improved from 0.61983 to 0.61447, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_5_close_updown_pr.h5
# Epoch 100/1000
#  - 32s - loss: 0.6796 - accuracy: 0.5686 - val_loss: 0.6918 - val_accuracy: 0.5364
#
# Epoch 00100: val_loss did not improve from 0.61447
# Epoch 101/1000
#  - 32s - loss: 0.6793 - accuracy: 0.5693 - val_loss: 0.7141 - val_accuracy: 0.5424
#
# Epoch 00101: val_loss did not improve from 0.61447
# Epoch 102/1000
#  - 32s - loss: 0.6792 - accuracy: 0.5699 - val_loss: 0.7376 - val_accuracy: 0.5267
#
# Epoch 00102: val_loss did not improve from 0.61447
# Epoch 103/1000
#  - 32s - loss: 0.6795 - accuracy: 0.5681 - val_loss: 0.7768 - val_accuracy: 0.5454
#
# Epoch 00103: val_loss did not improve from 0.61447
# Epoch 104/1000
#  - 32s - loss: 0.6792 - accuracy: 0.5697 - val_loss: 0.6161 - val_accuracy: 0.5366
#
# Epoch 00104: val_loss did not improve from 0.61447
# Epoch 105/1000
#  - 32s - loss: 0.6794 - accuracy: 0.5691 - val_loss: 0.7277 - val_accuracy: 0.5445
#
# Epoch 00105: val_loss did not improve from 0.61447
# Epoch 106/1000
#  - 32s - loss: 0.6791 - accuracy: 0.5699 - val_loss: 0.6695 - val_accuracy: 0.5507
#
# Epoch 00106: val_loss did not improve from 0.61447
# Epoch 107/1000
#  - 32s - loss: 0.6790 - accuracy: 0.5699 - val_loss: 0.6519 - val_accuracy: 0.5532
#
# Epoch 00107: val_loss did not improve from 0.61447
# Epoch 108/1000
#  - 31s - loss: 0.6790 - accuracy: 0.5707 - val_loss: 0.6534 - val_accuracy: 0.5415
#
# Epoch 00108: val_loss did not improve from 0.61447
# Epoch 109/1000
#  - 32s - loss: 0.6788 - accuracy: 0.5701 - val_loss: 0.6989 - val_accuracy: 0.5446
#
# Epoch 00109: val_loss did not improve from 0.61447
# Epoch 110/1000
#  - 32s - loss: 0.6789 - accuracy: 0.5700 - val_loss: 0.7234 - val_accuracy: 0.5388
#
# Epoch 00110: val_loss did not improve from 0.61447
# Epoch 111/1000
#  - 32s - loss: 0.6787 - accuracy: 0.5702 - val_loss: 0.6599 - val_accuracy: 0.5366
#
# Epoch 00111: val_loss did not improve from 0.61447
# Epoch 112/1000
#  - 32s - loss: 0.6786 - accuracy: 0.5715 - val_loss: 0.6971 - val_accuracy: 0.5466
#
# Epoch 00112: val_loss did not improve from 0.61447
# Epoch 113/1000
#  - 31s - loss: 0.6785 - accuracy: 0.5706 - val_loss: 0.7310 - val_accuracy: 0.5415
#
# Epoch 00113: val_loss did not improve from 0.61447
# Epoch 114/1000
#  - 32s - loss: 0.6783 - accuracy: 0.5710 - val_loss: 0.7134 - val_accuracy: 0.5555
#
# Epoch 00114: val_loss did not improve from 0.61447
# Epoch 115/1000
#  - 32s - loss: 0.6784 - accuracy: 0.5710 - val_loss: 0.6773 - val_accuracy: 0.5493
#
# Epoch 00115: val_loss did not improve from 0.61447
# Epoch 116/1000
#  - 32s - loss: 0.6782 - accuracy: 0.5717 - val_loss: 0.6836 - val_accuracy: 0.5475
#
# Epoch 00116: val_loss did not improve from 0.61447
# Epoch 117/1000
#  - 32s - loss: 0.6784 - accuracy: 0.5719 - val_loss: 0.6857 - val_accuracy: 0.5457
#
# Epoch 00117: val_loss did not improve from 0.61447
# Epoch 118/1000
#  - 32s - loss: 0.6780 - accuracy: 0.5726 - val_loss: 0.7624 - val_accuracy: 0.5403
#
# Epoch 00118: val_loss did not improve from 0.61447
# Epoch 119/1000
#  - 32s - loss: 0.6781 - accuracy: 0.5721 - val_loss: 0.7306 - val_accuracy: 0.5488
#
# Epoch 00119: val_loss did not improve from 0.61447
# Epoch 120/1000
#  - 32s - loss: 0.6777 - accuracy: 0.5735 - val_loss: 0.7624 - val_accuracy: 0.5516
#
# Epoch 00120: val_loss did not improve from 0.61447
# Epoch 121/1000
#  - 32s - loss: 0.6778 - accuracy: 0.5728 - val_loss: 0.6696 - val_accuracy: 0.5543
#
# Epoch 00121: val_loss did not improve from 0.61447
# Epoch 122/1000
#  - 32s - loss: 0.6779 - accuracy: 0.5725 - val_loss: 0.6228 - val_accuracy: 0.5466
#
# Epoch 00122: val_loss did not improve from 0.61447
# Epoch 123/1000
#  - 32s - loss: 0.6777 - accuracy: 0.5724 - val_loss: 0.6633 - val_accuracy: 0.5495
#
# Epoch 00123: val_loss did not improve from 0.61447
# Epoch 124/1000
#  - 32s - loss: 0.6777 - accuracy: 0.5730 - val_loss: 0.6263 - val_accuracy: 0.5530
#
# Epoch 00124: val_loss did not improve from 0.61447
# Epoch 125/1000
#  - 32s - loss: 0.6777 - accuracy: 0.5739 - val_loss: 0.7554 - val_accuracy: 0.5468
#
# Epoch 00125: val_loss did not improve from 0.61447
# Epoch 126/1000
#  - 32s - loss: 0.6776 - accuracy: 0.5722 - val_loss: 0.6623 - val_accuracy: 0.5376
#
# Epoch 00126: val_loss did not improve from 0.61447
# Epoch 127/1000
#  - 32s - loss: 0.6776 - accuracy: 0.5726 - val_loss: 0.6431 - val_accuracy: 0.5372
#
# Epoch 00127: val_loss did not improve from 0.61447
# Epoch 128/1000
#  - 32s - loss: 0.6771 - accuracy: 0.5735 - val_loss: 0.7021 - val_accuracy: 0.5526
#
# Epoch 00128: val_loss did not improve from 0.61447
# Epoch 129/1000
#  - 32s - loss: 0.6773 - accuracy: 0.5742 - val_loss: 0.7183 - val_accuracy: 0.5489
#
# Epoch 00129: val_loss did not improve from 0.61447
# Epoch 130/1000
#  - 32s - loss: 0.6772 - accuracy: 0.5735 - val_loss: 0.6679 - val_accuracy: 0.5474
#
# Epoch 00130: val_loss did not improve from 0.61447
# Epoch 131/1000
#  - 32s - loss: 0.6772 - accuracy: 0.5746 - val_loss: 0.6823 - val_accuracy: 0.5371
#
# Epoch 00131: val_loss did not improve from 0.61447
# Epoch 132/1000
#  - 32s - loss: 0.6772 - accuracy: 0.5746 - val_loss: 0.7520 - val_accuracy: 0.5483
#
# Epoch 00132: val_loss did not improve from 0.61447
# Epoch 133/1000
#  - 32s - loss: 0.6772 - accuracy: 0.5733 - val_loss: 0.7305 - val_accuracy: 0.5493
#
# Epoch 00133: val_loss did not improve from 0.61447
# Epoch 134/1000
#  - 32s - loss: 0.6769 - accuracy: 0.5749 - val_loss: 0.6729 - val_accuracy: 0.5581
#
# Epoch 00134: val_loss did not improve from 0.61447
# Epoch 135/1000
#  - 31s - loss: 0.6767 - accuracy: 0.5756 - val_loss: 0.6635 - val_accuracy: 0.5462
#
# Epoch 00135: val_loss did not improve from 0.61447
# Epoch 136/1000
#  - 32s - loss: 0.6766 - accuracy: 0.5755 - val_loss: 0.6776 - val_accuracy: 0.5427
#
# Epoch 00136: val_loss did not improve from 0.61447
# Epoch 137/1000
#  - 32s - loss: 0.6768 - accuracy: 0.5738 - val_loss: 0.7349 - val_accuracy: 0.5479
#
# Epoch 00137: val_loss did not improve from 0.61447
# Epoch 138/1000
#  - 31s - loss: 0.6769 - accuracy: 0.5744 - val_loss: 0.6701 - val_accuracy: 0.5508
#
# Epoch 00138: val_loss did not improve from 0.61447
# Epoch 139/1000
#  - 32s - loss: 0.6766 - accuracy: 0.5755 - val_loss: 0.7766 - val_accuracy: 0.5513
#
# Epoch 00139: val_loss did not improve from 0.61447
# Epoch 140/1000
#  - 32s - loss: 0.6768 - accuracy: 0.5750 - val_loss: 0.6815 - val_accuracy: 0.5454
#
# Epoch 00140: val_loss did not improve from 0.61447
# Epoch 141/1000
#  - 32s - loss: 0.6766 - accuracy: 0.5749 - val_loss: 0.5870 - val_accuracy: 0.5332
#
# Epoch 00141: val_loss improved from 0.61447 to 0.58703, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_5_close_updown_pr.h5
# Epoch 142/1000
#  - 32s - loss: 0.6763 - accuracy: 0.5759 - val_loss: 0.6999 - val_accuracy: 0.5399
#
# Epoch 00142: val_loss did not improve from 0.58703
# Epoch 143/1000
#  - 32s - loss: 0.6762 - accuracy: 0.5754 - val_loss: 0.8054 - val_accuracy: 0.5358
#
# Epoch 00143: val_loss did not improve from 0.58703
# Epoch 144/1000
#  - 32s - loss: 0.6760 - accuracy: 0.5766 - val_loss: 0.6668 - val_accuracy: 0.5427
#
# Epoch 00144: val_loss did not improve from 0.58703
# Epoch 145/1000
#  - 31s - loss: 0.6760 - accuracy: 0.5778 - val_loss: 0.7141 - val_accuracy: 0.5493
#
# Epoch 00145: val_loss did not improve from 0.58703
# Epoch 146/1000
#  - 32s - loss: 0.6760 - accuracy: 0.5767 - val_loss: 0.7222 - val_accuracy: 0.5354
#
# Epoch 00146: val_loss did not improve from 0.58703
# Epoch 147/1000
#  - 32s - loss: 0.6759 - accuracy: 0.5759 - val_loss: 0.6604 - val_accuracy: 0.5574
#
# Epoch 00147: val_loss did not improve from 0.58703
# Epoch 148/1000
#  - 32s - loss: 0.6760 - accuracy: 0.5760 - val_loss: 0.6341 - val_accuracy: 0.5512
#
# Epoch 00148: val_loss did not improve from 0.58703
# Epoch 149/1000
#  - 32s - loss: 0.6757 - accuracy: 0.5768 - val_loss: 0.7565 - val_accuracy: 0.5437
#
# Epoch 00149: val_loss did not improve from 0.58703
# Epoch 150/1000
#  - 32s - loss: 0.6759 - accuracy: 0.5767 - val_loss: 0.6784 - val_accuracy: 0.5256
#
# Epoch 00150: val_loss did not improve from 0.58703
# Epoch 151/1000
#  - 32s - loss: 0.6755 - accuracy: 0.5778 - val_loss: 0.7212 - val_accuracy: 0.5404
#
# Epoch 00151: val_loss did not improve from 0.58703
# Epoch 152/1000
#  - 31s - loss: 0.6754 - accuracy: 0.5777 - val_loss: 0.6396 - val_accuracy: 0.5467
#
# Epoch 00152: val_loss did not improve from 0.58703
# Epoch 153/1000
#  - 32s - loss: 0.6754 - accuracy: 0.5765 - val_loss: 0.7121 - val_accuracy: 0.5462
#
# Epoch 00153: val_loss did not improve from 0.58703
# Epoch 154/1000
#  - 32s - loss: 0.6754 - accuracy: 0.5775 - val_loss: 0.7122 - val_accuracy: 0.5478
#
# Epoch 00154: val_loss did not improve from 0.58703
# Epoch 155/1000
#  - 31s - loss: 0.6756 - accuracy: 0.5764 - val_loss: 0.6893 - val_accuracy: 0.5419
#
# Epoch 00155: val_loss did not improve from 0.58703
# Epoch 156/1000
#  - 32s - loss: 0.6753 - accuracy: 0.5763 - val_loss: 0.6738 - val_accuracy: 0.5389
#
# Epoch 00156: val_loss did not improve from 0.58703
# Epoch 157/1000
#  - 32s - loss: 0.6755 - accuracy: 0.5770 - val_loss: 0.6622 - val_accuracy: 0.5320
#
# Epoch 00157: val_loss did not improve from 0.58703
# Epoch 158/1000
#  - 32s - loss: 0.6753 - accuracy: 0.5778 - val_loss: 0.6927 - val_accuracy: 0.5548
#
# Epoch 00158: val_loss did not improve from 0.58703
# Epoch 159/1000
#  - 32s - loss: 0.6752 - accuracy: 0.5787 - val_loss: 0.6611 - val_accuracy: 0.5464
#
# Epoch 00159: val_loss did not improve from 0.58703
# Epoch 160/1000
#  - 32s - loss: 0.6748 - accuracy: 0.5792 - val_loss: 0.7649 - val_accuracy: 0.5490
#
# Epoch 00160: val_loss did not improve from 0.58703
# Epoch 161/1000
#  - 32s - loss: 0.6748 - accuracy: 0.5789 - val_loss: 0.7699 - val_accuracy: 0.5432
#
# Epoch 00161: val_loss did not improve from 0.58703
# Epoch 162/1000
#  - 32s - loss: 0.6751 - accuracy: 0.5776 - val_loss: 0.6413 - val_accuracy: 0.5417
#
# Epoch 00162: val_loss did not improve from 0.58703
# Epoch 163/1000
#  - 32s - loss: 0.6749 - accuracy: 0.5785 - val_loss: 0.6924 - val_accuracy: 0.5492
#
# Epoch 00163: val_loss did not improve from 0.58703
# Epoch 164/1000
#  - 32s - loss: 0.6751 - accuracy: 0.5773 - val_loss: 0.6659 - val_accuracy: 0.5496
#
# Epoch 00164: val_loss did not improve from 0.58703
# Epoch 165/1000
#  - 32s - loss: 0.6749 - accuracy: 0.5786 - val_loss: 0.6860 - val_accuracy: 0.5390
#
# Epoch 00165: val_loss did not improve from 0.58703
# Epoch 166/1000
#  - 32s - loss: 0.6745 - accuracy: 0.5789 - val_loss: 0.6860 - val_accuracy: 0.5496
#
# Epoch 00166: val_loss did not improve from 0.58703
# Epoch 167/1000
#  - 32s - loss: 0.6747 - accuracy: 0.5783 - val_loss: 0.6815 - val_accuracy: 0.5383
#
# Epoch 00167: val_loss did not improve from 0.58703
# Epoch 168/1000
#  - 31s - loss: 0.6746 - accuracy: 0.5810 - val_loss: 0.7182 - val_accuracy: 0.5397
#
# Epoch 00168: val_loss did not improve from 0.58703
# Epoch 169/1000
#  - 32s - loss: 0.6745 - accuracy: 0.5796 - val_loss: 0.7079 - val_accuracy: 0.5521
#
# Epoch 00169: val_loss did not improve from 0.58703
# Epoch 170/1000
#  - 32s - loss: 0.6745 - accuracy: 0.5798 - val_loss: 0.7484 - val_accuracy: 0.5380
#
# Epoch 00170: val_loss did not improve from 0.58703
# Epoch 171/1000
#  - 32s - loss: 0.6744 - accuracy: 0.5796 - val_loss: 0.6548 - val_accuracy: 0.5419
#
# Epoch 00171: val_loss did not improve from 0.58703
# Epoch 172/1000
#  - 32s - loss: 0.6744 - accuracy: 0.5811 - val_loss: 0.6658 - val_accuracy: 0.5353
#
# Epoch 00172: val_loss did not improve from 0.58703
# Epoch 173/1000
#  - 32s - loss: 0.6740 - accuracy: 0.5803 - val_loss: 0.7367 - val_accuracy: 0.5323
#
# Epoch 00173: val_loss did not improve from 0.58703
# Epoch 174/1000
#  - 32s - loss: 0.6745 - accuracy: 0.5805 - val_loss: 0.6672 - val_accuracy: 0.5420
#
# Epoch 00174: val_loss did not improve from 0.58703
# Epoch 175/1000
#  - 32s - loss: 0.6741 - accuracy: 0.5804 - val_loss: 0.6603 - val_accuracy: 0.5466
#
# Epoch 00175: val_loss did not improve from 0.58703
# Epoch 176/1000
#  - 32s - loss: 0.6741 - accuracy: 0.5807 - val_loss: 0.7224 - val_accuracy: 0.5540
#
# Epoch 00176: val_loss did not improve from 0.58703
# Epoch 177/1000
#  - 32s - loss: 0.6740 - accuracy: 0.5807 - val_loss: 0.7246 - val_accuracy: 0.5492
#
# Epoch 00177: val_loss did not improve from 0.58703
# Epoch 178/1000
#  - 32s - loss: 0.6738 - accuracy: 0.5808 - val_loss: 0.7195 - val_accuracy: 0.5448
#
# Epoch 00178: val_loss did not improve from 0.58703
# Epoch 179/1000
#  - 32s - loss: 0.6738 - accuracy: 0.5809 - val_loss: 0.7411 - val_accuracy: 0.5470
#
# Epoch 00179: val_loss did not improve from 0.58703
# Epoch 180/1000
#  - 32s - loss: 0.6736 - accuracy: 0.5826 - val_loss: 0.6335 - val_accuracy: 0.5558
#
# Epoch 00180: val_loss did not improve from 0.58703
# Epoch 181/1000
#  - 32s - loss: 0.6738 - accuracy: 0.5805 - val_loss: 0.6685 - val_accuracy: 0.5542
#
# Epoch 00181: val_loss did not improve from 0.58703
# Epoch 182/1000
#  - 32s - loss: 0.6735 - accuracy: 0.5819 - val_loss: 0.6573 - val_accuracy: 0.5444
#
# Epoch 00182: val_loss did not improve from 0.58703
# Epoch 183/1000
#  - 32s - loss: 0.6737 - accuracy: 0.5818 - val_loss: 0.7344 - val_accuracy: 0.5388
#
# Epoch 00183: val_loss did not improve from 0.58703
# Epoch 184/1000
#  - 32s - loss: 0.6735 - accuracy: 0.5817 - val_loss: 0.6824 - val_accuracy: 0.5378
#
# Epoch 00184: val_loss did not improve from 0.58703
# Epoch 185/1000
#  - 32s - loss: 0.6735 - accuracy: 0.5810 - val_loss: 0.6557 - val_accuracy: 0.5415
#
# Epoch 00185: val_loss did not improve from 0.58703
# Epoch 186/1000
#  - 32s - loss: 0.6733 - accuracy: 0.5817 - val_loss: 0.6751 - val_accuracy: 0.5517
#
# Epoch 00186: val_loss did not improve from 0.58703
# Epoch 187/1000
#  - 31s - loss: 0.6730 - accuracy: 0.5823 - val_loss: 0.6671 - val_accuracy: 0.5262
#
# Epoch 00187: val_loss did not improve from 0.58703
# Epoch 188/1000
#  - 32s - loss: 0.6730 - accuracy: 0.5810 - val_loss: 0.7877 - val_accuracy: 0.5505
#
# Epoch 00188: val_loss did not improve from 0.58703
# Epoch 189/1000
#  - 32s - loss: 0.6732 - accuracy: 0.5835 - val_loss: 0.7329 - val_accuracy: 0.5538
#
# Epoch 00189: val_loss did not improve from 0.58703
# Epoch 190/1000
#  - 32s - loss: 0.6730 - accuracy: 0.5825 - val_loss: 0.6467 - val_accuracy: 0.5367
#
# Epoch 00190: val_loss did not improve from 0.58703
# Epoch 191/1000
#  - 32s - loss: 0.6728 - accuracy: 0.5826 - val_loss: 0.6392 - val_accuracy: 0.5546
#
# Epoch 00191: val_loss did not improve from 0.58703
# Epoch 192/1000
#  - 32s - loss: 0.6728 - accuracy: 0.5832 - val_loss: 0.6439 - val_accuracy: 0.5454
#
# Epoch 00192: val_loss did not improve from 0.58703
# Epoch 193/1000
#  - 32s - loss: 0.6730 - accuracy: 0.5816 - val_loss: 0.6561 - val_accuracy: 0.5462
#
# Epoch 00193: val_loss did not improve from 0.58703
# Epoch 194/1000
#  - 32s - loss: 0.6731 - accuracy: 0.5819 - val_loss: 0.6796 - val_accuracy: 0.5411
#
# Epoch 00194: val_loss did not improve from 0.58703
# Epoch 195/1000
#  - 32s - loss: 0.6730 - accuracy: 0.5830 - val_loss: 0.6880 - val_accuracy: 0.5339
#
# Epoch 00195: val_loss did not improve from 0.58703
# Epoch 196/1000
#  - 32s - loss: 0.6728 - accuracy: 0.5822 - val_loss: 0.6923 - val_accuracy: 0.5257
#
# Epoch 00196: val_loss did not improve from 0.58703
# Epoch 197/1000
#  - 32s - loss: 0.6724 - accuracy: 0.5827 - val_loss: 0.6743 - val_accuracy: 0.5394
#
# Epoch 00197: val_loss did not improve from 0.58703
# Epoch 198/1000
#  - 32s - loss: 0.6725 - accuracy: 0.5828 - val_loss: 0.6887 - val_accuracy: 0.5287
#
# Epoch 00198: val_loss did not improve from 0.58703
# Epoch 199/1000
#  - 32s - loss: 0.6725 - accuracy: 0.5831 - val_loss: 0.7586 - val_accuracy: 0.5423
#
# Epoch 00199: val_loss did not improve from 0.58703
# Epoch 200/1000
#  - 32s - loss: 0.6721 - accuracy: 0.5837 - val_loss: 0.7259 - val_accuracy: 0.5307
#
# Epoch 00200: val_loss did not improve from 0.58703
# Epoch 201/1000
#  - 32s - loss: 0.6721 - accuracy: 0.5849 - val_loss: 0.6807 - val_accuracy: 0.5467
#
# Epoch 00201: val_loss did not improve from 0.58703
# Epoch 202/1000
#  - 32s - loss: 0.6721 - accuracy: 0.5834 - val_loss: 0.7359 - val_accuracy: 0.5426
#
# Epoch 00202: val_loss did not improve from 0.58703
# Epoch 203/1000
#  - 32s - loss: 0.6721 - accuracy: 0.5825 - val_loss: 0.6645 - val_accuracy: 0.5410
#
# Epoch 00203: val_loss did not improve from 0.58703
# Epoch 204/1000
#  - 31s - loss: 0.6720 - accuracy: 0.5842 - val_loss: 0.6506 - val_accuracy: 0.5457
#
# Epoch 00204: val_loss did not improve from 0.58703
# Epoch 205/1000
#  - 32s - loss: 0.6719 - accuracy: 0.5837 - val_loss: 0.6849 - val_accuracy: 0.5436
#
# Epoch 00205: val_loss did not improve from 0.58703
# Epoch 206/1000
#  - 32s - loss: 0.6721 - accuracy: 0.5830 - val_loss: 0.6706 - val_accuracy: 0.5471
#
# Epoch 00206: val_loss did not improve from 0.58703
# Epoch 207/1000
#  - 32s - loss: 0.6718 - accuracy: 0.5855 - val_loss: 0.7001 - val_accuracy: 0.5417
#
# Epoch 00207: val_loss did not improve from 0.58703
# Epoch 208/1000
#  - 31s - loss: 0.6717 - accuracy: 0.5848 - val_loss: 0.6882 - val_accuracy: 0.5464
#
# Epoch 00208: val_loss did not improve from 0.58703
# Epoch 209/1000
#  - 32s - loss: 0.6716 - accuracy: 0.5843 - val_loss: 0.6856 - val_accuracy: 0.5542
#
# Epoch 00209: val_loss did not improve from 0.58703
# Epoch 210/1000
#  - 32s - loss: 0.6719 - accuracy: 0.5839 - val_loss: 0.6815 - val_accuracy: 0.5348
#
# Epoch 00210: val_loss did not improve from 0.58703
# Epoch 211/1000
#  - 32s - loss: 0.6715 - accuracy: 0.5850 - val_loss: 0.6855 - val_accuracy: 0.5489
#
# Epoch 00211: val_loss did not improve from 0.58703
# Epoch 212/1000
#  - 32s - loss: 0.6716 - accuracy: 0.5853 - val_loss: 0.7597 - val_accuracy: 0.5358
#
# Epoch 00212: val_loss did not improve from 0.58703
# Epoch 213/1000
#  - 32s - loss: 0.6715 - accuracy: 0.5851 - val_loss: 0.6915 - val_accuracy: 0.5523
#
# Epoch 00213: val_loss did not improve from 0.58703
# Epoch 214/1000
#  - 32s - loss: 0.6714 - accuracy: 0.5841 - val_loss: 0.7608 - val_accuracy: 0.5418
#
# Epoch 00214: val_loss did not improve from 0.58703
# Epoch 215/1000
#  - 32s - loss: 0.6717 - accuracy: 0.5841 - val_loss: 0.7124 - val_accuracy: 0.5323
#
# Epoch 00215: val_loss did not improve from 0.58703
# Epoch 216/1000
#  - 32s - loss: 0.6712 - accuracy: 0.5856 - val_loss: 0.6829 - val_accuracy: 0.5392
#
# Epoch 00216: val_loss did not improve from 0.58703
# Epoch 217/1000
#  - 31s - loss: 0.6713 - accuracy: 0.5837 - val_loss: 0.7250 - val_accuracy: 0.5428
#
# Epoch 00217: val_loss did not improve from 0.58703
# Epoch 218/1000
#  - 31s - loss: 0.6710 - accuracy: 0.5871 - val_loss: 0.6152 - val_accuracy: 0.5424
#
# Epoch 00218: val_loss did not improve from 0.58703
# Epoch 219/1000
#  - 32s - loss: 0.6708 - accuracy: 0.5867 - val_loss: 0.7302 - val_accuracy: 0.5464
#
# Epoch 00219: val_loss did not improve from 0.58703
# Epoch 220/1000
#  - 32s - loss: 0.6712 - accuracy: 0.5854 - val_loss: 0.7293 - val_accuracy: 0.5402
#
# Epoch 00220: val_loss did not improve from 0.58703
# Epoch 221/1000
#  - 32s - loss: 0.6710 - accuracy: 0.5857 - val_loss: 0.6679 - val_accuracy: 0.5487
#
# Epoch 00221: val_loss did not improve from 0.58703
# Epoch 222/1000
#  - 32s - loss: 0.6711 - accuracy: 0.5852 - val_loss: 0.6624 - val_accuracy: 0.5436
#
# Epoch 00222: val_loss did not improve from 0.58703
# Epoch 223/1000
#  - 32s - loss: 0.6712 - accuracy: 0.5850 - val_loss: 0.6352 - val_accuracy: 0.5376
#
# Epoch 00223: val_loss did not improve from 0.58703
# Epoch 224/1000
#  - 32s - loss: 0.6703 - accuracy: 0.5869 - val_loss: 0.7309 - val_accuracy: 0.5349
#
# Epoch 00224: val_loss did not improve from 0.58703
# Epoch 225/1000
#  - 31s - loss: 0.6703 - accuracy: 0.5871 - val_loss: 0.6502 - val_accuracy: 0.5437
#
# Epoch 00225: val_loss did not improve from 0.58703
# Epoch 226/1000
#  - 32s - loss: 0.6709 - accuracy: 0.5864 - val_loss: 0.7474 - val_accuracy: 0.5404
#
# Epoch 00226: val_loss did not improve from 0.58703
# Epoch 227/1000
#  - 32s - loss: 0.6709 - accuracy: 0.5870 - val_loss: 0.6124 - val_accuracy: 0.5468
#
# Epoch 00227: val_loss did not improve from 0.58703
# Epoch 228/1000
#  - 32s - loss: 0.6705 - accuracy: 0.5875 - val_loss: 0.6614 - val_accuracy: 0.5512
#
# Epoch 00228: val_loss did not improve from 0.58703
# Epoch 229/1000
#  - 32s - loss: 0.6705 - accuracy: 0.5873 - val_loss: 0.7124 - val_accuracy: 0.5487
#
# Epoch 00229: val_loss did not improve from 0.58703
# Epoch 230/1000
#  - 32s - loss: 0.6703 - accuracy: 0.5881 - val_loss: 0.6317 - val_accuracy: 0.5490
#
# Epoch 00230: val_loss did not improve from 0.58703
# Epoch 231/1000
#  - 32s - loss: 0.6703 - accuracy: 0.5875 - val_loss: 0.7864 - val_accuracy: 0.5494
#
# Epoch 00231: val_loss did not improve from 0.58703
# Epoch 232/1000
#  - 32s - loss: 0.6703 - accuracy: 0.5872 - val_loss: 0.6758 - val_accuracy: 0.5535
#
# Epoch 00232: val_loss did not improve from 0.58703
# Epoch 233/1000
#  - 32s - loss: 0.6700 - accuracy: 0.5865 - val_loss: 0.7707 - val_accuracy: 0.5403
#
# Epoch 00233: val_loss did not improve from 0.58703
# Epoch 234/1000
#  - 32s - loss: 0.6694 - accuracy: 0.5890 - val_loss: 0.6408 - val_accuracy: 0.5553
#
# Epoch 00234: val_loss did not improve from 0.58703
# Epoch 235/1000
#  - 32s - loss: 0.6696 - accuracy: 0.5880 - val_loss: 0.6921 - val_accuracy: 0.5444
#
# Epoch 00235: val_loss did not improve from 0.58703
# Epoch 236/1000
#  - 32s - loss: 0.6701 - accuracy: 0.5860 - val_loss: 0.6428 - val_accuracy: 0.5482
#
# Epoch 00236: val_loss did not improve from 0.58703
# Epoch 237/1000
#  - 32s - loss: 0.6700 - accuracy: 0.5873 - val_loss: 0.6109 - val_accuracy: 0.5438
#
# Epoch 00237: val_loss did not improve from 0.58703
# Epoch 238/1000
#  - 32s - loss: 0.6698 - accuracy: 0.5871 - val_loss: 0.6827 - val_accuracy: 0.5484
#
# Epoch 00238: val_loss did not improve from 0.58703
# Epoch 239/1000
#  - 32s - loss: 0.6700 - accuracy: 0.5869 - val_loss: 0.7173 - val_accuracy: 0.5376
#
# Epoch 00239: val_loss did not improve from 0.58703
# Epoch 240/1000
#  - 31s - loss: 0.6697 - accuracy: 0.5880 - val_loss: 0.6971 - val_accuracy: 0.5477
#
# Epoch 00240: val_loss did not improve from 0.58703
# Epoch 241/1000
#  - 32s - loss: 0.6696 - accuracy: 0.5880 - val_loss: 0.6574 - val_accuracy: 0.5435
#
# Epoch 00241: val_loss did not improve from 0.58703
# Epoch 242/1000
#  - 32s - loss: 0.6693 - accuracy: 0.5888 - val_loss: 0.6446 - val_accuracy: 0.5544
#
# Epoch 00242: val_loss did not improve from 0.58703
# Epoch 243/1000
#  - 32s - loss: 0.6700 - accuracy: 0.5874 - val_loss: 0.7551 - val_accuracy: 0.5431
#
# Epoch 00243: val_loss did not improve from 0.58703
# Epoch 244/1000
#  - 32s - loss: 0.6697 - accuracy: 0.5874 - val_loss: 0.6653 - val_accuracy: 0.5414
#
# Epoch 00244: val_loss did not improve from 0.58703
# Epoch 245/1000
#  - 32s - loss: 0.6694 - accuracy: 0.5891 - val_loss: 0.6956 - val_accuracy: 0.5514
#
# Epoch 00245: val_loss did not improve from 0.58703
# Epoch 246/1000
#  - 32s - loss: 0.6695 - accuracy: 0.5881 - val_loss: 0.6190 - val_accuracy: 0.5475
#
# Epoch 00246: val_loss did not improve from 0.58703
# Epoch 247/1000
#  - 32s - loss: 0.6696 - accuracy: 0.5883 - val_loss: 0.6370 - val_accuracy: 0.5509
#
# Epoch 00247: val_loss did not improve from 0.58703
# Epoch 248/1000
#  - 32s - loss: 0.6688 - accuracy: 0.5898 - val_loss: 0.7232 - val_accuracy: 0.5410
#
# Epoch 00248: val_loss did not improve from 0.58703
# Epoch 249/1000
#  - 32s - loss: 0.6692 - accuracy: 0.5901 - val_loss: 0.6477 - val_accuracy: 0.5409
#
# Epoch 00249: val_loss did not improve from 0.58703
# Epoch 250/1000
#  - 31s - loss: 0.6693 - accuracy: 0.5872 - val_loss: 0.6845 - val_accuracy: 0.5423
#
# Epoch 00250: val_loss did not improve from 0.58703
# Epoch 251/1000
#  - 32s - loss: 0.6692 - accuracy: 0.5890 - val_loss: 0.7433 - val_accuracy: 0.5392
#
# Epoch 00251: val_loss did not improve from 0.58703
# Epoch 252/1000
#  - 31s - loss: 0.6686 - accuracy: 0.5904 - val_loss: 0.7004 - val_accuracy: 0.5503
#
# Epoch 00252: val_loss did not improve from 0.58703
# Epoch 253/1000
#  - 32s - loss: 0.6691 - accuracy: 0.5899 - val_loss: 0.6892 - val_accuracy: 0.5513
#
# Epoch 00253: val_loss did not improve from 0.58703
# Epoch 254/1000
#  - 31s - loss: 0.6690 - accuracy: 0.5901 - val_loss: 0.6872 - val_accuracy: 0.5454
#
# Epoch 00254: val_loss did not improve from 0.58703
# Epoch 255/1000
#  - 32s - loss: 0.6686 - accuracy: 0.5896 - val_loss: 0.7490 - val_accuracy: 0.5359
#
# Epoch 00255: val_loss did not improve from 0.58703
# Epoch 256/1000
#  - 31s - loss: 0.6686 - accuracy: 0.5907 - val_loss: 0.7167 - val_accuracy: 0.5491
#
# Epoch 00256: val_loss did not improve from 0.58703
# Epoch 257/1000
#  - 32s - loss: 0.6686 - accuracy: 0.5909 - val_loss: 0.6488 - val_accuracy: 0.5448
#
# Epoch 00257: val_loss did not improve from 0.58703
# Epoch 258/1000
#  - 32s - loss: 0.6690 - accuracy: 0.5899 - val_loss: 0.6743 - val_accuracy: 0.5442
#
# Epoch 00258: val_loss did not improve from 0.58703
# Epoch 259/1000
#  - 32s - loss: 0.6685 - accuracy: 0.5909 - val_loss: 0.6623 - val_accuracy: 0.5358
#
# Epoch 00259: val_loss did not improve from 0.58703
# Epoch 260/1000
#  - 32s - loss: 0.6688 - accuracy: 0.5890 - val_loss: 0.6331 - val_accuracy: 0.5452
#
# Epoch 00260: val_loss did not improve from 0.58703
# Epoch 261/1000
#  - 32s - loss: 0.6685 - accuracy: 0.5893 - val_loss: 0.7143 - val_accuracy: 0.5520
#
# Epoch 00261: val_loss did not improve from 0.58703
# Epoch 262/1000
#  - 32s - loss: 0.6683 - accuracy: 0.5906 - val_loss: 0.6568 - val_accuracy: 0.5441
#
# Epoch 00262: val_loss did not improve from 0.58703
# Epoch 263/1000
#  - 32s - loss: 0.6680 - accuracy: 0.5912 - val_loss: 0.6662 - val_accuracy: 0.5528
#
# Epoch 00263: val_loss did not improve from 0.58703
# Epoch 264/1000
#  - 32s - loss: 0.6683 - accuracy: 0.5908 - val_loss: 0.6694 - val_accuracy: 0.5423
#
# Epoch 00264: val_loss did not improve from 0.58703
# Epoch 265/1000
#  - 32s - loss: 0.6683 - accuracy: 0.5905 - val_loss: 0.7869 - val_accuracy: 0.5431
#
# Epoch 00265: val_loss did not improve from 0.58703
# Epoch 266/1000
#  - 32s - loss: 0.6679 - accuracy: 0.5910 - val_loss: 0.7272 - val_accuracy: 0.5386
#
# Epoch 00266: val_loss did not improve from 0.58703
# Epoch 267/1000
#  - 32s - loss: 0.6680 - accuracy: 0.5911 - val_loss: 0.6126 - val_accuracy: 0.5395
#
# Epoch 00267: val_loss did not improve from 0.58703
# Epoch 268/1000
#  - 32s - loss: 0.6678 - accuracy: 0.5909 - val_loss: 0.6727 - val_accuracy: 0.5430
#
# Epoch 00268: val_loss did not improve from 0.58703
# Epoch 269/1000
#  - 32s - loss: 0.6679 - accuracy: 0.5908 - val_loss: 0.6906 - val_accuracy: 0.5559
#
# Epoch 00269: val_loss did not improve from 0.58703
# Epoch 270/1000
#  - 32s - loss: 0.6678 - accuracy: 0.5921 - val_loss: 0.7267 - val_accuracy: 0.5454
#
# Epoch 00270: val_loss did not improve from 0.58703
# Epoch 271/1000
#  - 32s - loss: 0.6678 - accuracy: 0.5919 - val_loss: 0.7201 - val_accuracy: 0.5476
#
# Epoch 00271: val_loss did not improve from 0.58703
# Epoch 272/1000
#  - 32s - loss: 0.6677 - accuracy: 0.5927 - val_loss: 0.7146 - val_accuracy: 0.5389
#
# Epoch 00272: val_loss did not improve from 0.58703
# Epoch 273/1000
#  - 32s - loss: 0.6672 - accuracy: 0.5926 - val_loss: 0.6999 - val_accuracy: 0.5412
#
# Epoch 00273: val_loss did not improve from 0.58703
# Epoch 274/1000
#  - 32s - loss: 0.6678 - accuracy: 0.5924 - val_loss: 0.7573 - val_accuracy: 0.5444
#
# Epoch 00274: val_loss did not improve from 0.58703
# Epoch 275/1000
#  - 32s - loss: 0.6672 - accuracy: 0.5934 - val_loss: 0.6762 - val_accuracy: 0.5477
#
# Epoch 00275: val_loss did not improve from 0.58703
# Epoch 276/1000
#  - 32s - loss: 0.6673 - accuracy: 0.5925 - val_loss: 0.6985 - val_accuracy: 0.5481
#
# Epoch 00276: val_loss did not improve from 0.58703
# Epoch 277/1000
#  - 32s - loss: 0.6673 - accuracy: 0.5936 - val_loss: 0.7398 - val_accuracy: 0.5425
#
# Epoch 00277: val_loss did not improve from 0.58703
# Epoch 278/1000
#  - 32s - loss: 0.6675 - accuracy: 0.5925 - val_loss: 0.6234 - val_accuracy: 0.5432
#
# Epoch 00278: val_loss did not improve from 0.58703
# Epoch 279/1000
#  - 32s - loss: 0.6674 - accuracy: 0.5919 - val_loss: 0.6899 - val_accuracy: 0.5434
#
# Epoch 00279: val_loss did not improve from 0.58703
# Epoch 280/1000
#  - 32s - loss: 0.6672 - accuracy: 0.5913 - val_loss: 0.6800 - val_accuracy: 0.5486
#
# Epoch 00280: val_loss did not improve from 0.58703
# Epoch 281/1000
#  - 32s - loss: 0.6672 - accuracy: 0.5922 - val_loss: 0.7165 - val_accuracy: 0.5509
#
# Epoch 00281: val_loss did not improve from 0.58703
# Epoch 282/1000
#  - 32s - loss: 0.6673 - accuracy: 0.5914 - val_loss: 0.6962 - val_accuracy: 0.5415
#
# Epoch 00282: val_loss did not improve from 0.58703
# Epoch 283/1000
#  - 32s - loss: 0.6672 - accuracy: 0.5914 - val_loss: 0.7174 - val_accuracy: 0.5451
#
# Epoch 00283: val_loss did not improve from 0.58703
# Epoch 284/1000
#  - 32s - loss: 0.6670 - accuracy: 0.5925 - val_loss: 0.6732 - val_accuracy: 0.5426
#
# Epoch 00284: val_loss did not improve from 0.58703
# Epoch 285/1000
#  - 32s - loss: 0.6668 - accuracy: 0.5944 - val_loss: 0.6957 - val_accuracy: 0.5432
#
# Epoch 00285: val_loss did not improve from 0.58703
# Epoch 286/1000
#  - 32s - loss: 0.6667 - accuracy: 0.5939 - val_loss: 0.6655 - val_accuracy: 0.5430
#
# Epoch 00286: val_loss did not improve from 0.58703
# Epoch 287/1000
#  - 32s - loss: 0.6671 - accuracy: 0.5919 - val_loss: 0.6991 - val_accuracy: 0.5392
#
# Epoch 00287: val_loss did not improve from 0.58703
# Epoch 288/1000
#  - 32s - loss: 0.6666 - accuracy: 0.5921 - val_loss: 0.6866 - val_accuracy: 0.5393
#
# Epoch 00288: val_loss did not improve from 0.58703
# Epoch 289/1000
#  - 32s - loss: 0.6670 - accuracy: 0.5930 - val_loss: 0.7318 - val_accuracy: 0.5509
#
# Epoch 00289: val_loss did not improve from 0.58703
# Epoch 290/1000
#  - 31s - loss: 0.6666 - accuracy: 0.5926 - val_loss: 0.7378 - val_accuracy: 0.5522
#
# Epoch 00290: val_loss did not improve from 0.58703
# Epoch 291/1000
#  - 32s - loss: 0.6666 - accuracy: 0.5932 - val_loss: 0.6338 - val_accuracy: 0.5373
#
# Epoch 00291: val_loss did not improve from 0.58703
# Epoch 292/1000
#  - 32s - loss: 0.6664 - accuracy: 0.5935 - val_loss: 0.6711 - val_accuracy: 0.5326
#
# Epoch 00292: val_loss did not improve from 0.58703
# Epoch 293/1000
#  - 32s - loss: 0.6662 - accuracy: 0.5945 - val_loss: 0.7638 - val_accuracy: 0.5452
#
# Epoch 00293: val_loss did not improve from 0.58703
# Epoch 294/1000
#  - 32s - loss: 0.6662 - accuracy: 0.5944 - val_loss: 0.7164 - val_accuracy: 0.5448
#
# Epoch 00294: val_loss did not improve from 0.58703
# Epoch 295/1000
#  - 32s - loss: 0.6662 - accuracy: 0.5944 - val_loss: 0.6735 - val_accuracy: 0.5444
#
# Epoch 00295: val_loss did not improve from 0.58703
# Epoch 296/1000
#  - 32s - loss: 0.6664 - accuracy: 0.5948 - val_loss: 0.6422 - val_accuracy: 0.5482
#
# Epoch 00296: val_loss did not improve from 0.58703
# Epoch 297/1000
#  - 32s - loss: 0.6661 - accuracy: 0.5940 - val_loss: 0.6993 - val_accuracy: 0.5381
#
# Epoch 00297: val_loss did not improve from 0.58703
# Epoch 298/1000
#  - 32s - loss: 0.6657 - accuracy: 0.5943 - val_loss: 0.6450 - val_accuracy: 0.5382
#
# Epoch 00298: val_loss did not improve from 0.58703
# Epoch 299/1000
#  - 32s - loss: 0.6662 - accuracy: 0.5943 - val_loss: 0.7528 - val_accuracy: 0.5367
#
# Epoch 00299: val_loss did not improve from 0.58703
# Epoch 300/1000
#  - 32s - loss: 0.6660 - accuracy: 0.5946 - val_loss: 0.7013 - val_accuracy: 0.5491
#
# Epoch 00300: val_loss did not improve from 0.58703
# Epoch 301/1000
#  - 32s - loss: 0.6659 - accuracy: 0.5946 - val_loss: 0.5955 - val_accuracy: 0.5587
#
# Epoch 00301: val_loss did not improve from 0.58703
# Epoch 302/1000
#  - 32s - loss: 0.6659 - accuracy: 0.5948 - val_loss: 0.6629 - val_accuracy: 0.5448
#
# Epoch 00302: val_loss did not improve from 0.58703
# Epoch 303/1000
#  - 32s - loss: 0.6656 - accuracy: 0.5947 - val_loss: 0.6820 - val_accuracy: 0.5454
#
# Epoch 00303: val_loss did not improve from 0.58703
# Epoch 304/1000
#  - 32s - loss: 0.6658 - accuracy: 0.5948 - val_loss: 0.6729 - val_accuracy: 0.5538
#
# Epoch 00304: val_loss did not improve from 0.58703
# Epoch 305/1000
#  - 32s - loss: 0.6658 - accuracy: 0.5945 - val_loss: 0.6257 - val_accuracy: 0.5424
#
# Epoch 00305: val_loss did not improve from 0.58703
# Epoch 306/1000
#  - 32s - loss: 0.6657 - accuracy: 0.5945 - val_loss: 0.7237 - val_accuracy: 0.5456
#
# Epoch 00306: val_loss did not improve from 0.58703
# Epoch 307/1000
#  - 32s - loss: 0.6656 - accuracy: 0.5934 - val_loss: 0.7710 - val_accuracy: 0.5491
#
# Epoch 00307: val_loss did not improve from 0.58703
# Epoch 308/1000
#  - 32s - loss: 0.6653 - accuracy: 0.5958 - val_loss: 0.7026 - val_accuracy: 0.5485
#
# Epoch 00308: val_loss did not improve from 0.58703
# Epoch 309/1000
#  - 32s - loss: 0.6653 - accuracy: 0.5951 - val_loss: 0.6989 - val_accuracy: 0.5416
#
# Epoch 00309: val_loss did not improve from 0.58703
# ...
#  - 32s - loss: 0.6376 - accuracy: 0.6310 - val_loss: 0.6412 - val_accuracy: 0.5439
#
# Epoch 00895: val_loss did not improve from 0.56375
# Epoch 896/1000
#  - 32s - loss: 0.6379 - accuracy: 0.6322 - val_loss: 0.6192 - val_accuracy: 0.5429
#
# Epoch 00896: val_loss did not improve from 0.56375
# Epoch 897/1000
#  - 32s - loss: 0.6370 - accuracy: 0.6335 - val_loss: 0.7651 - val_accuracy: 0.5493
#
# Epoch 00897: val_loss did not improve from 0.56375
# Epoch 898/1000
#  - 32s - loss: 0.6369 - accuracy: 0.6322 - val_loss: 0.7213 - val_accuracy: 0.5394
#
# Epoch 00898: val_loss did not improve from 0.56375
# Epoch 899/1000
#  - 32s - loss: 0.6372 - accuracy: 0.6337 - val_loss: 0.7117 - val_accuracy: 0.5347
#
# Epoch 00899: val_loss did not improve from 0.56375
# Epoch 900/1000
#  - 32s - loss: 0.6371 - accuracy: 0.6328 - val_loss: 0.7622 - val_accuracy: 0.5414
#
# Epoch 00900: val_loss did not improve from 0.56375
# Epoch 901/1000
#  - 32s - loss: 0.6370 - accuracy: 0.6344 - val_loss: 0.8084 - val_accuracy: 0.5440
#
# Epoch 00901: val_loss did not improve from 0.56375
# Epoch 902/1000
#  - 32s - loss: 0.6375 - accuracy: 0.6324 - val_loss: 0.7106 - val_accuracy: 0.5354
#
# Epoch 00902: val_loss did not improve from 0.56375
# Epoch 903/1000
#  - 32s - loss: 0.6370 - accuracy: 0.6337 - val_loss: 0.7887 - val_accuracy: 0.5358
#
# Epoch 00903: val_loss did not improve from 0.56375
# Epoch 904/1000
#  - 32s - loss: 0.6370 - accuracy: 0.6327 - val_loss: 0.7246 - val_accuracy: 0.5411
#
# Epoch 00904: val_loss did not improve from 0.56375
# Epoch 905/1000
#  - 32s - loss: 0.6371 - accuracy: 0.6320 - val_loss: 0.6206 - val_accuracy: 0.5369
#
# Epoch 00905: val_loss did not improve from 0.56375
# Epoch 906/1000
#  - 32s - loss: 0.6371 - accuracy: 0.6328 - val_loss: 0.6077 - val_accuracy: 0.5465
#
# Epoch 00906: val_loss did not improve from 0.56375
# Epoch 907/1000
#  - 32s - loss: 0.6373 - accuracy: 0.6319 - val_loss: 0.7759 - val_accuracy: 0.5482
#
# Epoch 00907: val_loss did not improve from 0.56375
# Epoch 908/1000
#  - 32s - loss: 0.6370 - accuracy: 0.6320 - val_loss: 0.7142 - val_accuracy: 0.5337
#
# Epoch 00908: val_loss did not improve from 0.56375
# Epoch 909/1000
#  - 32s - loss: 0.6366 - accuracy: 0.6337 - val_loss: 0.6409 - val_accuracy: 0.5350
#
# Epoch 00909: val_loss did not improve from 0.56375
# Epoch 910/1000
#  - 32s - loss: 0.6366 - accuracy: 0.6327 - val_loss: 0.7688 - val_accuracy: 0.5413
#
# Epoch 00910: val_loss did not improve from 0.56375
# Epoch 911/1000
#  - 32s - loss: 0.6362 - accuracy: 0.6342 - val_loss: 0.6593 - val_accuracy: 0.5329
#
# Epoch 00911: val_loss did not improve from 0.56375
# Epoch 912/1000
#  - 32s - loss: 0.6369 - accuracy: 0.6326 - val_loss: 0.7057 - val_accuracy: 0.5386
#
# Epoch 00912: val_loss did not improve from 0.56375
# Epoch 913/1000
#  - 31s - loss: 0.6364 - accuracy: 0.6347 - val_loss: 0.6670 - val_accuracy: 0.5380
#
# Epoch 00913: val_loss did not improve from 0.56375
# Epoch 914/1000
#  - 32s - loss: 0.6365 - accuracy: 0.6321 - val_loss: 0.7958 - val_accuracy: 0.5422
#
# Epoch 00914: val_loss did not improve from 0.56375
# Epoch 915/1000
#  - 32s - loss: 0.6366 - accuracy: 0.6332 - val_loss: 0.7714 - val_accuracy: 0.5400
#
# Epoch 00915: val_loss did not improve from 0.56375
# Epoch 916/1000
#  - 32s - loss: 0.6365 - accuracy: 0.6332 - val_loss: 0.8016 - val_accuracy: 0.5415
#
# Epoch 00916: val_loss did not improve from 0.56375
# Epoch 917/1000
#  - 32s - loss: 0.6370 - accuracy: 0.6333 - val_loss: 0.7339 - val_accuracy: 0.5399
#
# Epoch 00917: val_loss did not improve from 0.56375
# Epoch 918/1000
#  - 32s - loss: 0.6365 - accuracy: 0.6334 - val_loss: 0.5492 - val_accuracy: 0.5390
#
# Epoch 00918: val_loss improved from 0.56375 to 0.54923, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_5_close_updown_pr.h5
# Epoch 919/1000
#  - 32s - loss: 0.6370 - accuracy: 0.6330 - val_loss: 0.5965 - val_accuracy: 0.5393
#
# Epoch 00919: val_loss did not improve from 0.54923
# Epoch 920/1000
#  - 32s - loss: 0.6362 - accuracy: 0.6342 - val_loss: 0.7737 - val_accuracy: 0.5351
#
# Epoch 00920: val_loss did not improve from 0.54923
# Epoch 921/1000
#  - 32s - loss: 0.6365 - accuracy: 0.6331 - val_loss: 0.7014 - val_accuracy: 0.5317
#
# Epoch 00921: val_loss did not improve from 0.54923
# Epoch 922/1000
#  - 32s - loss: 0.6363 - accuracy: 0.6367 - val_loss: 0.6745 - val_accuracy: 0.5356
#
# Epoch 00922: val_loss did not improve from 0.54923
# Epoch 923/1000
#  - 32s - loss: 0.6367 - accuracy: 0.6336 - val_loss: 0.6000 - val_accuracy: 0.5390
#
# Epoch 00923: val_loss did not improve from 0.54923
# Epoch 924/1000
#  - 32s - loss: 0.6360 - accuracy: 0.6335 - val_loss: 0.8011 - val_accuracy: 0.5328
#
# Epoch 00924: val_loss did not improve from 0.54923
# Epoch 925/1000
#  - 32s - loss: 0.6363 - accuracy: 0.6332 - val_loss: 0.6995 - val_accuracy: 0.5454
#
# Epoch 00925: val_loss did not improve from 0.54923
# Epoch 926/1000
#  - 32s - loss: 0.6358 - accuracy: 0.6336 - val_loss: 0.6826 - val_accuracy: 0.5449
#
# Epoch 00926: val_loss did not improve from 0.54923
# Epoch 927/1000
#  - 32s - loss: 0.6355 - accuracy: 0.6346 - val_loss: 0.7098 - val_accuracy: 0.5467
#
# Epoch 00927: val_loss did not improve from 0.54923
# Epoch 928/1000
#  - 32s - loss: 0.6357 - accuracy: 0.6344 - val_loss: 0.7998 - val_accuracy: 0.5451
#
# Epoch 00928: val_loss did not improve from 0.54923
# Epoch 929/1000
#  - 32s - loss: 0.6355 - accuracy: 0.6346 - val_loss: 0.6647 - val_accuracy: 0.5374
#
# Epoch 00929: val_loss did not improve from 0.54923
# Epoch 930/1000
#  - 32s - loss: 0.6368 - accuracy: 0.6335 - val_loss: 0.6314 - val_accuracy: 0.5444
#
# Epoch 00930: val_loss did not improve from 0.54923
# Epoch 931/1000
#  - 32s - loss: 0.6361 - accuracy: 0.6339 - val_loss: 0.6617 - val_accuracy: 0.5410
#
# Epoch 00931: val_loss did not improve from 0.54923
# Epoch 932/1000
#  - 32s - loss: 0.6359 - accuracy: 0.6342 - val_loss: 0.8088 - val_accuracy: 0.5473
#
# Epoch 00932: val_loss did not improve from 0.54923
# Epoch 933/1000
#  - 32s - loss: 0.6355 - accuracy: 0.6344 - val_loss: 0.7324 - val_accuracy: 0.5427
#
# Epoch 00933: val_loss did not improve from 0.54923
# Epoch 934/1000
#  - 32s - loss: 0.6353 - accuracy: 0.6345 - val_loss: 0.6942 - val_accuracy: 0.5481
#
# Epoch 00934: val_loss did not improve from 0.54923
# Epoch 935/1000
#  - 32s - loss: 0.6353 - accuracy: 0.6355 - val_loss: 0.7538 - val_accuracy: 0.5429
#
# Epoch 00935: val_loss did not improve from 0.54923
# Epoch 936/1000
#  - 32s - loss: 0.6356 - accuracy: 0.6348 - val_loss: 0.8655 - val_accuracy: 0.5479
#
# Epoch 00936: val_loss did not improve from 0.54923
# Epoch 937/1000
#  - 32s - loss: 0.6350 - accuracy: 0.6364 - val_loss: 0.7980 - val_accuracy: 0.5334
#
# Epoch 00937: val_loss did not improve from 0.54923
# Epoch 938/1000
#  - 32s - loss: 0.6358 - accuracy: 0.6339 - val_loss: 0.7471 - val_accuracy: 0.5397
#
# Epoch 00938: val_loss did not improve from 0.54923
# Epoch 939/1000
#  - 32s - loss: 0.6349 - accuracy: 0.6348 - val_loss: 0.8003 - val_accuracy: 0.5405
#
# Epoch 00939: val_loss did not improve from 0.54923
# Epoch 940/1000
#  - 32s - loss: 0.6341 - accuracy: 0.6359 - val_loss: 0.7553 - val_accuracy: 0.5510
#
# Epoch 00940: val_loss did not improve from 0.54923
# Epoch 941/1000
#  - 32s - loss: 0.6349 - accuracy: 0.6354 - val_loss: 0.7462 - val_accuracy: 0.5383
#
# Epoch 00941: val_loss did not improve from 0.54923
# Epoch 942/1000
#  - 32s - loss: 0.6348 - accuracy: 0.6354 - val_loss: 0.6612 - val_accuracy: 0.5495
#
# Epoch 00942: val_loss did not improve from 0.54923
# Epoch 943/1000
#  - 32s - loss: 0.6356 - accuracy: 0.6340 - val_loss: 0.7663 - val_accuracy: 0.5492
#
# Epoch 00943: val_loss did not improve from 0.54923
# Epoch 944/1000
#  - 32s - loss: 0.6348 - accuracy: 0.6358 - val_loss: 0.7419 - val_accuracy: 0.5424
#
# Epoch 00944: val_loss did not improve from 0.54923
# Epoch 945/1000
#  - 32s - loss: 0.6352 - accuracy: 0.6347 - val_loss: 0.7049 - val_accuracy: 0.5375
#
# Epoch 00945: val_loss did not improve from 0.54923
# Epoch 946/1000
#  - 32s - loss: 0.6356 - accuracy: 0.6351 - val_loss: 0.7272 - val_accuracy: 0.5425
#
# Epoch 00946: val_loss did not improve from 0.54923
# Epoch 947/1000
#  - 32s - loss: 0.6348 - accuracy: 0.6351 - val_loss: 0.7839 - val_accuracy: 0.5435
#
# Epoch 00947: val_loss did not improve from 0.54923
# Epoch 948/1000
#  - 32s - loss: 0.6349 - accuracy: 0.6365 - val_loss: 0.7421 - val_accuracy: 0.5419
#
# Epoch 00948: val_loss did not improve from 0.54923
# Epoch 949/1000
#  - 32s - loss: 0.6348 - accuracy: 0.6358 - val_loss: 0.7201 - val_accuracy: 0.5385
#
# Epoch 00949: val_loss did not improve from 0.54923
# Epoch 950/1000
#  - 32s - loss: 0.6345 - accuracy: 0.6356 - val_loss: 0.7819 - val_accuracy: 0.5402
#
# Epoch 00950: val_loss did not improve from 0.54923
# Epoch 951/1000
#  - 32s - loss: 0.6343 - accuracy: 0.6352 - val_loss: 0.7108 - val_accuracy: 0.5450
#
# Epoch 00951: val_loss did not improve from 0.54923
# Epoch 952/1000
#  - 32s - loss: 0.6349 - accuracy: 0.6351 - val_loss: 0.7934 - val_accuracy: 0.5435
#
# Epoch 00952: val_loss did not improve from 0.54923
# Epoch 953/1000
#  - 32s - loss: 0.6347 - accuracy: 0.6360 - val_loss: 0.6994 - val_accuracy: 0.5513
#
# Epoch 00953: val_loss did not improve from 0.54923
# Epoch 954/1000
#  - 32s - loss: 0.6352 - accuracy: 0.6353 - val_loss: 0.5680 - val_accuracy: 0.5444
#
# Epoch 00954: val_loss did not improve from 0.54923
# Epoch 955/1000
#  - 32s - loss: 0.6354 - accuracy: 0.6348 - val_loss: 0.7225 - val_accuracy: 0.5489
#
# Epoch 00955: val_loss did not improve from 0.54923
# Epoch 956/1000
#  - 32s - loss: 0.6353 - accuracy: 0.6350 - val_loss: 0.7476 - val_accuracy: 0.5433
#
# Epoch 00956: val_loss did not improve from 0.54923
# Epoch 957/1000
#  - 32s - loss: 0.6345 - accuracy: 0.6368 - val_loss: 0.7204 - val_accuracy: 0.5400
#
# Epoch 00957: val_loss did not improve from 0.54923
# Epoch 958/1000
#  - 32s - loss: 0.6345 - accuracy: 0.6354 - val_loss: 0.9075 - val_accuracy: 0.5502
#
# Epoch 00958: val_loss did not improve from 0.54923
# Epoch 959/1000
#  - 32s - loss: 0.6342 - accuracy: 0.6366 - val_loss: 0.6814 - val_accuracy: 0.5423
#
# Epoch 00959: val_loss did not improve from 0.54923
# Epoch 960/1000
#  - 32s - loss: 0.6349 - accuracy: 0.6358 - val_loss: 0.7318 - val_accuracy: 0.5425
#
# Epoch 00960: val_loss did not improve from 0.54923
# Epoch 961/1000
#  - 32s - loss: 0.6350 - accuracy: 0.6357 - val_loss: 0.7301 - val_accuracy: 0.5470
#
# Epoch 00961: val_loss did not improve from 0.54923
# Epoch 962/1000
#  - 32s - loss: 0.6351 - accuracy: 0.6346 - val_loss: 0.6776 - val_accuracy: 0.5311
#
# Epoch 00962: val_loss did not improve from 0.54923
# Epoch 963/1000
#  - 32s - loss: 0.6353 - accuracy: 0.6339 - val_loss: 0.7897 - val_accuracy: 0.5384
#
# Epoch 00963: val_loss did not improve from 0.54923
# Epoch 964/1000
#  - 32s - loss: 0.6348 - accuracy: 0.6353 - val_loss: 0.6927 - val_accuracy: 0.5414
#
# Epoch 00964: val_loss did not improve from 0.54923
# Epoch 965/1000
#  - 32s - loss: 0.6341 - accuracy: 0.6359 - val_loss: 0.9635 - val_accuracy: 0.5349
#
# Epoch 00965: val_loss did not improve from 0.54923
# Epoch 966/1000
#  - 32s - loss: 0.6346 - accuracy: 0.6359 - val_loss: 0.7160 - val_accuracy: 0.5521
#
# Epoch 00966: val_loss did not improve from 0.54923
# Epoch 967/1000
#  - 32s - loss: 0.6350 - accuracy: 0.6349 - val_loss: 0.6886 - val_accuracy: 0.5461
#
# Epoch 00967: val_loss did not improve from 0.54923
# Epoch 968/1000
#  - 32s - loss: 0.6340 - accuracy: 0.6366 - val_loss: 0.7167 - val_accuracy: 0.5373
#
# Epoch 00968: val_loss did not improve from 0.54923
# Epoch 969/1000
#  - 32s - loss: 0.6341 - accuracy: 0.6353 - val_loss: 0.5935 - val_accuracy: 0.5476
#
# Epoch 00969: val_loss did not improve from 0.54923
# Epoch 970/1000
#  - 32s - loss: 0.6342 - accuracy: 0.6370 - val_loss: 0.7614 - val_accuracy: 0.5458
#
# Epoch 00970: val_loss did not improve from 0.54923
# Epoch 971/1000
#  - 32s - loss: 0.6348 - accuracy: 0.6355 - val_loss: 0.7164 - val_accuracy: 0.5355
#
# Epoch 00971: val_loss did not improve from 0.54923
# Epoch 972/1000
#  - 32s - loss: 0.6339 - accuracy: 0.6379 - val_loss: 0.8671 - val_accuracy: 0.5400
#
# Epoch 00972: val_loss did not improve from 0.54923
# Epoch 973/1000
#  - 32s - loss: 0.6346 - accuracy: 0.6352 - val_loss: 0.5907 - val_accuracy: 0.5417
#
# Epoch 00973: val_loss did not improve from 0.54923
# Epoch 974/1000
#  - 32s - loss: 0.6343 - accuracy: 0.6371 - val_loss: 0.6711 - val_accuracy: 0.5373
#
# Epoch 00974: val_loss did not improve from 0.54923
# Epoch 975/1000
#  - 32s - loss: 0.6343 - accuracy: 0.6361 - val_loss: 0.6808 - val_accuracy: 0.5427
#
# Epoch 00975: val_loss did not improve from 0.54923
# Epoch 976/1000
#  - 32s - loss: 0.6348 - accuracy: 0.6352 - val_loss: 0.7749 - val_accuracy: 0.5402
#
# Epoch 00976: val_loss did not improve from 0.54923
# Epoch 977/1000
#  - 32s - loss: 0.6343 - accuracy: 0.6351 - val_loss: 0.7521 - val_accuracy: 0.5394
#
# Epoch 00977: val_loss did not improve from 0.54923
# Epoch 978/1000
#  - 32s - loss: 0.6338 - accuracy: 0.6360 - val_loss: 0.7299 - val_accuracy: 0.5443
#
# Epoch 00978: val_loss did not improve from 0.54923
# Epoch 979/1000
#  - 32s - loss: 0.6342 - accuracy: 0.6363 - val_loss: 0.7406 - val_accuracy: 0.5348
#
# Epoch 00979: val_loss did not improve from 0.54923
# Epoch 980/1000
#  - 32s - loss: 0.6339 - accuracy: 0.6362 - val_loss: 0.8785 - val_accuracy: 0.5390
#
# Epoch 00980: val_loss did not improve from 0.54923
# Epoch 981/1000
#  - 32s - loss: 0.6336 - accuracy: 0.6360 - val_loss: 0.7785 - val_accuracy: 0.5416
#
# Epoch 00981: val_loss did not improve from 0.54923
# Epoch 982/1000
#  - 32s - loss: 0.6333 - accuracy: 0.6380 - val_loss: 0.6912 - val_accuracy: 0.5411
#
# Epoch 00982: val_loss did not improve from 0.54923
# Epoch 983/1000
#  - 32s - loss: 0.6337 - accuracy: 0.6361 - val_loss: 0.7134 - val_accuracy: 0.5424
#
# Epoch 00983: val_loss did not improve from 0.54923
# Epoch 984/1000
#  - 32s - loss: 0.6340 - accuracy: 0.6365 - val_loss: 0.6356 - val_accuracy: 0.5436
#
# Epoch 00984: val_loss did not improve from 0.54923
# Epoch 985/1000
#  - 32s - loss: 0.6340 - accuracy: 0.6364 - val_loss: 0.6455 - val_accuracy: 0.5386
#
# Epoch 00985: val_loss did not improve from 0.54923
# Epoch 986/1000
#  - 32s - loss: 0.6338 - accuracy: 0.6354 - val_loss: 0.7984 - val_accuracy: 0.5416
#
# Epoch 00986: val_loss did not improve from 0.54923
# Epoch 987/1000
#  - 32s - loss: 0.6347 - accuracy: 0.6356 - val_loss: 0.7760 - val_accuracy: 0.5402
#
# Epoch 00987: val_loss did not improve from 0.54923
# Epoch 988/1000
#  - 32s - loss: 0.6332 - accuracy: 0.6376 - val_loss: 0.6124 - val_accuracy: 0.5461
#
# Epoch 00988: val_loss did not improve from 0.54923
# Epoch 989/1000
#  - 32s - loss: 0.6339 - accuracy: 0.6366 - val_loss: 0.7339 - val_accuracy: 0.5510
#
# Epoch 00989: val_loss did not improve from 0.54923
# Epoch 990/1000
#  - 32s - loss: 0.6340 - accuracy: 0.6367 - val_loss: 0.7494 - val_accuracy: 0.5464
#
# Epoch 00990: val_loss did not improve from 0.54923
# Epoch 991/1000
#  - 32s - loss: 0.6336 - accuracy: 0.6365 - val_loss: 0.6773 - val_accuracy: 0.5353
#
# Epoch 00991: val_loss did not improve from 0.54923
# Epoch 992/1000
#  - 32s - loss: 0.6327 - accuracy: 0.6381 - val_loss: 0.7320 - val_accuracy: 0.5419
#
# Epoch 00992: val_loss did not improve from 0.54923
# Epoch 993/1000
#  - 32s - loss: 0.6332 - accuracy: 0.6382 - val_loss: 0.7208 - val_accuracy: 0.5378
#
# Epoch 00993: val_loss did not improve from 0.54923
# Epoch 994/1000
#  - 32s - loss: 0.6324 - accuracy: 0.6379 - val_loss: 0.6497 - val_accuracy: 0.5466
#
# Epoch 00994: val_loss did not improve from 0.54923
# Epoch 995/1000
#  - 32s - loss: 0.6337 - accuracy: 0.6369 - val_loss: 0.7073 - val_accuracy: 0.5395
#
# Epoch 00995: val_loss did not improve from 0.54923
# Epoch 996/1000
#  - 32s - loss: 0.6337 - accuracy: 0.6363 - val_loss: 0.6830 - val_accuracy: 0.5381
#
# Epoch 00996: val_loss did not improve from 0.54923
# Epoch 997/1000
#  - 32s - loss: 0.6333 - accuracy: 0.6382 - val_loss: 0.6971 - val_accuracy: 0.5360
#
# Epoch 00997: val_loss did not improve from 0.54923
# Epoch 998/1000
#  - 32s - loss: 0.6332 - accuracy: 0.6375 - val_loss: 0.8285 - val_accuracy: 0.5394
#
# Epoch 00998: val_loss did not improve from 0.54923
# Epoch 999/1000
#  - 32s - loss: 0.6335 - accuracy: 0.6364 - val_loss: 0.6106 - val_accuracy: 0.5476
#
# Epoch 00999: val_loss did not improve from 0.54923
# Epoch 1000/1000
#  - 32s - loss: 0.6335 - accuracy: 0.6363 - val_loss: 0.8144 - val_accuracy: 0.5392
#
# Epoch 01000: val_loss did not improve from 0.54923

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_%s_close_updown_pr.h5' % period

model = keras.models.load_model(ckpt_path + model_name)

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)

# thresh = 0.19
# threshold = [thresh]
print('threshold :', threshold)
break

acc_pr_bythr = []
for thresh in threshold:

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  print('precision :', precision_score(y_test, y_pred))
  print('recall :', recall_score(y_test, y_pred))
  print()

  print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # plt.show()  
  print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
    print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
    print('thresh :', thresh)
    
  # if len(threshold) == 1:
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(test_pr_list))
    plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
  # plt.show()

    plt.subplot(122)
    plt.plot(np.cumprod(pred_pr_list))
    plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])

print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(threshold, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()
# Out:
# test_result.shape : (63006, 2)
# pr_val.shape : (63006, 1)
# y_test[:5] : [1 0 1 1 1]
# y_score[:5] : [[0.26928097]
#  [0.51422006]
#  [0.63943076]
#  [0.6102436 ]
#  [0.67291075]]
# y_test.shape : (63006, 1)
# y_score.shape : (63006, 1)
# len(y_test) : 63006
# threshold : [0.00823912 0.00836157 0.00939982 ... 0.9762955  0.9784837  0.9807241 ]
#   File "<ipython-input-11-76fcc560d050>", line 32
#     break
#          ^
# SyntaxError: 'break' outside loop

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
