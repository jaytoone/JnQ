# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
from sklearn.preprocessing import StandardScaler
from scipy.ndimage.filters import gaussian_filter1d
import warnings
# from scipy.ndimage.interpolation import shift

warnings.filterwarnings(action='ignore')
# %tensorflow_version 1.x
# %matplotlib inline


def min_max_scaler(x):
    scaled_x = (x - x.min()) / (x.max() - x.min())
    return scaled_x


def max_abs_scaler(x):
    scaled_x = x / abs(x).max()
    return scaled_x

  
def macd(df, short=12, long=26, signal=9):
    df['MACD'] = df['close'].ewm(span=short, min_periods=short - 1, adjust=False).mean() - \
                 df['close'].ewm(span=long, min_periods=long - 1, adjust=False).mean()
    df['MACD_Signal'] = df['MACD'].ewm(span=signal, min_periods=signal - 1, adjust=False).mean()
    df['MACD_OSC'] = df.MACD - df.MACD_Signal
    df['MACD_Zero'] = 0

    return

    
gdrive_path = '/content/gdrive/My Drive/Colab Notebooks/'

#           read reg ohlcv          #
file_path = gdrive_path + 'ohlcv/'
file_list = os.listdir(file_path)
# Out:
# TensorFlow 1.x selected.

# %%
input_data_length = 10
model_num = 108

short, long, signal = 105, 168, 32
sigma= 10
pull_range = 10
inverse = 0

# print(file_list)
# breakpoint

dataX, dataY = list(), list()
for i in range(len(file_list)):

  if i > 3:
    break

  file = file_list[i]
  print(file)

# file = file_list[3]
# print(file)
# breakpoint

  ohlcv_reg = pd.read_excel(file_path + file, index_col=0)
  macd(ohlcv_reg, short=short, long=long, signal=signal)
  # plt.plot(ohlcv_reg.iloc[:, [-2]])
  # macd(ohlcv_reg, short=150, long=300, signal=50)
  # plt.plot(ohlcv_reg.iloc[:, [-2]])
  # plt.show()
  # breakpoint

  ohlcv_reg['realtime_osc_reg'] = np.nan
  for i in range(input_data_length, len(ohlcv_reg)):
    y = ohlcv_reg.MACD_OSC.values[i + 1 - input_data_length:i + 1]
    y_smooth = gaussian_filter1d(y, sigma=sigma)

    ohlcv_reg['realtime_osc_reg'].iloc[i] = y_smooth[-1]

  ohlcv_reg['osc_reg'] = ohlcv_reg['realtime_osc_reg'].shift(-pull_range)
  # print(ohlcv_reg.iloc[:, -5:].head(15))
  # breakpoint

  #     X_data : idl 만큼의 close? (일단),    Y_data : reg
  #     실시간으로 reg의 형태가 machine learning으로는 고정되지 않기 때문에,
  #     먼저 고정을 시키고, deep learning을 이용해 실시간으로 고정된 regression 결과를 뽑아낼 수 있는지 확인한다.
  #     충분히 가능성 있다.     #

  #         reg_target = close인 경우 앞의 데이터가 산다.       #  close/ close_reg
  if pull_range != 0:
    ohlcv_reg = ohlcv_reg.values[sum(ohlcv_reg.osc_reg.isna())-pull_range:-pull_range, :] # 
  else:
    ohlcv_reg = ohlcv_reg.values[sum(ohlcv_reg.osc_reg.isna()):, :] # 

  reg_target = ohlcv_reg[:, [-2]].astype(np.float32)
  reg_result = ohlcv_reg[:, [-1]].astype(np.float32)
  # print(np.sum(np.isnan(reg_target)))
  # print(np.sum(np.isnan(reg_result)))
  # breakpoint
  # print(reg_target[-5:])
  # print(reg_result[-5:])
  plt.plot(reg_target, color='g')
  plt.plot(reg_result, color='r')
  plt.show()
  # breakpoint

  if len(reg_target) == 0:
    continue

  scaler_x = StandardScaler()
  scaler_y = StandardScaler()
  reg_target = scaler_x.fit_transform(reg_target)
  reg_result = scaler_y.fit_transform(reg_result)
  # reg_target = max_abs_scaler(reg_target)
  # reg_result = max_abs_scaler(reg_result)
  # print(reg_target, reg_result)
  # breakpoint

  # dataX, dataY = list(), list()
  for i in range(input_data_length, len(reg_target)):

    # group_x = reg_target[i - input_data_length: i]
    group_x = reg_target[i + 1 - input_data_length: i + 1]
    group_y = reg_result[i]
    # print(group_x[0])
    # quit()

    #   데이터 값에 결측치가 존재하는 경우 #
    if sum(sum(np.isnan(group_x))) > 0:
        continue

    if inverse == 1:
        dataX.append(group_x[::-1])  # dataX 리스트에 추가 [::-1]
    else:
        dataX.append(group_x)  # dataX 리스트에 추가 [::-1]
    dataY.append(group_y)

Made_X = np.array(dataX)
Made_Y = np.array(dataY)

# Made_X = np.array(reg_target)
# Made_Y = np.array(reg_result)
# print(Made_X.shape, Made_Y.shape)
# breakpoint  

# from sklearn.model_selection import train_test_split
# X_train, X_test, Y_train, Y_test = train_test_split(Made_X, Made_Y, test_size=0.4,
#                                                    shuffle=False)
# X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5,
#                                                    shuffle=False)

#     DATA CONTINOUS SPLIT    #
total_len = len(Made_X)
train_len = int(0.4 * total_len)
val_len = int(0.7 * total_len)

X_train = Made_X[:train_len]
X_val = Made_X[train_len:val_len]
X_test = Made_X[val_len:]
Y_train = Made_Y[:train_len]
Y_val = Made_Y[train_len:val_len]
Y_test = Made_Y[val_len:]
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)

print(Y_train.shape)
print(Y_test.shape)
print(Y_val.shape)
# breakpoint

row = X_train.shape[1]
col = X_train.shape[2]

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.layers import Dense, LSTM, Dropout, Input, Flatten
from keras.optimizers import Adam, SGD, RMSprop, Adagrad, Adadelta
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix
from keras.layers import Activation
from keras.utils.generic_utils import get_custom_objects
import tensorflow as tf

class Gelu(Activation):
    def __init__(self, activation, **kwargs):
        super(Gelu, self).__init__(activation, **kwargs)
        self.__name__='gelu'
        
def gelu(x):
    return 0.5 * x * (1 + tf.tanh(tf.sqrt(2 / np.pi) * (x + 0.044715 * tf.pow(x, 3))))

get_custom_objects().update({'gelu': Gelu(gelu)})


def FER_Model(input_shape=(row, col)):

    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    # net = layers.Dense(128)(visible)
    # # net = layers.LSTM(50, return_sequences=False)(net)
    # net = layers.Activation('gelu')(net)
    # # net = layers.LeakyReLU()(net)
    # net = layers.Dropout(0.3)(net)

    net = layers.Dense(64)(visible)
    # net = layers.LSTM(50, return_sequences=True)(visible)
    net = layers.Activation('gelu')(net)
    # net = layers.LeakyReLU()(net)
    net = layers.Dropout(0.3)(net)

    
    net = layers.Dense(32)(net)
    # net = layers.LSTM(50, return_sequences=True)(net)
    net = layers.Activation('gelu')(net)
    # net = layers.LeakyReLU()(net)
    net = layers.Dropout(0.3)(net)

  

    # net = layers.Dense(32)(net)
    # # net = layers.LSTM(64, return_sequences=False)(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.Dropout(0.2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.Activation('gelu')(net)

    net = layers.Dense(1)(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    model.summary()

    return model

model = FER_Model()
# from keras.models import load_model
# model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_ohlc.hdf5' % (input_data_length, model_num))

# opt = RMSprop(lr=0.05, rho=0.9,epsilon=1e-10)
opt = Adam(lr=0.0005, decay=1e-6)
# opt = Adadelta(lr=1., rho=0.95, epsilon=1e-13)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse'])
  
    
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath = gdrive_path + "model/rapid_ascending %s_%s_ohlc.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=30)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 500
history = model.fit(X_train, Y_train,
                    epochs=num_epochs,
                    batch_size=32,
                    validation_data=(X_val, Y_val),
                    verbose=2,
                    callbacks=callbacks_list,
                    shuffle=False,
                    )


#         RESULT COMPARING    #
pred_reg = model.predict(X_test)
Y_pred = Made_Y.copy()
Y_pred[val_len:] = pred_reg

# span_list = list()
# span_list_y = list()
# for i in range(val_len, len(Y_pred)):
#     if Y_pred[i - 1] < Y_pred[i]:
#       span_list.append((i, i + 1))
#     if Made_Y[i - 1] < Made_Y[i]:
#       span_list_y.append((i, i + 1))

plt.figure(figsize=(10, 7))
plt.subplot(311)
if inverse == 1:
    plt.plot(Made_X[:, [0]].reshape(-1, 1), color='g', label='origin_curve') #   if [::-1], [0]
else:
    plt.plot(Made_X[:, [-1]].reshape(-1, 1), color='g', label='origin_curve')
plt.plot(Made_Y, color='r', label='pulled_y')
plt.plot(Y_pred, color='b', label='pred')
plt.axvline(x=val_len)
# for i in range(len(span_list)):
#     plt.axvspan(span_list[i][0], span_list[i][1], facecolor='y', alpha=0.5)

# plt.title('Gaussian_PRED', color='white')
plt.legend(loc='upper right')

plt.subplot(312)
if inverse == 1:
    plt.plot(Made_X[:, [0]].reshape(-1, 1), color='g', label='origin_curve') #   if [::-1], [0]
else:
    plt.plot(Made_X[:, [-1]].reshape(-1, 1), color='g', label='origin_curve')
plt.plot(Made_Y, color='r', label='pulled_y')
plt.plot(Y_pred, color='b', label='pred')
# for i in range(len(span_list)):
    # plt.axvspan(span_list[i][0], span_list[i][1], facecolor='y', alpha=0.5)
# plt.xlim(val_len, len(Y_pred))
plt.xlim(len(Y_pred)-100, len(Y_pred))

# plt.subplot(313)
# plt.plot(Made_Y, color='r', label='osc')
# for i in range(len(span_list)):
#     plt.axvspan(span_list[i][0], span_list[i][1], facecolor='y', alpha=0.5)
# for i in range(len(span_list_y)):
#     plt.axvspan(span_list_y[i][0], span_list_y[i][1], facecolor='c', alpha=0.5)
# plt.xlim(val_len, len(Y_pred))

plt.show()
# Out:
# 2020-03-16 ELF ohlcv.xlsx
# 2020-03-16 CTXC ohlcv.xlsx
# 2020-03-16 DASH ohlcv.xlsx
# 2020-03-16 ENJ ohlcv.xlsx
# (652, 10, 1)
# (489, 10, 1)
# (489, 10, 1)
# (652, 1)
# (489, 1)
# (489, 1)
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 10, 1)             0
# _________________________________________________________________
# dense_25 (Dense)             (None, 10, 64)            128
# _________________________________________________________________
# activation_19 (Activation)   (None, 10, 64)            0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 10, 64)            0
# _________________________________________________________________
# dense_26 (Dense)             (None, 10, 32)            2080
# _________________________________________________________________
# activation_20 (Activation)   (None, 10, 32)            0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 10, 32)            0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 320)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 64)                20544
# _________________________________________________________________
# activation_21 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 22,817
# Trainable params: 22,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 652 samples, validate on 489 samples
# Epoch 1/500
#  - 1s - loss: 0.9110 - mse: 0.9110 - val_loss: 0.1320 - val_mse: 0.1320
#
# Epoch 00001: val_loss improved from inf to 0.13199, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 2/500
#  - 0s - loss: 0.4712 - mse: 0.4712 - val_loss: 0.0915 - val_mse: 0.0915
#
# Epoch 00002: val_loss improved from 0.13199 to 0.09147, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 3/500
#  - 0s - loss: 0.4006 - mse: 0.4006 - val_loss: 0.0872 - val_mse: 0.0872
#
# Epoch 00003: val_loss improved from 0.09147 to 0.08716, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 4/500
#  - 0s - loss: 0.3829 - mse: 0.3829 - val_loss: 0.0848 - val_mse: 0.0848
#
# Epoch 00004: val_loss improved from 0.08716 to 0.08478, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 5/500
#  - 0s - loss: 0.3731 - mse: 0.3731 - val_loss: 0.0821 - val_mse: 0.0821
#
# Epoch 00005: val_loss improved from 0.08478 to 0.08213, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 6/500
#  - 0s - loss: 0.3573 - mse: 0.3573 - val_loss: 0.0792 - val_mse: 0.0792
#
# Epoch 00006: val_loss improved from 0.08213 to 0.07918, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 7/500
#  - 0s - loss: 0.3557 - mse: 0.3557 - val_loss: 0.0770 - val_mse: 0.0770
#
# Epoch 00007: val_loss improved from 0.07918 to 0.07699, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 8/500
#  - 0s - loss: 0.3420 - mse: 0.3420 - val_loss: 0.0747 - val_mse: 0.0747
#
# Epoch 00008: val_loss improved from 0.07699 to 0.07469, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 9/500
#  - 0s - loss: 0.3167 - mse: 0.3167 - val_loss: 0.0720 - val_mse: 0.0720
#
# Epoch 00009: val_loss improved from 0.07469 to 0.07200, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 10/500
#  - 0s - loss: 0.3114 - mse: 0.3114 - val_loss: 0.0698 - val_mse: 0.0698
#
# Epoch 00010: val_loss improved from 0.07200 to 0.06981, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 11/500
#  - 0s - loss: 0.2894 - mse: 0.2894 - val_loss: 0.0671 - val_mse: 0.0671
#
# Epoch 00011: val_loss improved from 0.06981 to 0.06707, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 12/500
#  - 0s - loss: 0.2802 - mse: 0.2802 - val_loss: 0.0649 - val_mse: 0.0649
#
# Epoch 00012: val_loss improved from 0.06707 to 0.06488, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 13/500
#  - 0s - loss: 0.2662 - mse: 0.2662 - val_loss: 0.0626 - val_mse: 0.0626
#
# Epoch 00013: val_loss improved from 0.06488 to 0.06260, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 14/500
#  - 0s - loss: 0.2384 - mse: 0.2384 - val_loss: 0.0606 - val_mse: 0.0606
#
# Epoch 00014: val_loss improved from 0.06260 to 0.06060, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 15/500
#  - 0s - loss: 0.2360 - mse: 0.2360 - val_loss: 0.0583 - val_mse: 0.0583
#
# Epoch 00015: val_loss improved from 0.06060 to 0.05832, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 16/500
#  - 0s - loss: 0.2317 - mse: 0.2317 - val_loss: 0.0575 - val_mse: 0.0575
#
# Epoch 00016: val_loss improved from 0.05832 to 0.05748, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 17/500
#  - 0s - loss: 0.2462 - mse: 0.2462 - val_loss: 0.0557 - val_mse: 0.0557
#
# Epoch 00017: val_loss improved from 0.05748 to 0.05574, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 18/500
#  - 0s - loss: 0.2956 - mse: 0.2956 - val_loss: 0.0564 - val_mse: 0.0564
#
# Epoch 00018: val_loss did not improve from 0.05574
# Epoch 19/500
#  - 0s - loss: 0.2409 - mse: 0.2409 - val_loss: 0.0558 - val_mse: 0.0558
#
# Epoch 00019: val_loss did not improve from 0.05574
# Epoch 20/500
#  - 0s - loss: 0.2629 - mse: 0.2629 - val_loss: 0.0569 - val_mse: 0.0569
#
# Epoch 00020: val_loss did not improve from 0.05574
# Epoch 21/500
#  - 0s - loss: 0.2182 - mse: 0.2182 - val_loss: 0.0546 - val_mse: 0.0546
#
# Epoch 00021: val_loss improved from 0.05574 to 0.05457, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 22/500
#  - 0s - loss: 0.2032 - mse: 0.2032 - val_loss: 0.0535 - val_mse: 0.0535
#
# Epoch 00022: val_loss improved from 0.05457 to 0.05349, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 23/500
#  - 0s - loss: 0.1991 - mse: 0.1991 - val_loss: 0.0521 - val_mse: 0.0521
#
# Epoch 00023: val_loss improved from 0.05349 to 0.05208, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 24/500
#  - 0s - loss: 0.2227 - mse: 0.2227 - val_loss: 0.0523 - val_mse: 0.0523
#
# Epoch 00024: val_loss did not improve from 0.05208
# Epoch 25/500
#  - 0s - loss: 0.1991 - mse: 0.1991 - val_loss: 0.0511 - val_mse: 0.0511
#
# Epoch 00025: val_loss improved from 0.05208 to 0.05109, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 26/500
#  - 0s - loss: 0.2121 - mse: 0.2121 - val_loss: 0.0530 - val_mse: 0.0530
#
# Epoch 00026: val_loss did not improve from 0.05109
# Epoch 27/500
#  - 0s - loss: 0.2039 - mse: 0.2039 - val_loss: 0.0507 - val_mse: 0.0507
#
# Epoch 00027: val_loss improved from 0.05109 to 0.05071, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 28/500
#  - 0s - loss: 0.1913 - mse: 0.1913 - val_loss: 0.0518 - val_mse: 0.0518
#
# Epoch 00028: val_loss did not improve from 0.05071
# Epoch 29/500
#  - 0s - loss: 0.1825 - mse: 0.1825 - val_loss: 0.0515 - val_mse: 0.0515
#
# Epoch 00029: val_loss did not improve from 0.05071
# Epoch 30/500
#  - 0s - loss: 0.2126 - mse: 0.2126 - val_loss: 0.0504 - val_mse: 0.0504
#
# Epoch 00030: val_loss improved from 0.05071 to 0.05037, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 31/500
#  - 0s - loss: 0.1811 - mse: 0.1811 - val_loss: 0.0504 - val_mse: 0.0504
#
# Epoch 00031: val_loss did not improve from 0.05037
# Epoch 32/500
#  - 0s - loss: 0.1731 - mse: 0.1731 - val_loss: 0.0507 - val_mse: 0.0507
#
# Epoch 00032: val_loss did not improve from 0.05037
# Epoch 33/500
#  - 0s - loss: 0.2110 - mse: 0.2110 - val_loss: 0.0503 - val_mse: 0.0503
#
# Epoch 00033: val_loss improved from 0.05037 to 0.05031, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 34/500
#  - 0s - loss: 0.1762 - mse: 0.1762 - val_loss: 0.0497 - val_mse: 0.0497
#
# Epoch 00034: val_loss improved from 0.05031 to 0.04974, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 35/500
#  - 0s - loss: 0.2187 - mse: 0.2187 - val_loss: 0.0509 - val_mse: 0.0509
#
# Epoch 00035: val_loss did not improve from 0.04974
# Epoch 36/500
#  - 0s - loss: 0.1818 - mse: 0.1818 - val_loss: 0.0501 - val_mse: 0.0501
#
# Epoch 00036: val_loss did not improve from 0.04974
# Epoch 37/500
#  - 0s - loss: 0.1889 - mse: 0.1889 - val_loss: 0.0499 - val_mse: 0.0499
#
# Epoch 00037: val_loss did not improve from 0.04974
# Epoch 38/500
#  - 0s - loss: 0.1998 - mse: 0.1998 - val_loss: 0.0506 - val_mse: 0.0506
#
# Epoch 00038: val_loss did not improve from 0.04974
# Epoch 39/500
#  - 0s - loss: 0.2074 - mse: 0.2074 - val_loss: 0.0508 - val_mse: 0.0508
#
# Epoch 00039: val_loss did not improve from 0.04974
# Epoch 40/500
#  - 0s - loss: 0.1833 - mse: 0.1833 - val_loss: 0.0494 - val_mse: 0.0494
#
# Epoch 00040: val_loss improved from 0.04974 to 0.04938, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 41/500
#  - 0s - loss: 0.1743 - mse: 0.1743 - val_loss: 0.0503 - val_mse: 0.0503
#
# Epoch 00041: val_loss did not improve from 0.04938
# Epoch 42/500
#  - 0s - loss: 0.1921 - mse: 0.1921 - val_loss: 0.0510 - val_mse: 0.0510
#
# Epoch 00042: val_loss did not improve from 0.04938
# Epoch 43/500
#  - 0s - loss: 0.1977 - mse: 0.1977 - val_loss: 0.0510 - val_mse: 0.0510
#
# Epoch 00043: val_loss did not improve from 0.04938
# Epoch 44/500
#  - 0s - loss: 0.1855 - mse: 0.1855 - val_loss: 0.0505 - val_mse: 0.0505
#
# Epoch 00044: val_loss did not improve from 0.04938
# Epoch 45/500
#  - 0s - loss: 0.1891 - mse: 0.1891 - val_loss: 0.0507 - val_mse: 0.0507
#
# Epoch 00045: val_loss did not improve from 0.04938
# Epoch 46/500
#  - 0s - loss: 0.1844 - mse: 0.1844 - val_loss: 0.0495 - val_mse: 0.0495
#
# Epoch 00046: val_loss did not improve from 0.04938
# Epoch 47/500
#  - 0s - loss: 0.1960 - mse: 0.1960 - val_loss: 0.0507 - val_mse: 0.0507
#
# Epoch 00047: val_loss did not improve from 0.04938
# Epoch 48/500
#  - 0s - loss: 0.1713 - mse: 0.1713 - val_loss: 0.0491 - val_mse: 0.0491
#
# Epoch 00048: val_loss improved from 0.04938 to 0.04910, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 49/500
#  - 0s - loss: 0.1904 - mse: 0.1904 - val_loss: 0.0526 - val_mse: 0.0526
#
# Epoch 00049: val_loss did not improve from 0.04910
# Epoch 50/500
#  - 0s - loss: 0.1791 - mse: 0.1791 - val_loss: 0.0496 - val_mse: 0.0496
#
# Epoch 00050: val_loss did not improve from 0.04910
# Epoch 51/500
#  - 0s - loss: 0.1828 - mse: 0.1828 - val_loss: 0.0504 - val_mse: 0.0504
#
# Epoch 00051: val_loss did not improve from 0.04910
# Epoch 52/500
#  - 0s - loss: 0.1801 - mse: 0.1801 - val_loss: 0.0496 - val_mse: 0.0496
#
# Epoch 00052: val_loss did not improve from 0.04910
# Epoch 53/500
#  - 0s - loss: 0.1836 - mse: 0.1836 - val_loss: 0.0516 - val_mse: 0.0516
#
# Epoch 00053: val_loss did not improve from 0.04910
# Epoch 54/500
#  - 0s - loss: 0.1877 - mse: 0.1877 - val_loss: 0.0491 - val_mse: 0.0491
#
# Epoch 00054: val_loss improved from 0.04910 to 0.04907, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 55/500
#  - 0s - loss: 0.2061 - mse: 0.2061 - val_loss: 0.0503 - val_mse: 0.0503
#
# Epoch 00055: val_loss did not improve from 0.04907
# Epoch 56/500
#  - 0s - loss: 0.1807 - mse: 0.1807 - val_loss: 0.0488 - val_mse: 0.0488
#
# Epoch 00056: val_loss improved from 0.04907 to 0.04882, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 57/500
#  - 0s - loss: 0.1786 - mse: 0.1786 - val_loss: 0.0502 - val_mse: 0.0502
#
# Epoch 00057: val_loss did not improve from 0.04882
# Epoch 58/500
#  - 0s - loss: 0.1763 - mse: 0.1763 - val_loss: 0.0495 - val_mse: 0.0495
#
# Epoch 00058: val_loss did not improve from 0.04882
# Epoch 59/500
#  - 0s - loss: 0.1823 - mse: 0.1823 - val_loss: 0.0495 - val_mse: 0.0495
#
# Epoch 00059: val_loss did not improve from 0.04882
# Epoch 60/500
#  - 0s - loss: 0.1728 - mse: 0.1728 - val_loss: 0.0500 - val_mse: 0.0500
#
# Epoch 00060: val_loss did not improve from 0.04882
# Epoch 61/500
#  - 0s - loss: 0.1777 - mse: 0.1777 - val_loss: 0.0494 - val_mse: 0.0494
#
# Epoch 00061: val_loss did not improve from 0.04882
# Epoch 62/500
#  - 0s - loss: 0.1797 - mse: 0.1797 - val_loss: 0.0503 - val_mse: 0.0503
#
# Epoch 00062: val_loss did not improve from 0.04882
# Epoch 63/500
#  - 0s - loss: 0.1670 - mse: 0.1670 - val_loss: 0.0491 - val_mse: 0.0491
#
# Epoch 00063: val_loss did not improve from 0.04882
# Epoch 64/500
#  - 0s - loss: 0.1562 - mse: 0.1562 - val_loss: 0.0493 - val_mse: 0.0493
#
# Epoch 00064: val_loss did not improve from 0.04882
# Epoch 65/500
#  - 0s - loss: 0.1637 - mse: 0.1637 - val_loss: 0.0512 - val_mse: 0.0512
#
# Epoch 00065: val_loss did not improve from 0.04882
# Epoch 66/500
#  - 0s - loss: 0.1683 - mse: 0.1683 - val_loss: 0.0501 - val_mse: 0.0501
#
# Epoch 00066: val_loss did not improve from 0.04882
# Epoch 67/500
#  - 0s - loss: 0.1664 - mse: 0.1664 - val_loss: 0.0497 - val_mse: 0.0497
#
# Epoch 00067: val_loss did not improve from 0.04882
# Epoch 68/500
#  - 0s - loss: 0.1633 - mse: 0.1633 - val_loss: 0.0501 - val_mse: 0.0501
#
# Epoch 00068: val_loss did not improve from 0.04882
# Epoch 69/500
#  - 0s - loss: 0.1690 - mse: 0.1690 - val_loss: 0.0493 - val_mse: 0.0493
#
# Epoch 00069: val_loss did not improve from 0.04882
# Epoch 70/500
#  - 0s - loss: 0.1655 - mse: 0.1655 - val_loss: 0.0506 - val_mse: 0.0506
#
# Epoch 00070: val_loss did not improve from 0.04882
# Epoch 71/500
#  - 0s - loss: 0.1795 - mse: 0.1795 - val_loss: 0.0498 - val_mse: 0.0498
#
# Epoch 00071: val_loss did not improve from 0.04882
# Epoch 72/500
#  - 0s - loss: 0.1786 - mse: 0.1786 - val_loss: 0.0489 - val_mse: 0.0489
#
# Epoch 00072: val_loss did not improve from 0.04882
# Epoch 73/500
#  - 0s - loss: 0.1837 - mse: 0.1837 - val_loss: 0.0499 - val_mse: 0.0499
#
# Epoch 00073: val_loss did not improve from 0.04882
# Epoch 74/500
#  - 0s - loss: 0.1631 - mse: 0.1631 - val_loss: 0.0501 - val_mse: 0.0501
#
# Epoch 00074: val_loss did not improve from 0.04882
# Epoch 75/500
#  - 0s - loss: 0.1636 - mse: 0.1636 - val_loss: 0.0496 - val_mse: 0.0496
#
# Epoch 00075: val_loss did not improve from 0.04882
# Epoch 76/500
#  - 0s - loss: 0.1784 - mse: 0.1784 - val_loss: 0.0487 - val_mse: 0.0487
#
# Epoch 00076: val_loss improved from 0.04882 to 0.04866, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 77/500
#  - 0s - loss: 0.1680 - mse: 0.1680 - val_loss: 0.0499 - val_mse: 0.0499
#
# Epoch 00077: val_loss did not improve from 0.04866
# Epoch 78/500
#  - 0s - loss: 0.1628 - mse: 0.1628 - val_loss: 0.0492 - val_mse: 0.0492
#
# Epoch 00078: val_loss did not improve from 0.04866
# Epoch 79/500
#  - 0s - loss: 0.1698 - mse: 0.1698 - val_loss: 0.0495 - val_mse: 0.0495
#
# Epoch 00079: val_loss did not improve from 0.04866
# Epoch 80/500
#  - 0s - loss: 0.1642 - mse: 0.1642 - val_loss: 0.0489 - val_mse: 0.0489
#
# Epoch 00080: val_loss did not improve from 0.04866
# Epoch 81/500
#  - 0s - loss: 0.1687 - mse: 0.1687 - val_loss: 0.0499 - val_mse: 0.0499
#
# Epoch 00081: val_loss did not improve from 0.04866
# Epoch 82/500
#  - 0s - loss: 0.1507 - mse: 0.1507 - val_loss: 0.0488 - val_mse: 0.0488
#
# Epoch 00082: val_loss did not improve from 0.04866
# Epoch 83/500
#  - 0s - loss: 0.1667 - mse: 0.1667 - val_loss: 0.0498 - val_mse: 0.0498
#
# Epoch 00083: val_loss did not improve from 0.04866
# Epoch 84/500
#  - 0s - loss: 0.1738 - mse: 0.1738 - val_loss: 0.0484 - val_mse: 0.0484
#
# Epoch 00084: val_loss improved from 0.04866 to 0.04843, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 85/500
#  - 0s - loss: 0.1731 - mse: 0.1731 - val_loss: 0.0509 - val_mse: 0.0509
#
# Epoch 00085: val_loss did not improve from 0.04843
# Epoch 86/500
#  - 0s - loss: 0.1597 - mse: 0.1597 - val_loss: 0.0492 - val_mse: 0.0492
#
# Epoch 00086: val_loss did not improve from 0.04843
# Epoch 87/500
#  - 0s - loss: 0.1635 - mse: 0.1635 - val_loss: 0.0502 - val_mse: 0.0502
#
# Epoch 00087: val_loss did not improve from 0.04843
# Epoch 88/500
#  - 0s - loss: 0.1612 - mse: 0.1612 - val_loss: 0.0506 - val_mse: 0.0506
#
# Epoch 00088: val_loss did not improve from 0.04843
# Epoch 89/500
#  - 0s - loss: 0.1595 - mse: 0.1595 - val_loss: 0.0493 - val_mse: 0.0493
#
# Epoch 00089: val_loss did not improve from 0.04843
# Epoch 90/500
#  - 0s - loss: 0.1782 - mse: 0.1782 - val_loss: 0.0507 - val_mse: 0.0507
#
# Epoch 00090: val_loss did not improve from 0.04843
# Epoch 91/500
#  - 0s - loss: 0.1589 - mse: 0.1589 - val_loss: 0.0480 - val_mse: 0.0480
#
# Epoch 00091: val_loss improved from 0.04843 to 0.04798, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 92/500
#  - 0s - loss: 0.1706 - mse: 0.1706 - val_loss: 0.0509 - val_mse: 0.0509
#
# Epoch 00092: val_loss did not improve from 0.04798
# Epoch 93/500
#  - 0s - loss: 0.1613 - mse: 0.1613 - val_loss: 0.0482 - val_mse: 0.0482
#
# Epoch 00093: val_loss did not improve from 0.04798
# Epoch 94/500
#  - 0s - loss: 0.1644 - mse: 0.1644 - val_loss: 0.0516 - val_mse: 0.0516
#
# Epoch 00094: val_loss did not improve from 0.04798
# Epoch 95/500
#  - 0s - loss: 0.1625 - mse: 0.1625 - val_loss: 0.0477 - val_mse: 0.0477
#
# Epoch 00095: val_loss improved from 0.04798 to 0.04766, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 96/500
#  - 0s - loss: 0.1889 - mse: 0.1889 - val_loss: 0.0495 - val_mse: 0.0495
#
# Epoch 00096: val_loss did not improve from 0.04766
# Epoch 97/500
#  - 0s - loss: 0.1658 - mse: 0.1658 - val_loss: 0.0484 - val_mse: 0.0484
#
# Epoch 00097: val_loss did not improve from 0.04766
# Epoch 98/500
#  - 0s - loss: 0.1606 - mse: 0.1606 - val_loss: 0.0486 - val_mse: 0.0486
#
# Epoch 00098: val_loss did not improve from 0.04766
# Epoch 99/500
#  - 0s - loss: 0.1629 - mse: 0.1629 - val_loss: 0.0497 - val_mse: 0.0497
#
# Epoch 00099: val_loss did not improve from 0.04766
# Epoch 100/500
#  - 0s - loss: 0.1551 - mse: 0.1551 - val_loss: 0.0495 - val_mse: 0.0495
#
# Epoch 00100: val_loss did not improve from 0.04766
# Epoch 101/500
#  - 0s - loss: 0.1632 - mse: 0.1632 - val_loss: 0.0493 - val_mse: 0.0493
#
# Epoch 00101: val_loss did not improve from 0.04766
# Epoch 102/500
#  - 0s - loss: 0.1557 - mse: 0.1557 - val_loss: 0.0500 - val_mse: 0.0500
#
# Epoch 00102: val_loss did not improve from 0.04766
# Epoch 103/500
#  - 0s - loss: 0.1615 - mse: 0.1615 - val_loss: 0.0509 - val_mse: 0.0509
#
# Epoch 00103: val_loss did not improve from 0.04766
# Epoch 104/500
#  - 0s - loss: 0.1683 - mse: 0.1683 - val_loss: 0.0484 - val_mse: 0.0484
#
# Epoch 00104: val_loss did not improve from 0.04766
# Epoch 105/500
#  - 0s - loss: 0.1691 - mse: 0.1691 - val_loss: 0.0492 - val_mse: 0.0492
#
# Epoch 00105: val_loss did not improve from 0.04766
# Epoch 106/500
#  - 0s - loss: 0.1512 - mse: 0.1512 - val_loss: 0.0485 - val_mse: 0.0485
#
# Epoch 00106: val_loss did not improve from 0.04766
# Epoch 107/500
#  - 0s - loss: 0.1624 - mse: 0.1624 - val_loss: 0.0496 - val_mse: 0.0496
#
# Epoch 00107: val_loss did not improve from 0.04766
# Epoch 108/500
#  - 0s - loss: 0.1689 - mse: 0.1689 - val_loss: 0.0501 - val_mse: 0.0501
#
# Epoch 00108: val_loss did not improve from 0.04766
# Epoch 109/500
#  - 0s - loss: 0.1668 - mse: 0.1668 - val_loss: 0.0501 - val_mse: 0.0501
#
# Epoch 00109: val_loss did not improve from 0.04766
# Epoch 110/500
#  - 0s - loss: 0.1598 - mse: 0.1598 - val_loss: 0.0496 - val_mse: 0.0496
#
# Epoch 00110: val_loss did not improve from 0.04766
# Epoch 111/500
#  - 0s - loss: 0.1632 - mse: 0.1632 - val_loss: 0.0502 - val_mse: 0.0502
#
# Epoch 00111: val_loss did not improve from 0.04766
# Epoch 112/500
#  - 0s - loss: 0.1576 - mse: 0.1576 - val_loss: 0.0491 - val_mse: 0.0491
#
# Epoch 00112: val_loss did not improve from 0.04766
# Epoch 113/500
#  - 0s - loss: 0.1721 - mse: 0.1721 - val_loss: 0.0497 - val_mse: 0.0497
#
# Epoch 00113: val_loss did not improve from 0.04766
# Epoch 114/500
#  - 0s - loss: 0.1619 - mse: 0.1619 - val_loss: 0.0488 - val_mse: 0.0488
#
# Epoch 00114: val_loss did not improve from 0.04766
# Epoch 115/500
#  - 0s - loss: 0.1558 - mse: 0.1558 - val_loss: 0.0477 - val_mse: 0.0477
#
# Epoch 00115: val_loss improved from 0.04766 to 0.04765, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 116/500
#  - 0s - loss: 0.1608 - mse: 0.1608 - val_loss: 0.0483 - val_mse: 0.0483
#
# Epoch 00116: val_loss did not improve from 0.04765
# Epoch 117/500
#  - 0s - loss: 0.1549 - mse: 0.1549 - val_loss: 0.0481 - val_mse: 0.0481
#
# Epoch 00117: val_loss did not improve from 0.04765
# Epoch 118/500
#  - 0s - loss: 0.1538 - mse: 0.1538 - val_loss: 0.0482 - val_mse: 0.0482
#
# Epoch 00118: val_loss did not improve from 0.04765
# Epoch 119/500
#  - 0s - loss: 0.1634 - mse: 0.1634 - val_loss: 0.0496 - val_mse: 0.0496
#
# Epoch 00119: val_loss did not improve from 0.04765
# Epoch 120/500
#  - 0s - loss: 0.1595 - mse: 0.1595 - val_loss: 0.0475 - val_mse: 0.0475
#
# Epoch 00120: val_loss improved from 0.04765 to 0.04753, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 121/500
#  - 0s - loss: 0.1608 - mse: 0.1608 - val_loss: 0.0473 - val_mse: 0.0473
#
# Epoch 00121: val_loss improved from 0.04753 to 0.04733, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 122/500
#  - 0s - loss: 0.1652 - mse: 0.1652 - val_loss: 0.0488 - val_mse: 0.0488
#
# Epoch 00122: val_loss did not improve from 0.04733
# Epoch 123/500
#  - 0s - loss: 0.1539 - mse: 0.1539 - val_loss: 0.0472 - val_mse: 0.0472
#
# Epoch 00123: val_loss improved from 0.04733 to 0.04722, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_108_ohlc.hdf5
# Epoch 124/500
#  - 0s - loss: 0.1768 - mse: 0.1768 - val_loss: 0.0484 - val_mse: 0.0484
#
# Epoch 00124: val_loss did not improve from 0.04722
# Epoch 125/500
#  - 0s - loss: 0.1633 - mse: 0.1633 - val_loss: 0.0487 - val_mse: 0.0487
#
# Epoch 00125: val_loss did not improve from 0.04722
# Epoch 126/500
#  - 0s - loss: 0.1545 - mse: 0.1545 - val_loss: 0.0492 - val_mse: 0.0492
#
# Epoch 00126: val_loss did not improve from 0.04722
# Epoch 127/500
#  - 0s - loss: 0.1464 - mse: 0.1464 - val_loss: 0.0475 - val_mse: 0.0475
#
# Epoch 00127: val_loss did not improve from 0.04722
# Epoch 128/500
#  - 0s - loss: 0.1637 - mse: 0.1637 - val_loss: 0.0503 - val_mse: 0.0503
#
# Epoch 00128: val_loss did not improve from 0.04722
# Epoch 129/500
#  - 0s - loss: 0.1501 - mse: 0.1501 - val_loss: 0.0489 - val_mse: 0.0489
#
# Epoch 00129: val_loss did not improve from 0.04722
# Epoch 130/500
#  - 0s - loss: 0.1658 - mse: 0.1658 - val_loss: 0.0504 - val_mse: 0.0504
#
# Epoch 00130: val_loss did not improve from 0.04722
# Epoch 131/500
#  - 0s - loss: 0.1600 - mse: 0.1600 - val_loss: 0.0498 - val_mse: 0.0498
#
# Epoch 00131: val_loss did not improve from 0.04722
# Epoch 132/500
#  - 0s - loss: 0.1523 - mse: 0.1523 - val_loss: 0.0482 - val_mse: 0.0482
#
# Epoch 00132: val_loss did not improve from 0.04722
# Epoch 133/500
#  - 0s - loss: 0.1596 - mse: 0.1596 - val_loss: 0.0487 - val_mse: 0.0487
#
# Epoch 00133: val_loss did not improve from 0.04722
# Epoch 134/500
#  - 0s - loss: 0.1609 - mse: 0.1609 - val_loss: 0.0473 - val_mse: 0.0473
#
# Epoch 00134: val_loss did not improve from 0.04722
# Epoch 135/500
#  - 0s - loss: 0.1518 - mse: 0.1518 - val_loss: 0.0476 - val_mse: 0.0476
#
# Epoch 00135: val_loss did not improve from 0.04722
# Epoch 136/500
#  - 0s - loss: 0.1677 - mse: 0.1677 - val_loss: 0.0491 - val_mse: 0.0491
#
# Epoch 00136: val_loss did not improve from 0.04722
# Epoch 137/500
#  - 0s - loss: 0.1562 - mse: 0.1562 - val_loss: 0.0488 - val_mse: 0.0488
#
# Epoch 00137: val_loss did not improve from 0.04722
# Epoch 138/500
#  - 0s - loss: 0.1606 - mse: 0.1606 - val_loss: 0.0479 - val_mse: 0.0479
#
# Epoch 00138: val_loss did not improve from 0.04722
# Epoch 139/500
#  - 0s - loss: 0.1505 - mse: 0.1505 - val_loss: 0.0488 - val_mse: 0.0488
#
# Epoch 00139: val_loss did not improve from 0.04722
# Epoch 140/500
#  - 0s - loss: 0.1599 - mse: 0.1599 - val_loss: 0.0490 - val_mse: 0.0490
#
# Epoch 00140: val_loss did not improve from 0.04722
# Epoch 141/500
#  - 0s - loss: 0.1640 - mse: 0.1640 - val_loss: 0.0486 - val_mse: 0.0486
#
# Epoch 00141: val_loss did not improve from 0.04722
# Epoch 142/500
#  - 0s - loss: 0.1507 - mse: 0.1507 - val_loss: 0.0482 - val_mse: 0.0482
#
# Epoch 00142: val_loss did not improve from 0.04722
# Epoch 143/500
#  - 0s - loss: 0.1558 - mse: 0.1558 - val_loss: 0.0495 - val_mse: 0.0495
#
# Epoch 00143: val_loss did not improve from 0.04722
# Epoch 144/500
#  - 0s - loss: 0.1574 - mse: 0.1574 - val_loss: 0.0484 - val_mse: 0.0484
#
# Epoch 00144: val_loss did not improve from 0.04722
# Epoch 145/500
#  - 0s - loss: 0.1573 - mse: 0.1573 - val_loss: 0.0495 - val_mse: 0.0495
#
# Epoch 00145: val_loss did not improve from 0.04722
# Epoch 146/500
#  - 0s - loss: 0.1520 - mse: 0.1520 - val_loss: 0.0502 - val_mse: 0.0502
#
# Epoch 00146: val_loss did not improve from 0.04722
# Epoch 147/500
#  - 0s - loss: 0.1527 - mse: 0.1527 - val_loss: 0.0484 - val_mse: 0.0484
#
# Epoch 00147: val_loss did not improve from 0.04722
# Epoch 148/500
#  - 0s - loss: 0.1549 - mse: 0.1549 - val_loss: 0.0489 - val_mse: 0.0489
#
# Epoch 00148: val_loss did not improve from 0.04722
# Epoch 149/500
#  - 0s - loss: 0.1466 - mse: 0.1466 - val_loss: 0.0489 - val_mse: 0.0489
#
# Epoch 00149: val_loss did not improve from 0.04722
# Epoch 150/500
#  - 0s - loss: 0.1540 - mse: 0.1540 - val_loss: 0.0475 - val_mse: 0.0475
#
# Epoch 00150: val_loss did not improve from 0.04722
# Epoch 151/500
#  - 0s - loss: 0.1552 - mse: 0.1552 - val_loss: 0.0491 - val_mse: 0.0491
#
# Epoch 00151: val_loss did not improve from 0.04722
# Epoch 152/500
#  - 0s - loss: 0.1457 - mse: 0.1457 - val_loss: 0.0486 - val_mse: 0.0486
#
# Epoch 00152: val_loss did not improve from 0.04722
# Epoch 153/500
#  - 0s - loss: 0.1601 - mse: 0.1601 - val_loss: 0.0493 - val_mse: 0.0493
#
# Epoch 00153: val_loss did not improve from 0.04722

# %%
file = file_list[-5]
print(file)
inverse = 0

ohlcv_reg = pd.read_excel(file_path + file, index_col=0)
macd(ohlcv_reg, short=short, long=long, signal=signal)

ohlcv_reg['realtime_osc_reg'] = np.nan
for i in range(input_data_length, len(ohlcv_reg)):
  y = ohlcv_reg.MACD_OSC.values[i + 1 - input_data_length:i + 1]
  y_smooth = gaussian_filter1d(y, sigma=sigma)

  ohlcv_reg['realtime_osc_reg'].iloc[i] = y_smooth[-1]

ohlcv_reg['osc_reg'] = ohlcv_reg['realtime_osc_reg'].shift(-pull_range)
# print(ohlcv_reg.iloc[:, -5:].head(15))
# breakpoint

#     X_data : idl 만큼의 close? (일단),    Y_data : reg
#     실시간으로 reg의 형태가 machine learning으로는 고정되지 않기 때문에,
#     먼저 고정을 시키고, deep learning을 이용해 실시간으로 고정된 regression 결과를 뽑아낼 수 있는지 확인한다.
#     충분히 가능성 있다.     #

#         reg_target = close인 경우 앞의 데이터가 산다.       #  close/ close_reg
if pull_range != 0:
  ohlcv_reg = ohlcv_reg.values[sum(ohlcv_reg.osc_reg.isna())-pull_range:-pull_range, :] # 
else:
  ohlcv_reg = ohlcv_reg.values[sum(ohlcv_reg.osc_reg.isna()):, :] # 

reg_target = ohlcv_reg[:, [-2]].astype(np.float32)
reg_result = ohlcv_reg[:, [-1]].astype(np.float32)
# print(reg_result)
# print(np.sum(np.isnan(reg_target)))
# print(np.sum(np.isnan(reg_result)))
# breakpoint
if len(reg_target) == 0:
    breakpoint

scaler_x = StandardScaler()
scaler_y = StandardScaler()
reg_target = scaler_x.fit_transform(reg_target)
reg_result = scaler_y.fit_transform(reg_result)
# reg_target = max_abs_scaler(reg_target)
# reg_result = max_abs_scaler(reg_result)
# print(reg_target, reg_result)
# breakpoint

dataX, dataY = list(), list()
for i in range(input_data_length, len(reg_target)):

  # group_x = reg_target[i - input_data_length: i]
  group_x = reg_target[i + 1 - input_data_length: i + 1]
  # group_x = gaussian_filter1d(reg_target[i + 1 - input_data_length: i + 1], sigma=sigma)
  group_y = reg_result[i]
  # print(group_x[0])
  # quit()

  #   데이터 값에 결측치가 존재하는 경우 #
  if sum(sum(np.isnan(group_x))) > 0:
      continue

  if inverse == 1:
    dataX.append(group_x[::-1])  # dataX 리스트에 추가
  else:
    dataX.append(group_x)
  dataY.append(group_y)

Made_X = np.array(dataX)
Made_Y = np.array(dataY)

# Made_X = np.array(reg_target)
# Made_Y = np.array(reg_result)

# from keras.models import load_model
# model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_ohlc.hdf5' % (input_data_length, model_num))

pred_reg = model.predict(Made_X)

span_list = list()
span_list_y = list()
for i in range(1, len(pred_reg)):
    if pred_reg[i - 1] < pred_reg[i]:
      span_list.append((i, i + 1))
    if Made_Y[i - 1] < Made_Y[i]:
      span_list_y.append((i, i + 1))

plt.subplot(211)
if inverse == 1:
  plt.plot(Made_X[:, [0]].reshape(-1, 1), color='m', label='origin_curv')
else:
  plt.plot(Made_X[:, [-1]].reshape(-1, 1), color='m', label='origin_curv')
  
plt.plot(pred_reg, color='b',  label='prediction')
plt.legend(loc='upper right')
for i in range(len(span_list)):
    plt.axvspan(span_list[i][0], span_list[i][1], facecolor='y', alpha=0.5)

plt.subplot(212)
if inverse == 1:
  plt.plot(Made_X[:, [0]].reshape(-1, 1), color='m', label='origin_curv')
else:
  plt.plot(Made_X[:, [-1]].reshape(-1, 1), color='m', label='origin_curv')
plt.plot(Made_Y, color='r', label='pulled_y')

for i in range(len(span_list_y)):
    plt.axvspan(span_list_y[i][0], span_list_y[i][1], facecolor='c', alpha=0.5)


plt.show()
# Out:
# 2019-11-02 BCH ohlcv.xlsx
