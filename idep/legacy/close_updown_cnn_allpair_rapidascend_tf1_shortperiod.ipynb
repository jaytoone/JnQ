# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install h5py==2.10.0

# !pip install tensorflow==2.1.0
# !pip install keras==2.4.1

# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__
# Out:
# Collecting h5py==2.10.0
#   Downloading https://files.pythonhosted.org/packages/3f/c0/abde58b837e066bca19a3f7332d9d0493521d7dd6b48248451a9e3fe2214/h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 6.9MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.15.0)
# ERROR: tensorflow 2.5.0 has requirement h5py~=3.1.0, but you'll have h5py 2.10.0 which is incompatible.
# Installing collected packages: h5py
#   Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# Successfully installed h5py-2.10.0

# %%
# %tensorflow_version 1.x

import tensorflow as tf
tf.__version__
# Out:
# '2.1.0'

# %%
import keras
keras.__version__
from tensorflow.keras.utils import np_utils

# %% [markdown]
# ### load file list

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### custom model

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import tensorflow as tf
import keras

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

# from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
print(tf.__version__)
print(keras.__version__)
# Out:
# 1.15.2
# 2.3.1

# %% [markdown]
# ### all in one loop

# %%
print(ohlcv['close'].pct_change().head())
print(ohlcv['close'] / ohlcv['close'].shift(1).head() - 1)

# %%
# from tensorflow.keras.utils import to_categorical

# %%
from funcs_indicator import *
import matplotlib.pyplot as plt

# import mpl_finance as mf


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None


#           load saved npy & trained model        #
load_npy = False
load_model = False


seed = 1
random_state = 201
np.random.seed(seed)

fee = 0.0006
lvrg = 5

for i in range(len(candis)):

  keys = [candis[i]]

  if 'eth'.upper() not in candis[i]:
    continue

  # if 'comp'.upper() not in candis[i]:
  #   continue

  for key in keys:  
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))

        
    #       long      #
    pr = (ohlcv['close'].pct_change() - fee) * lvrg + 1    

    #       long liqudation     #
    lq = (ohlcv['low'] / ohlcv['close'].shift(1) - fee - 1) * lvrg + 1

    #       short       # <-- 이거를 단순히 minus 를 붙여도 되는걸까
    s_pr = (-ohlcv['close'].pct_change() - fee) * lvrg + 1

    #       short liqudation     #
    # s_lq = (ohlcv['high'] / ohlcv['close'].shift(1) - fee) * lvrg + 1
    

    #       fill na with 1.0      #
    # pr = np.where(np.isnan(pr), 1, pr)
    # print(len(pr))
    # print("len(pr[np.isnan(pr)]) :", len(pr[np.isnan(pr)]))
    # print("np.sum(np.isnan(pr)) :", np.sum(np.isnan(pr)))
    
    # sliced_ohlcv = ohlcv[np.sum(np.isnan(pr))]
    # print(sliced_ohlcv.head())
    # break
    # s_pr = np.where(np.isnan(s_pr), 1, pr)
    # lq = np.where(np.isnan(lq), 1, lq)


    #       set lq      #
    # pr = np.where((pr != 1) & (lq <= 0), 0, pr)

    # print("len(pr[pr < 0]) :", len(pr[pr < 0]))
    # break

    org_wr = len(pr[pr > 1]) / len(pr[pr != 1])

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(pr))
    plt.title("%s\norg_wr : %.3f\n acc_pr : %.3f" % (key, org_wr, np.cumprod(pr)[-1]))


    #                    strat                   #

    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) < ohlcv['close'].shift(3)), pr, 1)


    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
    #                     (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
    #                     (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)), pr, 1)


    strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
                        (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
                        (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
                        (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)) & 
                        (ohlcv['close'].shift(5) < ohlcv['close'].shift(6)), pr, 1)
    
    # strat_pr = np.where((ohlcv['high'].shift(2) > ohlcv['high'].shift(3))& 
    #                     (ohlcv['close'].shift(1) > ohlcv['close'].shift(2)), pr, 1)


    wr = len(strat_pr[strat_pr > 1]) / len(strat_pr[strat_pr != 1])

    plt.subplot(122)
    plt.plot(np.cumprod(strat_pr))
    plt.title("%s\norg_wr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr, np.cumprod(strat_pr)[-1]))


    # #                  sl cut                #
    # sl_line = ohlcv['low'].rolling(250).min().shift(1)
    # # sl_line = ohlcv['low'].shift(1)

    # strat_pr_sl = np.where((strat_pr != 1) & (sl_line > ohlcv['low']), 
    #                      1 + lvrg * (sl_line / ohlcv['close'].shift(1) - 1 - fee), strat_pr)


    # wr_sl = len(strat_pr_sl[strat_pr_sl > 1]) / len(strat_pr_sl[strat_pr_sl != 1])
    # # wl_pr_ratio = np.mean(strat_pr[strat_pr > 1]) / np.mean(strat_pr[strat_pr < 1])
    # # wl_pr_ratio = np.cumprod(strat_pr[strat_pr > 1])[-1] / np.cumprod(strat_pr[strat_pr < 1])[-1]

    # plt.subplot(122)
    # plt.plot(np.cumprod(strat_pr_sl))
    # plt.title("%s\norg_pr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr_sl, np.cumprod(strat_pr_sl)[-1]))


    plt.show()
    # break

    # period = 5
    period = 28
    symbol_name = key.split(' ')[1].split('.')[0]      

    x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
    pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
    index_save_path = current_path + 'npy/' + '%s_cnn_updown_index_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)



    if not load_npy:

      from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
      from sklearn.model_selection import train_test_split
      from datetime import datetime

      from funcs_indicator import *

      def min_max_scale(npy_x):

        return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[np.sum(np.isnan(pr)):]

      sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

      #       scale with price    #
      ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

      ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
      sar = lucid_sar(sliced_ohlcv)
      ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
      senkou1, senkou2 = ichimoku(sliced_ohlcv)

      #     min max scale   #
      vol = ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]
      # vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

      pr_list = pr[np.sum(np.isnan(pr)):]
      print("len(ohlc) :", len(ohlc))
      print("len(pr_list) :", len(pr_list))

      print("ohlc.index[0] :", ohlc.index[0])
      print("vol.index[0] :", vol.index[0])
      # break


      #       set params    #
      # period = 45
      key_i = i

      plotting = True

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(ohlc)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          # temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

          temp_close = min_max_scale(temp_ohlc[:, [3]])    

          price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          ind_temp_ohlc = min_max_scale(temp_ohlc)
          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


          if plotting:

            plt.plot(ind_temp_ohlc)
            plt.show()
            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          #                   feature selection                   #        
          temp_data = np.hstack((ind_temp_ohlc, temp_vol))

          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          # temp_data = temp_ohlc[:, [3]]
          # temp_data = ind_temp_ohlc[:, [3]]
          # temp_data = temp_close

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      # input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)


      # _, row, col, _ = input_x.shape
      # _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      #                 don't shuffle timeseries data                 #
      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)


      np.save(x_save_path, x_train)
      np.save(x_save_path.replace('x_train', 'x_val'), x_val)
      np.save(x_save_path.replace('x_train', 'x_test'), x_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('x series saved !')

      np.save(pr_save_path, pr_train)
      np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
      np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
      # np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
      print('pr series saved !')
      
      np.save(index_save_path, index_train)
      np.save(index_save_path.replace('index_train', 'index_val'), index_val)
      np.save(index_save_path.replace('index_train', 'index_test'), index_test)
      print('index series saved !')

    else:
      
      x_train = np.load(x_save_path)
      x_val = np.load(x_save_path.replace('x_train', 'x_val'))
      x_test = np.load(x_save_path.replace('x_train', 'x_test'))
      print('x series loaded !')


      pr_train = np.load(pr_save_path)
      pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
      pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
      print('y series loaded !')


      index_train = np.load(index_save_path, allow_pickle=True)
      index_val = np.load(index_save_path.replace('index_train', 'index_val'), allow_pickle=True)
      index_test = np.load(index_save_path.replace('index_train', 'index_test'), allow_pickle=True)
      print('index series loaded !')




    #       pr_thresh by percentage 0.285     #
    plt.plot(pr)
    plt.show()
    
    sorted_pr = sorted(pr, reverse=True)
    pct = 0.285
    len_pct = int(len(pr) * pct)
    pr_thresh = sorted_pr[len_pct]
    print("pr_thresh :", pr_thresh)

    # from tensorflow.keras.utils import np_utils
    # from keras.utils import to_categorical
    from keras.utils.np_utils import to_categorical

    from sklearn.utils import class_weight


    def class_ratio(in_list):

      return in_list / in_list[1]
      
    y_train = np.where(pr_train > pr_thresh, 1, 0)
    y_test = np.where(pr_test > pr_thresh, 1, 0)
    y_val = np.where(pr_val > pr_thresh, 1, 0)

    print('x_train.shape :', x_train.shape)
    print('x_test.shape :', x_test.shape)
    print('x_val.shape :', x_val.shape)
    print('y_train.shape :', y_train.shape)
    print('y_test.shape :', y_test.shape)
    print('y_val.shape :', y_val.shape)

    # try:
    print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
    print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
    print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

    # except Exception as e:
      # print(e)

    label = y_train.reshape(-1, )
    class_weights = class_weight.compute_class_weight('balanced', 
                                                        classes=np.unique(label),
                                                        y=label)
    class_weights = dict(enumerate(class_weights))
    print('class_weights :', class_weights)

    # sample_weight = np.ones(shape=(len(y_train),))
    # sample_weight[(y_train == 1).reshape(-1,)] = 1.5
    # print('sample_weight[:20] :', sample_weight[:20])


    print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
    print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
    print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

    print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
    print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
    print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

    num_classes = 2
    
    # y_train_ohe = np_utils.to_categorical(y_train, num_classes)
    # y_val_ohe = np_utils.to_categorical(y_val, num_classes)
    # y_test_ohe = np_utils.to_categorical(y_test, num_classes)
    
    y_train_ohe = to_categorical(y_train, num_classes)
    y_val_ohe = to_categorical(y_val, num_classes)
    y_test_ohe = to_categorical(y_test, num_classes)
    print('y_train_ohe.shape :', y_train_ohe.shape)
    print('y_val_ohe.shape :', y_val_ohe.shape)
    print('y_test_ohe.shape :', y_test_ohe.shape)

    from keras.preprocessing.image import ImageDataGenerator 
    # from tensorflow.keras.preprocessing.image import ImageDataGenerator 

    datagen = ImageDataGenerator( 
        # rotation_range = 45,
        # zoom_range = 0.5,
        # shear_range = 0.5,
        # horizontal_flip = True,
        # vertical_flip = True,
        # width_shift_range=0.5,
        # height_shift_range=0.5,
        # fill_mode = 'nearest'
        )

    valgen = ImageDataGenerator( 
        )

    datagen.fit(x_train)
    valgen.fit(x_val)


    batch_size = 512


    for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

        plt.suptitle("train x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break

    for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

        plt.suptitle("val x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break
        
    train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
    val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
    # break

    

    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'

    # batch_size = 512

    K.clear_session()


    # model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_tf250_%s_tvnon_shuffle.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_tf241_%s_tvnon_shuffle.h5' % (period, symbol_name)
    model_name = 'classifier_%s_cnn_updown_rascend_%s_tf115_%s.h5' % (period, int(pct * 1000), symbol_name)



    if not load_model:

      # from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
      from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

      model = FER_Model(input_shape=x_train.shape[1:])
      # opt = Adam(lr=1e-5, decay=5e-6)
      opt = Adam( learning_rate=1e-5, decay=5e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-7)

      # opt = Adam(lr=0.001, decay=0.0005)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir=board_path,
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_loss', patience=500)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]
      # callbacks_list = [checkpoint, checkpoint2]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 2000
      history = model.fit_generator(train_flow, 
                          steps_per_epoch=len(x_train) / batch_size, 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=val_flow,  
                          validation_steps=len(x_val) / batch_size,
                          shuffle=False)
      
    
    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'


    model = keras.models.load_model(ckpt_path + model_name)

    test_result = model.predict(x_test)
    # test_result = model.predict(test_set)

    print('test_result.shape :', test_result.shape)
    # print('pr_val.shape :', pr_val.shape)

    y_score = test_result[:, [1]]
    print('y_test[:5] :', y_test.reshape(-1,)[:5])
    # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
    print('y_score[:5] :', y_score[:5])
    # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

    print('y_test.shape :', y_test.shape)
    print('y_score.shape :', y_score.shape)

    print('len(y_test) :', len(y_test))

    #     precision recall curve   #
    precision, recall, threshold = precision_recall_curve(y_test, y_score)
    precision, recall = precision[:-1], recall[:-1]

    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    plt.show()
    # print(y_pred)


    # threshold = [0.65]
    # print('threshold :', threshold)
    # break

    acc_pr_bythr = []
    new_thresh = []
    temp_pr_list = []


    for thresh in threshold:
      
      # if thresh < 0.5:
      #     continue

      y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
      # print('y_pred.shape :', y_pred.shape)
      # print('y_pred :', y_pred)

      #     compare precision     #

      # print('precision :', precision_score(y_test, y_pred))
      # print('recall :', recall_score(y_test, y_pred))
      # print()

      # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
      # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

      # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
      # # plt.show()  
      # print()

      #     check win-ratio improvement     #
      cmat = confusion_matrix(y_test, y_pred)
      # print(cmat)
      # print(np.sum(cmat, axis=1))

      test_size = len(y_test)
      test_pr_list = pr_test
      # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

      org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
      ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
      # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

      # print('pr_test.shape :', pr_test.shape)

      # print(y_pred)
      # print(test_pr_list)

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
      # print('pred_pr_list.shape :', pred_pr_list.shape)

      temp_pr_list.append(pred_pr_list)


      # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
      #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
      #   print('thresh :', thresh)
        
      # if len(threshold) == 1:
    #   plt.figure(figsize=(10, 5))
    #   plt.subplot(121)
    #   plt.plot(np.cumprod(test_pr_list))
    #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
    # # plt.show()

    #   plt.subplot(122)
    #   plt.plot(np.cumprod(pred_pr_list))
    #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
    #   plt.show()


      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)


    print('acc_pr_bythr :', acc_pr_bythr)

    plt.figure(figsize=(13, 5))
    plt.subplot(131)
    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    # plt.show()
    plt.subplot(132)
    plt.plot(new_thresh, acc_pr_bythr)
    plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')

    best_thr = new_thresh[np.argmax(acc_pr_bythr)]
    plt.axvline(best_thr, linestyle='--', color='r')
    plt.title(symbol_name + '\n' + str(best_thr))

    plt.subplot(133)
    plt.plot(np.cumprod(temp_pr_list[np.argmax(acc_pr_bythr)]))

    plt.show()
# Out:
# start_stamp : 0
# len(ohlcv) : 18048
# len(ohlc) : 18047
# len(pr_list) : 18047
# ohlc.index[0] : 2020-04-17 00:59:59.999000
# vol.index[0] : 2020-04-17 00:59:59.999000
# np.array(data_x).shape : (17943, 28, 5)
# input_x.shape : (17943, 28, 5, 3)
# input_x.dtype : float32
# input_pr.shape : (17943, 1)
# input_ud.shape : (17943, 1)
# input_index.shape : (17943, 1)
# total_x.shape : (17943, 28, 5, 3)
# total_pr.shape : (17943, 1)
# total_ud.shape : (17943, 1)
# prev_index.shape : (17943, 1)
# (array([Timestamp('2020-04-19 04:59:59.999000'),
#        Timestamp('2020-04-19 05:29:59.999000'),
#        Timestamp('2020-04-19 05:59:59.999000'), ...,
#        Timestamp('2021-04-27 22:59:59.999000'),
#        Timestamp('2021-04-27 23:29:59.999000'),
#        Timestamp('2021-04-27 23:59:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (10765,)
# stamp_val.shape : (3589,)
# stamp_test.shape : (3589,)
# HBox(children=(FloatProgress(value=0.0, max=17943.0), HTML(value='')))
# x_train.shape : (10765, 28, 5, 3)
# x_val.shape : (3589, 28, 5, 3)
# x_test.shape : (3589, 28, 5, 3)
# x series saved !
# pr series saved !
# index series saved !
# pr_thresh : 1.010013727383401
# x_train.shape : (10765, 28, 5, 3)
# x_test.shape : (3589, 28, 5, 3)
# x_val.shape : (3589, 28, 5, 3)
# y_train.shape : (10765, 1)
# y_test.shape : (3589, 1)
# y_val.shape : (3589, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([7696, 3069])) [2.50765722 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2585, 1004])) [2.5747012 1.       ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2557, 1032])) [2.47771318 1.        ]
# class_weights : {0: 0.6993892931392931, 1: 1.7538286086673183}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10765, 2)
# y_val_ohe.shape : (3589, 2)
# y_test_ohe.shape : (3589, 2)
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/2000
#  - 5s - loss: 0.7412 - accuracy: 0.5137 - val_loss: 1.0944 - val_accuracy: 0.2823
#
# Epoch 00001: val_loss improved from inf to 1.09437, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/2000
#  - 1s - loss: 0.6983 - accuracy: 0.5624 - val_loss: 0.8547 - val_accuracy: 0.2864
#
# Epoch 00002: val_loss improved from 1.09437 to 0.85471, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 3/2000
#  - 1s - loss: 0.6931 - accuracy: 0.5644 - val_loss: 0.8490 - val_accuracy: 0.3263
#
# Epoch 00003: val_loss improved from 0.85471 to 0.84897, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 4/2000
#  - 1s - loss: 0.6838 - accuracy: 0.5647 - val_loss: 0.7322 - val_accuracy: 0.3104
#
# Epoch 00004: val_loss improved from 0.84897 to 0.73223, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 5/2000
#  - 1s - loss: 0.6750 - accuracy: 0.5815 - val_loss: 0.6927 - val_accuracy: 0.3703
#
# Epoch 00005: val_loss improved from 0.73223 to 0.69268, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 6/2000
#  - 1s - loss: 0.6674 - accuracy: 0.5839 - val_loss: 0.7192 - val_accuracy: 0.5740
#
# Epoch 00006: val_loss did not improve from 0.69268
# Epoch 7/2000
#  - 1s - loss: 0.6807 - accuracy: 0.5882 - val_loss: 0.5976 - val_accuracy: 0.5364
#
# Epoch 00007: val_loss improved from 0.69268 to 0.59758, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 8/2000
#  - 1s - loss: 0.6620 - accuracy: 0.6015 - val_loss: 0.6468 - val_accuracy: 0.5598
#
# Epoch 00008: val_loss did not improve from 0.59758
# Epoch 9/2000
#  - 1s - loss: 0.6529 - accuracy: 0.6091 - val_loss: 0.7513 - val_accuracy: 0.6520
#
# Epoch 00009: val_loss did not improve from 0.59758
# Epoch 10/2000
#  - 1s - loss: 0.6638 - accuracy: 0.6167 - val_loss: 0.6144 - val_accuracy: 0.5113
#
# Epoch 00010: val_loss did not improve from 0.59758
# Epoch 11/2000
#  - 1s - loss: 0.6572 - accuracy: 0.6001 - val_loss: 0.6166 - val_accuracy: 0.5857
#
# Epoch 00011: val_loss did not improve from 0.59758
# Epoch 12/2000
#  - 1s - loss: 0.6486 - accuracy: 0.6296 - val_loss: 0.5834 - val_accuracy: 0.4968
#
# Epoch 00012: val_loss improved from 0.59758 to 0.58337, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 13/2000
#  - 1s - loss: 0.6371 - accuracy: 0.6289 - val_loss: 0.5795 - val_accuracy: 0.5737
#
# Epoch 00013: val_loss improved from 0.58337 to 0.57950, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 14/2000
#  - 1s - loss: 0.6368 - accuracy: 0.6440 - val_loss: 0.7453 - val_accuracy: 0.5979
#
# Epoch 00014: val_loss did not improve from 0.57950
# Epoch 15/2000
#  - 1s - loss: 0.6236 - accuracy: 0.6473 - val_loss: 0.6624 - val_accuracy: 0.4876
#
# Epoch 00015: val_loss did not improve from 0.57950
# Epoch 16/2000
#  - 1s - loss: 0.6340 - accuracy: 0.6427 - val_loss: 0.7525 - val_accuracy: 0.5517
#
# Epoch 00016: val_loss did not improve from 0.57950
# Epoch 17/2000
#  - 1s - loss: 0.6242 - accuracy: 0.6455 - val_loss: 0.5851 - val_accuracy: 0.6063
#
# Epoch 00017: val_loss did not improve from 0.57950
# Epoch 18/2000
#  - 1s - loss: 0.6166 - accuracy: 0.6546 - val_loss: 0.5679 - val_accuracy: 0.6645
#
# Epoch 00018: val_loss improved from 0.57950 to 0.56787, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 19/2000
#  - 1s - loss: 0.6212 - accuracy: 0.6699 - val_loss: 0.5851 - val_accuracy: 0.6255
#
# Epoch 00019: val_loss did not improve from 0.56787
# Epoch 20/2000
#  - 1s - loss: 0.6324 - accuracy: 0.6453 - val_loss: 0.7489 - val_accuracy: 0.4514
#
# Epoch 00020: val_loss did not improve from 0.56787
# Epoch 21/2000
#  - 1s - loss: 0.6277 - accuracy: 0.6412 - val_loss: 0.6794 - val_accuracy: 0.5913
#
# Epoch 00021: val_loss did not improve from 0.56787
# Epoch 22/2000
#  - 1s - loss: 0.6134 - accuracy: 0.6699 - val_loss: 0.7998 - val_accuracy: 0.6389
#
# Epoch 00022: val_loss did not improve from 0.56787
# Epoch 23/2000
#  - 1s - loss: 0.5983 - accuracy: 0.6846 - val_loss: 0.6186 - val_accuracy: 0.5762
#
# Epoch 00023: val_loss did not improve from 0.56787
# Epoch 24/2000
#  - 1s - loss: 0.5903 - accuracy: 0.6844 - val_loss: 0.4268 - val_accuracy: 0.6467
#
# Epoch 00024: val_loss improved from 0.56787 to 0.42678, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 25/2000
#  - 1s - loss: 0.6059 - accuracy: 0.6854 - val_loss: 0.6398 - val_accuracy: 0.5795
#
# Epoch 00025: val_loss did not improve from 0.42678
# Epoch 26/2000
#  - 1s - loss: 0.5969 - accuracy: 0.6888 - val_loss: 0.6587 - val_accuracy: 0.5238
#
# Epoch 00026: val_loss did not improve from 0.42678
# Epoch 27/2000
#  - 1s - loss: 0.5935 - accuracy: 0.6802 - val_loss: 0.9416 - val_accuracy: 0.5659
#
# Epoch 00027: val_loss did not improve from 0.42678
# Epoch 28/2000
#  - 1s - loss: 0.5857 - accuracy: 0.6998 - val_loss: 0.9170 - val_accuracy: 0.4965
#
# Epoch 00028: val_loss did not improve from 0.42678
# Epoch 29/2000
#  - 1s - loss: 0.5926 - accuracy: 0.6697 - val_loss: 0.7623 - val_accuracy: 0.6183
#
# Epoch 00029: val_loss did not improve from 0.42678
# Epoch 30/2000
#  - 1s - loss: 0.5780 - accuracy: 0.7048 - val_loss: 0.7570 - val_accuracy: 0.6124
#
# Epoch 00030: val_loss did not improve from 0.42678
# Epoch 31/2000
#  - 1s - loss: 0.5685 - accuracy: 0.7152 - val_loss: 0.6680 - val_accuracy: 0.5737
#
# Epoch 00031: val_loss did not improve from 0.42678
# Epoch 32/2000
#  - 1s - loss: 0.5691 - accuracy: 0.7171 - val_loss: 0.7524 - val_accuracy: 0.5361
#
# Epoch 00032: val_loss did not improve from 0.42678
# Epoch 33/2000
#  - 1s - loss: 0.5759 - accuracy: 0.7157 - val_loss: 0.8601 - val_accuracy: 0.4586
#
# Epoch 00033: val_loss did not improve from 0.42678
# Epoch 34/2000
#  - 1s - loss: 0.5902 - accuracy: 0.6553 - val_loss: 0.5958 - val_accuracy: 0.5907
#
# Epoch 00034: val_loss did not improve from 0.42678
# Epoch 35/2000
#  - 1s - loss: 0.5871 - accuracy: 0.7010 - val_loss: 1.1221 - val_accuracy: 0.5506
#
# Epoch 00035: val_loss did not improve from 0.42678
# Epoch 36/2000
#  - 1s - loss: 0.5594 - accuracy: 0.7056 - val_loss: 0.8029 - val_accuracy: 0.6213
#
# Epoch 00036: val_loss did not improve from 0.42678
# Epoch 37/2000
#  - 1s - loss: 0.5465 - accuracy: 0.7371 - val_loss: 0.6278 - val_accuracy: 0.6225
#
# Epoch 00037: val_loss did not improve from 0.42678
# Epoch 38/2000
#  - 1s - loss: 0.5567 - accuracy: 0.7351 - val_loss: 0.5273 - val_accuracy: 0.5706
#
# Epoch 00038: val_loss did not improve from 0.42678
# Epoch 39/2000
#  - 1s - loss: 0.5546 - accuracy: 0.7235 - val_loss: 1.0831 - val_accuracy: 0.4804
#
# Epoch 00039: val_loss did not improve from 0.42678
# Epoch 40/2000
#  - 1s - loss: 0.5439 - accuracy: 0.7320 - val_loss: 0.9905 - val_accuracy: 0.5408
#
# Epoch 00040: val_loss did not improve from 0.42678
# Epoch 41/2000
#  - 1s - loss: 0.5388 - accuracy: 0.7540 - val_loss: 0.4326 - val_accuracy: 0.5333
#
# Epoch 00041: val_loss did not improve from 0.42678
# Epoch 42/2000
#  - 1s - loss: 0.5435 - accuracy: 0.7282 - val_loss: 1.0048 - val_accuracy: 0.5606
#
# Epoch 00042: val_loss did not improve from 0.42678
# Epoch 43/2000
#  - 1s - loss: 0.5339 - accuracy: 0.7567 - val_loss: 1.1655 - val_accuracy: 0.5617
#
# Epoch 00043: val_loss did not improve from 0.42678
# Epoch 44/2000
#  - 1s - loss: 0.5339 - accuracy: 0.7457 - val_loss: 0.5442 - val_accuracy: 0.5940
#
# Epoch 00044: val_loss did not improve from 0.42678
# Epoch 45/2000
#  - 1s - loss: 0.5304 - accuracy: 0.7540 - val_loss: 0.6229 - val_accuracy: 0.5860
#
# Epoch 00045: val_loss did not improve from 0.42678
# Epoch 46/2000
#  - 1s - loss: 0.5117 - accuracy: 0.7625 - val_loss: 0.4037 - val_accuracy: 0.6470
#
# Epoch 00046: val_loss improved from 0.42678 to 0.40368, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 47/2000
#  - 1s - loss: 0.5231 - accuracy: 0.7622 - val_loss: 0.4988 - val_accuracy: 0.6082
#
# Epoch 00047: val_loss did not improve from 0.40368
# Epoch 48/2000
#  - 1s - loss: 0.5158 - accuracy: 0.7689 - val_loss: 0.6837 - val_accuracy: 0.4987
#
# Epoch 00048: val_loss did not improve from 0.40368
# Epoch 49/2000
#  - 1s - loss: 0.5140 - accuracy: 0.7623 - val_loss: 0.6216 - val_accuracy: 0.6578
#
# Epoch 00049: val_loss did not improve from 0.40368
# Epoch 50/2000
#  - 1s - loss: 0.5183 - accuracy: 0.7575 - val_loss: 0.6219 - val_accuracy: 0.6436
#
# Epoch 00050: val_loss did not improve from 0.40368
# Epoch 51/2000
#  - 1s - loss: 0.5024 - accuracy: 0.7875 - val_loss: 0.5540 - val_accuracy: 0.5263
#
# Epoch 00051: val_loss did not improve from 0.40368
# Epoch 52/2000
#  - 1s - loss: 0.5050 - accuracy: 0.7663 - val_loss: 0.8292 - val_accuracy: 0.6049
#
# Epoch 00052: val_loss did not improve from 0.40368
# Epoch 53/2000
#  - 1s - loss: 0.4956 - accuracy: 0.7900 - val_loss: 0.4576 - val_accuracy: 0.5988
#
# Epoch 00053: val_loss did not improve from 0.40368
# Epoch 54/2000
#  - 1s - loss: 0.4916 - accuracy: 0.7911 - val_loss: 0.3411 - val_accuracy: 0.6280
#
# Epoch 00054: val_loss improved from 0.40368 to 0.34111, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 55/2000
#  - 1s - loss: 0.5032 - accuracy: 0.7828 - val_loss: 0.8453 - val_accuracy: 0.5004
#
# Epoch 00055: val_loss did not improve from 0.34111
# Epoch 56/2000
#  - 1s - loss: 0.5070 - accuracy: 0.7619 - val_loss: 0.5896 - val_accuracy: 0.5600
#
# Epoch 00056: val_loss did not improve from 0.34111
# Epoch 57/2000
#  - 1s - loss: 0.5012 - accuracy: 0.7815 - val_loss: 0.8720 - val_accuracy: 0.4876
#
# Epoch 00057: val_loss did not improve from 0.34111
# Epoch 58/2000
#  - 1s - loss: 0.5163 - accuracy: 0.7436 - val_loss: 1.2519 - val_accuracy: 0.4946
#
# Epoch 00058: val_loss did not improve from 0.34111
# Epoch 59/2000
#  - 1s - loss: 0.4892 - accuracy: 0.7850 - val_loss: 0.9495 - val_accuracy: 0.5807
#
# Epoch 00059: val_loss did not improve from 0.34111
# Epoch 60/2000
#  - 1s - loss: 0.4720 - accuracy: 0.7969 - val_loss: 1.0796 - val_accuracy: 0.6386
#
# Epoch 00060: val_loss did not improve from 0.34111
# Epoch 61/2000
#  - 1s - loss: 0.4771 - accuracy: 0.8032 - val_loss: 0.8094 - val_accuracy: 0.5085
#
# Epoch 00061: val_loss did not improve from 0.34111
# Epoch 62/2000
#  - 1s - loss: 0.4868 - accuracy: 0.7738 - val_loss: 0.6132 - val_accuracy: 0.5383
#
# Epoch 00062: val_loss did not improve from 0.34111
# Epoch 63/2000
#  - 1s - loss: 0.4669 - accuracy: 0.8007 - val_loss: 0.5867 - val_accuracy: 0.6408
#
# Epoch 00063: val_loss did not improve from 0.34111
# Epoch 64/2000
#  - 1s - loss: 0.4667 - accuracy: 0.8062 - val_loss: 0.9908 - val_accuracy: 0.6166
#
# Epoch 00064: val_loss did not improve from 0.34111
# Epoch 65/2000
#  - 1s - loss: 0.4767 - accuracy: 0.8007 - val_loss: 0.5317 - val_accuracy: 0.5628
#
# Epoch 00065: val_loss did not improve from 0.34111
# Epoch 66/2000
#  - 1s - loss: 0.4643 - accuracy: 0.8157 - val_loss: 0.8321 - val_accuracy: 0.5280
#
# Epoch 00066: val_loss did not improve from 0.34111
# Epoch 67/2000
#  - 1s - loss: 0.4780 - accuracy: 0.7742 - val_loss: 0.9075 - val_accuracy: 0.5169
#
# Epoch 00067: val_loss did not improve from 0.34111
# Epoch 68/2000
#  - 1s - loss: 0.4496 - accuracy: 0.8117 - val_loss: 0.3820 - val_accuracy: 0.6308
#
# Epoch 00068: val_loss did not improve from 0.34111
# Epoch 69/2000
#  - 1s - loss: 0.4594 - accuracy: 0.8208 - val_loss: 0.6402 - val_accuracy: 0.5467
#
# Epoch 00069: val_loss did not improve from 0.34111
# Epoch 70/2000
#  - 1s - loss: 0.4577 - accuracy: 0.7919 - val_loss: 0.6535 - val_accuracy: 0.5394
#
# Epoch 00070: val_loss did not improve from 0.34111
# Epoch 71/2000
#  - 1s - loss: 0.4356 - accuracy: 0.8238 - val_loss: 0.8849 - val_accuracy: 0.6199
#
# Epoch 00071: val_loss did not improve from 0.34111
# Epoch 72/2000
#  - 1s - loss: 0.4427 - accuracy: 0.8390 - val_loss: 0.7922 - val_accuracy: 0.6113
#
# Epoch 00072: val_loss did not improve from 0.34111
# Epoch 73/2000
#  - 1s - loss: 0.4372 - accuracy: 0.8305 - val_loss: 0.5896 - val_accuracy: 0.5542
#
# Epoch 00073: val_loss did not improve from 0.34111
# Epoch 74/2000
#  - 1s - loss: 0.4356 - accuracy: 0.8259 - val_loss: 1.0277 - val_accuracy: 0.5308
#
# Epoch 00074: val_loss did not improve from 0.34111
# Epoch 75/2000
#  - 1s - loss: 0.4283 - accuracy: 0.8373 - val_loss: 0.8655 - val_accuracy: 0.5497
#
# Epoch 00075: val_loss did not improve from 0.34111
# Epoch 76/2000
#  - 1s - loss: 0.4304 - accuracy: 0.8355 - val_loss: 0.6403 - val_accuracy: 0.5489
#
# Epoch 00076: val_loss did not improve from 0.34111
# Epoch 77/2000
#  - 1s - loss: 0.4224 - accuracy: 0.8348 - val_loss: 1.0956 - val_accuracy: 0.5648
#
# Epoch 00077: val_loss did not improve from 0.34111
# Epoch 78/2000
#  - 1s - loss: 0.4243 - accuracy: 0.8309 - val_loss: 0.2874 - val_accuracy: 0.5759
#
# Epoch 00078: val_loss improved from 0.34111 to 0.28743, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 79/2000
#  - 1s - loss: 0.4064 - accuracy: 0.8498 - val_loss: 1.0712 - val_accuracy: 0.6094
#
# Epoch 00079: val_loss did not improve from 0.28743
# Epoch 80/2000
#  - 1s - loss: 0.4056 - accuracy: 0.8577 - val_loss: 0.6724 - val_accuracy: 0.6272
#
# Epoch 00080: val_loss did not improve from 0.28743
# Epoch 81/2000
#  - 1s - loss: 0.4069 - accuracy: 0.8501 - val_loss: 0.7162 - val_accuracy: 0.6417
#
# Epoch 00081: val_loss did not improve from 0.28743
# Epoch 82/2000
#  - 1s - loss: 0.4012 - accuracy: 0.8551 - val_loss: 0.6822 - val_accuracy: 0.6133
#
# Epoch 00082: val_loss did not improve from 0.28743
# Epoch 83/2000
#  - 1s - loss: 0.3979 - accuracy: 0.8587 - val_loss: 0.7548 - val_accuracy: 0.6197
#
# Epoch 00083: val_loss did not improve from 0.28743
# Epoch 84/2000
#  - 1s - loss: 0.4005 - accuracy: 0.8667 - val_loss: 1.6763 - val_accuracy: 0.5272
#
# Epoch 00084: val_loss did not improve from 0.28743
# Epoch 85/2000
#  - 1s - loss: 0.4067 - accuracy: 0.8392 - val_loss: 0.5460 - val_accuracy: 0.5996
#
# Epoch 00085: val_loss did not improve from 0.28743
# Epoch 86/2000
#  - 1s - loss: 0.3969 - accuracy: 0.8636 - val_loss: 0.4501 - val_accuracy: 0.6141
#
# Epoch 00086: val_loss did not improve from 0.28743
# Epoch 87/2000
#  - 1s - loss: 0.3903 - accuracy: 0.8724 - val_loss: 0.9597 - val_accuracy: 0.5681
#
# Epoch 00087: val_loss did not improve from 0.28743
# Epoch 88/2000
#  - 1s - loss: 0.3913 - accuracy: 0.8694 - val_loss: 0.9151 - val_accuracy: 0.6258
#
# Epoch 00088: val_loss did not improve from 0.28743
# Epoch 89/2000
#  - 1s - loss: 0.3820 - accuracy: 0.8679 - val_loss: 0.6284 - val_accuracy: 0.6344
#
# Epoch 00089: val_loss did not improve from 0.28743
# Epoch 90/2000
#  - 1s - loss: 0.3891 - accuracy: 0.8594 - val_loss: 0.6508 - val_accuracy: 0.6007
#
# Epoch 00090: val_loss did not improve from 0.28743
# Epoch 91/2000
#  - 1s - loss: 0.3835 - accuracy: 0.8624 - val_loss: 0.2705 - val_accuracy: 0.5673
#
# Epoch 00091: val_loss improved from 0.28743 to 0.27053, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 92/2000
#  - 1s - loss: 0.3834 - accuracy: 0.8717 - val_loss: 0.8213 - val_accuracy: 0.6213
#
# Epoch 00092: val_loss did not improve from 0.27053
# Epoch 93/2000
#  - 1s - loss: 0.3838 - accuracy: 0.8683 - val_loss: 0.4884 - val_accuracy: 0.6016
#
# Epoch 00093: val_loss did not improve from 0.27053
# Epoch 94/2000
#  - 1s - loss: 0.3820 - accuracy: 0.8691 - val_loss: 0.6877 - val_accuracy: 0.6063
#
# Epoch 00094: val_loss did not improve from 0.27053
# Epoch 95/2000
#  - 1s - loss: 0.3785 - accuracy: 0.8719 - val_loss: 1.0622 - val_accuracy: 0.5467
#
# Epoch 00095: val_loss did not improve from 0.27053
# Epoch 96/2000
#  - 1s - loss: 0.3814 - accuracy: 0.8660 - val_loss: 0.8420 - val_accuracy: 0.5244
#
# Epoch 00096: val_loss did not improve from 0.27053
# Epoch 97/2000
#  - 1s - loss: 0.3757 - accuracy: 0.8641 - val_loss: 0.3781 - val_accuracy: 0.6264
#
# Epoch 00097: val_loss did not improve from 0.27053
# Epoch 98/2000
#  - 1s - loss: 0.3725 - accuracy: 0.8817 - val_loss: 0.4092 - val_accuracy: 0.5910
#
# Epoch 00098: val_loss did not improve from 0.27053
# Epoch 99/2000
#  - 1s - loss: 0.3667 - accuracy: 0.8835 - val_loss: 0.4312 - val_accuracy: 0.5528
#
# Epoch 00099: val_loss did not improve from 0.27053
# Epoch 100/2000
#  - 1s - loss: 0.3535 - accuracy: 0.8835 - val_loss: 1.3265 - val_accuracy: 0.5988
#
# Epoch 00100: val_loss did not improve from 0.27053
# Epoch 101/2000
#  - 1s - loss: 0.3529 - accuracy: 0.8922 - val_loss: 0.2118 - val_accuracy: 0.6481
#
# Epoch 00101: val_loss improved from 0.27053 to 0.21183, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 102/2000
#  - 1s - loss: 0.3570 - accuracy: 0.8888 - val_loss: 0.9474 - val_accuracy: 0.5653
#
# Epoch 00102: val_loss did not improve from 0.21183
# Epoch 103/2000
#  - 1s - loss: 0.3562 - accuracy: 0.8838 - val_loss: 0.2732 - val_accuracy: 0.6197
#
# Epoch 00103: val_loss did not improve from 0.21183
# Epoch 104/2000
#  - 1s - loss: 0.3483 - accuracy: 0.8911 - val_loss: 1.1998 - val_accuracy: 0.5876
#
# Epoch 00104: val_loss did not improve from 0.21183
# Epoch 105/2000
#  - 1s - loss: 0.3434 - accuracy: 0.8881 - val_loss: 0.5043 - val_accuracy: 0.5918
#
# Epoch 00105: val_loss did not improve from 0.21183
# Epoch 106/2000
#  - 1s - loss: 0.3366 - accuracy: 0.9003 - val_loss: 0.2937 - val_accuracy: 0.5695
#
# Epoch 00106: val_loss did not improve from 0.21183
# Epoch 107/2000
#  - 1s - loss: 0.3362 - accuracy: 0.8976 - val_loss: 0.6188 - val_accuracy: 0.5926
#
# Epoch 00107: val_loss did not improve from 0.21183
# Epoch 108/2000
#  - 1s - loss: 0.3380 - accuracy: 0.9044 - val_loss: 0.6494 - val_accuracy: 0.5514
#
# Epoch 00108: val_loss did not improve from 0.21183
# Epoch 109/2000
#  - 1s - loss: 0.3473 - accuracy: 0.8778 - val_loss: 0.2789 - val_accuracy: 0.6467
#
# Epoch 00109: val_loss did not improve from 0.21183
# Epoch 110/2000
#  - 1s - loss: 0.3351 - accuracy: 0.8982 - val_loss: 0.6778 - val_accuracy: 0.5829
#
# Epoch 00110: val_loss did not improve from 0.21183
# Epoch 111/2000
#  - 1s - loss: 0.3284 - accuracy: 0.8980 - val_loss: 0.6538 - val_accuracy: 0.5762
#
# Epoch 00111: val_loss did not improve from 0.21183
# Epoch 112/2000
#  - 1s - loss: 0.3289 - accuracy: 0.9122 - val_loss: 1.0969 - val_accuracy: 0.5277
#
# Epoch 00112: val_loss did not improve from 0.21183
# Epoch 113/2000
#  - 1s - loss: 0.3351 - accuracy: 0.8753 - val_loss: 0.7249 - val_accuracy: 0.6241
#
# Epoch 00113: val_loss did not improve from 0.21183
# Epoch 114/2000
#  - 1s - loss: 0.3167 - accuracy: 0.9091 - val_loss: 0.4605 - val_accuracy: 0.6091
#
# Epoch 00114: val_loss did not improve from 0.21183
# Epoch 115/2000
#  - 1s - loss: 0.3138 - accuracy: 0.9157 - val_loss: 0.3985 - val_accuracy: 0.5598
#
# Epoch 00115: val_loss did not improve from 0.21183
# Epoch 116/2000
#  - 1s - loss: 0.3118 - accuracy: 0.9060 - val_loss: 0.3683 - val_accuracy: 0.6024
#
# Epoch 00116: val_loss did not improve from 0.21183
# Epoch 117/2000
#  - 1s - loss: 0.3084 - accuracy: 0.9182 - val_loss: 0.7097 - val_accuracy: 0.5857
#
# Epoch 00117: val_loss did not improve from 0.21183
# Epoch 118/2000
#  - 1s - loss: 0.3007 - accuracy: 0.9113 - val_loss: 0.2652 - val_accuracy: 0.6347
#
# Epoch 00118: val_loss did not improve from 0.21183
# Epoch 119/2000
#  - 1s - loss: 0.3068 - accuracy: 0.9193 - val_loss: 0.8926 - val_accuracy: 0.5637
#
# Epoch 00119: val_loss did not improve from 0.21183
# Epoch 120/2000
#  - 1s - loss: 0.3150 - accuracy: 0.8974 - val_loss: 0.8195 - val_accuracy: 0.5745
#
# Epoch 00120: val_loss did not improve from 0.21183
# Epoch 121/2000
#  - 1s - loss: 0.3179 - accuracy: 0.9022 - val_loss: 0.8321 - val_accuracy: 0.5854
#
# Epoch 00121: val_loss did not improve from 0.21183
# Epoch 122/2000
#  - 1s - loss: 0.3135 - accuracy: 0.8980 - val_loss: 0.8479 - val_accuracy: 0.6158
#
# Epoch 00122: val_loss did not improve from 0.21183
# Epoch 123/2000
#  - 1s - loss: 0.2989 - accuracy: 0.9264 - val_loss: 0.5462 - val_accuracy: 0.5397
#
# Epoch 00123: val_loss did not improve from 0.21183
# Epoch 124/2000
#  - 1s - loss: 0.3109 - accuracy: 0.8962 - val_loss: 0.7459 - val_accuracy: 0.6043
#
# Epoch 00124: val_loss did not improve from 0.21183
# Epoch 125/2000
#  - 1s - loss: 0.2918 - accuracy: 0.9225 - val_loss: 0.4093 - val_accuracy: 0.6269
#
# Epoch 00125: val_loss did not improve from 0.21183
# Epoch 126/2000
#  - 1s - loss: 0.2901 - accuracy: 0.9242 - val_loss: 0.8311 - val_accuracy: 0.6255
#
# Epoch 00126: val_loss did not improve from 0.21183
# Epoch 127/2000
#  - 1s - loss: 0.2913 - accuracy: 0.9243 - val_loss: 0.7801 - val_accuracy: 0.5467
#
# Epoch 00127: val_loss did not improve from 0.21183
# Epoch 128/2000
#  - 1s - loss: 0.2956 - accuracy: 0.9160 - val_loss: 0.3546 - val_accuracy: 0.6239
#
# Epoch 00128: val_loss did not improve from 0.21183
# Epoch 129/2000
#  - 1s - loss: 0.2931 - accuracy: 0.9247 - val_loss: 0.9177 - val_accuracy: 0.5180
#
# Epoch 00129: val_loss did not improve from 0.21183
# Epoch 130/2000
#  - 1s - loss: 0.3038 - accuracy: 0.8907 - val_loss: 0.9975 - val_accuracy: 0.5960
#
# Epoch 00130: val_loss did not improve from 0.21183
# Epoch 131/2000
#  - 1s - loss: 0.2830 - accuracy: 0.9340 - val_loss: 0.8088 - val_accuracy: 0.5570
#
# Epoch 00131: val_loss did not improve from 0.21183
# Epoch 132/2000
#  - 1s - loss: 0.2876 - accuracy: 0.9142 - val_loss: 0.5577 - val_accuracy: 0.6191
#
# Epoch 00132: val_loss did not improve from 0.21183
# Epoch 133/2000
#  - 1s - loss: 0.2789 - accuracy: 0.9307 - val_loss: 0.5683 - val_accuracy: 0.6219
#
# Epoch 00133: val_loss did not improve from 0.21183
# Epoch 134/2000
#  - 1s - loss: 0.2809 - accuracy: 0.9258 - val_loss: 0.5536 - val_accuracy: 0.5932
#
# Epoch 00134: val_loss did not improve from 0.21183
# Epoch 135/2000
#  - 1s - loss: 0.2674 - accuracy: 0.9346 - val_loss: 0.8252 - val_accuracy: 0.5885
#
# Epoch 00135: val_loss did not improve from 0.21183
# Epoch 136/2000
#  - 1s - loss: 0.2697 - accuracy: 0.9380 - val_loss: 1.0011 - val_accuracy: 0.5846
#
# Epoch 00136: val_loss did not improve from 0.21183
# Epoch 137/2000
#  - 1s - loss: 0.2788 - accuracy: 0.9276 - val_loss: 0.8942 - val_accuracy: 0.6434
#
# Epoch 00137: val_loss did not improve from 0.21183
# Epoch 138/2000
#  - 1s - loss: 0.2721 - accuracy: 0.9259 - val_loss: 1.4124 - val_accuracy: 0.6110
#
# Epoch 00138: val_loss did not improve from 0.21183
# Epoch 139/2000
#  - 1s - loss: 0.2600 - accuracy: 0.9393 - val_loss: 0.3351 - val_accuracy: 0.6180
#
# Epoch 00139: val_loss did not improve from 0.21183
# Epoch 140/2000
#  - 1s - loss: 0.2565 - accuracy: 0.9430 - val_loss: 0.4915 - val_accuracy: 0.5913
#
# Epoch 00140: val_loss did not improve from 0.21183
# Epoch 141/2000
#  - 1s - loss: 0.2625 - accuracy: 0.9307 - val_loss: 0.9326 - val_accuracy: 0.6046
#
# Epoch 00141: val_loss did not improve from 0.21183
# Epoch 142/2000
#  - 1s - loss: 0.2562 - accuracy: 0.9448 - val_loss: 1.0827 - val_accuracy: 0.5715
#
# Epoch 00142: val_loss did not improve from 0.21183
# Epoch 143/2000
#  - 1s - loss: 0.2540 - accuracy: 0.9446 - val_loss: 1.0646 - val_accuracy: 0.5626
#
# Epoch 00143: val_loss did not improve from 0.21183
# Epoch 144/2000
#  - 1s - loss: 0.2625 - accuracy: 0.9337 - val_loss: 0.5471 - val_accuracy: 0.6144
#
# Epoch 00144: val_loss did not improve from 0.21183
# Epoch 145/2000
#  - 1s - loss: 0.2628 - accuracy: 0.9362 - val_loss: 0.4096 - val_accuracy: 0.5497
#
# Epoch 00145: val_loss did not improve from 0.21183
# Epoch 146/2000
#  - 1s - loss: 0.2552 - accuracy: 0.9382 - val_loss: 0.5749 - val_accuracy: 0.6043
#
# Epoch 00146: val_loss did not improve from 0.21183
# Epoch 147/2000
#  - 1s - loss: 0.2442 - accuracy: 0.9485 - val_loss: 0.4113 - val_accuracy: 0.5673
#
# Epoch 00147: val_loss did not improve from 0.21183
# Epoch 148/2000
#  - 1s - loss: 0.2561 - accuracy: 0.9313 - val_loss: 0.8719 - val_accuracy: 0.5720
#
# Epoch 00148: val_loss did not improve from 0.21183
# Epoch 149/2000
#  - 1s - loss: 0.2384 - accuracy: 0.9470 - val_loss: 1.0358 - val_accuracy: 0.6071
#
# Epoch 00149: val_loss did not improve from 0.21183
# Epoch 150/2000
#  - 1s - loss: 0.2358 - accuracy: 0.9530 - val_loss: 0.5179 - val_accuracy: 0.6116
#
# Epoch 00150: val_loss did not improve from 0.21183
# Epoch 151/2000
#  - 1s - loss: 0.2387 - accuracy: 0.9502 - val_loss: 0.3348 - val_accuracy: 0.5807
#
# Epoch 00151: val_loss did not improve from 0.21183
# Epoch 152/2000
#  - 1s - loss: 0.2392 - accuracy: 0.9428 - val_loss: 0.8985 - val_accuracy: 0.5868
#
# Epoch 00152: val_loss did not improve from 0.21183
# Epoch 153/2000
#  - 1s - loss: 0.2273 - accuracy: 0.9564 - val_loss: 0.5441 - val_accuracy: 0.6389
#
# Epoch 00153: val_loss did not improve from 0.21183
# Epoch 154/2000
#  - 1s - loss: 0.2325 - accuracy: 0.9582 - val_loss: 0.5110 - val_accuracy: 0.6041
#
# Epoch 00154: val_loss did not improve from 0.21183
# Epoch 155/2000
#  - 1s - loss: 0.2276 - accuracy: 0.9539 - val_loss: 0.7933 - val_accuracy: 0.6119
#
# Epoch 00155: val_loss did not improve from 0.21183
# Epoch 156/2000
#  - 1s - loss: 0.2263 - accuracy: 0.9567 - val_loss: 0.3498 - val_accuracy: 0.6389
#
# Epoch 00156: val_loss did not improve from 0.21183
# Epoch 157/2000
#  - 1s - loss: 0.2287 - accuracy: 0.9504 - val_loss: 0.9808 - val_accuracy: 0.5829
#
# Epoch 00157: val_loss did not improve from 0.21183
# Epoch 158/2000
#  - 1s - loss: 0.2193 - accuracy: 0.9572 - val_loss: 0.6416 - val_accuracy: 0.6060
#
# Epoch 00158: val_loss did not improve from 0.21183
# Epoch 159/2000
#  - 1s - loss: 0.2210 - accuracy: 0.9578 - val_loss: 0.8911 - val_accuracy: 0.6032
#
# Epoch 00159: val_loss did not improve from 0.21183
# Epoch 160/2000
#  - 1s - loss: 0.2269 - accuracy: 0.9544 - val_loss: 0.4319 - val_accuracy: 0.5375
#
# Epoch 00160: val_loss did not improve from 0.21183
# Epoch 161/2000
#  - 1s - loss: 0.2290 - accuracy: 0.9456 - val_loss: 1.2499 - val_accuracy: 0.6108
#
# Epoch 00161: val_loss did not improve from 0.21183
# Epoch 162/2000
#  - 1s - loss: 0.2153 - accuracy: 0.9618 - val_loss: 0.5339 - val_accuracy: 0.5876
#
# Epoch 00162: val_loss did not improve from 0.21183
# Epoch 163/2000
#  - 1s - loss: 0.2127 - accuracy: 0.9622 - val_loss: 0.6317 - val_accuracy: 0.6071
#
# Epoch 00163: val_loss did not improve from 0.21183
# Epoch 164/2000
#  - 1s - loss: 0.2093 - accuracy: 0.9634 - val_loss: 1.1050 - val_accuracy: 0.6342
#
# Epoch 00164: val_loss did not improve from 0.21183
# Epoch 165/2000
#  - 1s - loss: 0.2188 - accuracy: 0.9609 - val_loss: 0.4917 - val_accuracy: 0.5960
#
# Epoch 00165: val_loss did not improve from 0.21183
# Epoch 166/2000
#  - 1s - loss: 0.2172 - accuracy: 0.9519 - val_loss: 0.7073 - val_accuracy: 0.5960
#
# Epoch 00166: val_loss did not improve from 0.21183
# Epoch 167/2000
#  - 1s - loss: 0.2111 - accuracy: 0.9628 - val_loss: 1.0250 - val_accuracy: 0.5358
#
# Epoch 00167: val_loss did not improve from 0.21183
# Epoch 168/2000
#  - 1s - loss: 0.2376 - accuracy: 0.9326 - val_loss: 0.7243 - val_accuracy: 0.5770
#
# Epoch 00168: val_loss did not improve from 0.21183
# Epoch 169/2000
#  - 1s - loss: 0.2176 - accuracy: 0.9510 - val_loss: 0.8266 - val_accuracy: 0.6623
#
# Epoch 00169: val_loss did not improve from 0.21183
# Epoch 170/2000
#  - 1s - loss: 0.2197 - accuracy: 0.9575 - val_loss: 0.4512 - val_accuracy: 0.5556
#
# Epoch 00170: val_loss did not improve from 0.21183
# Epoch 171/2000
#  - 1s - loss: 0.2145 - accuracy: 0.9444 - val_loss: 0.5897 - val_accuracy: 0.6172
#
# Epoch 00171: val_loss did not improve from 0.21183
# Epoch 172/2000
#  - 1s - loss: 0.2003 - accuracy: 0.9641 - val_loss: 0.3694 - val_accuracy: 0.6024
#
# Epoch 00172: val_loss did not improve from 0.21183
# Epoch 173/2000
#  - 1s - loss: 0.1917 - accuracy: 0.9658 - val_loss: 0.5509 - val_accuracy: 0.5954
#
# Epoch 00173: val_loss did not improve from 0.21183
# Epoch 174/2000
#  - 1s - loss: 0.1908 - accuracy: 0.9718 - val_loss: 1.9328 - val_accuracy: 0.6509
#
# Epoch 00174: val_loss did not improve from 0.21183
# Epoch 175/2000
#  - 1s - loss: 0.1914 - accuracy: 0.9667 - val_loss: 0.2778 - val_accuracy: 0.6562
#
# Epoch 00175: val_loss did not improve from 0.21183
# Epoch 176/2000
#  - 1s - loss: 0.1921 - accuracy: 0.9680 - val_loss: 1.1031 - val_accuracy: 0.6105
#
# Epoch 00176: val_loss did not improve from 0.21183
# Epoch 177/2000
#  - 1s - loss: 0.1826 - accuracy: 0.9735 - val_loss: 0.9566 - val_accuracy: 0.6016
#
# Epoch 00177: val_loss did not improve from 0.21183
# Epoch 178/2000
#  - 1s - loss: 0.1845 - accuracy: 0.9700 - val_loss: 1.9510 - val_accuracy: 0.5940
#
# Epoch 00178: val_loss did not improve from 0.21183
# Epoch 179/2000
#  - 1s - loss: 0.1795 - accuracy: 0.9739 - val_loss: 0.7378 - val_accuracy: 0.6091
#
# Epoch 00179: val_loss did not improve from 0.21183
# Epoch 180/2000
#  - 1s - loss: 0.1812 - accuracy: 0.9736 - val_loss: 1.4586 - val_accuracy: 0.5821
#
# Epoch 00180: val_loss did not improve from 0.21183
# Epoch 181/2000
#  - 1s - loss: 0.1890 - accuracy: 0.9666 - val_loss: 0.8357 - val_accuracy: 0.6010
#
# Epoch 00181: val_loss did not improve from 0.21183
# Epoch 182/2000
#  - 1s - loss: 0.1847 - accuracy: 0.9718 - val_loss: 0.5888 - val_accuracy: 0.6160
#
# Epoch 00182: val_loss did not improve from 0.21183
# Epoch 183/2000
#  - 1s - loss: 0.1842 - accuracy: 0.9654 - val_loss: 0.8350 - val_accuracy: 0.5949
#
# Epoch 00183: val_loss did not improve from 0.21183
# Epoch 184/2000
#  - 1s - loss: 0.1755 - accuracy: 0.9742 - val_loss: 0.9276 - val_accuracy: 0.6383
#
# Epoch 00184: val_loss did not improve from 0.21183
# Epoch 185/2000
#  - 1s - loss: 0.1784 - accuracy: 0.9753 - val_loss: 0.6782 - val_accuracy: 0.6108
#
# Epoch 00185: val_loss did not improve from 0.21183
# Epoch 186/2000
#  - 1s - loss: 0.1842 - accuracy: 0.9609 - val_loss: 0.2967 - val_accuracy: 0.6096
#
# Epoch 00186: val_loss did not improve from 0.21183
# Epoch 187/2000
#  - 1s - loss: 0.1707 - accuracy: 0.9761 - val_loss: 0.3215 - val_accuracy: 0.6105
#
# Epoch 00187: val_loss did not improve from 0.21183
# Epoch 188/2000
#  - 1s - loss: 0.1670 - accuracy: 0.9776 - val_loss: 0.6627 - val_accuracy: 0.5938
#
# Epoch 00188: val_loss did not improve from 0.21183
# Epoch 189/2000
#  - 1s - loss: 0.1688 - accuracy: 0.9719 - val_loss: 1.1748 - val_accuracy: 0.5996
#
# Epoch 00189: val_loss did not improve from 0.21183
# Epoch 190/2000
#  - 1s - loss: 0.1645 - accuracy: 0.9803 - val_loss: 0.2265 - val_accuracy: 0.5821
#
# Epoch 00190: val_loss did not improve from 0.21183
# Epoch 191/2000
#  - 1s - loss: 0.1655 - accuracy: 0.9738 - val_loss: 0.4603 - val_accuracy: 0.5991
#
# Epoch 00191: val_loss did not improve from 0.21183
# Epoch 192/2000
#  - 1s - loss: 0.1630 - accuracy: 0.9802 - val_loss: 1.4308 - val_accuracy: 0.5737
#
# Epoch 00192: val_loss did not improve from 0.21183
# Epoch 193/2000
#  - 1s - loss: 0.1696 - accuracy: 0.9735 - val_loss: 1.1062 - val_accuracy: 0.6138
#
# Epoch 00193: val_loss did not improve from 0.21183
# Epoch 194/2000
#  - 1s - loss: 0.1643 - accuracy: 0.9758 - val_loss: 0.8863 - val_accuracy: 0.6506
#
# Epoch 00194: val_loss did not improve from 0.21183
# Epoch 195/2000
#  - 1s - loss: 0.1606 - accuracy: 0.9803 - val_loss: 1.1069 - val_accuracy: 0.5977
#
# Epoch 00195: val_loss did not improve from 0.21183
# Epoch 196/2000
#  - 1s - loss: 0.1612 - accuracy: 0.9785 - val_loss: 0.6234 - val_accuracy: 0.6205
#
# Epoch 00196: val_loss did not improve from 0.21183
# Epoch 197/2000
#  - 1s - loss: 0.1584 - accuracy: 0.9773 - val_loss: 0.1455 - val_accuracy: 0.6350
#
# Epoch 00197: val_loss improved from 0.21183 to 0.14554, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 198/2000
#  - 1s - loss: 0.1590 - accuracy: 0.9821 - val_loss: 0.9375 - val_accuracy: 0.5949
#
# Epoch 00198: val_loss did not improve from 0.14554
# Epoch 199/2000
#  - 1s - loss: 0.1626 - accuracy: 0.9714 - val_loss: 1.1885 - val_accuracy: 0.6055
#
# Epoch 00199: val_loss did not improve from 0.14554
# Epoch 200/2000
#  - 1s - loss: 0.1559 - accuracy: 0.9824 - val_loss: 0.6561 - val_accuracy: 0.5979
#
# Epoch 00200: val_loss did not improve from 0.14554
# Epoch 201/2000
#  - 1s - loss: 0.1547 - accuracy: 0.9755 - val_loss: 0.1821 - val_accuracy: 0.6205
#
# Epoch 00201: val_loss did not improve from 0.14554
# Epoch 202/2000
#  - 1s - loss: 0.1510 - accuracy: 0.9837 - val_loss: 0.3506 - val_accuracy: 0.6052
#
# Epoch 00202: val_loss did not improve from 0.14554
# Epoch 203/2000
#  - 1s - loss: 0.1544 - accuracy: 0.9719 - val_loss: 0.3647 - val_accuracy: 0.6085
#
# Epoch 00203: val_loss did not improve from 0.14554
# Epoch 204/2000
#  - 1s - loss: 0.1418 - accuracy: 0.9833 - val_loss: 0.6623 - val_accuracy: 0.6300
#
# Epoch 00204: val_loss did not improve from 0.14554
# Epoch 205/2000
#  - 1s - loss: 0.1432 - accuracy: 0.9858 - val_loss: 1.0336 - val_accuracy: 0.6197
#
# Epoch 00205: val_loss did not improve from 0.14554
# Epoch 206/2000
#  - 1s - loss: 0.1448 - accuracy: 0.9821 - val_loss: 0.1024 - val_accuracy: 0.6021
#
# Epoch 00206: val_loss improved from 0.14554 to 0.10235, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 207/2000
#  - 1s - loss: 0.1436 - accuracy: 0.9830 - val_loss: 0.8374 - val_accuracy: 0.6183
#
# Epoch 00207: val_loss did not improve from 0.10235
# Epoch 208/2000
#  - 1s - loss: 0.1400 - accuracy: 0.9837 - val_loss: 1.3695 - val_accuracy: 0.6147
#
# Epoch 00208: val_loss did not improve from 0.10235
# Epoch 209/2000
#  - 1s - loss: 0.1391 - accuracy: 0.9850 - val_loss: 1.6099 - val_accuracy: 0.6147
#
# Epoch 00209: val_loss did not improve from 0.10235
# Epoch 210/2000
#  - 1s - loss: 0.1421 - accuracy: 0.9863 - val_loss: 0.4748 - val_accuracy: 0.5857
#
# Epoch 00210: val_loss did not improve from 0.10235
# Epoch 211/2000
#  - 1s - loss: 0.1537 - accuracy: 0.9724 - val_loss: 2.0495 - val_accuracy: 0.6105
#
# Epoch 00211: val_loss did not improve from 0.10235
# Epoch 212/2000
#  - 1s - loss: 0.1359 - accuracy: 0.9853 - val_loss: 2.5137 - val_accuracy: 0.6258
#
# Epoch 00212: val_loss did not improve from 0.10235
# Epoch 213/2000
#  - 1s - loss: 0.1310 - accuracy: 0.9887 - val_loss: 0.5425 - val_accuracy: 0.6071
#
# Epoch 00213: val_loss did not improve from 0.10235
# Epoch 214/2000
#  - 1s - loss: 0.1291 - accuracy: 0.9891 - val_loss: 2.3651 - val_accuracy: 0.6119
#
# Epoch 00214: val_loss did not improve from 0.10235
# Epoch 215/2000
#  - 1s - loss: 0.1280 - accuracy: 0.9899 - val_loss: 1.1785 - val_accuracy: 0.6183
#
# Epoch 00215: val_loss did not improve from 0.10235
# Epoch 216/2000
#  - 1s - loss: 0.1254 - accuracy: 0.9880 - val_loss: 0.9121 - val_accuracy: 0.6283
#
# Epoch 00216: val_loss did not improve from 0.10235
# Epoch 217/2000
#  - 1s - loss: 0.1304 - accuracy: 0.9889 - val_loss: 0.8199 - val_accuracy: 0.5882
#
# Epoch 00217: val_loss did not improve from 0.10235
# Epoch 218/2000
#  - 1s - loss: 0.1358 - accuracy: 0.9822 - val_loss: 1.2092 - val_accuracy: 0.6308
#
# Epoch 00218: val_loss did not improve from 0.10235
# Epoch 219/2000
#  - 1s - loss: 0.1309 - accuracy: 0.9867 - val_loss: 1.0725 - val_accuracy: 0.6144
#
# Epoch 00219: val_loss did not improve from 0.10235
# Epoch 220/2000
#  - 1s - loss: 0.1244 - accuracy: 0.9884 - val_loss: 0.9221 - val_accuracy: 0.6043
#
# Epoch 00220: val_loss did not improve from 0.10235
# Epoch 221/2000
#  - 1s - loss: 0.1241 - accuracy: 0.9903 - val_loss: 1.4835 - val_accuracy: 0.6099
#
# Epoch 00221: val_loss did not improve from 0.10235
# Epoch 222/2000
#  - 1s - loss: 0.1271 - accuracy: 0.9859 - val_loss: 0.3358 - val_accuracy: 0.5896
#
# Epoch 00222: val_loss did not improve from 0.10235
# Epoch 223/2000
#  - 1s - loss: 0.1221 - accuracy: 0.9889 - val_loss: 1.2972 - val_accuracy: 0.6007
#
# Epoch 00223: val_loss did not improve from 0.10235
# Epoch 224/2000
#  - 1s - loss: 0.1176 - accuracy: 0.9901 - val_loss: 1.8157 - val_accuracy: 0.6191
#
# Epoch 00224: val_loss did not improve from 0.10235
# Epoch 225/2000
#  - 1s - loss: 0.1180 - accuracy: 0.9920 - val_loss: 0.3635 - val_accuracy: 0.6018
#
# Epoch 00225: val_loss did not improve from 0.10235
# Epoch 226/2000
#  - 1s - loss: 0.1185 - accuracy: 0.9901 - val_loss: 1.2519 - val_accuracy: 0.6071
#
# Epoch 00226: val_loss did not improve from 0.10235
# Epoch 227/2000
#  - 1s - loss: 0.1163 - accuracy: 0.9920 - val_loss: 0.1088 - val_accuracy: 0.6077
#
# Epoch 00227: val_loss did not improve from 0.10235
# Epoch 228/2000
#  - 1s - loss: 0.1173 - accuracy: 0.9892 - val_loss: 0.9665 - val_accuracy: 0.6052
#
# Epoch 00228: val_loss did not improve from 0.10235
# Epoch 229/2000
#  - 1s - loss: 0.1194 - accuracy: 0.9893 - val_loss: 0.2932 - val_accuracy: 0.6236
#
# Epoch 00229: val_loss did not improve from 0.10235
# Epoch 230/2000
#  - 1s - loss: 0.1222 - accuracy: 0.9863 - val_loss: 0.6150 - val_accuracy: 0.6369
#
# Epoch 00230: val_loss did not improve from 0.10235
# Epoch 231/2000
#  - 1s - loss: 0.1127 - accuracy: 0.9926 - val_loss: 1.0928 - val_accuracy: 0.5921
#
# Epoch 00231: val_loss did not improve from 0.10235
# Epoch 232/2000
#  - 1s - loss: 0.1173 - accuracy: 0.9869 - val_loss: 0.9265 - val_accuracy: 0.6116
#
# Epoch 00232: val_loss did not improve from 0.10235
# Epoch 233/2000
#  - 1s - loss: 0.1085 - accuracy: 0.9924 - val_loss: 1.6589 - val_accuracy: 0.6188
#
# Epoch 00233: val_loss did not improve from 0.10235
# Epoch 234/2000
#  - 1s - loss: 0.1043 - accuracy: 0.9938 - val_loss: 0.3744 - val_accuracy: 0.6113
#
# Epoch 00234: val_loss did not improve from 0.10235
# Epoch 235/2000
#  - 1s - loss: 0.1054 - accuracy: 0.9934 - val_loss: 0.6750 - val_accuracy: 0.6158
#
# Epoch 00235: val_loss did not improve from 0.10235
# Epoch 236/2000
#  - 1s - loss: 0.1037 - accuracy: 0.9939 - val_loss: 0.7600 - val_accuracy: 0.6272
#
# Epoch 00236: val_loss did not improve from 0.10235
# Epoch 237/2000
#  - 1s - loss: 0.1097 - accuracy: 0.9931 - val_loss: 0.3708 - val_accuracy: 0.6305
#
# Epoch 00237: val_loss did not improve from 0.10235
# Epoch 238/2000
#  - 1s - loss: 0.1094 - accuracy: 0.9905 - val_loss: 0.9476 - val_accuracy: 0.6071
#
# Epoch 00238: val_loss did not improve from 0.10235
# Epoch 239/2000
#  - 1s - loss: 0.1069 - accuracy: 0.9921 - val_loss: 0.5568 - val_accuracy: 0.6057
#
# Epoch 00239: val_loss did not improve from 0.10235
# Epoch 240/2000
#  - 1s - loss: 0.1121 - accuracy: 0.9875 - val_loss: 1.0177 - val_accuracy: 0.5938
#
# Epoch 00240: val_loss did not improve from 0.10235
# Epoch 241/2000
#  - 1s - loss: 0.1082 - accuracy: 0.9899 - val_loss: 1.1586 - val_accuracy: 0.6225
#
# Epoch 00241: val_loss did not improve from 0.10235
# Epoch 242/2000
#  - 1s - loss: 0.1029 - accuracy: 0.9935 - val_loss: 0.9093 - val_accuracy: 0.6102
#
# Epoch 00242: val_loss did not improve from 0.10235
# Epoch 243/2000
#  - 1s - loss: 0.1041 - accuracy: 0.9939 - val_loss: 2.0696 - val_accuracy: 0.6342
#
# Epoch 00243: val_loss did not improve from 0.10235
# Epoch 244/2000
#  - 1s - loss: 0.1053 - accuracy: 0.9917 - val_loss: 1.3518 - val_accuracy: 0.6074
#
# Epoch 00244: val_loss did not improve from 0.10235
# Epoch 245/2000
#  - 1s - loss: 0.0954 - accuracy: 0.9937 - val_loss: 0.6939 - val_accuracy: 0.6225
#
# Epoch 00245: val_loss did not improve from 0.10235
# Epoch 246/2000
#  - 1s - loss: 0.0946 - accuracy: 0.9962 - val_loss: 1.1081 - val_accuracy: 0.5949
#
# Epoch 00246: val_loss did not improve from 0.10235
# Epoch 247/2000
#  - 1s - loss: 0.0968 - accuracy: 0.9934 - val_loss: 0.6597 - val_accuracy: 0.6082
#
# Epoch 00247: val_loss did not improve from 0.10235
# Epoch 248/2000
#  - 1s - loss: 0.0918 - accuracy: 0.9953 - val_loss: 1.5407 - val_accuracy: 0.6174
#
# Epoch 00248: val_loss did not improve from 0.10235
# Epoch 249/2000
#  - 1s - loss: 0.0890 - accuracy: 0.9961 - val_loss: 0.6828 - val_accuracy: 0.6163
#
# Epoch 00249: val_loss did not improve from 0.10235
# Epoch 250/2000
#  - 1s - loss: 0.0930 - accuracy: 0.9967 - val_loss: 0.1127 - val_accuracy: 0.6147
#
# Epoch 00250: val_loss did not improve from 0.10235
# Epoch 251/2000
#  - 1s - loss: 0.0991 - accuracy: 0.9942 - val_loss: 0.9061 - val_accuracy: 0.5899
#
# Epoch 00251: val_loss did not improve from 0.10235
# Epoch 252/2000
#  - 1s - loss: 0.1010 - accuracy: 0.9891 - val_loss: 1.0876 - val_accuracy: 0.6291
#
# Epoch 00252: val_loss did not improve from 0.10235
# Epoch 253/2000
#  - 1s - loss: 0.0947 - accuracy: 0.9946 - val_loss: 0.0615 - val_accuracy: 0.6498
#
# Epoch 00253: val_loss improved from 0.10235 to 0.06153, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_cnn_updown_rascend_285_tf115_ETHUSDT.h5
# Epoch 254/2000
#  - 1s - loss: 0.1008 - accuracy: 0.9909 - val_loss: 0.4304 - val_accuracy: 0.6403
#
# Epoch 00254: val_loss did not improve from 0.06153
# Epoch 255/2000
#  - 1s - loss: 0.0912 - accuracy: 0.9946 - val_loss: 1.1396 - val_accuracy: 0.6152
#
# Epoch 00255: val_loss did not improve from 0.06153
# Epoch 256/2000
#  - 1s - loss: 0.0852 - accuracy: 0.9967 - val_loss: 1.4321 - val_accuracy: 0.6445
#
# Epoch 00256: val_loss did not improve from 0.06153
# Epoch 257/2000
#  - 1s - loss: 0.0863 - accuracy: 0.9967 - val_loss: 1.1404 - val_accuracy: 0.6520
#
# Epoch 00257: val_loss did not improve from 0.06153
# Epoch 258/2000
#  - 1s - loss: 0.0882 - accuracy: 0.9955 - val_loss: 0.6949 - val_accuracy: 0.6330
#
# Epoch 00258: val_loss did not improve from 0.06153
# Epoch 259/2000
#  - 1s - loss: 0.0863 - accuracy: 0.9960 - val_loss: 0.1004 - val_accuracy: 0.6096
#
# Epoch 00259: val_loss did not improve from 0.06153
# Epoch 260/2000
#  - 1s - loss: 0.0874 - accuracy: 0.9964 - val_loss: 2.3051 - val_accuracy: 0.6205
#
# Epoch 00260: val_loss did not improve from 0.06153
# Epoch 261/2000
#  - 1s - loss: 0.0810 - accuracy: 0.9973 - val_loss: 0.8478 - val_accuracy: 0.6188
#
# Epoch 00261: val_loss did not improve from 0.06153
# Epoch 262/2000
#  - 1s - loss: 0.0806 - accuracy: 0.9967 - val_loss: 1.3709 - val_accuracy: 0.6250
#
# Epoch 00262: val_loss did not improve from 0.06153
# Epoch 263/2000
#  - 1s - loss: 0.0775 - accuracy: 0.9975 - val_loss: 0.9221 - val_accuracy: 0.6127
#
# Epoch 00263: val_loss did not improve from 0.06153
# Epoch 264/2000
#  - 1s - loss: 0.0794 - accuracy: 0.9984 - val_loss: 0.3721 - val_accuracy: 0.6024
#
# Epoch 00264: val_loss did not improve from 0.06153
# Epoch 265/2000
#  - 1s - loss: 0.0844 - accuracy: 0.9956 - val_loss: 0.1283 - val_accuracy: 0.5954
#
# Epoch 00265: val_loss did not improve from 0.06153
# Epoch 266/2000
#  - 1s - loss: 0.0907 - accuracy: 0.9917 - val_loss: 1.2980 - val_accuracy: 0.5779
#
# Epoch 00266: val_loss did not improve from 0.06153
# Epoch 267/2000
#  - 1s - loss: 0.0865 - accuracy: 0.9940 - val_loss: 1.1108 - val_accuracy: 0.6071
#
# Epoch 00267: val_loss did not improve from 0.06153
# Epoch 268/2000
#  - 1s - loss: 0.0784 - accuracy: 0.9968 - val_loss: 1.1793 - val_accuracy: 0.6464
#
# Epoch 00268: val_loss did not improve from 0.06153
# Epoch 269/2000
#  - 1s - loss: 0.0789 - accuracy: 0.9967 - val_loss: 0.9636 - val_accuracy: 0.6389
#
# Epoch 00269: val_loss did not improve from 0.06153
# Epoch 270/2000
#  - 1s - loss: 0.0738 - accuracy: 0.9981 - val_loss: 0.8064 - val_accuracy: 0.6071
#
# Epoch 00270: val_loss did not improve from 0.06153
# Epoch 271/2000
#  - 1s - loss: 0.0743 - accuracy: 0.9981 - val_loss: 1.9401 - val_accuracy: 0.6336
#
# Epoch 00271: val_loss did not improve from 0.06153
# Epoch 272/2000
#  - 1s - loss: 0.0758 - accuracy: 0.9974 - val_loss: 1.7518 - val_accuracy: 0.6133
#
# Epoch 00272: val_loss did not improve from 0.06153
# Epoch 273/2000
#  - 1s - loss: 0.0725 - accuracy: 0.9980 - val_loss: 1.1208 - val_accuracy: 0.6361
#
# Epoch 00273: val_loss did not improve from 0.06153
# Epoch 274/2000
#  - 1s - loss: 0.0711 - accuracy: 0.9986 - val_loss: 1.5264 - val_accuracy: 0.6082
#
# Epoch 00274: val_loss did not improve from 0.06153
# Epoch 275/2000
#  - 1s - loss: 0.0712 - accuracy: 0.9975 - val_loss: 0.1398 - val_accuracy: 0.6141
#
# Epoch 00275: val_loss did not improve from 0.06153
# Epoch 276/2000
#  - 1s - loss: 0.0709 - accuracy: 0.9983 - val_loss: 1.2046 - val_accuracy: 0.6383
#
# Epoch 00276: val_loss did not improve from 0.06153
# Epoch 277/2000
#  - 1s - loss: 0.0724 - accuracy: 0.9977 - val_loss: 0.5533 - val_accuracy: 0.6049
#
# Epoch 00277: val_loss did not improve from 0.06153
# Epoch 278/2000
#  - 1s - loss: 0.0675 - accuracy: 0.9980 - val_loss: 0.9885 - val_accuracy: 0.6244
#
# Epoch 00278: val_loss did not improve from 0.06153
# Epoch 279/2000
#  - 1s - loss: 0.0684 - accuracy: 0.9985 - val_loss: 0.9192 - val_accuracy: 0.6116
#
# Epoch 00279: val_loss did not improve from 0.06153
# Epoch 280/2000
#  - 1s - loss: 0.0719 - accuracy: 0.9964 - val_loss: 1.7214 - val_accuracy: 0.6211
#
# Epoch 00280: val_loss did not improve from 0.06153
# Epoch 281/2000
#  - 1s - loss: 0.0673 - accuracy: 0.9990 - val_loss: 0.5568 - val_accuracy: 0.6166
#
# Epoch 00281: val_loss did not improve from 0.06153
# Epoch 282/2000
#  - 1s - loss: 0.0665 - accuracy: 0.9986 - val_loss: 0.4404 - val_accuracy: 0.6199
#
# Epoch 00282: val_loss did not improve from 0.06153
# Epoch 283/2000
#  - 1s - loss: 0.0632 - accuracy: 0.9989 - val_loss: 1.6599 - val_accuracy: 0.6227
#
# Epoch 00283: val_loss did not improve from 0.06153
# Epoch 284/2000
#  - 1s - loss: 0.0659 - accuracy: 0.9992 - val_loss: 0.3673 - val_accuracy: 0.6264
#
# Epoch 00284: val_loss did not improve from 0.06153
# Epoch 285/2000
#  - 1s - loss: 0.0670 - accuracy: 0.9984 - val_loss: 0.8631 - val_accuracy: 0.6202
#
# Epoch 00285: val_loss did not improve from 0.06153
# Epoch 286/2000
#  - 1s - loss: 0.0665 - accuracy: 0.9980 - val_loss: 1.7688 - val_accuracy: 0.6177
#
# Epoch 00286: val_loss did not improve from 0.06153
# Epoch 287/2000
#  - 1s - loss: 0.0657 - accuracy: 0.9983 - val_loss: 2.0761 - val_accuracy: 0.6024
#
# Epoch 00287: val_loss did not improve from 0.06153
# Epoch 288/2000
# ...
#
# Epoch 01005: val_loss did not improve from 0.00024
# Epoch 1006/2000
#  - 1s - loss: 2.7842e-04 - accuracy: 1.0000 - val_loss: 3.1640 - val_accuracy: 0.6314
#
# Epoch 01006: val_loss did not improve from 0.00024
# Epoch 1007/2000
#  - 1s - loss: 2.6942e-04 - accuracy: 1.0000 - val_loss: 2.1082 - val_accuracy: 0.6328
#
# Epoch 01007: val_loss did not improve from 0.00024
# Epoch 1008/2000
#  - 1s - loss: 2.7403e-04 - accuracy: 1.0000 - val_loss: 4.1249 - val_accuracy: 0.6319
#
# Epoch 01008: val_loss did not improve from 0.00024
# Epoch 1009/2000
#  - 1s - loss: 2.5169e-04 - accuracy: 1.0000 - val_loss: 5.1560 - val_accuracy: 0.6283
#
# Epoch 01009: val_loss did not improve from 0.00024
# Epoch 1010/2000
#  - 1s - loss: 2.5553e-04 - accuracy: 1.0000 - val_loss: 1.5082 - val_accuracy: 0.6319
#
# Epoch 01010: val_loss did not improve from 0.00024
# Epoch 1011/2000
#  - 1s - loss: 2.4160e-04 - accuracy: 1.0000 - val_loss: 1.4640 - val_accuracy: 0.6333
#
# Epoch 01011: val_loss did not improve from 0.00024
# Epoch 1012/2000
#  - 1s - loss: 2.3698e-04 - accuracy: 1.0000 - val_loss: 1.9096 - val_accuracy: 0.6328
#
# Epoch 01012: val_loss did not improve from 0.00024
# Epoch 1013/2000
#  - 1s - loss: 2.4239e-04 - accuracy: 1.0000 - val_loss: 3.5623 - val_accuracy: 0.6319
#
# Epoch 01013: val_loss did not improve from 0.00024
# Epoch 1014/2000
#  - 1s - loss: 2.4080e-04 - accuracy: 1.0000 - val_loss: 1.5729 - val_accuracy: 0.6322
#
# Epoch 01014: val_loss did not improve from 0.00024
# Epoch 1015/2000
#  - 1s - loss: 2.4010e-04 - accuracy: 1.0000 - val_loss: 0.2711 - val_accuracy: 0.6336
#
# Epoch 01015: val_loss did not improve from 0.00024
# Epoch 1016/2000
#  - 1s - loss: 2.3210e-04 - accuracy: 1.0000 - val_loss: 2.8137 - val_accuracy: 0.6322
#
# Epoch 01016: val_loss did not improve from 0.00024
# Epoch 1017/2000
#  - 1s - loss: 2.3404e-04 - accuracy: 1.0000 - val_loss: 4.3204 - val_accuracy: 0.6328
#
# Epoch 01017: val_loss did not improve from 0.00024
# Epoch 1018/2000
#  - 1s - loss: 2.4752e-04 - accuracy: 1.0000 - val_loss: 2.0833 - val_accuracy: 0.6314
#
# Epoch 01018: val_loss did not improve from 0.00024
# Epoch 1019/2000
#  - 1s - loss: 2.2301e-04 - accuracy: 1.0000 - val_loss: 1.9596 - val_accuracy: 0.6305
#
# Epoch 01019: val_loss did not improve from 0.00024
# Epoch 1020/2000
#  - 1s - loss: 2.2909e-04 - accuracy: 1.0000 - val_loss: 4.3808 - val_accuracy: 0.6322
#
# Epoch 01020: val_loss did not improve from 0.00024
# Epoch 1021/2000
#  - 1s - loss: 2.2177e-04 - accuracy: 1.0000 - val_loss: 1.4545 - val_accuracy: 0.6325
#
# Epoch 01021: val_loss did not improve from 0.00024
# Epoch 1022/2000
#  - 1s - loss: 2.4422e-04 - accuracy: 1.0000 - val_loss: 4.5440 - val_accuracy: 0.6353
#
# Epoch 01022: val_loss did not improve from 0.00024
# Epoch 1023/2000
#  - 1s - loss: 2.3602e-04 - accuracy: 1.0000 - val_loss: 6.5234 - val_accuracy: 0.6275
#
# Epoch 01023: val_loss did not improve from 0.00024
# Epoch 1024/2000
#  - 1s - loss: 2.1588e-04 - accuracy: 1.0000 - val_loss: 0.4737 - val_accuracy: 0.6347
#
# Epoch 01024: val_loss did not improve from 0.00024
# Epoch 1025/2000
#  - 1s - loss: 2.1203e-04 - accuracy: 1.0000 - val_loss: 2.2574 - val_accuracy: 0.6347
#
# Epoch 01025: val_loss did not improve from 0.00024
# Epoch 1026/2000
#  - 1s - loss: 2.1174e-04 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 0.6333
#
# Epoch 01026: val_loss did not improve from 0.00024
# Epoch 1027/2000
#  - 1s - loss: 2.1384e-04 - accuracy: 1.0000 - val_loss: 1.0430 - val_accuracy: 0.6319
#
# Epoch 01027: val_loss did not improve from 0.00024
# Epoch 1028/2000
#  - 1s - loss: 2.0858e-04 - accuracy: 1.0000 - val_loss: 3.3565 - val_accuracy: 0.6339
#
# Epoch 01028: val_loss did not improve from 0.00024
# Epoch 1029/2000
#  - 1s - loss: 2.1264e-04 - accuracy: 1.0000 - val_loss: 2.6255 - val_accuracy: 0.6356
#
# Epoch 01029: val_loss did not improve from 0.00024
# Epoch 1030/2000
#  - 1s - loss: 2.0526e-04 - accuracy: 1.0000 - val_loss: 3.8299 - val_accuracy: 0.6317
#
# Epoch 01030: val_loss did not improve from 0.00024
# Epoch 1031/2000
#  - 1s - loss: 1.9390e-04 - accuracy: 1.0000 - val_loss: 0.3167 - val_accuracy: 0.6342
#
# Epoch 01031: val_loss did not improve from 0.00024
# Epoch 1032/2000
#  - 1s - loss: 1.9349e-04 - accuracy: 1.0000 - val_loss: 3.1870 - val_accuracy: 0.6339
#
# Epoch 01032: val_loss did not improve from 0.00024
# Epoch 1033/2000
#  - 1s - loss: 1.9990e-04 - accuracy: 1.0000 - val_loss: 3.5541 - val_accuracy: 0.6342
#
# Epoch 01033: val_loss did not improve from 0.00024
# Epoch 1034/2000
#  - 1s - loss: 1.9790e-04 - accuracy: 1.0000 - val_loss: 1.3955 - val_accuracy: 0.6305
#
# Epoch 01034: val_loss did not improve from 0.00024
# Epoch 1035/2000
#  - 1s - loss: 2.2358e-04 - accuracy: 1.0000 - val_loss: 2.6253 - val_accuracy: 0.6311
#
# Epoch 01035: val_loss did not improve from 0.00024
# Epoch 1036/2000
#  - 1s - loss: 2.0919e-04 - accuracy: 1.0000 - val_loss: 1.7065 - val_accuracy: 0.6350
#
# Epoch 01036: val_loss did not improve from 0.00024
# Epoch 1037/2000
#  - 1s - loss: 1.9384e-04 - accuracy: 1.0000 - val_loss: 3.5311 - val_accuracy: 0.6300
#
# Epoch 01037: val_loss did not improve from 0.00024
# Epoch 1038/2000
#  - 1s - loss: 1.8943e-04 - accuracy: 1.0000 - val_loss: 2.5935 - val_accuracy: 0.6317
#
# Epoch 01038: val_loss did not improve from 0.00024
# Epoch 1039/2000
#  - 1s - loss: 1.8898e-04 - accuracy: 1.0000 - val_loss: 1.2712 - val_accuracy: 0.6325
#
# Epoch 01039: val_loss did not improve from 0.00024
# Epoch 1040/2000
#  - 1s - loss: 1.9754e-04 - accuracy: 1.0000 - val_loss: 0.3883 - val_accuracy: 0.6347
#
# Epoch 01040: val_loss did not improve from 0.00024
# Epoch 1041/2000
#  - 1s - loss: 2.0497e-04 - accuracy: 1.0000 - val_loss: 5.2740 - val_accuracy: 0.6317
#
# Epoch 01041: val_loss did not improve from 0.00024
# Epoch 1042/2000
#  - 1s - loss: 1.8897e-04 - accuracy: 1.0000 - val_loss: 4.0493 - val_accuracy: 0.6328
#
# Epoch 01042: val_loss did not improve from 0.00024
# Epoch 1043/2000
#  - 1s - loss: 1.9559e-04 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.6303
#
# Epoch 01043: val_loss did not improve from 0.00024
# Epoch 1044/2000
#  - 1s - loss: 1.8600e-04 - accuracy: 1.0000 - val_loss: 0.1262 - val_accuracy: 0.6353
#
# Epoch 01044: val_loss did not improve from 0.00024
# Epoch 1045/2000
#  - 1s - loss: 1.9553e-04 - accuracy: 1.0000 - val_loss: 2.5327 - val_accuracy: 0.6333
#
# Epoch 01045: val_loss did not improve from 0.00024
# Epoch 1046/2000
#  - 1s - loss: 1.8447e-04 - accuracy: 1.0000 - val_loss: 0.0143 - val_accuracy: 0.6289
#
# Epoch 01046: val_loss did not improve from 0.00024
# Epoch 1047/2000
#  - 1s - loss: 1.8026e-04 - accuracy: 1.0000 - val_loss: 0.3054 - val_accuracy: 0.6328
#
# Epoch 01047: val_loss did not improve from 0.00024
# Epoch 1048/2000
#  - 1s - loss: 1.7871e-04 - accuracy: 1.0000 - val_loss: 2.0055 - val_accuracy: 0.6308
#
# Epoch 01048: val_loss did not improve from 0.00024
# Epoch 1049/2000
#  - 1s - loss: 2.4432e-04 - accuracy: 1.0000 - val_loss: 0.7720 - val_accuracy: 0.6255
#
# Epoch 01049: val_loss did not improve from 0.00024
# Epoch 1050/2000
#  - 1s - loss: 3.9049e-04 - accuracy: 1.0000 - val_loss: 1.4074 - val_accuracy: 0.6272
#
# Epoch 01050: val_loss did not improve from 0.00024
# Epoch 1051/2000
#  - 1s - loss: 2.1436e-04 - accuracy: 1.0000 - val_loss: 2.9870 - val_accuracy: 0.6353
#
# Epoch 01051: val_loss did not improve from 0.00024
# Epoch 1052/2000
#  - 1s - loss: 1.8324e-04 - accuracy: 1.0000 - val_loss: 1.6724 - val_accuracy: 0.6322
#
# Epoch 01052: val_loss did not improve from 0.00024
# Epoch 1053/2000
#  - 1s - loss: 1.7119e-04 - accuracy: 1.0000 - val_loss: 1.0872 - val_accuracy: 0.6336
#
# Epoch 01053: val_loss did not improve from 0.00024
# Epoch 1054/2000
#  - 1s - loss: 1.6933e-04 - accuracy: 1.0000 - val_loss: 1.8203 - val_accuracy: 0.6347
#
# Epoch 01054: val_loss did not improve from 0.00024
# Epoch 1055/2000
#  - 1s - loss: 1.7568e-04 - accuracy: 1.0000 - val_loss: 2.6635 - val_accuracy: 0.6339
#
# Epoch 01055: val_loss did not improve from 0.00024
# Epoch 1056/2000
#  - 1s - loss: 1.7453e-04 - accuracy: 1.0000 - val_loss: 0.4358 - val_accuracy: 0.6317
#
# Epoch 01056: val_loss did not improve from 0.00024
# Epoch 1057/2000
#  - 1s - loss: 1.6869e-04 - accuracy: 1.0000 - val_loss: 3.3237 - val_accuracy: 0.6328
#
# Epoch 01057: val_loss did not improve from 0.00024
# Epoch 1058/2000
#  - 1s - loss: 1.6934e-04 - accuracy: 1.0000 - val_loss: 1.7557 - val_accuracy: 0.6314
#
# Epoch 01058: val_loss did not improve from 0.00024
# Epoch 1059/2000
#  - 1s - loss: 1.6734e-04 - accuracy: 1.0000 - val_loss: 5.9783 - val_accuracy: 0.6333
#
# Epoch 01059: val_loss did not improve from 0.00024
# Epoch 1060/2000
#  - 1s - loss: 1.8541e-04 - accuracy: 1.0000 - val_loss: 2.3995 - val_accuracy: 0.6303
#
# Epoch 01060: val_loss did not improve from 0.00024
# Epoch 1061/2000
#  - 1s - loss: 1.9512e-04 - accuracy: 1.0000 - val_loss: 3.7605 - val_accuracy: 0.6389
#
# Epoch 01061: val_loss did not improve from 0.00024
# Epoch 1062/2000
#  - 1s - loss: 1.7763e-04 - accuracy: 1.0000 - val_loss: 2.2618 - val_accuracy: 0.6400
#
# Epoch 01062: val_loss did not improve from 0.00024
# Epoch 1063/2000
#  - 1s - loss: 1.7194e-04 - accuracy: 1.0000 - val_loss: 1.7022 - val_accuracy: 0.6311
#
# Epoch 01063: val_loss did not improve from 0.00024
# Epoch 1064/2000
#  - 1s - loss: 1.6967e-04 - accuracy: 1.0000 - val_loss: 5.4238 - val_accuracy: 0.6325
#
# Epoch 01064: val_loss did not improve from 0.00024
# Epoch 1065/2000
#  - 1s - loss: 1.7480e-04 - accuracy: 1.0000 - val_loss: 0.8077 - val_accuracy: 0.6330
#
# Epoch 01065: val_loss did not improve from 0.00024
# Epoch 1066/2000
#  - 1s - loss: 1.8773e-04 - accuracy: 1.0000 - val_loss: 1.5476 - val_accuracy: 0.6308
#
# Epoch 01066: val_loss did not improve from 0.00024
# Epoch 1067/2000
#  - 1s - loss: 1.9712e-04 - accuracy: 1.0000 - val_loss: 5.6347 - val_accuracy: 0.6356
#
# Epoch 01067: val_loss did not improve from 0.00024
# Epoch 1068/2000
#  - 1s - loss: 1.7999e-04 - accuracy: 1.0000 - val_loss: 3.6752 - val_accuracy: 0.6361
#
# Epoch 01068: val_loss did not improve from 0.00024
# Epoch 1069/2000
#  - 1s - loss: 1.6576e-04 - accuracy: 1.0000 - val_loss: 0.3738 - val_accuracy: 0.6342
#
# Epoch 01069: val_loss did not improve from 0.00024
# Epoch 1070/2000
#  - 1s - loss: 1.6312e-04 - accuracy: 1.0000 - val_loss: 1.2298 - val_accuracy: 0.6319
#
# Epoch 01070: val_loss did not improve from 0.00024
# Epoch 1071/2000
#  - 1s - loss: 1.6318e-04 - accuracy: 1.0000 - val_loss: 0.9502 - val_accuracy: 0.6330
#
# Epoch 01071: val_loss did not improve from 0.00024
# Epoch 1072/2000
#  - 1s - loss: 1.6687e-04 - accuracy: 1.0000 - val_loss: 2.1764 - val_accuracy: 0.6303
#
# Epoch 01072: val_loss did not improve from 0.00024
# Epoch 1073/2000
#  - 1s - loss: 1.7003e-04 - accuracy: 1.0000 - val_loss: 0.7120 - val_accuracy: 0.6356
#
# Epoch 01073: val_loss did not improve from 0.00024
# Epoch 1074/2000
#  - 1s - loss: 1.5544e-04 - accuracy: 1.0000 - val_loss: 1.0707 - val_accuracy: 0.6344
#
# Epoch 01074: val_loss did not improve from 0.00024
# Epoch 1075/2000
#  - 1s - loss: 1.5471e-04 - accuracy: 1.0000 - val_loss: 3.5292 - val_accuracy: 0.6308
#
# Epoch 01075: val_loss did not improve from 0.00024
# Epoch 1076/2000
#  - 1s - loss: 1.5351e-04 - accuracy: 1.0000 - val_loss: 1.2775 - val_accuracy: 0.6330
#
# Epoch 01076: val_loss did not improve from 0.00024
# Epoch 1077/2000
#  - 1s - loss: 1.5164e-04 - accuracy: 1.0000 - val_loss: 2.1395 - val_accuracy: 0.6336
#
# Epoch 01077: val_loss did not improve from 0.00024
# Epoch 1078/2000
#  - 1s - loss: 1.5550e-04 - accuracy: 1.0000 - val_loss: 2.1671 - val_accuracy: 0.6344
#
# Epoch 01078: val_loss did not improve from 0.00024
# Epoch 1079/2000
#  - 1s - loss: 1.5005e-04 - accuracy: 1.0000 - val_loss: 0.9286 - val_accuracy: 0.6356
#
# Epoch 01079: val_loss did not improve from 0.00024
# Epoch 1080/2000
#  - 1s - loss: 1.5939e-04 - accuracy: 1.0000 - val_loss: 4.1455 - val_accuracy: 0.6328
#
# Epoch 01080: val_loss did not improve from 0.00024
# test_result.shape : (3589, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[9.9111432e-01]
#  [9.9980372e-01]
#  [2.8963732e-05]
#  [4.0545085e-04]
#  [3.6963981e-04]]
# y_test.shape : (3589, 1)
# y_score.shape : (3589, 1)
# len(y_test) : 3589
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:700: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [0.00030184386, 0.00029761303, 0.00029297895, 0.000294709, 0.0002770745, 0.00028267936, 0.00044640625, 0.00045477608, 0.0004409593, 0.00043462293, 0.00043496984, 0.00043465517, 0.00044006266, 0.0004349136, 0.00043599104, 0.00041955954, 0.00042178357, 0.00042788082, 0.0004087399, 0.00041058043, 0.00041005446, 0.0004222315, 0.00043015412, 0.00046134717, 0.00046373106, 0.0004680261, 0.00049783924, 0.00043947122, 0.00044117833, 0.00045263508, 0.00045853545, 0.00046001375, 0.00046861847, 0.000520106, 0.00053431676, 0.0005342085, 0.0005348868, 0.00053584704, 0.0005766753, 0.00057956256, 0.00059184065, 0.0005976685, 0.00057268393, 0.0005778138, 0.00058609515, 0.0005991651, 0.0006084348, 0.0006244631, 0.0006123571, 0.00062569475, 0.00063497893, 0.00064788054, 0.0006536172, 0.0006591468, 0.0006753218, 0.0006813294, 0.00070174783, 0.00070550566, 0.0007183149, 0.00071960845, 0.00070841453, 0.0007145191, 0.0007292898, 0.0007343013, 0.0007226048, 0.0007157472, 0.0007057185, 0.00070400146, 0.0007169224, 0.0007187769, 0.00072904787, 0.00072224246, 0.00086181023, 0.0008575649, 0.00087299553, 0.00088383234, 0.00081626984, 0.00084185216, 0.0008921263, 0.00088680827, 0.0008726859, 0.00090236124, 0.0009273138, 0.000939742, 0.00092149054, 0.000915747, 0.00092566735, 0.0009225853, 0.0008458551, 0.0008441085, 0.00084357144, 0.0008521567, 0.0008498516, 0.0008120958, 0.0008001861, 0.0007948851, 0.0007759903, 0.00079368247, 0.0007775198, 0.00075893657, 0.00077823654, 0.00078812626, 0.0007809908, 0.0008193646, 0.00082706544, 0.0008496135, 0.00087552547, 0.0008575991, 0.00086080574, 0.000858908, 0.00083404576, 0.00083602057, 0.0008333782, 0.0008158206, 0.0008171139, 0.00084840576, 0.00084726635, 0.00085416314, 0.0007622457, 0.0006524116, 0.0006700158, 0.00066023984, 0.00065985555, 0.00066364126, 0.00067954924, 0.0006815927, 0.0006851323, 0.00069449685, 0.0006657001, 0.0006681524, 0.0006441027, 0.0006353458, 0.0006462508, 0.00066031254, 0.00065488304, 0.0007083036, 0.0007235766, 0.0007400854, 0.00073306926, 0.0007386122, 0.00074466824, 0.00074939214, 0.00075382204, 0.0007315122, 0.0007452887, 0.00068558654, 0.0006943515, 0.0007142707, 0.0007318752, 0.00071632426, 0.00072115415, 0.0007217141, 0.00073205994, 0.0007276029, 0.00063980225, 0.0006387992, 0.0006338802, 0.00063260505, 0.00064576743, 0.0006684886, 0.00068064686, 0.00068941765, 0.0006785014, 0.0006884082, 0.0006809933, 0.0006489863, 0.0006529992, 0.0006380091, 0.0006273107, 0.00062020123, 0.0006276204, 0.0006288805, 0.0006030815, 0.0006064353, 0.00061087735, 0.0006056495, 0.00061968964, 0.0006185829, 0.0006204466, 0.0006219064, 0.00062192074, 0.00078175677, 0.0007933522, 0.0007997414, 0.00078619807, 0.00078960205, 0.0007902809, 0.00082803116, 0.0008422339, 0.00082871, 0.0008309564, 0.0007927038, 0.0007989758, 0.0008403642, 0.0008691164, 0.00091276004, 0.0008341908, 0.00080793246, 0.0008052683, 0.000773455, 0.00076428195, 0.00076485705, 0.00072701974, 0.0007080267, 0.00068682624, 0.00070743513, 0.0006729108, 0.0006752031, 0.0006760222, 0.0006745304, 0.00067776575, 0.00069314224, 0.0006804985, 0.0006997544, 0.0006972263, 0.00068976334, 0.0006985246, 0.000709845, 0.000707476, 0.0007138728, 0.0007058814, 0.00071490713, 0.00072907377, 0.0008404973, 0.000840182, 0.00084773375, 0.00086011924, 0.0008649843, 0.00086820155, 0.0008667949, 0.0008759337, 0.0009080987, 0.00093892345, 0.0009472727, 0.0009557949, 0.0009442892, 0.0009370137, 0.00091741036, 0.0009307626, 0.00096623687, 0.00097268156, 0.0009984613, 0.0010227497, 0.0010105191, 0.0010464521, 0.0010500288, 0.0010300073, 0.0010462255, 0.0010469635, 0.0010654401, 0.0010710256, 0.0011158905, 0.0011022822, 0.0010701483, 0.0010726975, 0.0010562108, 0.0010669224, 0.0011834288, 0.0011962748, 0.0012489425, 0.0012229744, 0.0012339627, 0.001233361, 0.0011258924, 0.0011512581, 0.0011431843, 0.001186337, 0.0011940722, 0.0011957805, 0.0011607964, 0.0011679353, 0.0011993396, 0.0013264504, 0.0013545165, 0.001332682, 0.0013712068, 0.0013987704, 0.0014213 ...

# %% [markdown]
# ### save npy

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from funcs_indicator import *

def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


#       set data features : ohlc, v, ep
time_index = ohlcv.index[np.sum(np.isnan(pr)):]

sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

#       scale with price    #
ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
sar = lucid_sar(sliced_ohlcv)
ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
senkou1, senkou2 = ichimoku(sliced_ohlcv)

#     min max scale   #
vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

pr_list = pr[np.sum(np.isnan(pr)):]
print("len(ohlc) :", len(ohlc))
print("len(pr) :", len(pr))

# break


#       set params    #
period = 45
key_i = i

plotting = True

data_x, data_pr, data_updown = [], [], []
data_index = []

for i in range(period, len(ohlc)):

  #   pr_list != 1 인 데이터만 사용한다
  # if 1:
  if pr_list[i] != 1:

    min_max = MinMaxScaler()
    
    #   prediction 을 제외한 이전 데이터를 사용해야한다
    temp_ohlc = ohlc.iloc[i - period : i].values
    # temp_long_ep = long_ep[i - period : i]          
    temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
    temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

    temp_close = min_max_scale(temp_ohlc[:, [3]])    

    price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

    if np.isnan(np.sum(price_data)):
      continue

    # print("price_data[:10] :", price_data[:10])
    # print("temp_ohlc.shape :", temp_ohlc.shape)
    # print("temp_long_ep.shape :", temp_long_ep.shape)
    # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
    # print("price_data.shape :", price_data.shape)

    if plotting:
      plt.plot(price_data)
      plt.show()

    ind_temp_ohlc = min_max_scale(temp_ohlc)
    temp_price_data = min_max_scale(price_data)
    # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


    if plotting:

      plt.plot(ind_temp_ohlc)
      plt.show()
      plt.plot(temp_price_data)
      plt.show()

      plotting = False
    # break

    #   vol -> min_max
    temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
    
    #                   feature selection                   #        
    temp_data = np.hstack((ind_temp_ohlc, temp_vol))

    # temp_data = trial_list[trial_number]
    # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
    # temp_data = temp_ohlc[:, [3]]
    # temp_data = ind_temp_ohlc[:, [3]]
    # temp_data = temp_close

    if np.isnan(np.sum(temp_data)):
      continue

    data_x.append(temp_data)
    data_pr.append(pr_list[i])
    data_index.append(time_index[i])
    data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


print('np.array(data_x).shape :', np.array(data_x).shape)
# print(data_x[0])


#       Reshape data for image deep - learning     #
_, row, col = np.array(data_x).shape

input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
# input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

#     1c to 3c    #
input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
# input_x = np.array(resize_npy(input_x))


input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
input_index = np.array(data_index).reshape(-1, 1)
print('input_x.shape :', input_x.shape)
print('input_x.dtype :', input_x.dtype)
print('input_pr.shape :', input_pr.shape)
print('input_ud.shape :', input_ud.shape)
print('input_index.shape :', input_index.shape)


# x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

#     do stacking   #
# if prev_x is None:
prev_x = input_x
prev_pr = input_pr
prev_ud = input_ud
prev_index = input_index

total_x = input_x
total_pr = input_pr
total_ud = input_ud
total_index = input_index

# else:
#   total_x = np.vstack((prev_x, input_x))
#   total_pr = np.vstack((prev_pr, input_pr))
#   total_ud = np.vstack((prev_ud, input_ud)) 
#   total_index = np.vstack((prev_index, input_index)) 

#   prev_x = total_x
#   prev_pr = total_pr
#   prev_ud = total_ud
#   prev_index = total_index

print('total_x.shape :', total_x.shape)
print('total_pr.shape :', total_pr.shape)
print('total_ud.shape :', total_ud.shape)
print('prev_index.shape :', prev_index.shape)


# _, row, col, _ = input_x.shape
# _, row, col = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


#         get unique timestamp      #
print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

#                 don't shuffle timeseries data                 #
stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)

index_train = np.array(index_train)
index_val = np.array(index_val)
index_test = np.array(index_test)
  
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

symbol_name = key.split(' ')[1].split('.')[0]

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)

np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %% [markdown]
# ### load npy

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


symbol_name = "SXPUSDT"
period = 45

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)


x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')


pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

# total_x = np.vstack((x_train, x_val, x_test))
# total_pr = np.vstack((pr_train, pr_val, pr_test))

# print("total_x.shape :", total_x.shape)
# Out:
# x series loaded !
# y series loaded !

# %% [markdown]
# ### rapid pr selection

# %%
plt.plot(pr)
plt.show()

pr_thresh = 1.005
rapid_pct = len(pr[pr > pr_thresh]) / len(pr)

print(rapid_pct)
# Out:
# 0.36131427304964536

# %% [markdown]
# ### class_weight & categorization

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


def class_ratio(in_list):

  return in_list / in_list[1]
  
y_train = np.where(pr_train > pr_thresh, 1, 0)
y_test = np.where(pr_test > pr_thresh, 1, 0)
y_val = np.where(pr_val > pr_thresh, 1, 0)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

# try:
print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

# except Exception as e:
  # print(e)

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)
# Out:
# x_train.shape : (10755, 45, 5, 3)
# x_test.shape : (3586, 45, 5, 3)
# x_val.shape : (3585, 45, 5, 3)
# y_train.shape : (10755, 1)
# y_test.shape : (3586, 1)
# y_val.shape : (3585, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([6864, 3891])) [1.76407093 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2303, 1282])) [1.79641186 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2291, 1295])) [1.76911197 1.        ]
# class_weights : {0: 0.7834353146853147, 1: 1.382035466461064}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10755, 2)
# y_val_ohe.shape : (3585, 2)
# y_test_ohe.shape : (3586, 2)

# %% [markdown]
# ### augment

# %%
from keras.preprocessing.image import ImageDataGenerator 

datagen = ImageDataGenerator( 
    # rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)


batch_size = 512


for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break

# %% [markdown]
# ### train

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'

# batch_size = 512

model = FER_Model(input_shape=x_train.shape[1:])
opt = Adam(lr=0.00001, decay=0.000005)
# opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model_name = 'classifier_%s_cnn_updown_rascend_1005_%s_tvnon_shuffle.h5' % (period, symbol_name)



checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]
# callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)

# %% [markdown]
# ### load model

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'


model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)


model = keras.models.load_model(ckpt_path + model_name)

# %% [markdown]
# ### test

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)

  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.title(symbol_name)
plt.show()
# Out:
# test_result.shape : (3586, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.04767541]
#  [0.00195843]
#  [0.1600004 ]
#  [0.14308068]
#  [0.00154134]]
# y_test.shape : (3586, 1)
# y_score.shape : (3586, 1)
# len(y_test) : 3586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [5.2342257e-05, 5.224965e-05, 5.119804e-05, 4.92728e-05, 4.9822964e-05, 5.1722614e-05, 5.241118e-05, 5.2653213e-05, 5.4707263e-05, 5.469477e-05, 5.5414595e-05, 5.4917986e-05, 5.5296758e-05, 5.482614e-05, 5.5313794e-05, 5.619928e-05, 5.7341047e-05, 5.8005982e-05, 5.7726982e-05, 5.8714617e-05, 5.924952e-05, 5.9157777e-05, 6.0730683e-05, 6.09751e-05, 6.1022805e-05, 6.194849e-05, 6.286581e-05, 6.367981e-05, 6.4932676e-05, 6.5769455e-05, 6.7948844e-05, 6.841887e-05, 6.806048e-05, 6.849957e-05, 6.9895126e-05, 7.091783e-05, 7.1859926e-05, 7.350335e-05, 7.346305e-05, 7.395025e-05, 7.968566e-05, 7.8947196e-05, 7.8341516e-05, 7.918357e-05, 7.912106e-05, 8.1205275e-05, 8.341604e-05, 8.386569e-05, 8.3938816e-05, 8.564359e-05, 7.970025e-05, 8.0672995e-05, 8.083643e-05, 8.727269e-05, 8.9510206e-05, 8.959228e-05, 8.962243e-05, 8.8885776e-05, 9.023229e-05, 9.169206e-05, 9.0867565e-05, 9.033618e-05, 9.429348e-05, 9.3799725e-05, 9.566918e-05, 9.6586686e-05, 9.398621e-05, 9.4105475e-05, 9.411831e-05, 9.466633e-05, 9.5054995e-05, 9.854746e-05, 9.9124496e-05, 0.00010614127, 0.000108136, 0.00010740872, 0.00010814099, 0.00010723293, 0.00010745465, 0.00010824714, 0.00010731329, 0.000108584194, 0.00010868803, 0.00010257258, 0.000101516416, 0.00010031571, 0.000103715196, 0.00010502134, 0.00010611775, 0.00010916348, 0.00010594193, 0.000104194485, 0.00010433929, 0.000104219216, 0.00010764128, 0.00010433711, 0.00010385209, 0.000106006635, 0.00010645543, 0.00010741285, 0.00010793885, 0.00010773461, 0.000107400294, 0.000107067055, 0.000110430265, 0.00010961514, 0.000110994966, 0.000109511326, 0.00011019072, 0.00011165826, 0.00011095228, 0.00011055433, 0.00011134691, 0.000109883986, 0.0001112986, 0.0001123257, 0.000114077506, 0.00011583454, 0.00011730796, 0.00011702095, 0.00012883096, 0.00012502969, 0.0001211144, 0.00012085415, 0.00012023333, 0.000121178586, 0.0001113643, 0.00011255329, 0.00011366057, 0.00011109531, 0.00011435672, 0.00011691414, 0.00011724194, 0.00011877652, 0.00011876732, 0.00012343662, 0.00012398258, 0.00012742475, 0.00013299534, 0.0001345203, 0.00013497796, 0.00013495858, 0.00013710273, 0.00013803714, 0.00013533776, 0.00014049193, 0.00013862025, 0.00013925365, 0.00013978127, 0.00014475136, 0.00014560782, 0.00014417202, 0.00015133772, 0.0001492487, 0.00015156744, 0.00015025465, 0.00015172384, 0.0001483679, 0.00015025485, 0.00017470514, 0.00017807752, 0.00018197432, 0.00018371776, 0.00018367464, 0.0001920926, 0.00019288564, 0.00020759454, 0.00020698183, 0.00023446795, 0.00023864223, 0.00024568185, 0.0002499611, 0.00025658592, 0.00025730263, 0.00025887572, 0.00026280092, 0.0002670472, 0.00027564648, 0.0002803122, 0.0002723821, 0.00027754836, 0.00027732784, 0.00028359605, 0.0002916876, 0.0002884358, 0.0002919522, 0.00029502896, 0.00028943687, 0.00028854128, 0.00029137387, 0.0002962364, 0.00029461124, 0.00029948735, 0.00030449385, 0.0002996868, 0.00029990985, 0.00029333428, 0.0002965417, 0.00029836778, 0.00029298887, 0.00030178405, 0.00029634495, 0.00029906907, 0.00029697176, 0.0002963374, 0.000295097, 0.000312998, 0.00031196643, 0.00031936396, 0.00032101592, 0.00032832168, 0.0003258465, 0.00033274552, 0.0003290262, 0.00033229083, 0.00034132804, 0.00033895372, 0.00035075872, 0.00034744598, 0.00034445102, 0.00032778905, 0.0003323982, 0.00034709118, 0.0003477889, 0.00035424854, 0.00040091967, 0.00042115894, 0.00041995398, 0.00041660885, 0.00042408038, 0.00044065266, 0.00045346154, 0.00044463656, 0.00047572926, 0.0005098468, 0.00050058664, 0.00049340463, 0.0004999284, 0.0005000292, 0.0004849475, 0.00048356556, 0.0004768842, 0.00047515446, 0.00046261746, 0.00046790738, 0.000461418, 0.00046818578, 0.00046653874, 0.00047877917, 0.00048961974, 0.0005021864, 0.00051662093, 0.00052976055, 0.00053512596, 0.000552535, 0.0005820823, 0.00058700517, 0.00059161586, 0.0005911128, 0.00059325877, 0.00059789245, 0.0006161917, 0.00060233, 0.0006037665, 0.0005968395, 0.0006049573, 0.0006040889, 0.0006045968, 0.000620602, 0.00062113034, 0.0006333279, ...

# %%
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)], linestyle='--', color='r')
plt.title(symbol_name + '\n' + str(new_thresh[np.argmax(acc_pr_bythr)]))
plt.show()

# %%
thresh = 0.5866
y_pred = np.where(y_score[:600, -1] > thresh, 1, 0)
# print('y_pred.shape :', y_pred.shape)
# print('y_pred :', y_pred)

#     compare precision     #

# print('precision :', precision_score(y_test, y_pred))
# print('recall :', recall_score(y_test, y_pred))
# print()

# print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
# print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

# # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
# # plt.show()  
# print()

#     check win-ratio improvement     #
cmat = confusion_matrix(y_test[:len(y_pred)], y_pred)
# print(cmat)
# print(np.sum(cmat, axis=1))

test_size = len(y_test[:len(y_pred)])
test_pr_list = pr_test[:len(y_pred)]
# print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
# print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

# print('pr_test.shape :', pr_test.shape)

# print(y_pred)
# print(test_pr_list)
pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

plt.plot(np.cumprod(pred_pr_list))
plt.show()

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72a922dd9685> in <module>()
#       5 # print(index_train)
#       6 # print(index_val)
# ----> 7 total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index))
#       8 timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train))
#       9 timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val))
#
# NameError: name 'input_index' is not defined

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
