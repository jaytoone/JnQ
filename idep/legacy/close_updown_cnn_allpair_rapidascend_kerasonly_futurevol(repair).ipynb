# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Requirements**

# %%
# %tensorflow_version 1.x

# import tensorflow as tf
# tf.__version__
# Out:
# '2.4.1'

# %%
# from tensorflow import keras
import keras
keras.__version__
# from tensorflow.keras.utils import np_utils
# Out:
# '2.5.0'

# %%
# !pip install tensorflow==2.4.1

# !pip install tensorflow==2.1.0

# !pip install tensorflow==2.3.0
# !pip install keras==2.3.1

# !pip install statsmodels==0.12.2

# !pip install h5py==2.10.0


# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### load file list

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### custom model

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

# import tensorflow as tf
import keras

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

# from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    print(model.summary())
    
    return model

# %%
# print(tf.__version__)
print(keras.__version__)
# Out:
# 2.5.0

# %% [markdown]
# ### ver check

# %%
import h5py

# model_name = 'classifier_%s_cnn_updown_rascend_285_%s_tvnon_shuffle.h5' % (45, "MKRUSDT")
model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (45, "ETHUSDT")

ckpt_path = current_path + 'ckpt/'

f = h5py.File(ckpt_path + model_name, 'r')
print(f.attrs.get('keras_version'))
# print(f.attrs.get('tensorflow_version'))

for att in f.attrs:
  print(f.attrs.get(att))
# Out:
# 2.3.1
# tensorflow
# 2.3.1
# {"class_name": "Model", "config": {"name": "model_5", "layers": [{"name": "input", "class_name": "InputLayer", "config": {"batch_input_shape": [null, 45, 5, 3], "dtype": "float32", "sparse": false, "name": "input"}, "inbound_nodes": []}, {"name": "conv2d_17", "class_name": "Conv2D", "config": {"name": "conv2d_17", "trainable": true, "dtype": "float32", "filters": 32, "kernel_size": [3, 3], "strides": [1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1], "activation": "linear", "use_bias": true, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 2.0, "mode": "fan_in", "distribution": "normal", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}, "inbound_nodes": [[["input", 0, 0, {}]]]}, {"name": "leaky_re_lu_25", "class_name": "LeakyReLU", "config": {"name": "leaky_re_lu_25", "trainable": true, "dtype": "float32", "alpha": 0.30000001192092896}, "inbound_nodes": [[["conv2d_17", 0, 0, {}]]]}, {"name": "conv2d_18", "class_name": "Conv2D", "config": {"name": "conv2d_18", "trainable": true, "dtype": "float32", "filters": 64, "kernel_size": [3, 3], "strides": [1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1], "activation": "linear", "use_bias": true, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 2.0, "mode": "fan_in", "distribution": "normal", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}, "inbound_nodes": [[["leaky_re_lu_25", 0, 0, {}]]]}, {"name": "leaky_re_lu_26", "class_name": "LeakyReLU", "config": {"name": "leaky_re_lu_26", "trainable": true, "dtype": "float32", "alpha": 0.30000001192092896}, "inbound_nodes": [[["conv2d_18", 0, 0, {}]]]}, {"name": "conv2d_19", "class_name": "Conv2D", "config": {"name": "conv2d_19", "trainable": true, "dtype": "float32", "filters": 128, "kernel_size": [3, 3], "strides": [1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1], "activation": "linear", "use_bias": true, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 2.0, "mode": "fan_in", "distribution": "normal", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}, "inbound_nodes": [[["leaky_re_lu_26", 0, 0, {}]]]}, {"name": "leaky_re_lu_27", "class_name": "LeakyReLU", "config": {"name": "leaky_re_lu_27", "trainable": true, "dtype": "float32", "alpha": 0.30000001192092896}, "inbound_nodes": [[["conv2d_19", 0, 0, {}]]]}, {"name": "conv2d_20", "class_name": "Conv2D", "config": {"name": "conv2d_20", "trainable": true, "dtype": "float32", "filters": 256, "kernel_size": [3, 3], "strides": [1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1], "activation": "linear", "use_bias": true, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"scale": 2.0, "mode": "fan_in", "distribution": "normal", "seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}, "inbound_nodes": [[["leaky_re_lu_27", 0, 0, {}]]]}, {"name": "leaky_re_lu_28", "class_name": "LeakyReLU", "config": {"name": "leaky_re_lu_28", "trainable": true, "dtype": "float32", "alpha": 0.30000001192092896}, "inbound_nodes": [[["conv2d_20", 0, 0, {}]]]}, {"name": "flatten_5", "class_name": "Flatten", "config": {"name": "flatten_5", "trainable": true, "dtype": "float32", "data_format": "channels_last"}, "inbound_nodes": [[["leaky_re_lu_28", 0, 0, {}]]]}, {"name": " ...
# {"optimizer_config": {"class_name": "Adam", "config": {"learning_rate": 9.999999747378752e-06, "beta_1": 0.8999999761581421, "beta_2": 0.9990000128746033, "decay": 4.999999873689376e-06, "epsilon": 1e-07, "amsgrad": false}}, "loss": "categorical_crossentropy", "metrics": ["accuracy"], "weighted_metrics": null, "sample_weight_mode": null, "loss_weights": null}

# %% [markdown]
# ### all in one loop

# %%
print(ohlcv['close'].pct_change().head())
print(ohlcv['close'] / ohlcv['close'].shift(1).head() - 1)

# %%
# from tensorflow.keras.utils import to_categorical

# %%
from funcs_indicator import *
import matplotlib.pyplot as plt

# import mpl_finance as mf


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None


#           load saved npy & trained model        #
load_npy = True
load_model = False


seed = 1
random_state = 201
np.random.seed(seed)

fee = 0.0006
lvrg = 5

for i in range(len(candis)):

  keys = [candis[i]]

  if 'eth'.upper() not in candis[i]:
    continue

  # if 'comp'.upper() not in candis[i]:
  #   continue

  for key in keys:  
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))

        
    #       long      #
    pr = (ohlcv['close'].pct_change() - fee) * lvrg + 1    

    #       long liqudation     #
    lq = (ohlcv['low'] / ohlcv['close'].shift(1) - fee - 1) * lvrg + 1

    #       short       # <-- 이거를 단순히 minus 를 붙여도 되는걸까
    s_pr = (-ohlcv['close'].pct_change() - fee) * lvrg + 1

    #       short liqudation     #
    # s_lq = (ohlcv['high'] / ohlcv['close'].shift(1) - fee) * lvrg + 1
    

    #       fill na with 1.0      #
    # pr = np.where(np.isnan(pr), 1, pr)
    # print(len(pr))
    # print("len(pr[np.isnan(pr)]) :", len(pr[np.isnan(pr)]))
    # print("np.sum(np.isnan(pr)) :", np.sum(np.isnan(pr)))
    
    # sliced_ohlcv = ohlcv[np.sum(np.isnan(pr))]
    # print(sliced_ohlcv.head())
    # break
    # s_pr = np.where(np.isnan(s_pr), 1, pr)
    # lq = np.where(np.isnan(lq), 1, lq)


    #       set lq      #
    # pr = np.where((pr != 1) & (lq <= 0), 0, pr)

    # print("len(pr[pr < 0]) :", len(pr[pr < 0]))
    # break

    org_wr = len(pr[pr > 1]) / len(pr[pr != 1])

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(pr))
    plt.title("%s\norg_wr : %.3f\n acc_pr : %.3f" % (key, org_wr, np.cumprod(pr)[-1]))


    #                    strat                   #

    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) < ohlcv['close'].shift(3)), pr, 1)


    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
    #                     (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
    #                     (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)), pr, 1)


    strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
                        (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
                        (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
                        (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)) & 
                        (ohlcv['close'].shift(5) < ohlcv['close'].shift(6)), pr, 1)
    
    # strat_pr = np.where((ohlcv['high'].shift(2) > ohlcv['high'].shift(3))& 
    #                     (ohlcv['close'].shift(1) > ohlcv['close'].shift(2)), pr, 1)


    wr = len(strat_pr[strat_pr > 1]) / len(strat_pr[strat_pr != 1])

    plt.subplot(122)
    plt.plot(np.cumprod(strat_pr))
    plt.title("%s\norg_wr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr, np.cumprod(strat_pr)[-1]))


    # #                  sl cut                #
    # sl_line = ohlcv['low'].rolling(250).min().shift(1)
    # # sl_line = ohlcv['low'].shift(1)

    # strat_pr_sl = np.where((strat_pr != 1) & (sl_line > ohlcv['low']), 
    #                      1 + lvrg * (sl_line / ohlcv['close'].shift(1) - 1 - fee), strat_pr)


    # wr_sl = len(strat_pr_sl[strat_pr_sl > 1]) / len(strat_pr_sl[strat_pr_sl != 1])
    # # wl_pr_ratio = np.mean(strat_pr[strat_pr > 1]) / np.mean(strat_pr[strat_pr < 1])
    # # wl_pr_ratio = np.cumprod(strat_pr[strat_pr > 1])[-1] / np.cumprod(strat_pr[strat_pr < 1])[-1]

    # plt.subplot(122)
    # plt.plot(np.cumprod(strat_pr_sl))
    # plt.title("%s\norg_pr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr_sl, np.cumprod(strat_pr_sl)[-1]))


    plt.show()
    # break

    period = 45
    symbol_name = key.split(' ')[1].split('.')[0]      

    x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_wvol_%s_tssplit.npy' % (period, symbol_name)
    pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_wvol_%s_tssplit.npy' % (period, symbol_name)
    index_save_path = current_path + 'npy/' + '%s_cnn_updown_index_train_rascend_ohlcv_wvol_%s_tssplit.npy' % (period, symbol_name)



    if not load_npy:

      from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
      from sklearn.model_selection import train_test_split
      from datetime import datetime

      from funcs_indicator import *

      def min_max_scale(npy_x):

        return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[np.sum(np.isnan(pr)):]

      sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

      #       scale with price    #
      ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

      ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
      sar = lucid_sar(sliced_ohlcv)
      ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
      senkou1, senkou2 = ichimoku(sliced_ohlcv)

      #     min max scale   #
      # vol = ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]
      vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

      pr_list = pr[np.sum(np.isnan(pr)):]
      print("len(ohlc) :", len(ohlc))
      print("len(pr_list) :", len(pr_list))

      print("ohlc.index[0] :", ohlc.index[0])
      print("vol.index[0] :", vol.index[0])
      # break


      #       set params    #
      period = 45
      key_i = i

      plotting = True

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(ohlc)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          # temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

          temp_close = min_max_scale(temp_ohlc[:, [3]])    

          price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          ind_temp_ohlc = min_max_scale(temp_ohlc)
          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


          if plotting:

            plt.plot(ind_temp_ohlc)
            plt.show()
            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          #                   feature selection                   #        
          temp_data = np.hstack((ind_temp_ohlc, temp_vol))

          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          # temp_data = temp_ohlc[:, [3]]
          # temp_data = ind_temp_ohlc[:, [3]]
          # temp_data = temp_close

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      # input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)


      # _, row, col, _ = input_x.shape
      # _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      #                 don't shuffle timeseries data                 #
      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)


      np.save(x_save_path, x_train)
      np.save(x_save_path.replace('x_train', 'x_val'), x_val)
      np.save(x_save_path.replace('x_train', 'x_test'), x_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('x series saved !')

      np.save(pr_save_path, pr_train)
      np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
      np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
      # np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
      print('pr series saved !')
      
      np.save(index_save_path, index_train)
      np.save(index_save_path.replace('index_train', 'index_val'), index_val)
      np.save(index_save_path.replace('index_train', 'index_test'), index_test)
      print('index series saved !')

    else:
      
      x_train = np.load(x_save_path)
      x_val = np.load(x_save_path.replace('x_train', 'x_val'))
      x_test = np.load(x_save_path.replace('x_train', 'x_test'))
      print('x series loaded !')


      pr_train = np.load(pr_save_path)
      pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
      pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
      print('y series loaded !')


      index_train = np.load(index_save_path, allow_pickle=True)
      index_val = np.load(index_save_path.replace('index_train', 'index_val'), allow_pickle=True)
      index_test = np.load(index_save_path.replace('index_train', 'index_test'), allow_pickle=True)
      print('index series loaded !')




    #       pr_thresh by percentage 0.285     #
    plt.plot(pr)
    plt.show()
    
    sorted_pr = sorted(pr, reverse=True)
    pct = 0.28
    len_pct = int(len(pr) * pct)
    pr_thresh = sorted_pr[len_pct]
    print("pr_thresh :", pr_thresh)

    from keras.utils.np_utils import to_categorical
    # from keras.utils import to_categorical
    # from tensorflow.keras.utils.np_utils import to_categorical

    from sklearn.utils import class_weight


    def class_ratio(in_list):

      return in_list / in_list[1]
      
    y_train = np.where(pr_train > pr_thresh, 1, 0)
    y_test = np.where(pr_test > pr_thresh, 1, 0)
    y_val = np.where(pr_val > pr_thresh, 1, 0)

    print('x_train.shape :', x_train.shape)
    print('x_test.shape :', x_test.shape)
    print('x_val.shape :', x_val.shape)
    print('y_train.shape :', y_train.shape)
    print('y_test.shape :', y_test.shape)
    print('y_val.shape :', y_val.shape)

    # try:
    print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
    print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
    print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

    # except Exception as e:
      # print(e)

    label = y_train.reshape(-1, )
    class_weights = class_weight.compute_class_weight('balanced', 
                                                        classes=np.unique(label),
                                                        y=label)
    class_weights = dict(enumerate(class_weights))
    print('class_weights :', class_weights)

    # sample_weight = np.ones(shape=(len(y_train),))
    # sample_weight[(y_train == 1).reshape(-1,)] = 1.5
    # print('sample_weight[:20] :', sample_weight[:20])


    print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
    print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
    print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

    print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
    print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
    print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

    num_classes = 2
    
    # y_train_ohe = np_utils.to_categorical(y_train, num_classes)
    # y_val_ohe = np_utils.to_categorical(y_val, num_classes)
    # y_test_ohe = np_utils.to_categorical(y_test, num_classes)
    
    y_train_ohe = to_categorical(y_train, num_classes)
    y_val_ohe = to_categorical(y_val, num_classes)
    y_test_ohe = to_categorical(y_test, num_classes)
    print('y_train_ohe.shape :', y_train_ohe.shape)
    print('y_val_ohe.shape :', y_val_ohe.shape)
    print('y_test_ohe.shape :', y_test_ohe.shape)

    from keras.preprocessing.image import ImageDataGenerator 
    # from tensorflow.keras.preprocessing.image import ImageDataGenerator 

    datagen = ImageDataGenerator( 
        # rotation_range = 45,
        # zoom_range = 0.5,
        # shear_range = 0.5,
        # horizontal_flip = True,
        # vertical_flip = True,
        # width_shift_range=0.5,
        # height_shift_range=0.5,
        # fill_mode = 'nearest'
        )

    valgen = ImageDataGenerator( 
        )

    datagen.fit(x_train)
    valgen.fit(x_val)


    batch_size = 512


    for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

        plt.suptitle("train x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break

    for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

        plt.suptitle("val x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break
        
    train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
    val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
    # break

    

    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'

    # batch_size = 512

    K.clear_session()


    # model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_tf210_lrcheck_%s.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_kr250_lrcheck_%s.h5' % (period, symbol_name)
    model_name = 'classifier_%s_cnn_updown_rascend_%s_kr250_normcheck_%s.h5' % (int(pct * 1000), period, symbol_name)



    if not load_model:

      # from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
      from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

      model = FER_Model(input_shape=x_train.shape[1:])
      # opt = Adam(learning_rate=1e-5, decay=1e-6)
      opt = Adam( learning_rate=1e-5, decay=1e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-7)
      # opt = Adam( learning_rate=1e-6, decay=1e-7, beta_1=0.9, beta_2=0.999, epsilon=1e-08)
      # opt = Adam( learning_rate=0.001, beta1=0.9, beta2=0.999, epsilon=1e-08, use_locking=False)
      
      # opt = SGD()
      # opt = Adam(lr=0.001, decay=0.0005)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir=board_path,
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_loss', patience=500)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]
      # callbacks_list = [checkpoint, checkpoint2]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 10000
      history = model.fit(train_flow, 
                          steps_per_epoch=len(x_train) / batch_size, 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=val_flow,  
                          validation_steps=len(x_val) / batch_size,
                          shuffle=False)
      
    
    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'


    model = keras.models.load_model(ckpt_path + model_name)

    test_result = model.predict(x_test)
    # test_result = model.predict(test_set)

    print('test_result.shape :', test_result.shape)
    # print('pr_val.shape :', pr_val.shape)

    y_score = test_result[:, [1]]
    print('y_test[:5] :', y_test.reshape(-1,)[:5])
    # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
    print('y_score[:5] :', y_score[:5])
    # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

    print('y_test.shape :', y_test.shape)
    print('y_score.shape :', y_score.shape)

    print('len(y_test) :', len(y_test))

    #     precision recall curve   #
    precision, recall, threshold = precision_recall_curve(y_test, y_score)
    precision, recall = precision[:-1], recall[:-1]

    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    plt.show()
    # print(y_pred)


    # threshold = [0.65]
    # print('threshold :', threshold)
    # break

    acc_pr_bythr = []
    new_thresh = []

    for thresh in threshold:
      
      # if thresh < 0.5:
      #     continue

      y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
      # print('y_pred.shape :', y_pred.shape)
      # print('y_pred :', y_pred)

      #     compare precision     #

      # print('precision :', precision_score(y_test, y_pred))
      # print('recall :', recall_score(y_test, y_pred))
      # print()

      # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
      # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

      # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
      # # plt.show()  
      # print()

      #     check win-ratio improvement     #
      cmat = confusion_matrix(y_test, y_pred)
      # print(cmat)
      # print(np.sum(cmat, axis=1))

      test_size = len(y_test)
      test_pr_list = pr_test
      # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

      org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
      ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
      # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

      # print('pr_test.shape :', pr_test.shape)

      # print(y_pred)
      # print(test_pr_list)

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
      # print('pred_pr_list.shape :', pred_pr_list.shape)

      # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
      #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
      #   print('thresh :', thresh)
        
      # if len(threshold) == 1:
    #   plt.figure(figsize=(10, 5))
    #   plt.subplot(121)
    #   plt.plot(np.cumprod(test_pr_list))
    #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
    # # plt.show()

    #   plt.subplot(122)
    #   plt.plot(np.cumprod(pred_pr_list))
    #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
    #   plt.show()


      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)


    print('acc_pr_bythr :', acc_pr_bythr)

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    # plt.show()
    plt.subplot(122)
    plt.plot(new_thresh, acc_pr_bythr)
    plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
    plt.title(symbol_name)
    plt.show()
# Out:
# start_stamp : 0
# len(ohlcv) : 18048
# x series loaded !
# y series loaded !
# index series loaded !
# pr_thresh : 1.010425784303729
# x_train.shape : (10755, 45, 5, 3)
# x_test.shape : (3586, 45, 5, 3)
# x_val.shape : (3585, 45, 5, 3)
# y_train.shape : (10755, 1)
# y_test.shape : (3586, 1)
# y_val.shape : (3585, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([7723, 3032])) [2.54716359 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2603,  982])) [2.65071283 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2593,  993])) [2.61127895 1.        ]
# class_weights : {0: 0.6962967758643014, 1: 1.7735817941952507}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10755, 2)
# y_val_ohe.shape : (3585, 2)
# y_test_ohe.shape : (3586, 2)
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 45, 5, 3)]        0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 45, 5, 32)         896
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 45, 5, 32)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 45, 5, 64)         18496
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 45, 5, 64)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 5, 128)        73856
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 45, 5, 128)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 45, 5, 256)        295168
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 45, 5, 256)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 57600)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               7372928
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 7,769,730
# Trainable params: 7,769,730
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10000
# 21/21 - 3s - loss: 0.6934 - accuracy: 0.4856 - val_loss: 0.6734 - val_accuracy: 0.7216
#
# Epoch 00001: val_loss improved from inf to 0.67337, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_280_cnn_updown_rascend_45_kr250_normcheck_ETHUSDT.h5
# Epoch 2/10000
# 21/21 - 1s - loss: 0.6929 - accuracy: 0.5520 - val_loss: 0.7294 - val_accuracy: 0.3149
#
# Epoch 00002: val_loss did not improve from 0.67337
# Epoch 3/10000
# 21/21 - 1s - loss: 0.6954 - accuracy: 0.4116 - val_loss: 0.6553 - val_accuracy: 0.7247
#
# Epoch 00003: val_loss improved from 0.67337 to 0.65529, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_280_cnn_updown_rascend_45_kr250_normcheck_ETHUSDT.h5
# Epoch 4/10000
# 21/21 - 1s - loss: 0.6957 - accuracy: 0.6417 - val_loss: 0.7047 - val_accuracy: 0.3674
#
# Epoch 00004: val_loss did not improve from 0.65529
# Epoch 5/10000
# 21/21 - 1s - loss: 0.6914 - accuracy: 0.5979 - val_loss: 0.6869 - val_accuracy: 0.6056
#
# Epoch 00005: val_loss did not improve from 0.65529
# Epoch 6/10000
# 21/21 - 1s - loss: 0.6915 - accuracy: 0.5133 - val_loss: 0.6936 - val_accuracy: 0.5283
#
# Epoch 00006: val_loss did not improve from 0.65529
# Epoch 7/10000
# 21/21 - 1s - loss: 0.6912 - accuracy: 0.5004 - val_loss: 0.6836 - val_accuracy: 0.6117
#
# Epoch 00007: val_loss did not improve from 0.65529
# Epoch 8/10000
# 21/21 - 1s - loss: 0.6920 - accuracy: 0.6745 - val_loss: 0.7023 - val_accuracy: 0.4089
#
# Epoch 00008: val_loss did not improve from 0.65529
# Epoch 9/10000
# 21/21 - 1s - loss: 0.6906 - accuracy: 0.4054 - val_loss: 0.6955 - val_accuracy: 0.4806
#
# Epoch 00009: val_loss did not improve from 0.65529
# Epoch 10/10000
# 21/21 - 1s - loss: 0.6896 - accuracy: 0.4563 - val_loss: 0.6881 - val_accuracy: 0.5816
#
# Epoch 00010: val_loss did not improve from 0.65529
# Epoch 11/10000
# 21/21 - 1s - loss: 0.6891 - accuracy: 0.5901 - val_loss: 0.6940 - val_accuracy: 0.5392
#
# Epoch 00011: val_loss did not improve from 0.65529
# Epoch 12/10000
# 21/21 - 1s - loss: 0.6895 - accuracy: 0.5699 - val_loss: 0.6917 - val_accuracy: 0.5562
#
# Epoch 00012: val_loss did not improve from 0.65529
# Epoch 13/10000
# 21/21 - 1s - loss: 0.6876 - accuracy: 0.5663 - val_loss: 0.6731 - val_accuracy: 0.6427
#
# Epoch 00013: val_loss did not improve from 0.65529
# Epoch 14/10000
# 21/21 - 1s - loss: 0.6893 - accuracy: 0.5857 - val_loss: 0.7275 - val_accuracy: 0.3389
#
# Epoch 00014: val_loss did not improve from 0.65529
# Epoch 15/10000
# 21/21 - 1s - loss: 0.6873 - accuracy: 0.5275 - val_loss: 0.6777 - val_accuracy: 0.6134
#
# Epoch 00015: val_loss did not improve from 0.65529
# Epoch 16/10000
# 21/21 - 1s - loss: 0.6885 - accuracy: 0.5680 - val_loss: 0.6838 - val_accuracy: 0.5847
#
# Epoch 00016: val_loss did not improve from 0.65529
# Epoch 17/10000
# 21/21 - 1s - loss: 0.6900 - accuracy: 0.6308 - val_loss: 0.7277 - val_accuracy: 0.3367
#
# Epoch 00017: val_loss did not improve from 0.65529
# Epoch 18/10000
# 21/21 - 1s - loss: 0.6869 - accuracy: 0.5022 - val_loss: 0.6707 - val_accuracy: 0.6516
#
# Epoch 00018: val_loss did not improve from 0.65529
# Epoch 19/10000
# 21/21 - 1s - loss: 0.6888 - accuracy: 0.6192 - val_loss: 0.7011 - val_accuracy: 0.4709
#
# Epoch 00019: val_loss did not improve from 0.65529
# Epoch 20/10000
# 21/21 - 1s - loss: 0.6858 - accuracy: 0.6351 - val_loss: 0.7014 - val_accuracy: 0.4709
#
# Epoch 00020: val_loss did not improve from 0.65529
# Epoch 21/10000
# 21/21 - 1s - loss: 0.6872 - accuracy: 0.4360 - val_loss: 0.6817 - val_accuracy: 0.5654
#
# Epoch 00021: val_loss did not improve from 0.65529
# Epoch 22/10000
# 21/21 - 1s - loss: 0.6861 - accuracy: 0.4474 - val_loss: 0.6887 - val_accuracy: 0.5389
#
# Epoch 00022: val_loss did not improve from 0.65529
# Epoch 23/10000
# 21/21 - 1s - loss: 0.6850 - accuracy: 0.5165 - val_loss: 0.6791 - val_accuracy: 0.5821
#
# Epoch 00023: val_loss did not improve from 0.65529
# Epoch 24/10000
# 21/21 - 1s - loss: 0.6829 - accuracy: 0.6169 - val_loss: 0.7038 - val_accuracy: 0.4815
#
# Epoch 00024: val_loss did not improve from 0.65529
# Epoch 25/10000
# 21/21 - 1s - loss: 0.6812 - accuracy: 0.6181 - val_loss: 0.7300 - val_accuracy: 0.4014
#
# Epoch 00025: val_loss did not improve from 0.65529
# Epoch 26/10000
# 21/21 - 1s - loss: 0.6872 - accuracy: 0.5011 - val_loss: 0.6603 - val_accuracy: 0.6508
#
# Epoch 00026: val_loss did not improve from 0.65529
# Epoch 27/10000
# 21/21 - 1s - loss: 0.6815 - accuracy: 0.6179 - val_loss: 0.6925 - val_accuracy: 0.5384
#
# Epoch 00027: val_loss did not improve from 0.65529
# Epoch 28/10000
# 21/21 - 1s - loss: 0.6816 - accuracy: 0.6042 - val_loss: 0.7062 - val_accuracy: 0.4865
#
# Epoch 00028: val_loss did not improve from 0.65529
# Epoch 29/10000
# 21/21 - 1s - loss: 0.6796 - accuracy: 0.6262 - val_loss: 0.7189 - val_accuracy: 0.4460
#
# Epoch 00029: val_loss did not improve from 0.65529
# Epoch 30/10000
# 21/21 - 1s - loss: 0.6864 - accuracy: 0.4545 - val_loss: 0.6569 - val_accuracy: 0.6619
#
# Epoch 00030: val_loss did not improve from 0.65529
# Epoch 31/10000
# 21/21 - 1s - loss: 0.6806 - accuracy: 0.5754 - val_loss: 0.7003 - val_accuracy: 0.5049
#
# Epoch 00031: val_loss did not improve from 0.65529
# Epoch 32/10000
# 21/21 - 1s - loss: 0.6817 - accuracy: 0.4920 - val_loss: 0.6740 - val_accuracy: 0.6031
#
# Epoch 00032: val_loss did not improve from 0.65529
# Epoch 33/10000
# 21/21 - 1s - loss: 0.6802 - accuracy: 0.5155 - val_loss: 0.6794 - val_accuracy: 0.5902
#
# Epoch 00033: val_loss did not improve from 0.65529
# Epoch 34/10000
# 21/21 - 1s - loss: 0.6783 - accuracy: 0.5863 - val_loss: 0.6692 - val_accuracy: 0.6153
#
# Epoch 00034: val_loss did not improve from 0.65529
# Epoch 35/10000
# 21/21 - 1s - loss: 0.6798 - accuracy: 0.6314 - val_loss: 0.7168 - val_accuracy: 0.4711
#
# Epoch 00035: val_loss did not improve from 0.65529
# Epoch 36/10000
# 21/21 - 1s - loss: 0.6771 - accuracy: 0.5559 - val_loss: 0.6784 - val_accuracy: 0.5866
#
# Epoch 00036: val_loss did not improve from 0.65529
# Epoch 37/10000
# 21/21 - 1s - loss: 0.6790 - accuracy: 0.5207 - val_loss: 0.6490 - val_accuracy: 0.6717
#
# Epoch 00037: val_loss improved from 0.65529 to 0.64905, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_280_cnn_updown_rascend_45_kr250_normcheck_ETHUSDT.h5
# Epoch 38/10000
# 21/21 - 1s - loss: 0.6811 - accuracy: 0.6386 - val_loss: 0.7060 - val_accuracy: 0.5018
#
# Epoch 00038: val_loss did not improve from 0.64905
# Epoch 39/10000
# 21/21 - 1s - loss: 0.6775 - accuracy: 0.5831 - val_loss: 0.6898 - val_accuracy: 0.5570
#
# Epoch 00039: val_loss did not improve from 0.64905
# Epoch 40/10000
# 21/21 - 1s - loss: 0.6773 - accuracy: 0.5642 - val_loss: 0.6704 - val_accuracy: 0.6053
#
# Epoch 00040: val_loss did not improve from 0.64905
# Epoch 41/10000
# 21/21 - 1s - loss: 0.6789 - accuracy: 0.6454 - val_loss: 0.7069 - val_accuracy: 0.5013
#
# Epoch 00041: val_loss did not improve from 0.64905
# Epoch 42/10000
# 21/21 - 1s - loss: 0.6769 - accuracy: 0.5543 - val_loss: 0.6671 - val_accuracy: 0.6198
#
# Epoch 00042: val_loss did not improve from 0.64905
# Epoch 43/10000
# 21/21 - 1s - loss: 0.6771 - accuracy: 0.6290 - val_loss: 0.7024 - val_accuracy: 0.5174
#
# Epoch 00043: val_loss did not improve from 0.64905
# Epoch 44/10000
# 21/21 - 1s - loss: 0.6751 - accuracy: 0.5895 - val_loss: 0.7141 - val_accuracy: 0.4887
#
# Epoch 00044: val_loss did not improve from 0.64905
# Epoch 45/10000
# 21/21 - 1s - loss: 0.6822 - accuracy: 0.5073 - val_loss: 0.6383 - val_accuracy: 0.6770
#
# Epoch 00045: val_loss improved from 0.64905 to 0.63830, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_280_cnn_updown_rascend_45_kr250_normcheck_ETHUSDT.h5
# Epoch 46/10000
# 21/21 - 1s - loss: 0.6783 - accuracy: 0.6413 - val_loss: 0.6997 - val_accuracy: 0.5269
#
# Epoch 00046: val_loss did not improve from 0.63830
# Epoch 47/10000
# 21/21 - 1s - loss: 0.6744 - accuracy: 0.6256 - val_loss: 0.6687 - val_accuracy: 0.6187
#
# Epoch 00047: val_loss did not improve from 0.63830
# Epoch 48/10000
# 21/21 - 1s - loss: 0.6739 - accuracy: 0.6332 - val_loss: 0.6995 - val_accuracy: 0.5322
#
# Epoch 00048: val_loss did not improve from 0.63830
# Epoch 49/10000
# 21/21 - 1s - loss: 0.6731 - accuracy: 0.5811 - val_loss: 0.6888 - val_accuracy: 0.5556
#
# Epoch 00049: val_loss did not improve from 0.63830
# Epoch 50/10000
# 21/21 - 1s - loss: 0.6731 - accuracy: 0.5539 - val_loss: 0.6540 - val_accuracy: 0.6413
#
# Epoch 00050: val_loss did not improve from 0.63830
# Epoch 51/10000
# 21/21 - 1s - loss: 0.6728 - accuracy: 0.5947 - val_loss: 0.6691 - val_accuracy: 0.6070
#
# Epoch 00051: val_loss did not improve from 0.63830
# Epoch 52/10000
# 21/21 - 1s - loss: 0.6721 - accuracy: 0.6020 - val_loss: 0.6610 - val_accuracy: 0.6215
#
# Epoch 00052: val_loss did not improve from 0.63830
# Epoch 53/10000
# 21/21 - 1s - loss: 0.6729 - accuracy: 0.6018 - val_loss: 0.6798 - val_accuracy: 0.5821
#
# Epoch 00053: val_loss did not improve from 0.63830
# Epoch 54/10000
# 21/21 - 1s - loss: 0.6706 - accuracy: 0.6177 - val_loss: 0.6733 - val_accuracy: 0.5992
#
# Epoch 00054: val_loss did not improve from 0.63830
# Epoch 55/10000
# 21/21 - 1s - loss: 0.6720 - accuracy: 0.6003 - val_loss: 0.6774 - val_accuracy: 0.5894
#
# Epoch 00055: val_loss did not improve from 0.63830
# Epoch 56/10000
# 21/21 - 1s - loss: 0.6740 - accuracy: 0.6329 - val_loss: 0.7051 - val_accuracy: 0.5208
#
# Epoch 00056: val_loss did not improve from 0.63830
# Epoch 57/10000
# 21/21 - 1s - loss: 0.6716 - accuracy: 0.6303 - val_loss: 0.6771 - val_accuracy: 0.5922
#
# Epoch 00057: val_loss did not improve from 0.63830
# Epoch 58/10000
# 21/21 - 1s - loss: 0.6712 - accuracy: 0.6248 - val_loss: 0.7118 - val_accuracy: 0.5013
#
# Epoch 00058: val_loss did not improve from 0.63830
# Epoch 59/10000
# 21/21 - 1s - loss: 0.6712 - accuracy: 0.5807 - val_loss: 0.6534 - val_accuracy: 0.6360
#
# Epoch 00059: val_loss did not improve from 0.63830
# Epoch 60/10000
# 21/21 - 1s - loss: 0.6703 - accuracy: 0.6261 - val_loss: 0.6671 - val_accuracy: 0.6123
#
# Epoch 00060: val_loss did not improve from 0.63830
# Epoch 61/10000
# 21/21 - 1s - loss: 0.6723 - accuracy: 0.6238 - val_loss: 0.7004 - val_accuracy: 0.5308
#
# Epoch 00061: val_loss did not improve from 0.63830
# Epoch 62/10000
# 21/21 - 1s - loss: 0.6690 - accuracy: 0.6146 - val_loss: 0.6932 - val_accuracy: 0.5537
#
# Epoch 00062: val_loss did not improve from 0.63830
# Epoch 63/10000
# 21/21 - 1s - loss: 0.6688 - accuracy: 0.5890 - val_loss: 0.6548 - val_accuracy: 0.6363
#
# Epoch 00063: val_loss did not improve from 0.63830
# Epoch 64/10000
# 21/21 - 1s - loss: 0.6689 - accuracy: 0.6231 - val_loss: 0.6989 - val_accuracy: 0.5417
#
# Epoch 00064: val_loss did not improve from 0.63830
# Epoch 65/10000
# 21/21 - 1s - loss: 0.6681 - accuracy: 0.6022 - val_loss: 0.6837 - val_accuracy: 0.5668
#
# Epoch 00065: val_loss did not improve from 0.63830
# Epoch 66/10000
# 21/21 - 1s - loss: 0.6676 - accuracy: 0.5933 - val_loss: 0.6579 - val_accuracy: 0.6279
#
# Epoch 00066: val_loss did not improve from 0.63830
# Epoch 67/10000
# 21/21 - 1s - loss: 0.6691 - accuracy: 0.6305 - val_loss: 0.6976 - val_accuracy: 0.5392
#
# Epoch 00067: val_loss did not improve from 0.63830
# Epoch 68/10000
# 21/21 - 1s - loss: 0.6681 - accuracy: 0.5754 - val_loss: 0.6566 - val_accuracy: 0.6296
#
# Epoch 00068: val_loss did not improve from 0.63830
# Epoch 69/10000
# 21/21 - 1s - loss: 0.6674 - accuracy: 0.6005 - val_loss: 0.6718 - val_accuracy: 0.5983
#
# Epoch 00069: val_loss did not improve from 0.63830
# Epoch 70/10000
# 21/21 - 1s - loss: 0.6664 - accuracy: 0.5777 - val_loss: 0.6614 - val_accuracy: 0.6243
#
# Epoch 00070: val_loss did not improve from 0.63830
# Epoch 71/10000
# 21/21 - 1s - loss: 0.6676 - accuracy: 0.5908 - val_loss: 0.6867 - val_accuracy: 0.5824
#
# Epoch 00071: val_loss did not improve from 0.63830
# Epoch 72/10000
# 21/21 - 1s - loss: 0.6690 - accuracy: 0.5638 - val_loss: 0.6434 - val_accuracy: 0.6502
#
# Epoch 00072: val_loss did not improve from 0.63830
# Epoch 73/10000
# 21/21 - 1s - loss: 0.6685 - accuracy: 0.6221 - val_loss: 0.6795 - val_accuracy: 0.5810
#
# Epoch 00073: val_loss did not improve from 0.63830
# Epoch 74/10000
# 21/21 - 1s - loss: 0.6656 - accuracy: 0.6278 - val_loss: 0.6580 - val_accuracy: 0.6257
#
# Epoch 00074: val_loss did not improve from 0.63830
# Epoch 75/10000
# 21/21 - 1s - loss: 0.6662 - accuracy: 0.6400 - val_loss: 0.7026 - val_accuracy: 0.5347
#
# Epoch 00075: val_loss did not improve from 0.63830
# Epoch 76/10000
# 21/21 - 1s - loss: 0.6664 - accuracy: 0.5660 - val_loss: 0.6592 - val_accuracy: 0.6240
#
# Epoch 00076: val_loss did not improve from 0.63830
# Epoch 77/10000
# 21/21 - 1s - loss: 0.6644 - accuracy: 0.6164 - val_loss: 0.6595 - val_accuracy: 0.6187
#
# Epoch 00077: val_loss did not improve from 0.63830
# Epoch 78/10000
# 21/21 - 1s - loss: 0.6652 - accuracy: 0.6430 - val_loss: 0.6683 - val_accuracy: 0.6064
#
# Epoch 00078: val_loss did not improve from 0.63830
# Epoch 79/10000
# 21/21 - 1s - loss: 0.6666 - accuracy: 0.6429 - val_loss: 0.6840 - val_accuracy: 0.5699
#
# Epoch 00079: val_loss did not improve from 0.63830
# Epoch 80/10000
# 21/21 - 1s - loss: 0.6639 - accuracy: 0.6221 - val_loss: 0.6950 - val_accuracy: 0.5534
#
# Epoch 00080: val_loss did not improve from 0.63830
# Epoch 81/10000
# 21/21 - 1s - loss: 0.6651 - accuracy: 0.5834 - val_loss: 0.6512 - val_accuracy: 0.6338
#
# Epoch 00081: val_loss did not improve from 0.63830
# Epoch 82/10000
# 21/21 - 1s - loss: 0.6634 - accuracy: 0.6367 - val_loss: 0.6734 - val_accuracy: 0.5992
#
# Epoch 00082: val_loss did not improve from 0.63830
# Epoch 83/10000
# 21/21 - 1s - loss: 0.6626 - accuracy: 0.6392 - val_loss: 0.6945 - val_accuracy: 0.5554
#
# Epoch 00083: val_loss did not improve from 0.63830
# Epoch 84/10000
# 21/21 - 1s - loss: 0.6622 - accuracy: 0.6045 - val_loss: 0.6667 - val_accuracy: 0.6033
#
# Epoch 00084: val_loss did not improve from 0.63830
# Epoch 85/10000
# 21/21 - 1s - loss: 0.6619 - accuracy: 0.6128 - val_loss: 0.7261 - val_accuracy: 0.4943
#
# Epoch 00085: val_loss did not improve from 0.63830
# Epoch 86/10000
# 21/21 - 1s - loss: 0.6790 - accuracy: 0.4915 - val_loss: 0.6400 - val_accuracy: 0.6572
#
# Epoch 00086: val_loss did not improve from 0.63830
# Epoch 87/10000
# 21/21 - 1s - loss: 0.6639 - accuracy: 0.6322 - val_loss: 0.6789 - val_accuracy: 0.5816
#
# Epoch 00087: val_loss did not improve from 0.63830
# Epoch 88/10000
# 21/21 - 1s - loss: 0.6643 - accuracy: 0.6438 - val_loss: 0.7074 - val_accuracy: 0.5236
#
# Epoch 00088: val_loss did not improve from 0.63830
# Epoch 89/10000
# 21/21 - 1s - loss: 0.6628 - accuracy: 0.5857 - val_loss: 0.6452 - val_accuracy: 0.6416
#
# Epoch 00089: val_loss did not improve from 0.63830
# Epoch 90/10000
# 21/21 - 1s - loss: 0.6629 - accuracy: 0.6366 - val_loss: 0.6784 - val_accuracy: 0.5838
#
# Epoch 00090: val_loss did not improve from 0.63830
# Epoch 91/10000
# 21/21 - 1s - loss: 0.6608 - accuracy: 0.6297 - val_loss: 0.6797 - val_accuracy: 0.5838
#
# Epoch 00091: val_loss did not improve from 0.63830
# Epoch 92/10000
# 21/21 - 1s - loss: 0.6599 - accuracy: 0.6183 - val_loss: 0.6604 - val_accuracy: 0.6151
#
# Epoch 00092: val_loss did not improve from 0.63830
# Epoch 93/10000
# 21/21 - 1s - loss: 0.6616 - accuracy: 0.6334 - val_loss: 0.6871 - val_accuracy: 0.5732
#
# Epoch 00093: val_loss did not improve from 0.63830
# Epoch 94/10000
# 21/21 - 1s - loss: 0.6592 - accuracy: 0.6269 - val_loss: 0.6758 - val_accuracy: 0.5936
#
# Epoch 00094: val_loss did not improve from 0.63830
# Epoch 95/10000
# 21/21 - 1s - loss: 0.6589 - accuracy: 0.5978 - val_loss: 0.6601 - val_accuracy: 0.6145
#
# Epoch 00095: val_loss did not improve from 0.63830
# Epoch 96/10000
# 21/21 - 1s - loss: 0.6590 - accuracy: 0.6221 - val_loss: 0.6668 - val_accuracy: 0.6095
#
# Epoch 00096: val_loss did not improve from 0.63830
# Epoch 97/10000
# 21/21 - 1s - loss: 0.6582 - accuracy: 0.6232 - val_loss: 0.6727 - val_accuracy: 0.5992
#
# Epoch 00097: val_loss did not improve from 0.63830
# Epoch 98/10000
# 21/21 - 1s - loss: 0.6585 - accuracy: 0.6331 - val_loss: 0.6652 - val_accuracy: 0.6126
#
# Epoch 00098: val_loss did not improve from 0.63830
# Epoch 99/10000
# 21/21 - 1s - loss: 0.6605 - accuracy: 0.6434 - val_loss: 0.6948 - val_accuracy: 0.5478
#
# Epoch 00099: val_loss did not improve from 0.63830
# Epoch 100/10000
# 21/21 - 1s - loss: 0.6579 - accuracy: 0.6140 - val_loss: 0.6663 - val_accuracy: 0.6103
#
# Epoch 00100: val_loss did not improve from 0.63830
# Epoch 101/10000
# 21/21 - 1s - loss: 0.6572 - accuracy: 0.6239 - val_loss: 0.6812 - val_accuracy: 0.5844
#
# Epoch 00101: val_loss did not improve from 0.63830
# Epoch 102/10000
# 21/21 - 1s - loss: 0.6584 - accuracy: 0.5997 - val_loss: 0.6661 - val_accuracy: 0.6059
#
# Epoch 00102: val_loss did not improve from 0.63830
# Epoch 103/10000
# 21/21 - 1s - loss: 0.6570 - accuracy: 0.6223 - val_loss: 0.6992 - val_accuracy: 0.5562
#
# Epoch 00103: val_loss did not improve from 0.63830
# Epoch 104/10000
# 21/21 - 1s - loss: 0.6638 - accuracy: 0.5426 - val_loss: 0.6401 - val_accuracy: 0.6469
#
# Epoch 00104: val_loss did not improve from 0.63830
# Epoch 105/10000
# 21/21 - 1s - loss: 0.6587 - accuracy: 0.6400 - val_loss: 0.6883 - val_accuracy: 0.5713
#
# Epoch 00105: val_loss did not improve from 0.63830
# Epoch 106/10000
# 21/21 - 1s - loss: 0.6583 - accuracy: 0.6365 - val_loss: 0.6992 - val_accuracy: 0.5526
#
# Epoch 00106: val_loss did not improve from 0.63830
# Epoch 107/10000
# 21/21 - 1s - loss: 0.6644 - accuracy: 0.5453 - val_loss: 0.6514 - val_accuracy: 0.6343
#
# Epoch 00107: val_loss did not improve from 0.63830
# Epoch 108/10000
# 21/21 - 1s - loss: 0.6575 - accuracy: 0.6154 - val_loss: 0.6658 - val_accuracy: 0.6131
#
# Epoch 00108: val_loss did not improve from 0.63830
# Epoch 109/10000
# 21/21 - 1s - loss: 0.6563 - accuracy: 0.6354 - val_loss: 0.6651 - val_accuracy: 0.6098
#
# Epoch 00109: val_loss did not improve from 0.63830
# Epoch 110/10000
# 21/21 - 1s - loss: 0.6559 - accuracy: 0.6407 - val_loss: 0.6708 - val_accuracy: 0.6000
#
# Epoch 00110: val_loss did not improve from 0.63830
# Epoch 111/10000
# 21/21 - 1s - loss: 0.6550 - accuracy: 0.6254 - val_loss: 0.6622 - val_accuracy: 0.6148
#
# Epoch 00111: val_loss did not improve from 0.63830
# Epoch 112/10000
# 21/21 - 1s - loss: 0.6554 - accuracy: 0.6173 - val_loss: 0.6593 - val_accuracy: 0.6139
#
# Epoch 00112: val_loss did not improve from 0.63830
# Epoch 113/10000
# 21/21 - 1s - loss: 0.6566 - accuracy: 0.6475 - val_loss: 0.6966 - val_accuracy: 0.5506
#
# Epoch 00113: val_loss did not improve from 0.63830
# Epoch 114/10000
# 21/21 - 1s - loss: 0.6553 - accuracy: 0.6106 - val_loss: 0.6650 - val_accuracy: 0.6123
#
# Epoch 00114: val_loss did not improve from 0.63830
# Epoch 115/10000
# 21/21 - 1s - loss: 0.6569 - accuracy: 0.5892 - val_loss: 0.6492 - val_accuracy: 0.6371
#
# Epoch 00115: val_loss did not improve from 0.63830
# Epoch 116/10000
# 21/21 - 1s - loss: 0.6549 - accuracy: 0.6294 - val_loss: 0.6775 - val_accuracy: 0.5880
#
# Epoch 00116: val_loss did not improve from 0.63830
# Epoch 117/10000
# 21/21 - 1s - loss: 0.6538 - accuracy: 0.6338 - val_loss: 0.6960 - val_accuracy: 0.5565
#
# Epoch 00117: val_loss did not improve from 0.63830
# Epoch 118/10000
# 21/21 - 1s - loss: 0.6610 - accuracy: 0.5504 - val_loss: 0.6347 - val_accuracy: 0.6538
#
# Epoch 00118: val_loss improved from 0.63830 to 0.63470, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_280_cnn_updown_rascend_45_kr250_normcheck_ETHUSDT.h5
# Epoch 119/10000
# 21/21 - 1s - loss: 0.6594 - accuracy: 0.6487 - val_loss: 0.6822 - val_accuracy: 0.5735
#
# Epoch 00119: val_loss did not improve from 0.63470
# Epoch 120/10000
# 21/21 - 1s - loss: 0.6547 - accuracy: 0.6510 - val_loss: 0.6811 - val_accuracy: 0.5743
#
# Epoch 00120: val_loss did not improve from 0.63470
# Epoch 121/10000
# 21/21 - 1s - loss: 0.6533 - accuracy: 0.6117 - val_loss: 0.6539 - val_accuracy: 0.6290
#
# Epoch 00121: val_loss did not improve from 0.63470
# Epoch 122/10000
# 21/21 - 1s - loss: 0.6543 - accuracy: 0.6498 - val_loss: 0.6836 - val_accuracy: 0.5746
#
# Epoch 00122: val_loss did not improve from 0.63470
# Epoch 123/10000
# 21/21 - 1s - loss: 0.6521 - accuracy: 0.6184 - val_loss: 0.6579 - val_accuracy: 0.6159
#
# Epoch 00123: val_loss did not improve from 0.63470
# Epoch 124/10000
# 21/21 - 1s - loss: 0.6522 - accuracy: 0.6240 - val_loss: 0.6521 - val_accuracy: 0.6279
#
# Epoch 00124: val_loss did not improve from 0.63470
# Epoch 125/10000
# 21/21 - 1s - loss: 0.6538 - accuracy: 0.6430 - val_loss: 0.6736 - val_accuracy: 0.5880
#
# Epoch 00125: val_loss did not improve from 0.63470
# Epoch 126/10000
# 21/21 - 1s - loss: 0.6538 - accuracy: 0.6439 - val_loss: 0.7014 - val_accuracy: 0.5400
#
# Epoch 00126: val_loss did not improve from 0.63470
# Epoch 127/10000
# 21/21 - 1s - loss: 0.6554 - accuracy: 0.5921 - val_loss: 0.6547 - val_accuracy: 0.6257
#
# Epoch 00127: val_loss did not improve from 0.63470
# Epoch 128/10000
# 21/21 - 1s - loss: 0.6516 - accuracy: 0.6091 - val_loss: 0.6609 - val_accuracy: 0.6162
#
# Epoch 00128: val_loss did not improve from 0.63470
# Epoch 129/10000
# 21/21 - 1s - loss: 0.6513 - accuracy: 0.6169 - val_loss: 0.6677 - val_accuracy: 0.6059
#
# Epoch 00129: val_loss did not improve from 0.63470
# Epoch 130/10000
# 21/21 - 1s - loss: 0.6523 - accuracy: 0.6073 - val_loss: 0.6549 - val_accuracy: 0.6243
#
# Epoch 00130: val_loss did not improve from 0.63470
# Epoch 131/10000
# 21/21 - 1s - loss: 0.6512 - accuracy: 0.6279 - val_loss: 0.6587 - val_accuracy: 0.6165
#
# Epoch 00131: val_loss did not improve from 0.63470
# Epoch 132/10000
# 21/21 - 1s - loss: 0.6516 - accuracy: 0.6495 - val_loss: 0.6660 - val_accuracy: 0.6067
#
# Epoch 00132: val_loss did not improve from 0.63470
# Epoch 133/10000
# 21/21 - 1s - loss: 0.6507 - accuracy: 0.6472 - val_loss: 0.6808 - val_accuracy: 0.5788
#
# Epoch 00133: val_loss did not improve from 0.63470
# Epoch 134/10000
# 21/21 - 1s - loss: 0.6511 - accuracy: 0.6076 - val_loss: 0.6545 - val_accuracy: 0.6243
#
# Epoch 00134: val_loss did not improve from 0.63470
# Epoch 135/10000
# 21/21 - 1s - loss: 0.6499 - accuracy: 0.6329 - val_loss: 0.6672 - val_accuracy: 0.6047
#
# Epoch 00135: val_loss did not improve from 0.63470
# Epoch 136/10000
# 21/21 - 1s - loss: 0.6496 - accuracy: 0.6450 - val_loss: 0.6629 - val_accuracy: 0.6106
#
# Epoch 00136: val_loss did not improve from 0.63470
# Epoch 137/10000
# 21/21 - 1s - loss: 0.6504 - accuracy: 0.6359 - val_loss: 0.6696 - val_accuracy: 0.5964
#
# Epoch 00137: val_loss did not improve from 0.63470
# Epoch 138/10000
# 21/21 - 1s - loss: 0.6485 - accuracy: 0.6329 - val_loss: 0.6518 - val_accuracy: 0.6268
#
# Epoch 00138: val_loss did not improve from 0.63470
# Epoch 139/10000
# 21/21 - 1s - loss: 0.6501 - accuracy: 0.6485 - val_loss: 0.6874 - val_accuracy: 0.5654
#
# Epoch 00139: val_loss did not improve from 0.63470
# Epoch 140/10000
# 21/21 - 1s - loss: 0.6484 - accuracy: 0.6261 - val_loss: 0.6695 - val_accuracy: 0.6011
#
# Epoch 00140: val_loss did not improve from 0.63470
# Epoch 141/10000
# 21/21 - 1s - loss: 0.6476 - accuracy: 0.6296 - val_loss: 0.6779 - val_accuracy: 0.5855
#
# Epoch 00141: val_loss did not improve from 0.63470
# Epoch 142/10000
# 21/21 - 1s - loss: 0.6504 - accuracy: 0.6025 - val_loss: 0.6312 - val_accuracy: 0.6530
#
# Epoch 00142: val_loss improved from 0.63470 to 0.63122, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_280_cnn_updown_rascend_45_kr250_normcheck_ETHUSDT.h5
# Epoch 143/10000
# 21/21 - 1s - loss: 0.6526 - accuracy: 0.6440 - val_loss: 0.6870 - val_accuracy: 0.5651
#
# Epoch 00143: val_loss did not improve from 0.63122
# Epoch 144/10000
# 21/21 - 1s - loss: 0.6479 - accuracy: 0.6245 - val_loss: 0.6672 - val_accuracy: 0.6039
#
# Epoch 00144: val_loss did not improve from 0.63122
# Epoch 145/10000
# 21/21 - 1s - loss: 0.6511 - accuracy: 0.5923 - val_loss: 0.6547 - val_accuracy: 0.6262
#
# Epoch 00145: val_loss did not improve from 0.63122
# Epoch 146/10000
# 21/21 - 1s - loss: 0.6471 - accuracy: 0.6180 - val_loss: 0.6490 - val_accuracy: 0.6304
#
# Epoch 00146: val_loss did not improve from 0.63122
# Epoch 147/10000
# 21/21 - 1s - loss: 0.6482 - accuracy: 0.6496 - val_loss: 0.7030 - val_accuracy: 0.5336
#
# Epoch 00147: val_loss did not improve from 0.63122
# Epoch 148/10000
# 21/21 - 1s - loss: 0.6547 - accuracy: 0.5689 - val_loss: 0.6345 - val_accuracy: 0.6477
#
# Epoch 00148: val_loss did not improve from 0.63122
# Epoch 149/10000
# 21/21 - 1s - loss: 0.6470 - accuracy: 0.6173 - val_loss: 0.6725 - val_accuracy: 0.5905
#
# Epoch 00149: val_loss did not improve from 0.63122
# Epoch 150/10000
# 21/21 - 1s - loss: 0.6476 - accuracy: 0.6342 - val_loss: 0.6848 - val_accuracy: 0.5623
#
# Epoch 00150: val_loss did not improve from 0.63122
# Epoch 151/10000
# 21/21 - 1s - loss: 0.6542 - accuracy: 0.5511 - val_loss: 0.6387 - val_accuracy: 0.6432
#
# Epoch 00151: val_loss did not improve from 0.63122
# Epoch 152/10000
# 21/21 - 1s - loss: 0.6489 - accuracy: 0.6369 - val_loss: 0.6710 - val_accuracy: 0.5953
#
# Epoch 00152: val_loss did not improve from 0.63122
# Epoch 153/10000
# 21/21 - 1s - loss: 0.6467 - accuracy: 0.6455 - val_loss: 0.6617 - val_accuracy: 0.6114
#
# Epoch 00153: val_loss did not improve from 0.63122
# Epoch 154/10000
# 21/21 - 1s - loss: 0.6465 - accuracy: 0.6524 - val_loss: 0.6774 - val_accuracy: 0.5774
#
# Epoch 00154: val_loss did not improve from 0.63122
# Epoch 155/10000
# 21/21 - 1s - loss: 0.6467 - accuracy: 0.6157 - val_loss: 0.6650 - val_accuracy: 0.6050
#
# Epoch 00155: val_loss did not improve from 0.63122
# Epoch 156/10000
# 21/21 - 1s - loss: 0.6485 - accuracy: 0.5967 - val_loss: 0.6572 - val_accuracy: 0.6173
#
# Epoch 00156: val_loss did not improve from 0.63122
# Epoch 157/10000
# 21/21 - 1s - loss: 0.6473 - accuracy: 0.6029 - val_loss: 0.6546 - val_accuracy: 0.6184
#
# Epoch 00157: val_loss did not improve from 0.63122
# Epoch 158/10000
# 21/21 - 1s - loss: 0.6454 - accuracy: 0.6251 - val_loss: 0.6557 - val_accuracy: 0.6220
#
# Epoch 00158: val_loss did not improve from 0.63122
# Epoch 159/10000
# 21/21 - 1s - loss: 0.6454 - accuracy: 0.6502 - val_loss: 0.6806 - val_accuracy: 0.5757
#
# Epoch 00159: val_loss did not improve from 0.63122
# Epoch 160/10000
# 21/21 - 1s - loss: 0.6448 - accuracy: 0.6219 - val_loss: 0.6580 - val_accuracy: 0.6190
#
# Epoch 00160: val_loss did not improve from 0.63122
# Epoch 161/10000
# 21/21 - 1s - loss: 0.6438 - accuracy: 0.6381 - val_loss: 0.6724 - val_accuracy: 0.5936
#
# Epoch 00161: val_loss did not improve from 0.63122
# Epoch 162/10000
# 21/21 - 1s - loss: 0.6437 - accuracy: 0.6281 - val_loss: 0.6729 - val_accuracy: 0.5886
#
# Epoch 00162: val_loss did not improve from 0.63122
# Epoch 163/10000
# 21/21 - 1s - loss: 0.6499 - accuracy: 0.5922 - val_loss: 0.6595 - val_accuracy: 0.6215
#
# Epoch 00163: val_loss did not improve from 0.63122
# Epoch 164/10000
# 21/21 - 1s - loss: 0.6498 - accuracy: 0.5737 - val_loss: 0.6506 - val_accuracy: 0.6315
#
# Epoch 00164: val_loss did not improve from 0.63122
# Epoch 165/10000
# 21/21 - 1s - loss: 0.6453 - accuracy: 0.6340 - val_loss: 0.6607 - val_accuracy: 0.6075
#
# Epoch 00165: val_loss did not improve from 0.63122
# Epoch 166/10000
# 21/21 - 1s - loss: 0.6436 - accuracy: 0.6366 - val_loss: 0.6568 - val_accuracy: 0.6192
#
# Epoch 00166: val_loss did not improve from 0.63122
# Epoch 167/10000
# 21/21 - 1s - loss: 0.6432 - accuracy: 0.6497 - val_loss: 0.6902 - val_accuracy: 0.5623
#
# Epoch 00167: val_loss did not improve from 0.63122
# Epoch 168/10000
# 21/21 - 1s - loss: 0.6442 - accuracy: 0.6079 - val_loss: 0.6502 - val_accuracy: 0.6321
#
# Epoch 00168: val_loss did not improve from 0.63122
# Epoch 169/10000
# 21/21 - 1s - loss: 0.6445 - accuracy: 0.6099 - val_loss: 0.6602 - val_accuracy: 0.6156
#
# Epoch 00169: val_loss did not improve from 0.63122
# Epoch 170/10000
# 21/21 - 1s - loss: 0.6429 - accuracy: 0.6347 - val_loss: 0.6595 - val_accuracy: 0.6112
#
# Epoch 00170: val_loss did not improve from 0.63122
# Epoch 171/10000
# 21/21 - 1s - loss: 0.6419 - accuracy: 0.6416 - val_loss: 0.6609 - val_accuracy: 0.6145
#
# Epoch 00171: val_loss did not improve from 0.63122
# Epoch 172/10000
# 21/21 - 1s - loss: 0.6424 - accuracy: 0.6441 - val_loss: 0.6675 - val_accuracy: 0.6003
#
# Epoch 00172: val_loss did not improve from 0.63122
# Epoch 173/10000
# 21/21 - 1s - loss: 0.6412 - accuracy: 0.6299 - val_loss: 0.6734 - val_accuracy: 0.5863
#
# Epoch 00173: val_loss did not improve from 0.63122
# Epoch 174/10000
# 21/21 - 1s - loss: 0.6456 - accuracy: 0.5862 - val_loss: 0.6415 - val_accuracy: 0.6374
#
# Epoch 00174: val_loss did not improve from 0.63122
# Epoch 175/10000
# 21/21 - 1s - loss: 0.6422 - accuracy: 0.6290 - val_loss: 0.6470 - val_accuracy: 0.6310
#
# Epoch 00175: val_loss did not improve from 0.63122
# Epoch 176/10000
# 21/21 - 1s - loss: 0.6435 - accuracy: 0.6492 - val_loss: 0.6835 - val_accuracy: 0.5724
#
# Epoch 00176: val_loss did not improve from 0.63122
# Epoch 177/10000
# 21/21 - 1s - loss: 0.6410 - accuracy: 0.6386 - val_loss: 0.6853 - val_accuracy: 0.5741
#
# Epoch 00177: val_loss did not improve from 0.63122
# Epoch 178/10000
# 21/21 - 1s - loss: 0.6464 - accuracy: 0.5866 - val_loss: 0.6341 - val_accuracy: 0.6363
#
# Epoch 00178: val_loss did not improve from 0.63122
# Epoch 179/10000
# 21/21 - 1s - loss: 0.6432 - accuracy: 0.6404 - val_loss: 0.6671 - val_accuracy: 0.5939
#
# Epoch 00179: val_loss did not improve from 0.63122
# Epoch 180/10000
# 21/21 - 1s - loss: 0.6394 - accuracy: 0.6380 - val_loss: 0.6611 - val_accuracy: 0.6045
#
# Epoch 00180: val_loss did not improve from 0.63122
# Epoch 181/10000
# 21/21 - 1s - loss: 0.6403 - accuracy: 0.6497 - val_loss: 0.7095 - val_accuracy: 0.5322
#
# Epoch 00181: val_loss did not improve from 0.63122
# Epoch 182/10000
# 21/21 - 1s - loss: 0.6459 - accuracy: 0.5811 - val_loss: 0.6284 - val_accuracy: 0.6494
#
# Epoch 00182: val_loss improved from 0.63122 to 0.62836, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_280_cnn_updown_rascend_45_kr250_normcheck_ETHUSDT.h5
# Epoch 183/10000
# 21/21 - 1s - loss: 0.6429 - accuracy: 0.6493 - val_loss: 0.6855 - val_accuracy: 0.5676
#
# Epoch 00183: val_loss did not improve from 0.62836
# Epoch 184/10000
# 21/21 - 1s - loss: 0.6396 - accuracy: 0.6246 - val_loss: 0.6719 - val_accuracy: 0.5922
#
# Epoch 00184: val_loss did not improve from 0.62836
# Epoch 185/10000
# 21/21 - 1s - loss: 0.6412 - accuracy: 0.6064 - val_loss: 0.6353 - val_accuracy: 0.6418
#
# Epoch 00185: val_loss did not improve from 0.62836
# Epoch 186/10000
# 21/21 - 1s - loss: 0.6409 - accuracy: 0.6472 - val_loss: 0.6674 - val_accuracy: 0.6006
#
# Epoch 00186: val_loss did not improve from 0.62836
# Epoch 187/10000
# 21/21 - 1s - loss: 0.6393 - accuracy: 0.6532 - val_loss: 0.6754 - val_accuracy: 0.5847
#
# Epoch 00187: val_loss did not improve from 0.62836
# Epoch 188/10000
# 21/21 - 1s - loss: 0.6387 - accuracy: 0.6298 - val_loss: 0.6528 - val_accuracy: 0.6184
#
# Epoch 00188: val_loss did not improve from 0.62836
# Epoch 189/10000
# 21/21 - 1s - loss: 0.6381 - accuracy: 0.6361 - val_loss: 0.6683 - val_accuracy: 0.6039
#
# Epoch 00189: val_loss did not improve from 0.62836
# Epoch 190/10000
# 21/21 - 1s - loss: 0.6392 - accuracy: 0.6343 - val_loss: 0.6687 - val_accuracy: 0.5964
#
# Epoch 00190: val_loss did not improve from 0.62836
# Epoch 191/10000
# 21/21 - 1s - loss: 0.6414 - accuracy: 0.5984 - val_loss: 0.6301 - val_accuracy: 0.6497
#
# Epoch 00191: val_loss did not improve from 0.62836
# Epoch 192/10000
# 21/21 - 1s - loss: 0.6407 - accuracy: 0.6467 - val_loss: 0.6707 - val_accuracy: 0.5902
#
# Epoch 00192: val_loss did not improve from 0.62836
# Epoch 193/10000
# 21/21 - 1s - loss: 0.6372 - accuracy: 0.6527 - val_loss: 0.6600 - val_accuracy: 0.6064
#
# Epoch 00193: val_loss did not improve from 0.62836
# Epoch 194/10000
# 21/21 - 1s - loss: 0.6364 - accuracy: 0.6491 - val_loss: 0.6693 - val_accuracy: 0.5955
#
# Epoch 00194: val_loss did not improve from 0.62836
# Epoch 195/10000
# 21/21 - 1s - loss: 0.6358 - accuracy: 0.6329 - val_loss: 0.6506 - val_accuracy: 0.6187
#
# Epoch 00195: val_loss did not improve from 0.62836
# Epoch 196/10000
# 21/21 - 1s - loss: 0.6365 - accuracy: 0.6419 - val_loss: 0.6993 - val_accuracy: 0.5565
#
# Epoch 00196: val_loss did not improve from 0.62836
# Epoch 197/10000
# 21/21 - 1s - loss: 0.6408 - accuracy: 0.6007 - val_loss: 0.6319 - val_accuracy: 0.6438
#
# Epoch 00197: val_loss did not improve from 0.62836
# Epoch 198/10000
# 21/21 - 1s - loss: 0.6362 - accuracy: 0.6429 - val_loss: 0.6723 - val_accuracy: 0.5877
#
# Epoch 00198: val_loss did not improve from 0.62836
# Epoch 199/10000
# 21/21 - 1s - loss: 0.6354 - accuracy: 0.6270 - val_loss: 0.6411 - val_accuracy: 0.6285
#
# Epoch 00199: val_loss did not improve from 0.62836
# Epoch 200/10000
# 21/21 - 1s - loss: 0.6357 - accuracy: 0.6335 - val_loss: 0.6630 - val_accuracy: 0.6008
#
# Epoch 00200: val_loss did not improve from 0.62836
# Epoch 201/10000
# 21/21 - 1s - loss: 0.6354 - accuracy: 0.6253 - val_loss: 0.6538 - val_accuracy: 0.6128
#
# Epoch 00201: val_loss did not improve from 0.62836
# Epoch 202/10000
# 21/21 - 1s - loss: 0.6352 - accuracy: 0.6382 - val_loss: 0.6634 - val_accuracy: 0.6039
#
# Epoch 00202: val_loss did not improve from 0.62836
# Epoch 203/10000
# 21/21 - 1s - loss: 0.6368 - accuracy: 0.6543 - val_loss: 0.6839 - val_accuracy: 0.5707
#
# Epoch 00203: val_loss did not improve from 0.62836
# Epoch 204/10000
# 21/21 - 1s - loss: 0.6352 - accuracy: 0.6218 - val_loss: 0.6720 - val_accuracy: 0.5911
#
# Epoch 00204: val_loss did not improve from 0.62836
# Epoch 205/10000
# 21/21 - 1s - loss: 0.6408 - accuracy: 0.5940 - val_loss: 0.6267 - val_accuracy: 0.6516
#
# Epoch 00205: val_loss improved from 0.62836 to 0.62667, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_280_cnn_updown_rascend_45_kr250_normcheck_ETHUSDT.h5
# Epoch 206/10000
# 21/21 - 1s - loss: 0.6383 - accuracy: 0.6410 - val_loss: 0.6657 - val_accuracy: 0.5953
#
# Epoch 00206: val_loss did not improve from 0.62667
# Epoch 207/10000
# 21/21 - 1s - loss: 0.6336 - accuracy: 0.6434 - val_loss: 0.6541 - val_accuracy: 0.6106
#
# Epoch 00207: val_loss did not improve from 0.62667
# Epoch 208/10000
# 21/21 - 1s - loss: 0.6342 - accuracy: 0.6493 - val_loss: 0.6675 - val_accuracy: 0.5900
#
# Epoch 00208: val_loss did not improve from 0.62667
# Epoch 209/10000
# 21/21 - 1s - loss: 0.6340 - accuracy: 0.6416 - val_loss: 0.6854 - val_accuracy: 0.5649
#
# Epoch 00209: val_loss did not improve from 0.62667
# Epoch 210/10000
# 21/21 - 1s - loss: 0.6357 - accuracy: 0.6138 - val_loss: 0.6287 - val_accuracy: 0.6455
#
# Epoch 00210: val_loss did not improve from 0.62667
# Epoch 211/10000
# 21/21 - 1s - loss: 0.6347 - accuracy: 0.6563 - val_loss: 0.6743 - val_accuracy: 0.5796
#
# Epoch 00211: val_loss did not improve from 0.62667
# Epoch 212/10000
# 21/21 - 1s - loss: 0.6320 - accuracy: 0.6458 - val_loss: 0.6720 - val_accuracy: 0.5844
#
# Epoch 00212: val_loss did not improve from 0.62667
# Epoch 213/10000
# 21/21 - 1s - loss: 0.6337 - accuracy: 0.6219 - val_loss: 0.6477 - val_accuracy: 0.6139
#
# Epoch 00213: val_loss did not improve from 0.62667
# Epoch 214/10000
# 21/21 - 1s - loss: 0.6338 - accuracy: 0.6171 - val_loss: 0.6435 - val_accuracy: 0.6209
#
# Epoch 00214: val_loss did not improve from 0.62667
# Epoch 215/10000
# 21/21 - 1s - loss: 0.6320 - accuracy: 0.6424 - val_loss: 0.6643 - val_accuracy: 0.5919
#
# Epoch 00215: val_loss did not improve from 0.62667
# Epoch 216/10000
# 21/21 - 1s - loss: 0.6321 - accuracy: 0.6368 - val_loss: 0.6637 - val_accuracy: 0.5944
#
# Epoch 00216: val_loss did not improve from 0.62667
# Epoch 217/10000
# 21/21 - 1s - loss: 0.6329 - accuracy: 0.6253 - val_loss: 0.6476 - val_accuracy: 0.6134
#
# Epoch 00217: val_loss did not improve from 0.62667
# Epoch 218/10000
# 21/21 - 1s - loss: 0.6328 - accuracy: 0.6429 - val_loss: 0.6694 - val_accuracy: 0.5869
#
# Epoch 00218: val_loss did not improve from 0.62667
# Epoch 219/10000
# 21/21 - 1s - loss: 0.6308 - accuracy: 0.6449 - val_loss: 0.6568 - val_accuracy: 0.6056
#
# Epoch 00219: val_loss did not improve from 0.62667
# Epoch 220/10000
# 21/21 - 1s - loss: 0.6314 - accuracy: 0.6451 - val_loss: 0.6652 - val_accuracy: 0.5939
#
# Epoch 00220: val_loss did not improve from 0.62667
# Epoch 221/10000
# 21/21 - 1s - loss: 0.6305 - accuracy: 0.6415 - val_loss: 0.6620 - val_accuracy: 0.5992
#
# Epoch 00221: val_loss did not improve from 0.62667
# Epoch 222/10000
# 21/21 - 1s - loss: 0.6298 - accuracy: 0.6394 - val_loss: 0.6614 - val_accuracy: 0.6011
#
# Epoch 00222: val_loss did not improve from 0.62667
# Epoch 223/10000
# 21/21 - 1s - loss: 0.6298 - accuracy: 0.6398 - val_loss: 0.6716 - val_accuracy: 0.5844
#
# Epoch 00223: val_loss did not improve from 0.62667
# Epoch 224/10000
# 21/21 - 1s - loss: 0.6302 - accuracy: 0.6325 - val_loss: 0.6373 - val_accuracy: 0.6301
#
# Epoch 00224: val_loss did not improve from 0.62667
# Epoch 225/10000
# 21/21 - 1s - loss: 0.6319 - accuracy: 0.6519 - val_loss: 0.6803 - val_accuracy: 0.5674
#
# Epoch 00225: val_loss did not improve from 0.62667
# Epoch 226/10000
# 21/21 - 1s - loss: 0.6294 - accuracy: 0.6363 - val_loss: 0.6526 - val_accuracy: 0.6109
#
# Epoch 00226: val_loss did not improve from 0.62667
# Epoch 227/10000
# 21/21 - 1s - loss: 0.6290 - accuracy: 0.6408 - val_loss: 0.6720 - val_accuracy: 0.5927
#
# Epoch 00227: val_loss did not improve from 0.62667
# Epoch 228/10000
# 21/21 - 1s - loss: 0.6303 - accuracy: 0.6245 - val_loss: 0.6418 - val_accuracy: 0.6257
#
# Epoch 00228: val_loss did not improve from 0.62667
# Epoch 229/10000
# 21/21 - 1s - loss: 0.6290 - accuracy: 0.6326 - val_loss: 0.6559 - val_accuracy: 0.6042
#
# Epoch 00229: val_loss did not improve from 0.62667
# Epoch 230/10000
# 21/21 - 1s - loss: 0.6302 - accuracy: 0.6289 - val_loss: 0.6598 - val_accuracy: 0.5986
#
# Epoch 00230: val_loss did not improve from 0.62667
# Epoch 231/10000
# 21/21 - 1s - loss: 0.6288 - accuracy: 0.6276 - val_loss: 0.6772 - val_accuracy: 0.5816
#
# Epoch 00231: val_loss did not improve from 0.62667
# Epoch 232/10000
# 21/21 - 1s - loss: 0.6314 - accuracy: 0.6198 - val_loss: 0.6536 - val_accuracy: 0.6053
#
# Epoch 00232: val_loss did not improve from 0.62667
# Epoch 233/10000
# 21/21 - 1s - loss: 0.6275 - accuracy: 0.6307 - val_loss: 0.6546 - val_accuracy: 0.6064
#
# Epoch 00233: val_loss did not improve from 0.62667
# Epoch 234/10000
# 21/21 - 1s - loss: 0.6271 - accuracy: 0.6429 - val_loss: 0.6856 - val_accuracy: 0.5637
#
# Epoch 00234: val_loss did not improve from 0.62667
# Epoch 235/10000
# 21/21 - 1s - loss: 0.6333 - accuracy: 0.6128 - val_loss: 0.6561 - val_accuracy: 0.6011
#
# Epoch 00235: val_loss did not improve from 0.62667
# Epoch 236/10000
# 21/21 - 1s - loss: 0.6272 - accuracy: 0.6299 - val_loss: 0.6438 - val_accuracy: 0.6232
#
# Epoch 00236: val_loss did not improve from 0.62667
# Epoch 237/10000
# 21/21 - 1s - loss: 0.6270 - accuracy: 0.6389 - val_loss: 0.6504 - val_accuracy: 0.6123
#
# Epoch 00237: val_loss did not improve from 0.62667
# Epoch 238/10000
# 21/21 - 1s - loss: 0.6261 - accuracy: 0.6303 - val_loss: 0.6336 - val_accuracy: 0.6290
#
# Epoch 00238: val_loss did not improve from 0.62667
# Epoch 239/10000
# 21/21 - 1s - loss: 0.6302 - accuracy: 0.6488 - val_loss: 0.6596 - val_accuracy: 0.5992
#
# Epoch 00239: val_loss did not improve from 0.62667
# Epoch 240/10000
# 21/21 - 1s - loss: 0.6294 - accuracy: 0.6545 - val_loss: 0.6792 - val_accuracy: 0.5710
#
# Epoch 00240: val_loss did not improve from 0.62667
# Epoch 241/10000
# 21/21 - 1s - loss: 0.6261 - accuracy: 0.6405 - val_loss: 0.6826 - val_accuracy: 0.5732
#
# Epoch 00241: val_loss did not improve from 0.62667
# Epoch 242/10000
# 21/21 - 1s - loss: 0.6252 - accuracy: 0.6272 - val_loss: 0.6665 - val_accuracy: 0.5902
#
# Epoch 00242: val_loss did not improve from 0.62667
# Epoch 243/10000
# 21/21 - 1s - loss: 0.6399 - accuracy: 0.5732 - val_loss: 0.6256 - val_accuracy: 0.6466
#
# Epoch 00243: val_loss improved from 0.62667 to 0.62557, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_280_cnn_updown_rascend_45_kr250_normcheck_ETHUSDT.h5
# Epoch 244/10000
# 21/21 - 1s - loss: 0.6280 - accuracy: 0.6446 - val_loss: 0.6696 - val_accuracy: 0.5897
#
# Epoch 00244: val_loss did not improve from 0.62557
# Epoch 245/10000
# 21/21 - 1s - loss: 0.6263 - accuracy: 0.6452 - val_loss: 0.6731 - val_accuracy: 0.5799
#
# Epoch 00245: val_loss did not improve from 0.62557
# Epoch 246/10000
# 21/21 - 1s - loss: 0.6264 - accuracy: 0.6383 - val_loss: 0.6573 - val_accuracy: 0.6022
#
# Epoch 00246: val_loss did not improve from 0.62557
# Epoch 247/10000
# 21/21 - 1s - loss: 0.6253 - accuracy: 0.6266 - val_loss: 0.6369 - val_accuracy: 0.6349
#
# Epoch 00247: val_loss did not improve from 0.62557
# Epoch 248/10000
# 21/21 - 1s - loss: 0.6252 - accuracy: 0.6431 - val_loss: 0.6399 - val_accuracy: 0.6298
#
# Epoch 00248: val_loss did not improve from 0.62557
# Epoch 249/10000
# 21/21 - 1s - loss: 0.6288 - accuracy: 0.6553 - val_loss: 0.6717 - val_accuracy: 0.5855
#
# Epoch 00249: val_loss did not improve from 0.62557
# Epoch 250/10000
# 21/21 - 1s - loss: 0.6246 - accuracy: 0.6539 - val_loss: 0.6796 - val_accuracy: 0.5746
#
# Epoch 00250: val_loss did not improve from 0.62557
# Epoch 251/10000
# 21/21 - 1s - loss: 0.6254 - accuracy: 0.6297 - val_loss: 0.6436 - val_accuracy: 0.6251
#
# Epoch 00251: val_loss did not improve from 0.62557
# Epoch 252/10000
# 21/21 - 1s - loss: 0.6234 - accuracy: 0.6402 - val_loss: 0.6539 - val_accuracy: 0.6106
#
# Epoch 00252: val_loss did not improve from 0.62557
# Epoch 253/10000
# 21/21 - 1s - loss: 0.6241 - accuracy: 0.6336 - val_loss: 0.6701 - val_accuracy: 0.5813
#
# Epoch 00253: val_loss did not improve from 0.62557
# Epoch 254/10000
# 21/21 - 1s - loss: 0.6277 - accuracy: 0.6126 - val_loss: 0.6214 - val_accuracy: 0.6547
#
# Epoch 00254: val_loss improved from 0.62557 to 0.62135, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_280_cnn_updown_rascend_45_kr250_normcheck_ETHUSDT.h5
# Epoch 255/10000
# 21/21 - 1s - loss: 0.6249 - accuracy: 0.6522 - val_loss: 0.6449 - val_accuracy: 0.6209
#
# Epoch 00255: val_loss did not improve from 0.62135
# Epoch 256/10000
# 21/21 - 1s - loss: 0.6256 - accuracy: 0.6658 - val_loss: 0.6683 - val_accuracy: 0.5863
#
# Epoch 00256: val_loss did not improve from 0.62135
# Epoch 257/10000
# 21/21 - 1s - loss: 0.6228 - accuracy: 0.6652 - val_loss: 0.6737 - val_accuracy: 0.5732
#
# Epoch 00257: val_loss did not improve from 0.62135
# Epoch 258/10000
# 21/21 - 1s - loss: 0.6217 - accuracy: 0.6417 - val_loss: 0.6527 - val_accuracy: 0.6022
#
# Epoch 00258: val_loss did not improve from 0.62135
# Epoch 259/10000
# 21/21 - 1s - loss: 0.6223 - accuracy: 0.6305 - val_loss: 0.6519 - val_accuracy: 0.6059
#
# Epoch 00259: val_loss did not improve from 0.62135
# Epoch 260/10000
# 21/21 - 1s - loss: 0.6230 - accuracy: 0.6341 - val_loss: 0.6508 - val_accuracy: 0.6075
#
# Epoch 00260: val_loss did not improve from 0.62135
# Epoch 261/10000
# 21/21 - 1s - loss: 0.6235 - accuracy: 0.6377 - val_loss: 0.6316 - val_accuracy: 0.6343
#
# Epoch 00261: val_loss did not improve from 0.62135
# Epoch 262/10000
# 21/21 - 1s - loss: 0.6231 - accuracy: 0.6532 - val_loss: 0.6614 - val_accuracy: 0.5916
#
# Epoch 00262: val_loss did not improve from 0.62135
# Epoch 263/10000
# 21/21 - 1s - loss: 0.6204 - accuracy: 0.6503 - val_loss: 0.6506 - val_accuracy: 0.6089
#
# Epoch 00263: val_loss did not improve from 0.62135
# Epoch 264/10000
# 21/21 - 1s - loss: 0.6208 - accuracy: 0.6503 - val_loss: 0.6745 - val_accuracy: 0.5749
#
# Epoch 00264: val_loss did not improve from 0.62135
# Epoch 265/10000
# 21/21 - 1s - loss: 0.6204 - accuracy: 0.6330 - val_loss: 0.6397 - val_accuracy: 0.6234
#
# Epoch 00265: val_loss did not improve from 0.62135
# Epoch 266/10000
# 21/21 - 1s - loss: 0.6195 - accuracy: 0.6482 - val_loss: 0.6497 - val_accuracy: 0.6106
#
# Epoch 00266: val_loss did not improve from 0.62135
# Epoch 267/10000
# 21/21 - 1s - loss: 0.6193 - accuracy: 0.6474 - val_loss: 0.6416 - val_accuracy: 0.6165
#
# Epoch 00267: val_loss did not improve from 0.62135
# Epoch 268/10000
# 21/21 - 1s - loss: 0.6200 - accuracy: 0.6564 - val_loss: 0.6550 - val_accuracy: 0.6020
#
# Epoch 00268: val_loss did not improve from 0.62135
# Epoch 269/10000
# 21/21 - 1s - loss: 0.6195 - accuracy: 0.6592 - val_loss: 0.6737 - val_accuracy: 0.5802
#
# Epoch 00269: val_loss did not improve from 0.62135
# Epoch 270/10000
# 21/21 - 1s - loss: 0.6183 - accuracy: 0.6456 - val_loss: 0.6565 - val_accuracy: 0.6075
#
# Epoch 00270: val_loss did not improve from 0.62135
# Epoch 271/10000
# 21/21 - 1s - loss: 0.6180 - accuracy: 0.6576 - val_loss: 0.6688 - val_accuracy: 0.5852
#
# Epoch 00271: val_loss did not improve from 0.62135
# Epoch 272/10000
# 21/21 - 1s - loss: 0.6173 - accuracy: 0.6592 - val_loss: 0.6396 - val_accuracy: 0.6226
#
# Epoch 00272: val_loss did not improve from 0.62135
# Epoch 273/10000
# 21/21 - 1s - loss: 0.6211 - accuracy: 0.6546 - val_loss: 0.6690 - val_accuracy: 0.5813
#
# Epoch 00273: val_loss did not improve from 0.62135
# Epoch 274/10000
# 21/21 - 1s - loss: 0.6175 - accuracy: 0.6444 - val_loss: 0.6478 - val_accuracy: 0.6201
#
# Epoch 00274: val_loss did not improve from 0.62135
# Epoch 275/10000
# 21/21 - 1s - loss: 0.6169 - accuracy: 0.6376 - val_loss: 0.6247 - val_accuracy: 0.6441
#
# Epoch 00275: val_loss did not improve from 0.62135
# Epoch 276/10000
# 21/21 - 1s - loss: 0.6235 - accuracy: 0.6586 - val_loss: 0.6818 - val_accuracy: 0.5646
#
# Epoch 00276: val_loss did not improve from 0.62135
# Epoch 277/10000
# 21/21 - 1s - loss: 0.6160 - accuracy: 0.6559 - val_loss: 0.6832 - val_accuracy: 0.5657
#
# Epoch 00277: val_loss did not improve from 0.62135
# Epoch 278/10000
# 21/21 - 1s - loss: 0.6199 - accuracy: 0.6195 - val_loss: 0.6231 - val_accuracy: 0.6427
#
# Epoch 00278: val_loss did not improve from 0.62135
# Epoch 279/10000
# 21/21 - 1s - loss: 0.6194 - accuracy: 0.6572 - val_loss: 0.6472 - val_accuracy: 0.6112
#
# Epoch 00279: val_loss did not improve from 0.62135
# Epoch 280/10000
# 21/21 - 1s - loss: 0.6178 - accuracy: 0.6695 - val_loss: 0.6594 - val_accuracy: 0.5922
#
# Epoch 00280: val_loss did not improve from 0.62135
# Epoch 281/10000
# ...
#
# Epoch 01018: val_loss did not improve from 0.60677
# Epoch 1019/10000
# 21/21 - 1s - loss: 0.3493 - accuracy: 0.8292 - val_loss: 0.8070 - val_accuracy: 0.6404
#
# Epoch 01019: val_loss did not improve from 0.60677
# Epoch 1020/10000
# 21/21 - 1s - loss: 0.3325 - accuracy: 0.8531 - val_loss: 0.8082 - val_accuracy: 0.6382
#
# Epoch 01020: val_loss did not improve from 0.60677
# Epoch 1021/10000
# 21/21 - 1s - loss: 0.2947 - accuracy: 0.8805 - val_loss: 0.9266 - val_accuracy: 0.5802
#
# Epoch 01021: val_loss did not improve from 0.60677
# Epoch 1022/10000
# 21/21 - 1s - loss: 0.3717 - accuracy: 0.8106 - val_loss: 0.7861 - val_accuracy: 0.6720
#
# Epoch 01022: val_loss did not improve from 0.60677
# Epoch 1023/10000
# 21/21 - 1s - loss: 0.3596 - accuracy: 0.8462 - val_loss: 0.7596 - val_accuracy: 0.6697
#
# Epoch 01023: val_loss did not improve from 0.60677
# Epoch 1024/10000
# 21/21 - 1s - loss: 0.2967 - accuracy: 0.8824 - val_loss: 0.7944 - val_accuracy: 0.6385
#
# Epoch 01024: val_loss did not improve from 0.60677
# Epoch 1025/10000
# 21/21 - 1s - loss: 0.2840 - accuracy: 0.8897 - val_loss: 0.7713 - val_accuracy: 0.6580
#
# Epoch 01025: val_loss did not improve from 0.60677
# Epoch 1026/10000
# 21/21 - 1s - loss: 0.2802 - accuracy: 0.8944 - val_loss: 0.7704 - val_accuracy: 0.6594
#
# Epoch 01026: val_loss did not improve from 0.60677
# Epoch 1027/10000
# 21/21 - 1s - loss: 0.2824 - accuracy: 0.8950 - val_loss: 0.8253 - val_accuracy: 0.6262
#
# Epoch 01027: val_loss did not improve from 0.60677
# Epoch 1028/10000
# 21/21 - 1s - loss: 0.2886 - accuracy: 0.8832 - val_loss: 0.7710 - val_accuracy: 0.6658
#
# Epoch 01028: val_loss did not improve from 0.60677
# Epoch 1029/10000
# 21/21 - 1s - loss: 0.2824 - accuracy: 0.8962 - val_loss: 0.8506 - val_accuracy: 0.6148
#
# Epoch 01029: val_loss did not improve from 0.60677
# Epoch 1030/10000
# 21/21 - 1s - loss: 0.3067 - accuracy: 0.8618 - val_loss: 0.8035 - val_accuracy: 0.6444
#
# Epoch 01030: val_loss did not improve from 0.60677
# Epoch 1031/10000
# 21/21 - 1s - loss: 0.2917 - accuracy: 0.8877 - val_loss: 0.8261 - val_accuracy: 0.6254
#
# Epoch 01031: val_loss did not improve from 0.60677
# Epoch 1032/10000
# 21/21 - 1s - loss: 0.2844 - accuracy: 0.8864 - val_loss: 0.7985 - val_accuracy: 0.6402
#
# Epoch 01032: val_loss did not improve from 0.60677
# Epoch 1033/10000
# 21/21 - 1s - loss: 0.2912 - accuracy: 0.8820 - val_loss: 0.7935 - val_accuracy: 0.6427
#
# Epoch 01033: val_loss did not improve from 0.60677
# Epoch 1034/10000
# 21/21 - 1s - loss: 0.2851 - accuracy: 0.8931 - val_loss: 0.8131 - val_accuracy: 0.6326
#
# Epoch 01034: val_loss did not improve from 0.60677
# Epoch 1035/10000
# 21/21 - 1s - loss: 0.2757 - accuracy: 0.8934 - val_loss: 0.7871 - val_accuracy: 0.6555
#
# Epoch 01035: val_loss did not improve from 0.60677
# Epoch 1036/10000
# 21/21 - 1s - loss: 0.2725 - accuracy: 0.9000 - val_loss: 0.7813 - val_accuracy: 0.6552
#
# Epoch 01036: val_loss did not improve from 0.60677
# Epoch 1037/10000
# 21/21 - 1s - loss: 0.2710 - accuracy: 0.9045 - val_loss: 0.7883 - val_accuracy: 0.6522
#
# Epoch 01037: val_loss did not improve from 0.60677
# Epoch 1038/10000
# 21/21 - 1s - loss: 0.2681 - accuracy: 0.9013 - val_loss: 0.7793 - val_accuracy: 0.6544
#
# Epoch 01038: val_loss did not improve from 0.60677
# Epoch 1039/10000
# 21/21 - 1s - loss: 0.2678 - accuracy: 0.9068 - val_loss: 0.8125 - val_accuracy: 0.6377
#
# Epoch 01039: val_loss did not improve from 0.60677
# Epoch 1040/10000
# 21/21 - 1s - loss: 0.2690 - accuracy: 0.8977 - val_loss: 0.8169 - val_accuracy: 0.6377
#
# Epoch 01040: val_loss did not improve from 0.60677
# Epoch 1041/10000
# 21/21 - 1s - loss: 0.2851 - accuracy: 0.8781 - val_loss: 0.7772 - val_accuracy: 0.6842
#
# Epoch 01041: val_loss did not improve from 0.60677
# Epoch 1042/10000
# 21/21 - 1s - loss: 0.2842 - accuracy: 0.8897 - val_loss: 0.7909 - val_accuracy: 0.6547
#
# Epoch 01042: val_loss did not improve from 0.60677
# Epoch 1043/10000
# 21/21 - 1s - loss: 0.2811 - accuracy: 0.8907 - val_loss: 0.8018 - val_accuracy: 0.6485
#
# Epoch 01043: val_loss did not improve from 0.60677
# Epoch 1044/10000
# 21/21 - 1s - loss: 0.2685 - accuracy: 0.8990 - val_loss: 0.8146 - val_accuracy: 0.6377
#
# Epoch 01044: val_loss did not improve from 0.60677
# Epoch 1045/10000
# 21/21 - 1s - loss: 0.2730 - accuracy: 0.8925 - val_loss: 0.7789 - val_accuracy: 0.6709
#
# Epoch 01045: val_loss did not improve from 0.60677
# Epoch 1046/10000
# 21/21 - 1s - loss: 0.2695 - accuracy: 0.9026 - val_loss: 0.7924 - val_accuracy: 0.6544
#
# Epoch 01046: val_loss did not improve from 0.60677
# Epoch 1047/10000
# 21/21 - 1s - loss: 0.2630 - accuracy: 0.9094 - val_loss: 0.8259 - val_accuracy: 0.6321
#
# Epoch 01047: val_loss did not improve from 0.60677
# Epoch 1048/10000
# 21/21 - 1s - loss: 0.2624 - accuracy: 0.9054 - val_loss: 0.7778 - val_accuracy: 0.6681
#
# Epoch 01048: val_loss did not improve from 0.60677
# Epoch 1049/10000
# 21/21 - 1s - loss: 0.2829 - accuracy: 0.8899 - val_loss: 0.8489 - val_accuracy: 0.6251
#
# Epoch 01049: val_loss did not improve from 0.60677
# Epoch 1050/10000
# 21/21 - 1s - loss: 0.2678 - accuracy: 0.9015 - val_loss: 0.8679 - val_accuracy: 0.6156
#
# Epoch 01050: val_loss did not improve from 0.60677
# Epoch 1051/10000
# 21/21 - 1s - loss: 0.2966 - accuracy: 0.8670 - val_loss: 0.7955 - val_accuracy: 0.6764
#
# Epoch 01051: val_loss did not improve from 0.60677
# Epoch 1052/10000
# 21/21 - 1s - loss: 0.2833 - accuracy: 0.8934 - val_loss: 0.8136 - val_accuracy: 0.6430
#
# Epoch 01052: val_loss did not improve from 0.60677
# Epoch 1053/10000
# 21/21 - 1s - loss: 0.2654 - accuracy: 0.9040 - val_loss: 0.8272 - val_accuracy: 0.6351
#
# Epoch 01053: val_loss did not improve from 0.60677
# Epoch 1054/10000
# 21/21 - 1s - loss: 0.2813 - accuracy: 0.8841 - val_loss: 0.7963 - val_accuracy: 0.6522
#
# Epoch 01054: val_loss did not improve from 0.60677
# Epoch 1055/10000
# 21/21 - 1s - loss: 0.2650 - accuracy: 0.9031 - val_loss: 0.8453 - val_accuracy: 0.6229
#
# Epoch 01055: val_loss did not improve from 0.60677
# Epoch 1056/10000
# 21/21 - 1s - loss: 0.2797 - accuracy: 0.8849 - val_loss: 0.8158 - val_accuracy: 0.6418
#
# Epoch 01056: val_loss did not improve from 0.60677
# Epoch 1057/10000
# 21/21 - 1s - loss: 0.2750 - accuracy: 0.8920 - val_loss: 0.7902 - val_accuracy: 0.6672
#
# Epoch 01057: val_loss did not improve from 0.60677
# Epoch 1058/10000
# 21/21 - 1s - loss: 0.2620 - accuracy: 0.9075 - val_loss: 0.7976 - val_accuracy: 0.6538
#
# Epoch 01058: val_loss did not improve from 0.60677
# Epoch 1059/10000
# 21/21 - 1s - loss: 0.2569 - accuracy: 0.9088 - val_loss: 0.8268 - val_accuracy: 0.6391
#
# Epoch 01059: val_loss did not improve from 0.60677
# Epoch 1060/10000
# 21/21 - 1s - loss: 0.2596 - accuracy: 0.9032 - val_loss: 0.8445 - val_accuracy: 0.6251
#
# Epoch 01060: val_loss did not improve from 0.60677
# Epoch 1061/10000
# 21/21 - 1s - loss: 0.2801 - accuracy: 0.8810 - val_loss: 0.7876 - val_accuracy: 0.6745
#
# Epoch 01061: val_loss did not improve from 0.60677
# Epoch 1062/10000
# 21/21 - 1s - loss: 0.2659 - accuracy: 0.9001 - val_loss: 0.8200 - val_accuracy: 0.6446
#
# Epoch 01062: val_loss did not improve from 0.60677
# Epoch 1063/10000
# 21/21 - 1s - loss: 0.2631 - accuracy: 0.8987 - val_loss: 0.7953 - val_accuracy: 0.6594
#
# Epoch 01063: val_loss did not improve from 0.60677
# Epoch 1064/10000
# 21/21 - 1s - loss: 0.2579 - accuracy: 0.9074 - val_loss: 0.9033 - val_accuracy: 0.6061
#
# Epoch 01064: val_loss did not improve from 0.60677
# Epoch 1065/10000
# 21/21 - 1s - loss: 0.3010 - accuracy: 0.8643 - val_loss: 0.8210 - val_accuracy: 0.6499
#
# Epoch 01065: val_loss did not improve from 0.60677
# Epoch 1066/10000
# 21/21 - 1s - loss: 0.2687 - accuracy: 0.8882 - val_loss: 0.8517 - val_accuracy: 0.6301
#
# Epoch 01066: val_loss did not improve from 0.60677
# Epoch 1067/10000
# 21/21 - 1s - loss: 0.2786 - accuracy: 0.8831 - val_loss: 0.8099 - val_accuracy: 0.6541
#
# Epoch 01067: val_loss did not improve from 0.60677
# Epoch 1068/10000
# 21/21 - 1s - loss: 0.2588 - accuracy: 0.9056 - val_loss: 0.8799 - val_accuracy: 0.6148
#
# Epoch 01068: val_loss did not improve from 0.60677
# Epoch 1069/10000
# 21/21 - 1s - loss: 0.2844 - accuracy: 0.8717 - val_loss: 0.8094 - val_accuracy: 0.6706
#
# Epoch 01069: val_loss did not improve from 0.60677
# Epoch 1070/10000
# 21/21 - 1s - loss: 0.2655 - accuracy: 0.8989 - val_loss: 0.8380 - val_accuracy: 0.6413
#
# Epoch 01070: val_loss did not improve from 0.60677
# Epoch 1071/10000
# 21/21 - 1s - loss: 0.2531 - accuracy: 0.9084 - val_loss: 0.8125 - val_accuracy: 0.6577
#
# Epoch 01071: val_loss did not improve from 0.60677
# Epoch 1072/10000
# 21/21 - 1s - loss: 0.2489 - accuracy: 0.9151 - val_loss: 0.8125 - val_accuracy: 0.6558
#
# Epoch 01072: val_loss did not improve from 0.60677
# Epoch 1073/10000
# 21/21 - 1s - loss: 0.2477 - accuracy: 0.9146 - val_loss: 0.7970 - val_accuracy: 0.6695
#
# Epoch 01073: val_loss did not improve from 0.60677
# Epoch 1074/10000
# 21/21 - 1s - loss: 0.2635 - accuracy: 0.9056 - val_loss: 0.8052 - val_accuracy: 0.6603
#
# Epoch 01074: val_loss did not improve from 0.60677
# Epoch 1075/10000
# 21/21 - 1s - loss: 0.2614 - accuracy: 0.9067 - val_loss: 0.8376 - val_accuracy: 0.6396
#
# Epoch 01075: val_loss did not improve from 0.60677
# Epoch 1076/10000
# 21/21 - 1s - loss: 0.2534 - accuracy: 0.9062 - val_loss: 0.8021 - val_accuracy: 0.6689
#
# Epoch 01076: val_loss did not improve from 0.60677
# Epoch 1077/10000
# 21/21 - 1s - loss: 0.2561 - accuracy: 0.9079 - val_loss: 0.7979 - val_accuracy: 0.6714
#
# Epoch 01077: val_loss did not improve from 0.60677
# Epoch 1078/10000
# 21/21 - 1s - loss: 0.2767 - accuracy: 0.8958 - val_loss: 0.8642 - val_accuracy: 0.6209
#
# Epoch 01078: val_loss did not improve from 0.60677
# Epoch 1079/10000
# 21/21 - 1s - loss: 0.2561 - accuracy: 0.9028 - val_loss: 0.8127 - val_accuracy: 0.6586
#
# Epoch 01079: val_loss did not improve from 0.60677
# Epoch 1080/10000
# 21/21 - 1s - loss: 0.2636 - accuracy: 0.8928 - val_loss: 0.8173 - val_accuracy: 0.6597
#
# Epoch 01080: val_loss did not improve from 0.60677
# Epoch 1081/10000
# 21/21 - 1s - loss: 0.2488 - accuracy: 0.9116 - val_loss: 0.8102 - val_accuracy: 0.6575
#
# Epoch 01081: val_loss did not improve from 0.60677
# Epoch 1082/10000
# 21/21 - 1s - loss: 0.2451 - accuracy: 0.9150 - val_loss: 0.8498 - val_accuracy: 0.6349
#
# Epoch 01082: val_loss did not improve from 0.60677
# Epoch 1083/10000
# 21/21 - 1s - loss: 0.2522 - accuracy: 0.9026 - val_loss: 0.8134 - val_accuracy: 0.6600
#
# Epoch 01083: val_loss did not improve from 0.60677
# Epoch 1084/10000
# 21/21 - 1s - loss: 0.2433 - accuracy: 0.9139 - val_loss: 0.8164 - val_accuracy: 0.6591
#
# Epoch 01084: val_loss did not improve from 0.60677
# Epoch 1085/10000
# 21/21 - 1s - loss: 0.2417 - accuracy: 0.9176 - val_loss: 0.8193 - val_accuracy: 0.6569
#
# Epoch 01085: val_loss did not improve from 0.60677
# Epoch 1086/10000
# 21/21 - 1s - loss: 0.2471 - accuracy: 0.9114 - val_loss: 0.8329 - val_accuracy: 0.6499
#
# Epoch 01086: val_loss did not improve from 0.60677
# Epoch 1087/10000
# 21/21 - 1s - loss: 0.2444 - accuracy: 0.9128 - val_loss: 0.8252 - val_accuracy: 0.6547
#
# Epoch 01087: val_loss did not improve from 0.60677
# Epoch 1088/10000
# 21/21 - 1s - loss: 0.2469 - accuracy: 0.9118 - val_loss: 0.8451 - val_accuracy: 0.6424
#
# Epoch 01088: val_loss did not improve from 0.60677
# Epoch 1089/10000
# 21/21 - 1s - loss: 0.2381 - accuracy: 0.9177 - val_loss: 0.8139 - val_accuracy: 0.6605
#
# Epoch 01089: val_loss did not improve from 0.60677
# Epoch 1090/10000
# 21/21 - 1s - loss: 0.2415 - accuracy: 0.9162 - val_loss: 0.8634 - val_accuracy: 0.6290
#
# Epoch 01090: val_loss did not improve from 0.60677
# Epoch 1091/10000
# 21/21 - 1s - loss: 0.2482 - accuracy: 0.9051 - val_loss: 0.8218 - val_accuracy: 0.6547
#
# Epoch 01091: val_loss did not improve from 0.60677
# Epoch 1092/10000
# 21/21 - 1s - loss: 0.2378 - accuracy: 0.9170 - val_loss: 0.8377 - val_accuracy: 0.6485
#
# Epoch 01092: val_loss did not improve from 0.60677
# test_result.shape : (3586, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.23929355]
#  [0.32822385]
#  [0.4345014 ]
#  [0.45943987]
#  [0.18791744]]
# y_test.shape : (3586, 1)
# y_score.shape : (3586, 1)
# len(y_test) : 3586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:700: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [0.000100783946, 0.00010206862, 0.000102376245, 0.00010297533, 0.000103696955, 0.00010542486, 0.000105911335, 0.00010799514, 0.00010967313, 0.00011146102, 0.00011270232, 0.000116999894, 0.0001202365, 0.00012423769, 0.00012393389, 0.00012711118, 0.00012802256, 0.00012971289, 0.00013159077, 0.00013236972, 0.00013533485, 0.00013454334, 0.00013670578, 0.00013768864, 0.00013970665, 0.00014039653, 0.00014288635, 0.0001445417, 0.00014700792, 0.0001465877, 0.00015119246, 0.0001503336, 0.00015253287, 0.00015403717, 0.00015300035, 0.00015088652, 0.0001568188, 0.00016036404, 0.00016161748, 0.00015858261, 0.00016220952, 0.00016230157, 0.00016573789, 0.00016538432, 0.0001675861, 0.0001696313, 0.0001676386, 0.00017000585, 0.00017167453, 0.00017334805, 0.0001733274, 0.0001739746, 0.00017246742, 0.00017054523, 0.00017133585, 0.00017419501, 0.00017409619, 0.00017393558, 0.00017586003, 0.0001830743, 0.00019104873, 0.00019499741, 0.00020030116, 0.00020989132, 0.00020867713, 0.00021157756, 0.00021430476, 0.00021788667, 0.00021683898, 0.00022258566, 0.00022413325, 0.00022721036, 0.00022601933, 0.00022575908, 0.00023202655, 0.0002300081, 0.00023149152, 0.00023666842, 0.00023485346, 0.0002369655, 0.00023960578, 0.00023912387, 0.00024000136, 0.00024260835, 0.0002428194, 0.00024445602, 0.00024595053, 0.00024565664, 0.00024583883, 0.0002497251, 0.00025286857, 0.0002511561, 0.00025317338, 0.00025754495, 0.00025926813, 0.0002634807, 0.00026469651, 0.00026758446, 0.00027629008, 0.00027651197, 0.0002754175, 0.00027936435, 0.00027932262, 0.00028201618, 0.00028487178, 0.00028586332, 0.00028849184, 0.00028837498, 0.00028881643, 0.00028635838, 0.00030081414, 0.00030790915, 0.00031466162, 0.00031640026, 0.00032119695, 0.00032066164, 0.00031563776, 0.00030114042, 0.00031220476, 0.000319548, 0.00032235496, 0.00033179854, 0.0003300059, 0.00032756984, 0.0003340973, 0.00034013475, 0.0003426433, 0.0003371161, 0.00033703726, 0.0003320329, 0.00033345964, 0.00033845604, 0.0003436464, 0.00035086632, 0.0003414194, 0.00034114986, 0.00034115705, 0.00034009854, 0.00034136264, 0.00034688154, 0.00034901395, 0.00035291107, 0.00036140304, 0.00037768472, 0.0003787234, 0.00037557984, 0.0003790448, 0.0003838857, 0.0003821663, 0.0003712414, 0.00037646072, 0.00037707633, 0.00037673663, 0.00038292698, 0.00037991093, 0.0003791758, 0.00038176114, 0.0003877349, 0.00039001467, 0.00039734234, 0.0004054396, 0.00040922, 0.00040454193, 0.0004040453, 0.00040050218, 0.0004097177, 0.0004265834, 0.0004343498, 0.0004425884, 0.0004419545, 0.00044499227, 0.0004525758, 0.00045233857, 0.00046099746, 0.00046383473, 0.00045836772, 0.00045994506, 0.00046749532, 0.0004775553, 0.00047642624, 0.00047652095, 0.00048360927, 0.0005131114, 0.0005177285, 0.0005231793, 0.00052185386, 0.0005325173, 0.0005349498, 0.0005764418, 0.00057469576, 0.00056606345, 0.00055824965, 0.00056698656, 0.0005714412, 0.00057599886, 0.000581249, 0.0005793314, 0.00059596024, 0.0005996283, 0.00060714985, 0.00063107477, 0.00065885956, 0.0006671822, 0.00066904793, 0.00066430354, 0.00066667015, 0.0006727969, 0.00067162997, 0.0006885813, 0.0006962578, 0.00069141755, 0.0006929042, 0.0006889571, 0.00068351935, 0.0007021279, 0.00071282743, 0.0007165148, 0.00071144104, 0.00071357965, 0.00070983224, 0.00071114727, 0.00071673817, 0.00071340636, 0.00072359806, 0.00074069947, 0.0007628826, 0.00076534576, 0.0007552893, 0.0007563895, 0.00075364567, 0.00075891207, 0.00077997404, 0.0007925771, 0.0007990931, 0.00079995516, 0.0008049513, 0.0008084059, 0.0008087777, 0.00081558264, 0.0008120885, 0.00081542507, 0.0008159898, 0.00078690343, 0.00079948537, 0.000786266, 0.0007968467, 0.0008110353, 0.0008241359, 0.0008420503, 0.000860302, 0.0008506826, 0.00084455684, 0.00086390594, 0.00086383877, 0.0008847068, 0.0009014003, 0.0009006878, 0.00091486913, 0.00092441984, 0.0009233163, 0.00095346494, 0.0009503002, 0.0010259642, 0.0010248208, 0.0010535532, 0.0010300458, 0.001003561, 0.001018692, 0.001018753, 0.0010177282, 0.0010263353, 0.0010461465, 0 ...

# %% [markdown]
# ### save npy

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from funcs_indicator import *

def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


#       set data features : ohlc, v, ep
time_index = ohlcv.index[np.sum(np.isnan(pr)):]

sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

#       scale with price    #
ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
sar = lucid_sar(sliced_ohlcv)
ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
senkou1, senkou2 = ichimoku(sliced_ohlcv)

#     min max scale   #
vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

pr_list = pr[np.sum(np.isnan(pr)):]
print("len(ohlc) :", len(ohlc))
print("len(pr) :", len(pr))

# break


#       set params    #
period = 45
key_i = i

plotting = True

data_x, data_pr, data_updown = [], [], []
data_index = []

for i in range(period, len(ohlc)):

  #   pr_list != 1 인 데이터만 사용한다
  # if 1:
  if pr_list[i] != 1:

    min_max = MinMaxScaler()
    
    #   prediction 을 제외한 이전 데이터를 사용해야한다
    temp_ohlc = ohlc.iloc[i - period : i].values
    # temp_long_ep = long_ep[i - period : i]          
    temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
    temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

    temp_close = min_max_scale(temp_ohlc[:, [3]])    

    price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

    if np.isnan(np.sum(price_data)):
      continue

    # print("price_data[:10] :", price_data[:10])
    # print("temp_ohlc.shape :", temp_ohlc.shape)
    # print("temp_long_ep.shape :", temp_long_ep.shape)
    # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
    # print("price_data.shape :", price_data.shape)

    if plotting:
      plt.plot(price_data)
      plt.show()

    ind_temp_ohlc = min_max_scale(temp_ohlc)
    temp_price_data = min_max_scale(price_data)
    # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


    if plotting:

      plt.plot(ind_temp_ohlc)
      plt.show()
      plt.plot(temp_price_data)
      plt.show()

      plotting = False
    # break

    #   vol -> min_max
    temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
    
    #                   feature selection                   #        
    temp_data = np.hstack((ind_temp_ohlc, temp_vol))

    # temp_data = trial_list[trial_number]
    # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
    # temp_data = temp_ohlc[:, [3]]
    # temp_data = ind_temp_ohlc[:, [3]]
    # temp_data = temp_close

    if np.isnan(np.sum(temp_data)):
      continue

    data_x.append(temp_data)
    data_pr.append(pr_list[i])
    data_index.append(time_index[i])
    data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


print('np.array(data_x).shape :', np.array(data_x).shape)
# print(data_x[0])


#       Reshape data for image deep - learning     #
_, row, col = np.array(data_x).shape

input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
# input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

#     1c to 3c    #
input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
# input_x = np.array(resize_npy(input_x))


input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
input_index = np.array(data_index).reshape(-1, 1)
print('input_x.shape :', input_x.shape)
print('input_x.dtype :', input_x.dtype)
print('input_pr.shape :', input_pr.shape)
print('input_ud.shape :', input_ud.shape)
print('input_index.shape :', input_index.shape)


# x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

#     do stacking   #
# if prev_x is None:
prev_x = input_x
prev_pr = input_pr
prev_ud = input_ud
prev_index = input_index

total_x = input_x
total_pr = input_pr
total_ud = input_ud
total_index = input_index

# else:
#   total_x = np.vstack((prev_x, input_x))
#   total_pr = np.vstack((prev_pr, input_pr))
#   total_ud = np.vstack((prev_ud, input_ud)) 
#   total_index = np.vstack((prev_index, input_index)) 

#   prev_x = total_x
#   prev_pr = total_pr
#   prev_ud = total_ud
#   prev_index = total_index

print('total_x.shape :', total_x.shape)
print('total_pr.shape :', total_pr.shape)
print('total_ud.shape :', total_ud.shape)
print('prev_index.shape :', prev_index.shape)


# _, row, col, _ = input_x.shape
# _, row, col = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


#         get unique timestamp      #
print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

#                 don't shuffle timeseries data                 #
stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)

index_train = np.array(index_train)
index_val = np.array(index_val)
index_test = np.array(index_test)
  
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

symbol_name = key.split(' ')[1].split('.')[0]

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)

np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %% [markdown]
# ### load npy

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


symbol_name = "SXPUSDT"
period = 45

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)


x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')


pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

# total_x = np.vstack((x_train, x_val, x_test))
# total_pr = np.vstack((pr_train, pr_val, pr_test))

# print("total_x.shape :", total_x.shape)
# Out:
# x series loaded !
# y series loaded !

# %% [markdown]
# ### rapid pr selection

# %%
plt.plot(pr)
plt.show()

pr_thresh = 1.005
rapid_pct = len(pr[pr > pr_thresh]) / len(pr)

print(rapid_pct)
# Out:
# 0.36131427304964536

# %% [markdown]
# ### class_weight & categorization

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


def class_ratio(in_list):

  return in_list / in_list[1]
  
y_train = np.where(pr_train > pr_thresh, 1, 0)
y_test = np.where(pr_test > pr_thresh, 1, 0)
y_val = np.where(pr_val > pr_thresh, 1, 0)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

# try:
print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

# except Exception as e:
  # print(e)

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)
# Out:
# x_train.shape : (10755, 45, 5, 3)
# x_test.shape : (3586, 45, 5, 3)
# x_val.shape : (3585, 45, 5, 3)
# y_train.shape : (10755, 1)
# y_test.shape : (3586, 1)
# y_val.shape : (3585, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([6864, 3891])) [1.76407093 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2303, 1282])) [1.79641186 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2291, 1295])) [1.76911197 1.        ]
# class_weights : {0: 0.7834353146853147, 1: 1.382035466461064}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10755, 2)
# y_val_ohe.shape : (3585, 2)
# y_test_ohe.shape : (3586, 2)

# %% [markdown]
# ### augment

# %%
from keras.preprocessing.image import ImageDataGenerator 

datagen = ImageDataGenerator( 
    # rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)


batch_size = 512


for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break

# %% [markdown]
# ### train

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'

# batch_size = 512

model = FER_Model(input_shape=x_train.shape[1:])
opt = Adam(lr=0.00001, decay=0.000005)
# opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model_name = 'classifier_%s_cnn_updown_rascend_1005_%s_tvnon_shuffle.h5' % (period, symbol_name)



checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]
# callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)

# %% [markdown]
# ### load model

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'


model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)


model = keras.models.load_model(ckpt_path + model_name)

# %% [markdown]
# ### test

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)

  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.title(symbol_name)
plt.show()
# Out:
# test_result.shape : (3586, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.04767541]
#  [0.00195843]
#  [0.1600004 ]
#  [0.14308068]
#  [0.00154134]]
# y_test.shape : (3586, 1)
# y_score.shape : (3586, 1)
# len(y_test) : 3586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [5.2342257e-05, 5.224965e-05, 5.119804e-05, 4.92728e-05, 4.9822964e-05, 5.1722614e-05, 5.241118e-05, 5.2653213e-05, 5.4707263e-05, 5.469477e-05, 5.5414595e-05, 5.4917986e-05, 5.5296758e-05, 5.482614e-05, 5.5313794e-05, 5.619928e-05, 5.7341047e-05, 5.8005982e-05, 5.7726982e-05, 5.8714617e-05, 5.924952e-05, 5.9157777e-05, 6.0730683e-05, 6.09751e-05, 6.1022805e-05, 6.194849e-05, 6.286581e-05, 6.367981e-05, 6.4932676e-05, 6.5769455e-05, 6.7948844e-05, 6.841887e-05, 6.806048e-05, 6.849957e-05, 6.9895126e-05, 7.091783e-05, 7.1859926e-05, 7.350335e-05, 7.346305e-05, 7.395025e-05, 7.968566e-05, 7.8947196e-05, 7.8341516e-05, 7.918357e-05, 7.912106e-05, 8.1205275e-05, 8.341604e-05, 8.386569e-05, 8.3938816e-05, 8.564359e-05, 7.970025e-05, 8.0672995e-05, 8.083643e-05, 8.727269e-05, 8.9510206e-05, 8.959228e-05, 8.962243e-05, 8.8885776e-05, 9.023229e-05, 9.169206e-05, 9.0867565e-05, 9.033618e-05, 9.429348e-05, 9.3799725e-05, 9.566918e-05, 9.6586686e-05, 9.398621e-05, 9.4105475e-05, 9.411831e-05, 9.466633e-05, 9.5054995e-05, 9.854746e-05, 9.9124496e-05, 0.00010614127, 0.000108136, 0.00010740872, 0.00010814099, 0.00010723293, 0.00010745465, 0.00010824714, 0.00010731329, 0.000108584194, 0.00010868803, 0.00010257258, 0.000101516416, 0.00010031571, 0.000103715196, 0.00010502134, 0.00010611775, 0.00010916348, 0.00010594193, 0.000104194485, 0.00010433929, 0.000104219216, 0.00010764128, 0.00010433711, 0.00010385209, 0.000106006635, 0.00010645543, 0.00010741285, 0.00010793885, 0.00010773461, 0.000107400294, 0.000107067055, 0.000110430265, 0.00010961514, 0.000110994966, 0.000109511326, 0.00011019072, 0.00011165826, 0.00011095228, 0.00011055433, 0.00011134691, 0.000109883986, 0.0001112986, 0.0001123257, 0.000114077506, 0.00011583454, 0.00011730796, 0.00011702095, 0.00012883096, 0.00012502969, 0.0001211144, 0.00012085415, 0.00012023333, 0.000121178586, 0.0001113643, 0.00011255329, 0.00011366057, 0.00011109531, 0.00011435672, 0.00011691414, 0.00011724194, 0.00011877652, 0.00011876732, 0.00012343662, 0.00012398258, 0.00012742475, 0.00013299534, 0.0001345203, 0.00013497796, 0.00013495858, 0.00013710273, 0.00013803714, 0.00013533776, 0.00014049193, 0.00013862025, 0.00013925365, 0.00013978127, 0.00014475136, 0.00014560782, 0.00014417202, 0.00015133772, 0.0001492487, 0.00015156744, 0.00015025465, 0.00015172384, 0.0001483679, 0.00015025485, 0.00017470514, 0.00017807752, 0.00018197432, 0.00018371776, 0.00018367464, 0.0001920926, 0.00019288564, 0.00020759454, 0.00020698183, 0.00023446795, 0.00023864223, 0.00024568185, 0.0002499611, 0.00025658592, 0.00025730263, 0.00025887572, 0.00026280092, 0.0002670472, 0.00027564648, 0.0002803122, 0.0002723821, 0.00027754836, 0.00027732784, 0.00028359605, 0.0002916876, 0.0002884358, 0.0002919522, 0.00029502896, 0.00028943687, 0.00028854128, 0.00029137387, 0.0002962364, 0.00029461124, 0.00029948735, 0.00030449385, 0.0002996868, 0.00029990985, 0.00029333428, 0.0002965417, 0.00029836778, 0.00029298887, 0.00030178405, 0.00029634495, 0.00029906907, 0.00029697176, 0.0002963374, 0.000295097, 0.000312998, 0.00031196643, 0.00031936396, 0.00032101592, 0.00032832168, 0.0003258465, 0.00033274552, 0.0003290262, 0.00033229083, 0.00034132804, 0.00033895372, 0.00035075872, 0.00034744598, 0.00034445102, 0.00032778905, 0.0003323982, 0.00034709118, 0.0003477889, 0.00035424854, 0.00040091967, 0.00042115894, 0.00041995398, 0.00041660885, 0.00042408038, 0.00044065266, 0.00045346154, 0.00044463656, 0.00047572926, 0.0005098468, 0.00050058664, 0.00049340463, 0.0004999284, 0.0005000292, 0.0004849475, 0.00048356556, 0.0004768842, 0.00047515446, 0.00046261746, 0.00046790738, 0.000461418, 0.00046818578, 0.00046653874, 0.00047877917, 0.00048961974, 0.0005021864, 0.00051662093, 0.00052976055, 0.00053512596, 0.000552535, 0.0005820823, 0.00058700517, 0.00059161586, 0.0005911128, 0.00059325877, 0.00059789245, 0.0006161917, 0.00060233, 0.0006037665, 0.0005968395, 0.0006049573, 0.0006040889, 0.0006045968, 0.000620602, 0.00062113034, 0.0006333279, ...

# %%
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)], linestyle='--', color='r')
plt.title(symbol_name + '\n' + str(new_thresh[np.argmax(acc_pr_bythr)]))
plt.show()

# %%
thresh = 0.5866
y_pred = np.where(y_score[:600, -1] > thresh, 1, 0)
# print('y_pred.shape :', y_pred.shape)
# print('y_pred :', y_pred)

#     compare precision     #

# print('precision :', precision_score(y_test, y_pred))
# print('recall :', recall_score(y_test, y_pred))
# print()

# print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
# print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

# # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
# # plt.show()  
# print()

#     check win-ratio improvement     #
cmat = confusion_matrix(y_test[:len(y_pred)], y_pred)
# print(cmat)
# print(np.sum(cmat, axis=1))

test_size = len(y_test[:len(y_pred)])
test_pr_list = pr_test[:len(y_pred)]
# print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
# print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

# print('pr_test.shape :', pr_test.shape)

# print(y_pred)
# print(test_pr_list)
pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

plt.plot(np.cumprod(pred_pr_list))
plt.show()

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72a922dd9685> in <module>()
#       5 # print(index_train)
#       6 # print(index_val)
# ----> 7 total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index))
#       8 timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train))
#       9 timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val))
#
# NameError: name 'input_index' is not defined

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
