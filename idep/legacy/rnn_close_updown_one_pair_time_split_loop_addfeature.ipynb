# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    # net = layers.LSTM(32, return_sequences=False)(visible)
    net = layers.LSTM(10, return_sequences=False)(visible)

    # net = layers.Dense(32)(visible)
    # net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    net = layers.Dense(128)(net)
    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(256)(net)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)


    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    # net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dropout(0.3)(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight

from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

from funcs_indicator import *

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None

seed = 1
random_state = 201
np.random.seed(seed)

for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue


  # if '02-11' not in candis[i]:  # <-- 04-08 includes all timestamp range
  #   continue  

  # if 'eth'.upper() not in candis[i]:
  #   continue

  # if 'neo'.upper() not in candis[i]:
  #   continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  

    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      # ohlcv = load_dict[key]['ohlcv']

    if 'eth'.upper() not in key:
      continue
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))


    #       select timestamp range      #
    # time_index = ohlcv.index
    # total_stamp = list(map(lambda x: datetime.timestamp(x), time_index)) 

    # rm_index_amt = np.sum(np.array(total_stamp) < start_stamp)

    # ohlcv = ohlcv.iloc[rm_index_amt:]
    # print(ohlcv.head())

    # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.3)]  # exclude back_range
    # predictions = load_dict[key]['predictions']
    # err_ranges = load_dict[key]['err_ranges']
    print("ohlcv.index[0] :", ohlcv.index[0])
    print("ohlcv.index[-1] :", ohlcv.index[-1])

    predictions = ohlcv['close'].shift(1).values
    err_ranges = np.zeros_like(predictions)

    # leverage_list = profit_result_dict[key]['leverage_list']
    # temp_ap_list = list()
    # temp_pr_list = list()

    try:
      print('-------------- %s --------------' % key)
      result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
      # temp_ap_list.append(result[2])
      # temp_pr_list.append(result[3])

      # if round(leverage) == 1:
      #   temp_pr_list = result[3]
      pr_list = result[3][long_index]

    except Exception as e:
      print(e)
      break    


    
  # break
    #         clustering zone           #

    #       set data features : ohlc, v, ep
    time_index = ohlcv.index[-len(predictions):]

    sliced_ohlcv = ohlcv[-len(predictions):]

    #       scale with price    #
    ohlc = ohlcv.iloc[-len(predictions):, :4]      
    long_ep = np.array(predictions)
    long_ep = long_ep.reshape(-1, 1)
    ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
    sar = lucid_sar(sliced_ohlcv)
    ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
    senkou1, senkou2 = ichimoku(sliced_ohlcv)

    #     min max scale   #
    vol = sliced_ohlcv.iloc[-len(predictions):, [4]]

    #     scale with baseline   #
    #     방법 1. 전체 기간 min_max scaling   #
    cbo, ema_cbo = cct_bbo(sliced_ohlcv, 21, 13) 

    _, _, bbw = bb_width(sliced_ohlcv, 20, 2) 
    
    fish = fisher(sliced_ohlcv, 60)
    trix = trix_hist(sliced_ohlcv, 14, 1, 5) 
    rsi_ = rsi(sliced_ohlcv)
    macd_hist = macd(sliced_ohlcv)




    # ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
    # ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
    # ohlcv['body'] = ohlcv['close'] / ohlcv['open']
    # candle = ohlcv.iloc[-len(predictions):, -3:]


    print('len(ohlc) :', len(ohlc))
    print('long_ep.shape :', long_ep.shape)
    print('len(ha_ohlc) :', len(ha_ohlc))
    print('len(sar) :', len(sar))
    print('len(ema1) :', len(ema1))
    print('len(senkou1) :', len(senkou1))
    print('len(cbo) :', len(cbo))
    print('len(ema_cbo) :', len(ema_cbo))
    print('len(bbw) :', len(bbw))
    print('len(fish) :', len(fish))
    print('len(trix) :', len(trix))
    print('len(rsi_) :', len(rsi_))
    print('len(macd_hist) :', len(macd_hist))


    # break


    #       set params    #
    period = 45
    key_i = i

    # plt.plot(cbo)
    # plt.plot(bbw)
    plt.plot(fish, color='b')
    # plt.plot(trix)
    # plt.plot(rsi_)
    # plt.plot(macd_hist)
    plt.show()

    #      global scaling   #
    min_max = MinMaxScaler()
    cbo = min_max.fit_transform(cbo.values.reshape(-1, 1))
    ema_cbo = min_max.fit_transform(ema_cbo.values.reshape(-1, 1))
    bbw = min_max.fit_transform(bbw.values.reshape(-1, 1))
    fish = min_max.fit_transform(fish.values.reshape(-1, 1))
    trix = min_max.fit_transform(trix.values.reshape(-1, 1))
    rsi_ = min_max.fit_transform(rsi_.values.reshape(-1, 1))
    macd_hist = min_max.fit_transform(macd_hist.values.reshape(-1, 1))

    # plt.plot(cbo)
    # plt.plot(bbw)
    plt.plot(fish, color='r')
    # plt.plot(trix)
    # plt.plot(rsi_)
    # plt.plot(macd_hist)
    plt.show()
    # break

    plotting = True

    for trial_number in [13]:

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)          

          price_data = np.hstack((temp_ohlc, temp_long_ep, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))

          temp_ohlc = temp_price_data[:, :4]
          temp_long_ep = temp_price_data[:, [4]]
          temp_ha_ohlc = temp_price_data[:, 5:9]
          temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2 = np.split(temp_price_data[:, 9:], 6, axis=1)

          if plotting:

            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          # temp_candle = candle.iloc[i - period : i].values

          temp_cbo = cbo[i - period : i]
          temp_ema_cbo = ema_cbo[i - period : i]
          temp_bbw = bbw[i - period : i]
          temp_fish = fish[i - period : i]
          temp_trix = trix[i - period : i]
          temp_rsi_ = rsi_[i - period : i]
          temp_macd_hist = macd_hist[i - period : i]

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          trial_list = [temp_long_ep, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2,
                        temp_cbo, temp_ema_cbo, temp_bbw, temp_fish, temp_trix, temp_rsi_, temp_macd_hist]

          # trial_list = [temp_ohlc[:, [0], temp_ohlc[:, [1], temp_ohlc[:, [2], temp_ohlc[:, [3]], temp_vol, temp_ema_cbo]

          #                   feature selection                   #  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, trial_list[trial_number]))
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          #     only close    #
          # temp_data = temp_ohlc[:, [-1]]

          # temp_data = temp_ohlc

          #     only volume    #
          # temp_data = temp_vol

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :-1] = max_abs.fit_transform(temp_data[:, :-1])

          
          # min_max = MinMaxScaler()
          # temp_data = min_max.fit_transform(temp_data)

          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      # input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      # input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)

      
      # _, row, col, _ = input_x.shape
      _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=True, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

  
      symbol_name = key.split(' ')[1].split('.')[0]

      x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_trial_%s_timesplit.npy' % (period, trial_number)
      np.save(x_save_path, x_train)
      np.save(x_save_path.replace('x_train', 'x_val'), x_val)
      np.save(x_save_path.replace('x_train', 'x_test'), x_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('x series saved !')

      pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_trial_%s_timesplit.npy' % (period, trial_number)
      np.save(pr_save_path, pr_train)
      np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
      np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
      # np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
      print('pr series saved !')

      
      _, row, col, = x_train.shape

      #         pr label   #
      y_train = np.where(pr_train > 1, 1, 0)
      y_test = np.where(pr_test > 1, 1, 0)
      y_val = np.where(pr_val > 1, 1, 0)


      seed = 1
      random_state = 20
      np.random.seed(seed)
      # tf.random.set_seed(seed)

      #         up label      #
      # y_train = np.where(ud_train > 1, 1, 0)
      # y_test = np.where(ud_test > 1, 1, 0)
      # y_val = np.where(ud_val > 1, 1, 0)

      # print('pr_train[:5] :', pr_train[:5])
      # print('ud_train[:5] :', ud_train[:5])
      print('y_train[:5] :', y_train[:5])
      print('y_train.dtype :', y_train.dtype)

      print('x_train.shape :', x_train.shape)
      print('x_test.shape :', x_test.shape)
      print('x_val.shape :', x_val.shape)
      print('y_train.shape :', y_train.shape)
      print('y_test.shape :', y_test.shape)
      print('y_val.shape :', y_val.shape)

      def class_ratio(in_list):

        return in_list / in_list[1]

      print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
      print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
      print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

      label = y_train.reshape(-1, )
      class_weights = class_weight.compute_class_weight('balanced', 
                                                          classes=np.unique(label),
                                                          y=label)
      class_weights = dict(enumerate(class_weights))
      print('class_weights :', class_weights)

      # sample_weight = np.ones(shape=(len(y_train),))
      # sample_weight[(y_train == 1).reshape(-1,)] = 1.5
      # print('sample_weight[:20] :', sample_weight[:20])


      print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
      print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
      print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

      print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
      print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
      print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

      y_train_ohe = np_utils.to_categorical(y_train, num_classes)
      y_val_ohe = np_utils.to_categorical(y_val, num_classes)
      y_test_ohe = np_utils.to_categorical(y_test, num_classes)
      print('y_train_ohe.shape :', y_train_ohe.shape)
      print('y_val_ohe.shape :', y_val_ohe.shape)
      print('y_test_ohe.shape :', y_test_ohe.shape)


      ckpt_path = current_path + 'ckpt/'
      board_path = current_path + 'graph/'
      # model_name = 'classifier_%s_close_updown_pr_theta_shuffle_without_back_03.h5' % period
      # model_name = 'classifier_%s_close_updown_pr_theta_train_prevdata_005.h5' % period

      # model_name = 'classifier_%s_close_updown_pr_theta_train_evendata_shuffle2_300k.h5' % period
      # model_name = 'classifier_%s_lstm_close_updown_pr_neo_re_tf1_timesplit.h5' % period
      # model = keras.models.load_model(ckpt_path + model_name)

      batch_size = 512
      # _, row, col, = x_train.shape
      # print("row, col :", row, col)

      model = FER_Model(input_shape=(row, col))
      opt = Adam(lr=0.00001, decay=0.000005)
      # opt = Adam(lr=0.001, decay=0.0005)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      # model_name = 'classifier_%s_close_updown_pr_all_pair_shuffle_300k_timesplit.h5' % period
      # model_name = 'classifier_%s_lstm_close_updown_pr_neo_re_tf1_timesplit.h5' % period
      # model_name = 'classifier_%s_lstm_close_updown_pr_eth_abs_timesplit.h5' % period
      # model_name = 'classifier_%s_lstm_close_updown_pr_neo_abs_timesplit.h5' % period
      model_name = 'classifier_%s_lstm_close_updown_pr_trial_%s_timesplit.h5' % (period, trial_number)



      checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir=board_path,
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]
      # callbacks_list = [checkpoint, checkpoint2]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 1000                    

      history = model.fit(x_train, y_train_ohe,
                          steps_per_epoch=int(len(x_train) / batch_size), 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=(x_val, y_val_ohe),  
                          validation_steps=int(len(x_val) / batch_size),
                          shuffle=False)
      
      ckpt_path = current_path + 'ckpt/'
      board_path = current_path + 'graph/'
      # model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_ex_02008.h5'
      # model_name = 'classifier_45_close_updown_pr_theta.h5'
      # model_name = 'classifier_45_close_updown_pr_theta_train_evendata_shuffle2_300k.h5'
      # model_name = 'classifier_45_lstm_close_updown_pr_neo_timesplit.h5'

      # model_name = 'classifier_45_lstm_close_updown_pr_eth_timesplit.h5'

      model = keras.models.load_model(ckpt_path + model_name)

      # x_test = new_input_x
      # y_test = np.where(new_input_pr > 1, 1, 0)
      # pr_test = new_input_pr

      # x_test = org_x_test
      # y_test = org_y_test
      # pr_test = org_pr_test

      # x_test = x_train
      # y_test = y_train
      # pr_test = pr_train

      # x_test = x_val
      # y_test = y_val
      # pr_test = pr_val

      # x_test = concat_x
      # y_test = np.where(concat_pr > 1, 1, 0)
      # pr_test = concat_pr

      test_result = model.predict(x_test)
      # test_result = model.predict(test_set)

      print('test_result.shape :', test_result.shape)
      # print('pr_val.shape :', pr_val.shape)

      y_score = test_result[:, [1]]
      print('y_test[:5] :', y_test.reshape(-1,)[:5])
      # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
      print('y_score[:5] :', y_score[:5])
      # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

      print('y_test.shape :', y_test.shape)
      print('y_score.shape :', y_score.shape)

      print('len(y_test) :', len(y_test))

      #     precision recall curve   #
      precision, recall, threshold = precision_recall_curve(y_test, y_score)
      precision, recall = precision[:-1], recall[:-1]

      plt.plot(threshold, precision, label='precision')
      plt.plot(threshold, recall, label='recall')
      plt.legend()
      plt.title('precision recall')
      plt.show()
      # print(y_pred)


      # threshold = [0.65]
      # print('threshold :', threshold)
      # break

      acc_pr_bythr = []
      new_thresh = []

      for thresh in threshold:
        
        # if thresh < 0.5:
        #     continue

        y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
        # print('y_pred.shape :', y_pred.shape)
        # print('y_pred :', y_pred)

        #     compare precision     #

        # print('precision :', precision_score(y_test, y_pred))
        # print('recall :', recall_score(y_test, y_pred))
        # print()

        # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
        # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

        # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
        # # plt.show()  
        # print()

        #     check win-ratio improvement     #
        cmat = confusion_matrix(y_test, y_pred)
        # print(cmat)
        # print(np.sum(cmat, axis=1))

        test_size = len(y_test)
        test_pr_list = pr_test
        # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

        org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
        ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
        # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

        # print('pr_test.shape :', pr_test.shape)

        # print(y_pred)
        # print(test_pr_list)
        pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
        pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
        pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
        # print('pred_pr_list.shape :', pred_pr_list.shape)

        # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
        #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
        #   print('thresh :', thresh)
          
        # if len(threshold) == 1:
      #   plt.figure(figsize=(10, 5))
      #   plt.subplot(121)
      #   plt.plot(np.cumprod(test_pr_list))
      #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
      # # plt.show()

      #   plt.subplot(122)
      #   plt.plot(np.cumprod(pred_pr_list))
      #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
      #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
      #   plt.show()


        acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
        new_thresh.append(thresh)


      print('acc_pr_bythr :', acc_pr_bythr)

      plt.figure(figsize=(10, 5))
      plt.subplot(121)
      plt.plot(threshold, precision, label='precision')
      plt.plot(threshold, recall, label='recall')
      plt.legend()
      plt.title('precision recall')
      # plt.show()
      plt.subplot(122)
      plt.plot(new_thresh, acc_pr_bythr)
      plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
      plt.show()


  # break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  try:
    if len(total_x) > 300000:
      break
  except:
    pass
# Out:
# start_stamp : 0
# len(ohlcv) : 18048
# ohlcv.index[0] : 2020-04-17 00:29:59.999000
# ohlcv.index[-1] : 2021-04-27 23:59:59.999000
# -------------- 2021-04-27 ETHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# /content/drive/My Drive/Colab Notebooks/Project_Stock/funcs_indicator.py:273: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlcv_df['up'] = np.where(ohlcv_df['close'].diff(1) > 0, ohlcv_df['close'].diff(1), 0)
# /content/drive/My Drive/Colab Notebooks/Project_Stock/funcs_indicator.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlcv_df['down'] = np.where(ohlcv_df['close'].diff(1) < 0, ohlcv_df['close'].diff(1) * (-1), 0)
# len(ohlc) : 18048
# long_ep.shape : (18048, 1)
# len(ha_ohlc) : 18048
# len(sar) : 18048
# len(ema1) : 18048
# len(senkou1) : 18048
# len(cbo) : 18048
# len(ema_cbo) : 18048
# len(bbw) : 18048
# len(fish) : 18048
# len(trix) : 18048
# len(rsi_) : 18048
# len(macd_hist) : 18048
# np.array(data_x).shape : (17476, 45, 1)
# input_x.shape : (17476, 45, 1)
# input_x.dtype : float32
# input_pr.shape : (17476, 1)
# input_ud.shape : (17476, 1)
# input_index.shape : (17476, 1)
# total_x.shape : (17476, 45, 1)
# total_pr.shape : (17476, 1)
# total_ud.shape : (17476, 1)
# prev_index.shape : (17476, 1)
# (array([Timestamp('2020-04-19 12:59:59.999000'),
#        Timestamp('2020-04-19 13:29:59.999000'),
#        Timestamp('2020-04-19 13:59:59.999000'), ...,
#        Timestamp('2021-04-27 22:59:59.999000'),
#        Timestamp('2021-04-27 23:29:59.999000'),
#        Timestamp('2021-04-27 23:59:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (10485,)
# stamp_val.shape : (3495,)
# stamp_test.shape : (3496,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:365: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# HBox(children=(FloatProgress(value=0.0, max=17476.0), HTML(value='')))
# x_train.shape : (10485, 45, 1)
# x_val.shape : (3495, 45, 1)
# x_test.shape : (3496, 45, 1)
# x series saved !
# pr series saved !
# y_train[:5] : [[0]
#  [1]
#  [0]
#  [0]
#  [0]]
# y_train.dtype : int64
# x_train.shape : (10485, 45, 1)
# x_test.shape : (3496, 45, 1)
# x_val.shape : (3495, 45, 1)
# y_train.shape : (10485, 1)
# y_test.shape : (3496, 1)
# y_val.shape : (3495, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([5912, 4573])) [1.2928056 1.       ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([1940, 1555])) [1.24758842 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([1949, 1547])) [1.25985779 1.        ]
# class_weights : {0: 0.886755751014885, 1: 1.1464027990378307}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10485, 2)
# y_val_ohe.shape : (3495, 2)
# y_test_ohe.shape : (3496, 2)
# Model: "model_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 45, 1)             0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 10)                480
# _________________________________________________________________
# leaky_re_lu_79 (LeakyReLU)   (None, 10)                0
# _________________________________________________________________
# dense_79 (Dense)             (None, 64)                704
# _________________________________________________________________
# leaky_re_lu_80 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 64)                256
# _________________________________________________________________
# dense_80 (Dense)             (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_81 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_81 (Dense)             (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_82 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_82 (Dense)             (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_83 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_83 (Dense)             (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_84 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_84 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 85,090
# Trainable params: 84,450
# Non-trainable params: 640
# _________________________________________________________________
# None
# Train on 10485 samples, validate on 3495 samples
# Epoch 1/1000
#  - 4s - loss: 0.7328 - accuracy: 0.4668 - val_loss: 0.1155 - val_accuracy: 3.3305
#
# Epoch 00001: val_loss improved from inf to 0.11549, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 2/1000
#  - 1s - loss: 0.7108 - accuracy: 0.4771 - val_loss: 0.1155 - val_accuracy: 3.3305
#
# Epoch 00002: val_loss did not improve from 0.11549
# Epoch 3/1000
#  - 1s - loss: 0.7033 - accuracy: 0.4996 - val_loss: 0.1155 - val_accuracy: 3.3305
#
# Epoch 00003: val_loss did not improve from 0.11549
# Epoch 4/1000
#  - 1s - loss: 0.7011 - accuracy: 0.5132 - val_loss: 0.1155 - val_accuracy: 3.3305
#
# Epoch 00004: val_loss improved from 0.11549 to 0.11547, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 5/1000
#  - 1s - loss: 0.6988 - accuracy: 0.5219 - val_loss: 0.1154 - val_accuracy: 3.3305
#
# Epoch 00005: val_loss improved from 0.11547 to 0.11543, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 6/1000
#  - 1s - loss: 0.6973 - accuracy: 0.5265 - val_loss: 0.1154 - val_accuracy: 3.3305
#
# Epoch 00006: val_loss improved from 0.11543 to 0.11541, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 7/1000
#  - 1s - loss: 0.6968 - accuracy: 0.5318 - val_loss: 0.1154 - val_accuracy: 3.3305
#
# Epoch 00007: val_loss improved from 0.11541 to 0.11538, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 8/1000
#  - 1s - loss: 0.6958 - accuracy: 0.5331 - val_loss: 0.1154 - val_accuracy: 3.3305
#
# Epoch 00008: val_loss improved from 0.11538 to 0.11535, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 9/1000
#  - 1s - loss: 0.6948 - accuracy: 0.5359 - val_loss: 0.1153 - val_accuracy: 3.3339
#
# Epoch 00009: val_loss improved from 0.11535 to 0.11532, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 10/1000
#  - 1s - loss: 0.6941 - accuracy: 0.5374 - val_loss: 0.1153 - val_accuracy: 3.3356
#
# Epoch 00010: val_loss improved from 0.11532 to 0.11529, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 11/1000
#  - 1s - loss: 0.6936 - accuracy: 0.5387 - val_loss: 0.1153 - val_accuracy: 3.3339
#
# Epoch 00011: val_loss improved from 0.11529 to 0.11526, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 12/1000
#  - 1s - loss: 0.6938 - accuracy: 0.5396 - val_loss: 0.1152 - val_accuracy: 3.3459
#
# Epoch 00012: val_loss improved from 0.11526 to 0.11523, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 13/1000
#  - 1s - loss: 0.6931 - accuracy: 0.5414 - val_loss: 0.1152 - val_accuracy: 3.3442
#
# Epoch 00013: val_loss improved from 0.11523 to 0.11520, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 14/1000
#  - 1s - loss: 0.6926 - accuracy: 0.5416 - val_loss: 0.1152 - val_accuracy: 3.3579
#
# Epoch 00014: val_loss improved from 0.11520 to 0.11517, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 15/1000
#  - 1s - loss: 0.6920 - accuracy: 0.5441 - val_loss: 0.1151 - val_accuracy: 3.3734
#
# Epoch 00015: val_loss improved from 0.11517 to 0.11514, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 16/1000
#  - 1s - loss: 0.6920 - accuracy: 0.5452 - val_loss: 0.1151 - val_accuracy: 3.3820
#
# Epoch 00016: val_loss improved from 0.11514 to 0.11511, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 17/1000
#  - 1s - loss: 0.6920 - accuracy: 0.5448 - val_loss: 0.1151 - val_accuracy: 3.3820
#
# Epoch 00017: val_loss improved from 0.11511 to 0.11509, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 18/1000
#  - 1s - loss: 0.6914 - accuracy: 0.5460 - val_loss: 0.1151 - val_accuracy: 3.3700
#
# Epoch 00018: val_loss improved from 0.11509 to 0.11507, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 19/1000
#  - 1s - loss: 0.6910 - accuracy: 0.5463 - val_loss: 0.1150 - val_accuracy: 3.3597
#
# Epoch 00019: val_loss improved from 0.11507 to 0.11504, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 20/1000
#  - 1s - loss: 0.6912 - accuracy: 0.5462 - val_loss: 0.1150 - val_accuracy: 3.3476
#
# Epoch 00020: val_loss improved from 0.11504 to 0.11502, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 21/1000
#  - 1s - loss: 0.6908 - accuracy: 0.5479 - val_loss: 0.1150 - val_accuracy: 3.3425
#
# Epoch 00021: val_loss improved from 0.11502 to 0.11499, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 22/1000
#  - 1s - loss: 0.6904 - accuracy: 0.5475 - val_loss: 0.1150 - val_accuracy: 3.3408
#
# Epoch 00022: val_loss improved from 0.11499 to 0.11496, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 23/1000
#  - 1s - loss: 0.6904 - accuracy: 0.5474 - val_loss: 0.1149 - val_accuracy: 3.3391
#
# Epoch 00023: val_loss improved from 0.11496 to 0.11493, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 24/1000
#  - 1s - loss: 0.6902 - accuracy: 0.5488 - val_loss: 0.1149 - val_accuracy: 3.3545
#
# Epoch 00024: val_loss improved from 0.11493 to 0.11489, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 25/1000
#  - 1s - loss: 0.6901 - accuracy: 0.5498 - val_loss: 0.1149 - val_accuracy: 3.3665
#
# Epoch 00025: val_loss improved from 0.11489 to 0.11487, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 26/1000
#  - 1s - loss: 0.6902 - accuracy: 0.5502 - val_loss: 0.1149 - val_accuracy: 3.3597
#
# Epoch 00026: val_loss improved from 0.11487 to 0.11485, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 27/1000
#  - 1s - loss: 0.6901 - accuracy: 0.5491 - val_loss: 0.1148 - val_accuracy: 3.3476
#
# Epoch 00027: val_loss improved from 0.11485 to 0.11480, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 28/1000
#  - 1s - loss: 0.6898 - accuracy: 0.5512 - val_loss: 0.1148 - val_accuracy: 3.3391
#
# Epoch 00028: val_loss improved from 0.11480 to 0.11476, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 29/1000
#  - 1s - loss: 0.6897 - accuracy: 0.5501 - val_loss: 0.1147 - val_accuracy: 3.3511
#
# Epoch 00029: val_loss improved from 0.11476 to 0.11474, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 30/1000
#  - 1s - loss: 0.6897 - accuracy: 0.5506 - val_loss: 0.1147 - val_accuracy: 3.3425
#
# Epoch 00030: val_loss improved from 0.11474 to 0.11469, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 31/1000
#  - 1s - loss: 0.6896 - accuracy: 0.5508 - val_loss: 0.1147 - val_accuracy: 3.3202
#
# Epoch 00031: val_loss improved from 0.11469 to 0.11466, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 32/1000
#  - 1s - loss: 0.6894 - accuracy: 0.5511 - val_loss: 0.1147 - val_accuracy: 3.3253
#
# Epoch 00032: val_loss did not improve from 0.11466
# Epoch 33/1000
#  - 1s - loss: 0.6892 - accuracy: 0.5521 - val_loss: 0.1147 - val_accuracy: 3.3150
#
# Epoch 00033: val_loss did not improve from 0.11466
# Epoch 34/1000
#  - 1s - loss: 0.6893 - accuracy: 0.5512 - val_loss: 0.1147 - val_accuracy: 3.3099
#
# Epoch 00034: val_loss did not improve from 0.11466
# Epoch 35/1000
#  - 1s - loss: 0.6891 - accuracy: 0.5520 - val_loss: 0.1148 - val_accuracy: 3.3185
#
# Epoch 00035: val_loss did not improve from 0.11466
# Epoch 36/1000
#  - 1s - loss: 0.6891 - accuracy: 0.5527 - val_loss: 0.1149 - val_accuracy: 3.3013
#
# Epoch 00036: val_loss did not improve from 0.11466
# Epoch 37/1000
#  - 1s - loss: 0.6890 - accuracy: 0.5517 - val_loss: 0.1148 - val_accuracy: 3.3322
#
# Epoch 00037: val_loss did not improve from 0.11466
# Epoch 38/1000
#  - 1s - loss: 0.6891 - accuracy: 0.5520 - val_loss: 0.1148 - val_accuracy: 3.3167
#
# Epoch 00038: val_loss did not improve from 0.11466
# Epoch 39/1000
#  - 1s - loss: 0.6889 - accuracy: 0.5528 - val_loss: 0.1149 - val_accuracy: 3.2996
#
# Epoch 00039: val_loss did not improve from 0.11466
# Epoch 40/1000
#  - 1s - loss: 0.6891 - accuracy: 0.5515 - val_loss: 0.1149 - val_accuracy: 3.3030
#
# Epoch 00040: val_loss did not improve from 0.11466
# Epoch 41/1000
#  - 1s - loss: 0.6888 - accuracy: 0.5530 - val_loss: 0.1149 - val_accuracy: 3.3013
#
# Epoch 00041: val_loss did not improve from 0.11466
# Epoch 42/1000
#  - 1s - loss: 0.6887 - accuracy: 0.5533 - val_loss: 0.1149 - val_accuracy: 3.3185
#
# Epoch 00042: val_loss did not improve from 0.11466
# Epoch 43/1000
#  - 1s - loss: 0.6883 - accuracy: 0.5540 - val_loss: 0.1149 - val_accuracy: 3.3082
#
# Epoch 00043: val_loss did not improve from 0.11466
# Epoch 44/1000
#  - 1s - loss: 0.6885 - accuracy: 0.5533 - val_loss: 0.1150 - val_accuracy: 3.3185
#
# Epoch 00044: val_loss did not improve from 0.11466
# Epoch 45/1000
#  - 1s - loss: 0.6885 - accuracy: 0.5536 - val_loss: 0.1150 - val_accuracy: 3.3099
#
# Epoch 00045: val_loss did not improve from 0.11466
# Epoch 46/1000
#  - 1s - loss: 0.6885 - accuracy: 0.5538 - val_loss: 0.1149 - val_accuracy: 3.3133
#
# Epoch 00046: val_loss did not improve from 0.11466
# Epoch 47/1000
#  - 1s - loss: 0.6883 - accuracy: 0.5544 - val_loss: 0.1151 - val_accuracy: 3.2910
#
# Epoch 00047: val_loss did not improve from 0.11466
# Epoch 48/1000
#  - 1s - loss: 0.6883 - accuracy: 0.5544 - val_loss: 0.1151 - val_accuracy: 3.2876
#
# Epoch 00048: val_loss did not improve from 0.11466
# Epoch 49/1000
#  - 1s - loss: 0.6882 - accuracy: 0.5550 - val_loss: 0.1152 - val_accuracy: 3.2721
#
# Epoch 00049: val_loss did not improve from 0.11466
# Epoch 50/1000
#  - 1s - loss: 0.6881 - accuracy: 0.5557 - val_loss: 0.1151 - val_accuracy: 3.2876
#
# Epoch 00050: val_loss did not improve from 0.11466
# Epoch 51/1000
#  - 1s - loss: 0.6882 - accuracy: 0.5546 - val_loss: 0.1151 - val_accuracy: 3.2755
#
# Epoch 00051: val_loss did not improve from 0.11466
# Epoch 52/1000
#  - 1s - loss: 0.6881 - accuracy: 0.5543 - val_loss: 0.1150 - val_accuracy: 3.2961
#
# Epoch 00052: val_loss did not improve from 0.11466
# Epoch 53/1000
#  - 1s - loss: 0.6880 - accuracy: 0.5553 - val_loss: 0.1150 - val_accuracy: 3.3013
#
# Epoch 00053: val_loss did not improve from 0.11466
# Epoch 54/1000
#  - 1s - loss: 0.6881 - accuracy: 0.5553 - val_loss: 0.1149 - val_accuracy: 3.3288
#
# Epoch 00054: val_loss did not improve from 0.11466
# Epoch 55/1000
#  - 1s - loss: 0.6879 - accuracy: 0.5563 - val_loss: 0.1149 - val_accuracy: 3.3185
#
# Epoch 00055: val_loss did not improve from 0.11466
# Epoch 56/1000
#  - 1s - loss: 0.6877 - accuracy: 0.5562 - val_loss: 0.1151 - val_accuracy: 3.3013
#
# Epoch 00056: val_loss did not improve from 0.11466
# Epoch 57/1000
#  - 1s - loss: 0.6880 - accuracy: 0.5561 - val_loss: 0.1152 - val_accuracy: 3.2910
#
# Epoch 00057: val_loss did not improve from 0.11466
# Epoch 58/1000
#  - 1s - loss: 0.6879 - accuracy: 0.5560 - val_loss: 0.1153 - val_accuracy: 3.2601
#
# Epoch 00058: val_loss did not improve from 0.11466
# Epoch 59/1000
#  - 1s - loss: 0.6879 - accuracy: 0.5558 - val_loss: 0.1151 - val_accuracy: 3.3150
#
# Epoch 00059: val_loss did not improve from 0.11466
# Epoch 60/1000
#  - 1s - loss: 0.6878 - accuracy: 0.5561 - val_loss: 0.1152 - val_accuracy: 3.3099
#
# Epoch 00060: val_loss did not improve from 0.11466
# Epoch 61/1000
#  - 1s - loss: 0.6876 - accuracy: 0.5559 - val_loss: 0.1151 - val_accuracy: 3.3013
#
# Epoch 00061: val_loss did not improve from 0.11466
# Epoch 62/1000
#  - 1s - loss: 0.6877 - accuracy: 0.5558 - val_loss: 0.1150 - val_accuracy: 3.3064
#
# Epoch 00062: val_loss did not improve from 0.11466
# Epoch 63/1000
#  - 1s - loss: 0.6878 - accuracy: 0.5562 - val_loss: 0.1152 - val_accuracy: 3.2996
#
# Epoch 00063: val_loss did not improve from 0.11466
# Epoch 64/1000
#  - 1s - loss: 0.6875 - accuracy: 0.5574 - val_loss: 0.1154 - val_accuracy: 3.2515
#
# Epoch 00064: val_loss did not improve from 0.11466
# Epoch 65/1000
#  - 1s - loss: 0.6878 - accuracy: 0.5559 - val_loss: 0.1154 - val_accuracy: 3.2378
#
# Epoch 00065: val_loss did not improve from 0.11466
# Epoch 66/1000
#  - 1s - loss: 0.6876 - accuracy: 0.5571 - val_loss: 0.1154 - val_accuracy: 3.2292
#
# Epoch 00066: val_loss did not improve from 0.11466
# Epoch 67/1000
#  - 1s - loss: 0.6873 - accuracy: 0.5573 - val_loss: 0.1154 - val_accuracy: 3.2240
#
# Epoch 00067: val_loss did not improve from 0.11466
# Epoch 68/1000
#  - 1s - loss: 0.6876 - accuracy: 0.5566 - val_loss: 0.1155 - val_accuracy: 3.2000
#
# Epoch 00068: val_loss did not improve from 0.11466
# Epoch 69/1000
#  - 1s - loss: 0.6875 - accuracy: 0.5566 - val_loss: 0.1155 - val_accuracy: 3.2086
#
# Epoch 00069: val_loss did not improve from 0.11466
# Epoch 70/1000
#  - 1s - loss: 0.6873 - accuracy: 0.5584 - val_loss: 0.1153 - val_accuracy: 3.2618
#
# Epoch 00070: val_loss did not improve from 0.11466
# Epoch 71/1000
#  - 1s - loss: 0.6874 - accuracy: 0.5574 - val_loss: 0.1154 - val_accuracy: 3.2223
#
# Epoch 00071: val_loss did not improve from 0.11466
# Epoch 72/1000
#  - 1s - loss: 0.6872 - accuracy: 0.5580 - val_loss: 0.1152 - val_accuracy: 3.2858
#
# Epoch 00072: val_loss did not improve from 0.11466
# Epoch 73/1000
#  - 1s - loss: 0.6874 - accuracy: 0.5569 - val_loss: 0.1151 - val_accuracy: 3.2876
#
# Epoch 00073: val_loss did not improve from 0.11466
# Epoch 74/1000
#  - 1s - loss: 0.6873 - accuracy: 0.5571 - val_loss: 0.1150 - val_accuracy: 3.3064
#
# Epoch 00074: val_loss did not improve from 0.11466
# Epoch 75/1000
#  - 1s - loss: 0.6872 - accuracy: 0.5585 - val_loss: 0.1150 - val_accuracy: 3.2893
#
# Epoch 00075: val_loss did not improve from 0.11466
# Epoch 76/1000
#  - 1s - loss: 0.6873 - accuracy: 0.5578 - val_loss: 0.1149 - val_accuracy: 3.3116
#
# Epoch 00076: val_loss did not improve from 0.11466
# Epoch 77/1000
#  - 1s - loss: 0.6871 - accuracy: 0.5583 - val_loss: 0.1148 - val_accuracy: 3.3219
#
# Epoch 00077: val_loss did not improve from 0.11466
# Epoch 78/1000
#  - 1s - loss: 0.6873 - accuracy: 0.5569 - val_loss: 0.1149 - val_accuracy: 3.3219
#
# Epoch 00078: val_loss did not improve from 0.11466
# Epoch 79/1000
#  - 1s - loss: 0.6870 - accuracy: 0.5581 - val_loss: 0.1147 - val_accuracy: 3.3150
#
# Epoch 00079: val_loss did not improve from 0.11466
# Epoch 80/1000
#  - 1s - loss: 0.6872 - accuracy: 0.5581 - val_loss: 0.1149 - val_accuracy: 3.3064
#
# Epoch 00080: val_loss did not improve from 0.11466
# Epoch 81/1000
#  - 1s - loss: 0.6871 - accuracy: 0.5578 - val_loss: 0.1150 - val_accuracy: 3.3099
#
# Epoch 00081: val_loss did not improve from 0.11466
# Epoch 82/1000
#  - 1s - loss: 0.6869 - accuracy: 0.5584 - val_loss: 0.1152 - val_accuracy: 3.2738
#
# Epoch 00082: val_loss did not improve from 0.11466
# Epoch 83/1000
#  - 1s - loss: 0.6869 - accuracy: 0.5585 - val_loss: 0.1154 - val_accuracy: 3.2223
#
# Epoch 00083: val_loss did not improve from 0.11466
# Epoch 84/1000
#  - 1s - loss: 0.6869 - accuracy: 0.5587 - val_loss: 0.1152 - val_accuracy: 3.2532
#
# Epoch 00084: val_loss did not improve from 0.11466
# Epoch 85/1000
#  - 1s - loss: 0.6870 - accuracy: 0.5584 - val_loss: 0.1155 - val_accuracy: 3.2017
#
# Epoch 00085: val_loss did not improve from 0.11466
# Epoch 86/1000
#  - 1s - loss: 0.6867 - accuracy: 0.5587 - val_loss: 0.1154 - val_accuracy: 3.2275
#
# Epoch 00086: val_loss did not improve from 0.11466
# Epoch 87/1000
#  - 1s - loss: 0.6868 - accuracy: 0.5584 - val_loss: 0.1152 - val_accuracy: 3.2687
#
# Epoch 00087: val_loss did not improve from 0.11466
# Epoch 88/1000
#  - 1s - loss: 0.6868 - accuracy: 0.5596 - val_loss: 0.1152 - val_accuracy: 3.2635
#
# Epoch 00088: val_loss did not improve from 0.11466
# Epoch 89/1000
#  - 1s - loss: 0.6868 - accuracy: 0.5588 - val_loss: 0.1153 - val_accuracy: 3.2395
#
# Epoch 00089: val_loss did not improve from 0.11466
# Epoch 90/1000
#  - 1s - loss: 0.6867 - accuracy: 0.5585 - val_loss: 0.1153 - val_accuracy: 3.2395
#
# Epoch 00090: val_loss did not improve from 0.11466
# Epoch 91/1000
#  - 1s - loss: 0.6869 - accuracy: 0.5591 - val_loss: 0.1156 - val_accuracy: 3.2189
#
# Epoch 00091: val_loss did not improve from 0.11466
# Epoch 92/1000
#  - 1s - loss: 0.6866 - accuracy: 0.5588 - val_loss: 0.1158 - val_accuracy: 3.1536
#
# Epoch 00092: val_loss did not improve from 0.11466
# Epoch 93/1000
#  - 1s - loss: 0.6867 - accuracy: 0.5593 - val_loss: 0.1156 - val_accuracy: 3.1725
#
# Epoch 00093: val_loss did not improve from 0.11466
# Epoch 94/1000
#  - 1s - loss: 0.6866 - accuracy: 0.5596 - val_loss: 0.1156 - val_accuracy: 3.1622
#
# Epoch 00094: val_loss did not improve from 0.11466
# Epoch 95/1000
#  - 1s - loss: 0.6866 - accuracy: 0.5597 - val_loss: 0.1154 - val_accuracy: 3.1931
#
# Epoch 00095: val_loss did not improve from 0.11466
# Epoch 96/1000
#  - 1s - loss: 0.6866 - accuracy: 0.5593 - val_loss: 0.1150 - val_accuracy: 3.2687
#
# Epoch 00096: val_loss did not improve from 0.11466
# Epoch 97/1000
#  - 1s - loss: 0.6866 - accuracy: 0.5589 - val_loss: 0.1151 - val_accuracy: 3.2532
#
# Epoch 00097: val_loss did not improve from 0.11466
# Epoch 98/1000
#  - 1s - loss: 0.6865 - accuracy: 0.5598 - val_loss: 0.1146 - val_accuracy: 3.3545
#
# Epoch 00098: val_loss improved from 0.11466 to 0.11457, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 99/1000
#  - 1s - loss: 0.6864 - accuracy: 0.5601 - val_loss: 0.1149 - val_accuracy: 3.3133
#
# Epoch 00099: val_loss did not improve from 0.11457
# Epoch 100/1000
#  - 1s - loss: 0.6864 - accuracy: 0.5595 - val_loss: 0.1146 - val_accuracy: 3.3494
#
# Epoch 00100: val_loss did not improve from 0.11457
# Epoch 101/1000
#  - 1s - loss: 0.6865 - accuracy: 0.5599 - val_loss: 0.1146 - val_accuracy: 3.3597
#
# Epoch 00101: val_loss did not improve from 0.11457
# Epoch 102/1000
#  - 1s - loss: 0.6863 - accuracy: 0.5600 - val_loss: 0.1147 - val_accuracy: 3.3305
#
# Epoch 00102: val_loss did not improve from 0.11457
# Epoch 103/1000
#  - 1s - loss: 0.6863 - accuracy: 0.5600 - val_loss: 0.1146 - val_accuracy: 3.3545
#
# Epoch 00103: val_loss did not improve from 0.11457
# Epoch 104/1000
#  - 1s - loss: 0.6864 - accuracy: 0.5602 - val_loss: 0.1147 - val_accuracy: 3.3030
#
# Epoch 00104: val_loss did not improve from 0.11457
# Epoch 105/1000
#  - 1s - loss: 0.6863 - accuracy: 0.5594 - val_loss: 0.1144 - val_accuracy: 3.3528
#
# Epoch 00105: val_loss improved from 0.11457 to 0.11445, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 106/1000
#  - 1s - loss: 0.6863 - accuracy: 0.5601 - val_loss: 0.1145 - val_accuracy: 3.3425
#
# Epoch 00106: val_loss did not improve from 0.11445
# Epoch 107/1000
#  - 1s - loss: 0.6864 - accuracy: 0.5599 - val_loss: 0.1146 - val_accuracy: 3.3150
#
# Epoch 00107: val_loss did not improve from 0.11445
# Epoch 108/1000
#  - 1s - loss: 0.6863 - accuracy: 0.5604 - val_loss: 0.1148 - val_accuracy: 3.3064
#
# Epoch 00108: val_loss did not improve from 0.11445
# Epoch 109/1000
#  - 1s - loss: 0.6862 - accuracy: 0.5605 - val_loss: 0.1149 - val_accuracy: 3.3099
#
# Epoch 00109: val_loss did not improve from 0.11445
# Epoch 110/1000
#  - 1s - loss: 0.6863 - accuracy: 0.5621 - val_loss: 0.1147 - val_accuracy: 3.3339
#
# Epoch 00110: val_loss did not improve from 0.11445
# Epoch 111/1000
#  - 1s - loss: 0.6862 - accuracy: 0.5616 - val_loss: 0.1147 - val_accuracy: 3.3511
#
# Epoch 00111: val_loss did not improve from 0.11445
# Epoch 112/1000
#  - 1s - loss: 0.6860 - accuracy: 0.5612 - val_loss: 0.1149 - val_accuracy: 3.3082
#
# Epoch 00112: val_loss did not improve from 0.11445
# Epoch 113/1000
#  - 1s - loss: 0.6860 - accuracy: 0.5620 - val_loss: 0.1151 - val_accuracy: 3.3167
#
# Epoch 00113: val_loss did not improve from 0.11445
# Epoch 114/1000
#  - 1s - loss: 0.6862 - accuracy: 0.5609 - val_loss: 0.1148 - val_accuracy: 3.3185
#
# Epoch 00114: val_loss did not improve from 0.11445
# Epoch 115/1000
#  - 1s - loss: 0.6860 - accuracy: 0.5607 - val_loss: 0.1146 - val_accuracy: 3.3459
#
# Epoch 00115: val_loss did not improve from 0.11445
# Epoch 116/1000
#  - 1s - loss: 0.6861 - accuracy: 0.5609 - val_loss: 0.1152 - val_accuracy: 3.2704
#
# Epoch 00116: val_loss did not improve from 0.11445
# Epoch 117/1000
#  - 1s - loss: 0.6860 - accuracy: 0.5617 - val_loss: 0.1151 - val_accuracy: 3.2979
#
# Epoch 00117: val_loss did not improve from 0.11445
# Epoch 118/1000
#  - 1s - loss: 0.6859 - accuracy: 0.5621 - val_loss: 0.1152 - val_accuracy: 3.2858
#
# Epoch 00118: val_loss did not improve from 0.11445
# Epoch 119/1000
#  - 1s - loss: 0.6860 - accuracy: 0.5612 - val_loss: 0.1150 - val_accuracy: 3.2961
#
# Epoch 00119: val_loss did not improve from 0.11445
# Epoch 120/1000
#  - 1s - loss: 0.6859 - accuracy: 0.5611 - val_loss: 0.1149 - val_accuracy: 3.3013
#
# Epoch 00120: val_loss did not improve from 0.11445
# Epoch 121/1000
#  - 1s - loss: 0.6859 - accuracy: 0.5624 - val_loss: 0.1151 - val_accuracy: 3.2824
#
# Epoch 00121: val_loss did not improve from 0.11445
# Epoch 122/1000
#  - 1s - loss: 0.6860 - accuracy: 0.5611 - val_loss: 0.1146 - val_accuracy: 3.3528
#
# Epoch 00122: val_loss did not improve from 0.11445
# Epoch 123/1000
#  - 1s - loss: 0.6860 - accuracy: 0.5614 - val_loss: 0.1147 - val_accuracy: 3.3236
#
# Epoch 00123: val_loss did not improve from 0.11445
# Epoch 124/1000
#  - 1s - loss: 0.6860 - accuracy: 0.5608 - val_loss: 0.1148 - val_accuracy: 3.3185
#
# Epoch 00124: val_loss did not improve from 0.11445
# Epoch 125/1000
#  - 1s - loss: 0.6859 - accuracy: 0.5626 - val_loss: 0.1147 - val_accuracy: 3.3167
#
# Epoch 00125: val_loss did not improve from 0.11445
# Epoch 126/1000
#  - 1s - loss: 0.6858 - accuracy: 0.5622 - val_loss: 0.1144 - val_accuracy: 3.3459
#
# Epoch 00126: val_loss improved from 0.11445 to 0.11444, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 127/1000
#  - 1s - loss: 0.6859 - accuracy: 0.5619 - val_loss: 0.1147 - val_accuracy: 3.3476
#
# Epoch 00127: val_loss did not improve from 0.11444
# Epoch 128/1000
#  - 1s - loss: 0.6858 - accuracy: 0.5619 - val_loss: 0.1146 - val_accuracy: 3.3545
#
# Epoch 00128: val_loss did not improve from 0.11444
# Epoch 129/1000
#  - 1s - loss: 0.6858 - accuracy: 0.5623 - val_loss: 0.1145 - val_accuracy: 3.3734
#
# Epoch 00129: val_loss did not improve from 0.11444
# Epoch 130/1000
#  - 1s - loss: 0.6857 - accuracy: 0.5625 - val_loss: 0.1147 - val_accuracy: 3.3356
#
# Epoch 00130: val_loss did not improve from 0.11444
# Epoch 131/1000
#  - 1s - loss: 0.6857 - accuracy: 0.5633 - val_loss: 0.1147 - val_accuracy: 3.3425
#
# Epoch 00131: val_loss did not improve from 0.11444
# Epoch 132/1000
#  - 1s - loss: 0.6857 - accuracy: 0.5625 - val_loss: 0.1148 - val_accuracy: 3.2944
#
# Epoch 00132: val_loss did not improve from 0.11444
# Epoch 133/1000
#  - 1s - loss: 0.6856 - accuracy: 0.5622 - val_loss: 0.1154 - val_accuracy: 3.2275
#
# Epoch 00133: val_loss did not improve from 0.11444
# Epoch 134/1000
#  - 1s - loss: 0.6856 - accuracy: 0.5633 - val_loss: 0.1157 - val_accuracy: 3.1588
#
# Epoch 00134: val_loss did not improve from 0.11444
# Epoch 135/1000
#  - 1s - loss: 0.6856 - accuracy: 0.5629 - val_loss: 0.1156 - val_accuracy: 3.1674
#
# Epoch 00135: val_loss did not improve from 0.11444
# Epoch 136/1000
#  - 1s - loss: 0.6856 - accuracy: 0.5630 - val_loss: 0.1154 - val_accuracy: 3.2618
#
# Epoch 00136: val_loss did not improve from 0.11444
# Epoch 137/1000
#  - 1s - loss: 0.6856 - accuracy: 0.5624 - val_loss: 0.1156 - val_accuracy: 3.2086
#
# Epoch 00137: val_loss did not improve from 0.11444
# Epoch 138/1000
#  - 1s - loss: 0.6856 - accuracy: 0.5634 - val_loss: 0.1149 - val_accuracy: 3.3013
#
# Epoch 00138: val_loss did not improve from 0.11444
# Epoch 139/1000
#  - 1s - loss: 0.6857 - accuracy: 0.5633 - val_loss: 0.1150 - val_accuracy: 3.2961
#
# Epoch 00139: val_loss did not improve from 0.11444
# Epoch 140/1000
#  - 1s - loss: 0.6856 - accuracy: 0.5631 - val_loss: 0.1149 - val_accuracy: 3.2979
#
# Epoch 00140: val_loss did not improve from 0.11444
# Epoch 141/1000
#  - 1s - loss: 0.6855 - accuracy: 0.5630 - val_loss: 0.1150 - val_accuracy: 3.2893
#
# Epoch 00141: val_loss did not improve from 0.11444
# Epoch 142/1000
#  - 1s - loss: 0.6855 - accuracy: 0.5631 - val_loss: 0.1154 - val_accuracy: 3.2567
#
# Epoch 00142: val_loss did not improve from 0.11444
# Epoch 143/1000
#  - 1s - loss: 0.6855 - accuracy: 0.5636 - val_loss: 0.1152 - val_accuracy: 3.2841
#
# Epoch 00143: val_loss did not improve from 0.11444
# Epoch 144/1000
#  - 1s - loss: 0.6854 - accuracy: 0.5633 - val_loss: 0.1150 - val_accuracy: 3.3133
#
# Epoch 00144: val_loss did not improve from 0.11444
# Epoch 145/1000
#  - 1s - loss: 0.6855 - accuracy: 0.5635 - val_loss: 0.1149 - val_accuracy: 3.3082
#
# Epoch 00145: val_loss did not improve from 0.11444
# Epoch 146/1000
#  - 1s - loss: 0.6854 - accuracy: 0.5633 - val_loss: 0.1151 - val_accuracy: 3.2790
#
# Epoch 00146: val_loss did not improve from 0.11444
# Epoch 147/1000
#  - 1s - loss: 0.6854 - accuracy: 0.5632 - val_loss: 0.1149 - val_accuracy: 3.2876
#
# Epoch 00147: val_loss did not improve from 0.11444
# Epoch 148/1000
#  - 1s - loss: 0.6852 - accuracy: 0.5637 - val_loss: 0.1150 - val_accuracy: 3.2876
#
# Epoch 00148: val_loss did not improve from 0.11444
# Epoch 149/1000
#  - 1s - loss: 0.6853 - accuracy: 0.5634 - val_loss: 0.1151 - val_accuracy: 3.2893
#
# Epoch 00149: val_loss did not improve from 0.11444
# Epoch 150/1000
#  - 1s - loss: 0.6852 - accuracy: 0.5640 - val_loss: 0.1150 - val_accuracy: 3.2944
#
# Epoch 00150: val_loss did not improve from 0.11444
# Epoch 151/1000
#  - 1s - loss: 0.6853 - accuracy: 0.5637 - val_loss: 0.1148 - val_accuracy: 3.3082
#
# Epoch 00151: val_loss did not improve from 0.11444
# Epoch 152/1000
#  - 1s - loss: 0.6852 - accuracy: 0.5650 - val_loss: 0.1146 - val_accuracy: 3.3442
#
# Epoch 00152: val_loss did not improve from 0.11444
# Epoch 153/1000
#  - 1s - loss: 0.6853 - accuracy: 0.5646 - val_loss: 0.1147 - val_accuracy: 3.2979
#
# Epoch 00153: val_loss did not improve from 0.11444
# Epoch 154/1000
#  - 1s - loss: 0.6851 - accuracy: 0.5648 - val_loss: 0.1145 - val_accuracy: 3.3494
#
# Epoch 00154: val_loss did not improve from 0.11444
# Epoch 155/1000
#  - 1s - loss: 0.6851 - accuracy: 0.5639 - val_loss: 0.1145 - val_accuracy: 3.3579
#
# Epoch 00155: val_loss did not improve from 0.11444
# Epoch 156/1000
#  - 1s - loss: 0.6851 - accuracy: 0.5641 - val_loss: 0.1144 - val_accuracy: 3.3528
#
# Epoch 00156: val_loss improved from 0.11444 to 0.11440, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 157/1000
#  - 1s - loss: 0.6852 - accuracy: 0.5639 - val_loss: 0.1146 - val_accuracy: 3.3013
#
# Epoch 00157: val_loss did not improve from 0.11440
# Epoch 158/1000
#  - 1s - loss: 0.6852 - accuracy: 0.5642 - val_loss: 0.1148 - val_accuracy: 3.2996
#
# Epoch 00158: val_loss did not improve from 0.11440
# Epoch 159/1000
#  - 1s - loss: 0.6852 - accuracy: 0.5639 - val_loss: 0.1149 - val_accuracy: 3.2755
#
# Epoch 00159: val_loss did not improve from 0.11440
# Epoch 160/1000
#  - 1s - loss: 0.6852 - accuracy: 0.5650 - val_loss: 0.1147 - val_accuracy: 3.2979
#
# Epoch 00160: val_loss did not improve from 0.11440
# Epoch 161/1000
#  - 1s - loss: 0.6849 - accuracy: 0.5651 - val_loss: 0.1150 - val_accuracy: 3.2944
#
# Epoch 00161: val_loss did not improve from 0.11440
# Epoch 162/1000
#  - 1s - loss: 0.6851 - accuracy: 0.5640 - val_loss: 0.1149 - val_accuracy: 3.2841
#
# Epoch 00162: val_loss did not improve from 0.11440
# Epoch 163/1000
#  - 1s - loss: 0.6850 - accuracy: 0.5650 - val_loss: 0.1151 - val_accuracy: 3.3030
#
# Epoch 00163: val_loss did not improve from 0.11440
# Epoch 164/1000
#  - 1s - loss: 0.6849 - accuracy: 0.5639 - val_loss: 0.1148 - val_accuracy: 3.2927
#
# Epoch 00164: val_loss did not improve from 0.11440
# Epoch 165/1000
#  - 1s - loss: 0.6849 - accuracy: 0.5647 - val_loss: 0.1147 - val_accuracy: 3.2961
#
# Epoch 00165: val_loss did not improve from 0.11440
# Epoch 166/1000
#  - 1s - loss: 0.6850 - accuracy: 0.5637 - val_loss: 0.1148 - val_accuracy: 3.3030
#
# Epoch 00166: val_loss did not improve from 0.11440
# Epoch 167/1000
#  - 1s - loss: 0.6849 - accuracy: 0.5638 - val_loss: 0.1153 - val_accuracy: 3.2275
#
# Epoch 00167: val_loss did not improve from 0.11440
# Epoch 168/1000
#  - 1s - loss: 0.6849 - accuracy: 0.5648 - val_loss: 0.1151 - val_accuracy: 3.2910
#
# Epoch 00168: val_loss did not improve from 0.11440
# Epoch 169/1000
#  - 1s - loss: 0.6850 - accuracy: 0.5647 - val_loss: 0.1150 - val_accuracy: 3.2944
#
# Epoch 00169: val_loss did not improve from 0.11440
# Epoch 170/1000
#  - 1s - loss: 0.6848 - accuracy: 0.5655 - val_loss: 0.1149 - val_accuracy: 3.2876
#
# Epoch 00170: val_loss did not improve from 0.11440
# Epoch 171/1000
#  - 1s - loss: 0.6849 - accuracy: 0.5639 - val_loss: 0.1151 - val_accuracy: 3.2841
#
# Epoch 00171: val_loss did not improve from 0.11440
# Epoch 172/1000
#  - 1s - loss: 0.6848 - accuracy: 0.5646 - val_loss: 0.1150 - val_accuracy: 3.2876
#
# Epoch 00172: val_loss did not improve from 0.11440
# Epoch 173/1000
#  - 1s - loss: 0.6848 - accuracy: 0.5654 - val_loss: 0.1147 - val_accuracy: 3.3133
#
# Epoch 00173: val_loss did not improve from 0.11440
# Epoch 174/1000
#  - 1s - loss: 0.6848 - accuracy: 0.5642 - val_loss: 0.1147 - val_accuracy: 3.3305
#
# Epoch 00174: val_loss did not improve from 0.11440
# Epoch 175/1000
#  - 1s - loss: 0.6848 - accuracy: 0.5656 - val_loss: 0.1148 - val_accuracy: 3.3099
#
# Epoch 00175: val_loss did not improve from 0.11440
# Epoch 176/1000
#  - 1s - loss: 0.6847 - accuracy: 0.5661 - val_loss: 0.1145 - val_accuracy: 3.3391
#
# Epoch 00176: val_loss did not improve from 0.11440
# Epoch 177/1000
#  - 1s - loss: 0.6847 - accuracy: 0.5659 - val_loss: 0.1148 - val_accuracy: 3.2979
#
# Epoch 00177: val_loss did not improve from 0.11440
# Epoch 178/1000
#  - 1s - loss: 0.6848 - accuracy: 0.5656 - val_loss: 0.1154 - val_accuracy: 3.2189
#
# Epoch 00178: val_loss did not improve from 0.11440
# Epoch 179/1000
#  - 1s - loss: 0.6846 - accuracy: 0.5654 - val_loss: 0.1153 - val_accuracy: 3.2240
#
# Epoch 00179: val_loss did not improve from 0.11440
# Epoch 180/1000
#  - 1s - loss: 0.6845 - accuracy: 0.5664 - val_loss: 0.1149 - val_accuracy: 3.2807
#
# Epoch 00180: val_loss did not improve from 0.11440
# Epoch 181/1000
#  - 1s - loss: 0.6845 - accuracy: 0.5664 - val_loss: 0.1153 - val_accuracy: 3.2275
#
# Epoch 00181: val_loss did not improve from 0.11440
# Epoch 182/1000
#  - 1s - loss: 0.6846 - accuracy: 0.5651 - val_loss: 0.1154 - val_accuracy: 3.2052
#
# Epoch 00182: val_loss did not improve from 0.11440
# Epoch 183/1000
#  - 1s - loss: 0.6846 - accuracy: 0.5654 - val_loss: 0.1154 - val_accuracy: 3.1948
#
# Epoch 00183: val_loss did not improve from 0.11440
# Epoch 184/1000
#  - 1s - loss: 0.6844 - accuracy: 0.5664 - val_loss: 0.1152 - val_accuracy: 3.2515
#
# Epoch 00184: val_loss did not improve from 0.11440
# Epoch 185/1000
#  - 1s - loss: 0.6843 - accuracy: 0.5665 - val_loss: 0.1151 - val_accuracy: 3.2807
#
# Epoch 00185: val_loss did not improve from 0.11440
# Epoch 186/1000
#  - 1s - loss: 0.6844 - accuracy: 0.5663 - val_loss: 0.1153 - val_accuracy: 3.2412
#
# Epoch 00186: val_loss did not improve from 0.11440
# Epoch 187/1000
#  - 1s - loss: 0.6845 - accuracy: 0.5666 - val_loss: 0.1153 - val_accuracy: 3.2223
#
# Epoch 00187: val_loss did not improve from 0.11440
# Epoch 188/1000
#  - 1s - loss: 0.6845 - accuracy: 0.5659 - val_loss: 0.1155 - val_accuracy: 3.1948
#
# Epoch 00188: val_loss did not improve from 0.11440
# Epoch 189/1000
#  - 1s - loss: 0.6845 - accuracy: 0.5662 - val_loss: 0.1154 - val_accuracy: 3.2223
#
# Epoch 00189: val_loss did not improve from 0.11440
# Epoch 190/1000
#  - 1s - loss: 0.6843 - accuracy: 0.5657 - val_loss: 0.1152 - val_accuracy: 3.2206
#
# Epoch 00190: val_loss did not improve from 0.11440
# Epoch 191/1000
#  - 1s - loss: 0.6843 - accuracy: 0.5664 - val_loss: 0.1155 - val_accuracy: 3.1948
#
# Epoch 00191: val_loss did not improve from 0.11440
# Epoch 192/1000
#  - 1s - loss: 0.6843 - accuracy: 0.5665 - val_loss: 0.1148 - val_accuracy: 3.3030
#
# Epoch 00192: val_loss did not improve from 0.11440
# Epoch 193/1000
#  - 1s - loss: 0.6843 - accuracy: 0.5670 - val_loss: 0.1150 - val_accuracy: 3.2841
#
# Epoch 00193: val_loss did not improve from 0.11440
# Epoch 194/1000
#  - 1s - loss: 0.6841 - accuracy: 0.5670 - val_loss: 0.1150 - val_accuracy: 3.3013
#
# Epoch 00194: val_loss did not improve from 0.11440
# Epoch 195/1000
#  - 1s - loss: 0.6842 - accuracy: 0.5663 - val_loss: 0.1154 - val_accuracy: 3.2326
#
# Epoch 00195: val_loss did not improve from 0.11440
# Epoch 196/1000
#  - 1s - loss: 0.6843 - accuracy: 0.5665 - val_loss: 0.1158 - val_accuracy: 3.1348
#
# Epoch 00196: val_loss did not improve from 0.11440
# Epoch 197/1000
#  - 1s - loss: 0.6843 - accuracy: 0.5674 - val_loss: 0.1160 - val_accuracy: 3.0850
#
# Epoch 00197: val_loss did not improve from 0.11440
# Epoch 198/1000
#  - 1s - loss: 0.6842 - accuracy: 0.5658 - val_loss: 0.1153 - val_accuracy: 3.2601
#
# Epoch 00198: val_loss did not improve from 0.11440
# Epoch 199/1000
#  - 1s - loss: 0.6841 - accuracy: 0.5657 - val_loss: 0.1152 - val_accuracy: 3.2738
#
# Epoch 00199: val_loss did not improve from 0.11440
# Epoch 200/1000
#  - 1s - loss: 0.6841 - accuracy: 0.5665 - val_loss: 0.1153 - val_accuracy: 3.2584
#
# Epoch 00200: val_loss did not improve from 0.11440
# Epoch 201/1000
#  - 1s - loss: 0.6840 - accuracy: 0.5661 - val_loss: 0.1152 - val_accuracy: 3.2601
#
# Epoch 00201: val_loss did not improve from 0.11440
# Epoch 202/1000
#  - 1s - loss: 0.6841 - accuracy: 0.5672 - val_loss: 0.1151 - val_accuracy: 3.2876
#
# Epoch 00202: val_loss did not improve from 0.11440
# Epoch 203/1000
#  - 1s - loss: 0.6840 - accuracy: 0.5670 - val_loss: 0.1150 - val_accuracy: 3.2927
#
# Epoch 00203: val_loss did not improve from 0.11440
# Epoch 204/1000
#  - 1s - loss: 0.6841 - accuracy: 0.5663 - val_loss: 0.1148 - val_accuracy: 3.3305
#
# Epoch 00204: val_loss did not improve from 0.11440
# Epoch 205/1000
#  - 1s - loss: 0.6839 - accuracy: 0.5665 - val_loss: 0.1149 - val_accuracy: 3.3099
#
# Epoch 00205: val_loss did not improve from 0.11440
# Epoch 206/1000
#  - 1s - loss: 0.6840 - accuracy: 0.5661 - val_loss: 0.1148 - val_accuracy: 3.3253
#
# Epoch 00206: val_loss did not improve from 0.11440
# Epoch 207/1000
#  - 1s - loss: 0.6840 - accuracy: 0.5672 - val_loss: 0.1150 - val_accuracy: 3.3236
#
# Epoch 00207: val_loss did not improve from 0.11440
# Epoch 208/1000
#  - 1s - loss: 0.6838 - accuracy: 0.5684 - val_loss: 0.1145 - val_accuracy: 3.3785
#
# Epoch 00208: val_loss did not improve from 0.11440
# Epoch 209/1000
#  - 1s - loss: 0.6839 - accuracy: 0.5670 - val_loss: 0.1146 - val_accuracy: 3.3614
#
# Epoch 00209: val_loss did not improve from 0.11440
# Epoch 210/1000
#  - 1s - loss: 0.6840 - accuracy: 0.5674 - val_loss: 0.1150 - val_accuracy: 3.2927
#
# Epoch 00210: val_loss did not improve from 0.11440
# Epoch 211/1000
#  - 1s - loss: 0.6838 - accuracy: 0.5666 - val_loss: 0.1152 - val_accuracy: 3.2343
#
# Epoch 00211: val_loss did not improve from 0.11440
# Epoch 212/1000
#  - 1s - loss: 0.6839 - accuracy: 0.5667 - val_loss: 0.1153 - val_accuracy: 3.2275
#
# Epoch 00212: val_loss did not improve from 0.11440
# Epoch 213/1000
#  - 1s - loss: 0.6838 - accuracy: 0.5671 - val_loss: 0.1149 - val_accuracy: 3.2858
#
# Epoch 00213: val_loss did not improve from 0.11440
# Epoch 214/1000
#  - 1s - loss: 0.6837 - accuracy: 0.5678 - val_loss: 0.1150 - val_accuracy: 3.2721
#
# Epoch 00214: val_loss did not improve from 0.11440
# Epoch 215/1000
#  - 1s - loss: 0.6836 - accuracy: 0.5674 - val_loss: 0.1147 - val_accuracy: 3.3356
#
# Epoch 00215: val_loss did not improve from 0.11440
# Epoch 216/1000
#  - 1s - loss: 0.6837 - accuracy: 0.5668 - val_loss: 0.1146 - val_accuracy: 3.3408
#
# Epoch 00216: val_loss did not improve from 0.11440
# Epoch 217/1000
#  - 1s - loss: 0.6837 - accuracy: 0.5672 - val_loss: 0.1146 - val_accuracy: 3.3511
#
# Epoch 00217: val_loss did not improve from 0.11440
# Epoch 218/1000
#  - 1s - loss: 0.6837 - accuracy: 0.5676 - val_loss: 0.1148 - val_accuracy: 3.3013
#
# Epoch 00218: val_loss did not improve from 0.11440
# Epoch 219/1000
#  - 1s - loss: 0.6836 - accuracy: 0.5676 - val_loss: 0.1153 - val_accuracy: 3.2378
#
# Epoch 00219: val_loss did not improve from 0.11440
# Epoch 220/1000
#  - 1s - loss: 0.6836 - accuracy: 0.5680 - val_loss: 0.1152 - val_accuracy: 3.2498
#
# Epoch 00220: val_loss did not improve from 0.11440
# Epoch 221/1000
#  - 1s - loss: 0.6835 - accuracy: 0.5685 - val_loss: 0.1153 - val_accuracy: 3.2172
#
# Epoch 00221: val_loss did not improve from 0.11440
# Epoch 222/1000
#  - 1s - loss: 0.6835 - accuracy: 0.5670 - val_loss: 0.1146 - val_accuracy: 3.3442
#
# Epoch 00222: val_loss did not improve from 0.11440
# Epoch 223/1000
#  - 1s - loss: 0.6835 - accuracy: 0.5685 - val_loss: 0.1146 - val_accuracy: 3.3442
#
# Epoch 00223: val_loss did not improve from 0.11440
# Epoch 224/1000
#  - 1s - loss: 0.6834 - accuracy: 0.5688 - val_loss: 0.1142 - val_accuracy: 3.3459
#
# Epoch 00224: val_loss improved from 0.11440 to 0.11418, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_trial_13_timesplit.h5
# Epoch 225/1000
#  - 1s - loss: 0.6833 - accuracy: 0.5689 - val_loss: 0.1144 - val_accuracy: 3.3511
#
# Epoch 00225: val_loss did not improve from 0.11418
# Epoch 226/1000
#  - 1s - loss: 0.6834 - accuracy: 0.5680 - val_loss: 0.1145 - val_accuracy: 3.3545
#
# Epoch 00226: val_loss did not improve from 0.11418
# Epoch 227/1000
#  - 1s - loss: 0.6834 - accuracy: 0.5674 - val_loss: 0.1144 - val_accuracy: 3.3391
#
# Epoch 00227: val_loss did not improve from 0.11418
# Epoch 228/1000
#  - 1s - loss: 0.6834 - accuracy: 0.5680 - val_loss: 0.1145 - val_accuracy: 3.3511
#
# Epoch 00228: val_loss did not improve from 0.11418
# Epoch 229/1000
#  - 1s - loss: 0.6832 - accuracy: 0.5691 - val_loss: 0.1145 - val_accuracy: 3.3270
#
# Epoch 00229: val_loss did not improve from 0.11418
# Epoch 230/1000
#  - 1s - loss: 0.6834 - accuracy: 0.5683 - val_loss: 0.1149 - val_accuracy: 3.2687
#
# Epoch 00230: val_loss did not improve from 0.11418
# Epoch 231/1000
#  - 1s - loss: 0.6833 - accuracy: 0.5680 - val_loss: 0.1157 - val_accuracy: 3.1931
#
# Epoch 00231: val_loss did not improve from 0.11418
# Epoch 232/1000
#  - 1s - loss: 0.6831 - accuracy: 0.5684 - val_loss: 0.1156 - val_accuracy: 3.2412
#
# Epoch 00232: val_loss did not improve from 0.11418
# Epoch 233/1000
#  - 1s - loss: 0.6833 - accuracy: 0.5689 - val_loss: 0.1156 - val_accuracy: 3.1897
#
# Epoch 00233: val_loss did not improve from 0.11418
# Epoch 234/1000
#  - 1s - loss: 0.6831 - accuracy: 0.5682 - val_loss: 0.1161 - val_accuracy: 3.0953
#
# Epoch 00234: val_loss did not improve from 0.11418
# Epoch 235/1000
#  - 1s - loss: 0.6832 - accuracy: 0.5691 - val_loss: 0.1161 - val_accuracy: 3.0266
#
# Epoch 00235: val_loss did not improve from 0.11418
# Epoch 236/1000
#  - 1s - loss: 0.6833 - accuracy: 0.5678 - val_loss: 0.1160 - val_accuracy: 3.1039
#
# Epoch 00236: val_loss did not improve from 0.11418
# Epoch 237/1000
#  - 1s - loss: 0.6832 - accuracy: 0.5682 - val_loss: 0.1159 - val_accuracy: 3.1571
#
# Epoch 00237: val_loss did not improve from 0.11418
# Epoch 238/1000
#  - 1s - loss: 0.6831 - accuracy: 0.5686 - val_loss: 0.1163 - val_accuracy: 2.9597
#
# Epoch 00238: val_loss did not improve from 0.11418
# Epoch 239/1000
#  - 1s - loss: 0.6831 - accuracy: 0.5686 - val_loss: 0.1165 - val_accuracy: 2.8481
#
# Epoch 00239: val_loss did not improve from 0.11418
# Epoch 240/1000
#  - 1s - loss: 0.6829 - accuracy: 0.5693 - val_loss: 0.1168 - val_accuracy: 2.8309
#
# Epoch 00240: val_loss did not improve from 0.11418
# Epoch 241/1000
# ...
# Epoch 397/1000
#  - 1s - loss: 0.6771 - accuracy: 0.5792 - val_loss: 0.1184 - val_accuracy: 2.7588
#
# Epoch 00397: val_loss did not improve from 0.11418
# Epoch 398/1000
#  - 1s - loss: 0.6770 - accuracy: 0.5785 - val_loss: 0.1173 - val_accuracy: 2.9185
#
# Epoch 00398: val_loss did not improve from 0.11418
# Epoch 399/1000
#  - 1s - loss: 0.6770 - accuracy: 0.5785 - val_loss: 0.1177 - val_accuracy: 2.8618
#
# Epoch 00399: val_loss did not improve from 0.11418
# Epoch 400/1000
#  - 1s - loss: 0.6770 - accuracy: 0.5794 - val_loss: 0.1176 - val_accuracy: 2.8773
#
# Epoch 00400: val_loss did not improve from 0.11418
# Epoch 401/1000
#  - 1s - loss: 0.6770 - accuracy: 0.5787 - val_loss: 0.1183 - val_accuracy: 2.7914
#
# Epoch 00401: val_loss did not improve from 0.11418
# Epoch 402/1000
#  - 1s - loss: 0.6770 - accuracy: 0.5784 - val_loss: 0.1185 - val_accuracy: 2.7931
#
# Epoch 00402: val_loss did not improve from 0.11418
# Epoch 403/1000
#  - 1s - loss: 0.6767 - accuracy: 0.5793 - val_loss: 0.1191 - val_accuracy: 2.7330
#
# Epoch 00403: val_loss did not improve from 0.11418
# Epoch 404/1000
#  - 1s - loss: 0.6766 - accuracy: 0.5792 - val_loss: 0.1175 - val_accuracy: 2.9185
#
# Epoch 00404: val_loss did not improve from 0.11418
# Epoch 405/1000
#  - 1s - loss: 0.6769 - accuracy: 0.5783 - val_loss: 0.1181 - val_accuracy: 2.8086
#
# Epoch 00405: val_loss did not improve from 0.11418
# Epoch 406/1000
#  - 1s - loss: 0.6768 - accuracy: 0.5796 - val_loss: 0.1180 - val_accuracy: 2.9099
#
# Epoch 00406: val_loss did not improve from 0.11418
# Epoch 407/1000
#  - 1s - loss: 0.6768 - accuracy: 0.5791 - val_loss: 0.1175 - val_accuracy: 2.9597
#
# Epoch 00407: val_loss did not improve from 0.11418
# Epoch 408/1000
#  - 1s - loss: 0.6767 - accuracy: 0.5783 - val_loss: 0.1175 - val_accuracy: 2.9597
#
# Epoch 00408: val_loss did not improve from 0.11418
# Epoch 409/1000
#  - 1s - loss: 0.6765 - accuracy: 0.5792 - val_loss: 0.1168 - val_accuracy: 3.0318
#
# Epoch 00409: val_loss did not improve from 0.11418
# Epoch 410/1000
#  - 1s - loss: 0.6767 - accuracy: 0.5789 - val_loss: 0.1158 - val_accuracy: 3.1948
#
# Epoch 00410: val_loss did not improve from 0.11418
# Epoch 411/1000
#  - 1s - loss: 0.6765 - accuracy: 0.5788 - val_loss: 0.1151 - val_accuracy: 3.2910
#
# Epoch 00411: val_loss did not improve from 0.11418
# Epoch 412/1000
#  - 1s - loss: 0.6765 - accuracy: 0.5789 - val_loss: 0.1158 - val_accuracy: 3.1897
#
# Epoch 00412: val_loss did not improve from 0.11418
# Epoch 413/1000
#  - 1s - loss: 0.6762 - accuracy: 0.5802 - val_loss: 0.1182 - val_accuracy: 2.8223
#
# Epoch 00413: val_loss did not improve from 0.11418
# Epoch 414/1000
#  - 1s - loss: 0.6764 - accuracy: 0.5798 - val_loss: 0.1172 - val_accuracy: 2.9356
#
# Epoch 00414: val_loss did not improve from 0.11418
# Epoch 415/1000
#  - 1s - loss: 0.6764 - accuracy: 0.5798 - val_loss: 0.1171 - val_accuracy: 3.0009
#
# Epoch 00415: val_loss did not improve from 0.11418
# Epoch 416/1000
#  - 1s - loss: 0.6763 - accuracy: 0.5794 - val_loss: 0.1172 - val_accuracy: 2.9803
#
# Epoch 00416: val_loss did not improve from 0.11418
# Epoch 417/1000
#  - 1s - loss: 0.6764 - accuracy: 0.5804 - val_loss: 0.1171 - val_accuracy: 3.0009
#
# Epoch 00417: val_loss did not improve from 0.11418
# Epoch 418/1000
#  - 1s - loss: 0.6762 - accuracy: 0.5796 - val_loss: 0.1185 - val_accuracy: 2.7811
#
# Epoch 00418: val_loss did not improve from 0.11418
# Epoch 419/1000
#  - 1s - loss: 0.6760 - accuracy: 0.5802 - val_loss: 0.1168 - val_accuracy: 3.0798
#
# Epoch 00419: val_loss did not improve from 0.11418
# Epoch 420/1000
#  - 1s - loss: 0.6760 - accuracy: 0.5803 - val_loss: 0.1166 - val_accuracy: 3.1279
#
# Epoch 00420: val_loss did not improve from 0.11418
# Epoch 421/1000
#  - 1s - loss: 0.6759 - accuracy: 0.5803 - val_loss: 0.1211 - val_accuracy: 2.7382
#
# Epoch 00421: val_loss did not improve from 0.11418
# Epoch 422/1000
#  - 1s - loss: 0.6760 - accuracy: 0.5798 - val_loss: 0.1223 - val_accuracy: 2.7124
#
# Epoch 00422: val_loss did not improve from 0.11418
# Epoch 423/1000
#  - 1s - loss: 0.6759 - accuracy: 0.5806 - val_loss: 0.1224 - val_accuracy: 2.6987
#
# Epoch 00423: val_loss did not improve from 0.11418
# Epoch 424/1000
#  - 1s - loss: 0.6761 - accuracy: 0.5799 - val_loss: 0.1219 - val_accuracy: 2.6918
#
# Epoch 00424: val_loss did not improve from 0.11418
# Epoch 425/1000
#  - 1s - loss: 0.6758 - accuracy: 0.5795 - val_loss: 0.1202 - val_accuracy: 2.7330
#
# Epoch 00425: val_loss did not improve from 0.11418
# Epoch 426/1000
#  - 1s - loss: 0.6759 - accuracy: 0.5800 - val_loss: 0.1185 - val_accuracy: 2.8000
#
# Epoch 00426: val_loss did not improve from 0.11418
# Epoch 427/1000
#  - 1s - loss: 0.6757 - accuracy: 0.5794 - val_loss: 0.1184 - val_accuracy: 2.8189
#
# Epoch 00427: val_loss did not improve from 0.11418
# Epoch 428/1000
#  - 1s - loss: 0.6757 - accuracy: 0.5802 - val_loss: 0.1198 - val_accuracy: 2.7485
#
# Epoch 00428: val_loss did not improve from 0.11418
# Epoch 429/1000
#  - 1s - loss: 0.6758 - accuracy: 0.5803 - val_loss: 0.1196 - val_accuracy: 2.7880
#
# Epoch 00429: val_loss did not improve from 0.11418
# Epoch 430/1000
#  - 1s - loss: 0.6757 - accuracy: 0.5802 - val_loss: 0.1199 - val_accuracy: 2.7176
#
# Epoch 00430: val_loss did not improve from 0.11418
# Epoch 431/1000
#  - 1s - loss: 0.6756 - accuracy: 0.5800 - val_loss: 0.1189 - val_accuracy: 2.7330
#
# Epoch 00431: val_loss did not improve from 0.11418
# Epoch 432/1000
#  - 1s - loss: 0.6755 - accuracy: 0.5801 - val_loss: 0.1188 - val_accuracy: 2.7536
#
# Epoch 00432: val_loss did not improve from 0.11418
# Epoch 433/1000
#  - 1s - loss: 0.6753 - accuracy: 0.5804 - val_loss: 0.1213 - val_accuracy: 2.7142
#
# Epoch 00433: val_loss did not improve from 0.11418
# Epoch 434/1000
#  - 1s - loss: 0.6754 - accuracy: 0.5796 - val_loss: 0.1199 - val_accuracy: 2.7073
#
# Epoch 00434: val_loss did not improve from 0.11418
# Epoch 435/1000
#  - 1s - loss: 0.6752 - accuracy: 0.5809 - val_loss: 0.1190 - val_accuracy: 2.7416
#
# Epoch 00435: val_loss did not improve from 0.11418
# Epoch 436/1000
#  - 1s - loss: 0.6755 - accuracy: 0.5800 - val_loss: 0.1197 - val_accuracy: 2.7262
#
# Epoch 00436: val_loss did not improve from 0.11418
# Epoch 437/1000
#  - 1s - loss: 0.6752 - accuracy: 0.5809 - val_loss: 0.1190 - val_accuracy: 2.7468
#
# Epoch 00437: val_loss did not improve from 0.11418
# Epoch 438/1000
#  - 1s - loss: 0.6753 - accuracy: 0.5807 - val_loss: 0.1195 - val_accuracy: 2.7176
#
# Epoch 00438: val_loss did not improve from 0.11418
# Epoch 439/1000
#  - 1s - loss: 0.6752 - accuracy: 0.5803 - val_loss: 0.1212 - val_accuracy: 2.7124
#
# Epoch 00439: val_loss did not improve from 0.11418
# Epoch 440/1000
#  - 1s - loss: 0.6751 - accuracy: 0.5811 - val_loss: 0.1222 - val_accuracy: 2.6970
#
# Epoch 00440: val_loss did not improve from 0.11418
# Epoch 441/1000
#  - 1s - loss: 0.6751 - accuracy: 0.5801 - val_loss: 0.1196 - val_accuracy: 2.7433
#
# Epoch 00441: val_loss did not improve from 0.11418
# Epoch 442/1000
#  - 1s - loss: 0.6751 - accuracy: 0.5807 - val_loss: 0.1216 - val_accuracy: 2.7227
#
# Epoch 00442: val_loss did not improve from 0.11418
# Epoch 443/1000
#  - 1s - loss: 0.6750 - accuracy: 0.5810 - val_loss: 0.1224 - val_accuracy: 2.7056
#
# Epoch 00443: val_loss did not improve from 0.11418
# Epoch 444/1000
#  - 1s - loss: 0.6752 - accuracy: 0.5795 - val_loss: 0.1212 - val_accuracy: 2.7090
#
# Epoch 00444: val_loss did not improve from 0.11418
# Epoch 445/1000
#  - 1s - loss: 0.6749 - accuracy: 0.5805 - val_loss: 0.1198 - val_accuracy: 2.7245
#
# Epoch 00445: val_loss did not improve from 0.11418
# Epoch 446/1000
#  - 1s - loss: 0.6749 - accuracy: 0.5806 - val_loss: 0.1232 - val_accuracy: 2.6918
#
# Epoch 00446: val_loss did not improve from 0.11418
# Epoch 447/1000
#  - 1s - loss: 0.6750 - accuracy: 0.5804 - val_loss: 0.1231 - val_accuracy: 2.6970
#
# Epoch 00447: val_loss did not improve from 0.11418
# Epoch 448/1000
#  - 1s - loss: 0.6748 - accuracy: 0.5817 - val_loss: 0.1251 - val_accuracy: 2.6918
#
# Epoch 00448: val_loss did not improve from 0.11418
# Epoch 449/1000
#  - 1s - loss: 0.6749 - accuracy: 0.5813 - val_loss: 0.1223 - val_accuracy: 2.7090
#
# Epoch 00449: val_loss did not improve from 0.11418
# Epoch 450/1000
#  - 1s - loss: 0.6746 - accuracy: 0.5814 - val_loss: 0.1227 - val_accuracy: 2.7021
#
# Epoch 00450: val_loss did not improve from 0.11418
# Epoch 451/1000
#  - 1s - loss: 0.6747 - accuracy: 0.5801 - val_loss: 0.1212 - val_accuracy: 2.7348
#
# Epoch 00451: val_loss did not improve from 0.11418
# Epoch 452/1000
#  - 1s - loss: 0.6747 - accuracy: 0.5805 - val_loss: 0.1214 - val_accuracy: 2.7176
#
# Epoch 00452: val_loss did not improve from 0.11418
# Epoch 453/1000
#  - 1s - loss: 0.6745 - accuracy: 0.5819 - val_loss: 0.1196 - val_accuracy: 2.7914
#
# Epoch 00453: val_loss did not improve from 0.11418
# Epoch 454/1000
#  - 1s - loss: 0.6745 - accuracy: 0.5808 - val_loss: 0.1185 - val_accuracy: 2.8069
#
# Epoch 00454: val_loss did not improve from 0.11418
# Epoch 455/1000
#  - 1s - loss: 0.6745 - accuracy: 0.5819 - val_loss: 0.1169 - val_accuracy: 3.0129
#
# Epoch 00455: val_loss did not improve from 0.11418
# Epoch 456/1000
#  - 1s - loss: 0.6744 - accuracy: 0.5823 - val_loss: 0.1166 - val_accuracy: 3.1176
#
# Epoch 00456: val_loss did not improve from 0.11418
# Epoch 457/1000
#  - 1s - loss: 0.6744 - accuracy: 0.5817 - val_loss: 0.1183 - val_accuracy: 2.7966
#
# Epoch 00457: val_loss did not improve from 0.11418
# Epoch 458/1000
#  - 1s - loss: 0.6745 - accuracy: 0.5821 - val_loss: 0.1187 - val_accuracy: 2.7674
#
# Epoch 00458: val_loss did not improve from 0.11418
# Epoch 459/1000
#  - 1s - loss: 0.6745 - accuracy: 0.5808 - val_loss: 0.1192 - val_accuracy: 2.7777
#
# Epoch 00459: val_loss did not improve from 0.11418
# Epoch 460/1000
#  - 1s - loss: 0.6744 - accuracy: 0.5801 - val_loss: 0.1187 - val_accuracy: 2.8034
#
# Epoch 00460: val_loss did not improve from 0.11418
# Epoch 461/1000
#  - 1s - loss: 0.6743 - accuracy: 0.5818 - val_loss: 0.1179 - val_accuracy: 2.8824
#
# Epoch 00461: val_loss did not improve from 0.11418
# Epoch 462/1000
#  - 1s - loss: 0.6742 - accuracy: 0.5814 - val_loss: 0.1187 - val_accuracy: 2.8000
#
# Epoch 00462: val_loss did not improve from 0.11418
# Epoch 463/1000
#  - 1s - loss: 0.6741 - accuracy: 0.5825 - val_loss: 0.1168 - val_accuracy: 2.9991
#
# Epoch 00463: val_loss did not improve from 0.11418
# Epoch 464/1000
#  - 1s - loss: 0.6743 - accuracy: 0.5815 - val_loss: 0.1164 - val_accuracy: 3.1451
#
# Epoch 00464: val_loss did not improve from 0.11418
# Epoch 465/1000
#  - 1s - loss: 0.6740 - accuracy: 0.5819 - val_loss: 0.1161 - val_accuracy: 3.1863
#
# Epoch 00465: val_loss did not improve from 0.11418
# Epoch 466/1000
#  - 1s - loss: 0.6740 - accuracy: 0.5818 - val_loss: 0.1157 - val_accuracy: 3.2532
#
# Epoch 00466: val_loss did not improve from 0.11418
# Epoch 467/1000
#  - 1s - loss: 0.6740 - accuracy: 0.5822 - val_loss: 0.1156 - val_accuracy: 3.2069
#
# Epoch 00467: val_loss did not improve from 0.11418
# Epoch 468/1000
#  - 1s - loss: 0.6739 - accuracy: 0.5824 - val_loss: 0.1165 - val_accuracy: 3.0524
#
# Epoch 00468: val_loss did not improve from 0.11418
# Epoch 469/1000
#  - 1s - loss: 0.6738 - accuracy: 0.5829 - val_loss: 0.1169 - val_accuracy: 3.0455
#
# Epoch 00469: val_loss did not improve from 0.11418
# Epoch 470/1000
#  - 1s - loss: 0.6739 - accuracy: 0.5833 - val_loss: 0.1168 - val_accuracy: 3.1193
#
# Epoch 00470: val_loss did not improve from 0.11418
# Epoch 471/1000
#  - 1s - loss: 0.6739 - accuracy: 0.5827 - val_loss: 0.1160 - val_accuracy: 3.2429
#
# Epoch 00471: val_loss did not improve from 0.11418
# Epoch 472/1000
#  - 1s - loss: 0.6739 - accuracy: 0.5823 - val_loss: 0.1155 - val_accuracy: 3.2721
#
# Epoch 00472: val_loss did not improve from 0.11418
# Epoch 473/1000
#  - 1s - loss: 0.6736 - accuracy: 0.5826 - val_loss: 0.1150 - val_accuracy: 3.3459
#
# Epoch 00473: val_loss did not improve from 0.11418
# Epoch 474/1000
#  - 1s - loss: 0.6738 - accuracy: 0.5823 - val_loss: 0.1155 - val_accuracy: 3.2944
#
# Epoch 00474: val_loss did not improve from 0.11418
# test_result.shape : (3496, 2)
# y_test[:5] : [1 0 0 0 1]
# y_score[:5] : [[0.51416445]
#  [0.4047318 ]
#  [0.4092592 ]
#  [0.4256538 ]
#  [0.4461576 ]]
# y_test.shape : (3496, 1)
# y_score.shape : (3496, 1)
# len(y_test) : 3496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:708: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [2.0117359e-05, 2.0222766e-05, 2.346872e-05, 2.341754e-05, 2.4098115e-05, 2.409837e-05, 2.2186128e-05, 2.1144506e-05, 2.5064734e-05, 2.5072719e-05, 2.5537212e-05, 2.491124e-05, 2.362471e-05, 2.5519195e-05, 2.7487029e-05, 2.7655085e-05, 2.6986869e-05, 2.72499e-05, 2.637103e-05, 2.5416612e-05, 2.5099444e-05, 2.5064723e-05, 2.6014251e-05, 2.6637399e-05, 2.688023e-05, 2.6721866e-05, 2.684713e-05, 2.6839627e-05, 2.6102307e-05, 2.1065316e-05, 2.0922746e-05, 2.0296258e-05, 2.0582856e-05, 1.9867113e-05, 2.0607045e-05, 2.0501908e-05, 2.0083431e-05, 1.9423818e-05, 1.9735578e-05, 2.011894e-05, 1.8916624e-05, 1.8841105e-05, 1.9128249e-05, 1.8943872e-05, 1.9265708e-05, 1.9183064e-05, 1.9005403e-05, 1.952843e-05, 1.9599758e-05, 2.0064566e-05, 1.9554442e-05, 2.0005558e-05, 1.996197e-05, 1.9868508e-05, 2.0146035e-05, 2.0645373e-05, 2.0925438e-05, 2.1846747e-05, 2.2445985e-05, 2.2487693e-05, 2.2636576e-05, 2.2930892e-05, 2.324267e-05, 2.2818223e-05, 2.25911e-05, 2.4786945e-05, 2.539215e-05, 2.4102765e-05, 2.3826444e-05, 2.3402736e-05, 2.3717648e-05, 2.3459968e-05, 2.2517392e-05, 2.3179638e-05, 2.3189767e-05, 2.339562e-05, 2.3547822e-05, 2.3510098e-05, 2.3307413e-05, 2.247668e-05, 2.1700662e-05, 2.1931912e-05, 2.1253745e-05, 2.275708e-05, 2.0934345e-05, 2.0872336e-05, 2.1399082e-05, 2.0172396e-05, 2.0406087e-05, 2.4219698e-05, 2.4285851e-05, 2.163443e-05, 2.0597083e-05, 2.0605688e-05, 2.120466e-05, 2.1256115e-05, 2.1270325e-05, 2.1855976e-05, 2.1993897e-05, 2.2107924e-05, 2.143621e-05, 2.1718055e-05, 2.2302069e-05, 2.3020164e-05, 2.3208497e-05, 2.3555496e-05, 2.3399298e-05, 2.4105517e-05, 2.476971e-05, 2.5379362e-05, 2.4704905e-05, 2.35677e-05, 2.3391945e-05, 2.4111754e-05, 2.4378916e-05, 2.5142108e-05, 2.3498613e-05, 2.3045299e-05, 2.3233455e-05, 2.489071e-05, 2.5687039e-05, 2.7317963e-05, 2.7565555e-05, 2.7581937e-05, 2.7044345e-05, 2.7518467e-05, 2.6663563e-05, 2.6094383e-05, 2.6571379e-05, 2.674479e-05, 2.5879724e-05, 2.5917388e-05, 2.2541053e-05, 2.3000981e-05, 2.3884784e-05, 2.4191067e-05, 2.4356916e-05, 2.452946e-05, 2.4559666e-05, 2.5119623e-05, 2.5349065e-05, 2.5085932e-05, 2.4483536e-05, 2.5566425e-05, 2.613817e-05, 2.6390351e-05, 2.667041e-05, 2.6714928e-05, 2.7133048e-05, 2.7214683e-05, 2.732472e-05, 2.629382e-05, 2.5763939e-05, 2.5656176e-05, 2.606936e-05, 2.598771e-05, 2.4182284e-05, 2.41961e-05, 2.466404e-05, 2.4763105e-05, 2.5309228e-05, 2.4808494e-05, 2.5007696e-05, 2.4973026e-05, 2.5372596e-05, 2.7211348e-05, 2.609575e-05, 2.6118243e-05, 2.6125997e-05, 2.628824e-05, 2.6606805e-05, 2.6578231e-05, 2.6890799e-05, 2.7760401e-05, 2.6789869e-05, 2.7087737e-05, 2.6955368e-05, 2.7214228e-05, 2.535867e-05, 2.5770669e-05, 2.486651e-05, 2.4890078e-05, 2.5489011e-05, 2.5973546e-05, 2.760963e-05, 2.797917e-05, 2.7891672e-05, 2.7763626e-05, 2.9219105e-05, 2.821179e-05, 2.817123e-05, 2.7034552e-05, 2.7237902e-05, 2.7068116e-05, 2.7832104e-05, 3.0064457e-05, 2.9362325e-05, 3.1346273e-05, 3.091815e-05, 3.0406649e-05, 3.030047e-05, 3.0445803e-05, 2.987786e-05, 2.5922234e-05, 2.6712976e-05, 2.7486876e-05, 2.7245254e-05, 2.7904201e-05, 2.856023e-05, 2.7603433e-05, 2.7698665e-05, 2.7625394e-05, 2.7648155e-05, 2.7842147e-05, 3.015001e-05, 3.0200745e-05, 3.0673214e-05, 3.0189076e-05, 2.9753188e-05, 2.9906623e-05, 3.0243471e-05, 3.004717e-05, 3.0329471e-05, 3.0152258e-05, 2.9169081e-05, 2.9744466e-05, 2.9480729e-05, 2.9504004e-05, 2.9173738e-05, 2.9125214e-05, 2.9054903e-05, 2.8835902e-05, 3.0886295e-05, 3.09261e-05, 3.0654966e-05, 3.082101e-05, 3.1002386e-05, 3.0301851e-05, 3.1003583e-05, 3.124767e-05, 3.1831383e-05, 3.1934105e-05, 3.2538333e-05, 3.2664484e-05, 3.201989e-05, 3.2211312e-05, 3.24644e-05, 3.2796095e-05, 3.033686e-05, 2.9069195e-05, 2.9530716e-05, 2.9590543e-05, 2.9834433e-05, 2.9366287e-05, 2.8902086e-05, 2.8995388e-05, 2.9274459e-05, 3.0123601e-05, 2.8493296e-05, 2.7955586e-05, 2.8194108e-05, 2.8695986e-05, 2.8874785e-05, 2.900552e-05, 2.9754932e-05, 2.964626e-05, 3.1320844e-05, 3.1668016e-05, 3.188657e-05, 3.118708e-05 ...

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %% [markdown]
# ### **Training**

# %%
org_x_test = x_test
org_y_test = y_test
org_pr_test = pr_test

# %%
x_test = org_x_test
y_test = org_y_test
pr_test = org_pr_test

# %%
concat_x = np.vstack((org_x_test, new_input_x))
concat_y = np.vstack((org_y_test, np.where(new_input_pr > 1, 1, 0)))
concat_pr = np.vstack((org_pr_test, new_input_pr))

# %%
x_test = new_input_x
y_test = np.where(new_input_pr > 1, 1, 0)
pr_test = new_input_pr

# %%
# print(pred_pr_list)
for pr in pred_pr_list:
  if pr != 1:
    print(pr)

# %%
plt.figure(figsize=(50, 5))
plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test):len(org_pr_test) + 10])
# plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test) - 10:len(org_pr_test) + 10])
plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
# plt.axvline(len(org_pr_test), linestyle='--', color='r')
plt.show()

# %%
# plt.show()
# plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
