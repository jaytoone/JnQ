# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install h5py==2.10.0

# !pip install tensorflow==2.1.0
# !pip install keras==2.4.1

# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %%
# %tensorflow_version 1.x

import tensorflow as tf
tf.__version__
# Out:
# '2.1.0'

# %%
import keras
keras.__version__
from tensorflow.keras.utils import np_utils

# %% [markdown]
# ### load file list

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### custom model

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import tensorflow as tf
import keras

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

# from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    # net = layers.Conv2D(32, kernel_size=3, padding='same')(visible)
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    net = layers.LeakyReLU()(net)
    # net = layers.BatchNormalization()(net)


    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.BatchNormalization()(net)


    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model

# %%
print(tf.__version__)
print(keras.__version__)
# Out:
# 1.15.2
# 2.3.1

# %% [markdown]
# ### all in one loop

# %%
print(ohlcv['close'].pct_change().head())
print(ohlcv['close'] / ohlcv['close'].shift(1).head() - 1)

# %%
# from tensorflow.keras.utils import to_categorical

# %%
from funcs_indicator import *
import matplotlib.pyplot as plt

# import mpl_finance as mf


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None


#           load saved npy & trained model        #
load_npy = True
load_model = False


seed = 1
random_state = 201
np.random.seed(seed)

fee = 0.0006
lvrg = 5

for i in range(len(candis)):

  keys = [candis[i]]

  if 'kava'.upper() not in candis[i]:
    continue

  # if 'comp'.upper() not in candis[i]:
  #   continue

  for key in keys:  
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))

        
    #       long      #
    pr = (ohlcv['close'].pct_change() - fee) * lvrg + 1    

    #       long liqudation     #
    lq = (ohlcv['low'] / ohlcv['close'].shift(1) - fee - 1) * lvrg + 1

    #       short       # <-- 이거를 단순히 minus 를 붙여도 되는걸까
    s_pr = (-ohlcv['close'].pct_change() - fee) * lvrg + 1

    #       short liqudation     #
    # s_lq = (ohlcv['high'] / ohlcv['close'].shift(1) - fee) * lvrg + 1
    

    #       fill na with 1.0      #
    # pr = np.where(np.isnan(pr), 1, pr)
    # print(len(pr))
    # print("len(pr[np.isnan(pr)]) :", len(pr[np.isnan(pr)]))
    # print("np.sum(np.isnan(pr)) :", np.sum(np.isnan(pr)))
    
    # sliced_ohlcv = ohlcv[np.sum(np.isnan(pr))]
    # print(sliced_ohlcv.head())
    # break
    # s_pr = np.where(np.isnan(s_pr), 1, pr)
    # lq = np.where(np.isnan(lq), 1, lq)


    #       set lq      #
    # pr = np.where((pr != 1) & (lq <= 0), 0, pr)

    # print("len(pr[pr < 0]) :", len(pr[pr < 0]))
    # break

    org_wr = len(pr[pr > 1]) / len(pr[pr != 1])

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(pr))
    plt.title("%s\norg_wr : %.3f\n acc_pr : %.3f" % (key, org_wr, np.cumprod(pr)[-1]))


    #                    strat                   #

    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) < ohlcv['close'].shift(3)), pr, 1)


    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
    #                     (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
    #                     (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)), pr, 1)


    strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
                        (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
                        (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
                        (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)) & 
                        (ohlcv['close'].shift(5) < ohlcv['close'].shift(6)), pr, 1)
    
    # strat_pr = np.where((ohlcv['high'].shift(2) > ohlcv['high'].shift(3))& 
    #                     (ohlcv['close'].shift(1) > ohlcv['close'].shift(2)), pr, 1)


    wr = len(strat_pr[strat_pr > 1]) / len(strat_pr[strat_pr != 1])

    plt.subplot(122)
    plt.plot(np.cumprod(strat_pr))
    plt.title("%s\norg_wr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr, np.cumprod(strat_pr)[-1]))


    # #                  sl cut                #
    # sl_line = ohlcv['low'].rolling(250).min().shift(1)
    # # sl_line = ohlcv['low'].shift(1)

    # strat_pr_sl = np.where((strat_pr != 1) & (sl_line > ohlcv['low']), 
    #                      1 + lvrg * (sl_line / ohlcv['close'].shift(1) - 1 - fee), strat_pr)


    # wr_sl = len(strat_pr_sl[strat_pr_sl > 1]) / len(strat_pr_sl[strat_pr_sl != 1])
    # # wl_pr_ratio = np.mean(strat_pr[strat_pr > 1]) / np.mean(strat_pr[strat_pr < 1])
    # # wl_pr_ratio = np.cumprod(strat_pr[strat_pr > 1])[-1] / np.cumprod(strat_pr[strat_pr < 1])[-1]

    # plt.subplot(122)
    # plt.plot(np.cumprod(strat_pr_sl))
    # plt.title("%s\norg_pr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr_sl, np.cumprod(strat_pr_sl)[-1]))


    plt.show()
    # break

    period = 45
    symbol_name = key.split(' ')[1].split('.')[0]      

    x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_fvol_%s_tssplit.npy' % (period, symbol_name)
    pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_fvol_%s_tssplit.npy' % (period, symbol_name)
    index_save_path = current_path + 'npy/' + '%s_cnn_updown_index_train_rascend_ohlcv_fvol_%s_tssplit.npy' % (period, symbol_name)



    if not load_npy:

      from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
      from sklearn.model_selection import train_test_split
      from datetime import datetime

      from funcs_indicator import *

      def min_max_scale(npy_x):

        return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[np.sum(np.isnan(pr)):]

      sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

      #       scale with price    #
      ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

      ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
      sar = lucid_sar(sliced_ohlcv)
      ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
      senkou1, senkou2 = ichimoku(sliced_ohlcv)

      #     min max scale   #
      # vol = ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]
      vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

      pr_list = pr[np.sum(np.isnan(pr)):]
      print("len(ohlc) :", len(ohlc))
      print("len(pr_list) :", len(pr_list))

      print("ohlc.index[0] :", ohlc.index[0])
      print("vol.index[0] :", vol.index[0])
      # break


      #       set params    #
      period = 45
      key_i = i

      plotting = True

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(ohlc)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          # temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

          temp_close = min_max_scale(temp_ohlc[:, [3]])    

          price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          ind_temp_ohlc = min_max_scale(temp_ohlc)
          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


          if plotting:

            plt.plot(ind_temp_ohlc)
            plt.show()
            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          #                   feature selection                   #        
          temp_data = np.hstack((ind_temp_ohlc, temp_vol))

          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          # temp_data = temp_ohlc[:, [3]]
          # temp_data = ind_temp_ohlc[:, [3]]
          # temp_data = temp_close

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      # input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)


      # _, row, col, _ = input_x.shape
      # _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      #                 don't shuffle timeseries data                 #
      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)


      np.save(x_save_path, x_train)
      np.save(x_save_path.replace('x_train', 'x_val'), x_val)
      np.save(x_save_path.replace('x_train', 'x_test'), x_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('x series saved !')

      np.save(pr_save_path, pr_train)
      np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
      np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
      # np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
      print('pr series saved !')
      
      np.save(index_save_path, index_train)
      np.save(index_save_path.replace('index_train', 'index_val'), index_val)
      np.save(index_save_path.replace('index_train', 'index_test'), index_test)
      print('index series saved !')

    else:
      
      x_train = np.load(x_save_path)
      x_val = np.load(x_save_path.replace('x_train', 'x_val'))
      x_test = np.load(x_save_path.replace('x_train', 'x_test'))
      print('x series loaded !')


      pr_train = np.load(pr_save_path)
      pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
      pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
      print('y series loaded !')


      index_train = np.load(index_save_path, allow_pickle=True)
      index_val = np.load(index_save_path.replace('index_train', 'index_val'), allow_pickle=True)
      index_test = np.load(index_save_path.replace('index_train', 'index_test'), allow_pickle=True)
      print('index series loaded !')




    #       pr_thresh by percentage 0.285     #
    plt.plot(pr)
    plt.show()
    
    sorted_pr = sorted(pr, reverse=True)
    pct = 0.285
    len_pct = int(len(pr) * pct)
    pr_thresh = sorted_pr[len_pct]
    print("pr_thresh :", pr_thresh)

    # from tensorflow.keras.utils import np_utils
    # from keras.utils import to_categorical
    from keras.utils.np_utils import to_categorical

    from sklearn.utils import class_weight


    def class_ratio(in_list):

      return in_list / in_list[1]
      
    y_train = np.where(pr_train > pr_thresh, 1, 0)
    y_test = np.where(pr_test > pr_thresh, 1, 0)
    y_val = np.where(pr_val > pr_thresh, 1, 0)

    print('x_train.shape :', x_train.shape)
    print('x_test.shape :', x_test.shape)
    print('x_val.shape :', x_val.shape)
    print('y_train.shape :', y_train.shape)
    print('y_test.shape :', y_test.shape)
    print('y_val.shape :', y_val.shape)

    # try:
    print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
    print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
    print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

    # except Exception as e:
      # print(e)

    label = y_train.reshape(-1, )
    class_weights = class_weight.compute_class_weight('balanced', 
                                                        classes=np.unique(label),
                                                        y=label)
    class_weights = dict(enumerate(class_weights))
    print('class_weights :', class_weights)

    # sample_weight = np.ones(shape=(len(y_train),))
    # sample_weight[(y_train == 1).reshape(-1,)] = 1.5
    # print('sample_weight[:20] :', sample_weight[:20])


    print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
    print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
    print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

    print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
    print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
    print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

    num_classes = 2
    
    # y_train_ohe = np_utils.to_categorical(y_train, num_classes)
    # y_val_ohe = np_utils.to_categorical(y_val, num_classes)
    # y_test_ohe = np_utils.to_categorical(y_test, num_classes)
    
    y_train_ohe = to_categorical(y_train, num_classes)
    y_val_ohe = to_categorical(y_val, num_classes)
    y_test_ohe = to_categorical(y_test, num_classes)
    print('y_train_ohe.shape :', y_train_ohe.shape)
    print('y_val_ohe.shape :', y_val_ohe.shape)
    print('y_test_ohe.shape :', y_test_ohe.shape)

    from keras.preprocessing.image import ImageDataGenerator 
    # from tensorflow.keras.preprocessing.image import ImageDataGenerator 

    datagen = ImageDataGenerator( 
        # rotation_range = 45,
        # zoom_range = 0.5,
        # shear_range = 0.5,
        # horizontal_flip = True,
        # vertical_flip = True,
        # width_shift_range=0.5,
        # height_shift_range=0.5,
        # fill_mode = 'nearest'
        )

    valgen = ImageDataGenerator( 
        )

    datagen.fit(x_train)
    valgen.fit(x_val)


    batch_size = 512


    for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

        plt.suptitle("train x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break

    for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

        plt.suptitle("val x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break
        
    train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
    val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
    # break

    

    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'

    # batch_size = 512

    K.clear_session()


    # model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_tf250_%s_tvnon_shuffle.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_tf241_%s_tvnon_shuffle.h5' % (period, symbol_name)
    model_name = 'classifier_%s_cnn_updown_rascend_%s_tf115_lrcheck_%s.h5' % (period, int(pct * 1000), symbol_name)



    if not load_model:

      # from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
      from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

      model = FER_Model(input_shape=x_train.shape[1:])
      # opt = Adam(lr=1e-5, decay=5e-6)
      opt = Adam( learning_rate=1e-5, decay=5e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-7)

      # opt = Adam(lr=0.001, decay=0.0005)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir=board_path,
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_loss', patience=500)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]
      # callbacks_list = [checkpoint, checkpoint2]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 2000
      history = model.fit_generator(train_flow, 
                          steps_per_epoch=len(x_train) / batch_size, 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=val_flow,  
                          validation_steps=len(x_val) / batch_size,
                          shuffle=False)
      
    
    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'


    model = keras.models.load_model(ckpt_path + model_name)

    test_result = model.predict(x_test)
    # test_result = model.predict(test_set)

    print('test_result.shape :', test_result.shape)
    # print('pr_val.shape :', pr_val.shape)

    y_score = test_result[:, [1]]
    print('y_test[:5] :', y_test.reshape(-1,)[:5])
    # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
    print('y_score[:5] :', y_score[:5])
    # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

    print('y_test.shape :', y_test.shape)
    print('y_score.shape :', y_score.shape)

    print('len(y_test) :', len(y_test))

    #     precision recall curve   #
    precision, recall, threshold = precision_recall_curve(y_test, y_score)
    precision, recall = precision[:-1], recall[:-1]

    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    plt.show()
    # print(y_pred)


    # threshold = [0.65]
    # print('threshold :', threshold)
    # break

    acc_pr_bythr = []
    new_thresh = []
    temp_pr_list = []


    for thresh in threshold:
      
      # if thresh < 0.5:
      #     continue

      y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
      # print('y_pred.shape :', y_pred.shape)
      # print('y_pred :', y_pred)

      #     compare precision     #

      # print('precision :', precision_score(y_test, y_pred))
      # print('recall :', recall_score(y_test, y_pred))
      # print()

      # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
      # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

      # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
      # # plt.show()  
      # print()

      #     check win-ratio improvement     #
      cmat = confusion_matrix(y_test, y_pred)
      # print(cmat)
      # print(np.sum(cmat, axis=1))

      test_size = len(y_test)
      test_pr_list = pr_test
      # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

      org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
      ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
      # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

      # print('pr_test.shape :', pr_test.shape)

      # print(y_pred)
      # print(test_pr_list)

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
      # print('pred_pr_list.shape :', pred_pr_list.shape)

      temp_pr_list.append(pred_pr_list)


      # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
      #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
      #   print('thresh :', thresh)
        
      # if len(threshold) == 1:
    #   plt.figure(figsize=(10, 5))
    #   plt.subplot(121)
    #   plt.plot(np.cumprod(test_pr_list))
    #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
    # # plt.show()

    #   plt.subplot(122)
    #   plt.plot(np.cumprod(pred_pr_list))
    #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
    #   plt.show()


      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)


    print('acc_pr_bythr :', acc_pr_bythr)

    plt.figure(figsize=(13, 5))
    plt.subplot(131)
    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    # plt.show()
    plt.subplot(132)
    plt.plot(new_thresh, acc_pr_bythr)
    plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')

    best_thr = new_thresh[np.argmax(acc_pr_bythr)]
    plt.axvline(best_thr, linestyle='--', color='r')
    plt.title(symbol_name + '\n' + str(best_thr))

    plt.subplot(133)
    plt.plot(np.cumprod(temp_pr_list[np.argmax(acc_pr_bythr)]))

    plt.show()
# Out:
# start_stamp : 0
# len(ohlcv) : 13120
# x series loaded !
# y series loaded !
# index series loaded !
# pr_thresh : 1.0263973542381188
# x_train.shape : (7798, 45, 5, 3)
# x_test.shape : (2600, 45, 5, 3)
# x_val.shape : (2600, 45, 5, 3)
# y_train.shape : (7798, 1)
# y_test.shape : (2600, 1)
# y_val.shape : (2600, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([5541, 2257])) [2.4550288 1.       ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([1887,  713])) [2.64656381 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([1862,  738])) [2.52303523 1.        ]
# class_weights : {0: 0.7036635986284064, 1: 1.727514399645547}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (7798, 2)
# y_val_ohe.shape : (2600, 2)
# y_test_ohe.shape : (2600, 2)
# Epoch 1/2000
#  - 1s - loss: 0.8417 - accuracy: 0.5024 - val_loss: 0.6194 - val_accuracy: 0.6258
#
# Epoch 00001: val_loss improved from inf to 0.61944, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf115_lrcheck_KAVAUSDT.h5
# Epoch 2/2000
#  - 1s - loss: 0.7222 - accuracy: 0.4932 - val_loss: 0.7523 - val_accuracy: 0.4408
#
# Epoch 00002: val_loss did not improve from 0.61944
# Epoch 3/2000
#  - 1s - loss: 0.6960 - accuracy: 0.5186 - val_loss: 0.6777 - val_accuracy: 0.5881
#
# Epoch 00003: val_loss did not improve from 0.61944
# Epoch 4/2000
#  - 1s - loss: 0.6795 - accuracy: 0.5873 - val_loss: 0.6587 - val_accuracy: 0.6050
#
# Epoch 00004: val_loss did not improve from 0.61944
# Epoch 5/2000
#  - 1s - loss: 0.6677 - accuracy: 0.5913 - val_loss: 0.7085 - val_accuracy: 0.5919
#
# Epoch 00005: val_loss did not improve from 0.61944
# Epoch 6/2000
#  - 1s - loss: 0.6618 - accuracy: 0.5896 - val_loss: 0.6860 - val_accuracy: 0.5969
#
# Epoch 00006: val_loss did not improve from 0.61944
# Epoch 7/2000
#  - 1s - loss: 0.6545 - accuracy: 0.6294 - val_loss: 0.6547 - val_accuracy: 0.5592
#
# Epoch 00007: val_loss did not improve from 0.61944
# Epoch 8/2000
#  - 1s - loss: 0.6548 - accuracy: 0.5986 - val_loss: 0.6434 - val_accuracy: 0.6223
#
# Epoch 00008: val_loss did not improve from 0.61944
# Epoch 9/2000
#  - 1s - loss: 0.6380 - accuracy: 0.6298 - val_loss: 0.6756 - val_accuracy: 0.6058
#
# Epoch 00009: val_loss did not improve from 0.61944
# Epoch 10/2000
#  - 1s - loss: 0.6304 - accuracy: 0.6565 - val_loss: 0.6857 - val_accuracy: 0.5781
#
# Epoch 00010: val_loss did not improve from 0.61944
# Epoch 11/2000
#  - 1s - loss: 0.6258 - accuracy: 0.6550 - val_loss: 0.6666 - val_accuracy: 0.5415
#
# Epoch 00011: val_loss did not improve from 0.61944
# Epoch 12/2000
#  - 1s - loss: 0.6223 - accuracy: 0.6634 - val_loss: 0.7381 - val_accuracy: 0.4465
#
# Epoch 00012: val_loss did not improve from 0.61944
# Epoch 13/2000
#  - 1s - loss: 0.6111 - accuracy: 0.6484 - val_loss: 0.6369 - val_accuracy: 0.6081
#
# Epoch 00013: val_loss did not improve from 0.61944
# Epoch 14/2000
#  - 1s - loss: 0.6088 - accuracy: 0.6740 - val_loss: 0.6805 - val_accuracy: 0.5592
#
# Epoch 00014: val_loss did not improve from 0.61944
# Epoch 15/2000
#  - 1s - loss: 0.6008 - accuracy: 0.6836 - val_loss: 0.7558 - val_accuracy: 0.4073
#
# Epoch 00015: val_loss did not improve from 0.61944
# Epoch 16/2000
#  - 1s - loss: 0.5997 - accuracy: 0.6854 - val_loss: 0.7738 - val_accuracy: 0.4335
#
# Epoch 00016: val_loss did not improve from 0.61944
# Epoch 17/2000
#  - 1s - loss: 0.5851 - accuracy: 0.7011 - val_loss: 0.7524 - val_accuracy: 0.4665
#
# Epoch 00017: val_loss did not improve from 0.61944
# Epoch 18/2000
#  - 1s - loss: 0.5861 - accuracy: 0.6936 - val_loss: 0.6802 - val_accuracy: 0.4558
#
# Epoch 00018: val_loss did not improve from 0.61944
# Epoch 19/2000
#  - 1s - loss: 0.5708 - accuracy: 0.7161 - val_loss: 0.7294 - val_accuracy: 0.4492
#
# Epoch 00019: val_loss did not improve from 0.61944
# Epoch 20/2000
#  - 1s - loss: 0.5638 - accuracy: 0.7139 - val_loss: 0.7216 - val_accuracy: 0.4919
#
# Epoch 00020: val_loss did not improve from 0.61944
# Epoch 21/2000
#  - 1s - loss: 0.5582 - accuracy: 0.7308 - val_loss: 0.6659 - val_accuracy: 0.5177
#
# Epoch 00021: val_loss did not improve from 0.61944
# Epoch 22/2000
#  - 1s - loss: 0.5509 - accuracy: 0.7345 - val_loss: 0.6843 - val_accuracy: 0.5600
#
# Epoch 00022: val_loss did not improve from 0.61944
# Epoch 23/2000
#  - 1s - loss: 0.5415 - accuracy: 0.7458 - val_loss: 0.6109 - val_accuracy: 0.5738
#
# Epoch 00023: val_loss improved from 0.61944 to 0.61087, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf115_lrcheck_KAVAUSDT.h5
# Epoch 24/2000
#  - 1s - loss: 0.5413 - accuracy: 0.7435 - val_loss: 0.7024 - val_accuracy: 0.5258
#
# Epoch 00024: val_loss did not improve from 0.61087
# Epoch 25/2000
#  - 1s - loss: 0.5360 - accuracy: 0.7478 - val_loss: 0.7683 - val_accuracy: 0.4865
#
# Epoch 00025: val_loss did not improve from 0.61087
# Epoch 26/2000
#  - 1s - loss: 0.5249 - accuracy: 0.7565 - val_loss: 0.7939 - val_accuracy: 0.5400
#
# Epoch 00026: val_loss did not improve from 0.61087
# Epoch 27/2000
#  - 1s - loss: 0.5180 - accuracy: 0.7664 - val_loss: 0.6943 - val_accuracy: 0.5435
#
# Epoch 00027: val_loss did not improve from 0.61087
# Epoch 28/2000
#  - 1s - loss: 0.5079 - accuracy: 0.7703 - val_loss: 0.6717 - val_accuracy: 0.5435
#
# Epoch 00028: val_loss did not improve from 0.61087
# Epoch 29/2000
#  - 1s - loss: 0.5061 - accuracy: 0.7733 - val_loss: 0.8920 - val_accuracy: 0.4592
#
# Epoch 00029: val_loss did not improve from 0.61087
# Epoch 30/2000
#  - 1s - loss: 0.4977 - accuracy: 0.7839 - val_loss: 0.8559 - val_accuracy: 0.4981
#
# Epoch 00030: val_loss did not improve from 0.61087
# Epoch 31/2000
#  - 1s - loss: 0.4889 - accuracy: 0.7847 - val_loss: 0.7879 - val_accuracy: 0.5177
#
# Epoch 00031: val_loss did not improve from 0.61087
# Epoch 32/2000
#  - 1s - loss: 0.4871 - accuracy: 0.7889 - val_loss: 0.6649 - val_accuracy: 0.5554
#
# Epoch 00032: val_loss did not improve from 0.61087
# Epoch 33/2000
#  - 1s - loss: 0.4723 - accuracy: 0.8052 - val_loss: 0.6382 - val_accuracy: 0.5404
#
# Epoch 00033: val_loss did not improve from 0.61087
# Epoch 34/2000
#  - 1s - loss: 0.4696 - accuracy: 0.8028 - val_loss: 0.7724 - val_accuracy: 0.6338
#
# Epoch 00034: val_loss did not improve from 0.61087
# Epoch 35/2000
#  - 1s - loss: 0.4760 - accuracy: 0.7926 - val_loss: 0.7131 - val_accuracy: 0.5931
#
# Epoch 00035: val_loss did not improve from 0.61087
# Epoch 36/2000
#  - 1s - loss: 0.4532 - accuracy: 0.8202 - val_loss: 0.5541 - val_accuracy: 0.5331
#
# Epoch 00036: val_loss improved from 0.61087 to 0.55409, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf115_lrcheck_KAVAUSDT.h5
# Epoch 37/2000
#  - 1s - loss: 0.4450 - accuracy: 0.8328 - val_loss: 0.7022 - val_accuracy: 0.5796
#
# Epoch 00037: val_loss did not improve from 0.55409
# Epoch 38/2000
#  - 1s - loss: 0.4379 - accuracy: 0.8348 - val_loss: 0.6779 - val_accuracy: 0.6015
#
# Epoch 00038: val_loss did not improve from 0.55409
# Epoch 39/2000
#  - 1s - loss: 0.4317 - accuracy: 0.8392 - val_loss: 0.8090 - val_accuracy: 0.5469
#
# Epoch 00039: val_loss did not improve from 0.55409
# Epoch 40/2000
#  - 1s - loss: 0.4317 - accuracy: 0.8270 - val_loss: 0.5733 - val_accuracy: 0.6254
#
# Epoch 00040: val_loss did not improve from 0.55409
# Epoch 41/2000
#  - 1s - loss: 0.4152 - accuracy: 0.8552 - val_loss: 0.6772 - val_accuracy: 0.5677
#
# Epoch 00041: val_loss did not improve from 0.55409
# Epoch 42/2000
#  - 1s - loss: 0.4153 - accuracy: 0.8462 - val_loss: 0.8033 - val_accuracy: 0.5331
#
# Epoch 00042: val_loss did not improve from 0.55409
# Epoch 43/2000
#  - 1s - loss: 0.4098 - accuracy: 0.8451 - val_loss: 0.7615 - val_accuracy: 0.6062
#
# Epoch 00043: val_loss did not improve from 0.55409
# Epoch 44/2000
#  - 1s - loss: 0.4003 - accuracy: 0.8587 - val_loss: 0.7460 - val_accuracy: 0.5708
#
# Epoch 00044: val_loss did not improve from 0.55409
# Epoch 45/2000
#  - 1s - loss: 0.3913 - accuracy: 0.8614 - val_loss: 0.8293 - val_accuracy: 0.5650
#
# Epoch 00045: val_loss did not improve from 0.55409
# Epoch 46/2000
#  - 1s - loss: 0.3903 - accuracy: 0.8570 - val_loss: 0.5694 - val_accuracy: 0.6358
#
# Epoch 00046: val_loss did not improve from 0.55409
# Epoch 47/2000
#  - 1s - loss: 0.3828 - accuracy: 0.8636 - val_loss: 0.6890 - val_accuracy: 0.5550
#
# Epoch 00047: val_loss did not improve from 0.55409
# Epoch 48/2000
#  - 1s - loss: 0.3824 - accuracy: 0.8564 - val_loss: 0.5240 - val_accuracy: 0.6108
#
# Epoch 00048: val_loss improved from 0.55409 to 0.52396, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf115_lrcheck_KAVAUSDT.h5
# Epoch 49/2000
#  - 1s - loss: 0.3694 - accuracy: 0.8768 - val_loss: 0.6100 - val_accuracy: 0.6327
#
# Epoch 00049: val_loss did not improve from 0.52396
# Epoch 50/2000
#  - 1s - loss: 0.3668 - accuracy: 0.8737 - val_loss: 0.6277 - val_accuracy: 0.5996
#
# Epoch 00050: val_loss did not improve from 0.52396
# Epoch 51/2000
#  - 1s - loss: 0.3605 - accuracy: 0.8709 - val_loss: 0.9128 - val_accuracy: 0.5781
#
# Epoch 00051: val_loss did not improve from 0.52396
# Epoch 52/2000
#  - 1s - loss: 0.3500 - accuracy: 0.8843 - val_loss: 0.8195 - val_accuracy: 0.6342
#
# Epoch 00052: val_loss did not improve from 0.52396
# Epoch 53/2000
#  - 1s - loss: 0.3450 - accuracy: 0.8923 - val_loss: 0.7540 - val_accuracy: 0.5538
#
# Epoch 00053: val_loss did not improve from 0.52396
# Epoch 54/2000
#  - 1s - loss: 0.3430 - accuracy: 0.8843 - val_loss: 0.6720 - val_accuracy: 0.5635
#
# Epoch 00054: val_loss did not improve from 0.52396
# Epoch 55/2000
#  - 1s - loss: 0.3301 - accuracy: 0.9015 - val_loss: 0.5545 - val_accuracy: 0.5888
#
# Epoch 00055: val_loss did not improve from 0.52396
# Epoch 56/2000
#  - 1s - loss: 0.3263 - accuracy: 0.8961 - val_loss: 0.5275 - val_accuracy: 0.6604
#
# Epoch 00056: val_loss did not improve from 0.52396
# Epoch 57/2000
#  - 1s - loss: 0.3205 - accuracy: 0.9068 - val_loss: 0.6622 - val_accuracy: 0.6312
#
# Epoch 00057: val_loss did not improve from 0.52396
# Epoch 58/2000
#  - 1s - loss: 0.3127 - accuracy: 0.9160 - val_loss: 0.7922 - val_accuracy: 0.6254
#
# Epoch 00058: val_loss did not improve from 0.52396
# Epoch 59/2000
#  - 1s - loss: 0.3115 - accuracy: 0.9105 - val_loss: 0.8429 - val_accuracy: 0.6081
#
# Epoch 00059: val_loss did not improve from 0.52396
# Epoch 60/2000
#  - 1s - loss: 0.3076 - accuracy: 0.9137 - val_loss: 0.8202 - val_accuracy: 0.5665
#
# Epoch 00060: val_loss did not improve from 0.52396
# Epoch 61/2000
#  - 1s - loss: 0.3026 - accuracy: 0.9113 - val_loss: 0.6877 - val_accuracy: 0.5869
#
# Epoch 00061: val_loss did not improve from 0.52396
# Epoch 62/2000
#  - 1s - loss: 0.2916 - accuracy: 0.9247 - val_loss: 1.0258 - val_accuracy: 0.6208
#
# Epoch 00062: val_loss did not improve from 0.52396
# Epoch 63/2000
#  - 1s - loss: 0.2855 - accuracy: 0.9281 - val_loss: 0.9952 - val_accuracy: 0.6181
#
# Epoch 00063: val_loss did not improve from 0.52396
# Epoch 64/2000
#  - 1s - loss: 0.2846 - accuracy: 0.9299 - val_loss: 0.9661 - val_accuracy: 0.6458
#
# Epoch 00064: val_loss did not improve from 0.52396
# Epoch 65/2000
#  - 1s - loss: 0.2786 - accuracy: 0.9259 - val_loss: 0.6956 - val_accuracy: 0.6412
#
# Epoch 00065: val_loss did not improve from 0.52396
# Epoch 66/2000
#  - 1s - loss: 0.2752 - accuracy: 0.9347 - val_loss: 0.6350 - val_accuracy: 0.6158
#
# Epoch 00066: val_loss did not improve from 0.52396
# Epoch 67/2000
#  - 1s - loss: 0.2697 - accuracy: 0.9311 - val_loss: 0.9106 - val_accuracy: 0.6181
#
# Epoch 00067: val_loss did not improve from 0.52396
# Epoch 68/2000
#  - 1s - loss: 0.2627 - accuracy: 0.9375 - val_loss: 0.9450 - val_accuracy: 0.6242
#
# Epoch 00068: val_loss did not improve from 0.52396
# Epoch 69/2000
#  - 1s - loss: 0.2568 - accuracy: 0.9465 - val_loss: 0.8366 - val_accuracy: 0.6115
#
# Epoch 00069: val_loss did not improve from 0.52396
# Epoch 70/2000
#  - 1s - loss: 0.2525 - accuracy: 0.9425 - val_loss: 0.7027 - val_accuracy: 0.6285
#
# Epoch 00070: val_loss did not improve from 0.52396
# Epoch 71/2000
#  - 1s - loss: 0.2536 - accuracy: 0.9402 - val_loss: 0.7577 - val_accuracy: 0.5738
#
# Epoch 00071: val_loss did not improve from 0.52396
# Epoch 72/2000
#  - 1s - loss: 0.2523 - accuracy: 0.9367 - val_loss: 0.5776 - val_accuracy: 0.5950
#
# Epoch 00072: val_loss did not improve from 0.52396
# Epoch 73/2000
#  - 1s - loss: 0.2408 - accuracy: 0.9477 - val_loss: 0.7168 - val_accuracy: 0.6319
#
# Epoch 00073: val_loss did not improve from 0.52396
# Epoch 74/2000
#  - 1s - loss: 0.2367 - accuracy: 0.9509 - val_loss: 0.6748 - val_accuracy: 0.6185
#
# Epoch 00074: val_loss did not improve from 0.52396
# Epoch 75/2000
#  - 1s - loss: 0.2283 - accuracy: 0.9555 - val_loss: 0.8126 - val_accuracy: 0.6146
#
# Epoch 00075: val_loss did not improve from 0.52396
# Epoch 76/2000
#  - 1s - loss: 0.2338 - accuracy: 0.9491 - val_loss: 0.7086 - val_accuracy: 0.6235
#
# Epoch 00076: val_loss did not improve from 0.52396
# Epoch 77/2000
#  - 1s - loss: 0.2245 - accuracy: 0.9590 - val_loss: 0.4990 - val_accuracy: 0.6369
#
# Epoch 00077: val_loss improved from 0.52396 to 0.49902, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf115_lrcheck_KAVAUSDT.h5
# Epoch 78/2000
#  - 1s - loss: 0.2203 - accuracy: 0.9576 - val_loss: 0.6775 - val_accuracy: 0.5892
#
# Epoch 00078: val_loss did not improve from 0.49902
# Epoch 79/2000
#  - 1s - loss: 0.2160 - accuracy: 0.9587 - val_loss: 0.8852 - val_accuracy: 0.6285
#
# Epoch 00079: val_loss did not improve from 0.49902
# Epoch 80/2000
#  - 1s - loss: 0.2137 - accuracy: 0.9586 - val_loss: 0.9189 - val_accuracy: 0.6335
#
# Epoch 00080: val_loss did not improve from 0.49902
# Epoch 81/2000
#  - 1s - loss: 0.2074 - accuracy: 0.9637 - val_loss: 0.7463 - val_accuracy: 0.6435
#
# Epoch 00081: val_loss did not improve from 0.49902
# Epoch 82/2000
#  - 1s - loss: 0.2058 - accuracy: 0.9647 - val_loss: 0.5574 - val_accuracy: 0.6208
#
# Epoch 00082: val_loss did not improve from 0.49902
# Epoch 83/2000
#  - 1s - loss: 0.2029 - accuracy: 0.9632 - val_loss: 0.5738 - val_accuracy: 0.6127
#
# Epoch 00083: val_loss did not improve from 0.49902
# Epoch 84/2000
#  - 1s - loss: 0.1976 - accuracy: 0.9649 - val_loss: 0.7727 - val_accuracy: 0.6319
#
# Epoch 00084: val_loss did not improve from 0.49902
# Epoch 85/2000
#  - 1s - loss: 0.1962 - accuracy: 0.9659 - val_loss: 0.7737 - val_accuracy: 0.6581
#
# Epoch 00085: val_loss did not improve from 0.49902
# Epoch 86/2000
#  - 1s - loss: 0.1903 - accuracy: 0.9694 - val_loss: 0.7836 - val_accuracy: 0.6300
#
# Epoch 00086: val_loss did not improve from 0.49902
# Epoch 87/2000
#  - 1s - loss: 0.1829 - accuracy: 0.9738 - val_loss: 0.8557 - val_accuracy: 0.6250
#
# Epoch 00087: val_loss did not improve from 0.49902
# Epoch 88/2000
#  - 1s - loss: 0.1799 - accuracy: 0.9733 - val_loss: 0.8176 - val_accuracy: 0.6438
#
# Epoch 00088: val_loss did not improve from 0.49902
# Epoch 89/2000
#  - 1s - loss: 0.1777 - accuracy: 0.9760 - val_loss: 0.9221 - val_accuracy: 0.6469
#
# Epoch 00089: val_loss did not improve from 0.49902
# Epoch 90/2000
#  - 1s - loss: 0.1744 - accuracy: 0.9745 - val_loss: 0.7035 - val_accuracy: 0.6215
#
# Epoch 00090: val_loss did not improve from 0.49902
# Epoch 91/2000
#  - 1s - loss: 0.1709 - accuracy: 0.9765 - val_loss: 0.6351 - val_accuracy: 0.6408
#
# Epoch 00091: val_loss did not improve from 0.49902
# Epoch 92/2000
#  - 1s - loss: 0.1673 - accuracy: 0.9795 - val_loss: 0.8466 - val_accuracy: 0.6235
#
# Epoch 00092: val_loss did not improve from 0.49902
# Epoch 93/2000
#  - 1s - loss: 0.1656 - accuracy: 0.9785 - val_loss: 0.4707 - val_accuracy: 0.6465
#
# Epoch 00093: val_loss improved from 0.49902 to 0.47070, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf115_lrcheck_KAVAUSDT.h5
# Epoch 94/2000
#  - 1s - loss: 0.1643 - accuracy: 0.9788 - val_loss: 1.1181 - val_accuracy: 0.6319
#
# Epoch 00094: val_loss did not improve from 0.47070
# Epoch 95/2000
#  - 1s - loss: 0.1612 - accuracy: 0.9801 - val_loss: 0.8718 - val_accuracy: 0.6288
#
# Epoch 00095: val_loss did not improve from 0.47070
# Epoch 96/2000
#  - 1s - loss: 0.1566 - accuracy: 0.9811 - val_loss: 0.8566 - val_accuracy: 0.6362
#
# Epoch 00096: val_loss did not improve from 0.47070
# Epoch 97/2000
#  - 1s - loss: 0.1551 - accuracy: 0.9818 - val_loss: 0.7323 - val_accuracy: 0.6227
#
# Epoch 00097: val_loss did not improve from 0.47070
# Epoch 98/2000
#  - 1s - loss: 0.1531 - accuracy: 0.9796 - val_loss: 0.5856 - val_accuracy: 0.5942
#
# Epoch 00098: val_loss did not improve from 0.47070
# Epoch 99/2000
#  - 1s - loss: 0.1542 - accuracy: 0.9795 - val_loss: 0.5790 - val_accuracy: 0.6135
#
# Epoch 00099: val_loss did not improve from 0.47070
# Epoch 100/2000
#  - 1s - loss: 0.1458 - accuracy: 0.9846 - val_loss: 1.0694 - val_accuracy: 0.6200
#
# Epoch 00100: val_loss did not improve from 0.47070
# Epoch 101/2000
#  - 1s - loss: 0.1450 - accuracy: 0.9833 - val_loss: 1.0744 - val_accuracy: 0.6296
#
# Epoch 00101: val_loss did not improve from 0.47070
# Epoch 102/2000
#  - 1s - loss: 0.1386 - accuracy: 0.9859 - val_loss: 0.8446 - val_accuracy: 0.6246
#
# Epoch 00102: val_loss did not improve from 0.47070
# Epoch 103/2000
#  - 1s - loss: 0.1370 - accuracy: 0.9865 - val_loss: 0.9332 - val_accuracy: 0.6573
#
# Epoch 00103: val_loss did not improve from 0.47070
# Epoch 104/2000
#  - 1s - loss: 0.1380 - accuracy: 0.9863 - val_loss: 0.9185 - val_accuracy: 0.6342
#
# Epoch 00104: val_loss did not improve from 0.47070
# Epoch 105/2000
#  - 1s - loss: 0.1351 - accuracy: 0.9863 - val_loss: 0.7891 - val_accuracy: 0.6212
#
# Epoch 00105: val_loss did not improve from 0.47070
# Epoch 106/2000
#  - 1s - loss: 0.1313 - accuracy: 0.9859 - val_loss: 0.6250 - val_accuracy: 0.6523
#
# Epoch 00106: val_loss did not improve from 0.47070
# Epoch 107/2000
#  - 1s - loss: 0.1301 - accuracy: 0.9895 - val_loss: 0.9081 - val_accuracy: 0.6419
#
# Epoch 00107: val_loss did not improve from 0.47070
# Epoch 108/2000
#  - 1s - loss: 0.1238 - accuracy: 0.9901 - val_loss: 0.7269 - val_accuracy: 0.6408
#
# Epoch 00108: val_loss did not improve from 0.47070
# Epoch 109/2000
#  - 1s - loss: 0.1204 - accuracy: 0.9917 - val_loss: 0.9937 - val_accuracy: 0.6319
#
# Epoch 00109: val_loss did not improve from 0.47070
# Epoch 110/2000
#  - 1s - loss: 0.1199 - accuracy: 0.9917 - val_loss: 1.0880 - val_accuracy: 0.6377
#
# Epoch 00110: val_loss did not improve from 0.47070
# Epoch 111/2000
#  - 1s - loss: 0.1182 - accuracy: 0.9912 - val_loss: 0.9979 - val_accuracy: 0.6396
#
# Epoch 00111: val_loss did not improve from 0.47070
# Epoch 112/2000
#  - 1s - loss: 0.1159 - accuracy: 0.9917 - val_loss: 0.6664 - val_accuracy: 0.6592
#
# Epoch 00112: val_loss did not improve from 0.47070
# Epoch 113/2000
#  - 1s - loss: 0.1176 - accuracy: 0.9899 - val_loss: 0.8944 - val_accuracy: 0.6500
#
# Epoch 00113: val_loss did not improve from 0.47070
# Epoch 114/2000
#  - 1s - loss: 0.1121 - accuracy: 0.9929 - val_loss: 0.6678 - val_accuracy: 0.6281
#
# Epoch 00114: val_loss did not improve from 0.47070
# Epoch 115/2000
#  - 1s - loss: 0.1107 - accuracy: 0.9912 - val_loss: 0.7304 - val_accuracy: 0.6250
#
# Epoch 00115: val_loss did not improve from 0.47070
# Epoch 116/2000
#  - 1s - loss: 0.1094 - accuracy: 0.9935 - val_loss: 0.8425 - val_accuracy: 0.6315
#
# Epoch 00116: val_loss did not improve from 0.47070
# Epoch 117/2000
#  - 1s - loss: 0.1089 - accuracy: 0.9928 - val_loss: 0.5225 - val_accuracy: 0.6408
#
# Epoch 00117: val_loss did not improve from 0.47070
# Epoch 118/2000
#  - 1s - loss: 0.1043 - accuracy: 0.9937 - val_loss: 0.8321 - val_accuracy: 0.6146
#
# Epoch 00118: val_loss did not improve from 0.47070
# Epoch 119/2000
#  - 1s - loss: 0.1043 - accuracy: 0.9927 - val_loss: 0.6717 - val_accuracy: 0.6354
#
# Epoch 00119: val_loss did not improve from 0.47070
# Epoch 120/2000
#  - 1s - loss: 0.0993 - accuracy: 0.9950 - val_loss: 1.0578 - val_accuracy: 0.6438
#
# Epoch 00120: val_loss did not improve from 0.47070
# Epoch 121/2000
#  - 1s - loss: 0.0999 - accuracy: 0.9936 - val_loss: 0.8853 - val_accuracy: 0.6496
#
# Epoch 00121: val_loss did not improve from 0.47070
# Epoch 122/2000
#  - 1s - loss: 0.0993 - accuracy: 0.9933 - val_loss: 1.0628 - val_accuracy: 0.6581
#
# Epoch 00122: val_loss did not improve from 0.47070
# Epoch 123/2000
#  - 1s - loss: 0.0968 - accuracy: 0.9938 - val_loss: 0.6880 - val_accuracy: 0.6508
#
# Epoch 00123: val_loss did not improve from 0.47070
# Epoch 124/2000
#  - 1s - loss: 0.0942 - accuracy: 0.9947 - val_loss: 1.2123 - val_accuracy: 0.6408
#
# Epoch 00124: val_loss did not improve from 0.47070
# Epoch 125/2000
#  - 1s - loss: 0.0916 - accuracy: 0.9953 - val_loss: 1.1800 - val_accuracy: 0.6446
#
# Epoch 00125: val_loss did not improve from 0.47070
# Epoch 126/2000
#  - 1s - loss: 0.0917 - accuracy: 0.9950 - val_loss: 1.1116 - val_accuracy: 0.6423
#
# Epoch 00126: val_loss did not improve from 0.47070
# Epoch 127/2000
#  - 1s - loss: 0.0879 - accuracy: 0.9959 - val_loss: 1.2673 - val_accuracy: 0.6469
#
# Epoch 00127: val_loss did not improve from 0.47070
# Epoch 128/2000
#  - 1s - loss: 0.0874 - accuracy: 0.9962 - val_loss: 0.7475 - val_accuracy: 0.6427
#
# Epoch 00128: val_loss did not improve from 0.47070
# Epoch 129/2000
#  - 1s - loss: 0.0852 - accuracy: 0.9960 - val_loss: 0.6225 - val_accuracy: 0.6481
#
# Epoch 00129: val_loss did not improve from 0.47070
# Epoch 130/2000
#  - 1s - loss: 0.0830 - accuracy: 0.9959 - val_loss: 0.6014 - val_accuracy: 0.6508
#
# Epoch 00130: val_loss did not improve from 0.47070
# Epoch 131/2000
#  - 1s - loss: 0.0812 - accuracy: 0.9964 - val_loss: 0.7432 - val_accuracy: 0.6319
#
# Epoch 00131: val_loss did not improve from 0.47070
# Epoch 132/2000
#  - 1s - loss: 0.0808 - accuracy: 0.9967 - val_loss: 1.2304 - val_accuracy: 0.6435
#
# Epoch 00132: val_loss did not improve from 0.47070
# Epoch 133/2000
#  - 1s - loss: 0.0786 - accuracy: 0.9971 - val_loss: 0.6317 - val_accuracy: 0.6350
#
# Epoch 00133: val_loss did not improve from 0.47070
# Epoch 134/2000
#  - 1s - loss: 0.0780 - accuracy: 0.9967 - val_loss: 0.8741 - val_accuracy: 0.6435
#
# Epoch 00134: val_loss did not improve from 0.47070
# Epoch 135/2000
#  - 1s - loss: 0.0752 - accuracy: 0.9968 - val_loss: 0.6329 - val_accuracy: 0.6508
#
# Epoch 00135: val_loss did not improve from 0.47070
# Epoch 136/2000
#  - 1s - loss: 0.0742 - accuracy: 0.9979 - val_loss: 0.9036 - val_accuracy: 0.6408
#
# Epoch 00136: val_loss did not improve from 0.47070
# Epoch 137/2000
#  - 1s - loss: 0.0731 - accuracy: 0.9978 - val_loss: 0.9867 - val_accuracy: 0.6465
#
# Epoch 00137: val_loss did not improve from 0.47070
# Epoch 138/2000
#  - 1s - loss: 0.0729 - accuracy: 0.9976 - val_loss: 1.1017 - val_accuracy: 0.6242
#
# Epoch 00138: val_loss did not improve from 0.47070
# Epoch 139/2000
#  - 1s - loss: 0.0721 - accuracy: 0.9973 - val_loss: 0.6126 - val_accuracy: 0.6396
#
# Epoch 00139: val_loss did not improve from 0.47070
# Epoch 140/2000
#  - 1s - loss: 0.0687 - accuracy: 0.9978 - val_loss: 1.0011 - val_accuracy: 0.6554
#
# Epoch 00140: val_loss did not improve from 0.47070
# Epoch 141/2000
#  - 1s - loss: 0.0691 - accuracy: 0.9974 - val_loss: 0.7716 - val_accuracy: 0.6469
#
# Epoch 00141: val_loss did not improve from 0.47070
# Epoch 142/2000
#  - 1s - loss: 0.0672 - accuracy: 0.9979 - val_loss: 0.8491 - val_accuracy: 0.6500
#
# Epoch 00142: val_loss did not improve from 0.47070
# Epoch 143/2000
#  - 1s - loss: 0.0666 - accuracy: 0.9978 - val_loss: 1.0699 - val_accuracy: 0.6438
#
# Epoch 00143: val_loss did not improve from 0.47070
# Epoch 144/2000
#  - 1s - loss: 0.0658 - accuracy: 0.9978 - val_loss: 0.4609 - val_accuracy: 0.6581
#
# Epoch 00144: val_loss improved from 0.47070 to 0.46087, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf115_lrcheck_KAVAUSDT.h5
# Epoch 145/2000
#  - 1s - loss: 0.0662 - accuracy: 0.9978 - val_loss: 0.9540 - val_accuracy: 0.6512
#
# Epoch 00145: val_loss did not improve from 0.46087
# Epoch 146/2000
#  - 1s - loss: 0.0636 - accuracy: 0.9979 - val_loss: 0.6706 - val_accuracy: 0.6577
#
# Epoch 00146: val_loss did not improve from 0.46087
# Epoch 147/2000
#  - 1s - loss: 0.0635 - accuracy: 0.9977 - val_loss: 0.7238 - val_accuracy: 0.6396
#
# Epoch 00147: val_loss did not improve from 0.46087
# Epoch 148/2000
#  - 1s - loss: 0.0613 - accuracy: 0.9986 - val_loss: 0.6065 - val_accuracy: 0.6504
#
# Epoch 00148: val_loss did not improve from 0.46087
# Epoch 149/2000
#  - 1s - loss: 0.0595 - accuracy: 0.9986 - val_loss: 0.8430 - val_accuracy: 0.6538
#
# Epoch 00149: val_loss did not improve from 0.46087
# Epoch 150/2000
#  - 1s - loss: 0.0584 - accuracy: 0.9987 - val_loss: 1.0069 - val_accuracy: 0.6408
#
# Epoch 00150: val_loss did not improve from 0.46087
# Epoch 151/2000
#  - 1s - loss: 0.0572 - accuracy: 0.9982 - val_loss: 0.9976 - val_accuracy: 0.6423
#
# Epoch 00151: val_loss did not improve from 0.46087
# Epoch 152/2000
#  - 1s - loss: 0.0558 - accuracy: 0.9991 - val_loss: 0.9145 - val_accuracy: 0.6442
#
# Epoch 00152: val_loss did not improve from 0.46087
# Epoch 153/2000
#  - 1s - loss: 0.0556 - accuracy: 0.9990 - val_loss: 1.0294 - val_accuracy: 0.6504
#
# Epoch 00153: val_loss did not improve from 0.46087
# Epoch 154/2000
#  - 1s - loss: 0.0549 - accuracy: 0.9990 - val_loss: 1.1612 - val_accuracy: 0.6546
#
# Epoch 00154: val_loss did not improve from 0.46087
# Epoch 155/2000
#  - 1s - loss: 0.0531 - accuracy: 0.9991 - val_loss: 1.0317 - val_accuracy: 0.6446
#
# Epoch 00155: val_loss did not improve from 0.46087
# Epoch 156/2000
#  - 1s - loss: 0.0529 - accuracy: 0.9990 - val_loss: 0.8630 - val_accuracy: 0.6392
#
# Epoch 00156: val_loss did not improve from 0.46087
# Epoch 157/2000
#  - 1s - loss: 0.0510 - accuracy: 0.9988 - val_loss: 1.0845 - val_accuracy: 0.6496
#
# Epoch 00157: val_loss did not improve from 0.46087
# Epoch 158/2000
#  - 1s - loss: 0.0499 - accuracy: 0.9994 - val_loss: 1.0891 - val_accuracy: 0.6504
#
# Epoch 00158: val_loss did not improve from 0.46087
# Epoch 159/2000
#  - 1s - loss: 0.0491 - accuracy: 0.9990 - val_loss: 1.1022 - val_accuracy: 0.6565
#
# Epoch 00159: val_loss did not improve from 0.46087
# Epoch 160/2000
#  - 1s - loss: 0.0487 - accuracy: 0.9991 - val_loss: 0.8712 - val_accuracy: 0.6573
#
# Epoch 00160: val_loss did not improve from 0.46087
# Epoch 161/2000
#  - 1s - loss: 0.0482 - accuracy: 0.9992 - val_loss: 0.6956 - val_accuracy: 0.6635
#
# Epoch 00161: val_loss did not improve from 0.46087
# Epoch 162/2000
#  - 1s - loss: 0.0477 - accuracy: 0.9992 - val_loss: 1.2434 - val_accuracy: 0.6558
#
# Epoch 00162: val_loss did not improve from 0.46087
# Epoch 163/2000
#  - 1s - loss: 0.0466 - accuracy: 0.9994 - val_loss: 1.1883 - val_accuracy: 0.6512
#
# Epoch 00163: val_loss did not improve from 0.46087
# Epoch 164/2000
#  - 1s - loss: 0.0456 - accuracy: 0.9995 - val_loss: 1.1361 - val_accuracy: 0.6592
#
# Epoch 00164: val_loss did not improve from 0.46087
# Epoch 165/2000
#  - 1s - loss: 0.0445 - accuracy: 0.9995 - val_loss: 1.0523 - val_accuracy: 0.6488
#
# Epoch 00165: val_loss did not improve from 0.46087
# Epoch 166/2000
#  - 1s - loss: 0.0436 - accuracy: 0.9996 - val_loss: 0.8487 - val_accuracy: 0.6496
#
# Epoch 00166: val_loss did not improve from 0.46087
# Epoch 167/2000
#  - 1s - loss: 0.0425 - accuracy: 0.9994 - val_loss: 1.1426 - val_accuracy: 0.6442
#
# Epoch 00167: val_loss did not improve from 0.46087
# Epoch 168/2000
#  - 1s - loss: 0.0424 - accuracy: 0.9995 - val_loss: 0.6618 - val_accuracy: 0.6508
#
# Epoch 00168: val_loss did not improve from 0.46087
# Epoch 169/2000
#  - 1s - loss: 0.0417 - accuracy: 0.9996 - val_loss: 0.8808 - val_accuracy: 0.6535
#
# Epoch 00169: val_loss did not improve from 0.46087
# Epoch 170/2000
#  - 1s - loss: 0.0417 - accuracy: 0.9996 - val_loss: 0.7272 - val_accuracy: 0.6519
#
# Epoch 00170: val_loss did not improve from 0.46087
# Epoch 171/2000
#  - 1s - loss: 0.0409 - accuracy: 0.9997 - val_loss: 1.3485 - val_accuracy: 0.6431
#
# Epoch 00171: val_loss did not improve from 0.46087
# Epoch 172/2000
#  - 1s - loss: 0.0400 - accuracy: 0.9996 - val_loss: 0.8567 - val_accuracy: 0.6496
#
# Epoch 00172: val_loss did not improve from 0.46087
# Epoch 173/2000
#  - 1s - loss: 0.0390 - accuracy: 0.9999 - val_loss: 1.1023 - val_accuracy: 0.6431
#
# Epoch 00173: val_loss did not improve from 0.46087
# Epoch 174/2000
#  - 1s - loss: 0.0384 - accuracy: 0.9999 - val_loss: 0.7012 - val_accuracy: 0.6442
#
# Epoch 00174: val_loss did not improve from 0.46087
# Epoch 175/2000
#  - 1s - loss: 0.0375 - accuracy: 0.9996 - val_loss: 1.0340 - val_accuracy: 0.6581
#
# Epoch 00175: val_loss did not improve from 0.46087
# Epoch 176/2000
#  - 1s - loss: 0.0368 - accuracy: 0.9997 - val_loss: 1.4405 - val_accuracy: 0.6558
#
# Epoch 00176: val_loss did not improve from 0.46087
# Epoch 177/2000
#  - 1s - loss: 0.0366 - accuracy: 0.9997 - val_loss: 0.9705 - val_accuracy: 0.6558
#
# Epoch 00177: val_loss did not improve from 0.46087
# Epoch 178/2000
#  - 1s - loss: 0.0359 - accuracy: 0.9999 - val_loss: 1.2103 - val_accuracy: 0.6588
#
# Epoch 00178: val_loss did not improve from 0.46087
# Epoch 179/2000
#  - 1s - loss: 0.0356 - accuracy: 0.9996 - val_loss: 0.9566 - val_accuracy: 0.6619
#
# Epoch 00179: val_loss did not improve from 0.46087
# Epoch 180/2000
#  - 1s - loss: 0.0348 - accuracy: 0.9999 - val_loss: 1.0269 - val_accuracy: 0.6515
#
# Epoch 00180: val_loss did not improve from 0.46087
# Epoch 181/2000
#  - 1s - loss: 0.0339 - accuracy: 0.9999 - val_loss: 0.8189 - val_accuracy: 0.6473
#
# Epoch 00181: val_loss did not improve from 0.46087
# Epoch 182/2000
#  - 1s - loss: 0.0334 - accuracy: 0.9999 - val_loss: 0.8465 - val_accuracy: 0.6512
#
# Epoch 00182: val_loss did not improve from 0.46087
# Epoch 183/2000
#  - 1s - loss: 0.0329 - accuracy: 0.9999 - val_loss: 0.7717 - val_accuracy: 0.6550
#
# Epoch 00183: val_loss did not improve from 0.46087
# Epoch 184/2000
#  - 1s - loss: 0.0321 - accuracy: 0.9999 - val_loss: 1.1147 - val_accuracy: 0.6504
#
# Epoch 00184: val_loss did not improve from 0.46087
# Epoch 185/2000
#  - 1s - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.9966 - val_accuracy: 0.6565
#
# Epoch 00185: val_loss did not improve from 0.46087
# Epoch 186/2000
#  - 1s - loss: 0.0313 - accuracy: 0.9999 - val_loss: 0.6238 - val_accuracy: 0.6623
#
# Epoch 00186: val_loss did not improve from 0.46087
# Epoch 187/2000
#  - 1s - loss: 0.0320 - accuracy: 1.0000 - val_loss: 1.0886 - val_accuracy: 0.6477
#
# Epoch 00187: val_loss did not improve from 0.46087
# Epoch 188/2000
#  - 1s - loss: 0.0309 - accuracy: 0.9999 - val_loss: 0.9842 - val_accuracy: 0.6488
#
# Epoch 00188: val_loss did not improve from 0.46087
# Epoch 189/2000
#  - 1s - loss: 0.0299 - accuracy: 0.9999 - val_loss: 1.0128 - val_accuracy: 0.6473
#
# Epoch 00189: val_loss did not improve from 0.46087
# Epoch 190/2000
#  - 1s - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.8307 - val_accuracy: 0.6604
#
# Epoch 00190: val_loss did not improve from 0.46087
# Epoch 191/2000
#  - 1s - loss: 0.0290 - accuracy: 1.0000 - val_loss: 1.0460 - val_accuracy: 0.6538
#
# Epoch 00191: val_loss did not improve from 0.46087
# Epoch 192/2000
#  - 1s - loss: 0.0283 - accuracy: 1.0000 - val_loss: 1.1601 - val_accuracy: 0.6527
#
# Epoch 00192: val_loss did not improve from 0.46087
# Epoch 193/2000
#  - 1s - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.8758 - val_accuracy: 0.6419
#
# Epoch 00193: val_loss did not improve from 0.46087
# Epoch 194/2000
#  - 1s - loss: 0.0280 - accuracy: 1.0000 - val_loss: 0.8029 - val_accuracy: 0.6435
#
# Epoch 00194: val_loss did not improve from 0.46087
# Epoch 195/2000
#  - 1s - loss: 0.0266 - accuracy: 0.9999 - val_loss: 0.9032 - val_accuracy: 0.6604
#
# Epoch 00195: val_loss did not improve from 0.46087
# Epoch 196/2000
#  - 1s - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.6575 - val_accuracy: 0.6519
#
# Epoch 00196: val_loss did not improve from 0.46087
# Epoch 197/2000
#  - 1s - loss: 0.0264 - accuracy: 0.9999 - val_loss: 1.3036 - val_accuracy: 0.6496
#
# Epoch 00197: val_loss did not improve from 0.46087
# Epoch 198/2000
#  - 1s - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.7783 - val_accuracy: 0.6515
#
# Epoch 00198: val_loss did not improve from 0.46087
# Epoch 199/2000
#  - 1s - loss: 0.0260 - accuracy: 1.0000 - val_loss: 1.0088 - val_accuracy: 0.6469
#
# Epoch 00199: val_loss did not improve from 0.46087
# Epoch 200/2000
#  - 1s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.8161 - val_accuracy: 0.6435
#
# Epoch 00200: val_loss did not improve from 0.46087
# Epoch 201/2000
#  - 1s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.7160 - val_accuracy: 0.6465
#
# Epoch 00201: val_loss did not improve from 0.46087
# Epoch 202/2000
#  - 1s - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.8631 - val_accuracy: 0.6646
#
# Epoch 00202: val_loss did not improve from 0.46087
# Epoch 203/2000
#  - 1s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.6648 - val_accuracy: 0.6600
#
# Epoch 00203: val_loss did not improve from 0.46087
# Epoch 204/2000
#  - 1s - loss: 0.0237 - accuracy: 1.0000 - val_loss: 1.4770 - val_accuracy: 0.6465
#
# Epoch 00204: val_loss did not improve from 0.46087
# Epoch 205/2000
#  - 1s - loss: 0.0229 - accuracy: 1.0000 - val_loss: 1.2362 - val_accuracy: 0.6562
#
# Epoch 00205: val_loss did not improve from 0.46087
# Epoch 206/2000
#  - 1s - loss: 0.0227 - accuracy: 1.0000 - val_loss: 1.5124 - val_accuracy: 0.6512
#
# Epoch 00206: val_loss did not improve from 0.46087
# Epoch 207/2000
#  - 1s - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.9844 - val_accuracy: 0.6492
#
# Epoch 00207: val_loss did not improve from 0.46087
# Epoch 208/2000
#  - 1s - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.8677 - val_accuracy: 0.6592
#
# Epoch 00208: val_loss did not improve from 0.46087
# Epoch 209/2000
#  - 1s - loss: 0.0218 - accuracy: 1.0000 - val_loss: 1.3377 - val_accuracy: 0.6431
#
# Epoch 00209: val_loss did not improve from 0.46087
# Epoch 210/2000
#  - 1s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.8352 - val_accuracy: 0.6523
#
# Epoch 00210: val_loss did not improve from 0.46087
# Epoch 211/2000
#  - 1s - loss: 0.0212 - accuracy: 1.0000 - val_loss: 1.0543 - val_accuracy: 0.6527
#
# Epoch 00211: val_loss did not improve from 0.46087
# Epoch 212/2000
#  - 1s - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.9888 - val_accuracy: 0.6519
#
# Epoch 00212: val_loss did not improve from 0.46087
# Epoch 213/2000
#  - 1s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 1.1737 - val_accuracy: 0.6508
#
# Epoch 00213: val_loss did not improve from 0.46087
# Epoch 214/2000
#  - 1s - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.9711 - val_accuracy: 0.6519
#
# Epoch 00214: val_loss did not improve from 0.46087
# Epoch 215/2000
#  - 1s - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.7610 - val_accuracy: 0.6546
#
# Epoch 00215: val_loss did not improve from 0.46087
# Epoch 216/2000
#  - 1s - loss: 0.0194 - accuracy: 1.0000 - val_loss: 1.3986 - val_accuracy: 0.6554
#
# Epoch 00216: val_loss did not improve from 0.46087
# Epoch 217/2000
#  - 1s - loss: 0.0191 - accuracy: 1.0000 - val_loss: 1.1809 - val_accuracy: 0.6450
#
# Epoch 00217: val_loss did not improve from 0.46087
# Epoch 218/2000
#  - 1s - loss: 0.0188 - accuracy: 1.0000 - val_loss: 1.0589 - val_accuracy: 0.6554
#
# Epoch 00218: val_loss did not improve from 0.46087
# Epoch 219/2000
#  - 1s - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.8716 - val_accuracy: 0.6500
#
# Epoch 00219: val_loss did not improve from 0.46087
# Epoch 220/2000
#  - 1s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 1.6546 - val_accuracy: 0.6588
#
# Epoch 00220: val_loss did not improve from 0.46087
# Epoch 221/2000
#  - 1s - loss: 0.0183 - accuracy: 1.0000 - val_loss: 1.0921 - val_accuracy: 0.6465
#
# Epoch 00221: val_loss did not improve from 0.46087
# Epoch 222/2000
#  - 1s - loss: 0.0178 - accuracy: 1.0000 - val_loss: 1.0062 - val_accuracy: 0.6538
#
# Epoch 00222: val_loss did not improve from 0.46087
# Epoch 223/2000
#  - 1s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 1.0914 - val_accuracy: 0.6600
#
# Epoch 00223: val_loss did not improve from 0.46087
# Epoch 224/2000
#  - 1s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.9941 - val_accuracy: 0.6435
#
# Epoch 00224: val_loss did not improve from 0.46087
# Epoch 225/2000
#  - 1s - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.6764 - val_accuracy: 0.6488
#
# Epoch 00225: val_loss did not improve from 0.46087
# Epoch 226/2000
#  - 1s - loss: 0.0167 - accuracy: 1.0000 - val_loss: 1.4619 - val_accuracy: 0.6581
#
# Epoch 00226: val_loss did not improve from 0.46087
# Epoch 227/2000
#  - 1s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 1.2063 - val_accuracy: 0.6488
#
# Epoch 00227: val_loss did not improve from 0.46087
# Epoch 228/2000
#  - 1s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 1.0940 - val_accuracy: 0.6523
#
# Epoch 00228: val_loss did not improve from 0.46087
# Epoch 229/2000
#  - 1s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 1.2268 - val_accuracy: 0.6592
#
# Epoch 00229: val_loss did not improve from 0.46087
# Epoch 230/2000
#  - 1s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.9253 - val_accuracy: 0.6515
#
# Epoch 00230: val_loss did not improve from 0.46087
# Epoch 231/2000
#  - 1s - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.9651 - val_accuracy: 0.6569
#
# Epoch 00231: val_loss did not improve from 0.46087
# Epoch 232/2000
#  - 1s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.8708 - val_accuracy: 0.6585
#
# Epoch 00232: val_loss did not improve from 0.46087
# Epoch 233/2000
#  - 1s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.7846 - val_accuracy: 0.6608
#
# Epoch 00233: val_loss did not improve from 0.46087
# Epoch 234/2000
#  - 1s - loss: 0.0148 - accuracy: 1.0000 - val_loss: 1.4790 - val_accuracy: 0.6462
#
# Epoch 00234: val_loss did not improve from 0.46087
# Epoch 235/2000
#  - 1s - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.7776 - val_accuracy: 0.6615
#
# Epoch 00235: val_loss did not improve from 0.46087
# Epoch 236/2000
#  - 1s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 1.0766 - val_accuracy: 0.6508
#
# Epoch 00236: val_loss did not improve from 0.46087
# Epoch 237/2000
#  - 1s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.6405 - val_accuracy: 0.6508
#
# Epoch 00237: val_loss did not improve from 0.46087
# Epoch 238/2000
#  - 1s - loss: 0.0140 - accuracy: 1.0000 - val_loss: 1.1265 - val_accuracy: 0.6473
#
# Epoch 00238: val_loss did not improve from 0.46087
# Epoch 239/2000
#  - 1s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 1.1037 - val_accuracy: 0.6581
#
# Epoch 00239: val_loss did not improve from 0.46087
# Epoch 240/2000
#  - 1s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.8157 - val_accuracy: 0.6458
#
# Epoch 00240: val_loss did not improve from 0.46087
# Epoch 241/2000
#  - 1s - loss: 0.0135 - accuracy: 1.0000 - val_loss: 1.3994 - val_accuracy: 0.6535
#
# Epoch 00241: val_loss did not improve from 0.46087
# Epoch 242/2000
#  - 1s - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.9064 - val_accuracy: 0.6554
#
# Epoch 00242: val_loss did not improve from 0.46087
# Epoch 243/2000
#  - 1s - loss: 0.0129 - accuracy: 1.0000 - val_loss: 1.0146 - val_accuracy: 0.6612
#
# Epoch 00243: val_loss did not improve from 0.46087
# Epoch 244/2000
#  - 1s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 1.0997 - val_accuracy: 0.6504
#
# Epoch 00244: val_loss did not improve from 0.46087
# Epoch 245/2000
#  - 1s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 1.2113 - val_accuracy: 0.6535
#
# Epoch 00245: val_loss did not improve from 0.46087
# Epoch 246/2000
#  - 1s - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.8317 - val_accuracy: 0.6527
#
# Epoch 00246: val_loss did not improve from 0.46087
# Epoch 247/2000
#  - 1s - loss: 0.0123 - accuracy: 1.0000 - val_loss: 1.6221 - val_accuracy: 0.6558
#
# Epoch 00247: val_loss did not improve from 0.46087
# Epoch 248/2000
#  - 1s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 1.8947 - val_accuracy: 0.6542
#
# Epoch 00248: val_loss did not improve from 0.46087
# Epoch 249/2000
#  - 1s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.6937 - val_accuracy: 0.6423
#
# Epoch 00249: val_loss did not improve from 0.46087
# Epoch 250/2000
#  - 1s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 1.2587 - val_accuracy: 0.6523
#
# Epoch 00250: val_loss did not improve from 0.46087
# Epoch 251/2000
#  - 1s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 1.7997 - val_accuracy: 0.6465
#
# Epoch 00251: val_loss did not improve from 0.46087
# Epoch 252/2000
#  - 1s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 1.4030 - val_accuracy: 0.6562
#
# Epoch 00252: val_loss did not improve from 0.46087
# Epoch 253/2000
#  - 1s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.4833 - val_accuracy: 0.6523
#
# Epoch 00253: val_loss did not improve from 0.46087
# Epoch 254/2000
#  - 1s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 1.3135 - val_accuracy: 0.6573
#
# Epoch 00254: val_loss did not improve from 0.46087
# Epoch 255/2000
#  - 1s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 1.1164 - val_accuracy: 0.6542
#
# Epoch 00255: val_loss did not improve from 0.46087
# Epoch 256/2000
#  - 1s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.2292 - val_accuracy: 0.6492
#
# Epoch 00256: val_loss did not improve from 0.46087
# Epoch 257/2000
#  - 1s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.8149 - val_accuracy: 0.6565
#
# Epoch 00257: val_loss did not improve from 0.46087
# Epoch 258/2000
#  - 1s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 1.4035 - val_accuracy: 0.6562
#
# Epoch 00258: val_loss did not improve from 0.46087
# Epoch 259/2000
#  - 1s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 1.7041 - val_accuracy: 0.6477
#
# Epoch 00259: val_loss did not improve from 0.46087
# Epoch 260/2000
#  - 1s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.3369 - val_accuracy: 0.6531
#
# Epoch 00260: val_loss did not improve from 0.46087
# Epoch 261/2000
#  - 1s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 1.4003 - val_accuracy: 0.6523
#
# Epoch 00261: val_loss did not improve from 0.46087
# Epoch 262/2000
#  - 1s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.8745 - val_accuracy: 0.6523
#
# Epoch 00262: val_loss did not improve from 0.46087
# Epoch 263/2000
#  - 1s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 1.1582 - val_accuracy: 0.6538
#
# Epoch 00263: val_loss did not improve from 0.46087
# Epoch 264/2000
#  - 1s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 1.4757 - val_accuracy: 0.6512
#
# Epoch 00264: val_loss did not improve from 0.46087
# Epoch 265/2000
#  - 1s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.7978 - val_accuracy: 0.6527
#
# Epoch 00265: val_loss did not improve from 0.46087
# Epoch 266/2000
#  - 1s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 1.2239 - val_accuracy: 0.6488
#
# Epoch 00266: val_loss did not improve from 0.46087
# Epoch 267/2000
#  - 1s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.0057 - val_accuracy: 0.6546
#
# Epoch 00267: val_loss did not improve from 0.46087
# Epoch 268/2000
#  - 1s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.3987 - val_accuracy: 0.6473
#
# Epoch 00268: val_loss did not improve from 0.46087
# Epoch 269/2000
#  - 1s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.7643 - val_accuracy: 0.6535
#
# Epoch 00269: val_loss did not improve from 0.46087
# Epoch 270/2000
#  - 1s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.8504 - val_accuracy: 0.6496
#
# Epoch 00270: val_loss did not improve from 0.46087
# Epoch 271/2000
#  - 1s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.7143 - val_accuracy: 0.6538
#
# Epoch 00271: val_loss did not improve from 0.46087
# Epoch 272/2000
#  - 1s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.6101 - val_accuracy: 0.6569
#
# Epoch 00272: val_loss did not improve from 0.46087
# Epoch 273/2000
#  - 1s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.3505 - val_accuracy: 0.6527
#
# Epoch 00273: val_loss did not improve from 0.46087
# Epoch 274/2000
#  - 1s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 1.1838 - val_accuracy: 0.6500
#
# Epoch 00274: val_loss did not improve from 0.46087
# Epoch 275/2000
#  - 1s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.5389 - val_accuracy: 0.6542
#
# Epoch 00275: val_loss did not improve from 0.46087
# Epoch 276/2000
#  - 1s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.6832 - val_accuracy: 0.6531
#
# Epoch 00276: val_loss did not improve from 0.46087
# Epoch 277/2000
#  - 1s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.1514 - val_accuracy: 0.6565
#
# Epoch 00277: val_loss did not improve from 0.46087
# Epoch 278/2000
#  - 1s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.6031 - val_accuracy: 0.6535
#
# Epoch 00278: val_loss did not improve from 0.46087
# Epoch 279/2000
#  - 1s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.1391 - val_accuracy: 0.6485
#
# Epoch 00279: val_loss did not improve from 0.46087
# Epoch 280/2000
#  - 1s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 1.5003 - val_accuracy: 0.6577
#
# Epoch 00280: val_loss did not improve from 0.46087
# Epoch 281/2000
#  - 1s - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.2846 - val_accuracy: 0.6473
#
# Epoch 00281: val_loss did not improve from 0.46087
# Epoch 282/2000
#  - 1s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.3871 - val_accuracy: 0.6562
#
# Epoch 00282: val_loss did not improve from 0.46087
# Epoch 283/2000
#  - 1s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.0192 - val_accuracy: 0.6500
#
# Epoch 00283: val_loss did not improve from 0.46087
# Epoch 284/2000
#  - 1s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.6169 - val_accuracy: 0.6542
#
# Epoch 00284: val_loss did not improve from 0.46087
# Epoch 285/2000
#  - 1s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.1039 - val_accuracy: 0.6500
#
# Epoch 00285: val_loss did not improve from 0.46087
# Epoch 286/2000
#  - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.5059 - val_accuracy: 0.6538
#
# Epoch 00286: val_loss did not improve from 0.46087
# Epoch 287/2000
#  - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.2999 - val_accuracy: 0.6523
#
# Epoch 00287: val_loss did not improve from 0.46087
# Epoch 288/2000
#  - 1s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.7471 - val_accuracy: 0.6546
#
# Epoch 00288: val_loss did not improve from 0.46087
# Epoch 289/2000
#  - 1s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.9161 - val_accuracy: 0.6577
#
# Epoch 00289: val_loss did not improve from 0.46087
# Epoch 290/2000
#  - 1s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.4714 - val_accuracy: 0.6527
#
# Epoch 00290: val_loss did not improve from 0.46087
# Epoch 291/2000
#  - 1s - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.1041 - val_accuracy: 0.6477
#
# Epoch 00291: val_loss did not improve from 0.46087
# Epoch 292/2000
#  - 1s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.1955 - val_accuracy: 0.6562
#
# Epoch 00292: val_loss did not improve from 0.46087
# Epoch 293/2000
#  - 1s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.3174 - val_accuracy: 0.6585
#
# Epoch 00293: val_loss did not improve from 0.46087
# Epoch 294/2000
#  - 1s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 1.1339 - val_accuracy: 0.6515
#
# Epoch 00294: val_loss did not improve from 0.46087
# Epoch 295/2000
#  - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.8884 - val_accuracy: 0.6523
#
# Epoch 00295: val_loss did not improve from 0.46087
# Epoch 296/2000
#  - 1s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.1412 - val_accuracy: 0.6546
#
# Epoch 00296: val_loss did not improve from 0.46087
# Epoch 297/2000
#  - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5452 - val_accuracy: 0.6527
#
# Epoch 00297: val_loss did not improve from 0.46087
# Epoch 298/2000
#  - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.4759 - val_accuracy: 0.6519
#
# Epoch 00298: val_loss did not improve from 0.46087
# Epoch 299/2000
#  - 1s - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.2402 - val_accuracy: 0.6508
#
# Epoch 00299: val_loss did not improve from 0.46087
# Epoch 300/2000
#  - 1s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.6689 - val_accuracy: 0.6538
#
# Epoch 00300: val_loss did not improve from 0.46087
# Epoch 301/2000
#  - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.1834 - val_accuracy: 0.6546
#
# Epoch 00301: val_loss did not improve from 0.46087
# Epoch 302/2000
#  - 1s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.3990 - val_accuracy: 0.6542
#
# Epoch 00302: val_loss did not improve from 0.46087
# Epoch 303/2000
#  - 1s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.1766 - val_accuracy: 0.6542
#
# Epoch 00303: val_loss did not improve from 0.46087
# Epoch 304/2000
#  - 1s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.1131 - val_accuracy: 0.6538
#
# Epoch 00304: val_loss did not improve from 0.46087
# Epoch 305/2000
#  - 1s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.2260 - val_accuracy: 0.6558
#
# Epoch 00305: val_loss did not improve from 0.46087
# Epoch 306/2000
#  - 1s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.2782 - val_accuracy: 0.6504
#
# Epoch 00306: val_loss did not improve from 0.46087
# Epoch 307/2000
#  - 1s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.4547 - val_accuracy: 0.6550
#
# Epoch 00307: val_loss did not improve from 0.46087
# Epoch 308/2000
#  - 1s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9176 - val_accuracy: 0.6550
#
# Epoch 00308: val_loss did not improve from 0.46087
# Epoch 309/2000
#  - 1s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.3889 - val_accuracy: 0.6573
#
# Epoch 00309: val_loss did not improve from 0.46087
# Epoch 310/2000
#  - 1s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.5470 - val_accuracy: 0.6481
#
# Epoch 00310: val_loss did not improve from 0.46087
# Epoch 311/2000
# ...
# Epoch 569/2000
#  - 1s - loss: 3.1480e-04 - accuracy: 1.0000 - val_loss: 2.2175 - val_accuracy: 0.6565
#
# Epoch 00569: val_loss did not improve from 0.46087
# Epoch 570/2000
#  - 1s - loss: 3.1617e-04 - accuracy: 1.0000 - val_loss: 1.2732 - val_accuracy: 0.6554
#
# Epoch 00570: val_loss did not improve from 0.46087
# Epoch 571/2000
#  - 1s - loss: 3.1490e-04 - accuracy: 1.0000 - val_loss: 0.9796 - val_accuracy: 0.6531
#
# Epoch 00571: val_loss did not improve from 0.46087
# Epoch 572/2000
#  - 1s - loss: 3.1003e-04 - accuracy: 1.0000 - val_loss: 2.4649 - val_accuracy: 0.6508
#
# Epoch 00572: val_loss did not improve from 0.46087
# Epoch 573/2000
#  - 1s - loss: 3.0508e-04 - accuracy: 1.0000 - val_loss: 2.1002 - val_accuracy: 0.6538
#
# Epoch 00573: val_loss did not improve from 0.46087
# Epoch 574/2000
#  - 1s - loss: 2.9889e-04 - accuracy: 1.0000 - val_loss: 2.3326 - val_accuracy: 0.6562
#
# Epoch 00574: val_loss did not improve from 0.46087
# Epoch 575/2000
#  - 1s - loss: 2.9957e-04 - accuracy: 1.0000 - val_loss: 2.4403 - val_accuracy: 0.6565
#
# Epoch 00575: val_loss did not improve from 0.46087
# Epoch 576/2000
#  - 1s - loss: 2.9125e-04 - accuracy: 1.0000 - val_loss: 3.0203 - val_accuracy: 0.6527
#
# Epoch 00576: val_loss did not improve from 0.46087
# Epoch 577/2000
#  - 1s - loss: 2.9173e-04 - accuracy: 1.0000 - val_loss: 2.6815 - val_accuracy: 0.6535
#
# Epoch 00577: val_loss did not improve from 0.46087
# Epoch 578/2000
#  - 1s - loss: 2.8476e-04 - accuracy: 1.0000 - val_loss: 2.3731 - val_accuracy: 0.6523
#
# Epoch 00578: val_loss did not improve from 0.46087
# Epoch 579/2000
#  - 1s - loss: 2.8864e-04 - accuracy: 1.0000 - val_loss: 2.0272 - val_accuracy: 0.6523
#
# Epoch 00579: val_loss did not improve from 0.46087
# Epoch 580/2000
#  - 1s - loss: 2.8345e-04 - accuracy: 1.0000 - val_loss: 1.9331 - val_accuracy: 0.6519
#
# Epoch 00580: val_loss did not improve from 0.46087
# Epoch 581/2000
#  - 1s - loss: 2.7885e-04 - accuracy: 1.0000 - val_loss: 1.6639 - val_accuracy: 0.6554
#
# Epoch 00581: val_loss did not improve from 0.46087
# Epoch 582/2000
#  - 1s - loss: 2.7871e-04 - accuracy: 1.0000 - val_loss: 1.4166 - val_accuracy: 0.6538
#
# Epoch 00582: val_loss did not improve from 0.46087
# Epoch 583/2000
#  - 1s - loss: 2.7292e-04 - accuracy: 1.0000 - val_loss: 1.2428 - val_accuracy: 0.6542
#
# Epoch 00583: val_loss did not improve from 0.46087
# Epoch 584/2000
#  - 1s - loss: 2.7167e-04 - accuracy: 1.0000 - val_loss: 2.4006 - val_accuracy: 0.6542
#
# Epoch 00584: val_loss did not improve from 0.46087
# Epoch 585/2000
#  - 1s - loss: 2.7204e-04 - accuracy: 1.0000 - val_loss: 2.0955 - val_accuracy: 0.6554
#
# Epoch 00585: val_loss did not improve from 0.46087
# Epoch 586/2000
#  - 1s - loss: 2.6322e-04 - accuracy: 1.0000 - val_loss: 1.8288 - val_accuracy: 0.6562
#
# Epoch 00586: val_loss did not improve from 0.46087
# Epoch 587/2000
#  - 1s - loss: 2.6936e-04 - accuracy: 1.0000 - val_loss: 3.2975 - val_accuracy: 0.6558
#
# Epoch 00587: val_loss did not improve from 0.46087
# Epoch 588/2000
#  - 1s - loss: 2.6554e-04 - accuracy: 1.0000 - val_loss: 1.7869 - val_accuracy: 0.6492
#
# Epoch 00588: val_loss did not improve from 0.46087
# Epoch 589/2000
#  - 1s - loss: 2.6321e-04 - accuracy: 1.0000 - val_loss: 2.3968 - val_accuracy: 0.6527
#
# Epoch 00589: val_loss did not improve from 0.46087
# Epoch 590/2000
#  - 1s - loss: 2.5470e-04 - accuracy: 1.0000 - val_loss: 2.2697 - val_accuracy: 0.6554
#
# Epoch 00590: val_loss did not improve from 0.46087
# Epoch 591/2000
#  - 1s - loss: 2.5719e-04 - accuracy: 1.0000 - val_loss: 2.4937 - val_accuracy: 0.6512
#
# Epoch 00591: val_loss did not improve from 0.46087
# Epoch 592/2000
#  - 1s - loss: 2.5139e-04 - accuracy: 1.0000 - val_loss: 1.6542 - val_accuracy: 0.6508
#
# Epoch 00592: val_loss did not improve from 0.46087
# Epoch 593/2000
#  - 1s - loss: 2.5020e-04 - accuracy: 1.0000 - val_loss: 1.7602 - val_accuracy: 0.6519
#
# Epoch 00593: val_loss did not improve from 0.46087
# Epoch 594/2000
#  - 1s - loss: 2.5287e-04 - accuracy: 1.0000 - val_loss: 1.5405 - val_accuracy: 0.6550
#
# Epoch 00594: val_loss did not improve from 0.46087
# Epoch 595/2000
#  - 1s - loss: 2.4626e-04 - accuracy: 1.0000 - val_loss: 1.4669 - val_accuracy: 0.6565
#
# Epoch 00595: val_loss did not improve from 0.46087
# Epoch 596/2000
#  - 1s - loss: 2.3926e-04 - accuracy: 1.0000 - val_loss: 1.3171 - val_accuracy: 0.6538
#
# Epoch 00596: val_loss did not improve from 0.46087
# Epoch 597/2000
#  - 1s - loss: 2.3965e-04 - accuracy: 1.0000 - val_loss: 1.3674 - val_accuracy: 0.6531
#
# Epoch 00597: val_loss did not improve from 0.46087
# Epoch 598/2000
#  - 1s - loss: 2.3694e-04 - accuracy: 1.0000 - val_loss: 1.3696 - val_accuracy: 0.6535
#
# Epoch 00598: val_loss did not improve from 0.46087
# Epoch 599/2000
#  - 1s - loss: 2.3376e-04 - accuracy: 1.0000 - val_loss: 1.6086 - val_accuracy: 0.6562
#
# Epoch 00599: val_loss did not improve from 0.46087
# Epoch 600/2000
#  - 1s - loss: 2.3228e-04 - accuracy: 1.0000 - val_loss: 3.4075 - val_accuracy: 0.6538
#
# Epoch 00600: val_loss did not improve from 0.46087
# Epoch 601/2000
#  - 1s - loss: 2.2959e-04 - accuracy: 1.0000 - val_loss: 2.3008 - val_accuracy: 0.6531
#
# Epoch 00601: val_loss did not improve from 0.46087
# Epoch 602/2000
#  - 1s - loss: 2.2601e-04 - accuracy: 1.0000 - val_loss: 3.0381 - val_accuracy: 0.6515
#
# Epoch 00602: val_loss did not improve from 0.46087
# Epoch 603/2000
#  - 1s - loss: 2.2945e-04 - accuracy: 1.0000 - val_loss: 1.3561 - val_accuracy: 0.6515
#
# Epoch 00603: val_loss did not improve from 0.46087
# Epoch 604/2000
#  - 1s - loss: 2.2363e-04 - accuracy: 1.0000 - val_loss: 2.2653 - val_accuracy: 0.6519
#
# Epoch 00604: val_loss did not improve from 0.46087
# Epoch 605/2000
#  - 1s - loss: 2.1943e-04 - accuracy: 1.0000 - val_loss: 1.2895 - val_accuracy: 0.6515
#
# Epoch 00605: val_loss did not improve from 0.46087
# Epoch 606/2000
#  - 1s - loss: 2.2193e-04 - accuracy: 1.0000 - val_loss: 1.5479 - val_accuracy: 0.6496
#
# Epoch 00606: val_loss did not improve from 0.46087
# Epoch 607/2000
#  - 1s - loss: 2.2115e-04 - accuracy: 1.0000 - val_loss: 1.8880 - val_accuracy: 0.6550
#
# Epoch 00607: val_loss did not improve from 0.46087
# Epoch 608/2000
#  - 1s - loss: 2.1669e-04 - accuracy: 1.0000 - val_loss: 1.6301 - val_accuracy: 0.6554
#
# Epoch 00608: val_loss did not improve from 0.46087
# Epoch 609/2000
#  - 1s - loss: 2.1483e-04 - accuracy: 1.0000 - val_loss: 1.9390 - val_accuracy: 0.6554
#
# Epoch 00609: val_loss did not improve from 0.46087
# Epoch 610/2000
#  - 1s - loss: 2.0909e-04 - accuracy: 1.0000 - val_loss: 1.7690 - val_accuracy: 0.6554
#
# Epoch 00610: val_loss did not improve from 0.46087
# Epoch 611/2000
#  - 1s - loss: 2.0797e-04 - accuracy: 1.0000 - val_loss: 2.3884 - val_accuracy: 0.6573
#
# Epoch 00611: val_loss did not improve from 0.46087
# Epoch 612/2000
#  - 1s - loss: 2.0737e-04 - accuracy: 1.0000 - val_loss: 2.0599 - val_accuracy: 0.6554
#
# Epoch 00612: val_loss did not improve from 0.46087
# Epoch 613/2000
#  - 1s - loss: 2.0463e-04 - accuracy: 1.0000 - val_loss: 2.2777 - val_accuracy: 0.6538
#
# Epoch 00613: val_loss did not improve from 0.46087
# Epoch 614/2000
#  - 1s - loss: 2.0551e-04 - accuracy: 1.0000 - val_loss: 1.2298 - val_accuracy: 0.6519
#
# Epoch 00614: val_loss did not improve from 0.46087
# Epoch 615/2000
#  - 1s - loss: 1.9787e-04 - accuracy: 1.0000 - val_loss: 1.6938 - val_accuracy: 0.6538
#
# Epoch 00615: val_loss did not improve from 0.46087
# Epoch 616/2000
#  - 1s - loss: 1.9853e-04 - accuracy: 1.0000 - val_loss: 1.8116 - val_accuracy: 0.6527
#
# Epoch 00616: val_loss did not improve from 0.46087
# Epoch 617/2000
#  - 1s - loss: 1.9444e-04 - accuracy: 1.0000 - val_loss: 2.1352 - val_accuracy: 0.6550
#
# Epoch 00617: val_loss did not improve from 0.46087
# Epoch 618/2000
#  - 1s - loss: 1.9451e-04 - accuracy: 1.0000 - val_loss: 1.2787 - val_accuracy: 0.6554
#
# Epoch 00618: val_loss did not improve from 0.46087
# Epoch 619/2000
#  - 1s - loss: 1.9238e-04 - accuracy: 1.0000 - val_loss: 2.2767 - val_accuracy: 0.6523
#
# Epoch 00619: val_loss did not improve from 0.46087
# Epoch 620/2000
#  - 1s - loss: 1.9144e-04 - accuracy: 1.0000 - val_loss: 2.3542 - val_accuracy: 0.6550
#
# Epoch 00620: val_loss did not improve from 0.46087
# Epoch 621/2000
#  - 1s - loss: 1.8862e-04 - accuracy: 1.0000 - val_loss: 2.3588 - val_accuracy: 0.6558
#
# Epoch 00621: val_loss did not improve from 0.46087
# Epoch 622/2000
#  - 1s - loss: 1.8627e-04 - accuracy: 1.0000 - val_loss: 2.2682 - val_accuracy: 0.6512
#
# Epoch 00622: val_loss did not improve from 0.46087
# Epoch 623/2000
#  - 1s - loss: 1.8519e-04 - accuracy: 1.0000 - val_loss: 2.2852 - val_accuracy: 0.6538
#
# Epoch 00623: val_loss did not improve from 0.46087
# Epoch 624/2000
#  - 1s - loss: 1.8147e-04 - accuracy: 1.0000 - val_loss: 1.4166 - val_accuracy: 0.6546
#
# Epoch 00624: val_loss did not improve from 0.46087
# Epoch 625/2000
#  - 1s - loss: 1.8237e-04 - accuracy: 1.0000 - val_loss: 3.0117 - val_accuracy: 0.6542
#
# Epoch 00625: val_loss did not improve from 0.46087
# Epoch 626/2000
#  - 1s - loss: 1.8111e-04 - accuracy: 1.0000 - val_loss: 2.9686 - val_accuracy: 0.6550
#
# Epoch 00626: val_loss did not improve from 0.46087
# Epoch 627/2000
#  - 1s - loss: 1.7703e-04 - accuracy: 1.0000 - val_loss: 2.1411 - val_accuracy: 0.6565
#
# Epoch 00627: val_loss did not improve from 0.46087
# Epoch 628/2000
#  - 1s - loss: 1.7707e-04 - accuracy: 1.0000 - val_loss: 1.8160 - val_accuracy: 0.6565
#
# Epoch 00628: val_loss did not improve from 0.46087
# Epoch 629/2000
#  - 1s - loss: 1.7458e-04 - accuracy: 1.0000 - val_loss: 1.4588 - val_accuracy: 0.6565
#
# Epoch 00629: val_loss did not improve from 0.46087
# Epoch 630/2000
#  - 1s - loss: 1.7179e-04 - accuracy: 1.0000 - val_loss: 1.7804 - val_accuracy: 0.6496
#
# Epoch 00630: val_loss did not improve from 0.46087
# Epoch 631/2000
#  - 1s - loss: 1.7087e-04 - accuracy: 1.0000 - val_loss: 2.0749 - val_accuracy: 0.6569
#
# Epoch 00631: val_loss did not improve from 0.46087
# Epoch 632/2000
#  - 1s - loss: 1.7091e-04 - accuracy: 1.0000 - val_loss: 2.5081 - val_accuracy: 0.6527
#
# Epoch 00632: val_loss did not improve from 0.46087
# Epoch 633/2000
#  - 1s - loss: 1.7070e-04 - accuracy: 1.0000 - val_loss: 1.7289 - val_accuracy: 0.6508
#
# Epoch 00633: val_loss did not improve from 0.46087
# Epoch 634/2000
#  - 1s - loss: 1.6841e-04 - accuracy: 1.0000 - val_loss: 1.7829 - val_accuracy: 0.6542
#
# Epoch 00634: val_loss did not improve from 0.46087
# Epoch 635/2000
#  - 1s - loss: 1.6542e-04 - accuracy: 1.0000 - val_loss: 2.2340 - val_accuracy: 0.6546
#
# Epoch 00635: val_loss did not improve from 0.46087
# Epoch 636/2000
#  - 1s - loss: 1.6255e-04 - accuracy: 1.0000 - val_loss: 1.4666 - val_accuracy: 0.6519
#
# Epoch 00636: val_loss did not improve from 0.46087
# Epoch 637/2000
#  - 1s - loss: 1.6198e-04 - accuracy: 1.0000 - val_loss: 2.3244 - val_accuracy: 0.6508
#
# Epoch 00637: val_loss did not improve from 0.46087
# Epoch 638/2000
#  - 1s - loss: 1.6132e-04 - accuracy: 1.0000 - val_loss: 2.2562 - val_accuracy: 0.6527
#
# Epoch 00638: val_loss did not improve from 0.46087
# Epoch 639/2000
#  - 1s - loss: 1.5749e-04 - accuracy: 1.0000 - val_loss: 1.8303 - val_accuracy: 0.6538
#
# Epoch 00639: val_loss did not improve from 0.46087
# Epoch 640/2000
#  - 1s - loss: 1.5765e-04 - accuracy: 1.0000 - val_loss: 2.1044 - val_accuracy: 0.6565
#
# Epoch 00640: val_loss did not improve from 0.46087
# Epoch 641/2000
#  - 1s - loss: 1.5704e-04 - accuracy: 1.0000 - val_loss: 0.7727 - val_accuracy: 0.6558
#
# Epoch 00641: val_loss did not improve from 0.46087
# Epoch 642/2000
#  - 1s - loss: 1.5406e-04 - accuracy: 1.0000 - val_loss: 2.4091 - val_accuracy: 0.6523
#
# Epoch 00642: val_loss did not improve from 0.46087
# Epoch 643/2000
#  - 1s - loss: 1.5316e-04 - accuracy: 1.0000 - val_loss: 2.5164 - val_accuracy: 0.6554
#
# Epoch 00643: val_loss did not improve from 0.46087
# Epoch 644/2000
#  - 1s - loss: 1.5441e-04 - accuracy: 1.0000 - val_loss: 1.7253 - val_accuracy: 0.6542
#
# Epoch 00644: val_loss did not improve from 0.46087
# test_result.shape : (2600, 2)
# y_test[:5] : [1 1 0 0 0]
# y_score[:5] : [[9.6458012e-01]
#  [2.4314572e-01]
#  [1.3105641e-04]
#  [9.7437686e-01]
#  [8.9668506e-04]]
# y_test.shape : (2600, 1)
# y_score.shape : (2600, 1)
# len(y_test) : 2600
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:699: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [5.154768e-06, 5.248116e-06, 5.2385426e-06, 5.433999e-06, 5.026968e-06, 4.7656936e-06, 4.799916e-06, 4.8444576e-06, 4.977398e-06, 5.013587e-06, 5.2009855e-06, 5.2682476e-06, 5.127957e-06, 5.0546473e-06, 5.2656146e-06, 5.104906e-06, 5.278954e-06, 5.3602735e-06, 5.086076e-06, 5.2151345e-06, 5.812315e-06, 5.572728e-06, 6.021932e-06, 5.844044e-06, 5.751964e-06, 6.4341834e-06, 6.716121e-06, 6.4585106e-06, 6.903323e-06, 7.285286e-06, 7.703128e-06, 7.643539e-06, 7.844802e-06, 7.5083803e-06, 7.4909335e-06, 7.407107e-06, 7.059671e-06, 6.80348e-06, 6.2895756e-06, 6.2656522e-06, 6.3326083e-06, 6.3356115e-06, 6.3915154e-06, 6.332285e-06, 6.3733573e-06, 6.3106595e-06, 6.26283e-06, 6.2516174e-06, 6.470075e-06, 6.4422065e-06, 6.7811416e-06, 6.9737007e-06, 7.108615e-06, 7.240758e-06, 7.377162e-06, 7.854519e-06, 7.6250567e-06, 7.508343e-06, 7.3778892e-06, 7.5088383e-06, 7.7742e-06, 7.451198e-06, 7.2853704e-06, 7.738453e-06, 7.922919e-06, 8.720369e-06, 9.531793e-06, 1.05511535e-05, 1.00397265e-05, 9.996372e-06, 1.0205399e-05, 1.1016996e-05, 8.9604755e-06, 8.61631e-06, 8.706967e-06, 8.506322e-06, 8.556883e-06, 8.051528e-06, 8.169328e-06, 8.34916e-06, 8.510558e-06, 8.545016e-06, 8.424816e-06, 7.794504e-06, 7.569188e-06, 7.5791786e-06, 7.6179435e-06, 8.438156e-06, 8.001318e-06, 8.22227e-06, 8.288889e-06, 8.590318e-06, 8.453611e-06, 8.945972e-06, 9.007973e-06, 9.326126e-06, 9.383488e-06, 9.444857e-06, 9.485606e-06, 9.228498e-06, 9.808376e-06, 1.0054234e-05, 9.677348e-06, 9.954585e-06, 9.80098e-06, 9.842504e-06, 1.38330015e-05, 1.52559915e-05, 1.50704955e-05, 1.5779382e-05, 1.632724e-05, 1.6730963e-05, 1.6971186e-05, 1.6570317e-05, 1.5899082e-05, 1.5837522e-05, 1.625769e-05, 1.582435e-05, 1.5842075e-05, 1.658188e-05, 1.5858774e-05, 1.6603271e-05, 1.6390288e-05, 1.705188e-05, 1.6284472e-05, 1.6178885e-05, 2.066297e-05, 2.1240094e-05, 2.137381e-05, 2.065631e-05, 2.0014984e-05, 1.914415e-05, 1.9626232e-05, 2.0379039e-05, 2.0948557e-05, 2.1786776e-05, 2.0926074e-05, 2.1271022e-05, 2.2021632e-05, 2.2382728e-05, 2.2817963e-05, 2.2660632e-05, 2.2957322e-05, 2.5518522e-05, 2.5551566e-05, 2.6975029e-05, 2.7149923e-05, 3.0417186e-05, 3.0151858e-05, 2.963017e-05, 2.6410937e-05, 2.6217547e-05, 2.585768e-05, 2.8128903e-05, 2.6821665e-05, 2.7125778e-05, 2.80248e-05, 2.7599495e-05, 2.7639762e-05, 2.9807687e-05, 3.022097e-05, 2.8647142e-05, 3.1557844e-05, 2.9152532e-05, 2.7099468e-05, 2.6754611e-05, 3.1811724e-05, 3.2246953e-05, 3.288358e-05, 3.447056e-05, 3.4917855e-05, 3.512989e-05, 3.3243283e-05, 2.9553039e-05, 3.3234923e-05, 3.3023898e-05, 3.803934e-05, 3.5702833e-05, 3.5204754e-05, 3.6654852e-05, 3.6819154e-05, 3.840165e-05, 3.903186e-05, 3.943336e-05, 4.6916935e-05, 4.7014943e-05, 4.6800058e-05, 4.4550743e-05, 4.4297183e-05, 4.569084e-05, 5.8374855e-05, 5.7221318e-05, 5.9569797e-05, 6.2554784e-05, 6.3636166e-05, 6.503935e-05, 6.910267e-05, 7.303547e-05, 7.229692e-05, 7.1134884e-05, 7.2472365e-05, 7.5833705e-05, 7.6843484e-05, 7.6514945e-05, 7.699721e-05, 7.996512e-05, 7.6011565e-05, 8.864591e-05, 9.179704e-05, 9.388622e-05, 9.5367745e-05, 8.4778796e-05, 8.00602e-05, 8.090091e-05, 8.4055064e-05, 9.216774e-05, 8.728114e-05, 8.606054e-05, 8.54084e-05, 7.542352e-05, 7.0955764e-05, 6.752156e-05, 6.851531e-05, 6.211699e-05, 6.480476e-05, 6.2077284e-05, 6.496788e-05, 6.2569525e-05, 6.789843e-05, 6.8706824e-05, 7.028877e-05, 6.726244e-05, 6.995257e-05, 7.60219e-05, 7.4913994e-05, 7.4446056e-05, 7.709018e-05, 7.632168e-05, 7.505899e-05, 7.4114745e-05, 7.414251e-05, 7.270433e-05, 6.602925e-05, 6.201613e-05, 6.553097e-05, 6.818914e-05, 6.7726796e-05, 6.305198e-05, 6.266023e-05, 6.259803e-05, 6.204927e-05, 6.402068e-05, 6.4662716e-05, 6.537023e-05, 6.947572e-05, 6.854666e-05, 6.0617258e-05, 6.1012033e-05, 6.241433e-05, 6.467582e-05, 5.6801848e-05, 6.490928e-05, 6.6339766e-05, 6.5539156e-05, 6.56e-05, 6.40497e-05, 6.397168e-05, 6.531669e-05, 6.448998e-05, 6.472666e-05, 5.7685713e-05, 5.5284356e-05, 5.1629835e-05, 5.7898134e-05, 5.672798e-05, 5.8755657e-05,  ...

# %% [markdown]
# ### save npy

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from funcs_indicator import *

def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


#       set data features : ohlc, v, ep
time_index = ohlcv.index[np.sum(np.isnan(pr)):]

sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

#       scale with price    #
ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
sar = lucid_sar(sliced_ohlcv)
ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
senkou1, senkou2 = ichimoku(sliced_ohlcv)

#     min max scale   #
vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

pr_list = pr[np.sum(np.isnan(pr)):]
print("len(ohlc) :", len(ohlc))
print("len(pr) :", len(pr))

# break


#       set params    #
period = 45
key_i = i

plotting = True

data_x, data_pr, data_updown = [], [], []
data_index = []

for i in range(period, len(ohlc)):

  #   pr_list != 1 인 데이터만 사용한다
  # if 1:
  if pr_list[i] != 1:

    min_max = MinMaxScaler()
    
    #   prediction 을 제외한 이전 데이터를 사용해야한다
    temp_ohlc = ohlc.iloc[i - period : i].values
    # temp_long_ep = long_ep[i - period : i]          
    temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
    temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

    temp_close = min_max_scale(temp_ohlc[:, [3]])    

    price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

    if np.isnan(np.sum(price_data)):
      continue

    # print("price_data[:10] :", price_data[:10])
    # print("temp_ohlc.shape :", temp_ohlc.shape)
    # print("temp_long_ep.shape :", temp_long_ep.shape)
    # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
    # print("price_data.shape :", price_data.shape)

    if plotting:
      plt.plot(price_data)
      plt.show()

    ind_temp_ohlc = min_max_scale(temp_ohlc)
    temp_price_data = min_max_scale(price_data)
    # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


    if plotting:

      plt.plot(ind_temp_ohlc)
      plt.show()
      plt.plot(temp_price_data)
      plt.show()

      plotting = False
    # break

    #   vol -> min_max
    temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
    
    #                   feature selection                   #        
    temp_data = np.hstack((ind_temp_ohlc, temp_vol))

    # temp_data = trial_list[trial_number]
    # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
    # temp_data = temp_ohlc[:, [3]]
    # temp_data = ind_temp_ohlc[:, [3]]
    # temp_data = temp_close

    if np.isnan(np.sum(temp_data)):
      continue

    data_x.append(temp_data)
    data_pr.append(pr_list[i])
    data_index.append(time_index[i])
    data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


print('np.array(data_x).shape :', np.array(data_x).shape)
# print(data_x[0])


#       Reshape data for image deep - learning     #
_, row, col = np.array(data_x).shape

input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
# input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

#     1c to 3c    #
input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
# input_x = np.array(resize_npy(input_x))


input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
input_index = np.array(data_index).reshape(-1, 1)
print('input_x.shape :', input_x.shape)
print('input_x.dtype :', input_x.dtype)
print('input_pr.shape :', input_pr.shape)
print('input_ud.shape :', input_ud.shape)
print('input_index.shape :', input_index.shape)


# x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

#     do stacking   #
# if prev_x is None:
prev_x = input_x
prev_pr = input_pr
prev_ud = input_ud
prev_index = input_index

total_x = input_x
total_pr = input_pr
total_ud = input_ud
total_index = input_index

# else:
#   total_x = np.vstack((prev_x, input_x))
#   total_pr = np.vstack((prev_pr, input_pr))
#   total_ud = np.vstack((prev_ud, input_ud)) 
#   total_index = np.vstack((prev_index, input_index)) 

#   prev_x = total_x
#   prev_pr = total_pr
#   prev_ud = total_ud
#   prev_index = total_index

print('total_x.shape :', total_x.shape)
print('total_pr.shape :', total_pr.shape)
print('total_ud.shape :', total_ud.shape)
print('prev_index.shape :', prev_index.shape)


# _, row, col, _ = input_x.shape
# _, row, col = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


#         get unique timestamp      #
print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

#                 don't shuffle timeseries data                 #
stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)

index_train = np.array(index_train)
index_val = np.array(index_val)
index_test = np.array(index_test)
  
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

symbol_name = key.split(' ')[1].split('.')[0]

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)

np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %% [markdown]
# ### load npy

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


symbol_name = "SXPUSDT"
period = 45

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)


x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')


pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

# total_x = np.vstack((x_train, x_val, x_test))
# total_pr = np.vstack((pr_train, pr_val, pr_test))

# print("total_x.shape :", total_x.shape)
# Out:
# x series loaded !
# y series loaded !

# %% [markdown]
# ### rapid pr selection

# %%
plt.plot(pr)
plt.show()

pr_thresh = 1.005
rapid_pct = len(pr[pr > pr_thresh]) / len(pr)

print(rapid_pct)
# Out:
# 0.36131427304964536

# %% [markdown]
# ### class_weight & categorization

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


def class_ratio(in_list):

  return in_list / in_list[1]
  
y_train = np.where(pr_train > pr_thresh, 1, 0)
y_test = np.where(pr_test > pr_thresh, 1, 0)
y_val = np.where(pr_val > pr_thresh, 1, 0)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

# try:
print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

# except Exception as e:
  # print(e)

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)
# Out:
# x_train.shape : (10755, 45, 5, 3)
# x_test.shape : (3586, 45, 5, 3)
# x_val.shape : (3585, 45, 5, 3)
# y_train.shape : (10755, 1)
# y_test.shape : (3586, 1)
# y_val.shape : (3585, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([6864, 3891])) [1.76407093 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2303, 1282])) [1.79641186 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2291, 1295])) [1.76911197 1.        ]
# class_weights : {0: 0.7834353146853147, 1: 1.382035466461064}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10755, 2)
# y_val_ohe.shape : (3585, 2)
# y_test_ohe.shape : (3586, 2)

# %% [markdown]
# ### augment

# %%
from keras.preprocessing.image import ImageDataGenerator 

datagen = ImageDataGenerator( 
    # rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)


batch_size = 512


for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break

# %% [markdown]
# ### train

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'

# batch_size = 512

model = FER_Model(input_shape=x_train.shape[1:])
opt = Adam(lr=0.00001, decay=0.000005)
# opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model_name = 'classifier_%s_cnn_updown_rascend_1005_%s_tvnon_shuffle.h5' % (period, symbol_name)



checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]
# callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)

# %% [markdown]
# ### load model

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'


model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)


model = keras.models.load_model(ckpt_path + model_name)

# %% [markdown]
# ### test

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)

  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.title(symbol_name)
plt.show()
# Out:
# test_result.shape : (3586, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.04767541]
#  [0.00195843]
#  [0.1600004 ]
#  [0.14308068]
#  [0.00154134]]
# y_test.shape : (3586, 1)
# y_score.shape : (3586, 1)
# len(y_test) : 3586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [5.2342257e-05, 5.224965e-05, 5.119804e-05, 4.92728e-05, 4.9822964e-05, 5.1722614e-05, 5.241118e-05, 5.2653213e-05, 5.4707263e-05, 5.469477e-05, 5.5414595e-05, 5.4917986e-05, 5.5296758e-05, 5.482614e-05, 5.5313794e-05, 5.619928e-05, 5.7341047e-05, 5.8005982e-05, 5.7726982e-05, 5.8714617e-05, 5.924952e-05, 5.9157777e-05, 6.0730683e-05, 6.09751e-05, 6.1022805e-05, 6.194849e-05, 6.286581e-05, 6.367981e-05, 6.4932676e-05, 6.5769455e-05, 6.7948844e-05, 6.841887e-05, 6.806048e-05, 6.849957e-05, 6.9895126e-05, 7.091783e-05, 7.1859926e-05, 7.350335e-05, 7.346305e-05, 7.395025e-05, 7.968566e-05, 7.8947196e-05, 7.8341516e-05, 7.918357e-05, 7.912106e-05, 8.1205275e-05, 8.341604e-05, 8.386569e-05, 8.3938816e-05, 8.564359e-05, 7.970025e-05, 8.0672995e-05, 8.083643e-05, 8.727269e-05, 8.9510206e-05, 8.959228e-05, 8.962243e-05, 8.8885776e-05, 9.023229e-05, 9.169206e-05, 9.0867565e-05, 9.033618e-05, 9.429348e-05, 9.3799725e-05, 9.566918e-05, 9.6586686e-05, 9.398621e-05, 9.4105475e-05, 9.411831e-05, 9.466633e-05, 9.5054995e-05, 9.854746e-05, 9.9124496e-05, 0.00010614127, 0.000108136, 0.00010740872, 0.00010814099, 0.00010723293, 0.00010745465, 0.00010824714, 0.00010731329, 0.000108584194, 0.00010868803, 0.00010257258, 0.000101516416, 0.00010031571, 0.000103715196, 0.00010502134, 0.00010611775, 0.00010916348, 0.00010594193, 0.000104194485, 0.00010433929, 0.000104219216, 0.00010764128, 0.00010433711, 0.00010385209, 0.000106006635, 0.00010645543, 0.00010741285, 0.00010793885, 0.00010773461, 0.000107400294, 0.000107067055, 0.000110430265, 0.00010961514, 0.000110994966, 0.000109511326, 0.00011019072, 0.00011165826, 0.00011095228, 0.00011055433, 0.00011134691, 0.000109883986, 0.0001112986, 0.0001123257, 0.000114077506, 0.00011583454, 0.00011730796, 0.00011702095, 0.00012883096, 0.00012502969, 0.0001211144, 0.00012085415, 0.00012023333, 0.000121178586, 0.0001113643, 0.00011255329, 0.00011366057, 0.00011109531, 0.00011435672, 0.00011691414, 0.00011724194, 0.00011877652, 0.00011876732, 0.00012343662, 0.00012398258, 0.00012742475, 0.00013299534, 0.0001345203, 0.00013497796, 0.00013495858, 0.00013710273, 0.00013803714, 0.00013533776, 0.00014049193, 0.00013862025, 0.00013925365, 0.00013978127, 0.00014475136, 0.00014560782, 0.00014417202, 0.00015133772, 0.0001492487, 0.00015156744, 0.00015025465, 0.00015172384, 0.0001483679, 0.00015025485, 0.00017470514, 0.00017807752, 0.00018197432, 0.00018371776, 0.00018367464, 0.0001920926, 0.00019288564, 0.00020759454, 0.00020698183, 0.00023446795, 0.00023864223, 0.00024568185, 0.0002499611, 0.00025658592, 0.00025730263, 0.00025887572, 0.00026280092, 0.0002670472, 0.00027564648, 0.0002803122, 0.0002723821, 0.00027754836, 0.00027732784, 0.00028359605, 0.0002916876, 0.0002884358, 0.0002919522, 0.00029502896, 0.00028943687, 0.00028854128, 0.00029137387, 0.0002962364, 0.00029461124, 0.00029948735, 0.00030449385, 0.0002996868, 0.00029990985, 0.00029333428, 0.0002965417, 0.00029836778, 0.00029298887, 0.00030178405, 0.00029634495, 0.00029906907, 0.00029697176, 0.0002963374, 0.000295097, 0.000312998, 0.00031196643, 0.00031936396, 0.00032101592, 0.00032832168, 0.0003258465, 0.00033274552, 0.0003290262, 0.00033229083, 0.00034132804, 0.00033895372, 0.00035075872, 0.00034744598, 0.00034445102, 0.00032778905, 0.0003323982, 0.00034709118, 0.0003477889, 0.00035424854, 0.00040091967, 0.00042115894, 0.00041995398, 0.00041660885, 0.00042408038, 0.00044065266, 0.00045346154, 0.00044463656, 0.00047572926, 0.0005098468, 0.00050058664, 0.00049340463, 0.0004999284, 0.0005000292, 0.0004849475, 0.00048356556, 0.0004768842, 0.00047515446, 0.00046261746, 0.00046790738, 0.000461418, 0.00046818578, 0.00046653874, 0.00047877917, 0.00048961974, 0.0005021864, 0.00051662093, 0.00052976055, 0.00053512596, 0.000552535, 0.0005820823, 0.00058700517, 0.00059161586, 0.0005911128, 0.00059325877, 0.00059789245, 0.0006161917, 0.00060233, 0.0006037665, 0.0005968395, 0.0006049573, 0.0006040889, 0.0006045968, 0.000620602, 0.00062113034, 0.0006333279, ...

# %%
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)], linestyle='--', color='r')
plt.title(symbol_name + '\n' + str(new_thresh[np.argmax(acc_pr_bythr)]))
plt.show()

# %%
thresh = 0.5866
y_pred = np.where(y_score[:600, -1] > thresh, 1, 0)
# print('y_pred.shape :', y_pred.shape)
# print('y_pred :', y_pred)

#     compare precision     #

# print('precision :', precision_score(y_test, y_pred))
# print('recall :', recall_score(y_test, y_pred))
# print()

# print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
# print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

# # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
# # plt.show()  
# print()

#     check win-ratio improvement     #
cmat = confusion_matrix(y_test[:len(y_pred)], y_pred)
# print(cmat)
# print(np.sum(cmat, axis=1))

test_size = len(y_test[:len(y_pred)])
test_pr_list = pr_test[:len(y_pred)]
# print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
# print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

# print('pr_test.shape :', pr_test.shape)

# print(y_pred)
# print(test_pr_list)
pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

plt.plot(np.cumprod(pred_pr_list))
plt.show()

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72a922dd9685> in <module>()
#       5 # print(index_train)
#       6 # print(index_val)
# ----> 7 total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index))
#       8 timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train))
#       9 timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val))
#
# NameError: name 'input_index' is not defined

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
