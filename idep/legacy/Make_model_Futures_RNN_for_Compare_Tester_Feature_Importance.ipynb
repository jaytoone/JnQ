# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %tensorflow_version 2.x
# import tensorflow as tf
# print(tf.__version__)
# import keras
# print(keras.__version__)

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %matplotlib inline
import random

# %tensorflow_version 1.x
import tensorflow as tf

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.model_selection import train_test_split

# Data Class Weight
from sklearn.utils import class_weight
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard



def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    #             LSTM Version            #
    # net = layers.LSTM(10, return_sequences=False)(visible)
    net = layers.Dense(64, activation='relu')(visible)
    # net = layers.Dropout(0.2)(net)


    # net = layers.LSTM(5, return_sequences=True)(net)
    net = layers.Dense(32, activation='relu')(net)
    net = layers.Dropout(0.2)(net)

    # net = layers.LSTM(5, return_sequences=True)(visible)
    # net = layers.Dense(16, activation='relu')(net)
    # # net = layers.Dropout(0.2)(net)

    # net = layers.LSTM(1, return_sequences=False)(visible)
    # net = layers.Dense(8, activation='relu')(net)
    # net = layers.Dropout(0.5)(net)

    # net = layers.Conv2D(64, kernel_size=3, padding='same')(visible)
    # net = layers.Activation('relu')(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    # shortcut_1 = net

    # net = layers.Conv2D(32, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    # shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
    
    return model



# seed = 1213
# np.random.seed(seed)
# random.seed(seed)
# tf.random.set_random_seed(seed)
# tf.random.set_seed(seed)

num_classes = 2
batch_size = 30


gdrive_path = '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/'


model_range = range(1180, 1214)
features = [[0, 1, 2, 3], [i for i in range(4, 10)], [i for i in range(10, 16)], [i for i in range(16, 18)],
            [i for i in range(18, 21)], [i for i in range(21, 24)], [i for i in range(24, 26)], [i for i in range(26, 29)],
            [i for i in range(29, 31)]]
feature_name = ['ohlc', 'minor ST', 'Major ST', 'EMA', 'minor ST Trend', 'Major ST Trend', 'CB', 'Fisher', 'Trix']
break

for model_num in model_range:

  # try:

    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % model_num)
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s.npy' % model_num).reshape(-1, 1)

    #         Feature Selection      #
    for feature_i in range(len(features)):
      # Made_X = Made_X_[:, :, [-4]]
      # Made_X = Made_X_[:, :, :4]
      Made_X = Made_X_[:, :, features[feature_i]]

      #             Train Limitation          #
      # Made_X = Made_X[-limit_train_size:]
      # Made_Y = Made_Y[-limit_train_size:]
      # print(Made_X.shape)
      # print(Made_Y.shape)
      # break

      row = Made_X.shape[1]
      col = Made_X.shape[2]

      X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                          shuffle=False)

      print('X_train.shape :', X_train.shape)
      print('X_val.shape :', X_val.shape)


      label = Y_train.reshape(-1, )
      # print(label.shape)

      Y_train = np_utils.to_categorical(Y_train, num_classes)
      Y_val = np_utils.to_categorical(Y_val, num_classes)
      
      print('Y_train.shape :', Y_train.shape)
      print('Y_val.shape :', Y_val.shape)

      
      #         Get Class_Weights (--> should be considered only for TrainSet)       #
      class_weights = class_weight.compute_class_weight('balanced', 
                                                        classes=np.unique(label),
                                                        y=label)
      class_weights = dict(enumerate(class_weights))
      print(class_weights)
      # quit()

      model = FER_Model((row, col))
      opt = Adam(lr=0.0001, decay=1e-6)

      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
        
          
      filepath = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (model_num, feature_i)
      checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_accuracy', patience=100)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 1000
      history = model.fit(X_train, Y_train,
                          steps_per_epoch=int(len(X_train) / batch_size), 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=(X_val, Y_val),  
                          validation_steps=int(len(X_val) / batch_size),
                          shuffle=False)
      
    # except Exception as e:
    #   print('Error occured :', e)
# Out:
#   File "<ipython-input-3-10bea324ae58>", line 115
#     break
#          ^
# SyntaxError: 'break' outside loop

# %% [markdown]
# ### ***Backtest***

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, precision_score, recall_score, roc_curve, auc


trade_on = True
show_trade_data = False

input_data_length = 30 # <-- Need for Back-Test
test_model_range = range(1044, 1078)
all_pair_profit_result = list()
all_pair_precision_auc = list()
all_pair_f1_auc = list()
all_pair_auc = list()
for model_num, test_model_num in zip(model_range, test_model_range):

  # try:

    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % model_num)
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s.npy' % model_num).reshape(-1, 1)

    Made_X_test_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % test_model_num)
    #     for trade, ohlc data    #
    Made_Z_test = np.load(gdrive_path + 'Made_X/Made_Z %s.npy' % test_model_num)

    # Made_X2 = np.load(gdrive_path + 'Made_X/Made_X 30_%s.npy' % (30, 219))
    # Made_Y2 = np.load(gdrive_path + 'Made_X/Made_Y 30_%s.npy' % (30, 219))

    model_list = features

    total_precision_result = list()
    total_f1_result = list()
    total_auc_result = list()
    total_profit_result = list()
    total_pr = list()
    plt.figure(figsize=(20, 10))

    #         Feature Selection      #
    for specific_num in range(len(model_list)):
      # Made_X = Made_X_[:, :, [-4]]
      # Made_X = Made_X_[:, :, :4]
      Made_X = Made_X_[:, :, features[specific_num]]
      # Made_X2 = Made_X2[:, :, [0, 2, 3, 1]]

      #         Train Limit         #
      # Made_X = Made_X[-4000:]
      # Made_Y = Made_Y[-4000:]
      Made_X_test = Made_X_test_[:, :, :4]
      print('Made_X.shape :', Made_X.shape)
      print('Made_Y.shape :', Made_Y.shape)
      print('Made_X_test.shape :', Made_X_test.shape)
      print('Made_Z_test.shape :', Made_Z_test.shape)

      # print('min(Made_Z_test) :', np.min(Made_Z_test))
      # print(sum(sum(Made_X != Made_X2)))
      # break

      row = Made_X.shape[1]
      col = Made_X.shape[2]

      X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                          shuffle=False)
      X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
      X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)

      Y_train = Y_train.astype('float32')
      Y_val = Y_val.astype('float32')
      
      X_test = Made_X_test
      print('np.unique(Made_Y) :', np.unique(Made_Y, return_counts=True))
      print('np.unique(Y_train) :', np.unique(Y_train, return_counts=True))
      print('np.unique(Y_val) :', np.unique(Y_val, return_counts=True))

      Y_train = np_utils.to_categorical(Y_train, num_classes)
      Y_val = np_utils.to_categorical(Y_val, num_classes)
      
      print('X_train.shape :', X_train.shape)
      print('X_val.shape :', X_val.shape)

      print('model_num :', model_num)

      model_path = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (model_num, specific_num)
      model = load_model(model_path)

      #     val, train -> confidence 와 evaluate 용
      val_y_pred_ = model.predict(X_val, verbose=1)
      train_y_pred_ = model.predict(X_train, verbose=1)

      #     test -> profit 용
      # test_y_pred_ = model.predict(X_test, verbose=1)

      train_val_predmin = min(min(val_y_pred_[:, [1]]), min(train_y_pred_[:, [1]]))
      train_val_predmax = max(max(val_y_pred_[:, [1]]), max(train_y_pred_[:, [1]]))

      
      for index, y_pred_ in enumerate([val_y_pred_, train_y_pred_]):

        # print('len(y_pred_) :', len(y_pred_))
        target_column = y_pred_[:, [1]]
        # column_min, column_max = train_y_pred_.min(),train_y_pred_.max()
        column_min, column_max = min(target_column),max(target_column)
        # print(column_min, column_max)

        if index == 0:
          _, model_acc = model.evaluate(X_val, Y_val, batch_size=batch_size)
        elif index == 1:
          _, model_acc = model.evaluate(X_train, Y_train, batch_size=batch_size)

        x_ticks = np.arange(0.5, 1, 0.005)
        # x_ticks = [0.6]

        precision_result = list()
        f1_result = list()
        profit_result = list()        
        for confidence in x_ticks:
          # confidence = 0.9

          # if column_max < 0.5:
          #   break
          # else:
          #   scaled_confidence = .5 + (column_max - .5) * confidence
          # scaled_confidence = column_min + (column_max - column_min) * confidence
          scaled_confidence = train_val_predmin + (train_val_predmax - train_val_predmin) * confidence
          # scaled_confidence = confidence

          # print(scaled_confidence)
          # print('confidence :', confidence)

          y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )

          pred_true, real_true, true_true = 0, 0, 0   

          #     결국, Categorical 은 index 값으로 value 를 나타내는 것    #
          # t_te = np.argmax(Y_test, axis=1)            
          if index == 0:
            t_te = np.argmax(Y_val, axis=1)
          elif index == 1:
            t_te = np.argmax(Y_train, axis=1)

          #       Trading Session, Accumulate Profit     #
          elif index == 2:

              accumulated_profit = 1.

              if trade_on:
                tp_ratio = 3
                target_percentage = 0.05
                sl_least_gap_ratio = 0.05

                long_marker_x = list()
                long_marker_y = list()
                tp_marker_x = list()
                tp_marker_y = list()
                sl_marker_x = list()
                sl_marker_y = list()
                tp_level_list_x = list()
                tp_level_list_y = list()
                sl_level_list_x = list()
                sl_level_list_y = list()

                #         This column order should be changed     #
                high, low, close = np.split(Made_Z_test[:, 1:4], 3, axis=1) # <-- Column Order should be changed
                # break
                i = input_data_length
                while (i < len(y_pred)):

                  #     Long    #
                  if y_pred[i] == 1:  

                    long_sl = np.min(low[i + 1 -input_data_length:i + 1])
                    short_sl = np.max(high[i + 1 -input_data_length:i + 1])
                    tp_level_0 = (close[i] - long_sl) * tp_ratio * 1/3 + close[i]
                    tp_level_1 = (close[i] - long_sl) * tp_ratio * 2/3 + close[i]
                    tp_level = (close[i] - long_sl) * tp_ratio + close[i]
                    tp_count = 3

                    #       Consider 'sl_least_gap'     #
                    if not close[i] >= long_sl + (short_sl - long_sl) * sl_least_gap_ratio:
                      i += 1
                      if i >= len(y_pred):
                        break
                      continue

                    if show_trade_data: print(i, 'long')
                    pred_true += 1

                    long_marker_x.append(i)
                    long_marker_y.append(close[i])

                    if i + 1 >= len(y_pred):
                      break
                    
                    for j in range(i + 1, len(y_pred)):

                      if show_trade_data: print(long_sl, low[j], high[j], tp_level)
                      tp_level_list_x.append(j)
                      tp_level_list_y.append(tp_level)

                      if high[j] > tp_level_0 and tp_count == 3:
                        accumulated_profit *= 1 + target_percentage * tp_ratio * 1/3 * .25
                        tp_count -= 1
                      elif high[j] > tp_level_0 and tp_count == 2:
                        accumulated_profit *= 1 + target_percentage * tp_ratio * 2/3 * .25
                        tp_count -= 1
                      elif high[j] > tp_level and tp_count == 1:
                        accumulated_profit *= 1 + target_percentage * tp_ratio * .5
                        if show_trade_data: print(j, 'tp, accum.profit :', accumulated_profit)  
                        tp_marker_x.append(j)
                        tp_marker_y.append(high[j])
                        real_true += 1
                        break
                      
                      elif low[j] < long_sl:
                        accumulated_profit *= 1 - target_percentage
                        if show_trade_data: print(j, 'tp, accum.profit :', accumulated_profit)          
                        sl_marker_x.append(j)
                        sl_marker_y.append(low[j])
                        break

                    i = j

                  i += 1
                  # print('i, len(y_pred) :', i, len(y_pred))
                  if i >= len(y_pred):
                    break

              profit_result.append(accumulated_profit)

          if index != 2:

            for i in range(len(y_pred)):
              if y_pred[i] == 1:  
                pred_true += 1
                if t_te[i] == y_pred[i]:
                  real_true += 1

            #     precision   #
            # precision = precision_score(t_te, y_pred) * 100
            f1 = f1_score(t_te, y_pred) * 100

          if pred_true != 0:
            true_true = real_true / pred_true * 100
            # print('precision, true_true :', precision, true_true)

            #     Test 는 따로    #
            #     in confidence loop    #
          if index != 2:
            precision_result.append(true_true)
            f1_result.append(f1)

          # print('Real True / Pred True : %s / %s' % (real_true, pred_true))
          # print('Accuracy : %.2f %%' % (true_true))
          # print('Accumulated Profit : %.3f' % accumulated_profit)
          # print()
        
        #     in val, train / test pred loop    #
        if index != 2:
          fpr, tpr, thr = roc_curve(t_te, target_column)
          auc_ = auc(fpr, tpr) * 100

          # if index == 0:
          #   print('len(fpr) in 0 :', len(fpr))
          # elif index == 1:
          #   print('len(fpr) in 1 :', len(fpr))

          total_precision_result.append(precision_result)
          total_f1_result.append(f1_result)
          total_auc_result.append(auc_)
          total_pr.append((fpr, tpr))
        
        if index == 2:
          total_profit_result.append(profit_result)   

      all_pair_profit_result.append(profit_result)

        #          Show Entry Point       #
        # plt.subplot(2, 1, index + 1 + model_i * 1)
        # plt.plot(close)
        # plt.plot(long_marker_x, long_marker_y, 'o', color='green')             
        # plt.plot(tp_marker_x, tp_marker_y, 'o', color='blue')
        # plt.plot(sl_marker_x, sl_marker_y, 'o', color='red')
        # plt.plot(tp_level_list_x, tp_level_list_y, '.', color='blue')
        # plt.title('Accumulated Profit : %.3f' % accumulated_profit, color='white')

    print('len(total_precision_result) :', len(total_precision_result))
    print('len(total_f1_result) :', len(total_f1_result))
    print('len(total_auc_result) :', len(total_auc_result))
    print('len(total_profit_result) :', len(total_profit_result))

    cmap = plt.cm.get_cmap(name='prism', lut=(len(model_list)))

    #         Show Precision by confidence    #
    #       even index => Val / odd index => Train    #
    plt.subplot(2, 7, 1)
    # print(total_precision_result[0][1:5])
    # print(total_precision_result[1][1:5])
    # test_np = np.array([total_precision_result[0::2], total_precision_result[1::2]])
    mean_precision = np.mean(np.array([total_precision_result[0::2], total_precision_result[1::2]]), axis=0)
    # print(mean_precision[0][1:5])
    mean_precision_auc = [np.sum(mean_precision[auc_i])/len(x_ticks) for auc_i in range(len(model_list))]
    # for i in range(len(model_list)):
    #   plt.plot(x_ticks, mean_precision[i], label='%s' % i, c=cmap(i))
    plt.bar(range(len(model_list)), mean_precision_auc, color='g')
    plt.xticks(range(len(model_list)), feature_name, rotation=45)
    plt.axhline(50, linestyle='--', color='red')
    plt.ylim(-5, 105)
    # plt.legend()
    plt.title('Mean Precision AUC', color='white', fontsize=10)

    print('last index =', index)
    
    plt.subplot(2, 7, 3)
    mean_f1 = np.mean(np.array([total_f1_result[0::2], total_f1_result[1::2]]), axis=0)
    mean_f1_auc = [np.sum(mean_f1[auc_i])/len(x_ticks) for auc_i in range(len(model_list))]
    # for i in range(len(model_list)):
    #   plt.plot(x_ticks, mean_f1[i], label='%s' % i, c=cmap(i))
    plt.bar(range(len(model_list)), mean_f1_auc, color='g')
    plt.xticks(range(len(model_list)), feature_name, rotation=45)
    plt.axhline(50, linestyle='--', color='red')
    plt.ylim(-5, 105)
    # plt.legend()
    plt.title('Mean F1', color='white', fontsize=10) 

    plt.subplot(2, 7, 4)
    #         Can compare only AUC      # --> Different length (fpr, tpr)
    mean_auc = np.mean(np.array([total_auc_result[0::2], total_auc_result[1::2]]), axis=0)
    plt.bar(range(len(model_list)), mean_auc, color='g')
    plt.xticks(range(len(model_list)), feature_name, rotation=45)
    plt.ylim(-5, 105)
    plt.axhline(50, linestyle='--', color='red')
    plt.title('Mean AUC', color='white', fontsize=10)   

    plt.subplot(2, 7, 5)
    plt.plot(Made_X_[-len(X_val):, [-1], [3]])
    plt.subplot(2, 7, 6)
    plt.plot(Made_X_[:len(X_train), [-1], [3]])
    plt.subplot(2, 7, 7)
    plt.plot(Made_Z_test[:, 3])

    plt.show()

    all_pair_precision_auc.append(mean_precision_auc)
    all_pair_f1_auc.append(mean_f1_auc)
    all_pair_auc.append(mean_auc)

      #   except Exception as e:
      #     print('Error occured : ', e)
      # print()

      # break
# Out:
# Made_X.shape : (2290, 30, 4)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 4)
# X_val.shape : (687, 30, 4)
# model_num : 1180
# 22/22 [==============================] - 1s 2ms/step
# 51/51 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6757 - accuracy: 0.9229
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6840 - accuracy: 0.7168
# Made_X.shape : (2290, 30, 6)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 6)
# X_val.shape : (687, 30, 6)
# model_num : 1180
# 22/22 [==============================] - 0s 1ms/step
# 51/51 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6251 - accuracy: 0.9185
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6605 - accuracy: 0.7168
# Made_X.shape : (2290, 30, 6)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 6)
# X_val.shape : (687, 30, 6)
# model_num : 1180
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6763 - accuracy: 0.4702
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5783 - accuracy: 0.7617
# Made_X.shape : (2290, 30, 2)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 2)
# X_val.shape : (687, 30, 2)
# model_num : 1180
# 22/22 [==============================] - 0s 1ms/step
# 51/51 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6685 - accuracy: 0.9214
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6807 - accuracy: 0.7168
# Made_X.shape : (2290, 30, 3)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 3)
# X_val.shape : (687, 30, 3)
# model_num : 1180
# 22/22 [==============================] - 0s 1ms/step
# 51/51 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7476 - accuracy: 0.5633
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.7511
# Made_X.shape : (2290, 30, 3)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 3)
# X_val.shape : (687, 30, 3)
# model_num : 1180
# 22/22 [==============================] - 0s 1ms/step
# 51/51 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7992 - accuracy: 0.8544
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6088 - accuracy: 0.7455
# Made_X.shape : (2290, 30, 2)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 2)
# X_val.shape : (687, 30, 2)
# model_num : 1180
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6416 - accuracy: 0.9185
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6670 - accuracy: 0.7168
# Made_X.shape : (2290, 30, 3)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 3)
# X_val.shape : (687, 30, 3)
# model_num : 1180
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6602 - accuracy: 0.6405
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6603 - accuracy: 0.6575
# Made_X.shape : (2290, 30, 2)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 2)
# X_val.shape : (687, 30, 2)
# model_num : 1180
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6396 - accuracy: 0.6681
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6632 - accuracy: 0.6619
# len(total_precision_result) : 18
# len(total_f1_result) : 18
# len(total_auc_result) : 18
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2283, 30, 4)
# Made_Y.shape : (2283, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1508,  775]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1187,  411]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([321, 364]))
# X_train.shape : (1598, 30, 4)
# X_val.shape : (685, 30, 4)
# model_num : 1181
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6789 - accuracy: 0.6745
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6588 - accuracy: 0.6471
# Made_X.shape : (2283, 30, 6)
# Made_Y.shape : (2283, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1508,  775]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1187,  411]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([321, 364]))
# X_train.shape : (1598, 30, 6)
# X_val.shape : (685, 30, 6)
# model_num : 1181
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7225 - accuracy: 0.6219
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6575 - accuracy: 0.6421
# Made_X.shape : (2283, 30, 6)
# Made_Y.shape : (2283, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1508,  775]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1187,  411]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([321, 364]))
# X_train.shape : (1598, 30, 6)
# X_val.shape : (685, 30, 6)
# model_num : 1181
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6957 - accuracy: 0.5401
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6929 - accuracy: 0.4487
# Made_X.shape : (2283, 30, 2)
# Made_Y.shape : (2283, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1508,  775]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1187,  411]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([321, 364]))
# X_train.shape : (1598, 30, 2)
# X_val.shape : (685, 30, 2)
# model_num : 1181
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7467 - accuracy: 0.6964
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6545 - accuracy: 0.6208
# Made_X.shape : (2283, 30, 3)
# Made_Y.shape : (2283, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1508,  775]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1187,  411]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([321, 364]))
# X_train.shape : (1598, 30, 3)
# X_val.shape : (685, 30, 3)
# model_num : 1181
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6884 - accuracy: 0.6102
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6085 - accuracy: 0.6865
# Made_X.shape : (2283, 30, 3)
# Made_Y.shape : (2283, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1508,  775]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1187,  411]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([321, 364]))
# X_train.shape : (1598, 30, 3)
# X_val.shape : (685, 30, 3)
# model_num : 1181
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7013 - accuracy: 0.4847
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6516 - accuracy: 0.6940
# Made_X.shape : (2283, 30, 2)
# Made_Y.shape : (2283, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1508,  775]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1187,  411]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([321, 364]))
# X_train.shape : (1598, 30, 2)
# X_val.shape : (685, 30, 2)
# model_num : 1181
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7073 - accuracy: 0.6569
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6828 - accuracy: 0.6496
# Made_X.shape : (2283, 30, 3)
# Made_Y.shape : (2283, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1508,  775]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1187,  411]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([321, 364]))
# X_train.shape : (1598, 30, 3)
# X_val.shape : (685, 30, 3)
# model_num : 1181
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6848 - accuracy: 0.5474
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6820 - accuracy: 0.5319
# Made_X.shape : (2283, 30, 2)
# Made_Y.shape : (2283, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1508,  775]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1187,  411]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([321, 364]))
# X_train.shape : (1598, 30, 2)
# X_val.shape : (685, 30, 2)
# model_num : 1181
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7048 - accuracy: 0.4686
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6627 - accuracy: 0.7428
# len(total_precision_result) : 18
# len(total_f1_result) : 18
# len(total_auc_result) : 18
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2206, 30, 4)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1696,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1206,  338]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([490, 172]))
# X_train.shape : (1544, 30, 4)
# X_val.shape : (662, 30, 4)
# model_num : 1182
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6710 - accuracy: 0.7659
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6547 - accuracy: 0.7811
# Made_X.shape : (2206, 30, 6)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1696,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1206,  338]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([490, 172]))
# X_train.shape : (1544, 30, 6)
# X_val.shape : (662, 30, 6)
# model_num : 1182
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6669 - accuracy: 0.7538
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6445 - accuracy: 0.7811
# Made_X.shape : (2206, 30, 6)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1696,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1206,  338]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([490, 172]))
# X_train.shape : (1544, 30, 6)
# X_val.shape : (662, 30, 6)
# model_num : 1182
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6841 - accuracy: 0.7387
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.7811
# Made_X.shape : (2206, 30, 2)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1696,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1206,  338]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([490, 172]))
# X_train.shape : (1544, 30, 2)
# X_val.shape : (662, 30, 2)
# model_num : 1182
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6723 - accuracy: 0.7568
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6582 - accuracy: 0.7811
# Made_X.shape : (2206, 30, 3)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1696,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1206,  338]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([490, 172]))
# X_train.shape : (1544, 30, 3)
# X_val.shape : (662, 30, 3)
# model_num : 1182
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7137 - accuracy: 0.6526
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5303 - accuracy: 0.7539
# Made_X.shape : (2206, 30, 3)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1696,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1206,  338]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([490, 172]))
# X_train.shape : (1544, 30, 3)
# X_val.shape : (662, 30, 3)
# model_num : 1182
# 21/21 [==============================] - 0s 1ms/step
# 49/49 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6624 - accuracy: 0.7009
# 52/52 [==============================] - 0s 2ms/step - loss: 0.7268 - accuracy: 0.3536
# Made_X.shape : (2206, 30, 2)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1696,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1206,  338]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([490, 172]))
# X_train.shape : (1544, 30, 2)
# X_val.shape : (662, 30, 2)
# model_num : 1182
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6670 - accuracy: 0.7402
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6620 - accuracy: 0.7811
# Made_X.shape : (2206, 30, 3)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1696,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1206,  338]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([490, 172]))
# X_train.shape : (1544, 30, 3)
# X_val.shape : (662, 30, 3)
# model_num : 1182
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 1.1206 - accuracy: 0.6375
# 52/52 [==============================] - 0s 2ms/step - loss: 0.2282 - accuracy: 0.9152
# Made_X.shape : (2206, 30, 2)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1696,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1206,  338]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([490, 172]))
# X_train.shape : (1544, 30, 2)
# X_val.shape : (662, 30, 2)
# model_num : 1182
# 21/21 [==============================] - 0s 1ms/step
# 49/49 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7173 - accuracy: 0.6329
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5727 - accuracy: 0.7241
# len(total_precision_result) : 18
# len(total_f1_result) : 18
# len(total_auc_result) : 18
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2184, 30, 4)
# Made_Y.shape : (2184, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1680,  504]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1148,  380]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([532, 124]))
# X_train.shape : (1528, 30, 4)
# X_val.shape : (656, 30, 4)
# model_num : 1183
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6851 - accuracy: 0.8308
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6843 - accuracy: 0.7513
# Made_X.shape : (2184, 30, 6)
# Made_Y.shape : (2184, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1680,  504]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1148,  380]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([532, 124]))
# X_train.shape : (1528, 30, 6)
# X_val.shape : (656, 30, 6)
# model_num : 1183
# 21/21 [==============================] - 0s 1ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6565 - accuracy: 0.8110
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6592 - accuracy: 0.7513
# Made_X.shape : (2184, 30, 6)
# Made_Y.shape : (2184, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1680,  504]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1148,  380]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([532, 124]))
# X_train.shape : (1528, 30, 6)
# X_val.shape : (656, 30, 6)
# model_num : 1183
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6703 - accuracy: 0.7942
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6750 - accuracy: 0.7428
# Made_X.shape : (2184, 30, 2)
# Made_Y.shape : (2184, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1680,  504]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1148,  380]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([532, 124]))
# X_train.shape : (1528, 30, 2)
# X_val.shape : (656, 30, 2)
# model_num : 1183
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6867 - accuracy: 0.8293
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.7690
# Made_X.shape : (2184, 30, 3)
# Made_Y.shape : (2184, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1680,  504]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1148,  380]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([532, 124]))
# X_train.shape : (1528, 30, 3)
# X_val.shape : (656, 30, 3)
# model_num : 1183
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6809 - accuracy: 0.6936
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6295 - accuracy: 0.7205
# Made_X.shape : (2184, 30, 3)
# Made_Y.shape : (2184, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1680,  504]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1148,  380]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([532, 124]))
# X_train.shape : (1528, 30, 3)
# X_val.shape : (656, 30, 3)
# model_num : 1183
# 21/21 [==============================] - 0s 1ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.7862 - accuracy: 0.4848
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6292 - accuracy: 0.7919
# Made_X.shape : (2184, 30, 2)
# Made_Y.shape : (2184, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1680,  504]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1148,  380]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([532, 124]))
# X_train.shape : (1528, 30, 2)
# X_val.shape : (656, 30, 2)
# model_num : 1183
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6750 - accuracy: 0.8125
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6783 - accuracy: 0.7539
# Made_X.shape : (2184, 30, 3)
# Made_Y.shape : (2184, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1680,  504]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1148,  380]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([532, 124]))
# X_train.shape : (1528, 30, 3)
# X_val.shape : (656, 30, 3)
# model_num : 1183
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6645 - accuracy: 0.7805
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6768 - accuracy: 0.7029
# Made_X.shape : (2184, 30, 2)
# Made_Y.shape : (2184, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1680,  504]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1148,  380]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([532, 124]))
# X_train.shape : (1528, 30, 2)
# X_val.shape : (656, 30, 2)
# model_num : 1183
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6807 - accuracy: 0.8095
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6763 - accuracy: 0.7382
# len(total_precision_result) : 18
# len(total_f1_result) : 18
# len(total_auc_result) : 18
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2161, 30, 4)
# Made_Y.shape : (2161, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1370,  791]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([928, 584]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([442, 207]))
# X_train.shape : (1512, 30, 4)
# X_val.shape : (649, 30, 4)
# model_num : 1184
# 21/21 [==============================] - 0s 1ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6815 - accuracy: 0.7057
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.6217
# Made_X.shape : (2161, 30, 6)
# Made_Y.shape : (2161, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1370,  791]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([928, 584]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([442, 207]))
# X_train.shape : (1512, 30, 6)
# X_val.shape : (649, 30, 6)
# model_num : 1184
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6773 - accuracy: 0.6949
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6836 - accuracy: 0.6296
# Made_X.shape : (2161, 30, 6)
# Made_Y.shape : (2161, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1370,  791]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([928, 584]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([442, 207]))
# X_train.shape : (1512, 30, 6)
# X_val.shape : (649, 30, 6)
# model_num : 1184
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6608 - accuracy: 0.6872
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6703 - accuracy: 0.6058
# Made_X.shape : (2161, 30, 2)
# Made_Y.shape : (2161, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1370,  791]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([928, 584]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([442, 207]))
# X_train.shape : (1512, 30, 2)
# X_val.shape : (649, 30, 2)
# model_num : 1184
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6833 - accuracy: 0.7042
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6870 - accuracy: 0.6151
# Made_X.shape : (2161, 30, 3)
# Made_Y.shape : (2161, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1370,  791]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([928, 584]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([442, 207]))
# X_train.shape : (1512, 30, 3)
# X_val.shape : (649, 30, 3)
# model_num : 1184
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.7987 - accuracy: 0.5054
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5098 - accuracy: 0.7440
# Made_X.shape : (2161, 30, 3)
# Made_Y.shape : (2161, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1370,  791]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([928, 584]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([442, 207]))
# X_train.shape : (1512, 30, 3)
# X_val.shape : (649, 30, 3)
# model_num : 1184
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6967 - accuracy: 0.7026
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6418 - accuracy: 0.6422
# Made_X.shape : (2161, 30, 2)
# Made_Y.shape : (2161, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1370,  791]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([928, 584]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([442, 207]))
# X_train.shape : (1512, 30, 2)
# X_val.shape : (649, 30, 2)
# model_num : 1184
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6902 - accuracy: 0.6888
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6858 - accuracy: 0.6257
# Made_X.shape : (2161, 30, 3)
# Made_Y.shape : (2161, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1370,  791]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([928, 584]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([442, 207]))
# X_train.shape : (1512, 30, 3)
# X_val.shape : (649, 30, 3)
# model_num : 1184
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.9233 - accuracy: 0.6795
# 51/51 [==============================] - 0s 3ms/step - loss: 0.3189 - accuracy: 0.8856
# Made_X.shape : (2161, 30, 2)
# Made_Y.shape : (2161, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1370,  791]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([928, 584]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([442, 207]))
# X_train.shape : (1512, 30, 2)
# X_val.shape : (649, 30, 2)
# model_num : 1184
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6800 - accuracy: 0.6410
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6842 - accuracy: 0.5893
# len(total_precision_result) : 18
# len(total_f1_result) : 18
# len(total_auc_result) : 18
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2303, 30, 4)
# Made_Y.shape : (2303, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1514,  789]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1151,  461]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([363, 328]))
# X_train.shape : (1612, 30, 4)
# X_val.shape : (691, 30, 4)
# model_num : 1185
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6778 - accuracy: 0.6454
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5689 - accuracy: 0.7246
# Made_X.shape : (2303, 30, 6)
# Made_Y.shape : (2303, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1514,  789]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1151,  461]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([363, 328]))
# X_train.shape : (1612, 30, 6)
# X_val.shape : (691, 30, 6)
# model_num : 1185
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5796 - accuracy: 0.7352
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6158 - accuracy: 0.6681
# Made_X.shape : (2303, 30, 6)
# Made_Y.shape : (2303, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1514,  789]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1151,  461]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([363, 328]))
# X_train.shape : (1612, 30, 6)
# X_val.shape : (691, 30, 6)
# model_num : 1185
# 22/22 [==============================] - 0s 1ms/step
# 51/51 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6555 - accuracy: 0.6686
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4666 - accuracy: 0.7978
# Made_X.shape : (2303, 30, 2)
# Made_Y.shape : (2303, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1514,  789]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1151,  461]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([363, 328]))
# X_train.shape : (1612, 30, 2)
# X_val.shape : (691, 30, 2)
# model_num : 1185
# 22/22 [==============================] - 0s 1ms/step
# 51/51 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6964 - accuracy: 0.5253
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5954 - accuracy: 0.7140
# Made_X.shape : (2303, 30, 3)
# Made_Y.shape : (2303, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1514,  789]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1151,  461]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([363, 328]))
# X_train.shape : (1612, 30, 3)
# X_val.shape : (691, 30, 3)
# model_num : 1185
# 22/22 [==============================] - 0s 1ms/step
# 51/51 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7105 - accuracy: 0.5253
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6280 - accuracy: 0.7115
# Made_X.shape : (2303, 30, 3)
# Made_Y.shape : (2303, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1514,  789]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1151,  461]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([363, 328]))
# X_train.shape : (1612, 30, 3)
# X_val.shape : (691, 30, 3)
# model_num : 1185
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7043 - accuracy: 0.7149
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5681 - accuracy: 0.6315
# Made_X.shape : (2303, 30, 2)
# Made_Y.shape : (2303, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1514,  789]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1151,  461]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([363, 328]))
# X_train.shape : (1612, 30, 2)
# X_val.shape : (691, 30, 2)
# model_num : 1185
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6856 - accuracy: 0.5832
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6575 - accuracy: 0.6266
# Made_X.shape : (2303, 30, 3)
# Made_Y.shape : (2303, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1514,  789]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1151,  461]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([363, 328]))
# X_train.shape : (1612, 30, 3)
# X_val.shape : (691, 30, 3)
# model_num : 1185
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6910 - accuracy: 0.5253
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6345 - accuracy: 0.7140
# Made_X.shape : (2303, 30, 2)
# Made_Y.shape : (2303, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1514,  789]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1151,  461]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([363, 328]))
# X_train.shape : (1612, 30, 2)
# X_val.shape : (691, 30, 2)
# model_num : 1185
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6952 - accuracy: 0.5803
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6772 - accuracy: 0.6222
# len(total_precision_result) : 18
# len(total_f1_result) : 18
# len(total_auc_result) : 18
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2206, 30, 4)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1633,  573]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1062,  482]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([571,  91]))
# X_train.shape : (1544, 30, 4)
# X_val.shape : (662, 30, 4)
# model_num : 1186
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6813 - accuracy: 0.8625
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.6878
# Made_X.shape : (2206, 30, 6)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1633,  573]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1062,  482]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([571,  91]))
# X_train.shape : (1544, 30, 6)
# X_val.shape : (662, 30, 6)
# model_num : 1186
# 21/21 [==============================] - 0s 1ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6654 - accuracy: 0.8625
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6766 - accuracy: 0.6878
# Made_X.shape : (2206, 30, 6)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1633,  573]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1062,  482]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([571,  91]))
# X_train.shape : (1544, 30, 6)
# X_val.shape : (662, 30, 6)
# model_num : 1186
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6168 - accuracy: 0.8399
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6006 - accuracy: 0.7746
# Made_X.shape : (2206, 30, 2)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1633,  573]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1062,  482]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([571,  91]))
# X_train.shape : (1544, 30, 2)
# X_val.shape : (662, 30, 2)
# model_num : 1186
# 21/21 [==============================] - 0s 1ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6477 - accuracy: 0.8625
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6669 - accuracy: 0.6878
# Made_X.shape : (2206, 30, 3)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1633,  573]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1062,  482]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([571,  91]))
# X_train.shape : (1544, 30, 3)
# X_val.shape : (662, 30, 3)
# model_num : 1186
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6407 - accuracy: 0.6420
# 52/52 [==============================] - 0s 2ms/step - loss: 0.5655 - accuracy: 0.6503
# Made_X.shape : (2206, 30, 3)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1633,  573]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1062,  482]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([571,  91]))
# X_train.shape : (1544, 30, 3)
# X_val.shape : (662, 30, 3)
# model_num : 1186
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.9888 - accuracy: 0.4230
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6604 - accuracy: 0.7085
# Made_X.shape : (2206, 30, 2)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1633,  573]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1062,  482]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([571,  91]))
# X_train.shape : (1544, 30, 2)
# X_val.shape : (662, 30, 2)
# model_num : 1186
# 21/21 [==============================] - 0s 1ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6332 - accuracy: 0.8625
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6663 - accuracy: 0.6872
# Made_X.shape : (2206, 30, 3)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1633,  573]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1062,  482]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([571,  91]))
# X_train.shape : (1544, 30, 3)
# X_val.shape : (662, 30, 3)
# model_num : 1186
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6387 - accuracy: 0.7221
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6136 - accuracy: 0.6898
# Made_X.shape : (2206, 30, 2)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1633,  573]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1062,  482]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([571,  91]))
# X_train.shape : (1544, 30, 2)
# X_val.shape : (662, 30, 2)
# model_num : 1186
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6661 - accuracy: 0.8127
# 52/52 [==============================] - 0s 2ms/step - loss: 0.6720 - accuracy: 0.6962
# len(total_precision_result) : 18
# len(total_f1_result) : 18
# len(total_auc_result) : 18
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2258, 30, 4)
# Made_Y.shape : (2258, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1548,  710]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1040,  540]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([508, 170]))
# X_train.shape : (1580, 30, 4)
# X_val.shape : (678, 30, 4)
# model_num : 1187
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6772 - accuracy: 0.7611
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6752 - accuracy: 0.6582
# Made_X.shape : (2258, 30, 6)
# Made_Y.shape : (2258, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1548,  710]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1040,  540]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([508, 170]))
# X_train.shape : (1580, 30, 6)
# X_val.shape : (678, 30, 6)
# model_num : 1187
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6806 - accuracy: 0.7493
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6824 - accuracy: 0.6582
# Made_X.shape : (2258, 30, 6)
# Made_Y.shape : (2258, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1548,  710]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1040,  540]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([508, 170]))
# X_train.shape : (1580, 30, 6)
# X_val.shape : (678, 30, 6)
# model_num : 1187
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.7242
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6872 - accuracy: 0.6582
# Made_X.shape : (2258, 30, 2)
# Made_Y.shape : (2258, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1548,  710]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1040,  540]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([508, 170]))
# X_train.shape : (1580, 30, 2)
# X_val.shape : (678, 30, 2)
# model_num : 1187
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6567 - accuracy: 0.7493
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6649 - accuracy: 0.6582
# Made_X.shape : (2258, 30, 3)
# Made_Y.shape : (2258, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1548,  710]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1040,  540]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([508, 170]))
# X_train.shape : (1580, 30, 3)
# X_val.shape : (678, 30, 3)
# model_num : 1187
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.8943 - accuracy: 0.6313
# 53/53 [==============================] - 0s 2ms/step - loss: 0.5412 - accuracy: 0.7146
# Made_X.shape : (2258, 30, 3)
# Made_Y.shape : (2258, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1548,  710]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1040,  540]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([508, 170]))
# X_train.shape : (1580, 30, 3)
# X_val.shape : (678, 30, 3)
# model_num : 1187
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6651 - accuracy: 0.7478
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6708 - accuracy: 0.6652
# Made_X.shape : (2258, 30, 2)
# Made_Y.shape : (2258, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1548,  710]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1040,  540]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([508, 170]))
# X_train.shape : (1580, 30, 2)
# X_val.shape : (678, 30, 2)
# ...
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1263,  359]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([566, 130]))
# X_train.shape : (1622, 30, 3)
# X_val.shape : (696, 30, 3)
# model_num : 1206
# 22/22 [==============================] - 0s 1ms/step
# 51/51 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.4109
# 55/55 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.7250
# Made_X.shape : (2318, 30, 2)
# Made_Y.shape : (2318, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1829,  489]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1263,  359]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([566, 130]))
# X_train.shape : (1622, 30, 2)
# X_val.shape : (696, 30, 2)
# model_num : 1206
# 22/22 [==============================] - 0s 1ms/step
# 51/51 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6616 - accuracy: 0.8132
# 55/55 [==============================] - 0s 2ms/step - loss: 0.6655 - accuracy: 0.7787
# Made_X.shape : (2318, 30, 3)
# Made_Y.shape : (2318, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1829,  489]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1263,  359]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([566, 130]))
# X_train.shape : (1622, 30, 3)
# X_val.shape : (696, 30, 3)
# model_num : 1206
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6508 - accuracy: 0.8132
# 55/55 [==============================] - 0s 2ms/step - loss: 0.6477 - accuracy: 0.7787
# Made_X.shape : (2318, 30, 2)
# Made_Y.shape : (2318, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1829,  489]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1263,  359]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([566, 130]))
# X_train.shape : (1622, 30, 2)
# X_val.shape : (696, 30, 2)
# model_num : 1206
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6589 - accuracy: 0.8132
# 55/55 [==============================] - 0s 2ms/step - loss: 0.6457 - accuracy: 0.7787
# len(total_precision_result) : 18
# len(total_f1_result) : 18
# len(total_auc_result) : 18
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2246, 30, 4)
# Made_Y.shape : (2246, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1958,  288]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1363,  209]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([595,  79]))
# X_train.shape : (1572, 30, 4)
# X_val.shape : (674, 30, 4)
# model_num : 1207
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6633 - accuracy: 0.8887
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6392 - accuracy: 0.8670
# Made_X.shape : (2246, 30, 6)
# Made_Y.shape : (2246, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1958,  288]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1363,  209]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([595,  79]))
# X_train.shape : (1572, 30, 6)
# X_val.shape : (674, 30, 6)
# model_num : 1207
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.7656
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6738 - accuracy: 0.8607
# Made_X.shape : (2246, 30, 6)
# Made_Y.shape : (2246, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1958,  288]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1363,  209]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([595,  79]))
# X_train.shape : (1572, 30, 6)
# X_val.shape : (674, 30, 6)
# model_num : 1207
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6738 - accuracy: 0.8828
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6633 - accuracy: 0.8639
# Made_X.shape : (2246, 30, 2)
# Made_Y.shape : (2246, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1958,  288]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1363,  209]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([595,  79]))
# X_train.shape : (1572, 30, 2)
# X_val.shape : (674, 30, 2)
# model_num : 1207
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6647 - accuracy: 0.8828
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6543 - accuracy: 0.8670
# Made_X.shape : (2246, 30, 3)
# Made_Y.shape : (2246, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1958,  288]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1363,  209]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([595,  79]))
# X_train.shape : (1572, 30, 3)
# X_val.shape : (674, 30, 3)
# model_num : 1207
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6149 - accuracy: 0.7077
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6632 - accuracy: 0.5935
# Made_X.shape : (2246, 30, 3)
# Made_Y.shape : (2246, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1958,  288]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1363,  209]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([595,  79]))
# X_train.shape : (1572, 30, 3)
# X_val.shape : (674, 30, 3)
# model_num : 1207
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6437 - accuracy: 0.8828
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6574 - accuracy: 0.8562
# Made_X.shape : (2246, 30, 2)
# Made_Y.shape : (2246, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1958,  288]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1363,  209]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([595,  79]))
# X_train.shape : (1572, 30, 2)
# X_val.shape : (674, 30, 2)
# model_num : 1207
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6525 - accuracy: 0.8828
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6520 - accuracy: 0.8670
# Made_X.shape : (2246, 30, 3)
# Made_Y.shape : (2246, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1958,  288]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1363,  209]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([595,  79]))
# X_train.shape : (1572, 30, 3)
# X_val.shape : (674, 30, 3)
# model_num : 1207
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.5072 - accuracy: 0.7552
# 53/53 [==============================] - 0s 2ms/step - loss: 0.4909 - accuracy: 0.7246
# Made_X.shape : (2246, 30, 2)
# Made_Y.shape : (2246, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1958,  288]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1363,  209]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([595,  79]))
# X_train.shape : (1572, 30, 2)
# X_val.shape : (674, 30, 2)
# model_num : 1207
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.6261
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6754 - accuracy: 0.6978
# len(total_precision_result) : 18
# len(total_f1_result) : 18
# len(total_auc_result) : 18
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2243, 30, 4)
# Made_Y.shape : (2243, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1838,  405]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1315,  255]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([523, 150]))
# X_train.shape : (1570, 30, 4)
# X_val.shape : (673, 30, 4)
# model_num : 1208
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6532 - accuracy: 0.7771
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6356 - accuracy: 0.8376
# Made_X.shape : (2243, 30, 6)
# Made_Y.shape : (2243, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1838,  405]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1315,  255]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([523, 150]))
# X_train.shape : (1570, 30, 6)
# X_val.shape : (673, 30, 6)
# model_num : 1208
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6869 - accuracy: 0.7786
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6820 - accuracy: 0.8382
# Made_X.shape : (2243, 30, 6)
# Made_Y.shape : (2243, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1838,  405]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1315,  255]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([523, 150]))
# X_train.shape : (1570, 30, 6)
# X_val.shape : (673, 30, 6)
# model_num : 1208
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6861 - accuracy: 0.8143
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6790 - accuracy: 0.8369
# Made_X.shape : (2243, 30, 2)
# Made_Y.shape : (2243, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1838,  405]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1315,  255]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([523, 150]))
# X_train.shape : (1570, 30, 2)
# X_val.shape : (673, 30, 2)
# model_num : 1208
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6684 - accuracy: 0.7771
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6577 - accuracy: 0.8376
# Made_X.shape : (2243, 30, 3)
# Made_Y.shape : (2243, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1838,  405]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1315,  255]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([523, 150]))
# X_train.shape : (1570, 30, 3)
# X_val.shape : (673, 30, 3)
# model_num : 1208
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7503 - accuracy: 0.5453
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6278 - accuracy: 0.6497
# Made_X.shape : (2243, 30, 3)
# Made_Y.shape : (2243, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1838,  405]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1315,  255]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([523, 150]))
# X_train.shape : (1570, 30, 3)
# X_val.shape : (673, 30, 3)
# model_num : 1208
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7425 - accuracy: 0.6404
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7154 - accuracy: 0.5019
# Made_X.shape : (2243, 30, 2)
# Made_Y.shape : (2243, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1838,  405]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1315,  255]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([523, 150]))
# X_train.shape : (1570, 30, 2)
# X_val.shape : (673, 30, 2)
# model_num : 1208
# 22/22 [==============================] - 0s 1ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6497 - accuracy: 0.7771
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6403 - accuracy: 0.8376
# Made_X.shape : (2243, 30, 3)
# Made_Y.shape : (2243, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1838,  405]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1315,  255]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([523, 150]))
# X_train.shape : (1570, 30, 3)
# X_val.shape : (673, 30, 3)
# model_num : 1208
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6683 - accuracy: 0.7147
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6703 - accuracy: 0.7694
# Made_X.shape : (2243, 30, 2)
# Made_Y.shape : (2243, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1838,  405]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1315,  255]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([523, 150]))
# X_train.shape : (1570, 30, 2)
# X_val.shape : (673, 30, 2)
# model_num : 1208
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 2ms/step - loss: 0.6670 - accuracy: 0.7771
# 53/53 [==============================] - 0s 2ms/step - loss: 0.6548 - accuracy: 0.8376
# len(total_precision_result) : 18
# len(total_f1_result) : 18
# len(total_auc_result) : 18
# len(total_profit_result) : 0
# last index = 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-3a4bc95e9b27> in <module>()
#      18   # try:
#      19
# ---> 20     Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % model_num)
#      21     Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s.npy' % model_num).reshape(-1, 1)
#      22
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 1209.npy'

# %% [markdown]
# ### ***Compare Result***

# %%
print(np.array(all_pair_precision_auc).shape)
print(np.array(all_pair_f1_auc).shape)
print(np.array(all_pair_auc).shape)

# print(np.sum(np.array(all_pair_precision_auc), axis=0))
fig = plt.figure(figsize=(10, 6))
plt.subplot(131)
plt.bar(range(len(model_list)), np.mean(np.array(all_pair_precision_auc), axis=0))
plt.axhline(50, linestyle='--', color='red')
plt.xticks(range(len(model_list)), feature_name, rotation=45)
plt.title('Precision Mean AUC')

plt.subplot(132)
plt.bar(range(len(model_list)), np.mean(np.array(all_pair_f1_auc), axis=0))
plt.axhline(50, linestyle='--', color='red')
plt.xticks(range(len(model_list)), feature_name, rotation=45)
plt.title('F1 Mean AUC')

plt.subplot(133)
plt.bar(range(len(model_list)), np.mean(np.array(all_pair_auc), axis=0))
plt.axhline(50, linestyle='--', color='red')
plt.xticks(range(len(model_list)), feature_name, rotation=45)
plt.title('Mean AUC')

fig.suptitle('All Pair') # or plt.suptitle('Main title')

plt.show()
# Out:
# (29, 9)
# (29, 9)
# (29, 9)

# %% [markdown]
# ### ***AUC***

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import f1_score, precision_score, recall_score


trade_on = True
show_trade_data = False

input_data_length = 30 # <-- Need for Back-Test
test_model_range = range(1044, 1078)
total_profit_result = list()
for model_num, test_model_num in zip(model_range, test_model_range):

  # try:

    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % model_num)
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s.npy' % model_num).reshape(-1, 1)

    Made_X_test_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % test_model_num)
    #     for trade, ohlc data    #
    Made_Z_test = np.load(gdrive_path + 'Made_X/Made_Z %s.npy' % test_model_num)

    # Made_X2 = np.load(gdrive_path + 'Made_X/Made_X 30_%s.npy' % (30, 219))
    # Made_Y2 = np.load(gdrive_path + 'Made_X/Made_Y 30_%s.npy' % (30, 219))

    #         Feature Selection      #
    # Made_X = Made_X_[:, :, [-4]]
    # Made_X = Made_X_[:, :, :4]
    Made_X = Made_X_[:, :, :4]
    # Made_X2 = Made_X2[:, :, [0, 2, 3, 1]]


    #         Train Limit         #
    # Made_X = Made_X[-4000:]
    # Made_Y = Made_Y[-4000:]
    Made_X_test = Made_X_test_[:, :, :4]
    print('Made_X.shape :', Made_X.shape)
    print('Made_Y.shape :', Made_Y.shape)
    print('Made_X_test.shape :', Made_X_test.shape)
    print('Made_Z_test.shape :', Made_Z_test.shape)

    # print('min(Made_Z_test) :', np.min(Made_Z_test))
    # print(sum(sum(Made_X != Made_X2)))
    # break

    row = Made_X.shape[1]
    col = Made_X.shape[2]

    X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                        shuffle=False)
    X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
    X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)

    Y_train = Y_train.astype('float32')
    Y_val = Y_val.astype('float32')
    
    X_test = Made_X_test
    print('np.unique(Made_Y) :', np.unique(Made_Y, return_counts=True))
    print('np.unique(Y_train) :', np.unique(Y_train, return_counts=True))
    print('np.unique(Y_val) :', np.unique(Y_val, return_counts=True))

    Y_train = np_utils.to_categorical(Y_train, num_classes)
    Y_val = np_utils.to_categorical(Y_val, num_classes)
    
    print('X_train.shape :', X_train.shape)
    print('X_val.shape :', X_val.shape)

      
    for model_i, model_num in enumerate([model_num]):

      print('model_num :', model_num)
      if model_i == 0:
        print('Pred by Real')
      else:
        print('Pred by None Real')

      model_path = gdrive_path + "model/rapid_ascending %s_futures_rnn.hdf5" % model_num
      model = load_model(model_path)

      #     val, train -> confidence 와 evaluate 용
      val_y_pred_ = model.predict(X_val, verbose=1)
      train_y_pred_ = model.predict(X_train, verbose=1)

      # val_y_pred_ = np.argmax(val_y_pred_, axis=1)
      val_y_pred_ = val_y_pred_[:, [1]]
      train_y_pred_ = train_y_pred_[:, [1]]

      # print('len(val_y_pred_) :', len(val_y_pred_))
      #     test -> profit 용
      test_y_pred_ = model.predict(X_test, verbose=1).ravel()

      val_fpr, val_tpr, val_thr = roc_curve(Y_val[:, [1]], val_y_pred_)
      train_fpr, train_tpr, train_thr = roc_curve(Y_train[:, [1]], train_y_pred_)

      val_auc = auc(val_fpr, val_tpr)
      train_auc = auc(train_fpr, train_tpr)

      # precision = precision_score(t_te, y_pred) * 100
      f1 = f1_score(Y_val[:, [1]], val_y_pred_) * 100
      print('f1 :', f1)

      plt.figure(figsize=(10, 5))

      plt.subplot(121)
      plt.plot([0, 1], [0, 1], 'k--')
      plt.plot(val_fpr, val_tpr)
      plt.title('Val AUC = %.2f' % val_auc, color='white', fontsize=10)
      
      plt.subplot(122)
      plt.plot([0, 1], [0, 1], 'k--')
      plt.plot(train_fpr, train_tpr)
      plt.title('Train AUC = %.2f' % val_auc, color='white', fontsize=10)
      plt.show()
# Out:
# Made_X.shape : (2290, 30, 4)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 4)
# X_val.shape : (687, 30, 4)
# model_num : 1180
# Pred by Real
# 22/22 [==============================] - 0s 1ms/step
# 51/51 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-7d274cf28d3a> in <module>()
#      99
#     100       # precision = precision_score(t_te, y_pred) * 100
# --> 101       f1 = f1_score(Y_val[:, [1]], val_y_pred_) * 100
#     102       print('f1 :', f1)
#     103
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1097                        pos_label=pos_label, average=average,
#    1098                        sample_weight=sample_weight,
# -> 1099                        zero_division=zero_division)
#    1100
#    1101
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1224                                                  warn_for=('f-score',),
#    1225                                                  sample_weight=sample_weight,
# -> 1226                                                  zero_division=zero_division)
#    1227     return f
#    1228
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1482         raise ValueError("beta should be >=0 in the F-beta score")
#    1483     labels = _check_set_wise_labels(y_true, y_pred, average, labels,
# -> 1484                                     pos_label)
#    1485
#    1486     # Calculate tp_sum, pred_sum, true_sum ###
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1299                          str(average_options))
#    1300
# -> 1301     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1302     present_labels = unique_labels(y_true, y_pred)
#    1303     if average == 'binary':
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      88     if len(y_type) > 1:
#      89         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 90                          "and {1} targets".format(type_true, type_pred))
#      91
#      92     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %% [markdown]
# ### ***Find Best Confidence***

# %%
total_profit_result = np.array(total_profit_result)
print('total_profit_result.shape :', total_profit_result.shape)
total_profit_sum = np.sum(total_profit_result, axis=0)
# print(total_profit_sum)

# plt.hist(x_ticks, bins=len(x_ticks),weights=total_profit_sum)
plt.plot(x_ticks, total_profit_sum)
plt.plot(x_ticks[np.argmax(total_profit_sum)], max(total_profit_sum), 'o', color='red')
plt.show()

print(x_ticks[np.argmax(total_profit_sum)])
# Out:
# total_profit_result.shape : (34, 100)
# 0.56

# %% [markdown]
# ### ***Find Best Partial***

# %%
max_tp_ratio = 1.
remain_qty = 1
partial_num = 10
tp_list = list()
qty_list = list()
for i in range(partial_num, 0, -1):

  tp_list.append(max_tp_ratio * i / partial_num)
  # df['long_tp_1'] = df['ep'] + abs(df['ep'] - df['long_sl']) * tp_ratio * 2 / 3

  if i != 1:
    qty = remain_qty / 1.5
    remain_qty -= qty
  else:
    qty = remain_qty

  qty_list.append(qty)

# print(tp_list)
# print(np.array([tp_list, qty_list]).astype(np.float64))
print('total_income :', np.sum(np.prod(np.array([tp_list, qty_list]), axis=0)))
# Out:
# total_income : 0.9500025402631713

# %% [markdown]
# ### ***None Realtime vs Realtime***

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model
import matplotlib.pyplot as plt

for model_num in model_range:

  try:

    #     Get Test Dataset   #
    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num + 41 * 3))
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num + 41 * 3)).reshape(-1, 1)

    #       dataset 분리      #
    # dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    # dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    # Made_X = Made_X_[:, :, [-4]]
    Made_X = Made_X_[:, :, :4]
    # print(Made_X.shape)
    # print(Made_Y.shape)
    # break

    row = Made_X.shape[1]
    col = Made_X.shape[2]

    # X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
    #                                                   shuffle=False)

    # X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
    # X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)

    X_test = Made_X.astype('float32')
    Y_test = Made_Y
    
    for model_i, model_num in enumerate([model_num, model_num + 41]):

      if model_i == 0:
        print('Pred by Real')
      else:
        print('Pred by None Real')

      model_path = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (input_data_length, model_num)
      model = load_model(model_path)
      y_pred_ = model.predict(X_test, verbose=1)
      # total_y_pred_ = model.predict(Made_X, verbose=1)

      plt.figure(figsize=(10, 6))
      
      for index, y_pred_ in enumerate([y_pred_]):

        # print('len(y_pred_) :', len(y_pred_))
        target_column = y_pred_[:, [-1]]
        # column_min, column_max = train_y_pred_.min(),train_y_pred_.max()
        column_min, column_max = target_column.min(),target_column.max()
        # print(column_min, column_max)

        x_ticks = np.arange(0.5, 1, 0.005)
        # x_ticks = np.arange(0.5, column_max, 0.005) <-- column_max 대응할만한 값을 찾아야한다. 1 까지는 사용못할것
        confidence_result = list()
        for confidence in x_ticks:
          # confidence = 0.9

          # if column_max < 0.5:
          #   break
          # else:
          #   scaled_confidence = .5 + (column_max - .5) * confidence
          scaled_confidence = column_min + (column_max - column_min) * confidence

          # scaled_confidence = confidence
          # print(scaled_confidence)
          # print('confidence :', confidence)

          y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )

          #   inverse version   #
          # confidence = 1 - confidence
          # scaled_confidence = y_pred_[:, [-1]].min() + (y_pred_[:, [-1]].max() - y_pred_[:, [-1]].min()) * confidence
          # y_pred = np.where(y_pred_[:, [-1]] <= scaled_confidence, 1, 0).reshape(-1, )

          #     결국, Categorical 은 index 값으로 value 를 나타내는 것    #
          # t_te = np.argmax(Y_val, axis=1)

          t_te = Y_test

          # print(y_pred_[:5])
          # print(Y_val[:5])
          # break

          pred_true = 0
          real_true = 0

          #       predict value 존나 높으면 True 일 확률 존나 높은건데, 그게 진짜 True가 맞냐 이걸 알고 싶은거지     #
          #       confidence를 만족하는 label이 1인 데이터 안에서 pred 1 / label 1 -> 이걸 도출해면 된다        #

          for i in range(len(y_pred)):
            if y_pred[i] == 1:  
              pred_true += 1
              if t_te[i] == y_pred[i]:
                real_true += 1

          true_true = real_true / pred_true * 100
          confidence_result.append(true_true)
          # print('True Pred / Total True : %s / %s' % (real_true, pred_true))
          # print('Accuracy : %2.f %%' % (true_true))
          # print()

        # if column_max < 0.5:
        #   continue
        
        plt.subplot(2, 4, index + 1 + model_i * 4)
        plt.plot(x_ticks, confidence_result)
        plt.axhline(50, linestyle='--', color='red')
        plt.ylim(-5, 105)
        plt.title('%s %s' % ((column_min, column_max)), color='white', fontsize=10)

        if index == 0:
          plt.subplot(2, 4, index + 3 + model_i * 4)
          plt.plot(Made_X_[:, [-1], [3]])
        elif index == 1:
          plt.subplot(2, 4, index + 3 + model_i * 4)
          plt.plot(Made_X_[:, [-1], [3]])

    plt.show()

  except Exception as e:
    print('Error occured : ', e)
  print()
# Out:
# Pred by Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 2ms/step
# Pred by Real
# 65/65 [==============================] - 0s 951us/step
# Pred by None Real
# 65/65 [==============================] - 0s 944us/step
# Pred by Real
# 65/65 [==============================] - 0s 2ms/step
# Pred by None Real
# 65/65 [==============================] - 0s 1ms/step
# Pred by Real
# 67/67 [==============================] - 0s 2ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 68/68 [==============================] - 0s 2ms/step
# Pred by None Real
# 68/68 [==============================] - 0s 2ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_227_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
#
# Pred by Real
# 67/67 [==============================] - 0s 2ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 2ms/step
# Pred by Real
# 66/66 [==============================] - 0s 2ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 65/65 [==============================] - 0s 2ms/step
# Pred by None Real
# 65/65 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 2ms/step
# Pred by Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by Real
# 64/64 [==============================] - 0s 2ms/step
# Pred by None Real
# 64/64 [==============================] - 0s 1ms/step
# Pred by Real
# 63/63 [==============================] - 0s 1ms/step
# Pred by None Real
# 63/63 [==============================] - 0s 2ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 2ms/step
# Pred by Real
# 63/63 [==============================] - 0s 1ms/step
# Pred by None Real
# 63/63 [==============================] - 0s 1ms/step
# Pred by Real
# 64/64 [==============================] - 0s 1ms/step
# Pred by None Real
# 64/64 [==============================] - 0s 1ms/step
# Pred by Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by Real
# 65/65 [==============================] - 0s 1ms/step
# Pred by None Real
# 65/65 [==============================] - 0s 2ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by Real
# 69/69 [==============================] - 0s 1ms/step
# Pred by None Real
# 69/69 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 2ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 68/68 [==============================] - 0s 2ms/step
# Pred by None Real
# 68/68 [==============================] - 0s 1ms/step
# Pred by Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by Real
# 64/64 [==============================] - 0s 1ms/step
# Pred by None Real
# 64/64 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 2ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_376.npy'
#
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_377.npy'
#
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_378.npy'
#
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_379.npy'
#
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_380.npy'
#
# Pred by Real
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_258_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
#
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_382.npy'

# %% [markdown]
# ### ***Check Entry points in Chart***

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model


confidence = 0.8
scaled_confidence = column_min + (column_max - column_min) * confidence
# print(scaled_confidence)
print('confidence :', confidence)

y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )
t_te = np.argmax(Y_val, axis=1)

close = Made_X_[-len(X_val):, [-1], [3]]
plt.plot(close)
# plt.show()

long_marker_x = list()
long_marker_y = list()
for i in range(len(y_pred)):
  if y_pred[i] == 1:  
    if t_te[i] == y_pred[i]:
      long_marker_x.append(i)
      long_marker_y.append(close[i])
      

plt.plot(long_marker_x, long_marker_y, 'o', color='blue')
plt.show()
# Out:
# confidence : 0.8
