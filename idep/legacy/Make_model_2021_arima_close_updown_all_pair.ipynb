# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-02-11/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-02-11 BTCUSDT.xlsx', '2021-02-11 ETHUSDT.xlsx', '2021-02-11 BCHUSDT.xlsx', '2021-02-11 XRPUSDT.xlsx', '2021-02-11 EOSUSDT.xlsx', '2021-02-11 LTCUSDT.xlsx', '2021-02-11 ETCUSDT.xlsx', '2021-02-11 LINKUSDT.xlsx', '2021-02-11 XLMUSDT.xlsx', '2021-02-11 ADAUSDT.xlsx', '2021-02-11 XMRUSDT.xlsx', '2021-02-11 SXPUSDT.xlsx', '2021-02-11 KAVAUSDT.xlsx', '2021-02-11 BANDUSDT.xlsx', '2021-02-11 DASHUSDT.xlsx', '2021-02-11 ZECUSDT.xlsx', '2021-02-11 XTZUSDT.xlsx', '2021-02-11 BNBUSDT.xlsx', '2021-02-11 ATOMUSDT.xlsx', '2021-02-11 ONTUSDT.xlsx', '2021-02-11 IOTAUSDT.xlsx', '2021-02-11 BATUSDT.xlsx', '2021-02-11 NEOUSDT.xlsx', '2021-02-11 QTUMUSDT.xlsx', '2021-02-11 WAVESUSDT.xlsx', '2021-02-11 MKRUSDT.xlsx', '2021-02-11 SNXUSDT.xlsx', '2021-02-11 DOTUSDT.xlsx', '2021-02-11 THETAUSDT.xlsx', '2021-02-11 ALGOUSDT.xlsx', '2021-02-11 KNCUSDT.xlsx', '2021-02-11 ZRXUSDT.xlsx', '2021-02-11 COMPUSDT.xlsx', '2021-02-11 OMGUSDT.xlsx']

# %% [markdown]
# ### **Data Stacking**

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle

with open('./arima_result/arima_ma7_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
  load_dict = pickle.load(f)

candis = list(load_dict.keys())
long_index = 0
leverage = 5
prev_x = None
for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue
  if '2021-03-02 DOTUSDT.xlsx' in candis[i]:
    # print('')
    continue

  if '04-08' not in candis[i]:
    # print('')
    continue

  # if '02-11' not in candis[i]:
  #   # print('')
  #   continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      ohlcv = load_dict[key]['ohlcv']

      # print("ohlcv.columns")
      # print(ohlcv.columns)
      # break
      # ohlcv = ohlcv.iloc[-int(len(ohlcv) * 0.34):]
      predictions = load_dict[key]['predictions']
      err_ranges = load_dict[key]['err_ranges']

      # predictions = ohlcv['close'].shift(1).values
      # err_ranges = np.zeros_like(predictions)

      # leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]

      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = np.array(predictions)
      long_ep = long_ep.reshape(-1, 1)

      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 45
      data_x, data_pr, data_updown = [], [], []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          min_max = MinMaxScaler()
          temp_data[:, :5] = min_max.fit_transform(temp_data[:, :5])


          #   vol -> min_max
          min_max = MinMaxScaler()
          temp_data[:, [5]] = min_max.fit_transform(temp_data[:, [5]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]

      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)

      #     do stacking   #
      if prev_x is None:
        prev_x = input_x
        prev_pr = input_pr
        prev_ud = input_ud
      else:
        total_x = np.vstack((prev_x, input_x))
        total_pr = np.vstack((prev_pr, input_pr))
        total_ud = np.vstack((prev_ud, input_ud))

        prev_x = total_x
        prev_pr = total_pr
        prev_ud = total_ud

        print('total_x.shape :', total_x.shape)
        print('total_pr.shape :', total_pr.shape)
        print('total_ud.shape :', total_ud.shape)
# Out:
# -------------- 2021-04-08 BTCUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5758, 45, 6)
# input_x.shape : (5758, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5758, 1)
# input_ud.shape : (5758, 1)
# -------------- 2021-04-08 ETHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5665, 45, 6)
# input_x.shape : (5665, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5665, 1)
# input_ud.shape : (5665, 1)
# total_x.shape : (11423, 45, 6, 3)
# total_pr.shape : (11423, 1)
# total_ud.shape : (11423, 1)
# -------------- 2021-04-08 BCHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5664, 45, 6)
# input_x.shape : (5664, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5664, 1)
# input_ud.shape : (5664, 1)
# total_x.shape : (17087, 45, 6, 3)
# total_pr.shape : (17087, 1)
# total_ud.shape : (17087, 1)
# -------------- 2021-04-08 XRPUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5565, 45, 6)
# input_x.shape : (5565, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5565, 1)
# input_ud.shape : (5565, 1)
# total_x.shape : (22652, 45, 6, 3)
# total_pr.shape : (22652, 1)
# total_ud.shape : (22652, 1)
# -------------- 2021-04-08 EOSUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5601, 45, 6)
# input_x.shape : (5601, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5601, 1)
# input_ud.shape : (5601, 1)
# total_x.shape : (28253, 45, 6, 3)
# total_pr.shape : (28253, 1)
# total_ud.shape : (28253, 1)
# -------------- 2021-04-08 LTCUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5711, 45, 6)
# input_x.shape : (5711, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5711, 1)
# input_ud.shape : (5711, 1)
# total_x.shape : (33964, 45, 6, 3)
# total_pr.shape : (33964, 1)
# total_ud.shape : (33964, 1)
# -------------- 2021-04-08 ETCUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5659, 45, 6)
# input_x.shape : (5659, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5659, 1)
# input_ud.shape : (5659, 1)
# total_x.shape : (39623, 45, 6, 3)
# total_pr.shape : (39623, 1)
# total_ud.shape : (39623, 1)
# -------------- 2021-04-08 LINKUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5661, 45, 6)
# input_x.shape : (5661, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5661, 1)
# input_ud.shape : (5661, 1)
# total_x.shape : (45284, 45, 6, 3)
# total_pr.shape : (45284, 1)
# total_ud.shape : (45284, 1)
# -------------- 2021-04-08 XLMUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5615, 45, 6)
# input_x.shape : (5615, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5615, 1)
# input_ud.shape : (5615, 1)
# total_x.shape : (50899, 45, 6, 3)
# total_pr.shape : (50899, 1)
# total_ud.shape : (50899, 1)
# -------------- 2021-04-08 ADAUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5699, 45, 6)
# input_x.shape : (5699, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5699, 1)
# input_ud.shape : (5699, 1)
# total_x.shape : (56598, 45, 6, 3)
# total_pr.shape : (56598, 1)
# total_ud.shape : (56598, 1)
# -------------- 2021-04-08 XMRUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5669, 45, 6)
# input_x.shape : (5669, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5669, 1)
# input_ud.shape : (5669, 1)
# total_x.shape : (62267, 45, 6, 3)
# total_pr.shape : (62267, 1)
# total_ud.shape : (62267, 1)
# -------------- 2021-04-08 SXPUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 4262
# long_ep.shape : (4262, 1)
# len(pr_list) : 4262
# np.array(data_x).shape : (4173, 45, 6)
# input_x.shape : (4173, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (4173, 1)
# input_ud.shape : (4173, 1)
# total_x.shape : (66440, 45, 6, 3)
# total_pr.shape : (66440, 1)
# total_ud.shape : (66440, 1)
# -------------- 2021-04-08 KAVAUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 4149
# long_ep.shape : (4149, 1)
# len(pr_list) : 4149
# np.array(data_x).shape : (4028, 45, 6)
# input_x.shape : (4028, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (4028, 1)
# input_ud.shape : (4028, 1)
# total_x.shape : (70468, 45, 6, 3)
# total_pr.shape : (70468, 1)
# total_ud.shape : (70468, 1)
# -------------- 2021-04-08 BANDUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 4133
# long_ep.shape : (4133, 1)
# len(pr_list) : 4133
# np.array(data_x).shape : (3989, 45, 6)
# input_x.shape : (3989, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (3989, 1)
# input_ud.shape : (3989, 1)
# total_x.shape : (74457, 45, 6, 3)
# total_pr.shape : (74457, 1)
# total_ud.shape : (74457, 1)
# -------------- 2021-04-08 DASHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5617, 45, 6)
# input_x.shape : (5617, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5617, 1)
# input_ud.shape : (5617, 1)
# total_x.shape : (80074, 45, 6, 3)
# total_pr.shape : (80074, 1)
# total_ud.shape : (80074, 1)
# -------------- 2021-04-08 ZECUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5618, 45, 6)
# input_x.shape : (5618, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5618, 1)
# input_ud.shape : (5618, 1)
# total_x.shape : (85692, 45, 6, 3)
# total_pr.shape : (85692, 1)
# total_ud.shape : (85692, 1)
# -------------- 2021-04-08 XTZUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5631, 45, 6)
# input_x.shape : (5631, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5631, 1)
# input_ud.shape : (5631, 1)
# total_x.shape : (91323, 45, 6, 3)
# total_pr.shape : (91323, 1)
# total_ud.shape : (91323, 1)
# -------------- 2021-04-08 BNBUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5738, 45, 6)
# input_x.shape : (5738, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5738, 1)
# input_ud.shape : (5738, 1)
# total_x.shape : (97061, 45, 6, 3)
# total_pr.shape : (97061, 1)
# total_ud.shape : (97061, 1)
# -------------- 2021-04-08 ATOMUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5672, 45, 6)
# input_x.shape : (5672, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5672, 1)
# input_ud.shape : (5672, 1)
# total_x.shape : (102733, 45, 6, 3)
# total_pr.shape : (102733, 1)
# total_ud.shape : (102733, 1)
# -------------- 2021-04-08 ONTUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5621, 45, 6)
# input_x.shape : (5621, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5621, 1)
# input_ud.shape : (5621, 1)
# total_x.shape : (108354, 45, 6, 3)
# total_pr.shape : (108354, 1)
# total_ud.shape : (108354, 1)
# -------------- 2021-04-08 IOTAUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5658, 45, 6)
# input_x.shape : (5658, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5658, 1)
# input_ud.shape : (5658, 1)
# total_x.shape : (114012, 45, 6, 3)
# total_pr.shape : (114012, 1)
# total_ud.shape : (114012, 1)
# -------------- 2021-04-08 BATUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5628, 45, 6)
# input_x.shape : (5628, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5628, 1)
# input_ud.shape : (5628, 1)
# total_x.shape : (119640, 45, 6, 3)
# total_pr.shape : (119640, 1)
# total_ud.shape : (119640, 1)
# -------------- 2021-04-08 NEOUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5670, 45, 6)
# input_x.shape : (5670, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5670, 1)
# input_ud.shape : (5670, 1)
# total_x.shape : (125310, 45, 6, 3)
# total_pr.shape : (125310, 1)
# total_ud.shape : (125310, 1)
# -------------- 2021-04-08 QTUMUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5824
# long_ep.shape : (5824, 1)
# len(pr_list) : 5824
# np.array(data_x).shape : (5647, 45, 6)
# input_x.shape : (5647, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5647, 1)
# input_ud.shape : (5647, 1)
# total_x.shape : (130957, 45, 6, 3)
# total_pr.shape : (130957, 1)
# total_ud.shape : (130957, 1)
# -------------- 2021-04-08 WAVESUSDT.xlsx --------------
# ...
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 3888
# long_ep.shape : (3888, 1)
# len(pr_list) : 3888
# np.array(data_x).shape : (3736, 45, 6)
# input_x.shape : (3736, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (3736, 1)
# input_ud.shape : (3736, 1)
# total_x.shape : (138476, 45, 6, 3)
# total_pr.shape : (138476, 1)
# total_ud.shape : (138476, 1)
# -------------- 2021-04-08 SNXUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 3871
# long_ep.shape : (3871, 1)
# len(pr_list) : 3871
# np.array(data_x).shape : (3699, 45, 6)
# input_x.shape : (3699, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (3699, 1)
# input_ud.shape : (3699, 1)
# total_x.shape : (142175, 45, 6, 3)
# total_pr.shape : (142175, 1)
# total_ud.shape : (142175, 1)
# -------------- 2021-04-08 DOTUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 3741
# long_ep.shape : (3741, 1)
# len(pr_list) : 3741
# np.array(data_x).shape : (3664, 45, 6)
# input_x.shape : (3664, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (3664, 1)
# input_ud.shape : (3664, 1)
# total_x.shape : (145839, 45, 6, 3)
# total_pr.shape : (145839, 1)
# total_ud.shape : (145839, 1)
# -------------- 2021-04-08 THETAUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 5160
# long_ep.shape : (5160, 1)
# len(pr_list) : 5160
# np.array(data_x).shape : (5082, 45, 6)
# input_x.shape : (5082, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (5082, 1)
# input_ud.shape : (5082, 1)
# total_x.shape : (150921, 45, 6, 3)
# total_pr.shape : (150921, 1)
# total_ud.shape : (150921, 1)
# -------------- 2021-04-08 ALGOUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 4833
# long_ep.shape : (4833, 1)
# len(pr_list) : 4833
# np.array(data_x).shape : (4705, 45, 6)
# input_x.shape : (4705, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (4705, 1)
# input_ud.shape : (4705, 1)
# total_x.shape : (155626, 45, 6, 3)
# total_pr.shape : (155626, 1)
# total_ud.shape : (155626, 1)
# -------------- 2021-04-08 KNCUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:194: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 4735
# long_ep.shape : (4735, 1)
# len(pr_list) : 4735
# np.array(data_x).shape : (4580, 45, 6)
# input_x.shape : (4580, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (4580, 1)
# input_ud.shape : (4580, 1)
# total_x.shape : (160206, 45, 6, 3)
# total_pr.shape : (160206, 1)
# total_ud.shape : (160206, 1)
# -------------- 2021-04-08 ZRXUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 4702
# long_ep.shape : (4702, 1)
# len(pr_list) : 4702
# np.array(data_x).shape : (4554, 45, 6)
# input_x.shape : (4554, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (4554, 1)
# input_ud.shape : (4554, 1)
# total_x.shape : (164760, 45, 6, 3)
# total_pr.shape : (164760, 1)
# total_ud.shape : (164760, 1)
# -------------- 2021-04-08 COMPUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 4604
# long_ep.shape : (4604, 1)
# len(pr_list) : 4604
# np.array(data_x).shape : (4378, 45, 6)
# input_x.shape : (4378, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (4378, 1)
# input_ud.shape : (4378, 1)
# total_x.shape : (169138, 45, 6, 3)
# total_pr.shape : (169138, 1)
# total_ud.shape : (169138, 1)
# -------------- 2021-04-08 OMGUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 4572
# long_ep.shape : (4572, 1)
# len(pr_list) : 4572
# np.array(data_x).shape : (4430, 45, 6)
# input_x.shape : (4430, 45, 6, 3)
# input_x.dtype : float32
# input_pr.shape : (4430, 1)
# input_ud.shape : (4430, 1)
# total_x.shape : (173568, 45, 6, 3)
# total_pr.shape : (173568, 1)
# total_ud.shape : (173568, 1)

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape=(row, col, 3)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight
# import cv2



seed = 1
random_state = 20
np.random.seed(seed)
# tf.random.set_seed(seed)

#         resize total_x shape  (, 5, 6, 3)      #
# .repeat(2, axis=0).repeat(2, axis=1)
temp_x = list()
for d_i, data in enumerate(total_x):
  # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
  resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
  # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
  # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
  
  if d_i == 0:
    plt.imshow(data)
    plt.show()
    plt.imshow(resized_data)
    plt.show()
  # print('resized_data.shape :', resized_data.shape)
  # break
  temp_x.append(resized_data)

re_total_x = np.array(temp_x)
print('re_total_x.shape :', re_total_x.shape)
# break

#         train / test split      #
x_train, x_test_, pr_train, pr_test_, ud_train, ud_test_ = train_test_split(re_total_x, total_pr, total_ud, test_size=0.4, shuffle=True, random_state=random_state)
x_test, x_val, pr_test, pr_val, ud_test, ud_val = train_test_split(x_test_, pr_test_, ud_test_, test_size=0.5, shuffle=True, random_state=random_state)


#         pr label   #
y_train = np.where(pr_train > 1, 1, 0)
y_test = np.where(pr_test > 1, 1, 0)
y_val = np.where(pr_val > 1, 1, 0)

#         up label      #
# y_train = np.where(ud_train > 1, 1, 0)
# y_test = np.where(ud_test > 1, 1, 0)
# y_val = np.where(ud_val > 1, 1, 0)

print('pr_train[:5] :', pr_train[:5])
print('ud_train[:5] :', ud_train[:5])
print('y_train[:5] :', y_train[:5])
print('y_train.dtype :', y_train.dtype)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

def class_ratio(in_list):

  return in_list / in_list[1]

print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)

datagen = ImageDataGenerator( 
    rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)

batch_size = 256

for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break
# Out:
# re_total_x.shape : (173568, 90, 12, 3)
# pr_train[:5] : [[1.0393989]
#  [1.055382 ]
#  [1.0241528]
#  [1.016777 ]
#  [0.9873842]]
# ud_train[:5] : [[1.0089116 ]
#  [1.0118363 ]
#  [1.0052873 ]
#  [1.0046616 ]
#  [0.99625933]]
# y_train[:5] : [[1]
#  [1]
#  [1]
#  [1]
#  [0]]
# y_train.dtype : int64
# x_train.shape : (104140, 90, 12, 3)
# x_test.shape : (34714, 90, 12, 3)
# x_val.shape : (34714, 90, 12, 3)
# y_train.shape : (104140, 1)
# y_test.shape : (34714, 1)
# y_val.shape : (34714, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([55570, 48570])) [1.14412189 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([18413, 16301])) [1.1295626 1.       ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([18566, 16148])) [1.14973991 1.        ]
# class_weights : {0: 0.937016375742307, 1: 1.0720609429689107}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (104140, 2)
# y_val_ohe.shape : (34714, 2)
# y_test_ohe.shape : (34714, 2)

# %% [markdown]
# ### **Training**

# %%
(_, row, col, _) = x_train.shape

# model = FER_Model(input_shape=(row, col, 3))
# opt = Adam(lr=0.0001, decay=0.00005)
# model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])


ckpt_path = current_path + 'ckpt/'
model_name = 'classifier_%s_arima_close_updown_pr_05581.h5' % period
model = keras.models.load_model(ckpt_path + model_name)
  
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_%s_arima_close_updown_pr.h5' % period

checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=40)
# callbacks_list = [checkpoint, checkpoint2, checkpoint3]
callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/1000
#  - 55s - loss: 0.5511 - accuracy: 0.7065 - val_loss: 0.5902 - val_accuracy: 0.6355
#
# Epoch 00001: val_loss improved from inf to 0.59023, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_arima_close_updown_pr.h5
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/1000
#  - 50s - loss: 0.5511 - accuracy: 0.7051 - val_loss: 0.7120 - val_accuracy: 0.6393
#
# Epoch 00002: val_loss did not improve from 0.59023
# Epoch 3/1000
#  - 48s - loss: 0.5508 - accuracy: 0.7048 - val_loss: 0.7047 - val_accuracy: 0.6412
#
# Epoch 00003: val_loss did not improve from 0.59023
# Epoch 4/1000
#  - 48s - loss: 0.5463 - accuracy: 0.7095 - val_loss: 0.6574 - val_accuracy: 0.6395
#
# Epoch 00004: val_loss did not improve from 0.59023
# Epoch 5/1000
#  - 49s - loss: 0.5456 - accuracy: 0.7088 - val_loss: 0.6739 - val_accuracy: 0.6429
#
# Epoch 00005: val_loss did not improve from 0.59023
# Epoch 6/1000
#  - 49s - loss: 0.5444 - accuracy: 0.7114 - val_loss: 0.6698 - val_accuracy: 0.6385
#
# Epoch 00006: val_loss did not improve from 0.59023
# Epoch 7/1000
#  - 49s - loss: 0.5400 - accuracy: 0.7146 - val_loss: 0.6354 - val_accuracy: 0.6403
#
# Epoch 00007: val_loss did not improve from 0.59023
# Epoch 8/1000
#  - 49s - loss: 0.5417 - accuracy: 0.7141 - val_loss: 0.7424 - val_accuracy: 0.6413
#
# Epoch 00008: val_loss did not improve from 0.59023
# Epoch 9/1000
#  - 48s - loss: 0.5393 - accuracy: 0.7163 - val_loss: 0.5968 - val_accuracy: 0.6418
#
# Epoch 00009: val_loss did not improve from 0.59023
# Epoch 10/1000
#  - 48s - loss: 0.5361 - accuracy: 0.7193 - val_loss: 0.6935 - val_accuracy: 0.6422
#
# Epoch 00010: val_loss did not improve from 0.59023
# Epoch 11/1000
#  - 48s - loss: 0.5341 - accuracy: 0.7193 - val_loss: 0.6119 - val_accuracy: 0.6417
#
# Epoch 00011: val_loss did not improve from 0.59023
# Epoch 12/1000
#  - 48s - loss: 0.5343 - accuracy: 0.7204 - val_loss: 0.5974 - val_accuracy: 0.6429
#
# Epoch 00012: val_loss did not improve from 0.59023
# Epoch 13/1000
#  - 48s - loss: 0.5326 - accuracy: 0.7221 - val_loss: 0.7439 - val_accuracy: 0.6409
#
# Epoch 00013: val_loss did not improve from 0.59023
# Epoch 14/1000
#  - 48s - loss: 0.5311 - accuracy: 0.7218 - val_loss: 0.6720 - val_accuracy: 0.6409
#
# Epoch 00014: val_loss did not improve from 0.59023
# Epoch 15/1000
#  - 48s - loss: 0.5289 - accuracy: 0.7236 - val_loss: 0.8304 - val_accuracy: 0.6435
#
# Epoch 00015: val_loss did not improve from 0.59023
# Epoch 16/1000
#  - 48s - loss: 0.5268 - accuracy: 0.7271 - val_loss: 0.7466 - val_accuracy: 0.6428
#
# Epoch 00016: val_loss did not improve from 0.59023
# Epoch 17/1000
#  - 48s - loss: 0.5268 - accuracy: 0.7261 - val_loss: 0.6907 - val_accuracy: 0.6419
#
# Epoch 00017: val_loss did not improve from 0.59023
# Epoch 18/1000
#  - 48s - loss: 0.5243 - accuracy: 0.7272 - val_loss: 0.7667 - val_accuracy: 0.6414
#
# Epoch 00018: val_loss did not improve from 0.59023
# Epoch 19/1000
#  - 48s - loss: 0.5227 - accuracy: 0.7294 - val_loss: 0.6845 - val_accuracy: 0.6429
#
# Epoch 00019: val_loss did not improve from 0.59023
# Epoch 20/1000
#  - 48s - loss: 0.5218 - accuracy: 0.7308 - val_loss: 0.6705 - val_accuracy: 0.6436
#
# Epoch 00020: val_loss did not improve from 0.59023
# Epoch 21/1000
#  - 48s - loss: 0.5203 - accuracy: 0.7312 - val_loss: 0.7643 - val_accuracy: 0.6434
#
# Epoch 00021: val_loss did not improve from 0.59023
# Epoch 22/1000
#  - 48s - loss: 0.5175 - accuracy: 0.7331 - val_loss: 0.6779 - val_accuracy: 0.6426
#
# Epoch 00022: val_loss did not improve from 0.59023
# Epoch 23/1000
#  - 48s - loss: 0.5172 - accuracy: 0.7332 - val_loss: 0.6799 - val_accuracy: 0.6433
#
# Epoch 00023: val_loss did not improve from 0.59023
# Epoch 24/1000
#  - 47s - loss: 0.5137 - accuracy: 0.7349 - val_loss: 0.7947 - val_accuracy: 0.6450
#
# Epoch 00024: val_loss did not improve from 0.59023
# Epoch 25/1000
#  - 47s - loss: 0.5116 - accuracy: 0.7367 - val_loss: 0.7032 - val_accuracy: 0.6448
#
# Epoch 00025: val_loss did not improve from 0.59023
# Epoch 26/1000
#  - 48s - loss: 0.5120 - accuracy: 0.7361 - val_loss: 0.8894 - val_accuracy: 0.6437
#
# Epoch 00026: val_loss did not improve from 0.59023
# Epoch 27/1000
#  - 48s - loss: 0.5093 - accuracy: 0.7382 - val_loss: 0.6191 - val_accuracy: 0.6467
#
# Epoch 00027: val_loss did not improve from 0.59023
# Epoch 28/1000
#  - 48s - loss: 0.5090 - accuracy: 0.7382 - val_loss: 0.5917 - val_accuracy: 0.6423
#
# Epoch 00028: val_loss did not improve from 0.59023
# Epoch 29/1000
#  - 48s - loss: 0.5061 - accuracy: 0.7412 - val_loss: 0.6901 - val_accuracy: 0.6431
#
# Epoch 00029: val_loss did not improve from 0.59023
# Epoch 30/1000
#  - 48s - loss: 0.5049 - accuracy: 0.7415 - val_loss: 0.6683 - val_accuracy: 0.6423
#
# Epoch 00030: val_loss did not improve from 0.59023
# Epoch 31/1000
#  - 47s - loss: 0.5041 - accuracy: 0.7414 - val_loss: 0.7052 - val_accuracy: 0.6458
#
# Epoch 00031: val_loss did not improve from 0.59023
# Epoch 32/1000
#  - 48s - loss: 0.4994 - accuracy: 0.7465 - val_loss: 0.6450 - val_accuracy: 0.6466
#
# Epoch 00032: val_loss did not improve from 0.59023
# Epoch 33/1000
#  - 47s - loss: 0.4983 - accuracy: 0.7476 - val_loss: 0.6477 - val_accuracy: 0.6457
#
# Epoch 00033: val_loss did not improve from 0.59023
# Epoch 34/1000
#  - 47s - loss: 0.4988 - accuracy: 0.7456 - val_loss: 0.7533 - val_accuracy: 0.6457
#
# Epoch 00034: val_loss did not improve from 0.59023
# Epoch 35/1000
#  - 47s - loss: 0.4979 - accuracy: 0.7467 - val_loss: 0.7834 - val_accuracy: 0.6435
#
# Epoch 00035: val_loss did not improve from 0.59023
# Epoch 36/1000
#  - 47s - loss: 0.4970 - accuracy: 0.7465 - val_loss: 0.7172 - val_accuracy: 0.6455
#
# Epoch 00036: val_loss did not improve from 0.59023
# Epoch 37/1000
#  - 47s - loss: 0.4918 - accuracy: 0.7504 - val_loss: 0.7007 - val_accuracy: 0.6453
#
# Epoch 00037: val_loss did not improve from 0.59023
# Epoch 38/1000
#  - 47s - loss: 0.4927 - accuracy: 0.7492 - val_loss: 0.8642 - val_accuracy: 0.6488
#
# Epoch 00038: val_loss did not improve from 0.59023
# Epoch 39/1000
#  - 48s - loss: 0.4897 - accuracy: 0.7530 - val_loss: 0.6714 - val_accuracy: 0.6480
#
# Epoch 00039: val_loss did not improve from 0.59023
# Epoch 40/1000
#  - 48s - loss: 0.4889 - accuracy: 0.7539 - val_loss: 0.8115 - val_accuracy: 0.6456
#
# Epoch 00040: val_loss did not improve from 0.59023
# Epoch 41/1000
#  - 48s - loss: 0.4901 - accuracy: 0.7520 - val_loss: 0.7577 - val_accuracy: 0.6473
#
# Epoch 00041: val_loss did not improve from 0.59023
# Epoch 42/1000
#  - 48s - loss: 0.4882 - accuracy: 0.7528 - val_loss: 0.8010 - val_accuracy: 0.6469
#
# Epoch 00042: val_loss did not improve from 0.59023
# Epoch 43/1000
#  - 48s - loss: 0.4833 - accuracy: 0.7569 - val_loss: 0.5868 - val_accuracy: 0.6452
#
# Epoch 00043: val_loss improved from 0.59023 to 0.58678, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_arima_close_updown_pr.h5
# Epoch 44/1000
#  - 49s - loss: 0.4864 - accuracy: 0.7552 - val_loss: 0.9181 - val_accuracy: 0.6487
#
# Epoch 00044: val_loss did not improve from 0.58678
# Epoch 45/1000
#  - 48s - loss: 0.4842 - accuracy: 0.7573 - val_loss: 0.7465 - val_accuracy: 0.6472
#
# Epoch 00045: val_loss did not improve from 0.58678
# Epoch 46/1000
#  - 47s - loss: 0.4804 - accuracy: 0.7604 - val_loss: 0.7105 - val_accuracy: 0.6440
#
# Epoch 00046: val_loss did not improve from 0.58678
# Epoch 47/1000
#  - 47s - loss: 0.4809 - accuracy: 0.7592 - val_loss: 0.6067 - val_accuracy: 0.6492
#
# Epoch 00047: val_loss did not improve from 0.58678
# Epoch 48/1000
#  - 47s - loss: 0.4775 - accuracy: 0.7606 - val_loss: 0.6870 - val_accuracy: 0.6469
#
# Epoch 00048: val_loss did not improve from 0.58678
# Epoch 49/1000
#  - 47s - loss: 0.4766 - accuracy: 0.7611 - val_loss: 0.7233 - val_accuracy: 0.6476
#
# Epoch 00049: val_loss did not improve from 0.58678
# Epoch 50/1000
#  - 47s - loss: 0.4746 - accuracy: 0.7633 - val_loss: 0.5779 - val_accuracy: 0.6457
#
# Epoch 00050: val_loss improved from 0.58678 to 0.57795, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_arima_close_updown_pr.h5
# Epoch 51/1000
#  - 49s - loss: 0.4720 - accuracy: 0.7643 - val_loss: 0.8280 - val_accuracy: 0.6497
#
# Epoch 00051: val_loss did not improve from 0.57795
# Epoch 52/1000
#  - 48s - loss: 0.4720 - accuracy: 0.7653 - val_loss: 0.6697 - val_accuracy: 0.6482
#
# Epoch 00052: val_loss did not improve from 0.57795
# Epoch 53/1000
#  - 48s - loss: 0.4700 - accuracy: 0.7680 - val_loss: 0.8613 - val_accuracy: 0.6481
#
# Epoch 00053: val_loss did not improve from 0.57795
# Epoch 54/1000
#  - 48s - loss: 0.4714 - accuracy: 0.7650 - val_loss: 0.8711 - val_accuracy: 0.6488
#
# Epoch 00054: val_loss did not improve from 0.57795
# Epoch 55/1000
#  - 48s - loss: 0.4660 - accuracy: 0.7680 - val_loss: 0.8598 - val_accuracy: 0.6488
#
# Epoch 00055: val_loss did not improve from 0.57795
# Epoch 56/1000
#  - 47s - loss: 0.4686 - accuracy: 0.7674 - val_loss: 0.8276 - val_accuracy: 0.6486
#
# Epoch 00056: val_loss did not improve from 0.57795
# Epoch 57/1000
#  - 47s - loss: 0.4657 - accuracy: 0.7681 - val_loss: 0.8204 - val_accuracy: 0.6461
#
# Epoch 00057: val_loss did not improve from 0.57795
# Epoch 58/1000
#  - 47s - loss: 0.4631 - accuracy: 0.7690 - val_loss: 0.8845 - val_accuracy: 0.6481
#
# Epoch 00058: val_loss did not improve from 0.57795
# Epoch 59/1000
#  - 47s - loss: 0.4615 - accuracy: 0.7714 - val_loss: 0.8097 - val_accuracy: 0.6484
#
# Epoch 00059: val_loss did not improve from 0.57795
# Epoch 60/1000
#  - 48s - loss: 0.4609 - accuracy: 0.7722 - val_loss: 0.6736 - val_accuracy: 0.6451
#
# Epoch 00060: val_loss did not improve from 0.57795
# Epoch 61/1000
#  - 48s - loss: 0.4623 - accuracy: 0.7720 - val_loss: 0.9124 - val_accuracy: 0.6466
#
# Epoch 00061: val_loss did not improve from 0.57795
# Epoch 62/1000
#  - 48s - loss: 0.4581 - accuracy: 0.7749 - val_loss: 0.6853 - val_accuracy: 0.6464
#
# Epoch 00062: val_loss did not improve from 0.57795
# Epoch 63/1000
#  - 48s - loss: 0.4583 - accuracy: 0.7747 - val_loss: 0.6514 - val_accuracy: 0.6481
#
# Epoch 00063: val_loss did not improve from 0.57795
# Epoch 64/1000
#  - 48s - loss: 0.4550 - accuracy: 0.7752 - val_loss: 0.8168 - val_accuracy: 0.6483
#
# Epoch 00064: val_loss did not improve from 0.57795
# Epoch 65/1000
#  - 48s - loss: 0.4538 - accuracy: 0.7775 - val_loss: 0.7174 - val_accuracy: 0.6489
#
# Epoch 00065: val_loss did not improve from 0.57795
# Epoch 66/1000
#  - 48s - loss: 0.4523 - accuracy: 0.7781 - val_loss: 0.8748 - val_accuracy: 0.6488
#
# Epoch 00066: val_loss did not improve from 0.57795
# Epoch 67/1000
#  - 48s - loss: 0.4526 - accuracy: 0.7784 - val_loss: 0.8942 - val_accuracy: 0.6445
#
# Epoch 00067: val_loss did not improve from 0.57795
# Epoch 68/1000
#  - 48s - loss: 0.4487 - accuracy: 0.7793 - val_loss: 0.6926 - val_accuracy: 0.6467
#
# Epoch 00068: val_loss did not improve from 0.57795
# Epoch 69/1000
#  - 48s - loss: 0.4456 - accuracy: 0.7812 - val_loss: 0.6881 - val_accuracy: 0.6490
#
# Epoch 00069: val_loss did not improve from 0.57795
# Epoch 70/1000
#  - 48s - loss: 0.4471 - accuracy: 0.7811 - val_loss: 0.7330 - val_accuracy: 0.6496
#
# Epoch 00070: val_loss did not improve from 0.57795
# Epoch 71/1000
#  - 48s - loss: 0.4457 - accuracy: 0.7822 - val_loss: 0.7930 - val_accuracy: 0.6495
#
# Epoch 00071: val_loss did not improve from 0.57795
# Epoch 72/1000
#  - 48s - loss: 0.4448 - accuracy: 0.7818 - val_loss: 0.7296 - val_accuracy: 0.6499
#
# Epoch 00072: val_loss did not improve from 0.57795
# Epoch 73/1000
#  - 48s - loss: 0.4428 - accuracy: 0.7833 - val_loss: 0.6963 - val_accuracy: 0.6494
#
# Epoch 00073: val_loss did not improve from 0.57795
# Epoch 74/1000
#  - 48s - loss: 0.4400 - accuracy: 0.7851 - val_loss: 0.7698 - val_accuracy: 0.6488
#
# Epoch 00074: val_loss did not improve from 0.57795
# Epoch 75/1000
#  - 47s - loss: 0.4412 - accuracy: 0.7832 - val_loss: 0.7678 - val_accuracy: 0.6512
#
# Epoch 00075: val_loss did not improve from 0.57795
# Epoch 76/1000
#  - 47s - loss: 0.4389 - accuracy: 0.7862 - val_loss: 0.7585 - val_accuracy: 0.6496
#
# Epoch 00076: val_loss did not improve from 0.57795
# Epoch 77/1000
#  - 47s - loss: 0.4386 - accuracy: 0.7852 - val_loss: 0.7939 - val_accuracy: 0.6494
#
# Epoch 00077: val_loss did not improve from 0.57795
# Epoch 78/1000
#  - 47s - loss: 0.4367 - accuracy: 0.7870 - val_loss: 0.8866 - val_accuracy: 0.6505
#
# Epoch 00078: val_loss did not improve from 0.57795
# Epoch 79/1000
#  - 47s - loss: 0.4365 - accuracy: 0.7871 - val_loss: 0.8516 - val_accuracy: 0.6502
#
# Epoch 00079: val_loss did not improve from 0.57795
# Epoch 80/1000
#  - 48s - loss: 0.4350 - accuracy: 0.7889 - val_loss: 0.8192 - val_accuracy: 0.6505
#
# Epoch 00080: val_loss did not improve from 0.57795
# Epoch 81/1000
#  - 47s - loss: 0.4325 - accuracy: 0.7894 - val_loss: 0.7348 - val_accuracy: 0.6479
#
# Epoch 00081: val_loss did not improve from 0.57795
# Epoch 82/1000
#  - 47s - loss: 0.4320 - accuracy: 0.7891 - val_loss: 0.9178 - val_accuracy: 0.6499
#
# Epoch 00082: val_loss did not improve from 0.57795
# Epoch 83/1000
#  - 47s - loss: 0.4310 - accuracy: 0.7914 - val_loss: 0.8032 - val_accuracy: 0.6500
#
# Epoch 00083: val_loss did not improve from 0.57795
# Epoch 84/1000
#  - 47s - loss: 0.4298 - accuracy: 0.7912 - val_loss: 0.7859 - val_accuracy: 0.6497
#
# Epoch 00084: val_loss did not improve from 0.57795
# Epoch 85/1000
#  - 47s - loss: 0.4274 - accuracy: 0.7957 - val_loss: 0.7092 - val_accuracy: 0.6488
#
# Epoch 00085: val_loss did not improve from 0.57795
# Epoch 86/1000
#  - 47s - loss: 0.4270 - accuracy: 0.7942 - val_loss: 0.7754 - val_accuracy: 0.6502
#
# Epoch 00086: val_loss did not improve from 0.57795
# Epoch 87/1000
#  - 47s - loss: 0.4263 - accuracy: 0.7933 - val_loss: 0.7965 - val_accuracy: 0.6484
#
# Epoch 00087: val_loss did not improve from 0.57795
# Epoch 88/1000
#  - 48s - loss: 0.4253 - accuracy: 0.7947 - val_loss: 0.6645 - val_accuracy: 0.6484
#
# Epoch 00088: val_loss did not improve from 0.57795
# Epoch 89/1000
#  - 47s - loss: 0.4227 - accuracy: 0.7964 - val_loss: 0.7752 - val_accuracy: 0.6473
#
# Epoch 00089: val_loss did not improve from 0.57795
# Epoch 90/1000
#  - 47s - loss: 0.4207 - accuracy: 0.7978 - val_loss: 0.9414 - val_accuracy: 0.6476
#
# Epoch 00090: val_loss did not improve from 0.57795
# Epoch 91/1000
#  - 47s - loss: 0.4209 - accuracy: 0.7970 - val_loss: 0.8821 - val_accuracy: 0.6509
#
# Epoch 00091: val_loss did not improve from 0.57795
# Epoch 92/1000
#  - 47s - loss: 0.4203 - accuracy: 0.7993 - val_loss: 0.8209 - val_accuracy: 0.6479
#
# Epoch 00092: val_loss did not improve from 0.57795
# Epoch 93/1000
#  - 47s - loss: 0.4167 - accuracy: 0.7997 - val_loss: 0.9245 - val_accuracy: 0.6472
#
# Epoch 00093: val_loss did not improve from 0.57795
# Epoch 94/1000
#  - 47s - loss: 0.4190 - accuracy: 0.7973 - val_loss: 0.7282 - val_accuracy: 0.6500
#
# Epoch 00094: val_loss did not improve from 0.57795
# Epoch 95/1000
#  - 47s - loss: 0.4156 - accuracy: 0.7989 - val_loss: 0.8327 - val_accuracy: 0.6472
#
# Epoch 00095: val_loss did not improve from 0.57795
# Epoch 96/1000
#  - 47s - loss: 0.4154 - accuracy: 0.7997 - val_loss: 0.7656 - val_accuracy: 0.6503
#
# Epoch 00096: val_loss did not improve from 0.57795
# Epoch 97/1000
#  - 47s - loss: 0.4140 - accuracy: 0.8017 - val_loss: 0.9856 - val_accuracy: 0.6473
#
# Epoch 00097: val_loss did not improve from 0.57795
# Epoch 98/1000
#  - 47s - loss: 0.4118 - accuracy: 0.8028 - val_loss: 0.9179 - val_accuracy: 0.6483
#
# Epoch 00098: val_loss did not improve from 0.57795
# Epoch 99/1000
#  - 47s - loss: 0.4113 - accuracy: 0.8020 - val_loss: 0.8622 - val_accuracy: 0.6503
#
# Epoch 00099: val_loss did not improve from 0.57795
# Epoch 100/1000
#  - 47s - loss: 0.4115 - accuracy: 0.8038 - val_loss: 0.8163 - val_accuracy: 0.6482
#
# Epoch 00100: val_loss did not improve from 0.57795
# Epoch 101/1000
#  - 47s - loss: 0.4080 - accuracy: 0.8051 - val_loss: 0.8602 - val_accuracy: 0.6472
#
# Epoch 00101: val_loss did not improve from 0.57795
# Epoch 102/1000
#  - 47s - loss: 0.4085 - accuracy: 0.8056 - val_loss: 0.7536 - val_accuracy: 0.6466
#
# Epoch 00102: val_loss did not improve from 0.57795
# Epoch 103/1000
#  - 47s - loss: 0.4054 - accuracy: 0.8067 - val_loss: 0.7542 - val_accuracy: 0.6511
#
# Epoch 00103: val_loss did not improve from 0.57795
# Epoch 104/1000
#  - 47s - loss: 0.4064 - accuracy: 0.8057 - val_loss: 0.8204 - val_accuracy: 0.6492
#
# Epoch 00104: val_loss did not improve from 0.57795
# Epoch 105/1000
#  - 47s - loss: 0.4038 - accuracy: 0.8092 - val_loss: 0.8469 - val_accuracy: 0.6500
#
# Epoch 00105: val_loss did not improve from 0.57795
# Epoch 106/1000
#  - 47s - loss: 0.4042 - accuracy: 0.8083 - val_loss: 0.8862 - val_accuracy: 0.6494
#
# Epoch 00106: val_loss did not improve from 0.57795
# Epoch 107/1000
#  - 47s - loss: 0.4028 - accuracy: 0.8078 - val_loss: 0.8139 - val_accuracy: 0.6489
#
# Epoch 00107: val_loss did not improve from 0.57795
# Epoch 108/1000
#  - 47s - loss: 0.4006 - accuracy: 0.8105 - val_loss: 0.8416 - val_accuracy: 0.6495
#
# Epoch 00108: val_loss did not improve from 0.57795
# Epoch 109/1000
#  - 47s - loss: 0.3987 - accuracy: 0.8116 - val_loss: 0.8471 - val_accuracy: 0.6492
#
# Epoch 00109: val_loss did not improve from 0.57795
# Epoch 110/1000
#  - 47s - loss: 0.3970 - accuracy: 0.8106 - val_loss: 0.6848 - val_accuracy: 0.6498
#
# Epoch 00110: val_loss did not improve from 0.57795
# Epoch 111/1000
#  - 47s - loss: 0.3977 - accuracy: 0.8118 - val_loss: 0.8327 - val_accuracy: 0.6514
#
# Epoch 00111: val_loss did not improve from 0.57795
# Epoch 112/1000
#  - 47s - loss: 0.3970 - accuracy: 0.8106 - val_loss: 0.9111 - val_accuracy: 0.6506
#
# Epoch 00112: val_loss did not improve from 0.57795
# Epoch 113/1000
#  - 47s - loss: 0.3944 - accuracy: 0.8143 - val_loss: 1.0609 - val_accuracy: 0.6523
#
# Epoch 00113: val_loss did not improve from 0.57795
# Epoch 114/1000
#  - 47s - loss: 0.3934 - accuracy: 0.8133 - val_loss: 0.9288 - val_accuracy: 0.6509
#
# Epoch 00114: val_loss did not improve from 0.57795
# Epoch 115/1000
#  - 47s - loss: 0.3931 - accuracy: 0.8136 - val_loss: 0.7918 - val_accuracy: 0.6487
#
# Epoch 00115: val_loss did not improve from 0.57795
# Epoch 116/1000
#  - 47s - loss: 0.3932 - accuracy: 0.8145 - val_loss: 0.8057 - val_accuracy: 0.6513
#
# Epoch 00116: val_loss did not improve from 0.57795
# Epoch 117/1000
#  - 47s - loss: 0.3899 - accuracy: 0.8166 - val_loss: 0.7733 - val_accuracy: 0.6492
#
# Epoch 00117: val_loss did not improve from 0.57795
# Epoch 118/1000
#  - 47s - loss: 0.3900 - accuracy: 0.8162 - val_loss: 1.0788 - val_accuracy: 0.6486
#
# Epoch 00118: val_loss did not improve from 0.57795
# Epoch 119/1000
#  - 47s - loss: 0.3898 - accuracy: 0.8178 - val_loss: 0.8488 - val_accuracy: 0.6514
#
# Epoch 00119: val_loss did not improve from 0.57795
# Epoch 120/1000
#  - 47s - loss: 0.3863 - accuracy: 0.8182 - val_loss: 0.7014 - val_accuracy: 0.6497
#
# Epoch 00120: val_loss did not improve from 0.57795
# Epoch 121/1000
#  - 47s - loss: 0.3858 - accuracy: 0.8187 - val_loss: 0.8124 - val_accuracy: 0.6516
#
# Epoch 00121: val_loss did not improve from 0.57795
# Epoch 122/1000
#  - 47s - loss: 0.3863 - accuracy: 0.8175 - val_loss: 0.6573 - val_accuracy: 0.6520
#
# Epoch 00122: val_loss did not improve from 0.57795
# Epoch 123/1000
#  - 47s - loss: 0.3847 - accuracy: 0.8193 - val_loss: 0.9106 - val_accuracy: 0.6494
#
# Epoch 00123: val_loss did not improve from 0.57795
# Epoch 124/1000
#  - 47s - loss: 0.3823 - accuracy: 0.8195 - val_loss: 0.8231 - val_accuracy: 0.6504
#
# Epoch 00124: val_loss did not improve from 0.57795
# Epoch 125/1000
#  - 47s - loss: 0.3798 - accuracy: 0.8208 - val_loss: 0.7965 - val_accuracy: 0.6513
#
# Epoch 00125: val_loss did not improve from 0.57795
# Epoch 126/1000
#  - 49s - loss: 0.3806 - accuracy: 0.8205 - val_loss: 0.8489 - val_accuracy: 0.6514
#
# Epoch 00126: val_loss did not improve from 0.57795
# Epoch 127/1000
#  - 47s - loss: 0.3812 - accuracy: 0.8205 - val_loss: 1.2505 - val_accuracy: 0.6505
#
# Epoch 00127: val_loss did not improve from 0.57795
# Epoch 128/1000
#  - 47s - loss: 0.3782 - accuracy: 0.8234 - val_loss: 0.6983 - val_accuracy: 0.6500
#
# Epoch 00128: val_loss did not improve from 0.57795
# Epoch 129/1000
#  - 47s - loss: 0.3781 - accuracy: 0.8234 - val_loss: 0.8616 - val_accuracy: 0.6488
#
# Epoch 00129: val_loss did not improve from 0.57795
# Epoch 130/1000
#  - 49s - loss: 0.3777 - accuracy: 0.8233 - val_loss: 1.1027 - val_accuracy: 0.6505
#
# Epoch 00130: val_loss did not improve from 0.57795
# Epoch 131/1000
#  - 48s - loss: 0.3763 - accuracy: 0.8253 - val_loss: 0.7288 - val_accuracy: 0.6490
#
# Epoch 00131: val_loss did not improve from 0.57795
# Epoch 132/1000
#  - 48s - loss: 0.3733 - accuracy: 0.8257 - val_loss: 0.7975 - val_accuracy: 0.6480
#
# Epoch 00132: val_loss did not improve from 0.57795
# Epoch 133/1000
#  - 47s - loss: 0.3740 - accuracy: 0.8251 - val_loss: 1.1146 - val_accuracy: 0.6498
#
# Epoch 00133: val_loss did not improve from 0.57795
# Epoch 134/1000
#  - 47s - loss: 0.3725 - accuracy: 0.8258 - val_loss: 0.9214 - val_accuracy: 0.6489
#
# Epoch 00134: val_loss did not improve from 0.57795
# Epoch 135/1000
#  - 47s - loss: 0.3716 - accuracy: 0.8271 - val_loss: 0.8074 - val_accuracy: 0.6473
#
# Epoch 00135: val_loss did not improve from 0.57795
# Epoch 136/1000
#  - 47s - loss: 0.3718 - accuracy: 0.8272 - val_loss: 0.8372 - val_accuracy: 0.6493
#
# Epoch 00136: val_loss did not improve from 0.57795
# Epoch 137/1000
#  - 47s - loss: 0.3686 - accuracy: 0.8284 - val_loss: 1.0148 - val_accuracy: 0.6490
#
# Epoch 00137: val_loss did not improve from 0.57795
# Epoch 138/1000
#  - 47s - loss: 0.3688 - accuracy: 0.8287 - val_loss: 0.9963 - val_accuracy: 0.6520
#
# Epoch 00138: val_loss did not improve from 0.57795
# Epoch 139/1000
#  - 47s - loss: 0.3671 - accuracy: 0.8295 - val_loss: 0.9580 - val_accuracy: 0.6526
#
# Epoch 00139: val_loss did not improve from 0.57795
# Epoch 140/1000
#  - 47s - loss: 0.3677 - accuracy: 0.8282 - val_loss: 0.8194 - val_accuracy: 0.6501
#
# Epoch 00140: val_loss did not improve from 0.57795
# Epoch 141/1000
#  - 47s - loss: 0.3662 - accuracy: 0.8287 - val_loss: 0.8876 - val_accuracy: 0.6500
#
# Epoch 00141: val_loss did not improve from 0.57795
# Epoch 142/1000
#  - 47s - loss: 0.3670 - accuracy: 0.8294 - val_loss: 1.0914 - val_accuracy: 0.6485
#
# Epoch 00142: val_loss did not improve from 0.57795
# Epoch 143/1000
#  - 47s - loss: 0.3620 - accuracy: 0.8310 - val_loss: 0.9170 - val_accuracy: 0.6488
#
# Epoch 00143: val_loss did not improve from 0.57795
# Epoch 144/1000
#  - 47s - loss: 0.3627 - accuracy: 0.8318 - val_loss: 0.8834 - val_accuracy: 0.6493
#
# Epoch 00144: val_loss did not improve from 0.57795
# Epoch 145/1000
#  - 47s - loss: 0.3619 - accuracy: 0.8331 - val_loss: 0.9884 - val_accuracy: 0.6482
#
# Epoch 00145: val_loss did not improve from 0.57795
# Epoch 146/1000
#  - 48s - loss: 0.3599 - accuracy: 0.8335 - val_loss: 0.8523 - val_accuracy: 0.6494
#
# Epoch 00146: val_loss did not improve from 0.57795
# Epoch 147/1000
#  - 47s - loss: 0.3603 - accuracy: 0.8334 - val_loss: 0.9456 - val_accuracy: 0.6479
#
# Epoch 00147: val_loss did not improve from 0.57795
# Epoch 148/1000
#  - 47s - loss: 0.3584 - accuracy: 0.8334 - val_loss: 1.1640 - val_accuracy: 0.6497
#
# Epoch 00148: val_loss did not improve from 0.57795
# Epoch 149/1000
#  - 47s - loss: 0.3573 - accuracy: 0.8356 - val_loss: 1.0736 - val_accuracy: 0.6486
#
# Epoch 00149: val_loss did not improve from 0.57795
# Epoch 150/1000
#  - 47s - loss: 0.3581 - accuracy: 0.8353 - val_loss: 1.1084 - val_accuracy: 0.6511
#
# Epoch 00150: val_loss did not improve from 0.57795
# Epoch 151/1000
#  - 47s - loss: 0.3548 - accuracy: 0.8365 - val_loss: 0.8872 - val_accuracy: 0.6501
#
# Epoch 00151: val_loss did not improve from 0.57795
# Epoch 152/1000
#  - 47s - loss: 0.3560 - accuracy: 0.8346 - val_loss: 0.9809 - val_accuracy: 0.6489
#
# Epoch 00152: val_loss did not improve from 0.57795
# Epoch 153/1000
#  - 47s - loss: 0.3569 - accuracy: 0.8349 - val_loss: 0.7969 - val_accuracy: 0.6481
#
# Epoch 00153: val_loss did not improve from 0.57795
# Epoch 154/1000
#  - 47s - loss: 0.3519 - accuracy: 0.8376 - val_loss: 0.7471 - val_accuracy: 0.6485
#
# Epoch 00154: val_loss did not improve from 0.57795
# Epoch 155/1000
#  - 47s - loss: 0.3514 - accuracy: 0.8383 - val_loss: 0.9590 - val_accuracy: 0.6490
#
# Epoch 00155: val_loss did not improve from 0.57795
# Epoch 156/1000
#  - 47s - loss: 0.3537 - accuracy: 0.8370 - val_loss: 1.2288 - val_accuracy: 0.6482
#
# Epoch 00156: val_loss did not improve from 0.57795
# Epoch 157/1000
#  - 47s - loss: 0.3496 - accuracy: 0.8394 - val_loss: 1.3265 - val_accuracy: 0.6484
#
# Epoch 00157: val_loss did not improve from 0.57795
# Epoch 158/1000
#  - 48s - loss: 0.3506 - accuracy: 0.8390 - val_loss: 0.9133 - val_accuracy: 0.6491
#
# Epoch 00158: val_loss did not improve from 0.57795
# Epoch 159/1000
#  - 47s - loss: 0.3487 - accuracy: 0.8389 - val_loss: 0.9685 - val_accuracy: 0.6481
#
# Epoch 00159: val_loss did not improve from 0.57795
# Epoch 160/1000
#  - 47s - loss: 0.3482 - accuracy: 0.8403 - val_loss: 0.9568 - val_accuracy: 0.6489
#
# Epoch 00160: val_loss did not improve from 0.57795
# Epoch 161/1000
#  - 47s - loss: 0.3459 - accuracy: 0.8418 - val_loss: 1.0661 - val_accuracy: 0.6489
#
# Epoch 00161: val_loss did not improve from 0.57795
# Epoch 162/1000
#  - 47s - loss: 0.3454 - accuracy: 0.8407 - val_loss: 1.0062 - val_accuracy: 0.6515
#
# Epoch 00162: val_loss did not improve from 0.57795
# Epoch 163/1000
#  - 47s - loss: 0.3443 - accuracy: 0.8419 - val_loss: 1.3331 - val_accuracy: 0.6522
#
# Epoch 00163: val_loss did not improve from 0.57795
# Epoch 164/1000
#  - 47s - loss: 0.3444 - accuracy: 0.8417 - val_loss: 1.0475 - val_accuracy: 0.6506
#
# Epoch 00164: val_loss did not improve from 0.57795
# Epoch 165/1000
#  - 48s - loss: 0.3438 - accuracy: 0.8434 - val_loss: 0.9860 - val_accuracy: 0.6508
#
# Epoch 00165: val_loss did not improve from 0.57795
# Epoch 166/1000
#  - 48s - loss: 0.3417 - accuracy: 0.8442 - val_loss: 0.9756 - val_accuracy: 0.6494
#
# Epoch 00166: val_loss did not improve from 0.57795
# Epoch 167/1000
#  - 49s - loss: 0.3406 - accuracy: 0.8436 - val_loss: 0.6911 - val_accuracy: 0.6486
#
# Epoch 00167: val_loss did not improve from 0.57795
# Epoch 168/1000
#  - 47s - loss: 0.3395 - accuracy: 0.8450 - val_loss: 1.0668 - val_accuracy: 0.6508
#
# Epoch 00168: val_loss did not improve from 0.57795
# Epoch 169/1000
#  - 47s - loss: 0.3368 - accuracy: 0.8458 - val_loss: 0.7595 - val_accuracy: 0.6480
#
# Epoch 00169: val_loss did not improve from 0.57795
# Epoch 170/1000
#  - 47s - loss: 0.3383 - accuracy: 0.8457 - val_loss: 1.2914 - val_accuracy: 0.6517
#
# Epoch 00170: val_loss did not improve from 0.57795
# Epoch 171/1000
#  - 47s - loss: 0.3396 - accuracy: 0.8445 - val_loss: 1.0735 - val_accuracy: 0.6503
#
# Epoch 00171: val_loss did not improve from 0.57795
# Epoch 172/1000
#  - 48s - loss: 0.3378 - accuracy: 0.8462 - val_loss: 1.0519 - val_accuracy: 0.6493
#
# Epoch 00172: val_loss did not improve from 0.57795
# Epoch 173/1000
#  - 48s - loss: 0.3338 - accuracy: 0.8471 - val_loss: 1.1685 - val_accuracy: 0.6501
#
# Epoch 00173: val_loss did not improve from 0.57795
# Epoch 174/1000
#  - 48s - loss: 0.3351 - accuracy: 0.8462 - val_loss: 1.0410 - val_accuracy: 0.6494
#
# Epoch 00174: val_loss did not improve from 0.57795
# Epoch 175/1000
#  - 48s - loss: 0.3343 - accuracy: 0.8485 - val_loss: 1.0571 - val_accuracy: 0.6484
#
# Epoch 00175: val_loss did not improve from 0.57795
# Epoch 176/1000
#  - 48s - loss: 0.3322 - accuracy: 0.8486 - val_loss: 1.0667 - val_accuracy: 0.6514
#
# Epoch 00176: val_loss did not improve from 0.57795
# Epoch 177/1000
#  - 48s - loss: 0.3324 - accuracy: 0.8486 - val_loss: 0.9163 - val_accuracy: 0.6500
#
# Epoch 00177: val_loss did not improve from 0.57795
# Epoch 178/1000
#  - 48s - loss: 0.3300 - accuracy: 0.8499 - val_loss: 0.9999 - val_accuracy: 0.6511
#
# Epoch 00178: val_loss did not improve from 0.57795
# Epoch 179/1000
#  - 48s - loss: 0.3303 - accuracy: 0.8495 - val_loss: 0.9589 - val_accuracy: 0.6494
#
# Epoch 00179: val_loss did not improve from 0.57795
# Epoch 180/1000
#  - 48s - loss: 0.3281 - accuracy: 0.8506 - val_loss: 0.8938 - val_accuracy: 0.6490
#
# Epoch 00180: val_loss did not improve from 0.57795
# Epoch 181/1000
#  - 48s - loss: 0.3287 - accuracy: 0.8514 - val_loss: 1.0071 - val_accuracy: 0.6496
#
# Epoch 00181: val_loss did not improve from 0.57795
# Epoch 182/1000
#  - 48s - loss: 0.3279 - accuracy: 0.8515 - val_loss: 0.9771 - val_accuracy: 0.6486
#
# Epoch 00182: val_loss did not improve from 0.57795
# Epoch 183/1000
#  - 47s - loss: 0.3293 - accuracy: 0.8495 - val_loss: 0.7631 - val_accuracy: 0.6510
#
# Epoch 00183: val_loss did not improve from 0.57795
# Epoch 184/1000
#  - 48s - loss: 0.3266 - accuracy: 0.8527 - val_loss: 1.0295 - val_accuracy: 0.6497
#
# Epoch 00184: val_loss did not improve from 0.57795
# Epoch 185/1000
#  - 48s - loss: 0.3247 - accuracy: 0.8521 - val_loss: 1.1305 - val_accuracy: 0.6497
#
# Epoch 00185: val_loss did not improve from 0.57795
# Epoch 186/1000
#  - 48s - loss: 0.3226 - accuracy: 0.8539 - val_loss: 1.1613 - val_accuracy: 0.6501
#
# Epoch 00186: val_loss did not improve from 0.57795
# Epoch 187/1000
#  - 48s - loss: 0.3212 - accuracy: 0.8544 - val_loss: 1.1322 - val_accuracy: 0.6493
#
# Epoch 00187: val_loss did not improve from 0.57795
# Epoch 188/1000
#  - 48s - loss: 0.3217 - accuracy: 0.8545 - val_loss: 1.1854 - val_accuracy: 0.6508
#
# Epoch 00188: val_loss did not improve from 0.57795
# Epoch 189/1000
#  - 48s - loss: 0.3227 - accuracy: 0.8549 - val_loss: 0.9389 - val_accuracy: 0.6501
#
# Epoch 00189: val_loss did not improve from 0.57795
# Epoch 190/1000
#  - 48s - loss: 0.3194 - accuracy: 0.8558 - val_loss: 1.0705 - val_accuracy: 0.6492
#
# Epoch 00190: val_loss did not improve from 0.57795
# Epoch 191/1000
#  - 48s - loss: 0.3195 - accuracy: 0.8560 - val_loss: 1.0469 - val_accuracy: 0.6501
#
# Epoch 00191: val_loss did not improve from 0.57795
# Epoch 192/1000
#  - 47s - loss: 0.3203 - accuracy: 0.8544 - val_loss: 1.0083 - val_accuracy: 0.6500
#
# Epoch 00192: val_loss did not improve from 0.57795
# Epoch 193/1000
#  - 48s - loss: 0.3195 - accuracy: 0.8559 - val_loss: 1.2681 - val_accuracy: 0.6512
#
# Epoch 00193: val_loss did not improve from 0.57795
# Epoch 194/1000
#  - 48s - loss: 0.3182 - accuracy: 0.8571 - val_loss: 0.9028 - val_accuracy: 0.6484
#
# Epoch 00194: val_loss did not improve from 0.57795
# Epoch 195/1000
#  - 47s - loss: 0.3171 - accuracy: 0.8574 - val_loss: 1.2377 - val_accuracy: 0.6479
#
# Epoch 00195: val_loss did not improve from 0.57795
# Epoch 196/1000
#  - 47s - loss: 0.3149 - accuracy: 0.8574 - val_loss: 1.1756 - val_accuracy: 0.6501
#
# Epoch 00196: val_loss did not improve from 0.57795
# Epoch 197/1000
#  - 47s - loss: 0.3141 - accuracy: 0.8582 - val_loss: 1.1791 - val_accuracy: 0.6498
#
# Epoch 00197: val_loss did not improve from 0.57795
# Epoch 198/1000
#  - 47s - loss: 0.3137 - accuracy: 0.8594 - val_loss: 0.9966 - val_accuracy: 0.6496
#
# Epoch 00198: val_loss did not improve from 0.57795
# Epoch 199/1000
#  - 48s - loss: 0.3135 - accuracy: 0.8597 - val_loss: 1.0993 - val_accuracy: 0.6507
#
# Epoch 00199: val_loss did not improve from 0.57795
# Epoch 200/1000
#  - 47s - loss: 0.3111 - accuracy: 0.8609 - val_loss: 1.0100 - val_accuracy: 0.6493
#
# Epoch 00200: val_loss did not improve from 0.57795
# Epoch 201/1000
#  - 47s - loss: 0.3128 - accuracy: 0.8589 - val_loss: 1.1493 - val_accuracy: 0.6513
#
# Epoch 00201: val_loss did not improve from 0.57795
# Epoch 202/1000
#  - 48s - loss: 0.3098 - accuracy: 0.8622 - val_loss: 1.2335 - val_accuracy: 0.6521
#
# Epoch 00202: val_loss did not improve from 0.57795
# Epoch 203/1000
#  - 49s - loss: 0.3100 - accuracy: 0.8611 - val_loss: 1.0971 - val_accuracy: 0.6495
#
# Epoch 00203: val_loss did not improve from 0.57795
# Epoch 204/1000
#  - 48s - loss: 0.3082 - accuracy: 0.8630 - val_loss: 1.0217 - val_accuracy: 0.6503
#
# Epoch 00204: val_loss did not improve from 0.57795
# Epoch 205/1000
#  - 48s - loss: 0.3086 - accuracy: 0.8621 - val_loss: 0.9283 - val_accuracy: 0.6489
#
# Epoch 00205: val_loss did not improve from 0.57795
# Epoch 206/1000
#  - 49s - loss: 0.3054 - accuracy: 0.8639 - val_loss: 1.1816 - val_accuracy: 0.6518
#
# Epoch 00206: val_loss did not improve from 0.57795
# Epoch 207/1000
#  - 49s - loss: 0.3059 - accuracy: 0.8630 - val_loss: 0.9589 - val_accuracy: 0.6520
#
# Epoch 00207: val_loss did not improve from 0.57795
# Epoch 208/1000
#  - 49s - loss: 0.3066 - accuracy: 0.8635 - val_loss: 1.1028 - val_accuracy: 0.6483
#
# Epoch 00208: val_loss did not improve from 0.57795
# Epoch 209/1000
#  - 48s - loss: 0.3065 - accuracy: 0.8637 - val_loss: 1.1490 - val_accuracy: 0.6499
#
# Epoch 00209: val_loss did not improve from 0.57795
# Epoch 210/1000
#  - 49s - loss: 0.3042 - accuracy: 0.8639 - val_loss: 0.8351 - val_accuracy: 0.6471
#
# Epoch 00210: val_loss did not improve from 0.57795
# Epoch 211/1000
#  - 48s - loss: 0.3052 - accuracy: 0.8634 - val_loss: 0.8620 - val_accuracy: 0.6507
#
# Epoch 00211: val_loss did not improve from 0.57795
# Epoch 212/1000
#  - 49s - loss: 0.3039 - accuracy: 0.8646 - val_loss: 1.1100 - val_accuracy: 0.6454
#
# Epoch 00212: val_loss did not improve from 0.57795
# Epoch 213/1000
#  - 49s - loss: 0.3032 - accuracy: 0.8652 - val_loss: 0.8981 - val_accuracy: 0.6502
#
# Epoch 00213: val_loss did not improve from 0.57795
# Epoch 214/1000
#  - 48s - loss: 0.3011 - accuracy: 0.8664 - val_loss: 0.7518 - val_accuracy: 0.6511
#
# Epoch 00214: val_loss did not improve from 0.57795
# Epoch 215/1000
#  - 49s - loss: 0.3020 - accuracy: 0.8652 - val_loss: 1.6850 - val_accuracy: 0.6488
#
# Epoch 00215: val_loss did not improve from 0.57795
# Epoch 216/1000
#  - 49s - loss: 0.2993 - accuracy: 0.8666 - val_loss: 1.1812 - val_accuracy: 0.6509
#
# Epoch 00216: val_loss did not improve from 0.57795
# Epoch 217/1000
#  - 48s - loss: 0.3009 - accuracy: 0.8658 - val_loss: 0.9332 - val_accuracy: 0.6498
#
# Epoch 00217: val_loss did not improve from 0.57795
# Epoch 218/1000
#  - 49s - loss: 0.2972 - accuracy: 0.8679 - val_loss: 1.0141 - val_accuracy: 0.6498
#
# Epoch 00218: val_loss did not improve from 0.57795
# Epoch 219/1000
#  - 49s - loss: 0.2970 - accuracy: 0.8689 - val_loss: 0.9862 - val_accuracy: 0.6490
#
# Epoch 00219: val_loss did not improve from 0.57795
# Epoch 220/1000
#  - 49s - loss: 0.2967 - accuracy: 0.8676 - val_loss: 1.1034 - val_accuracy: 0.6486
#
# Epoch 00220: val_loss did not improve from 0.57795
# Epoch 221/1000
#  - 49s - loss: 0.2958 - accuracy: 0.8686 - val_loss: 1.2121 - val_accuracy: 0.6469
#
# Epoch 00221: val_loss did not improve from 0.57795
# Epoch 222/1000
#  - 48s - loss: 0.2929 - accuracy: 0.8708 - val_loss: 1.0695 - val_accuracy: 0.6496
#
# Epoch 00222: val_loss did not improve from 0.57795
# Epoch 223/1000
#  - 47s - loss: 0.2923 - accuracy: 0.8705 - val_loss: 1.2034 - val_accuracy: 0.6488
#
# Epoch 00223: val_loss did not improve from 0.57795
# Epoch 224/1000
#  - 47s - loss: 0.2937 - accuracy: 0.8709 - val_loss: 0.9764 - val_accuracy: 0.6486
#
# Epoch 00224: val_loss did not improve from 0.57795
# Epoch 225/1000
#  - 48s - loss: 0.2938 - accuracy: 0.8696 - val_loss: 1.4132 - val_accuracy: 0.6477
#
# Epoch 00225: val_loss did not improve from 0.57795
# Epoch 226/1000
#  - 48s - loss: 0.2891 - accuracy: 0.8728 - val_loss: 1.0820 - val_accuracy: 0.6475
#
# Epoch 00226: val_loss did not improve from 0.57795
# Epoch 227/1000
#  - 48s - loss: 0.2905 - accuracy: 0.8722 - val_loss: 1.0174 - val_accuracy: 0.6493
#
# Epoch 00227: val_loss did not improve from 0.57795
# Epoch 228/1000
#  - 48s - loss: 0.2898 - accuracy: 0.8710 - val_loss: 1.3933 - val_accuracy: 0.6468
#
# Epoch 00228: val_loss did not improve from 0.57795
# Epoch 229/1000
#  - 48s - loss: 0.2904 - accuracy: 0.8721 - val_loss: 1.3178 - val_accuracy: 0.6481
#
# Epoch 00229: val_loss did not improve from 0.57795
# Epoch 230/1000
#  - 47s - loss: 0.2867 - accuracy: 0.8737 - val_loss: 1.3800 - val_accuracy: 0.6486
#
# Epoch 00230: val_loss did not improve from 0.57795
# Epoch 231/1000
#  - 47s - loss: 0.2877 - accuracy: 0.8719 - val_loss: 1.2227 - val_accuracy: 0.6490
#
# Epoch 00231: val_loss did not improve from 0.57795
# Epoch 232/1000
#  - 47s - loss: 0.2881 - accuracy: 0.8733 - val_loss: 0.8541 - val_accuracy: 0.6479
#
# Epoch 00232: val_loss did not improve from 0.57795
# Epoch 233/1000
#  - 46s - loss: 0.2856 - accuracy: 0.8747 - val_loss: 1.0349 - val_accuracy: 0.6461
#
# Epoch 00233: val_loss did not improve from 0.57795
# Epoch 234/1000
#  - 47s - loss: 0.2865 - accuracy: 0.8734 - val_loss: 1.4339 - val_accuracy: 0.6487
#
# Epoch 00234: val_loss did not improve from 0.57795
# Epoch 235/1000
#  - 47s - loss: 0.2857 - accuracy: 0.8740 - val_loss: 1.1601 - val_accuracy: 0.6465
#
# Epoch 00235: val_loss did not improve from 0.57795
# Epoch 236/1000
#  - 47s - loss: 0.2838 - accuracy: 0.8757 - val_loss: 1.1883 - val_accuracy: 0.6486
#
# Epoch 00236: val_loss did not improve from 0.57795
# Epoch 237/1000
#  - 47s - loss: 0.2840 - accuracy: 0.8759 - val_loss: 1.4359 - val_accuracy: 0.6477
#
# Epoch 00237: val_loss did not improve from 0.57795
# Epoch 238/1000
#  - 47s - loss: 0.2829 - accuracy: 0.8745 - val_loss: 1.2852 - val_accuracy: 0.6486
#
# Epoch 00238: val_loss did not improve from 0.57795
# Epoch 239/1000
#  - 46s - loss: 0.2816 - accuracy: 0.8764 - val_loss: 1.1540 - val_accuracy: 0.6488
#
# Epoch 00239: val_loss did not improve from 0.57795
# Epoch 240/1000
#  - 47s - loss: 0.2819 - accuracy: 0.8756 - val_loss: 1.1547 - val_accuracy: 0.6479
#
# Epoch 00240: val_loss did not improve from 0.57795
# Epoch 241/1000
#  - 47s - loss: 0.2795 - accuracy: 0.8775 - val_loss: 0.9237 - val_accuracy: 0.6501
#
# Epoch 00241: val_loss did not improve from 0.57795
# Epoch 242/1000
#  - 47s - loss: 0.2800 - accuracy: 0.8770 - val_loss: 1.1119 - val_accuracy: 0.6482
#
# Epoch 00242: val_loss did not improve from 0.57795
# Epoch 243/1000
#  - 47s - loss: 0.2767 - accuracy: 0.8779 - val_loss: 1.4575 - val_accuracy: 0.6506
#
# Epoch 00243: val_loss did not improve from 0.57795
# Epoch 244/1000
#  - 47s - loss: 0.2793 - accuracy: 0.8774 - val_loss: 1.1652 - val_accuracy: 0.6485
#
# Epoch 00244: val_loss did not improve from 0.57795
# Epoch 245/1000
#  - 46s - loss: 0.2765 - accuracy: 0.8785 - val_loss: 0.9587 - val_accuracy: 0.6478
#
# Epoch 00245: val_loss did not improve from 0.57795
# Epoch 246/1000
#  - 47s - loss: 0.2783 - accuracy: 0.8783 - val_loss: 1.3435 - val_accuracy: 0.6483
#
# Epoch 00246: val_loss did not improve from 0.57795
# Epoch 247/1000
#  - 48s - loss: 0.2793 - accuracy: 0.8775 - val_loss: 1.2927 - val_accuracy: 0.6494
#
# Epoch 00247: val_loss did not improve from 0.57795
# Epoch 248/1000
#  - 48s - loss: 0.2757 - accuracy: 0.8786 - val_loss: 1.5867 - val_accuracy: 0.6487
#
# Epoch 00248: val_loss did not improve from 0.57795
# Epoch 249/1000
#  - 47s - loss: 0.2739 - accuracy: 0.8781 - val_loss: 1.4788 - val_accuracy: 0.6483
#
# Epoch 00249: val_loss did not improve from 0.57795
# Epoch 250/1000
#  - 47s - loss: 0.2755 - accuracy: 0.8796 - val_loss: 1.3058 - val_accuracy: 0.6490
#
# Epoch 00250: val_loss did not improve from 0.57795
# Epoch 251/1000
#  - 48s - loss: 0.2737 - accuracy: 0.8805 - val_loss: 0.9332 - val_accuracy: 0.6500
#
# Epoch 00251: val_loss did not improve from 0.57795
# Epoch 252/1000
#  - 47s - loss: 0.2713 - accuracy: 0.8819 - val_loss: 1.3707 - val_accuracy: 0.6486
#
# Epoch 00252: val_loss did not improve from 0.57795
# Epoch 253/1000
#  - 47s - loss: 0.2726 - accuracy: 0.8804 - val_loss: 1.1488 - val_accuracy: 0.6489
#
# Epoch 00253: val_loss did not improve from 0.57795
# Epoch 254/1000
#  - 47s - loss: 0.2726 - accuracy: 0.8805 - val_loss: 1.1823 - val_accuracy: 0.6503
#
# Epoch 00254: val_loss did not improve from 0.57795
# Epoch 255/1000
#  - 47s - loss: 0.2697 - accuracy: 0.8833 - val_loss: 1.4262 - val_accuracy: 0.6510
#
# Epoch 00255: val_loss did not improve from 0.57795
# Epoch 256/1000
#  - 47s - loss: 0.2706 - accuracy: 0.8812 - val_loss: 1.1860 - val_accuracy: 0.6495
#
# Epoch 00256: val_loss did not improve from 0.57795
# Epoch 257/1000
#  - 47s - loss: 0.2681 - accuracy: 0.8836 - val_loss: 1.1004 - val_accuracy: 0.6501
#
# Epoch 00257: val_loss did not improve from 0.57795
# Epoch 258/1000
#  - 47s - loss: 0.2665 - accuracy: 0.8845 - val_loss: 1.6228 - val_accuracy: 0.6492
#
# Epoch 00258: val_loss did not improve from 0.57795
# Epoch 259/1000
#  - 47s - loss: 0.2675 - accuracy: 0.8836 - val_loss: 1.3095 - val_accuracy: 0.6477
#
# Epoch 00259: val_loss did not improve from 0.57795
# Epoch 260/1000
#  - 47s - loss: 0.2668 - accuracy: 0.8846 - val_loss: 1.6393 - val_accuracy: 0.6497
#
# Epoch 00260: val_loss did not improve from 0.57795
# Epoch 261/1000
#  - 47s - loss: 0.2638 - accuracy: 0.8859 - val_loss: 1.2979 - val_accuracy: 0.6485
#
# Epoch 00261: val_loss did not improve from 0.57795
# Epoch 262/1000
#  - 47s - loss: 0.2665 - accuracy: 0.8844 - val_loss: 1.0758 - val_accuracy: 0.6480
#
# Epoch 00262: val_loss did not improve from 0.57795
# Epoch 263/1000
#  - 46s - loss: 0.2646 - accuracy: 0.8856 - val_loss: 1.3522 - val_accuracy: 0.6473
#
# Epoch 00263: val_loss did not improve from 0.57795
# Epoch 264/1000
#  - 46s - loss: 0.2661 - accuracy: 0.8847 - val_loss: 0.9123 - val_accuracy: 0.6468
#
# Epoch 00264: val_loss did not improve from 0.57795
# Epoch 265/1000
#  - 46s - loss: 0.2650 - accuracy: 0.8855 - val_loss: 1.2247 - val_accuracy: 0.6497
#
# Epoch 00265: val_loss did not improve from 0.57795
# Epoch 266/1000
#  - 46s - loss: 0.2653 - accuracy: 0.8844 - val_loss: 1.5124 - val_accuracy: 0.6493
#
# Epoch 00266: val_loss did not improve from 0.57795
# Epoch 267/1000
#  - 46s - loss: 0.2628 - accuracy: 0.8866 - val_loss: 1.3859 - val_accuracy: 0.6481
#
# Epoch 00267: val_loss did not improve from 0.57795
# Epoch 268/1000
#  - 46s - loss: 0.2616 - accuracy: 0.8878 - val_loss: 1.0739 - val_accuracy: 0.6482
#
# Epoch 00268: val_loss did not improve from 0.57795
# Epoch 269/1000
#  - 46s - loss: 0.2602 - accuracy: 0.8875 - val_loss: 1.5567 - val_accuracy: 0.6489
#
# Epoch 00269: val_loss did not improve from 0.57795
# Epoch 270/1000
#  - 46s - loss: 0.2584 - accuracy: 0.8889 - val_loss: 1.1975 - val_accuracy: 0.6507
#
# Epoch 00270: val_loss did not improve from 0.57795
# Epoch 271/1000
#  - 47s - loss: 0.2599 - accuracy: 0.8873 - val_loss: 1.2410 - val_accuracy: 0.6488
#
# Epoch 00271: val_loss did not improve from 0.57795
# Epoch 272/1000
#  - 46s - loss: 0.2595 - accuracy: 0.8887 - val_loss: 1.2229 - val_accuracy: 0.6501
#
# Epoch 00272: val_loss did not improve from 0.57795
# Epoch 273/1000
#  - 46s - loss: 0.2584 - accuracy: 0.8881 - val_loss: 1.2476 - val_accuracy: 0.6497
#
# Epoch 00273: val_loss did not improve from 0.57795
# Epoch 274/1000
#  - 46s - loss: 0.2562 - accuracy: 0.8902 - val_loss: 1.3845 - val_accuracy: 0.6504
#
# Epoch 00274: val_loss did not improve from 0.57795
# Epoch 275/1000
#  - 46s - loss: 0.2573 - accuracy: 0.8885 - val_loss: 1.1504 - val_accuracy: 0.6495
#
# Epoch 00275: val_loss did not improve from 0.57795
# Epoch 276/1000
#  - 47s - loss: 0.2572 - accuracy: 0.8886 - val_loss: 1.2563 - val_accuracy: 0.6455
#
# Epoch 00276: val_loss did not improve from 0.57795
# Epoch 277/1000
#  - 47s - loss: 0.2554 - accuracy: 0.8902 - val_loss: 1.3609 - val_accuracy: 0.6506
#
# Epoch 00277: val_loss did not improve from 0.57795
# Epoch 278/1000
#  - 47s - loss: 0.2541 - accuracy: 0.8906 - val_loss: 1.6622 - val_accuracy: 0.6468
#
# Epoch 00278: val_loss did not improve from 0.57795
# Epoch 279/1000
#  - 47s - loss: 0.2560 - accuracy: 0.8902 - val_loss: 1.3842 - val_accuracy: 0.6499
#
# Epoch 00279: val_loss did not improve from 0.57795
# Epoch 280/1000
#  - 47s - loss: 0.2533 - accuracy: 0.8908 - val_loss: 1.5206 - val_accuracy: 0.6485
#
# Epoch 00280: val_loss did not improve from 0.57795
# Epoch 281/1000
#  - 46s - loss: 0.2527 - accuracy: 0.8915 - val_loss: 1.6693 - val_accuracy: 0.6469
#
# Epoch 00281: val_loss did not improve from 0.57795
# Epoch 282/1000
#  - 47s - loss: 0.2520 - accuracy: 0.8916 - val_loss: 1.2788 - val_accuracy: 0.6474
#
# Epoch 00282: val_loss did not improve from 0.57795
# Epoch 283/1000
#  - 46s - loss: 0.2524 - accuracy: 0.8920 - val_loss: 1.3629 - val_accuracy: 0.6479
#
# Epoch 00283: val_loss did not improve from 0.57795
# Epoch 284/1000
#  - 46s - loss: 0.2500 - accuracy: 0.8920 - val_loss: 1.5002 - val_accuracy: 0.6481
#
# Epoch 00284: val_loss did not improve from 0.57795
# Epoch 285/1000
#  - 46s - loss: 0.2514 - accuracy: 0.8920 - val_loss: 1.2290 - val_accuracy: 0.6489
#
# Epoch 00285: val_loss did not improve from 0.57795
# Epoch 286/1000
#  - 46s - loss: 0.2515 - accuracy: 0.8918 - val_loss: 1.4116 - val_accuracy: 0.6478
#
# Epoch 00286: val_loss did not improve from 0.57795
# Epoch 287/1000
#  - 46s - loss: 0.2500 - accuracy: 0.8931 - val_loss: 1.3815 - val_accuracy: 0.6506
#
# Epoch 00287: val_loss did not improve from 0.57795
# Epoch 288/1000
#  - 46s - loss: 0.2473 - accuracy: 0.8944 - val_loss: 1.5852 - val_accuracy: 0.6499
#
# Epoch 00288: val_loss did not improve from 0.57795
# Epoch 289/1000
#  - 46s - loss: 0.2487 - accuracy: 0.8938 - val_loss: 1.2835 - val_accuracy: 0.6485
#
# Epoch 00289: val_loss did not improve from 0.57795
# Epoch 290/1000
#  - 46s - loss: 0.2483 - accuracy: 0.8938 - val_loss: 1.5273 - val_accuracy: 0.6469
#
# Epoch 00290: val_loss did not improve from 0.57795
# Epoch 291/1000
#  - 46s - loss: 0.2470 - accuracy: 0.8939 - val_loss: 1.2031 - val_accuracy: 0.6484
#
# Epoch 00291: val_loss did not improve from 0.57795
# Epoch 292/1000
#  - 46s - loss: 0.2452 - accuracy: 0.8951 - val_loss: 1.2361 - val_accuracy: 0.6498
#
# Epoch 00292: val_loss did not improve from 0.57795
# Epoch 293/1000
#  - 46s - loss: 0.2440 - accuracy: 0.8966 - val_loss: 1.3154 - val_accuracy: 0.6508
#
# Epoch 00293: val_loss did not improve from 0.57795
# Epoch 294/1000
#  - 46s - loss: 0.2440 - accuracy: 0.8955 - val_loss: 1.5349 - val_accuracy: 0.6492
#
# Epoch 00294: val_loss did not improve from 0.57795
# Epoch 295/1000
#  - 46s - loss: 0.2432 - accuracy: 0.8971 - val_loss: 1.5244 - val_accuracy: 0.6484
#
# Epoch 00295: val_loss did not improve from 0.57795
# Epoch 296/1000
#  - 46s - loss: 0.2428 - accuracy: 0.8963 - val_loss: 1.0905 - val_accuracy: 0.6501
#
# Epoch 00296: val_loss did not improve from 0.57795
# Epoch 297/1000
#  - 46s - loss: 0.2424 - accuracy: 0.8959 - val_loss: 1.2628 - val_accuracy: 0.6511
#
# Epoch 00297: val_loss did not improve from 0.57795
# Epoch 298/1000
#  - 46s - loss: 0.2436 - accuracy: 0.8961 - val_loss: 1.3705 - val_accuracy: 0.6515
#
# Epoch 00298: val_loss did not improve from 0.57795
# Epoch 299/1000
#  - 46s - loss: 0.2442 - accuracy: 0.8944 - val_loss: 1.3218 - val_accuracy: 0.6497
#
# Epoch 00299: val_loss did not improve from 0.57795
# Epoch 300/1000
#  - 46s - loss: 0.2410 - accuracy: 0.8971 - val_loss: 1.1289 - val_accuracy: 0.6493
#
# Epoch 00300: val_loss did not improve from 0.57795
# Epoch 301/1000
#  - 46s - loss: 0.2407 - accuracy: 0.8970 - val_loss: 1.1799 - val_accuracy: 0.6479
#
# Epoch 00301: val_loss did not improve from 0.57795
# Epoch 302/1000
#  - 46s - loss: 0.2402 - accuracy: 0.8985 - val_loss: 1.5076 - val_accuracy: 0.6516
#
# Epoch 00302: val_loss did not improve from 0.57795
# Epoch 303/1000
#  - 46s - loss: 0.2398 - accuracy: 0.8978 - val_loss: 1.1878 - val_accuracy: 0.6488
#
# Epoch 00303: val_loss did not improve from 0.57795
# Epoch 304/1000
#  - 46s - loss: 0.2402 - accuracy: 0.8972 - val_loss: 1.1053 - val_accuracy: 0.6478
#
# Epoch 00304: val_loss did not improve from 0.57795
# Epoch 305/1000
#  - 46s - loss: 0.2364 - accuracy: 0.8998 - val_loss: 1.2756 - val_accuracy: 0.6485
#
# Epoch 00305: val_loss did not improve from 0.57795
# Epoch 306/1000
#  - 46s - loss: 0.2366 - accuracy: 0.8998 - val_loss: 1.1554 - val_accuracy: 0.6502
#
# Epoch 00306: val_loss did not improve from 0.57795
# Epoch 307/1000
#  - 46s - loss: 0.2369 - accuracy: 0.8984 - val_loss: 1.0937 - val_accuracy: 0.6496
#
# Epoch 00307: val_loss did not improve from 0.57795
# Epoch 308/1000
#  - 46s - loss: 0.2374 - accuracy: 0.8992 - val_loss: 1.1155 - val_accuracy: 0.6484
#
# Epoch 00308: val_loss did not improve from 0.57795
# Epoch 309/1000
#  - 46s - loss: 0.2361 - accuracy: 0.8999 - val_loss: 1.5130 - val_accuracy: 0.6497
#
# Epoch 00309: val_loss did not improve from 0.57795
# Epoch 310/1000
#  - 46s - loss: 0.2371 - accuracy: 0.9002 - val_loss: 1.1597 - val_accuracy: 0.6503
#
# Epoch 00310: val_loss did not improve from 0.57795
# Epoch 311/1000
#  - 46s - loss: 0.2340 - accuracy: 0.9008 - val_loss: 0.9780 - val_accuracy: 0.6500
#
# Epoch 00311: val_loss did not improve from 0.57795
# Epoch 312/1000
#  - 46s - loss: 0.2345 - accuracy: 0.9010 - val_loss: 1.6339 - val_accuracy: 0.6488
#
# Epoch 00312: val_loss did not improve from 0.57795
# Epoch 313/1000
#  - 46s - loss: 0.2339 - accuracy: 0.9005 - val_loss: 1.1957 - val_accuracy: 0.6494
#
# Epoch 00313: val_loss did not improve from 0.57795
# Epoch 314/1000
#  - 46s - loss: 0.2328 - accuracy: 0.9009 - val_loss: 1.3496 - val_accuracy: 0.6500
#
# Epoch 00314: val_loss did not improve from 0.57795
# Epoch 315/1000
#  - 47s - loss: 0.2333 - accuracy: 0.9012 - val_loss: 1.5017 - val_accuracy: 0.6495
#
# Epoch 00315: val_loss did not improve from 0.57795
# Epoch 316/1000
#  - 46s - loss: 0.2304 - accuracy: 0.9027 - val_loss: 1.5900 - val_accuracy: 0.6504
#
# Epoch 00316: val_loss did not improve from 0.57795
# Epoch 317/1000
#  - 46s - loss: 0.2335 - accuracy: 0.9003 - val_loss: 1.6266 - val_accuracy: 0.6489
#
# Epoch 00317: val_loss did not improve from 0.57795
# Epoch 318/1000
#  - 47s - loss: 0.2315 - accuracy: 0.9017 - val_loss: 1.4383 - val_accuracy: 0.6491
#
# Epoch 00318: val_loss did not improve from 0.57795
# Epoch 319/1000
#  - 46s - loss: 0.2303 - accuracy: 0.9038 - val_loss: 1.5561 - val_accuracy: 0.6509
#
# Epoch 00319: val_loss did not improve from 0.57795
# Epoch 320/1000
#  - 46s - loss: 0.2289 - accuracy: 0.9039 - val_loss: 1.2271 - val_accuracy: 0.6491
#
# Epoch 00320: val_loss did not improve from 0.57795
# Epoch 321/1000
#  - 47s - loss: 0.2291 - accuracy: 0.9040 - val_loss: 1.3911 - val_accuracy: 0.6508
#
# Epoch 00321: val_loss did not improve from 0.57795
# Epoch 322/1000
#  - 46s - loss: 0.2273 - accuracy: 0.9046 - val_loss: 1.1867 - val_accuracy: 0.6522
#
# Epoch 00322: val_loss did not improve from 0.57795
# Epoch 323/1000
#  - 47s - loss: 0.2305 - accuracy: 0.9037 - val_loss: 1.2505 - val_accuracy: 0.6492
#
# Epoch 00323: val_loss did not improve from 0.57795
# Epoch 324/1000
#  - 46s - loss: 0.2287 - accuracy: 0.9027 - val_loss: 1.4415 - val_accuracy: 0.6479
#
# Epoch 00324: val_loss did not improve from 0.57795
# Epoch 325/1000
#  - 46s - loss: 0.2276 - accuracy: 0.9034 - val_loss: 1.0625 - val_accuracy: 0.6499
#
# Epoch 00325: val_loss did not improve from 0.57795
# Epoch 326/1000
#  - 46s - loss: 0.2267 - accuracy: 0.9048 - val_loss: 1.2962 - val_accuracy: 0.6489
#
# Epoch 00326: val_loss did not improve from 0.57795
# Epoch 327/1000
#  - 46s - loss: 0.2273 - accuracy: 0.9049 - val_loss: 1.5777 - val_accuracy: 0.6492
#
# Epoch 00327: val_loss did not improve from 0.57795
# Epoch 328/1000
#  - 47s - loss: 0.2251 - accuracy: 0.9060 - val_loss: 1.4507 - val_accuracy: 0.6489
#
# Epoch 00328: val_loss did not improve from 0.57795
# Epoch 329/1000
#  - 46s - loss: 0.2234 - accuracy: 0.9067 - val_loss: 1.4190 - val_accuracy: 0.6501
#
# Epoch 00329: val_loss did not improve from 0.57795
# Epoch 330/1000
#  - 46s - loss: 0.2262 - accuracy: 0.9048 - val_loss: 1.2175 - val_accuracy: 0.6508
#
# Epoch 00330: val_loss did not improve from 0.57795
# Epoch 331/1000
#  - 47s - loss: 0.2220 - accuracy: 0.9066 - val_loss: 1.7560 - val_accuracy: 0.6490
#
# Epoch 00331: val_loss did not improve from 0.57795
# Epoch 332/1000
#  - 47s - loss: 0.2243 - accuracy: 0.9054 - val_loss: 1.5698 - val_accuracy: 0.6490
#
# Epoch 00332: val_loss did not improve from 0.57795
# Epoch 333/1000
#  - 49s - loss: 0.2217 - accuracy: 0.9076 - val_loss: 1.2288 - val_accuracy: 0.6492
#
# Epoch 00333: val_loss did not improve from 0.57795
# Epoch 334/1000
#  - 48s - loss: 0.2240 - accuracy: 0.9055 - val_loss: 1.2268 - val_accuracy: 0.6486
#
# Epoch 00334: val_loss did not improve from 0.57795
# Epoch 335/1000
#  - 47s - loss: 0.2200 - accuracy: 0.9085 - val_loss: 1.2409 - val_accuracy: 0.6500
#
# Epoch 00335: val_loss did not improve from 0.57795
# Epoch 336/1000
#  - 47s - loss: 0.2213 - accuracy: 0.9068 - val_loss: 1.4205 - val_accuracy: 0.6498
#
# Epoch 00336: val_loss did not improve from 0.57795
# Epoch 337/1000
#  - 48s - loss: 0.2191 - accuracy: 0.9091 - val_loss: 1.2112 - val_accuracy: 0.6498
#
# Epoch 00337: val_loss did not improve from 0.57795
# Epoch 338/1000
#  - 47s - loss: 0.2208 - accuracy: 0.9081 - val_loss: 1.0166 - val_accuracy: 0.6494
#
# Epoch 00338: val_loss did not improve from 0.57795
# Epoch 339/1000
#  - 47s - loss: 0.2218 - accuracy: 0.9064 - val_loss: 1.4615 - val_accuracy: 0.6497
#
# Epoch 00339: val_loss did not improve from 0.57795
# Epoch 340/1000
#  - 47s - loss: 0.2197 - accuracy: 0.9084 - val_loss: 1.7330 - val_accuracy: 0.6504
#
# Epoch 00340: val_loss did not improve from 0.57795
# Epoch 341/1000
#  - 47s - loss: 0.2178 - accuracy: 0.9087 - val_loss: 1.3447 - val_accuracy: 0.6503
#
# Epoch 00341: val_loss did not improve from 0.57795
# Epoch 342/1000
#  - 46s - loss: 0.2174 - accuracy: 0.9092 - val_loss: 1.3278 - val_accuracy: 0.6494
#
# Epoch 00342: val_loss did not improve from 0.57795
# Epoch 343/1000
#  - 47s - loss: 0.2190 - accuracy: 0.9084 - val_loss: 1.7383 - val_accuracy: 0.6502
#
# Epoch 00343: val_loss did not improve from 0.57795
# Epoch 344/1000
#  - 46s - loss: 0.2192 - accuracy: 0.9089 - val_loss: 1.5552 - val_accuracy: 0.6508
#
# Epoch 00344: val_loss did not improve from 0.57795
# Epoch 345/1000
#  - 46s - loss: 0.2190 - accuracy: 0.9083 - val_loss: 1.4086 - val_accuracy: 0.6501
#
# Epoch 00345: val_loss did not improve from 0.57795
# Epoch 346/1000
#  - 46s - loss: 0.2169 - accuracy: 0.9099 - val_loss: 1.6479 - val_accuracy: 0.6511
#
# Epoch 00346: val_loss did not improve from 0.57795
# Epoch 347/1000
#  - 48s - loss: 0.2176 - accuracy: 0.9092 - val_loss: 1.4537 - val_accuracy: 0.6486
#
# Epoch 00347: val_loss did not improve from 0.57795
# Epoch 348/1000
#  - 46s - loss: 0.2155 - accuracy: 0.9099 - val_loss: 1.2544 - val_accuracy: 0.6492
#
# Epoch 00348: val_loss did not improve from 0.57795
# Epoch 349/1000
#  - 46s - loss: 0.2144 - accuracy: 0.9108 - val_loss: 1.4496 - val_accuracy: 0.6474
#
# Epoch 00349: val_loss did not improve from 0.57795
# Epoch 350/1000
#  - 46s - loss: 0.2147 - accuracy: 0.9105 - val_loss: 1.3686 - val_accuracy: 0.6489
#
# Epoch 00350: val_loss did not improve from 0.57795
# Epoch 351/1000
#  - 46s - loss: 0.2134 - accuracy: 0.9115 - val_loss: 1.1819 - val_accuracy: 0.6490
#
# Epoch 00351: val_loss did not improve from 0.57795
# Epoch 352/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-bfdbd8b0a055> in <module>()
#      37                     validation_data=val_flow,
#      38                     validation_steps=len(x_val) / batch_size,
# ---> 39                     shuffle=False)
#
# /tensorflow-1.15.2/python3.7/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /tensorflow-1.15.2/python3.7/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /tensorflow-1.15.2/python3.7/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# /tensorflow-1.15.2/python3.7/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# model_name = "classifier_45_min_pr_re2.h5"  # <-- specifying model name
# model_name = 'classifier_%s_ma7_pr2.h5' % period

model = keras.models.load_model(ckpt_path + model_name)

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)

# thresh = 0.19
# threshold = [thresh]
print('threshold :', threshold)
break

acc_pr_bythr = []
for thresh in threshold:

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  print('precision :', precision_score(y_test, y_pred))
  print('recall :', recall_score(y_test, y_pred))
  print()

  print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # plt.show()  
  print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
    print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
    print('thresh :', thresh)
    
  # if len(threshold) == 1:
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(test_pr_list))
    plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
  # plt.show()

    plt.subplot(122)
    plt.plot(np.cumprod(pred_pr_list))
    plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])

print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(threshold, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
