# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %tensorflow_version 1.x
# %matplotlib inline

input_data_length = 15
model_num = 125
num_classes = 3

gdrive_path = '/content/gdrive/My Drive/Colab Notebooks/'

Made_X = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)


#       dataset 분리      #
# dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
# dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
Made_X = Made_X[:, :, :4]
print(Made_X.shape)
print(Made_Y.shape)

row = Made_X.shape[1]
col = Made_X.shape[2]

from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                   shuffle=False)

X_train = X_train.astype('float32').reshape(-1, input_data_length, col, 1)
X_val = X_val.astype('float32').reshape(-1, input_data_length, col, 1)
print(X_train.shape)
print(X_val.shape)

from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 

# Data Class Weight
from sklearn.utils import class_weight

print(Y_train[:, 0])
class_weights = class_weight.compute_class_weight('balanced', 
                                                  np.unique(Y_train[:, 0]),
                                                  Y_train[:, 0])
class_weights = dict(enumerate(class_weights))
print(class_weights)
# quit()

Y_train = Y_train.astype('float32')
Y_val = Y_val.astype('float32')
Y_train = np_utils.to_categorical(Y_train, num_classes)
Y_val = np_utils.to_categorical(Y_val, num_classes)
print(Y_train.shape)
print(Y_val.shape)

datagen = ImageDataGenerator( 
#     rotation_range = 60,
#     zoom_range = 0.6,
#     shear_range = 0.6,
#     horizontal_flip = True,
#     width_shift_range=0.6,
#     height_shift_range=0.6,
    fill_mode = 'nearest'
    )

testgen = ImageDataGenerator( 
    )
datagen.fit(X_train)
batch_size = 128

for X_batch, _ in datagen.flow(X_train, Y_train, batch_size=9):
    for i in range(0, 9): 
        pyplot.axis('off') 
        pyplot.subplot(330 + 1 + i) 
        pyplot.imshow(X_batch[i].reshape(input_data_length, col))
    pyplot.axis('off') 
    pyplot.show() 
    break
    
    
train_flow = datagen.flow(X_train, Y_train, batch_size=batch_size) 
val_flow = testgen.flow(X_val, Y_val, batch_size=batch_size) 


from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix

def FER_Model(input_shape=(row, col, 1)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(64, kernel_size=3, padding='same')(visible)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_1 = net

    net = layers.Conv2D(128, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
    
    return model

model = FER_Model()
# from keras.models import load_model
# model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_ohlc.hdf5' % (input_data_length, model_num))
opt = Adam(lr=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
  
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath = gdrive_path + "model/rapid_ascending %s_%s_ohlc.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=100)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 500
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(X_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(X_val) / batch_size,
                    shuffle=False)
# Out:
# (753035, 15, 4)
# (753035, 1)
# (527124, 15, 4, 1)
# (225911, 15, 4, 1)
# [0. 0. 0. ... 0. 0. 0.]
# {0: 0.35225719017012624, 1: 12.413140233133168, 2: 12.406128645061075}
# (527124, 3)
# (225911, 3)
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 15, 4, 1)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 4, 64)         640
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 15, 4, 64)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 2, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 2, 128)         73856
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 7, 2, 128)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 1, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 384)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                24640
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 99,331
# Trainable params: 99,331
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/500
#  - 31s - loss: 0.7186 - accuracy: 0.2792 - val_loss: 0.9643 - val_accuracy: 0.2987
#
# Epoch 00001: val_loss improved from inf to 0.96432, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 15_127_ohlc.hdf5
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/500
#  - 25s - loss: 0.6588 - accuracy: 0.3078 - val_loss: 0.7995 - val_accuracy: 0.3987
#
# Epoch 00002: val_loss improved from 0.96432 to 0.79946, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 15_127_ohlc.hdf5
# Epoch 3/500
#  - 24s - loss: 0.6447 - accuracy: 0.3338 - val_loss: 0.9282 - val_accuracy: 0.3596
#
# Epoch 00003: val_loss did not improve from 0.79946
# Epoch 4/500
#  - 24s - loss: 0.6375 - accuracy: 0.3463 - val_loss: 1.0042 - val_accuracy: 0.3213
#
# Epoch 00004: val_loss did not improve from 0.79946
# Epoch 5/500
#  - 24s - loss: 0.6338 - accuracy: 0.3504 - val_loss: 0.8830 - val_accuracy: 0.3740
#
# Epoch 00005: val_loss did not improve from 0.79946
# Epoch 6/500
#  - 24s - loss: 0.6304 - accuracy: 0.3550 - val_loss: 1.1808 - val_accuracy: 0.2659
#
# Epoch 00006: val_loss did not improve from 0.79946
# Epoch 7/500
#  - 24s - loss: 0.6275 - accuracy: 0.3583 - val_loss: 0.7794 - val_accuracy: 0.4667
#
# Epoch 00007: val_loss improved from 0.79946 to 0.77940, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 15_127_ohlc.hdf5
# Epoch 8/500
#  - 24s - loss: 0.6250 - accuracy: 0.3630 - val_loss: 0.9435 - val_accuracy: 0.4255
#
# Epoch 00008: val_loss did not improve from 0.77940
# Epoch 9/500
#  - 24s - loss: 0.6234 - accuracy: 0.3638 - val_loss: 1.0671 - val_accuracy: 0.3176
#
# Epoch 00009: val_loss did not improve from 0.77940
# Epoch 10/500
#  - 23s - loss: 0.6218 - accuracy: 0.3640 - val_loss: 1.0854 - val_accuracy: 0.2960
#
# Epoch 00010: val_loss did not improve from 0.77940
# Epoch 11/500
#  - 23s - loss: 0.6200 - accuracy: 0.3663 - val_loss: 1.0246 - val_accuracy: 0.3122
#
# Epoch 00011: val_loss did not improve from 0.77940
# Epoch 12/500
#  - 23s - loss: 0.6187 - accuracy: 0.3672 - val_loss: 1.0421 - val_accuracy: 0.3947
#
# Epoch 00012: val_loss did not improve from 0.77940
# Epoch 13/500
#  - 24s - loss: 0.6182 - accuracy: 0.3685 - val_loss: 0.9296 - val_accuracy: 0.3825
#
# Epoch 00013: val_loss did not improve from 0.77940
# Epoch 14/500
#  - 24s - loss: 0.6164 - accuracy: 0.3690 - val_loss: 0.9675 - val_accuracy: 0.3355
#
# Epoch 00014: val_loss did not improve from 0.77940
# Epoch 15/500
#  - 23s - loss: 0.6149 - accuracy: 0.3710 - val_loss: 0.9053 - val_accuracy: 0.4023
#
# Epoch 00015: val_loss did not improve from 0.77940
# Epoch 16/500
#  - 23s - loss: 0.6136 - accuracy: 0.3720 - val_loss: 0.9403 - val_accuracy: 0.3992
#
# Epoch 00016: val_loss did not improve from 0.77940
# Epoch 17/500
#  - 23s - loss: 0.6128 - accuracy: 0.3748 - val_loss: 1.0160 - val_accuracy: 0.3479
#
# Epoch 00017: val_loss did not improve from 0.77940
# Epoch 18/500
#  - 23s - loss: 0.6118 - accuracy: 0.3743 - val_loss: 0.9682 - val_accuracy: 0.4150
#
# Epoch 00018: val_loss did not improve from 0.77940
# Epoch 19/500
#  - 23s - loss: 0.6109 - accuracy: 0.3783 - val_loss: 1.0531 - val_accuracy: 0.3478
#
# Epoch 00019: val_loss did not improve from 0.77940
# Epoch 20/500
#  - 23s - loss: 0.6096 - accuracy: 0.3749 - val_loss: 0.9574 - val_accuracy: 0.3517
#
# Epoch 00020: val_loss did not improve from 0.77940
# Epoch 21/500
#  - 23s - loss: 0.6088 - accuracy: 0.3778 - val_loss: 0.9499 - val_accuracy: 0.4051
#
# Epoch 00021: val_loss did not improve from 0.77940
# Epoch 22/500
#  - 23s - loss: 0.6075 - accuracy: 0.3794 - val_loss: 0.9111 - val_accuracy: 0.4544
#
# Epoch 00022: val_loss did not improve from 0.77940
# Epoch 23/500
#  - 23s - loss: 0.6063 - accuracy: 0.3812 - val_loss: 0.9674 - val_accuracy: 0.3710
#
# Epoch 00023: val_loss did not improve from 0.77940
# Epoch 24/500
#  - 23s - loss: 0.6057 - accuracy: 0.3813 - val_loss: 1.0260 - val_accuracy: 0.3541
#
# Epoch 00024: val_loss did not improve from 0.77940
# Epoch 25/500
#  - 23s - loss: 0.6046 - accuracy: 0.3833 - val_loss: 0.8243 - val_accuracy: 0.4116
#
# Epoch 00025: val_loss did not improve from 0.77940
# Epoch 26/500
#  - 24s - loss: 0.6041 - accuracy: 0.3831 - val_loss: 0.9806 - val_accuracy: 0.3788
#
# Epoch 00026: val_loss did not improve from 0.77940
# Epoch 27/500
#  - 23s - loss: 0.6031 - accuracy: 0.3845 - val_loss: 0.9549 - val_accuracy: 0.3904
#
# Epoch 00027: val_loss did not improve from 0.77940
# Epoch 28/500
#  - 23s - loss: 0.6017 - accuracy: 0.3863 - val_loss: 1.0995 - val_accuracy: 0.3299
#
# Epoch 00028: val_loss did not improve from 0.77940
# Epoch 29/500
#  - 23s - loss: 0.6007 - accuracy: 0.3870 - val_loss: 1.0803 - val_accuracy: 0.3522
#
# Epoch 00029: val_loss did not improve from 0.77940
# Epoch 30/500
#  - 23s - loss: 0.5998 - accuracy: 0.3880 - val_loss: 0.8998 - val_accuracy: 0.4131
#
# Epoch 00030: val_loss did not improve from 0.77940
# Epoch 31/500
#  - 23s - loss: 0.5988 - accuracy: 0.3887 - val_loss: 1.0818 - val_accuracy: 0.3462
#
# Epoch 00031: val_loss did not improve from 0.77940
# Epoch 32/500
#  - 23s - loss: 0.5979 - accuracy: 0.3911 - val_loss: 1.0320 - val_accuracy: 0.3634
#
# Epoch 00032: val_loss did not improve from 0.77940
# Epoch 33/500
#  - 23s - loss: 0.5965 - accuracy: 0.3926 - val_loss: 0.8969 - val_accuracy: 0.4028
#
# Epoch 00033: val_loss did not improve from 0.77940
# Epoch 34/500
#  - 23s - loss: 0.5953 - accuracy: 0.3931 - val_loss: 0.9324 - val_accuracy: 0.4052
#
# Epoch 00034: val_loss did not improve from 0.77940
# Epoch 35/500
#  - 23s - loss: 0.5951 - accuracy: 0.3954 - val_loss: 0.9542 - val_accuracy: 0.3789
#
# Epoch 00035: val_loss did not improve from 0.77940
# Epoch 36/500
#  - 23s - loss: 0.5935 - accuracy: 0.3962 - val_loss: 1.0201 - val_accuracy: 0.3513
#
# Epoch 00036: val_loss did not improve from 0.77940
# Epoch 37/500
#  - 23s - loss: 0.5927 - accuracy: 0.3975 - val_loss: 0.9159 - val_accuracy: 0.3889
#
# Epoch 00037: val_loss did not improve from 0.77940
# Epoch 38/500
#  - 23s - loss: 0.5914 - accuracy: 0.3984 - val_loss: 0.9681 - val_accuracy: 0.3814
#
# Epoch 00038: val_loss did not improve from 0.77940
# Epoch 39/500
#  - 24s - loss: 0.5901 - accuracy: 0.4011 - val_loss: 0.9127 - val_accuracy: 0.3710
#
# Epoch 00039: val_loss did not improve from 0.77940
# Epoch 40/500
#  - 23s - loss: 0.5889 - accuracy: 0.4020 - val_loss: 0.8447 - val_accuracy: 0.4450
#
# Epoch 00040: val_loss did not improve from 0.77940
# Epoch 41/500
#  - 23s - loss: 0.5889 - accuracy: 0.4032 - val_loss: 0.9142 - val_accuracy: 0.3738
#
# Epoch 00041: val_loss did not improve from 0.77940
# Epoch 42/500
#  - 23s - loss: 0.5874 - accuracy: 0.4039 - val_loss: 1.0580 - val_accuracy: 0.3375
#
# Epoch 00042: val_loss did not improve from 0.77940
# Epoch 43/500
#  - 23s - loss: 0.5861 - accuracy: 0.4050 - val_loss: 1.0156 - val_accuracy: 0.3897
#
# Epoch 00043: val_loss did not improve from 0.77940
# Epoch 44/500
#  - 23s - loss: 0.5856 - accuracy: 0.4070 - val_loss: 0.9464 - val_accuracy: 0.3575
#
# Epoch 00044: val_loss did not improve from 0.77940
# Epoch 45/500
#  - 23s - loss: 0.5844 - accuracy: 0.4082 - val_loss: 0.8365 - val_accuracy: 0.4266
#
# Epoch 00045: val_loss did not improve from 0.77940
# Epoch 46/500
#  - 23s - loss: 0.5830 - accuracy: 0.4110 - val_loss: 1.0754 - val_accuracy: 0.2999
#
# Epoch 00046: val_loss did not improve from 0.77940
# Epoch 47/500
#  - 23s - loss: 0.5822 - accuracy: 0.4104 - val_loss: 1.0270 - val_accuracy: 0.3632
#
# Epoch 00047: val_loss did not improve from 0.77940
# Epoch 48/500
#  - 23s - loss: 0.5809 - accuracy: 0.4125 - val_loss: 0.7573 - val_accuracy: 0.4788
#
# Epoch 00048: val_loss improved from 0.77940 to 0.75728, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 15_127_ohlc.hdf5
# Epoch 49/500
#  - 23s - loss: 0.5798 - accuracy: 0.4144 - val_loss: 0.9852 - val_accuracy: 0.3749
#
# Epoch 00049: val_loss did not improve from 0.75728
# Epoch 50/500
#  - 23s - loss: 0.5785 - accuracy: 0.4166 - val_loss: 0.8953 - val_accuracy: 0.3870
#
# Epoch 00050: val_loss did not improve from 0.75728
# Epoch 51/500
#  - 23s - loss: 0.5781 - accuracy: 0.4168 - val_loss: 0.8816 - val_accuracy: 0.4526
#
# Epoch 00051: val_loss did not improve from 0.75728
# Epoch 52/500
#  - 23s - loss: 0.5769 - accuracy: 0.4179 - val_loss: 1.1491 - val_accuracy: 0.4071
#
# Epoch 00052: val_loss did not improve from 0.75728
# Epoch 53/500
#  - 24s - loss: 0.5754 - accuracy: 0.4202 - val_loss: 0.9524 - val_accuracy: 0.3907
#
# Epoch 00053: val_loss did not improve from 0.75728
# Epoch 54/500
#  - 23s - loss: 0.5741 - accuracy: 0.4212 - val_loss: 0.8618 - val_accuracy: 0.4449
#
# Epoch 00054: val_loss did not improve from 0.75728
# Epoch 55/500
#  - 23s - loss: 0.5732 - accuracy: 0.4234 - val_loss: 0.9685 - val_accuracy: 0.4041
#
# Epoch 00055: val_loss did not improve from 0.75728
# Epoch 56/500
#  - 23s - loss: 0.5718 - accuracy: 0.4263 - val_loss: 0.9040 - val_accuracy: 0.4046
#
# Epoch 00056: val_loss did not improve from 0.75728
# Epoch 57/500
#  - 23s - loss: 0.5710 - accuracy: 0.4262 - val_loss: 0.8841 - val_accuracy: 0.3869
#
# Epoch 00057: val_loss did not improve from 0.75728
# Epoch 58/500
#  - 23s - loss: 0.5701 - accuracy: 0.4276 - val_loss: 0.8774 - val_accuracy: 0.4722
#
# Epoch 00058: val_loss did not improve from 0.75728
# Epoch 59/500
#  - 23s - loss: 0.5688 - accuracy: 0.4296 - val_loss: 0.8762 - val_accuracy: 0.4212
#
# Epoch 00059: val_loss did not improve from 0.75728
# Epoch 60/500
#  - 23s - loss: 0.5673 - accuracy: 0.4320 - val_loss: 0.8501 - val_accuracy: 0.4238
#
# Epoch 00060: val_loss did not improve from 0.75728
# Epoch 61/500
#  - 23s - loss: 0.5663 - accuracy: 0.4335 - val_loss: 0.8378 - val_accuracy: 0.4547
#
# Epoch 00061: val_loss did not improve from 0.75728
# Epoch 62/500
#  - 23s - loss: 0.5653 - accuracy: 0.4344 - val_loss: 0.8280 - val_accuracy: 0.4781
#
# Epoch 00062: val_loss did not improve from 0.75728
# Epoch 63/500
#  - 23s - loss: 0.5641 - accuracy: 0.4357 - val_loss: 0.9676 - val_accuracy: 0.4106
#
# Epoch 00063: val_loss did not improve from 0.75728
# Epoch 64/500
#  - 24s - loss: 0.5627 - accuracy: 0.4382 - val_loss: 0.9139 - val_accuracy: 0.4311
#
# Epoch 00064: val_loss did not improve from 0.75728
# Epoch 65/500
#  - 24s - loss: 0.5617 - accuracy: 0.4389 - val_loss: 0.9774 - val_accuracy: 0.4221
#
# Epoch 00065: val_loss did not improve from 0.75728
# Epoch 66/500
#  - 24s - loss: 0.5604 - accuracy: 0.4422 - val_loss: 0.8735 - val_accuracy: 0.4593
#
# Epoch 00066: val_loss did not improve from 0.75728
# Epoch 67/500
#  - 24s - loss: 0.5596 - accuracy: 0.4425 - val_loss: 0.9504 - val_accuracy: 0.4462
#
# Epoch 00067: val_loss did not improve from 0.75728
# Epoch 68/500
#  - 24s - loss: 0.5588 - accuracy: 0.4438 - val_loss: 0.9334 - val_accuracy: 0.3682
#
# Epoch 00068: val_loss did not improve from 0.75728
# Epoch 69/500
#  - 24s - loss: 0.5572 - accuracy: 0.4448 - val_loss: 0.9662 - val_accuracy: 0.3793
#
# Epoch 00069: val_loss did not improve from 0.75728
# Epoch 70/500
#  - 24s - loss: 0.5557 - accuracy: 0.4482 - val_loss: 0.9266 - val_accuracy: 0.4209
#
# Epoch 00070: val_loss did not improve from 0.75728
# Epoch 71/500
#  - 24s - loss: 0.5548 - accuracy: 0.4488 - val_loss: 0.9663 - val_accuracy: 0.4138
#
# Epoch 00071: val_loss did not improve from 0.75728
# Epoch 72/500
#  - 24s - loss: 0.5538 - accuracy: 0.4504 - val_loss: 0.9511 - val_accuracy: 0.4412
#
# Epoch 00072: val_loss did not improve from 0.75728
# Epoch 73/500
#  - 23s - loss: 0.5523 - accuracy: 0.4521 - val_loss: 1.1312 - val_accuracy: 0.4303
#
# Epoch 00073: val_loss did not improve from 0.75728
# Epoch 74/500
#  - 23s - loss: 0.5512 - accuracy: 0.4538 - val_loss: 1.0363 - val_accuracy: 0.4417
#
# Epoch 00074: val_loss did not improve from 0.75728
# Epoch 75/500
#  - 24s - loss: 0.5505 - accuracy: 0.4546 - val_loss: 0.9772 - val_accuracy: 0.4722
#
# Epoch 00075: val_loss did not improve from 0.75728
# Epoch 76/500
#  - 24s - loss: 0.5496 - accuracy: 0.4560 - val_loss: 0.9615 - val_accuracy: 0.4502
#
# Epoch 00076: val_loss did not improve from 0.75728
# Epoch 77/500
#  - 23s - loss: 0.5482 - accuracy: 0.4583 - val_loss: 1.0572 - val_accuracy: 0.3891
#
# Epoch 00077: val_loss did not improve from 0.75728
# Epoch 78/500
#  - 24s - loss: 0.5462 - accuracy: 0.4602 - val_loss: 0.9658 - val_accuracy: 0.4502
#
# Epoch 00078: val_loss did not improve from 0.75728
# Epoch 79/500
#  - 24s - loss: 0.5458 - accuracy: 0.4621 - val_loss: 0.9131 - val_accuracy: 0.4402
#
# Epoch 00079: val_loss did not improve from 0.75728
# Epoch 80/500
#  - 23s - loss: 0.5443 - accuracy: 0.4637 - val_loss: 1.0443 - val_accuracy: 0.3907
#
# Epoch 00080: val_loss did not improve from 0.75728
# Epoch 81/500
#  - 23s - loss: 0.5437 - accuracy: 0.4644 - val_loss: 0.8074 - val_accuracy: 0.4695
#
# Epoch 00081: val_loss did not improve from 0.75728
# Epoch 82/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-749892e58f8d> in <module>()
#     170                     validation_data=val_flow,
#     171                     validation_steps=len(X_val) / batch_size,
# --> 172                     shuffle=False)
#     173
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
