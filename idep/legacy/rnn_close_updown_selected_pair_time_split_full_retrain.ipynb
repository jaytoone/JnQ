# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    # net = layers.LSTM(32, return_sequences=False)(visible)
    net = layers.LSTM(10, return_sequences=False)(visible)

    # net = layers.Dense(32)(visible)
    # net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    net = layers.Dense(128)(net)
    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(256)(net)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)


    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    # net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dropout(0.3)(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


def class_ratio(in_list):

  return in_list / in_list[1]

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight

from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

from funcs_indicator import *
from tqdm.notebook import tqdm


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None

seed = 1
random_state = 201
np.random.seed(seed)

for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue


  # if '02-11' not in candis[i]:  # <-- 04-08 includes all timestamp range
  #   continue  

  # if 'eth'.upper() not in candis[i]:
  #   continue

  # if 'neo'.upper() not in candis[i]:
  #   continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  

    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      # ohlcv = load_dict[key]['ohlcv']

    if 'sxp'.upper() not in key:
      continue
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))


    #       select timestamp range      #
    # time_index = ohlcv.index
    # total_stamp = list(map(lambda x: datetime.timestamp(x), time_index)) 

    # rm_index_amt = np.sum(np.array(total_stamp) < start_stamp)

    # ohlcv = ohlcv.iloc[rm_index_amt:]
    # print(ohlcv.head())

    ohlcv = ohlcv.iloc[:-2603]  # exclude back_range
    # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.3)]  # exclude back_range
    # predictions = load_dict[key]['predictions']
    # err_ranges = load_dict[key]['err_ranges']
    print("ohlcv.index[0] :", ohlcv.index[0])
    print("ohlcv.index[-1] :", ohlcv.index[-1])

    predictions = ohlcv['close'].shift(1).values
    err_ranges = np.zeros_like(predictions)

    # leverage_list = profit_result_dict[key]['leverage_list']
    # temp_ap_list = list()
    # temp_pr_list = list()

    try:
      print('-------------- %s --------------' % key)
      result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
      # temp_ap_list.append(result[2])
      # temp_pr_list.append(result[3])

      # if round(leverage) == 1:
      #   temp_pr_list = result[3]
      pr_list = result[3][long_index]

    except Exception as e:
      print(e)
      break    


    
  # break
    #         clustering zone           #

    #       set data features : ohlc, v, ep
    time_index = ohlcv.index[-len(predictions):]

    sliced_ohlcv = ohlcv[-len(predictions):]

    #       scale with price    #
    ohlc = ohlcv.iloc[-len(predictions):, :4]      
    long_ep = np.array(predictions)
    long_ep = long_ep.reshape(-1, 1)
    ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
    sar = lucid_sar(sliced_ohlcv)
    ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
    senkou1, senkou2 = ichimoku(sliced_ohlcv)

    #     min max scale   #
    vol = sliced_ohlcv.iloc[-len(predictions):, [4]]

    #     scale with baseline   #
    #     방법 1. 전체 기간 min_max scaling   #
    cbo, ema_cbo = cct_bbo(sliced_ohlcv, 21, 13) 

    _, _, bbw = bb_width(sliced_ohlcv, 20, 2) 
    
    fish = fisher(sliced_ohlcv, 60)
    trix = trix_hist(sliced_ohlcv, 14, 1, 5) 
    rsi_ = rsi(sliced_ohlcv)
    macd_hist = macd(sliced_ohlcv)




    # ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
    # ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
    # ohlcv['body'] = ohlcv['close'] / ohlcv['open']
    # candle = ohlcv.iloc[-len(predictions):, -3:]


    print('len(ohlc) :', len(ohlc))
    print('long_ep.shape :', long_ep.shape)
    print('len(ha_ohlc) :', len(ha_ohlc))
    print('len(sar) :', len(sar))
    print('len(ema1) :', len(ema1))
    print('len(senkou1) :', len(senkou1))
    print('len(cbo) :', len(cbo))
    print('len(ema_cbo) :', len(ema_cbo))
    print('len(bbw) :', len(bbw))
    print('len(fish) :', len(fish))
    print('len(trix) :', len(trix))
    print('len(rsi_) :', len(rsi_))
    print('len(macd_hist) :', len(macd_hist))


    # break


    #       set params    #
    period = 45
    key_i = i

    # plt.plot(cbo)
    # plt.plot(bbw)
    plt.plot(fish, color='b')
    # plt.plot(trix)
    # plt.plot(rsi_)
    # plt.plot(macd_hist)
    plt.show()

    #      global scaling   #
    min_max = MinMaxScaler()
    cbo = min_max.fit_transform(cbo.values.reshape(-1, 1))
    ema_cbo = min_max.fit_transform(ema_cbo.values.reshape(-1, 1))
    bbw = min_max.fit_transform(bbw.values.reshape(-1, 1))
    fish = min_max.fit_transform(fish.values.reshape(-1, 1))
    trix = min_max.fit_transform(trix.values.reshape(-1, 1))
    rsi_ = min_max.fit_transform(rsi_.values.reshape(-1, 1))
    macd_hist = min_max.fit_transform(macd_hist.values.reshape(-1, 1))

    # plt.plot(cbo)
    # plt.plot(bbw)
    plt.plot(fish, color='r')
    # plt.plot(trix)
    # plt.plot(rsi_)
    # plt.plot(macd_hist)
    plt.show()
    # break

    plotting = True

    for trial_number in range(1):

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)          

          price_data = np.hstack((temp_ohlc, temp_long_ep, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))

          temp_ohlc = temp_price_data[:, :4]
          temp_long_ep = temp_price_data[:, [4]]
          temp_ha_ohlc = temp_price_data[:, 5:9]
          temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2 = np.split(temp_price_data[:, 9:], 6, axis=1)

          if plotting:

            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          # temp_candle = candle.iloc[i - period : i].values

          temp_cbo = cbo[i - period : i]
          temp_ema_cbo = ema_cbo[i - period : i]
          temp_bbw = bbw[i - period : i]
          temp_fish = fish[i - period : i]
          temp_trix = trix[i - period : i]
          temp_rsi_ = rsi_[i - period : i]
          temp_macd_hist = macd_hist[i - period : i]

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          trial_list = [temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2,
                        temp_cbo, temp_ema_cbo, temp_bbw, temp_fish, temp_trix, temp_rsi_, temp_macd_hist]

          # trial_list = [temp_ohlc[:, [0], temp_ohlc[:, [1], temp_ohlc[:, [2], temp_ohlc[:, [3]], temp_vol, temp_ema_cbo]

          #                   feature selection                   #  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          temp_data = temp_ohlc[:, [3]]
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          #     only close    #
          # temp_data = temp_ohlc[:, [-1]]

          # temp_data = temp_ohlc

          #     only volume    #
          # temp_data = temp_vol

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :-1] = max_abs.fit_transform(temp_data[:, :-1])

          
          # min_max = MinMaxScaler()
          # temp_data = min_max.fit_transform(temp_data)

          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      # input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      # input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)

      
      # _, row, col, _ = input_x.shape
      _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      # print(np.unique(total_index, return_counts=True))
      # uniq_stamp = np.unique(total_index)

      # stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      # stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=True, random_state=random_state)

      # print("stamp_train.shape :", stamp_train.shape)
      # print("stamp_val.shape :", stamp_val.shape)
      # print("stamp_test.shape :", stamp_test.shape)
      # # break


      # #         split data by stamp     #
      # x_train, x_val, x_test = [], [], []
      # pr_train, pr_val, pr_test = [], [], []
      # index_train, index_val, index_test = [], [], []



      # np.random.shuffle(total_index)

      # for i in tqdm(range(len(total_index))):

      #   if total_index[i] in stamp_train:
      #     x_train.append(total_x[i])
      #     pr_train.append(total_pr[i])
      #     index_train.append(total_index[i])

      #   elif total_index[i] in stamp_val:
      #     x_val.append(total_x[i])
      #     pr_val.append(total_pr[i])
      #     index_val.append(total_index[i])
        
      #   elif total_index[i] in stamp_test:
      #     x_test.append(total_x[i])
      #     pr_test.append(total_pr[i])
      #     index_test.append(total_index[i])


      # x_train = np.array(x_train)
      # x_val = np.array(x_val)
      # x_test = np.array(x_test)

      # pr_train = np.array(pr_train)
      # pr_val = np.array(pr_val)
      # pr_test = np.array(pr_test)

      # index_train = np.array(index_train)
      # index_val = np.array(index_val)
      # index_test = np.array(index_test)
        
      # print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      # print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      # print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)



      seed = 1
      random_state = 20
      np.random.seed(seed)
  
      symbol_name = key.split(' ')[1].split('.')[0]

      #     test 로 부터 index 한개씩, train / val 로 붙이고 train / val 로부터 -1 data   #
      #     len(test) 만큼 수행   #
      org_test_size = 2092
      x_train, x_test, pr_train, pr_test = train_test_split(total_x, total_pr, test_size=0.2, shuffle=False)

      _, row, col, = x_train.shape
      y_test = np.where(pr_test > 1, 1, 0)

      # org_x_train, org_x_test, org_pr_train, org_pr_test = train_test_split(total_x, total_pr, test_size=0.2, shuffle=False)

      total_result = []
      t_result_path = current_path + 'npy/' + '%s_rnn_close_updown_x_t_result_full_%s.npy' % (period, symbol_name)
      try:
        total_result = np.load(t_result_path)
        total_result = list(total_result)
        print("----------------------- total_result loaded ! -----------------------")
        print("len(total_result) :", len(total_result))
      except:
        pass

      first_iter = True
      for r_i in tqdm(range(len(x_test))):

        if r_i < len(total_result):
          continue

        new_x_test = x_test[[r_i]]
        new_pr_test = pr_test[[r_i]]

        ind_x_train = np.vstack((x_train[r_i:], x_test[:r_i]))
        ind_pr_train = np.vstack((pr_train[r_i:], pr_test[:r_i]))

        #     add & remove test set   #
        new_x_train, new_x_val, new_pr_train, new_pr_val = train_test_split(ind_x_train, ind_pr_train, test_size=0.25, shuffle=True, random_state=random_state)

        new_y_train = np.where(new_pr_train > 1, 1, 0)
        new_y_val = np.where(new_pr_val > 1, 1, 0)
        new_y_test = np.where(new_pr_test > 1, 1, 0)

        
        print('new_x_train.shape :', new_x_train.shape)
        print('new_x_test.shape :', new_x_test.shape)
        print('new_x_val.shape :', new_x_val.shape)
        print('new_y_train.shape :', new_y_train.shape)
        print('new_y_test.shape :', new_y_test.shape)
        print('new_y_val.shape :', new_y_val.shape)


        print('np.unique(y_train, return_counts=True :', np.unique(new_y_train, return_counts=True), class_ratio(np.unique(new_y_train, return_counts=True)[1]))
        print('np.unique(new_y_val, return_counts=True :', np.unique(new_y_val, return_counts=True), class_ratio(np.unique(new_y_val, return_counts=True)[1]))
        # print('np.unique(new_y_test, return_counts=True :', np.unique(new_y_test, return_counts=True), class_ratio(np.unique(new_y_test, return_counts=True)[1]))

        label = new_y_train.reshape(-1, )
        class_weights = class_weight.compute_class_weight('balanced', 
                                                            classes=np.unique(label),
                                                            y=label)
        class_weights = dict(enumerate(class_weights))
        print('class_weights :', class_weights)

        # sample_weight = np.ones(shape=(len(new_y_train),))
        # sample_weight[(new_y_train == 1).reshape(-1,)] = 1.5
        # print('sample_weight[:20] :', sample_weight[:20])


        print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(new_x_train)))
        print('np.isnan(np.sum(new_x_val)) :', np.isnan(np.sum(new_x_val)))
        print('np.isnan(np.sum(new_x_test)) :', np.isnan(np.sum(new_x_test)))

        print('np.isnan(np.sum(new_y_train)) :', np.isnan(np.sum(new_y_train)))
        print('np.isnan(np.sum(new_y_val)) :', np.isnan(np.sum(new_y_val)))
        print('np.isnan(np.sum(new_y_test)) :', np.isnan(np.sum(new_y_test)))

        new_y_train_ohe = np_utils.to_categorical(new_y_train, num_classes)
        new_y_val_ohe = np_utils.to_categorical(new_y_val, num_classes)
        new_y_test_ohe = np_utils.to_categorical(new_y_test, num_classes)
        print('new_y_train_ohe.shape :', new_y_train_ohe.shape)
        print('new_y_val_ohe.shape :', new_y_val_ohe.shape)
        print('new_y_test_ohe.shape :', new_y_test_ohe.shape)


        ckpt_path = current_path + 'ckpt/'
        board_path = current_path + 'graph/'

        model_name = 'classifier_%s_lstm_close_updown_pr_retrain_full_%s_timesplit.h5' % (period, symbol_name)

        
        #       retraining    #       
        if r_i != 0:

          K.clear_session() # added for training delation

          try:
            model = keras.models.load_model(ckpt_path + model_name)
            print("----------------------- model loaded ! -----------------------")
          except Exception as e:
            print('Error in load_model :', e)
            model = FER_Model(input_shape=(row, col))

          # first_iter = False
          
          # for l_i, layer in enumerate(model.layers):

          #   if l_i != len(model.layers) - 1:
          #     layer.trainable = False

        else:
          model = FER_Model(input_shape=(row, col))

        batch_size = 512
        # _, row, col, = x_train.shape
        # print("row, col :", row, col)

        opt = Adam(lr=0.00001, decay=0.000005)
        # opt = Adam(lr=0.001, decay=0.0005)
        model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

        checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
        checkpoint2 = TensorBoard(log_dir=board_path,
                                  histogram_freq=0,
                                  write_graph=True,
                                  write_images=True)
        checkpoint3 = EarlyStopping(monitor='val_loss', patience=50)
        callbacks_list = [checkpoint, checkpoint2, checkpoint3]
        # callbacks_list = [checkpoint, checkpoint2]

        # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

        # we iterate 200 times over the entire training set
        num_epochs = 1000                    

        history = model.fit(new_x_train, new_y_train_ohe,
                            steps_per_epoch=int(len(new_x_train) / batch_size), 
                            epochs=num_epochs,  
                            verbose=2,  
                            callbacks=callbacks_list,
                            class_weight=class_weights,
                            validation_data=(new_x_val, new_y_val_ohe),  
                            validation_steps=int(len(new_x_val) / batch_size),
                            shuffle=False)
        
        ckpt_path = current_path + 'ckpt/'
        board_path = current_path + 'graph/'
        # model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_ex_02008.h5'
        # model_name = 'classifier_45_close_updown_pr_theta.h5'
        # model_name = 'classifier_45_close_updown_pr_theta_train_evendata_shuffle2_300k.h5'
        # model_name = 'classifier_45_lstm_close_updown_pr_neo_timesplit.h5'

        # model_name = 'classifier_45_lstm_close_updown_pr_eth_timesplit.h5'

        model = keras.models.load_model(ckpt_path + model_name)

        # x_test = new_input_x
        # y_test = np.where(new_input_pr > 1, 1, 0)
        # pr_test = new_input_pr

        # x_test = org_x_test
        # y_test = org_y_test
        # pr_test = org_pr_test

        # x_test = x_train
        # y_test = y_train
        # pr_test = pr_train

        # x_test = x_val
        # y_test = y_val
        # pr_test = pr_val

        # x_test = concat_x
        # y_test = np.where(concat_pr > 1, 1, 0)
        # pr_test = concat_pr

        test_result = model.predict(new_x_test)
        # test_result = model.predict(test_set)

        total_result.append(test_result)

        print('test_result.shape :', test_result.shape)

        
        np.save(t_result_path, np.array(total_result))
        print('total_result.shape :', np.array(total_result).shape)

      # print('pr_val.shape :', pr_val.shape)


      total_result = np.array(total_result).reshape(-1, 2)
      y_score = total_result[:, [1]]
      print('y_test[:5] :', y_test.reshape(-1,)[:5])
      # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
      print('y_score[:5] :', y_score[:5])
      # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

      print('y_test.shape :', y_test.shape)
      print('y_score.shape :', y_score.shape)

      print('len(y_test) :', len(y_test))

      #     precision recall curve   #
      precision, recall, threshold = precision_recall_curve(y_test, y_score)
      precision, recall = precision[:-1], recall[:-1]

      plt.plot(threshold, precision, label='precision')
      plt.plot(threshold, recall, label='recall')
      plt.legend()
      plt.title('precision recall')
      plt.show()
      # print(y_pred)


      # threshold = [0.65]
      # print('threshold :', threshold)
      # break

      acc_pr_bythr = []
      new_thresh = []

      for thresh in threshold:
        
        # if thresh < 0.5:
        #     continue

        y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
        # print('y_pred.shape :', y_pred.shape)
        # print('y_pred :', y_pred)

        #     compare precision     #

        # print('precision :', precision_score(y_test, y_pred))
        # print('recall :', recall_score(y_test, y_pred))
        # print()

        # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
        # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

        # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
        # # plt.show()  
        # print()

        #     check win-ratio improvement     #
        cmat = confusion_matrix(y_test, y_pred)
        # print(cmat)
        # print(np.sum(cmat, axis=1))

        test_size = len(y_test)
        test_pr_list = pr_test
        # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

        org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
        ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
        # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

        # print('pr_test.shape :', pr_test.shape)

        # print(y_pred)
        # print(test_pr_list)
        pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
        pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
        pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
        # print('pred_pr_list.shape :', pred_pr_list.shape)

        # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
        #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
        #   print('thresh :', thresh)
          
        # if len(threshold) == 1:
      #   plt.figure(figsize=(10, 5))
      #   plt.subplot(121)
      #   plt.plot(np.cumprod(test_pr_list))
      #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
      # # plt.show()

      #   plt.subplot(122)
      #   plt.plot(np.cumprod(pred_pr_list))
      #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
      #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
      #   plt.show()


        acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
        new_thresh.append(thresh)


      print('acc_pr_bythr :', acc_pr_bythr)

      plt.figure(figsize=(10, 5))
      plt.subplot(121)
      plt.plot(threshold, precision, label='precision')
      plt.plot(threshold, recall, label='recall')
      plt.legend()
      plt.title('precision recall')
      # plt.show()
      plt.subplot(122)
      plt.plot(new_thresh, acc_pr_bythr)
      plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
      plt.title(symbol_name)
      plt.show()


  # break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  try:
    if len(total_x) > 300000:
      break
  except:
    pass
# Out:
# start_stamp : 0
# len(ohlcv) : 13452
# ohlcv.index[0] : 2020-07-21 18:29:59.999000
# ohlcv.index[-1] : 2021-03-04 18:29:59.999000
# -------------- 2021-04-27 SXPUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# /content/drive/My Drive/Colab Notebooks/Project_Stock/funcs_indicator.py:273: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlcv_df['up'] = np.where(ohlcv_df['close'].diff(1) > 0, ohlcv_df['close'].diff(1), 0)
# /content/drive/My Drive/Colab Notebooks/Project_Stock/funcs_indicator.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlcv_df['down'] = np.where(ohlcv_df['close'].diff(1) < 0, ohlcv_df['close'].diff(1) * (-1), 0)
# len(ohlc) : 10849
# long_ep.shape : (10849, 1)
# len(ha_ohlc) : 10849
# len(sar) : 10849
# len(ema1) : 10849
# len(senkou1) : 10849
# len(cbo) : 10849
# len(ema_cbo) : 10849
# len(bbw) : 10849
# len(fish) : 10849
# len(trix) : 10849
# len(rsi_) : 10849
# len(macd_hist) : 10849
# np.array(data_x).shape : (10460, 45, 1)
# input_x.shape : (10460, 45, 1)
# input_x.dtype : float32
# input_pr.shape : (10460, 1)
# input_ud.shape : (10460, 1)
# input_index.shape : (10460, 1)
# total_x.shape : (10460, 45, 1)
# total_pr.shape : (10460, 1)
# total_ud.shape : (10460, 1)
# prev_index.shape : (10460, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:369: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# ----------------------- total_result loaded ! -----------------------
# len(total_result) : 1688
# HBox(children=(FloatProgress(value=0.0, max=2092.0), HTML(value='')))
# Streaming output truncated to the last 5000 lines.
#
# Epoch 00003: val_loss did not improve from 0.16948
# Epoch 4/1000
#  - 1s - loss: 0.5798 - accuracy: 0.6720 - val_loss: 0.1605 - val_accuracy: 2.5258
#
# Epoch 00004: val_loss improved from 0.16948 to 0.16046, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 5/1000
#  - 0s - loss: 0.5780 - accuracy: 0.6770 - val_loss: 0.1550 - val_accuracy: 2.5774
#
# Epoch 00005: val_loss improved from 0.16046 to 0.15499, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 6/1000
#  - 1s - loss: 0.5762 - accuracy: 0.6782 - val_loss: 0.1544 - val_accuracy: 2.6176
#
# Epoch 00006: val_loss improved from 0.15499 to 0.15436, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 7/1000
#  - 0s - loss: 0.5767 - accuracy: 0.6774 - val_loss: 0.1551 - val_accuracy: 2.6080
#
# Epoch 00007: val_loss did not improve from 0.15436
# Epoch 8/1000
#  - 0s - loss: 0.5755 - accuracy: 0.6792 - val_loss: 0.1547 - val_accuracy: 2.5946
#
# Epoch 00008: val_loss did not improve from 0.15436
# Epoch 9/1000
#  - 1s - loss: 0.5755 - accuracy: 0.6802 - val_loss: 0.1528 - val_accuracy: 2.5851
#
# Epoch 00009: val_loss improved from 0.15436 to 0.15281, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 10/1000
#  - 1s - loss: 0.5755 - accuracy: 0.6794 - val_loss: 0.1594 - val_accuracy: 2.4761
#
# Epoch 00010: val_loss did not improve from 0.15281
# Epoch 11/1000
#  - 0s - loss: 0.5743 - accuracy: 0.6807 - val_loss: 0.1578 - val_accuracy: 2.5315
#
# Epoch 00011: val_loss did not improve from 0.15281
# Epoch 12/1000
#  - 1s - loss: 0.5747 - accuracy: 0.6806 - val_loss: 0.1567 - val_accuracy: 2.5220
#
# Epoch 00012: val_loss did not improve from 0.15281
# Epoch 13/1000
#  - 0s - loss: 0.5741 - accuracy: 0.6805 - val_loss: 0.1622 - val_accuracy: 2.4054
#
# Epoch 00013: val_loss did not improve from 0.15281
# Epoch 14/1000
#  - 1s - loss: 0.5746 - accuracy: 0.6789 - val_loss: 0.1659 - val_accuracy: 2.3556
#
# Epoch 00014: val_loss did not improve from 0.15281
# Epoch 15/1000
#  - 0s - loss: 0.5736 - accuracy: 0.6818 - val_loss: 0.1728 - val_accuracy: 2.3098
#
# Epoch 00015: val_loss did not improve from 0.15281
# Epoch 16/1000
#  - 1s - loss: 0.5739 - accuracy: 0.6806 - val_loss: 0.1637 - val_accuracy: 2.3728
#
# Epoch 00016: val_loss did not improve from 0.15281
# Epoch 17/1000
#  - 0s - loss: 0.5728 - accuracy: 0.6820 - val_loss: 0.1644 - val_accuracy: 2.4015
#
# Epoch 00017: val_loss did not improve from 0.15281
# Epoch 18/1000
#  - 1s - loss: 0.5740 - accuracy: 0.6816 - val_loss: 0.1652 - val_accuracy: 2.3824
#
# Epoch 00018: val_loss did not improve from 0.15281
# Epoch 19/1000
#  - 1s - loss: 0.5730 - accuracy: 0.6818 - val_loss: 0.1628 - val_accuracy: 2.3996
#
# Epoch 00019: val_loss did not improve from 0.15281
# Epoch 20/1000
#  - 0s - loss: 0.5732 - accuracy: 0.6827 - val_loss: 0.1630 - val_accuracy: 2.4245
#
# Epoch 00020: val_loss did not improve from 0.15281
# Epoch 21/1000
#  - 0s - loss: 0.5731 - accuracy: 0.6830 - val_loss: 0.1659 - val_accuracy: 2.4054
#
# Epoch 00021: val_loss did not improve from 0.15281
# Epoch 22/1000
#  - 0s - loss: 0.5727 - accuracy: 0.6833 - val_loss: 0.1729 - val_accuracy: 2.2964
#
# Epoch 00022: val_loss did not improve from 0.15281
# Epoch 23/1000
#  - 1s - loss: 0.5732 - accuracy: 0.6816 - val_loss: 0.1810 - val_accuracy: 2.2753
#
# Epoch 00023: val_loss did not improve from 0.15281
# Epoch 24/1000
#  - 1s - loss: 0.5718 - accuracy: 0.6829 - val_loss: 0.1700 - val_accuracy: 2.3461
#
# Epoch 00024: val_loss did not improve from 0.15281
# Epoch 25/1000
#  - 0s - loss: 0.5720 - accuracy: 0.6831 - val_loss: 0.1741 - val_accuracy: 2.2964
#
# Epoch 00025: val_loss did not improve from 0.15281
# Epoch 26/1000
#  - 1s - loss: 0.5716 - accuracy: 0.6840 - val_loss: 0.1748 - val_accuracy: 2.3040
#
# Epoch 00026: val_loss did not improve from 0.15281
# Epoch 27/1000
#  - 0s - loss: 0.5726 - accuracy: 0.6834 - val_loss: 0.1707 - val_accuracy: 2.3289
#
# Epoch 00027: val_loss did not improve from 0.15281
# Epoch 28/1000
#  - 1s - loss: 0.5724 - accuracy: 0.6826 - val_loss: 0.1719 - val_accuracy: 2.3078
#
# Epoch 00028: val_loss did not improve from 0.15281
# Epoch 29/1000
#  - 0s - loss: 0.5714 - accuracy: 0.6842 - val_loss: 0.1777 - val_accuracy: 2.2715
#
# Epoch 00029: val_loss did not improve from 0.15281
# Epoch 30/1000
#  - 1s - loss: 0.5720 - accuracy: 0.6823 - val_loss: 0.1701 - val_accuracy: 2.3250
#
# Epoch 00030: val_loss did not improve from 0.15281
# Epoch 31/1000
#  - 1s - loss: 0.5718 - accuracy: 0.6845 - val_loss: 0.1605 - val_accuracy: 2.4168
#
# Epoch 00031: val_loss did not improve from 0.15281
# Epoch 32/1000
#  - 0s - loss: 0.5716 - accuracy: 0.6836 - val_loss: 0.1566 - val_accuracy: 2.4608
#
# Epoch 00032: val_loss did not improve from 0.15281
# Epoch 33/1000
#  - 0s - loss: 0.5709 - accuracy: 0.6847 - val_loss: 0.1576 - val_accuracy: 2.4551
#
# Epoch 00033: val_loss did not improve from 0.15281
# Epoch 34/1000
#  - 1s - loss: 0.5706 - accuracy: 0.6846 - val_loss: 0.1503 - val_accuracy: 2.6138
#
# Epoch 00034: val_loss improved from 0.15281 to 0.15029, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 35/1000
#  - 1s - loss: 0.5710 - accuracy: 0.6836 - val_loss: 0.1514 - val_accuracy: 2.6042
#
# Epoch 00035: val_loss did not improve from 0.15029
# Epoch 36/1000
#  - 0s - loss: 0.5714 - accuracy: 0.6850 - val_loss: 0.1494 - val_accuracy: 2.6310
#
# Epoch 00036: val_loss improved from 0.15029 to 0.14940, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 37/1000
#  - 1s - loss: 0.5705 - accuracy: 0.6844 - val_loss: 0.1512 - val_accuracy: 2.6214
#
# Epoch 00037: val_loss did not improve from 0.14940
# Epoch 38/1000
#  - 1s - loss: 0.5712 - accuracy: 0.6836 - val_loss: 0.1551 - val_accuracy: 2.6004
#
# Epoch 00038: val_loss did not improve from 0.14940
# Epoch 39/1000
#  - 0s - loss: 0.5702 - accuracy: 0.6863 - val_loss: 0.1530 - val_accuracy: 2.6195
#
# Epoch 00039: val_loss did not improve from 0.14940
# Epoch 40/1000
#  - 0s - loss: 0.5698 - accuracy: 0.6845 - val_loss: 0.1588 - val_accuracy: 2.5908
#
# Epoch 00040: val_loss did not improve from 0.14940
# Epoch 41/1000
#  - 0s - loss: 0.5712 - accuracy: 0.6850 - val_loss: 0.1618 - val_accuracy: 2.5468
#
# Epoch 00041: val_loss did not improve from 0.14940
# Epoch 42/1000
#  - 1s - loss: 0.5714 - accuracy: 0.6827 - val_loss: 0.1615 - val_accuracy: 2.5602
#
# Epoch 00042: val_loss did not improve from 0.14940
# Epoch 43/1000
#  - 0s - loss: 0.5708 - accuracy: 0.6833 - val_loss: 0.1688 - val_accuracy: 2.4952
#
# Epoch 00043: val_loss did not improve from 0.14940
# Epoch 44/1000
#  - 0s - loss: 0.5694 - accuracy: 0.6875 - val_loss: 0.1695 - val_accuracy: 2.4818
#
# Epoch 00044: val_loss did not improve from 0.14940
# Epoch 45/1000
#  - 0s - loss: 0.5708 - accuracy: 0.6836 - val_loss: 0.1595 - val_accuracy: 2.5564
#
# Epoch 00045: val_loss did not improve from 0.14940
# Epoch 46/1000
#  - 1s - loss: 0.5705 - accuracy: 0.6848 - val_loss: 0.1568 - val_accuracy: 2.5220
#
# Epoch 00046: val_loss did not improve from 0.14940
# Epoch 47/1000
#  - 1s - loss: 0.5698 - accuracy: 0.6866 - val_loss: 0.1566 - val_accuracy: 2.5296
#
# Epoch 00047: val_loss did not improve from 0.14940
# Epoch 48/1000
#  - 1s - loss: 0.5697 - accuracy: 0.6873 - val_loss: 0.1521 - val_accuracy: 2.5774
#
# Epoch 00048: val_loss did not improve from 0.14940
# Epoch 49/1000
#  - 1s - loss: 0.5697 - accuracy: 0.6848 - val_loss: 0.1527 - val_accuracy: 2.5774
#
# Epoch 00049: val_loss did not improve from 0.14940
# Epoch 50/1000
#  - 1s - loss: 0.5698 - accuracy: 0.6847 - val_loss: 0.1513 - val_accuracy: 2.5985
#
# Epoch 00050: val_loss did not improve from 0.14940
# Epoch 51/1000
#  - 0s - loss: 0.5699 - accuracy: 0.6873 - val_loss: 0.1528 - val_accuracy: 2.5717
#
# Epoch 00051: val_loss did not improve from 0.14940
# Epoch 52/1000
#  - 1s - loss: 0.5698 - accuracy: 0.6869 - val_loss: 0.1535 - val_accuracy: 2.5488
#
# Epoch 00052: val_loss did not improve from 0.14940
# Epoch 53/1000
#  - 0s - loss: 0.5692 - accuracy: 0.6865 - val_loss: 0.1559 - val_accuracy: 2.5239
#
# Epoch 00053: val_loss did not improve from 0.14940
# Epoch 54/1000
#  - 1s - loss: 0.5697 - accuracy: 0.6845 - val_loss: 0.1544 - val_accuracy: 2.5296
#
# Epoch 00054: val_loss did not improve from 0.14940
# Epoch 55/1000
#  - 0s - loss: 0.5686 - accuracy: 0.6886 - val_loss: 0.1522 - val_accuracy: 2.5449
#
# Epoch 00055: val_loss did not improve from 0.14940
# Epoch 56/1000
#  - 1s - loss: 0.5695 - accuracy: 0.6853 - val_loss: 0.1512 - val_accuracy: 2.5755
#
# Epoch 00056: val_loss did not improve from 0.14940
# Epoch 57/1000
#  - 0s - loss: 0.5692 - accuracy: 0.6853 - val_loss: 0.1498 - val_accuracy: 2.6252
#
# Epoch 00057: val_loss did not improve from 0.14940
# Epoch 58/1000
#  - 1s - loss: 0.5690 - accuracy: 0.6845 - val_loss: 0.1518 - val_accuracy: 2.5966
#
# Epoch 00058: val_loss did not improve from 0.14940
# Epoch 59/1000
#  - 0s - loss: 0.5691 - accuracy: 0.6869 - val_loss: 0.1556 - val_accuracy: 2.5526
#
# Epoch 00059: val_loss did not improve from 0.14940
# Epoch 60/1000
#  - 1s - loss: 0.5694 - accuracy: 0.6849 - val_loss: 0.1560 - val_accuracy: 2.5048
#
# Epoch 00060: val_loss did not improve from 0.14940
# Epoch 61/1000
#  - 1s - loss: 0.5693 - accuracy: 0.6872 - val_loss: 0.1648 - val_accuracy: 2.4187
#
# Epoch 00061: val_loss did not improve from 0.14940
# Epoch 62/1000
#  - 1s - loss: 0.5685 - accuracy: 0.6861 - val_loss: 0.1620 - val_accuracy: 2.4187
#
# Epoch 00062: val_loss did not improve from 0.14940
# Epoch 63/1000
#  - 1s - loss: 0.5694 - accuracy: 0.6861 - val_loss: 0.1521 - val_accuracy: 2.5813
#
# Epoch 00063: val_loss did not improve from 0.14940
# Epoch 64/1000
#  - 1s - loss: 0.5691 - accuracy: 0.6874 - val_loss: 0.1625 - val_accuracy: 2.4933
#
# Epoch 00064: val_loss did not improve from 0.14940
# Epoch 65/1000
#  - 0s - loss: 0.5685 - accuracy: 0.6864 - val_loss: 0.1591 - val_accuracy: 2.5430
#
# Epoch 00065: val_loss did not improve from 0.14940
# Epoch 66/1000
#  - 1s - loss: 0.5680 - accuracy: 0.6867 - val_loss: 0.1616 - val_accuracy: 2.4990
#
# Epoch 00066: val_loss did not improve from 0.14940
# Epoch 67/1000
#  - 1s - loss: 0.5691 - accuracy: 0.6872 - val_loss: 0.1566 - val_accuracy: 2.5354
#
# Epoch 00067: val_loss did not improve from 0.14940
# Epoch 68/1000
#  - 1s - loss: 0.5687 - accuracy: 0.6853 - val_loss: 0.1537 - val_accuracy: 2.5698
#
# Epoch 00068: val_loss did not improve from 0.14940
# Epoch 69/1000
#  - 1s - loss: 0.5679 - accuracy: 0.6866 - val_loss: 0.1591 - val_accuracy: 2.5182
#
# Epoch 00069: val_loss did not improve from 0.14940
# Epoch 70/1000
#  - 1s - loss: 0.5688 - accuracy: 0.6866 - val_loss: 0.1634 - val_accuracy: 2.5373
#
# Epoch 00070: val_loss did not improve from 0.14940
# Epoch 71/1000
#  - 1s - loss: 0.5686 - accuracy: 0.6856 - val_loss: 0.1542 - val_accuracy: 2.5717
#
# Epoch 00071: val_loss did not improve from 0.14940
# Epoch 72/1000
#  - 1s - loss: 0.5677 - accuracy: 0.6885 - val_loss: 0.1529 - val_accuracy: 2.6023
#
# Epoch 00072: val_loss did not improve from 0.14940
# Epoch 73/1000
#  - 1s - loss: 0.5689 - accuracy: 0.6873 - val_loss: 0.1544 - val_accuracy: 2.5449
#
# Epoch 00073: val_loss did not improve from 0.14940
# Epoch 74/1000
#  - 1s - loss: 0.5682 - accuracy: 0.6864 - val_loss: 0.1581 - val_accuracy: 2.5010
#
# Epoch 00074: val_loss did not improve from 0.14940
# Epoch 75/1000
#  - 1s - loss: 0.5683 - accuracy: 0.6861 - val_loss: 0.1575 - val_accuracy: 2.4952
#
# Epoch 00075: val_loss did not improve from 0.14940
# Epoch 76/1000
#  - 0s - loss: 0.5681 - accuracy: 0.6868 - val_loss: 0.1594 - val_accuracy: 2.4818
#
# Epoch 00076: val_loss did not improve from 0.14940
# Epoch 77/1000
#  - 1s - loss: 0.5692 - accuracy: 0.6840 - val_loss: 0.1590 - val_accuracy: 2.5105
#
# Epoch 00077: val_loss did not improve from 0.14940
# Epoch 78/1000
#  - 1s - loss: 0.5679 - accuracy: 0.6875 - val_loss: 0.1687 - val_accuracy: 2.3843
#
# Epoch 00078: val_loss did not improve from 0.14940
# Epoch 79/1000
#  - 1s - loss: 0.5688 - accuracy: 0.6862 - val_loss: 0.1876 - val_accuracy: 2.3270
#
# Epoch 00079: val_loss did not improve from 0.14940
# Epoch 80/1000
#  - 1s - loss: 0.5684 - accuracy: 0.6873 - val_loss: 0.2082 - val_accuracy: 2.2486
#
# Epoch 00080: val_loss did not improve from 0.14940
# Epoch 81/1000
#  - 1s - loss: 0.5680 - accuracy: 0.6868 - val_loss: 0.1954 - val_accuracy: 2.2696
#
# Epoch 00081: val_loss did not improve from 0.14940
# Epoch 82/1000
#  - 0s - loss: 0.5678 - accuracy: 0.6874 - val_loss: 0.1812 - val_accuracy: 2.3365
#
# Epoch 00082: val_loss did not improve from 0.14940
# Epoch 83/1000
#  - 0s - loss: 0.5678 - accuracy: 0.6856 - val_loss: 0.1924 - val_accuracy: 2.2486
#
# Epoch 00083: val_loss did not improve from 0.14940
# Epoch 84/1000
#  - 0s - loss: 0.5675 - accuracy: 0.6868 - val_loss: 0.2095 - val_accuracy: 2.1453
#
# Epoch 00084: val_loss did not improve from 0.14940
# Epoch 85/1000
#  - 1s - loss: 0.5678 - accuracy: 0.6878 - val_loss: 0.2038 - val_accuracy: 2.1128
#
# Epoch 00085: val_loss did not improve from 0.14940
# Epoch 86/1000
#  - 0s - loss: 0.5677 - accuracy: 0.6864 - val_loss: 0.1982 - val_accuracy: 2.1472
#
# Epoch 00086: val_loss did not improve from 0.14940
# test_result.shape : (1, 2)
# total_result.shape : (2077, 1, 2)
# new_x_train.shape : (6276, 45, 1)
# new_x_test.shape : (1, 45, 1)
# new_x_val.shape : (2092, 45, 1)
# new_y_train.shape : (6276, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (2092, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3347, 2929])) [1.14271082 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1148,  944])) [1.21610169 1.        ]
# class_weights : {0: 0.9375560203167015, 1: 1.0713554114032093}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (6276, 2)
# new_y_val_ohe.shape : (2092, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# Train on 6276 samples, validate on 2092 samples
# Epoch 1/1000
#  - 1s - loss: 0.6376 - accuracy: 0.6409 - val_loss: 0.1916 - val_accuracy: 2.2945
#
# Epoch 00001: val_loss improved from inf to 0.19165, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 2/1000
#  - 1s - loss: 0.5944 - accuracy: 0.6595 - val_loss: 0.1715 - val_accuracy: 2.3002
#
# Epoch 00002: val_loss improved from 0.19165 to 0.17147, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 3/1000
#  - 1s - loss: 0.5801 - accuracy: 0.6780 - val_loss: 0.1659 - val_accuracy: 2.3843
#
# Epoch 00003: val_loss improved from 0.17147 to 0.16585, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 4/1000
#  - 1s - loss: 0.5756 - accuracy: 0.6825 - val_loss: 0.1708 - val_accuracy: 2.3423
#
# Epoch 00004: val_loss did not improve from 0.16585
# Epoch 5/1000
#  - 1s - loss: 0.5743 - accuracy: 0.6849 - val_loss: 0.1788 - val_accuracy: 2.2543
#
# Epoch 00005: val_loss did not improve from 0.16585
# Epoch 6/1000
#  - 1s - loss: 0.5742 - accuracy: 0.6865 - val_loss: 0.1906 - val_accuracy: 2.1683
#
# Epoch 00006: val_loss did not improve from 0.16585
# Epoch 7/1000
#  - 1s - loss: 0.5720 - accuracy: 0.6856 - val_loss: 0.1956 - val_accuracy: 2.1453
#
# Epoch 00007: val_loss did not improve from 0.16585
# Epoch 8/1000
#  - 1s - loss: 0.5726 - accuracy: 0.6872 - val_loss: 0.1939 - val_accuracy: 2.1549
#
# Epoch 00008: val_loss did not improve from 0.16585
# Epoch 9/1000
#  - 1s - loss: 0.5724 - accuracy: 0.6869 - val_loss: 0.1929 - val_accuracy: 2.1721
#
# Epoch 00009: val_loss did not improve from 0.16585
# Epoch 10/1000
#  - 1s - loss: 0.5720 - accuracy: 0.6864 - val_loss: 0.1946 - val_accuracy: 2.1912
#
# Epoch 00010: val_loss did not improve from 0.16585
# Epoch 11/1000
#  - 1s - loss: 0.5718 - accuracy: 0.6874 - val_loss: 0.2065 - val_accuracy: 2.1396
#
# Epoch 00011: val_loss did not improve from 0.16585
# Epoch 12/1000
#  - 1s - loss: 0.5711 - accuracy: 0.6874 - val_loss: 0.1847 - val_accuracy: 2.2447
#
# Epoch 00012: val_loss did not improve from 0.16585
# Epoch 13/1000
#  - 1s - loss: 0.5711 - accuracy: 0.6867 - val_loss: 0.1588 - val_accuracy: 2.4589
#
# Epoch 00013: val_loss improved from 0.16585 to 0.15876, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 14/1000
#  - 1s - loss: 0.5717 - accuracy: 0.6878 - val_loss: 0.1526 - val_accuracy: 2.5468
#
# Epoch 00014: val_loss improved from 0.15876 to 0.15258, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 15/1000
#  - 1s - loss: 0.5713 - accuracy: 0.6877 - val_loss: 0.1536 - val_accuracy: 2.5698
#
# Epoch 00015: val_loss did not improve from 0.15258
# Epoch 16/1000
#  - 1s - loss: 0.5702 - accuracy: 0.6891 - val_loss: 0.1647 - val_accuracy: 2.5105
#
# Epoch 00016: val_loss did not improve from 0.15258
# Epoch 17/1000
#  - 1s - loss: 0.5708 - accuracy: 0.6890 - val_loss: 0.1608 - val_accuracy: 2.5373
#
# Epoch 00017: val_loss did not improve from 0.15258
# Epoch 18/1000
#  - 1s - loss: 0.5710 - accuracy: 0.6891 - val_loss: 0.1523 - val_accuracy: 2.6099
#
# Epoch 00018: val_loss improved from 0.15258 to 0.15232, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 19/1000
#  - 1s - loss: 0.5710 - accuracy: 0.6867 - val_loss: 0.1483 - val_accuracy: 2.5889
#
# Epoch 00019: val_loss improved from 0.15232 to 0.14825, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 20/1000
#  - 1s - loss: 0.5701 - accuracy: 0.6899 - val_loss: 0.1485 - val_accuracy: 2.5927
#
# Epoch 00020: val_loss did not improve from 0.14825
# Epoch 21/1000
#  - 1s - loss: 0.5700 - accuracy: 0.6907 - val_loss: 0.1495 - val_accuracy: 2.5641
#
# Epoch 00021: val_loss did not improve from 0.14825
# Epoch 22/1000
#  - 1s - loss: 0.5708 - accuracy: 0.6877 - val_loss: 0.1496 - val_accuracy: 2.5660
#
# Epoch 00022: val_loss did not improve from 0.14825
# Epoch 23/1000
#  - 1s - loss: 0.5694 - accuracy: 0.6906 - val_loss: 0.1511 - val_accuracy: 2.5507
#
# Epoch 00023: val_loss did not improve from 0.14825
# Epoch 24/1000
#  - 1s - loss: 0.5700 - accuracy: 0.6891 - val_loss: 0.1550 - val_accuracy: 2.4895
#
# Epoch 00024: val_loss did not improve from 0.14825
# Epoch 25/1000
#  - 1s - loss: 0.5702 - accuracy: 0.6902 - val_loss: 0.1550 - val_accuracy: 2.4837
#
# Epoch 00025: val_loss did not improve from 0.14825
# Epoch 26/1000
#  - 1s - loss: 0.5699 - accuracy: 0.6871 - val_loss: 0.1535 - val_accuracy: 2.5143
#
# Epoch 00026: val_loss did not improve from 0.14825
# Epoch 27/1000
#  - 1s - loss: 0.5696 - accuracy: 0.6914 - val_loss: 0.1606 - val_accuracy: 2.4742
#
# Epoch 00027: val_loss did not improve from 0.14825
# Epoch 28/1000
#  - 1s - loss: 0.5689 - accuracy: 0.6902 - val_loss: 0.1666 - val_accuracy: 2.3862
#
# Epoch 00028: val_loss did not improve from 0.14825
# Epoch 29/1000
#  - 1s - loss: 0.5690 - accuracy: 0.6889 - val_loss: 0.1682 - val_accuracy: 2.3289
#
# Epoch 00029: val_loss did not improve from 0.14825
# Epoch 30/1000
#  - 1s - loss: 0.5687 - accuracy: 0.6907 - val_loss: 0.1662 - val_accuracy: 2.3748
#
# Epoch 00030: val_loss did not improve from 0.14825
# Epoch 31/1000
#  - 1s - loss: 0.5686 - accuracy: 0.6898 - val_loss: 0.1581 - val_accuracy: 2.4245
#
# Epoch 00031: val_loss did not improve from 0.14825
# Epoch 32/1000
#  - 0s - loss: 0.5697 - accuracy: 0.6901 - val_loss: 0.1562 - val_accuracy: 2.4818
#
# Epoch 00032: val_loss did not improve from 0.14825
# Epoch 33/1000
#  - 1s - loss: 0.5696 - accuracy: 0.6905 - val_loss: 0.1591 - val_accuracy: 2.4512
#
# Epoch 00033: val_loss did not improve from 0.14825
# Epoch 34/1000
#  - 0s - loss: 0.5685 - accuracy: 0.6909 - val_loss: 0.1547 - val_accuracy: 2.5163
#
# Epoch 00034: val_loss did not improve from 0.14825
# Epoch 35/1000
#  - 1s - loss: 0.5685 - accuracy: 0.6917 - val_loss: 0.1493 - val_accuracy: 2.5889
#
# Epoch 00035: val_loss did not improve from 0.14825
# Epoch 36/1000
#  - 0s - loss: 0.5689 - accuracy: 0.6895 - val_loss: 0.1510 - val_accuracy: 2.5526
#
# Epoch 00036: val_loss did not improve from 0.14825
# Epoch 37/1000
#  - 1s - loss: 0.5689 - accuracy: 0.6910 - val_loss: 0.1510 - val_accuracy: 2.5488
#
# Epoch 00037: val_loss did not improve from 0.14825
# Epoch 38/1000
#  - 0s - loss: 0.5688 - accuracy: 0.6901 - val_loss: 0.1538 - val_accuracy: 2.5564
#
# Epoch 00038: val_loss did not improve from 0.14825
# Epoch 39/1000
#  - 1s - loss: 0.5683 - accuracy: 0.6898 - val_loss: 0.1593 - val_accuracy: 2.5373
#
# Epoch 00039: val_loss did not improve from 0.14825
# Epoch 40/1000
#  - 0s - loss: 0.5689 - accuracy: 0.6894 - val_loss: 0.1539 - val_accuracy: 2.5793
#
# Epoch 00040: val_loss did not improve from 0.14825
# Epoch 41/1000
#  - 1s - loss: 0.5689 - accuracy: 0.6903 - val_loss: 0.1512 - val_accuracy: 2.5641
#
# Epoch 00041: val_loss did not improve from 0.14825
# Epoch 42/1000
#  - 0s - loss: 0.5672 - accuracy: 0.6925 - val_loss: 0.1542 - val_accuracy: 2.5411
#
# Epoch 00042: val_loss did not improve from 0.14825
# Epoch 43/1000
#  - 0s - loss: 0.5681 - accuracy: 0.6910 - val_loss: 0.1673 - val_accuracy: 2.3958
#
# Epoch 00043: val_loss did not improve from 0.14825
# Epoch 44/1000
#  - 0s - loss: 0.5679 - accuracy: 0.6916 - val_loss: 0.1594 - val_accuracy: 2.4646
#
# Epoch 00044: val_loss did not improve from 0.14825
# Epoch 45/1000
#  - 1s - loss: 0.5687 - accuracy: 0.6921 - val_loss: 0.1533 - val_accuracy: 2.5430
#
# Epoch 00045: val_loss did not improve from 0.14825
# Epoch 46/1000
#  - 0s - loss: 0.5677 - accuracy: 0.6930 - val_loss: 0.1532 - val_accuracy: 2.5488
#
# Epoch 00046: val_loss did not improve from 0.14825
# Epoch 47/1000
#  - 0s - loss: 0.5675 - accuracy: 0.6927 - val_loss: 0.1516 - val_accuracy: 2.5583
#
# Epoch 00047: val_loss did not improve from 0.14825
# Epoch 48/1000
#  - 0s - loss: 0.5679 - accuracy: 0.6902 - val_loss: 0.1513 - val_accuracy: 2.5717
#
# Epoch 00048: val_loss did not improve from 0.14825
# Epoch 49/1000
#  - 0s - loss: 0.5675 - accuracy: 0.6909 - val_loss: 0.1508 - val_accuracy: 2.5870
#
# Epoch 00049: val_loss did not improve from 0.14825
# Epoch 50/1000
#  - 1s - loss: 0.5678 - accuracy: 0.6915 - val_loss: 0.1524 - val_accuracy: 2.5526
#
# Epoch 00050: val_loss did not improve from 0.14825
# Epoch 51/1000
#  - 0s - loss: 0.5670 - accuracy: 0.6935 - val_loss: 0.1512 - val_accuracy: 2.5774
#
# Epoch 00051: val_loss did not improve from 0.14825
# Epoch 52/1000
#  - 1s - loss: 0.5674 - accuracy: 0.6910 - val_loss: 0.1532 - val_accuracy: 2.5870
#
# Epoch 00052: val_loss did not improve from 0.14825
# Epoch 53/1000
#  - 1s - loss: 0.5680 - accuracy: 0.6908 - val_loss: 0.1544 - val_accuracy: 2.5545
#
# Epoch 00053: val_loss did not improve from 0.14825
# Epoch 54/1000
#  - 1s - loss: 0.5677 - accuracy: 0.6908 - val_loss: 0.1523 - val_accuracy: 2.5679
#
# Epoch 00054: val_loss did not improve from 0.14825
# Epoch 55/1000
#  - 1s - loss: 0.5668 - accuracy: 0.6913 - val_loss: 0.1506 - val_accuracy: 2.5889
#
# Epoch 00055: val_loss did not improve from 0.14825
# Epoch 56/1000
#  - 1s - loss: 0.5671 - accuracy: 0.6917 - val_loss: 0.1511 - val_accuracy: 2.5793
#
# Epoch 00056: val_loss did not improve from 0.14825
# Epoch 57/1000
#  - 0s - loss: 0.5675 - accuracy: 0.6918 - val_loss: 0.1529 - val_accuracy: 2.5315
#
# Epoch 00057: val_loss did not improve from 0.14825
# Epoch 58/1000
#  - 0s - loss: 0.5669 - accuracy: 0.6922 - val_loss: 0.1565 - val_accuracy: 2.5048
#
# Epoch 00058: val_loss did not improve from 0.14825
# Epoch 59/1000
#  - 1s - loss: 0.5668 - accuracy: 0.6909 - val_loss: 0.1523 - val_accuracy: 2.5564
#
# Epoch 00059: val_loss did not improve from 0.14825
# Epoch 60/1000
#  - 0s - loss: 0.5680 - accuracy: 0.6920 - val_loss: 0.1526 - val_accuracy: 2.5602
#
# Epoch 00060: val_loss did not improve from 0.14825
# Epoch 61/1000
#  - 1s - loss: 0.5681 - accuracy: 0.6911 - val_loss: 0.1519 - val_accuracy: 2.5793
#
# Epoch 00061: val_loss did not improve from 0.14825
# Epoch 62/1000
#  - 0s - loss: 0.5672 - accuracy: 0.6905 - val_loss: 0.1524 - val_accuracy: 2.5717
#
# Epoch 00062: val_loss did not improve from 0.14825
# Epoch 63/1000
#  - 0s - loss: 0.5668 - accuracy: 0.6919 - val_loss: 0.1555 - val_accuracy: 2.5105
#
# Epoch 00063: val_loss did not improve from 0.14825
# Epoch 64/1000
#  - 0s - loss: 0.5672 - accuracy: 0.6914 - val_loss: 0.1660 - val_accuracy: 2.3996
#
# Epoch 00064: val_loss did not improve from 0.14825
# Epoch 65/1000
#  - 0s - loss: 0.5668 - accuracy: 0.6918 - val_loss: 0.1673 - val_accuracy: 2.3824
#
# Epoch 00065: val_loss did not improve from 0.14825
# Epoch 66/1000
#  - 1s - loss: 0.5671 - accuracy: 0.6914 - val_loss: 0.1658 - val_accuracy: 2.3709
#
# Epoch 00066: val_loss did not improve from 0.14825
# Epoch 67/1000
#  - 0s - loss: 0.5666 - accuracy: 0.6931 - val_loss: 0.1657 - val_accuracy: 2.4092
#
# Epoch 00067: val_loss did not improve from 0.14825
# Epoch 68/1000
#  - 0s - loss: 0.5667 - accuracy: 0.6924 - val_loss: 0.1566 - val_accuracy: 2.4990
#
# Epoch 00068: val_loss did not improve from 0.14825
# Epoch 69/1000
#  - 1s - loss: 0.5656 - accuracy: 0.6933 - val_loss: 0.1542 - val_accuracy: 2.5641
#
# Epoch 00069: val_loss did not improve from 0.14825
# test_result.shape : (1, 2)
# total_result.shape : (2078, 1, 2)
# new_x_train.shape : (6276, 45, 1)
# new_x_test.shape : (1, 45, 1)
# new_x_val.shape : (2092, 45, 1)
# new_y_train.shape : (6276, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (2092, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3366, 2910])) [1.15670103 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1130,  962])) [1.17463617 1.        ]
# class_weights : {0: 0.9322638146167558, 1: 1.0783505154639175}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (6276, 2)
# new_y_val_ohe.shape : (2092, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# Train on 6276 samples, validate on 2092 samples
# Epoch 1/1000
#  - 1s - loss: 0.6236 - accuracy: 0.6448 - val_loss: 0.1665 - val_accuracy: 2.4876
#
# Epoch 00001: val_loss improved from inf to 0.16649, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 2/1000
#  - 0s - loss: 0.5853 - accuracy: 0.6681 - val_loss: 0.1659 - val_accuracy: 2.5449
#
# Epoch 00002: val_loss improved from 0.16649 to 0.16590, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 3/1000
#  - 0s - loss: 0.5766 - accuracy: 0.6787 - val_loss: 0.1662 - val_accuracy: 2.4780
#
# Epoch 00003: val_loss did not improve from 0.16590
# Epoch 4/1000
#  - 1s - loss: 0.5728 - accuracy: 0.6811 - val_loss: 0.1605 - val_accuracy: 2.5105
#
# Epoch 00004: val_loss improved from 0.16590 to 0.16054, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 5/1000
#  - 1s - loss: 0.5711 - accuracy: 0.6855 - val_loss: 0.1603 - val_accuracy: 2.5048
#
# Epoch 00005: val_loss improved from 0.16054 to 0.16032, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 6/1000
#  - 1s - loss: 0.5709 - accuracy: 0.6858 - val_loss: 0.1719 - val_accuracy: 2.4455
#
# Epoch 00006: val_loss did not improve from 0.16032
# Epoch 7/1000
#  - 1s - loss: 0.5715 - accuracy: 0.6842 - val_loss: 0.1857 - val_accuracy: 2.4054
#
# Epoch 00007: val_loss did not improve from 0.16032
# Epoch 8/1000
#  - 0s - loss: 0.5707 - accuracy: 0.6857 - val_loss: 0.1921 - val_accuracy: 2.4015
#
# Epoch 00008: val_loss did not improve from 0.16032
# Epoch 9/1000
#  - 0s - loss: 0.5701 - accuracy: 0.6875 - val_loss: 0.1812 - val_accuracy: 2.4130
#
# Epoch 00009: val_loss did not improve from 0.16032
# Epoch 10/1000
#  - 1s - loss: 0.5700 - accuracy: 0.6867 - val_loss: 0.1684 - val_accuracy: 2.4493
#
# Epoch 00010: val_loss did not improve from 0.16032
# Epoch 11/1000
#  - 0s - loss: 0.5700 - accuracy: 0.6864 - val_loss: 0.1580 - val_accuracy: 2.4895
#
# Epoch 00011: val_loss improved from 0.16032 to 0.15801, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 12/1000
#  - 1s - loss: 0.5695 - accuracy: 0.6883 - val_loss: 0.1550 - val_accuracy: 2.5679
#
# Epoch 00012: val_loss improved from 0.15801 to 0.15502, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 13/1000
#  - 0s - loss: 0.5698 - accuracy: 0.6865 - val_loss: 0.1531 - val_accuracy: 2.5870
#
# Epoch 00013: val_loss improved from 0.15502 to 0.15314, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 14/1000
#  - 1s - loss: 0.5686 - accuracy: 0.6875 - val_loss: 0.1506 - val_accuracy: 2.5583
#
# Epoch 00014: val_loss improved from 0.15314 to 0.15063, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 15/1000
#  - 1s - loss: 0.5680 - accuracy: 0.6885 - val_loss: 0.1526 - val_accuracy: 2.5679
#
# Epoch 00015: val_loss did not improve from 0.15063
# Epoch 16/1000
#  - 1s - loss: 0.5684 - accuracy: 0.6868 - val_loss: 0.1599 - val_accuracy: 2.5182
#
# Epoch 00016: val_loss did not improve from 0.15063
# Epoch 17/1000
#  - 1s - loss: 0.5694 - accuracy: 0.6872 - val_loss: 0.1551 - val_accuracy: 2.5468
#
# Epoch 00017: val_loss did not improve from 0.15063
# Epoch 18/1000
#  - 1s - loss: 0.5686 - accuracy: 0.6870 - val_loss: 0.1492 - val_accuracy: 2.6405
#
# Epoch 00018: val_loss improved from 0.15063 to 0.14916, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 19/1000
#  - 1s - loss: 0.5690 - accuracy: 0.6870 - val_loss: 0.1538 - val_accuracy: 2.5488
#
# Epoch 00019: val_loss did not improve from 0.14916
# Epoch 20/1000
#  - 1s - loss: 0.5685 - accuracy: 0.6870 - val_loss: 0.1675 - val_accuracy: 2.4015
#
# Epoch 00020: val_loss did not improve from 0.14916
# Epoch 21/1000
#  - 1s - loss: 0.5679 - accuracy: 0.6877 - val_loss: 0.1673 - val_accuracy: 2.3901
#
# Epoch 00021: val_loss did not improve from 0.14916
# Epoch 22/1000
#  - 1s - loss: 0.5676 - accuracy: 0.6881 - val_loss: 0.1546 - val_accuracy: 2.5315
#
# Epoch 00022: val_loss did not improve from 0.14916
# Epoch 23/1000
#  - 1s - loss: 0.5683 - accuracy: 0.6885 - val_loss: 0.1616 - val_accuracy: 2.4570
#
# Epoch 00023: val_loss did not improve from 0.14916
# Epoch 24/1000
#  - 1s - loss: 0.5682 - accuracy: 0.6880 - val_loss: 0.1755 - val_accuracy: 2.3270
#
# Epoch 00024: val_loss did not improve from 0.14916
# Epoch 25/1000
#  - 1s - loss: 0.5685 - accuracy: 0.6865 - val_loss: 0.1810 - val_accuracy: 2.2620
#
# Epoch 00025: val_loss did not improve from 0.14916
# Epoch 26/1000
#  - 1s - loss: 0.5682 - accuracy: 0.6888 - val_loss: 0.1703 - val_accuracy: 2.3671
#
# Epoch 00026: val_loss did not improve from 0.14916
# Epoch 27/1000
#  - 1s - loss: 0.5673 - accuracy: 0.6895 - val_loss: 0.1620 - val_accuracy: 2.4512
#
# Epoch 00027: val_loss did not improve from 0.14916
# Epoch 28/1000
#  - 0s - loss: 0.5670 - accuracy: 0.6884 - val_loss: 0.1623 - val_accuracy: 2.4589
#
# Epoch 00028: val_loss did not improve from 0.14916
# Epoch 29/1000
#  - 1s - loss: 0.5677 - accuracy: 0.6880 - val_loss: 0.1622 - val_accuracy: 2.4359
#
# Epoch 00029: val_loss did not improve from 0.14916
# Epoch 30/1000
#  - 0s - loss: 0.5672 - accuracy: 0.6900 - val_loss: 0.1651 - val_accuracy: 2.4130
#
# Epoch 00030: val_loss did not improve from 0.14916
# Epoch 31/1000
#  - 1s - loss: 0.5669 - accuracy: 0.6876 - val_loss: 0.1667 - val_accuracy: 2.3633
#
# Epoch 00031: val_loss did not improve from 0.14916
# Epoch 32/1000
#  - 1s - loss: 0.5674 - accuracy: 0.6884 - val_loss: 0.1589 - val_accuracy: 2.4971
#
# Epoch 00032: val_loss did not improve from 0.14916
# Epoch 33/1000
#  - 1s - loss: 0.5672 - accuracy: 0.6893 - val_loss: 0.1582 - val_accuracy: 2.5373
#
# Epoch 00033: val_loss did not improve from 0.14916
# Epoch 34/1000
#  - 1s - loss: 0.5673 - accuracy: 0.6876 - val_loss: 0.1506 - val_accuracy: 2.5985
#
# Epoch 00034: val_loss did not improve from 0.14916
# Epoch 35/1000
#  - 1s - loss: 0.5666 - accuracy: 0.6901 - val_loss: 0.1602 - val_accuracy: 2.4818
#
# Epoch 00035: val_loss did not improve from 0.14916
# Epoch 36/1000
#  - 0s - loss: 0.5664 - accuracy: 0.6906 - val_loss: 0.1737 - val_accuracy: 2.3499
#
# Epoch 00036: val_loss did not improve from 0.14916
# Epoch 37/1000
#  - 1s - loss: 0.5666 - accuracy: 0.6898 - val_loss: 0.1665 - val_accuracy: 2.4226
#
# Epoch 00037: val_loss did not improve from 0.14916
# Epoch 38/1000
#  - 0s - loss: 0.5664 - accuracy: 0.6886 - val_loss: 0.1601 - val_accuracy: 2.5086
#
# Epoch 00038: val_loss did not improve from 0.14916
# Epoch 39/1000
#  - 1s - loss: 0.5664 - accuracy: 0.6893 - val_loss: 0.1506 - val_accuracy: 2.5908
#
# Epoch 00039: val_loss did not improve from 0.14916
# Epoch 40/1000
#  - 0s - loss: 0.5662 - accuracy: 0.6899 - val_loss: 0.1501 - val_accuracy: 2.5793
#
# Epoch 00040: val_loss did not improve from 0.14916
# Epoch 41/1000
#  - 0s - loss: 0.5666 - accuracy: 0.6885 - val_loss: 0.1540 - val_accuracy: 2.5736
#
# Epoch 00041: val_loss did not improve from 0.14916
# Epoch 42/1000
#  - 0s - loss: 0.5665 - accuracy: 0.6899 - val_loss: 0.1565 - val_accuracy: 2.5602
#
# Epoch 00042: val_loss did not improve from 0.14916
# Epoch 43/1000
#  - 1s - loss: 0.5667 - accuracy: 0.6904 - val_loss: 0.1526 - val_accuracy: 2.5660
#
# Epoch 00043: val_loss did not improve from 0.14916
# Epoch 44/1000
#  - 1s - loss: 0.5660 - accuracy: 0.6893 - val_loss: 0.1571 - val_accuracy: 2.5048
#
# Epoch 00044: val_loss did not improve from 0.14916
# Epoch 45/1000
#  - 1s - loss: 0.5663 - accuracy: 0.6896 - val_loss: 0.1568 - val_accuracy: 2.5201
#
# Epoch 00045: val_loss did not improve from 0.14916
# Epoch 46/1000
#  - 0s - loss: 0.5655 - accuracy: 0.6906 - val_loss: 0.1694 - val_accuracy: 2.3652
#
# Epoch 00046: val_loss did not improve from 0.14916
# Epoch 47/1000
#  - 1s - loss: 0.5667 - accuracy: 0.6906 - val_loss: 0.1695 - val_accuracy: 2.3805
#
# Epoch 00047: val_loss did not improve from 0.14916
# Epoch 48/1000
#  - 1s - loss: 0.5662 - accuracy: 0.6892 - val_loss: 0.1802 - val_accuracy: 2.2925
#
# Epoch 00048: val_loss did not improve from 0.14916
# Epoch 49/1000
#  - 1s - loss: 0.5656 - accuracy: 0.6899 - val_loss: 0.1756 - val_accuracy: 2.3423
#
# Epoch 00049: val_loss did not improve from 0.14916
# Epoch 50/1000
#  - 1s - loss: 0.5656 - accuracy: 0.6901 - val_loss: 0.1634 - val_accuracy: 2.4570
#
# Epoch 00050: val_loss did not improve from 0.14916
# Epoch 51/1000
#  - 1s - loss: 0.5654 - accuracy: 0.6902 - val_loss: 0.1583 - val_accuracy: 2.4857
#
# Epoch 00051: val_loss did not improve from 0.14916
# Epoch 52/1000
#  - 1s - loss: 0.5649 - accuracy: 0.6905 - val_loss: 0.1573 - val_accuracy: 2.5315
#
# Epoch 00052: val_loss did not improve from 0.14916
# Epoch 53/1000
#  - 1s - loss: 0.5652 - accuracy: 0.6901 - val_loss: 0.1544 - val_accuracy: 2.5239
#
# Epoch 00053: val_loss did not improve from 0.14916
# Epoch 54/1000
#  - 1s - loss: 0.5653 - accuracy: 0.6915 - val_loss: 0.1567 - val_accuracy: 2.5010
#
# Epoch 00054: val_loss did not improve from 0.14916
# Epoch 55/1000
#  - 1s - loss: 0.5659 - accuracy: 0.6902 - val_loss: 0.1547 - val_accuracy: 2.5335
#
# Epoch 00055: val_loss did not improve from 0.14916
# Epoch 56/1000
#  - 1s - loss: 0.5656 - accuracy: 0.6903 - val_loss: 0.1503 - val_accuracy: 2.6214
#
# Epoch 00056: val_loss did not improve from 0.14916
# Epoch 57/1000
#  - 1s - loss: 0.5651 - accuracy: 0.6915 - val_loss: 0.1530 - val_accuracy: 2.5736
#
# Epoch 00057: val_loss did not improve from 0.14916
# Epoch 58/1000
#  - 1s - loss: 0.5654 - accuracy: 0.6911 - val_loss: 0.1584 - val_accuracy: 2.4933
#
# Epoch 00058: val_loss did not improve from 0.14916
# Epoch 59/1000
#  - 1s - loss: 0.5653 - accuracy: 0.6903 - val_loss: 0.1542 - val_accuracy: 2.5583
#
# Epoch 00059: val_loss did not improve from 0.14916
# Epoch 60/1000
#  - 1s - loss: 0.5658 - accuracy: 0.6892 - val_loss: 0.1518 - val_accuracy: 2.5813
#
# Epoch 00060: val_loss did not improve from 0.14916
# Epoch 61/1000
#  - 1s - loss: 0.5653 - accuracy: 0.6913 - val_loss: 0.1526 - val_accuracy: 2.5545
#
# Epoch 00061: val_loss did not improve from 0.14916
# Epoch 62/1000
#  - 1s - loss: 0.5659 - accuracy: 0.6895 - val_loss: 0.1539 - val_accuracy: 2.5449
#
# Epoch 00062: val_loss did not improve from 0.14916
# Epoch 63/1000
#  - 1s - loss: 0.5657 - accuracy: 0.6916 - val_loss: 0.1668 - val_accuracy: 2.4723
#
# Epoch 00063: val_loss did not improve from 0.14916
# Epoch 64/1000
#  - 1s - loss: 0.5649 - accuracy: 0.6905 - val_loss: 0.1654 - val_accuracy: 2.4704
#
# Epoch 00064: val_loss did not improve from 0.14916
# Epoch 65/1000
#  - 1s - loss: 0.5654 - accuracy: 0.6896 - val_loss: 0.1745 - val_accuracy: 2.4245
#
# Epoch 00065: val_loss did not improve from 0.14916
# Epoch 66/1000
#  - 1s - loss: 0.5652 - accuracy: 0.6914 - val_loss: 0.1766 - val_accuracy: 2.4245
#
# Epoch 00066: val_loss did not improve from 0.14916
# Epoch 67/1000
#  - 1s - loss: 0.5648 - accuracy: 0.6900 - val_loss: 0.1728 - val_accuracy: 2.4359
#
# Epoch 00067: val_loss did not improve from 0.14916
# Epoch 68/1000
#  - 1s - loss: 0.5651 - accuracy: 0.6889 - val_loss: 0.1683 - val_accuracy: 2.4455
#
# Epoch 00068: val_loss did not improve from 0.14916
# test_result.shape : (1, 2)
# total_result.shape : (2079, 1, 2)
# new_x_train.shape : (6276, 45, 1)
# new_x_test.shape : (1, 45, 1)
# new_x_val.shape : (2092, 45, 1)
# new_y_train.shape : (6276, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (2092, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3399, 2877])) [1.181439 1.      ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1096,  996])) [1.10040161 1.        ]
# class_weights : {0: 0.9232127096204766, 1: 1.0907194994786236}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (6276, 2)
# new_y_val_ohe.shape : (2092, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# Train on 6276 samples, validate on 2092 samples
# Epoch 1/1000
#  - 1s - loss: 0.6328 - accuracy: 0.6390 - val_loss: 0.1777 - val_accuracy: 2.3423
#
# Epoch 00001: val_loss improved from inf to 0.17769, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 2/1000
#  - 0s - loss: 0.5910 - accuracy: 0.6608 - val_loss: 0.1481 - val_accuracy: 2.6558
#
# Epoch 00002: val_loss improved from 0.17769 to 0.14808, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 3/1000
#  - 0s - loss: 0.5793 - accuracy: 0.6738 - val_loss: 0.1482 - val_accuracy: 2.6195
#
# Epoch 00003: val_loss did not improve from 0.14808
# Epoch 4/1000
#  - 1s - loss: 0.5748 - accuracy: 0.6797 - val_loss: 0.1500 - val_accuracy: 2.5832
#
# Epoch 00004: val_loss did not improve from 0.14808
# Epoch 5/1000
#  - 0s - loss: 0.5737 - accuracy: 0.6821 - val_loss: 0.1514 - val_accuracy: 2.6348
#
# Epoch 00005: val_loss did not improve from 0.14808
# Epoch 6/1000
#  - 1s - loss: 0.5732 - accuracy: 0.6821 - val_loss: 0.1590 - val_accuracy: 2.5258
#
# Epoch 00006: val_loss did not improve from 0.14808
# Epoch 7/1000
#  - 0s - loss: 0.5718 - accuracy: 0.6847 - val_loss: 0.1563 - val_accuracy: 2.5583
#
# Epoch 00007: val_loss did not improve from 0.14808
# Epoch 8/1000
#  - 1s - loss: 0.5715 - accuracy: 0.6841 - val_loss: 0.1549 - val_accuracy: 2.5832
#
# Epoch 00008: val_loss did not improve from 0.14808
# Epoch 9/1000
#  - 0s - loss: 0.5711 - accuracy: 0.6855 - val_loss: 0.1543 - val_accuracy: 2.6042
#
# Epoch 00009: val_loss did not improve from 0.14808
# Epoch 10/1000
#  - 1s - loss: 0.5715 - accuracy: 0.6850 - val_loss: 0.1553 - val_accuracy: 2.5488
#
# Epoch 00010: val_loss did not improve from 0.14808
# Epoch 11/1000
#  - 0s - loss: 0.5715 - accuracy: 0.6834 - val_loss: 0.1564 - val_accuracy: 2.4990
#
# Epoch 00011: val_loss did not improve from 0.14808
# Epoch 12/1000
#  - 1s - loss: 0.5712 - accuracy: 0.6852 - val_loss: 0.1595 - val_accuracy: 2.4474
#
# Epoch 00012: val_loss did not improve from 0.14808
# Epoch 13/1000
#  - 0s - loss: 0.5703 - accuracy: 0.6850 - val_loss: 0.1625 - val_accuracy: 2.4359
#
# Epoch 00013: val_loss did not improve from 0.14808
# Epoch 14/1000
#  - 0s - loss: 0.5712 - accuracy: 0.6846 - val_loss: 0.1597 - val_accuracy: 2.4723
#
# Epoch 00014: val_loss did not improve from 0.14808
# Epoch 15/1000
#  - 1s - loss: 0.5713 - accuracy: 0.6851 - val_loss: 0.1528 - val_accuracy: 2.6042
#
# Epoch 00015: val_loss did not improve from 0.14808
# Epoch 16/1000
#  - 1s - loss: 0.5704 - accuracy: 0.6860 - val_loss: 0.1607 - val_accuracy: 2.5488
#
# Epoch 00016: val_loss did not improve from 0.14808
# Epoch 17/1000
#  - 0s - loss: 0.5708 - accuracy: 0.6840 - val_loss: 0.1678 - val_accuracy: 2.4837
#
# Epoch 00017: val_loss did not improve from 0.14808
# Epoch 18/1000
#  - 1s - loss: 0.5701 - accuracy: 0.6863 - val_loss: 0.1723 - val_accuracy: 2.4340
#
# Epoch 00018: val_loss did not improve from 0.14808
# Epoch 19/1000
#  - 0s - loss: 0.5703 - accuracy: 0.6856 - val_loss: 0.1597 - val_accuracy: 2.5239
#
# Epoch 00019: val_loss did not improve from 0.14808
# Epoch 20/1000
#  - 0s - loss: 0.5703 - accuracy: 0.6862 - val_loss: 0.1563 - val_accuracy: 2.5813
#
# Epoch 00020: val_loss did not improve from 0.14808
# Epoch 21/1000
#  - 0s - loss: 0.5701 - accuracy: 0.6873 - val_loss: 0.1567 - val_accuracy: 2.5641
#
# Epoch 00021: val_loss did not improve from 0.14808
# Epoch 22/1000
#  - 1s - loss: 0.5704 - accuracy: 0.6849 - val_loss: 0.1538 - val_accuracy: 2.5698
#
# Epoch 00022: val_loss did not improve from 0.14808
# Epoch 23/1000
#  - 0s - loss: 0.5697 - accuracy: 0.6869 - val_loss: 0.1516 - val_accuracy: 2.6061
#
# Epoch 00023: val_loss did not improve from 0.14808
# Epoch 24/1000
#  - 1s - loss: 0.5705 - accuracy: 0.6847 - val_loss: 0.1510 - val_accuracy: 2.5985
#
# Epoch 00024: val_loss did not improve from 0.14808
# Epoch 25/1000
#  - 0s - loss: 0.5696 - accuracy: 0.6860 - val_loss: 0.1577 - val_accuracy: 2.5449
#
# Epoch 00025: val_loss did not improve from 0.14808
# Epoch 26/1000
#  - 1s - loss: 0.5700 - accuracy: 0.6853 - val_loss: 0.1555 - val_accuracy: 2.5545
#
# Epoch 00026: val_loss did not improve from 0.14808
# Epoch 27/1000
#  - 0s - loss: 0.5692 - accuracy: 0.6864 - val_loss: 0.1593 - val_accuracy: 2.5182
#
# Epoch 00027: val_loss did not improve from 0.14808
# Epoch 28/1000
#  - 1s - loss: 0.5696 - accuracy: 0.6867 - val_loss: 0.1628 - val_accuracy: 2.4952
#
# Epoch 00028: val_loss did not improve from 0.14808
# Epoch 29/1000
#  - 0s - loss: 0.5688 - accuracy: 0.6866 - val_loss: 0.1609 - val_accuracy: 2.5067
#
# Epoch 00029: val_loss did not improve from 0.14808
# Epoch 30/1000
#  - 0s - loss: 0.5691 - accuracy: 0.6870 - val_loss: 0.1567 - val_accuracy: 2.5143
#
# Epoch 00030: val_loss did not improve from 0.14808
# Epoch 31/1000
#  - 1s - loss: 0.5685 - accuracy: 0.6889 - val_loss: 0.1530 - val_accuracy: 2.5679
#
# Epoch 00031: val_loss did not improve from 0.14808
# Epoch 32/1000
#  - 1s - loss: 0.5684 - accuracy: 0.6894 - val_loss: 0.1496 - val_accuracy: 2.5985
#
# Epoch 00032: val_loss did not improve from 0.14808
# Epoch 33/1000
#  - 1s - loss: 0.5686 - accuracy: 0.6879 - val_loss: 0.1489 - val_accuracy: 2.6272
#
# Epoch 00033: val_loss did not improve from 0.14808
# Epoch 34/1000
#  - 1s - loss: 0.5690 - accuracy: 0.6862 - val_loss: 0.1495 - val_accuracy: 2.6195
#
# Epoch 00034: val_loss did not improve from 0.14808
# Epoch 35/1000
#  - 0s - loss: 0.5687 - accuracy: 0.6876 - val_loss: 0.1489 - val_accuracy: 2.6463
#
# Epoch 00035: val_loss did not improve from 0.14808
# Epoch 36/1000
#  - 0s - loss: 0.5688 - accuracy: 0.6859 - val_loss: 0.1498 - val_accuracy: 2.6252
#
# Epoch 00036: val_loss did not improve from 0.14808
# Epoch 37/1000
# ...
# Epoch 00037: val_loss did not improve from 0.14740
# Epoch 38/1000
#  - 0s - loss: 0.5659 - accuracy: 0.6885 - val_loss: 0.1529 - val_accuracy: 2.6099
#
# Epoch 00038: val_loss did not improve from 0.14740
# Epoch 39/1000
#  - 0s - loss: 0.5659 - accuracy: 0.6908 - val_loss: 0.1522 - val_accuracy: 2.6023
#
# Epoch 00039: val_loss did not improve from 0.14740
# Epoch 40/1000
#  - 1s - loss: 0.5653 - accuracy: 0.6890 - val_loss: 0.1527 - val_accuracy: 2.5966
#
# Epoch 00040: val_loss did not improve from 0.14740
# Epoch 41/1000
#  - 1s - loss: 0.5657 - accuracy: 0.6907 - val_loss: 0.1555 - val_accuracy: 2.5296
#
# Epoch 00041: val_loss did not improve from 0.14740
# Epoch 42/1000
#  - 1s - loss: 0.5655 - accuracy: 0.6903 - val_loss: 0.1552 - val_accuracy: 2.5335
#
# Epoch 00042: val_loss did not improve from 0.14740
# Epoch 43/1000
#  - 1s - loss: 0.5649 - accuracy: 0.6909 - val_loss: 0.1615 - val_accuracy: 2.4914
#
# Epoch 00043: val_loss did not improve from 0.14740
# Epoch 44/1000
#  - 1s - loss: 0.5651 - accuracy: 0.6912 - val_loss: 0.1610 - val_accuracy: 2.4665
#
# Epoch 00044: val_loss did not improve from 0.14740
# Epoch 45/1000
#  - 1s - loss: 0.5645 - accuracy: 0.6921 - val_loss: 0.1649 - val_accuracy: 2.4952
#
# Epoch 00045: val_loss did not improve from 0.14740
# Epoch 46/1000
#  - 0s - loss: 0.5649 - accuracy: 0.6914 - val_loss: 0.1634 - val_accuracy: 2.4990
#
# Epoch 00046: val_loss did not improve from 0.14740
# Epoch 47/1000
#  - 0s - loss: 0.5651 - accuracy: 0.6899 - val_loss: 0.1643 - val_accuracy: 2.4608
#
# Epoch 00047: val_loss did not improve from 0.14740
# Epoch 48/1000
#  - 0s - loss: 0.5654 - accuracy: 0.6901 - val_loss: 0.1653 - val_accuracy: 2.4742
#
# Epoch 00048: val_loss did not improve from 0.14740
# Epoch 49/1000
#  - 1s - loss: 0.5650 - accuracy: 0.6905 - val_loss: 0.1666 - val_accuracy: 2.4474
#
# Epoch 00049: val_loss did not improve from 0.14740
# Epoch 50/1000
#  - 0s - loss: 0.5642 - accuracy: 0.6914 - val_loss: 0.1789 - val_accuracy: 2.3958
#
# Epoch 00050: val_loss did not improve from 0.14740
# Epoch 51/1000
#  - 0s - loss: 0.5650 - accuracy: 0.6910 - val_loss: 0.1776 - val_accuracy: 2.3996
#
# Epoch 00051: val_loss did not improve from 0.14740
# Epoch 52/1000
#  - 0s - loss: 0.5645 - accuracy: 0.6914 - val_loss: 0.1805 - val_accuracy: 2.3824
#
# Epoch 00052: val_loss did not improve from 0.14740
# Epoch 53/1000
#  - 0s - loss: 0.5642 - accuracy: 0.6906 - val_loss: 0.1635 - val_accuracy: 2.4704
#
# Epoch 00053: val_loss did not improve from 0.14740
# Epoch 54/1000
#  - 0s - loss: 0.5647 - accuracy: 0.6914 - val_loss: 0.1530 - val_accuracy: 2.5507
#
# Epoch 00054: val_loss did not improve from 0.14740
# Epoch 55/1000
#  - 1s - loss: 0.5638 - accuracy: 0.6922 - val_loss: 0.1534 - val_accuracy: 2.5507
#
# Epoch 00055: val_loss did not improve from 0.14740
# test_result.shape : (1, 2)
# total_result.shape : (2091, 1, 2)
# new_x_train.shape : (6276, 45, 1)
# new_x_test.shape : (1, 45, 1)
# new_x_val.shape : (2092, 45, 1)
# new_y_train.shape : (6276, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (2092, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([3378, 2898])) [1.16563147 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1119,  973])) [1.15005139 1.        ]
# class_weights : {0: 0.9289520426287744, 1: 1.0828157349896481}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (6276, 2)
# new_y_val_ohe.shape : (2092, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# Train on 6276 samples, validate on 2092 samples
# Epoch 1/1000
#  - 1s - loss: 0.6453 - accuracy: 0.6369 - val_loss: 0.1615 - val_accuracy: 2.4933
#
# Epoch 00001: val_loss improved from inf to 0.16150, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 2/1000
#  - 0s - loss: 0.5947 - accuracy: 0.6573 - val_loss: 0.1452 - val_accuracy: 2.6750
#
# Epoch 00002: val_loss improved from 0.16150 to 0.14524, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_lstm_close_updown_pr_retrain_full_SXPUSDT_timesplit.h5
# Epoch 3/1000
#  - 0s - loss: 0.5780 - accuracy: 0.6754 - val_loss: 0.1471 - val_accuracy: 2.6616
#
# Epoch 00003: val_loss did not improve from 0.14524
# Epoch 4/1000
#  - 0s - loss: 0.5736 - accuracy: 0.6797 - val_loss: 0.1465 - val_accuracy: 2.6922
#
# Epoch 00004: val_loss did not improve from 0.14524
# Epoch 5/1000
#  - 1s - loss: 0.5727 - accuracy: 0.6819 - val_loss: 0.1466 - val_accuracy: 2.6922
#
# Epoch 00005: val_loss did not improve from 0.14524
# Epoch 6/1000
#  - 0s - loss: 0.5700 - accuracy: 0.6834 - val_loss: 0.1473 - val_accuracy: 2.6558
#
# Epoch 00006: val_loss did not improve from 0.14524
# Epoch 7/1000
#  - 1s - loss: 0.5714 - accuracy: 0.6845 - val_loss: 0.1503 - val_accuracy: 2.6424
#
# Epoch 00007: val_loss did not improve from 0.14524
# Epoch 8/1000
#  - 0s - loss: 0.5701 - accuracy: 0.6830 - val_loss: 0.1522 - val_accuracy: 2.6310
#
# Epoch 00008: val_loss did not improve from 0.14524
# Epoch 9/1000
#  - 1s - loss: 0.5713 - accuracy: 0.6832 - val_loss: 0.1601 - val_accuracy: 2.5449
#
# Epoch 00009: val_loss did not improve from 0.14524
# Epoch 10/1000
#  - 0s - loss: 0.5706 - accuracy: 0.6849 - val_loss: 0.1585 - val_accuracy: 2.5698
#
# Epoch 00010: val_loss did not improve from 0.14524
# Epoch 11/1000
#  - 1s - loss: 0.5704 - accuracy: 0.6843 - val_loss: 0.1560 - val_accuracy: 2.5813
#
# Epoch 00011: val_loss did not improve from 0.14524
# Epoch 12/1000
#  - 0s - loss: 0.5696 - accuracy: 0.6835 - val_loss: 0.1530 - val_accuracy: 2.6119
#
# Epoch 00012: val_loss did not improve from 0.14524
# Epoch 13/1000
#  - 0s - loss: 0.5696 - accuracy: 0.6866 - val_loss: 0.1530 - val_accuracy: 2.6119
#
# Epoch 00013: val_loss did not improve from 0.14524
# Epoch 14/1000
#  - 1s - loss: 0.5697 - accuracy: 0.6843 - val_loss: 0.1631 - val_accuracy: 2.5258
#
# Epoch 00014: val_loss did not improve from 0.14524
# Epoch 15/1000
#  - 0s - loss: 0.5694 - accuracy: 0.6843 - val_loss: 0.1675 - val_accuracy: 2.4608
#
# Epoch 00015: val_loss did not improve from 0.14524
# Epoch 16/1000
#  - 0s - loss: 0.5692 - accuracy: 0.6844 - val_loss: 0.1749 - val_accuracy: 2.3767
#
# Epoch 00016: val_loss did not improve from 0.14524
# Epoch 17/1000
#  - 1s - loss: 0.5694 - accuracy: 0.6841 - val_loss: 0.1785 - val_accuracy: 2.3595
#
# Epoch 00017: val_loss did not improve from 0.14524
# Epoch 18/1000
#  - 1s - loss: 0.5693 - accuracy: 0.6848 - val_loss: 0.1706 - val_accuracy: 2.4340
#
# Epoch 00018: val_loss did not improve from 0.14524
# Epoch 19/1000
#  - 1s - loss: 0.5692 - accuracy: 0.6844 - val_loss: 0.1668 - val_accuracy: 2.4187
#
# Epoch 00019: val_loss did not improve from 0.14524
# Epoch 20/1000
#  - 0s - loss: 0.5691 - accuracy: 0.6845 - val_loss: 0.1655 - val_accuracy: 2.4799
#
# Epoch 00020: val_loss did not improve from 0.14524
# Epoch 21/1000
#  - 0s - loss: 0.5689 - accuracy: 0.6846 - val_loss: 0.1607 - val_accuracy: 2.5296
#
# Epoch 00021: val_loss did not improve from 0.14524
# Epoch 22/1000
#  - 1s - loss: 0.5687 - accuracy: 0.6848 - val_loss: 0.1605 - val_accuracy: 2.5124
#
# Epoch 00022: val_loss did not improve from 0.14524
# Epoch 23/1000
#  - 0s - loss: 0.5688 - accuracy: 0.6858 - val_loss: 0.1612 - val_accuracy: 2.4895
#
# Epoch 00023: val_loss did not improve from 0.14524
# Epoch 24/1000
#  - 1s - loss: 0.5680 - accuracy: 0.6856 - val_loss: 0.1627 - val_accuracy: 2.5048
#
# Epoch 00024: val_loss did not improve from 0.14524
# Epoch 25/1000
#  - 1s - loss: 0.5689 - accuracy: 0.6854 - val_loss: 0.1688 - val_accuracy: 2.4685
#
# Epoch 00025: val_loss did not improve from 0.14524
# Epoch 26/1000
#  - 1s - loss: 0.5677 - accuracy: 0.6866 - val_loss: 0.1923 - val_accuracy: 2.2581
#
# Epoch 00026: val_loss did not improve from 0.14524
# Epoch 27/1000
#  - 0s - loss: 0.5690 - accuracy: 0.6862 - val_loss: 0.1973 - val_accuracy: 2.1855
#
# Epoch 00027: val_loss did not improve from 0.14524
# Epoch 28/1000
#  - 0s - loss: 0.5685 - accuracy: 0.6856 - val_loss: 0.1993 - val_accuracy: 2.1721
#
# Epoch 00028: val_loss did not improve from 0.14524
# Epoch 29/1000
#  - 0s - loss: 0.5684 - accuracy: 0.6848 - val_loss: 0.1929 - val_accuracy: 2.1989
#
# Epoch 00029: val_loss did not improve from 0.14524
# Epoch 30/1000
#  - 0s - loss: 0.5683 - accuracy: 0.6850 - val_loss: 0.1769 - val_accuracy: 2.3002
#
# Epoch 00030: val_loss did not improve from 0.14524
# Epoch 31/1000
#  - 1s - loss: 0.5685 - accuracy: 0.6868 - val_loss: 0.1595 - val_accuracy: 2.4876
#
# Epoch 00031: val_loss did not improve from 0.14524
# Epoch 32/1000
#  - 0s - loss: 0.5682 - accuracy: 0.6853 - val_loss: 0.1501 - val_accuracy: 2.6329
#
# Epoch 00032: val_loss did not improve from 0.14524
# Epoch 33/1000
#  - 1s - loss: 0.5672 - accuracy: 0.6864 - val_loss: 0.1534 - val_accuracy: 2.5870
#
# Epoch 00033: val_loss did not improve from 0.14524
# Epoch 34/1000
#  - 1s - loss: 0.5675 - accuracy: 0.6839 - val_loss: 0.1692 - val_accuracy: 2.4704
#
# Epoch 00034: val_loss did not improve from 0.14524
# Epoch 35/1000
#  - 1s - loss: 0.5675 - accuracy: 0.6866 - val_loss: 0.1997 - val_accuracy: 2.3021
#
# Epoch 00035: val_loss did not improve from 0.14524
# Epoch 36/1000
#  - 0s - loss: 0.5680 - accuracy: 0.6839 - val_loss: 0.1901 - val_accuracy: 2.3365
#
# Epoch 00036: val_loss did not improve from 0.14524
# Epoch 37/1000
#  - 0s - loss: 0.5678 - accuracy: 0.6854 - val_loss: 0.1771 - val_accuracy: 2.4015
#
# Epoch 00037: val_loss did not improve from 0.14524
# Epoch 38/1000
#  - 0s - loss: 0.5682 - accuracy: 0.6836 - val_loss: 0.1602 - val_accuracy: 2.5373
#
# Epoch 00038: val_loss did not improve from 0.14524
# Epoch 39/1000
#  - 0s - loss: 0.5676 - accuracy: 0.6859 - val_loss: 0.1675 - val_accuracy: 2.4971
#
# Epoch 00039: val_loss did not improve from 0.14524
# Epoch 40/1000
#  - 1s - loss: 0.5663 - accuracy: 0.6853 - val_loss: 0.1604 - val_accuracy: 2.5182
#
# Epoch 00040: val_loss did not improve from 0.14524
# Epoch 41/1000
#  - 0s - loss: 0.5674 - accuracy: 0.6855 - val_loss: 0.1578 - val_accuracy: 2.5220
#
# Epoch 00041: val_loss did not improve from 0.14524
# Epoch 42/1000
#  - 1s - loss: 0.5679 - accuracy: 0.6844 - val_loss: 0.1583 - val_accuracy: 2.5545
#
# Epoch 00042: val_loss did not improve from 0.14524
# Epoch 43/1000
#  - 0s - loss: 0.5680 - accuracy: 0.6854 - val_loss: 0.1583 - val_accuracy: 2.5239
#
# Epoch 00043: val_loss did not improve from 0.14524
# Epoch 44/1000
#  - 1s - loss: 0.5669 - accuracy: 0.6862 - val_loss: 0.1648 - val_accuracy: 2.4933
#
# Epoch 00044: val_loss did not improve from 0.14524
# Epoch 45/1000
#  - 0s - loss: 0.5661 - accuracy: 0.6865 - val_loss: 0.1671 - val_accuracy: 2.4493
#
# Epoch 00045: val_loss did not improve from 0.14524
# Epoch 46/1000
#  - 1s - loss: 0.5670 - accuracy: 0.6862 - val_loss: 0.1573 - val_accuracy: 2.5430
#
# Epoch 00046: val_loss did not improve from 0.14524
# Epoch 47/1000
#  - 0s - loss: 0.5669 - accuracy: 0.6868 - val_loss: 0.1546 - val_accuracy: 2.5774
#
# Epoch 00047: val_loss did not improve from 0.14524
# Epoch 48/1000
#  - 1s - loss: 0.5663 - accuracy: 0.6867 - val_loss: 0.1684 - val_accuracy: 2.4359
#
# Epoch 00048: val_loss did not improve from 0.14524
# Epoch 49/1000
#  - 0s - loss: 0.5662 - accuracy: 0.6865 - val_loss: 0.1837 - val_accuracy: 2.3442
#
# Epoch 00049: val_loss did not improve from 0.14524
# Epoch 50/1000
#  - 0s - loss: 0.5664 - accuracy: 0.6874 - val_loss: 0.1828 - val_accuracy: 2.3709
#
# Epoch 00050: val_loss did not improve from 0.14524
# Epoch 51/1000
#  - 0s - loss: 0.5667 - accuracy: 0.6852 - val_loss: 0.1875 - val_accuracy: 2.3403
#
# Epoch 00051: val_loss did not improve from 0.14524
# Epoch 52/1000
#  - 1s - loss: 0.5659 - accuracy: 0.6878 - val_loss: 0.1889 - val_accuracy: 2.3767
#
# Epoch 00052: val_loss did not improve from 0.14524
# test_result.shape : (1, 2)
# total_result.shape : (2092, 1, 2)
#
# y_test[:5] : [1 0 0 1 0]
# y_score[:5] : [[0.5472768 ]
#  [0.51651144]
#  [0.5285524 ]
#  [0.5743    ]
#  [0.5384113 ]]
# y_test.shape : (2092, 1)
# y_score.shape : (2092, 1)
# len(y_test) : 2092
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:734: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [1.9733484e-06, 1.9823703e-06, 2.049479e-06, 2.229738e-06, 2.1815324e-06, 1.9921235e-06, 1.9162146e-06, 2.0619177e-06, 2.124027e-06, 2.2666427e-06, 2.1940948e-06, 2.105944e-06, 2.247646e-06, 2.2667537e-06, 1.993408e-06, 2.0599455e-06, 2.087619e-06, 2.0587415e-06, 2.1855972e-06, 2.2795216e-06, 2.6090534e-06, 2.5840593e-06, 2.4822516e-06, 2.639987e-06, 2.9331127e-06, 3.4966122e-06, 3.336542e-06, 2.7468375e-06, 2.648722e-06, 2.9469873e-06, 2.7772744e-06, 3.137577e-06, 3.2047742e-06, 3.5274347e-06, 3.8341e-06, 3.7081643e-06, 3.6599065e-06, 3.8321605e-06, 3.7084312e-06, 3.4125303e-06, 3.1461798e-06, 3.2256262e-06, 3.0812723e-06, 3.0851165e-06, 3.1116315e-06, 3.3975862e-06, 3.6995862e-06, 3.5305022e-06, 3.7024636e-06, 4.370363e-06, 4.1126546e-06, 4.4850176e-06, 4.504711e-06, 4.649815e-06, 4.8855823e-06, 4.903752e-06, 5.233764e-06, 5.2369946e-06, 5.207534e-06, 5.8703076e-06, 5.88509e-06, 6.009589e-06, 6.4000087e-06, 5.8426695e-06, 6.500194e-06, 5.5323294e-06, 5.2600576e-06, 5.315735e-06, 6.2099284e-06, 6.7471806e-06, 6.767483e-06, 6.660464e-06, 6.4443675e-06, 6.2832455e-06, 8.220877e-06, 7.940487e-06, 6.891919e-06, 6.963452e-06, 6.9830044e-06, 6.5529584e-06, 6.260044e-06, 6.826712e-06, 7.955428e-06, 8.828125e-06, 8.88398e-06, 9.29737e-06, 9.156942e-06, 1.058334e-05, 1.0973723e-05, 1.065691e-05, 1.1170182e-05, 1.0348784e-05, 1.1885998e-05, 1.3736778e-05, 1.3004608e-05, 1.2261972e-05, 1.215756e-05, 1.1188938e-05, 1.21268395e-05, 1.2865189e-05, 1.1883495e-05, 1.6492295e-05, 1.592483e-05, 1.7429105e-05, 2.0305622e-05, 1.8818344e-05, 2.010945e-05, 1.9236179e-05, 1.897917e-05, 2.0817364e-05, 2.1310954e-05, 1.8787627e-05, 2.2275766e-05, 2.4816964e-05, 2.7690083e-05, 2.8995944e-05, 2.572383e-05, 3.8266022e-05, 3.9067487e-05, 4.2496893e-05, 3.838952e-05, 4.158262e-05, 4.4283428e-05, 4.881152e-05, 4.986202e-05, 5.2032374e-05, 5.6836907e-05, 5.8648813e-05, 5.0190076e-05, 4.9844304e-05, 5.0101833e-05, 4.686205e-05, 4.6177014e-05, 4.5185796e-05, 3.672117e-05, 4.1953077e-05, 4.210701e-05, 4.1294596e-05, 3.8950762e-05, 4.5177465e-05, 4.475722e-05, 4.4081386e-05, 4.433252e-05, 3.939032e-05, 4.359781e-05, 4.8327216e-05, 4.7425106e-05, 4.578169e-05, 4.1874206e-05, 3.780204e-05, 3.5930352e-05, 3.527855e-05, 3.3336517e-05, 4.148916e-05, 4.1233507e-05, 4.182911e-05, 3.7326823e-05, 3.3709457e-05, 3.382596e-05, 3.667845e-05, 3.381461e-05, 3.489925e-05, 4.043215e-05, 3.266316e-05, 3.5285557e-05, 3.3785807e-05, 3.070632e-05, 2.6031688e-05, 2.2535345e-05, 2.5589341e-05, 1.842607e-05, 1.9845207e-05, 2.2608036e-05, 2.3092181e-05, 2.2568282e-05, 2.4226558e-05, 2.378362e-05, 2.6037555e-05, 3.0110601e-05, 3.1522664e-05, 2.7137443e-05, 3.5263358e-05, 3.1902007e-05, 3.6148467e-05, 3.139244e-05, 3.3927383e-05, 3.776129e-05, 4.0250987e-05, 3.793718e-05, 3.5225577e-05, 4.510252e-05, 4.052594e-05, 4.169511e-05, 4.6254238e-05, 4.617131e-05, 4.6932648e-05, 4.6452147e-05, 4.9914168e-05, 5.2332423e-05, 5.4964414e-05, 6.0510265e-05, 7.0785114e-05, 7.117927e-05, 7.535999e-05, 6.8245135e-05, 7.005002e-05, 7.313491e-05, 7.0843205e-05, 7.0663606e-05, 5.7557485e-05, 5.792343e-05, 5.40452e-05, 5.772667e-05, 6.249077e-05, 6.1611194e-05, 5.8531627e-05, 8.8128894e-05, 9.7662145e-05, 9.8025994e-05, 0.00010217552, 9.786619e-05, 0.00010163535, 0.0001102311, 9.673782e-05, 9.3928305e-05, 8.9625486e-05, 9.549312e-05, 9.578066e-05, 9.5316e-05, 0.000100373494, 0.00010629611, 0.000100533296, 6.314143e-05, 6.890501e-05, 6.751498e-05, 6.995824e-05, 7.170295e-05, 6.959345e-05, 6.832606e-05, 8.025379e-05, 6.713005e-05, 6.324635e-05, 5.843707e-05, 5.3395663e-05, 4.7719986e-05, 4.006176e-05, 3.867351e-05, 3.750447e-05, 3.8980932e-05, 4.1736104e-05, 3.8265774e-05, 3.577026e-05, 3.523108e-05, 3.1645217e-05, 3.01906e-05, 3.3152326e-05, 3.219614e-05, 3.5939607e-05, 3.5369107e-05, 3.5124518e-05, 3.615681e-05, 4.0470757e-05, 3.472797e-05, 3.5246794e-05, 2.8802828e-05, 2.92748e-05, 2.8957804e-05, 3.071191e-05, 2.995718e-05, 2.9454379e-05, 3.0018926e-05, 3.2996344e-05, 3.069663e-05, 3.154238 ...

# %%
model = keras.models.load_model(ckpt_path + model_name)
for l_i, layer in enumerate(model.layers):
  print(layer, layer.trainable)
            # if l_i != len(model.layers) - 1:
            #   layer.trainable = False
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f5afe5d2e50> False
# <keras.layers.recurrent.LSTM object at 0x7f5b0f96c290> True
# <keras.layers.advanced_activations.LeakyReLU object at 0x7f5afe5d3690> True
# <keras.layers.core.Dense object at 0x7f5afe5d2cd0> True
# <keras.layers.advanced_activations.LeakyReLU object at 0x7f5afe5d2050> True
# <keras.layers.normalization.BatchNormalization object at 0x7f5afe5d2550> True
# <keras.layers.core.Dense object at 0x7f5afe5d2710> True
# <keras.layers.advanced_activations.LeakyReLU object at 0x7f5afe5d27d0> True
# <keras.layers.core.Dense object at 0x7f5afe5d2790> True
# <keras.layers.advanced_activations.LeakyReLU object at 0x7f5afe5d2dd0> True
# <keras.layers.normalization.BatchNormalization object at 0x7f5afe5d2910> True
# <keras.layers.core.Dense object at 0x7f5afe5d2190> True
# <keras.layers.advanced_activations.LeakyReLU object at 0x7f5afe5d2d10> True
# <keras.layers.core.Dense object at 0x7f5afe5d2d90> True
# <keras.layers.advanced_activations.LeakyReLU object at 0x7f5afe5e46d0> True
# <keras.layers.core.Dropout object at 0x7f5afe5e47d0> True
# <keras.layers.core.Dense object at 0x7f5afe5e4bd0> True

# %%
total_result = np.array(total_result).reshape(-1, 2)
y_score = total_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test[:len(y_score)], y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test[:len(y_score)], y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test[:len(y_score)])
  test_pr_list = pr_test[:len(y_score)]
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.title(symbol_name)
plt.show()
# Out:
# y_test[:5] : [1 0 0 1 0]
# y_score[:5] : [[0.5472768 ]
#  [0.51651144]
#  [0.5285524 ]
#  [0.5743    ]
#  [0.5384113 ]]
# y_test.shape : (2092, 1)
# y_score.shape : (2092, 1)
# len(y_test) : 2092
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:64: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [1.9733484e-06, 1.9823703e-06, 2.049479e-06, 2.229738e-06, 2.1815324e-06, 1.9921235e-06, 1.9162146e-06, 2.0619177e-06, 2.124027e-06, 2.2666427e-06, 2.1940948e-06, 2.105944e-06, 2.247646e-06, 2.2667537e-06, 1.993408e-06, 2.0599455e-06, 2.087619e-06, 2.0587415e-06, 2.1855972e-06, 2.2795216e-06, 2.6090534e-06, 2.5840593e-06, 2.4822516e-06, 2.639987e-06, 2.9331127e-06, 3.4966122e-06, 3.336542e-06, 2.7468375e-06, 2.648722e-06, 2.9469873e-06, 2.7772744e-06, 3.137577e-06, 3.2047742e-06, 3.5274347e-06, 3.8341e-06, 3.7081643e-06, 3.6599065e-06, 3.8321605e-06, 3.7084312e-06, 3.4125303e-06, 3.1461798e-06, 3.2256262e-06, 3.0812723e-06, 3.0851165e-06, 3.1116315e-06, 3.3975862e-06, 3.6995862e-06, 3.5305022e-06, 3.7024636e-06, 4.370363e-06, 4.1126546e-06, 4.4850176e-06, 4.504711e-06, 4.649815e-06, 4.8855823e-06, 4.903752e-06, 5.233764e-06, 5.2369946e-06, 5.207534e-06, 5.8703076e-06, 5.88509e-06, 6.009589e-06, 6.4000087e-06, 5.8426695e-06, 6.500194e-06, 5.5323294e-06, 5.2600576e-06, 5.315735e-06, 6.2099284e-06, 6.7471806e-06, 6.767483e-06, 6.660464e-06, 6.4443675e-06, 6.2832455e-06, 8.220877e-06, 7.940487e-06, 6.891919e-06, 6.963452e-06, 6.9830044e-06, 6.5529584e-06, 6.260044e-06, 6.826712e-06, 7.955428e-06, 8.828125e-06, 8.88398e-06, 9.29737e-06, 9.156942e-06, 1.058334e-05, 1.0973723e-05, 1.065691e-05, 1.1170182e-05, 1.0348784e-05, 1.1885998e-05, 1.3736778e-05, 1.3004608e-05, 1.2261972e-05, 1.215756e-05, 1.1188938e-05, 1.21268395e-05, 1.2865189e-05, 1.1883495e-05, 1.6492295e-05, 1.592483e-05, 1.7429105e-05, 2.0305622e-05, 1.8818344e-05, 2.010945e-05, 1.9236179e-05, 1.897917e-05, 2.0817364e-05, 2.1310954e-05, 1.8787627e-05, 2.2275766e-05, 2.4816964e-05, 2.7690083e-05, 2.8995944e-05, 2.572383e-05, 3.8266022e-05, 3.9067487e-05, 4.2496893e-05, 3.838952e-05, 4.158262e-05, 4.4283428e-05, 4.881152e-05, 4.986202e-05, 5.2032374e-05, 5.6836907e-05, 5.8648813e-05, 5.0190076e-05, 4.9844304e-05, 5.0101833e-05, 4.686205e-05, 4.6177014e-05, 4.5185796e-05, 3.672117e-05, 4.1953077e-05, 4.210701e-05, 4.1294596e-05, 3.8950762e-05, 4.5177465e-05, 4.475722e-05, 4.4081386e-05, 4.433252e-05, 3.939032e-05, 4.359781e-05, 4.8327216e-05, 4.7425106e-05, 4.578169e-05, 4.1874206e-05, 3.780204e-05, 3.5930352e-05, 3.527855e-05, 3.3336517e-05, 4.148916e-05, 4.1233507e-05, 4.182911e-05, 3.7326823e-05, 3.3709457e-05, 3.382596e-05, 3.667845e-05, 3.381461e-05, 3.489925e-05, 4.043215e-05, 3.266316e-05, 3.5285557e-05, 3.3785807e-05, 3.070632e-05, 2.6031688e-05, 2.2535345e-05, 2.5589341e-05, 1.842607e-05, 1.9845207e-05, 2.2608036e-05, 2.3092181e-05, 2.2568282e-05, 2.4226558e-05, 2.378362e-05, 2.6037555e-05, 3.0110601e-05, 3.1522664e-05, 2.7137443e-05, 3.5263358e-05, 3.1902007e-05, 3.6148467e-05, 3.139244e-05, 3.3927383e-05, 3.776129e-05, 4.0250987e-05, 3.793718e-05, 3.5225577e-05, 4.510252e-05, 4.052594e-05, 4.169511e-05, 4.6254238e-05, 4.617131e-05, 4.6932648e-05, 4.6452147e-05, 4.9914168e-05, 5.2332423e-05, 5.4964414e-05, 6.0510265e-05, 7.0785114e-05, 7.117927e-05, 7.535999e-05, 6.8245135e-05, 7.005002e-05, 7.313491e-05, 7.0843205e-05, 7.0663606e-05, 5.7557485e-05, 5.792343e-05, 5.40452e-05, 5.772667e-05, 6.249077e-05, 6.1611194e-05, 5.8531627e-05, 8.8128894e-05, 9.7662145e-05, 9.8025994e-05, 0.00010217552, 9.786619e-05, 0.00010163535, 0.0001102311, 9.673782e-05, 9.3928305e-05, 8.9625486e-05, 9.549312e-05, 9.578066e-05, 9.5316e-05, 0.000100373494, 0.00010629611, 0.000100533296, 6.314143e-05, 6.890501e-05, 6.751498e-05, 6.995824e-05, 7.170295e-05, 6.959345e-05, 6.832606e-05, 8.025379e-05, 6.713005e-05, 6.324635e-05, 5.843707e-05, 5.3395663e-05, 4.7719986e-05, 4.006176e-05, 3.867351e-05, 3.750447e-05, 3.8980932e-05, 4.1736104e-05, 3.8265774e-05, 3.577026e-05, 3.523108e-05, 3.1645217e-05, 3.01906e-05, 3.3152326e-05, 3.219614e-05, 3.5939607e-05, 3.5369107e-05, 3.5124518e-05, 3.615681e-05, 4.0470757e-05, 3.472797e-05, 3.5246794e-05, 2.8802828e-05, 2.92748e-05, 2.8957804e-05, 3.071191e-05, 2.995718e-05, 2.9454379e-05, 3.0018926e-05, 3.2996344e-05, 3.069663e-05, 3.154238 ...

# %%
# model = FER_Model(input_shape=(45, 1))

period = 45
symbol_name = 'SXPUSDT'

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_%s_lstm_close_updown_pr_robust_trial_re_%s_timesplit.h5' % (period, symbol_name)

# model_name = 'classifier_%s_close_updown_pr_theta_shuffle_without_back_03.h5' % period

model = keras.models.load_model(ckpt_path + model_name)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
for l_i, layer in enumerate(model.layers):

  if l_i != len(model.layers) - 1:
    layer.trainable = False

  print(layer, layer.trainable)

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %% [markdown]
# ### **Training**

# %%
org_x_test = x_test
org_y_test = y_test
org_pr_test = pr_test

# %%
x_test = org_x_test
y_test = org_y_test
pr_test = org_pr_test

# %%
concat_x = np.vstack((org_x_test, new_input_x))
concat_y = np.vstack((org_y_test, np.where(new_input_pr > 1, 1, 0)))
concat_pr = np.vstack((org_pr_test, new_input_pr))

# %%
x_test = new_input_x
y_test = np.where(new_input_pr > 1, 1, 0)
pr_test = new_input_pr

# %%
# print(pred_pr_list)
for pr in pred_pr_list:
  if pr != 1:
    print(pr)

# %%
plt.figure(figsize=(50, 5))
plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test):len(org_pr_test) + 10])
# plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test) - 10:len(org_pr_test) + 10])
plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
# plt.axvline(len(org_pr_test), linestyle='--', color='r')
plt.show()

# %%
# plt.show()
# plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
