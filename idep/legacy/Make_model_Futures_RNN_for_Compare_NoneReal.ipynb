# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %tensorflow_version 2.x
# import tensorflow as tf
# print(tf.__version__)

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %matplotlib inline
import random

# %tensorflow_version 1.x
import tensorflow as tf

seed = 1203
np.random.seed(seed)
random.seed(seed)
# tf.random.set_random_seed(seed)
# tf.random.set_seed(seed)

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.model_selection import train_test_split

# Data Class Weight
from sklearn.utils import class_weight
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard



def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    #             LSTM Version            #
    # net = layers.LSTM(10, return_sequences=False)(visible)
    net = layers.Dense(64, activation='relu')(visible)
    # net = layers.Dropout(0.2)(net)


    # net = layers.LSTM(5, return_sequences=True)(net)
    net = layers.Dense(32, activation='relu')(net)
    net = layers.Dropout(0.2)(net)

    # net = layers.LSTM(5, return_sequences=True)(visible)
    # net = layers.Dense(16, activation='relu')(net)
    # # net = layers.Dropout(0.2)(net)

    # net = layers.LSTM(1, return_sequences=False)(visible)
    # net = layers.Dense(8, activation='relu')(net)
    # net = layers.Dropout(0.5)(net)

    # net = layers.Conv2D(64, kernel_size=3, padding='same')(visible)
    # net = layers.Activation('relu')(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    # shortcut_1 = net

    # net = layers.Conv2D(32, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    # shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
    
    return model

# input_data_length = int(input('input_data_length : '))
input_data_length = 30
num_classes = 2

gdrive_path = '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/'

# model_num = 138
model_range = range(260, 301)
# model_range = range(219, 260)
# break

for model_num in model_range:

  try:
    rt_Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num - 41))
    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)


    #       dataset 분리      #
    # dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    # dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    Made_X_ = Made_X_[-len(rt_Made_X_):]
    Made_Y = Made_Y[-len(rt_Made_X_):]
    # Made_X = Made_X_[:, :, [-4]]
    Made_X = Made_X_[:, :, :4]
    print(Made_X.shape)
    print(Made_Y.shape)
    # break

    # plt.plot(rt_Made_X_[:, -1, 3])
    # plt.plot(Made_X_[:, -1, 3])
    # plt.show()

    row = Made_X.shape[1]
    col = Made_X.shape[2]

    X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                      shuffle=False)

    X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
    X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)
    print(X_train.shape)
    print(X_val.shape)

    # print(Y_train[:, 0])
    class_weights = class_weight.compute_class_weight('balanced', 
                                                      np.unique(Y_train[:, 0]),
                                                      Y_train[:, 0])
    class_weights = dict(enumerate(class_weights))
    print(class_weights)
    # quit()

    Y_train = Y_train.astype('float32')
    Y_val = Y_val.astype('float32')
    # print(Y_val[:5])
    Y_train = np_utils.to_categorical(Y_train, num_classes)
    Y_val = np_utils.to_categorical(Y_val, num_classes)
    # print(Y_val[:5])
    # break
    print(Y_train.shape)
    print(Y_val.shape)

    # datagen = ImageDataGenerator( 
    # #     rotation_range = 60,
    # #     zoom_range = 0.6,
    # #     shear_range = 0.6,
    # #     horizontal_flip = True,
    # #     width_shift_range=0.6,
    # #     height_shift_range=0.6,
    #     fill_mode = 'nearest'
    #     )

    # testgen = ImageDataGenerator( 
    #     )
    # datagen.fit(X_train)
    batch_size = 26

    # for X_batch, _ in datagen.flow(X_train, Y_train, batch_size=9):
    #     for i in range(0, 9): 
    #         pyplot.axis('off') 
    #         pyplot.subplot(330 + 1 + i) 
    #         pyplot.imshow(X_batch[i].reshape(input_data_length, col))
    #     pyplot.axis('off') 
    #     pyplot.show() 
    #     break
        
    # train_flow = datagen.flow(X_train, Y_train, batch_size=batch_size) 
    # val_flow = testgen.flow(X_val, Y_val, batch_size=batch_size) 

    model = FER_Model((row, col))
    # from keras.models import load_model
    # model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_rnn_macdonly.hdf5' % (input_data_length, model_num))
    opt = Adam(lr=0.0001, decay=1e-6)
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
      
        
    filepath = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (input_data_length, model_num)
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
    checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                              histogram_freq=0,
                              write_graph=True,
                              write_images=True)
    checkpoint3 = EarlyStopping(monitor='val_accuracy', patience=200)
    callbacks_list = [checkpoint, checkpoint2, checkpoint3]

    # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

    # we iterate 200 times over the entire training set
    num_epochs = 1000
    history = model.fit(X_train, Y_train,
                        steps_per_epoch=int(len(X_train) / batch_size), 
                        epochs=num_epochs,  
                        verbose=2,  
                        callbacks=callbacks_list,
                        class_weight=class_weights,
                        validation_data=(X_val, Y_val),  
                        validation_steps=int(len(X_val) / batch_size),
                        shuffle=False)
    
  except Exception as e:
    print('Error occured :', e)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Epoch 00093: val_accuracy did not improve from 0.70358
# 55/55 - 0s - loss: 0.6974 - accuracy: 0.5901 - val_loss: 0.6550 - val_accuracy: 0.5081
# Epoch 94/1000
#
# Epoch 00094: val_accuracy did not improve from 0.70358
# 55/55 - 0s - loss: 0.6848 - accuracy: 0.5984 - val_loss: 0.6549 - val_accuracy: 0.5114
# Epoch 95/1000
#
# Epoch 00095: val_accuracy did not improve from 0.70358
# 55/55 - 0s - loss: 0.6791 - accuracy: 0.5874 - val_loss: 0.6547 - val_accuracy: 0.5391
# Epoch 96/1000
#
# Epoch 00096: val_accuracy did not improve from 0.70358
# 55/55 - 0s - loss: 0.6802 - accuracy: 0.5949 - val_loss: 0.6537 - val_accuracy: 0.5863
# Epoch 97/1000
#
# Epoch 00097: val_accuracy did not improve from 0.70358
# 55/55 - 0s - loss: 0.6810 - accuracy: 0.5936 - val_loss: 0.6528 - val_accuracy: 0.6450
# Epoch 98/1000
#
# Epoch 00098: val_accuracy did not improve from 0.70358
# 55/55 - 0s - loss: 0.6820 - accuracy: 0.5963 - val_loss: 0.6527 - val_accuracy: 0.6515
# Epoch 99/1000
#
# Epoch 00099: val_accuracy did not improve from 0.70358
# 55/55 - 0s - loss: 0.6826 - accuracy: 0.5990 - val_loss: 0.6522 - val_accuracy: 0.6906
# Epoch 100/1000
#
# Epoch 00100: val_accuracy improved from 0.70358 to 0.70521, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 1s - loss: 0.6845 - accuracy: 0.5984 - val_loss: 0.6520 - val_accuracy: 0.7052
# Epoch 101/1000
#
# Epoch 00101: val_accuracy improved from 0.70521 to 0.72964, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6838 - accuracy: 0.5977 - val_loss: 0.6529 - val_accuracy: 0.7296
# Epoch 102/1000
#
# Epoch 00102: val_accuracy improved from 0.72964 to 0.76059, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6847 - accuracy: 0.5970 - val_loss: 0.6530 - val_accuracy: 0.7606
# Epoch 103/1000
#
# Epoch 00103: val_accuracy improved from 0.76059 to 0.77687, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6880 - accuracy: 0.5977 - val_loss: 0.6535 - val_accuracy: 0.7769
# Epoch 104/1000
#
# Epoch 00104: val_accuracy improved from 0.77687 to 0.80619, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6899 - accuracy: 0.6100 - val_loss: 0.6536 - val_accuracy: 0.8062
# Epoch 105/1000
#
# Epoch 00105: val_accuracy improved from 0.80619 to 0.81433, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6867 - accuracy: 0.6100 - val_loss: 0.6538 - val_accuracy: 0.8143
# Epoch 106/1000
#
# Epoch 00106: val_accuracy improved from 0.81433 to 0.82573, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6832 - accuracy: 0.5997 - val_loss: 0.6532 - val_accuracy: 0.8257
# Epoch 107/1000
#
# Epoch 00107: val_accuracy improved from 0.82573 to 0.84039, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6931 - accuracy: 0.6080 - val_loss: 0.6526 - val_accuracy: 0.8404
# Epoch 108/1000
#
# Epoch 00108: val_accuracy improved from 0.84039 to 0.85179, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6837 - accuracy: 0.6106 - val_loss: 0.6514 - val_accuracy: 0.8518
# Epoch 109/1000
#
# Epoch 00109: val_accuracy improved from 0.85179 to 0.86808, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6790 - accuracy: 0.6175 - val_loss: 0.6500 - val_accuracy: 0.8681
# Epoch 110/1000
#
# Epoch 00110: val_accuracy did not improve from 0.86808
# 55/55 - 0s - loss: 0.6974 - accuracy: 0.6107 - val_loss: 0.6494 - val_accuracy: 0.8518
# Epoch 111/1000
#
# Epoch 00111: val_accuracy did not improve from 0.86808
# 55/55 - 0s - loss: 0.6969 - accuracy: 0.6169 - val_loss: 0.6494 - val_accuracy: 0.8208
# Epoch 112/1000
#
# Epoch 00112: val_accuracy did not improve from 0.86808
# 55/55 - 0s - loss: 0.6768 - accuracy: 0.6271 - val_loss: 0.6489 - val_accuracy: 0.8127
# Epoch 113/1000
#
# Epoch 00113: val_accuracy did not improve from 0.86808
# 55/55 - 0s - loss: 0.6763 - accuracy: 0.6258 - val_loss: 0.6482 - val_accuracy: 0.7997
# Epoch 114/1000
#
# Epoch 00114: val_accuracy did not improve from 0.86808
# 55/55 - 0s - loss: 0.6767 - accuracy: 0.6196 - val_loss: 0.6476 - val_accuracy: 0.8127
# Epoch 115/1000
#
# Epoch 00115: val_accuracy did not improve from 0.86808
# 55/55 - 0s - loss: 0.6775 - accuracy: 0.6271 - val_loss: 0.6466 - val_accuracy: 0.8208
# Epoch 116/1000
#
# Epoch 00116: val_accuracy did not improve from 0.86808
# 55/55 - 0s - loss: 0.6769 - accuracy: 0.6299 - val_loss: 0.6462 - val_accuracy: 0.8290
# Epoch 117/1000
#
# Epoch 00117: val_accuracy did not improve from 0.86808
# 55/55 - 0s - loss: 0.6762 - accuracy: 0.6333 - val_loss: 0.6457 - val_accuracy: 0.8436
# Epoch 118/1000
#
# Epoch 00118: val_accuracy did not improve from 0.86808
# 55/55 - 0s - loss: 0.6767 - accuracy: 0.6278 - val_loss: 0.6442 - val_accuracy: 0.8599
# Epoch 119/1000
#
# Epoch 00119: val_accuracy improved from 0.86808 to 0.88111, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6788 - accuracy: 0.6244 - val_loss: 0.6432 - val_accuracy: 0.8811
# Epoch 120/1000
#
# Epoch 00120: val_accuracy improved from 0.88111 to 0.89577, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6865 - accuracy: 0.6278 - val_loss: 0.6420 - val_accuracy: 0.8958
# Epoch 121/1000
#
# Epoch 00121: val_accuracy did not improve from 0.89577
# 55/55 - 0s - loss: 0.6769 - accuracy: 0.6402 - val_loss: 0.6419 - val_accuracy: 0.8958
# Epoch 122/1000
#
# Epoch 00122: val_accuracy improved from 0.89577 to 0.89902, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.6862 - accuracy: 0.6319 - val_loss: 0.6417 - val_accuracy: 0.8990
# Epoch 123/1000
#
# Epoch 00123: val_accuracy did not improve from 0.89902
# 55/55 - 0s - loss: 0.6823 - accuracy: 0.6340 - val_loss: 0.6412 - val_accuracy: 0.8974
# Epoch 124/1000
#
# Epoch 00124: val_accuracy did not improve from 0.89902
# 55/55 - 0s - loss: 0.6775 - accuracy: 0.6415 - val_loss: 0.6397 - val_accuracy: 0.8941
# Epoch 125/1000
#
# Epoch 00125: val_accuracy did not improve from 0.89902
# 55/55 - 0s - loss: 0.7097 - accuracy: 0.6292 - val_loss: 0.6406 - val_accuracy: 0.8974
# Epoch 126/1000
#
# Epoch 00126: val_accuracy improved from 0.89902 to 0.90228, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5
# 55/55 - 0s - loss: 0.7056 - accuracy: 0.6313 - val_loss: 0.6417 - val_accuracy: 0.9023
# Epoch 127/1000
#
# Epoch 00127: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6950 - accuracy: 0.6319 - val_loss: 0.6420 - val_accuracy: 0.8681
# Epoch 128/1000
#
# Epoch 00128: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6757 - accuracy: 0.6402 - val_loss: 0.6433 - val_accuracy: 0.8453
# Epoch 129/1000
#
# Epoch 00129: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6748 - accuracy: 0.6456 - val_loss: 0.6438 - val_accuracy: 0.8371
# Epoch 130/1000
#
# Epoch 00130: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6779 - accuracy: 0.6525 - val_loss: 0.6433 - val_accuracy: 0.8176
# Epoch 131/1000
#
# Epoch 00131: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6770 - accuracy: 0.6504 - val_loss: 0.6439 - val_accuracy: 0.8160
# Epoch 132/1000
#
# Epoch 00132: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6763 - accuracy: 0.6518 - val_loss: 0.6432 - val_accuracy: 0.8160
# Epoch 133/1000
#
# Epoch 00133: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6760 - accuracy: 0.6491 - val_loss: 0.6432 - val_accuracy: 0.8160
# Epoch 134/1000
#
# Epoch 00134: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6787 - accuracy: 0.6532 - val_loss: 0.6433 - val_accuracy: 0.8176
# Epoch 135/1000
#
# Epoch 00135: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6784 - accuracy: 0.6546 - val_loss: 0.6433 - val_accuracy: 0.8306
# Epoch 136/1000
#
# Epoch 00136: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6755 - accuracy: 0.6580 - val_loss: 0.6430 - val_accuracy: 0.8371
# Epoch 137/1000
#
# Epoch 00137: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6771 - accuracy: 0.6518 - val_loss: 0.6425 - val_accuracy: 0.8469
# Epoch 138/1000
#
# Epoch 00138: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6813 - accuracy: 0.6573 - val_loss: 0.6406 - val_accuracy: 0.8795
# Epoch 139/1000
#
# Epoch 00139: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6851 - accuracy: 0.6518 - val_loss: 0.6403 - val_accuracy: 0.8893
# Epoch 140/1000
#
# Epoch 00140: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6758 - accuracy: 0.6669 - val_loss: 0.6404 - val_accuracy: 0.8990
# Epoch 141/1000
#
# Epoch 00141: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6763 - accuracy: 0.6648 - val_loss: 0.6414 - val_accuracy: 0.8958
# Epoch 142/1000
#
# Epoch 00142: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6748 - accuracy: 0.6655 - val_loss: 0.6403 - val_accuracy: 0.8941
# Epoch 143/1000
#
# Epoch 00143: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6765 - accuracy: 0.6566 - val_loss: 0.6389 - val_accuracy: 0.8909
# Epoch 144/1000
#
# Epoch 00144: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6768 - accuracy: 0.6484 - val_loss: 0.6379 - val_accuracy: 0.8876
# Epoch 145/1000
#
# Epoch 00145: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6761 - accuracy: 0.6546 - val_loss: 0.6371 - val_accuracy: 0.8827
# Epoch 146/1000
#
# Epoch 00146: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6773 - accuracy: 0.6614 - val_loss: 0.6362 - val_accuracy: 0.8779
# Epoch 147/1000
#
# Epoch 00147: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6964 - accuracy: 0.6655 - val_loss: 0.6364 - val_accuracy: 0.8811
# Epoch 148/1000
#
# Epoch 00148: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6807 - accuracy: 0.6655 - val_loss: 0.6353 - val_accuracy: 0.8827
# Epoch 149/1000
#
# Epoch 00149: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6751 - accuracy: 0.6772 - val_loss: 0.6347 - val_accuracy: 0.8811
# Epoch 150/1000
#
# Epoch 00150: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6762 - accuracy: 0.6737 - val_loss: 0.6352 - val_accuracy: 0.8811
# Epoch 151/1000
#
# Epoch 00151: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6782 - accuracy: 0.6683 - val_loss: 0.6346 - val_accuracy: 0.8713
# Epoch 152/1000
#
# Epoch 00152: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6789 - accuracy: 0.6690 - val_loss: 0.6346 - val_accuracy: 0.8616
# Epoch 153/1000
#
# Epoch 00153: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6788 - accuracy: 0.6621 - val_loss: 0.6333 - val_accuracy: 0.8518
# Epoch 154/1000
#
# Epoch 00154: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6818 - accuracy: 0.6690 - val_loss: 0.6320 - val_accuracy: 0.8518
# Epoch 155/1000
#
# Epoch 00155: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6815 - accuracy: 0.6690 - val_loss: 0.6320 - val_accuracy: 0.8518
# Epoch 156/1000
#
# Epoch 00156: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6812 - accuracy: 0.6724 - val_loss: 0.6326 - val_accuracy: 0.8485
# Epoch 157/1000
#
# Epoch 00157: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6838 - accuracy: 0.6751 - val_loss: 0.6336 - val_accuracy: 0.8485
# Epoch 158/1000
#
# Epoch 00158: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6848 - accuracy: 0.6847 - val_loss: 0.6341 - val_accuracy: 0.8485
# Epoch 159/1000
#
# Epoch 00159: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6808 - accuracy: 0.6875 - val_loss: 0.6340 - val_accuracy: 0.8485
# Epoch 160/1000
#
# Epoch 00160: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6816 - accuracy: 0.6765 - val_loss: 0.6338 - val_accuracy: 0.8485
# Epoch 161/1000
#
# Epoch 00161: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6882 - accuracy: 0.6827 - val_loss: 0.6335 - val_accuracy: 0.8485
# Epoch 162/1000
#
# Epoch 00162: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6803 - accuracy: 0.6902 - val_loss: 0.6316 - val_accuracy: 0.8485
# Epoch 163/1000
#
# Epoch 00163: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6745 - accuracy: 0.6971 - val_loss: 0.6305 - val_accuracy: 0.8485
# Epoch 164/1000
#
# Epoch 00164: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6925 - accuracy: 0.6888 - val_loss: 0.6290 - val_accuracy: 0.8485
# Epoch 165/1000
#
# Epoch 00165: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6927 - accuracy: 0.6916 - val_loss: 0.6282 - val_accuracy: 0.8485
# Epoch 166/1000
#
# Epoch 00166: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6722 - accuracy: 0.6991 - val_loss: 0.6290 - val_accuracy: 0.8485
# Epoch 167/1000
#
# Epoch 00167: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6728 - accuracy: 0.6991 - val_loss: 0.6275 - val_accuracy: 0.8485
# Epoch 168/1000
#
# Epoch 00168: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6736 - accuracy: 0.7012 - val_loss: 0.6270 - val_accuracy: 0.8485
# Epoch 169/1000
#
# Epoch 00169: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6754 - accuracy: 0.6984 - val_loss: 0.6262 - val_accuracy: 0.8485
# Epoch 170/1000
#
# Epoch 00170: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6736 - accuracy: 0.6984 - val_loss: 0.6257 - val_accuracy: 0.8485
# Epoch 171/1000
#
# Epoch 00171: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6733 - accuracy: 0.7005 - val_loss: 0.6243 - val_accuracy: 0.8485
# Epoch 172/1000
#
# Epoch 00172: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6746 - accuracy: 0.6971 - val_loss: 0.6236 - val_accuracy: 0.8485
# Epoch 173/1000
#
# Epoch 00173: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6763 - accuracy: 0.7005 - val_loss: 0.6221 - val_accuracy: 0.8485
# Epoch 174/1000
#
# Epoch 00174: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6839 - accuracy: 0.6984 - val_loss: 0.6222 - val_accuracy: 0.8485
# Epoch 175/1000
#
# Epoch 00175: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6708 - accuracy: 0.7080 - val_loss: 0.6206 - val_accuracy: 0.8485
# Epoch 176/1000
#
# Epoch 00176: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6838 - accuracy: 0.7012 - val_loss: 0.6199 - val_accuracy: 0.8485
# Epoch 177/1000
#
# Epoch 00177: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6784 - accuracy: 0.7066 - val_loss: 0.6182 - val_accuracy: 0.8485
# Epoch 178/1000
#
# Epoch 00178: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6741 - accuracy: 0.7053 - val_loss: 0.6165 - val_accuracy: 0.8485
# Epoch 179/1000
#
# Epoch 00179: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.7054 - accuracy: 0.6923 - val_loss: 0.6154 - val_accuracy: 0.8485
# Epoch 180/1000
#
# Epoch 00180: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.7026 - accuracy: 0.6936 - val_loss: 0.6166 - val_accuracy: 0.8485
# Epoch 181/1000
#
# Epoch 00181: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6925 - accuracy: 0.6971 - val_loss: 0.6181 - val_accuracy: 0.8485
# Epoch 182/1000
#
# Epoch 00182: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6715 - accuracy: 0.7114 - val_loss: 0.6194 - val_accuracy: 0.8518
# Epoch 183/1000
#
# Epoch 00183: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6715 - accuracy: 0.7108 - val_loss: 0.6198 - val_accuracy: 0.8518
# Epoch 184/1000
#
# Epoch 00184: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6745 - accuracy: 0.7101 - val_loss: 0.6205 - val_accuracy: 0.8518
# Epoch 185/1000
#
# Epoch 00185: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6738 - accuracy: 0.7053 - val_loss: 0.6215 - val_accuracy: 0.8518
# Epoch 186/1000
#
# Epoch 00186: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6710 - accuracy: 0.7101 - val_loss: 0.6206 - val_accuracy: 0.8567
# Epoch 187/1000
#
# Epoch 00187: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6716 - accuracy: 0.7101 - val_loss: 0.6198 - val_accuracy: 0.8518
# Epoch 188/1000
#
# Epoch 00188: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6757 - accuracy: 0.7039 - val_loss: 0.6210 - val_accuracy: 0.8485
# Epoch 189/1000
#
# Epoch 00189: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6748 - accuracy: 0.7114 - val_loss: 0.6200 - val_accuracy: 0.8518
# Epoch 190/1000
#
# Epoch 00190: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6718 - accuracy: 0.7108 - val_loss: 0.6189 - val_accuracy: 0.8518
# Epoch 191/1000
#
# Epoch 00191: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6715 - accuracy: 0.7114 - val_loss: 0.6183 - val_accuracy: 0.8485
# Epoch 192/1000
#
# Epoch 00192: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6769 - accuracy: 0.7080 - val_loss: 0.6165 - val_accuracy: 0.8518
# Epoch 193/1000
#
# Epoch 00193: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6818 - accuracy: 0.7066 - val_loss: 0.6166 - val_accuracy: 0.8485
# Epoch 194/1000
#
# Epoch 00194: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6694 - accuracy: 0.7121 - val_loss: 0.6161 - val_accuracy: 0.8485
# Epoch 195/1000
#
# Epoch 00195: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6710 - accuracy: 0.7135 - val_loss: 0.6159 - val_accuracy: 0.8485
# Epoch 196/1000
#
# Epoch 00196: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6711 - accuracy: 0.7121 - val_loss: 0.6146 - val_accuracy: 0.8485
# Epoch 197/1000
#
# Epoch 00197: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6707 - accuracy: 0.7025 - val_loss: 0.6141 - val_accuracy: 0.8485
# Epoch 198/1000
#
# Epoch 00198: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6718 - accuracy: 0.6977 - val_loss: 0.6112 - val_accuracy: 0.8485
# Epoch 199/1000
#
# Epoch 00199: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6713 - accuracy: 0.7108 - val_loss: 0.6105 - val_accuracy: 0.8485
# Epoch 200/1000
#
# Epoch 00200: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6717 - accuracy: 0.7176 - val_loss: 0.6103 - val_accuracy: 0.8485
# Epoch 201/1000
#
# Epoch 00201: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6921 - accuracy: 0.7087 - val_loss: 0.6102 - val_accuracy: 0.8485
# Epoch 202/1000
#
# Epoch 00202: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6749 - accuracy: 0.7149 - val_loss: 0.6093 - val_accuracy: 0.8485
# Epoch 203/1000
#
# Epoch 00203: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6689 - accuracy: 0.7128 - val_loss: 0.6077 - val_accuracy: 0.8485
# Epoch 204/1000
#
# Epoch 00204: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6726 - accuracy: 0.7156 - val_loss: 0.6069 - val_accuracy: 0.8485
# Epoch 205/1000
#
# Epoch 00205: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6739 - accuracy: 0.7039 - val_loss: 0.6073 - val_accuracy: 0.8485
# Epoch 206/1000
#
# Epoch 00206: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6714 - accuracy: 0.7005 - val_loss: 0.6058 - val_accuracy: 0.8469
# Epoch 207/1000
#
# Epoch 00207: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6770 - accuracy: 0.7019 - val_loss: 0.6049 - val_accuracy: 0.8469
# Epoch 208/1000
#
# Epoch 00208: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6786 - accuracy: 0.7005 - val_loss: 0.6045 - val_accuracy: 0.8469
# Epoch 209/1000
#
# Epoch 00209: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6760 - accuracy: 0.7019 - val_loss: 0.6045 - val_accuracy: 0.8469
# Epoch 210/1000
#
# Epoch 00210: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6772 - accuracy: 0.7032 - val_loss: 0.6045 - val_accuracy: 0.8469
# Epoch 211/1000
#
# Epoch 00211: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6768 - accuracy: 0.7080 - val_loss: 0.6037 - val_accuracy: 0.8469
# Epoch 212/1000
#
# Epoch 00212: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6787 - accuracy: 0.7135 - val_loss: 0.6048 - val_accuracy: 0.8469
# Epoch 213/1000
#
# Epoch 00213: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6774 - accuracy: 0.7156 - val_loss: 0.6062 - val_accuracy: 0.8469
# Epoch 214/1000
#
# Epoch 00214: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6765 - accuracy: 0.7046 - val_loss: 0.6061 - val_accuracy: 0.8469
# Epoch 215/1000
#
# Epoch 00215: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6835 - accuracy: 0.7156 - val_loss: 0.6049 - val_accuracy: 0.8469
# Epoch 216/1000
#
# Epoch 00216: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6743 - accuracy: 0.7125 - val_loss: 0.6036 - val_accuracy: 0.8469
# Epoch 217/1000
#
# Epoch 00217: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6707 - accuracy: 0.7162 - val_loss: 0.6023 - val_accuracy: 0.8469
# Epoch 218/1000
#
# Epoch 00218: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6872 - accuracy: 0.7108 - val_loss: 0.5993 - val_accuracy: 0.8469
# Epoch 219/1000
#
# Epoch 00219: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6867 - accuracy: 0.7135 - val_loss: 0.5997 - val_accuracy: 0.8469
# Epoch 220/1000
#
# Epoch 00220: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6687 - accuracy: 0.7238 - val_loss: 0.5991 - val_accuracy: 0.8469
# Epoch 221/1000
#
# Epoch 00221: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6691 - accuracy: 0.7197 - val_loss: 0.5984 - val_accuracy: 0.8469
# Epoch 222/1000
#
# Epoch 00222: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6681 - accuracy: 0.7210 - val_loss: 0.5970 - val_accuracy: 0.8469
# Epoch 223/1000
#
# Epoch 00223: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6691 - accuracy: 0.7231 - val_loss: 0.5952 - val_accuracy: 0.8469
# Epoch 224/1000
#
# Epoch 00224: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6672 - accuracy: 0.7183 - val_loss: 0.5939 - val_accuracy: 0.8469
# Epoch 225/1000
#
# Epoch 00225: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6694 - accuracy: 0.7224 - val_loss: 0.5922 - val_accuracy: 0.8469
# Epoch 226/1000
#
# Epoch 00226: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6674 - accuracy: 0.7190 - val_loss: 0.5901 - val_accuracy: 0.8469
# Epoch 227/1000
#
# Epoch 00227: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6717 - accuracy: 0.7197 - val_loss: 0.5894 - val_accuracy: 0.8469
# Epoch 228/1000
#
# Epoch 00228: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6790 - accuracy: 0.7149 - val_loss: 0.5880 - val_accuracy: 0.8469
# Epoch 229/1000
#
# Epoch 00229: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6679 - accuracy: 0.7197 - val_loss: 0.5866 - val_accuracy: 0.8469
# Epoch 230/1000
#
# Epoch 00230: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6765 - accuracy: 0.7135 - val_loss: 0.5842 - val_accuracy: 0.8469
# Epoch 231/1000
#
# Epoch 00231: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6728 - accuracy: 0.7197 - val_loss: 0.5829 - val_accuracy: 0.8469
# Epoch 232/1000
#
# Epoch 00232: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6710 - accuracy: 0.7210 - val_loss: 0.5836 - val_accuracy: 0.8469
# Epoch 233/1000
#
# Epoch 00233: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6999 - accuracy: 0.7046 - val_loss: 0.5830 - val_accuracy: 0.8469
# Epoch 234/1000
#
# Epoch 00234: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6963 - accuracy: 0.7066 - val_loss: 0.5838 - val_accuracy: 0.8469
# Epoch 235/1000
#
# Epoch 00235: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6881 - accuracy: 0.7114 - val_loss: 0.5850 - val_accuracy: 0.8469
# Epoch 236/1000
#
# Epoch 00236: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6671 - accuracy: 0.7217 - val_loss: 0.5863 - val_accuracy: 0.8469
# Epoch 237/1000
#
# Epoch 00237: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6668 - accuracy: 0.7162 - val_loss: 0.5853 - val_accuracy: 0.8469
# Epoch 238/1000
#
# Epoch 00238: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6689 - accuracy: 0.7190 - val_loss: 0.5862 - val_accuracy: 0.8469
# Epoch 239/1000
#
# Epoch 00239: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6664 - accuracy: 0.7204 - val_loss: 0.5852 - val_accuracy: 0.8469
# Epoch 240/1000
#
# Epoch 00240: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6636 - accuracy: 0.7238 - val_loss: 0.5838 - val_accuracy: 0.8469
# Epoch 241/1000
#
# Epoch 00241: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6645 - accuracy: 0.7217 - val_loss: 0.5849 - val_accuracy: 0.8469
# Epoch 242/1000
#
# Epoch 00242: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6683 - accuracy: 0.7169 - val_loss: 0.5870 - val_accuracy: 0.8469
# Epoch 243/1000
#
# Epoch 00243: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6689 - accuracy: 0.7176 - val_loss: 0.5845 - val_accuracy: 0.8469
# Epoch 244/1000
#
# Epoch 00244: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6645 - accuracy: 0.7197 - val_loss: 0.5843 - val_accuracy: 0.8469
# Epoch 245/1000
#
# Epoch 00245: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6673 - accuracy: 0.7176 - val_loss: 0.5825 - val_accuracy: 0.8469
# Epoch 246/1000
#
# Epoch 00246: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6710 - accuracy: 0.7183 - val_loss: 0.5811 - val_accuracy: 0.8469
# Epoch 247/1000
#
# Epoch 00247: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6751 - accuracy: 0.7135 - val_loss: 0.5819 - val_accuracy: 0.8469
# Epoch 248/1000
#
# Epoch 00248: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6643 - accuracy: 0.7210 - val_loss: 0.5785 - val_accuracy: 0.8469
# Epoch 249/1000
#
# Epoch 00249: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6662 - accuracy: 0.7217 - val_loss: 0.5786 - val_accuracy: 0.8469
# Epoch 250/1000
#
# Epoch 00250: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6627 - accuracy: 0.7183 - val_loss: 0.5763 - val_accuracy: 0.8469
# Epoch 251/1000
#
# Epoch 00251: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6678 - accuracy: 0.7101 - val_loss: 0.5742 - val_accuracy: 0.8469
# Epoch 252/1000
#
# Epoch 00252: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6685 - accuracy: 0.7005 - val_loss: 0.5723 - val_accuracy: 0.8469
# Epoch 253/1000
#
# Epoch 00253: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6641 - accuracy: 0.7162 - val_loss: 0.5707 - val_accuracy: 0.8469
# Epoch 254/1000
#
# Epoch 00254: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6621 - accuracy: 0.7217 - val_loss: 0.5693 - val_accuracy: 0.8469
# Epoch 255/1000
#
# Epoch 00255: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6874 - accuracy: 0.7121 - val_loss: 0.5680 - val_accuracy: 0.8469
# Epoch 256/1000
#
# Epoch 00256: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6689 - accuracy: 0.7197 - val_loss: 0.5671 - val_accuracy: 0.8469
# Epoch 257/1000
#
# Epoch 00257: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6621 - accuracy: 0.7169 - val_loss: 0.5649 - val_accuracy: 0.8469
# Epoch 258/1000
#
# Epoch 00258: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6645 - accuracy: 0.7224 - val_loss: 0.5624 - val_accuracy: 0.8469
# Epoch 259/1000
#
# Epoch 00259: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6674 - accuracy: 0.6998 - val_loss: 0.5637 - val_accuracy: 0.8469
# Epoch 260/1000
#
# Epoch 00260: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6685 - accuracy: 0.6984 - val_loss: 0.5635 - val_accuracy: 0.8469
# Epoch 261/1000
#
# Epoch 00261: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6700 - accuracy: 0.6950 - val_loss: 0.5616 - val_accuracy: 0.8469
# Epoch 262/1000
#
# Epoch 00262: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6713 - accuracy: 0.7039 - val_loss: 0.5614 - val_accuracy: 0.8469
# Epoch 263/1000
#
# Epoch 00263: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6729 - accuracy: 0.7012 - val_loss: 0.5625 - val_accuracy: 0.8453
# Epoch 264/1000
#
# Epoch 00264: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6699 - accuracy: 0.7019 - val_loss: 0.5626 - val_accuracy: 0.8436
# Epoch 265/1000
#
# Epoch 00265: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6719 - accuracy: 0.7025 - val_loss: 0.5662 - val_accuracy: 0.8274
# Epoch 266/1000
#
# Epoch 00266: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6720 - accuracy: 0.7025 - val_loss: 0.5672 - val_accuracy: 0.8257
# Epoch 267/1000
#
# Epoch 00267: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6680 - accuracy: 0.7053 - val_loss: 0.5650 - val_accuracy: 0.8208
# Epoch 268/1000
#
# Epoch 00268: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6662 - accuracy: 0.7032 - val_loss: 0.5643 - val_accuracy: 0.8176
# Epoch 269/1000
#
# Epoch 00269: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6782 - accuracy: 0.7142 - val_loss: 0.5674 - val_accuracy: 0.8176
# Epoch 270/1000
#
# Epoch 00270: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6695 - accuracy: 0.7034 - val_loss: 0.5641 - val_accuracy: 0.8192
# Epoch 271/1000
#
# Epoch 00271: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6652 - accuracy: 0.7094 - val_loss: 0.5623 - val_accuracy: 0.8241
# Epoch 272/1000
#
# Epoch 00272: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6817 - accuracy: 0.7046 - val_loss: 0.5631 - val_accuracy: 0.8257
# Epoch 273/1000
#
# Epoch 00273: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6814 - accuracy: 0.7039 - val_loss: 0.5606 - val_accuracy: 0.8274
# Epoch 274/1000
#
# Epoch 00274: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6611 - accuracy: 0.7121 - val_loss: 0.5586 - val_accuracy: 0.8306
# Epoch 275/1000
#
# Epoch 00275: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6632 - accuracy: 0.7012 - val_loss: 0.5570 - val_accuracy: 0.8404
# Epoch 276/1000
#
# Epoch 00276: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6620 - accuracy: 0.7066 - val_loss: 0.5581 - val_accuracy: 0.8436
# Epoch 277/1000
#
# Epoch 00277: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6634 - accuracy: 0.7080 - val_loss: 0.5554 - val_accuracy: 0.8436
# Epoch 278/1000
#
# Epoch 00278: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6586 - accuracy: 0.7094 - val_loss: 0.5521 - val_accuracy: 0.8436
# Epoch 279/1000
#
# Epoch 00279: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6621 - accuracy: 0.7142 - val_loss: 0.5510 - val_accuracy: 0.8436
# Epoch 280/1000
#
# Epoch 00280: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6647 - accuracy: 0.7032 - val_loss: 0.5506 - val_accuracy: 0.8436
# Epoch 281/1000
#
# Epoch 00281: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6632 - accuracy: 0.7080 - val_loss: 0.5488 - val_accuracy: 0.8469
# Epoch 282/1000
#
# Epoch 00282: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6711 - accuracy: 0.7012 - val_loss: 0.5473 - val_accuracy: 0.8436
# Epoch 283/1000
#
# Epoch 00283: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6613 - accuracy: 0.7101 - val_loss: 0.5463 - val_accuracy: 0.8436
# Epoch 284/1000
#
# Epoch 00284: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6736 - accuracy: 0.7032 - val_loss: 0.5430 - val_accuracy: 0.8469
# Epoch 285/1000
#
# Epoch 00285: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6676 - accuracy: 0.6923 - val_loss: 0.5432 - val_accuracy: 0.8436
# Epoch 286/1000
#
# Epoch 00286: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6600 - accuracy: 0.7142 - val_loss: 0.5433 - val_accuracy: 0.8436
# Epoch 287/1000
#
# Epoch 00287: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6932 - accuracy: 0.7019 - val_loss: 0.5432 - val_accuracy: 0.8436
# Epoch 288/1000
#
# Epoch 00288: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6894 - accuracy: 0.6943 - val_loss: 0.5440 - val_accuracy: 0.8436
# Epoch 289/1000
#
# Epoch 00289: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6800 - accuracy: 0.7032 - val_loss: 0.5453 - val_accuracy: 0.8436
# Epoch 290/1000
#
# Epoch 00290: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6606 - accuracy: 0.7053 - val_loss: 0.5455 - val_accuracy: 0.8469
# Epoch 291/1000
#
# Epoch 00291: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6622 - accuracy: 0.6950 - val_loss: 0.5496 - val_accuracy: 0.8469
# Epoch 292/1000
#
# Epoch 00292: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6631 - accuracy: 0.6964 - val_loss: 0.5504 - val_accuracy: 0.8469
# Epoch 293/1000
#
# Epoch 00293: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6621 - accuracy: 0.7012 - val_loss: 0.5535 - val_accuracy: 0.8436
# Epoch 294/1000
#
# Epoch 00294: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6604 - accuracy: 0.6984 - val_loss: 0.5503 - val_accuracy: 0.8469
# Epoch 295/1000
#
# Epoch 00295: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6614 - accuracy: 0.7039 - val_loss: 0.5511 - val_accuracy: 0.8469
# Epoch 296/1000
#
# Epoch 00296: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6620 - accuracy: 0.6902 - val_loss: 0.5486 - val_accuracy: 0.8469
# Epoch 297/1000
#
# Epoch 00297: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6626 - accuracy: 0.6902 - val_loss: 0.5481 - val_accuracy: 0.8469
# Epoch 298/1000
#
# Epoch 00298: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6570 - accuracy: 0.7053 - val_loss: 0.5499 - val_accuracy: 0.8469
# Epoch 299/1000
#
# Epoch 00299: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6583 - accuracy: 0.6943 - val_loss: 0.5490 - val_accuracy: 0.8469
# Epoch 300/1000
#
# Epoch 00300: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6669 - accuracy: 0.6895 - val_loss: 0.5493 - val_accuracy: 0.8469
# Epoch 301/1000
#
# Epoch 00301: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6696 - accuracy: 0.6806 - val_loss: 0.5464 - val_accuracy: 0.8469
# Epoch 302/1000
#
# Epoch 00302: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6601 - accuracy: 0.6895 - val_loss: 0.5457 - val_accuracy: 0.8469
# Epoch 303/1000
#
# Epoch 00303: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6584 - accuracy: 0.6964 - val_loss: 0.5460 - val_accuracy: 0.8436
# Epoch 304/1000
#
# Epoch 00304: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6608 - accuracy: 0.6868 - val_loss: 0.5432 - val_accuracy: 0.8469
# Epoch 305/1000
#
# Epoch 00305: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6592 - accuracy: 0.6916 - val_loss: 0.5418 - val_accuracy: 0.8436
# Epoch 306/1000
#
# Epoch 00306: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6624 - accuracy: 0.6861 - val_loss: 0.5413 - val_accuracy: 0.8436
# Epoch 307/1000
#
# Epoch 00307: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6556 - accuracy: 0.6779 - val_loss: 0.5412 - val_accuracy: 0.8469
# Epoch 308/1000
#
# Epoch 00308: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6576 - accuracy: 0.6875 - val_loss: 0.5420 - val_accuracy: 0.8257
# Epoch 309/1000
#
# Epoch 00309: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6872 - accuracy: 0.6772 - val_loss: 0.5414 - val_accuracy: 0.8306
# Epoch 310/1000
#
# Epoch 00310: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6649 - accuracy: 0.6833 - val_loss: 0.5385 - val_accuracy: 0.8306
# Epoch 311/1000
#
# Epoch 00311: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6564 - accuracy: 0.6847 - val_loss: 0.5350 - val_accuracy: 0.8436
# Epoch 312/1000
#
# Epoch 00312: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6620 - accuracy: 0.6799 - val_loss: 0.5368 - val_accuracy: 0.8436
# Epoch 313/1000
#
# Epoch 00313: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6613 - accuracy: 0.6532 - val_loss: 0.5338 - val_accuracy: 0.8306
# Epoch 314/1000
#
# Epoch 00314: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6623 - accuracy: 0.6696 - val_loss: 0.5350 - val_accuracy: 0.8274
# Epoch 315/1000
#
# Epoch 00315: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6645 - accuracy: 0.6614 - val_loss: 0.5330 - val_accuracy: 0.8241
# Epoch 316/1000
#
# Epoch 00316: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6721 - accuracy: 0.6587 - val_loss: 0.5366 - val_accuracy: 0.8192
# Epoch 317/1000
#
# Epoch 00317: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6659 - accuracy: 0.6607 - val_loss: 0.5368 - val_accuracy: 0.8176
# Epoch 318/1000
#
# Epoch 00318: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6718 - accuracy: 0.6477 - val_loss: 0.5382 - val_accuracy: 0.8160
# Epoch 319/1000
#
# Epoch 00319: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6670 - accuracy: 0.6621 - val_loss: 0.5402 - val_accuracy: 0.8143
# Epoch 320/1000
#
# Epoch 00320: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6659 - accuracy: 0.6868 - val_loss: 0.5394 - val_accuracy: 0.8111
# Epoch 321/1000
#
# Epoch 00321: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6641 - accuracy: 0.6854 - val_loss: 0.5407 - val_accuracy: 0.8111
# Epoch 322/1000
#
# Epoch 00322: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6647 - accuracy: 0.6703 - val_loss: 0.5446 - val_accuracy: 0.8094
# Epoch 323/1000
#
# Epoch 00323: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6729 - accuracy: 0.6511 - val_loss: 0.5425 - val_accuracy: 0.8094
# Epoch 324/1000
#
# Epoch 00324: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6627 - accuracy: 0.6825 - val_loss: 0.5418 - val_accuracy: 0.8111
# Epoch 325/1000
#
# Epoch 00325: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6584 - accuracy: 0.6710 - val_loss: 0.5398 - val_accuracy: 0.8111
# Epoch 326/1000
#
# Epoch 00326: val_accuracy did not improve from 0.90228
# 55/55 - 0s - loss: 0.6773 - accuracy: 0.6566 - val_loss: 0.5410 - val_accuracy: 0.8127
# (2036, 30, 4)
# (2036, 1)
# (1425, 30, 4)
# (611, 30, 4)
# {0: 0.5736714975845411, 1: 3.8934426229508197}
# (1425, 2)
# (611, 2)
# Model: "functional_65"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 30, 4)]           0
# _________________________________________________________________
# dense_128 (Dense)            (None, 30, 64)            320
# _________________________________________________________________
# dense_129 (Dense)            (None, 30, 32)            2080
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 30, 32)            0
# _________________________________________________________________
# flatten_32 (Flatten)         (None, 960)               0
# _________________________________________________________________
# dense_130 (Dense)            (None, 64)                61504
# _________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dense_131 (Dense)            (None, 2)                 130
# =================================================================
# Total params: 64,034
# Trainable params: 64,034
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0054s vs `on_train_batch_end` time: 0.0601s). Check your callbacks.
#
# Epoch 00001: val_accuracy improved from -inf to 0.72668, saving model to /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_292_futures_rnn.hdf5
# 54/54 - 1s - loss: 0.6985 - accuracy: 0.5448 - val_loss: 0.6852 - val_accuracy: 0.7267
# Epoch 2/1000
#
# Epoch 00002: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.7057 - accuracy: 0.4986 - val_loss: 0.6882 - val_accuracy: 0.7267
# Epoch 3/1000
#
# Epoch 00003: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6976 - accuracy: 0.4690 - val_loss: 0.6894 - val_accuracy: 0.7267
# Epoch 4/1000
#
# Epoch 00004: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6940 - accuracy: 0.4325 - val_loss: 0.6890 - val_accuracy: 0.7267
# Epoch 5/1000
#
# Epoch 00005: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6933 - accuracy: 0.4449 - val_loss: 0.6881 - val_accuracy: 0.7267
# Epoch 6/1000
#
# Epoch 00006: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6980 - accuracy: 0.4229 - val_loss: 0.6884 - val_accuracy: 0.7267
# Epoch 7/1000
#
# Epoch 00007: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6963 - accuracy: 0.4428 - val_loss: 0.6870 - val_accuracy: 0.7267
# Epoch 8/1000
#
# Epoch 00008: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6933 - accuracy: 0.4511 - val_loss: 0.6865 - val_accuracy: 0.7267
# Epoch 9/1000
#
# Epoch 00009: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6945 - accuracy: 0.3994 - val_loss: 0.6865 - val_accuracy: 0.7267
# Epoch 10/1000
#
# Epoch 00010: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6953 - accuracy: 0.4229 - val_loss: 0.6858 - val_accuracy: 0.7267
# Epoch 11/1000
#
# Epoch 00011: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6973 - accuracy: 0.4236 - val_loss: 0.6857 - val_accuracy: 0.7267
# Epoch 12/1000
#
# Epoch 00012: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.7329 - accuracy: 0.4353 - val_loss: 0.6860 - val_accuracy: 0.7267
# Epoch 13/1000
#
# Epoch 00013: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.7102 - accuracy: 0.4125 - val_loss: 0.6868 - val_accuracy: 0.7267
# Epoch 14/1000
#
# Epoch 00014: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.7047 - accuracy: 0.4201 - val_loss: 0.6880 - val_accuracy: 0.7267
# Epoch 15/1000
#
# Epoch 00015: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6947 - accuracy: 0.4236 - val_loss: 0.6888 - val_accuracy: 0.7267
# Epoch 16/1000
#
# Epoch 00016: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6928 - accuracy: 0.4504 - val_loss: 0.6889 - val_accuracy: 0.7267
# Epoch 17/1000
#
# Epoch 00017: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.7070 - accuracy: 0.4738 - val_loss: 0.6894 - val_accuracy: 0.7267
# Epoch 18/1000
#
# Epoch 00018: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.7181 - accuracy: 0.4566 - val_loss: 0.6907 - val_accuracy: 0.7267
# Epoch 19/1000
#
# Epoch 00019: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.7108 - accuracy: 0.4745 - val_loss: 0.6921 - val_accuracy: 0.7119
# Epoch 20/1000
#
# Epoch 00020: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6912 - accuracy: 0.4518 - val_loss: 0.6927 - val_accuracy: 0.6465
# Epoch 21/1000
#
# Epoch 00021: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6900 - accuracy: 0.4401 - val_loss: 0.6934 - val_accuracy: 0.4173
# Epoch 22/1000
#
# Epoch 00022: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6902 - accuracy: 0.4518 - val_loss: 0.6932 - val_accuracy: 0.5025
# Epoch 23/1000
#
# Epoch 00023: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6895 - accuracy: 0.4814 - val_loss: 0.6939 - val_accuracy: 0.3126
# Epoch 24/1000
#
# Epoch 00024: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6892 - accuracy: 0.4759 - val_loss: 0.6940 - val_accuracy: 0.2913
# Epoch 25/1000
#
# Epoch 00025: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6891 - accuracy: 0.4793 - val_loss: 0.6937 - val_accuracy: 0.3241
# Epoch 26/1000
#
# Epoch 00026: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6923 - accuracy: 0.4607 - val_loss: 0.6938 - val_accuracy: 0.3142
# Epoch 27/1000
#
# Epoch 00027: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6902 - accuracy: 0.4766 - val_loss: 0.6937 - val_accuracy: 0.3142
# Epoch 28/1000
#
# Epoch 00028: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6952 - accuracy: 0.4890 - val_loss: 0.6937 - val_accuracy: 0.3126
# Epoch 29/1000
#
# Epoch 00029: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6899 - accuracy: 0.4642 - val_loss: 0.6937 - val_accuracy: 0.3290
# Epoch 30/1000
#
# Epoch 00030: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6970 - accuracy: 0.4725 - val_loss: 0.6934 - val_accuracy: 0.3993
# Epoch 31/1000
#
# Epoch 00031: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.7005 - accuracy: 0.4842 - val_loss: 0.6931 - val_accuracy: 0.5172
# Epoch 32/1000
#
# Epoch 00032: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.7022 - accuracy: 0.4835 - val_loss: 0.6933 - val_accuracy: 0.4632
# Epoch 33/1000
#
# Epoch 00033: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6891 - accuracy: 0.4897 - val_loss: 0.6934 - val_accuracy: 0.4108
# Epoch 34/1000
#
# Epoch 00034: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6903 - accuracy: 0.5007 - val_loss: 0.6931 - val_accuracy: 0.5401
# Epoch 35/1000
#
# Epoch 00035: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6890 - accuracy: 0.5014 - val_loss: 0.6929 - val_accuracy: 0.6268
# Epoch 36/1000
#
# Epoch 00036: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6938 - accuracy: 0.4573 - val_loss: 0.6929 - val_accuracy: 0.6350
# Epoch 37/1000
#
# Epoch 00037: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6890 - accuracy: 0.4986 - val_loss: 0.6927 - val_accuracy: 0.6645
# Epoch 38/1000
#
# Epoch 00038: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6938 - accuracy: 0.4497 - val_loss: 0.6926 - val_accuracy: 0.6858
# Epoch 39/1000
#
# Epoch 00039: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.7030 - accuracy: 0.4986 - val_loss: 0.6927 - val_accuracy: 0.6841
# Epoch 40/1000
#
# Epoch 00040: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6911 - accuracy: 0.5021 - val_loss: 0.6929 - val_accuracy: 0.6383
# Epoch 41/1000
#
# Epoch 00041: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6891 - accuracy: 0.4683 - val_loss: 0.6928 - val_accuracy: 0.6661
# Epoch 42/1000
#
# Epoch 00042: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6946 - accuracy: 0.4731 - val_loss: 0.6925 - val_accuracy: 0.7087
# Epoch 43/1000
#
# Epoch 00043: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6982 - accuracy: 0.4731 - val_loss: 0.6924 - val_accuracy: 0.7103
# Epoch 44/1000
#
# Epoch 00044: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6880 - accuracy: 0.5131 - val_loss: 0.6926 - val_accuracy: 0.6989
# Epoch 45/1000
#
# Epoch 00045: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6906 - accuracy: 0.4842 - val_loss: 0.6926 - val_accuracy: 0.6939
# Epoch 46/1000
#
# Epoch 00046: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6886 - accuracy: 0.4814 - val_loss: 0.6924 - val_accuracy: 0.7103
# Epoch 47/1000
#
# Epoch 00047: val_accuracy did not improve from 0.72668
# 54/54 - 0s - loss: 0.6950 - accuracy: 0.5076 - val_loss: 0.6923 - val_accuracy: 0.7185
# Epoch 48/1000
#
# Epoch 00048: val_accuracy did not improve from 0.72668
# ...
# Epoch 117/1000
#
# Epoch 00117: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6571 - accuracy: 0.7707 - val_loss: 0.6716 - val_accuracy: 0.8333
# Epoch 118/1000
#
# Epoch 00118: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6584 - accuracy: 0.7721 - val_loss: 0.6719 - val_accuracy: 0.8333
# Epoch 119/1000
#
# Epoch 00119: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6575 - accuracy: 0.7756 - val_loss: 0.6724 - val_accuracy: 0.8333
# Epoch 120/1000
#
# Epoch 00120: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6567 - accuracy: 0.7728 - val_loss: 0.6725 - val_accuracy: 0.8317
# Epoch 121/1000
#
# Epoch 00121: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6611 - accuracy: 0.7749 - val_loss: 0.6730 - val_accuracy: 0.8150
# Epoch 122/1000
#
# Epoch 00122: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6588 - accuracy: 0.7784 - val_loss: 0.6730 - val_accuracy: 0.8050
# Epoch 123/1000
#
# Epoch 00123: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6664 - accuracy: 0.7742 - val_loss: 0.6732 - val_accuracy: 0.7817
# Epoch 124/1000
#
# Epoch 00124: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6566 - accuracy: 0.7833 - val_loss: 0.6733 - val_accuracy: 0.7533
# Epoch 125/1000
#
# Epoch 00125: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6580 - accuracy: 0.7791 - val_loss: 0.6738 - val_accuracy: 0.6783
# Epoch 126/1000
#
# Epoch 00126: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6550 - accuracy: 0.7854 - val_loss: 0.6734 - val_accuracy: 0.6517
# Epoch 127/1000
#
# Epoch 00127: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6556 - accuracy: 0.7868 - val_loss: 0.6736 - val_accuracy: 0.6333
# Epoch 128/1000
#
# Epoch 00128: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6562 - accuracy: 0.7875 - val_loss: 0.6735 - val_accuracy: 0.6233
# Epoch 129/1000
#
# Epoch 00129: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6549 - accuracy: 0.7854 - val_loss: 0.6734 - val_accuracy: 0.6050
# Epoch 130/1000
#
# Epoch 00130: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6605 - accuracy: 0.7903 - val_loss: 0.6735 - val_accuracy: 0.6100
# Epoch 131/1000
#
# Epoch 00131: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6617 - accuracy: 0.7889 - val_loss: 0.6733 - val_accuracy: 0.5983
# Epoch 132/1000
#
# Epoch 00132: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6560 - accuracy: 0.7945 - val_loss: 0.6734 - val_accuracy: 0.5933
# Epoch 133/1000
#
# Epoch 00133: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6573 - accuracy: 0.7973 - val_loss: 0.6732 - val_accuracy: 0.5933
# Epoch 134/1000
#
# Epoch 00134: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6569 - accuracy: 0.7987 - val_loss: 0.6733 - val_accuracy: 0.5917
# Epoch 135/1000
#
# Epoch 00135: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6595 - accuracy: 0.8001 - val_loss: 0.6734 - val_accuracy: 0.5917
# Epoch 136/1000
#
# Epoch 00136: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6574 - accuracy: 0.8036 - val_loss: 0.6730 - val_accuracy: 0.5917
# Epoch 137/1000
#
# Epoch 00137: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6534 - accuracy: 0.8107 - val_loss: 0.6731 - val_accuracy: 0.5917
# Epoch 138/1000
#
# Epoch 00138: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6553 - accuracy: 0.8079 - val_loss: 0.6732 - val_accuracy: 0.5917
# Epoch 139/1000
#
# Epoch 00139: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6572 - accuracy: 0.8072 - val_loss: 0.6731 - val_accuracy: 0.5917
# Epoch 140/1000
#
# Epoch 00140: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6603 - accuracy: 0.8072 - val_loss: 0.6732 - val_accuracy: 0.5917
# Epoch 141/1000
#
# Epoch 00141: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6546 - accuracy: 0.8107 - val_loss: 0.6731 - val_accuracy: 0.5917
# Epoch 142/1000
#
# Epoch 00142: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6635 - accuracy: 0.8036 - val_loss: 0.6735 - val_accuracy: 0.5917
# Epoch 143/1000
#
# Epoch 00143: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6844 - accuracy: 0.7952 - val_loss: 0.6736 - val_accuracy: 0.5917
# Epoch 144/1000
#
# Epoch 00144: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6598 - accuracy: 0.8079 - val_loss: 0.6740 - val_accuracy: 0.5917
# Epoch 145/1000
#
# Epoch 00145: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6535 - accuracy: 0.8135 - val_loss: 0.6744 - val_accuracy: 0.5917
# Epoch 146/1000
#
# Epoch 00146: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6615 - accuracy: 0.8093 - val_loss: 0.6748 - val_accuracy: 0.5917
# Epoch 147/1000
#
# Epoch 00147: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6515 - accuracy: 0.8149 - val_loss: 0.6750 - val_accuracy: 0.5917
# Epoch 148/1000
#
# Epoch 00148: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6518 - accuracy: 0.8170 - val_loss: 0.6747 - val_accuracy: 0.5917
# Epoch 149/1000
#
# Epoch 00149: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6528 - accuracy: 0.8156 - val_loss: 0.6754 - val_accuracy: 0.5917
# Epoch 150/1000
#
# Epoch 00150: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6530 - accuracy: 0.8170 - val_loss: 0.6756 - val_accuracy: 0.5917
# Epoch 151/1000
#
# Epoch 00151: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6537 - accuracy: 0.8128 - val_loss: 0.6758 - val_accuracy: 0.5917
# Epoch 152/1000
#
# Epoch 00152: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6535 - accuracy: 0.8072 - val_loss: 0.6762 - val_accuracy: 0.5917
# Epoch 153/1000
#
# Epoch 00153: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6512 - accuracy: 0.8128 - val_loss: 0.6764 - val_accuracy: 0.5917
# Epoch 154/1000
#
# Epoch 00154: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6532 - accuracy: 0.8093 - val_loss: 0.6768 - val_accuracy: 0.5917
# Epoch 155/1000
#
# Epoch 00155: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6587 - accuracy: 0.8184 - val_loss: 0.6770 - val_accuracy: 0.5917
# Epoch 156/1000
#
# Epoch 00156: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6552 - accuracy: 0.8072 - val_loss: 0.6772 - val_accuracy: 0.5917
# Epoch 157/1000
#
# Epoch 00157: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6818 - accuracy: 0.8043 - val_loss: 0.6779 - val_accuracy: 0.5917
# Epoch 158/1000
#
# Epoch 00158: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6854 - accuracy: 0.8036 - val_loss: 0.6785 - val_accuracy: 0.5917
# Epoch 159/1000
#
# Epoch 00159: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6592 - accuracy: 0.8149 - val_loss: 0.6794 - val_accuracy: 0.5917
# Epoch 160/1000
#
# Epoch 00160: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6497 - accuracy: 0.8205 - val_loss: 0.6805 - val_accuracy: 0.5917
# Epoch 161/1000
#
# Epoch 00161: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6539 - accuracy: 0.8198 - val_loss: 0.6810 - val_accuracy: 0.5917
# Epoch 162/1000
#
# Epoch 00162: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6516 - accuracy: 0.8198 - val_loss: 0.6817 - val_accuracy: 0.5917
# Epoch 163/1000
#
# Epoch 00163: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6498 - accuracy: 0.8240 - val_loss: 0.6821 - val_accuracy: 0.5917
# Epoch 164/1000
#
# Epoch 00164: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6496 - accuracy: 0.8240 - val_loss: 0.6825 - val_accuracy: 0.5917
# Epoch 165/1000
#
# Epoch 00165: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6502 - accuracy: 0.8254 - val_loss: 0.6827 - val_accuracy: 0.5917
# Epoch 166/1000
#
# Epoch 00166: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6556 - accuracy: 0.8261 - val_loss: 0.6833 - val_accuracy: 0.5917
# Epoch 167/1000
#
# Epoch 00167: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6784 - accuracy: 0.8093 - val_loss: 0.6841 - val_accuracy: 0.5917
# Epoch 168/1000
#
# Epoch 00168: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6780 - accuracy: 0.8121 - val_loss: 0.6851 - val_accuracy: 0.5917
# Epoch 169/1000
#
# Epoch 00169: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6495 - accuracy: 0.8275 - val_loss: 0.6860 - val_accuracy: 0.5917
# Epoch 170/1000
#
# Epoch 00170: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6496 - accuracy: 0.8317 - val_loss: 0.6867 - val_accuracy: 0.5917
# Epoch 171/1000
#
# Epoch 00171: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6492 - accuracy: 0.8310 - val_loss: 0.6870 - val_accuracy: 0.5917
# Epoch 172/1000
#
# Epoch 00172: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6490 - accuracy: 0.8296 - val_loss: 0.6867 - val_accuracy: 0.5917
# Epoch 173/1000
#
# Epoch 00173: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6529 - accuracy: 0.8289 - val_loss: 0.6873 - val_accuracy: 0.5917
# Epoch 174/1000
#
# Epoch 00174: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6516 - accuracy: 0.8324 - val_loss: 0.6884 - val_accuracy: 0.5917
# Epoch 175/1000
#
# Epoch 00175: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6585 - accuracy: 0.8268 - val_loss: 0.6889 - val_accuracy: 0.5917
# Epoch 176/1000
#
# Epoch 00176: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6480 - accuracy: 0.8352 - val_loss: 0.6898 - val_accuracy: 0.5917
# Epoch 177/1000
#
# Epoch 00177: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6495 - accuracy: 0.8338 - val_loss: 0.6912 - val_accuracy: 0.5917
# Epoch 178/1000
#
# Epoch 00178: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6472 - accuracy: 0.8338 - val_loss: 0.6922 - val_accuracy: 0.5917
# Epoch 179/1000
#
# Epoch 00179: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6474 - accuracy: 0.8352 - val_loss: 0.6916 - val_accuracy: 0.5917
# Epoch 180/1000
#
# Epoch 00180: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6478 - accuracy: 0.8352 - val_loss: 0.6945 - val_accuracy: 0.5917
# Epoch 181/1000
#
# Epoch 00181: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6467 - accuracy: 0.8366 - val_loss: 0.6937 - val_accuracy: 0.5917
# Epoch 182/1000
#
# Epoch 00182: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6520 - accuracy: 0.8338 - val_loss: 0.6968 - val_accuracy: 0.5917
# Epoch 183/1000
#
# Epoch 00183: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6539 - accuracy: 0.8331 - val_loss: 0.6950 - val_accuracy: 0.5900
# Epoch 184/1000
#
# Epoch 00184: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6470 - accuracy: 0.8359 - val_loss: 0.7001 - val_accuracy: 0.5900
# Epoch 185/1000
#
# Epoch 00185: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6498 - accuracy: 0.8359 - val_loss: 0.6962 - val_accuracy: 0.5900
# Epoch 186/1000
#
# Epoch 00186: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6479 - accuracy: 0.8359 - val_loss: 0.7069 - val_accuracy: 0.5900
# Epoch 187/1000
#
# Epoch 00187: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6527 - accuracy: 0.8352 - val_loss: 0.7025 - val_accuracy: 0.5900
# Epoch 188/1000
#
# Epoch 00188: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6500 - accuracy: 0.8352 - val_loss: 0.7042 - val_accuracy: 0.5900
# Epoch 189/1000
#
# Epoch 00189: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6466 - accuracy: 0.8387 - val_loss: 0.7032 - val_accuracy: 0.5900
# Epoch 190/1000
#
# Epoch 00190: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6460 - accuracy: 0.8380 - val_loss: 0.7122 - val_accuracy: 0.5900
# Epoch 191/1000
#
# Epoch 00191: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6497 - accuracy: 0.8366 - val_loss: 0.7039 - val_accuracy: 0.5900
# Epoch 192/1000
#
# Epoch 00192: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6523 - accuracy: 0.8345 - val_loss: 0.7171 - val_accuracy: 0.5900
# Epoch 193/1000
#
# Epoch 00193: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6476 - accuracy: 0.8408 - val_loss: 0.7076 - val_accuracy: 0.5900
# Epoch 194/1000
#
# Epoch 00194: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6543 - accuracy: 0.8324 - val_loss: 0.7200 - val_accuracy: 0.5900
# Epoch 195/1000
#
# Epoch 00195: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6765 - accuracy: 0.8233 - val_loss: 0.7091 - val_accuracy: 0.5900
# Epoch 196/1000
#
# Epoch 00196: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6524 - accuracy: 0.8345 - val_loss: 0.7189 - val_accuracy: 0.5900
# Epoch 197/1000
#
# Epoch 00197: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6440 - accuracy: 0.8408 - val_loss: 0.7129 - val_accuracy: 0.5900
# Epoch 198/1000
#
# Epoch 00198: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6532 - accuracy: 0.8366 - val_loss: 0.7179 - val_accuracy: 0.5900
# Epoch 199/1000
#
# Epoch 00199: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6442 - accuracy: 0.8408 - val_loss: 0.7145 - val_accuracy: 0.5900
# Epoch 200/1000
#
# Epoch 00200: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6439 - accuracy: 0.8408 - val_loss: 0.7168 - val_accuracy: 0.5900
# Epoch 201/1000
#
# Epoch 00201: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6435 - accuracy: 0.8415 - val_loss: 0.7167 - val_accuracy: 0.5900
# Epoch 202/1000
#
# Epoch 00202: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6444 - accuracy: 0.8422 - val_loss: 0.7166 - val_accuracy: 0.5900
# Epoch 203/1000
#
# Epoch 00203: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6417 - accuracy: 0.8394 - val_loss: 0.7212 - val_accuracy: 0.5900
# Epoch 204/1000
#
# Epoch 00204: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6432 - accuracy: 0.8352 - val_loss: 0.7194 - val_accuracy: 0.5900
# Epoch 205/1000
#
# Epoch 00205: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6409 - accuracy: 0.8373 - val_loss: 0.7262 - val_accuracy: 0.5900
# Epoch 206/1000
#
# Epoch 00206: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6412 - accuracy: 0.8408 - val_loss: 0.7273 - val_accuracy: 0.5900
# Epoch 207/1000
#
# Epoch 00207: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6503 - accuracy: 0.8387 - val_loss: 0.7374 - val_accuracy: 0.5900
# Epoch 208/1000
#
# Epoch 00208: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6449 - accuracy: 0.8431 - val_loss: 0.7272 - val_accuracy: 0.5900
# Epoch 209/1000
#
# Epoch 00209: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6701 - accuracy: 0.8261 - val_loss: 0.7369 - val_accuracy: 0.5900
# Epoch 210/1000
#
# Epoch 00210: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6751 - accuracy: 0.8254 - val_loss: 0.7332 - val_accuracy: 0.5900
# Epoch 211/1000
#
# Epoch 00211: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6488 - accuracy: 0.8380 - val_loss: 0.7452 - val_accuracy: 0.5900
# Epoch 212/1000
#
# Epoch 00212: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6413 - accuracy: 0.8415 - val_loss: 0.7384 - val_accuracy: 0.5900
# Epoch 213/1000
#
# Epoch 00213: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6429 - accuracy: 0.8408 - val_loss: 0.7517 - val_accuracy: 0.5900
# Epoch 214/1000
#
# Epoch 00214: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6429 - accuracy: 0.8429 - val_loss: 0.7367 - val_accuracy: 0.5900
# Epoch 215/1000
#
# Epoch 00215: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6399 - accuracy: 0.8436 - val_loss: 0.7510 - val_accuracy: 0.5900
# Epoch 216/1000
#
# Epoch 00216: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6395 - accuracy: 0.8436 - val_loss: 0.7536 - val_accuracy: 0.5900
# Epoch 217/1000
#
# Epoch 00217: val_accuracy did not improve from 0.89167
# 53/53 - 0s - loss: 0.6398 - accuracy: 0.8443 - val_loss: 0.7592 - val_accuracy: 0.5900

# %% [markdown]
# ### None Realtime vs Realtime

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model
import matplotlib.pyplot as plt

for model_num in model_range:

  try:

    #     Get Realtime Dataset   #
    model_num -= 41

    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)

    #       dataset 분리      #
    # dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    # dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    # Made_X = Made_X_[:, :, [-4]]
    Made_X = Made_X_[:, :, :4]
    # print(Made_X.shape)
    # print(Made_Y.shape)
    # break

    row = Made_X.shape[1]
    col = Made_X.shape[2]

    X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                      shuffle=False)

    X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
    X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)
    
    for model_i, model_num in enumerate([model_num, model_num + 41]):

      if model_i == 0:
        print('Pred by Real')
      else:
        print('Pred by None Real')

      model_path = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (input_data_length, model_num)
      model = load_model(model_path)
      y_pred_ = model.predict(X_val, verbose=1)
      train_y_pred_ = model.predict(X_train, verbose=1)
      # total_y_pred_ = model.predict(Made_X, verbose=1)

      plt.figure(figsize=(10, 6))
      
      for index, y_pred_ in enumerate([y_pred_, train_y_pred_]):

        # print('len(y_pred_) :', len(y_pred_))
        target_column = y_pred_[:, [-1]]
        # column_min, column_max = train_y_pred_.min(),train_y_pred_.max()
        column_min, column_max = target_column.min(),target_column.max()
        # print(column_min, column_max)

        x_ticks = np.arange(0.5, 1, 0.005)
        # x_ticks = np.arange(0.5, column_max, 0.005) <-- column_max 대응할만한 값을 찾아야한다. 1 까지는 사용못할것
        confidence_result = list()
        for confidence in x_ticks:
          # confidence = 0.9

          # if column_max < 0.5:
          #   break
          # else:
          #   scaled_confidence = .5 + (column_max - .5) * confidence
          scaled_confidence = column_min + (column_max - column_min) * confidence

          # scaled_confidence = confidence
          # print(scaled_confidence)
          # print('confidence :', confidence)

          y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )

          #   inverse version   #
          # confidence = 1 - confidence
          # scaled_confidence = y_pred_[:, [-1]].min() + (y_pred_[:, [-1]].max() - y_pred_[:, [-1]].min()) * confidence
          # y_pred = np.where(y_pred_[:, [-1]] <= scaled_confidence, 1, 0).reshape(-1, )

          #     결국, Categorical 은 index 값으로 value 를 나타내는 것    #
          # t_te = np.argmax(Y_val, axis=1)

          if index == 0:
            t_te = Y_val
          else:
            t_te = Y_train

          # print(y_pred_[:5])
          # print(Y_val[:5])
          # break

          pred_true = 0
          real_true = 0

          #       predict value 존나 높으면 True 일 확률 존나 높은건데, 그게 진짜 True가 맞냐 이걸 알고 싶은거지     #
          #       confidence를 만족하는 label이 1인 데이터 안에서 pred 1 / label 1 -> 이걸 도출해면 된다        #

          for i in range(len(y_pred)):
            if y_pred[i] == 1:  
              pred_true += 1
              if t_te[i] == y_pred[i]:
                real_true += 1

          true_true = real_true / pred_true * 100
          confidence_result.append(true_true)
          # print('True Pred / Total True : %s / %s' % (real_true, pred_true))
          # print('Accuracy : %2.f %%' % (true_true))
          # print()

        # if column_max < 0.5:
        #   continue
        
        plt.subplot(2, 4, index + 1 + model_i * 4)
        plt.plot(x_ticks, confidence_result)
        plt.axhline(50, linestyle='--', color='red')
        plt.ylim(-5, 105)
        plt.title('%s %s' % ((column_min, column_max)), color='white', fontsize=10)

        if index == 0:
          plt.subplot(2, 4, index + 3 + model_i * 4)
          plt.plot(Made_X_[-len(X_val):, [-1], [3]])
        elif index == 1:
          plt.subplot(2, 4, index + 3 + model_i * 4)
          plt.plot(Made_X_[:len(X_train), [-1], [3]])

    plt.show()

  except Exception as e:
    print('Error occured : ', e)

  print()
# Out:
# Pred by Real
# 19/19 [==============================] - 0s 2ms/step
# 45/45 [==============================] - 0s 2ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e78a9b3ce931> in <module>()
#      98             if y_pred[i] == 1:
#      99               pred_true += 1
# --> 100               if t_te[i] == y_pred[i]:
#     101                 real_true += 1
#     102
#
# KeyboardInterrupt:

# %% [markdown]
# ### Realtime vs Realtime Scale Fixed Pred by None Real

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model
import matplotlib.pyplot as plt


for model_num in model_range:

  try:

    model_path = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (input_data_length, model_num)
    model = load_model(model_path)    
    
    for model_i, model_num in enumerate([model_num - 41, model_num + 41]):

      if model_i == 0:
        print('Pred at Real')
      else:
        print('Pred at Scale fixed Real')

      Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
      Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)

      #       dataset 분리      #
      # dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
      # dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
      # Made_X = Made_X_[:, :, [-4]]
      Made_X = Made_X_[:, :, :4]
      # print(Made_X.shape)
      # print(Made_Y.shape)
      # break

      row = Made_X.shape[1]
      col = Made_X.shape[2]

      X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                        shuffle=False)

      X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
      X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)
      
      y_pred_ = model.predict(X_val, verbose=1)
      train_y_pred_ = model.predict(X_train, verbose=1)
      # total_y_pred_ = model.predict(Made_X, verbose=1)

      plt.figure(figsize=(10, 6))
      
      for index, y_pred_ in enumerate([y_pred_, train_y_pred_]):

        # print('len(y_pred_) :', len(y_pred_))
        target_column = y_pred_[:, [-1]]
        # column_min, column_max = train_y_pred_.min(),train_y_pred_.max()
        column_min, column_max = target_column.min(),target_column.max()
        # print(column_min, column_max)

        x_ticks = np.arange(0.5, 1, 0.005)
        # x_ticks = np.arange(0.5, column_max, 0.005) <-- column_max 대응할만한 값을 찾아야한다. 1 까지는 사용못할것
        confidence_result = list()
        for confidence in x_ticks:
          # confidence = 0.9

          # if column_max < 0.5:
          #   break
          # else:
          #   scaled_confidence = .5 + (column_max - .5) * confidence
          scaled_confidence = column_min + (column_max - column_min) * confidence

          # scaled_confidence = confidence
          # print(scaled_confidence)
          # print('confidence :', confidence)

          y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )

          #   inverse version   #
          # confidence = 1 - confidence
          # scaled_confidence = y_pred_[:, [-1]].min() + (y_pred_[:, [-1]].max() - y_pred_[:, [-1]].min()) * confidence
          # y_pred = np.where(y_pred_[:, [-1]] <= scaled_confidence, 1, 0).reshape(-1, )

          #     결국, Categorical 은 index 값으로 value 를 나타내는 것    #
          # t_te = np.argmax(Y_val, axis=1)

          if index == 0:
            t_te = Y_val
          else:
            t_te = Y_train

          # print(y_pred_[:5])
          # print(Y_val[:5])
          # break

          pred_true = 0
          real_true = 0

          #       predict value 존나 높으면 True 일 확률 존나 높은건데, 그게 진짜 True가 맞냐 이걸 알고 싶은거지     #
          #       confidence를 만족하는 label이 1인 데이터 안에서 pred 1 / label 1 -> 이걸 도출해면 된다        #

          for i in range(len(y_pred)):
            if y_pred[i] == 1:  
              pred_true += 1
              if t_te[i] == y_pred[i]:
                real_true += 1

          true_true = real_true / pred_true * 100
          confidence_result.append(true_true)
          # print('True Pred / Total True : %s / %s' % (real_true, pred_true))
          # print('Accuracy : %2.f %%' % (true_true))
          # print()

        # if column_max < 0.5:
        #   continue
        
        plt.subplot(2, 4, index + 1 + model_i * 4)
        plt.plot(x_ticks, confidence_result)
        plt.axhline(50, linestyle='--', color='red')
        plt.ylim(-5, 105)
        plt.title('%s %s' % ((column_min, column_max)), color='white', fontsize=10)

        if index == 0:
          plt.subplot(2, 4, index + 3 + model_i * 4)
          plt.plot(Made_X_[-len(X_val):, [-1], [3]])
        elif index == 1:
          plt.subplot(2, 4, index + 3 + model_i * 4)
          plt.plot(Made_X_[:len(X_train), [-1], [3]])

    plt.show()

  except Exception as e:
    print('Error occured : ', e)

  print()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Check True True Realtime

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model
import matplotlib.pyplot as plt

for model_num in model_range:

  try:

    #     Just for pred Realtime Dataset by None_Realtime Model   #
    model_num -= 41

    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)

    model_num += 41

    #       dataset 분리      #
    # dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    # dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    # Made_X = Made_X_[:, :, [-4]]
    Made_X = Made_X_[:, :, :4]
    # print(Made_X.shape)
    # print(Made_Y.shape)
    # break

    row = Made_X.shape[1]
    col = Made_X.shape[2]

    X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                      shuffle=False)

    X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
    X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)

    model_path = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (input_data_length, model_num)
    model = load_model(model_path)
    y_pred_ = model.predict(X_val, verbose=1)
    train_y_pred_ = model.predict(X_train, verbose=1)
    # total_y_pred_ = model.predict(Made_X, verbose=1)
    
    plt.figure(figsize=(10, 3))

    for index, y_pred_ in enumerate([y_pred_, train_y_pred_]):

      # print('len(y_pred_) :', len(y_pred_))
      target_column = y_pred_[:, [-1]]
      # column_min, column_max = train_y_pred_.min(),train_y_pred_.max()
      column_min, column_max = target_column.min(),target_column.max()
      # print(column_min, column_max)

      x_ticks = np.arange(0.5, 1, 0.005)
      # x_ticks = np.arange(0.5, column_max, 0.005) <-- column_max 대응할만한 값을 찾아야한다. 1 까지는 사용못할것
      confidence_result = list()
      for confidence in x_ticks:
        # confidence = 0.9

        # if column_max < 0.5:
        #   break
        # else:
        #   scaled_confidence = .5 + (column_max - .5) * confidence
        scaled_confidence = column_min + (column_max - column_min) * confidence

        # scaled_confidence = confidence
        # print(scaled_confidence)
        # print('confidence :', confidence)

        y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )

        #   inverse version   #
        # confidence = 1 - confidence
        # scaled_confidence = y_pred_[:, [-1]].min() + (y_pred_[:, [-1]].max() - y_pred_[:, [-1]].min()) * confidence
        # y_pred = np.where(y_pred_[:, [-1]] <= scaled_confidence, 1, 0).reshape(-1, )

        #     결국, Categorical 은 index 값으로 value 를 나타내는 것    #
        # t_te = np.argmax(Y_val, axis=1)

        if index == 0:
          t_te = Y_val
        else:
          t_te = Y_train

        # print(y_pred_[:5])
        # print(Y_val[:5])
        # break

        pred_true = 0
        real_true = 0

        #       predict value 존나 높으면 True 일 확률 존나 높은건데, 그게 진짜 True가 맞냐 이걸 알고 싶은거지     #
        #       confidence를 만족하는 label이 1인 데이터 안에서 pred 1 / label 1 -> 이걸 도출해면 된다        #

        for i in range(len(y_pred)):
          if y_pred[i] == 1:  
            pred_true += 1
            if t_te[i] == y_pred[i]:
              real_true += 1

        true_true = real_true / pred_true * 100
        confidence_result.append(true_true)
        # print('True Pred / Total True : %s / %s' % (real_true, pred_true))
        # print('Accuracy : %2.f %%' % (true_true))
        # print()

      # if column_max < 0.5:
      #   continue
      
      plt.subplot(1, 4, index + 1)
      plt.plot(x_ticks, confidence_result)
      plt.axhline(50, linestyle='--', color='red')
      plt.ylim(-5, 105)
      plt.title('%s %s' % ((column_min, column_max)), color='white', fontsize=10)

      if index == 0:
        plt.subplot(1, 4, index + 3)
        plt.plot(Made_X_[-len(X_val):, [-1], [3]])
      elif index == 1:
        plt.subplot(1, 4, index + 3)
        plt.plot(Made_X_[:len(X_train), [-1], [3]])
        plt.show()

  except Exception as e:
    print('Error occured : ', e)
# Out:
# 19/19 [==============================] - 0s 2ms/step
# 45/45 [==============================] - 0s 1ms/step
# 19/19 [==============================] - 0s 1ms/step
# 45/45 [==============================] - 0s 1ms/step
# 19/19 [==============================] - 0s 2ms/step
# 43/43 [==============================] - 0s 2ms/step
# 19/19 [==============================] - 0s 2ms/step
# 43/43 [==============================] - 0s 2ms/step
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_264_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_265_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_266_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_267_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  too many indices for array
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_269_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_270_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_271_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_272_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_273_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_274_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_275_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_276_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_277_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_278_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_279_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_280_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_281_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_282_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_283_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_284_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_285_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_286_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_287_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_288_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_289_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_290_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_291_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_292_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_293_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_294_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_254.npy'
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_255.npy'
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_256.npy'
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_257.npy'
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_258.npy'
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_300_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}

# %% [markdown]
# ### Check True True Possibility

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model
import matplotlib.pyplot as plt

for model_num in model_range:

  try:

    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)


    #       dataset 분리      #
    # dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    # dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    # Made_X = Made_X_[:, :, [-4]]
    Made_X = Made_X_[:, :, :4]
    # print(Made_X.shape)
    # print(Made_Y.shape)
    # break

    row = Made_X.shape[1]
    col = Made_X.shape[2]

    X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                      shuffle=False)

    X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
    X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)

    model_path = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (input_data_length, model_num)
    model = load_model(model_path)
    y_pred_ = model.predict(X_val, verbose=1)

    target_column = y_pred_[:, [-1]]
    column_min, column_max = target_column.min(),target_column.max()
    # print(column_min, column_max)

    x_ticks = np.arange(0.8, 1, 0.005)
    # x_ticks = np.arange(0.5, column_max, 0.005)
    confidence_result = list()
    for confidence in x_ticks:
      # confidence = 0.9

      if column_max < 0.5:
        break
      scaled_confidence = .5 + (column_max - .5) * confidence
      # scaled_confidence = confidence
      # print(scaled_confidence)
      # print('confidence :', confidence)

      y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )

      #   inverse version   #
      # confidence = 1 - confidence
      # scaled_confidence = y_pred_[:, [-1]].min() + (y_pred_[:, [-1]].max() - y_pred_[:, [-1]].min()) * confidence
      # y_pred = np.where(y_pred_[:, [-1]] <= scaled_confidence, 1, 0).reshape(-1, )

      #     결국, Categorical 은 index 값으로 value 를 나타내는 것    #
      # t_te = np.argmax(Y_val, axis=1)
      t_te = Y_val

      # print(y_pred_[:5])
      # print(Y_val[:5])
      # break

      pred_true = 0
      real_true = 0

      #       predict value 존나 높으면 True 일 확률 존나 높은건데, 그게 진짜 True가 맞냐 이걸 알고 싶은거지     #
      #       confidence를 만족하는 label이 1인 데이터 안에서 pred 1 / label 1 -> 이걸 도출해면 된다        #

      for i in range(len(y_pred)):
        if y_pred[i] == 1:  
          pred_true += 1
          if t_te[i] == y_pred[i]:
            real_true += 1

      true_true = real_true / pred_true * 100
      confidence_result.append(true_true)
      print('True Pred / Total True : %s / %s' % (real_true, pred_true))
      print('Accuracy : %2.f %%' % (true_true))
      # print()

    if column_max < 0.5:
      continue
    plt.plot(x_ticks, confidence_result)
    plt.axhline(50, linestyle='--', color='red')
    plt.ylim(-5, 105)
    plt.title('%.2f %.2f' % ((column_min, column_max)), color='white', fontsize=10)
    plt.show()

  except Exception as e:
    print('Error occured : ', e)
# Out:
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# True Pred / Total True : 2 / 2
# Accuracy : 100 %
# 11/11 [==============================] - 0s 1ms/step
# True Pred / Total True : 27 / 91
# Accuracy : 30 %
# True Pred / Total True : 10 / 44
# Accuracy : 23 %
# True Pred / Total True : 0 / 15
# Accuracy :  0 %
# True Pred / Total True : 0 / 10
# Accuracy :  0 %
# True Pred / Total True : 0 / 1
# Accuracy :  0 %
# True Pred / Total True : 0 / 1
# Accuracy :  0 %
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# True Pred / Total True : 17 / 19
# Accuracy : 89 %
# 11/11 [==============================] - 0s 1ms/step
# True Pred / Total True : 10 / 12
# Accuracy : 83 %
# 11/11 [==============================] - 0s 1ms/step
# True Pred / Total True : 0 / 8
# Accuracy :  0 %
# True Pred / Total True : 0 / 4
# Accuracy :  0 %
# True Pred / Total True : 0 / 2
# Accuracy :  0 %
# True Pred / Total True : 0 / 2
# Accuracy :  0 %
# True Pred / Total True : 0 / 2
# Accuracy :  0 %
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# True Pred / Total True : 1 / 51
# Accuracy :  2 %
# True Pred / Total True : 1 / 51
# Accuracy :  2 %
# True Pred / Total True : 1 / 51
# Accuracy :  2 %
# True Pred / Total True : 1 / 49
# Accuracy :  2 %
# True Pred / Total True : 1 / 49
# Accuracy :  2 %
# True Pred / Total True : 1 / 47
# Accuracy :  2 %
# True Pred / Total True : 1 / 46
# Accuracy :  2 %
# True Pred / Total True : 1 / 46
# Accuracy :  2 %
# True Pred / Total True : 1 / 45
# Accuracy :  2 %
# True Pred / Total True : 1 / 45
# Accuracy :  2 %
# True Pred / Total True : 1 / 43
# Accuracy :  2 %
# True Pred / Total True : 1 / 37
# Accuracy :  3 %
# True Pred / Total True : 1 / 32
# Accuracy :  3 %
# True Pred / Total True : 1 / 30
# Accuracy :  3 %
# True Pred / Total True : 1 / 28
# Accuracy :  4 %
# True Pred / Total True : 1 / 22
# Accuracy :  5 %
# True Pred / Total True : 1 / 19
# Accuracy :  5 %
# True Pred / Total True : 0 / 13
# Accuracy :  0 %
# True Pred / Total True : 0 / 11
# Accuracy :  0 %
# True Pred / Total True : 0 / 11
# Accuracy :  0 %
# True Pred / Total True : 0 / 9
# Accuracy :  0 %
# True Pred / Total True : 0 / 8
# Accuracy :  0 %
# True Pred / Total True : 0 / 8
# Accuracy :  0 %
# True Pred / Total True : 0 / 6
# Accuracy :  0 %
# True Pred / Total True : 0 / 1
# Accuracy :  0 %
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# True Pred / Total True : 0 / 26
# Accuracy :  0 %
# True Pred / Total True : 0 / 22
# Accuracy :  0 %
# True Pred / Total True : 0 / 19
# Accuracy :  0 %
# True Pred / Total True : 0 / 14
# Accuracy :  0 %
# True Pred / Total True : 0 / 2
# Accuracy :  0 %
# 11/11 [==============================] - 0s 1ms/step
# 10/10 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# True Pred / Total True : 1 / 45
# Accuracy :  2 %
# True Pred / Total True : 1 / 43
# Accuracy :  2 %
# True Pred / Total True : 1 / 40
# Accuracy :  2 %
# True Pred / Total True : 1 / 37
# Accuracy :  3 %
# True Pred / Total True : 1 / 32
# Accuracy :  3 %
# True Pred / Total True : 1 / 26
# Accuracy :  4 %
# True Pred / Total True : 1 / 22
# Accuracy :  5 %
# True Pred / Total True : 0 / 9
# Accuracy :  0 %
# 11/11 [==============================] - 0s 1ms/step
# True Pred / Total True : 25 / 38
# Accuracy : 66 %
# True Pred / Total True : 24 / 37
# Accuracy : 65 %
# True Pred / Total True : 24 / 37
# Accuracy : 65 %
# True Pred / Total True : 24 / 36
# Accuracy : 67 %
# True Pred / Total True : 22 / 34
# Accuracy : 65 %
# True Pred / Total True : 21 / 33
# Accuracy : 64 %
# True Pred / Total True : 20 / 32
# Accuracy : 62 %
# True Pred / Total True : 19 / 31
# Accuracy : 61 %
# True Pred / Total True : 19 / 31
# Accuracy : 61 %
# True Pred / Total True : 17 / 28
# Accuracy : 61 %
# True Pred / Total True : 16 / 27
# Accuracy : 59 %
# True Pred / Total True : 15 / 25
# Accuracy : 60 %
# True Pred / Total True : 14 / 24
# Accuracy : 58 %
# True Pred / Total True : 14 / 23
# Accuracy : 61 %
# True Pred / Total True : 9 / 16
# Accuracy : 56 %
# True Pred / Total True : 9 / 13
# Accuracy : 69 %
# True Pred / Total True : 8 / 9
# Accuracy : 89 %
# True Pred / Total True : 8 / 8
# Accuracy : 100 %
# True Pred / Total True : 8 / 8
# Accuracy : 100 %
# True Pred / Total True : 7 / 7
# Accuracy : 100 %
# True Pred / Total True : 7 / 7
# Accuracy : 100 %
# True Pred / Total True : 7 / 7
# Accuracy : 100 %
# True Pred / Total True : 6 / 6
# Accuracy : 100 %
# True Pred / Total True : 6 / 6
# Accuracy : 100 %
# True Pred / Total True : 6 / 6
# Accuracy : 100 %
# True Pred / Total True : 4 / 4
# Accuracy : 100 %
# True Pred / Total True : 4 / 4
# Accuracy : 100 %
# True Pred / Total True : 3 / 3
# Accuracy : 100 %
# 11/11 [==============================] - 0s 1ms/step
# True Pred / Total True : 18 / 129
# Accuracy : 14 %
# True Pred / Total True : 18 / 129
# Accuracy : 14 %
# True Pred / Total True : 18 / 128
# Accuracy : 14 %
# True Pred / Total True : 18 / 127
# Accuracy : 14 %
# True Pred / Total True : 18 / 126
# Accuracy : 14 %
# True Pred / Total True : 18 / 125
# Accuracy : 14 %
# True Pred / Total True : 18 / 125
# Accuracy : 14 %
# True Pred / Total True : 18 / 125
# Accuracy : 14 %
# True Pred / Total True : 18 / 124
# Accuracy : 15 %
# True Pred / Total True : 18 / 123
# Accuracy : 15 %
# True Pred / Total True : 18 / 123
# Accuracy : 15 %
# True Pred / Total True : 18 / 123
# Accuracy : 15 %
# True Pred / Total True : 18 / 122
# Accuracy : 15 %
# True Pred / Total True : 18 / 122
# Accuracy : 15 %
# True Pred / Total True : 18 / 120
# Accuracy : 15 %
# True Pred / Total True : 18 / 117
# Accuracy : 15 %
# True Pred / Total True : 18 / 116
# Accuracy : 16 %
# True Pred / Total True : 18 / 116
# Accuracy : 16 %
# True Pred / Total True : 18 / 115
# Accuracy : 16 %
# True Pred / Total True : 17 / 112
# Accuracy : 15 %
# True Pred / Total True : 17 / 110
# Accuracy : 15 %
# True Pred / Total True : 17 / 109
# Accuracy : 16 %
# True Pred / Total True : 17 / 109
# Accuracy : 16 %
# True Pred / Total True : 17 / 109
# Accuracy : 16 %
# True Pred / Total True : 17 / 109
# Accuracy : 16 %
# True Pred / Total True : 17 / 109
# Accuracy : 16 %
# True Pred / Total True : 17 / 109
# Accuracy : 16 %
# True Pred / Total True : 17 / 109
# Accuracy : 16 %
# True Pred / Total True : 17 / 108
# Accuracy : 16 %
# True Pred / Total True : 17 / 108
# Accuracy : 16 %
# True Pred / Total True : 17 / 106
# Accuracy : 16 %
# True Pred / Total True : 17 / 104
# Accuracy : 16 %
# True Pred / Total True : 16 / 103
# Accuracy : 16 %
# True Pred / Total True : 16 / 103
# Accuracy : 16 %
# True Pred / Total True : 16 / 100
# Accuracy : 16 %
# True Pred / Total True : 16 / 99
# Accuracy : 16 %
# True Pred / Total True : 16 / 99
# Accuracy : 16 %
# True Pred / Total True : 16 / 98
# Accuracy : 16 %
# True Pred / Total True : 16 / 93
# Accuracy : 17 %
# True Pred / Total True : 16 / 92
# Accuracy : 17 %
# True Pred / Total True : 16 / 91
# Accuracy : 18 %
# True Pred / Total True : 16 / 90
# Accuracy : 18 %
# True Pred / Total True : 15 / 89
# Accuracy : 17 %
# True Pred / Total True : 15 / 88
# Accuracy : 17 %
# True Pred / Total True : 15 / 88
# Accuracy : 17 %
# True Pred / Total True : 14 / 85
# Accuracy : 16 %
# True Pred / Total True : 14 / 84
# Accuracy : 17 %
# True Pred / Total True : 14 / 81
# Accuracy : 17 %
# True Pred / Total True : 14 / 80
# Accuracy : 18 %
# True Pred / Total True : 14 / 79
# Accuracy : 18 %
# True Pred / Total True : 14 / 77
# Accuracy : 18 %
# True Pred / Total True : 13 / 75
# Accuracy : 17 %
# True Pred / Total True : 13 / 74
# Accuracy : 18 %
# True Pred / Total True : 12 / 72
# Accuracy : 17 %
# True Pred / Total True : 11 / 70
# Accuracy : 16 %
# True Pred / Total True : 11 / 69
# Accuracy : 16 %
# True Pred / Total True : 10 / 67
# Accuracy : 15 %
# True Pred / Total True : 9 / 64
# Accuracy : 14 %
# True Pred / Total True : 9 / 61
# Accuracy : 15 %
# True Pred / Total True : 9 / 60
# Accuracy : 15 %
# True Pred / Total True : 9 / 59
# Accuracy : 15 %
# True Pred / Total True : 9 / 57
# Accuracy : 16 %
# True Pred / Total True : 9 / 56
# Accuracy : 16 %
# True Pred / Total True : 9 / 54
# Accuracy : 17 %
# True Pred / Total True : 8 / 52
# Accuracy : 15 %
# True Pred / Total True : 8 / 52
# Accuracy : 15 %
# True Pred / Total True : 8 / 52
# Accuracy : 15 %
# True Pred / Total True : 7 / 48
# Accuracy : 15 %
# True Pred / Total True : 6 / 45
# Accuracy : 13 %
# True Pred / Total True : 6 / 42
# Accuracy : 14 %
# True Pred / Total True : 6 / 41
# Accuracy : 15 %
# True Pred / Total True : 6 / 40
# Accuracy : 15 %
# True Pred / Total True : 6 / 38
# Accuracy : 16 %
# True Pred / Total True : 6 / 37
# Accuracy : 16 %
# True Pred / Total True : 4 / 34
# Accuracy : 12 %
# True Pred / Total True : 4 / 32
# Accuracy : 12 %
# True Pred / Total True : 3 / 31
# Accuracy : 10 %
# True Pred / Total True : 2 / 29
# Accuracy :  7 %
# True Pred / Total True : 2 / 28
# Accuracy :  7 %
# True Pred / Total True : 1 / 26
# Accuracy :  4 %
# True Pred / Total True : 1 / 26
# Accuracy :  4 %
# True Pred / Total True : 1 / 25
# Accuracy :  4 %
# True Pred / Total True : 1 / 25
# Accuracy :  4 %
# True Pred / Total True : 1 / 24
# Accuracy :  4 %
# True Pred / Total True : 1 / 23
# Accuracy :  4 %
# True Pred / Total True : 1 / 23
# Accuracy :  4 %
# True Pred / Total True : 1 / 23
# Accuracy :  4 %
# True Pred / Total True : 1 / 23
# Accuracy :  4 %
# True Pred / Total True : 1 / 21
# Accuracy :  5 %
# True Pred / Total True : 1 / 20
# Accuracy :  5 %
# True Pred / Total True : 1 / 19
# Accuracy :  5 %
# True Pred / Total True : 1 / 19
# Accuracy :  5 %
# True Pred / Total True : 1 / 18
# Accuracy :  6 %
# True Pred / Total True : 1 / 18
# Accuracy :  6 %
# True Pred / Total True : 1 / 16
# Accuracy :  6 %
# True Pred / Total True : 1 / 14
# Accuracy :  7 %
# True Pred / Total True : 1 / 14
# Accuracy :  7 %
# True Pred / Total True : 1 / 10
# Accuracy : 10 %
# True Pred / Total True : 1 / 9
# Accuracy : 11 %
# True Pred / Total True : 1 / 7
# Accuracy : 14 %
# 11/11 [==============================] - 0s 1ms/step
# True Pred / Total True : 34 / 38
# Accuracy : 89 %
# True Pred / Total True : 1 / 1
# Accuracy : 100 %
# 11/11 [==============================] - 0s 1ms/step
# True Pred / Total True : 2 / 2
# Accuracy : 100 %
# 12/12 [==============================] - 0s 1ms/step
# True Pred / Total True : 3 / 5
# Accuracy : 60 %
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# True Pred / Total True : 5 / 35
# Accuracy : 14 %
# True Pred / Total True : 0 / 1
# Accuracy :  0 %
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 1ms/step
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_212.npy'
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_213.npy'
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_214.npy'
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_215.npy'

# %% [markdown]
# ### Check Entry points in Chart

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model


confidence = 0.8
scaled_confidence = column_min + (column_max - column_min) * confidence
# print(scaled_confidence)
print('confidence :', confidence)

y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )
t_te = np.argmax(Y_val, axis=1)

close = Made_X_[-len(X_val):, [-1], [3]]
plt.plot(close)
# plt.show()

long_marker_x = list()
long_marker_y = list()
for i in range(len(y_pred)):
  if y_pred[i] == 1:  
    if t_te[i] == y_pred[i]:
      long_marker_x.append(i)
      long_marker_y.append(close[i])
      

plt.plot(long_marker_x, long_marker_y, 'o', color='blue')
plt.show()
# Out:
# confidence : 0.8
