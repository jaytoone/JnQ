# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-02-11/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-02-11 BTCUSDT.xlsx', '2021-02-11 ETHUSDT.xlsx', '2021-02-11 BCHUSDT.xlsx', '2021-02-11 XRPUSDT.xlsx', '2021-02-11 EOSUSDT.xlsx', '2021-02-11 LTCUSDT.xlsx', '2021-02-11 ETCUSDT.xlsx', '2021-02-11 LINKUSDT.xlsx', '2021-02-11 XLMUSDT.xlsx', '2021-02-11 ADAUSDT.xlsx', '2021-02-11 XMRUSDT.xlsx', '2021-02-11 SXPUSDT.xlsx', '2021-02-11 KAVAUSDT.xlsx', '2021-02-11 BANDUSDT.xlsx', '2021-02-11 DASHUSDT.xlsx', '2021-02-11 ZECUSDT.xlsx', '2021-02-11 XTZUSDT.xlsx', '2021-02-11 BNBUSDT.xlsx', '2021-02-11 ATOMUSDT.xlsx', '2021-02-11 ONTUSDT.xlsx', '2021-02-11 IOTAUSDT.xlsx', '2021-02-11 BATUSDT.xlsx', '2021-02-11 NEOUSDT.xlsx', '2021-02-11 QTUMUSDT.xlsx', '2021-02-11 WAVESUSDT.xlsx', '2021-02-11 MKRUSDT.xlsx', '2021-02-11 SNXUSDT.xlsx', '2021-02-11 DOTUSDT.xlsx', '2021-02-11 THETAUSDT.xlsx', '2021-02-11 ALGOUSDT.xlsx', '2021-02-11 KNCUSDT.xlsx', '2021-02-11 ZRXUSDT.xlsx', '2021-02-11 COMPUSDT.xlsx', '2021-02-11 OMGUSDT.xlsx']

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split

with open('./arima_result/arima_opt_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
  load_dict = pickle.load(f)

candis = list(load_dict.keys())
long_index = 0
leverage = 5
prev_x = None

seed = 1
random_state = 20
np.random.seed(seed)

for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue
  if '2021-03-02 DOTUSDT.xlsx' in candis[i]:
    # print('')
    continue

  if '04-08' not in candis[i]:  # <-- 04-08 includes all timestamp range
    continue

  if 'eth'.upper() not in candis[i]:
    continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      ohlcv = load_dict[key]['ohlcv']
      # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.3)]  # exclude back_range
      # predictions = load_dict[key]['predictions']
      # err_ranges = load_dict[key]['err_ranges']
      print("ohlcv.index[0] :", ohlcv.index[0])
      print("ohlcv.index[-1] :", ohlcv.index[-1])

      predictions = ohlcv['close'].shift(1).values
      err_ranges = np.zeros_like(predictions)

      # leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]

      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = np.array(predictions)
      long_ep = long_ep.reshape(-1, 1)

      #       ma series 7, 30, 60, 120    #
      ma7 = ohlcv['close'].rolling(7).mean()
      ma30 = ohlcv['close'].rolling(30).mean()
      ma60 = ohlcv['close'].rolling(60).mean()
      ma120 = ohlcv['close'].rolling(120).mean()


      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 45
      data_x, data_pr, data_updown = [], [], []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          temp_ma7 = ma7.iloc[i - period : i].values.reshape(-1, 1)
          temp_ma30 = ma30.iloc[i - period : i].values.reshape(-1, 1)
          temp_ma60 = ma60.iloc[i - period : i].values.reshape(-1, 1)
          temp_ma120 = ma120.iloc[i - period : i].values.reshape(-1, 1)

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_ma7, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_ma30, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_ma60, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_ma120, temp_vol))


          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          min_max = MinMaxScaler()
          # temp_data[:, :5] = min_max.fit_transform(temp_data[:, :5])
          temp_data[:, :-1] = min_max.fit_transform(temp_data[:, :-1])


          #   vol -> min_max
          min_max = MinMaxScaler()
          temp_data[:, [-1]] = min_max.fit_transform(temp_data[:, [-1]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)

      
      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      #     do stacking   #
      if prev_x is None:
        prev_x = input_x
        prev_pr = input_pr
        prev_ud = input_ud
      else:
        total_x = np.vstack((prev_x, input_x))
        total_pr = np.vstack((prev_pr, input_pr))
        total_ud = np.vstack((prev_ud, input_ud))

        prev_x = total_x
        prev_pr = total_pr
        prev_ud = total_ud

        print('total_x.shape :', total_x.shape)
        print('total_pr.shape :', total_pr.shape)
        print('total_ud.shape :', total_ud.shape)
      # if prev_train_x is None:
      #   prev_train_x = x_train
      #   prev_val_x = x_val
      #   prev_test_x = x_test
        
      #   prev_train_pr = pr_train
      #   prev_val_pr = pr_val
      #   prev_test_pr = pr_test

      #   prev_train_ud = ud_train
      #   prev_val_ud = ud_val
      #   prev_test_ud = ud_test

      # else:

      #   total_train_x = np.vstack((prev_train_x, x_train))
      #   total_val_x = np.vstack((prev_val_x, x_val))
      #   total_test_x = np.vstack((prev_test_x, x_test))
      #   total_train_pr = np.vstack((prev_train_pr, pr_train))
      #   total_val_pr = np.vstack((prev_val_pr, pr_val))
      #   total_test_pr = np.vstack((prev_test_pr, pr_test))
      #   total_train_ud = np.vstack((prev_train_ud, ud_train))
      #   total_val_ud = np.vstack((prev_val_ud, ud_val))
      #   total_test_ud = np.vstack((prev_test_ud, ud_test))
        
      #   prev_train_x = total_train_x
      #   prev_val_x = total_val_x
      #   prev_test_x = total_test_x
        
      #   prev_train_pr = total_train_pr
      #   prev_val_pr = total_val_pr
      #   prev_test_pr = total_test_pr

      #   prev_train_ud = total_train_ud
      #   prev_val_ud = total_val_ud
      #   prev_test_ud = total_test_ud
        
      #   print("total_train_x.shape :", total_train_x.shape)
      #   print("total_val_x.shape :", total_val_x.shape)
      #   print("total_test_x.shape :", total_test_x.shape)
      #   print("total_train_pr.shape :", total_train_pr.shape)
      #   print("total_val_pr.shape :", total_val_pr.shape)
      #   print("total_test_pr.shape :", total_test_pr.shape)
      #   print("total_train_ud.shape :", total_train_ud.shape)
      #   print("total_val_ud.shape :", total_val_ud.shape)
      #   print("total_test_ud.shape :", total_test_ud.shape)

  break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  # try:
  #   if len(total_x) > 300000:
  #     break
  # except:
  #   pass
# Out:
# ohlcv.index[0] : 2020-04-17 00:29:59.999000
# ohlcv.index[-1] : 2021-04-08 20:29:59.999000
# -------------- 2021-04-08 ETHUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16646, 45, 6)
# input_x.shape : (16646, 90, 12, 3)
# input_x.dtype : float32
# input_pr.shape : (16646, 1)
# input_ud.shape : (16646, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:218: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
period = 45
# x_save_path = current_path + 'npy/' + '%s_close_updown_x.npy' % period
# y_save_path = current_path + 'npy/' + '%s_close_updown_y.npy' % period
#         save to npy     #
# x_save_path = current_path + 'npy/' + '%s_close_updown_theta_x_ex.npy' % period
# y_save_path = current_path + 'npy/' + '%s_close_updown_theta_y_ex.npy' % period

# total_x = np.load(x_save_path)
# total_pr = np.load(y_save_path)

_, row, col, _ = input_x.shape



seed = 1
random_state = 20
np.random.seed(seed)
from sklearn.model_selection import train_test_split
#         train / test split      #
# x_train, x_test_, pr_train, pr_test_, ud_train, ud_test_ = train_test_split(re_input_x, total_pr, total_ud, test_size=0.4, shuffle=True, random_state=random_state)
x_train_, x_test, pr_train_, pr_test = train_test_split(input_x, input_pr, test_size=0.02, shuffle=False, random_state=random_state)
x_train, x_val, pr_train, pr_val = train_test_split(x_train_, pr_train_, test_size=0.25, shuffle=False, random_state=random_state)
# break
#         pr label   #
y_train = np.where(pr_train > 1, 1, 0)
y_test = np.where(pr_test > 1, 1, 0)
y_val = np.where(pr_val > 1, 1, 0)

# del input_x

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape=(row, col, 3)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight
# import cv2


_, row, col, _ = x_train.shape

#         pr label   #
# y_train = np.where(pr_train > 1, 1, 0)
# y_test = np.where(pr_test > 1, 1, 0)
# y_val = np.where(pr_val > 1, 1, 0)


seed = 1
random_state = 20
np.random.seed(seed)
# tf.random.set_seed(seed)

#         up label      #
# y_train = np.where(ud_train > 1, 1, 0)
# y_test = np.where(ud_test > 1, 1, 0)
# y_val = np.where(ud_val > 1, 1, 0)

print('pr_train[:5] :', pr_train[:5])
# print('ud_train[:5] :', ud_train[:5])
print('y_train[:5] :', y_train[:5])
print('y_train.dtype :', y_train.dtype)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

def class_ratio(in_list):

  return in_list / in_list[1]

print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)

datagen = ImageDataGenerator( 
    rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)

batch_size = 16

for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break
# Out:
# pr_train[:5] : [[0.98730326]
#  [0.9846347 ]
#  [0.99877083]
#  [1.0043759 ]
#  [1.0117302 ]]
# y_train[:5] : [[0]
#  [0]
#  [0]
#  [1]
#  [1]]
# y_train.dtype : int64
# x_train.shape : (12234, 90, 12, 3)
# x_test.shape : (333, 90, 12, 3)
# x_val.shape : (4079, 90, 12, 3)
# y_train.shape : (12234, 1)
# y_test.shape : (333, 1)
# y_val.shape : (4079, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([7024, 5210])) [1.34817658 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2160, 1919])) [1.12558624 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([170, 163])) [1.04294479 1.        ]
# class_weights : {0: 0.870871298405467, 1: 1.174088291746641}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (12234, 2)
# y_val_ohe.shape : (4079, 2)
# y_test_ohe.shape : (333, 2)

# %%
# print(x_train[0])

# %% [markdown]
# ### **Training**

# %%
(_, row, col, _) = x_train.shape
  
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_%s_close_updown_pr_theta_non_shuffle_ex_small_test.h5' % period
# model_name = 'classifier_%s_close_updown_pr_theta_non_shuffle_ex_ma7.h5' % period

# model = keras.models.load_model(ckpt_path + model_name)

model = FER_Model(input_shape=(row, col, 3))
opt = Adam(lr=0.00001, decay=0.000005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=40)
# callbacks_list = [checkpoint, checkpoint2, checkpoint3]
callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)
# Out:
# Epoch 1/1000
#  - 18s - loss: 0.7226 - accuracy: 0.5009 - val_loss: 0.6381 - val_accuracy: 0.4982
#
# Epoch 00001: val_loss improved from inf to 0.63809, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_non_shuffle_ex_small_test.h5
# Epoch 2/1000
#  - 17s - loss: 0.7032 - accuracy: 0.5087 - val_loss: 0.8122 - val_accuracy: 0.4773
#
# Epoch 00002: val_loss did not improve from 0.63809
# Epoch 3/1000
#  - 17s - loss: 0.7001 - accuracy: 0.5072 - val_loss: 0.7091 - val_accuracy: 0.5151
#
# Epoch 00003: val_loss did not improve from 0.63809
# Epoch 4/1000
#  - 17s - loss: 0.6975 - accuracy: 0.5074 - val_loss: 0.7004 - val_accuracy: 0.4930
#
# Epoch 00004: val_loss did not improve from 0.63809
# Epoch 5/1000
#  - 17s - loss: 0.6967 - accuracy: 0.5104 - val_loss: 0.7190 - val_accuracy: 0.5058
#
# Epoch 00005: val_loss did not improve from 0.63809
# Epoch 6/1000
#  - 17s - loss: 0.6971 - accuracy: 0.5015 - val_loss: 0.7068 - val_accuracy: 0.5168
#
# Epoch 00006: val_loss did not improve from 0.63809
# Epoch 7/1000
#  - 17s - loss: 0.6950 - accuracy: 0.5154 - val_loss: 0.7243 - val_accuracy: 0.4881
#
# Epoch 00007: val_loss did not improve from 0.63809
# Epoch 8/1000
#  - 17s - loss: 0.6941 - accuracy: 0.5193 - val_loss: 0.6809 - val_accuracy: 0.5183
#
# Epoch 00008: val_loss did not improve from 0.63809
# Epoch 9/1000
#  - 17s - loss: 0.6955 - accuracy: 0.5056 - val_loss: 0.7126 - val_accuracy: 0.5180
#
# Epoch 00009: val_loss did not improve from 0.63809
# Epoch 10/1000
#  - 17s - loss: 0.6939 - accuracy: 0.5198 - val_loss: 0.7044 - val_accuracy: 0.5234
#
# Epoch 00010: val_loss did not improve from 0.63809
# Epoch 11/1000
#  - 17s - loss: 0.6940 - accuracy: 0.5166 - val_loss: 0.6671 - val_accuracy: 0.4893
#
# Epoch 00011: val_loss did not improve from 0.63809
# Epoch 12/1000
#  - 17s - loss: 0.6938 - accuracy: 0.5159 - val_loss: 0.7070 - val_accuracy: 0.5028
#
# Epoch 00012: val_loss did not improve from 0.63809
# Epoch 13/1000
#  - 17s - loss: 0.6938 - accuracy: 0.5146 - val_loss: 0.6596 - val_accuracy: 0.4950
#
# Epoch 00013: val_loss did not improve from 0.63809
# Epoch 14/1000
#  - 17s - loss: 0.6925 - accuracy: 0.5178 - val_loss: 0.7052 - val_accuracy: 0.5291
#
# Epoch 00014: val_loss did not improve from 0.63809
# Epoch 15/1000
#  - 17s - loss: 0.6924 - accuracy: 0.5213 - val_loss: 0.6960 - val_accuracy: 0.5288
#
# Epoch 00015: val_loss did not improve from 0.63809
# Epoch 16/1000
#  - 17s - loss: 0.6930 - accuracy: 0.5135 - val_loss: 0.6530 - val_accuracy: 0.5317
#
# Epoch 00016: val_loss did not improve from 0.63809
# Epoch 17/1000
#  - 17s - loss: 0.6919 - accuracy: 0.5230 - val_loss: 0.7243 - val_accuracy: 0.5087
#
# Epoch 00017: val_loss did not improve from 0.63809
# Epoch 18/1000
#  - 17s - loss: 0.6910 - accuracy: 0.5197 - val_loss: 0.6680 - val_accuracy: 0.5325
#
# Epoch 00018: val_loss did not improve from 0.63809
# Epoch 19/1000
#  - 17s - loss: 0.6892 - accuracy: 0.5325 - val_loss: 0.6987 - val_accuracy: 0.5045
#
# Epoch 00019: val_loss did not improve from 0.63809
# Epoch 20/1000
#  - 17s - loss: 0.6908 - accuracy: 0.5247 - val_loss: 0.7169 - val_accuracy: 0.5102
#
# Epoch 00020: val_loss did not improve from 0.63809
# Epoch 21/1000
#  - 17s - loss: 0.6889 - accuracy: 0.5377 - val_loss: 0.7121 - val_accuracy: 0.4888
#
# Epoch 00021: val_loss did not improve from 0.63809
# Epoch 22/1000
#  - 17s - loss: 0.6896 - accuracy: 0.5335 - val_loss: 0.6661 - val_accuracy: 0.5143
#
# Epoch 00022: val_loss did not improve from 0.63809
# Epoch 23/1000
#  - 17s - loss: 0.6888 - accuracy: 0.5327 - val_loss: 0.6850 - val_accuracy: 0.5163
#
# Epoch 00023: val_loss did not improve from 0.63809
# Epoch 24/1000
#  - 17s - loss: 0.6894 - accuracy: 0.5297 - val_loss: 0.7470 - val_accuracy: 0.4969
#
# Epoch 00024: val_loss did not improve from 0.63809
# Epoch 25/1000
#  - 17s - loss: 0.6897 - accuracy: 0.5257 - val_loss: 0.6649 - val_accuracy: 0.4982
#
# Epoch 00025: val_loss did not improve from 0.63809
# Epoch 26/1000
#  - 17s - loss: 0.6884 - accuracy: 0.5316 - val_loss: 0.7317 - val_accuracy: 0.5033
#
# Epoch 00026: val_loss did not improve from 0.63809
# Epoch 27/1000
#  - 17s - loss: 0.6874 - accuracy: 0.5363 - val_loss: 0.7089 - val_accuracy: 0.5053
#
# Epoch 00027: val_loss did not improve from 0.63809
# Epoch 28/1000
#  - 17s - loss: 0.6884 - accuracy: 0.5316 - val_loss: 0.6647 - val_accuracy: 0.5001
#
# Epoch 00028: val_loss did not improve from 0.63809
# Epoch 29/1000
#  - 17s - loss: 0.6871 - accuracy: 0.5349 - val_loss: 0.6848 - val_accuracy: 0.5168
#
# Epoch 00029: val_loss did not improve from 0.63809
# Epoch 30/1000
#  - 17s - loss: 0.6860 - accuracy: 0.5427 - val_loss: 0.7462 - val_accuracy: 0.5089
#
# Epoch 00030: val_loss did not improve from 0.63809
# Epoch 31/1000
#  - 17s - loss: 0.6844 - accuracy: 0.5445 - val_loss: 0.7070 - val_accuracy: 0.5266
#
# Epoch 00031: val_loss did not improve from 0.63809
# Epoch 32/1000
#  - 17s - loss: 0.6858 - accuracy: 0.5415 - val_loss: 0.7209 - val_accuracy: 0.4915
#
# Epoch 00032: val_loss did not improve from 0.63809
# Epoch 33/1000
#  - 17s - loss: 0.6852 - accuracy: 0.5454 - val_loss: 0.7366 - val_accuracy: 0.5202
#
# Epoch 00033: val_loss did not improve from 0.63809
# Epoch 34/1000
#  - 17s - loss: 0.6843 - accuracy: 0.5421 - val_loss: 0.6274 - val_accuracy: 0.5158
#
# Epoch 00034: val_loss improved from 0.63809 to 0.62743, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_non_shuffle_ex_small_test.h5
# Epoch 35/1000
#  - 17s - loss: 0.6835 - accuracy: 0.5449 - val_loss: 0.6843 - val_accuracy: 0.5067
#
# Epoch 00035: val_loss did not improve from 0.62743
# Epoch 36/1000
#  - 17s - loss: 0.6827 - accuracy: 0.5478 - val_loss: 0.7594 - val_accuracy: 0.5190
#
# Epoch 00036: val_loss did not improve from 0.62743
# Epoch 37/1000
#  - 17s - loss: 0.6825 - accuracy: 0.5475 - val_loss: 0.7588 - val_accuracy: 0.5085
#
# Epoch 00037: val_loss did not improve from 0.62743
# Epoch 38/1000
#  - 17s - loss: 0.6818 - accuracy: 0.5550 - val_loss: 0.6859 - val_accuracy: 0.4994
#
# Epoch 00038: val_loss did not improve from 0.62743
# Epoch 39/1000
#  - 17s - loss: 0.6804 - accuracy: 0.5533 - val_loss: 0.6565 - val_accuracy: 0.5234
#
# Epoch 00039: val_loss did not improve from 0.62743
# Epoch 40/1000
#  - 17s - loss: 0.6790 - accuracy: 0.5582 - val_loss: 0.7346 - val_accuracy: 0.5168
#
# Epoch 00040: val_loss did not improve from 0.62743
# Epoch 41/1000
#  - 17s - loss: 0.6800 - accuracy: 0.5611 - val_loss: 0.6557 - val_accuracy: 0.5173
#
# Epoch 00041: val_loss did not improve from 0.62743
# Epoch 42/1000
#  - 17s - loss: 0.6793 - accuracy: 0.5543 - val_loss: 0.6278 - val_accuracy: 0.5264
#
# Epoch 00042: val_loss did not improve from 0.62743
# Epoch 43/1000
#  - 17s - loss: 0.6778 - accuracy: 0.5605 - val_loss: 0.6938 - val_accuracy: 0.5207
#
# Epoch 00043: val_loss did not improve from 0.62743
# Epoch 44/1000
#  - 17s - loss: 0.6787 - accuracy: 0.5602 - val_loss: 0.6988 - val_accuracy: 0.5212
#
# Epoch 00044: val_loss did not improve from 0.62743
# Epoch 45/1000
#  - 17s - loss: 0.6760 - accuracy: 0.5647 - val_loss: 0.6501 - val_accuracy: 0.5072
#
# Epoch 00045: val_loss did not improve from 0.62743
# Epoch 46/1000
#  - 17s - loss: 0.6768 - accuracy: 0.5623 - val_loss: 0.8449 - val_accuracy: 0.5077
#
# Epoch 00046: val_loss did not improve from 0.62743
# Epoch 47/1000
#  - 17s - loss: 0.6743 - accuracy: 0.5652 - val_loss: 0.8462 - val_accuracy: 0.5112
#
# Epoch 00047: val_loss did not improve from 0.62743
# Epoch 48/1000
#  - 17s - loss: 0.6749 - accuracy: 0.5708 - val_loss: 0.7069 - val_accuracy: 0.5241
#
# Epoch 00048: val_loss did not improve from 0.62743
# Epoch 49/1000
#  - 17s - loss: 0.6755 - accuracy: 0.5670 - val_loss: 0.6795 - val_accuracy: 0.5124
#
# Epoch 00049: val_loss did not improve from 0.62743
# Epoch 50/1000
#  - 17s - loss: 0.6708 - accuracy: 0.5764 - val_loss: 0.6562 - val_accuracy: 0.5281
#
# Epoch 00050: val_loss did not improve from 0.62743
# Epoch 51/1000
#  - 17s - loss: 0.6724 - accuracy: 0.5702 - val_loss: 0.7335 - val_accuracy: 0.5102
#
# Epoch 00051: val_loss did not improve from 0.62743
# Epoch 52/1000
#  - 17s - loss: 0.6718 - accuracy: 0.5669 - val_loss: 0.7116 - val_accuracy: 0.5217
#
# Epoch 00052: val_loss did not improve from 0.62743
# Epoch 53/1000
#  - 17s - loss: 0.6688 - accuracy: 0.5804 - val_loss: 0.6149 - val_accuracy: 0.5109
#
# Epoch 00053: val_loss improved from 0.62743 to 0.61487, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_non_shuffle_ex_small_test.h5
# Epoch 54/1000
#  - 17s - loss: 0.6706 - accuracy: 0.5752 - val_loss: 0.8345 - val_accuracy: 0.5153
#
# Epoch 00054: val_loss did not improve from 0.61487
# Epoch 55/1000
#  - 17s - loss: 0.6703 - accuracy: 0.5687 - val_loss: 0.6334 - val_accuracy: 0.5055
#
# Epoch 00055: val_loss did not improve from 0.61487
# Epoch 56/1000
#  - 17s - loss: 0.6636 - accuracy: 0.5835 - val_loss: 0.6909 - val_accuracy: 0.5126
#
# Epoch 00056: val_loss did not improve from 0.61487
# Epoch 57/1000
#  - 17s - loss: 0.6649 - accuracy: 0.5836 - val_loss: 0.7929 - val_accuracy: 0.5063
#
# Epoch 00057: val_loss did not improve from 0.61487
# Epoch 58/1000
#  - 17s - loss: 0.6650 - accuracy: 0.5802 - val_loss: 0.7182 - val_accuracy: 0.5217
#
# Epoch 00058: val_loss did not improve from 0.61487
# Epoch 59/1000
#  - 17s - loss: 0.6613 - accuracy: 0.5906 - val_loss: 0.6433 - val_accuracy: 0.5143
#
# Epoch 00059: val_loss did not improve from 0.61487
# Epoch 60/1000
#  - 17s - loss: 0.6632 - accuracy: 0.5842 - val_loss: 0.6770 - val_accuracy: 0.5173
#
# Epoch 00060: val_loss did not improve from 0.61487
# Epoch 61/1000
#  - 17s - loss: 0.6613 - accuracy: 0.5965 - val_loss: 0.6655 - val_accuracy: 0.5185
#
# Epoch 00061: val_loss did not improve from 0.61487
# Epoch 62/1000
#  - 17s - loss: 0.6606 - accuracy: 0.5951 - val_loss: 0.6795 - val_accuracy: 0.5099
#
# Epoch 00062: val_loss did not improve from 0.61487
# Epoch 63/1000
#  - 17s - loss: 0.6595 - accuracy: 0.5925 - val_loss: 0.8097 - val_accuracy: 0.5202
#
# Epoch 00063: val_loss did not improve from 0.61487
# Epoch 64/1000
#  - 17s - loss: 0.6577 - accuracy: 0.5953 - val_loss: 0.7915 - val_accuracy: 0.5190
#
# Epoch 00064: val_loss did not improve from 0.61487
# Epoch 65/1000
#  - 17s - loss: 0.6567 - accuracy: 0.5988 - val_loss: 0.6159 - val_accuracy: 0.5053
#
# Epoch 00065: val_loss did not improve from 0.61487
# Epoch 66/1000
#  - 17s - loss: 0.6550 - accuracy: 0.6012 - val_loss: 0.7600 - val_accuracy: 0.5055
#
# Epoch 00066: val_loss did not improve from 0.61487
# Epoch 67/1000
#  - 17s - loss: 0.6519 - accuracy: 0.6058 - val_loss: 0.7486 - val_accuracy: 0.5080
#
# Epoch 00067: val_loss did not improve from 0.61487
# Epoch 68/1000
#  - 17s - loss: 0.6535 - accuracy: 0.5996 - val_loss: 0.6777 - val_accuracy: 0.5121
#
# Epoch 00068: val_loss did not improve from 0.61487
# Epoch 69/1000
#  - 17s - loss: 0.6520 - accuracy: 0.5994 - val_loss: 0.8453 - val_accuracy: 0.5163
#
# Epoch 00069: val_loss did not improve from 0.61487
# Epoch 70/1000
#  - 17s - loss: 0.6492 - accuracy: 0.6083 - val_loss: 0.5817 - val_accuracy: 0.5200
#
# Epoch 00070: val_loss improved from 0.61487 to 0.58165, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_non_shuffle_ex_small_test.h5
# Epoch 71/1000
#  - 17s - loss: 0.6524 - accuracy: 0.6051 - val_loss: 0.7186 - val_accuracy: 0.5097
#
# Epoch 00071: val_loss did not improve from 0.58165
# Epoch 72/1000
#  - 17s - loss: 0.6467 - accuracy: 0.6083 - val_loss: 0.6629 - val_accuracy: 0.5200
#
# Epoch 00072: val_loss did not improve from 0.58165
# Epoch 73/1000
#  - 17s - loss: 0.6449 - accuracy: 0.6136 - val_loss: 0.9163 - val_accuracy: 0.5067
#
# Epoch 00073: val_loss did not improve from 0.58165
# Epoch 74/1000
#  - 16s - loss: 0.6454 - accuracy: 0.6118 - val_loss: 0.8717 - val_accuracy: 0.5048
#
# Epoch 00074: val_loss did not improve from 0.58165
# Epoch 75/1000
#  - 16s - loss: 0.6455 - accuracy: 0.6146 - val_loss: 0.7795 - val_accuracy: 0.5006
#
# Epoch 00075: val_loss did not improve from 0.58165
# Epoch 76/1000
#  - 16s - loss: 0.6409 - accuracy: 0.6199 - val_loss: 0.7053 - val_accuracy: 0.5021
#
# Epoch 00076: val_loss did not improve from 0.58165
# Epoch 77/1000
#  - 16s - loss: 0.6402 - accuracy: 0.6202 - val_loss: 0.8401 - val_accuracy: 0.5143
#
# Epoch 00077: val_loss did not improve from 0.58165
# Epoch 78/1000
#  - 16s - loss: 0.6383 - accuracy: 0.6282 - val_loss: 0.7359 - val_accuracy: 0.4977
#
# Epoch 00078: val_loss did not improve from 0.58165
# Epoch 79/1000
#  - 16s - loss: 0.6411 - accuracy: 0.6149 - val_loss: 0.6759 - val_accuracy: 0.5048
#
# Epoch 00079: val_loss did not improve from 0.58165
# Epoch 80/1000
#  - 16s - loss: 0.6385 - accuracy: 0.6188 - val_loss: 0.7615 - val_accuracy: 0.5097
#
# Epoch 00080: val_loss did not improve from 0.58165
# Epoch 81/1000
#  - 17s - loss: 0.6337 - accuracy: 0.6265 - val_loss: 0.8591 - val_accuracy: 0.5107
#
# Epoch 00081: val_loss did not improve from 0.58165
# Epoch 82/1000
#  - 17s - loss: 0.6354 - accuracy: 0.6240 - val_loss: 0.7879 - val_accuracy: 0.5001
#
# Epoch 00082: val_loss did not improve from 0.58165
# Epoch 83/1000
#  - 17s - loss: 0.6352 - accuracy: 0.6221 - val_loss: 0.8441 - val_accuracy: 0.5055
#
# Epoch 00083: val_loss did not improve from 0.58165
# Epoch 84/1000
#  - 17s - loss: 0.6303 - accuracy: 0.6283 - val_loss: 0.6267 - val_accuracy: 0.5087
#
# Epoch 00084: val_loss did not improve from 0.58165
# Epoch 85/1000
#  - 17s - loss: 0.6307 - accuracy: 0.6270 - val_loss: 0.7140 - val_accuracy: 0.5087
#
# Epoch 00085: val_loss did not improve from 0.58165
# Epoch 86/1000
#  - 17s - loss: 0.6317 - accuracy: 0.6288 - val_loss: 0.7259 - val_accuracy: 0.5087
#
# Epoch 00086: val_loss did not improve from 0.58165
# Epoch 87/1000
#  - 17s - loss: 0.6290 - accuracy: 0.6338 - val_loss: 0.7802 - val_accuracy: 0.4950
#
# Epoch 00087: val_loss did not improve from 0.58165
# Epoch 88/1000
#  - 16s - loss: 0.6279 - accuracy: 0.6338 - val_loss: 0.6540 - val_accuracy: 0.5063
#
# Epoch 00088: val_loss did not improve from 0.58165
# Epoch 89/1000
#  - 16s - loss: 0.6270 - accuracy: 0.6362 - val_loss: 0.6259 - val_accuracy: 0.5085
#
# Epoch 00089: val_loss did not improve from 0.58165
# Epoch 90/1000
#  - 16s - loss: 0.6232 - accuracy: 0.6387 - val_loss: 0.5886 - val_accuracy: 0.5033
#
# Epoch 00090: val_loss did not improve from 0.58165
# Epoch 91/1000
#  - 16s - loss: 0.6216 - accuracy: 0.6401 - val_loss: 1.0213 - val_accuracy: 0.5001
#
# Epoch 00091: val_loss did not improve from 0.58165
# Epoch 92/1000
#  - 16s - loss: 0.6221 - accuracy: 0.6384 - val_loss: 0.7256 - val_accuracy: 0.5094
#
# Epoch 00092: val_loss did not improve from 0.58165
# Epoch 93/1000
#  - 17s - loss: 0.6197 - accuracy: 0.6378 - val_loss: 0.8120 - val_accuracy: 0.5112
#
# Epoch 00093: val_loss did not improve from 0.58165
# Epoch 94/1000
#  - 16s - loss: 0.6197 - accuracy: 0.6412 - val_loss: 0.7064 - val_accuracy: 0.5023
#
# Epoch 00094: val_loss did not improve from 0.58165
# Epoch 95/1000
#  - 17s - loss: 0.6172 - accuracy: 0.6459 - val_loss: 0.8170 - val_accuracy: 0.5151
#
# Epoch 00095: val_loss did not improve from 0.58165
# Epoch 96/1000
#  - 17s - loss: 0.6164 - accuracy: 0.6489 - val_loss: 0.9137 - val_accuracy: 0.5136
#
# Epoch 00096: val_loss did not improve from 0.58165
# Epoch 97/1000
#  - 16s - loss: 0.6159 - accuracy: 0.6439 - val_loss: 0.6364 - val_accuracy: 0.5148
#
# Epoch 00097: val_loss did not improve from 0.58165
# Epoch 98/1000
#  - 16s - loss: 0.6139 - accuracy: 0.6507 - val_loss: 1.0511 - val_accuracy: 0.5107
#
# Epoch 00098: val_loss did not improve from 0.58165
# Epoch 99/1000
#  - 16s - loss: 0.6103 - accuracy: 0.6512 - val_loss: 0.7293 - val_accuracy: 0.5077
#
# Epoch 00099: val_loss did not improve from 0.58165
# Epoch 100/1000
#  - 16s - loss: 0.6089 - accuracy: 0.6505 - val_loss: 0.7950 - val_accuracy: 0.4994
#
# Epoch 00100: val_loss did not improve from 0.58165
# Epoch 101/1000
#  - 16s - loss: 0.6067 - accuracy: 0.6553 - val_loss: 0.9771 - val_accuracy: 0.5092
#
# Epoch 00101: val_loss did not improve from 0.58165
# Epoch 102/1000
#  - 16s - loss: 0.6083 - accuracy: 0.6522 - val_loss: 0.8057 - val_accuracy: 0.5102
#
# Epoch 00102: val_loss did not improve from 0.58165
# Epoch 103/1000
#  - 16s - loss: 0.6087 - accuracy: 0.6542 - val_loss: 0.8109 - val_accuracy: 0.5080
#
# Epoch 00103: val_loss did not improve from 0.58165
# Epoch 104/1000
#  - 16s - loss: 0.6064 - accuracy: 0.6520 - val_loss: 0.7919 - val_accuracy: 0.5099
#
# Epoch 00104: val_loss did not improve from 0.58165
# Epoch 105/1000
#  - 16s - loss: 0.6013 - accuracy: 0.6568 - val_loss: 0.7920 - val_accuracy: 0.5124
#
# Epoch 00105: val_loss did not improve from 0.58165
# Epoch 106/1000
#  - 16s - loss: 0.6014 - accuracy: 0.6616 - val_loss: 1.0962 - val_accuracy: 0.5072
#
# Epoch 00106: val_loss did not improve from 0.58165
# Epoch 107/1000
#  - 16s - loss: 0.5991 - accuracy: 0.6623 - val_loss: 0.7854 - val_accuracy: 0.5013
#
# Epoch 00107: val_loss did not improve from 0.58165
# Epoch 108/1000
#  - 16s - loss: 0.5995 - accuracy: 0.6603 - val_loss: 0.7000 - val_accuracy: 0.5102
#
# Epoch 00108: val_loss did not improve from 0.58165
# Epoch 109/1000
#  - 16s - loss: 0.5952 - accuracy: 0.6715 - val_loss: 0.7418 - val_accuracy: 0.4962
#
# Epoch 00109: val_loss did not improve from 0.58165
# Epoch 110/1000
#  - 16s - loss: 0.5966 - accuracy: 0.6683 - val_loss: 0.8135 - val_accuracy: 0.5153
#
# Epoch 00110: val_loss did not improve from 0.58165
# Epoch 111/1000
#  - 16s - loss: 0.5916 - accuracy: 0.6727 - val_loss: 0.7000 - val_accuracy: 0.4996
#
# Epoch 00111: val_loss did not improve from 0.58165
# Epoch 112/1000
#  - 16s - loss: 0.5932 - accuracy: 0.6720 - val_loss: 0.7417 - val_accuracy: 0.5004
#
# Epoch 00112: val_loss did not improve from 0.58165
# Epoch 113/1000
#  - 16s - loss: 0.5945 - accuracy: 0.6633 - val_loss: 0.7738 - val_accuracy: 0.5099
#
# Epoch 00113: val_loss did not improve from 0.58165
# Epoch 114/1000
#  - 16s - loss: 0.5877 - accuracy: 0.6756 - val_loss: 0.6297 - val_accuracy: 0.5026
#
# Epoch 00114: val_loss did not improve from 0.58165
# Epoch 115/1000
#  - 16s - loss: 0.5879 - accuracy: 0.6703 - val_loss: 0.6225 - val_accuracy: 0.5048
#
# Epoch 00115: val_loss did not improve from 0.58165
# Epoch 116/1000
#  - 16s - loss: 0.5857 - accuracy: 0.6750 - val_loss: 0.9619 - val_accuracy: 0.4974
#
# Epoch 00116: val_loss did not improve from 0.58165
# Epoch 117/1000
#  - 16s - loss: 0.5881 - accuracy: 0.6751 - val_loss: 0.4866 - val_accuracy: 0.5026
#
# Epoch 00117: val_loss improved from 0.58165 to 0.48655, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_non_shuffle_ex_small_test.h5
# Epoch 118/1000
#  - 17s - loss: 0.5831 - accuracy: 0.6796 - val_loss: 1.3758 - val_accuracy: 0.5040
#
# Epoch 00118: val_loss did not improve from 0.48655
# Epoch 119/1000
#  - 16s - loss: 0.5791 - accuracy: 0.6791 - val_loss: 0.7290 - val_accuracy: 0.5089
#
# Epoch 00119: val_loss did not improve from 0.48655
# Epoch 120/1000
#  - 16s - loss: 0.5829 - accuracy: 0.6775 - val_loss: 0.5914 - val_accuracy: 0.5013
#
# Epoch 00120: val_loss did not improve from 0.48655
# Epoch 121/1000
#  - 16s - loss: 0.5804 - accuracy: 0.6813 - val_loss: 0.7160 - val_accuracy: 0.5050
#
# Epoch 00121: val_loss did not improve from 0.48655
# Epoch 122/1000
#  - 16s - loss: 0.5792 - accuracy: 0.6829 - val_loss: 0.8608 - val_accuracy: 0.5048
#
# Epoch 00122: val_loss did not improve from 0.48655
# Epoch 123/1000
#  - 17s - loss: 0.5766 - accuracy: 0.6836 - val_loss: 0.5683 - val_accuracy: 0.5060
#
# Epoch 00123: val_loss did not improve from 0.48655
# Epoch 124/1000
#  - 17s - loss: 0.5783 - accuracy: 0.6803 - val_loss: 0.6221 - val_accuracy: 0.5016
#
# Epoch 00124: val_loss did not improve from 0.48655
# Epoch 125/1000
#  - 17s - loss: 0.5794 - accuracy: 0.6771 - val_loss: 0.7586 - val_accuracy: 0.5036
#
# Epoch 00125: val_loss did not improve from 0.48655
# Epoch 126/1000
#  - 17s - loss: 0.5711 - accuracy: 0.6891 - val_loss: 0.7551 - val_accuracy: 0.5040
#
# Epoch 00126: val_loss did not improve from 0.48655
# Epoch 127/1000
#  - 17s - loss: 0.5754 - accuracy: 0.6820 - val_loss: 1.0046 - val_accuracy: 0.4967
#
# Epoch 00127: val_loss did not improve from 0.48655
# Epoch 128/1000
#  - 17s - loss: 0.5705 - accuracy: 0.6846 - val_loss: 0.7067 - val_accuracy: 0.5058
#
# Epoch 00128: val_loss did not improve from 0.48655
# Epoch 129/1000
#  - 17s - loss: 0.5687 - accuracy: 0.6927 - val_loss: 1.1219 - val_accuracy: 0.5048
#
# Epoch 00129: val_loss did not improve from 0.48655
# Epoch 130/1000
#  - 17s - loss: 0.5712 - accuracy: 0.6905 - val_loss: 0.7378 - val_accuracy: 0.5011
#
# Epoch 00130: val_loss did not improve from 0.48655
# Epoch 131/1000
#  - 17s - loss: 0.5704 - accuracy: 0.6881 - val_loss: 0.7990 - val_accuracy: 0.5016
#
# Epoch 00131: val_loss did not improve from 0.48655
# Epoch 132/1000
#  - 17s - loss: 0.5597 - accuracy: 0.6992 - val_loss: 0.6674 - val_accuracy: 0.4977
#
# Epoch 00132: val_loss did not improve from 0.48655
# Epoch 133/1000
#  - 17s - loss: 0.5622 - accuracy: 0.6947 - val_loss: 0.6862 - val_accuracy: 0.5006
#
# Epoch 00133: val_loss did not improve from 0.48655
# Epoch 134/1000
#  - 17s - loss: 0.5637 - accuracy: 0.6957 - val_loss: 0.8478 - val_accuracy: 0.5094
#
# Epoch 00134: val_loss did not improve from 0.48655
# Epoch 135/1000
#  - 17s - loss: 0.5528 - accuracy: 0.7021 - val_loss: 0.9167 - val_accuracy: 0.5013
#
# Epoch 00135: val_loss did not improve from 0.48655
# Epoch 136/1000
#  - 17s - loss: 0.5600 - accuracy: 0.6954 - val_loss: 0.7833 - val_accuracy: 0.5048
#
# Epoch 00136: val_loss did not improve from 0.48655
# Epoch 137/1000
#  - 17s - loss: 0.5591 - accuracy: 0.6973 - val_loss: 1.1235 - val_accuracy: 0.4989
#
# Epoch 00137: val_loss did not improve from 0.48655
# Epoch 138/1000
#  - 17s - loss: 0.5538 - accuracy: 0.7029 - val_loss: 1.0764 - val_accuracy: 0.4969
#
# Epoch 00138: val_loss did not improve from 0.48655
# Epoch 139/1000
#  - 17s - loss: 0.5542 - accuracy: 0.7052 - val_loss: 0.8945 - val_accuracy: 0.4972
#
# Epoch 00139: val_loss did not improve from 0.48655
# Epoch 140/1000
#  - 17s - loss: 0.5487 - accuracy: 0.7081 - val_loss: 0.5478 - val_accuracy: 0.4920
#
# Epoch 00140: val_loss did not improve from 0.48655
# Epoch 141/1000
#  - 17s - loss: 0.5466 - accuracy: 0.7116 - val_loss: 0.9959 - val_accuracy: 0.4920
#
# Epoch 00141: val_loss did not improve from 0.48655
# Epoch 142/1000
#  - 17s - loss: 0.5426 - accuracy: 0.7147 - val_loss: 0.6074 - val_accuracy: 0.5080
#
# Epoch 00142: val_loss did not improve from 0.48655
# Epoch 143/1000
#  - 17s - loss: 0.5422 - accuracy: 0.7127 - val_loss: 0.6672 - val_accuracy: 0.4987
#
# Epoch 00143: val_loss did not improve from 0.48655
# Epoch 144/1000
#  - 17s - loss: 0.5474 - accuracy: 0.7080 - val_loss: 0.5126 - val_accuracy: 0.5011
#
# Epoch 00144: val_loss did not improve from 0.48655
# Epoch 145/1000
#  - 17s - loss: 0.5472 - accuracy: 0.7085 - val_loss: 0.6746 - val_accuracy: 0.4955
#
# Epoch 00145: val_loss did not improve from 0.48655
# Epoch 146/1000
#  - 17s - loss: 0.5417 - accuracy: 0.7141 - val_loss: 0.9157 - val_accuracy: 0.5006
#
# Epoch 00146: val_loss did not improve from 0.48655
# Epoch 147/1000
#  - 16s - loss: 0.5376 - accuracy: 0.7164 - val_loss: 0.8654 - val_accuracy: 0.4964
#
# Epoch 00147: val_loss did not improve from 0.48655
# Epoch 148/1000
#  - 16s - loss: 0.5423 - accuracy: 0.7117 - val_loss: 0.9732 - val_accuracy: 0.5048
#
# Epoch 00148: val_loss did not improve from 0.48655
# Epoch 149/1000
#  - 17s - loss: 0.5361 - accuracy: 0.7181 - val_loss: 0.9604 - val_accuracy: 0.5072
#
# Epoch 00149: val_loss did not improve from 0.48655
# Epoch 150/1000
#  - 17s - loss: 0.5357 - accuracy: 0.7215 - val_loss: 1.1188 - val_accuracy: 0.4996
#
# Epoch 00150: val_loss did not improve from 0.48655
# Epoch 151/1000
#  - 17s - loss: 0.5345 - accuracy: 0.7151 - val_loss: 0.6649 - val_accuracy: 0.5048
#
# Epoch 00151: val_loss did not improve from 0.48655
# Epoch 152/1000
#  - 17s - loss: 0.5380 - accuracy: 0.7155 - val_loss: 1.1162 - val_accuracy: 0.4822
#
# Epoch 00152: val_loss did not improve from 0.48655
# Epoch 153/1000
#  - 17s - loss: 0.5288 - accuracy: 0.7264 - val_loss: 0.9690 - val_accuracy: 0.5097
#
# Epoch 00153: val_loss did not improve from 0.48655
# Epoch 154/1000
#  - 17s - loss: 0.5319 - accuracy: 0.7233 - val_loss: 0.6424 - val_accuracy: 0.5107
#
# Epoch 00154: val_loss did not improve from 0.48655
# Epoch 155/1000
#  - 17s - loss: 0.5262 - accuracy: 0.7278 - val_loss: 0.8545 - val_accuracy: 0.5048
#
# Epoch 00155: val_loss did not improve from 0.48655
# Epoch 156/1000
#  - 17s - loss: 0.5274 - accuracy: 0.7245 - val_loss: 0.9168 - val_accuracy: 0.5063
#
# Epoch 00156: val_loss did not improve from 0.48655
# Epoch 157/1000
#  - 16s - loss: 0.5277 - accuracy: 0.7240 - val_loss: 0.8040 - val_accuracy: 0.5026
#
# Epoch 00157: val_loss did not improve from 0.48655
# Epoch 158/1000
#  - 17s - loss: 0.5226 - accuracy: 0.7281 - val_loss: 0.3908 - val_accuracy: 0.5082
#
# Epoch 00158: val_loss improved from 0.48655 to 0.39079, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_non_shuffle_ex_small_test.h5
# Epoch 159/1000
#  - 17s - loss: 0.5291 - accuracy: 0.7231 - val_loss: 1.0277 - val_accuracy: 0.4991
#
# Epoch 00159: val_loss did not improve from 0.39079
# Epoch 160/1000
#  - 16s - loss: 0.5219 - accuracy: 0.7317 - val_loss: 0.8111 - val_accuracy: 0.5038
#
# Epoch 00160: val_loss did not improve from 0.39079
# Epoch 161/1000
#  - 16s - loss: 0.5212 - accuracy: 0.7321 - val_loss: 0.7061 - val_accuracy: 0.5136
#
# Epoch 00161: val_loss did not improve from 0.39079
# Epoch 162/1000
#  - 16s - loss: 0.5230 - accuracy: 0.7275 - val_loss: 0.7508 - val_accuracy: 0.5114
#
# Epoch 00162: val_loss did not improve from 0.39079
# Epoch 163/1000
#  - 17s - loss: 0.5165 - accuracy: 0.7344 - val_loss: 1.2906 - val_accuracy: 0.5077
#
# Epoch 00163: val_loss did not improve from 0.39079
# Epoch 164/1000
#  - 16s - loss: 0.5162 - accuracy: 0.7380 - val_loss: 0.7585 - val_accuracy: 0.5134
#
# Epoch 00164: val_loss did not improve from 0.39079
# Epoch 165/1000
#  - 17s - loss: 0.5122 - accuracy: 0.7395 - val_loss: 1.1317 - val_accuracy: 0.5087
#
# Epoch 00165: val_loss did not improve from 0.39079
# Epoch 166/1000
#  - 17s - loss: 0.5091 - accuracy: 0.7417 - val_loss: 0.8181 - val_accuracy: 0.5134
#
# Epoch 00166: val_loss did not improve from 0.39079
# Epoch 167/1000
#  - 17s - loss: 0.5135 - accuracy: 0.7334 - val_loss: 0.6739 - val_accuracy: 0.5092
#
# Epoch 00167: val_loss did not improve from 0.39079
# Epoch 168/1000
#  - 17s - loss: 0.5112 - accuracy: 0.7395 - val_loss: 1.0930 - val_accuracy: 0.5065
#
# Epoch 00168: val_loss did not improve from 0.39079
# Epoch 169/1000
#  - 17s - loss: 0.5067 - accuracy: 0.7410 - val_loss: 0.7174 - val_accuracy: 0.5107
#
# Epoch 00169: val_loss did not improve from 0.39079
# Epoch 170/1000
#  - 17s - loss: 0.5079 - accuracy: 0.7379 - val_loss: 1.0889 - val_accuracy: 0.5116
#
# Epoch 00170: val_loss did not improve from 0.39079
# Epoch 171/1000
#  - 17s - loss: 0.5068 - accuracy: 0.7385 - val_loss: 0.9237 - val_accuracy: 0.5094
#
# Epoch 00171: val_loss did not improve from 0.39079
# Epoch 172/1000
#  - 17s - loss: 0.5018 - accuracy: 0.7466 - val_loss: 1.5977 - val_accuracy: 0.5018
#
# Epoch 00172: val_loss did not improve from 0.39079
# Epoch 173/1000
#  - 17s - loss: 0.5014 - accuracy: 0.7482 - val_loss: 0.8259 - val_accuracy: 0.5183
#
# Epoch 00173: val_loss did not improve from 0.39079
# Epoch 174/1000
#  - 16s - loss: 0.5002 - accuracy: 0.7494 - val_loss: 1.2131 - val_accuracy: 0.5043
#
# Epoch 00174: val_loss did not improve from 0.39079
# Epoch 175/1000
#  - 16s - loss: 0.4977 - accuracy: 0.7415 - val_loss: 0.9429 - val_accuracy: 0.5033
#
# Epoch 00175: val_loss did not improve from 0.39079
# Epoch 176/1000
#  - 17s - loss: 0.4986 - accuracy: 0.7472 - val_loss: 1.0028 - val_accuracy: 0.4967
#
# Epoch 00176: val_loss did not improve from 0.39079
# Epoch 177/1000
#  - 17s - loss: 0.4963 - accuracy: 0.7513 - val_loss: 1.2586 - val_accuracy: 0.5043
#
# Epoch 00177: val_loss did not improve from 0.39079
# Epoch 178/1000
#  - 17s - loss: 0.4960 - accuracy: 0.7470 - val_loss: 0.6238 - val_accuracy: 0.5063
#
# Epoch 00178: val_loss did not improve from 0.39079
# Epoch 179/1000
#  - 17s - loss: 0.4942 - accuracy: 0.7498 - val_loss: 0.7162 - val_accuracy: 0.5085
#
# Epoch 00179: val_loss did not improve from 0.39079
# Epoch 180/1000
#  - 17s - loss: 0.4924 - accuracy: 0.7519 - val_loss: 0.7982 - val_accuracy: 0.5045
#
# Epoch 00180: val_loss did not improve from 0.39079
# Epoch 181/1000
#  - 17s - loss: 0.4858 - accuracy: 0.7595 - val_loss: 1.1621 - val_accuracy: 0.5016
#
# Epoch 00181: val_loss did not improve from 0.39079
# Epoch 182/1000
#  - 16s - loss: 0.4889 - accuracy: 0.7500 - val_loss: 0.6969 - val_accuracy: 0.5006
#
# Epoch 00182: val_loss did not improve from 0.39079
# Epoch 183/1000
#  - 17s - loss: 0.4898 - accuracy: 0.7525 - val_loss: 1.2663 - val_accuracy: 0.5077
#
# Epoch 00183: val_loss did not improve from 0.39079
# Epoch 184/1000
#  - 17s - loss: 0.4792 - accuracy: 0.7616 - val_loss: 0.7792 - val_accuracy: 0.4996
#
# Epoch 00184: val_loss did not improve from 0.39079
# Epoch 185/1000
#  - 17s - loss: 0.4910 - accuracy: 0.7522 - val_loss: 1.5839 - val_accuracy: 0.5026
#
# Epoch 00185: val_loss did not improve from 0.39079
# Epoch 186/1000
#  - 16s - loss: 0.4829 - accuracy: 0.7559 - val_loss: 0.9110 - val_accuracy: 0.5021
#
# Epoch 00186: val_loss did not improve from 0.39079
# Epoch 187/1000
#  - 17s - loss: 0.4797 - accuracy: 0.7585 - val_loss: 0.6598 - val_accuracy: 0.5058
#
# Epoch 00187: val_loss did not improve from 0.39079
# Epoch 188/1000
#  - 16s - loss: 0.4856 - accuracy: 0.7546 - val_loss: 1.0280 - val_accuracy: 0.5016
#
# Epoch 00188: val_loss did not improve from 0.39079
# Epoch 189/1000
#  - 16s - loss: 0.4833 - accuracy: 0.7540 - val_loss: 1.0852 - val_accuracy: 0.5026
#
# Epoch 00189: val_loss did not improve from 0.39079
# Epoch 190/1000
#  - 16s - loss: 0.4781 - accuracy: 0.7605 - val_loss: 1.2582 - val_accuracy: 0.5038
#
# Epoch 00190: val_loss did not improve from 0.39079
# Epoch 191/1000
#  - 16s - loss: 0.4771 - accuracy: 0.7634 - val_loss: 1.2419 - val_accuracy: 0.4967
#
# Epoch 00191: val_loss did not improve from 0.39079
# Epoch 192/1000
#  - 16s - loss: 0.4686 - accuracy: 0.7708 - val_loss: 0.8379 - val_accuracy: 0.5045
#
# Epoch 00192: val_loss did not improve from 0.39079
# Epoch 193/1000
#  - 16s - loss: 0.4667 - accuracy: 0.7733 - val_loss: 0.8227 - val_accuracy: 0.5013
#
# Epoch 00193: val_loss did not improve from 0.39079
# Epoch 194/1000
#  - 16s - loss: 0.4757 - accuracy: 0.7630 - val_loss: 1.1083 - val_accuracy: 0.4930
#
# Epoch 00194: val_loss did not improve from 0.39079
# Epoch 195/1000
#  - 16s - loss: 0.4747 - accuracy: 0.7625 - val_loss: 0.7791 - val_accuracy: 0.4982
#
# Epoch 00195: val_loss did not improve from 0.39079
# Epoch 196/1000
#  - 16s - loss: 0.4640 - accuracy: 0.7693 - val_loss: 1.3110 - val_accuracy: 0.4984
#
# Epoch 00196: val_loss did not improve from 0.39079
# Epoch 197/1000
#  - 16s - loss: 0.4713 - accuracy: 0.7627 - val_loss: 0.9376 - val_accuracy: 0.4945
#
# Epoch 00197: val_loss did not improve from 0.39079
# Epoch 198/1000
#  - 16s - loss: 0.4684 - accuracy: 0.7669 - val_loss: 1.5510 - val_accuracy: 0.4972
#
# Epoch 00198: val_loss did not improve from 0.39079
# Epoch 199/1000
#  - 16s - loss: 0.4661 - accuracy: 0.7706 - val_loss: 0.9720 - val_accuracy: 0.4962
#
# Epoch 00199: val_loss did not improve from 0.39079
# Epoch 200/1000
#  - 16s - loss: 0.4618 - accuracy: 0.7761 - val_loss: 0.7607 - val_accuracy: 0.4937
#
# Epoch 00200: val_loss did not improve from 0.39079
# Epoch 201/1000
#  - 16s - loss: 0.4640 - accuracy: 0.7687 - val_loss: 1.0096 - val_accuracy: 0.4979
#
# Epoch 00201: val_loss did not improve from 0.39079
# Epoch 202/1000
#  - 16s - loss: 0.4676 - accuracy: 0.7692 - val_loss: 1.4053 - val_accuracy: 0.4962
#
# Epoch 00202: val_loss did not improve from 0.39079
# Epoch 203/1000
#  - 17s - loss: 0.4588 - accuracy: 0.7730 - val_loss: 1.0198 - val_accuracy: 0.5094
#
# Epoch 00203: val_loss did not improve from 0.39079
# Epoch 204/1000
#  - 16s - loss: 0.4545 - accuracy: 0.7781 - val_loss: 0.8139 - val_accuracy: 0.5082
#
# Epoch 00204: val_loss did not improve from 0.39079
# Epoch 205/1000
#  - 17s - loss: 0.4511 - accuracy: 0.7786 - val_loss: 0.5467 - val_accuracy: 0.5028
#
# Epoch 00205: val_loss did not improve from 0.39079
# Epoch 206/1000
#  - 16s - loss: 0.4569 - accuracy: 0.7731 - val_loss: 0.7881 - val_accuracy: 0.5060
#
# Epoch 00206: val_loss did not improve from 0.39079
# Epoch 207/1000
#  - 16s - loss: 0.4514 - accuracy: 0.7785 - val_loss: 1.1401 - val_accuracy: 0.5060
#
# Epoch 00207: val_loss did not improve from 0.39079
# Epoch 208/1000
#  - 16s - loss: 0.4545 - accuracy: 0.7791 - val_loss: 0.9944 - val_accuracy: 0.5011
#
# Epoch 00208: val_loss did not improve from 0.39079
# Epoch 209/1000
#  - 16s - loss: 0.4464 - accuracy: 0.7804 - val_loss: 0.7917 - val_accuracy: 0.5070
#
# Epoch 00209: val_loss did not improve from 0.39079
# Epoch 210/1000
#  - 16s - loss: 0.4486 - accuracy: 0.7766 - val_loss: 0.9383 - val_accuracy: 0.5045
#
# Epoch 00210: val_loss did not improve from 0.39079
# Epoch 211/1000
#  - 17s - loss: 0.4519 - accuracy: 0.7760 - val_loss: 1.5440 - val_accuracy: 0.5045
#
# Epoch 00211: val_loss did not improve from 0.39079
# Epoch 212/1000
#  - 16s - loss: 0.4420 - accuracy: 0.7822 - val_loss: 0.9341 - val_accuracy: 0.5016
#
# Epoch 00212: val_loss did not improve from 0.39079
# Epoch 213/1000
#  - 17s - loss: 0.4483 - accuracy: 0.7827 - val_loss: 1.7597 - val_accuracy: 0.5033
#
# Epoch 00213: val_loss did not improve from 0.39079
# Epoch 214/1000
#  - 17s - loss: 0.4474 - accuracy: 0.7822 - val_loss: 0.9257 - val_accuracy: 0.4972
#
# Epoch 00214: val_loss did not improve from 0.39079
# Epoch 215/1000
#  - 17s - loss: 0.4333 - accuracy: 0.7900 - val_loss: 1.1962 - val_accuracy: 0.4964
#
# Epoch 00215: val_loss did not improve from 0.39079
# Epoch 216/1000
#  - 17s - loss: 0.4409 - accuracy: 0.7851 - val_loss: 1.6730 - val_accuracy: 0.4996
#
# Epoch 00216: val_loss did not improve from 0.39079
# Epoch 217/1000
#  - 16s - loss: 0.4405 - accuracy: 0.7872 - val_loss: 1.5658 - val_accuracy: 0.5006
#
# Epoch 00217: val_loss did not improve from 0.39079
# Epoch 218/1000
#  - 16s - loss: 0.4358 - accuracy: 0.7861 - val_loss: 0.7894 - val_accuracy: 0.5026
#
# Epoch 00218: val_loss did not improve from 0.39079
# Epoch 219/1000
#  - 17s - loss: 0.4392 - accuracy: 0.7885 - val_loss: 0.8023 - val_accuracy: 0.4999
#
# Epoch 00219: val_loss did not improve from 0.39079
# Epoch 220/1000
#  - 16s - loss: 0.4330 - accuracy: 0.7912 - val_loss: 0.5877 - val_accuracy: 0.4925
#
# Epoch 00220: val_loss did not improve from 0.39079
# Epoch 221/1000
#  - 17s - loss: 0.4305 - accuracy: 0.7921 - val_loss: 0.9353 - val_accuracy: 0.4908
#
# Epoch 00221: val_loss did not improve from 0.39079
# Epoch 222/1000
#  - 16s - loss: 0.4320 - accuracy: 0.7927 - val_loss: 0.3995 - val_accuracy: 0.4952
#
# Epoch 00222: val_loss did not improve from 0.39079
# Epoch 223/1000
#  - 17s - loss: 0.4274 - accuracy: 0.7987 - val_loss: 0.9132 - val_accuracy: 0.4979
#
# Epoch 00223: val_loss did not improve from 0.39079
# Epoch 224/1000
#  - 17s - loss: 0.4302 - accuracy: 0.7939 - val_loss: 1.2208 - val_accuracy: 0.4974
#
# Epoch 00224: val_loss did not improve from 0.39079
# Epoch 225/1000
#  - 17s - loss: 0.4238 - accuracy: 0.7982 - val_loss: 1.3196 - val_accuracy: 0.5026
#
# Epoch 00225: val_loss did not improve from 0.39079
# Epoch 226/1000
#  - 16s - loss: 0.4330 - accuracy: 0.7830 - val_loss: 0.6747 - val_accuracy: 0.5001
#
# Epoch 00226: val_loss did not improve from 0.39079
# Epoch 227/1000
#  - 16s - loss: 0.4226 - accuracy: 0.8019 - val_loss: 1.1294 - val_accuracy: 0.5026
#
# Epoch 00227: val_loss did not improve from 0.39079
# Epoch 228/1000
#  - 16s - loss: 0.4255 - accuracy: 0.7948 - val_loss: 1.6896 - val_accuracy: 0.4942
#
# Epoch 00228: val_loss did not improve from 0.39079
# Epoch 229/1000
#  - 17s - loss: 0.4247 - accuracy: 0.8002 - val_loss: 0.8733 - val_accuracy: 0.5048
#
# Epoch 00229: val_loss did not improve from 0.39079
# Epoch 230/1000
#  - 17s - loss: 0.4288 - accuracy: 0.7948 - val_loss: 1.2555 - val_accuracy: 0.4960
#
# Epoch 00230: val_loss did not improve from 0.39079
# Epoch 231/1000
#  - 17s - loss: 0.4208 - accuracy: 0.8010 - val_loss: 1.2521 - val_accuracy: 0.4918
#
# Epoch 00231: val_loss did not improve from 0.39079
# Epoch 232/1000
#  - 17s - loss: 0.4205 - accuracy: 0.7968 - val_loss: 0.9716 - val_accuracy: 0.5021
#
# Epoch 00232: val_loss did not improve from 0.39079
# Epoch 233/1000
#  - 17s - loss: 0.4206 - accuracy: 0.8011 - val_loss: 1.1614 - val_accuracy: 0.4935
#
# Epoch 00233: val_loss did not improve from 0.39079
# Epoch 234/1000
#  - 17s - loss: 0.4172 - accuracy: 0.8045 - val_loss: 0.6635 - val_accuracy: 0.5036
#
# Epoch 00234: val_loss did not improve from 0.39079
# Epoch 235/1000
#  - 17s - loss: 0.4234 - accuracy: 0.7949 - val_loss: 0.7601 - val_accuracy: 0.5001
#
# Epoch 00235: val_loss did not improve from 0.39079
# Epoch 236/1000
#  - 16s - loss: 0.4102 - accuracy: 0.8055 - val_loss: 2.0072 - val_accuracy: 0.4996
#
# Epoch 00236: val_loss did not improve from 0.39079
# Epoch 237/1000
#  - 16s - loss: 0.4131 - accuracy: 0.8055 - val_loss: 0.9369 - val_accuracy: 0.5001
#
# Epoch 00237: val_loss did not improve from 0.39079
# Epoch 238/1000
#  - 16s - loss: 0.4142 - accuracy: 0.7977 - val_loss: 1.3955 - val_accuracy: 0.5031
#
# Epoch 00238: val_loss did not improve from 0.39079
# Epoch 239/1000
#  - 16s - loss: 0.4029 - accuracy: 0.8103 - val_loss: 1.5070 - val_accuracy: 0.4982
#
# Epoch 00239: val_loss did not improve from 0.39079
# Epoch 240/1000
#  - 16s - loss: 0.4119 - accuracy: 0.8014 - val_loss: 0.8968 - val_accuracy: 0.4984
#
# Epoch 00240: val_loss did not improve from 0.39079
# Epoch 241/1000
#  - 16s - loss: 0.4053 - accuracy: 0.8069 - val_loss: 0.9421 - val_accuracy: 0.4996
#
# Epoch 00241: val_loss did not improve from 0.39079
# Epoch 242/1000
#  - 17s - loss: 0.4056 - accuracy: 0.8094 - val_loss: 1.5166 - val_accuracy: 0.4987
#
# Epoch 00242: val_loss did not improve from 0.39079
# Epoch 243/1000
#  - 16s - loss: 0.4059 - accuracy: 0.8054 - val_loss: 1.1896 - val_accuracy: 0.5026
#
# Epoch 00243: val_loss did not improve from 0.39079
# Epoch 244/1000
#  - 16s - loss: 0.4087 - accuracy: 0.8061 - val_loss: 1.0581 - val_accuracy: 0.5026
#
# Epoch 00244: val_loss did not improve from 0.39079
# Epoch 245/1000
#  - 16s - loss: 0.4038 - accuracy: 0.8101 - val_loss: 1.6077 - val_accuracy: 0.4999
#
# Epoch 00245: val_loss did not improve from 0.39079
# Epoch 246/1000
#  - 16s - loss: 0.3966 - accuracy: 0.8121 - val_loss: 0.9250 - val_accuracy: 0.4942
#
# Epoch 00246: val_loss did not improve from 0.39079
# Epoch 247/1000
#  - 16s - loss: 0.4016 - accuracy: 0.8086 - val_loss: 1.0562 - val_accuracy: 0.4960
#
# Epoch 00247: val_loss did not improve from 0.39079
# Epoch 248/1000
#  - 16s - loss: 0.4006 - accuracy: 0.8111 - val_loss: 0.5247 - val_accuracy: 0.4974
#
# Epoch 00248: val_loss did not improve from 0.39079
# Epoch 249/1000
#  - 16s - loss: 0.3998 - accuracy: 0.8136 - val_loss: 1.7756 - val_accuracy: 0.4989
#
# Epoch 00249: val_loss did not improve from 0.39079
# Epoch 250/1000
#  - 16s - loss: 0.3936 - accuracy: 0.8136 - val_loss: 1.2578 - val_accuracy: 0.5009
#
# Epoch 00250: val_loss did not improve from 0.39079
# Epoch 251/1000
#  - 16s - loss: 0.3961 - accuracy: 0.8153 - val_loss: 1.5324 - val_accuracy: 0.5001
#
# Epoch 00251: val_loss did not improve from 0.39079
# Epoch 252/1000
#  - 16s - loss: 0.3962 - accuracy: 0.8158 - val_loss: 1.0121 - val_accuracy: 0.4962
#
# Epoch 00252: val_loss did not improve from 0.39079
# Epoch 253/1000
#  - 16s - loss: 0.3915 - accuracy: 0.8191 - val_loss: 1.3948 - val_accuracy: 0.4947
#
# Epoch 00253: val_loss did not improve from 0.39079
# Epoch 254/1000
#  - 16s - loss: 0.3952 - accuracy: 0.8138 - val_loss: 0.9845 - val_accuracy: 0.5033
#
# Epoch 00254: val_loss did not improve from 0.39079
# Epoch 255/1000
#  - 16s - loss: 0.3859 - accuracy: 0.8198 - val_loss: 1.6240 - val_accuracy: 0.5033
#
# Epoch 00255: val_loss did not improve from 0.39079
# Epoch 256/1000
#  - 16s - loss: 0.3814 - accuracy: 0.8205 - val_loss: 1.8273 - val_accuracy: 0.5026
#
# Epoch 00256: val_loss did not improve from 0.39079
# Epoch 257/1000
#  - 16s - loss: 0.3859 - accuracy: 0.8178 - val_loss: 1.1208 - val_accuracy: 0.5036
#
# Epoch 00257: val_loss did not improve from 0.39079
# Epoch 258/1000
#  - 16s - loss: 0.3893 - accuracy: 0.8169 - val_loss: 1.9549 - val_accuracy: 0.5063
#
# Epoch 00258: val_loss did not improve from 0.39079
# Epoch 259/1000
#  - 16s - loss: 0.3915 - accuracy: 0.8162 - val_loss: 0.9475 - val_accuracy: 0.5048
#
# Epoch 00259: val_loss did not improve from 0.39079
# Epoch 260/1000
#  - 16s - loss: 0.3858 - accuracy: 0.8224 - val_loss: 1.9364 - val_accuracy: 0.4979
#
# Epoch 00260: val_loss did not improve from 0.39079
# Epoch 261/1000
#  - 16s - loss: 0.3873 - accuracy: 0.8198 - val_loss: 1.0596 - val_accuracy: 0.4994
#
# Epoch 00261: val_loss did not improve from 0.39079
# Epoch 262/1000
#  - 16s - loss: 0.3762 - accuracy: 0.8233 - val_loss: 1.5094 - val_accuracy: 0.4967
#
# Epoch 00262: val_loss did not improve from 0.39079
# Epoch 263/1000
#  - 16s - loss: 0.3848 - accuracy: 0.8221 - val_loss: 0.6784 - val_accuracy: 0.4994
#
# Epoch 00263: val_loss did not improve from 0.39079
# Epoch 264/1000
#  - 16s - loss: 0.3745 - accuracy: 0.8265 - val_loss: 0.8130 - val_accuracy: 0.5036
#
# Epoch 00264: val_loss did not improve from 0.39079
# Epoch 265/1000
#  - 16s - loss: 0.3793 - accuracy: 0.8206 - val_loss: 1.5840 - val_accuracy: 0.5001
#
# Epoch 00265: val_loss did not improve from 0.39079
# Epoch 266/1000
#  - 16s - loss: 0.3704 - accuracy: 0.8306 - val_loss: 0.8936 - val_accuracy: 0.5006
#
# Epoch 00266: val_loss did not improve from 0.39079
# Epoch 267/1000
#  - 16s - loss: 0.3767 - accuracy: 0.8207 - val_loss: 2.0600 - val_accuracy: 0.4933
#
# Epoch 00267: val_loss did not improve from 0.39079
# Epoch 268/1000
#  - 16s - loss: 0.3788 - accuracy: 0.8207 - val_loss: 1.2998 - val_accuracy: 0.4979
#
# Epoch 00268: val_loss did not improve from 0.39079
# Epoch 269/1000
#  - 16s - loss: 0.3705 - accuracy: 0.8306 - val_loss: 1.2220 - val_accuracy: 0.4979
#
# Epoch 00269: val_loss did not improve from 0.39079
# Epoch 270/1000
#  - 16s - loss: 0.3743 - accuracy: 0.8283 - val_loss: 1.6469 - val_accuracy: 0.5013
#
# Epoch 00270: val_loss did not improve from 0.39079
# Epoch 271/1000
#  - 16s - loss: 0.3726 - accuracy: 0.8268 - val_loss: 1.0291 - val_accuracy: 0.5021
#
# Epoch 00271: val_loss did not improve from 0.39079
# Epoch 272/1000
#  - 16s - loss: 0.3681 - accuracy: 0.8333 - val_loss: 0.7098 - val_accuracy: 0.5077
#
# Epoch 00272: val_loss did not improve from 0.39079
# Epoch 273/1000
#  - 16s - loss: 0.3654 - accuracy: 0.8320 - val_loss: 1.3429 - val_accuracy: 0.5028
#
# Epoch 00273: val_loss did not improve from 0.39079
# Epoch 274/1000
#  - 16s - loss: 0.3668 - accuracy: 0.8263 - val_loss: 1.1474 - val_accuracy: 0.5055
#
# Epoch 00274: val_loss did not improve from 0.39079
# Epoch 275/1000
#  - 16s - loss: 0.3633 - accuracy: 0.8323 - val_loss: 1.5502 - val_accuracy: 0.5009
#
# Epoch 00275: val_loss did not improve from 0.39079
# Epoch 276/1000
#  - 16s - loss: 0.3655 - accuracy: 0.8324 - val_loss: 0.8538 - val_accuracy: 0.5018
#
# Epoch 00276: val_loss did not improve from 0.39079
# Epoch 277/1000
#  - 16s - loss: 0.3664 - accuracy: 0.8342 - val_loss: 1.7490 - val_accuracy: 0.5119
#
# Epoch 00277: val_loss did not improve from 0.39079
# Epoch 278/1000
#  - 16s - loss: 0.3686 - accuracy: 0.8279 - val_loss: 1.3098 - val_accuracy: 0.4913
#
# Epoch 00278: val_loss did not improve from 0.39079
# Epoch 279/1000
#  - 16s - loss: 0.3623 - accuracy: 0.8351 - val_loss: 1.6191 - val_accuracy: 0.5063
#
# Epoch 00279: val_loss did not improve from 0.39079
# Epoch 280/1000
#  - 16s - loss: 0.3547 - accuracy: 0.8400 - val_loss: 1.1204 - val_accuracy: 0.5085
#
# Epoch 00280: val_loss did not improve from 0.39079
# Epoch 281/1000
#  - 16s - loss: 0.3569 - accuracy: 0.8350 - val_loss: 0.8883 - val_accuracy: 0.4962
#
# Epoch 00281: val_loss did not improve from 0.39079
# Epoch 282/1000
#  - 16s - loss: 0.3553 - accuracy: 0.8391 - val_loss: 0.5746 - val_accuracy: 0.5055
#
# Epoch 00282: val_loss did not improve from 0.39079
# Epoch 283/1000
#  - 16s - loss: 0.3560 - accuracy: 0.8404 - val_loss: 1.1256 - val_accuracy: 0.4982
#
# Epoch 00283: val_loss did not improve from 0.39079
# Epoch 284/1000
#  - 16s - loss: 0.3584 - accuracy: 0.8356 - val_loss: 2.9267 - val_accuracy: 0.5053
#
# Epoch 00284: val_loss did not improve from 0.39079
# Epoch 285/1000
#  - 16s - loss: 0.3578 - accuracy: 0.8342 - val_loss: 2.2876 - val_accuracy: 0.5006
#
# Epoch 00285: val_loss did not improve from 0.39079
# Epoch 286/1000
#  - 16s - loss: 0.3560 - accuracy: 0.8367 - val_loss: 0.7286 - val_accuracy: 0.5048
#
# Epoch 00286: val_loss did not improve from 0.39079
# Epoch 287/1000
#  - 16s - loss: 0.3498 - accuracy: 0.8433 - val_loss: 1.5468 - val_accuracy: 0.5067
#
# Epoch 00287: val_loss did not improve from 0.39079
# Epoch 288/1000
#  - 16s - loss: 0.3541 - accuracy: 0.8393 - val_loss: 1.1657 - val_accuracy: 0.5033
#
# Epoch 00288: val_loss did not improve from 0.39079
# Epoch 289/1000
#  - 16s - loss: 0.3474 - accuracy: 0.8440 - val_loss: 1.8802 - val_accuracy: 0.5016
#
# Epoch 00289: val_loss did not improve from 0.39079
# Epoch 290/1000
#  - 16s - loss: 0.3461 - accuracy: 0.8456 - val_loss: 0.7366 - val_accuracy: 0.5011
#
# Epoch 00290: val_loss did not improve from 0.39079
# Epoch 291/1000
#  - 16s - loss: 0.3495 - accuracy: 0.8442 - val_loss: 0.9607 - val_accuracy: 0.4989
#
# Epoch 00291: val_loss did not improve from 0.39079
# Epoch 292/1000
#  - 16s - loss: 0.3412 - accuracy: 0.8408 - val_loss: 0.9853 - val_accuracy: 0.5001
#
# Epoch 00292: val_loss did not improve from 0.39079
# Epoch 293/1000
#  - 17s - loss: 0.3476 - accuracy: 0.8447 - val_loss: 1.0536 - val_accuracy: 0.4974
#
# Epoch 00293: val_loss did not improve from 0.39079
# Epoch 294/1000
#  - 16s - loss: 0.3439 - accuracy: 0.8451 - val_loss: 1.0729 - val_accuracy: 0.4996
#
# Epoch 00294: val_loss did not improve from 0.39079
# Epoch 295/1000
#  - 17s - loss: 0.3379 - accuracy: 0.8448 - val_loss: 1.2295 - val_accuracy: 0.5036
#
# Epoch 00295: val_loss did not improve from 0.39079
# Epoch 296/1000
#  - 17s - loss: 0.3366 - accuracy: 0.8478 - val_loss: 1.2030 - val_accuracy: 0.5009
#
# Epoch 00296: val_loss did not improve from 0.39079
# Epoch 297/1000
#  - 17s - loss: 0.3497 - accuracy: 0.8437 - val_loss: 1.9475 - val_accuracy: 0.4942
#
# Epoch 00297: val_loss did not improve from 0.39079
# Epoch 298/1000
#  - 16s - loss: 0.3434 - accuracy: 0.8433 - val_loss: 2.1955 - val_accuracy: 0.5043
#
# Epoch 00298: val_loss did not improve from 0.39079
# Epoch 299/1000
#  - 16s - loss: 0.3464 - accuracy: 0.8418 - val_loss: 0.8512 - val_accuracy: 0.5013
#
# Epoch 00299: val_loss did not improve from 0.39079
# Epoch 300/1000
#  - 16s - loss: 0.3419 - accuracy: 0.8440 - val_loss: 1.3150 - val_accuracy: 0.4991
#
# Epoch 00300: val_loss did not improve from 0.39079
# Epoch 301/1000
#  - 16s - loss: 0.3378 - accuracy: 0.8485 - val_loss: 1.7612 - val_accuracy: 0.5028
#
# Epoch 00301: val_loss did not improve from 0.39079
# Epoch 302/1000
#  - 16s - loss: 0.3362 - accuracy: 0.8500 - val_loss: 1.6180 - val_accuracy: 0.4964
#
# Epoch 00302: val_loss did not improve from 0.39079
# Epoch 303/1000
#  - 16s - loss: 0.3285 - accuracy: 0.8506 - val_loss: 1.3425 - val_accuracy: 0.5011
#
# Epoch 00303: val_loss did not improve from 0.39079
# Epoch 304/1000
#  - 16s - loss: 0.3335 - accuracy: 0.8456 - val_loss: 2.1049 - val_accuracy: 0.4969
#
# Epoch 00304: val_loss did not improve from 0.39079
# Epoch 305/1000
#  - 16s - loss: 0.3360 - accuracy: 0.8447 - val_loss: 2.1005 - val_accuracy: 0.5004
#
# Epoch 00305: val_loss did not improve from 0.39079
# Epoch 306/1000
#  - 16s - loss: 0.3270 - accuracy: 0.8560 - val_loss: 1.1270 - val_accuracy: 0.5063
#
# Epoch 00306: val_loss did not improve from 0.39079
# Epoch 307/1000
#  - 16s - loss: 0.3340 - accuracy: 0.8509 - val_loss: 0.8551 - val_accuracy: 0.5028
#
# Epoch 00307: val_loss did not improve from 0.39079
# Epoch 308/1000
#  - 17s - loss: 0.3272 - accuracy: 0.8525 - val_loss: 1.2531 - val_accuracy: 0.4942
#
# Epoch 00308: val_loss did not improve from 0.39079
# Epoch 309/1000
#  - 16s - loss: 0.3330 - accuracy: 0.8482 - val_loss: 1.9326 - val_accuracy: 0.5018
#
# Epoch 00309: val_loss did not improve from 0.39079
# Epoch 310/1000
#  - 16s - loss: 0.3224 - accuracy: 0.8566 - val_loss: 1.4873 - val_accuracy: 0.4991
#
# Epoch 00310: val_loss did not improve from 0.39079
# Epoch 311/1000
#  - 16s - loss: 0.3217 - accuracy: 0.8552 - val_loss: 1.6768 - val_accuracy: 0.5018
#
# Epoch 00311: val_loss did not improve from 0.39079
# Epoch 312/1000
#  - 16s - loss: 0.3301 - accuracy: 0.8557 - val_loss: 1.7366 - val_accuracy: 0.4960
#
# Epoch 00312: val_loss did not improve from 0.39079
# Epoch 313/1000
#  - 16s - loss: 0.3219 - accuracy: 0.8543 - val_loss: 1.4019 - val_accuracy: 0.4999
#
# Epoch 00313: val_loss did not improve from 0.39079
# Epoch 314/1000
#  - 16s - loss: 0.3209 - accuracy: 0.8546 - val_loss: 0.6314 - val_accuracy: 0.4969
#
# Epoch 00314: val_loss did not improve from 0.39079
# Epoch 315/1000
#  - 16s - loss: 0.3256 - accuracy: 0.8543 - val_loss: 1.1274 - val_accuracy: 0.4947
#
# ...
#
# Epoch 00894: val_loss did not improve from 0.29907
# Epoch 895/1000
#  - 17s - loss: 0.0574 - accuracy: 0.9826 - val_loss: 4.8366 - val_accuracy: 0.4987
#
# Epoch 00895: val_loss did not improve from 0.29907
# Epoch 896/1000
#  - 17s - loss: 0.0566 - accuracy: 0.9831 - val_loss: 4.5720 - val_accuracy: 0.4957
#
# Epoch 00896: val_loss did not improve from 0.29907
# Epoch 897/1000
#  - 17s - loss: 0.0577 - accuracy: 0.9823 - val_loss: 4.9195 - val_accuracy: 0.4957
#
# Epoch 00897: val_loss did not improve from 0.29907
# Epoch 898/1000
#  - 17s - loss: 0.0553 - accuracy: 0.9828 - val_loss: 5.4421 - val_accuracy: 0.4950
#
# Epoch 00898: val_loss did not improve from 0.29907
# Epoch 899/1000
#  - 17s - loss: 0.0572 - accuracy: 0.9829 - val_loss: 4.6145 - val_accuracy: 0.4962
#
# Epoch 00899: val_loss did not improve from 0.29907
# Epoch 900/1000
#  - 17s - loss: 0.0573 - accuracy: 0.9819 - val_loss: 3.5397 - val_accuracy: 0.4935
#
# Epoch 00900: val_loss did not improve from 0.29907
# Epoch 901/1000
#  - 17s - loss: 0.0573 - accuracy: 0.9821 - val_loss: 3.3664 - val_accuracy: 0.4945
#
# Epoch 00901: val_loss did not improve from 0.29907
# Epoch 902/1000
#  - 17s - loss: 0.0559 - accuracy: 0.9827 - val_loss: 1.8444 - val_accuracy: 0.5004
#
# Epoch 00902: val_loss did not improve from 0.29907
# Epoch 903/1000
#  - 17s - loss: 0.0558 - accuracy: 0.9836 - val_loss: 2.9031 - val_accuracy: 0.4935
#
# Epoch 00903: val_loss did not improve from 0.29907
# Epoch 904/1000
#  - 17s - loss: 0.0531 - accuracy: 0.9842 - val_loss: 1.3148 - val_accuracy: 0.4930
#
# Epoch 00904: val_loss did not improve from 0.29907
# Epoch 905/1000
#  - 17s - loss: 0.0556 - accuracy: 0.9820 - val_loss: 4.6721 - val_accuracy: 0.4945
#
# Epoch 00905: val_loss did not improve from 0.29907
# Epoch 906/1000
#  - 17s - loss: 0.0556 - accuracy: 0.9834 - val_loss: 3.1553 - val_accuracy: 0.4960
#
# Epoch 00906: val_loss did not improve from 0.29907
# Epoch 907/1000
#  - 17s - loss: 0.0533 - accuracy: 0.9848 - val_loss: 3.1059 - val_accuracy: 0.4945
#
# Epoch 00907: val_loss did not improve from 0.29907
# Epoch 908/1000
#  - 17s - loss: 0.0537 - accuracy: 0.9825 - val_loss: 2.6651 - val_accuracy: 0.4942
#
# Epoch 00908: val_loss did not improve from 0.29907
# Epoch 909/1000
#  - 17s - loss: 0.0580 - accuracy: 0.9828 - val_loss: 2.2306 - val_accuracy: 0.4952
#
# Epoch 00909: val_loss did not improve from 0.29907
# Epoch 910/1000
#  - 17s - loss: 0.0523 - accuracy: 0.9853 - val_loss: 3.7454 - val_accuracy: 0.4952
#
# Epoch 00910: val_loss did not improve from 0.29907
# Epoch 911/1000
#  - 17s - loss: 0.0536 - accuracy: 0.9845 - val_loss: 3.8899 - val_accuracy: 0.4915
#
# Epoch 00911: val_loss did not improve from 0.29907
# Epoch 912/1000
#  - 16s - loss: 0.0535 - accuracy: 0.9842 - val_loss: 1.5257 - val_accuracy: 0.4955
#
# Epoch 00912: val_loss did not improve from 0.29907
# Epoch 913/1000
#  - 16s - loss: 0.0542 - accuracy: 0.9831 - val_loss: 2.3475 - val_accuracy: 0.4933
#
# Epoch 00913: val_loss did not improve from 0.29907
# Epoch 914/1000
#  - 16s - loss: 0.0543 - accuracy: 0.9824 - val_loss: 2.6907 - val_accuracy: 0.4923
#
# Epoch 00914: val_loss did not improve from 0.29907
# Epoch 915/1000
#  - 16s - loss: 0.0537 - accuracy: 0.9838 - val_loss: 3.7207 - val_accuracy: 0.4940
#
# Epoch 00915: val_loss did not improve from 0.29907
# Epoch 916/1000
#  - 16s - loss: 0.0546 - accuracy: 0.9841 - val_loss: 3.7438 - val_accuracy: 0.4911
#
# Epoch 00916: val_loss did not improve from 0.29907
# Epoch 917/1000
#  - 16s - loss: 0.0570 - accuracy: 0.9828 - val_loss: 3.4568 - val_accuracy: 0.4964
#
# Epoch 00917: val_loss did not improve from 0.29907
# Epoch 918/1000
#  - 16s - loss: 0.0537 - accuracy: 0.9843 - val_loss: 2.5842 - val_accuracy: 0.5001
#
# Epoch 00918: val_loss did not improve from 0.29907
# Epoch 919/1000
#  - 16s - loss: 0.0558 - accuracy: 0.9820 - val_loss: 3.5467 - val_accuracy: 0.4942
#
# Epoch 00919: val_loss did not improve from 0.29907
# Epoch 920/1000
#  - 16s - loss: 0.0542 - accuracy: 0.9844 - val_loss: 4.2411 - val_accuracy: 0.4933
#
# Epoch 00920: val_loss did not improve from 0.29907
# Epoch 921/1000
#  - 16s - loss: 0.0526 - accuracy: 0.9846 - val_loss: 2.2558 - val_accuracy: 0.4942
#
# Epoch 00921: val_loss did not improve from 0.29907
# Epoch 922/1000
#  - 16s - loss: 0.0546 - accuracy: 0.9830 - val_loss: 1.9069 - val_accuracy: 0.4969
#
# Epoch 00922: val_loss did not improve from 0.29907
# Epoch 923/1000
#  - 16s - loss: 0.0534 - accuracy: 0.9843 - val_loss: 3.8114 - val_accuracy: 0.4977
#
# Epoch 00923: val_loss did not improve from 0.29907
# Epoch 924/1000
#  - 16s - loss: 0.0500 - accuracy: 0.9863 - val_loss: 8.2172 - val_accuracy: 0.4969
#
# Epoch 00924: val_loss did not improve from 0.29907
# Epoch 925/1000
#  - 16s - loss: 0.0501 - accuracy: 0.9845 - val_loss: 2.4701 - val_accuracy: 0.4960
#
# Epoch 00925: val_loss did not improve from 0.29907
# Epoch 926/1000
#  - 16s - loss: 0.0494 - accuracy: 0.9855 - val_loss: 3.6458 - val_accuracy: 0.4920
#
# Epoch 00926: val_loss did not improve from 0.29907
# Epoch 927/1000
#  - 16s - loss: 0.0524 - accuracy: 0.9844 - val_loss: 7.4220 - val_accuracy: 0.4933
#
# Epoch 00927: val_loss did not improve from 0.29907
# Epoch 928/1000
#  - 16s - loss: 0.0498 - accuracy: 0.9858 - val_loss: 4.8471 - val_accuracy: 0.4903
#
# Epoch 00928: val_loss did not improve from 0.29907
# Epoch 929/1000
#  - 16s - loss: 0.0516 - accuracy: 0.9850 - val_loss: 4.4580 - val_accuracy: 0.4930
#
# Epoch 00929: val_loss did not improve from 0.29907
# Epoch 930/1000
#  - 16s - loss: 0.0533 - accuracy: 0.9848 - val_loss: 2.9214 - val_accuracy: 0.4930
#
# Epoch 00930: val_loss did not improve from 0.29907
# Epoch 931/1000
#  - 16s - loss: 0.0543 - accuracy: 0.9837 - val_loss: 4.7226 - val_accuracy: 0.4967
#
# Epoch 00931: val_loss did not improve from 0.29907
# Epoch 932/1000
#  - 16s - loss: 0.0525 - accuracy: 0.9857 - val_loss: 1.0585 - val_accuracy: 0.4962
#
# Epoch 00932: val_loss did not improve from 0.29907
# Epoch 933/1000
#  - 16s - loss: 0.0515 - accuracy: 0.9841 - val_loss: 9.2522 - val_accuracy: 0.4923
#
# Epoch 00933: val_loss did not improve from 0.29907
# Epoch 934/1000
#  - 16s - loss: 0.0512 - accuracy: 0.9847 - val_loss: 5.7171 - val_accuracy: 0.4925
#
# Epoch 00934: val_loss did not improve from 0.29907
# Epoch 935/1000
#  - 16s - loss: 0.0529 - accuracy: 0.9850 - val_loss: 3.3982 - val_accuracy: 0.4945
#
# Epoch 00935: val_loss did not improve from 0.29907
# Epoch 936/1000
#  - 16s - loss: 0.0514 - accuracy: 0.9844 - val_loss: 2.8244 - val_accuracy: 0.4967
#
# Epoch 00936: val_loss did not improve from 0.29907
# Epoch 937/1000
#  - 16s - loss: 0.0508 - accuracy: 0.9863 - val_loss: 1.9236 - val_accuracy: 0.4950
#
# Epoch 00937: val_loss did not improve from 0.29907
# Epoch 938/1000
#  - 16s - loss: 0.0487 - accuracy: 0.9868 - val_loss: 3.3239 - val_accuracy: 0.4891
#
# Epoch 00938: val_loss did not improve from 0.29907
# Epoch 939/1000
#  - 16s - loss: 0.0484 - accuracy: 0.9866 - val_loss: 3.4763 - val_accuracy: 0.4967
#
# Epoch 00939: val_loss did not improve from 0.29907
# Epoch 940/1000
#  - 16s - loss: 0.0511 - accuracy: 0.9848 - val_loss: 4.6267 - val_accuracy: 0.4967
#
# Epoch 00940: val_loss did not improve from 0.29907
# Epoch 941/1000
#  - 16s - loss: 0.0493 - accuracy: 0.9863 - val_loss: 8.2808 - val_accuracy: 0.4962
#
# Epoch 00941: val_loss did not improve from 0.29907
# Epoch 942/1000
#  - 16s - loss: 0.0503 - accuracy: 0.9856 - val_loss: 3.1341 - val_accuracy: 0.4940
#
# Epoch 00942: val_loss did not improve from 0.29907
# Epoch 943/1000
#  - 16s - loss: 0.0515 - accuracy: 0.9845 - val_loss: 3.9498 - val_accuracy: 0.4940
#
# Epoch 00943: val_loss did not improve from 0.29907
# Epoch 944/1000
#  - 16s - loss: 0.0514 - accuracy: 0.9852 - val_loss: 2.7584 - val_accuracy: 0.4913
#
# Epoch 00944: val_loss did not improve from 0.29907
# Epoch 945/1000
#  - 16s - loss: 0.0495 - accuracy: 0.9860 - val_loss: 5.6535 - val_accuracy: 0.4928
#
# Epoch 00945: val_loss did not improve from 0.29907
# Epoch 946/1000
#  - 16s - loss: 0.0517 - accuracy: 0.9861 - val_loss: 2.5099 - val_accuracy: 0.4945
#
# Epoch 00946: val_loss did not improve from 0.29907
# Epoch 947/1000
#  - 17s - loss: 0.0535 - accuracy: 0.9846 - val_loss: 5.8610 - val_accuracy: 0.4940
#
# Epoch 00947: val_loss did not improve from 0.29907
# Epoch 948/1000
#  - 17s - loss: 0.0480 - accuracy: 0.9877 - val_loss: 3.3181 - val_accuracy: 0.4918
#
# Epoch 00948: val_loss did not improve from 0.29907
# Epoch 949/1000
#  - 17s - loss: 0.0497 - accuracy: 0.9861 - val_loss: 2.7359 - val_accuracy: 0.4955
#
# Epoch 00949: val_loss did not improve from 0.29907
# Epoch 950/1000
#  - 17s - loss: 0.0495 - accuracy: 0.9848 - val_loss: 7.8552 - val_accuracy: 0.4972
#
# Epoch 00950: val_loss did not improve from 0.29907
# Epoch 951/1000
#  - 16s - loss: 0.0504 - accuracy: 0.9837 - val_loss: 3.3115 - val_accuracy: 0.4947
#
# Epoch 00951: val_loss did not improve from 0.29907
# Epoch 952/1000
#  - 16s - loss: 0.0474 - accuracy: 0.9863 - val_loss: 3.2118 - val_accuracy: 0.4918
#
# Epoch 00952: val_loss did not improve from 0.29907
# Epoch 953/1000
#  - 16s - loss: 0.0480 - accuracy: 0.9872 - val_loss: 6.1732 - val_accuracy: 0.4903
#
# Epoch 00953: val_loss did not improve from 0.29907
# Epoch 954/1000
#  - 16s - loss: 0.0495 - accuracy: 0.9843 - val_loss: 4.0116 - val_accuracy: 0.4937
#
# Epoch 00954: val_loss did not improve from 0.29907
# Epoch 955/1000
#  - 16s - loss: 0.0473 - accuracy: 0.9853 - val_loss: 7.7206 - val_accuracy: 0.4957
#
# Epoch 00955: val_loss did not improve from 0.29907
# Epoch 956/1000
#  - 16s - loss: 0.0485 - accuracy: 0.9860 - val_loss: 5.7286 - val_accuracy: 0.4962
#
# Epoch 00956: val_loss did not improve from 0.29907
# Epoch 957/1000
#  - 16s - loss: 0.0488 - accuracy: 0.9854 - val_loss: 4.4570 - val_accuracy: 0.4942
#
# Epoch 00957: val_loss did not improve from 0.29907
# Epoch 958/1000
#  - 16s - loss: 0.0483 - accuracy: 0.9866 - val_loss: 2.4057 - val_accuracy: 0.4928
#
# Epoch 00958: val_loss did not improve from 0.29907
# Epoch 959/1000
#  - 17s - loss: 0.0481 - accuracy: 0.9864 - val_loss: 1.2625 - val_accuracy: 0.4947
#
# Epoch 00959: val_loss did not improve from 0.29907
# Epoch 960/1000
#  - 16s - loss: 0.0458 - accuracy: 0.9868 - val_loss: 4.0434 - val_accuracy: 0.4972
#
# Epoch 00960: val_loss did not improve from 0.29907
# Epoch 961/1000
#  - 16s - loss: 0.0467 - accuracy: 0.9868 - val_loss: 1.7773 - val_accuracy: 0.4962
#
# Epoch 00961: val_loss did not improve from 0.29907
# Epoch 962/1000
#  - 16s - loss: 0.0487 - accuracy: 0.9848 - val_loss: 7.6217 - val_accuracy: 0.4960
#
# Epoch 00962: val_loss did not improve from 0.29907
# Epoch 963/1000
#  - 16s - loss: 0.0465 - accuracy: 0.9863 - val_loss: 3.3826 - val_accuracy: 0.4925
#
# Epoch 00963: val_loss did not improve from 0.29907
# Epoch 964/1000
#  - 16s - loss: 0.0454 - accuracy: 0.9880 - val_loss: 4.9716 - val_accuracy: 0.4947
#
# Epoch 00964: val_loss did not improve from 0.29907
# Epoch 965/1000
#  - 16s - loss: 0.0495 - accuracy: 0.9853 - val_loss: 1.8046 - val_accuracy: 0.4925
#
# Epoch 00965: val_loss did not improve from 0.29907
# Epoch 966/1000
#  - 16s - loss: 0.0459 - accuracy: 0.9870 - val_loss: 4.9575 - val_accuracy: 0.4920
#
# Epoch 00966: val_loss did not improve from 0.29907
# Epoch 967/1000
#  - 16s - loss: 0.0476 - accuracy: 0.9863 - val_loss: 2.5475 - val_accuracy: 0.4969
#
# Epoch 00967: val_loss did not improve from 0.29907
# Epoch 968/1000
#  - 16s - loss: 0.0480 - accuracy: 0.9855 - val_loss: 4.1145 - val_accuracy: 0.4903
#
# Epoch 00968: val_loss did not improve from 0.29907
# Epoch 969/1000
#  - 16s - loss: 0.0482 - accuracy: 0.9855 - val_loss: 2.0201 - val_accuracy: 0.4972
#
# Epoch 00969: val_loss did not improve from 0.29907
# Epoch 970/1000
#  - 16s - loss: 0.0473 - accuracy: 0.9858 - val_loss: 2.5785 - val_accuracy: 0.4930
#
# Epoch 00970: val_loss did not improve from 0.29907
# Epoch 971/1000
#  - 16s - loss: 0.0485 - accuracy: 0.9859 - val_loss: 5.1660 - val_accuracy: 0.4952
#
# Epoch 00971: val_loss did not improve from 0.29907
# Epoch 972/1000
#  - 17s - loss: 0.0483 - accuracy: 0.9845 - val_loss: 3.8669 - val_accuracy: 0.4942
#
# Epoch 00972: val_loss did not improve from 0.29907
# Epoch 973/1000
#  - 17s - loss: 0.0458 - accuracy: 0.9858 - val_loss: 3.8953 - val_accuracy: 0.4930
#
# Epoch 00973: val_loss did not improve from 0.29907
# Epoch 974/1000
#  - 16s - loss: 0.0482 - accuracy: 0.9869 - val_loss: 3.6157 - val_accuracy: 0.4930
#
# Epoch 00974: val_loss did not improve from 0.29907
# Epoch 975/1000
#  - 16s - loss: 0.0491 - accuracy: 0.9847 - val_loss: 5.0227 - val_accuracy: 0.4898
#
# Epoch 00975: val_loss did not improve from 0.29907
# Epoch 976/1000
#  - 16s - loss: 0.0475 - accuracy: 0.9859 - val_loss: 2.1737 - val_accuracy: 0.4972
#
# Epoch 00976: val_loss did not improve from 0.29907
# Epoch 977/1000
#  - 16s - loss: 0.0439 - accuracy: 0.9881 - val_loss: 2.3621 - val_accuracy: 0.4955
#
# Epoch 00977: val_loss did not improve from 0.29907
# Epoch 978/1000
#  - 17s - loss: 0.0445 - accuracy: 0.9869 - val_loss: 8.8656 - val_accuracy: 0.4960
#
# Epoch 00978: val_loss did not improve from 0.29907
# Epoch 979/1000
#  - 16s - loss: 0.0450 - accuracy: 0.9872 - val_loss: 4.7763 - val_accuracy: 0.4974
#
# Epoch 00979: val_loss did not improve from 0.29907
# Epoch 980/1000
#  - 16s - loss: 0.0471 - accuracy: 0.9868 - val_loss: 5.2821 - val_accuracy: 0.4945
#
# Epoch 00980: val_loss did not improve from 0.29907
# Epoch 981/1000
#  - 16s - loss: 0.0466 - accuracy: 0.9873 - val_loss: 6.1768 - val_accuracy: 0.4935
#
# Epoch 00981: val_loss did not improve from 0.29907
# Epoch 982/1000
#  - 16s - loss: 0.0441 - accuracy: 0.9872 - val_loss: 2.5243 - val_accuracy: 0.4940
#
# Epoch 00982: val_loss did not improve from 0.29907
# Epoch 983/1000
#  - 16s - loss: 0.0458 - accuracy: 0.9869 - val_loss: 6.3669 - val_accuracy: 0.4972
#
# Epoch 00983: val_loss did not improve from 0.29907
# Epoch 984/1000
#  - 16s - loss: 0.0451 - accuracy: 0.9868 - val_loss: 5.8765 - val_accuracy: 0.4940
#
# Epoch 00984: val_loss did not improve from 0.29907
# Epoch 985/1000
#  - 16s - loss: 0.0460 - accuracy: 0.9865 - val_loss: 5.6653 - val_accuracy: 0.4930
#
# Epoch 00985: val_loss did not improve from 0.29907
# Epoch 986/1000
#  - 16s - loss: 0.0459 - accuracy: 0.9876 - val_loss: 5.0042 - val_accuracy: 0.4925
#
# Epoch 00986: val_loss did not improve from 0.29907
# Epoch 987/1000
#  - 16s - loss: 0.0423 - accuracy: 0.9875 - val_loss: 4.9465 - val_accuracy: 0.4915
#
# Epoch 00987: val_loss did not improve from 0.29907
# Epoch 988/1000
#  - 16s - loss: 0.0443 - accuracy: 0.9866 - val_loss: 2.3662 - val_accuracy: 0.4933
#
# Epoch 00988: val_loss did not improve from 0.29907
# Epoch 989/1000
#  - 16s - loss: 0.0431 - accuracy: 0.9881 - val_loss: 3.7374 - val_accuracy: 0.4935
#
# Epoch 00989: val_loss did not improve from 0.29907
# Epoch 990/1000
#  - 17s - loss: 0.0447 - accuracy: 0.9880 - val_loss: 5.7902 - val_accuracy: 0.4925
#
# Epoch 00990: val_loss did not improve from 0.29907
# Epoch 991/1000
#  - 16s - loss: 0.0441 - accuracy: 0.9862 - val_loss: 2.4482 - val_accuracy: 0.4915
#
# Epoch 00991: val_loss did not improve from 0.29907
# Epoch 992/1000
#  - 16s - loss: 0.0449 - accuracy: 0.9869 - val_loss: 4.0385 - val_accuracy: 0.4923
#
# Epoch 00992: val_loss did not improve from 0.29907
# Epoch 993/1000
#  - 16s - loss: 0.0427 - accuracy: 0.9873 - val_loss: 3.0687 - val_accuracy: 0.4920
#
# Epoch 00993: val_loss did not improve from 0.29907
# Epoch 994/1000
#  - 16s - loss: 0.0472 - accuracy: 0.9866 - val_loss: 3.4451 - val_accuracy: 0.4937
#
# Epoch 00994: val_loss did not improve from 0.29907
# Epoch 995/1000
#  - 16s - loss: 0.0455 - accuracy: 0.9868 - val_loss: 6.9166 - val_accuracy: 0.4957
#
# Epoch 00995: val_loss did not improve from 0.29907
# Epoch 996/1000
#  - 17s - loss: 0.0433 - accuracy: 0.9881 - val_loss: 4.4620 - val_accuracy: 0.4947
#
# Epoch 00996: val_loss did not improve from 0.29907
# Epoch 997/1000
#  - 17s - loss: 0.0448 - accuracy: 0.9873 - val_loss: 8.6687 - val_accuracy: 0.4930
#
# Epoch 00997: val_loss did not improve from 0.29907
# Epoch 998/1000
#  - 16s - loss: 0.0440 - accuracy: 0.9876 - val_loss: 4.9999 - val_accuracy: 0.4935
#
# Epoch 00998: val_loss did not improve from 0.29907
# Epoch 999/1000
#  - 16s - loss: 0.0452 - accuracy: 0.9881 - val_loss: 2.8438 - val_accuracy: 0.4923
#
# Epoch 00999: val_loss did not improve from 0.29907
# Epoch 1000/1000
#  - 16s - loss: 0.0444 - accuracy: 0.9877 - val_loss: 6.1310 - val_accuracy: 0.4906
#
# Epoch 01000: val_loss did not improve from 0.29907

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_ex_small_test_02997.h5'
# s_close_updown_pr_theta_non_shuffle_ex_ma7
# model_name = 'classifier_45_close_updown_pr_theta.h5'

model = keras.models.load_model(ckpt_path + model_name)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
org_x_test = x_test
org_y_test = y_test
org_pr_test = pr_test

# %%
x_test = x_val
y_test = y_val
pr_test = pr_val

test_result = model.predict(x_test)
# test_result = model.predict(x_val)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
# precision, recall, threshold = precision_recall_curve(y_val, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
for thresh in threshold:

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  print('precision :', precision_score(y_test, y_pred))
  print('recall :', recall_score(y_test, y_pred))
  print()

  print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # plt.show()  
  print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  # test_pr_list = pr_val
  print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
    print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
    print('thresh :', thresh)
    
  # if len(threshold) == 1:
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(test_pr_list))
    plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
  # plt.show()

    plt.subplot(122)
    plt.plot(np.cumprod(pred_pr_list))
    plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])

print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(threshold, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()
# Out:
# test_result.shape : (4079, 2)
# pr_val.shape : (4079, 1)
# y_test[:5] : [1 1 1 0 0]
# y_score[:5] : [[5.52383602e-01]
#  [1.03413491e-02]
#  [5.99138498e-01]
#  [1.05728805e-05]
#  [1.00000000e+00]]
# y_test.shape : (4079, 1)
# y_score.shape : (4079, 1)
# len(y_test) : 4079
# y_pred.shape : (4079,)
# precision : 0.45515558267236117
# recall : 0.3887441375716519
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 5.5692215e-08
# win ratio improvement 0.47 --> 0.46
# accum_pr increased ! : 0.000 --> 0.000
# thresh : 0.65
# acc_pr_bythr : [0.00015960658]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-684444aded9f> in <module>()
#     102 plt.figure(figsize=(10, 5))
#     103 plt.subplot(121)
# --> 104 plt.plot(threshold, precision, label='precision')
#     105 plt.plot(threshold, recall, label='recall')
#     106 plt.legend()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (3877,)

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
