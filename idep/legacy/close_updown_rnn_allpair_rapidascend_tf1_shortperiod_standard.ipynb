# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install h5py==2.10.0

# !pip install tensorflow==2.1.0
# !pip install keras==2.4.1

# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__
# Out:
# Collecting h5py==2.10.0
#   Downloading https://files.pythonhosted.org/packages/3f/c0/abde58b837e066bca19a3f7332d9d0493521d7dd6b48248451a9e3fe2214/h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 7.7MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.19.5)
# ERROR: tensorflow 2.5.0 has requirement h5py~=3.1.0, but you'll have h5py 2.10.0 which is incompatible.
# Installing collected packages: h5py
#   Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# Successfully installed h5py-2.10.0

# %%
# %tensorflow_version 1.x

import tensorflow as tf
tf.__version__
# Out:
# '2.1.0'

# %%
import keras
keras.__version__
from tensorflow.keras.utils import np_utils

# %% [markdown]
# ### load file list

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### custom model

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

# from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    
    visible = layers.Input(shape=input_shape, name='input')

    # net = layers.LSTM(32, return_sequences=False)(visible)
    net = layers.LSTM(32, return_sequences=True)(visible)
    net = layers.LeakyReLU()(net)

    net = layers.LSTM(32, return_sequences=False)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(256)(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)


    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dropout(0.3)(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
print(tf.__version__)
print(keras.__version__)
# Out:
# 1.15.2
# 2.3.1

# %% [markdown]
# ### all in one loop

# %%
print(ohlcv['close'].pct_change().head())
print(ohlcv['close'] / ohlcv['close'].shift(1).head() - 1)

# %%
# from tensorflow.keras.utils import to_categorical

# %%
from funcs_indicator import *
import matplotlib.pyplot as plt

# import mpl_finance as mf


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


def std_scale(values):
    return (values - values.mean()) / values.std()


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None


#           load saved npy & trained model        #
load_npy = False
load_model = False


seed = 1
random_state = 201
np.random.seed(seed)

fee = 0.0006
lvrg = 5

for i in range(len(candis)):

  keys = [candis[i]]

  if 'eth'.upper() not in candis[i]:
    continue

  # if 'comp'.upper() not in candis[i]:
  #   continue

  for key in keys:  
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))

        
    #       long      #
    pr = (ohlcv['close'].pct_change() - fee) * lvrg + 1    

    #       long liqudation     #
    lq = (ohlcv['low'] / ohlcv['close'].shift(1) - fee - 1) * lvrg + 1

    #       short       # <-- 이거를 단순히 minus 를 붙여도 되는걸까
    s_pr = (-ohlcv['close'].pct_change() - fee) * lvrg + 1

    #       short liqudation     #
    # s_lq = (ohlcv['high'] / ohlcv['close'].shift(1) - fee) * lvrg + 1
    

    #       fill na with 1.0      #
    # pr = np.where(np.isnan(pr), 1, pr)
    # print(len(pr))
    # print("len(pr[np.isnan(pr)]) :", len(pr[np.isnan(pr)]))
    # print("np.sum(np.isnan(pr)) :", np.sum(np.isnan(pr)))
    
    # sliced_ohlcv = ohlcv[np.sum(np.isnan(pr))]
    # print(sliced_ohlcv.head())
    # break
    # s_pr = np.where(np.isnan(s_pr), 1, pr)
    # lq = np.where(np.isnan(lq), 1, lq)


    #       set lq      #
    # pr = np.where((pr != 1) & (lq <= 0), 0, pr)

    # print("len(pr[pr < 0]) :", len(pr[pr < 0]))
    # break

    org_wr = len(pr[pr > 1]) / len(pr[pr != 1])

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(pr))
    plt.title("%s\norg_wr : %.3f\n acc_pr : %.3f" % (key, org_wr, np.cumprod(pr)[-1]))


    #                    strat                   #

    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) < ohlcv['close'].shift(3)), pr, 1)


    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
    #                     (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
    #                     (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)), pr, 1)


    strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
                        (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
                        (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
                        (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)) & 
                        (ohlcv['close'].shift(5) < ohlcv['close'].shift(6)), pr, 1)
    
    # strat_pr = np.where((ohlcv['high'].shift(2) > ohlcv['high'].shift(3))& 
    #                     (ohlcv['close'].shift(1) > ohlcv['close'].shift(2)), pr, 1)


    wr = len(strat_pr[strat_pr > 1]) / len(strat_pr[strat_pr != 1])

    plt.subplot(122)
    plt.plot(np.cumprod(strat_pr))
    plt.title("%s\norg_wr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr, np.cumprod(strat_pr)[-1]))


    # #                  sl cut                #
    # sl_line = ohlcv['low'].rolling(250).min().shift(1)
    # # sl_line = ohlcv['low'].shift(1)

    # strat_pr_sl = np.where((strat_pr != 1) & (sl_line > ohlcv['low']), 
    #                      1 + lvrg * (sl_line / ohlcv['close'].shift(1) - 1 - fee), strat_pr)


    # wr_sl = len(strat_pr_sl[strat_pr_sl > 1]) / len(strat_pr_sl[strat_pr_sl != 1])
    # # wl_pr_ratio = np.mean(strat_pr[strat_pr > 1]) / np.mean(strat_pr[strat_pr < 1])
    # # wl_pr_ratio = np.cumprod(strat_pr[strat_pr > 1])[-1] / np.cumprod(strat_pr[strat_pr < 1])[-1]

    # plt.subplot(122)
    # plt.plot(np.cumprod(strat_pr_sl))
    # plt.title("%s\norg_pr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr_sl, np.cumprod(strat_pr_sl)[-1]))


    plt.show()
    # break

    period = 28
    symbol_name = key.split(' ')[1].split('.')[0]      

    x_save_path = current_path + 'npy/' + '%s_lstm_updown_x_train_rascend_ohlcv_speriod_std_%s_tssplit.npy' % (period, symbol_name)
    pr_save_path = current_path + 'npy/' + '%s_lstm_updown_pr_train_rascend_ohlcv_speriod_std_%s_tssplit.npy' % (period, symbol_name)
    index_save_path = current_path + 'npy/' + '%s_lstm_updown_index_train_rascend_ohlcv_speriod_std_%s_tssplit.npy' % (period, symbol_name)



    if not load_npy:

      from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler, StandardScaler
      from sklearn.model_selection import train_test_split
      from datetime import datetime

      from funcs_indicator import *

      def min_max_scale(npy_x):

        return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[np.sum(np.isnan(pr)):]

      sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

      #       scale with price    #
      ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

      ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
      sar = lucid_sar(sliced_ohlcv)
      ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
      senkou1, senkou2 = ichimoku(sliced_ohlcv)

      #     min max scale   #
      vol = ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]
      # vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

      pr_list = pr[np.sum(np.isnan(pr)):]
      print("len(ohlc) :", len(ohlc))
      print("len(pr_list) :", len(pr_list))

      print("ohlc.index[0] :", ohlc.index[0])
      print("vol.index[0] :", vol.index[0])
      # break


      #       set params    #
      # period = 45
      key_i = i

      plotting = True

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(ohlc)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()

          std = StandardScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          # temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

          temp_close = min_max_scale(temp_ohlc[:, [3]])    

          price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          # ind_temp_ohlc = min_max_scale(temp_ohlc)
          # ind_temp_ohlc = std.fit_transform(temp_ohlc)
          ind_temp_ohlc = std_scale(temp_ohlc)

          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


          if plotting:

            plt.plot(ind_temp_ohlc)
            plt.show()
            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          # temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          temp_vol = std.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          #                   feature selection                   #        
          temp_data = np.hstack((ind_temp_ohlc, temp_vol))

          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          # temp_data = temp_ohlc[:, [3]]
          # temp_data = ind_temp_ohlc[:, [3]]
          # temp_data = temp_close

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      # input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      # input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)


      # _, row, col, _ = input_x.shape
      # _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      #                 don't shuffle timeseries data                 #
      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)


      np.save(x_save_path, x_train)
      np.save(x_save_path.replace('x_train', 'x_val'), x_val)
      np.save(x_save_path.replace('x_train', 'x_test'), x_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('x series saved !')

      np.save(pr_save_path, pr_train)
      np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
      np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
      # np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
      print('pr series saved !')
      
      np.save(index_save_path, index_train)
      np.save(index_save_path.replace('index_train', 'index_val'), index_val)
      np.save(index_save_path.replace('index_train', 'index_test'), index_test)
      print('index series saved !')

    else:
      
      x_train = np.load(x_save_path)
      x_val = np.load(x_save_path.replace('x_train', 'x_val'))
      x_test = np.load(x_save_path.replace('x_train', 'x_test'))
      print('x series loaded !')


      pr_train = np.load(pr_save_path)
      pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
      pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
      print('y series loaded !')


      index_train = np.load(index_save_path, allow_pickle=True)
      index_val = np.load(index_save_path.replace('index_train', 'index_val'), allow_pickle=True)
      index_test = np.load(index_save_path.replace('index_train', 'index_test'), allow_pickle=True)
      print('index series loaded !')




    #       pr_thresh by percentage 0.285     #
    plt.plot(pr)
    plt.show()
    
    sorted_pr = sorted(pr, reverse=True)
    pct = 0.285
    len_pct = int(len(pr) * pct)
    pr_thresh = sorted_pr[len_pct]
    print("pr_thresh :", pr_thresh)

    # from tensorflow.keras.utils import np_utils
    # from keras.utils import to_categorical
    from keras.utils.np_utils import to_categorical

    from sklearn.utils import class_weight


    def class_ratio(in_list):

      return in_list / in_list[1]
      
    y_train = np.where(pr_train > pr_thresh, 1, 0)
    y_test = np.where(pr_test > pr_thresh, 1, 0)
    y_val = np.where(pr_val > pr_thresh, 1, 0)

    print('x_train.shape :', x_train.shape)
    print('x_test.shape :', x_test.shape)
    print('x_val.shape :', x_val.shape)
    print('y_train.shape :', y_train.shape)
    print('y_test.shape :', y_test.shape)
    print('y_val.shape :', y_val.shape)

    # try:
    print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
    print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
    print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

    # except Exception as e:
      # print(e)

    label = y_train.reshape(-1, )
    class_weights = class_weight.compute_class_weight('balanced', 
                                                        classes=np.unique(label),
                                                        y=label)
    class_weights = dict(enumerate(class_weights))
    print('class_weights :', class_weights)

    # sample_weight = np.ones(shape=(len(y_train),))
    # sample_weight[(y_train == 1).reshape(-1,)] = 1.5
    # print('sample_weight[:20] :', sample_weight[:20])


    print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
    print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
    print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

    print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
    print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
    print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

    num_classes = 2
    
    # y_train_ohe = np_utils.to_categorical(y_train, num_classes)
    # y_val_ohe = np_utils.to_categorical(y_val, num_classes)
    # y_test_ohe = np_utils.to_categorical(y_test, num_classes)
    
    y_train_ohe = to_categorical(y_train, num_classes)
    y_val_ohe = to_categorical(y_val, num_classes)
    y_test_ohe = to_categorical(y_test, num_classes)
    print('y_train_ohe.shape :', y_train_ohe.shape)
    print('y_val_ohe.shape :', y_val_ohe.shape)
    print('y_test_ohe.shape :', y_test_ohe.shape)



    batch_size = 512

    

    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'

    # batch_size = 512

    K.clear_session()


    # model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_tf250_%s_tvnon_shuffle.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_tf241_%s_tvnon_shuffle.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_lstm_updown_rascend_%s_tf115_%s.h5' % (period, int(pct * 1000), symbol_name)
    model_name = 'classifier_%s_lstm_updown_rascend_std_%s_tf115_%s.h5' % (period, int(pct * 1000), symbol_name)



    if not load_model:

      # from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
      from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

      model = FER_Model(input_shape=x_train.shape[1:])
      # opt = Adam(lr=1e-5, decay=5e-6)
      opt = Adam( learning_rate=1e-5, decay=5e-6, beta_1=0.9, beta_2=0.999, epsilon=1e-7)

      # opt = Adam(lr=0.001, decay=0.0005)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
      # checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir=board_path,
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_loss', patience=500)
      callbacks_list = [checkpoint,
                        checkpoint2, 
                        checkpoint3
                        ]
      # callbacks_list = [checkpoint, checkpoint2]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 2000
      history = model.fit(x_train, y_train_ohe, 
                          steps_per_epoch=int(len(x_train) / batch_size), 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=(x_val, y_val_ohe),  
                          validation_steps=int(len(x_val) / batch_size),
                          shuffle=False)
      
    
    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'


    model = keras.models.load_model(ckpt_path + model_name)

    test_result = model.predict(x_test)
    # test_result = model.predict(test_set)

    print('test_result.shape :', test_result.shape)
    # print('pr_val.shape :', pr_val.shape)

    y_score = test_result[:, [1]]
    print('y_test[:5] :', y_test.reshape(-1,)[:5])
    # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
    print('y_score[:5] :', y_score[:5])
    # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

    print('y_test.shape :', y_test.shape)
    print('y_score.shape :', y_score.shape)

    print('len(y_test) :', len(y_test))

    #     precision recall curve   #
    precision, recall, threshold = precision_recall_curve(y_test, y_score)
    precision, recall = precision[:-1], recall[:-1]

    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    plt.show()
    # print(y_pred)


    # threshold = [0.65]
    # print('threshold :', threshold)
    # break

    acc_pr_bythr = []
    new_thresh = []
    temp_pr_list = []


    for thresh in threshold:
      
      # if thresh < 0.5:
      #     continue

      y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
      # print('y_pred.shape :', y_pred.shape)
      # print('y_pred :', y_pred)

      #     compare precision     #

      # print('precision :', precision_score(y_test, y_pred))
      # print('recall :', recall_score(y_test, y_pred))
      # print()

      # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
      # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

      # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
      # # plt.show()  
      # print()

      #     check win-ratio improvement     #
      cmat = confusion_matrix(y_test, y_pred)
      # print(cmat)
      # print(np.sum(cmat, axis=1))

      test_size = len(y_test)
      test_pr_list = pr_test
      # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

      org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
      ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
      # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

      # print('pr_test.shape :', pr_test.shape)

      # print(y_pred)
      # print(test_pr_list)

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
      # print('pred_pr_list.shape :', pred_pr_list.shape)

      temp_pr_list.append(pred_pr_list)


      # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
      #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
      #   print('thresh :', thresh)
        
      # if len(threshold) == 1:
    #   plt.figure(figsize=(10, 5))
    #   plt.subplot(121)
    #   plt.plot(np.cumprod(test_pr_list))
    #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
    # # plt.show()

    #   plt.subplot(122)
    #   plt.plot(np.cumprod(pred_pr_list))
    #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
    #   plt.show()


      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)


    print('acc_pr_bythr :', acc_pr_bythr)

    plt.figure(figsize=(13, 5))
    plt.subplot(131)
    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    # plt.show()
    plt.subplot(132)
    plt.plot(new_thresh, acc_pr_bythr)
    plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')

    best_thr = new_thresh[np.argmax(acc_pr_bythr)]
    plt.axvline(best_thr, linestyle='--', color='r')
    plt.title(symbol_name + '\n' + str(best_thr))

    plt.subplot(133)
    plt.plot(np.cumprod(temp_pr_list[np.argmax(acc_pr_bythr)]))

    plt.show()
# Out:
# start_stamp : 0
# len(ohlcv) : 18048
# len(ohlc) : 18047
# len(pr_list) : 18047
# ohlc.index[0] : 2020-04-17 00:59:59.999000
# vol.index[0] : 2020-04-17 00:59:59.999000
# np.array(data_x).shape : (17943, 28, 5)
# input_x.shape : (17943, 28, 5)
# input_x.dtype : float32
# input_pr.shape : (17943, 1)
# input_ud.shape : (17943, 1)
# input_index.shape : (17943, 1)
# total_x.shape : (17943, 28, 5)
# total_pr.shape : (17943, 1)
# total_ud.shape : (17943, 1)
# prev_index.shape : (17943, 1)
# (array([Timestamp('2020-04-19 04:59:59.999000'),
#        Timestamp('2020-04-19 05:29:59.999000'),
#        Timestamp('2020-04-19 05:59:59.999000'), ...,
#        Timestamp('2021-04-27 22:59:59.999000'),
#        Timestamp('2021-04-27 23:29:59.999000'),
#        Timestamp('2021-04-27 23:59:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (10765,)
# stamp_val.shape : (3589,)
# stamp_test.shape : (3589,)
# HBox(children=(FloatProgress(value=0.0, max=17943.0), HTML(value='')))
# x_train.shape : (10765, 28, 5)
# x_val.shape : (3589, 28, 5)
# x_test.shape : (3589, 28, 5)
# x series saved !
# pr series saved !
# index series saved !
# pr_thresh : 1.010013727383401
# x_train.shape : (10765, 28, 5)
# x_test.shape : (3589, 28, 5)
# x_val.shape : (3589, 28, 5)
# y_train.shape : (10765, 1)
# y_test.shape : (3589, 1)
# y_val.shape : (3589, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([7696, 3069])) [2.50765722 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2585, 1004])) [2.5747012 1.       ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2557, 1032])) [2.47771318 1.        ]
# class_weights : {0: 0.6993892931392931, 1: 1.7538286086673183}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10765, 2)
# y_val_ohe.shape : (3589, 2)
# y_test_ohe.shape : (3589, 2)
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 28, 5)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 28, 32)            4864
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 28, 32)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 99,202
# Trainable params: 98,562
# Non-trainable params: 640
# _________________________________________________________________
# None
# Train on 10765 samples, validate on 3589 samples
# Epoch 1/2000
#  - 2s - loss: 0.9519 - accuracy: 0.4660 - val_loss: 0.0980 - val_accuracy: 5.0418
#
# Epoch 00001: val_loss improved from inf to 0.09803, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 2/2000
#  - 1s - loss: 0.8457 - accuracy: 0.4517 - val_loss: 0.0968 - val_accuracy: 5.0418
#
# Epoch 00002: val_loss improved from 0.09803 to 0.09682, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 3/2000
#  - 1s - loss: 0.7947 - accuracy: 0.4643 - val_loss: 0.0957 - val_accuracy: 5.0418
#
# Epoch 00003: val_loss improved from 0.09682 to 0.09575, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 4/2000
#  - 1s - loss: 0.7729 - accuracy: 0.4871 - val_loss: 0.0948 - val_accuracy: 5.0418
#
# Epoch 00004: val_loss improved from 0.09575 to 0.09483, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 5/2000
#  - 1s - loss: 0.7622 - accuracy: 0.5009 - val_loss: 0.0941 - val_accuracy: 5.0418
#
# Epoch 00005: val_loss improved from 0.09483 to 0.09405, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 6/2000
#  - 1s - loss: 0.7545 - accuracy: 0.5086 - val_loss: 0.0934 - val_accuracy: 5.0418
#
# Epoch 00006: val_loss improved from 0.09405 to 0.09339, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 7/2000
#  - 1s - loss: 0.7486 - accuracy: 0.5082 - val_loss: 0.0928 - val_accuracy: 5.0418
#
# Epoch 00007: val_loss improved from 0.09339 to 0.09282, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 8/2000
#  - 1s - loss: 0.7458 - accuracy: 0.5092 - val_loss: 0.0923 - val_accuracy: 5.0418
#
# Epoch 00008: val_loss improved from 0.09282 to 0.09230, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 9/2000
#  - 1s - loss: 0.7419 - accuracy: 0.5096 - val_loss: 0.0918 - val_accuracy: 5.0418
#
# Epoch 00009: val_loss improved from 0.09230 to 0.09182, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 10/2000
#  - 1s - loss: 0.7358 - accuracy: 0.5147 - val_loss: 0.0914 - val_accuracy: 5.0418
#
# Epoch 00010: val_loss improved from 0.09182 to 0.09140, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 11/2000
#  - 1s - loss: 0.7340 - accuracy: 0.5142 - val_loss: 0.0910 - val_accuracy: 5.0418
#
# Epoch 00011: val_loss improved from 0.09140 to 0.09104, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 12/2000
#  - 1s - loss: 0.7304 - accuracy: 0.5170 - val_loss: 0.0907 - val_accuracy: 5.0418
#
# Epoch 00012: val_loss improved from 0.09104 to 0.09072, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 13/2000
#  - 1s - loss: 0.7271 - accuracy: 0.5189 - val_loss: 0.0905 - val_accuracy: 5.0418
#
# Epoch 00013: val_loss improved from 0.09072 to 0.09045, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 14/2000
#  - 1s - loss: 0.7247 - accuracy: 0.5194 - val_loss: 0.0902 - val_accuracy: 5.0418
#
# Epoch 00014: val_loss improved from 0.09045 to 0.09024, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 15/2000
#  - 1s - loss: 0.7221 - accuracy: 0.5209 - val_loss: 0.0901 - val_accuracy: 5.0418
#
# Epoch 00015: val_loss improved from 0.09024 to 0.09007, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 16/2000
#  - 1s - loss: 0.7201 - accuracy: 0.5213 - val_loss: 0.0900 - val_accuracy: 5.0418
#
# Epoch 00016: val_loss improved from 0.09007 to 0.08996, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 17/2000
#  - 1s - loss: 0.7182 - accuracy: 0.5237 - val_loss: 0.0899 - val_accuracy: 5.0418
#
# Epoch 00017: val_loss improved from 0.08996 to 0.08988, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 18/2000
#  - 1s - loss: 0.7164 - accuracy: 0.5238 - val_loss: 0.0898 - val_accuracy: 5.0418
#
# Epoch 00018: val_loss improved from 0.08988 to 0.08984, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_28_lstm_updown_rascend_std_285_tf115_ETHUSDT.h5
# Epoch 19/2000
#  - 1s - loss: 0.7140 - accuracy: 0.5240 - val_loss: 0.0899 - val_accuracy: 5.0418
#
# Epoch 00019: val_loss did not improve from 0.08984
# Epoch 20/2000
#  - 1s - loss: 0.7125 - accuracy: 0.5267 - val_loss: 0.0899 - val_accuracy: 5.0398
#
# Epoch 00020: val_loss did not improve from 0.08984
# Epoch 21/2000
#  - 1s - loss: 0.7108 - accuracy: 0.5274 - val_loss: 0.0899 - val_accuracy: 5.0398
#
# Epoch 00021: val_loss did not improve from 0.08984
# Epoch 22/2000
#  - 1s - loss: 0.7100 - accuracy: 0.5296 - val_loss: 0.0900 - val_accuracy: 5.0379
#
# Epoch 00022: val_loss did not improve from 0.08984
# Epoch 23/2000
#  - 1s - loss: 0.7082 - accuracy: 0.5297 - val_loss: 0.0901 - val_accuracy: 5.0379
#
# Epoch 00023: val_loss did not improve from 0.08984
# Epoch 24/2000
#  - 1s - loss: 0.7058 - accuracy: 0.5331 - val_loss: 0.0901 - val_accuracy: 5.0398
#
# Epoch 00024: val_loss did not improve from 0.08984
# Epoch 25/2000
#  - 1s - loss: 0.7054 - accuracy: 0.5336 - val_loss: 0.0903 - val_accuracy: 5.0398
#
# Epoch 00025: val_loss did not improve from 0.08984
# Epoch 26/2000
#  - 1s - loss: 0.7041 - accuracy: 0.5339 - val_loss: 0.0905 - val_accuracy: 5.0203
#
# Epoch 00026: val_loss did not improve from 0.08984
# Epoch 27/2000
#  - 1s - loss: 0.7029 - accuracy: 0.5351 - val_loss: 0.0907 - val_accuracy: 5.0067
#
# Epoch 00027: val_loss did not improve from 0.08984
# Epoch 28/2000
#  - 1s - loss: 0.7016 - accuracy: 0.5364 - val_loss: 0.0910 - val_accuracy: 4.9833
#
# Epoch 00028: val_loss did not improve from 0.08984
# Epoch 29/2000
#  - 1s - loss: 0.7014 - accuracy: 0.5362 - val_loss: 0.0914 - val_accuracy: 4.9696
#
# Epoch 00029: val_loss did not improve from 0.08984
# Epoch 30/2000
#  - 1s - loss: 0.6994 - accuracy: 0.5377 - val_loss: 0.0917 - val_accuracy: 4.9423
#
# Epoch 00030: val_loss did not improve from 0.08984
# Epoch 31/2000
#  - 1s - loss: 0.6987 - accuracy: 0.5397 - val_loss: 0.0921 - val_accuracy: 4.8994
#
# Epoch 00031: val_loss did not improve from 0.08984
# Epoch 32/2000
#  - 1s - loss: 0.6978 - accuracy: 0.5392 - val_loss: 0.0925 - val_accuracy: 4.8390
#
# Epoch 00032: val_loss did not improve from 0.08984
# Epoch 33/2000
#  - 1s - loss: 0.6954 - accuracy: 0.5430 - val_loss: 0.0930 - val_accuracy: 4.8097
#
# Epoch 00033: val_loss did not improve from 0.08984
# Epoch 34/2000
#  - 1s - loss: 0.6958 - accuracy: 0.5434 - val_loss: 0.0935 - val_accuracy: 4.7278
#
# Epoch 00034: val_loss did not improve from 0.08984
# Epoch 35/2000
#  - 1s - loss: 0.6955 - accuracy: 0.5436 - val_loss: 0.0940 - val_accuracy: 4.6225
#
# Epoch 00035: val_loss did not improve from 0.08984
# Epoch 36/2000
#  - 1s - loss: 0.6932 - accuracy: 0.5465 - val_loss: 0.0945 - val_accuracy: 4.5308
#
# Epoch 00036: val_loss did not improve from 0.08984
# Epoch 37/2000
#  - 1s - loss: 0.6932 - accuracy: 0.5474 - val_loss: 0.0948 - val_accuracy: 4.4742
#
# Epoch 00037: val_loss did not improve from 0.08984
# Epoch 38/2000
#  - 1s - loss: 0.6913 - accuracy: 0.5483 - val_loss: 0.0952 - val_accuracy: 4.4294
#
# Epoch 00038: val_loss did not improve from 0.08984
# Epoch 39/2000
#  - 1s - loss: 0.6906 - accuracy: 0.5508 - val_loss: 0.0955 - val_accuracy: 4.3689
#
# Epoch 00039: val_loss did not improve from 0.08984
# Epoch 40/2000
#  - 1s - loss: 0.6906 - accuracy: 0.5506 - val_loss: 0.0958 - val_accuracy: 4.2948
#
# Epoch 00040: val_loss did not improve from 0.08984
# Epoch 41/2000
#  - 1s - loss: 0.6900 - accuracy: 0.5505 - val_loss: 0.0961 - val_accuracy: 4.2109
#
# Epoch 00041: val_loss did not improve from 0.08984
# Epoch 42/2000
#  - 1s - loss: 0.6899 - accuracy: 0.5525 - val_loss: 0.0962 - val_accuracy: 4.1739
#
# Epoch 00042: val_loss did not improve from 0.08984
# Epoch 43/2000
#  - 1s - loss: 0.6887 - accuracy: 0.5534 - val_loss: 0.0964 - val_accuracy: 4.1251
#
# Epoch 00043: val_loss did not improve from 0.08984
# Epoch 44/2000
#  - 1s - loss: 0.6874 - accuracy: 0.5555 - val_loss: 0.0966 - val_accuracy: 4.1017
#
# Epoch 00044: val_loss did not improve from 0.08984
# Epoch 45/2000
#  - 1s - loss: 0.6874 - accuracy: 0.5551 - val_loss: 0.0967 - val_accuracy: 4.0939
#
# Epoch 00045: val_loss did not improve from 0.08984
# Epoch 46/2000
#  - 1s - loss: 0.6860 - accuracy: 0.5586 - val_loss: 0.0968 - val_accuracy: 4.0724
#
# Epoch 00046: val_loss did not improve from 0.08984
# Epoch 47/2000
#  - 1s - loss: 0.6859 - accuracy: 0.5584 - val_loss: 0.0969 - val_accuracy: 4.0568
#
# Epoch 00047: val_loss did not improve from 0.08984
# Epoch 48/2000
#  - 1s - loss: 0.6850 - accuracy: 0.5597 - val_loss: 0.0969 - val_accuracy: 4.0490
#
# Epoch 00048: val_loss did not improve from 0.08984
# Epoch 49/2000
#  - 1s - loss: 0.6841 - accuracy: 0.5607 - val_loss: 0.0969 - val_accuracy: 4.0490
#
# Epoch 00049: val_loss did not improve from 0.08984
# Epoch 50/2000
#  - 1s - loss: 0.6838 - accuracy: 0.5599 - val_loss: 0.0969 - val_accuracy: 4.0549
#
# Epoch 00050: val_loss did not improve from 0.08984
# Epoch 51/2000
#  - 1s - loss: 0.6839 - accuracy: 0.5609 - val_loss: 0.0969 - val_accuracy: 4.0451
#
# Epoch 00051: val_loss did not improve from 0.08984
# Epoch 52/2000
#  - 1s - loss: 0.6826 - accuracy: 0.5637 - val_loss: 0.0968 - val_accuracy: 4.0705
#
# Epoch 00052: val_loss did not improve from 0.08984
# Epoch 53/2000
#  - 1s - loss: 0.6822 - accuracy: 0.5653 - val_loss: 0.0968 - val_accuracy: 4.0802
#
# Epoch 00053: val_loss did not improve from 0.08984
# Epoch 54/2000
#  - 1s - loss: 0.6820 - accuracy: 0.5652 - val_loss: 0.0967 - val_accuracy: 4.0705
#
# Epoch 00054: val_loss did not improve from 0.08984
# Epoch 55/2000
#  - 1s - loss: 0.6818 - accuracy: 0.5655 - val_loss: 0.0968 - val_accuracy: 4.0705
#
# Epoch 00055: val_loss did not improve from 0.08984
# Epoch 56/2000
#  - 1s - loss: 0.6799 - accuracy: 0.5670 - val_loss: 0.0968 - val_accuracy: 4.0802
#
# Epoch 00056: val_loss did not improve from 0.08984
# Epoch 57/2000
#  - 1s - loss: 0.6799 - accuracy: 0.5685 - val_loss: 0.0969 - val_accuracy: 4.0432
#
# Epoch 00057: val_loss did not improve from 0.08984
# Epoch 58/2000
#  - 1s - loss: 0.6796 - accuracy: 0.5692 - val_loss: 0.0971 - val_accuracy: 4.0393
#
# Epoch 00058: val_loss did not improve from 0.08984
# Epoch 59/2000
#  - 1s - loss: 0.6788 - accuracy: 0.5715 - val_loss: 0.0970 - val_accuracy: 4.0471
#
# Epoch 00059: val_loss did not improve from 0.08984
# Epoch 60/2000
#  - 1s - loss: 0.6790 - accuracy: 0.5679 - val_loss: 0.0970 - val_accuracy: 4.0315
#
# Epoch 00060: val_loss did not improve from 0.08984
# Epoch 61/2000
#  - 1s - loss: 0.6773 - accuracy: 0.5733 - val_loss: 0.0971 - val_accuracy: 4.0198
#
# Epoch 00061: val_loss did not improve from 0.08984
# Epoch 62/2000
#  - 1s - loss: 0.6772 - accuracy: 0.5740 - val_loss: 0.0970 - val_accuracy: 4.0295
#
# Epoch 00062: val_loss did not improve from 0.08984
# Epoch 63/2000
#  - 1s - loss: 0.6768 - accuracy: 0.5752 - val_loss: 0.0969 - val_accuracy: 4.0276
#
# Epoch 00063: val_loss did not improve from 0.08984
# Epoch 64/2000
#  - 1s - loss: 0.6763 - accuracy: 0.5748 - val_loss: 0.0970 - val_accuracy: 4.0178
#
# Epoch 00064: val_loss did not improve from 0.08984
# Epoch 65/2000
#  - 1s - loss: 0.6760 - accuracy: 0.5750 - val_loss: 0.0968 - val_accuracy: 4.0432
#
# Epoch 00065: val_loss did not improve from 0.08984
# Epoch 66/2000
#  - 1s - loss: 0.6759 - accuracy: 0.5759 - val_loss: 0.0968 - val_accuracy: 4.0276
#
# Epoch 00066: val_loss did not improve from 0.08984
# Epoch 67/2000
#  - 1s - loss: 0.6743 - accuracy: 0.5773 - val_loss: 0.0969 - val_accuracy: 4.0139
#
# Epoch 00067: val_loss did not improve from 0.08984
# Epoch 68/2000
#  - 1s - loss: 0.6747 - accuracy: 0.5793 - val_loss: 0.0968 - val_accuracy: 4.0159
#
# Epoch 00068: val_loss did not improve from 0.08984
# Epoch 69/2000
#  - 1s - loss: 0.6747 - accuracy: 0.5783 - val_loss: 0.0968 - val_accuracy: 4.0198
#
# Epoch 00069: val_loss did not improve from 0.08984
# Epoch 70/2000
#  - 1s - loss: 0.6738 - accuracy: 0.5802 - val_loss: 0.0967 - val_accuracy: 4.0217
#
# Epoch 00070: val_loss did not improve from 0.08984
# Epoch 71/2000
#  - 1s - loss: 0.6734 - accuracy: 0.5798 - val_loss: 0.0966 - val_accuracy: 4.0568
#
# Epoch 00071: val_loss did not improve from 0.08984
# Epoch 72/2000
#  - 1s - loss: 0.6726 - accuracy: 0.5836 - val_loss: 0.0966 - val_accuracy: 4.0763
#
# Epoch 00072: val_loss did not improve from 0.08984
# Epoch 73/2000
#  - 1s - loss: 0.6727 - accuracy: 0.5826 - val_loss: 0.0967 - val_accuracy: 4.0588
#
# Epoch 00073: val_loss did not improve from 0.08984
# Epoch 74/2000
#  - 1s - loss: 0.6719 - accuracy: 0.5835 - val_loss: 0.0967 - val_accuracy: 4.0354
#
# Epoch 00074: val_loss did not improve from 0.08984
# Epoch 75/2000
#  - 1s - loss: 0.6708 - accuracy: 0.5854 - val_loss: 0.0968 - val_accuracy: 4.0178
#
# Epoch 00075: val_loss did not improve from 0.08984
# Epoch 76/2000
#  - 1s - loss: 0.6719 - accuracy: 0.5833 - val_loss: 0.0968 - val_accuracy: 4.0198
#
# Epoch 00076: val_loss did not improve from 0.08984
# Epoch 77/2000
#  - 1s - loss: 0.6707 - accuracy: 0.5858 - val_loss: 0.0969 - val_accuracy: 4.0022
#
# Epoch 00077: val_loss did not improve from 0.08984
# Epoch 78/2000
#  - 1s - loss: 0.6707 - accuracy: 0.5857 - val_loss: 0.0967 - val_accuracy: 4.0334
#
# Epoch 00078: val_loss did not improve from 0.08984
# Epoch 79/2000
#  - 1s - loss: 0.6701 - accuracy: 0.5872 - val_loss: 0.0966 - val_accuracy: 4.0373
#
# Epoch 00079: val_loss did not improve from 0.08984
# Epoch 80/2000
#  - 1s - loss: 0.6694 - accuracy: 0.5901 - val_loss: 0.0967 - val_accuracy: 4.0393
#
# Epoch 00080: val_loss did not improve from 0.08984
# Epoch 81/2000
#  - 1s - loss: 0.6688 - accuracy: 0.5893 - val_loss: 0.0967 - val_accuracy: 4.0237
#
# Epoch 00081: val_loss did not improve from 0.08984
# Epoch 82/2000
#  - 1s - loss: 0.6688 - accuracy: 0.5899 - val_loss: 0.0969 - val_accuracy: 4.0061
#
# Epoch 00082: val_loss did not improve from 0.08984
# Epoch 83/2000
#  - 1s - loss: 0.6682 - accuracy: 0.5897 - val_loss: 0.0967 - val_accuracy: 4.0198
#
# Epoch 00083: val_loss did not improve from 0.08984
# Epoch 84/2000
#  - 1s - loss: 0.6677 - accuracy: 0.5925 - val_loss: 0.0966 - val_accuracy: 4.0568
#
# Epoch 00084: val_loss did not improve from 0.08984
# Epoch 85/2000
#  - 1s - loss: 0.6671 - accuracy: 0.5928 - val_loss: 0.0965 - val_accuracy: 4.0471
#
# Epoch 00085: val_loss did not improve from 0.08984
# Epoch 86/2000
#  - 1s - loss: 0.6669 - accuracy: 0.5926 - val_loss: 0.0966 - val_accuracy: 4.0139
#
# Epoch 00086: val_loss did not improve from 0.08984
# Epoch 87/2000
#  - 1s - loss: 0.6669 - accuracy: 0.5941 - val_loss: 0.0965 - val_accuracy: 4.0568
#
# Epoch 00087: val_loss did not improve from 0.08984
# Epoch 88/2000
#  - 1s - loss: 0.6663 - accuracy: 0.5938 - val_loss: 0.0964 - val_accuracy: 4.0666
#
# Epoch 00088: val_loss did not improve from 0.08984
# Epoch 89/2000
#  - 1s - loss: 0.6657 - accuracy: 0.5963 - val_loss: 0.0965 - val_accuracy: 4.0607
#
# Epoch 00089: val_loss did not improve from 0.08984
# Epoch 90/2000
#  - 1s - loss: 0.6656 - accuracy: 0.5958 - val_loss: 0.0963 - val_accuracy: 4.0588
#
# Epoch 00090: val_loss did not improve from 0.08984
# Epoch 91/2000
#  - 1s - loss: 0.6649 - accuracy: 0.5967 - val_loss: 0.0963 - val_accuracy: 4.0627
#
# Epoch 00091: val_loss did not improve from 0.08984
# Epoch 92/2000
#  - 1s - loss: 0.6645 - accuracy: 0.5970 - val_loss: 0.0963 - val_accuracy: 4.0451
#
# Epoch 00092: val_loss did not improve from 0.08984
# Epoch 93/2000
#  - 1s - loss: 0.6638 - accuracy: 0.5998 - val_loss: 0.0964 - val_accuracy: 4.0627
#
# Epoch 00093: val_loss did not improve from 0.08984
# Epoch 94/2000
#  - 1s - loss: 0.6639 - accuracy: 0.5975 - val_loss: 0.0964 - val_accuracy: 4.0627
#
# Epoch 00094: val_loss did not improve from 0.08984
# Epoch 95/2000
#  - 1s - loss: 0.6634 - accuracy: 0.6000 - val_loss: 0.0963 - val_accuracy: 4.0802
#
# Epoch 00095: val_loss did not improve from 0.08984
# Epoch 96/2000
#  - 1s - loss: 0.6626 - accuracy: 0.6007 - val_loss: 0.0964 - val_accuracy: 4.0510
#
# Epoch 00096: val_loss did not improve from 0.08984
# Epoch 97/2000
#  - 1s - loss: 0.6628 - accuracy: 0.5993 - val_loss: 0.0964 - val_accuracy: 4.0510
#
# Epoch 00097: val_loss did not improve from 0.08984
# Epoch 98/2000
#  - 1s - loss: 0.6622 - accuracy: 0.6014 - val_loss: 0.0963 - val_accuracy: 4.0607
#
# Epoch 00098: val_loss did not improve from 0.08984
# Epoch 99/2000
#  - 1s - loss: 0.6617 - accuracy: 0.6035 - val_loss: 0.0963 - val_accuracy: 4.0627
#
# Epoch 00099: val_loss did not improve from 0.08984
# Epoch 100/2000
#  - 1s - loss: 0.6614 - accuracy: 0.6022 - val_loss: 0.0962 - val_accuracy: 4.0802
#
# Epoch 00100: val_loss did not improve from 0.08984
# Epoch 101/2000
#  - 1s - loss: 0.6607 - accuracy: 0.6049 - val_loss: 0.0962 - val_accuracy: 4.0783
#
# Epoch 00101: val_loss did not improve from 0.08984
# Epoch 102/2000
#  - 1s - loss: 0.6605 - accuracy: 0.6040 - val_loss: 0.0964 - val_accuracy: 4.0588
#
# Epoch 00102: val_loss did not improve from 0.08984
# Epoch 103/2000
#  - 1s - loss: 0.6602 - accuracy: 0.6056 - val_loss: 0.0963 - val_accuracy: 4.0588
#
# Epoch 00103: val_loss did not improve from 0.08984
# Epoch 104/2000
#  - 1s - loss: 0.6594 - accuracy: 0.6067 - val_loss: 0.0962 - val_accuracy: 4.0802
#
# Epoch 00104: val_loss did not improve from 0.08984
# Epoch 105/2000
#  - 1s - loss: 0.6591 - accuracy: 0.6063 - val_loss: 0.0962 - val_accuracy: 4.0588
#
# Epoch 00105: val_loss did not improve from 0.08984
# Epoch 106/2000
#  - 1s - loss: 0.6582 - accuracy: 0.6080 - val_loss: 0.0963 - val_accuracy: 4.0510
#
# Epoch 00106: val_loss did not improve from 0.08984
# Epoch 107/2000
#  - 1s - loss: 0.6579 - accuracy: 0.6088 - val_loss: 0.0963 - val_accuracy: 4.0432
#
# Epoch 00107: val_loss did not improve from 0.08984
# Epoch 108/2000
#  - 1s - loss: 0.6575 - accuracy: 0.6092 - val_loss: 0.0963 - val_accuracy: 4.0510
#
# Epoch 00108: val_loss did not improve from 0.08984
# Epoch 109/2000
#  - 1s - loss: 0.6573 - accuracy: 0.6099 - val_loss: 0.0960 - val_accuracy: 4.1017
#
# Epoch 00109: val_loss did not improve from 0.08984
# Epoch 110/2000
#  - 1s - loss: 0.6568 - accuracy: 0.6101 - val_loss: 0.0962 - val_accuracy: 4.0841
#
# Epoch 00110: val_loss did not improve from 0.08984
# Epoch 111/2000
#  - 1s - loss: 0.6566 - accuracy: 0.6100 - val_loss: 0.0962 - val_accuracy: 4.0568
#
# Epoch 00111: val_loss did not improve from 0.08984
# Epoch 112/2000
#  - 1s - loss: 0.6563 - accuracy: 0.6100 - val_loss: 0.0961 - val_accuracy: 4.0627
#
# Epoch 00112: val_loss did not improve from 0.08984
# Epoch 113/2000
#  - 1s - loss: 0.6554 - accuracy: 0.6115 - val_loss: 0.0962 - val_accuracy: 4.0607
#
# Epoch 00113: val_loss did not improve from 0.08984
# Epoch 114/2000
#  - 1s - loss: 0.6554 - accuracy: 0.6129 - val_loss: 0.0962 - val_accuracy: 4.0705
#
# Epoch 00114: val_loss did not improve from 0.08984
# Epoch 115/2000
#  - 1s - loss: 0.6544 - accuracy: 0.6139 - val_loss: 0.0961 - val_accuracy: 4.0744
#
# Epoch 00115: val_loss did not improve from 0.08984
# Epoch 116/2000
#  - 1s - loss: 0.6546 - accuracy: 0.6145 - val_loss: 0.0964 - val_accuracy: 4.0471
#
# Epoch 00116: val_loss did not improve from 0.08984
# Epoch 117/2000
#  - 1s - loss: 0.6533 - accuracy: 0.6156 - val_loss: 0.0962 - val_accuracy: 4.0685
#
# Epoch 00117: val_loss did not improve from 0.08984
# Epoch 118/2000
#  - 1s - loss: 0.6538 - accuracy: 0.6150 - val_loss: 0.0962 - val_accuracy: 4.0724
#
# Epoch 00118: val_loss did not improve from 0.08984
# Epoch 119/2000
#  - 1s - loss: 0.6533 - accuracy: 0.6154 - val_loss: 0.0963 - val_accuracy: 4.0685
#
# Epoch 00119: val_loss did not improve from 0.08984
# Epoch 120/2000
#  - 1s - loss: 0.6521 - accuracy: 0.6178 - val_loss: 0.0961 - val_accuracy: 4.0900
#
# Epoch 00120: val_loss did not improve from 0.08984
# Epoch 121/2000
#  - 1s - loss: 0.6521 - accuracy: 0.6175 - val_loss: 0.0963 - val_accuracy: 4.0510
#
# Epoch 00121: val_loss did not improve from 0.08984
# Epoch 122/2000
#  - 1s - loss: 0.6510 - accuracy: 0.6187 - val_loss: 0.0963 - val_accuracy: 4.0393
#
# Epoch 00122: val_loss did not improve from 0.08984
# Epoch 123/2000
#  - 1s - loss: 0.6510 - accuracy: 0.6190 - val_loss: 0.0963 - val_accuracy: 4.0451
#
# Epoch 00123: val_loss did not improve from 0.08984
# Epoch 124/2000
#  - 1s - loss: 0.6505 - accuracy: 0.6203 - val_loss: 0.0964 - val_accuracy: 4.0412
#
# Epoch 00124: val_loss did not improve from 0.08984
# Epoch 125/2000
#  - 1s - loss: 0.6499 - accuracy: 0.6206 - val_loss: 0.0963 - val_accuracy: 4.0451
#
# Epoch 00125: val_loss did not improve from 0.08984
# Epoch 126/2000
#  - 1s - loss: 0.6491 - accuracy: 0.6207 - val_loss: 0.0963 - val_accuracy: 4.0588
#
# Epoch 00126: val_loss did not improve from 0.08984
# Epoch 127/2000
#  - 1s - loss: 0.6498 - accuracy: 0.6219 - val_loss: 0.0965 - val_accuracy: 4.0217
#
# Epoch 00127: val_loss did not improve from 0.08984
# Epoch 128/2000
#  - 1s - loss: 0.6482 - accuracy: 0.6233 - val_loss: 0.0964 - val_accuracy: 4.0412
#
# Epoch 00128: val_loss did not improve from 0.08984
# Epoch 129/2000
#  - 1s - loss: 0.6487 - accuracy: 0.6226 - val_loss: 0.0964 - val_accuracy: 4.0412
#
# Epoch 00129: val_loss did not improve from 0.08984
# Epoch 130/2000
#  - 1s - loss: 0.6477 - accuracy: 0.6252 - val_loss: 0.0965 - val_accuracy: 4.0217
#
# Epoch 00130: val_loss did not improve from 0.08984
# Epoch 131/2000
#  - 1s - loss: 0.6471 - accuracy: 0.6248 - val_loss: 0.0967 - val_accuracy: 4.0100
#
# Epoch 00131: val_loss did not improve from 0.08984
# Epoch 132/2000
#  - 1s - loss: 0.6467 - accuracy: 0.6252 - val_loss: 0.0966 - val_accuracy: 4.0198
#
# Epoch 00132: val_loss did not improve from 0.08984
# Epoch 133/2000
#  - 1s - loss: 0.6461 - accuracy: 0.6268 - val_loss: 0.0965 - val_accuracy: 4.0295
#
# Epoch 00133: val_loss did not improve from 0.08984
# Epoch 134/2000
#  - 1s - loss: 0.6456 - accuracy: 0.6282 - val_loss: 0.0963 - val_accuracy: 4.0802
#
# Epoch 00134: val_loss did not improve from 0.08984
# Epoch 135/2000
#  - 1s - loss: 0.6451 - accuracy: 0.6279 - val_loss: 0.0964 - val_accuracy: 4.0510
#
# Epoch 00135: val_loss did not improve from 0.08984
# Epoch 136/2000
#  - 1s - loss: 0.6451 - accuracy: 0.6275 - val_loss: 0.0964 - val_accuracy: 4.0432
#
# Epoch 00136: val_loss did not improve from 0.08984
# Epoch 137/2000
#  - 1s - loss: 0.6440 - accuracy: 0.6289 - val_loss: 0.0964 - val_accuracy: 4.0568
#
# Epoch 00137: val_loss did not improve from 0.08984
# Epoch 138/2000
#  - 1s - loss: 0.6437 - accuracy: 0.6300 - val_loss: 0.0964 - val_accuracy: 4.0451
#
# Epoch 00138: val_loss did not improve from 0.08984
# Epoch 139/2000
#  - 1s - loss: 0.6431 - accuracy: 0.6308 - val_loss: 0.0961 - val_accuracy: 4.1017
#
# Epoch 00139: val_loss did not improve from 0.08984
# Epoch 140/2000
#  - 1s - loss: 0.6431 - accuracy: 0.6306 - val_loss: 0.0963 - val_accuracy: 4.0802
#
# Epoch 00140: val_loss did not improve from 0.08984
# Epoch 141/2000
#  - 1s - loss: 0.6422 - accuracy: 0.6311 - val_loss: 0.0965 - val_accuracy: 4.0529
#
# Epoch 00141: val_loss did not improve from 0.08984
# Epoch 142/2000
#  - 1s - loss: 0.6420 - accuracy: 0.6326 - val_loss: 0.0963 - val_accuracy: 4.0646
#
# Epoch 00142: val_loss did not improve from 0.08984
# Epoch 143/2000
#  - 1s - loss: 0.6411 - accuracy: 0.6325 - val_loss: 0.0964 - val_accuracy: 4.0607
#
# Epoch 00143: val_loss did not improve from 0.08984
# Epoch 144/2000
#  - 1s - loss: 0.6409 - accuracy: 0.6319 - val_loss: 0.0965 - val_accuracy: 4.0685
#
# Epoch 00144: val_loss did not improve from 0.08984
# Epoch 145/2000
#  - 1s - loss: 0.6403 - accuracy: 0.6343 - val_loss: 0.0967 - val_accuracy: 4.0315
#
# Epoch 00145: val_loss did not improve from 0.08984
# Epoch 146/2000
#  - 1s - loss: 0.6396 - accuracy: 0.6354 - val_loss: 0.0965 - val_accuracy: 4.0666
#
# Epoch 00146: val_loss did not improve from 0.08984
# Epoch 147/2000
#  - 1s - loss: 0.6387 - accuracy: 0.6355 - val_loss: 0.0965 - val_accuracy: 4.0607
#
# Epoch 00147: val_loss did not improve from 0.08984
# Epoch 148/2000
#  - 1s - loss: 0.6381 - accuracy: 0.6380 - val_loss: 0.0965 - val_accuracy: 4.0588
#
# Epoch 00148: val_loss did not improve from 0.08984
# Epoch 149/2000
#  - 1s - loss: 0.6377 - accuracy: 0.6374 - val_loss: 0.0966 - val_accuracy: 4.0666
#
# Epoch 00149: val_loss did not improve from 0.08984
# Epoch 150/2000
#  - 1s - loss: 0.6376 - accuracy: 0.6376 - val_loss: 0.0968 - val_accuracy: 4.0549
#
# Epoch 00150: val_loss did not improve from 0.08984
# Epoch 151/2000
#  - 1s - loss: 0.6362 - accuracy: 0.6398 - val_loss: 0.0965 - val_accuracy: 4.0763
#
# Epoch 00151: val_loss did not improve from 0.08984
# Epoch 152/2000
#  - 1s - loss: 0.6363 - accuracy: 0.6390 - val_loss: 0.0962 - val_accuracy: 4.1095
#
# Epoch 00152: val_loss did not improve from 0.08984
# Epoch 153/2000
#  - 1s - loss: 0.6348 - accuracy: 0.6405 - val_loss: 0.0963 - val_accuracy: 4.0900
#
# Epoch 00153: val_loss did not improve from 0.08984
# Epoch 154/2000
#  - 1s - loss: 0.6346 - accuracy: 0.6413 - val_loss: 0.0963 - val_accuracy: 4.0958
#
# Epoch 00154: val_loss did not improve from 0.08984
# Epoch 155/2000
#  - 1s - loss: 0.6344 - accuracy: 0.6416 - val_loss: 0.0963 - val_accuracy: 4.0997
#
# Epoch 00155: val_loss did not improve from 0.08984
# Epoch 156/2000
#  - 1s - loss: 0.6335 - accuracy: 0.6423 - val_loss: 0.0963 - val_accuracy: 4.1095
#
# Epoch 00156: val_loss did not improve from 0.08984
# Epoch 157/2000
#  - 1s - loss: 0.6328 - accuracy: 0.6450 - val_loss: 0.0962 - val_accuracy: 4.1115
#
# Epoch 00157: val_loss did not improve from 0.08984
# Epoch 158/2000
#  - 1s - loss: 0.6322 - accuracy: 0.6439 - val_loss: 0.0963 - val_accuracy: 4.1173
#
# Epoch 00158: val_loss did not improve from 0.08984
# Epoch 159/2000
#  - 1s - loss: 0.6320 - accuracy: 0.6454 - val_loss: 0.0966 - val_accuracy: 4.0958
#
# Epoch 00159: val_loss did not improve from 0.08984
# Epoch 160/2000
#  - 1s - loss: 0.6310 - accuracy: 0.6462 - val_loss: 0.0966 - val_accuracy: 4.0939
#
# Epoch 00160: val_loss did not improve from 0.08984
# Epoch 161/2000
#  - 1s - loss: 0.6301 - accuracy: 0.6465 - val_loss: 0.0966 - val_accuracy: 4.1134
#
# Epoch 00161: val_loss did not improve from 0.08984
# Epoch 162/2000
#  - 1s - loss: 0.6302 - accuracy: 0.6463 - val_loss: 0.0967 - val_accuracy: 4.0939
#
# Epoch 00162: val_loss did not improve from 0.08984
# Epoch 163/2000
#  - 1s - loss: 0.6290 - accuracy: 0.6487 - val_loss: 0.0967 - val_accuracy: 4.1056
#
# Epoch 00163: val_loss did not improve from 0.08984
# Epoch 164/2000
#  - 1s - loss: 0.6280 - accuracy: 0.6496 - val_loss: 0.0967 - val_accuracy: 4.0978
#
# Epoch 00164: val_loss did not improve from 0.08984
# Epoch 165/2000
#  - 1s - loss: 0.6280 - accuracy: 0.6490 - val_loss: 0.0966 - val_accuracy: 4.1115
#
# Epoch 00165: val_loss did not improve from 0.08984
# Epoch 166/2000
#  - 1s - loss: 0.6273 - accuracy: 0.6496 - val_loss: 0.0966 - val_accuracy: 4.1076
#
# Epoch 00166: val_loss did not improve from 0.08984
# Epoch 167/2000
#  - 1s - loss: 0.6268 - accuracy: 0.6496 - val_loss: 0.0966 - val_accuracy: 4.1056
#
# Epoch 00167: val_loss did not improve from 0.08984
# Epoch 168/2000
#  - 1s - loss: 0.6261 - accuracy: 0.6508 - val_loss: 0.0966 - val_accuracy: 4.1134
#
# Epoch 00168: val_loss did not improve from 0.08984
# Epoch 169/2000
#  - 1s - loss: 0.6254 - accuracy: 0.6518 - val_loss: 0.0968 - val_accuracy: 4.0919
#
# Epoch 00169: val_loss did not improve from 0.08984
# Epoch 170/2000
#  - 1s - loss: 0.6249 - accuracy: 0.6523 - val_loss: 0.0968 - val_accuracy: 4.0939
#
# Epoch 00170: val_loss did not improve from 0.08984
# Epoch 171/2000
#  - 1s - loss: 0.6241 - accuracy: 0.6540 - val_loss: 0.0968 - val_accuracy: 4.0900
#
# Epoch 00171: val_loss did not improve from 0.08984
# Epoch 172/2000
#  - 1s - loss: 0.6235 - accuracy: 0.6543 - val_loss: 0.0964 - val_accuracy: 4.1271
#
# Epoch 00172: val_loss did not improve from 0.08984
# Epoch 173/2000
#  - 1s - loss: 0.6229 - accuracy: 0.6550 - val_loss: 0.0966 - val_accuracy: 4.1193
#
# Epoch 00173: val_loss did not improve from 0.08984
# Epoch 174/2000
#  - 1s - loss: 0.6221 - accuracy: 0.6554 - val_loss: 0.0962 - val_accuracy: 4.1485
#
# Epoch 00174: val_loss did not improve from 0.08984
# Epoch 175/2000
#  - 1s - loss: 0.6210 - accuracy: 0.6566 - val_loss: 0.0968 - val_accuracy: 4.1076
#
# Epoch 00175: val_loss did not improve from 0.08984
# Epoch 176/2000
#  - 1s - loss: 0.6201 - accuracy: 0.6576 - val_loss: 0.0968 - val_accuracy: 4.1017
#
# Epoch 00176: val_loss did not improve from 0.08984
# Epoch 177/2000
#  - 1s - loss: 0.6206 - accuracy: 0.6576 - val_loss: 0.0969 - val_accuracy: 4.0900
#
# Epoch 00177: val_loss did not improve from 0.08984
# Epoch 178/2000
#  - 1s - loss: 0.6192 - accuracy: 0.6594 - val_loss: 0.0969 - val_accuracy: 4.0939
#
# Epoch 00178: val_loss did not improve from 0.08984
# Epoch 179/2000
#  - 1s - loss: 0.6185 - accuracy: 0.6612 - val_loss: 0.0967 - val_accuracy: 4.1251
#
# Epoch 00179: val_loss did not improve from 0.08984
# Epoch 180/2000
#  - 1s - loss: 0.6178 - accuracy: 0.6610 - val_loss: 0.0966 - val_accuracy: 4.1173
#
# Epoch 00180: val_loss did not improve from 0.08984
# Epoch 181/2000
#  - 1s - loss: 0.6171 - accuracy: 0.6616 - val_loss: 0.0969 - val_accuracy: 4.0939
#
# Epoch 00181: val_loss did not improve from 0.08984
# Epoch 182/2000
#  - 1s - loss: 0.6162 - accuracy: 0.6615 - val_loss: 0.0966 - val_accuracy: 4.1271
#
# Epoch 00182: val_loss did not improve from 0.08984
# Epoch 183/2000
#  - 1s - loss: 0.6158 - accuracy: 0.6618 - val_loss: 0.0966 - val_accuracy: 4.1368
#
# Epoch 00183: val_loss did not improve from 0.08984
# Epoch 184/2000
#  - 1s - loss: 0.6154 - accuracy: 0.6629 - val_loss: 0.0966 - val_accuracy: 4.1290
#
# Epoch 00184: val_loss did not improve from 0.08984
# Epoch 185/2000
#  - 1s - loss: 0.6146 - accuracy: 0.6631 - val_loss: 0.0963 - val_accuracy: 4.1446
#
# Epoch 00185: val_loss did not improve from 0.08984
# Epoch 186/2000
#  - 1s - loss: 0.6132 - accuracy: 0.6631 - val_loss: 0.0966 - val_accuracy: 4.1388
#
# Epoch 00186: val_loss did not improve from 0.08984
# Epoch 187/2000
#  - 1s - loss: 0.6124 - accuracy: 0.6668 - val_loss: 0.0965 - val_accuracy: 4.1446
#
# Epoch 00187: val_loss did not improve from 0.08984
# Epoch 188/2000
#  - 1s - loss: 0.6120 - accuracy: 0.6661 - val_loss: 0.0965 - val_accuracy: 4.1485
#
# Epoch 00188: val_loss did not improve from 0.08984
# Epoch 189/2000
#  - 1s - loss: 0.6109 - accuracy: 0.6676 - val_loss: 0.0965 - val_accuracy: 4.1524
#
# Epoch 00189: val_loss did not improve from 0.08984
# Epoch 190/2000
#  - 1s - loss: 0.6106 - accuracy: 0.6683 - val_loss: 0.0963 - val_accuracy: 4.1661
#
# Epoch 00190: val_loss did not improve from 0.08984
# Epoch 191/2000
#  - 1s - loss: 0.6085 - accuracy: 0.6708 - val_loss: 0.0962 - val_accuracy: 4.1661
#
# Epoch 00191: val_loss did not improve from 0.08984
# Epoch 192/2000
#  - 1s - loss: 0.6090 - accuracy: 0.6694 - val_loss: 0.0963 - val_accuracy: 4.1680
#
# Epoch 00192: val_loss did not improve from 0.08984
# Epoch 193/2000
#  - 1s - loss: 0.6083 - accuracy: 0.6707 - val_loss: 0.0966 - val_accuracy: 4.1583
#
# Epoch 00193: val_loss did not improve from 0.08984
# Epoch 194/2000
#  - 1s - loss: 0.6078 - accuracy: 0.6706 - val_loss: 0.0965 - val_accuracy: 4.1758
#
# Epoch 00194: val_loss did not improve from 0.08984
# Epoch 195/2000
#  - 1s - loss: 0.6056 - accuracy: 0.6733 - val_loss: 0.0968 - val_accuracy: 4.1505
#
# Epoch 00195: val_loss did not improve from 0.08984
# Epoch 196/2000
#  - 1s - loss: 0.6057 - accuracy: 0.6724 - val_loss: 0.0965 - val_accuracy: 4.1680
#
# Epoch 00196: val_loss did not improve from 0.08984
# Epoch 197/2000
#  - 1s - loss: 0.6045 - accuracy: 0.6744 - val_loss: 0.0968 - val_accuracy: 4.1407
#
# Epoch 00197: val_loss did not improve from 0.08984
# Epoch 198/2000
#  - 1s - loss: 0.6040 - accuracy: 0.6751 - val_loss: 0.0968 - val_accuracy: 4.1680
#
# Epoch 00198: val_loss did not improve from 0.08984
# Epoch 199/2000
#  - 1s - loss: 0.6034 - accuracy: 0.6757 - val_loss: 0.0965 - val_accuracy: 4.1778
#
# Epoch 00199: val_loss did not improve from 0.08984
# Epoch 200/2000
#  - 1s - loss: 0.6021 - accuracy: 0.6766 - val_loss: 0.0965 - val_accuracy: 4.1739
#
# Epoch 00200: val_loss did not improve from 0.08984
# Epoch 201/2000
#  - 1s - loss: 0.6019 - accuracy: 0.6765 - val_loss: 0.0968 - val_accuracy: 4.1700
#
# Epoch 00201: val_loss did not improve from 0.08984
# Epoch 202/2000
#  - 1s - loss: 0.6009 - accuracy: 0.6772 - val_loss: 0.0967 - val_accuracy: 4.1602
#
# Epoch 00202: val_loss did not improve from 0.08984
# Epoch 203/2000
#  - 1s - loss: 0.6002 - accuracy: 0.6781 - val_loss: 0.0968 - val_accuracy: 4.1544
#
# Epoch 00203: val_loss did not improve from 0.08984
# Epoch 204/2000
#  - 1s - loss: 0.5993 - accuracy: 0.6786 - val_loss: 0.0968 - val_accuracy: 4.1583
#
# Epoch 00204: val_loss did not improve from 0.08984
# Epoch 205/2000
#  - 1s - loss: 0.5983 - accuracy: 0.6798 - val_loss: 0.0968 - val_accuracy: 4.1641
#
# Epoch 00205: val_loss did not improve from 0.08984
# Epoch 206/2000
#  - 1s - loss: 0.5977 - accuracy: 0.6811 - val_loss: 0.0967 - val_accuracy: 4.1583
#
# Epoch 00206: val_loss did not improve from 0.08984
# Epoch 207/2000
#  - 1s - loss: 0.5970 - accuracy: 0.6815 - val_loss: 0.0969 - val_accuracy: 4.1641
#
# Epoch 00207: val_loss did not improve from 0.08984
# Epoch 208/2000
#  - 1s - loss: 0.5960 - accuracy: 0.6818 - val_loss: 0.0964 - val_accuracy: 4.1953
#
# Epoch 00208: val_loss did not improve from 0.08984
# Epoch 209/2000
#  - 1s - loss: 0.5953 - accuracy: 0.6834 - val_loss: 0.0967 - val_accuracy: 4.1641
#
# Epoch 00209: val_loss did not improve from 0.08984
# Epoch 210/2000
#  - 1s - loss: 0.5942 - accuracy: 0.6843 - val_loss: 0.0970 - val_accuracy: 4.1544
#
# Epoch 00210: val_loss did not improve from 0.08984
# Epoch 211/2000
#  - 1s - loss: 0.5934 - accuracy: 0.6845 - val_loss: 0.0973 - val_accuracy: 4.1290
#
# Epoch 00211: val_loss did not improve from 0.08984
# Epoch 212/2000
#  - 1s - loss: 0.5924 - accuracy: 0.6850 - val_loss: 0.0969 - val_accuracy: 4.1700
#
# Epoch 00212: val_loss did not improve from 0.08984
# Epoch 213/2000
#  - 1s - loss: 0.5920 - accuracy: 0.6847 - val_loss: 0.0973 - val_accuracy: 4.1329
#
# Epoch 00213: val_loss did not improve from 0.08984
# Epoch 214/2000
#  - 1s - loss: 0.5915 - accuracy: 0.6860 - val_loss: 0.0975 - val_accuracy: 4.1388
#
# Epoch 00214: val_loss did not improve from 0.08984
# Epoch 215/2000
#  - 1s - loss: 0.5903 - accuracy: 0.6863 - val_loss: 0.0970 - val_accuracy: 4.1680
#
# Epoch 00215: val_loss did not improve from 0.08984
# Epoch 216/2000
#  - 1s - loss: 0.5894 - accuracy: 0.6885 - val_loss: 0.0971 - val_accuracy: 4.1758
#
# Epoch 00216: val_loss did not improve from 0.08984
# Epoch 217/2000
#  - 1s - loss: 0.5885 - accuracy: 0.6886 - val_loss: 0.0972 - val_accuracy: 4.1427
#
# Epoch 00217: val_loss did not improve from 0.08984
# Epoch 218/2000
#  - 1s - loss: 0.5880 - accuracy: 0.6889 - val_loss: 0.0973 - val_accuracy: 4.1680
#
# Epoch 00218: val_loss did not improve from 0.08984
# Epoch 219/2000
#  - 1s - loss: 0.5871 - accuracy: 0.6896 - val_loss: 0.0975 - val_accuracy: 4.1524
#
# Epoch 00219: val_loss did not improve from 0.08984
# Epoch 220/2000
#  - 1s - loss: 0.5861 - accuracy: 0.6911 - val_loss: 0.0974 - val_accuracy: 4.1758
#
# Epoch 00220: val_loss did not improve from 0.08984
# Epoch 221/2000
#  - 1s - loss: 0.5853 - accuracy: 0.6915 - val_loss: 0.0977 - val_accuracy: 4.1680
#
# Epoch 00221: val_loss did not improve from 0.08984
# Epoch 222/2000
#  - 1s - loss: 0.5849 - accuracy: 0.6915 - val_loss: 0.0980 - val_accuracy: 4.1407
#
# Epoch 00222: val_loss did not improve from 0.08984
# Epoch 223/2000
#  - 1s - loss: 0.5838 - accuracy: 0.6926 - val_loss: 0.0979 - val_accuracy: 4.1563
#
# Epoch 00223: val_loss did not improve from 0.08984
# Epoch 224/2000
#  - 1s - loss: 0.5828 - accuracy: 0.6945 - val_loss: 0.0980 - val_accuracy: 4.1407
#
# Epoch 00224: val_loss did not improve from 0.08984
# Epoch 225/2000
#  - 1s - loss: 0.5820 - accuracy: 0.6948 - val_loss: 0.0982 - val_accuracy: 4.1368
#
# Epoch 00225: val_loss did not improve from 0.08984
# Epoch 226/2000
#  - 1s - loss: 0.5810 - accuracy: 0.6954 - val_loss: 0.0979 - val_accuracy: 4.1719
#
# Epoch 00226: val_loss did not improve from 0.08984
# Epoch 227/2000
#  - 1s - loss: 0.5810 - accuracy: 0.6945 - val_loss: 0.0979 - val_accuracy: 4.1544
#
# Epoch 00227: val_loss did not improve from 0.08984
# Epoch 228/2000
#  - 1s - loss: 0.5793 - accuracy: 0.6967 - val_loss: 0.0980 - val_accuracy: 4.1641
#
# Epoch 00228: val_loss did not improve from 0.08984
# Epoch 229/2000
#  - 1s - loss: 0.5787 - accuracy: 0.6970 - val_loss: 0.0982 - val_accuracy: 4.1446
#
# Epoch 00229: val_loss did not improve from 0.08984
# Epoch 230/2000
#  - 1s - loss: 0.5777 - accuracy: 0.6973 - val_loss: 0.0982 - val_accuracy: 4.1544
#
# Epoch 00230: val_loss did not improve from 0.08984
# Epoch 231/2000
#  - 1s - loss: 0.5763 - accuracy: 0.6984 - val_loss: 0.0980 - val_accuracy: 4.1602
#
# Epoch 00231: val_loss did not improve from 0.08984
# Epoch 232/2000
#  - 1s - loss: 0.5756 - accuracy: 0.6994 - val_loss: 0.0987 - val_accuracy: 4.1193
#
# Epoch 00232: val_loss did not improve from 0.08984
# Epoch 233/2000
#  - 1s - loss: 0.5749 - accuracy: 0.7006 - val_loss: 0.0991 - val_accuracy: 4.0900
#
# Epoch 00233: val_loss did not improve from 0.08984
# Epoch 234/2000
#  - 1s - loss: 0.5741 - accuracy: 0.6999 - val_loss: 0.0987 - val_accuracy: 4.1056
#
# Epoch 00234: val_loss did not improve from 0.08984
# Epoch 235/2000
#  - 1s - loss: 0.5731 - accuracy: 0.7018 - val_loss: 0.0991 - val_accuracy: 4.0958
#
# Epoch 00235: val_loss did not improve from 0.08984
# Epoch 236/2000
#  - 1s - loss: 0.5723 - accuracy: 0.7022 - val_loss: 0.0990 - val_accuracy: 4.1056
#
# Epoch 00236: val_loss did not improve from 0.08984
# Epoch 237/2000
#  - 1s - loss: 0.5723 - accuracy: 0.7028 - val_loss: 0.0990 - val_accuracy: 4.1173
#
# Epoch 00237: val_loss did not improve from 0.08984
# Epoch 238/2000
#  - 1s - loss: 0.5709 - accuracy: 0.7029 - val_loss: 0.0992 - val_accuracy: 4.0685
#
# Epoch 00238: val_loss did not improve from 0.08984
# Epoch 239/2000
#  - 1s - loss: 0.5696 - accuracy: 0.7042 - val_loss: 0.0992 - val_accuracy: 4.0978
#
# Epoch 00239: val_loss did not improve from 0.08984
# Epoch 240/2000
#  - 1s - loss: 0.5689 - accuracy: 0.7044 - val_loss: 0.0993 - val_accuracy: 4.0724
#
# Epoch 00240: val_loss did not improve from 0.08984
# Epoch 241/2000
#  - 1s - loss: 0.5685 - accuracy: 0.7051 - val_loss: 0.0991 - val_accuracy: 4.0978
#
# Epoch 00241: val_loss did not improve from 0.08984
# Epoch 242/2000
#  - 1s - loss: 0.5672 - accuracy: 0.7065 - val_loss: 0.0996 - val_accuracy: 4.0646
#
# Epoch 00242: val_loss did not improve from 0.08984
# Epoch 243/2000
#  - 1s - loss: 0.5664 - accuracy: 0.7066 - val_loss: 0.0995 - val_accuracy: 4.0939
#
# Epoch 00243: val_loss did not improve from 0.08984
# Epoch 244/2000
#  - 1s - loss: 0.5656 - accuracy: 0.7075 - val_loss: 0.0996 - val_accuracy: 4.0822
#
# Epoch 00244: val_loss did not improve from 0.08984
# Epoch 245/2000
#  - 1s - loss: 0.5646 - accuracy: 0.7081 - val_loss: 0.0998 - val_accuracy: 4.0744
#
# Epoch 00245: val_loss did not improve from 0.08984
# Epoch 246/2000
#  - 1s - loss: 0.5643 - accuracy: 0.7089 - val_loss: 0.0996 - val_accuracy: 4.0900
#
# Epoch 00246: val_loss did not improve from 0.08984
# Epoch 247/2000
#  - 1s - loss: 0.5629 - accuracy: 0.7102 - val_loss: 0.0997 - val_accuracy: 4.0841
#
# Epoch 00247: val_loss did not improve from 0.08984
# Epoch 248/2000
#  - 1s - loss: 0.5620 - accuracy: 0.7107 - val_loss: 0.1000 - val_accuracy: 4.0744
#
# Epoch 00248: val_loss did not improve from 0.08984
# Epoch 249/2000
#  - 1s - loss: 0.5619 - accuracy: 0.7107 - val_loss: 0.1002 - val_accuracy: 4.0549
#
# Epoch 00249: val_loss did not improve from 0.08984
# Epoch 250/2000
#  - 1s - loss: 0.5602 - accuracy: 0.7111 - val_loss: 0.1001 - val_accuracy: 4.0529
#
# Epoch 00250: val_loss did not improve from 0.08984
# Epoch 251/2000
#  - 1s - loss: 0.5594 - accuracy: 0.7127 - val_loss: 0.1002 - val_accuracy: 4.0588
#
# Epoch 00251: val_loss did not improve from 0.08984
# Epoch 252/2000
#  - 1s - loss: 0.5591 - accuracy: 0.7115 - val_loss: 0.1000 - val_accuracy: 4.0705
#
# Epoch 00252: val_loss did not improve from 0.08984
# Epoch 253/2000
#  - 1s - loss: 0.5574 - accuracy: 0.7144 - val_loss: 0.1003 - val_accuracy: 4.0724
#
# Epoch 00253: val_loss did not improve from 0.08984
# Epoch 254/2000
#  - 1s - loss: 0.5562 - accuracy: 0.7151 - val_loss: 0.0999 - val_accuracy: 4.0958
#
# Epoch 00254: val_loss did not improve from 0.08984
# Epoch 255/2000
#  - 1s - loss: 0.5552 - accuracy: 0.7155 - val_loss: 0.1005 - val_accuracy: 4.0685
#
# Epoch 00255: val_loss did not improve from 0.08984
# Epoch 256/2000
#  - 1s - loss: 0.5547 - accuracy: 0.7156 - val_loss: 0.1005 - val_accuracy: 4.0822
#
# Epoch 00256: val_loss did not improve from 0.08984
# Epoch 257/2000
#  - 1s - loss: 0.5541 - accuracy: 0.7162 - val_loss: 0.1003 - val_accuracy: 4.0841
#
# Epoch 00257: val_loss did not improve from 0.08984
# Epoch 258/2000
#  - 1s - loss: 0.5529 - accuracy: 0.7177 - val_loss: 0.1004 - val_accuracy: 4.0783
#
# Epoch 00258: val_loss did not improve from 0.08984
# Epoch 259/2000
#  - 1s - loss: 0.5516 - accuracy: 0.7182 - val_loss: 0.1004 - val_accuracy: 4.0841
#
# Epoch 00259: val_loss did not improve from 0.08984
# Epoch 260/2000
#  - 1s - loss: 0.5513 - accuracy: 0.7185 - val_loss: 0.1007 - val_accuracy: 4.0724
#
# Epoch 00260: val_loss did not improve from 0.08984
# Epoch 261/2000
#  - 1s - loss: 0.5502 - accuracy: 0.7194 - val_loss: 0.1005 - val_accuracy: 4.0685
#
# Epoch 00261: val_loss did not improve from 0.08984
# Epoch 262/2000
#  - 1s - loss: 0.5493 - accuracy: 0.7196 - val_loss: 0.1002 - val_accuracy: 4.1154
#
# Epoch 00262: val_loss did not improve from 0.08984
# Epoch 263/2000
#  - 1s - loss: 0.5486 - accuracy: 0.7207 - val_loss: 0.1000 - val_accuracy: 4.1095
#
# Epoch 00263: val_loss did not improve from 0.08984
# Epoch 264/2000
#  - 1s - loss: 0.5473 - accuracy: 0.7211 - val_loss: 0.1005 - val_accuracy: 4.0900
#
# Epoch 00264: val_loss did not improve from 0.08984
# Epoch 265/2000
#  - 1s - loss: 0.5468 - accuracy: 0.7215 - val_loss: 0.1008 - val_accuracy: 4.0744
#
# Epoch 00265: val_loss did not improve from 0.08984
# Epoch 266/2000
#  - 1s - loss: 0.5454 - accuracy: 0.7220 - val_loss: 0.1008 - val_accuracy: 4.0822
#
# Epoch 00266: val_loss did not improve from 0.08984
# Epoch 267/2000
#  - 1s - loss: 0.5451 - accuracy: 0.7227 - val_loss: 0.1007 - val_accuracy: 4.0841
#
# Epoch 00267: val_loss did not improve from 0.08984
# Epoch 268/2000
#  - 1s - loss: 0.5437 - accuracy: 0.7235 - val_loss: 0.1008 - val_accuracy: 4.0861
#
# Epoch 00268: val_loss did not improve from 0.08984
# Epoch 269/2000
#  - 1s - loss: 0.5430 - accuracy: 0.7249 - val_loss: 0.1007 - val_accuracy: 4.0861
#
# Epoch 00269: val_loss did not improve from 0.08984
# Epoch 270/2000
#  - 1s - loss: 0.5421 - accuracy: 0.7255 - val_loss: 0.1003 - val_accuracy: 4.1095
#
# Epoch 00270: val_loss did not improve from 0.08984
# Epoch 271/2000
#  - 1s - loss: 0.5409 - accuracy: 0.7259 - val_loss: 0.1005 - val_accuracy: 4.1076
#
# Epoch 00271: val_loss did not improve from 0.08984
# Epoch 272/2000
#  - 1s - loss: 0.5404 - accuracy: 0.7263 - val_loss: 0.1004 - val_accuracy: 4.1115
#
# Epoch 00272: val_loss did not improve from 0.08984
# Epoch 273/2000
#  - 1s - loss: 0.5393 - accuracy: 0.7259 - val_loss: 0.1011 - val_accuracy: 4.0919
#
# Epoch 00273: val_loss did not improve from 0.08984
# Epoch 274/2000
#  - 1s - loss: 0.5385 - accuracy: 0.7275 - val_loss: 0.1010 - val_accuracy: 4.0822
#
# Epoch 00274: val_loss did not improve from 0.08984
# Epoch 275/2000
#  - 1s - loss: 0.5377 - accuracy: 0.7286 - val_loss: 0.1014 - val_accuracy: 4.0763
#
# ...
# Epoch 441/2000
#  - 1s - loss: 0.3922 - accuracy: 0.8194 - val_loss: 0.1217 - val_accuracy: 4.1719
#
# Epoch 00441: val_loss did not improve from 0.08984
# Epoch 442/2000
#  - 1s - loss: 0.3912 - accuracy: 0.8200 - val_loss: 0.1222 - val_accuracy: 4.1797
#
# Epoch 00442: val_loss did not improve from 0.08984
# Epoch 443/2000
#  - 1s - loss: 0.3901 - accuracy: 0.8200 - val_loss: 0.1223 - val_accuracy: 4.1700
#
# Epoch 00443: val_loss did not improve from 0.08984
# Epoch 444/2000
#  - 1s - loss: 0.3895 - accuracy: 0.8210 - val_loss: 0.1224 - val_accuracy: 4.1797
#
# Epoch 00444: val_loss did not improve from 0.08984
# Epoch 445/2000
#  - 1s - loss: 0.3893 - accuracy: 0.8213 - val_loss: 0.1227 - val_accuracy: 4.1700
#
# Epoch 00445: val_loss did not improve from 0.08984
# Epoch 446/2000
#  - 1s - loss: 0.3877 - accuracy: 0.8207 - val_loss: 0.1228 - val_accuracy: 4.1758
#
# Epoch 00446: val_loss did not improve from 0.08984
# Epoch 447/2000
#  - 1s - loss: 0.3874 - accuracy: 0.8222 - val_loss: 0.1228 - val_accuracy: 4.1778
#
# Epoch 00447: val_loss did not improve from 0.08984
# Epoch 448/2000
#  - 1s - loss: 0.3869 - accuracy: 0.8217 - val_loss: 0.1228 - val_accuracy: 4.1661
#
# Epoch 00448: val_loss did not improve from 0.08984
# Epoch 449/2000
#  - 1s - loss: 0.3857 - accuracy: 0.8225 - val_loss: 0.1230 - val_accuracy: 4.1817
#
# Epoch 00449: val_loss did not improve from 0.08984
# Epoch 450/2000
#  - 1s - loss: 0.3852 - accuracy: 0.8233 - val_loss: 0.1234 - val_accuracy: 4.1758
#
# Epoch 00450: val_loss did not improve from 0.08984
# Epoch 451/2000
#  - 1s - loss: 0.3839 - accuracy: 0.8241 - val_loss: 0.1234 - val_accuracy: 4.1817
#
# Epoch 00451: val_loss did not improve from 0.08984
# Epoch 452/2000
#  - 1s - loss: 0.3838 - accuracy: 0.8239 - val_loss: 0.1236 - val_accuracy: 4.1661
#
# Epoch 00452: val_loss did not improve from 0.08984
# Epoch 453/2000
#  - 1s - loss: 0.3829 - accuracy: 0.8242 - val_loss: 0.1244 - val_accuracy: 4.1661
#
# Epoch 00453: val_loss did not improve from 0.08984
# Epoch 454/2000
#  - 1s - loss: 0.3815 - accuracy: 0.8259 - val_loss: 0.1240 - val_accuracy: 4.1778
#
# Epoch 00454: val_loss did not improve from 0.08984
# Epoch 455/2000
#  - 1s - loss: 0.3820 - accuracy: 0.8250 - val_loss: 0.1241 - val_accuracy: 4.1856
#
# Epoch 00455: val_loss did not improve from 0.08984
# Epoch 456/2000
#  - 1s - loss: 0.3807 - accuracy: 0.8259 - val_loss: 0.1242 - val_accuracy: 4.1875
#
# Epoch 00456: val_loss did not improve from 0.08984
# Epoch 457/2000
#  - 1s - loss: 0.3800 - accuracy: 0.8263 - val_loss: 0.1241 - val_accuracy: 4.1817
#
# Epoch 00457: val_loss did not improve from 0.08984
# Epoch 458/2000
#  - 1s - loss: 0.3790 - accuracy: 0.8271 - val_loss: 0.1247 - val_accuracy: 4.1758
#
# Epoch 00458: val_loss did not improve from 0.08984
# Epoch 459/2000
#  - 1s - loss: 0.3782 - accuracy: 0.8265 - val_loss: 0.1251 - val_accuracy: 4.1700
#
# Epoch 00459: val_loss did not improve from 0.08984
# Epoch 460/2000
#  - 1s - loss: 0.3773 - accuracy: 0.8273 - val_loss: 0.1251 - val_accuracy: 4.1817
#
# Epoch 00460: val_loss did not improve from 0.08984
# Epoch 461/2000
#  - 1s - loss: 0.3766 - accuracy: 0.8284 - val_loss: 0.1252 - val_accuracy: 4.1836
#
# Epoch 00461: val_loss did not improve from 0.08984
# Epoch 462/2000
#  - 1s - loss: 0.3762 - accuracy: 0.8275 - val_loss: 0.1255 - val_accuracy: 4.1797
#
# Epoch 00462: val_loss did not improve from 0.08984
# Epoch 463/2000
#  - 1s - loss: 0.3745 - accuracy: 0.8294 - val_loss: 0.1254 - val_accuracy: 4.1739
#
# Epoch 00463: val_loss did not improve from 0.08984
# Epoch 464/2000
#  - 1s - loss: 0.3740 - accuracy: 0.8299 - val_loss: 0.1257 - val_accuracy: 4.1973
#
# Epoch 00464: val_loss did not improve from 0.08984
# Epoch 465/2000
#  - 1s - loss: 0.3737 - accuracy: 0.8298 - val_loss: 0.1258 - val_accuracy: 4.1719
#
# Epoch 00465: val_loss did not improve from 0.08984
# Epoch 466/2000
#  - 1s - loss: 0.3730 - accuracy: 0.8297 - val_loss: 0.1264 - val_accuracy: 4.1622
#
# Epoch 00466: val_loss did not improve from 0.08984
# Epoch 467/2000
#  - 1s - loss: 0.3725 - accuracy: 0.8301 - val_loss: 0.1264 - val_accuracy: 4.1739
#
# Epoch 00467: val_loss did not improve from 0.08984
# Epoch 468/2000
#  - 1s - loss: 0.3716 - accuracy: 0.8305 - val_loss: 0.1267 - val_accuracy: 4.1680
#
# Epoch 00468: val_loss did not improve from 0.08984
# Epoch 469/2000
#  - 1s - loss: 0.3707 - accuracy: 0.8309 - val_loss: 0.1264 - val_accuracy: 4.1836
#
# Epoch 00469: val_loss did not improve from 0.08984
# Epoch 470/2000
#  - 1s - loss: 0.3708 - accuracy: 0.8312 - val_loss: 0.1269 - val_accuracy: 4.1836
#
# Epoch 00470: val_loss did not improve from 0.08984
# Epoch 471/2000
#  - 1s - loss: 0.3697 - accuracy: 0.8320 - val_loss: 0.1274 - val_accuracy: 4.1524
#
# Epoch 00471: val_loss did not improve from 0.08984
# Epoch 472/2000
#  - 1s - loss: 0.3692 - accuracy: 0.8319 - val_loss: 0.1273 - val_accuracy: 4.1485
#
# Epoch 00472: val_loss did not improve from 0.08984
# Epoch 473/2000
#  - 1s - loss: 0.3684 - accuracy: 0.8326 - val_loss: 0.1272 - val_accuracy: 4.1719
#
# Epoch 00473: val_loss did not improve from 0.08984
# Epoch 474/2000
#  - 1s - loss: 0.3673 - accuracy: 0.8330 - val_loss: 0.1277 - val_accuracy: 4.1680
#
# Epoch 00474: val_loss did not improve from 0.08984
# Epoch 475/2000
#  - 1s - loss: 0.3666 - accuracy: 0.8335 - val_loss: 0.1276 - val_accuracy: 4.1856
#
# Epoch 00475: val_loss did not improve from 0.08984
# Epoch 476/2000
#  - 1s - loss: 0.3663 - accuracy: 0.8330 - val_loss: 0.1281 - val_accuracy: 4.1583
#
# Epoch 00476: val_loss did not improve from 0.08984
# Epoch 477/2000
#  - 1s - loss: 0.3660 - accuracy: 0.8333 - val_loss: 0.1279 - val_accuracy: 4.1758
#
# Epoch 00477: val_loss did not improve from 0.08984
# Epoch 478/2000
#  - 1s - loss: 0.3640 - accuracy: 0.8349 - val_loss: 0.1284 - val_accuracy: 4.1758
#
# Epoch 00478: val_loss did not improve from 0.08984
# Epoch 479/2000
#  - 1s - loss: 0.3644 - accuracy: 0.8342 - val_loss: 0.1288 - val_accuracy: 4.1602
#
# Epoch 00479: val_loss did not improve from 0.08984
# Epoch 480/2000
#  - 1s - loss: 0.3634 - accuracy: 0.8348 - val_loss: 0.1291 - val_accuracy: 4.1524
#
# Epoch 00480: val_loss did not improve from 0.08984
# Epoch 481/2000
#  - 1s - loss: 0.3625 - accuracy: 0.8361 - val_loss: 0.1289 - val_accuracy: 4.1700
#
# Epoch 00481: val_loss did not improve from 0.08984
# Epoch 482/2000
#  - 1s - loss: 0.3622 - accuracy: 0.8362 - val_loss: 0.1289 - val_accuracy: 4.1856
#
# Epoch 00482: val_loss did not improve from 0.08984
# Epoch 483/2000
#  - 1s - loss: 0.3607 - accuracy: 0.8368 - val_loss: 0.1291 - val_accuracy: 4.1778
#
# Epoch 00483: val_loss did not improve from 0.08984
# Epoch 484/2000
#  - 1s - loss: 0.3604 - accuracy: 0.8368 - val_loss: 0.1295 - val_accuracy: 4.1583
#
# Epoch 00484: val_loss did not improve from 0.08984
# Epoch 485/2000
#  - 1s - loss: 0.3594 - accuracy: 0.8372 - val_loss: 0.1297 - val_accuracy: 4.1700
#
# Epoch 00485: val_loss did not improve from 0.08984
# Epoch 486/2000
#  - 1s - loss: 0.3591 - accuracy: 0.8378 - val_loss: 0.1299 - val_accuracy: 4.1563
#
# Epoch 00486: val_loss did not improve from 0.08984
# Epoch 487/2000
#  - 1s - loss: 0.3583 - accuracy: 0.8375 - val_loss: 0.1304 - val_accuracy: 4.1407
#
# Epoch 00487: val_loss did not improve from 0.08984
# Epoch 488/2000
#  - 1s - loss: 0.3577 - accuracy: 0.8385 - val_loss: 0.1299 - val_accuracy: 4.1719
#
# Epoch 00488: val_loss did not improve from 0.08984
# Epoch 489/2000
#  - 1s - loss: 0.3572 - accuracy: 0.8384 - val_loss: 0.1301 - val_accuracy: 4.1778
#
# Epoch 00489: val_loss did not improve from 0.08984
# Epoch 490/2000
#  - 1s - loss: 0.3561 - accuracy: 0.8393 - val_loss: 0.1303 - val_accuracy: 4.1719
#
# Epoch 00490: val_loss did not improve from 0.08984
# Epoch 491/2000
#  - 1s - loss: 0.3556 - accuracy: 0.8391 - val_loss: 0.1307 - val_accuracy: 4.1583
#
# Epoch 00491: val_loss did not improve from 0.08984
# Epoch 492/2000
#  - 1s - loss: 0.3545 - accuracy: 0.8402 - val_loss: 0.1310 - val_accuracy: 4.1388
#
# Epoch 00492: val_loss did not improve from 0.08984
# Epoch 493/2000
#  - 1s - loss: 0.3546 - accuracy: 0.8398 - val_loss: 0.1313 - val_accuracy: 4.1505
#
# Epoch 00493: val_loss did not improve from 0.08984
# Epoch 494/2000
#  - 1s - loss: 0.3533 - accuracy: 0.8413 - val_loss: 0.1308 - val_accuracy: 4.2012
#
# Epoch 00494: val_loss did not improve from 0.08984
# Epoch 495/2000
#  - 1s - loss: 0.3526 - accuracy: 0.8411 - val_loss: 0.1308 - val_accuracy: 4.2070
#
# Epoch 00495: val_loss did not improve from 0.08984
# Epoch 496/2000
#  - 1s - loss: 0.3520 - accuracy: 0.8411 - val_loss: 0.1318 - val_accuracy: 4.1563
#
# Epoch 00496: val_loss did not improve from 0.08984
# Epoch 497/2000
#  - 1s - loss: 0.3517 - accuracy: 0.8420 - val_loss: 0.1319 - val_accuracy: 4.1485
#
# Epoch 00497: val_loss did not improve from 0.08984
# Epoch 498/2000
#  - 1s - loss: 0.3514 - accuracy: 0.8427 - val_loss: 0.1317 - val_accuracy: 4.1778
#
# Epoch 00498: val_loss did not improve from 0.08984
# Epoch 499/2000
#  - 1s - loss: 0.3505 - accuracy: 0.8422 - val_loss: 0.1317 - val_accuracy: 4.1875
#
# Epoch 00499: val_loss did not improve from 0.08984
# Epoch 500/2000
#  - 1s - loss: 0.3490 - accuracy: 0.8441 - val_loss: 0.1321 - val_accuracy: 4.1836
#
# Epoch 00500: val_loss did not improve from 0.08984
# Epoch 501/2000
#  - 1s - loss: 0.3487 - accuracy: 0.8433 - val_loss: 0.1324 - val_accuracy: 4.1817
#
# Epoch 00501: val_loss did not improve from 0.08984
# Epoch 502/2000
#  - 1s - loss: 0.3482 - accuracy: 0.8438 - val_loss: 0.1325 - val_accuracy: 4.1758
#
# Epoch 00502: val_loss did not improve from 0.08984
# Epoch 503/2000
#  - 1s - loss: 0.3473 - accuracy: 0.8446 - val_loss: 0.1327 - val_accuracy: 4.1739
#
# Epoch 00503: val_loss did not improve from 0.08984
# Epoch 504/2000
#  - 1s - loss: 0.3464 - accuracy: 0.8451 - val_loss: 0.1327 - val_accuracy: 4.1856
#
# Epoch 00504: val_loss did not improve from 0.08984
# Epoch 505/2000
#  - 1s - loss: 0.3461 - accuracy: 0.8451 - val_loss: 0.1328 - val_accuracy: 4.1739
#
# Epoch 00505: val_loss did not improve from 0.08984
# Epoch 506/2000
#  - 1s - loss: 0.3460 - accuracy: 0.8451 - val_loss: 0.1332 - val_accuracy: 4.1700
#
# Epoch 00506: val_loss did not improve from 0.08984
# Epoch 507/2000
#  - 1s - loss: 0.3449 - accuracy: 0.8457 - val_loss: 0.1335 - val_accuracy: 4.1661
#
# Epoch 00507: val_loss did not improve from 0.08984
# Epoch 508/2000
#  - 1s - loss: 0.3442 - accuracy: 0.8461 - val_loss: 0.1335 - val_accuracy: 4.1739
#
# Epoch 00508: val_loss did not improve from 0.08984
# Epoch 509/2000
#  - 1s - loss: 0.3433 - accuracy: 0.8468 - val_loss: 0.1337 - val_accuracy: 4.1836
#
# Epoch 00509: val_loss did not improve from 0.08984
# Epoch 510/2000
#  - 1s - loss: 0.3429 - accuracy: 0.8467 - val_loss: 0.1335 - val_accuracy: 4.1661
#
# Epoch 00510: val_loss did not improve from 0.08984
# Epoch 511/2000
#  - 1s - loss: 0.3424 - accuracy: 0.8472 - val_loss: 0.1341 - val_accuracy: 4.1719
#
# Epoch 00511: val_loss did not improve from 0.08984
# Epoch 512/2000
#  - 1s - loss: 0.3413 - accuracy: 0.8478 - val_loss: 0.1342 - val_accuracy: 4.1817
#
# Epoch 00512: val_loss did not improve from 0.08984
# Epoch 513/2000
#  - 1s - loss: 0.3408 - accuracy: 0.8480 - val_loss: 0.1343 - val_accuracy: 4.1661
#
# Epoch 00513: val_loss did not improve from 0.08984
# Epoch 514/2000
#  - 1s - loss: 0.3405 - accuracy: 0.8481 - val_loss: 0.1346 - val_accuracy: 4.1700
#
# Epoch 00514: val_loss did not improve from 0.08984
# Epoch 515/2000
#  - 1s - loss: 0.3397 - accuracy: 0.8479 - val_loss: 0.1349 - val_accuracy: 4.1778
#
# Epoch 00515: val_loss did not improve from 0.08984
# Epoch 516/2000
#  - 1s - loss: 0.3389 - accuracy: 0.8488 - val_loss: 0.1352 - val_accuracy: 4.1661
#
# Epoch 00516: val_loss did not improve from 0.08984
# Epoch 517/2000
#  - 1s - loss: 0.3381 - accuracy: 0.8485 - val_loss: 0.1353 - val_accuracy: 4.1602
#
# Epoch 00517: val_loss did not improve from 0.08984
# Epoch 518/2000
#  - 1s - loss: 0.3376 - accuracy: 0.8490 - val_loss: 0.1356 - val_accuracy: 4.1641
#
# Epoch 00518: val_loss did not improve from 0.08984
# test_result.shape : (3589, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.4271463 ]
#  [0.43509835]
#  [0.41206366]
#  [0.39374387]
#  [0.3783748 ]]
# y_test.shape : (3589, 1)
# y_score.shape : (3589, 1)
# len(y_test) : 3589
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:660: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [0.00033061017, 0.00034282994, 0.0003462082, 0.00033637966, 0.00032900486, 0.0003312258, 0.00033304509, 0.0003357843, 0.00033405592, 0.0003367478, 0.0003855731, 0.00037781344, 0.00037810695, 0.0003800017, 0.00038653382, 0.00038827248, 0.0003880807, 0.00033670175, 0.0003250968, 0.00032979774, 0.00035299305, 0.00036301673, 0.00036005018, 0.0003624795, 0.00035724227, 0.00037128804, 0.00036823476, 0.00035715438, 0.00035830642, 0.00035306232, 0.00033896527, 0.00034772622, 0.00036240756, 0.00037183185, 0.00036503625, 0.00036162863, 0.00035821216, 0.00036032917, 0.00035336392, 0.00035655394, 0.00035665746, 0.000362708, 0.00036064725, 0.0003806862, 0.00038120328, 0.0003856702, 0.00036410431, 0.00036021153, 0.00036502344, 0.00038938547, 0.00038547945, 0.00039853444, 0.00039816555, 0.00037815046, 0.00037645004, 0.0003726846, 0.00037748602, 0.00035993406, 0.0003816437, 0.0003808012, 0.0003612708, 0.00036932772, 0.00038040505, 0.00037913918, 0.00039044552, 0.00038266164, 0.00038707262, 0.00038567337, 0.00035418934, 0.00035764152, 0.00036084498, 0.00034838638, 0.00034654813, 0.00034904908, 0.00034209466, 0.00029780134, 0.00028781855, 0.0002807741, 0.0002812437, 0.0002680243, 0.00026602892, 0.00026543156, 0.0002908985, 0.00028773426, 0.00027950332, 0.00028852836, 0.00027958394, 0.0002677997, 0.00026793158, 0.00026772704, 0.00027726675, 0.00027632408, 0.00027777298, 0.00027896848, 0.0002804266, 0.00027891048, 0.00026905086, 0.0002716721, 0.000272549, 0.00030032723, 0.00029694292, 0.00026482105, 0.0002609564, 0.0002642313, 0.00025266717, 0.00025791372, 0.0002588811, 0.0002503638, 0.0002530654, 0.00025172936, 0.00026078126, 0.00026084046, 0.00026073953, 0.0002621693, 0.00025604112, 0.00025836044, 0.0002598644, 0.00026070126, 0.00025633222, 0.00025493873, 0.00025132723, 0.00026994623, 0.00024089664, 0.0002477803, 0.00024638665, 0.00022482312, 0.00022516595, 0.00022487898, 0.00023465662, 0.00024326949, 0.00024017907, 0.00023954618, 0.00024312943, 0.0002403198, 0.0002471416, 0.00024329753, 0.00024480183, 0.00023701454, 0.00024341038, 0.00023172548, 0.00022789619, 0.00022098205, 0.00021594205, 0.0002198027, 0.00021821362, 0.00021337564, 0.00021452265, 0.00022371013, 0.00022366004, 0.00022210744, 0.00022212234, 0.00021541872, 0.0002051059, 0.0001921053, 0.00018451338, 0.00018448521, 0.00018177347, 0.00018323104, 0.00018074038, 0.000180975, 0.00018127431, 0.00017851024, 0.00017324074, 0.00017445578, 0.00016938147, 0.00017366688, 0.00016490399, 0.00016303177, 0.0001588034, 0.00020067992, 0.00019518723, 0.00021151012, 0.00021322911, 0.00020931978, 0.00020629932, 0.00021095212, 0.00021711936, 0.0002029271, 0.00020451211, 0.000190705, 0.0001910329, 0.00018971165, 0.00019146262, 0.00019307307, 0.00018602342, 0.0001856969, 0.00018579645, 0.00018754194, 0.00018623554, 0.00018630244, 0.00019807278, 0.00019303274, 0.00018754766, 0.00018576776, 0.0001820666, 0.00018357935, 0.00018581076, 0.00018733459, 0.00018916138, 0.00018448521, 0.00019090335, 0.00019288479, 0.00019171054, 0.00019869358, 0.0002043998, 0.00020923353, 0.00020819515, 0.00022288934, 0.00022451927, 0.00019896279, 0.00019574411, 0.00019387447, 0.00019277973, 0.0002009428, 0.00020272055, 0.00019834242, 0.0002243026, 0.00022395156, 0.00022758268, 0.00022765364, 0.00022761774, 0.00021463708, 0.00021417967, 0.00021654078, 0.00021657182, 0.00022115697, 0.0002453074, 0.00024563182, 0.0002489075, 0.0002478156, 0.00025020225, 0.00024531447, 0.00023790813, 0.00023405197, 0.00023183812, 0.00023202902, 0.00025402987, 0.00025606964, 0.00021917181, 0.0002179001, 0.000218272, 0.00022162081, 0.00021926957, 0.00021347399, 0.00023329185, 0.00023242272, 0.00023366361, 0.00023003727, 0.0002424918, 0.00024694033, 0.00026265226, 0.00025152194, 0.00025572465, 0.00026664592, 0.00026696152, 0.00027016978, 0.0002735722, 0.00027908373, 0.00025338202, 0.0002596863, 0.00027608257, 0.0002751917, 0.00027848335, 0.0002725754, 0.0002760737, 0.00027661174, 0.00028214967, 0.00028878325, 0.00029404555, 0.0003000968 ...

# %% [markdown]
# ### save npy

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from funcs_indicator import *

def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


#       set data features : ohlc, v, ep
time_index = ohlcv.index[np.sum(np.isnan(pr)):]

sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

#       scale with price    #
ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
sar = lucid_sar(sliced_ohlcv)
ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
senkou1, senkou2 = ichimoku(sliced_ohlcv)

#     min max scale   #
vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

pr_list = pr[np.sum(np.isnan(pr)):]
print("len(ohlc) :", len(ohlc))
print("len(pr) :", len(pr))

# break


#       set params    #
period = 45
key_i = i

plotting = True

data_x, data_pr, data_updown = [], [], []
data_index = []

for i in range(period, len(ohlc)):

  #   pr_list != 1 인 데이터만 사용한다
  # if 1:
  if pr_list[i] != 1:

    min_max = MinMaxScaler()
    
    #   prediction 을 제외한 이전 데이터를 사용해야한다
    temp_ohlc = ohlc.iloc[i - period : i].values
    # temp_long_ep = long_ep[i - period : i]          
    temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
    temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

    temp_close = min_max_scale(temp_ohlc[:, [3]])    

    price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

    if np.isnan(np.sum(price_data)):
      continue

    # print("price_data[:10] :", price_data[:10])
    # print("temp_ohlc.shape :", temp_ohlc.shape)
    # print("temp_long_ep.shape :", temp_long_ep.shape)
    # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
    # print("price_data.shape :", price_data.shape)

    if plotting:
      plt.plot(price_data)
      plt.show()

    ind_temp_ohlc = min_max_scale(temp_ohlc)
    temp_price_data = min_max_scale(price_data)
    # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


    if plotting:

      plt.plot(ind_temp_ohlc)
      plt.show()
      plt.plot(temp_price_data)
      plt.show()

      plotting = False
    # break

    #   vol -> min_max
    temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
    
    #                   feature selection                   #        
    temp_data = np.hstack((ind_temp_ohlc, temp_vol))

    # temp_data = trial_list[trial_number]
    # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
    # temp_data = temp_ohlc[:, [3]]
    # temp_data = ind_temp_ohlc[:, [3]]
    # temp_data = temp_close

    if np.isnan(np.sum(temp_data)):
      continue

    data_x.append(temp_data)
    data_pr.append(pr_list[i])
    data_index.append(time_index[i])
    data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


print('np.array(data_x).shape :', np.array(data_x).shape)
# print(data_x[0])


#       Reshape data for image deep - learning     #
_, row, col = np.array(data_x).shape

input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
# input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

#     1c to 3c    #
input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
# input_x = np.array(resize_npy(input_x))


input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
input_index = np.array(data_index).reshape(-1, 1)
print('input_x.shape :', input_x.shape)
print('input_x.dtype :', input_x.dtype)
print('input_pr.shape :', input_pr.shape)
print('input_ud.shape :', input_ud.shape)
print('input_index.shape :', input_index.shape)


# x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

#     do stacking   #
# if prev_x is None:
prev_x = input_x
prev_pr = input_pr
prev_ud = input_ud
prev_index = input_index

total_x = input_x
total_pr = input_pr
total_ud = input_ud
total_index = input_index

# else:
#   total_x = np.vstack((prev_x, input_x))
#   total_pr = np.vstack((prev_pr, input_pr))
#   total_ud = np.vstack((prev_ud, input_ud)) 
#   total_index = np.vstack((prev_index, input_index)) 

#   prev_x = total_x
#   prev_pr = total_pr
#   prev_ud = total_ud
#   prev_index = total_index

print('total_x.shape :', total_x.shape)
print('total_pr.shape :', total_pr.shape)
print('total_ud.shape :', total_ud.shape)
print('prev_index.shape :', prev_index.shape)


# _, row, col, _ = input_x.shape
# _, row, col = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


#         get unique timestamp      #
print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

#                 don't shuffle timeseries data                 #
stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)

index_train = np.array(index_train)
index_val = np.array(index_val)
index_test = np.array(index_test)
  
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

symbol_name = key.split(' ')[1].split('.')[0]

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)

np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %% [markdown]
# ### load npy

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


symbol_name = "SXPUSDT"
period = 45

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)


x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')


pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

# total_x = np.vstack((x_train, x_val, x_test))
# total_pr = np.vstack((pr_train, pr_val, pr_test))

# print("total_x.shape :", total_x.shape)
# Out:
# x series loaded !
# y series loaded !

# %% [markdown]
# ### rapid pr selection

# %%
plt.plot(pr)
plt.show()

pr_thresh = 1.005
rapid_pct = len(pr[pr > pr_thresh]) / len(pr)

print(rapid_pct)
# Out:
# 0.36131427304964536

# %% [markdown]
# ### class_weight & categorization

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


def class_ratio(in_list):

  return in_list / in_list[1]
  
y_train = np.where(pr_train > pr_thresh, 1, 0)
y_test = np.where(pr_test > pr_thresh, 1, 0)
y_val = np.where(pr_val > pr_thresh, 1, 0)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

# try:
print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

# except Exception as e:
  # print(e)

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)
# Out:
# x_train.shape : (10755, 45, 5, 3)
# x_test.shape : (3586, 45, 5, 3)
# x_val.shape : (3585, 45, 5, 3)
# y_train.shape : (10755, 1)
# y_test.shape : (3586, 1)
# y_val.shape : (3585, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([6864, 3891])) [1.76407093 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2303, 1282])) [1.79641186 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2291, 1295])) [1.76911197 1.        ]
# class_weights : {0: 0.7834353146853147, 1: 1.382035466461064}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10755, 2)
# y_val_ohe.shape : (3585, 2)
# y_test_ohe.shape : (3586, 2)

# %% [markdown]
# ### augment

# %%
from keras.preprocessing.image import ImageDataGenerator 

datagen = ImageDataGenerator( 
    # rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)


batch_size = 512


for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break

# %% [markdown]
# ### train

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'

# batch_size = 512

model = FER_Model(input_shape=x_train.shape[1:])
opt = Adam(lr=0.00001, decay=0.000005)
# opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model_name = 'classifier_%s_cnn_updown_rascend_1005_%s_tvnon_shuffle.h5' % (period, symbol_name)



checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]
# callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)

# %% [markdown]
# ### load model

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'


# model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)


model = keras.models.load_model(ckpt_path + model_name)

# %% [markdown]
# ### test

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break
acc_pr_bythr = []
new_thresh = []
temp_pr_list = []


for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)

  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  temp_pr_list.append(pred_pr_list)


  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(13, 5))
plt.subplot(131)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(132)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')

best_thr = new_thresh[np.argmax(acc_pr_bythr)]
plt.axvline(best_thr, linestyle='--', color='r')
plt.title(symbol_name + '\n' + str(best_thr))

plt.subplot(133)
plt.plot(np.cumprod(temp_pr_list[np.argmax(acc_pr_bythr)]))

plt.show()
# Out:
# test_result.shape : (3586, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.2967579 ]
#  [0.58192027]
#  [0.24180868]
#  [0.2117169 ]
#  [0.38554308]]
# y_test.shape : (3586, 1)
# y_score.shape : (3586, 1)
# len(y_test) : 3586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:70: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [5.655078e-05, 5.520107e-05, 5.5330333e-05, 5.5152388e-05, 5.5390752e-05, 5.43783e-05, 5.3821786e-05, 5.3719716e-05, 5.3675743e-05, 5.3988468e-05, 5.3519037e-05, 5.302161e-05, 5.4104647e-05, 5.166685e-05, 5.2683325e-05, 5.2943476e-05, 5.3775533e-05, 5.430922e-05, 5.4266344e-05, 5.49028e-05, 5.5253076e-05, 5.276297e-05, 5.333982e-05, 5.4236934e-05, 5.552557e-05, 5.578506e-05, 5.345386e-05, 5.360306e-05, 5.4610166e-05, 5.5654975e-05, 5.6132867e-05, 5.6584915e-05, 5.674103e-05, 5.532068e-05, 5.6154833e-05, 5.6213146e-05, 5.589686e-05, 5.604205e-05, 5.628267e-05, 5.7030997e-05, 5.6243658e-05, 5.601442e-05, 5.646138e-05, 5.5428463e-05, 5.628157e-05, 5.840626e-05, 6.109183e-05, 6.134273e-05, 6.292447e-05, 6.313881e-05, 6.5777356e-05, 6.53976e-05, 6.5210865e-05, 6.419067e-05, 6.476796e-05, 6.4382504e-05, 6.55541e-05, 6.5452485e-05, 6.5249435e-05, 6.419496e-05, 6.476423e-05, 6.492506e-05, 6.5751046e-05, 6.2620165e-05, 6.437592e-05, 6.462331e-05, 6.801586e-05, 6.7693654e-05, 6.614884e-05, 6.437985e-05, 6.486002e-05, 6.423155e-05, 6.417903e-05, 6.452413e-05, 6.500568e-05, 6.6838635e-05, 6.624353e-05, 6.7260706e-05, 6.647928e-05, 6.818756e-05, 6.8915855e-05, 6.805248e-05, 6.89511e-05, 7.036587e-05, 7.326979e-05, 7.065091e-05, 7.225045e-05, 7.221067e-05, 7.000439e-05, 7.0488626e-05, 7.469813e-05, 6.877086e-05, 6.8285655e-05, 7.5541044e-05, 7.59109e-05, 7.5227676e-05, 7.8340316e-05, 7.920282e-05, 8.091853e-05, 8.21443e-05, 8.28473e-05, 8.24133e-05, 8.3677005e-05, 8.397523e-05, 8.274032e-05, 8.3947074e-05, 8.854853e-05, 8.887778e-05, 8.8237815e-05, 9.0176254e-05, 8.627809e-05, 8.7011846e-05, 8.903624e-05, 8.8547786e-05, 8.986805e-05, 9.287384e-05, 9.1382564e-05, 9.290532e-05, 9.228036e-05, 9.471127e-05, 8.977273e-05, 8.976577e-05, 8.994613e-05, 9.10928e-05, 8.96696e-05, 9.095449e-05, 9.3412185e-05, 9.5005926e-05, 9.589863e-05, 9.568425e-05, 9.447747e-05, 9.357707e-05, 9.435524e-05, 9.171831e-05, 9.1081216e-05, 8.8054025e-05, 8.75671e-05, 8.734238e-05, 8.8639026e-05, 9.070475e-05, 9.050466e-05, 8.986403e-05, 8.873263e-05, 8.857961e-05, 8.903897e-05, 8.9397574e-05, 8.711334e-05, 8.906553e-05, 9.0693255e-05, 9.0109446e-05, 9.014448e-05, 9.268405e-05, 9.1892245e-05, 9.124063e-05, 9.136879e-05, 9.409891e-05, 9.50517e-05, 9.538832e-05, 9.930735e-05, 9.989454e-05, 9.875602e-05, 9.9093515e-05, 0.000100750476, 0.000100150944, 0.0001004308, 0.00010149061, 9.951968e-05, 9.986607e-05, 0.000101167796, 0.00010713392, 0.00010840478, 0.00010405836, 0.00010337646, 0.00010798385, 0.000107155334, 0.000105306186, 0.000105751795, 0.000104867875, 0.000106827036, 0.00010687932, 0.00010915114, 0.00010937274, 0.00011121047, 0.000110081666, 0.00010974538, 0.00011179644, 0.000112659436, 0.00011266655, 0.000113447626, 0.00011456148, 0.000117434996, 0.00011816488, 0.00012011631, 0.000118910306, 0.00011751313, 0.00011158044, 0.000111053356, 0.00010966703, 0.00011447091, 0.00011452321, 0.00011290235, 0.000107441134, 0.00010564327, 0.00010485477, 0.0001037572, 0.000100963574, 0.00010250914, 0.00010187085, 0.00010217729, 0.000104082654, 0.00010194415, 0.000102163845, 0.0001015418, 9.571324e-05, 9.689976e-05, 9.2931725e-05, 9.3481e-05, 9.517918e-05, 9.9320474e-05, 0.00010020035, 9.871816e-05, 9.6594944e-05, 9.812609e-05, 9.705547e-05, 0.0001003807, 0.00010935121, 0.00010578462, 9.7838485e-05, 9.956839e-05, 9.916078e-05, 9.730118e-05, 9.65546e-05, 9.8827135e-05, 9.867449e-05, 9.865194e-05, 0.000102401405, 0.00010587168, 0.000109928595, 0.000110167966, 0.00011322554, 0.000111794674, 0.00011214637, 0.000109060544, 0.00010492743, 0.00010460153, 0.00010516639, 0.00010494196, 0.00010589498, 0.000103736886, 0.00010193135, 9.85419e-05, 9.86999e-05, 0.00010004239, 0.00010002664, 9.7913544e-05, 9.751047e-05, 9.733665e-05, 9.719883e-05, 9.4854564e-05, 9.562092e-05, 9.855631e-05, 9.926471e-05, 9.6015974e-05, 9.4427895e-05, 9.363725e-05, 9.237256e-05, 9.7822056e-05, 9.688444e-05, 9.7427364e-05, 9.6133226e-05, 9.6317424e-05, 9.6218966e-05, 9.734897e-05, 9.596875e-05, 9.523 ...

# %%
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)], linestyle='--', color='r')
plt.title(symbol_name + '\n' + str(new_thresh[np.argmax(acc_pr_bythr)]))
plt.show()

# %%
thresh = 0.5866
y_pred = np.where(y_score[:600, -1] > thresh, 1, 0)
# print('y_pred.shape :', y_pred.shape)
# print('y_pred :', y_pred)

#     compare precision     #

# print('precision :', precision_score(y_test, y_pred))
# print('recall :', recall_score(y_test, y_pred))
# print()

# print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
# print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

# # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
# # plt.show()  
# print()

#     check win-ratio improvement     #
cmat = confusion_matrix(y_test[:len(y_pred)], y_pred)
# print(cmat)
# print(np.sum(cmat, axis=1))

test_size = len(y_test[:len(y_pred)])
test_pr_list = pr_test[:len(y_pred)]
# print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
# print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

# print('pr_test.shape :', pr_test.shape)

# print(y_pred)
# print(test_pr_list)
pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

plt.plot(np.cumprod(pred_pr_list))
plt.show()

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72a922dd9685> in <module>()
#       5 # print(index_train)
#       6 # print(index_val)
# ----> 7 total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index))
#       8 timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train))
#       9 timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val))
#
# NameError: name 'input_index' is not defined

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
