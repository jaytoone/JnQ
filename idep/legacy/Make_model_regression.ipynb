# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
import warnings

warnings.filterwarnings(action='ignore')
# %tensorflow_version 1.x
# %matplotlib inline


def min_max_scaler(x):
    scaled_x = (x - x.min()) / (x.max() - x.min())
    return scaled_x


def max_abs_scaler(x):
    scaled_x = x / abs(x).max()
    return scaled_x


# input_data_length = int(input('input_data_length : '))
input_data_length = 10
model_num = 105
# num_classes = 3

gdrive_path = '/content/gdrive/My Drive/Colab Notebooks/'

#           read reg ohlcv          #
file_path = gdrive_path + 'ohlcv_reg/'
file_list = os.listdir(file_path)
# print(file_list)
# breakpoint
# file = file_list[-2]

# 500, 20, 1
# 0.1, 100, 0.5
C, gamma, epsilon = 1000, 10, 0.1
svr = SVR(kernel='rbf', C=C, gamma=gamma, epsilon=epsilon)

# dataX, dataY = list(), list()
# for i in range(1, len(file_list) - 1):

file = file_list[3]
print(file)
# breakpoint 
# file = '2020-04-02 BackTest GNT_from_excel.xlsx'

ohlcv_reg = pd.read_excel(file_path + file, index_col=0)
# print(ohlcv_reg.iloc[:, [-7]])
# breakpoint

#     X_data : idl 만큼의 close? (일단),    Y_data : reg
#     실시간으로 reg의 형태가 machine learning으로는 고정되지 않기 때문에,
#     먼저 고정을 시키고, deep learning을 이용해 실시간으로 고정된 regression 결과를 뽑아낼 수 있는지 확인한다.
#     충분히 가능성 있다.     #

#         reg_target = close인 경우 앞의 데이터가 산다.       #  close/ close_reg
ohlcv_reg = ohlcv_reg.values[sum(ohlcv_reg.MACD_Signal.isna()):, :]
reg_target = ohlcv_reg[:, [-7]].astype(np.float32)
reg_result = ohlcv_reg[:, [-5]].astype(np.float32)
# print(np.sum(np.isnan(reg_target), axis=0))
# breakpoint

x = np.arange(len(reg_target)).reshape(-1, 1)
y = reg_target.reshape(-1, 1)
scaler_x = StandardScaler()
scaler_y = StandardScaler()
x = scaler_x.fit_transform(x)
y = scaler_y.fit_transform(y)
svr.fit(x, y)
reg_result = svr.predict(x).reshape(-1, 1)
# breakpoint

scaler_x = StandardScaler()
scaler_y = StandardScaler()
reg_target = scaler_x.fit_transform(reg_target)
reg_result = scaler_y.fit_transform(reg_result)

# reg_target = max_abs_scaler(reg_target)
# reg_result = max_abs_scaler(reg_result)
# print(reg_target, reg_result)
# breakpoint

dataX, dataY = list(), list()
for i in range(input_data_length, len(reg_target)):

  # group_x = reg_target[i - input_data_length: i]
  group_x = reg_target[i + 1 - input_data_length: i + 1]
  group_y = reg_result[i]
  # print(group_x[0])
  # quit()

  #   데이터 값에 결측치가 존재하는 경우 #
  if sum(sum(np.isnan(group_x))) > 0:
      continue

  dataX.append(group_x)  # dataX 리스트에 추가
  dataY.append(group_y)

Made_X = np.array(dataX)
Made_Y = np.array(dataY)
# print(Made_X.shape, Made_Y.shape)
# breakpoint  


from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(Made_X, Made_Y, test_size=0.4,
                                                   shuffle=False)
X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5,
                                                   shuffle=False)
print(X_train.shape)
print(X_test.shape)
print(X_val.shape)
print(Y_train.shape)
print(Y_test.shape)
print(Y_val.shape)
# breakpoint

row = X_train.shape[1]
col = X_train.shape[2]

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.layers import Dense, LSTM, Dropout, Input, Flatten
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix

def FER_Model(input_shape=(row, col)):

    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Dense(32)(visible)
    # net = layers.LSTM(10, return_sequences=True)(visible)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    
    net = layers.Dense(64)(net)
    # net = layers.LSTM(64, return_sequences=True)(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.Dropout(0.5)(net)

    # net = layers.Dense(50)(net)
    # # net = layers.LSTM(64, return_sequences=False)(net)
    # net = layers.LeakyReLU()(net)
    # # net = layers.Dropout(0.5)(net)

    # net = layers.Dense(32)(net)
    # # net = layers.LSTM(64, return_sequences=False)(net)
    # net = layers.LeakyReLU()(net)
    # # net = layers.Dropout(0.5)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(1)(net)
    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    model.summary()

    return model

model = FER_Model()
# from keras.models import load_model
# model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_ohlc.hdf5' % (input_data_length, model_num))

opt = Adam(lr=0.0001, decay=1e-6)
model.compile(loss='mean_squared_error', optimizer=opt, metrics=['mse'])
  
    
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath = gdrive_path + "model/rapid_ascending %s_%s_ohlc.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=20)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 100
history = model.fit(X_train, Y_train,
                    epochs=num_epochs,
                    batch_size=300,
                    validation_data=(X_val, Y_val),
                    verbose=2,
                    callbacks=callbacks_list,
                    shuffle=False,
                    )

#         RESULT COMPARING    #
plt.subplot(211)
plt.plot(reg_target, color='r')
plt.plot(reg_result, color='b')
plt.title('MACD_OSC & SVR', color='white')
plt.show()

pred_reg = model.predict(X_test)

plt.subplot(212)
plt.plot(Y_test, color='r', label='Y_test')
plt.plot(X_test[:, [-1]].reshape(-1, 1), color='y', label='MACD_OSC')
plt.plot(pred_reg, color='b',  label='pred_reg')
plt.title('OSC_PRED', color='white')
plt.legend(loc='upper right')
plt.show()
# Out:
# 2020-04-04 BackTest DAD.xlsx
# (45, 10, 1)
# (15, 10, 1)
# (16, 10, 1)
# (45, 1)
# (15, 1)
# (16, 1)
# Model: "model_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 10, 1)             0
# _________________________________________________________________
# dense_109 (Dense)            (None, 10, 32)            64
# _________________________________________________________________
# leaky_re_lu_73 (LeakyReLU)   (None, 10, 32)            0
# _________________________________________________________________
# dense_110 (Dense)            (None, 10, 64)            2112
# _________________________________________________________________
# leaky_re_lu_74 (LeakyReLU)   (None, 10, 64)            0
# _________________________________________________________________
# flatten_37 (Flatten)         (None, 640)               0
# _________________________________________________________________
# dense_111 (Dense)            (None, 1)                 641
# =================================================================
# Total params: 2,817
# Trainable params: 2,817
# Non-trainable params: 0
# _________________________________________________________________
# Train on 45 samples, validate on 16 samples
# Epoch 1/100
#  - 1s - loss: 0.4122 - mean_squared_error: 0.4122 - val_loss: 2.0790 - val_mean_squared_error: 2.0790
#
# Epoch 00001: val_loss improved from inf to 2.07899, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 2/100
#  - 0s - loss: 0.4063 - mean_squared_error: 0.4063 - val_loss: 2.0490 - val_mean_squared_error: 2.0490
#
# Epoch 00002: val_loss improved from 2.07899 to 2.04901, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 3/100
#  - 0s - loss: 0.4005 - mean_squared_error: 0.4005 - val_loss: 2.0193 - val_mean_squared_error: 2.0193
#
# Epoch 00003: val_loss improved from 2.04901 to 2.01927, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 4/100
#  - 0s - loss: 0.3947 - mean_squared_error: 0.3947 - val_loss: 1.9899 - val_mean_squared_error: 1.9899
#
# Epoch 00004: val_loss improved from 2.01927 to 1.98990, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 5/100
#  - 0s - loss: 0.3889 - mean_squared_error: 0.3889 - val_loss: 1.9610 - val_mean_squared_error: 1.9610
#
# Epoch 00005: val_loss improved from 1.98990 to 1.96102, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 6/100
#  - 0s - loss: 0.3832 - mean_squared_error: 0.3832 - val_loss: 1.9325 - val_mean_squared_error: 1.9325
#
# Epoch 00006: val_loss improved from 1.96102 to 1.93248, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 7/100
#  - 0s - loss: 0.3775 - mean_squared_error: 0.3775 - val_loss: 1.9042 - val_mean_squared_error: 1.9042
#
# Epoch 00007: val_loss improved from 1.93248 to 1.90421, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 8/100
#  - 0s - loss: 0.3718 - mean_squared_error: 0.3718 - val_loss: 1.8762 - val_mean_squared_error: 1.8762
#
# Epoch 00008: val_loss improved from 1.90421 to 1.87617, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 9/100
#  - 0s - loss: 0.3662 - mean_squared_error: 0.3662 - val_loss: 1.8484 - val_mean_squared_error: 1.8484
#
# Epoch 00009: val_loss improved from 1.87617 to 1.84836, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 10/100
#  - 0s - loss: 0.3606 - mean_squared_error: 0.3606 - val_loss: 1.8208 - val_mean_squared_error: 1.8208
#
# Epoch 00010: val_loss improved from 1.84836 to 1.82078, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 11/100
#  - 0s - loss: 0.3551 - mean_squared_error: 0.3551 - val_loss: 1.7934 - val_mean_squared_error: 1.7934
#
# Epoch 00011: val_loss improved from 1.82078 to 1.79341, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 12/100
#  - 0s - loss: 0.3495 - mean_squared_error: 0.3495 - val_loss: 1.7663 - val_mean_squared_error: 1.7663
#
# Epoch 00012: val_loss improved from 1.79341 to 1.76626, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 13/100
#  - 0s - loss: 0.3440 - mean_squared_error: 0.3440 - val_loss: 1.7393 - val_mean_squared_error: 1.7393
#
# Epoch 00013: val_loss improved from 1.76626 to 1.73932, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 14/100
#  - 0s - loss: 0.3386 - mean_squared_error: 0.3386 - val_loss: 1.7126 - val_mean_squared_error: 1.7126
#
# Epoch 00014: val_loss improved from 1.73932 to 1.71260, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 15/100
#  - 0s - loss: 0.3332 - mean_squared_error: 0.3332 - val_loss: 1.6861 - val_mean_squared_error: 1.6861
#
# Epoch 00015: val_loss improved from 1.71260 to 1.68610, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 16/100
#  - 0s - loss: 0.3279 - mean_squared_error: 0.3279 - val_loss: 1.6598 - val_mean_squared_error: 1.6598
#
# Epoch 00016: val_loss improved from 1.68610 to 1.65983, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 17/100
#  - 0s - loss: 0.3225 - mean_squared_error: 0.3225 - val_loss: 1.6338 - val_mean_squared_error: 1.6338
#
# Epoch 00017: val_loss improved from 1.65983 to 1.63379, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 18/100
#  - 0s - loss: 0.3173 - mean_squared_error: 0.3173 - val_loss: 1.6080 - val_mean_squared_error: 1.6080
#
# Epoch 00018: val_loss improved from 1.63379 to 1.60798, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 19/100
#  - 0s - loss: 0.3121 - mean_squared_error: 0.3121 - val_loss: 1.5824 - val_mean_squared_error: 1.5824
#
# Epoch 00019: val_loss improved from 1.60798 to 1.58241, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 20/100
#  - 0s - loss: 0.3070 - mean_squared_error: 0.3070 - val_loss: 1.5571 - val_mean_squared_error: 1.5571
#
# Epoch 00020: val_loss improved from 1.58241 to 1.55707, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 21/100
#  - 0s - loss: 0.3019 - mean_squared_error: 0.3019 - val_loss: 1.5320 - val_mean_squared_error: 1.5320
#
# Epoch 00021: val_loss improved from 1.55707 to 1.53197, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 22/100
#  - 0s - loss: 0.2969 - mean_squared_error: 0.2969 - val_loss: 1.5071 - val_mean_squared_error: 1.5071
#
# Epoch 00022: val_loss improved from 1.53197 to 1.50711, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 23/100
#  - 0s - loss: 0.2919 - mean_squared_error: 0.2919 - val_loss: 1.4825 - val_mean_squared_error: 1.4825
#
# Epoch 00023: val_loss improved from 1.50711 to 1.48248, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 24/100
#  - 0s - loss: 0.2870 - mean_squared_error: 0.2870 - val_loss: 1.4581 - val_mean_squared_error: 1.4581
#
# Epoch 00024: val_loss improved from 1.48248 to 1.45815, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 25/100
#  - 0s - loss: 0.2821 - mean_squared_error: 0.2821 - val_loss: 1.4341 - val_mean_squared_error: 1.4341
#
# Epoch 00025: val_loss improved from 1.45815 to 1.43407, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 26/100
#  - 0s - loss: 0.2772 - mean_squared_error: 0.2772 - val_loss: 1.4102 - val_mean_squared_error: 1.4102
#
# Epoch 00026: val_loss improved from 1.43407 to 1.41023, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 27/100
#  - 0s - loss: 0.2725 - mean_squared_error: 0.2725 - val_loss: 1.3866 - val_mean_squared_error: 1.3866
#
# Epoch 00027: val_loss improved from 1.41023 to 1.38661, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 28/100
#  - 0s - loss: 0.2677 - mean_squared_error: 0.2677 - val_loss: 1.3632 - val_mean_squared_error: 1.3632
#
# Epoch 00028: val_loss improved from 1.38661 to 1.36323, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 29/100
#  - 0s - loss: 0.2631 - mean_squared_error: 0.2631 - val_loss: 1.3401 - val_mean_squared_error: 1.3401
#
# Epoch 00029: val_loss improved from 1.36323 to 1.34008, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 30/100
#  - 0s - loss: 0.2584 - mean_squared_error: 0.2584 - val_loss: 1.3172 - val_mean_squared_error: 1.3172
#
# Epoch 00030: val_loss improved from 1.34008 to 1.31717, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 31/100
#  - 0s - loss: 0.2538 - mean_squared_error: 0.2538 - val_loss: 1.2946 - val_mean_squared_error: 1.2946
#
# Epoch 00031: val_loss improved from 1.31717 to 1.29456, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 32/100
#  - 0s - loss: 0.2493 - mean_squared_error: 0.2493 - val_loss: 1.2722 - val_mean_squared_error: 1.2722
#
# Epoch 00032: val_loss improved from 1.29456 to 1.27221, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 33/100
#  - 0s - loss: 0.2448 - mean_squared_error: 0.2448 - val_loss: 1.2501 - val_mean_squared_error: 1.2501
#
# Epoch 00033: val_loss improved from 1.27221 to 1.25010, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 34/100
#  - 0s - loss: 0.2404 - mean_squared_error: 0.2404 - val_loss: 1.2282 - val_mean_squared_error: 1.2282
#
# Epoch 00034: val_loss improved from 1.25010 to 1.22821, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 35/100
#  - 0s - loss: 0.2360 - mean_squared_error: 0.2360 - val_loss: 1.2065 - val_mean_squared_error: 1.2065
#
# Epoch 00035: val_loss improved from 1.22821 to 1.20654, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 36/100
#  - 0s - loss: 0.2316 - mean_squared_error: 0.2316 - val_loss: 1.1851 - val_mean_squared_error: 1.1851
#
# Epoch 00036: val_loss improved from 1.20654 to 1.18511, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 37/100
#  - 0s - loss: 0.2273 - mean_squared_error: 0.2273 - val_loss: 1.1639 - val_mean_squared_error: 1.1639
#
# Epoch 00037: val_loss improved from 1.18511 to 1.16389, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 38/100
#  - 0s - loss: 0.2231 - mean_squared_error: 0.2231 - val_loss: 1.1429 - val_mean_squared_error: 1.1429
#
# Epoch 00038: val_loss improved from 1.16389 to 1.14291, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 39/100
#  - 0s - loss: 0.2189 - mean_squared_error: 0.2189 - val_loss: 1.1221 - val_mean_squared_error: 1.1221
#
# Epoch 00039: val_loss improved from 1.14291 to 1.12214, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 40/100
#  - 0s - loss: 0.2147 - mean_squared_error: 0.2147 - val_loss: 1.1016 - val_mean_squared_error: 1.1016
#
# Epoch 00040: val_loss improved from 1.12214 to 1.10158, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 41/100
#  - 0s - loss: 0.2106 - mean_squared_error: 0.2106 - val_loss: 1.0812 - val_mean_squared_error: 1.0812
#
# Epoch 00041: val_loss improved from 1.10158 to 1.08124, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 42/100
#  - 0s - loss: 0.2065 - mean_squared_error: 0.2065 - val_loss: 1.0612 - val_mean_squared_error: 1.0612
#
# Epoch 00042: val_loss improved from 1.08124 to 1.06123, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 43/100
#  - 0s - loss: 0.2025 - mean_squared_error: 0.2025 - val_loss: 1.0415 - val_mean_squared_error: 1.0415
#
# Epoch 00043: val_loss improved from 1.06123 to 1.04154, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 44/100
#  - 0s - loss: 0.1985 - mean_squared_error: 0.1985 - val_loss: 1.0221 - val_mean_squared_error: 1.0221
#
# Epoch 00044: val_loss improved from 1.04154 to 1.02213, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 45/100
#  - 0s - loss: 0.1945 - mean_squared_error: 0.1945 - val_loss: 1.0030 - val_mean_squared_error: 1.0030
#
# Epoch 00045: val_loss improved from 1.02213 to 1.00299, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 46/100
#  - 0s - loss: 0.1906 - mean_squared_error: 0.1906 - val_loss: 0.9841 - val_mean_squared_error: 0.9841
#
# Epoch 00046: val_loss improved from 1.00299 to 0.98409, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 47/100
#  - 0s - loss: 0.1868 - mean_squared_error: 0.1868 - val_loss: 0.9654 - val_mean_squared_error: 0.9654
#
# Epoch 00047: val_loss improved from 0.98409 to 0.96540, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 48/100
#  - 0s - loss: 0.1830 - mean_squared_error: 0.1830 - val_loss: 0.9469 - val_mean_squared_error: 0.9469
#
# Epoch 00048: val_loss improved from 0.96540 to 0.94694, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 49/100
#  - 0s - loss: 0.1792 - mean_squared_error: 0.1792 - val_loss: 0.9287 - val_mean_squared_error: 0.9287
#
# Epoch 00049: val_loss improved from 0.94694 to 0.92870, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 50/100
#  - 0s - loss: 0.1755 - mean_squared_error: 0.1755 - val_loss: 0.9107 - val_mean_squared_error: 0.9107
#
# Epoch 00050: val_loss improved from 0.92870 to 0.91068, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 51/100
#  - 0s - loss: 0.1719 - mean_squared_error: 0.1719 - val_loss: 0.8929 - val_mean_squared_error: 0.8929
#
# Epoch 00051: val_loss improved from 0.91068 to 0.89288, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 52/100
#  - 0s - loss: 0.1682 - mean_squared_error: 0.1682 - val_loss: 0.8753 - val_mean_squared_error: 0.8753
#
# Epoch 00052: val_loss improved from 0.89288 to 0.87529, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 53/100
#  - 0s - loss: 0.1647 - mean_squared_error: 0.1647 - val_loss: 0.8579 - val_mean_squared_error: 0.8579
#
# Epoch 00053: val_loss improved from 0.87529 to 0.85792, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 54/100
#  - 0s - loss: 0.1611 - mean_squared_error: 0.1611 - val_loss: 0.8408 - val_mean_squared_error: 0.8408
#
# Epoch 00054: val_loss improved from 0.85792 to 0.84077, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 55/100
#  - 0s - loss: 0.1577 - mean_squared_error: 0.1577 - val_loss: 0.8238 - val_mean_squared_error: 0.8238
#
# Epoch 00055: val_loss improved from 0.84077 to 0.82382, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 56/100
#  - 0s - loss: 0.1542 - mean_squared_error: 0.1542 - val_loss: 0.8071 - val_mean_squared_error: 0.8071
#
# Epoch 00056: val_loss improved from 0.82382 to 0.80709, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 57/100
#  - 0s - loss: 0.1508 - mean_squared_error: 0.1508 - val_loss: 0.7905 - val_mean_squared_error: 0.7905
#
# Epoch 00057: val_loss improved from 0.80709 to 0.79055, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 58/100
#  - 0s - loss: 0.1475 - mean_squared_error: 0.1475 - val_loss: 0.7741 - val_mean_squared_error: 0.7741
#
# Epoch 00058: val_loss improved from 0.79055 to 0.77410, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 59/100
#  - 0s - loss: 0.1442 - mean_squared_error: 0.1442 - val_loss: 0.7578 - val_mean_squared_error: 0.7578
#
# Epoch 00059: val_loss improved from 0.77410 to 0.75782, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 60/100
#  - 0s - loss: 0.1410 - mean_squared_error: 0.1410 - val_loss: 0.7417 - val_mean_squared_error: 0.7417
#
# Epoch 00060: val_loss improved from 0.75782 to 0.74170, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 61/100
#  - 0s - loss: 0.1378 - mean_squared_error: 0.1378 - val_loss: 0.7258 - val_mean_squared_error: 0.7258
#
# Epoch 00061: val_loss improved from 0.74170 to 0.72581, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 62/100
#  - 0s - loss: 0.1346 - mean_squared_error: 0.1346 - val_loss: 0.7101 - val_mean_squared_error: 0.7101
#
# Epoch 00062: val_loss improved from 0.72581 to 0.71013, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 63/100
#  - 0s - loss: 0.1315 - mean_squared_error: 0.1315 - val_loss: 0.6947 - val_mean_squared_error: 0.6947
#
# Epoch 00063: val_loss improved from 0.71013 to 0.69467, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 64/100
#  - 0s - loss: 0.1285 - mean_squared_error: 0.1285 - val_loss: 0.6794 - val_mean_squared_error: 0.6794
#
# Epoch 00064: val_loss improved from 0.69467 to 0.67941, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 65/100
#  - 0s - loss: 0.1254 - mean_squared_error: 0.1254 - val_loss: 0.6644 - val_mean_squared_error: 0.6644
#
# Epoch 00065: val_loss improved from 0.67941 to 0.66438, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 66/100
#  - 0s - loss: 0.1225 - mean_squared_error: 0.1225 - val_loss: 0.6496 - val_mean_squared_error: 0.6496
#
# Epoch 00066: val_loss improved from 0.66438 to 0.64955, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 67/100
#  - 0s - loss: 0.1195 - mean_squared_error: 0.1195 - val_loss: 0.6349 - val_mean_squared_error: 0.6349
#
# Epoch 00067: val_loss improved from 0.64955 to 0.63495, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 68/100
#  - 0s - loss: 0.1167 - mean_squared_error: 0.1167 - val_loss: 0.6205 - val_mean_squared_error: 0.6205
#
# Epoch 00068: val_loss improved from 0.63495 to 0.62055, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 69/100
#  - 0s - loss: 0.1138 - mean_squared_error: 0.1138 - val_loss: 0.6064 - val_mean_squared_error: 0.6064
#
# Epoch 00069: val_loss improved from 0.62055 to 0.60636, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 70/100
#  - 0s - loss: 0.1110 - mean_squared_error: 0.1110 - val_loss: 0.5924 - val_mean_squared_error: 0.5924
#
# Epoch 00070: val_loss improved from 0.60636 to 0.59239, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 71/100
#  - 0s - loss: 0.1083 - mean_squared_error: 0.1083 - val_loss: 0.5786 - val_mean_squared_error: 0.5786
#
# Epoch 00071: val_loss improved from 0.59239 to 0.57863, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 72/100
#  - 0s - loss: 0.1056 - mean_squared_error: 0.1056 - val_loss: 0.5651 - val_mean_squared_error: 0.5651
#
# Epoch 00072: val_loss improved from 0.57863 to 0.56508, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 73/100
#  - 0s - loss: 0.1029 - mean_squared_error: 0.1029 - val_loss: 0.5518 - val_mean_squared_error: 0.5518
#
# Epoch 00073: val_loss improved from 0.56508 to 0.55177, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 74/100
#  - 0s - loss: 0.1003 - mean_squared_error: 0.1003 - val_loss: 0.5387 - val_mean_squared_error: 0.5387
#
# Epoch 00074: val_loss improved from 0.55177 to 0.53868, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 75/100
#  - 0s - loss: 0.0978 - mean_squared_error: 0.0978 - val_loss: 0.5258 - val_mean_squared_error: 0.5258
#
# Epoch 00075: val_loss improved from 0.53868 to 0.52582, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 76/100
#  - 0s - loss: 0.0952 - mean_squared_error: 0.0952 - val_loss: 0.5131 - val_mean_squared_error: 0.5131
#
# Epoch 00076: val_loss improved from 0.52582 to 0.51314, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 77/100
#  - 0s - loss: 0.0928 - mean_squared_error: 0.0928 - val_loss: 0.5006 - val_mean_squared_error: 0.5006
#
# Epoch 00077: val_loss improved from 0.51314 to 0.50064, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 78/100
#  - 0s - loss: 0.0904 - mean_squared_error: 0.0904 - val_loss: 0.4883 - val_mean_squared_error: 0.4883
#
# Epoch 00078: val_loss improved from 0.50064 to 0.48835, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 79/100
#  - 0s - loss: 0.0880 - mean_squared_error: 0.0880 - val_loss: 0.4762 - val_mean_squared_error: 0.4762
#
# Epoch 00079: val_loss improved from 0.48835 to 0.47625, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 80/100
#  - 0s - loss: 0.0857 - mean_squared_error: 0.0857 - val_loss: 0.4643 - val_mean_squared_error: 0.4643
#
# Epoch 00080: val_loss improved from 0.47625 to 0.46434, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 81/100
#  - 0s - loss: 0.0834 - mean_squared_error: 0.0834 - val_loss: 0.4526 - val_mean_squared_error: 0.4526
#
# Epoch 00081: val_loss improved from 0.46434 to 0.45263, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 82/100
#  - 0s - loss: 0.0811 - mean_squared_error: 0.0811 - val_loss: 0.4411 - val_mean_squared_error: 0.4411
#
# Epoch 00082: val_loss improved from 0.45263 to 0.44112, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 83/100
#  - 0s - loss: 0.0789 - mean_squared_error: 0.0789 - val_loss: 0.4298 - val_mean_squared_error: 0.4298
#
# Epoch 00083: val_loss improved from 0.44112 to 0.42983, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 84/100
#  - 0s - loss: 0.0768 - mean_squared_error: 0.0768 - val_loss: 0.4188 - val_mean_squared_error: 0.4188
#
# Epoch 00084: val_loss improved from 0.42983 to 0.41875, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 85/100
#  - 0s - loss: 0.0747 - mean_squared_error: 0.0747 - val_loss: 0.4079 - val_mean_squared_error: 0.4079
#
# Epoch 00085: val_loss improved from 0.41875 to 0.40789, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 86/100
#  - 0s - loss: 0.0727 - mean_squared_error: 0.0727 - val_loss: 0.3973 - val_mean_squared_error: 0.3973
#
# Epoch 00086: val_loss improved from 0.40789 to 0.39725, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 87/100
#  - 0s - loss: 0.0706 - mean_squared_error: 0.0706 - val_loss: 0.3868 - val_mean_squared_error: 0.3868
#
# Epoch 00087: val_loss improved from 0.39725 to 0.38683, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 88/100
#  - 0s - loss: 0.0687 - mean_squared_error: 0.0687 - val_loss: 0.3766 - val_mean_squared_error: 0.3766
#
# Epoch 00088: val_loss improved from 0.38683 to 0.37663, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 89/100
#  - 0s - loss: 0.0668 - mean_squared_error: 0.0668 - val_loss: 0.3666 - val_mean_squared_error: 0.3666
#
# Epoch 00089: val_loss improved from 0.37663 to 0.36664, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 90/100
#  - 0s - loss: 0.0649 - mean_squared_error: 0.0649 - val_loss: 0.3569 - val_mean_squared_error: 0.3569
#
# Epoch 00090: val_loss improved from 0.36664 to 0.35687, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 91/100
#  - 0s - loss: 0.0631 - mean_squared_error: 0.0631 - val_loss: 0.3473 - val_mean_squared_error: 0.3473
#
# Epoch 00091: val_loss improved from 0.35687 to 0.34732, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 92/100
#  - 0s - loss: 0.0613 - mean_squared_error: 0.0613 - val_loss: 0.3380 - val_mean_squared_error: 0.3380
#
# Epoch 00092: val_loss improved from 0.34732 to 0.33797, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 93/100
#  - 0s - loss: 0.0596 - mean_squared_error: 0.0596 - val_loss: 0.3288 - val_mean_squared_error: 0.3288
#
# Epoch 00093: val_loss improved from 0.33797 to 0.32884, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 94/100
#  - 0s - loss: 0.0579 - mean_squared_error: 0.0579 - val_loss: 0.3199 - val_mean_squared_error: 0.3199
#
# Epoch 00094: val_loss improved from 0.32884 to 0.31992, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 95/100
#  - 0s - loss: 0.0562 - mean_squared_error: 0.0562 - val_loss: 0.3112 - val_mean_squared_error: 0.3112
#
# Epoch 00095: val_loss improved from 0.31992 to 0.31121, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 96/100
#  - 0s - loss: 0.0546 - mean_squared_error: 0.0546 - val_loss: 0.3027 - val_mean_squared_error: 0.3027
#
# Epoch 00096: val_loss improved from 0.31121 to 0.30270, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 97/100
#  - 0s - loss: 0.0530 - mean_squared_error: 0.0530 - val_loss: 0.2944 - val_mean_squared_error: 0.2944
#
# Epoch 00097: val_loss improved from 0.30270 to 0.29439, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 98/100
#  - 0s - loss: 0.0515 - mean_squared_error: 0.0515 - val_loss: 0.2863 - val_mean_squared_error: 0.2863
#
# Epoch 00098: val_loss improved from 0.29439 to 0.28627, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 99/100
#  - 0s - loss: 0.0501 - mean_squared_error: 0.0501 - val_loss: 0.2783 - val_mean_squared_error: 0.2783
#
# Epoch 00099: val_loss improved from 0.28627 to 0.27834, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5
# Epoch 100/100
#  - 0s - loss: 0.0486 - mean_squared_error: 0.0486 - val_loss: 0.2706 - val_mean_squared_error: 0.2706
#
# Epoch 00100: val_loss improved from 0.27834 to 0.27060, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 10_105_ohlc.hdf5

# %%
file_list = os.listdir(file_path)
# print(file_list)
# breakpoint
file = file_list[-4]
ohlcv_reg = pd.read_excel(file_path + file, index_col=0)
# print(ohlcv_reg.iloc[:, [1, -5]])
# breakpoint

#     X_data : idl 만큼의 close? (일단),    Y_data : reg
#     실시간으로 reg의 형태가 machine learning으로는 고정되지 않기 때문에,
#     먼저 고정을 시키고, deep learning을 이용해 실시간으로 고정된 regression 결과를 뽑아낼 수 있는지 확인한다.
#     충분히 가능성 있다.     #

#         reg_target = close인 경우 앞의 데이터가 산다.       #  close/ close_reg
ohlcv_reg = ohlcv_reg.values[sum(ohlcv_reg.MACD_Signal.isna()):, :]
reg_target = ohlcv_reg[:, [-7]].astype(np.float32)
reg_result = ohlcv_reg[:, [-5]].astype(np.float32)
# ohlcv_data = ohlcv_reg.values[sum(ohlcv_reg.MACD_Signal.isna()):, :-4].astype(np.float)
# print(np.sum(np.isnan(ohlcv_data), axis=0))
# breakpoint
x = np.arange(len(reg_target)).reshape(-1, 1)
y = reg_target.reshape(-1, 1)
scaler_x = StandardScaler()
scaler_y = StandardScaler()
x = scaler_x.fit_transform(x)
y = scaler_y.fit_transform(y)
svr.fit(x, y)
reg_result = svr.predict(x).reshape(-1, 1)

scaler_x = StandardScaler()
scaler_y = StandardScaler()
reg_target = scaler_x.fit_transform(reg_target)
reg_result = scaler_y.fit_transform(reg_result)
# reg_target = max_abs_scaler(reg_target)
# reg_result = max_abs_scaler(reg_result)
# print(reg_target, reg_result)
# breakpoint

dataX, dataY = list(), list()
for i in range(input_data_length, len(reg_target)):

  # group_x = reg_target[i - input_data_length: i]
  group_x = reg_target[i + 1 - input_data_length: i + 1]
  group_y = reg_result[i]
  # print(group_x[0])
  # quit()

  #   데이터 값에 결측치가 존재하는 경우 #
  if sum(sum(np.isnan(group_x))) > 0:
      continue

  dataX.append(group_x)  # dataX 리스트에 추가
  dataY.append(group_y)

Made_X = np.array(dataX)
Made_Y = np.array(dataY)

# from keras.models import load_model
# model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_ohlc.hdf5' % (input_data_length, model_num))

pred_reg = model.predict(Made_X)

plt.plot(Made_Y, color='r', label='Y_test')
plt.plot(reg_target[input_data_length:], color='m', label='MACD_OSC')
plt.plot(pred_reg, color='b',  label='pred_reg')
plt.legend(loc='upper right')

span_list = list()
for i in range(1, len(pred_reg)):
    if pred_reg[i - 1] < pred_reg[i]:
        span_list.append((i, i + 1))
for i in range(len(span_list)):
    plt.axvspan(span_list[i][0], span_list[i][1], facecolor='b', alpha=0.5)

plt.show()
