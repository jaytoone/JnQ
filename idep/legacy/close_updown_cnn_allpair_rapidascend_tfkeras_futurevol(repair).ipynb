# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Requirements**

# %%
# %tensorflow_version 1.x

import tensorflow as tf
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.2.0
# 2.3.0-tf

# %%
# from tensorflow import keras
import keras
keras.__version__
# from tensorflow.keras.utils import np_utils
# Out:
# '2.5.0'

# %%
# !pip install tensorflow==2.2.0

# !pip install tensorflow==2.1.0
# !pip install keras==2.3.1

# !pip install statsmodels==0.12.2

# !pip install h5py==2.10.0


# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### load file list

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### custom model

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

# import tensorflow as tf
# import tensorflow.keras

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

# from tensorflow.keras.utils import plot_model
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model, Sequential
import tensorflow.keras.layers as layers
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model

# %%
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 2.4.1
# 2.4.0

# %% [markdown]
# ### ver check

# %%
import h5py

# model_name = 'classifier_%s_cnn_updown_rascend_285_%s_tvnon_shuffle.h5' % (45, "MKRUSDT")
model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (45, "ETHUSDT")

ckpt_path = current_path + 'ckpt/'

f = h5py.File(ckpt_path + model_name, 'r')
print(f.attrs.get('keras_version'))
# print(f.attrs.get('tensorflow_version'))

for att in f.attrs:
  print(f.attrs.get(att))

# %% [markdown]
# ### all in one loop

# %%
print(ohlcv['close'].pct_change().head())
print(ohlcv['close'] / ohlcv['close'].shift(1).head() - 1)

# %%
# from tensorflow.keras.utils import to_categorical

# %%
from funcs_indicator import *
import matplotlib.pyplot as plt

# import mpl_finance as mf


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None


#           load saved npy & trained model        #
load_npy = True
load_model = False


seed = 1
random_state = 201
np.random.seed(seed)

fee = 0.0006
lvrg = 5

for i in range(len(candis)):

  keys = [candis[i]]

  if 'eth'.upper() not in candis[i]:
    continue

  # if 'comp'.upper() not in candis[i]:
  #   continue

  for key in keys:  
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))

        
    #       long      #
    pr = (ohlcv['close'].pct_change() - fee) * lvrg + 1    

    #       long liqudation     #
    lq = (ohlcv['low'] / ohlcv['close'].shift(1) - fee - 1) * lvrg + 1

    #       short       # <-- 이거를 단순히 minus 를 붙여도 되는걸까
    s_pr = (-ohlcv['close'].pct_change() - fee) * lvrg + 1

    #       short liqudation     #
    # s_lq = (ohlcv['high'] / ohlcv['close'].shift(1) - fee) * lvrg + 1
    

    #       fill na with 1.0      #
    # pr = np.where(np.isnan(pr), 1, pr)
    # print(len(pr))
    # print("len(pr[np.isnan(pr)]) :", len(pr[np.isnan(pr)]))
    # print("np.sum(np.isnan(pr)) :", np.sum(np.isnan(pr)))
    
    # sliced_ohlcv = ohlcv[np.sum(np.isnan(pr))]
    # print(sliced_ohlcv.head())
    # break
    # s_pr = np.where(np.isnan(s_pr), 1, pr)
    # lq = np.where(np.isnan(lq), 1, lq)


    #       set lq      #
    # pr = np.where((pr != 1) & (lq <= 0), 0, pr)

    # print("len(pr[pr < 0]) :", len(pr[pr < 0]))
    # break

    org_wr = len(pr[pr > 1]) / len(pr[pr != 1])

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(pr))
    plt.title("%s\norg_wr : %.3f\n acc_pr : %.3f" % (key, org_wr, np.cumprod(pr)[-1]))


    #                    strat                   #

    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) < ohlcv['close'].shift(3)), pr, 1)


    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
    #                     (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
    #                     (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)), pr, 1)


    strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
                        (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
                        (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
                        (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)) & 
                        (ohlcv['close'].shift(5) < ohlcv['close'].shift(6)), pr, 1)
    
    # strat_pr = np.where((ohlcv['high'].shift(2) > ohlcv['high'].shift(3))& 
    #                     (ohlcv['close'].shift(1) > ohlcv['close'].shift(2)), pr, 1)


    wr = len(strat_pr[strat_pr > 1]) / len(strat_pr[strat_pr != 1])

    plt.subplot(122)
    plt.plot(np.cumprod(strat_pr))
    plt.title("%s\norg_wr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr, np.cumprod(strat_pr)[-1]))


    # #                  sl cut                #
    # sl_line = ohlcv['low'].rolling(250).min().shift(1)
    # # sl_line = ohlcv['low'].shift(1)

    # strat_pr_sl = np.where((strat_pr != 1) & (sl_line > ohlcv['low']), 
    #                      1 + lvrg * (sl_line / ohlcv['close'].shift(1) - 1 - fee), strat_pr)


    # wr_sl = len(strat_pr_sl[strat_pr_sl > 1]) / len(strat_pr_sl[strat_pr_sl != 1])
    # # wl_pr_ratio = np.mean(strat_pr[strat_pr > 1]) / np.mean(strat_pr[strat_pr < 1])
    # # wl_pr_ratio = np.cumprod(strat_pr[strat_pr > 1])[-1] / np.cumprod(strat_pr[strat_pr < 1])[-1]

    # plt.subplot(122)
    # plt.plot(np.cumprod(strat_pr_sl))
    # plt.title("%s\norg_pr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr_sl, np.cumprod(strat_pr_sl)[-1]))


    plt.show()
    # break

    period = 45
    symbol_name = key.split(' ')[1].split('.')[0]      

    x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_wvol_%s_tssplit.npy' % (period, symbol_name)
    pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_wvol_%s_tssplit.npy' % (period, symbol_name)
    index_save_path = current_path + 'npy/' + '%s_cnn_updown_index_train_rascend_ohlcv_wvol_%s_tssplit.npy' % (period, symbol_name)



    if not load_npy:

      from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
      from sklearn.model_selection import train_test_split
      from datetime import datetime

      from funcs_indicator import *

      def min_max_scale(npy_x):

        return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[np.sum(np.isnan(pr)):]

      sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

      #       scale with price    #
      ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

      ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
      sar = lucid_sar(sliced_ohlcv)
      ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
      senkou1, senkou2 = ichimoku(sliced_ohlcv)

      #     min max scale   #
      # vol = ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]
      vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

      pr_list = pr[np.sum(np.isnan(pr)):]
      print("len(ohlc) :", len(ohlc))
      print("len(pr_list) :", len(pr_list))

      print("ohlc.index[0] :", ohlc.index[0])
      print("vol.index[0] :", vol.index[0])
      # break


      #       set params    #
      period = 45
      key_i = i

      plotting = True

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(ohlc)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          # temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

          temp_close = min_max_scale(temp_ohlc[:, [3]])    

          price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          ind_temp_ohlc = min_max_scale(temp_ohlc)
          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


          if plotting:

            plt.plot(ind_temp_ohlc)
            plt.show()
            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          #                   feature selection                   #        
          temp_data = np.hstack((ind_temp_ohlc, temp_vol))

          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          # temp_data = temp_ohlc[:, [3]]
          # temp_data = ind_temp_ohlc[:, [3]]
          # temp_data = temp_close

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      # input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)


      # _, row, col, _ = input_x.shape
      # _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      #                 don't shuffle timeseries data                 #
      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)


      np.save(x_save_path, x_train)
      np.save(x_save_path.replace('x_train', 'x_val'), x_val)
      np.save(x_save_path.replace('x_train', 'x_test'), x_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('x series saved !')

      np.save(pr_save_path, pr_train)
      np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
      np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
      # np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
      print('pr series saved !')
      
      np.save(index_save_path, index_train)
      np.save(index_save_path.replace('index_train', 'index_val'), index_val)
      np.save(index_save_path.replace('index_train', 'index_test'), index_test)
      print('index series saved !')

    else:
      
      x_train = np.load(x_save_path)
      x_val = np.load(x_save_path.replace('x_train', 'x_val'))
      x_test = np.load(x_save_path.replace('x_train', 'x_test'))
      print('x series loaded !')


      pr_train = np.load(pr_save_path)
      pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
      pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
      print('y series loaded !')


      index_train = np.load(index_save_path, allow_pickle=True)
      index_val = np.load(index_save_path.replace('index_train', 'index_val'), allow_pickle=True)
      index_test = np.load(index_save_path.replace('index_train', 'index_test'), allow_pickle=True)
      print('index series loaded !')




    #       pr_thresh by percentage 0.285     #
    plt.plot(pr)
    plt.show()
    
    sorted_pr = sorted(pr, reverse=True)
    pct = 0.285
    len_pct = int(len(pr) * pct)
    pr_thresh = sorted_pr[len_pct]
    print("pr_thresh :", pr_thresh)

    # from tensorflow.keras.utils import np_utils
    from tensorflow.keras.utils import to_categorical
    # from tensorflow.keras.utils.np_utils import to_categorical

    from sklearn.utils import class_weight


    def class_ratio(in_list):

      return in_list / in_list[1]
      
    y_train = np.where(pr_train > pr_thresh, 1, 0)
    y_test = np.where(pr_test > pr_thresh, 1, 0)
    y_val = np.where(pr_val > pr_thresh, 1, 0)

    print('x_train.shape :', x_train.shape)
    print('x_test.shape :', x_test.shape)
    print('x_val.shape :', x_val.shape)
    print('y_train.shape :', y_train.shape)
    print('y_test.shape :', y_test.shape)
    print('y_val.shape :', y_val.shape)

    # try:
    print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
    print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
    print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

    # except Exception as e:
      # print(e)

    label = y_train.reshape(-1, )
    class_weights = class_weight.compute_class_weight('balanced', 
                                                        classes=np.unique(label),
                                                        y=label)
    class_weights = dict(enumerate(class_weights))
    print('class_weights :', class_weights)

    # sample_weight = np.ones(shape=(len(y_train),))
    # sample_weight[(y_train == 1).reshape(-1,)] = 1.5
    # print('sample_weight[:20] :', sample_weight[:20])


    print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
    print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
    print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

    print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
    print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
    print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

    num_classes = 2
    
    # y_train_ohe = np_utils.to_categorical(y_train, num_classes)
    # y_val_ohe = np_utils.to_categorical(y_val, num_classes)
    # y_test_ohe = np_utils.to_categorical(y_test, num_classes)
    
    y_train_ohe = to_categorical(y_train, num_classes)
    y_val_ohe = to_categorical(y_val, num_classes)
    y_test_ohe = to_categorical(y_test, num_classes)
    print('y_train_ohe.shape :', y_train_ohe.shape)
    print('y_val_ohe.shape :', y_val_ohe.shape)
    print('y_test_ohe.shape :', y_test_ohe.shape)

    from tensorflow.keras.preprocessing.image import ImageDataGenerator 
    # from tensorflow.keras.preprocessing.image import ImageDataGenerator 

    datagen = ImageDataGenerator( 
        # rotation_range = 45,
        # zoom_range = 0.5,
        # shear_range = 0.5,
        # horizontal_flip = True,
        # vertical_flip = True,
        # width_shift_range=0.5,
        # height_shift_range=0.5,
        # fill_mode = 'nearest'
        )

    valgen = ImageDataGenerator( 
        )

    datagen.fit(x_train)
    valgen.fit(x_val)


    batch_size = 512


    for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

        plt.suptitle("train x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break

    for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

        plt.suptitle("val x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break
        
    train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
    val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
    # break

    

    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'

    # batch_size = 512

    K.clear_session()


    # model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_tf210_lrcheck_%s.h5' % (period, symbol_name)
    # model_name = 'classifier_%s_cnn_updown_rascend_285_tf241_lrcheck_%s.h5' % (period, symbol_name)
    model_name = 'classifier_%s_cnn_updown_rascend_285_tf220_lrcheck_%s.h5' % (period, symbol_name)



    if not load_model:

      # from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
      from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

      model = FER_Model(input_shape=x_train.shape[1:])
      opt = Adam(lr=1e-2, decay=1e-4)
      # opt = Adam(lr=1e-5, decay=5e-6)
      # opt = Adam(lr=0.001, decay=0.0005)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir=board_path,
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_loss', patience=500)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]
      # callbacks_list = [checkpoint, checkpoint2]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 2000
      history = model.fit(train_flow, 
                          steps_per_epoch=len(x_train) / batch_size, 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=val_flow,  
                          validation_steps=len(x_val) / batch_size,
                          shuffle=False)
      
    
    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'


    model = tf.keras.models.load_model(ckpt_path + model_name)

    test_result = model.predict(x_test)
    # test_result = model.predict(test_set)

    print('test_result.shape :', test_result.shape)
    # print('pr_val.shape :', pr_val.shape)

    y_score = test_result[:, [1]]
    print('y_test[:5] :', y_test.reshape(-1,)[:5])
    # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
    print('y_score[:5] :', y_score[:5])
    # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

    print('y_test.shape :', y_test.shape)
    print('y_score.shape :', y_score.shape)

    print('len(y_test) :', len(y_test))

    #     precision recall curve   #
    precision, recall, threshold = precision_recall_curve(y_test, y_score)
    precision, recall = precision[:-1], recall[:-1]

    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    plt.show()
    # print(y_pred)


    # threshold = [0.65]
    # print('threshold :', threshold)
    # break

    acc_pr_bythr = []
    new_thresh = []

    for thresh in threshold:
      
      # if thresh < 0.5:
      #     continue

      y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
      # print('y_pred.shape :', y_pred.shape)
      # print('y_pred :', y_pred)

      #     compare precision     #

      # print('precision :', precision_score(y_test, y_pred))
      # print('recall :', recall_score(y_test, y_pred))
      # print()

      # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
      # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

      # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
      # # plt.show()  
      # print()

      #     check win-ratio improvement     #
      cmat = confusion_matrix(y_test, y_pred)
      # print(cmat)
      # print(np.sum(cmat, axis=1))

      test_size = len(y_test)
      test_pr_list = pr_test
      # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

      org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
      ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
      # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

      # print('pr_test.shape :', pr_test.shape)

      # print(y_pred)
      # print(test_pr_list)

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
      # print('pred_pr_list.shape :', pred_pr_list.shape)

      # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
      #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
      #   print('thresh :', thresh)
        
      # if len(threshold) == 1:
    #   plt.figure(figsize=(10, 5))
    #   plt.subplot(121)
    #   plt.plot(np.cumprod(test_pr_list))
    #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
    # # plt.show()

    #   plt.subplot(122)
    #   plt.plot(np.cumprod(pred_pr_list))
    #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
    #   plt.show()


      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)


    print('acc_pr_bythr :', acc_pr_bythr)

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    # plt.show()
    plt.subplot(122)
    plt.plot(new_thresh, acc_pr_bythr)
    plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
    plt.title(symbol_name)
    plt.show()
# Out:
# start_stamp : 0
# len(ohlcv) : 18048
# x series loaded !
# y series loaded !
# index series loaded !
# pr_thresh : 1.010013727383401
# x_train.shape : (10755, 45, 5, 3)
# x_test.shape : (3586, 45, 5, 3)
# x_val.shape : (3585, 45, 5, 3)
# y_train.shape : (10755, 1)
# y_test.shape : (3586, 1)
# y_val.shape : (3585, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([7678, 3077])) [2.49528762 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2575, 1010])) [2.54950495 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2576, 1010])) [2.55049505 1.        ]
# class_weights : {0: 0.7003777025266996, 1: 1.7476438089047774}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10755, 2)
# y_val_ohe.shape : (3585, 2)
# y_test_ohe.shape : (3586, 2)
# Epoch 1/2000
#
# Epoch 00001: val_loss improved from inf to 719.90710, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 2s - loss: 1216.3353 - accuracy: 0.4775 - val_loss: 719.9071 - val_accuracy: 0.2817
# Epoch 2/2000
#
# Epoch 00002: val_loss improved from 719.90710 to 13.56255, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 1s - loss: 211.2661 - accuracy: 0.5169 - val_loss: 13.5626 - val_accuracy: 0.3049
# Epoch 3/2000
#
# Epoch 00003: val_loss did not improve from 13.56255
# 22/21 - 1s - loss: 82.8274 - accuracy: 0.4841 - val_loss: 150.4306 - val_accuracy: 0.2817
# Epoch 4/2000
#
# Epoch 00004: val_loss did not improve from 13.56255
# 22/21 - 1s - loss: 62.2273 - accuracy: 0.4942 - val_loss: 65.4573 - val_accuracy: 0.7183
# Epoch 5/2000
#
# Epoch 00005: val_loss improved from 13.56255 to 11.49405, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 1s - loss: 62.9919 - accuracy: 0.5310 - val_loss: 11.4940 - val_accuracy: 0.2845
# Epoch 6/2000
#
# Epoch 00006: val_loss improved from 11.49405 to 1.14135, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 1s - loss: 6.4515 - accuracy: 0.4998 - val_loss: 1.1414 - val_accuracy: 0.6605
# Epoch 7/2000
#
# Epoch 00007: val_loss improved from 1.14135 to 1.05351, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 1s - loss: 1.0798 - accuracy: 0.5201 - val_loss: 1.0535 - val_accuracy: 0.3551
# Epoch 8/2000
#
# Epoch 00008: val_loss improved from 1.05351 to 0.85331, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 2s - loss: 0.8004 - accuracy: 0.5233 - val_loss: 0.8533 - val_accuracy: 0.7177
# Epoch 9/2000
#
# Epoch 00009: val_loss did not improve from 0.85331
# 22/21 - 1s - loss: 0.9965 - accuracy: 0.5302 - val_loss: 1.1839 - val_accuracy: 0.2932
# Epoch 10/2000
#
# Epoch 00010: val_loss improved from 0.85331 to 0.75768, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 1s - loss: 0.7622 - accuracy: 0.5163 - val_loss: 0.7577 - val_accuracy: 0.7177
# Epoch 11/2000
#
# Epoch 00011: val_loss did not improve from 0.75768
# 22/21 - 1s - loss: 0.8437 - accuracy: 0.5208 - val_loss: 1.4033 - val_accuracy: 0.2834
# Epoch 12/2000
#
# Epoch 00012: val_loss did not improve from 0.75768
# 22/21 - 1s - loss: 0.8002 - accuracy: 0.5228 - val_loss: 0.8670 - val_accuracy: 0.3657
# Epoch 13/2000
#
# Epoch 00013: val_loss did not improve from 0.75768
# 22/21 - 1s - loss: 0.7471 - accuracy: 0.5079 - val_loss: 0.8020 - val_accuracy: 0.3729
# Epoch 14/2000
#
# Epoch 00014: val_loss improved from 0.75768 to 0.75501, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 1s - loss: 0.7066 - accuracy: 0.5269 - val_loss: 0.7550 - val_accuracy: 0.4446
# Epoch 15/2000
#
# Epoch 00015: val_loss improved from 0.75501 to 0.61490, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 1s - loss: 0.7070 - accuracy: 0.5308 - val_loss: 0.6149 - val_accuracy: 0.6993
# Epoch 16/2000
#
# Epoch 00016: val_loss did not improve from 0.61490
# 22/21 - 1s - loss: 0.7061 - accuracy: 0.5291 - val_loss: 0.7070 - val_accuracy: 0.5227
# Epoch 17/2000
#
# Epoch 00017: val_loss did not improve from 0.61490
# 22/21 - 1s - loss: 0.6947 - accuracy: 0.5367 - val_loss: 2.5364 - val_accuracy: 0.2815
# Epoch 18/2000
#
# Epoch 00018: val_loss did not improve from 0.61490
# 22/21 - 1s - loss: 1.0075 - accuracy: 0.4956 - val_loss: 1.3331 - val_accuracy: 0.2848
# Epoch 19/2000
#
# Epoch 00019: val_loss did not improve from 0.61490
# 22/21 - 1s - loss: 0.8419 - accuracy: 0.5148 - val_loss: 0.6899 - val_accuracy: 0.7188
# Epoch 20/2000
#
# Epoch 00020: val_loss did not improve from 0.61490
# 22/21 - 1s - loss: 0.8178 - accuracy: 0.5242 - val_loss: 0.6224 - val_accuracy: 0.6974
# Epoch 21/2000
#
# Epoch 00021: val_loss improved from 0.61490 to 0.60541, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 1s - loss: 0.7406 - accuracy: 0.5497 - val_loss: 0.6054 - val_accuracy: 0.7105
# Epoch 22/2000
#
# Epoch 00022: val_loss improved from 0.60541 to 0.59914, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 1s - loss: 0.7172 - accuracy: 0.5563 - val_loss: 0.5991 - val_accuracy: 0.7149
# Epoch 23/2000
#
# Epoch 00023: val_loss did not improve from 0.59914
# 22/21 - 1s - loss: 0.7548 - accuracy: 0.5530 - val_loss: 0.6367 - val_accuracy: 0.6789
# Epoch 24/2000
#
# Epoch 00024: val_loss did not improve from 0.59914
# 22/21 - 1s - loss: 0.7068 - accuracy: 0.5660 - val_loss: 0.9614 - val_accuracy: 0.3213
# Epoch 25/2000
#
# Epoch 00025: val_loss did not improve from 0.59914
# 22/21 - 1s - loss: 0.7387 - accuracy: 0.5381 - val_loss: 0.8260 - val_accuracy: 0.3771
# Epoch 26/2000
#
# Epoch 00026: val_loss did not improve from 0.59914
# 22/21 - 1s - loss: 0.6970 - accuracy: 0.5411 - val_loss: 0.8134 - val_accuracy: 0.3559
# Epoch 27/2000
#
# Epoch 00027: val_loss did not improve from 0.59914
# 22/21 - 1s - loss: 0.6835 - accuracy: 0.5581 - val_loss: 0.6278 - val_accuracy: 0.6809
# Epoch 28/2000
#
# Epoch 00028: val_loss did not improve from 0.59914
# 22/21 - 1s - loss: 0.6852 - accuracy: 0.5639 - val_loss: 1.2878 - val_accuracy: 0.2865
# Epoch 29/2000
#
# Epoch 00029: val_loss improved from 0.59914 to 0.59578, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 1s - loss: 0.8019 - accuracy: 0.5282 - val_loss: 0.5958 - val_accuracy: 0.7163
# Epoch 30/2000
#
# Epoch 00030: val_loss did not improve from 0.59578
# 22/21 - 1s - loss: 0.7128 - accuracy: 0.5405 - val_loss: 0.7250 - val_accuracy: 0.4812
# Epoch 31/2000
#
# Epoch 00031: val_loss improved from 0.59578 to 0.58995, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 1s - loss: 0.6791 - accuracy: 0.5865 - val_loss: 0.5900 - val_accuracy: 0.7146
# Epoch 32/2000
#
# Epoch 00032: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.6921 - accuracy: 0.5858 - val_loss: 0.7363 - val_accuracy: 0.4695
# Epoch 33/2000
#
# Epoch 00033: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.6809 - accuracy: 0.5589 - val_loss: 0.6990 - val_accuracy: 0.5425
# Epoch 34/2000
#
# Epoch 00034: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.6761 - accuracy: 0.5735 - val_loss: 0.8710 - val_accuracy: 0.3261
# Epoch 35/2000
#
# Epoch 00035: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.6948 - accuracy: 0.5420 - val_loss: 0.6241 - val_accuracy: 0.6798
# Epoch 36/2000
#
# Epoch 00036: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.6944 - accuracy: 0.5821 - val_loss: 0.5953 - val_accuracy: 0.7110
# Epoch 37/2000
#
# Epoch 00037: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.6890 - accuracy: 0.5775 - val_loss: 0.6285 - val_accuracy: 0.6815
# Epoch 38/2000
#
# Epoch 00038: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.6760 - accuracy: 0.5877 - val_loss: 0.8678 - val_accuracy: 0.3294
# Epoch 39/2000
#
# Epoch 00039: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.7207 - accuracy: 0.5206 - val_loss: 0.6151 - val_accuracy: 0.6826
# Epoch 40/2000
#
# Epoch 00040: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.7050 - accuracy: 0.5641 - val_loss: 0.6984 - val_accuracy: 0.5512
# Epoch 41/2000
#
# Epoch 00041: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.6829 - accuracy: 0.5629 - val_loss: 0.6567 - val_accuracy: 0.6167
# Epoch 42/2000
#
# Epoch 00042: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.6708 - accuracy: 0.5855 - val_loss: 0.7028 - val_accuracy: 0.5325
# Epoch 43/2000
#
# Epoch 00043: val_loss did not improve from 0.58995
# 22/21 - 1s - loss: 0.6779 - accuracy: 0.5689 - val_loss: 0.7169 - val_accuracy: 0.5038
# Epoch 44/2000
#
# Epoch 00044: val_loss improved from 0.58995 to 0.58106, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_285_tf220_lrcheck_ETHUSDT.h5
# 22/21 - 2s - loss: 0.6783 - accuracy: 0.5641 - val_loss: 0.5811 - val_accuracy: 0.7211
# Epoch 45/2000
#
# Epoch 00045: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7061 - accuracy: 0.5570 - val_loss: 0.7102 - val_accuracy: 0.5247
# Epoch 46/2000
#
# Epoch 00046: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.6829 - accuracy: 0.5795 - val_loss: 1.3887 - val_accuracy: 0.2834
# Epoch 47/2000
#
# Epoch 00047: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 4.6255 - accuracy: 0.4904 - val_loss: 84.9837 - val_accuracy: 0.7183
# Epoch 48/2000
#
# Epoch 00048: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1638.5745 - accuracy: 0.4780 - val_loss: 10968.7607 - val_accuracy: 0.7183
# Epoch 49/2000
#
# Epoch 00049: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1297753.2500 - accuracy: 0.4790 - val_loss: 287517.1250 - val_accuracy: 0.7183
# Epoch 50/2000
#
# Epoch 00050: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1614596.8750 - accuracy: 0.5401 - val_loss: 411273.1250 - val_accuracy: 0.2817
# Epoch 51/2000
#
# Epoch 00051: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 786697.9375 - accuracy: 0.4923 - val_loss: 221717.1250 - val_accuracy: 0.2817
# Epoch 52/2000
#
# Epoch 00052: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 80033.5391 - accuracy: 0.4669 - val_loss: 15538.8408 - val_accuracy: 0.7183
# Epoch 53/2000
#
# Epoch 00053: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 23649.9746 - accuracy: 0.5248 - val_loss: 2232.0178 - val_accuracy: 0.7183
# Epoch 54/2000
#
# Epoch 00054: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 10589.3047 - accuracy: 0.5034 - val_loss: 21920.7617 - val_accuracy: 0.2859
# Epoch 55/2000
#
# Epoch 00055: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 4818.0093 - accuracy: 0.5077 - val_loss: 10038.4492 - val_accuracy: 0.2817
# Epoch 56/2000
#
# Epoch 00056: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 7781.9878 - accuracy: 0.5008 - val_loss: 3094.8750 - val_accuracy: 0.2817
# Epoch 57/2000
#
# Epoch 00057: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 2827.5859 - accuracy: 0.4660 - val_loss: 1897.7740 - val_accuracy: 0.7183
# Epoch 58/2000
#
# Epoch 00058: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 3442.7441 - accuracy: 0.5012 - val_loss: 1900.3169 - val_accuracy: 0.7183
# Epoch 59/2000
#
# Epoch 00059: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1253.8381 - accuracy: 0.5094 - val_loss: 1704.0613 - val_accuracy: 0.2817
# Epoch 60/2000
#
# Epoch 00060: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1118.5758 - accuracy: 0.4930 - val_loss: 1712.4972 - val_accuracy: 0.2817
# Epoch 61/2000
#
# Epoch 00061: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 600.5323 - accuracy: 0.4939 - val_loss: 166.8973 - val_accuracy: 0.4081
# Epoch 62/2000
#
# Epoch 00062: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 164.1555 - accuracy: 0.4859 - val_loss: 127.9679 - val_accuracy: 0.7091
# Epoch 63/2000
#
# Epoch 00063: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 126.6414 - accuracy: 0.5238 - val_loss: 77.6923 - val_accuracy: 0.6932
# Epoch 64/2000
#
# Epoch 00064: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 111.2271 - accuracy: 0.5158 - val_loss: 488.7527 - val_accuracy: 0.2831
# Epoch 65/2000
#
# Epoch 00065: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 236.2532 - accuracy: 0.4825 - val_loss: 109.5460 - val_accuracy: 0.7113
# Epoch 66/2000
#
# Epoch 00066: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 177.8043 - accuracy: 0.5326 - val_loss: 420.7990 - val_accuracy: 0.2831
# Epoch 67/2000
#
# Epoch 00067: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 176.4715 - accuracy: 0.4859 - val_loss: 151.0985 - val_accuracy: 0.7169
# Epoch 68/2000
#
# Epoch 00068: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 121.9599 - accuracy: 0.5132 - val_loss: 38.3025 - val_accuracy: 0.6179
# Epoch 69/2000
#
# Epoch 00069: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 46.9099 - accuracy: 0.5052 - val_loss: 151.0633 - val_accuracy: 0.2929
# Epoch 70/2000
#
# Epoch 00070: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 60.1922 - accuracy: 0.5141 - val_loss: 261.8097 - val_accuracy: 0.2845
# Epoch 71/2000
#
# Epoch 00071: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 81.3491 - accuracy: 0.5046 - val_loss: 345.7524 - val_accuracy: 0.2828
# Epoch 72/2000
#
# Epoch 00072: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 160.2535 - accuracy: 0.4757 - val_loss: 231.5918 - val_accuracy: 0.7183
# Epoch 73/2000
#
# Epoch 00073: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 178.9203 - accuracy: 0.5158 - val_loss: 43.6047 - val_accuracy: 0.4444
# Epoch 74/2000
#
# Epoch 00074: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 32.6572 - accuracy: 0.5121 - val_loss: 119.1035 - val_accuracy: 0.7177
# Epoch 75/2000
#
# Epoch 00075: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 214.5335 - accuracy: 0.4971 - val_loss: 137.8449 - val_accuracy: 0.7180
# Epoch 76/2000
#
# Epoch 00076: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 99.7745 - accuracy: 0.5185 - val_loss: 48.9350 - val_accuracy: 0.7132
# Epoch 77/2000
#
# Epoch 00077: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 126.0627 - accuracy: 0.5291 - val_loss: 257.0653 - val_accuracy: 0.2848
# Epoch 78/2000
#
# Epoch 00078: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 114.6983 - accuracy: 0.4997 - val_loss: 80.7691 - val_accuracy: 0.3386
# Epoch 79/2000
#
# Epoch 00079: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 86.0592 - accuracy: 0.4824 - val_loss: 53.7589 - val_accuracy: 0.3955
# Epoch 80/2000
#
# Epoch 00080: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 48.5062 - accuracy: 0.5021 - val_loss: 115.3579 - val_accuracy: 0.2993
# Epoch 81/2000
#
# Epoch 00081: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 52.7772 - accuracy: 0.5086 - val_loss: 53.7845 - val_accuracy: 0.7152
# Epoch 82/2000
#
# Epoch 00082: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 116.1141 - accuracy: 0.5138 - val_loss: 132.6864 - val_accuracy: 0.2859
# Epoch 83/2000
#
# Epoch 00083: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 55.4410 - accuracy: 0.4887 - val_loss: 20.1151 - val_accuracy: 0.6530
# Epoch 84/2000
#
# Epoch 00084: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 43.5213 - accuracy: 0.5273 - val_loss: 68.5148 - val_accuracy: 0.7174
# Epoch 85/2000
#
# Epoch 00085: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 92.0319 - accuracy: 0.5208 - val_loss: 47.4851 - val_accuracy: 0.3615
# Epoch 86/2000
#
# Epoch 00086: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 44.1210 - accuracy: 0.5136 - val_loss: 52.7822 - val_accuracy: 0.7177
# Epoch 87/2000
#
# Epoch 00087: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 41.4190 - accuracy: 0.5179 - val_loss: 46.1016 - val_accuracy: 0.7149
# Epoch 88/2000
#
# Epoch 00088: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 41.0450 - accuracy: 0.5124 - val_loss: 14.3182 - val_accuracy: 0.6455
# Epoch 89/2000
#
# Epoch 00089: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 23.0874 - accuracy: 0.5267 - val_loss: 32.8689 - val_accuracy: 0.3501
# Epoch 90/2000
#
# Epoch 00090: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 48.9388 - accuracy: 0.4895 - val_loss: 109.6847 - val_accuracy: 0.7185
# Epoch 91/2000
#
# Epoch 00091: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 149.7281 - accuracy: 0.5125 - val_loss: 18.4268 - val_accuracy: 0.6764
# Epoch 92/2000
#
# Epoch 00092: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 33.0567 - accuracy: 0.5305 - val_loss: 40.5198 - val_accuracy: 0.7144
# Epoch 93/2000
#
# Epoch 00093: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 27.4855 - accuracy: 0.5306 - val_loss: 12.3525 - val_accuracy: 0.6686
# Epoch 94/2000
#
# Epoch 00094: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 25.1018 - accuracy: 0.5326 - val_loss: 133.7460 - val_accuracy: 0.2826
# Epoch 95/2000
#
# Epoch 00095: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 44.1730 - accuracy: 0.5144 - val_loss: 26.9500 - val_accuracy: 0.7102
# Epoch 96/2000
#
# Epoch 00096: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 67.0298 - accuracy: 0.5098 - val_loss: 174.7159 - val_accuracy: 0.2820
# Epoch 97/2000
#
# Epoch 00097: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 116.4939 - accuracy: 0.4882 - val_loss: 223.0437 - val_accuracy: 0.2817
# Epoch 98/2000
#
# Epoch 00098: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 121.3161 - accuracy: 0.4800 - val_loss: 62.3550 - val_accuracy: 0.7079
# Epoch 99/2000
#
# Epoch 00099: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 63.7862 - accuracy: 0.5305 - val_loss: 18.9886 - val_accuracy: 0.5155
# Epoch 100/2000
#
# Epoch 00100: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 31.5977 - accuracy: 0.5268 - val_loss: 190.9808 - val_accuracy: 0.2820
# Epoch 101/2000
#
# Epoch 00101: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 102.4362 - accuracy: 0.4775 - val_loss: 107.6166 - val_accuracy: 0.2979
# Epoch 102/2000
#
# Epoch 00102: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 56.4919 - accuracy: 0.5035 - val_loss: 61.3776 - val_accuracy: 0.7144
# Epoch 103/2000
#
# Epoch 00103: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 60.1424 - accuracy: 0.5121 - val_loss: 35.4782 - val_accuracy: 0.3869
# Epoch 104/2000
#
# Epoch 00104: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 24.1423 - accuracy: 0.5197 - val_loss: 11.1380 - val_accuracy: 0.6717
# Epoch 105/2000
#
# Epoch 00105: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 48.8880 - accuracy: 0.5159 - val_loss: 114.4692 - val_accuracy: 0.2826
# Epoch 106/2000
#
# Epoch 00106: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 59.8924 - accuracy: 0.5036 - val_loss: 66.2238 - val_accuracy: 0.7185
# Epoch 107/2000
#
# Epoch 00107: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 47.3685 - accuracy: 0.5319 - val_loss: 24.8224 - val_accuracy: 0.3782
# Epoch 108/2000
#
# Epoch 00108: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 30.9747 - accuracy: 0.5100 - val_loss: 96.9674 - val_accuracy: 0.2823
# Epoch 109/2000
#
# Epoch 00109: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 49.8044 - accuracy: 0.5108 - val_loss: 65.3997 - val_accuracy: 0.2951
# Epoch 110/2000
#
# Epoch 00110: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 32.3860 - accuracy: 0.5213 - val_loss: 11.5387 - val_accuracy: 0.5322
# Epoch 111/2000
#
# Epoch 00111: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 20.2861 - accuracy: 0.5440 - val_loss: 11.2815 - val_accuracy: 0.6887
# Epoch 112/2000
#
# Epoch 00112: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 12.1076 - accuracy: 0.5430 - val_loss: 15.0104 - val_accuracy: 0.7110
# Epoch 113/2000
#
# Epoch 00113: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 13.7880 - accuracy: 0.5332 - val_loss: 30.8954 - val_accuracy: 0.7174
# Epoch 114/2000
#
# Epoch 00114: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 36.9530 - accuracy: 0.5331 - val_loss: 69.8177 - val_accuracy: 0.2845
# Epoch 115/2000
#
# Epoch 00115: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 43.7708 - accuracy: 0.5181 - val_loss: 26.0481 - val_accuracy: 0.6951
# Epoch 116/2000
#
# Epoch 00116: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 49.7554 - accuracy: 0.5171 - val_loss: 39.7535 - val_accuracy: 0.7166
# Epoch 117/2000
#
# Epoch 00117: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 71.8750 - accuracy: 0.5219 - val_loss: 68.9832 - val_accuracy: 0.2996
# Epoch 118/2000
#
# Epoch 00118: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 23.3470 - accuracy: 0.5285 - val_loss: 19.7856 - val_accuracy: 0.7119
# Epoch 119/2000
#
# Epoch 00119: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 55.8949 - accuracy: 0.4987 - val_loss: 18.0522 - val_accuracy: 0.6926
# Epoch 120/2000
#
# Epoch 00120: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 31.5395 - accuracy: 0.5298 - val_loss: 26.1486 - val_accuracy: 0.7144
# Epoch 121/2000
#
# Epoch 00121: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 42.6307 - accuracy: 0.5114 - val_loss: 182.7837 - val_accuracy: 0.2817
# Epoch 122/2000
#
# Epoch 00122: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 112.9814 - accuracy: 0.4576 - val_loss: 89.5219 - val_accuracy: 0.7169
# Epoch 123/2000
#
# Epoch 00123: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 195.6319 - accuracy: 0.5298 - val_loss: 237.2498 - val_accuracy: 0.2862
# Epoch 124/2000
#
# Epoch 00124: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 112.0250 - accuracy: 0.4748 - val_loss: 336.5316 - val_accuracy: 0.2815
# Epoch 125/2000
#
# Epoch 00125: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 120.2915 - accuracy: 0.4943 - val_loss: 82.0779 - val_accuracy: 0.7177
# Epoch 126/2000
#
# Epoch 00126: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 73.5421 - accuracy: 0.5090 - val_loss: 43.2189 - val_accuracy: 0.7085
# Epoch 127/2000
#
# Epoch 00127: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 87.8393 - accuracy: 0.4911 - val_loss: 27.1413 - val_accuracy: 0.6711
# Epoch 128/2000
#
# Epoch 00128: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 34.9049 - accuracy: 0.5226 - val_loss: 22.2411 - val_accuracy: 0.7035
# Epoch 129/2000
#
# Epoch 00129: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 33.3114 - accuracy: 0.5227 - val_loss: 39.2814 - val_accuracy: 0.7180
# Epoch 130/2000
#
# Epoch 00130: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 22.5785 - accuracy: 0.5208 - val_loss: 12.0058 - val_accuracy: 0.6901
# Epoch 131/2000
#
# Epoch 00131: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 31.6804 - accuracy: 0.5176 - val_loss: 13.4490 - val_accuracy: 0.7043
# Epoch 132/2000
#
# Epoch 00132: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 30.8532 - accuracy: 0.5130 - val_loss: 122.2144 - val_accuracy: 0.2820
# Epoch 133/2000
#
# Epoch 00133: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 48.2258 - accuracy: 0.5035 - val_loss: 32.5638 - val_accuracy: 0.7169
# Epoch 134/2000
#
# Epoch 00134: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 45.3112 - accuracy: 0.5159 - val_loss: 29.1573 - val_accuracy: 0.3755
# Epoch 135/2000
#
# Epoch 00135: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 60.1648 - accuracy: 0.5279 - val_loss: 14.1505 - val_accuracy: 0.6368
# Epoch 136/2000
#
# Epoch 00136: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 14.4891 - accuracy: 0.5424 - val_loss: 10.4253 - val_accuracy: 0.6817
# Epoch 137/2000
#
# Epoch 00137: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 17.7665 - accuracy: 0.5270 - val_loss: 51.0492 - val_accuracy: 0.2859
# Epoch 138/2000
#
# Epoch 00138: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 26.8311 - accuracy: 0.5037 - val_loss: 19.1257 - val_accuracy: 0.3891
# Epoch 139/2000
#
# Epoch 00139: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 23.4440 - accuracy: 0.5152 - val_loss: 198.3752 - val_accuracy: 0.2837
# Epoch 140/2000
#
# Epoch 00140: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 141.2596 - accuracy: 0.4852 - val_loss: 74.7786 - val_accuracy: 0.7183
# Epoch 141/2000
#
# Epoch 00141: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 137.5799 - accuracy: 0.5191 - val_loss: 62.8312 - val_accuracy: 0.3997
# Epoch 142/2000
#
# Epoch 00142: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 49.4240 - accuracy: 0.5068 - val_loss: 62.5351 - val_accuracy: 0.7174
# Epoch 143/2000
#
# Epoch 00143: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 57.4182 - accuracy: 0.5236 - val_loss: 61.8437 - val_accuracy: 0.2909
# Epoch 144/2000
#
# Epoch 00144: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 47.3627 - accuracy: 0.4945 - val_loss: 18.2189 - val_accuracy: 0.6873
# Epoch 145/2000
#
# Epoch 00145: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 51.5184 - accuracy: 0.5078 - val_loss: 19.2984 - val_accuracy: 0.4759
# Epoch 146/2000
#
# Epoch 00146: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 27.1516 - accuracy: 0.5194 - val_loss: 11.1181 - val_accuracy: 0.6840
# Epoch 147/2000
#
# Epoch 00147: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 36.1861 - accuracy: 0.5201 - val_loss: 9.7993 - val_accuracy: 0.6474
# Epoch 148/2000
#
# Epoch 00148: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 16.5417 - accuracy: 0.5401 - val_loss: 38.4658 - val_accuracy: 0.7183
# Epoch 149/2000
#
# Epoch 00149: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 78.6205 - accuracy: 0.5172 - val_loss: 15.3446 - val_accuracy: 0.6179
# Epoch 150/2000
#
# Epoch 00150: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 385.2907 - accuracy: 0.5051 - val_loss: 344.0396 - val_accuracy: 0.7183
# Epoch 151/2000
#
# Epoch 00151: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 283.9942 - accuracy: 0.5024 - val_loss: 333.4721 - val_accuracy: 0.7183
# Epoch 152/2000
#
# Epoch 00152: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 403.4229 - accuracy: 0.5035 - val_loss: 70.3743 - val_accuracy: 0.7130
# Epoch 153/2000
#
# Epoch 00153: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 200.5675 - accuracy: 0.5153 - val_loss: 268.3149 - val_accuracy: 0.2817
# Epoch 154/2000
#
# Epoch 00154: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 3846.3223 - accuracy: 0.4888 - val_loss: 7106.1870 - val_accuracy: 0.2817
# Epoch 155/2000
#
# Epoch 00155: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1838.2384 - accuracy: 0.4910 - val_loss: 1304.3613 - val_accuracy: 0.7183
# Epoch 156/2000
#
# Epoch 00156: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1292.6056 - accuracy: 0.5342 - val_loss: 877.1112 - val_accuracy: 0.2817
# Epoch 157/2000
#
# Epoch 00157: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 185.4525 - accuracy: 0.5059 - val_loss: 42.2414 - val_accuracy: 0.7183
# Epoch 158/2000
#
# Epoch 00158: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 130.8258 - accuracy: 0.5239 - val_loss: 74.3919 - val_accuracy: 0.3068
# Epoch 159/2000
#
# Epoch 00159: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 43.7559 - accuracy: 0.4991 - val_loss: 27.4118 - val_accuracy: 0.3785
# Epoch 160/2000
#
# Epoch 00160: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 29.2609 - accuracy: 0.5158 - val_loss: 17.6108 - val_accuracy: 0.7068
# Epoch 161/2000
#
# Epoch 00161: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 25.9014 - accuracy: 0.5190 - val_loss: 10.6150 - val_accuracy: 0.4731
# Epoch 162/2000
#
# Epoch 00162: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 13.8674 - accuracy: 0.5194 - val_loss: 31.3927 - val_accuracy: 0.3035
# Epoch 163/2000
#
# Epoch 00163: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 38.2285 - accuracy: 0.5137 - val_loss: 52.0028 - val_accuracy: 0.2923
# Epoch 164/2000
#
# Epoch 00164: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 33.1355 - accuracy: 0.5292 - val_loss: 15.6274 - val_accuracy: 0.4184
# Epoch 165/2000
#
# Epoch 00165: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 27.5429 - accuracy: 0.5217 - val_loss: 8.5971 - val_accuracy: 0.6273
# Epoch 166/2000
#
# Epoch 00166: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 11.4098 - accuracy: 0.5488 - val_loss: 97.9527 - val_accuracy: 0.2817
# Epoch 167/2000
#
# Epoch 00167: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 48.4694 - accuracy: 0.4781 - val_loss: 83.0714 - val_accuracy: 0.2831
# Epoch 168/2000
#
# Epoch 00168: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 31.7824 - accuracy: 0.4823 - val_loss: 33.0351 - val_accuracy: 0.7163
# Epoch 169/2000
#
# Epoch 00169: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 39.9113 - accuracy: 0.5146 - val_loss: 63.0522 - val_accuracy: 0.2862
# Epoch 170/2000
#
# Epoch 00170: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 28.2578 - accuracy: 0.5108 - val_loss: 23.9969 - val_accuracy: 0.3420
# Epoch 171/2000
#
# Epoch 00171: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 11.9514 - accuracy: 0.5415 - val_loss: 19.3299 - val_accuracy: 0.7141
# Epoch 172/2000
#
# Epoch 00172: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 29.0088 - accuracy: 0.5168 - val_loss: 9.1112 - val_accuracy: 0.6329
# Epoch 173/2000
#
# Epoch 00173: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 21.9872 - accuracy: 0.5069 - val_loss: 25.0916 - val_accuracy: 0.7160
# Epoch 174/2000
#
# Epoch 00174: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 20.9332 - accuracy: 0.5218 - val_loss: 7.3100 - val_accuracy: 0.6112
# Epoch 175/2000
#
# Epoch 00175: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 8.2497 - accuracy: 0.5526 - val_loss: 63.8983 - val_accuracy: 0.2815
# Epoch 176/2000
#
# Epoch 00176: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 18.9869 - accuracy: 0.5167 - val_loss: 62.7326 - val_accuracy: 0.2817
# Epoch 177/2000
#
# Epoch 00177: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 27.3331 - accuracy: 0.5153 - val_loss: 23.2017 - val_accuracy: 0.7152
# Epoch 178/2000
#
# Epoch 00178: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 35.5438 - accuracy: 0.5214 - val_loss: 11.2715 - val_accuracy: 0.4536
# Epoch 179/2000
#
# Epoch 00179: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 50.5442 - accuracy: 0.4895 - val_loss: 16.4170 - val_accuracy: 0.5618
# Epoch 180/2000
#
# Epoch 00180: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 21.1458 - accuracy: 0.5187 - val_loss: 23.9549 - val_accuracy: 0.7144
# Epoch 181/2000
#
# Epoch 00181: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 22.8237 - accuracy: 0.5186 - val_loss: 126.7132 - val_accuracy: 0.2815
# Epoch 182/2000
#
# Epoch 00182: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 61.2791 - accuracy: 0.4919 - val_loss: 51.4285 - val_accuracy: 0.3107
# Epoch 183/2000
#
# Epoch 00183: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 46.3686 - accuracy: 0.5281 - val_loss: 63.3313 - val_accuracy: 0.7183
# Epoch 184/2000
#
# Epoch 00184: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 58.7653 - accuracy: 0.5102 - val_loss: 33.7428 - val_accuracy: 0.7180
# Epoch 185/2000
#
# Epoch 00185: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 34.9447 - accuracy: 0.5335 - val_loss: 13.4226 - val_accuracy: 0.4399
# Epoch 186/2000
#
# Epoch 00186: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 12.3817 - accuracy: 0.5394 - val_loss: 26.5690 - val_accuracy: 0.3149
# Epoch 187/2000
#
# Epoch 00187: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 20.1985 - accuracy: 0.5203 - val_loss: 71.9760 - val_accuracy: 0.2840
# Epoch 188/2000
#
# Epoch 00188: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 24.5147 - accuracy: 0.5219 - val_loss: 19.5079 - val_accuracy: 0.7155
# Epoch 189/2000
#
# Epoch 00189: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 14.3856 - accuracy: 0.5465 - val_loss: 10.2404 - val_accuracy: 0.7093
# Epoch 190/2000
#
# Epoch 00190: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 15.5760 - accuracy: 0.5205 - val_loss: 7.8905 - val_accuracy: 0.6848
# Epoch 191/2000
#
# Epoch 00191: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 12.3079 - accuracy: 0.5489 - val_loss: 22.0155 - val_accuracy: 0.3063
# Epoch 192/2000
#
# Epoch 00192: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 10.6321 - accuracy: 0.5399 - val_loss: 45.5152 - val_accuracy: 0.2817
# Epoch 193/2000
#
# Epoch 00193: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 25.6716 - accuracy: 0.5201 - val_loss: 7.0666 - val_accuracy: 0.6410
# Epoch 194/2000
#
# Epoch 00194: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 17.4373 - accuracy: 0.5199 - val_loss: 26.1858 - val_accuracy: 0.2940
# Epoch 195/2000
#
# Epoch 00195: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 13.2924 - accuracy: 0.5220 - val_loss: 276.3284 - val_accuracy: 0.3018
# Epoch 196/2000
#
# Epoch 00196: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 207.3725 - accuracy: 0.4696 - val_loss: 55.6310 - val_accuracy: 0.4073
# Epoch 197/2000
#
# Epoch 00197: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 220.7249 - accuracy: 0.4907 - val_loss: 403.1684 - val_accuracy: 0.7183
# Epoch 198/2000
#
# Epoch 00198: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 222.5055 - accuracy: 0.5064 - val_loss: 85.8149 - val_accuracy: 0.7169
# Epoch 199/2000
#
# Epoch 00199: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 240.5322 - accuracy: 0.4937 - val_loss: 325.2792 - val_accuracy: 0.7183
# Epoch 200/2000
#
# Epoch 00200: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 248.9440 - accuracy: 0.4891 - val_loss: 178.3975 - val_accuracy: 0.7183
# Epoch 201/2000
#
# Epoch 00201: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 372.3584 - accuracy: 0.5141 - val_loss: 159.0971 - val_accuracy: 0.7183
# Epoch 202/2000
#
# Epoch 00202: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 142.2414 - accuracy: 0.4662 - val_loss: 53.5192 - val_accuracy: 0.7166
# Epoch 203/2000
#
# Epoch 00203: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 51.5179 - accuracy: 0.5151 - val_loss: 20.4316 - val_accuracy: 0.6976
# Epoch 204/2000
#
# Epoch 00204: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 130.1178 - accuracy: 0.4998 - val_loss: 72.3961 - val_accuracy: 0.6374
# Epoch 205/2000
#
# Epoch 00205: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 195.4499 - accuracy: 0.5052 - val_loss: 349.3953 - val_accuracy: 0.2817
# Epoch 206/2000
#
# Epoch 00206: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 170.7013 - accuracy: 0.5171 - val_loss: 421.3926 - val_accuracy: 0.2817
# Epoch 207/2000
#
# Epoch 00207: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 106.0011 - accuracy: 0.4806 - val_loss: 71.3143 - val_accuracy: 0.7183
# Epoch 208/2000
#
# Epoch 00208: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 108.9988 - accuracy: 0.5072 - val_loss: 123.8533 - val_accuracy: 0.2817
# Epoch 209/2000
#
# Epoch 00209: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 35.0346 - accuracy: 0.5252 - val_loss: 17.3616 - val_accuracy: 0.6893
# Epoch 210/2000
#
# Epoch 00210: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 17.8304 - accuracy: 0.5291 - val_loss: 12.3168 - val_accuracy: 0.7021
# Epoch 211/2000
#
# Epoch 00211: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 16.1292 - accuracy: 0.5260 - val_loss: 31.0624 - val_accuracy: 0.7166
# Epoch 212/2000
#
# Epoch 00212: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 30.5855 - accuracy: 0.5299 - val_loss: 17.6652 - val_accuracy: 0.7166
# Epoch 213/2000
#
# Epoch 00213: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 25.6453 - accuracy: 0.5262 - val_loss: 54.5120 - val_accuracy: 0.2879
# Epoch 214/2000
#
# Epoch 00214: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 26.3696 - accuracy: 0.4939 - val_loss: 24.2800 - val_accuracy: 0.7174
# Epoch 215/2000
#
# Epoch 00215: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 19.1366 - accuracy: 0.5182 - val_loss: 6.2145 - val_accuracy: 0.5994
# Epoch 216/2000
#
# Epoch 00216: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 15.7327 - accuracy: 0.5074 - val_loss: 14.6692 - val_accuracy: 0.7149
# Epoch 217/2000
#
# Epoch 00217: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 14.3158 - accuracy: 0.5440 - val_loss: 11.3827 - val_accuracy: 0.7105
# Epoch 218/2000
#
# Epoch 00218: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 12.1974 - accuracy: 0.5411 - val_loss: 56.9246 - val_accuracy: 0.2828
# Epoch 219/2000
#
# Epoch 00219: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 13.0731 - accuracy: 0.5235 - val_loss: 9.3766 - val_accuracy: 0.7127
# Epoch 220/2000
#
# Epoch 00220: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 11.2627 - accuracy: 0.5270 - val_loss: 8.6775 - val_accuracy: 0.7107
# Epoch 221/2000
#
# Epoch 00221: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 6.2364 - accuracy: 0.5562 - val_loss: 6.7652 - val_accuracy: 0.7099
# Epoch 222/2000
#
# Epoch 00222: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 6.2260 - accuracy: 0.5469 - val_loss: 3.4110 - val_accuracy: 0.6538
# Epoch 223/2000
#
# Epoch 00223: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 8.2412 - accuracy: 0.5186 - val_loss: 3.8837 - val_accuracy: 0.6784
# Epoch 224/2000
#
# Epoch 00224: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 19.6972 - accuracy: 0.5120 - val_loss: 15.6429 - val_accuracy: 0.7149
# Epoch 225/2000
#
# Epoch 00225: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 26.3456 - accuracy: 0.5219 - val_loss: 82.6098 - val_accuracy: 0.2815
# Epoch 226/2000
#
# Epoch 00226: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 36.5414 - accuracy: 0.4908 - val_loss: 24.5350 - val_accuracy: 0.3261
# Epoch 227/2000
#
# Epoch 00227: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 17.6945 - accuracy: 0.5120 - val_loss: 7.8944 - val_accuracy: 0.6787
# Epoch 228/2000
#
# Epoch 00228: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 8.6073 - accuracy: 0.5440 - val_loss: 16.0515 - val_accuracy: 0.7155
# Epoch 229/2000
#
# Epoch 00229: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 20.1620 - accuracy: 0.5202 - val_loss: 83.2750 - val_accuracy: 0.2826
# Epoch 230/2000
#
# Epoch 00230: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 45.6426 - accuracy: 0.4916 - val_loss: 73.3154 - val_accuracy: 0.7183
# Epoch 231/2000
#
# Epoch 00231: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 39.0391 - accuracy: 0.5103 - val_loss: 79.0163 - val_accuracy: 0.2817
# Epoch 232/2000
#
# Epoch 00232: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 48.5403 - accuracy: 0.4806 - val_loss: 42.5346 - val_accuracy: 0.3180
# Epoch 233/2000
#
# Epoch 00233: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 58.6322 - accuracy: 0.4882 - val_loss: 55.9513 - val_accuracy: 0.6446
# Epoch 234/2000
#
# Epoch 00234: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 33.6024 - accuracy: 0.5210 - val_loss: 57.7801 - val_accuracy: 0.7169
# Epoch 235/2000
#
# Epoch 00235: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 32.4363 - accuracy: 0.5188 - val_loss: 22.2245 - val_accuracy: 0.7127
# Epoch 236/2000
#
# Epoch 00236: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 43.8829 - accuracy: 0.5121 - val_loss: 115.2891 - val_accuracy: 0.2823
# Epoch 237/2000
#
# Epoch 00237: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 40.5347 - accuracy: 0.5023 - val_loss: 28.7789 - val_accuracy: 0.3353
# Epoch 238/2000
#
# Epoch 00238: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 31.6697 - accuracy: 0.5225 - val_loss: 12.7246 - val_accuracy: 0.6828
# Epoch 239/2000
#
# Epoch 00239: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 25.2177 - accuracy: 0.5318 - val_loss: 17.8270 - val_accuracy: 0.5342
# Epoch 240/2000
#
# Epoch 00240: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 14.3676 - accuracy: 0.5307 - val_loss: 13.4295 - val_accuracy: 0.7197
# Epoch 241/2000
#
# Epoch 00241: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 20.4382 - accuracy: 0.5303 - val_loss: 10.2137 - val_accuracy: 0.5439
# Epoch 242/2000
#
# Epoch 00242: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 9.4399 - accuracy: 0.5453 - val_loss: 29.8314 - val_accuracy: 0.2909
# Epoch 243/2000
#
# Epoch 00243: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 8.2697 - accuracy: 0.5299 - val_loss: 120.2741 - val_accuracy: 0.2817
# Epoch 244/2000
#
# Epoch 00244: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 48.2993 - accuracy: 0.4709 - val_loss: 48.0504 - val_accuracy: 0.7183
# Epoch 245/2000
#
# Epoch 00245: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 105.2298 - accuracy: 0.5344 - val_loss: 951.5649 - val_accuracy: 0.2828
# Epoch 246/2000
#
# Epoch 00246: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 2507.7537 - accuracy: 0.4757 - val_loss: 2509.3010 - val_accuracy: 0.2817
# Epoch 247/2000
#
# Epoch 00247: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1365.2621 - accuracy: 0.4976 - val_loss: 1060.5874 - val_accuracy: 0.7183
# Epoch 248/2000
#
# Epoch 00248: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 767.0773 - accuracy: 0.4998 - val_loss: 148.3395 - val_accuracy: 0.7110
# Epoch 249/2000
#
# Epoch 00249: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 748.4244 - accuracy: 0.4813 - val_loss: 283.5749 - val_accuracy: 0.7183
# Epoch 250/2000
#
# Epoch 00250: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 298.9030 - accuracy: 0.4849 - val_loss: 416.7968 - val_accuracy: 0.7183
# Epoch 251/2000
#
# Epoch 00251: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 536.4559 - accuracy: 0.5230 - val_loss: 1105.8154 - val_accuracy: 0.2817
# Epoch 252/2000
#
# Epoch 00252: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 313.9046 - accuracy: 0.4919 - val_loss: 503.4224 - val_accuracy: 0.2817
# Epoch 253/2000
#
# Epoch 00253: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 103.5025 - accuracy: 0.5036 - val_loss: 93.4311 - val_accuracy: 0.3054
# Epoch 254/2000
#
# Epoch 00254: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 63.3945 - accuracy: 0.4947 - val_loss: 83.7682 - val_accuracy: 0.7146
# Epoch 255/2000
#
# Epoch 00255: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 128.8451 - accuracy: 0.4847 - val_loss: 121.5065 - val_accuracy: 0.7183
# Epoch 256/2000
#
# Epoch 00256: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 176.2389 - accuracy: 0.5185 - val_loss: 151.4747 - val_accuracy: 0.7183
# Epoch 257/2000
#
# Epoch 00257: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 112.7409 - accuracy: 0.5063 - val_loss: 41.7908 - val_accuracy: 0.3690
# Epoch 258/2000
#
# Epoch 00258: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 27.9877 - accuracy: 0.5194 - val_loss: 37.5575 - val_accuracy: 0.7183
# Epoch 259/2000
#
# Epoch 00259: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 64.5231 - accuracy: 0.5210 - val_loss: 187.0148 - val_accuracy: 0.2817
# Epoch 260/2000
#
# Epoch 00260: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 108.0058 - accuracy: 0.4677 - val_loss: 202.9686 - val_accuracy: 0.7177
# Epoch 261/2000
#
# Epoch 00261: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 170.9083 - accuracy: 0.5336 - val_loss: 17.2699 - val_accuracy: 0.7079
# Epoch 262/2000
#
# Epoch 00262: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 42.0442 - accuracy: 0.5116 - val_loss: 40.7849 - val_accuracy: 0.7183
# Epoch 263/2000
#
# Epoch 00263: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 35.0400 - accuracy: 0.5203 - val_loss: 17.8930 - val_accuracy: 0.7141
# Epoch 264/2000
#
# Epoch 00264: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 16.7801 - accuracy: 0.5384 - val_loss: 14.7471 - val_accuracy: 0.7149
# Epoch 265/2000
#
# Epoch 00265: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 13.4499 - accuracy: 0.5385 - val_loss: 9.7335 - val_accuracy: 0.4215
# Epoch 266/2000
#
# Epoch 00266: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 5.6882 - accuracy: 0.5489 - val_loss: 17.8100 - val_accuracy: 0.2943
# Epoch 267/2000
#
# Epoch 00267: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 9.5208 - accuracy: 0.5266 - val_loss: 5.2572 - val_accuracy: 0.5679
# Epoch 268/2000
#
# Epoch 00268: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 9.3013 - accuracy: 0.5431 - val_loss: 12.0020 - val_accuracy: 0.7158
# Epoch 269/2000
#
# Epoch 00269: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 22.4290 - accuracy: 0.5093 - val_loss: 25.2521 - val_accuracy: 0.2912
# Epoch 270/2000
#
# Epoch 00270: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 17.7809 - accuracy: 0.4957 - val_loss: 17.3800 - val_accuracy: 0.7119
# Epoch 271/2000
#
# Epoch 00271: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 17.7680 - accuracy: 0.5148 - val_loss: 5.9301 - val_accuracy: 0.6820
# Epoch 272/2000
#
# Epoch 00272: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 8.1963 - accuracy: 0.5253 - val_loss: 13.4887 - val_accuracy: 0.7166
# Epoch 273/2000
#
# Epoch 00273: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 9.2067 - accuracy: 0.5359 - val_loss: 24.5639 - val_accuracy: 0.2912
# Epoch 274/2000
#
# Epoch 00274: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 10.7131 - accuracy: 0.5084 - val_loss: 16.7725 - val_accuracy: 0.2979
# Epoch 275/2000
#
# Epoch 00275: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 9.9266 - accuracy: 0.4980 - val_loss: 12.0964 - val_accuracy: 0.7177
# Epoch 276/2000
#
# Epoch 00276: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 9.9966 - accuracy: 0.5398 - val_loss: 11.3748 - val_accuracy: 0.3278
# Epoch 277/2000
#
# Epoch 00277: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 3.6108 - accuracy: 0.5551 - val_loss: 6.9464 - val_accuracy: 0.7130
# Epoch 278/2000
#
# Epoch 00278: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 6.2507 - accuracy: 0.5220 - val_loss: 7.2818 - val_accuracy: 0.7183
# Epoch 279/2000
#
# Epoch 00279: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 9.5225 - accuracy: 0.5301 - val_loss: 3.7408 - val_accuracy: 0.6611
# Epoch 280/2000
#
# Epoch 00280: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 5.6115 - accuracy: 0.5496 - val_loss: 3.2608 - val_accuracy: 0.5384
# Epoch 281/2000
#
# Epoch 00281: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 4.7317 - accuracy: 0.5337 - val_loss: 14.7380 - val_accuracy: 0.2971
# Epoch 282/2000
#
# Epoch 00282: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 9.0464 - accuracy: 0.5130 - val_loss: 16.2111 - val_accuracy: 0.2915
# Epoch 283/2000
#
# Epoch 00283: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 4.5400 - accuracy: 0.5362 - val_loss: 3.1978 - val_accuracy: 0.4912
# Epoch 284/2000
#
# Epoch 00284: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 2.8756 - accuracy: 0.5616 - val_loss: 4.1788 - val_accuracy: 0.3969
# Epoch 285/2000
#
# Epoch 00285: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 5.2764 - accuracy: 0.5138 - val_loss: 9.0959 - val_accuracy: 0.7172
# Epoch 286/2000
#
# Epoch 00286: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 9.5749 - accuracy: 0.5455 - val_loss: 19.0348 - val_accuracy: 0.2879
# Epoch 287/2000
#
# Epoch 00287: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 7.1544 - accuracy: 0.5189 - val_loss: 3.6761 - val_accuracy: 0.7085
# Epoch 288/2000
#
# Epoch 00288: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 4.9236 - accuracy: 0.5412 - val_loss: 6.9693 - val_accuracy: 0.3342
# Epoch 289/2000
#
# Epoch 00289: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 3.1598 - accuracy: 0.5472 - val_loss: 7.4907 - val_accuracy: 0.3130
# Epoch 290/2000
#
# Epoch 00290: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 4.5128 - accuracy: 0.5263 - val_loss: 2.7892 - val_accuracy: 0.5336
# ...
# 22/21 - 1s - loss: 2.1768 - accuracy: 0.5152 - val_loss: 5.3059 - val_accuracy: 0.2854
# Epoch 470/2000
#
# Epoch 00470: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 2.4663 - accuracy: 0.5124 - val_loss: 2.4839 - val_accuracy: 0.7110
# Epoch 471/2000
#
# Epoch 00471: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 2.2062 - accuracy: 0.5380 - val_loss: 2.5432 - val_accuracy: 0.3155
# Epoch 472/2000
#
# Epoch 00472: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.2982 - accuracy: 0.5218 - val_loss: 1.4877 - val_accuracy: 0.7160
# Epoch 473/2000
#
# Epoch 00473: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.5316 - accuracy: 0.5239 - val_loss: 1.1076 - val_accuracy: 0.7105
# Epoch 474/2000
#
# Epoch 00474: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.2408 - accuracy: 0.5436 - val_loss: 1.1905 - val_accuracy: 0.4301
# Epoch 475/2000
#
# Epoch 00475: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.9241 - accuracy: 0.5563 - val_loss: 0.9838 - val_accuracy: 0.4787
# Epoch 476/2000
#
# Epoch 00476: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.8290 - accuracy: 0.5621 - val_loss: 1.6814 - val_accuracy: 0.7180
# Epoch 477/2000
#
# Epoch 00477: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 2.2387 - accuracy: 0.5263 - val_loss: 1.2364 - val_accuracy: 0.4477
# Epoch 478/2000
#
# Epoch 00478: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.0299 - accuracy: 0.5441 - val_loss: 1.4432 - val_accuracy: 0.3372
# Epoch 479/2000
#
# Epoch 00479: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.8455 - accuracy: 0.5519 - val_loss: 2.8433 - val_accuracy: 0.2845
# Epoch 480/2000
#
# Epoch 00480: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.1720 - accuracy: 0.5363 - val_loss: 1.2751 - val_accuracy: 0.3646
# Epoch 481/2000
#
# Epoch 00481: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.9571 - accuracy: 0.5333 - val_loss: 9.8092 - val_accuracy: 0.2817
# Epoch 482/2000
#
# Epoch 00482: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 5.8869 - accuracy: 0.4793 - val_loss: 4.1992 - val_accuracy: 0.2895
# Epoch 483/2000
#
# Epoch 00483: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 8.9422 - accuracy: 0.4969 - val_loss: 17.8819 - val_accuracy: 0.7183
# Epoch 484/2000
#
# Epoch 00484: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 19.3865 - accuracy: 0.5087 - val_loss: 12.3423 - val_accuracy: 0.2831
# Epoch 485/2000
#
# Epoch 00485: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 4.8902 - accuracy: 0.5206 - val_loss: 5.6162 - val_accuracy: 0.7183
# Epoch 486/2000
#
# Epoch 00486: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 6.6535 - accuracy: 0.5384 - val_loss: 5.3997 - val_accuracy: 0.3297
# Epoch 487/2000
#
# Epoch 00487: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.7388 - accuracy: 0.5318 - val_loss: 1.2341 - val_accuracy: 0.7146
# Epoch 488/2000
#
# Epoch 00488: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.3086 - accuracy: 0.5527 - val_loss: 0.9839 - val_accuracy: 0.4865
# Epoch 489/2000
#
# Epoch 00489: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.9699 - accuracy: 0.5675 - val_loss: 0.8147 - val_accuracy: 0.5255
# Epoch 490/2000
#
# Epoch 00490: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.8649 - accuracy: 0.5562 - val_loss: 0.7255 - val_accuracy: 0.7113
# Epoch 491/2000
#
# Epoch 00491: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.8769 - accuracy: 0.5495 - val_loss: 7.4510 - val_accuracy: 0.2817
# Epoch 492/2000
#
# Epoch 00492: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 4.3394 - accuracy: 0.4885 - val_loss: 1.6054 - val_accuracy: 0.7105
# Epoch 493/2000
#
# Epoch 00493: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 2.5562 - accuracy: 0.5217 - val_loss: 1.3013 - val_accuracy: 0.7013
# Epoch 494/2000
#
# Epoch 00494: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.6191 - accuracy: 0.5411 - val_loss: 0.7973 - val_accuracy: 0.6176
# Epoch 495/2000
#
# Epoch 00495: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.9731 - accuracy: 0.5437 - val_loss: 2.9601 - val_accuracy: 0.2845
# Epoch 496/2000
#
# Epoch 00496: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.0833 - accuracy: 0.5365 - val_loss: 5.5816 - val_accuracy: 0.2826
# Epoch 497/2000
#
# Epoch 00497: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 2.1382 - accuracy: 0.5074 - val_loss: 0.8847 - val_accuracy: 0.7018
# Epoch 498/2000
#
# Epoch 00498: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.0495 - accuracy: 0.5537 - val_loss: 0.9003 - val_accuracy: 0.5322
# Epoch 499/2000
#
# Epoch 00499: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7991 - accuracy: 0.5756 - val_loss: 0.6697 - val_accuracy: 0.6748
# Epoch 500/2000
#
# Epoch 00500: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7543 - accuracy: 0.5811 - val_loss: 1.3068 - val_accuracy: 0.7172
# Epoch 501/2000
#
# Epoch 00501: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.4824 - accuracy: 0.5234 - val_loss: 1.6081 - val_accuracy: 0.7180
# Epoch 502/2000
#
# Epoch 00502: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.3601 - accuracy: 0.5304 - val_loss: 4.5441 - val_accuracy: 0.2834
# Epoch 503/2000
#
# Epoch 00503: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.5646 - accuracy: 0.5171 - val_loss: 1.3976 - val_accuracy: 0.3646
# Epoch 504/2000
#
# Epoch 00504: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.9386 - accuracy: 0.5476 - val_loss: 0.7909 - val_accuracy: 0.5417
# Epoch 505/2000
#
# Epoch 00505: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7961 - accuracy: 0.5679 - val_loss: 0.8309 - val_accuracy: 0.4784
# Epoch 506/2000
#
# Epoch 00506: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.8273 - accuracy: 0.5562 - val_loss: 0.6735 - val_accuracy: 0.6296
# Epoch 507/2000
#
# Epoch 00507: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7308 - accuracy: 0.5798 - val_loss: 0.9962 - val_accuracy: 0.7169
# Epoch 508/2000
#
# Epoch 00508: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.0897 - accuracy: 0.5358 - val_loss: 0.6543 - val_accuracy: 0.6823
# Epoch 509/2000
#
# Epoch 00509: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.8233 - accuracy: 0.5655 - val_loss: 1.3404 - val_accuracy: 0.3227
# Epoch 510/2000
#
# Epoch 00510: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.8019 - accuracy: 0.5589 - val_loss: 0.6538 - val_accuracy: 0.6937
# Epoch 511/2000
#
# Epoch 00511: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7627 - accuracy: 0.5751 - val_loss: 0.6393 - val_accuracy: 0.6921
# Epoch 512/2000
#
# Epoch 00512: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7699 - accuracy: 0.5703 - val_loss: 1.7129 - val_accuracy: 0.2932
# Epoch 513/2000
#
# Epoch 00513: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.8255 - accuracy: 0.5652 - val_loss: 2.4980 - val_accuracy: 0.2851
# Epoch 514/2000
#
# Epoch 00514: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.9945 - accuracy: 0.5316 - val_loss: 1.9150 - val_accuracy: 0.2943
# Epoch 515/2000
#
# Epoch 00515: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.9421 - accuracy: 0.5305 - val_loss: 0.9755 - val_accuracy: 0.3986
# Epoch 516/2000
#
# Epoch 00516: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7250 - accuracy: 0.5679 - val_loss: 3.6405 - val_accuracy: 0.2823
# Epoch 517/2000
#
# Epoch 00517: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.0126 - accuracy: 0.5403 - val_loss: 0.9847 - val_accuracy: 0.7169
# Epoch 518/2000
#
# Epoch 00518: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.0063 - accuracy: 0.5368 - val_loss: 0.6444 - val_accuracy: 0.6717
# Epoch 519/2000
#
# Epoch 00519: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7521 - accuracy: 0.5621 - val_loss: 0.9044 - val_accuracy: 0.3908
# Epoch 520/2000
#
# Epoch 00520: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7261 - accuracy: 0.5587 - val_loss: 0.7798 - val_accuracy: 0.4876
# Epoch 521/2000
#
# Epoch 00521: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7597 - accuracy: 0.5516 - val_loss: 0.9349 - val_accuracy: 0.4047
# Epoch 522/2000
#
# Epoch 00522: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7760 - accuracy: 0.5594 - val_loss: 0.8978 - val_accuracy: 0.7169
# Epoch 523/2000
#
# Epoch 00523: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.0094 - accuracy: 0.5485 - val_loss: 3.4137 - val_accuracy: 0.2834
# Epoch 524/2000
#
# Epoch 00524: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.1957 - accuracy: 0.5201 - val_loss: 1.0511 - val_accuracy: 0.7169
# Epoch 525/2000
#
# Epoch 00525: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.0791 - accuracy: 0.5358 - val_loss: 0.7067 - val_accuracy: 0.6061
# Epoch 526/2000
#
# Epoch 00526: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7276 - accuracy: 0.5920 - val_loss: 1.0313 - val_accuracy: 0.7177
# Epoch 527/2000
#
# Epoch 00527: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.9435 - accuracy: 0.5535 - val_loss: 0.6460 - val_accuracy: 0.7063
# Epoch 528/2000
#
# Epoch 00528: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.8168 - accuracy: 0.5535 - val_loss: 1.0128 - val_accuracy: 0.7169
# Epoch 529/2000
#
# Epoch 00529: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.9757 - accuracy: 0.5495 - val_loss: 0.6605 - val_accuracy: 0.6388
# Epoch 530/2000
#
# Epoch 00530: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.6967 - accuracy: 0.5882 - val_loss: 0.9266 - val_accuracy: 0.7166
# Epoch 531/2000
#
# Epoch 00531: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.0256 - accuracy: 0.5494 - val_loss: 0.6822 - val_accuracy: 0.6265
# Epoch 532/2000
#
# Epoch 00532: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.8700 - accuracy: 0.5479 - val_loss: 4.1169 - val_accuracy: 0.2837
# Epoch 533/2000
#
# Epoch 00533: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.7140 - accuracy: 0.4987 - val_loss: 2.1890 - val_accuracy: 0.7183
# Epoch 534/2000
#
# Epoch 00534: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 2.6817 - accuracy: 0.5299 - val_loss: 7.8772 - val_accuracy: 0.2823
# Epoch 535/2000
#
# Epoch 00535: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 3.2878 - accuracy: 0.4998 - val_loss: 5.9533 - val_accuracy: 0.7183
# Epoch 536/2000
#
# Epoch 00536: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 8.8995 - accuracy: 0.5231 - val_loss: 3.0573 - val_accuracy: 0.3741
# Epoch 537/2000
#
# Epoch 00537: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 2.3808 - accuracy: 0.5125 - val_loss: 2.3155 - val_accuracy: 0.7183
# Epoch 538/2000
#
# Epoch 00538: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 2.0815 - accuracy: 0.5278 - val_loss: 2.1375 - val_accuracy: 0.3038
# Epoch 539/2000
#
# Epoch 00539: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.2012 - accuracy: 0.5287 - val_loss: 1.8378 - val_accuracy: 0.7174
# Epoch 540/2000
#
# Epoch 00540: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 1.2388 - accuracy: 0.5476 - val_loss: 0.8183 - val_accuracy: 0.5199
# Epoch 541/2000
#
# Epoch 00541: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.7575 - accuracy: 0.5777 - val_loss: 0.6845 - val_accuracy: 0.6112
# Epoch 542/2000
#
# Epoch 00542: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.6840 - accuracy: 0.6004 - val_loss: 1.7983 - val_accuracy: 0.2898
# Epoch 543/2000
#
# Epoch 00543: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.9054 - accuracy: 0.5407 - val_loss: 2.0214 - val_accuracy: 0.2879
# Epoch 544/2000
#
# Epoch 00544: val_loss did not improve from 0.58106
# 22/21 - 1s - loss: 0.8501 - accuracy: 0.5472 - val_loss: 3.0111 - val_accuracy: 0.2828
# test_result.shape : (3586, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.2960815 ]
#  [0.51422024]
#  [0.2745158 ]
#  [0.27292553]
#  [0.20064883]]
# y_test.shape : (3586, 1)
# y_score.shape : (3586, 1)
# len(y_test) : 3586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:696: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [5.5543587e-05, 5.553563e-05, 5.489056e-05, 5.759692e-05, 5.8044334e-05, 5.8815396e-05, 5.967711e-05, 5.9683098e-05, 5.9268456e-05, 6.05438e-05, 5.956723e-05, 5.9245358e-05, 5.772197e-05, 5.721591e-05, 5.6200082e-05, 5.5187375e-05, 5.4989523e-05, 5.586962e-05, 5.627486e-05, 5.6397865e-05, 5.6071676e-05, 5.6587243e-05, 5.6556146e-05, 5.7616515e-05, 5.777728e-05, 5.8089052e-05, 5.8075442e-05, 5.8708505e-05, 5.8926635e-05, 5.8892798e-05, 5.9645186e-05, 6.040781e-05, 6.0470997e-05, 6.175215e-05, 6.220979e-05, 6.425256e-05, 6.535387e-05, 6.64416e-05, 6.6524975e-05, 6.684407e-05, 6.1823004e-05, 6.225419e-05, 6.612283e-05, 6.662668e-05, 6.8617475e-05, 7.007036e-05, 7.138685e-05, 7.1055016e-05, 7.115846e-05, 7.1290146e-05, 7.2376344e-05, 7.362613e-05, 7.306471e-05, 7.4264106e-05, 7.396764e-05, 7.38707e-05, 7.4567506e-05, 7.457275e-05, 7.591002e-05, 7.6107295e-05, 7.580515e-05, 7.259964e-05, 7.309433e-05, 7.351628e-05, 7.4027106e-05, 7.8798e-05, 7.824229e-05, 7.910869e-05, 7.818968e-05, 8.0047306e-05, 7.7978664e-05, 7.852509e-05, 7.866612e-05, 7.865998e-05, 7.889667e-05, 8.0571706e-05, 8.107496e-05, 8.174595e-05, 8.1285834e-05, 8.020294e-05, 8.174242e-05, 8.170803e-05, 8.292655e-05, 8.402329e-05, 8.187164e-05, 8.217085e-05, 8.218192e-05, 8.347373e-05, 8.47756e-05, 8.54531e-05, 8.482731e-05, 8.4591025e-05, 8.443395e-05, 8.463176e-05, 8.463682e-05, 8.468881e-05, 8.541944e-05, 8.6779415e-05, 8.718488e-05, 8.8614994e-05, 8.713295e-05, 8.690847e-05, 8.5640204e-05, 8.61674e-05, 8.755962e-05, 8.79921e-05, 8.729951e-05, 8.880697e-05, 8.93958e-05, 8.959902e-05, 8.5660075e-05, 8.521127e-05, 8.6243526e-05, 8.644629e-05, 8.6930006e-05, 9.1223264e-05, 9.043286e-05, 8.9627734e-05, 8.9620706e-05, 9.2192975e-05, 9.22211e-05, 9.361839e-05, 9.3698145e-05, 9.3348295e-05, 9.4036746e-05, 9.574806e-05, 9.720038e-05, 9.887971e-05, 9.961752e-05, 0.00010327552, 0.00010285246, 0.00010233553, 0.0001018265, 0.00010478628, 0.000103823455, 0.000106751, 0.00010593204, 0.00010669139, 0.00010681847, 0.00010782753, 0.00010443314, 0.000105350846, 0.00010558153, 0.00010397351, 0.00010259904, 9.913154e-05, 9.775668e-05, 9.477542e-05, 9.390814e-05, 9.272521e-05, 9.517609e-05, 9.6589174e-05, 9.728684e-05, 9.948816e-05, 9.1801674e-05, 8.9379544e-05, 9.051912e-05, 9.071353e-05, 9.0811984e-05, 9.106588e-05, 9.133951e-05, 8.837791e-05, 8.6848566e-05, 8.99368e-05, 8.839502e-05, 8.9706715e-05, 8.873119e-05, 8.685084e-05, 8.886788e-05, 8.905137e-05, 8.8668916e-05, 8.5703556e-05, 8.626073e-05, 8.630971e-05, 8.438379e-05, 8.6351945e-05, 8.701892e-05, 8.804062e-05, 8.731335e-05, 8.3155566e-05, 8.406091e-05, 8.5014755e-05, 8.580754e-05, 8.676474e-05, 8.729812e-05, 8.895611e-05, 8.990808e-05, 9.185026e-05, 9.303386e-05, 9.25454e-05, 9.409223e-05, 9.345939e-05, 9.6007236e-05, 9.6317235e-05, 9.738206e-05, 9.6705124e-05, 9.775569e-05, 9.565324e-05, 9.747163e-05, 9.7529955e-05, 9.678214e-05, 9.678371e-05, 0.000103582475, 0.00010060268, 0.000101716025, 0.000100770536, 9.958269e-05, 0.000101141326, 0.00010109245, 0.00010169026, 0.00010176088, 0.00010236367, 0.00010281496, 0.00010446711, 0.00010485545, 0.00010465201, 0.00010505411, 0.00010241097, 0.00010344561, 0.000103190374, 0.00010247232, 0.00010059703, 9.987248e-05, 0.000101587975, 0.00010177478, 0.000105131214, 0.00010275856, 0.000102966864, 0.00010223688, 0.00010236395, 0.00010076471, 0.000102401755, 0.000105069405, 0.00010561851, 0.00010391256, 0.00010298601, 0.00010376566, 0.000106138876, 0.000108000284, 0.000108020184, 0.00010789514, 0.000109051754, 0.00010683661, 0.00010834195, 0.00010798475, 0.00011045828, 0.00011142839, 0.00011393899, 0.0001148318, 0.0001136665, 0.00011330447, 0.000111402696, 0.00011565029, 0.00011658478, 0.00010983304, 0.00011355269, 0.00011443959, 0.00011511618, 0.00011587356, 0.00011774695, 0.00012159165, 0.00012129398, 0.0001196827, 0.000120268676, 0.00011945422, 0.000118980526, 0.00012310849, 0.00012318617, 0.000125493, 0.00012211429, 0.00012265486, 0.00012523188, 0.00012681997, 0.00012805611,  ...

# %% [markdown]
# ### save npy

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from funcs_indicator import *

def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


#       set data features : ohlc, v, ep
time_index = ohlcv.index[np.sum(np.isnan(pr)):]

sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

#       scale with price    #
ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
sar = lucid_sar(sliced_ohlcv)
ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
senkou1, senkou2 = ichimoku(sliced_ohlcv)

#     min max scale   #
vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

pr_list = pr[np.sum(np.isnan(pr)):]
print("len(ohlc) :", len(ohlc))
print("len(pr) :", len(pr))

# break


#       set params    #
period = 45
key_i = i

plotting = True

data_x, data_pr, data_updown = [], [], []
data_index = []

for i in range(period, len(ohlc)):

  #   pr_list != 1 인 데이터만 사용한다
  # if 1:
  if pr_list[i] != 1:

    min_max = MinMaxScaler()
    
    #   prediction 을 제외한 이전 데이터를 사용해야한다
    temp_ohlc = ohlc.iloc[i - period : i].values
    # temp_long_ep = long_ep[i - period : i]          
    temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
    temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

    temp_close = min_max_scale(temp_ohlc[:, [3]])    

    price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

    if np.isnan(np.sum(price_data)):
      continue

    # print("price_data[:10] :", price_data[:10])
    # print("temp_ohlc.shape :", temp_ohlc.shape)
    # print("temp_long_ep.shape :", temp_long_ep.shape)
    # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
    # print("price_data.shape :", price_data.shape)

    if plotting:
      plt.plot(price_data)
      plt.show()

    ind_temp_ohlc = min_max_scale(temp_ohlc)
    temp_price_data = min_max_scale(price_data)
    # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


    if plotting:

      plt.plot(ind_temp_ohlc)
      plt.show()
      plt.plot(temp_price_data)
      plt.show()

      plotting = False
    # break

    #   vol -> min_max
    temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
    
    #                   feature selection                   #        
    temp_data = np.hstack((ind_temp_ohlc, temp_vol))

    # temp_data = trial_list[trial_number]
    # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
    # temp_data = temp_ohlc[:, [3]]
    # temp_data = ind_temp_ohlc[:, [3]]
    # temp_data = temp_close

    if np.isnan(np.sum(temp_data)):
      continue

    data_x.append(temp_data)
    data_pr.append(pr_list[i])
    data_index.append(time_index[i])
    data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


print('np.array(data_x).shape :', np.array(data_x).shape)
# print(data_x[0])


#       Reshape data for image deep - learning     #
_, row, col = np.array(data_x).shape

input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
# input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

#     1c to 3c    #
input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
# input_x = np.array(resize_npy(input_x))


input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
input_index = np.array(data_index).reshape(-1, 1)
print('input_x.shape :', input_x.shape)
print('input_x.dtype :', input_x.dtype)
print('input_pr.shape :', input_pr.shape)
print('input_ud.shape :', input_ud.shape)
print('input_index.shape :', input_index.shape)


# x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

#     do stacking   #
# if prev_x is None:
prev_x = input_x
prev_pr = input_pr
prev_ud = input_ud
prev_index = input_index

total_x = input_x
total_pr = input_pr
total_ud = input_ud
total_index = input_index

# else:
#   total_x = np.vstack((prev_x, input_x))
#   total_pr = np.vstack((prev_pr, input_pr))
#   total_ud = np.vstack((prev_ud, input_ud)) 
#   total_index = np.vstack((prev_index, input_index)) 

#   prev_x = total_x
#   prev_pr = total_pr
#   prev_ud = total_ud
#   prev_index = total_index

print('total_x.shape :', total_x.shape)
print('total_pr.shape :', total_pr.shape)
print('total_ud.shape :', total_ud.shape)
print('prev_index.shape :', prev_index.shape)


# _, row, col, _ = input_x.shape
# _, row, col = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


#         get unique timestamp      #
print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

#                 don't shuffle timeseries data                 #
stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)

index_train = np.array(index_train)
index_val = np.array(index_val)
index_test = np.array(index_test)
  
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

symbol_name = key.split(' ')[1].split('.')[0]

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)

np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %% [markdown]
# ### load npy

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


symbol_name = "SXPUSDT"
period = 45

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)


x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')


pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

# total_x = np.vstack((x_train, x_val, x_test))
# total_pr = np.vstack((pr_train, pr_val, pr_test))

# print("total_x.shape :", total_x.shape)
# Out:
# x series loaded !
# y series loaded !

# %% [markdown]
# ### rapid pr selection

# %%
plt.plot(pr)
plt.show()

pr_thresh = 1.005
rapid_pct = len(pr[pr > pr_thresh]) / len(pr)

print(rapid_pct)
# Out:
# 0.36131427304964536

# %% [markdown]
# ### class_weight & categorization

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


def class_ratio(in_list):

  return in_list / in_list[1]
  
y_train = np.where(pr_train > pr_thresh, 1, 0)
y_test = np.where(pr_test > pr_thresh, 1, 0)
y_val = np.where(pr_val > pr_thresh, 1, 0)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

# try:
print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

# except Exception as e:
  # print(e)

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)
# Out:
# x_train.shape : (10755, 45, 5, 3)
# x_test.shape : (3586, 45, 5, 3)
# x_val.shape : (3585, 45, 5, 3)
# y_train.shape : (10755, 1)
# y_test.shape : (3586, 1)
# y_val.shape : (3585, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([6864, 3891])) [1.76407093 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2303, 1282])) [1.79641186 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2291, 1295])) [1.76911197 1.        ]
# class_weights : {0: 0.7834353146853147, 1: 1.382035466461064}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10755, 2)
# y_val_ohe.shape : (3585, 2)
# y_test_ohe.shape : (3586, 2)

# %% [markdown]
# ### augment

# %%
from keras.preprocessing.image import ImageDataGenerator 

datagen = ImageDataGenerator( 
    # rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)


batch_size = 512


for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break

# %% [markdown]
# ### train

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'

# batch_size = 512

model = FER_Model(input_shape=x_train.shape[1:])
opt = Adam(lr=0.00001, decay=0.000005)
# opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model_name = 'classifier_%s_cnn_updown_rascend_1005_%s_tvnon_shuffle.h5' % (period, symbol_name)



checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]
# callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)

# %% [markdown]
# ### load model

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'


model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)


model = keras.models.load_model(ckpt_path + model_name)

# %% [markdown]
# ### test

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)

  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.title(symbol_name)
plt.show()
# Out:
# test_result.shape : (3586, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.04767541]
#  [0.00195843]
#  [0.1600004 ]
#  [0.14308068]
#  [0.00154134]]
# y_test.shape : (3586, 1)
# y_score.shape : (3586, 1)
# len(y_test) : 3586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [5.2342257e-05, 5.224965e-05, 5.119804e-05, 4.92728e-05, 4.9822964e-05, 5.1722614e-05, 5.241118e-05, 5.2653213e-05, 5.4707263e-05, 5.469477e-05, 5.5414595e-05, 5.4917986e-05, 5.5296758e-05, 5.482614e-05, 5.5313794e-05, 5.619928e-05, 5.7341047e-05, 5.8005982e-05, 5.7726982e-05, 5.8714617e-05, 5.924952e-05, 5.9157777e-05, 6.0730683e-05, 6.09751e-05, 6.1022805e-05, 6.194849e-05, 6.286581e-05, 6.367981e-05, 6.4932676e-05, 6.5769455e-05, 6.7948844e-05, 6.841887e-05, 6.806048e-05, 6.849957e-05, 6.9895126e-05, 7.091783e-05, 7.1859926e-05, 7.350335e-05, 7.346305e-05, 7.395025e-05, 7.968566e-05, 7.8947196e-05, 7.8341516e-05, 7.918357e-05, 7.912106e-05, 8.1205275e-05, 8.341604e-05, 8.386569e-05, 8.3938816e-05, 8.564359e-05, 7.970025e-05, 8.0672995e-05, 8.083643e-05, 8.727269e-05, 8.9510206e-05, 8.959228e-05, 8.962243e-05, 8.8885776e-05, 9.023229e-05, 9.169206e-05, 9.0867565e-05, 9.033618e-05, 9.429348e-05, 9.3799725e-05, 9.566918e-05, 9.6586686e-05, 9.398621e-05, 9.4105475e-05, 9.411831e-05, 9.466633e-05, 9.5054995e-05, 9.854746e-05, 9.9124496e-05, 0.00010614127, 0.000108136, 0.00010740872, 0.00010814099, 0.00010723293, 0.00010745465, 0.00010824714, 0.00010731329, 0.000108584194, 0.00010868803, 0.00010257258, 0.000101516416, 0.00010031571, 0.000103715196, 0.00010502134, 0.00010611775, 0.00010916348, 0.00010594193, 0.000104194485, 0.00010433929, 0.000104219216, 0.00010764128, 0.00010433711, 0.00010385209, 0.000106006635, 0.00010645543, 0.00010741285, 0.00010793885, 0.00010773461, 0.000107400294, 0.000107067055, 0.000110430265, 0.00010961514, 0.000110994966, 0.000109511326, 0.00011019072, 0.00011165826, 0.00011095228, 0.00011055433, 0.00011134691, 0.000109883986, 0.0001112986, 0.0001123257, 0.000114077506, 0.00011583454, 0.00011730796, 0.00011702095, 0.00012883096, 0.00012502969, 0.0001211144, 0.00012085415, 0.00012023333, 0.000121178586, 0.0001113643, 0.00011255329, 0.00011366057, 0.00011109531, 0.00011435672, 0.00011691414, 0.00011724194, 0.00011877652, 0.00011876732, 0.00012343662, 0.00012398258, 0.00012742475, 0.00013299534, 0.0001345203, 0.00013497796, 0.00013495858, 0.00013710273, 0.00013803714, 0.00013533776, 0.00014049193, 0.00013862025, 0.00013925365, 0.00013978127, 0.00014475136, 0.00014560782, 0.00014417202, 0.00015133772, 0.0001492487, 0.00015156744, 0.00015025465, 0.00015172384, 0.0001483679, 0.00015025485, 0.00017470514, 0.00017807752, 0.00018197432, 0.00018371776, 0.00018367464, 0.0001920926, 0.00019288564, 0.00020759454, 0.00020698183, 0.00023446795, 0.00023864223, 0.00024568185, 0.0002499611, 0.00025658592, 0.00025730263, 0.00025887572, 0.00026280092, 0.0002670472, 0.00027564648, 0.0002803122, 0.0002723821, 0.00027754836, 0.00027732784, 0.00028359605, 0.0002916876, 0.0002884358, 0.0002919522, 0.00029502896, 0.00028943687, 0.00028854128, 0.00029137387, 0.0002962364, 0.00029461124, 0.00029948735, 0.00030449385, 0.0002996868, 0.00029990985, 0.00029333428, 0.0002965417, 0.00029836778, 0.00029298887, 0.00030178405, 0.00029634495, 0.00029906907, 0.00029697176, 0.0002963374, 0.000295097, 0.000312998, 0.00031196643, 0.00031936396, 0.00032101592, 0.00032832168, 0.0003258465, 0.00033274552, 0.0003290262, 0.00033229083, 0.00034132804, 0.00033895372, 0.00035075872, 0.00034744598, 0.00034445102, 0.00032778905, 0.0003323982, 0.00034709118, 0.0003477889, 0.00035424854, 0.00040091967, 0.00042115894, 0.00041995398, 0.00041660885, 0.00042408038, 0.00044065266, 0.00045346154, 0.00044463656, 0.00047572926, 0.0005098468, 0.00050058664, 0.00049340463, 0.0004999284, 0.0005000292, 0.0004849475, 0.00048356556, 0.0004768842, 0.00047515446, 0.00046261746, 0.00046790738, 0.000461418, 0.00046818578, 0.00046653874, 0.00047877917, 0.00048961974, 0.0005021864, 0.00051662093, 0.00052976055, 0.00053512596, 0.000552535, 0.0005820823, 0.00058700517, 0.00059161586, 0.0005911128, 0.00059325877, 0.00059789245, 0.0006161917, 0.00060233, 0.0006037665, 0.0005968395, 0.0006049573, 0.0006040889, 0.0006045968, 0.000620602, 0.00062113034, 0.0006333279, ...

# %%
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)], linestyle='--', color='r')
plt.title(symbol_name + '\n' + str(new_thresh[np.argmax(acc_pr_bythr)]))
plt.show()

# %%
thresh = 0.5866
y_pred = np.where(y_score[:600, -1] > thresh, 1, 0)
# print('y_pred.shape :', y_pred.shape)
# print('y_pred :', y_pred)

#     compare precision     #

# print('precision :', precision_score(y_test, y_pred))
# print('recall :', recall_score(y_test, y_pred))
# print()

# print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
# print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

# # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
# # plt.show()  
# print()

#     check win-ratio improvement     #
cmat = confusion_matrix(y_test[:len(y_pred)], y_pred)
# print(cmat)
# print(np.sum(cmat, axis=1))

test_size = len(y_test[:len(y_pred)])
test_pr_list = pr_test[:len(y_pred)]
# print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
# print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

# print('pr_test.shape :', pr_test.shape)

# print(y_pred)
# print(test_pr_list)
pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

plt.plot(np.cumprod(pred_pr_list))
plt.show()

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72a922dd9685> in <module>()
#       5 # print(index_train)
#       6 # print(index_val)
# ----> 7 total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index))
#       8 timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train))
#       9 timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val))
#
# NameError: name 'input_index' is not defined

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
