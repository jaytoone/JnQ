# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %tensorflow_version 2.x
# import tensorflow as tf
# print(tf.__version__)
# import keras
# print(keras.__version__)

# %% [markdown]
# ### ***Model Types***

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %matplotlib inline
import random

# %tensorflow_version 1.x
import tensorflow as tf

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.model_selection import train_test_split
from keras.utils.vis_utils import plot_model

# Data Class Weight
from sklearn.utils import class_weight
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

# %%
def Basic_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    #             LSTM Version            #
    net = layers.Dense(64, activation='relu')(visible)
    # net = layers.Dropout(0.2)(net)


    # net = layers.LSTM(5, return_sequences=True)(net)
    net = layers.Dense(32, activation='relu')(net)
    net = layers.Dropout(0.2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
        
    return model

# %%
def Hard_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    #             LSTM Version            #
    net = layers.Dense(128)(visible)
    net = layers.LeakyReLU()(net)

    # net = layers.Dropout(0.2)(net)


    # net = layers.LSTM(5, return_sequences=True)(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(32)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dropout(0.2)(net)

    # net = layers.LSTM(5, return_sequences=True)(visible)
    # net = layers.Dense(16, activation='relu')(net)
    # # net = layers.Dropout(0.2)(net)

    # net = layers.LSTM(1, return_sequences=False)(visible)
    # net = layers.Dense(8, activation='relu')(net)
    # net = layers.Dropout(0.5)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
        
    return model

# %%
def LSTM_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    #             LSTM Version            #
    net = layers.LSTM(30, return_sequences=False)(visible)
    net = layers.Dense(64, activation='relu')(visible)
    # net = layers.Dropout(0.2)(net)


    # net = layers.LSTM(5, return_sequences=True)(net)
    net = layers.Dense(32, activation='relu')(net)
    net = layers.Dropout(0.2)(net)

    # net = layers.LSTM(5, return_sequences=True)(visible)
    # net = layers.Dense(16, activation='relu')(net)
    # # net = layers.Dropout(0.2)(net)

    # net = layers.LSTM(1, return_sequences=False)(visible)
    # net = layers.Dense(8, activation='relu')(net)
    # net = layers.Dropout(0.5)(net)

    # net = layers.Conv2D(64, kernel_size=3, padding='same')(visible)
    # net = layers.Activation('relu')(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    # shortcut_1 = net

    # net = layers.Conv2D(32, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    # net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    # shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())

    return model

# %%
seed = 1213
np.random.seed(seed)
random.seed(seed)
# tf.random.set_random_seed(seed)
# tf.random.set_seed(seed)num_classes = 2

num_classes = 2
batch_size = 30


gdrive_path = '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/'


model_range = range(1180, 1214)
# break

for model_num in model_range:

  # try:

    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % model_num)
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s.npy' % model_num).reshape(-1, 1)

    #         Feature Selection      #
    # Made_X = Made_X_[:, :, [-4]]
    Made_X = Made_X_[:, :, :4]

    #             Train Limitation          #
    # Made_X = Made_X[-limit_train_size:]
    # Made_Y = Made_Y[-limit_train_size:]
    # print(Made_X.shape)
    # print(Made_Y.shape)
    # break

    row = Made_X.shape[1]
    col = Made_X.shape[2]

    X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                        shuffle=False)

    print('X_train.shape :', X_train.shape)
    print('X_val.shape :', X_val.shape)


    label = Y_train.reshape(-1, )
    # print(label.shape)

    Y_train = np_utils.to_categorical(Y_train, num_classes)
    Y_val = np_utils.to_categorical(Y_val, num_classes)
    
    print('Y_train.shape :', Y_train.shape)
    print('Y_val.shape :', Y_val.shape)

    
    #         Get Class_Weights (--> should be considered only for TrainSet)       #
    class_weights = class_weight.compute_class_weight('balanced', 
                                                      classes=np.unique(label),
                                                      y=label)
    class_weights = dict(enumerate(class_weights))
    print(class_weights)
    # quit()

    # model = FER_Model((row, col))
    model_list = [Basic_Model((row, col)), Hard_Model((row, col)), LSTM_Model((row, col))]
    break
    for specific_num, model in enumerate(model_list):

      plot_model(model, to_file=gdrive_path + 'model_plot/rapid_ascending %s_sota_%s_futures_rnn.png' % (model_num, specific_num), show_shapes=True, show_layer_names=True)
      opt = Adam(lr=0.0001, decay=1e-6)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
        
          
      filepath = gdrive_path + "model/rapid_ascending %s_sota_%s_futures_rnn.hdf5" % (model_num, specific_num)
      checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_accuracy', patience=100)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 1000
      history = model.fit(X_train, Y_train,
                          steps_per_epoch=int(len(X_train) / batch_size), 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=(X_val, Y_val),  
                          validation_steps=int(len(X_val) / batch_size),
                          shuffle=False)
    # break
    
  # except Exception as e:
  #   print('Error occured :', e)
# Out:
# X_train.shape : (1603, 30, 4)
# X_val.shape : (687, 30, 4)
# Y_train.shape : (1603, 2)
# Y_val.shape : (687, 2)
# {0: 0.6975630983463882, 1: 1.7654185022026432}
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 30, 4)]           0
# _________________________________________________________________
# dense (Dense)                (None, 30, 64)            320
# _________________________________________________________________
# dense_1 (Dense)              (None, 30, 32)            2080
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 32)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 960)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                61504
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 64,034
# Trainable params: 64,034
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 30, 4)]           0
# _________________________________________________________________
# dense_4 (Dense)              (None, 30, 128)           640
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 30, 128)           0
# _________________________________________________________________
# dense_5 (Dense)              (None, 30, 64)            8256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 30, 64)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 30, 32)            2080
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 30, 32)            0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 32)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 960)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                61504
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 72,610
# Trainable params: 72,610
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 30, 4)]           0
# _________________________________________________________________
# dense_9 (Dense)              (None, 30, 64)            320
# _________________________________________________________________
# dense_10 (Dense)             (None, 30, 32)            2080
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 32)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 960)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                61504
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 64,034
# Trainable params: 64,034
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### ***Backtest***

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, f1_score, recall_score, roc_curve, auc


trade_on = True
show_trade_data = False

input_data_length = 30 # <-- Need for Back-Test
test_model_range = range(1044, 1078)
all_pair_profit_result = list()
all_pair_precision_auc = list()
all_pair_f1_auc = list()
all_pair_auc = list()
for model_num, test_model_num in zip(model_range, test_model_range):

  # try:

    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % model_num)
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s.npy' % model_num).reshape(-1, 1)

    Made_X_test_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % test_model_num)
    #     for trade, ohlc data    #
    Made_Z_test = np.load(gdrive_path + 'Made_X/Made_Z %s.npy' % test_model_num)

    # Made_X2 = np.load(gdrive_path + 'Made_X/Made_X 30_%s.npy' % (30, 219))
    # Made_Y2 = np.load(gdrive_path + 'Made_X/Made_Y 30_%s.npy' % (30, 219))

    #         Feature Selection      #
    # Made_X = Made_X_[:, :, [-4]]
    # Made_X = Made_X_[:, :, :4]
    Made_X = Made_X_[:, :, :4]
    # Made_X2 = Made_X2[:, :, [0, 2, 3, 1]]


    #         Train Limit         #
    # Made_X = Made_X[-4000:]
    # Made_Y = Made_Y[-4000:]
    Made_X_test = Made_X_test_[:, :, :4]
    print('Made_X.shape :', Made_X.shape)
    print('Made_Y.shape :', Made_Y.shape)
    print('Made_X_test.shape :', Made_X_test.shape)
    print('Made_Z_test.shape :', Made_Z_test.shape)

    # print('min(Made_Z_test) :', np.min(Made_Z_test))
    # print(sum(sum(Made_X != Made_X2)))
    # break

    row = Made_X.shape[1]
    col = Made_X.shape[2]

    X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                        shuffle=False)
    X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
    X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)

    Y_train = Y_train.astype('float32')
    Y_val = Y_val.astype('float32')
    
    X_test = Made_X_test
    print('np.unique(Made_Y) :', np.unique(Made_Y, return_counts=True))
    print('np.unique(Y_train) :', np.unique(Y_train, return_counts=True))
    print('np.unique(Y_val) :', np.unique(Y_val, return_counts=True))

    Y_train = np_utils.to_categorical(Y_train, num_classes)
    Y_val = np_utils.to_categorical(Y_val, num_classes)
    
    print('X_train.shape :', X_train.shape)
    print('X_val.shape :', X_val.shape)

    print('model_num :', model_num)

    total_precision_result = list()
    total_f1_result = list()
    total_auc_result = list()
    total_profit_result = list()
    total_pr = list()
    plt.figure(figsize=(20, 10))

    for specific_num in range(len(model_list)):

      model_path = gdrive_path + "model/rapid_ascending %s_sota_%s_futures_rnn.hdf5" % (model_num, specific_num)
      model = load_model(model_path)

      #     val, train -> confidence 와 evaluate 용
      val_y_pred_ = model.predict(X_val, verbose=1)
      train_y_pred_ = model.predict(X_train, verbose=1)

      #     test -> profit 용
      test_y_pred_ = model.predict(X_test, verbose=1)

      train_val_predmin = min(min(val_y_pred_[:, [1]]), min(train_y_pred_[:, [1]]))
      train_val_predmax = max(max(val_y_pred_[:, [1]]), max(train_y_pred_[:, [1]]))

      
      for index, y_pred_ in enumerate([val_y_pred_, train_y_pred_]):

        # print('len(y_pred_) :', len(y_pred_))
        target_column = y_pred_[:, [1]]
        # column_min, column_max = train_y_pred_.min(),train_y_pred_.max()
        column_min, column_max = min(target_column),max(target_column)
        # print(column_min, column_max)

        if index == 0:
          _, model_acc = model.evaluate(X_val, Y_val, batch_size=batch_size)
        elif index == 1:
          _, model_acc = model.evaluate(X_train, Y_train, batch_size=batch_size)

        x_ticks = np.arange(0.5, 1, 0.005)
        # x_ticks = [0.6]

        precision_result = list()
        f1_result = list()
        profit_result = list()        
        for confidence in x_ticks:
          # confidence = 0.9

          # if column_max < 0.5:
          #   break
          # else:
          #   scaled_confidence = .5 + (column_max - .5) * confidence
          # scaled_confidence = column_min + (column_max - column_min) * confidence
          scaled_confidence = train_val_predmin + (train_val_predmax - train_val_predmin) * confidence
          # scaled_confidence = confidence

          # print(scaled_confidence)
          # print('confidence :', confidence)

          y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )

          pred_true, real_true, true_true = 0, 0, 0   

          #     결국, Categorical 은 index 값으로 value 를 나타내는 것    #
          # t_te = np.argmax(Y_test, axis=1)            
          if index == 0:
            t_te = np.argmax(Y_val, axis=1)
          elif index == 1:
            t_te = np.argmax(Y_train, axis=1)

          #       Trading Session, Accumulate Profit     #
          elif index == 2:

              accumulated_profit = 1.

              if trade_on:
                tp_ratio = 3
                target_percentage = 0.05
                sl_least_gap_ratio = 0.05

                long_marker_x = list()
                long_marker_y = list()
                tp_marker_x = list()
                tp_marker_y = list()
                sl_marker_x = list()
                sl_marker_y = list()
                tp_level_list_x = list()
                tp_level_list_y = list()
                sl_level_list_x = list()
                sl_level_list_y = list()

                #         This column order should be changed     #
                high, low, close = np.split(Made_Z_test[:, 1:4], 3, axis=1) # <-- Column Order should be changed
                # break
                i = input_data_length
                while (i < len(y_pred)):

                  #     Long    #
                  if y_pred[i] == 1:  

                    long_sl = np.min(low[i + 1 -input_data_length:i + 1])
                    short_sl = np.max(high[i + 1 -input_data_length:i + 1])
                    tp_level_0 = (close[i] - long_sl) * tp_ratio * 1/3 + close[i]
                    tp_level_1 = (close[i] - long_sl) * tp_ratio * 2/3 + close[i]
                    tp_level = (close[i] - long_sl) * tp_ratio + close[i]
                    tp_count = 3

                    #       Consider 'sl_least_gap'     #
                    if not close[i] >= long_sl + (short_sl - long_sl) * sl_least_gap_ratio:
                      i += 1
                      if i >= len(y_pred):
                        break
                      continue

                    if show_trade_data: print(i, 'long')
                    pred_true += 1

                    long_marker_x.append(i)
                    long_marker_y.append(close[i])

                    if i + 1 >= len(y_pred):
                      break
                    
                    for j in range(i + 1, len(y_pred)):

                      if show_trade_data: print(long_sl, low[j], high[j], tp_level)
                      tp_level_list_x.append(j)
                      tp_level_list_y.append(tp_level)

                      if high[j] > tp_level_0 and tp_count == 3:
                        accumulated_profit *= 1 + target_percentage * tp_ratio * 1/3 * .25
                        tp_count -= 1
                      elif high[j] > tp_level_0 and tp_count == 2:
                        accumulated_profit *= 1 + target_percentage * tp_ratio * 2/3 * .25
                        tp_count -= 1
                      elif high[j] > tp_level and tp_count == 1:
                        accumulated_profit *= 1 + target_percentage * tp_ratio * .5
                        if show_trade_data: print(j, 'tp, accum.profit :', accumulated_profit)  
                        tp_marker_x.append(j)
                        tp_marker_y.append(high[j])
                        real_true += 1
                        break
                      
                      elif low[j] < long_sl:
                        accumulated_profit *= 1 - target_percentage
                        if show_trade_data: print(j, 'tp, accum.profit :', accumulated_profit)          
                        sl_marker_x.append(j)
                        sl_marker_y.append(low[j])
                        break

                    i = j

                  i += 1
                  # print('i, len(y_pred) :', i, len(y_pred))
                  if i >= len(y_pred):
                    break

              profit_result.append(accumulated_profit)

          if index != 2:

            for i in range(len(y_pred)):
              if y_pred[i] == 1:  
                pred_true += 1
                if t_te[i] == y_pred[i]:
                  real_true += 1

            #     precision   #
            # precision = precision_score(t_te, y_pred) * 100
            f1 = f1_score(t_te, y_pred) * 100

          if pred_true != 0:
            true_true = real_true / pred_true * 100
            # print('precision, true_true :', precision, true_true)

            #     Test 는 따로    #
            #     in confidence loop    #
          if index != 2:
            precision_result.append(true_true)
            f1_result.append(f1)

          # print('Real True / Pred True : %s / %s' % (real_true, pred_true))
          # print('Accuracy : %.2f %%' % (true_true))
          # print('Accumulated Profit : %.3f' % accumulated_profit)
          # print()
        
        #     in val, train / test pred loop    #
        if index != 2:
          fpr, tpr, thr = roc_curve(t_te, target_column)
          auc_ = auc(fpr, tpr) * 100

          # if index == 0:
          #   print('len(fpr) in 0 :', len(fpr))
          # elif index == 1:
          #   print('len(fpr) in 1 :', len(fpr))

          total_precision_result.append(precision_result)
          total_f1_result.append(f1_result)
          total_auc_result.append(auc_)
          total_pr.append((fpr, tpr))
        
        if index == 2:
          total_profit_result.append(profit_result)   

      all_pair_profit_result.append(profit_result)

        #          Show Entry Point       #
        # plt.subplot(2, 1, index + 1 + model_i * 1)
        # plt.plot(close)
        # plt.plot(long_marker_x, long_marker_y, 'o', color='green')             
        # plt.plot(tp_marker_x, tp_marker_y, 'o', color='blue')
        # plt.plot(sl_marker_x, sl_marker_y, 'o', color='red')
        # plt.plot(tp_level_list_x, tp_level_list_y, '.', color='blue')
        # plt.title('Accumulated Profit : %.3f' % accumulated_profit, color='white')

    print('len(total_precision_result) :', len(total_precision_result))
    print('len(total_f1_result) :', len(total_f1_result))
    print('len(total_auc_result) :', len(total_auc_result))
    print('len(total_profit_result) :', len(total_profit_result))

    cmap = plt.cm.get_cmap(name='prism', lut=(len(model_list)))

    #         Show Precision by confidence    #
    #       even index => Val / odd index => Train    #
    plt.subplot(2, 7, 1)
    # print(total_precision_result[0][1:5])
    # print(total_precision_result[1][1:5])
    # test_np = np.array([total_precision_result[0::2], total_precision_result[1::2]])
    mean_precision = np.mean(np.array([total_precision_result[0::2], total_precision_result[1::2]]), axis=0)
    # print(mean_precision[0][1:5])
    mean_precision_auc = [np.sum(mean_precision[auc_i])/len(x_ticks) for auc_i in range(len(model_list))]
    # for i in range(len(model_list)):
    #   plt.plot(x_ticks, mean_precision[i], label='%s' % i, c=cmap(i))
    plt.bar(range(len(model_list)), mean_precision_auc, color='g')
    plt.xticks(range(len(model_list)), range(len(model_list)), rotation=45)
    plt.axhline(50, linestyle='--', color='red')
    plt.ylim(-5, 105)
    # plt.legend()
    plt.title('Mean Precision AUC', color='white', fontsize=10)

    print('last index =', index)
    
    plt.subplot(2, 7, 3)
    mean_f1 = np.mean(np.array([total_f1_result[0::2], total_f1_result[1::2]]), axis=0)
    mean_f1_auc = [np.sum(mean_f1[auc_i])/len(x_ticks) for auc_i in range(len(model_list))]
    # for i in range(len(model_list)):
    #   plt.plot(x_ticks, mean_f1[i], label='%s' % i, c=cmap(i))
    plt.bar(range(len(model_list)), mean_f1_auc, color='g')
    plt.xticks(range(len(model_list)), range(len(model_list)), rotation=45)
    plt.axhline(50, linestyle='--', color='red')
    plt.ylim(-5, 105)
    # plt.legend()
    plt.title('Mean F1', color='white', fontsize=10) 

    plt.subplot(2, 7, 4)
    #         Can compare only AUC      # --> Different length (fpr, tpr)
    mean_auc = np.mean(np.array([total_auc_result[0::2], total_auc_result[1::2]]), axis=0)
    plt.bar(range(len(model_list)), mean_auc, color='g')
    plt.xticks(range(len(model_list)), range(len(model_list)), rotation=45)
    plt.ylim(-5, 105)
    plt.axhline(50, linestyle='--', color='red')
    plt.title('Mean AUC', color='white', fontsize=10)   

    plt.subplot(2, 7, 5)
    plt.plot(Made_X_[-len(X_val):, [-1], [3]])
    plt.subplot(2, 7, 6)
    plt.plot(Made_X_[:len(X_train), [-1], [3]])
    plt.subplot(2, 7, 7)
    plt.plot(Made_Z_test[:, 3])

    plt.show()

    all_pair_precision_auc.append(mean_precision_auc)
    all_pair_f1_auc.append(mean_f1_auc)
    all_pair_auc.append(mean_auc)

    #   except Exception as e:
    #     print('Error occured : ', e)
    # print()

    # break
# Out:
# Made_X.shape : (2290, 30, 4)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 4)
# X_val.shape : (687, 30, 4)
# model_num : 1180
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6752 - accuracy: 0.9229
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6837 - accuracy: 0.7168
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6884 - accuracy: 0.9229
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6906 - accuracy: 0.7168
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6702 - accuracy: 0.9214
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6812 - accuracy: 0.7168
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2283, 30, 4)
# Made_Y.shape : (2283, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1508,  775]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1187,  411]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([321, 364]))
# X_train.shape : (1598, 30, 4)
# X_val.shape : (685, 30, 4)
# model_num : 1181
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6814 - accuracy: 0.6949
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6650 - accuracy: 0.6083
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6959 - accuracy: 0.6920
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6791 - accuracy: 0.5688
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6810 - accuracy: 0.6920
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6727 - accuracy: 0.6120
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2206, 30, 4)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1696,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1206,  338]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([490, 172]))
# X_train.shape : (1544, 30, 4)
# X_val.shape : (662, 30, 4)
# model_num : 1182
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6662 - accuracy: 0.7764
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6457 - accuracy: 0.7811
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6760 - accuracy: 0.7810
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6635 - accuracy: 0.7811
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6724 - accuracy: 0.7462
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6576 - accuracy: 0.7811
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2184, 30, 4)
# Made_Y.shape : (2184, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1680,  504]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1148,  380]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([532, 124]))
# X_train.shape : (1528, 30, 4)
# X_val.shape : (656, 30, 4)
# model_num : 1183
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.8308
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6789 - accuracy: 0.7513
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6872 - accuracy: 0.8338
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6865 - accuracy: 0.7513
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6857 - accuracy: 0.8354
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6846 - accuracy: 0.7513
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2161, 30, 4)
# Made_Y.shape : (2161, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1370,  791]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([928, 584]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([442, 207]))
# X_train.shape : (1512, 30, 4)
# X_val.shape : (649, 30, 4)
# model_num : 1184
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6841 - accuracy: 0.7026
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6878 - accuracy: 0.6111
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6852 - accuracy: 0.7057
# 51/51 [==============================] - 0s 4ms/step - loss: 0.6885 - accuracy: 0.6204
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 4ms/step - loss: 0.6813 - accuracy: 0.7042
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6862 - accuracy: 0.6171
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2303, 30, 4)
# Made_Y.shape : (2303, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1514,  789]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1151,  461]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([363, 328]))
# X_train.shape : (1612, 30, 4)
# X_val.shape : (691, 30, 4)
# model_num : 1185
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6697 - accuracy: 0.6556
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5860 - accuracy: 0.7246
# 22/22 [==============================] - 0s 3ms/step
# 51/51 [==============================] - 0s 3ms/step
# 60/60 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6260 - accuracy: 0.7019
# 54/54 [==============================] - 0s 4ms/step - loss: 0.6327 - accuracy: 0.6073
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6600 - accuracy: 0.6758
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5843 - accuracy: 0.7029
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2206, 30, 4)
# Made_Y.shape : (2206, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1633,  573]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1062,  482]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([571,  91]))
# X_train.shape : (1544, 30, 4)
# X_val.shape : (662, 30, 4)
# model_num : 1186
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6806 - accuracy: 0.8625
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6861 - accuracy: 0.6872
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6757 - accuracy: 0.8640
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6795 - accuracy: 0.6878
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6404 - accuracy: 0.8625
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6633 - accuracy: 0.6878
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2258, 30, 4)
# Made_Y.shape : (2258, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1548,  710]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1040,  540]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([508, 170]))
# X_train.shape : (1580, 30, 4)
# X_val.shape : (678, 30, 4)
# model_num : 1187
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6783 - accuracy: 0.7507
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6759 - accuracy: 0.6582
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6891 - accuracy: 0.7537
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6887 - accuracy: 0.6582
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6788 - accuracy: 0.7566
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6763 - accuracy: 0.6582
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2264, 30, 4)
# Made_Y.shape : (2264, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1619,  645]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1107,  477]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([512, 168]))
# X_train.shape : (1584, 30, 4)
# X_val.shape : (680, 30, 4)
# model_num : 1188
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6836 - accuracy: 0.8529
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6770 - accuracy: 0.6793
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6879 - accuracy: 0.8765
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6848 - accuracy: 0.6869
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6834 - accuracy: 0.8676
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6776 - accuracy: 0.6856
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2233, 30, 4)
# Made_Y.shape : (2233, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1782,  451]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1223,  340]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([559, 111]))
# X_train.shape : (1563, 30, 4)
# X_val.shape : (670, 30, 4)
# model_num : 1189
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6626 - accuracy: 0.8388
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6468 - accuracy: 0.7825
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6682 - accuracy: 0.8403
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6580 - accuracy: 0.7825
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6581 - accuracy: 0.8418
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6382 - accuracy: 0.7825
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2287, 30, 4)
# Made_Y.shape : (2287, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1656,  631]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1140,  460]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([516, 171]))
# X_train.shape : (1600, 30, 4)
# X_val.shape : (687, 30, 4)
# model_num : 1190
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6013 - accuracy: 0.7511
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6349 - accuracy: 0.7275
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6229 - accuracy: 0.7511
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6489 - accuracy: 0.7237
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.5994 - accuracy: 0.7511
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6324 - accuracy: 0.7194
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2256, 30, 4)
# Made_Y.shape : (2256, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1528,  728]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1111,  468]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([417, 260]))
# X_train.shape : (1579, 30, 4)
# X_val.shape : (677, 30, 4)
# model_num : 1191
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6621 - accuracy: 0.7415
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6331 - accuracy: 0.7036
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6713 - accuracy: 0.7430
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6550 - accuracy: 0.7036
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6621 - accuracy: 0.7386
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6340 - accuracy: 0.7036
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2183, 30, 4)
# Made_Y.shape : (2183, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1584,  599]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1119,  409]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([465, 190]))
# X_train.shape : (1528, 30, 4)
# X_val.shape : (655, 30, 4)
# model_num : 1192
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6498 - accuracy: 0.7237
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6068 - accuracy: 0.7323
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6374 - accuracy: 0.7099
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6142 - accuracy: 0.7323
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6515 - accuracy: 0.7282
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6089 - accuracy: 0.7376
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2219, 30, 4)
# Made_Y.shape : (2219, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1654,  565]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1178,  375]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([476, 190]))
# X_train.shape : (1553, 30, 4)
# X_val.shape : (666, 30, 4)
# model_num : 1193
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6563 - accuracy: 0.7147
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6420 - accuracy: 0.7585
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6907 - accuracy: 0.7297
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6888 - accuracy: 0.7592
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6797 - accuracy: 0.7147
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6747 - accuracy: 0.7585
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2309, 30, 4)
# Made_Y.shape : (2309, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1486,  823]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1058,  558]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([428, 265]))
# X_train.shape : (1616, 30, 4)
# X_val.shape : (693, 30, 4)
# model_num : 1194
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6563 - accuracy: 0.7085
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6675 - accuracy: 0.5903
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6769 - accuracy: 0.7085
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.6269
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6681 - accuracy: 0.7071
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6733 - accuracy: 0.6312
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2192, 30, 4)
# Made_Y.shape : (2192, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1591,  601]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1141,  393]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([450, 208]))
# X_train.shape : (1534, 30, 4)
# X_val.shape : (658, 30, 4)
# model_num : 1195
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6925 - accuracy: 0.6991
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6937 - accuracy: 0.4179
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.7720
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6937 - accuracy: 0.3820
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6920 - accuracy: 0.7295
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6937 - accuracy: 0.4153
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2159, 30, 4)
# Made_Y.shape : (2159, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1590,  569]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1223,  288]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([367, 281]))
# X_train.shape : (1511, 30, 4)
# X_val.shape : (648, 30, 4)
# model_num : 1196
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6615 - accuracy: 0.7917
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6315 - accuracy: 0.7948
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6486 - accuracy: 0.7793
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6200 - accuracy: 0.7518
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6648 - accuracy: 0.8102
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6375 - accuracy: 0.8074
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2249, 30, 4)
# Made_Y.shape : (2249, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1889,  360]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1285,  289]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([604,  71]))
# X_train.shape : (1574, 30, 4)
# X_val.shape : (675, 30, 4)
# model_num : 1197
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6406 - accuracy: 0.9007
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6191 - accuracy: 0.8164
# 22/22 [==============================] - 0s 3ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6573 - accuracy: 0.9022
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6452 - accuracy: 0.8164
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6476 - accuracy: 0.9022
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6327 - accuracy: 0.8164
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2226, 30, 4)
# Made_Y.shape : (2226, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1692,  534]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1146,  412]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([546, 122]))
# X_train.shape : (1558, 30, 4)
# X_val.shape : (668, 30, 4)
# model_num : 1198
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6805 - accuracy: 0.8383
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6818 - accuracy: 0.7099
# 21/21 [==============================] - 0s 3ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6889 - accuracy: 0.8249
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6894 - accuracy: 0.7067
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6807 - accuracy: 0.8398
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6818 - accuracy: 0.7003
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2143, 30, 4)
# Made_Y.shape : (2143, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1315,  828]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([884, 616]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([431, 212]))
# X_train.shape : (1500, 30, 4)
# X_val.shape : (643, 30, 4)
# model_num : 1199
# 21/21 [==============================] - 0s 2ms/step
# 47/47 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6852 - accuracy: 0.6967
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6867 - accuracy: 0.6313
# 21/21 [==============================] - 0s 2ms/step
# 47/47 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6883 - accuracy: 0.6921
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6892 - accuracy: 0.6300
# 21/21 [==============================] - 0s 2ms/step
# 47/47 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6877 - accuracy: 0.7294
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.5973
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2204, 30, 4)
# Made_Y.shape : (2204, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1474,  730]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([919, 623]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([555, 107]))
# X_train.shape : (1542, 30, 4)
# X_val.shape : (662, 30, 4)
# model_num : 1200
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6805 - accuracy: 0.8837
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5960
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6863 - accuracy: 0.8625
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6892 - accuracy: 0.5960
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6815 - accuracy: 0.8580
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6870 - accuracy: 0.5960
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2152, 30, 4)
# Made_Y.shape : (2152, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1798,  354]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1254,  252]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([544, 102]))
# X_train.shape : (1506, 30, 4)
# X_val.shape : (646, 30, 4)
# model_num : 1201
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6693 - accuracy: 0.8452
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6612 - accuracy: 0.8327
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6733 - accuracy: 0.8591
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6668 - accuracy: 0.8327
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6687 - accuracy: 0.8437
# 51/51 [==============================] - 0s 3ms/step - loss: 0.6602 - accuracy: 0.8327
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2211, 30, 4)
# Made_Y.shape : (2211, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1715,  496]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1193,  354]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([522, 142]))
# X_train.shape : (1547, 30, 4)
# X_val.shape : (664, 30, 4)
# model_num : 1202
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6604 - accuracy: 0.7861
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6524 - accuracy: 0.7712
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6773 - accuracy: 0.7937
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6682 - accuracy: 0.7712
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6735 - accuracy: 0.7937
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6610 - accuracy: 0.7712
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2219, 30, 4)
# Made_Y.shape : (2219, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1711,  508]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1198,  355]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([513, 153]))
# X_train.shape : (1553, 30, 4)
# X_val.shape : (666, 30, 4)
# model_num : 1203
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6681 - accuracy: 0.7913
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6381 - accuracy: 0.7714
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6710 - accuracy: 0.8003
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6476 - accuracy: 0.7714
# 21/21 [==============================] - 0s 2ms/step
# 49/49 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6667 - accuracy: 0.7883
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6376 - accuracy: 0.7714
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2190, 30, 4)
# Made_Y.shape : (2190, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1320,  870]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([851, 682]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([469, 188]))
# X_train.shape : (1533, 30, 4)
# X_val.shape : (657, 30, 4)
# model_num : 1204
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6565 - accuracy: 0.8584
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6687 - accuracy: 0.6243
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6561 - accuracy: 0.8432
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6647 - accuracy: 0.6262
# 21/21 [==============================] - 0s 2ms/step
# 48/48 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6247 - accuracy: 0.8569
# 52/52 [==============================] - 0s 3ms/step - loss: 0.6492 - accuracy: 0.6236
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2309, 30, 4)
# Made_Y.shape : (2309, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1660,  649]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1283,  333]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([377, 316]))
# X_train.shape : (1616, 30, 4)
# X_val.shape : (693, 30, 4)
# model_num : 1205
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6867 - accuracy: 0.5440
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6308 - accuracy: 0.7939
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6876 - accuracy: 0.5440
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6153 - accuracy: 0.7939
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6869 - accuracy: 0.5440
# 54/54 [==============================] - 0s 3ms/step - loss: 0.6213 - accuracy: 0.7939
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2318, 30, 4)
# Made_Y.shape : (2318, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1829,  489]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1263,  359]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([566, 130]))
# X_train.shape : (1622, 30, 4)
# X_val.shape : (696, 30, 4)
# model_num : 1206
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6727 - accuracy: 0.8132
# 55/55 [==============================] - 0s 3ms/step - loss: 0.6725 - accuracy: 0.7787
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6869 - accuracy: 0.8175
# 55/55 [==============================] - 0s 3ms/step - loss: 0.6825 - accuracy: 0.7787
# 22/22 [==============================] - 0s 2ms/step
# 51/51 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6872 - accuracy: 0.8161
# 55/55 [==============================] - 0s 3ms/step - loss: 0.6835 - accuracy: 0.7787
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2246, 30, 4)
# Made_Y.shape : (2246, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1958,  288]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1363,  209]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([595,  79]))
# X_train.shape : (1572, 30, 4)
# X_val.shape : (674, 30, 4)
# model_num : 1207
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6725 - accuracy: 0.8858
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6586 - accuracy: 0.8670
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6675 - accuracy: 0.8872
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6475 - accuracy: 0.8670
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6615 - accuracy: 0.8887
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6387 - accuracy: 0.8670
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# Made_X.shape : (2243, 30, 4)
# Made_Y.shape : (2243, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1838,  405]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1315,  255]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([523, 150]))
# X_train.shape : (1570, 30, 4)
# X_val.shape : (673, 30, 4)
# model_num : 1208
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6869 - accuracy: 0.7786
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6809 - accuracy: 0.8376
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6508 - accuracy: 0.7771
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6320 - accuracy: 0.8376
# 22/22 [==============================] - 0s 2ms/step
# 50/50 [==============================] - 0s 2ms/step
# 60/60 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6802 - accuracy: 0.7771
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6749 - accuracy: 0.8376
# len(total_precision_result) : 6
# len(total_f1_result) : 6
# len(total_auc_result) : 6
# len(total_profit_result) : 0
# last index = 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-b594ec52dd51> in <module>()
#      18   # try:
#      19
# ---> 20     Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % model_num)
#      21     Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s.npy' % model_num).reshape(-1, 1)
#      22
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 1209.npy'

# %% [markdown]
# ### ***Compare Result***

# %%
print(np.array(all_pair_precision_auc).shape)
print(np.array(all_pair_f1_auc).shape)
print(np.array(all_pair_auc).shape)

# print(np.sum(np.array(all_pair_precision_auc), axis=0))
plt.subplot(131)
plt.bar(range(len(model_list)), np.mean(np.array(all_pair_precision_auc), axis=0))
plt.axhline(50, linestyle='--', color='red')
plt.title('All Pair Precision Mean AUC')

plt.subplot(132)
plt.bar(range(len(model_list)), np.mean(np.array(all_pair_f1_auc), axis=0))
plt.axhline(50, linestyle='--', color='red')
plt.title('All Pair F1 Mean AUC')

plt.subplot(133)
plt.bar(range(len(model_list)), np.mean(np.array(all_pair_auc), axis=0))
plt.axhline(50, linestyle='--', color='red')
plt.title('All Pair Mean AUC')
fig.suptitle('Main title') # or plt.suptitle('Main title')

plt.show()
# Out:
# (29, 3)
# (29, 3)
# (29, 3)

# %%
# test_list = np.arange(5)
# arr = [([1, 2, 3], [4, 5, 6]), ([1, 2, 3], [4, 5, 6])]
# arr2 = [([1, 2, 3], [4, 5, 6]), ([1, 2, 3], [4, 5, 6])]
# arr3 = np.array([arr, arr2])
# print(np.mean(arr3, axis=0))
# print(arr3.shape)

arr = [10.504201680672269, 10.480349344978166, 10.85972850678733, 11.11111111111111]
arr1 = [36.94779116465863, 38.095238095238095, 38.347457627118644, 38.961038961038966]
arr2 = [23.72599642,24.28779372,24.60359307,25.03607504]
temp = np.array([arr, arr1])
print(np.mean(temp, axis=0))
# print(test_list[1::2])
# print(test_list)
# Out:
# [23.72599642 24.28779372 24.60359307 25.03607504]

# %% [markdown]
# ### ***AUC***

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import f1_score, precision_score, recall_score


trade_on = True
show_trade_data = False

input_data_length = 30 # <-- Need for Back-Test
test_model_range = range(1044, 1078)
total_profit_result = list()
for model_num, test_model_num in zip(model_range, test_model_range):

  # try:

    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % model_num)
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s.npy' % model_num).reshape(-1, 1)

    Made_X_test_ = np.load(gdrive_path + 'Made_X/Made_X %s.npy' % test_model_num)
    #     for trade, ohlc data    #
    Made_Z_test = np.load(gdrive_path + 'Made_X/Made_Z %s.npy' % test_model_num)

    # Made_X2 = np.load(gdrive_path + 'Made_X/Made_X 30_%s.npy' % (30, 219))
    # Made_Y2 = np.load(gdrive_path + 'Made_X/Made_Y 30_%s.npy' % (30, 219))

    #         Feature Selection      #
    # Made_X = Made_X_[:, :, [-4]]
    # Made_X = Made_X_[:, :, :4]
    Made_X = Made_X_[:, :, :4]
    # Made_X2 = Made_X2[:, :, [0, 2, 3, 1]]


    #         Train Limit         #
    # Made_X = Made_X[-4000:]
    # Made_Y = Made_Y[-4000:]
    Made_X_test = Made_X_test_[:, :, :4]
    print('Made_X.shape :', Made_X.shape)
    print('Made_Y.shape :', Made_Y.shape)
    print('Made_X_test.shape :', Made_X_test.shape)
    print('Made_Z_test.shape :', Made_Z_test.shape)

    # print('min(Made_Z_test) :', np.min(Made_Z_test))
    # print(sum(sum(Made_X != Made_X2)))
    # break

    row = Made_X.shape[1]
    col = Made_X.shape[2]

    X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                        shuffle=False)
    X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
    X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)

    Y_train = Y_train.astype('float32')
    Y_val = Y_val.astype('float32')
    
    X_test = Made_X_test
    print('np.unique(Made_Y) :', np.unique(Made_Y, return_counts=True))
    print('np.unique(Y_train) :', np.unique(Y_train, return_counts=True))
    print('np.unique(Y_val) :', np.unique(Y_val, return_counts=True))

    Y_train = np_utils.to_categorical(Y_train, num_classes)
    Y_val = np_utils.to_categorical(Y_val, num_classes)
    
    print('X_train.shape :', X_train.shape)
    print('X_val.shape :', X_val.shape)

      
    for model_i, model_num in enumerate([model_num]):

      print('model_num :', model_num)
      if model_i == 0:
        print('Pred by Real')
      else:
        print('Pred by None Real')

      model_path = gdrive_path + "model/rapid_ascending %s_futures_rnn.hdf5" % model_num
      model = load_model(model_path)

      #     val, train -> confidence 와 evaluate 용
      val_y_pred_ = model.predict(X_val, verbose=1)
      train_y_pred_ = model.predict(X_train, verbose=1)

      # val_y_pred_ = np.argmax(val_y_pred_, axis=1)
      val_y_pred_ = val_y_pred_[:, [1]]
      train_y_pred_ = train_y_pred_[:, [1]]

      # print('len(val_y_pred_) :', len(val_y_pred_))
      #     test -> profit 용
      test_y_pred_ = model.predict(X_test, verbose=1).ravel()

      val_fpr, val_tpr, val_thr = roc_curve(Y_val[:, [1]], val_y_pred_)
      train_fpr, train_tpr, train_thr = roc_curve(Y_train[:, [1]], train_y_pred_)

      val_auc = auc(val_fpr, val_tpr)
      train_auc = auc(train_fpr, train_tpr)

      # precision = precision_score(t_te, y_pred) * 100
      f1 = f1_score(Y_val[:, [1]], val_y_pred_) * 100
      print('f1 :', f1)

      plt.figure(figsize=(10, 5))

      plt.subplot(121)
      plt.plot([0, 1], [0, 1], 'k--')
      plt.plot(val_fpr, val_tpr)
      plt.title('Val AUC = %.2f' % val_auc, color='white', fontsize=10)
      
      plt.subplot(122)
      plt.plot([0, 1], [0, 1], 'k--')
      plt.plot(train_fpr, train_tpr)
      plt.title('Train AUC = %.2f' % val_auc, color='white', fontsize=10)
      plt.show()
# Out:
# Made_X.shape : (2290, 30, 4)
# Made_Y.shape : (2290, 1)
# Made_X_test.shape : (1914, 30, 4)
# Made_Z_test.shape : (1914, 4)
# np.unique(Made_Y) : (array([0., 1.]), array([1780,  510]))
# np.unique(Y_train) : (array([0., 1.], dtype=float32), array([1149,  454]))
# np.unique(Y_val) : (array([0., 1.], dtype=float32), array([631,  56]))
# X_train.shape : (1603, 30, 4)
# X_val.shape : (687, 30, 4)
# model_num : 1180
# Pred by Real
# 22/22 [==============================] - 0s 1ms/step
# 51/51 [==============================] - 0s 1ms/step
# 60/60 [==============================] - 0s 1ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-7d274cf28d3a> in <module>()
#      99
#     100       # precision = precision_score(t_te, y_pred) * 100
# --> 101       f1 = f1_score(Y_val[:, [1]], val_y_pred_) * 100
#     102       print('f1 :', f1)
#     103
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1097                        pos_label=pos_label, average=average,
#    1098                        sample_weight=sample_weight,
# -> 1099                        zero_division=zero_division)
#    1100
#    1101
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1224                                                  warn_for=('f-score',),
#    1225                                                  sample_weight=sample_weight,
# -> 1226                                                  zero_division=zero_division)
#    1227     return f
#    1228
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1482         raise ValueError("beta should be >=0 in the F-beta score")
#    1483     labels = _check_set_wise_labels(y_true, y_pred, average, labels,
# -> 1484                                     pos_label)
#    1485
#    1486     # Calculate tp_sum, pred_sum, true_sum ###
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1299                          str(average_options))
#    1300
# -> 1301     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1302     present_labels = unique_labels(y_true, y_pred)
#    1303     if average == 'binary':
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      88     if len(y_type) > 1:
#      89         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 90                          "and {1} targets".format(type_true, type_pred))
#      91
#      92     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %% [markdown]
# ### ***Find Best Confidence***

# %%
total_profit_result = np.array(total_profit_result)
print('total_profit_result.shape :', total_profit_result.shape)
total_profit_sum = np.sum(total_profit_result, axis=0)
# print(total_profit_sum)

# plt.hist(x_ticks, bins=len(x_ticks),weights=total_profit_sum)
plt.plot(x_ticks, total_profit_sum)
plt.plot(x_ticks[np.argmax(total_profit_sum)], max(total_profit_sum), 'o', color='red')
plt.show()

print(x_ticks[np.argmax(total_profit_sum)])
# Out:
# total_profit_result.shape : (34, 100)
# 0.56

# %% [markdown]
# ### ***Find Best Partial***

# %%
max_tp_ratio = 1.
remain_qty = 1
partial_num = 10
tp_list = list()
qty_list = list()
for i in range(partial_num, 0, -1):

  tp_list.append(max_tp_ratio * i / partial_num)
  # df['long_tp_1'] = df['ep'] + abs(df['ep'] - df['long_sl']) * tp_ratio * 2 / 3

  if i != 1:
    qty = remain_qty / 1.5
    remain_qty -= qty
  else:
    qty = remain_qty

  qty_list.append(qty)

# print(tp_list)
# print(np.array([tp_list, qty_list]).astype(np.float64))
print('total_income :', np.sum(np.prod(np.array([tp_list, qty_list]), axis=0)))
# Out:
# total_income : 0.9500025402631713

# %% [markdown]
# ### ***None Realtime vs Realtime***

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model
import matplotlib.pyplot as plt

for model_num in model_range:

  try:

    #     Get Test Dataset   #
    Made_X_ = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num + 41 * 3))
    Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num + 41 * 3)).reshape(-1, 1)

    #       dataset 분리      #
    # dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    # dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
    # Made_X = Made_X_[:, :, [-4]]
    Made_X = Made_X_[:, :, :4]
    # print(Made_X.shape)
    # print(Made_Y.shape)
    # break

    row = Made_X.shape[1]
    col = Made_X.shape[2]

    # X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
    #                                                   shuffle=False)

    # X_train = X_train.astype('float32')#.reshape(-1, input_data_length, col, 1)
    # X_val = X_val.astype('float32')#.reshape(-1, input_data_length, col, 1)

    X_test = Made_X.astype('float32')
    Y_test = Made_Y
    
    for model_i, model_num in enumerate([model_num, model_num + 41]):

      if model_i == 0:
        print('Pred by Real')
      else:
        print('Pred by None Real')

      model_path = gdrive_path + "model/rapid_ascending %s_%s_futures_rnn.hdf5" % (input_data_length, model_num)
      model = load_model(model_path)
      y_pred_ = model.predict(X_test, verbose=1)
      # total_y_pred_ = model.predict(Made_X, verbose=1)

      plt.figure(figsize=(10, 6))
      
      for index, y_pred_ in enumerate([y_pred_]):

        # print('len(y_pred_) :', len(y_pred_))
        target_column = y_pred_[:, [-1]]
        # column_min, column_max = train_y_pred_.min(),train_y_pred_.max()
        column_min, column_max = target_column.min(),target_column.max()
        # print(column_min, column_max)

        x_ticks = np.arange(0.5, 1, 0.005)
        # x_ticks = np.arange(0.5, column_max, 0.005) <-- column_max 대응할만한 값을 찾아야한다. 1 까지는 사용못할것
        confidence_result = list()
        for confidence in x_ticks:
          # confidence = 0.9

          # if column_max < 0.5:
          #   break
          # else:
          #   scaled_confidence = .5 + (column_max - .5) * confidence
          scaled_confidence = column_min + (column_max - column_min) * confidence

          # scaled_confidence = confidence
          # print(scaled_confidence)
          # print('confidence :', confidence)

          y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )

          #   inverse version   #
          # confidence = 1 - confidence
          # scaled_confidence = y_pred_[:, [-1]].min() + (y_pred_[:, [-1]].max() - y_pred_[:, [-1]].min()) * confidence
          # y_pred = np.where(y_pred_[:, [-1]] <= scaled_confidence, 1, 0).reshape(-1, )

          #     결국, Categorical 은 index 값으로 value 를 나타내는 것    #
          # t_te = np.argmax(Y_val, axis=1)

          t_te = Y_test

          # print(y_pred_[:5])
          # print(Y_val[:5])
          # break

          pred_true = 0
          real_true = 0

          #       predict value 존나 높으면 True 일 확률 존나 높은건데, 그게 진짜 True가 맞냐 이걸 알고 싶은거지     #
          #       confidence를 만족하는 label이 1인 데이터 안에서 pred 1 / label 1 -> 이걸 도출해면 된다        #

          for i in range(len(y_pred)):
            if y_pred[i] == 1:  
              pred_true += 1
              if t_te[i] == y_pred[i]:
                real_true += 1

          true_true = real_true / pred_true * 100
          confidence_result.append(true_true)
          # print('True Pred / Total True : %s / %s' % (real_true, pred_true))
          # print('Accuracy : %2.f %%' % (true_true))
          # print()

        # if column_max < 0.5:
        #   continue
        
        plt.subplot(2, 4, index + 1 + model_i * 4)
        plt.plot(x_ticks, confidence_result)
        plt.axhline(50, linestyle='--', color='red')
        plt.ylim(-5, 105)
        plt.title('%s %s' % ((column_min, column_max)), color='white', fontsize=10)

        if index == 0:
          plt.subplot(2, 4, index + 3 + model_i * 4)
          plt.plot(Made_X_[:, [-1], [3]])
        elif index == 1:
          plt.subplot(2, 4, index + 3 + model_i * 4)
          plt.plot(Made_X_[:, [-1], [3]])

    plt.show()

  except Exception as e:
    print('Error occured : ', e)
  print()
# Out:
# Pred by Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 2ms/step
# Pred by Real
# 65/65 [==============================] - 0s 951us/step
# Pred by None Real
# 65/65 [==============================] - 0s 944us/step
# Pred by Real
# 65/65 [==============================] - 0s 2ms/step
# Pred by None Real
# 65/65 [==============================] - 0s 1ms/step
# Pred by Real
# 67/67 [==============================] - 0s 2ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 68/68 [==============================] - 0s 2ms/step
# Pred by None Real
# 68/68 [==============================] - 0s 2ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_227_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
#
# Pred by Real
# 67/67 [==============================] - 0s 2ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 2ms/step
# Pred by Real
# 66/66 [==============================] - 0s 2ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 65/65 [==============================] - 0s 2ms/step
# Pred by None Real
# 65/65 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 2ms/step
# Pred by Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by Real
# 64/64 [==============================] - 0s 2ms/step
# Pred by None Real
# 64/64 [==============================] - 0s 1ms/step
# Pred by Real
# 63/63 [==============================] - 0s 1ms/step
# Pred by None Real
# 63/63 [==============================] - 0s 2ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 2ms/step
# Pred by Real
# 63/63 [==============================] - 0s 1ms/step
# Pred by None Real
# 63/63 [==============================] - 0s 1ms/step
# Pred by Real
# 64/64 [==============================] - 0s 1ms/step
# Pred by None Real
# 64/64 [==============================] - 0s 1ms/step
# Pred by Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by Real
# 65/65 [==============================] - 0s 1ms/step
# Pred by None Real
# 65/65 [==============================] - 0s 2ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by Real
# 69/69 [==============================] - 0s 1ms/step
# Pred by None Real
# 69/69 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 2ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Pred by Real
# 68/68 [==============================] - 0s 2ms/step
# Pred by None Real
# 68/68 [==============================] - 0s 1ms/step
# Pred by Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by None Real
# 67/67 [==============================] - 0s 1ms/step
# Pred by Real
# 64/64 [==============================] - 0s 1ms/step
# Pred by None Real
# 64/64 [==============================] - 0s 1ms/step
# Pred by Real
# 66/66 [==============================] - 0s 2ms/step
# Pred by None Real
# 66/66 [==============================] - 0s 1ms/step
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_376.npy'
#
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_377.npy'
#
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_378.npy'
#
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_379.npy'
#
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_380.npy'
#
# Pred by Real
# Error occured :  SavedModel file does not exist at: /content/gdrive/My Drive/Colab Notebooks/Project_Stock/model/rapid_ascending 30_258_futures_rnn.hdf5/{saved_model.pbtxt|saved_model.pb}
#
# Error occured :  [Errno 2] No such file or directory: '/content/gdrive/My Drive/Colab Notebooks/Project_Stock/Made_X/Made_X 30_382.npy'

# %% [markdown]
# ### ***Check Entry points in Chart***

# %%
#     Confidence value should be adjusted by min max scale in y_pred    #
from keras.models import load_model


confidence = 0.8
scaled_confidence = column_min + (column_max - column_min) * confidence
# print(scaled_confidence)
print('confidence :', confidence)

y_pred = np.where(target_column >= scaled_confidence, 1, 0).reshape(-1, )
t_te = np.argmax(Y_val, axis=1)

close = Made_X_[-len(X_val):, [-1], [3]]
plt.plot(close)
# plt.show()

long_marker_x = list()
long_marker_y = list()
for i in range(len(y_pred)):
  if y_pred[i] == 1:  
    if t_te[i] == y_pred[i]:
      long_marker_x.append(i)
      long_marker_y.append(close[i])
      

plt.plot(long_marker_x, long_marker_y, 'o', color='blue')
plt.show()
# Out:
# confidence : 0.8
