# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2
# !pip install vit-keras

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### load file list

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x
# from vit_keras import *
# from vit_keras.vit import *

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

# from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# from vit_keras import vit, utils


gdrive_path = current_path

num_classes = 2

# %% [markdown]
# ### vit model

# %%
image_shape = (45, 5, 3)

# model = build_model(
#         **CONFIG_B,
#         name="vit-b16",
#         patch_size=1,
#         image_shape=image_shape,
#         classes=num_classes,
#         activation="sigmoid",
#         include_top=False,
#     )

# print(CONFIG_B)

# %% [markdown]
# ### custom model

# %%
def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model

# %% [markdown]
# ### all in one loop

# %%
print(ohlcv['close'].pct_change(10).head(20))
print((ohlcv['close'] / ohlcv['close'].shift(10)).head(20) - 1)

# %%
from funcs_indicator import *
import matplotlib.pyplot as plt

# import mpl_finance as mf


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None


term = 10

#           load saved npy & trained model        #
load_npy = False
load_model = False


seed = 1
random_state = 201
np.random.seed(seed)

fee = 0.0006
lvrg = 5

for i in range(len(candis)):

  keys = [candis[i]]

  if 'eth'.upper() not in candis[i]:
    continue

  # if 'comp'.upper() not in candis[i]:
  #   continue

  for key in keys:  
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))

        
    #       long      #
    pr = (ohlcv['close'].pct_change() - fee) * lvrg + 1    

    #       long liqudation     #
    lq = (ohlcv['low'] / ohlcv['close'].shift(1) - fee - 1) * lvrg + 1

    #       short       # <-- 이거를 단순히 minus 를 붙여도 되는걸까
    s_pr = (-ohlcv['close'].pct_change() - fee) * lvrg + 1

    #       short liqudation     #
    # s_lq = (ohlcv['high'] / ohlcv['close'].shift(1) - fee) * lvrg + 1
    

    #       fill na with 1.0      #
    # pr = np.where(np.isnan(pr), 1, pr)
    # print(len(pr))
    # print("len(pr[np.isnan(pr)]) :", len(pr[np.isnan(pr)]))
    # print("np.sum(np.isnan(pr)) :", np.sum(np.isnan(pr)))
    
    # sliced_ohlcv = ohlcv[np.sum(np.isnan(pr))]
    # print(sliced_ohlcv.head())
    # break
    # s_pr = np.where(np.isnan(s_pr), 1, pr)
    # lq = np.where(np.isnan(lq), 1, lq)


    #       set lq      #
    # pr = np.where((pr != 1) & (lq <= 0), 0, pr)

    # print("len(pr[pr < 0]) :", len(pr[pr < 0]))
    # break

    org_wr = len(pr[pr > 1]) / len(pr[pr != 1])

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(pr))
    plt.title("%s\norg_wr : %.3f\n acc_pr : %.3f" % (key, org_wr, np.cumprod(pr)[-1]))


    #                    strat                   #

    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) < ohlcv['close'].shift(3)), pr, 1)


    # strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
    #                     (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
    #                     (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
    #                     (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)), pr, 1)


    strat_pr = np.where((ohlcv['close'].shift(1) < ohlcv['close'].shift(2)) & 
                        (ohlcv['close'].shift(2) > ohlcv['close'].shift(3)) & 
                        (ohlcv['close'].shift(3) > ohlcv['close'].shift(4)) & 
                        (ohlcv['close'].shift(4) < ohlcv['close'].shift(5)) & 
                        (ohlcv['close'].shift(5) < ohlcv['close'].shift(6)), pr, 1)
    
    # strat_pr = np.where((ohlcv['high'].shift(2) > ohlcv['high'].shift(3))& 
    #                     (ohlcv['close'].shift(1) > ohlcv['close'].shift(2)), pr, 1)


    wr = len(strat_pr[strat_pr > 1]) / len(strat_pr[strat_pr != 1])

    plt.subplot(122)
    plt.plot(np.cumprod(strat_pr))
    plt.title("%s\norg_wr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr, np.cumprod(strat_pr)[-1]))


    # #                  sl cut                #
    # sl_line = ohlcv['low'].rolling(250).min().shift(1)
    # # sl_line = ohlcv['low'].shift(1)

    # strat_pr_sl = np.where((strat_pr != 1) & (sl_line > ohlcv['low']), 
    #                      1 + lvrg * (sl_line / ohlcv['close'].shift(1) - 1 - fee), strat_pr)


    # wr_sl = len(strat_pr_sl[strat_pr_sl > 1]) / len(strat_pr_sl[strat_pr_sl != 1])
    # # wl_pr_ratio = np.mean(strat_pr[strat_pr > 1]) / np.mean(strat_pr[strat_pr < 1])
    # # wl_pr_ratio = np.cumprod(strat_pr[strat_pr > 1])[-1] / np.cumprod(strat_pr[strat_pr < 1])[-1]

    # plt.subplot(122)
    # plt.plot(np.cumprod(strat_pr_sl))
    # plt.title("%s\norg_pr : %.3f\n wr : %.5f\nacc_pr : %.3f" % (key, org_wr, wr_sl, np.cumprod(strat_pr_sl)[-1]))


    plt.show()
    # break

    period = 45
    symbol_name = key.split(' ')[1].split('.')[0]      

    x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_term_%s_%s_tssplit.npy' % (period, term, symbol_name)
    pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_term_%s_%s_tssplit.npy' % (period, term, symbol_name)
    index_save_path = current_path + 'npy/' + '%s_cnn_updown_index_train_term_%s_%s_tssplit.npy' % (period, term, symbol_name)



    if not load_npy:

      from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
      from sklearn.model_selection import train_test_split
      from datetime import datetime

      from funcs_indicator import *

      def min_max_scale(npy_x):

        return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[np.sum(np.isnan(pr)):]

      sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

      #       scale with price    #
      ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

      ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
      sar = lucid_sar(sliced_ohlcv)
      ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
      senkou1, senkou2 = ichimoku(sliced_ohlcv)

      #     min max scale   #
      vol = ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]
      # vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

      pr_list = pr[np.sum(np.isnan(pr)):]
      print("len(ohlc) :", len(ohlc))
      print("len(pr_list) :", len(pr_list))

      # break


      #       set params    #
      period = 45
      key_i = i

      plotting = True

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(ohlc), term):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          # temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

          temp_close = min_max_scale(temp_ohlc[:, [3]])    

          price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          ind_temp_ohlc = min_max_scale(temp_ohlc)
          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


          if plotting:

            plt.plot(ind_temp_ohlc)
            plt.show()
            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          #                   feature selection                   #        
          temp_data = np.hstack((ind_temp_ohlc, temp_vol))

          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          # temp_data = temp_ohlc[:, [3]]
          # temp_data = ind_temp_ohlc[:, [3]]
          # temp_data = temp_close

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i + term])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      # input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)


      # _, row, col, _ = input_x.shape
      # _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      #                 don't shuffle timeseries data                 #
      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)


      np.save(x_save_path, x_train)
      np.save(x_save_path.replace('x_train', 'x_val'), x_val)
      np.save(x_save_path.replace('x_train', 'x_test'), x_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('x series saved !')

      np.save(pr_save_path, pr_train)
      np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
      np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
      # np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
      print('pr series saved !')
      
      np.save(index_save_path, index_train)
      np.save(index_save_path.replace('index_train', 'index_val'), index_val)
      np.save(index_save_path.replace('index_train', 'index_test'), index_test)
      print('index series saved !')

    else:
      
      x_train = np.load(x_save_path)
      x_val = np.load(x_save_path.replace('x_train', 'x_val'))
      x_test = np.load(x_save_path.replace('x_train', 'x_test'))
      print('x series loaded !')


      pr_train = np.load(pr_save_path)
      pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
      pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
      print('y series loaded !')


      index_train = np.load(index_save_path, allow_pickle=True)
      index_val = np.load(index_save_path.replace('index_train', 'index_val'), allow_pickle=True)
      index_test = np.load(index_save_path.replace('index_train', 'index_test'), allow_pickle=True)
      print('index series loaded !')




    #       pr_thresh by percentage 0.285     #
    plt.plot(pr)
    plt.show()
    
    # sorted_pr = sorted(pr, reverse=True)
    # pct = 0.28
    # len_pct = int(len(pr) * pct)
    # pr_thresh = sorted_pr[len_pct]
    # print("pr_thresh :", pr_thresh)

    pr_thresh = 1

    from keras.utils import np_utils

    # from keras.preprocessing.image import ImageDataGenerator 
    from sklearn.utils import class_weight


    def class_ratio(in_list):

      return in_list / in_list[1]
      
    y_train = np.where(pr_train > pr_thresh, 1, 0)
    y_test = np.where(pr_test > pr_thresh, 1, 0)
    y_val = np.where(pr_val > pr_thresh, 1, 0)

    print('x_train.shape :', x_train.shape)
    print('x_test.shape :', x_test.shape)
    print('x_val.shape :', x_val.shape)
    print('y_train.shape :', y_train.shape)
    print('y_test.shape :', y_test.shape)
    print('y_val.shape :', y_val.shape)

    # try:
    print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
    print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
    print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

    # except Exception as e:
      # print(e)

    label = y_train.reshape(-1, )
    class_weights = class_weight.compute_class_weight('balanced', 
                                                        classes=np.unique(label),
                                                        y=label)
    class_weights = dict(enumerate(class_weights))
    print('class_weights :', class_weights)

    # sample_weight = np.ones(shape=(len(y_train),))
    # sample_weight[(y_train == 1).reshape(-1,)] = 1.5
    # print('sample_weight[:20] :', sample_weight[:20])


    print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
    print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
    print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

    print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
    print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
    print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

    y_train_ohe = np_utils.to_categorical(y_train, num_classes)
    y_val_ohe = np_utils.to_categorical(y_val, num_classes)
    y_test_ohe = np_utils.to_categorical(y_test, num_classes)
    print('y_train_ohe.shape :', y_train_ohe.shape)
    print('y_val_ohe.shape :', y_val_ohe.shape)
    print('y_test_ohe.shape :', y_test_ohe.shape)

    from keras.preprocessing.image import ImageDataGenerator 

    datagen = ImageDataGenerator( 
        # rotation_range = 45,
        # zoom_range = 0.5,
        # shear_range = 0.5,
        # horizontal_flip = True,
        # vertical_flip = True,
        # width_shift_range=0.5,
        # height_shift_range=0.5,
        # fill_mode = 'nearest'
        )

    valgen = ImageDataGenerator( 
        )

    datagen.fit(x_train)
    valgen.fit(x_val)


    batch_size = 512


    for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

        plt.suptitle("train x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break

    for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

        plt.suptitle("val x_batch")

        for i in range(0, 9): 
            plt.subplot(330 + 1 + i) 
            # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
            # cmapped = plt.cm.Set1(resized)
            # plt.imshow(cmapped)
            # plt.imshow(x_batch[i].reshape(row, col))
            plt.imshow(x_batch[i])
            plt.axis('off') 
        plt.show() 
        break
        
    train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
    val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
    # break

    

    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'

    # batch_size = 512

    K.clear_session()


    # model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)
    model_name = 'classifier_%s_cnn_updown_rascend_modvol_%s_%s_term.h5' % (period, term, symbol_name)



    if not load_model:

      from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard      
      
      # model = build_model(
      #         **CONFIG_B,
      #         name="vit-b16",
      #         patch_size=1,
      #         image_shape=x_train.shape[1:],
      #         classes=num_classes,
      #         activation="sigmoid",
      #         include_top=False,
      #     )

      model = FER_Model(input_shape=x_train.shape[1:])

      opt = Adam(lr=0.00001, decay=0.000005)
      # opt = Adam(lr=0.001, decay=0.0005)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir=board_path,
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]
      # callbacks_list = [checkpoint, checkpoint2]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 1000
      history = model.fit_generator(train_flow, 
                          steps_per_epoch=len(x_train) / batch_size, 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=val_flow,  
                          validation_steps=len(x_val) / batch_size,
                          shuffle=False)
      
    
    ckpt_path = current_path + 'ckpt/'
    board_path = current_path + 'graph/'


    model = keras.models.load_model(ckpt_path + model_name)

    test_result = model.predict(x_test)
    # test_result = model.predict(test_set)

    print('test_result.shape :', test_result.shape)
    # print('pr_val.shape :', pr_val.shape)

    y_score = test_result[:, [1]]
    print('y_test[:5] :', y_test.reshape(-1,)[:5])
    # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
    print('y_score[:5] :', y_score[:5])
    # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

    print('y_test.shape :', y_test.shape)
    print('y_score.shape :', y_score.shape)

    print('len(y_test) :', len(y_test))

    #     precision recall curve   #
    precision, recall, threshold = precision_recall_curve(y_test, y_score)
    precision, recall = precision[:-1], recall[:-1]

    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    plt.show()
    # print(y_pred)


    # threshold = [0.65]
    # print('threshold :', threshold)
    # break

    acc_pr_bythr = []
    new_thresh = []

    for thresh in threshold:
      
      # if thresh < 0.5:
      #     continue

      y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
      # print('y_pred.shape :', y_pred.shape)
      # print('y_pred :', y_pred)

      #     compare precision     #

      # print('precision :', precision_score(y_test, y_pred))
      # print('recall :', recall_score(y_test, y_pred))
      # print()

      # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
      # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

      # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
      # # plt.show()  
      # print()

      #     check win-ratio improvement     #
      cmat = confusion_matrix(y_test, y_pred)
      # print(cmat)
      # print(np.sum(cmat, axis=1))

      test_size = len(y_test)
      test_pr_list = pr_test
      # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

      org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
      ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
      # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

      # print('pr_test.shape :', pr_test.shape)

      # print(y_pred)
      # print(test_pr_list)

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
      # print('pred_pr_list.shape :', pred_pr_list.shape)

      # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
      #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
      #   print('thresh :', thresh)
        
      # if len(threshold) == 1:
    #   plt.figure(figsize=(10, 5))
    #   plt.subplot(121)
    #   plt.plot(np.cumprod(test_pr_list))
    #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
    # # plt.show()

    #   plt.subplot(122)
    #   plt.plot(np.cumprod(pred_pr_list))
    #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
    #   plt.show()


      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)


    print('acc_pr_bythr :', acc_pr_bythr)

    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(threshold, precision, label='precision')
    plt.plot(threshold, recall, label='recall')
    plt.legend()
    plt.title('precision recall')
    # plt.show()
    plt.subplot(122)
    plt.plot(new_thresh, acc_pr_bythr)
    plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
    plt.title(symbol_name)
    plt.show()
# Out:
# start_stamp : 0
# len(ohlcv) : 18048
# len(ohlc) : 18047
# len(pr_list) : 18047
# np.array(data_x).shape : (17916, 45, 5)
# input_x.shape : (17916, 45, 5, 3)
# input_x.dtype : float32
# input_pr.shape : (17916, 1)
# input_ud.shape : (17916, 1)
# input_index.shape : (17916, 1)
# total_x.shape : (17916, 45, 5, 3)
# total_pr.shape : (17916, 1)
# total_ud.shape : (17916, 1)
# prev_index.shape : (17916, 1)
# (array([Timestamp('2020-04-19 13:29:59.999000'),
#        Timestamp('2020-04-19 13:59:59.999000'),
#        Timestamp('2020-04-19 14:29:59.999000'), ...,
#        Timestamp('2021-04-27 17:59:59.999000'),
#        Timestamp('2021-04-27 18:29:59.999000'),
#        Timestamp('2021-04-27 18:59:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (10749,)
# stamp_val.shape : (3583,)
# stamp_test.shape : (3584,)
# HBox(children=(FloatProgress(value=0.0, max=17916.0), HTML(value='')))
# x_train.shape : (10749, 45, 5, 3)
# x_val.shape : (3583, 45, 5, 3)
# x_test.shape : (3584, 45, 5, 3)
# x series saved !
# pr series saved !
# index series saved !
# x_train.shape : (10749, 45, 5, 3)
# x_test.shape : (3584, 45, 5, 3)
# x_val.shape : (3583, 45, 5, 3)
# y_train.shape : (10749, 1)
# y_test.shape : (3584, 1)
# y_val.shape : (3583, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([5939, 4810])) [1.23471933 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([1959, 1624])) [1.20628079 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([1909, 1675])) [1.13970149 1.        ]
# class_weights : {0: 0.9049503283381041, 1: 1.1173596673596673}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10749, 2)
# y_val_ohe.shape : (3583, 2)
# y_test_ohe.shape : (3584, 2)
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1915: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/1000
# 20/20 - 4s - loss: 0.7188 - accuracy: 0.5068 - val_loss: 0.6897 - val_accuracy: 0.5334
#
# Epoch 00001: val_loss improved from inf to 0.68975, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_modvol_10_ETHUSDT_term.h5
# Epoch 2/1000
# 20/20 - 1s - loss: 0.6948 - accuracy: 0.4973 - val_loss: 0.6913 - val_accuracy: 0.5289
#
# Epoch 00002: val_loss did not improve from 0.68975
# Epoch 3/1000
# 20/20 - 1s - loss: 0.6942 - accuracy: 0.5103 - val_loss: 0.7019 - val_accuracy: 0.4597
#
# Epoch 00003: val_loss did not improve from 0.68975
# Epoch 4/1000
# 20/20 - 1s - loss: 0.6931 - accuracy: 0.5231 - val_loss: 0.6912 - val_accuracy: 0.5250
#
# Epoch 00004: val_loss did not improve from 0.68975
# Epoch 5/1000
# 20/20 - 1s - loss: 0.6936 - accuracy: 0.5081 - val_loss: 0.6892 - val_accuracy: 0.5484
#
# Epoch 00005: val_loss improved from 0.68975 to 0.68918, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_updown_rascend_modvol_10_ETHUSDT_term.h5
# Epoch 6/1000
# 20/20 - 2s - loss: 0.6932 - accuracy: 0.5169 - val_loss: 0.6898 - val_accuracy: 0.5375
#
# Epoch 00006: val_loss did not improve from 0.68918
# Epoch 7/1000
# 20/20 - 1s - loss: 0.6923 - accuracy: 0.5206 - val_loss: 0.6898 - val_accuracy: 0.5303
#
# Epoch 00007: val_loss did not improve from 0.68918
# Epoch 8/1000
# 20/20 - 1s - loss: 0.6913 - accuracy: 0.5239 - val_loss: 0.6911 - val_accuracy: 0.5250
#
# Epoch 00008: val_loss did not improve from 0.68918
# Epoch 9/1000
# 20/20 - 1s - loss: 0.6895 - accuracy: 0.5297 - val_loss: 0.6915 - val_accuracy: 0.5247
#
# Epoch 00009: val_loss did not improve from 0.68918
# Epoch 10/1000
# 20/20 - 1s - loss: 0.6905 - accuracy: 0.5316 - val_loss: 0.6897 - val_accuracy: 0.5434
#
# Epoch 00010: val_loss did not improve from 0.68918
# Epoch 11/1000
# 20/20 - 1s - loss: 0.6901 - accuracy: 0.5266 - val_loss: 0.6994 - val_accuracy: 0.4820
#
# Epoch 00011: val_loss did not improve from 0.68918
# Epoch 12/1000
# 20/20 - 1s - loss: 0.6888 - accuracy: 0.5414 - val_loss: 0.6930 - val_accuracy: 0.5169
#
# Epoch 00012: val_loss did not improve from 0.68918
# Epoch 13/1000
# 20/20 - 1s - loss: 0.6884 - accuracy: 0.5334 - val_loss: 0.6933 - val_accuracy: 0.5197
#
# Epoch 00013: val_loss did not improve from 0.68918
# Epoch 14/1000
# 20/20 - 1s - loss: 0.6875 - accuracy: 0.5436 - val_loss: 0.6925 - val_accuracy: 0.5155
#
# Epoch 00014: val_loss did not improve from 0.68918
# Epoch 15/1000
# 20/20 - 1s - loss: 0.6867 - accuracy: 0.5441 - val_loss: 0.7051 - val_accuracy: 0.4700
#
# Epoch 00015: val_loss did not improve from 0.68918
# Epoch 16/1000
# 20/20 - 1s - loss: 0.6871 - accuracy: 0.5398 - val_loss: 0.6938 - val_accuracy: 0.5057
#
# Epoch 00016: val_loss did not improve from 0.68918
# Epoch 17/1000
# 20/20 - 1s - loss: 0.6893 - accuracy: 0.5427 - val_loss: 0.6924 - val_accuracy: 0.5495
#
# Epoch 00017: val_loss did not improve from 0.68918
# Epoch 18/1000
# 20/20 - 1s - loss: 0.6907 - accuracy: 0.5255 - val_loss: 0.6981 - val_accuracy: 0.4893
#
# Epoch 00018: val_loss did not improve from 0.68918
# Epoch 19/1000
# 20/20 - 1s - loss: 0.6857 - accuracy: 0.5509 - val_loss: 0.6976 - val_accuracy: 0.4982
#
# Epoch 00019: val_loss did not improve from 0.68918
# Epoch 20/1000
# 20/20 - 1s - loss: 0.6866 - accuracy: 0.5479 - val_loss: 0.6999 - val_accuracy: 0.4946
#
# Epoch 00020: val_loss did not improve from 0.68918
# Epoch 21/1000
# 20/20 - 1s - loss: 0.6843 - accuracy: 0.5471 - val_loss: 0.6928 - val_accuracy: 0.5188
#
# Epoch 00021: val_loss did not improve from 0.68918
# Epoch 22/1000
# 20/20 - 1s - loss: 0.6877 - accuracy: 0.5446 - val_loss: 0.6918 - val_accuracy: 0.5247
#
# Epoch 00022: val_loss did not improve from 0.68918
# Epoch 23/1000
# 20/20 - 1s - loss: 0.6850 - accuracy: 0.5500 - val_loss: 0.7033 - val_accuracy: 0.4789
#
# Epoch 00023: val_loss did not improve from 0.68918
# Epoch 24/1000
# 20/20 - 1s - loss: 0.6845 - accuracy: 0.5534 - val_loss: 0.6940 - val_accuracy: 0.5147
#
# Epoch 00024: val_loss did not improve from 0.68918
# Epoch 25/1000
# 20/20 - 1s - loss: 0.6844 - accuracy: 0.5515 - val_loss: 0.6936 - val_accuracy: 0.5110
#
# Epoch 00025: val_loss did not improve from 0.68918
# Epoch 26/1000
# 20/20 - 1s - loss: 0.6829 - accuracy: 0.5645 - val_loss: 0.7191 - val_accuracy: 0.4647
#
# Epoch 00026: val_loss did not improve from 0.68918
# Epoch 27/1000
# 20/20 - 1s - loss: 0.6845 - accuracy: 0.5476 - val_loss: 0.6919 - val_accuracy: 0.5289
#
# Epoch 00027: val_loss did not improve from 0.68918
# Epoch 28/1000
# 20/20 - 1s - loss: 0.6830 - accuracy: 0.5535 - val_loss: 0.7136 - val_accuracy: 0.4675
#
# Epoch 00028: val_loss did not improve from 0.68918
# Epoch 29/1000
# 20/20 - 1s - loss: 0.6819 - accuracy: 0.5587 - val_loss: 0.6924 - val_accuracy: 0.5306
#
# Epoch 00029: val_loss did not improve from 0.68918
# Epoch 30/1000
# 20/20 - 1s - loss: 0.6824 - accuracy: 0.5676 - val_loss: 0.7059 - val_accuracy: 0.4873
#
# Epoch 00030: val_loss did not improve from 0.68918
# Epoch 31/1000
# 20/20 - 1s - loss: 0.6815 - accuracy: 0.5578 - val_loss: 0.7027 - val_accuracy: 0.4842
#
# Epoch 00031: val_loss did not improve from 0.68918
# Epoch 32/1000
# 20/20 - 1s - loss: 0.6819 - accuracy: 0.5532 - val_loss: 0.6953 - val_accuracy: 0.5074
#
# Epoch 00032: val_loss did not improve from 0.68918
# Epoch 33/1000
# 20/20 - 1s - loss: 0.6783 - accuracy: 0.5714 - val_loss: 0.6988 - val_accuracy: 0.4976
#
# Epoch 00033: val_loss did not improve from 0.68918
# Epoch 34/1000
# 20/20 - 1s - loss: 0.6771 - accuracy: 0.5748 - val_loss: 0.7049 - val_accuracy: 0.4867
#
# Epoch 00034: val_loss did not improve from 0.68918
# Epoch 35/1000
# 20/20 - 1s - loss: 0.6766 - accuracy: 0.5738 - val_loss: 0.6968 - val_accuracy: 0.5035
#
# Epoch 00035: val_loss did not improve from 0.68918
# Epoch 36/1000
# 20/20 - 1s - loss: 0.6750 - accuracy: 0.5766 - val_loss: 0.6958 - val_accuracy: 0.5169
#
# Epoch 00036: val_loss did not improve from 0.68918
# Epoch 37/1000
# 20/20 - 1s - loss: 0.6790 - accuracy: 0.5625 - val_loss: 0.6953 - val_accuracy: 0.5225
#
# Epoch 00037: val_loss did not improve from 0.68918
# Epoch 38/1000
# 20/20 - 1s - loss: 0.6787 - accuracy: 0.5594 - val_loss: 0.6959 - val_accuracy: 0.5133
#
# Epoch 00038: val_loss did not improve from 0.68918
# Epoch 39/1000
# 20/20 - 1s - loss: 0.6761 - accuracy: 0.5799 - val_loss: 0.7033 - val_accuracy: 0.4884
#
# Epoch 00039: val_loss did not improve from 0.68918
# Epoch 40/1000
# 20/20 - 1s - loss: 0.6738 - accuracy: 0.5807 - val_loss: 0.6984 - val_accuracy: 0.5264
#
# Epoch 00040: val_loss did not improve from 0.68918
# Epoch 41/1000
# 20/20 - 1s - loss: 0.6739 - accuracy: 0.5778 - val_loss: 0.6983 - val_accuracy: 0.5068
#
# Epoch 00041: val_loss did not improve from 0.68918
# Epoch 42/1000
# 20/20 - 1s - loss: 0.6704 - accuracy: 0.5898 - val_loss: 0.7006 - val_accuracy: 0.5099
#
# Epoch 00042: val_loss did not improve from 0.68918
# Epoch 43/1000
# 20/20 - 1s - loss: 0.6707 - accuracy: 0.5875 - val_loss: 0.7051 - val_accuracy: 0.4909
#
# Epoch 00043: val_loss did not improve from 0.68918
# Epoch 44/1000
# 20/20 - 1s - loss: 0.6671 - accuracy: 0.5958 - val_loss: 0.6998 - val_accuracy: 0.5138
#
# Epoch 00044: val_loss did not improve from 0.68918
# Epoch 45/1000
# 20/20 - 1s - loss: 0.6689 - accuracy: 0.5898 - val_loss: 0.7080 - val_accuracy: 0.4887
#
# Epoch 00045: val_loss did not improve from 0.68918
# Epoch 46/1000
# 20/20 - 1s - loss: 0.6703 - accuracy: 0.5813 - val_loss: 0.7078 - val_accuracy: 0.4865
#
# Epoch 00046: val_loss did not improve from 0.68918
# Epoch 47/1000
# 20/20 - 1s - loss: 0.6686 - accuracy: 0.5901 - val_loss: 0.6980 - val_accuracy: 0.5275
#
# Epoch 00047: val_loss did not improve from 0.68918
# Epoch 48/1000
# 20/20 - 1s - loss: 0.6678 - accuracy: 0.5916 - val_loss: 0.6996 - val_accuracy: 0.5093
#
# Epoch 00048: val_loss did not improve from 0.68918
# Epoch 49/1000
# 20/20 - 1s - loss: 0.6648 - accuracy: 0.6024 - val_loss: 0.7014 - val_accuracy: 0.5255
#
# Epoch 00049: val_loss did not improve from 0.68918
# Epoch 50/1000
# 20/20 - 1s - loss: 0.6650 - accuracy: 0.6006 - val_loss: 0.7077 - val_accuracy: 0.4890
#
# Epoch 00050: val_loss did not improve from 0.68918
# Epoch 51/1000
# 20/20 - 1s - loss: 0.6601 - accuracy: 0.6102 - val_loss: 0.7029 - val_accuracy: 0.4982
#
# Epoch 00051: val_loss did not improve from 0.68918
# Epoch 52/1000
# 20/20 - 1s - loss: 0.6634 - accuracy: 0.6017 - val_loss: 0.7028 - val_accuracy: 0.5093
#
# Epoch 00052: val_loss did not improve from 0.68918
# Epoch 53/1000
# 20/20 - 1s - loss: 0.6594 - accuracy: 0.6070 - val_loss: 0.7050 - val_accuracy: 0.5027
#
# Epoch 00053: val_loss did not improve from 0.68918
# Epoch 54/1000
# 20/20 - 1s - loss: 0.6590 - accuracy: 0.6086 - val_loss: 0.7028 - val_accuracy: 0.5119
#
# Epoch 00054: val_loss did not improve from 0.68918
# Epoch 55/1000
# 20/20 - 1s - loss: 0.6608 - accuracy: 0.6055 - val_loss: 0.7012 - val_accuracy: 0.5300
#
# Epoch 00055: val_loss did not improve from 0.68918
# Epoch 56/1000
# 20/20 - 1s - loss: 0.6570 - accuracy: 0.6126 - val_loss: 0.7145 - val_accuracy: 0.4915
#
# Epoch 00056: val_loss did not improve from 0.68918
# Epoch 57/1000
# 20/20 - 1s - loss: 0.6538 - accuracy: 0.6186 - val_loss: 0.7039 - val_accuracy: 0.5099
#
# Epoch 00057: val_loss did not improve from 0.68918
# Epoch 58/1000
# 20/20 - 1s - loss: 0.6554 - accuracy: 0.6125 - val_loss: 0.7037 - val_accuracy: 0.5107
#
# Epoch 00058: val_loss did not improve from 0.68918
# Epoch 59/1000
# 20/20 - 1s - loss: 0.6543 - accuracy: 0.6151 - val_loss: 0.7035 - val_accuracy: 0.5102
#
# Epoch 00059: val_loss did not improve from 0.68918
# Epoch 60/1000
# 20/20 - 1s - loss: 0.6528 - accuracy: 0.6215 - val_loss: 0.7116 - val_accuracy: 0.4957
#
# Epoch 00060: val_loss did not improve from 0.68918
# Epoch 61/1000
# 20/20 - 1s - loss: 0.6485 - accuracy: 0.6284 - val_loss: 0.7498 - val_accuracy: 0.4728
#
# Epoch 00061: val_loss did not improve from 0.68918
# Epoch 62/1000
# 20/20 - 1s - loss: 0.6485 - accuracy: 0.6282 - val_loss: 0.7142 - val_accuracy: 0.4923
#
# Epoch 00062: val_loss did not improve from 0.68918
# Epoch 63/1000
# 20/20 - 1s - loss: 0.6488 - accuracy: 0.6162 - val_loss: 0.7047 - val_accuracy: 0.5133
#
# Epoch 00063: val_loss did not improve from 0.68918
# Epoch 64/1000
# 20/20 - 1s - loss: 0.6468 - accuracy: 0.6328 - val_loss: 0.7122 - val_accuracy: 0.4867
#
# Epoch 00064: val_loss did not improve from 0.68918
# Epoch 65/1000
# 20/20 - 1s - loss: 0.6437 - accuracy: 0.6302 - val_loss: 0.7163 - val_accuracy: 0.5004
#
# Epoch 00065: val_loss did not improve from 0.68918
# Epoch 66/1000
# 20/20 - 1s - loss: 0.6461 - accuracy: 0.6282 - val_loss: 0.7244 - val_accuracy: 0.4840
#
# Epoch 00066: val_loss did not improve from 0.68918
# Epoch 67/1000
# 20/20 - 1s - loss: 0.6516 - accuracy: 0.6171 - val_loss: 0.7080 - val_accuracy: 0.5071
#
# Epoch 00067: val_loss did not improve from 0.68918
# Epoch 68/1000
# 20/20 - 1s - loss: 0.6420 - accuracy: 0.6344 - val_loss: 0.7153 - val_accuracy: 0.4912
#
# Epoch 00068: val_loss did not improve from 0.68918
# Epoch 69/1000
# 20/20 - 1s - loss: 0.6371 - accuracy: 0.6464 - val_loss: 0.7092 - val_accuracy: 0.4976
#
# Epoch 00069: val_loss did not improve from 0.68918
# Epoch 70/1000
# 20/20 - 1s - loss: 0.6368 - accuracy: 0.6486 - val_loss: 0.7094 - val_accuracy: 0.5105
#
# Epoch 00070: val_loss did not improve from 0.68918
# Epoch 71/1000
# 20/20 - 1s - loss: 0.6362 - accuracy: 0.6470 - val_loss: 0.7099 - val_accuracy: 0.5253
#
# Epoch 00071: val_loss did not improve from 0.68918
# Epoch 72/1000
# 20/20 - 1s - loss: 0.6397 - accuracy: 0.6332 - val_loss: 0.7155 - val_accuracy: 0.5320
#
# Epoch 00072: val_loss did not improve from 0.68918
# Epoch 73/1000
# 20/20 - 1s - loss: 0.6366 - accuracy: 0.6509 - val_loss: 0.7249 - val_accuracy: 0.4890
#
# Epoch 00073: val_loss did not improve from 0.68918
# Epoch 74/1000
# 20/20 - 1s - loss: 0.6324 - accuracy: 0.6485 - val_loss: 0.7135 - val_accuracy: 0.5269
#
# Epoch 00074: val_loss did not improve from 0.68918
# Epoch 75/1000
# 20/20 - 1s - loss: 0.6330 - accuracy: 0.6518 - val_loss: 0.7139 - val_accuracy: 0.5021
#
# Epoch 00075: val_loss did not improve from 0.68918
# Epoch 76/1000
# 20/20 - 1s - loss: 0.6318 - accuracy: 0.6499 - val_loss: 0.7174 - val_accuracy: 0.4915
#
# Epoch 00076: val_loss did not improve from 0.68918
# Epoch 77/1000
# 20/20 - 1s - loss: 0.6268 - accuracy: 0.6588 - val_loss: 0.7173 - val_accuracy: 0.4932
#
# Epoch 00077: val_loss did not improve from 0.68918
# Epoch 78/1000
# 20/20 - 1s - loss: 0.6250 - accuracy: 0.6653 - val_loss: 0.7146 - val_accuracy: 0.5021
#
# Epoch 00078: val_loss did not improve from 0.68918
# Epoch 79/1000
# 20/20 - 1s - loss: 0.6222 - accuracy: 0.6691 - val_loss: 0.7196 - val_accuracy: 0.4940
#
# Epoch 00079: val_loss did not improve from 0.68918
# Epoch 80/1000
# 20/20 - 1s - loss: 0.6213 - accuracy: 0.6688 - val_loss: 0.7310 - val_accuracy: 0.4809
#
# Epoch 00080: val_loss did not improve from 0.68918
# Epoch 81/1000
# 20/20 - 1s - loss: 0.6219 - accuracy: 0.6676 - val_loss: 0.7153 - val_accuracy: 0.5063
#
# Epoch 00081: val_loss did not improve from 0.68918
# Epoch 82/1000
# 20/20 - 1s - loss: 0.6194 - accuracy: 0.6686 - val_loss: 0.7206 - val_accuracy: 0.4912
#
# Epoch 00082: val_loss did not improve from 0.68918
# Epoch 83/1000
# 20/20 - 1s - loss: 0.6162 - accuracy: 0.6727 - val_loss: 0.7383 - val_accuracy: 0.4753
#
# Epoch 00083: val_loss did not improve from 0.68918
# Epoch 84/1000
# 20/20 - 1s - loss: 0.6137 - accuracy: 0.6820 - val_loss: 0.7231 - val_accuracy: 0.5021
#
# Epoch 00084: val_loss did not improve from 0.68918
# Epoch 85/1000
# 20/20 - 1s - loss: 0.6140 - accuracy: 0.6816 - val_loss: 0.7267 - val_accuracy: 0.4940
#
# Epoch 00085: val_loss did not improve from 0.68918
# Epoch 86/1000
# 20/20 - 1s - loss: 0.6112 - accuracy: 0.6815 - val_loss: 0.7336 - val_accuracy: 0.4912
#
# Epoch 00086: val_loss did not improve from 0.68918
# Epoch 87/1000
# 20/20 - 1s - loss: 0.6127 - accuracy: 0.6712 - val_loss: 0.7308 - val_accuracy: 0.4915
#
# Epoch 00087: val_loss did not improve from 0.68918
# Epoch 88/1000
# 20/20 - 1s - loss: 0.6078 - accuracy: 0.6866 - val_loss: 0.7267 - val_accuracy: 0.4940
#
# Epoch 00088: val_loss did not improve from 0.68918
# Epoch 89/1000
# 20/20 - 1s - loss: 0.6060 - accuracy: 0.6862 - val_loss: 0.7350 - val_accuracy: 0.4848
#
# Epoch 00089: val_loss did not improve from 0.68918
# Epoch 90/1000
# 20/20 - 1s - loss: 0.6050 - accuracy: 0.6886 - val_loss: 0.7438 - val_accuracy: 0.4862
#
# Epoch 00090: val_loss did not improve from 0.68918
# Epoch 91/1000
# 20/20 - 1s - loss: 0.6059 - accuracy: 0.6782 - val_loss: 0.7644 - val_accuracy: 0.4770
#
# Epoch 00091: val_loss did not improve from 0.68918
# Epoch 92/1000
# 20/20 - 1s - loss: 0.6046 - accuracy: 0.6860 - val_loss: 0.7332 - val_accuracy: 0.4920
#
# Epoch 00092: val_loss did not improve from 0.68918
# Epoch 93/1000
# 20/20 - 1s - loss: 0.6009 - accuracy: 0.6910 - val_loss: 0.7296 - val_accuracy: 0.4960
#
# Epoch 00093: val_loss did not improve from 0.68918
# Epoch 94/1000
# 20/20 - 1s - loss: 0.6009 - accuracy: 0.6934 - val_loss: 0.7248 - val_accuracy: 0.5127
#
# Epoch 00094: val_loss did not improve from 0.68918
# Epoch 95/1000
# 20/20 - 1s - loss: 0.5988 - accuracy: 0.6930 - val_loss: 0.7374 - val_accuracy: 0.4915
#
# Epoch 00095: val_loss did not improve from 0.68918
# Epoch 96/1000
# 20/20 - 1s - loss: 0.5943 - accuracy: 0.7049 - val_loss: 0.7276 - val_accuracy: 0.5174
#
# Epoch 00096: val_loss did not improve from 0.68918
# Epoch 97/1000
# 20/20 - 1s - loss: 0.5942 - accuracy: 0.6982 - val_loss: 0.7296 - val_accuracy: 0.4973
#
# Epoch 00097: val_loss did not improve from 0.68918
# Epoch 98/1000
# 20/20 - 1s - loss: 0.5908 - accuracy: 0.7078 - val_loss: 0.7338 - val_accuracy: 0.5057
#
# Epoch 00098: val_loss did not improve from 0.68918
# Epoch 99/1000
# 20/20 - 1s - loss: 0.5910 - accuracy: 0.7056 - val_loss: 0.7306 - val_accuracy: 0.5040
#
# Epoch 00099: val_loss did not improve from 0.68918
# Epoch 100/1000
# 20/20 - 1s - loss: 0.5913 - accuracy: 0.7019 - val_loss: 0.7500 - val_accuracy: 0.4795
#
# Epoch 00100: val_loss did not improve from 0.68918
# Epoch 101/1000
# 20/20 - 1s - loss: 0.5919 - accuracy: 0.6971 - val_loss: 0.7363 - val_accuracy: 0.5029
#
# Epoch 00101: val_loss did not improve from 0.68918
# Epoch 102/1000
# 20/20 - 1s - loss: 0.5893 - accuracy: 0.7021 - val_loss: 0.7463 - val_accuracy: 0.4856
#
# Epoch 00102: val_loss did not improve from 0.68918
# Epoch 103/1000
# 20/20 - 1s - loss: 0.5814 - accuracy: 0.7158 - val_loss: 0.7442 - val_accuracy: 0.4954
#
# Epoch 00103: val_loss did not improve from 0.68918
# Epoch 104/1000
# 20/20 - 1s - loss: 0.5821 - accuracy: 0.7086 - val_loss: 0.7368 - val_accuracy: 0.5043
#
# Epoch 00104: val_loss did not improve from 0.68918
# Epoch 105/1000
# 20/20 - 1s - loss: 0.5892 - accuracy: 0.6984 - val_loss: 0.7501 - val_accuracy: 0.5225
#
# Epoch 00105: val_loss did not improve from 0.68918
# Epoch 106/1000
# 20/20 - 1s - loss: 0.5837 - accuracy: 0.7048 - val_loss: 0.7563 - val_accuracy: 0.4817
#
# Epoch 00106: val_loss did not improve from 0.68918
# Epoch 107/1000
# 20/20 - 1s - loss: 0.5759 - accuracy: 0.7200 - val_loss: 0.7434 - val_accuracy: 0.4918
#
# Epoch 00107: val_loss did not improve from 0.68918
# Epoch 108/1000
# 20/20 - 1s - loss: 0.5730 - accuracy: 0.7206 - val_loss: 0.7457 - val_accuracy: 0.4960
#
# Epoch 00108: val_loss did not improve from 0.68918
# Epoch 109/1000
# 20/20 - 1s - loss: 0.5722 - accuracy: 0.7254 - val_loss: 0.7388 - val_accuracy: 0.5049
#
# Epoch 00109: val_loss did not improve from 0.68918
# Epoch 110/1000
# 20/20 - 1s - loss: 0.5717 - accuracy: 0.7237 - val_loss: 0.7438 - val_accuracy: 0.4990
#
# Epoch 00110: val_loss did not improve from 0.68918
# Epoch 111/1000
# 20/20 - 1s - loss: 0.5725 - accuracy: 0.7200 - val_loss: 0.7531 - val_accuracy: 0.4918
#
# Epoch 00111: val_loss did not improve from 0.68918
# Epoch 112/1000
# 20/20 - 1s - loss: 0.5660 - accuracy: 0.7284 - val_loss: 0.7454 - val_accuracy: 0.5010
#
# Epoch 00112: val_loss did not improve from 0.68918
# Epoch 113/1000
# 20/20 - 1s - loss: 0.5658 - accuracy: 0.7343 - val_loss: 0.7504 - val_accuracy: 0.4951
#
# Epoch 00113: val_loss did not improve from 0.68918
# Epoch 114/1000
# 20/20 - 1s - loss: 0.5723 - accuracy: 0.7102 - val_loss: 0.7415 - val_accuracy: 0.5116
#
# Epoch 00114: val_loss did not improve from 0.68918
# Epoch 115/1000
# 20/20 - 1s - loss: 0.5701 - accuracy: 0.7178 - val_loss: 0.7452 - val_accuracy: 0.4990
#
# Epoch 00115: val_loss did not improve from 0.68918
# Epoch 116/1000
# 20/20 - 1s - loss: 0.5609 - accuracy: 0.7295 - val_loss: 0.7558 - val_accuracy: 0.4960
#
# Epoch 00116: val_loss did not improve from 0.68918
# Epoch 117/1000
# 20/20 - 1s - loss: 0.5636 - accuracy: 0.7283 - val_loss: 0.7606 - val_accuracy: 0.4887
#
# Epoch 00117: val_loss did not improve from 0.68918
# Epoch 118/1000
# 20/20 - 1s - loss: 0.5557 - accuracy: 0.7444 - val_loss: 0.7483 - val_accuracy: 0.5027
#
# Epoch 00118: val_loss did not improve from 0.68918
# Epoch 119/1000
# 20/20 - 1s - loss: 0.5534 - accuracy: 0.7441 - val_loss: 0.7480 - val_accuracy: 0.5021
#
# Epoch 00119: val_loss did not improve from 0.68918
# Epoch 120/1000
# 20/20 - 1s - loss: 0.5570 - accuracy: 0.7355 - val_loss: 0.7505 - val_accuracy: 0.5091
#
# Epoch 00120: val_loss did not improve from 0.68918
# Epoch 121/1000
# 20/20 - 1s - loss: 0.5574 - accuracy: 0.7270 - val_loss: 0.7617 - val_accuracy: 0.4826
#
# Epoch 00121: val_loss did not improve from 0.68918
# Epoch 122/1000
# 20/20 - 1s - loss: 0.5485 - accuracy: 0.7419 - val_loss: 0.7566 - val_accuracy: 0.5029
#
# Epoch 00122: val_loss did not improve from 0.68918
# Epoch 123/1000
# 20/20 - 1s - loss: 0.5498 - accuracy: 0.7389 - val_loss: 0.7625 - val_accuracy: 0.4890
#
# Epoch 00123: val_loss did not improve from 0.68918
# Epoch 124/1000
# 20/20 - 1s - loss: 0.5468 - accuracy: 0.7435 - val_loss: 0.7600 - val_accuracy: 0.4993
#
# Epoch 00124: val_loss did not improve from 0.68918
# Epoch 125/1000
# 20/20 - 1s - loss: 0.5452 - accuracy: 0.7452 - val_loss: 0.7589 - val_accuracy: 0.5152
#
# Epoch 00125: val_loss did not improve from 0.68918
# Epoch 126/1000
# 20/20 - 1s - loss: 0.5476 - accuracy: 0.7455 - val_loss: 0.7783 - val_accuracy: 0.4834
#
# Epoch 00126: val_loss did not improve from 0.68918
# Epoch 127/1000
# 20/20 - 1s - loss: 0.5431 - accuracy: 0.7447 - val_loss: 0.7689 - val_accuracy: 0.4837
#
# Epoch 00127: val_loss did not improve from 0.68918
# Epoch 128/1000
# 20/20 - 1s - loss: 0.5398 - accuracy: 0.7523 - val_loss: 0.7637 - val_accuracy: 0.4976
#
# Epoch 00128: val_loss did not improve from 0.68918
# Epoch 129/1000
# 20/20 - 1s - loss: 0.5420 - accuracy: 0.7466 - val_loss: 0.7763 - val_accuracy: 0.4840
#
# Epoch 00129: val_loss did not improve from 0.68918
# Epoch 130/1000
# 20/20 - 1s - loss: 0.5354 - accuracy: 0.7561 - val_loss: 0.7665 - val_accuracy: 0.4976
#
# Epoch 00130: val_loss did not improve from 0.68918
# Epoch 131/1000
# 20/20 - 1s - loss: 0.5343 - accuracy: 0.7520 - val_loss: 0.7623 - val_accuracy: 0.5163
#
# Epoch 00131: val_loss did not improve from 0.68918
# Epoch 132/1000
# 20/20 - 1s - loss: 0.5339 - accuracy: 0.7568 - val_loss: 0.7733 - val_accuracy: 0.4946
#
# Epoch 00132: val_loss did not improve from 0.68918
# Epoch 133/1000
# 20/20 - 1s - loss: 0.5292 - accuracy: 0.7627 - val_loss: 0.7627 - val_accuracy: 0.5091
#
# Epoch 00133: val_loss did not improve from 0.68918
# Epoch 134/1000
# 20/20 - 1s - loss: 0.5293 - accuracy: 0.7640 - val_loss: 0.8040 - val_accuracy: 0.4767
#
# Epoch 00134: val_loss did not improve from 0.68918
# Epoch 135/1000
# 20/20 - 1s - loss: 0.5326 - accuracy: 0.7511 - val_loss: 0.7703 - val_accuracy: 0.5032
#
# Epoch 00135: val_loss did not improve from 0.68918
# Epoch 136/1000
# 20/20 - 1s - loss: 0.5258 - accuracy: 0.7653 - val_loss: 0.7766 - val_accuracy: 0.4971
#
# Epoch 00136: val_loss did not improve from 0.68918
# Epoch 137/1000
# 20/20 - 1s - loss: 0.5229 - accuracy: 0.7658 - val_loss: 0.7684 - val_accuracy: 0.5158
#
# Epoch 00137: val_loss did not improve from 0.68918
# Epoch 138/1000
# 20/20 - 1s - loss: 0.5331 - accuracy: 0.7467 - val_loss: 0.8037 - val_accuracy: 0.4806
#
# Epoch 00138: val_loss did not improve from 0.68918
# Epoch 139/1000
# 20/20 - 1s - loss: 0.5225 - accuracy: 0.7647 - val_loss: 0.7807 - val_accuracy: 0.4965
#
# Epoch 00139: val_loss did not improve from 0.68918
# Epoch 140/1000
# 20/20 - 1s - loss: 0.5194 - accuracy: 0.7703 - val_loss: 0.7713 - val_accuracy: 0.5060
#
# Epoch 00140: val_loss did not improve from 0.68918
# Epoch 141/1000
# 20/20 - 1s - loss: 0.5155 - accuracy: 0.7727 - val_loss: 0.7769 - val_accuracy: 0.5001
#
# Epoch 00141: val_loss did not improve from 0.68918
# Epoch 142/1000
# 20/20 - 1s - loss: 0.5114 - accuracy: 0.7769 - val_loss: 0.7761 - val_accuracy: 0.5074
#
# Epoch 00142: val_loss did not improve from 0.68918
# Epoch 143/1000
# 20/20 - 1s - loss: 0.5130 - accuracy: 0.7724 - val_loss: 0.7800 - val_accuracy: 0.4943
#
# Epoch 00143: val_loss did not improve from 0.68918
# Epoch 144/1000
# 20/20 - 1s - loss: 0.5092 - accuracy: 0.7788 - val_loss: 0.7771 - val_accuracy: 0.5091
#
# Epoch 00144: val_loss did not improve from 0.68918
# Epoch 145/1000
# 20/20 - 1s - loss: 0.5147 - accuracy: 0.7653 - val_loss: 0.8239 - val_accuracy: 0.4728
#
# Epoch 00145: val_loss did not improve from 0.68918
# Epoch 146/1000
# 20/20 - 1s - loss: 0.5164 - accuracy: 0.7592 - val_loss: 0.7785 - val_accuracy: 0.5147
#
# Epoch 00146: val_loss did not improve from 0.68918
# Epoch 147/1000
# 20/20 - 1s - loss: 0.5091 - accuracy: 0.7764 - val_loss: 0.7813 - val_accuracy: 0.5066
#
# Epoch 00147: val_loss did not improve from 0.68918
# Epoch 148/1000
# 20/20 - 1s - loss: 0.5038 - accuracy: 0.7806 - val_loss: 0.7881 - val_accuracy: 0.5004
#
# Epoch 00148: val_loss did not improve from 0.68918
# Epoch 149/1000
# 20/20 - 1s - loss: 0.5036 - accuracy: 0.7796 - val_loss: 0.7858 - val_accuracy: 0.5124
#
# Epoch 00149: val_loss did not improve from 0.68918
# Epoch 150/1000
# 20/20 - 1s - loss: 0.5040 - accuracy: 0.7805 - val_loss: 0.7907 - val_accuracy: 0.5015
#
# Epoch 00150: val_loss did not improve from 0.68918
# Epoch 151/1000
# 20/20 - 1s - loss: 0.5001 - accuracy: 0.7821 - val_loss: 0.8281 - val_accuracy: 0.4714
#
# Epoch 00151: val_loss did not improve from 0.68918
# Epoch 152/1000
# 20/20 - 1s - loss: 0.4996 - accuracy: 0.7823 - val_loss: 0.7957 - val_accuracy: 0.5013
#
# Epoch 00152: val_loss did not improve from 0.68918
# Epoch 153/1000
# 20/20 - 1s - loss: 0.4936 - accuracy: 0.7844 - val_loss: 0.7910 - val_accuracy: 0.5174
#
# Epoch 00153: val_loss did not improve from 0.68918
# Epoch 154/1000
# 20/20 - 1s - loss: 0.4981 - accuracy: 0.7819 - val_loss: 0.7901 - val_accuracy: 0.5049
#
# Epoch 00154: val_loss did not improve from 0.68918
# Epoch 155/1000
# 20/20 - 1s - loss: 0.4952 - accuracy: 0.7837 - val_loss: 0.7918 - val_accuracy: 0.5144
#
# Epoch 00155: val_loss did not improve from 0.68918
# Epoch 156/1000
# 20/20 - 1s - loss: 0.4895 - accuracy: 0.7938 - val_loss: 0.7945 - val_accuracy: 0.5052
#
# Epoch 00156: val_loss did not improve from 0.68918
# Epoch 157/1000
# 20/20 - 1s - loss: 0.4872 - accuracy: 0.7938 - val_loss: 0.7916 - val_accuracy: 0.5144
#
# Epoch 00157: val_loss did not improve from 0.68918
# Epoch 158/1000
# 20/20 - 1s - loss: 0.4912 - accuracy: 0.7837 - val_loss: 0.7935 - val_accuracy: 0.5057
#
# Epoch 00158: val_loss did not improve from 0.68918
# Epoch 159/1000
# 20/20 - 1s - loss: 0.4843 - accuracy: 0.7986 - val_loss: 0.8077 - val_accuracy: 0.4982
#
# Epoch 00159: val_loss did not improve from 0.68918
# Epoch 160/1000
# 20/20 - 1s - loss: 0.4805 - accuracy: 0.7980 - val_loss: 0.8117 - val_accuracy: 0.4912
#
# Epoch 00160: val_loss did not improve from 0.68918
# Epoch 161/1000
# 20/20 - 1s - loss: 0.4823 - accuracy: 0.7945 - val_loss: 0.7981 - val_accuracy: 0.5035
#
# Epoch 00161: val_loss did not improve from 0.68918
# Epoch 162/1000
# 20/20 - 1s - loss: 0.4775 - accuracy: 0.8024 - val_loss: 0.8107 - val_accuracy: 0.4971
#
# Epoch 00162: val_loss did not improve from 0.68918
# Epoch 163/1000
# 20/20 - 1s - loss: 0.4796 - accuracy: 0.7932 - val_loss: 0.8002 - val_accuracy: 0.5029
#
# Epoch 00163: val_loss did not improve from 0.68918
# Epoch 164/1000
# 20/20 - 1s - loss: 0.4776 - accuracy: 0.7971 - val_loss: 0.8043 - val_accuracy: 0.5127
#
# Epoch 00164: val_loss did not improve from 0.68918
# Epoch 165/1000
# 20/20 - 1s - loss: 0.4735 - accuracy: 0.8041 - val_loss: 0.8044 - val_accuracy: 0.5018
#
# Epoch 00165: val_loss did not improve from 0.68918
# Epoch 166/1000
# 20/20 - 1s - loss: 0.4688 - accuracy: 0.8136 - val_loss: 0.8159 - val_accuracy: 0.4951
#
# Epoch 00166: val_loss did not improve from 0.68918
# Epoch 167/1000
# 20/20 - 1s - loss: 0.4705 - accuracy: 0.8017 - val_loss: 0.8199 - val_accuracy: 0.5211
#
# Epoch 00167: val_loss did not improve from 0.68918
# Epoch 168/1000
# 20/20 - 1s - loss: 0.4721 - accuracy: 0.8022 - val_loss: 0.8349 - val_accuracy: 0.4817
#
# Epoch 00168: val_loss did not improve from 0.68918
# Epoch 169/1000
# 20/20 - 1s - loss: 0.4688 - accuracy: 0.8070 - val_loss: 0.8186 - val_accuracy: 0.5021
#
# Epoch 00169: val_loss did not improve from 0.68918
# Epoch 170/1000
# 20/20 - 1s - loss: 0.4674 - accuracy: 0.7994 - val_loss: 0.8136 - val_accuracy: 0.5147
#
# Epoch 00170: val_loss did not improve from 0.68918
# Epoch 171/1000
# 20/20 - 1s - loss: 0.4628 - accuracy: 0.8122 - val_loss: 0.8158 - val_accuracy: 0.5027
#
# Epoch 00171: val_loss did not improve from 0.68918
# Epoch 172/1000
# 20/20 - 1s - loss: 0.4588 - accuracy: 0.8147 - val_loss: 0.8185 - val_accuracy: 0.4960
#
# Epoch 00172: val_loss did not improve from 0.68918
# Epoch 173/1000
# 20/20 - 1s - loss: 0.4612 - accuracy: 0.8108 - val_loss: 0.8198 - val_accuracy: 0.5088
#
# Epoch 00173: val_loss did not improve from 0.68918
# Epoch 174/1000
# 20/20 - 1s - loss: 0.4543 - accuracy: 0.8174 - val_loss: 0.8168 - val_accuracy: 0.5071
#
# Epoch 00174: val_loss did not improve from 0.68918
# Epoch 175/1000
# 20/20 - 1s - loss: 0.4552 - accuracy: 0.8159 - val_loss: 0.8211 - val_accuracy: 0.5032
#
# Epoch 00175: val_loss did not improve from 0.68918
# Epoch 176/1000
# 20/20 - 1s - loss: 0.4516 - accuracy: 0.8213 - val_loss: 0.8231 - val_accuracy: 0.5035
#
# Epoch 00176: val_loss did not improve from 0.68918
# Epoch 177/1000
# 20/20 - 1s - loss: 0.4495 - accuracy: 0.8237 - val_loss: 0.8220 - val_accuracy: 0.5066
#
# Epoch 00177: val_loss did not improve from 0.68918
# Epoch 178/1000
# 20/20 - 1s - loss: 0.4641 - accuracy: 0.7957 - val_loss: 0.8402 - val_accuracy: 0.4968
#
# Epoch 00178: val_loss did not improve from 0.68918
# Epoch 179/1000
# 20/20 - 1s - loss: 0.4545 - accuracy: 0.8088 - val_loss: 0.8237 - val_accuracy: 0.5071
#
# Epoch 00179: val_loss did not improve from 0.68918
# Epoch 180/1000
# 20/20 - 1s - loss: 0.4451 - accuracy: 0.8194 - val_loss: 0.8253 - val_accuracy: 0.5066
#
# Epoch 00180: val_loss did not improve from 0.68918
# Epoch 181/1000
# 20/20 - 1s - loss: 0.4425 - accuracy: 0.8292 - val_loss: 0.8336 - val_accuracy: 0.5063
#
# Epoch 00181: val_loss did not improve from 0.68918
# Epoch 182/1000
# 20/20 - 1s - loss: 0.4404 - accuracy: 0.8267 - val_loss: 0.8266 - val_accuracy: 0.5035
#
# Epoch 00182: val_loss did not improve from 0.68918
# Epoch 183/1000
# 20/20 - 1s - loss: 0.4451 - accuracy: 0.8187 - val_loss: 0.8329 - val_accuracy: 0.5040
#
# Epoch 00183: val_loss did not improve from 0.68918
# Epoch 184/1000
# 20/20 - 1s - loss: 0.4373 - accuracy: 0.8284 - val_loss: 0.8325 - val_accuracy: 0.5057
#
# Epoch 00184: val_loss did not improve from 0.68918
# Epoch 185/1000
# 20/20 - 1s - loss: 0.4341 - accuracy: 0.8351 - val_loss: 0.8375 - val_accuracy: 0.5040
#
# Epoch 00185: val_loss did not improve from 0.68918
# Epoch 186/1000
# 20/20 - 1s - loss: 0.4333 - accuracy: 0.8347 - val_loss: 0.8361 - val_accuracy: 0.5043
#
# Epoch 00186: val_loss did not improve from 0.68918
# Epoch 187/1000
# 20/20 - 1s - loss: 0.4318 - accuracy: 0.8336 - val_loss: 0.8355 - val_accuracy: 0.5127
#
# Epoch 00187: val_loss did not improve from 0.68918
# Epoch 188/1000
# 20/20 - 1s - loss: 0.4323 - accuracy: 0.8310 - val_loss: 0.8380 - val_accuracy: 0.5066
#
# Epoch 00188: val_loss did not improve from 0.68918
# Epoch 189/1000
# 20/20 - 1s - loss: 0.4281 - accuracy: 0.8351 - val_loss: 0.8445 - val_accuracy: 0.5032
#
# Epoch 00189: val_loss did not improve from 0.68918
# Epoch 190/1000
# 20/20 - 1s - loss: 0.4265 - accuracy: 0.8337 - val_loss: 0.8386 - val_accuracy: 0.4993
#
# Epoch 00190: val_loss did not improve from 0.68918
# Epoch 191/1000
# 20/20 - 1s - loss: 0.4291 - accuracy: 0.8293 - val_loss: 0.8460 - val_accuracy: 0.5027
#
# Epoch 00191: val_loss did not improve from 0.68918
# Epoch 192/1000
# 20/20 - 1s - loss: 0.4374 - accuracy: 0.8173 - val_loss: 0.8536 - val_accuracy: 0.5052
#
# Epoch 00192: val_loss did not improve from 0.68918
# Epoch 193/1000
# 20/20 - 1s - loss: 0.4242 - accuracy: 0.8361 - val_loss: 0.8593 - val_accuracy: 0.5013
#
# Epoch 00193: val_loss did not improve from 0.68918
# Epoch 194/1000
# 20/20 - 1s - loss: 0.4201 - accuracy: 0.8388 - val_loss: 0.8473 - val_accuracy: 0.5116
#
# Epoch 00194: val_loss did not improve from 0.68918
# Epoch 195/1000
# 20/20 - 1s - loss: 0.4172 - accuracy: 0.8435 - val_loss: 0.8502 - val_accuracy: 0.5013
#
# Epoch 00195: val_loss did not improve from 0.68918
# Epoch 196/1000
# 20/20 - 1s - loss: 0.4153 - accuracy: 0.8451 - val_loss: 0.8603 - val_accuracy: 0.5027
#
# Epoch 00196: val_loss did not improve from 0.68918
# Epoch 197/1000
# 20/20 - 1s - loss: 0.4127 - accuracy: 0.8467 - val_loss: 0.8569 - val_accuracy: 0.5046
#
# Epoch 00197: val_loss did not improve from 0.68918
# Epoch 198/1000
# 20/20 - 1s - loss: 0.4098 - accuracy: 0.8490 - val_loss: 0.8642 - val_accuracy: 0.5007
#
# Epoch 00198: val_loss did not improve from 0.68918
# Epoch 199/1000
# 20/20 - 1s - loss: 0.4121 - accuracy: 0.8418 - val_loss: 0.8678 - val_accuracy: 0.5186
#
# Epoch 00199: val_loss did not improve from 0.68918
# Epoch 200/1000
# 20/20 - 1s - loss: 0.4123 - accuracy: 0.8417 - val_loss: 0.8663 - val_accuracy: 0.5038
#
# Epoch 00200: val_loss did not improve from 0.68918
# Epoch 201/1000
# 20/20 - 1s - loss: 0.4092 - accuracy: 0.8465 - val_loss: 0.8725 - val_accuracy: 0.4968
#
# Epoch 00201: val_loss did not improve from 0.68918
# Epoch 202/1000
# 20/20 - 1s - loss: 0.4039 - accuracy: 0.8550 - val_loss: 0.8715 - val_accuracy: 0.5049
#
# Epoch 00202: val_loss did not improve from 0.68918
# Epoch 203/1000
# 20/20 - 1s - loss: 0.4014 - accuracy: 0.8554 - val_loss: 0.8661 - val_accuracy: 0.5052
#
# Epoch 00203: val_loss did not improve from 0.68918
# Epoch 204/1000
# 20/20 - 1s - loss: 0.4055 - accuracy: 0.8490 - val_loss: 0.8667 - val_accuracy: 0.5141
#
# Epoch 00204: val_loss did not improve from 0.68918
# Epoch 205/1000
# 20/20 - 1s - loss: 0.3989 - accuracy: 0.8519 - val_loss: 0.8686 - val_accuracy: 0.4999
#
# Epoch 00205: val_loss did not improve from 0.68918
# Epoch 206/1000
# 20/20 - 1s - loss: 0.3953 - accuracy: 0.8586 - val_loss: 0.8670 - val_accuracy: 0.5077
#
# Epoch 00206: val_loss did not improve from 0.68918
# Epoch 207/1000
# 20/20 - 1s - loss: 0.3973 - accuracy: 0.8500 - val_loss: 0.8795 - val_accuracy: 0.5169
#
# Epoch 00207: val_loss did not improve from 0.68918
# Epoch 208/1000
# 20/20 - 1s - loss: 0.3977 - accuracy: 0.8505 - val_loss: 0.8748 - val_accuracy: 0.5152
#
# Epoch 00208: val_loss did not improve from 0.68918
# Epoch 209/1000
# 20/20 - 1s - loss: 0.3983 - accuracy: 0.8491 - val_loss: 0.8735 - val_accuracy: 0.5074
#
# Epoch 00209: val_loss did not improve from 0.68918
# Epoch 210/1000
# 20/20 - 1s - loss: 0.3971 - accuracy: 0.8491 - val_loss: 0.8797 - val_accuracy: 0.5040
#
# Epoch 00210: val_loss did not improve from 0.68918
# Epoch 211/1000
# 20/20 - 1s - loss: 0.3864 - accuracy: 0.8637 - val_loss: 0.8795 - val_accuracy: 0.5057
#
# Epoch 00211: val_loss did not improve from 0.68918
# Epoch 212/1000
# 20/20 - 1s - loss: 0.3874 - accuracy: 0.8615 - val_loss: 0.8853 - val_accuracy: 0.5024
#
# Epoch 00212: val_loss did not improve from 0.68918
# Epoch 213/1000
# 20/20 - 1s - loss: 0.3871 - accuracy: 0.8604 - val_loss: 0.8896 - val_accuracy: 0.5032
#
# Epoch 00213: val_loss did not improve from 0.68918
# Epoch 214/1000
# 20/20 - 1s - loss: 0.3805 - accuracy: 0.8670 - val_loss: 0.8818 - val_accuracy: 0.5119
#
# Epoch 00214: val_loss did not improve from 0.68918
# Epoch 215/1000
# 20/20 - 1s - loss: 0.3860 - accuracy: 0.8561 - val_loss: 0.8826 - val_accuracy: 0.5071
#
# Epoch 00215: val_loss did not improve from 0.68918
# Epoch 216/1000
# 20/20 - 1s - loss: 0.3793 - accuracy: 0.8661 - val_loss: 0.8972 - val_accuracy: 0.5149
#
# Epoch 00216: val_loss did not improve from 0.68918
# Epoch 217/1000
# 20/20 - 1s - loss: 0.3872 - accuracy: 0.8454 - val_loss: 0.8956 - val_accuracy: 0.5080
#
# Epoch 00217: val_loss did not improve from 0.68918
# Epoch 218/1000
# 20/20 - 1s - loss: 0.3761 - accuracy: 0.8670 - val_loss: 0.9030 - val_accuracy: 0.4982
#
# Epoch 00218: val_loss did not improve from 0.68918
# Epoch 219/1000
# 20/20 - 1s - loss: 0.3733 - accuracy: 0.8687 - val_loss: 0.8980 - val_accuracy: 0.5018
#
# Epoch 00219: val_loss did not improve from 0.68918
# Epoch 220/1000
# 20/20 - 1s - loss: 0.3734 - accuracy: 0.8674 - val_loss: 0.9124 - val_accuracy: 0.4943
#
# Epoch 00220: val_loss did not improve from 0.68918
# Epoch 221/1000
# 20/20 - 1s - loss: 0.3713 - accuracy: 0.8680 - val_loss: 0.9056 - val_accuracy: 0.5035
#
# Epoch 00221: val_loss did not improve from 0.68918
# Epoch 222/1000
# 20/20 - 1s - loss: 0.3669 - accuracy: 0.8714 - val_loss: 0.8968 - val_accuracy: 0.5152
#
# Epoch 00222: val_loss did not improve from 0.68918
# Epoch 223/1000
# 20/20 - 1s - loss: 0.3691 - accuracy: 0.8696 - val_loss: 0.9056 - val_accuracy: 0.5091
#
# Epoch 00223: val_loss did not improve from 0.68918
# Epoch 224/1000
# 20/20 - 1s - loss: 0.3642 - accuracy: 0.8771 - val_loss: 0.9044 - val_accuracy: 0.5105
#
# Epoch 00224: val_loss did not improve from 0.68918
# Epoch 225/1000
# 20/20 - 1s - loss: 0.3660 - accuracy: 0.8719 - val_loss: 0.9154 - val_accuracy: 0.5099
#
# Epoch 00225: val_loss did not improve from 0.68918
# Epoch 226/1000
# 20/20 - 1s - loss: 0.3690 - accuracy: 0.8646 - val_loss: 0.9160 - val_accuracy: 0.5169
#
# Epoch 00226: val_loss did not improve from 0.68918
# Epoch 227/1000
# 20/20 - 1s - loss: 0.3612 - accuracy: 0.8774 - val_loss: 0.9126 - val_accuracy: 0.5015
#
# Epoch 00227: val_loss did not improve from 0.68918
# Epoch 228/1000
# 20/20 - 1s - loss: 0.3601 - accuracy: 0.8745 - val_loss: 0.9270 - val_accuracy: 0.4957
#
# Epoch 00228: val_loss did not improve from 0.68918
# Epoch 229/1000
# 20/20 - 1s - loss: 0.3552 - accuracy: 0.8815 - val_loss: 0.9240 - val_accuracy: 0.4968
#
# Epoch 00229: val_loss did not improve from 0.68918
# Epoch 230/1000
# 20/20 - 1s - loss: 0.3581 - accuracy: 0.8733 - val_loss: 0.9302 - val_accuracy: 0.4990
#
# Epoch 00230: val_loss did not improve from 0.68918
# Epoch 231/1000
# 20/20 - 1s - loss: 0.3504 - accuracy: 0.8826 - val_loss: 0.9267 - val_accuracy: 0.5021
#
# Epoch 00231: val_loss did not improve from 0.68918
# Epoch 232/1000
# 20/20 - 1s - loss: 0.3499 - accuracy: 0.8843 - val_loss: 0.9180 - val_accuracy: 0.5110
#
# Epoch 00232: val_loss did not improve from 0.68918
# Epoch 233/1000
# 20/20 - 1s - loss: 0.3485 - accuracy: 0.8823 - val_loss: 0.9181 - val_accuracy: 0.5102
#
# Epoch 00233: val_loss did not improve from 0.68918
# Epoch 234/1000
# 20/20 - 1s - loss: 0.3486 - accuracy: 0.8803 - val_loss: 0.9331 - val_accuracy: 0.5124
#
# Epoch 00234: val_loss did not improve from 0.68918
# Epoch 235/1000
# 20/20 - 1s - loss: 0.3477 - accuracy: 0.8798 - val_loss: 0.9262 - val_accuracy: 0.5066
#
# Epoch 00235: val_loss did not improve from 0.68918
# Epoch 236/1000
# 20/20 - 1s - loss: 0.3448 - accuracy: 0.8856 - val_loss: 0.9343 - val_accuracy: 0.5091
#
# Epoch 00236: val_loss did not improve from 0.68918
# Epoch 237/1000
# 20/20 - 1s - loss: 0.3465 - accuracy: 0.8775 - val_loss: 1.0045 - val_accuracy: 0.4837
#
# Epoch 00237: val_loss did not improve from 0.68918
# Epoch 238/1000
# 20/20 - 1s - loss: 0.3627 - accuracy: 0.8549 - val_loss: 0.9588 - val_accuracy: 0.4965
#
# Epoch 00238: val_loss did not improve from 0.68918
# Epoch 239/1000
# 20/20 - 1s - loss: 0.3432 - accuracy: 0.8828 - val_loss: 0.9560 - val_accuracy: 0.4971
#
# Epoch 00239: val_loss did not improve from 0.68918
# Epoch 240/1000
# 20/20 - 1s - loss: 0.3363 - accuracy: 0.8892 - val_loss: 0.9372 - val_accuracy: 0.5124
#
# Epoch 00240: val_loss did not improve from 0.68918
# Epoch 241/1000
# 20/20 - 1s - loss: 0.3341 - accuracy: 0.8923 - val_loss: 0.9561 - val_accuracy: 0.5001
#
# Epoch 00241: val_loss did not improve from 0.68918
# Epoch 242/1000
# 20/20 - 1s - loss: 0.3337 - accuracy: 0.8911 - val_loss: 0.9437 - val_accuracy: 0.5038
#
# Epoch 00242: val_loss did not improve from 0.68918
# Epoch 243/1000
# 20/20 - 1s - loss: 0.3286 - accuracy: 0.8977 - val_loss: 0.9432 - val_accuracy: 0.5043
#
# Epoch 00243: val_loss did not improve from 0.68918
# Epoch 244/1000
# 20/20 - 1s - loss: 0.3310 - accuracy: 0.8928 - val_loss: 0.9502 - val_accuracy: 0.5113
#
# Epoch 00244: val_loss did not improve from 0.68918
# Epoch 245/1000
# 20/20 - 1s - loss: 0.3280 - accuracy: 0.8932 - val_loss: 0.9478 - val_accuracy: 0.5029
#
# Epoch 00245: val_loss did not improve from 0.68918
# Epoch 246/1000
# 20/20 - 1s - loss: 0.3333 - accuracy: 0.8884 - val_loss: 0.9659 - val_accuracy: 0.5007
#
# Epoch 00246: val_loss did not improve from 0.68918
# Epoch 247/1000
# 20/20 - 1s - loss: 0.3286 - accuracy: 0.8917 - val_loss: 0.9514 - val_accuracy: 0.5060
#
# Epoch 00247: val_loss did not improve from 0.68918
# Epoch 248/1000
# 20/20 - 1s - loss: 0.3218 - accuracy: 0.8992 - val_loss: 0.9560 - val_accuracy: 0.5119
#
# Epoch 00248: val_loss did not improve from 0.68918
# Epoch 249/1000
# 20/20 - 1s - loss: 0.3188 - accuracy: 0.9007 - val_loss: 0.9606 - val_accuracy: 0.5060
#
# Epoch 00249: val_loss did not improve from 0.68918
# Epoch 250/1000
# 20/20 - 1s - loss: 0.3237 - accuracy: 0.8939 - val_loss: 0.9700 - val_accuracy: 0.5035
#
# Epoch 00250: val_loss did not improve from 0.68918
# Epoch 251/1000
# 20/20 - 1s - loss: 0.3231 - accuracy: 0.8913 - val_loss: 0.9684 - val_accuracy: 0.5088
#
# Epoch 00251: val_loss did not improve from 0.68918
# Epoch 252/1000
# 20/20 - 1s - loss: 0.3221 - accuracy: 0.8954 - val_loss: 0.9701 - val_accuracy: 0.5007
#
# Epoch 00252: val_loss did not improve from 0.68918
# Epoch 253/1000
# 20/20 - 1s - loss: 0.3155 - accuracy: 0.9008 - val_loss: 0.9784 - val_accuracy: 0.5119
#
# Epoch 00253: val_loss did not improve from 0.68918
# Epoch 254/1000
# 20/20 - 1s - loss: 0.3171 - accuracy: 0.8957 - val_loss: 0.9706 - val_accuracy: 0.5071
#
# Epoch 00254: val_loss did not improve from 0.68918
# Epoch 255/1000
# 20/20 - 1s - loss: 0.3145 - accuracy: 0.9015 - val_loss: 0.9728 - val_accuracy: 0.5010
#
# Epoch 00255: val_loss did not improve from 0.68918
# test_result.shape : (3584, 2)
# y_test[:5] : [0 0 0 1 0]
# y_score[:5] : [[0.427466  ]
#  [0.41710874]
#  [0.43978155]
#  [0.4156939 ]
#  [0.4201574 ]]
# y_test.shape : (3584, 1)
# y_score.shape : (3584, 1)
# len(y_test) : 3584
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:696: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [0.0010983007, 0.0011031434, 0.001120407, 0.0011162525, 0.0011264046, 0.00108757, 0.0010957994, 0.0011250869, 0.0011179553, 0.0011318953, 0.0011221099, 0.0011308048, 0.0011613866, 0.0011753624, 0.001197803, 0.001231252, 0.001173936, 0.0011753965, 0.0011839236, 0.0011906102, 0.0011837481, 0.001203488, 0.0012029591, 0.0012016683, 0.0011947101, 0.001183731, 0.0011746077, 0.0011811783, 0.0011420761, 0.0011452154, 0.0011720705, 0.0011468568, 0.0011403909, 0.0011216017, 0.0010869775, 0.0010950036, 0.0010826436, 0.0013074912, 0.0013839786, 0.0013872773, 0.0014598725, 0.0014461774, 0.0014007965, 0.0014156805, 0.001373649, 0.0013575797, 0.0014031593, 0.0013983407, 0.0014084278, 0.0013269478, 0.0012522856, 0.0012983176, 0.0012890288, 0.0012868546, 0.0011683431, 0.0012063464, 0.0012542176, 0.0012358265, 0.0012833637, 0.0012755734, 0.0012408836, 0.0012135514, 0.0012120634, 0.0011936626, 0.0012917536, 0.0012962453, 0.0013052598, 0.0013117266, 0.0013433626, 0.0013344765, 0.0013100014, 0.0013175482, 0.0013259429, 0.0014144607, 0.0014002906, 0.001397938, 0.0013824422, 0.0013902808, 0.0013978415, 0.0014036479, 0.0013971232, 0.0014262175, 0.0014758578, 0.0013326644, 0.0013254357, 0.0013341197, 0.0013347248, 0.0013562911, 0.0013027088, 0.0013153343, 0.001334968, 0.0013396034, 0.0013216098, 0.0013291456, 0.0013039551, 0.0013278419, 0.0013338013, 0.0013407436, 0.0013619377, 0.0013612175, 0.0013565817, 0.0013814116, 0.0013942957, 0.0014005498, 0.0014129482, 0.0013873605, 0.0013734783, 0.0013724396, 0.0014824129, 0.0015059742, 0.0015073776, 0.0015285714, 0.0014622489, 0.0013842706, 0.0014242625, 0.0014185434, 0.0014196463, 0.0014206723, 0.0014215669, 0.0014084597, 0.0014056327, 0.0014317412, 0.0014407956, 0.0014251737, 0.0013944978, 0.0013708775, 0.0013747277, 0.0014137671, 0.0014218447, 0.0013651241, 0.0013649024, 0.001378595, 0.0013315673, 0.0013641926, 0.0013226328, 0.0012591524, 0.0012939498, 0.0012879894, 0.0013396192, 0.0013424509, 0.0015379494, 0.0016995874, 0.0016760172, 0.0016583327, 0.0017125389, 0.0017276384, 0.001751741, 0.0018211153, 0.001800554, 0.0018296193, 0.0017910221, 0.0018290761, 0.0018223785, 0.0017932332, 0.0018001838, 0.0018926098, 0.0019285883, 0.001899119, 0.0019480125, 0.0019754402, 0.001985758, 0.002027536, 0.002037436, 0.0021353224, 0.0021880968, 0.0022116285, 0.0025593806, 0.0025763304, 0.002556169, 0.0026343928, 0.0026534642, 0.0027038534, 0.0027228098, 0.003092392, 0.0030645463, 0.0030817592, 0.0033173899, 0.0032715553, 0.0034541783, 0.0035579656, 0.0036388715, 0.0037212016, 0.00375786, 0.0035705927, 0.0034679878, 0.0034747815, 0.0035171362, 0.0034417936, 0.003513242, 0.0036353387, 0.0034615253, 0.0034829807, 0.0035567142, 0.0034517338, 0.0034780754, 0.0034252345, 0.0038933074, 0.0039149127, 0.0040133283, 0.0041578826, 0.004236521, 0.004076405, 0.004061312, 0.00408518, 0.004105361, 0.0040360373, 0.004270913, 0.0044002384, 0.004453174, 0.004628214, 0.004685168, 0.005082396, 0.004898913, 0.0049529476, 0.005028895, 0.005035593, 0.005068483, 0.005065215, 0.005134704, 0.0051303795, 0.005172599, 0.005131755, 0.005406176, 0.0052526616, 0.0052611236, 0.005318977, 0.005597993, 0.0059677335, 0.005912165, 0.0059942473, 0.006267119, 0.0062325867, 0.006323936, 0.0062313653, 0.005798922, 0.0053573605, 0.0056235343, 0.00520715, 0.005294644, 0.0052941497, 0.005254685, 0.0054984186, 0.0056632203, 0.0056146607, 0.0055375127, 0.005349421, 0.005547781, 0.00558259, 0.0056766095, 0.0057592825, 0.0057025054, 0.0056124576, 0.005454308, 0.005501342, 0.0055287494, 0.005624886, 0.0058150026, 0.005747174, 0.005692913, 0.0059060096, 0.0059092264, 0.005819634, 0.0058026738, 0.0057197274, 0.005766512, 0.0058484073, 0.006011115, 0.006038342, 0.006119043, 0.0065108878, 0.0063378536, 0.0062418906, 0.0070162555, 0.007313952, 0.007281648, 0.007268658, 0.00743098, 0.007441626, 0.007356904, 0.0074098036, 0.0074723186, 0.0071369233, 0.007625571, 0.0076802582, 0.0077495566, 0.0074677123, 0.007379648, 0.0070194863, 0.0071805282, 0.0073650847,  ...

# %% [markdown]
# ### save npy

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from funcs_indicator import *

def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


#       set data features : ohlc, v, ep
time_index = ohlcv.index[np.sum(np.isnan(pr)):]

sliced_ohlcv = ohlcv[np.sum(np.isnan(pr)):]

#       scale with price    #
ohlc = ohlcv.iloc[np.sum(np.isnan(pr)):, :4]      

ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
sar = lucid_sar(sliced_ohlcv)
ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
senkou1, senkou2 = ichimoku(sliced_ohlcv)

#     min max scale   #
vol = sliced_ohlcv.iloc[np.sum(np.isnan(pr)):, [4]]

pr_list = pr[np.sum(np.isnan(pr)):]
print("len(ohlc) :", len(ohlc))
print("len(pr) :", len(pr))

# break


#       set params    #
period = 45
key_i = i

plotting = True

data_x, data_pr, data_updown = [], [], []
data_index = []

for i in range(period, len(ohlc)):

  #   pr_list != 1 인 데이터만 사용한다
  # if 1:
  if pr_list[i] != 1:

    min_max = MinMaxScaler()
    
    #   prediction 을 제외한 이전 데이터를 사용해야한다
    temp_ohlc = ohlc.iloc[i - period : i].values
    # temp_long_ep = long_ep[i - period : i]          
    temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
    temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
    temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
    temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

    temp_close = min_max_scale(temp_ohlc[:, [3]])    

    price_data = np.hstack((temp_ohlc, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

    if np.isnan(np.sum(price_data)):
      continue

    # print("price_data[:10] :", price_data[:10])
    # print("temp_ohlc.shape :", temp_ohlc.shape)
    # print("temp_long_ep.shape :", temp_long_ep.shape)
    # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
    # print("price_data.shape :", price_data.shape)

    if plotting:
      plt.plot(price_data)
      plt.show()

    ind_temp_ohlc = min_max_scale(temp_ohlc)
    temp_price_data = min_max_scale(price_data)
    # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))


    if plotting:

      plt.plot(ind_temp_ohlc)
      plt.show()
      plt.plot(temp_price_data)
      plt.show()

      plotting = False
    # break

    #   vol -> min_max
    temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
    
    #                   feature selection                   #        
    temp_data = np.hstack((ind_temp_ohlc, temp_vol))

    # temp_data = trial_list[trial_number]
    # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
    # temp_data = temp_ohlc[:, [3]]
    # temp_data = ind_temp_ohlc[:, [3]]
    # temp_data = temp_close

    if np.isnan(np.sum(temp_data)):
      continue

    data_x.append(temp_data)
    data_pr.append(pr_list[i])
    data_index.append(time_index[i])
    data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


print('np.array(data_x).shape :', np.array(data_x).shape)
# print(data_x[0])


#       Reshape data for image deep - learning     #
_, row, col = np.array(data_x).shape

input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
# input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

#     1c to 3c    #
input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
# input_x = np.array(resize_npy(input_x))


input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
input_index = np.array(data_index).reshape(-1, 1)
print('input_x.shape :', input_x.shape)
print('input_x.dtype :', input_x.dtype)
print('input_pr.shape :', input_pr.shape)
print('input_ud.shape :', input_ud.shape)
print('input_index.shape :', input_index.shape)


# x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

#     do stacking   #
# if prev_x is None:
prev_x = input_x
prev_pr = input_pr
prev_ud = input_ud
prev_index = input_index

total_x = input_x
total_pr = input_pr
total_ud = input_ud
total_index = input_index

# else:
#   total_x = np.vstack((prev_x, input_x))
#   total_pr = np.vstack((prev_pr, input_pr))
#   total_ud = np.vstack((prev_ud, input_ud)) 
#   total_index = np.vstack((prev_index, input_index)) 

#   prev_x = total_x
#   prev_pr = total_pr
#   prev_ud = total_ud
#   prev_index = total_index

print('total_x.shape :', total_x.shape)
print('total_pr.shape :', total_pr.shape)
print('total_ud.shape :', total_ud.shape)
print('prev_index.shape :', prev_index.shape)


# _, row, col, _ = input_x.shape
# _, row, col = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


#         get unique timestamp      #
print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

#                 don't shuffle timeseries data                 #
stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=False, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)

index_train = np.array(index_train)
index_val = np.array(index_val)
index_test = np.array(index_test)
  
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

symbol_name = key.split(' ')[1].split('.')[0]

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)

np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %% [markdown]
# ### load npy

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


symbol_name = "SXPUSDT"
period = 45

x_save_path = current_path + 'npy/' + '%s_cnn_updown_x_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)
pr_save_path = current_path + 'npy/' + '%s_cnn_updown_pr_train_rascend_ohlcv_%s_tssplit.npy' % (period, symbol_name)


x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')


pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

# total_x = np.vstack((x_train, x_val, x_test))
# total_pr = np.vstack((pr_train, pr_val, pr_test))

# print("total_x.shape :", total_x.shape)
# Out:
# x series loaded !
# y series loaded !

# %% [markdown]
# ### rapid pr selection

# %%
plt.plot(pr)
plt.show()

pr_thresh = 1.005
rapid_pct = len(pr[pr > pr_thresh]) / len(pr)

print(rapid_pct)
# Out:
# 0.36131427304964536

# %% [markdown]
# ### class_weight & categorization

# %%
from keras.utils import np_utils

# from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight


def class_ratio(in_list):

  return in_list / in_list[1]
  
y_train = np.where(pr_train > pr_thresh, 1, 0)
y_test = np.where(pr_test > pr_thresh, 1, 0)
y_val = np.where(pr_val > pr_thresh, 1, 0)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

# try:
print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

# except Exception as e:
  # print(e)

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)
# Out:
# x_train.shape : (10755, 45, 5, 3)
# x_test.shape : (3586, 45, 5, 3)
# x_val.shape : (3585, 45, 5, 3)
# y_train.shape : (10755, 1)
# y_test.shape : (3586, 1)
# y_val.shape : (3585, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([6864, 3891])) [1.76407093 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([2303, 1282])) [1.79641186 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2291, 1295])) [1.76911197 1.        ]
# class_weights : {0: 0.7834353146853147, 1: 1.382035466461064}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (10755, 2)
# y_val_ohe.shape : (3585, 2)
# y_test_ohe.shape : (3586, 2)

# %% [markdown]
# ### augment

# %%
from keras.preprocessing.image import ImageDataGenerator 

datagen = ImageDataGenerator( 
    # rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)


batch_size = 512


for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break

# %% [markdown]
# ### train

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'

# batch_size = 512

model = FER_Model(input_shape=x_train.shape[1:])
opt = Adam(lr=0.00001, decay=0.000005)
# opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model_name = 'classifier_%s_cnn_updown_rascend_1005_%s_tvnon_shuffle.h5' % (period, symbol_name)



checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]
# callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)

# %% [markdown]
# ### load model

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'


model_name = 'classifier_%s_cnn_updown_rascend_101_%s_tvnon_shuffle.h5' % (period, symbol_name)


model = keras.models.load_model(ckpt_path + model_name)

# %% [markdown]
# ### test

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)

  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  # pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.title(symbol_name)
plt.show()
# Out:
# test_result.shape : (3586, 2)
# y_test[:5] : [0 1 0 0 0]
# y_score[:5] : [[0.04767541]
#  [0.00195843]
#  [0.1600004 ]
#  [0.14308068]
#  [0.00154134]]
# y_test.shape : (3586, 1)
# y_score.shape : (3586, 1)
# len(y_test) : 3586
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:69: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [5.2342257e-05, 5.224965e-05, 5.119804e-05, 4.92728e-05, 4.9822964e-05, 5.1722614e-05, 5.241118e-05, 5.2653213e-05, 5.4707263e-05, 5.469477e-05, 5.5414595e-05, 5.4917986e-05, 5.5296758e-05, 5.482614e-05, 5.5313794e-05, 5.619928e-05, 5.7341047e-05, 5.8005982e-05, 5.7726982e-05, 5.8714617e-05, 5.924952e-05, 5.9157777e-05, 6.0730683e-05, 6.09751e-05, 6.1022805e-05, 6.194849e-05, 6.286581e-05, 6.367981e-05, 6.4932676e-05, 6.5769455e-05, 6.7948844e-05, 6.841887e-05, 6.806048e-05, 6.849957e-05, 6.9895126e-05, 7.091783e-05, 7.1859926e-05, 7.350335e-05, 7.346305e-05, 7.395025e-05, 7.968566e-05, 7.8947196e-05, 7.8341516e-05, 7.918357e-05, 7.912106e-05, 8.1205275e-05, 8.341604e-05, 8.386569e-05, 8.3938816e-05, 8.564359e-05, 7.970025e-05, 8.0672995e-05, 8.083643e-05, 8.727269e-05, 8.9510206e-05, 8.959228e-05, 8.962243e-05, 8.8885776e-05, 9.023229e-05, 9.169206e-05, 9.0867565e-05, 9.033618e-05, 9.429348e-05, 9.3799725e-05, 9.566918e-05, 9.6586686e-05, 9.398621e-05, 9.4105475e-05, 9.411831e-05, 9.466633e-05, 9.5054995e-05, 9.854746e-05, 9.9124496e-05, 0.00010614127, 0.000108136, 0.00010740872, 0.00010814099, 0.00010723293, 0.00010745465, 0.00010824714, 0.00010731329, 0.000108584194, 0.00010868803, 0.00010257258, 0.000101516416, 0.00010031571, 0.000103715196, 0.00010502134, 0.00010611775, 0.00010916348, 0.00010594193, 0.000104194485, 0.00010433929, 0.000104219216, 0.00010764128, 0.00010433711, 0.00010385209, 0.000106006635, 0.00010645543, 0.00010741285, 0.00010793885, 0.00010773461, 0.000107400294, 0.000107067055, 0.000110430265, 0.00010961514, 0.000110994966, 0.000109511326, 0.00011019072, 0.00011165826, 0.00011095228, 0.00011055433, 0.00011134691, 0.000109883986, 0.0001112986, 0.0001123257, 0.000114077506, 0.00011583454, 0.00011730796, 0.00011702095, 0.00012883096, 0.00012502969, 0.0001211144, 0.00012085415, 0.00012023333, 0.000121178586, 0.0001113643, 0.00011255329, 0.00011366057, 0.00011109531, 0.00011435672, 0.00011691414, 0.00011724194, 0.00011877652, 0.00011876732, 0.00012343662, 0.00012398258, 0.00012742475, 0.00013299534, 0.0001345203, 0.00013497796, 0.00013495858, 0.00013710273, 0.00013803714, 0.00013533776, 0.00014049193, 0.00013862025, 0.00013925365, 0.00013978127, 0.00014475136, 0.00014560782, 0.00014417202, 0.00015133772, 0.0001492487, 0.00015156744, 0.00015025465, 0.00015172384, 0.0001483679, 0.00015025485, 0.00017470514, 0.00017807752, 0.00018197432, 0.00018371776, 0.00018367464, 0.0001920926, 0.00019288564, 0.00020759454, 0.00020698183, 0.00023446795, 0.00023864223, 0.00024568185, 0.0002499611, 0.00025658592, 0.00025730263, 0.00025887572, 0.00026280092, 0.0002670472, 0.00027564648, 0.0002803122, 0.0002723821, 0.00027754836, 0.00027732784, 0.00028359605, 0.0002916876, 0.0002884358, 0.0002919522, 0.00029502896, 0.00028943687, 0.00028854128, 0.00029137387, 0.0002962364, 0.00029461124, 0.00029948735, 0.00030449385, 0.0002996868, 0.00029990985, 0.00029333428, 0.0002965417, 0.00029836778, 0.00029298887, 0.00030178405, 0.00029634495, 0.00029906907, 0.00029697176, 0.0002963374, 0.000295097, 0.000312998, 0.00031196643, 0.00031936396, 0.00032101592, 0.00032832168, 0.0003258465, 0.00033274552, 0.0003290262, 0.00033229083, 0.00034132804, 0.00033895372, 0.00035075872, 0.00034744598, 0.00034445102, 0.00032778905, 0.0003323982, 0.00034709118, 0.0003477889, 0.00035424854, 0.00040091967, 0.00042115894, 0.00041995398, 0.00041660885, 0.00042408038, 0.00044065266, 0.00045346154, 0.00044463656, 0.00047572926, 0.0005098468, 0.00050058664, 0.00049340463, 0.0004999284, 0.0005000292, 0.0004849475, 0.00048356556, 0.0004768842, 0.00047515446, 0.00046261746, 0.00046790738, 0.000461418, 0.00046818578, 0.00046653874, 0.00047877917, 0.00048961974, 0.0005021864, 0.00051662093, 0.00052976055, 0.00053512596, 0.000552535, 0.0005820823, 0.00058700517, 0.00059161586, 0.0005911128, 0.00059325877, 0.00059789245, 0.0006161917, 0.00060233, 0.0006037665, 0.0005968395, 0.0006049573, 0.0006040889, 0.0006045968, 0.000620602, 0.00062113034, 0.0006333279, ...

# %%
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)], linestyle='--', color='r')
plt.title(symbol_name + '\n' + str(new_thresh[np.argmax(acc_pr_bythr)]))
plt.show()

# %%
thresh = 0.5866
y_pred = np.where(y_score[:600, -1] > thresh, 1, 0)
# print('y_pred.shape :', y_pred.shape)
# print('y_pred :', y_pred)

#     compare precision     #

# print('precision :', precision_score(y_test, y_pred))
# print('recall :', recall_score(y_test, y_pred))
# print()

# print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
# print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

# # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
# # plt.show()  
# print()

#     check win-ratio improvement     #
cmat = confusion_matrix(y_test[:len(y_pred)], y_pred)
# print(cmat)
# print(np.sum(cmat, axis=1))

test_size = len(y_test[:len(y_pred)])
test_pr_list = pr_test[:len(y_pred)]
# print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
# print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

# print('pr_test.shape :', pr_test.shape)

# print(y_pred)
# print(test_pr_list)
pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

plt.plot(np.cumprod(pred_pr_list))
plt.show()

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72a922dd9685> in <module>()
#       5 # print(index_train)
#       6 # print(index_val)
# ----> 7 total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index))
#       8 timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train))
#       9 timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val))
#
# NameError: name 'input_index' is not defined

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
