# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    # long_ep = predictions[i]
    long_ep = (predictions[i] - err_ranges[i]) * (1 / (1 + tp))

    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-02-11/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-02-11 BTCUSDT.xlsx', '2021-02-11 ETHUSDT.xlsx', '2021-02-11 BCHUSDT.xlsx', '2021-02-11 XRPUSDT.xlsx', '2021-02-11 EOSUSDT.xlsx', '2021-02-11 LTCUSDT.xlsx', '2021-02-11 ETCUSDT.xlsx', '2021-02-11 LINKUSDT.xlsx', '2021-02-11 XLMUSDT.xlsx', '2021-02-11 ADAUSDT.xlsx', '2021-02-11 XMRUSDT.xlsx', '2021-02-11 SXPUSDT.xlsx', '2021-02-11 KAVAUSDT.xlsx', '2021-02-11 BANDUSDT.xlsx', '2021-02-11 DASHUSDT.xlsx', '2021-02-11 ZECUSDT.xlsx', '2021-02-11 XTZUSDT.xlsx', '2021-02-11 BNBUSDT.xlsx', '2021-02-11 ATOMUSDT.xlsx', '2021-02-11 ONTUSDT.xlsx', '2021-02-11 IOTAUSDT.xlsx', '2021-02-11 BATUSDT.xlsx', '2021-02-11 NEOUSDT.xlsx', '2021-02-11 QTUMUSDT.xlsx', '2021-02-11 WAVESUSDT.xlsx', '2021-02-11 MKRUSDT.xlsx', '2021-02-11 SNXUSDT.xlsx', '2021-02-11 DOTUSDT.xlsx', '2021-02-11 THETAUSDT.xlsx', '2021-02-11 ALGOUSDT.xlsx', '2021-02-11 KNCUSDT.xlsx', '2021-02-11 ZRXUSDT.xlsx', '2021-02-11 COMPUSDT.xlsx', '2021-02-11 OMGUSDT.xlsx']

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

with open('./arima_result/prev_close_candi_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
  load_dict = pickle.load(f)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break


candis = list(load_dict.keys())
long_index = 0
leverage = 5
prev_x = None
total_x = None

seed = 1
random_state = 201
np.random.seed(seed)

for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue
  if '2021-03-02 DOTUSDT.xlsx' in candis[i]:
    # print('')
    continue

  if '04-08' not in candis[i]:  # <-- 04-08 includes all timestamp range
    continue

  # if '02-11' not in candis[i]:  # <-- 04-08 includes all timestamp range
  #   continue  

  # if 'neo'.upper() not in candis[i]:
  #   continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      ohlcv = load_dict[key]['ohlcv']
      print('len(ohlcv) :', len(ohlcv))


      #       select timestamp range      #
      # time_index = ohlcv.index
      # total_stamp = list(map(lambda x: datetime.timestamp(x), time_index)) 

      # rm_index_amt = np.sum(np.array(total_stamp) < start_stamp)

      # ohlcv = ohlcv.iloc[rm_index_amt:]
      # print(ohlcv.head())

      ohlcv = ohlcv.iloc[:-2603]  # exclude back_range

      # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.3)]  # exclude back_range
      # predictions = load_dict[key]['predictions']
      # err_ranges = load_dict[key]['err_ranges']
      print("ohlcv.index[0] :", ohlcv.index[0])
      print("ohlcv.index[-1] :", ohlcv.index[-1])

      predictions = ohlcv['close'].shift(1).values
      err_ranges = np.zeros_like(predictions)

      # leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]

      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[-len(predictions):]
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = np.array(predictions)
      long_ep = long_ep.reshape(-1, 1)

      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 45
      data_x, data_pr, data_updown = [], [], []
      data_index = []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          min_max = MinMaxScaler()
          temp_data[:, :5] = min_max.fit_transform(temp_data[:, :5])


          #   vol -> min_max
          min_max = MinMaxScaler()
          temp_data[:, [5]] = min_max.fit_transform(temp_data[:, [5]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      if prev_x is None:
        prev_x = input_x
        prev_pr = input_pr
        prev_ud = input_ud
        prev_index = input_index

        total_x = input_x
        total_pr = input_pr
        total_ud = input_ud
        total_index = input_index

      else:
        total_x = np.vstack((prev_x, input_x))
        total_pr = np.vstack((prev_pr, input_pr))
        total_ud = np.vstack((prev_ud, input_ud)) 
        total_index = np.vstack((prev_index, input_index)) 

        prev_x = total_x
        prev_pr = total_pr
        prev_ud = total_ud
        prev_index = total_index

        print('total_x.shape :', total_x.shape)
        print('total_pr.shape :', total_pr.shape)
        print('total_ud.shape :', total_ud.shape)
        print('prev_index.shape :', prev_index.shape)

      # if prev_train_x is None:
      #   prev_train_x = x_train
      #   prev_val_x = x_val
      #   prev_test_x = x_test
        
      #   prev_train_pr = pr_train
      #   prev_val_pr = pr_val
      #   prev_test_pr = pr_test

      #   prev_train_ud = ud_train
      #   prev_val_ud = ud_val
      #   prev_test_ud = ud_test

      # else:

      #   total_train_x = np.vstack((prev_train_x, x_train))
      #   total_val_x = np.vstack((prev_val_x, x_val))
      #   total_test_x = np.vstack((prev_test_x, x_test))
      #   total_train_pr = np.vstack((prev_train_pr, pr_train))
      #   total_val_pr = np.vstack((prev_val_pr, pr_val))
      #   total_test_pr = np.vstack((prev_test_pr, pr_test))
      #   total_train_ud = np.vstack((prev_train_ud, ud_train))
      #   total_val_ud = np.vstack((prev_val_ud, ud_val))
      #   total_test_ud = np.vstack((prev_test_ud, ud_test))
        
      #   prev_train_x = total_train_x
      #   prev_val_x = total_val_x
      #   prev_test_x = total_test_x
        
      #   prev_train_pr = total_train_pr
      #   prev_val_pr = total_val_pr
      #   prev_test_pr = total_test_pr

      #   prev_train_ud = total_train_ud
      #   prev_val_ud = total_val_ud
      #   prev_test_ud = total_test_ud
        
      #   print("total_train_x.shape :", total_train_x.shape)
      #   print("total_val_x.shape :", total_val_x.shape)
      #   print("total_test_x.shape :", total_test_x.shape)
      #   print("total_train_pr.shape :", total_train_pr.shape)
      #   print("total_val_pr.shape :", total_val_pr.shape)
      #   print("total_test_pr.shape :", total_test_pr.shape)
      #   print("total_train_ud.shape :", total_train_ud.shape)
      #   print("total_val_ud.shape :", total_val_ud.shape)
      #   print("total_test_ud.shape :", total_test_ud.shape)

  # break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  try:
    if len(total_x) > 300000:
      break
  except:
    pass
# Out:
# start_stamp : 0
# len(ohlcv) : 17129
# ohlcv.index[0] : 2020-04-17 00:29:59.999000
# ohlcv.index[-1] : 2021-04-08 20:29:59.999000
# -------------- 2021-04-08 NEOUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 17129
# long_ep.shape : (17129, 1)
# len(pr_list) : 17129
# np.array(data_x).shape : (16382, 45, 6)
# input_x.shape : (16382, 90, 12, 3)
# input_x.dtype : float32
# input_pr.shape : (16382, 1)
# input_ud.shape : (16382, 1)
# input_index.shape : (16382, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:225: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
period = 45

_, row, col, _ = input_x.shape

#       split new test      #

seed = 1
random_state = 201
np.random.seed(seed)
from sklearn.model_selection import train_test_split


#         get unique timestamp      #
print(np.unique(total_index, return_counts=True))
uniq_stamp = np.unique(total_index)

stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.3, shuffle=True, random_state=random_state)
stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.3, shuffle=True, random_state=random_state)

print("stamp_train.shape :", stamp_train.shape)
print("stamp_val.shape :", stamp_val.shape)
print("stamp_test.shape :", stamp_test.shape)
# break


#         split data by stamp     #
x_train, x_val, x_test = [], [], []
pr_train, pr_val, pr_test = [], [], []
index_train, index_val, index_test = [], [], []


from tqdm.notebook import tqdm

np.random.shuffle(total_index)

for i in tqdm(range(len(total_index))):

  if total_index[i] in stamp_train:
    x_train.append(total_x[i])
    pr_train.append(total_pr[i])
    index_train.append(total_index[i])

  elif total_index[i] in stamp_val:
    x_val.append(total_x[i])
    pr_val.append(total_pr[i])
    index_val.append(total_index[i])
  
  elif total_index[i] in stamp_test:
    x_test.append(total_x[i])
    pr_test.append(total_pr[i])
    index_test.append(total_index[i])


x_train = np.array(x_train)
x_val = np.array(x_val)
x_test = np.array(x_test)

pr_train = np.array(pr_train)
pr_val = np.array(pr_val)
pr_test = np.array(pr_test)

index_train = np.array(index_train)
index_val = np.array(index_val)
index_test = np.array(index_test)
  
print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

# del total_x
# Out:
# (array([Timestamp('2020-04-17 23:29:59.999000'),
#        Timestamp('2020-04-17 23:59:59.999000'),
#        Timestamp('2020-04-18 00:29:59.999000'), ...,
#        Timestamp('2021-04-08 19:29:59.999000'),
#        Timestamp('2021-04-08 19:59:59.999000'),
#        Timestamp('2021-04-08 20:29:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (8026,)
# stamp_val.shape : (3441,)
# stamp_test.shape : (4915,)
# HBox(children=(FloatProgress(value=0.0, max=16382.0), HTML(value='')))
# x_train.shape : (8026, 90, 12, 3)
# x_val.shape : (3441, 90, 12, 3)
# x_test.shape : (4915, 90, 12, 3)

# %%
x_save_path = current_path + 'npy/' + '%s_close_updown_x_train_neo_timesplit.npy' % period
np.save(x_save_path, x_train)
np.save(x_save_path.replace('x_train', 'x_val'), x_val)
np.save(x_save_path.replace('x_train', 'x_test'), x_test)
# np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
print('x series saved !')

pr_save_path = current_path + 'npy/' + '%s_close_updown_pr_train_neo_timesplit.npy' % period
np.save(pr_save_path, pr_train)
np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
# np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
print('pr series saved !')
# Out:
# x series saved !
# pr series saved !

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_close_updown_x_train3.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

y_save_path = current_path + 'npy/' + '%s_close_updown_y_train3.npy' % period
y_train = np.load(y_save_path)
y_val = np.load(y_save_path.replace('y_train', 'y_val'))
y_test = np.load(y_save_path.replace('y_train', 'y_test'))
print('y series loaded !')

_, row, col, _ = x_train.shape
# Out:
# x series loaded !
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-14ce671818e9> in <module>()
#       8
#       9 y_save_path = current_path + 'npy/' + '%s_close_updown_y_train3.npy' % period
# ---> 10 y_train = np.load(y_save_path)
#      11 y_val = np.load(y_save_path.replace('y_train', 'y_val'))
#      12 y_test = np.load(y_save_path.replace('y_train', 'y_test'))
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Colab Notebooks/Project_Stock/npy/45_close_updown_y_train3.npy'

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape=(row, col, 3)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)


    net = layers.Dropout(0.3)(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight
# import cv2


_, row, col, _ = x_train.shape

#         pr label   #
y_train = np.where(pr_train > 1, 1, 0)
y_test = np.where(pr_test > 1, 1, 0)
y_val = np.where(pr_val > 1, 1, 0)


seed = 1
random_state = 20
np.random.seed(seed)
# tf.random.set_seed(seed)

#         up label      #
# y_train = np.where(ud_train > 1, 1, 0)
# y_test = np.where(ud_test > 1, 1, 0)
# y_val = np.where(ud_val > 1, 1, 0)

# print('pr_train[:5] :', pr_train[:5])
# print('ud_train[:5] :', ud_train[:5])
print('y_train[:5] :', y_train[:5])
print('y_train.dtype :', y_train.dtype)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

def class_ratio(in_list):

  return in_list / in_list[1]

print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)

datagen = ImageDataGenerator( 
    rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)

batch_size = 64

for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break
# Out:
# y_train[:5] : [[0]
#  [1]
#  [1]
#  [0]
#  [1]]
# y_train.dtype : int64
# x_train.shape : (8026, 90, 12, 3)
# x_test.shape : (4915, 90, 12, 3)
# x_val.shape : (3441, 90, 12, 3)
# y_train.shape : (8026, 1)
# y_test.shape : (4915, 1)
# y_val.shape : (3441, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([4544, 3482])) [1.30499713 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([1877, 1564])) [1.20012788 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2768, 2147])) [1.2892408 1.       ]
# class_weights : {0: 0.8831426056338029, 1: 1.1524985640436531}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (8026, 2)
# y_val_ohe.shape : (3441, 2)
# y_test_ohe.shape : (4915, 2)

# %% [markdown]
# ### **Training**

# %%
(_, row, col, _) = x_train.shape
  
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
# model_name = 'classifier_%s_close_updown_pr_theta_shuffle_without_back_03.h5' % period
# model_name = 'classifier_%s_close_updown_pr_theta_train_prevdata_005.h5' % period

# model_name = 'classifier_%s_close_updown_pr_theta_train_evendata_shuffle2_300k.h5' % period
# model_name = 'classifier_%s_close_updown_pr_all_pair_shuffle_final_0211_062.h5' % period
# model = keras.models.load_model(ckpt_path + model_name)


model = FER_Model(input_shape=(row, col, 3))
opt = Adam(lr=0.00001, decay=0.000005)
# opt = Adam(lr=0.001, decay=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# model_name = 'classifier_%s_close_updown_pr_all_pair_shuffle_300k_timesplit.h5' % period
model_name = 'classifier_%s_close_updown_pr_neo_shuffle_300k_timesplit_bn.h5' % period


checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=40)
# callbacks_list = [checkpoint, checkpoint2, checkpoint3]
callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)
# Out:
# Epoch 1/1000
#  - 5s - loss: 0.7920 - accuracy: 0.5052 - val_loss: 0.7137 - val_accuracy: 0.4534
#
# Epoch 00001: val_loss improved from inf to 0.71370, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_neo_shuffle_300k_timesplit_bn.h5
# Epoch 2/1000
#  - 4s - loss: 0.7509 - accuracy: 0.5009 - val_loss: 0.7052 - val_accuracy: 0.4987
#
# Epoch 00002: val_loss improved from 0.71370 to 0.70518, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_neo_shuffle_300k_timesplit_bn.h5
# Epoch 3/1000
#  - 4s - loss: 0.7324 - accuracy: 0.5172 - val_loss: 0.7606 - val_accuracy: 0.5051
#
# Epoch 00003: val_loss did not improve from 0.70518
# Epoch 4/1000
#  - 4s - loss: 0.7312 - accuracy: 0.5232 - val_loss: 0.7909 - val_accuracy: 0.5414
#
# Epoch 00004: val_loss did not improve from 0.70518
# Epoch 5/1000
#  - 5s - loss: 0.7324 - accuracy: 0.5130 - val_loss: 0.6820 - val_accuracy: 0.5071
#
# Epoch 00005: val_loss improved from 0.70518 to 0.68200, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_neo_shuffle_300k_timesplit_bn.h5
# Epoch 6/1000
#  - 4s - loss: 0.7308 - accuracy: 0.5184 - val_loss: 0.7197 - val_accuracy: 0.5199
#
# Epoch 00006: val_loss did not improve from 0.68200
# Epoch 7/1000
#  - 4s - loss: 0.7332 - accuracy: 0.5187 - val_loss: 0.7069 - val_accuracy: 0.5266
#
# Epoch 00007: val_loss did not improve from 0.68200
# Epoch 8/1000
#  - 5s - loss: 0.7282 - accuracy: 0.5248 - val_loss: 0.6647 - val_accuracy: 0.5272
#
# Epoch 00008: val_loss improved from 0.68200 to 0.66465, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_neo_shuffle_300k_timesplit_bn.h5
# Epoch 9/1000
#  - 4s - loss: 0.7411 - accuracy: 0.5163 - val_loss: 0.7489 - val_accuracy: 0.5324
#
# Epoch 00009: val_loss did not improve from 0.66465
# Epoch 10/1000
#  - 4s - loss: 0.7307 - accuracy: 0.5194 - val_loss: 0.8285 - val_accuracy: 0.4993
#
# Epoch 00010: val_loss did not improve from 0.66465
# Epoch 11/1000
#  - 4s - loss: 0.7242 - accuracy: 0.5318 - val_loss: 0.7789 - val_accuracy: 0.4929
#
# Epoch 00011: val_loss did not improve from 0.66465
# Epoch 12/1000
#  - 5s - loss: 0.7300 - accuracy: 0.5249 - val_loss: 0.7465 - val_accuracy: 0.4740
#
# Epoch 00012: val_loss did not improve from 0.66465
# Epoch 13/1000
#  - 4s - loss: 0.7373 - accuracy: 0.5237 - val_loss: 0.7505 - val_accuracy: 0.4798
#
# Epoch 00013: val_loss did not improve from 0.66465
# Epoch 14/1000
#  - 4s - loss: 0.7382 - accuracy: 0.5193 - val_loss: 0.8344 - val_accuracy: 0.4885
#
# Epoch 00014: val_loss did not improve from 0.66465
# Epoch 15/1000
#  - 4s - loss: 0.7252 - accuracy: 0.5283 - val_loss: 0.7951 - val_accuracy: 0.5269
#
# Epoch 00015: val_loss did not improve from 0.66465
# Epoch 16/1000
#  - 4s - loss: 0.7259 - accuracy: 0.5237 - val_loss: 0.6800 - val_accuracy: 0.5449
#
# Epoch 00016: val_loss did not improve from 0.66465
# Epoch 17/1000
#  - 4s - loss: 0.7174 - accuracy: 0.5431 - val_loss: 0.7352 - val_accuracy: 0.5042
#
# Epoch 00017: val_loss did not improve from 0.66465
# Epoch 18/1000
#  - 4s - loss: 0.7302 - accuracy: 0.5263 - val_loss: 0.7763 - val_accuracy: 0.5388
#
# Epoch 00018: val_loss did not improve from 0.66465
# Epoch 19/1000
#  - 4s - loss: 0.7345 - accuracy: 0.5250 - val_loss: 0.7059 - val_accuracy: 0.5179
#
# Epoch 00019: val_loss did not improve from 0.66465
# Epoch 20/1000
#  - 4s - loss: 0.7227 - accuracy: 0.5349 - val_loss: 0.8237 - val_accuracy: 0.4882
#
# Epoch 00020: val_loss did not improve from 0.66465
# Epoch 21/1000
#  - 4s - loss: 0.7242 - accuracy: 0.5404 - val_loss: 0.7695 - val_accuracy: 0.5429
#
# Epoch 00021: val_loss did not improve from 0.66465
# Epoch 22/1000
#  - 4s - loss: 0.7270 - accuracy: 0.5309 - val_loss: 0.7860 - val_accuracy: 0.4813
#
# Epoch 00022: val_loss did not improve from 0.66465
# Epoch 23/1000
#  - 4s - loss: 0.7254 - accuracy: 0.5313 - val_loss: 0.7229 - val_accuracy: 0.5185
#
# Epoch 00023: val_loss did not improve from 0.66465
# Epoch 24/1000
#  - 4s - loss: 0.7136 - accuracy: 0.5370 - val_loss: 0.7255 - val_accuracy: 0.5057
#
# Epoch 00024: val_loss did not improve from 0.66465
# Epoch 25/1000
#  - 4s - loss: 0.7244 - accuracy: 0.5344 - val_loss: 0.6887 - val_accuracy: 0.5283
#
# Epoch 00025: val_loss did not improve from 0.66465
# Epoch 26/1000
#  - 4s - loss: 0.7159 - accuracy: 0.5361 - val_loss: 0.8206 - val_accuracy: 0.4702
#
# Epoch 00026: val_loss did not improve from 0.66465
# Epoch 27/1000
#  - 4s - loss: 0.7156 - accuracy: 0.5435 - val_loss: 0.6931 - val_accuracy: 0.4920
#
# Epoch 00027: val_loss did not improve from 0.66465
# Epoch 28/1000
#  - 4s - loss: 0.7171 - accuracy: 0.5420 - val_loss: 0.7642 - val_accuracy: 0.5179
#
# Epoch 00028: val_loss did not improve from 0.66465
# Epoch 29/1000
#  - 4s - loss: 0.7122 - accuracy: 0.5437 - val_loss: 0.6951 - val_accuracy: 0.5042
#
# Epoch 00029: val_loss did not improve from 0.66465
# Epoch 30/1000
#  - 4s - loss: 0.7124 - accuracy: 0.5373 - val_loss: 0.8023 - val_accuracy: 0.4763
#
# Epoch 00030: val_loss did not improve from 0.66465
# Epoch 31/1000
#  - 4s - loss: 0.7164 - accuracy: 0.5454 - val_loss: 0.7514 - val_accuracy: 0.4900
#
# Epoch 00031: val_loss did not improve from 0.66465
# Epoch 32/1000
#  - 4s - loss: 0.7070 - accuracy: 0.5457 - val_loss: 0.8126 - val_accuracy: 0.5193
#
# Epoch 00032: val_loss did not improve from 0.66465
# Epoch 33/1000
#  - 4s - loss: 0.7102 - accuracy: 0.5385 - val_loss: 0.6427 - val_accuracy: 0.5254
#
# Epoch 00033: val_loss improved from 0.66465 to 0.64266, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_neo_shuffle_300k_timesplit_bn.h5
# Epoch 34/1000
#  - 4s - loss: 0.7103 - accuracy: 0.5482 - val_loss: 0.8850 - val_accuracy: 0.4821
#
# Epoch 00034: val_loss did not improve from 0.64266
# Epoch 35/1000
#  - 4s - loss: 0.7076 - accuracy: 0.5497 - val_loss: 0.6848 - val_accuracy: 0.5118
#
# Epoch 00035: val_loss did not improve from 0.64266
# Epoch 36/1000
#  - 5s - loss: 0.7097 - accuracy: 0.5442 - val_loss: 0.7401 - val_accuracy: 0.4705
#
# Epoch 00036: val_loss did not improve from 0.64266
# Epoch 37/1000
#  - 4s - loss: 0.7093 - accuracy: 0.5477 - val_loss: 0.8048 - val_accuracy: 0.5164
#
# Epoch 00037: val_loss did not improve from 0.64266
# Epoch 38/1000
#  - 4s - loss: 0.7061 - accuracy: 0.5506 - val_loss: 0.7806 - val_accuracy: 0.4917
#
# Epoch 00038: val_loss did not improve from 0.64266
# Epoch 39/1000
#  - 4s - loss: 0.7008 - accuracy: 0.5506 - val_loss: 0.8140 - val_accuracy: 0.4659
#
# Epoch 00039: val_loss did not improve from 0.64266
# Epoch 40/1000
#  - 4s - loss: 0.7074 - accuracy: 0.5452 - val_loss: 0.6427 - val_accuracy: 0.5033
#
# Epoch 00040: val_loss did not improve from 0.64266
# Epoch 41/1000
#  - 4s - loss: 0.7072 - accuracy: 0.5501 - val_loss: 0.7607 - val_accuracy: 0.5031
#
# Epoch 00041: val_loss did not improve from 0.64266
# Epoch 42/1000
#  - 4s - loss: 0.7016 - accuracy: 0.5581 - val_loss: 0.7463 - val_accuracy: 0.4845
#
# Epoch 00042: val_loss did not improve from 0.64266
# Epoch 43/1000
#  - 4s - loss: 0.7036 - accuracy: 0.5611 - val_loss: 0.7116 - val_accuracy: 0.5246
#
# Epoch 00043: val_loss did not improve from 0.64266
# Epoch 44/1000
#  - 4s - loss: 0.7031 - accuracy: 0.5521 - val_loss: 0.7561 - val_accuracy: 0.5182
#
# Epoch 00044: val_loss did not improve from 0.64266
# Epoch 45/1000
#  - 4s - loss: 0.6953 - accuracy: 0.5680 - val_loss: 0.9554 - val_accuracy: 0.5437
#
# Epoch 00045: val_loss did not improve from 0.64266
# Epoch 46/1000
#  - 4s - loss: 0.6981 - accuracy: 0.5618 - val_loss: 0.7189 - val_accuracy: 0.4990
#
# Epoch 00046: val_loss did not improve from 0.64266
# Epoch 47/1000
#  - 4s - loss: 0.6951 - accuracy: 0.5655 - val_loss: 0.7682 - val_accuracy: 0.5045
#
# Epoch 00047: val_loss did not improve from 0.64266
# Epoch 48/1000
#  - 4s - loss: 0.7105 - accuracy: 0.5542 - val_loss: 0.7195 - val_accuracy: 0.5121
#
# Epoch 00048: val_loss did not improve from 0.64266
# Epoch 49/1000
#  - 4s - loss: 0.6952 - accuracy: 0.5629 - val_loss: 0.8064 - val_accuracy: 0.5318
#
# Epoch 00049: val_loss did not improve from 0.64266
# Epoch 50/1000
#  - 4s - loss: 0.7011 - accuracy: 0.5576 - val_loss: 0.8664 - val_accuracy: 0.4690
#
# Epoch 00050: val_loss did not improve from 0.64266
# Epoch 51/1000
#  - 4s - loss: 0.6970 - accuracy: 0.5654 - val_loss: 0.7293 - val_accuracy: 0.4699
#
# Epoch 00051: val_loss did not improve from 0.64266
# Epoch 52/1000
#  - 4s - loss: 0.7058 - accuracy: 0.5569 - val_loss: 0.7580 - val_accuracy: 0.5045
#
# Epoch 00052: val_loss did not improve from 0.64266
# Epoch 53/1000
#  - 4s - loss: 0.6909 - accuracy: 0.5647 - val_loss: 0.8856 - val_accuracy: 0.4679
#
# Epoch 00053: val_loss did not improve from 0.64266
# Epoch 54/1000
#  - 4s - loss: 0.6984 - accuracy: 0.5647 - val_loss: 0.7504 - val_accuracy: 0.4897
#
# Epoch 00054: val_loss did not improve from 0.64266
# Epoch 55/1000
#  - 4s - loss: 0.6961 - accuracy: 0.5638 - val_loss: 0.7002 - val_accuracy: 0.4850
#
# Epoch 00055: val_loss did not improve from 0.64266
# Epoch 56/1000
#  - 4s - loss: 0.6929 - accuracy: 0.5613 - val_loss: 0.6978 - val_accuracy: 0.5115
#
# Epoch 00056: val_loss did not improve from 0.64266
# Epoch 57/1000
#  - 4s - loss: 0.6883 - accuracy: 0.5660 - val_loss: 0.8060 - val_accuracy: 0.5222
#
# Epoch 00057: val_loss did not improve from 0.64266
# Epoch 58/1000
#  - 4s - loss: 0.6907 - accuracy: 0.5669 - val_loss: 0.7660 - val_accuracy: 0.5092
#
# Epoch 00058: val_loss did not improve from 0.64266
# Epoch 59/1000
#  - 4s - loss: 0.6901 - accuracy: 0.5703 - val_loss: 0.7155 - val_accuracy: 0.5144
#
# Epoch 00059: val_loss did not improve from 0.64266
# Epoch 60/1000
#  - 4s - loss: 0.6861 - accuracy: 0.5775 - val_loss: 0.7088 - val_accuracy: 0.4717
#
# Epoch 00060: val_loss did not improve from 0.64266
# Epoch 61/1000
#  - 4s - loss: 0.6823 - accuracy: 0.5735 - val_loss: 0.8253 - val_accuracy: 0.5138
#
# Epoch 00061: val_loss did not improve from 0.64266
# Epoch 62/1000
#  - 4s - loss: 0.6882 - accuracy: 0.5739 - val_loss: 0.6732 - val_accuracy: 0.4874
#
# Epoch 00062: val_loss did not improve from 0.64266
# Epoch 63/1000
#  - 4s - loss: 0.6845 - accuracy: 0.5764 - val_loss: 0.8570 - val_accuracy: 0.5010
#
# Epoch 00063: val_loss did not improve from 0.64266
# Epoch 64/1000
#  - 4s - loss: 0.6794 - accuracy: 0.5749 - val_loss: 0.7080 - val_accuracy: 0.5365
#
# Epoch 00064: val_loss did not improve from 0.64266
# Epoch 65/1000
#  - 4s - loss: 0.6869 - accuracy: 0.5781 - val_loss: 0.7117 - val_accuracy: 0.5051
#
# Epoch 00065: val_loss did not improve from 0.64266
# Epoch 66/1000
#  - 4s - loss: 0.6892 - accuracy: 0.5796 - val_loss: 0.7403 - val_accuracy: 0.4975
#
# Epoch 00066: val_loss did not improve from 0.64266
# Epoch 67/1000
#  - 4s - loss: 0.6799 - accuracy: 0.5853 - val_loss: 0.7627 - val_accuracy: 0.4972
#
# Epoch 00067: val_loss did not improve from 0.64266
# Epoch 68/1000
#  - 4s - loss: 0.6832 - accuracy: 0.5775 - val_loss: 0.8072 - val_accuracy: 0.4842
#
# Epoch 00068: val_loss did not improve from 0.64266
# Epoch 69/1000
#  - 4s - loss: 0.6807 - accuracy: 0.5776 - val_loss: 0.7851 - val_accuracy: 0.5062
#
# Epoch 00069: val_loss did not improve from 0.64266
# Epoch 70/1000
#  - 4s - loss: 0.6758 - accuracy: 0.5841 - val_loss: 0.8854 - val_accuracy: 0.4856
#
# Epoch 00070: val_loss did not improve from 0.64266
# Epoch 71/1000
#  - 4s - loss: 0.6750 - accuracy: 0.5872 - val_loss: 0.6807 - val_accuracy: 0.5304
#
# Epoch 00071: val_loss did not improve from 0.64266
# Epoch 72/1000
#  - 4s - loss: 0.6717 - accuracy: 0.5863 - val_loss: 0.7066 - val_accuracy: 0.5283
#
# Epoch 00072: val_loss did not improve from 0.64266
# Epoch 73/1000
#  - 4s - loss: 0.6703 - accuracy: 0.5875 - val_loss: 0.8270 - val_accuracy: 0.5129
#
# Epoch 00073: val_loss did not improve from 0.64266
# Epoch 74/1000
#  - 4s - loss: 0.6755 - accuracy: 0.5826 - val_loss: 0.7681 - val_accuracy: 0.5292
#
# Epoch 00074: val_loss did not improve from 0.64266
# Epoch 75/1000
#  - 4s - loss: 0.6649 - accuracy: 0.6027 - val_loss: 0.8177 - val_accuracy: 0.5222
#
# Epoch 00075: val_loss did not improve from 0.64266
# Epoch 76/1000
#  - 4s - loss: 0.6764 - accuracy: 0.5791 - val_loss: 0.7577 - val_accuracy: 0.5039
#
# Epoch 00076: val_loss did not improve from 0.64266
# Epoch 77/1000
#  - 4s - loss: 0.6699 - accuracy: 0.5964 - val_loss: 0.7866 - val_accuracy: 0.5202
#
# Epoch 00077: val_loss did not improve from 0.64266
# Epoch 78/1000
#  - 4s - loss: 0.6761 - accuracy: 0.5920 - val_loss: 0.7079 - val_accuracy: 0.5263
#
# Epoch 00078: val_loss did not improve from 0.64266
# Epoch 79/1000
#  - 4s - loss: 0.6718 - accuracy: 0.5841 - val_loss: 0.7048 - val_accuracy: 0.5054
#
# Epoch 00079: val_loss did not improve from 0.64266
# Epoch 80/1000
#  - 4s - loss: 0.6681 - accuracy: 0.5991 - val_loss: 0.6874 - val_accuracy: 0.4781
#
# Epoch 00080: val_loss did not improve from 0.64266
# Epoch 81/1000
#  - 4s - loss: 0.6653 - accuracy: 0.5972 - val_loss: 0.7802 - val_accuracy: 0.5231
#
# Epoch 00081: val_loss did not improve from 0.64266
# Epoch 82/1000
#  - 4s - loss: 0.6614 - accuracy: 0.6042 - val_loss: 0.7819 - val_accuracy: 0.4996
#
# Epoch 00082: val_loss did not improve from 0.64266
# Epoch 83/1000
#  - 4s - loss: 0.6622 - accuracy: 0.6014 - val_loss: 0.7366 - val_accuracy: 0.5141
#
# Epoch 00083: val_loss did not improve from 0.64266
# Epoch 84/1000
#  - 4s - loss: 0.6624 - accuracy: 0.5958 - val_loss: 0.8342 - val_accuracy: 0.4871
#
# Epoch 00084: val_loss did not improve from 0.64266
# Epoch 85/1000
#  - 4s - loss: 0.6626 - accuracy: 0.5920 - val_loss: 0.6777 - val_accuracy: 0.5153
#
# Epoch 00085: val_loss did not improve from 0.64266
# Epoch 86/1000
#  - 4s - loss: 0.6667 - accuracy: 0.5928 - val_loss: 0.6709 - val_accuracy: 0.5260
#
# Epoch 00086: val_loss did not improve from 0.64266
# Epoch 87/1000
#  - 4s - loss: 0.6570 - accuracy: 0.6070 - val_loss: 0.7648 - val_accuracy: 0.5074
#
# Epoch 00087: val_loss did not improve from 0.64266
# Epoch 88/1000
#  - 4s - loss: 0.6560 - accuracy: 0.6110 - val_loss: 0.7995 - val_accuracy: 0.5155
#
# Epoch 00088: val_loss did not improve from 0.64266
# Epoch 89/1000
#  - 4s - loss: 0.6527 - accuracy: 0.6162 - val_loss: 0.8195 - val_accuracy: 0.5150
#
# Epoch 00089: val_loss did not improve from 0.64266
# Epoch 90/1000
#  - 4s - loss: 0.6520 - accuracy: 0.6140 - val_loss: 0.7503 - val_accuracy: 0.5231
#
# Epoch 00090: val_loss did not improve from 0.64266
# Epoch 91/1000
#  - 4s - loss: 0.6535 - accuracy: 0.6103 - val_loss: 0.6081 - val_accuracy: 0.5202
#
# Epoch 00091: val_loss improved from 0.64266 to 0.60810, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_neo_shuffle_300k_timesplit_bn.h5
# Epoch 92/1000
#  - 4s - loss: 0.6487 - accuracy: 0.6123 - val_loss: 0.8948 - val_accuracy: 0.4891
#
# Epoch 00092: val_loss did not improve from 0.60810
# Epoch 93/1000
#  - 4s - loss: 0.6471 - accuracy: 0.6126 - val_loss: 0.8584 - val_accuracy: 0.5182
#
# Epoch 00093: val_loss did not improve from 0.60810
# Epoch 94/1000
#  - 5s - loss: 0.6528 - accuracy: 0.6039 - val_loss: 0.8700 - val_accuracy: 0.5060
#
# Epoch 00094: val_loss did not improve from 0.60810
# Epoch 95/1000
#  - 4s - loss: 0.6423 - accuracy: 0.6155 - val_loss: 0.7853 - val_accuracy: 0.5196
#
# Epoch 00095: val_loss did not improve from 0.60810
# Epoch 96/1000
#  - 4s - loss: 0.6468 - accuracy: 0.6149 - val_loss: 0.7234 - val_accuracy: 0.5190
#
# Epoch 00096: val_loss did not improve from 0.60810
# Epoch 97/1000
#  - 4s - loss: 0.6410 - accuracy: 0.6182 - val_loss: 0.8224 - val_accuracy: 0.5301
#
# Epoch 00097: val_loss did not improve from 0.60810
# Epoch 98/1000
#  - 4s - loss: 0.6409 - accuracy: 0.6225 - val_loss: 0.7354 - val_accuracy: 0.5214
#
# Epoch 00098: val_loss did not improve from 0.60810
# Epoch 99/1000
#  - 4s - loss: 0.6411 - accuracy: 0.6190 - val_loss: 0.8401 - val_accuracy: 0.5164
#
# Epoch 00099: val_loss did not improve from 0.60810
# Epoch 100/1000
#  - 4s - loss: 0.6415 - accuracy: 0.6230 - val_loss: 0.7523 - val_accuracy: 0.5176
#
# Epoch 00100: val_loss did not improve from 0.60810
# Epoch 101/1000
#  - 4s - loss: 0.6394 - accuracy: 0.6197 - val_loss: 0.8304 - val_accuracy: 0.5112
#
# Epoch 00101: val_loss did not improve from 0.60810
# Epoch 102/1000
#  - 4s - loss: 0.6370 - accuracy: 0.6231 - val_loss: 0.7192 - val_accuracy: 0.4969
#
# Epoch 00102: val_loss did not improve from 0.60810
# Epoch 103/1000
#  - 4s - loss: 0.6382 - accuracy: 0.6211 - val_loss: 0.8390 - val_accuracy: 0.4984
#
# Epoch 00103: val_loss did not improve from 0.60810
# Epoch 104/1000
#  - 4s - loss: 0.6413 - accuracy: 0.6209 - val_loss: 0.7656 - val_accuracy: 0.5158
#
# Epoch 00104: val_loss did not improve from 0.60810
# Epoch 105/1000
#  - 4s - loss: 0.6364 - accuracy: 0.6280 - val_loss: 0.7834 - val_accuracy: 0.5153
#
# Epoch 00105: val_loss did not improve from 0.60810
# Epoch 106/1000
#  - 4s - loss: 0.6230 - accuracy: 0.6414 - val_loss: 0.8500 - val_accuracy: 0.4885
#
# Epoch 00106: val_loss did not improve from 0.60810
# Epoch 107/1000
#  - 4s - loss: 0.6287 - accuracy: 0.6317 - val_loss: 0.7543 - val_accuracy: 0.5248
#
# Epoch 00107: val_loss did not improve from 0.60810
# Epoch 108/1000
#  - 4s - loss: 0.6276 - accuracy: 0.6328 - val_loss: 0.6686 - val_accuracy: 0.5167
#
# Epoch 00108: val_loss did not improve from 0.60810
# Epoch 109/1000
#  - 4s - loss: 0.6264 - accuracy: 0.6327 - val_loss: 0.7431 - val_accuracy: 0.5344
#
# Epoch 00109: val_loss did not improve from 0.60810
# Epoch 110/1000
#  - 4s - loss: 0.6316 - accuracy: 0.6334 - val_loss: 0.8087 - val_accuracy: 0.5225
#
# Epoch 00110: val_loss did not improve from 0.60810
# Epoch 111/1000
#  - 4s - loss: 0.6246 - accuracy: 0.6400 - val_loss: 0.7982 - val_accuracy: 0.5219
#
# Epoch 00111: val_loss did not improve from 0.60810
# Epoch 112/1000
#  - 4s - loss: 0.6287 - accuracy: 0.6394 - val_loss: 0.7629 - val_accuracy: 0.5298
#
# Epoch 00112: val_loss did not improve from 0.60810
# Epoch 113/1000
#  - 4s - loss: 0.6224 - accuracy: 0.6420 - val_loss: 0.7754 - val_accuracy: 0.4894
#
# Epoch 00113: val_loss did not improve from 0.60810
# Epoch 114/1000
#  - 4s - loss: 0.6163 - accuracy: 0.6399 - val_loss: 0.8301 - val_accuracy: 0.5013
#
# Epoch 00114: val_loss did not improve from 0.60810
# Epoch 115/1000
#  - 4s - loss: 0.6192 - accuracy: 0.6443 - val_loss: 0.8013 - val_accuracy: 0.5362
#
# Epoch 00115: val_loss did not improve from 0.60810
# Epoch 116/1000
#  - 4s - loss: 0.6121 - accuracy: 0.6508 - val_loss: 0.7474 - val_accuracy: 0.5054
#
# Epoch 00116: val_loss did not improve from 0.60810
# Epoch 117/1000
#  - 4s - loss: 0.6105 - accuracy: 0.6544 - val_loss: 0.6865 - val_accuracy: 0.5254
#
# Epoch 00117: val_loss did not improve from 0.60810
# Epoch 118/1000
#  - 4s - loss: 0.6095 - accuracy: 0.6525 - val_loss: 0.8778 - val_accuracy: 0.4949
#
# Epoch 00118: val_loss did not improve from 0.60810
# Epoch 119/1000
#  - 4s - loss: 0.6058 - accuracy: 0.6508 - val_loss: 0.9196 - val_accuracy: 0.5135
#
# Epoch 00119: val_loss did not improve from 0.60810
# Epoch 120/1000
#  - 4s - loss: 0.6132 - accuracy: 0.6535 - val_loss: 0.8908 - val_accuracy: 0.5170
#
# Epoch 00120: val_loss did not improve from 0.60810
# Epoch 121/1000
#  - 4s - loss: 0.6105 - accuracy: 0.6483 - val_loss: 0.7391 - val_accuracy: 0.5170
#
# Epoch 00121: val_loss did not improve from 0.60810
# Epoch 122/1000
#  - 4s - loss: 0.6086 - accuracy: 0.6550 - val_loss: 0.8899 - val_accuracy: 0.5060
#
# Epoch 00122: val_loss did not improve from 0.60810
# Epoch 123/1000
#  - 4s - loss: 0.6158 - accuracy: 0.6443 - val_loss: 0.6954 - val_accuracy: 0.5129
#
# Epoch 00123: val_loss did not improve from 0.60810
# Epoch 124/1000
#  - 4s - loss: 0.6027 - accuracy: 0.6577 - val_loss: 0.8131 - val_accuracy: 0.5153
#
# Epoch 00124: val_loss did not improve from 0.60810
# Epoch 125/1000
#  - 4s - loss: 0.6002 - accuracy: 0.6591 - val_loss: 0.8399 - val_accuracy: 0.5025
#
# Epoch 00125: val_loss did not improve from 0.60810
# Epoch 126/1000
#  - 4s - loss: 0.6050 - accuracy: 0.6600 - val_loss: 0.7700 - val_accuracy: 0.5179
#
# Epoch 00126: val_loss did not improve from 0.60810
# Epoch 127/1000
#  - 4s - loss: 0.6004 - accuracy: 0.6628 - val_loss: 0.7864 - val_accuracy: 0.4969
#
# Epoch 00127: val_loss did not improve from 0.60810
# Epoch 128/1000
#  - 4s - loss: 0.5961 - accuracy: 0.6657 - val_loss: 0.9321 - val_accuracy: 0.5173
#
# Epoch 00128: val_loss did not improve from 0.60810
# Epoch 129/1000
#  - 4s - loss: 0.5911 - accuracy: 0.6706 - val_loss: 0.8031 - val_accuracy: 0.4964
#
# Epoch 00129: val_loss did not improve from 0.60810
# Epoch 130/1000
#  - 4s - loss: 0.5978 - accuracy: 0.6637 - val_loss: 0.8917 - val_accuracy: 0.4955
#
# Epoch 00130: val_loss did not improve from 0.60810
# Epoch 131/1000
#  - 4s - loss: 0.5908 - accuracy: 0.6708 - val_loss: 0.9131 - val_accuracy: 0.5092
#
# Epoch 00131: val_loss did not improve from 0.60810
# Epoch 132/1000
#  - 4s - loss: 0.5895 - accuracy: 0.6707 - val_loss: 0.7822 - val_accuracy: 0.5124
#
# Epoch 00132: val_loss did not improve from 0.60810
# Epoch 133/1000
#  - 4s - loss: 0.5835 - accuracy: 0.6722 - val_loss: 0.7234 - val_accuracy: 0.5132
#
# Epoch 00133: val_loss did not improve from 0.60810
# Epoch 134/1000
#  - 4s - loss: 0.5877 - accuracy: 0.6702 - val_loss: 0.8632 - val_accuracy: 0.5118
#
# Epoch 00134: val_loss did not improve from 0.60810
# Epoch 135/1000
#  - 4s - loss: 0.5783 - accuracy: 0.6812 - val_loss: 0.9813 - val_accuracy: 0.5080
#
# Epoch 00135: val_loss did not improve from 0.60810
# Epoch 136/1000
#  - 4s - loss: 0.5830 - accuracy: 0.6749 - val_loss: 0.7562 - val_accuracy: 0.5106
#
# Epoch 00136: val_loss did not improve from 0.60810
# Epoch 137/1000
#  - 4s - loss: 0.5818 - accuracy: 0.6748 - val_loss: 1.1452 - val_accuracy: 0.4984
#
# Epoch 00137: val_loss did not improve from 0.60810
# Epoch 138/1000
#  - 4s - loss: 0.5824 - accuracy: 0.6795 - val_loss: 0.6978 - val_accuracy: 0.5243
#
# Epoch 00138: val_loss did not improve from 0.60810
# Epoch 139/1000
#  - 4s - loss: 0.5806 - accuracy: 0.6743 - val_loss: 0.8708 - val_accuracy: 0.5196
#
# Epoch 00139: val_loss did not improve from 0.60810
# Epoch 140/1000
#  - 4s - loss: 0.5842 - accuracy: 0.6780 - val_loss: 0.9150 - val_accuracy: 0.5083
#
# Epoch 00140: val_loss did not improve from 0.60810
# Epoch 141/1000
#  - 4s - loss: 0.5760 - accuracy: 0.6804 - val_loss: 1.0452 - val_accuracy: 0.5074
#
# Epoch 00141: val_loss did not improve from 0.60810
# Epoch 142/1000
#  - 4s - loss: 0.5738 - accuracy: 0.6833 - val_loss: 0.8374 - val_accuracy: 0.5129
#
# Epoch 00142: val_loss did not improve from 0.60810
# Epoch 143/1000
#  - 4s - loss: 0.5705 - accuracy: 0.6825 - val_loss: 0.7585 - val_accuracy: 0.4955
#
# Epoch 00143: val_loss did not improve from 0.60810
# Epoch 144/1000
#  - 4s - loss: 0.5667 - accuracy: 0.6909 - val_loss: 0.8665 - val_accuracy: 0.5144
#
# Epoch 00144: val_loss did not improve from 0.60810
# Epoch 145/1000
#  - 4s - loss: 0.5789 - accuracy: 0.6751 - val_loss: 1.0948 - val_accuracy: 0.5019
#
# Epoch 00145: val_loss did not improve from 0.60810
# Epoch 146/1000
#  - 4s - loss: 0.5667 - accuracy: 0.6884 - val_loss: 0.7570 - val_accuracy: 0.5173
#
# Epoch 00146: val_loss did not improve from 0.60810
# Epoch 147/1000
#  - 4s - loss: 0.5648 - accuracy: 0.6939 - val_loss: 0.7692 - val_accuracy: 0.4984
#
# Epoch 00147: val_loss did not improve from 0.60810
# Epoch 148/1000
#  - 4s - loss: 0.5628 - accuracy: 0.6955 - val_loss: 0.9331 - val_accuracy: 0.5001
#
# Epoch 00148: val_loss did not improve from 0.60810
# Epoch 149/1000
#  - 4s - loss: 0.5595 - accuracy: 0.7075 - val_loss: 0.8265 - val_accuracy: 0.5141
#
# Epoch 00149: val_loss did not improve from 0.60810
# Epoch 150/1000
#  - 4s - loss: 0.5585 - accuracy: 0.7000 - val_loss: 0.9473 - val_accuracy: 0.4987
#
# Epoch 00150: val_loss did not improve from 0.60810
# Epoch 151/1000
#  - 4s - loss: 0.5535 - accuracy: 0.7006 - val_loss: 0.7885 - val_accuracy: 0.5060
#
# Epoch 00151: val_loss did not improve from 0.60810
# Epoch 152/1000
#  - 4s - loss: 0.5580 - accuracy: 0.6982 - val_loss: 0.8478 - val_accuracy: 0.5173
#
# Epoch 00152: val_loss did not improve from 0.60810
# Epoch 153/1000
#  - 4s - loss: 0.5542 - accuracy: 0.6984 - val_loss: 0.8490 - val_accuracy: 0.4981
#
# Epoch 00153: val_loss did not improve from 0.60810
# Epoch 154/1000
#  - 4s - loss: 0.5479 - accuracy: 0.7073 - val_loss: 1.0291 - val_accuracy: 0.4978
#
# Epoch 00154: val_loss did not improve from 0.60810
# Epoch 155/1000
#  - 4s - loss: 0.5421 - accuracy: 0.7101 - val_loss: 0.7890 - val_accuracy: 0.5187
#
# Epoch 00155: val_loss did not improve from 0.60810
# Epoch 156/1000
#  - 4s - loss: 0.5456 - accuracy: 0.7026 - val_loss: 0.9165 - val_accuracy: 0.5065
#
# Epoch 00156: val_loss did not improve from 0.60810
# Epoch 157/1000
#  - 4s - loss: 0.5408 - accuracy: 0.7118 - val_loss: 1.1500 - val_accuracy: 0.5217
#
# Epoch 00157: val_loss did not improve from 0.60810
# Epoch 158/1000
#  - 4s - loss: 0.5398 - accuracy: 0.7158 - val_loss: 1.0745 - val_accuracy: 0.5196
#
# Epoch 00158: val_loss did not improve from 0.60810
# Epoch 159/1000
#  - 4s - loss: 0.5410 - accuracy: 0.7144 - val_loss: 1.0902 - val_accuracy: 0.5217
#
# Epoch 00159: val_loss did not improve from 0.60810
# Epoch 160/1000
#  - 4s - loss: 0.5421 - accuracy: 0.7098 - val_loss: 0.9503 - val_accuracy: 0.5019
#
# Epoch 00160: val_loss did not improve from 0.60810
# Epoch 161/1000
#  - 4s - loss: 0.5440 - accuracy: 0.7112 - val_loss: 0.7988 - val_accuracy: 0.4903
#
# Epoch 00161: val_loss did not improve from 0.60810
# Epoch 162/1000
#  - 4s - loss: 0.5333 - accuracy: 0.7154 - val_loss: 0.8420 - val_accuracy: 0.5065
#
# Epoch 00162: val_loss did not improve from 0.60810
# Epoch 163/1000
#  - 4s - loss: 0.5263 - accuracy: 0.7177 - val_loss: 0.9378 - val_accuracy: 0.4961
#
# Epoch 00163: val_loss did not improve from 0.60810
# Epoch 164/1000
#  - 4s - loss: 0.5425 - accuracy: 0.7131 - val_loss: 1.0397 - val_accuracy: 0.4975
#
# Epoch 00164: val_loss did not improve from 0.60810
# Epoch 165/1000
#  - 4s - loss: 0.5326 - accuracy: 0.7259 - val_loss: 0.9714 - val_accuracy: 0.5170
#
# Epoch 00165: val_loss did not improve from 0.60810
# Epoch 166/1000
#  - 4s - loss: 0.5365 - accuracy: 0.7126 - val_loss: 0.9515 - val_accuracy: 0.5083
#
# Epoch 00166: val_loss did not improve from 0.60810
# Epoch 167/1000
#  - 4s - loss: 0.5318 - accuracy: 0.7195 - val_loss: 0.9159 - val_accuracy: 0.5167
#
# Epoch 00167: val_loss did not improve from 0.60810
# Epoch 168/1000
#  - 4s - loss: 0.5226 - accuracy: 0.7268 - val_loss: 0.9635 - val_accuracy: 0.4955
#
# Epoch 00168: val_loss did not improve from 0.60810
# Epoch 169/1000
#  - 4s - loss: 0.5260 - accuracy: 0.7183 - val_loss: 0.9452 - val_accuracy: 0.5118
#
# Epoch 00169: val_loss did not improve from 0.60810
# Epoch 170/1000
#  - 4s - loss: 0.5253 - accuracy: 0.7246 - val_loss: 0.8576 - val_accuracy: 0.4932
#
# Epoch 00170: val_loss did not improve from 0.60810
# Epoch 171/1000
#  - 4s - loss: 0.5206 - accuracy: 0.7285 - val_loss: 0.8935 - val_accuracy: 0.4961
#
# Epoch 00171: val_loss did not improve from 0.60810
# Epoch 172/1000
#  - 4s - loss: 0.5224 - accuracy: 0.7243 - val_loss: 0.6991 - val_accuracy: 0.5060
#
# Epoch 00172: val_loss did not improve from 0.60810
# Epoch 173/1000
#  - 4s - loss: 0.5130 - accuracy: 0.7355 - val_loss: 0.9709 - val_accuracy: 0.4856
#
# Epoch 00173: val_loss did not improve from 0.60810
# Epoch 174/1000
#  - 4s - loss: 0.5180 - accuracy: 0.7284 - val_loss: 0.7206 - val_accuracy: 0.5202
#
# Epoch 00174: val_loss did not improve from 0.60810
# Epoch 175/1000
#  - 4s - loss: 0.5162 - accuracy: 0.7285 - val_loss: 1.0188 - val_accuracy: 0.5065
#
# Epoch 00175: val_loss did not improve from 0.60810
# Epoch 176/1000
#  - 4s - loss: 0.5149 - accuracy: 0.7266 - val_loss: 0.6895 - val_accuracy: 0.5019
#
# Epoch 00176: val_loss did not improve from 0.60810
# Epoch 177/1000
#  - 4s - loss: 0.5153 - accuracy: 0.7330 - val_loss: 1.0427 - val_accuracy: 0.4961
#
# Epoch 00177: val_loss did not improve from 0.60810
# Epoch 178/1000
#  - 4s - loss: 0.5095 - accuracy: 0.7377 - val_loss: 1.0398 - val_accuracy: 0.5062
#
# Epoch 00178: val_loss did not improve from 0.60810
# Epoch 179/1000
#  - 4s - loss: 0.5136 - accuracy: 0.7342 - val_loss: 0.8677 - val_accuracy: 0.5124
#
# Epoch 00179: val_loss did not improve from 0.60810
# Epoch 180/1000
#  - 4s - loss: 0.5010 - accuracy: 0.7452 - val_loss: 1.0695 - val_accuracy: 0.4815
#
# Epoch 00180: val_loss did not improve from 0.60810
# Epoch 181/1000
#  - 4s - loss: 0.4980 - accuracy: 0.7412 - val_loss: 1.0379 - val_accuracy: 0.4920
#
# Epoch 00181: val_loss did not improve from 0.60810
# Epoch 182/1000
#  - 4s - loss: 0.5093 - accuracy: 0.7312 - val_loss: 0.9456 - val_accuracy: 0.5132
#
# Epoch 00182: val_loss did not improve from 0.60810
# Epoch 183/1000
#  - 4s - loss: 0.5043 - accuracy: 0.7396 - val_loss: 0.7849 - val_accuracy: 0.5019
#
# Epoch 00183: val_loss did not improve from 0.60810
# Epoch 184/1000
#  - 4s - loss: 0.4953 - accuracy: 0.7471 - val_loss: 1.1612 - val_accuracy: 0.5060
#
# Epoch 00184: val_loss did not improve from 0.60810
# Epoch 185/1000
#  - 4s - loss: 0.4966 - accuracy: 0.7487 - val_loss: 0.6785 - val_accuracy: 0.5013
#
# Epoch 00185: val_loss did not improve from 0.60810
# Epoch 186/1000
#  - 4s - loss: 0.5014 - accuracy: 0.7412 - val_loss: 0.8858 - val_accuracy: 0.4996
#
# Epoch 00186: val_loss did not improve from 0.60810
# Epoch 187/1000
#  - 4s - loss: 0.4815 - accuracy: 0.7575 - val_loss: 1.0586 - val_accuracy: 0.4917
#
# Epoch 00187: val_loss did not improve from 0.60810
# Epoch 188/1000
#  - 4s - loss: 0.4958 - accuracy: 0.7526 - val_loss: 1.1110 - val_accuracy: 0.5013
#
# Epoch 00188: val_loss did not improve from 0.60810
# Epoch 189/1000
#  - 4s - loss: 0.4933 - accuracy: 0.7496 - val_loss: 0.9502 - val_accuracy: 0.4923
#
# Epoch 00189: val_loss did not improve from 0.60810
# Epoch 190/1000
#  - 4s - loss: 0.4910 - accuracy: 0.7498 - val_loss: 0.9086 - val_accuracy: 0.5112
#
# Epoch 00190: val_loss did not improve from 0.60810
# Epoch 191/1000
#  - 4s - loss: 0.4829 - accuracy: 0.7562 - val_loss: 0.9937 - val_accuracy: 0.5074
#
# Epoch 00191: val_loss did not improve from 0.60810
# Epoch 192/1000
#  - 4s - loss: 0.4876 - accuracy: 0.7514 - val_loss: 0.9416 - val_accuracy: 0.5057
#
# Epoch 00192: val_loss did not improve from 0.60810
# Epoch 193/1000
#  - 4s - loss: 0.4842 - accuracy: 0.7514 - val_loss: 0.7671 - val_accuracy: 0.5094
#
# Epoch 00193: val_loss did not improve from 0.60810
# Epoch 194/1000
#  - 4s - loss: 0.4786 - accuracy: 0.7578 - val_loss: 0.7289 - val_accuracy: 0.5068
#
# Epoch 00194: val_loss did not improve from 0.60810
# Epoch 195/1000
#  - 4s - loss: 0.4775 - accuracy: 0.7605 - val_loss: 1.0161 - val_accuracy: 0.5068
#
# Epoch 00195: val_loss did not improve from 0.60810
# Epoch 196/1000
#  - 4s - loss: 0.4809 - accuracy: 0.7533 - val_loss: 1.2363 - val_accuracy: 0.4938
#
# Epoch 00196: val_loss did not improve from 0.60810
# Epoch 197/1000
#  - 4s - loss: 0.4742 - accuracy: 0.7616 - val_loss: 1.1988 - val_accuracy: 0.5083
#
# Epoch 00197: val_loss did not improve from 0.60810
# Epoch 198/1000
#  - 4s - loss: 0.4746 - accuracy: 0.7629 - val_loss: 0.6778 - val_accuracy: 0.5048
#
# Epoch 00198: val_loss did not improve from 0.60810
# Epoch 199/1000
#  - 4s - loss: 0.4669 - accuracy: 0.7656 - val_loss: 0.8408 - val_accuracy: 0.5071
#
# Epoch 00199: val_loss did not improve from 0.60810
# Epoch 200/1000
#  - 4s - loss: 0.4677 - accuracy: 0.7683 - val_loss: 1.0259 - val_accuracy: 0.5077
#
# Epoch 00200: val_loss did not improve from 0.60810
# Epoch 201/1000
#  - 4s - loss: 0.4666 - accuracy: 0.7648 - val_loss: 0.9203 - val_accuracy: 0.4932
#
# Epoch 00201: val_loss did not improve from 0.60810
# Epoch 202/1000
#  - 4s - loss: 0.4691 - accuracy: 0.7660 - val_loss: 0.7782 - val_accuracy: 0.5155
#
# Epoch 00202: val_loss did not improve from 0.60810
# Epoch 203/1000
#  - 4s - loss: 0.4633 - accuracy: 0.7705 - val_loss: 1.0222 - val_accuracy: 0.5077
#
# Epoch 00203: val_loss did not improve from 0.60810
# Epoch 204/1000
#  - 4s - loss: 0.4688 - accuracy: 0.7651 - val_loss: 1.0296 - val_accuracy: 0.5126
#
# Epoch 00204: val_loss did not improve from 0.60810
# Epoch 205/1000
#  - 4s - loss: 0.4651 - accuracy: 0.7715 - val_loss: 1.0741 - val_accuracy: 0.5080
#
# Epoch 00205: val_loss did not improve from 0.60810
# Epoch 206/1000
#  - 4s - loss: 0.4595 - accuracy: 0.7736 - val_loss: 1.1389 - val_accuracy: 0.5033
#
# Epoch 00206: val_loss did not improve from 0.60810
# Epoch 207/1000
#  - 4s - loss: 0.4565 - accuracy: 0.7772 - val_loss: 1.1325 - val_accuracy: 0.4975
#
# Epoch 00207: val_loss did not improve from 0.60810
# Epoch 208/1000
#  - 4s - loss: 0.4570 - accuracy: 0.7761 - val_loss: 1.1131 - val_accuracy: 0.4964
#
# Epoch 00208: val_loss did not improve from 0.60810
# Epoch 209/1000
#  - 4s - loss: 0.4571 - accuracy: 0.7711 - val_loss: 0.9241 - val_accuracy: 0.5141
#
# Epoch 00209: val_loss did not improve from 0.60810
# Epoch 210/1000
#  - 4s - loss: 0.4601 - accuracy: 0.7761 - val_loss: 0.8913 - val_accuracy: 0.5025
#
# Epoch 00210: val_loss did not improve from 0.60810
# Epoch 211/1000
#  - 4s - loss: 0.4483 - accuracy: 0.7846 - val_loss: 0.8643 - val_accuracy: 0.4990
#
# Epoch 00211: val_loss did not improve from 0.60810
# Epoch 212/1000
#  - 4s - loss: 0.4483 - accuracy: 0.7806 - val_loss: 1.1826 - val_accuracy: 0.4955
#
# Epoch 00212: val_loss did not improve from 0.60810
# Epoch 213/1000
#  - 4s - loss: 0.4527 - accuracy: 0.7777 - val_loss: 1.0906 - val_accuracy: 0.5007
#
# Epoch 00213: val_loss did not improve from 0.60810
# Epoch 214/1000
#  - 4s - loss: 0.4539 - accuracy: 0.7737 - val_loss: 1.0240 - val_accuracy: 0.5010
#
# Epoch 00214: val_loss did not improve from 0.60810
# Epoch 215/1000
#  - 4s - loss: 0.4526 - accuracy: 0.7755 - val_loss: 0.7406 - val_accuracy: 0.4935
#
# Epoch 00215: val_loss did not improve from 0.60810
# Epoch 216/1000
#  - 4s - loss: 0.4498 - accuracy: 0.7798 - val_loss: 0.9531 - val_accuracy: 0.5013
#
# Epoch 00216: val_loss did not improve from 0.60810
# Epoch 217/1000
#  - 4s - loss: 0.4430 - accuracy: 0.7828 - val_loss: 0.8553 - val_accuracy: 0.5028
#
# Epoch 00217: val_loss did not improve from 0.60810
# Epoch 218/1000
#  - 4s - loss: 0.4422 - accuracy: 0.7886 - val_loss: 1.0717 - val_accuracy: 0.4999
#
# Epoch 00218: val_loss did not improve from 0.60810
# Epoch 219/1000
#  - 4s - loss: 0.4419 - accuracy: 0.7881 - val_loss: 0.8299 - val_accuracy: 0.4961
#
# Epoch 00219: val_loss did not improve from 0.60810
# Epoch 220/1000
#  - 4s - loss: 0.4387 - accuracy: 0.7954 - val_loss: 1.0088 - val_accuracy: 0.4920
#
# Epoch 00220: val_loss did not improve from 0.60810
# Epoch 221/1000
#  - 4s - loss: 0.4320 - accuracy: 0.7958 - val_loss: 0.9926 - val_accuracy: 0.4996
#
# Epoch 00221: val_loss did not improve from 0.60810
# Epoch 222/1000
#  - 4s - loss: 0.4350 - accuracy: 0.7858 - val_loss: 1.1635 - val_accuracy: 0.5016
#
# Epoch 00222: val_loss did not improve from 0.60810
# Epoch 223/1000
#  - 4s - loss: 0.4347 - accuracy: 0.7847 - val_loss: 0.8898 - val_accuracy: 0.5124
#
# Epoch 00223: val_loss did not improve from 0.60810
# Epoch 224/1000
#  - 4s - loss: 0.4268 - accuracy: 0.7958 - val_loss: 1.3327 - val_accuracy: 0.4923
#
# Epoch 00224: val_loss did not improve from 0.60810
# Epoch 225/1000
#  - 4s - loss: 0.4324 - accuracy: 0.7916 - val_loss: 0.9260 - val_accuracy: 0.4978
#
# Epoch 00225: val_loss did not improve from 0.60810
# Epoch 226/1000
#  - 4s - loss: 0.4239 - accuracy: 0.7983 - val_loss: 1.0872 - val_accuracy: 0.5126
#
# Epoch 00226: val_loss did not improve from 0.60810
# Epoch 227/1000
#  - 4s - loss: 0.4281 - accuracy: 0.7945 - val_loss: 1.1306 - val_accuracy: 0.4999
#
# Epoch 00227: val_loss did not improve from 0.60810
# Epoch 228/1000
#  - 4s - loss: 0.4243 - accuracy: 0.7978 - val_loss: 0.9960 - val_accuracy: 0.5094
#
# Epoch 00228: val_loss did not improve from 0.60810
# Epoch 229/1000
#  - 4s - loss: 0.4277 - accuracy: 0.7954 - val_loss: 1.0604 - val_accuracy: 0.5048
#
# Epoch 00229: val_loss did not improve from 0.60810
# Epoch 230/1000
#  - 4s - loss: 0.4235 - accuracy: 0.8001 - val_loss: 0.8518 - val_accuracy: 0.5060
#
# Epoch 00230: val_loss did not improve from 0.60810
# Epoch 231/1000
#  - 4s - loss: 0.4172 - accuracy: 0.8026 - val_loss: 1.3594 - val_accuracy: 0.4900
#
# Epoch 00231: val_loss did not improve from 0.60810
# Epoch 232/1000
#  - 4s - loss: 0.4219 - accuracy: 0.7949 - val_loss: 1.0451 - val_accuracy: 0.5048
#
# Epoch 00232: val_loss did not improve from 0.60810
# Epoch 233/1000
#  - 4s - loss: 0.4177 - accuracy: 0.8059 - val_loss: 0.7439 - val_accuracy: 0.4920
#
# Epoch 00233: val_loss did not improve from 0.60810
# Epoch 234/1000
#  - 4s - loss: 0.4222 - accuracy: 0.8005 - val_loss: 0.9749 - val_accuracy: 0.5106
#
# Epoch 00234: val_loss did not improve from 0.60810
# Epoch 235/1000
#  - 4s - loss: 0.4102 - accuracy: 0.8092 - val_loss: 1.1384 - val_accuracy: 0.4975
#
# Epoch 00235: val_loss did not improve from 0.60810
# Epoch 236/1000
#  - 4s - loss: 0.4128 - accuracy: 0.8040 - val_loss: 0.9924 - val_accuracy: 0.5179
#
# Epoch 00236: val_loss did not improve from 0.60810
# Epoch 237/1000
#  - 4s - loss: 0.4082 - accuracy: 0.8074 - val_loss: 0.9073 - val_accuracy: 0.5045
#
# Epoch 00237: val_loss did not improve from 0.60810
# Epoch 238/1000
#  - 4s - loss: 0.4113 - accuracy: 0.8081 - val_loss: 1.0311 - val_accuracy: 0.5141
#
# Epoch 00238: val_loss did not improve from 0.60810
# Epoch 239/1000
#  - 4s - loss: 0.4021 - accuracy: 0.8137 - val_loss: 1.0881 - val_accuracy: 0.5065
#
# Epoch 00239: val_loss did not improve from 0.60810
# Epoch 240/1000
#  - 4s - loss: 0.4078 - accuracy: 0.8081 - val_loss: 0.9610 - val_accuracy: 0.5010
#
# Epoch 00240: val_loss did not improve from 0.60810
# Epoch 241/1000
#  - 4s - loss: 0.4051 - accuracy: 0.8151 - val_loss: 0.9220 - val_accuracy: 0.5031
#
# Epoch 00241: val_loss did not improve from 0.60810
# Epoch 242/1000
#  - 4s - loss: 0.4067 - accuracy: 0.8073 - val_loss: 0.9265 - val_accuracy: 0.5086
#
# Epoch 00242: val_loss did not improve from 0.60810
# Epoch 243/1000
#  - 4s - loss: 0.4023 - accuracy: 0.8135 - val_loss: 1.2508 - val_accuracy: 0.5115
#
# Epoch 00243: val_loss did not improve from 0.60810
# Epoch 244/1000
#  - 4s - loss: 0.4069 - accuracy: 0.8110 - val_loss: 1.4651 - val_accuracy: 0.5086
#
# Epoch 00244: val_loss did not improve from 0.60810
# Epoch 245/1000
#  - 4s - loss: 0.3952 - accuracy: 0.8156 - val_loss: 1.5811 - val_accuracy: 0.5089
#
# Epoch 00245: val_loss did not improve from 0.60810
# Epoch 246/1000
#  - 4s - loss: 0.3990 - accuracy: 0.8145 - val_loss: 1.2633 - val_accuracy: 0.5129
#
# Epoch 00246: val_loss did not improve from 0.60810
# Epoch 247/1000
#  - 4s - loss: 0.3845 - accuracy: 0.8243 - val_loss: 1.1766 - val_accuracy: 0.5057
#
# Epoch 00247: val_loss did not improve from 0.60810
# Epoch 248/1000
#  - 4s - loss: 0.3917 - accuracy: 0.8167 - val_loss: 0.9681 - val_accuracy: 0.5051
#
# Epoch 00248: val_loss did not improve from 0.60810
# Epoch 249/1000
#  - 4s - loss: 0.3946 - accuracy: 0.8144 - val_loss: 1.2195 - val_accuracy: 0.5039
#
# Epoch 00249: val_loss did not improve from 0.60810
# Epoch 250/1000
#  - 4s - loss: 0.3919 - accuracy: 0.8157 - val_loss: 0.9891 - val_accuracy: 0.5071
#
# Epoch 00250: val_loss did not improve from 0.60810
# Epoch 251/1000
#  - 4s - loss: 0.3889 - accuracy: 0.8228 - val_loss: 1.2942 - val_accuracy: 0.5010
#
# Epoch 00251: val_loss did not improve from 0.60810
# Epoch 252/1000
#  - 4s - loss: 0.3842 - accuracy: 0.8237 - val_loss: 0.9029 - val_accuracy: 0.5010
#
# Epoch 00252: val_loss did not improve from 0.60810
# Epoch 253/1000
#  - 5s - loss: 0.3912 - accuracy: 0.8181 - val_loss: 1.3604 - val_accuracy: 0.5071
#
# Epoch 00253: val_loss did not improve from 0.60810
# Epoch 254/1000
#  - 4s - loss: 0.3832 - accuracy: 0.8251 - val_loss: 1.2122 - val_accuracy: 0.5147
#
# Epoch 00254: val_loss did not improve from 0.60810
# Epoch 255/1000
#  - 4s - loss: 0.3743 - accuracy: 0.8294 - val_loss: 1.1519 - val_accuracy: 0.5010
#
# Epoch 00255: val_loss did not improve from 0.60810
# Epoch 256/1000
#  - 4s - loss: 0.3820 - accuracy: 0.8277 - val_loss: 1.2244 - val_accuracy: 0.5068
#
# Epoch 00256: val_loss did not improve from 0.60810
# Epoch 257/1000
#  - 4s - loss: 0.3791 - accuracy: 0.8332 - val_loss: 1.5063 - val_accuracy: 0.5054
#
# Epoch 00257: val_loss did not improve from 0.60810
# Epoch 258/1000
#  - 4s - loss: 0.3740 - accuracy: 0.8296 - val_loss: 1.0945 - val_accuracy: 0.4955
#
# Epoch 00258: val_loss did not improve from 0.60810
# Epoch 259/1000
#  - 4s - loss: 0.3756 - accuracy: 0.8294 - val_loss: 1.2851 - val_accuracy: 0.4946
#
# Epoch 00259: val_loss did not improve from 0.60810
# Epoch 260/1000
#  - 4s - loss: 0.3764 - accuracy: 0.8262 - val_loss: 1.1232 - val_accuracy: 0.5144
#
# Epoch 00260: val_loss did not improve from 0.60810
# Epoch 261/1000
#  - 4s - loss: 0.3750 - accuracy: 0.8277 - val_loss: 1.0534 - val_accuracy: 0.4961
#
# Epoch 00261: val_loss did not improve from 0.60810
# Epoch 262/1000
#  - 4s - loss: 0.3671 - accuracy: 0.8317 - val_loss: 1.4720 - val_accuracy: 0.5007
#
# Epoch 00262: val_loss did not improve from 0.60810
# Epoch 263/1000
#  - 4s - loss: 0.3798 - accuracy: 0.8254 - val_loss: 1.3216 - val_accuracy: 0.5057
#
# Epoch 00263: val_loss did not improve from 0.60810
# Epoch 264/1000
#  - 4s - loss: 0.3655 - accuracy: 0.8350 - val_loss: 1.1114 - val_accuracy: 0.5065
#
# Epoch 00264: val_loss did not improve from 0.60810
# Epoch 265/1000
#  - 4s - loss: 0.3592 - accuracy: 0.8360 - val_loss: 1.1402 - val_accuracy: 0.5086
#
# Epoch 00265: val_loss did not improve from 0.60810
# Epoch 266/1000
#  - 4s - loss: 0.3558 - accuracy: 0.8436 - val_loss: 1.1565 - val_accuracy: 0.5147
#
# Epoch 00266: val_loss did not improve from 0.60810
# Epoch 267/1000
#  - 4s - loss: 0.3652 - accuracy: 0.8343 - val_loss: 1.3908 - val_accuracy: 0.5028
#
# Epoch 00267: val_loss did not improve from 0.60810
# Epoch 268/1000
#  - 4s - loss: 0.3555 - accuracy: 0.8462 - val_loss: 1.3720 - val_accuracy: 0.5155
#
# Epoch 00268: val_loss did not improve from 0.60810
# Epoch 269/1000
#  - 4s - loss: 0.3618 - accuracy: 0.8389 - val_loss: 1.5292 - val_accuracy: 0.5019
#
# Epoch 00269: val_loss did not improve from 0.60810
# Epoch 270/1000
#  - 4s - loss: 0.3644 - accuracy: 0.8309 - val_loss: 1.0975 - val_accuracy: 0.5016
#
# Epoch 00270: val_loss did not improve from 0.60810
# Epoch 271/1000
#  - 4s - loss: 0.3561 - accuracy: 0.8420 - val_loss: 1.4475 - val_accuracy: 0.5118
#
# Epoch 00271: val_loss did not improve from 0.60810
# Epoch 272/1000
#  - 4s - loss: 0.3563 - accuracy: 0.8382 - val_loss: 0.7134 - val_accuracy: 0.5068
#
# Epoch 00272: val_loss did not improve from 0.60810
# Epoch 273/1000
#  - 4s - loss: 0.3533 - accuracy: 0.8439 - val_loss: 0.8424 - val_accuracy: 0.5092
#
# Epoch 00273: val_loss did not improve from 0.60810
# Epoch 274/1000
#  - 4s - loss: 0.3560 - accuracy: 0.8362 - val_loss: 0.7439 - val_accuracy: 0.5196
#
# Epoch 00274: val_loss did not improve from 0.60810
# Epoch 275/1000
#  - 4s - loss: 0.3541 - accuracy: 0.8386 - val_loss: 1.2897 - val_accuracy: 0.4990
#
# Epoch 00275: val_loss did not improve from 0.60810
# Epoch 276/1000
#  - 4s - loss: 0.3469 - accuracy: 0.8499 - val_loss: 1.3234 - val_accuracy: 0.4996
#
# Epoch 00276: val_loss did not improve from 0.60810
# Epoch 277/1000
#  - 4s - loss: 0.3471 - accuracy: 0.8434 - val_loss: 1.4100 - val_accuracy: 0.5170
#
# Epoch 00277: val_loss did not improve from 0.60810
# Epoch 278/1000
#  - 4s - loss: 0.3327 - accuracy: 0.8535 - val_loss: 1.2962 - val_accuracy: 0.4993
#
# Epoch 00278: val_loss did not improve from 0.60810
# Epoch 279/1000
#  - 4s - loss: 0.3490 - accuracy: 0.8450 - val_loss: 1.0900 - val_accuracy: 0.5089
#
# Epoch 00279: val_loss did not improve from 0.60810
# Epoch 280/1000
#  - 4s - loss: 0.3487 - accuracy: 0.8494 - val_loss: 1.4259 - val_accuracy: 0.5219
#
# Epoch 00280: val_loss did not improve from 0.60810
# Epoch 281/1000
#  - 4s - loss: 0.3467 - accuracy: 0.8466 - val_loss: 1.2985 - val_accuracy: 0.5036
#
# Epoch 00281: val_loss did not improve from 0.60810
# Epoch 282/1000
#  - 4s - loss: 0.3436 - accuracy: 0.8482 - val_loss: 0.8256 - val_accuracy: 0.5112
#
# Epoch 00282: val_loss did not improve from 0.60810
# Epoch 283/1000
#  - 4s - loss: 0.3415 - accuracy: 0.8531 - val_loss: 1.6654 - val_accuracy: 0.5155
#
# Epoch 00283: val_loss did not improve from 0.60810
# Epoch 284/1000
#  - 4s - loss: 0.3388 - accuracy: 0.8516 - val_loss: 1.2394 - val_accuracy: 0.5042
#
# Epoch 00284: val_loss did not improve from 0.60810
# Epoch 285/1000
#  - 4s - loss: 0.3395 - accuracy: 0.8511 - val_loss: 1.2938 - val_accuracy: 0.5106
#
# Epoch 00285: val_loss did not improve from 0.60810
# Epoch 286/1000
#  - 4s - loss: 0.3397 - accuracy: 0.8535 - val_loss: 1.2190 - val_accuracy: 0.5051
#
# Epoch 00286: val_loss did not improve from 0.60810
# Epoch 287/1000
#  - 4s - loss: 0.3347 - accuracy: 0.8537 - val_loss: 1.1749 - val_accuracy: 0.5074
#
# Epoch 00287: val_loss did not improve from 0.60810
# Epoch 288/1000
#  - 4s - loss: 0.3256 - accuracy: 0.8605 - val_loss: 1.2108 - val_accuracy: 0.5170
#
# Epoch 00288: val_loss did not improve from 0.60810
# Epoch 289/1000
#  - 4s - loss: 0.3322 - accuracy: 0.8548 - val_loss: 1.1672 - val_accuracy: 0.5106
#
# Epoch 00289: val_loss did not improve from 0.60810
# Epoch 290/1000
#  - 4s - loss: 0.3311 - accuracy: 0.8553 - val_loss: 1.5531 - val_accuracy: 0.5060
#
# Epoch 00290: val_loss did not improve from 0.60810
# Epoch 291/1000
#  - 4s - loss: 0.3312 - accuracy: 0.8563 - val_loss: 1.1762 - val_accuracy: 0.5074
#
# Epoch 00291: val_loss did not improve from 0.60810
# Epoch 292/1000
#  - 5s - loss: 0.3266 - accuracy: 0.8576 - val_loss: 0.9686 - val_accuracy: 0.5126
#
# Epoch 00292: val_loss did not improve from 0.60810
# Epoch 293/1000
#  - 4s - loss: 0.3280 - accuracy: 0.8546 - val_loss: 1.0154 - val_accuracy: 0.5051
#
# Epoch 00293: val_loss did not improve from 0.60810
# Epoch 294/1000
#  - 4s - loss: 0.3229 - accuracy: 0.8612 - val_loss: 1.0049 - val_accuracy: 0.5042
#
# Epoch 00294: val_loss did not improve from 0.60810
# Epoch 295/1000
#  - 4s - loss: 0.3242 - accuracy: 0.8624 - val_loss: 1.5713 - val_accuracy: 0.5045
#
# Epoch 00295: val_loss did not improve from 0.60810
# Epoch 296/1000
#  - 4s - loss: 0.3242 - accuracy: 0.8592 - val_loss: 1.0125 - val_accuracy: 0.5109
#
# Epoch 00296: val_loss did not improve from 0.60810
# Epoch 297/1000
#  - 4s - loss: 0.3176 - accuracy: 0.8657 - val_loss: 1.2294 - val_accuracy: 0.5173
#
# Epoch 00297: val_loss did not improve from 0.60810
# Epoch 298/1000
#  - 4s - loss: 0.3197 - accuracy: 0.8612 - val_loss: 1.0823 - val_accuracy: 0.5042
#
# Epoch 00298: val_loss did not improve from 0.60810
# Epoch 299/1000
#  - 4s - loss: 0.3216 - accuracy: 0.8612 - val_loss: 1.1379 - val_accuracy: 0.5045
#
# Epoch 00299: val_loss did not improve from 0.60810
# Epoch 300/1000
#  - 4s - loss: 0.3154 - accuracy: 0.8691 - val_loss: 1.2317 - val_accuracy: 0.5179
#
# Epoch 00300: val_loss did not improve from 0.60810
# Epoch 301/1000
#  - 4s - loss: 0.3105 - accuracy: 0.8738 - val_loss: 1.3212 - val_accuracy: 0.5033
#
# Epoch 00301: val_loss did not improve from 0.60810
# Epoch 302/1000
#  - 4s - loss: 0.3094 - accuracy: 0.8689 - val_loss: 1.7855 - val_accuracy: 0.5074
#
# Epoch 00302: val_loss did not improve from 0.60810
# Epoch 303/1000
#  - 4s - loss: 0.3092 - accuracy: 0.8637 - val_loss: 1.2776 - val_accuracy: 0.5103
#
# Epoch 00303: val_loss did not improve from 0.60810
# Epoch 304/1000
#  - 4s - loss: 0.3091 - accuracy: 0.8683 - val_loss: 1.0082 - val_accuracy: 0.5028
#
# Epoch 00304: val_loss did not improve from 0.60810
# Epoch 305/1000
#  - 4s - loss: 0.3113 - accuracy: 0.8704 - val_loss: 1.5578 - val_accuracy: 0.5164
#
# Epoch 00305: val_loss did not improve from 0.60810
# Epoch 306/1000
#  - 4s - loss: 0.3056 - accuracy: 0.8740 - val_loss: 1.6933 - val_accuracy: 0.5100
#
# Epoch 00306: val_loss did not improve from 0.60810
# Epoch 307/1000
#  - 4s - loss: 0.3061 - accuracy: 0.8714 - val_loss: 1.6388 - val_accuracy: 0.5013
#
# Epoch 00307: val_loss did not improve from 0.60810
# Epoch 308/1000
#  - 4s - loss: 0.3040 - accuracy: 0.8763 - val_loss: 1.1562 - val_accuracy: 0.5074
#
# Epoch 00308: val_loss did not improve from 0.60810
# Epoch 309/1000
#  - 4s - loss: 0.2995 - accuracy: 0.8767 - val_loss: 1.2830 - val_accuracy: 0.5010
#
# Epoch 00309: val_loss did not improve from 0.60810
# Epoch 310/1000
#  - 4s - loss: 0.3027 - accuracy: 0.8744 - val_loss: 1.9202 - val_accuracy: 0.5054
#
# Epoch 00310: val_loss did not improve from 0.60810
# Epoch 311/1000
#  - 4s - loss: 0.2989 - accuracy: 0.8763 - val_loss: 1.4071 - val_accuracy: 0.5039
#
# Epoch 00311: val_loss did not improve from 0.60810
# Epoch 312/1000
#  - 4s - loss: 0.2936 - accuracy: 0.8765 - val_loss: 1.2235 - val_accuracy: 0.5007
#
# Epoch 00312: val_loss did not improve from 0.60810
# Epoch 313/1000
#  - 4s - loss: 0.2943 - accuracy: 0.8773 - val_loss: 1.4147 - val_accuracy: 0.5010
#
# Epoch 00313: val_loss did not improve from 0.60810
# Epoch 314/1000
#  - 4s - loss: 0.2964 - accuracy: 0.8768 - val_loss: 1.6744 - val_accuracy: 0.5025
#
# Epoch 00314: val_loss did not improve from 0.60810
# Epoch 315/1000
#  - 4s - loss: 0.3028 - accuracy: 0.8713 - val_loss: 1.2511 - val_accuracy: 0.5071
#
# Epoch 00315: val_loss did not improve from 0.60810
# Epoch 316/1000
#  - 4s - loss: 0.2900 - accuracy: 0.8847 - val_loss: 1.4675 - val_accuracy: 0.4868
#
# Epoch 00316: val_loss did not improve from 0.60810
# Epoch 317/1000
#  - 4s - loss: 0.2841 - accuracy: 0.8854 - val_loss: 1.2617 - val_accuracy: 0.5022
#
# Epoch 00317: val_loss did not improve from 0.60810
# Epoch 318/1000
# ...
#
# Epoch 00893: val_loss did not improve from 0.60810
# Epoch 894/1000
#  - 4s - loss: 0.0270 - accuracy: 0.9951 - val_loss: 4.2045 - val_accuracy: 0.5190
#
# Epoch 00894: val_loss did not improve from 0.60810
# Epoch 895/1000
#  - 4s - loss: 0.0255 - accuracy: 0.9960 - val_loss: 3.2317 - val_accuracy: 0.5211
#
# Epoch 00895: val_loss did not improve from 0.60810
# Epoch 896/1000
#  - 4s - loss: 0.0264 - accuracy: 0.9953 - val_loss: 2.6483 - val_accuracy: 0.5170
#
# Epoch 00896: val_loss did not improve from 0.60810
# Epoch 897/1000
#  - 4s - loss: 0.0255 - accuracy: 0.9951 - val_loss: 3.1094 - val_accuracy: 0.5173
#
# Epoch 00897: val_loss did not improve from 0.60810
# Epoch 898/1000
#  - 4s - loss: 0.0252 - accuracy: 0.9949 - val_loss: 3.6921 - val_accuracy: 0.5173
#
# Epoch 00898: val_loss did not improve from 0.60810
# Epoch 899/1000
#  - 4s - loss: 0.0238 - accuracy: 0.9968 - val_loss: 2.1317 - val_accuracy: 0.5103
#
# Epoch 00899: val_loss did not improve from 0.60810
# Epoch 900/1000
#  - 4s - loss: 0.0259 - accuracy: 0.9953 - val_loss: 2.8203 - val_accuracy: 0.5103
#
# Epoch 00900: val_loss did not improve from 0.60810
# Epoch 901/1000
#  - 4s - loss: 0.0252 - accuracy: 0.9955 - val_loss: 2.2325 - val_accuracy: 0.5109
#
# Epoch 00901: val_loss did not improve from 0.60810
# Epoch 902/1000
#  - 4s - loss: 0.0246 - accuracy: 0.9955 - val_loss: 2.7037 - val_accuracy: 0.5193
#
# Epoch 00902: val_loss did not improve from 0.60810
# Epoch 903/1000
#  - 4s - loss: 0.0238 - accuracy: 0.9958 - val_loss: 1.4952 - val_accuracy: 0.5103
#
# Epoch 00903: val_loss did not improve from 0.60810
# Epoch 904/1000
#  - 4s - loss: 0.0221 - accuracy: 0.9968 - val_loss: 3.0480 - val_accuracy: 0.5080
#
# Epoch 00904: val_loss did not improve from 0.60810
# Epoch 905/1000
#  - 4s - loss: 0.0221 - accuracy: 0.9973 - val_loss: 2.5996 - val_accuracy: 0.5167
#
# Epoch 00905: val_loss did not improve from 0.60810
# Epoch 906/1000
#  - 4s - loss: 0.0238 - accuracy: 0.9955 - val_loss: 3.4318 - val_accuracy: 0.5118
#
# Epoch 00906: val_loss did not improve from 0.60810
# Epoch 907/1000
#  - 4s - loss: 0.0241 - accuracy: 0.9963 - val_loss: 2.6778 - val_accuracy: 0.5211
#
# Epoch 00907: val_loss did not improve from 0.60810
# Epoch 908/1000
#  - 4s - loss: 0.0257 - accuracy: 0.9945 - val_loss: 3.3875 - val_accuracy: 0.5083
#
# Epoch 00908: val_loss did not improve from 0.60810
# Epoch 909/1000
#  - 4s - loss: 0.0228 - accuracy: 0.9964 - val_loss: 2.8801 - val_accuracy: 0.5121
#
# Epoch 00909: val_loss did not improve from 0.60810
# Epoch 910/1000
#  - 4s - loss: 0.0231 - accuracy: 0.9955 - val_loss: 2.3247 - val_accuracy: 0.5103
#
# Epoch 00910: val_loss did not improve from 0.60810
# Epoch 911/1000
#  - 4s - loss: 0.0214 - accuracy: 0.9975 - val_loss: 4.3911 - val_accuracy: 0.5182
#
# Epoch 00911: val_loss did not improve from 0.60810
# Epoch 912/1000
#  - 4s - loss: 0.0229 - accuracy: 0.9963 - val_loss: 3.0920 - val_accuracy: 0.5164
#
# Epoch 00912: val_loss did not improve from 0.60810
# Epoch 913/1000
#  - 4s - loss: 0.0224 - accuracy: 0.9963 - val_loss: 2.4319 - val_accuracy: 0.5173
#
# Epoch 00913: val_loss did not improve from 0.60810
# Epoch 914/1000
#  - 4s - loss: 0.0222 - accuracy: 0.9968 - val_loss: 2.0681 - val_accuracy: 0.5100
#
# Epoch 00914: val_loss did not improve from 0.60810
# Epoch 915/1000
#  - 4s - loss: 0.0236 - accuracy: 0.9953 - val_loss: 1.9888 - val_accuracy: 0.5074
#
# Epoch 00915: val_loss did not improve from 0.60810
# Epoch 916/1000
#  - 4s - loss: 0.0225 - accuracy: 0.9965 - val_loss: 2.1193 - val_accuracy: 0.5185
#
# Epoch 00916: val_loss did not improve from 0.60810
# Epoch 917/1000
#  - 4s - loss: 0.0221 - accuracy: 0.9954 - val_loss: 3.7404 - val_accuracy: 0.5109
#
# Epoch 00917: val_loss did not improve from 0.60810
# Epoch 918/1000
#  - 4s - loss: 0.0241 - accuracy: 0.9953 - val_loss: 2.0068 - val_accuracy: 0.5112
#
# Epoch 00918: val_loss did not improve from 0.60810
# Epoch 919/1000
#  - 4s - loss: 0.0216 - accuracy: 0.9968 - val_loss: 2.5453 - val_accuracy: 0.5158
#
# Epoch 00919: val_loss did not improve from 0.60810
# Epoch 920/1000
#  - 4s - loss: 0.0230 - accuracy: 0.9966 - val_loss: 3.1275 - val_accuracy: 0.5138
#
# Epoch 00920: val_loss did not improve from 0.60810
# Epoch 921/1000
#  - 4s - loss: 0.0209 - accuracy: 0.9970 - val_loss: 4.2892 - val_accuracy: 0.5115
#
# Epoch 00921: val_loss did not improve from 0.60810
# Epoch 922/1000
#  - 4s - loss: 0.0238 - accuracy: 0.9949 - val_loss: 3.1334 - val_accuracy: 0.5135
#
# Epoch 00922: val_loss did not improve from 0.60810
# Epoch 923/1000
#  - 4s - loss: 0.0220 - accuracy: 0.9965 - val_loss: 2.8212 - val_accuracy: 0.5193
#
# Epoch 00923: val_loss did not improve from 0.60810
# Epoch 924/1000
#  - 4s - loss: 0.0209 - accuracy: 0.9964 - val_loss: 1.7725 - val_accuracy: 0.5150
#
# Epoch 00924: val_loss did not improve from 0.60810
# Epoch 925/1000
#  - 4s - loss: 0.0227 - accuracy: 0.9963 - val_loss: 1.9648 - val_accuracy: 0.5158
#
# Epoch 00925: val_loss did not improve from 0.60810
# Epoch 926/1000
#  - 4s - loss: 0.0217 - accuracy: 0.9969 - val_loss: 2.7907 - val_accuracy: 0.5118
#
# Epoch 00926: val_loss did not improve from 0.60810
# Epoch 927/1000
#  - 4s - loss: 0.0219 - accuracy: 0.9965 - val_loss: 3.5054 - val_accuracy: 0.5158
#
# Epoch 00927: val_loss did not improve from 0.60810
# Epoch 928/1000
#  - 4s - loss: 0.0211 - accuracy: 0.9968 - val_loss: 3.1440 - val_accuracy: 0.5158
#
# Epoch 00928: val_loss did not improve from 0.60810
# Epoch 929/1000
#  - 4s - loss: 0.0214 - accuracy: 0.9969 - val_loss: 2.8263 - val_accuracy: 0.5158
#
# Epoch 00929: val_loss did not improve from 0.60810
# Epoch 930/1000
#  - 4s - loss: 0.0212 - accuracy: 0.9961 - val_loss: 3.1114 - val_accuracy: 0.5190
#
# Epoch 00930: val_loss did not improve from 0.60810
# Epoch 931/1000
#  - 4s - loss: 0.0209 - accuracy: 0.9964 - val_loss: 4.2090 - val_accuracy: 0.5158
#
# Epoch 00931: val_loss did not improve from 0.60810
# Epoch 932/1000
#  - 4s - loss: 0.0227 - accuracy: 0.9964 - val_loss: 2.5288 - val_accuracy: 0.5187
#
# Epoch 00932: val_loss did not improve from 0.60810
# Epoch 933/1000
#  - 4s - loss: 0.0226 - accuracy: 0.9958 - val_loss: 3.7995 - val_accuracy: 0.5228
#
# Epoch 00933: val_loss did not improve from 0.60810
# Epoch 934/1000
#  - 4s - loss: 0.0198 - accuracy: 0.9971 - val_loss: 3.5881 - val_accuracy: 0.5155
#
# Epoch 00934: val_loss did not improve from 0.60810
# Epoch 935/1000
#  - 4s - loss: 0.0222 - accuracy: 0.9953 - val_loss: 3.4021 - val_accuracy: 0.5153
#
# Epoch 00935: val_loss did not improve from 0.60810
# Epoch 936/1000
#  - 4s - loss: 0.0183 - accuracy: 0.9978 - val_loss: 3.3192 - val_accuracy: 0.5155
#
# Epoch 00936: val_loss did not improve from 0.60810
# Epoch 937/1000
#  - 4s - loss: 0.0222 - accuracy: 0.9960 - val_loss: 2.1073 - val_accuracy: 0.5219
#
# Epoch 00937: val_loss did not improve from 0.60810
# Epoch 938/1000
#  - 4s - loss: 0.0251 - accuracy: 0.9949 - val_loss: 2.8031 - val_accuracy: 0.5132
#
# Epoch 00938: val_loss did not improve from 0.60810
# Epoch 939/1000
#  - 4s - loss: 0.0235 - accuracy: 0.9965 - val_loss: 2.9737 - val_accuracy: 0.5176
#
# Epoch 00939: val_loss did not improve from 0.60810
# Epoch 940/1000
#  - 4s - loss: 0.0202 - accuracy: 0.9971 - val_loss: 3.3220 - val_accuracy: 0.5173
#
# Epoch 00940: val_loss did not improve from 0.60810
# Epoch 941/1000
#  - 4s - loss: 0.0224 - accuracy: 0.9960 - val_loss: 2.7607 - val_accuracy: 0.5164
#
# Epoch 00941: val_loss did not improve from 0.60810
# Epoch 942/1000
#  - 4s - loss: 0.0228 - accuracy: 0.9954 - val_loss: 3.0054 - val_accuracy: 0.5153
#
# Epoch 00942: val_loss did not improve from 0.60810
# Epoch 943/1000
#  - 4s - loss: 0.0210 - accuracy: 0.9965 - val_loss: 2.7156 - val_accuracy: 0.5179
#
# Epoch 00943: val_loss did not improve from 0.60810
# Epoch 944/1000
#  - 4s - loss: 0.0204 - accuracy: 0.9959 - val_loss: 2.4688 - val_accuracy: 0.5158
#
# Epoch 00944: val_loss did not improve from 0.60810
# Epoch 945/1000
#  - 4s - loss: 0.0191 - accuracy: 0.9970 - val_loss: 3.5793 - val_accuracy: 0.5126
#
# Epoch 00945: val_loss did not improve from 0.60810
# Epoch 946/1000
#  - 4s - loss: 0.0184 - accuracy: 0.9981 - val_loss: 3.1888 - val_accuracy: 0.5103
#
# Epoch 00946: val_loss did not improve from 0.60810
# Epoch 947/1000
#  - 4s - loss: 0.0207 - accuracy: 0.9969 - val_loss: 2.3757 - val_accuracy: 0.5121
#
# Epoch 00947: val_loss did not improve from 0.60810
# Epoch 948/1000
#  - 4s - loss: 0.0232 - accuracy: 0.9950 - val_loss: 4.1402 - val_accuracy: 0.5199
#
# Epoch 00948: val_loss did not improve from 0.60810
# Epoch 949/1000
#  - 4s - loss: 0.0239 - accuracy: 0.9960 - val_loss: 2.4959 - val_accuracy: 0.5187
#
# Epoch 00949: val_loss did not improve from 0.60810
# Epoch 950/1000
#  - 4s - loss: 0.0220 - accuracy: 0.9953 - val_loss: 3.2647 - val_accuracy: 0.5190
#
# Epoch 00950: val_loss did not improve from 0.60810
# Epoch 951/1000
#  - 4s - loss: 0.0203 - accuracy: 0.9965 - val_loss: 2.7806 - val_accuracy: 0.5147
#
# Epoch 00951: val_loss did not improve from 0.60810
# Epoch 952/1000
#  - 4s - loss: 0.0187 - accuracy: 0.9978 - val_loss: 2.4447 - val_accuracy: 0.5176
#
# Epoch 00952: val_loss did not improve from 0.60810
# Epoch 953/1000
#  - 4s - loss: 0.0184 - accuracy: 0.9973 - val_loss: 2.8784 - val_accuracy: 0.5109
#
# Epoch 00953: val_loss did not improve from 0.60810
# Epoch 954/1000
#  - 4s - loss: 0.0207 - accuracy: 0.9965 - val_loss: 2.3082 - val_accuracy: 0.5138
#
# Epoch 00954: val_loss did not improve from 0.60810
# Epoch 955/1000
#  - 4s - loss: 0.0206 - accuracy: 0.9970 - val_loss: 2.9759 - val_accuracy: 0.5150
#
# Epoch 00955: val_loss did not improve from 0.60810
# Epoch 956/1000
#  - 4s - loss: 0.0206 - accuracy: 0.9956 - val_loss: 3.0953 - val_accuracy: 0.5109
#
# Epoch 00956: val_loss did not improve from 0.60810
# Epoch 957/1000
#  - 4s - loss: 0.0205 - accuracy: 0.9966 - val_loss: 2.2882 - val_accuracy: 0.5126
#
# Epoch 00957: val_loss did not improve from 0.60810
# Epoch 958/1000
#  - 4s - loss: 0.0206 - accuracy: 0.9959 - val_loss: 3.0803 - val_accuracy: 0.5161
#
# Epoch 00958: val_loss did not improve from 0.60810
# Epoch 959/1000
#  - 4s - loss: 0.0206 - accuracy: 0.9966 - val_loss: 3.2479 - val_accuracy: 0.5124
#
# Epoch 00959: val_loss did not improve from 0.60810
# Epoch 960/1000
#  - 4s - loss: 0.0188 - accuracy: 0.9968 - val_loss: 2.9077 - val_accuracy: 0.5158
#
# Epoch 00960: val_loss did not improve from 0.60810
# Epoch 961/1000
#  - 4s - loss: 0.0214 - accuracy: 0.9958 - val_loss: 2.5356 - val_accuracy: 0.5176
#
# Epoch 00961: val_loss did not improve from 0.60810
# Epoch 962/1000
#  - 4s - loss: 0.0214 - accuracy: 0.9970 - val_loss: 3.8456 - val_accuracy: 0.5121
#
# Epoch 00962: val_loss did not improve from 0.60810
# Epoch 963/1000
#  - 4s - loss: 0.0231 - accuracy: 0.9950 - val_loss: 2.3516 - val_accuracy: 0.5138
#
# Epoch 00963: val_loss did not improve from 0.60810
# Epoch 964/1000
#  - 4s - loss: 0.0210 - accuracy: 0.9961 - val_loss: 2.8567 - val_accuracy: 0.5193
#
# Epoch 00964: val_loss did not improve from 0.60810
# Epoch 965/1000
#  - 4s - loss: 0.0202 - accuracy: 0.9971 - val_loss: 3.6798 - val_accuracy: 0.5182
#
# Epoch 00965: val_loss did not improve from 0.60810
# Epoch 966/1000
#  - 4s - loss: 0.0217 - accuracy: 0.9963 - val_loss: 1.8861 - val_accuracy: 0.5161
#
# Epoch 00966: val_loss did not improve from 0.60810
# Epoch 967/1000
#  - 4s - loss: 0.0198 - accuracy: 0.9963 - val_loss: 2.8746 - val_accuracy: 0.5167
#
# Epoch 00967: val_loss did not improve from 0.60810
# Epoch 968/1000
#  - 4s - loss: 0.0209 - accuracy: 0.9959 - val_loss: 3.9252 - val_accuracy: 0.5219
#
# Epoch 00968: val_loss did not improve from 0.60810
# Epoch 969/1000
#  - 4s - loss: 0.0200 - accuracy: 0.9970 - val_loss: 3.2615 - val_accuracy: 0.5147
#
# Epoch 00969: val_loss did not improve from 0.60810
# Epoch 970/1000
#  - 4s - loss: 0.0187 - accuracy: 0.9968 - val_loss: 2.8670 - val_accuracy: 0.5158
#
# Epoch 00970: val_loss did not improve from 0.60810
# Epoch 971/1000
#  - 4s - loss: 0.0180 - accuracy: 0.9975 - val_loss: 3.6299 - val_accuracy: 0.5147
#
# Epoch 00971: val_loss did not improve from 0.60810
# Epoch 972/1000
#  - 4s - loss: 0.0192 - accuracy: 0.9971 - val_loss: 2.5524 - val_accuracy: 0.5129
#
# Epoch 00972: val_loss did not improve from 0.60810
# Epoch 973/1000
#  - 4s - loss: 0.0185 - accuracy: 0.9969 - val_loss: 3.0719 - val_accuracy: 0.5179
#
# Epoch 00973: val_loss did not improve from 0.60810
# Epoch 974/1000
#  - 4s - loss: 0.0178 - accuracy: 0.9975 - val_loss: 2.4959 - val_accuracy: 0.5158
#
# Epoch 00974: val_loss did not improve from 0.60810
# Epoch 975/1000
#  - 4s - loss: 0.0174 - accuracy: 0.9970 - val_loss: 2.6456 - val_accuracy: 0.5150
#
# Epoch 00975: val_loss did not improve from 0.60810
# Epoch 976/1000
#  - 4s - loss: 0.0186 - accuracy: 0.9968 - val_loss: 2.5315 - val_accuracy: 0.5126
#
# Epoch 00976: val_loss did not improve from 0.60810
# Epoch 977/1000
#  - 4s - loss: 0.0165 - accuracy: 0.9978 - val_loss: 3.0816 - val_accuracy: 0.5118
#
# Epoch 00977: val_loss did not improve from 0.60810
# Epoch 978/1000
#  - 4s - loss: 0.0169 - accuracy: 0.9974 - val_loss: 0.8701 - val_accuracy: 0.5112
#
# Epoch 00978: val_loss did not improve from 0.60810
# Epoch 979/1000
#  - 4s - loss: 0.0215 - accuracy: 0.9949 - val_loss: 2.5430 - val_accuracy: 0.5092
#
# Epoch 00979: val_loss did not improve from 0.60810
# Epoch 980/1000
#  - 4s - loss: 0.0171 - accuracy: 0.9978 - val_loss: 2.3722 - val_accuracy: 0.5161
#
# Epoch 00980: val_loss did not improve from 0.60810
# Epoch 981/1000
#  - 4s - loss: 0.0179 - accuracy: 0.9970 - val_loss: 1.9398 - val_accuracy: 0.5161
#
# Epoch 00981: val_loss did not improve from 0.60810
# Epoch 982/1000
#  - 4s - loss: 0.0189 - accuracy: 0.9965 - val_loss: 2.7913 - val_accuracy: 0.5144
#
# Epoch 00982: val_loss did not improve from 0.60810
# Epoch 983/1000
#  - 4s - loss: 0.0201 - accuracy: 0.9961 - val_loss: 2.1620 - val_accuracy: 0.5080
#
# Epoch 00983: val_loss did not improve from 0.60810
# Epoch 984/1000
#  - 4s - loss: 0.0175 - accuracy: 0.9975 - val_loss: 3.0126 - val_accuracy: 0.5150
#
# Epoch 00984: val_loss did not improve from 0.60810
# Epoch 985/1000
#  - 4s - loss: 0.0183 - accuracy: 0.9973 - val_loss: 2.3437 - val_accuracy: 0.5071
#
# Epoch 00985: val_loss did not improve from 0.60810
# Epoch 986/1000
#  - 4s - loss: 0.0173 - accuracy: 0.9979 - val_loss: 4.1221 - val_accuracy: 0.5089
#
# Epoch 00986: val_loss did not improve from 0.60810
# Epoch 987/1000
#  - 4s - loss: 0.0168 - accuracy: 0.9978 - val_loss: 2.4933 - val_accuracy: 0.5124
#
# Epoch 00987: val_loss did not improve from 0.60810
# Epoch 988/1000
#  - 4s - loss: 0.0185 - accuracy: 0.9973 - val_loss: 2.2674 - val_accuracy: 0.5112
#
# Epoch 00988: val_loss did not improve from 0.60810
# Epoch 989/1000
#  - 4s - loss: 0.0198 - accuracy: 0.9959 - val_loss: 3.0806 - val_accuracy: 0.5118
#
# Epoch 00989: val_loss did not improve from 0.60810
# Epoch 990/1000
#  - 4s - loss: 0.0182 - accuracy: 0.9975 - val_loss: 2.9120 - val_accuracy: 0.5106
#
# Epoch 00990: val_loss did not improve from 0.60810
# Epoch 991/1000
#  - 4s - loss: 0.0178 - accuracy: 0.9975 - val_loss: 2.5257 - val_accuracy: 0.5150
#
# Epoch 00991: val_loss did not improve from 0.60810
# Epoch 992/1000
#  - 4s - loss: 0.0181 - accuracy: 0.9975 - val_loss: 2.3714 - val_accuracy: 0.5135
#
# Epoch 00992: val_loss did not improve from 0.60810
# Epoch 993/1000
#  - 4s - loss: 0.0163 - accuracy: 0.9973 - val_loss: 3.3661 - val_accuracy: 0.5164
#
# Epoch 00993: val_loss did not improve from 0.60810
# Epoch 994/1000
#  - 4s - loss: 0.0161 - accuracy: 0.9981 - val_loss: 3.2967 - val_accuracy: 0.5124
#
# Epoch 00994: val_loss did not improve from 0.60810
# Epoch 995/1000
#  - 4s - loss: 0.0168 - accuracy: 0.9974 - val_loss: 2.6039 - val_accuracy: 0.5126
#
# Epoch 00995: val_loss did not improve from 0.60810
# Epoch 996/1000
#  - 4s - loss: 0.0175 - accuracy: 0.9976 - val_loss: 3.7082 - val_accuracy: 0.5129
#
# Epoch 00996: val_loss did not improve from 0.60810
# Epoch 997/1000
#  - 4s - loss: 0.0177 - accuracy: 0.9968 - val_loss: 3.6328 - val_accuracy: 0.5135
#
# Epoch 00997: val_loss did not improve from 0.60810
# Epoch 998/1000
#  - 4s - loss: 0.0180 - accuracy: 0.9970 - val_loss: 2.7932 - val_accuracy: 0.5109
#
# Epoch 00998: val_loss did not improve from 0.60810
# Epoch 999/1000
#  - 4s - loss: 0.0180 - accuracy: 0.9968 - val_loss: 2.6025 - val_accuracy: 0.5176
#
# Epoch 00999: val_loss did not improve from 0.60810
# Epoch 1000/1000
#  - 4s - loss: 0.0169 - accuracy: 0.9978 - val_loss: 2.5067 - val_accuracy: 0.5234
#
# Epoch 01000: val_loss did not improve from 0.60810

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
# model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_ex_02008.h5'
# model_name = 'classifier_45_close_updown_pr_theta.h5'
# model_name = 'classifier_45_close_updown_pr_theta_train_evendata_shuffle2_300k.h5'
# model_name = 'classifier_45_close_updown_pr_05532.h5'

model = keras.models.load_model(ckpt_path + model_name)

# %%
org_x_test = x_test
org_y_test = y_test
org_pr_test = pr_test

# %%
x_test = org_x_test
y_test = org_y_test
pr_test = org_pr_test

# %%
concat_x = np.vstack((org_x_test, new_input_x))
concat_y = np.vstack((org_y_test, np.where(new_input_pr > 1, 1, 0)))
concat_pr = np.vstack((org_pr_test, new_input_pr))

# %%
x_test = new_input_x
y_test = np.where(new_input_pr > 1, 1, 0)
pr_test = new_input_pr

# %%
# x_test = new_input_x
# y_test = np.where(new_input_pr > 1, 1, 0)
# pr_test = new_input_pr

# x_test = org_x_test
# y_test = org_y_test
# pr_test = org_pr_test

# x_test = x_train
# y_test = y_train
# pr_test = pr_train

# x_test = x_val
# y_test = y_val
# pr_test = pr_val

# x_test = concat_x
# y_test = np.where(concat_pr > 1, 1, 0)
# pr_test = concat_pr

test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
# print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  if thresh < 0.6:
      continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  print('precision :', precision_score(y_test, y_pred))
  print('recall :', recall_score(y_test, y_pred))
  print()

  print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # plt.show()  
  print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
    print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
    print('thresh :', thresh)
    
  # if len(threshold) == 1:
  plt.figure(figsize=(10, 5))
  plt.subplot(121)
  plt.plot(np.cumprod(test_pr_list))
  plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# plt.show()

  plt.subplot(122)
  plt.plot(np.cumprod(pred_pr_list))
  plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
  # plt.axvline(len(org_pr_test), linestyle='--', color='r')
  plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()
# Out:
# test_result.shape : (4915, 2)
# y_test[:5] : [0 0 0 1 0]
# y_score[:5] : [[0.11796856]
#  [0.97380495]
#  [0.01919546]
#  [0.44154748]
#  [0.5382951 ]]
# y_test.shape : (4915, 1)
# y_score.shape : (4915, 1)
# len(y_test) : 4915
# y_pred.shape : (4915,)
# precision : 0.4423076923076923
# recall : 0.31066604564508615
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 6.2339483e-12
# win ratio improvement 0.44 --> 0.44
# accum_pr increased ! : 0.000 --> 0.000
# thresh : 0.65
# acc_pr_bythr : [0.00014826126]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-268f5b199e72> in <module>()
#     125 plt.figure(figsize=(10, 5))
#     126 plt.subplot(121)
# --> 127 plt.plot(threshold, precision, label='precision')
#     128 plt.plot(threshold, recall, label='recall')
#     129 plt.legend()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (4913,)

# %%
plt.figure(figsize=(50, 5))
plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test):len(org_pr_test) + 10])
# plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test) - 10:len(org_pr_test) + 10])
plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
# plt.axvline(len(org_pr_test), linestyle='--', color='r')
plt.show()

# %%
# plt.show()
# plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
