# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-02-11/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-02-11 BTCUSDT.xlsx', '2021-02-11 ETHUSDT.xlsx', '2021-02-11 BCHUSDT.xlsx', '2021-02-11 XRPUSDT.xlsx', '2021-02-11 EOSUSDT.xlsx', '2021-02-11 LTCUSDT.xlsx', '2021-02-11 ETCUSDT.xlsx', '2021-02-11 LINKUSDT.xlsx', '2021-02-11 XLMUSDT.xlsx', '2021-02-11 ADAUSDT.xlsx', '2021-02-11 XMRUSDT.xlsx', '2021-02-11 SXPUSDT.xlsx', '2021-02-11 KAVAUSDT.xlsx', '2021-02-11 BANDUSDT.xlsx', '2021-02-11 DASHUSDT.xlsx', '2021-02-11 ZECUSDT.xlsx', '2021-02-11 XTZUSDT.xlsx', '2021-02-11 BNBUSDT.xlsx', '2021-02-11 ATOMUSDT.xlsx', '2021-02-11 ONTUSDT.xlsx', '2021-02-11 IOTAUSDT.xlsx', '2021-02-11 BATUSDT.xlsx', '2021-02-11 NEOUSDT.xlsx', '2021-02-11 QTUMUSDT.xlsx', '2021-02-11 WAVESUSDT.xlsx', '2021-02-11 MKRUSDT.xlsx', '2021-02-11 SNXUSDT.xlsx', '2021-02-11 DOTUSDT.xlsx', '2021-02-11 THETAUSDT.xlsx', '2021-02-11 ALGOUSDT.xlsx', '2021-02-11 KNCUSDT.xlsx', '2021-02-11 ZRXUSDT.xlsx', '2021-02-11 COMPUSDT.xlsx', '2021-02-11 OMGUSDT.xlsx']

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split

with open('./arima_result/arima_opt_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
  load_dict = pickle.load(f)

candis = list(load_dict.keys())
long_index = 0
leverage = 5
prev_x = None

seed = 1
random_state = 20
np.random.seed(seed)

for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue
  if '2021-03-02 DOTUSDT.xlsx' in candis[i]:
    # print('')
    continue

  if '04-08' not in candis[i]:  # <-- 04-08 includes all timestamp range
    continue

  if 'theta'.upper() not in candis[i]:
    continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      ohlcv = load_dict[key]['ohlcv']
      # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.3)]  # exclude back_range
      # predictions = load_dict[key]['predictions']
      # err_ranges = load_dict[key]['err_ranges']
      print("ohlcv.index[0] :", ohlcv.index[0])
      print("ohlcv.index[-1] :", ohlcv.index[-1])

      predictions = ohlcv['close'].shift(1).values
      err_ranges = np.zeros_like(predictions)

      # leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]

      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      time_index = ohlcv.index[-len(predictions):]
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = np.array(predictions)
      long_ep = long_ep.reshape(-1, 1)

      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 45
      data_x, data_pr, data_updown = [], [], []
      data_index = []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          min_max = MinMaxScaler()
          temp_data[:, :5] = min_max.fit_transform(temp_data[:, :5])


          #   vol -> min_max
          min_max = MinMaxScaler()
          temp_data[:, [5]] = min_max.fit_transform(temp_data[:, [5]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      if prev_x is None:
        prev_x = input_x
        prev_pr = input_pr
        prev_ud = input_ud
      else:
        total_x = np.vstack((prev_x, input_x))
        total_pr = np.vstack((prev_pr, input_pr))
        total_ud = np.vstack((prev_ud, input_ud))

        prev_x = total_x
        prev_pr = total_pr
        prev_ud = total_ud

        print('total_x.shape :', total_x.shape)
        print('total_pr.shape :', total_pr.shape)
        print('total_ud.shape :', total_ud.shape)

      # if prev_train_x is None:
      #   prev_train_x = x_train
      #   prev_val_x = x_val
      #   prev_test_x = x_test
        
      #   prev_train_pr = pr_train
      #   prev_val_pr = pr_val
      #   prev_test_pr = pr_test

      #   prev_train_ud = ud_train
      #   prev_val_ud = ud_val
      #   prev_test_ud = ud_test

      # else:

      #   total_train_x = np.vstack((prev_train_x, x_train))
      #   total_val_x = np.vstack((prev_val_x, x_val))
      #   total_test_x = np.vstack((prev_test_x, x_test))
      #   total_train_pr = np.vstack((prev_train_pr, pr_train))
      #   total_val_pr = np.vstack((prev_val_pr, pr_val))
      #   total_test_pr = np.vstack((prev_test_pr, pr_test))
      #   total_train_ud = np.vstack((prev_train_ud, ud_train))
      #   total_val_ud = np.vstack((prev_val_ud, ud_val))
      #   total_test_ud = np.vstack((prev_test_ud, ud_test))
        
      #   prev_train_x = total_train_x
      #   prev_val_x = total_val_x
      #   prev_test_x = total_test_x
        
      #   prev_train_pr = total_train_pr
      #   prev_val_pr = total_val_pr
      #   prev_test_pr = total_test_pr

      #   prev_train_ud = total_train_ud
      #   prev_val_ud = total_val_ud
      #   prev_test_ud = total_test_ud
        
      #   print("total_train_x.shape :", total_train_x.shape)
      #   print("total_val_x.shape :", total_val_x.shape)
      #   print("total_test_x.shape :", total_test_x.shape)
      #   print("total_train_pr.shape :", total_train_pr.shape)
      #   print("total_val_pr.shape :", total_val_pr.shape)
      #   print("total_test_pr.shape :", total_test_pr.shape)
      #   print("total_train_ud.shape :", total_train_ud.shape)
      #   print("total_val_ud.shape :", total_val_ud.shape)
      #   print("total_test_ud.shape :", total_test_ud.shape)

  break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  # try:
  #   if len(total_x) > 300000:
  #     break
  # except:
  #   pass
# Out:
# ohlcv.index[0] : 2020-05-27 17:29:59.999000
# ohlcv.index[-1] : 2021-04-08 20:29:59.999000
# -------------- 2021-04-08 THETAUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 15175
# long_ep.shape : (15175, 1)
# len(pr_list) : 15175
# np.array(data_x).shape : (14504, 45, 6)
# input_x.shape : (14504, 90, 12, 3)
# input_x.dtype : float32
# input_pr.shape : (14504, 1)
# input_ud.shape : (14504, 1)
# input_index.shape : (14504, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:201: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
period = 45
# x_save_path = current_path + 'npy/' + '%s_close_updown_x.npy' % period
# y_save_path = current_path + 'npy/' + '%s_close_updown_y.npy' % period
#         save to npy     #
# x_save_path = current_path + 'npy/' + '%s_close_updown_theta_x_ex.npy' % period
# y_save_path = current_path + 'npy/' + '%s_close_updown_theta_y_ex.npy' % period

# total_x = np.load(x_save_path)
# total_pr = np.load(y_save_path)

# _, row, col, _ = total_x.shape

_, row, col, _ = input_x.shape

#       split new test      #

seed = 1
random_state = 20
np.random.seed(seed)
from sklearn.model_selection import train_test_split
#         train / test split      #
# x_train, x_test_, pr_train, pr_test_, ud_train, ud_test_ = train_test_split(re_input_x, input_pr, input_ud, test_size=0.4, shuffle=True, random_state=random_state)
# x_train_, x_test, pr_train_, pr_test = train_test_split(total_x, total_pr, test_size=0.2, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val = train_test_split(x_train_, pr_train_, test_size=0.25, shuffle=True, random_state=random_state)
# break
print("input_x.shape : ", input_x.shape)

a_input_x, new_input_x, a_input_pr, new_input_pr, a_input_index, new_input_index = train_test_split(input_x, input_pr, input_index, test_size=0.3, shuffle=False, random_state=random_state)

print("a_input_x.shape : ", a_input_x.shape)      

even_input_x = a_input_x[::2]
x_test = a_input_x[1::2]
even_input_pr = a_input_pr[::2]
pr_test = a_input_pr[1::2]
even_input_index = a_input_index[::2]
index_test = a_input_index[1::2]

# x_train_, x_test, pr_train_, pr_test, index_train_, index_test = train_test_split(a_input_x, a_input_pr, a_input_index, test_size=0.4, shuffle=False, random_state=random_state)

# print("x_train_.shape :", x_train_.shape) # with a_input_x -> 4263 / with input_x -> 4219

#           extract prev data           #
#           test data 의 짝수차 데이터를 train set 에 넘기고, train & val split 을 shuffle 로 진행한다
# print('org x_test.shape :', x_test.shape)
# x_test4train, pr_test4train, index_test4train =  x_test[::2], pr_test[::2], index_test[::2]
# x_test, pr_test, index_test =  x_test[1::2], pr_test[1::2], index_test[1::2]
# print('divided x_test.shape :', x_test.shape)
# print()


#          add test4train data to training set      #
# x_train_ = np.vstack((x_train_, x_test4train))
# pr_train_ = np.vstack((pr_train_, pr_test4train))
# index_train_ = np.vstack((index_train_, index_test4train))

# print("x_test4train.shape :", x_test4train.shape) 
# print("added x_train_.shape :", x_train_.shape) # with a_input_x -> 4263 / with input_x -> 4219


# x_train_, x_test, pr_train_, pr_test = train_test_split(input_x, input_pr, test_size=0.4, shuffle=True, random_state=random_state)
x_train, x_val, pr_train, pr_val, index_train, index_val = train_test_split(even_input_x, even_input_pr, even_input_index, test_size=0.25, shuffle=True, random_state=random_state)
# x_train, x_val, pr_train, pr_val, index_train, index_val = train_test_split(x_train_, pr_train_, index_train_, test_size=0.3, shuffle=True, random_state=random_state)

#         pr label   #
y_train = np.where(pr_train > 1, 1, 0)
y_test = np.where(pr_test > 1, 1, 0)
y_val = np.where(pr_val > 1, 1, 0)

print("x_train.shape :", x_train.shape) # with a_input_x -> 4263 / with input_x -> 4219

# del total_x
# Out:
# input_x.shape :  (14504, 90, 12, 3)
# a_input_x.shape :  (10152, 90, 12, 3)
# x_train.shape : (3807, 90, 12, 3)

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)

# %% [markdown]
# ### Load Data

# %%
# period = 45
# # x_save_path = current_path + 'npy/' + '%s_close_updown_x.npy' % period
# # y_save_path = current_path + 'npy/' + '%s_close_updown_y.npy' % period
# #         save to npy     #
# x_save_path = current_path + 'npy/' + '%s_close_updown_theta_x_ex.npy' % period
# y_save_path = current_path + 'npy/' + '%s_close_updown_theta_y_ex.npy' % period

# total_x = np.load(x_save_path)
# total_pr = np.load(y_save_path)

# _, row, col, _ = total_x.shape



# seed = 1
# random_state = 20
# np.random.seed(seed)
# from sklearn.model_selection import train_test_split
# #         train / test split      #
# # x_train, x_test_, pr_train, pr_test_, ud_train, ud_test_ = train_test_split(re_total_x, total_pr, total_ud, test_size=0.4, shuffle=True, random_state=random_state)
# x_train_, x_test, pr_train_, pr_test = train_test_split(total_x, total_pr, test_size=0.2, shuffle=False, random_state=random_state)
# x_train, x_val, pr_train, pr_val = train_test_split(x_train_, pr_train_, test_size=0.25, shuffle=False, random_state=random_state)
# # break
# #         pr label   #
# y_train = np.where(pr_train > 1, 1, 0)
# y_test = np.where(pr_test > 1, 1, 0)
# y_val = np.where(pr_val > 1, 1, 0)

# del total_x

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape=(row, col, 3)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight
# import cv2


_, row, col, _ = x_train.shape

#         pr label   #
# y_train = np.where(pr_train > 1, 1, 0)
# y_test = np.where(pr_test > 1, 1, 0)
# y_val = np.where(pr_val > 1, 1, 0)


seed = 1
random_state = 20
np.random.seed(seed)
# tf.random.set_seed(seed)

#         up label      #
# y_train = np.where(ud_train > 1, 1, 0)
# y_test = np.where(ud_test > 1, 1, 0)
# y_val = np.where(ud_val > 1, 1, 0)

print('pr_train[:5] :', pr_train[:5])
# print('ud_train[:5] :', ud_train[:5])
print('y_train[:5] :', y_train[:5])
print('y_train.dtype :', y_train.dtype)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

def class_ratio(in_list):

  return in_list / in_list[1]

print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)

datagen = ImageDataGenerator( 
    rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)

batch_size = 16

for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break
# Out:
# pr_train[:5] : [[0.9831578]
#  [1.0202861]
#  [1.0138757]
#  [0.9751041]
#  [1.004269 ]]
# y_train[:5] : [[0]
#  [1]
#  [1]
#  [0]
#  [1]]
# y_train.dtype : int64
# x_train.shape : (3807, 90, 12, 3)
# x_test.shape : (5076, 90, 12, 3)
# x_val.shape : (1269, 90, 12, 3)
# y_train.shape : (3807, 1)
# y_test.shape : (5076, 1)
# y_val.shape : (1269, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([2140, 1667])) [1.28374325 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([725, 544])) [1.33272059 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([2779, 2297])) [1.20983892 1.        ]
# class_weights : {0: 0.8894859813084112, 1: 1.141871625674865}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (3807, 2)
# y_val_ohe.shape : (1269, 2)
# y_test_ohe.shape : (5076, 2)

# %% [markdown]
# ### **Training**

# %%
(_, row, col, _) = x_train.shape
  
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
# model_name = 'classifier_%s_close_updown_pr_theta_shuffle_without_back_03.h5' % period
# model_name = 'classifier_%s_close_updown_pr_theta_train_prevdata_005.h5' % period

model_name = 'classifier_%s_close_updown_pr_theta_train_evendata_004.h5' % period
# model_name = 'classifier_%s_close_updown_pr_theta_train_evendata_012.h5' % period
model = keras.models.load_model(ckpt_path + model_name)


# model = FER_Model(input_shape=(row, col, 3))
# opt = Adam(lr=0.00001, decay=0.000005)
# model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model_name = 'classifier_%s_close_updown_pr_theta_train_evendata.h5' % period


checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=40)
# callbacks_list = [checkpoint, checkpoint2, checkpoint3]
callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)
# Out:
# Epoch 1/1000
#  - 5s - loss: 0.2295 - accuracy: 0.9152 - val_loss: 0.0203 - val_accuracy: 0.5201
#
# Epoch 00001: val_loss improved from inf to 0.02027, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_train_evendata.h5
# Epoch 2/1000
#  - 5s - loss: 0.2451 - accuracy: 0.9044 - val_loss: 0.9011 - val_accuracy: 0.5201
#
# Epoch 00002: val_loss did not improve from 0.02027
# Epoch 3/1000
#  - 5s - loss: 0.2413 - accuracy: 0.9023 - val_loss: 0.1313 - val_accuracy: 0.5240
#
# Epoch 00003: val_loss did not improve from 0.02027
# Epoch 4/1000
#  - 5s - loss: 0.2373 - accuracy: 0.9033 - val_loss: 0.2304 - val_accuracy: 0.5343
#
# Epoch 00004: val_loss did not improve from 0.02027
# Epoch 5/1000
#  - 5s - loss: 0.2366 - accuracy: 0.9031 - val_loss: 1.5631 - val_accuracy: 0.5146
#
# Epoch 00005: val_loss did not improve from 0.02027
# Epoch 6/1000
#  - 5s - loss: 0.2431 - accuracy: 0.9025 - val_loss: 0.5791 - val_accuracy: 0.5256
#
# Epoch 00006: val_loss did not improve from 0.02027
# Epoch 7/1000
#  - 5s - loss: 0.2359 - accuracy: 0.9057 - val_loss: 1.0665 - val_accuracy: 0.5240
#
# Epoch 00007: val_loss did not improve from 0.02027
# Epoch 8/1000
#  - 5s - loss: 0.2322 - accuracy: 0.9091 - val_loss: 2.8991 - val_accuracy: 0.5382
#
# Epoch 00008: val_loss did not improve from 0.02027
# Epoch 9/1000
#  - 5s - loss: 0.2360 - accuracy: 0.9062 - val_loss: 1.6231 - val_accuracy: 0.5366
#
# Epoch 00009: val_loss did not improve from 0.02027
# Epoch 10/1000
#  - 5s - loss: 0.2287 - accuracy: 0.9149 - val_loss: 0.5332 - val_accuracy: 0.5225
#
# Epoch 00010: val_loss did not improve from 0.02027
# Epoch 11/1000
#  - 5s - loss: 0.2235 - accuracy: 0.9117 - val_loss: 1.0565 - val_accuracy: 0.5051
#
# Epoch 00011: val_loss did not improve from 0.02027
# Epoch 12/1000
#  - 5s - loss: 0.2232 - accuracy: 0.9154 - val_loss: 2.2056 - val_accuracy: 0.5343
#
# Epoch 00012: val_loss did not improve from 0.02027
# Epoch 13/1000
#  - 5s - loss: 0.2327 - accuracy: 0.9041 - val_loss: 3.0730 - val_accuracy: 0.5382
#
# Epoch 00013: val_loss did not improve from 0.02027
# Epoch 14/1000
#  - 5s - loss: 0.2249 - accuracy: 0.9125 - val_loss: 1.4524 - val_accuracy: 0.5414
#
# Epoch 00014: val_loss did not improve from 0.02027
# Epoch 15/1000
#  - 5s - loss: 0.2234 - accuracy: 0.9089 - val_loss: 1.4021 - val_accuracy: 0.5280
#
# Epoch 00015: val_loss did not improve from 0.02027
# Epoch 16/1000
#  - 5s - loss: 0.2182 - accuracy: 0.9183 - val_loss: 1.4989 - val_accuracy: 0.5067
#
# Epoch 00016: val_loss did not improve from 0.02027
# Epoch 17/1000
#  - 5s - loss: 0.2280 - accuracy: 0.9054 - val_loss: 2.6013 - val_accuracy: 0.5296
#
# Epoch 00017: val_loss did not improve from 0.02027
# Epoch 18/1000
#  - 5s - loss: 0.2275 - accuracy: 0.9075 - val_loss: 2.5990 - val_accuracy: 0.5162
#
# Epoch 00018: val_loss did not improve from 0.02027
# Epoch 19/1000
#  - 5s - loss: 0.2286 - accuracy: 0.9099 - val_loss: 1.6316 - val_accuracy: 0.5130
#
# Epoch 00019: val_loss did not improve from 0.02027
# Epoch 20/1000
#  - 5s - loss: 0.2082 - accuracy: 0.9222 - val_loss: 1.0249 - val_accuracy: 0.5169
#
# Epoch 00020: val_loss did not improve from 0.02027
# Epoch 21/1000
#  - 5s - loss: 0.2137 - accuracy: 0.9201 - val_loss: 1.0869 - val_accuracy: 0.5217
#
# Epoch 00021: val_loss did not improve from 0.02027
# Epoch 22/1000
#  - 5s - loss: 0.2201 - accuracy: 0.9170 - val_loss: 1.6089 - val_accuracy: 0.5075
#
# Epoch 00022: val_loss did not improve from 0.02027
# Epoch 23/1000
#  - 5s - loss: 0.2077 - accuracy: 0.9180 - val_loss: 1.6228 - val_accuracy: 0.5130
#
# Epoch 00023: val_loss did not improve from 0.02027
# Epoch 24/1000
#  - 5s - loss: 0.2151 - accuracy: 0.9128 - val_loss: 1.8779 - val_accuracy: 0.5146
#
# Epoch 00024: val_loss did not improve from 0.02027
# Epoch 25/1000
#  - 5s - loss: 0.2091 - accuracy: 0.9191 - val_loss: 0.2648 - val_accuracy: 0.5193
#
# Epoch 00025: val_loss did not improve from 0.02027
# Epoch 26/1000
#  - 5s - loss: 0.2096 - accuracy: 0.9162 - val_loss: 1.8141 - val_accuracy: 0.5043
#
# Epoch 00026: val_loss did not improve from 0.02027
# Epoch 27/1000
#  - 5s - loss: 0.2194 - accuracy: 0.9159 - val_loss: 1.0979 - val_accuracy: 0.5043
#
# Epoch 00027: val_loss did not improve from 0.02027
# Epoch 28/1000
#  - 5s - loss: 0.2202 - accuracy: 0.9117 - val_loss: 4.4244 - val_accuracy: 0.5075
#
# Epoch 00028: val_loss did not improve from 0.02027
# Epoch 29/1000
#  - 5s - loss: 0.1937 - accuracy: 0.9236 - val_loss: 2.4361 - val_accuracy: 0.5209
#
# Epoch 00029: val_loss did not improve from 0.02027
# Epoch 30/1000
#  - 5s - loss: 0.2030 - accuracy: 0.9225 - val_loss: 1.0367 - val_accuracy: 0.5177
#
# Epoch 00030: val_loss did not improve from 0.02027
# Epoch 31/1000
#  - 5s - loss: 0.2031 - accuracy: 0.9199 - val_loss: 0.8283 - val_accuracy: 0.5225
#
# Epoch 00031: val_loss did not improve from 0.02027
# Epoch 32/1000
#  - 5s - loss: 0.2047 - accuracy: 0.9152 - val_loss: 0.4086 - val_accuracy: 0.5185
#
# Epoch 00032: val_loss did not improve from 0.02027
# Epoch 33/1000
#  - 5s - loss: 0.1960 - accuracy: 0.9241 - val_loss: 0.9446 - val_accuracy: 0.5154
#
# Epoch 00033: val_loss did not improve from 0.02027
# Epoch 34/1000
#  - 5s - loss: 0.1985 - accuracy: 0.9262 - val_loss: 4.5032 - val_accuracy: 0.5264
#
# Epoch 00034: val_loss did not improve from 0.02027
# Epoch 35/1000
#  - 5s - loss: 0.2040 - accuracy: 0.9191 - val_loss: 2.0223 - val_accuracy: 0.5303
#
# Epoch 00035: val_loss did not improve from 0.02027
# Epoch 36/1000
#  - 5s - loss: 0.1891 - accuracy: 0.9309 - val_loss: 1.7582 - val_accuracy: 0.5248
#
# Epoch 00036: val_loss did not improve from 0.02027
# Epoch 37/1000
#  - 5s - loss: 0.1965 - accuracy: 0.9215 - val_loss: 3.8993 - val_accuracy: 0.5248
#
# Epoch 00037: val_loss did not improve from 0.02027
# Epoch 38/1000
#  - 5s - loss: 0.1902 - accuracy: 0.9270 - val_loss: 1.6747 - val_accuracy: 0.5177
#
# Epoch 00038: val_loss did not improve from 0.02027
# Epoch 39/1000
#  - 5s - loss: 0.1958 - accuracy: 0.9243 - val_loss: 0.2313 - val_accuracy: 0.5177
#
# Epoch 00039: val_loss did not improve from 0.02027
# Epoch 40/1000
#  - 5s - loss: 0.1992 - accuracy: 0.9222 - val_loss: 0.6430 - val_accuracy: 0.5296
#
# Epoch 00040: val_loss did not improve from 0.02027
# Epoch 41/1000
#  - 5s - loss: 0.1947 - accuracy: 0.9238 - val_loss: 1.7308 - val_accuracy: 0.5359
#
# Epoch 00041: val_loss did not improve from 0.02027
# Epoch 42/1000
#  - 5s - loss: 0.1816 - accuracy: 0.9328 - val_loss: 1.4876 - val_accuracy: 0.5343
#
# Epoch 00042: val_loss did not improve from 0.02027
# Epoch 43/1000
#  - 5s - loss: 0.2099 - accuracy: 0.9173 - val_loss: 4.2181 - val_accuracy: 0.5335
#
# Epoch 00043: val_loss did not improve from 0.02027
# Epoch 44/1000
#  - 5s - loss: 0.1887 - accuracy: 0.9291 - val_loss: 1.2409 - val_accuracy: 0.5319
#
# Epoch 00044: val_loss did not improve from 0.02027
# Epoch 45/1000
#  - 5s - loss: 0.1837 - accuracy: 0.9288 - val_loss: 3.1437 - val_accuracy: 0.5303
#
# Epoch 00045: val_loss did not improve from 0.02027
# Epoch 46/1000
#  - 5s - loss: 0.1880 - accuracy: 0.9325 - val_loss: 0.9340 - val_accuracy: 0.5185
#
# Epoch 00046: val_loss did not improve from 0.02027
# Epoch 47/1000
#  - 5s - loss: 0.1902 - accuracy: 0.9286 - val_loss: 4.7977 - val_accuracy: 0.5272
#
# Epoch 00047: val_loss did not improve from 0.02027
# Epoch 48/1000
#  - 5s - loss: 0.1711 - accuracy: 0.9383 - val_loss: 1.9965 - val_accuracy: 0.5146
#
# Epoch 00048: val_loss did not improve from 0.02027
# Epoch 49/1000
#  - 5s - loss: 0.1801 - accuracy: 0.9354 - val_loss: 0.4097 - val_accuracy: 0.5209
#
# Epoch 00049: val_loss did not improve from 0.02027
# Epoch 50/1000
#  - 5s - loss: 0.1770 - accuracy: 0.9307 - val_loss: 2.5597 - val_accuracy: 0.5240
#
# Epoch 00050: val_loss did not improve from 0.02027
# Epoch 51/1000
#  - 5s - loss: 0.1767 - accuracy: 0.9338 - val_loss: 1.9266 - val_accuracy: 0.5217
#
# Epoch 00051: val_loss did not improve from 0.02027
# Epoch 52/1000
#  - 5s - loss: 0.1766 - accuracy: 0.9401 - val_loss: 1.1652 - val_accuracy: 0.5296
#
# Epoch 00052: val_loss did not improve from 0.02027
# Epoch 53/1000
#  - 5s - loss: 0.1749 - accuracy: 0.9351 - val_loss: 0.8392 - val_accuracy: 0.5114
#
# Epoch 00053: val_loss did not improve from 0.02027
# Epoch 54/1000
#  - 5s - loss: 0.1749 - accuracy: 0.9349 - val_loss: 0.2481 - val_accuracy: 0.5154
#
# Epoch 00054: val_loss did not improve from 0.02027
# Epoch 55/1000
#  - 5s - loss: 0.1776 - accuracy: 0.9377 - val_loss: 1.7439 - val_accuracy: 0.5146
#
# Epoch 00055: val_loss did not improve from 0.02027
# Epoch 56/1000
#  - 5s - loss: 0.1876 - accuracy: 0.9270 - val_loss: 2.2921 - val_accuracy: 0.5225
#
# Epoch 00056: val_loss did not improve from 0.02027
# Epoch 57/1000
#  - 5s - loss: 0.1706 - accuracy: 0.9383 - val_loss: 1.6203 - val_accuracy: 0.5232
#
# Epoch 00057: val_loss did not improve from 0.02027
# Epoch 58/1000
#  - 5s - loss: 0.1703 - accuracy: 0.9398 - val_loss: 2.5035 - val_accuracy: 0.5146
#
# Epoch 00058: val_loss did not improve from 0.02027
# Epoch 59/1000
#  - 5s - loss: 0.1701 - accuracy: 0.9349 - val_loss: 2.0278 - val_accuracy: 0.5004
#
# Epoch 00059: val_loss did not improve from 0.02027
# Epoch 60/1000
#  - 5s - loss: 0.1722 - accuracy: 0.9372 - val_loss: 0.2780 - val_accuracy: 0.5122
#
# Epoch 00060: val_loss did not improve from 0.02027
# Epoch 61/1000
#  - 5s - loss: 0.1738 - accuracy: 0.9351 - val_loss: 0.1972 - val_accuracy: 0.5185
#
# Epoch 00061: val_loss did not improve from 0.02027
# Epoch 62/1000
#  - 5s - loss: 0.1808 - accuracy: 0.9330 - val_loss: 4.3569 - val_accuracy: 0.5311
#
# Epoch 00062: val_loss did not improve from 0.02027
# Epoch 63/1000
#  - 5s - loss: 0.1691 - accuracy: 0.9409 - val_loss: 1.4531 - val_accuracy: 0.5154
#
# Epoch 00063: val_loss did not improve from 0.02027
# Epoch 64/1000
#  - 5s - loss: 0.1663 - accuracy: 0.9375 - val_loss: 0.4288 - val_accuracy: 0.5225
#
# Epoch 00064: val_loss did not improve from 0.02027
# Epoch 65/1000
#  - 5s - loss: 0.1676 - accuracy: 0.9346 - val_loss: 1.2494 - val_accuracy: 0.5051
#
# Epoch 00065: val_loss did not improve from 0.02027
# Epoch 66/1000
#  - 5s - loss: 0.1702 - accuracy: 0.9359 - val_loss: 1.8535 - val_accuracy: 0.5130
#
# Epoch 00066: val_loss did not improve from 0.02027
# Epoch 67/1000
#  - 5s - loss: 0.1651 - accuracy: 0.9391 - val_loss: 4.3664 - val_accuracy: 0.5303
#
# Epoch 00067: val_loss did not improve from 0.02027
# Epoch 68/1000
#  - 5s - loss: 0.1656 - accuracy: 0.9377 - val_loss: 2.5498 - val_accuracy: 0.5130
#
# Epoch 00068: val_loss did not improve from 0.02027
# Epoch 69/1000
#  - 5s - loss: 0.1602 - accuracy: 0.9448 - val_loss: 1.3404 - val_accuracy: 0.5122
#
# Epoch 00069: val_loss did not improve from 0.02027
# Epoch 70/1000
#  - 5s - loss: 0.1598 - accuracy: 0.9427 - val_loss: 0.1583 - val_accuracy: 0.5296
#
# Epoch 00070: val_loss did not improve from 0.02027
# Epoch 71/1000
#  - 5s - loss: 0.1522 - accuracy: 0.9443 - val_loss: 2.1767 - val_accuracy: 0.5138
#
# Epoch 00071: val_loss did not improve from 0.02027
# Epoch 72/1000
#  - 5s - loss: 0.1661 - accuracy: 0.9364 - val_loss: 2.4829 - val_accuracy: 0.5296
#
# Epoch 00072: val_loss did not improve from 0.02027
# Epoch 73/1000
#  - 5s - loss: 0.1705 - accuracy: 0.9385 - val_loss: 0.2143 - val_accuracy: 0.5225
#
# Epoch 00073: val_loss did not improve from 0.02027
# Epoch 74/1000
#  - 5s - loss: 0.1474 - accuracy: 0.9456 - val_loss: 1.1236 - val_accuracy: 0.5201
#
# Epoch 00074: val_loss did not improve from 0.02027
# Epoch 75/1000
#  - 5s - loss: 0.1533 - accuracy: 0.9469 - val_loss: 0.4577 - val_accuracy: 0.5201
#
# Epoch 00075: val_loss did not improve from 0.02027
# Epoch 76/1000
#  - 5s - loss: 0.1552 - accuracy: 0.9422 - val_loss: 1.9036 - val_accuracy: 0.5185
#
# Epoch 00076: val_loss did not improve from 0.02027
# Epoch 77/1000
#  - 5s - loss: 0.1501 - accuracy: 0.9469 - val_loss: 2.0600 - val_accuracy: 0.5177
#
# Epoch 00077: val_loss did not improve from 0.02027
# Epoch 78/1000
#  - 5s - loss: 0.1461 - accuracy: 0.9488 - val_loss: 3.7488 - val_accuracy: 0.5217
#
# Epoch 00078: val_loss did not improve from 0.02027
# Epoch 79/1000
#  - 5s - loss: 0.1694 - accuracy: 0.9372 - val_loss: 2.0815 - val_accuracy: 0.5311
#
# Epoch 00079: val_loss did not improve from 0.02027
# Epoch 80/1000
#  - 5s - loss: 0.1536 - accuracy: 0.9441 - val_loss: 2.6767 - val_accuracy: 0.5028
#
# Epoch 00080: val_loss did not improve from 0.02027
# Epoch 81/1000
#  - 5s - loss: 0.1565 - accuracy: 0.9417 - val_loss: 0.4592 - val_accuracy: 0.5091
#
# Epoch 00081: val_loss did not improve from 0.02027
# Epoch 82/1000
#  - 5s - loss: 0.1542 - accuracy: 0.9425 - val_loss: 2.1468 - val_accuracy: 0.5272
#
# Epoch 00082: val_loss did not improve from 0.02027
# Epoch 83/1000
#  - 5s - loss: 0.1403 - accuracy: 0.9514 - val_loss: 3.5208 - val_accuracy: 0.5264
#
# Epoch 00083: val_loss did not improve from 0.02027
# Epoch 84/1000
#  - 5s - loss: 0.1488 - accuracy: 0.9459 - val_loss: 1.9275 - val_accuracy: 0.5240
#
# Epoch 00084: val_loss did not improve from 0.02027
# Epoch 85/1000
#  - 5s - loss: 0.1524 - accuracy: 0.9451 - val_loss: 0.1750 - val_accuracy: 0.5043
#
# Epoch 00085: val_loss did not improve from 0.02027
# Epoch 86/1000
#  - 5s - loss: 0.1404 - accuracy: 0.9490 - val_loss: 0.6969 - val_accuracy: 0.5303
#
# Epoch 00086: val_loss did not improve from 0.02027
# Epoch 87/1000
#  - 5s - loss: 0.1403 - accuracy: 0.9525 - val_loss: 0.9418 - val_accuracy: 0.5201
#
# Epoch 00087: val_loss did not improve from 0.02027
# Epoch 88/1000
#  - 5s - loss: 0.1508 - accuracy: 0.9451 - val_loss: 2.9106 - val_accuracy: 0.5201
#
# Epoch 00088: val_loss did not improve from 0.02027
# Epoch 89/1000
#  - 5s - loss: 0.1474 - accuracy: 0.9446 - val_loss: 2.2309 - val_accuracy: 0.5382
#
# Epoch 00089: val_loss did not improve from 0.02027
# Epoch 90/1000
#  - 5s - loss: 0.1455 - accuracy: 0.9527 - val_loss: 0.3676 - val_accuracy: 0.5075
#
# Epoch 00090: val_loss did not improve from 0.02027
# Epoch 91/1000
#  - 5s - loss: 0.1399 - accuracy: 0.9548 - val_loss: 3.4563 - val_accuracy: 0.5232
#
# Epoch 00091: val_loss did not improve from 0.02027
# Epoch 92/1000
#  - 5s - loss: 0.1352 - accuracy: 0.9496 - val_loss: 1.7444 - val_accuracy: 0.5272
#
# Epoch 00092: val_loss did not improve from 0.02027
# Epoch 93/1000
#  - 5s - loss: 0.1311 - accuracy: 0.9556 - val_loss: 2.3354 - val_accuracy: 0.5374
#
# Epoch 00093: val_loss did not improve from 0.02027
# Epoch 94/1000
#  - 5s - loss: 0.1372 - accuracy: 0.9514 - val_loss: 1.5397 - val_accuracy: 0.5232
#
# Epoch 00094: val_loss did not improve from 0.02027
# Epoch 95/1000
#  - 5s - loss: 0.1379 - accuracy: 0.9490 - val_loss: 1.8515 - val_accuracy: 0.5130
#
# Epoch 00095: val_loss did not improve from 0.02027
# Epoch 96/1000
#  - 5s - loss: 0.1414 - accuracy: 0.9454 - val_loss: 1.8410 - val_accuracy: 0.5028
#
# Epoch 00096: val_loss did not improve from 0.02027
# Epoch 97/1000
#  - 5s - loss: 0.1342 - accuracy: 0.9535 - val_loss: 2.0169 - val_accuracy: 0.5075
#
# Epoch 00097: val_loss did not improve from 0.02027
# Epoch 98/1000
#  - 5s - loss: 0.1359 - accuracy: 0.9493 - val_loss: 1.1587 - val_accuracy: 0.5311
#
# Epoch 00098: val_loss did not improve from 0.02027
# Epoch 99/1000
#  - 5s - loss: 0.1366 - accuracy: 0.9511 - val_loss: 2.1322 - val_accuracy: 0.5185
#
# Epoch 00099: val_loss did not improve from 0.02027
# Epoch 100/1000
#  - 5s - loss: 0.1379 - accuracy: 0.9543 - val_loss: 1.8643 - val_accuracy: 0.5083
#
# Epoch 00100: val_loss did not improve from 0.02027
# Epoch 101/1000
#  - 5s - loss: 0.1244 - accuracy: 0.9574 - val_loss: 5.0129 - val_accuracy: 0.5209
#
# Epoch 00101: val_loss did not improve from 0.02027
# Epoch 102/1000
#  - 5s - loss: 0.1352 - accuracy: 0.9561 - val_loss: 1.4117 - val_accuracy: 0.5225
#
# Epoch 00102: val_loss did not improve from 0.02027
# Epoch 103/1000
#  - 5s - loss: 0.1344 - accuracy: 0.9538 - val_loss: 2.2514 - val_accuracy: 0.5099
#
# Epoch 00103: val_loss did not improve from 0.02027
# Epoch 104/1000
#  - 5s - loss: 0.1304 - accuracy: 0.9501 - val_loss: 1.6058 - val_accuracy: 0.5162
#
# Epoch 00104: val_loss did not improve from 0.02027
# Epoch 105/1000
#  - 5s - loss: 0.1271 - accuracy: 0.9556 - val_loss: 2.4257 - val_accuracy: 0.5248
#
# Epoch 00105: val_loss did not improve from 0.02027
# Epoch 106/1000
#  - 5s - loss: 0.1283 - accuracy: 0.9590 - val_loss: 3.0911 - val_accuracy: 0.5288
#
# Epoch 00106: val_loss did not improve from 0.02027
# Epoch 107/1000
#  - 5s - loss: 0.1345 - accuracy: 0.9485 - val_loss: 0.4478 - val_accuracy: 0.5177
#
# Epoch 00107: val_loss did not improve from 0.02027
# Epoch 108/1000
#  - 5s - loss: 0.1236 - accuracy: 0.9577 - val_loss: 2.6396 - val_accuracy: 0.5303
#
# Epoch 00108: val_loss did not improve from 0.02027
# Epoch 109/1000
#  - 5s - loss: 0.1283 - accuracy: 0.9540 - val_loss: 2.1309 - val_accuracy: 0.5169
#
# Epoch 00109: val_loss did not improve from 0.02027
# Epoch 110/1000
#  - 5s - loss: 0.1351 - accuracy: 0.9551 - val_loss: 0.6678 - val_accuracy: 0.5240
#
# Epoch 00110: val_loss did not improve from 0.02027
# Epoch 111/1000
#  - 5s - loss: 0.1274 - accuracy: 0.9556 - val_loss: 2.7375 - val_accuracy: 0.5264
#
# Epoch 00111: val_loss did not improve from 0.02027
# Epoch 112/1000
#  - 5s - loss: 0.1229 - accuracy: 0.9561 - val_loss: 0.7276 - val_accuracy: 0.5272
#
# Epoch 00112: val_loss did not improve from 0.02027
# Epoch 113/1000
#  - 5s - loss: 0.1302 - accuracy: 0.9546 - val_loss: 3.7006 - val_accuracy: 0.5256
#
# Epoch 00113: val_loss did not improve from 0.02027
# Epoch 114/1000
#  - 5s - loss: 0.1300 - accuracy: 0.9522 - val_loss: 1.7391 - val_accuracy: 0.5335
#
# Epoch 00114: val_loss did not improve from 0.02027
# Epoch 115/1000
#  - 5s - loss: 0.1230 - accuracy: 0.9564 - val_loss: 1.7796 - val_accuracy: 0.5091
#
# Epoch 00115: val_loss did not improve from 0.02027
# Epoch 116/1000
#  - 5s - loss: 0.1203 - accuracy: 0.9574 - val_loss: 3.5808 - val_accuracy: 0.5138
#
# Epoch 00116: val_loss did not improve from 0.02027
# Epoch 117/1000
#  - 5s - loss: 0.1213 - accuracy: 0.9595 - val_loss: 6.1395 - val_accuracy: 0.5351
#
# Epoch 00117: val_loss did not improve from 0.02027
# Epoch 118/1000
#  - 5s - loss: 0.1225 - accuracy: 0.9556 - val_loss: 3.3490 - val_accuracy: 0.5296
#
# Epoch 00118: val_loss did not improve from 0.02027
# Epoch 119/1000
#  - 5s - loss: 0.1188 - accuracy: 0.9564 - val_loss: 0.1628 - val_accuracy: 0.5169
#
# Epoch 00119: val_loss did not improve from 0.02027
# Epoch 120/1000
#  - 5s - loss: 0.1078 - accuracy: 0.9669 - val_loss: 0.1955 - val_accuracy: 0.5374
#
# Epoch 00120: val_loss did not improve from 0.02027
# Epoch 121/1000
#  - 5s - loss: 0.1130 - accuracy: 0.9603 - val_loss: 3.2139 - val_accuracy: 0.5106
#
# Epoch 00121: val_loss did not improve from 0.02027
# Epoch 122/1000
#  - 5s - loss: 0.1187 - accuracy: 0.9574 - val_loss: 1.3773 - val_accuracy: 0.5280
#
# Epoch 00122: val_loss did not improve from 0.02027
# Epoch 123/1000
#  - 5s - loss: 0.1191 - accuracy: 0.9577 - val_loss: 2.2352 - val_accuracy: 0.5232
#
# Epoch 00123: val_loss did not improve from 0.02027
# Epoch 124/1000
#  - 5s - loss: 0.1136 - accuracy: 0.9611 - val_loss: 0.6697 - val_accuracy: 0.5169
#
# Epoch 00124: val_loss did not improve from 0.02027
# Epoch 125/1000
#  - 5s - loss: 0.1093 - accuracy: 0.9611 - val_loss: 0.2451 - val_accuracy: 0.5177
#
# Epoch 00125: val_loss did not improve from 0.02027
# Epoch 126/1000
#  - 5s - loss: 0.1128 - accuracy: 0.9609 - val_loss: 0.6445 - val_accuracy: 0.5169
#
# Epoch 00126: val_loss did not improve from 0.02027
# Epoch 127/1000
#  - 5s - loss: 0.1134 - accuracy: 0.9590 - val_loss: 3.9088 - val_accuracy: 0.5177
#
# Epoch 00127: val_loss did not improve from 0.02027
# Epoch 128/1000
#  - 5s - loss: 0.1157 - accuracy: 0.9609 - val_loss: 1.2154 - val_accuracy: 0.5343
#
# Epoch 00128: val_loss did not improve from 0.02027
# Epoch 129/1000
#  - 5s - loss: 0.1120 - accuracy: 0.9622 - val_loss: 5.1319 - val_accuracy: 0.5232
#
# Epoch 00129: val_loss did not improve from 0.02027
# Epoch 130/1000
#  - 5s - loss: 0.1114 - accuracy: 0.9616 - val_loss: 1.2954 - val_accuracy: 0.5225
#
# Epoch 00130: val_loss did not improve from 0.02027
# Epoch 131/1000
#  - 5s - loss: 0.1141 - accuracy: 0.9603 - val_loss: 4.1810 - val_accuracy: 0.5382
#
# Epoch 00131: val_loss did not improve from 0.02027
# Epoch 132/1000
#  - 5s - loss: 0.1064 - accuracy: 0.9661 - val_loss: 2.5547 - val_accuracy: 0.5296
#
# Epoch 00132: val_loss did not improve from 0.02027
# Epoch 133/1000
#  - 5s - loss: 0.1033 - accuracy: 0.9666 - val_loss: 4.0856 - val_accuracy: 0.5303
#
# Epoch 00133: val_loss did not improve from 0.02027
# Epoch 134/1000
#  - 5s - loss: 0.1016 - accuracy: 0.9680 - val_loss: 0.6923 - val_accuracy: 0.5240
#
# Epoch 00134: val_loss did not improve from 0.02027
# Epoch 135/1000
#  - 5s - loss: 0.1075 - accuracy: 0.9632 - val_loss: 4.4400 - val_accuracy: 0.5256
#
# Epoch 00135: val_loss did not improve from 0.02027
# Epoch 136/1000
#  - 5s - loss: 0.1029 - accuracy: 0.9659 - val_loss: 1.8793 - val_accuracy: 0.5264
#
# Epoch 00136: val_loss did not improve from 0.02027
# Epoch 137/1000
#  - 5s - loss: 0.1129 - accuracy: 0.9601 - val_loss: 6.1661 - val_accuracy: 0.5169
#
# Epoch 00137: val_loss did not improve from 0.02027
# Epoch 138/1000
#  - 5s - loss: 0.0938 - accuracy: 0.9664 - val_loss: 2.8668 - val_accuracy: 0.5256
#
# Epoch 00138: val_loss did not improve from 0.02027
# Epoch 139/1000
#  - 5s - loss: 0.1051 - accuracy: 0.9627 - val_loss: 0.5886 - val_accuracy: 0.5217
#
# Epoch 00139: val_loss did not improve from 0.02027
# Epoch 140/1000
#  - 5s - loss: 0.1073 - accuracy: 0.9632 - val_loss: 0.1077 - val_accuracy: 0.5288
#
# Epoch 00140: val_loss did not improve from 0.02027
# Epoch 141/1000
#  - 5s - loss: 0.1136 - accuracy: 0.9619 - val_loss: 2.8965 - val_accuracy: 0.5083
#
# Epoch 00141: val_loss did not improve from 0.02027
# Epoch 142/1000
#  - 5s - loss: 0.1099 - accuracy: 0.9606 - val_loss: 2.9841 - val_accuracy: 0.5138
#
# Epoch 00142: val_loss did not improve from 0.02027
# Epoch 143/1000
#  - 5s - loss: 0.1099 - accuracy: 0.9619 - val_loss: 0.7539 - val_accuracy: 0.5099
#
# Epoch 00143: val_loss did not improve from 0.02027
# Epoch 144/1000
#  - 5s - loss: 0.1050 - accuracy: 0.9624 - val_loss: 1.1121 - val_accuracy: 0.5114
#
# Epoch 00144: val_loss did not improve from 0.02027
# Epoch 145/1000
#  - 5s - loss: 0.1011 - accuracy: 0.9674 - val_loss: 2.8044 - val_accuracy: 0.5225
#
# Epoch 00145: val_loss did not improve from 0.02027
# Epoch 146/1000
#  - 5s - loss: 0.1065 - accuracy: 0.9632 - val_loss: 4.6568 - val_accuracy: 0.5138
#
# Epoch 00146: val_loss did not improve from 0.02027
# Epoch 147/1000
#  - 5s - loss: 0.1042 - accuracy: 0.9635 - val_loss: 0.7027 - val_accuracy: 0.5099
#
# Epoch 00147: val_loss did not improve from 0.02027
# Epoch 148/1000
#  - 5s - loss: 0.1082 - accuracy: 0.9601 - val_loss: 0.7106 - val_accuracy: 0.5075
#
# Epoch 00148: val_loss did not improve from 0.02027
# Epoch 149/1000
#  - 5s - loss: 0.1052 - accuracy: 0.9611 - val_loss: 1.1935 - val_accuracy: 0.5075
#
# Epoch 00149: val_loss did not improve from 0.02027
# Epoch 150/1000
#  - 5s - loss: 0.1028 - accuracy: 0.9656 - val_loss: 3.2217 - val_accuracy: 0.5162
#
# Epoch 00150: val_loss did not improve from 0.02027
# Epoch 151/1000
#  - 5s - loss: 0.0975 - accuracy: 0.9648 - val_loss: 3.9760 - val_accuracy: 0.5264
#
# Epoch 00151: val_loss did not improve from 0.02027
# Epoch 152/1000
#  - 5s - loss: 0.0958 - accuracy: 0.9706 - val_loss: 0.9790 - val_accuracy: 0.5201
#
# Epoch 00152: val_loss did not improve from 0.02027
# Epoch 153/1000
#  - 5s - loss: 0.0987 - accuracy: 0.9687 - val_loss: 6.3870 - val_accuracy: 0.5122
#
# Epoch 00153: val_loss did not improve from 0.02027
# Epoch 154/1000
#  - 5s - loss: 0.1026 - accuracy: 0.9682 - val_loss: 3.8077 - val_accuracy: 0.5280
#
# Epoch 00154: val_loss did not improve from 0.02027
# Epoch 155/1000
#  - 5s - loss: 0.0851 - accuracy: 0.9748 - val_loss: 2.5432 - val_accuracy: 0.5075
#
# Epoch 00155: val_loss did not improve from 0.02027
# Epoch 156/1000
#  - 5s - loss: 0.0918 - accuracy: 0.9716 - val_loss: 0.2681 - val_accuracy: 0.5272
#
# Epoch 00156: val_loss did not improve from 0.02027
# Epoch 157/1000
#  - 5s - loss: 0.0933 - accuracy: 0.9682 - val_loss: 3.5340 - val_accuracy: 0.5288
#
# Epoch 00157: val_loss did not improve from 0.02027
# Epoch 158/1000
#  - 5s - loss: 0.0928 - accuracy: 0.9711 - val_loss: 5.0557 - val_accuracy: 0.5209
#
# Epoch 00158: val_loss did not improve from 0.02027
# Epoch 159/1000
#  - 5s - loss: 0.0954 - accuracy: 0.9690 - val_loss: 5.1725 - val_accuracy: 0.5422
#
# Epoch 00159: val_loss did not improve from 0.02027
# Epoch 160/1000
#  - 5s - loss: 0.1006 - accuracy: 0.9666 - val_loss: 2.6769 - val_accuracy: 0.5185
#
# Epoch 00160: val_loss did not improve from 0.02027
# Epoch 161/1000
#  - 5s - loss: 0.0940 - accuracy: 0.9674 - val_loss: 0.5384 - val_accuracy: 0.5240
#
# Epoch 00161: val_loss did not improve from 0.02027
# Epoch 162/1000
#  - 5s - loss: 0.0910 - accuracy: 0.9701 - val_loss: 1.4610 - val_accuracy: 0.5264
#
# Epoch 00162: val_loss did not improve from 0.02027
# Epoch 163/1000
#  - 5s - loss: 0.0948 - accuracy: 0.9653 - val_loss: 3.7698 - val_accuracy: 0.5256
#
# Epoch 00163: val_loss did not improve from 0.02027
# Epoch 164/1000
#  - 5s - loss: 0.0805 - accuracy: 0.9758 - val_loss: 1.1400 - val_accuracy: 0.5162
#
# Epoch 00164: val_loss did not improve from 0.02027
# Epoch 165/1000
#  - 5s - loss: 0.1006 - accuracy: 0.9648 - val_loss: 2.0523 - val_accuracy: 0.5248
#
# Epoch 00165: val_loss did not improve from 0.02027
# Epoch 166/1000
#  - 5s - loss: 0.0935 - accuracy: 0.9666 - val_loss: 5.6444 - val_accuracy: 0.5264
#
# Epoch 00166: val_loss did not improve from 0.02027
# Epoch 167/1000
#  - 5s - loss: 0.0921 - accuracy: 0.9680 - val_loss: 0.1334 - val_accuracy: 0.5240
#
# Epoch 00167: val_loss did not improve from 0.02027
# Epoch 168/1000
#  - 5s - loss: 0.0931 - accuracy: 0.9664 - val_loss: 5.3574 - val_accuracy: 0.5177
#
# Epoch 00168: val_loss did not improve from 0.02027
# Epoch 169/1000
#  - 5s - loss: 0.0918 - accuracy: 0.9674 - val_loss: 0.8500 - val_accuracy: 0.5264
#
# Epoch 00169: val_loss did not improve from 0.02027
# Epoch 170/1000
#  - 5s - loss: 0.0885 - accuracy: 0.9722 - val_loss: 0.9422 - val_accuracy: 0.5303
#
# Epoch 00170: val_loss did not improve from 0.02027
# Epoch 171/1000
#  - 5s - loss: 0.1002 - accuracy: 0.9653 - val_loss: 1.5359 - val_accuracy: 0.5248
#
# Epoch 00171: val_loss did not improve from 0.02027
# Epoch 172/1000
#  - 5s - loss: 0.0929 - accuracy: 0.9698 - val_loss: 1.0096 - val_accuracy: 0.5232
#
# Epoch 00172: val_loss did not improve from 0.02027
# Epoch 173/1000
#  - 5s - loss: 0.0957 - accuracy: 0.9645 - val_loss: 5.0733 - val_accuracy: 0.5319
#
# Epoch 00173: val_loss did not improve from 0.02027
# Epoch 174/1000
#  - 5s - loss: 0.0822 - accuracy: 0.9756 - val_loss: 3.2841 - val_accuracy: 0.5193
#
# Epoch 00174: val_loss did not improve from 0.02027
# Epoch 175/1000
#  - 5s - loss: 0.0880 - accuracy: 0.9706 - val_loss: 1.4613 - val_accuracy: 0.5335
#
# Epoch 00175: val_loss did not improve from 0.02027
# Epoch 176/1000
#  - 5s - loss: 0.0783 - accuracy: 0.9753 - val_loss: 1.1038 - val_accuracy: 0.5091
#
# Epoch 00176: val_loss did not improve from 0.02027
# Epoch 177/1000
#  - 5s - loss: 0.0838 - accuracy: 0.9740 - val_loss: 2.0593 - val_accuracy: 0.5335
#
# Epoch 00177: val_loss did not improve from 0.02027
# Epoch 178/1000
#  - 5s - loss: 0.0851 - accuracy: 0.9727 - val_loss: 0.5985 - val_accuracy: 0.5311
#
# Epoch 00178: val_loss did not improve from 0.02027
# Epoch 179/1000
#  - 5s - loss: 0.0885 - accuracy: 0.9740 - val_loss: 3.6358 - val_accuracy: 0.5311
#
# Epoch 00179: val_loss did not improve from 0.02027
# Epoch 180/1000
#  - 5s - loss: 0.0786 - accuracy: 0.9743 - val_loss: 6.4584 - val_accuracy: 0.5351
#
# Epoch 00180: val_loss did not improve from 0.02027
# Epoch 181/1000
#  - 5s - loss: 0.0783 - accuracy: 0.9761 - val_loss: 1.8842 - val_accuracy: 0.5232
#
# Epoch 00181: val_loss did not improve from 0.02027
# Epoch 182/1000
#  - 5s - loss: 0.0794 - accuracy: 0.9748 - val_loss: 5.9792 - val_accuracy: 0.5201
#
# Epoch 00182: val_loss did not improve from 0.02027
# Epoch 183/1000
#  - 5s - loss: 0.0800 - accuracy: 0.9745 - val_loss: 0.4437 - val_accuracy: 0.5256
#
# Epoch 00183: val_loss did not improve from 0.02027
# Epoch 184/1000
#  - 5s - loss: 0.0726 - accuracy: 0.9769 - val_loss: 3.3369 - val_accuracy: 0.5217
#
# Epoch 00184: val_loss did not improve from 0.02027
# Epoch 185/1000
#  - 5s - loss: 0.0856 - accuracy: 0.9727 - val_loss: 0.0844 - val_accuracy: 0.5248
#
# Epoch 00185: val_loss did not improve from 0.02027
# Epoch 186/1000
#  - 5s - loss: 0.0923 - accuracy: 0.9664 - val_loss: 4.9699 - val_accuracy: 0.5319
#
# Epoch 00186: val_loss did not improve from 0.02027
# Epoch 187/1000
#  - 5s - loss: 0.0842 - accuracy: 0.9722 - val_loss: 1.7260 - val_accuracy: 0.5327
#
# Epoch 00187: val_loss did not improve from 0.02027
# Epoch 188/1000
#  - 5s - loss: 0.0848 - accuracy: 0.9701 - val_loss: 2.7879 - val_accuracy: 0.5280
#
# Epoch 00188: val_loss did not improve from 0.02027
# Epoch 189/1000
#  - 5s - loss: 0.0861 - accuracy: 0.9703 - val_loss: 4.0043 - val_accuracy: 0.5201
#
# Epoch 00189: val_loss did not improve from 0.02027
# Epoch 190/1000
#  - 5s - loss: 0.0788 - accuracy: 0.9769 - val_loss: 5.7250 - val_accuracy: 0.5303
#
# Epoch 00190: val_loss did not improve from 0.02027
# Epoch 191/1000
#  - 5s - loss: 0.0748 - accuracy: 0.9782 - val_loss: 0.6369 - val_accuracy: 0.5264
#
# Epoch 00191: val_loss did not improve from 0.02027
# Epoch 192/1000
#  - 5s - loss: 0.0844 - accuracy: 0.9732 - val_loss: 1.1198 - val_accuracy: 0.5382
#
# Epoch 00192: val_loss did not improve from 0.02027
# Epoch 193/1000
#  - 5s - loss: 0.0776 - accuracy: 0.9766 - val_loss: 1.9055 - val_accuracy: 0.5256
#
# Epoch 00193: val_loss did not improve from 0.02027
# Epoch 194/1000
#  - 5s - loss: 0.0826 - accuracy: 0.9722 - val_loss: 4.2124 - val_accuracy: 0.5248
#
# Epoch 00194: val_loss did not improve from 0.02027
# Epoch 195/1000
#  - 5s - loss: 0.0793 - accuracy: 0.9722 - val_loss: 0.3989 - val_accuracy: 0.5162
#
# Epoch 00195: val_loss did not improve from 0.02027
# Epoch 196/1000
#  - 5s - loss: 0.0889 - accuracy: 0.9698 - val_loss: 0.6454 - val_accuracy: 0.5146
#
# Epoch 00196: val_loss did not improve from 0.02027
# Epoch 197/1000
#  - 5s - loss: 0.0769 - accuracy: 0.9761 - val_loss: 1.6664 - val_accuracy: 0.5351
#
# Epoch 00197: val_loss did not improve from 0.02027
# Epoch 198/1000
#  - 5s - loss: 0.0759 - accuracy: 0.9743 - val_loss: 2.0391 - val_accuracy: 0.5390
#
# Epoch 00198: val_loss did not improve from 0.02027
# Epoch 199/1000
#  - 5s - loss: 0.0795 - accuracy: 0.9729 - val_loss: 0.5665 - val_accuracy: 0.5201
#
# Epoch 00199: val_loss did not improve from 0.02027
# Epoch 200/1000
#  - 5s - loss: 0.0828 - accuracy: 0.9729 - val_loss: 0.5039 - val_accuracy: 0.5177
#
# Epoch 00200: val_loss did not improve from 0.02027
# Epoch 201/1000
#  - 5s - loss: 0.0786 - accuracy: 0.9748 - val_loss: 2.0633 - val_accuracy: 0.5177
#
# Epoch 00201: val_loss did not improve from 0.02027
# Epoch 202/1000
#  - 5s - loss: 0.0785 - accuracy: 0.9727 - val_loss: 0.3985 - val_accuracy: 0.5303
#
# Epoch 00202: val_loss did not improve from 0.02027
# Epoch 203/1000
#  - 5s - loss: 0.0759 - accuracy: 0.9750 - val_loss: 1.5325 - val_accuracy: 0.5390
#
# Epoch 00203: val_loss did not improve from 0.02027
# Epoch 204/1000
#  - 5s - loss: 0.0724 - accuracy: 0.9785 - val_loss: 1.6902 - val_accuracy: 0.5398
#
# Epoch 00204: val_loss did not improve from 0.02027
# Epoch 205/1000
#  - 5s - loss: 0.0759 - accuracy: 0.9769 - val_loss: 1.4993 - val_accuracy: 0.5232
#
# Epoch 00205: val_loss did not improve from 0.02027
# Epoch 206/1000
#  - 5s - loss: 0.0755 - accuracy: 0.9769 - val_loss: 1.3665 - val_accuracy: 0.5240
#
# Epoch 00206: val_loss did not improve from 0.02027
# Epoch 207/1000
#  - 5s - loss: 0.0659 - accuracy: 0.9800 - val_loss: 1.9258 - val_accuracy: 0.5162
#
# Epoch 00207: val_loss did not improve from 0.02027
# Epoch 208/1000
#  - 5s - loss: 0.0752 - accuracy: 0.9740 - val_loss: 4.3339 - val_accuracy: 0.5256
#
# Epoch 00208: val_loss did not improve from 0.02027
# Epoch 209/1000
#  - 5s - loss: 0.0786 - accuracy: 0.9748 - val_loss: 2.7220 - val_accuracy: 0.5248
#
# Epoch 00209: val_loss did not improve from 0.02027
# Epoch 210/1000
#  - 5s - loss: 0.0729 - accuracy: 0.9782 - val_loss: 3.8006 - val_accuracy: 0.5366
#
# Epoch 00210: val_loss did not improve from 0.02027
# Epoch 211/1000
#  - 5s - loss: 0.0709 - accuracy: 0.9782 - val_loss: 0.8398 - val_accuracy: 0.5217
#
# Epoch 00211: val_loss did not improve from 0.02027
# Epoch 212/1000
#  - 5s - loss: 0.0671 - accuracy: 0.9800 - val_loss: 2.1217 - val_accuracy: 0.5382
#
# Epoch 00212: val_loss did not improve from 0.02027
# Epoch 213/1000
#  - 5s - loss: 0.0718 - accuracy: 0.9785 - val_loss: 3.9874 - val_accuracy: 0.5146
#
# Epoch 00213: val_loss did not improve from 0.02027
# Epoch 214/1000
#  - 5s - loss: 0.0787 - accuracy: 0.9708 - val_loss: 2.1929 - val_accuracy: 0.5106
#
# Epoch 00214: val_loss did not improve from 0.02027
# Epoch 215/1000
#  - 5s - loss: 0.0634 - accuracy: 0.9803 - val_loss: 3.5086 - val_accuracy: 0.5201
#
# Epoch 00215: val_loss did not improve from 0.02027
# Epoch 216/1000
#  - 5s - loss: 0.0705 - accuracy: 0.9753 - val_loss: 1.7839 - val_accuracy: 0.5209
#
# Epoch 00216: val_loss did not improve from 0.02027
# Epoch 217/1000
#  - 5s - loss: 0.0700 - accuracy: 0.9774 - val_loss: 0.0722 - val_accuracy: 0.5106
#
# Epoch 00217: val_loss did not improve from 0.02027
# Epoch 218/1000
#  - 5s - loss: 0.0750 - accuracy: 0.9756 - val_loss: 5.7795 - val_accuracy: 0.5327
#
# Epoch 00218: val_loss did not improve from 0.02027
# Epoch 219/1000
#  - 5s - loss: 0.0697 - accuracy: 0.9774 - val_loss: 3.9153 - val_accuracy: 0.5343
#
# Epoch 00219: val_loss did not improve from 0.02027
# Epoch 220/1000
#  - 5s - loss: 0.0731 - accuracy: 0.9756 - val_loss: 2.2233 - val_accuracy: 0.5201
#
# Epoch 00220: val_loss did not improve from 0.02027
# Epoch 221/1000
#  - 5s - loss: 0.0696 - accuracy: 0.9792 - val_loss: 1.6039 - val_accuracy: 0.5146
#
# Epoch 00221: val_loss did not improve from 0.02027
# Epoch 222/1000
#  - 5s - loss: 0.0614 - accuracy: 0.9829 - val_loss: 2.1792 - val_accuracy: 0.5225
#
# Epoch 00222: val_loss did not improve from 0.02027
# Epoch 223/1000
#  - 5s - loss: 0.0743 - accuracy: 0.9756 - val_loss: 2.9780 - val_accuracy: 0.5130
#
# Epoch 00223: val_loss did not improve from 0.02027
# Epoch 224/1000
#  - 5s - loss: 0.0643 - accuracy: 0.9808 - val_loss: 2.8632 - val_accuracy: 0.5020
#
# Epoch 00224: val_loss did not improve from 0.02027
# Epoch 225/1000
#  - 5s - loss: 0.0726 - accuracy: 0.9756 - val_loss: 3.3264 - val_accuracy: 0.5075
#
# Epoch 00225: val_loss did not improve from 0.02027
# Epoch 226/1000
#  - 5s - loss: 0.0646 - accuracy: 0.9814 - val_loss: 1.7712 - val_accuracy: 0.5177
#
# Epoch 00226: val_loss did not improve from 0.02027
# Epoch 227/1000
#  - 5s - loss: 0.0720 - accuracy: 0.9756 - val_loss: 0.0731 - val_accuracy: 0.5185
#
# Epoch 00227: val_loss did not improve from 0.02027
# Epoch 228/1000
#  - 5s - loss: 0.0621 - accuracy: 0.9816 - val_loss: 1.6962 - val_accuracy: 0.5138
#
# Epoch 00228: val_loss did not improve from 0.02027
# Epoch 229/1000
#  - 5s - loss: 0.0617 - accuracy: 0.9824 - val_loss: 4.4883 - val_accuracy: 0.5296
#
# Epoch 00229: val_loss did not improve from 0.02027
# Epoch 230/1000
#  - 5s - loss: 0.0668 - accuracy: 0.9790 - val_loss: 1.1242 - val_accuracy: 0.5256
#
# Epoch 00230: val_loss did not improve from 0.02027
# Epoch 231/1000
#  - 5s - loss: 0.0617 - accuracy: 0.9808 - val_loss: 5.6692 - val_accuracy: 0.5343
#
# Epoch 00231: val_loss did not improve from 0.02027
# Epoch 232/1000
#  - 5s - loss: 0.0650 - accuracy: 0.9795 - val_loss: 2.0921 - val_accuracy: 0.5225
#
# Epoch 00232: val_loss did not improve from 0.02027
# Epoch 233/1000
#  - 5s - loss: 0.0651 - accuracy: 0.9800 - val_loss: 3.6269 - val_accuracy: 0.5091
#
# Epoch 00233: val_loss did not improve from 0.02027
# Epoch 234/1000
#  - 5s - loss: 0.0648 - accuracy: 0.9808 - val_loss: 1.7597 - val_accuracy: 0.5225
#
# Epoch 00234: val_loss did not improve from 0.02027
# Epoch 235/1000
#  - 5s - loss: 0.0608 - accuracy: 0.9835 - val_loss: 1.8621 - val_accuracy: 0.5296
#
# Epoch 00235: val_loss did not improve from 0.02027
# Epoch 236/1000
#  - 5s - loss: 0.0630 - accuracy: 0.9800 - val_loss: 0.3793 - val_accuracy: 0.5248
#
# Epoch 00236: val_loss did not improve from 0.02027
# Epoch 237/1000
#  - 5s - loss: 0.0670 - accuracy: 0.9782 - val_loss: 4.6027 - val_accuracy: 0.5225
#
# Epoch 00237: val_loss did not improve from 0.02027
# Epoch 238/1000
#  - 5s - loss: 0.0719 - accuracy: 0.9748 - val_loss: 1.7041 - val_accuracy: 0.5264
#
# Epoch 00238: val_loss did not improve from 0.02027
# Epoch 239/1000
#  - 5s - loss: 0.0598 - accuracy: 0.9835 - val_loss: 4.3609 - val_accuracy: 0.5130
#
# Epoch 00239: val_loss did not improve from 0.02027
# Epoch 240/1000
#  - 5s - loss: 0.0651 - accuracy: 0.9808 - val_loss: 2.7462 - val_accuracy: 0.5138
#
# Epoch 00240: val_loss did not improve from 0.02027
# Epoch 241/1000
#  - 5s - loss: 0.0653 - accuracy: 0.9792 - val_loss: 2.7842 - val_accuracy: 0.5217
#
# Epoch 00241: val_loss did not improve from 0.02027
# Epoch 242/1000
#  - 5s - loss: 0.0584 - accuracy: 0.9811 - val_loss: 4.0365 - val_accuracy: 0.5185
#
# Epoch 00242: val_loss did not improve from 0.02027
# Epoch 243/1000
#  - 5s - loss: 0.0616 - accuracy: 0.9819 - val_loss: 5.2471 - val_accuracy: 0.5146
#
# Epoch 00243: val_loss did not improve from 0.02027
# Epoch 244/1000
#  - 5s - loss: 0.0628 - accuracy: 0.9816 - val_loss: 1.4798 - val_accuracy: 0.5351
#
# Epoch 00244: val_loss did not improve from 0.02027
# Epoch 245/1000
#  - 5s - loss: 0.0625 - accuracy: 0.9790 - val_loss: 5.2872 - val_accuracy: 0.5256
#
# Epoch 00245: val_loss did not improve from 0.02027
# Epoch 246/1000
#  - 5s - loss: 0.0540 - accuracy: 0.9840 - val_loss: 1.9707 - val_accuracy: 0.5154
#
# Epoch 00246: val_loss did not improve from 0.02027
# Epoch 247/1000
#  - 5s - loss: 0.0657 - accuracy: 0.9777 - val_loss: 3.4573 - val_accuracy: 0.5185
#
# Epoch 00247: val_loss did not improve from 0.02027
# Epoch 248/1000
#  - 5s - loss: 0.0584 - accuracy: 0.9837 - val_loss: 6.2069 - val_accuracy: 0.5193
#
# Epoch 00248: val_loss did not improve from 0.02027
# Epoch 249/1000
#  - 5s - loss: 0.0571 - accuracy: 0.9842 - val_loss: 3.3022 - val_accuracy: 0.5114
#
# Epoch 00249: val_loss did not improve from 0.02027
# Epoch 250/1000
#  - 5s - loss: 0.0557 - accuracy: 0.9840 - val_loss: 2.5631 - val_accuracy: 0.5130
#
# Epoch 00250: val_loss did not improve from 0.02027
# Epoch 251/1000
#  - 5s - loss: 0.0555 - accuracy: 0.9824 - val_loss: 3.4069 - val_accuracy: 0.5162
#
# Epoch 00251: val_loss did not improve from 0.02027
# Epoch 252/1000
#  - 5s - loss: 0.0635 - accuracy: 0.9787 - val_loss: 5.0853 - val_accuracy: 0.5264
#
# Epoch 00252: val_loss did not improve from 0.02027
# Epoch 253/1000
#  - 5s - loss: 0.0590 - accuracy: 0.9835 - val_loss: 2.7116 - val_accuracy: 0.5232
#
# Epoch 00253: val_loss did not improve from 0.02027
# Epoch 254/1000
#  - 5s - loss: 0.0573 - accuracy: 0.9837 - val_loss: 0.9789 - val_accuracy: 0.5256
#
# Epoch 00254: val_loss did not improve from 0.02027
# Epoch 255/1000
#  - 5s - loss: 0.0607 - accuracy: 0.9808 - val_loss: 1.2535 - val_accuracy: 0.5209
#
# Epoch 00255: val_loss did not improve from 0.02027
# Epoch 256/1000
#  - 5s - loss: 0.0581 - accuracy: 0.9821 - val_loss: 6.0062 - val_accuracy: 0.5217
#
# Epoch 00256: val_loss did not improve from 0.02027
# Epoch 257/1000
#  - 5s - loss: 0.0661 - accuracy: 0.9750 - val_loss: 0.4990 - val_accuracy: 0.5280
#
# Epoch 00257: val_loss did not improve from 0.02027
# Epoch 258/1000
#  - 5s - loss: 0.0571 - accuracy: 0.9842 - val_loss: 4.0379 - val_accuracy: 0.5343
#
# Epoch 00258: val_loss did not improve from 0.02027
# Epoch 259/1000
#  - 5s - loss: 0.0667 - accuracy: 0.9756 - val_loss: 6.5382 - val_accuracy: 0.5343
#
# Epoch 00259: val_loss did not improve from 0.02027
# Epoch 260/1000
#  - 5s - loss: 0.0569 - accuracy: 0.9840 - val_loss: 8.2177 - val_accuracy: 0.5390
#
# Epoch 00260: val_loss did not improve from 0.02027
# Epoch 261/1000
#  - 5s - loss: 0.0577 - accuracy: 0.9808 - val_loss: 1.6888 - val_accuracy: 0.5280
#
# Epoch 00261: val_loss did not improve from 0.02027
# Epoch 262/1000
#  - 5s - loss: 0.0568 - accuracy: 0.9837 - val_loss: 2.5621 - val_accuracy: 0.5296
#
# Epoch 00262: val_loss did not improve from 0.02027
# Epoch 263/1000
#  - 5s - loss: 0.0529 - accuracy: 0.9832 - val_loss: 2.6257 - val_accuracy: 0.5280
#
# Epoch 00263: val_loss did not improve from 0.02027
# Epoch 264/1000
#  - 5s - loss: 0.0609 - accuracy: 0.9777 - val_loss: 1.7804 - val_accuracy: 0.5248
#
# Epoch 00264: val_loss did not improve from 0.02027
# Epoch 265/1000
#  - 5s - loss: 0.0491 - accuracy: 0.9853 - val_loss: 0.6924 - val_accuracy: 0.5264
#
# Epoch 00265: val_loss did not improve from 0.02027
# Epoch 266/1000
#  - 5s - loss: 0.0532 - accuracy: 0.9829 - val_loss: 5.2605 - val_accuracy: 0.5311
#
# Epoch 00266: val_loss did not improve from 0.02027
# Epoch 267/1000
#  - 5s - loss: 0.0586 - accuracy: 0.9792 - val_loss: 1.5985 - val_accuracy: 0.5303
#
# Epoch 00267: val_loss did not improve from 0.02027
# Epoch 268/1000
#  - 5s - loss: 0.0523 - accuracy: 0.9853 - val_loss: 3.1392 - val_accuracy: 0.5225
#
# Epoch 00268: val_loss did not improve from 0.02027
# Epoch 269/1000
#  - 5s - loss: 0.0477 - accuracy: 0.9887 - val_loss: 1.7554 - val_accuracy: 0.5240
#
# Epoch 00269: val_loss did not improve from 0.02027
# Epoch 270/1000
#  - 5s - loss: 0.0500 - accuracy: 0.9866 - val_loss: 1.0846 - val_accuracy: 0.5169
#
# Epoch 00270: val_loss did not improve from 0.02027
# Epoch 271/1000
#  - 5s - loss: 0.0551 - accuracy: 0.9850 - val_loss: 2.8141 - val_accuracy: 0.5130
#
# Epoch 00271: val_loss did not improve from 0.02027
# Epoch 272/1000
#  - 5s - loss: 0.0517 - accuracy: 0.9845 - val_loss: 1.7061 - val_accuracy: 0.5217
#
# Epoch 00272: val_loss did not improve from 0.02027
# Epoch 273/1000
#  - 5s - loss: 0.0563 - accuracy: 0.9845 - val_loss: 0.1028 - val_accuracy: 0.5240
#
# Epoch 00273: val_loss did not improve from 0.02027
# Epoch 274/1000
#  - 5s - loss: 0.0485 - accuracy: 0.9848 - val_loss: 1.0005 - val_accuracy: 0.5240
#
# Epoch 00274: val_loss did not improve from 0.02027
# Epoch 275/1000
#  - 5s - loss: 0.0511 - accuracy: 0.9845 - val_loss: 0.2292 - val_accuracy: 0.5185
#
# Epoch 00275: val_loss did not improve from 0.02027
# Epoch 276/1000
#  - 5s - loss: 0.0520 - accuracy: 0.9842 - val_loss: 1.4570 - val_accuracy: 0.5256
#
# Epoch 00276: val_loss did not improve from 0.02027
# Epoch 277/1000
#  - 5s - loss: 0.0539 - accuracy: 0.9837 - val_loss: 2.7388 - val_accuracy: 0.5288
#
# Epoch 00277: val_loss did not improve from 0.02027
# Epoch 278/1000
#  - 5s - loss: 0.0541 - accuracy: 0.9835 - val_loss: 5.2340 - val_accuracy: 0.5185
#
# Epoch 00278: val_loss did not improve from 0.02027
# Epoch 279/1000
#  - 5s - loss: 0.0610 - accuracy: 0.9816 - val_loss: 0.0567 - val_accuracy: 0.5209
#
# Epoch 00279: val_loss did not improve from 0.02027
# Epoch 280/1000
#  - 5s - loss: 0.0521 - accuracy: 0.9848 - val_loss: 1.8339 - val_accuracy: 0.5288
#
# Epoch 00280: val_loss did not improve from 0.02027
# Epoch 281/1000
#  - 5s - loss: 0.0504 - accuracy: 0.9850 - val_loss: 3.0119 - val_accuracy: 0.5327
#
# Epoch 00281: val_loss did not improve from 0.02027
# Epoch 282/1000
#  - 5s - loss: 0.0501 - accuracy: 0.9861 - val_loss: 1.6355 - val_accuracy: 0.5185
#
# Epoch 00282: val_loss did not improve from 0.02027
# Epoch 283/1000
#  - 5s - loss: 0.0486 - accuracy: 0.9848 - val_loss: 1.0113 - val_accuracy: 0.5280
#
# Epoch 00283: val_loss did not improve from 0.02027
# Epoch 284/1000
#  - 5s - loss: 0.0506 - accuracy: 0.9850 - val_loss: 7.9546 - val_accuracy: 0.5335
#
# Epoch 00284: val_loss did not improve from 0.02027
# Epoch 285/1000
#  - 5s - loss: 0.0521 - accuracy: 0.9835 - val_loss: 6.1216 - val_accuracy: 0.5154
#
# Epoch 00285: val_loss did not improve from 0.02027
# Epoch 286/1000
#  - 5s - loss: 0.0462 - accuracy: 0.9858 - val_loss: 2.1503 - val_accuracy: 0.5146
#
# Epoch 00286: val_loss did not improve from 0.02027
# Epoch 287/1000
#  - 5s - loss: 0.0440 - accuracy: 0.9887 - val_loss: 0.2894 - val_accuracy: 0.5185
#
# Epoch 00287: val_loss did not improve from 0.02027
# Epoch 288/1000
#  - 5s - loss: 0.0474 - accuracy: 0.9877 - val_loss: 2.8670 - val_accuracy: 0.5201
#
# Epoch 00288: val_loss did not improve from 0.02027
# Epoch 289/1000
#  - 5s - loss: 0.0455 - accuracy: 0.9871 - val_loss: 4.9770 - val_accuracy: 0.5217
#
# Epoch 00289: val_loss did not improve from 0.02027
# Epoch 290/1000
#  - 5s - loss: 0.0468 - accuracy: 0.9856 - val_loss: 1.5014 - val_accuracy: 0.5201
#
# Epoch 00290: val_loss did not improve from 0.02027
# Epoch 291/1000
#  - 5s - loss: 0.0532 - accuracy: 0.9827 - val_loss: 2.0229 - val_accuracy: 0.5177
#
# Epoch 00291: val_loss did not improve from 0.02027
# Epoch 292/1000
#  - 5s - loss: 0.0523 - accuracy: 0.9842 - val_loss: 3.0672 - val_accuracy: 0.5351
#
# Epoch 00292: val_loss did not improve from 0.02027
# Epoch 293/1000
#  - 5s - loss: 0.0463 - accuracy: 0.9866 - val_loss: 2.4219 - val_accuracy: 0.5209
#
# Epoch 00293: val_loss did not improve from 0.02027
# Epoch 294/1000
#  - 5s - loss: 0.0511 - accuracy: 0.9829 - val_loss: 4.0420 - val_accuracy: 0.5217
#
# Epoch 00294: val_loss did not improve from 0.02027
# Epoch 295/1000
#  - 5s - loss: 0.0452 - accuracy: 0.9871 - val_loss: 5.3653 - val_accuracy: 0.5177
#
# Epoch 00295: val_loss did not improve from 0.02027
# Epoch 296/1000
#  - 5s - loss: 0.0433 - accuracy: 0.9882 - val_loss: 4.8307 - val_accuracy: 0.5146
#
# Epoch 00296: val_loss did not improve from 0.02027
# Epoch 297/1000
#  - 5s - loss: 0.0443 - accuracy: 0.9874 - val_loss: 0.9648 - val_accuracy: 0.5225
#
# Epoch 00297: val_loss did not improve from 0.02027
# Epoch 298/1000
#  - 5s - loss: 0.0465 - accuracy: 0.9845 - val_loss: 4.0659 - val_accuracy: 0.5146
#
# Epoch 00298: val_loss did not improve from 0.02027
# Epoch 299/1000
#  - 5s - loss: 0.0457 - accuracy: 0.9866 - val_loss: 3.5621 - val_accuracy: 0.5114
#
# Epoch 00299: val_loss did not improve from 0.02027
# Epoch 300/1000
#  - 5s - loss: 0.0533 - accuracy: 0.9816 - val_loss: 1.3882 - val_accuracy: 0.5035
#
# Epoch 00300: val_loss did not improve from 0.02027
# Epoch 301/1000
#  - 5s - loss: 0.0454 - accuracy: 0.9845 - val_loss: 2.1870 - val_accuracy: 0.5296
#
# Epoch 00301: val_loss did not improve from 0.02027
# Epoch 302/1000
#  - 5s - loss: 0.0440 - accuracy: 0.9863 - val_loss: 7.0140 - val_accuracy: 0.5114
#
# Epoch 00302: val_loss did not improve from 0.02027
# Epoch 303/1000
#  - 5s - loss: 0.0514 - accuracy: 0.9827 - val_loss: 1.8069 - val_accuracy: 0.5209
#
# Epoch 00303: val_loss did not improve from 0.02027
# Epoch 304/1000
#  - 5s - loss: 0.0467 - accuracy: 0.9866 - val_loss: 4.5509 - val_accuracy: 0.5169
#
# Epoch 00304: val_loss did not improve from 0.02027
# Epoch 305/1000
#  - 5s - loss: 0.0523 - accuracy: 0.9858 - val_loss: 0.9592 - val_accuracy: 0.5067
#
# Epoch 00305: val_loss did not improve from 0.02027
# Epoch 306/1000
#  - 5s - loss: 0.0443 - accuracy: 0.9877 - val_loss: 2.5237 - val_accuracy: 0.5091
#
# Epoch 00306: val_loss did not improve from 0.02027
# Epoch 307/1000
#  - 5s - loss: 0.0356 - accuracy: 0.9916 - val_loss: 0.4288 - val_accuracy: 0.5201
#
# Epoch 00307: val_loss did not improve from 0.02027
# Epoch 308/1000
#  - 5s - loss: 0.0418 - accuracy: 0.9874 - val_loss: 7.7569 - val_accuracy: 0.5217
#
# Epoch 00308: val_loss did not improve from 0.02027
# Epoch 309/1000
#  - 5s - loss: 0.0443 - accuracy: 0.9853 - val_loss: 2.0123 - val_accuracy: 0.5162
#
# Epoch 00309: val_loss did not improve from 0.02027
# Epoch 310/1000
#  - 5s - loss: 0.0498 - accuracy: 0.9858 - val_loss: 6.4070 - val_accuracy: 0.5162
#
# Epoch 00310: val_loss did not improve from 0.02027
# Epoch 311/1000
#  - 5s - loss: 0.0485 - accuracy: 0.9853 - val_loss: 3.7261 - val_accuracy: 0.5067
#
# Epoch 00311: val_loss did not improve from 0.02027
# Epoch 312/1000
#  - 5s - loss: 0.0458 - accuracy: 0.9848 - val_loss: 1.8354 - val_accuracy: 0.5240
#
# Epoch 00312: val_loss did not improve from 0.02027
# Epoch 313/1000
#  - 5s - loss: 0.0508 - accuracy: 0.9848 - val_loss: 4.2222 - val_accuracy: 0.5177
#
# Epoch 00313: val_loss did not improve from 0.02027
# Epoch 314/1000
#  - 5s - loss: 0.0427 - accuracy: 0.9882 - val_loss: 6.7630 - val_accuracy: 0.5319
#
# Epoch 00314: val_loss did not improve from 0.02027
# Epoch 315/1000
#  - 5s - loss: 0.0424 - accuracy: 0.9884 - val_loss: 5.2749 - val_accuracy: 0.5146
#
# Epoch 00315: val_loss did not improve from 0.02027
# Epoch 316/1000
#  - 5s - loss: 0.0484 - accuracy: 0.9853 - val_loss: 2.6739 - val_accuracy: 0.5122
#
# Epoch 00316: val_loss did not improve from 0.02027
# Epoch 317/1000
#  - 5s - loss: 0.0430 - accuracy: 0.9858 - val_loss: 2.7500 - val_accuracy: 0.4980
#
# Epoch 00317: val_loss did not improve from 0.02027
# Epoch 318/1000
#  - 5s - loss: 0.0442 - accuracy: 0.9882 - val_loss: 0.7814 - val_accuracy: 0.5067
#
# Epoch 00318: val_loss did not improve from 0.02027
# Epoch 319/1000
#  - 5s - loss: 0.0388 - accuracy: 0.9869 - val_loss: 4.1399 - val_accuracy: 0.5138
#
# Epoch 00319: val_loss did not improve from 0.02027
# Epoch 320/1000
#  - 5s - loss: 0.0413 - accuracy: 0.9871 - val_loss: 1.6361 - val_accuracy: 0.5106
#
# Epoch 00320: val_loss did not improve from 0.02027
# Epoch 321/1000
#  - 5s - loss: 0.0463 - accuracy: 0.9866 - val_loss: 3.9906 - val_accuracy: 0.5004
#
# Epoch 00321: val_loss did not improve from 0.02027
# Epoch 322/1000
#  - 5s - loss: 0.0489 - accuracy: 0.9858 - val_loss: 2.5045 - val_accuracy: 0.5169
#
# Epoch 00322: val_loss did not improve from 0.02027
# Epoch 323/1000
#  - 5s - loss: 0.0455 - accuracy: 0.9863 - val_loss: 3.7186 - val_accuracy: 0.5146
#
# Epoch 00323: val_loss did not improve from 0.02027
# Epoch 324/1000
#  - 5s - loss: 0.0457 - accuracy: 0.9861 - val_loss: 1.6297 - val_accuracy: 0.5154
#
# Epoch 00324: val_loss did not improve from 0.02027
# Epoch 325/1000
#  - 5s - loss: 0.0452 - accuracy: 0.9848 - val_loss: 2.8362 - val_accuracy: 0.5209
#
# Epoch 00325: val_loss did not improve from 0.02027
# Epoch 326/1000
#  - 5s - loss: 0.0430 - accuracy: 0.9863 - val_loss: 5.6157 - val_accuracy: 0.5240
#
# Epoch 00326: val_loss did not improve from 0.02027
# Epoch 327/1000
#  - 5s - loss: 0.0391 - accuracy: 0.9898 - val_loss: 1.8963 - val_accuracy: 0.5201
#
# Epoch 00327: val_loss did not improve from 0.02027
# Epoch 328/1000
#  - 5s - loss: 0.0425 - accuracy: 0.9856 - val_loss: 1.9002 - val_accuracy: 0.5335
#
# Epoch 00328: val_loss did not improve from 0.02027
# Epoch 329/1000
#  - 5s - loss: 0.0430 - accuracy: 0.9882 - val_loss: 2.0130 - val_accuracy: 0.5201
#
# Epoch 00329: val_loss did not improve from 0.02027
# Epoch 330/1000
#  - 5s - loss: 0.0348 - accuracy: 0.9919 - val_loss: 1.5698 - val_accuracy: 0.5256
#
# Epoch 00330: val_loss did not improve from 0.02027
# Epoch 331/1000
#  - 5s - loss: 0.0418 - accuracy: 0.9882 - val_loss: 0.4066 - val_accuracy: 0.5162
#
# Epoch 00331: val_loss did not improve from 0.02027
# Epoch 332/1000
#  - 5s - loss: 0.0425 - accuracy: 0.9882 - val_loss: 3.6485 - val_accuracy: 0.5256
#
# Epoch 00332: val_loss did not improve from 0.02027
# Epoch 333/1000
#  - 5s - loss: 0.0441 - accuracy: 0.9853 - val_loss: 2.6518 - val_accuracy: 0.5272
#
# Epoch 00333: val_loss did not improve from 0.02027
# Epoch 334/1000
#  - 5s - loss: 0.0393 - accuracy: 0.9890 - val_loss: 2.8822 - val_accuracy: 0.5232
#
# Epoch 00334: val_loss did not improve from 0.02027
# Epoch 335/1000
#  - 5s - loss: 0.0417 - accuracy: 0.9874 - val_loss: 6.2816 - val_accuracy: 0.5296
#
# Epoch 00335: val_loss did not improve from 0.02027
# Epoch 336/1000
#  - 5s - loss: 0.0414 - accuracy: 0.9892 - val_loss: 3.5710 - val_accuracy: 0.5288
#
# Epoch 00336: val_loss did not improve from 0.02027
# Epoch 337/1000
#  - 5s - loss: 0.0308 - accuracy: 0.9940 - val_loss: 0.8585 - val_accuracy: 0.5209
#
# Epoch 00337: val_loss did not improve from 0.02027
# Epoch 338/1000
#  - 5s - loss: 0.0409 - accuracy: 0.9877 - val_loss: 4.7939 - val_accuracy: 0.5169
#
# Epoch 00338: val_loss did not improve from 0.02027
# Epoch 339/1000
#  - 5s - loss: 0.0355 - accuracy: 0.9911 - val_loss: 6.9809 - val_accuracy: 0.5185
#
# Epoch 00339: val_loss did not improve from 0.02027
# Epoch 340/1000
#  - 5s - loss: 0.0338 - accuracy: 0.9905 - val_loss: 3.1842 - val_accuracy: 0.5146
#
# Epoch 00340: val_loss did not improve from 0.02027
# Epoch 341/1000
#  - 5s - loss: 0.0411 - accuracy: 0.9898 - val_loss: 3.9831 - val_accuracy: 0.5232
#
# Epoch 00341: val_loss did not improve from 0.02027
# Epoch 342/1000
#  - 5s - loss: 0.0398 - accuracy: 0.9879 - val_loss: 4.0260 - val_accuracy: 0.5296
#
# Epoch 00342: val_loss did not improve from 0.02027
# Epoch 343/1000
#  - 5s - loss: 0.0341 - accuracy: 0.9919 - val_loss: 3.8246 - val_accuracy: 0.5272
#
# Epoch 00343: val_loss did not improve from 0.02027
# Epoch 344/1000
#  - 5s - loss: 0.0340 - accuracy: 0.9908 - val_loss: 2.4562 - val_accuracy: 0.5099
#
# Epoch 00344: val_loss did not improve from 0.02027
# Epoch 345/1000
#  - 5s - loss: 0.0418 - accuracy: 0.9890 - val_loss: 0.0875 - val_accuracy: 0.5217
#
# Epoch 00345: val_loss did not improve from 0.02027
# Epoch 346/1000
#  - 5s - loss: 0.0440 - accuracy: 0.9858 - val_loss: 4.6506 - val_accuracy: 0.5193
#
# Epoch 00346: val_loss did not improve from 0.02027
# Epoch 347/1000
#  - 5s - loss: 0.0404 - accuracy: 0.9882 - val_loss: 4.0593 - val_accuracy: 0.5272
#
# Epoch 00347: val_loss did not improve from 0.02027
# Epoch 348/1000
#  - 5s - loss: 0.0412 - accuracy: 0.9877 - val_loss: 2.7611 - val_accuracy: 0.5311
#
# Epoch 00348: val_loss did not improve from 0.02027
# Epoch 349/1000
#  - 5s - loss: 0.0385 - accuracy: 0.9879 - val_loss: 4.7445 - val_accuracy: 0.5240
#
# Epoch 00349: val_loss did not improve from 0.02027
# Epoch 350/1000
#  - 5s - loss: 0.0315 - accuracy: 0.9924 - val_loss: 2.6311 - val_accuracy: 0.5122
#
# Epoch 00350: val_loss did not improve from 0.02027
# Epoch 351/1000
#  - 5s - loss: 0.0374 - accuracy: 0.9879 - val_loss: 5.9022 - val_accuracy: 0.5193
#
# Epoch 00351: val_loss did not improve from 0.02027
# Epoch 352/1000
#  - 5s - loss: 0.0398 - accuracy: 0.9890 - val_loss: 6.2513 - val_accuracy: 0.5162
#
# Epoch 00352: val_loss did not improve from 0.02027
# Epoch 353/1000
#  - 5s - loss: 0.0421 - accuracy: 0.9879 - val_loss: 3.0378 - val_accuracy: 0.5169
#
# Epoch 00353: val_loss did not improve from 0.02027
# Epoch 354/1000
#  - 5s - loss: 0.0294 - accuracy: 0.9932 - val_loss: 2.4526 - val_accuracy: 0.5327
#
# Epoch 00354: val_loss did not improve from 0.02027
# Epoch 355/1000
#  - 5s - loss: 0.0415 - accuracy: 0.9879 - val_loss: 4.5775 - val_accuracy: 0.5327
#
# Epoch 00355: val_loss did not improve from 0.02027
# Epoch 356/1000
#  - 5s - loss: 0.0470 - accuracy: 0.9829 - val_loss: 4.6961 - val_accuracy: 0.5225
#
# Epoch 00356: val_loss did not improve from 0.02027
# Epoch 357/1000
#  - 5s - loss: 0.0388 - accuracy: 0.9898 - val_loss: 5.3056 - val_accuracy: 0.5225
#
# Epoch 00357: val_loss did not improve from 0.02027
# Epoch 358/1000
#  - 5s - loss: 0.0339 - accuracy: 0.9892 - val_loss: 6.0447 - val_accuracy: 0.5232
#
# Epoch 00358: val_loss did not improve from 0.02027
# Epoch 359/1000
#  - 5s - loss: 0.0368 - accuracy: 0.9882 - val_loss: 6.7640 - val_accuracy: 0.5106
#
# Epoch 00359: val_loss did not improve from 0.02027
# Epoch 360/1000
#  - 5s - loss: 0.0382 - accuracy: 0.9884 - val_loss: 2.3870 - val_accuracy: 0.5240
#
# Epoch 00360: val_loss did not improve from 0.02027
# Epoch 361/1000
#  - 5s - loss: 0.0344 - accuracy: 0.9892 - val_loss: 3.6981 - val_accuracy: 0.5193
#
# Epoch 00361: val_loss did not improve from 0.02027
# Epoch 362/1000
#  - 5s - loss: 0.0373 - accuracy: 0.9887 - val_loss: 6.1708 - val_accuracy: 0.5272
#
# Epoch 00362: val_loss did not improve from 0.02027
# Epoch 363/1000
#  - 5s - loss: 0.0318 - accuracy: 0.9932 - val_loss: 7.0232 - val_accuracy: 0.5232
#
# Epoch 00363: val_loss did not improve from 0.02027
# Epoch 364/1000
#  - 5s - loss: 0.0306 - accuracy: 0.9916 - val_loss: 2.4768 - val_accuracy: 0.5217
#
# Epoch 00364: val_loss did not improve from 0.02027
# Epoch 365/1000
#  - 5s - loss: 0.0310 - accuracy: 0.9913 - val_loss: 3.3619 - val_accuracy: 0.5288
#
# Epoch 00365: val_loss did not improve from 0.02027
# Epoch 366/1000
#  - 5s - loss: 0.0323 - accuracy: 0.9916 - val_loss: 3.2610 - val_accuracy: 0.5303
#
# Epoch 00366: val_loss did not improve from 0.02027
# Epoch 367/1000
#  - 5s - loss: 0.0283 - accuracy: 0.9940 - val_loss: 2.6461 - val_accuracy: 0.5225
#
# Epoch 00367: val_loss did not improve from 0.02027
# Epoch 368/1000
#  - 5s - loss: 0.0329 - accuracy: 0.9913 - val_loss: 4.5301 - val_accuracy: 0.5264
#
# Epoch 00368: val_loss did not improve from 0.02027
# Epoch 369/1000
#  - 5s - loss: 0.0313 - accuracy: 0.9913 - val_loss: 5.3873 - val_accuracy: 0.5225
#
# Epoch 00369: val_loss did not improve from 0.02027
# Epoch 370/1000
#  - 5s - loss: 0.0416 - accuracy: 0.9863 - val_loss: 3.4108 - val_accuracy: 0.5114
#
# Epoch 00370: val_loss did not improve from 0.02027
# Epoch 371/1000
#  - 5s - loss: 0.0368 - accuracy: 0.9900 - val_loss: 1.7419 - val_accuracy: 0.5091
#
# Epoch 00371: val_loss did not improve from 0.02027
# Epoch 372/1000
#  - 5s - loss: 0.0319 - accuracy: 0.9919 - val_loss: 2.2620 - val_accuracy: 0.5256
#
# Epoch 00372: val_loss did not improve from 0.02027
# Epoch 373/1000
#  - 5s - loss: 0.0398 - accuracy: 0.9900 - val_loss: 2.4399 - val_accuracy: 0.5280
#
# Epoch 00373: val_loss did not improve from 0.02027
# Epoch 374/1000
#  - 5s - loss: 0.0382 - accuracy: 0.9882 - val_loss: 6.6056 - val_accuracy: 0.5288
#
# Epoch 00374: val_loss did not improve from 0.02027
# Epoch 375/1000
#  - 5s - loss: 0.0363 - accuracy: 0.9898 - val_loss: 2.9471 - val_accuracy: 0.5248
#
# Epoch 00375: val_loss did not improve from 0.02027
# Epoch 376/1000
#  - 5s - loss: 0.0353 - accuracy: 0.9898 - val_loss: 5.0693 - val_accuracy: 0.5130
#
# Epoch 00376: val_loss did not improve from 0.02027
# Epoch 377/1000
#  - 5s - loss: 0.0360 - accuracy: 0.9900 - val_loss: 1.8856 - val_accuracy: 0.5240
#
# Epoch 00377: val_loss did not improve from 0.02027
# Epoch 378/1000
#  - 5s - loss: 0.0355 - accuracy: 0.9905 - val_loss: 0.9788 - val_accuracy: 0.5154
#
# Epoch 00378: val_loss did not improve from 0.02027
# Epoch 379/1000
#  - 5s - loss: 0.0276 - accuracy: 0.9940 - val_loss: 7.4213 - val_accuracy: 0.5130
#
# Epoch 00379: val_loss did not improve from 0.02027
# Epoch 380/1000
#  - 5s - loss: 0.0336 - accuracy: 0.9919 - val_loss: 1.1708 - val_accuracy: 0.5091
#
# Epoch 00380: val_loss did not improve from 0.02027
# Epoch 381/1000
#  - 5s - loss: 0.0360 - accuracy: 0.9892 - val_loss: 3.0201 - val_accuracy: 0.5099
#
# Epoch 00381: val_loss did not improve from 0.02027
# Epoch 382/1000
#  - 5s - loss: 0.0300 - accuracy: 0.9942 - val_loss: 6.1036 - val_accuracy: 0.5012
#
# Epoch 00382: val_loss did not improve from 0.02027
# Epoch 383/1000
#  - 5s - loss: 0.0305 - accuracy: 0.9921 - val_loss: 3.2712 - val_accuracy: 0.5177
#
# Epoch 00383: val_loss did not improve from 0.02027
# Epoch 384/1000
#  - 5s - loss: 0.0297 - accuracy: 0.9913 - val_loss: 0.1866 - val_accuracy: 0.5043
#
# Epoch 00384: val_loss did not improve from 0.02027
# Epoch 385/1000
#  - 5s - loss: 0.0298 - accuracy: 0.9905 - val_loss: 2.2040 - val_accuracy: 0.5169
#
# Epoch 00385: val_loss did not improve from 0.02027
# Epoch 386/1000
#  - 5s - loss: 0.0381 - accuracy: 0.9874 - val_loss: 5.5780 - val_accuracy: 0.5114
#
# Epoch 00386: val_loss did not improve from 0.02027
# Epoch 387/1000
#  - 5s - loss: 0.0293 - accuracy: 0.9932 - val_loss: 5.5819 - val_accuracy: 0.5209
#
# Epoch 00387: val_loss did not improve from 0.02027
# Epoch 388/1000
#  - 5s - loss: 0.0311 - accuracy: 0.9911 - val_loss: 5.2615 - val_accuracy: 0.5114
#
# Epoch 00388: val_loss did not improve from 0.02027
# Epoch 389/1000
#  - 5s - loss: 0.0285 - accuracy: 0.9921 - val_loss: 7.6350 - val_accuracy: 0.5272
#
# Epoch 00389: val_loss did not improve from 0.02027
# Epoch 390/1000
#  - 5s - loss: 0.0322 - accuracy: 0.9921 - val_loss: 14.6828 - val_accuracy: 0.5193
#
# Epoch 00390: val_loss did not improve from 0.02027
# Epoch 391/1000
#  - 5s - loss: 0.0329 - accuracy: 0.9911 - val_loss: 2.9289 - val_accuracy: 0.5288
#
# Epoch 00391: val_loss did not improve from 0.02027
# Epoch 392/1000
#  - 5s - loss: 0.0318 - accuracy: 0.9903 - val_loss: 3.4696 - val_accuracy: 0.5004
#
# Epoch 00392: val_loss did not improve from 0.02027
# Epoch 393/1000
#  - 5s - loss: 0.0287 - accuracy: 0.9934 - val_loss: 2.4925 - val_accuracy: 0.5154
#
# Epoch 00393: val_loss did not improve from 0.02027
# Epoch 394/1000
#  - 5s - loss: 0.0311 - accuracy: 0.9929 - val_loss: 7.1621 - val_accuracy: 0.5264
#
# Epoch 00394: val_loss did not improve from 0.02027
# Epoch 395/1000
#  - 5s - loss: 0.0388 - accuracy: 0.9877 - val_loss: 0.3072 - val_accuracy: 0.5225
#
# Epoch 00395: val_loss did not improve from 0.02027
# Epoch 396/1000
#  - 5s - loss: 0.0353 - accuracy: 0.9903 - val_loss: 2.7307 - val_accuracy: 0.5201
#
# Epoch 00396: val_loss did not improve from 0.02027
# Epoch 397/1000
#  - 5s - loss: 0.0282 - accuracy: 0.9934 - val_loss: 2.6220 - val_accuracy: 0.5256
#
# Epoch 00397: val_loss did not improve from 0.02027
# Epoch 398/1000
#  - 5s - loss: 0.0271 - accuracy: 0.9929 - val_loss: 7.7327 - val_accuracy: 0.5232
#
# Epoch 00398: val_loss did not improve from 0.02027
# Epoch 399/1000
#  - 5s - loss: 0.0294 - accuracy: 0.9921 - val_loss: 3.5665 - val_accuracy: 0.5296
#
# Epoch 00399: val_loss did not improve from 0.02027
# Epoch 400/1000
#  - 5s - loss: 0.0286 - accuracy: 0.9929 - val_loss: 0.6411 - val_accuracy: 0.5154
#
# Epoch 00400: val_loss did not improve from 0.02027
# Epoch 401/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-b9d396ecb92b> in <module>()
#      41                     validation_data=val_flow,
#      42                     validation_steps=len(x_val) / batch_size,
# ---> 43                     shuffle=False)
#
# /tensorflow-1.15.2/python3.7/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /tensorflow-1.15.2/python3.7/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /tensorflow-1.15.2/python3.7/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# /tensorflow-1.15.2/python3.7/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
# model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_ex_02008.h5'
# model_name = 'classifier_45_close_updown_pr_theta.h5'
# model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_0002.h5'

model = keras.models.load_model(ckpt_path + model_name)

# %%
org_x_test = x_test
org_y_test = y_test
org_pr_test = pr_test

# %%
concat_x = np.vstack((org_x_test, new_input_x))
concat_y = np.vstack((org_y_test, np.where(new_input_pr > 1, 1, 0)))
concat_pr = np.vstack((org_pr_test, new_input_pr))

# %%
# x_test = new_input_x
# y_test = np.where(new_input_pr > 1, 1, 0)
# pr_test = new_input_pr

# x_test = org_x_test
# y_test = org_y_test
# pr_test = org_pr_test

# x_test = x_train
# y_test = y_train
# pr_test = pr_train

# x_test = x_val
# y_test = y_val
# pr_test = pr_val

# x_test = concat_x
# y_test = np.where(concat_pr > 1, 1, 0)
# pr_test = concat_pr

test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  if thresh < 0.6:
      continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  print('precision :', precision_score(y_test, y_pred))
  print('recall :', recall_score(y_test, y_pred))
  print()

  print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # plt.show()  
  print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
    print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
    print('thresh :', thresh)
    
  # if len(threshold) == 1:
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(test_pr_list))
    plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
  # plt.show()

    plt.subplot(122)
    plt.plot(np.cumprod(pred_pr_list))
    plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    plt.axvline(len(org_pr_test), linestyle='--', color='r')
    plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()
# Out:
# test_result.shape : (5076, 2)
# pr_val.shape : (1269, 1)
# y_test[:5] : [1 1 1 0 1]
# y_score[:5] : [[0.63109666]
#  [0.95781577]
#  [0.08306561]
#  [0.4201619 ]
#  [0.8793043 ]]
# y_test.shape : (5076, 1)
# y_score.shape : (5076, 1)
# len(y_test) : 5076
# y_pred.shape : (5076,)
# precision : 0.4700352526439483
# recall : 0.348280365694384
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 0.0
# win ratio improvement 0.45 --> 0.47
# accum_pr increased ! : 0.000 --> 0.000
# thresh : 0.65
# acc_pr_bythr : [0.00025347236]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-a6d3591e8ee6> in <module>()
#     123 plt.figure(figsize=(10, 5))
#     124 plt.subplot(121)
# --> 125 plt.plot(threshold, precision, label='precision')
#     126 plt.plot(threshold, recall, label='recall')
#     127 plt.legend()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (5076,)

# %%
plt.figure(figsize=(50, 5))
plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test):len(org_pr_test) + 10])
# plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test) - 10:len(org_pr_test) + 10])
plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
# plt.axvline(len(org_pr_test), linestyle='--', color='r')
plt.show()

# %%
# plt.show()
# plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
