# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    # long_ep = predictions[i]
    long_ep = (predictions[i] - err_ranges[i]) * (1 / (1 + tp))

    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = predictions[i]
    # short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    # net = layers.LSTM(32, return_sequences=False)(visible)
    net = layers.LSTM(10, return_sequences=False)(visible)

    # net = layers.Dense(32)(visible)
    # net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    # net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)

    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    net = layers.Dense(128)(net)
    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(256)(net)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.BatchNormalization()(net)


    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    # net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dropout(0.3)(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight

from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

from funcs_indicator import *

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None

seed = 1
random_state = 201
np.random.seed(seed)

for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue


  # if '02-11' not in candis[i]:  # <-- 04-08 includes all timestamp range
  #   continue  

  # if 'eth'.upper() not in candis[i]:
  #   continue

  # if 'neo'.upper() not in candis[i]:
  #   continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  

    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      # ohlcv = load_dict[key]['ohlcv']

    if 'dot'.upper() not in key:
      continue
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))


    #       select timestamp range      #
    # time_index = ohlcv.index
    # total_stamp = list(map(lambda x: datetime.timestamp(x), time_index)) 

    # rm_index_amt = np.sum(np.array(total_stamp) < start_stamp)

    # ohlcv = ohlcv.iloc[rm_index_amt:]
    # print(ohlcv.head())

    # ohlcv = ohlcv.iloc[:-2603]  # exclude back_range
    # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.3)]  # exclude back_range
    # predictions = load_dict[key]['predictions']
    # err_ranges = load_dict[key]['err_ranges']
    print("ohlcv.index[0] :", ohlcv.index[0])
    print("ohlcv.index[-1] :", ohlcv.index[-1])

    predictions = ohlcv['close'].shift(1).values
    err_ranges = np.zeros_like(predictions)

    # leverage_list = profit_result_dict[key]['leverage_list']
    # temp_ap_list = list()
    # temp_pr_list = list()

    try:
      print('-------------- %s --------------' % key)
      result = get_back_result(ohlcv, predictions, err_ranges, tp=0.014, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
      # temp_ap_list.append(result[2])
      # temp_pr_list.append(result[3])

      # if round(leverage) == 1:
      #   temp_pr_list = result[3]
      pr_list = result[3][long_index]

    except Exception as e:
      print(e)
      break    


    
  # break
    #         clustering zone           #

    #       set data features : ohlc, v, ep
    time_index = ohlcv.index[-len(predictions):]

    sliced_ohlcv = ohlcv[-len(predictions):]

    #       scale with price    #
    ohlc = ohlcv.iloc[-len(predictions):, :4]      
    long_ep = np.array(predictions)
    long_ep = long_ep.reshape(-1, 1)
    ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
    sar = lucid_sar(sliced_ohlcv)
    ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
    senkou1, senkou2 = ichimoku(sliced_ohlcv)

    #     min max scale   #
    vol = sliced_ohlcv.iloc[-len(predictions):, [4]]

    #     scale with baseline   #
    #     방법 1. 전체 기간 min_max scaling   #
    cbo, ema_cbo = cct_bbo(sliced_ohlcv, 21, 13) 

    _, _, bbw = bb_width(sliced_ohlcv, 20, 2) 
    
    fish = fisher(sliced_ohlcv, 60)
    trix = trix_hist(sliced_ohlcv, 14, 1, 5) 
    rsi_ = rsi(sliced_ohlcv)
    macd_hist = macd(sliced_ohlcv)




    # ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
    # ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
    # ohlcv['body'] = ohlcv['close'] / ohlcv['open']
    # candle = ohlcv.iloc[-len(predictions):, -3:]


    print('len(ohlc) :', len(ohlc))
    print('long_ep.shape :', long_ep.shape)
    print('len(ha_ohlc) :', len(ha_ohlc))
    print('len(sar) :', len(sar))
    print('len(ema1) :', len(ema1))
    print('len(senkou1) :', len(senkou1))
    print('len(cbo) :', len(cbo))
    print('len(ema_cbo) :', len(ema_cbo))
    print('len(bbw) :', len(bbw))
    print('len(fish) :', len(fish))
    print('len(trix) :', len(trix))
    print('len(rsi_) :', len(rsi_))
    print('len(macd_hist) :', len(macd_hist))


    # break


    #       set params    #
    period = 45
    key_i = i

    # plt.plot(cbo)
    # plt.plot(bbw)
    plt.plot(fish, color='b')
    # plt.plot(trix)
    # plt.plot(rsi_)
    # plt.plot(macd_hist)
    plt.show()

    #      global scaling   #
    min_max = MinMaxScaler()
    cbo = min_max.fit_transform(cbo.values.reshape(-1, 1))
    ema_cbo = min_max.fit_transform(ema_cbo.values.reshape(-1, 1))
    bbw = min_max.fit_transform(bbw.values.reshape(-1, 1))
    fish = min_max.fit_transform(fish.values.reshape(-1, 1))
    trix = min_max.fit_transform(trix.values.reshape(-1, 1))
    rsi_ = min_max.fit_transform(rsi_.values.reshape(-1, 1))
    macd_hist = min_max.fit_transform(macd_hist.values.reshape(-1, 1))

    # plt.plot(cbo)
    # plt.plot(bbw)
    plt.plot(fish, color='r')
    # plt.plot(trix)
    # plt.plot(rsi_)
    # plt.plot(macd_hist)
    plt.show()
    # break

    plotting = True

    for trial_number in range(1):

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)      

          temp_close = min_max_scale(temp_ohlc[:, [3]])    

          price_data = np.hstack((temp_ohlc, temp_long_ep, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))

          temp_ohlc = temp_price_data[:, :4]
          temp_long_ep = temp_price_data[:, [4]]
          temp_ha_ohlc = temp_price_data[:, 5:9]
          temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2 = np.split(temp_price_data[:, 9:], 6, axis=1)

          if plotting:

            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          # temp_candle = candle.iloc[i - period : i].values

          temp_cbo = cbo[i - period : i]
          temp_ema_cbo = ema_cbo[i - period : i]
          temp_bbw = bbw[i - period : i]
          temp_fish = fish[i - period : i]
          temp_trix = trix[i - period : i]
          temp_rsi_ = rsi_[i - period : i]
          temp_macd_hist = macd_hist[i - period : i]

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          trial_list = [temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2,
                        temp_cbo, temp_ema_cbo, temp_bbw, temp_fish, temp_trix, temp_rsi_, temp_macd_hist]

          # trial_list = [temp_ohlc[:, [0], temp_ohlc[:, [1], temp_ohlc[:, [2], temp_ohlc[:, [3]], temp_vol, temp_ema_cbo]

          #                   feature selection                   #  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          temp_data = temp_ohlc[:, [3]]
          # temp_data = temp_close
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          #     only close    #
          # temp_data = temp_ohlc[:, [-1]]

          # temp_data = temp_ohlc

          #     only volume    #
          # temp_data = temp_vol

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :-1] = max_abs.fit_transform(temp_data[:, :-1])

          
          # min_max = MinMaxScaler()
          # temp_data = min_max.fit_transform(temp_data)

          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      # input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      # input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      # input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)

      
      # _, row, col, _ = input_x.shape
      _, row, col = input_x.shape

      #       split new test      #

      seed = 1
      random_state = 201
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split


      #         get unique timestamp      #
      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=True, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

  
      symbol_name = key.split(' ')[1].split('.')[0]

      x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_fishing_%s_timesplit.npy' % (period, symbol_name)
      np.save(x_save_path, x_train)
      np.save(x_save_path.replace('x_train', 'x_val'), x_val)
      np.save(x_save_path.replace('x_train', 'x_test'), x_test)
      # np.save(x_save_path.replace('x_train', 'new_input_x'), new_input_x)
      print('x series saved !')

      pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_fishing_%s_timesplit.npy' % (period, symbol_name)
      np.save(pr_save_path, pr_train)
      np.save(pr_save_path.replace('pr_train', 'pr_val'), pr_val)
      np.save(pr_save_path.replace('pr_train', 'pr_test'), pr_test)
      # np.save(pr_save_path.replace('pr_train', 'new_input_pr'), new_input_pr)
      print('pr series saved !')

      
      _, row, col, = x_train.shape

      #         pr label   #
      y_train = np.where(pr_train > 1, 1, 0)
      y_test = np.where(pr_test > 1, 1, 0)
      y_val = np.where(pr_val > 1, 1, 0)


      seed = 1
      random_state = 20
      np.random.seed(seed)
      # tf.random.set_seed(seed)

      #         up label      #
      # y_train = np.where(ud_train > 1, 1, 0)
      # y_test = np.where(ud_test > 1, 1, 0)
      # y_val = np.where(ud_val > 1, 1, 0)

      # print('pr_train[:5] :', pr_train[:5])
      # print('ud_train[:5] :', ud_train[:5])
      print('y_train[:5] :', y_train[:5])
      print('y_train.dtype :', y_train.dtype)

      print('x_train.shape :', x_train.shape)
      print('x_test.shape :', x_test.shape)
      print('x_val.shape :', x_val.shape)
      print('y_train.shape :', y_train.shape)
      print('y_test.shape :', y_test.shape)
      print('y_val.shape :', y_val.shape)

      def class_ratio(in_list):

        return in_list / in_list[1]

      print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
      print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
      print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

      label = y_train.reshape(-1, )
      class_weights = class_weight.compute_class_weight('balanced', 
                                                          classes=np.unique(label),
                                                          y=label)
      class_weights = dict(enumerate(class_weights))
      print('class_weights :', class_weights)

      # sample_weight = np.ones(shape=(len(y_train),))
      # sample_weight[(y_train == 1).reshape(-1,)] = 1.5
      # print('sample_weight[:20] :', sample_weight[:20])


      print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
      print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
      print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

      print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
      print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
      print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

      y_train_ohe = np_utils.to_categorical(y_train, num_classes)
      y_val_ohe = np_utils.to_categorical(y_val, num_classes)
      y_test_ohe = np_utils.to_categorical(y_test, num_classes)
      print('y_train_ohe.shape :', y_train_ohe.shape)
      print('y_val_ohe.shape :', y_val_ohe.shape)
      print('y_test_ohe.shape :', y_test_ohe.shape)


      ckpt_path = current_path + 'ckpt/'
      board_path = current_path + 'graph/'
      # model_name = 'classifier_%s_close_updown_pr_theta_shuffle_without_back_03.h5' % period
      # model_name = 'classifier_%s_close_updown_pr_theta_train_prevdata_005.h5' % period

      # model_name = 'classifier_%s_close_updown_pr_theta_train_evendata_shuffle2_300k.h5' % period
      # model_name = 'classifier_%s_lstm_close_updown_pr_neo_re_tf1_timesplit.h5' % period
      # model = keras.models.load_model(ckpt_path + model_name)

      batch_size = 16
      # _, row, col, = x_train.shape
      # print("row, col :", row, col)

      model = FER_Model(input_shape=(row, col))
      opt = Adam(lr=0.00001, decay=0.000005)
      # opt = Adam(lr=0.001, decay=0.0005)
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      # model_name = 'classifier_%s_close_updown_pr_all_pair_shuffle_300k_timesplit.h5' % period
      # model_name = 'classifier_%s_lstm_close_updown_pr_neo_re_tf1_timesplit.h5' % period
      # model_name = 'classifier_%s_lstm_close_updown_pr_eth_abs_timesplit.h5' % period
      # model_name = 'classifier_%s_lstm_close_updown_pr_neo_abs_timesplit.h5' % period
      model_name = 'classifier_%s_lstm_close_updown_pr_fishing_%s_timesplit.h5' % (period, symbol_name)



      checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
      checkpoint2 = TensorBoard(log_dir=board_path,
                                histogram_freq=0,
                                write_graph=True,
                                write_images=True)
      checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
      callbacks_list = [checkpoint, checkpoint2, checkpoint3]
      # callbacks_list = [checkpoint, checkpoint2]

      # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

      # we iterate 200 times over the entire training set
      num_epochs = 1000                    

      history = model.fit(x_train, y_train_ohe,
                          steps_per_epoch=int(len(x_train) / batch_size), 
                          epochs=num_epochs,  
                          verbose=2,  
                          callbacks=callbacks_list,
                          class_weight=class_weights,
                          validation_data=(x_val, y_val_ohe),  
                          validation_steps=int(len(x_val) / batch_size),
                          shuffle=False)
      
      ckpt_path = current_path + 'ckpt/'
      board_path = current_path + 'graph/'
      # model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_ex_02008.h5'
      # model_name = 'classifier_45_close_updown_pr_theta.h5'
      # model_name = 'classifier_45_close_updown_pr_theta_train_evendata_shuffle2_300k.h5'
      # model_name = 'classifier_45_lstm_close_updown_pr_neo_timesplit.h5'

      # model_name = 'classifier_45_lstm_close_updown_pr_eth_timesplit.h5'

      model = keras.models.load_model(ckpt_path + model_name)

      # x_test = new_input_x
      # y_test = np.where(new_input_pr > 1, 1, 0)
      # pr_test = new_input_pr

      # x_test = org_x_test
      # y_test = org_y_test
      # pr_test = org_pr_test

      # x_test = x_train
      # y_test = y_train
      # pr_test = pr_train

      # x_test = x_val
      # y_test = y_val
      # pr_test = pr_val

      # x_test = concat_x
      # y_test = np.where(concat_pr > 1, 1, 0)
      # pr_test = concat_pr

      test_result = model.predict(x_test)
      # test_result = model.predict(test_set)

      print('test_result.shape :', test_result.shape)
      # print('pr_val.shape :', pr_val.shape)

      y_score = test_result[:, [1]]
      print('y_test[:5] :', y_test.reshape(-1,)[:5])
      # print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
      print('y_score[:5] :', y_score[:5])
      # print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

      print('y_test.shape :', y_test.shape)
      print('y_score.shape :', y_score.shape)

      print('len(y_test) :', len(y_test))

      #     precision recall curve   #
      precision, recall, threshold = precision_recall_curve(y_test, y_score)
      precision, recall = precision[:-1], recall[:-1]

      plt.plot(threshold, precision, label='precision')
      plt.plot(threshold, recall, label='recall')
      plt.legend()
      plt.title('precision recall')
      plt.show()
      # print(y_pred)


      # threshold = [0.65]
      # print('threshold :', threshold)
      # break

      acc_pr_bythr = []
      new_thresh = []

      for thresh in threshold:
        
        # if thresh < 0.5:
        #     continue

        y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
        # print('y_pred.shape :', y_pred.shape)
        # print('y_pred :', y_pred)

        #     compare precision     #

        # print('precision :', precision_score(y_test, y_pred))
        # print('recall :', recall_score(y_test, y_pred))
        # print()

        # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
        # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

        # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
        # # plt.show()  
        # print()

        #     check win-ratio improvement     #
        cmat = confusion_matrix(y_test, y_pred)
        # print(cmat)
        # print(np.sum(cmat, axis=1))

        test_size = len(y_test)
        test_pr_list = pr_test
        # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

        org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
        ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
        # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

        # print('pr_test.shape :', pr_test.shape)

        # print(y_pred)
        # print(test_pr_list)
        pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
        pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
        pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
        # print('pred_pr_list.shape :', pred_pr_list.shape)

        # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
        #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
        #   print('thresh :', thresh)
          
        # if len(threshold) == 1:
      #   plt.figure(figsize=(10, 5))
      #   plt.subplot(121)
      #   plt.plot(np.cumprod(test_pr_list))
      #   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
      # # plt.show()

      #   plt.subplot(122)
      #   plt.plot(np.cumprod(pred_pr_list))
      #   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
      #   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
      #   plt.show()


        acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
        new_thresh.append(thresh)


      print('acc_pr_bythr :', acc_pr_bythr)

      plt.figure(figsize=(10, 5))
      plt.subplot(121)
      plt.plot(threshold, precision, label='precision')
      plt.plot(threshold, recall, label='recall')
      plt.legend()
      plt.title('precision recall')
      # plt.show()
      plt.subplot(122)
      plt.plot(new_thresh, acc_pr_bythr)
      plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
      plt.title(symbol_name)
      plt.show()


  # break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  try:
    if len(total_x) > 300000:
      break
  except:
    pass
# Out:
# start_stamp : 0
# len(ohlcv) : 11920
# ohlcv.index[0] : 2020-08-22 16:29:59.999000
# ohlcv.index[-1] : 2021-04-27 23:59:59.999000
# -------------- 2021-04-27 DOTUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:161: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:162: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:166: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# /content/drive/My Drive/Colab Notebooks/300/funcs_indicator.py:273: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlcv_df['up'] = np.where(ohlcv_df['close'].diff(1) > 0, ohlcv_df['close'].diff(1), 0)
# /content/drive/My Drive/Colab Notebooks/300/funcs_indicator.py:274: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ohlcv_df['down'] = np.where(ohlcv_df['close'].diff(1) < 0, ohlcv_df['close'].diff(1) * (-1), 0)
# len(ohlc) : 11920
# long_ep.shape : (11920, 1)
# len(ha_ohlc) : 11920
# len(sar) : 11920
# len(ema1) : 11920
# len(senkou1) : 11920
# len(cbo) : 11920
# len(ema_cbo) : 11920
# len(bbw) : 11920
# len(fish) : 11920
# len(trix) : 11920
# len(rsi_) : 11920
# len(macd_hist) : 11920
# np.array(data_x).shape : (2055, 45, 1)
# input_x.shape : (2055, 45, 1)
# input_x.dtype : float32
# input_pr.shape : (2055, 1)
# input_ud.shape : (2055, 1)
# input_index.shape : (2055, 1)
# total_x.shape : (2055, 45, 1)
# total_pr.shape : (2055, 1)
# total_ud.shape : (2055, 1)
# prev_index.shape : (2055, 1)
# (array([Timestamp('2020-08-25 05:29:59.999000'),
#        Timestamp('2020-08-25 06:29:59.999000'),
#        Timestamp('2020-08-25 06:59:59.999000'), ...,
#        Timestamp('2021-04-27 12:29:59.999000'),
#        Timestamp('2021-04-27 21:59:59.999000'),
#        Timestamp('2021-04-27 23:29:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (1233,)
# stamp_val.shape : (411,)
# stamp_test.shape : (411,)
# HBox(children=(FloatProgress(value=0.0, max=2055.0), HTML(value='')))
# x_train.shape : (1233, 45, 1)
# x_val.shape : (411, 45, 1)
# x_test.shape : (411, 45, 1)
# x series saved !
# pr series saved !
# y_train[:5] : [[1]
#  [1]
#  [1]
#  [0]
#  [0]]
# y_train.dtype : int64
# x_train.shape : (1233, 45, 1)
# x_test.shape : (411, 45, 1)
# x_val.shape : (411, 45, 1)
# y_train.shape : (1233, 1)
# y_test.shape : (411, 1)
# y_val.shape : (411, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([540, 693])) [0.77922078 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([190, 221])) [0.85972851 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([193, 218])) [0.8853211 1.       ]
# class_weights : {0: 1.1416666666666666, 1: 0.8896103896103896}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (1233, 2)
# y_val_ohe.shape : (411, 2)
# y_test_ohe.shape : (411, 2)
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 45, 1)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10)                480
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                704
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 130
# =================================================================
# Total params: 85,090
# Trainable params: 84,450
# Non-trainable params: 640
# _________________________________________________________________
# None
# Train on 1233 samples, validate on 411 samples
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/1000
#  - 4s - loss: 0.7715 - accuracy: 0.5092 - val_loss: 0.0278 - val_accuracy: 11.5572
#
# Epoch 00001: val_loss improved from inf to 0.02775, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_lstm_close_updown_pr_fishing_DOTUSDT_timesplit.h5
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/1000
#  - 2s - loss: 0.7272 - accuracy: 0.5086 - val_loss: 0.0279 - val_accuracy: 11.5572
#
# Epoch 00002: val_loss did not improve from 0.02775
# Epoch 3/1000
#  - 3s - loss: 0.7097 - accuracy: 0.5177 - val_loss: 0.0280 - val_accuracy: 11.5572
#
# Epoch 00003: val_loss did not improve from 0.02775
# Epoch 4/1000
#  - 2s - loss: 0.7014 - accuracy: 0.5241 - val_loss: 0.0280 - val_accuracy: 11.5572
#
# Epoch 00004: val_loss did not improve from 0.02775
# Epoch 5/1000
#  - 2s - loss: 0.6952 - accuracy: 0.5300 - val_loss: 0.0280 - val_accuracy: 12.5304
#
# Epoch 00005: val_loss did not improve from 0.02775
# Epoch 6/1000
#  - 2s - loss: 0.6920 - accuracy: 0.5337 - val_loss: 0.0278 - val_accuracy: 12.7737
#
# Epoch 00006: val_loss did not improve from 0.02775
# Epoch 7/1000
#  - 2s - loss: 0.6891 - accuracy: 0.5401 - val_loss: 0.0278 - val_accuracy: 12.5912
#
# Epoch 00007: val_loss did not improve from 0.02775
# Epoch 8/1000
#  - 2s - loss: 0.6871 - accuracy: 0.5447 - val_loss: 0.0278 - val_accuracy: 13.3820
#
# Epoch 00008: val_loss did not improve from 0.02775
# Epoch 9/1000
#  - 2s - loss: 0.6854 - accuracy: 0.5483 - val_loss: 0.0278 - val_accuracy: 13.6253
#
# Epoch 00009: val_loss did not improve from 0.02775
# Epoch 10/1000
#  - 2s - loss: 0.6839 - accuracy: 0.5516 - val_loss: 0.0278 - val_accuracy: 13.4428
#
# Epoch 00010: val_loss did not improve from 0.02775
# Epoch 11/1000
#  - 2s - loss: 0.6832 - accuracy: 0.5535 - val_loss: 0.0278 - val_accuracy: 13.3820
#
# Epoch 00011: val_loss did not improve from 0.02775
# Epoch 12/1000
#  - 2s - loss: 0.6822 - accuracy: 0.5555 - val_loss: 0.0279 - val_accuracy: 13.6253
#
# Epoch 00012: val_loss did not improve from 0.02775
# Epoch 13/1000
#  - 2s - loss: 0.6816 - accuracy: 0.5569 - val_loss: 0.0279 - val_accuracy: 13.5645
#
# Epoch 00013: val_loss did not improve from 0.02775
# Epoch 14/1000
#  - 2s - loss: 0.6805 - accuracy: 0.5613 - val_loss: 0.0279 - val_accuracy: 13.4428
#
# Epoch 00014: val_loss did not improve from 0.02775
# Epoch 15/1000
#  - 2s - loss: 0.6793 - accuracy: 0.5643 - val_loss: 0.0279 - val_accuracy: 13.5645
#
# Epoch 00015: val_loss did not improve from 0.02775
# Epoch 16/1000
#  - 3s - loss: 0.6790 - accuracy: 0.5630 - val_loss: 0.0279 - val_accuracy: 13.6861
#
# Epoch 00016: val_loss did not improve from 0.02775
# Epoch 17/1000
#  - 3s - loss: 0.6776 - accuracy: 0.5655 - val_loss: 0.0279 - val_accuracy: 13.5645
#
# Epoch 00017: val_loss did not improve from 0.02775
# Epoch 18/1000
#  - 2s - loss: 0.6772 - accuracy: 0.5690 - val_loss: 0.0279 - val_accuracy: 13.5645
#
# Epoch 00018: val_loss did not improve from 0.02775
# Epoch 19/1000
#  - 2s - loss: 0.6768 - accuracy: 0.5701 - val_loss: 0.0279 - val_accuracy: 13.4428
#
# Epoch 00019: val_loss did not improve from 0.02775
# Epoch 20/1000
#  - 3s - loss: 0.6760 - accuracy: 0.5711 - val_loss: 0.0279 - val_accuracy: 13.5036
#
# Epoch 00020: val_loss did not improve from 0.02775
# Epoch 21/1000
#  - 2s - loss: 0.6756 - accuracy: 0.5739 - val_loss: 0.0279 - val_accuracy: 13.6253
#
# Epoch 00021: val_loss did not improve from 0.02775
# Epoch 22/1000
#  - 2s - loss: 0.6745 - accuracy: 0.5748 - val_loss: 0.0279 - val_accuracy: 13.5036
#
# Epoch 00022: val_loss did not improve from 0.02775
# Epoch 23/1000
#  - 2s - loss: 0.6739 - accuracy: 0.5776 - val_loss: 0.0279 - val_accuracy: 13.5645
#
# Epoch 00023: val_loss did not improve from 0.02775
# Epoch 24/1000
#  - 2s - loss: 0.6726 - accuracy: 0.5802 - val_loss: 0.0279 - val_accuracy: 13.6253
#
# Epoch 00024: val_loss did not improve from 0.02775
# Epoch 25/1000
#  - 2s - loss: 0.6724 - accuracy: 0.5792 - val_loss: 0.0280 - val_accuracy: 13.3212
#
# Epoch 00025: val_loss did not improve from 0.02775
# Epoch 26/1000
#  - 2s - loss: 0.6724 - accuracy: 0.5808 - val_loss: 0.0279 - val_accuracy: 13.4428
#
# Epoch 00026: val_loss did not improve from 0.02775
# Epoch 27/1000
#  - 3s - loss: 0.6717 - accuracy: 0.5823 - val_loss: 0.0280 - val_accuracy: 13.1387
#
# Epoch 00027: val_loss did not improve from 0.02775
# Epoch 28/1000
#  - 3s - loss: 0.6708 - accuracy: 0.5836 - val_loss: 0.0280 - val_accuracy: 13.0779
#
# Epoch 00028: val_loss did not improve from 0.02775
# Epoch 29/1000
#  - 3s - loss: 0.6699 - accuracy: 0.5872 - val_loss: 0.0280 - val_accuracy: 13.1387
#
# Epoch 00029: val_loss did not improve from 0.02775
# Epoch 30/1000
#  - 3s - loss: 0.6690 - accuracy: 0.5903 - val_loss: 0.0280 - val_accuracy: 12.9562
#
# Epoch 00030: val_loss did not improve from 0.02775
# Epoch 31/1000
#  - 3s - loss: 0.6688 - accuracy: 0.5899 - val_loss: 0.0281 - val_accuracy: 12.5912
#
# Epoch 00031: val_loss did not improve from 0.02775
# Epoch 32/1000
#  - 3s - loss: 0.6681 - accuracy: 0.5903 - val_loss: 0.0280 - val_accuracy: 12.8954
#
# Epoch 00032: val_loss did not improve from 0.02775
# Epoch 33/1000
#  - 3s - loss: 0.6673 - accuracy: 0.5943 - val_loss: 0.0281 - val_accuracy: 12.8346
#
# Epoch 00033: val_loss did not improve from 0.02775
# Epoch 34/1000
#  - 2s - loss: 0.6668 - accuracy: 0.5953 - val_loss: 0.0281 - val_accuracy: 12.8954
#
# Epoch 00034: val_loss did not improve from 0.02775
# Epoch 35/1000
#  - 2s - loss: 0.6658 - accuracy: 0.5983 - val_loss: 0.0281 - val_accuracy: 12.3479
#
# Epoch 00035: val_loss did not improve from 0.02775
# Epoch 36/1000
#  - 2s - loss: 0.6653 - accuracy: 0.5988 - val_loss: 0.0280 - val_accuracy: 12.8346
#
# Epoch 00036: val_loss did not improve from 0.02775
# Epoch 37/1000
#  - 2s - loss: 0.6648 - accuracy: 0.5988 - val_loss: 0.0281 - val_accuracy: 13.0170
#
# Epoch 00037: val_loss did not improve from 0.02775
# Epoch 38/1000
#  - 2s - loss: 0.6646 - accuracy: 0.5974 - val_loss: 0.0281 - val_accuracy: 12.5304
#
# Epoch 00038: val_loss did not improve from 0.02775
# Epoch 39/1000
#  - 2s - loss: 0.6636 - accuracy: 0.6021 - val_loss: 0.0282 - val_accuracy: 12.4696
#
# Epoch 00039: val_loss did not improve from 0.02775
# Epoch 40/1000
#  - 3s - loss: 0.6631 - accuracy: 0.6017 - val_loss: 0.0281 - val_accuracy: 12.5304
#
# Epoch 00040: val_loss did not improve from 0.02775
# Epoch 41/1000
#  - 2s - loss: 0.6627 - accuracy: 0.6020 - val_loss: 0.0282 - val_accuracy: 12.6521
#
# Epoch 00041: val_loss did not improve from 0.02775
# Epoch 42/1000
#  - 3s - loss: 0.6621 - accuracy: 0.6036 - val_loss: 0.0282 - val_accuracy: 12.7737
#
# Epoch 00042: val_loss did not improve from 0.02775
# Epoch 43/1000
#  - 2s - loss: 0.6615 - accuracy: 0.6032 - val_loss: 0.0282 - val_accuracy: 12.4696
#
# Epoch 00043: val_loss did not improve from 0.02775
# Epoch 44/1000
#  - 2s - loss: 0.6608 - accuracy: 0.6055 - val_loss: 0.0282 - val_accuracy: 12.5304
#
# Epoch 00044: val_loss did not improve from 0.02775
# Epoch 45/1000
#  - 2s - loss: 0.6606 - accuracy: 0.6044 - val_loss: 0.0282 - val_accuracy: 12.2871
#
# Epoch 00045: val_loss did not improve from 0.02775
# Epoch 46/1000
#  - 2s - loss: 0.6598 - accuracy: 0.6061 - val_loss: 0.0282 - val_accuracy: 12.5304
#
# Epoch 00046: val_loss did not improve from 0.02775
# Epoch 47/1000
#  - 2s - loss: 0.6588 - accuracy: 0.6093 - val_loss: 0.0282 - val_accuracy: 12.7129
#
# Epoch 00047: val_loss did not improve from 0.02775
# Epoch 48/1000
#  - 2s - loss: 0.6585 - accuracy: 0.6092 - val_loss: 0.0282 - val_accuracy: 12.7129
#
# Epoch 00048: val_loss did not improve from 0.02775
# Epoch 49/1000
#  - 2s - loss: 0.6576 - accuracy: 0.6111 - val_loss: 0.0283 - val_accuracy: 12.6521
#
# Epoch 00049: val_loss did not improve from 0.02775
# Epoch 50/1000
#  - 2s - loss: 0.6571 - accuracy: 0.6107 - val_loss: 0.0283 - val_accuracy: 12.8954
#
# Epoch 00050: val_loss did not improve from 0.02775
# Epoch 51/1000
#  - 3s - loss: 0.6569 - accuracy: 0.6098 - val_loss: 0.0283 - val_accuracy: 12.9562
#
# Epoch 00051: val_loss did not improve from 0.02775
# Epoch 52/1000
#  - 3s - loss: 0.6559 - accuracy: 0.6122 - val_loss: 0.0284 - val_accuracy: 12.8954
#
# Epoch 00052: val_loss did not improve from 0.02775
# Epoch 53/1000
#  - 2s - loss: 0.6550 - accuracy: 0.6140 - val_loss: 0.0284 - val_accuracy: 13.0779
#
# Epoch 00053: val_loss did not improve from 0.02775
# Epoch 54/1000
#  - 2s - loss: 0.6548 - accuracy: 0.6127 - val_loss: 0.0283 - val_accuracy: 13.0170
#
# Epoch 00054: val_loss did not improve from 0.02775
# Epoch 55/1000
#  - 3s - loss: 0.6540 - accuracy: 0.6158 - val_loss: 0.0284 - val_accuracy: 12.8346
#
# Epoch 00055: val_loss did not improve from 0.02775
# Epoch 56/1000
#  - 3s - loss: 0.6528 - accuracy: 0.6162 - val_loss: 0.0284 - val_accuracy: 12.8954
#
# Epoch 00056: val_loss did not improve from 0.02775
# Epoch 57/1000
#  - 2s - loss: 0.6528 - accuracy: 0.6162 - val_loss: 0.0284 - val_accuracy: 12.7129
#
# Epoch 00057: val_loss did not improve from 0.02775
# Epoch 58/1000
#  - 2s - loss: 0.6513 - accuracy: 0.6170 - val_loss: 0.0284 - val_accuracy: 13.0170
#
# Epoch 00058: val_loss did not improve from 0.02775
# Epoch 59/1000
#  - 2s - loss: 0.6508 - accuracy: 0.6181 - val_loss: 0.0285 - val_accuracy: 12.7737
#
# Epoch 00059: val_loss did not improve from 0.02775
# Epoch 60/1000
#  - 2s - loss: 0.6506 - accuracy: 0.6193 - val_loss: 0.0284 - val_accuracy: 13.1387
#
# Epoch 00060: val_loss did not improve from 0.02775
# Epoch 61/1000
#  - 2s - loss: 0.6496 - accuracy: 0.6186 - val_loss: 0.0285 - val_accuracy: 12.4696
#
# Epoch 00061: val_loss did not improve from 0.02775
# Epoch 62/1000
#  - 2s - loss: 0.6493 - accuracy: 0.6196 - val_loss: 0.0285 - val_accuracy: 12.6521
#
# Epoch 00062: val_loss did not improve from 0.02775
# Epoch 63/1000
#  - 2s - loss: 0.6483 - accuracy: 0.6221 - val_loss: 0.0285 - val_accuracy: 12.8954
#
# Epoch 00063: val_loss did not improve from 0.02775
# Epoch 64/1000
#  - 2s - loss: 0.6473 - accuracy: 0.6211 - val_loss: 0.0285 - val_accuracy: 12.5304
#
# Epoch 00064: val_loss did not improve from 0.02775
# Epoch 65/1000
#  - 2s - loss: 0.6467 - accuracy: 0.6212 - val_loss: 0.0286 - val_accuracy: 13.0779
#
# Epoch 00065: val_loss did not improve from 0.02775
# Epoch 66/1000
#  - 2s - loss: 0.6464 - accuracy: 0.6229 - val_loss: 0.0286 - val_accuracy: 12.5912
#
# Epoch 00066: val_loss did not improve from 0.02775
# Epoch 67/1000
#  - 2s - loss: 0.6458 - accuracy: 0.6238 - val_loss: 0.0286 - val_accuracy: 12.4696
#
# Epoch 00067: val_loss did not improve from 0.02775
# Epoch 68/1000
#  - 2s - loss: 0.6449 - accuracy: 0.6239 - val_loss: 0.0286 - val_accuracy: 12.6521
#
# Epoch 00068: val_loss did not improve from 0.02775
# Epoch 69/1000
#  - 3s - loss: 0.6446 - accuracy: 0.6236 - val_loss: 0.0287 - val_accuracy: 12.8346
#
# Epoch 00069: val_loss did not improve from 0.02775
# Epoch 70/1000
#  - 2s - loss: 0.6438 - accuracy: 0.6254 - val_loss: 0.0287 - val_accuracy: 12.7129
#
# Epoch 00070: val_loss did not improve from 0.02775
# Epoch 71/1000
#  - 2s - loss: 0.6427 - accuracy: 0.6262 - val_loss: 0.0287 - val_accuracy: 12.7737
#
# Epoch 00071: val_loss did not improve from 0.02775
# Epoch 72/1000
#  - 2s - loss: 0.6418 - accuracy: 0.6275 - val_loss: 0.0288 - val_accuracy: 12.6521
#
# Epoch 00072: val_loss did not improve from 0.02775
# Epoch 73/1000
#  - 3s - loss: 0.6414 - accuracy: 0.6279 - val_loss: 0.0288 - val_accuracy: 12.7129
#
# Epoch 00073: val_loss did not improve from 0.02775
# Epoch 74/1000
#  - 2s - loss: 0.6405 - accuracy: 0.6285 - val_loss: 0.0288 - val_accuracy: 12.5912
#
# Epoch 00074: val_loss did not improve from 0.02775
# Epoch 75/1000
#  - 2s - loss: 0.6401 - accuracy: 0.6288 - val_loss: 0.0288 - val_accuracy: 12.6521
#
# Epoch 00075: val_loss did not improve from 0.02775
# Epoch 76/1000
#  - 3s - loss: 0.6385 - accuracy: 0.6310 - val_loss: 0.0289 - val_accuracy: 12.6521
#
# Epoch 00076: val_loss did not improve from 0.02775
# Epoch 77/1000
#  - 3s - loss: 0.6384 - accuracy: 0.6297 - val_loss: 0.0289 - val_accuracy: 12.6521
#
# Epoch 00077: val_loss did not improve from 0.02775
# Epoch 78/1000
#  - 2s - loss: 0.6374 - accuracy: 0.6329 - val_loss: 0.0289 - val_accuracy: 12.5912
#
# Epoch 00078: val_loss did not improve from 0.02775
# Epoch 79/1000
#  - 3s - loss: 0.6372 - accuracy: 0.6317 - val_loss: 0.0289 - val_accuracy: 12.5912
#
# Epoch 00079: val_loss did not improve from 0.02775
# Epoch 80/1000
#  - 3s - loss: 0.6359 - accuracy: 0.6336 - val_loss: 0.0289 - val_accuracy: 12.9562
#
# Epoch 00080: val_loss did not improve from 0.02775
# Epoch 81/1000
#  - 2s - loss: 0.6355 - accuracy: 0.6330 - val_loss: 0.0290 - val_accuracy: 12.7129
#
# Epoch 00081: val_loss did not improve from 0.02775
# Epoch 82/1000
#  - 3s - loss: 0.6348 - accuracy: 0.6338 - val_loss: 0.0290 - val_accuracy: 12.7129
#
# Epoch 00082: val_loss did not improve from 0.02775
# Epoch 83/1000
#  - 2s - loss: 0.6337 - accuracy: 0.6339 - val_loss: 0.0290 - val_accuracy: 12.4088
#
# Epoch 00083: val_loss did not improve from 0.02775
# Epoch 84/1000
#  - 2s - loss: 0.6334 - accuracy: 0.6335 - val_loss: 0.0290 - val_accuracy: 13.0170
#
# Epoch 00084: val_loss did not improve from 0.02775
# Epoch 85/1000
#  - 2s - loss: 0.6327 - accuracy: 0.6358 - val_loss: 0.0291 - val_accuracy: 12.5304
#
# Epoch 00085: val_loss did not improve from 0.02775
# Epoch 86/1000
#  - 2s - loss: 0.6319 - accuracy: 0.6354 - val_loss: 0.0291 - val_accuracy: 13.0779
#
# Epoch 00086: val_loss did not improve from 0.02775
# Epoch 87/1000
#  - 2s - loss: 0.6310 - accuracy: 0.6380 - val_loss: 0.0291 - val_accuracy: 12.5912
#
# Epoch 00087: val_loss did not improve from 0.02775
# Epoch 88/1000
#  - 3s - loss: 0.6295 - accuracy: 0.6380 - val_loss: 0.0292 - val_accuracy: 12.5912
#
# Epoch 00088: val_loss did not improve from 0.02775
# Epoch 89/1000
#  - 3s - loss: 0.6292 - accuracy: 0.6391 - val_loss: 0.0292 - val_accuracy: 12.7737
#
# Epoch 00089: val_loss did not improve from 0.02775
# Epoch 90/1000
#  - 2s - loss: 0.6287 - accuracy: 0.6397 - val_loss: 0.0293 - val_accuracy: 12.2871
#
# Epoch 00090: val_loss did not improve from 0.02775
# Epoch 91/1000
#  - 2s - loss: 0.6277 - accuracy: 0.6402 - val_loss: 0.0293 - val_accuracy: 12.4088
#
# Epoch 00091: val_loss did not improve from 0.02775
# Epoch 92/1000
#  - 2s - loss: 0.6266 - accuracy: 0.6419 - val_loss: 0.0293 - val_accuracy: 12.8954
#
# Epoch 00092: val_loss did not improve from 0.02775
# Epoch 93/1000
#  - 2s - loss: 0.6257 - accuracy: 0.6411 - val_loss: 0.0293 - val_accuracy: 12.4088
#
# Epoch 00093: val_loss did not improve from 0.02775
# Epoch 94/1000
#  - 2s - loss: 0.6251 - accuracy: 0.6421 - val_loss: 0.0294 - val_accuracy: 12.4088
#
# Epoch 00094: val_loss did not improve from 0.02775
# Epoch 95/1000
#  - 2s - loss: 0.6245 - accuracy: 0.6421 - val_loss: 0.0294 - val_accuracy: 12.4088
#
# Epoch 00095: val_loss did not improve from 0.02775
# Epoch 96/1000
#  - 2s - loss: 0.6243 - accuracy: 0.6429 - val_loss: 0.0296 - val_accuracy: 12.7737
#
# Epoch 00096: val_loss did not improve from 0.02775
# Epoch 97/1000
#  - 2s - loss: 0.6235 - accuracy: 0.6458 - val_loss: 0.0295 - val_accuracy: 12.5304
#
# Epoch 00097: val_loss did not improve from 0.02775
# Epoch 98/1000
#  - 2s - loss: 0.6223 - accuracy: 0.6440 - val_loss: 0.0295 - val_accuracy: 12.5304
#
# Epoch 00098: val_loss did not improve from 0.02775
# Epoch 99/1000
#  - 2s - loss: 0.6208 - accuracy: 0.6466 - val_loss: 0.0294 - val_accuracy: 13.1387
#
# Epoch 00099: val_loss did not improve from 0.02775
# Epoch 100/1000
#  - 2s - loss: 0.6203 - accuracy: 0.6473 - val_loss: 0.0295 - val_accuracy: 12.7129
#
# Epoch 00100: val_loss did not improve from 0.02775
# Epoch 101/1000
#  - 2s - loss: 0.6195 - accuracy: 0.6481 - val_loss: 0.0296 - val_accuracy: 12.8954
#
# Epoch 00101: val_loss did not improve from 0.02775
# Epoch 102/1000
#  - 2s - loss: 0.6190 - accuracy: 0.6495 - val_loss: 0.0297 - val_accuracy: 12.3479
#
# Epoch 00102: val_loss did not improve from 0.02775
# Epoch 103/1000
#  - 2s - loss: 0.6172 - accuracy: 0.6508 - val_loss: 0.0297 - val_accuracy: 12.5304
#
# Epoch 00103: val_loss did not improve from 0.02775
# Epoch 104/1000
#  - 2s - loss: 0.6163 - accuracy: 0.6501 - val_loss: 0.0298 - val_accuracy: 12.4088
#
# Epoch 00104: val_loss did not improve from 0.02775
# Epoch 105/1000
#  - 2s - loss: 0.6159 - accuracy: 0.6523 - val_loss: 0.0299 - val_accuracy: 12.5304
#
# Epoch 00105: val_loss did not improve from 0.02775
# Epoch 106/1000
#  - 3s - loss: 0.6148 - accuracy: 0.6522 - val_loss: 0.0299 - val_accuracy: 12.4696
#
# Epoch 00106: val_loss did not improve from 0.02775
# Epoch 107/1000
#  - 3s - loss: 0.6141 - accuracy: 0.6510 - val_loss: 0.0298 - val_accuracy: 12.7129
#
# Epoch 00107: val_loss did not improve from 0.02775
# Epoch 108/1000
#  - 3s - loss: 0.6130 - accuracy: 0.6520 - val_loss: 0.0298 - val_accuracy: 12.4088
#
# Epoch 00108: val_loss did not improve from 0.02775
# Epoch 109/1000
#  - 3s - loss: 0.6128 - accuracy: 0.6542 - val_loss: 0.0298 - val_accuracy: 12.7129
#
# Epoch 00109: val_loss did not improve from 0.02775
# Epoch 110/1000
#  - 2s - loss: 0.6112 - accuracy: 0.6549 - val_loss: 0.0299 - val_accuracy: 12.2263
#
# Epoch 00110: val_loss did not improve from 0.02775
# Epoch 111/1000
#  - 2s - loss: 0.6104 - accuracy: 0.6559 - val_loss: 0.0300 - val_accuracy: 12.5304
#
# Epoch 00111: val_loss did not improve from 0.02775
# Epoch 112/1000
#  - 3s - loss: 0.6092 - accuracy: 0.6578 - val_loss: 0.0300 - val_accuracy: 12.5912
#
# Epoch 00112: val_loss did not improve from 0.02775
# Epoch 113/1000
#  - 3s - loss: 0.6091 - accuracy: 0.6570 - val_loss: 0.0300 - val_accuracy: 12.8346
#
# Epoch 00113: val_loss did not improve from 0.02775
# Epoch 114/1000
#  - 2s - loss: 0.6074 - accuracy: 0.6575 - val_loss: 0.0301 - val_accuracy: 12.7129
#
# Epoch 00114: val_loss did not improve from 0.02775
# Epoch 115/1000
#  - 2s - loss: 0.6070 - accuracy: 0.6595 - val_loss: 0.0301 - val_accuracy: 12.5912
#
# Epoch 00115: val_loss did not improve from 0.02775
# Epoch 116/1000
#  - 2s - loss: 0.6058 - accuracy: 0.6608 - val_loss: 0.0301 - val_accuracy: 13.0779
#
# Epoch 00116: val_loss did not improve from 0.02775
# Epoch 117/1000
#  - 2s - loss: 0.6046 - accuracy: 0.6630 - val_loss: 0.0301 - val_accuracy: 12.8346
#
# Epoch 00117: val_loss did not improve from 0.02775
# Epoch 118/1000
#  - 2s - loss: 0.6038 - accuracy: 0.6611 - val_loss: 0.0302 - val_accuracy: 12.2263
#
# Epoch 00118: val_loss did not improve from 0.02775
# Epoch 119/1000
#  - 3s - loss: 0.6032 - accuracy: 0.6619 - val_loss: 0.0302 - val_accuracy: 12.4696
#
# Epoch 00119: val_loss did not improve from 0.02775
# Epoch 120/1000
#  - 2s - loss: 0.6025 - accuracy: 0.6621 - val_loss: 0.0304 - val_accuracy: 12.5304
#
# Epoch 00120: val_loss did not improve from 0.02775
# Epoch 121/1000
#  - 3s - loss: 0.6019 - accuracy: 0.6642 - val_loss: 0.0305 - val_accuracy: 12.6521
#
# Epoch 00121: val_loss did not improve from 0.02775
# Epoch 122/1000
#  - 2s - loss: 0.6010 - accuracy: 0.6641 - val_loss: 0.0304 - val_accuracy: 12.3479
#
# Epoch 00122: val_loss did not improve from 0.02775
# Epoch 123/1000
#  - 2s - loss: 0.6001 - accuracy: 0.6652 - val_loss: 0.0304 - val_accuracy: 12.7737
#
# Epoch 00123: val_loss did not improve from 0.02775
# Epoch 124/1000
#  - 2s - loss: 0.5984 - accuracy: 0.6663 - val_loss: 0.0304 - val_accuracy: 12.5304
#
# Epoch 00124: val_loss did not improve from 0.02775
# Epoch 125/1000
#  - 2s - loss: 0.5973 - accuracy: 0.6666 - val_loss: 0.0304 - val_accuracy: 12.7737
#
# Epoch 00125: val_loss did not improve from 0.02775
# Epoch 126/1000
#  - 2s - loss: 0.5966 - accuracy: 0.6685 - val_loss: 0.0306 - val_accuracy: 12.7129
#
# Epoch 00126: val_loss did not improve from 0.02775
# Epoch 127/1000
#  - 2s - loss: 0.5956 - accuracy: 0.6675 - val_loss: 0.0306 - val_accuracy: 12.7737
#
# Epoch 00127: val_loss did not improve from 0.02775
# Epoch 128/1000
#  - 2s - loss: 0.5948 - accuracy: 0.6688 - val_loss: 0.0308 - val_accuracy: 12.5912
#
# Epoch 00128: val_loss did not improve from 0.02775
# Epoch 129/1000
#  - 2s - loss: 0.5943 - accuracy: 0.6704 - val_loss: 0.0309 - val_accuracy: 12.4696
#
# Epoch 00129: val_loss did not improve from 0.02775
# Epoch 130/1000
#  - 2s - loss: 0.5934 - accuracy: 0.6700 - val_loss: 0.0309 - val_accuracy: 12.5304
#
# Epoch 00130: val_loss did not improve from 0.02775
# Epoch 131/1000
#  - 2s - loss: 0.5919 - accuracy: 0.6720 - val_loss: 0.0309 - val_accuracy: 12.4088
#
# Epoch 00131: val_loss did not improve from 0.02775
# Epoch 132/1000
#  - 2s - loss: 0.5914 - accuracy: 0.6717 - val_loss: 0.0309 - val_accuracy: 12.3479
#
# Epoch 00132: val_loss did not improve from 0.02775
# Epoch 133/1000
#  - 2s - loss: 0.5910 - accuracy: 0.6711 - val_loss: 0.0308 - val_accuracy: 12.7737
#
# Epoch 00133: val_loss did not improve from 0.02775
# Epoch 134/1000
#  - 2s - loss: 0.5893 - accuracy: 0.6732 - val_loss: 0.0309 - val_accuracy: 12.3479
#
# Epoch 00134: val_loss did not improve from 0.02775
# Epoch 135/1000
#  - 3s - loss: 0.5881 - accuracy: 0.6750 - val_loss: 0.0309 - val_accuracy: 12.4088
#
# Epoch 00135: val_loss did not improve from 0.02775
# Epoch 136/1000
#  - 2s - loss: 0.5881 - accuracy: 0.6757 - val_loss: 0.0312 - val_accuracy: 12.4088
#
# Epoch 00136: val_loss did not improve from 0.02775
# Epoch 137/1000
#  - 3s - loss: 0.5871 - accuracy: 0.6750 - val_loss: 0.0310 - val_accuracy: 12.5912
#
# Epoch 00137: val_loss did not improve from 0.02775
# Epoch 138/1000
#  - 2s - loss: 0.5861 - accuracy: 0.6778 - val_loss: 0.0312 - val_accuracy: 12.4696
#
# Epoch 00138: val_loss did not improve from 0.02775
# Epoch 139/1000
#  - 3s - loss: 0.5839 - accuracy: 0.6780 - val_loss: 0.0310 - val_accuracy: 12.7737
#
# Epoch 00139: val_loss did not improve from 0.02775
# Epoch 140/1000
#  - 2s - loss: 0.5838 - accuracy: 0.6794 - val_loss: 0.0311 - val_accuracy: 12.7737
#
# Epoch 00140: val_loss did not improve from 0.02775
# Epoch 141/1000
#  - 3s - loss: 0.5823 - accuracy: 0.6803 - val_loss: 0.0311 - val_accuracy: 12.7737
#
# Epoch 00141: val_loss did not improve from 0.02775
# Epoch 142/1000
#  - 2s - loss: 0.5819 - accuracy: 0.6817 - val_loss: 0.0310 - val_accuracy: 12.8954
#
# Epoch 00142: val_loss did not improve from 0.02775
# Epoch 143/1000
#  - 2s - loss: 0.5808 - accuracy: 0.6805 - val_loss: 0.0311 - val_accuracy: 12.9562
#
# Epoch 00143: val_loss did not improve from 0.02775
# Epoch 144/1000
#  - 2s - loss: 0.5799 - accuracy: 0.6816 - val_loss: 0.0313 - val_accuracy: 12.5304
#
# Epoch 00144: val_loss did not improve from 0.02775
# Epoch 145/1000
#  - 2s - loss: 0.5787 - accuracy: 0.6833 - val_loss: 0.0315 - val_accuracy: 12.2871
#
# Epoch 00145: val_loss did not improve from 0.02775
# Epoch 146/1000
#  - 2s - loss: 0.5775 - accuracy: 0.6846 - val_loss: 0.0316 - val_accuracy: 12.7129
#
# Epoch 00146: val_loss did not improve from 0.02775
# Epoch 147/1000
#  - 2s - loss: 0.5777 - accuracy: 0.6841 - val_loss: 0.0316 - val_accuracy: 12.7129
#
# Epoch 00147: val_loss did not improve from 0.02775
# Epoch 148/1000
#  - 3s - loss: 0.5762 - accuracy: 0.6867 - val_loss: 0.0315 - val_accuracy: 12.8954
#
# Epoch 00148: val_loss did not improve from 0.02775
# Epoch 149/1000
#  - 3s - loss: 0.5752 - accuracy: 0.6866 - val_loss: 0.0316 - val_accuracy: 12.7129
#
# Epoch 00149: val_loss did not improve from 0.02775
# Epoch 150/1000
#  - 3s - loss: 0.5747 - accuracy: 0.6865 - val_loss: 0.0316 - val_accuracy: 12.5912
#
# Epoch 00150: val_loss did not improve from 0.02775
# Epoch 151/1000
#  - 3s - loss: 0.5733 - accuracy: 0.6883 - val_loss: 0.0316 - val_accuracy: 12.5912
#
# Epoch 00151: val_loss did not improve from 0.02775
# Epoch 152/1000
#  - 2s - loss: 0.5723 - accuracy: 0.6877 - val_loss: 0.0315 - val_accuracy: 13.0779
#
# Epoch 00152: val_loss did not improve from 0.02775
# Epoch 153/1000
#  - 3s - loss: 0.5716 - accuracy: 0.6900 - val_loss: 0.0317 - val_accuracy: 12.3479
#
# Epoch 00153: val_loss did not improve from 0.02775
# Epoch 154/1000
#  - 3s - loss: 0.5701 - accuracy: 0.6916 - val_loss: 0.0317 - val_accuracy: 12.6521
#
# Epoch 00154: val_loss did not improve from 0.02775
# Epoch 155/1000
#  - 3s - loss: 0.5696 - accuracy: 0.6909 - val_loss: 0.0318 - val_accuracy: 12.7129
#
# Epoch 00155: val_loss did not improve from 0.02775
# Epoch 156/1000
#  - 3s - loss: 0.5686 - accuracy: 0.6926 - val_loss: 0.0317 - val_accuracy: 13.1995
#
# Epoch 00156: val_loss did not improve from 0.02775
# Epoch 157/1000
#  - 3s - loss: 0.5674 - accuracy: 0.6938 - val_loss: 0.0320 - val_accuracy: 12.5912
#
# Epoch 00157: val_loss did not improve from 0.02775
# Epoch 158/1000
#  - 3s - loss: 0.5660 - accuracy: 0.6937 - val_loss: 0.0320 - val_accuracy: 12.4696
#
# Epoch 00158: val_loss did not improve from 0.02775
# Epoch 159/1000
#  - 2s - loss: 0.5656 - accuracy: 0.6962 - val_loss: 0.0320 - val_accuracy: 12.6521
#
# Epoch 00159: val_loss did not improve from 0.02775
# Epoch 160/1000
#  - 3s - loss: 0.5644 - accuracy: 0.6959 - val_loss: 0.0323 - val_accuracy: 12.4088
#
# Epoch 00160: val_loss did not improve from 0.02775
# Epoch 161/1000
#  - 2s - loss: 0.5633 - accuracy: 0.6981 - val_loss: 0.0322 - val_accuracy: 12.8954
#
# Epoch 00161: val_loss did not improve from 0.02775
# Epoch 162/1000
#  - 2s - loss: 0.5631 - accuracy: 0.6976 - val_loss: 0.0323 - val_accuracy: 12.2263
#
# Epoch 00162: val_loss did not improve from 0.02775
# Epoch 163/1000
#  - 2s - loss: 0.5616 - accuracy: 0.7000 - val_loss: 0.0324 - val_accuracy: 12.6521
#
# Epoch 00163: val_loss did not improve from 0.02775
# Epoch 164/1000
#  - 2s - loss: 0.5602 - accuracy: 0.7009 - val_loss: 0.0323 - val_accuracy: 12.7129
#
# Epoch 00164: val_loss did not improve from 0.02775
# Epoch 165/1000
#  - 2s - loss: 0.5598 - accuracy: 0.7000 - val_loss: 0.0324 - val_accuracy: 12.4696
#
# Epoch 00165: val_loss did not improve from 0.02775
# Epoch 166/1000
#  - 2s - loss: 0.5587 - accuracy: 0.7032 - val_loss: 0.0322 - val_accuracy: 12.5304
#
# Epoch 00166: val_loss did not improve from 0.02775
# Epoch 167/1000
#  - 2s - loss: 0.5573 - accuracy: 0.7044 - val_loss: 0.0321 - val_accuracy: 12.9562
#
# Epoch 00167: val_loss did not improve from 0.02775
# Epoch 168/1000
#  - 2s - loss: 0.5562 - accuracy: 0.7051 - val_loss: 0.0323 - val_accuracy: 13.1995
#
# Epoch 00168: val_loss did not improve from 0.02775
# Epoch 169/1000
#  - 2s - loss: 0.5555 - accuracy: 0.7046 - val_loss: 0.0324 - val_accuracy: 12.9562
#
# Epoch 00169: val_loss did not improve from 0.02775
# Epoch 170/1000
#  - 2s - loss: 0.5545 - accuracy: 0.7078 - val_loss: 0.0325 - val_accuracy: 12.7129
#
# Epoch 00170: val_loss did not improve from 0.02775
# Epoch 171/1000
#  - 2s - loss: 0.5537 - accuracy: 0.7062 - val_loss: 0.0325 - val_accuracy: 13.0170
#
# Epoch 00171: val_loss did not improve from 0.02775
# Epoch 172/1000
#  - 3s - loss: 0.5527 - accuracy: 0.7091 - val_loss: 0.0327 - val_accuracy: 12.7737
#
# Epoch 00172: val_loss did not improve from 0.02775
# Epoch 173/1000
#  - 2s - loss: 0.5516 - accuracy: 0.7088 - val_loss: 0.0327 - val_accuracy: 13.1387
#
# Epoch 00173: val_loss did not improve from 0.02775
# Epoch 174/1000
#  - 3s - loss: 0.5505 - accuracy: 0.7101 - val_loss: 0.0327 - val_accuracy: 13.2603
#
# Epoch 00174: val_loss did not improve from 0.02775
# Epoch 175/1000
#  - 2s - loss: 0.5496 - accuracy: 0.7112 - val_loss: 0.0327 - val_accuracy: 13.1995
#
# Epoch 00175: val_loss did not improve from 0.02775
# Epoch 176/1000
#  - 2s - loss: 0.5484 - accuracy: 0.7130 - val_loss: 0.0331 - val_accuracy: 13.4428
#
# Epoch 00176: val_loss did not improve from 0.02775
# Epoch 177/1000
#  - 2s - loss: 0.5476 - accuracy: 0.7138 - val_loss: 0.0336 - val_accuracy: 12.5304
#
# Epoch 00177: val_loss did not improve from 0.02775
# Epoch 178/1000
#  - 3s - loss: 0.5469 - accuracy: 0.7140 - val_loss: 0.0329 - val_accuracy: 13.0170
#
# Epoch 00178: val_loss did not improve from 0.02775
# Epoch 179/1000
#  - 2s - loss: 0.5459 - accuracy: 0.7142 - val_loss: 0.0329 - val_accuracy: 13.3820
#
# Epoch 00179: val_loss did not improve from 0.02775
# Epoch 180/1000
#  - 2s - loss: 0.5458 - accuracy: 0.7148 - val_loss: 0.0332 - val_accuracy: 12.4696
#
# Epoch 00180: val_loss did not improve from 0.02775
# Epoch 181/1000
#  - 2s - loss: 0.5442 - accuracy: 0.7166 - val_loss: 0.0335 - val_accuracy: 12.2871
#
# Epoch 00181: val_loss did not improve from 0.02775
# Epoch 182/1000
#  - 2s - loss: 0.5429 - accuracy: 0.7172 - val_loss: 0.0331 - val_accuracy: 12.7737
#
# Epoch 00182: val_loss did not improve from 0.02775
# Epoch 183/1000
#  - 2s - loss: 0.5429 - accuracy: 0.7188 - val_loss: 0.0334 - val_accuracy: 12.7737
#
# Epoch 00183: val_loss did not improve from 0.02775
# Epoch 184/1000
#  - 3s - loss: 0.5419 - accuracy: 0.7171 - val_loss: 0.0333 - val_accuracy: 12.7737
#
# Epoch 00184: val_loss did not improve from 0.02775
# Epoch 185/1000
#  - 2s - loss: 0.5403 - accuracy: 0.7188 - val_loss: 0.0331 - val_accuracy: 12.5304
#
# Epoch 00185: val_loss did not improve from 0.02775
# Epoch 186/1000
#  - 2s - loss: 0.5396 - accuracy: 0.7204 - val_loss: 0.0331 - val_accuracy: 13.1995
#
# Epoch 00186: val_loss did not improve from 0.02775
# Epoch 187/1000
#  - 3s - loss: 0.5388 - accuracy: 0.7208 - val_loss: 0.0333 - val_accuracy: 12.7737
#
# Epoch 00187: val_loss did not improve from 0.02775
# Epoch 188/1000
#  - 2s - loss: 0.5379 - accuracy: 0.7221 - val_loss: 0.0336 - val_accuracy: 13.2603
#
# Epoch 00188: val_loss did not improve from 0.02775
# Epoch 189/1000
#  - 2s - loss: 0.5373 - accuracy: 0.7216 - val_loss: 0.0344 - val_accuracy: 12.1655
#
# Epoch 00189: val_loss did not improve from 0.02775
# Epoch 190/1000
#  - 2s - loss: 0.5351 - accuracy: 0.7229 - val_loss: 0.0339 - val_accuracy: 12.6521
#
# Epoch 00190: val_loss did not improve from 0.02775
# Epoch 191/1000
#  - 2s - loss: 0.5346 - accuracy: 0.7246 - val_loss: 0.0340 - val_accuracy: 12.9562
#
# Epoch 00191: val_loss did not improve from 0.02775
# Epoch 192/1000
#  - 2s - loss: 0.5346 - accuracy: 0.7254 - val_loss: 0.0338 - val_accuracy: 13.0779
#
# Epoch 00192: val_loss did not improve from 0.02775
# Epoch 193/1000
#  - 2s - loss: 0.5329 - accuracy: 0.7260 - val_loss: 0.0336 - val_accuracy: 13.0170
#
# Epoch 00193: val_loss did not improve from 0.02775
# Epoch 194/1000
#  - 2s - loss: 0.5324 - accuracy: 0.7267 - val_loss: 0.0336 - val_accuracy: 12.8346
#
# Epoch 00194: val_loss did not improve from 0.02775
# Epoch 195/1000
#  - 2s - loss: 0.5313 - accuracy: 0.7277 - val_loss: 0.0337 - val_accuracy: 12.1655
#
# Epoch 00195: val_loss did not improve from 0.02775
# Epoch 196/1000
#  - 2s - loss: 0.5307 - accuracy: 0.7269 - val_loss: 0.0336 - val_accuracy: 12.6521
#
# Epoch 00196: val_loss did not improve from 0.02775
# Epoch 197/1000
#  - 2s - loss: 0.5291 - accuracy: 0.7291 - val_loss: 0.0341 - val_accuracy: 12.5304
#
# Epoch 00197: val_loss did not improve from 0.02775
# Epoch 198/1000
#  - 2s - loss: 0.5287 - accuracy: 0.7302 - val_loss: 0.0340 - val_accuracy: 13.0170
#
# Epoch 00198: val_loss did not improve from 0.02775
# Epoch 199/1000
#  - 2s - loss: 0.5275 - accuracy: 0.7308 - val_loss: 0.0342 - val_accuracy: 12.4088
#
# Epoch 00199: val_loss did not improve from 0.02775
# Epoch 200/1000
#  - 3s - loss: 0.5269 - accuracy: 0.7326 - val_loss: 0.0344 - val_accuracy: 12.5304
#
# Epoch 00200: val_loss did not improve from 0.02775
# Epoch 201/1000
#  - 3s - loss: 0.5256 - accuracy: 0.7315 - val_loss: 0.0348 - val_accuracy: 12.1655
#
# Epoch 00201: val_loss did not improve from 0.02775
# Epoch 202/1000
#  - 3s - loss: 0.5259 - accuracy: 0.7330 - val_loss: 0.0355 - val_accuracy: 11.9830
#
# Epoch 00202: val_loss did not improve from 0.02775
# Epoch 203/1000
#  - 3s - loss: 0.5244 - accuracy: 0.7332 - val_loss: 0.0343 - val_accuracy: 12.8954
#
# Epoch 00203: val_loss did not improve from 0.02775
# Epoch 204/1000
#  - 2s - loss: 0.5237 - accuracy: 0.7330 - val_loss: 0.0346 - val_accuracy: 12.4696
#
# Epoch 00204: val_loss did not improve from 0.02775
# Epoch 205/1000
#  - 2s - loss: 0.5224 - accuracy: 0.7353 - val_loss: 0.0344 - val_accuracy: 12.2263
#
# Epoch 00205: val_loss did not improve from 0.02775
# Epoch 206/1000
#  - 2s - loss: 0.5217 - accuracy: 0.7349 - val_loss: 0.0348 - val_accuracy: 11.9830
#
# Epoch 00206: val_loss did not improve from 0.02775
# Epoch 207/1000
#  - 2s - loss: 0.5203 - accuracy: 0.7379 - val_loss: 0.0349 - val_accuracy: 12.1655
#
# Epoch 00207: val_loss did not improve from 0.02775
# Epoch 208/1000
#  - 3s - loss: 0.5187 - accuracy: 0.7383 - val_loss: 0.0345 - val_accuracy: 12.6521
#
# Epoch 00208: val_loss did not improve from 0.02775
# Epoch 209/1000
#  - 3s - loss: 0.5196 - accuracy: 0.7366 - val_loss: 0.0349 - val_accuracy: 12.4088
#
# Epoch 00209: val_loss did not improve from 0.02775
# Epoch 210/1000
#  - 2s - loss: 0.5180 - accuracy: 0.7388 - val_loss: 0.0348 - val_accuracy: 12.8346
#
# Epoch 00210: val_loss did not improve from 0.02775
# Epoch 211/1000
#  - 2s - loss: 0.5175 - accuracy: 0.7388 - val_loss: 0.0348 - val_accuracy: 12.4696
#
# Epoch 00211: val_loss did not improve from 0.02775
# Epoch 212/1000
#  - 2s - loss: 0.5171 - accuracy: 0.7378 - val_loss: 0.0347 - val_accuracy: 12.7129
#
# Epoch 00212: val_loss did not improve from 0.02775
# Epoch 213/1000
#  - 2s - loss: 0.5153 - accuracy: 0.7403 - val_loss: 0.0351 - val_accuracy: 12.5304
#
# Epoch 00213: val_loss did not improve from 0.02775
# Epoch 214/1000
#  - 3s - loss: 0.5149 - accuracy: 0.7410 - val_loss: 0.0355 - val_accuracy: 12.1655
#
# Epoch 00214: val_loss did not improve from 0.02775
# Epoch 215/1000
#  - 3s - loss: 0.5133 - accuracy: 0.7417 - val_loss: 0.0355 - val_accuracy: 12.1655
#
# Epoch 00215: val_loss did not improve from 0.02775
# Epoch 216/1000
#  - 2s - loss: 0.5127 - accuracy: 0.7409 - val_loss: 0.0356 - val_accuracy: 12.1655
#
# Epoch 00216: val_loss did not improve from 0.02775
# Epoch 217/1000
#  - 2s - loss: 0.5124 - accuracy: 0.7423 - val_loss: 0.0352 - val_accuracy: 12.5912
#
# Epoch 00217: val_loss did not improve from 0.02775
# Epoch 218/1000
#  - 2s - loss: 0.5109 - accuracy: 0.7428 - val_loss: 0.0359 - val_accuracy: 12.1655
#
# Epoch 00218: val_loss did not improve from 0.02775
# Epoch 219/1000
#  - 2s - loss: 0.5104 - accuracy: 0.7429 - val_loss: 0.0357 - val_accuracy: 12.4088
#
# Epoch 00219: val_loss did not improve from 0.02775
# Epoch 220/1000
#  - 2s - loss: 0.5095 - accuracy: 0.7431 - val_loss: 0.0355 - val_accuracy: 13.0170
#
# Epoch 00220: val_loss did not improve from 0.02775
# Epoch 221/1000
#  - 2s - loss: 0.5092 - accuracy: 0.7443 - val_loss: 0.0354 - val_accuracy: 13.0779
#
# Epoch 00221: val_loss did not improve from 0.02775
# Epoch 222/1000
#  - 2s - loss: 0.5087 - accuracy: 0.7436 - val_loss: 0.0355 - val_accuracy: 12.7737
#
# Epoch 00222: val_loss did not improve from 0.02775
# Epoch 223/1000
#  - 2s - loss: 0.5072 - accuracy: 0.7458 - val_loss: 0.0356 - val_accuracy: 12.7737
#
# Epoch 00223: val_loss did not improve from 0.02775
# Epoch 224/1000
#  - 2s - loss: 0.5060 - accuracy: 0.7463 - val_loss: 0.0354 - val_accuracy: 12.7737
#
# Epoch 00224: val_loss did not improve from 0.02775
# Epoch 225/1000
#  - 2s - loss: 0.5053 - accuracy: 0.7456 - val_loss: 0.0355 - val_accuracy: 12.3479
#
# Epoch 00225: val_loss did not improve from 0.02775
# Epoch 226/1000
#  - 2s - loss: 0.5044 - accuracy: 0.7460 - val_loss: 0.0356 - val_accuracy: 12.8346
#
# Epoch 00226: val_loss did not improve from 0.02775
# Epoch 227/1000
#  - 2s - loss: 0.5044 - accuracy: 0.7471 - val_loss: 0.0358 - val_accuracy: 12.4088
#
# Epoch 00227: val_loss did not improve from 0.02775
# Epoch 228/1000
#  - 2s - loss: 0.5034 - accuracy: 0.7475 - val_loss: 0.0358 - val_accuracy: 12.2263
#
# Epoch 00228: val_loss did not improve from 0.02775
# Epoch 229/1000
#  - 2s - loss: 0.5028 - accuracy: 0.7475 - val_loss: 0.0360 - val_accuracy: 13.0170
#
# Epoch 00229: val_loss did not improve from 0.02775
# Epoch 230/1000
#  - 2s - loss: 0.5014 - accuracy: 0.7484 - val_loss: 0.0360 - val_accuracy: 12.7129
#
# Epoch 00230: val_loss did not improve from 0.02775
# Epoch 231/1000
#  - 3s - loss: 0.5009 - accuracy: 0.7485 - val_loss: 0.0360 - val_accuracy: 13.1995
#
# Epoch 00231: val_loss did not improve from 0.02775
# Epoch 232/1000
#  - 3s - loss: 0.5000 - accuracy: 0.7496 - val_loss: 0.0368 - val_accuracy: 12.5304
#
# Epoch 00232: val_loss did not improve from 0.02775
# Epoch 233/1000
#  - 3s - loss: 0.4995 - accuracy: 0.7503 - val_loss: 0.0377 - val_accuracy: 12.2263
#
# Epoch 00233: val_loss did not improve from 0.02775
# Epoch 234/1000
#  - 2s - loss: 0.4983 - accuracy: 0.7504 - val_loss: 0.0365 - val_accuracy: 12.7737
#
# Epoch 00234: val_loss did not improve from 0.02775
# Epoch 235/1000
#  - 2s - loss: 0.4980 - accuracy: 0.7502 - val_loss: 0.0367 - val_accuracy: 12.7129
#
# Epoch 00235: val_loss did not improve from 0.02775
# Epoch 236/1000
#  - 2s - loss: 0.4967 - accuracy: 0.7521 - val_loss: 0.0365 - val_accuracy: 12.5912
#
# Epoch 00236: val_loss did not improve from 0.02775
# Epoch 237/1000
#  - 2s - loss: 0.4965 - accuracy: 0.7520 - val_loss: 0.0364 - val_accuracy: 13.1387
#
# Epoch 00237: val_loss did not improve from 0.02775
# Epoch 238/1000
#  - 2s - loss: 0.4959 - accuracy: 0.7525 - val_loss: 0.0370 - val_accuracy: 11.9830
#
# Epoch 00238: val_loss did not improve from 0.02775
# Epoch 239/1000
#  - 2s - loss: 0.4953 - accuracy: 0.7523 - val_loss: 0.0371 - val_accuracy: 12.4696
#
# Epoch 00239: val_loss did not improve from 0.02775
# Epoch 240/1000
#  - 3s - loss: 0.4939 - accuracy: 0.7544 - val_loss: 0.0371 - val_accuracy: 12.2263
#
# Epoch 00240: val_loss did not improve from 0.02775
# Epoch 241/1000
#  - 3s - loss: 0.4930 - accuracy: 0.7542 - val_loss: 0.0369 - val_accuracy: 12.5304
#
# Epoch 00241: val_loss did not improve from 0.02775
# Epoch 242/1000
#  - 2s - loss: 0.4922 - accuracy: 0.7561 - val_loss: 0.0371 - val_accuracy: 12.4088
#
# Epoch 00242: val_loss did not improve from 0.02775
# Epoch 243/1000
#  - 2s - loss: 0.4912 - accuracy: 0.7562 - val_loss: 0.0370 - val_accuracy: 12.6521
#
# Epoch 00243: val_loss did not improve from 0.02775
# Epoch 244/1000
#  - 2s - loss: 0.4904 - accuracy: 0.7559 - val_loss: 0.0370 - val_accuracy: 12.7737
#
# Epoch 00244: val_loss did not improve from 0.02775
# Epoch 245/1000
#  - 2s - loss: 0.4890 - accuracy: 0.7573 - val_loss: 0.0373 - val_accuracy: 13.0170
#
# Epoch 00245: val_loss did not improve from 0.02775
# Epoch 246/1000
#  - 2s - loss: 0.4893 - accuracy: 0.7561 - val_loss: 0.0372 - val_accuracy: 13.1995
#
# Epoch 00246: val_loss did not improve from 0.02775
# Epoch 247/1000
#  - 2s - loss: 0.4890 - accuracy: 0.7561 - val_loss: 0.0372 - val_accuracy: 13.2603
#
# Epoch 00247: val_loss did not improve from 0.02775
# Epoch 248/1000
#  - 2s - loss: 0.4875 - accuracy: 0.7588 - val_loss: 0.0373 - val_accuracy: 13.1995
#
# Epoch 00248: val_loss did not improve from 0.02775
# Epoch 249/1000
#  - 2s - loss: 0.4872 - accuracy: 0.7582 - val_loss: 0.0373 - val_accuracy: 12.8954
#
# Epoch 00249: val_loss did not improve from 0.02775
# Epoch 250/1000
#  - 2s - loss: 0.4863 - accuracy: 0.7581 - val_loss: 0.0373 - val_accuracy: 12.8954
#
# Epoch 00250: val_loss did not improve from 0.02775
# Epoch 251/1000
#  - 3s - loss: 0.4855 - accuracy: 0.7583 - val_loss: 0.0378 - val_accuracy: 13.2603
#
# Epoch 00251: val_loss did not improve from 0.02775
# test_result.shape : (411, 2)
# y_test[:5] : [1 1 1 0 0]
# y_score[:5] : [[0.4978377 ]
#  [0.4985951 ]
#  [0.4983228 ]
#  [0.49839428]
#  [0.4983651 ]]
# y_test.shape : (411, 1)
# y_score.shape : (411, 1)
# len(y_test) : 411
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:713: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [11.365984, 12.477781, 11.589157, 11.473092, 12.753713, 13.118064, 13.188006, 15.284202, 16.19899, 16.589115, 18.774176, 15.944133, 14.082032, 14.679111, 14.75006, 13.774244, 13.097381, 12.634593, 11.408763, 11.138619, 11.265828, 11.229589, 10.92912, 9.584987, 9.150919, 8.581221, 8.217781, 7.5577903, 7.5552187, 8.137264, 9.595978, 8.858242, 8.408727, 9.158028, 9.140386, 9.095078, 9.260869, 10.214157, 10.062561, 9.247389, 9.695394, 9.917699, 9.940474, 9.701741, 10.178503, 9.705999, 9.933221, 8.982561, 8.979079, 9.595518, 9.84501, 10.671624, 10.889414, 11.783421, 11.635862, 13.4751215, 13.54876, 14.032499, 14.400289, 13.93345, 13.755443, 13.934826, 14.30684, 13.588011, 13.569095, 15.064049, 14.965997, 14.30108, 14.58578, 14.902416, 15.781463, 14.919215, 13.565842, 12.633775, 12.17747, 10.842355, 10.741132, 10.606728, 11.527504, 11.609757, 11.861528, 12.149008, 11.013184, 10.55416, 10.66116, 9.202627, 9.598517, 9.843781, 10.03747, 10.076493, 10.532154, 9.857976, 9.923337, 9.128869, 8.61003, 8.303917, 8.195156, 8.372049, 8.513622, 8.4838705, 9.232764, 9.5265045, 9.727739, 9.717923, 8.044771, 8.284871, 7.9239526, 7.407525, 7.5284147, 7.397328, 7.7480674, 7.117916, 6.945265, 7.183768, 6.9143357, 6.968394, 7.3426075, 7.079149, 6.9688263, 7.0195146, 6.966863, 7.3312125, 7.232302, 6.3852844, 6.38419, 6.6959147, 4.8082037, 4.9916897, 4.8436384, 9.490221, 8.832126, 9.02041, 8.703243, 9.001045, 9.030118, 8.8086815, 8.609677, 8.097901, 8.38934, 8.238143, 8.391755, 8.56024, 8.589356, 8.617607, 8.462311, 8.660613, 8.684904, 9.113331, 8.926211, 9.157285, 8.545767, 8.507151, 8.233045, 8.111334, 7.8011465, 8.615696, 9.518469, 9.414414, 8.932144, 8.948945, 7.253898, 7.0110373, 6.6319304, 6.0731106, 5.750746, 5.7992206, 6.0011263, 6.0035086, 5.897075, 5.6483865, 4.824964, 3.6800082, 3.6287086, 3.7512195, 3.9126356, 3.9485881, 3.9616385, 3.9234574, 3.7648304, 3.736832, 3.7462718, 3.3050134, 3.4023168, 2.8122044, 4.6116905, 4.640625, 4.0036907, 3.253635, 3.2670462, 3.2201028, 3.2578337, 3.4867845, 3.2832465, 3.4013882, 3.4646442, 4.018084, 3.9547193, 4.11451, 4.0995984, 4.089488, 4.15643, 4.4254107, 3.907497, 3.6616106, 3.5525503, 3.693343, 3.6870418, 4.6470203, 4.8196936, 5.100985, 4.8401756, 4.843884, 4.8842425, 5.034394, 5.134911, 4.839022, 4.7703786, 4.6278334, 4.053402, 4.0217195, 4.1103344, 4.3285356, 4.2133107, 3.977051, 3.5883994, 3.3542647, 3.3475287, 3.4154098, 3.6203883, 3.561041, 3.620781, 3.4096808, 3.2798493, 2.8736672, 2.8280816, 2.7552035, 2.7772543, 2.8790495, 2.9287894, 2.7775912, 2.6941032, 2.6300452, 2.5799146, 2.4974048, 2.449967, 1.8853663, 1.8991661, 1.9216378, 1.8758001, 1.8203096, 1.80188, 1.8762683, 1.7793968, 1.5613204, 1.5275873, 1.5483135, 1.5530788, 1.4932908, 1.4102186, 1.4036957, 1.472118, 1.4404818, 1.4273484, 1.4901997, 1.582865, 1.4530835, 1.4580115, 1.3885508, 1.3588861, 1.3759197, 1.4385772, 1.4307903, 1.2519937, 1.2569362, 1.1992384, 1.2512882, 1.253026, 1.3551975, 1.3772261, 1.3938373, 1.3789381, 1.3665069, 1.34705, 1.3547548, 1.313158, 1.3182157, 1.2419021, 1.2305497, 1.2305138, 1.297629, 1.3117862, 1.2753443, 1.2618316, 1.0720898, 1.0617115, 1.065505, 1.0450625, 0.9816884, 0.97859085, 0.8550333, 0.91731006, 0.9028998, 0.9483057, 0.9287518, 0.94099367, 0.99478364, 1.0059222, 0.98044825, 1.0538466, 0.9973586, 1.0159401, 1.0078608, 1.0294677, 0.9768363, 0.956341, 0.9032243, 0.7828404, 0.697682, 0.68365395, 0.7164198, 0.7018679, 0.7790493, 0.9213896, 0.88127136, 0.8497458, 0.85760295, 0.8488047, 0.84999, 0.8896819, 0.88765943, 0.8763433, 0.8691727, 0.85968703, 0.91931546, 0.96523815, 0.96597403, 0.98847204, 0.97069985, 1.033822, 1.0302929, 1.0084155, 0.97774136, 0.9860414, 0.9050641, 0.93470526, 0.9602624, 0.9181246, 0.8936096, 0.89283675, 0.8985637, 0.930485, 0.9270637, 0.8953022, 1.0579607, 1.0892448, 1.0756683, 0.9833318, 0.78444654, 0.78727007, 0.7473166, 0.8204601, 0.77492046, 0.77915806, 0.7755791, 0.6917169, 0.6293987, 0.6361125, 0.6269698, 0.72916377, 0.73521036, 0.73510903, 0.76681364, 0. ...

# %%
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)], linestyle='--', color='r')
plt.title(symbol_name + '\n' + str(new_thresh[np.argmax(acc_pr_bythr)]))
plt.show()

# %%
thresh = 0.5866
y_pred = np.where(y_score[:600, -1] > thresh, 1, 0)
# print('y_pred.shape :', y_pred.shape)
# print('y_pred :', y_pred)

#     compare precision     #

# print('precision :', precision_score(y_test, y_pred))
# print('recall :', recall_score(y_test, y_pred))
# print()

# print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
# print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

# # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
# # plt.show()  
# print()

#     check win-ratio improvement     #
cmat = confusion_matrix(y_test[:len(y_pred)], y_pred)
# print(cmat)
# print(np.sum(cmat, axis=1))

test_size = len(y_test[:len(y_pred)])
test_pr_list = pr_test[:len(y_pred)]
# print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
# print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

# print('pr_test.shape :', pr_test.shape)

# print(y_pred)
# print(test_pr_list)
pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

plt.plot(np.cumprod(pred_pr_list))
plt.show()

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %% [markdown]
# ### **Training**

# %%
org_x_test = x_test
org_y_test = y_test
org_pr_test = pr_test

# %%
x_test = org_x_test
y_test = org_y_test
pr_test = org_pr_test

# %%
concat_x = np.vstack((org_x_test, new_input_x))
concat_y = np.vstack((org_y_test, np.where(new_input_pr > 1, 1, 0)))
concat_pr = np.vstack((org_pr_test, new_input_pr))

# %%
x_test = new_input_x
y_test = np.where(new_input_pr > 1, 1, 0)
pr_test = new_input_pr

# %%
# print(pred_pr_list)
for pr in pred_pr_list:
  if pr != 1:
    print(pr)

# %%
plt.figure(figsize=(50, 5))
plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test):len(org_pr_test) + 10])
# plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test) - 10:len(org_pr_test) + 10])
plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
# plt.axvline(len(org_pr_test), linestyle='--', color='r')
plt.show()

# %%
# plt.show()
# plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
