# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/Project_Stock/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-02-11/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-02-11 BTCUSDT.xlsx', '2021-02-11 ETHUSDT.xlsx', '2021-02-11 BCHUSDT.xlsx', '2021-02-11 XRPUSDT.xlsx', '2021-02-11 EOSUSDT.xlsx', '2021-02-11 LTCUSDT.xlsx', '2021-02-11 ETCUSDT.xlsx', '2021-02-11 LINKUSDT.xlsx', '2021-02-11 XLMUSDT.xlsx', '2021-02-11 ADAUSDT.xlsx', '2021-02-11 XMRUSDT.xlsx', '2021-02-11 SXPUSDT.xlsx', '2021-02-11 KAVAUSDT.xlsx', '2021-02-11 BANDUSDT.xlsx', '2021-02-11 DASHUSDT.xlsx', '2021-02-11 ZECUSDT.xlsx', '2021-02-11 XTZUSDT.xlsx', '2021-02-11 BNBUSDT.xlsx', '2021-02-11 ATOMUSDT.xlsx', '2021-02-11 ONTUSDT.xlsx', '2021-02-11 IOTAUSDT.xlsx', '2021-02-11 BATUSDT.xlsx', '2021-02-11 NEOUSDT.xlsx', '2021-02-11 QTUMUSDT.xlsx', '2021-02-11 WAVESUSDT.xlsx', '2021-02-11 MKRUSDT.xlsx', '2021-02-11 SNXUSDT.xlsx', '2021-02-11 DOTUSDT.xlsx', '2021-02-11 THETAUSDT.xlsx', '2021-02-11 ALGOUSDT.xlsx', '2021-02-11 KNCUSDT.xlsx', '2021-02-11 ZRXUSDT.xlsx', '2021-02-11 COMPUSDT.xlsx', '2021-02-11 OMGUSDT.xlsx']

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split

with open('./arima_result/arima_opt_profit_ls_only_long_result_%s.pickle' % interval, 'rb') as f:
  load_dict = pickle.load(f)

candis = list(load_dict.keys())
long_index = 0
leverage = 5
prev_x = None

seed = 1
random_state = 20
np.random.seed(seed)

for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue
  if '2021-03-02 DOTUSDT.xlsx' in candis[i]:
    # print('')
    continue

  if '04-08' not in candis[i]:  # <-- 04-08 includes all timestamp range
    continue

  if 'theta'.upper() not in candis[i]:
    continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  
    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      ohlcv = load_dict[key]['ohlcv']
      # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.3)]  # exclude back_range
      # predictions = load_dict[key]['predictions']
      # err_ranges = load_dict[key]['err_ranges']
      print("ohlcv.index[0] :", ohlcv.index[0])
      print("ohlcv.index[-1] :", ohlcv.index[-1])

      predictions = ohlcv['close'].shift(1).values
      err_ranges = np.zeros_like(predictions)

      # leverage_list = profit_result_dict[key]['leverage_list']
      # temp_ap_list = list()
      # temp_pr_list = list()

      try:
        print('-------------- %s --------------' % key)
        result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
        # temp_ap_list.append(result[2])
        # temp_pr_list.append(result[3])

        # if round(leverage) == 1:
        #   temp_pr_list = result[3]
        pr_list = result[3][long_index]

      except Exception as e:
        print(e)
        break    
  # break


      pd.set_option('display.max_rows', 500)
      pd.set_option('display.max_columns', 500)
      pd.set_option('display.width', 1000)

      #         clustering zone           #

      #       set data features : ohlc, v, ep
      ohlc = ohlcv.iloc[-len(predictions):, :4]
      vol = ohlcv.iloc[-len(predictions):, [4]]
      long_ep = np.array(predictions)
      long_ep = long_ep.reshape(-1, 1)

      ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
      ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
      ohlcv['body'] = ohlcv['close'] / ohlcv['open']

      candle = ohlcv.iloc[-len(predictions):, -3:]


      print('len(ohlc) :', len(ohlc))
      print('long_ep.shape :', long_ep.shape)
      print('len(pr_list) :', len(pr_list))


      #       set params    #
      period = 45
      data_x, data_pr, data_updown = [], [], []
      key_i = i

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]
          temp_vol = vol.iloc[i - period : i].values
          temp_candle = candle.iloc[i - period : i].values

          # print(temp_ohlc.shape)
          # print(temp_long_ep.shape)
          # print(temp_vol.shape)
          # print(temp_candle.shape)
          # break

          #   stacking  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol))
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          max_abs = MaxAbsScaler()
          temp_data[:, :5] = max_abs.fit_transform(temp_data[:, :5])


          # min_max = MinMaxScaler()
          # temp_data[:, :5] = min_max.fit_transform(temp_data[:, :5])


          #   vol -> min_max
          min_max = MinMaxScaler()
          temp_data[:, [5]] = min_max.fit_transform(temp_data[:, [5]])


          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)

      
      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      #     do stacking   #
      if prev_x is None:
        prev_x = input_x
        prev_pr = input_pr
        prev_ud = input_ud
      else:
        total_x = np.vstack((prev_x, input_x))
        total_pr = np.vstack((prev_pr, input_pr))
        total_ud = np.vstack((prev_ud, input_ud))

        prev_x = total_x
        prev_pr = total_pr
        prev_ud = total_ud

        print('total_x.shape :', total_x.shape)
        print('total_pr.shape :', total_pr.shape)
        print('total_ud.shape :', total_ud.shape)
      # if prev_train_x is None:
      #   prev_train_x = x_train
      #   prev_val_x = x_val
      #   prev_test_x = x_test
        
      #   prev_train_pr = pr_train
      #   prev_val_pr = pr_val
      #   prev_test_pr = pr_test

      #   prev_train_ud = ud_train
      #   prev_val_ud = ud_val
      #   prev_test_ud = ud_test

      # else:

      #   total_train_x = np.vstack((prev_train_x, x_train))
      #   total_val_x = np.vstack((prev_val_x, x_val))
      #   total_test_x = np.vstack((prev_test_x, x_test))
      #   total_train_pr = np.vstack((prev_train_pr, pr_train))
      #   total_val_pr = np.vstack((prev_val_pr, pr_val))
      #   total_test_pr = np.vstack((prev_test_pr, pr_test))
      #   total_train_ud = np.vstack((prev_train_ud, ud_train))
      #   total_val_ud = np.vstack((prev_val_ud, ud_val))
      #   total_test_ud = np.vstack((prev_test_ud, ud_test))
        
      #   prev_train_x = total_train_x
      #   prev_val_x = total_val_x
      #   prev_test_x = total_test_x
        
      #   prev_train_pr = total_train_pr
      #   prev_val_pr = total_val_pr
      #   prev_test_pr = total_test_pr

      #   prev_train_ud = total_train_ud
      #   prev_val_ud = total_val_ud
      #   prev_test_ud = total_test_ud
        
      #   print("total_train_x.shape :", total_train_x.shape)
      #   print("total_val_x.shape :", total_val_x.shape)
      #   print("total_test_x.shape :", total_test_x.shape)
      #   print("total_train_pr.shape :", total_train_pr.shape)
      #   print("total_val_pr.shape :", total_val_pr.shape)
      #   print("total_test_pr.shape :", total_test_pr.shape)
      #   print("total_train_ud.shape :", total_train_ud.shape)
      #   print("total_val_ud.shape :", total_val_ud.shape)
      #   print("total_test_ud.shape :", total_test_ud.shape)

  break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  # try:
  #   if len(total_x) > 300000:
  #     break
  # except:
  #   pass
# Out:
# ohlcv.index[0] : 2020-05-27 17:29:59.999000
# ohlcv.index[-1] : 2021-04-08 20:29:59.999000
# -------------- 2021-04-08 THETAUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 15175
# long_ep.shape : (15175, 1)
# len(pr_list) : 15175
# np.array(data_x).shape : (14504, 45, 6)
# input_x.shape : (14504, 90, 12, 3)
# input_x.dtype : float32
# input_pr.shape : (14504, 1)
# input_ud.shape : (14504, 1)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:198: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %% [markdown]
# ### Load Data

# %%
period = 45
# x_save_path = current_path + 'npy/' + '%s_close_updown_x.npy' % period
# y_save_path = current_path + 'npy/' + '%s_close_updown_y.npy' % period
#         save to npy     #
# x_save_path = current_path + 'npy/' + '%s_close_updown_theta_x_ex.npy' % period
# y_save_path = current_path + 'npy/' + '%s_close_updown_theta_y_ex.npy' % period

# total_x = np.load(x_save_path)
# total_pr = np.load(y_save_path)

_, row, col, _ = input_x.shape



seed = 1
random_state = 20
np.random.seed(seed)
from sklearn.model_selection import train_test_split
#         train / test split      #
# x_train, x_test_, pr_train, pr_test_, ud_train, ud_test_ = train_test_split(re_input_x, total_pr, total_ud, test_size=0.4, shuffle=True, random_state=random_state)
x_train_, x_test, pr_train_, pr_test = train_test_split(input_x, input_pr, test_size=0.2, shuffle=False, random_state=random_state)
x_train, x_val, pr_train, pr_val = train_test_split(x_train_, pr_train_, test_size=0.25, shuffle=False, random_state=random_state)
# break
#         pr label   #
y_train = np.where(pr_train > 1, 1, 0)
y_test = np.where(pr_test > 1, 1, 0)
y_val = np.where(pr_val > 1, 1, 0)

del input_x

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape=(row, col, 3)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %%
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight
# import cv2


_, row, col, _ = x_train.shape

#         pr label   #
# y_train = np.where(pr_train > 1, 1, 0)
# y_test = np.where(pr_test > 1, 1, 0)
# y_val = np.where(pr_val > 1, 1, 0)


seed = 1
random_state = 20
np.random.seed(seed)
# tf.random.set_seed(seed)

#         up label      #
# y_train = np.where(ud_train > 1, 1, 0)
# y_test = np.where(ud_test > 1, 1, 0)
# y_val = np.where(ud_val > 1, 1, 0)

print('pr_train[:5] :', pr_train[:5])
# print('ud_train[:5] :', ud_train[:5])
print('y_train[:5] :', y_train[:5])
print('y_train.dtype :', y_train.dtype)

print('x_train.shape :', x_train.shape)
print('x_test.shape :', x_test.shape)
print('x_val.shape :', x_val.shape)
print('y_train.shape :', y_train.shape)
print('y_test.shape :', y_test.shape)
print('y_val.shape :', y_val.shape)

def class_ratio(in_list):

  return in_list / in_list[1]

print('np.unique(y_train, return_counts=True :', np.unique(y_train, return_counts=True), class_ratio(np.unique(y_train, return_counts=True)[1]))
print('np.unique(y_val, return_counts=True :', np.unique(y_val, return_counts=True), class_ratio(np.unique(y_val, return_counts=True)[1]))
print('np.unique(y_test, return_counts=True :', np.unique(y_test, return_counts=True), class_ratio(np.unique(y_test, return_counts=True)[1]))

label = y_train.reshape(-1, )
class_weights = class_weight.compute_class_weight('balanced', 
                                                    classes=np.unique(label),
                                                    y=label)
class_weights = dict(enumerate(class_weights))
print('class_weights :', class_weights)

# sample_weight = np.ones(shape=(len(y_train),))
# sample_weight[(y_train == 1).reshape(-1,)] = 1.5
# print('sample_weight[:20] :', sample_weight[:20])


print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(x_train)))
print('np.isnan(np.sum(x_val)) :', np.isnan(np.sum(x_val)))
print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))

print('np.isnan(np.sum(y_train)) :', np.isnan(np.sum(y_train)))
print('np.isnan(np.sum(y_val)) :', np.isnan(np.sum(y_val)))
print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

y_train_ohe = np_utils.to_categorical(y_train, num_classes)
y_val_ohe = np_utils.to_categorical(y_val, num_classes)
y_test_ohe = np_utils.to_categorical(y_test, num_classes)
print('y_train_ohe.shape :', y_train_ohe.shape)
print('y_val_ohe.shape :', y_val_ohe.shape)
print('y_test_ohe.shape :', y_test_ohe.shape)

datagen = ImageDataGenerator( 
    rotation_range = 45,
    # zoom_range = 0.5,
    # shear_range = 0.5,
    # horizontal_flip = True,
    # vertical_flip = True,
    # width_shift_range=0.5,
    # height_shift_range=0.5,
    # fill_mode = 'nearest'
    )

valgen = ImageDataGenerator( 
    )

datagen.fit(x_train)
valgen.fit(x_val)

batch_size = 16

for x_batch, _ in datagen.flow(x_train, y_train_ohe, batch_size=9):

    plt.suptitle("train x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break

for x_batch, _ in valgen.flow(x_val, y_val_ohe, batch_size=9):

    plt.suptitle("val x_batch")

    for i in range(0, 9): 
        plt.subplot(330 + 1 + i) 
        # resized = cv2.resize(x_batch[i].reshape(row, col), (row * 2, col * 10))
        # cmapped = plt.cm.Set1(resized)
        # plt.imshow(cmapped)
        # plt.imshow(x_batch[i].reshape(row, col))
        plt.imshow(x_batch[i])
        plt.axis('off') 
    plt.show() 
    break
    
train_flow = datagen.flow(x_train, y_train_ohe, batch_size=batch_size) 
val_flow = valgen.flow(x_val, y_val_ohe, batch_size=batch_size) 
# break
# Out:
# pr_train[:5] : [[0.82290965]
#  [1.154621  ]
#  [1.0678885 ]
#  [1.3340611 ]
#  [0.9096892 ]]
# y_train[:5] : [[0]
#  [1]
#  [1]
#  [1]
#  [0]]
# y_train.dtype : int64
# x_train.shape : (8702, 90, 12, 3)
# x_test.shape : (2901, 90, 12, 3)
# x_val.shape : (2901, 90, 12, 3)
# y_train.shape : (8702, 1)
# y_test.shape : (2901, 1)
# y_val.shape : (2901, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([4880, 3822])) [1.27681842 1.        ]
# np.unique(y_val, return_counts=True : (array([0, 1]), array([1533, 1368])) [1.12061404 1.        ]
# np.unique(y_test, return_counts=True : (array([0, 1]), array([1484, 1417])) [1.04728299 1.        ]
# class_weights : {0: 0.8915983606557377, 1: 1.1384092098377814}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(x_val)) : False
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_train)) : False
# np.isnan(np.sum(y_val)) : False
# np.isnan(np.sum(y_test)) : False
# y_train_ohe.shape : (8702, 2)
# y_val_ohe.shape : (2901, 2)
# y_test_ohe.shape : (2901, 2)

# %% [markdown]
# ### **Training**

# %%
(_, row, col, _) = x_train.shape
  
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_%s_close_updown_pr_theta_non_shuffle_ex_maxabs.h5' % period

# model = keras.models.load_model(ckpt_path + model_name)

model = FER_Model(input_shape=(row, col, 3))
opt = Adam(lr=0.00001, decay=0.000005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir=board_path,
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=40)
# callbacks_list = [checkpoint, checkpoint2, checkpoint3]
callbacks_list = [checkpoint, checkpoint2]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 1000
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(x_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(x_val) / batch_size,
                    shuffle=False)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/1000
#  - 12s - loss: 0.7720 - accuracy: 0.5001 - val_loss: 0.7076 - val_accuracy: 0.4812
#
# Epoch 00001: val_loss improved from inf to 0.70755, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_non_shuffle_ex_maxabs.h5
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/1000
#  - 11s - loss: 0.7153 - accuracy: 0.4969 - val_loss: 0.5873 - val_accuracy: 0.5281
#
# Epoch 00002: val_loss improved from 0.70755 to 0.58728, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_non_shuffle_ex_maxabs.h5
# Epoch 3/1000
#  - 11s - loss: 0.7061 - accuracy: 0.4948 - val_loss: 0.7623 - val_accuracy: 0.5284
#
# Epoch 00003: val_loss did not improve from 0.58728
# Epoch 4/1000
#  - 11s - loss: 0.7035 - accuracy: 0.4999 - val_loss: 0.8679 - val_accuracy: 0.5284
#
# Epoch 00004: val_loss did not improve from 0.58728
# Epoch 5/1000
#  - 11s - loss: 0.6994 - accuracy: 0.5107 - val_loss: 0.6751 - val_accuracy: 0.4853
#
# Epoch 00005: val_loss did not improve from 0.58728
# Epoch 6/1000
#  - 11s - loss: 0.6990 - accuracy: 0.5075 - val_loss: 0.8122 - val_accuracy: 0.5284
#
# Epoch 00006: val_loss did not improve from 0.58728
# Epoch 7/1000
#  - 11s - loss: 0.6983 - accuracy: 0.5033 - val_loss: 0.6898 - val_accuracy: 0.5284
#
# Epoch 00007: val_loss did not improve from 0.58728
# Epoch 8/1000
#  - 11s - loss: 0.6991 - accuracy: 0.5030 - val_loss: 0.6177 - val_accuracy: 0.5288
#
# Epoch 00008: val_loss did not improve from 0.58728
# Epoch 9/1000
#  - 11s - loss: 0.6966 - accuracy: 0.5039 - val_loss: 0.7210 - val_accuracy: 0.5209
#
# Epoch 00009: val_loss did not improve from 0.58728
# Epoch 10/1000
#  - 11s - loss: 0.6985 - accuracy: 0.4971 - val_loss: 0.6939 - val_accuracy: 0.5084
#
# Epoch 00010: val_loss did not improve from 0.58728
# Epoch 11/1000
#  - 11s - loss: 0.6980 - accuracy: 0.4978 - val_loss: 0.7092 - val_accuracy: 0.4819
#
# Epoch 00011: val_loss did not improve from 0.58728
# Epoch 12/1000
#  - 11s - loss: 0.6967 - accuracy: 0.5023 - val_loss: 0.6881 - val_accuracy: 0.4743
#
# Epoch 00012: val_loss did not improve from 0.58728
# Epoch 13/1000
#  - 11s - loss: 0.6947 - accuracy: 0.5048 - val_loss: 0.6910 - val_accuracy: 0.5136
#
# Epoch 00013: val_loss did not improve from 0.58728
# Epoch 14/1000
#  - 11s - loss: 0.6946 - accuracy: 0.5102 - val_loss: 0.7454 - val_accuracy: 0.4705
#
# Epoch 00014: val_loss did not improve from 0.58728
# Epoch 15/1000
#  - 11s - loss: 0.6964 - accuracy: 0.4983 - val_loss: 0.8519 - val_accuracy: 0.4712
#
# Epoch 00015: val_loss did not improve from 0.58728
# Epoch 16/1000
#  - 11s - loss: 0.6953 - accuracy: 0.5082 - val_loss: 0.7594 - val_accuracy: 0.4719
#
# Epoch 00016: val_loss did not improve from 0.58728
# Epoch 17/1000
#  - 11s - loss: 0.6951 - accuracy: 0.5055 - val_loss: 0.7058 - val_accuracy: 0.5274
#
# Epoch 00017: val_loss did not improve from 0.58728
# Epoch 18/1000
#  - 11s - loss: 0.6958 - accuracy: 0.5003 - val_loss: 0.6861 - val_accuracy: 0.5126
#
# Epoch 00018: val_loss did not improve from 0.58728
# Epoch 19/1000
#  - 11s - loss: 0.6938 - accuracy: 0.5126 - val_loss: 0.6504 - val_accuracy: 0.4719
#
# Epoch 00019: val_loss did not improve from 0.58728
# Epoch 20/1000
#  - 11s - loss: 0.6949 - accuracy: 0.5086 - val_loss: 0.7630 - val_accuracy: 0.5284
#
# Epoch 00020: val_loss did not improve from 0.58728
# Epoch 21/1000
#  - 11s - loss: 0.6941 - accuracy: 0.5231 - val_loss: 0.7198 - val_accuracy: 0.4743
#
# Epoch 00021: val_loss did not improve from 0.58728
# Epoch 22/1000
#  - 11s - loss: 0.6959 - accuracy: 0.4923 - val_loss: 0.6796 - val_accuracy: 0.5160
#
# Epoch 00022: val_loss did not improve from 0.58728
# Epoch 23/1000
#  - 11s - loss: 0.6937 - accuracy: 0.5105 - val_loss: 0.7480 - val_accuracy: 0.4802
#
# Epoch 00023: val_loss did not improve from 0.58728
# Epoch 24/1000
#  - 11s - loss: 0.6938 - accuracy: 0.5075 - val_loss: 0.6743 - val_accuracy: 0.4723
#
# Epoch 00024: val_loss did not improve from 0.58728
# Epoch 25/1000
#  - 11s - loss: 0.6942 - accuracy: 0.5110 - val_loss: 0.7287 - val_accuracy: 0.4791
#
# Epoch 00025: val_loss did not improve from 0.58728
# Epoch 26/1000
#  - 11s - loss: 0.6943 - accuracy: 0.5095 - val_loss: 0.6912 - val_accuracy: 0.5202
#
# Epoch 00026: val_loss did not improve from 0.58728
# Epoch 27/1000
#  - 11s - loss: 0.6942 - accuracy: 0.5128 - val_loss: 0.6483 - val_accuracy: 0.4798
#
# Epoch 00027: val_loss did not improve from 0.58728
# Epoch 28/1000
#  - 11s - loss: 0.6938 - accuracy: 0.5146 - val_loss: 0.7266 - val_accuracy: 0.4867
#
# Epoch 00028: val_loss did not improve from 0.58728
# Epoch 29/1000
#  - 11s - loss: 0.6931 - accuracy: 0.5091 - val_loss: 0.6577 - val_accuracy: 0.4747
#
# Epoch 00029: val_loss did not improve from 0.58728
# Epoch 30/1000
#  - 11s - loss: 0.6938 - accuracy: 0.5046 - val_loss: 0.7243 - val_accuracy: 0.4785
#
# Epoch 00030: val_loss did not improve from 0.58728
# Epoch 31/1000
#  - 11s - loss: 0.6931 - accuracy: 0.5126 - val_loss: 0.6933 - val_accuracy: 0.5219
#
# Epoch 00031: val_loss did not improve from 0.58728
# Epoch 32/1000
#  - 11s - loss: 0.6933 - accuracy: 0.5123 - val_loss: 0.6940 - val_accuracy: 0.4719
#
# Epoch 00032: val_loss did not improve from 0.58728
# Epoch 33/1000
#  - 11s - loss: 0.6939 - accuracy: 0.5068 - val_loss: 0.6908 - val_accuracy: 0.4767
#
# Epoch 00033: val_loss did not improve from 0.58728
# Epoch 34/1000
#  - 11s - loss: 0.6933 - accuracy: 0.5088 - val_loss: 0.7242 - val_accuracy: 0.5260
#
# Epoch 00034: val_loss did not improve from 0.58728
# Epoch 35/1000
#  - 11s - loss: 0.6924 - accuracy: 0.5172 - val_loss: 0.7022 - val_accuracy: 0.5236
#
# Epoch 00035: val_loss did not improve from 0.58728
# Epoch 36/1000
#  - 11s - loss: 0.6936 - accuracy: 0.5069 - val_loss: 0.6623 - val_accuracy: 0.5105
#
# Epoch 00036: val_loss did not improve from 0.58728
# Epoch 37/1000
#  - 11s - loss: 0.6930 - accuracy: 0.5053 - val_loss: 0.6999 - val_accuracy: 0.5171
#
# Epoch 00037: val_loss did not improve from 0.58728
# Epoch 38/1000
#  - 11s - loss: 0.6927 - accuracy: 0.5199 - val_loss: 0.7150 - val_accuracy: 0.5284
#
# Epoch 00038: val_loss did not improve from 0.58728
# Epoch 39/1000
#  - 11s - loss: 0.6926 - accuracy: 0.5144 - val_loss: 0.6073 - val_accuracy: 0.5233
#
# Epoch 00039: val_loss did not improve from 0.58728
# Epoch 40/1000
#  - 11s - loss: 0.6920 - accuracy: 0.5124 - val_loss: 0.6992 - val_accuracy: 0.5009
#
# Epoch 00040: val_loss did not improve from 0.58728
# Epoch 41/1000
#  - 11s - loss: 0.6927 - accuracy: 0.5165 - val_loss: 0.7523 - val_accuracy: 0.4998
#
# Epoch 00041: val_loss did not improve from 0.58728
# Epoch 42/1000
#  - 11s - loss: 0.6922 - accuracy: 0.5111 - val_loss: 0.6670 - val_accuracy: 0.5022
#
# Epoch 00042: val_loss did not improve from 0.58728
# Epoch 43/1000
#  - 11s - loss: 0.6921 - accuracy: 0.5163 - val_loss: 0.7030 - val_accuracy: 0.5209
#
# Epoch 00043: val_loss did not improve from 0.58728
# Epoch 44/1000
#  - 11s - loss: 0.6917 - accuracy: 0.5129 - val_loss: 0.7156 - val_accuracy: 0.4881
#
# Epoch 00044: val_loss did not improve from 0.58728
# Epoch 45/1000
#  - 11s - loss: 0.6935 - accuracy: 0.5084 - val_loss: 0.6874 - val_accuracy: 0.4960
#
# Epoch 00045: val_loss did not improve from 0.58728
# Epoch 46/1000
#  - 11s - loss: 0.6921 - accuracy: 0.5138 - val_loss: 0.6453 - val_accuracy: 0.5260
#
# Epoch 00046: val_loss did not improve from 0.58728
# Epoch 47/1000
#  - 11s - loss: 0.6926 - accuracy: 0.5171 - val_loss: 0.6788 - val_accuracy: 0.5209
#
# Epoch 00047: val_loss did not improve from 0.58728
# Epoch 48/1000
#  - 11s - loss: 0.6925 - accuracy: 0.5176 - val_loss: 0.6875 - val_accuracy: 0.5026
#
# Epoch 00048: val_loss did not improve from 0.58728
# Epoch 49/1000
#  - 11s - loss: 0.6919 - accuracy: 0.5193 - val_loss: 0.7107 - val_accuracy: 0.4805
#
# Epoch 00049: val_loss did not improve from 0.58728
# Epoch 50/1000
#  - 11s - loss: 0.6918 - accuracy: 0.5177 - val_loss: 0.7081 - val_accuracy: 0.5202
#
# Epoch 00050: val_loss did not improve from 0.58728
# Epoch 51/1000
#  - 11s - loss: 0.6905 - accuracy: 0.5288 - val_loss: 0.7134 - val_accuracy: 0.4719
#
# Epoch 00051: val_loss did not improve from 0.58728
# Epoch 52/1000
#  - 11s - loss: 0.6925 - accuracy: 0.5221 - val_loss: 0.6708 - val_accuracy: 0.4933
#
# Epoch 00052: val_loss did not improve from 0.58728
# Epoch 53/1000
#  - 11s - loss: 0.6918 - accuracy: 0.5177 - val_loss: 0.6974 - val_accuracy: 0.5202
#
# Epoch 00053: val_loss did not improve from 0.58728
# Epoch 54/1000
#  - 11s - loss: 0.6905 - accuracy: 0.5305 - val_loss: 0.7036 - val_accuracy: 0.4933
#
# Epoch 00054: val_loss did not improve from 0.58728
# Epoch 55/1000
#  - 11s - loss: 0.6910 - accuracy: 0.5179 - val_loss: 0.7900 - val_accuracy: 0.5298
#
# Epoch 00055: val_loss did not improve from 0.58728
# Epoch 56/1000
#  - 11s - loss: 0.6913 - accuracy: 0.5269 - val_loss: 0.7122 - val_accuracy: 0.4802
#
# Epoch 00056: val_loss did not improve from 0.58728
# Epoch 57/1000
#  - 11s - loss: 0.6910 - accuracy: 0.5121 - val_loss: 0.6792 - val_accuracy: 0.4981
#
# Epoch 00057: val_loss did not improve from 0.58728
# Epoch 58/1000
#  - 11s - loss: 0.6909 - accuracy: 0.5237 - val_loss: 0.6610 - val_accuracy: 0.4940
#
# Epoch 00058: val_loss did not improve from 0.58728
# Epoch 59/1000
#  - 11s - loss: 0.6918 - accuracy: 0.5107 - val_loss: 0.6768 - val_accuracy: 0.4885
#
# Epoch 00059: val_loss did not improve from 0.58728
# Epoch 60/1000
#  - 11s - loss: 0.6917 - accuracy: 0.5153 - val_loss: 0.7155 - val_accuracy: 0.4912
#
# Epoch 00060: val_loss did not improve from 0.58728
# Epoch 61/1000
#  - 11s - loss: 0.6918 - accuracy: 0.5236 - val_loss: 0.6846 - val_accuracy: 0.4922
#
# Epoch 00061: val_loss did not improve from 0.58728
# Epoch 62/1000
#  - 11s - loss: 0.6910 - accuracy: 0.5144 - val_loss: 0.7012 - val_accuracy: 0.4943
#
# Epoch 00062: val_loss did not improve from 0.58728
# Epoch 63/1000
#  - 11s - loss: 0.6912 - accuracy: 0.5290 - val_loss: 0.6522 - val_accuracy: 0.4850
#
# Epoch 00063: val_loss did not improve from 0.58728
# Epoch 64/1000
#  - 11s - loss: 0.6911 - accuracy: 0.5323 - val_loss: 0.6696 - val_accuracy: 0.4874
#
# Epoch 00064: val_loss did not improve from 0.58728
# Epoch 65/1000
#  - 11s - loss: 0.6911 - accuracy: 0.5255 - val_loss: 0.6820 - val_accuracy: 0.4853
#
# Epoch 00065: val_loss did not improve from 0.58728
# Epoch 66/1000
#  - 11s - loss: 0.6914 - accuracy: 0.5128 - val_loss: 0.7039 - val_accuracy: 0.5081
#
# Epoch 00066: val_loss did not improve from 0.58728
# Epoch 67/1000
#  - 11s - loss: 0.6896 - accuracy: 0.5295 - val_loss: 0.6864 - val_accuracy: 0.5012
#
# Epoch 00067: val_loss did not improve from 0.58728
# Epoch 68/1000
#  - 11s - loss: 0.6903 - accuracy: 0.5347 - val_loss: 0.7006 - val_accuracy: 0.5109
#
# Epoch 00068: val_loss did not improve from 0.58728
# Epoch 69/1000
#  - 11s - loss: 0.6910 - accuracy: 0.5248 - val_loss: 0.6968 - val_accuracy: 0.4860
#
# Epoch 00069: val_loss did not improve from 0.58728
# Epoch 70/1000
#  - 11s - loss: 0.6906 - accuracy: 0.5236 - val_loss: 0.6826 - val_accuracy: 0.4802
#
# Epoch 00070: val_loss did not improve from 0.58728
# Epoch 71/1000
#  - 11s - loss: 0.6904 - accuracy: 0.5175 - val_loss: 0.6933 - val_accuracy: 0.4809
#
# Epoch 00071: val_loss did not improve from 0.58728
# Epoch 72/1000
#  - 11s - loss: 0.6912 - accuracy: 0.5247 - val_loss: 0.6700 - val_accuracy: 0.4909
#
# Epoch 00072: val_loss did not improve from 0.58728
# Epoch 73/1000
#  - 11s - loss: 0.6904 - accuracy: 0.5208 - val_loss: 0.6767 - val_accuracy: 0.4967
#
# Epoch 00073: val_loss did not improve from 0.58728
# Epoch 74/1000
#  - 11s - loss: 0.6903 - accuracy: 0.5221 - val_loss: 0.7174 - val_accuracy: 0.5064
#
# Epoch 00074: val_loss did not improve from 0.58728
# Epoch 75/1000
#  - 11s - loss: 0.6892 - accuracy: 0.5264 - val_loss: 0.7365 - val_accuracy: 0.5129
#
# Epoch 00075: val_loss did not improve from 0.58728
# Epoch 76/1000
#  - 11s - loss: 0.6889 - accuracy: 0.5352 - val_loss: 0.7173 - val_accuracy: 0.5153
#
# Epoch 00076: val_loss did not improve from 0.58728
# Epoch 77/1000
#  - 11s - loss: 0.6894 - accuracy: 0.5285 - val_loss: 0.7137 - val_accuracy: 0.4740
#
# Epoch 00077: val_loss did not improve from 0.58728
# Epoch 78/1000
#  - 11s - loss: 0.6897 - accuracy: 0.5183 - val_loss: 0.7066 - val_accuracy: 0.4881
#
# Epoch 00078: val_loss did not improve from 0.58728
# Epoch 79/1000
#  - 11s - loss: 0.6897 - accuracy: 0.5264 - val_loss: 0.7060 - val_accuracy: 0.5095
#
# Epoch 00079: val_loss did not improve from 0.58728
# Epoch 80/1000
#  - 11s - loss: 0.6890 - accuracy: 0.5300 - val_loss: 0.7750 - val_accuracy: 0.4867
#
# Epoch 00080: val_loss did not improve from 0.58728
# Epoch 81/1000
#  - 11s - loss: 0.6903 - accuracy: 0.5350 - val_loss: 0.6823 - val_accuracy: 0.4881
#
# Epoch 00081: val_loss did not improve from 0.58728
# Epoch 82/1000
#  - 11s - loss: 0.6888 - accuracy: 0.5340 - val_loss: 0.6991 - val_accuracy: 0.5205
#
# Epoch 00082: val_loss did not improve from 0.58728
# Epoch 83/1000
#  - 11s - loss: 0.6904 - accuracy: 0.5275 - val_loss: 0.6956 - val_accuracy: 0.5212
#
# Epoch 00083: val_loss did not improve from 0.58728
# Epoch 84/1000
#  - 11s - loss: 0.6885 - accuracy: 0.5294 - val_loss: 0.7042 - val_accuracy: 0.5033
#
# Epoch 00084: val_loss did not improve from 0.58728
# Epoch 85/1000
#  - 11s - loss: 0.6896 - accuracy: 0.5274 - val_loss: 0.7346 - val_accuracy: 0.5181
#
# Epoch 00085: val_loss did not improve from 0.58728
# Epoch 86/1000
#  - 11s - loss: 0.6902 - accuracy: 0.5241 - val_loss: 0.6338 - val_accuracy: 0.5184
#
# Epoch 00086: val_loss did not improve from 0.58728
# Epoch 87/1000
#  - 11s - loss: 0.6894 - accuracy: 0.5293 - val_loss: 0.6525 - val_accuracy: 0.5246
#
# Epoch 00087: val_loss did not improve from 0.58728
# Epoch 88/1000
#  - 11s - loss: 0.6894 - accuracy: 0.5257 - val_loss: 0.6962 - val_accuracy: 0.5060
#
# Epoch 00088: val_loss did not improve from 0.58728
# Epoch 89/1000
#  - 11s - loss: 0.6884 - accuracy: 0.5348 - val_loss: 0.6696 - val_accuracy: 0.5264
#
# Epoch 00089: val_loss did not improve from 0.58728
# Epoch 90/1000
#  - 11s - loss: 0.6877 - accuracy: 0.5370 - val_loss: 0.6945 - val_accuracy: 0.5119
#
# Epoch 00090: val_loss did not improve from 0.58728
# Epoch 91/1000
#  - 11s - loss: 0.6887 - accuracy: 0.5394 - val_loss: 0.6803 - val_accuracy: 0.4878
#
# Epoch 00091: val_loss did not improve from 0.58728
# Epoch 92/1000
#  - 11s - loss: 0.6898 - accuracy: 0.5301 - val_loss: 0.7294 - val_accuracy: 0.4902
#
# Epoch 00092: val_loss did not improve from 0.58728
# Epoch 93/1000
#  - 11s - loss: 0.6891 - accuracy: 0.5373 - val_loss: 0.7421 - val_accuracy: 0.4850
#
# Epoch 00093: val_loss did not improve from 0.58728
# Epoch 94/1000
#  - 11s - loss: 0.6888 - accuracy: 0.5287 - val_loss: 0.7492 - val_accuracy: 0.4850
#
# Epoch 00094: val_loss did not improve from 0.58728
# Epoch 95/1000
#  - 11s - loss: 0.6889 - accuracy: 0.5357 - val_loss: 0.7435 - val_accuracy: 0.4864
#
# Epoch 00095: val_loss did not improve from 0.58728
# Epoch 96/1000
#  - 11s - loss: 0.6870 - accuracy: 0.5463 - val_loss: 0.6879 - val_accuracy: 0.4847
#
# Epoch 00096: val_loss did not improve from 0.58728
# Epoch 97/1000
#  - 11s - loss: 0.6859 - accuracy: 0.5483 - val_loss: 0.7702 - val_accuracy: 0.4850
#
# Epoch 00097: val_loss did not improve from 0.58728
# Epoch 98/1000
#  - 11s - loss: 0.6872 - accuracy: 0.5372 - val_loss: 0.7453 - val_accuracy: 0.4795
#
# Epoch 00098: val_loss did not improve from 0.58728
# Epoch 99/1000
#  - 11s - loss: 0.6888 - accuracy: 0.5376 - val_loss: 0.6756 - val_accuracy: 0.4850
#
# Epoch 00099: val_loss did not improve from 0.58728
# Epoch 100/1000
#  - 11s - loss: 0.6865 - accuracy: 0.5447 - val_loss: 0.7028 - val_accuracy: 0.4736
#
# Epoch 00100: val_loss did not improve from 0.58728
# Epoch 101/1000
#  - 11s - loss: 0.6886 - accuracy: 0.5360 - val_loss: 0.7534 - val_accuracy: 0.4812
#
# Epoch 00101: val_loss did not improve from 0.58728
# Epoch 102/1000
#  - 11s - loss: 0.6883 - accuracy: 0.5386 - val_loss: 0.6556 - val_accuracy: 0.4953
#
# Epoch 00102: val_loss did not improve from 0.58728
# Epoch 103/1000
#  - 11s - loss: 0.6878 - accuracy: 0.5333 - val_loss: 0.7226 - val_accuracy: 0.4771
#
# Epoch 00103: val_loss did not improve from 0.58728
# Epoch 104/1000
#  - 11s - loss: 0.6872 - accuracy: 0.5405 - val_loss: 0.7514 - val_accuracy: 0.4840
#
# Epoch 00104: val_loss did not improve from 0.58728
# Epoch 105/1000
#  - 11s - loss: 0.6877 - accuracy: 0.5340 - val_loss: 0.6398 - val_accuracy: 0.4822
#
# Epoch 00105: val_loss did not improve from 0.58728
# Epoch 106/1000
#  - 11s - loss: 0.6865 - accuracy: 0.5432 - val_loss: 0.7320 - val_accuracy: 0.4902
#
# Epoch 00106: val_loss did not improve from 0.58728
# Epoch 107/1000
#  - 11s - loss: 0.6888 - accuracy: 0.5349 - val_loss: 0.6989 - val_accuracy: 0.4809
#
# Epoch 00107: val_loss did not improve from 0.58728
# Epoch 108/1000
#  - 11s - loss: 0.6860 - accuracy: 0.5422 - val_loss: 0.6814 - val_accuracy: 0.5084
#
# Epoch 00108: val_loss did not improve from 0.58728
# Epoch 109/1000
#  - 11s - loss: 0.6872 - accuracy: 0.5409 - val_loss: 0.7536 - val_accuracy: 0.4888
#
# Epoch 00109: val_loss did not improve from 0.58728
# Epoch 110/1000
#  - 11s - loss: 0.6857 - accuracy: 0.5416 - val_loss: 0.6929 - val_accuracy: 0.4874
#
# Epoch 00110: val_loss did not improve from 0.58728
# Epoch 111/1000
#  - 11s - loss: 0.6855 - accuracy: 0.5395 - val_loss: 0.6399 - val_accuracy: 0.4847
#
# Epoch 00111: val_loss did not improve from 0.58728
# Epoch 112/1000
#  - 11s - loss: 0.6872 - accuracy: 0.5419 - val_loss: 0.7093 - val_accuracy: 0.5047
#
# Epoch 00112: val_loss did not improve from 0.58728
# Epoch 113/1000
#  - 11s - loss: 0.6866 - accuracy: 0.5453 - val_loss: 0.6310 - val_accuracy: 0.4871
#
# Epoch 00113: val_loss did not improve from 0.58728
# Epoch 114/1000
#  - 11s - loss: 0.6854 - accuracy: 0.5432 - val_loss: 0.6692 - val_accuracy: 0.5043
#
# Epoch 00114: val_loss did not improve from 0.58728
# Epoch 115/1000
#  - 11s - loss: 0.6865 - accuracy: 0.5422 - val_loss: 0.7274 - val_accuracy: 0.4822
#
# Epoch 00115: val_loss did not improve from 0.58728
# Epoch 116/1000
#  - 11s - loss: 0.6855 - accuracy: 0.5388 - val_loss: 0.6325 - val_accuracy: 0.5133
#
# Epoch 00116: val_loss did not improve from 0.58728
# Epoch 117/1000
#  - 11s - loss: 0.6853 - accuracy: 0.5457 - val_loss: 0.6614 - val_accuracy: 0.4936
#
# Epoch 00117: val_loss did not improve from 0.58728
# Epoch 118/1000
#  - 11s - loss: 0.6856 - accuracy: 0.5467 - val_loss: 0.7207 - val_accuracy: 0.4988
#
# Epoch 00118: val_loss did not improve from 0.58728
# Epoch 119/1000
#  - 11s - loss: 0.6842 - accuracy: 0.5485 - val_loss: 0.6869 - val_accuracy: 0.5095
#
# Epoch 00119: val_loss did not improve from 0.58728
# Epoch 120/1000
#  - 11s - loss: 0.6845 - accuracy: 0.5411 - val_loss: 0.6819 - val_accuracy: 0.5129
#
# Epoch 00120: val_loss did not improve from 0.58728
# Epoch 121/1000
#  - 11s - loss: 0.6854 - accuracy: 0.5413 - val_loss: 0.6643 - val_accuracy: 0.4895
#
# Epoch 00121: val_loss did not improve from 0.58728
# Epoch 122/1000
#  - 11s - loss: 0.6836 - accuracy: 0.5478 - val_loss: 0.6774 - val_accuracy: 0.4978
#
# Epoch 00122: val_loss did not improve from 0.58728
# Epoch 123/1000
#  - 11s - loss: 0.6838 - accuracy: 0.5453 - val_loss: 0.5970 - val_accuracy: 0.5153
#
# Epoch 00123: val_loss did not improve from 0.58728
# Epoch 124/1000
#  - 11s - loss: 0.6831 - accuracy: 0.5501 - val_loss: 0.6644 - val_accuracy: 0.4891
#
# Epoch 00124: val_loss did not improve from 0.58728
# Epoch 125/1000
#  - 11s - loss: 0.6830 - accuracy: 0.5395 - val_loss: 0.6996 - val_accuracy: 0.5026
#
# Epoch 00125: val_loss did not improve from 0.58728
# Epoch 126/1000
#  - 11s - loss: 0.6822 - accuracy: 0.5460 - val_loss: 0.6711 - val_accuracy: 0.5053
#
# Epoch 00126: val_loss did not improve from 0.58728
# Epoch 127/1000
#  - 11s - loss: 0.6837 - accuracy: 0.5522 - val_loss: 0.6835 - val_accuracy: 0.5126
#
# Epoch 00127: val_loss did not improve from 0.58728
# Epoch 128/1000
#  - 11s - loss: 0.6840 - accuracy: 0.5470 - val_loss: 0.6933 - val_accuracy: 0.5205
#
# Epoch 00128: val_loss did not improve from 0.58728
# Epoch 129/1000
#  - 11s - loss: 0.6848 - accuracy: 0.5379 - val_loss: 0.6977 - val_accuracy: 0.5198
#
# Epoch 00129: val_loss did not improve from 0.58728
# Epoch 130/1000
#  - 11s - loss: 0.6829 - accuracy: 0.5514 - val_loss: 0.6216 - val_accuracy: 0.5126
#
# Epoch 00130: val_loss did not improve from 0.58728
# Epoch 131/1000
#  - 11s - loss: 0.6833 - accuracy: 0.5527 - val_loss: 0.6607 - val_accuracy: 0.5202
#
# Epoch 00131: val_loss did not improve from 0.58728
# Epoch 132/1000
#  - 11s - loss: 0.6830 - accuracy: 0.5484 - val_loss: 0.6614 - val_accuracy: 0.5136
#
# Epoch 00132: val_loss did not improve from 0.58728
# Epoch 133/1000
#  - 11s - loss: 0.6839 - accuracy: 0.5488 - val_loss: 0.7177 - val_accuracy: 0.4998
#
# Epoch 00133: val_loss did not improve from 0.58728
# Epoch 134/1000
#  - 11s - loss: 0.6838 - accuracy: 0.5478 - val_loss: 0.7385 - val_accuracy: 0.5012
#
# Epoch 00134: val_loss did not improve from 0.58728
# Epoch 135/1000
#  - 11s - loss: 0.6819 - accuracy: 0.5493 - val_loss: 0.7260 - val_accuracy: 0.4947
#
# Epoch 00135: val_loss did not improve from 0.58728
# Epoch 136/1000
#  - 11s - loss: 0.6801 - accuracy: 0.5560 - val_loss: 0.6519 - val_accuracy: 0.5115
#
# Epoch 00136: val_loss did not improve from 0.58728
# Epoch 137/1000
#  - 11s - loss: 0.6800 - accuracy: 0.5600 - val_loss: 0.6822 - val_accuracy: 0.4953
#
# Epoch 00137: val_loss did not improve from 0.58728
# Epoch 138/1000
#  - 11s - loss: 0.6808 - accuracy: 0.5541 - val_loss: 0.7661 - val_accuracy: 0.5136
#
# Epoch 00138: val_loss did not improve from 0.58728
# Epoch 139/1000
#  - 11s - loss: 0.6822 - accuracy: 0.5490 - val_loss: 0.6588 - val_accuracy: 0.5150
#
# Epoch 00139: val_loss did not improve from 0.58728
# Epoch 140/1000
#  - 11s - loss: 0.6814 - accuracy: 0.5657 - val_loss: 0.7819 - val_accuracy: 0.4902
#
# Epoch 00140: val_loss did not improve from 0.58728
# Epoch 141/1000
#  - 11s - loss: 0.6805 - accuracy: 0.5554 - val_loss: 0.6080 - val_accuracy: 0.5026
#
# Epoch 00141: val_loss did not improve from 0.58728
# Epoch 142/1000
#  - 11s - loss: 0.6787 - accuracy: 0.5613 - val_loss: 0.7068 - val_accuracy: 0.5119
#
# Epoch 00142: val_loss did not improve from 0.58728
# Epoch 143/1000
#  - 11s - loss: 0.6806 - accuracy: 0.5515 - val_loss: 0.6867 - val_accuracy: 0.5164
#
# Epoch 00143: val_loss did not improve from 0.58728
# Epoch 144/1000
#  - 11s - loss: 0.6813 - accuracy: 0.5542 - val_loss: 0.6179 - val_accuracy: 0.5098
#
# Epoch 00144: val_loss did not improve from 0.58728
# Epoch 145/1000
#  - 11s - loss: 0.6793 - accuracy: 0.5554 - val_loss: 0.7167 - val_accuracy: 0.4991
#
# Epoch 00145: val_loss did not improve from 0.58728
# Epoch 146/1000
#  - 11s - loss: 0.6797 - accuracy: 0.5560 - val_loss: 0.6266 - val_accuracy: 0.5012
#
# Epoch 00146: val_loss did not improve from 0.58728
# Epoch 147/1000
#  - 11s - loss: 0.6797 - accuracy: 0.5600 - val_loss: 0.7192 - val_accuracy: 0.4940
#
# Epoch 00147: val_loss did not improve from 0.58728
# Epoch 148/1000
#  - 11s - loss: 0.6806 - accuracy: 0.5495 - val_loss: 0.7429 - val_accuracy: 0.5033
#
# Epoch 00148: val_loss did not improve from 0.58728
# Epoch 149/1000
#  - 11s - loss: 0.6805 - accuracy: 0.5599 - val_loss: 0.6795 - val_accuracy: 0.5029
#
# Epoch 00149: val_loss did not improve from 0.58728
# Epoch 150/1000
#  - 11s - loss: 0.6785 - accuracy: 0.5596 - val_loss: 0.7784 - val_accuracy: 0.5036
#
# Epoch 00150: val_loss did not improve from 0.58728
# Epoch 151/1000
#  - 11s - loss: 0.6782 - accuracy: 0.5580 - val_loss: 0.6766 - val_accuracy: 0.5153
#
# Epoch 00151: val_loss did not improve from 0.58728
# Epoch 152/1000
#  - 11s - loss: 0.6783 - accuracy: 0.5647 - val_loss: 0.7234 - val_accuracy: 0.4950
#
# Epoch 00152: val_loss did not improve from 0.58728
# Epoch 153/1000
#  - 11s - loss: 0.6757 - accuracy: 0.5671 - val_loss: 0.6391 - val_accuracy: 0.4953
#
# Epoch 00153: val_loss did not improve from 0.58728
# Epoch 154/1000
#  - 11s - loss: 0.6792 - accuracy: 0.5579 - val_loss: 0.7696 - val_accuracy: 0.4971
#
# Epoch 00154: val_loss did not improve from 0.58728
# Epoch 155/1000
#  - 11s - loss: 0.6789 - accuracy: 0.5627 - val_loss: 0.6398 - val_accuracy: 0.5198
#
# Epoch 00155: val_loss did not improve from 0.58728
# Epoch 156/1000
#  - 11s - loss: 0.6752 - accuracy: 0.5607 - val_loss: 0.7417 - val_accuracy: 0.4943
#
# Epoch 00156: val_loss did not improve from 0.58728
# Epoch 157/1000
#  - 11s - loss: 0.6748 - accuracy: 0.5677 - val_loss: 0.6306 - val_accuracy: 0.5153
#
# Epoch 00157: val_loss did not improve from 0.58728
# Epoch 158/1000
#  - 11s - loss: 0.6780 - accuracy: 0.5603 - val_loss: 0.8762 - val_accuracy: 0.5178
#
# Epoch 00158: val_loss did not improve from 0.58728
# Epoch 159/1000
#  - 11s - loss: 0.6739 - accuracy: 0.5731 - val_loss: 0.7431 - val_accuracy: 0.5126
#
# Epoch 00159: val_loss did not improve from 0.58728
# Epoch 160/1000
#  - 11s - loss: 0.6754 - accuracy: 0.5675 - val_loss: 0.6932 - val_accuracy: 0.5167
#
# Epoch 00160: val_loss did not improve from 0.58728
# Epoch 161/1000
#  - 11s - loss: 0.6772 - accuracy: 0.5621 - val_loss: 0.8255 - val_accuracy: 0.5219
#
# Epoch 00161: val_loss did not improve from 0.58728
# Epoch 162/1000
#  - 11s - loss: 0.6727 - accuracy: 0.5718 - val_loss: 0.8404 - val_accuracy: 0.5133
#
# Epoch 00162: val_loss did not improve from 0.58728
# Epoch 163/1000
#  - 11s - loss: 0.6774 - accuracy: 0.5570 - val_loss: 0.5383 - val_accuracy: 0.5036
#
# Epoch 00163: val_loss improved from 0.58728 to 0.53833, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_non_shuffle_ex_maxabs.h5
# Epoch 164/1000
#  - 11s - loss: 0.6745 - accuracy: 0.5688 - val_loss: 0.6654 - val_accuracy: 0.5047
#
# Epoch 00164: val_loss did not improve from 0.53833
# Epoch 165/1000
#  - 11s - loss: 0.6741 - accuracy: 0.5680 - val_loss: 0.6696 - val_accuracy: 0.4988
#
# Epoch 00165: val_loss did not improve from 0.53833
# Epoch 166/1000
#  - 11s - loss: 0.6762 - accuracy: 0.5650 - val_loss: 0.7457 - val_accuracy: 0.5088
#
# Epoch 00166: val_loss did not improve from 0.53833
# Epoch 167/1000
#  - 11s - loss: 0.6721 - accuracy: 0.5704 - val_loss: 0.6017 - val_accuracy: 0.5188
#
# Epoch 00167: val_loss did not improve from 0.53833
# Epoch 168/1000
#  - 11s - loss: 0.6694 - accuracy: 0.5791 - val_loss: 0.7585 - val_accuracy: 0.5147
#
# Epoch 00168: val_loss did not improve from 0.53833
# Epoch 169/1000
#  - 11s - loss: 0.6734 - accuracy: 0.5775 - val_loss: 0.7113 - val_accuracy: 0.5157
#
# Epoch 00169: val_loss did not improve from 0.53833
# Epoch 170/1000
#  - 11s - loss: 0.6711 - accuracy: 0.5765 - val_loss: 0.6217 - val_accuracy: 0.5191
#
# Epoch 00170: val_loss did not improve from 0.53833
# Epoch 171/1000
#  - 11s - loss: 0.6730 - accuracy: 0.5665 - val_loss: 0.6924 - val_accuracy: 0.5081
#
# Epoch 00171: val_loss did not improve from 0.53833
# Epoch 172/1000
#  - 11s - loss: 0.6710 - accuracy: 0.5693 - val_loss: 0.7028 - val_accuracy: 0.5184
#
# Epoch 00172: val_loss did not improve from 0.53833
# Epoch 173/1000
#  - 11s - loss: 0.6739 - accuracy: 0.5702 - val_loss: 0.5835 - val_accuracy: 0.5160
#
# Epoch 00173: val_loss did not improve from 0.53833
# Epoch 174/1000
#  - 11s - loss: 0.6724 - accuracy: 0.5726 - val_loss: 0.7593 - val_accuracy: 0.5084
#
# Epoch 00174: val_loss did not improve from 0.53833
# Epoch 175/1000
#  - 11s - loss: 0.6731 - accuracy: 0.5730 - val_loss: 0.7703 - val_accuracy: 0.5050
#
# Epoch 00175: val_loss did not improve from 0.53833
# Epoch 176/1000
#  - 11s - loss: 0.6699 - accuracy: 0.5755 - val_loss: 0.6930 - val_accuracy: 0.5153
#
# Epoch 00176: val_loss did not improve from 0.53833
# Epoch 177/1000
#  - 11s - loss: 0.6698 - accuracy: 0.5756 - val_loss: 0.6681 - val_accuracy: 0.5143
#
# Epoch 00177: val_loss did not improve from 0.53833
# Epoch 178/1000
#  - 11s - loss: 0.6719 - accuracy: 0.5739 - val_loss: 0.7391 - val_accuracy: 0.5081
#
# Epoch 00178: val_loss did not improve from 0.53833
# Epoch 179/1000
#  - 11s - loss: 0.6718 - accuracy: 0.5715 - val_loss: 0.7545 - val_accuracy: 0.5174
#
# Epoch 00179: val_loss did not improve from 0.53833
# Epoch 180/1000
#  - 11s - loss: 0.6700 - accuracy: 0.5777 - val_loss: 0.6729 - val_accuracy: 0.5209
#
# Epoch 00180: val_loss did not improve from 0.53833
# Epoch 181/1000
#  - 11s - loss: 0.6681 - accuracy: 0.5783 - val_loss: 0.7180 - val_accuracy: 0.5240
#
# Epoch 00181: val_loss did not improve from 0.53833
# Epoch 182/1000
#  - 11s - loss: 0.6715 - accuracy: 0.5701 - val_loss: 0.6217 - val_accuracy: 0.5171
#
# Epoch 00182: val_loss did not improve from 0.53833
# Epoch 183/1000
#  - 11s - loss: 0.6693 - accuracy: 0.5772 - val_loss: 0.6846 - val_accuracy: 0.5184
#
# Epoch 00183: val_loss did not improve from 0.53833
# Epoch 184/1000
#  - 11s - loss: 0.6684 - accuracy: 0.5837 - val_loss: 0.6695 - val_accuracy: 0.5246
#
# Epoch 00184: val_loss did not improve from 0.53833
# Epoch 185/1000
#  - 11s - loss: 0.6670 - accuracy: 0.5879 - val_loss: 0.7494 - val_accuracy: 0.5209
#
# Epoch 00185: val_loss did not improve from 0.53833
# Epoch 186/1000
#  - 11s - loss: 0.6680 - accuracy: 0.5817 - val_loss: 0.7561 - val_accuracy: 0.5171
#
# Epoch 00186: val_loss did not improve from 0.53833
# Epoch 187/1000
#  - 11s - loss: 0.6694 - accuracy: 0.5824 - val_loss: 0.8239 - val_accuracy: 0.5040
#
# Epoch 00187: val_loss did not improve from 0.53833
# Epoch 188/1000
#  - 11s - loss: 0.6690 - accuracy: 0.5829 - val_loss: 0.7877 - val_accuracy: 0.5205
#
# Epoch 00188: val_loss did not improve from 0.53833
# Epoch 189/1000
#  - 11s - loss: 0.6672 - accuracy: 0.5853 - val_loss: 0.6532 - val_accuracy: 0.5209
#
# Epoch 00189: val_loss did not improve from 0.53833
# Epoch 190/1000
#  - 11s - loss: 0.6672 - accuracy: 0.5788 - val_loss: 0.8075 - val_accuracy: 0.5229
#
# Epoch 00190: val_loss did not improve from 0.53833
# Epoch 191/1000
#  - 11s - loss: 0.6683 - accuracy: 0.5833 - val_loss: 0.6997 - val_accuracy: 0.5212
#
# Epoch 00191: val_loss did not improve from 0.53833
# Epoch 192/1000
#  - 11s - loss: 0.6687 - accuracy: 0.5691 - val_loss: 0.6842 - val_accuracy: 0.5119
#
# Epoch 00192: val_loss did not improve from 0.53833
# Epoch 193/1000
#  - 11s - loss: 0.6674 - accuracy: 0.5806 - val_loss: 0.6468 - val_accuracy: 0.5102
#
# Epoch 00193: val_loss did not improve from 0.53833
# Epoch 194/1000
#  - 11s - loss: 0.6661 - accuracy: 0.5872 - val_loss: 0.6891 - val_accuracy: 0.5202
#
# Epoch 00194: val_loss did not improve from 0.53833
# Epoch 195/1000
#  - 11s - loss: 0.6677 - accuracy: 0.5823 - val_loss: 0.6952 - val_accuracy: 0.5195
#
# Epoch 00195: val_loss did not improve from 0.53833
# Epoch 196/1000
#  - 11s - loss: 0.6620 - accuracy: 0.5930 - val_loss: 0.7058 - val_accuracy: 0.5188
#
# Epoch 00196: val_loss did not improve from 0.53833
# Epoch 197/1000
#  - 11s - loss: 0.6672 - accuracy: 0.5748 - val_loss: 0.7322 - val_accuracy: 0.5088
#
# Epoch 00197: val_loss did not improve from 0.53833
# Epoch 198/1000
#  - 11s - loss: 0.6656 - accuracy: 0.5843 - val_loss: 0.5671 - val_accuracy: 0.5243
#
# Epoch 00198: val_loss did not improve from 0.53833
# Epoch 199/1000
#  - 11s - loss: 0.6654 - accuracy: 0.5848 - val_loss: 0.6780 - val_accuracy: 0.5074
#
# Epoch 00199: val_loss did not improve from 0.53833
# Epoch 200/1000
#  - 11s - loss: 0.6661 - accuracy: 0.5811 - val_loss: 0.7895 - val_accuracy: 0.4933
#
# Epoch 00200: val_loss did not improve from 0.53833
# Epoch 201/1000
#  - 11s - loss: 0.6619 - accuracy: 0.5846 - val_loss: 0.7162 - val_accuracy: 0.5178
#
# Epoch 00201: val_loss did not improve from 0.53833
# Epoch 202/1000
#  - 11s - loss: 0.6596 - accuracy: 0.6007 - val_loss: 0.7755 - val_accuracy: 0.5098
#
# Epoch 00202: val_loss did not improve from 0.53833
# Epoch 203/1000
#  - 11s - loss: 0.6623 - accuracy: 0.5841 - val_loss: 0.7079 - val_accuracy: 0.5105
#
# Epoch 00203: val_loss did not improve from 0.53833
# Epoch 204/1000
#  - 11s - loss: 0.6621 - accuracy: 0.5886 - val_loss: 0.7995 - val_accuracy: 0.5143
#
# Epoch 00204: val_loss did not improve from 0.53833
# Epoch 205/1000
#  - 11s - loss: 0.6642 - accuracy: 0.5881 - val_loss: 0.5468 - val_accuracy: 0.5109
#
# Epoch 00205: val_loss did not improve from 0.53833
# Epoch 206/1000
#  - 11s - loss: 0.6608 - accuracy: 0.6008 - val_loss: 0.6951 - val_accuracy: 0.5140
#
# Epoch 00206: val_loss did not improve from 0.53833
# Epoch 207/1000
#  - 11s - loss: 0.6591 - accuracy: 0.5931 - val_loss: 0.7463 - val_accuracy: 0.5126
#
# Epoch 00207: val_loss did not improve from 0.53833
# Epoch 208/1000
#  - 11s - loss: 0.6614 - accuracy: 0.5888 - val_loss: 0.6120 - val_accuracy: 0.5191
#
# Epoch 00208: val_loss did not improve from 0.53833
# Epoch 209/1000
#  - 11s - loss: 0.6610 - accuracy: 0.5906 - val_loss: 0.7649 - val_accuracy: 0.5129
#
# Epoch 00209: val_loss did not improve from 0.53833
# Epoch 210/1000
#  - 11s - loss: 0.6617 - accuracy: 0.5907 - val_loss: 0.7025 - val_accuracy: 0.5198
#
# Epoch 00210: val_loss did not improve from 0.53833
# Epoch 211/1000
#  - 11s - loss: 0.6652 - accuracy: 0.5865 - val_loss: 0.7351 - val_accuracy: 0.5022
#
# Epoch 00211: val_loss did not improve from 0.53833
# Epoch 212/1000
#  - 11s - loss: 0.6619 - accuracy: 0.5923 - val_loss: 0.6910 - val_accuracy: 0.5067
#
# Epoch 00212: val_loss did not improve from 0.53833
# Epoch 213/1000
#  - 11s - loss: 0.6598 - accuracy: 0.5950 - val_loss: 0.6119 - val_accuracy: 0.5184
#
# Epoch 00213: val_loss did not improve from 0.53833
# Epoch 214/1000
#  - 11s - loss: 0.6605 - accuracy: 0.5900 - val_loss: 0.8200 - val_accuracy: 0.5195
#
# Epoch 00214: val_loss did not improve from 0.53833
# Epoch 215/1000
#  - 11s - loss: 0.6597 - accuracy: 0.5961 - val_loss: 0.6446 - val_accuracy: 0.5147
#
# Epoch 00215: val_loss did not improve from 0.53833
# Epoch 216/1000
#  - 11s - loss: 0.6548 - accuracy: 0.6057 - val_loss: 0.7677 - val_accuracy: 0.5136
#
# Epoch 00216: val_loss did not improve from 0.53833
# Epoch 217/1000
#  - 11s - loss: 0.6607 - accuracy: 0.5979 - val_loss: 0.6692 - val_accuracy: 0.5115
#
# Epoch 00217: val_loss did not improve from 0.53833
# Epoch 218/1000
#  - 11s - loss: 0.6560 - accuracy: 0.6007 - val_loss: 0.6370 - val_accuracy: 0.5184
#
# Epoch 00218: val_loss did not improve from 0.53833
# Epoch 219/1000
#  - 11s - loss: 0.6603 - accuracy: 0.5930 - val_loss: 0.7251 - val_accuracy: 0.5133
#
# Epoch 00219: val_loss did not improve from 0.53833
# Epoch 220/1000
#  - 11s - loss: 0.6563 - accuracy: 0.5962 - val_loss: 0.5884 - val_accuracy: 0.5181
#
# Epoch 00220: val_loss did not improve from 0.53833
# Epoch 221/1000
#  - 11s - loss: 0.6570 - accuracy: 0.5992 - val_loss: 0.5958 - val_accuracy: 0.5122
#
# Epoch 00221: val_loss did not improve from 0.53833
# Epoch 222/1000
#  - 11s - loss: 0.6556 - accuracy: 0.6007 - val_loss: 0.7621 - val_accuracy: 0.5198
#
# Epoch 00222: val_loss did not improve from 0.53833
# Epoch 223/1000
#  - 11s - loss: 0.6572 - accuracy: 0.5966 - val_loss: 0.7034 - val_accuracy: 0.5150
#
# Epoch 00223: val_loss did not improve from 0.53833
# Epoch 224/1000
#  - 11s - loss: 0.6554 - accuracy: 0.5934 - val_loss: 0.5880 - val_accuracy: 0.4984
#
# Epoch 00224: val_loss did not improve from 0.53833
# Epoch 225/1000
#  - 11s - loss: 0.6563 - accuracy: 0.5987 - val_loss: 0.6626 - val_accuracy: 0.4984
#
# Epoch 00225: val_loss did not improve from 0.53833
# Epoch 226/1000
#  - 11s - loss: 0.6582 - accuracy: 0.5901 - val_loss: 0.6484 - val_accuracy: 0.5057
#
# Epoch 00226: val_loss did not improve from 0.53833
# Epoch 227/1000
#  - 11s - loss: 0.6519 - accuracy: 0.6084 - val_loss: 0.8189 - val_accuracy: 0.5019
#
# Epoch 00227: val_loss did not improve from 0.53833
# Epoch 228/1000
#  - 11s - loss: 0.6528 - accuracy: 0.6016 - val_loss: 0.6542 - val_accuracy: 0.5150
#
# Epoch 00228: val_loss did not improve from 0.53833
# Epoch 229/1000
#  - 11s - loss: 0.6529 - accuracy: 0.6049 - val_loss: 0.5150 - val_accuracy: 0.5236
#
# Epoch 00229: val_loss improved from 0.53833 to 0.51499, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_non_shuffle_ex_maxabs.h5
# Epoch 230/1000
#  - 11s - loss: 0.6477 - accuracy: 0.6085 - val_loss: 0.6735 - val_accuracy: 0.5291
#
# Epoch 00230: val_loss did not improve from 0.51499
# Epoch 231/1000
#  - 11s - loss: 0.6503 - accuracy: 0.6051 - val_loss: 0.5756 - val_accuracy: 0.5246
#
# Epoch 00231: val_loss did not improve from 0.51499
# Epoch 232/1000
#  - 11s - loss: 0.6526 - accuracy: 0.6011 - val_loss: 0.6003 - val_accuracy: 0.5202
#
# Epoch 00232: val_loss did not improve from 0.51499
# Epoch 233/1000
#  - 11s - loss: 0.6522 - accuracy: 0.6094 - val_loss: 0.6711 - val_accuracy: 0.5160
#
# Epoch 00233: val_loss did not improve from 0.51499
# Epoch 234/1000
#  - 11s - loss: 0.6510 - accuracy: 0.6083 - val_loss: 0.6904 - val_accuracy: 0.5160
#
# Epoch 00234: val_loss did not improve from 0.51499
# Epoch 235/1000
#  - 11s - loss: 0.6515 - accuracy: 0.6108 - val_loss: 0.8623 - val_accuracy: 0.5112
#
# Epoch 00235: val_loss did not improve from 0.51499
# Epoch 236/1000
#  - 11s - loss: 0.6527 - accuracy: 0.6073 - val_loss: 0.6972 - val_accuracy: 0.4971
#
# Epoch 00236: val_loss did not improve from 0.51499
# Epoch 237/1000
#  - 11s - loss: 0.6507 - accuracy: 0.6093 - val_loss: 0.7547 - val_accuracy: 0.5078
#
# Epoch 00237: val_loss did not improve from 0.51499
# Epoch 238/1000
#  - 11s - loss: 0.6478 - accuracy: 0.6096 - val_loss: 0.6440 - val_accuracy: 0.5184
#
# Epoch 00238: val_loss did not improve from 0.51499
# Epoch 239/1000
#  - 11s - loss: 0.6486 - accuracy: 0.6118 - val_loss: 0.8970 - val_accuracy: 0.5064
#
# Epoch 00239: val_loss did not improve from 0.51499
# Epoch 240/1000
#  - 11s - loss: 0.6469 - accuracy: 0.6081 - val_loss: 0.6501 - val_accuracy: 0.5098
#
# Epoch 00240: val_loss did not improve from 0.51499
# Epoch 241/1000
#  - 11s - loss: 0.6451 - accuracy: 0.6211 - val_loss: 0.6653 - val_accuracy: 0.5016
#
# Epoch 00241: val_loss did not improve from 0.51499
# Epoch 242/1000
#  - 11s - loss: 0.6510 - accuracy: 0.6051 - val_loss: 0.7771 - val_accuracy: 0.4964
#
# Epoch 00242: val_loss did not improve from 0.51499
# Epoch 243/1000
#  - 11s - loss: 0.6496 - accuracy: 0.6045 - val_loss: 0.6471 - val_accuracy: 0.5067
#
# Epoch 00243: val_loss did not improve from 0.51499
# Epoch 244/1000
#  - 11s - loss: 0.6484 - accuracy: 0.6114 - val_loss: 0.7468 - val_accuracy: 0.5143
#
# Epoch 00244: val_loss did not improve from 0.51499
# Epoch 245/1000
#  - 11s - loss: 0.6469 - accuracy: 0.6160 - val_loss: 0.6009 - val_accuracy: 0.5105
#
# Epoch 00245: val_loss did not improve from 0.51499
# Epoch 246/1000
#  - 11s - loss: 0.6460 - accuracy: 0.6168 - val_loss: 0.7443 - val_accuracy: 0.5016
#
# Epoch 00246: val_loss did not improve from 0.51499
# Epoch 247/1000
#  - 11s - loss: 0.6480 - accuracy: 0.6104 - val_loss: 0.6696 - val_accuracy: 0.4947
#
# Epoch 00247: val_loss did not improve from 0.51499
# Epoch 248/1000
#  - 11s - loss: 0.6458 - accuracy: 0.6128 - val_loss: 0.7779 - val_accuracy: 0.5171
#
# Epoch 00248: val_loss did not improve from 0.51499
# Epoch 249/1000
#  - 11s - loss: 0.6478 - accuracy: 0.6191 - val_loss: 0.6500 - val_accuracy: 0.5078
#
# Epoch 00249: val_loss did not improve from 0.51499
# Epoch 250/1000
#  - 11s - loss: 0.6443 - accuracy: 0.6160 - val_loss: 0.6416 - val_accuracy: 0.5043
#
# Epoch 00250: val_loss did not improve from 0.51499
# Epoch 251/1000
#  - 11s - loss: 0.6415 - accuracy: 0.6149 - val_loss: 0.6914 - val_accuracy: 0.5064
#
# Epoch 00251: val_loss did not improve from 0.51499
# Epoch 252/1000
#  - 11s - loss: 0.6434 - accuracy: 0.6101 - val_loss: 0.7678 - val_accuracy: 0.5043
#
# Epoch 00252: val_loss did not improve from 0.51499
# Epoch 253/1000
#  - 11s - loss: 0.6503 - accuracy: 0.6042 - val_loss: 0.6867 - val_accuracy: 0.5126
#
# Epoch 00253: val_loss did not improve from 0.51499
# Epoch 254/1000
#  - 11s - loss: 0.6413 - accuracy: 0.6205 - val_loss: 0.7663 - val_accuracy: 0.5074
#
# Epoch 00254: val_loss did not improve from 0.51499
# Epoch 255/1000
#  - 11s - loss: 0.6390 - accuracy: 0.6169 - val_loss: 0.9246 - val_accuracy: 0.5053
#
# Epoch 00255: val_loss did not improve from 0.51499
# Epoch 256/1000
#  - 11s - loss: 0.6385 - accuracy: 0.6224 - val_loss: 0.6883 - val_accuracy: 0.5060
#
# Epoch 00256: val_loss did not improve from 0.51499
# Epoch 257/1000
#  - 11s - loss: 0.6391 - accuracy: 0.6215 - val_loss: 0.7078 - val_accuracy: 0.5109
#
# Epoch 00257: val_loss did not improve from 0.51499
# Epoch 258/1000
#  - 11s - loss: 0.6402 - accuracy: 0.6142 - val_loss: 0.6858 - val_accuracy: 0.5047
#
# Epoch 00258: val_loss did not improve from 0.51499
# Epoch 259/1000
#  - 11s - loss: 0.6410 - accuracy: 0.6161 - val_loss: 0.5771 - val_accuracy: 0.5198
#
# Epoch 00259: val_loss did not improve from 0.51499
# Epoch 260/1000
#  - 11s - loss: 0.6397 - accuracy: 0.6173 - val_loss: 0.6011 - val_accuracy: 0.5143
#
# Epoch 00260: val_loss did not improve from 0.51499
# Epoch 261/1000
#  - 11s - loss: 0.6382 - accuracy: 0.6227 - val_loss: 0.5333 - val_accuracy: 0.5026
#
# Epoch 00261: val_loss did not improve from 0.51499
# Epoch 262/1000
#  - 11s - loss: 0.6393 - accuracy: 0.6161 - val_loss: 0.6640 - val_accuracy: 0.5105
#
# Epoch 00262: val_loss did not improve from 0.51499
# Epoch 263/1000
#  - 11s - loss: 0.6428 - accuracy: 0.6162 - val_loss: 0.8256 - val_accuracy: 0.5005
#
# Epoch 00263: val_loss did not improve from 0.51499
# Epoch 264/1000
#  - 11s - loss: 0.6384 - accuracy: 0.6185 - val_loss: 0.6604 - val_accuracy: 0.5081
#
# Epoch 00264: val_loss did not improve from 0.51499
# Epoch 265/1000
#  - 11s - loss: 0.6385 - accuracy: 0.6208 - val_loss: 0.6460 - val_accuracy: 0.5095
#
# Epoch 00265: val_loss did not improve from 0.51499
# Epoch 266/1000
#  - 11s - loss: 0.6399 - accuracy: 0.6185 - val_loss: 0.7259 - val_accuracy: 0.5057
#
# Epoch 00266: val_loss did not improve from 0.51499
# Epoch 267/1000
#  - 11s - loss: 0.6383 - accuracy: 0.6165 - val_loss: 0.6514 - val_accuracy: 0.5181
#
# Epoch 00267: val_loss did not improve from 0.51499
# Epoch 268/1000
#  - 11s - loss: 0.6388 - accuracy: 0.6189 - val_loss: 0.6707 - val_accuracy: 0.5043
#
# Epoch 00268: val_loss did not improve from 0.51499
# Epoch 269/1000
#  - 11s - loss: 0.6395 - accuracy: 0.6239 - val_loss: 0.6382 - val_accuracy: 0.5081
#
# Epoch 00269: val_loss did not improve from 0.51499
# Epoch 270/1000
#  - 11s - loss: 0.6397 - accuracy: 0.6164 - val_loss: 0.6416 - val_accuracy: 0.5098
#
# Epoch 00270: val_loss did not improve from 0.51499
# Epoch 271/1000
#  - 11s - loss: 0.6354 - accuracy: 0.6243 - val_loss: 0.6563 - val_accuracy: 0.5043
#
# Epoch 00271: val_loss did not improve from 0.51499
# Epoch 272/1000
#  - 11s - loss: 0.6352 - accuracy: 0.6262 - val_loss: 0.5934 - val_accuracy: 0.5074
#
# Epoch 00272: val_loss did not improve from 0.51499
# Epoch 273/1000
#  - 11s - loss: 0.6334 - accuracy: 0.6276 - val_loss: 0.7098 - val_accuracy: 0.5112
#
# Epoch 00273: val_loss did not improve from 0.51499
# Epoch 274/1000
#  - 11s - loss: 0.6329 - accuracy: 0.6292 - val_loss: 0.8112 - val_accuracy: 0.5102
#
# Epoch 00274: val_loss did not improve from 0.51499
# Epoch 275/1000
#  - 11s - loss: 0.6290 - accuracy: 0.6218 - val_loss: 0.7300 - val_accuracy: 0.5053
#
# Epoch 00275: val_loss did not improve from 0.51499
# Epoch 276/1000
#  - 11s - loss: 0.6336 - accuracy: 0.6293 - val_loss: 0.6772 - val_accuracy: 0.5150
#
# Epoch 00276: val_loss did not improve from 0.51499
# Epoch 277/1000
#  - 11s - loss: 0.6320 - accuracy: 0.6281 - val_loss: 0.7107 - val_accuracy: 0.4950
#
# Epoch 00277: val_loss did not improve from 0.51499
# Epoch 278/1000
#  - 11s - loss: 0.6324 - accuracy: 0.6222 - val_loss: 0.6083 - val_accuracy: 0.5053
#
# Epoch 00278: val_loss did not improve from 0.51499
# Epoch 279/1000
#  - 11s - loss: 0.6327 - accuracy: 0.6316 - val_loss: 0.6057 - val_accuracy: 0.5053
#
# Epoch 00279: val_loss did not improve from 0.51499
# Epoch 280/1000
#  - 11s - loss: 0.6347 - accuracy: 0.6258 - val_loss: 0.8866 - val_accuracy: 0.5050
#
# Epoch 00280: val_loss did not improve from 0.51499
# Epoch 281/1000
#  - 11s - loss: 0.6285 - accuracy: 0.6348 - val_loss: 0.5834 - val_accuracy: 0.5005
#
# Epoch 00281: val_loss did not improve from 0.51499
# Epoch 282/1000
#  - 11s - loss: 0.6321 - accuracy: 0.6286 - val_loss: 0.6913 - val_accuracy: 0.4940
#
# Epoch 00282: val_loss did not improve from 0.51499
# Epoch 283/1000
#  - 11s - loss: 0.6273 - accuracy: 0.6343 - val_loss: 0.6512 - val_accuracy: 0.5091
#
# Epoch 00283: val_loss did not improve from 0.51499
# Epoch 284/1000
#  - 11s - loss: 0.6323 - accuracy: 0.6232 - val_loss: 0.6586 - val_accuracy: 0.4943
#
# Epoch 00284: val_loss did not improve from 0.51499
# Epoch 285/1000
#  - 11s - loss: 0.6260 - accuracy: 0.6404 - val_loss: 0.8614 - val_accuracy: 0.4916
#
# Epoch 00285: val_loss did not improve from 0.51499
# Epoch 286/1000
#  - 11s - loss: 0.6298 - accuracy: 0.6248 - val_loss: 0.8556 - val_accuracy: 0.4967
#
# Epoch 00286: val_loss did not improve from 0.51499
# Epoch 287/1000
#  - 11s - loss: 0.6281 - accuracy: 0.6330 - val_loss: 0.8409 - val_accuracy: 0.4898
#
# Epoch 00287: val_loss did not improve from 0.51499
# Epoch 288/1000
#  - 11s - loss: 0.6283 - accuracy: 0.6348 - val_loss: 0.6880 - val_accuracy: 0.5019
#
# Epoch 00288: val_loss did not improve from 0.51499
# Epoch 289/1000
#  - 11s - loss: 0.6291 - accuracy: 0.6307 - val_loss: 0.6703 - val_accuracy: 0.5009
#
# Epoch 00289: val_loss did not improve from 0.51499
# Epoch 290/1000
#  - 11s - loss: 0.6280 - accuracy: 0.6323 - val_loss: 0.9247 - val_accuracy: 0.4998
#
# Epoch 00290: val_loss did not improve from 0.51499
# Epoch 291/1000
#  - 11s - loss: 0.6282 - accuracy: 0.6330 - val_loss: 0.6373 - val_accuracy: 0.5022
#
# Epoch 00291: val_loss did not improve from 0.51499
# Epoch 292/1000
#  - 11s - loss: 0.6274 - accuracy: 0.6348 - val_loss: 0.7207 - val_accuracy: 0.5105
#
# Epoch 00292: val_loss did not improve from 0.51499
# Epoch 293/1000
#  - 11s - loss: 0.6245 - accuracy: 0.6386 - val_loss: 0.5242 - val_accuracy: 0.5074
#
# Epoch 00293: val_loss did not improve from 0.51499
# Epoch 294/1000
#  - 11s - loss: 0.6245 - accuracy: 0.6395 - val_loss: 0.8337 - val_accuracy: 0.4978
#
# Epoch 00294: val_loss did not improve from 0.51499
# Epoch 295/1000
#  - 11s - loss: 0.6206 - accuracy: 0.6393 - val_loss: 0.5891 - val_accuracy: 0.5057
#
# Epoch 00295: val_loss did not improve from 0.51499
# Epoch 296/1000
#  - 11s - loss: 0.6282 - accuracy: 0.6304 - val_loss: 0.7641 - val_accuracy: 0.4998
#
# Epoch 00296: val_loss did not improve from 0.51499
# Epoch 297/1000
#  - 11s - loss: 0.6246 - accuracy: 0.6400 - val_loss: 0.6714 - val_accuracy: 0.5057
#
# Epoch 00297: val_loss did not improve from 0.51499
# Epoch 298/1000
#  - 11s - loss: 0.6257 - accuracy: 0.6400 - val_loss: 0.7152 - val_accuracy: 0.5095
#
# Epoch 00298: val_loss did not improve from 0.51499
# Epoch 299/1000
#  - 11s - loss: 0.6253 - accuracy: 0.6376 - val_loss: 0.9222 - val_accuracy: 0.5088
#
# Epoch 00299: val_loss did not improve from 0.51499
# Epoch 300/1000
#  - 11s - loss: 0.6243 - accuracy: 0.6404 - val_loss: 0.6484 - val_accuracy: 0.5143
#
# Epoch 00300: val_loss did not improve from 0.51499
# Epoch 301/1000
#  - 11s - loss: 0.6183 - accuracy: 0.6462 - val_loss: 1.0819 - val_accuracy: 0.5074
#
# Epoch 00301: val_loss did not improve from 0.51499
# Epoch 302/1000
#  - 11s - loss: 0.6192 - accuracy: 0.6453 - val_loss: 0.6911 - val_accuracy: 0.5095
#
# Epoch 00302: val_loss did not improve from 0.51499
# Epoch 303/1000
#  - 11s - loss: 0.6190 - accuracy: 0.6402 - val_loss: 0.7782 - val_accuracy: 0.5012
#
# Epoch 00303: val_loss did not improve from 0.51499
# Epoch 304/1000
#  - 11s - loss: 0.6240 - accuracy: 0.6345 - val_loss: 0.7831 - val_accuracy: 0.4998
#
# Epoch 00304: val_loss did not improve from 0.51499
# Epoch 305/1000
#  - 11s - loss: 0.6172 - accuracy: 0.6464 - val_loss: 0.6467 - val_accuracy: 0.5088
#
# Epoch 00305: val_loss did not improve from 0.51499
# Epoch 306/1000
#  - 11s - loss: 0.6237 - accuracy: 0.6339 - val_loss: 1.2247 - val_accuracy: 0.5047
#
# Epoch 00306: val_loss did not improve from 0.51499
# Epoch 307/1000
#  - 11s - loss: 0.6198 - accuracy: 0.6393 - val_loss: 0.6927 - val_accuracy: 0.5022
#
# Epoch 00307: val_loss did not improve from 0.51499
# Epoch 308/1000
#  - 11s - loss: 0.6174 - accuracy: 0.6440 - val_loss: 0.6478 - val_accuracy: 0.5109
#
# Epoch 00308: val_loss did not improve from 0.51499
# Epoch 309/1000
#  - 11s - loss: 0.6236 - accuracy: 0.6354 - val_loss: 1.0245 - val_accuracy: 0.5091
#
# Epoch 00309: val_loss did not improve from 0.51499
# Epoch 310/1000
#  - 11s - loss: 0.6165 - accuracy: 0.6428 - val_loss: 0.5642 - val_accuracy: 0.5026
#
# Epoch 00310: val_loss did not improve from 0.51499
# Epoch 311/1000
#  - 11s - loss: 0.6171 - accuracy: 0.6410 - val_loss: 0.7332 - val_accuracy: 0.5029
#
# Epoch 00311: val_loss did not improve from 0.51499
# Epoch 312/1000
#  - 11s - loss: 0.6198 - accuracy: 0.6404 - val_loss: 0.9417 - val_accuracy: 0.5050
#
# Epoch 00312: val_loss did not improve from 0.51499
# Epoch 313/1000
#  - 11s - loss: 0.6138 - accuracy: 0.6467 - val_loss: 0.7303 - val_accuracy: 0.5012
#
# Epoch 00313: val_loss did not improve from 0.51499
# Epoch 314/1000
# ...
# Epoch 662/1000
#  - 11s - loss: 0.4465 - accuracy: 0.7782 - val_loss: 0.9803 - val_accuracy: 0.4953
#
# Epoch 00662: val_loss did not improve from 0.24500
# Epoch 663/1000
#  - 11s - loss: 0.4509 - accuracy: 0.7712 - val_loss: 0.7791 - val_accuracy: 0.5009
#
# Epoch 00663: val_loss did not improve from 0.24500
# Epoch 664/1000
#  - 11s - loss: 0.4582 - accuracy: 0.7656 - val_loss: 0.7915 - val_accuracy: 0.5053
#
# Epoch 00664: val_loss did not improve from 0.24500
# Epoch 665/1000
#  - 11s - loss: 0.4499 - accuracy: 0.7789 - val_loss: 0.4291 - val_accuracy: 0.5005
#
# Epoch 00665: val_loss did not improve from 0.24500
# Epoch 666/1000
#  - 11s - loss: 0.4499 - accuracy: 0.7805 - val_loss: 0.3756 - val_accuracy: 0.5074
#
# Epoch 00666: val_loss did not improve from 0.24500
# Epoch 667/1000
#  - 11s - loss: 0.4404 - accuracy: 0.7805 - val_loss: 0.8571 - val_accuracy: 0.5060
#
# Epoch 00667: val_loss did not improve from 0.24500
# Epoch 668/1000
#  - 11s - loss: 0.4553 - accuracy: 0.7686 - val_loss: 1.0779 - val_accuracy: 0.5012
#
# Epoch 00668: val_loss did not improve from 0.24500
# Epoch 669/1000
#  - 11s - loss: 0.4459 - accuracy: 0.7792 - val_loss: 0.8779 - val_accuracy: 0.5071
#
# Epoch 00669: val_loss did not improve from 0.24500
# Epoch 670/1000
#  - 11s - loss: 0.4465 - accuracy: 0.7737 - val_loss: 1.6346 - val_accuracy: 0.5171
#
# Epoch 00670: val_loss did not improve from 0.24500
# Epoch 671/1000
#  - 11s - loss: 0.4454 - accuracy: 0.7755 - val_loss: 1.2348 - val_accuracy: 0.5084
#
# Epoch 00671: val_loss did not improve from 0.24500
# Epoch 672/1000
#  - 11s - loss: 0.4485 - accuracy: 0.7773 - val_loss: 0.8713 - val_accuracy: 0.4984
#
# Epoch 00672: val_loss did not improve from 0.24500
# Epoch 673/1000
#  - 11s - loss: 0.4448 - accuracy: 0.7779 - val_loss: 0.8965 - val_accuracy: 0.4991
#
# Epoch 00673: val_loss did not improve from 0.24500
# Epoch 674/1000
#  - 11s - loss: 0.4433 - accuracy: 0.7840 - val_loss: 0.3737 - val_accuracy: 0.5029
#
# Epoch 00674: val_loss did not improve from 0.24500
# Epoch 675/1000
#  - 11s - loss: 0.4468 - accuracy: 0.7741 - val_loss: 1.0017 - val_accuracy: 0.4967
#
# Epoch 00675: val_loss did not improve from 0.24500
# Epoch 676/1000
#  - 11s - loss: 0.4478 - accuracy: 0.7795 - val_loss: 0.6658 - val_accuracy: 0.5019
#
# Epoch 00676: val_loss did not improve from 0.24500
# Epoch 677/1000
#  - 11s - loss: 0.4401 - accuracy: 0.7827 - val_loss: 0.5345 - val_accuracy: 0.5016
#
# Epoch 00677: val_loss did not improve from 0.24500
# Epoch 678/1000
#  - 11s - loss: 0.4486 - accuracy: 0.7722 - val_loss: 0.9694 - val_accuracy: 0.4978
#
# Epoch 00678: val_loss did not improve from 0.24500
# Epoch 679/1000
#  - 11s - loss: 0.4408 - accuracy: 0.7823 - val_loss: 2.0375 - val_accuracy: 0.4978
#
# Epoch 00679: val_loss did not improve from 0.24500
# Epoch 680/1000
#  - 11s - loss: 0.4397 - accuracy: 0.7804 - val_loss: 0.7285 - val_accuracy: 0.5105
#
# Epoch 00680: val_loss did not improve from 0.24500
# Epoch 681/1000
#  - 11s - loss: 0.4336 - accuracy: 0.7860 - val_loss: 0.5205 - val_accuracy: 0.4998
#
# Epoch 00681: val_loss did not improve from 0.24500
# Epoch 682/1000
#  - 11s - loss: 0.4423 - accuracy: 0.7778 - val_loss: 0.2069 - val_accuracy: 0.4988
#
# Epoch 00682: val_loss improved from 0.24500 to 0.20692, saving model to /content/drive/My Drive/Colab Notebooks/Project_Stock/ckpt/classifier_45_close_updown_pr_theta_non_shuffle_ex_maxabs.h5
# Epoch 683/1000
#  - 11s - loss: 0.4399 - accuracy: 0.7776 - val_loss: 1.0587 - val_accuracy: 0.5129
#
# Epoch 00683: val_loss did not improve from 0.20692
# Epoch 684/1000
#  - 11s - loss: 0.4437 - accuracy: 0.7852 - val_loss: 1.0178 - val_accuracy: 0.4940
#
# Epoch 00684: val_loss did not improve from 0.20692
# Epoch 685/1000
#  - 11s - loss: 0.4447 - accuracy: 0.7799 - val_loss: 0.6023 - val_accuracy: 0.5126
#
# Epoch 00685: val_loss did not improve from 0.20692
# Epoch 686/1000
#  - 11s - loss: 0.4476 - accuracy: 0.7748 - val_loss: 0.7961 - val_accuracy: 0.5060
#
# Epoch 00686: val_loss did not improve from 0.20692
# Epoch 687/1000
#  - 11s - loss: 0.4385 - accuracy: 0.7822 - val_loss: 0.9736 - val_accuracy: 0.5119
#
# Epoch 00687: val_loss did not improve from 0.20692
# Epoch 688/1000
#  - 11s - loss: 0.4319 - accuracy: 0.7822 - val_loss: 0.8877 - val_accuracy: 0.4964
#
# Epoch 00688: val_loss did not improve from 0.20692
# Epoch 689/1000
#  - 11s - loss: 0.4408 - accuracy: 0.7820 - val_loss: 0.9550 - val_accuracy: 0.4984
#
# Epoch 00689: val_loss did not improve from 0.20692
# Epoch 690/1000
#  - 11s - loss: 0.4391 - accuracy: 0.7826 - val_loss: 1.3874 - val_accuracy: 0.4905
#
# Epoch 00690: val_loss did not improve from 0.20692
# Epoch 691/1000
#  - 11s - loss: 0.4406 - accuracy: 0.7860 - val_loss: 0.8888 - val_accuracy: 0.4998
#
# Epoch 00691: val_loss did not improve from 0.20692
# Epoch 692/1000
#  - 11s - loss: 0.4402 - accuracy: 0.7844 - val_loss: 1.1610 - val_accuracy: 0.5040
#
# Epoch 00692: val_loss did not improve from 0.20692
# Epoch 693/1000
#  - 11s - loss: 0.4377 - accuracy: 0.7884 - val_loss: 1.1306 - val_accuracy: 0.4885
#
# Epoch 00693: val_loss did not improve from 0.20692
# Epoch 694/1000
#  - 11s - loss: 0.4284 - accuracy: 0.7919 - val_loss: 1.2724 - val_accuracy: 0.4926
#
# Epoch 00694: val_loss did not improve from 0.20692
# Epoch 695/1000
#  - 11s - loss: 0.4307 - accuracy: 0.7814 - val_loss: 0.9968 - val_accuracy: 0.5078
#
# Epoch 00695: val_loss did not improve from 0.20692
# Epoch 696/1000
#  - 11s - loss: 0.4336 - accuracy: 0.7859 - val_loss: 1.2859 - val_accuracy: 0.4981
#
# Epoch 00696: val_loss did not improve from 0.20692
# Epoch 697/1000
#  - 11s - loss: 0.4339 - accuracy: 0.7869 - val_loss: 0.8636 - val_accuracy: 0.5071
#
# Epoch 00697: val_loss did not improve from 0.20692
# Epoch 698/1000
#  - 11s - loss: 0.4315 - accuracy: 0.7843 - val_loss: 0.4814 - val_accuracy: 0.5064
#
# Epoch 00698: val_loss did not improve from 0.20692
# Epoch 699/1000
#  - 11s - loss: 0.4374 - accuracy: 0.7845 - val_loss: 0.6676 - val_accuracy: 0.5174
#
# Epoch 00699: val_loss did not improve from 0.20692
# Epoch 700/1000
#  - 11s - loss: 0.4383 - accuracy: 0.7811 - val_loss: 0.3866 - val_accuracy: 0.5019
#
# Epoch 00700: val_loss did not improve from 0.20692
# Epoch 701/1000
#  - 11s - loss: 0.4301 - accuracy: 0.7868 - val_loss: 1.0680 - val_accuracy: 0.4950
#
# Epoch 00701: val_loss did not improve from 0.20692
# Epoch 702/1000
#  - 11s - loss: 0.4350 - accuracy: 0.7835 - val_loss: 0.8432 - val_accuracy: 0.5053
#
# Epoch 00702: val_loss did not improve from 0.20692
# Epoch 703/1000
#  - 11s - loss: 0.4410 - accuracy: 0.7821 - val_loss: 0.5013 - val_accuracy: 0.5005
#
# Epoch 00703: val_loss did not improve from 0.20692
# Epoch 704/1000
#  - 11s - loss: 0.4381 - accuracy: 0.7860 - val_loss: 1.3326 - val_accuracy: 0.4898
#
# Epoch 00704: val_loss did not improve from 0.20692
# Epoch 705/1000
#  - 11s - loss: 0.4431 - accuracy: 0.7789 - val_loss: 1.0404 - val_accuracy: 0.5060
#
# Epoch 00705: val_loss did not improve from 0.20692
# Epoch 706/1000
#  - 11s - loss: 0.4265 - accuracy: 0.7874 - val_loss: 0.8039 - val_accuracy: 0.5022
#
# Epoch 00706: val_loss did not improve from 0.20692
# Epoch 707/1000
#  - 11s - loss: 0.4365 - accuracy: 0.7805 - val_loss: 0.9099 - val_accuracy: 0.4991
#
# Epoch 00707: val_loss did not improve from 0.20692
# Epoch 708/1000
#  - 11s - loss: 0.4303 - accuracy: 0.7890 - val_loss: 1.0364 - val_accuracy: 0.4967
#
# Epoch 00708: val_loss did not improve from 0.20692
# Epoch 709/1000
#  - 11s - loss: 0.4268 - accuracy: 0.7864 - val_loss: 0.7600 - val_accuracy: 0.5036
#
# Epoch 00709: val_loss did not improve from 0.20692
# Epoch 710/1000
#  - 11s - loss: 0.4315 - accuracy: 0.7898 - val_loss: 1.5535 - val_accuracy: 0.5064
#
# Epoch 00710: val_loss did not improve from 0.20692
# Epoch 711/1000
#  - 11s - loss: 0.4240 - accuracy: 0.7905 - val_loss: 1.5006 - val_accuracy: 0.5029
#
# Epoch 00711: val_loss did not improve from 0.20692
# Epoch 712/1000
#  - 11s - loss: 0.4313 - accuracy: 0.7838 - val_loss: 1.6498 - val_accuracy: 0.4950
#
# Epoch 00712: val_loss did not improve from 0.20692
# Epoch 713/1000
#  - 11s - loss: 0.4223 - accuracy: 0.7897 - val_loss: 1.0904 - val_accuracy: 0.5053
#
# Epoch 00713: val_loss did not improve from 0.20692
# Epoch 714/1000
#  - 11s - loss: 0.4286 - accuracy: 0.7903 - val_loss: 1.6439 - val_accuracy: 0.5005
#
# Epoch 00714: val_loss did not improve from 0.20692
# Epoch 715/1000
#  - 11s - loss: 0.4248 - accuracy: 0.7913 - val_loss: 0.8835 - val_accuracy: 0.4895
#
# Epoch 00715: val_loss did not improve from 0.20692
# Epoch 716/1000
#  - 11s - loss: 0.4258 - accuracy: 0.7912 - val_loss: 1.1609 - val_accuracy: 0.4984
#
# Epoch 00716: val_loss did not improve from 0.20692
# Epoch 717/1000
#  - 11s - loss: 0.4319 - accuracy: 0.7879 - val_loss: 1.3981 - val_accuracy: 0.5002
#
# Epoch 00717: val_loss did not improve from 0.20692
# Epoch 718/1000
#  - 11s - loss: 0.4320 - accuracy: 0.7850 - val_loss: 1.2104 - val_accuracy: 0.4929
#
# Epoch 00718: val_loss did not improve from 0.20692
# Epoch 719/1000
#  - 11s - loss: 0.4301 - accuracy: 0.7928 - val_loss: 0.8069 - val_accuracy: 0.4971
#
# Epoch 00719: val_loss did not improve from 0.20692
# Epoch 720/1000
#  - 11s - loss: 0.4298 - accuracy: 0.7834 - val_loss: 0.6803 - val_accuracy: 0.4953
#
# Epoch 00720: val_loss did not improve from 0.20692
# Epoch 721/1000
#  - 11s - loss: 0.4199 - accuracy: 0.7997 - val_loss: 1.8064 - val_accuracy: 0.4991
#
# Epoch 00721: val_loss did not improve from 0.20692
# Epoch 722/1000
#  - 11s - loss: 0.4324 - accuracy: 0.7833 - val_loss: 1.2826 - val_accuracy: 0.5026
#
# Epoch 00722: val_loss did not improve from 0.20692
# Epoch 723/1000
#  - 11s - loss: 0.4235 - accuracy: 0.7922 - val_loss: 0.3291 - val_accuracy: 0.5040
#
# Epoch 00723: val_loss did not improve from 0.20692
# Epoch 724/1000
#  - 11s - loss: 0.4233 - accuracy: 0.7959 - val_loss: 1.3534 - val_accuracy: 0.5002
#
# Epoch 00724: val_loss did not improve from 0.20692
# Epoch 725/1000
#  - 11s - loss: 0.4247 - accuracy: 0.7886 - val_loss: 2.0974 - val_accuracy: 0.4981
#
# Epoch 00725: val_loss did not improve from 0.20692
# Epoch 726/1000
#  - 11s - loss: 0.4281 - accuracy: 0.7923 - val_loss: 1.3010 - val_accuracy: 0.4929
#
# Epoch 00726: val_loss did not improve from 0.20692
# Epoch 727/1000
#  - 11s - loss: 0.4321 - accuracy: 0.7845 - val_loss: 1.0106 - val_accuracy: 0.4926
#
# Epoch 00727: val_loss did not improve from 0.20692
# Epoch 728/1000
#  - 11s - loss: 0.4280 - accuracy: 0.7914 - val_loss: 0.8266 - val_accuracy: 0.5067
#
# Epoch 00728: val_loss did not improve from 0.20692
# Epoch 729/1000
#  - 11s - loss: 0.4209 - accuracy: 0.7921 - val_loss: 1.8444 - val_accuracy: 0.4957
#
# Epoch 00729: val_loss did not improve from 0.20692
# Epoch 730/1000
#  - 11s - loss: 0.4252 - accuracy: 0.7909 - val_loss: 1.1071 - val_accuracy: 0.4991
#
# Epoch 00730: val_loss did not improve from 0.20692
# Epoch 731/1000
#  - 11s - loss: 0.4249 - accuracy: 0.7887 - val_loss: 0.4091 - val_accuracy: 0.5036
#
# Epoch 00731: val_loss did not improve from 0.20692
# Epoch 732/1000
#  - 11s - loss: 0.4190 - accuracy: 0.7937 - val_loss: 1.4157 - val_accuracy: 0.4998
#
# Epoch 00732: val_loss did not improve from 0.20692
# Epoch 733/1000
#  - 11s - loss: 0.4239 - accuracy: 0.7889 - val_loss: 0.5549 - val_accuracy: 0.4978
#
# Epoch 00733: val_loss did not improve from 0.20692
# Epoch 734/1000
#  - 11s - loss: 0.4274 - accuracy: 0.7938 - val_loss: 0.9273 - val_accuracy: 0.4974
#
# Epoch 00734: val_loss did not improve from 0.20692
# Epoch 735/1000
#  - 11s - loss: 0.4196 - accuracy: 0.7942 - val_loss: 1.2915 - val_accuracy: 0.4967
#
# Epoch 00735: val_loss did not improve from 0.20692
# Epoch 736/1000
#  - 11s - loss: 0.4272 - accuracy: 0.7949 - val_loss: 0.7565 - val_accuracy: 0.5022
#
# Epoch 00736: val_loss did not improve from 0.20692
# Epoch 737/1000
#  - 11s - loss: 0.4226 - accuracy: 0.7918 - val_loss: 1.2034 - val_accuracy: 0.4971
#
# Epoch 00737: val_loss did not improve from 0.20692
# Epoch 738/1000
#  - 11s - loss: 0.4196 - accuracy: 0.8009 - val_loss: 0.9534 - val_accuracy: 0.4964
#
# Epoch 00738: val_loss did not improve from 0.20692
# Epoch 739/1000
#  - 11s - loss: 0.4202 - accuracy: 0.7944 - val_loss: 1.1423 - val_accuracy: 0.5005
#
# Epoch 00739: val_loss did not improve from 0.20692
# Epoch 740/1000
#  - 11s - loss: 0.4227 - accuracy: 0.7920 - val_loss: 1.5672 - val_accuracy: 0.4998
#
# Epoch 00740: val_loss did not improve from 0.20692
# Epoch 741/1000
#  - 11s - loss: 0.4239 - accuracy: 0.7969 - val_loss: 1.1642 - val_accuracy: 0.4916
#
# Epoch 00741: val_loss did not improve from 0.20692
# Epoch 742/1000
#  - 11s - loss: 0.4260 - accuracy: 0.7913 - val_loss: 1.4375 - val_accuracy: 0.5050
#
# Epoch 00742: val_loss did not improve from 0.20692
# Epoch 743/1000
#  - 11s - loss: 0.4199 - accuracy: 0.7938 - val_loss: 1.2002 - val_accuracy: 0.5067
#
# Epoch 00743: val_loss did not improve from 0.20692
# Epoch 744/1000
#  - 11s - loss: 0.4149 - accuracy: 0.7998 - val_loss: 0.7812 - val_accuracy: 0.5088
#
# Epoch 00744: val_loss did not improve from 0.20692
# Epoch 745/1000
#  - 11s - loss: 0.4130 - accuracy: 0.7981 - val_loss: 0.7025 - val_accuracy: 0.4916
#
# Epoch 00745: val_loss did not improve from 0.20692
# Epoch 746/1000
#  - 11s - loss: 0.4162 - accuracy: 0.7943 - val_loss: 0.6455 - val_accuracy: 0.4998
#
# Epoch 00746: val_loss did not improve from 0.20692
# Epoch 747/1000
#  - 11s - loss: 0.4226 - accuracy: 0.7973 - val_loss: 1.0657 - val_accuracy: 0.5067
#
# Epoch 00747: val_loss did not improve from 0.20692
# Epoch 748/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-65c4ff7d3370> in <module>()
#      34                     validation_data=val_flow,
#      35                     validation_steps=len(x_val) / batch_size,
# ---> 36                     shuffle=False)
#
# /tensorflow-1.15.2/python3.7/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /tensorflow-1.15.2/python3.7/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /tensorflow-1.15.2/python3.7/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# /tensorflow-1.15.2/python3.7/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
# model_name = 'classifier_45_close_updown_pr_theta_non_shuffle_ex_02008.h5'
# model_name = 'classifier_45_close_updown_pr_theta.h5'

model = keras.models.load_model(ckpt_path + model_name)

# %%
test_result = model.predict(x_test)
# test_result = model.predict(test_set)

print('test_result.shape :', test_result.shape)
print('pr_val.shape :', pr_val.shape)

y_score = test_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
for thresh in threshold:

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  print('precision :', precision_score(y_test, y_pred))
  print('recall :', recall_score(y_test, y_pred))
  print()

  print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # plt.show()  
  print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test)
  test_pr_list = pr_test
  print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
    print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
    print('thresh :', thresh)
    
  # if len(threshold) == 1:
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(test_pr_list))
    plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
  # plt.show()

    plt.subplot(122)
    plt.plot(np.cumprod(pred_pr_list))
    plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])

print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(threshold, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()
# Out:
# test_result.shape : (2901, 2)
# pr_val.shape : (2901, 1)
# y_test[:5] : [1 1 1 1 1]
# y_score[:5] : [[0.06002754]
#  [0.28203174]
#  [0.8779696 ]
#  [0.13999628]
#  [0.24018347]]
# y_test.shape : (2901, 1)
# y_score.shape : (2901, 1)
# len(y_test) : 2901
# y_pred.shape : (2901,)
# precision : 0.4825425246195166
# recall : 0.3803810868031052
#
# np.isnan(np.sum(x_test)) : False
# np.isnan(np.sum(y_test)) : False
#
# origin ac_pr : 6.17001e-05
# win ratio improvement 0.49 --> 0.48
# accum_pr increased ! : 0.000 --> 0.021
# thresh : 0.65
# acc_pr_bythr : [0.02133044]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-709f91521dfa> in <module>()
#      95 plt.figure(figsize=(10, 5))
#      96 plt.subplot(121)
# ---> 97 plt.plot(threshold, precision, label='precision')
#      98 plt.plot(threshold, recall, label='recall')
#      99 plt.legend()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (2900,)

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
