# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %tensorflow_version 1.x
# %matplotlib inline

input_data_length = 60
model_num = 126
num_classes = 3

gdrive_path = '/content/gdrive/My Drive/Colab Notebooks/'

Made_X = np.load(gdrive_path + 'Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
Made_Y = np.load(gdrive_path + 'Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)


#       dataset 분리      #
# dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
# dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
Made_X = Made_X[:, :, :4]
print(Made_X.shape)
print(Made_Y.shape)

row = Made_X.shape[1]
col = Made_X.shape[2]

from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                   shuffle=False)

X_train = X_train.astype('float32').reshape(-1, input_data_length, col, 1)
X_val = X_val.astype('float32').reshape(-1, input_data_length, col, 1)
print(X_train.shape)
print(X_val.shape)

from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 

# Data Class Weight
from sklearn.utils import class_weight

print(Y_train[:, 0])
class_weights = class_weight.compute_class_weight('balanced', 
                                                  np.unique(Y_train[:, 0]),
                                                  Y_train[:, 0])
class_weights = dict(enumerate(class_weights))
print(class_weights)
# quit()

Y_train = Y_train.astype('float32')
Y_val = Y_val.astype('float32')
Y_train = np_utils.to_categorical(Y_train, num_classes)
Y_val = np_utils.to_categorical(Y_val, num_classes)
print(Y_train.shape)
print(Y_val.shape)

datagen = ImageDataGenerator( 
#     rotation_range = 60,
#     zoom_range = 0.6,
#     shear_range = 0.6,
#     horizontal_flip = True,
#     width_shift_range=0.6,
#     height_shift_range=0.6,
    fill_mode = 'nearest'
    )

testgen = ImageDataGenerator( 
    )
datagen.fit(X_train)
batch_size = 128

for X_batch, _ in datagen.flow(X_train, Y_train, batch_size=9):
    for i in range(0, 9): 
        pyplot.axis('off') 
        pyplot.subplot(330 + 1 + i) 
        pyplot.imshow(X_batch[i].reshape(input_data_length, col))
    pyplot.axis('off') 
    pyplot.show() 
    break
    
    
train_flow = datagen.flow(X_train, Y_train, batch_size=batch_size) 
val_flow = testgen.flow(X_val, Y_val, batch_size=batch_size) 


from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix

def FER_Model(input_shape=(row, col, 1)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(64, kernel_size=3, padding='same')(visible)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_1 = net

    net = layers.Conv2D(128, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
    
    return model

model = FER_Model()

#   Load Model  #
# from keras.models import load_model
# model = load_model(gdrive_path + 'model/rapid_ascending %s_%s_ohlc.hdf5' % (input_data_length, model_num))

opt = Adam(lr=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
  
    
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath = gdrive_path + "model/rapid_ascending %s_%s_ohlc.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_loss', patience=100)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 500
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(X_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(X_val) / batch_size,
                    shuffle=False)
# Out:
# (670754, 60, 4)
# (670754, 1)
# (469527, 60, 4, 1)
# (201227, 60, 4, 1)
# Using TensorFlow backend.
# [0. 0. 0. ... 0. 0. 0.]
# {0: 0.3520592595258608, 1: 12.52472791293214, 2: 12.542795319762783}
# (469527, 3)
# (201227, 3)
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 60, 4, 1)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 4, 64)         640
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 60, 4, 64)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 4, 128)        73856
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 60, 4, 128)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 30720)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                1966144
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 2,040,835
# Trainable params: 2,040,835
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/500
#  - 46s - loss: 0.7146 - accuracy: 0.3186 - val_loss: 1.0200 - val_accuracy: 0.3401
#
# Epoch 00001: val_loss improved from inf to 1.02002, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 60_126_ohlc.hdf5
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/500
#  - 38s - loss: 0.6484 - accuracy: 0.3576 - val_loss: 0.8905 - val_accuracy: 0.4381
#
# Epoch 00002: val_loss improved from 1.02002 to 0.89045, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 60_126_ohlc.hdf5
# Epoch 3/500
#  - 39s - loss: 0.6366 - accuracy: 0.3651 - val_loss: 0.8303 - val_accuracy: 0.4872
#
# Epoch 00003: val_loss improved from 0.89045 to 0.83030, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 60_126_ohlc.hdf5
# Epoch 4/500
#  - 39s - loss: 0.6286 - accuracy: 0.3704 - val_loss: 1.0320 - val_accuracy: 0.3699
#
# Epoch 00004: val_loss did not improve from 0.83030
# Epoch 5/500
#  - 39s - loss: 0.6232 - accuracy: 0.3751 - val_loss: 0.9601 - val_accuracy: 0.3595
#
# Epoch 00005: val_loss did not improve from 0.83030
# Epoch 6/500
#  - 39s - loss: 0.6191 - accuracy: 0.3785 - val_loss: 1.0845 - val_accuracy: 0.3920
#
# Epoch 00006: val_loss did not improve from 0.83030
# Epoch 7/500
#  - 39s - loss: 0.6149 - accuracy: 0.3845 - val_loss: 1.0979 - val_accuracy: 0.4000
#
# Epoch 00007: val_loss did not improve from 0.83030
# Epoch 8/500
#  - 39s - loss: 0.6104 - accuracy: 0.3887 - val_loss: 1.2513 - val_accuracy: 0.3454
#
# Epoch 00008: val_loss did not improve from 0.83030
# Epoch 9/500
#  - 39s - loss: 0.6073 - accuracy: 0.3945 - val_loss: 1.1437 - val_accuracy: 0.3927
#
# Epoch 00009: val_loss did not improve from 0.83030
# Epoch 10/500
#  - 39s - loss: 0.6034 - accuracy: 0.3991 - val_loss: 0.7336 - val_accuracy: 0.4201
#
# Epoch 00010: val_loss improved from 0.83030 to 0.73357, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 60_126_ohlc.hdf5
# Epoch 11/500
#  - 39s - loss: 0.5992 - accuracy: 0.4051 - val_loss: 0.7649 - val_accuracy: 0.4073
#
# Epoch 00011: val_loss did not improve from 0.73357
# Epoch 12/500
#  - 39s - loss: 0.5960 - accuracy: 0.4091 - val_loss: 0.9594 - val_accuracy: 0.3969
#
# Epoch 00012: val_loss did not improve from 0.73357
# Epoch 13/500
#  - 39s - loss: 0.5920 - accuracy: 0.4149 - val_loss: 0.8149 - val_accuracy: 0.4286
#
# Epoch 00013: val_loss did not improve from 0.73357
# Epoch 14/500
#  - 39s - loss: 0.5880 - accuracy: 0.4204 - val_loss: 0.9118 - val_accuracy: 0.4151
#
# Epoch 00014: val_loss did not improve from 0.73357
# Epoch 15/500
#  - 39s - loss: 0.5836 - accuracy: 0.4274 - val_loss: 1.0554 - val_accuracy: 0.3282
#
# Epoch 00015: val_loss did not improve from 0.73357
# Epoch 16/500
#  - 39s - loss: 0.5801 - accuracy: 0.4317 - val_loss: 1.0026 - val_accuracy: 0.4452
#
# Epoch 00016: val_loss did not improve from 0.73357
# Epoch 17/500
#  - 39s - loss: 0.5760 - accuracy: 0.4378 - val_loss: 0.9511 - val_accuracy: 0.4854
#
# Epoch 00017: val_loss did not improve from 0.73357
# Epoch 18/500
#  - 39s - loss: 0.5715 - accuracy: 0.4440 - val_loss: 1.1067 - val_accuracy: 0.4373
#
# Epoch 00018: val_loss did not improve from 0.73357
# Epoch 19/500
#  - 39s - loss: 0.5672 - accuracy: 0.4514 - val_loss: 0.9901 - val_accuracy: 0.4050
#
# Epoch 00019: val_loss did not improve from 0.73357
# Epoch 20/500
#  - 39s - loss: 0.5622 - accuracy: 0.4581 - val_loss: 1.4686 - val_accuracy: 0.3840
#
# Epoch 00020: val_loss did not improve from 0.73357
# Epoch 21/500
#  - 39s - loss: 0.5567 - accuracy: 0.4647 - val_loss: 0.6363 - val_accuracy: 0.4333
#
# Epoch 00021: val_loss improved from 0.73357 to 0.63632, saving model to /content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending 60_126_ohlc.hdf5
# Epoch 22/500
#  - 39s - loss: 0.5520 - accuracy: 0.4725 - val_loss: 1.1925 - val_accuracy: 0.4060
#
# Epoch 00022: val_loss did not improve from 0.63632
# Epoch 23/500
#  - 39s - loss: 0.5468 - accuracy: 0.4787 - val_loss: 1.6236 - val_accuracy: 0.4490
#
# Epoch 00023: val_loss did not improve from 0.63632
# Epoch 24/500
#  - 39s - loss: 0.5415 - accuracy: 0.4867 - val_loss: 0.8268 - val_accuracy: 0.4647
#
# Epoch 00024: val_loss did not improve from 0.63632
# Epoch 25/500
#  - 39s - loss: 0.5361 - accuracy: 0.4928 - val_loss: 0.7545 - val_accuracy: 0.5145
#
# Epoch 00025: val_loss did not improve from 0.63632
# Epoch 26/500
#  - 39s - loss: 0.5306 - accuracy: 0.5009 - val_loss: 1.1288 - val_accuracy: 0.4959
#
# Epoch 00026: val_loss did not improve from 0.63632
# Epoch 27/500
#  - 39s - loss: 0.5249 - accuracy: 0.5087 - val_loss: 0.8799 - val_accuracy: 0.4494
#
# Epoch 00027: val_loss did not improve from 0.63632
# Epoch 28/500
#  - 39s - loss: 0.5195 - accuracy: 0.5158 - val_loss: 0.6863 - val_accuracy: 0.5395
#
# Epoch 00028: val_loss did not improve from 0.63632
# Epoch 29/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0bb535399da6> in <module>()
#     174                     validation_data=val_flow,
#     175                     validation_steps=len(X_val) / batch_size,
# --> 176                     shuffle=False)
#     177
#
# /usr/local/lib/python3.6/dist-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
