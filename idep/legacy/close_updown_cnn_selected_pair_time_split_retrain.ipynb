# %%
from google.colab import drive
drive.mount('/content/drive')

import os, sys

current_path = '/content/drive/My Drive/Colab Notebooks/300/'

os.chdir(current_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Requirements**

# %%
# !pip install statsmodels==0.12.2

# import statsmodels
# statsmodels.__version__

# %% [markdown]
# ### **ARIMA**

# %%
from statsmodels.tsa.arima_model import ARIMA
# from statsmodels.tsa.arima.model import ARIMA

from datetime import datetime


def arima_test(target, use_rows=None):

  size = int(len(target) * 0.66)
  train, test = target[:size].values, target[size:]
  test_shift = test.shift(1).values
  test = test.values
  # break

  history = list(train)
  predictions = list()
  err_ranges = list()
  for t in range(len(test)):
    
      if use_rows is not None:
        history = history[-use_rows:]
        
      model = ARIMA(history, order=(0, 2, 4))
      model_fit = model.fit()
      output = model_fit.forecast()
      # print(output)
      # break

      predictions.append(output[0])
      err_ranges.append(output[1])
      obs = test[t]
      # print('obs :', obs)
      history.append(obs)
      # break
      print('\r %.2f%%' % (t / len(test) * 100), end='')

  print(len(test), len(predictions))

  return predictions, err_ranges


# print(high)


def get_back_result(ohlcv, predictions, err_ranges, tp=0.04, sl=None, leverage=1, show_detail=False, show_plot=False, return_pr=False, cumsum=False, 
                    close_ver=False, reverse_short=False):

  
  high, low, test = np.split(ohlcv.values[-len(predictions):, [1, 2, 3]], 3, axis=1)

  if close_ver:
    predictions = ohlcv['close'].shift(1).values[-len(test):]

  fee = 0.0006
  long_profits = []
  short_profits = []
  liquidations = []
  win_cnt = 0
  for i in range(len(test)):

    long_ep = predictions[i]
    if sl is not None:
      long_sl = long_ep * (1 / (sl + 1))

    # assert long_ep < long_exit, 'long_exit < long_ep !, %s, %s' % (long_exit, long_ep)
    
    short_ep = (predictions[i] + err_ranges[i]) * (1 + tp)
    # short_ep = (predictions[i] + err_ranges[i]) * (1 / (1 - tp))
    if sl is not None:
      short_sl = short_ep * (1 / (1 - sl))

    # print((low[i]))

    #    long 우선   # <-- long & short 둘다 체결된 상황에서는 long 체결을 우선으로 한다.
    if low[i] < long_ep:
      
      liquidation = low[i] / long_ep - fee
      l_liquidation = 1 + (liquidation - 1) * leverage
      liquidations.append(l_liquidation)

      if max(l_liquidation, 0) == 0:
        l_profit = 0
        # print('low[i], long_ep, l_liquidation :', low[i], long_ep, l_liquidation)
      else:

        if sl is not None:
          if low[i] < long_sl:
            profit = long_sl / long_ep - fee
          else:
            profit = test[i] / long_ep - fee

        else:
          profit = test[i] / long_ep - fee

        l_profit = 1 + (profit - 1) * leverage
        l_profit = max(l_profit, 0)
        
        if profit >= 1:
          win_cnt += 1

      long_profits.append(l_profit)
      short_profits.append(1.0)

      if show_detail:
        print(test[i], predictions[i], long_ep)

    # if high[i] > short_ep > low[i]: # 지정 대기가 아니라, 해당 price 가 지나면, long 한다.

    #   if not reverse_short:
    #     liquidation = short_ep / high[i]  - fee
    #   else:
    #     liquidation = low[i] / short_ep  - fee
    #   l_liquidation = 1 + (liquidation - 1) * leverage

    #   if max(l_liquidation, 0) == 0:
    #     l_profit = 0
    #   else:

    #     if sl is not None:
    #       if high[i] > short_sl:

    #         if not reverse_short:
    #           profit = short_ep / short_sl - fee
    #         else:
    #           profit = short_sl / short_ep - fee

    #       else:
    #         if not reverse_short:
    #           profit = short_ep / test[i] - fee
    #         else:
    #           profit = test[i] / short_ep - fee

    #     else:

    #       if not reverse_short:
    #         profit = short_ep / test[i] - fee
    #       else:
    #         profit = test[i] / short_ep - fee

    #     l_profit = 1 + (profit - 1) * leverage
    #     l_profit = max(l_profit, 0)

    #     if profit >= 1:
    #       win_cnt += 1

    #   short_profits.append(l_profit)
    #   long_profits.append(1.0)

    #   if show_detail:
    #     print(test[i], predictions[i], short_ep)
    
    else:
      long_profits.append(1.0)
      short_profits.append(1.0)
      liquidations.append(1.0)


  long_win_ratio = sum(np.array(long_profits) > 1.0) / sum(np.array(long_profits) != 1.0)
  short_win_ratio = sum(np.array(short_profits) > 1.0) / sum(np.array(short_profits) != 1.0)
  long_frequency = sum(np.array(long_profits) != 1.0) / len(test)
  short_frequency = sum(np.array(short_profits) != 1.0) / len(test)
  if not cumsum:
    long_accum_profit = np.array(long_profits).cumprod()
    short_accum_profit = np.array(short_profits).cumprod()
  else:
    long_accum_profit = (np.array(long_profits) - 1.0).cumsum()
    short_accum_profit = (np.array(short_profits) - 1.0).cumsum()

  # print(win_ratio)

  if show_plot:

    plt.figure(figsize=(10, 5))
    plt.suptitle('tp=%.4f, lvrg=%d' % (tp, leverage))

    plt.subplot(151)
    plt.plot(liquidations)
    plt.title('liquidations')

    plt.subplot(152)
    plt.plot(long_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (long_win_ratio * 100, long_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(153)
    plt.plot(long_accum_profit)
    plt.title('Accum_profit : %.2f' % long_accum_profit[-1], color='black')

    plt.subplot(154)
    plt.plot(short_profits)
    plt.title('Win Ratio : %.2f %%\nrequency : %.2f %%' % (short_win_ratio * 100, short_frequency * 100), color='black')
    # plt.show()

    # print()
    plt.subplot(155)
    plt.plot(short_accum_profit)
    plt.title('Accum_profit : %.2f' % short_accum_profit[-1], color='black')
    plt.show()

  return [long_win_ratio, short_win_ratio], [long_frequency, short_frequency], [long_accum_profit[-1], short_accum_profit[-1]], [long_profits, short_profits]


# get_back_result(tp=0.04, leverage=1, show_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

interval = '30m'
date_path = './candlestick_concated/%s/2021-04-27/' % interval
file_list = os.listdir(date_path)

print((file_list))
# Out:
# ['2021-04-27 BTCUSDT.xlsx', '2021-04-27 ETHUSDT.xlsx', '2021-04-27 BCHUSDT.xlsx', '2021-04-27 XRPUSDT.xlsx', '2021-04-27 EOSUSDT.xlsx', '2021-04-27 LTCUSDT.xlsx', '2021-04-27 ETCUSDT.xlsx', '2021-04-27 LINKUSDT.xlsx', '2021-04-27 XLMUSDT.xlsx', '2021-04-27 ADAUSDT.xlsx', '2021-04-27 XMRUSDT.xlsx', '2021-04-27 SXPUSDT.xlsx', '2021-04-27 KAVAUSDT.xlsx', '2021-04-27 BANDUSDT.xlsx', '2021-04-27 DASHUSDT.xlsx', '2021-04-27 ZECUSDT.xlsx', '2021-04-27 XTZUSDT.xlsx', '2021-04-27 BNBUSDT.xlsx', '2021-04-27 ATOMUSDT.xlsx', '2021-04-27 ONTUSDT.xlsx', '2021-04-27 IOTAUSDT.xlsx', '2021-04-27 BATUSDT.xlsx', '2021-04-27 NEOUSDT.xlsx', '2021-04-27 QTUMUSDT.xlsx', '2021-04-27 WAVESUSDT.xlsx', '2021-04-27 MKRUSDT.xlsx', '2021-04-27 SNXUSDT.xlsx', '2021-04-27 DOTUSDT.xlsx', '2021-04-27 THETAUSDT.xlsx', '2021-04-27 ALGOUSDT.xlsx', '2021-04-27 KNCUSDT.xlsx', '2021-04-27 ZRXUSDT.xlsx', '2021-04-27 COMPUSDT.xlsx', '2021-04-27 OMGUSDT.xlsx']

# %% [markdown]
# ### **Model**

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
# os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %tensorflow_version 1.x

import keras
import tensorflow as tf

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display

# %matplotlib inline

from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import precision_score, recall_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix


gdrive_path = current_path

num_classes = 2

def FER_Model(input_shape):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(32, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(visible)
    # net = layers.BatchNormalization()(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)
    # net = layers.AveragePooling2D(padding='same')(net)

    shortcut_1 = net

    # net = layers.Conv2D(64, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.Conv2D(128, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    net = layers.LeakyReLU()(net)

    net = layers.Conv2D(256, kernel_size=3, padding='same', kernel_initializer='he_normal')(net)
    # net = layers.BatchNormalization()(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    # net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(128)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)

    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs=visible, outputs=net)
    # summary layers
    # print(model.summary())
    
    return model
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %% [markdown]
# ### **Data Stacking**

# %%
def resize_npy(x):

  temp_x = []

  for d_i, data in enumerate(x):
    # resized_data = cv2.resize(data, (row * 2, col * 2)) --> input image 홰손된다
    # resized_data = data.repeat(2, axis=0).repeat(2, axis=1)
    data = data.repeat(2, axis=0).repeat(2, axis=1)
    # resized_data = data.repeat(1, axis=0).repeat(1, axis=1)
    # cmapped = plt.cm.Set1(resized_data)[:, :, :3]  # Drop Alpha Channel
    
    if d_i == 0:
      plt.imshow(data)
      plt.show()
      # plt.imshow(resized_data)
      # plt.show()
    # print('resized_data.shape :', resized_data.shape)
    # break
    temp_x.append(data)

  return temp_x

# %%
def min_max_scale(npy_x):

  return (npy_x - np.min(npy_x)) / (np.max(npy_x) - np.min(npy_x))


def class_ratio(in_list):

  return in_list / in_list[1]

# %%
from sklearn.preprocessing import MinMaxScaler, MaxAbsScaler
import pickle
from sklearn.model_selection import train_test_split
from datetime import datetime

from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 
from sklearn.utils import class_weight

from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

from funcs_indicator import *
from tqdm.notebook import tqdm


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)


start_stamp = 0
# start_stamp = datetime.timestamp(pd.to_datetime('2021-02-12'))
print("start_stamp :", start_stamp)
# break

np.random.shuffle(file_list)
candis = file_list

long_index = 0
leverage = 5
prev_x = None
total_x = None

seed = 1
random_state = 201
np.random.seed(seed)


for i in range(len(candis)):

  keys = [candis[i]]
  
  # if 'algo'.upper() not in candis[i]:
  #   continue


  # if '02-11' not in candis[i]:  # <-- 04-08 includes all timestamp range
  #   continue  

  # if 'eth'.upper() not in candis[i]:
  #   continue

  # if 'neo'.upper() not in candis[i]:
  #   continue

  # plt.figure(figsize=(35, 10))
  # plt.suptitle('%s %s' % (interval, keys))


  #         get tp parameter        #

  # plt.subplot(1,10,3)
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['ap_list'])
  #   argmax = np.argmax(profit_result_dict[key]['ap_list'][:, [long_index]])
  #   peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(peak_tp, linestyle='--')
  #   # plt.title('acc profit, max at %.4f' % (peak_tp))  

  # plt.subplot(1,10,4)
  # plt.title('max acc profit by leverage')  
  # for key in keys:  
  #   # plt.plot(profit_result_dict[key]['tp_list'], profit_result_dict[key]['max_ap_list'], label=key)
  #   argmax = np.argmax(profit_result_dict[key]['max_ap_list'][:, [long_index]])
  #   max_peak_tp = profit_result_dict[key]['tp_list'][argmax]
  #   # plt.axvline(max_peak_tp, linestyle='--')
  #   # plt.title('max acc profit, max at %.4f' % (max_peak_tp))  


  for key in keys:  

    # print(profit_result_dict[key]['leverage_ap_list'])

    # for tp in [max_peak_tp]:

      # if tp == peak_tp:
      #   plt.subplot(1,10,5)
      # else:
      #   plt.subplot(1,10,6)

      #     leverage analysis     #
      # ohlcv = load_dict[key]['ohlcv']

    if 'neo'.upper() not in key:
      continue
    
    ohlcv = pd.read_excel(date_path + key, index_col=0)
    print('len(ohlcv) :', len(ohlcv))


    #       select timestamp range      #
    # time_index = ohlcv.index
    # total_stamp = list(map(lambda x: datetime.timestamp(x), time_index)) 

    # rm_index_amt = np.sum(np.array(total_stamp) < start_stamp)

    # ohlcv = ohlcv.iloc[rm_index_amt:]
    # print(ohlcv.head())

    # ohlcv = ohlcv.iloc[:-2603]  # exclude back_range
    # ohlcv = ohlcv.iloc[:-int(len(ohlcv) * 0.3)]  # exclude back_range
    # predictions = load_dict[key]['predictions']
    # err_ranges = load_dict[key]['err_ranges']
    print("ohlcv.index[0] :", ohlcv.index[0])
    print("ohlcv.index[-1] :", ohlcv.index[-1])

    predictions = ohlcv['close'].shift(1).values
    err_ranges = np.zeros_like(predictions)

    # leverage_list = profit_result_dict[key]['leverage_list']
    # temp_ap_list = list()
    # temp_pr_list = list()

    try:
      print('-------------- %s --------------' % key)
      result = get_back_result(ohlcv, predictions, err_ranges, tp=0, leverage=leverage, show_plot=True, reverse_short=False, show_detail=False)
      # temp_ap_list.append(result[2])
      # temp_pr_list.append(result[3])

      # if round(leverage) == 1:
      #   temp_pr_list = result[3]
      pr_list = result[3][long_index]

    except Exception as e:
      print(e)
      break    


    
  # break
    #         clustering zone           #

    #       set data features : ohlc, v, ep
    time_index = ohlcv.index[-len(predictions):]

    sliced_ohlcv = ohlcv[-len(predictions):]

    #       scale with price    #
    ohlc = ohlcv.iloc[-len(predictions):, :4]      
    long_ep = np.array(predictions)
    long_ep = long_ep.reshape(-1, 1)
    ha_ohlc = heikinashi(sliced_ohlcv).iloc[:, :4]
    sar = lucid_sar(sliced_ohlcv)
    ema1, ema2, ema3 = ema_ribbon(sliced_ohlcv)
    senkou1, senkou2 = ichimoku(sliced_ohlcv)

    #     min max scale   #
    vol = sliced_ohlcv.iloc[-len(predictions):, [4]]

    #     scale with baseline   #
    #     방법 1. 전체 기간 min_max scaling   #
    # cbo, ema_cbo = cct_bbo(sliced_ohlcv, 21, 13) 

    # _, _, bbw = bb_width(sliced_ohlcv, 20, 2) 
    
    # fish = fisher(sliced_ohlcv, 60)
    # trix = trix_hist(sliced_ohlcv, 14, 1, 5) 
    # rsi_ = rsi(sliced_ohlcv)
    # macd_hist = macd(sliced_ohlcv)




    # ohlcv['u_wick'] = ohlcv['high'] / np.maximum(ohlcv['close'] , ohlcv['open'])
    # ohlcv['d_wick'] = np.minimum(ohlcv['close'] , ohlcv['open']) / ohlcv['low']
    # ohlcv['body'] = ohlcv['close'] / ohlcv['open']
    # candle = ohlcv.iloc[-len(predictions):, -3:]


    print('len(ohlc) :', len(ohlc))
    print('long_ep.shape :', long_ep.shape)
    print('len(ha_ohlc) :', len(ha_ohlc))
    print('len(sar) :', len(sar))
    print('len(ema1) :', len(ema1))
    print('len(senkou1) :', len(senkou1))
    # print('len(cbo) :', len(cbo))
    # print('len(ema_cbo) :', len(ema_cbo))
    # print('len(bbw) :', len(bbw))
    # print('len(fish) :', len(fish))
    # print('len(trix) :', len(trix))
    # print('len(rsi_) :', len(rsi_))
    # print('len(macd_hist) :', len(macd_hist))


    # break


    #       set params    #
    period = 45
    # key_i = i

    # # plt.plot(cbo)
    # # plt.plot(bbw)
    # plt.plot(fish, color='b')
    # # plt.plot(trix)
    # # plt.plot(rsi_)
    # # plt.plot(macd_hist)
    # plt.show()

    #      global scaling   #
    # min_max = MinMaxScaler()
    # cbo = min_max.fit_transform(cbo.values.reshape(-1, 1))
    # ema_cbo = min_max.fit_transform(ema_cbo.values.reshape(-1, 1))
    # bbw = min_max.fit_transform(bbw.values.reshape(-1, 1))
    # fish = min_max.fit_transform(fish.values.reshape(-1, 1))
    # trix = min_max.fit_transform(trix.values.reshape(-1, 1))
    # rsi_ = min_max.fit_transform(rsi_.values.reshape(-1, 1))
    # macd_hist = min_max.fit_transform(macd_hist.values.reshape(-1, 1))

    # # plt.plot(cbo)
    # # plt.plot(bbw)
    # plt.plot(fish, color='r')
    # # plt.plot(trix)
    # # plt.plot(rsi_)
    # # plt.plot(macd_hist)
    # plt.show()
    # break

    plotting = True

    for trial_number in range(1):

      data_x, data_pr, data_updown = [], [], []
      data_index = []

      for i in range(period, len(predictions)):

        #   pr_list != 1 인 데이터만 사용한다
        # if 1:
        if pr_list[i] != 1:

          min_max = MinMaxScaler()
          
          #   prediction 을 제외한 이전 데이터를 사용해야한다
          temp_ohlc = ohlc.iloc[i - period : i].values
          temp_long_ep = long_ep[i - period : i]          
          temp_ha_ohlc = ha_ohlc.iloc[i - period : i].values
          temp_sar = sar.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema1 = ema1.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema2 = ema2.iloc[i - period : i].values.reshape(-1, 1)
          temp_ema3 = ema3.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou1 = senkou1.iloc[i - period : i].values.reshape(-1, 1)
          temp_senkou2 = senkou2.iloc[i - period : i].values.reshape(-1, 1)          

          price_data = np.hstack((temp_ohlc, temp_long_ep, temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2))

          if np.isnan(np.sum(price_data)):
            continue

          # print("price_data[:10] :", price_data[:10])
          # print("temp_ohlc.shape :", temp_ohlc.shape)
          # print("temp_long_ep.shape :", temp_long_ep.shape)
          # print("temp_ha_ohlc.shape :", temp_ha_ohlc.shape)
          # print("price_data.shape :", price_data.shape)

          if plotting:
            plt.plot(price_data)
            plt.show()

          ind_temp_ohlc = min_max_scale(temp_ohlc)
          temp_price_data = min_max_scale(price_data)
          # temp_price_data = (price_data - np.min(price_data)) / (np.max(price_data) - np.min(price_data))

          temp_ohlc = temp_price_data[:, :4]
          # temp_long_ep = temp_price_data[:, [4]]
          # temp_ha_ohlc = temp_price_data[:, 5:9]
          # temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2 = np.split(temp_price_data[:, 9:], 6, axis=1)

          if plotting:

            plt.plot(temp_price_data)
            plt.show()

            plotting = False
          # break

          #   vol -> min_max
          temp_vol = min_max.fit_transform(vol.iloc[i - period : i].values.reshape(-1, 1))
          
          # temp_candle = candle.iloc[i - period : i].values

          # temp_cbo = cbo[i - period : i]
          # temp_ema_cbo = ema_cbo[i - period : i]
          # temp_bbw = bbw[i - period : i]
          # temp_fish = fish[i - period : i]
          # temp_trix = trix[i - period : i]
          # temp_rsi_ = rsi_[i - period : i]
          # temp_macd_hist = macd_hist[i - period : i]

          # # print(temp_ohlc.shape)
          # # print(temp_long_ep.shape)
          # # print(temp_vol.shape)
          # # print(temp_candle.shape)
          # # break

          # trial_list = [temp_ha_ohlc, temp_sar, temp_ema1, temp_ema2, temp_ema3, temp_senkou1, temp_senkou2,
          #               temp_cbo, temp_ema_cbo, temp_bbw, temp_fish, temp_trix, temp_rsi_, temp_macd_hist]

          # trial_list = [temp_ohlc[:, [0], temp_ohlc[:, [1], temp_ohlc[:, [2], temp_ohlc[:, [3]], temp_vol, temp_ema_cbo]

          #                   feature selection                   #  
          # temp_data = np.hstack((temp_ohlc, temp_long_ep, temp_vol, temp_candle))
          # temp_data = trial_list[trial_number]
          # temp_data = np.hstack((temp_ohlc[:, [3]], temp_ohlc[:, [1]], temp_bbw))
          # temp_data = temp_ohlc[:, [3]]
          temp_data = ind_temp_ohlc[:, [3]]
          # temp_data = np.hstack((temp_ohlc, temp_vol))

          #     only close    #
          # temp_data = temp_ohlc[:, [-1]]

          # temp_data = temp_ohlc

          #     only volume    #
          # temp_data = temp_vol

          # temp_data = np.hstack((temp_ohlc, temp_long_ep))
          # temp_data = temp_vol

          #   scaler 설정

          #   ohlc & ep -> max_abs
          # max_abs = MaxAbsScaler()
          # temp_data[:, :-1] = max_abs.fit_transform(temp_data[:, :-1])

          
          # min_max = MinMaxScaler()
          # temp_data = min_max.fit_transform(temp_data)

          #   candle -> max_abs    
          # max_abs = MaxAbsScaler()
          # temp_data[:, -3:] = max_abs.fit_transform(temp_data[:, -3:])

          # min_max = MinMaxScaler()
          # temp_data[:, -3:] = min_max.fit_transform(temp_data[:, -3:])

          if np.isnan(np.sum(temp_data)):
            continue

          data_x.append(temp_data)
          data_pr.append(pr_list[i])
          data_index.append(time_index[i])
          data_updown.append(ohlc['close'].iloc[i] / ohlc['open'].iloc[i])


      print('np.array(data_x).shape :', np.array(data_x).shape)
      # print(data_x[0])


      #       Reshape data for image deep - learning     #
      _, row, col = np.array(data_x).shape

      input_x = np.array(data_x).reshape(-1, row, col, 1).astype(np.float32)
      # input_x = np.array(data_x).reshape(-1, row, col).astype(np.float32)

      #     1c to 3c    #
      input_x = input_x * np.ones(3, dtype=np.float32)[None, None, None, :]
      input_x = np.array(resize_npy(input_x))


      input_pr = np.array(data_pr).reshape(-1, 1).astype(np.float32)
      input_ud = np.array(data_updown).reshape(-1, 1).astype(np.float32)
      input_index = np.array(data_index).reshape(-1, 1)
      print('input_x.shape :', input_x.shape)
      print('input_x.dtype :', input_x.dtype)
      print('input_pr.shape :', input_pr.shape)
      print('input_ud.shape :', input_ud.shape)
      print('input_index.shape :', input_index.shape)


      # x_train_, x_test, pr_train_, pr_test, ud_train_, ud_test = train_test_split(input_x, input_pr, input_ud, test_size=0.4, shuffle=False, random_state=random_state)
      # x_train, x_val, pr_train, pr_val, ud_train, ud_val = train_test_split(x_train_, pr_train_, ud_train_, test_size=0.25, shuffle=False, random_state=random_state)

      #     do stacking   #
      # if prev_x is None:
      prev_x = input_x
      prev_pr = input_pr
      prev_ud = input_ud
      prev_index = input_index

      total_x = input_x
      total_pr = input_pr
      total_ud = input_ud
      total_index = input_index

      # else:
      #   total_x = np.vstack((prev_x, input_x))
      #   total_pr = np.vstack((prev_pr, input_pr))
      #   total_ud = np.vstack((prev_ud, input_ud)) 
      #   total_index = np.vstack((prev_index, input_index)) 

      #   prev_x = total_x
      #   prev_pr = total_pr
      #   prev_ud = total_ud
      #   prev_index = total_index

      print('total_x.shape :', total_x.shape)
      print('total_pr.shape :', total_pr.shape)
      print('total_ud.shape :', total_ud.shape)
      print('prev_index.shape :', prev_index.shape)

      
      _, row, col, _ = input_x.shape
      # _, row, col = input_x.shape
      # row = 

      #       split new test      #

      seed = 1
      random_state = 202
      np.random.seed(seed)
      from sklearn.model_selection import train_test_split
  
      symbol_name = key.split(' ')[1].split('.')[0]

      print(np.unique(total_index, return_counts=True))
      uniq_stamp = np.unique(total_index)

      stamp_train_, stamp_test = train_test_split(uniq_stamp, test_size=0.2, shuffle=False, random_state=random_state)
      stamp_train, stamp_val = train_test_split(stamp_train_, test_size=0.25, shuffle=True, random_state=random_state)

      print("stamp_train.shape :", stamp_train.shape)
      print("stamp_val.shape :", stamp_val.shape)
      print("stamp_test.shape :", stamp_test.shape)
      # break


      #         split data by stamp     #
      x_train, x_val, x_test = [], [], []
      pr_train, pr_val, pr_test = [], [], []
      index_train, index_val, index_test = [], [], []


      from tqdm.notebook import tqdm

      np.random.shuffle(total_index)

      for i in tqdm(range(len(total_index))):

        if total_index[i] in stamp_train:
          x_train.append(total_x[i])
          pr_train.append(total_pr[i])
          index_train.append(total_index[i])

        elif total_index[i] in stamp_val:
          x_val.append(total_x[i])
          pr_val.append(total_pr[i])
          index_val.append(total_index[i])
        
        elif total_index[i] in stamp_test:
          x_test.append(total_x[i])
          pr_test.append(total_pr[i])
          index_test.append(total_index[i])


      x_train = np.array(x_train)
      x_val = np.array(x_val)
      x_test = np.array(x_test)

      pr_train = np.array(pr_train)
      pr_val = np.array(pr_val)
      pr_test = np.array(pr_test)

      y_test = np.where(pr_test > 1, 1, 0)


      index_train = np.array(index_train)
      index_val = np.array(index_val)
      index_test = np.array(index_test)
        
      print("x_train.shape :", x_train.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_val.shape :", x_val.shape) # x_train.shape : (3807, 90, 12, 3)
      print("x_test.shape :", x_test.shape) # x_train.shape : (3807, 90, 12, 3)

      #     test 로 부터 index 한개씩, train / val 로 붙이고 train / val 로부터 -1 data   #
      #     len(test) 만큼 수행   #
      x_train, x_test, pr_train, pr_test = train_test_split(total_x, total_pr, test_size=0.2, shuffle=False)

      # x_test = np.vstack((x_test, total_x))
      # pr_test = np.vstack((pr_test, total_pr))

      # org_x_train, org_x_test, org_pr_train, org_pr_test = train_test_split(total_x, total_pr, test_size=0.2, shuffle=False)   


  # break # --> use only one pair dataset

  #         chunks 로 나누지 않아도, generator 에서 batch_size 만큼만 load 할 것   #
  try:
    if len(total_x) > 300000:
      break
  except:
    pass
# Out:
# start_stamp : 0
# len(ohlcv) : 18048
# ohlcv.index[0] : 2020-04-17 00:29:59.999000
# ohlcv.index[-1] : 2021-04-27 23:59:59.999000
# -------------- 2021-04-27 NEOUSDT.xlsx --------------
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:158: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: invalid value encountered in long_scalars
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# len(ohlc) : 18048
# long_ep.shape : (18048, 1)
# len(ha_ohlc) : 18048
# len(sar) : 18048
# len(ema1) : 18048
# len(senkou1) : 18048
# np.array(data_x).shape : (17218, 45, 1)
# input_x.shape : (17218, 90, 2, 3)
# input_x.dtype : float32
# input_pr.shape : (17218, 1)
# input_ud.shape : (17218, 1)
# input_index.shape : (17218, 1)
# total_x.shape : (17218, 90, 2, 3)
# total_pr.shape : (17218, 1)
# total_ud.shape : (17218, 1)
# prev_index.shape : (17218, 1)
# (array([Timestamp('2020-04-19 12:59:59.999000'),
#        Timestamp('2020-04-19 13:29:59.999000'),
#        Timestamp('2020-04-19 13:59:59.999000'), ...,
#        Timestamp('2021-04-27 22:59:59.999000'),
#        Timestamp('2021-04-27 23:29:59.999000'),
#        Timestamp('2021-04-27 23:59:59.999000')], dtype=object), array([1, 1, 1, ..., 1, 1, 1]))
# stamp_train.shape : (10330,)
# stamp_val.shape : (3444,)
# stamp_test.shape : (3444,)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:372: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# HBox(children=(FloatProgress(value=0.0, max=17218.0), HTML(value='')))
# x_train.shape : (10330, 90, 2, 3)
# x_val.shape : (3444, 90, 2, 3)
# x_test.shape : (3444, 90, 2, 3)

# %%
total_result = []
t_result_path = current_path + 'npy/' + '%s_cnn_close_updown_x_t_result_timesplit_norot_%s.npy' % (period, symbol_name)
try:
  total_result = np.load(t_result_path)
  total_result = list(total_result)
  print("----------------------- total_result loaded ! -----------------------")
  print("len(total_result) :", len(total_result))
except:
  pass

for r_i in tqdm(range(len(x_test))):

  if r_i < len(total_result):
    continue

  new_x_test = x_test[[r_i]]
  new_pr_test = pr_test[[r_i]]

  ind_x_train = np.vstack((x_train[r_i:], x_test[:r_i]))
  ind_pr_train = np.vstack((pr_train[r_i:], pr_test[:r_i]))

  # new_x_test = x_test
  # new_pr_test = pr_test

  #     add & remove test set   #
  new_x_train, new_x_val, new_pr_train, new_pr_val = train_test_split(ind_x_train, ind_pr_train, test_size=0.25, shuffle=True, random_state=random_state)
  # new_x_train = x_train
  # new_x_val = x_val

  new_y_train = np.where(new_pr_train > 1, 1, 0)
  new_y_val = np.where(new_pr_val > 1, 1, 0)
  new_y_test = np.where(new_pr_test > 1, 1, 0)

  
  print('new_x_train.shape :', new_x_train.shape)
  print('new_x_test.shape :', new_x_test.shape)
  print('new_x_val.shape :', new_x_val.shape)
  print('new_y_train.shape :', new_y_train.shape)
  print('new_y_test.shape :', new_y_test.shape)
  print('new_y_val.shape :', new_y_val.shape)


  print('np.unique(y_train, return_counts=True :', np.unique(new_y_train, return_counts=True), class_ratio(np.unique(new_y_train, return_counts=True)[1]))
  print('np.unique(new_y_val, return_counts=True :', np.unique(new_y_val, return_counts=True), class_ratio(np.unique(new_y_val, return_counts=True)[1]))
  # print('np.unique(new_y_test, return_counts=True :', np.unique(new_y_test, return_counts=True), class_ratio(np.unique(new_y_test, return_counts=True)[1]))

  label = new_y_train.reshape(-1, )
  class_weights = class_weight.compute_class_weight('balanced', 
                                                      classes=np.unique(label),
                                                      y=label)
  class_weights = dict(enumerate(class_weights))
  print('class_weights :', class_weights)

  # sample_weight = np.ones(shape=(len(new_y_train),))
  # sample_weight[(new_y_train == 1).reshape(-1,)] = 1.5
  # print('sample_weight[:20] :', sample_weight[:20])


  print('np.isnan(np.sum(x_train)) :', np.isnan(np.sum(new_x_train)))
  print('np.isnan(np.sum(new_x_val)) :', np.isnan(np.sum(new_x_val)))
  print('np.isnan(np.sum(new_x_test)) :', np.isnan(np.sum(new_x_test)))

  print('np.isnan(np.sum(new_y_train)) :', np.isnan(np.sum(new_y_train)))
  print('np.isnan(np.sum(new_y_val)) :', np.isnan(np.sum(new_y_val)))
  print('np.isnan(np.sum(new_y_test)) :', np.isnan(np.sum(new_y_test)))

  num_classes = 2
  new_y_train_ohe = np_utils.to_categorical(new_y_train, num_classes)
  new_y_val_ohe = np_utils.to_categorical(new_y_val, num_classes)
  new_y_test_ohe = np_utils.to_categorical(new_y_test, num_classes)
  print('new_y_train_ohe.shape :', new_y_train_ohe.shape)
  print('new_y_val_ohe.shape :', new_y_val_ohe.shape)
  print('new_y_test_ohe.shape :', new_y_test_ohe.shape)
  
  datagen = ImageDataGenerator( 
      # rotation_range = 45,
      # zoom_range = 0.5,
      # shear_range = 0.5,
      # horizontal_flip = True,
      # vertical_flip = True,
      # width_shift_range=0.5,
      # height_shift_range=0.5,
      # fill_mode = 'nearest'
      )

  valgen = ImageDataGenerator( 
      )

  datagen.fit(new_x_train)
  valgen.fit(new_x_val)

  batch_size = 128
      
  train_flow = datagen.flow(new_x_train, new_y_train_ohe, batch_size=batch_size) 
  val_flow = valgen.flow(new_x_val, new_y_val_ohe, batch_size=batch_size) 
  # break


  ckpt_path = current_path + 'ckpt/'
  board_path = current_path + 'graph/'

  model_name = 'classifier_%s_cnn_close_updown_timesplit_norot_%s.h5' % (period, symbol_name)

#       retraining    #       
  if r_i != 0:

    K.clear_session() # added for training delation

    try:
      model = keras.models.load_model(ckpt_path + model_name)
      print("----------------------- model loaded ! -----------------------")

      for l_i, layer in enumerate(model.layers):

        if l_i != len(model.layers) - 1:
          layer.trainable = False

    except Exception as e:
      print('Error in load_model :', e)
      model = FER_Model(input_shape=(x_train.shape[1:]))

    # first_iter = False
    

  else:
    model = FER_Model(input_shape=(x_train.shape[1:]))


  # batch_size = 128
  # _, row, col, = x_train.shape
  # print("row, col :", row, col)

  opt = Adam(lr=0.00001, decay=0.000005)
  # opt = Adam(lr=0.001, decay=0.0005)
  model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

  checkpoint = ModelCheckpoint(ckpt_path + model_name, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')
  checkpoint2 = TensorBoard(log_dir=board_path,
                            histogram_freq=0,
                            write_graph=True,
                            write_images=True)
  checkpoint3 = EarlyStopping(monitor='val_loss', patience=50)
  # checkpoint3 = EarlyStopping(monitor='val_loss', patience=250)
  callbacks_list = [checkpoint, checkpoint2, checkpoint3]
  # callbacks_list = [checkpoint, checkpoint2]

  # keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

  # we iterate 200 times over the entire training set
  num_epochs = 1000    
  history = model.fit_generator(train_flow, 
                      steps_per_epoch=len(x_train) / batch_size, 
                      epochs=num_epochs,  
                      verbose=2,  
                      callbacks=callbacks_list,
                      class_weight=class_weights,
                      validation_data=val_flow,  
                      validation_steps=len(x_val) / batch_size,
                      shuffle=False)
  

  model = keras.models.load_model(ckpt_path + model_name)

  test_result = model.predict(new_x_test)
  
  total_result.append(test_result)
  print('test_result.shape :', test_result.shape)

  
  np.save(t_result_path, np.array(total_result))
  print('total_result.shape :', np.array(total_result).shape)

total_result = np.array(total_result).reshape(-1, 2)

# total_result = test_result
y_score = total_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(new_y_test, y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.65]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(new_y_test, y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(new_y_test)
  test_pr_list = pr_test
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  # if len(threshold) == 1:
#   plt.figure(figsize=(10, 5))
#   plt.subplot(121)
#   plt.plot(np.cumprod(test_pr_list))
#   plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
# # plt.show()

#   plt.subplot(122)
#   plt.plot(np.cumprod(pred_pr_list))
#   plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
#   # plt.axvline(len(org_pr_test), linestyle='--', color='r')
#   plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.title(symbol_name)
plt.show()
# Out:
# ----------------------- total_result loaded ! -----------------------
# len(total_result) : 1840
# HBox(children=(FloatProgress(value=0.0, max=3444.0), HTML(value='')))
# Streaming output truncated to the last 5000 lines.
#
# Epoch 00044: val_loss did not improve from 0.63735
# Epoch 45/1000
#  - 1s - loss: 0.6710 - accuracy: 0.5909 - val_loss: 0.6688 - val_accuracy: 0.5865
#
# Epoch 00045: val_loss did not improve from 0.63735
# Epoch 46/1000
#  - 1s - loss: 0.6701 - accuracy: 0.5908 - val_loss: 0.6654 - val_accuracy: 0.5859
#
# Epoch 00046: val_loss did not improve from 0.63735
# Epoch 47/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5901 - val_loss: 0.7006 - val_accuracy: 0.5865
#
# Epoch 00047: val_loss did not improve from 0.63735
# Epoch 48/1000
#  - 1s - loss: 0.6705 - accuracy: 0.5901 - val_loss: 0.6859 - val_accuracy: 0.5862
#
# Epoch 00048: val_loss did not improve from 0.63735
# Epoch 49/1000
#  - 1s - loss: 0.6712 - accuracy: 0.5889 - val_loss: 0.6473 - val_accuracy: 0.5865
#
# Epoch 00049: val_loss did not improve from 0.63735
# Epoch 50/1000
#  - 1s - loss: 0.6691 - accuracy: 0.5915 - val_loss: 0.6784 - val_accuracy: 0.5865
#
# Epoch 00050: val_loss did not improve from 0.63735
# Epoch 51/1000
#  - 1s - loss: 0.6717 - accuracy: 0.5905 - val_loss: 0.6817 - val_accuracy: 0.5865
#
# Epoch 00051: val_loss did not improve from 0.63735
# Epoch 52/1000
#  - 1s - loss: 0.6697 - accuracy: 0.5897 - val_loss: 0.6809 - val_accuracy: 0.5868
#
# Epoch 00052: val_loss did not improve from 0.63735
# Epoch 53/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5924 - val_loss: 0.6676 - val_accuracy: 0.5871
#
# Epoch 00053: val_loss did not improve from 0.63735
# Epoch 54/1000
#  - 1s - loss: 0.6708 - accuracy: 0.5883 - val_loss: 0.6411 - val_accuracy: 0.5871
#
# Epoch 00054: val_loss did not improve from 0.63735
# Epoch 55/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5884 - val_loss: 0.6876 - val_accuracy: 0.5871
#
# Epoch 00055: val_loss did not improve from 0.63735
# Epoch 56/1000
#  - 1s - loss: 0.6685 - accuracy: 0.5918 - val_loss: 0.6841 - val_accuracy: 0.5871
#
# Epoch 00056: val_loss did not improve from 0.63735
# Epoch 57/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5900 - val_loss: 0.6929 - val_accuracy: 0.5871
#
# Epoch 00057: val_loss did not improve from 0.63735
# Epoch 58/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5906 - val_loss: 0.6963 - val_accuracy: 0.5874
#
# Epoch 00058: val_loss did not improve from 0.63735
# Epoch 59/1000
#  - 1s - loss: 0.6684 - accuracy: 0.5915 - val_loss: 0.6930 - val_accuracy: 0.5871
#
# Epoch 00059: val_loss did not improve from 0.63735
# Epoch 60/1000
#  - 1s - loss: 0.6722 - accuracy: 0.5876 - val_loss: 0.6776 - val_accuracy: 0.5871
#
# Epoch 00060: val_loss did not improve from 0.63735
# Epoch 61/1000
#  - 1s - loss: 0.6707 - accuracy: 0.5918 - val_loss: 0.6808 - val_accuracy: 0.5874
#
# Epoch 00061: val_loss did not improve from 0.63735
# Epoch 62/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5874 - val_loss: 0.6593 - val_accuracy: 0.5871
#
# Epoch 00062: val_loss did not improve from 0.63735
# Epoch 63/1000
#  - 1s - loss: 0.6696 - accuracy: 0.5900 - val_loss: 0.7031 - val_accuracy: 0.5874
#
# Epoch 00063: val_loss did not improve from 0.63735
# Epoch 64/1000
#  - 1s - loss: 0.6712 - accuracy: 0.5881 - val_loss: 0.6774 - val_accuracy: 0.5877
#
# Epoch 00064: val_loss did not improve from 0.63735
# Epoch 65/1000
#  - 1s - loss: 0.6705 - accuracy: 0.5917 - val_loss: 0.6691 - val_accuracy: 0.5865
#
# Epoch 00065: val_loss did not improve from 0.63735
# Epoch 66/1000
#  - 1s - loss: 0.6701 - accuracy: 0.5892 - val_loss: 0.6580 - val_accuracy: 0.5871
#
# Epoch 00066: val_loss did not improve from 0.63735
# Epoch 67/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5897 - val_loss: 0.6945 - val_accuracy: 0.5865
#
# Epoch 00067: val_loss did not improve from 0.63735
# Epoch 68/1000
#  - 1s - loss: 0.6698 - accuracy: 0.5896 - val_loss: 0.6798 - val_accuracy: 0.5868
#
# Epoch 00068: val_loss did not improve from 0.63735
# Epoch 69/1000
#  - 1s - loss: 0.6708 - accuracy: 0.5895 - val_loss: 0.6572 - val_accuracy: 0.5868
#
# Epoch 00069: val_loss did not improve from 0.63735
# Epoch 70/1000
#  - 1s - loss: 0.6704 - accuracy: 0.5902 - val_loss: 0.6792 - val_accuracy: 0.5868
#
# Epoch 00070: val_loss did not improve from 0.63735
# Epoch 71/1000
#  - 1s - loss: 0.6704 - accuracy: 0.5907 - val_loss: 0.6768 - val_accuracy: 0.5868
#
# Epoch 00071: val_loss did not improve from 0.63735
# test_result.shape : (1, 2)
# total_result.shape : (1955, 1, 2)
# new_x_train.shape : (10330, 90, 2, 3)
# new_x_test.shape : (1, 90, 2, 3)
# new_x_val.shape : (3444, 90, 2, 3)
# new_y_train.shape : (10330, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (3444, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([5824, 4506])) [1.29249889 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1903, 1541])) [1.23491239 1.        ]
# class_weights : {0: 0.8868475274725275, 1: 1.146249445184199}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (10330, 2)
# new_y_val_ohe.shape : (3444, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# Epoch 1/1000
#  - 1s - loss: 0.6734 - accuracy: 0.5867 - val_loss: 0.6729 - val_accuracy: 0.5976
#
# Epoch 00001: val_loss improved from inf to 0.67293, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 2/1000
#  - 1s - loss: 0.6709 - accuracy: 0.5907 - val_loss: 0.7104 - val_accuracy: 0.5967
#
# Epoch 00002: val_loss did not improve from 0.67293
# Epoch 3/1000
#  - 1s - loss: 0.6745 - accuracy: 0.5857 - val_loss: 0.6565 - val_accuracy: 0.5970
#
# Epoch 00003: val_loss improved from 0.67293 to 0.65652, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 4/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5890 - val_loss: 0.6581 - val_accuracy: 0.5970
#
# Epoch 00004: val_loss did not improve from 0.65652
# Epoch 5/1000
#  - 1s - loss: 0.6745 - accuracy: 0.5860 - val_loss: 0.6388 - val_accuracy: 0.5967
#
# Epoch 00005: val_loss improved from 0.65652 to 0.63876, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 6/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5882 - val_loss: 0.6682 - val_accuracy: 0.5964
#
# Epoch 00006: val_loss did not improve from 0.63876
# Epoch 7/1000
#  - 1s - loss: 0.6732 - accuracy: 0.5882 - val_loss: 0.6488 - val_accuracy: 0.5967
#
# Epoch 00007: val_loss did not improve from 0.63876
# Epoch 8/1000
#  - 1s - loss: 0.6732 - accuracy: 0.5863 - val_loss: 0.6940 - val_accuracy: 0.5967
#
# Epoch 00008: val_loss did not improve from 0.63876
# Epoch 9/1000
#  - 1s - loss: 0.6723 - accuracy: 0.5874 - val_loss: 0.6576 - val_accuracy: 0.5967
#
# Epoch 00009: val_loss did not improve from 0.63876
# Epoch 10/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5899 - val_loss: 0.7006 - val_accuracy: 0.5967
#
# Epoch 00010: val_loss did not improve from 0.63876
# Epoch 11/1000
#  - 1s - loss: 0.6745 - accuracy: 0.5843 - val_loss: 0.6759 - val_accuracy: 0.5970
#
# Epoch 00011: val_loss did not improve from 0.63876
# Epoch 12/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5881 - val_loss: 0.6869 - val_accuracy: 0.5967
#
# Epoch 00012: val_loss did not improve from 0.63876
# Epoch 13/1000
#  - 1s - loss: 0.6739 - accuracy: 0.5857 - val_loss: 0.6561 - val_accuracy: 0.5967
#
# Epoch 00013: val_loss did not improve from 0.63876
# Epoch 14/1000
#  - 1s - loss: 0.6709 - accuracy: 0.5917 - val_loss: 0.6520 - val_accuracy: 0.5967
#
# Epoch 00014: val_loss did not improve from 0.63876
# Epoch 15/1000
#  - 1s - loss: 0.6740 - accuracy: 0.5844 - val_loss: 0.6473 - val_accuracy: 0.5973
#
# Epoch 00015: val_loss did not improve from 0.63876
# Epoch 16/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5876 - val_loss: 0.6642 - val_accuracy: 0.5973
#
# Epoch 00016: val_loss did not improve from 0.63876
# Epoch 17/1000
#  - 1s - loss: 0.6736 - accuracy: 0.5866 - val_loss: 0.6806 - val_accuracy: 0.5973
#
# Epoch 00017: val_loss did not improve from 0.63876
# Epoch 18/1000
#  - 1s - loss: 0.6729 - accuracy: 0.5868 - val_loss: 0.6884 - val_accuracy: 0.5973
#
# Epoch 00018: val_loss did not improve from 0.63876
# Epoch 19/1000
#  - 1s - loss: 0.6735 - accuracy: 0.5852 - val_loss: 0.6502 - val_accuracy: 0.5973
#
# Epoch 00019: val_loss did not improve from 0.63876
# Epoch 20/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5897 - val_loss: 0.6778 - val_accuracy: 0.5973
#
# Epoch 00020: val_loss did not improve from 0.63876
# Epoch 21/1000
#  - 1s - loss: 0.6733 - accuracy: 0.5864 - val_loss: 0.6783 - val_accuracy: 0.5973
#
# Epoch 00021: val_loss did not improve from 0.63876
# Epoch 22/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5888 - val_loss: 0.6896 - val_accuracy: 0.5976
#
# Epoch 00022: val_loss did not improve from 0.63876
# Epoch 23/1000
#  - 1s - loss: 0.6736 - accuracy: 0.5864 - val_loss: 0.6843 - val_accuracy: 0.5973
#
# Epoch 00023: val_loss did not improve from 0.63876
# Epoch 24/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5858 - val_loss: 0.6770 - val_accuracy: 0.5976
#
# Epoch 00024: val_loss did not improve from 0.63876
# Epoch 25/1000
#  - 1s - loss: 0.6734 - accuracy: 0.5872 - val_loss: 0.6662 - val_accuracy: 0.5973
#
# Epoch 00025: val_loss did not improve from 0.63876
# Epoch 26/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5881 - val_loss: 0.6674 - val_accuracy: 0.5976
#
# Epoch 00026: val_loss did not improve from 0.63876
# Epoch 27/1000
#  - 1s - loss: 0.6733 - accuracy: 0.5859 - val_loss: 0.6621 - val_accuracy: 0.5973
#
# Epoch 00027: val_loss did not improve from 0.63876
# Epoch 28/1000
#  - 1s - loss: 0.6728 - accuracy: 0.5867 - val_loss: 0.6736 - val_accuracy: 0.5976
#
# Epoch 00028: val_loss did not improve from 0.63876
# Epoch 29/1000
#  - 1s - loss: 0.6738 - accuracy: 0.5878 - val_loss: 0.6479 - val_accuracy: 0.5976
#
# Epoch 00029: val_loss did not improve from 0.63876
# Epoch 30/1000
#  - 1s - loss: 0.6723 - accuracy: 0.5869 - val_loss: 0.6747 - val_accuracy: 0.5976
#
# Epoch 00030: val_loss did not improve from 0.63876
# Epoch 31/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5877 - val_loss: 0.6580 - val_accuracy: 0.5976
#
# Epoch 00031: val_loss did not improve from 0.63876
# Epoch 32/1000
#  - 1s - loss: 0.6730 - accuracy: 0.5881 - val_loss: 0.6761 - val_accuracy: 0.5979
#
# Epoch 00032: val_loss did not improve from 0.63876
# Epoch 33/1000
#  - 1s - loss: 0.6741 - accuracy: 0.5852 - val_loss: 0.6863 - val_accuracy: 0.5973
#
# Epoch 00033: val_loss did not improve from 0.63876
# Epoch 34/1000
#  - 1s - loss: 0.6749 - accuracy: 0.5844 - val_loss: 0.6779 - val_accuracy: 0.5970
#
# Epoch 00034: val_loss did not improve from 0.63876
# Epoch 35/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5882 - val_loss: 0.6569 - val_accuracy: 0.5976
#
# Epoch 00035: val_loss did not improve from 0.63876
# Epoch 36/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5882 - val_loss: 0.6795 - val_accuracy: 0.5967
#
# Epoch 00036: val_loss did not improve from 0.63876
# Epoch 37/1000
#  - 1s - loss: 0.6730 - accuracy: 0.5872 - val_loss: 0.6681 - val_accuracy: 0.5961
#
# Epoch 00037: val_loss did not improve from 0.63876
# Epoch 38/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5889 - val_loss: 0.6662 - val_accuracy: 0.5967
#
# Epoch 00038: val_loss did not improve from 0.63876
# Epoch 39/1000
#  - 1s - loss: 0.6739 - accuracy: 0.5844 - val_loss: 0.6669 - val_accuracy: 0.5967
#
# Epoch 00039: val_loss did not improve from 0.63876
# Epoch 40/1000
#  - 1s - loss: 0.6737 - accuracy: 0.5860 - val_loss: 0.6541 - val_accuracy: 0.5964
#
# Epoch 00040: val_loss did not improve from 0.63876
# Epoch 41/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5864 - val_loss: 0.6275 - val_accuracy: 0.5970
#
# Epoch 00041: val_loss improved from 0.63876 to 0.62751, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 42/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5887 - val_loss: 0.6539 - val_accuracy: 0.5964
#
# Epoch 00042: val_loss did not improve from 0.62751
# Epoch 43/1000
#  - 1s - loss: 0.6733 - accuracy: 0.5881 - val_loss: 0.6839 - val_accuracy: 0.5961
#
# Epoch 00043: val_loss did not improve from 0.62751
# Epoch 44/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5851 - val_loss: 0.6220 - val_accuracy: 0.5961
#
# Epoch 00044: val_loss improved from 0.62751 to 0.62198, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 45/1000
#  - 1s - loss: 0.6739 - accuracy: 0.5874 - val_loss: 0.6589 - val_accuracy: 0.5955
#
# Epoch 00045: val_loss did not improve from 0.62198
# Epoch 46/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5875 - val_loss: 0.6937 - val_accuracy: 0.5958
#
# Epoch 00046: val_loss did not improve from 0.62198
# Epoch 47/1000
#  - 1s - loss: 0.6731 - accuracy: 0.5874 - val_loss: 0.6568 - val_accuracy: 0.5955
#
# Epoch 00047: val_loss did not improve from 0.62198
# Epoch 48/1000
#  - 1s - loss: 0.6730 - accuracy: 0.5874 - val_loss: 0.6796 - val_accuracy: 0.5952
#
# Epoch 00048: val_loss did not improve from 0.62198
# Epoch 49/1000
#  - 1s - loss: 0.6734 - accuracy: 0.5873 - val_loss: 0.6735 - val_accuracy: 0.5952
#
# Epoch 00049: val_loss did not improve from 0.62198
# Epoch 50/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5881 - val_loss: 0.6611 - val_accuracy: 0.5952
#
# Epoch 00050: val_loss did not improve from 0.62198
# Epoch 51/1000
#  - 1s - loss: 0.6736 - accuracy: 0.5860 - val_loss: 0.6808 - val_accuracy: 0.5955
#
# Epoch 00051: val_loss did not improve from 0.62198
# Epoch 52/1000
#  - 1s - loss: 0.6731 - accuracy: 0.5881 - val_loss: 0.6774 - val_accuracy: 0.5949
#
# Epoch 00052: val_loss did not improve from 0.62198
# Epoch 53/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5868 - val_loss: 0.6413 - val_accuracy: 0.5952
#
# Epoch 00053: val_loss did not improve from 0.62198
# Epoch 54/1000
#  - 1s - loss: 0.6730 - accuracy: 0.5863 - val_loss: 0.6716 - val_accuracy: 0.5952
#
# Epoch 00054: val_loss did not improve from 0.62198
# Epoch 55/1000
#  - 1s - loss: 0.6735 - accuracy: 0.5868 - val_loss: 0.6451 - val_accuracy: 0.5952
#
# Epoch 00055: val_loss did not improve from 0.62198
# Epoch 56/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5872 - val_loss: 0.6947 - val_accuracy: 0.5955
#
# Epoch 00056: val_loss did not improve from 0.62198
# Epoch 57/1000
#  - 1s - loss: 0.6729 - accuracy: 0.5874 - val_loss: 0.6786 - val_accuracy: 0.5955
#
# Epoch 00057: val_loss did not improve from 0.62198
# Epoch 58/1000
#  - 1s - loss: 0.6732 - accuracy: 0.5871 - val_loss: 0.6456 - val_accuracy: 0.5949
#
# Epoch 00058: val_loss did not improve from 0.62198
# Epoch 59/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5867 - val_loss: 0.6479 - val_accuracy: 0.5949
#
# Epoch 00059: val_loss did not improve from 0.62198
# Epoch 60/1000
#  - 1s - loss: 0.6734 - accuracy: 0.5861 - val_loss: 0.6677 - val_accuracy: 0.5952
#
# Epoch 00060: val_loss did not improve from 0.62198
# Epoch 61/1000
#  - 1s - loss: 0.6735 - accuracy: 0.5861 - val_loss: 0.6503 - val_accuracy: 0.5949
#
# Epoch 00061: val_loss did not improve from 0.62198
# Epoch 62/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5880 - val_loss: 0.6746 - val_accuracy: 0.5947
#
# Epoch 00062: val_loss did not improve from 0.62198
# Epoch 63/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5863 - val_loss: 0.6464 - val_accuracy: 0.5955
#
# Epoch 00063: val_loss did not improve from 0.62198
# Epoch 64/1000
#  - 1s - loss: 0.6739 - accuracy: 0.5841 - val_loss: 0.6343 - val_accuracy: 0.5952
#
# Epoch 00064: val_loss did not improve from 0.62198
# Epoch 65/1000
#  - 1s - loss: 0.6700 - accuracy: 0.5944 - val_loss: 0.6562 - val_accuracy: 0.5949
#
# Epoch 00065: val_loss did not improve from 0.62198
# Epoch 66/1000
#  - 1s - loss: 0.6752 - accuracy: 0.5823 - val_loss: 0.6241 - val_accuracy: 0.5955
#
# Epoch 00066: val_loss did not improve from 0.62198
# Epoch 67/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5866 - val_loss: 0.6632 - val_accuracy: 0.5955
#
# Epoch 00067: val_loss did not improve from 0.62198
# Epoch 68/1000
#  - 1s - loss: 0.6736 - accuracy: 0.5862 - val_loss: 0.6327 - val_accuracy: 0.5952
#
# Epoch 00068: val_loss did not improve from 0.62198
# Epoch 69/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5874 - val_loss: 0.6481 - val_accuracy: 0.5952
#
# Epoch 00069: val_loss did not improve from 0.62198
# Epoch 70/1000
#  - 1s - loss: 0.6746 - accuracy: 0.5852 - val_loss: 0.6622 - val_accuracy: 0.5955
#
# Epoch 00070: val_loss did not improve from 0.62198
# Epoch 71/1000
#  - 1s - loss: 0.6723 - accuracy: 0.5868 - val_loss: 0.6676 - val_accuracy: 0.5949
#
# Epoch 00071: val_loss did not improve from 0.62198
# Epoch 72/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5888 - val_loss: 0.6506 - val_accuracy: 0.5955
#
# Epoch 00072: val_loss did not improve from 0.62198
# Epoch 73/1000
#  - 1s - loss: 0.6735 - accuracy: 0.5864 - val_loss: 0.6802 - val_accuracy: 0.5944
#
# Epoch 00073: val_loss did not improve from 0.62198
# Epoch 74/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5860 - val_loss: 0.6552 - val_accuracy: 0.5947
#
# Epoch 00074: val_loss did not improve from 0.62198
# Epoch 75/1000
#  - 1s - loss: 0.6728 - accuracy: 0.5885 - val_loss: 0.6747 - val_accuracy: 0.5955
#
# Epoch 00075: val_loss did not improve from 0.62198
# Epoch 76/1000
#  - 1s - loss: 0.6735 - accuracy: 0.5863 - val_loss: 0.6642 - val_accuracy: 0.5947
#
# Epoch 00076: val_loss did not improve from 0.62198
# Epoch 77/1000
#  - 1s - loss: 0.6731 - accuracy: 0.5873 - val_loss: 0.6935 - val_accuracy: 0.5949
#
# Epoch 00077: val_loss did not improve from 0.62198
# Epoch 78/1000
#  - 1s - loss: 0.6722 - accuracy: 0.5874 - val_loss: 0.6624 - val_accuracy: 0.5944
#
# Epoch 00078: val_loss did not improve from 0.62198
# Epoch 79/1000
#  - 1s - loss: 0.6747 - accuracy: 0.5830 - val_loss: 0.6647 - val_accuracy: 0.5947
#
# Epoch 00079: val_loss did not improve from 0.62198
# Epoch 80/1000
#  - 1s - loss: 0.6700 - accuracy: 0.5917 - val_loss: 0.6758 - val_accuracy: 0.5947
#
# Epoch 00080: val_loss did not improve from 0.62198
# Epoch 81/1000
#  - 1s - loss: 0.6741 - accuracy: 0.5864 - val_loss: 0.6446 - val_accuracy: 0.5947
#
# Epoch 00081: val_loss did not improve from 0.62198
# Epoch 82/1000
#  - 1s - loss: 0.6737 - accuracy: 0.5873 - val_loss: 0.6592 - val_accuracy: 0.5944
#
# Epoch 00082: val_loss did not improve from 0.62198
# Epoch 83/1000
#  - 1s - loss: 0.6713 - accuracy: 0.5886 - val_loss: 0.6784 - val_accuracy: 0.5947
#
# Epoch 00083: val_loss did not improve from 0.62198
# Epoch 84/1000
#  - 1s - loss: 0.6738 - accuracy: 0.5852 - val_loss: 0.6638 - val_accuracy: 0.5944
#
# Epoch 00084: val_loss did not improve from 0.62198
# Epoch 85/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5877 - val_loss: 0.6691 - val_accuracy: 0.5941
#
# Epoch 00085: val_loss did not improve from 0.62198
# Epoch 86/1000
#  - 1s - loss: 0.6737 - accuracy: 0.5857 - val_loss: 0.6721 - val_accuracy: 0.5944
#
# Epoch 00086: val_loss did not improve from 0.62198
# Epoch 87/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5881 - val_loss: 0.6772 - val_accuracy: 0.5938
#
# Epoch 00087: val_loss did not improve from 0.62198
# Epoch 88/1000
#  - 1s - loss: 0.6738 - accuracy: 0.5857 - val_loss: 0.6762 - val_accuracy: 0.5941
#
# Epoch 00088: val_loss did not improve from 0.62198
# Epoch 89/1000
#  - 1s - loss: 0.6708 - accuracy: 0.5904 - val_loss: 0.6475 - val_accuracy: 0.5944
#
# Epoch 00089: val_loss did not improve from 0.62198
# Epoch 90/1000
#  - 1s - loss: 0.6741 - accuracy: 0.5857 - val_loss: 0.6546 - val_accuracy: 0.5935
#
# Epoch 00090: val_loss did not improve from 0.62198
# Epoch 91/1000
#  - 1s - loss: 0.6723 - accuracy: 0.5882 - val_loss: 0.6837 - val_accuracy: 0.5941
#
# Epoch 00091: val_loss did not improve from 0.62198
# Epoch 92/1000
#  - 1s - loss: 0.6742 - accuracy: 0.5857 - val_loss: 0.6560 - val_accuracy: 0.5938
#
# Epoch 00092: val_loss did not improve from 0.62198
# Epoch 93/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5880 - val_loss: 0.6554 - val_accuracy: 0.5938
#
# Epoch 00093: val_loss did not improve from 0.62198
# Epoch 94/1000
#  - 1s - loss: 0.6743 - accuracy: 0.5852 - val_loss: 0.6644 - val_accuracy: 0.5938
#
# Epoch 00094: val_loss did not improve from 0.62198
# test_result.shape : (1, 2)
# total_result.shape : (1956, 1, 2)
# new_x_train.shape : (10330, 90, 2, 3)
# new_x_test.shape : (1, 90, 2, 3)
# new_x_val.shape : (3444, 90, 2, 3)
# new_y_train.shape : (10330, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (3444, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([5812, 4518])) [1.28640992 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1915, 1529])) [1.25245258 1.        ]
# class_weights : {0: 0.8886785960082588, 1: 1.1432049579459937}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (10330, 2)
# new_y_val_ohe.shape : (3444, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# Epoch 1/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5890 - val_loss: 0.6762 - val_accuracy: 0.5883
#
# Epoch 00001: val_loss improved from inf to 0.67618, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 2/1000
#  - 1s - loss: 0.6729 - accuracy: 0.5902 - val_loss: 0.6658 - val_accuracy: 0.5883
#
# Epoch 00002: val_loss improved from 0.67618 to 0.66578, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 3/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5900 - val_loss: 0.6868 - val_accuracy: 0.5883
#
# Epoch 00003: val_loss did not improve from 0.66578
# Epoch 4/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5904 - val_loss: 0.6679 - val_accuracy: 0.5874
#
# Epoch 00004: val_loss did not improve from 0.66578
# Epoch 5/1000
#  - 1s - loss: 0.6730 - accuracy: 0.5869 - val_loss: 0.6446 - val_accuracy: 0.5874
#
# Epoch 00005: val_loss improved from 0.66578 to 0.64462, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 6/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5917 - val_loss: 0.6472 - val_accuracy: 0.5877
#
# Epoch 00006: val_loss did not improve from 0.64462
# Epoch 7/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5922 - val_loss: 0.6889 - val_accuracy: 0.5874
#
# Epoch 00007: val_loss did not improve from 0.64462
# Epoch 8/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5861 - val_loss: 0.6707 - val_accuracy: 0.5877
#
# Epoch 00008: val_loss did not improve from 0.64462
# Epoch 9/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5898 - val_loss: 0.6644 - val_accuracy: 0.5871
#
# Epoch 00009: val_loss did not improve from 0.64462
# Epoch 10/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5899 - val_loss: 0.6480 - val_accuracy: 0.5871
#
# Epoch 00010: val_loss did not improve from 0.64462
# Epoch 11/1000
#  - 1s - loss: 0.6731 - accuracy: 0.5891 - val_loss: 0.6672 - val_accuracy: 0.5865
#
# Epoch 00011: val_loss did not improve from 0.64462
# Epoch 12/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5891 - val_loss: 0.6871 - val_accuracy: 0.5877
#
# Epoch 00012: val_loss did not improve from 0.64462
# Epoch 13/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5902 - val_loss: 0.6698 - val_accuracy: 0.5871
#
# Epoch 00013: val_loss did not improve from 0.64462
# Epoch 14/1000
#  - 1s - loss: 0.6730 - accuracy: 0.5878 - val_loss: 0.6367 - val_accuracy: 0.5868
#
# Epoch 00014: val_loss improved from 0.64462 to 0.63667, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 15/1000
#  - 1s - loss: 0.6712 - accuracy: 0.5896 - val_loss: 0.6467 - val_accuracy: 0.5874
#
# Epoch 00015: val_loss did not improve from 0.63667
# Epoch 16/1000
#  - 1s - loss: 0.6717 - accuracy: 0.5895 - val_loss: 0.6667 - val_accuracy: 0.5874
#
# Epoch 00016: val_loss did not improve from 0.63667
# Epoch 17/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5895 - val_loss: 0.6452 - val_accuracy: 0.5862
#
# Epoch 00017: val_loss did not improve from 0.63667
# Epoch 18/1000
#  - 1s - loss: 0.6729 - accuracy: 0.5886 - val_loss: 0.6788 - val_accuracy: 0.5868
#
# Epoch 00018: val_loss did not improve from 0.63667
# Epoch 19/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5886 - val_loss: 0.6906 - val_accuracy: 0.5871
#
# Epoch 00019: val_loss did not improve from 0.63667
# Epoch 20/1000
#  - 1s - loss: 0.6735 - accuracy: 0.5886 - val_loss: 0.6751 - val_accuracy: 0.5865
#
# Epoch 00020: val_loss did not improve from 0.63667
# Epoch 21/1000
#  - 1s - loss: 0.6717 - accuracy: 0.5902 - val_loss: 0.6439 - val_accuracy: 0.5874
#
# Epoch 00021: val_loss did not improve from 0.63667
# Epoch 22/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5901 - val_loss: 0.6677 - val_accuracy: 0.5874
#
# Epoch 00022: val_loss did not improve from 0.63667
# Epoch 23/1000
#  - 1s - loss: 0.6744 - accuracy: 0.5841 - val_loss: 0.6471 - val_accuracy: 0.5871
#
# Epoch 00023: val_loss did not improve from 0.63667
# Epoch 24/1000
#  - 1s - loss: 0.6704 - accuracy: 0.5918 - val_loss: 0.7468 - val_accuracy: 0.5874
#
# Epoch 00024: val_loss did not improve from 0.63667
# Epoch 25/1000
#  - 1s - loss: 0.6717 - accuracy: 0.5881 - val_loss: 0.6722 - val_accuracy: 0.5868
#
# Epoch 00025: val_loss did not improve from 0.63667
# Epoch 26/1000
#  - 1s - loss: 0.6749 - accuracy: 0.5862 - val_loss: 0.6695 - val_accuracy: 0.5865
#
# Epoch 00026: val_loss did not improve from 0.63667
# Epoch 27/1000
#  - 1s - loss: 0.6699 - accuracy: 0.5923 - val_loss: 0.6677 - val_accuracy: 0.5868
#
# Epoch 00027: val_loss did not improve from 0.63667
# Epoch 28/1000
#  - 1s - loss: 0.6723 - accuracy: 0.5886 - val_loss: 0.6946 - val_accuracy: 0.5865
#
# Epoch 00028: val_loss did not improve from 0.63667
# Epoch 29/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5890 - val_loss: 0.6712 - val_accuracy: 0.5868
#
# Epoch 00029: val_loss did not improve from 0.63667
# Epoch 30/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5896 - val_loss: 0.6728 - val_accuracy: 0.5862
#
# Epoch 00030: val_loss did not improve from 0.63667
# Epoch 31/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5863 - val_loss: 0.6534 - val_accuracy: 0.5862
#
# Epoch 00031: val_loss did not improve from 0.63667
# Epoch 32/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5930 - val_loss: 0.6564 - val_accuracy: 0.5862
#
# Epoch 00032: val_loss did not improve from 0.63667
# Epoch 33/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5885 - val_loss: 0.6513 - val_accuracy: 0.5859
#
# Epoch 00033: val_loss did not improve from 0.63667
# Epoch 34/1000
#  - 1s - loss: 0.6717 - accuracy: 0.5878 - val_loss: 0.6804 - val_accuracy: 0.5857
#
# Epoch 00034: val_loss did not improve from 0.63667
# Epoch 35/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5908 - val_loss: 0.6425 - val_accuracy: 0.5857
#
# Epoch 00035: val_loss did not improve from 0.63667
# Epoch 36/1000
#  - 1s - loss: 0.6723 - accuracy: 0.5893 - val_loss: 0.6648 - val_accuracy: 0.5857
#
# Epoch 00036: val_loss did not improve from 0.63667
# Epoch 37/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5899 - val_loss: 0.6418 - val_accuracy: 0.5857
#
# Epoch 00037: val_loss did not improve from 0.63667
# Epoch 38/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5881 - val_loss: 0.6846 - val_accuracy: 0.5854
#
# Epoch 00038: val_loss did not improve from 0.63667
# Epoch 39/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5899 - val_loss: 0.6482 - val_accuracy: 0.5857
#
# Epoch 00039: val_loss did not improve from 0.63667
# Epoch 40/1000
#  - 1s - loss: 0.6733 - accuracy: 0.5873 - val_loss: 0.6483 - val_accuracy: 0.5854
#
# Epoch 00040: val_loss did not improve from 0.63667
# Epoch 41/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5902 - val_loss: 0.6518 - val_accuracy: 0.5862
#
# Epoch 00041: val_loss did not improve from 0.63667
# Epoch 42/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5906 - val_loss: 0.7044 - val_accuracy: 0.5859
#
# Epoch 00042: val_loss did not improve from 0.63667
# Epoch 43/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5893 - val_loss: 0.6822 - val_accuracy: 0.5859
#
# Epoch 00043: val_loss did not improve from 0.63667
# Epoch 44/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5903 - val_loss: 0.6557 - val_accuracy: 0.5854
#
# Epoch 00044: val_loss did not improve from 0.63667
# Epoch 45/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5879 - val_loss: 0.6705 - val_accuracy: 0.5862
#
# Epoch 00045: val_loss did not improve from 0.63667
# Epoch 46/1000
#  - 1s - loss: 0.6730 - accuracy: 0.5877 - val_loss: 0.6662 - val_accuracy: 0.5859
#
# Epoch 00046: val_loss did not improve from 0.63667
# Epoch 47/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5906 - val_loss: 0.6706 - val_accuracy: 0.5857
#
# Epoch 00047: val_loss did not improve from 0.63667
# Epoch 48/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5895 - val_loss: 0.6675 - val_accuracy: 0.5857
#
# Epoch 00048: val_loss did not improve from 0.63667
# Epoch 49/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5893 - val_loss: 0.6548 - val_accuracy: 0.5859
#
# Epoch 00049: val_loss did not improve from 0.63667
# Epoch 50/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5899 - val_loss: 0.6812 - val_accuracy: 0.5859
#
# Epoch 00050: val_loss did not improve from 0.63667
# Epoch 51/1000
#  - 1s - loss: 0.6722 - accuracy: 0.5886 - val_loss: 0.6605 - val_accuracy: 0.5857
#
# Epoch 00051: val_loss did not improve from 0.63667
# Epoch 52/1000
#  - 1s - loss: 0.6711 - accuracy: 0.5909 - val_loss: 0.7073 - val_accuracy: 0.5857
#
# Epoch 00052: val_loss did not improve from 0.63667
# Epoch 53/1000
#  - 1s - loss: 0.6732 - accuracy: 0.5876 - val_loss: 0.6735 - val_accuracy: 0.5854
#
# Epoch 00053: val_loss did not improve from 0.63667
# Epoch 54/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5893 - val_loss: 0.6793 - val_accuracy: 0.5857
#
# Epoch 00054: val_loss did not improve from 0.63667
# Epoch 55/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5895 - val_loss: 0.6923 - val_accuracy: 0.5857
#
# Epoch 00055: val_loss did not improve from 0.63667
# Epoch 56/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5915 - val_loss: 0.6826 - val_accuracy: 0.5859
#
# Epoch 00056: val_loss did not improve from 0.63667
# Epoch 57/1000
#  - 1s - loss: 0.6722 - accuracy: 0.5865 - val_loss: 0.6667 - val_accuracy: 0.5859
#
# Epoch 00057: val_loss did not improve from 0.63667
# Epoch 58/1000
#  - 1s - loss: 0.6722 - accuracy: 0.5907 - val_loss: 0.6457 - val_accuracy: 0.5859
#
# Epoch 00058: val_loss did not improve from 0.63667
# Epoch 59/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5868 - val_loss: 0.6756 - val_accuracy: 0.5857
#
# Epoch 00059: val_loss did not improve from 0.63667
# Epoch 60/1000
#  - 1s - loss: 0.6722 - accuracy: 0.5903 - val_loss: 0.6741 - val_accuracy: 0.5854
#
# Epoch 00060: val_loss did not improve from 0.63667
# Epoch 61/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5920 - val_loss: 0.6833 - val_accuracy: 0.5854
#
# Epoch 00061: val_loss did not improve from 0.63667
# Epoch 62/1000
#  - 1s - loss: 0.6728 - accuracy: 0.5887 - val_loss: 0.6656 - val_accuracy: 0.5854
#
# Epoch 00062: val_loss did not improve from 0.63667
# Epoch 63/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5865 - val_loss: 0.6858 - val_accuracy: 0.5857
#
# Epoch 00063: val_loss did not improve from 0.63667
# Epoch 64/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5902 - val_loss: 0.6348 - val_accuracy: 0.5859
#
# Epoch 00064: val_loss improved from 0.63667 to 0.63485, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 65/1000
#  - 1s - loss: 0.6735 - accuracy: 0.5874 - val_loss: 0.6839 - val_accuracy: 0.5857
#
# Epoch 00065: val_loss did not improve from 0.63485
# Epoch 66/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5887 - val_loss: 0.6540 - val_accuracy: 0.5859
#
# Epoch 00066: val_loss did not improve from 0.63485
# Epoch 67/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5872 - val_loss: 0.6737 - val_accuracy: 0.5857
#
# Epoch 00067: val_loss did not improve from 0.63485
# Epoch 68/1000
#  - 1s - loss: 0.6731 - accuracy: 0.5897 - val_loss: 0.6912 - val_accuracy: 0.5854
#
# Epoch 00068: val_loss did not improve from 0.63485
# Epoch 69/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5890 - val_loss: 0.6405 - val_accuracy: 0.5857
#
# Epoch 00069: val_loss did not improve from 0.63485
# Epoch 70/1000
#  - 1s - loss: 0.6704 - accuracy: 0.5931 - val_loss: 0.6922 - val_accuracy: 0.5857
#
# Epoch 00070: val_loss did not improve from 0.63485
# Epoch 71/1000
#  - 1s - loss: 0.6737 - accuracy: 0.5854 - val_loss: 0.6862 - val_accuracy: 0.5854
#
# Epoch 00071: val_loss did not improve from 0.63485
# Epoch 72/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5874 - val_loss: 0.6664 - val_accuracy: 0.5859
#
# Epoch 00072: val_loss did not improve from 0.63485
# Epoch 73/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5881 - val_loss: 0.6706 - val_accuracy: 0.5857
#
# Epoch 00073: val_loss did not improve from 0.63485
# Epoch 74/1000
#  - 1s - loss: 0.6728 - accuracy: 0.5888 - val_loss: 0.6912 - val_accuracy: 0.5857
#
# Epoch 00074: val_loss did not improve from 0.63485
# Epoch 75/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5890 - val_loss: 0.6692 - val_accuracy: 0.5859
#
# Epoch 00075: val_loss did not improve from 0.63485
# Epoch 76/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5879 - val_loss: 0.6635 - val_accuracy: 0.5857
#
# Epoch 00076: val_loss did not improve from 0.63485
# Epoch 77/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5907 - val_loss: 0.6592 - val_accuracy: 0.5857
#
# Epoch 00077: val_loss did not improve from 0.63485
# Epoch 78/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5871 - val_loss: 0.6828 - val_accuracy: 0.5857
#
# Epoch 00078: val_loss did not improve from 0.63485
# Epoch 79/1000
#  - 1s - loss: 0.6729 - accuracy: 0.5870 - val_loss: 0.6706 - val_accuracy: 0.5854
#
# Epoch 00079: val_loss did not improve from 0.63485
# Epoch 80/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5890 - val_loss: 0.6690 - val_accuracy: 0.5859
#
# Epoch 00080: val_loss did not improve from 0.63485
# Epoch 81/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5898 - val_loss: 0.6671 - val_accuracy: 0.5859
#
# Epoch 00081: val_loss did not improve from 0.63485
# Epoch 82/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5913 - val_loss: 0.6713 - val_accuracy: 0.5851
#
# Epoch 00082: val_loss did not improve from 0.63485
# Epoch 83/1000
#  - 1s - loss: 0.6735 - accuracy: 0.5862 - val_loss: 0.6805 - val_accuracy: 0.5854
#
# Epoch 00083: val_loss did not improve from 0.63485
# Epoch 84/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5887 - val_loss: 0.6863 - val_accuracy: 0.5857
#
# Epoch 00084: val_loss did not improve from 0.63485
# Epoch 85/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5879 - val_loss: 0.7024 - val_accuracy: 0.5857
#
# Epoch 00085: val_loss did not improve from 0.63485
# Epoch 86/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5911 - val_loss: 0.6696 - val_accuracy: 0.5857
#
# Epoch 00086: val_loss did not improve from 0.63485
# Epoch 87/1000
#  - 1s - loss: 0.6733 - accuracy: 0.5871 - val_loss: 0.6659 - val_accuracy: 0.5857
#
# Epoch 00087: val_loss did not improve from 0.63485
# Epoch 88/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5891 - val_loss: 0.7100 - val_accuracy: 0.5865
#
# Epoch 00088: val_loss did not improve from 0.63485
# Epoch 89/1000
#  - 1s - loss: 0.6728 - accuracy: 0.5891 - val_loss: 0.6654 - val_accuracy: 0.5857
#
# Epoch 00089: val_loss did not improve from 0.63485
# Epoch 90/1000
#  - 1s - loss: 0.6717 - accuracy: 0.5881 - val_loss: 0.6489 - val_accuracy: 0.5857
#
# Epoch 00090: val_loss did not improve from 0.63485
# Epoch 91/1000
#  - 1s - loss: 0.6729 - accuracy: 0.5868 - val_loss: 0.6711 - val_accuracy: 0.5851
#
# Epoch 00091: val_loss did not improve from 0.63485
# Epoch 92/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5927 - val_loss: 0.6285 - val_accuracy: 0.5845
#
# Epoch 00092: val_loss improved from 0.63485 to 0.62854, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 93/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5868 - val_loss: 0.6733 - val_accuracy: 0.5865
#
# Epoch 00093: val_loss did not improve from 0.62854
# Epoch 94/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5897 - val_loss: 0.6695 - val_accuracy: 0.5859
#
# Epoch 00094: val_loss did not improve from 0.62854
# Epoch 95/1000
#  - 1s - loss: 0.6734 - accuracy: 0.5852 - val_loss: 0.6299 - val_accuracy: 0.5854
#
# Epoch 00095: val_loss did not improve from 0.62854
# Epoch 96/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5919 - val_loss: 0.6667 - val_accuracy: 0.5854
#
# Epoch 00096: val_loss did not improve from 0.62854
# Epoch 97/1000
#  - 1s - loss: 0.6704 - accuracy: 0.5902 - val_loss: 0.6749 - val_accuracy: 0.5865
#
# Epoch 00097: val_loss did not improve from 0.62854
# Epoch 98/1000
#  - 1s - loss: 0.6753 - accuracy: 0.5852 - val_loss: 0.6716 - val_accuracy: 0.5859
#
# Epoch 00098: val_loss did not improve from 0.62854
# Epoch 99/1000
#  - 1s - loss: 0.6707 - accuracy: 0.5916 - val_loss: 0.6744 - val_accuracy: 0.5862
#
# Epoch 00099: val_loss did not improve from 0.62854
# Epoch 100/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5899 - val_loss: 0.6774 - val_accuracy: 0.5865
#
# Epoch 00100: val_loss did not improve from 0.62854
# Epoch 101/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5870 - val_loss: 0.6482 - val_accuracy: 0.5862
#
# Epoch 00101: val_loss did not improve from 0.62854
# Epoch 102/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5909 - val_loss: 0.6682 - val_accuracy: 0.5862
#
# Epoch 00102: val_loss did not improve from 0.62854
# Epoch 103/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5899 - val_loss: 0.6696 - val_accuracy: 0.5859
#
# Epoch 00103: val_loss did not improve from 0.62854
# Epoch 104/1000
#  - 1s - loss: 0.6717 - accuracy: 0.5887 - val_loss: 0.6602 - val_accuracy: 0.5865
#
# Epoch 00104: val_loss did not improve from 0.62854
# Epoch 105/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5890 - val_loss: 0.6862 - val_accuracy: 0.5865
#
# Epoch 00105: val_loss did not improve from 0.62854
# Epoch 106/1000
#  - 1s - loss: 0.6710 - accuracy: 0.5909 - val_loss: 0.6761 - val_accuracy: 0.5865
#
# Epoch 00106: val_loss did not improve from 0.62854
# Epoch 107/1000
#  - 1s - loss: 0.6734 - accuracy: 0.5885 - val_loss: 0.6892 - val_accuracy: 0.5862
#
# Epoch 00107: val_loss did not improve from 0.62854
# Epoch 108/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5885 - val_loss: 0.6721 - val_accuracy: 0.5868
#
# Epoch 00108: val_loss did not improve from 0.62854
# Epoch 109/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5913 - val_loss: 0.6603 - val_accuracy: 0.5868
#
# Epoch 00109: val_loss did not improve from 0.62854
# Epoch 110/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5876 - val_loss: 0.6499 - val_accuracy: 0.5851
#
# Epoch 00110: val_loss did not improve from 0.62854
# Epoch 111/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5883 - val_loss: 0.6647 - val_accuracy: 0.5865
#
# Epoch 00111: val_loss did not improve from 0.62854
# Epoch 112/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5893 - val_loss: 0.6695 - val_accuracy: 0.5857
#
# Epoch 00112: val_loss did not improve from 0.62854
# Epoch 113/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5865 - val_loss: 0.6419 - val_accuracy: 0.5862
#
# Epoch 00113: val_loss did not improve from 0.62854
# Epoch 114/1000
#  - 1s - loss: 0.6712 - accuracy: 0.5916 - val_loss: 0.6914 - val_accuracy: 0.5862
#
# Epoch 00114: val_loss did not improve from 0.62854
# Epoch 115/1000
#  - 1s - loss: 0.6732 - accuracy: 0.5876 - val_loss: 0.6377 - val_accuracy: 0.5862
#
# Epoch 00115: val_loss did not improve from 0.62854
# Epoch 116/1000
#  - 1s - loss: 0.6712 - accuracy: 0.5908 - val_loss: 0.6634 - val_accuracy: 0.5859
#
# Epoch 00116: val_loss did not improve from 0.62854
# Epoch 117/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5890 - val_loss: 0.6680 - val_accuracy: 0.5865
#
# Epoch 00117: val_loss did not improve from 0.62854
# Epoch 118/1000
#  - 1s - loss: 0.6731 - accuracy: 0.5884 - val_loss: 0.6631 - val_accuracy: 0.5865
#
# Epoch 00118: val_loss did not improve from 0.62854
# Epoch 119/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5911 - val_loss: 0.6581 - val_accuracy: 0.5862
#
# Epoch 00119: val_loss did not improve from 0.62854
# Epoch 120/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5877 - val_loss: 0.6445 - val_accuracy: 0.5865
#
# Epoch 00120: val_loss did not improve from 0.62854
# Epoch 121/1000
#  - 1s - loss: 0.6710 - accuracy: 0.5910 - val_loss: 0.6712 - val_accuracy: 0.5868
#
# Epoch 00121: val_loss did not improve from 0.62854
# Epoch 122/1000
#  - 1s - loss: 0.6748 - accuracy: 0.5836 - val_loss: 0.6801 - val_accuracy: 0.5859
#
# Epoch 00122: val_loss did not improve from 0.62854
# Epoch 123/1000
#  - 1s - loss: 0.6704 - accuracy: 0.5927 - val_loss: 0.6398 - val_accuracy: 0.5868
#
# Epoch 00123: val_loss did not improve from 0.62854
# Epoch 124/1000
#  - 1s - loss: 0.6722 - accuracy: 0.5876 - val_loss: 0.6592 - val_accuracy: 0.5862
#
# Epoch 00124: val_loss did not improve from 0.62854
# Epoch 125/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5893 - val_loss: 0.6879 - val_accuracy: 0.5862
#
# Epoch 00125: val_loss did not improve from 0.62854
# Epoch 126/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5897 - val_loss: 0.6529 - val_accuracy: 0.5862
#
# Epoch 00126: val_loss did not improve from 0.62854
# Epoch 127/1000
#  - 1s - loss: 0.6730 - accuracy: 0.5866 - val_loss: 0.6712 - val_accuracy: 0.5857
#
# Epoch 00127: val_loss did not improve from 0.62854
# Epoch 128/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5896 - val_loss: 0.6875 - val_accuracy: 0.5862
#
# Epoch 00128: val_loss did not improve from 0.62854
# Epoch 129/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5901 - val_loss: 0.6721 - val_accuracy: 0.5862
#
# Epoch 00129: val_loss did not improve from 0.62854
# Epoch 130/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5907 - val_loss: 0.6782 - val_accuracy: 0.5862
#
# Epoch 00130: val_loss did not improve from 0.62854
# Epoch 131/1000
#  - 1s - loss: 0.6711 - accuracy: 0.5878 - val_loss: 0.6981 - val_accuracy: 0.5868
#
# Epoch 00131: val_loss did not improve from 0.62854
# Epoch 132/1000
#  - 1s - loss: 0.6734 - accuracy: 0.5875 - val_loss: 0.6475 - val_accuracy: 0.5865
#
# Epoch 00132: val_loss did not improve from 0.62854
# Epoch 133/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5901 - val_loss: 0.6748 - val_accuracy: 0.5868
#
# Epoch 00133: val_loss did not improve from 0.62854
# Epoch 134/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5884 - val_loss: 0.6791 - val_accuracy: 0.5862
#
# Epoch 00134: val_loss did not improve from 0.62854
# Epoch 135/1000
#  - 1s - loss: 0.6732 - accuracy: 0.5875 - val_loss: 0.6605 - val_accuracy: 0.5868
#
# Epoch 00135: val_loss did not improve from 0.62854
# Epoch 136/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5879 - val_loss: 0.6537 - val_accuracy: 0.5857
#
# Epoch 00136: val_loss did not improve from 0.62854
# Epoch 137/1000
#  - 1s - loss: 0.6723 - accuracy: 0.5889 - val_loss: 0.6941 - val_accuracy: 0.5862
#
# Epoch 00137: val_loss did not improve from 0.62854
# Epoch 138/1000
#  - 1s - loss: 0.6723 - accuracy: 0.5883 - val_loss: 0.6827 - val_accuracy: 0.5857
#
# Epoch 00138: val_loss did not improve from 0.62854
# Epoch 139/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5889 - val_loss: 0.6594 - val_accuracy: 0.5862
#
# Epoch 00139: val_loss did not improve from 0.62854
# Epoch 140/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5890 - val_loss: 0.6747 - val_accuracy: 0.5857
#
# Epoch 00140: val_loss did not improve from 0.62854
# Epoch 141/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5870 - val_loss: 0.6491 - val_accuracy: 0.5857
#
# Epoch 00141: val_loss did not improve from 0.62854
# Epoch 142/1000
#  - 1s - loss: 0.6722 - accuracy: 0.5872 - val_loss: 0.6699 - val_accuracy: 0.5862
#
# Epoch 00142: val_loss did not improve from 0.62854
# test_result.shape : (1, 2)
# total_result.shape : (1957, 1, 2)
# new_x_train.shape : (10330, 90, 2, 3)
# new_x_test.shape : (1, 90, 2, 3)
# new_x_val.shape : (3444, 90, 2, 3)
# new_y_train.shape : (10330, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (3444, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([5767, 4563])) [1.26386149 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1960, 1484])) [1.32075472 1.        ]
# class_weights : {0: 0.8956129703485348, 1: 1.1319307473153628}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (10330, 2)
# new_y_val_ohe.shape : (3444, 2)
# new_y_test_ohe.shape : (1, 2)
# ----------------------- model loaded ! -----------------------
# Epoch 1/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5850 - val_loss: 0.6764 - val_accuracy: 0.5990
#
# Epoch 00001: val_loss improved from inf to 0.67638, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 2/1000
#  - 1s - loss: 0.6744 - accuracy: 0.5821 - val_loss: 0.6714 - val_accuracy: 0.5999
#
# Epoch 00002: val_loss improved from 0.67638 to 0.67136, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 3/1000
#  - 1s - loss: 0.6710 - accuracy: 0.5850 - val_loss: 0.6707 - val_accuracy: 0.5999
#
# Epoch 00003: val_loss improved from 0.67136 to 0.67070, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 4/1000
#  - 1s - loss: 0.6722 - accuracy: 0.5862 - val_loss: 0.6686 - val_accuracy: 0.5999
#
# Epoch 00004: val_loss improved from 0.67070 to 0.66862, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 5/1000
#  - 1s - loss: 0.6717 - accuracy: 0.5836 - val_loss: 0.6540 - val_accuracy: 0.6002
#
# Epoch 00005: val_loss improved from 0.66862 to 0.65401, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 6/1000
#  - 1s - loss: 0.6730 - accuracy: 0.5829 - val_loss: 0.6540 - val_accuracy: 0.6002
#
# Epoch 00006: val_loss improved from 0.65401 to 0.65395, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 7/1000
#  - 1s - loss: 0.6730 - accuracy: 0.5820 - val_loss: 0.6709 - val_accuracy: 0.6005
#
# Epoch 00007: val_loss did not improve from 0.65395
# Epoch 8/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5857 - val_loss: 0.6511 - val_accuracy: 0.6002
#
# Epoch 00008: val_loss improved from 0.65395 to 0.65108, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 9/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5852 - val_loss: 0.6775 - val_accuracy: 0.6002
#
# Epoch 00009: val_loss did not improve from 0.65108
# Epoch 10/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5825 - val_loss: 0.6793 - val_accuracy: 0.6002
#
# Epoch 00010: val_loss did not improve from 0.65108
# Epoch 11/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5862 - val_loss: 0.6931 - val_accuracy: 0.6002
#
# Epoch 00011: val_loss did not improve from 0.65108
# Epoch 12/1000
#  - 1s - loss: 0.6723 - accuracy: 0.5834 - val_loss: 0.6624 - val_accuracy: 0.6005
#
# Epoch 00012: val_loss did not improve from 0.65108
# Epoch 13/1000
#  - 1s - loss: 0.6733 - accuracy: 0.5831 - val_loss: 0.6655 - val_accuracy: 0.6002
#
# Epoch 00013: val_loss did not improve from 0.65108
# Epoch 14/1000
#  - 1s - loss: 0.6709 - accuracy: 0.5841 - val_loss: 0.6537 - val_accuracy: 0.6016
#
# Epoch 00014: val_loss did not improve from 0.65108
# Epoch 15/1000
#  - 1s - loss: 0.6730 - accuracy: 0.5833 - val_loss: 0.6798 - val_accuracy: 0.6005
#
# Epoch 00015: val_loss did not improve from 0.65108
# Epoch 16/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5834 - val_loss: 0.6849 - val_accuracy: 0.6013
#
# Epoch 00016: val_loss did not improve from 0.65108
# Epoch 17/1000
#  - 1s - loss: 0.6737 - accuracy: 0.5823 - val_loss: 0.6785 - val_accuracy: 0.6002
#
# Epoch 00017: val_loss did not improve from 0.65108
# Epoch 18/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5843 - val_loss: 0.6507 - val_accuracy: 0.6013
#
# Epoch 00018: val_loss improved from 0.65108 to 0.65066, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 19/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5858 - val_loss: 0.6921 - val_accuracy: 0.6013
#
# Epoch 00019: val_loss did not improve from 0.65066
# Epoch 20/1000
#  - 1s - loss: 0.6742 - accuracy: 0.5798 - val_loss: 0.6826 - val_accuracy: 0.6008
#
# Epoch 00020: val_loss did not improve from 0.65066
# Epoch 21/1000
#  - 1s - loss: 0.6710 - accuracy: 0.5848 - val_loss: 0.6879 - val_accuracy: 0.6008
#
# Epoch 00021: val_loss did not improve from 0.65066
# Epoch 22/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5830 - val_loss: 0.6464 - val_accuracy: 0.6005
#
# Epoch 00022: val_loss improved from 0.65066 to 0.64640, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 23/1000
#  - 1s - loss: 0.6712 - accuracy: 0.5855 - val_loss: 0.6936 - val_accuracy: 0.6010
#
# Epoch 00023: val_loss did not improve from 0.64640
# Epoch 24/1000
#  - 1s - loss: 0.6732 - accuracy: 0.5823 - val_loss: 0.6883 - val_accuracy: 0.6008
#
# Epoch 00024: val_loss did not improve from 0.64640
# ...
# Epoch 5/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5889 - val_loss: 0.7309 - val_accuracy: 0.5944
#
# Epoch 00005: val_loss did not improve from 0.64998
# Epoch 6/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5882 - val_loss: 0.7015 - val_accuracy: 0.5947
#
# Epoch 00006: val_loss did not improve from 0.64998
# Epoch 7/1000
#  - 1s - loss: 0.6728 - accuracy: 0.5854 - val_loss: 0.6616 - val_accuracy: 0.5944
#
# Epoch 00007: val_loss did not improve from 0.64998
# Epoch 8/1000
#  - 1s - loss: 0.6706 - accuracy: 0.5902 - val_loss: 0.7034 - val_accuracy: 0.5949
#
# Epoch 00008: val_loss did not improve from 0.64998
# Epoch 9/1000
#  - 1s - loss: 0.6733 - accuracy: 0.5872 - val_loss: 0.6477 - val_accuracy: 0.5947
#
# Epoch 00009: val_loss improved from 0.64998 to 0.64770, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 10/1000
#  - 1s - loss: 0.6707 - accuracy: 0.5922 - val_loss: 0.6811 - val_accuracy: 0.5944
#
# Epoch 00010: val_loss did not improve from 0.64770
# Epoch 11/1000
#  - 1s - loss: 0.6739 - accuracy: 0.5812 - val_loss: 0.6762 - val_accuracy: 0.5949
#
# Epoch 00011: val_loss did not improve from 0.64770
# Epoch 12/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5896 - val_loss: 0.6580 - val_accuracy: 0.5947
#
# Epoch 00012: val_loss did not improve from 0.64770
# Epoch 13/1000
#  - 1s - loss: 0.6732 - accuracy: 0.5824 - val_loss: 0.6718 - val_accuracy: 0.5949
#
# Epoch 00013: val_loss did not improve from 0.64770
# Epoch 14/1000
#  - 1s - loss: 0.6711 - accuracy: 0.5939 - val_loss: 0.6586 - val_accuracy: 0.5949
#
# Epoch 00014: val_loss did not improve from 0.64770
# Epoch 15/1000
#  - 1s - loss: 0.6723 - accuracy: 0.5863 - val_loss: 0.6418 - val_accuracy: 0.5949
#
# Epoch 00015: val_loss improved from 0.64770 to 0.64176, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 16/1000
#  - 1s - loss: 0.6732 - accuracy: 0.5852 - val_loss: 0.6418 - val_accuracy: 0.5949
#
# Epoch 00016: val_loss did not improve from 0.64176
# Epoch 17/1000
#  - 1s - loss: 0.6706 - accuracy: 0.5922 - val_loss: 0.6678 - val_accuracy: 0.5947
#
# Epoch 00017: val_loss did not improve from 0.64176
# Epoch 18/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5855 - val_loss: 0.6487 - val_accuracy: 0.5949
#
# Epoch 00018: val_loss did not improve from 0.64176
# Epoch 19/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5874 - val_loss: 0.6781 - val_accuracy: 0.5952
#
# Epoch 00019: val_loss did not improve from 0.64176
# Epoch 20/1000
#  - 1s - loss: 0.6713 - accuracy: 0.5919 - val_loss: 0.6827 - val_accuracy: 0.5947
#
# Epoch 00020: val_loss did not improve from 0.64176
# Epoch 21/1000
#  - 1s - loss: 0.6735 - accuracy: 0.5830 - val_loss: 0.6360 - val_accuracy: 0.5949
#
# Epoch 00021: val_loss improved from 0.64176 to 0.63601, saving model to /content/drive/My Drive/Colab Notebooks/300/ckpt/classifier_45_cnn_close_updown_timesplit_norot_NEOUSDT.h5
# Epoch 22/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5867 - val_loss: 0.6838 - val_accuracy: 0.5952
#
# Epoch 00022: val_loss did not improve from 0.63601
# Epoch 23/1000
#  - 1s - loss: 0.6728 - accuracy: 0.5889 - val_loss: 0.6792 - val_accuracy: 0.5952
#
# Epoch 00023: val_loss did not improve from 0.63601
# Epoch 24/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5868 - val_loss: 0.6592 - val_accuracy: 0.5952
#
# Epoch 00024: val_loss did not improve from 0.63601
# Epoch 25/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5894 - val_loss: 0.6544 - val_accuracy: 0.5952
#
# Epoch 00025: val_loss did not improve from 0.63601
# Epoch 26/1000
#  - 1s - loss: 0.6722 - accuracy: 0.5831 - val_loss: 0.6819 - val_accuracy: 0.5952
#
# Epoch 00026: val_loss did not improve from 0.63601
# Epoch 27/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5900 - val_loss: 0.6758 - val_accuracy: 0.5955
#
# Epoch 00027: val_loss did not improve from 0.63601
# Epoch 28/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5844 - val_loss: 0.6457 - val_accuracy: 0.5955
#
# Epoch 00028: val_loss did not improve from 0.63601
# Epoch 29/1000
#  - 1s - loss: 0.6731 - accuracy: 0.5890 - val_loss: 0.6475 - val_accuracy: 0.5944
#
# Epoch 00029: val_loss did not improve from 0.63601
# Epoch 30/1000
#  - 1s - loss: 0.6706 - accuracy: 0.5879 - val_loss: 0.6709 - val_accuracy: 0.5958
#
# Epoch 00030: val_loss did not improve from 0.63601
# Epoch 31/1000
#  - 1s - loss: 0.6739 - accuracy: 0.5865 - val_loss: 0.6924 - val_accuracy: 0.5955
#
# Epoch 00031: val_loss did not improve from 0.63601
# Epoch 32/1000
#  - 1s - loss: 0.6701 - accuracy: 0.5877 - val_loss: 0.6518 - val_accuracy: 0.5955
#
# Epoch 00032: val_loss did not improve from 0.63601
# Epoch 33/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5871 - val_loss: 0.6677 - val_accuracy: 0.5958
#
# Epoch 00033: val_loss did not improve from 0.63601
# Epoch 34/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5878 - val_loss: 0.6389 - val_accuracy: 0.5958
#
# Epoch 00034: val_loss did not improve from 0.63601
# Epoch 35/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5860 - val_loss: 0.6555 - val_accuracy: 0.5958
#
# Epoch 00035: val_loss did not improve from 0.63601
# Epoch 36/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5869 - val_loss: 0.6932 - val_accuracy: 0.5958
#
# Epoch 00036: val_loss did not improve from 0.63601
# Epoch 37/1000
#  - 1s - loss: 0.6738 - accuracy: 0.5850 - val_loss: 0.6750 - val_accuracy: 0.5952
#
# Epoch 00037: val_loss did not improve from 0.63601
# Epoch 38/1000
#  - 1s - loss: 0.6696 - accuracy: 0.5902 - val_loss: 0.6746 - val_accuracy: 0.5958
#
# Epoch 00038: val_loss did not improve from 0.63601
# Epoch 39/1000
#  - 1s - loss: 0.6732 - accuracy: 0.5858 - val_loss: 0.6612 - val_accuracy: 0.5952
#
# Epoch 00039: val_loss did not improve from 0.63601
# Epoch 40/1000
#  - 1s - loss: 0.6722 - accuracy: 0.5838 - val_loss: 0.6470 - val_accuracy: 0.5955
#
# Epoch 00040: val_loss did not improve from 0.63601
# Epoch 41/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5914 - val_loss: 0.6802 - val_accuracy: 0.5958
#
# Epoch 00041: val_loss did not improve from 0.63601
# Epoch 42/1000
#  - 1s - loss: 0.6731 - accuracy: 0.5858 - val_loss: 0.7032 - val_accuracy: 0.5952
#
# Epoch 00042: val_loss did not improve from 0.63601
# Epoch 43/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5866 - val_loss: 0.6483 - val_accuracy: 0.5952
#
# Epoch 00043: val_loss did not improve from 0.63601
# Epoch 44/1000
#  - 1s - loss: 0.6728 - accuracy: 0.5860 - val_loss: 0.6907 - val_accuracy: 0.5949
#
# Epoch 00044: val_loss did not improve from 0.63601
# Epoch 45/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5885 - val_loss: 0.6667 - val_accuracy: 0.5949
#
# Epoch 00045: val_loss did not improve from 0.63601
# Epoch 46/1000
#  - 1s - loss: 0.6716 - accuracy: 0.5876 - val_loss: 0.6723 - val_accuracy: 0.5949
#
# Epoch 00046: val_loss did not improve from 0.63601
# Epoch 47/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5870 - val_loss: 0.6371 - val_accuracy: 0.5949
#
# Epoch 00047: val_loss did not improve from 0.63601
# Epoch 48/1000
#  - 1s - loss: 0.6732 - accuracy: 0.5859 - val_loss: 0.6686 - val_accuracy: 0.5949
#
# Epoch 00048: val_loss did not improve from 0.63601
# Epoch 49/1000
#  - 1s - loss: 0.6710 - accuracy: 0.5876 - val_loss: 0.6697 - val_accuracy: 0.5947
#
# Epoch 00049: val_loss did not improve from 0.63601
# Epoch 50/1000
#  - 1s - loss: 0.6734 - accuracy: 0.5866 - val_loss: 0.6491 - val_accuracy: 0.5949
#
# Epoch 00050: val_loss did not improve from 0.63601
# Epoch 51/1000
#  - 1s - loss: 0.6719 - accuracy: 0.5860 - val_loss: 0.6845 - val_accuracy: 0.5947
#
# Epoch 00051: val_loss did not improve from 0.63601
# Epoch 52/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5847 - val_loss: 0.6811 - val_accuracy: 0.5949
#
# Epoch 00052: val_loss did not improve from 0.63601
# Epoch 53/1000
#  - 1s - loss: 0.6692 - accuracy: 0.5926 - val_loss: 0.6946 - val_accuracy: 0.5949
#
# Epoch 00053: val_loss did not improve from 0.63601
# Epoch 54/1000
#  - 1s - loss: 0.6747 - accuracy: 0.5823 - val_loss: 0.6636 - val_accuracy: 0.5949
#
# Epoch 00054: val_loss did not improve from 0.63601
# Epoch 55/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5847 - val_loss: 0.6868 - val_accuracy: 0.5952
#
# Epoch 00055: val_loss did not improve from 0.63601
# Epoch 56/1000
#  - 1s - loss: 0.6721 - accuracy: 0.5874 - val_loss: 0.6885 - val_accuracy: 0.5947
#
# Epoch 00056: val_loss did not improve from 0.63601
# Epoch 57/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5863 - val_loss: 0.6749 - val_accuracy: 0.5952
#
# Epoch 00057: val_loss did not improve from 0.63601
# Epoch 58/1000
#  - 1s - loss: 0.6727 - accuracy: 0.5856 - val_loss: 0.7023 - val_accuracy: 0.5952
#
# Epoch 00058: val_loss did not improve from 0.63601
# Epoch 59/1000
#  - 1s - loss: 0.6714 - accuracy: 0.5868 - val_loss: 0.6617 - val_accuracy: 0.5949
#
# Epoch 00059: val_loss did not improve from 0.63601
# Epoch 60/1000
#  - 1s - loss: 0.6725 - accuracy: 0.5857 - val_loss: 0.6476 - val_accuracy: 0.5949
#
# Epoch 00060: val_loss did not improve from 0.63601
# Epoch 61/1000
#  - 1s - loss: 0.6720 - accuracy: 0.5873 - val_loss: 0.6513 - val_accuracy: 0.5947
#
# Epoch 00061: val_loss did not improve from 0.63601
# Epoch 62/1000
#  - 1s - loss: 0.6715 - accuracy: 0.5858 - val_loss: 0.6865 - val_accuracy: 0.5949
#
# Epoch 00062: val_loss did not improve from 0.63601
# Epoch 63/1000
#  - 1s - loss: 0.6728 - accuracy: 0.5843 - val_loss: 0.6755 - val_accuracy: 0.5952
#
# Epoch 00063: val_loss did not improve from 0.63601
# Epoch 64/1000
#  - 1s - loss: 0.6710 - accuracy: 0.5891 - val_loss: 0.6803 - val_accuracy: 0.5947
#
# Epoch 00064: val_loss did not improve from 0.63601
# Epoch 65/1000
#  - 1s - loss: 0.6731 - accuracy: 0.5817 - val_loss: 0.6646 - val_accuracy: 0.5947
#
# Epoch 00065: val_loss did not improve from 0.63601
# Epoch 66/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5864 - val_loss: 0.6752 - val_accuracy: 0.5949
#
# Epoch 00066: val_loss did not improve from 0.63601
# Epoch 67/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5842 - val_loss: 0.6638 - val_accuracy: 0.5947
#
# Epoch 00067: val_loss did not improve from 0.63601
# Epoch 68/1000
#  - 1s - loss: 0.6717 - accuracy: 0.5883 - val_loss: 0.7023 - val_accuracy: 0.5949
#
# Epoch 00068: val_loss did not improve from 0.63601
# Epoch 69/1000
#  - 1s - loss: 0.6724 - accuracy: 0.5849 - val_loss: 0.6592 - val_accuracy: 0.5947
#
# Epoch 00069: val_loss did not improve from 0.63601
# Epoch 70/1000
#  - 1s - loss: 0.6718 - accuracy: 0.5853 - val_loss: 0.6712 - val_accuracy: 0.5947
#
# Epoch 00070: val_loss did not improve from 0.63601
# Epoch 71/1000
#  - 1s - loss: 0.6726 - accuracy: 0.5879 - val_loss: 0.6555 - val_accuracy: 0.5947
#
# Epoch 00071: val_loss did not improve from 0.63601
# test_result.shape : (1, 2)
# total_result.shape : (1965, 1, 2)
# new_x_train.shape : (10330, 90, 2, 3)
# new_x_test.shape : (1, 90, 2, 3)
# new_x_val.shape : (3444, 90, 2, 3)
# new_y_train.shape : (10330, 1)
# new_y_test.shape : (1, 1)
# new_y_val.shape : (3444, 1)
# np.unique(y_train, return_counts=True : (array([0, 1]), array([5808, 4522])) [1.28438744 1.        ]
# np.unique(new_y_val, return_counts=True : (array([0, 1]), array([1918, 1526])) [1.25688073 1.        ]
# class_weights : {0: 0.8892906336088154, 1: 1.1421937195931005}
# np.isnan(np.sum(x_train)) : False
# np.isnan(np.sum(new_x_val)) : False
# np.isnan(np.sum(new_x_test)) : False
# np.isnan(np.sum(new_y_train)) : False
# np.isnan(np.sum(new_y_val)) : False
# np.isnan(np.sum(new_y_test)) : False
# new_y_train_ohe.shape : (10330, 2)
# new_y_val_ohe.shape : (3444, 2)
# new_y_test_ohe.shape : (1, 2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b134033ffc53> in <module>()
#     108
#     109     try:
# --> 110       model = keras.models.load_model(ckpt_path + model_name)
#     111       print("----------------------- model loaded ! -----------------------")
#     112
#
# /tensorflow-1.15.2/python3.7/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# /tensorflow-1.15.2/python3.7/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#     586         def load_function(h5file):
#
# /tensorflow-1.15.2/python3.7/keras/engine/saving.py in _deserialize_model(h5dict, custom_objects, compile)
#     334                              ' elements.')
#     335         weight_value_tuples += zip(symbolic_weights, weight_values)
# --> 336     K.batch_set_value(weight_value_tuples)
#     337
#     338     if compile:
#
# /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py in batch_set_value(tuples)
#    2958             `value` should be a Numpy array.
#    2959     """
# -> 2960     tf_keras_backend.batch_set_value(tuples)
#    2961
#    2962
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in batch_set_value(tuples)
#    3257           assign_ops.append(assign_op)
#    3258           feed_dict[assign_placeholder] = value
# -> 3259         get_session().run(assign_ops, feed_dict=feed_dict)
#    3260
#    3261
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in get_session(op_input_list)
#     484   if not _MANUAL_VAR_INIT:
#     485     with session.graph.as_default():
# --> 486       _initialize_variables(session)
#     487   return session
#     488
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in _initialize_variables(session)
#     901     # marked as initialized.
#     902     is_initialized = session.run(
# --> 903         [variables_module.is_variable_initialized(v) for v in candidate_vars])
#     904     uninitialized_vars = []
#     905     for flag, v in zip(is_initialized, candidate_vars):
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1346     def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1347       # Ensure any changes to the graph are reflected in the runtime.
# -> 1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#    1350                                       target_list, run_metadata)
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py in _extend_graph(self)
#    1386   def _extend_graph(self):
#    1387     with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1388       tf_session.ExtendSession(self._session)
#    1389
#    1390   # The threshold to run garbage collection to delete dead tensors.
#
# KeyboardInterrupt:

# %% [markdown]
# ### check pr-rc curve

# %%
total_result = np.array(total_result).reshape(-1, 2)
# y_score = total_result[:, [0]]
y_score = total_result[:, [1]]
print('y_test[:5] :', y_test.reshape(-1,)[:5])
# print('np.unique(y_test) :', np.unique(y_test, return_counts=True))
print('y_score[:5] :', y_score[:5])
# print('np.unique(y_score) :', np.unique(y_score, return_counts=True))

print('y_test.shape :', y_test.shape)
print('y_score.shape :', y_score.shape)

print('len(y_test) :', len(y_test))

#     precision recall curve   #
precision, recall, threshold = precision_recall_curve(y_test[:len(y_score)], y_score)
precision, recall = precision[:-1], recall[:-1]

plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
plt.show()
# print(y_pred)


# threshold = [0.70]
# print('threshold :', threshold)
# break

acc_pr_bythr = []
new_thresh = []

for thresh in threshold:
  
  # if thresh < 0.5:
  #     continue

  y_pred = np.where(y_score[:, -1] > thresh, 1, 0)
  # print('y_pred.shape :', y_pred.shape)
  # print('y_pred :', y_pred)

  #     compare precision     #

  # print('precision :', precision_score(y_test, y_pred))
  # print('recall :', recall_score(y_test, y_pred))
  # print()

  # print('np.isnan(np.sum(x_test)) :', np.isnan(np.sum(x_test)))
  # print('np.isnan(np.sum(y_test)) :', np.isnan(np.sum(y_test)))

  # # plot_confusion_matrix(best_model, x_test, y_test, normalize=None)
  # # plt.show()  
  # print()

  #     check win-ratio improvement     #
  cmat = confusion_matrix(y_test[:len(y_score)], y_pred)
  # print(cmat)
  # print(np.sum(cmat, axis=1))

  test_size = len(y_test[:len(y_score)])
  test_pr_list = pr_test[:len(y_score)]

  # short_pr_list = np.where(test_pr_list != 1, ((1 / ((test_pr_list - 1) / lvrg + 1 + fee)) - 1 - fee) * lvrg + 1, test_pr_list)
  # test_pr_list = short_pr_list
  # print('origin ac_pr :', np.cumprod(test_pr_list)[-1])

  org_wr = np.sum(cmat, axis=1)[-1] / sum(np.sum(cmat, axis=1))
  ml_wr = cmat[1][1] / np.sum(cmat, axis=0)[-1]
  # print('win ratio improvement %.2f --> %.2f' % (org_wr, ml_wr))

  # print('pr_test.shape :', pr_test.shape)

  # print(y_pred)
  # print(test_pr_list)
  pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
  pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
  pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
  # print('pred_pr_list.shape :', pred_pr_list.shape)

  # if np.cumprod(test_pr_list)[-1] < np.cumprod(pred_pr_list)[-1]:
  #   print('accum_pr increased ! : %.3f --> %.3f' % (np.cumprod(test_pr_list)[-1], np.cumprod(pred_pr_list)[-1]))
  #   print('thresh :', thresh)
    
  if len(threshold) == 1:
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.plot(np.cumprod(test_pr_list))
    plt.title('%.3f' % (np.cumprod(test_pr_list)[-1]))
  # plt.show()

    plt.subplot(122)
    plt.plot(np.cumprod(pred_pr_list))
    plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
    # plt.axvline(len(org_pr_test), linestyle='--', color='r')
    plt.show()


  acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
  new_thresh.append(thresh)


print('acc_pr_bythr :', acc_pr_bythr)

plt.figure(figsize=(10, 5))
plt.subplot(121)
plt.plot(threshold, precision, label='precision')
plt.plot(threshold, recall, label='recall')
plt.legend()
plt.title('precision recall')
# plt.show()
plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.axvline(new_thresh[np.argmax(acc_pr_bythr)])
plt.title(symbol_name + '\n' + "%s" % new_thresh[np.argmax(acc_pr_bythr)])
plt.show()
# Out:
# y_test[:5] : [0 1 0 1 1]
# y_score[:5] : [[0.43051797]
#  [0.41643232]
#  [0.35523826]
#  [0.4515546 ]
#  [0.511365  ]]
# y_test.shape : (3444, 1)
# y_score.shape : (1965, 1)
# len(y_test) : 3444
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:68: RuntimeWarning: invalid value encountered in long_scalars
# acc_pr_bythr : [3.6587414e-06, 3.7349632e-06, 3.943503e-06, 4.292332e-06, 4.3789155e-06, 4.724926e-06, 4.876955e-06, 5.0369554e-06, 4.9987902e-06, 4.6247205e-06, 4.765643e-06, 4.814942e-06, 4.649295e-06, 4.8730462e-06, 5.1427305e-06, 4.9730315e-06, 4.8434304e-06, 5.0488284e-06, 5.3063904e-06, 5.306886e-06, 5.2068435e-06, 5.330145e-06, 5.2556916e-06, 5.62261e-06, 5.5485066e-06, 5.701281e-06, 5.9413233e-06, 6.1387013e-06, 6.157177e-06, 6.367181e-06, 6.358075e-06, 6.248271e-06, 6.368195e-06, 6.2181625e-06, 6.3191806e-06, 6.2084096e-06, 6.2664676e-06, 6.172178e-06, 6.160561e-06, 6.145926e-06, 6.2297436e-06, 6.394938e-06, 6.3359385e-06, 6.5693716e-06, 6.3750917e-06, 6.1753067e-06, 6.0234333e-06, 6.2274567e-06, 6.5192644e-06, 6.295989e-06, 5.8305195e-06, 5.9041963e-06, 5.287633e-06, 5.4735483e-06, 5.4105253e-06, 5.1925936e-06, 5.3978197e-06, 5.236385e-06, 4.9311025e-06, 4.989224e-06, 4.8262723e-06, 4.142314e-06, 4.1284875e-06, 4.132696e-06, 3.999789e-06, 3.7071998e-06, 3.76572e-06, 3.756289e-06, 3.4922298e-06, 4.2419383e-06, 4.2742104e-06, 4.2168567e-06, 4.5709266e-06, 4.621404e-06, 4.7670223e-06, 4.5479187e-06, 4.8442475e-06, 4.79662e-06, 4.781702e-06, 4.9614196e-06, 4.5960264e-06, 4.4992175e-06, 4.5039405e-06, 4.315951e-06, 4.252919e-06, 4.1102085e-06, 4.7247086e-06, 4.712056e-06, 4.9216424e-06, 5.0820654e-06, 5.2768914e-06, 5.408267e-06, 5.0337717e-06, 5.143717e-06, 5.072156e-06, 4.7906246e-06, 5.0116532e-06, 5.129994e-06, 4.8143747e-06, 5.0397566e-06, 5.364777e-06, 5.5108994e-06, 6.3071075e-06, 6.0278726e-06, 6.0593566e-06, 5.62475e-06, 5.8005107e-06, 5.7561665e-06, 5.011479e-06, 5.1461266e-06, 5.116965e-06, 5.2271694e-06, 5.0637323e-06, 5.0412377e-06, 5.1013963e-06, 5.1995607e-06, 5.000187e-06, 5.017897e-06, 4.8263933e-06, 4.968084e-06, 4.9967157e-06, 5.1187303e-06, 5.0271187e-06, 5.47348e-06, 5.495713e-06, 5.3965405e-06, 5.1739466e-06, 5.049066e-06, 5.372555e-06, 5.3835797e-06, 5.1281613e-06, 5.151702e-06, 5.071931e-06, 4.959409e-06, 5.3577537e-06, 5.307095e-06, 5.287475e-06, 5.2723867e-06, 5.2730575e-06, 5.355781e-06, 4.920756e-06, 4.6786067e-06, 5.027797e-06, 5.223967e-06, 5.3654553e-06, 5.458354e-06, 4.8211277e-06, 4.798099e-06, 5.3038375e-06, 5.2924893e-06, 5.1356465e-06, 5.2428377e-06, 6.2949157e-06, 5.846109e-06, 5.963708e-06, 5.996028e-06, 6.171664e-06, 5.9073523e-06, 5.8096184e-06, 5.865702e-06, 5.9036793e-06, 5.874543e-06, 6.028614e-06, 5.924646e-06, 5.215023e-06, 5.090559e-06, 5.1226993e-06, 5.0546323e-06, 5.182083e-06, 5.066883e-06, 5.405521e-06, 5.4882585e-06, 5.7262196e-06, 5.347524e-06, 5.222149e-06, 5.2576133e-06, 4.8913375e-06, 4.9851146e-06, 5.055303e-06, 5.1616043e-06, 5.2782543e-06, 5.3909803e-06, 5.0706335e-06, 4.8792226e-06, 5.1884904e-06, 4.7068293e-06, 4.800585e-06, 4.9413243e-06, 5.4613633e-06, 5.4718985e-06, 5.4011703e-06, 6.1515075e-06, 6.038459e-06, 6.0006237e-06, 6.056225e-06, 6.6178127e-06, 6.36174e-06, 6.5404647e-06, 6.5772874e-06, 6.6156676e-06, 6.58634e-06, 6.8232202e-06, 6.721231e-06, 7.0489264e-06, 7.048742e-06, 8.464981e-06, 8.56884e-06, 8.761072e-06, 8.730202e-06, 8.014828e-06, 7.923357e-06, 7.1493905e-06, 7.720676e-06, 7.8288385e-06, 7.939164e-06, 8.0341e-06, 8.262903e-06, 9.205853e-06, 9.3664385e-06, 1.070913e-05, 1.0555829e-05, 1.0833795e-05, 1.0480309e-05, 1.0120967e-05, 1.0089291e-05, 1.0179894e-05, 1.0704352e-05, 1.0350518e-05, 1.0746832e-05, 1.0514895e-05, 1.1248775e-05, 1.0481845e-05, 1.1073977e-05, 1.1198496e-05, 1.1010471e-05, 1.0328189e-05, 1.0023641e-05, 9.580574e-06, 9.555626e-06, 9.56439e-06, 9.752994e-06, 1.01455125e-05, 1.0097724e-05, 8.736634e-06, 8.775668e-06, 8.778317e-06, 8.731935e-06, 8.277499e-06, 8.449267e-06, 8.31711e-06, 7.789331e-06, 8.278756e-06, 7.7769555e-06, 8.2110955e-06, 7.887029e-06, 8.17815e-06, 7.980913e-06, 8.211827e-06, 8.382742e-06, 8.465504e-06, 8.245671e-06, 8.225832e-06, 8.805089e-06, 9.305084e-06, 9.134559e-06, 8.95655e-06, 9.354795e-06, 1.1326505e-05, 1.2110197e-05, 1.2348802e-05, 1.1756389e-05, 1.1977966e-05, 1.2602981e-05, 1.3161427e-05, 1.3709347 ...

# %% [markdown]
# ### realtime threshold

# %%
#   lookback n - period, find and use the best thresh for the next infer    #
lb_period = 1000

total_result = np.array(total_result).reshape(-1, 2)
y_score = total_result[:, [1]]

# def find_best_thr():
# min_thr_list = np.arange(0.60, 0.62, 0.01)
min_thr_list = np.arange(0.54, 0.56, 0.01)
# min_thr_list = [0.591]

for thr_i in tqdm(range(len(min_thr_list))):

  min_thr = min_thr_list[thr_i]

  best_thr_list = []
  new_pr_list = []
  for i in tqdm(range(lb_period, len(total_result))):

    precision, recall, threshold = precision_recall_curve(y_test[:len(y_score)][i - lb_period:i], y_score[i - lb_period:i])
    precision, recall = precision[:-1], recall[:-1]

    acc_pr_bythr = []
    new_thresh = []
    for thresh in threshold:

      if thresh < 0.5:
          continue

      #   lookback previous range   #
      y_pred = np.where(y_score[i - lb_period:i, -1] > thresh, 1, 0)

      test_size = len(y_test[:len(y_score)][i - lb_period:i])
      test_pr_list = pr_test[:len(y_score)][i - lb_period:i]

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)
    

    #       replace best_thr only max_pr > 1      #
    # if np.max(acc_pr_bythr) > 1.10:
    best_thr = new_thresh[np.argmax(acc_pr_bythr)]

    if best_thr < min_thr:
      best_thr = min_thr

      # if best_thr < 0.52:
      #   plt.subplot(121)
      #   plt.plot(threshold, precision, label='precision')
      #   plt.plot(threshold, recall, label='recall')
      #   plt.legend()
      #   plt.title('precision recall')
      #   # plt.show()
      #   plt.subplot(122)
      #   plt.plot(new_thresh, acc_pr_bythr)
      #   plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
      #   plt.axvline(new_thresh[np.argmax(acc_pr_bythr)])
      #   plt.title(symbol_name + '\n' + "%s" % new_thresh[np.argmax(acc_pr_bythr)])
      #   plt.show()


    best_thr_list.append(best_thr)

    #   use it   #
    # print("i :", i)
    if i >= len(y_score):
      break
    new_pr = np.where(y_score[i, -1] > best_thr, pr_test[:len(y_score)][i], 1)

    if new_pr == 0:
      continue

    #   use moving average  #
    # ma_period = 5
    # if len(best_thr_list) > ma_period:
    #   new_pr = np.where(y_score[i, -1] > np.mean(best_thr_list[-ma_period:]), pr_test[:len(y_score)][i], 1)

    new_pr_list.append(new_pr)

  plt.plot(np.cumprod(new_pr_list))
  plt.title(np.cumprod(new_pr_list)[-1])
  plt.show()

  plt.plot(best_thr_list)
  plt.title("best_thr_list")
  plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1603.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1603.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1603.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-a27555040437> in <module>()
#      36       pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
#      37       pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
# ---> 38       pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)
#      39
#      40       acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ### short ver.

# %%
#   lookback n - period, find and use the best thresh for the next infer    #
lb_period = 100
lvrg = 5
fee = 0.0006

total_result = np.array(total_result).reshape(-1, 2)
y_score = total_result[:, [0]]

# def find_best_thr():
min_thr_list = np.arange(0.63, 0.67, 0.01)

for thr_i in tqdm(range(len(min_thr_list))):

  min_thr = min_thr_list[thr_i]

  best_thr_list = []
  new_pr_list = []
  for i in tqdm(range(lb_period, len(total_result))):

    precision, recall, threshold = precision_recall_curve(y_test[:len(y_score)][i - lb_period:i], y_score[i - lb_period:i])
    precision, recall = precision[:-1], recall[:-1]

    acc_pr_bythr = []
    new_thresh = []
    for thresh in threshold:

      if thresh < 0.5:
          continue

      #   lookback previous range   #
      y_pred = np.where(y_score[i - lb_period:i, -1] > thresh, 1, 0)

      test_size = len(y_test[:len(y_score)][i - lb_period:i])
      test_pr_list = pr_test[:len(y_score)][i - lb_period:i]

      short_pr_list = np.where(test_pr_list != 1, ((1 / ((test_pr_list - 1) / lvrg + 1 + fee)) - 1 - fee) * lvrg + 1, test_pr_list)
      test_pr_list = short_pr_list

      pred_pr_list = np.where(y_pred == 1, test_pr_list.reshape(-1, ), 1.0)
      pred_pr_list = np.where(np.isnan(pred_pr_list), 1.0, pred_pr_list)
      pred_pr_list = np.where(pred_pr_list == 0.0, 1.0, pred_pr_list)

      acc_pr_bythr.append(np.cumprod(pred_pr_list)[-1])
      new_thresh.append(thresh)
    

    #       replace best_thr only max_pr > 1      #
    # if np.max(acc_pr_bythr) > 1.10:
    best_thr = new_thresh[np.argmax(acc_pr_bythr)]

    if best_thr < min_thr:
      best_thr = min_thr

      # if best_thr < 0.52:
      #   plt.subplot(121)
      #   plt.plot(threshold, precision, label='precision')
      #   plt.plot(threshold, recall, label='recall')
      #   plt.legend()
      #   plt.title('precision recall')
      #   # plt.show()
      #   plt.subplot(122)
      #   plt.plot(new_thresh, acc_pr_bythr)
      #   plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
      #   plt.axvline(new_thresh[np.argmax(acc_pr_bythr)])
      #   plt.title(symbol_name + '\n' + "%s" % new_thresh[np.argmax(acc_pr_bythr)])
      #   plt.show()


    best_thr_list.append(best_thr)

    #   use it   #
    new_pr = np.where(y_score[i, -1] > best_thr, pr_test[:len(y_score)][i], 1)

    #   use moving average  #
    # ma_period = 5
    # if len(best_thr_list) > ma_period:
    #   new_pr = np.where(y_score[i, -1] > np.mean(best_thr_list[-ma_period:]), pr_test[:len(y_score)][i], 1)

    new_pr_list.append(new_pr)

  plt.plot(np.cumprod(new_pr_list))
  plt.title(np.cumprod(new_pr_list)[-1])
  plt.show()

  plt.plot(best_thr_list)
  plt.title("best_thr_list")
  plt.show()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1992.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1992.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1992.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1992.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1992.0), HTML(value='')))

# %%
# model = FER_Model(input_shape=(45, 1))

period = 45
symbol_name = 'SXPUSDT'

ckpt_path = current_path + 'ckpt/'
board_path = current_path + 'graph/'
model_name = 'classifier_%s_lstm_close_updown_pr_robust_trial_re_%s_timesplit.h5' % (period, symbol_name)

# model_name = 'classifier_%s_close_updown_pr_theta_shuffle_without_back_03.h5' % period

model = keras.models.load_model(ckpt_path + model_name)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
for l_i, layer in enumerate(model.layers):

  if l_i != len(model.layers) - 1:
    layer.trainable = False

  print(layer, layer.trainable)

# %%
min_max = MinMaxScaler()
cbo1 = min_max.fit_transform(cbo.values.reshape(-1, 1))
bbw1 = min_max.fit_transform(bbw.values.reshape(-1, 1))

min_max = MinMaxScaler()
bbw2 = min_max.fit_transform(bbw.values.reshape(-1, 1))

print(bbw1[-10:])
print(bbw2[-10:])
plt.plot(bbw1)
plt.plot(bbw2)

plt.show()

print(len(bbw1))

# %% [markdown]
# ### Check shuffled index

# %%
# print(index_val)
from datetime import datetime

# print(index_test)
# print(index_train)
# print(index_val)
total_stamp = list(map(lambda x: datetime.timestamp(x[0]), input_index)) 
timestamp_train = list(map(lambda x: datetime.timestamp(x[0]), index_train)) 
timestamp_val = list(map(lambda x: datetime.timestamp(x[0]), index_val)) 
timestamp_test = list(map(lambda x: datetime.timestamp(x[0]), index_test)) 
# print(total_stamp)
# print(timestamp_train)
plt.figure(figsize=(40, 4))
plt.scatter(range(len(timestamp_train)), timestamp_train, label='train')
plt.scatter(range(len(timestamp_val)), timestamp_val, color='orange', label='val')
plt.scatter(range(len(timestamp_test)), timestamp_test, color='red', label='test')
plt.ylim(min(total_stamp), max(total_stamp))
plt.legend(fontsize=20)

# print(new_input_index)

# %% [markdown]
# ### Load Data

# %%
period = 45

x_save_path = current_path + 'npy/' + '%s_rnn_close_updown_x_train_neo_timesplit.npy' % period
x_train = np.load(x_save_path)
x_val = np.load(x_save_path.replace('x_train', 'x_val'))
x_test = np.load(x_save_path.replace('x_train', 'x_test'))
print('x series loaded !')

pr_save_path = current_path + 'npy/' + '%s_rnn_close_updown_pr_train_neo_timesplit.npy' % period
pr_train = np.load(pr_save_path)
pr_val = np.load(pr_save_path.replace('pr_train', 'pr_val'))
pr_test = np.load(pr_save_path.replace('pr_train', 'pr_test'))
print('y series loaded !')

_, row, col = x_train.shape
# Out:
# x series loaded !
# y series loaded !

# %%
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.3.1
# 1.15.2

# %% [markdown]
# ### **Data Split**

# %% [markdown]
# ### **Training**

# %%
org_x_test = x_test
org_y_test = y_test
org_pr_test = pr_test

# %%
x_test = org_x_test
y_test = org_y_test
pr_test = org_pr_test

# %%
concat_x = np.vstack((org_x_test, new_input_x))
concat_y = np.vstack((org_y_test, np.where(new_input_pr > 1, 1, 0)))
concat_pr = np.vstack((org_pr_test, new_input_pr))

# %%
x_test = new_input_x
y_test = np.where(new_input_pr > 1, 1, 0)
pr_test = new_input_pr

# %%
# print(pred_pr_list)
for pr in pred_pr_list:
  if pr != 1:
    print(pr)

# %%
plt.figure(figsize=(50, 5))
plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test):len(org_pr_test) + 10])
# plt.plot(np.cumprod(pred_pr_list)[len(org_pr_test) - 10:len(org_pr_test) + 10])
plt.title('%.3f' % (np.cumprod(pred_pr_list)[-1]))
# plt.axvline(len(org_pr_test), linestyle='--', color='r')
plt.show()

# %%
# plt.show()
# plt.subplot(122)
plt.plot(new_thresh, acc_pr_bythr)
plt.axhline(np.cumprod(test_pr_list)[-1], linestyle='--', color='r')
plt.show()

# %% [markdown]
# #### **clustering output**

# %%
# x_train_for_k = test_result.flatten().reshape(-1, 1)
x_train_for_k = test_result
print(x_train_for_k[:10])
# x_train_for_k = test_result[:, [1]]
pr_train = pr_test

print('x_train_for_k.shape :', x_train_for_k.shape)
print('pr_train.shape :', pr_train.shape)

K = range(2, 10)
s_dist = []
sil = []
for k in K:
  # if cen_data.shape[0] < k:
  #   break

  km = KMeans(n_clusters=k)
  km = km.fit(x_train_for_k)

  labels = km.labels_
  # print('len(labels) :', len(labels))
  # print('labels[:10] :', labels[:10])
  sil.append(silhouette_score(x_train_for_k, labels, metric='euclidean'))

  # inertia = km.inertia_
  # s_dist.append(inertia)

best_k = K[np.argmax(np.array(sil))]

plt.figure(figsize=(10, 5))
plt.plot(K, sil)
plt.axvline(best_k, linestyle='--')
# plt.plot(K, s_dist)
plt.show()





#   with best_k, label 별 pr_list 확인
km = KMeans(n_clusters=best_k)
km = km.fit(x_train_for_k)

labels = km.labels_

print(km.score(x_train_for_k))
print(len(labels), len(pr_train))





#   label 별로 profit 을 저장, 승률을 확인한다
label_types = np.unique(labels, return_counts=False)

label_pr_dict = {}
#   init dict   #
for label in label_types:
  label_pr_dict[label] = []
print(label_pr_dict)
# break

for i, (label, pr) in enumerate(zip(labels, pr_train)):
  label_pr_dict[label].append(pr[0])

  
# for label in label_types:
print(label_pr_dict)





def win_ratio(list_x):

  win_cnt = np.sum(np.array(list_x) > 1)
  return win_cnt / len(list_x)


def acc_pr(list_x):

  return np.cumprod(np.array(list_x))[-1]


for key in label_pr_dict:
  
  print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))





#     predict test && test 의 라벨에 따른 win_ratio 확인
# test_labels = km.predict(x_test)
# # print(test_labels)

# label_pr_dict = {}
# #   init dict   #
# for label in label_types:
#   label_pr_dict[label] = []
# print(label_pr_dict)
# # break

# for i, (label, pr) in enumerate(zip(test_labels, pr_test)):
#   label_pr_dict[label].append(pr[0])

# for key in label_pr_dict:

#   print(key, ':', 'win_ratio : %.2f' % (win_ratio(label_pr_dict[key])), 'acc_pr : %.2f' % (acc_pr(label_pr_dict[key])))
