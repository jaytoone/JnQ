# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %matplotlib inline

# input_data_length = int(input('input_data_length : '))
input_data_length = 30
model_num = 83
num_classes = 3

Made_X = np.load('Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
Made_Y = np.load('Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)


#       dataset 분리      #
# dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
# dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
Made_X = Made_X[:, :, :4]
print(Made_X.shape)
print(Made_Y.shape)

row = Made_X.shape[1]
col = Made_X.shape[2]

from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                   shuffle=False)

X_train = X_train.astype('float32').reshape(-1, input_data_length, col, 1)
X_val = X_val.astype('float32').reshape(-1, input_data_length, col, 1)
print(X_train.shape)
print(X_val.shape)

from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 

# Data Class Weight
from sklearn.utils import class_weight

print(Y_train[:, 0])
class_weights = class_weight.compute_class_weight('balanced', 
                                                  np.unique(Y_train[:, 0]),
                                                  Y_train[:, 0])
class_weights = dict(enumerate(class_weights))
# class_weights[1] *= 0.97
# class_weights[2] *= 0.97
print(class_weights)
# quit()

Y_train = Y_train.astype('float32')
Y_val = Y_val.astype('float32')
Y_train = np_utils.to_categorical(Y_train, num_classes)
Y_val = np_utils.to_categorical(Y_val, num_classes)
print(Y_train.shape)
print(Y_val.shape)

datagen = ImageDataGenerator( 
#     rotation_range = 60,
#     zoom_range = 0.6,
#     shear_range = 0.6,
#     horizontal_flip = True,
#     width_shift_range=0.6,
#     height_shift_range=0.6,
    fill_mode = 'nearest'
    )

testgen = ImageDataGenerator( 
    )
datagen.fit(X_train)
batch_size = 128

for X_batch, _ in datagen.flow(X_train, Y_train, batch_size=9):
    for i in range(0, 9): 
        pyplot.axis('off') 
        pyplot.subplot(330 + 1 + i) 
        pyplot.imshow(X_batch[i].reshape(input_data_length, col), cmap=pyplot.get_cmap('gray'))
    pyplot.axis('off') 
    pyplot.show() 
    break
    
    
train_flow = datagen.flow(X_train, Y_train, batch_size=batch_size) 
val_flow = testgen.flow(X_val, Y_val, batch_size=batch_size) 


from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix

def FER_Model(input_shape=(row, col, 1)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(64, kernel_size=3, padding='same')(visible)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_1 = net

    net = layers.Conv2D(128, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
    
    return model

model = FER_Model()
# from keras.models import load_model
# model = load_model('model/rapid_ascending %s_%s_ohlc.hdf5' % (input_data_length, model_num))
opt = Adam(lr=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
  
    
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath="model/rapid_ascending %s_%s_ohlc.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_accuracy', patience=50)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 100
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(X_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(X_val) / batch_size,
                    shuffle=False)
# Out:
# (238688, 30, 4)
# (238688, 1)
# (167081, 30, 4, 1)
# (71607, 30, 4, 1)
# Using TensorFlow backend.
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/lab23/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# [0. 0. 0. ... 0. 0. 0.]
# {0: 0.440433260578454, 1: 2.452385146044327, 2: 3.1080789478579534}
# (167081, 3)
# (71607, 3)
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, 30, 4, 1)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 4, 64)         640
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 30, 4, 64)         0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 2, 64)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 2, 128)        73856
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 15, 2, 128)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 896)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                57408
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 132,099
# Trainable params: 132,099
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:200: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:203: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/100
#  - 7s - loss: 0.9901 - accuracy: 0.3924 - val_loss: 1.0045 - val_accuracy: 0.4373
#
# Epoch 00001: val_accuracy improved from -inf to 0.43729, saving model to model/rapid_ascending 30_83_ohlc.hdf5
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow2_p36/lib/python3.6/site-packages/keras/callbacks/tensorboard_v1.py:343: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/100
#  - 5s - loss: 0.9474 - accuracy: 0.3969 - val_loss: 0.9272 - val_accuracy: 0.4874
#
# Epoch 00002: val_accuracy improved from 0.43729 to 0.48744, saving model to model/rapid_ascending 30_83_ohlc.hdf5
# Epoch 3/100
#  - 5s - loss: 0.9393 - accuracy: 0.4021 - val_loss: 1.0221 - val_accuracy: 0.4196
#
# Epoch 00003: val_accuracy did not improve from 0.48744
# Epoch 4/100
#  - 5s - loss: 0.9330 - accuracy: 0.4037 - val_loss: 0.9493 - val_accuracy: 0.4434
#
# Epoch 00004: val_accuracy did not improve from 0.48744
# Epoch 5/100
#  - 5s - loss: 0.9279 - accuracy: 0.4078 - val_loss: 0.9224 - val_accuracy: 0.4233
#
# Epoch 00005: val_accuracy did not improve from 0.48744
# Epoch 6/100
#  - 5s - loss: 0.9235 - accuracy: 0.4108 - val_loss: 1.0932 - val_accuracy: 0.3330
#
# Epoch 00006: val_accuracy did not improve from 0.48744
# Epoch 7/100
#  - 5s - loss: 0.9200 - accuracy: 0.4129 - val_loss: 0.9578 - val_accuracy: 0.4048
#
# Epoch 00007: val_accuracy did not improve from 0.48744
# Epoch 8/100
#  - 5s - loss: 0.9151 - accuracy: 0.4163 - val_loss: 0.8654 - val_accuracy: 0.4593
#
# Epoch 00008: val_accuracy did not improve from 0.48744
# Epoch 9/100
#  - 5s - loss: 0.9118 - accuracy: 0.4186 - val_loss: 0.8549 - val_accuracy: 0.4738
#
# Epoch 00009: val_accuracy did not improve from 0.48744
# Epoch 10/100
#  - 5s - loss: 0.9081 - accuracy: 0.4216 - val_loss: 0.9392 - val_accuracy: 0.4208
#
# Epoch 00010: val_accuracy did not improve from 0.48744
# Epoch 11/100
#  - 5s - loss: 0.9053 - accuracy: 0.4231 - val_loss: 0.9402 - val_accuracy: 0.4396
#
# Epoch 00011: val_accuracy did not improve from 0.48744
# Epoch 12/100
#  - 5s - loss: 0.9037 - accuracy: 0.4248 - val_loss: 1.0064 - val_accuracy: 0.4022
#
# Epoch 00012: val_accuracy did not improve from 0.48744
# Epoch 13/100
#  - 5s - loss: 0.9010 - accuracy: 0.4266 - val_loss: 0.8944 - val_accuracy: 0.4267
#
# Epoch 00013: val_accuracy did not improve from 0.48744
# Epoch 14/100
#  - 5s - loss: 0.8986 - accuracy: 0.4293 - val_loss: 1.1157 - val_accuracy: 0.4262
#
# Epoch 00014: val_accuracy did not improve from 0.48744
# Epoch 15/100
#  - 5s - loss: 0.8970 - accuracy: 0.4314 - val_loss: 0.8600 - val_accuracy: 0.4885
#
# Epoch 00015: val_accuracy improved from 0.48744 to 0.48849, saving model to model/rapid_ascending 30_83_ohlc.hdf5
# Epoch 16/100
#  - 5s - loss: 0.8955 - accuracy: 0.4343 - val_loss: 0.8558 - val_accuracy: 0.4868
#
# Epoch 00016: val_accuracy did not improve from 0.48849
# Epoch 17/100
#  - 5s - loss: 0.8936 - accuracy: 0.4361 - val_loss: 0.9416 - val_accuracy: 0.4921
#
# Epoch 00017: val_accuracy improved from 0.48849 to 0.49213, saving model to model/rapid_ascending 30_83_ohlc.hdf5
# Epoch 18/100
#  - 5s - loss: 0.8921 - accuracy: 0.4401 - val_loss: 1.0228 - val_accuracy: 0.4327
#
# Epoch 00018: val_accuracy did not improve from 0.49213
# Epoch 19/100
#  - 5s - loss: 0.8905 - accuracy: 0.4386 - val_loss: 1.0809 - val_accuracy: 0.4451
#
# Epoch 00019: val_accuracy did not improve from 0.49213
# Epoch 20/100
#  - 5s - loss: 0.8896 - accuracy: 0.4430 - val_loss: 0.9347 - val_accuracy: 0.4406
#
# Epoch 00020: val_accuracy did not improve from 0.49213
# Epoch 21/100
#  - 5s - loss: 0.8876 - accuracy: 0.4434 - val_loss: 0.8758 - val_accuracy: 0.5282
#
# Epoch 00021: val_accuracy improved from 0.49213 to 0.52822, saving model to model/rapid_ascending 30_83_ohlc.hdf5
# Epoch 22/100
#  - 5s - loss: 0.8865 - accuracy: 0.4444 - val_loss: 0.9026 - val_accuracy: 0.4813
#
# Epoch 00022: val_accuracy did not improve from 0.52822
# Epoch 23/100
#  - 5s - loss: 0.8862 - accuracy: 0.4458 - val_loss: 0.8850 - val_accuracy: 0.4530
#
# Epoch 00023: val_accuracy did not improve from 0.52822
# Epoch 24/100
#  - 5s - loss: 0.8847 - accuracy: 0.4461 - val_loss: 0.8826 - val_accuracy: 0.4913
#
# Epoch 00024: val_accuracy did not improve from 0.52822
# Epoch 25/100
#  - 5s - loss: 0.8835 - accuracy: 0.4503 - val_loss: 1.0284 - val_accuracy: 0.4583
#
# Epoch 00025: val_accuracy did not improve from 0.52822
# Epoch 26/100
#  - 5s - loss: 0.8830 - accuracy: 0.4499 - val_loss: 0.9423 - val_accuracy: 0.4553
#
# Epoch 00026: val_accuracy did not improve from 0.52822
# Epoch 27/100
#  - 5s - loss: 0.8815 - accuracy: 0.4525 - val_loss: 0.9390 - val_accuracy: 0.4148
#
# Epoch 00027: val_accuracy did not improve from 0.52822
# Epoch 28/100
#  - 5s - loss: 0.8808 - accuracy: 0.4548 - val_loss: 1.0114 - val_accuracy: 0.4471
#
# Epoch 00028: val_accuracy did not improve from 0.52822
# Epoch 29/100
#  - 5s - loss: 0.8800 - accuracy: 0.4539 - val_loss: 0.9432 - val_accuracy: 0.4849
#
# Epoch 00029: val_accuracy did not improve from 0.52822
# Epoch 30/100
#  - 5s - loss: 0.8791 - accuracy: 0.4546 - val_loss: 0.9156 - val_accuracy: 0.4498
#
# Epoch 00030: val_accuracy did not improve from 0.52822
# Epoch 31/100
#  - 5s - loss: 0.8776 - accuracy: 0.4569 - val_loss: 0.8935 - val_accuracy: 0.4810
#
# Epoch 00031: val_accuracy did not improve from 0.52822
# Epoch 32/100
#  - 5s - loss: 0.8768 - accuracy: 0.4566 - val_loss: 0.8424 - val_accuracy: 0.4852
#
# Epoch 00032: val_accuracy did not improve from 0.52822
# Epoch 33/100
#  - 5s - loss: 0.8760 - accuracy: 0.4586 - val_loss: 0.9996 - val_accuracy: 0.4339
#
# Epoch 00033: val_accuracy did not improve from 0.52822
# Epoch 34/100
#  - 5s - loss: 0.8761 - accuracy: 0.4591 - val_loss: 1.0300 - val_accuracy: 0.4518
#
# Epoch 00034: val_accuracy did not improve from 0.52822
# Epoch 35/100
#  - 5s - loss: 0.8753 - accuracy: 0.4585 - val_loss: 0.9158 - val_accuracy: 0.4666
#
# Epoch 00035: val_accuracy did not improve from 0.52822
# Epoch 36/100
#  - 5s - loss: 0.8741 - accuracy: 0.4607 - val_loss: 0.8851 - val_accuracy: 0.4649
#
# Epoch 00036: val_accuracy did not improve from 0.52822
# Epoch 37/100
#  - 5s - loss: 0.8730 - accuracy: 0.4618 - val_loss: 1.0523 - val_accuracy: 0.4425
#
# Epoch 00037: val_accuracy did not improve from 0.52822
# Epoch 38/100
#  - 5s - loss: 0.8723 - accuracy: 0.4610 - val_loss: 0.8903 - val_accuracy: 0.4766
#
# Epoch 00038: val_accuracy did not improve from 0.52822
# Epoch 39/100
#  - 5s - loss: 0.8716 - accuracy: 0.4647 - val_loss: 0.8207 - val_accuracy: 0.4501
#
# Epoch 00039: val_accuracy did not improve from 0.52822
# Epoch 40/100
#  - 5s - loss: 0.8712 - accuracy: 0.4637 - val_loss: 0.9845 - val_accuracy: 0.4888
#
# Epoch 00040: val_accuracy did not improve from 0.52822
# Epoch 41/100
#  - 5s - loss: 0.8699 - accuracy: 0.4641 - val_loss: 0.9638 - val_accuracy: 0.4755
#
# Epoch 00041: val_accuracy did not improve from 0.52822
# Epoch 42/100
#  - 5s - loss: 0.8692 - accuracy: 0.4646 - val_loss: 0.9983 - val_accuracy: 0.4799
#
# Epoch 00042: val_accuracy did not improve from 0.52822
# Epoch 43/100
#  - 5s - loss: 0.8686 - accuracy: 0.4657 - val_loss: 0.9624 - val_accuracy: 0.4653
#
# Epoch 00043: val_accuracy did not improve from 0.52822
# Epoch 44/100
#  - 5s - loss: 0.8689 - accuracy: 0.4650 - val_loss: 0.8881 - val_accuracy: 0.4378
#
# Epoch 00044: val_accuracy did not improve from 0.52822
# Epoch 45/100
#  - 5s - loss: 0.8671 - accuracy: 0.4659 - val_loss: 0.9231 - val_accuracy: 0.4725
#
# Epoch 00045: val_accuracy did not improve from 0.52822
# Epoch 46/100
#  - 5s - loss: 0.8670 - accuracy: 0.4669 - val_loss: 1.0572 - val_accuracy: 0.4440
#
# Epoch 00046: val_accuracy did not improve from 0.52822
# Epoch 47/100
#  - 5s - loss: 0.8662 - accuracy: 0.4689 - val_loss: 0.9535 - val_accuracy: 0.4472
#
# Epoch 00047: val_accuracy did not improve from 0.52822
# Epoch 48/100
#  - 5s - loss: 0.8655 - accuracy: 0.4688 - val_loss: 0.9257 - val_accuracy: 0.4703
#
# Epoch 00048: val_accuracy did not improve from 0.52822
# Epoch 49/100
#  - 5s - loss: 0.8656 - accuracy: 0.4681 - val_loss: 1.0355 - val_accuracy: 0.4749
#
# Epoch 00049: val_accuracy did not improve from 0.52822
# Epoch 50/100
#  - 5s - loss: 0.8646 - accuracy: 0.4684 - val_loss: 0.8261 - val_accuracy: 0.5266
#
# Epoch 00050: val_accuracy did not improve from 0.52822
# Epoch 51/100
#  - 5s - loss: 0.8636 - accuracy: 0.4696 - val_loss: 0.9167 - val_accuracy: 0.4933
#
# Epoch 00051: val_accuracy did not improve from 0.52822
# Epoch 52/100
#  - 5s - loss: 0.8631 - accuracy: 0.4707 - val_loss: 0.9091 - val_accuracy: 0.4711
#
# Epoch 00052: val_accuracy did not improve from 0.52822
# Epoch 53/100
#  - 5s - loss: 0.8626 - accuracy: 0.4699 - val_loss: 0.8911 - val_accuracy: 0.5367
#
# Epoch 00053: val_accuracy improved from 0.52822 to 0.53675, saving model to model/rapid_ascending 30_83_ohlc.hdf5
# Epoch 54/100
#  - 5s - loss: 0.8614 - accuracy: 0.4709 - val_loss: 0.8629 - val_accuracy: 0.4757
#
# Epoch 00054: val_accuracy did not improve from 0.53675
# Epoch 55/100
#  - 5s - loss: 0.8617 - accuracy: 0.4707 - val_loss: 0.9490 - val_accuracy: 0.4907
#
# Epoch 00055: val_accuracy did not improve from 0.53675
# Epoch 56/100
#  - 5s - loss: 0.8606 - accuracy: 0.4717 - val_loss: 0.9577 - val_accuracy: 0.4725
#
# Epoch 00056: val_accuracy did not improve from 0.53675
# Epoch 57/100
#  - 5s - loss: 0.8607 - accuracy: 0.4719 - val_loss: 0.9579 - val_accuracy: 0.5039
#
# Epoch 00057: val_accuracy did not improve from 0.53675
# Epoch 58/100
#  - 5s - loss: 0.8594 - accuracy: 0.4723 - val_loss: 1.0105 - val_accuracy: 0.4726
#
# Epoch 00058: val_accuracy did not improve from 0.53675
# Epoch 59/100
#  - 5s - loss: 0.8582 - accuracy: 0.4730 - val_loss: 0.7836 - val_accuracy: 0.4449
#
# Epoch 00059: val_accuracy did not improve from 0.53675
# Epoch 60/100
#  - 5s - loss: 0.8583 - accuracy: 0.4719 - val_loss: 1.0419 - val_accuracy: 0.4233
#
# Epoch 00060: val_accuracy did not improve from 0.53675
# Epoch 61/100
#  - 5s - loss: 0.8583 - accuracy: 0.4740 - val_loss: 0.9601 - val_accuracy: 0.4384
#
# Epoch 00061: val_accuracy did not improve from 0.53675
# Epoch 62/100
#  - 5s - loss: 0.8575 - accuracy: 0.4736 - val_loss: 0.9226 - val_accuracy: 0.4643
#
# Epoch 00062: val_accuracy did not improve from 0.53675
# Epoch 63/100
#  - 5s - loss: 0.8568 - accuracy: 0.4740 - val_loss: 0.8904 - val_accuracy: 0.4765
#
# Epoch 00063: val_accuracy did not improve from 0.53675
# Epoch 64/100
#  - 5s - loss: 0.8563 - accuracy: 0.4742 - val_loss: 1.0555 - val_accuracy: 0.4444
#
# Epoch 00064: val_accuracy did not improve from 0.53675
# Epoch 65/100
#  - 5s - loss: 0.8550 - accuracy: 0.4748 - val_loss: 0.7955 - val_accuracy: 0.5164
#
# Epoch 00065: val_accuracy did not improve from 0.53675
# Epoch 66/100
#  - 5s - loss: 0.8545 - accuracy: 0.4756 - val_loss: 0.9014 - val_accuracy: 0.4889
#
# Epoch 00066: val_accuracy did not improve from 0.53675
# Epoch 67/100
#  - 5s - loss: 0.8542 - accuracy: 0.4758 - val_loss: 0.9194 - val_accuracy: 0.4820
#
# Epoch 00067: val_accuracy did not improve from 0.53675
# Epoch 68/100
#  - 5s - loss: 0.8539 - accuracy: 0.4757 - val_loss: 1.0379 - val_accuracy: 0.4822
#
# Epoch 00068: val_accuracy did not improve from 0.53675
# Epoch 69/100
#  - 5s - loss: 0.8524 - accuracy: 0.4763 - val_loss: 0.9454 - val_accuracy: 0.5109
#
# Epoch 00069: val_accuracy did not improve from 0.53675
# Epoch 70/100
#  - 5s - loss: 0.8525 - accuracy: 0.4755 - val_loss: 0.8952 - val_accuracy: 0.4945
#
# Epoch 00070: val_accuracy did not improve from 0.53675
# Epoch 71/100
#  - 5s - loss: 0.8513 - accuracy: 0.4771 - val_loss: 0.9177 - val_accuracy: 0.4750
#
# Epoch 00071: val_accuracy did not improve from 0.53675
# Epoch 72/100
#  - 5s - loss: 0.8507 - accuracy: 0.4772 - val_loss: 0.9152 - val_accuracy: 0.4743
#
# Epoch 00072: val_accuracy did not improve from 0.53675
# Epoch 73/100
#  - 5s - loss: 0.8504 - accuracy: 0.4771 - val_loss: 0.8858 - val_accuracy: 0.4835
#
# Epoch 00073: val_accuracy did not improve from 0.53675
# Epoch 74/100
#  - 5s - loss: 0.8499 - accuracy: 0.4777 - val_loss: 0.9472 - val_accuracy: 0.4589
#
# Epoch 00074: val_accuracy did not improve from 0.53675
# Epoch 75/100
#  - 5s - loss: 0.8483 - accuracy: 0.4781 - val_loss: 0.9353 - val_accuracy: 0.4848
#
# Epoch 00075: val_accuracy did not improve from 0.53675
# Epoch 76/100
#  - 5s - loss: 0.8489 - accuracy: 0.4776 - val_loss: 0.9097 - val_accuracy: 0.4914
#
# Epoch 00076: val_accuracy did not improve from 0.53675
# Epoch 77/100
#  - 5s - loss: 0.8485 - accuracy: 0.4781 - val_loss: 1.0043 - val_accuracy: 0.4552
#
# Epoch 00077: val_accuracy did not improve from 0.53675
# Epoch 78/100
#  - 5s - loss: 0.8469 - accuracy: 0.4792 - val_loss: 0.9524 - val_accuracy: 0.4832
#
# Epoch 00078: val_accuracy did not improve from 0.53675
# Epoch 79/100
#  - 5s - loss: 0.8467 - accuracy: 0.4801 - val_loss: 0.7892 - val_accuracy: 0.5104
#
# Epoch 00079: val_accuracy did not improve from 0.53675
# Epoch 80/100
#  - 5s - loss: 0.8461 - accuracy: 0.4801 - val_loss: 0.8773 - val_accuracy: 0.4820
#
# Epoch 00080: val_accuracy did not improve from 0.53675
# Epoch 81/100
#  - 5s - loss: 0.8456 - accuracy: 0.4792 - val_loss: 0.9211 - val_accuracy: 0.5153
#
# Epoch 00081: val_accuracy did not improve from 0.53675
# Epoch 82/100
#  - 5s - loss: 0.8445 - accuracy: 0.4809 - val_loss: 1.0783 - val_accuracy: 0.4547
#
# Epoch 00082: val_accuracy did not improve from 0.53675
# Epoch 83/100
#  - 5s - loss: 0.8442 - accuracy: 0.4795 - val_loss: 0.6604 - val_accuracy: 0.4982
#
# Epoch 00083: val_accuracy did not improve from 0.53675
# Epoch 84/100
#  - 5s - loss: 0.8437 - accuracy: 0.4810 - val_loss: 0.9828 - val_accuracy: 0.4444
#
# Epoch 00084: val_accuracy did not improve from 0.53675
# Epoch 85/100
#  - 5s - loss: 0.8435 - accuracy: 0.4796 - val_loss: 0.9215 - val_accuracy: 0.4736
#
# Epoch 00085: val_accuracy did not improve from 0.53675
# Epoch 86/100
#  - 5s - loss: 0.8430 - accuracy: 0.4812 - val_loss: 0.9541 - val_accuracy: 0.4515
#
# Epoch 00086: val_accuracy did not improve from 0.53675
# Epoch 87/100
#  - 5s - loss: 0.8413 - accuracy: 0.4816 - val_loss: 0.9990 - val_accuracy: 0.4962
#
# Epoch 00087: val_accuracy did not improve from 0.53675
# Epoch 88/100
#  - 5s - loss: 0.8406 - accuracy: 0.4826 - val_loss: 0.9750 - val_accuracy: 0.4875
#
# Epoch 00088: val_accuracy did not improve from 0.53675
# Epoch 89/100
#  - 5s - loss: 0.8399 - accuracy: 0.4838 - val_loss: 0.8508 - val_accuracy: 0.4754
#
# Epoch 00089: val_accuracy did not improve from 0.53675
# Epoch 90/100
#  - 5s - loss: 0.8395 - accuracy: 0.4828 - val_loss: 0.9794 - val_accuracy: 0.4779
#
# Epoch 00090: val_accuracy did not improve from 0.53675
# Epoch 91/100
#  - 5s - loss: 0.8390 - accuracy: 0.4823 - val_loss: 1.0351 - val_accuracy: 0.5072
#
# Epoch 00091: val_accuracy did not improve from 0.53675
# Epoch 92/100
#  - 5s - loss: 0.8386 - accuracy: 0.4828 - val_loss: 0.9454 - val_accuracy: 0.4967
#
# Epoch 00092: val_accuracy did not improve from 0.53675
# Epoch 93/100
#  - 5s - loss: 0.8383 - accuracy: 0.4828 - val_loss: 0.9581 - val_accuracy: 0.4799
#
# Epoch 00093: val_accuracy did not improve from 0.53675
# Epoch 94/100
#  - 5s - loss: 0.8368 - accuracy: 0.4850 - val_loss: 1.0283 - val_accuracy: 0.4561
#
# Epoch 00094: val_accuracy did not improve from 0.53675
# Epoch 95/100
#  - 5s - loss: 0.8368 - accuracy: 0.4848 - val_loss: 1.0152 - val_accuracy: 0.4329
#
# Epoch 00095: val_accuracy did not improve from 0.53675
# Epoch 96/100
#  - 5s - loss: 0.8357 - accuracy: 0.4842 - val_loss: 0.9810 - val_accuracy: 0.4986
#
# Epoch 00096: val_accuracy did not improve from 0.53675
# Epoch 97/100
#  - 5s - loss: 0.8353 - accuracy: 0.4857 - val_loss: 0.9041 - val_accuracy: 0.4773
#
# Epoch 00097: val_accuracy did not improve from 0.53675
# Epoch 98/100
#  - 5s - loss: 0.8353 - accuracy: 0.4845 - val_loss: 1.0378 - val_accuracy: 0.4305
#
# Epoch 00098: val_accuracy did not improve from 0.53675
# Epoch 99/100
#  - 5s - loss: 0.8339 - accuracy: 0.4867 - val_loss: 1.0090 - val_accuracy: 0.4452
#
# Epoch 00099: val_accuracy did not improve from 0.53675
# Epoch 100/100
#  - 5s - loss: 0.8329 - accuracy: 0.4861 - val_loss: 0.9048 - val_accuracy: 0.4471
#
# Epoch 00100: val_accuracy did not improve from 0.53675

# %%
from keras.models import load_model

model = load_model('model/rapid_ascending %s_%s.hdf5' % (input_data_length, model_num))
# model = load_model('/content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending %s.hdf5' % input_data_length)
# loss = model.evaluate_generator(test_flow, steps=len(X_test) / batch_size) 
# print("Test Loss " + str(loss[0]))
# print("Test Acc: " + str(loss[1]))

# loss = model.evaluate(X_val, Y_val) 
# print(X_val.shape)
# print(Y_val.shape)

# print("Val Loss " + str(loss[0]))
# print("Val Acc: " + str(loss[1]))

#     Prediction    #
Y_pred_ = model.predict(X_test, verbose=1)

# Y_pred = Y_pred_[:,[-1]]
# print(Y_pred.shape)
# print(Y_test.shape)
Y_pred = np.argmax(Y_pred_, axis=1)
t_te = np.argmax(Y_test, axis=1)

#     Manual processing     #
Y_pred_one = Y_pred_[:, [-1]]
print(Y_pred_)
max_value = np.max(Y_pred_one)
print(max_value)

limit_line = 0.9
Y_pred_one = np.where(Y_pred_one > max_value * limit_line, 1, 0)

# print(Y_pred_one)
Y_pred_one = Y_pred_one.reshape(-1,)
# print(Y_pred_1)
# print(Y_pred.shape)
# print(t_te.shape)

# fail = 0
# fail2 = 0
# for i in range(len(Y_pred)):
#   if Y_pred_1[i] != t_te[i]:
#     fail += 1

#   if Y_pred[i] != t_te[i]:
#     fail2 += 1

# print(1 - fail / len(Y_pred))
# print(1 - fail2 / len(Y_pred))

# print(np.sum(Y_pred), np.sum(t_te))
# print('Y_pred / Y_test :', np.sum(Y_pred) / np.sum(t_te))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(100,10))
plt.subplot(211)
plt.plot(Y_test, 'purple', label='test')

plt.subplot(212)
plt.plot(Y_pred_one, 'y', label='pred')
plt.show()
# plt.savefig('/content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending %s.png' % input_data_length)
# plt.close()
