# %%
import numpy as np
import pandas as pd
import pybithumb
import os
import matplotlib.pyplot as plt
import warnings
from sklearn.preprocessing import MinMaxScaler
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 500)

dir = 'ohlcv/'
ohlcv_list = os.listdir(dir)

def min_max_scaler(price):
    Scaler = MinMaxScaler()
    Scaler.fit(price)

    return Scaler.transform(price)


def low_high(Coin, input_data_length, trade_limit=0):

    #   거래 제한은 고점과 저점을 분리한다.

    #   User-Agent Configuration
    ohlcv_excel = pybithumb.get_ohlcv(Coin, 'KRW', 'minute1')

    price_gap = ohlcv_excel.close.max() / ohlcv_excel.close.min()
    if (price_gap < 1.07) and (trade_limit == 1):
        return None, None

    obv = [0] * len(ohlcv_excel)
    for m in range(1, len(ohlcv_excel)):
        if ohlcv_excel['close'].iloc[m] > ohlcv_excel['close'].iloc[m - 1]:
            obv[m] = obv[m - 1] + ohlcv_excel['volume'].iloc[m]
        elif ohlcv_excel['close'].iloc[m] == ohlcv_excel['close'].iloc[m - 1]:
            obv[m] = obv[m - 1]
        else:
            obv[m] = obv[m - 1] - ohlcv_excel['volume'].iloc[m]
    ohlcv_excel['OBV'] = obv

    closeprice = ohlcv_excel['close'].iloc[-1]

    # ----------- dataX, dataY 추출하기 -----------#
    #   OBV :
    ohlcv_data = ohlcv_excel.values[1:].astype(np.float)

    # 결측 데이터 제외
    if len(ohlcv_data) != 0:

        #          데이터 전처리         #
        #   Fixed X_data    #
        price = ohlcv_data[:, :4]
        volume = ohlcv_data[:, [4]]
        OBV = ohlcv_data[:, [-1]]

        scaled_price = min_max_scaler(price)
        scaled_volume = min_max_scaler(volume)
        scaled_OBV = min_max_scaler(OBV)
        # print(scaled_MA60.shape)

        x = np.concatenate((scaled_price, scaled_volume, scaled_OBV), axis=1)  # axis=1, 세로로 합친다

        if (x[-1][1] > 0.3) and (trade_limit == 1):
            return None, None

        # print(x.shape)  # (258, 6)
        # quit()

        dataX = []  # input_data length 만큼 담을 dataX 그릇
        for i in range(input_data_length, len(ohlcv_data) + 1):  # 마지막 데이터까지 다 긇어모은다.
            group_x = x[i - input_data_length:i]
            dataX.append(group_x)  # dataX 리스트에 추가

        if (len(dataX) < 100) and (trade_limit == 1):
            return None, None

        X_test = np.array(dataX)
        row = X_test.shape[1]
        col = X_test.shape[2]

        X_test = X_test.astype('float32').reshape(-1, row, col, 1)

        return X_test, closeprice


def made_x(file, input_data_length, model_num, check_span, get_fig):

    ohlcv_excel = pd.read_excel(dir + file, index_col=0)

    obv = [0] * len(ohlcv_excel)
    for m in range(1, len(ohlcv_excel)):
        if ohlcv_excel['close'].iloc[m] > ohlcv_excel['close'].iloc[m - 1]:
            obv[m] = obv[m - 1] + ohlcv_excel['volume'].iloc[m]
        elif ohlcv_excel['close'].iloc[m] == ohlcv_excel['close'].iloc[m - 1]:
            obv[m] = obv[m - 1]
        else:
            obv[m] = obv[m - 1] - ohlcv_excel['volume'].iloc[m]
    ohlcv_excel['OBV'] = obv

    #   이후 check_span 데이터와 현재 포인트를 비교해서 현재 포인트가 저가인지 고가인지 예측한다.
    #   최대 3개의 중복 값을 허용한다.
    #   고저점을 잡아주는 함수 구현
    list_low_check = [np.NaN] * len(ohlcv_excel)
    list_high_check = [np.NaN] * len(ohlcv_excel)
    for i in range(len(ohlcv_excel) - check_span):
        if ohlcv_excel['close'][i + 1:i + 1 + check_span].min() >= ohlcv_excel['close'][i]:
            if ohlcv_excel['close'][i:i + 1 + check_span].value_counts().sort_index().iloc[0] <= 3:
                list_low_check[i] = 1
            else:
                list_low_check[i] = 0
        else:
            list_low_check[i] = 0

        if ohlcv_excel['close'][i + 1:i + 1 + check_span].max() <= ohlcv_excel['close'][i]:
            if ohlcv_excel['close'][i:i + 1 + check_span].value_counts().sort_index().iloc[-1] <= 3:
                list_high_check[i] = 1
            else:
                list_high_check[i] = 0
        else:
            list_high_check[i] = 0

    ohlcv_excel['low_check'] = list_low_check
    ohlcv_excel['high_check'] = list_high_check

    # ----------- dataX, dataY 추출하기 -----------#
    # print(ohlcv_excel.info())
    # ohlcv_excel.to_excel('test.xlsx')
    # quit()

    # NaN 제외하고 데이터 자르기 (데이터가 PIXEL 로 들어간다고 생각하면 된다)
    #   OBV : -CHECK_SPAN
    ohlcv_data = ohlcv_excel.values[1: -check_span].astype(np.float)
    # print(pd.DataFrame(ohlcv_data).info())
    # print(pd.DataFrame(ohlcv_data).to_excel('test.xlsx'))
    # print(list(map(float, ohlcv_data[0])))
    # quit()

    # 결측 데이터 제외
    if len(ohlcv_data) != 0:

        #          데이터 전처리         #
        #   Fixed X_data    #
        price = ohlcv_data[:, :4]
        volume = ohlcv_data[:, [4]]
        OBV = ohlcv_data[:, [-3]]

        #   Flexible Y_data    #
        low_check = ohlcv_data[:, [-2]]
        high_check = ohlcv_data[:, [-1]]

        # scaled_price = min_max_scaler(price)
        # scaled_volume = min_max_scaler(volume)
        scaled_OBV = min_max_scaler(OBV)

        x = np.concatenate((price, volume, scaled_OBV), axis=1)  # axis=1, 세로로 합친다
        y_low = low_check
        y_high = high_check
        # print(x.shape, y_low.shape)  # (258, 6) (258, 1)
        # quit()

        dataX = []  # input_data length 만큼 담을 dataX 그릇
        dataY_low = []  # Target 을 담을 그릇
        dataY_high = []  # Target 을 담을 그릇

        for i in range(input_data_length, len(ohlcv_data)):
            # group_x >> 이전 완성된 데이터를 사용해보도록 한다. (진입하는 시점은 데이터가 완성되어있지 않으니까)
            group_x = x[i - input_data_length: i]  # group_y 보다 1개 이전 데이터
            group_y_low = y_low[i]
            group_y_high = y_high[i]

            #       Rescaling       #
            group_x[:, :4] = min_max_scaler(group_x[:, :4])
            group_x[:, [4]] = min_max_scaler(group_x[:, [4]])

            # print(group_x.max(), group_x.min())  # (28, 6)
            # quit()

            # if i == len(y) - 1:
            #     # print(group_x, "->", group_y)
            #     print(group_x[-1])
            #     print(x[i - 1])
            #     quit()
            dataX.append(group_x)  # dataX 리스트에 추가
            dataY_low.append(group_y_low)  # dataY 리스트에 추가
            dataY_high.append(group_y_high)  # dataY 리스트에 추가

        if len(dataX) < 100:
            return None

        #       Exstracting fiexd X_data       #
        sliced_ohlcv = ohlcv_data[input_data_length:, :6]

        #                      Get Figure                     #
        if get_fig == 1:
            spanlist_low = []
            spanlist_high = []

            for m in range(len(low_check)):
                if low_check[m] > 0.5:
                    if m + 1 < len(low_check):
                        spanlist_low.append((m, m + 1))
                    else:
                        spanlist_low.append((m - 1, m))

            for m in range(len(high_check)):
                if high_check[m] > 0.5:
                    if m + 1 < len(high_check):
                        spanlist_high.append((m, m + 1))
                    else:
                        spanlist_high.append((m - 1, m))

            # ----------- 인덱스 초기화 됨 -----------#

            # ----------- 공통된 Chart 그리기 -----------#

            plt.subplot(211)
            plt.plot(min_max_scaler(ohlcv_data[:, 1:2]), 'r', label='close')
            plt.plot(scaled_OBV, 'b', label='MA60')
            plt.legend(loc='upper right')
            for i in range(len(spanlist_low)):
                plt.axvspan(spanlist_low[i][0], spanlist_low[i][1], facecolor='m', alpha=0.5)

            plt.subplot(212)
            plt.plot(min_max_scaler(ohlcv_data[:, 1:2]), 'r', label='close')
            plt.plot(scaled_OBV, 'b', label='MA60')
            plt.legend(loc='upper right')
            for i in range(len(spanlist_high)):
                plt.axvspan(spanlist_high[i][0], spanlist_high[i][1], facecolor='c', alpha=0.5)

            Date = file.split()[0]
            Coin = file.split()[1].split('.')[0]
            plt.savefig('./Figure_data/%s_%s/%s %s.png' % (input_data_length, model_num, Date, Coin), dpi=500)
            plt.close()
            # plt.show()
            # ----------- Chart 그리기 -----------#

        return dataX, dataY_low, dataY_high, sliced_ohlcv


if __name__ == '__main__':

    # ----------- Params -----------#
    input_data_length = 54
    model_num = input('Press model number : ')

    #       Make folder      #
    try:
        os.mkdir('./Figure_data/%s_%s/' % (input_data_length, model_num))

    except Exception as e:
        pass
    check_span = 30
    get_fig = 0

    Made_X = []
    Made_Y = []
    Made_Y_low = []
    Made_Y_high = []

    for file in ohlcv_list:

        if int(file.split()[0].split('-')[1]) == 1:
            continue

        # file = '2019-10-27 LAMB ohlcv.xlsx'

        result = made_x(file, input_data_length, model_num, check_span, get_fig)
        # result = low_high('FX', input_data_length)
        # quit()

        # ------------ 데이터가 있으면 dataX, dataY 병합하기 ------------#
        if result is not None:

            Made_X += result[0]
            Made_Y_low += result[1]
            Made_Y_high += result[2]

            # 누적 데이터량 표시
            print(file, len(Made_X))

    # SAVING X, Y
    X = np.array(Made_X)
    Y_low = np.array(Made_Y_low)
    Y_high = np.array(Made_Y_high)

    np.save('./Made_X/Made_X %s_%s' % (input_data_length, model_num), X)
    np.save('./Made_X_low/Made_Y %s_%s' % (input_data_length, model_num), Y_low)
    np.save('./Made_X_high/Made_Y %s_%s' % (input_data_length, model_num), Y_high)
# Out:
# Press model number : 13
# 2019-10-25 FAB ohlcv.xlsx 292
# 2019-11-02 PAY ohlcv.xlsx 491
# 2019-11-13 DVP ohlcv.xlsx 682
# 2019-11-02 IOST ohlcv.xlsx 904
# 2019-10-28 FNB ohlcv.xlsx 1932
# 2019-11-14 QTUM ohlcv.xlsx 2548
# 2019-11-20 LBA ohlcv.xlsx 3157
# 2019-10-30 LTC ohlcv.xlsx 3929
# 2019-10-31 FX ohlcv.xlsx 4345
# 2019-10-16 STRAT ohlcv.xlsx 4648
# 2019-10-26 WTC ohlcv.xlsx 4988
# 2019-10-31 ICX ohlcv.xlsx 5160
# 2019-10-10 CHR ohlcv.xlsx 5405
# 2019-11-15 CTXC ohlcv.xlsx 6514
# 2019-11-01 FX ohlcv.xlsx 6664
# 2019-11-02 CMT ohlcv.xlsx 7101
# 2019-10-27 LBA ohlcv.xlsx 7234
# 2019-10-26 PLY ohlcv.xlsx 8225
# 2019-10-26 BCH ohlcv.xlsx 9521
# 2019-10-22 BSV ohlcv.xlsx 10564
# 2019-10-25 GXC ohlcv.xlsx 10800
# 2019-11-02 LOOM ohlcv.xlsx 11003
# 2019-11-20 CTXC ohlcv.xlsx 11731
# 2019-10-31 BHP ohlcv.xlsx 12461
# 2019-10-30 RNT ohlcv.xlsx 12612
# 2019-10-26 LTC ohlcv.xlsx 13511
# 2019-11-24 VET ohlcv.xlsx 13871
# 2019-10-29 KNC ohlcv.xlsx 13980
# 2019-10-20 ZRX ohlcv.xlsx 14510
# 2019-10-27 POWR ohlcv.xlsx 14611
# 2019-11-15 ITC ohlcv.xlsx 15391
# 2019-11-01 GXC ohlcv.xlsx 15503
# 2019-10-29 LBA ohlcv.xlsx 16039
# 2019-10-21 BTC ohlcv.xlsx 17390
# 2019-10-31 BTC ohlcv.xlsx 18744
# 2019-11-13 PST ohlcv.xlsx 18983
# 2019-10-31 GXC ohlcv.xlsx 19101
# 2019-10-26 QTUM ohlcv.xlsx 19917
# 2019-11-20 WOM ohlcv.xlsx 20128
# 2019-10-29 VET ohlcv.xlsx 20500
# 2019-10-30 CMT ohlcv.xlsx 21385
# 2019-10-16 LOOM ohlcv.xlsx 21790
# 2019-10-30 VET ohlcv.xlsx 22175
# 2019-10-29 BTG ohlcv.xlsx 22457
# 2019-10-30 HYC ohlcv.xlsx 22601
# 2019-11-24 WET ohlcv.xlsx 23051
# 2019-10-16 GXC ohlcv.xlsx 23753
# 2019-10-29 OMG ohlcv.xlsx 24220
# 2019-10-24 ORBS ohlcv.xlsx 24762
# 2019-10-28 MITH ohlcv.xlsx 25159
# 2019-10-17 LOOM ohlcv.xlsx 25370
# 2019-10-24 ETC ohlcv.xlsx 25719
# 2019-10-31 LBA ohlcv.xlsx 26199
# 2019-10-21 INS ohlcv.xlsx 26404
# 2019-11-01 ENJ ohlcv.xlsx 26620
# 2019-10-26 LOOM ohlcv.xlsx 26926
# 2019-10-25 FNB ohlcv.xlsx 27962
# 2019-10-19 FNB ohlcv.xlsx 28571
# 2019-10-19 WAVES ohlcv.xlsx 28818
# 2019-10-25 LAMB ohlcv.xlsx 29204
# 2019-11-13 ABT ohlcv.xlsx 29617
# 2019-10-19 ELF ohlcv.xlsx 29908
# 2019-10-10 ARN ohlcv.xlsx 30221
# 2019-10-28 STRAT ohlcv.xlsx 30470
# 2019-10-26 OMG ohlcv.xlsx 30846
# 2019-10-06 ZIL ohlcv.xlsx 31431
# 2019-10-30 MTL ohlcv.xlsx 32170
# 2019-10-25 OMG ohlcv.xlsx 32434
# 2019-10-06 ITC ohlcv.xlsx 32816
# 2019-10-21 LBA ohlcv.xlsx 32983
# 2019-10-20 TRX ohlcv.xlsx 33346
# 2019-10-29 BCH ohlcv.xlsx 34542
# 2019-10-18 BAT ohlcv.xlsx 34743
# 2019-11-13 WOM ohlcv.xlsx 35060
# 2019-10-31 IOST ohlcv.xlsx 35865
# 2019-10-26 VALOR ohlcv.xlsx 36317
# 2019-10-18 ORBS ohlcv.xlsx 36488
# 2019-11-21 ORBS ohlcv.xlsx 36721
# 2019-10-27 DAC ohlcv.xlsx 37396
# 2019-10-27 LOOM ohlcv.xlsx 37554
# 2019-11-21 REP ohlcv.xlsx 38298
# 2019-10-19 ZRX ohlcv.xlsx 38488
# 2019-10-22 OGO ohlcv.xlsx 39297
# 2019-10-30 WTC ohlcv.xlsx 39554
# 2019-10-28 ICX ohlcv.xlsx 39856
# 2019-10-22 PPT ohlcv.xlsx 40246
# 2019-10-26 XVG ohlcv.xlsx 40382
# 2019-10-15 PPT ohlcv.xlsx 40968
# 2019-10-17 XVG ohlcv.xlsx 41119
# 2019-10-17 XEM ohlcv.xlsx 41486
# 2019-10-30 TRV ohlcv.xlsx 41983
# 2019-11-14 BAT ohlcv.xlsx 42159
# 2019-10-31 BAT ohlcv.xlsx 42302
# 2019-10-28 ELF ohlcv.xlsx 42692
# 2019-10-19 EOS ohlcv.xlsx 43667
# 2019-11-13 IOST ohlcv.xlsx 43790
# 2019-10-21 BAT ohlcv.xlsx 43912
# 2019-10-19 XRP ohlcv.xlsx 44979
# 2019-10-24 OMG ohlcv.xlsx 45302
# 2019-10-22 BAT ohlcv.xlsx 45448
# 2019-10-30 RDN ohlcv.xlsx 45617
# 2019-10-17 ZEC ohlcv.xlsx 45754
# 2019-10-18 ZRX ohlcv.xlsx 46312
# 2019-11-20 FNB ohlcv.xlsx 46770
# 2019-10-27 LAMB ohlcv.xlsx 47417
# 2019-10-29 CHR ohlcv.xlsx 47557
# 2019-10-28 BZNT ohlcv.xlsx 47712
# 2019-10-24 LBA ohlcv.xlsx 48472
# 2019-10-26 RNT ohlcv.xlsx 48622
# 2019-10-27 MTL ohlcv.xlsx 48984
# 2019-10-31 DAC ohlcv.xlsx 49509
# 2019-10-19 BTG ohlcv.xlsx 49853
# 2019-10-29 PAY ohlcv.xlsx 50339
# 2019-10-28 ANKR ohlcv.xlsx 50593
# 2019-11-01 PAY ohlcv.xlsx 50781
# 2019-10-26 ZRX ohlcv.xlsx 51530
# 2019-10-27 XRP ohlcv.xlsx 52814
# 2019-10-28 DASH ohlcv.xlsx 52997
# 2019-10-27 XLM ohlcv.xlsx 53516
# 2019-10-15 ZRX ohlcv.xlsx 54450
# 2019-10-15 XRP ohlcv.xlsx 55695
# 2019-10-27 WAX ohlcv.xlsx 56150
# 2019-10-31 FNB ohlcv.xlsx 56917
# 2019-10-27 OGO ohlcv.xlsx 57174
# 2019-10-28 QTUM ohlcv.xlsx 58391
# 2019-10-27 HDAC ohlcv.xlsx 58573
# 2019-10-14 XRP ohlcv.xlsx 59741
# 2019-11-20 PIVX ohlcv.xlsx 59901
# 2019-10-19 BHP ohlcv.xlsx 60742
# 2019-11-02 OGO ohlcv.xlsx 61271
# 2019-11-02 MIX ohlcv.xlsx 61888
# 2019-10-29 RDN ohlcv.xlsx 62347
# 2019-10-26 ABT ohlcv.xlsx 62536
# 2019-11-01 CTXC ohlcv.xlsx 62638
# 2019-10-14 IOST ohlcv.xlsx 62769
# 2019-10-19 DVP ohlcv.xlsx 63106
# 2019-10-27 HC ohlcv.xlsx 63358
# 2019-11-20 XVG ohlcv.xlsx 63526
# 2019-10-31 DAD ohlcv-Jayone.xlsx 64335
# 2019-10-22 BCH ohlcv.xlsx 65270
# 2019-10-27 ETC ohlcv.xlsx 65592
# 2019-10-19 RNT ohlcv.xlsx 65911
# 2019-11-01 MIX ohlcv.xlsx 66353
# 2019-10-26 DAC ohlcv.xlsx 67265
# 2019-10-28 ETH ohlcv.xlsx 68556
# 2019-10-16 LAMB ohlcv.xlsx 69122
# 2019-10-27 QTUM ohlcv.xlsx 69819
# 2019-10-29 INS ohlcv.xlsx 70131
# 2019-11-21 STRAT ohlcv.xlsx 70369
# 2019-10-26 DASH ohlcv.xlsx 70651
# 2019-10-27 OMG ohlcv.xlsx 70819
# 2019-10-27 ZRX ohlcv.xlsx 71276
# 2019-10-31 ORBS ohlcv.xlsx 71379
# 2019-10-08 ZRX ohlcv.xlsx 71702
# 2019-10-16 XMR ohlcv.xlsx 71938
# 2019-11-01 ITC ohlcv.xlsx 72211
# 2019-10-19 ENJ ohlcv.xlsx 72461
# 2019-10-30 WAX ohlcv.xlsx 72602
# 2019-10-30 ADA ohlcv.xlsx 73245
# 2019-10-30 HC ohlcv.xlsx 73494
# 2019-10-05 TMTG ohlcv.xlsx 74320
# 2019-10-26 BTC ohlcv.xlsx 75674
# 2019-10-26 BTG ohlcv.xlsx 76139
# 2019-10-27 ETHOS ohlcv.xlsx 76254
# 2019-10-30 DAD ohlcv.xlsx 76576
# 2019-10-31 WTC ohlcv.xlsx 76856
# 2019-10-09 PIVX ohlcv.xlsx 77396
# 2019-10-19 QTUM ohlcv.xlsx 77600
# 2019-11-17 MITH ohlcv.xlsx 77744
# 2019-10-27 REP ohlcv.xlsx 77966
# 2019-11-24 BAT ohlcv.xlsx 78179
# 2019-10-30 XLM ohlcv.xlsx 78736
# 2019-10-26 ZEC ohlcv.xlsx 78900
# 2019-10-30 ELF ohlcv.xlsx 79062
# 2019-11-01 LINK ohlcv.xlsx 79626
# 2019-10-07 XRP ohlcv.xlsx 80838
# 2019-10-18 XLM ohlcv.xlsx 81277
# 2019-10-24 LAMB ohlcv.xlsx 81621
# 2019-10-19 FAB ohlcv.xlsx 81801
# 2019-11-13 SALT ohlcv.xlsx 81983
# 2019-11-02 PPT ohlcv.xlsx 82169
# 2019-11-24 BSV ohlcv.xlsx 82885
# 2019-10-19 BCD ohlcv.xlsx 82993
# 2019-10-28 XMR ohlcv.xlsx 83117
# 2019-11-01 BHP ohlcv.xlsx 83481
# 2019-10-19 HDAC ohlcv.xlsx 83631
# 2019-11-21 WOM ohlcv.xlsx 83908
# 2019-10-26 PAY ohlcv.xlsx 84351
# 2019-10-30 FNB ohlcv.xlsx 85277
# 2019-10-26 BCD ohlcv.xlsx 85930
# 2019-10-14 HYC ohlcv.xlsx 86884
# 2019-11-01 RNT ohlcv.xlsx 87229
# 2019-10-29 ETHOS ohlcv.xlsx 87413
# 2019-10-27 KNC ohlcv.xlsx 87513
# 2019-10-16 ANKR ohlcv.xlsx 88077
# 2019-10-31 FZZ ohlcv.xlsx 88563
# 2019-10-28 STEEM ohlcv.xlsx 88827
# 2019-10-19 MIX ohlcv.xlsx 89595
# 2019-10-14 PPT ohlcv.xlsx 90174
# 2019-10-29 BZNT ohlcv.xlsx 90322
# 2019-11-15 ABT ohlcv.xlsx 90502
# 2019-10-09 LINK ohlcv.xlsx 91563
# 2019-10-29 QTUM ohlcv.xlsx 92676
# 2019-10-27 CHR ohlcv.xlsx 92910
# 2019-10-26 OGO ohlcv.xlsx 93102
# 2019-10-30 OGO ohlcv.xlsx 93517
# 2019-11-16 XVG ohlcv.xlsx 94274
# 2019-11-01 LAMB ohlcv.xlsx 95272
# 2019-10-09 PPT ohlcv.xlsx 96029
# 2019-10-22 FZZ ohlcv.xlsx 96229
# 2019-11-26 FCT ohlcv.xlsx 96584
# 2019-10-20 INS ohlcv.xlsx 96878
# 2019-10-31 LAMB ohlcv.xlsx 97588
# 2019-10-18 CON ohlcv.xlsx 98691
# 2019-10-30 ICX ohlcv.xlsx 98850
# 2019-10-28 XLM ohlcv.xlsx 99633
# 2019-10-18 XRP ohlcv.xlsx 100867
# 2019-10-26 HC ohlcv.xlsx 101177
# 2019-10-29 LOOM ohlcv.xlsx 101571
# 2019-10-19 PAY ohlcv.xlsx 101737
# 2019-10-05 LAMB ohlcv.xlsx 102606
# 2019-10-31 MITH ohlcv.xlsx 102888
# 2019-11-26 WOM ohlcv.xlsx 103038
# 2019-10-29 THETA ohlcv.xlsx 103193
# 2019-11-12 HDAC ohlcv.xlsx 103579
# 2019-10-17 CMT ohlcv.xlsx 103777
# 2019-10-19 ETC ohlcv.xlsx 103927
# 2019-10-25 PPT ohlcv.xlsx 104431
# 2019-10-28 ZEC ohlcv.xlsx 104650
# 2019-11-02 XLM ohlcv.xlsx 105576
# 2019-10-24 SNT ohlcv.xlsx 105693
# 2019-10-28 VALOR ohlcv.xlsx 105828
# 2019-11-13 VET ohlcv.xlsx 106510
# 2019-10-29 XMR ohlcv.xlsx 106670
# 2019-10-29 FAB ohlcv.xlsx 106805
# 2019-11-12 WET ohlcv.xlsx 106928
# 2019-10-15 INS ohlcv.xlsx 107040
# 2019-10-30 LAMB ohlcv.xlsx 107886
# 2019-10-29 MIX ohlcv.xlsx 108538
# 2019-10-27 CON ohlcv.xlsx 109604
# 2019-11-20 REP ohlcv.xlsx 110263
# 2019-11-24 HDAC ohlcv.xlsx 110594
# 2019-10-18 LINK ohlcv.xlsx 111332
# 2019-10-27 FX ohlcv.xlsx 111596
# 2019-10-15 FAB ohlcv.xlsx 112267
# 2019-10-26 ETC ohlcv.xlsx 112942
# 2019-10-05 FAB ohlcv.xlsx 113153
# 2019-10-27 BCD ohlcv.xlsx 113529
# 2019-10-30 IOST ohlcv.xlsx 113927
# 2019-10-31 CMT ohlcv.xlsx 114852
# 2019-11-01 DAD ohlcv.xlsx 115816
# 2019-11-02 MXC ohlcv.xlsx 116073
# 2019-10-26 GTO ohlcv.xlsx 116234
# 2019-10-19 LTC ohlcv.xlsx 116561
# 2019-10-15 XLM ohlcv.xlsx 117105
# 2019-10-29 ENJ ohlcv.xlsx 117439
# 2019-10-28 BCH ohlcv.xlsx 118670
# 2019-11-02 LAMB ohlcv.xlsx 119947
# 2019-11-01 WTC ohlcv.xlsx 120222
# 2019-10-31 LINK ohlcv.xlsx 120562
# 2019-11-13 HDAC ohlcv.xlsx 121123
# 2019-10-19 LOOM ohlcv.xlsx 121300
# 2019-11-02 ZRX ohlcv.xlsx 121755
# 2019-10-20 DVP ohlcv.xlsx 122395
# 2019-10-26 ITC ohlcv.xlsx 123067
# 2019-10-28 LRC ohlcv.xlsx 123276
# 2019-11-20 GXC ohlcv.xlsx 123462
# 2019-10-31 POWR ohlcv.xlsx 123733
# 2019-10-14 ZRX ohlcv.xlsx 124321
# 2019-10-10 ETC ohlcv.xlsx 125038
# 2019-11-18 MIX ohlcv.xlsx 125918
# 2019-10-30 ETC ohlcv.xlsx 126419
# 2019-10-15 WAVES ohlcv.xlsx 126816
# 2019-10-28 KNC ohlcv.xlsx 127070
# 2019-11-02 ITC ohlcv.xlsx 127256
# 2019-10-28 IOST ohlcv.xlsx 127436
# 2019-10-21 PST ohlcv.xlsx 127943
# 2019-10-30 MIX ohlcv.xlsx 128357
# 2019-10-26 ETZ ohlcv.xlsx 128971
# 2019-10-15 TRUE ohlcv.xlsx 129173
# 2019-11-14 LINK ohlcv.xlsx 130015
# 2019-10-19 PLY ohlcv.xlsx 130722
# 2019-11-01 CON ohlcv.xlsx 131789
# 2019-11-13 WET ohlcv.xlsx 132028
# 2019-11-18 IOST ohlcv.xlsx 132804
# 2019-10-12 VALOR ohlcv.xlsx 132957
# 2019-10-27 WET ohlcv.xlsx 133143
# 2019-10-21 OGO ohlcv.xlsx 133566
# 2019-10-18 HYC ohlcv.xlsx 133746
# 2019-11-12 PIVX ohlcv.xlsx 133874
# 2019-10-12 FAB ohlcv.xlsx 134202
# 2019-10-16 FX ohlcv.xlsx 134378
# 2019-10-24 FNB ohlcv.xlsx 135554
# 2019-11-21 CON ohlcv.xlsx 136658
# 2019-10-26 LINK ohlcv.xlsx 137448
# 2019-11-20 ZIL ohlcv.xlsx 138132
# 2019-11-14 OGO ohlcv.xlsx 138382
# 2019-10-30 OCN ohlcv.xlsx 138828
# 2019-10-21 BSV ohlcv.xlsx 139645
# 2019-10-31 CTXC ohlcv.xlsx 139769
# 2019-10-16 DAC ohlcv.xlsx 140568
# 2019-10-26 WET ohlcv.xlsx 140840
# 2019-10-25 LINK ohlcv.xlsx 141546
# 2019-10-31 HC ohlcv.xlsx 141663
# 2019-11-01 POWR ohlcv.xlsx 141830
# 2019-10-29 HDAC ohlcv.xlsx 142159
# 2019-10-25 MTL ohlcv.xlsx 142703
# 2019-11-01 BCD ohlcv.xlsx 142861
# 2019-10-31 TRUE ohlcv.xlsx 143024
# 2019-11-02 DAC ohlcv.xlsx 143896
# 2019-11-01 DAC ohlcv.xlsx 144903
# 2019-10-26 ADA ohlcv.xlsx 145806
# 2019-10-24 BSV ohlcv.xlsx 146585
# 2019-10-13 PPT ohlcv.xlsx 147206
# 2019-11-13 LBA ohlcv.xlsx 147377
# 2019-10-26 XMR ohlcv.xlsx 147574
# 2019-10-22 LAMB ohlcv.xlsx 148525
# 2019-10-27 FZZ ohlcv.xlsx 149245
# 2019-10-11 WTC ohlcv.xlsx 149508
# 2019-10-19 INS ohlcv.xlsx 149638
# 2019-10-26 KNC ohlcv.xlsx 149940
# 2019-10-27 TRX ohlcv.xlsx 150618
# 2019-11-18 ADA ohlcv.xlsx 150999
# 2019-10-29 ORBS ohlcv.xlsx 151309
# 2019-11-19 FCT ohlcv.xlsx 151750
# 2019-10-11 LINK ohlcv.xlsx 152696
# 2019-10-26 ETH ohlcv.xlsx 154007
# 2019-10-22 WTC ohlcv.xlsx 154172
# 2019-10-18 MITH ohlcv.xlsx 154289
# 2019-10-29 ETC ohlcv.xlsx 154760
# 2019-10-26 XEM ohlcv.xlsx 155003
# 2019-10-29 AE ohlcv.xlsx 155111
# 2019-11-01 ANKR ohlcv.xlsx 155251
# 2019-11-01 ZRX ohlcv.xlsx 155498
# 2019-10-30 REP ohlcv.xlsx 156224
# 2019-11-02 XEM ohlcv.xlsx 156412
# 2019-11-21 ZRX ohlcv.xlsx 156524
# 2019-11-17 IOST ohlcv.xlsx 156983
# 2019-10-17 FNB ohlcv.xlsx 157769
# 2019-11-02 GXC ohlcv.xlsx 157972
# 2019-11-21 FCT ohlcv.xlsx 158531
# 2019-11-01 LOOM ohlcv.xlsx 158738
# 2019-10-29 POWR ohlcv.xlsx 159064
# 2019-10-29 LINK ohlcv.xlsx 159776
# 2019-10-27 VALOR ohlcv.xlsx 159997
# 2019-10-08 INS ohlcv.xlsx 160332
# 2019-10-29 LAMB ohlcv.xlsx 160974
# 2019-10-27 ETZ ohlcv.xlsx 161235
# 2019-10-26 REP ohlcv.xlsx 161669
# 2019-10-30 WAVES ohlcv.xlsx 162215
# 2019-10-28 MTL ohlcv.xlsx 163116
# 2019-10-29 PLY ohlcv.xlsx 164023
# 2019-10-30 THETA ohlcv.xlsx 164299
# 2019-11-02 MTL ohlcv.xlsx 165192
# 2019-10-26 SNT ohlcv.xlsx 165382
# 2019-10-30 FX ohlcv.xlsx 165752
# 2019-10-24 LINK ohlcv.xlsx 166458
# 2019-11-01 LBA ohlcv.xlsx 167229
# 2019-10-26 INS ohlcv.xlsx 167477
# 2019-10-31 VET ohlcv.xlsx 167768
# 2019-10-24 KNC ohlcv.xlsx 168120
# 2019-10-16 FAB ohlcv.xlsx 168779
# 2019-10-29 DAD ohlcv.xlsx 168927
# 2019-10-31 ENJ ohlcv.xlsx 169029
# 2019-10-30 XRP ohlcv.xlsx 170368
# 2019-10-21 BCH ohlcv.xlsx 171284
# 2019-10-27 LTC ohlcv.xlsx 171841
# 2019-10-24 THETA ohlcv.xlsx 171955
# 2019-11-01 ETZ ohlcv.xlsx 172315
# 2019-10-26 POWR ohlcv.xlsx 172617
# 2019-11-01 ICX ohlcv.xlsx 172807
# 2019-10-21 BCD ohlcv.xlsx 173020
# 2019-11-02 ZIL ohlcv.xlsx 173155
# 2019-11-18 WTC ohlcv.xlsx 173280
# 2019-10-27 ITC ohlcv.xlsx 173503
# 2019-10-30 HDAC ohlcv.xlsx 173628
# 2019-10-27 FNB ohlcv.xlsx 174794
# 2019-10-17 BTG ohlcv.xlsx 175021
# 2019-10-29 HYC ohlcv.xlsx 175266
# 2019-11-21 LBA ohlcv.xlsx 175421
# 2019-11-02 ETZ ohlcv.xlsx 175580
# 2019-11-05 XLM ohlcv.xlsx 176331
# 2019-10-27 VET ohlcv.xlsx 176500
# 2019-10-29 STEEM ohlcv.xlsx 176622
# 2019-10-19 MTL ohlcv.xlsx 176841
# 2019-10-25 ORBS ohlcv.xlsx 177027
# 2019-10-26 VET ohlcv.xlsx 177333
# 2019-10-25 TRX ohlcv.xlsx 177897
# 2019-10-21 DVP ohlcv.xlsx 178613
# 2019-10-22 LOOM ohlcv.xlsx 178805
# 2019-10-26 RDN ohlcv.xlsx 179189
# 2019-10-27 BTG ohlcv.xlsx 179359
# 2019-11-12 FZZ ohlcv.xlsx 180189
# 2019-10-29 DVP ohlcv.xlsx 180847
# 2019-11-15 VET ohlcv.xlsx 181524
# 2019-10-29 ICX ohlcv.xlsx 181640
# 2019-10-28 CON ohlcv.xlsx 182692
# 2019-11-20 ANKR ohlcv.xlsx 182854
# 2019-10-06 DVP ohlcv.xlsx 183352
# 2019-10-18 LBA ohlcv.xlsx 183596
# 2019-10-18 XMR ohlcv.xlsx 184001
# 2019-10-26 BZNT ohlcv.xlsx 184117
# 2019-10-28 SNT ohlcv.xlsx 184308
# 2019-10-28 DAC ohlcv.xlsx 185047
# 2019-10-29 MITH ohlcv-Jayone.xlsx 185223
# 2019-10-15 KNC ohlcv.xlsx 185375
# 2019-10-15 GXC ohlcv.xlsx 185659
# 2019-10-19 REP ohlcv.xlsx 185840
# 2019-11-02 TRV ohlcv.xlsx 186307
# 2019-11-02 CRO ohlcv.xlsx 186441
# 2019-10-14 WAVES ohlcv.xlsx 186704
# 2019-10-06 LINK ohlcv.xlsx 187219
# 2019-10-15 STRAT ohlcv.xlsx 187367
# 2019-10-30 BZNT ohlcv.xlsx 187529
# 2019-10-26 WAVES ohlcv.xlsx 187864
# 2019-10-31 REP ohlcv.xlsx 188177
# 2019-10-30 BCH ohlcv.xlsx 189433
# 2019-10-29 TRX ohlcv.xlsx 190528
# 2019-11-21 ANKR ohlcv.xlsx 190692
# 2019-10-30 BTG ohlcv.xlsx 191016
# 2019-10-27 MIX ohlcv.xlsx 191786
# 2019-10-26 BHP ohlcv.xlsx 192635
# 2019-10-20 BCH ohlcv.xlsx 193232
# 2019-10-19 TRX ohlcv.xlsx 193754
# 2019-10-27 DVP ohlcv.xlsx 194644
# 2019-10-25 DVP ohlcv.xlsx 195250
# 2019-11-12 ABT ohlcv.xlsx 195786
# 2019-10-29 XLM ohlcv.xlsx 196347
# 2019-10-27 RDN ohlcv.xlsx 196501
# 2019-10-21 FNB ohlcv.xlsx 197550
# 2019-10-31 WET ohlcv.xlsx 197667
# 2019-10-17 LAMB ohlcv.xlsx 198190
# 2019-10-29 LTC ohlcv.xlsx 198918
# 2019-10-27 LRC ohlcv.xlsx 199053
# 2019-11-01 PLY ohlcv.xlsx 199751
# 2019-11-12 SALT ohlcv.xlsx 200051
# 2019-10-24 FAB ohlcv.xlsx 200348
# 2019-10-30 MITH ohlcv.xlsx 200583
# 2019-10-26 XRP ohlcv.xlsx 201938
# 2019-10-27 BSV ohlcv.xlsx 203030
# 2019-11-20 WET ohlcv.xlsx 203334
# 2019-10-19 XLM ohlcv.xlsx 203824
# 2019-10-26 ETHOS ohlcv.xlsx 204094
# 2019-11-02 QTUM ohlcv.xlsx 204609
# 2019-10-28 LTC ohlcv.xlsx 205454
# 2019-10-17 HDAC ohlcv.xlsx 206063
# 2019-10-18 XEM ohlcv.xlsx 206785
# 2019-10-26 MITH ohlcv.xlsx 207121
# 2019-11-02 BCH ohlcv.xlsx 208143
# 2019-10-18 KNC ohlcv.xlsx 208299
# 2019-10-19 XEM ohlcv.xlsx 208422
# 2019-10-29 REP ohlcv.xlsx 209129
# 2019-10-22 FX ohlcv.xlsx 209297
# 2019-11-01 CMT ohlcv.xlsx 209741
# 2019-11-20 FAB ohlcv.xlsx 210737
# 2019-10-26 AE ohlcv.xlsx 210883
# 2019-11-01 XLM ohlcv.xlsx 211737
# 2019-10-29 BHP ohlcv.xlsx 212566
# 2019-10-27 WTC ohlcv.xlsx 212701
# 2019-10-30 TRX ohlcv.xlsx 213876
# 2019-10-14 FAB ohlcv.xlsx 214550
# 2019-10-14 BTG ohlcv.xlsx 214796
# 2019-11-02 ANKR ohlcv.xlsx 215095
# 2019-10-30 LBA ohlcv.xlsx 215601
# 2019-10-24 BAT ohlcv.xlsx 216061
# 2019-10-28 WAX ohlcv.xlsx 216458
# 2019-10-25 LBA ohlcv.xlsx 217231
# 2019-11-17 DVP ohlcv.xlsx 217867
# 2019-10-31 TRV ohlcv.xlsx 218706
# 2019-10-19 BSV ohlcv.xlsx 219127
# 2019-10-15 LOOM ohlcv.xlsx 219528
# 2019-11-02 LBA ohlcv.xlsx 220252
# 2019-10-24 MXC ohlcv.xlsx 220439
# 2019-10-28 ETHOS ohlcv.xlsx 220793
# 2019-10-31 ETZ ohlcv.xlsx 221298
# 2019-10-18 LOOM ohlcv.xlsx 221715
# 2019-11-02 ENJ ohlcv.xlsx 221908
# 2019-10-24 ENJ ohlcv.xlsx 222115
# 2019-10-27 EOS ohlcv.xlsx 223297
# 2019-10-21 BTG ohlcv.xlsx 223539
# 2019-10-26 FZZ ohlcv.xlsx 224361
# 2019-10-11 MITH ohlcv.xlsx 224574
# 2019-10-17 FAB ohlcv.xlsx 225234
# 2019-10-26 HDAC ohlcv.xlsx 225573
# 2019-10-27 ETH ohlcv.xlsx 226780
# 2019-10-28 BTC ohlcv.xlsx 228134
# 2019-10-17 XMR ohlcv.xlsx 228614
# 2019-10-30 DVP ohlcv.xlsx 229101
# 2019-10-21 ETC ohlcv.xlsx 229330
# 2019-10-15 BAT ohlcv.xlsx 229718
# 2019-11-15 FAB ohlcv.xlsx 230195
# 2019-11-21 FAB ohlcv.xlsx 231141
# 2019-10-27 LINK ohlcv.xlsx 231596
# 2019-11-13 FCT ohlcv.xlsx 232451
# 2019-10-19 LINK ohlcv.xlsx 232942
# 2019-10-16 BAT ohlcv.xlsx 233472
# 2019-10-07 LINK ohlcv.xlsx 234563
# 2019-10-17 BAT ohlcv.xlsx 234806
# 2019-10-27 INS ohlcv.xlsx 234970
# 2019-11-01 FNB ohlcv.xlsx 235677
# 2019-10-14 MTL ohlcv.xlsx 236117
# 2019-10-27 ADA ohlcv.xlsx 236601
# 2019-11-24 XLM ohlcv.xlsx 237163
# 2019-10-28 BTG ohlcv.xlsx 237484
# 2019-11-20 ENJ ohlcv.xlsx 237742
# 2019-10-26 FAB ohlcv.xlsx 238021
# 2019-10-28 PAY ohlcv.xlsx 238677
# 2019-10-19 XVG ohlcv.xlsx 238851
# 2019-10-28 RNT ohlcv.xlsx 239314
# 2019-10-17 CHR ohlcv.xlsx 239458
# 2019-11-14 KNC ohlcv.xlsx 239631
# 2019-11-18 STRAT ohlcv.xlsx 239848
# 2019-11-21 ENJ ohlcv.xlsx 240303
# 2019-11-12 VET ohlcv.xlsx 240895
# 2019-11-18 FAB ohlcv.xlsx 241279
# 2019-10-27 PIVX ohlcv.xlsx 241500
# 2019-10-17 LBA ohlcv.xlsx 241628
# 2019-11-21 PIVX ohlcv.xlsx 241789
# 2019-10-29 MTL ohlcv.xlsx 242716
# 2019-10-09 ZRX ohlcv.xlsx 243465
# 2019-10-22 LINK ohlcv.xlsx 244321
# 2019-10-31 XVG ohlcv.xlsx 244576
# 2019-10-29 ANKR ohlcv.xlsx 244715
# 2019-10-16 HYC ohlcv.xlsx 245205
# 2019-10-29 IOST ohlcv.xlsx 245366
# 2019-10-28 PLY ohlcv.xlsx 246157
# 2019-10-26 ORBS ohlcv.xlsx 246544
# 2019-10-29 OGO ohlcv.xlsx 247106
# 2019-11-02 DVP ohlcv.xlsx 247960
# 2019-10-15 LBA ohlcv.xlsx 248156
# 2019-10-18 STEEM ohlcv.xlsx 248258
# 2019-10-28 XVG ohlcv.xlsx 248397
# 2019-11-01 WAX ohlcv.xlsx 248501
# 2019-10-27 PAY ohlcv.xlsx 248774
# 2019-11-13 PPT ohlcv.xlsx 248924
# 2019-10-26 BSV ohlcv.xlsx 250118
# 2019-11-14 ABT ohlcv.xlsx 250309
# 2019-10-19 LBA ohlcv.xlsx 250791
# 2019-10-26 FX ohlcv.xlsx 250916
# 2019-10-29 WTC ohlcv.xlsx 251315
# 2019-10-26 MIX ohlcv.xlsx 252036
# 2019-10-08 HDAC ohlcv.xlsx 252682
# 2019-10-28 TRX ohlcv.xlsx 253849
# 2019-11-24 LAMB ohlcv.xlsx 254215
# 2019-10-16 HDAC ohlcv.xlsx 254857
# 2019-10-27 ORBS ohlcv.xlsx 255061
# 2019-10-26 MCO ohlcv.xlsx 255177
# 2019-11-24 ENJ ohlcv.xlsx 255295
# 2019-10-26 LAMB ohlcv.xlsx 255911
# 2019-10-31 STRAT ohlcv.xlsx 256123
# 2019-10-27 PPT ohlcv.xlsx 256917
# 2019-10-09 MCO ohlcv.xlsx 257097
# 2019-10-26 CMT ohlcv.xlsx 257329
# 2019-10-07 VALOR ohlcv.xlsx 257954
# 2019-10-31 HYC ohlcv.xlsx 258076
# 2019-10-31 PAY ohlcv.xlsx 258203
# 2019-10-17 ZRX ohlcv.xlsx 258789
# 2019-11-01 HC ohlcv.xlsx 258974
# 2019-10-26 ICX ohlcv.xlsx 259164
# 2019-10-22 MITH ohlcv.xlsx 259286
# 2019-10-30 EOS ohlcv.xlsx 260501
# 2019-10-19 LAMB ohlcv.xlsx 260851
# 2019-10-16 ARN ohlcv.xlsx 260957
# 2019-10-27 FAB ohlcv.xlsx 261083
# 2019-10-11 STEEM ohlcv.xlsx 261404
# 2019-10-31 MTL ohlcv.xlsx 262136
# 2019-10-28 DVP ohlcv.xlsx 262883
# 2019-10-31 RDN ohlcv.xlsx 263027
# 2019-10-26 LBA ohlcv.xlsx 263292
# 2019-10-26 PIVX ohlcv.xlsx 263823
# 2019-10-29 SNT ohlcv.xlsx 263971
# 2019-10-29 CMT ohlcv.xlsx 264270
# 2019-10-26 BAT ohlcv.xlsx 264553
# 2019-10-26 GXC ohlcv.xlsx 264792
# 2019-10-30 MCO ohlcv.xlsx 264941
# 2019-10-31 PIVX ohlcv.xlsx 265105
# 2019-10-30 OMG ohlcv.xlsx 265544
# 2019-10-28 POWR ohlcv.xlsx 265884
# 2019-10-28 ETC ohlcv.xlsx 266550
# 2019-10-29 LRC ohlcv.xlsx 266732
# 2019-10-27 PLY ohlcv.xlsx 267397
# 2019-10-26 THETA ohlcv.xlsx 267600
# 2019-10-26 STRAT ohlcv.xlsx 267795
# 2019-10-16 BTG ohlcv.xlsx 268017
# 2019-11-13 DAC ohlcv.xlsx 268150
# 2019-11-02 PIVX ohlcv.xlsx 268347
# 2019-10-31 DAD ohlcv.xlsx 268962
# 2019-10-26 POLY ohlcv.xlsx 269136
# 2019-10-26 EOS ohlcv.xlsx 270439
# 2019-10-10 ZRX ohlcv.xlsx 270948
# 2019-11-01 BAT ohlcv.xlsx 271098
# 2019-10-20 LOOM ohlcv.xlsx 271215
# 2019-10-18 FAB ohlcv.xlsx 271494
# 2019-11-21 CTXC ohlcv.xlsx 272450
# 2019-10-22 ENJ ohlcv.xlsx 272607
# 2019-11-15 LAMB ohlcv.xlsx 273132
# 2019-10-21 LAMB ohlcv.xlsx 273726
# 2019-11-01 SNT ohlcv.xlsx 273917
# 2019-10-21 ZRX ohlcv.xlsx 274522
# 2019-10-30 XVG ohlcv.xlsx 274756
# 2019-10-28 XRP ohlcv.xlsx 276110
# 2019-10-27 MITH ohlcv.xlsx 276243
# 2019-10-29 WAVES ohlcv.xlsx 276753
# 2019-11-02 FNB ohlcv.xlsx 277608
# 2019-10-19 BCH ohlcv.xlsx 278316
# 2019-10-30 ORBS ohlcv.xlsx 278505
# 2019-10-25 BSV ohlcv.xlsx 279541
# 2019-11-20 ZRX ohlcv.xlsx 279653
# 2019-11-01 IOST ohlcv.xlsx 280031
# 2019-10-10 TRUE ohlcv.xlsx 280517
# 2019-10-11 TMTG ohlcv.xlsx 281026
# 2019-11-13 FZZ ohlcv.xlsx 282219
# 2019-10-30 TRUE ohlcv.xlsx 282372
# 2019-10-31 BCH ohlcv.xlsx 283610
# 2019-10-31 ZRX ohlcv.xlsx 283866
# 2019-10-14 TMTG ohlcv.xlsx 284292
# 2019-11-02 WTC ohlcv.xlsx 284448
# 2019-10-18 QTUM ohlcv.xlsx 284891
# 2019-11-02 SNT ohlcv.xlsx 285068
# 2019-10-26 FNB ohlcv.xlsx 285915
# 2019-10-30 CTXC ohlcv.xlsx 286076
# 2019-10-15 BTG ohlcv.xlsx 286248
# 2019-10-28 WTC ohlcv.xlsx 286740
# 2019-11-01 STRAT ohlcv.xlsx 286961
# 2019-10-05 CMT ohlcv.xlsx 287212
# 2019-10-12 PPT ohlcv.xlsx 287976
# 2019-10-31 OGO ohlcv.xlsx 288394
# 2019-10-28 OMG ohlcv.xlsx 288930
# 2019-11-13 QTUM ohlcv.xlsx 289377
# 2019-11-18 BAT ohlcv.xlsx 289491
# 2019-11-02 HC ohlcv.xlsx 289788
# 2019-10-19 ETH ohlcv.xlsx 290808
# 2019-10-16 MXC ohlcv.xlsx 290961
# 2019-11-15 FNB ohlcv.xlsx 291320
# 2019-10-29 WAX ohlcv.xlsx 291498
# 2019-11-20 PPT ohlcv.xlsx 291643
# 2019-10-15 TRX ohlcv.xlsx 292139
# 2019-11-01 ZIL ohlcv.xlsx 292287
# 2019-11-24 STRAT ohlcv.xlsx 292387
# 2019-10-26 DVP ohlcv.xlsx 292873
# 2019-10-31 LOOM ohlcv.xlsx 293020
# 2019-11-02 REP ohlcv.xlsx 293546
# 2019-11-02 FX ohlcv.xlsx 294162
# 2019-11-21 ZIL ohlcv.xlsx 294845
# 2019-10-26 ENJ ohlcv.xlsx 295062
# 2019-10-29 TRV ohlcv.xlsx 295322
# 2019-10-19 OMG ohlcv.xlsx 295466
# 2019-10-19 BTC ohlcv.xlsx 296802
# 2019-10-25 KNC ohlcv.xlsx 297163
# 2019-10-27 BCH ohlcv.xlsx 298354
# 2019-10-06 BAT ohlcv.xlsx 298477
# 2019-10-19 KNC ohlcv.xlsx 298651
# 2019-10-26 XLM ohlcv.xlsx 299486
# 2019-11-18 CHR ohlcv.xlsx 299764
# 2019-10-25 MIX ohlcv.xlsx 300416
# 2019-10-24 TRX ohlcv.xlsx 301107
# 2019-11-01 OGO ohlcv.xlsx 301297
# 2019-10-24 MIX ohlcv.xlsx 301799
# 2019-11-17 FX ohlcv.xlsx 302140
# 2019-11-01 CHR ohlcv.xlsx 302349
# 2019-10-19 FX ohlcv.xlsx 302464
# 2019-11-01 MTL ohlcv.xlsx 303104
# 2019-10-16 BSV ohlcv.xlsx 303903
# 2019-10-29 PIVX ohlcv.xlsx 304254
# 2019-11-14 PPT ohlcv.xlsx 304543
# 2019-10-21 LINK ohlcv.xlsx 305368
# 2019-10-31 CHR ohlcv.xlsx 305554
# 2019-10-19 CON ohlcv.xlsx 306703
# 2019-10-21 MTL ohlcv.xlsx 307054
# 2019-10-10 VET ohlcv.xlsx 307307
# 2019-10-30 ETH ohlcv.xlsx 308574
# 2019-10-26 PPT ohlcv.xlsx 309644
# 2019-11-21 PLY ohlcv.xlsx 310686
# 2019-10-16 LRC ohlcv.xlsx 310847
# 2019-10-28 EOS ohlcv.xlsx 312162
# 2019-10-15 MTL ohlcv.xlsx 312679
# 2019-10-14 TRX ohlcv.xlsx 313168
# 2019-10-28 LAMB ohlcv.xlsx 313789
# 2019-10-21 OMG ohlcv.xlsx 314024
# 2019-10-26 HYC ohlcv.xlsx 314299
# 2019-11-20 STRAT ohlcv.xlsx 314506
# 2019-10-29 GXC ohlcv.xlsx 315238
# 2019-11-01 DVP ohlcv.xlsx 316024
# 2019-10-26 ELF ohlcv.xlsx 316194
# 2019-11-02 CHR ohlcv.xlsx 316393
# 2019-10-18 GXC ohlcv.xlsx 316694
# 2019-10-26 MTL ohlcv.xlsx 317409
# 2019-11-02 RNT ohlcv.xlsx 317968
# 2019-10-31 DVP ohlcv.xlsx 318672
# 2019-10-25 DAC ohlcv.xlsx 319738
# 2019-10-26 STEEM ohlcv.xlsx 319840
# 2019-10-29 STRAT ohlcv.xlsx 320142
# 2019-10-11 TRUE ohlcv.xlsx 320735
# 2019-10-20 PST ohlcv.xlsx 320908
# 2019-10-19 PPT ohlcv.xlsx 321055
# 2019-10-17 HYC ohlcv.xlsx 321530
# 2019-10-26 TRX ohlcv.xlsx 322500
# 2019-11-20 FCT ohlcv.xlsx 322967
# 2019-10-27 BHP ohlcv.xlsx 323780
# 2019-11-18 ICX ohlcv.xlsx 324141
# 2019-10-17 LINK ohlcv.xlsx 324887
# 2019-10-17 ORBS ohlcv.xlsx 325067
# 2019-10-29 RNT ohlcv.xlsx 325929
# 2019-10-26 CON ohlcv.xlsx 327017
# 2019-11-17 CTXC ohlcv.xlsx 327889
# 2019-11-15 XVG ohlcv.xlsx 328646
# 2019-10-27 BTC ohlcv.xlsx 330000
# 2019-11-21 WET ohlcv.xlsx 330298
# 2019-10-17 ANKR ohlcv.xlsx 330805
# 2019-10-29 MITH ohlcv.xlsx 330961
