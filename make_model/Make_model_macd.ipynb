# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="2"

import pandas as pd
import numpy as np
from matplotlib import pyplot
import scipy.misc 
from math import sqrt 
import itertools
from IPython.display import display
# %matplotlib inline

input_data_length = 30
model_num = 84
num_classes = 2

Made_X = np.load('Made_X/Made_X %s_%s.npy' % (input_data_length, model_num))
Made_Y = np.load('Made_X/Made_Y %s_%s.npy' % (input_data_length, model_num)).reshape(-1, 1)


#       dataset 분리      #
# dataX 구성 : VOLUME, MA, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC 
# dataX 구성 : VOLUME, EMA1, EMA2, CMO, OBV, RSI, MACD, MACD_SIGNAL, MACD_OSC, MACD_ZERO
Made_X = Made_X[:, :,[9,10,11,12]]
print(Made_X.shape)
print(Made_Y.shape)

row = Made_X.shape[1]
col = Made_X.shape[2]

from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(Made_X, Made_Y, test_size=0.3,
                                                   shuffle=False)

X_train = X_train.astype('float32').reshape(-1, input_data_length, col, 1)
X_val = X_val.astype('float32').reshape(-1, input_data_length, col, 1)
print(X_train.shape)
print(X_val.shape)

from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator 

# Data Class Weight
from sklearn.utils import class_weight

print(Y_train[:, 0])
class_weights = class_weight.compute_class_weight('balanced', 
                                                  np.unique(Y_train[:, 0]),
                                                  Y_train[:, 0])
class_weights = dict(enumerate(class_weights))
# class_weights[1] *= 0.97
# class_weights[2] *= 0.97
print(class_weights)
# quit()

Y_train = Y_train.astype('float32')
Y_val = Y_val.astype('float32')
Y_train = np_utils.to_categorical(Y_train, num_classes)
Y_val = np_utils.to_categorical(Y_val, num_classes)
print(Y_train.shape)
print(Y_val.shape)

datagen = ImageDataGenerator( 
#     rotation_range = 60,
#     zoom_range = 0.6,
#     shear_range = 0.6,
#     horizontal_flip = True,
#     width_shift_range=0.6,
#     height_shift_range=0.6,
    fill_mode = 'nearest'
    )

testgen = ImageDataGenerator( 
    )
datagen.fit(X_train)
batch_size = 128

for X_batch, _ in datagen.flow(X_train, Y_train, batch_size=9):
    for i in range(0, 9): 
        pyplot.axis('off') 
        pyplot.subplot(330 + 1 + i) 
        pyplot.imshow(X_batch[i].reshape(input_data_length, col), cmap=pyplot.get_cmap('gray'))
    pyplot.axis('off') 
    pyplot.show() 
    break
    
    
train_flow = datagen.flow(X_train, Y_train, batch_size=batch_size) 
val_flow = testgen.flow(X_val, Y_val, batch_size=batch_size) 


from keras.utils import plot_model
import keras.backend as K
from keras.models import Model, Sequential
import keras.layers as layers
from keras.optimizers import Adam, SGD
from keras.regularizers import l1, l2
from sklearn.metrics import confusion_matrix

def FER_Model(input_shape=(row, col, 1)):
    # first input model
    visible = layers.Input(shape=input_shape, name='input')
    
    net = layers.Conv2D(64, kernel_size=3, padding='same')(visible)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
    net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_1 = net

    net = layers.Conv2D(128, kernel_size=3, padding='same')(net)
    # net = layers.Activation('relu')(net)
    net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    shortcut_2 = net

#     net = layers.Conv2D(256, kernel_size=3, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

#     shortcut_3 = net

#     net = layers.Conv2D(128, kernel_size=1, padding='same')(net)
#     # net = layers.Activation('relu')(net)
#     net = layers.LeakyReLU()(net)
#     net = layers.MaxPool2D(pool_size=2)(net)

    net = layers.Flatten()(net)
    net = layers.Dense(64)(net)
    net = layers.LeakyReLU()(net)
    net = layers.Dense(num_classes, activation='softmax')(net)

    # create model 
    model = Model(inputs =visible, outputs = net)
    # summary layers
    print(model.summary())
    
    return model

# model = FER_Model()
from keras.models import load_model
model = load_model('model/rapid_ascending %s_%s_macd.hdf5' % (input_data_length, model_num))
opt = Adam(lr=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    
    
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
filepath="model/rapid_ascending %s_%s_macd.hdf5" % (input_data_length, model_num)
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
checkpoint2 = TensorBoard(log_dir='Tensorboard_graph',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
checkpoint3 = EarlyStopping(monitor='val_accuracy', patience=100)
callbacks_list = [checkpoint, checkpoint2, checkpoint3]

# keras.callbacks.Callback 로 부터 log 를 받아와 history log 를 작성할 수 있다.

# we iterate 200 times over the entire training set
num_epochs = 500
history = model.fit_generator(train_flow, 
                    steps_per_epoch=len(X_train) / batch_size, 
                    epochs=num_epochs,  
                    verbose=2,  
                    callbacks=callbacks_list,
                    class_weight=class_weights,
                    validation_data=val_flow,  
                    validation_steps=len(X_val) / batch_size,
                    shuffle=False)
# Out:
# (238688, 30, 4)
# (238688, 1)
# (167081, 30, 4, 1)
# (71607, 30, 4, 1)
# [0. 0. 0. ... 0. 0. 0.]
# {0: 0.5097414087669628, 1: 26.163639210773567}
# (167081, 2)
# (71607, 2)
# Epoch 1/500
#  - 6s - loss: 0.3365 - accuracy: 0.7952 - val_loss: 0.4227 - val_accuracy: 0.8146
#
# Epoch 00001: val_accuracy improved from -inf to 0.81460, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 2/500
#  - 5s - loss: 0.3353 - accuracy: 0.7953 - val_loss: 0.3626 - val_accuracy: 0.8139
#
# Epoch 00002: val_accuracy did not improve from 0.81460
# Epoch 3/500
#  - 5s - loss: 0.3355 - accuracy: 0.7961 - val_loss: 0.5090 - val_accuracy: 0.7818
#
# Epoch 00003: val_accuracy did not improve from 0.81460
# Epoch 4/500
#  - 5s - loss: 0.3342 - accuracy: 0.7958 - val_loss: 0.3200 - val_accuracy: 0.7840
#
# Epoch 00004: val_accuracy did not improve from 0.81460
# Epoch 5/500
#  - 5s - loss: 0.3329 - accuracy: 0.7976 - val_loss: 0.5941 - val_accuracy: 0.7660
#
# Epoch 00005: val_accuracy did not improve from 0.81460
# Epoch 6/500
#  - 5s - loss: 0.3318 - accuracy: 0.7983 - val_loss: 0.3470 - val_accuracy: 0.8036
#
# Epoch 00006: val_accuracy did not improve from 0.81460
# Epoch 7/500
#  - 5s - loss: 0.3300 - accuracy: 0.7991 - val_loss: 0.1768 - val_accuracy: 0.8190
#
# Epoch 00007: val_accuracy improved from 0.81460 to 0.81903, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 8/500
#  - 5s - loss: 0.3305 - accuracy: 0.7982 - val_loss: 0.3039 - val_accuracy: 0.8012
#
# Epoch 00008: val_accuracy did not improve from 0.81903
# Epoch 9/500
#  - 5s - loss: 0.3277 - accuracy: 0.8008 - val_loss: 0.3872 - val_accuracy: 0.8242
#
# Epoch 00009: val_accuracy improved from 0.81903 to 0.82417, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 10/500
#  - 5s - loss: 0.3274 - accuracy: 0.8011 - val_loss: 0.6182 - val_accuracy: 0.7787
#
# Epoch 00010: val_accuracy did not improve from 0.82417
# Epoch 11/500
#  - 5s - loss: 0.3263 - accuracy: 0.8005 - val_loss: 0.3898 - val_accuracy: 0.8252
#
# Epoch 00011: val_accuracy improved from 0.82417 to 0.82523, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 12/500
#  - 5s - loss: 0.3247 - accuracy: 0.8014 - val_loss: 0.3203 - val_accuracy: 0.8056
#
# Epoch 00012: val_accuracy did not improve from 0.82523
# Epoch 13/500
#  - 5s - loss: 0.3252 - accuracy: 0.8025 - val_loss: 0.5590 - val_accuracy: 0.7921
#
# Epoch 00013: val_accuracy did not improve from 0.82523
# Epoch 14/500
#  - 5s - loss: 0.3229 - accuracy: 0.8030 - val_loss: 0.4692 - val_accuracy: 0.8038
#
# Epoch 00014: val_accuracy did not improve from 0.82523
# Epoch 15/500
#  - 5s - loss: 0.3229 - accuracy: 0.8032 - val_loss: 0.3917 - val_accuracy: 0.8197
#
# Epoch 00015: val_accuracy did not improve from 0.82523
# Epoch 16/500
#  - 5s - loss: 0.3213 - accuracy: 0.8032 - val_loss: 0.2996 - val_accuracy: 0.8015
#
# Epoch 00016: val_accuracy did not improve from 0.82523
# Epoch 17/500
#  - 5s - loss: 0.3210 - accuracy: 0.8049 - val_loss: 0.3131 - val_accuracy: 0.8183
#
# Epoch 00017: val_accuracy did not improve from 0.82523
# Epoch 18/500
#  - 5s - loss: 0.3193 - accuracy: 0.8056 - val_loss: 0.4180 - val_accuracy: 0.8178
#
# Epoch 00018: val_accuracy did not improve from 0.82523
# Epoch 19/500
#  - 5s - loss: 0.3183 - accuracy: 0.8062 - val_loss: 0.4802 - val_accuracy: 0.7812
#
# Epoch 00019: val_accuracy did not improve from 0.82523
# Epoch 20/500
#  - 5s - loss: 0.3161 - accuracy: 0.8075 - val_loss: 0.3618 - val_accuracy: 0.8286
#
# Epoch 00020: val_accuracy improved from 0.82523 to 0.82859, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 21/500
#  - 5s - loss: 0.3162 - accuracy: 0.8070 - val_loss: 0.3747 - val_accuracy: 0.8071
#
# Epoch 00021: val_accuracy did not improve from 0.82859
# Epoch 22/500
#  - 5s - loss: 0.3156 - accuracy: 0.8083 - val_loss: 0.4251 - val_accuracy: 0.7805
#
# Epoch 00022: val_accuracy did not improve from 0.82859
# Epoch 23/500
#  - 5s - loss: 0.3144 - accuracy: 0.8094 - val_loss: 0.4428 - val_accuracy: 0.7857
#
# Epoch 00023: val_accuracy did not improve from 0.82859
# Epoch 24/500
#  - 5s - loss: 0.3135 - accuracy: 0.8083 - val_loss: 0.5049 - val_accuracy: 0.7960
#
# Epoch 00024: val_accuracy did not improve from 0.82859
# Epoch 25/500
#  - 5s - loss: 0.3124 - accuracy: 0.8103 - val_loss: 0.6787 - val_accuracy: 0.7837
#
# Epoch 00025: val_accuracy did not improve from 0.82859
# Epoch 26/500
#  - 5s - loss: 0.3105 - accuracy: 0.8101 - val_loss: 0.4649 - val_accuracy: 0.8146
#
# Epoch 00026: val_accuracy did not improve from 0.82859
# Epoch 27/500
#  - 5s - loss: 0.3087 - accuracy: 0.8122 - val_loss: 0.3767 - val_accuracy: 0.7780
#
# Epoch 00027: val_accuracy did not improve from 0.82859
# Epoch 28/500
#  - 5s - loss: 0.3087 - accuracy: 0.8116 - val_loss: 0.3595 - val_accuracy: 0.8129
#
# Epoch 00028: val_accuracy did not improve from 0.82859
# Epoch 29/500
#  - 5s - loss: 0.3088 - accuracy: 0.8111 - val_loss: 0.2325 - val_accuracy: 0.8240
#
# Epoch 00029: val_accuracy did not improve from 0.82859
# Epoch 30/500
#  - 5s - loss: 0.3061 - accuracy: 0.8144 - val_loss: 0.4456 - val_accuracy: 0.8035
#
# Epoch 00030: val_accuracy did not improve from 0.82859
# Epoch 31/500
#  - 5s - loss: 0.3051 - accuracy: 0.8125 - val_loss: 0.2115 - val_accuracy: 0.8250
#
# Epoch 00031: val_accuracy did not improve from 0.82859
# Epoch 32/500
#  - 5s - loss: 0.3045 - accuracy: 0.8145 - val_loss: 0.4289 - val_accuracy: 0.8313
#
# Epoch 00032: val_accuracy improved from 0.82859 to 0.83132, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 33/500
#  - 5s - loss: 0.3026 - accuracy: 0.8150 - val_loss: 0.3240 - val_accuracy: 0.8232
#
# Epoch 00033: val_accuracy did not improve from 0.83132
# Epoch 34/500
#  - 5s - loss: 0.3021 - accuracy: 0.8156 - val_loss: 0.4580 - val_accuracy: 0.7935
#
# Epoch 00034: val_accuracy did not improve from 0.83132
# Epoch 35/500
#  - 5s - loss: 0.3010 - accuracy: 0.8161 - val_loss: 0.2533 - val_accuracy: 0.8135
#
# Epoch 00035: val_accuracy did not improve from 0.83132
# Epoch 36/500
#  - 5s - loss: 0.2997 - accuracy: 0.8175 - val_loss: 0.2140 - val_accuracy: 0.8026
#
# Epoch 00036: val_accuracy did not improve from 0.83132
# Epoch 37/500
#  - 5s - loss: 0.2985 - accuracy: 0.8179 - val_loss: 0.3359 - val_accuracy: 0.7888
#
# Epoch 00037: val_accuracy did not improve from 0.83132
# Epoch 38/500
#  - 5s - loss: 0.2969 - accuracy: 0.8190 - val_loss: 0.3827 - val_accuracy: 0.7980
#
# Epoch 00038: val_accuracy did not improve from 0.83132
# Epoch 39/500
#  - 5s - loss: 0.2962 - accuracy: 0.8191 - val_loss: 0.3522 - val_accuracy: 0.8416
#
# Epoch 00039: val_accuracy improved from 0.83132 to 0.84161, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 40/500
#  - 5s - loss: 0.2964 - accuracy: 0.8189 - val_loss: 0.2581 - val_accuracy: 0.8199
#
# Epoch 00040: val_accuracy did not improve from 0.84161
# Epoch 41/500
#  - 5s - loss: 0.2942 - accuracy: 0.8212 - val_loss: 0.4332 - val_accuracy: 0.8283
#
# Epoch 00041: val_accuracy did not improve from 0.84161
# Epoch 42/500
#  - 5s - loss: 0.2940 - accuracy: 0.8207 - val_loss: 0.3915 - val_accuracy: 0.8168
#
# Epoch 00042: val_accuracy did not improve from 0.84161
# Epoch 43/500
#  - 5s - loss: 0.2913 - accuracy: 0.8219 - val_loss: 0.3733 - val_accuracy: 0.8178
#
# Epoch 00043: val_accuracy did not improve from 0.84161
# Epoch 44/500
#  - 5s - loss: 0.2922 - accuracy: 0.8223 - val_loss: 0.5282 - val_accuracy: 0.8111
#
# Epoch 00044: val_accuracy did not improve from 0.84161
# Epoch 45/500
#  - 5s - loss: 0.2915 - accuracy: 0.8222 - val_loss: 0.3778 - val_accuracy: 0.8049
#
# Epoch 00045: val_accuracy did not improve from 0.84161
# Epoch 46/500
#  - 5s - loss: 0.2907 - accuracy: 0.8228 - val_loss: 0.3315 - val_accuracy: 0.7995
#
# Epoch 00046: val_accuracy did not improve from 0.84161
# Epoch 47/500
#  - 5s - loss: 0.2876 - accuracy: 0.8246 - val_loss: 0.2953 - val_accuracy: 0.8449
#
# Epoch 00047: val_accuracy improved from 0.84161 to 0.84486, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 48/500
#  - 5s - loss: 0.2867 - accuracy: 0.8250 - val_loss: 0.3065 - val_accuracy: 0.8168
#
# Epoch 00048: val_accuracy did not improve from 0.84486
# Epoch 49/500
#  - 5s - loss: 0.2858 - accuracy: 0.8258 - val_loss: 0.2749 - val_accuracy: 0.8273
#
# Epoch 00049: val_accuracy did not improve from 0.84486
# Epoch 50/500
#  - 5s - loss: 0.2849 - accuracy: 0.8277 - val_loss: 0.4165 - val_accuracy: 0.8260
#
# Epoch 00050: val_accuracy did not improve from 0.84486
# Epoch 51/500
#  - 5s - loss: 0.2850 - accuracy: 0.8273 - val_loss: 0.3642 - val_accuracy: 0.8112
#
# Epoch 00051: val_accuracy did not improve from 0.84486
# Epoch 52/500
#  - 5s - loss: 0.2825 - accuracy: 0.8279 - val_loss: 0.2728 - val_accuracy: 0.8456
# Epoch 00052: val_accuracy improved from 0.84486 to 0.84563, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 53/500
#  - 5s - loss: 0.2815 - accuracy: 0.8292 - val_loss: 0.2828 - val_accuracy: 0.8446
#
# Epoch 00053: val_accuracy did not improve from 0.84563
# Epoch 54/500
#  - 5s - loss: 0.2814 - accuracy: 0.8293 - val_loss: 0.4353 - val_accuracy: 0.8118
#
# Epoch 00054: val_accuracy did not improve from 0.84563
# Epoch 55/500
#  - 5s - loss: 0.2791 - accuracy: 0.8306 - val_loss: 0.3139 - val_accuracy: 0.8209
#
# Epoch 00055: val_accuracy did not improve from 0.84563
# Epoch 56/500
#  - 5s - loss: 0.2788 - accuracy: 0.8305 - val_loss: 0.4943 - val_accuracy: 0.7993
#
# Epoch 00056: val_accuracy did not improve from 0.84563
# Epoch 57/500
#  - 5s - loss: 0.2790 - accuracy: 0.8303 - val_loss: 0.2739 - val_accuracy: 0.8354
#
# Epoch 00057: val_accuracy did not improve from 0.84563
# Epoch 58/500
#  - 5s - loss: 0.2761 - accuracy: 0.8320 - val_loss: 0.3781 - val_accuracy: 0.8492
#
# Epoch 00058: val_accuracy improved from 0.84563 to 0.84922, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 59/500
#  - 5s - loss: 0.2745 - accuracy: 0.8329 - val_loss: 0.3845 - val_accuracy: 0.8451
#
# Epoch 00059: val_accuracy did not improve from 0.84922
# Epoch 60/500
#  - 5s - loss: 0.2755 - accuracy: 0.8333 - val_loss: 0.2036 - val_accuracy: 0.8074
#
# Epoch 00060: val_accuracy did not improve from 0.84922
# Epoch 61/500
#  - 5s - loss: 0.2736 - accuracy: 0.8341 - val_loss: 0.6111 - val_accuracy: 0.8296
#
# Epoch 00061: val_accuracy did not improve from 0.84922
# Epoch 62/500
#  - 5s - loss: 0.2712 - accuracy: 0.8357 - val_loss: 0.2744 - val_accuracy: 0.8223
#
# Epoch 00062: val_accuracy did not improve from 0.84922
# Epoch 63/500
#  - 5s - loss: 0.2718 - accuracy: 0.8358 - val_loss: 0.2893 - val_accuracy: 0.8249
#
# Epoch 00063: val_accuracy did not improve from 0.84922
# Epoch 64/500
#  - 5s - loss: 0.2710 - accuracy: 0.8363 - val_loss: 0.1962 - val_accuracy: 0.8249
#
# Epoch 00064: val_accuracy did not improve from 0.84922
# Epoch 65/500
#  - 5s - loss: 0.2685 - accuracy: 0.8367 - val_loss: 0.2143 - val_accuracy: 0.8261
#
# Epoch 00065: val_accuracy did not improve from 0.84922
# Epoch 66/500
#  - 5s - loss: 0.2679 - accuracy: 0.8379 - val_loss: 0.2265 - val_accuracy: 0.8524
#
# Epoch 00066: val_accuracy improved from 0.84922 to 0.85240, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 67/500
#  - 5s - loss: 0.2663 - accuracy: 0.8391 - val_loss: 0.3233 - val_accuracy: 0.8323
#
# Epoch 00067: val_accuracy did not improve from 0.85240
# Epoch 68/500
#  - 5s - loss: 0.2661 - accuracy: 0.8387 - val_loss: 0.2921 - val_accuracy: 0.8264
#
# Epoch 00068: val_accuracy did not improve from 0.85240
# Epoch 69/500
#  - 5s - loss: 0.2649 - accuracy: 0.8393 - val_loss: 0.2004 - val_accuracy: 0.8465
#
# Epoch 00069: val_accuracy did not improve from 0.85240
# Epoch 70/500
#  - 5s - loss: 0.2637 - accuracy: 0.8412 - val_loss: 0.4182 - val_accuracy: 0.8339
#
# Epoch 00070: val_accuracy did not improve from 0.85240
# Epoch 71/500
#  - 5s - loss: 0.2638 - accuracy: 0.8412 - val_loss: 0.4661 - val_accuracy: 0.8222
#
# Epoch 00071: val_accuracy did not improve from 0.85240
# Epoch 72/500
#  - 5s - loss: 0.2613 - accuracy: 0.8421 - val_loss: 0.3551 - val_accuracy: 0.8403
#
# Epoch 00072: val_accuracy did not improve from 0.85240
# Epoch 73/500
#  - 5s - loss: 0.2608 - accuracy: 0.8425 - val_loss: 0.4212 - val_accuracy: 0.8496
#
# Epoch 00073: val_accuracy did not improve from 0.85240
# Epoch 74/500
#  - 5s - loss: 0.2598 - accuracy: 0.8434 - val_loss: 0.1508 - val_accuracy: 0.8422
#
# Epoch 00074: val_accuracy did not improve from 0.85240
# Epoch 75/500
#  - 5s - loss: 0.2588 - accuracy: 0.8439 - val_loss: 0.2694 - val_accuracy: 0.8493
#
# Epoch 00075: val_accuracy did not improve from 0.85240
# Epoch 76/500
#  - 5s - loss: 0.2583 - accuracy: 0.8440 - val_loss: 0.3756 - val_accuracy: 0.8405
#
# Epoch 00076: val_accuracy did not improve from 0.85240
# Epoch 77/500
#  - 5s - loss: 0.2574 - accuracy: 0.8453 - val_loss: 0.1963 - val_accuracy: 0.8497
#
# Epoch 00077: val_accuracy did not improve from 0.85240
# Epoch 78/500
#  - 5s - loss: 0.2560 - accuracy: 0.8463 - val_loss: 0.3064 - val_accuracy: 0.8338
#
# Epoch 00078: val_accuracy did not improve from 0.85240
# Epoch 79/500
#  - 5s - loss: 0.2544 - accuracy: 0.8474 - val_loss: 0.4090 - val_accuracy: 0.8242
#
# Epoch 00079: val_accuracy did not improve from 0.85240
# Epoch 80/500
#  - 5s - loss: 0.2552 - accuracy: 0.8458 - val_loss: 0.3286 - val_accuracy: 0.8414
#
# Epoch 00080: val_accuracy did not improve from 0.85240
# Epoch 81/500
#  - 5s - loss: 0.2543 - accuracy: 0.8467 - val_loss: 0.2929 - val_accuracy: 0.8618
#
# Epoch 00081: val_accuracy improved from 0.85240 to 0.86179, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 82/500
#  - 5s - loss: 0.2516 - accuracy: 0.8485 - val_loss: 0.3644 - val_accuracy: 0.8102
#
# Epoch 00082: val_accuracy did not improve from 0.86179
# Epoch 83/500
#  - 5s - loss: 0.2509 - accuracy: 0.8490 - val_loss: 0.2981 - val_accuracy: 0.8461
#
# Epoch 00083: val_accuracy did not improve from 0.86179
# Epoch 84/500
#  - 5s - loss: 0.2500 - accuracy: 0.8498 - val_loss: 0.4817 - val_accuracy: 0.8286
#
# Epoch 00084: val_accuracy did not improve from 0.86179
# Epoch 85/500
#  - 5s - loss: 0.2500 - accuracy: 0.8497 - val_loss: 0.3650 - val_accuracy: 0.8404
#
# Epoch 00085: val_accuracy did not improve from 0.86179
# Epoch 86/500
#  - 5s - loss: 0.2482 - accuracy: 0.8504 - val_loss: 0.2431 - val_accuracy: 0.8356
#
# Epoch 00086: val_accuracy did not improve from 0.86179
# Epoch 87/500
#  - 5s - loss: 0.2478 - accuracy: 0.8504 - val_loss: 0.2645 - val_accuracy: 0.8546
#
# Epoch 00087: val_accuracy did not improve from 0.86179
# Epoch 88/500
#  - 5s - loss: 0.2456 - accuracy: 0.8521 - val_loss: 0.2244 - val_accuracy: 0.8547
#
# Epoch 00088: val_accuracy did not improve from 0.86179
# Epoch 89/500
#  - 5s - loss: 0.2460 - accuracy: 0.8519 - val_loss: 0.3112 - val_accuracy: 0.8632
#
# Epoch 00089: val_accuracy improved from 0.86179 to 0.86318, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 90/500
#  - 5s - loss: 0.2446 - accuracy: 0.8537 - val_loss: 0.3004 - val_accuracy: 0.8470
#
# Epoch 00090: val_accuracy did not improve from 0.86318
# Epoch 91/500
#  - 5s - loss: 0.2445 - accuracy: 0.8536 - val_loss: 0.2469 - val_accuracy: 0.8577
#
# Epoch 00091: val_accuracy did not improve from 0.86318
# Epoch 92/500
#  - 5s - loss: 0.2438 - accuracy: 0.8541 - val_loss: 0.4138 - val_accuracy: 0.8577
#
# Epoch 00092: val_accuracy did not improve from 0.86318
# Epoch 93/500
#  - 5s - loss: 0.2412 - accuracy: 0.8550 - val_loss: 0.2954 - val_accuracy: 0.8480
#
# Epoch 00093: val_accuracy did not improve from 0.86318
# Epoch 94/500
#  - 5s - loss: 0.2417 - accuracy: 0.8552 - val_loss: 0.3741 - val_accuracy: 0.8440
#
# Epoch 00094: val_accuracy did not improve from 0.86318
# Epoch 95/500
#  - 5s - loss: 0.2393 - accuracy: 0.8556 - val_loss: 0.3973 - val_accuracy: 0.8541
#
# Epoch 00095: val_accuracy did not improve from 0.86318
# Epoch 96/500
#  - 5s - loss: 0.2380 - accuracy: 0.8580 - val_loss: 0.4492 - val_accuracy: 0.8289
#
# Epoch 00096: val_accuracy did not improve from 0.86318
# Epoch 97/500
#  - 5s - loss: 0.2380 - accuracy: 0.8570 - val_loss: 0.2013 - val_accuracy: 0.8389
#
# Epoch 00097: val_accuracy did not improve from 0.86318
# Epoch 98/500
#  - 5s - loss: 0.2365 - accuracy: 0.8587 - val_loss: 0.3336 - val_accuracy: 0.8442
#
# Epoch 00098: val_accuracy did not improve from 0.86318
# Epoch 99/500
#  - 5s - loss: 0.2365 - accuracy: 0.8581 - val_loss: 0.3199 - val_accuracy: 0.8238
#
# Epoch 00099: val_accuracy did not improve from 0.86318
# Epoch 100/500
#  - 5s - loss: 0.2374 - accuracy: 0.8582 - val_loss: 0.3729 - val_accuracy: 0.8556
#
# Epoch 00100: val_accuracy did not improve from 0.86318
# Epoch 101/500
#  - 5s - loss: 0.2354 - accuracy: 0.8596 - val_loss: 0.4465 - val_accuracy: 0.8439
#
# Epoch 00101: val_accuracy did not improve from 0.86318
# Epoch 102/500
#  - 5s - loss: 0.2342 - accuracy: 0.8596 - val_loss: 0.4413 - val_accuracy: 0.8339
#
# Epoch 00102: val_accuracy did not improve from 0.86318
# Epoch 103/500
#  - 5s - loss: 0.2313 - accuracy: 0.8613 - val_loss: 0.3915 - val_accuracy: 0.8625
#
# Epoch 00103: val_accuracy did not improve from 0.86318
# Epoch 104/500
#  - 5s - loss: 0.2310 - accuracy: 0.8614 - val_loss: 0.3104 - val_accuracy: 0.8726
#
# Epoch 00104: val_accuracy improved from 0.86318 to 0.87258, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 105/500
#  - 5s - loss: 0.2314 - accuracy: 0.8617 - val_loss: 0.3088 - val_accuracy: 0.8276
#
# Epoch 00105: val_accuracy did not improve from 0.87258
# Epoch 106/500
#  - 5s - loss: 0.2321 - accuracy: 0.8618 - val_loss: 0.2340 - val_accuracy: 0.8498
#
# Epoch 00106: val_accuracy did not improve from 0.87258
# Epoch 107/500
#  - 5s - loss: 0.2288 - accuracy: 0.8629 - val_loss: 0.3602 - val_accuracy: 0.8717
#
# Epoch 00107: val_accuracy did not improve from 0.87258
# Epoch 108/500
#  - 5s - loss: 0.2289 - accuracy: 0.8631 - val_loss: 0.2082 - val_accuracy: 0.8629
#
# Epoch 00108: val_accuracy did not improve from 0.87258
# Epoch 109/500
#  - 5s - loss: 0.2273 - accuracy: 0.8652 - val_loss: 0.3116 - val_accuracy: 0.8710
#
# Epoch 00109: val_accuracy did not improve from 0.87258
# Epoch 110/500
#  - 5s - loss: 0.2263 - accuracy: 0.8654 - val_loss: 0.1932 - val_accuracy: 0.8446
#
# Epoch 00110: val_accuracy did not improve from 0.87258
# Epoch 111/500
#  - 5s - loss: 0.2246 - accuracy: 0.8659 - val_loss: 0.2436 - val_accuracy: 0.8572
#
# Epoch 00111: val_accuracy did not improve from 0.87258
# Epoch 112/500
#  - 5s - loss: 0.2256 - accuracy: 0.8660 - val_loss: 0.5128 - val_accuracy: 0.8496
#
# Epoch 00112: val_accuracy did not improve from 0.87258
# Epoch 113/500
#  - 5s - loss: 0.2217 - accuracy: 0.8676 - val_loss: 0.2029 - val_accuracy: 0.8686
#
# Epoch 00113: val_accuracy did not improve from 0.87258
# Epoch 114/500
#  - 5s - loss: 0.2241 - accuracy: 0.8670 - val_loss: 0.2096 - val_accuracy: 0.8936
#
# Epoch 00114: val_accuracy improved from 0.87258 to 0.89359, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 115/500
#  - 5s - loss: 0.2224 - accuracy: 0.8677 - val_loss: 0.3774 - val_accuracy: 0.8525
#
# Epoch 00115: val_accuracy did not improve from 0.89359
# Epoch 116/500
#  - 5s - loss: 0.2210 - accuracy: 0.8680 - val_loss: 0.4817 - val_accuracy: 0.8554
#
# Epoch 00116: val_accuracy did not improve from 0.89359
# Epoch 117/500
#  - 5s - loss: 0.2204 - accuracy: 0.8691 - val_loss: 0.2824 - val_accuracy: 0.8583
#
# Epoch 00117: val_accuracy did not improve from 0.89359
# Epoch 118/500
#  - 5s - loss: 0.2202 - accuracy: 0.8691 - val_loss: 0.3821 - val_accuracy: 0.8654
#
# Epoch 00118: val_accuracy did not improve from 0.89359
# Epoch 119/500
#  - 5s - loss: 0.2188 - accuracy: 0.8704 - val_loss: 0.2234 - val_accuracy: 0.8623
#
# Epoch 00119: val_accuracy did not improve from 0.89359
# Epoch 120/500
#  - 5s - loss: 0.2173 - accuracy: 0.8702 - val_loss: 0.1971 - val_accuracy: 0.8599
#
# Epoch 00120: val_accuracy did not improve from 0.89359
# Epoch 121/500
#  - 5s - loss: 0.2173 - accuracy: 0.8714 - val_loss: 0.2094 - val_accuracy: 0.8688
#
# Epoch 00121: val_accuracy did not improve from 0.89359
# Epoch 122/500
#  - 5s - loss: 0.2167 - accuracy: 0.8714 - val_loss: 0.2941 - val_accuracy: 0.8671
#
# Epoch 00122: val_accuracy did not improve from 0.89359
# Epoch 123/500
#  - 5s - loss: 0.2153 - accuracy: 0.8725 - val_loss: 0.2470 - val_accuracy: 0.8674
#
# Epoch 00123: val_accuracy did not improve from 0.89359
# Epoch 124/500
#  - 5s - loss: 0.2156 - accuracy: 0.8723 - val_loss: 0.2169 - val_accuracy: 0.8737
#
# Epoch 00124: val_accuracy did not improve from 0.89359
# Epoch 125/500
#  - 5s - loss: 0.2135 - accuracy: 0.8727 - val_loss: 0.3149 - val_accuracy: 0.8732
#
# Epoch 00125: val_accuracy did not improve from 0.89359
# Epoch 126/500
#  - 5s - loss: 0.2127 - accuracy: 0.8735 - val_loss: 0.3090 - val_accuracy: 0.8635
#
# Epoch 00126: val_accuracy did not improve from 0.89359
# Epoch 127/500
#  - 5s - loss: 0.2119 - accuracy: 0.8744 - val_loss: 0.1857 - val_accuracy: 0.8765
#
# Epoch 00127: val_accuracy did not improve from 0.89359
# Epoch 128/500
#  - 5s - loss: 0.2120 - accuracy: 0.8745 - val_loss: 0.3588 - val_accuracy: 0.8798
#
# Epoch 00128: val_accuracy did not improve from 0.89359
# Epoch 129/500
#  - 5s - loss: 0.2111 - accuracy: 0.8750 - val_loss: 0.1865 - val_accuracy: 0.8742
#
# Epoch 00129: val_accuracy did not improve from 0.89359
# Epoch 130/500
#  - 5s - loss: 0.2097 - accuracy: 0.8752 - val_loss: 0.2798 - val_accuracy: 0.8727
#
# Epoch 00130: val_accuracy did not improve from 0.89359
# Epoch 131/500
#  - 5s - loss: 0.2088 - accuracy: 0.8763 - val_loss: 0.3186 - val_accuracy: 0.8731
#
# Epoch 00131: val_accuracy did not improve from 0.89359
# Epoch 132/500
#  - 5s - loss: 0.2077 - accuracy: 0.8776 - val_loss: 0.3374 - val_accuracy: 0.8390
#
# Epoch 00132: val_accuracy did not improve from 0.89359
# Epoch 133/500
#  - 5s - loss: 0.2090 - accuracy: 0.8769 - val_loss: 0.0645 - val_accuracy: 0.8627
#
# Epoch 00133: val_accuracy did not improve from 0.89359
# Epoch 134/500
#  - 5s - loss: 0.2082 - accuracy: 0.8773 - val_loss: 0.3104 - val_accuracy: 0.8778
#
# Epoch 00134: val_accuracy did not improve from 0.89359
# Epoch 135/500
#  - 5s - loss: 0.2052 - accuracy: 0.8782 - val_loss: 0.2775 - val_accuracy: 0.8879
#
# Epoch 00135: val_accuracy did not improve from 0.89359
# Epoch 136/500
#  - 5s - loss: 0.2041 - accuracy: 0.8795 - val_loss: 0.3139 - val_accuracy: 0.8704
#
# Epoch 00136: val_accuracy did not improve from 0.89359
# Epoch 137/500
#  - 5s - loss: 0.2038 - accuracy: 0.8791 - val_loss: 0.3263 - val_accuracy: 0.8785
#
# Epoch 00137: val_accuracy did not improve from 0.89359
# Epoch 138/500
#  - 5s - loss: 0.2044 - accuracy: 0.8797 - val_loss: 0.1898 - val_accuracy: 0.8545
#
# Epoch 00138: val_accuracy did not improve from 0.89359
# Epoch 139/500
#  - 5s - loss: 0.2029 - accuracy: 0.8800 - val_loss: 0.1958 - val_accuracy: 0.8896
#
# Epoch 00139: val_accuracy did not improve from 0.89359
# Epoch 140/500
#  - 5s - loss: 0.2021 - accuracy: 0.8813 - val_loss: 0.5487 - val_accuracy: 0.8442
#
# Epoch 00140: val_accuracy did not improve from 0.89359
# Epoch 141/500
#  - 5s - loss: 0.2013 - accuracy: 0.8811 - val_loss: 0.3396 - val_accuracy: 0.8665
#
# Epoch 00141: val_accuracy did not improve from 0.89359
# Epoch 142/500
#  - 5s - loss: 0.2003 - accuracy: 0.8826 - val_loss: 0.2071 - val_accuracy: 0.8609
#
# Epoch 00142: val_accuracy did not improve from 0.89359
# Epoch 143/500
#  - 5s - loss: 0.2003 - accuracy: 0.8821 - val_loss: 0.2748 - val_accuracy: 0.8645
#
# Epoch 00143: val_accuracy did not improve from 0.89359
# Epoch 144/500
#  - 5s - loss: 0.1983 - accuracy: 0.8834 - val_loss: 0.2822 - val_accuracy: 0.8584
#
# Epoch 00144: val_accuracy did not improve from 0.89359
# Epoch 145/500
#  - 5s - loss: 0.1989 - accuracy: 0.8834 - val_loss: 0.3012 - val_accuracy: 0.8678
#
# Epoch 00145: val_accuracy did not improve from 0.89359
# Epoch 146/500
#  - 5s - loss: 0.1970 - accuracy: 0.8844 - val_loss: 0.1599 - val_accuracy: 0.8735
#
# Epoch 00146: val_accuracy did not improve from 0.89359
# Epoch 147/500
#  - 5s - loss: 0.1975 - accuracy: 0.8844 - val_loss: 0.3051 - val_accuracy: 0.8726
#
# Epoch 00147: val_accuracy did not improve from 0.89359
# Epoch 148/500
#  - 5s - loss: 0.1952 - accuracy: 0.8852 - val_loss: 0.3364 - val_accuracy: 0.8815
#
# Epoch 00148: val_accuracy did not improve from 0.89359
# Epoch 149/500
#  - 5s - loss: 0.1955 - accuracy: 0.8849 - val_loss: 0.1926 - val_accuracy: 0.8806
#
# Epoch 00149: val_accuracy did not improve from 0.89359
# Epoch 150/500
#  - 5s - loss: 0.1947 - accuracy: 0.8858 - val_loss: 0.1853 - val_accuracy: 0.8588
#
# Epoch 00150: val_accuracy did not improve from 0.89359
# Epoch 151/500
#  - 5s - loss: 0.1934 - accuracy: 0.8866 - val_loss: 0.4731 - val_accuracy: 0.8618
#
# Epoch 00151: val_accuracy did not improve from 0.89359
# Epoch 152/500
#  - 5s - loss: 0.1945 - accuracy: 0.8856 - val_loss: 0.4583 - val_accuracy: 0.8771
#
# Epoch 00152: val_accuracy did not improve from 0.89359
# Epoch 153/500
#  - 5s - loss: 0.1917 - accuracy: 0.8878 - val_loss: 0.2299 - val_accuracy: 0.8740
#
# Epoch 00153: val_accuracy did not improve from 0.89359
# Epoch 154/500
#  - 5s - loss: 0.1929 - accuracy: 0.8877 - val_loss: 0.4565 - val_accuracy: 0.8612
#
# Epoch 00154: val_accuracy did not improve from 0.89359
# Epoch 155/500
#  - 5s - loss: 0.1919 - accuracy: 0.8877 - val_loss: 0.2097 - val_accuracy: 0.8774
#
# Epoch 00155: val_accuracy did not improve from 0.89359
# Epoch 156/500
#  - 5s - loss: 0.1902 - accuracy: 0.8889 - val_loss: 0.2392 - val_accuracy: 0.8735
#
# Epoch 00156: val_accuracy did not improve from 0.89359
# Epoch 157/500
#  - 5s - loss: 0.1886 - accuracy: 0.8896 - val_loss: 0.3108 - val_accuracy: 0.8658
#
# Epoch 00157: val_accuracy did not improve from 0.89359
# Epoch 158/500
#  - 5s - loss: 0.1904 - accuracy: 0.8888 - val_loss: 0.1576 - val_accuracy: 0.8894
# Epoch 00158: val_accuracy did not improve from 0.89359
# Epoch 159/500
#  - 5s - loss: 0.1877 - accuracy: 0.8903 - val_loss: 0.3522 - val_accuracy: 0.8809
#
# Epoch 00159: val_accuracy did not improve from 0.89359
# Epoch 160/500
#  - 5s - loss: 0.1867 - accuracy: 0.8897 - val_loss: 0.2543 - val_accuracy: 0.8919
#
# Epoch 00160: val_accuracy did not improve from 0.89359
# Epoch 161/500
#  - 5s - loss: 0.1865 - accuracy: 0.8916 - val_loss: 0.4562 - val_accuracy: 0.8858
#
# Epoch 00161: val_accuracy did not improve from 0.89359
# Epoch 162/500
#  - 5s - loss: 0.1871 - accuracy: 0.8909 - val_loss: 0.0728 - val_accuracy: 0.8995
#
# Epoch 00162: val_accuracy improved from 0.89359 to 0.89949, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 163/500
#  - 5s - loss: 0.1848 - accuracy: 0.8922 - val_loss: 0.2078 - val_accuracy: 0.8582
#
# Epoch 00163: val_accuracy did not improve from 0.89949
# Epoch 164/500
#  - 5s - loss: 0.1841 - accuracy: 0.8922 - val_loss: 0.2315 - val_accuracy: 0.8806
#
# Epoch 00164: val_accuracy did not improve from 0.89949
# Epoch 165/500
#  - 5s - loss: 0.1846 - accuracy: 0.8920 - val_loss: 0.2584 - val_accuracy: 0.8933
#
# Epoch 00165: val_accuracy did not improve from 0.89949
# Epoch 166/500
#  - 5s - loss: 0.1837 - accuracy: 0.8926 - val_loss: 0.3210 - val_accuracy: 0.8814
#
# Epoch 00166: val_accuracy did not improve from 0.89949
# Epoch 167/500
#  - 5s - loss: 0.1820 - accuracy: 0.8932 - val_loss: 0.3489 - val_accuracy: 0.8905
#
# Epoch 00167: val_accuracy did not improve from 0.89949
# Epoch 168/500
#  - 5s - loss: 0.1828 - accuracy: 0.8933 - val_loss: 0.2151 - val_accuracy: 0.8779
#
# Epoch 00168: val_accuracy did not improve from 0.89949
# Epoch 169/500
#  - 5s - loss: 0.1822 - accuracy: 0.8948 - val_loss: 0.4578 - val_accuracy: 0.8763
#
# Epoch 00169: val_accuracy did not improve from 0.89949
# Epoch 170/500
#  - 5s - loss: 0.1809 - accuracy: 0.8947 - val_loss: 0.1795 - val_accuracy: 0.8791
#
# Epoch 00170: val_accuracy did not improve from 0.89949
# Epoch 171/500
#  - 5s - loss: 0.1795 - accuracy: 0.8952 - val_loss: 0.2270 - val_accuracy: 0.8839
#
# Epoch 00171: val_accuracy did not improve from 0.89949
# Epoch 172/500
#  - 5s - loss: 0.1818 - accuracy: 0.8948 - val_loss: 0.4572 - val_accuracy: 0.8938
#
# Epoch 00172: val_accuracy did not improve from 0.89949
# Epoch 173/500
#  - 5s - loss: 0.1797 - accuracy: 0.8958 - val_loss: 0.2646 - val_accuracy: 0.8907
#
# Epoch 00173: val_accuracy did not improve from 0.89949
# Epoch 174/500
#  - 5s - loss: 0.1774 - accuracy: 0.8966 - val_loss: 0.1213 - val_accuracy: 0.9040
#
# Epoch 00174: val_accuracy improved from 0.89949 to 0.90400, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 175/500
#  - 5s - loss: 0.1785 - accuracy: 0.8960 - val_loss: 0.3160 - val_accuracy: 0.8786
#
# Epoch 00175: val_accuracy did not improve from 0.90400
# Epoch 176/500
#  - 5s - loss: 0.1770 - accuracy: 0.8977 - val_loss: 0.3956 - val_accuracy: 0.8821
#
# Epoch 00176: val_accuracy did not improve from 0.90400
# Epoch 177/500
#  - 5s - loss: 0.1749 - accuracy: 0.8984 - val_loss: 0.1659 - val_accuracy: 0.8913
#
# Epoch 00177: val_accuracy did not improve from 0.90400
# Epoch 178/500
#  - 5s - loss: 0.1755 - accuracy: 0.8982 - val_loss: 0.1943 - val_accuracy: 0.9117
#
# Epoch 00178: val_accuracy improved from 0.90400 to 0.91173, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 179/500
#  - 5s - loss: 0.1738 - accuracy: 0.8991 - val_loss: 0.1237 - val_accuracy: 0.8985
#
# Epoch 00179: val_accuracy did not improve from 0.91173
# Epoch 180/500
#  - 5s - loss: 0.1740 - accuracy: 0.8993 - val_loss: 0.2984 - val_accuracy: 0.8915
#
# Epoch 00180: val_accuracy did not improve from 0.91173
# Epoch 181/500
#  - 5s - loss: 0.1756 - accuracy: 0.8983 - val_loss: 0.3418 - val_accuracy: 0.8911
#
# Epoch 00181: val_accuracy did not improve from 0.91173
# Epoch 182/500
#  - 5s - loss: 0.1727 - accuracy: 0.8998 - val_loss: 0.1956 - val_accuracy: 0.8809
#
# Epoch 00182: val_accuracy did not improve from 0.91173
# Epoch 183/500
#  - 5s - loss: 0.1730 - accuracy: 0.8993 - val_loss: 0.1691 - val_accuracy: 0.8885
#
# Epoch 00183: val_accuracy did not improve from 0.91173
# Epoch 184/500
#  - 5s - loss: 0.1696 - accuracy: 0.9018 - val_loss: 0.2390 - val_accuracy: 0.8904
#
# Epoch 00184: val_accuracy did not improve from 0.91173
# Epoch 185/500
#  - 5s - loss: 0.1717 - accuracy: 0.9005 - val_loss: 0.1590 - val_accuracy: 0.8886
#
# Epoch 00185: val_accuracy did not improve from 0.91173
# Epoch 186/500
#  - 5s - loss: 0.1712 - accuracy: 0.9009 - val_loss: 0.3226 - val_accuracy: 0.8900
#
# Epoch 00186: val_accuracy did not improve from 0.91173
# Epoch 187/500
#  - 5s - loss: 0.1702 - accuracy: 0.9016 - val_loss: 0.1952 - val_accuracy: 0.8894
#
# Epoch 00187: val_accuracy did not improve from 0.91173
# Epoch 188/500
#  - 5s - loss: 0.1695 - accuracy: 0.9020 - val_loss: 0.1736 - val_accuracy: 0.8888
#
# Epoch 00188: val_accuracy did not improve from 0.91173
# Epoch 189/500
#  - 5s - loss: 0.1688 - accuracy: 0.9020 - val_loss: 0.3327 - val_accuracy: 0.9023
#
# Epoch 00189: val_accuracy did not improve from 0.91173
# Epoch 190/500
#  - 5s - loss: 0.1686 - accuracy: 0.9025 - val_loss: 0.1188 - val_accuracy: 0.8889
#
# Epoch 00190: val_accuracy did not improve from 0.91173
# Epoch 191/500
#  - 5s - loss: 0.1686 - accuracy: 0.9030 - val_loss: 0.2403 - val_accuracy: 0.8829
#
# Epoch 00191: val_accuracy did not improve from 0.91173
# Epoch 192/500
#  - 5s - loss: 0.1675 - accuracy: 0.9033 - val_loss: 0.2185 - val_accuracy: 0.9057
#
# Epoch 00192: val_accuracy did not improve from 0.91173
# Epoch 193/500
#  - 5s - loss: 0.1681 - accuracy: 0.9032 - val_loss: 0.2736 - val_accuracy: 0.8928
#
# Epoch 00193: val_accuracy did not improve from 0.91173
# Epoch 194/500
#  - 5s - loss: 0.1663 - accuracy: 0.9043 - val_loss: 0.1365 - val_accuracy: 0.8912
#
# Epoch 00194: val_accuracy did not improve from 0.91173
# Epoch 195/500
#  - 5s - loss: 0.1645 - accuracy: 0.9045 - val_loss: 0.3057 - val_accuracy: 0.8750
#
# Epoch 00195: val_accuracy did not improve from 0.91173
# Epoch 196/500
#  - 5s - loss: 0.1659 - accuracy: 0.9044 - val_loss: 0.0804 - val_accuracy: 0.9007
#
# Epoch 00196: val_accuracy did not improve from 0.91173
# Epoch 197/500
#  - 5s - loss: 0.1626 - accuracy: 0.9056 - val_loss: 0.1991 - val_accuracy: 0.9158
#
# Epoch 00197: val_accuracy improved from 0.91173 to 0.91578, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 198/500
#  - 5s - loss: 0.1643 - accuracy: 0.9057 - val_loss: 0.3191 - val_accuracy: 0.8827
#
# Epoch 00198: val_accuracy did not improve from 0.91578
# Epoch 199/500
#  - 5s - loss: 0.1624 - accuracy: 0.9059 - val_loss: 0.3292 - val_accuracy: 0.8814
#
# Epoch 00199: val_accuracy did not improve from 0.91578
# Epoch 200/500
#  - 5s - loss: 0.1630 - accuracy: 0.9062 - val_loss: 0.2637 - val_accuracy: 0.8834
#
# Epoch 00200: val_accuracy did not improve from 0.91578
# Epoch 201/500
#  - 5s - loss: 0.1621 - accuracy: 0.9072 - val_loss: 0.1036 - val_accuracy: 0.8897
#
# Epoch 00201: val_accuracy did not improve from 0.91578
# Epoch 202/500
#  - 5s - loss: 0.1608 - accuracy: 0.9069 - val_loss: 0.2158 - val_accuracy: 0.9044
#
# Epoch 00202: val_accuracy did not improve from 0.91578
# Epoch 203/500
#  - 5s - loss: 0.1613 - accuracy: 0.9078 - val_loss: 0.1194 - val_accuracy: 0.9037
#
# Epoch 00203: val_accuracy did not improve from 0.91578
# Epoch 204/500
#  - 5s - loss: 0.1621 - accuracy: 0.9069 - val_loss: 0.2702 - val_accuracy: 0.8956
#
# Epoch 00204: val_accuracy did not improve from 0.91578
# Epoch 205/500
#  - 5s - loss: 0.1600 - accuracy: 0.9084 - val_loss: 0.2017 - val_accuracy: 0.8886
#
# Epoch 00205: val_accuracy did not improve from 0.91578
# Epoch 206/500
#  - 5s - loss: 0.1584 - accuracy: 0.9094 - val_loss: 0.3714 - val_accuracy: 0.8863
#
# Epoch 00206: val_accuracy did not improve from 0.91578
# Epoch 207/500
#  - 5s - loss: 0.1583 - accuracy: 0.9090 - val_loss: 0.1581 - val_accuracy: 0.9004
#
# Epoch 00207: val_accuracy did not improve from 0.91578
# Epoch 208/500
#  - 5s - loss: 0.1598 - accuracy: 0.9083 - val_loss: 0.2521 - val_accuracy: 0.9036
#
# Epoch 00208: val_accuracy did not improve from 0.91578
# Epoch 209/500
#  - 5s - loss: 0.1558 - accuracy: 0.9104 - val_loss: 0.0771 - val_accuracy: 0.8996
#
# Epoch 00209: val_accuracy did not improve from 0.91578
# Epoch 210/500
#  - 5s - loss: 0.1575 - accuracy: 0.9098 - val_loss: 0.3457 - val_accuracy: 0.9090
#
# Epoch 00210: val_accuracy did not improve from 0.91578
# Epoch 211/500
#  - 5s - loss: 0.1570 - accuracy: 0.9099 - val_loss: 0.0992 - val_accuracy: 0.9128
#
# Epoch 00211: val_accuracy did not improve from 0.91578
# Epoch 212/500
#  - 5s - loss: 0.1560 - accuracy: 0.9109 - val_loss: 0.4436 - val_accuracy: 0.9021
#
# Epoch 00212: val_accuracy did not improve from 0.91578
# Epoch 213/500
#  - 5s - loss: 0.1555 - accuracy: 0.9104 - val_loss: 0.3483 - val_accuracy: 0.9089
#
# Epoch 00213: val_accuracy did not improve from 0.91578
# Epoch 214/500
#  - 5s - loss: 0.1550 - accuracy: 0.9115 - val_loss: 0.1800 - val_accuracy: 0.9043
#
# Epoch 00214: val_accuracy did not improve from 0.91578
# Epoch 215/500
#  - 5s - loss: 0.1519 - accuracy: 0.9126 - val_loss: 0.3895 - val_accuracy: 0.8993
#
# Epoch 00215: val_accuracy did not improve from 0.91578
# Epoch 216/500
#  - 5s - loss: 0.1522 - accuracy: 0.9125 - val_loss: 0.4392 - val_accuracy: 0.9089
#
# Epoch 00216: val_accuracy did not improve from 0.91578
# Epoch 217/500
#  - 5s - loss: 0.1538 - accuracy: 0.9124 - val_loss: 0.1635 - val_accuracy: 0.9095
#
# Epoch 00217: val_accuracy did not improve from 0.91578
# Epoch 218/500
#  - 5s - loss: 0.1508 - accuracy: 0.9139 - val_loss: 0.2439 - val_accuracy: 0.8979
#
# Epoch 00218: val_accuracy did not improve from 0.91578
# Epoch 219/500
#  - 5s - loss: 0.1517 - accuracy: 0.9136 - val_loss: 0.1172 - val_accuracy: 0.9041
#
# Epoch 00219: val_accuracy did not improve from 0.91578
# Epoch 220/500
#  - 5s - loss: 0.1526 - accuracy: 0.9133 - val_loss: 0.2478 - val_accuracy: 0.9075
#
# Epoch 00220: val_accuracy did not improve from 0.91578
# Epoch 221/500
#  - 5s - loss: 0.1493 - accuracy: 0.9152 - val_loss: 0.2487 - val_accuracy: 0.8998
#
# Epoch 00221: val_accuracy did not improve from 0.91578
# Epoch 222/500
#  - 5s - loss: 0.1509 - accuracy: 0.9142 - val_loss: 0.0784 - val_accuracy: 0.9187
#
# Epoch 00222: val_accuracy improved from 0.91578 to 0.91874, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 223/500
#  - 5s - loss: 0.1494 - accuracy: 0.9147 - val_loss: 0.0442 - val_accuracy: 0.8994
#
# Epoch 00223: val_accuracy did not improve from 0.91874
# Epoch 224/500
#  - 5s - loss: 0.1469 - accuracy: 0.9156 - val_loss: 0.3250 - val_accuracy: 0.8992
#
# Epoch 00224: val_accuracy did not improve from 0.91874
# Epoch 225/500
#  - 5s - loss: 0.1463 - accuracy: 0.9163 - val_loss: 0.0673 - val_accuracy: 0.8971
#
# Epoch 00225: val_accuracy did not improve from 0.91874
# Epoch 226/500
#  - 5s - loss: 0.1489 - accuracy: 0.9156 - val_loss: 0.0754 - val_accuracy: 0.9072
#
# Epoch 00226: val_accuracy did not improve from 0.91874
# Epoch 227/500
#  - 5s - loss: 0.1468 - accuracy: 0.9167 - val_loss: 0.1316 - val_accuracy: 0.9044
#
# Epoch 00227: val_accuracy did not improve from 0.91874
# Epoch 228/500
#  - 5s - loss: 0.1470 - accuracy: 0.9163 - val_loss: 0.1347 - val_accuracy: 0.9031
#
# Epoch 00228: val_accuracy did not improve from 0.91874
# Epoch 229/500
#  - 5s - loss: 0.1455 - accuracy: 0.9166 - val_loss: 0.0798 - val_accuracy: 0.9149
#
# Epoch 00229: val_accuracy did not improve from 0.91874
# Epoch 230/500
#  - 5s - loss: 0.1477 - accuracy: 0.9165 - val_loss: 0.2613 - val_accuracy: 0.9049
#
# Epoch 00230: val_accuracy did not improve from 0.91874
# Epoch 231/500
#  - 5s - loss: 0.1439 - accuracy: 0.9179 - val_loss: 0.6162 - val_accuracy: 0.8918
#
# Epoch 00231: val_accuracy did not improve from 0.91874
# Epoch 232/500
#  - 5s - loss: 0.1467 - accuracy: 0.9169 - val_loss: 0.3214 - val_accuracy: 0.9108
#
# Epoch 00232: val_accuracy did not improve from 0.91874
# Epoch 233/500
#  - 5s - loss: 0.1438 - accuracy: 0.9180 - val_loss: 0.2489 - val_accuracy: 0.8995
#
# Epoch 00233: val_accuracy did not improve from 0.91874
# Epoch 234/500
#  - 5s - loss: 0.1429 - accuracy: 0.9195 - val_loss: 0.1517 - val_accuracy: 0.8979
#
# Epoch 00234: val_accuracy did not improve from 0.91874
# Epoch 235/500
#  - 5s - loss: 0.1426 - accuracy: 0.9193 - val_loss: 0.2193 - val_accuracy: 0.9071
#
# Epoch 00235: val_accuracy did not improve from 0.91874
# Epoch 236/500
#  - 5s - loss: 0.1418 - accuracy: 0.9191 - val_loss: 0.1105 - val_accuracy: 0.9060
#
# Epoch 00236: val_accuracy did not improve from 0.91874
# Epoch 237/500
#  - 5s - loss: 0.1454 - accuracy: 0.9181 - val_loss: 0.1202 - val_accuracy: 0.8927
#
# Epoch 00237: val_accuracy did not improve from 0.91874
# Epoch 238/500
#  - 5s - loss: 0.1400 - accuracy: 0.9207 - val_loss: 0.3985 - val_accuracy: 0.8836
#
# Epoch 00238: val_accuracy did not improve from 0.91874
# Epoch 239/500
#  - 5s - loss: 0.1408 - accuracy: 0.9201 - val_loss: 0.9746 - val_accuracy: 0.9008
#
# Epoch 00239: val_accuracy did not improve from 0.91874
# Epoch 240/500
#  - 5s - loss: 0.1426 - accuracy: 0.9194 - val_loss: 0.1717 - val_accuracy: 0.9141
#
# Epoch 00240: val_accuracy did not improve from 0.91874
# Epoch 241/500
#  - 5s - loss: 0.1390 - accuracy: 0.9209 - val_loss: 0.0847 - val_accuracy: 0.9181
#
# Epoch 00241: val_accuracy did not improve from 0.91874
# Epoch 242/500
#  - 5s - loss: 0.1383 - accuracy: 0.9215 - val_loss: 0.1731 - val_accuracy: 0.9152
#
# Epoch 00242: val_accuracy did not improve from 0.91874
# Epoch 243/500
#  - 5s - loss: 0.1411 - accuracy: 0.9204 - val_loss: 0.1335 - val_accuracy: 0.9098
#
# Epoch 00243: val_accuracy did not improve from 0.91874
# Epoch 244/500
#  - 5s - loss: 0.1390 - accuracy: 0.9217 - val_loss: 0.1718 - val_accuracy: 0.8942
#
# Epoch 00244: val_accuracy did not improve from 0.91874
# Epoch 245/500
#  - 5s - loss: 0.1372 - accuracy: 0.9218 - val_loss: 0.3251 - val_accuracy: 0.9109
#
# Epoch 00245: val_accuracy did not improve from 0.91874
# Epoch 246/500
#  - 5s - loss: 0.1374 - accuracy: 0.9222 - val_loss: 0.0402 - val_accuracy: 0.9066
#
# Epoch 00246: val_accuracy did not improve from 0.91874
# Epoch 247/500
#  - 5s - loss: 0.1382 - accuracy: 0.9219 - val_loss: 0.5005 - val_accuracy: 0.9107
#
# Epoch 00247: val_accuracy did not improve from 0.91874
# Epoch 248/500
#  - 5s - loss: 0.1368 - accuracy: 0.9230 - val_loss: 0.2073 - val_accuracy: 0.9182
#
# Epoch 00248: val_accuracy did not improve from 0.91874
# Epoch 249/500
#  - 5s - loss: 0.1354 - accuracy: 0.9234 - val_loss: 0.2831 - val_accuracy: 0.9166
#
# Epoch 00249: val_accuracy did not improve from 0.91874
# Epoch 250/500
#  - 5s - loss: 0.1359 - accuracy: 0.9235 - val_loss: 0.3755 - val_accuracy: 0.9080
#
# Epoch 00250: val_accuracy did not improve from 0.91874
# Epoch 251/500
#  - 5s - loss: 0.1338 - accuracy: 0.9242 - val_loss: 0.1995 - val_accuracy: 0.9170
#
# Epoch 00251: val_accuracy did not improve from 0.91874
# Epoch 252/500
#  - 5s - loss: 0.1355 - accuracy: 0.9242 - val_loss: 0.0721 - val_accuracy: 0.9043
#
# Epoch 00252: val_accuracy did not improve from 0.91874
# Epoch 253/500
#  - 5s - loss: 0.1333 - accuracy: 0.9247 - val_loss: 0.3039 - val_accuracy: 0.9144
#
# Epoch 00253: val_accuracy did not improve from 0.91874
# Epoch 254/500
#  - 5s - loss: 0.1332 - accuracy: 0.9247 - val_loss: 0.5945 - val_accuracy: 0.8810
#
# Epoch 00254: val_accuracy did not improve from 0.91874
# Epoch 255/500
#  - 5s - loss: 0.1318 - accuracy: 0.9253 - val_loss: 0.2465 - val_accuracy: 0.9119
#
# Epoch 00255: val_accuracy did not improve from 0.91874
# Epoch 256/500
#  - 5s - loss: 0.1321 - accuracy: 0.9254 - val_loss: 0.3841 - val_accuracy: 0.9021
#
# Epoch 00256: val_accuracy did not improve from 0.91874
# Epoch 257/500
#  - 5s - loss: 0.1320 - accuracy: 0.9253 - val_loss: 0.4266 - val_accuracy: 0.9069
#
# Epoch 00257: val_accuracy did not improve from 0.91874
# Epoch 258/500
#  - 5s - loss: 0.1350 - accuracy: 0.9251 - val_loss: 0.4064 - val_accuracy: 0.8879
#
# Epoch 00258: val_accuracy did not improve from 0.91874
# Epoch 259/500
#  - 5s - loss: 0.1316 - accuracy: 0.9259 - val_loss: 0.2710 - val_accuracy: 0.9254
#
# Epoch 00259: val_accuracy improved from 0.91874 to 0.92543, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 260/500
#  - 5s - loss: 0.1315 - accuracy: 0.9262 - val_loss: 0.3047 - val_accuracy: 0.9056
#
# Epoch 00260: val_accuracy did not improve from 0.92543
# Epoch 261/500
#  - 5s - loss: 0.1319 - accuracy: 0.9269 - val_loss: 0.2492 - val_accuracy: 0.9040
#
# Epoch 00261: val_accuracy did not improve from 0.92543
# Epoch 262/500
#  - 5s - loss: 0.1304 - accuracy: 0.9263 - val_loss: 0.2850 - val_accuracy: 0.9124
#
# Epoch 00262: val_accuracy did not improve from 0.92543
# Epoch 263/500
#  - 5s - loss: 0.1285 - accuracy: 0.9280 - val_loss: 0.2245 - val_accuracy: 0.9032
#
# Epoch 00263: val_accuracy did not improve from 0.92543
# Epoch 264/500
#  - 5s - loss: 0.1310 - accuracy: 0.9267 - val_loss: 0.0701 - val_accuracy: 0.9065
# Epoch 00264: val_accuracy did not improve from 0.92543
# Epoch 265/500
#  - 5s - loss: 0.1285 - accuracy: 0.9282 - val_loss: 0.4236 - val_accuracy: 0.9219
#
# Epoch 00265: val_accuracy did not improve from 0.92543
# Epoch 266/500
#  - 5s - loss: 0.1289 - accuracy: 0.9279 - val_loss: 0.1709 - val_accuracy: 0.8970
#
# Epoch 00266: val_accuracy did not improve from 0.92543
# Epoch 267/500
#  - 5s - loss: 0.1269 - accuracy: 0.9287 - val_loss: 0.0805 - val_accuracy: 0.9054
#
# Epoch 00267: val_accuracy did not improve from 0.92543
# Epoch 268/500
#  - 5s - loss: 0.1294 - accuracy: 0.9278 - val_loss: 0.1410 - val_accuracy: 0.9123
#
# Epoch 00268: val_accuracy did not improve from 0.92543
# Epoch 269/500
#  - 5s - loss: 0.1256 - accuracy: 0.9298 - val_loss: 0.1245 - val_accuracy: 0.9275
#
# Epoch 00269: val_accuracy improved from 0.92543 to 0.92753, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 270/500
#  - 5s - loss: 0.1259 - accuracy: 0.9296 - val_loss: 0.0823 - val_accuracy: 0.9174
#
# Epoch 00270: val_accuracy did not improve from 0.92753
# Epoch 271/500
#  - 5s - loss: 0.1277 - accuracy: 0.9289 - val_loss: 0.2789 - val_accuracy: 0.8973
#
# Epoch 00271: val_accuracy did not improve from 0.92753
# Epoch 272/500
#  - 5s - loss: 0.1281 - accuracy: 0.9291 - val_loss: 0.1275 - val_accuracy: 0.9231
#
# Epoch 00272: val_accuracy did not improve from 0.92753
# Epoch 273/500
#  - 5s - loss: 0.1266 - accuracy: 0.9293 - val_loss: 0.1906 - val_accuracy: 0.9147
#
# Epoch 00273: val_accuracy did not improve from 0.92753
# Epoch 274/500
#  - 5s - loss: 0.1230 - accuracy: 0.9306 - val_loss: 0.1344 - val_accuracy: 0.8967
#
# Epoch 00274: val_accuracy did not improve from 0.92753
# Epoch 275/500
#  - 5s - loss: 0.1264 - accuracy: 0.9295 - val_loss: 0.0927 - val_accuracy: 0.9216
#
# Epoch 00275: val_accuracy did not improve from 0.92753
# Epoch 276/500
#  - 5s - loss: 0.1252 - accuracy: 0.9302 - val_loss: 0.0928 - val_accuracy: 0.9208
#
# Epoch 00276: val_accuracy did not improve from 0.92753
# Epoch 277/500
#  - 5s - loss: 0.1246 - accuracy: 0.9308 - val_loss: 0.1467 - val_accuracy: 0.9194
#
# Epoch 00277: val_accuracy did not improve from 0.92753
# Epoch 278/500
#  - 6s - loss: 0.1222 - accuracy: 0.9318 - val_loss: 1.0690 - val_accuracy: 0.9127
#
# Epoch 00278: val_accuracy did not improve from 0.92753
# Epoch 279/500
#  - 5s - loss: 0.1227 - accuracy: 0.9314 - val_loss: 0.1811 - val_accuracy: 0.9181
#
# Epoch 00279: val_accuracy did not improve from 0.92753
# Epoch 280/500
#  - 5s - loss: 0.1235 - accuracy: 0.9314 - val_loss: 0.1406 - val_accuracy: 0.9126
#
# Epoch 00280: val_accuracy did not improve from 0.92753
# Epoch 281/500
#  - 5s - loss: 0.1218 - accuracy: 0.9319 - val_loss: 0.1545 - val_accuracy: 0.9030
#
# Epoch 00281: val_accuracy did not improve from 0.92753
# Epoch 282/500
#  - 5s - loss: 0.1221 - accuracy: 0.9316 - val_loss: 0.3265 - val_accuracy: 0.9241
#
# Epoch 00282: val_accuracy did not improve from 0.92753
# Epoch 283/500
#  - 5s - loss: 0.1201 - accuracy: 0.9328 - val_loss: 0.1183 - val_accuracy: 0.9057
#
# Epoch 00283: val_accuracy did not improve from 0.92753
# Epoch 284/500
#  - 5s - loss: 0.1244 - accuracy: 0.9319 - val_loss: 0.4067 - val_accuracy: 0.9226
#
# Epoch 00284: val_accuracy did not improve from 0.92753
# Epoch 285/500
#  - 5s - loss: 0.1211 - accuracy: 0.9330 - val_loss: 0.3848 - val_accuracy: 0.9172
#
# Epoch 00285: val_accuracy did not improve from 0.92753
# Epoch 286/500
#  - 5s - loss: 0.1210 - accuracy: 0.9327 - val_loss: 0.1008 - val_accuracy: 0.9162
#
# Epoch 00286: val_accuracy did not improve from 0.92753
# Epoch 287/500
#  - 5s - loss: 0.1240 - accuracy: 0.9319 - val_loss: 0.1225 - val_accuracy: 0.9110
#
# Epoch 00287: val_accuracy did not improve from 0.92753
# Epoch 288/500
#  - 6s - loss: 0.1169 - accuracy: 0.9349 - val_loss: 0.3320 - val_accuracy: 0.9277
#
# Epoch 00288: val_accuracy improved from 0.92753 to 0.92766, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 289/500
#  - 5s - loss: 0.1165 - accuracy: 0.9351 - val_loss: 0.6057 - val_accuracy: 0.9213
#
# Epoch 00289: val_accuracy did not improve from 0.92766
# Epoch 290/500
#  - 5s - loss: 0.1194 - accuracy: 0.9338 - val_loss: 0.1648 - val_accuracy: 0.9219
#
# Epoch 00290: val_accuracy did not improve from 0.92766
# Epoch 291/500
#  - 6s - loss: 0.1178 - accuracy: 0.9345 - val_loss: 0.0720 - val_accuracy: 0.9112
#
# Epoch 00291: val_accuracy did not improve from 0.92766
# Epoch 292/500
#  - 6s - loss: 0.1208 - accuracy: 0.9335 - val_loss: 0.3046 - val_accuracy: 0.9142
#
# Epoch 00292: val_accuracy did not improve from 0.92766
# Epoch 293/500
#  - 6s - loss: 0.1151 - accuracy: 0.9360 - val_loss: 0.3503 - val_accuracy: 0.9215
#
# Epoch 00293: val_accuracy did not improve from 0.92766
# Epoch 294/500
#  - 5s - loss: 0.1199 - accuracy: 0.9342 - val_loss: 0.0379 - val_accuracy: 0.9040
#
# Epoch 00294: val_accuracy did not improve from 0.92766
# Epoch 295/500
#  - 6s - loss: 0.1145 - accuracy: 0.9363 - val_loss: 0.1661 - val_accuracy: 0.9372
#
# Epoch 00295: val_accuracy improved from 0.92766 to 0.93720, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 296/500
#  - 6s - loss: 0.1187 - accuracy: 0.9353 - val_loss: 0.2903 - val_accuracy: 0.8999
#
# Epoch 00296: val_accuracy did not improve from 0.93720
# Epoch 297/500
#  - 6s - loss: 0.1180 - accuracy: 0.9354 - val_loss: 0.4971 - val_accuracy: 0.9189
#
# Epoch 00297: val_accuracy did not improve from 0.93720
# Epoch 298/500
#  - 6s - loss: 0.1144 - accuracy: 0.9364 - val_loss: 0.1244 - val_accuracy: 0.9331
#
# Epoch 00298: val_accuracy did not improve from 0.93720
# Epoch 299/500
#  - 5s - loss: 0.1181 - accuracy: 0.9353 - val_loss: 0.0518 - val_accuracy: 0.9208
#
# Epoch 00299: val_accuracy did not improve from 0.93720
# Epoch 300/500
#  - 5s - loss: 0.1134 - accuracy: 0.9371 - val_loss: 0.3809 - val_accuracy: 0.9249
#
# Epoch 00300: val_accuracy did not improve from 0.93720
# Epoch 301/500
#  - 5s - loss: 0.1123 - accuracy: 0.9375 - val_loss: 0.2720 - val_accuracy: 0.9096
#
# Epoch 00301: val_accuracy did not improve from 0.93720
# Epoch 302/500
#  - 6s - loss: 0.1131 - accuracy: 0.9373 - val_loss: 0.2655 - val_accuracy: 0.9189
#
# Epoch 00302: val_accuracy did not improve from 0.93720
# Epoch 303/500
#  - 5s - loss: 0.1141 - accuracy: 0.9366 - val_loss: 0.1044 - val_accuracy: 0.9297
#
# Epoch 00303: val_accuracy did not improve from 0.93720
# Epoch 304/500
#  - 5s - loss: 0.1139 - accuracy: 0.9369 - val_loss: 0.1379 - val_accuracy: 0.9238
#
# Epoch 00304: val_accuracy did not improve from 0.93720
# Epoch 305/500
#  - 6s - loss: 0.1164 - accuracy: 0.9360 - val_loss: 0.1559 - val_accuracy: 0.9267
#
# Epoch 00305: val_accuracy did not improve from 0.93720
# Epoch 306/500
#  - 5s - loss: 0.1112 - accuracy: 0.9381 - val_loss: 0.6047 - val_accuracy: 0.9259
#
# Epoch 00306: val_accuracy did not improve from 0.93720
# Epoch 307/500
# ...
#
# Epoch 00397: val_accuracy did not improve from 0.94246
# Epoch 398/500
#  - 6s - loss: 0.0838 - accuracy: 0.9551 - val_loss: 0.5563 - val_accuracy: 0.9354
#
# Epoch 00398: val_accuracy did not improve from 0.94246
# Epoch 399/500
#  - 6s - loss: 0.0816 - accuracy: 0.9561 - val_loss: 0.1893 - val_accuracy: 0.9270
#
# Epoch 00399: val_accuracy did not improve from 0.94246
# Epoch 400/500
#  - 6s - loss: 0.0884 - accuracy: 0.9534 - val_loss: 0.0904 - val_accuracy: 0.9382
#
# Epoch 00400: val_accuracy did not improve from 0.94246
# Epoch 401/500
#  - 6s - loss: 0.0798 - accuracy: 0.9571 - val_loss: 0.0345 - val_accuracy: 0.9398
#
# Epoch 00401: val_accuracy did not improve from 0.94246
# Epoch 402/500
#  - 6s - loss: 0.0811 - accuracy: 0.9565 - val_loss: 0.2830 - val_accuracy: 0.9377
#
# Epoch 00402: val_accuracy did not improve from 0.94246
# Epoch 403/500
#  - 6s - loss: 0.0863 - accuracy: 0.9550 - val_loss: 0.0258 - val_accuracy: 0.9457
#
# Epoch 00403: val_accuracy improved from 0.94246 to 0.94575, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 404/500
#  - 6s - loss: 0.0809 - accuracy: 0.9566 - val_loss: 0.0887 - val_accuracy: 0.9435
#
# Epoch 00404: val_accuracy did not improve from 0.94575
# Epoch 405/500
#  - 5s - loss: 0.0825 - accuracy: 0.9565 - val_loss: 0.2159 - val_accuracy: 0.9383
#
# Epoch 00405: val_accuracy did not improve from 0.94575
# Epoch 406/500
#  - 6s - loss: 0.0814 - accuracy: 0.9569 - val_loss: 0.1814 - val_accuracy: 0.9331
#
# Epoch 00406: val_accuracy did not improve from 0.94575
# Epoch 407/500
#  - 6s - loss: 0.0830 - accuracy: 0.9560 - val_loss: 0.1667 - val_accuracy: 0.9373
#
# Epoch 00407: val_accuracy did not improve from 0.94575
# Epoch 408/500
#  - 5s - loss: 0.0814 - accuracy: 0.9568 - val_loss: 0.1123 - val_accuracy: 0.9401
#
# Epoch 00408: val_accuracy did not improve from 0.94575
# Epoch 409/500
#  - 6s - loss: 0.0794 - accuracy: 0.9576 - val_loss: 0.2120 - val_accuracy: 0.9125
#
# Epoch 00409: val_accuracy did not improve from 0.94575
# Epoch 410/500
#  - 6s - loss: 0.0860 - accuracy: 0.9547 - val_loss: 0.3942 - val_accuracy: 0.9335
#
# Epoch 00410: val_accuracy did not improve from 0.94575
# Epoch 411/500
#  - 6s - loss: 0.0838 - accuracy: 0.9558 - val_loss: 0.0822 - val_accuracy: 0.9378
#
# Epoch 00411: val_accuracy did not improve from 0.94575
# Epoch 412/500
#  - 6s - loss: 0.0783 - accuracy: 0.9575 - val_loss: 0.2684 - val_accuracy: 0.9392
#
# Epoch 00412: val_accuracy did not improve from 0.94575
# Epoch 413/500
#  - 5s - loss: 0.0821 - accuracy: 0.9572 - val_loss: 0.4553 - val_accuracy: 0.9286
#
# Epoch 00413: val_accuracy did not improve from 0.94575
# Epoch 414/500
#  - 6s - loss: 0.0803 - accuracy: 0.9579 - val_loss: 0.6311 - val_accuracy: 0.9290
#
# Epoch 00414: val_accuracy did not improve from 0.94575
# Epoch 415/500
#  - 6s - loss: 0.0782 - accuracy: 0.9583 - val_loss: 0.2656 - val_accuracy: 0.9435
#
# Epoch 00415: val_accuracy did not improve from 0.94575
# Epoch 416/500
#  - 5s - loss: 0.0812 - accuracy: 0.9570 - val_loss: 0.2019 - val_accuracy: 0.9265
#
# Epoch 00416: val_accuracy did not improve from 0.94575
# Epoch 417/500
#  - 6s - loss: 0.0797 - accuracy: 0.9579 - val_loss: 0.2415 - val_accuracy: 0.9354
#
# Epoch 00417: val_accuracy did not improve from 0.94575
# Epoch 418/500
#  - 6s - loss: 0.0794 - accuracy: 0.9580 - val_loss: 0.2587 - val_accuracy: 0.9359
#
# Epoch 00418: val_accuracy did not improve from 0.94575
# Epoch 419/500
#  - 6s - loss: 0.0787 - accuracy: 0.9580 - val_loss: 0.1486 - val_accuracy: 0.9387
#
# Epoch 00419: val_accuracy did not improve from 0.94575
# Epoch 420/500
#  - 5s - loss: 0.0817 - accuracy: 0.9574 - val_loss: 0.0114 - val_accuracy: 0.9391
#
# Epoch 00420: val_accuracy did not improve from 0.94575
# Epoch 421/500
#  - 6s - loss: 0.0754 - accuracy: 0.9600 - val_loss: 0.4363 - val_accuracy: 0.9402
#
# Epoch 00421: val_accuracy did not improve from 0.94575
# Epoch 422/500
#  - 6s - loss: 0.0768 - accuracy: 0.9593 - val_loss: 0.0910 - val_accuracy: 0.9359
#
# Epoch 00422: val_accuracy did not improve from 0.94575
# Epoch 423/500
#  - 6s - loss: 0.0823 - accuracy: 0.9572 - val_loss: 0.2814 - val_accuracy: 0.9360
#
# Epoch 00423: val_accuracy did not improve from 0.94575
# Epoch 424/500
#  - 6s - loss: 0.0791 - accuracy: 0.9583 - val_loss: 0.3796 - val_accuracy: 0.9256
# Epoch 00424: val_accuracy did not improve from 0.94575
# Epoch 425/500
#  - 5s - loss: 0.0804 - accuracy: 0.9580 - val_loss: 0.2061 - val_accuracy: 0.9394
#
# Epoch 00425: val_accuracy did not improve from 0.94575
# Epoch 426/500
#  - 5s - loss: 0.0758 - accuracy: 0.9595 - val_loss: 0.1245 - val_accuracy: 0.9392
#
# Epoch 00426: val_accuracy did not improve from 0.94575
# Epoch 427/500
#  - 6s - loss: 0.0761 - accuracy: 0.9599 - val_loss: 0.2923 - val_accuracy: 0.9308
#
# Epoch 00427: val_accuracy did not improve from 0.94575
# Epoch 428/500
#  - 5s - loss: 0.0755 - accuracy: 0.9601 - val_loss: 0.1433 - val_accuracy: 0.9274
#
# Epoch 00428: val_accuracy did not improve from 0.94575
# Epoch 429/500
#  - 6s - loss: 0.0785 - accuracy: 0.9586 - val_loss: 0.3165 - val_accuracy: 0.9307
#
# Epoch 00429: val_accuracy did not improve from 0.94575
# Epoch 430/500
#  - 6s - loss: 0.0748 - accuracy: 0.9603 - val_loss: 0.2652 - val_accuracy: 0.9306
#
# Epoch 00430: val_accuracy did not improve from 0.94575
# Epoch 431/500
#  - 6s - loss: 0.0758 - accuracy: 0.9599 - val_loss: 0.2758 - val_accuracy: 0.9273
#
# Epoch 00431: val_accuracy did not improve from 0.94575
# Epoch 432/500
#  - 6s - loss: 0.0790 - accuracy: 0.9589 - val_loss: 0.4034 - val_accuracy: 0.9223
#
# Epoch 00432: val_accuracy did not improve from 0.94575
# Epoch 433/500
#  - 6s - loss: 0.0736 - accuracy: 0.9609 - val_loss: 0.1872 - val_accuracy: 0.9218
#
# Epoch 00433: val_accuracy did not improve from 0.94575
# Epoch 434/500
#  - 6s - loss: 0.0747 - accuracy: 0.9605 - val_loss: 0.1181 - val_accuracy: 0.9386
#
# Epoch 00434: val_accuracy did not improve from 0.94575
# Epoch 435/500
#  - 5s - loss: 0.0756 - accuracy: 0.9602 - val_loss: 0.2088 - val_accuracy: 0.9414
#
# Epoch 00435: val_accuracy did not improve from 0.94575
# Epoch 436/500
#  - 6s - loss: 0.0813 - accuracy: 0.9581 - val_loss: 0.1314 - val_accuracy: 0.9399
#
# Epoch 00436: val_accuracy did not improve from 0.94575
# Epoch 437/500
#  - 6s - loss: 0.0711 - accuracy: 0.9621 - val_loss: 0.0360 - val_accuracy: 0.9445
#
# Epoch 00437: val_accuracy did not improve from 0.94575
# Epoch 438/500
#  - 6s - loss: 0.0753 - accuracy: 0.9606 - val_loss: 0.1936 - val_accuracy: 0.9449
#
# Epoch 00438: val_accuracy did not improve from 0.94575
# Epoch 439/500
#  - 6s - loss: 0.0760 - accuracy: 0.9603 - val_loss: 0.2553 - val_accuracy: 0.9377
#
# Epoch 00439: val_accuracy did not improve from 0.94575
# Epoch 440/500
#  - 5s - loss: 0.0724 - accuracy: 0.9619 - val_loss: 0.0218 - val_accuracy: 0.9334
#
# Epoch 00440: val_accuracy did not improve from 0.94575
# Epoch 441/500
#  - 6s - loss: 0.0719 - accuracy: 0.9623 - val_loss: 0.0111 - val_accuracy: 0.9418
#
# Epoch 00441: val_accuracy did not improve from 0.94575
# Epoch 442/500
#  - 6s - loss: 0.0752 - accuracy: 0.9605 - val_loss: 0.2431 - val_accuracy: 0.9517
#
# Epoch 00442: val_accuracy improved from 0.94575 to 0.95167, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 443/500
#  - 6s - loss: 0.0733 - accuracy: 0.9616 - val_loss: 0.1087 - val_accuracy: 0.9355
#
# Epoch 00443: val_accuracy did not improve from 0.95167
# Epoch 444/500
#  - 6s - loss: 0.0789 - accuracy: 0.9592 - val_loss: 0.2593 - val_accuracy: 0.9369
#
# Epoch 00444: val_accuracy did not improve from 0.95167
# Epoch 445/500
#  - 6s - loss: 0.0725 - accuracy: 0.9619 - val_loss: 0.6658 - val_accuracy: 0.9431
#
# Epoch 00445: val_accuracy did not improve from 0.95167
# Epoch 446/500
#  - 6s - loss: 0.0715 - accuracy: 0.9624 - val_loss: 0.0688 - val_accuracy: 0.9400
#
# Epoch 00446: val_accuracy did not improve from 0.95167
# Epoch 447/500
#  - 6s - loss: 0.0765 - accuracy: 0.9603 - val_loss: 0.1406 - val_accuracy: 0.9325
#
# Epoch 00447: val_accuracy did not improve from 0.95167
# Epoch 448/500
#  - 6s - loss: 0.0694 - accuracy: 0.9634 - val_loss: 0.3565 - val_accuracy: 0.9231
#
# Epoch 00448: val_accuracy did not improve from 0.95167
# Epoch 449/500
#  - 5s - loss: 0.0751 - accuracy: 0.9606 - val_loss: 0.2794 - val_accuracy: 0.9439
#
# Epoch 00449: val_accuracy did not improve from 0.95167
# Epoch 450/500
#  - 5s - loss: 0.0707 - accuracy: 0.9632 - val_loss: 0.1747 - val_accuracy: 0.9391
#
# Epoch 00450: val_accuracy did not improve from 0.95167
# Epoch 451/500
#  - 6s - loss: 0.0721 - accuracy: 0.9625 - val_loss: 0.2972 - val_accuracy: 0.9358
#
# Epoch 00451: val_accuracy did not improve from 0.95167
# Epoch 452/500
#  - 5s - loss: 0.0731 - accuracy: 0.9621 - val_loss: 0.1820 - val_accuracy: 0.9356
#
# Epoch 00452: val_accuracy did not improve from 0.95167
# Epoch 453/500
#  - 6s - loss: 0.0699 - accuracy: 0.9633 - val_loss: 0.0688 - val_accuracy: 0.9421
#
# Epoch 00453: val_accuracy did not improve from 0.95167
# Epoch 454/500
#  - 6s - loss: 0.0736 - accuracy: 0.9622 - val_loss: 0.7464 - val_accuracy: 0.9412
#
# Epoch 00454: val_accuracy did not improve from 0.95167
# Epoch 455/500
#  - 6s - loss: 0.0707 - accuracy: 0.9627 - val_loss: 0.0503 - val_accuracy: 0.9389
#
# Epoch 00455: val_accuracy did not improve from 0.95167
# Epoch 456/500
#  - 5s - loss: 0.0723 - accuracy: 0.9620 - val_loss: 0.1375 - val_accuracy: 0.9437
#
# Epoch 00456: val_accuracy did not improve from 0.95167
# Epoch 457/500
#  - 6s - loss: 0.0711 - accuracy: 0.9629 - val_loss: 0.2552 - val_accuracy: 0.9393
#
# Epoch 00457: val_accuracy did not improve from 0.95167
# Epoch 458/500
#  - 6s - loss: 0.0724 - accuracy: 0.9622 - val_loss: 0.1100 - val_accuracy: 0.9516
#
# Epoch 00458: val_accuracy did not improve from 0.95167
# Epoch 459/500
#  - 5s - loss: 0.0686 - accuracy: 0.9638 - val_loss: 0.5852 - val_accuracy: 0.9394
#
# Epoch 00459: val_accuracy did not improve from 0.95167
# Epoch 460/500
#  - 6s - loss: 0.0787 - accuracy: 0.9605 - val_loss: 0.0547 - val_accuracy: 0.9362
#
# Epoch 00460: val_accuracy did not improve from 0.95167
# Epoch 461/500
#  - 6s - loss: 0.0686 - accuracy: 0.9640 - val_loss: 0.2164 - val_accuracy: 0.9456
#
# Epoch 00461: val_accuracy did not improve from 0.95167
# Epoch 462/500
#  - 6s - loss: 0.0673 - accuracy: 0.9646 - val_loss: 0.1990 - val_accuracy: 0.9374
#
# Epoch 00462: val_accuracy did not improve from 0.95167
# Epoch 463/500
#  - 6s - loss: 0.0736 - accuracy: 0.9619 - val_loss: 0.2985 - val_accuracy: 0.9516
#
# Epoch 00463: val_accuracy did not improve from 0.95167
# Epoch 464/500
#  - 5s - loss: 0.0657 - accuracy: 0.9654 - val_loss: 0.2396 - val_accuracy: 0.9409
#
# Epoch 00464: val_accuracy did not improve from 0.95167
# Epoch 465/500
#  - 5s - loss: 0.0713 - accuracy: 0.9632 - val_loss: 0.8756 - val_accuracy: 0.9355
#
# Epoch 00465: val_accuracy did not improve from 0.95167
# Epoch 466/500
#  - 6s - loss: 0.0686 - accuracy: 0.9641 - val_loss: 0.4177 - val_accuracy: 0.9366
#
# Epoch 00466: val_accuracy did not improve from 0.95167
# Epoch 467/500
#  - 5s - loss: 0.0673 - accuracy: 0.9650 - val_loss: 0.0768 - val_accuracy: 0.9447
#
# Epoch 00467: val_accuracy did not improve from 0.95167
# Epoch 468/500
#  - 5s - loss: 0.0698 - accuracy: 0.9640 - val_loss: 0.1031 - val_accuracy: 0.9394
#
# Epoch 00468: val_accuracy did not improve from 0.95167
# Epoch 469/500
#  - 6s - loss: 0.0736 - accuracy: 0.9624 - val_loss: 0.4787 - val_accuracy: 0.9446
#
# Epoch 00469: val_accuracy did not improve from 0.95167
# Epoch 470/500
#  - 6s - loss: 0.0668 - accuracy: 0.9650 - val_loss: 0.3054 - val_accuracy: 0.9384
#
# Epoch 00470: val_accuracy did not improve from 0.95167
# Epoch 471/500
#  - 6s - loss: 0.0732 - accuracy: 0.9628 - val_loss: 0.1926 - val_accuracy: 0.9393
#
# Epoch 00471: val_accuracy did not improve from 0.95167
# Epoch 472/500
#  - 6s - loss: 0.0649 - accuracy: 0.9658 - val_loss: 0.5382 - val_accuracy: 0.9281
#
# Epoch 00472: val_accuracy did not improve from 0.95167
# Epoch 473/500
#  - 6s - loss: 0.0677 - accuracy: 0.9647 - val_loss: 0.0816 - val_accuracy: 0.9399
#
# Epoch 00473: val_accuracy did not improve from 0.95167
# Epoch 474/500
#  - 5s - loss: 0.0667 - accuracy: 0.9655 - val_loss: 0.1459 - val_accuracy: 0.9260
#
# Epoch 00474: val_accuracy did not improve from 0.95167
# Epoch 475/500
#  - 6s - loss: 0.0682 - accuracy: 0.9642 - val_loss: 0.3625 - val_accuracy: 0.9433
#
# Epoch 00475: val_accuracy did not improve from 0.95167
# Epoch 476/500
#  - 6s - loss: 0.0680 - accuracy: 0.9648 - val_loss: 0.4810 - val_accuracy: 0.9421
#
# Epoch 00476: val_accuracy did not improve from 0.95167
# Epoch 477/500
#  - 6s - loss: 0.0673 - accuracy: 0.9650 - val_loss: 0.1352 - val_accuracy: 0.9480
#
# Epoch 00477: val_accuracy did not improve from 0.95167
# Epoch 478/500
#  - 6s - loss: 0.0645 - accuracy: 0.9662 - val_loss: 0.2600 - val_accuracy: 0.9429
# Epoch 00478: val_accuracy did not improve from 0.95167
# Epoch 479/500
#  - 6s - loss: 0.0688 - accuracy: 0.9642 - val_loss: 0.0933 - val_accuracy: 0.9451
#
# Epoch 00479: val_accuracy did not improve from 0.95167
# Epoch 480/500
#  - 6s - loss: 0.0647 - accuracy: 0.9663 - val_loss: 0.1019 - val_accuracy: 0.9408
#
# Epoch 00480: val_accuracy did not improve from 0.95167
# Epoch 481/500
#  - 5s - loss: 0.0654 - accuracy: 0.9658 - val_loss: 0.0336 - val_accuracy: 0.9519
#
# Epoch 00481: val_accuracy improved from 0.95167 to 0.95195, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 482/500
#  - 6s - loss: 0.0707 - accuracy: 0.9641 - val_loss: 0.1806 - val_accuracy: 0.9342
#
# Epoch 00482: val_accuracy did not improve from 0.95195
# Epoch 483/500
#  - 6s - loss: 0.0617 - accuracy: 0.9675 - val_loss: 0.0989 - val_accuracy: 0.9401
#
# Epoch 00483: val_accuracy did not improve from 0.95195
# Epoch 484/500
#  - 6s - loss: 0.0671 - accuracy: 0.9654 - val_loss: 0.0853 - val_accuracy: 0.9435
#
# Epoch 00484: val_accuracy did not improve from 0.95195
# Epoch 485/500
#  - 6s - loss: 0.0626 - accuracy: 0.9672 - val_loss: 0.2918 - val_accuracy: 0.9499
#
# Epoch 00485: val_accuracy did not improve from 0.95195
# Epoch 486/500
#  - 6s - loss: 0.0667 - accuracy: 0.9652 - val_loss: 0.5125 - val_accuracy: 0.9440
#
# Epoch 00486: val_accuracy did not improve from 0.95195
# Epoch 487/500
#  - 6s - loss: 0.0630 - accuracy: 0.9670 - val_loss: 0.2080 - val_accuracy: 0.9265
#
# Epoch 00487: val_accuracy did not improve from 0.95195
# Epoch 488/500
#  - 5s - loss: 0.0670 - accuracy: 0.9652 - val_loss: 0.1918 - val_accuracy: 0.9499
#
# Epoch 00488: val_accuracy did not improve from 0.95195
# Epoch 489/500
#  - 6s - loss: 0.0659 - accuracy: 0.9661 - val_loss: 0.1597 - val_accuracy: 0.9390
#
# Epoch 00489: val_accuracy did not improve from 0.95195
# Epoch 490/500
#  - 5s - loss: 0.0640 - accuracy: 0.9665 - val_loss: 0.1428 - val_accuracy: 0.9319
#
# Epoch 00490: val_accuracy did not improve from 0.95195
# Epoch 491/500
#  - 6s - loss: 0.0630 - accuracy: 0.9669 - val_loss: 0.2092 - val_accuracy: 0.9442
#
# Epoch 00491: val_accuracy did not improve from 0.95195
# Epoch 492/500
#  - 6s - loss: 0.0650 - accuracy: 0.9661 - val_loss: 0.0830 - val_accuracy: 0.9447
#
# Epoch 00492: val_accuracy did not improve from 0.95195
# Epoch 493/500
#  - 6s - loss: 0.0634 - accuracy: 0.9671 - val_loss: 0.0689 - val_accuracy: 0.9447
#
# Epoch 00493: val_accuracy did not improve from 0.95195
# Epoch 494/500
#  - 6s - loss: 0.0635 - accuracy: 0.9671 - val_loss: 0.2171 - val_accuracy: 0.9481
#
# Epoch 00494: val_accuracy did not improve from 0.95195
# Epoch 495/500
#  - 6s - loss: 0.0635 - accuracy: 0.9673 - val_loss: 0.1556 - val_accuracy: 0.9410
#
# Epoch 00495: val_accuracy did not improve from 0.95195
# Epoch 496/500
#  - 6s - loss: 0.0616 - accuracy: 0.9680 - val_loss: 0.5280 - val_accuracy: 0.9420
#
# Epoch 00496: val_accuracy did not improve from 0.95195
# Epoch 497/500
#  - 5s - loss: 0.0627 - accuracy: 0.9676 - val_loss: 0.6129 - val_accuracy: 0.9309
#
# Epoch 00497: val_accuracy did not improve from 0.95195
# Epoch 498/500
#  - 6s - loss: 0.0653 - accuracy: 0.9666 - val_loss: 0.1476 - val_accuracy: 0.9352
#
# Epoch 00498: val_accuracy did not improve from 0.95195
# Epoch 499/500
#  - 5s - loss: 0.0630 - accuracy: 0.9672 - val_loss: 0.1044 - val_accuracy: 0.9521
#
# Epoch 00499: val_accuracy improved from 0.95195 to 0.95210, saving model to model/rapid_ascending 30_84_macd.hdf5
# Epoch 500/500
#  - 6s - loss: 0.0618 - accuracy: 0.9681 - val_loss: 0.3344 - val_accuracy: 0.9317
#
# Epoch 00500: val_accuracy did not improve from 0.95210

# %%
from keras.models import load_model

model = load_model('model/rapid_ascending %s_%s.hdf5' % (input_data_length, model_num))
# model = load_model('/content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending %s.hdf5' % input_data_length)
# loss = model.evaluate_generator(test_flow, steps=len(X_test) / batch_size) 
# print("Test Loss " + str(loss[0]))
# print("Test Acc: " + str(loss[1]))

# loss = model.evaluate(X_val, Y_val) 
# print(X_val.shape)
# print(Y_val.shape)

# print("Val Loss " + str(loss[0]))
# print("Val Acc: " + str(loss[1]))

#     Prediction    #
Y_pred_ = model.predict(X_test, verbose=1)

# Y_pred = Y_pred_[:,[-1]]
# print(Y_pred.shape)
# print(Y_test.shape)
Y_pred = np.argmax(Y_pred_, axis=1)
t_te = np.argmax(Y_test, axis=1)

#     Manual processing     #
Y_pred_one = Y_pred_[:, [-1]]
print(Y_pred_)
max_value = np.max(Y_pred_one)
print(max_value)

limit_line = 0.9
Y_pred_one = np.where(Y_pred_one > max_value * limit_line, 1, 0)

# print(Y_pred_one)
Y_pred_one = Y_pred_one.reshape(-1,)
# print(Y_pred_1)
# print(Y_pred.shape)
# print(t_te.shape)

# fail = 0
# fail2 = 0
# for i in range(len(Y_pred)):
#   if Y_pred_1[i] != t_te[i]:
#     fail += 1

#   if Y_pred[i] != t_te[i]:
#     fail2 += 1

# print(1 - fail / len(Y_pred))
# print(1 - fail2 / len(Y_pred))

# print(np.sum(Y_pred), np.sum(t_te))
# print('Y_pred / Y_test :', np.sum(Y_pred) / np.sum(t_te))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(100,10))
plt.subplot(211)
plt.plot(Y_test, 'purple', label='test')

plt.subplot(212)
plt.plot(Y_pred_one, 'y', label='pred')
plt.show()
# plt.savefig('/content/gdrive/My Drive/Colab Notebooks/model/rapid_ascending %s.png' % input_data_length)
# plt.close()
